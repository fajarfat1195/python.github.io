# %%
import gspread
import pandas as pd
from fractions import Fraction

# Pastikan permision access di menu "Share" di rubah ke anyone with the link terlebih dahulu, agar bisa mengunakan cara OAuth
# Jika Ingin lebih dibatasi menggunakan cara google service account lebih disarankan

gc = gspread.oauth(
    credentials_filename= r'C:\Users\fajar\Documents\Python\Data\Google Credentials\karma-oauth.json'
)

SHEET_ID = '1_O4_ZmZJe86gS_qiz7W0PZ2-USiVIFbVu6U7XWXCBUk'
SHEET_NAME = 'Sheet1'

# %%
# Open the spreadsheet
spreadsheet_source = gc.open_by_key(SHEET_ID)

# Get all sheet names
sheet_names = [sheet.title for sheet in spreadsheet_source.worksheets()]
sheet_names
# Out:
# ['Sheet1']

# %%
# get data gsheet

spreadsheet = gc.open_by_key(SHEET_ID)
worksheet = spreadsheet.worksheet(SHEET_NAME)
rows = worksheet.get_all_records()

# print(rows[:5])

# print('==============================')
# df = pd.DataFrame(rows, dtype="string")
df = pd.DataFrame(rows)
# df['Mobile Number'] = df['Mobile Number'].apply(Fraction)
df
# Out:
#                                         Email                         Name  \
# 0     KarmaIndia.salesmanagers@karmagroup.com  Karma India. Sales Managers
# 1                  johnandmel1@btinternet.com                 John Windley
# 2                         chasdove@icloud.com                 Charlie Dove
# 3                     jane.bryant52@gmail.com                  Jane Bryant
# 4                       marita2006@hotmail.de             Douglas Cornwell
# ...                                       ...                          ...
# 8908         reception.odyssey@karmagroup.com            Reception Odyssey
# 8909       clinton.albuquerque@karmagroup.com          Clinton Albuquerque
# 8910               wayan.wirka@karmagroup.com                I Wayan Wirka
# 8911         jessica.whytcross@karmagroup.com        Jessica May Whytcross
# 8912               ayu.febrina@karmagroup.com                  Ayu Febrina
#
#       Total Opens  Total Clicks
# 0              25             0
# 1              11             1
# 2               8             0
# 3               7             0
# 4               6             0
# ...           ...           ...
# 8908            1             0
# 8909            1             0
# 8910            1             0
# 8911            1             0
# 8912            1             0
#
# [8913 rows x 4 columns]

# %%
df.drop(df.loc[df['Email'].str.contains('karmagroup')].index, inplace=True)
df.loc[df['Email'].str.contains('karmagroup')]
# Out:
# Empty DataFrame
# Columns: [Email, Name, Total Opens, Total Clicks]
# Index: []

# %%
df
# Out:
#                            Email                   Name  Total Opens  \
# 1     johnandmel1@btinternet.com           John Windley           11
# 2            chasdove@icloud.com           Charlie Dove            8
# 3        jane.bryant52@gmail.com            Jane Bryant            7
# 4          marita2006@hotmail.de       Douglas Cornwell            6
# 5         janosul@btinternet.com     Patrick O'Sullivan            6
# ...                          ...                    ...          ...
# 8896          bems.rpm@gmail.com        Bambang Saputra            1
# 8897      delfimetiary@gmail.com  Delfianus J.m.metiary            1
# 8898    purilokasadewa@gmail.com                 #NAME?            1
# 8899      Pindonta2104@gmail.com             Linda Sari            1
# 8900          m.reki@yahoo.co.id           Reki Mailoor            1
#
#       Total Clicks
# 1                1
# 2                0
# 3                0
# 4                0
# 5                2
# ...            ...
# 8896             0
# 8897             0
# 8898             0
# 8899             0
# 8900             0
#
# [8830 rows x 4 columns]
