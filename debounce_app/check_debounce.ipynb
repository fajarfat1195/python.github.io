# %%
import sys
sys.path.append('../zoho_data_app/')

import main_module as m
import zoho_filter_module as fil
import pandas as pd
import re
import numpy as np

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
path = r'C:\Users\fajar\Documents\Python\Data\Leads_2024_12_11.csv'
df_push = pd.read_csv(path, dtype='string')
# df_push = pd.read_excel(path, dtype='string', sheet_name='Sheet1')

df_push.reset_index(drop=True, inplace=True)
count_total_data = df_push.shape[0]

# mengisi kolom <NA> dengan value string 'empty' supaya mudah mengecek data member dan booking dengan isin
df_push.fillna('empty', inplace=True)
df_push
# Out:
#                       Record Id         Created Time  \
# 0      zcrm_3584690000005979529  2019-04-02 02:18:01
# 1      zcrm_3584690000095921978  2019-08-16 16:51:55
# 2      zcrm_3584690000158011261  2020-01-09 19:48:59
# 3      zcrm_3584690000176244166  2020-03-19 16:18:41
# 4      zcrm_3584690000311007503  2021-08-27 11:49:35
# ...                         ...                  ...
# 11730  zcrm_3584690000517862338  2024-12-09 12:22:38
# 11731  zcrm_3584690000517868117  2024-12-09 12:18:17
# 11732  zcrm_3584690000517868216  2024-12-09 12:21:07
# 11733  zcrm_3584690000517868354  2024-12-09 12:23:57
# 11734  zcrm_3584690000517869379  2024-12-09 12:24:03
#
#                                Email     Lead Brand Lead Sub-Brand  \
# 0              csolomon@iinet.net.au  Karma Resorts          Other
# 1            floraloizou@hotmail.com  Karma Resorts          Other
# 2               sidthacker@gmail.com  Karma Resorts          Other
# 3            chris-karen@outlook.com  Karma Resorts          Other
# 4                              empty  Karma Resorts  Karma Sanctum
# ...                              ...            ...            ...
# 11730   elaine64bruce@btinternet.com  Karma Resorts          Other
# 11731            wwjdmerci@yahoo.com  Karma Resorts          Other
# 11732            fimac30@hotmail.com  Karma Resorts          Other
# 11733  paul.broughall@btinternet.com  Karma Resorts          Other
# 11734           kimmyb1104@gmail.com  Karma Resorts          Other
#
#        Lead Source Lead Source Description        First Name   Last Name  \
# 0      Past Guests                   empty              Carl     Solomon
# 1      Past Guests               Viewpoint             Flora      Loizou
# 2      Past Guests                   empty  Rohit Ramnarayan      Laddha
# 3      Past Guests               Viewpoint             Chris    Jennings
# 4      Past Guests                   empty               Mr.  Alan Brown
# ...            ...                     ...               ...         ...
# 11730  Past Guests               Viewpoint            Elaine       Bruce
# 11731  Past Guests               Viewpoint             Merci      Clarke
# 11732  Past Guests               Viewpoint             Fiona   Macdonald
# 11733  Past Guests               Viewpoint            Paul G   Broughall
# 11734  Past Guests               Viewpoint               Kim       Brown
#
#                Phone  ... United Kingdom GDPR Compliant Opt In  \
# 0       +61400833311  ...          false          false  false
# 1      +447587007823  ...           true           true   true
# 2      +919714357520  ...          false          false  false
# 3      +447733154624  ...           true           true   true
# 4      +442035640799  ...           true          false  false
# ...              ...  ...            ...            ...    ...
# 11730  +447790433240  ...           true           true   true
# 11731  +447766812319  ...           true           true   true
# 11732  +447936348965  ...           true          false   true
# 11733  +447776445566  ...           true           true   true
# 11734  +447852151231  ...           true           true   true
#
#       Agree with Terms and Condition Enquiry sent to     Contact type  \
# 0                              false           empty  Email and Phone
# 1                              false           empty  Email And Phone
# 2                              false           empty            empty
# 3                              false           empty  Email And Phone
# 4                              false           empty       Phone Only
# ...                              ...             ...              ...
# 11730                          false           empty  Email and Phone
# 11731                          false           empty  Email and Phone
# 11732                          false           empty  Email and Phone
# 11733                          false           empty  Email and Phone
# 11734                          false           empty  Email and Phone
#
#       Messages Preferred Destination Odyssey Members Odyssey Member ID
# 0        empty                 empty           false             empty
# 1        empty                 empty           false             empty
# 2        empty                 empty           false             empty
# 3        empty          Karma Mayura           false             empty
# 4        empty                 empty           false             empty
# ...        ...                   ...             ...               ...
# 11730    empty                 empty           false             empty
# 11731    empty                 empty           false             empty
# 11732    empty                 empty           false             empty
# 11733    empty                 empty           false             empty
# 11734    empty                 empty           false             empty
#
# [11735 rows x 34 columns]

# %%
path = r'C:\Users\fajar\Documents\Python\Data\Debounce\debounce_backup.csv'
df_1 = pd.read_csv(path, dtype='string')

path = r'C:\Users\fajar\Documents\Python\Data\Debounce\debounce_new_temp.csv'
df_2 = pd.read_csv(path, dtype='string')


frames = [df_1, df_2]
df_bounced = pd.concat(frames, ignore_index=True)
df_bounced
# Out:
#                                  EMAIL        RESULT       REASON STATUS CODE  \
# 0                00001111den@gmail.com  Safe to Send  Deliverable           5
# 1        007dhananjaykumbhar@gmail.com  Safe to Send  Deliverable           5
# 2                      0597396@mail.ru  Safe to Send  Deliverable           5
# 3                07deepanshu@gmail.com  Safe to Send  Deliverable           5
# 4                    1078049354@qq.com  Safe to Send  Deliverable           5
# ...                                ...           ...          ...         ...
# 1266206         amanmadaan80@gmail.com  Safe to Send  Deliverable           5
# 1266207             vik.4151@ymail.com  Safe to Send  Deliverable           5
# 1266208       bhattmandar444@gmail.com  Safe to Send  Deliverable           5
# 1266209           ravina2394@gmail.com  Safe to Send  Deliverable           5
# 1266210            dlc_fea@yahoo.co.uk  Safe to Send  Deliverable           5
#
#           ROLE   FREE     DOMAIN    Sheet Name
# 0           No    Yes  gmail.com  All Campaign
# 1           No    Yes  gmail.com  All Campaign
# 2           No    Yes    mail.ru  All Campaign
# 3           No    Yes  gmail.com  All Campaign
# 4           No    Yes     qq.com  All Campaign
# ...        ...    ...        ...           ...
# 1266206  FALSE  FALSE       <NA>          <NA>
# 1266207  FALSE  FALSE       <NA>          <NA>
# 1266208  FALSE  FALSE       <NA>          <NA>
# 1266209  FALSE  FALSE       <NA>          <NA>
# 1266210  FALSE  FALSE       <NA>          <NA>
#
# [1266211 rows x 8 columns]

# %%
df_bounced['EMAIL'] = m.lowercase(df_bounced, 'EMAIL')
m.clean_space(df_bounced, 'EMAIL')
# Out:
# 0                  00001111den@gmail.com
# 1          007dhananjaykumbhar@gmail.com
# 2                        0597396@mail.ru
# 3                  07deepanshu@gmail.com
# 4                      1078049354@qq.com
#                        ...
# 1266206           amanmadaan80@gmail.com
# 1266207               vik.4151@ymail.com
# 1266208         bhattmandar444@gmail.com
# 1266209             ravina2394@gmail.com
# 1266210              dlc_fea@yahoo.co.uk
# Name: EMAIL, Length: 1266211, dtype: string

# %% [markdown]
# # ====================== Awal Filter Umum ======================

# %%
df_bounced.drop_duplicates(subset='EMAIL', inplace=True)
df_bounced.reset_index(drop=True, inplace=True)
df_bounced
# Out:
#                                  EMAIL        RESULT       REASON STATUS CODE  \
# 0                00001111den@gmail.com  Safe to Send  Deliverable           5
# 1        007dhananjaykumbhar@gmail.com  Safe to Send  Deliverable           5
# 2                      0597396@mail.ru  Safe to Send  Deliverable           5
# 3                07deepanshu@gmail.com  Safe to Send  Deliverable           5
# 4                    1078049354@qq.com  Safe to Send  Deliverable           5
# ...                                ...           ...          ...         ...
# 1020063         amanmadaan80@gmail.com  Safe to Send  Deliverable           5
# 1020064             vik.4151@ymail.com  Safe to Send  Deliverable           5
# 1020065       bhattmandar444@gmail.com  Safe to Send  Deliverable           5
# 1020066           ravina2394@gmail.com  Safe to Send  Deliverable           5
# 1020067            dlc_fea@yahoo.co.uk  Safe to Send  Deliverable           5
#
#           ROLE   FREE     DOMAIN    Sheet Name
# 0           No    Yes  gmail.com  All Campaign
# 1           No    Yes  gmail.com  All Campaign
# 2           No    Yes    mail.ru  All Campaign
# 3           No    Yes  gmail.com  All Campaign
# 4           No    Yes     qq.com  All Campaign
# ...        ...    ...        ...           ...
# 1020063  FALSE  FALSE       <NA>          <NA>
# 1020064  FALSE  FALSE       <NA>          <NA>
# 1020065  FALSE  FALSE       <NA>          <NA>
# 1020066  FALSE  FALSE       <NA>          <NA>
# 1020067  FALSE  FALSE       <NA>          <NA>
#
# [1020068 rows x 8 columns]

# %%
df_push['Email'] = m.lowercase(df_push, 'Email')
m.clean_space(df_push, 'Email')

df_bounced['EMAIL'] = m.lowercase(df_bounced, 'EMAIL')
m.clean_space(df_bounced, 'EMAIL')
# Out:
# 0                  00001111den@gmail.com
# 1          007dhananjaykumbhar@gmail.com
# 2                        0597396@mail.ru
# 3                  07deepanshu@gmail.com
# 4                      1078049354@qq.com
#                        ...
# 1020063           amanmadaan80@gmail.com
# 1020064               vik.4151@ymail.com
# 1020065         bhattmandar444@gmail.com
# 1020066             ravina2394@gmail.com
# 1020067              dlc_fea@yahoo.co.uk
# Name: EMAIL, Length: 1020068, dtype: string

# %%
df_push.loc[df_push['Email'].isin(df_bounced['EMAIL'])]
# Out:
#                       Record Id         Created Time  \
# 0      zcrm_3584690000005979529  2019-04-02 02:18:01
# 1      zcrm_3584690000095921978  2019-08-16 16:51:55
# 2      zcrm_3584690000158011261  2020-01-09 19:48:59
# 3      zcrm_3584690000176244166  2020-03-19 16:18:41
# 5      zcrm_3584690000317737345  2021-09-29 21:55:25
# ...                         ...                  ...
# 11707  zcrm_3584690000516315248  2024-11-25 12:34:37
# 11708  zcrm_3584690000516315251  2024-11-25 12:34:37
# 11709  zcrm_3584690000516315256  2024-11-25 12:34:37
# 11710  zcrm_3584690000516315261  2024-11-25 12:34:37
# 11727  zcrm_3584690000517850140  2024-12-09 12:14:26
#
#                                 Email     Lead Brand Lead Sub-Brand  \
# 0               csolomon@iinet.net.au  Karma Resorts          Other
# 1             floraloizou@hotmail.com  Karma Resorts          Other
# 2                sidthacker@gmail.com  Karma Resorts          Other
# 3             chris-karen@outlook.com  Karma Resorts          Other
# 5              gholland6060@gmail.com  Karma Resorts          Other
# ...                               ...            ...            ...
# 11707           jturneris@yahoo.co.uk  Karma Resorts          Other
# 11708  laura_blondie_26@hotmail.co.uk  Karma Resorts          Other
# 11709   sharonnewman@blueyonder.co.uk  Karma Resorts          Other
# 11710    lyndsaymcgowan@hotmail.co.uk  Karma Resorts          Other
# 11727            jimmy.lind@gmail.com  Karma Resorts          Other
#
#        Lead Source Lead Source Description        First Name        Last Name  \
# 0      Past Guests                   empty              Carl          Solomon
# 1      Past Guests               Viewpoint             Flora           Loizou
# 2      Past Guests                   empty  Rohit Ramnarayan           Laddha
# 3      Past Guests               Viewpoint             Chris         Jennings
# 5      Past Guests               Viewpoint            George          Holland
# ...            ...                     ...               ...              ...
# 11707  Past Guests               Viewpoint               Jim         Hamilton
# 11708  Past Guests               Viewpoint            Andrew        Fieldsend
# 11709  Past Guests               Viewpoint            Karren            Allan
# 11710  Past Guests               Viewpoint           Lyndsay  Gemmell-Mcgowan
# 11727  Past Guests                   empty             James             Lind
#
#                Phone  ... United Kingdom GDPR Compliant Opt In  \
# 0       +61400833311  ...          false          false  false
# 1      +447587007823  ...           true           true   true
# 2      +919714357520  ...          false          false  false
# 3      +447733154624  ...           true           true   true
# 5        13027574150  ...          false          false  false
# ...              ...  ...            ...            ...    ...
# 11707  +447578014514  ...          false           true   true
# 11708  +447851224881  ...          false           true   true
# 11709  +447854820388  ...          false           true   true
# 11710  +447800600925  ...          false           true   true
# 11727  +447865077538  ...           true           true   true
#
#       Agree with Terms and Condition Enquiry sent to     Contact type  \
# 0                              false           empty  Email and Phone
# 1                              false           empty  Email And Phone
# 2                              false           empty            empty
# 3                              false           empty  Email And Phone
# 5                              false           empty  Email And Phone
# ...                              ...             ...              ...
# 11707                          false           empty  Email And Phone
# 11708                          false           empty  Email And Phone
# 11709                          false           empty  Email And Phone
# 11710                          false           empty  Email And Phone
# 11727                          false           empty  Email and Phone
#
#       Messages Preferred Destination Odyssey Members Odyssey Member ID
# 0        empty                 empty           false             empty
# 1        empty                 empty           false             empty
# 2        empty                 empty           false             empty
# 3        empty          Karma Mayura           false             empty
# 5        empty                 empty           false             empty
# ...        ...                   ...             ...               ...
# 11707    empty                 empty           false             empty
# 11708    empty                 empty           false             empty
# 11709    empty                 empty           false             empty
# 11710    empty                 empty           false             empty
# 11727    empty                 empty           false             empty
#
# [10060 rows x 34 columns]

# %%
joined_df = pd.merge(df_push,
                     df_bounced,
                     left_on ='Email',
                     right_on ='EMAIL',
                     how ='left')
joined_df
# Out:
#                       Record Id         Created Time  \
# 0      zcrm_3584690000005979529  2019-04-02 02:18:01
# 1      zcrm_3584690000095921978  2019-08-16 16:51:55
# 2      zcrm_3584690000158011261  2020-01-09 19:48:59
# 3      zcrm_3584690000176244166  2020-03-19 16:18:41
# 4      zcrm_3584690000311007503  2021-08-27 11:49:35
# ...                         ...                  ...
# 11730  zcrm_3584690000517862338  2024-12-09 12:22:38
# 11731  zcrm_3584690000517868117  2024-12-09 12:18:17
# 11732  zcrm_3584690000517868216  2024-12-09 12:21:07
# 11733  zcrm_3584690000517868354  2024-12-09 12:23:57
# 11734  zcrm_3584690000517869379  2024-12-09 12:24:03
#
#                                Email     Lead Brand Lead Sub-Brand  \
# 0              csolomon@iinet.net.au  Karma Resorts          Other
# 1            floraloizou@hotmail.com  Karma Resorts          Other
# 2               sidthacker@gmail.com  Karma Resorts          Other
# 3            chris-karen@outlook.com  Karma Resorts          Other
# 4                              empty  Karma Resorts  Karma Sanctum
# ...                              ...            ...            ...
# 11730   elaine64bruce@btinternet.com  Karma Resorts          Other
# 11731            wwjdmerci@yahoo.com  Karma Resorts          Other
# 11732            fimac30@hotmail.com  Karma Resorts          Other
# 11733  paul.broughall@btinternet.com  Karma Resorts          Other
# 11734           kimmyb1104@gmail.com  Karma Resorts          Other
#
#        Lead Source Lead Source Description        First Name   Last Name  \
# 0      Past Guests                   empty              Carl     Solomon
# 1      Past Guests               Viewpoint             Flora      Loizou
# 2      Past Guests                   empty  Rohit Ramnarayan      Laddha
# 3      Past Guests               Viewpoint             Chris    Jennings
# 4      Past Guests                   empty               Mr.  Alan Brown
# ...            ...                     ...               ...         ...
# 11730  Past Guests               Viewpoint            Elaine       Bruce
# 11731  Past Guests               Viewpoint             Merci      Clarke
# 11732  Past Guests               Viewpoint             Fiona   Macdonald
# 11733  Past Guests               Viewpoint            Paul G   Broughall
# 11734  Past Guests               Viewpoint               Kim       Brown
#
#                Phone  ... Odyssey Members Odyssey Member ID  \
# 0       +61400833311  ...           false             empty
# 1      +447587007823  ...           false             empty
# 2      +919714357520  ...           false             empty
# 3      +447733154624  ...           false             empty
# 4      +442035640799  ...           false             empty
# ...              ...  ...             ...               ...
# 11730  +447790433240  ...           false             empty
# 11731  +447766812319  ...           false             empty
# 11732  +447936348965  ...           false             empty
# 11733  +447776445566  ...           false             empty
# 11734  +447852151231  ...           false             empty
#
#                          EMAIL        RESULT       REASON STATUS CODE   ROLE  \
# 0        csolomon@iinet.net.au  Safe to Send  Deliverable           5     No
# 1      floraloizou@hotmail.com  Safe to Send  Deliverable           5  False
# 2         sidthacker@gmail.com  Safe to Send  Deliverable           5     No
# 3      chris-karen@outlook.com  Safe to Send  Deliverable           5  False
# 4                         <NA>          <NA>         <NA>        <NA>   <NA>
# ...                        ...           ...          ...         ...    ...
# 11730                     <NA>          <NA>         <NA>        <NA>   <NA>
# 11731                     <NA>          <NA>         <NA>        <NA>   <NA>
# 11732                     <NA>          <NA>         <NA>        <NA>   <NA>
# 11733                     <NA>          <NA>         <NA>        <NA>   <NA>
# 11734                     <NA>          <NA>         <NA>        <NA>   <NA>
#
#        FREE        DOMAIN          Sheet Name
# 0       Yes  iinet.net.au        Beambox KLOM
# 1      True          <NA>          Past Guest
# 2       Yes     gmail.com  KK Past Guests ALL
# 3      True          <NA>          Past Guest
# 4      <NA>          <NA>                <NA>
# ...     ...           ...                 ...
# 11730  <NA>          <NA>                <NA>
# 11731  <NA>          <NA>                <NA>
# 11732  <NA>          <NA>                <NA>
# 11733  <NA>          <NA>                <NA>
# 11734  <NA>          <NA>                <NA>
#
# [11735 rows x 42 columns]

# %%
joined_list = joined_df.loc[~joined_df['RESULT'].isna()].copy()
joined_list.reset_index(drop=True, inplace=True)

not_exist_list = joined_df.loc[joined_df['RESULT'].isna()].copy()
not_exist_list.reset_index(drop=True, inplace=True)

count_exist_in_bounce = joined_list.shape[0]
count_not_exist_in_bounce = not_exist_list.shape[0]

# %%
safe_to_send = joined_list.loc[joined_list['RESULT'] == 'Safe to Send'].copy()
safe_to_send.reset_index(drop=True, inplace=True)
count_safe_to_send = safe_to_send.shape[0]

ex_safe_to_send = joined_list.loc[joined_list['RESULT'] != 'Safe to Send'].copy()
ex_safe_to_send.reset_index(drop=True, inplace=True)
count_ex_safe_to_send = ex_safe_to_send.shape[0]

# %%
print("==========================================================")
print("Summary")
print("==========================================================")
print("Jumlah Total Data : "+str(count_total_data))
print("Jumlah Data Exist di Database Bounce : "+str(count_exist_in_bounce))
print("Jumlah Data Tidak Exist di Database Bounce : "+str(count_not_exist_in_bounce))
print("==========================================================")
print("Summary Bounced")
print("==========================================================")
print("Jumlah Data Safe to Send : "+str(count_safe_to_send))
print("Jumlah Data not Safe to Send : "+str(count_ex_safe_to_send))
# Out:
# ==========================================================
# Summary
# ==========================================================
# Jumlah Total Data : 11735
# Jumlah Data Exist di Database Bounce : 10060
# Jumlah Data Tidak Exist di Database Bounce : 1675
# ==========================================================
# Summary Bounced
# ==========================================================
# Jumlah Data Safe to Send : 8856
# Jumlah Data not Safe to Send : 1204

# %%
safe_to_send.replace('empty', '', inplace=True)
safe_to_send.reset_index(drop=True, inplace=True)
df_safe = safe_to_send.copy()
df_safe

df_safe[['Email','First Name','Last Name','RESULT']].to_csv(r'C:\Users\fajar\Documents\Python\Data\push-result.csv', index=False, encoding='utf-8')

# %%
# ex_safe_to_send.replace('empty', '', inplace=True)
# ex_safe_to_send.reset_index(drop=True, inplace=True)
# df_ex_safe_to_send = ex_safe_to_send.copy()
# df_ex_safe_to_send

# df_ex_safe_to_send[['Email','RESULT']].to_excel(r'C:\Users\fajar\Documents\Python\Data\not-safe-to-send-debounce.xlsx', index=False)

# %%
# not_exist_list.replace('empty', '', inplace=True)
# not_exist_list.reset_index(drop=True, inplace=True)
# df_not_exist = not_exist_list.copy()
# df_not_exist

# df_not_exist[['Email','RESULT']].to_excel(r'C:\Users\fajar\Documents\Python\Data\not-exist-debounce.xlsx', index=False)

# %%
# joined_df.to_excel(r'C:\Users\fajar\Documents\Python\Data\debounce-result.xlsx', index=False)
