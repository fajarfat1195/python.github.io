# %%
import main_module as m
import zoho_filter_module as fil
import pandas as pd
import re
import numpy as np

# %load_ext autoreload
# %autoreload 2

dir_path = r'C:\Users\fajar\Documents\Python\Data\Zoho_Backup'
file_name = '\Leads_'

cols = ['Record Id',	
'Created Time',
'Created Date',	
'First Name',	
'Last Name',	
'Email',	
'Phone',	
'Mobile',	
'Birthdate',	
'Year of Birth',
'Street',	
'Street2',	
'City',	
'State',	
'Country',	
'Nationality',
'Booking Status', 
'BookRef',
'Departure Date',	
'Arrival Date',	
'Card Type',	
'Marital Status',	
'Lead Brand',	
'Lead Sub-Brand',	
'Lead Source',	
'Lead Locations',	
'Lead Source Description',	
'Lead Regions',
'Lead Status',
'Email Opt Out',	
'Opt In']
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
df = m.load_data_multiple(dir_path, file_name, cols)
count_data_awal = df.shape[0]
df = df.reindex(columns=cols)
df.shape[0]

df['Created Time'] = pd.to_datetime(df['Created Time'], format='%Y-%m-%d %H:%M:%S')
df.dtypes
# Out:
# Record Id                          string
# Created Time               datetime64[ns]
# Created Date                       string
# First Name                         string
# Last Name                          string
# Email                              string
# Phone                              string
# Mobile                             string
# Birthdate                          string
# Year of Birth                      string
# Street                             string
# Street2                            string
# City                               string
# State                              string
# Country                            string
# Nationality                        string
# Booking Status                     string
# BookRef                            string
# Departure Date                     string
# Arrival Date                       string
# Card Type                          string
# Marital Status                     string
# Lead Brand                         string
# Lead Sub-Brand                     string
# Lead Source                        string
# Lead Locations                     string
# Lead Source Description            string
# Lead Regions                       string
# Lead Status                        string
# Email Opt Out                      string
# Opt In                             string
# dtype: object

# %%
path = r'G:\.shortcut-targets-by-id\0B_d3smBjzo04eXpvS1NXTWF2RVE\_BOOKING\Booking By Year\FlyBuy Booking Data (BGAU & BGID & KE).xlsx'
df_booking = pd.read_excel(path, dtype='string', sheet_name='booking Start feb 2021')

path = r'G:\.shortcut-targets-by-id\0B_d3smBjzo04UUNBME5GOVhoMjA\_ODYSSEY\Phone Members.xlsx'
df_phone = pd.read_excel(path, dtype='string', sheet_name='Sheet1')

path = r'G:\.shortcut-targets-by-id\0B_d3smBjzo04UUNBME5GOVhoMjA\_ODYSSEY\Email Members.xlsx'
df_email = pd.read_excel(path, dtype='string', sheet_name='Sheet1')

# %%
zoho_filter = fil.user_req(df)
zoho_df = df.loc[zoho_filter].copy() # menggunakan copy untuk menghindari setting copy warning
zoho_df.reset_index(drop=True, inplace=True)
count_filter_awal = zoho_df.shape[0]

# mengisi kolom <NA> dengan value string 'empty' supaya mudah mengecek data member dan booking dengan isin

zoho_df.fillna('empty', inplace=True)
zoho_df
# Out:
#                     Record Id        Created Time Created Date  First Name  \
# 0    zcrm_3584690000426781936 2023-02-06 13:12:19        empty       Kamna
# 1    zcrm_3584690000426927090 2023-02-06 13:17:14        empty       Sarah
# 2    zcrm_3584690000426932041 2023-02-06 13:16:48        empty        John
# 3    zcrm_3584690000426935052 2023-02-06 13:17:43        empty      Nathan
# 4    zcrm_3584690000428132582 2023-02-13 15:18:13        empty        Paul
# ..                        ...                 ...          ...         ...
# 174  zcrm_3584690000439838156 2023-04-10 12:52:55        empty      Kelvin
# 175  zcrm_3584690000439839377 2023-04-10 13:01:29        empty       Sonya
# 176  zcrm_3584690000439840143 2023-04-10 12:53:41        empty     Randhir
# 177  zcrm_3584690000439840661 2023-04-10 13:03:12        empty  Lisa Marie
# 178  zcrm_3584690000439852124 2023-04-10 13:02:33        empty      Nicola
#
#      Last Name                             Email          Phone  \
# 0       Kapoor    kamna.kapoor@yarratrams.com.au    61466947313
# 1       Noller                sarah@noller.id.au    61450429274
# 2        Major           majorbricks54@gmail.com    61406397873
# 3     Claypole         claypole.nathan@gmail.com    61430188682
# 4       Kottos              paulkottos@gmail.com    61414908909
# ..         ...                               ...            ...
# 174       Tjia                ktjia.kt@gmail.com  6181510539008
# 175   Stephens              molly2410@icloud.com    61438490055
# 176  Kowlessur  australia@luckydodomigration.com     6193052167
# 177  O'Donnell            lisaodonnell@email.com    61414445510
# 178    Bartley             nicola_ny@hotmail.com    61431410910
#
#             Mobile Birthdate Year of Birth  ... Marital Status     Lead Brand  \
# 0            empty     empty         empty  ...          empty  Karma Resorts
# 1      61450429274     empty         empty  ...          empty  Karma Resorts
# 2            empty     empty         empty  ...          empty  Karma Resorts
# 3            empty     empty         empty  ...          empty  Karma Resorts
# 4      61414908909     empty         empty  ...          empty  Karma Resorts
# ..             ...       ...           ...  ...            ...            ...
# 174  6181510539008     empty         empty  ...          empty  Karma Resorts
# 175          empty     empty         empty  ...          empty  Karma Resorts
# 176          empty     empty         empty  ...          empty  Karma Resorts
# 177          empty     empty         empty  ...          empty  Karma Resorts
# 178          empty     empty         empty  ...          empty  Karma Resorts
#
#     Lead Sub-Brand  Lead Source         Lead Locations  \
# 0            Other  Past Guests  Karma Royal Candidasa
# 1            Other  Past Guests      Karma Royal Sanur
# 2            Other  Past Guests  Karma Royal Candidasa
# 3            Other  Past Guests   Karma Royal Jimbaran
# 4            Other  Past Guests          Karma Kandara
# ..             ...          ...                    ...
# 174          Other  Past Guests          Karma Kandara
# 175          Other  Past Guests        Karma Song Hoai
# 176          Other  Past Guests          Karma Kandara
# 177          Other  Past Guests          Karma Bavaria
# 178          Other  Past Guests        Karma Song Hoai
#
#     Lead Source Description Lead Regions Lead Status Email Opt Out Opt In
# 0                 Viewpoint        empty       empty         false   true
# 1                 Viewpoint        empty       empty         false   true
# 2                 Viewpoint        empty       empty         false   true
# 3                 Viewpoint        empty       empty         false   true
# 4                     empty        empty       empty         false   true
# ..                      ...          ...         ...           ...    ...
# 174                   empty        empty       empty         false   true
# 175               Viewpoint        empty       empty         false   true
# 176                   empty        empty       empty          true  false
# 177               Viewpoint        empty       empty         false   true
# 178               Viewpoint        empty       empty         false   true
#
# [179 rows x 31 columns]

# %% [markdown]
# # ====================== Awal Filter Umum ======================

# %%
# data phone, mobile dam email member yang ada di master data (wash member)

m.clean_number(zoho_df, 'Phone')
m.clean_number(zoho_df, 'Mobile')
m.replace_not_valid_to_empty(zoho_df, 'Phone')
m.replace_not_valid_to_empty(zoho_df, 'Mobile')
zoho_df['Email'] = m.lowercase(zoho_df, 'Email')
m.clean_space(zoho_df, 'Email')

m.clean_number(df_booking, 'Phone1')
m.clean_number(df_booking, 'Mobile')
df_booking['Email'] = m.lowercase(df_booking, 'Email')
m.clean_space(df_booking, 'Email')

m.clean_number(df_phone, 'Mobile')

df_email['Email'] = m.lowercase(df_email, 'Email')
m.clean_space(df_email, 'Email')

count_deleted_wrong_format = m.delete_email_wrong_format(zoho_df, 'Email')
count_after_deleted_wrong_format = zoho_df.shape[0]

# %%
path = r'C:\Users\fajar\Documents\Python\Data\dedup_aunz.xlsx'
df_aunz = pd.read_excel(path, dtype='string', sheet_name='Sheet1')

# data phone, mobile dam email member yang ada di master data 
count_wash_prev = zoho_df.loc[
    zoho_df['Record Id'].isin(df_aunz['Record Id']) 
].shape[0]

count_wash_prev
# Out:
# 40

# %%
zoho_df.drop(zoho_df.loc[
    zoho_df['Record Id'].isin(df_aunz['Record Id']) 
].index, inplace=True)
df.reset_index(drop=True, inplace=True)

count_after_wash_aunz = zoho_df.shape[0]

# %%
# Cek leads test
test_leads = zoho_df.loc[
    
        zoho_df['Email'].str.contains('^test@', flags=re.I, regex=True) |
        zoho_df['Email'].str.contains('\+test', flags=re.I, regex=True) |
    
        zoho_df['First Name'].str.contains('^test$', flags=re.I, regex=True) |
        zoho_df['Last Name'].str.contains('^test$', flags=re.I, regex=True) |

        zoho_df['First Name'].str.contains('test 1', flags=re.I, regex=True) |
        zoho_df['Last Name'].str.contains('test 2', flags=re.I, regex=True)|
        zoho_df['First Name'].str.contains('test1', flags=re.I, regex=True) |
        zoho_df['Last Name'].str.contains('test2', flags=re.I, regex=True)|

        zoho_df['First Name'].str.contains(' test ', flags=re.I, regex=True) | 
        zoho_df['Last Name'].str.contains(' test ', flags=re.I, regex=True) | 
        zoho_df['Last Name'].str.contains(' test$', flags=re.I, regex=True)
    ]

count_leads_test = test_leads.shape[0]

# test_leads.to_excel(r'C:\Users\fajar\Documents\Python\Data\test_leads_2.xlsx', index=False)
test_leads
# Out:
# Empty DataFrame
# Columns: [Record Id, Created Time, Created Date, First Name, Last Name, Email, Phone, Mobile, Birthdate, Year of Birth, Street, Street2, City, State, Country, Nationality, Booking Status, BookRef, Departure Date, Arrival Date, Card Type, Marital Status, Lead Brand, Lead Sub-Brand, Lead Source, Lead Locations, Lead Source Description, Lead Regions, Lead Status, Email Opt Out, Opt In]
# Index: []
#
# [0 rows x 31 columns]

# %%
zoho_df.drop(test_leads.index, inplace=True)
zoho_df.reset_index(drop=True, inplace=True)

count_after_dedup_test = zoho_df.shape[0]

# %%
# Cek Email Karma
email_karma = m.find_karma(zoho_df, 'Email')
count_email_karma = email_karma.shape[0]
# email_OTA.to_excel(r'C:\Users\fajar\Documents\Python\Data\email_OTA.xlsx', index=False)

email_karma
# Out:
# johnspence88@hotmail\.com|baligetaway|rottnestlodge\.com\.au|hotel\.discount|balirewardscard\.com|conceptvenues\.com|discoverkarma\.com|discoveryourkarma\.com|geales\.com|haathimahal\.com|adimahkota\.com|baligetaway\.co\.id|baligetaway\.com\.au|catkingproductions\.com|complementarystay-karmaexperience\.com|confirmation-karmaexperience\.com|tiketmurahbali\.com|karmasanctumsoho\.co|experiencekarmaclub\.com|karmabavaria\.com|karmabeach\.com|karmaclub\.com|karmadevelopments\.com|karmaestates\.com|karmaexperience\.co\.uk|karmaexperience\.com|karmaexperience\.in|karmagroup\.com|karmajimbaran\.com|karmakandara\.com|karmaminoan\.com|karmanormandy\.com|karmapelikanos\.com|karmareef\.com|karmaresorts\.com|karmaroyalexperience\.co\.uk|karmaroyalexperience\.com|karmaroyalgroup\.com|karmaroyalvacations\.com|karmasalak\.com|karmasalfordhall\.com|karmastmartins\.com|karmgroup\.com|krresidences\.com|lepreverger\.com|odysseypremier\.com|rci\.com|thebaligetaway\.comkarmarottnest\.com\.au|karmasanctumonthegreen\.com|karmasanctumclub\.com|balifreestay\.com|karma25\.com|karmarottnest\.com\.au|karmasanctumsoho\.com|karmaroyalpromotions\.com|justclickbali\.com|karmaapsara\.com|karmabahamas\.com|karmaborgodicolleoli\.com|karmacamino\.com|karmaclub\.community|karmaclubhouse\.club|karmaclubhouse\.com|karma-concierge|karmaconcierge|karmaconstellation\.com|karmadestinations\.com|karmaexperiences\.com|karmaexperiences\.com|karmagroupreviews\.com|karmakasa|karmalaherizza|karmamargaretriver\.com|karmamayura\.com|karmaminoan\.com|karmamykonos\.com|karmapassport\.com|karmaprivilege\.com|karmaprivileges\.com|karmaresortdestinations\.com|karmarestaurants\.com|karmaroyalbellavista\.com|karmaroyalboatlagoon\.com|karmaroyalresidences\.com|karmasanctum\.com|karmasanctumspa\.com|karmaspa\.com|karmaspas\.com|karmastmartin\.com|karmaubud\.com|karmawinery\.com|krgstorage\.com|mykarmaconcierge\.com|odysseykarma\.com|odysseypremier\.com|royalbalitimeshare\.com|royalperspective\.com|royalresortsasia\.com|royalresortstimeshare\.com|sanctumhotel\.com|sanctumsoho\.com|thebaligetaway\.com|thekarmaclub\.com|thekarmacollection|themoleandbadger\.com|timesharebali\.com|wildheartbarandgrill\.com|wildheartsoho\.com|yuktamasya\.com
# Empty DataFrame
# Columns: [Record Id, Created Time, Created Date, First Name, Last Name, Email, Phone, Mobile, Birthdate, Year of Birth, Street, Street2, City, State, Country, Nationality, Booking Status, BookRef, Departure Date, Arrival Date, Card Type, Marital Status, Lead Brand, Lead Sub-Brand, Lead Source, Lead Locations, Lead Source Description, Lead Regions, Lead Status, Email Opt Out, Opt In]
# Index: []
#
# [0 rows x 31 columns]

# %%
# delete email Karma
count_after_clean_karma = m.delete_karma(zoho_df, 'Email')
# zoho_df.to_excel(r'C:\Users\fajar\Documents\Python\Data\after_clean_OTA.xlsx', index=False)

zoho_df
# Out:
#                     Record Id        Created Time Created Date  \
# 0    zcrm_3584690000426781936 2023-02-06 13:12:19        empty
# 1    zcrm_3584690000428158680 2023-02-13 15:18:20        empty
# 2    zcrm_3584690000428174965 2023-02-13 15:18:11        empty
# 3    zcrm_3584690000428450383 2023-02-13 15:31:14        empty
# 4    zcrm_3584690000428450665 2023-02-13 15:38:50        empty
# ..                        ...                 ...          ...
# 134  zcrm_3584690000439838156 2023-04-10 12:52:55        empty
# 135  zcrm_3584690000439839377 2023-04-10 13:01:29        empty
# 136  zcrm_3584690000439840143 2023-04-10 12:53:41        empty
# 137  zcrm_3584690000439840661 2023-04-10 13:03:12        empty
# 138  zcrm_3584690000439852124 2023-04-10 13:02:33        empty
#
#            First Name  Last Name                             Email  \
# 0               Kamna     Kapoor    kamna.kapoor@yarratrams.com.au
# 1    Deane Jacqueline    Brosnan          deanebrosnan@hotmail.com
# 2               Jason     Crofts            jcrofts@bigpond.net.au
# 3               Shiji      Titus           shiji_titus@yahoo.co.uk
# 4              Samuel      Riley              samriley77@gmail.com
# ..                ...        ...                               ...
# 134            Kelvin       Tjia                ktjia.kt@gmail.com
# 135             Sonya   Stephens              molly2410@icloud.com
# 136           Randhir  Kowlessur  australia@luckydodomigration.com
# 137        Lisa Marie  O'Donnell            lisaodonnell@email.com
# 138            Nicola    Bartley             nicola_ny@hotmail.com
#
#              Phone         Mobile Birthdate Year of Birth  ... Marital Status  \
# 0      61466947313          empty     empty         empty  ...          empty
# 1      61411696222    61411696222     empty         empty  ...          empty
# 2       6143798932     6143798932     empty         empty  ...          empty
# 3      61405516642          empty     empty         empty  ...          empty
# 4      61488250049          empty     empty         empty  ...          empty
# ..             ...            ...       ...           ...  ...            ...
# 134  6181510539008  6181510539008     empty         empty  ...          empty
# 135    61438490055          empty     empty         empty  ...          empty
# 136     6193052167          empty     empty         empty  ...          empty
# 137    61414445510          empty     empty         empty  ...          empty
# 138    61431410910          empty     empty         empty  ...          empty
#
#         Lead Brand Lead Sub-Brand  Lead Source  \
# 0    Karma Resorts          Other  Past Guests
# 1    Karma Resorts          Other  Past Guests
# 2    Karma Resorts          Other  Past Guests
# 3    Karma Resorts          Other  Past Guests
# 4    Karma Resorts          Other  Past Guests
# ..             ...            ...          ...
# 134  Karma Resorts          Other  Past Guests
# 135  Karma Resorts          Other  Past Guests
# 136  Karma Resorts          Other  Past Guests
# 137  Karma Resorts          Other  Past Guests
# 138  Karma Resorts          Other  Past Guests
#
#                         Lead Locations Lead Source Description Lead Regions  \
# 0                Karma Royal Candidasa               Viewpoint        empty
# 1                        Karma Kandara                   empty        empty
# 2                        Karma Kandara                   empty        empty
# 3                Karma Royal Candidasa               Viewpoint        empty
# 4    KRR @ Karma Kandara;Karma Kandara               Viewpoint        empty
# ..                                 ...                     ...          ...
# 134                      Karma Kandara                   empty        empty
# 135                    Karma Song Hoai               Viewpoint        empty
# 136                      Karma Kandara                   empty        empty
# 137                      Karma Bavaria               Viewpoint        empty
# 138                    Karma Song Hoai               Viewpoint        empty
#
#     Lead Status Email Opt Out Opt In
# 0         empty         false   true
# 1         empty         false   true
# 2         empty         false   true
# 3         empty         false   true
# 4         empty         false   true
# ..          ...           ...    ...
# 134       empty         false   true
# 135       empty         false   true
# 136       empty          true  false
# 137       empty         false   true
# 138       empty         false   true
#
# [139 rows x 31 columns]

# %%
# hitung jumlah duplicate
count_duplicate_general = zoho_df.loc[zoho_df.duplicated(subset=['Phone','Mobile','Email'])].shape[0]

zoho_df.loc[zoho_df.duplicated(subset=['Phone','Mobile','Email'])]
# Out:
#                   Record Id        Created Time Created Date First Name  \
# 7  zcrm_3584690000428466005 2023-02-13 15:29:26        empty      Shiji
#
#   Last Name                    Email        Phone Mobile Birthdate  \
# 7     Titus  shiji_titus@yahoo.co.uk  61405516642  empty     empty
#
#   Year of Birth  ... Marital Status     Lead Brand Lead Sub-Brand  \
# 7         empty  ...          empty  Karma Resorts          Other
#
#    Lead Source     Lead Locations Lead Source Description Lead Regions  \
# 7  Past Guests  Karma Royal Sanur               Viewpoint        empty
#
#   Lead Status Email Opt Out Opt In
# 7       empty         false   true
#
# [1 rows x 31 columns]

# %%
zoho_df.drop_duplicates(subset=['Phone','Mobile','Email'], inplace=True)
zoho_df.reset_index(drop=True, inplace=True)

# hitung jumlah setelah value duplicate dihapus
count_after_dedup_duplicate = zoho_df.shape[0]

zoho_df
# Out:
#                     Record Id        Created Time Created Date  \
# 0    zcrm_3584690000426781936 2023-02-06 13:12:19        empty
# 1    zcrm_3584690000428158680 2023-02-13 15:18:20        empty
# 2    zcrm_3584690000428174965 2023-02-13 15:18:11        empty
# 3    zcrm_3584690000428450383 2023-02-13 15:31:14        empty
# 4    zcrm_3584690000428450665 2023-02-13 15:38:50        empty
# ..                        ...                 ...          ...
# 133  zcrm_3584690000439838156 2023-04-10 12:52:55        empty
# 134  zcrm_3584690000439839377 2023-04-10 13:01:29        empty
# 135  zcrm_3584690000439840143 2023-04-10 12:53:41        empty
# 136  zcrm_3584690000439840661 2023-04-10 13:03:12        empty
# 137  zcrm_3584690000439852124 2023-04-10 13:02:33        empty
#
#            First Name  Last Name                             Email  \
# 0               Kamna     Kapoor    kamna.kapoor@yarratrams.com.au
# 1    Deane Jacqueline    Brosnan          deanebrosnan@hotmail.com
# 2               Jason     Crofts            jcrofts@bigpond.net.au
# 3               Shiji      Titus           shiji_titus@yahoo.co.uk
# 4              Samuel      Riley              samriley77@gmail.com
# ..                ...        ...                               ...
# 133            Kelvin       Tjia                ktjia.kt@gmail.com
# 134             Sonya   Stephens              molly2410@icloud.com
# 135           Randhir  Kowlessur  australia@luckydodomigration.com
# 136        Lisa Marie  O'Donnell            lisaodonnell@email.com
# 137            Nicola    Bartley             nicola_ny@hotmail.com
#
#              Phone         Mobile Birthdate Year of Birth  ... Marital Status  \
# 0      61466947313          empty     empty         empty  ...          empty
# 1      61411696222    61411696222     empty         empty  ...          empty
# 2       6143798932     6143798932     empty         empty  ...          empty
# 3      61405516642          empty     empty         empty  ...          empty
# 4      61488250049          empty     empty         empty  ...          empty
# ..             ...            ...       ...           ...  ...            ...
# 133  6181510539008  6181510539008     empty         empty  ...          empty
# 134    61438490055          empty     empty         empty  ...          empty
# 135     6193052167          empty     empty         empty  ...          empty
# 136    61414445510          empty     empty         empty  ...          empty
# 137    61431410910          empty     empty         empty  ...          empty
#
#         Lead Brand Lead Sub-Brand  Lead Source  \
# 0    Karma Resorts          Other  Past Guests
# 1    Karma Resorts          Other  Past Guests
# 2    Karma Resorts          Other  Past Guests
# 3    Karma Resorts          Other  Past Guests
# 4    Karma Resorts          Other  Past Guests
# ..             ...            ...          ...
# 133  Karma Resorts          Other  Past Guests
# 134  Karma Resorts          Other  Past Guests
# 135  Karma Resorts          Other  Past Guests
# 136  Karma Resorts          Other  Past Guests
# 137  Karma Resorts          Other  Past Guests
#
#                         Lead Locations Lead Source Description Lead Regions  \
# 0                Karma Royal Candidasa               Viewpoint        empty
# 1                        Karma Kandara                   empty        empty
# 2                        Karma Kandara                   empty        empty
# 3                Karma Royal Candidasa               Viewpoint        empty
# 4    KRR @ Karma Kandara;Karma Kandara               Viewpoint        empty
# ..                                 ...                     ...          ...
# 133                      Karma Kandara                   empty        empty
# 134                    Karma Song Hoai               Viewpoint        empty
# 135                      Karma Kandara                   empty        empty
# 136                      Karma Bavaria               Viewpoint        empty
# 137                    Karma Song Hoai               Viewpoint        empty
#
#     Lead Status Email Opt Out Opt In
# 0         empty         false   true
# 1         empty         false   true
# 2         empty         false   true
# 3         empty         false   true
# 4         empty         false   true
# ..          ...           ...    ...
# 133       empty         false   true
# 134       empty         false   true
# 135       empty          true  false
# 136       empty         false   true
# 137       empty         false   true
#
# [138 rows x 31 columns]

# %%
find_member_booking = zoho_df.copy()

find_member_booking.loc[find_member_booking['Phone'].isin(df_booking['Phone1']), 'Same Value Find'] = 'Booking-Phone1'
find_member_booking.loc[find_member_booking['Phone'].isin(df_booking['Mobile']), 'Same Value Find'] = 'Booking-Mobile'
find_member_booking.loc[find_member_booking['Mobile'].isin(df_booking['Phone1']), 'Same Value Find'] = 'Booking-Phone1' 
find_member_booking.loc[find_member_booking['Mobile'].isin(df_booking['Mobile']), 'Same Value Find'] = 'Booking-Mobile'
find_member_booking.loc[find_member_booking['Email'].isin(df_booking['Email']), 'Same Value Find'] = 'Booking-Email'

find_member_booking.loc[find_member_booking['Phone'].isin(df_phone['Mobile']), 'Same Value Find'] = 'Member-Mobile' 
find_member_booking.loc[find_member_booking['Mobile'].isin(df_phone['Mobile']), 'Same Value Find'] = 'Member-Mobile'

find_member_booking.loc[find_member_booking['Email'].isin(df_email['Email']), 'Same Value Find'] = 'Member-Email'

find_member_booking.drop(find_member_booking.loc[find_member_booking['Same Value Find'].isna()].index, inplace=True)

count_booking_dedup = find_member_booking.loc[find_member_booking['Same Value Find'].str.contains('Booking', flags=re.I, regex=True)].shape[0]
count_member_dedup = find_member_booking.loc[find_member_booking['Same Value Find'].str.contains('Member', flags=re.I, regex=True)].shape[0]

find_member_booking.replace('empty', '', inplace=True)
#find_member_booking.to_csv(r'C:\Users\fajar\Documents\Python\Data\booking-member-dedup.csv', index=False)

#find_member_booking.loc[find_member_booking['Same Value Find'] == 'Booking-Phone1']

# %%
# data phone, mobile dam email member yang ada di master data 
count_wash_member = zoho_df.loc[
    zoho_df['Phone'].isin(df_booking['Phone1']) | 
    zoho_df['Phone'].isin(df_booking['Mobile']) |
    zoho_df['Mobile'].isin(df_booking['Phone1']) | 
    zoho_df['Mobile'].isin(df_booking['Mobile']) |
    zoho_df['Email'].isin(df_booking['Email'])| 

    zoho_df['Phone'].isin(df_phone['Mobile']) | 
    zoho_df['Mobile'].isin(df_phone['Mobile']) |

    zoho_df['Email'].isin(df_email['Email'])

].shape[0]

zoho_df.drop(zoho_df.loc[
    zoho_df['Phone'].isin(df_booking['Phone1']) | 
    zoho_df['Phone'].isin(df_booking['Mobile']) |
    zoho_df['Mobile'].isin(df_booking['Phone1']) | 
    zoho_df['Mobile'].isin(df_booking['Mobile']) |
    zoho_df['Email'].isin(df_booking['Email']) |
    
    zoho_df['Phone'].isin(df_phone['Mobile']) | 
    zoho_df['Mobile'].isin(df_phone['Mobile']) |

    zoho_df['Email'].isin(df_email['Email'])

    ].index, inplace=True)
    
zoho_df.reset_index(drop=True, inplace=True)

count_after_wash_member = zoho_df.shape[0]

# %%
count_email_only = zoho_df.loc[(zoho_df['Email'] != 'empty') & ((zoho_df['Phone'] == 'empty') & (zoho_df['Mobile'] == 'empty'))].shape[0]
count_phone_only = zoho_df.loc[(zoho_df['Email'] == 'empty') & ((zoho_df['Phone'] != 'empty') | (zoho_df['Mobile'] != 'empty'))].shape[0]
count_email_and_phone = zoho_df.loc[(zoho_df['Email'] != 'empty') & ((zoho_df['Phone'] != 'empty') | (zoho_df['Mobile'] != 'empty'))].shape[0]

count_blank = zoho_df.loc[(zoho_df['Email'] =='empty') & (zoho_df['Phone']=='empty') & (zoho_df['Mobile']=='empty')].shape[0]

# zoho_df.loc[(zoho_df['Email'] =='empty') & (zoho_df['Phone']=='empty') & (zoho_df['Mobile']=='empty')].to_excel(r'C:\Users\fajar\Documents\Python\Data\blank_data.xlsx', index=False)

zoho_df.loc[(zoho_df['Email'] != 'empty') & ((zoho_df['Phone'] == 'empty') & (zoho_df['Mobile'] == 'empty')), 'Contact Type'] = 'Email Only'
zoho_df.loc[(zoho_df['Email'] == 'empty') & ((zoho_df['Phone'] != 'empty') | (zoho_df['Mobile'] != 'empty')), 'Contact Type'] = 'Phone Only'
zoho_df.loc[(zoho_df['Email'] != 'empty') & ((zoho_df['Phone'] != 'empty') | (zoho_df['Mobile'] != 'empty')), 'Contact Type'] = 'Email and Phone'

zoho_df.drop(zoho_df.loc[(zoho_df['Email'] =='empty') & (zoho_df['Phone']=='empty') & (zoho_df['Mobile']=='empty')].index, inplace=True)
zoho_df.reset_index(drop=True, inplace=True)

count_after_wash_blank = zoho_df.shape[0]

# %%
path = r'C:\Users\fajar\Documents\Python\Data\Debounce\bounced_zoho.csv'
df_bounced_zoho = pd.read_csv(path, dtype='string', on_bad_lines='skip')

# data phone, mobile dam email member yang ada di master data 
count_wash_bounced_zoho = zoho_df.loc[
    zoho_df['Email'].isin(df_bounced_zoho['Contact Email'])

].shape[0]

# zoho_df.loc[
#     zoho_df['Email'].isin(df_bounced_zoho['Contact Email'])

# ].to_excel(r'C:\Users\fajar\Documents\Python\Data\Debounce\dedup_bounced_zoho.xlsx', index=False)

zoho_df.drop(zoho_df.loc[
    zoho_df['Email'].isin(df_bounced_zoho['Contact Email'])

].index, inplace=True)
zoho_df.reset_index(drop=True, inplace=True)

count_after_wash_bounced_zoho = zoho_df.shape[0]
count_after_wash_bounced_zoho
# Out:
# 105

# %%
path = r'C:\Users\fajar\Documents\Python\Data\Debounce\unsubs_zoho.csv'
df_unsub_zoho = pd.read_csv(path, dtype='string', on_bad_lines='skip')

# data phone, mobile dam email member yang ada di master data 
count_wash_unsub_zoho = zoho_df.loc[
    zoho_df['Email'].isin(df_unsub_zoho['Contact Email'])

].shape[0]

# zoho_df.loc[
#     zoho_df['Email'].isin(df_unsub_zoho['Contact Email'])

# ].to_excel(r'C:\Users\fajar\Documents\Python\Data\Debounce\dedup_unsub_zoho.xlsx', index=False)

zoho_df.drop(zoho_df.loc[
    zoho_df['Email'].isin(df_unsub_zoho['Contact Email'])

].index, inplace=True)
zoho_df.reset_index(drop=True, inplace=True)

count_after_wash_unsub_zoho = zoho_df.shape[0]
count_after_wash_unsub_zoho
# Out:
# 92

# %%
print("==========================================================")
print("Summary")
print("==========================================================")
print("Jumlah Keseluruhan Master Zoho : "+str(count_data_awal))
print("Jumlah Filter Leads Awal : "+str(count_filter_awal))
print("Jumlah Data Dedup AUNZ : "+str(count_wash_prev))
print("Jumlah After Wash AUNZ : "+str(count_after_wash_aunz))
print("Jumlah Format Email Salah : "+str(count_deleted_wrong_format))
print("Jumlah Setelah Clean Format Email Salah : "+str(count_after_deleted_wrong_format))
print("Jumlah Lead Test : "+str(count_leads_test))
print("Jumlah Setelah Clean Lead Test : "+str(count_after_dedup_test))
print("Jumlah Email Karma : "+str(count_email_karma))
print("Jumlah Setelah Clean Email Karma : "+str(count_after_clean_karma))
print("Jumlah Duplicate (Phone, Mobile dan Email) : "+str(count_duplicate_general))
print("Jumlah Setelah Clean Duplicate : "+str(count_after_dedup_duplicate))
print("Jumlah Wash Member : "+str(count_member_dedup))
print("Jumlah Wash Booking : "+str(count_booking_dedup))
print("Jumlah Setelah Wash Member : "+str(count_after_wash_member))
print("==========================================================")
print("Contact Type")
print("==========================================================")
print("Jumlah Email Only : "+str(count_email_only))
print("Jumlah Phone Only : "+str(count_phone_only))
print("Jumlah Email dan Phone : "+str(count_email_and_phone))
print("Jumlah Phone Email Blank (Setelah phone yang tidak valid dihapus) : "+str(count_blank))
print("Jumlah Setelah Wash Phone Email Blank : "+str(count_after_wash_blank))
print("Jumlah Data Dedup bounced zoho : "+str(count_wash_bounced_zoho))
print("Jumlah After Wash bounced zoho : "+str(count_after_wash_bounced_zoho))
print("Jumlah Data Dedup unsubs zoho : "+str(count_wash_unsub_zoho))
print("Jumlah After Wash unsubs zoho : "+str(count_after_wash_unsub_zoho))
# Out:
# ==========================================================
# Summary
# ==========================================================
# Jumlah Keseluruhan Master Zoho : 4704484
# Jumlah Filter Leads Awal : 179
# Jumlah Data Dedup AUNZ : 40
# Jumlah After Wash AUNZ : 139
# Jumlah Format Email Salah : 0
# Jumlah Setelah Clean Format Email Salah : 179
# Jumlah Lead Test : 0
# Jumlah Setelah Clean Lead Test : 139
# Jumlah Email Karma : 0
# Jumlah Setelah Clean Email Karma : 139
# Jumlah Duplicate (Phone, Mobile dan Email) : 1
# Jumlah Setelah Clean Duplicate : 138
# Jumlah Wash Member : 2
# Jumlah Wash Booking : 29
# Jumlah Setelah Wash Member : 107
# ==========================================================
# Contact Type
# ==========================================================
# Jumlah Email Only : 2
# Jumlah Phone Only : 20
# Jumlah Email dan Phone : 85
# Jumlah Phone Email Blank (Setelah phone yang tidak valid dihapus) : 0
# Jumlah Setelah Wash Phone Email Blank : 107
# Jumlah Data Dedup bounced zoho : 2
# Jumlah After Wash bounced zoho : 105
# Jumlah Data Dedup unsubs zoho : 13
# Jumlah After Wash unsubs zoho : 92

# %% [markdown]
# # ====================== Akhir Filter Umum ======================

# %%
zoho_df.replace('empty', '', inplace=True)
zoho_df.to_excel(r'C:\Users\fajar\Documents\Python\Data\past_guest_au_clean.xlsx', index=False)
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# c:\Users\fajar\Documents\Python\Task Offline\zoho_data_app\user_request.ipynb Cell 22 in 2
#       <a href='vscode-notebook-cell:/c%3A/Users/fajar/Documents/Python/Task%20Offline/zoho_data_app/user_request.ipynb#X25sZmlsZQ%3D%3D?line=0'>1</a> zoho_df.replace('empty', '', inplace=True)
# ----> <a href='vscode-notebook-cell:/c%3A/Users/fajar/Documents/Python/Task%20Offline/zoho_data_app/user_request.ipynb#X25sZmlsZQ%3D%3D?line=1'>2</a> zoho_df.to_excel(r'C:\Users\fajar\Documents\Python\Data\past_guest_au_clean.xlsx', index=False)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\core\generic.py:2373, in NDFrame.to_excel(self, excel_writer, sheet_name, na_rep, float_format, columns, header, index, index_label, startrow, startcol, engine, merge_cells, encoding, inf_rep, verbose, freeze_panes, storage_options)
#    2360 from pandas.io.formats.excel import ExcelFormatter
#    2362 formatter = ExcelFormatter(
#    2363     df,
#    2364     na_rep=na_rep,
#    (...)
#    2371     inf_rep=inf_rep,
#    2372 )
# -> 2373 formatter.write(
#    2374     excel_writer,
#    2375     sheet_name=sheet_name,
#    2376     startrow=startrow,
#    2377     startcol=startcol,
#    2378     freeze_panes=freeze_panes,
#    2379     engine=engine,
#    2380     storage_options=storage_options,
#    2381 )
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\io\formats\excel.py:911, in ExcelFormatter.write(self, writer, sheet_name, startrow, startcol, freeze_panes, engine, storage_options)
#     907     need_save = False
#     908 else:
#     909     # error: Cannot instantiate abstract class 'ExcelWriter' with abstract
#     910     # attributes 'engine', 'save', 'supported_extensions' and 'write_cells'
# --> 911     writer = ExcelWriter(  # type: ignore[abstract]
#     912         writer, engine=engine, storage_options=storage_options
#     913     )
#     914     need_save = True
#     916 try:
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\io\excel\_xlsxwriter.py:199, in XlsxWriter.__init__(self, path, engine, date_format, datetime_format, mode, storage_options, if_sheet_exists, engine_kwargs, **kwargs)
#     196 if mode == "a":
#     197     raise ValueError("Append mode is not supported with xlsxwriter!")
# --> 199 super().__init__(
#     200     path,
#     201     engine=engine,
#     202     date_format=date_format,
#     203     datetime_format=datetime_format,
#     204     mode=mode,
#     205     storage_options=storage_options,
#     206     if_sheet_exists=if_sheet_exists,
#     207     engine_kwargs=engine_kwargs,
#     208 )
#     210 self._book = Workbook(self._handles.handle, **engine_kwargs)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\io\excel\_base.py:1302, in ExcelWriter.__init__(self, path, engine, date_format, datetime_format, mode, storage_options, if_sheet_exists, engine_kwargs, **kwargs)
#    1298 self._handles = IOHandles(
#    1299     cast(IO[bytes], path), compression={"compression": None}
#    1300 )
#    1301 if not isinstance(path, ExcelWriter):
# -> 1302     self._handles = get_handle(
#    1303         path, mode, storage_options=storage_options, is_text=False
#    1304     )
#    1305 self._cur_sheet = None
#    1307 if date_format is None:
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\io\common.py:866, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     857         handle = open(
#     858             handle,
#     859             ioargs.mode,
#    (...)
#     862             newline="",
#     863         )
#     864     else:
#     865         # Binary mode
# --> 866         handle = open(handle, ioargs.mode)
#     867     handles.append(handle)
#     869 # Convert BytesIO or file objects passed with an encoding
#
# PermissionError: [Errno 13] Permission denied: 'C:\\Users\\fajar\\Documents\\Python\\Data\\past_guest_au_clean.xlsx'
