# %%
import requests
from requests.auth import HTTPBasicAuth
import pandas as pd
import campaign_monitor_modul as cm

# %load_ext autoreload
# %autoreload 2

# Replace with your actual API key and client ID
api_key = 'W7KbXzk9fFsN+G3XrIemdIu156KSPq3Qh60OQFQw9oP0UPnDvfq8w2SH5plgeZnpzyA4Bc2QCKVpK9SB42n8ZO3Z4Cpefu2/HGULJneNoJZ2zza129wfcsOL35Fpoweq3ZcidTNu110I/HCNguRGUw=='
client_id = '1545f43bbfe89f34ea7cf143c36c5e9f'

# API endpoint
url = f'https://api.createsend.com/api/v3.2/clients/{client_id}/campaigns.json'
# Out:
# Campaigns List:

# %%
# Make the GET request
response = requests.get(url, auth=HTTPBasicAuth(api_key, ''))

# Check for successful response
if response.status_code == 200:
    campaigns = response.json()
    print("Campaigns List:")
    # Create a DataFrame from the campaigns data
    df = pd.DataFrame(campaigns)
    # Display the DataFrame
else:
    print(f"Failed to retrieve campaigns. Status Code: {response.status_code}, Response: {response.text}")

# %%
test = cm.get_campaign_list(api_key, client_id, 'Vol_230')
test
# Out:
# Campaigns List:
#                                               Name         FromName  \
# 1422    KCB_Bahasa_W3Jun24_Karma_Community_Vol_230  Karma Concierge
# 1425           KCI_W3Jun24_Karma_Community_Vol_230  Karma Concierge
# 1426         KCDEU_W3Jun24_Karma_Community_Vol_230       Karma Club
# 1427          KCEU_W3Jun24_Karma_Community_Vol_230       Karma Club
# 1428           KCB_W3Jun24_Karma_Community_Vol_230  Karma Concierge
# 1429  Villa_Owners_W3Jun24_Karma_Community_Vol_230      Karma Group
#
#                                       FromEmail  \
# 1422   karma.community.bali@karmaclub.community
# 1425  karma.community.india@karmaclub.community
# 1426             concierge.europe@karmaclub.com
# 1427             concierge.europe@karmaclub.com
# 1428   karma.community.bali@karmaclub.community
# 1429           karma.community@karmaresorts.com
#
#                                   ReplyTo             SentDate  \
# 1422       karma.concierge@karmagroup.com  2024-06-18 18:14:00
# 1425  karmaconcierge.india@karmagroup.com  2024-06-17 22:48:00
# 1426  karmaconcierge.india@karmagroup.com  2024-06-17 22:46:00
# 1427       concierge.europe@karmaclub.com  2024-06-17 22:45:00
# 1428       karma.concierge@karmagroup.com  2024-06-17 19:48:00
# 1429     karma.community@karmaresorts.com  2024-06-17 19:04:00
#
#       TotalRecipients                        CampaignID  \
# 1422             3751  6a996eec5dad5596654003f11ba9dd73
# 1425            40855  5489242c196e25e8772adf912ca66443
# 1426             1069  1d239c3fabce90fbaeccc7ce14fa27f3
# 1427               35  373419911e677ef134aa2d50ac3865fe
# 1428            11755  4b1b09375b278a11e390c2838aba6946
# 1429              199  00e83241effc101e8e7833be826a7401
#
#                                                 Subject  \
# 1422  Harta Karun Tersembunyi Tuscan dan Perselisiha...
# 1425                Tuscan Treasures and Burger Brawls!
# 1426                Tuscan Treasures and Burger Brawls!
# 1427                Tuscan Treasures and Burger Brawls!
# 1428                Tuscan Treasures and Burger Brawls!
# 1429                Tuscan Treasures and Burger Brawls!
#
#                                           WebVersionURL  \
# 1422  http://createsend.com/t/d-84AD53FD60948B0F2540...
# 1425  http://createsend.com/t/d-23880F3DC9CDC0F52540...
# 1426  http://createsend.com/t/d-568ACC89E6E137EF2540...
# 1427  http://createsend.com/t/d-47367B05086B2C762540...
# 1428  http://createsend.com/t/d-8BB16B55A8A1D1152540...
# 1429  http://createsend.com/t/d-663E63CD75AF51FE2540...
#
#                                       WebVersionTextURL
# 1422  http://createsend.com/t/d-84AD53FD60948B0F2540...
# 1425  http://createsend.com/t/d-23880F3DC9CDC0F52540...
# 1426  http://createsend.com/t/d-568ACC89E6E137EF2540...
# 1427  http://createsend.com/t/d-47367B05086B2C762540...
# 1428  http://createsend.com/t/d-8BB16B55A8A1D1152540...
# 1429  http://createsend.com/t/d-663E63CD75AF51FE2540...
