# %%
import requests
from requests.auth import HTTPBasicAuth
import pandas as pd
import campaign_monitor_modul as cm

# %load_ext autoreload
# %autoreload 2

# Replace with your actual API key and campaign ID
api_key = 'W7KbXzk9fFsN+G3XrIemdIu156KSPq3Qh60OQFQw9oP0UPnDvfq8w2SH5plgeZnpzyA4Bc2QCKVpK9SB42n8ZO3Z4Cpefu2/HGULJneNoJZ2zza129wfcsOL35Fpoweq3ZcidTNu110I/HCNguRGUw=='
campaign_id = '5489242c196e25e8772adf912ca66443'

# API endpoint
url = f'https://api.createsend.com/api/v3.2/campaigns/{campaign_id}/opens.json'
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# Make the GET request
response = requests.get(url, auth=HTTPBasicAuth(api_key, ''))

# Check for successful response
if response.status_code == 200:
    opens_data = response.json()
    # Extract the 'Results' part of the JSON response
    openers_list = opens_data.get('Results', [])
    numbers_of_page = opens_data.get("NumberOfPages", [])
    # Create a DataFrame from the list of openers
    df = pd.DataFrame(openers_list)
    print(f"Load data success")
    if numbers_of_page > 1:
        print("Page lebih dari 1")
else:
    print(f"Failed to retrieve openers. Status Code: {response.status_code}, Response: {response.text}")

# %%
get_openers_list = cm.get_openers_list(api_key, campaign_id)
count_page = get_openers_list['page_total']
count_page
# Out:
# Load data success
# Page lebih dari 1
# 18

# %%
get_openers_list = cm.get_openers_list(api_key, campaign_id)
data = get_openers_list['data']
data
# Out:
# Load data success
# Page lebih dari 1
#                      EmailAddress                            ListID  \
# 0          craja753@eeilindia.com  c135c4bfa452fea3c9ed1f95d7d5bab5
# 1          deacon@telusplanet.net  186d20c855844ba701a152b02b203cef
# 2    azimodin.khan@karmagroup.com  c135c4bfa452fea3c9ed1f95d7d5bab5
# 3          bambiapparels@moffi.in  c135c4bfa452fea3c9ed1f95d7d5bab5
# 4                 dases@telus.net  c135c4bfa452fea3c9ed1f95d7d5bab5
# ..                            ...                               ...
# 995    ismailmulani1965@gmail.com  c135c4bfa452fea3c9ed1f95d7d5bab5
# 996         latadgehani@gmail.com  c135c4bfa452fea3c9ed1f95d7d5bab5
# 997     pushkark.gcekme@gmail.com  c135c4bfa452fea3c9ed1f95d7d5bab5
# 998       joejoseph2009@gmail.com  c135c4bfa452fea3c9ed1f95d7d5bab5
# 999      mailthegeorges@gmail.com  8bbe8471e7f2a44899ba366646b49f98
#
#                     Date      IPAddress  Latitude  Longitude City Region  \
# 0    2024-06-17 22:46:00   72.14.199.44    37.751    -97.822
# 1    2024-06-17 22:46:00   72.14.199.45    37.751    -97.822
# 2    2024-06-17 22:46:00   72.14.199.45    37.751    -97.822
# 3    2024-06-17 22:46:00   72.14.199.44    37.751    -97.822
# 4    2024-06-17 22:46:00   72.14.199.44    37.751    -97.822
# ..                   ...            ...       ...        ...  ...    ...
# 995  2024-06-17 22:48:00   72.14.199.67    37.751    -97.822
# 996  2024-06-17 22:48:00   72.14.199.67    37.751    -97.822
# 997  2024-06-17 22:48:00   66.249.84.99       NaN        NaN  NaN    NaN
# 998  2024-06-17 22:48:00   72.14.199.67    37.751    -97.822
# 999  2024-06-17 22:48:00  66.249.84.193       NaN        NaN  NaN    NaN
#
#     CountryCode               CountryName
# 0            US  United States of America
# 1            US  United States of America
# 2            US  United States of America
# 3            US  United States of America
# 4            US  United States of America
# ..          ...                       ...
# 995          US  United States of America
# 996          US  United States of America
# 997         NaN                       NaN
# 998          US  United States of America
# 999         NaN                       NaN
#
# [1000 rows x 10 columns]
