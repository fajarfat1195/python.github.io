# %%
import sys
sys.path.append('../../zoho_data_app/')

import main_module as m
import zoho_filter_module as fil
import pandas as pd
import re
import numpy as np

# %load_ext autoreload
# %autoreload 2

dir_path_2020 = r'C:\Users\fajar\Documents\Python\Combine All Leads\2020'
dir_path_2021 = r'C:\Users\fajar\Documents\Python\Combine All Leads\2021'
dir_path_2022 = r'C:\Users\fajar\Documents\Python\Combine All Leads\2022'
dir_path_2023 = r'C:\Users\fajar\Documents\Python\Combine All Leads\2023'
dir_path_2024 = r'C:\Users\fajar\Documents\Python\Combine All Leads\2024'

file_name = '\Leads_'

cols_2020 = ['Lead ID',	
'Created Time',
'Created Date',	
'First Name',	
'Last Name',	
'Email',	
'Phone',	
'Mobile',	
'Birthdate',	
'Year of Birth',
'Street',	
'Street2',	
'City',	
'State',	
'Country',	
'Nationality',
'Departure Date',	
'Arrival Date',	
'Card Type',	
'Marital Status',	
'Lead Brand',	
'Lead Sub-Brand',	
'Lead Source',	
'Lead Locations',	
'Lead Source Description',	
'Lead Regions',
'Lead Status']

cols = ['Record Id',	
'Created Time',
'Created Date',	
'First Name',	
'Last Name',	
'Email',	
'Phone',	
'Mobile',	
'Birthdate',	
'Year of Birth',
'Street',	
'Street2',	
'City',	
'State',	
'Country',	
'Nationality',
'Departure Date',	
'Arrival Date',	
'Card Type',	
'Marital Status',	
'Lead Brand',	
'Lead Sub-Brand',	
'Lead Source',	
'Lead Locations',	
'Lead Source Description',	
'Lead Regions',
'Lead Status']

# %%
df_2020 = m.load_data_multiple(dir_path_2020, file_name, cols_2020)
count_data_awal = df_2020.shape[0]
df_2020 = df_2020.reindex(columns=cols_2020)
df_2020.shape[0]

df_2020['Created Time'] = pd.to_datetime(df_2020['Created Time'], format='%Y-%m-%d %H:%M:%S')
df_2020['Arrival Date'] = pd.to_datetime(df_2020['Arrival Date'], format='%Y-%m-%d')
df_2020['Departure Date'] = pd.to_datetime(df_2020['Departure Date'], format='%Y-%m-%d')
# fungsi errors cource untuk menhindari error jika value data date null atau kosong
# df['Birthdate'] = pd.to_datetime(df['Birthdate'], format='%Y-%m-%d', errors='coerce')
df_2020.dtypes

df_2020.rename(columns = {'Lead ID':'Record Id'}, inplace = True)
df_2020
# Out:
#                         Record Id        Created Time Created Date  \
# 0        zcrm_3584690000000404058 2019-01-07 15:08:38   2019-01-06
# 1        zcrm_3584690000000404059 2019-01-07 15:08:38   2019-01-06
# 2        zcrm_3584690000000404060 2019-01-07 15:08:38   2019-01-06
# 3        zcrm_3584690000000404065 2019-01-07 15:08:38   2019-01-06
# 4        zcrm_3584690000000404068 2019-01-07 15:08:38   2019-01-06
# ...                           ...                 ...          ...
# 8749420  zcrm_3584690000208711001 2020-08-03 17:56:31   2020-08-03
# 8749421  zcrm_3584690000208712002 2020-08-03 18:05:04         <NA>
# 8749422  zcrm_3584690000208713001 2020-08-03 18:10:03         <NA>
# 8749423  zcrm_3584690000208713055 2020-08-03 19:13:12         <NA>
# 8749424  zcrm_3584690000208714001 2020-08-03 18:20:28         <NA>
#
#               First Name   Last Name  \
# 0               Nicholas        Wood
# 1                   Liao        Yuan
# 2                Vedanta    Abhiyoga
# ...

# %%
df_2021 = m.load_data_multiple(dir_path_2021, file_name, cols)
count_data_awal = df_2021.shape[0]
df_2021 = df_2021.reindex(columns=cols)
df_2021.shape[0]

# fungsi errors cource untuk menhindari error jika value data date null atau kosong
# df['Birthdate'] = pd.to_datetime(df['Birthdate'], format='%Y-%m-%d', errors='coerce')
df_2021.dtypes
df_2021
# Out:
#                         Record Id         Created Time Created Date  \
# 0        zcrm_3584690000000404058  2019-01-07 15:08:38   2019-01-06
# 1        zcrm_3584690000000404059  2019-01-07 15:08:38   2019-01-06
# 2        zcrm_3584690000000404060  2019-01-07 15:08:38   2019-01-06
# 3        zcrm_3584690000000404065  2019-01-07 15:08:38   2019-01-06
# 4        zcrm_3584690000000404068  2019-01-07 15:08:38   2019-01-06
# ...                           ...                  ...          ...
# 4121109  zcrm_3584690000332273002  2021-12-20 18:35:39         <NA>
# 4121110  zcrm_3584690000332275015  2021-12-20 18:32:33         <NA>
# 4121111  zcrm_3584690000332275050  2021-12-20 18:51:37         <NA>
# 4121112  zcrm_3584690000332275085  2021-12-20 18:56:56         <NA>
# 4121113  zcrm_3584690000332275120  2021-12-20 18:57:29         <NA>
#
#           First Name  Last Name                       Email           Phone  \
# ...

# %%
result_df = pd.concat([df_2020, df_2021], ignore_index=True)
result_df.drop_duplicates(subset=['Record Id'], inplace=True)
result_df.reset_index(drop=True, inplace=True)

result_df
# Out:
#                         Record Id         Created Time Created Date  \
# 0        zcrm_3584690000000404058  2019-01-07 15:08:38   2019-01-06
# 1        zcrm_3584690000000404059  2019-01-07 15:08:38   2019-01-06
# 2        zcrm_3584690000000404060  2019-01-07 15:08:38   2019-01-06
# 3        zcrm_3584690000000404065  2019-01-07 15:08:38   2019-01-06
# 4        zcrm_3584690000000404068  2019-01-07 15:08:38   2019-01-06
# ...                           ...                  ...          ...
# 9196759  zcrm_3584690000332273002  2021-12-20 18:35:39         <NA>
# 9196760  zcrm_3584690000332275015  2021-12-20 18:32:33         <NA>
# 9196761  zcrm_3584690000332275050  2021-12-20 18:51:37         <NA>
# 9196762  zcrm_3584690000332275085  2021-12-20 18:56:56         <NA>
# 9196763  zcrm_3584690000332275120  2021-12-20 18:57:29         <NA>
#
#           First Name  Last Name                       Email           Phone  \
# ...

# %%
df_2022 = m.load_data_multiple(dir_path_2022, file_name, cols)
count_data_awal = df_2022.shape[0]
df_2022 = df_2022.reindex(columns=cols)
df_2022.shape[0]

# fungsi errors cource untuk menhindari error jika value data date null atau kosong
# df['Birthdate'] = pd.to_datetime(df['Birthdate'], format='%Y-%m-%d', errors='coerce')
df_2022.dtypes
df_2022
# Out:
#                         Record Id         Created Time Created Date  \
# 0        zcrm_3584690000000404058  2019-01-07 15:08:38   2019-01-06
# 1        zcrm_3584690000000404059  2019-01-07 15:08:38   2019-01-06
# 2        zcrm_3584690000000404060  2019-01-07 15:08:38   2019-01-06
# 3        zcrm_3584690000000404065  2019-01-07 15:08:38   2019-01-06
# 4        zcrm_3584690000000404068  2019-01-07 15:08:38   2019-01-06
# ...                           ...                  ...          ...
# 4572781  zcrm_3584690000419507114  2022-12-26 15:30:31         <NA>
# 4572782  zcrm_3584690000419509006  2022-12-26 18:23:07         <NA>
# 4572783  zcrm_3584690000419509032  2022-12-26 18:54:40         <NA>
# 4572784  zcrm_3584690000419510020  2022-12-26 18:01:51         <NA>
# 4572785  zcrm_3584690000419510045  2022-12-26 18:57:43         <NA>
#
#            First Name   Last Name                        Email  \
# 0            Nicholas        Wood   1230woodnicholas@gmail.com
# ...

# %%
result_df = pd.concat([result_df, df_2022], ignore_index=True)
result_df.drop_duplicates(subset=['Record Id'], inplace=True)
result_df.reset_index(drop=True, inplace=True)

result_df
# Out:
#                         Record Id         Created Time Created Date  \
# 0        zcrm_3584690000000404058  2019-01-07 15:08:38   2019-01-06
# 1        zcrm_3584690000000404059  2019-01-07 15:08:38   2019-01-06
# 2        zcrm_3584690000000404060  2019-01-07 15:08:38   2019-01-06
# 3        zcrm_3584690000000404065  2019-01-07 15:08:38   2019-01-06
# 4        zcrm_3584690000000404068  2019-01-07 15:08:38   2019-01-06
# ...                           ...                  ...          ...
# 9648794  zcrm_3584690000419507114  2022-12-26 15:30:31         <NA>
# 9648795  zcrm_3584690000419509006  2022-12-26 18:23:07         <NA>
# 9648796  zcrm_3584690000419509032  2022-12-26 18:54:40         <NA>
# 9648797  zcrm_3584690000419510020  2022-12-26 18:01:51         <NA>
# 9648798  zcrm_3584690000419510045  2022-12-26 18:57:43         <NA>
#
#            First Name   Last Name                        Email  \
# 0            Nicholas        Wood   1230woodnicholas@gmail.com
# ...

# %%
df_2023 = m.load_data_multiple(dir_path_2023, file_name, cols)
count_data_awal = df_2023.shape[0]
df_2023 = df_2023.reindex(columns=cols)
df_2023.shape[0]

# fungsi errors cource untuk menhindari error jika value data date null atau kosong
# df['Birthdate'] = pd.to_datetime(df['Birthdate'], format='%Y-%m-%d', errors='coerce')
df_2023.dtypes
df_2023
# Out:
#                         Record Id         Created Time Created Date  \
# 0        zcrm_3584690000000404058  2019-01-07 15:08:38   2019-01-06
# 1        zcrm_3584690000000404059  2019-01-07 15:08:38   2019-01-06
# 2        zcrm_3584690000000404060  2019-01-07 15:08:38   2019-01-06
# 3        zcrm_3584690000000404065  2019-01-07 15:08:38   2019-01-06
# 4        zcrm_3584690000000404068  2019-01-07 15:08:38   2019-01-06
# ...                           ...                  ...          ...
# 4711142  zcrm_3584690000473377001  2023-12-18 18:29:37         <NA>
# 4711143  zcrm_3584690000473382001  2023-12-18 18:38:23         <NA>
# 4711144  zcrm_3584690000473383001  2023-12-18 18:42:28         <NA>
# 4711145  zcrm_3584690000473384001  2023-12-18 18:42:59         <NA>
# 4711146  zcrm_3584690000473385001  2023-12-18 18:47:05         <NA>
#
#            First Name     Last Name                       Email  \
# 0            Nicholas          Wood  1230woodnicholas@gmail.com
# ...

# %%
result_df = pd.concat([result_df, df_2023], ignore_index=True)
result_df.drop_duplicates(subset=['Record Id'], inplace=True)
result_df.reset_index(drop=True, inplace=True)

result_df
# Out:
#                         Record Id         Created Time Created Date  \
# 0        zcrm_3584690000000404058  2019-01-07 15:08:38   2019-01-06
# 1        zcrm_3584690000000404059  2019-01-07 15:08:38   2019-01-06
# 2        zcrm_3584690000000404060  2019-01-07 15:08:38   2019-01-06
# 3        zcrm_3584690000000404065  2019-01-07 15:08:38   2019-01-06
# 4        zcrm_3584690000000404068  2019-01-07 15:08:38   2019-01-06
# ...                           ...                  ...          ...
# 9935198  zcrm_3584690000473377001  2023-12-18 18:29:37         <NA>
# 9935199  zcrm_3584690000473382001  2023-12-18 18:38:23         <NA>
# 9935200  zcrm_3584690000473383001  2023-12-18 18:42:28         <NA>
# 9935201  zcrm_3584690000473384001  2023-12-18 18:42:59         <NA>
# 9935202  zcrm_3584690000473385001  2023-12-18 18:47:05         <NA>
#
#            First Name     Last Name                       Email  \
# 0            Nicholas          Wood  1230woodnicholas@gmail.com
# ...

# %%
df_2024 = m.load_data_multiple(dir_path_2024, file_name, cols)
count_data_awal = df_2024.shape[0]
df_2024 = df_2024.reindex(columns=cols)
df_2024.shape[0]

# fungsi errors cource untuk menhindari error jika value data date null atau kosong
# df['Birthdate'] = pd.to_datetime(df['Birthdate'], format='%Y-%m-%d', errors='coerce')
df_2024.dtypes
df_2024
# Out:
#                         Record Id         Created Time Created Date  \
# 0        zcrm_3584690000000404058  2019-01-07 15:08:38   2019-01-06
# 1        zcrm_3584690000000404059  2019-01-07 15:08:38   2019-01-06
# 2        zcrm_3584690000000404060  2019-01-07 15:08:38   2019-01-06
# 3        zcrm_3584690000000404065  2019-01-07 15:08:38   2019-01-06
# 4        zcrm_3584690000000404068  2019-01-07 15:08:38   2019-01-06
# ...                           ...                  ...          ...
# 1888025  zcrm_3584690000489266005  2024-03-25 16:19:45         <NA>
# 1888026  zcrm_3584690000489266034  2024-03-25 16:19:51         <NA>
# 1888027  zcrm_3584690000489266063  2024-03-25 17:29:27         <NA>
# 1888028  zcrm_3584690000489269015  2024-03-25 16:20:25         <NA>
# 1888029  zcrm_3584690000489271002  2024-03-25 18:40:17         <NA>
#
#         First Name   Last Name                                 Email  \
# 0         Nicholas        Wood            1230woodnicholas@gmail.com
# ...

# %%
result_df = pd.concat([result_df, df_2024], ignore_index=True)
result_df.drop_duplicates(subset=['Record Id'], inplace=True)
result_df.reset_index(drop=True, inplace=True)

result_df
# Out:
#                         Record Id         Created Time Created Date  \
# 0        zcrm_3584690000000404058  2019-01-07 15:08:38   2019-01-06
# 1        zcrm_3584690000000404059  2019-01-07 15:08:38   2019-01-06
# 2        zcrm_3584690000000404060  2019-01-07 15:08:38   2019-01-06
# 3        zcrm_3584690000000404065  2019-01-07 15:08:38   2019-01-06
# 4        zcrm_3584690000000404068  2019-01-07 15:08:38   2019-01-06
# ...                           ...                  ...          ...
# 9965980  zcrm_3584690000489266005  2024-03-25 16:19:45         <NA>
# 9965981  zcrm_3584690000489266034  2024-03-25 16:19:51         <NA>
# 9965982  zcrm_3584690000489266063  2024-03-25 17:29:27         <NA>
# 9965983  zcrm_3584690000489269015  2024-03-25 16:20:25         <NA>
# 9965984  zcrm_3584690000489271002  2024-03-25 18:40:17         <NA>
#
#         First Name   Last Name                                 Email  \
# 0         Nicholas        Wood            1230woodnicholas@gmail.com
# ...

# %%
result_df.shape[0]
# Out:
# 9965985

# %%
result_df.to_csv(r'C:\Users\fajar\Documents\Python\Data\Zoho_Backup\2020-2024\backup.csv', index=False)
