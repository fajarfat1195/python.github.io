# %%
import main_module as m
import zoho_filter_module as fil
import pandas as pd
import re
import numpy as np

# %load_ext autoreload
# %autoreload 2

# %%
path = r'C:\Users\fajar\Documents\Python\Data\zoho.xlsx'
df = pd.read_excel(path, dtype='string', sheet_name='Sheet1')
df
# Out:
#                       Record Id         Created Time Created Date First Name  \
# 0      zcrm_3584690000000450087  2019-01-08 16:38:18         <NA>    Siobhan
# 1      zcrm_3584690000000450109  2019-01-08 16:38:18         <NA>  Ana Maria
# 2      zcrm_3584690000000450110  2019-01-08 16:38:18         <NA>      Maeve
# 3      zcrm_3584690000000450116  2019-01-08 16:38:18         <NA>     Moritz
# 4      zcrm_3584690000000450136  2019-01-08 16:38:18         <NA>  Christina
# ...                         ...                  ...          ...        ...
# 55415  zcrm_3584690000425348457  2023-01-30 15:44:35         <NA>    SOUGATA
# 55416  zcrm_3584690000425348545  2023-01-30 18:41:55         <NA>   Himanshu
# 55417  zcrm_3584690000425354441  2023-01-30 17:45:42         <NA>       SONU
# 55418  zcrm_3584690000425360301  2023-01-30 16:25:23         <NA>    Chethan
# 55419  zcrm_3584690000425364305  2023-01-30 16:55:41         <NA>     Sanjay
#
# ...

# %%
df.loc[(~df['Email'].isna()) & (~df['Phone'].isna())].to_excel(r'C:\Users\fajar\Documents\Python\Data\zoho_phone_email.xlsx', index=False)
df.loc[(~df['Email'].isna()) & (df['Phone'].isna())].to_excel(r'C:\Users\fajar\Documents\Python\Data\zoho_email_only.xlsx', index=False)
df.loc[(df['Email'].isna()) & (~df['Phone'].isna())].to_excel(r'C:\Users\fajar\Documents\Python\Data\zoho_phone_only.xlsx', index=False)

# %% [markdown]
# # ====================== Awal Filter Umum ======================
