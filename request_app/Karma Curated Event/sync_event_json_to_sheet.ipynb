# %%
import requests
import pandas as pd

import gspread
import pandas as pd
from fractions import Fraction
import re

# Pastikan permision access di menu "Share" di rubah ke anyone with the link terlebih dahulu, agar bisa mengunakan cara OAuth
# Jika Ingin lebih dibatasi menggunakan cara google service account lebih disarankan

gc = gspread.oauth(
    credentials_filename= r'..\..\Data\Google Credentials\karma-oauth.json'
)

SHEET_ID = '1k-70BJNRm01RE2S7gBXuOfqxofk1gYz4g6lPbLUCklw'
SHEET_NAME = 'Event List'
# SHEET_NAME = 'DB Test'


# Step 1: Fetch the JSON data from the URL
url = "https://karmagroup.com/karma-curated-list-json/"
response = requests.get(url)

# Check if the request was successful
if response.status_code == 200:
    data = response.json()  # Parse the JSON data

    # Step 2: Convert JSON data into a DataFrame
    df_json = pd.DataFrame(data)

    # Step 3: Display the DataFrame
    print("DataFrame created successfully:")

    print("DataFrame saved to 'karma_events.csv'")

else:
    print(f"Failed to fetch data. Status code: {response.status_code}")

df_json
# Out:
# DataFrame created successfully:
# DataFrame saved to 'karma_events.csv'
#                                                  name                  dates  \
# 0                          Polo in the City: Adelaide            19 Dec 2025
# 1                             Polo in the City: PERTH            13 Dec 2025
# 2   Bohemian Rhapsody: Freddie’s Hometown Musical ...  08 Dec to 11 Dec 2025
# 3                          Christmas in the Cotswolds  05 Dec to 08 Dec 2025
# 4               Secrets Of The Tuscan Truffle Hunters  05 Dec to 07 Dec 2025
# ..                                                ...                    ...
# 84        Fawlty Towers: A Comical Dining Experience!            08 May 2025
# 85      Ancient Traditions & Flavours of Eastern Bali  06 May to 09 May 2025
# 86     Where Tibet Meets India: A Himalayan Adventure  05 May to 09 May 2025
# 87                      Phillip Island Penguin Parade  02 May to 04 May 2025
# 88      Member Mixer: Rooftop Rendezvous in Melbourne            01 May 2025
#
#                                                 event  \
# 0            Polo in the City: Adelaide (19 Dec 2025)
# 1               Polo in the City: PERTH (13 Dec 2025)
# 2   Bohemian Rhapsody: Freddie’s Hometown Musical ...
# 3   Christmas in the Cotswolds (05 Dec to 08 Dec 2...
# 4   Secrets Of The Tuscan Truffle Hunters (05 Dec ...
# ..                                                ...
# 84  Fawlty Towers: A Comical Dining Experience! (0...
# 85  Ancient Traditions & Flavours of Eastern Bali ...
# 86  Where Tibet Meets India: A Himalayan Adventure...
# 87  Phillip Island Penguin Parade (02 May to 04 Ma...
# 88  Member Mixer: Rooftop Rendezvous in Melbourne ...
#
#                      destination  \
# 0            Adelaide, Australia
# 1               Perth, Australia
# 2           Mahabaleshwar, India
# 3   Warwickshire, United Kingdom
# 4                 Tuscany, Italy
# ..                           ...
# 84             Sydney, Australia
# 85               Candidasa, Bali
# 86                Gangtok, India
# 87                VIC, Australia
# 88          Melbourne, Australia
#
#                                    event_email_banner event_email_banner_id
# 0   https://storage.karmagroup.com/assets/karmagro...                 87951
# 1   https://storage.karmagroup.com/assets/karmagro...                 88081
# 2   https://storage.karmagroup.com/assets/karmagro...                 85864
# 3   https://storage.karmagroup.com/assets/karmagro...                 85813
# 4   https://storage.karmagroup.com/assets/karmagro...                 85831
# ..                                                ...                   ...
# 84
# 85  https://storage.karmagroup.com/assets/karmagro...                 85873
# 86  https://storage.karmagroup.com/assets/karmagro...                 85848
# 87
# 88
#
# [89 rows x 6 columns]

# %%
# get data gsheet

spreadsheet = gc.open_by_key(SHEET_ID)
worksheet = spreadsheet.worksheet(SHEET_NAME)
rows = worksheet.get_all_records()

# print(rows[:5])

# print('==============================')
# df = pd.DataFrame(rows, dtype="string")
df_sheets = pd.DataFrame(rows)
# df['Mobile Number'] = df['Mobile Number'].apply(Fraction)
df_sheets
# Out:
#                                                  name                  dates  \
# 0                           Summer Long Lunch: SYDNEY            09 Nov 2025
# 1                       Titans of Rugby at Twickenham            08 Nov 2025
# 2                            Polo in the City: SYDNEY            08 Nov 2025
# 3         Flavoursome Fungi & Medici Magic in Tuscany  07 Nov to 09 Nov 2025
# 4                        Eco Luxury: Broome Weekender  31 Oct to 02 Nov 2025
# ..                                                ...                    ...
# 91              Cocktails, Canapes & Grand Slam Glory            20 Jan 2025
# 92                       Member Mixer: Game, Set, Sip            19 Jan 2025
# 93        Digital-Detox: A Country Retreat in Tuscany  02 May to 05 May 2025
# 94      Sacred Summit: Mount Agung Trekking Adventure  06 Apr to 09 Apr 2025
# 95  Alpine Wellness Adventure
# in Bavaria’s Heartl...  30 Mar to 02 Apr 2025
#
#                                                 event  \
# 0             Summer Long Lunch: SYDNEY (09 Nov 2025)
# 1         Titans of Rugby at Twickenham (08 Nov 2025)
# 2              Polo in the City: SYDNEY (08 Nov 2025)
# 3   Flavoursome Fungi & Medici Magic in Tuscany (0...
# 4   Eco Luxury: Broome Weekender (31 Oct to 02 Nov...
# ..                                                ...
# 91  Cocktails, Canapes & Grand Slam Glory (20 Jan ...
# 92         Member Mixer: Game, Set, Sip (19 Jan 2025)
# 93  Digital-Detox: A Country Retreat in Tuscany (0...
# 94  Sacred Summit: Mount Agung Trekking Adventure ...
# 95  Alpine Wellness Adventure
# in Bavaria’s Heartl...
#
#                      destination  \
# 0              Sydney, Australia
# 1     Twickenham, United Kingdom
# 2              Sydney, Australia
# 3                 Tuscany, Italy
# 4   Western Australia, Australia
# ..                           ...
# 91                     Melbourne
# 92            Melbourne VIC 3000
# 93                Tuscany, Italy
# 94                          Bali
# 95           Schliersee, Germany
#
#                                    event_email_banner event_email_banner_id
# 0   https://storage.karmagroup.com/assets/karmagro...                 87886
# 1   https://storage.karmagroup.com/assets/karmagro...                 86867
# 2   https://storage.karmagroup.com/assets/karmagro...                 88088
# 3   https://storage.karmagroup.com/assets/karmagro...                 85829
# 4
# ..                                                ...                   ...
# 91
# 92
# 93  https://storage.karmagroup.com/assets/karmagro...                 85821
# 94  https://storage.karmagroup.com/assets/karmagro...                 85868
# 95  https://storage.karmagroup.com/assets/karmagro...                 85835
#
# [96 rows x 6 columns]

# %%
# Perform a left join between df_sheets and df on the 'event' column
df_join = pd.merge(df_sheets, df_json, how='left', on='event')

# Select specific columns and filter rows where 'name_y' is null (event doesn't exist in df_json, but exist in df_sheets)
df_not_exists = df_join.loc[
    df_join['name_y'].isnull(),  # Filter condition
    ['name_x', 'dates_x', 'event', 'destination_x', 'event_email_banner_x', 'event_email_banner_id_x']  # Selected columns
].copy()

# Rename columns by removing the '_x' suffix
df_not_exists = df_not_exists.rename(columns={
    'name_x': 'name',
    'dates_x': 'dates',
    'destination_x': 'destination',
    'event_email_banner_x': 'event_email_banner',
    'event_email_banner_id_x': 'event_email_banner_id'
})

# Display the resulting DataFrame
print(df_not_exists)

# Optionally, convert the filtered DataFrame to a list of lists
not_exists_list = df_not_exists.values.tolist()
print(not_exists_list)
# Out:
#                                                  name                  dates  \
# 22                   Watersports & Wellness Weekender  23 Aug to 25 Aug 2025
# 40                     Saints & Sinners in Andalusia  16 Jun to 20 Jun 2025
# 63  Melukat: A Balinese Spiritual & Cultural Immer...  25 Apr to 28 Apr 2025
# 64             Karma Supper Club: Flavours of Freedom            25 Apr 2025
# 65              As You Like It in Shakespeare Country  22 Apr to 24 Apr 2025
# 66           Discover the Authentic Tastes of Tuscany  18 Apr to 21 Apr 2025
# 67  Songkran Splash: Thailand’s Unforgettable Wate...  12 Apr to 14 Apr 2025
# 68          Konkan Flavours: A Royal Culinary Journey  07 Apr to 10 Apr 2025
# 69                 Pedals & Pampering in Wine Country  04 Apr to 06 Apr 2025
# 70           Karma Attends: Andrea Bocelli in Concert            03 Apr 2025
# 71         Forest Bathing, Qi Qong & Gourmet Delights  28 Mar to 30 Mar 2025
# 72            Karma Supper Club: Curries of the World            28 Mar 2025
# 73               Single Malt, Spice & All Things Nice  17 Mar to 19 Mar 2025
# 74       Cheltenham Races: High Stakes & High Society  11 Mar to 13 Mar 2025
# 75   Wild Wings & Fine Fizz in the Scottish Highlands  22 Sep to 24 Sep 2025
# 76                           Bunbury Cup WA Weekender  07 Mar to 09 Mar 2025
# 77                                 Perth Member Mixer            06 Mar 2025
# 78                              Trullo, Madly, Deeply            28 Feb 2025
# 79              Shuck & Sip: Sydney Oyster Experience            22 Feb 2025
# 80                              The Nile’s VIP Voyage  13 Feb to 20 Feb 2025
# 81    Alpine Adventures & Legends of the Wolpertinger  11 Feb to 14 Feb 2025
# 82  Strawberry Fields & Culinary Classics in Mahar...  09 Feb to 11 Feb 2025
# 83              All Aboard: Australia Sail Grand Prix            08 Feb 2025
# 84                       Karma x CUB Networking Lunch            09 May 2025
# 85       Himalayan Skiing & Winter Carnival Adventure  04 Feb to 08 Feb 2025
# 86                               James Bond’s Udaipur  03 Feb to 06 Feb 2025
# 87         White Heat: A Culinary Masterpiece Evening            31 Jan 2025
# 88                            Karma Long Lunch: Perth            27 Jan 2025
# 89                Experience VIP Rugby Sevens Heaven!            26 Jan 2025
# 90             Beginners’ Ski & Feast with Chef Dario  21 Jan to 24 Jan 2025
# 91              Cocktails, Canapes & Grand Slam Glory            20 Jan 2025
# 92                       Member Mixer: Game, Set, Sip            19 Jan 2025
# 93        Digital-Detox: A Country Retreat in Tuscany  02 May to 05 May 2025
# 94      Sacred Summit: Mount Agung Trekking Adventure  06 Apr to 09 Apr 2025
# 95  Alpine Wellness Adventure in Bavaria’s Heartl...  30 Mar to 02 Apr 2025
#
#                                                 event  \
# 22  Watersports & Wellness Weekender (23 Aug to 25...
# 40  Saints & Sinners in Andalusia (16 Jun to 20 J...
# 63  Melukat: A Balinese Spiritual & Cultural Immer...
# 64  Karma Supper Club: Flavours of Freedom (25 Apr...
# 65  As You Like It in Shakespeare Country (22 Apr ...
# 66  Discover the Authentic Tastes of Tuscany (18 A...
# 67  Songkran Splash: Thailand’s Unforgettable Wate...
# 68  Konkan Flavours: A Royal Culinary Journey (07 ...
# 69  Pedals & Pampering in Wine Country (04 Apr to ...
# 70  Karma Attends: Andrea Bocelli in Concert (03 A...
# 71  Forest Bathing, Qi Qong & Gourmet Delights (28...
# 72  Karma Supper Club: Curries of the World (28 Ma...
# 73  Single Malt, Spice & All Things Nice (17 Mar t...
# 74  Cheltenham Races: High Stakes & High Society (...
# 75  Wild Wings & Fine Fizz in the Scottish Highlan...
# 76   Bunbury Cup WA Weekender (07 Mar to 09 Mar 2025)
# 77                   Perth Member Mixer (06 Mar 2025)
# 78                Trullo, Madly, Deeply (28 Feb 2025)
# 79  Shuck & Sip: Sydney Oyster Experience (22 Feb ...
# 80      The Nile’s VIP Voyage (13 Feb to 20 Feb 2025)
# 81  Alpine Adventures & Legends of the Wolpertinge...
# 82  Strawberry Fields & Culinary Classics in Mahar...
# 83  All Aboard: Australia Sail Grand Prix (08 Feb ...
# 84         Karma x CUB Networking Lunch (09 May 2025)
# 85  Himalayan Skiing & Winter Carnival Adventure (...
# 86       James Bond’s Udaipur (03 Feb to 06 Feb 2025)
# 87  White Heat: A Culinary Masterpiece Evening (31...
# 88              Karma Long Lunch: Perth (27 Jan 2025)
# 89  Experience VIP Rugby Sevens Heaven! (26 Jan 2025)
# 90  Beginners’ Ski & Feast with Chef Dario (21 Jan...
# 91  Cocktails, Canapes & Grand Slam Glory (20 Jan ...
# 92         Member Mixer: Game, Set, Sip (19 Jan 2025)
# 93  Digital-Detox: A Country Retreat in Tuscany (0...
# 94  Sacred Summit: Mount Agung Trekking Adventure ...
# 95  Alpine Wellness Adventure in Bavaria’s Heartl...
#
#                            destination  \
# 22                       Ungasan, Bali
# 40                       Gaucín, Spain
# 63                     Bali, Indonesia
# 64                       Gaucin, Spain
# 65        Warwickshire, United Kingdom
# 66                      Tuscany, Italy
# 67                 Koh Samui, Thailand
# 68                          Goa, India
# 69             Pokolbin NSW, Australia
# 70                   Sydney, Australia
# 71        Western Australia, Australia
# 72                               India
# 73                          Goa, India
# 74                      United Kingdom
# 75                  Stirling, Scotland
# 76                        Bunbury, WA
# 77                           Australia
# 78                     Bali, Indonesia
# 79                Hawkesbury River NSW
# 80                        Luxor, Egypt
# 81                 Schliersee, Germany
# 82                Mahabaleshwar, India
# 83                     Sydney Harbour
# 84                   Sydney, Australia
# 85                       Manali, India
# 86                    Rajasthan, India
# 87        Warwickshire, United Kingdom
# 88  H&C Urban Winery, Fremantle, Perth
# 89                     HBF Park, Perth
# 90                 Schliersee, Germany
# 91                           Melbourne
# 92                  Melbourne VIC 3000
# 93                      Tuscany, Italy
# 94                                Bali
# 95                 Schliersee, Germany
#
#                                    event_email_banner event_email_banner_id
# 22  https://storage.karmagroup.com/assets/karmagro...                 85892
# 40  https://storage.karmagroup.com/assets/karmagro...                 85911
# 63  https://storage.karmagroup.com/assets/karmagro...                 85870
# 64  https://storage.karmagroup.com/assets/karmagro...                 87324
# 65  https://storage.karmagroup.com/assets/karmagro...                 85815
# 66  https://storage.karmagroup.com/assets/karmagro...                 85819
# 67  https://storage.karmagroup.com/assets/karmagro...                 85898
# 68  https://storage.karmagroup.com/assets/karmagro...                 85846
# 69
# 70
# 71
# 72  https://storage.karmagroup.com/assets/karmagro...                 85844
# 73  https://storage.karmagroup.com/assets/karmagro...                 85842
# 74  https://storage.karmagroup.com/assets/karmagro...                 85795
# 75  https://storage.karmagroup.com/assets/karmagro...                 85811
# 76
# 77
# 78  https://storage.karmagroup.com/assets/karmagro...                 85866
# 79
# 80
# 81
# 82
# 83
# 84
# 85
# 86
# 87
# 88
# 89
# 90
# 91
# 92
# 93  https://storage.karmagroup.com/assets/karmagro...                 85821
# 94  https://storage.karmagroup.com/assets/karmagro...                 85868
# 95  https://storage.karmagroup.com/assets/karmagro...                 85835
# [['Watersports & Wellness Weekender', '23 Aug to 25 Aug 2025', 'Watersports & Wellness Weekender (23 Aug to 25 Aug 2025)', 'Ungasan, Bali', 'https://storage.karmagroup.com/assets/karmagroup.com/2024/12/182-Watersport-and-Wellness-Weekender.jpg', 85892], ['Saints & Sinners \u2028in Andalusia', '16 Jun to 20 Jun 2025', 'Saints & Sinners \u2028in Andalusia (16 Jun to 20 Jun 2025)', 'Gaucín, Spain', 'https://storage.karmagroup.com/assets/karmagroup.com/2024/11/175-Saints-and-Sinners.jpg', 85911], ['Melukat: A Balinese Spiritual & Cultural Immersion', '25 Apr to 28 Apr 2025', 'Melukat: A Balinese Spiritual & Cultural Immersion (25 Apr to 28 Apr 2025)', 'Bali, Indonesia', 'https://storage.karmagroup.com/assets/karmagroup.com/2024/11/154-Melukat.jpg', 85870], ['Karma Supper Club: Flavours of Freedom', '25 Apr 2025', 'Karma Supper Club: Flavours of Freedom (25 Apr 2025)', 'Gaucin, Spain', 'https://storage.karmagroup.com/assets/karmagroup.com/2025/04/4-Post-Event-Email-Banner-1.jpg', 87324], ['As You Like It in Shakespeare Country', '22 Apr to 24 Apr 2025', 'As You Like It in Shakespeare Country (22 Apr to 24 Apr 2025)', 'Warwickshire, United Kingdom', 'https://storage.karmagroup.com/assets/karmagroup.com/2024/11/153-AsYouLikeIT.jpg', 85815], ['Discover the Authentic Tastes of Tuscany', '18 Apr to 21 Apr 2025', 'Discover the Authentic Tastes of Tuscany (18 Apr to 21 Apr 2025)', 'Tuscany, Italy', 'https://storage.karmagroup.com/assets/karmagroup.com/2024/11/152-Discover-the-authentic-taste.jpg', 85819], ['Songkran Splash: Thailand’s Unforgettable Water Festival', '12 Apr to 14 Apr 2025', 'Songkran Splash: Thailand’s Unforgettable Water Festival (12 Apr to 14 Apr 2025)', 'Koh Samui, Thailand', 'https://storage.karmagroup.com/assets/karmagroup.com/2024/11/151-Songkran-Festival.jpg', 85898], ['Konkan Flavours: A Royal Culinary Journey', '07 Apr to 10 Apr 2025', 'Konkan Flavours: A Royal Culinary Journey (07 Apr to 10 Apr 2025)', 'Goa, India', 'https://storage.karmagroup.com/assets/karmagroup.com/2024/11/150-The-Konkan-Food.jpg', 85846], ['Pedals & Pampering in Wine Country', '04 Apr to 06 Apr 2025', 'Pedals & Pampering in Wine Country (04 Apr to 06 Apr 2025)', 'Pokolbin NSW, Australia', '', ''], ['Karma Attends: Andrea Bocelli in Concert', '03 Apr 2025', 'Karma Attends: Andrea Bocelli in Concert (03 Apr 2025)', 'Sydney, Australia', '', ''], ['Forest Bathing, Qi Qong & Gourmet Delights', '28 Mar to 30 Mar 2025', 'Forest Bathing, Qi Qong & Gourmet Delights (28 Mar to 30 Mar 2025)', 'Western Australia, Australia', '', ''], ['Karma Supper Club: Curries of the World', '28 Mar 2025', 'Karma Supper Club: Curries of the World (28 Mar 2025)', 'India', 'https://storage.karmagroup.com/assets/karmagroup.com/2025/02/3-Karma-Supper-Club.jpg', 85844], ['Single Malt, Spice & All Things Nice', '17 Mar to 19 Mar 2025', 'Single Malt, Spice & All Things Nice (17 Mar to 19 Mar 2025)', 'Goa, India', 'https://storage.karmagroup.com/assets/karmagroup.com/2024/11/147-Single-Malt.jpg', 85842], ['Cheltenham Races: High Stakes & High Society', '11 Mar to 13 Mar 2025', 'Cheltenham Races: High Stakes & High Society (11 Mar to 13 Mar 2025)', 'United Kingdom', 'https://storage.karmagroup.com/assets/karmagroup.com/2024/11/148-Cheltenham.jpg', 85795], ['Wild Wings & Fine Fizz in the Scottish Highlands', '22 Sep to 24 Sep 2025', 'Wild Wings & Fine Fizz in the Scottish Highlands (22 Sep to 24 Sep 2025)', ' Stirling, Scotland', 'https://storage.karmagroup.com/assets/karmagroup.com/2024/12/186-Wild-Wings.jpg', 85811], ['Bunbury Cup WA Weekender', '07 Mar to 09 Mar 2025', 'Bunbury Cup WA Weekender (07 Mar to 09 Mar 2025)', 'Bunbury, WA ', '', ''], ['Perth Member Mixer', '06 Mar 2025', 'Perth Member Mixer (06 Mar 2025)', 'Australia', '', ''], ['Trullo, Madly, Deeply', '28 Feb 2025', 'Trullo, Madly, Deeply (28 Feb 2025)', 'Bali, Indonesia', 'https://storage.karmagroup.com/assets/karmagroup.com/2025/01/3-Trullo.jpg', 85866], ['Shuck & Sip: Sydney Oyster Experience', '22 Feb 2025', ...

# %%
df_new = pd.concat([df_json, df_not_exists], ignore_index=True)
df_new
# Out:
#                                                   name                  dates  \
# 0                           Polo in the City: Adelaide            19 Dec 2025
# 1                              Polo in the City: PERTH            13 Dec 2025
# 2    Bohemian Rhapsody: Freddie’s Hometown Musical ...  08 Dec to 11 Dec 2025
# 3                           Christmas in the Cotswolds  05 Dec to 08 Dec 2025
# 4                Secrets Of The Tuscan Truffle Hunters  05 Dec to 07 Dec 2025
# ..                                                 ...                    ...
# 119              Cocktails, Canapes & Grand Slam Glory            20 Jan 2025
# 120                       Member Mixer: Game, Set, Sip            19 Jan 2025
# 121        Digital-Detox: A Country Retreat in Tuscany  02 May to 05 May 2025
# 122      Sacred Summit: Mount Agung Trekking Adventure  06 Apr to 09 Apr 2025
# 123  Alpine Wellness Adventure
# in Bavaria’s Heartl...  30 Mar to 02 Apr 2025
#
#                                                  event  \
# 0             Polo in the City: Adelaide (19 Dec 2025)
# 1                Polo in the City: PERTH (13 Dec 2025)
# 2    Bohemian Rhapsody: Freddie’s Hometown Musical ...
# 3    Christmas in the Cotswolds (05 Dec to 08 Dec 2...
# 4    Secrets Of The Tuscan Truffle Hunters (05 Dec ...
# ..                                                 ...
# 119  Cocktails, Canapes & Grand Slam Glory (20 Jan ...
# 120         Member Mixer: Game, Set, Sip (19 Jan 2025)
# 121  Digital-Detox: A Country Retreat in Tuscany (0...
# 122  Sacred Summit: Mount Agung Trekking Adventure ...
# 123  Alpine Wellness Adventure
# in Bavaria’s Heartl...
#
#                       destination  \
# 0             Adelaide, Australia
# 1                Perth, Australia
# 2            Mahabaleshwar, India
# 3    Warwickshire, United Kingdom
# 4                  Tuscany, Italy
# ..                            ...
# 119                     Melbourne
# 120            Melbourne VIC 3000
# 121                Tuscany, Italy
# 122                          Bali
# 123           Schliersee, Germany
#
#                                     event_email_banner event_email_banner_id
# 0    https://storage.karmagroup.com/assets/karmagro...                 87951
# 1    https://storage.karmagroup.com/assets/karmagro...                 88081
# 2    https://storage.karmagroup.com/assets/karmagro...                 85864
# 3    https://storage.karmagroup.com/assets/karmagro...                 85813
# 4    https://storage.karmagroup.com/assets/karmagro...                 85831
# ..                                                 ...                   ...
# 119
# 120
# 121  https://storage.karmagroup.com/assets/karmagro...                 85821
# 122  https://storage.karmagroup.com/assets/karmagro...                 85868
# 123  https://storage.karmagroup.com/assets/karmagro...                 85835
#
# [124 rows x 6 columns]

# %%
# Update keseluruhan data, delete data yang lama terlebih dahulu
# clear all row before update
worksheet.clear()
worksheet.update([df_new.columns.values.tolist()] + df_new.values.tolist())
# Out:
# {'spreadsheetId': '1k-70BJNRm01RE2S7gBXuOfqxofk1gYz4g6lPbLUCklw',
#  'updatedRange': "'Event List'!A1:F125",
#  'updatedRows': 125,
#  'updatedColumns': 6,
#  'updatedCells': 750}
