# %%
import requests
import pandas as pd

import gspread
import pandas as pd
from fractions import Fraction
import re

# Pastikan permision access di menu "Share" di rubah ke anyone with the link terlebih dahulu, agar bisa mengunakan cara OAuth
# Jika Ingin lebih dibatasi menggunakan cara google service account lebih disarankan

gc = gspread.oauth(
    credentials_filename= r'..\..\Data\Google Credentials\karma-oauth.json'
)

SHEET_ID = '1k-70BJNRm01RE2S7gBXuOfqxofk1gYz4g6lPbLUCklw'
SHEET_NAME = 'Event List'
# SHEET_NAME = 'DB Test'


# Step 1: Fetch the JSON data from the URL
url = "https://karmagroup.com/karma-curated-list-json/"
response = requests.get(url)

# Check if the request was successful
if response.status_code == 200:
    data = response.json()  # Parse the JSON data

    # Step 2: Convert JSON data into a DataFrame
    df_json = pd.DataFrame(data)

    # Step 3: Display the DataFrame
    print("DataFrame created successfully:")

    print("DataFrame saved to 'karma_events.csv'")

else:
    print(f"Failed to fetch data. Status code: {response.status_code}")

df_json
# Out:
# DataFrame created successfully:
# DataFrame saved to 'karma_events.csv'
#                                               name                  dates  \
# 0          Wild Flavours & Tropical Island Rhythms  20 Feb to 23 Feb 2026
# 1                                The Goa Spy Trail  13 Feb to 16 Feb 2026
# 2     Beginners’ Ski With Martina & Mountain Meals  07 Feb to 10 Feb 2026
# 3                    Murder Mysteries & Manor Life  06 Feb to 09 Feb 2026
# 4                         Weekend Wonder in Hobart  06 Feb to 08 Feb 2026
# ..                                             ...                    ...
# 74     Jazz Age Reverie: London’s Secret Speakeasy            23 Jul 2025
# 75                 A VIP Rugby Spectacle in Sydney            05 Jul 2025
# 76                        Karma Summer Social 2025            05 Jul 2025
# 77                Pre-Rugby Member Mixer in Sydney            04 Jul 2025
# 78  Lords of the Game: A Luxury Cricket Experience  03 Jul to 05 Jul 2025
#
#                                                 event  \
# 0   Wild Flavours & Tropical Island Rhythms (20 Fe...
# 1           The Goa Spy Trail (13 Feb to 16 Feb 2026)
# 2   Beginners’ Ski With Martina & Mountain Meals (...
# 3   Murder Mysteries & Manor Life (06 Feb to 09 Fe...
# 4    Weekend Wonder in Hobart (06 Feb to 08 Feb 2026)
# ..                                                ...
# 74  Jazz Age Reverie: London’s Secret Speakeasy (2...
# 75      A VIP Rugby Spectacle in Sydney (05 Jul 2025)
# 76             Karma Summer Social 2025 (05 Jul 2025)
# 77     Pre-Rugby Member Mixer in Sydney (04 Jul 2025)
# 78  Lords of the Game: A Luxury Cricket Experience...
#
#                 destination  \
# 0       Koh Samui, Thailand
# 1                Goa, India
# 2       Schliersee, Germany
# 3   The Vale of Evesham, UK
# 4       Tasmania, Australia
# ..                      ...
# 74   London, United Kingdom
# 75        Sydney, Australia
# 76  The Vale of Evesham, UK
# 77        Sydney, Australia
# 78           United Kingdom
#
#                                    event_email_banner event_email_banner_id
# 0   https://storage.karmagroup.com/assets/karmagro...                 88269
# 1
# 2   https://storage.karmagroup.com/assets/karmagro...                 90371
# 3
# 4
# ..                                                ...                   ...
# 74  https://storage.karmagroup.com/assets/karmagro...                 87933
# 75
# 76  https://storage.karmagroup.com/assets/karmagro...                 85807
# 77  https://storage.karmagroup.com/assets/karmagro...                 89430
# 78  https://storage.karmagroup.com/assets/karmagro...                 85805
#
# [79 rows x 6 columns]

# %%
# get data gsheet

spreadsheet = gc.open_by_key(SHEET_ID)
worksheet = spreadsheet.worksheet(SHEET_NAME)
rows = worksheet.get_all_records()

# print(rows[:5])

# print('==============================')
# df = pd.DataFrame(rows, dtype="string")
df_sheets = pd.DataFrame(rows)
# df['Mobile Number'] = df['Mobile Number'].apply(Fraction)
df_sheets
# Out:
#                                                   name                  dates  \
# 0                  Giants & Knights, Dreams & Dungeons  24 Jan to 26 Jan 2026
# 1                           Australian Open, VIP-Style            20 Jan 2026
# 2              The Orange Fest at Karma Martam Retreat  19 Jan to 22 Jan 2026
# 3             Alpine Tobogganing & Snow Polo Adventure  15 Jan to 18 Jan 2026
# 4                Canvas & Coast: Goa with Rajesh Chari  05 Jan to 08 Jan 2026
# ..                                                 ...                    ...
# 130              Cocktails, Canapes & Grand Slam Glory            20 Jan 2025
# 131                       Member Mixer: Game, Set, Sip            19 Jan 2025
# 132        Digital-Detox: A Country Retreat in Tuscany  02 May to 05 May 2025
# 133      Sacred Summit: Mount Agung Trekking Adventure  06 Apr to 09 Apr 2025
# 134  Alpine Wellness Adventure
# in Bavaria’s Heartl...  30 Mar to 02 Apr 2025
#
#                                                  event  \
# 0    Giants & Knights, Dreams & Dungeons (24 Jan to...
# 1             Australian Open, VIP-Style (20 Jan 2026)
# 2    The Orange Fest at Karma Martam Retreat (19 Ja...
# 3    Alpine Tobogganing & Snow Polo Adventure (15 J...
# 4    Canvas & Coast: Goa with Rajesh Chari (05 Jan ...
# ..                                                 ...
# 130  Cocktails, Canapes & Grand Slam Glory (20 Jan ...
# 131         Member Mixer: Game, Set, Sip (19 Jan 2025)
# 132  Digital-Detox: A Country Retreat in Tuscany (0...
# 133  Sacred Summit: Mount Agung Trekking Adventure ...
# 134  Alpine Wellness Adventure
# in Bavaria’s Heartl...
#
#                                            destination  \
# 0                         Warwickshire, United Kingdom
# 1                                 Melbourne, Australia
# 2    Karma Martam Retreat, P.O. Gangkha, Via Singta...
# 3                                  Schliersee, Germany
# 4                                                India
# ..                                                 ...
# 130                                          Melbourne
# 131                                 Melbourne VIC 3000
# 132                                     Tuscany, Italy
# 133                                               Bali
# 134                                Schliersee, Germany
#
#                                     event_email_banner event_email_banner_id
# 0
# 1    https://storage.karmagroup.com/assets/karmagro...                 87678
# 2
# 3
# 4
# ..                                                 ...                   ...
# 130
# 131
# 132  https://storage.karmagroup.com/assets/karmagro...                 85821
# 133  https://storage.karmagroup.com/assets/karmagro...                 85868
# 134  https://storage.karmagroup.com/assets/karmagro...                 85835
#
# [135 rows x 6 columns]

# %%
# Perform a left join between df_sheets and df on the 'event' column
df_join = pd.merge(df_sheets, df_json, how='left', on='event')

# Select specific columns and filter rows where 'name_y' is null (event doesn't exist in df_json, but exist in df_sheets)
df_not_exists = df_join.loc[
    df_join['name_y'].isnull(),  # Filter condition
    ['name_x', 'dates_x', 'event', 'destination_x', 'event_email_banner_x', 'event_email_banner_id_x']  # Selected columns
].copy()

# Rename columns by removing the '_x' suffix
df_not_exists = df_not_exists.rename(columns={
    'name_x': 'name',
    'dates_x': 'dates',
    'destination_x': 'destination',
    'event_email_banner_x': 'event_email_banner',
    'event_email_banner_id_x': 'event_email_banner_id'
})

# Display the resulting DataFrame
print(df_not_exists)

# Optionally, convert the filtered DataFrame to a list of lists
not_exists_list = df_not_exists.values.tolist()
print(not_exists_list)
# Out:
#                                                   name                  dates  \
# 1                           Australian Open, VIP-Style            20 Jan 2026
# 12         Digital-Detox: A Country Retreat in Tuscany  21 Nov to 23 Nov 2025
# 20                           Summer Long Lunch: SYDNEY            09 Nov 2025
# 31       Karma Attends: Cheltenham Literature Festival            11 Oct 2025
# 34      Goan Colours, Sunset Stories & Craft Creations  03 Oct to 06 Oct 2025
# ..                                                 ...                    ...
# 130              Cocktails, Canapes & Grand Slam Glory            20 Jan 2025
# 131                       Member Mixer: Game, Set, Sip            19 Jan 2025
# 132        Digital-Detox: A Country Retreat in Tuscany  02 May to 05 May 2025
# 133      Sacred Summit: Mount Agung Trekking Adventure  06 Apr to 09 Apr 2025
# 134  Alpine Wellness Adventure in Bavaria’s Heartl...  30 Mar to 02 Apr 2025
#
#                                                  event  \
# 1             Australian Open, VIP-Style (20 Jan 2026)
# 12   Digital-Detox: A Country Retreat in Tuscany (2...
# 20             Summer Long Lunch: SYDNEY (09 Nov 2025)
# 31   Karma Attends: Cheltenham Literature Festival ...
# 34   Goan Colours, Sunset Stories & Craft Creations...
# ..                                                 ...
# 130  Cocktails, Canapes & Grand Slam Glory (20 Jan ...
# 131         Member Mixer: Game, Set, Sip (19 Jan 2025)
# 132  Digital-Detox: A Country Retreat in Tuscany (0...
# 133  Sacred Summit: Mount Agung Trekking Adventure ...
# 134  Alpine Wellness Adventure in Bavaria’s Heartl...
#
#                  destination  \
# 1       Melbourne, Australia
# 12            Tuscany, Italy
# 20         Sydney, Australia
# 31   England, United Kingdom
# 34                Goa, India
# ..                       ...
# 130                Melbourne
# 131       Melbourne VIC 3000
# 132           Tuscany, Italy
# 133                     Bali
# 134      Schliersee, Germany
#
#                                     event_email_banner event_email_banner_id
# 1    https://storage.karmagroup.com/assets/karmagro...                 87678
# 12   https://storage.karmagroup.com/assets/karmagro...                 85821
# 20   https://storage.karmagroup.com/assets/karmagro...                 87886
# 31   https://storage.karmagroup.com/assets/karmagro...                 88918
# 34   https://storage.karmagroup.com/assets/karmagro...                 85858
# ..                                                 ...                   ...
# 130
# 131
# 132  https://storage.karmagroup.com/assets/karmagro...                 85821
# 133  https://storage.karmagroup.com/assets/karmagro...                 85868
# 134  https://storage.karmagroup.com/assets/karmagro...                 85835
#
# [77 rows x 6 columns]
# [['Australian Open, VIP-Style', '20 Jan 2026', 'Australian Open, VIP-Style (20 Jan 2026)', 'Melbourne, Australia', 'https://storage.karmagroup.com/assets/karmagroup.com/2025/04/245-Post-Event-Email-Banner.jpg', 87678], ['Digital-Detox: A Country Retreat in Tuscany', '21 Nov to 23 Nov 2025', 'Digital-Detox: A Country Retreat in Tuscany (21 Nov to 23 Nov 2025)', 'Tuscany, Italy', 'https://storage.karmagroup.com/assets/karmagroup.com/2024/11/161-3-Day-Detox.jpg', 85821], ['Summer Long Lunch: SYDNEY', '09 Nov 2025', 'Summer Long Lunch: SYDNEY (09 Nov 2025)', 'Sydney, Australia', 'https://storage.karmagroup.com/assets/karmagroup.com/2025/04/Post-Event-Email-Banner-250.jpg', 87886], ['Karma Attends: Cheltenham Literature Festival', '11 Oct 2025', 'Karma Attends: Cheltenham Literature Festival (11 Oct 2025)', 'England, United Kingdom', 'https://storage.karmagroup.com/assets/karmagroup.com/2025/05/Post-Event-Email-Banner-267.jpg', 88918], ['Goan Colours, Sunset Stories & Craft Creations', '03 Oct to 06 Oct 2025', 'Goan Colours, Sunset Stories & Craft Creations (03 Oct to 06 Oct 2025)', 'Goa, India', 'https://storage.karmagroup.com/assets/karmagroup.com/2024/12/192-Goan-Colours.jpg', 85858], ['Gourmet Mexico: Mezcal, Mole & Magic', '02 Oct to 07 Oct 2025', 'Gourmet Mexico: Mezcal, Mole & Magic (02 Oct to 07 Oct 2025)', 'Oaxaca, Mexico', 'https://storage.karmagroup.com/assets/karmagroup.com/2024/11/201-Gourmet-mexico.jpg', 85920], ['Peaks, Pedals and Bali Panoramas', '15 Sep to 18 Sep 2025', 'Peaks, Pedals and Bali Panoramas (15 Sep to 18 Sep 2025)', 'Ungasan, Bali', 'https://storage.karmagroup.com/assets/karmagroup.com/2024/12/187-Hike-Bike.jpg', 85894], ['Immersive Literary Experiences: Victoria Hislop at Karma Minoan', '11 Sep to 13 Sep 2025', 'Immersive Literary Experiences: Victoria Hislop at Karma Minoan (11 Sep to 13 Sep 2025)', 'Crete, Greece', '', ''], ['Alpine Adventures: Bavarian Nature Escape', '29 Jun to 02 Jul 2025', 'Alpine Adventures: Bavarian Nature Escape (29 Jun to 02 Jul 2025)', ' Schliersee, Germany', 'https://storage.karmagroup.com/assets/karmagroup.com/2024/12/211-Post-Event-Email-Banner.jpg', 87314], ['Witness The Legendary & Grand Lions In Perth', '28 Jun 2025', 'Witness The Legendary & Grand Lions In Perth (28 Jun 2025)', 'Perth, Australia', '', ''], ['Karma Supper Club: A Gastronomic Feast at Karma St Martin’s', '28 Jun 2025', 'Karma Supper Club: A Gastronomic Feast at Karma St Martin’s (28 Jun 2025)', 'Isles of Scilly, United Kingdom', 'https://storage.karmagroup.com/assets/karmagroup.com/2025/05/Post-Event-Email-Banner-6.jpg', 88833], ['Crete: Myths, Mountains & Mediterranean Flavours', '26 Jun to 29 Jun 2025', 'Crete: Myths, Mountains & Mediterranean Flavours (26 Jun to 29 Jun 2025)', 'Crete, Greece', 'https://storage.karmagroup.com/assets/karmagroup.com/2024/11/174-Crete_Myths.jpg', 85915], ['World Class Tennis at Eastbourne', '26 Jun 2025', 'World Class Tennis at Eastbourne (26 Jun 2025)', 'Eastbourne', 'https://storage.karmagroup.com/assets/karmagroup.com/2024/12/189-World-Class-Tennis.jpg', 85803], ['Padel, Pampering & Putts in Paradise', '25 Jun to 28 Jun 2025', 'Padel, Pampering & Putts in Paradise (25 Jun to 28 Jun 2025)', 'Bali, Indonesia', 'https://storage.karmagroup.com/assets/karmagroup.com/2025/01/209-Padel_pampering_golf.jpg', 85883], ['Bannockburn & Scotland’s Storied Legacy', '23 Jun to 25 Jun 2025', 'Bannockburn & Scotland’s Storied Legacy (23 Jun to 25 Jun 2025)', ' Stirling, Scotland', 'https://storage.karmagroup.com/assets/karmagroup.com/2024/11/173-Bannockburn.jpg', 85797], ['Vietnam’s Tropical Treasures: Coastlines & Coral Reefs', '21 Jun to 23 Jun 2025', 'Vietnam’s Tropical Treasures: Coastlines & Coral Reefs (21 Jun to 23 Jun 2025)', 'Hoi An, Vietnam', 'https://storage.karmagroup.com/assets/karmagroup.com/2024/11/172-Vietnam-Tropical-Treasure.jpg', 85903], ['Margaret River Winery Weekend', '20 Jun to 22 Jun 2025', 'Margaret River Winery Weekend (20 Jun to 22 Jun 2025)', 'Western Austr ...

# %%
df_new = pd.concat([df_json, df_not_exists], ignore_index=True)
df_new
# Out:
#                                                   name                  dates  \
# 0              Wild Flavours & Tropical Island Rhythms  20 Feb to 23 Feb 2026
# 1                                    The Goa Spy Trail  13 Feb to 16 Feb 2026
# 2         Beginners’ Ski With Martina & Mountain Meals  07 Feb to 10 Feb 2026
# 3                        Murder Mysteries & Manor Life  06 Feb to 09 Feb 2026
# 4                             Weekend Wonder in Hobart  06 Feb to 08 Feb 2026
# ..                                                 ...                    ...
# 151              Cocktails, Canapes & Grand Slam Glory            20 Jan 2025
# 152                       Member Mixer: Game, Set, Sip            19 Jan 2025
# 153        Digital-Detox: A Country Retreat in Tuscany  02 May to 05 May 2025
# 154      Sacred Summit: Mount Agung Trekking Adventure  06 Apr to 09 Apr 2025
# 155  Alpine Wellness Adventure
# in Bavaria’s Heartl...  30 Mar to 02 Apr 2025
#
#                                                  event  \
# 0    Wild Flavours & Tropical Island Rhythms (20 Fe...
# 1            The Goa Spy Trail (13 Feb to 16 Feb 2026)
# 2    Beginners’ Ski With Martina & Mountain Meals (...
# 3    Murder Mysteries & Manor Life (06 Feb to 09 Fe...
# 4     Weekend Wonder in Hobart (06 Feb to 08 Feb 2026)
# ..                                                 ...
# 151  Cocktails, Canapes & Grand Slam Glory (20 Jan ...
# 152         Member Mixer: Game, Set, Sip (19 Jan 2025)
# 153  Digital-Detox: A Country Retreat in Tuscany (0...
# 154  Sacred Summit: Mount Agung Trekking Adventure ...
# 155  Alpine Wellness Adventure
# in Bavaria’s Heartl...
#
#                  destination  \
# 0        Koh Samui, Thailand
# 1                 Goa, India
# 2        Schliersee, Germany
# 3    The Vale of Evesham, UK
# 4        Tasmania, Australia
# ..                       ...
# 151                Melbourne
# 152       Melbourne VIC 3000
# 153           Tuscany, Italy
# 154                     Bali
# 155      Schliersee, Germany
#
#                                     event_email_banner event_email_banner_id
# 0    https://storage.karmagroup.com/assets/karmagro...                 88269
# 1
# 2    https://storage.karmagroup.com/assets/karmagro...                 90371
# 3
# 4
# ..                                                 ...                   ...
# 151
# 152
# 153  https://storage.karmagroup.com/assets/karmagro...                 85821
# 154  https://storage.karmagroup.com/assets/karmagro...                 85868
# 155  https://storage.karmagroup.com/assets/karmagro...                 85835
#
# [156 rows x 6 columns]

# %%
# Update keseluruhan data, delete data yang lama terlebih dahulu
# clear all row before update
worksheet.clear()
worksheet.update([df_new.columns.values.tolist()] + df_new.values.tolist())
# Out:
# {'spreadsheetId': '1k-70BJNRm01RE2S7gBXuOfqxofk1gYz4g6lPbLUCklw',
#  'updatedRange': "'Event List'!A1:F157",
#  'updatedRows': 157,
#  'updatedColumns': 6,
#  'updatedCells': 942}
