# %%
import requests
import pandas as pd

import gspread
import pandas as pd
from fractions import Fraction
import re

# Pastikan permision access di menu "Share" di rubah ke anyone with the link terlebih dahulu, agar bisa mengunakan cara OAuth
# Jika Ingin lebih dibatasi menggunakan cara google service account lebih disarankan

gc = gspread.oauth(
    credentials_filename= r'..\..\Data\Google Credentials\karma-oauth.json'
)

SHEET_ID = '1k-70BJNRm01RE2S7gBXuOfqxofk1gYz4g6lPbLUCklw'
SHEET_NAME = 'Event List'
# SHEET_NAME = 'DB Test'


# Step 1: Fetch the JSON data from the URL
url = "https://karmagroup.com/karma-curated-list-json/"
response = requests.get(url)

# Check if the request was successful
if response.status_code == 200:
    data = response.json()  # Parse the JSON data

    # Step 2: Convert JSON data into a DataFrame
    df_json = pd.DataFrame(data)

    # Step 3: Display the DataFrame
    print("DataFrame created successfully:")

    print("DataFrame saved to 'karma_events.csv'")

else:
    print(f"Failed to fetch data. Status code: {response.status_code}")

df_json
# Out:
# DataFrame created successfully:
# DataFrame saved to 'karma_events.csv'
#                                             name                  dates  \
# 0                      Summer Long Lunch: SYDNEY            09 Nov 2025
# 1                  Titans of Rugby at Twickenham            08 Nov 2025
# 2                       Polo in the City: SYDNEY            08 Nov 2025
# 3    Flavoursome Fungi & Medici Magic in Tuscany  07 Nov to 09 Nov 2025
# 4                   Eco Luxury: Broome Weekender  31 Oct to 02 Nov 2025
# ..                                           ...                    ...
# 70      Karma Attends: Andrea Bocelli in Concert            03 Apr 2025
# 71    Forest Bathing, Qi Qong & Gourmet Delights  28 Mar to 30 Mar 2025
# 72       Karma Supper Club: Curries of the World            28 Mar 2025
# 73          Single Malt, Spice & All Things Nice  17 Mar to 19 Mar 2025
# 74  Cheltenham Races: High Stakes & High Society  11 Mar to 13 Mar 2025
#
#                                                 event  \
# 0             Summer Long Lunch: SYDNEY (09 Nov 2025)
# 1         Titans of Rugby at Twickenham (08 Nov 2025)
# 2              Polo in the City: SYDNEY (08 Nov 2025)
# 3   Flavoursome Fungi & Medici Magic in Tuscany (0...
# 4   Eco Luxury: Broome Weekender (31 Oct to 02 Nov...
# ..                                                ...
# 70  Karma Attends: Andrea Bocelli in Concert (03 A...
# 71  Forest Bathing, Qi Qong & Gourmet Delights (28...
# 72  Karma Supper Club: Curries of the World (28 Ma...
# 73  Single Malt, Spice & All Things Nice (17 Mar t...
# 74  Cheltenham Races: High Stakes & High Society (...
#
#                      destination  \
# 0              Sydney, Australia
# 1     Twickenham, United Kingdom
# 2              Sydney, Australia
# 3                 Tuscany, Italy
# 4   Western Australia, Australia
# ..                           ...
# 70             Sydney, Australia
# 71  Western Australia, Australia
# 72                         India
# 73                    Goa, India
# 74                United Kingdom
#
#                                    event_email_banner event_email_banner_id
# 0   https://storage.karmagroup.com/assets/karmagro...                 87886
# 1   https://storage.karmagroup.com/assets/karmagro...                 86867
# 2   https://storage.karmagroup.com/assets/karmagro...                 88088
# 3   https://storage.karmagroup.com/assets/karmagro...                 85829
# 4
# ..                                                ...                   ...
# 70
# 71
# 72  https://storage.karmagroup.com/assets/karmagro...                 85844
# 73  https://storage.karmagroup.com/assets/karmagro...                 85842
# 74  https://storage.karmagroup.com/assets/karmagro...                 85795
#
# [75 rows x 6 columns]

# %%
# get data gsheet

spreadsheet = gc.open_by_key(SHEET_ID)
worksheet = spreadsheet.worksheet(SHEET_NAME)
rows = worksheet.get_all_records()

# print(rows[:5])

# print('==============================')
# df = pd.DataFrame(rows, dtype="string")
df_sheets = pd.DataFrame(rows)
# df['Mobile Number'] = df['Mobile Number'].apply(Fraction)
df_sheets
# Out:
#                                                  name                  dates  \
# 0                        Dolphins at Dawn in Paradise  08 Oct to 10 Oct 2025
# 1                  World Class Rugby & VIP Indulgence            04 Oct 2025
# 2      Goan Colours, Sunset Stories & Craft Creations  03 Oct to 06 Oct 2025
# 3                Gourmet Mexico: Mezcal, Mole & Magic  02 Oct to 07 Oct 2025
# 4   Goan Wilderness Adventure & Tropical Forest Es...  01 Oct to 04 Oct 2025
# ..                                                ...                    ...
# 79              Cocktails, Canapes & Grand Slam Glory            20 Jan 2025
# 80                       Member Mixer: Game, Set, Sip            19 Jan 2025
# 81        Digital-Detox: A Country Retreat in Tuscany  02 May to 05 May 2025
# 82      Sacred Summit: Mount Agung Trekking Adventure  06 Apr to 09 Apr 2025
# 83  Alpine Wellness Adventure
# in Bavaria’s Heartl...  30 Mar to 02 Apr 2025
#
#                                                 event          destination  \
# 0   Dolphins at Dawn in Paradise (08 Oct to 10 Oct...      Bali, Indonesia
# 1    World Class Rugby & VIP Indulgence (04 Oct 2025)     Perth, Australia
# 2   Goan Colours, Sunset Stories & Craft Creations...           Goa, India
# 3   Gourmet Mexico: Mezcal, Mole & Magic (02 Oct t...       Oaxaca, Mexico
# 4   Goan Wilderness Adventure & Tropical Forest Es...                  Goa
# ..                                                ...                  ...
# 79  Cocktails, Canapes & Grand Slam Glory (20 Jan ...            Melbourne
# 80         Member Mixer: Game, Set, Sip (19 Jan 2025)   Melbourne VIC 3000
# 81  Digital-Detox: A Country Retreat in Tuscany (0...       Tuscany, Italy
# 82  Sacred Summit: Mount Agung Trekking Adventure ...                 Bali
# 83  Alpine Wellness Adventure
# in Bavaria’s Heartl...  Schliersee, Germany
#
#                                    event_email_banner event_email_banner_id
# 0   https://storage.karmagroup.com/assets/karmagro...                 86860
# 1
# 2   https://storage.karmagroup.com/assets/karmagro...                 85858
# 3   https://storage.karmagroup.com/assets/karmagro...                 85920
# 4   https://storage.karmagroup.com/assets/karmagro...                 85856
# ..                                                ...                   ...
# 79
# 80
# 81  https://storage.karmagroup.com/assets/karmagro...                 85821
# 82  https://storage.karmagroup.com/assets/karmagro...                 85868
# 83  https://storage.karmagroup.com/assets/karmagro...                 85835
#
# [84 rows x 6 columns]

# %%
# Perform a left join between df_sheets and df on the 'event' column
df_join = pd.merge(df_sheets, df_json, how='left', on='event')

# Select specific columns and filter rows where 'name_y' is null (event doesn't exist in df_json, but exist in df_sheets)
df_not_exists = df_join.loc[
    df_join['name_y'].isnull(),  # Filter condition
    ['name_x', 'dates_x', 'event', 'destination_x', 'event_email_banner_x', 'event_email_banner_id_x']  # Selected columns
].copy()

# Rename columns by removing the '_x' suffix
df_not_exists = df_not_exists.rename(columns={
    'name_x': 'name',
    'dates_x': 'dates',
    'destination_x': 'destination',
    'event_email_banner_x': 'event_email_banner',
    'event_email_banner_id_x': 'event_email_banner_id'
})

# Display the resulting DataFrame
print(df_not_exists)

# Optionally, convert the filtered DataFrame to a list of lists
not_exists_list = df_not_exists.values.tolist()
print(not_exists_list)
# Out:
#                                                  name                  dates  \
# 6    Wild Wings & Fine Fizz in the Scottish Highlands  22 Sep to 24 Sep 2025
# 64                           Bunbury Cup WA Weekender  07 Mar to 09 Mar 2025
# 65                                 Perth Member Mixer            06 Mar 2025
# 66                              Trullo, Madly, Deeply            28 Feb 2025
# 67              Shuck & Sip: Sydney Oyster Experience            22 Feb 2025
# 68                              The Nile’s VIP Voyage  13 Feb to 20 Feb 2025
# 69    Alpine Adventures & Legends of the Wolpertinger  11 Feb to 14 Feb 2025
# 70  Strawberry Fields & Culinary Classics in Mahar...  09 Feb to 11 Feb 2025
# 71              All Aboard: Australia Sail Grand Prix            08 Feb 2025
# 72                       Karma x CUB Networking Lunch            09 May 2025
# 73       Himalayan Skiing & Winter Carnival Adventure  04 Feb to 08 Feb 2025
# 74                               James Bond’s Udaipur  03 Feb to 06 Feb 2025
# 75         White Heat: A Culinary Masterpiece Evening            31 Jan 2025
# 76                            Karma Long Lunch: Perth            27 Jan 2025
# 77                Experience VIP Rugby Sevens Heaven!            26 Jan 2025
# 78             Beginners’ Ski & Feast with Chef Dario  21 Jan to 24 Jan 2025
# 79              Cocktails, Canapes & Grand Slam Glory            20 Jan 2025
# 80                       Member Mixer: Game, Set, Sip            19 Jan 2025
# 81        Digital-Detox: A Country Retreat in Tuscany  02 May to 05 May 2025
# 82      Sacred Summit: Mount Agung Trekking Adventure  06 Apr to 09 Apr 2025
# 83  Alpine Wellness Adventure in Bavaria’s Heartl...  30 Mar to 02 Apr 2025
#
#                                                 event  \
# 6   Wild Wings & Fine Fizz in the Scottish Highlan...
# 64   Bunbury Cup WA Weekender (07 Mar to 09 Mar 2025)
# 65                   Perth Member Mixer (06 Mar 2025)
# 66                Trullo, Madly, Deeply (28 Feb 2025)
# 67  Shuck & Sip: Sydney Oyster Experience (22 Feb ...
# 68      The Nile’s VIP Voyage (13 Feb to 20 Feb 2025)
# 69  Alpine Adventures & Legends of the Wolpertinge...
# 70  Strawberry Fields & Culinary Classics in Mahar...
# 71  All Aboard: Australia Sail Grand Prix (08 Feb ...
# 72         Karma x CUB Networking Lunch (09 May 2025)
# 73  Himalayan Skiing & Winter Carnival Adventure (...
# 74       James Bond’s Udaipur (03 Feb to 06 Feb 2025)
# 75  White Heat: A Culinary Masterpiece Evening (31...
# 76              Karma Long Lunch: Perth (27 Jan 2025)
# 77  Experience VIP Rugby Sevens Heaven! (26 Jan 2025)
# 78  Beginners’ Ski & Feast with Chef Dario (21 Jan...
# 79  Cocktails, Canapes & Grand Slam Glory (20 Jan ...
# 80         Member Mixer: Game, Set, Sip (19 Jan 2025)
# 81  Digital-Detox: A Country Retreat in Tuscany (0...
# 82  Sacred Summit: Mount Agung Trekking Adventure ...
# 83  Alpine Wellness Adventure in Bavaria’s Heartl...
#
#                            destination  \
# 6                   Stirling, Scotland
# 64                        Bunbury, WA
# 65                           Australia
# 66                     Bali, Indonesia
# 67                Hawkesbury River NSW
# 68                        Luxor, Egypt
# 69                 Schliersee, Germany
# 70                Mahabaleshwar, India
# 71                     Sydney Harbour
# 72                   Sydney, Australia
# 73                       Manali, India
# 74                    Rajasthan, India
# 75        Warwickshire, United Kingdom
# 76  H&C Urban Winery, Fremantle, Perth
# 77                     HBF Park, Perth
# 78                 Schliersee, Germany
# 79                           Melbourne
# 80                  Melbourne VIC 3000
# 81                      Tuscany, Italy
# 82                                Bali
# 83                 Schliersee, Germany
#
#                                    event_email_banner event_email_banner_id
# 6   https://storage.karmagroup.com/assets/karmagro...                 85811
# 64
# 65
# 66  https://storage.karmagroup.com/assets/karmagro...                 85866
# 67
# 68
# 69
# 70
# 71
# 72
# 73
# 74
# 75
# 76
# 77
# 78
# 79
# 80
# 81  https://storage.karmagroup.com/assets/karmagro...                 85821
# 82  https://storage.karmagroup.com/assets/karmagro...                 85868
# 83  https://storage.karmagroup.com/assets/karmagro...                 85835
# [['Wild Wings & Fine Fizz in the Scottish Highlands', '22 Sep to 24 Sep 2025', 'Wild Wings & Fine Fizz in the Scottish Highlands (22 Sep to 24 Sep 2025)', ' Stirling, Scotland', 'https://storage.karmagroup.com/assets/karmagroup.com/2024/12/186-Wild-Wings.jpg', 85811], ['Bunbury Cup WA Weekender', '07 Mar to 09 Mar 2025', 'Bunbury Cup WA Weekender (07 Mar to 09 Mar 2025)', 'Bunbury, WA ', '', ''], ['Perth Member Mixer', '06 Mar 2025', 'Perth Member Mixer (06 Mar 2025)', 'Australia', '', ''], ['Trullo, Madly, Deeply', '28 Feb 2025', 'Trullo, Madly, Deeply (28 Feb 2025)', 'Bali, Indonesia', 'https://storage.karmagroup.com/assets/karmagroup.com/2025/01/3-Trullo.jpg', 85866], ['Shuck & Sip: Sydney Oyster Experience', '22 Feb 2025', 'Shuck & Sip: Sydney Oyster Experience (22 Feb 2025)', 'Hawkesbury River NSW', '', ''], ['The Nile’s VIP Voyage', '13 Feb to 20 Feb 2025', 'The Nile’s VIP Voyage (13 Feb to 20 Feb 2025)', 'Luxor, Egypt', '', ''], ['Alpine Adventures & Legends of the Wolpertinger', '11 Feb to 14 Feb 2025', 'Alpine Adventures & Legends of the Wolpertinger (11 Feb to 14 Feb 2025)', 'Schliersee, Germany', '', ''], ['Strawberry Fields & Culinary Classics in Maharashtra', '09 Feb to 11 Feb 2025', 'Strawberry Fields & Culinary Classics in Maharashtra (09 Feb to 11 Feb 2025)', 'Mahabaleshwar, India', '', ''], ['All Aboard: Australia Sail Grand Prix', '08 Feb 2025', 'All Aboard: Australia Sail Grand Prix (08 Feb 2025)', 'Sydney Harbour ', '', ''], ['Karma x CUB Networking Lunch', '09 May 2025', 'Karma x CUB Networking Lunch (09 May 2025)', 'Sydney, Australia', '', ''], ['Himalayan Skiing & Winter Carnival Adventure', '04 Feb to 08 Feb 2025', 'Himalayan Skiing & Winter Carnival Adventure (04 Feb to 08 Feb 2025)', ' Manali, India', '', ''], ['James Bond’s Udaipur', '03 Feb to 06 Feb 2025', 'James Bond’s Udaipur (03 Feb to 06 Feb 2025)', 'Rajasthan, India', '', ''], ['White Heat: A Culinary Masterpiece Evening', '31 Jan 2025', 'White Heat: A Culinary Masterpiece Evening (31 Jan 2025)', 'Warwickshire, United Kingdom', '', ''], ['Karma Long Lunch: Perth', '27 Jan 2025', 'Karma Long Lunch: Perth (27 Jan 2025)', 'H&C Urban Winery, Fremantle, Perth', '', ''], ['Experience VIP Rugby Sevens Heaven!', '26 Jan 2025', 'Experience VIP Rugby Sevens Heaven! (26 Jan 2025)', 'HBF Park, Perth', '', ''], ['Beginners’ Ski & Feast with Chef Dario', '21 Jan to 24 Jan 2025', 'Beginners’ Ski & Feast with Chef Dario (21 Jan to 24 Jan 2025)', 'Schliersee, Germany', '', ''], ['Cocktails, Canapes & Grand Slam Glory', '20 Jan 2025', 'Cocktails, Canapes & Grand Slam Glory (20 Jan 2025)', 'Melbourne', '', ''], ['Member Mixer: Game, Set, Sip', '19 Jan 2025', 'Member Mixer: Game, Set, Sip (19 Jan 2025)', 'Melbourne VIC 3000', '', ''], ['Digital-Detox: A Country Retreat in Tuscany', '02 May to 05 May 2025', 'Digital-Detox: A Country Retreat in Tuscany (02 May to 05 May 2025)', 'Tuscany, Italy', 'https://storage.karmagroup.com/assets/karmagroup.com/2024/11/161-3-Day-Detox.jpg', 85821], ['Sacred Summit: Mount Agung Trekking Adventure', '06 Apr to 09 Apr 2025', 'Sacred Summit: Mount Agung Trekking Adventure (06 Apr to 09 Apr 2025)', 'Bali', 'https://storage.karmagroup.com/assets/karmagroup.com/2024/11/149-AttackSummit.jpg', 85868], ['Alpine Wellness Adventure \u2028in Bavaria’s Heartlands', '30 Mar to 02 Apr 2025', 'Alpine Wellness Adventure \u2028in Bavaria’s Heartlands (30 Mar to 02 Apr 2025)', 'Schliersee, Germany', 'https://storage.karmagroup.com/assets/karmagroup.com/2024/12/159-Alpine-Wellness.jpg', 85835]]

# %%
df_new = pd.concat([df_json, df_not_exists], ignore_index=True)
df_new
# Out:
#                                                  name                  dates  \
# 0                           Summer Long Lunch: SYDNEY            09 Nov 2025
# 1                       Titans of Rugby at Twickenham            08 Nov 2025
# 2                            Polo in the City: SYDNEY            08 Nov 2025
# 3         Flavoursome Fungi & Medici Magic in Tuscany  07 Nov to 09 Nov 2025
# 4                        Eco Luxury: Broome Weekender  31 Oct to 02 Nov 2025
# ..                                                ...                    ...
# 91              Cocktails, Canapes & Grand Slam Glory            20 Jan 2025
# 92                       Member Mixer: Game, Set, Sip            19 Jan 2025
# 93        Digital-Detox: A Country Retreat in Tuscany  02 May to 05 May 2025
# 94      Sacred Summit: Mount Agung Trekking Adventure  06 Apr to 09 Apr 2025
# 95  Alpine Wellness Adventure
# in Bavaria’s Heartl...  30 Mar to 02 Apr 2025
#
#                                                 event  \
# 0             Summer Long Lunch: SYDNEY (09 Nov 2025)
# 1         Titans of Rugby at Twickenham (08 Nov 2025)
# 2              Polo in the City: SYDNEY (08 Nov 2025)
# 3   Flavoursome Fungi & Medici Magic in Tuscany (0...
# 4   Eco Luxury: Broome Weekender (31 Oct to 02 Nov...
# ..                                                ...
# 91  Cocktails, Canapes & Grand Slam Glory (20 Jan ...
# 92         Member Mixer: Game, Set, Sip (19 Jan 2025)
# 93  Digital-Detox: A Country Retreat in Tuscany (0...
# 94  Sacred Summit: Mount Agung Trekking Adventure ...
# 95  Alpine Wellness Adventure
# in Bavaria’s Heartl...
#
#                      destination  \
# 0              Sydney, Australia
# 1     Twickenham, United Kingdom
# 2              Sydney, Australia
# 3                 Tuscany, Italy
# 4   Western Australia, Australia
# ..                           ...
# 91                     Melbourne
# 92            Melbourne VIC 3000
# 93                Tuscany, Italy
# 94                          Bali
# 95           Schliersee, Germany
#
#                                    event_email_banner event_email_banner_id
# 0   https://storage.karmagroup.com/assets/karmagro...                 87886
# 1   https://storage.karmagroup.com/assets/karmagro...                 86867
# 2   https://storage.karmagroup.com/assets/karmagro...                 88088
# 3   https://storage.karmagroup.com/assets/karmagro...                 85829
# 4
# ..                                                ...                   ...
# 91
# 92
# 93  https://storage.karmagroup.com/assets/karmagro...                 85821
# 94  https://storage.karmagroup.com/assets/karmagro...                 85868
# 95  https://storage.karmagroup.com/assets/karmagro...                 85835
#
# [96 rows x 6 columns]

# %%
# Update keseluruhan data, delete data yang lama terlebih dahulu
# clear all row before update
worksheet.clear()
worksheet.update([df_new.columns.values.tolist()] + df_new.values.tolist())
# Out:
# {'spreadsheetId': '1k-70BJNRm01RE2S7gBXuOfqxofk1gYz4g6lPbLUCklw',
#  'updatedRange': "'Event List'!A1:F97",
#  'updatedRows': 97,
#  'updatedColumns': 6,
#  'updatedCells': 582}
