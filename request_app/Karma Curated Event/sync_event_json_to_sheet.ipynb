# %%
import requests
import pandas as pd

import gspread
import pandas as pd
from fractions import Fraction
import re

# Pastikan permision access di menu "Share" di rubah ke anyone with the link terlebih dahulu, agar bisa mengunakan cara OAuth
# Jika Ingin lebih dibatasi menggunakan cara google service account lebih disarankan

gc = gspread.oauth(
    credentials_filename= r'..\..\Data\Google Credentials\karma-oauth.json'
)

SHEET_ID = '1k-70BJNRm01RE2S7gBXuOfqxofk1gYz4g6lPbLUCklw'
SHEET_NAME = 'Event List'
# SHEET_NAME = 'DB Test'


# Step 1: Fetch the JSON data from the URL
url = "https://karmagroup.com/karma-curated-list-json/"
response = requests.get(url)

# Check if the request was successful
if response.status_code == 200:
    data = response.json()  # Parse the JSON data

    # Step 2: Convert JSON data into a DataFrame
    df_json = pd.DataFrame(data)

    # Step 3: Display the DataFrame
    print("DataFrame created successfully:")

    print("DataFrame saved to 'karma_events.csv'")

else:
    print(f"Failed to fetch data. Status code: {response.status_code}")

df_json
# Out:
# DataFrame created successfully:
# DataFrame saved to 'karma_events.csv'
#                                            name                  dates  \
# 0   Immersive Kalaripayattu Cultural Experience  08 Sep to 11 Sep 2025
# 1      Karma Attends: Cirque du Soleil’s Corteo            04 Sep 2025
# 2                   Sail, Saddle & Savour Crete  01 Sep to 04 Sep 2025
# 3     Celebrate Ganesha’s Divine Journey in Goa  26 Aug to 29 Aug 2025
# 4              Watersports & Wellness Weekender  23 Aug to 25 Aug 2025
# ..                                          ...                    ...
# 67                      Karma Long Lunch: Perth            27 Jan 2025
# 68          Experience VIP Rugby Sevens Heaven!            26 Jan 2025
# 69       Beginners’ Ski & Feast with Chef Dario  21 Jan to 24 Jan 2025
# 70        Cocktails, Canapes & Grand Slam Glory            20 Jan 2025
# 71                 Member Mixer: Game, Set, Sip            19 Jan 2025
#
#                                                 event  \
# 0   Immersive Kalaripayattu Cultural Experience (0...
# 1   Karma Attends: Cirque du Soleil’s Corteo (04 S...
# 2   Sail, Saddle & Savour Crete (01 Sep to 04 Sep ...
# 3   Celebrate Ganesha’s Divine Journey in Goa (26 ...
# 4   Watersports & Wellness Weekender (23 Aug to 25...
# ..                                                ...
# 67              Karma Long Lunch: Perth (27 Jan 2025)
# 68  Experience VIP Rugby Sevens Heaven! (26 Jan 2025)
# 69  Beginners’ Ski & Feast with Chef Dario (21 Jan...
# 70  Cocktails, Canapes & Grand Slam Glory (20 Jan ...
# 71         Member Mixer: Game, Set, Sip (19 Jan 2025)
#
#                            destination  \
# 0            Munnar, Idukki Dt. Kerala
# 1                    Sydney, Australia
# 2                               Greece
# 3                                India
# 4                        Ungasan, Bali
# ..                                 ...
# 67  H&C Urban Winery, Fremantle, Perth
# 68                     HBF Park, Perth
# 69                 Schliersee, Germany
# 70                           Melbourne
# 71                  Melbourne VIC 3000
#
#                                    event_email_banner event_email_banner_id
# 0   https://storage.karmagroup.com/assets/karmagro...                 85852
# 1   https://storage.karmagroup.com/assets/karmagro...                 86452
# 2   https://storage.karmagroup.com/assets/karmagro...                 85918
# 3   https://storage.karmagroup.com/assets/karmagro...                 85850
# 4   https://storage.karmagroup.com/assets/karmagro...                 85892
# ..                                                ...                   ...
# 67
# 68
# 69
# 70
# 71
#
# [72 rows x 6 columns]

# %%
# get data gsheet

spreadsheet = gc.open_by_key(SHEET_ID)
worksheet = spreadsheet.worksheet(SHEET_NAME)
rows = worksheet.get_all_records()

# print(rows[:5])

# print('==============================')
# df = pd.DataFrame(rows, dtype="string")
df_sheets = pd.DataFrame(rows)
# df['Mobile Number'] = df['Mobile Number'].apply(Fraction)
df_sheets
# Out:
#                                                  name                  dates  \
# 0         Immersive Kalaripayattu Cultural Experience  08 Sep to 11 Sep 2025
# 1            Karma Attends: Cirque du Soleil’s Corteo            04 Sep 2025
# 2                         Sail, Saddle & Savour Crete  01 Sep to 04 Sep 2025
# 3           Celebrate Ganesha’s Divine Journey in Goa  26 Aug to 29 Aug 2025
# 4                    Watersports & Wellness Weekender  23 Aug to 25 Aug 2025
# 5      Culinary Adventures & Cultural Wonders in Bali  10 Aug to 13 Aug 2025
# 6             Journey into the Heart of Co Tu Culture  06 Aug to 08 Aug 2025
# 7             Wild Birds, Wilderness & Warming Whisky  03 Aug to 06 Aug 2025
# 8   Arabian Nights: Gourmet Starlit Magic Carpet Ride  17 Jul to 19 Jul 2025
# 9                     A VIP Rugby Spectacle in Sydney            05 Jul 2025
# 10                           Karma Summer Social 2025            05 Jul 2025
# 11     Lords of the Game: A Luxury Cricket Experience  03 Jul to 05 Jul 2025
# 12          Alpine Adventures: Bavarian Nature Escape  29 Jun to 02 Jul 2025
# 13       Witness The Legendary & Grand Lions In Perth            28 Jun 2025
# 14   Crete: Myths, Mountains & Mediterranean Flavours  26 Jun to 29 Jun 2025
# 15                   World Class Tennis at Eastbourne            26 Jun 2025
# 16               Padel, Pampering & Putts in Paradise  25 Jun to 28 Jun 2025
# 17            Bannockburn & Scotland’s Storied Legacy  23 Jun to 25 Jun 2025
# 18  Vietnam’s Tropical Treasures: Coastlines & Cor...  21 Jun to 23 Jun 2025
# 19                      Margaret River Winery Weekend  20 Jun to 22 Jun 2025
# 20                        La Vie Provençal a la Karma  19 Jun to 22 Jun 2025
# 21                     Saints & Sinners
# in Andalusia  16 Jun to 20 Jun 2025
# 22     Balloon Rides, River Cruising & Medici Secrets  13 Jun to 15 Jun 2025
# 23           Soul of Bali: Temples, Blessings & Bliss  13 Jun to 16 Jun 2025
# 24        Bali’s Wild Side: Lakes, Lava & Hot Springs  10 Jun to 13 Jun 2025
# 25                    Riverside Tea Affair: Melbourne            08 Jun 2025
# 26         MCG Magic: Richmond Tigers vs Sydney Swans            07 Jun 2025
# 27        Uncovering Andalusia with Karma Wine Safari  06 Jun to 09 Jun 2025
# 28                         Karma Long Lunch: Brisbane            30 May 2025
# 29            Experience Elite AFL Access in Brisbane            29 May 2025
# 30             Cretan Bliss: Yoga, Wine & Vitamin Sea  27 May to 30 May 2025
# 31               Ancient Trails & Ocean Tales of Bali  25 May to 28 May 2025
# 32                         Karma Long Lunch:
# Adelaide            17 May 2025
# 33                Art Of The Eight Limbs
# Supper Club  16 May to 18 May 2025
# 34     Quips, One Liners & Laughs Galore with Jimeoin            16 May 2025
# 35                      Wheels, Wine & Tuscan Wonders  16 May to 18 May 2025
# 36                       Karma x CUB Networking Lunch            09 May 2025
# 37        Fawlty Towers: A Comical Dining Experience!            08 May 2025
# 38      Ancient Traditions & Flavours of Eastern Bali  06 May to 09 May 2025
# 39     Where Tibet Meets India: A Himalayan Adventure  05 May to 09 May 2025
# 40        Digital-Detox: A Country Retreat in Tuscany  02 May to 05 May 2025
# 41                      Phillip Island Penguin Parade  02 May to 04 May 2025
# 42      Member Mixer: Rooftop Rendezvous in Melbourne            01 May 2025
#
#                                    event_email_banner event_email_banner_id
# 0   https://storage.karmagroup.com/assets/karmagro...                 85852
# 1   https://storage.karmagroup.com/assets/karmagro...                 86452
# 2   https://storage.karmagroup.com/assets/karmagro...                 85918
# 3   https://storage.karmagroup.com/assets/karmagro...                 85850
# 4   https://storage.karmagroup.com/assets/karmagro...                 85892
# 5   https://storage.karmagroup.com/assets/karmagro...                 85887
# 6   https://storage.karmagroup.com/assets/karmagro...                 85905
# 7   https://storage.karmagroup.com/assets/karmagro...                 85809
# 8   https://storage.karmagroup.com/assets/karmagro...                 85885
# 9
# 10  https://storage.karmagroup.com/assets/karmagro...                 85807
# 11  https://storage.karmagroup.com/assets/karmagro...                 85805
# 12  https://storage.karmagroup.com/assets/karmagro...                 85838
# 13
# 14  https://storage.karmagroup.com/assets/karmagro...                 85915
# 15  https://storage.karmagroup.com/assets/karmagro...                 85803
# 16  https://storage.karmagroup.com/assets/karmagro...                 85883
# 17  https://storage.karmagroup.com/assets/karmagro...                 85797
# 18  https://storage.karmagroup.com/assets/karmagro...                 85903
# 19
# 20  https://storage.karmagroup.com/assets/karmagro...                 86387
# 21  https://storage.karmagroup.com/assets/karmagro...                 85911
# 22  https://storage.karmagroup.com/assets/karmagro...                 85825
# 23  https://storage.karmagroup.com/assets/karmagro...                 85881
# 24  https://storage.karmagroup.com/assets/karmagro...                 85879
# 25  https://storage.karmagroup.com/assets/karmagro...                 86407
# 26
# 27  https://storage.karmagroup.com/assets/karmagro...                 85909
# 28  https://storage.karmagroup.com/assets/karmagro...                 86421
# 29
# 30  https://storage.karmagroup.com/assets/karmagro...                 85913
# 31  https://storage.karmagroup.com/assets/karmagro...                 85877
# 32
# 33  https://storage.karmagroup.com/assets/karmagro...                 85875
# 34
# 35  https://storage.karmagroup.com/assets/karmagro...                 85823
# 36
# 37
# 38  https://storage.karmagroup.com/assets/karmagro...                 85873
# 39  https://storage.karmagroup.com/assets/karmagro...                 85848
# 40  https://storage.karmagroup.com/assets/karmagro...                 85821
# 41
# 42
# 43  https://storage.karmagroup.com/assets/karmagro...                 85870
# 44  https://storage.karmagroup.com/assets/karmagro...                 85815
# 45  https://storage.karmagroup.com/assets/karmagro...                 85819
# 46  https://storage.karmagroup.com/assets/karmagro...                 85898
# 47  https://storage.karmagroup.com/assets/karmagro...                 85846
# 48  https://storage.karmagroup.com/assets/karmagro...                 85868
# 49
# 50
# 51  https://storage.karmagroup.com/assets/karmagro...                 85835
# 52
# 53  https://storage.karmagroup.com/assets/karmagro...                 85844
# 54  https://storage.karmagroup.com/assets/karmagro...                 85842
# 55  https://storage.karmagroup.com/assets/karmagro...                 85795
# 56
# 57
# 58  https://storage.karmagroup.com/assets/karmagro...                 85866

# %%
# Perform a left join between df_sheets and df on the 'event' column
df_join = pd.merge(df_sheets, df_json, how='left', on='event')

# Select specific columns and filter rows where 'name_y' is null (event doesn't exist in df_json, but exist in df_sheets)
df_not_exists = df_join.loc[
    df_join['name_y'].isnull(),  # Filter condition
    ['name_x', 'dates_x', 'event', 'destination_x', 'event_email_banner_x', 'event_email_banner_id_x']  # Selected columns
].copy()

# Rename columns by removing the '_x' suffix
df_not_exists = df_not_exists.rename(columns={
    'name_x': 'name',
    'dates_x': 'dates',
    'destination_x': 'destination',
    'event_email_banner_x': 'event_email_banner',
    'event_email_banner_id_x': 'event_email_banner_id'
})

# Display the resulting DataFrame
print(df_not_exists)

# Optionally, convert the filtered DataFrame to a list of lists
not_exists_list = df_not_exists.values.tolist()
print(not_exists_list)
# Out:
# Empty DataFrame
# Columns: [name, dates, event, destination, event_email_banner, event_email_banner_id]
# Index: []
# []

# %%
df_new = pd.concat([df_json, df_not_exists], ignore_index=True)
df_new
# Out:
#                                            name                  dates  \
# 0   Immersive Kalaripayattu Cultural Experience  08 Sep to 11 Sep 2025
# 1      Karma Attends: Cirque du Soleil’s Corteo            04 Sep 2025
# 2                   Sail, Saddle & Savour Crete  01 Sep to 04 Sep 2025
# 3     Celebrate Ganesha’s Divine Journey in Goa  26 Aug to 29 Aug 2025
# 4              Watersports & Wellness Weekender  23 Aug to 25 Aug 2025
# ..                                          ...                    ...
# 67                      Karma Long Lunch: Perth            27 Jan 2025
# 68          Experience VIP Rugby Sevens Heaven!            26 Jan 2025
# 69       Beginners’ Ski & Feast with Chef Dario  21 Jan to 24 Jan 2025
# 70        Cocktails, Canapes & Grand Slam Glory            20 Jan 2025
# 71                 Member Mixer: Game, Set, Sip            19 Jan 2025
#
#                                                 event  \
# 0   Immersive Kalaripayattu Cultural Experience (0...
# 1   Karma Attends: Cirque du Soleil’s Corteo (04 S...
# 2   Sail, Saddle & Savour Crete (01 Sep to 04 Sep ...
# 3   Celebrate Ganesha’s Divine Journey in Goa (26 ...
# 4   Watersports & Wellness Weekender (23 Aug to 25...
# ..                                                ...
# 67              Karma Long Lunch: Perth (27 Jan 2025)
# 68  Experience VIP Rugby Sevens Heaven! (26 Jan 2025)
# 69  Beginners’ Ski & Feast with Chef Dario (21 Jan...
# 70  Cocktails, Canapes & Grand Slam Glory (20 Jan ...
# 71         Member Mixer: Game, Set, Sip (19 Jan 2025)
#
#                            destination  \
# 0            Munnar, Idukki Dt. Kerala
# 1                    Sydney, Australia
# 2                               Greece
# 3                                India
# 4                        Ungasan, Bali
# ..                                 ...
# 67  H&C Urban Winery, Fremantle, Perth
# 68                     HBF Park, Perth
# 69                 Schliersee, Germany
# 70                           Melbourne
# 71                  Melbourne VIC 3000
#
#                                    event_email_banner event_email_banner_id
# 0   https://storage.karmagroup.com/assets/karmagro...                 85852
# 1   https://storage.karmagroup.com/assets/karmagro...                 86452
# 2   https://storage.karmagroup.com/assets/karmagro...                 85918
# 3   https://storage.karmagroup.com/assets/karmagro...                 85850
# 4   https://storage.karmagroup.com/assets/karmagro...                 85892
# ..                                                ...                   ...
# 67
# 68
# 69
# 70
# 71
#
# [72 rows x 6 columns]

# %%
# Update keseluruhan data, delete data yang lama terlebih dahulu
# clear all row before update
worksheet.clear()
worksheet.update([df_new.columns.values.tolist()] + df_new.values.tolist())
# Out:
# {'spreadsheetId': '1k-70BJNRm01RE2S7gBXuOfqxofk1gYz4g6lPbLUCklw',
#  'updatedRange': "'Event List'!A1:F73",
#  'updatedRows': 73,
#  'updatedColumns': 6,
#  'updatedCells': 438}
