# %%
import requests
import pandas as pd

import gspread
import pandas as pd
from fractions import Fraction
import re

# Pastikan permision access di menu "Share" di rubah ke anyone with the link terlebih dahulu, agar bisa mengunakan cara OAuth
# Jika Ingin lebih dibatasi menggunakan cara google service account lebih disarankan

gc = gspread.oauth(
    credentials_filename= r'..\..\Data\Google Credentials\karma-oauth.json'
)

SHEET_ID = '1k-70BJNRm01RE2S7gBXuOfqxofk1gYz4g6lPbLUCklw'
SHEET_NAME = 'Event List'
# SHEET_NAME = 'DB Test'


# Step 1: Fetch the JSON data from the URL
url = "https://karmagroup.com/karma-curated-list-json/"
response = requests.get(url)

# Check if the request was successful
if response.status_code == 200:
    data = response.json()  # Parse the JSON data

    # Step 2: Convert JSON data into a DataFrame
    df_json = pd.DataFrame(data)

    # Step 3: Display the DataFrame
    print("DataFrame created successfully:")

    print("DataFrame saved to 'karma_events.csv'")

else:
    print(f"Failed to fetch data. Status code: {response.status_code}")

df_json
# Out:
# DataFrame created successfully:
# DataFrame saved to 'karma_events.csv'
#                                                  name                  dates  \
# 0                 Giants & Knights, Dreams & Dungeons  24 Jan to 26 Jan 2026
# 1                          Australian Open, VIP-Style            20 Jan 2026
# 2             The Orange Fest at Karma Martam Retreat  19 Jan to 22 Jan 2026
# 3            Alpine Tobogganing & Snow Polo Adventure  15 Jan to 18 Jan 2026
# 4               Canvas & Coast: Goa with Rajesh Chari  05 Jan to 08 Jan 2026
# ..                                                ...                    ...
# 80                The Karma White Lotus Experience #2  09 Jun to 11 Jun 2025
# 81                    Riverside Tea Affair: Melbourne            08 Jun 2025
# 82         MCG Magic: Richmond Tigers vs Sydney Swans            07 Jun 2025
# 83        Uncovering Andalusia with Karma Wine Safari  06 Jun to 09 Jun 2025
# 84  Pete Tong’s Ibiza Classics at the Royal Albert...            01 Jun 2025
#
#                                                 event  \
# 0   Giants & Knights, Dreams & Dungeons (24 Jan to...
# 1            Australian Open, VIP-Style (20 Jan 2026)
# 2   The Orange Fest at Karma Martam Retreat (19 Ja...
# 3   Alpine Tobogganing & Snow Polo Adventure (15 J...
# 4   Canvas & Coast: Goa with Rajesh Chari (05 Jan ...
# ..                                                ...
# 80  The Karma White Lotus Experience #2 (09 Jun to...
# 81      Riverside Tea Affair: Melbourne (08 Jun 2025)
# 82  MCG Magic: Richmond Tigers vs Sydney Swans (07...
# 83  Uncovering Andalusia with Karma Wine Safari (0...
# 84  Pete Tong’s Ibiza Classics at the Royal Albert...
#
#                                           destination  \
# 0                        Warwickshire, United Kingdom
# 1                                Melbourne, Australia
# 2   Karma Martam Retreat, P.O. Gangkha, Via Singta...
# 3                                 Schliersee, Germany
# 4                                               India
# ..                                                ...
# 80                                Koh Samui, Thailand
# 81                               Melbourne, Australia
# 82                                Victoria, Australia
# 83                                              Spain
# 84                             London, United Kingdom
#
#                                    event_email_banner event_email_banner_id
# 0
# 1   https://storage.karmagroup.com/assets/karmagro...                 87678
# 2
# 3
# 4
# ..                                                ...                   ...
# 80  https://storage.karmagroup.com/assets/karmagro...                 87432
# 81  https://storage.karmagroup.com/assets/karmagro...                 86407
# 82
# 83  https://storage.karmagroup.com/assets/karmagro...                 85909
# 84  https://storage.karmagroup.com/assets/karmagro...                 88254
#
# [85 rows x 6 columns]

# %%
# get data gsheet

spreadsheet = gc.open_by_key(SHEET_ID)
worksheet = spreadsheet.worksheet(SHEET_NAME)
rows = worksheet.get_all_records()

# print(rows[:5])

# print('==============================')
# df = pd.DataFrame(rows, dtype="string")
df_sheets = pd.DataFrame(rows)
# df['Mobile Number'] = df['Mobile Number'].apply(Fraction)
df_sheets
# Out:
#                                                   name                  dates  \
# 0                           Polo in the City: Adelaide            19 Dec 2025
# 1                              Polo in the City: PERTH            13 Dec 2025
# 2    Bohemian Rhapsody: Freddie’s Hometown Musical ...  08 Dec to 11 Dec 2025
# 3                           Christmas in the Cotswolds  05 Dec to 08 Dec 2025
# 4                Secrets Of The Tuscan Truffle Hunters  05 Dec to 07 Dec 2025
# ..                                                 ...                    ...
# 119              Cocktails, Canapes & Grand Slam Glory            20 Jan 2025
# 120                       Member Mixer: Game, Set, Sip            19 Jan 2025
# 121        Digital-Detox: A Country Retreat in Tuscany  02 May to 05 May 2025
# 122      Sacred Summit: Mount Agung Trekking Adventure  06 Apr to 09 Apr 2025
# 123  Alpine Wellness Adventure
# in Bavaria’s Heartl...  30 Mar to 02 Apr 2025
#
#                                                  event  \
# 0             Polo in the City: Adelaide (19 Dec 2025)
# 1                Polo in the City: PERTH (13 Dec 2025)
# 2    Bohemian Rhapsody: Freddie’s Hometown Musical ...
# 3    Christmas in the Cotswolds (05 Dec to 08 Dec 2...
# 4    Secrets Of The Tuscan Truffle Hunters (05 Dec ...
# ..                                                 ...
# 119  Cocktails, Canapes & Grand Slam Glory (20 Jan ...
# 120         Member Mixer: Game, Set, Sip (19 Jan 2025)
# 121  Digital-Detox: A Country Retreat in Tuscany (0...
# 122  Sacred Summit: Mount Agung Trekking Adventure ...
# 123  Alpine Wellness Adventure
# in Bavaria’s Heartl...
#
#                       destination  \
# 0             Adelaide, Australia
# 1                Perth, Australia
# 2            Mahabaleshwar, India
# 3    Warwickshire, United Kingdom
# 4                  Tuscany, Italy
# ..                            ...
# 119                     Melbourne
# 120            Melbourne VIC 3000
# 121                Tuscany, Italy
# 122                          Bali
# 123           Schliersee, Germany
#
#                                     event_email_banner event_email_banner_id
# 0    https://storage.karmagroup.com/assets/karmagro...                 87951
# 1    https://storage.karmagroup.com/assets/karmagro...                 88081
# 2    https://storage.karmagroup.com/assets/karmagro...                 85864
# 3    https://storage.karmagroup.com/assets/karmagro...                 85813
# 4    https://storage.karmagroup.com/assets/karmagro...                 85831
# ..                                                 ...                   ...
# 119
# 120
# 121  https://storage.karmagroup.com/assets/karmagro...                 85821
# 122  https://storage.karmagroup.com/assets/karmagro...                 85868
# 123  https://storage.karmagroup.com/assets/karmagro...                 85835
#
# [124 rows x 6 columns]

# %%
# Perform a left join between df_sheets and df on the 'event' column
df_join = pd.merge(df_sheets, df_json, how='left', on='event')

# Select specific columns and filter rows where 'name_y' is null (event doesn't exist in df_json, but exist in df_sheets)
df_not_exists = df_join.loc[
    df_join['name_y'].isnull(),  # Filter condition
    ['name_x', 'dates_x', 'event', 'destination_x', 'event_email_banner_x', 'event_email_banner_id_x']  # Selected columns
].copy()

# Rename columns by removing the '_x' suffix
df_not_exists = df_not_exists.rename(columns={
    'name_x': 'name',
    'dates_x': 'dates',
    'destination_x': 'destination',
    'event_email_banner_x': 'event_email_banner',
    'event_email_banner_id_x': 'event_email_banner_id'
})

# Display the resulting DataFrame
print(df_not_exists)

# Optionally, convert the filtered DataFrame to a list of lists
not_exists_list = df_not_exists.values.tolist()
print(not_exists_list)
# Out:
#                                                   name                  dates  \
# 51   Arabian Nights: Gourmet Starlit Magic Carpet Ride  17 Jul to 19 Jul 2025
Member Mixer: Game, Set, Sip (19 Jan 2025)
# 121  Digital-Detox: A Country Retreat in Tuscany (0...
# 122  Sacred Summit: Mount Agung Trekking Adventure ...
# 123  Alpine Wellness Adventure in Bavaria’s Heartl...
#
#                             destination  \
# 51                        Ungasan, Bali
# 75                  Brisbane, Australia
# 76                Queensland, Australia
# 77                        Crete, Greece
# 78                                 Bali
# 79                  Adelaide, Australia
# 80                        Ungasan, Bali
# 81                  Adelaide, Australia
# 82                       Tuscany, Italy
# 83            Stirling , United Kingdom
# 84                    Sydney, Australia
# 85                      Candidasa, Bali
# 86                       Gangtok, India
# 87                       VIC, Australia
# 88                 Melbourne, Australia
# 89                        Ungasan, Bali
# 90                        Gaucín, Spain
# 91                      Bali, Indonesia
# 92                        Gaucin, Spain
# 93         Warwickshire, United Kingdom
# 94                       Tuscany, Italy
# 95                  Koh Samui, Thailand
# 96                           Goa, India
# 97              Pokolbin NSW, Australia
# 98                    Sydney, Australia
# 99         Western Australia, Australia
# 100                               India
# 101                          Goa, India
# 102                      United Kingdom
# 103                  Stirling, Scotland
# 104                        Bunbury, WA
# 105                           Australia
# 106                     Bali, Indonesia
# 107                Hawkesbury River NSW
# 108                        Luxor, Egypt
# 109                 Schliersee, Germany
# 110                Mahabaleshwar, India
# 111                     Sydney Harbour
# 112                   Sydney, Australia
# 113                       Manali, India
# 114                    Rajasthan, India
# 115        Warwickshire, United Kingdom
# 116  H&C Urban Winery, Fremantle, Perth
# 117                     HBF Park, Perth
# 118                 Schliersee, Germany
# 119                           Melbourne
# 120                  Melbourne VIC 3000
# 121                      Tuscany, Italy
# 122                                Bali
# 123                 Schliersee, Germany
#
#                                     event_email_banner event_email_banner_id
# 51   https://storage.karmagroup.com/assets/karmagro...                 85885
# 75   https://storage.karmagroup.com/assets/karmagro...                 86421
# 76
# 77   https://storage.karmagroup.com/assets/karmagro...                 85913
# 78   https://storage.karmagroup.com/assets/karmagro...                 85877
# 79
# 80   https://storage.karmagroup.com/assets/karmagro...                 85875
# 81
# 82   https://storage.karmagroup.com/assets/karmagro...                 85823
# 83   https://storage.karmagroup.com/assets/karmagro...                 88102
# 84
# 85   https://storage.karmagroup.com/assets/karmagro...                 85873
# 86   https://storage.karmagroup.com/assets/karmagro...                 85848
# 87
# 88
# 89   https://storage.karmagroup.com/assets/karmagro...                 85892
# 90   https://storage.karmagroup.com/assets/karmagro...                 85911
# 91   https://storage.karmagroup.com/assets/karmagro...                 85870
# 92   https://storage.karmagroup.com/assets/karmagro...                 87324
# 93   https://storage.karmagroup.com/assets/karmagro...                 85815
# 94   https://storage.karmagroup.com/assets/karmagro...                 85819
# 95   https://storage.karmagroup.com/assets/karmagro...                 85898
# 96   https://storage.karmagroup.com/assets/karmagro...                 85846
# 97
# 98
# 99
# 100  https://storage.karmagroup.com/assets/karmagro...                 85844
# 101  https://storage.karmagroup.com/assets/karmagro...                 85842
# 102  https://storage.karmagroup.com/assets/karmagro...                 85795
# 103  https://storage.karmagroup.com/assets/karmagro...                 85811
# 104
# 105
# 106  https://storage.karmagroup.com/assets/karmagro...                 85866
# 107
# 108
# 109
# 110
# 111
# 112
# 113
# 114
# 115
# 116
# 117
# 118
# 119
# 120
# 121  https://storage.karmagroup.com/assets/karmagro...                 85821
# 122  https://storage.karmagroup.com/assets/karmagro...                 85868
# 123  https://storage.karmagroup.com/assets/karmagro...                 85835
# [['Arabian Nights: Gourmet Starlit Magic Carpet Ride', '17 Jul to 19 Jul 2025', 'Arabian Nights: Gourmet Starlit Magic Carpet Ride (17 Jul to 19 Jul 2025)', 'Ungasan, Bali', 'https://storage.karmagroup.com/assets/karmagroup.com/2024/12/178-Magic-Carpet-Dinner.jpg', 85885], ['Karma Long Lunch: Brisbane', '30 May 2025', 'Karma Long Lunch: Brisbane (30 May 2025)', 'Brisbane, Australia', 'https://storage.karmagroup.com/assets/karmagroup.com/2025/03/Post_event_232.jpg', 86421], ['Experience Elite AFL Access in Brisbane', '29 May 2025', 'Experience Elite AFL Access in Brisbane (29 May 2025)', 'Queensland, Australia', '', ''], ['Cretan Bliss: Yoga, Wine & Vitamin Sea', '27 May to 30 May 2025', 'Cretan Bliss: Yoga, Wine & Vitamin Sea (27 May to 30 May 2025)', 'Crete, Greece', 'https://storage.karmagroup.com/assets/karmagroup.com/2024/12/205-Cretan-Bliss.jpg', 85913], ['Ancient Trails & Ocean Tales of Bali', '25 May to 28 May 2025', 'Ancient Trails & Ocean Tales of Bali (25 May to 28 May 2025)', 'Bali', 'https://storage.karmagroup.com/assets/karmagroup.com/2024/11/167-Ancient-Trails-Ocean-Tales.jpg', 85877], ['Karma Long Lunch:\u2028Adelaide', '17 May 2025', 'Karma Long Lunch:\u2028Adelaide (17 May 2025)', 'Adelaide, Australia', '', ''], ['Art Of The Eight Limbs \u2028Supper Club', '16 May to 18 May 2025', 'Art Of The Eight Limbs \u2028Supper Club (16 May to 18 May 2025)', 'Ungasan, Bali', 'https://storage.karmagroup.com/assets/karmagroup.com/2024/11/164-Art-of-the-eight-limbs.jpg', 85875], ['Quips, One Liners & Laughs Galore with Jimeoin', '16 May 2025', 'Quips, One Liners & Laughs Galore with Jimeoin (16 May 2025)', 'Adelaide, Australia', '', ''], ['Wheels, Wine & Tuscan Wonders', '16 May to 18 May 2025', 'Wheels, Wine & Tuscan Wonders (16 May to 18 May 2025)', 'Tuscany, Italy', 'https://storage.karmagroup.com/assets/karmagroup.com/2025/02/216-Wheel-Wine.jpg', 85823], ['Karma Supper Club: Lakeside Smokehouse', '09 May 2025', 'Karma Supper Club: Lakeside Smokehouse (09 May 2025)', 'Stirling , United Kingdom', 'https://storage.karmagroup.com/assets/karmagroup.com/2025/04/5_1-Post-Event-Email-Banner.jpg', 88102], ['Fawlty Towers: A Comical Dining Experience!', '08 May 2025', 'Fawlty Towers: A Comical Dining Experience! (08 May 2025)', 'Sydney, Australia', '', ''], ['Ancient Traditions & Flavours of Eastern Bali', '06 May to 09 May 2025', 'Ancient Traditions & Flavours of Eastern Bali (06 May to 09 May 2025)', 'Candidasa, Bali', 'https://storage.karmagroup.com/assets/karmagroup.com/2024/11/163-Ancient-Traditions.jpg', 85873], ['Where Tibet Meets India: A Himalayan Adventure', '05 May to 09 May 2025', 'Where Tibet Meets India: A Himalayan Adventure (05 May to 09 May 2025)', 'Gangtok, India', 'https://storage.karmagroup.com/assets/karmagroup.com/2024/11/162-Where-Tibet.jpg', 85848], ['Phillip Island Penguin Parade', '02 May to 04 May 2025', 'Phillip Island Penguin Parade (02 May to 04 May 2025)', 'VIC, Australia', '', ''], ['Member Mixer: Rooftop Rendezvous in Melbourne', '01 May 2025', 'Member Mixer: Rooftop Rendezvous in Melbourne (01 May 2025)', 'Melbourne, Australia', '', ''], ['Watersports & Wellness Weekender', '23 Aug to 25 Aug 2025', 'Watersports & Wellness Weekender (23 Aug to 25 Aug 2025)', 'Ungasan, Bali', 'https://storage.karmagroup.com/assets/karmagroup.com/2024/12/182-Watersport-and-Wellness-Weekender.jpg', 85892], ['Saints & Sinners \u2028in Andalusia', '16 Jun to 20 Jun 2025', 'Saints & Sinners \u2028in Andalusia (16 Jun to 20 Jun 2025)', 'Gaucín, Spain', 'https://storage.karmagroup.com/assets/karmagroup.com/2024/11/175-Saints-and-Sinners.jpg', 85911], ['Melukat: A Balinese Spiritual & Cultural Immersion', '25 Apr to 28 Apr 2025', 'Melukat: A Balinese Spiritual & Cultural Immersion (25 Apr to 28 Apr 2025)', 'Bali, Indonesia', 'https://storage.karmagroup.com/assets/karmagroup.com/2024/11/154-Melukat.jpg', 85870], ['Karma Supper Club: Flavours of Freedom', '25 Apr 2025', 'Karma Supper Club: Flavours of Freedom (25 Apr 2025)', ...

# %%
df_new = pd.concat([df_json, df_not_exists], ignore_index=True)
df_new
# Out:
#                                                   name                  dates  \
# 0                  Giants & Knights, Dreams & Dungeons  24 Jan to 26 Jan 2026
# 1                           Australian Open, VIP-Style            20 Jan 2026
# 2              The Orange Fest at Karma Martam Retreat  19 Jan to 22 Jan 2026
# 3             Alpine Tobogganing & Snow Polo Adventure  15 Jan to 18 Jan 2026
# 4                Canvas & Coast: Goa with Rajesh Chari  05 Jan to 08 Jan 2026
# ..                                                 ...                    ...
# 130              Cocktails, Canapes & Grand Slam Glory            20 Jan 2025
# 131                       Member Mixer: Game, Set, Sip            19 Jan 2025
# 132        Digital-Detox: A Country Retreat in Tuscany  02 May to 05 May 2025
# 133      Sacred Summit: Mount Agung Trekking Adventure  06 Apr to 09 Apr 2025
# 134  Alpine Wellness Adventure
# in Bavaria’s Heartl...  30 Mar to 02 Apr 2025
#
#                                                  event  \
# 0    Giants & Knights, Dreams & Dungeons (24 Jan to...
# 1             Australian Open, VIP-Style (20 Jan 2026)
# 2    The Orange Fest at Karma Martam Retreat (19 Ja...
# 3    Alpine Tobogganing & Snow Polo Adventure (15 J...
# 4    Canvas & Coast: Goa with Rajesh Chari (05 Jan ...
# ..                                                 ...
# 130  Cocktails, Canapes & Grand Slam Glory (20 Jan ...
# 131         Member Mixer: Game, Set, Sip (19 Jan 2025)
# 132  Digital-Detox: A Country Retreat in Tuscany (0...
# 133  Sacred Summit: Mount Agung Trekking Adventure ...
# 134  Alpine Wellness Adventure
# in Bavaria’s Heartl...
#
#                                            destination  \
# 0                         Warwickshire, United Kingdom
# 1                                 Melbourne, Australia
# 2    Karma Martam Retreat, P.O. Gangkha, Via Singta...
# 3                                  Schliersee, Germany
# 4                                                India
# ..                                                 ...
# 130                                          Melbourne
# 131                                 Melbourne VIC 3000
# 132                                     Tuscany, Italy
# 133                                               Bali
# 134                                Schliersee, Germany
#
#                                     event_email_banner event_email_banner_id
# 0
# 1    https://storage.karmagroup.com/assets/karmagro...                 87678
# 2
# 3
# 4
# ..                                                 ...                   ...
# 130
# 131
# 132  https://storage.karmagroup.com/assets/karmagro...                 85821
# 133  https://storage.karmagroup.com/assets/karmagro...                 85868
# 134  https://storage.karmagroup.com/assets/karmagro...                 85835
#
# [135 rows x 6 columns]

# %%
# Update keseluruhan data, delete data yang lama terlebih dahulu
# clear all row before update
worksheet.clear()
worksheet.update([df_new.columns.values.tolist()] + df_new.values.tolist())
# Out:
# {'spreadsheetId': '1k-70BJNRm01RE2S7gBXuOfqxofk1gYz4g6lPbLUCklw',
#  'updatedRange': "'Event List'!A1:F136",
#  'updatedRows': 136,
#  'updatedColumns': 6,
#  'updatedCells': 816}
