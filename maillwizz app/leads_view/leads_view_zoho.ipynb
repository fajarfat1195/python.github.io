# %%
import pandas as pd
import numpy as np
from datetime import datetime

import re

import sys
sys.path.append('../../zoho_data_app/')

# importing
import main_module as m
import zoho_filter_module as fil

# %load_ext autoreload
# %autoreload 2

# %%
path = r'C:\Users\fajar\Documents\Python\Data\Request Data\karmaspa.xlsx'
zoho_df = pd.read_excel(path, dtype='string', sheet_name='Sheet0')

# %%
path = r'G:\.shortcut-targets-by-id\0B_d3smBjzo04eXpvS1NXTWF2RVE\_BOOKING\Booking By Year\FlyBuy Booking Data (BGAU & BGID & KE).xlsx'
df_booking = pd.read_excel(path, dtype='string', sheet_name='BOOKING_BGAU_BGID_KE')

path = r'G:\.shortcut-targets-by-id\0B_d3smBjzo04UUNBME5GOVhoMjA\_ODYSSEY\Phone Members.xlsx'
df_phone = pd.read_excel(path, dtype='string', sheet_name='Sheet1')

path = r'G:\.shortcut-targets-by-id\0B_d3smBjzo04UUNBME5GOVhoMjA\_ODYSSEY\Email Members.xlsx'
df_email = pd.read_excel(path, dtype='string', sheet_name='Sheet1')

# %%
path = r'C:\Users\fajar\Documents\Python\Data\Zoho_Campaign\unsub-zoho-campaigns.csv'
df_unsub_zoho = pd.read_csv(path, dtype='string')

# %%
count_filter_awal = zoho_df.shape[0]

# mengisi kolom <NA> dengan value string 'empty' supaya mudah mengecek data member dan booking dengan isin

zoho_df.fillna('empty', inplace=True)
zoho_df
# Out:
#                       Record Id         Created Time         Created Date  \
# 0      zcrm_3584690000409794028  2022-11-10 00:54:00  2022-11-09 00:00:00
# 1      zcrm_3584690000404526047  2022-10-12 19:13:00  2022-10-12 00:00:00
# 2      zcrm_3584690000402673323  2022-10-03 16:10:00  2022-10-03 00:00:00
# 3      zcrm_3584690000402072082  2022-09-29 17:38:00  2022-09-29 00:00:00
# 4      zcrm_3584690000400243001  2022-09-20 21:52:00  2022-09-20 00:00:00
# ...                         ...                  ...                  ...
# 11443  zcrm_3584690000002607163  2019-02-23 18:21:00                empty
# 11444  zcrm_3584690000002503001  2019-02-21 23:22:00                empty
# 11445  zcrm_3584690000001876097  2019-02-12 17:44:00  2019-02-12 00:00:00
# 11446  zcrm_3584690000001291015  2019-01-31 20:19:00  2019-01-31 00:00:00
# 11447  zcrm_3584690000001115009  2019-01-27 13:22:00  2019-01-27 00:00:00
#
#       First Name Last Name                              Email          Phone  \
# 0           Guru         C              gururajgcss@gmail.com          empty
# 1           Joao   Tavares           jmtavares@btinternet.com          empty
# 2       Valencia     Lopez         valencia.lopez00@gmail.com          empty
# 3       Ranjitha        BM              ranju281094@gmail.com          empty
# 4         vishal     ingle            vishal.ingle1@gmail.com          empty
# ...          ...       ...                                ...            ...
# 11443    Bhargav     Patel                   bhargv@gmail.com          empty
# 11444     Lauren   Brenton          laurenbrenton@outlook.com          empty
# 11445  Aishwarya    Ganesh              divya_g24@yahoo.co.in   917709923249
# 11446       Ajay     Mahan  ajay.mahan@theintelligentsp.co.uk   441543483700
# 11447     Amilya    Amilya         amilya.rossintya@gmail.com  6281336773732
#
#       Mobile            Birthdate Year of Birth  ...  \
# 0      empty                empty         empty  ...
# 1      empty                empty         empty  ...
# 2      empty                empty         empty  ...
# 3      empty                empty         empty  ...
# 4      empty                empty         empty  ...
# ...      ...                  ...           ...  ...
# 11443  empty                empty         empty  ...
# 11444  empty  1984-06-08 00:00:00          1984  ...
# 11445  empty                empty         empty  ...
# 11446  empty                empty         empty  ...
# 11447  empty                empty         empty  ...
#
#                  Lead Locations                Lead Source Description  \
# 0          Karma Royal Benaulim      Karma Spa at Karma Royal Benaulim
# 1             Karma Royal Sanur         Karma Spa at Karma Royal Sanur
# 2      Karma Royal Haathi Mahal  Karma Spa at Karma Royal Haathi Mahal
# 3          Karma Royal Benaulim      Karma Spa at Karma Royal Benaulim
# 4                  Karma Chakra              Karma Spa at Karma Chakra
# ...                         ...                                    ...
# 11443                     empty                                  empty
# 11444                     empty                                  empty
# 11445              Karma Chakra                                  empty
# 11446             Karma Kandara                                  empty
# 11447              Karma Mayura                                  empty
#
#       Lead Regions Lead Status Email Opt Out Opt In Booking Status BookRef  \
# 0            India       empty         false  false          empty   empty
# 1        UK/Europe       empty         false  false          empty   empty
# 2            India       empty         false  false          empty   empty
# 3            India       empty         false  false          empty   empty
# 4            India       empty         false  false          empty   empty
# ...            ...         ...           ...    ...            ...     ...
# 11443        India    New Lead         false  false          empty   empty
# 11444         SEAP    New Lead         false  false          empty   empty
# 11445        India    New Lead         false  false          empty   empty
# 11446    UK/Europe    New Lead         false  false          empty   empty
# 11447         SEAP    New Lead         false  false          empty   empty
#
#       Guest Type External ID
# 0          empty       empty
# 1          empty       empty
# 2          empty       empty
# 3          empty       empty
# 4          empty       empty
# ...          ...         ...
# 11443      empty       empty
# 11444      empty       empty
# 11445      empty       empty
# 11446      empty       empty
# 11447      empty       empty
#
# [11448 rows x 32 columns]

# %%
# zoho_df_awal = df.loc[zoho_filter].copy() # menggunakan copy untuk menghindari setting copy warning
# zoho_df_awal.reset_index(drop=True, inplace=True)

# # mengisi kolom <NA> dengan value string 'empty' supaya mudah mengecek data member dan booking dengan isin
# zoho_df_awal.to_csv(r'C:\Users\fajar\Documents\Python\Data\filter_awal_newsletter.csv', index=False)

# %%
# membersihkan format phone number dan email

m.clean_number(zoho_df, 'Phone')
m.clean_number(zoho_df, 'Mobile')
m.replace_not_valid_to_empty(zoho_df, 'Phone')
m.replace_not_valid_to_empty(zoho_df, 'Mobile')
zoho_df['Email'] = m.lowercase(zoho_df, 'Email')
m.clean_space(zoho_df, 'Email')

m.clean_number(df_booking, 'Phone1')
m.clean_number(df_booking, 'Mobile')
df_booking['Email'] = m.lowercase(df_booking, 'Email')
m.clean_space(df_booking, 'Email')

m.clean_number(df_phone, 'Mobile')

df_email['Email'] = m.lowercase(df_email, 'Email')
m.clean_space(df_email, 'Email')

df_unsub_zoho['Contact Email'] = m.lowercase(df_unsub_zoho, 'Contact Email')
m.clean_space(df_unsub_zoho, 'Contact Email')

count_deleted_wrong_fromat = m.delete_email_wrong_format(zoho_df, 'Email')
count_after_deleted_wrong_format = zoho_df.shape[0]

# %%
# membersihkan email kosong dan duplikat

count_empty_email = zoho_df.loc[zoho_df['Email'] == 'empty'].shape[0]
zoho_df.drop(zoho_df.loc[zoho_df['Email'] == 'empty'].index, inplace=True)
count_after_dedup_empty_email = zoho_df.shape[0]

count_email_duplicate = zoho_df.loc[zoho_df['Email'].duplicated()].shape[0]
zoho_df.drop_duplicates('Email', inplace=True)
count_after_dedup_duplicated_email = zoho_df.shape[0]

zoho_df.reset_index(drop=True, inplace=True)
zoho_df
# Out:
#                       Record Id         Created Time         Created Date  \
# 0      zcrm_3584690000409794028  2022-11-10 00:54:00  2022-11-09 00:00:00
# 1      zcrm_3584690000404526047  2022-10-12 19:13:00  2022-10-12 00:00:00
# 2      zcrm_3584690000402673323  2022-10-03 16:10:00  2022-10-03 00:00:00
# 3      zcrm_3584690000402072082  2022-09-29 17:38:00  2022-09-29 00:00:00
# 4      zcrm_3584690000400243001  2022-09-20 21:52:00  2022-09-20 00:00:00
# ...                         ...                  ...                  ...
# 11146  zcrm_3584690000002607163  2019-02-23 18:21:00                empty
# 11147  zcrm_3584690000002503001  2019-02-21 23:22:00                empty
# 11148  zcrm_3584690000001876097  2019-02-12 17:44:00  2019-02-12 00:00:00
# 11149  zcrm_3584690000001291015  2019-01-31 20:19:00  2019-01-31 00:00:00
# 11150  zcrm_3584690000001115009  2019-01-27 13:22:00  2019-01-27 00:00:00
#
#       First Name Last Name                              Email          Phone  \
# 0           Guru         C              gururajgcss@gmail.com          empty
# 1           Joao   Tavares           jmtavares@btinternet.com          empty
# 2       Valencia     Lopez         valencia.lopez00@gmail.com          empty
# 3       Ranjitha        BM              ranju281094@gmail.com          empty
# 4         vishal     ingle            vishal.ingle1@gmail.com          empty
# ...          ...       ...                                ...            ...
# 11146    Bhargav     Patel                   bhargv@gmail.com          empty
# 11147     Lauren   Brenton          laurenbrenton@outlook.com          empty
# 11148  Aishwarya    Ganesh              divya_g24@yahoo.co.in   917709923249
# 11149       Ajay     Mahan  ajay.mahan@theintelligentsp.co.uk   441543483700
# 11150     Amilya    Amilya         amilya.rossintya@gmail.com  6281336773732
#
#       Mobile            Birthdate Year of Birth  ...  \
# 0      empty                empty         empty  ...
# 1      empty                empty         empty  ...
# 2      empty                empty         empty  ...
# 3      empty                empty         empty  ...
# 4      empty                empty         empty  ...
# ...      ...                  ...           ...  ...
# 11146  empty                empty         empty  ...
# 11147  empty  1984-06-08 00:00:00          1984  ...
# 11148  empty                empty         empty  ...
# 11149  empty                empty         empty  ...
# 11150  empty                empty         empty  ...
#
#                  Lead Locations                Lead Source Description  \
# 0          Karma Royal Benaulim      Karma Spa at Karma Royal Benaulim
# 1             Karma Royal Sanur         Karma Spa at Karma Royal Sanur
# 2      Karma Royal Haathi Mahal  Karma Spa at Karma Royal Haathi Mahal
# 3          Karma Royal Benaulim      Karma Spa at Karma Royal Benaulim
# 4                  Karma Chakra              Karma Spa at Karma Chakra
# ...                         ...                                    ...
# 11146                     empty                                  empty
# 11147                     empty                                  empty
# 11148              Karma Chakra                                  empty
# 11149             Karma Kandara                                  empty
# 11150              Karma Mayura                                  empty
#
#       Lead Regions Lead Status Email Opt Out Opt In Booking Status BookRef  \
# 0            India       empty         false  false          empty   empty
# 1        UK/Europe       empty         false  false          empty   empty
# 2            India       empty         false  false          empty   empty
# 3            India       empty         false  false          empty   empty
# 4            India       empty         false  false          empty   empty
# ...            ...         ...           ...    ...            ...     ...
# 11146        India    New Lead         false  false          empty   empty
# 11147         SEAP    New Lead         false  false          empty   empty
# 11148        India    New Lead         false  false          empty   empty
# 11149    UK/Europe    New Lead         false  false          empty   empty
# 11150         SEAP    New Lead         false  false          empty   empty
#
#       Guest Type External ID
# 0          empty       empty
# 1          empty       empty
# 2          empty       empty
# 3          empty       empty
# 4          empty       empty
# ...          ...         ...
# 11146      empty       empty
# 11147      empty       empty
# 11148      empty       empty
# 11149      empty       empty
# 11150      empty       empty
#
# [11151 rows x 32 columns]

# %%
# Cek Email OTA
count_email_OTA = m.find_OTA(zoho_df, 'Email')
zoho_df.loc[zoho_df['Email']=='OTA']
# Out:
#                       Record Id         Created Time         Created Date  \
# 417    zcrm_3584690000346108276  2022-02-17 13:39:00  2022-02-17 00:00:00
# 2374   zcrm_3584690000265563361  2021-02-17 08:53:00  2021-02-17 00:00:00
# 4014   zcrm_3584690000147162352  2019-11-28 10:51:00  2019-11-27 00:00:00
# 4886   zcrm_3584690000090856537  2019-08-06 19:55:00  2018-12-15 00:00:00
# 5294   zcrm_3584690000073302177  2019-07-16 18:56:00  2019-07-15 00:00:00
# 5429   zcrm_3584690000054562511  2019-06-29 13:07:00  2019-06-28 00:00:00
# 5467   zcrm_3584690000050011008  2019-06-22 13:41:00  2019-05-22 00:00:00
# 7047   zcrm_3584690000029864256  2019-05-10 16:20:00                empty
# 10419  zcrm_3584690000024541960  2019-04-07 15:08:00  2018-01-31 00:00:00
#
#       First Name   Last Name Email       Phone Mobile Birthdate Year of Birth  \
# 417         Agus     Mardika   OTA       empty  empty     empty         empty
# 2374       Gavin      Parker   OTA       empty  empty     empty         empty
# 4014     Dorothy  Nullmayers   OTA  0452565958  empty     empty         empty
# 4886        Adam    Saunders   OTA       empty  empty     empty         empty
# 5294      Ingrid   sellarulo   OTA       empty  empty     empty         empty
# 5429       Renee      Rudolf   OTA       empty  empty     empty         empty
# 5467         tes         dev   OTA       empty  empty     empty         empty
# 7047       empty       Manny   OTA       empty  empty     empty         empty
# 10419    Josefin        Pote   OTA       empty  empty     empty         empty
#
#        ...  Lead Locations         Lead Source Description Lead Regions  \
# 417    ...   Karma Kandara      Karma Spa at Karma Kandara    UK/Europe
# 2374   ...  Karma Rottnest     Karma Spa at Karma Rottnest         SEAP
# 4014   ...  Karma Rottnest                           empty         SEAP
# 4886   ...  Karma Rottnest                           empty        empty
# 5294   ...   Karma Kandara                           empty         SEAP
# 5429   ...   Karma Kandara                           empty         SEAP
# 5467   ...   Karma Kandara                           empty        Other
# 7047   ...           empty                           empty         SEAP
# 10419  ...   Karma Kandara  Karma Kandara Spa January 2018    UK/Europe
#
#       Lead Status Email Opt Out Opt In Booking Status BookRef Guest Type  \
# 417         empty         false  false          empty   empty      empty
# 2374        empty         false  false          empty   empty      empty
# 4014        empty         false  false          empty   empty      empty
# 4886     New Lead         false  false          empty   empty      empty
# 5294        empty         false  false          empty   empty      empty
# 5429        empty         false  false          empty   empty      empty
# 5467        empty         false  false          empty   empty      empty
# 7047     New Lead         false  false          empty   empty      empty
# 10419    New Lead         false  false          empty   empty      empty
#
#       External ID
# 417         empty
# 2374        empty
# 4014        empty
# 4886        empty
# 5294        empty
# 5429        empty
# 5467        empty
# 7047        empty
# 10419       empty
#
# [9 rows x 32 columns]

# %%
# Hapus email OTA

zoho_df.drop(zoho_df[zoho_df['Email'] == 'OTA'].index, inplace=True)
zoho_df.reset_index(drop=True, inplace=True)

count_after_clean_OTA = zoho_df.shape[0]

zoho_df
# Out:
#                       Record Id         Created Time         Created Date  \
# 0      zcrm_3584690000409794028  2022-11-10 00:54:00  2022-11-09 00:00:00
# 1      zcrm_3584690000404526047  2022-10-12 19:13:00  2022-10-12 00:00:00
# 2      zcrm_3584690000402673323  2022-10-03 16:10:00  2022-10-03 00:00:00
# 3      zcrm_3584690000402072082  2022-09-29 17:38:00  2022-09-29 00:00:00
# 4      zcrm_3584690000400243001  2022-09-20 21:52:00  2022-09-20 00:00:00
# ...                         ...                  ...                  ...
# 11137  zcrm_3584690000002607163  2019-02-23 18:21:00                empty
# 11138  zcrm_3584690000002503001  2019-02-21 23:22:00                empty
# 11139  zcrm_3584690000001876097  2019-02-12 17:44:00  2019-02-12 00:00:00
# 11140  zcrm_3584690000001291015  2019-01-31 20:19:00  2019-01-31 00:00:00
# 11141  zcrm_3584690000001115009  2019-01-27 13:22:00  2019-01-27 00:00:00
#
#       First Name Last Name                              Email          Phone  \
# 0           Guru         C              gururajgcss@gmail.com          empty
# 1           Joao   Tavares           jmtavares@btinternet.com          empty
# 2       Valencia     Lopez         valencia.lopez00@gmail.com          empty
# 3       Ranjitha        BM              ranju281094@gmail.com          empty
# 4         vishal     ingle            vishal.ingle1@gmail.com          empty
# ...          ...       ...                                ...            ...
# 11137    Bhargav     Patel                   bhargv@gmail.com          empty
# 11138     Lauren   Brenton          laurenbrenton@outlook.com          empty
# 11139  Aishwarya    Ganesh              divya_g24@yahoo.co.in   917709923249
# 11140       Ajay     Mahan  ajay.mahan@theintelligentsp.co.uk   441543483700
# 11141     Amilya    Amilya         amilya.rossintya@gmail.com  6281336773732
#
#       Mobile            Birthdate Year of Birth  ...  \
# 0      empty                empty         empty  ...
# 1      empty                empty         empty  ...
# 2      empty                empty         empty  ...
# 3      empty                empty         empty  ...
# 4      empty                empty         empty  ...
# ...      ...                  ...           ...  ...
# 11137  empty                empty         empty  ...
# 11138  empty  1984-06-08 00:00:00          1984  ...
# 11139  empty                empty         empty  ...
# 11140  empty                empty         empty  ...
# 11141  empty                empty         empty  ...
#
#                  Lead Locations                Lead Source Description  \
# 0          Karma Royal Benaulim      Karma Spa at Karma Royal Benaulim
# 1             Karma Royal Sanur         Karma Spa at Karma Royal Sanur
# 2      Karma Royal Haathi Mahal  Karma Spa at Karma Royal Haathi Mahal
# 3          Karma Royal Benaulim      Karma Spa at Karma Royal Benaulim
# 4                  Karma Chakra              Karma Spa at Karma Chakra
# ...                         ...                                    ...
# 11137                     empty                                  empty
# 11138                     empty                                  empty
# 11139              Karma Chakra                                  empty
# 11140             Karma Kandara                                  empty
# 11141              Karma Mayura                                  empty
#
#       Lead Regions Lead Status Email Opt Out Opt In Booking Status BookRef  \
# 0            India       empty         false  false          empty   empty
# 1        UK/Europe       empty         false  false          empty   empty
# 2            India       empty         false  false          empty   empty
# 3            India       empty         false  false          empty   empty
# 4            India       empty         false  false          empty   empty
# ...            ...         ...           ...    ...            ...     ...
# 11137        India    New Lead         false  false          empty   empty
# 11138         SEAP    New Lead         false  false          empty   empty
# 11139        India    New Lead         false  false          empty   empty
# 11140    UK/Europe    New Lead         false  false          empty   empty
# 11141         SEAP    New Lead         false  false          empty   empty
#
#       Guest Type External ID
# 0          empty       empty
# 1          empty       empty
# 2          empty       empty
# 3          empty       empty
# 4          empty       empty
# ...          ...         ...
# 11137      empty       empty
# 11138      empty       empty
# 11139      empty       empty
# 11140      empty       empty
# 11141      empty       empty
#
# [11142 rows x 32 columns]

# %%
find_member_booking = zoho_df.copy()

find_member_booking.loc[find_member_booking['Phone'].isin(df_booking['Phone1']), 'Same Value Find'] = 'Booking-Phone1'
find_member_booking.loc[find_member_booking['Phone'].isin(df_booking['Mobile']), 'Same Value Find'] = 'Booking-Mobile'
find_member_booking.loc[find_member_booking['Mobile'].isin(df_booking['Phone1']), 'Same Value Find'] = 'Booking-Phone1' 
find_member_booking.loc[find_member_booking['Mobile'].isin(df_booking['Mobile']), 'Same Value Find'] = 'Booking-Mobile'
find_member_booking.loc[find_member_booking['Email'].isin(df_booking['Email']), 'Same Value Find'] = 'Booking-Email'

find_member_booking.loc[find_member_booking['Phone'].isin(df_phone['Mobile']), 'Same Value Find'] = 'Member-Mobile' 
find_member_booking.loc[find_member_booking['Mobile'].isin(df_phone['Mobile']), 'Same Value Find'] = 'Member-Mobile'

find_member_booking.loc[find_member_booking['Email'].isin(df_email['Email']), 'Same Value Find'] = 'Member-Email'

find_member_booking.drop(find_member_booking.loc[find_member_booking['Same Value Find'].isna()].index, inplace=True)

count_booking_dedup = find_member_booking.loc[find_member_booking['Same Value Find'].str.contains('Booking', flags=re.I, regex=True)].shape[0]
count_member_dedup = find_member_booking.loc[find_member_booking['Same Value Find'].str.contains('Member', flags=re.I, regex=True)].shape[0]

find_member_booking.replace('empty', '', inplace=True)

# find_member_booking.to_csv(r'C:\Users\fajar\Documents\Python\Data\booking-member-dedup-spa.csv', index=False)

# %%
# data phone, mobile dam email member yang ada di master data (wash member)
count_wash_member = zoho_df.loc[
    zoho_df['Phone'].isin(df_booking['Phone1']) | 
    zoho_df['Phone'].isin(df_booking['Mobile']) |
    zoho_df['Mobile'].isin(df_booking['Phone1']) | 
    zoho_df['Mobile'].isin(df_booking['Mobile']) |
    zoho_df['Email'].isin(df_booking['Email'])| 

    zoho_df['Phone'].isin(df_phone['Mobile']) | 
    zoho_df['Mobile'].isin(df_phone['Mobile']) |

    zoho_df['Email'].isin(df_email['Email'])

].shape[0]

zoho_df.drop(zoho_df.loc[
    zoho_df['Phone'].isin(df_booking['Phone1']) | 
    zoho_df['Phone'].isin(df_booking['Mobile']) |
    zoho_df['Mobile'].isin(df_booking['Phone1']) | 
    zoho_df['Mobile'].isin(df_booking['Mobile']) |
    zoho_df['Email'].isin(df_booking['Email']) |
    
    zoho_df['Phone'].isin(df_phone['Mobile']) | 
    zoho_df['Mobile'].isin(df_phone['Mobile']) |

    zoho_df['Email'].isin(df_email['Email'])

    ].index, inplace=True)
zoho_df.reset_index(drop=True, inplace=True)

count_after_wash_member = zoho_df.shape[0]

# %%
find_zoho_unsubs = zoho_df.loc[zoho_df['Email'].isin(df_unsub_zoho['Contact Email'])].copy()
count_wash_zoho_unsubs = find_zoho_unsubs.shape[0]

find_zoho_unsubs.replace('empty', '', inplace=True)

# find_zoho_unsubs.to_csv(r'C:\Users\fajar\Documents\Python\Data\zoho-unsub-dedup-spa.csv', index=False)
zoho_df.drop(find_zoho_unsubs.index, inplace=True)

count_after_wash_zoho_unsubs = zoho_df.shape[0]
print(count_after_wash_zoho_unsubs)
# Out:
# 5734

# %%
zoho_df.replace('empty', '', inplace=True)

# %%
print("==========================================================")
print("Summary")
print("==========================================================")
print("Jumlah Filter Leads Awal : "+str(count_filter_awal))
print("Jumlah Format Email Salah : "+str(count_deleted_wrong_fromat))
print("Jumlah Setelah Clean Format Email Salah : "+str(count_after_deleted_wrong_format))
print("Jumlah Email Kosong : "+str(count_empty_email))
print("Jumlah Setelah Clean Email Kosong : "+str(count_after_dedup_empty_email))
print("Jumlah Email Duplikat : "+str(count_email_duplicate))
print("Jumlah Setelah Clean Format Email Duplikat : "+str(count_after_dedup_duplicated_email))
print("Jumlah Email OTA : "+str(count_email_OTA))
print("Jumlah Setelah Clean Email OTA : "+str(count_after_clean_OTA))
print("Jumlah Wash Member dan Booking : "+str(count_wash_member))
print("Jumlah Setelah Wash Member : "+str(count_after_wash_member))
print("Jumlah Wash Zoho Unsubs: "+str(count_wash_zoho_unsubs))
print("Jumlah Setelah Wash Zoho Unsubs : "+str(count_after_wash_zoho_unsubs))
# Out:
# ==========================================================
# Summary
# ==========================================================
# Jumlah Filter Leads Awal : 11448
# Jumlah Format Email Salah : 16
# Jumlah Setelah Clean Format Email Salah : 11432
# Jumlah Email Kosong : 0
# Jumlah Setelah Clean Email Kosong : 11432
# Jumlah Email Duplikat : 281
# Jumlah Setelah Clean Format Email Duplikat : 11151
# Jumlah Email OTA : 9
# Jumlah Setelah Clean Email OTA : 11142
# Jumlah Wash Member dan Booking : 459
# Jumlah Setelah Wash Member : 10683
# Jumlah Wash Zoho Unsubs: 4949
# Jumlah Setelah Wash Zoho Unsubs : 5734

# %%
# zoho_df.to_csv(r'C:\Users\fajar\Documents\Python\Data\karmaspa-clean.csv', index=False)

# %% [markdown]
# # ===================== Split File =====================

# %%
# membuat batch file excel

zoho_df['Batch'] = ''
batch_number = 10000
zoho_df = m.insert_batch_loop(zoho_df, batch_number, -1)
zoho_df.groupby('Batch').count()
# Out:
#        Record Id  Created Time  Created Date  First Name  Last Name  Email  \
# Batch
#             5734          5734          5734        5734       5734   5734
#
#        Phone  Mobile  Birthdate  Year of Birth  ...  Lead Locations  \
# Batch                                           ...
#         5734    5734       5734           5734  ...            5734
#
#        Lead Source Description  Lead Regions  Lead Status  Email Opt Out  \
# Batch
#                           5734          5734         5734           5734
#
#        Opt In  Booking Status  BookRef  Guest Type  External ID
# Batch
#          5734            5734     5734        5734         5734
#
# [1 rows x 32 columns]

# %%
# melakukan split file

filename = 'test'
split_number = 50000
m.split_file(zoho_df, split_number, filename)
