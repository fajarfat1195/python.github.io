# %%
import pandas as pd
import numpy as np
import subscribers_module_live as sub

# %load_ext autoreload
# %autoreload 2

# %%
list = sub.load_lists_id() # load list id

list = sub.load_lists_id() # load list id

maillwizz_cols = ['subscriber_uid',	
'CREATEDTIME',
'CREATEDDATE',	
'FNAME',	
'LNAME',	
'EMAIL',	
'PHONE',	
'MOBILE',	
'BIRTHDATE',	
'BIRTHYEAR',
'STREET',	
'STREET2',	
'CITY',	
'STATE',	
'COUNTRY',	
'DEPDATE',	
'ARRDATE',	
'CARDTYPE',	
'MARSTATUS',	
'LABELBRAND',	
'LEADSUBBRAND',	
'LEADSOURCE',	
'LEADLOCATIONS',	
'LEADSOURCEDESC',	
'LEADREGIONS',
'LEADSTATUS',
'EMAILOPTOUT',	
'OPTIN']

zoho_cols = ['Record Id',	
'Created Time',
'Created Date',	
'First Name',	
'Last Name',	
'Email',	
'Phone',	
'Mobile',	
'Birthdate',	
'Year of Birth',
'Street',	
'Street2',	
'City',	
'State',	
'Country',	
'Departure Date',	
'Arrival Date',	
'Card Type',	
'Marital Status',	
'Lead Brand',	
'Lead Sub-Brand',	
'Lead Source',	
'Lead Locations',	
'Lead Source Description',	
'Lead Regions',
'Lead Status',
'Email Opt Out',	
'Opt In']

dir_path = r'C:\Users\fajar\Documents\Python\Data\Zoho_Backup'
file_name = '\Leads_'

load_maillwizz_df = sub.load_subs(list['Test'])
load_maillwizz_df = sub.reindex_cols(load_maillwizz_df, maillwizz_cols)
load_maillwizz_df
# Out:
#     subscriber_uid          CREATEDTIME CREATEDDATE       FNAME      LNAME  \
# 0    zo175rxtc5b76  2019-01-09 11:10:59                    Yann      Cohen
# 1    nz734w5b8bd60  2019-01-09 11:10:59                   Clive    Langdon
# 2    fy580b0bwr943  2019-01-09 11:10:59                   Clive       Penn
# 3    ax469yzdj3ff4  2019-01-09 11:10:59              Clementine   Michalik
# 4    mr839jbfbxc23  2019-01-09 11:10:59                   Claus     Lapicz
# ..             ...                  ...         ...         ...        ...
# 303  gh6607h4d3571  2019-01-08 16:38:18                Michelle    Rasborn
# 304  ol172clcw0235  2019-01-08 16:38:18               Christina      K�nig
# 305  mn944fhyjm2e4  2019-01-08 16:38:18                  Moritz   Holzmann
# 306  zx944ckphmb60  2019-01-08 16:38:18                   Maeve      Maher
# 307  no724gk6qd88f  2019-01-08 16:38:18                    Lisa  Ferkovich
#
#                               EMAIL          PHONE MOBILE   BIRTHDATE  \
# 0             cohensolaly@gmail.com   330660407329
# 1    clivelangdon887@btinternet.com      442809167
# 2             clive.penn@icloud.com    61434086027
# 3             clemichalik@gmail.com      671981933
# 4          claus.lapicz@t-online.de  4989998299531         1979-03-31
# ..                              ...            ...    ...         ...
# 303         mrasborn@netvigator.com    85290173230         1976-08-20
# 304                tina.gick@gmx.de  4917620503503         1978-03-08
# 305          moritz.holzmann@gmx.de  4915140714809         1978-07-09
# 306           maeve.maher@gmail.com   353868702583         1973-01-15
# 307            lisajo2009@yahoo.com    14062394749         1963-07-08
#
#     BIRTHYEAR  ... MARSTATUS     LABELBRAND LEADSUBBRAND   LEADSOURCE  \
# 0              ...            Karma Resorts        Other  Past Guests
# 1              ...            Karma Resorts        Other  Past Guests
# 2              ...            Karma Resorts        Other  Past Guests
# 3              ...            Karma Resorts        Other  Past Guests
# 4        1979  ...            Karma Resorts        Other  Past Guests
# ..        ...  ...       ...            ...          ...          ...
# 303      1976  ...            Karma Resorts        Other  Past Guests
# 304      1978  ...            Karma Resorts        Other  Past Guests
# 305      1978  ...            Karma Resorts        Other  Past Guests
# 306      1973  ...            Karma Resorts        Other  Past Guests
# 307      1963  ...            Karma Resorts        Other  Past Guests
#
#                                  LEADLOCATIONS LEADSOURCEDESC LEADREGIONS  \
# 0    Karma Manoir;Karma Manoir des Deux Amants                  UK/Europe
# 1          Karma St. Martin's;Karma St Martins                  UK/Europe
# 2                               Karma Rottnest                       SEAP
# 3    Karma Manoir;Karma Manoir des Deux Amants                  UK/Europe
# 4                  Karma Bavaria;Karma Kandara                  UK/Europe
# ..                                         ...            ...         ...
# 303                              Karma Kandara                  UK/Europe
# 304                              Karma Bavaria                  UK/Europe
# 305                              Karma Bavaria                  UK/Europe
# 306                              Karma Bavaria                  UK/Europe
# 307                              Karma Bavaria                  UK/Europe
#
#       LEADSTATUS EMAILOPTOUT  OPTIN
# 0       New Lead        true  false
# 1       New Lead        true  false
# 2       New Lead        true  false
# 3       New Lead        true  false
# 4       New Lead        true  false
# ..           ...         ...    ...
# 303  No Response       false  false
# 304     New Lead        true  false
# 305     New Lead        true  false
# 306     New Lead        true  false
# 307     New Lead        true  false
#
# [308 rows x 28 columns]
