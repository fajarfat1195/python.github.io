# %%
import gspread
import pandas as pd

# Pastikan permision access di menu "Share" di rubah ke anyone with the link terlebih dahulu, agar bisa mengunakan cara OAuth
# Jika Ingin lebih dibatasi menggunakan cara google service account lebih disarankan

gc = gspread.oauth(
    credentials_filename= r'C:\Users\fajar\Documents\Python\Data\Google Credentials\fajar-fatoni-OAuth.json'
)

SHEET_ID = '1zW8LbcZje0Z8oDWM0utJxJwrtTjGsXtcIjuk8PmZNzw'
SHEET_NAME = 'Data'

# %%
def next_available_row(worksheet):
    str_list = worksheet.col_values(1)
    return str(len(str_list)+1)

# %%
# get data gsheet

spreadsheet = gc.open_by_key(SHEET_ID)
worksheet = spreadsheet.worksheet(SHEET_NAME)
rows = worksheet.get_all_records()

# print(rows[:5])

# print('==============================')
df = pd.DataFrame(rows)
df
# Out:
#        Odyssey Member ID  Contact ID  FirstName  LastName         Street  \
# 0                1118668     1109047     Elliot    Styche
# 1                1118840     1109358     Marcus    Willis
# 2                1118843     1109361    Jackson  Springer
# 3                1118885     1109425       Kirk   Mathews
# 4                1118886     1109427  Alexander      Parr
# ...                  ...         ...        ...       ...            ...
# 32235             978027      904127    Mustafa   Alawami    AL MUNTAZAH
# 32236             993278      911101    Anthony     Brett  4 FROME PLACE
# 32237             993278      911102     Sandra    Tanner  4 FROME PLACE
# 32238             996049      915079        Kim    Lawson   11 THIRD AVE
# 32239             996049      915080    Michael   Moralee   11 THIRD AVE
#
#       Street 2        State            City       Country Post Code  ...  \
# 0                      Hull                     Australia            ...
# 1               Collingwood                     Australia            ...
# 2                 Melbourne                     Australia            ...
# 3                    Sydney                     Australia            ...
# 4                    Sydney                     Australia            ...
# ...        ...          ...             ...           ...       ...  ...
# 32235                DAMMAM    EASTERN PROV  Saudi Arabia     31441  ...
# 32236                               BRISTOL       England  BS16 1DJ  ...
# 32237                               BRISTOL       England  BS16 1DJ  ...
# 32238               MORPETH  NORTHUMBERLAND       England  NE61 2HZ  ...
# 32239               MORPETH  NORTHUMBERLAND       England  NE61 2HZ  ...
#
#         Birthdate Wedding Date Odyssey Acoount Status Odyssey Member Type  \
# 0      1988-12-07                              Active      HOUSE OF KARMA
# 1      1989-12-20                              Active      HOUSE OF KARMA
# 2      2023-07-14                              Active      HOUSE OF KARMA
# 3      2023-03-30                              Active      HOUSE OF KARMA
# 4      1992-08-13                              Active      HOUSE OF KARMA
# ...           ...          ...                    ...                 ...
# 32235  1991-08-15                           Suspended          KARMA CLUB
# 32236  1945-02-27                           Suspended          KARMA CLUB
# 32237  1951-01-21                           Suspended          KARMA CLUB
# 32238  1970-11-23                           Suspended          KARMA CLUB
# 32239  1964-09-03                           Suspended          KARMA CLUB
#
#             Servicing Office                             Email   Lead Brand  \
# 0       KARMA CONCIERGE BALI        elliotstyche@hotmail.co.uk  Karma Group
# 1       KARMA CONCIERGE BALI  marcuswillis@eightclients.com.au  Karma Group
# 2       KARMA CONCIERGE BALI              jackson@plumm.agency  Karma Group
# 3       KARMA CONCIERGE BALI            kirk_mathews@ymail.com  Karma Group
# 4       KARMA CONCIERGE BALI                 alex.parr@mac.com  Karma Group
# ...                      ...                               ...          ...
# 32235  KARMA CONCIERGE INDIA            malawami1991@gmail.com  Karma Group
# 32236  KARMA CONCIERGE INDIA              tonybrett3@gmail.com  Karma Group
# 32237  KARMA CONCIERGE INDIA            spannerroo@hotmail.com  Karma Group
# 32238  KARMA CONCIERGE INDIA              kimlawson@live.co.uk  Karma Group
# 32239  KARMA CONCIERGE INDIA             moraleemick@gmail.com  Karma Group
#
#         Lead Sub Brand Lead Source              Lead Source Description
# 0      Karma Concierge      Member  Members Birthday & Anniversary Data
# 1      Karma Concierge      Member  Members Birthday & Anniversary Data
# 2      Karma Concierge      Member  Members Birthday & Anniversary Data
# 3      Karma Concierge      Member  Members Birthday & Anniversary Data
# 4      Karma Concierge      Member  Members Birthday & Anniversary Data
# ...                ...         ...                                  ...
# 32235  Karma Concierge      Member  Members Birthday & Anniversary Data
# 32236  Karma Concierge      Member  Members Birthday & Anniversary Data
# 32237  Karma Concierge      Member  Members Birthday & Anniversary Data
# 32238  Karma Concierge      Member  Members Birthday & Anniversary Data
# 32239  Karma Concierge      Member  Members Birthday & Anniversary Data
#
# [32240 rows x 21 columns]

# %%
next_row = next_available_row(worksheet)
next_row
# Out:
# '16'

# %%
# # clear all row before update
# worksheet.clear()

# %%
# Update Using
worksheet.update('A2:C3', [['US', 'Wallstreet', 125000], ['US', 'Brooklyn', 44587]])
# Out:
# ---------------------------------------------------------------------------
# APIError                                  Traceback (most recent call last)
# c:\Users\fajar\Documents\Python\Task Offline\gsheet_app\gsheet_app_oauth_client.ipynb Cell 5 in 2
#       <a href='vscode-notebook-cell:/c%3A/Users/fajar/Documents/Python/Task%20Offline/gsheet_app/gsheet_app_oauth_client.ipynb#W4sZmlsZQ%3D%3D?line=0'>1</a> # Update Using
# ----> <a href='vscode-notebook-cell:/c%3A/Users/fajar/Documents/Python/Task%20Offline/gsheet_app/gsheet_app_oauth_client.ipynb#W4sZmlsZQ%3D%3D?line=1'>2</a> worksheet.update('A2:C3', [['US', 'Wallstreet', 125000], ['US', 'Brooklyn', 44587]])
#
# File ~\AppData\Roaming\Python\Python310\site-packages\gspread\utils.py:702, in accepted_kwargs.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     699 for k, v in default_kwargs.items():
#     700     kwargs.setdefault(k, v)
# --> 702 return f(*args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\gspread\worksheet.py:1041, in Worksheet.update(self, range_name, values, **kwargs)
#    1026     kwargs["value_input_option"] = (
#    1027         ValueInputOption.raw if kwargs["raw"] else ValueInputOption.user_entered
#    1028     )
#    1030 params = filter_dict_values(
#    1031     {
#    1032         "valueInputOption": kwargs["value_input_option"],
#    (...)
#    1038     }
#    1039 )
# -> 1041 response = self.spreadsheet.values_update(
#    1042     range_name,
#    1043     params=params,
#    1044     body=filter_dict_values(
#    1045         {"values": values, "majorDimension": kwargs["major_dimension"]}
#    1046     ),
#    1047 )
#    1049 return response
#
# File ~\AppData\Roaming\Python\Python310\site-packages\gspread\spreadsheet.py:226, in Spreadsheet.values_update(self, range, params, body)
#     203 """Lower-level method that directly calls `spreadsheets/<ID>/values/<range>`_.
#     204
#     205 :param str range: The `A1 notation <https://developers.google.com/sheets/api/guides/concepts#a1_notation>`_ of the values to update.
#    (...)
#     223 .. versionadded:: 3.0
#     224 """
#     225 url = SPREADSHEET_VALUES_URL % (self.id, quote(range))
# --> 226 r = self.client.request("put", url, params=params, json=body)
#     227 return r.json()
#
# File ~\AppData\Roaming\Python\Python310\site-packages\gspread\client.py:92, in Client.request(self, method, endpoint, params, data, json, files, headers)
#      90     return response
#      91 else:
# ---> 92     raise APIError(response)
#
# APIError: {'code': 400, 'message': 'You are trying to edit a protected cell or object. Please contact the spreadsheet owner to remove protection if you need to edit.', 'status': 'INVALID_ARGUMENT'}

# %%
worksheet.update([df.columns.values.tolist()] + df.values.tolist())
# Out:
# ---------------------------------------------------------------------------
# APIError                                  Traceback (most recent call last)
# Cell In [55], line 1
# ----> 1 worksheet.update([df.columns.values.tolist()] + df.values.tolist())
#
# File ~\AppData\Roaming\Python\Python310\site-packages\gspread\utils.py:702, in accepted_kwargs.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     699 for k, v in default_kwargs.items():
#     700     kwargs.setdefault(k, v)
# --> 702 return f(*args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\gspread\worksheet.py:1041, in Worksheet.update(self, range_name, values, **kwargs)
#    1026     kwargs["value_input_option"] = (
#    1027         ValueInputOption.raw if kwargs["raw"] else ValueInputOption.user_entered
#    1028     )
#    1030 params = filter_dict_values(
#    1031     {
#    1032         "valueInputOption": kwargs["value_input_option"],
#    (...)
#    1038     }
#    1039 )
# -> 1041 response = self.spreadsheet.values_update(
#    1042     range_name,
#    1043     params=params,
#    1044     body=filter_dict_values(
#    1045         {"values": values, "majorDimension": kwargs["major_dimension"]}
#    1046     ),
#    1047 )
#    1049 return response
#
# File ~\AppData\Roaming\Python\Python310\site-packages\gspread\spreadsheet.py:226, in Spreadsheet.values_update(self, range, params, body)
#     203 """Lower-level method that directly calls `spreadsheets/<ID>/values/<range>`_.
#     204
#     205 :param str range: The `A1 notation <https://developers.google.com/sheets/api/guides/concepts#a1_notation>`_ of the values to update.
#    (...)
#     223 .. versionadded:: 3.0
#     224 """
#     225 url = SPREADSHEET_VALUES_URL % (self.id, quote(range))
# --> 226 r = self.client.request("put", url, params=params, json=body)
#     227 return r.json()
#
# File ~\AppData\Roaming\Python\Python310\site-packages\gspread\client.py:92, in Client.request(self, method, endpoint, params, data, json, files, headers)
#      90     return response
#      91 else:
# ---> 92     raise APIError(response)
#
# APIError: {'code': 400, 'message': 'You are trying to edit a protected cell or object. Please contact the spreadsheet owner to remove protection if you need to edit.', 'status': 'INVALID_ARGUMENT'}
