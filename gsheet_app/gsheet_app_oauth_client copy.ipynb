# %%
import gspread
import pandas as pd
from fractions import Fraction
import re

import sys
sys.path.append('../zoho_data_app')

import main_module as m

# Pastikan permision access di menu "Share" di rubah ke anyone with the link terlebih dahulu, agar bisa mengunakan cara OAuth
# Jika Ingin lebih dibatasi menggunakan cara google service account lebih disarankan

gc = gspread.oauth(
    credentials_filename= r'C:\Users\fajar\Documents\Python\Data\Google Credentials\fajar-fatoni-OAuth.json'
)

SHEET_ID = '1B7e1rVK0c8Krh4ng5Fdc0Xew7-HMOVa28I_HwW3E2Ok'
SHEET_NAME = 'Karma Beach'
SHEET_NAME_2 = 'Karma Kandara'
SHEET_NAME_3 = 'Karma Jimbaran'

# %%
path = r'C:\Users\fajar\Documents\Python\Data\Leads_2024_08_05.csv'
zoho_df = pd.read_csv(path, dtype='string')
count_data_awal = zoho_df.shape[0]
zoho_df.fillna('empty', inplace=True)

# %%
# get data gsheet

spreadsheet = gc.open_by_key(SHEET_ID)
worksheet = spreadsheet.worksheet(SHEET_NAME)
rows = worksheet.get_all_records()

# print(rows[:5])

# print('==============================')
df = pd.DataFrame(rows)
df['Mobile Number'] = df['Mobile Number'].apply(Fraction)
df
# Out:
#                  Name  Mobile Number  \
# 0           Tri Sabdo  6285250841919
# 1      Dave Scheckter   628113893039
# 2               Shaun  6281138006892
# 3         Rai Artawan  6281338016603
# 4         Karma Beach  6281138305944
# ...               ...            ...
# 16077              FD    33652587816
# 16078       Guadalupe    34662228304
# 16079           Lau ✨    33749637347
# 16080    Mohit Dhawan   447976238475
# 16081          Alexis   447853556262
#
#                                                     Tags      Last Active  \
# 0               Past Purple Guest | KK_Valentine_12Feb24  12/15/2023 6:17
# 1                         Management | Past Purple Guest   7/23/2024 6:30
# 2                  Past Purple Guest | In House 7 May 24    8/1/2024 3:42
# 3      KK Sample Blast | Past Purple Guest | Beach En...    8/2/2024 0:10
# 4                                      Past Purple Guest
# ...                                                  ...              ...
# 16077                                                       8/1/2024 2:51
# 16078                                                       8/1/2024 1:55
# 16079                                                       8/1/2024 0:18
# 16080                                                       8/1/2024 3:59
# 16081                                                      8/1/2024 19:39
#
#              Joined On First Message Tag   Source Incoming Opted In  \
# 0      12/15/2023 5:53                    ORGANIC   Active      Yes
# 1      12/15/2023 6:12                    ORGANIC   Active      Yes
# 2      12/16/2023 6:30                    ORGANIC   Active      Yes
# 3      12/16/2023 6:32                    ORGANIC   Active      Yes
# 4      12/16/2023 8:26                              Active      Yes
# ...                ...               ...      ...      ...      ...
# 16077  7/31/2024 11:29                    ORGANIC   Active      Yes
# 16078  7/31/2024 14:23                    ORGANIC   Active      Yes
# 16079  7/31/2024 21:51                    ORGANIC   Active      Yes
# 16080    8/1/2024 0:20                    ORGANIC   Active      Yes
# 16081   8/1/2024 19:39                    ORGANIC   Active      Yes
#
#       Intervened By ZohoID Email    Country
# 0
# 1                                         -
# 2                                 Indonesia
# 3
# 4
# ...             ...    ...   ...        ...
# 16077
# 16078
# 16079     Eka Canis
# 16080
# 16081
#
# [16082 rows x 13 columns]

# %%
# get data gsheet

spreadsheet = gc.open_by_key(SHEET_ID)
worksheet = spreadsheet.worksheet(SHEET_NAME_2)
rows = worksheet.get_all_records()

# print(rows[:5])

# print('==============================')
df2 = pd.DataFrame(rows)
df2['Mobile Number'] = df2['Mobile Number'].apply(Fraction)
df2
# Out:
#                            Name  Mobile Number  \
# 0              Mr Andrew Stuart  9161409813333
# 1         Mr Brett Jared Peters  9161425787589
# 2            Amol Prakash Punde   918983623496
# 3               Shaun Duenhofen  6281138006892
# 4             Tanya Klimentyeva  6281138305940
# ...                         ...            ...
# 2714          Edward Hasoloan P   628119199373
# 2715  Jitendra Ariga Ratnatraya  6796599363843
# 2716             Kalyan Acharya    61426291122
# 2717              Thomas Wachal    61490712192
# 2718             Prateek Bajpai   919039109451
#
#                                                    Tags     Last Active  \
# 0                                               Invalid
# 1                                               Invalid
# 2     In House 22 March 24 | In House 24 March 24 | ...
# 3     In House 23 July 24 | In House 25 July 24 | Pa...  5/11/2024 4:21
# 4                                       KK Sample Blast
# ...                                                 ...             ...
# 2714                               In House 1 August 24
# 2715                               In House 1 August 24
# 2716                               In House 1 August 24
# 2717                               In House 1 August 24
# 2718                               In House 1 August 24
#
#            Joined On First Message Tag    Source Incoming Opted In  \
# 0     3/19/2024 7:01                    IMPORTED   Active       No
# 1     3/19/2024 7:01                    IMPORTED   Active       No
# 2     3/19/2024 7:01                    IMPORTED   Active       No
# 3     3/19/2024 7:02                    IMPORTED   Active      Yes
# 4     3/19/2024 7:02                    IMPORTED   Active      Yes
# ...              ...               ...       ...      ...      ...
# 2714   8/1/2024 2:19                    IMPORTED   Active      Yes
# 2715   8/1/2024 2:19                    IMPORTED   Active      Yes
# 2716   8/1/2024 2:19                    IMPORTED   Active      Yes
# 2717   8/1/2024 2:19                    IMPORTED   Active      Yes
# 2718   8/1/2024 2:19                    IMPORTED   Active      Yes
#
#      Intervened By
# 0
# 1
# 2
# 3
# 4
# ...            ...
# 2714
# 2715
# 2716
# 2717
# 2718
#
# [2719 rows x 10 columns]

# %%
# get data gsheet

spreadsheet = gc.open_by_key(SHEET_ID)
worksheet = spreadsheet.worksheet(SHEET_NAME_3)
rows = worksheet.get_all_records()

# print(rows[:5])

# print('==============================')
df3 = pd.DataFrame(rows)
df3['Mobile Number'] = df3['Mobile Number'].apply(Fraction)
df3
# Out:
#                           Name  Mobile Number                           Tags  \
# 0    Tri Sabdo Pamungkas KG IT  6285250841919             Past inHouse Guest
# 1                 Agus Maryana   628122730101            Sample | Management
# 2             Mona Bartholomay   628113863499  Sample | Invalid | Management
# 3              Mahendra Temaja  6289607464993                     Management
# 4              David Scheckter   628113893039                     Management
# ..                         ...            ...                            ...
# 704               Hazem Sallam   201066557713           In House 2 August 24
# 705   Margaret Ellen Mathiesen    61405609363           In House 2 August 24
# 706                 Ran Feifei   628113088069           In House 2 August 24
# 707          Magomed Dzhamalov    79285999821           In House 2 August 24
# 708                 Krish Shah   919833460509           In House 2 August 24
#
#         Last Active       Joined On First Message Tag        Source Incoming  \
# 0                    3/22/2024 2:13                    Manual input   Active
# 1     4/9/2024 9:36  3/22/2024 2:14                    Manual Input   Active
# 2    4/12/2024 5:12  3/28/2024 1:53                                   Active
# 3                    3/28/2024 1:54                                   Active
# 4                    3/28/2024 1:54                                   Active
# ..              ...             ...               ...           ...      ...
# 704                   8/2/2024 1:10                        IMPORTED   Active
# 705                   8/2/2024 1:10                        IMPORTED   Active
# 706                   8/2/2024 1:10                        IMPORTED   Active
# 707                   8/2/2024 1:10                        IMPORTED   Active
# 708                   8/2/2024 1:10                        IMPORTED   Active
#
#     Opted In Intervened By
# 0        Yes
# 1        Yes
# 2        Yes
# 3        Yes
# 4        Yes
# ..       ...           ...
# 704      Yes
# 705      Yes
# 706      Yes
# 707      Yes
# 708      Yes
#
# [709 rows x 10 columns]

# %%
df_all = pd.concat([df,df2,df3], ignore_index=True)
df_all
# Out:
#                            Name  Mobile Number  \
# 0                     Tri Sabdo  6285250841919
# 1                Dave Scheckter   628113893039
# 2                         Shaun  6281138006892
# 3                   Rai Artawan  6281338016603
# 4                   Karma Beach  6281138305944
# ...                         ...            ...
# 19505              Hazem Sallam   201066557713
# 19506  Margaret Ellen Mathiesen    61405609363
# 19507                Ran Feifei   628113088069
# 19508         Magomed Dzhamalov    79285999821
# 19509                Krish Shah   919833460509
#
#                                                     Tags      Last Active  \
# 0               Past Purple Guest | KK_Valentine_12Feb24  12/15/2023 6:17
# 1                         Management | Past Purple Guest   7/23/2024 6:30
# 2                  Past Purple Guest | In House 7 May 24    8/1/2024 3:42
# 3      KK Sample Blast | Past Purple Guest | Beach En...    8/2/2024 0:10
# 4                                      Past Purple Guest
# ...                                                  ...              ...
# 19505                               In House 2 August 24
# 19506                               In House 2 August 24
# 19507                               In House 2 August 24
# 19508                               In House 2 August 24
# 19509                               In House 2 August 24
#
#              Joined On First Message Tag    Source Incoming Opted In  \
# 0      12/15/2023 5:53                     ORGANIC   Active      Yes
# 1      12/15/2023 6:12                     ORGANIC   Active      Yes
# 2      12/16/2023 6:30                     ORGANIC   Active      Yes
# 3      12/16/2023 6:32                     ORGANIC   Active      Yes
# 4      12/16/2023 8:26                               Active      Yes
# ...                ...               ...       ...      ...      ...
# 19505    8/2/2024 1:10                    IMPORTED   Active      Yes
# 19506    8/2/2024 1:10                    IMPORTED   Active      Yes
# 19507    8/2/2024 1:10                    IMPORTED   Active      Yes
# 19508    8/2/2024 1:10                    IMPORTED   Active      Yes
# 19509    8/2/2024 1:10                    IMPORTED   Active      Yes
#
#       Intervened By ZohoID Email    Country
# 0
# 1                                         -
# 2                                 Indonesia
# 3
# 4
# ...             ...    ...   ...        ...
# 19505                  NaN   NaN        NaN
# 19506                  NaN   NaN        NaN
# 19507                  NaN   NaN        NaN
# 19508                  NaN   NaN        NaN
# 19509                  NaN   NaN        NaN
#
# [19510 rows x 13 columns]

# %%
df_all.loc[df_all['Source'].str.contains('organic', regex=True, flags=re.I)]
# Out:
#                   Name  Mobile Number  \
# 0            Tri Sabdo  6285250841919
# 1       Dave Scheckter   628113893039
# 2                Shaun  6281138006892
# 3          Rai Artawan  6281338016603
# 558        Karan.Nagra   919592733130
# ...                ...            ...
# 18875  Goyal Madhurima   919986885250
# 18876    Bryan Whiting   447931789709
# 18877    Oki Ramadhana    62811150700
# 18951      Arya Wijaya  6285738679736
# 19253         Info Bri  6281393445510
#
#                                                     Tags      Last Active  \
# 0               Past Purple Guest | KK_Valentine_12Feb24  12/15/2023 6:17
# 1                         Management | Past Purple Guest   7/23/2024 6:30
# 2                  Past Purple Guest | In House 7 May 24    8/1/2024 3:42
# 3      KK Sample Blast | Past Purple Guest | Beach En...    8/2/2024 0:10
# 558             KK_Valentine_12Feb24 | Past Purple Guest  12/22/2023 7:55
# ...                                                  ...              ...
# 18875                                 Past inHouse Guest
# 18876                                 Past inHouse Guest
# 18877  In House 25 July 24 | Past inHouse Guest | In ...
# 18951                                                     6/29/2024 12:44
# 19253                                                      6/22/2024 7:29
#
#              Joined On First Message Tag   Source Incoming Opted In  \
# 0      12/15/2023 5:53                    ORGANIC   Active      Yes
# 1      12/15/2023 6:12                    ORGANIC   Active      Yes
# 2      12/16/2023 6:30                    ORGANIC   Active      Yes
# 3      12/16/2023 6:32                    ORGANIC   Active      Yes
# 558    12/22/2023 7:55                    ORGANIC   Active      Yes
# ...                ...               ...      ...      ...      ...
# 18875   4/16/2024 1:42                    ORGANIC   Active      Yes
# 18876   4/16/2024 1:42                    ORGANIC   Active      Yes
# 18877   4/16/2024 1:42                    ORGANIC   Active      Yes
# 18951    5/4/2024 3:05                    ORGANIC   Active      Yes
# 19253   6/22/2024 7:29                    ORGANIC   Active      Yes
#
#         Intervened By ZohoID Email    Country
# 0
# 1                                           -
# 2                                   Indonesia
# 3
# 558
# ...               ...    ...   ...        ...
# 18875                    NaN   NaN        NaN
# 18876                    NaN   NaN        NaN
# 18877                    NaN   NaN        NaN
# 18951  Guest Services    NaN   NaN        NaN
# 19253                    NaN   NaN        NaN
#
# [2576 rows x 13 columns]

# %%
m.clean_number(zoho_df, 'Phone')
m.replace_not_valid_to_empty(zoho_df, 'Phone')
zoho_df
# Out:
#                      Record Id     Created Time  \
# 0     zcrm_3584690000004718267  3/21/2019 16:18
# 1     zcrm_3584690000004742294  3/21/2019 13:49
# 2     zcrm_3584690000004918028  3/21/2019 20:39
# 3     zcrm_3584690000004950012   3/22/2019 5:05
# 4     zcrm_3584690000004950058   3/24/2019 1:56
# ...                        ...              ...
# 2794  zcrm_3584690000504195113   8/4/2024 11:32
# 2795  zcrm_3584690000504195152   8/4/2024 19:21
# 2796  zcrm_3584690000504204010   8/4/2024 14:15
# 2797  zcrm_3584690000504208001   8/3/2024 18:12
# 2798  zcrm_3584690000504222001   8/4/2024 19:10
#
#                                 Lead Source Description First Name  \
# 0     35% off Today with Karma Reservations | Webcha...    Pallavi
# 1     35% off Today with Karma Reservations | Webcha...   Abhijeet
# 2     35% off Today with Karma Reservations | Webcha...       Katy
# 3     35% off Today with Karma Reservations | Webcha...    Pauline
# 4     35% off Today with Karma Reservations | Webcha...   Geoffrey
# ...                                                 ...        ...
# 2794              Karma Reservations - WhatsApp Channel   Richelle
# 2795              Karma Reservations - WhatsApp Channel      Karin
# 2796              Karma Reservations - WhatsApp Channel       Sasa
# 2797              Karma Reservations - WhatsApp Channel          -
# 2798              Karma Reservations - WhatsApp Channel   ~Lloyd T
#
#             Last Name                      Email          Phone  \
# 0              Thakur   pallavithakur7@gmail.com     9820810812
# 1            Abhijeet  salokheabhijeet@gmail.com   971557459103
# 2                Katy      katy_lees@hotmail.com     7817075759
# 3               Snell     paulinesnell@yahoo.com    61427604080
# 4     Mark Hersch Dds     geoff@herschsmiles.com     9498136414
# ...               ...                        ...            ...
# 2794          Nitelet                      empty    16474569920
# 2795                -                      empty  6281223415689
# 2796            Bavec                      empty  6232477881588
# 2797                -                      empty          54302
# 2798                -                      empty    61402221462
#
#          Lead Brand Lead Sub-Brand       Lead Source Lead Locations  \
# 0       Karma Group          Other  WhatsApp Enquiry          empty
# 1       Karma Group          Other  WhatsApp Enquiry          empty
# 2       Karma Group          Other  WhatsApp Enquiry          empty
# 3       Karma Group          Other  WhatsApp Enquiry          empty
# 4       Karma Group          Other  WhatsApp Enquiry          empty
# ...             ...            ...               ...            ...
# 2794  Karma Resorts          Other  WhatsApp Enquiry     Karma Reef
# 2795  Karma Resorts          Other  WhatsApp Enquiry  Karma Kandara
# 2796  Karma Resorts          Other  WhatsApp Enquiry  Karma Kandara
# 2797  Karma Resorts          Other  WhatsApp Enquiry  Karma Kandara
# 2798  Karma Resorts          Other  WhatsApp Enquiry  Karma Kandara
#
#                                            Lead History
# 0                                                 empty
# 1                Other - Other,  Other India DB - Other
# 2                                                 empty
# 3     Other Bali DB - Wifi,  Other - Past Guests,  K...
# 4                                                 empty
# ...                                                 ...
# 2794                                             Others
# 2795  Interest for Karma Beach, entrance fee, hostin...
# 2796                          Reconfirm booking/payment
# 2797  Interest for Karma Beach, entrance fee, hostin...
# 2798                    Interest for Di Mare Restaurant
#
# [2799 rows x 12 columns]

# %%
zoho_df.loc[zoho_df['Phone'].isin(df['Mobile Number'])]
# Out:
# Empty DataFrame
# Columns: [Record Id, Created Time, Lead Source Description, First Name, Last Name, Email, Phone, Lead Brand, Lead Sub-Brand, Lead Source, Lead Locations, Lead History]
# Index: []
