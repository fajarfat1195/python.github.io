# %%
import sys

sys.path.append('../zoho_data_app')

import main_module as m
import zoho_filter_module as fil
import pandas as pd
import re
import numpy as np

import glob

# %load_ext autoreload
# %autoreload 2

# download semua report 63 di vp
# download 2x berdasarkan servicing office yang non-india dan india 

file_loc = r'C:\Users\fajar.fatoni\Documents\Python\Data\Booking Data\1202115-TravelDetails.xlsx'

# %%
excel_file = pd.ExcelFile(file_loc)
sheet_names = excel_file.sheet_names
frames = []
count = 0
for sheet in sheet_names:
    count += 1
    print(f"Compiling {sheet}")
    if sheet == 'Sheet1':
        globals()['df%s' % count]= pd.read_excel(file_loc, sheet_name=sheet, dtype='string')
        globals()['column'] = globals()['df%s' % count].columns.to_list()
    else:
        globals()['df%s' % count]= pd.read_excel(file_loc, sheet_name=sheet, dtype='string', header=None)
        globals()['df%s' % count].columns = globals()['column']

    frames.append(globals()['df%s' % count])

result = pd.concat(frames, ignore_index=True)

result.drop(result.loc[result['Status'].isna()].index, inplace=True)
result
# Out:
# Compiling Sheet1
# Compiling Sheet2
# Compiling Sheet3
# Compiling Sheet4
#        Member #        Status Account Type                   First Name  \
# 1       1075018        ACTIVE      CONTACT        Benn, Geoffrey & Anne
# 2       1092339        ACTIVE      CONTACT                        Laura
# 3       1100098        ACTIVE      CONTACT  Hughes, Ronald & Evangeline
# 4       1109952        ACTIVE      CONTACT                       sergei
# 5       1114214        ACTIVE      CONTACT                 Dinesh Kumar
# ...         ...           ...          ...                          ...
# 213917  1240497        ACTIVE      CONTACT                        Becky
# 213918  1240497        ACTIVE      CONTACT                        Becky
# 213919  1239719        ACTIVE      CONTACT                      Charles
# 213920   813205        ACTIVE        STAFF                         Mike
# 213922      krg  Fajar Fatoni          113                         <NA>
#
#            LastName Booking # Source              Arrival  \
# 1              <NA>   2263023  HOTEL  2023-11-01 00:00:00
# 2            Schlag   2205677    FVO  2023-11-01 00:00:00
# 3              <NA>   2166117  HOTEL  2023-11-01 00:00:00
# 4            zotkin   2349507    FVO  2023-11-01 00:00:00
# 5       Balal Patel   2223490   GMBR  2023-11-01 00:00:00
# ...             ...       ...    ...                  ...
# 213917       Walker   2770382  HOTEL  2026-04-26 00:00:00
# 213918       Walker   2770383  HOTEL  2026-04-26 00:00:00
# 213919       Powell   2928441  HOTEL  2026-05-12 00:00:00
# 213920        Evans   2714673  STAFF  2026-05-14 00:00:00
# 213922         <NA>      <NA>   <NA>                 <NA>
#
#                   Departure                        Resort Name  \
# 1       2023-11-07 00:00:00  Wyndham -  Manoir des Deux Amants
# 2       2023-11-04 00:00:00                      Karma Bavaria
# 3       2023-11-06 00:00:00  Wyndham -  Manoir des Deux Amants
# 4       2023-12-01 00:00:00                     Karma Jimbaran
# 5       2023-11-04 00:00:00               Karma Chakra, Kerala
# ...                     ...                                ...
# 213917  2026-04-27 00:00:00                   Karma La Herriza
# 213918  2026-04-27 00:00:00                   Karma La Herriza
# 213919  2026-05-15 00:00:00                   Karma La Herriza
# 213920  2026-06-25 00:00:00                       Karma Karnak
# 213922                 <NA>                               <NA>
#
#                                Email    GuestCountry Airport Pick up  \
# 1             ANNE_BENN@YAHOO.COM.AU            <NA>            <NA>
# 2            lauraschlag87@gmail.com         Germany            <NA>
# 3                RONHFIRE1@GMAIL.COM            <NA>            <NA>
# 4                           sz@i1.ru          Russia            <NA>
# 5           dineshkb.patel@gmail.com           India            <NA>
# ...                              ...             ...             ...
# 213917  reception@karmalaherriza.com  United Kingdom            <NA>
# 213918  reception@karmalaherriza.com  United Kingdom            <NA>
# 213919  reception@karmalaherriza.com  United Kingdom            <NA>
# 213920     mike.evans@karmagroup.com         England            <NA>
# 213922                          <NA>            <NA>            <NA>
#
#        Flight Details Flight Arrival Modify Date         DepartmentName
# 1                <NA>           <NA>        <NA>                   <NA>
# 2                <NA>           <NA>        <NA>           KARMA OWNERS
# 3                <NA>           <NA>        <NA>                   <NA>
# 4                <NA>           <NA>        <NA>             K JIMBARAN
# 5                <NA>           <NA>        <NA>  KARMA CONCIERGE - Goa
# ...               ...            ...         ...                    ...
# 213917           <NA>           <NA>        <NA>           K LA HERRIZA
# 213918           <NA>           <NA>        <NA>           K LA HERRIZA
# 213919           <NA>           <NA>        <NA>           K LA HERRIZA
# 213920           <NA>           <NA>        <NA>      INVENTORY CONTROL
# 213922           <NA>           <NA>        <NA>                   <NA>
#
# [213889 rows x 17 columns]

# %%
df_final = pd.concat([result], ignore_index=True)
df_final.fillna('empty', inplace=True)
df_final
# Out:
#        Member #        Status Account Type                   First Name  \
# 0       1075018        ACTIVE      CONTACT        Benn, Geoffrey & Anne
# 1       1092339        ACTIVE      CONTACT                        Laura
# 2       1100098        ACTIVE      CONTACT  Hughes, Ronald & Evangeline
# 3       1109952        ACTIVE      CONTACT                       sergei
# 4       1114214        ACTIVE      CONTACT                 Dinesh Kumar
# ...         ...           ...          ...                          ...
# 213884  1240497        ACTIVE      CONTACT                        Becky
# 213885  1240497        ACTIVE      CONTACT                        Becky
# 213886  1239719        ACTIVE      CONTACT                      Charles
# 213887   813205        ACTIVE        STAFF                         Mike
# 213888      krg  Fajar Fatoni          113                        empty
#
#            LastName Booking # Source              Arrival  \
# 0             empty   2263023  HOTEL  2023-11-01 00:00:00
# 1            Schlag   2205677    FVO  2023-11-01 00:00:00
# 2             empty   2166117  HOTEL  2023-11-01 00:00:00
# 3            zotkin   2349507    FVO  2023-11-01 00:00:00
# 4       Balal Patel   2223490   GMBR  2023-11-01 00:00:00
# ...             ...       ...    ...                  ...
# 213884       Walker   2770382  HOTEL  2026-04-26 00:00:00
# 213885       Walker   2770383  HOTEL  2026-04-26 00:00:00
# 213886       Powell   2928441  HOTEL  2026-05-12 00:00:00
# 213887        Evans   2714673  STAFF  2026-05-14 00:00:00
# 213888        empty     empty  empty                empty
#
#                   Departure                        Resort Name  \
# 0       2023-11-07 00:00:00  Wyndham -  Manoir des Deux Amants
# 1       2023-11-04 00:00:00                      Karma Bavaria
# 2       2023-11-06 00:00:00  Wyndham -  Manoir des Deux Amants
# 3       2023-12-01 00:00:00                     Karma Jimbaran
# 4       2023-11-04 00:00:00               Karma Chakra, Kerala
# ...                     ...                                ...
# 213884  2026-04-27 00:00:00                   Karma La Herriza
# 213885  2026-04-27 00:00:00                   Karma La Herriza
# 213886  2026-05-15 00:00:00                   Karma La Herriza
# 213887  2026-06-25 00:00:00                       Karma Karnak
# 213888                empty                              empty
#
#                                Email    GuestCountry Airport Pick up  \
# 0             ANNE_BENN@YAHOO.COM.AU           empty           empty
# 1            lauraschlag87@gmail.com         Germany           empty
# 2                RONHFIRE1@GMAIL.COM           empty           empty
# 3                           sz@i1.ru          Russia           empty
# 4           dineshkb.patel@gmail.com           India           empty
# ...                              ...             ...             ...
# 213884  reception@karmalaherriza.com  United Kingdom           empty
# 213885  reception@karmalaherriza.com  United Kingdom           empty
# 213886  reception@karmalaherriza.com  United Kingdom           empty
# 213887     mike.evans@karmagroup.com         England           empty
# 213888                         empty           empty           empty
#
#        Flight Details Flight Arrival Modify Date         DepartmentName
# 0               empty          empty       empty                  empty
# 1               empty          empty       empty           KARMA OWNERS
# 2               empty          empty       empty                  empty
# 3               empty          empty       empty             K JIMBARAN
# 4               empty          empty       empty  KARMA CONCIERGE - Goa
# ...               ...            ...         ...                    ...
# 213884          empty          empty       empty           K LA HERRIZA
# 213885          empty          empty       empty           K LA HERRIZA
# 213886          empty          empty       empty           K LA HERRIZA
# 213887          empty          empty       empty      INVENTORY CONTROL
# 213888          empty          empty       empty                  empty
#
# [213889 rows x 17 columns]

# %%
# data phone, mobile dam email member yang ada di master data (wash member)
df_final['Email'] = m.lowercase(df_final, 'Email')
m.clean_space(df_final, 'Email')
m.clean_not_valid_email_format(df_final, 'Email')
# Out:
# c:\Users\fajar.fatoni\Documents\Python\Task Offline\booking_data_app\../zoho_data_app\main_module.py:127: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[df_columns].replace(' ','', regex=True, inplace=True)
# 'Email'

# %%
df_final.replace('empty', '', inplace=True)
df_final
# Out:
#        Member #        Status Account Type                   First Name  \
# 0       1075018        ACTIVE      CONTACT        Benn, Geoffrey & Anne
# 1       1092339        ACTIVE      CONTACT                        Laura
# 2       1100098        ACTIVE      CONTACT  Hughes, Ronald & Evangeline
# 3       1109952        ACTIVE      CONTACT                       sergei
# 4       1114214        ACTIVE      CONTACT                 Dinesh Kumar
# ...         ...           ...          ...                          ...
# 213884  1240497        ACTIVE      CONTACT                        Becky
# 213885  1240497        ACTIVE      CONTACT                        Becky
# 213886  1239719        ACTIVE      CONTACT                      Charles
# 213887   813205        ACTIVE        STAFF                         Mike
# 213888      krg  Fajar Fatoni          113
#
#            LastName Booking # Source              Arrival  \
# 0                     2263023  HOTEL  2023-11-01 00:00:00
# 1            Schlag   2205677    FVO  2023-11-01 00:00:00
# 2                     2166117  HOTEL  2023-11-01 00:00:00
# 3            zotkin   2349507    FVO  2023-11-01 00:00:00
# 4       Balal Patel   2223490   GMBR  2023-11-01 00:00:00
# ...             ...       ...    ...                  ...
# 213884       Walker   2770382  HOTEL  2026-04-26 00:00:00
# 213885       Walker   2770383  HOTEL  2026-04-26 00:00:00
# 213886       Powell   2928441  HOTEL  2026-05-12 00:00:00
# 213887        Evans   2714673  STAFF  2026-05-14 00:00:00
# 213888
#
#                   Departure                        Resort Name  \
# 0       2023-11-07 00:00:00  Wyndham -  Manoir des Deux Amants
# 1       2023-11-04 00:00:00                      Karma Bavaria
# 2       2023-11-06 00:00:00  Wyndham -  Manoir des Deux Amants
# 3       2023-12-01 00:00:00                     Karma Jimbaran
# 4       2023-11-04 00:00:00               Karma Chakra, Kerala
# ...                     ...                                ...
# 213884  2026-04-27 00:00:00                   Karma La Herriza
# 213885  2026-04-27 00:00:00                   Karma La Herriza
# 213886  2026-05-15 00:00:00                   Karma La Herriza
# 213887  2026-06-25 00:00:00                       Karma Karnak
# 213888
#
#                                Email    GuestCountry Airport Pick up  \
# 0             anne_benn@yahoo.com.au
# 1            lauraschlag87@gmail.com         Germany
# 2                ronhfire1@gmail.com
# 3                           sz@i1.ru          Russia
# 4           dineshkb.patel@gmail.com           India
# ...                              ...             ...             ...
# 213884  reception@karmalaherriza.com  United Kingdom
# 213885  reception@karmalaherriza.com  United Kingdom
# 213886  reception@karmalaherriza.com  United Kingdom
# 213887     mike.evans@karmagroup.com         England
# 213888
#
#        Flight Details Flight Arrival Modify Date         DepartmentName
# 0
# 1                                                          KARMA OWNERS
# 2
# 3                                                            K JIMBARAN
# 4                                                 KARMA CONCIERGE - Goa
# ...               ...            ...         ...                    ...
# 213884                                                     K LA HERRIZA
# 213885                                                     K LA HERRIZA
# 213886                                                     K LA HERRIZA
# 213887                                                INVENTORY CONTROL
# 213888
#
# [213889 rows x 17 columns]

# %%
df_final.to_csv(r'C:\Users\fajar.fatoni\Documents\Python\Data\Booking Data\compiled_booking.csv', index=False)
