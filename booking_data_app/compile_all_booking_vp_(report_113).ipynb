# %%
import sys

sys.path.append('../zoho_data_app')

import main_module as m
import zoho_filter_module as fil
import pandas as pd
import re
import numpy as np

import glob

# %load_ext autoreload
# %autoreload 2

# download semua report 63 di vp
# download 2x berdasarkan servicing office yang non-india dan india 

file_loc = r'C:\Users\fajar.fatoni\Documents\Python\Data\Booking Data\1198207-TravelDetails.xlsx'
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
excel_file = pd.ExcelFile(file_loc)
sheet_names = excel_file.sheet_names
frames = []
count = 0
for sheet in sheet_names:
    count += 1
    print(f"Compiling {sheet}")
    if sheet == 'Sheet1':
        globals()['df%s' % count]= pd.read_excel(file_loc, sheet_name=sheet, dtype='string')
        globals()['column'] = globals()['df%s' % count].columns.to_list()
    else:
        globals()['df%s' % count]= pd.read_excel(file_loc, sheet_name=sheet, dtype='string', header=None)
        globals()['df%s' % count].columns = globals()['column']

    frames.append(globals()['df%s' % count])

result = pd.concat(frames, ignore_index=True)

result.drop(result.loc[result['Status'].isna()].index, inplace=True)
result
# Out:
# Compiling Sheet1
# Compiling Sheet2
# Compiling Sheet3
#        Member #        Status           Account Type              First Name  \
# 1       1165195        ACTIVE                CONTACT               Abhilasha
# 2       1165195        ACTIVE                CONTACT               Abhilasha
# 3       1172136        ACTIVE                CONTACT                  KOESIO
# 4       1173898        ACTIVE                  STAFF                   Dario
# 5       1173954        ACTIVE                CONTACT  Schoenfisch, Ekaterina
# ...         ...           ...                    ...                     ...
# 166642   770237        ACTIVE                    GAP        Nicholas Leonard
# 166643  1261702        ACTIVE  KARMA CLUB EXPERIENCE            Maria Divina
# 166644   813205        ACTIVE                  STAFF                    Mike
# 166645  1262331        ACTIVE                CONTACT                   Maria
# 166647      krg  Fajar Fatoni                    113                    <NA>
#
#           LastName Booking # Source              Arrival            Departure  \
# 1       Khushalani   2473572   GMBR  2024-04-14 00:00:00  2024-04-17 00:00:00
# 2       Khushalani   2442133   GMBR  2024-04-14 00:00:00  2024-04-17 00:00:00
# 3                .   2470389  HOTEL  2024-04-14 00:00:00  2024-04-18 00:00:00
# 4        Quinteros   2477117  STAFF  2024-04-14 00:00:00  2024-04-22 00:00:00
# 5             <NA>   2477188  HOTEL  2024-04-14 00:00:00  2024-04-17 00:00:00
# ...            ...       ...    ...                  ...                  ...
# 166642      Harris   2801763    EXT  2026-03-07 00:00:00  2026-03-21 00:00:00
# 166643   De Guzman   2958092    FBW  2026-04-01 00:00:00  2026-04-08 00:00:00
# 166644       Evans   2714672  STAFF  2026-04-02 00:00:00  2026-05-14 00:00:00
# 166645     Kovacic   2963182    FBW  2026-04-10 00:00:00  2026-04-15 00:00:00
# 166647        <NA>      <NA>   <NA>                 <NA>                 <NA>
#
#                               Resort Name                          Email  \
# 1              Karma Seven Lakes, Udaipur   abhilasha.gpurohit@gmail.com
# 2              Karma Seven Lakes, Udaipur   abhilasha.gpurohit@gmail.com
# 3       Wyndham -  Manoir des Deux Amants                    booking.com
# 4                Karma Royal Haathi Mahal                           <NA>
# 5       Wyndham -  Manoir des Deux Amants                    Booking.com
# ...                                   ...                            ...
# 166642                  Karma Royal Palms  nick.harris050@btinternet.com
# 166643              Amina Lantana, Hoi An           dek2212000@yahoo.com
# 166644                       Karma Karnak                           <NA>
# 166645       KRR @ Karma Kandara, Phase V          mariakovo@bigpond.com
# 166647                               <NA>                           <NA>
#
#        GuestCountry Airport Pick up Flight Details Flight Arrival  \
# 1             India            <NA>           <NA>           <NA>
# 2             India    Not Required     self drive           <NA>
# 3            France            <NA>           <NA>           <NA>
# 4             India            <NA>           <NA>           <NA>
# 5              <NA>            <NA>           <NA>           <NA>
# ...             ...             ...            ...            ...
# 166642        Spain            <NA>           <NA>           <NA>
# 166643    Australia            <NA>           <NA>           <NA>
# 166644         <NA>            <NA>           <NA>           <NA>
# 166645    Australia            <NA>           <NA>           <NA>
# 166647         <NA>            <NA>           <NA>           <NA>
#
#                 Modify Date                DepartmentName
# 1                      <NA>         KARMA CONCIERGE - Goa
# 2       2024-03-30 00:00:00   KARMA CONCIERGE - Bengaluru
# 3                      <NA>                          <NA>
# 4                      <NA>        SPACE MANAGEMENT INDIA
# 5                      <NA>                          <NA>
# ...                     ...                           ...
# 166642                 <NA>         SPACE MANAGEMENT BALI
# 166643                 <NA>  MARKETING OFFICE - Bengaluru
# 166644                 <NA>             INVENTORY CONTROL
# 166645                 <NA>  MARKETING OFFICE - Bengaluru
# 166647                 <NA>                          <NA>
#
# [166617 rows x 17 columns]

# %%
df_final = pd.concat([result], ignore_index=True)
df_final.fillna('empty', inplace=True)
df_final
# Out:
#        Member #        Status           Account Type              First Name  \
# 0       1165195        ACTIVE                CONTACT               Abhilasha
# 1       1165195        ACTIVE                CONTACT               Abhilasha
# 2       1172136        ACTIVE                CONTACT                  KOESIO
# 3       1173898        ACTIVE                  STAFF                   Dario
# 4       1173954        ACTIVE                CONTACT  Schoenfisch, Ekaterina
# ...         ...           ...                    ...                     ...
# 166612   770237        ACTIVE                    GAP        Nicholas Leonard
# 166613  1261702        ACTIVE  KARMA CLUB EXPERIENCE            Maria Divina
# 166614   813205        ACTIVE                  STAFF                    Mike
# 166615  1262331        ACTIVE                CONTACT                   Maria
# 166616      krg  Fajar Fatoni                    113                   empty
#
#           LastName Booking # Source              Arrival            Departure  \
# 0       Khushalani   2473572   GMBR  2024-04-14 00:00:00  2024-04-17 00:00:00
# 1       Khushalani   2442133   GMBR  2024-04-14 00:00:00  2024-04-17 00:00:00
# 2                .   2470389  HOTEL  2024-04-14 00:00:00  2024-04-18 00:00:00
# 3        Quinteros   2477117  STAFF  2024-04-14 00:00:00  2024-04-22 00:00:00
# 4            empty   2477188  HOTEL  2024-04-14 00:00:00  2024-04-17 00:00:00
# ...            ...       ...    ...                  ...                  ...
# 166612      Harris   2801763    EXT  2026-03-07 00:00:00  2026-03-21 00:00:00
# 166613   De Guzman   2958092    FBW  2026-04-01 00:00:00  2026-04-08 00:00:00
# 166614       Evans   2714672  STAFF  2026-04-02 00:00:00  2026-05-14 00:00:00
# 166615     Kovacic   2963182    FBW  2026-04-10 00:00:00  2026-04-15 00:00:00
# 166616       empty     empty  empty                empty                empty
#
#                               Resort Name                          Email  \
# 0              Karma Seven Lakes, Udaipur   abhilasha.gpurohit@gmail.com
# 1              Karma Seven Lakes, Udaipur   abhilasha.gpurohit@gmail.com
# 2       Wyndham -  Manoir des Deux Amants                    booking.com
# 3                Karma Royal Haathi Mahal                          empty
# 4       Wyndham -  Manoir des Deux Amants                    Booking.com
# ...                                   ...                            ...
# 166612                  Karma Royal Palms  nick.harris050@btinternet.com
# 166613              Amina Lantana, Hoi An           dek2212000@yahoo.com
# 166614                       Karma Karnak                          empty
# 166615       KRR @ Karma Kandara, Phase V          mariakovo@bigpond.com
# 166616                              empty                          empty
#
#        GuestCountry Airport Pick up Flight Details Flight Arrival  \
# 0             India           empty          empty          empty
# 1             India    Not Required     self drive          empty
# 2            France           empty          empty          empty
# 3             India           empty          empty          empty
# 4             empty           empty          empty          empty
# ...             ...             ...            ...            ...
# 166612        Spain           empty          empty          empty
# 166613    Australia           empty          empty          empty
# 166614        empty           empty          empty          empty
# 166615    Australia           empty          empty          empty
# 166616        empty           empty          empty          empty
#
#                 Modify Date                DepartmentName
# 0                     empty         KARMA CONCIERGE - Goa
# 1       2024-03-30 00:00:00   KARMA CONCIERGE - Bengaluru
# 2                     empty                         empty
# 3                     empty        SPACE MANAGEMENT INDIA
# 4                     empty                         empty
# ...                     ...                           ...
# 166612                empty         SPACE MANAGEMENT BALI
# 166613                empty  MARKETING OFFICE - Bengaluru
# 166614                empty             INVENTORY CONTROL
# 166615                empty  MARKETING OFFICE - Bengaluru
# 166616                empty                         empty
#
# [166617 rows x 17 columns]

# %%
# data phone, mobile dam email member yang ada di master data (wash member)
df_final['Email'] = m.lowercase(df_final, 'Email')
m.clean_space(df_final, 'Email')
m.clean_not_valid_email_format(df_final, 'Email')
# Out:
# c:\Users\fajar.fatoni\Documents\Python\Task Offline\booking_data_app\../zoho_data_app\main_module.py:127: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[df_columns].replace(' ','', regex=True, inplace=True)
# 'Email'

# %%
df_final.replace('empty', '', inplace=True)
df_final
# Out:
#        Member #        Status           Account Type              First Name  \
# 0       1165195        ACTIVE                CONTACT               Abhilasha
# 1       1165195        ACTIVE                CONTACT               Abhilasha
# 2       1172136        ACTIVE                CONTACT                  KOESIO
# 3       1173898        ACTIVE                  STAFF                   Dario
# 4       1173954        ACTIVE                CONTACT  Schoenfisch, Ekaterina
# ...         ...           ...                    ...                     ...
# 166612   770237        ACTIVE                    GAP        Nicholas Leonard
# 166613  1261702        ACTIVE  KARMA CLUB EXPERIENCE            Maria Divina
# 166614   813205        ACTIVE                  STAFF                    Mike
# 166615  1262331        ACTIVE                CONTACT                   Maria
# 166616      krg  Fajar Fatoni                    113
#
#           LastName Booking # Source              Arrival            Departure  \
# 0       Khushalani   2473572   GMBR  2024-04-14 00:00:00  2024-04-17 00:00:00
# 1       Khushalani   2442133   GMBR  2024-04-14 00:00:00  2024-04-17 00:00:00
# 2                .   2470389  HOTEL  2024-04-14 00:00:00  2024-04-18 00:00:00
# 3        Quinteros   2477117  STAFF  2024-04-14 00:00:00  2024-04-22 00:00:00
# 4                    2477188  HOTEL  2024-04-14 00:00:00  2024-04-17 00:00:00
# ...            ...       ...    ...                  ...                  ...
# 166612      Harris   2801763    EXT  2026-03-07 00:00:00  2026-03-21 00:00:00
# 166613   De Guzman   2958092    FBW  2026-04-01 00:00:00  2026-04-08 00:00:00
# 166614       Evans   2714672  STAFF  2026-04-02 00:00:00  2026-05-14 00:00:00
# 166615     Kovacic   2963182    FBW  2026-04-10 00:00:00  2026-04-15 00:00:00
# 166616
#
#                               Resort Name                          Email  \
# 0              Karma Seven Lakes, Udaipur   abhilasha.gpurohit@gmail.com
# 1              Karma Seven Lakes, Udaipur   abhilasha.gpurohit@gmail.com
# 2       Wyndham -  Manoir des Deux Amants                    booking.com
# 3                Karma Royal Haathi Mahal
# 4       Wyndham -  Manoir des Deux Amants                    booking.com
# ...                                   ...                            ...
# 166612                  Karma Royal Palms  nick.harris050@btinternet.com
# 166613              Amina Lantana, Hoi An           dek2212000@yahoo.com
# 166614                       Karma Karnak
# 166615       KRR @ Karma Kandara, Phase V          mariakovo@bigpond.com
# 166616
#
#        GuestCountry Airport Pick up Flight Details Flight Arrival  \
# 0             India
# 1             India    Not Required     self drive
# 2            France
# 3             India
# 4
# ...             ...             ...            ...            ...
# 166612        Spain
# 166613    Australia
# 166614
# 166615    Australia
# 166616
#
#                 Modify Date                DepartmentName
# 0                                   KARMA CONCIERGE - Goa
# 1       2024-03-30 00:00:00   KARMA CONCIERGE - Bengaluru
# 2
# 3                                  SPACE MANAGEMENT INDIA
# 4
# ...                     ...                           ...
# 166612                              SPACE MANAGEMENT BALI
# 166613                       MARKETING OFFICE - Bengaluru
# 166614                                  INVENTORY CONTROL
# 166615                       MARKETING OFFICE - Bengaluru
# 166616
#
# [166617 rows x 17 columns]

# %%
df_final.to_csv(r'C:\Users\fajar.fatoni\Documents\Python\Data\Booking Data\compiled_booking.csv', index=False)
