# %%
# CARA INI HANYA EFEKTIF DILAKUKAN JIKA SEMUA KOLOM DI SETIAP SHEET FROMATNYA SUDAH SAMA
# JIKA FORMATNYA KOLOMNYA BERBEDA, LAKUKAN DENGAN CARA SEPERTI DI edm_plan_app

import pandas as pd

file_path = r'C:\Users\fajar\Documents\Python\Data\Member Data\inner sanctum\KS Inner Sanctum NEW MEMBERSHIP LIST updated 2024.xlsx'

# %%
all_dfs = pd.read_excel(file_path, sheet_name=None)
df = pd.concat(all_dfs, keys=all_dfs,
    names=['Sheets Name', None],
    ).reset_index(level='Sheets Name')   
df.reset_index(drop=True, inplace=True)
df
# Out:
#                           Sheets Name Card number TITLE First name  \
# 0     Investors & Family,close friend       10018  Miss        Kas
# 1     Investors & Family,close friend       10027  Miss      Clare
# 2     Investors & Family,close friend       10040  Miss     Ashley
# 3     Investors & Family,close friend       10045    MR       CRIS
# 4     Investors & Family,close friend       10051    Mr   Stephan
# ...                               ...         ...   ...        ...
# 2620             Community Membership         NaN   NaN       Bath
# 2621             Community Membership         NaN   NaN       Katy
# 2622             Community Membership         NaN   NaN     Sophie
# 2623             Community Membership         NaN   NaN      Emily
# 2624             Community Membership         NaN   NaN       Gift
#
#             Surname                              Email       Phone  \
# 0            Mercer  kas.mercer@mercenarypublicity.com  7904157720
# 1             Baker    clare.baker@absoluteradio.co.uk  7739963496
# 2           Roberts           butterflymuzak@gmail.com  7563300230
# 3         CICIRELLO          criscicirello@hotmail.com  7780688769
# 4     von Schilling                                NaN         NaN
# ...             ...                                ...         ...
# 2620        Watling                 beth@playfuluk.com         NaN
# 2621          Eynon                 katy@playfuluk.com         NaN
# 2622          Beard               sophie@playfuluk.com         NaN
# 2623           Hall               emilyh@playfuluk.com         NaN
# 2624         Onomor                 gift@playfuluk.com         NaN
#
#      Date of Birth Contacted via email Unnamed: 8  ... Date Issued Inv    F  \
# 0            23.07                 NaN         MK  ...         NaN NaN  NaN
# 1             2.01                 NaN         MK  ...         NaN NaN  NaN
# 2            14.09                 NaN         MK  ...         NaN NaN  NaN
# 3           11.10'           COLLECTED         MK  ...         NaN NaN  NaN
# 4              NaN              POSTED        NaN  ...         NaN NaN  NaN
# ...            ...                 ...        ...  ...         ...  ..  ...
# 2620           NaN                 NaN        NaN  ...         NaN NaN  NaN
# 2621           NaN                 NaN        NaN  ...         NaN NaN  NaN
# 2622           NaN                 NaN        NaN  ...         NaN NaN  NaN
# 2623           NaN                 NaN        NaN  ...         NaN NaN  NaN
# 2624           NaN                 NaN        NaN  ...         NaN NaN  NaN
#
#      Unnamed: 14 Unnamed: 16 Unnamed: 17 Card Number    NAME CAST   \
# 0            NaN         NaN         NaN         NaN           NaN
# 1            NaN         NaN         NaN         NaN           NaN
# 2            NaN         NaN         NaN         NaN           NaN
# 3            NaN         NaN         NaN         NaN           NaN
# 4            NaN         NaN         NaN         NaN           NaN
# ...          ...         ...         ...         ...           ...
# 2620         NaN         NaN         NaN        O178  Bath Watling
# 2621         NaN         NaN         NaN        O940    Katy Eynon
# 2622         NaN         NaN         NaN        O939  Sophie Beard
# 2623         NaN         NaN         NaN        O938    Emily Hall
# 2624         NaN         NaN         NaN        O937   Gift Onomor
#
#       START DATE    END DATE
# 0            NaN         NaN
# 1            NaN         NaN
# 2            NaN         NaN
# 3            NaN         NaN
# 4            NaN         NaN
# ...          ...         ...
# 2620  02.03.2024  02.03.2025
# 2621  02.03.2024  02.03.2025
# 2622  02.03.2024  02.03.2025
# 2623  02.03.2024  02.03.2025
# 2624  02.03.2024  02.03.2025
#
# [2625 rows x 33 columns]

# %%
df.to_excel(r'C:\Users\fajar\Documents\Python\Data\Member Data\inner sanctum\compiled_file.xlsx', index=False)
