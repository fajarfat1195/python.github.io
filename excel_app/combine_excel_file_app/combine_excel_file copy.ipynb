# %%
import os
import pandas as pd
import re
 
# Get the list of all files and directories
# dir_path = "C://Users//Vanshi//Desktop//gfg"
dir_path = r"C:\Users\fajar.fatoni\Documents\Python\Data\Member Data\vp\report 119 all details\17 Mar\compile"

# dir_list = os.listdir(dir_path)
 
# print("Files and directories in '", dir_path, "' :")
 
# # prints all files
# print(dir_list)

frames = []

# itterate file di dalam directory
for path in os.listdir(dir_path):

    # cek apakah di dalam directory ada file
    if os.path.isfile(os.path.join(dir_path, path)):
        if ".xlsx" in path:
            print(path)
            df = pd.read_excel(dir_path+'\\'+path, dtype='string')
            df['filename'] = path
            frames.append(df)

        if ".csv" in path:
            print(path)
            df = pd.read_csv(dir_path+'\\'+path, dtype='string', on_bad_lines='skip')
            df['filename'] = path
            frames.append(df)
    else:
        print('file doesn\'t exist')

result = pd.concat(frames, ignore_index=True)
result
# Out:
# 119 - kcb.xlsx
# 119 - kci.xlsx
#       Account ID ContactID           FirstName     LastName  \
# 0        1000056    921274             Yohanes      Mustamu
# 1        1000056    921301                Jane  Chrisdianty
# 2        1000056    921274             Yohanes      Mustamu
# 3        1000109    921347  Willy Stevan Berny         Suak
# 4        1000109    921354      Cecilia Ingrid         Tjan
# ...          ...       ...                 ...          ...
# 99444      53032     57165              Samuel        Jacob
# 99445      53044     57178            M. Anand      Krishna
# 99446      53044    183697        K.N. Savitha        Anand
# 99447      53044    934334            Akshatha        Anand
# 99448      53044    934335            Sharvari        Anand
#
#                                        AddressLine1  \
# 0                      WELLINGTON RESIDENCE BLOK A1
# 1                      WELLINGTON RESIDENCE BLOK A1
# 2                      WELLINGTON RESIDENCE BLOK A1
# 3                JL. KEMBANG NO 59, SARIO KOTA BARU
# 4                JL. KEMBANG NO 59, SARIO KOTA BARU
# ...                                             ...
# 99444                 #12, MARUTHI MEADOWS CROSSOPP
# 99445    ARCHITHA AITHAL AAROHI APARTMENT, FLAT#403
# 99446  ARCHITHA AITHAL AAROHI APARTMENT, FLAT #403,
# 99447  ARCHITHA AITHAL AAROHI APARTMENT, FLAT #403,
# 99448  ARCHITHA AITHAL AAROHI APARTMENT, FLAT #403,
#
#                                             AddressLine2               Town  \
# 0                       RT. 009/009 BENDA BARU, PAMULANG  TANGERANG SELATAN
# 1                       RT. 009/009 BENDA BARU, PAMULANG  TANGERANG SELATAN
# 2                       RT. 009/009 BENDA BARU, PAMULANG  TANGERANG SELATAN
# 3                                                   <NA>             MANADO
# 4                                                   <NA>             MANADO
# ...                                                  ...                ...
# 99444                           S.A.B.C. GATE,  KOTHANUR          BENGALURU
# 99445  SRI THIRUCHI MAHASWAMY ROAD, RAJARAJESHWARI NAGAR          BENGALURU
# 99446   SRI THIRUCHI MAHASWAMY ROAD, RAJARAJESWARI NAGAR          BENGALURU
# 99447   SRI THIRUCHI MAHASWAMY ROAD, RAJARAJESWARI NAGAR          BENGALURU
# 99448   SRI THIRUCHI MAHASWAMY ROAD, RAJARAJESWARI NAGAR          BENGALURU
#
#                  City    Country Post Code  ... No_Concierge_EDM  \
# 0              BANTEN  Indonesia     15417  ...             <NA>
# 1              BANTEN  Indonesia         -  ...             <NA>
# 2              BANTEN  Indonesia     15417  ...             <NA>
# 3      SULAWESI UTARA  Indonesia     95114  ...             <NA>
# 4      SULAWESI UTARA  Indonesia     95114  ...             <NA>
# ...               ...        ...       ...  ...              ...
# 99444       KARNATAKA      India   560 077  ...             <NA>
# 99445       KARNATAKA      India    560098  ...             <NA>
# 99446       KARNATAKA      India    560098  ...             <NA>
# 99447       KARNATAKA      India    560098  ...             <NA>
# 99448       KARNATAKA      India    560098  ...             <NA>
#
#       No_Events_EDM No_Community_EDM No_MC_EDM CreateDateTime  \
# 0              <NA>             <NA>      <NA>           <NA>
# 1              <NA>             <NA>      <NA>           <NA>
# 2              <NA>             <NA>      <NA>           <NA>
# 3              <NA>             <NA>      <NA>           <NA>
# 4              <NA>             <NA>      <NA>           <NA>
# ...             ...              ...       ...            ...
# 99444          <NA>             <NA>      <NA>           <NA>
# 99445          <NA>             <NA>      <NA>           <NA>
# 99446          <NA>             <NA>      <NA>           <NA>
# 99447          <NA>             <NA>      <NA>           <NA>
# 99448          <NA>             <NA>      <NA>           <NA>
#
#                       Modified By        Modified Date KC EDM Received  \
# 0         Jessica Whytcross (vp5)  2024-11-25 14:22:07             YES
# 1            Karma Website (api2)  2023-11-15 15:31:30             YES
# 2         Jessica Whytcross (vp5)  2024-11-25 14:22:07             YES
# 3      Haritha Subramani (vp1846)  2024-11-13 18:25:41            <NA>
# 4      Haritha Subramani (vp1846)  2024-11-13 18:25:51            <NA>
# ...                           ...                  ...             ...
# 99444        Karma Website (api2)  2024-01-04 19:16:43             YES
# 99445        Karma Website (api2)  2024-01-04 19:18:14            <NA>
# 99446        Karma Website (api2)  2024-01-04 19:18:16            <NA>
# 99447        Karma Website (api2)  2024-01-04 19:18:17            <NA>
# 99448        Karma Website (api2)  2024-01-04 19:18:18            <NA>
#
#       Preferred Communication Method        filename
# 0                               <NA>  119 - kcb.xlsx
# 1                               <NA>  119 - kcb.xlsx
# 2                               <NA>  119 - kcb.xlsx
# 3                               <NA>  119 - kcb.xlsx
# 4                               <NA>  119 - kcb.xlsx
# ...                              ...             ...
# 99444                           <NA>  119 - kci.xlsx
# 99445                           <NA>  119 - kci.xlsx
# 99446                           <NA>  119 - kci.xlsx
# 99447                           <NA>  119 - kci.xlsx
# 99448                           <NA>  119 - kci.xlsx
#
# [99449 rows x 36 columns]

# %%
df = result.loc[
    (result['Primary'] == 'Primary') &
    (~result['Country'].str.contains('Australia|Indonesia', regex=True, flags=re.I))
    ].copy()

# %%
result.to_excel(r'C:\Users\fajar.fatoni\Documents\Python\Data\Member Data\vp\report 119 all details\17 Mar\compile\df_member.xlsx', index=False)
df.to_excel(r'C:\Users\fajar.fatoni\Documents\Python\Data\Member Data\vp\report 119 all details\17 Mar\compile\df_member_primary(exclude ID & AU).xlsx', index=False)
