# %%
import os
import pandas as pd
import re

# %load_ext autoreload
# %autoreload 2
 
# Get the list of all files and directories
# dir_path = "C://Users//Vanshi//Desktop//gfg"
dir_path = r"C:\Users\fajar.fatoni\Documents\Python\Data\Master Data Backup\CRM\Past Guests\KSM Guest"

# dir_list = os.listdir(dir_path)
 
# print("Files and directories in '", dir_path, "' :")
 
# # prints all files
# print(dir_list)

frames = []

# itterate file di dalam directory
for path in os.listdir(dir_path):

    # cek apakah di dalam directory ada file
    if os.path.isfile(os.path.join(dir_path, path)):
        if ".xlsx" in path:
            print(path)
            df = pd.read_excel(dir_path+'\\'+path, dtype='string')
            df['filename'] = path
            frames.append(df)

        if ".csv" in path:
            print(path)
            df = pd.read_csv(dir_path+'\\'+path, dtype='string', on_bad_lines='skip')
            df['filename'] = path
            frames.append(df)
    else:
        print('file doesn\'t exist')

result = pd.concat(frames, ignore_index=True)
result
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# Foodie Opt Ins.xlsx
# ksm_guest.xlsx
# Out & About Opt Ins.xlsx
# Pamper Opt Ins.xlsx
# Stay Opt Ins.xlsx
#                         Email Address First Name Last Name  Gender  \
# 0          juliahibbert@hotmail.co.uk      Julia   Hibbert  Female
# 1         judithekneen@btinternet.com     judith     kneen  Female
# 2                terena@hotmail.co.uk     Terena      Gill  Female
# 3                lowejacqui@gmail.com         Ja      Lowe  Female
# 4                 helen_nevin@sky.com    Anthony   Redhead    Male
# ...                               ...        ...       ...     ...
# 9752               mediabmj@gmail.com      Raana      Alwi  Female
# 9753          paul.colloff@live.co.uk       Paul   Colloff    Male
# 9754       angelatheobald06@gmail.com     Angela  Theobald  Female
# 9755        jeni-flower@hotmail.co.uk   Jennifer      Bull  Female
# 9756  tracy.pointon369@btinternet.com      Tracy   Pointon  Female
#
#             Date of Birth Home Postcode Residential Property Value  \
# 0     1982-11-04 00:00:00      BH18 8LZ            £251k - £500k
# 1     1962-05-24 00:00:00      GL18 1RY            £251k - £500k
# 2                    <NA>          <NA>            £251k - £500k
# 3     1962-02-02 00:00:00      CH49 2QZ              £501k - £1m
# 4     1971-04-01 00:00:00      NE42 5AP               £0 - £250k
# ...                   ...           ...                        ...
# 9752  1956-02-24 00:00:00       SE264SD            £251k - £500k
# 9753                 <NA>      CW11 1GY                       <NA>
# 9754  1968-03-28 00:00:00      SG11 1DQ               £0 - £250k
# 9755  1984-03-02 00:00:00      PL24 2FU               £0 - £250k
# 9756  1964-06-24 00:00:00       ST4 8LX                       <NA>
#
#      What is your household income per annum  \
# 0                            £101k - £150k
# 1                            £201k - £300k
# 2                              £29k - £43k
# 3                              £58k - £73k
# 4                              £58k - £73k
# ...                                      ...
# 9752                           £44k - £57k
# 9753                                    <NA>
# 9754                           £16k - £28k
# 9755                           £29k - £43k
# 9756                                    <NA>
#
#      Do you own a second property in Cornwall?  \
# 0                                           No
# 1                                           No
# 2                                         <NA>
# 3                                           No
# 4                                           No
# ...                                        ...
# 9752                                        No
# 9753                                      <NA>
# 9754                                        No
# 9755                                        No
# 9756                                        No
#
#      How often do you visit Cornwall?  ... DSTOFF       TIMEZONE  CC REGION  \
# 0               Less than once a year  ...      1  Europe/London  UK    BCP
# 1                        Twice a year  ...      1  Europe/London  UK    WSM
# 2           Four times a year or more  ...      1  Europe/London  UK    LND
# 3                  Three times a year  ...      1  Europe/London  UK    LND
# 4                         Once a year  ...      1  Europe/London  UK    NET
# ...                               ...  ...    ...            ...  ..    ...
# 9752                      Once a year  ...      1  Europe/London  UK    LND
# 9753                             <NA>  ...      2  Europe/Madrid  ES     PM
# 9754                     Twice a year  ...      1  Europe/London  UK    DBY
# 9755               I live in Cornwall  ...      1  Europe/London  UK    CON
# 9756                      Once a year  ...      1  Europe/London  UK    STE
#
#              LAST_CHANGED       LEID        EUID NOTES  TAGS  \
# 0     2025-06-03 07:11:25  647438590  70a5b56378  <NA>  <NA>
# 1     2025-06-02 19:38:26  647438374  b9a48cf176  <NA>  <NA>
# 2     2025-05-15 08:12:51  647438606  6122c5b934  <NA>  <NA>
# 3     2025-08-01 09:56:09  647442782  542b223feb  <NA>  <NA>
# 4     2025-07-06 16:36:18  647451792  6df251afa7  <NA>  <NA>
# ...                   ...        ...         ...   ...   ...
# 9752  2025-06-03 18:05:42  647443770  ae2aeef50e  <NA>  <NA>
# 9753  2025-07-05 07:35:13  647443360  511af02641  <NA>  <NA>
# 9754  2025-07-02 18:11:59  647450358  1ace37503b  <NA>  <NA>
# 9755  2025-08-01 09:45:17  647443264  5138a242aa  <NA>  <NA>
# 9756  2025-06-02 20:37:21  647442690  f7076e1745  <NA>  <NA>
#
#                  filename
# 0     Foodie Opt Ins.xlsx
# 1     Foodie Opt Ins.xlsx
# 2     Foodie Opt Ins.xlsx
# 3     Foodie Opt Ins.xlsx
# 4     Foodie Opt Ins.xlsx
# ...                   ...
# 9752    Stay Opt Ins.xlsx
# 9753    Stay Opt Ins.xlsx
# 9754    Stay Opt Ins.xlsx
# 9755    Stay Opt Ins.xlsx
# 9756    Stay Opt Ins.xlsx
#
# [9757 rows x 39 columns]

# %%
# m.clean_number(df, 'Phone')
# m.clean_number(df, 'Mobile')
# m.replace_not_valid_to_empty(df, 'Phone')
# m.replace_not_valid_to_empty(df, 'Mobile')
# df['Email Address'] = m.lowercase(df, 'Email Address')
# m.clean_space(df, 'Email Address')
# m.clean_not_valid_email_format(df, 'Email Address')

# %%
# result.to_excel(r'C:\Users\fajar.fatoni\Documents\Python\Data\Member Data\vp\report 119 all details\17 Mar\compile\df_member.xlsx', index=False)
result.to_excel(r'C:\Users\fajar.fatoni\Documents\Python\Data\Master Data Backup\CRM\Past Guests\KSM Guest\ksm_guest.xlsx', index=False)
