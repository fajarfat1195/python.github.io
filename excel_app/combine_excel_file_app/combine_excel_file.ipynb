# %%
# import OS module
import os
import pandas as pd
 
# Get the list of all files and directories
# dir_path = "C://Users//Vanshi//Desktop//gfg"
dir_path = r"C:\Users\fajar\Documents\Python\Data\Request Data\Benny\2 Juli\Other-Other"

# dir_list = os.listdir(dir_path)
 
# print("Files and directories in '", dir_path, "' :")
 
# # prints all files
# print(dir_list)

frames = []

# itterate file di dalam directory
for path in os.listdir(dir_path):

    # cek apakah di dalam directory ada file
    if os.path.isfile(os.path.join(dir_path, path)):
        if ".xlsx" in path:
            print(path)
            df = pd.read_excel(dir_path+'\\'+path, dtype='string')
            df['filename'] = path
            frames.append(df)

        if ".csv" in path:
            print(path)
            df = pd.read_csv(dir_path+'\\'+path, dtype='string', on_bad_lines='skip')
            df['filename'] = path
            frames.append(df)
    else:
        print('file doesn\'t exist')

result = pd.concat(frames, ignore_index=True)
result
# Out:
# df_other_1.csv
# df_other_2.csv
# df_other_3.csv
# df_other_4.csv
# df_other_5.csv
# df_other_6.csv
#                        Record Id         Created Time Created Date First Name  \
# 0       zcrm_3584690000005915587  2019-04-02 06:23:24   2000-01-01       Arun
# 1       zcrm_3584690000005915588  2019-04-02 06:23:24   2017-06-30        Joy
# 2       zcrm_3584690000005915589  2019-04-02 06:23:24   2017-07-04      James
# 3       zcrm_3584690000005915590  2019-04-02 06:23:24   2017-06-29       Jing
# 4       zcrm_3584690000005915591  2019-04-02 06:23:24   2017-06-29  Josephine
# ...                          ...                  ...          ...        ...
# 127650  zcrm_3584690000024725651  2019-04-07 17:14:56   2019-02-22    Dennice
# 127651  zcrm_3584690000024725657  2019-04-07 17:14:56   2019-02-23     Louise
# 127652  zcrm_3584690000024725660  2019-04-07 17:14:56   2019-02-25        Mel
# 127653  zcrm_3584690000024725662  2019-04-07 17:14:56   2019-03-18        Dan
# 127654  zcrm_3584690000024725668  2019-04-07 17:14:56   2019-03-19        Sam
#
#              Last Name                         Email          Phone Mobile  \
# 0             Kumar Jp     jp_arun_kumar@yahoo.co.in     6592376311   <NA>
# 1                  Kho             jp_kho8@yahoo.com           <NA>   <NA>
# 2          O'callaghan     jp_ocallaghan@hotmail.com           <NA>   <NA>
# 3          Pitchayanin             jp432@hotmail.com           <NA>   <NA>
# 4               Pascua           Jp50first@yahoo.com     7143503328   <NA>
# ...                ...                           ...            ...    ...
# 127650  Henry Gevandha      dhgevandha+464@gmail.com  6282236523643   <NA>
# 127651       Scrowther       louise_jazz@hotmail.com  +447894157660   <NA>
# 127652       Whitfield   melcwhitfield@hotmail.co.uk  +447976403541   <NA>
# 127653         Fullard  mygorgeousfriend@hotmail.com  +447850354382   <NA>
# 127654           Coote        samcoote.cc@icloud.com  +447914858418   <NA>
#
#        Birthdate Year of Birth  ... Lead Locations  \
# 0           <NA>          <NA>  ...           <NA>
# 1           <NA>          <NA>  ...           <NA>
# 2           <NA>          <NA>  ...           <NA>
# 3           <NA>          <NA>  ...           <NA>
# 4           <NA>          <NA>  ...        General
# ...          ...           ...  ...            ...
# 127650      <NA>          <NA>  ...           <NA>
# 127651      <NA>          1969  ...           <NA>
# 127652      <NA>          1984  ...           <NA>
# 127653      <NA>          1991  ...           <NA>
# 127654      <NA>          1984  ...           <NA>
#
#                                 Lead Source Description Lead Regions  \
# 0                                                  <NA>        Other
# 1                                                  <NA>        Other
# 2                                                  <NA>         SEAP
# 3                                                  <NA>        Other
# 4       KE | EDM | w2jan19 | 25 Anniversary Multi Offer         SEAP
# ...                                                 ...          ...
# 127650                                             <NA>        Other
# 127651                                             <NA>    UK/Europe
# 127652                                             <NA>    UK/Europe
# 127653                                             <NA>    UK/Europe
# 127654                                             <NA>    UK/Europe
#
#        Lead Status Email Opt Out Opt In GDPR Compliant  \
# 0             <NA>         false  false          false
# 1             <NA>         false  false          false
# 2             <NA>         false  false          false
# 3             <NA>         false  false          false
# 4             <NA>         false  false          false
# ...            ...           ...    ...            ...
# 127650    New Lead         false  false          false
# 127651    New Lead         false  false          false
# 127652    New Lead         false  false          false
# 127653    New Lead         false  false          false
# 127654    New Lead         false  false          false
#
#                                        Website                    Comments  \
# 0                                         <NA>                        <NA>
# 1                                         <NA>                        <NA>
# 2                                         <NA>                        <NA>
# 3                                         <NA>                        <NA>
# 4                                         <NA>  060320 SEAP KE legacy data
# ...                                        ...                         ...
# 127650                                    <NA>                        <NA>
# 127651                                    <NA>                        <NA>
# 127652                                    <NA>                        <NA>
# 127653  https://karmagroup.com/timeandleisure/                        <NA>
# 127654                                    <NA>                        <NA>
#
#               filename
# 0       df_other_1.csv
# 1       df_other_1.csv
# 2       df_other_1.csv
# 3       df_other_1.csv
# 4       df_other_1.csv
# ...                ...
# 127650  df_other_6.csv
# 127651  df_other_6.csv
# 127652  df_other_6.csv
# 127653  df_other_6.csv
# 127654  df_other_6.csv
#
# [127655 rows x 35 columns]

# %%
result.to_excel(r'C:\Users\fajar\Documents\Python\Data\Request Data\Benny\2 Juli\Other-Other\df_other_all.xlsx', index=False)
