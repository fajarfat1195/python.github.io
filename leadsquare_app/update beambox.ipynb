# %%
import sys
sys.path.append('../zoho_data_app')

import main_module as m
import pandas as pd
import re

import gspread

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
gc = gspread.oauth(
    credentials_filename= r'C:\Users\fajar\Documents\Python\Data\Google Credentials\karma-oauth.json'
)

SHEET_ID = '1FZ4bgWOEiVsbICA0WcG7DmBmjqA58v7ZdpiRZrARCqY'
SHEET_NAME_KLOM = 'KLOM'
SHEET_NAME_KSH = 'KSH'
SHEET_NAME_KB = 'KB'
SHEET_NAME_LSQ = 'Done in LSQ'
SHEET_NAME_API = 'API'

# get data gsheet

spreadsheet = gc.open_by_key(SHEET_ID)

worksheet_klom= spreadsheet.worksheet(SHEET_NAME_KLOM)
rows_klom = worksheet_klom.get_all_records()
df_klom = pd.DataFrame(rows_klom)
df_klom['Lead Location'] = 'Karma Lake Of Menteith'

worksheet_ksh= spreadsheet.worksheet(SHEET_NAME_KSH)
rows_ksh = worksheet_ksh.get_all_records()
df_ksh = pd.DataFrame(rows_ksh)
df_ksh['Lead Location'] = 'Karma Salford Hall'

worksheet_kb= spreadsheet.worksheet(SHEET_NAME_KB)
rows_kb = worksheet_kb.get_all_records()
df_kb = pd.DataFrame(rows_kb)
df_kb['Lead Location'] = 'Karma Bavaria'

worksheet_lsq= spreadsheet.worksheet(SHEET_NAME_LSQ)
rows_lsq = worksheet_lsq.get_all_records()
df_lsq = pd.DataFrame(rows_lsq)

worksheet_api= spreadsheet.worksheet(SHEET_NAME_API)
rows_api = worksheet_api.get_all_records()
df_api = pd.DataFrame(rows_api)

df_klom
# Out:
#                      Full Name First Name Last Name  \
# 0                  Maria Jones      Maria     Jones
# 1                    Rosey Pee      Rosey       Pee
# 2                 Marian Brown
# 3               Curtis Denison     Curtis   Denison
# 4                    Rosey Pee      Rosey       Pee
# ...                        ...        ...       ...
# 7752      Jessa Marie Pimentel      Jessa  Pimentel
# 7753  Mike Sinclair Uw Partner       Mike   Partner
# 7754      Rochelle Mc Laughlin   Rochelle  Laughlin
# 7755                Josh Mayes       Josh     Mayes
# 7756             John E Entity       John    Entity
#
#                                    Email Phone Gender Date of Birth  \
# 0               mariarosajones@gmail.com                 1954-06-12
# 1                     eunama21@yahoo.com                 1972-06-10
# 2              marjan.brown@ntlworld.com                 1963-08-13
# 3               curtisdenison4@gmail.com                 2005-01-01
# 4                    eunamma21@yahoo.com                 1972-06-10
# ...                                  ...   ...    ...           ...
# 7752    cabarles.jessamarie@yahoo.com.ph
# 7753        michael.sinclair@uw.partners
# 7754  rochelle_mclaughlin101@hotmail.com
# 7755                 jmayes697@gmail.com
# 7756     curiousorange666@googlemail.com
#
#      Nationality    Source  Visits  ...          First Login  \
# 0                    Email       7  ...  21-10-2024 18:30:18
# 1                    Email       1  ...  24-10-2024 19:30:19
# 2                    Email      12  ...  18-10-2024 17:15:00
# 3                    Email      57  ...  23-06-2024 20:02:12
# 4                    Email       1  ...  24-10-2024 16:57:59
# ...          ...       ...     ...  ...                  ...
# 7752              Facebook       0  ...
# 7753              Facebook       0  ...
# 7754              Facebook       0  ...
# 7755              Facebook       0  ...
# 7756              Facebook       0  ...
#
#                Last Login                Location Marketing Opt-in  \
# 0     24-10-2024 20:58:17  Karma Lake of Menteith             TRUE
# 1     24-10-2024 19:30:19  Karma Lake of Menteith             TRUE
# 2     24-10-2024 19:15:19  Karma Lake of Menteith             TRUE
# 3     24-10-2024 11:08:56  Karma Lake of Menteith             TRUE
# 4     24-10-2024 16:57:59  Karma Lake of Menteith            FALSE
# ...                   ...                     ...              ...
# 7752                                                          TRUE
# 7753                                                          TRUE
# 7754                                                          TRUE
# 7755                                                          TRUE
# 7756                                                          TRUE
#
#             MAC Address  \
# 0     1e:9a:ad:67:c5:89
# 1     26:b4:e2:c2:3e:ed
# 2     b2:63:8b:6e:2f:ee
# 3     ee:99:05:26:25:86
# 4     c2:b0:bb:15:72:45
# ...                 ...
# 7752
# 7753
# 7754
# 7755
# 7756
#
#      I Agree To Being Contacted By Karma Group. You Can Unsubscribe At Any Time, Please See Karma Group’s Privacy Policy For More Information.  \
# 0
# 1
# 2
# 3
# 4
# ...                                                 ...
# 7752
# 7753
# 7754
# 7755
# 7756
#
#      I Agree To Being Contacted By Karma Group  \
# 0
# 1
# 2
# 3
# 4
# ...                                        ...
# 7752
# 7753
# 7754
# 7755
# 7756
#
#      Https://Karmagroup.Com/Privacy Policy/  \
# 0
# 1
# 2
# 3
# 4
# ...                                     ...
# 7752
# 7753
# 7754
# 7755
# 7756
#
#      I Agree  To Being Contacted By Karma Group           Lead Location
# 0                                                Karma Lake Of Menteith
# 1                                                Karma Lake Of Menteith
# 2                                                Karma Lake Of Menteith
# 3                                                Karma Lake Of Menteith
# 4                                                Karma Lake Of Menteith
# ...                                         ...                     ...
# 7752                                             Karma Lake Of Menteith
# 7753                                             Karma Lake Of Menteith
# 7754                                             Karma Lake Of Menteith
# 7755                                             Karma Lake Of Menteith
# 7756                                             Karma Lake Of Menteith
#
# [7757 rows x 23 columns]

# %%
df_offline_join = pd.concat([df_klom,df_ksh,df_kb])
df_offline_join.loc[df_offline_join['Email'] == '','Email'] = 'empty'
df_offline_join.loc[df_offline_join['Phone'] == '','Email'] = 'empty'
count_data_gabungan = df_offline_join.shape[0]
df_offline_join
# Out:
#                Full Name First Name  Last Name                     Email  \
# 0            Maria Jones      Maria      Jones                     empty
# 1              Rosey Pee      Rosey        Pee                     empty
# 2           Marian Brown                                           empty
# 3         Curtis Denison     Curtis    Denison                     empty
# 4              Rosey Pee      Rosey        Pee                     empty
# ...                  ...        ...        ...                       ...
# 2668      Bormann Silvia    Bormann     Silvia  silvia.bormann@gmail.com
# 2669    Christoph Depner  Christoph     Depner     christophd89@yahoo.de
# 2670        Irvan Fauzie      Irvan     Fauzie                     empty
# 2671  Valerios Koutsonis   Valerios  Koutsonis                     empty
# 2672        Irvan Fauzie      Irvan     Fauzie                     empty
#
#               Phone Gender Date of Birth Nationality  Source  Visits  ...  \
# 0                             1954-06-12               Email       7  ...
# 1                             1972-06-10               Email       1  ...
# 2                             1963-08-13               Email      12  ...
# 3                             2005-01-01               Email      57  ...
# 4                             1972-06-10               Email       1  ...
# ...             ...    ...           ...         ...     ...     ...  ...
# 2668  4917666699852           1969-12-23               Email       1  ...
# 2669   491747642423           1989-11-25               Email       1  ...
# 2670                                                  Import       0  ...
# 2671                                                  Import       0  ...
# 2672                                                  Import       0  ...
#
#                Last Login                Location Marketing Opt-in  \
# 0     24-10-2024 20:58:17  Karma Lake of Menteith             TRUE
# 1     24-10-2024 19:30:19  Karma Lake of Menteith             TRUE
# 2     24-10-2024 19:15:19  Karma Lake of Menteith             TRUE
# 3     24-10-2024 11:08:56  Karma Lake of Menteith             TRUE
# 4     24-10-2024 16:57:59  Karma Lake of Menteith            FALSE
# ...                   ...                     ...              ...
# 2668   30-05-2024 7:28:33           Karma Bavaria             TRUE
# 2669   30-05-2024 7:12:04           Karma Bavaria            FALSE
# 2670                                                          TRUE
# 2671                                                          TRUE
# 2672                                                          TRUE
#
#             MAC Address  \
# 0     1e:9a:ad:67:c5:89
# 1     26:b4:e2:c2:3e:ed
# 2     b2:63:8b:6e:2f:ee
# 3     ee:99:05:26:25:86
# 4     c2:b0:bb:15:72:45
# ...                 ...
# 2668  e6:c4:aa:47:ba:68
# 2669  0e:af:6c:ac:7f:b9
# 2670
# 2671
# 2672
#
#      I Agree To Being Contacted By Karma Group. You Can Unsubscribe At Any Time, Please See Karma Group’s Privacy Policy For More Information.  \
# 0
# 1
# 2
# 3
# 4
# ...                                                 ...
# 2668                                                NaN
# 2669                                                NaN
# 2670                                                NaN
# 2671                                                NaN
# 2672                                                NaN
#
#      I Agree To Being Contacted By Karma Group  \
# 0
# 1
# 2
# 3
# 4
# ...                                        ...
# 2668                                       NaN
# 2669                                       NaN
# 2670                                       NaN
# 2671                                       NaN
# 2672                                       NaN
#
#      Https://Karmagroup.Com/Privacy Policy/  \
# 0
# 1
# 2
# 3
# 4
# ...                                     ...
# 2668                                    NaN
# 2669                                    NaN
# 2670                                    NaN
# 2671                                    NaN
# 2672                                    NaN
#
#      I Agree  To Being Contacted By Karma Group           Lead Location  \
# 0                                                Karma Lake Of Menteith
# 1                                                Karma Lake Of Menteith
# 2                                                Karma Lake Of Menteith
# 3                                                Karma Lake Of Menteith
# 4                                                Karma Lake Of Menteith
# ...                                         ...                     ...
# 2668                                        NaN           Karma Bavaria
# 2669                                        NaN           Karma Bavaria
# 2670                                        NaN           Karma Bavaria
# 2671                                        NaN           Karma Bavaria
# 2672                                        NaN           Karma Bavaria
#
#      Room Number
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
# ...          ...
# 2668         NaN
# 2669         NaN
# 2670         NaN
# 2671         NaN
# 2672         NaN
#
# [21657 rows x 24 columns]

# %% [markdown]
# # ====================== Awal Filter Umum ======================

# %%
# data phone, mobile dam email member yang ada di master data (wash member)

m.clean_number(df_offline_join, 'Phone')
m.replace_not_valid_to_empty(df_offline_join, 'Phone')
df_offline_join['Email'] = m.lowercase(df_offline_join, 'Email')
m.clean_space(df_offline_join, 'Email')

m.clean_number(df_lsq, 'Phone')
df_lsq['Email'] = m.lowercase(df_lsq, 'Email')
m.clean_space(df_lsq, 'Email')

m.clean_number(df_api, 'Phone')
df_lsq['Email'] = m.lowercase(df_api, 'Email')
m.clean_space(df_api, 'Email')
# Out:
# 0        descaldicott@hotmail.com
# 1           jimmeebee@hotmail.com
# 2            chrisband7@gmail.com
# 3         trowe640@btinternet.com
# 4          christina@di-nolfo.com
#                   ...
# 3196       martin_nuss@outlook.de
# 3197      anthonywywong@gmail.com
# 3198    filip.suryana@hotmail.com
# 3199           cade3217@gmail.com
# 3200     steffi.siebert@e-mail.de
# Name: Email, Length: 3201, dtype: object

# %% [markdown]
# # ====================== Akhir Filter Umum ======================

# %%
# hitung jumlah duplicate
count_duplicate_general = df_offline_join.loc[df_offline_join.duplicated(subset=['Email'])].shape[0]

df_offline_join.loc[df_offline_join.duplicated(subset=['Email'])]
# Out:
#                 Full Name First Name  Last Name                      Email  \
# 1               Rosey Pee      Rosey        Pee                      empty
# 2            Marian Brown                                            empty
# 3          Curtis Denison     Curtis    Denison                      empty
# 4               Rosey Pee      Rosey        Pee                      empty
# 5     Christopher Edmunds                                            empty
# ...                   ...        ...        ...                        ...
# 2634        Ashton Dsouza     Ashton     Dsouza  dr.ashtondsouza@gmail.com
# 2665    Gowri Manoj Kumar      Gowri      Kumar       gowrimanoj@gmail.com
# 2670         Irvan Fauzie      Irvan     Fauzie                      empty
# 2671   Valerios Koutsonis   Valerios  Koutsonis                      empty
# 2672         Irvan Fauzie      Irvan     Fauzie                      empty
#
#              Phone Gender Date of Birth Nationality  Source  Visits  ...  \
# 1            empty           1972-06-10               Email       1  ...
# 2            empty           1963-08-13               Email      12  ...
# 3            empty           2005-01-01               Email      57  ...
# 4            empty           1972-06-10               Email       1  ...
# 5            empty           1977-01-29               Email       1  ...
# ...            ...    ...           ...         ...     ...     ...  ...
# 2634  919880664143           1986-10-09               Email       1  ...
# 2665  440753936827           1978-01-28               Email       1  ...
# 2670         empty                                   Import       0  ...
# 2671         empty                                   Import       0  ...
# 2672         empty                                   Import       0  ...
#
#                Last Login                Location Marketing Opt-in  \
# 1     24-10-2024 19:30:19  Karma Lake of Menteith             TRUE
# 2     24-10-2024 19:15:19  Karma Lake of Menteith             TRUE
# 3     24-10-2024 11:08:56  Karma Lake of Menteith             TRUE
# 4     24-10-2024 16:57:59  Karma Lake of Menteith            FALSE
# 5     24-10-2024 16:54:51  Karma Lake of Menteith            FALSE
# ...                   ...                     ...              ...
# 2634   31-05-2024 8:16:56           Karma Bavaria             TRUE
# 2665   30-05-2024 8:03:38           Karma Bavaria             TRUE
# 2670                                                          TRUE
# 2671                                                          TRUE
# 2672                                                          TRUE
#
#             MAC Address  \
# 1     26:b4:e2:c2:3e:ed
# 2     b2:63:8b:6e:2f:ee
# 3     ee:99:05:26:25:86
# 4     c2:b0:bb:15:72:45
# 5     ea:5b:fc:f6:52:d3
# ...                 ...
# 2634  82:aa:c0:19:85:e1
# 2665  ce:0f:22:25:4e:55
# 2670
# 2671
# 2672
#
#      I Agree To Being Contacted By Karma Group. You Can Unsubscribe At Any Time, Please See Karma Group’s Privacy Policy For More Information.  \
# 1
# 2
# 3
# 4
# 5
# ...                                                 ...
# 2634                                                NaN
# 2665                                                NaN
# 2670                                                NaN
# 2671                                                NaN
# 2672                                                NaN
#
#      I Agree To Being Contacted By Karma Group  \
# 1
# 2
# 3
# 4
# 5
# ...                                        ...
# 2634                                       NaN
# 2665                                       NaN
# 2670                                       NaN
# 2671                                       NaN
# 2672                                       NaN
#
#      Https://Karmagroup.Com/Privacy Policy/  \
# 1
# 2
# 3
# 4
# 5
# ...                                     ...
# 2634                                    NaN
# 2665                                    NaN
# 2670                                    NaN
# 2671                                    NaN
# 2672                                    NaN
#
#      I Agree  To Being Contacted By Karma Group           Lead Location  \
# 1                                                Karma Lake Of Menteith
# 2                                                Karma Lake Of Menteith
# 3                                                Karma Lake Of Menteith
# 4                                                Karma Lake Of Menteith
# 5                                                Karma Lake Of Menteith
# ...                                         ...                     ...
# 2634                                        NaN           Karma Bavaria
# 2665                                        NaN           Karma Bavaria
# 2670                                        NaN           Karma Bavaria
# 2671                                        NaN           Karma Bavaria
# 2672                                        NaN           Karma Bavaria
#
#      Room Number
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
# 5            NaN
# ...          ...
# 2634         NaN
# 2665         NaN
# 2670         NaN
# 2671         NaN
# 2672         NaN
#
# [3230 rows x 24 columns]

# %%
df_offline_join.drop_duplicates(subset=['Email'], inplace=True)
df_offline_join.reset_index(drop=True, inplace=True)

# hitung jumlah setelah value duplicate dihapus
count_after_dedup_duplicate = df_offline_join.shape[0]
df_offline_join
# Out:
#                  Full Name First Name  Last Name                        Email  \
# 0              Maria Jones      Maria      Jones                        empty
# 1       Margaret Mccracken   Margaret  Mccracken    margaretmccrckn@gmail.com
# 2      Sambit Kumar Mishra                            sambit2705.uk@gmail.com
# 3      Harish Kutty Shetty     Harish     Shetty           aeande@hotmail.com
# 4            Kerrie Sicard                         kerrie.sicard@yahoo.com.au
# ...                    ...        ...        ...                          ...
# 18422     Edwin Jose Sunil      Edwin      Sunil  edwinjosesunil584@gmail.com
# 18423      Ishwari Chhatre    Ishwari    Chhatre        ishwari2604@gmail.com
# 18424         Anna Brunner       Anna    Brunner     brunner.anna26@gmail.com
# 18425       Bormann Silvia    Bormann     Silvia     silvia.bormann@gmail.com
# 18426     Christoph Depner  Christoph     Depner        christophd89@yahoo.de
#
#                Phone Gender Date of Birth Nationality Source  Visits  ...  \
# 0              empty           1954-06-12              Email       7  ...
# 1       447887761443                                   Email     191  ...
# 2      4407404281293                                   Email       4  ...
# 3       449898033013                                   Email       3  ...
# 4       610418673095                                   Email       6  ...
# ...              ...    ...           ...         ...    ...     ...  ...
# 18422   491782913994           2008-05-24              Email       1  ...
# 18423   919372758771           2004-04-26              Email       1  ...
# 18424  4915141291029           2006-03-26              Email       1  ...
# 18425  4917666699852           1969-12-23              Email       1  ...
# 18426   491747642423           1989-11-25              Email       1  ...
#
#                 Last Login                Location Marketing Opt-in  \
# 0      24-10-2024 20:58:17  Karma Lake of Menteith             TRUE
# 1      10-04-2024 10:18:28  Karma Lake of Menteith             TRUE
# 2       10-04-2024 9:21:58  Karma Lake of Menteith            FALSE
# 3       10-04-2024 8:47:17  Karma Lake of Menteith             TRUE
# 4       10-04-2024 7:47:04  Karma Lake of Menteith            FALSE
# ...                    ...                     ...              ...
# 18422   30-05-2024 8:19:47           Karma Bavaria             TRUE
# 18423   30-05-2024 7:39:59           Karma Bavaria            FALSE
# 18424   30-05-2024 7:36:52           Karma Bavaria            FALSE
# 18425   30-05-2024 7:28:33           Karma Bavaria             TRUE
# 18426   30-05-2024 7:12:04           Karma Bavaria            FALSE
#
#              MAC Address  \
# 0      1e:9a:ad:67:c5:89
# 1      06:f6:62:f6:8a:da
# 2      70:a8:d3:9d:60:8e
# 3      72:fe:f3:f2:ce:dc
# 4      ba:ce:40:fc:c5:2f
# ...                  ...
# 18422  ec:8c:9a:84:7f:de
# 18423  b6:ed:53:56:17:e5
# 18424  ca:ae:bc:c4:59:1b
# 18425  e6:c4:aa:47:ba:68
# 18426  0e:af:6c:ac:7f:b9
#
#       I Agree To Being Contacted By Karma Group. You Can Unsubscribe At Any Time, Please See Karma Group’s Privacy Policy For More Information.  \
# 0
# 1
# 2
# 3
# 4
# ...                                                  ...
# 18422                                                NaN
# 18423                                                NaN
# 18424                                                NaN
# 18425                                                NaN
# 18426                                                NaN
#
#       I Agree To Being Contacted By Karma Group  \
# 0
# 1                                           Yes
# 2                                           Yes
# 3                                            No
# 4                                           Yes
# ...                                         ...
# 18422                                       NaN
# 18423                                       NaN
# 18424                                       NaN
# 18425                                       NaN
# 18426                                       NaN
#
#       Https://Karmagroup.Com/Privacy Policy/  \
# 0
# 1
# 2
# 3
# 4
# ...                                      ...
# 18422                                    NaN
# 18423                                    NaN
# 18424                                    NaN
# 18425                                    NaN
# 18426                                    NaN
#
#       I Agree  To Being Contacted By Karma Group           Lead Location  \
# 0                                                 Karma Lake Of Menteith
# 1                                                 Karma Lake Of Menteith
# 2                                                 Karma Lake Of Menteith
# 3                                                 Karma Lake Of Menteith
# 4                                                 Karma Lake Of Menteith
# ...                                          ...                     ...
# 18422                                        NaN           Karma Bavaria
# 18423                                        NaN           Karma Bavaria
# 18424                                        NaN           Karma Bavaria
# 18425                                        NaN           Karma Bavaria
# 18426                                        NaN           Karma Bavaria
#
#       Room Number
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
# ...           ...
# 18422         NaN
# 18423         NaN
# 18424         NaN
# 18425         NaN
# 18426         NaN
#
# [18427 rows x 24 columns]

# %%
# data phone, mobile dam email member yang ada di master data 
count_wash_before = df_offline_join.loc[
    df_offline_join['Phone'].isin(df_lsq['Phone']) | 
    df_offline_join['Email'].isin(df_lsq['Email'])| 

    df_offline_join['Phone'].isin(df_api['Phone']) | 

    df_offline_join['Email'].isin(df_api['Email'])

].shape[0]

df_offline_join.drop(df_offline_join.loc[
    df_offline_join['Phone'].isin(df_lsq['Phone']) | 
    df_offline_join['Email'].isin(df_lsq['Email'])| 

    df_offline_join['Phone'].isin(df_api['Phone']) | 

    df_offline_join['Email'].isin(df_api['Email'])

    ].index, inplace=True)
    
df_offline_join.reset_index(drop=True, inplace=True)

count_after_wash_before = df_offline_join.shape[0]

# %%
# data phone, mobile dam email member yang ada di master data 
count_wash_contact_empty = df_offline_join.loc[
    (df_offline_join['Email'] == 'empty') & 
    (df_offline_join['Phone'] == 'empty')
    
].shape[0]

df_offline_join.drop(df_offline_join.loc[
    (df_offline_join['Email'] == 'empty') & 
    (df_offline_join['Phone'] == 'empty')
    ].index, inplace=True)
    
df_offline_join.reset_index(drop=True, inplace=True)

count_after_wash_contact_empty = df_offline_join.shape[0]

# %%
print("==========================================================")
print("Summary")
print("==========================================================")
print("Jumlah Filter Leads Awal : "+str(count_data_gabungan))
print("Jumlah Duplicate (Phone, Mobile dan Email) : "+str(count_duplicate_general))
print("Jumlah Setelah Clean Duplicate : "+str(count_after_dedup_duplicate))
print("Jumlah Wash Before : "+str(count_wash_before))
print("Jumlah Setelah Wash Member : "+str(count_after_wash_before))
print("Jumlah Wash Empty Contact : "+str(count_wash_contact_empty))
print("Jumlah Setelah Wash Empty Contact : "+str(count_after_wash_contact_empty))
# Out:
# ==========================================================
# Summary
# ==========================================================
# Jumlah Filter Leads Awal : 21657
# Jumlah Duplicate (Phone, Mobile dan Email) : 3230
# Jumlah Setelah Clean Duplicate : 18427
# Jumlah Wash Before : 10885
# Jumlah Setelah Wash Member : 7542
# Jumlah Wash Empty Contact : 1
# Jumlah Setelah Wash Empty Contact : 7541

# %%
df_final = pd.DataFrame()
df_final['Created Time'] = df_offline_join['First Visit'].copy()
df_final['Lead Location'] = df_offline_join['Lead Location'].copy()
df_final['First Name'] = df_offline_join['First Name'].copy()
df_final['Last Name'] = df_offline_join['Last Name'].copy()
df_final['Email'] = df_offline_join['Email'].copy()
df_final['Phone'] = df_offline_join['Phone'].copy()
df_final['Lead Brand'] = 'Timeshare Marketing'
df_final['Lead Sub-Brand'] = 'Other'
df_final['Lead Source'] = 'Wifi'
df_final['Lead Source Description'] = 'Beambox'
df_final['Email Opt Out'] = False
df_final['Opt In'] = True
df_final['Do Not Contact'] = False
df_final['Do Not Mail'] = False

df_final['Phone'] = df_final['Phone'].astype("string")

df_final['Phone'].replace('^440','44', regex=True, inplace=True)
df_final
# Out:
#              Created Time           Lead Location First Name Last Name  \
# 0     08-04-2024 16:50:46  Karma Lake Of Menteith     Harish    Shetty
# 1     05-04-2024 11:56:28  Karma Lake Of Menteith
# 2     05-04-2024 11:48:58  Karma Lake Of Menteith
# 3      12-05-2022 8:30:42  Karma Lake Of Menteith
# 4     07-04-2024 14:30:04  Karma Lake Of Menteith
# ...                   ...                     ...        ...       ...
# 7536   30-05-2024 8:19:47           Karma Bavaria      Edwin     Sunil
# 7537   30-05-2024 7:39:59           Karma Bavaria    Ishwari   Chhatre
# 7538   30-05-2024 7:36:52           Karma Bavaria       Anna   Brunner
# 7539   30-05-2024 7:28:33           Karma Bavaria    Bormann    Silvia
# 7540   30-05-2024 7:12:04           Karma Bavaria  Christoph    Depner
#
#                             Email          Phone           Lead Brand  \
# 0              aeande@hotmail.com   449898033013  Timeshare Marketing
# 1      kerrie.sicard@yahoo.com.au   610418673095  Timeshare Marketing
# 2       allan.sicard@yahoo.com.au   610447443339  Timeshare Marketing
# 3             premsharma1@aol.com   447840806773  Timeshare Marketing
# 4     panigrahi.saswati@gmail.com   447448243673  Timeshare Marketing
# ...                           ...            ...                  ...
# 7536  edwinjosesunil584@gmail.com   491782913994  Timeshare Marketing
# 7537        ishwari2604@gmail.com   919372758771  Timeshare Marketing
# 7538     brunner.anna26@gmail.com  4915141291029  Timeshare Marketing
# 7539     silvia.bormann@gmail.com  4917666699852  Timeshare Marketing
# 7540        christophd89@yahoo.de   491747642423  Timeshare Marketing
#
#      Lead Sub-Brand Lead Source Lead Source Description  Email Opt Out  \
# 0             Other        Wifi                 Beambox          False
# 1             Other        Wifi                 Beambox          False
# 2             Other        Wifi                 Beambox          False
# 3             Other        Wifi                 Beambox          False
# 4             Other        Wifi                 Beambox          False
# ...             ...         ...                     ...            ...
# 7536          Other        Wifi                 Beambox          False
# 7537          Other        Wifi                 Beambox          False
# 7538          Other        Wifi                 Beambox          False
# 7539          Other        Wifi                 Beambox          False
# 7540          Other        Wifi                 Beambox          False
#
#       Opt In  Do Not Contact  Do Not Mail
# 0       True           False        False
# 1       True           False        False
# 2       True           False        False
# 3       True           False        False
# 4       True           False        False
# ...      ...             ...          ...
# 7536    True           False        False
# 7537    True           False        False
# 7538    True           False        False
# 7539    True           False        False
# 7540    True           False        False
#
# [7541 rows x 14 columns]

# %%
df_final.replace('empty', '', inplace=True, regex=True)
df_final.loc[df_final['Phone'].str.len() < 3, 'Phone'] = ''

# %%
# df_final.to_excel(r'C:\Users\fajar\Documents\Python\Data\update_beambox.xlsx', index=False)

# %%
SHEET_NAME_UPDATE = 'Update Beambox'
# SHEET_NAME_UPDATE = 'Test'
worksheet_update= spreadsheet.worksheet(SHEET_NAME_UPDATE)
worksheet_update.clear()

worksheet_update.update([df_final.columns.values.tolist()] + df_final.values.tolist())
# Out:
# {'spreadsheetId': '1FZ4bgWOEiVsbICA0WcG7DmBmjqA58v7ZdpiRZrARCqY',
#  'updatedRange': "'Update Beambox'!A1:N7542",
#  'updatedRows': 7542,
#  'updatedColumns': 14,
#  'updatedCells': 105588}
