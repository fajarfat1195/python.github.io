# %%
import sys
sys.path.append('../zoho_data_app')

import main_module as m
import pandas as pd
import re

import gspread

# %load_ext autoreload
# %autoreload 2

# %%
gc = gspread.oauth(
    credentials_filename= r'C:\Users\fajar\Documents\Python\Data\Google Credentials\karma-oauth.json'
)

SHEET_ID = '1FZ4bgWOEiVsbICA0WcG7DmBmjqA58v7ZdpiRZrARCqY'
SHEET_NAME_KLOM = 'KLOM'
SHEET_NAME_KSH = 'KSH'
SHEET_NAME_KB = 'KB'
SHEET_NAME_LSQ = 'Done in LSQ'
SHEET_NAME_API = 'API'

# get data gsheet

spreadsheet = gc.open_by_key(SHEET_ID)

worksheet_klom= spreadsheet.worksheet(SHEET_NAME_KLOM)
rows_klom = worksheet_klom.get_all_records()
df_klom = pd.DataFrame(rows_klom)
df_klom['Lead Location'] = 'Karma Lake Of Menteith'

worksheet_ksh= spreadsheet.worksheet(SHEET_NAME_KSH)
rows_ksh = worksheet_ksh.get_all_records()
df_ksh = pd.DataFrame(rows_ksh)
df_ksh['Lead Location'] = 'Karma Salford Hall'

worksheet_kb= spreadsheet.worksheet(SHEET_NAME_KB)
rows_kb = worksheet_kb.get_all_records()
df_kb = pd.DataFrame(rows_kb)
df_kb['Lead Location'] = 'Karma Bavaria'

worksheet_lsq= spreadsheet.worksheet(SHEET_NAME_LSQ)
rows_lsq = worksheet_lsq.get_all_records()
df_lsq = pd.DataFrame(rows_lsq)

worksheet_api= spreadsheet.worksheet(SHEET_NAME_API)
rows_api = worksheet_api.get_all_records()
df_api = pd.DataFrame(rows_api)

df_klom
# Out:
#                      Full Name   First Name Last Name  \
# 0                 Merci Clarke
# 1          Christopher Kindred  Christopher   Kindred
# 2                 David Hadson
# 3                David Bennett        David   Bennett
# 4                  Craig Coull        Craig     Coull
# ...                        ...          ...       ...
# 8021      Jessa Marie Pimentel        Jessa  Pimentel
# 8022  Mike Sinclair Uw Partner         Mike   Partner
# 8023      Rochelle Mc Laughlin     Rochelle  Laughlin
# 8024                Josh Mayes         Josh     Mayes
# 8025             John E Entity         John    Entity
#
#                                    Email Phone Gender Date of Birth  \
# 0                    wwjdmerci@yahoo.com                   7/8/1975
# 1                 chriskindred@gmail.com                 12/31/1970
# 2            david.hadson@karmagroup.com                 10/13/1969
# 3           david@possumsolutions.com.au                   3/5/1962
# 4               craigcoull@hotmail.co.uk                  2/15/1995
# ...                                  ...   ...    ...           ...
# 8021    cabarles.jessamarie@yahoo.com.ph
# 8022        michael.sinclair@uw.partners
# 8023  rochelle_mclaughlin101@hotmail.com
# 8024                 jmayes697@gmail.com
# 8025     curiousorange666@googlemail.com
#
#      Nationality    Source  Visits  ...          First Login  \
# 0                    Email      16  ...  28-11-2024 14:50:14
# 1                    Email      41  ...  20-11-2024 11:04:07
# 2                    Email       2  ...   1-12-2024 16:11:00
# 3                    Email       1  ...  01-12-2024 21:51:00
# 4                    Email       1  ...   1-12-2024 21:45:00
# ...          ...       ...     ...  ...                  ...
# 8021              Facebook       0  ...
# 8022              Facebook       0  ...
# 8023              Facebook       0  ...
# 8024              Facebook       0  ...
# 8025              Facebook       0  ...
#
#               Last Login                Location Marketing Opt-in  \
# 0      2-12-2024 0:11:00  Karma Lake of Menteith            FALSE
# 1      2-12-2024 0:06:00  Karma Lake of Menteith             TRUE
# 2     1-12-2024 16:11:00  Karma Lake of Menteith             TRUE
# 3     1-12-2024 21:51:00  Karma Lake of Menteith             TRUE
# 4     1-12-2024 21:45:00  Karma Lake of Menteith            FALSE
# ...                  ...                     ...              ...
# 8021                                                         TRUE
# 8022                                                         TRUE
# 8023                                                         TRUE
# 8024                                                         TRUE
# 8025                                                         TRUE
#
#             MAC Address  \
# 0     76:3e:79:00:55:19
# 1     76:08:e7:7a:d1:b9
# 2     4e:69:17:b0:06:90
# 3     e2:03:00:a0:9c:bb
# 4     3a:f3:21:b1:77:9a
# ...                 ...
# 8021
# 8022
# 8023
# 8024
# 8025
#
#      I Agree To Being Contacted By Karma Group. You Can Unsubscribe At Any Time, Please See Karma Groupâ€™s Privacy Policy For More Information.  \
# 0
# 1
# 2
# 3
# 4
# ...                                                 ...
# 8021
# 8022
# 8023
# 8024
# 8025
#
#      I Agree To Being Contacted By Karma Group  \
# 0
# 1
# 2
# 3
# 4
# ...                                        ...
# 8021
# 8022
# 8023
# 8024
# 8025
#
#      Https://Karmagroup.Com/Privacy Policy/  \
# 0
# 1
# 2
# 3
# 4
# ...                                     ...
# 8021
# 8022
# 8023
# 8024
# 8025
#
#      I Agree  To Being Contacted By Karma Group           Lead Location
# 0                                                Karma Lake Of Menteith
# 1                                                Karma Lake Of Menteith
# 2                                                Karma Lake Of Menteith
# 3                                                Karma Lake Of Menteith
# 4                                                Karma Lake Of Menteith
# ...                                         ...                     ...
# 8021                                             Karma Lake Of Menteith
# 8022                                             Karma Lake Of Menteith
# 8023                                             Karma Lake Of Menteith
# 8024                                             Karma Lake Of Menteith
# 8025                                             Karma Lake Of Menteith
#
# [8026 rows x 23 columns]

# %%
df_offline_join = pd.concat([df_klom,df_ksh,df_kb])
df_offline_join.loc[df_offline_join['Email'] == '','Email'] = 'empty'
df_offline_join.loc[df_offline_join['Phone'] == '','Email'] = 'empty'
count_data_gabungan = df_offline_join.shape[0]
df_offline_join
# Out:
#                 Full Name   First Name  Last Name                     Email  \
# 0            Merci Clarke                                             empty
# 1     Christopher Kindred  Christopher    Kindred                     empty
# 2            David Hadson                                             empty
# 3           David Bennett        David    Bennett                     empty
# 4             Craig Coull        Craig      Coull                     empty
# ...                   ...          ...        ...                       ...
# 3133      Ishwari Chhatre      Ishwari    Chhatre     ishwari2604@gmail.com
# 3134         Anna Brunner         Anna    Brunner  brunner.anna26@gmail.com
# 3135       Bormann Silvia      Bormann     Silvia  silvia.bormann@gmail.com
# 3136     Christoph Depner    Christoph     Depner     christophd89@yahoo.de
# 3137   Valerios Koutsonis     Valerios  Koutsonis                     empty
#
#               Phone Gender Date of Birth Nationality  Source  Visits  ...  \
# 0                               7/8/1975               Email      16  ...
# 1                             12/31/1970               Email      41  ...
# 2                             10/13/1969               Email       2  ...
# 3                               3/5/1962               Email       1  ...
# 4                              2/15/1995               Email       1  ...
# ...             ...    ...           ...         ...     ...     ...  ...
# 3133   919372758771            4/26/2004               Email       1  ...
# 3134  4915141291029            3/26/2006               Email       1  ...
# 3135  4917666699852           12/23/1969               Email       1  ...
# 3136   491747642423           11/25/1989               Email       1  ...
# 3137                                                  Import       0  ...
#
#               Last Login                Location Marketing Opt-in  \
# 0      2-12-2024 0:11:00  Karma Lake of Menteith            FALSE
# 1      2-12-2024 0:06:00  Karma Lake of Menteith             TRUE
# 2     1-12-2024 16:11:00  Karma Lake of Menteith             TRUE
# 3     1-12-2024 21:51:00  Karma Lake of Menteith             TRUE
# 4     1-12-2024 21:45:00  Karma Lake of Menteith            FALSE
# ...                  ...                     ...              ...
# 3133  30-05-2024 7:39:59           Karma Bavaria            FALSE
# 3134  30-05-2024 7:36:52           Karma Bavaria            FALSE
# 3135  30-05-2024 7:28:33           Karma Bavaria             TRUE
# 3136  30-05-2024 7:12:04           Karma Bavaria            FALSE
# 3137                                                         TRUE
#
#             MAC Address  \
# 0     76:3e:79:00:55:19
# 1     76:08:e7:7a:d1:b9
# 2     4e:69:17:b0:06:90
# 3     e2:03:00:a0:9c:bb
# 4     3a:f3:21:b1:77:9a
# ...                 ...
# 3133  b6:ed:53:56:17:e5
# 3134  ca:ae:bc:c4:59:1b
# 3135  e6:c4:aa:47:ba:68
# 3136  0e:af:6c:ac:7f:b9
# 3137
#
#      I Agree To Being Contacted By Karma Group. You Can Unsubscribe At Any Time, Please See Karma Groupâ€™s Privacy Policy For More Information.  \
# 0
# 1
# 2
# 3
# 4
# ...                                                 ...
# 3133                                                NaN
# 3134                                                NaN
# 3135                                                NaN
# 3136                                                NaN
# 3137                                                NaN
#
#      I Agree To Being Contacted By Karma Group  \
# 0
# 1
# 2
# 3
# 4
# ...                                        ...
# 3133                                       NaN
# 3134                                       NaN
# 3135                                       NaN
# 3136                                       NaN
# 3137                                       NaN
#
#      Https://Karmagroup.Com/Privacy Policy/  \
# 0
# 1
# 2
# 3
# 4
# ...                                     ...
# 3133                                    NaN
# 3134                                    NaN
# 3135                                    NaN
# 3136                                    NaN
# 3137                                    NaN
#
#      I Agree  To Being Contacted By Karma Group           Lead Location  \
# 0                                                Karma Lake Of Menteith
# 1                                                Karma Lake Of Menteith
# 2                                                Karma Lake Of Menteith
# 3                                                Karma Lake Of Menteith
# 4                                                Karma Lake Of Menteith
# ...                                         ...                     ...
# 3133                                        NaN           Karma Bavaria
# 3134                                        NaN           Karma Bavaria
# 3135                                        NaN           Karma Bavaria
# 3136                                        NaN           Karma Bavaria
# 3137                                        NaN           Karma Bavaria
#
#      Room Number
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
# ...          ...
# 3133         NaN
# 3134         NaN
# 3135         NaN
# 3136         NaN
# 3137         NaN
#
# [22721 rows x 24 columns]

# %% [markdown]
# # ====================== Awal Filter Umum ======================

# %%
# data phone, mobile dam email member yang ada di master data (wash member)

m.clean_number(df_offline_join, 'Phone')
m.replace_not_valid_to_empty(df_offline_join, 'Phone')
df_offline_join['Email'] = m.lowercase(df_offline_join, 'Email')
m.clean_space(df_offline_join, 'Email')

m.clean_number(df_lsq, 'Phone')
df_lsq['Email'] = m.lowercase(df_lsq, 'Email')
m.clean_space(df_lsq, 'Email')

m.clean_number(df_api, 'Phone')
df_lsq['Email'] = m.lowercase(df_api, 'Email')
m.clean_space(df_api, 'Email')
# Out:
# 0          descaldicott@hotmail.com
# 1             jimmeebee@hotmail.com
# 2              chrisband7@gmail.com
# 3           trowe640@btinternet.com
# 4            christina@di-nolfo.com
#                    ...
# 3218         dawnandjoe@bigppnd.com
# 3219          nair.renu93@gmail.com
# 3220           mercyjey@hotmail.com
# 3221                  nskew@aol.com
# 3222    photo@ampersandmemories.com
# Name: Email, Length: 3223, dtype: object

# %% [markdown]
# # ====================== Akhir Filter Umum ======================

# %%
# hitung jumlah duplicate
count_duplicate_general = df_offline_join.loc[df_offline_join.duplicated(subset=['Email'])].shape[0]

df_offline_join.loc[df_offline_join.duplicated(subset=['Email'])]
# Out:
#                 Full Name   First Name  Last Name                       Email  \
# 1     Christopher Kindred  Christopher    Kindred                       empty
# 2            David Hadson                                               empty
# 3           David Bennett        David    Bennett                       empty
# 4             Craig Coull        Craig      Coull                       empty
# 5           Julia Wardell                                               empty
# ...                   ...          ...        ...                         ...
# 3100          Manoj Kumar                                  mankrish@gmail.com
# 3101    Rahul Manoj Kumar                          rahulmanojkumar3@gmail.com
# 3103        Ashton Dsouza       Ashton     Dsouza   dr.ashtondsouza@gmail.com
# 3132    Gowri Manoj Kumar        Gowri      Kumar        gowrimanoj@gmail.com
# 3137   Valerios Koutsonis     Valerios  Koutsonis                       empty
#
#               Phone Gender Date of Birth Nationality  Source  Visits  ...  \
# 1             empty           12/31/1970               Email      41  ...
# 2             empty           10/13/1969               Email       2  ...
# 3             empty             3/5/1962               Email       1  ...
# 4             empty            2/15/1995               Email       1  ...
# 5             empty            8/17/1960               Email       4  ...
# ...             ...    ...           ...         ...     ...     ...  ...
# 3100   447539368277            4/16/1975               Email       3  ...
# 3101  4407394134008            1/18/2002               Email       3  ...
# 3103   919880664143            10/9/1986               Email       1  ...
# 3132   440753936827            1/28/1978               Email       1  ...
# 3137          empty                                   Import       0  ...
#
#               Last Login                Location Marketing Opt-in  \
# 1      2-12-2024 0:06:00  Karma Lake of Menteith             TRUE
# 2     1-12-2024 16:11:00  Karma Lake of Menteith             TRUE
# 3     1-12-2024 21:51:00  Karma Lake of Menteith             TRUE
# 4     1-12-2024 21:45:00  Karma Lake of Menteith            FALSE
# 5     1-12-2024 21:36:00  Karma Lake of Menteith            FALSE
# ...                  ...                     ...              ...
# 3100  31-05-2024 8:32:51           Karma Bavaria             TRUE
# 3101  31-05-2024 8:29:45           Karma Bavaria            FALSE
# 3103  31-05-2024 8:16:56           Karma Bavaria             TRUE
# 3132  30-05-2024 8:03:38           Karma Bavaria             TRUE
# 3137                                                         TRUE
#
#             MAC Address  \
# 1     76:08:e7:7a:d1:b9
# 2     4e:69:17:b0:06:90
# 3     e2:03:00:a0:9c:bb
# 4     3a:f3:21:b1:77:9a
# 5     b6:39:56:e8:de:48
# ...                 ...
# 3100  b6:6f:bb:ad:63:3e
# 3101  ba:75:4b:9b:73:4d
# 3103  82:aa:c0:19:85:e1
# 3132  ce:0f:22:25:4e:55
# 3137
#
#      I Agree To Being Contacted By Karma Group. You Can Unsubscribe At Any Time, Please See Karma Groupâ€™s Privacy Policy For More Information.  \
# 1
# 2
# 3
# 4
# 5
# ...                                                 ...
# 3100                                                NaN
# 3101                                                NaN
# 3103                                                NaN
# 3132                                                NaN
# 3137                                                NaN
#
#      I Agree To Being Contacted By Karma Group  \
# 1
# 2
# 3
# 4
# 5
# ...                                        ...
# 3100                                       NaN
# 3101                                       NaN
# 3103                                       NaN
# 3132                                       NaN
# 3137                                       NaN
#
#      Https://Karmagroup.Com/Privacy Policy/  \
# 1
# 2
# 3
# 4
# 5
# ...                                     ...
# 3100                                    NaN
# 3101                                    NaN
# 3103                                    NaN
# 3132                                    NaN
# 3137                                    NaN
#
#      I Agree  To Being Contacted By Karma Group           Lead Location  \
# 1                                                Karma Lake Of Menteith
# 2                                                Karma Lake Of Menteith
# 3                                                Karma Lake Of Menteith
# 4                                                Karma Lake Of Menteith
# 5                                                Karma Lake Of Menteith
# ...                                         ...                     ...
# 3100                                        NaN           Karma Bavaria
# 3101                                        NaN           Karma Bavaria
# 3103                                        NaN           Karma Bavaria
# 3132                                        NaN           Karma Bavaria
# 3137                                        NaN           Karma Bavaria
#
#      Room Number
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
# 5            NaN
# ...          ...
# 3100         NaN
# 3101         NaN
# 3103         NaN
# 3132         NaN
# 3137         NaN
#
# [3535 rows x 24 columns]

# %%
df_offline_join.drop_duplicates(subset=['Email'], inplace=True)
df_offline_join.reset_index(drop=True, inplace=True)

# hitung jumlah setelah value duplicate dihapus
count_after_dedup_duplicate = df_offline_join.shape[0]
df_offline_join
# Out:
#                  Full Name First Name  Last Name                       Email  \
# 0             Merci Clarke                                             empty
# 1       Margaret Mccracken   Margaret  Mccracken   margaretmccrckn@gmail.com
# 2      Sambit Kumar Mishra                           sambit2705.uk@gmail.com
# 3      Harish Kutty Shetty     Harish     Shetty          aeande@hotmail.com
# 4            Kerrie Sicard                        kerrie.sicard@yahoo.com.au
# ...                    ...        ...        ...                         ...
# 19181       Susanne Dewald                          susannedewald4@gmail.com
# 19182      Ishwari Chhatre    Ishwari    Chhatre       ishwari2604@gmail.com
# 19183         Anna Brunner       Anna    Brunner    brunner.anna26@gmail.com
# 19184       Bormann Silvia    Bormann     Silvia    silvia.bormann@gmail.com
# 19185     Christoph Depner  Christoph     Depner       christophd89@yahoo.de
#
#                        Phone Gender Date of Birth Nationality Source  Visits  \
# 0                      empty             7/8/1975              Email      16
# 1      4480000000000000000.0                                   Email     191
# 2      4410000000000000000.0                                   Email       4
# 3      4500000000000000000.0                                   Email       3
# 4      6100000000000000000.0                                   Email       6
# ...                      ...    ...           ...         ...    ...     ...
# 19181            49613144343             8/2/1964              Email       1
# 19182           919372758771            4/26/2004              Email       1
# 19183          4915141291029            3/26/2006              Email       1
# 19184          4917666699852           12/23/1969              Email       1
# 19185           491747642423           11/25/1989              Email       1
#
#        ...           Last Login                Location Marketing Opt-in  \
# 0      ...    2-12-2024 0:11:00  Karma Lake of Menteith            FALSE
# 1      ...  10-04-2024 10:18:00  Karma Lake of Menteith             TRUE
# 2      ...   10-04-2024 9:21:00  Karma Lake of Menteith            FALSE
# 3      ...   10-04-2024 8:47:00  Karma Lake of Menteith             TRUE
# 4      ...   10-04-2024 7:47:00  Karma Lake of Menteith            FALSE
# ...    ...                  ...                     ...              ...
# 19181  ...   30-05-2024 9:27:12           Karma Bavaria             TRUE
# 19182  ...   30-05-2024 7:39:59           Karma Bavaria            FALSE
# 19183  ...   30-05-2024 7:36:52           Karma Bavaria            FALSE
# 19184  ...   30-05-2024 7:28:33           Karma Bavaria             TRUE
# 19185  ...   30-05-2024 7:12:04           Karma Bavaria            FALSE
#
#              MAC Address  \
# 0      76:3e:79:00:55:19
# 1      06:f6:62:f6:8a:da
# 2      70:a8:d3:9d:60:8e
# 3      72:fe:f3:f2:ce:dc
# 4      ba:ce:40:fc:c5:2f
# ...                  ...
# 19181  1e:e5:49:b5:88:94
# 19182  b6:ed:53:56:17:e5
# 19183  ca:ae:bc:c4:59:1b
# 19184  e6:c4:aa:47:ba:68
# 19185  0e:af:6c:ac:7f:b9
#
#       I Agree To Being Contacted By Karma Group. You Can Unsubscribe At Any Time, Please See Karma Groupâ€™s Privacy Policy For More Information.  \
# 0
# 1
# 2
# 3
# 4
# ...                                                  ...
# 19181                                                NaN
# 19182                                                NaN
# 19183                                                NaN
# 19184                                                NaN
# 19185                                                NaN
#
#       I Agree To Being Contacted By Karma Group  \
# 0
# 1                                           Yes
# 2                                           Yes
# 3                                            No
# 4                                           Yes
# ...                                         ...
# 19181                                       NaN
# 19182                                       NaN
# 19183                                       NaN
# 19184                                       NaN
# 19185                                       NaN
#
#       Https://Karmagroup.Com/Privacy Policy/  \
# 0
# 1
# 2
# 3
# 4
# ...                                      ...
# 19181                                    NaN
# 19182                                    NaN
# 19183                                    NaN
# 19184                                    NaN
# 19185                                    NaN
#
#       I Agree  To Being Contacted By Karma Group           Lead Location  \
# 0                                                 Karma Lake Of Menteith
# 1                                                 Karma Lake Of Menteith
# 2                                                 Karma Lake Of Menteith
# 3                                                 Karma Lake Of Menteith
# 4                                                 Karma Lake Of Menteith
# ...                                          ...                     ...
# 19181                                        NaN           Karma Bavaria
# 19182                                        NaN           Karma Bavaria
# 19183                                        NaN           Karma Bavaria
# 19184                                        NaN           Karma Bavaria
# 19185                                        NaN           Karma Bavaria
#
#       Room Number
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
# ...           ...
# 19181         NaN
# 19182         NaN
# 19183         NaN
# 19184         NaN
# 19185         NaN
#
# [19186 rows x 24 columns]

# %%
# data phone, mobile dam email member yang ada di master data 
count_wash_before = df_offline_join.loc[
    df_offline_join['Phone'].isin(df_lsq['Phone']) | 
    df_offline_join['Email'].isin(df_lsq['Email'])| 

    df_offline_join['Phone'].isin(df_api['Phone']) | 

    df_offline_join['Email'].isin(df_api['Email'])

].shape[0]

df_offline_join.drop(df_offline_join.loc[
    df_offline_join['Phone'].isin(df_lsq['Phone']) | 
    df_offline_join['Email'].isin(df_lsq['Email'])| 

    df_offline_join['Phone'].isin(df_api['Phone']) | 

    df_offline_join['Email'].isin(df_api['Email'])

    ].index, inplace=True)
    
df_offline_join.reset_index(drop=True, inplace=True)

count_after_wash_before = df_offline_join.shape[0]

# %%
# data phone, mobile dam email member yang ada di master data 
count_wash_contact_empty = df_offline_join.loc[
    (df_offline_join['Email'] == 'empty') & 
    (df_offline_join['Phone'] == 'empty')
    
].shape[0]

df_offline_join.drop(df_offline_join.loc[
    (df_offline_join['Email'] == 'empty') & 
    (df_offline_join['Phone'] == 'empty')
    ].index, inplace=True)
    
df_offline_join.reset_index(drop=True, inplace=True)

count_after_wash_contact_empty = df_offline_join.shape[0]

# %%
print("==========================================================")
print("Summary")
print("==========================================================")
print("JumQUlah Filter Leads Awal : "+str(count_data_gabungan))
print("Jumlah Duplicate (Phone, Mobile dan Email) : "+str(count_duplicate_general))
print("Jumlah Setelah Clean Duplicate : "+str(count_after_dedup_duplicate))
print("Jumlah Wash Before : "+str(count_wash_before))
print("Jumlah Setelah Wash Member : "+str(count_after_wash_before))
print("Jumlah Wash Empty Contact : "+str(count_wash_contact_empty))
print("Jumlah Setelah Wash Empty Contact : "+str(count_after_wash_contact_empty))
# Out:
# ==========================================================
# Summary
# ==========================================================
# Jumlah Filter Leads Awal : 22721
# Jumlah Duplicate (Phone, Mobile dan Email) : 3535
# Jumlah Setelah Clean Duplicate : 19186
# Jumlah Wash Before : 4702
# Jumlah Setelah Wash Member : 14484
# Jumlah Wash Empty Contact : 1
# Jumlah Setelah Wash Empty Contact : 14483

# %%
df_final = pd.DataFrame()
df_final['Created Time'] = df_offline_join['First Visit'].copy()
df_final['Lead Location'] = df_offline_join['Lead Location'].copy()
df_final['First Name'] = df_offline_join['First Name'].copy()
df_final['Last Name'] = df_offline_join['Last Name'].copy()
df_final['Email'] = df_offline_join['Email'].copy()
df_final['Phone'] = df_offline_join['Phone'].copy()
df_final['Lead Brand'] = 'Timeshare Marketing'
df_final['Lead Sub-Brand'] = 'Other'
df_final['Lead Source'] = 'Wifi'
df_final['Lead Source Description'] = 'Beambox'
df_final['Email Opt Out'] = False
df_final['Opt In'] = True
df_final['Do Not Contact'] = False
df_final['Do Not Mail'] = False

df_final['Phone'] = df_final['Phone'].astype("string")

df_final['Phone'].replace('^440','44', regex=True, inplace=True)
df_final
# Out:
#               Created Time           Lead Location First Name   Last Name  \
# 0       29-04-2023 9:28:14  Karma Lake Of Menteith   Margaret   Mccracken
# 1      07-04-2024 14:29:00  Karma Lake Of Menteith
# 2      08-04-2024 16:50:00  Karma Lake Of Menteith     Harish      Shetty
# 3      05-04-2024 11:56:00  Karma Lake Of Menteith
# 4      06-04-2024 20:18:00  Karma Lake Of Menteith  Prakruthi  Kantharaju
# ...                    ...                     ...        ...         ...
# 14478   30-05-2024 9:27:12           Karma Bavaria
# 14479   30-05-2024 7:39:59           Karma Bavaria    Ishwari     Chhatre
# 14480   30-05-2024 7:36:52           Karma Bavaria       Anna     Brunner
# 14481   30-05-2024 7:28:33           Karma Bavaria    Bormann      Silvia
# 14482   30-05-2024 7:12:04           Karma Bavaria  Christoph      Depner
#
#                                Email          Phone           Lead Brand  \
# 0          margaretmccrckn@gmail.com       4.48e+18  Timeshare Marketing
# 1            sambit2705.uk@gmail.com       4.41e+18  Timeshare Marketing
# 2                 aeande@hotmail.com        4.5e+18  Timeshare Marketing
# 3         kerrie.sicard@yahoo.com.au        6.1e+18  Timeshare Marketing
# 4      kantharajuprakruthi@gmail.com       9.19e+18  Timeshare Marketing
# ...                              ...            ...                  ...
# 14478       susannedewald4@gmail.com    49613144343  Timeshare Marketing
# 14479          ishwari2604@gmail.com   919372758771  Timeshare Marketing
# 14480       brunner.anna26@gmail.com  4915141291029  Timeshare Marketing
# 14481       silvia.bormann@gmail.com  4917666699852  Timeshare Marketing
# 14482          christophd89@yahoo.de   491747642423  Timeshare Marketing
#
#       Lead Sub-Brand Lead Source Lead Source Description  Email Opt Out  \
# 0              Other        Wifi                 Beambox          False
# 1              Other        Wifi                 Beambox          False
# 2              Other        Wifi                 Beambox          False
# 3              Other        Wifi                 Beambox          False
# 4              Other        Wifi                 Beambox          False
# ...              ...         ...                     ...            ...
# 14478          Other        Wifi                 Beambox          False
# 14479          Other        Wifi                 Beambox          False
# 14480          Other        Wifi                 Beambox          False
# 14481          Other        Wifi                 Beambox          False
# 14482          Other        Wifi                 Beambox          False
#
#        Opt In  Do Not Contact  Do Not Mail
# 0        True           False        False
# 1        True           False        False
# 2        True           False        False
# 3        True           False        False
# 4        True           False        False
# ...       ...             ...          ...
# 14478    True           False        False
# 14479    True           False        False
# 14480    True           False        False
# 14481    True           False        False
# 14482    True           False        False
#
# [14483 rows x 14 columns]

# %%
df_final.replace('empty', '', inplace=True, regex=True)
df_final.loc[df_final['Phone'].str.len() < 3, 'Phone'] = ''

# %%
# df_final.to_excel(r'C:\Users\fajar\Documents\Python\Data\update_beambox.xlsx', index=False)

# %%
SHEET_NAME_UPDATE = 'Update Beambox'
# SHEET_NAME_UPDATE = 'Test'
worksheet_update= spreadsheet.worksheet(SHEET_NAME_UPDATE)
worksheet_update.clear()

worksheet_update.update([df_final.columns.values.tolist()] + df_final.values.tolist())
# Out:
# {'spreadsheetId': '1FZ4bgWOEiVsbICA0WcG7DmBmjqA58v7ZdpiRZrARCqY',
#  'updatedRange': "'Update Beambox'!A1:N14484",
#  'updatedRows': 14484,
#  'updatedColumns': 14,
#  'updatedCells': 202776}
