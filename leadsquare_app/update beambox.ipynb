# %%
import sys
sys.path.append('../zoho_data_app')

import main_module as m
import pandas as pd
import re

import gspread

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
gc = gspread.oauth(
    credentials_filename= r'C:\Users\fajar\Documents\Python\Data\test.json'
)

SHEET_ID = '1FZ4bgWOEiVsbICA0WcG7DmBmjqA58v7ZdpiRZrARCqY'
SHEET_NAME_KLOM = 'KLOM'
SHEET_NAME_KSH = 'KSH'
SHEET_NAME_KB = 'KB'
SHEET_NAME_LSQ = 'Done in LSQ'
SHEET_NAME_API = 'API'

# get data gsheet

spreadsheet = gc.open_by_key(SHEET_ID)

worksheet_klom= spreadsheet.worksheet(SHEET_NAME_KLOM)
rows_klom = worksheet_klom.get_all_records()
df_klom = pd.DataFrame(rows_klom)
df_klom['Lead Location'] = 'Karma Lake Of Menteith'

worksheet_ksh= spreadsheet.worksheet(SHEET_NAME_KSH)
rows_ksh = worksheet_ksh.get_all_records()
df_ksh = pd.DataFrame(rows_ksh)
df_ksh['Lead Location'] = 'Karma Salford Hall'

worksheet_kb= spreadsheet.worksheet(SHEET_NAME_KB)
rows_kb = worksheet_kb.get_all_records()
df_kb = pd.DataFrame(rows_kb)
df_kb['Lead Location'] = 'Karma Bavaria'

worksheet_lsq= spreadsheet.worksheet(SHEET_NAME_LSQ)
rows_lsq = worksheet_lsq.get_all_records()
df_lsq = pd.DataFrame(rows_lsq)

worksheet_api= spreadsheet.worksheet(SHEET_NAME_API)
rows_api = worksheet_api.get_all_records()
df_api = pd.DataFrame(rows_api)

df_klom
# Out:
#                      Full Name First Name Last Name  \
# 0                 Brenda Clift
# 1            Aqil Mangalassery
# 2               Alvaro Ramirez
# 3         Muhammed Basheer M K   Muhammed         K
# 4               Alison Mc Lean
# ...                        ...        ...       ...
# 7438      Jessa Marie Pimentel      Jessa  Pimentel
# 7439  Mike Sinclair Uw Partner       Mike   Partner
# 7440      Rochelle Mc Laughlin   Rochelle  Laughlin
# 7441                Josh Mayes       Josh     Mayes
# 7442             John E Entity       John    Entity
#
#                                    Email Phone Gender Date of Birth  \
# 0                  clift1@btinternet.com                   ########
# 1             aqilmangalassery@gmail.com                   6/7/1996
# 2              alvaroramirez74@gmail.com                   ########
# 3                mkmohdbasheer@gmail.com                   ########
# 4            alimac_scotland@yahoo.co.uk                   6/8/1954
# ...                                  ...   ...    ...           ...
# 7438    cabarles.jessamarie@yahoo.com.ph
# 7439        michael.sinclair@uw.partners
# 7440  rochelle_mclaughlin101@hotmail.com
# 7441                 jmayes697@gmail.com
# 7442     curiousorange666@googlemail.com
#
#      Nationality    Source  Visits  ...          First Login  \
# 0                    Email      19  ...             ########
# 1                    Email       2  ...  13-09-2024 20:49:06
# 2                    Email     319  ...             ########
# 3                    Email       2  ...  13-09-2024 21:12:55
# 4                    Email       3  ...             ########
# ...          ...       ...     ...  ...                  ...
# 7438              Facebook       0  ...
# 7439              Facebook       0  ...
# 7440              Facebook       0  ...
# 7441              Facebook       0  ...
# 7442              Facebook       0  ...
#
#                Last Login                Location Marketing Opt-in  \
# 0      16-09-2024 0:11:38  Karma Lake of Menteith            FALSE
# 1     15-09-2024 22:23:25  Karma Lake of Menteith            FALSE
# 2      15-09-2024 8:13:19  Karma Lake of Menteith            FALSE
# 3     15-09-2024 21:58:58  Karma Lake of Menteith             TRUE
# 4     15-09-2024 21:15:58  Karma Lake of Menteith             TRUE
# ...                   ...                     ...              ...
# 7438                                                          TRUE
# 7439                                                          TRUE
# 7440                                                          TRUE
# 7441                                                          TRUE
# 7442                                                          TRUE
#
#             MAC Address  \
# 0     76:82:42:f7:5b:91
# 1     56:a9:0f:97:8a:16
# 2     9c:b6:d0:e1:06:29
# 3     2e:5a:89:be:e5:a3
# 4     fc:fc:48:2a:96:a9
# ...                 ...
# 7438
# 7439
# 7440
# 7441
# 7442
#
#      I Agree To Being Contacted By Karma Group. You Can Unsubscribe At Any Time, Please See Karma Group’s Privacy Policy For More Information.  \
# 0
# 1
# 2
# 3
# 4
# ...                                                 ...
# 7438
# 7439
# 7440
# 7441
# 7442
#
#      I Agree To Being Contacted By Karma Group  \
# 0                                          Yes
# 1
# 2                                           No
# 3
# 4
# ...                                        ...
# 7438
# 7439
# 7440
# 7441
# 7442
#
#      Https://Karmagroup.Com/Privacy Policy/  \
# 0
# 1
# 2
# 3
# 4
# ...                                     ...
# 7438
# 7439
# 7440
# 7441
# 7442
#
#      I Agree  To Being Contacted By Karma Group           Lead Location
# 0                                                Karma Lake Of Menteith
# 1                                                Karma Lake Of Menteith
# 2                                                Karma Lake Of Menteith
# 3                                                Karma Lake Of Menteith
# 4                                                Karma Lake Of Menteith
# ...                                         ...                     ...
# 7438                                             Karma Lake Of Menteith
# 7439                                             Karma Lake Of Menteith
# 7440                                             Karma Lake Of Menteith
# 7441                                             Karma Lake Of Menteith
# 7442                                             Karma Lake Of Menteith
#
# [7443 rows x 23 columns]

# %%
df_offline_join = pd.concat([df_klom,df_ksh,df_kb])
df_offline_join.loc[df_offline_join['Email'] == '','Email'] = 'empty'
df_offline_join.loc[df_offline_join['Phone'] == '','Email'] = 'empty'

# %% [markdown]
# # ====================== Awal Filter Umum ======================

# %%
# data phone, mobile dam email member yang ada di master data (wash member)

m.clean_number(df_offline_join, 'Phone')
m.replace_not_valid_to_empty(df_offline_join, 'Phone')
df_offline_join['Email'] = m.lowercase(df_offline_join, 'Email')
m.clean_space(df_offline_join, 'Email')

m.clean_number(df_lsq, 'Phone')
df_lsq['Email'] = m.lowercase(df_lsq, 'Email')
m.clean_space(df_lsq, 'Email')

m.clean_number(df_api, 'Phone')
df_lsq['Email'] = m.lowercase(df_api, 'Email')
m.clean_space(df_api, 'Email')
# Out:
# 0               descaldicott@hotmail.com
# 1                  jimmeebee@hotmail.com
# 2                   chrisband7@gmail.com
# 3                trowe640@btinternet.com
# 4                 christina@di-nolfo.com
#                       ...
# 3028    peterandsarahglad@btinternet.com
# 3029                  kks61412@gmail.com
# 3030              john.douglass@mail.com
# 3031           bretthanrahan30@gmail.com
# 3032            christina.stepper@hkm.de
# Name: Email, Length: 3033, dtype: object

# %% [markdown]
# # ====================== Akhir Filter Umum ======================

# %%
# hitung jumlah duplicate
count_duplicate_general = df_offline_join.loc[df_offline_join.duplicated(subset=['Email'])].shape[0]

df_offline_join.loc[df_offline_join.duplicated(subset=['Email'])]
# Out:
#                  Full Name First Name  Last Name                      Email  \
# 1        Aqil Mangalassery                                            empty
# 2           Alvaro Ramirez                                            empty
# 3     Muhammed Basheer M K   Muhammed          K                      empty
# 4           Alison Mc Lean                                            empty
# 5            Alekh Chapman                                            empty
# ...                    ...        ...        ...                        ...
# 2026         Ashton Dsouza     Ashton     Dsouza  dr.ashtondsouza@gmail.com
# 2057     Gowri Manoj Kumar      Gowri      Kumar       gowrimanoj@gmail.com
# 2062          Irvan Fauzie      Irvan     Fauzie                      empty
# 2063    Valerios Koutsonis   Valerios  Koutsonis                      empty
# 2064          Irvan Fauzie      Irvan     Fauzie                      empty
#
#              Phone Gender Date of Birth Nationality  Source  Visits  ...  \
# 1            empty             6/7/1996               Email       2  ...
# 2            empty             ########               Email     319  ...
# 3            empty             ########               Email       2  ...
# 4            empty             6/8/1954               Email       3  ...
# 5            empty             ########               Email       2  ...
# ...            ...    ...           ...         ...     ...     ...  ...
# 2026  919880664143            10/9/1986               Email       1  ...
# 2057  440753936827            1/28/1978               Email       1  ...
# 2062         empty                                   Import       0  ...
# 2063         empty                                   Import       0  ...
# 2064         empty                                   Import       0  ...
#
#                Last Login                Location Marketing Opt-in  \
# 1     15-09-2024 22:23:25  Karma Lake of Menteith            FALSE
# 2      15-09-2024 8:13:19  Karma Lake of Menteith            FALSE
# 3     15-09-2024 21:58:58  Karma Lake of Menteith             TRUE
# 4     15-09-2024 21:15:58  Karma Lake of Menteith             TRUE
# 5     15-09-2024 14:50:37  Karma Lake of Menteith            FALSE
# ...                   ...                     ...              ...
# 2026   31-05-2024 8:16:56           Karma Bavaria             TRUE
# 2057   30-05-2024 8:03:38           Karma Bavaria             TRUE
# 2062                                                          TRUE
# 2063                                                          TRUE
# 2064                                                          TRUE
#
#             MAC Address  \
# 1     56:a9:0f:97:8a:16
# 2     9c:b6:d0:e1:06:29
# 3     2e:5a:89:be:e5:a3
# 4     fc:fc:48:2a:96:a9
# 5     c6:c6:c4:f6:70:21
# ...                 ...
# 2026  82:aa:c0:19:85:e1
# 2057  ce:0f:22:25:4e:55
# 2062
# 2063
# 2064
#
#      I Agree To Being Contacted By Karma Group. You Can Unsubscribe At Any Time, Please See Karma Group’s Privacy Policy For More Information.  \
# 1
# 2
# 3
# 4
# 5
# ...                                                 ...
# 2026                                                NaN
# 2057                                                NaN
# 2062                                                NaN
# 2063                                                NaN
# 2064                                                NaN
#
#      I Agree To Being Contacted By Karma Group  \
# 1
# 2                                           No
# 3
# 4
# 5
# ...                                        ...
# 2026                                       NaN
# 2057                                       NaN
# 2062                                       NaN
# 2063                                       NaN
# 2064                                       NaN
#
#      Https://Karmagroup.Com/Privacy Policy/  \
# 1
# 2
# 3
# 4
# 5
# ...                                     ...
# 2026                                    NaN
# 2057                                    NaN
# 2062                                    NaN
# 2063                                    NaN
# 2064                                    NaN
#
#      I Agree  To Being Contacted By Karma Group           Lead Location  \
# 1                                                Karma Lake Of Menteith
# 2                                                Karma Lake Of Menteith
# 3                                                Karma Lake Of Menteith
# 4                                                Karma Lake Of Menteith
# 5                                                Karma Lake Of Menteith
# ...                                         ...                     ...
# 2026                                        NaN           Karma Bavaria
# 2057                                        NaN           Karma Bavaria
# 2062                                        NaN           Karma Bavaria
# 2063                                        NaN           Karma Bavaria
# 2064                                        NaN           Karma Bavaria
#
#      Room Number
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
# 5            NaN
# ...          ...
# 2026         NaN
# 2057         NaN
# 2062         NaN
# 2063         NaN
# 2064         NaN
#
# [2873 rows x 24 columns]

# %%
df_offline_join.drop_duplicates(subset=['Email'], inplace=True)
df_offline_join.reset_index(drop=True, inplace=True)

# hitung jumlah setelah value duplicate dihapus
count_after_dedup_duplicate = df_offline_join.shape[0]

count_data_gabungan = df_offline_join.shape[0]
df_offline_join
# Out:
#                  Full Name First Name  Last Name                        Email  \
# 0             Brenda Clift                                              empty
# 1       Margaret Mccracken   Margaret  Mccracken    margaretmccrckn@gmail.com
# 2      Sambit Kumar Mishra                            sambit2705.uk@gmail.com
# 3      Harish Kutty Shetty     Harish     Shetty           aeande@hotmail.com
# 4            Kerrie Sicard                         kerrie.sicard@yahoo.com.au
# ...                    ...        ...        ...                          ...
# 17378     Edwin Jose Sunil      Edwin      Sunil  edwinjosesunil584@gmail.com
# 17379      Ishwari Chhatre    Ishwari    Chhatre        ishwari2604@gmail.com
# 17380         Anna Brunner       Anna    Brunner     brunner.anna26@gmail.com
# 17381       Bormann Silvia    Bormann     Silvia     silvia.bormann@gmail.com
# 17382     Christoph Depner  Christoph     Depner        christophd89@yahoo.de
#
#                Phone Gender Date of Birth Nationality Source  Visits  ...  \
# 0              empty             ########              Email      19  ...
# 1       447887761443                                   Email     191  ...
# 2      4407404281293                                   Email       4  ...
# 3       449898033013                                   Email       3  ...
# 4       610418673095                                   Email       6  ...
# ...              ...    ...           ...         ...    ...     ...  ...
# 17378   491782913994            5/24/2008              Email       1  ...
# 17379   919372758771            4/26/2004              Email       1  ...
# 17380  4915141291029            3/26/2006              Email       1  ...
# 17381  4917666699852           12/23/1969              Email       1  ...
# 17382   491747642423           11/25/1989              Email       1  ...
#
#                Last Login                Location Marketing Opt-in  \
# 0      16-09-2024 0:11:38  Karma Lake of Menteith            FALSE
# 1                ########  Karma Lake of Menteith             TRUE
# 2                ########  Karma Lake of Menteith            FALSE
# 3                ########  Karma Lake of Menteith             TRUE
# 4                ########  Karma Lake of Menteith            FALSE
# ...                   ...                     ...              ...
# 17378  30-05-2024 8:19:47           Karma Bavaria             TRUE
# 17379  30-05-2024 7:39:59           Karma Bavaria            FALSE
# 17380  30-05-2024 7:36:52           Karma Bavaria            FALSE
# 17381  30-05-2024 7:28:33           Karma Bavaria             TRUE
# 17382  30-05-2024 7:12:04           Karma Bavaria            FALSE
#
#              MAC Address  \
# 0      76:82:42:f7:5b:91
# 1      06:f6:62:f6:8a:da
# 2      70:a8:d3:9d:60:8e
# 3      72:fe:f3:f2:ce:dc
# 4      ba:ce:40:fc:c5:2f
# ...                  ...
# 17378  ec:8c:9a:84:7f:de
# 17379  b6:ed:53:56:17:e5
# 17380  ca:ae:bc:c4:59:1b
# 17381  e6:c4:aa:47:ba:68
# 17382  0e:af:6c:ac:7f:b9
#
#       I Agree To Being Contacted By Karma Group. You Can Unsubscribe At Any Time, Please See Karma Group’s Privacy Policy For More Information.  \
# 0
# 1
# 2
# 3
# 4
# ...                                                  ...
# 17378                                                NaN
# 17379                                                NaN
# 17380                                                NaN
# 17381                                                NaN
# 17382                                                NaN
#
#       I Agree To Being Contacted By Karma Group  \
# 0                                           Yes
# 1                                           Yes
# 2                                           Yes
# 3                                            No
# 4                                           Yes
# ...                                         ...
# 17378                                       NaN
# 17379                                       NaN
# 17380                                       NaN
# 17381                                       NaN
# 17382                                       NaN
#
#       Https://Karmagroup.Com/Privacy Policy/  \
# 0
# 1
# 2
# 3
# 4
# ...                                      ...
# 17378                                    NaN
# 17379                                    NaN
# 17380                                    NaN
# 17381                                    NaN
# 17382                                    NaN
#
#       I Agree  To Being Contacted By Karma Group           Lead Location  \
# 0                                                 Karma Lake Of Menteith
# 1                                                 Karma Lake Of Menteith
# 2                                                 Karma Lake Of Menteith
# 3                                                 Karma Lake Of Menteith
# 4                                                 Karma Lake Of Menteith
# ...                                          ...                     ...
# 17378                                        NaN           Karma Bavaria
# 17379                                        NaN           Karma Bavaria
# 17380                                        NaN           Karma Bavaria
# 17381                                        NaN           Karma Bavaria
# 17382                                        NaN           Karma Bavaria
#
#       Room Number
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
# ...           ...
# 17378         NaN
# 17379         NaN
# 17380         NaN
# 17381         NaN
# 17382         NaN
#
# [17383 rows x 24 columns]

# %%
# data phone, mobile dam email member yang ada di master data 
count_wash_before = df_offline_join.loc[
    df_offline_join['Phone'].isin(df_lsq['Phone']) | 
    df_offline_join['Email'].isin(df_lsq['Email'])| 

    df_offline_join['Phone'].isin(df_api['Phone']) | 

    df_offline_join['Email'].isin(df_api['Email'])

].shape[0]

df_offline_join.drop(df_offline_join.loc[
    df_offline_join['Phone'].isin(df_lsq['Phone']) | 
    df_offline_join['Email'].isin(df_lsq['Email'])| 

    df_offline_join['Phone'].isin(df_api['Phone']) | 

    df_offline_join['Email'].isin(df_api['Email'])

    ].index, inplace=True)
    
df_offline_join.reset_index(drop=True, inplace=True)

count_after_wash_before = df_offline_join.shape[0]

# %%
# data phone, mobile dam email member yang ada di master data 
count_wash_contact_empty = df_offline_join.loc[
    (df_offline_join['Email'] == 'empty') & 
    (df_offline_join['Phone'] == 'empty')
    
].shape[0]

df_offline_join.drop(df_offline_join.loc[
    (df_offline_join['Email'] == 'empty') & 
    (df_offline_join['Phone'] == 'empty')
    ].index, inplace=True)
    
df_offline_join.reset_index(drop=True, inplace=True)

count_after_wash_contact_empty = df_offline_join.shape[0]

# %%
print("==========================================================")
print("Summary")
print("==========================================================")
print("Jumlah Filter Leads Awal : "+str(count_data_gabungan))
print("Jumlah Duplicate (Phone, Mobile dan Email) : "+str(count_duplicate_general))
print("Jumlah Setelah Clean Duplicate : "+str(count_after_dedup_duplicate))
print("Jumlah Wash Before : "+str(count_wash_before))
print("Jumlah Setelah Wash Member : "+str(count_after_wash_before))
print("Jumlah Wash Empty Contact : "+str(count_wash_contact_empty))
print("Jumlah Setelah Wash Empty Contact : "+str(count_after_wash_contact_empty))
# Out:
# ==========================================================
# Summary
# ==========================================================
# Jumlah Filter Leads Awal : 17383
# Jumlah Duplicate (Phone, Mobile dan Email) : 2873
# Jumlah Setelah Clean Duplicate : 17383
# Jumlah Wash Before : 10734
# Jumlah Setelah Wash Member : 6649
# Jumlah Wash Empty Contact : 1
# Jumlah Setelah Wash Empty Contact : 6648

# %%
df_final = pd.DataFrame()
df_final['Created Time'] = df_offline_join['First Visit'].copy()
df_final['Lead Location'] = df_offline_join['Lead Location'].copy()
df_final['First Name'] = df_offline_join['First Name'].copy()
df_final['Last Name'] = df_offline_join['Last Name'].copy()
df_final['Email'] = df_offline_join['Email'].copy()
df_final['Phone'] = df_offline_join['Phone'].copy()
df_final['Lead Brand'] = 'Timeshare Marketing'
df_final['Lead Sub-Brand'] = 'Other'
df_final['Lead Source'] = 'Wifi'
df_final['Lead Source Description'] = 'Beambox'
df_final['Email Opt Out'] = False
df_final['Opt In'] = True
df_final['Do Not Contact'] = False
df_final['Do Not Mail'] = False

df_final['Phone'] = df_final['Phone'].astype("string")

df_final['Phone'].replace('^440','44', regex=True, inplace=True)
df_final
# Out:
#             Created Time           Lead Location First Name Last Name  \
# 0               ########  Karma Lake Of Menteith     Harish    Shetty
# 1               ########  Karma Lake Of Menteith
# 2               ########  Karma Lake Of Menteith
# 3               ########  Karma Lake Of Menteith
# 4               ########  Karma Lake Of Menteith
# ...                  ...                     ...        ...       ...
# 6643  30-05-2024 8:19:47           Karma Bavaria      Edwin     Sunil
# 6644  30-05-2024 7:39:59           Karma Bavaria    Ishwari   Chhatre
# 6645  30-05-2024 7:36:52           Karma Bavaria       Anna   Brunner
# 6646  30-05-2024 7:28:33           Karma Bavaria    Bormann    Silvia
# 6647  30-05-2024 7:12:04           Karma Bavaria  Christoph    Depner
#
#                             Email          Phone           Lead Brand  \
# 0              aeande@hotmail.com   449898033013  Timeshare Marketing
# 1      kerrie.sicard@yahoo.com.au   610418673095  Timeshare Marketing
# 2       allan.sicard@yahoo.com.au   610447443339  Timeshare Marketing
# 3             premsharma1@aol.com   447840806773  Timeshare Marketing
# 4     panigrahi.saswati@gmail.com   447448243673  Timeshare Marketing
# ...                           ...            ...                  ...
# 6643  edwinjosesunil584@gmail.com   491782913994  Timeshare Marketing
# 6644        ishwari2604@gmail.com   919372758771  Timeshare Marketing
# 6645     brunner.anna26@gmail.com  4915141291029  Timeshare Marketing
# 6646     silvia.bormann@gmail.com  4917666699852  Timeshare Marketing
# 6647        christophd89@yahoo.de   491747642423  Timeshare Marketing
#
#      Lead Sub-Brand Lead Source Lead Source Description  Email Opt Out  \
# 0             Other        Wifi                 Beambox          False
# 1             Other        Wifi                 Beambox          False
# 2             Other        Wifi                 Beambox          False
# 3             Other        Wifi                 Beambox          False
# 4             Other        Wifi                 Beambox          False
# ...             ...         ...                     ...            ...
# 6643          Other        Wifi                 Beambox          False
# 6644          Other        Wifi                 Beambox          False
# 6645          Other        Wifi                 Beambox          False
# 6646          Other        Wifi                 Beambox          False
# 6647          Other        Wifi                 Beambox          False
#
#       Opt In  Do Not Contact  Do Not Mail
# 0       True           False        False
# 1       True           False        False
# 2       True           False        False
# 3       True           False        False
# 4       True           False        False
# ...      ...             ...          ...
# 6643    True           False        False
# 6644    True           False        False
# 6645    True           False        False
# 6646    True           False        False
# 6647    True           False        False
#
# [6648 rows x 14 columns]

# %%
df_final.replace('empty', '', inplace=True, regex=True)
df_final.loc[df_final['Phone'].str.len() < 3, 'Phone'] = ''

# %%
# df_final.to_excel(r'C:\Users\fajar\Documents\Python\Data\update_beambox.xlsx', index=False)

# %%
SHEET_NAME_UPDATE = 'Update Beambox'
# SHEET_NAME_UPDATE = 'Test'
worksheet_update= spreadsheet.worksheet(SHEET_NAME_UPDATE)
worksheet_update.clear()

worksheet_update.update([df_final.columns.values.tolist()] + df_final.values.tolist())
# Out:
# {'spreadsheetId': '1FZ4bgWOEiVsbICA0WcG7DmBmjqA58v7ZdpiRZrARCqY',
#  'updatedRange': "'Update Beambox'!A1:N6649",
#  'updatedRows': 6649,
#  'updatedColumns': 14,
#  'updatedCells': 93086}
