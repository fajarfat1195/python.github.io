# %%
import pandas as pd
import gspread

file_path = r'G:\.shortcut-targets-by-id\1BKe3lpZLP3aj_PPa_Bai9V8nzzywN1RZ\_Toni\Member Data\MEMBER ALL.xlsx'

# %%
all_dfs = pd.read_excel(file_path, sheet_name=None)
df = pd.concat(all_dfs, keys=all_dfs,
    names=['Category', None],
    ).reset_index(level='Category')   
df.reset_index(drop=True, inplace=True)
df
# Out:
#                               Category  Account ID  ContactID     FirstName  \
# 0          Karma Club 2021 - Indonesia     1020665     994461         Melia
# 1      Karma Club 2021 - Non Indonesia     1014893     977080        Andrew
# 2      Karma Club 2021 - Non Indonesia     1015230     943406         Sarah
# 3      Karma Club 2021 - Non Indonesia     1015693     977628      Jennifer
# 4      Karma Club 2021 - Non Indonesia     1015694     977652      Felicity
# ...                                ...         ...        ...           ...
# 62773               KCID-Non Indonesia       66328     198495        Bianca
# 62774               KCID-Non Indonesia       75280      81854   Mas Nawi Md
# 62775               KCID-Non Indonesia       75280      81854   Mas Nawi Md
# 62776               KCID-Non Indonesia       75280      81854   Mas Nawi Md
# 62777               KCID-Non Indonesia      979535    1005719  Maria Olyvia
#
#        LastName       AddressLine1  \
# 0       Silmina            Jakarta
# 1        Wright       Barley House
# 2        Tellis  NANTOER, ASHCURCH
# 3       Hickton   5 Hobs Hole Lane
# 4      Sharland  3 Noddy Park Road
# ...         ...                ...
# 62773  Sugiarto                  .
# 62774       Zin           BLK 305C
# 62775       Zin           BLK 305C
# 62776       Zin           BLK 305C
# 62777   Samosir                  -
#
#                                      AddressLine2         Town  \
# 0                                             NaN      Jakarta
# 1                              Drayton St Leonard  Wallingford
# 2                                             NaN   TEWKESBURY
# 3                                             NaN     Aldridge
# 4                                        Aldridge     Aldridge
# ...                                           ...          ...
# 62773                    TAMAN BOTANIK, JAGAKARSA            .
# 62774                      ANCHORVALE LINK #04-33            -
# 62775                      ANCHORVALE LINK #04-33            -
# 62776                      ANCHORVALE LINK #04-33            -
# 62777  RT/RW: 003/012 PONDOK RANJI, CIPUTAT TIMUR            -
#
#                   City         Country  ... Keywords NoEDM Account Status  \
# 0              Jakarta       Indonesia  ...      NaN   NaN         Active
# 1          Oxfordshire  United Kingdom  ...      NaN   NaN         Active
# 2      Gloucestershire  United Kingdom  ...      NaN   NaN         Active
# 3        West Midlands  United Kingdom  ...      NaN   NaN         Active
# 4        West Midlands  United Kingdom  ...      NaN   NaN         Active
# ...                ...             ...  ...      ...   ...            ...
# 62773                .       Indonesia  ...      NaN   NaN         Active
# 62774                -       Singapore  ...      NaN   NaN         Active
# 62775                -       Singapore  ...      NaN   NaN         Active
# 62776                -       Singapore  ...      NaN   NaN         Active
# 62777                -       Indonesia  ...      NaN   NaN         Active
#
#           Account Type  OdysseyNo      Servicing Office  \
# 0      KARMA CLUB 2021        NaN  KARMA CONCIERGE BALI
# 1      KARMA CLUB 2021        NaN     KARMA CLUB EUROPE
# 2      KARMA CLUB 2021        NaN     KARMA CLUB EUROPE
# 3      KARMA CLUB 2021        NaN     KARMA CLUB EUROPE
# 4      KARMA CLUB 2021        NaN     KARMA CLUB EUROPE
# ...                ...        ...                   ...
# 62773       KARMA CLUB  C82013297  KARMA CONCIERGE BALI
# 62774       KARMA CLUB  C82022270  KARMA CONCIERGE BALI
# 62775       KARMA CLUB  C82022270  KARMA CONCIERGE BALI
# 62776       KARMA CLUB  C82022270  KARMA CONCIERGE BALI
# 62777       KARMA CLUB  C82046405  KARMA CONCIERGE BALI
#
#                                 Email Unnamed: 23  Unnamed: 24 segment
# 0              mellysilmina@gmail.com         NaN          NaN     NaN
# 1      andrew.wright55@btinternet.com         NaN          NaN     NaN
# 2                sarah.tellis@sky.com         NaN          NaN     NaN
# 3                    jmch48@gmail.com         NaN          NaN     NaN
# 4             anne.sharland@gmail.com         NaN          NaN     NaN
# ...                               ...         ...          ...     ...
# 62773       bianca.sugiarto@gmail.com         NaN          NaN     NaN
# 62774                qbesli@gmail.com         NaN          NaN     NaN
# 62775            eska6284@hotmail.com         NaN          NaN     NaN
# 62776                qbesli@gmail.com         NaN          NaN     NaN
# 62777     mariaolyvia.lyvia@gmail.com         NaN          NaN     NaN
#
# [62778 rows x 27 columns]

# %%
df.columns
# Out:
# Index(['Category', 'Account ID', 'ContactID', 'FirstName', 'LastName',
#        'AddressLine1', 'AddressLine2', 'Town', 'City', 'Country', 'Post Code',
#        'Phones', 'Owner', 'Family', 'Nationality', 'DoB', 'WeddingDate',
#        'Keywords', 'NoEDM', 'Account Status', 'Account Type', 'OdysseyNo',
#        'Servicing Office', 'Email', 'Unnamed: 23', 'Unnamed: 24', 'segment'],
#       dtype='object')

# %%
df = df.reindex(columns=['Account ID', 'ContactID', 'FirstName', 'LastName',
       'AddressLine1', 'AddressLine2', 'Town', 'City', 'Country', 'Post Code',
       'Phones', 'Owner', 'Family', 'Nationality', 'DoB', 'WeddingDate',
       'Keywords', 'NoEDM', 'Account Status', 'Account Type', 'OdysseyNo',
       'Servicing Office', 'Email','Category'])

# %%
df.sort_values(['Account ID', 'DoB'], ascending=True, inplace=True)
df_clean = df.copy()

# %%
# hitung jumlah duplicate
count_duplicate_general = df_clean.loc[df_clean.duplicated(subset=['Account ID'])].shape[0]

df_clean.loc[df_clean.duplicated(subset=['Account ID'])]
# Out:
#        Account ID  ContactID    FirstName     LastName  \
# 36578          14     814558       Akarsh    Sudarshan
# 36581          14     814558       Akarsh    Sudarshan
# 36580          14     842834         Roma       Ganesh
# 38497          25      27707        V. S.  Jayashankar
# 38887          31      34238      Padmini  Nagachandra
# ...           ...        ...          ...          ...
# 17831     1110264    1092118       Michel       Dumont
# 17834     1110268    1092130      Jocelyn     Luansing
# 4076      1110270    1092133      Stephen    Grimstone
# 60960     1110284    1092154  Paramananda    Ponnaiyan
# 60962     1110284    1092154  Paramananda    Ponnaiyan
#
#                                         AddressLine1        AddressLine2  \
# 36578              #368, 14TH CROSS, SADASHIVANAGAR,                 NaN
# 36581              #368, 14TH CROSS, SADASHIVANAGAR,                 NaN
# 36580              #368, 14TH CROSS, SUDASHIVANAGAR,                 NaN
# 38497                              KALPAVRIKSHA # 13  BRUNTON CROSS ROAD
# 38887                   NO.1628, 8TH MAIN, 3RD BLOCK           JAYANAGAR
# ...                                              ...                 ...
# 17831                        17440 RUE DU GRAND PRIX                   -
# 17834                               278 W 6TH STREET                   -
# 4076                                  19 ELANA COURT             CROYDON
# 60960  B-906 MAANGALYA ASHIRWAD  OPP. KOLI FARM GATE     BANNERGHATTA RD
# 60962  B-906 MAANGALYA ASHIRWAD  OPP. KOLI FARM GATE     BANNERGHATTA RD
#
#             Town        City    Country Post Code  ...         DoB  \
# 36578  BANGALORE   KARNATAKA      India    560080  ...  1989-02-19
# 36581  BANGALORE   KARNATAKA      India    560080  ...  1989-02-19
# 36580  BANGALORE   KARNATAKA      India    560080  ...  1989-10-20
# 38497  BANGALORE          KA      India   560 025  ...         NaN
# 38887  BANGALORE          KA      India   560 011  ...         NaN
# ...          ...         ...        ...       ...  ...         ...
# 17831    MIRABEL      QUEBEC     Canada   J7J 2M3  ...  1958-03-14
# 17834  PITTSBURG  CALIFORNIA        USA     94565  ...  1988-06-30
# 4076   MELBOURNE    VICTORIA  Australia      3136  ...  1952-06-21
# 60960  BANGALORE   KARNATAKA      India    560083  ...  1980-07-13
# 60962  BANGALORE   KARNATAKA      India    560083  ...  1980-07-13
#
#       WeddingDate Keywords NoEDM    Account Status  Account Type  OdysseyNo  \
# 36578         NaN      NaN   NaN            Active    KARMA CLUB  C82001700
# 36581         NaN      NaN   NaN            Active    KARMA CLUB  C82001700
# 36580         NaN      NaN   NaN            Active    KARMA CLUB  C82001700
# 38497         NaN      NaN   NaN            Active  WEEKS MEMBER  C82020365
# 38887         NaN      NaN   NaN     Active / Open    FRACTIONAL  D89100419
# ...           ...      ...   ...               ...           ...        ...
# 17831         NaN      NaN   NaN  Open Deal Member    KARMA CLUB        NaN
# 17834         NaN      NaN   NaN  Open Deal Member    KARMA CLUB        NaN
# 4076          NaN      NaN   NaN            Active    KARMA CLUB  C82050436
# 60960         NaN      NaN   NaN  Open Deal Member    KARMA CLUB        NaN
# 60962         NaN      NaN   NaN  Open Deal Member    KARMA CLUB        NaN
#
#             Servicing Office                        Email             Category
# 36578  KARMA CONCIERGE INDIA          15.akarsh@gmail.com                  KCI
# 36581  KARMA CONCIERGE INDIA          15.akarsh@gmail.com                  KCI
# 36580  KARMA CONCIERGE INDIA        roma.ganesh@gmail.com                  KCI
# 38497  KARMA CONCIERGE INDIA    pvjayashankar@hotmail.com                  KCI
# 38887  KARMA CONCIERGE INDIA      sknagachandra@gmail.com                  KCI
# ...                      ...                          ...                  ...
# 17831   KARMA CONCIERGE BALI          rodupomi@hotmail.ca  KCB - Non Indonesia
# 17834   KARMA CONCIERGE BALI         jbluansing@gmail.com  KCB - Non Indonesia
# 4076    KARMA CONCIERGE BALI  stephengrimstone@henkel.com  KCB - Non Indonesia
# 60960  KARMA CONCIERGE INDIA        palukkhanna@yahoo.com                  KCI
# 60962  KARMA CONCIERGE INDIA    param.ponnaiyan@gmail.com                  KCI
#
# [30867 rows x 24 columns]

# %%
df_clean.drop_duplicates(subset=['Account ID'], inplace=True)
df_clean.reset_index(drop=True, inplace=True)

# hitung jumlah setelah value duplicate dihapus
count_after_dedup_duplicate = df_clean.shape[0]

df_clean
# Out:
#        Account ID  ContactID               FirstName      LastName  \
# 0               5      54901                       K      Ankaiyan
# 1              14     842833                   Leela     Sudarshan
# 2              20      23850                       .  Govindarajan
# 3              25      27707                   V. S.   Jayashankar
# 4              31      34238                 Padmini   Nagachandra
# ...           ...        ...                     ...           ...
# 31906     1110279    1092148                   Shiju        Thomas
# 31907     1110284    1092155                   Paluk        Khanna
# 31908     1110285    1092156             Sonal Kunal         Sheth
# 31909     1110297    1092180  Alpeshkumar Arvindbhai    Kanthariya
# 31910     1110309    1092193                  Victor     Nicholson
#
#                                         AddressLine1  \
# 0                            NO. 1671, 9TH MAIN ROAD
# 1                                                  -
# 2                             VI - 75/3, GURKHA CAMP
# 3                                  KALPAVRIKSHA # 13
# 4                       NO.1628, 8TH MAIN, 3RD BLOCK
# ...                                              ...
# 31906           EA-802 , PURVA ETERNITY THENGODE P O
# 31907  B-906 MAANGALYA ASHIRWAD  OPP. KOLI FARM GATE
# 31908                   C - 204, RAJ HEIGHTS CHS LTD
# 31909                             16 / 1, SABRIDHAM,
# 31910                   1154 BRIGHTON ROAD, BRIGHTON
#
#                                         AddressLine2       Town         City  \
# 0                            4TH CROSS HAL III STAGE  BANGALORE           KA
# 1                                                NaN          -            -
# 2                               WELLINGTON, NILGIRIS    COONOOR           TN
# 3                                 BRUNTON CROSS ROAD  BANGALORE           KA
# 4                                          JAYANAGAR  BANGALORE           KA
# ...                                              ...        ...          ...
# 31906                                       KAKKANAD      COCHN       KERALA
# 31907                                BANNERGHATTA RD  BANGALORE    KARNATAKA
# 31908  OPP VORA COLONY, M. G. ROAD, KANDIVALI (WEST)     MUMBAI  MAHARASHTRA
# 31909                        BHIMPOR DUMAS, CHORASI,      SURAT      GUJARAT
# 31910                                            NaN    DUNEDIN        OTAGO
#
#            Country Post Code  ...         DoB WeddingDate Keywords NoEDM  \
# 0            India   560 075  ...         NaN         NaN      NaN   NaN
# 1            India         -  ...  1969-03-03         NaN      NaN   NaN
# 2            India    643231  ...         NaN         NaN      NaN   NaN
# 3            India   560 025  ...         NaN         NaN      NaN   NaN
# 4            India   560 011  ...         NaN         NaN      NaN   NaN
# ...            ...       ...  ...         ...         ...      ...   ...
# 31906        India    682030  ...  1974-08-02         NaN      NaN   NaN
# 31907        India    560083  ...  1978-06-08         NaN      NaN   NaN
# 31908        India    400067  ...  1982-11-05         NaN      NaN   NaN
# 31909        India    394550  ...  1989-06-02         NaN      NaN   NaN
# 31910  New Zealand      9035  ...  1963-07-14         NaN      NaN   NaN
#
#              Account Status  Account Type  OdysseyNo       Servicing Office  \
# 0                    Active  WEEKS MEMBER  C82034750  KARMA CONCIERGE INDIA
# 1                    Active    KARMA CLUB  C82001700  KARMA CONCIERGE INDIA
# 2      Reminder Notice Sent  WEEKS MEMBER  C82003626  KARMA CONCIERGE INDIA
# 3                    Active  WEEKS MEMBER  C82020365  KARMA CONCIERGE INDIA
# 4             Active / Open    FRACTIONAL  D89100419  KARMA CONCIERGE INDIA
# ...                     ...           ...        ...                    ...
# 31906      Open Deal Member    KARMA CLUB        NaN  KARMA CONCIERGE INDIA
# 31907      Open Deal Member    KARMA CLUB        NaN  KARMA CONCIERGE INDIA
# 31908      Open Deal Member    KARMA CLUB        NaN  KARMA CONCIERGE INDIA
# 31909      Open Deal Member    KARMA CLUB        NaN  KARMA CONCIERGE INDIA
# 31910      Open Deal Member    KARMA CLUB        NaN   KARMA CONCIERGE BALI
#
#                                Email             Category
# 0               k.ankaiyan@gmail.com                  KCI
# 1                15.akarsh@gmail.com                  KCI
# 2            govind30008@yahoo.co.in                  KCI
# 3               viji1997@hotmail.com                  KCI
# 4      padmini.nagachandra@gmail.com                  KCI
# ...                              ...                  ...
# 31906             shiju74@icloud.com                  KCI
# 31907      param.ponnaiyan@gmail.com                  KCI
# 31908        shethkunal005@gmail.com                  KCI
# 31909   alpeshkanthariya41@gmail.com                  KCI
# 31910            nics5@hotmail.co.nz  KCB - Non Indonesia
#
# [31911 rows x 24 columns]

# %%
# df.loc[df['Account ID'] == 15345]
# df_clean.loc[df_clean['Account ID'] == 15345]

# %%
df_clean.sort_values(['Category', 'Account ID', 'DoB'], ascending=True, inplace=True)

# %%
# df_test_input = df_clean.iloc[0:5].copy()
# df_test_input.fillna('', inplace=True)

df_clean.fillna('', inplace=True)
df_clean.loc[(df_clean['DoB'] == '0000-00-00'), 'DoB'] = ''

# %%
# df_clean.to_excel(r'C:\Users\fajar\Documents\Python\Data\Member Clean Database(Account ID).xlsx', index=False)

# %%
gc = gspread.oauth(
    credentials_filename= r'C:\Users\fajar\Documents\Python\Data\Google Credentials\fajar-fatoni-OAuth.json'
)

SHEET_ID = '19yYAv0drTU-zG_9KKjDzAyTzeDmJ2YmQp02rUVxsLnE'
SHEET_NAME = 'Master Data'

# %%
def next_available_row(worksheet):
    str_list = worksheet.col_values(1)
    return str(len(str_list)+1)

# %%
# get data gsheet

spreadsheet = gc.open_by_key(SHEET_ID)
worksheet = spreadsheet.worksheet(SHEET_NAME)
rows = worksheet.get_all_records()

# print(rows[:5])

# print('==============================')
df_gsheets = pd.DataFrame(rows)
df_gsheets
# Out:
#        Account ID  ContactID    FirstName     LastName  \
# 0           35030      38716       Irvine      McMahon
# 1          131181      13696        Terry  Cruickshank
# 2          803010     467322       Alison        Blain
# 3          803570     467882    Kulvinder         Devi
# 4          902206     792866   Susan Jane       Milsom
# ...           ...        ...          ...          ...
# 31906     1049965     989757  Christopher       Morris
# 31907     1049969     989762        David  Betterridge
# 31908     1049970     989764       Andrew         Wall
# 31909     1062875    1009146        Arjun         Shah
# 31910     1105338    1082985         John        Craib
#
#                                             AddressLine1  AddressLine2  \
# 0      4 CRAWSHAW AVENUE BEVERLEY EAST RIDING OF YORK...
# 1                                4 PEEBLES LETHAM GRANGE      ARBROATH
# 2                                    56 JUBILEE CRESCENT
# 3                                         16 CRANFORD RD
# 4                                             TANGLEWOOD
# ...                                                  ...           ...
# 31906                               35 Theydon Park Road  Theydon Bois
# 31907                                          Rosegarth      The Mall
# 31908                                    Hackeridge Farm      Batts Ln
# 31909                                                  -             -
# 31910
#
#                                  Town           City         Country  \
# 0                            BEVERLEY          EAYOR         England
# 1                               ANGUS       ARBROATH        Scotland
# 2      MANGOTSFIELD, SOUTH GLUCESTERS      UNDEFINED         England
# 3                       WOLVERHAMPTON              -         England
# 4                             PENALLT  MONMOUTHSHIRE         England
# ...                               ...            ...             ...
# 31906                           Essex          Essex  United Kingdom
# 31907                   Isle of Wight    Totland Bay  United Kingdom
# 31908                        Bridport                 United Kingdom
# 31909                               -              -           India
# 31910                                                 United Kingdom
#
#       Post Code  ...         DoB WeddingDate Keywords NoEDM    Account Status  \
# 0      HU17 7QW  ...  1952-10-29                                       Active
# 1      DD11 4QA  ...                                         Open Deal Member
# 2      BS16 9AZ  ...  1962-08-01                             Open Deal Member
# 3       WV3 8EP  ...  1974-04-03                                       Active
# 4      NP25 4SE  ...                                                   Active
# ...         ...  ...         ...         ...      ...   ...               ...
# 31906  CM16 7LR  ...  1951-05-22                                       Active
# 31907  PO39 0DS  ...  1951-06-14                                       Active
# 31908   DT6 5NY  ...  1964-09-21                                       Active
# 31909         -  ...  1988-10-17                                       Active
# 31910            ...                                                   Active
#
#                Account Type  OdysseyNo       Servicing Office  \
# 0      KARMA CLUB DISCOVERY  C82006555      KARMA CLUB EUROPE
# 1      KARMA CLUB DISCOVERY  C82002119      KARMA CLUB EUROPE
# 2      KARMA CLUB DISCOVERY                 KARMA CLUB EUROPE
# 3           KARMA DISCOVERY                 KARMA CLUB EUROPE
# 4           KARMA DISCOVERY                 KARMA CLUB EUROPE
# ...                     ...        ...                    ...
# 31906       KARMA CLUB 2021                 KARMA CLUB EUROPE
# 31907       KARMA CLUB 2021                 KARMA CLUB EUROPE
# 31908       KARMA CLUB 2021                 KARMA CLUB EUROPE
# 31909       KARMA CLUB 2021             KARMA CONCIERGE INDIA
# 31910       KARMA CLUB 2021                 KARMA CLUB EUROPE
#
#                               Email                         Category
# 0         irvinemcmahon@hotmail.com            KC Discovery - Europe
# 1             telandsue@yahoo.co.uk            KC Discovery - Europe
# 2               alibi56@hotmail.com            KC Discovery - Europe
# 3               kullydevi@gmail.com            KC Discovery - Europe
# 4       susan.milsom@btinternet.com            KC Discovery - Europe
# ...                             ...                              ...
# 31906      morrisdenise@outlook.com  Karma Club 2021 - Non Indonesia
# 31907          fubib@btinternet.com  Karma Club 2021 - Non Indonesia
# 31908          ajwall@btconnect.com  Karma Club 2021 - Non Indonesia
# 31909  arjun5hah.personal@gmail.com  Karma Club 2021 - Non Indonesia
# 31910           jcraib@ntlworld.com  Karma Club 2021 - Non Indonesia
#
# [31911 rows x 24 columns]

# %%
# df_gsheets.loc[(df_gsheets['Category'] == 'KCI') & (df_gsheets['DoB'] == '0000-00-00')]

# %%
worksheet.clear()
# Out:
# {'spreadsheetId': '19yYAv0drTU-zG_9KKjDzAyTzeDmJ2YmQp02rUVxsLnE',
#  'clearedRange': "'Master Data'!A1:Z31912"}

# %%
worksheet.update([df_clean.columns.values.tolist()] + df_clean.values.tolist())
# Out:
# {'spreadsheetId': '19yYAv0drTU-zG_9KKjDzAyTzeDmJ2YmQp02rUVxsLnE',
#  'updatedRange': "'Master Data'!A1:X31912",
#  'updatedRows': 31912,
#  'updatedColumns': 24,
#  'updatedCells': 765888}
