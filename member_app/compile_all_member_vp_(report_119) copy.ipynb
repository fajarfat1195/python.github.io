# %%
import sys

sys.path.append('../zoho_data_app')

import main_module as m
import zoho_filter_module as fil
import pandas as pd
import re
import numpy as np

import glob

# %load_ext autoreload
# %autoreload 2

# download semua report 63 di vp
# download 2x berdasarkan servicing office yang non-india dan india 

file_loc = r'C:\Users\fajar\Documents\Python\Data\1167383-MemberContactDetails-29Jan25-KSB-diluar-Active.xlsx'

# %%
excel_file = pd.ExcelFile(file_loc)
sheet_names = excel_file.sheet_names
frames = []
count = 0
for sheet in sheet_names:
    count += 1
    print(f"Compiling {sheet}")
    if sheet == 'Sheet1':
        globals()['df%s' % count]= pd.read_excel(file_loc, sheet_name=sheet, dtype='string')
        globals()['column'] = globals()['df%s' % count].columns.to_list()
    else:
        globals()['df%s' % count]= pd.read_excel(file_loc, sheet_name=sheet, dtype='string', header=None)
        globals()['df%s' % count].columns = globals()['column']

    frames.append(globals()['df%s' % count])

result = pd.concat(frames, ignore_index=True)

result.drop(result.loc[result['Account ID'] == 'krg'].index, inplace=True)
result
# Out:
# Compiling Sheet1
# Compiling Sheet2
# Compiling Sheet3
# Compiling Sheet4
#        Account ID ContactID                         FirstName      LastName  \
# 0              10         2                         Baharudin         Murad
# 1              10    131077                       Siti Suriah  Abdul Rahman
# 2              10    660146                             Extra        Detail
# 3            1000         4                             Anand        Jaokar
# 4            1000    132487                              Usha        Jaokar
# ...           ...       ...                               ...           ...
# 205560       RTHC      <NA>       Royal Thailand Holiday Club          <NA>
# 205561       SFEX      <NA>            San Francisco Exchange          <NA>
# 205562        VMI      <NA>                               VMI          <NA>
# 205563       VOYA      <NA>                      Voyager Club          <NA>
# 205564      WOTIF      <NA>  Asian Vacation Concepts Pte. Ltd          <NA>
#
#                AddressLine1                  AddressLine2    Town  \
# 0                   BLK 829  JURONG WEST ST. 81, # 08-308    <NA>
# 1                   BLK 829  JURONG WEST ST. 81, # 08-308    <NA>
# 2                   BLK 829  JURONG WEST ST. 81, # 08-308    <NA>
# 3       B-13/20, BEST NAGAR            GOREGAONKAR (WEST)  MUMBAI
# 4       B-13/20, BEST NAGAR            GOREGAONKAR (WEST)  MUMBAI
# ...                     ...                           ...     ...
# 205560                 <NA>                          <NA>    <NA>
# 205561                 <NA>                          <NA>    <NA>
# 205562                 <NA>                          <NA>    <NA>
# 205563                 <NA>                          <NA>    <NA>
# 205564                 <NA>                          <NA>    <NA>
#
#                City    Country Post Code  ... No_HotDeals_EDM  \
# 0              <NA>  Singapore    640829  ...            <NA>
# 1              <NA>  Singapore    640829  ...            <NA>
# 2              <NA>  Singapore    640829  ...            <NA>
# 3       MAHARASHTRA      India    400104  ...            <NA>
# 4       MAHARASHTRA      India    400104  ...            <NA>
# ...             ...        ...       ...  ...             ...
# 205560         <NA>       <NA>      <NA>  ...            <NA>
# 205561         <NA>       <NA>      <NA>  ...            <NA>
# 205562         <NA>       <NA>      <NA>  ...            <NA>
# 205563         <NA>       <NA>      <NA>  ...            <NA>
# 205564         <NA>       <NA>      <NA>  ...            <NA>
#
#        No_Concierge_EDM No_Events_EDM No_Community_EDM No_MC_EDM  \
# 0                  <NA>          <NA>             <NA>      <NA>
# 1                  <NA>          <NA>             <NA>      <NA>
# 2                  <NA>          <NA>             <NA>      <NA>
# 3                  <NA>          <NA>             <NA>      <NA>
# 4                  <NA>          <NA>             <NA>      <NA>
# ...                 ...           ...              ...       ...
# 205560             <NA>          <NA>             <NA>      <NA>
# 205561             <NA>          <NA>             <NA>      <NA>
# 205562             <NA>          <NA>             <NA>      <NA>
# 205563             <NA>          <NA>             <NA>      <NA>
# 205564             <NA>          <NA>             <NA>      <NA>
#
#        CreateDateTime            Modified By        Modified Date  \
# 0                <NA>                   <NA>                 <NA>
# 1                <NA>                   <NA>                 <NA>
# 2                <NA>                   <NA>                 <NA>
# 3                <NA>   Karma Website (api2)  2024-03-01 16:51:21
# 4                <NA>  Aris Apriyanti (vp17)  2023-11-03 17:38:49
# ...               ...                    ...                  ...
# 205560           <NA>                   <NA>                 <NA>
# 205561           <NA>                   <NA>                 <NA>
# 205562           <NA>                   <NA>                 <NA>
# 205563           <NA>                   <NA>                 <NA>
# 205564           <NA>                   <NA>                 <NA>
#
#        KC EDM Received Preferred Communication Method
# 0                 <NA>                           <NA>
# 1                 <NA>                           <NA>
# 2                 <NA>                           <NA>
# 3                 <NA>                           <NA>
# 4                 <NA>                           <NA>
# ...                ...                            ...
# 205560            <NA>                           <NA>
# 205561            <NA>                           <NA>
# 205562            <NA>                           <NA>
# 205563            <NA>                           <NA>
# 205564            <NA>                           <NA>
#
# [205565 rows x 35 columns]

# %%
df_final = pd.concat([result], ignore_index=True)
df_final.fillna('empty', inplace=True)
df_final
# Out:
#        Account ID ContactID                         FirstName      LastName  \
# 0              10         2                         Baharudin         Murad
# 1              10    131077                       Siti Suriah  Abdul Rahman
# 2              10    660146                             Extra        Detail
# 3            1000         4                             Anand        Jaokar
# 4            1000    132487                              Usha        Jaokar
# ...           ...       ...                               ...           ...
# 205560       RTHC     empty       Royal Thailand Holiday Club         empty
# 205561       SFEX     empty            San Francisco Exchange         empty
# 205562        VMI     empty                               VMI         empty
# 205563       VOYA     empty                      Voyager Club         empty
# 205564      WOTIF     empty  Asian Vacation Concepts Pte. Ltd         empty
#
#                AddressLine1                  AddressLine2    Town  \
# 0                   BLK 829  JURONG WEST ST. 81, # 08-308   empty
# 1                   BLK 829  JURONG WEST ST. 81, # 08-308   empty
# 2                   BLK 829  JURONG WEST ST. 81, # 08-308   empty
# 3       B-13/20, BEST NAGAR            GOREGAONKAR (WEST)  MUMBAI
# 4       B-13/20, BEST NAGAR            GOREGAONKAR (WEST)  MUMBAI
# ...                     ...                           ...     ...
# 205560                empty                         empty   empty
# 205561                empty                         empty   empty
# 205562                empty                         empty   empty
# 205563                empty                         empty   empty
# 205564                empty                         empty   empty
#
#                City    Country Post Code  ... No_HotDeals_EDM  \
# 0             empty  Singapore    640829  ...           empty
# 1             empty  Singapore    640829  ...           empty
# 2             empty  Singapore    640829  ...           empty
# 3       MAHARASHTRA      India    400104  ...           empty
# 4       MAHARASHTRA      India    400104  ...           empty
# ...             ...        ...       ...  ...             ...
# 205560        empty      empty     empty  ...           empty
# 205561        empty      empty     empty  ...           empty
# 205562        empty      empty     empty  ...           empty
# 205563        empty      empty     empty  ...           empty
# 205564        empty      empty     empty  ...           empty
#
#        No_Concierge_EDM No_Events_EDM No_Community_EDM No_MC_EDM  \
# 0                 empty         empty            empty     empty
# 1                 empty         empty            empty     empty
# 2                 empty         empty            empty     empty
# 3                 empty         empty            empty     empty
# 4                 empty         empty            empty     empty
# ...                 ...           ...              ...       ...
# 205560            empty         empty            empty     empty
# 205561            empty         empty            empty     empty
# 205562            empty         empty            empty     empty
# 205563            empty         empty            empty     empty
# 205564            empty         empty            empty     empty
#
#        CreateDateTime            Modified By        Modified Date  \
# 0               empty                  empty                empty
# 1               empty                  empty                empty
# 2               empty                  empty                empty
# 3               empty   Karma Website (api2)  2024-03-01 16:51:21
# 4               empty  Aris Apriyanti (vp17)  2023-11-03 17:38:49
# ...               ...                    ...                  ...
# 205560          empty                  empty                empty
# 205561          empty                  empty                empty
# 205562          empty                  empty                empty
# 205563          empty                  empty                empty
# 205564          empty                  empty                empty
#
#        KC EDM Received Preferred Communication Method
# 0                empty                          empty
# 1                empty                          empty
# 2                empty                          empty
# 3                empty                          empty
# 4                empty                          empty
# ...                ...                            ...
# 205560           empty                          empty
# 205561           empty                          empty
# 205562           empty                          empty
# 205563           empty                          empty
# 205564           empty                          empty
#
# [205565 rows x 35 columns]

# %%
# data phone, mobile dam email member yang ada di master data (wash member)

df_final['Email'] = m.lowercase(df_final, 'Email')
m.clean_space(df_final, 'Email')
m.clean_not_valid_email_format(df_final, 'Email')
# Out:
# c:\Users\fajar\Documents\Python\Task Offline\member_app\../zoho_data_app\main_module.py:90: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[df_columns].replace(' ','', regex=True, inplace=True)
# 'Email'

# %%
df_final.replace('empty', '', inplace=True)
df_final
# Out:
#        Account ID ContactID                         FirstName      LastName  \
# 0              10         2                         Baharudin         Murad
# 1              10    131077                       Siti Suriah  Abdul Rahman
# 2              10    660146                             Extra        Detail
# 3            1000         4                             Anand        Jaokar
# 4            1000    132487                              Usha        Jaokar
# ...           ...       ...                               ...           ...
# 205560       RTHC                 Royal Thailand Holiday Club
# 205561       SFEX                      San Francisco Exchange
# 205562        VMI                                         VMI
# 205563       VOYA                                Voyager Club
# 205564      WOTIF            Asian Vacation Concepts Pte. Ltd
#
#                AddressLine1                  AddressLine2    Town  \
# 0                   BLK 829  JURONG WEST ST. 81, # 08-308
# 1                   BLK 829  JURONG WEST ST. 81, # 08-308
# 2                   BLK 829  JURONG WEST ST. 81, # 08-308
# 3       B-13/20, BEST NAGAR            GOREGAONKAR (WEST)  MUMBAI
# 4       B-13/20, BEST NAGAR            GOREGAONKAR (WEST)  MUMBAI
# ...                     ...                           ...     ...
# 205560
# 205561
# 205562
# 205563
# 205564
#
#                City    Country Post Code  ... No_HotDeals_EDM  \
# 0                    Singapore    640829  ...
# 1                    Singapore    640829  ...
# 2                    Singapore    640829  ...
# 3       MAHARASHTRA      India    400104  ...
# 4       MAHARASHTRA      India    400104  ...
# ...             ...        ...       ...  ...             ...
# 205560                                    ...
# 205561                                    ...
# 205562                                    ...
# 205563                                    ...
# 205564                                    ...
#
#        No_Concierge_EDM No_Events_EDM No_Community_EDM No_MC_EDM  \
# 0
# 1
# 2
# 3
# 4
# ...                 ...           ...              ...       ...
# 205560
# 205561
# 205562
# 205563
# 205564
#
#        CreateDateTime            Modified By        Modified Date  \
# 0
# 1
# 2
# 3                       Karma Website (api2)  2024-03-01 16:51:21
# 4                      Aris Apriyanti (vp17)  2023-11-03 17:38:49
# ...               ...                    ...                  ...
# 205560
# 205561
# 205562
# 205563
# 205564
#
#        KC EDM Received Preferred Communication Method
# 0
# 1
# 2
# 3
# 4
# ...                ...                            ...
# 205560
# 205561
# 205562
# 205563
# 205564
#
# [205565 rows x 35 columns]

# %%
df_final.to_csv(r'C:\Users\fajar\Documents\Python\Data\compiled_member_inactive.csv', index=False)

# %%
# df_au_primary = df_final.loc[
#     (df_final['Country'].str.contains('Australia', regex=True, flags=re.IGNORECASE))&
#     (df_final['Primary'].str.contains('Primary', regex=True, flags=re.IGNORECASE))&
#     (df_final['Account Status'].str.contains('Active|Open Deal Member', regex=True, flags=re.IGNORECASE))
#     ].copy()

# df_au_primary.to_excel(r'C:\Users\fajar\Documents\Python\Data\australia-primary.xlsx', index=False)

# %%
# df_final.loc[
#     (df_final['Country'].str.contains('Australia', regex=True, flags=re.IGNORECASE))&
#     (df_final['Post Code'].str.len() > 1) & 
#     (df_final['City'].str.len() < 1) 
#     ].to_csv(r'C:\Users\fajar\Documents\Python\Data\missing_postcode.csv', index=False)

# %%
# df_au_primary.loc[
#     (df_au_primary['City'].str.len() < 2) & 
#     (df_au_primary['Post Code'].str.len() > 2)
#                   ]
