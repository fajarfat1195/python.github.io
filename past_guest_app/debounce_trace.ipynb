# %%
from sqlalchemy import create_engine

from datetime import datetime
from uuid import uuid4
    
# 'mysql+pymysql://mysql_user:mysql_password@mysql_host/mysql_db'
engine_str = 'mysql+pymysql://root:@localhost/past_guest_tmp'
engine = create_engine(engine_str)

import pprint
import pandas as pd
import numpy as np
from normalization import setDateTime
from debounce import Debounce
deb = Debounce()

# %%
def debounce_check(email):
    if email != 'empty_email':
        deb_data = deb.validonce(email)
        reason = deb_data['debounce']['reason']
        result = deb_data['debounce']['result']
        status_code = deb_data['debounce']['code']
        role = deb_data['debounce']['role']
        free = deb_data['debounce']['free_email']

        now = datetime.now()
        dt_string = now.strftime("%Y-%m-%d %H:%M:%S")


        engine.execute("INSERT INTO tb_debounce (email, result, reason, status_code, role, free, created_time) VALUES ('"+email+"', '"+result+"', '"+reason+"', '"+status_code+"', '"+role+"', '"+free+"','"+dt_string+"')")
    else:
        reason = ''
    return reason

# %%
path = r'C:\Users\fajar\Documents\Python\Data\normalize_viewpoint.csv'
df_past_guest = pd.read_csv(path, dtype='string', encoding='utf8')

df_past_guest['Email'].fillna('empty_email', inplace=True)

df_past_guest['Email_status'] = df_past_guest.apply(
    lambda x: debounce_check(x['Email']),
    axis=1,
)
# Out:
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>

# %%
# now = datetime.now()
# dt_now = now.strftime("%Y-%m-%d")

# df_debounce_temp = pd.read_sql("SELECT * FROM tb_debounce WHERE created_time BETWEEN '"+dt_now+" 00:00:00' AND '"+dt_now+" 23:59:59' ", con=engine)

# df_debounce_temp.rename(columns = {'email':'EMAIL', 
#                               'result':'RESULT',
#                               'reason':'REASON',
#                               'status_code':'STATUS CODE',
#                               'role':'ROLE',
#                               'free':'FREE'
#                               }, inplace = True)

# cols = ['EMAIL',	
# 'RESULT',
# 'REASON',	
# 'STATUS CODE',	
# 'ROLE',	
# 'FREE']	

# df_debounce_temp = df_debounce_temp.reindex(columns=cols)
# df_debounce_temp.to_csv(r'C:\Users\fajar\Documents\Python\Data\Debounce\debounce_new_temp.csv', index=False, encoding='utf8')
# df_debounce_temp
# Out:
#                            EMAIL        RESULT       REASON  STATUS CODE  \
# 0          susa.schneider@web.de  Safe to Send  Deliverable            5
# 1        katharinazeidler@web.de  Safe to Send  Deliverable            5
# 2    juliandullinger91@gmail.com  Safe to Send  Deliverable            5
# 3     michael.tiefer@hotmail.com       Invalid       Bounce            6
# 4         info@goenner-dental.de       Unknown      Unknown            7
# ..                           ...           ...          ...          ...
# 402       shyam32shyam@gmail.com  Safe to Send  Deliverable            5
# 403       vinod.dhru89@gmail.com  Safe to Send  Deliverable            5
# 404       jaiswalji.ji@gmail.com  Safe to Send  Deliverable            5
# 405       dilrana.9090@gmail.com  Safe to Send  Deliverable            5
# 406   sumeet_joshi83@yahoo.co.in  Safe to Send  Deliverable            5
#
#       ROLE   FREE
# 0    false   true
# 1    false   true
# 2    false   true
# 3    false   true
# 4     true  false
# ..     ...    ...
# 402  false   true
# 403  false   true
# 404  false   true
# 405  false   true
# 406  false   true
#
# [407 rows x 6 columns]

# %%
df_past_guest['Email'].replace('empty_email', '', inplace=True)

df_past_guest.to_csv(r'C:\Users\fajar\Documents\Python\Data\normalize_viewpoint_debounce.csv', index=False, encoding='utf8')
df_past_guest
# Out:
#      BookRef Email_Opt_In Email_Opt_Out          Brand Lead_Sub_Brand  \
# 0    2611005         True         False  Karma Resorts          Other
# 1    2304643         True         False  Karma Resorts          Other
# 2    2576979         True         False  Karma Resorts          Other
# 3    2578686         True         False  Karma Resorts          Other
# 4    2529903         True         False  Karma Resorts          Other
# ..       ...          ...           ...            ...            ...
# 354  2569149         True         False  Karma Resorts          Other
# 355  2603049         True         False  Karma Resorts          Other
# 356  2583050         True         False  Karma Resorts          Other
# 357  2616726         True         False  Karma Resorts          Other
# 358  2614826         True         False  Karma Resorts          Other
#
#      Lead_Source Lead_Source_Description                     Lead_Locations  \
# 0    Past Guests               Viewpoint                  Karma Royal Palms
# 1    Past Guests               Viewpoint                      Karma Bavaria
# 2    Past Guests               Viewpoint            Karma Sitabani, Corbett
# 3    Past Guests               Viewpoint           Karma Royal Haathi Mahal
# 4    Past Guests               Viewpoint                  Karma Royal Palms
# ..           ...                     ...                                ...
# 354  Past Guests               Viewpoint  Wyndham -  Manoir des Deux Amants
# 355  Past Guests               Viewpoint  Wyndham -  Manoir des Deux Amants
# 356  Past Guests               Viewpoint  Wyndham -  Manoir des Deux Amants
# 357  Past Guests               Viewpoint  Wyndham -  Manoir des Deux Amants
# 358  Past Guests               Viewpoint           Karma Royal Haathi Mahal
#
#     Guest_Type Booking_Status  ... Year_of_Birth     Contact_type  \
# 0      Booking    Checked-Out  ...          <NA>  Email And Phone
# 1      Booking    Checked-Out  ...          1973  Email And Phone
# 2      Booking    Checked-Out  ...          <NA>  Email And Phone
# 3      Booking    Checked-Out  ...          <NA>  Email And Phone
# 4      Booking    Checked-Out  ...          <NA>  Email And Phone
# ..         ...            ...  ...           ...              ...
# 354    Booking    Checked-Out  ...          <NA>  Email And Phone
# 355    Booking    Checked-Out  ...          <NA>  Email And Phone
# 356    Booking    Checked-Out  ...          <NA>  Email And Phone
# 357    Booking    Checked-Out  ...          <NA>  Email And Phone
# 358    Booking    Checked-Out  ...          <NA>       Phone Only
#
#     Email_status IDzoho meta_id zoho_check debounce_check process_status  \
# 0    Deliverable   <NA>     186      False          False       Pendding
# 1    Deliverable   <NA>     186      False          False       Pendding
# 2    Deliverable   <NA>     186      False          False       Pendding
# 3    Deliverable   <NA>     186      False          False       Pendding
# 4    Deliverable   <NA>     186      False          False       Pendding
# ..           ...    ...     ...        ...            ...            ...
# 354                <NA>     186      False          False       Pendding
# 355                <NA>     186      False          False       Pendding
# 356                <NA>     186      False          False       Pendding
# 357                <NA>     186      False          False       Pendding
# 358                <NA>     186      False          False       Pendding
#
#     process_date              created
# 0           <NA>  2024-09-09 11:43:24
# 1           <NA>  2024-09-09 11:43:24
# 2           <NA>  2024-09-09 11:43:24
# 3           <NA>  2024-09-09 11:43:25
# 4           <NA>  2024-09-09 11:43:25
# ..           ...                  ...
# 354         <NA>  2024-09-09 11:43:37
# 355         <NA>  2024-09-09 11:43:37
# 356         <NA>  2024-09-09 11:43:37
# 357         <NA>  2024-09-09 11:43:37
# 358         <NA>  2024-09-09 11:43:37
#
# [359 rows x 37 columns]

# %%
# df_past_guest.to_excel(r'C:\Users\fajar\Documents\Python\Data\normalize_viewpoint_debounce.xlsx', index=False)
