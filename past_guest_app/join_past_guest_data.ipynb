# %%
import pandas as pd
import numpy as np
from fractions import Fraction

# %%
push_cols = ['BookRef', 'PrimaryGuestProfileRef', 'Lead_Locations', 'Language', 'Brand','Lead_Sub_Brand',
              'Lead_Source', 'Lead_Source_Description', 'Guest_Type', 'Booking_Status', 
              'Arrival_Date', 'Departure_Date', 'Street', 'Street2', 
              'City', 'State', 'Country', 'Nationality', 'Zip_Code', 'Phone', 'Mobile', 'Email',
              'Salutation', 'First_Name', 'Last_Name', 'Gender', 'Media_Source_Code', 'Market_Segment',
              'Adult', 'Children', 'Contact_type', 'Email_Opt_In', 'Email_Opt_Out', 'Email_status']

# "BookRef" : rw['BookRef'],
#                 "PrimaryGuestProfileRef" : rw['PrimaryGuestProfileRef'],
#                 "Destination" : rw['Lead_Locations'],
#                 "Language" : rw['Language'],
#                 "Brand": rw['Brand'],
#                 "Lead_Sub_Brand": rw['Lead_Sub_Brand'],
#                 "Lead_Source": rw['Lead_Source'],
#                 "Lead_Source_Description": rw['Lead_Source_Description'],
#                 "Lead_Locations": rw['Lead_Locations'],
#                 "Guest_Type": rw['Guest_Type'],
#                 "Booking_Status" : rw['Booking_Status'],
#                 "Arrival_Date" : rw['Arrival_Date'],
#                 "Departure_Date" : rw['Departure_Date'],
#                 "Street" : rw['Street'],
#                 "Street2" : rw['Street2'],
#                 "City": rw['City'],
#                 "State": rw['State'],
#                 "Country": rw['Country'],
#                 "Nationality": rw['Nationality'],
#                 "Zip_Code": rw['Zip_Code'],
#                 "Phone": rw['Phone'],
#                 "Mobile": rw['Mobile'],
#                 "Email": rw['Email'],
#                 "Salutation" : rw['Salutation'],
#                 "First_Name": rw['First_Name'],
#                 "Last_Name": rw['Last_Name'],
#                 "Gender": rw['Gender'],
#                 "Media_Source_Code": rw['Media_Source_Code'],
#                 "Market_Segment": rw['Market_Segment'],
#                 "Adult": str(rw['Adult']),
#                 "Children": str(rw['Children']),
#                 "Contact_type" : [rw['Contact_type']],
#                 "Email_Opt_In": boolConv(rw['Email_Opt_In']),
#                 "Email_Opt_Out": boolConv(rw['Email_Opt_Out']),
#                 "Do_Not_Mail": boolConv(rw['Email_Opt_Out']),
#                 "Email_status" : [rw['Email_status']]

# %%
path = r'C:\Users\fajar\Documents\Python\Data\normalize_checkout_debounce.csv'
df_check_out = pd.read_csv(path, encoding='utf8')

path = r'C:\Users\fajar\Documents\Python\Data\normalize_cancelled_debounce.csv'
df_cancelled = pd.read_csv(path, encoding='utf8')

path = r'C:\Users\fajar\Documents\Python\Data\normalize_viewpoint_debounce.csv'
df_viewpoint = pd.read_csv(path, encoding='utf8')

# %%
df_check_out.columns = df_check_out.columns.str.replace(' ', '')
df_cancelled.columns = df_cancelled.columns.str.replace(' ', '')
df_viewpoint.columns = df_viewpoint.columns.str.replace(' ', '')

# %%
# df_check_out.columns
# df_cancelled.columns
df_viewpoint.columns
# Out:
# Index(['BookRef', 'Email_Opt_In', 'Email_Opt_Out', 'Brand', 'Lead_Sub_Brand',
#        'Lead_Source', 'Lead_Source_Description', 'Lead_Locations',
#        'Guest_Type', 'Booking_Status', 'Arrival_Date', 'Departure_Date',
#        'Street', 'Street2', 'City', 'State', 'Country', 'Nationality',
#        'Zip_Code', 'Phone', 'Mobile', 'Email', 'Odyssey_Members', 'Salutation',
#        'First_Name', 'Last_Name', 'Birthdate', 'Year_of_Birth', 'Contact_type',
#        'Email_status', 'IDzoho', 'meta_id', 'zoho_check', 'debounce_check',
#        'process_status', 'process_date', 'created'],
#       dtype='object')

# %%
def con_fraction(phone):
    if phone == '':
        new_phone = ''
    else:
        new_phone = Fraction(phone)
    return new_phone

def con_str(phone):
    if phone == '':
        new_phone = ''
    else:
        new_phone = '+'+str(int(phone))
    return new_phone

def con_number(number):
    if number == '':
        new_number = ''
    else:
        new_number = int(number)
    return new_number

# %%
frames = [df_check_out, df_cancelled, df_viewpoint]
new_df = pd.concat(frames, ignore_index=True)

new_df.fillna('', inplace=True)

new_df['Destination'] = new_df['Lead_Locations']
new_df['Do_Not_Mail'] = new_df['Email_Opt_Out']


new_df['Phone'] = new_df.apply(
lambda x: con_str(x['Phone']),
    axis=1,
)

new_df['Mobile'] = new_df.apply(
    lambda x: con_str(x['Mobile']),
    axis=1,
)

# new_df['Phone'] = new_df.apply(
# lambda x: con_fraction(x['Phone']),
#     axis=1,
# )

# new_df['Mobile'] = new_df.apply(
#     lambda x: con_fraction(x['Mobile']),
#     axis=1,
# )

new_df['Adult'] = new_df.apply(
    lambda x: con_number(x['Adult']),
    axis=1,
)

new_df['Children'] = new_df.apply(
    lambda x: con_number(x['Children']),
    axis=1,
)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\core\indexes\base.py:3800, in Index.get_loc(self, key, method, tolerance)
#    3799 try:
# -> 3800     return self._engine.get_loc(casted_key)
#    3801 except KeyError as err:
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Adult'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In [8], line 30
#      15 new_df['Mobile'] = new_df.apply(
#      16     lambda x: con_str(x['Mobile']),
#      17     axis=1,
#      18 )
#      20 # new_df['Phone'] = new_df.apply(
#      21 # lambda x: con_fraction(x['Phone']),
#      22 #     axis=1,
#    (...)
#      27 #     axis=1,
#      28 # )
# ---> 30 new_df['Adult'] = new_df.apply(
#      31     lambda x: con_number(x['Adult']),
#      32     axis=1,
#      33 )
#      35 new_df['Children'] = new_df.apply(
#      36     lambda x: con_number(x['Children']),
#      37     axis=1,
#      38 )
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\core\frame.py:9558, in DataFrame.apply(self, func, axis, raw, result_type, args, **kwargs)
#    9547 from pandas.core.apply import frame_apply
#    9549 op = frame_apply(
#    9550     self,
#    9551     func=func,
#    (...)
#    9556     kwargs=kwargs,
#    9557 )
# -> 9558 return op.apply().__finalize__(self, method="apply")
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\core\apply.py:741, in FrameApply.apply(self)
#     738 elif self.raw:
#     739     return self.apply_raw()
# --> 741 return self.apply_standard()
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\core\apply.py:868, in FrameApply.apply_standard(self)
#     867 def apply_standard(self):
# --> 868     results, res_index = self.apply_series_generator()
#     870     # wrap results
#     871     return self.wrap_results(results, res_index)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\core\apply.py:884, in FrameApply.apply_series_generator(self)
#     881 with option_context("mode.chained_assignment", None):
#     882     for i, v in enumerate(series_gen):
#     883         # ignore SettingWithCopy here in case the user mutates
# --> 884         results[i] = self.f(v)
#     885         if isinstance(results[i], ABCSeries):
#     886             # If we have a view on v, we need to make a copy because
#     887             #  series_generator will swap out the underlying data
#     888             results[i] = results[i].copy(deep=False)
#
# Cell In [8], line 31, in <lambda>(x)
#      15 new_df['Mobile'] = new_df.apply(
#      16     lambda x: con_str(x['Mobile']),
#      17     axis=1,
#      18 )
#      20 # new_df['Phone'] = new_df.apply(
#      21 # lambda x: con_fraction(x['Phone']),
#      22 #     axis=1,
#    (...)
#      27 #     axis=1,
#      28 # )
#      30 new_df['Adult'] = new_df.apply(
# ---> 31     lambda x: con_number(x['Adult']),
#      32     axis=1,
#      33 )
#      35 new_df['Children'] = new_df.apply(
#      36     lambda x: con_number(x['Children']),
#      37     axis=1,
#      38 )
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\core\series.py:982, in Series.__getitem__(self, key)
#     979     return self._values[key]
#     981 elif key_is_scalar:
# --> 982     return self._get_value(key)
#     984 if is_hashable(key):
#     985     # Otherwise index.get_value will raise InvalidIndexError
#     986     try:
#     987         # For labels that don't resolve as scalars like tuples and frozensets
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\core\series.py:1092, in Series._get_value(self, label, takeable)
#    1089     return self._values[label]
#    1091 # Similar to Index.get_value, but we do not fall back to positional
# -> 1092 loc = self.index.get_loc(label)
#    1093 return self.index._get_values_for_loc(self, loc, label)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3800     return self._engine.get_loc(casted_key)
#    3801 except KeyError as err:
# -> 3802     raise KeyError(key) from err
#    3803 except TypeError:
#    3804     # If we have a listlike key, _check_indexing_error will raise
#    3805     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3806     #  the TypeError.
#    3807     self._check_indexing_error(key)
#
# KeyError: 'Adult'

# %%
dob_con_date = pd.to_datetime(new_df['Birthdate'])
dob_date = dob_con_date.dt.strftime('%d/%m/%Y')

arr_con_date = pd.to_datetime(new_df['Arrival_Date'])
arr_date = arr_con_date.dt.strftime('%d/%m/%Y')

dep_con_date = pd.to_datetime(new_df['Departure_Date'])
dep_date = dep_con_date.dt.strftime('%d/%m/%Y')

new_df['Birthdate'] = dob_date
new_df['Arrival_Date'] = arr_date
new_df['Departure_Date'] = dep_date
new_df
# Out:
#        BookRef  Email_Opt_In  Email_Opt_Out          Brand Lead_Sub_Brand  \
# 0    KSM011973         False           True  Karma Resorts          Other
# 1     KK051014          True          False  Karma Resorts          Other
# 2    KSM011166          True          False  Karma Resorts          Other
# 3    KSM011163          True          False  Karma Resorts          Other
# 4     KK052671          True          False  Karma Resorts          Other
# ..         ...           ...            ...            ...            ...
# 682    2484272          True          False  Karma Resorts          Other
# 683    2482946          True          False  Karma Resorts          Other
# 684    2484645          True          False  Karma Resorts          Other
# 685    2479158          True          False  Karma Resorts          Other
# 686    2377166          True          False  Karma Resorts          Other
#
#      Lead_Source                     Lead_Locations Guest_Type Booking_Status  \
# 0    Past Guests                   Karma St Martins    Booking    Checked-Out
# 1    Past Guests                      Karma Kandara    Booking    Checked-Out
# 2    Past Guests                   Karma St Martins    Booking    Checked-Out
# 3    Past Guests                   Karma St Martins    Booking    Checked-Out
# 4    Past Guests                      Karma Kandara    Booking    Checked-Out
# ..           ...                                ...        ...            ...
# 682  Past Guests                     Karma Jimbaran    Booking    Checked-Out
# 683  Past Guests  Wyndham -  Manoir des Deux Amants    Booking    Checked-Out
# 684  Past Guests  Wyndham -  Manoir des Deux Amants    Booking    Checked-Out
# 685  Past Guests  Wyndham -  Manoir des Deux Amants    Booking    Checked-Out
# 686  Past Guests               Karma Chakra, Kerala    Booking    Checked-Out
#
#     Arrival_Date  ... IDzoho meta_id zoho_check debounce_check process_status  \
# 0     31/03/2024  ...            185      False          False       Pendding
# 1     31/03/2024  ...            185      False          False       Pendding
# 2     01/04/2024  ...            185      False          False       Pendding
# 3     01/04/2024  ...            185      False          False       Pendding
# 4     04/04/2024  ...            185      False          False       Pendding
# ..           ...  ...    ...     ...        ...            ...            ...
# 682   12/04/2024  ...            186      False          False       Pendding
# 683   14/04/2024  ...            186      False          False       Pendding
# 684   13/04/2024  ...            186      False          False       Pendding
# 685   13/04/2024  ...            186      False          False       Pendding
# 686   11/04/2024  ...            186      False          False       Pendding
#
#     process_date              created Lead_Source_Description  \
# 0                 2024-04-15 10:58:27
# 1                 2024-04-15 10:58:27
# 2                 2024-04-15 10:58:27
# 3                 2024-04-15 10:58:27
# 4                 2024-04-15 10:58:27
# ..           ...                  ...                     ...
# 682               2024-04-15 10:59:45               Viewpoint
# 683               2024-04-15 10:59:45               Viewpoint
# 684               2024-04-15 10:59:45               Viewpoint
# 685               2024-04-15 10:59:45               Viewpoint
# 686               2024-04-15 10:59:45               Viewpoint
#
#                            Destination Do_Not_Mail
# 0                     Karma St Martins        True
# 1                        Karma Kandara       False
# 2                     Karma St Martins       False
# 3                     Karma St Martins       False
# 4                        Karma Kandara       False
# ..                                 ...         ...
# 682                     Karma Jimbaran       False
# 683  Wyndham -  Manoir des Deux Amants       False
# 684  Wyndham -  Manoir des Deux Amants       False
# 685  Wyndham -  Manoir des Deux Amants       False
# 686               Karma Chakra, Kerala       False
#
# [687 rows x 47 columns]

# %%
list_GDPR = ['Russia', 'Germany', 'France', 'Italy', 'Spain','Ukraine','Poland','Romania','Netherlands','Belgium','Czechia','Greece','Portugal','Sweden','Hungary',
        'Belarus','Austria','Serbia','Switzerland','Bulgaria','Denmark','Finland','Slovakia','Norway','Ireland','Croatia','Moldova','Bosnia','Herzegovina','Albania','Lithuania',
        'North Macedonia','Slovenia','Latvia','Kosovo','Estonia','Montenegro','Luxembourg','Malta','Iceland','Andorra','Monaco','Liechtenstein','San Marino','Holy See',
        'Czech Republic','Israel','New Caledonia','Republic of Cyprus', 'England', 'United Kingdom', 'Wales', 'Scotland', 'Northern ireland']

# %%
new_df['GDPR Compliant'] =  False

# new_df.loc[new_df['Country'].isin(list_GDPR)]
new_df.loc[(new_df['Country'].isin(list_GDPR)) & (new_df['Email_Opt_In'] == True), 'GDPR Compliant'] = True
new_df[['Country', 'Email_Opt_In', 'GDPR Compliant']].loc[new_df['GDPR Compliant'] == True]
# Out:
#             Country  Email_Opt_In  GDPR Compliant
# 2    United Kingdom          True            True
# 3    United Kingdom          True            True
# 8    United Kingdom          True            True
# 9    United Kingdom          True            True
# 11   United Kingdom          True            True
# ..              ...           ...             ...
# 661         Germany          True            True
# 664          France          True            True
# 668          France          True            True
# 669           Italy          True            True
# 672           Spain          True            True
#
# [129 rows x 3 columns]

# %%
new_df.columns
# Out:
# Index(['BookRef', 'Email_Opt_In', 'Email_Opt_Out', 'Brand', 'Lead_Sub_Brand',
#        'Lead_Source', 'Lead_Locations', 'Guest_Type', 'Booking_Status',
#        'Arrival_Date', 'Departure_Date', 'Street', 'Street2', 'City', 'State',
#        'Country', 'Nationality', 'Zip_Code', 'Phone', 'Mobile', 'Email',
#        'Odyssey_Members', 'PrimaryGuestProfileRef', 'Salutation', 'First_Name',
#        'Last_Name', 'Birthdate', 'Year_of_Birth', 'Gender',
#        'Media_Source_Code', 'Market_Segment', 'Adult', 'Children', 'Infant',
#        'Contact_type', 'Language', 'Email_status', 'IDzoho', 'meta_id',
#        'zoho_check', 'debounce_check', 'process_status', 'process_date',
#        'created', 'Lead_Source_Description', 'Destination', 'Do_Not_Mail',
#        'GDPR Compliant'],
#       dtype='object')

# %%
new_df.dtypes
# Out:
# BookRef                    object
# Email_Opt_In                 bool
# Email_Opt_Out                bool
# Brand                      object
# Lead_Sub_Brand             object
# Lead_Source                object
# Lead_Locations             object
# Guest_Type                 object
# Booking_Status             object
# Arrival_Date               object
# Departure_Date             object
# Street                     object
# Street2                    object
# City                       object
# State                      object
# Country                    object
# Nationality                object
# Zip_Code                   object
# Phone                      object
# Mobile                     object
# Email                      object
# Odyssey_Members              bool
# PrimaryGuestProfileRef     object
# Salutation                 object
# First_Name                 object
# Last_Name                  object
# Birthdate                  object
# Year_of_Birth              object
# Gender                     object
# Media_Source_Code          object
# Market_Segment             object
# Adult                      object
# Children                   object
# Infant                     object
# Contact_type               object
# Language                   object
# Email_status               object
# IDzoho                     object
# meta_id                     int64
# zoho_check                   bool
# debounce_check               bool
# process_status             object
# process_date               object
# created                    object
# Lead_Source_Description    object
# Destination                object
# Do_Not_Mail                  bool
# GDPR Compliant               bool
# dtype: object

# %%
new_push_cols = ['BookRef', 'PrimaryGuestProfileRef', 'Destination', 'Lead_Locations', 'Language', 'Brand','Lead_Sub_Brand',
              'Lead_Source', 'Lead_Source_Description', 'Guest_Type', 'Booking_Status', 
              'Arrival_Date', 'Departure_Date', 'Street', 'Street2', 
              'City', 'State', 'Country', 'Nationality', 'Zip_Code', 'Phone', 'Mobile', 'Email',
              'Salutation', 'First_Name', 'Last_Name', 'Gender', 'Media_Source_Code', 'Market_Segment',
              'Adult', 'Children', 'Contact_type', 'Email_Opt_In', 'Email_Opt_Out', 'Do_Not_Mail', 'GDPR Compliant', 'Email_status']

# %%
new_df.drop(new_df.columns.difference(new_push_cols), axis='columns', inplace=True)
new_df = new_df.reindex(columns=new_push_cols)
new_df.columns
# Out:
# Index(['BookRef', 'PrimaryGuestProfileRef', 'Destination', 'Lead_Locations',
#        'Language', 'Brand', 'Lead_Sub_Brand', 'Lead_Source',
#        'Lead_Source_Description', 'Guest_Type', 'Booking_Status',
#        'Arrival_Date', 'Departure_Date', 'Street', 'Street2', 'City', 'State',
#        'Country', 'Nationality', 'Zip_Code', 'Phone', 'Mobile', 'Email',
#        'Salutation', 'First_Name', 'Last_Name', 'Gender', 'Media_Source_Code',
#        'Market_Segment', 'Adult', 'Children', 'Contact_type', 'Email_Opt_In',
#        'Email_Opt_Out', 'Do_Not_Mail', 'GDPR Compliant', 'Email_status'],
#       dtype='object')

# %%
# test_df = new_df.loc[new_df['Email'].str.contains('bea.fliedner@google.com')]
# test_df.to_csv(r'C:\Users\fajar\Documents\Python\Data\compile_data_pastguest_test.csv', encoding='utf-8', index=False)

# %%
# new_df.to_csv(r'C:\Users\fajar\Documents\Python\Data\compile_data_pastguest.csv', encoding='utf-8', index=False)

new_df.to_excel(r'C:\Users\fajar\Documents\Python\Data\compile_data_pastguest.xlsx', index=False)
