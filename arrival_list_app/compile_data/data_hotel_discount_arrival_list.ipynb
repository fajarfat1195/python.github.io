# %%
import pandas as pd
import re
import numpy as np
import openpyxl
import arrival_compile_main as ac

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
path = r'C:\Users\fajar\Documents\Python\Data\Arrival List Raw\HOTEL DISCOUNT ARRIVAL LIST 2022.xlsx'

# %%
xl = pd.ExcelFile(path)
sheets = xl.sheet_names  # see all sheet names

delete_sheets = [
 
]

arr = np.array(sheets)
# arr = np.delete(arr, delete_sheets)

sheet_will_be_used = []

for i in sheets:
    sheets_name = i
    result = np.isin(sheets_name, delete_sheets)
    if result == True:
        print(sheets_name)
    else:
        print(sheets_name)
        sheet_will_be_used.extend([sheets_name])

sheet_will_be_used

# sheet_will_be_used = ['JAN 23']
# arr
# Out:
# CANCEL
# CANCEL AS OPENDATE
# ['CANCEL', 'CANCEL AS OPENDATE']

# %%
key_columns = 'NO.'

cols = [key_columns, 
        'Programme', 
        'Nationality',
        'Region',
        'Client Name', 
        'Email Address', 
        'Phone Number',
        'Check in',
        'Check out']

# %%
df = ac.load_data_multiple(path, sheet_will_be_used, cols, key_columns)
df.rename(columns = {
    key_columns:'Sheet Row No.',
    'Email Address' : 'Email',
    'Phone Number' : 'Phone'
}, inplace = True)
df
# Out:
# Compiling sheets [CANCEL] - On progress : Proses Single Header
# Compiling sheets [CANCEL AS OPENDATE] - On progress : Proses Single Header
# 0   Sheet Row No.                Programme Nationality                Region  \
# 0               1            Web Comp HDID  Indonesian           DKI Jakarta
# 1               2           Hotel Discount  Indonesian  Deli Serdang - Sumut
# 2               3           Hotel Discount  Indonesian     Tangerang Selatan
# 3               4  Facebook Hotel Discount  Indonesian            Pekan Baru
# 4               5           Hotel Discount  Indonesian              Sidoarjo
# ..            ...                      ...         ...                   ...
# 554           294              Regent HDID  Indonesian         Jakarta Timur
# 555           295          Facebook 2 HDID  Indonesian              Semarang
# 556           296             Landing Page  Indonesian                Cimahi
# 557           297       Facebook Comp HDID  Indonesian            Temanggung
# 558           298       Facebook Comp HDID  Indonesian         Bandung Barat
#
# 0                                          Client Name  \
# 0                     Novy M Rumondor & Popy Juliyanti
# 1                   Darul Indra & Ridhawati Br Tarigan
# 2                              Hendri Dunan & Maryatun
# 3                  Syatril Hutagalung & Dora Abdullah
# 4                Didik Irianto & Riana Dewi Kusumawati
# ..                                                 ...
# 554                Samuel Arthur & Gokman Marlina BR.S
# 555             Wishnu Noorcahyo & Ika Dewi Retno Sari
# 556  Paulus Yustinus Maria Wibowo Ndaruhadi & Santi...
# 557                     Agus Purnomo & Ratna Panggalih
# 558                    Harris Sagala & Winna Apriyanti
#
# 0                           Email                       Phone  \
# 0             popyboons@yahoo.com                081583774521
# 1             darul_175@yahoo.com                082166433910
# 2        hendry.dunan88@gmail.com                  0811731972
# 3     syatrilhutagalung@gmail.com                081270162666
# 4       rianadewinana70@gmail.com                 08123561033
# ..                            ...                         ...
# 554         samuelart80@gmail.com                 08151886462
# 555  noorcahyowishnu974@gmail.com                081253458125
# 556        santi.pramit@gmail.com  081321355658 / 08131355658
# 557            cellshea@gmail.com                082133400120
# 558     sagala.harrys@yahoo.co.id                081809559200
#
# 0               Check in            Check out          Sheet Name
# 0    2019-06-01 00:00:00  2019-06-04 00:00:00              CANCEL
# 1    2019-06-12 00:00:00  2019-06-15 00:00:00              CANCEL
# 2    2019-06-12 00:00:00  2019-06-15 00:00:00              CANCEL
# 3    2019-06-11 00:00:00  2019-06-14 00:00:00              CANCEL
# 4    2019-06-12 00:00:00  2019-06-15 00:00:00              CANCEL
# ..                   ...                  ...                 ...
# 554  2020-11-15 00:00:00  2020-11-18 00:00:00  CANCEL AS OPENDATE
# 555  2020-11-17 00:00:00  2020-11-20 00:00:00  CANCEL AS OPENDATE
# 556  2020-11-16 00:00:00  2020-11-19 00:00:00  CANCEL AS OPENDATE
# 557  2020-11-22 00:00:00  2020-11-25 00:00:00  CANCEL AS OPENDATE
# 558  2020-11-29 00:00:00  2020-12-02 00:00:00  CANCEL AS OPENDATE
#
# [559 rows x 10 columns]

# %%
df.to_excel(r'C:\Users\fajar\Documents\Python\Data\Arrival List Raw\Compile Arrival\HOTEL DISCOUNT ARRIVAL LIST 2022-compile.xlsx', index=False)

# %%
# # jumlah header columns yang ada di sheets (menghitung berdasarkan jumlah nilai 'key columns' yang ada di kolom tersebut)
# count_header = df.loc[df[0] == key_columns].shape[0]

# # kumpulan index row dari setiap header columns yang ada di sheets
# arr_index = df.loc[df[0] == key_columns].index

# sheet_name = 'JAN 23'


# if count_header == 1:
#     print('Proses Single Header')
#     new_df = get_data_segment_single_header(sheet_name, df, arr_index, cols)

# elif count_header > 1:
#     print('Proses Multiple Header')
#     new_df = get_data_segment_multi_header(sheet_name, df, count_header, arr_index, cols)

# else:
#     print('Column Header Not Found')

# new_df

# %%
# df = pd.read_excel(path, dtype='string', sheet_name='Jan 23', index_col=None, header=None)
# df.shape[0]

# %%
# # mencari nomor row index untuk memulai compile data

# start_segment = df.loc[df[0] == key_columns].index.values.astype(int)[0]
# end_segment = df.shape[0]

# new_df = df.iloc[start_segment:end_segment].reset_index(drop=True).copy()
# new_df.columns = new_df.iloc[0] # define kolom berdasarkan row paling awal
# new_df.drop([0,0], inplace=True) # menghapus row yang sudah dijadikan kolom (karena meskipun row index 0 sudah di define sebagai kolom, row index 0 tetap ada di row record data)
# arr_df = new_df[cols].loc[~new_df[key_columns].isna()].copy()
# arr_df.reset_index(drop=True, inplace=True)
# arr_df

# %%
# df.loc[~df['Check in'].str.contains('00:00:00')]
