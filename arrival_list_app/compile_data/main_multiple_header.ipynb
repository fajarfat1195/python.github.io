# %%
import pandas as pd
import re
import numpy as np
import openpyxl
import arrival_compile_main as ac

# %load_ext autoreload
# %autoreload 2

# %%
path = r'C:\Users\fajar\Documents\Python\Data\Arrival List Raw\KE2 REDEEM VOUCHER INDO 2022.xlsx'

# %%
xl = pd.ExcelFile(path)
sheets = xl.sheet_names  # see all sheet names

delete_sheets = [
    'Old Cancel - Dec 2019',
    'CANCEL VOLCANO', 
    'CANCEL',
    'CANCEL AS OPENDATE', 
    'TSR Analysis Sep 22',
    'Sheet5', 
    'Sheet6'
]

arr = np.array(sheets)
# arr = np.delete(arr, delete_sheets)

sheet_will_be_used = []

for i in sheets:
    sheets_name = i
    result = np.isin(sheets_name, delete_sheets)
    if result == True:
        print(sheets_name)
    else:
        print(sheets_name)
        sheet_will_be_used.extend([sheets_name])

sheet_will_be_used

# sheet_will_be_used = ['JAN 23']
# arr
# Out:
# Cancel Discovery
# Pending Discovery
# CANCEL
# CANCEL AS OPENDATE
# Sep 23
# Apr 23
# Feb 23
# JAN 23
# Dec 22
# Nov 22
# Oct 22
# Sept 22
# Aug 22
# July 22
# Jun 22
# May 22
# Apr 22
# Mar 22
# Feb 22
# Jan 22
# Dec 21
# ['Cancel Discovery',
#  'Pending Discovery',
#  'Sep 23',
#  'Apr 23',
#  'Feb 23',
#  'JAN 23',
#  'Dec 22',
#  'Nov 22',
#  'Oct 22',
#  'Sept 22',
#  'Aug 22',
#  'July 22',
#  'Jun 22',
#  'May 22',
#  'Apr 22',
#  'Mar 22',
#  'Feb 22',
#  'Jan 22',
#  'Dec 21']

# %%
key_columns = 'No'

cols = [key_columns, 
        'Programme', 
        'Nationality',
        'Region',
        'Phone Number', 
        'Email Address', 
        'Phone Number',
        'Check in',
        'Check out']

# %%
df = ac.load_data_multiple(path, sheet_will_be_used, cols, key_columns)
df.rename(columns = {'NO.':'Sheet Row No.'}, inplace = True)
df
# Out:
# Compiling sheets [Cancel Discovery] - On progress : Proses Single Header
# Compiling sheets [Pending Discovery] - On progress : Proses Single Header
# Compiling sheets [Sep 23] - On progress : Proses Single Header
# Compiling sheets [Apr 23] - On progress : Proses Multiple Header
# Compiling sheets [Feb 23] - On progress : Proses Single Header
# Compiling sheets [JAN 23] - On progress : Proses Single Header
# Compiling sheets [Dec 22] - On progress : Proses Single Header
# Compiling sheets [Nov 22] - On progress : Proses Multiple Header
# Compiling sheets [Oct 22] - On progress : Proses Single Header
# Compiling sheets [Sept 22] - On progress : Proses Multiple Header
# Compiling sheets [Aug 22] - On progress : Proses Multiple Header
# Compiling sheets [July 22] - On progress : Proses Multiple Header
# Compiling sheets [Jun 22] - On progress : Proses Multiple Header
# Compiling sheets [May 22] - On progress : Proses Multiple Header
# Compiling sheets [Apr 22] - On progress : Proses Multiple Header
# Compiling sheets [Mar 22] - On progress : Proses Multiple Header
# Compiling sheets [Feb 22] - On progress : Proses Multiple Header
# Compiling sheets [Jan 22] - On progress : Proses Multiple Header
# Compiling sheets [Dec 21] - On progress : Proses Multiple Header
# 0   No                    Programme  Nationality         Region  Phone Number  \
# 0    1      KARMA DISCOVERY VOUCHER   Indonesian           <NA>  081212596409
# 1    2  REDEEM KARMA DISCOVERY VCHR   Indonesian      Tangerang  081289911162
# 2    1      KARMA DISCOVERY VOUCHER   Indonesian           <NA>   08156714748
# 3    2  REDEEM KARMA DISCOVERY VCHR  Indonesian        Bandung    08122393858
# 4    1           KE2 Redeem Voucher   Indonesian      Indonesia   81225919281
# ..  ..                          ...          ...            ...           ...
# 282  4      REDEEM KARMA SALAK VCHR   Indonesian  Jakarta Pusat  081392575705
# 283  5      REDEEM KARMA SALAK VCHR   Indonesian         Bekasi  081230009363
# 284  6           Redeem Karma Salak   Indonesian  Jakarta Barat  081510001456
# 285  7      REDEEM KARMA SALAK VCHR   Indonesian  Jakarta Timur  081284171102
# 286  1  REDEEM KARMA DISCOVERY VCHR   Indonesian  Jakarta Barat    0817738015
#
# 0                Email Address  Phone Number             Check in  \
# 0    micdisuksesjaya@gmail.com  081212596409  2022-01-08 00:00:00
# 1         verairiani@yahoo.com  081289911162  2022-06-04 00:00:00
# 2      wisnu.mutiara@gmail.com   08156714748  2021-01-30 00:00:00
# 3       auliamarta@yahoo.co.id   08122393858  2022-09-28 00:00:00
# 4       wiryohartoyo@gmail.com   81225919281  2023-09-09 00:00:00
# ..                         ...           ...                  ...
# 282       tengkuzaki@gmail.com  081392575705  2021-12-11 00:00:00
# 283    ttstengker.mm@gmail.com  081230009363  2021-12-11 00:00:00
# 284    ivana_wahyadi@yahoo.com  081510001456  2021-12-11 00:00:00
# 285      rezafahlevi@gmail.com  081284171102  2021-12-11 00:00:00
# 286    jossy.sugondo@gmail.com    0817738015  2021-12-11 00:00:00
#
# 0              Check out         Sheet Name
# 0    2022-01-15 00:00:00   Cancel Discovery
# 1    2022-06-11 00:00:00   Cancel Discovery
# 2    2021-02-02 00:00:00  Pending Discovery
# 3    2022-10-01 00:00:00  Pending Discovery
# 4               7 Nights             Sep 23
# ..                   ...                ...
# 282  2021-12-18 00:00:00             Dec 21
# 283  2021-12-18 00:00:00             Dec 21
# 284  2021-12-18 00:00:00             Dec 21
# 285  2021-12-18 00:00:00             Dec 21
# 286  2021-12-18 00:00:00             Dec 21
#
# [287 rows x 10 columns]

# %%
df.to_excel(r'C:\Users\fajar\Documents\Python\Data\Arrival List Raw\Compile Arrival\KE2 REDEEM VOUCHER INDO 2022-compile.xlsx', index=False)

# %%
# # jumlah header columns yang ada di sheets (menghitung berdasarkan jumlah nilai 'key columns' yang ada di kolom tersebut)
# count_header = df.loc[df[0] == key_columns].shape[0]

# # kumpulan index row dari setiap header columns yang ada di sheets
# arr_index = df.loc[df[0] == key_columns].index

# sheet_name = 'JAN 23'


# if count_header == 1:
#     print('Proses Single Header')
#     new_df = get_data_segment_single_header(sheet_name, df, arr_index, cols)

# elif count_header > 1:
#     print('Proses Multiple Header')
#     new_df = get_data_segment_multi_header(sheet_name, df, count_header, arr_index, cols)

# else:
#     print('Column Header Not Found')

# new_df

# %%
# df = pd.read_excel(path, dtype='string', sheet_name='JAN 23', index_col=None, header=None)
# df.shape[0]

# %%
# # mencari nomor row index untuk memulai compile data

# start_segment = df.loc[df[0] == key_columns].index.values.astype(int)[0]
# end_segment = df.shape[0]

# new_df = df.iloc[start_segment:end_segment].reset_index().copy()
# new_df.columns = new_df.iloc[0] # define kolom berdasarkan row paling awal
# new_df.drop([0,0], inplace=True) # menghapus row yang sudah dijadikan kolom (karena meskipun row index 0 sudah di define sebagai kolom, row index 0 tetap ada di row record data)
# arr_df = new_df[cols].loc[~new_df[key_columns].isna()].copy()
# arr_df.reset_index(inplace=True)
# arr_df.drop(arr_df.columns[[0]],axis = 1, inplace=True)
# arr_df

# %%
# df.loc[~df['Check in'].str.contains('00:00:00')]
