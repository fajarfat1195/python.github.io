# %%
import pandas as pd
import re
import numpy as np
import openpyxl
import arrival_compile_main as ac

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
path = r'C:\Users\fajar\Documents\Python\Data\Arrival List Raw\BG INDO ARRIVAL LIST 2022.xlsx'

# %%
xl = pd.ExcelFile(path)
sheets = xl.sheet_names  # see all sheet names

delete_sheets = [
    'CANCEL',
    'TSR Analysis Sep 22',
    'Sheet5', 
    'Sheet6'
]

arr = np.array(sheets)
# arr = np.delete(arr, delete_sheets)

sheet_will_be_used = []

for i in sheets:
    sheets_name = i
    result = np.isin(sheets_name, delete_sheets)
    if result == True:
        print(sheets_name)
    else:
        print(sheets_name)
        sheet_will_be_used.extend([sheets_name])

sheet_will_be_used

# sheet_will_be_used = ['JAN 23']
# arr
# Out:
# Old Cancel - Dec 2019
# CANCEL VOLCANO
# CANCEL
# CANCEL AS OPENDATE
# TSR Analysis Sep 22
# Feb 23
# Jan 23
# Dec 22
# Nov 22
# Oct 22
# Sep 22
# Aug 22
# July 22
# June 22
# May 22
# Apr 22
# Mar 22
# FEB 22
# JAN 22
# Dec 21
# Sheet5
# Sheet6
# ['Old Cancel - Dec 2019',
#  'CANCEL VOLCANO',
#  'CANCEL AS OPENDATE',
#  'Feb 23',
#  'Jan 23',
#  'Dec 22',
#  'Nov 22',
#  'Oct 22',
#  'Sep 22',
#  'Aug 22',
#  'July 22',
#  'June 22',
#  'May 22',
#  'Apr 22',
#  'Mar 22',
#  'FEB 22',
#  'JAN 22',
#  'Dec 21']

# %%
key_columns = 'NO.'

cols = [key_columns, 
        'Programme', 
        'Nationality',
        'Region',
        'Client Name', 
        'Email Address', 
        'Phone Number',
        'Check in',
        'Check out']

# %%
df = ac.load_data_multiple(path, sheet_will_be_used, cols, key_columns)
df.rename(columns = {
    key_columns:'Sheet Row No.',
    'Email Address' : 'Email',
    'Phone Number' : 'Phone'
}, inplace = True)
df
# Out:
# Compiling sheets [Old Cancel - Dec 2019] - On progress : Proses Single Header
# Compiling sheets [CANCEL VOLCANO] - On progress : Proses Single Header
# Compiling sheets [CANCEL AS OPENDATE] - On progress : Proses Single Header
# Compiling sheets [Feb 23] - On progress : Proses Single Header
# Compiling sheets [Jan 23] - On progress : Proses Single Header
# Compiling sheets [Dec 22] - On progress : Proses Single Header
# Compiling sheets [Nov 22] - On progress : Proses Single Header
# Compiling sheets [Oct 22] - On progress : Proses Single Header
# Compiling sheets [Sep 22] - On progress : Proses Single Header
# Compiling sheets [Aug 22] - On progress : Proses Single Header
# Compiling sheets [July 22] - On progress : Proses Single Header
# Compiling sheets [June 22] - On progress : Proses Single Header
# Compiling sheets [May 22] - On progress : Proses Single Header
# Compiling sheets [Apr 22] - On progress : Proses Single Header
# Compiling sheets [Mar 22] - On progress : Proses Single Header
# Compiling sheets [FEB 22] - On progress : Proses Single Header
# Compiling sheets [JAN 22] - On progress : Proses Single Header
# Compiling sheets [Dec 21] - On progress : Proses Single Header
# 0    Sheet Row No.                                  Programme Nationality  \
# 0                1                                 Activation  Indonesian
# 1                2  LMD - facebook SwissBel Hotel Tuban Data   Indonesian
# 2                3  LMD - facebook SwissBel Hotel Tuban Data   Indonesian
# 3                4        LMD Facebook - Swiss Belhotel Tuban  Indonesian
# 4                5        LMD Facebook - Swiss Belhotel Tuban  Indonesian
# ...            ...                                        ...         ...
# 6497           196                              Facebook Comp  Indonesian
# 6498           197                                   Referral  Indonesian
# 6499           198                              Facebook Comp  Indonesian
# 6500           199                                        EDM  Indonesian
# 6501           200                              Landing Page   Indonesian
#
# 0            Region                                        Client Name  \
# 0           Bandung                Bayu Kurniawan & Shinto Watiningsih
# 1        Kalimantan                              Sunarwan & Melinda Lu
# 2           Jakarta       Kencana Widi Astuti Carbite & Indra Novyanto
# 3     Jakarta Timur                            Paska Puluaji & Lias Na
# 4             Bogor              Debie Christine Samosir & Juju Juanda
# ...             ...                                                ...
# 6497  Jakarta Pusat               Leonardo Cajady & Catherine Widianto
# 6498        Jombang  Steven Christianto Gunawan SE & Levina Hanhout...
# 6499  Jakarta Timur          Efendi T. Bolon & Dr. Shinta VR. Hutajulu
# 6500      Pekanbaru                             Hidayat & Titi Lasmini
# 6501         Mimika                     Herry Wijaya & Helmi Sitanajah
#
# 0                            Email                      Phone  \
# 0     bayu.kurniawan9937@gmail.com               081315662678
# 1       sunarwan_amerson@yahoo.com                 0811526265
# 2        widyak@ramsayhealth.co.id                08119701323
# 3               paskasin@yahoo.com               081252222151
# 4               deb_smsr@yahoo.com  08128378782 / 08125525727
# ...                            ...                        ...
# 6497     leonardo.cajadi@gmail.com                08161159887
# 6498    pheng_innamorata@yahoo.com               081330008899
# 6499        shintavera12@gmail.com               081513540005
# 6500          thdayat090@gmail.com               082285105305
# 6501      wijayaheri62@yahoo.co.id                 0811497488
#
# 0                Check in            Check out             Sheet Name
# 0     2015-11-13 00:00:00  2015-11-16 00:00:00  Old Cancel - Dec 2019
# 1     2016-01-07 00:00:00  2016-01-10 00:00:00  Old Cancel - Dec 2019
# 2     2016-01-08 00:00:00  2016-01-11 00:00:00  Old Cancel - Dec 2019
# 3     2016-01-07 00:00:00  2016-01-10 00:00:00  Old Cancel - Dec 2019
# 4     2016-01-03 00:00:00  2016-01-06 00:00:00  Old Cancel - Dec 2019
# ...                   ...                  ...                    ...
# 6497  2021-12-30 00:00:00  2022-01-02 00:00:00                 Dec 21
# 6498  2021-12-30 00:00:00  2022-01-02 00:00:00                 Dec 21
# 6499  2021-12-30 00:00:00  2022-01-02 00:00:00                 Dec 21
# 6500  2021-12-30 00:00:00  2022-01-02 00:00:00                 Dec 21
# 6501  2021-12-30 00:00:00  2022-01-02 00:00:00                 Dec 21
#
# [6502 rows x 10 columns]

# %%
df.to_excel(r'C:\Users\fajar\Documents\Python\Data\Arrival List Raw\Compile Arrival\BG INDO ARRIVAL LIST 2022-compile.xlsx', index=False)

# %%
# # jumlah header columns yang ada di sheets (menghitung berdasarkan jumlah nilai 'key columns' yang ada di kolom tersebut)
# count_header = df.loc[df[0] == key_columns].shape[0]

# # kumpulan index row dari setiap header columns yang ada di sheets
# arr_index = df.loc[df[0] == key_columns].index

# sheet_name = 'JAN 23'


# if count_header == 1:
#     print('Proses Single Header')
#     new_df = get_data_segment_single_header(sheet_name, df, arr_index, cols)

# elif count_header > 1:
#     print('Proses Multiple Header')
#     new_df = get_data_segment_multi_header(sheet_name, df, count_header, arr_index, cols)

# else:
#     print('Column Header Not Found')

# new_df

# %%
# df = pd.read_excel(path, dtype='string', sheet_name='Jan 23', index_col=None, header=None)
# df.shape[0]

# %%
# # mencari nomor row index untuk memulai compile data

# start_segment = df.loc[df[0] == key_columns].index.values.astype(int)[0]
# end_segment = df.shape[0]

# new_df = df.iloc[start_segment:end_segment].reset_index(drop=True).copy()
# new_df.columns = new_df.iloc[0] # define kolom berdasarkan row paling awal
# new_df.drop([0,0], inplace=True) # menghapus row yang sudah dijadikan kolom (karena meskipun row index 0 sudah di define sebagai kolom, row index 0 tetap ada di row record data)
# arr_df = new_df[cols].loc[~new_df[key_columns].isna()].copy()
# arr_df.reset_index(drop=True, inplace=True)
# arr_df

# %%
# df.loc[~df['Check in'].str.contains('00:00:00')]
