# %%
import pandas as pd
import json

# Specify the path to the JSON file
following_path = 'following.json'
# Read the JSON data from the file
with open(following_path, 'r') as f1:
    data_following = json.load(f1)
# Extract the 'string_list_data' from the JSON data
string_list_following = [item['string_list_data'][0] for item in data_following['relationships_following']]
# Create a pandas DataFrame from the extracted data
df_following = pd.DataFrame(string_list_following)


# Specify the path to the JSON file
followers_path = 'followers_1.json'
# Read the JSON data from the file
with open(followers_path, 'r') as f2:
    data_followers = json.load(f2)
string_list_followers = [item['string_list_data'][0] for item in data_followers]
df_followers = pd.DataFrame(string_list_followers)

df_followers
# Out:
#                                             href               value  \
# 0          https://www.instagram.com/mayaayuning         mayaayuning
# 1    https://www.instagram.com/gray.d.fullbuster   gray.d.fullbuster
# 2           https://www.instagram.com/grefi.muda          grefi.muda
# 3      https://www.instagram.com/leli_dilyfamily     leli_dilyfamily
# 4             https://www.instagram.com/menkiani            menkiani
# 5         https://www.instagram.com/rose.pratiwi        rose.pratiwi
# 6        https://www.instagram.com/herugalih2020       herugalih2020
# 7   https://www.instagram.com/biiekristyaningrum  biiekristyaningrum
# 8          https://www.instagram.com/joniarsana_         joniarsana_
# 9       https://www.instagram.com/adisumardiyasa      adisumardiyasa
# 10         https://www.instagram.com/muzaroah354         muzaroah354
# 11           https://www.instagram.com/ienaranie           ienaranie
# 12           https://www.instagram.com/kpimixlmn           kpimixlmn
# 13         https://www.instagram.com/si.erlangga         si.erlangga
#
#      timestamp
# 0   1722308433
# 1   1721926627
# 2   1721800701
# 3   1719756994
# 4   1705386334
# 5   1703307661
# 6   1700870638
# 7   1700870604
# 8   1699522662
# 9   1696599230
# 10  1695794583
# 11  1695790062
# 12  1693738554
# 13  1693656673

# %%
df_following.loc[~df_following['value'].isin(df_followers['value'])]
# Out:
#                                                href                  value  \
# 0             https://www.instagram.com/realityclub            realityclub
# 3               https://www.instagram.com/facemelts              facemelts
# 4               https://www.instagram.com/salpriadi              salpriadi
# 6             https://www.instagram.com/converse_id            converse_id
# 7         https://www.instagram.com/findingoodfilms        findingoodfilms
# 8                  https://www.instagram.com/fender                 fender
# 9   https://www.instagram.com/explainingtheuniverse  explainingtheuniverse
# 10          https://www.instagram.com/altsongdigger          altsongdigger
# 11                 https://www.instagram.com/natgeo                 natgeo
# 12       https://www.instagram.com/diskon.indonesia       diskon.indonesia
# 13            https://www.instagram.com/goodlifebca            goodlifebca
# 14          https://www.instagram.com/arcticmonkeys          arcticmonkeys
# 15               https://www.instagram.com/ussfeeds               ussfeeds
# 16              https://www.instagram.com/folkative              folkative
# 17                https://www.instagram.com/viceind                viceind
# 18         https://www.instagram.com/kulturdomestik         kulturdomestik
# 19               https://www.instagram.com/plfrprod               plfrprod
# 20               https://www.instagram.com/triple_j               triple_j
# 21             https://www.instagram.com/some_crumb             some_crumb
# 22              https://www.instagram.com/royelotis              royelotis
# 23        https://www.instagram.com/cinematologist_        cinematologist_
# 24       https://www.instagram.com/mappingtheguitar       mappingtheguitar
# 27             https://www.instagram.com/konserbali             konserbali
# 30    https://www.instagram.com/historyphotographed    historyphotographed
# 32            https://www.instagram.com/joylandfest            joylandfest
# 35      https://www.instagram.com/whiteboardjournal      whiteboardjournal
# 36             https://www.instagram.com/sorezeband             sorezeband
# 39        https://www.instagram.com/jazzguitarlicks        jazzguitarlicks
# 40          https://www.instagram.com/caitlinguitar          caitlinguitar
# 41             https://www.instagram.com/hai_online             hai_online
# 42               https://www.instagram.com/vicenews               vicenews
#
#      timestamp
# 0   1723850814
# 3   1721471310
# 4   1720163585
# 6   1717759188
# 7   1717345567
# 8   1716395949
# 9   1715184582
# 10  1715183341
# 11  1713527429
# 12  1711341643
# 13  1711085777
# 14  1708866749
# 15  1708599725
# 16  1708599698
# 17  1708599696
# 18  1708174410
# 19  1707376910
# 20  1707219851
# 21  1706684626
# 22  1706666121
# 23  1705812658
# 24  1705412011
# 27  1702196043
# 30  1700144066
# 32  1698969244
# 35  1694383796
# 36  1694003309
# 39  1693543591
# 40  1693543459
# 41  1693543381
# 42  1693543294
