# %%
import pandas as pd
import re
import numpy as np

import sys
sys.path.append('../../zoho_data_app/')
import main_module as m
import zoho_filter_module as fil

# %load_ext autoreload
# %autoreload 2

import gspread
import pandas as pd

# %%
# Pastikan permision access di menu "Share" di rubah ke anyone with the link terlebih dahulu, agar bisa mengunakan cara OAuth
# Jika Ingin lebih dibatasi menggunakan cara google service account lebih disarankan

gc = gspread.oauth(
    credentials_filename= r'C:\Users\fajar\Documents\Python\Data\Google Credentials\karma-group-credentials.json'
)

SHEET_ID = '1vPxSc9wB3zRIGA8OI2lDA955mRypBGy9peC2KBnHyVo'
SHEET_NAME_WESTERN = 'Feb-2023-W'
SHEET_NAME_INDO = 'Feb-2023-I'

# %%
# get data gsheet

spreadsheet = gc.open_by_key(SHEET_ID)

worksheet_western = spreadsheet.worksheet(SHEET_NAME_WESTERN)
rows_western = worksheet_western.get_all_records()
df_western = pd.DataFrame(rows_western)

worksheet_indo = spreadsheet.worksheet(SHEET_NAME_INDO)
rows_indo = worksheet_indo.get_all_records()
df_indo = pd.DataFrame(rows_indo)

# %%
df_all_kce = pd.concat([df_western, df_indo], ignore_index=True)
df_all_kce
# Out:
#                     Record Id        Record Id (Emails)         Created Time  \
# 0    zcrm_3584690000428141544  zcrm_3584690000428141562  11/02/2023 03:46 PM
# 1    zcrm_3584690000428408270  zcrm_3584690000428408288  13/02/2023 02:10 PM
# 2    zcrm_3584690000428364056  zcrm_3584690000428364074  12/02/2023 05:14 PM
# 3    zcrm_3584690000428360163  zcrm_3584690000428360181  12/02/2023 05:46 PM
# 4    zcrm_3584690000428355720  zcrm_3584690000428355738  13/02/2023 12:27 PM
# ..                        ...                       ...                  ...
# 648  zcrm_3584690000429869737  zcrm_3584690000429869755  19/02/2023 12:23 PM
# 649  zcrm_3584690000429849834  zcrm_3584690000429849852  19/02/2023 03:37 PM
# 650  zcrm_3584690000429693232  zcrm_3584690000429693250  17/02/2023 03:57 PM
# 651  zcrm_3584690000429623225  zcrm_3584690000429623243  17/02/2023 01:43 PM
# 652  zcrm_3584690000429618306  zcrm_3584690000429618324  17/02/2023 03:53 PM
#
#     First Name      Last Name                           Email          Phone  \
# 0      MOHAMED          DAHIM       larbibenhorabir@gmail.com   213667046811
# 1     SHAILESH         MASAND           josh.sydney@gmail.com    61433433787
# 2      CHETHAN       UMAKANTH           write2chets@gmail.com   919845441027
# 3       JOSHUA         REIHER      taylor.e.bennett@gmail.com    61449500605
# 4      BRENDAN         WRIGHT  brendan_wdight1994@hotmail.com    61433133553
# ..         ...            ...                             ...            ...
# 648        OEI       WE JIANG             wejiang86@gmail.com  6281259577978
# 649        UDA  ALEXANDAY, ST          udaalexanday@gmail.com   628111368957
# 650      RAHUL          SWAMI          errahulswami@gmail.com   918882227811
# 651   DESWANTO       DESWANTO          deswanto.jbi@gmail.com   628127411601
# 652    MUSTOFA        MUSTOFA     mustofadjaelaji13@gmail.com  6285717446184
#
#               Birthdate  Year of Birth       State    Country  \
# 0    1995-01-31 0:00:00           1995    ALGERIAN    ALGERIA
# 1    1984-04-25 0:00:00           1984  AUSTRALIAN  AUSTRALIA
# 2    1979-02-02 0:00:00           1979      INDIAN  AUSTRALIA
# 3    1994-11-11 0:00:00           1994  AUSTRALIAN  AUSTRALIA
# 4    1994-06-08 0:00:00           1994  AUSTRALIAN  AUSTRALIA
# ..                  ...            ...         ...        ...
# 648  1986-10-12 0:00:00           1986  INDONESIAN  INDONESIA
# 649  1985-04-23 0:00:00           1985  INDONESIAN  INDONESIA
# 650  1987-09-20 0:00:00           1987      INDIAN  INDONESIA
# 651  1967-12-04 0:00:00           1967  INDONESIAN  INDONESIA
# 652  1970-04-13 0:00:00           1970  INDONESIAN  INDONESIA
#
#               Lead Brand Lead Sub-Brand Lead Source       Lead Locations  \
# 0    Timeshare Marketing            KCE  Guest Exit  Sales Deck Jimbaran
# 1    Timeshare Marketing            KCE  Guest Exit  Sales Deck Jimbaran
# 2    Timeshare Marketing            KCE  Guest Exit  Sales Deck Jimbaran
# 3    Timeshare Marketing            KCE  Guest Exit  Sales Deck Jimbaran
# 4    Timeshare Marketing            KCE  Guest Exit  Sales Deck Jimbaran
# ..                   ...            ...         ...                  ...
# 648  Timeshare Marketing            KCE  Guest Exit  Sales Deck Jimbaran
# 649  Timeshare Marketing            KCE  Guest Exit     Sales Deck Salak
# 650  Timeshare Marketing            KCE  Guest Exit  Sales Deck Jimbaran
# 651  Timeshare Marketing            KCE  Guest Exit  Sales Deck Jimbaran
# 652  Timeshare Marketing            KCE  Guest Exit  Sales Deck Jimbaran
#
#                                Lead Source Description Lead Regions  \
# 0    REGISTRATION CONFIRMED | Your Exclusive 7 NIGH...         SEAP
# 1    REGISTRATION CONFIRMED | Your Exclusive 7 NIGH...         SEAP
# 2    REGISTRATION CONFIRMED | Your Exclusive 7 NIGH...         SEAP
# 3    REGISTRATION CONFIRMED | Your Exclusive 7 NIGH...         SEAP
# 4    REGISTRATION CONFIRMED | Your Exclusive 7 NIGH...         SEAP
# ..                                                 ...          ...
# 648  REGISTRATION CONFIRMED | Your Exclusive 7 NIGH...         SEAP
# 649  Karma Salak | REGISTRATION CONFIRMED | Your Ex...         SEAP
# 650  REGISTRATION CONFIRMED | Your Exclusive 7 NIGH...         SEAP
# 651  REGISTRATION CONFIRMED | Your Exclusive 7 NIGH...         SEAP
# 652  REGISTRATION CONFIRMED | Your Exclusive 7 NIGH...         SEAP
#
#       Lead Status  External ID
# 0    Hot Prospect  IVO20231437
# 1    Hot Prospect  IVO20231536
# 2    Hot Prospect  IVO20231497
# 3    Hot Prospect  IVO20231496
# 4    Hot Prospect  IVO20231512
# ..            ...          ...
# 648  Hot Prospect  IVO20231772
# 649  Hot Prospect  IVO20231785
# 650  Hot Prospect  IVO20231693
# 651  Hot Prospect  IVO20231673
# 652  Hot Prospect  IVO20231656
#
# [653 rows x 19 columns]

# %%
dir_path = r'C:\Users\fajar\Documents\Python\Data\Zoho_Backup'
file_name = '\Leads_'

cols = ['Record Id',	
'Created Time',
'Created Date',	
'First Name',	
'Last Name',	
'Email',	
'Phone',	
'Mobile',	
'Birthdate',	
'Year of Birth',
'Street',	
'Street2',	
'City',	
'State',	
'Country',	
'Nationality',
'Booking Status', 
'BookRef',
'Departure Date',	
'Arrival Date',	
'Card Type',	
'Marital Status',	
'Lead Brand',	
'Lead Sub-Brand',	
'Lead Source',	
'Lead Locations',	
'Lead Source Description',	
'Lead Regions',
'Lead Status',
'Email Opt Out',	
'Opt In']

# %%
path = r'G:\.shortcut-targets-by-id\0B_d3smBjzo04eXpvS1NXTWF2RVE\_BOOKING\Booking By Year\FlyBuy Booking Data (BGAU & BGID & KE).xlsx'
df_booking = pd.read_excel(path, dtype='string', sheet_name='BOOKING_BGAU_BGID_KE')

path = r'G:\.shortcut-targets-by-id\0B_d3smBjzo04UUNBME5GOVhoMjA\_ODYSSEY\Phone Members.xlsx'
df_phone = pd.read_excel(path, dtype='string', sheet_name='Sheet1')

path = r'G:\.shortcut-targets-by-id\0B_d3smBjzo04UUNBME5GOVhoMjA\_ODYSSEY\Email Members.xlsx'
df_email = pd.read_excel(path, dtype='string', sheet_name='Sheet1')

# %%
df = m.load_data_multiple(dir_path, file_name, cols)
count_data_awal = df.shape[0]
df = df.reindex(columns=cols)
df.shape[0]

df['Created Time'] = pd.to_datetime(df['Created Time'], format='%Y-%m-%d %H:%M:%S')
df.dtypes
# Out:
# Record Id                          string
# Created Time               datetime64[ns]
# Created Date                       string
# First Name                         string
# Last Name                          string
# Email                              string
# Phone                              string
# Mobile                             string
# Birthdate                          string
# Year of Birth                      string
# Street                             string
# Street2                            string
# City                               string
# State                              string
# Country                            string
# Nationality                        string
# Booking Status                     string
# BookRef                            string
# Departure Date                     string
# Arrival Date                       string
# Card Type                          string
# Marital Status                     string
# Lead Brand                         string
# Lead Sub-Brand                     string
# Lead Source                        string
# Lead Locations                     string
# Lead Source Description            string
# Lead Regions                       string
# Lead Status                        string
# Email Opt Out                      string
# Opt In                             string
# dtype: object

# %%
df_past_guest = df.loc[df['Lead Source'] == 'Past Guests'].groupby('Lead Locations')['Record Id'].count().reset_index(name='Count Data').copy()
df_past_guest.to_excel(r'C:\Users\fajar\Documents\Python\Data\past_guest_location.xlsx', index=False)

# %%
zoho_filter = fil.guest_exit_india_team(df)
zoho_df = df.loc[zoho_filter].copy() # menggunakan copy untuk menghindari setting copy warning
zoho_df.reset_index(drop=True, inplace=True)
count_filter_awal = zoho_df.shape[0]

# mengisi kolom <NA> dengan value string 'empty' supaya mudah mengecek data member dan booking dengan isin

zoho_df.fillna('empty', inplace=True)
zoho_df
# Out:
#                    Record Id        Created Time Created Date      First Name  \
# 0   zcrm_3584690000432471430 2023-03-02 13:26:14        empty       SHESHNATH
# 1   zcrm_3584690000432471485 2023-03-02 14:21:08        empty  MANPREET SINGH
# 2   zcrm_3584690000432471519 2023-03-02 17:09:58        empty       CASSANDRA
# 3   zcrm_3584690000432471574 2023-03-02 18:25:43        empty           SUMIT
# 4   zcrm_3584690000432480370 2023-03-02 14:09:26        empty         CAMERON
# ..                       ...                 ...          ...             ...
# 87  zcrm_3584690000433188436 2023-03-05 16:09:39        empty         MANIKAM
# 88  zcrm_3584690000433188465 2023-03-05 16:16:47        empty            YYAN
# 89  zcrm_3584690000433201571 2023-03-06 16:34:51        empty         SANDEEP
# 90  zcrm_3584690000433202137 2023-03-05 12:05:08        empty           THANG
# 91  zcrm_3584690000433202166 2023-03-05 12:18:21        empty          RAHMAT
#
#      Last Name                        Email           Phone Mobile  \
# 0       PANDEY      sheshnath8953@gmail.com   +918953096800  empty
# 1        OTTAL      ottalmanpreet@gmail.com    +61470350302  empty
# 2         HUNN             hunncd@gmail.com    +64273070723  empty
# 3        SINGH       sumitsinghau@gmail.com    +61455091990  empty
# 4       TALEBI      camerontalebi@gmail.com    +19255862443  empty
# ..         ...                          ...             ...    ...
# 87       NAIDU          anaidu729@gmail.com    +27837843483  empty
# 88  PROVENCHER     yvanpro.psy@videotron.ca    +15142291761  empty
# 89      GANDHI          sangandhi@yahoo.com    +14162588653  empty
# 90       LIENG      thanglpt@hotmail.com.au    +61430378288  empty
# 91     SUTISNA  rahmat.sutisnaa65@gmail.com  +6282298207633  empty
#
#      Birthdate Year of Birth  ... Marital Status           Lead Brand  \
# 0   1991-01-15          1991  ...          empty  Timeshare Marketing
# 1   1984-09-26          1984  ...          empty  Timeshare Marketing
# 2   1978-04-30          1978  ...          empty  Timeshare Marketing
# 3   1990-11-16          1990  ...          empty  Timeshare Marketing
# 4   1991-06-19          1991  ...          empty  Timeshare Marketing
# ..         ...           ...  ...            ...                  ...
# 87  1955-03-08          1955  ...          empty  Timeshare Marketing
# 88  1957-10-13          1957  ...          empty  Timeshare Marketing
# 89  1967-12-06          1967  ...          empty  Timeshare Marketing
# 90  1969-09-09          1969  ...          empty  Timeshare Marketing
# 91  1965-10-17          1965  ...          empty  Timeshare Marketing
#
#    Lead Sub-Brand Lead Source       Lead Locations  \
# 0             KCE  Guest Exit  Sales Deck Jimbaran
# 1             KCE  Guest Exit  Sales Deck Jimbaran
# 2             KCE  Guest Exit  Sales Deck Jimbaran
# 3             KCE  Guest Exit  Sales Deck Jimbaran
# 4             KCE  Guest Exit  Sales Deck Jimbaran
# ..            ...         ...                  ...
# 87            KCE  Guest Exit  Sales Deck Jimbaran
# 88            KCE  Guest Exit  Sales Deck Jimbaran
# 89            KCE  Guest Exit  Sales Deck Jimbaran
# 90            KCE  Guest Exit  Sales Deck Jimbaran
# 91            KCE  Guest Exit  Sales Deck Jimbaran
#
#                               Lead Source Description Lead Regions  \
# 0   REGISTRATION CONFIRMED | Your Exclusive 7 NIGH...         SEAP
# 1   REGISTRATION CONFIRMED | Your Exclusive 7 NIGH...         SEAP
# 2   REGISTRATION CONFIRMED | Your Exclusive 7 NIGH...         SEAP
# 3   REGISTRATION CONFIRMED | Your Exclusive 7 NIGH...         SEAP
# 4   REGISTRATION CONFIRMED | Your Exclusive 7 NIGH...         SEAP
# ..                                                ...          ...
# 87  REGISTRATION CONFIRMED | Your Exclusive 7 NIGH...         SEAP
# 88  REGISTRATION CONFIRMED | Your Exclusive 7 NIGH...         SEAP
# 89  REGISTRATION CONFIRMED | Your Exclusive 7 NIGH...         SEAP
# 90  REGISTRATION CONFIRMED | Your Exclusive 7 NIGH...         SEAP
# 91  REGISTRATION CONFIRMED | Your Exclusive 7 NIGH...         SEAP
#
#      Lead Status Email Opt Out Opt In
# 0   Hot Prospect         false  false
# 1   Hot Prospect         false  false
# 2   Hot Prospect         false  false
# 3   Hot Prospect         false  false
# 4   Hot Prospect         false  false
# ..           ...           ...    ...
# 87  Hot Prospect         false  false
# 88  Hot Prospect         false  false
# 89  Hot Prospect         false  false
# 90  Hot Prospect         false  false
# 91  Hot Prospect         false  false
#
# [92 rows x 31 columns]

# %% [markdown]
# # ====================== Awal Filter Umum ======================

# %%
# data phone, mobile dam email member yang ada di master data (wash member)

m.clean_number(zoho_df, 'Phone')
m.clean_number(zoho_df, 'Mobile')
m.replace_not_valid_to_empty(zoho_df, 'Phone')
m.replace_not_valid_to_empty(zoho_df, 'Mobile')
zoho_df['Email'] = m.lowercase(zoho_df, 'Email')
m.clean_space(zoho_df, 'Email')

m.clean_number(df_booking, 'Phone1')
m.clean_number(df_booking, 'Mobile')
df_booking['Email'] = m.lowercase(df_booking, 'Email')
m.clean_space(df_booking, 'Email')

m.clean_number(df_phone, 'Mobile')

df_email['Email'] = m.lowercase(df_email, 'Email')
m.clean_space(df_email, 'Email')

count_deleted_wrong_format = m.delete_email_wrong_format(zoho_df, 'Email')
count_after_deleted_wrong_format = zoho_df.shape[0]

# %%
# Cek leads test
test_leads = zoho_df.loc[
    
        zoho_df['Email'].str.contains('^test@', flags=re.I, regex=True) |
        zoho_df['Email'].str.contains('\+test', flags=re.I, regex=True) |
    
        zoho_df['First Name'].str.contains('^test$', flags=re.I, regex=True) |
        zoho_df['Last Name'].str.contains('^test$', flags=re.I, regex=True) |

        zoho_df['First Name'].str.contains('test 1', flags=re.I, regex=True) |
        zoho_df['Last Name'].str.contains('test 2', flags=re.I, regex=True)|
        zoho_df['First Name'].str.contains('test1', flags=re.I, regex=True) |
        zoho_df['Last Name'].str.contains('test2', flags=re.I, regex=True)|

        zoho_df['First Name'].str.contains(' test ', flags=re.I, regex=True) | 
        zoho_df['Last Name'].str.contains(' test ', flags=re.I, regex=True) | 
        zoho_df['Last Name'].str.contains(' test$', flags=re.I, regex=True)
    ]

count_leads_test = test_leads.shape[0]

# test_leads.to_excel(r'C:\Users\fajar\Documents\Python\Data\test_leads_2.xlsx', index=False)
test_leads
# Out:
# Empty DataFrame
# Columns: [Record Id, Created Time, Created Date, First Name, Last Name, Email, Phone, Mobile, Birthdate, Year of Birth, Street, Street2, City, State, Country, Nationality, Booking Status, BookRef, Departure Date, Arrival Date, Card Type, Marital Status, Lead Brand, Lead Sub-Brand, Lead Source, Lead Locations, Lead Source Description, Lead Regions, Lead Status, Email Opt Out, Opt In]
# Index: []
#
# [0 rows x 31 columns]

# %%
zoho_df.drop(test_leads.index, inplace=True)
zoho_df.reset_index(drop=True, inplace=True)

count_after_dedup_test = zoho_df.shape[0]

# %%
# Cek Email Karma
email_karma = m.find_karma(zoho_df, 'Email')
count_email_karma = email_karma.shape[0]
# email_OTA.to_excel(r'C:\Users\fajar\Documents\Python\Data\email_OTA.xlsx', index=False)

email_karma
# Out:
# johnspence88@hotmail\.com|baligetaway|rottnestlodge\.com\.au|hotel.discount|adimahkota\.com|baligetaway\.co\.id|baligetaway\.com\.au|catkingproductions\.com|complementarystay-karmaexperience\.com|confirmation-karmaexperience\.com|tiketmurahbali\.com|karmasanctumsoho\.co|experiencekarmaclub\.com|karmabavaria\.com|karmabeach\.com|karmaclub\.com|karmadevelopments\.com|karmaestates\.com|karmaexperience\.co\.uk|karmaexperience\.com|karmaexperience\.in|karmagroup\.com|karmajimbaran\.com|karmakandara\.com|karmaminoan\.com|karmanormandy\.com|karmapelikanos\.com|karmareef\.com|karmaresorts\.com|karmaroyalexperience\.co\.uk|karmaroyalexperience\.com|karmaroyalgroup\.com|karmaroyalvacations\.com|karmasalak\.com|karmasalfordhall\.com|karmastmartins\.com|karmgroup\.com|krresidences\.com|lepreverger\.com|odysseypremier\.com|rci\.com|thebaligetaway\.comkarmarottnest\.com\.au|karmasanctumonthegreen\.com|karmasanctumclub\.com|karma\.co\.uk|karma\.com|karmarottnest\.com\.au|karmasanctumsoho\.com|karmaroyalpromotions\.com
# Empty DataFrame
# Columns: [Record Id, Created Time, Created Date, First Name, Last Name, Email, Phone, Mobile, Birthdate, Year of Birth, Street, Street2, City, State, Country, Nationality, Booking Status, BookRef, Departure Date, Arrival Date, Card Type, Marital Status, Lead Brand, Lead Sub-Brand, Lead Source, Lead Locations, Lead Source Description, Lead Regions, Lead Status, Email Opt Out, Opt In]
# Index: []
#
# [0 rows x 31 columns]

# %%
# delete email Karma
count_after_clean_karma = m.delete_karma(zoho_df, 'Email')
# zoho_df.to_excel(r'C:\Users\fajar\Documents\Python\Data\after_clean_OTA.xlsx', index=False)

zoho_df
# Out:
#                    Record Id        Created Time Created Date      First Name  \
# 0   zcrm_3584690000432471430 2023-03-02 13:26:14        empty       SHESHNATH
# 1   zcrm_3584690000432471485 2023-03-02 14:21:08        empty  MANPREET SINGH
# 2   zcrm_3584690000432471519 2023-03-02 17:09:58        empty       CASSANDRA
# 3   zcrm_3584690000432471574 2023-03-02 18:25:43        empty           SUMIT
# 4   zcrm_3584690000432480370 2023-03-02 14:09:26        empty         CAMERON
# ..                       ...                 ...          ...             ...
# 87  zcrm_3584690000433188436 2023-03-05 16:09:39        empty         MANIKAM
# 88  zcrm_3584690000433188465 2023-03-05 16:16:47        empty            YYAN
# 89  zcrm_3584690000433201571 2023-03-06 16:34:51        empty         SANDEEP
# 90  zcrm_3584690000433202137 2023-03-05 12:05:08        empty           THANG
# 91  zcrm_3584690000433202166 2023-03-05 12:18:21        empty          RAHMAT
#
#      Last Name                        Email          Phone Mobile   Birthdate  \
# 0       PANDEY      sheshnath8953@gmail.com   918953096800  empty  1991-01-15
# 1        OTTAL      ottalmanpreet@gmail.com    61470350302  empty  1984-09-26
# 2         HUNN             hunncd@gmail.com    64273070723  empty  1978-04-30
# 3        SINGH       sumitsinghau@gmail.com    61455091990  empty  1990-11-16
# 4       TALEBI      camerontalebi@gmail.com    19255862443  empty  1991-06-19
# ..         ...                          ...            ...    ...         ...
# 87       NAIDU          anaidu729@gmail.com    27837843483  empty  1955-03-08
# 88  PROVENCHER     yvanpro.psy@videotron.ca    15142291761  empty  1957-10-13
# 89      GANDHI          sangandhi@yahoo.com    14162588653  empty  1967-12-06
# 90       LIENG      thanglpt@hotmail.com.au    61430378288  empty  1969-09-09
# 91     SUTISNA  rahmat.sutisnaa65@gmail.com  6282298207633  empty  1965-10-17
#
#    Year of Birth  ... Marital Status           Lead Brand Lead Sub-Brand  \
# 0           1991  ...          empty  Timeshare Marketing            KCE
# 1           1984  ...          empty  Timeshare Marketing            KCE
# 2           1978  ...          empty  Timeshare Marketing            KCE
# 3           1990  ...          empty  Timeshare Marketing            KCE
# 4           1991  ...          empty  Timeshare Marketing            KCE
# ..           ...  ...            ...                  ...            ...
# 87          1955  ...          empty  Timeshare Marketing            KCE
# 88          1957  ...          empty  Timeshare Marketing            KCE
# 89          1967  ...          empty  Timeshare Marketing            KCE
# 90          1969  ...          empty  Timeshare Marketing            KCE
# 91          1965  ...          empty  Timeshare Marketing            KCE
#
#    Lead Source       Lead Locations  \
# 0   Guest Exit  Sales Deck Jimbaran
# 1   Guest Exit  Sales Deck Jimbaran
# 2   Guest Exit  Sales Deck Jimbaran
# 3   Guest Exit  Sales Deck Jimbaran
# 4   Guest Exit  Sales Deck Jimbaran
# ..         ...                  ...
# 87  Guest Exit  Sales Deck Jimbaran
# 88  Guest Exit  Sales Deck Jimbaran
# 89  Guest Exit  Sales Deck Jimbaran
# 90  Guest Exit  Sales Deck Jimbaran
# 91  Guest Exit  Sales Deck Jimbaran
#
#                               Lead Source Description Lead Regions  \
# 0   REGISTRATION CONFIRMED | Your Exclusive 7 NIGH...         SEAP
# 1   REGISTRATION CONFIRMED | Your Exclusive 7 NIGH...         SEAP
# 2   REGISTRATION CONFIRMED | Your Exclusive 7 NIGH...         SEAP
# 3   REGISTRATION CONFIRMED | Your Exclusive 7 NIGH...         SEAP
# 4   REGISTRATION CONFIRMED | Your Exclusive 7 NIGH...         SEAP
# ..                                                ...          ...
# 87  REGISTRATION CONFIRMED | Your Exclusive 7 NIGH...         SEAP
# 88  REGISTRATION CONFIRMED | Your Exclusive 7 NIGH...         SEAP
# 89  REGISTRATION CONFIRMED | Your Exclusive 7 NIGH...         SEAP
# 90  REGISTRATION CONFIRMED | Your Exclusive 7 NIGH...         SEAP
# 91  REGISTRATION CONFIRMED | Your Exclusive 7 NIGH...         SEAP
#
#      Lead Status Email Opt Out Opt In
# 0   Hot Prospect         false  false
# 1   Hot Prospect         false  false
# 2   Hot Prospect         false  false
# 3   Hot Prospect         false  false
# 4   Hot Prospect         false  false
# ..           ...           ...    ...
# 87  Hot Prospect         false  false
# 88  Hot Prospect         false  false
# 89  Hot Prospect         false  false
# 90  Hot Prospect         false  false
# 91  Hot Prospect         false  false
#
# [92 rows x 31 columns]

# %%
# hitung jumlah duplicate
count_duplicate_general = zoho_df.loc[zoho_df.duplicated(subset=['Phone','Mobile','Email'])].shape[0]

zoho_df.loc[zoho_df.duplicated(subset=['Phone','Mobile','Email'])]
# Out:
# Empty DataFrame
# Columns: [Record Id, Created Time, Created Date, First Name, Last Name, Email, Phone, Mobile, Birthdate, Year of Birth, Street, Street2, City, State, Country, Nationality, Booking Status, BookRef, Departure Date, Arrival Date, Card Type, Marital Status, Lead Brand, Lead Sub-Brand, Lead Source, Lead Locations, Lead Source Description, Lead Regions, Lead Status, Email Opt Out, Opt In]
# Index: []
#
# [0 rows x 31 columns]

# %%
zoho_df.drop_duplicates(subset=['Phone','Mobile','Email'], inplace=True)
zoho_df.reset_index(drop=True, inplace=True)

# hitung jumlah setelah value duplicate dihapus
count_after_dedup_duplicate = zoho_df.shape[0]

zoho_df
# Out:
#                    Record Id        Created Time Created Date      First Name  \
# 0   zcrm_3584690000432471430 2023-03-02 13:26:14        empty       SHESHNATH
# 1   zcrm_3584690000432471485 2023-03-02 14:21:08        empty  MANPREET SINGH
# 2   zcrm_3584690000432471519 2023-03-02 17:09:58        empty       CASSANDRA
# 3   zcrm_3584690000432471574 2023-03-02 18:25:43        empty           SUMIT
# 4   zcrm_3584690000432480370 2023-03-02 14:09:26        empty         CAMERON
# ..                       ...                 ...          ...             ...
# 87  zcrm_3584690000433188436 2023-03-05 16:09:39        empty         MANIKAM
# 88  zcrm_3584690000433188465 2023-03-05 16:16:47        empty            YYAN
# 89  zcrm_3584690000433201571 2023-03-06 16:34:51        empty         SANDEEP
# 90  zcrm_3584690000433202137 2023-03-05 12:05:08        empty           THANG
# 91  zcrm_3584690000433202166 2023-03-05 12:18:21        empty          RAHMAT
#
#      Last Name                        Email          Phone Mobile   Birthdate  \
# 0       PANDEY      sheshnath8953@gmail.com   918953096800  empty  1991-01-15
# 1        OTTAL      ottalmanpreet@gmail.com    61470350302  empty  1984-09-26
# 2         HUNN             hunncd@gmail.com    64273070723  empty  1978-04-30
# 3        SINGH       sumitsinghau@gmail.com    61455091990  empty  1990-11-16
# 4       TALEBI      camerontalebi@gmail.com    19255862443  empty  1991-06-19
# ..         ...                          ...            ...    ...         ...
# 87       NAIDU          anaidu729@gmail.com    27837843483  empty  1955-03-08
# 88  PROVENCHER     yvanpro.psy@videotron.ca    15142291761  empty  1957-10-13
# 89      GANDHI          sangandhi@yahoo.com    14162588653  empty  1967-12-06
# 90       LIENG      thanglpt@hotmail.com.au    61430378288  empty  1969-09-09
# 91     SUTISNA  rahmat.sutisnaa65@gmail.com  6282298207633  empty  1965-10-17
#
#    Year of Birth  ... Marital Status           Lead Brand Lead Sub-Brand  \
# 0           1991  ...          empty  Timeshare Marketing            KCE
# 1           1984  ...          empty  Timeshare Marketing            KCE
# 2           1978  ...          empty  Timeshare Marketing            KCE
# 3           1990  ...          empty  Timeshare Marketing            KCE
# 4           1991  ...          empty  Timeshare Marketing            KCE
# ..           ...  ...            ...                  ...            ...
# 87          1955  ...          empty  Timeshare Marketing            KCE
# 88          1957  ...          empty  Timeshare Marketing            KCE
# 89          1967  ...          empty  Timeshare Marketing            KCE
# 90          1969  ...          empty  Timeshare Marketing            KCE
# 91          1965  ...          empty  Timeshare Marketing            KCE
#
#    Lead Source       Lead Locations  \
# 0   Guest Exit  Sales Deck Jimbaran
# 1   Guest Exit  Sales Deck Jimbaran
# 2   Guest Exit  Sales Deck Jimbaran
# 3   Guest Exit  Sales Deck Jimbaran
# 4   Guest Exit  Sales Deck Jimbaran
# ..         ...                  ...
# 87  Guest Exit  Sales Deck Jimbaran
# 88  Guest Exit  Sales Deck Jimbaran
# 89  Guest Exit  Sales Deck Jimbaran
# 90  Guest Exit  Sales Deck Jimbaran
# 91  Guest Exit  Sales Deck Jimbaran
#
#                               Lead Source Description Lead Regions  \
# 0   REGISTRATION CONFIRMED | Your Exclusive 7 NIGH...         SEAP
# 1   REGISTRATION CONFIRMED | Your Exclusive 7 NIGH...         SEAP
# 2   REGISTRATION CONFIRMED | Your Exclusive 7 NIGH...         SEAP
# 3   REGISTRATION CONFIRMED | Your Exclusive 7 NIGH...         SEAP
# 4   REGISTRATION CONFIRMED | Your Exclusive 7 NIGH...         SEAP
# ..                                                ...          ...
# 87  REGISTRATION CONFIRMED | Your Exclusive 7 NIGH...         SEAP
# 88  REGISTRATION CONFIRMED | Your Exclusive 7 NIGH...         SEAP
# 89  REGISTRATION CONFIRMED | Your Exclusive 7 NIGH...         SEAP
# 90  REGISTRATION CONFIRMED | Your Exclusive 7 NIGH...         SEAP
# 91  REGISTRATION CONFIRMED | Your Exclusive 7 NIGH...         SEAP
#
#      Lead Status Email Opt Out Opt In
# 0   Hot Prospect         false  false
# 1   Hot Prospect         false  false
# 2   Hot Prospect         false  false
# 3   Hot Prospect         false  false
# 4   Hot Prospect         false  false
# ..           ...           ...    ...
# 87  Hot Prospect         false  false
# 88  Hot Prospect         false  false
# 89  Hot Prospect         false  false
# 90  Hot Prospect         false  false
# 91  Hot Prospect         false  false
#
# [92 rows x 31 columns]

# %%
find_member_booking = zoho_df.copy()

find_member_booking.loc[find_member_booking['Phone'].isin(df_booking['Phone1']), 'Same Value Find'] = 'Booking-Phone1'
find_member_booking.loc[find_member_booking['Phone'].isin(df_booking['Mobile']), 'Same Value Find'] = 'Booking-Mobile'
find_member_booking.loc[find_member_booking['Mobile'].isin(df_booking['Phone1']), 'Same Value Find'] = 'Booking-Phone1' 
find_member_booking.loc[find_member_booking['Mobile'].isin(df_booking['Mobile']), 'Same Value Find'] = 'Booking-Mobile'
find_member_booking.loc[find_member_booking['Email'].isin(df_booking['Email']), 'Same Value Find'] = 'Booking-Email'

find_member_booking.loc[find_member_booking['Phone'].isin(df_phone['Mobile']), 'Same Value Find'] = 'Member-Mobile' 
find_member_booking.loc[find_member_booking['Mobile'].isin(df_phone['Mobile']), 'Same Value Find'] = 'Member-Mobile'

find_member_booking.loc[find_member_booking['Email'].isin(df_email['Email']), 'Same Value Find'] = 'Member-Email'

find_member_booking.drop(find_member_booking.loc[find_member_booking['Same Value Find'].isna()].index, inplace=True)

count_booking_dedup = find_member_booking.loc[find_member_booking['Same Value Find'].str.contains('Booking', flags=re.I, regex=True)].shape[0]
count_member_dedup = find_member_booking.loc[find_member_booking['Same Value Find'].str.contains('Member', flags=re.I, regex=True)].shape[0]

find_member_booking.replace('empty', '', inplace=True)
# find_member_booking.to_csv(r'C:\Users\fajar\Documents\Python\Data\booking-member-dedup(guest_exit).csv', index=False)

#find_member_booking.loc[find_member_booking['Same Value Find'] == 'Booking-Phone1']

# %%
# data phone, mobile dam email member yang ada di master data 
count_wash_member = zoho_df.loc[
    zoho_df['Phone'].isin(df_booking['Phone1']) | 
    zoho_df['Phone'].isin(df_booking['Mobile']) |
    zoho_df['Mobile'].isin(df_booking['Phone1']) | 
    zoho_df['Mobile'].isin(df_booking['Mobile']) |
    zoho_df['Email'].isin(df_booking['Email'])| 

    zoho_df['Phone'].isin(df_phone['Mobile']) | 
    zoho_df['Mobile'].isin(df_phone['Mobile']) |

    zoho_df['Email'].isin(df_email['Email'])

].shape[0]

zoho_df.drop(zoho_df.loc[
    zoho_df['Phone'].isin(df_booking['Phone1']) | 
    zoho_df['Phone'].isin(df_booking['Mobile']) |
    zoho_df['Mobile'].isin(df_booking['Phone1']) | 
    zoho_df['Mobile'].isin(df_booking['Mobile']) |
    zoho_df['Email'].isin(df_booking['Email']) |
    
    zoho_df['Phone'].isin(df_phone['Mobile']) | 
    zoho_df['Mobile'].isin(df_phone['Mobile']) |

    zoho_df['Email'].isin(df_email['Email'])

    ].index, inplace=True)
    
zoho_df.reset_index(drop=True, inplace=True)

count_after_wash_member = zoho_df.shape[0]

# %% [markdown]
# # ====================== Akhir Filter Umum ======================

# %%
find_exist_kce = zoho_df.copy()

find_exist_kce.loc[find_exist_kce['Phone'].isin(df_all_kce['Phone']), 'Same Value Find'] = 'Exist-Phone'
find_exist_kce.loc[find_exist_kce['Mobile'].isin(df_all_kce['Phone']), 'Same Value Find'] = 'Exist-Phone' 
find_exist_kce.loc[find_exist_kce['Email'].isin(df_all_kce['Email']), 'Same Value Find'] = 'Exist-Email'

find_exist_kce.drop(find_exist_kce.loc[find_exist_kce['Same Value Find'].isna()].index, inplace=True)

find_member_booking.replace('empty', '', inplace=True)
# find_member_booking.to_csv(r'C:\Users\fajar\Documents\Python\Data\zoho_exist_in_kce.csv', index=False)

#find_member_booking.loc[find_member_booking['Same Value Find'] == 'Booking-Phone1']

# %%
count_wash_exist = zoho_df.loc[
    zoho_df['Phone'].isin(df_all_kce['Phone']) | 
    zoho_df['Mobile'].isin(df_all_kce['Phone']) | 
    zoho_df['Email'].isin(df_all_kce['Email'])
].shape[0]

zoho_df.drop(zoho_df.loc[
    zoho_df['Phone'].isin(df_all_kce['Phone']) | 
    zoho_df['Mobile'].isin(df_all_kce['Phone']) | 
    zoho_df['Email'].isin(df_all_kce['Email'])
].index , inplace=True)

count_after_wash_exist = zoho_df.shape[0]
count_wash_exist
# Out:
# 0

# %%
count_email_only = zoho_df.loc[(zoho_df['Email'] != 'empty') & ((zoho_df['Phone'] == 'empty') & (zoho_df['Mobile'] == 'empty'))].shape[0]
count_phone_only = zoho_df.loc[(zoho_df['Email'] == 'empty') & ((zoho_df['Phone'] != 'empty') | (zoho_df['Mobile'] != 'empty'))].shape[0]
count_email_and_phone = zoho_df.loc[(zoho_df['Email'] != 'empty') & ((zoho_df['Phone'] != 'empty') | (zoho_df['Mobile'] != 'empty'))].shape[0]

count_blank = zoho_df.loc[(zoho_df['Email'] =='empty') & (zoho_df['Phone']=='empty') & (zoho_df['Mobile']=='empty')].shape[0]

# zoho_df.loc[(zoho_df['Email'] =='empty') & (zoho_df['Phone']=='empty') & (zoho_df['Mobile']=='empty')].to_excel(r'C:\Users\fajar\Documents\Python\Data\blank_data.xlsx', index=False)

zoho_df.loc[(zoho_df['Email'] != 'empty') & ((zoho_df['Phone'] == 'empty') & (zoho_df['Mobile'] == 'empty')), 'Contact Type'] = 'Email Only'
zoho_df.loc[(zoho_df['Email'] == 'empty') & ((zoho_df['Phone'] != 'empty') | (zoho_df['Mobile'] != 'empty')), 'Contact Type'] = 'Phone Only'
zoho_df.loc[(zoho_df['Email'] != 'empty') & ((zoho_df['Phone'] != 'empty') | (zoho_df['Mobile'] != 'empty')), 'Contact Type'] = 'Email and Phone'

zoho_df.drop(zoho_df.loc[(zoho_df['Email'] =='empty') & (zoho_df['Phone']=='empty') & (zoho_df['Mobile']=='empty')].index, inplace=True)
zoho_df.reset_index(drop=True, inplace=True)

count_after_wash_blank = zoho_df.shape[0]

# %%
print("==========================================================")
print("Summary")
print("==========================================================")
print("Jumlah Keseluruhan Master Zoho : "+str(count_data_awal))
print("Jumlah Filter Leads Awal : "+str(count_filter_awal))
print("Jumlah Format Email Salah : "+str(count_deleted_wrong_format))
print("Jumlah Setelah Clean Format Email Salah : "+str(count_after_deleted_wrong_format))
print("Jumlah Lead Test : "+str(count_leads_test))
print("Jumlah Setelah Clean Lead Test : "+str(count_after_dedup_test))
print("Jumlah Email Karma : "+str(count_email_karma))
print("Jumlah Setelah Clean Email Karma : "+str(count_after_clean_karma))
print("Jumlah Duplicate (Phone, Mobile dan Email) : "+str(count_duplicate_general))
print("Jumlah Setelah Clean Duplicate : "+str(count_after_dedup_duplicate))
print("Jumlah Wash Member : "+str(count_member_dedup))
print("Jumlah Wash Booking : "+str(count_booking_dedup))
print("Jumlah Setelah Wash Member : "+str(count_after_wash_member))
print("Jumlah Wash Exist : "+str(count_wash_exist))
print("Jumlah Setelah Wash Exist : "+str(count_after_wash_exist))
print("Jumlah Phone Email Blank (Setelah phone yang tidak valid dihapus) : "+str(count_blank))
print("Jumlah Setelah Wash Phone Email Blank : "+str(count_after_wash_blank))
print("==========================================================")
print("Contact Type")
print("==========================================================")
print("Jumlah Email Only : "+str(count_email_only))
print("Jumlah Phone Only : "+str(count_phone_only))
print("Jumlah Email dan Phone : "+str(count_email_and_phone))
# Out:
# ==========================================================
# Summary
# ==========================================================
# Jumlah Keseluruhan Master Zoho : 4642005
# Jumlah Filter Leads Awal : 92
# Jumlah Format Email Salah : 0
# Jumlah Setelah Clean Format Email Salah : 92
# Jumlah Lead Test : 0
# Jumlah Setelah Clean Lead Test : 92
# Jumlah Email Karma : 0
# Jumlah Setelah Clean Email Karma : 92
# Jumlah Duplicate (Phone, Mobile dan Email) : 0
# Jumlah Setelah Clean Duplicate : 92
# Jumlah Wash Member : 0
# Jumlah Wash Booking : 0
# Jumlah Setelah Wash Member : 92
# Jumlah Wash Exist : 0
# Jumlah Setelah Wash Exist : 92
# Jumlah Phone Email Blank (Setelah phone yang tidak valid dihapus) : 0
# Jumlah Setelah Wash Phone Email Blank : 92
# ==========================================================
# Contact Type
# ==========================================================
# Jumlah Email Only : 0
# Jumlah Phone Only : 0
# Jumlah Email dan Phone : 92

# %%
zoho_df
# Out:
#                    Record Id        Created Time Created Date      First Name  \
# 0   zcrm_3584690000432471430 2023-03-02 13:26:14        empty       SHESHNATH
# 1   zcrm_3584690000432471485 2023-03-02 14:21:08        empty  MANPREET SINGH
# 2   zcrm_3584690000432471519 2023-03-02 17:09:58        empty       CASSANDRA
# 3   zcrm_3584690000432471574 2023-03-02 18:25:43        empty           SUMIT
# 4   zcrm_3584690000432480370 2023-03-02 14:09:26        empty         CAMERON
# ..                       ...                 ...          ...             ...
# 87  zcrm_3584690000433188436 2023-03-05 16:09:39        empty         MANIKAM
# 88  zcrm_3584690000433188465 2023-03-05 16:16:47        empty            YYAN
# 89  zcrm_3584690000433201571 2023-03-06 16:34:51        empty         SANDEEP
# 90  zcrm_3584690000433202137 2023-03-05 12:05:08        empty           THANG
# 91  zcrm_3584690000433202166 2023-03-05 12:18:21        empty          RAHMAT
#
#      Last Name                        Email          Phone Mobile   Birthdate  \
# 0       PANDEY      sheshnath8953@gmail.com   918953096800  empty  1991-01-15
# 1        OTTAL      ottalmanpreet@gmail.com    61470350302  empty  1984-09-26
# 2         HUNN             hunncd@gmail.com    64273070723  empty  1978-04-30
# 3        SINGH       sumitsinghau@gmail.com    61455091990  empty  1990-11-16
# 4       TALEBI      camerontalebi@gmail.com    19255862443  empty  1991-06-19
# ..         ...                          ...            ...    ...         ...
# 87       NAIDU          anaidu729@gmail.com    27837843483  empty  1955-03-08
# 88  PROVENCHER     yvanpro.psy@videotron.ca    15142291761  empty  1957-10-13
# 89      GANDHI          sangandhi@yahoo.com    14162588653  empty  1967-12-06
# 90       LIENG      thanglpt@hotmail.com.au    61430378288  empty  1969-09-09
# 91     SUTISNA  rahmat.sutisnaa65@gmail.com  6282298207633  empty  1965-10-17
#
#    Year of Birth  ...           Lead Brand Lead Sub-Brand Lead Source  \
# 0           1991  ...  Timeshare Marketing            KCE  Guest Exit
# 1           1984  ...  Timeshare Marketing            KCE  Guest Exit
# 2           1978  ...  Timeshare Marketing            KCE  Guest Exit
# 3           1990  ...  Timeshare Marketing            KCE  Guest Exit
# 4           1991  ...  Timeshare Marketing            KCE  Guest Exit
# ..           ...  ...                  ...            ...         ...
# 87          1955  ...  Timeshare Marketing            KCE  Guest Exit
# 88          1957  ...  Timeshare Marketing            KCE  Guest Exit
# 89          1967  ...  Timeshare Marketing            KCE  Guest Exit
# 90          1969  ...  Timeshare Marketing            KCE  Guest Exit
# 91          1965  ...  Timeshare Marketing            KCE  Guest Exit
#
#          Lead Locations                            Lead Source Description  \
# 0   Sales Deck Jimbaran  REGISTRATION CONFIRMED | Your Exclusive 7 NIGH...
# 1   Sales Deck Jimbaran  REGISTRATION CONFIRMED | Your Exclusive 7 NIGH...
# 2   Sales Deck Jimbaran  REGISTRATION CONFIRMED | Your Exclusive 7 NIGH...
# 3   Sales Deck Jimbaran  REGISTRATION CONFIRMED | Your Exclusive 7 NIGH...
# 4   Sales Deck Jimbaran  REGISTRATION CONFIRMED | Your Exclusive 7 NIGH...
# ..                  ...                                                ...
# 87  Sales Deck Jimbaran  REGISTRATION CONFIRMED | Your Exclusive 7 NIGH...
# 88  Sales Deck Jimbaran  REGISTRATION CONFIRMED | Your Exclusive 7 NIGH...
# 89  Sales Deck Jimbaran  REGISTRATION CONFIRMED | Your Exclusive 7 NIGH...
# 90  Sales Deck Jimbaran  REGISTRATION CONFIRMED | Your Exclusive 7 NIGH...
# 91  Sales Deck Jimbaran  REGISTRATION CONFIRMED | Your Exclusive 7 NIGH...
#
#    Lead Regions   Lead Status Email Opt Out Opt In     Contact Type
# 0          SEAP  Hot Prospect         false  false  Email and Phone
# 1          SEAP  Hot Prospect         false  false  Email and Phone
# 2          SEAP  Hot Prospect         false  false  Email and Phone
# 3          SEAP  Hot Prospect         false  false  Email and Phone
# 4          SEAP  Hot Prospect         false  false  Email and Phone
# ..          ...           ...           ...    ...              ...
# 87         SEAP  Hot Prospect         false  false  Email and Phone
# 88         SEAP  Hot Prospect         false  false  Email and Phone
# 89         SEAP  Hot Prospect         false  false  Email and Phone
# 90         SEAP  Hot Prospect         false  false  Email and Phone
# 91         SEAP  Hot Prospect         false  false  Email and Phone
#
# [92 rows x 32 columns]

# %%
# zoho_df.replace('empty', '', inplace=True)
# zoho_df.to_excel(r'C:\Users\fajar\Documents\Python\Data\Past Guest (AU).xlsx', index=False)
