# %%
import main_module as m
import zoho_filter_module as fil
import pandas as pd
import re
import numpy as np

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
path = r'G:\.shortcut-targets-by-id\0B_d3smBjzo04eXpvS1NXTWF2RVE\_BOOKING\Booking By Year\FlyBuy Booking Data (BGAU & BGID & KE).xlsx'
df_booking = pd.read_excel(path, dtype='string', sheet_name='BOOKING_BGAU_BGID_KE')

path = r'G:\.shortcut-targets-by-id\0B_d3smBjzo04UUNBME5GOVhoMjA\_ODYSSEY\Phone Members.xlsx'
df_phone = pd.read_excel(path, dtype='string', sheet_name='Sheet1')

path = r'G:\.shortcut-targets-by-id\0B_d3smBjzo04UUNBME5GOVhoMjA\_ODYSSEY\Email Members.xlsx'
df_email = pd.read_excel(path, dtype='string', sheet_name='Sheet1')

# %%
path = r'C:\Users\fajar\Documents\Python\Data\kce-feb-2023.xlsx'
zoho_df = pd.read_excel(path, dtype='string', sheet_name='Sheet0', engine='openpyxl')

zoho_df.fillna('empty', inplace=True)

count_data_awal = zoho_df.shape[0]
zoho_df
# Out:
# C:\Users\fajar\AppData\Roaming\Python\Python310\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
#                     Record Id        Record Id (Emails)         Created Time  \
# 0    zcrm_3584690000432131234  zcrm_3584690000432131252  2023-02-28 15:20:00
# 1    zcrm_3584690000432131151  zcrm_3584690000432131169  2023-02-28 13:52:00
# 2    zcrm_3584690000432128212  zcrm_3584690000432128230  2023-02-28 14:30:00
# 3    zcrm_3584690000432124265  zcrm_3584690000432124283  2023-02-28 15:05:00
# 4    zcrm_3584690000432124183  zcrm_3584690000432124201  2023-02-28 13:20:00
# ..                        ...                       ...                  ...
# 676  zcrm_3584690000426094324  zcrm_3584690000426094342  2023-02-02 11:23:00
# 677  zcrm_3584690000426088407  zcrm_3584690000426088425  2023-02-02 14:09:00
# 678  zcrm_3584690000426088376  zcrm_3584690000426088394  2023-02-02 13:33:00
# 679  zcrm_3584690000426084458  zcrm_3584690000426084476  2023-02-02 12:54:00
# 680  zcrm_3584690000426084403  zcrm_3584690000426084421  2023-02-02 12:01:00
#
#     Created Date    First Name        Last Name                       Email  \
# 0          empty   TAPIWANASHE         MAPUVIRE        zanarose.m@gmail.com
# 1          empty       MAHMOUD  SULEIMAN HALABI      mahmoudslm@hotmail.com
# 2          empty       RAYMOND             FREW         rayfrew@hotmail.com
# 3          empty     TUANG WOO              TAN      freddiettw@hotmail.com
# 4          empty       PRATEEK             JAIN   mannimitation23@gmail.com
# ..           ...           ...              ...                         ...
# 676        empty      FREDERIC        HAUVILLER     fredhauviller@gmail.com
# 677        empty  SUBIN SURESH             NAIR    subinsuresh991@gmail.com
# 678        empty        AKSARA        MAKKIMANE    akshara.raxidi@gmail.com
# 679        empty        MIGUEL           SANTOS          mjgs1979@gmail.com
# 680        empty        GIOZZI        GUILLAUME  giozzi.guillaume@gmail.com
#
#              Phone Mobile            Birthdate  ... Email Opt Out Opt In  \
# 0     +61424336334  empty  1995-01-10 00:00:00  ...         false  false
# 1     +61478654006  empty  1990-01-21 00:00:00  ...         false  false
# 2     +64277654188  empty  1982-01-04 00:00:00  ...         false  false
# 3      +6597200896  empty  1956-06-15 00:00:00  ...         false  false
# 4    +919983160789  empty  1990-10-23 00:00:00  ...         false  false
# ..             ...    ...                  ...  ...           ...    ...
# 676            +33  empty  1968-06-01 00:00:00  ...         false  false
# 677            +91  empty  1991-03-24 00:00:00  ...         false  false
# 678            +91  empty  1984-05-01 00:00:00  ...         false  false
# 679           +351  empty  1979-10-02 00:00:00  ...         false  false
# 680            +33  empty  1991-12-08 00:00:00  ...         false  false
#
#     Booking Status BookRef Guest Type  External ID GDPR Compliant Description  \
# 0            empty   empty      empty  IVO20232166          false       empty
# 1            empty   empty      empty  IVO20232163          false       empty
# 2            empty   empty      empty  IVO20232162          false       empty
# 3            empty   empty      empty  IVO20232146          false       empty
# 4            empty   empty      empty  IVO20232159          false       empty
# ..             ...     ...        ...          ...            ...         ...
# 676          empty   empty      empty  IVO20231060          false       empty
# 677          empty   empty      empty  IVO20231061          false       empty
# 678          empty   empty      empty  IVO20231064          false       empty
# 679          empty   empty      empty  IVO20231058          false       empty
# 680          empty   empty      empty  IVO20231068          false       empty
#
#     Media Source Code First Page Visited
# 0               empty              empty
# 1               empty              empty
# 2               empty              empty
# 3               empty              empty
# 4               empty              empty
# ..                ...                ...
# 676             empty              empty
# 677             empty              empty
# 678             empty              empty
# 679             empty              empty
# 680             empty              empty
#
# [681 rows x 38 columns]

# %% [markdown]
# # ====================== Awal Filter Umum ======================

# %%
# data phone, mobile dam email member yang ada di master data (wash member)

m.clean_number(zoho_df, 'Phone')
m.clean_number(zoho_df, 'Mobile')
m.replace_not_valid_to_empty(zoho_df, 'Phone')
m.replace_not_valid_to_empty(zoho_df, 'Mobile')
zoho_df['Email'] = m.lowercase(zoho_df, 'Email')
m.clean_space(zoho_df, 'Email')

m.clean_number(df_booking, 'Phone1')
m.clean_number(df_booking, 'Mobile')
df_booking['Email'] = m.lowercase(df_booking, 'Email')
m.clean_space(df_booking, 'Email')

m.clean_number(df_phone, 'Mobile')

df_email['Email'] = m.lowercase(df_email, 'Email')
m.clean_space(df_email, 'Email')

count_deleted_wrong_format = m.delete_email_wrong_format(zoho_df, 'Email')
count_after_deleted_wrong_format = zoho_df.shape[0]

# %%
# Cek leads test
test_leads = zoho_df.loc[
    
        zoho_df['Email'].str.contains('^test@', flags=re.I, regex=True) |
        zoho_df['Email'].str.contains('\+test', flags=re.I, regex=True) |
    
        zoho_df['First Name'].str.contains('^test$', flags=re.I, regex=True) |
        zoho_df['Last Name'].str.contains('^test$', flags=re.I, regex=True) |

        zoho_df['First Name'].str.contains('test 1', flags=re.I, regex=True) |
        zoho_df['Last Name'].str.contains('test 2', flags=re.I, regex=True)|
        zoho_df['First Name'].str.contains('test1', flags=re.I, regex=True) |
        zoho_df['Last Name'].str.contains('test2', flags=re.I, regex=True)|

        zoho_df['First Name'].str.contains(' test ', flags=re.I, regex=True) | 
        zoho_df['Last Name'].str.contains(' test ', flags=re.I, regex=True) | 
        zoho_df['Last Name'].str.contains(' test$', flags=re.I, regex=True)
    ]

count_leads_test = test_leads.shape[0]

# test_leads.to_excel(r'C:\Users\fajar\Documents\Python\Data\test_leads_2.xlsx', index=False)
test_leads
# Out:
# Empty DataFrame
# Columns: [Record Id, Record Id (Emails), Created Time, Created Date, First Name, Last Name, Email, Phone, Mobile, Birthdate, Year of Birth, Street, Street2, City, State, Country, Nationality, Departure Date, Arrival Date, Card Type, Marital Status, Lead Brand, Lead Sub-Brand, Lead Source, Lead Locations, Lead Source Description, Lead Regions, Lead Status, Email Opt Out, Opt In, Booking Status, BookRef, Guest Type, External ID, GDPR Compliant, Description, Media Source Code, First Page Visited]
# Index: []
#
# [0 rows x 38 columns]

# %%
zoho_df.drop(test_leads.index, inplace=True)
zoho_df.reset_index(drop=True, inplace=True)

count_after_dedup_test = zoho_df.shape[0]

# %%
# Cek Email Karma
email_karma = m.find_karma(zoho_df, 'Email')
count_email_karma = email_karma.shape[0]
# email_OTA.to_excel(r'C:\Users\fajar\Documents\Python\Data\email_OTA.xlsx', index=False)

email_karma
# Out:
#                     Record Id        Record Id (Emails)         Created Time  \
# 652  zcrm_3584690000426460208  zcrm_3584690000426460226  2023-02-03 15:33:00
#
#     Created Date First Name Last Name                              Email  \
# 652        empty    STEPHEN      DEAN  karma.concierge@karmasonghoai.com
#
#      Phone Mobile            Birthdate  ... Email Opt Out Opt In  \
# 652  empty  empty  1900-01-01 00:00:00  ...         false  false
#
#     Booking Status BookRef Guest Type External ID GDPR Compliant Description  \
# 652          empty   empty      empty   VTM202315          false       empty
#
#     Media Source Code First Page Visited
# 652             empty              empty
#
# [1 rows x 38 columns]

# %%
# delete email Karma
count_after_clean_karma = m.delete_karma(zoho_df, 'Email')
# zoho_df.to_excel(r'C:\Users\fajar\Documents\Python\Data\after_clean_OTA.xlsx', index=False)

zoho_df
# Out:
#                     Record Id        Record Id (Emails)         Created Time  \
# 0    zcrm_3584690000432131234  zcrm_3584690000432131252  2023-02-28 15:20:00
# 1    zcrm_3584690000432131151  zcrm_3584690000432131169  2023-02-28 13:52:00
# 2    zcrm_3584690000432128212  zcrm_3584690000432128230  2023-02-28 14:30:00
# 3    zcrm_3584690000432124265  zcrm_3584690000432124283  2023-02-28 15:05:00
# 4    zcrm_3584690000432124183  zcrm_3584690000432124201  2023-02-28 13:20:00
# ..                        ...                       ...                  ...
# 675  zcrm_3584690000426094324  zcrm_3584690000426094342  2023-02-02 11:23:00
# 676  zcrm_3584690000426088407  zcrm_3584690000426088425  2023-02-02 14:09:00
# 677  zcrm_3584690000426088376  zcrm_3584690000426088394  2023-02-02 13:33:00
# 678  zcrm_3584690000426084458  zcrm_3584690000426084476  2023-02-02 12:54:00
# 679  zcrm_3584690000426084403  zcrm_3584690000426084421  2023-02-02 12:01:00
#
#     Created Date    First Name        Last Name                       Email  \
# 0          empty   TAPIWANASHE         MAPUVIRE        zanarose.m@gmail.com
# 1          empty       MAHMOUD  SULEIMAN HALABI      mahmoudslm@hotmail.com
# 2          empty       RAYMOND             FREW         rayfrew@hotmail.com
# 3          empty     TUANG WOO              TAN      freddiettw@hotmail.com
# 4          empty       PRATEEK             JAIN   mannimitation23@gmail.com
# ..           ...           ...              ...                         ...
# 675        empty      FREDERIC        HAUVILLER     fredhauviller@gmail.com
# 676        empty  SUBIN SURESH             NAIR    subinsuresh991@gmail.com
# 677        empty        AKSARA        MAKKIMANE    akshara.raxidi@gmail.com
# 678        empty        MIGUEL           SANTOS          mjgs1979@gmail.com
# 679        empty        GIOZZI        GUILLAUME  giozzi.guillaume@gmail.com
#
#             Phone Mobile            Birthdate  ... Email Opt Out Opt In  \
# 0     61424336334  empty  1995-01-10 00:00:00  ...         false  false
# 1     61478654006  empty  1990-01-21 00:00:00  ...         false  false
# 2     64277654188  empty  1982-01-04 00:00:00  ...         false  false
# 3      6597200896  empty  1956-06-15 00:00:00  ...         false  false
# 4    919983160789  empty  1990-10-23 00:00:00  ...         false  false
# ..            ...    ...                  ...  ...           ...    ...
# 675         empty  empty  1968-06-01 00:00:00  ...         false  false
# 676         empty  empty  1991-03-24 00:00:00  ...         false  false
# 677         empty  empty  1984-05-01 00:00:00  ...         false  false
# 678         empty  empty  1979-10-02 00:00:00  ...         false  false
# 679         empty  empty  1991-12-08 00:00:00  ...         false  false
#
#     Booking Status BookRef Guest Type  External ID GDPR Compliant Description  \
# 0            empty   empty      empty  IVO20232166          false       empty
# 1            empty   empty      empty  IVO20232163          false       empty
# 2            empty   empty      empty  IVO20232162          false       empty
# 3            empty   empty      empty  IVO20232146          false       empty
# 4            empty   empty      empty  IVO20232159          false       empty
# ..             ...     ...        ...          ...            ...         ...
# 675          empty   empty      empty  IVO20231060          false       empty
# 676          empty   empty      empty  IVO20231061          false       empty
# 677          empty   empty      empty  IVO20231064          false       empty
# 678          empty   empty      empty  IVO20231058          false       empty
# 679          empty   empty      empty  IVO20231068          false       empty
#
#     Media Source Code First Page Visited
# 0               empty              empty
# 1               empty              empty
# 2               empty              empty
# 3               empty              empty
# 4               empty              empty
# ..                ...                ...
# 675             empty              empty
# 676             empty              empty
# 677             empty              empty
# 678             empty              empty
# 679             empty              empty
#
# [680 rows x 38 columns]

# %%
# hitung jumlah duplicate
count_duplicate_general = zoho_df.loc[zoho_df.duplicated(subset=['Phone','Mobile','Email'])].shape[0]

zoho_df.loc[zoho_df.duplicated(subset=['Phone','Mobile','Email'])]
# Out:
#                     Record Id        Record Id (Emails)         Created Time  \
# 335  zcrm_3584690000428955002  zcrm_3584690000428955020  2023-02-14 16:10:00
# 477  zcrm_3584690000427689870  zcrm_3584690000427689888  2023-02-10 17:29:00
# 596  zcrm_3584690000426780135  zcrm_3584690000426780153  2023-02-04 14:14:00
#
#     Created Date First Name Last Name                              Email  \
# 335        empty    ANTHONY   ROBERTS               kayabanana@gmail.com
# 477        empty       NEIZ   MANNING            neil.manning@xtra.co.nz
# 596        empty       DEAN    AUSTIN  experienced_traveller@hotmail.com
#
#            Phone Mobile            Birthdate  ... Email Opt Out Opt In  \
# 335  16613476737  empty  1969-12-25 00:00:00  ...         false  false
# 477   6421586532  empty  1969-02-02 00:00:00  ...         false  false
# 596  61994678003  empty  1960-01-04 00:00:00  ...         false  false
#
#     Booking Status BookRef Guest Type  External ID GDPR Compliant Description  \
# 335          empty   empty      empty  IVO20231602          false       empty
# 477          empty   empty      empty    VTM202339          false       empty
# 596          empty   empty      empty    VTM202320          false       empty
#
#     Media Source Code First Page Visited
# 335             empty              empty
# 477             empty              empty
# 596             empty              empty
#
# [3 rows x 38 columns]

# %%
zoho_df.drop_duplicates(subset=['Phone','Mobile','Email'], inplace=True)
zoho_df.reset_index(drop=True, inplace=True)

# hitung jumlah setelah value duplicate dihapus
count_after_dedup_duplicate = zoho_df.shape[0]

zoho_df
# Out:
#                     Record Id        Record Id (Emails)         Created Time  \
# 0    zcrm_3584690000432131234  zcrm_3584690000432131252  2023-02-28 15:20:00
# 1    zcrm_3584690000432131151  zcrm_3584690000432131169  2023-02-28 13:52:00
# 2    zcrm_3584690000432128212  zcrm_3584690000432128230  2023-02-28 14:30:00
# 3    zcrm_3584690000432124265  zcrm_3584690000432124283  2023-02-28 15:05:00
# 4    zcrm_3584690000432124183  zcrm_3584690000432124201  2023-02-28 13:20:00
# ..                        ...                       ...                  ...
# 672  zcrm_3584690000426094324  zcrm_3584690000426094342  2023-02-02 11:23:00
# 673  zcrm_3584690000426088407  zcrm_3584690000426088425  2023-02-02 14:09:00
# 674  zcrm_3584690000426088376  zcrm_3584690000426088394  2023-02-02 13:33:00
# 675  zcrm_3584690000426084458  zcrm_3584690000426084476  2023-02-02 12:54:00
# 676  zcrm_3584690000426084403  zcrm_3584690000426084421  2023-02-02 12:01:00
#
#     Created Date    First Name        Last Name                       Email  \
# 0          empty   TAPIWANASHE         MAPUVIRE        zanarose.m@gmail.com
# 1          empty       MAHMOUD  SULEIMAN HALABI      mahmoudslm@hotmail.com
# 2          empty       RAYMOND             FREW         rayfrew@hotmail.com
# 3          empty     TUANG WOO              TAN      freddiettw@hotmail.com
# 4          empty       PRATEEK             JAIN   mannimitation23@gmail.com
# ..           ...           ...              ...                         ...
# 672        empty      FREDERIC        HAUVILLER     fredhauviller@gmail.com
# 673        empty  SUBIN SURESH             NAIR    subinsuresh991@gmail.com
# 674        empty        AKSARA        MAKKIMANE    akshara.raxidi@gmail.com
# 675        empty        MIGUEL           SANTOS          mjgs1979@gmail.com
# 676        empty        GIOZZI        GUILLAUME  giozzi.guillaume@gmail.com
#
#             Phone Mobile            Birthdate  ... Email Opt Out Opt In  \
# 0     61424336334  empty  1995-01-10 00:00:00  ...         false  false
# 1     61478654006  empty  1990-01-21 00:00:00  ...         false  false
# 2     64277654188  empty  1982-01-04 00:00:00  ...         false  false
# 3      6597200896  empty  1956-06-15 00:00:00  ...         false  false
# 4    919983160789  empty  1990-10-23 00:00:00  ...         false  false
# ..            ...    ...                  ...  ...           ...    ...
# 672         empty  empty  1968-06-01 00:00:00  ...         false  false
# 673         empty  empty  1991-03-24 00:00:00  ...         false  false
# 674         empty  empty  1984-05-01 00:00:00  ...         false  false
# 675         empty  empty  1979-10-02 00:00:00  ...         false  false
# 676         empty  empty  1991-12-08 00:00:00  ...         false  false
#
#     Booking Status BookRef Guest Type  External ID GDPR Compliant Description  \
# 0            empty   empty      empty  IVO20232166          false       empty
# 1            empty   empty      empty  IVO20232163          false       empty
# 2            empty   empty      empty  IVO20232162          false       empty
# 3            empty   empty      empty  IVO20232146          false       empty
# 4            empty   empty      empty  IVO20232159          false       empty
# ..             ...     ...        ...          ...            ...         ...
# 672          empty   empty      empty  IVO20231060          false       empty
# 673          empty   empty      empty  IVO20231061          false       empty
# 674          empty   empty      empty  IVO20231064          false       empty
# 675          empty   empty      empty  IVO20231058          false       empty
# 676          empty   empty      empty  IVO20231068          false       empty
#
#     Media Source Code First Page Visited
# 0               empty              empty
# 1               empty              empty
# 2               empty              empty
# 3               empty              empty
# 4               empty              empty
# ..                ...                ...
# 672             empty              empty
# 673             empty              empty
# 674             empty              empty
# 675             empty              empty
# 676             empty              empty
#
# [677 rows x 38 columns]

# %%
find_member_booking = zoho_df.copy()

find_member_booking.loc[find_member_booking['Phone'].isin(df_booking['Phone1']), 'Same Value Find'] = 'Booking-Phone1'
find_member_booking.loc[find_member_booking['Phone'].isin(df_booking['Mobile']), 'Same Value Find'] = 'Booking-Mobile'
find_member_booking.loc[find_member_booking['Mobile'].isin(df_booking['Phone1']), 'Same Value Find'] = 'Booking-Phone1' 
find_member_booking.loc[find_member_booking['Mobile'].isin(df_booking['Mobile']), 'Same Value Find'] = 'Booking-Mobile'
find_member_booking.loc[find_member_booking['Email'].isin(df_booking['Email']), 'Same Value Find'] = 'Booking-Email'

find_member_booking.loc[find_member_booking['Phone'].isin(df_phone['Mobile']), 'Same Value Find'] = 'Member-Mobile' 
find_member_booking.loc[find_member_booking['Mobile'].isin(df_phone['Mobile']), 'Same Value Find'] = 'Member-Mobile'

find_member_booking.loc[find_member_booking['Email'].isin(df_email['Email']), 'Same Value Find'] = 'Member-Email'

find_member_booking.drop(find_member_booking.loc[find_member_booking['Same Value Find'].isna()].index, inplace=True)

count_booking_dedup = find_member_booking.loc[find_member_booking['Same Value Find'].str.contains('Booking', flags=re.I, regex=True)].shape[0]
count_member_dedup = find_member_booking.loc[find_member_booking['Same Value Find'].str.contains('Member', flags=re.I, regex=True)].shape[0]

find_member_booking.replace('empty', '', inplace=True)
find_member_booking.to_csv(r'C:\Users\fajar\Documents\Python\Data\booking-member-dedup(AU).csv', index=False)

#find_member_booking.loc[find_member_booking['Same Value Find'] == 'Booking-Phone1']

# %%
# data phone, mobile dam email member yang ada di master data 
count_wash_member = zoho_df.loc[
    zoho_df['Phone'].isin(df_booking['Phone1']) | 
    zoho_df['Phone'].isin(df_booking['Mobile']) |
    zoho_df['Mobile'].isin(df_booking['Phone1']) | 
    zoho_df['Mobile'].isin(df_booking['Mobile']) |
    zoho_df['Email'].isin(df_booking['Email'])| 

    zoho_df['Phone'].isin(df_phone['Mobile']) | 
    zoho_df['Mobile'].isin(df_phone['Mobile']) |

    zoho_df['Email'].isin(df_email['Email'])

].shape[0]

zoho_df.drop(zoho_df.loc[
    zoho_df['Phone'].isin(df_booking['Phone1']) | 
    zoho_df['Phone'].isin(df_booking['Mobile']) |
    zoho_df['Mobile'].isin(df_booking['Phone1']) | 
    zoho_df['Mobile'].isin(df_booking['Mobile']) |
    zoho_df['Email'].isin(df_booking['Email']) |
    
    zoho_df['Phone'].isin(df_phone['Mobile']) | 
    zoho_df['Mobile'].isin(df_phone['Mobile']) |

    zoho_df['Email'].isin(df_email['Email'])

    ].index, inplace=True)
    
zoho_df.reset_index(drop=True, inplace=True)

count_after_wash_member = zoho_df.shape[0]

# %%
count_email_only = zoho_df.loc[(zoho_df['Email'] != 'empty') & ((zoho_df['Phone'] == 'empty') & (zoho_df['Mobile'] == 'empty'))].shape[0]
count_phone_only = zoho_df.loc[(zoho_df['Email'] == 'empty') & ((zoho_df['Phone'] != 'empty') | (zoho_df['Mobile'] != 'empty'))].shape[0]
count_email_and_phone = zoho_df.loc[(zoho_df['Email'] != 'empty') & ((zoho_df['Phone'] != 'empty') | (zoho_df['Mobile'] != 'empty'))].shape[0]

count_blank = zoho_df.loc[(zoho_df['Email'] =='empty') & (zoho_df['Phone']=='empty') & (zoho_df['Mobile']=='empty')].shape[0]

# zoho_df.loc[(zoho_df['Email'] =='empty') & (zoho_df['Phone']=='empty') & (zoho_df['Mobile']=='empty')].to_excel(r'C:\Users\fajar\Documents\Python\Data\blank_data.xlsx', index=False)

zoho_df.loc[(zoho_df['Email'] != 'empty') & ((zoho_df['Phone'] == 'empty') & (zoho_df['Mobile'] == 'empty')), 'Contact Type'] = 'Email Only'
zoho_df.loc[(zoho_df['Email'] == 'empty') & ((zoho_df['Phone'] != 'empty') | (zoho_df['Mobile'] != 'empty')), 'Contact Type'] = 'Phone Only'
zoho_df.loc[(zoho_df['Email'] != 'empty') & ((zoho_df['Phone'] != 'empty') | (zoho_df['Mobile'] != 'empty')), 'Contact Type'] = 'Email and Phone'

zoho_df.drop(zoho_df.loc[(zoho_df['Email'] =='empty') & (zoho_df['Phone']=='empty') & (zoho_df['Mobile']=='empty')].index, inplace=True)
zoho_df.reset_index(drop=True, inplace=True)

count_after_wash_blank = zoho_df.shape[0]

# %%
print("==========================================================")
print("Summary")
print("==========================================================")
print("Jumlah Keseluruhan Master Zoho : "+str(count_data_awal))
print("Jumlah Format Email Salah : "+str(count_deleted_wrong_format))
print("Jumlah Setelah Clean Format Email Salah : "+str(count_after_deleted_wrong_format))
print("Jumlah Lead Test : "+str(count_leads_test))
print("Jumlah Setelah Clean Lead Test : "+str(count_after_dedup_test))
print("Jumlah Email Karma : "+str(count_email_karma))
print("Jumlah Setelah Clean Email Karma : "+str(count_after_clean_karma))
print("Jumlah Duplicate (Phone, Mobile dan Email) : "+str(count_duplicate_general))
print("Jumlah Setelah Clean Duplicate : "+str(count_after_dedup_duplicate))
print("Jumlah Wash Member : "+str(count_member_dedup))
print("Jumlah Wash Booking : "+str(count_booking_dedup))
print("Jumlah Setelah Wash Member : "+str(count_after_wash_member))
print("Jumlah Phone Email Blank (Setelah phone yang tidak valid dihapus) : "+str(count_blank))
print("Jumlah Setelah Wash Phone Email Blank : "+str(count_after_wash_blank))
print("==========================================================")
print("Contact Type")
print("==========================================================")
print("Jumlah Email Only : "+str(count_email_only))
print("Jumlah Phone Only : "+str(count_phone_only))
print("Jumlah Email dan Phone : "+str(count_email_and_phone))
# Out:
# ==========================================================
# Summary
# ==========================================================
# Jumlah Keseluruhan Master Zoho : 681
# Jumlah Format Email Salah : 0
# Jumlah Setelah Clean Format Email Salah : 681
# Jumlah Lead Test : 0
# Jumlah Setelah Clean Lead Test : 681
# Jumlah Email Karma : 1
# Jumlah Setelah Clean Email Karma : 680
# Jumlah Duplicate (Phone, Mobile dan Email) : 3
# Jumlah Setelah Clean Duplicate : 677
# Jumlah Wash Member : 13
# Jumlah Wash Booking : 78
# Jumlah Setelah Wash Member : 586
# Jumlah Phone Email Blank (Setelah phone yang tidak valid dihapus) : 0
# Jumlah Setelah Wash Phone Email Blank : 586
# ==========================================================
# Contact Type
# ==========================================================
# Jumlah Email Only : 44
# Jumlah Phone Only : 0
# Jumlah Email dan Phone : 542

# %% [markdown]
# # ====================== Akhir Filter Umum ======================

# %%
# zoho_df.replace('empty', '', inplace=True)
# zoho_df.to_excel(r'C:\Users\fajar\Documents\Python\Data\KCE-FEB.xlsx', index=False)

# %%
path = r'C:\Users\fajar\Documents\Python\Data\dedup-KCE.xlsx'
df_kce_before = pd.read_excel(path, dtype='string', sheet_name='Email')

df_kce_before['Email'] = m.lowercase(df_kce_before, 'Email')
m.clean_space(df_kce_before, 'Email')

df_kce_before
# Out:
#                               Email
# 0         larbibenhorabir@gmail.com
# 1             josh.sydney@gmail.com
# 2             write2chets@gmail.com
# 3        taylor.e.bennett@gmail.com
# 4    brendan_wdight1994@hotmail.com
# ..                              ...
# 337            skhosana01@gmail.com
# 338       racheal.james01@gmail.com
# 339       vernon_govender@yahoo.com
# 340        omarrkhaled.93@gmail.com
# 341              bencrory@gmail.com
#
# [342 rows x 1 columns]

# %%
count_kce_exist = zoho_df.loc[zoho_df['Email'].isin(df_kce_before['Email'])].shape[0]
final_df = zoho_df.loc[~zoho_df['Email'].isin(df_kce_before['Email'])].copy()
final_df.replace('empty', '', inplace=True)

final_df.loc[final_df['Country'].str.contains('indonesia', flags=re.I)].to_excel(r'C:\Users\fajar\Documents\Python\Data\kce-new-indo.xlsx', index=False)
final_df.loc[~final_df['Country'].str.contains('indonesia', flags=re.I)].to_excel(r'C:\Users\fajar\Documents\Python\Data\kce-new-western.xlsx', index=False)
