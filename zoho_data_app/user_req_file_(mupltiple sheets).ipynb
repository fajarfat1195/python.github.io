# %%
import main_module as m
import zoho_filter_module as fil
import pandas as pd
import re
import numpy as np

# %load_ext autoreload
# %autoreload 2

cols = ['Record Id',	
'Created Time',
'Created Date',	
'First Name',	
'Last Name',	
'Email',	
'PHONE',	
'Mobile',	
'Birthdate',	
'Year of Birth',
'Street',	
'Street2',	
'City',	
'State',	
'Country',	
'Nationality',
'Booking Status', 
'BookRef',
'Departure Date',	
'Arrival Date',	
'Card Type',	
'Marital Status',	
'Lead Brand',	
'Lead Sub-Brand',	
'Lead Source',	
'Lead Locations',	
'Lead Source Description',	
'Lead Regions',
'Lead Status',
'Email Opt Out',	
'Opt In']
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
path = r'C:\Users\fajar\Documents\Python\Data\new-wifi.xlsx'
zoho_df = pd.read_excel(path, dtype='string', sheet_name="Sheet0")

zoho_df.reset_index(drop=True, inplace=True)
count_filter_awal = zoho_df.shape[0]

# mengisi kolom <NA> dengan value string 'empty' supaya mudah mengecek data member dan booking dengan isin
zoho_df.fillna('empty', inplace=True)
zoho_df
# Out:
# C:\Users\fajar\AppData\Roaming\Python\Python310\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
#                      Record Id         Created Time Created Date  \
# 0     zcrm_3584690000495006174  2024-05-09 16:00:00        empty
# 1     zcrm_3584690000494998179  2024-05-09 16:00:00        empty
# 2     zcrm_3584690000494987148  2024-05-09 16:00:00        empty
# 3     zcrm_3584690000494966425  2024-05-09 16:00:00        empty
# 4     zcrm_3584690000494904356  2024-05-08 12:25:00        empty
# ...                        ...                  ...          ...
# 4210  zcrm_3584690000494083330  2024-05-02 16:00:00        empty
# 4211  zcrm_3584690000494074551  2024-05-02 16:02:00        empty
# 4212  zcrm_3584690000494074508  2024-05-02 16:01:00        empty
# 4213  zcrm_3584690000494074465  2024-05-02 16:01:00        empty
# 4214  zcrm_3584690000494074422  2024-05-02 16:00:00        empty
#
#      Lead Source Description First Name   Last Name  \
# 0                    Beambox        Jim      Aitken
# 1                    Beambox     JOSEPH  Antonishek
# 2                    Beambox     Eamonn      MURPHY
# 3                    Beambox      KEITH      Knight
# 4                    Beambox        Ian      Harley
# ...                      ...        ...         ...
# 4210                 Beambox    Michael      Weller
# 4211                 Beambox        JAN   Etheridge
# 4212                 Beambox    Georgia   Pritchard
# 4213                 Beambox      Nabha   Rankhambe
# 4214                 Beambox   Felicity        Inns
#
#                                  Email           Phone Occupation  \
# 0                   a1tkendrum@aol.com   +447798725281      empty
# 1     joseph.antonishek@karmagroup.com  +6282235541045      empty
# 2                eamonn365@hotmail.com  +4407707733547      empty
# 3                   kgk22547@gmail.com   +447392456672      empty
# 4                   ianh1703@gmail.com           empty      empty
# ...                                ...             ...        ...
# 4210              mickweller@gmail.com  +4407419997730      empty
# 4211         trevorwinalot94@gmail.com   +441908568988      empty
# 4212            geepritchard@gmail.com   +447447811304      empty
# 4213        nabharankhambe01@gmail.com   +918828391429      empty
# 4214            felicityinns@gmail.com   +447535787631      empty
#
#               Mobile  ... Messages Do Not Mail Do Not Contact Lead Location  \
# 0      +447798725281  ...    empty       false          false         empty
# 1     +6282235541045  ...    empty       false          false         empty
# 2     +4407707733547  ...    empty       false          false         empty
# 3      +447392456672  ...    empty       false          false         empty
# 4              empty  ...    empty       false          false         empty
# ...              ...  ...      ...         ...            ...           ...
# 4210  +4407419997730  ...    empty       false          false         empty
# 4211   +441908568988  ...    empty       false          false         empty
# 4212   +447447811304  ...    empty       false          false         empty
# 4213   +918828391429  ...    empty       false          false         empty
# 4214   +447535787631  ...    empty       false          false         empty
#
#      Lead Location Description Agency Name Agent Name Campaign Name  \
# 0                        empty       empty      empty         empty
# 1                        empty       empty      empty         empty
# 2                        empty       empty      empty         empty
# 3                        empty       empty      empty         empty
# 4                        empty       empty      empty         empty
# ...                        ...         ...        ...           ...
# 4210                     empty       empty      empty         empty
# 4211                     empty       empty      empty         empty
# 4212                     empty       empty      empty         empty
# 4213                     empty       empty      empty         empty
# 4214                     empty       empty      empty         empty
#
#      Card Number Website
# 0          empty   empty
# 1          empty   empty
# 2          empty   empty
# 3          empty   empty
# 4          empty   empty
# ...          ...     ...
# 4210       empty   empty
# 4211       empty   empty
# 4212       empty   empty
# 4213       empty   empty
# 4214       empty   empty
#
# [4215 rows x 50 columns]

# %%
path = r'G:\.shortcut-targets-by-id\0B_d3smBjzo04eXpvS1NXTWF2RVE\_BOOKING\Booking By Year\FlyBuy Booking Data (BGAU & BGID & KE).xlsx'
df_booking = pd.read_excel(path, dtype='string', sheet_name='BOOKING_BGAU_BGID_KE')

path = r'G:\.shortcut-targets-by-id\0B_d3smBjzo04UUNBME5GOVhoMjA\_ODYSSEY\Phone Members.xlsx'
df_phone = pd.read_excel(path, dtype='string', sheet_name='Sheet1')

path = r'G:\.shortcut-targets-by-id\0B_d3smBjzo04UUNBME5GOVhoMjA\_ODYSSEY\Email Members.xlsx'
df_email = pd.read_excel(path, dtype='string', sheet_name='Sheet1')

path = r'C:\Users\fajar\Documents\Python\Data\Wifi All.xlsx'
df_wifi = pd.read_excel(path, dtype='string', sheet_name='Data')

# %% [markdown]
# # ====================== Awal Filter Umum ======================

# %%
# data phone, mobile dam email member yang ada di master data (wash member)

m.clean_number(zoho_df, 'Phone')
m.clean_number(zoho_df, 'Mobile')
m.replace_not_valid_to_empty(zoho_df, 'Phone')
m.replace_not_valid_to_empty(zoho_df, 'Mobile')
zoho_df['Email'] = m.lowercase(zoho_df, 'Email')
m.clean_space(zoho_df, 'Email')
m.clean_not_valid_email_format(zoho_df, 'Email')

m.clean_number(df_wifi, 'Phone')
m.clean_number(df_wifi, 'Mobile')
df_wifi['Email'] = m.lowercase(df_wifi, 'Email')
m.clean_space(df_wifi, 'Email')
m.clean_not_valid_email_format(df_wifi, 'Email')

m.clean_number(df_booking, 'Phone1')
m.clean_number(df_booking, 'Mobile')
df_booking['Email'] = m.lowercase(df_booking, 'Email')
m.clean_space(df_booking, 'Email')
m.clean_not_valid_email_format(df_booking, 'Email')

m.clean_number(df_phone, 'Mobile')

df_email['Email'] = m.lowercase(df_email, 'Email')
m.clean_space(df_email, 'Email')
m.clean_not_valid_email_format(df_email, 'Email')
# Out:
# 'Email'

# %%
zoho_df.loc[
    (zoho_df['Phone'] == 'empty') & (zoho_df['Mobile'] != 'empty'), 
    'Phone'] = zoho_df['Mobile']
zoho_df.loc[zoho_df['Phone'] == zoho_df['Mobile'],'Mobile'] = 'empty'

# %%
count_deleted_wrong_format = m.delete_email_wrong_format(zoho_df, 'Email')
count_after_deleted_wrong_format = zoho_df.shape[0]

# %% [markdown]
# # ====================== Akhir Filter Umum ======================

# %%
# hitung jumlah duplicate
count_duplicate_general = zoho_df.loc[zoho_df.duplicated(subset=['Phone','Mobile','Email'])].shape[0]

zoho_df.loc[zoho_df.duplicated(subset=['Phone','Mobile','Email'])]
# Out:
# Empty DataFrame
# Columns: [Record Id, Created Time, Created Date, Lead Source Description, First Name, Last Name, Email, Phone, Occupation, Mobile, Birthdate, Year of Birth, Street, Street2, City, State, Country, Nationality, Departure Date, Arrival Date, Card Type, Marital Status, Lead Brand, Lead Sub-Brand, Lead Source, Lead Locations, Lead Regions, Lead Status, Email Opt Out, Opt In, Booking Status, BookRef, Guest Type, External ID, GDPR Compliant, Description, Media Source Code, First Page Visited, Do you have passport?, Agree with Terms and Condition, Messages, Do Not Mail, Do Not Contact, Lead Location, Lead Location Description, Agency Name, Agent Name, Campaign Name, Card Number, Website]
# Index: []
#
# [0 rows x 50 columns]

# %%
zoho_df.drop_duplicates(subset=['Phone','Mobile','Email'], inplace=True)
zoho_df.reset_index(drop=True, inplace=True)

# hitung jumlah setelah value duplicate dihapus
count_after_dedup_duplicate = zoho_df.shape[0]

zoho_df
# Out:
#                      Record Id         Created Time Created Date  \
# 0     zcrm_3584690000495006174  2024-05-09 16:00:00        empty
# 1     zcrm_3584690000494998179  2024-05-09 16:00:00        empty
# 2     zcrm_3584690000494987148  2024-05-09 16:00:00        empty
# 3     zcrm_3584690000494966425  2024-05-09 16:00:00        empty
# 4     zcrm_3584690000494904356  2024-05-08 12:25:00        empty
# ...                        ...                  ...          ...
# 4210  zcrm_3584690000494083330  2024-05-02 16:00:00        empty
# 4211  zcrm_3584690000494074551  2024-05-02 16:02:00        empty
# 4212  zcrm_3584690000494074508  2024-05-02 16:01:00        empty
# 4213  zcrm_3584690000494074465  2024-05-02 16:01:00        empty
# 4214  zcrm_3584690000494074422  2024-05-02 16:00:00        empty
#
#      Lead Source Description First Name   Last Name  \
# 0                    Beambox        Jim      Aitken
# 1                    Beambox     JOSEPH  Antonishek
# 2                    Beambox     Eamonn      MURPHY
# 3                    Beambox      KEITH      Knight
# 4                    Beambox        Ian      Harley
# ...                      ...        ...         ...
# 4210                 Beambox    Michael      Weller
# 4211                 Beambox        JAN   Etheridge
# 4212                 Beambox    Georgia   Pritchard
# 4213                 Beambox      Nabha   Rankhambe
# 4214                 Beambox   Felicity        Inns
#
#                                  Email          Phone Occupation  \
# 0                   a1tkendrum@aol.com   447798725281      empty
# 1     joseph.antonishek@karmagroup.com  6282235541045      empty
# 2                eamonn365@hotmail.com  4407707733547      empty
# 3                   kgk22547@gmail.com   447392456672      empty
# 4                   ianh1703@gmail.com          empty      empty
# ...                                ...            ...        ...
# 4210              mickweller@gmail.com  4407419997730      empty
# 4211         trevorwinalot94@gmail.com   441908568988      empty
# 4212            geepritchard@gmail.com   447447811304      empty
# 4213        nabharankhambe01@gmail.com   918828391429      empty
# 4214            felicityinns@gmail.com   447535787631      empty
#
#              Mobile  ... Messages Do Not Mail Do Not Contact Lead Location  \
# 0      447798725281  ...    empty       false          false         empty
# 1     6282235541045  ...    empty       false          false         empty
# 2     4407707733547  ...    empty       false          false         empty
# 3      447392456672  ...    empty       false          false         empty
# 4             empty  ...    empty       false          false         empty
# ...             ...  ...      ...         ...            ...           ...
# 4210  4407419997730  ...    empty       false          false         empty
# 4211   441908568988  ...    empty       false          false         empty
# 4212   447447811304  ...    empty       false          false         empty
# 4213   918828391429  ...    empty       false          false         empty
# 4214   447535787631  ...    empty       false          false         empty
#
#      Lead Location Description Agency Name Agent Name Campaign Name  \
# 0                        empty       empty      empty         empty
# 1                        empty       empty      empty         empty
# 2                        empty       empty      empty         empty
# 3                        empty       empty      empty         empty
# 4                        empty       empty      empty         empty
# ...                        ...         ...        ...           ...
# 4210                     empty       empty      empty         empty
# 4211                     empty       empty      empty         empty
# 4212                     empty       empty      empty         empty
# 4213                     empty       empty      empty         empty
# 4214                     empty       empty      empty         empty
#
#      Card Number Website
# 0          empty   empty
# 1          empty   empty
# 2          empty   empty
# 3          empty   empty
# 4          empty   empty
# ...          ...     ...
# 4210       empty   empty
# 4211       empty   empty
# 4212       empty   empty
# 4213       empty   empty
# 4214       empty   empty
#
# [4215 rows x 50 columns]

# %%
# Cek leads test
test_leads = zoho_df.loc[
    
        zoho_df['Email'].str.contains('^test@', flags=re.I, regex=True) |
        zoho_df['Email'].str.contains('\+test', flags=re.I, regex=True) |
    
        zoho_df['First Name'].str.contains('^test$', flags=re.I, regex=True) |
        zoho_df['Last Name'].str.contains('^test$', flags=re.I, regex=True) |

        zoho_df['First Name'].str.contains('test 1', flags=re.I, regex=True) |
        zoho_df['Last Name'].str.contains('test 2', flags=re.I, regex=True)|
        zoho_df['First Name'].str.contains('test1', flags=re.I, regex=True) |
        zoho_df['Last Name'].str.contains('test2', flags=re.I, regex=True)|

        zoho_df['First Name'].str.contains(' test ', flags=re.I, regex=True) | 
        zoho_df['Last Name'].str.contains(' test ', flags=re.I, regex=True) | 
        zoho_df['Last Name'].str.contains(' test$', flags=re.I, regex=True)
    ]

count_leads_test = test_leads.shape[0]

# test_leads.to_excel(r'C:\Users\fajar\Documents\Python\Data\test_leads_2.xlsx', index=False)
test_leads
# Out:
# Empty DataFrame
# Columns: [Record Id, Created Time, Created Date, Lead Source Description, First Name, Last Name, Email, Phone, Occupation, Mobile, Birthdate, Year of Birth, Street, Street2, City, State, Country, Nationality, Departure Date, Arrival Date, Card Type, Marital Status, Lead Brand, Lead Sub-Brand, Lead Source, Lead Locations, Lead Regions, Lead Status, Email Opt Out, Opt In, Booking Status, BookRef, Guest Type, External ID, GDPR Compliant, Description, Media Source Code, First Page Visited, Do you have passport?, Agree with Terms and Condition, Messages, Do Not Mail, Do Not Contact, Lead Location, Lead Location Description, Agency Name, Agent Name, Campaign Name, Card Number, Website]
# Index: []
#
# [0 rows x 50 columns]

# %%
zoho_df.drop(test_leads.index, inplace=True)
zoho_df.reset_index(drop=True, inplace=True)

count_after_dedup_test = zoho_df.shape[0]

# %%
# dnm_leads = zoho_df.loc[(zoho_df['Do Not Mail'] == 'true') | (zoho_df['Do Not Contact'] == 'true')]
# count_dnm = dnm_leads.shape[0]

# %%
# zoho_df.drop(dnm_leads.index, inplace=True)
# zoho_df.reset_index(drop=True, inplace=True)

# count_after_dedup_dnm = zoho_df.shape[0]

# %%
# Cek Email OTA
email_OTA = m.find_OTA(zoho_df, 'Email')
count_email_OTA = email_OTA.shape[0]
# email_OTA.to_excel(r'C:\Users\fajar\Documents\Python\Data\email_OTA.xlsx', index=False)

email_OTA
# Out:
#                      Record Id         Created Time Created Date  \
# 831   zcrm_3584690000494902756  2024-05-08 12:25:00        empty
# 871   zcrm_3584690000494902716  2024-05-08 12:25:00        empty
# 3679  zcrm_3584690000494819821  2024-05-08 12:24:00        empty
# 3948  zcrm_3584690000494819295  2024-05-08 12:24:00        empty
#
#      Lead Source Description First Name      Last Name  \
# 831                  Beambox     Duncan  Stuart Barker
# 871                  Beambox      James        Wallace
# 3679                 Beambox       Toni        Coleman
# 3948                 Beambox       Beth       Clelland
#
#                            Email          Phone Occupation Mobile  ...  \
# 831      enquiry@duntourscot.com  4407972818072      empty  empty  ...
# 871       office@scotustours.com   447576071743      empty  empty  ...
# 3679  toni_coleman24@booking.com   447776350018      empty  empty  ...
# 3948   beth.clelland@booking.com   447801398083      empty  empty  ...
#
#      Messages Do Not Mail Do Not Contact Lead Location  \
# 831     empty       false          false         empty
# 871     empty       false          false         empty
# 3679    empty       false          false         empty
# 3948    empty       false          false         empty
#
#      Lead Location Description Agency Name Agent Name Campaign Name  \
# 831                      empty       empty      empty         empty
# 871                      empty       empty      empty         empty
# 3679                     empty       empty      empty         empty
# 3948                     empty       empty      empty         empty
#
#      Card Number Website
# 831        empty   empty
# 871        empty   empty
# 3679       empty   empty
# 3948       empty   empty
#
# [4 rows x 50 columns]

# %%
# delete email OTA
count_after_clean_OTA = m.delete_OTA(zoho_df, 'Email')
# zoho_df.to_excel(r'C:\Users\fajar\Documents\Python\Data\after_clean_OTA.xlsx', index=False)

zoho_df
# Out:
#                      Record Id         Created Time Created Date  \
# 0     zcrm_3584690000495006174  2024-05-09 16:00:00        empty
# 1     zcrm_3584690000494998179  2024-05-09 16:00:00        empty
# 2     zcrm_3584690000494987148  2024-05-09 16:00:00        empty
# 3     zcrm_3584690000494966425  2024-05-09 16:00:00        empty
# 4     zcrm_3584690000494904356  2024-05-08 12:25:00        empty
# ...                        ...                  ...          ...
# 4206  zcrm_3584690000494083330  2024-05-02 16:00:00        empty
# 4207  zcrm_3584690000494074551  2024-05-02 16:02:00        empty
# 4208  zcrm_3584690000494074508  2024-05-02 16:01:00        empty
# 4209  zcrm_3584690000494074465  2024-05-02 16:01:00        empty
# 4210  zcrm_3584690000494074422  2024-05-02 16:00:00        empty
#
#      Lead Source Description First Name   Last Name  \
# 0                    Beambox        Jim      Aitken
# 1                    Beambox     JOSEPH  Antonishek
# 2                    Beambox     Eamonn      MURPHY
# 3                    Beambox      KEITH      Knight
# 4                    Beambox        Ian      Harley
# ...                      ...        ...         ...
# 4206                 Beambox    Michael      Weller
# 4207                 Beambox        JAN   Etheridge
# 4208                 Beambox    Georgia   Pritchard
# 4209                 Beambox      Nabha   Rankhambe
# 4210                 Beambox   Felicity        Inns
#
#                                  Email          Phone Occupation  \
# 0                   a1tkendrum@aol.com   447798725281      empty
# 1     joseph.antonishek@karmagroup.com  6282235541045      empty
# 2                eamonn365@hotmail.com  4407707733547      empty
# 3                   kgk22547@gmail.com   447392456672      empty
# 4                   ianh1703@gmail.com          empty      empty
# ...                                ...            ...        ...
# 4206              mickweller@gmail.com  4407419997730      empty
# 4207         trevorwinalot94@gmail.com   441908568988      empty
# 4208            geepritchard@gmail.com   447447811304      empty
# 4209        nabharankhambe01@gmail.com   918828391429      empty
# 4210            felicityinns@gmail.com   447535787631      empty
#
#              Mobile  ... Messages Do Not Mail Do Not Contact Lead Location  \
# 0      447798725281  ...    empty       false          false         empty
# 1     6282235541045  ...    empty       false          false         empty
# 2     4407707733547  ...    empty       false          false         empty
# 3      447392456672  ...    empty       false          false         empty
# 4             empty  ...    empty       false          false         empty
# ...             ...  ...      ...         ...            ...           ...
# 4206  4407419997730  ...    empty       false          false         empty
# 4207   441908568988  ...    empty       false          false         empty
# 4208   447447811304  ...    empty       false          false         empty
# 4209   918828391429  ...    empty       false          false         empty
# 4210   447535787631  ...    empty       false          false         empty
#
#      Lead Location Description Agency Name Agent Name Campaign Name  \
# 0                        empty       empty      empty         empty
# 1                        empty       empty      empty         empty
# 2                        empty       empty      empty         empty
# 3                        empty       empty      empty         empty
# 4                        empty       empty      empty         empty
# ...                        ...         ...        ...           ...
# 4206                     empty       empty      empty         empty
# 4207                     empty       empty      empty         empty
# 4208                     empty       empty      empty         empty
# 4209                     empty       empty      empty         empty
# 4210                     empty       empty      empty         empty
#
#      Card Number Website
# 0          empty   empty
# 1          empty   empty
# 2          empty   empty
# 3          empty   empty
# 4          empty   empty
# ...          ...     ...
# 4206       empty   empty
# 4207       empty   empty
# 4208       empty   empty
# 4209       empty   empty
# 4210       empty   empty
#
# [4211 rows x 50 columns]

# %%
# Cek Email Karma
email_karma = m.find_karma(zoho_df, 'Email')
count_email_karma = email_karma.shape[0]
# email_OTA.to_excel(r'C:\Users\fajar\Documents\Python\Data\email_OTA.xlsx', index=False)

email_karma
# Out:
#                      Record Id         Created Time Created Date  \
# 1     zcrm_3584690000494998179  2024-05-09 16:00:00        empty
# 385   zcrm_3584690000494903716  2024-05-08 12:25:00        empty
# 713   zcrm_3584690000494902874  2024-05-08 12:25:00        empty
# 860   zcrm_3584690000494902726  2024-05-08 12:25:00        empty
# 895   zcrm_3584690000494902433  2024-05-08 12:25:00        empty
# 910   zcrm_3584690000494902418  2024-05-08 12:25:00        empty
# 1038  zcrm_3584690000494902290  2024-05-08 12:25:00        empty
# 1507  zcrm_3584690000494901305  2024-05-08 12:25:00        empty
# 1858  zcrm_3584690000494900697  2024-05-08 12:25:00        empty
# 2052  zcrm_3584690000494900246  2024-05-08 12:25:00        empty
# 2739  zcrm_3584690000494898787  2024-05-08 12:24:00        empty
# 2845  zcrm_3584690000494898681  2024-05-08 12:24:00        empty
# 2953  zcrm_3584690000494898316  2024-05-08 12:24:00        empty
# 3047  zcrm_3584690000494898222  2024-05-08 12:24:00        empty
# 3420  zcrm_3584690000494897335  2024-05-08 12:24:00        empty
# 3826  zcrm_3584690000494819671  2024-05-08 12:24:00        empty
# 3834  zcrm_3584690000494819663  2024-05-08 12:24:00        empty
# 3836  zcrm_3584690000494819661  2024-05-08 12:24:00        empty
# 3862  zcrm_3584690000494819635  2024-05-08 12:24:00        empty
# 3887  zcrm_3584690000494819610  2024-05-08 12:24:00        empty
# 3976  zcrm_3584690000494819263  2024-05-08 12:24:00        empty
#
#      Lead Source Description First Name    Last Name  \
# 1                    Beambox     JOSEPH   Antonishek
# 385                  Beambox       Neil    Aitchison
# 713                  Beambox     Andrea     Pavlidis
# 860                  Beambox    Anthony        Hinds
# 895                  Beambox    Ricardo       Coppen
# 910                  Beambox        Vic     Faulkner
# 1038                 Beambox       Paul     FERGUSON
# 1507                 Beambox   Valerios    Koutsonis
# 1858                 Beambox       JOHN       Spence
# 2052                 Beambox    Melanie       Hyslop
# 2739                 Beambox     Mihaly      Horvath
# 2845                 Beambox       Ruth         Liew
# 2953                 Beambox       Paul        Moran
# 3047                 Beambox     MARTIN     Hathaway
# 3420                 Beambox       Maik      Schramm
# 3826                 Beambox      Hanna       Thomas
# 3834                 Beambox    Clinton  Albuquerque
# 3836                 Beambox      Chris      Diplock
# 3862                 Beambox      Maria    Wedemeier
# 3887                 Beambox      PETER      Knights
# 3976                 Beambox      Luisa        Nunes
#
#                                    Email          Phone Occupation  \
# 1       joseph.antonishek@karmagroup.com  6282235541045      empty
# 385        neil.aitchison@karmagroup.com    34628735220      empty
# 713       andrea.pavlidis@karmagroup.com   306979898735      empty
# 860          headchef@karmastmartins.com   447575775972      empty
# 895        ricardo.coppen@karmagroup.com  6181213501888      empty
# 910          vic.faulkner@karmagroup.com  6208113974868      empty
# 1038        paul.ferguson@karmagroup.com  4407523601591      empty
# 1507   valerios.koutsonis@karmagroup.com          empty      empty
# 1858            johnspence88@hotmail.com   447808661562      empty
# 2052       melanie.hyslop@karmagroup.com   447972109731      empty
# 2739       mihaly.horvath@karmagroup.com  6281916475046      empty
# 2845            ruth.liew@karmagroup.com    97150826588      empty
# 2953           paul.moran@karmagroup.com  4407436361231      empty
# 3047               gm@karmastmartins.com   447756613312      empty
# 3420         maik.schramm@karmagroup.com  4915206817600      empty
# 3826         hanna.thomas@karmagroup.com   447542941142      empty
# 3834  clinton.albuquerque@karmagroup.com  4917624819410      empty
# 3836        chris.diplock@karmagroup.com   447508180124      empty
# 3862      maria.wedemeier@karmagroup.com   491718159690      empty
# 3887        peter.knights@karmagroup.com  4407522774337      empty
# 3976          luisa.nunes@karmagroup.com   447704365708      empty
#
#              Mobile  ... Messages Do Not Mail Do Not Contact Lead Location  \
# 1     6282235541045  ...    empty       false          false         empty
# 385           empty  ...    empty       false          false         empty
# 713           empty  ...    empty       false          false         empty
# 860           empty  ...    empty       false          false         empty
# 895           empty  ...    empty       false          false         empty
# 910           empty  ...    empty       false          false         empty
# 1038          empty  ...    empty       false          false         empty
# 1507          empty  ...    empty       false          false         empty
# 1858          empty  ...    empty       false          false         empty
# 2052          empty  ...    empty       false          false         empty
# 2739          empty  ...    empty       false          false         empty
# 2845          empty  ...    empty       false          false         empty
# 2953          empty  ...    empty       false          false         empty
# 3047          empty  ...    empty       false          false         empty
# 3420          empty  ...    empty       false          false         empty
# 3826          empty  ...    empty       false          false         empty
# 3834          empty  ...    empty       false          false         empty
# 3836          empty  ...    empty       false          false         empty
# 3862          empty  ...    empty       false          false         empty
# 3887          empty  ...    empty       false          false         empty
# 3976          empty  ...    empty       false          false         empty
#
#      Lead Location Description Agency Name Agent Name Campaign Name  \
# 1                        empty       empty      empty         empty
# 385                      empty       empty      empty         empty
# 713                      empty       empty      empty         empty
# 860                      empty       empty      empty         empty
# 895                      empty       empty      empty         empty
# 910                      empty       empty      empty         empty
# 1038                     empty       empty      empty         empty
# 1507                     empty       empty      empty         empty
# 1858                     empty       empty      empty         empty
# 2052                     empty       empty      empty         empty
# 2739                     empty       empty      empty         empty
# 2845                     empty       empty      empty         empty
# 2953                     empty       empty      empty         empty
# 3047                     empty       empty      empty         empty
# 3420                     empty       empty      empty         empty
# 3826                     empty       empty      empty         empty
# 3834                     empty       empty      empty         empty
# 3836                     empty       empty      empty         empty
# 3862                     empty       empty      empty         empty
# 3887                     empty       empty      empty         empty
# 3976                     empty       empty      empty         empty
#
#      Card Number Website
# 1          empty   empty
# 385        empty   empty
# 713        empty   empty
# 860        empty   empty
# 895        empty   empty
# 910        empty   empty
# 1038       empty   empty
# 1507       empty   empty
# 1858       empty   empty
# 2052       empty   empty
# 2739       empty   empty
# 2845       empty   empty
# 2953       empty   empty
# 3047       empty   empty
# 3420       empty   empty
# 3826       empty   empty
# 3834       empty   empty
# 3836       empty   empty
# 3862       empty   empty
# 3887       empty   empty
# 3976       empty   empty
#
# [21 rows x 50 columns]

# %%
# delete email Karma
count_after_clean_karma = m.delete_karma(zoho_df, 'Email')
# zoho_df.to_excel(r'C:\Users\fajar\Documents\Python\Data\after_clean_OTA.xlsx', index=False)

zoho_df
# Out:
#                      Record Id         Created Time Created Date  \
# 0     zcrm_3584690000495006174  2024-05-09 16:00:00        empty
# 1     zcrm_3584690000494987148  2024-05-09 16:00:00        empty
# 2     zcrm_3584690000494966425  2024-05-09 16:00:00        empty
# 3     zcrm_3584690000494904356  2024-05-08 12:25:00        empty
# 4     zcrm_3584690000494904355  2024-05-08 12:25:00        empty
# ...                        ...                  ...          ...
# 4185  zcrm_3584690000494083330  2024-05-02 16:00:00        empty
# 4186  zcrm_3584690000494074551  2024-05-02 16:02:00        empty
# 4187  zcrm_3584690000494074508  2024-05-02 16:01:00        empty
# 4188  zcrm_3584690000494074465  2024-05-02 16:01:00        empty
# 4189  zcrm_3584690000494074422  2024-05-02 16:00:00        empty
#
#      Lead Source Description First Name  Last Name  \
# 0                    Beambox        Jim     Aitken
# 1                    Beambox     Eamonn     MURPHY
# 2                    Beambox      KEITH     Knight
# 3                    Beambox        Ian     Harley
# 4                    Beambox     Flavia     Michel
# ...                      ...        ...        ...
# 4185                 Beambox    Michael     Weller
# 4186                 Beambox        JAN  Etheridge
# 4187                 Beambox    Georgia  Pritchard
# 4188                 Beambox      Nabha  Rankhambe
# 4189                 Beambox   Felicity       Inns
#
#                            Email          Phone Occupation         Mobile  \
# 0             a1tkendrum@aol.com   447798725281      empty   447798725281
# 1          eamonn365@hotmail.com  4407707733547      empty  4407707733547
# 2             kgk22547@gmail.com   447392456672      empty   447392456672
# 3             ianh1703@gmail.com          empty      empty          empty
# 4      flaviamichel.fm@gmail.com          empty      empty          empty
# ...                          ...            ...        ...            ...
# 4185        mickweller@gmail.com  4407419997730      empty  4407419997730
# 4186   trevorwinalot94@gmail.com   441908568988      empty   441908568988
# 4187      geepritchard@gmail.com   447447811304      empty   447447811304
# 4188  nabharankhambe01@gmail.com   918828391429      empty   918828391429
# 4189      felicityinns@gmail.com   447535787631      empty   447535787631
#
#       ... Messages Do Not Mail Do Not Contact Lead Location  \
# 0     ...    empty       false          false         empty
# 1     ...    empty       false          false         empty
# 2     ...    empty       false          false         empty
# 3     ...    empty       false          false         empty
# 4     ...    empty       false          false         empty
# ...   ...      ...         ...            ...           ...
# 4185  ...    empty       false          false         empty
# 4186  ...    empty       false          false         empty
# 4187  ...    empty       false          false         empty
# 4188  ...    empty       false          false         empty
# 4189  ...    empty       false          false         empty
#
#      Lead Location Description Agency Name Agent Name Campaign Name  \
# 0                        empty       empty      empty         empty
# 1                        empty       empty      empty         empty
# 2                        empty       empty      empty         empty
# 3                        empty       empty      empty         empty
# 4                        empty       empty      empty         empty
# ...                        ...         ...        ...           ...
# 4185                     empty       empty      empty         empty
# 4186                     empty       empty      empty         empty
# 4187                     empty       empty      empty         empty
# 4188                     empty       empty      empty         empty
# 4189                     empty       empty      empty         empty
#
#      Card Number Website
# 0          empty   empty
# 1          empty   empty
# 2          empty   empty
# 3          empty   empty
# 4          empty   empty
# ...          ...     ...
# 4185       empty   empty
# 4186       empty   empty
# 4187       empty   empty
# 4188       empty   empty
# 4189       empty   empty
#
# [4190 rows x 50 columns]

# %%
find_member_booking = zoho_df.copy()

find_member_booking.loc[find_member_booking['Phone'].isin(df_booking['Phone1']), 'Same Value Find'] = 'Booking-Phone1'
find_member_booking.loc[find_member_booking['Phone'].isin(df_booking['Mobile']), 'Same Value Find'] = 'Booking-Mobile'
find_member_booking.loc[find_member_booking['Mobile'].isin(df_booking['Phone1']), 'Same Value Find'] = 'Booking-Phone1' 
find_member_booking.loc[find_member_booking['Mobile'].isin(df_booking['Mobile']), 'Same Value Find'] = 'Booking-Mobile'
find_member_booking.loc[find_member_booking['Email'].isin(df_booking['Email']), 'Same Value Find'] = 'Booking-Email'

find_member_booking.loc[find_member_booking['Phone'].isin(df_phone['Mobile']), 'Same Value Find'] = 'Member-Mobile' 
find_member_booking.loc[find_member_booking['Mobile'].isin(df_phone['Mobile']), 'Same Value Find'] = 'Member-Mobile'

find_member_booking.loc[find_member_booking['Email'].isin(df_email['Email']), 'Same Value Find'] = 'Member-Email'

find_member_booking.drop(find_member_booking.loc[find_member_booking['Same Value Find'].isna()].index, inplace=True)

count_booking_dedup = find_member_booking.loc[find_member_booking['Same Value Find'].str.contains('Booking', flags=re.I, regex=True)].shape[0]
count_member_dedup = find_member_booking.loc[find_member_booking['Same Value Find'].str.contains('Member', flags=re.I, regex=True)].shape[0]

find_member_booking.replace('empty', '', inplace=True)
# find_member_booking.to_csv(r'C:\Users\fajar\Documents\Python\Data\booking-member-dedup.csv', index=False)
# find_member_booking.to_excel(r'C:\Users\fajar\Documents\Python\Data\booking-member-dedup.xlsx', index=False)

#find_member_booking.loc[find_member_booking['Same Value Find'] == 'Booking-Phone1']

# %%
# data phone, mobile dam email member yang ada di master data 
count_wash_member = zoho_df.loc[
    zoho_df['Phone'].isin(df_booking['Phone1']) | 
    zoho_df['Phone'].isin(df_booking['Mobile']) |
    zoho_df['Mobile'].isin(df_booking['Phone1']) | 
    zoho_df['Mobile'].isin(df_booking['Mobile']) |
    zoho_df['Email'].isin(df_booking['Email'])| 

    zoho_df['Phone'].isin(df_phone['Mobile']) | 
    zoho_df['Mobile'].isin(df_phone['Mobile']) |

    zoho_df['Email'].isin(df_email['Email'])

].shape[0]

zoho_df.drop(zoho_df.loc[
    zoho_df['Phone'].isin(df_booking['Phone1']) | 
    zoho_df['Phone'].isin(df_booking['Mobile']) |
    zoho_df['Mobile'].isin(df_booking['Phone1']) | 
    zoho_df['Mobile'].isin(df_booking['Mobile']) |
    zoho_df['Email'].isin(df_booking['Email']) |
    
    zoho_df['Phone'].isin(df_phone['Mobile']) | 
    zoho_df['Mobile'].isin(df_phone['Mobile']) |

    zoho_df['Email'].isin(df_email['Email'])

    ].index, inplace=True)
    
zoho_df.reset_index(drop=True, inplace=True)

count_after_wash_member = zoho_df.shape[0]

zoho_df
# Out:
#                      Record Id         Created Time Created Date  \
# 0     zcrm_3584690000495006174  2024-05-09 16:00:00        empty
# 1     zcrm_3584690000494987148  2024-05-09 16:00:00        empty
# 2     zcrm_3584690000494966425  2024-05-09 16:00:00        empty
# 3     zcrm_3584690000494904356  2024-05-08 12:25:00        empty
# 4     zcrm_3584690000494904355  2024-05-08 12:25:00        empty
# ...                        ...                  ...          ...
# 3274  zcrm_3584690000494083330  2024-05-02 16:00:00        empty
# 3275  zcrm_3584690000494074551  2024-05-02 16:02:00        empty
# 3276  zcrm_3584690000494074508  2024-05-02 16:01:00        empty
# 3277  zcrm_3584690000494074465  2024-05-02 16:01:00        empty
# 3278  zcrm_3584690000494074422  2024-05-02 16:00:00        empty
#
#      Lead Source Description First Name  Last Name  \
# 0                    Beambox        Jim     Aitken
# 1                    Beambox     Eamonn     MURPHY
# 2                    Beambox      KEITH     Knight
# 3                    Beambox        Ian     Harley
# 4                    Beambox     Flavia     Michel
# ...                      ...        ...        ...
# 3274                 Beambox    Michael     Weller
# 3275                 Beambox        JAN  Etheridge
# 3276                 Beambox    Georgia  Pritchard
# 3277                 Beambox      Nabha  Rankhambe
# 3278                 Beambox   Felicity       Inns
#
#                            Email          Phone Occupation         Mobile  \
# 0             a1tkendrum@aol.com   447798725281      empty   447798725281
# 1          eamonn365@hotmail.com  4407707733547      empty  4407707733547
# 2             kgk22547@gmail.com   447392456672      empty   447392456672
# 3             ianh1703@gmail.com          empty      empty          empty
# 4      flaviamichel.fm@gmail.com          empty      empty          empty
# ...                          ...            ...        ...            ...
# 3274        mickweller@gmail.com  4407419997730      empty  4407419997730
# 3275   trevorwinalot94@gmail.com   441908568988      empty   441908568988
# 3276      geepritchard@gmail.com   447447811304      empty   447447811304
# 3277  nabharankhambe01@gmail.com   918828391429      empty   918828391429
# 3278      felicityinns@gmail.com   447535787631      empty   447535787631
#
#       ... Messages Do Not Mail Do Not Contact Lead Location  \
# 0     ...    empty       false          false         empty
# 1     ...    empty       false          false         empty
# 2     ...    empty       false          false         empty
# 3     ...    empty       false          false         empty
# 4     ...    empty       false          false         empty
# ...   ...      ...         ...            ...           ...
# 3274  ...    empty       false          false         empty
# 3275  ...    empty       false          false         empty
# 3276  ...    empty       false          false         empty
# 3277  ...    empty       false          false         empty
# 3278  ...    empty       false          false         empty
#
#      Lead Location Description Agency Name Agent Name Campaign Name  \
# 0                        empty       empty      empty         empty
# 1                        empty       empty      empty         empty
# 2                        empty       empty      empty         empty
# 3                        empty       empty      empty         empty
# 4                        empty       empty      empty         empty
# ...                        ...         ...        ...           ...
# 3274                     empty       empty      empty         empty
# 3275                     empty       empty      empty         empty
# 3276                     empty       empty      empty         empty
# 3277                     empty       empty      empty         empty
# 3278                     empty       empty      empty         empty
#
#      Card Number Website
# 0          empty   empty
# 1          empty   empty
# 2          empty   empty
# 3          empty   empty
# 4          empty   empty
# ...          ...     ...
# 3274       empty   empty
# 3275       empty   empty
# 3276       empty   empty
# 3277       empty   empty
# 3278       empty   empty
#
# [3279 rows x 50 columns]

# %%
# data phone, mobile dam email member yang ada di master data 
count_wash_prev_wifi = zoho_df.loc[
    zoho_df['Phone'].isin(df_wifi['Phone']) | 
    zoho_df['Phone'].isin(df_wifi['Mobile']) |
    zoho_df['Mobile'].isin(df_wifi['Phone']) | 
    zoho_df['Mobile'].isin(df_wifi['Mobile']) |
    zoho_df['Email'].isin(df_wifi['Email'])

].shape[0]

zoho_df.drop(zoho_df.loc[
    zoho_df['Phone'].isin(df_wifi['Phone']) | 
    zoho_df['Phone'].isin(df_wifi['Mobile']) |
    zoho_df['Mobile'].isin(df_wifi['Phone']) | 
    zoho_df['Mobile'].isin(df_wifi['Mobile']) |
    zoho_df['Email'].isin(df_wifi['Email'])

    ].index, inplace=True)
    
zoho_df.reset_index(drop=True, inplace=True)

count_after_wash_prev_wifi = zoho_df.shape[0]

zoho_df
# Out:
#                      Record Id         Created Time Created Date  \
# 0     zcrm_3584690000495006174  2024-05-09 16:00:00        empty
# 1     zcrm_3584690000494987148  2024-05-09 16:00:00        empty
# 2     zcrm_3584690000494904356  2024-05-08 12:25:00        empty
# 3     zcrm_3584690000494904355  2024-05-08 12:25:00        empty
# 4     zcrm_3584690000494904354  2024-05-08 12:25:00        empty
# ...                        ...                  ...          ...
# 3193  zcrm_3584690000494819106  2024-05-08 12:24:00        empty
# 3194  zcrm_3584690000494819105  2024-05-08 12:24:00        empty
# 3195  zcrm_3584690000494819103  2024-05-08 12:24:00        empty
# 3196  zcrm_3584690000494819102  2024-05-08 12:24:00        empty
# 3197  zcrm_3584690000494819101  2024-05-08 12:24:00        empty
#
#      Lead Source Description First Name Last Name  \
# 0                    Beambox        Jim    Aitken
# 1                    Beambox     Eamonn    MURPHY
# 2                    Beambox        Ian    Harley
# 3                    Beambox     Flavia    Michel
# 4                    Beambox        Kai     Speck
# ...                      ...        ...       ...
# 3193                 Beambox        Laf        Ju
# 3194                 Beambox     Fibria   Rhischa
# 3195                 Beambox     Murray      Hill
# 3196                 Beambox    Frankie   Clifton
# 3197                 Beambox      Gavin   Barrack
#
#                              Email          Phone Occupation         Mobile  \
# 0               a1tkendrum@aol.com   447798725281      empty   447798725281
# 1            eamonn365@hotmail.com  4407707733547      empty  4407707733547
# 2               ianh1703@gmail.com          empty      empty          empty
# 3        flaviamichel.fm@gmail.com          empty      empty          empty
# 4                kai.speck@live.de          empty      empty          empty
# ...                            ...            ...        ...            ...
# 3193            injal42@hotmail.fr    44668233661      empty          empty
# 3194        vytaditya_ra@yahoo.com          empty      empty          empty
# 3195       murraymhill@hotmail.com   447925997047      empty          empty
# 3196   frankie.clifton95@gmail.com  4407501677462      empty          empty
# 3197  gavin.barrack@btinternet.com   447533897029      empty          empty
#
#       ... Messages Do Not Mail Do Not Contact Lead Location  \
# 0     ...    empty       false          false         empty
# 1     ...    empty       false          false         empty
# 2     ...    empty       false          false         empty
# 3     ...    empty       false          false         empty
# 4     ...    empty       false          false         empty
# ...   ...      ...         ...            ...           ...
# 3193  ...    empty       false          false         empty
# 3194  ...    empty       false          false         empty
# 3195  ...    empty       false          false         empty
# 3196  ...    empty       false          false         empty
# 3197  ...    empty       false          false         empty
#
#      Lead Location Description Agency Name Agent Name Campaign Name  \
# 0                        empty       empty      empty         empty
# 1                        empty       empty      empty         empty
# 2                        empty       empty      empty         empty
# 3                        empty       empty      empty         empty
# 4                        empty       empty      empty         empty
# ...                        ...         ...        ...           ...
# 3193                     empty       empty      empty         empty
# 3194                     empty       empty      empty         empty
# 3195                     empty       empty      empty         empty
# 3196                     empty       empty      empty         empty
# 3197                     empty       empty      empty         empty
#
#      Card Number Website
# 0          empty   empty
# 1          empty   empty
# 2          empty   empty
# 3          empty   empty
# 4          empty   empty
# ...          ...     ...
# 3193       empty   empty
# 3194       empty   empty
# 3195       empty   empty
# 3196       empty   empty
# 3197       empty   empty
#
# [3198 rows x 50 columns]

# %%
count_email_only = zoho_df.loc[(zoho_df['Email'] != 'empty') & ((zoho_df['Phone'] == 'empty') & (zoho_df['Mobile'] == 'empty'))].shape[0]
count_phone_only = zoho_df.loc[(zoho_df['Email'] == 'empty') & ((zoho_df['Phone'] != 'empty') | (zoho_df['Mobile'] != 'empty'))].shape[0]
count_email_and_phone = zoho_df.loc[(zoho_df['Email'] != 'empty') & ((zoho_df['Phone'] != 'empty') | (zoho_df['Mobile'] != 'empty'))].shape[0]

count_blank = zoho_df.loc[(zoho_df['Email'] =='empty') & (zoho_df['Phone']=='empty') & (zoho_df['Mobile']=='empty')].shape[0]

# zoho_df.loc[(zoho_df['Email'] =='empty') & (zoho_df['Phone']=='empty') & (zoho_df['Mobile']=='empty')].to_excel(r'C:\Users\fajar\Documents\Python\Data\blank_data.xlsx', index=False)

zoho_df.loc[(zoho_df['Email'] != 'empty') & ((zoho_df['Phone'] == 'empty') & (zoho_df['Mobile'] == 'empty')), 'Contact Type'] = 'Email Only'
zoho_df.loc[(zoho_df['Email'] == 'empty') & ((zoho_df['Phone'] != 'empty') | (zoho_df['Mobile'] != 'empty')), 'Contact Type'] = 'Phone Only'
zoho_df.loc[(zoho_df['Email'] != 'empty') & ((zoho_df['Phone'] != 'empty') | (zoho_df['Mobile'] != 'empty')), 'Contact Type'] = 'Email and Phone'

zoho_df.drop(zoho_df.loc[(zoho_df['Email'] =='empty') & (zoho_df['Phone']=='empty') & (zoho_df['Mobile']=='empty')].index, inplace=True)
zoho_df.reset_index(drop=True, inplace=True)

count_after_wash_blank = zoho_df.shape[0]

# %%
arr_dedup = [count_deleted_wrong_format, count_duplicate_general, count_leads_test, count_email_OTA, count_email_karma, count_blank]
count_sum_dedup = sum(arr_dedup)
count_sum_dedup
# Out:
# 25

# %%
print("==========================================================")
print("Summary")
print("==========================================================")
print("Jumlah Filter Leads Awal : "+str(count_filter_awal))
print("Jumlah Format Email Salah : "+str(count_deleted_wrong_format))
print("Jumlah Setelah Clean Format Email Salah : "+str(count_after_deleted_wrong_format))
print("Jumlah Duplicate (Phone, Mobile dan Email) : "+str(count_duplicate_general))
print("Jumlah Setelah Clean Duplicate : "+str(count_after_dedup_duplicate))
print("Jumlah Lead Test : "+str(count_leads_test))
print("Jumlah Setelah Clean Lead Test : "+str(count_after_dedup_test))
# print("Jumlah Lead Do Not Mail : "+str(count_dnm))
# print("Jumlah Setelah Clean Lead Do Not Mail : "+str(count_after_dedup_dnm))
print("Jumlah Email OTA : "+str(count_email_OTA))
print("Jumlah Setelah Clean Email OTA : "+str(count_after_clean_OTA))
print("Jumlah Email Karma : "+str(count_email_karma))
print("Jumlah Setelah Clean Email Karma : "+str(count_after_clean_karma))
print("Jumlah Wash Member : "+str(count_member_dedup))
print("Jumlah Wash Booking : "+str(count_booking_dedup))
print("Jumlah Setelah Wash Member : "+str(count_after_wash_member))
print("Jumlah Wash Wifi : "+str(count_wash_prev_wifi))
print("Jumlah Setelah Wash Wifi : "+str(count_after_wash_prev_wifi))
print("Jumlah Phone Email Blank (Setelah phone yang tidak valid dihapus) : "+str(count_blank))
print("Jumlah Setelah Wash Phone Email Blank : "+str(count_after_wash_blank))
print("==========================================================")
print("Contact Type")
print("==========================================================")
print("Jumlah Email Only : "+str(count_email_only))
print("Jumlah Phone Only : "+str(count_phone_only))
print("Jumlah Email dan Phone : "+str(count_email_and_phone))
# Out:
# ==========================================================
# Summary
# ==========================================================
# Jumlah Filter Leads Awal : 4215
# Jumlah Format Email Salah : 0
# Jumlah Setelah Clean Format Email Salah : 4215
# Jumlah Duplicate (Phone, Mobile dan Email) : 0
# Jumlah Setelah Clean Duplicate : 4215
# Jumlah Lead Test : 0
# Jumlah Setelah Clean Lead Test : 4215
# Jumlah Email OTA : 4
# Jumlah Setelah Clean Email OTA : 4211
# Jumlah Email Karma : 21
# Jumlah Setelah Clean Email Karma : 4190
# Jumlah Wash Member : 905
# Jumlah Wash Booking : 6
# Jumlah Setelah Wash Member : 3279
# Jumlah Wash Wifi : 81
# Jumlah Setelah Wash Wifi : 3198
# Jumlah Phone Email Blank (Setelah phone yang tidak valid dihapus) : 0
# Jumlah Setelah Wash Phone Email Blank : 3198
# ==========================================================
# Contact Type
# ==========================================================
# Jumlah Email Only : 405
# Jumlah Phone Only : 0
# Jumlah Email dan Phone : 2793

# %%
print("==========================================================")
print("Summary Report")
print("==========================================================")
print("Jumlah Data Awal : "+str(count_filter_awal))
print("Jumlah Wash Dedup : "+str(count_sum_dedup))
print("Jumlah Wash Member : "+str(count_member_dedup))
print("Jumlah Wash Booking : "+str(count_booking_dedup))
print("Jumlah Wash Wifi : "+str(count_wash_prev_wifi))
print("Jumlah Data Akhir : "+str(count_after_wash_blank))
# Out:
# ==========================================================
# Summary Report
# ==========================================================
# Jumlah Data Awal : 4215
# Jumlah Wash Dedup : 25
# Jumlah Wash Member : 905
# Jumlah Wash Booking : 6
# Jumlah Wash Wifi : 81
# Jumlah Data Akhir : 3198

# %%
zoho_df.replace('empty', '', inplace=True, regex=True)

zoho_df['First Name'] = zoho_df['First Name'].str.title()
zoho_df['Last Name'] = zoho_df['Last Name'].str.title()

zoho_df.to_excel(r'C:\Users\fajar\Documents\Python\Data\wifi-update.xlsx', index=False)
