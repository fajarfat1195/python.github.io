# %%
import main_module as m
import pandas as pd
import re
import numpy as np

# %load_ext autoreload
# %autoreload 2

dir_path = r'C:\Users\fajar\Documents\Python\Data\Zoho_Backup\2020-2024\\'
dir_path_live = r'C:\Users\fajar\Documents\Python\Data\Zoho_Backup\\'
dir_path_old = r'C:\Users\fajar\Documents\Python\Data\Zoho_Backup\old\\'
file_name = '\Leads_'

cols = ['Record Id',	
'Created Time',
'Created Date',	
'First Name',	
'Last Name',	
'Email',	
'Phone',	
'Mobile',	
'Birthdate',	
'Year of Birth',
'Street',	
'Street2',	
'City',	
'State',	
'Country',	
'Nationality',
'Booking Status', 
'BookRef',
'Departure Date',	
'Arrival Date',	
'Card Type',	
'Marital Status',	
'Lead Brand',	
'Lead Sub-Brand',	
'Lead Source',	
'Lead Locations',	
'Lead Source Description',	
'Lead Regions',
'Lead Status',
'Email Opt Out',	
'Opt In',
'GDPR Compliant',
'Website',
'Comments']
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
column_name = 'Lead Sub-Brand'
search_value = 'Karma Club'

operator = 'is'
# operator = 'contains'

target_location = r'C:\Users\fajar\Documents\Python\Data'
file_type = 'xlsx'

# %%
path = dir_path+'\\backup.csv'
df_all = pd.read_csv(path, dtype='string', on_bad_lines='skip')
df_all.drop(df_all.loc[df_all['Created Time'].str.len() < 5 ].index, inplace=True)
df_all.reset_index(drop=True, inplace=True)

df_all['Created Time'] = pd.to_datetime(df_all['Created Time'], format='%Y-%m-%d %H:%M:%S')

df_all.shape[0]
df_all
# Out:
#                         Record Id        Created Time Created Date First Name  \
# 0        zcrm_3584690000000404058 2019-01-07 15:08:38   2019-01-06   Nicholas
# 1        zcrm_3584690000000404059 2019-01-07 15:08:38   2019-01-06       Liao
# 2        zcrm_3584690000000404060 2019-01-07 15:08:38   2019-01-06    Vedanta
# 3        zcrm_3584690000000404065 2019-01-07 15:08:38   2019-01-06      Aidai
# 4        zcrm_3584690000000404068 2019-01-07 15:08:38   2019-01-06      Ardra
# ...                           ...                 ...          ...        ...
# 9965978  zcrm_3584690000489266005 2024-03-25 16:19:45         <NA>      Keval
# 9965979  zcrm_3584690000489266034 2024-03-25 16:19:51         <NA>     Suresh
# 9965980  zcrm_3584690000489266063 2024-03-25 17:29:27         <NA>     Nathan
# 9965981  zcrm_3584690000489269015 2024-03-25 16:20:25         <NA>    Leonora
# 9965982  zcrm_3584690000489271002 2024-03-25 18:40:17         <NA>       Annu
#
#           Last Name                                 Email           Phone  \
# 0              Wood            1230woodnicholas@gmail.com     61438600845
# 1              Yuan                      158066546@qq.com   8618718399923
# 2          Abhiyoga            abhiyoga.vedanta@gmail.com   6282146524550
# 3         Atakanova                aidai.nurbek@gmail.com    996779641590
# 4             Ardra            aliefardraqariru@gmail.com  +6282139300818
# ...             ...                                   ...             ...
# 9965978        Gala                   keval2403@gmail.com   +919022872972
# 9965979      Shroff  sureshshroff@breachcandyhospital.org   +919819533303
# 9965980   Fernandes       nathan.fernandes@karmagroup.com  +9179724486854
# 9965981     Hackman                leonora_hf@bigpond.com    +61439855115
# 9965982  Shriwastav          annusrivastava1990@gmail.com   +919561074124
#
#                  Mobile   Birthdate Year of Birth  ...         Arrival Date  \
# 0                  <NA>        <NA>          <NA>  ...  2019-01-06 00:00:00
# 1                  <NA>        <NA>          <NA>  ...  2019-01-06 00:00:00
# 2                  <NA>  2000-07-05          2000  ...  2018-12-01 00:00:00
# 3                  <NA>  1997-02-05          1997  ...  2019-01-06 00:00:00
# 4        +6282139300818  2005-01-20          2005  ...  2018-11-30 00:00:00
# ...                 ...         ...           ...  ...                  ...
# 9965978   +917700904802        <NA>          <NA>  ...           2024-03-21
# 9965979   +919819814280        <NA>          <NA>  ...           2024-03-21
# 9965980            <NA>        <NA>          <NA>  ...                 <NA>
# 9965981            <NA>        <NA>          <NA>  ...           2024-03-14
# 9965982            <NA>        <NA>          <NA>  ...                 <NA>
#
#         Card Type Marital Status           Lead Brand   Lead Sub-Brand  \
# 0            <NA>           <NA>  Timeshare Marketing    Other Bali DB
# 1            <NA>           <NA>  Timeshare Marketing    Other Bali DB
# 2            <NA>        Pelajar  Timeshare Marketing    Other Bali DB
# 3            <NA>         Single  Timeshare Marketing    Other Bali DB
# 4            <NA>          OTHER  Timeshare Marketing    Other Bali DB
# ...           ...            ...                  ...              ...
# 9965978      <NA>           <NA>        Karma Resorts            Other
# 9965979      <NA>           <NA>        Karma Resorts            Other
# 9965980      <NA>           <NA>          Karma Group  Karma Community
# 9965981      <NA>           <NA>        Karma Resorts            Other
# 9965982      <NA>           <NA>  Timeshare Marketing            Other
#
#          Lead Source           Lead Locations  \
# 0               Wifi              Purple Wifi
# 1               Wifi              Purple Wifi
# 2               Wifi              Purple Wifi
# 3               Wifi              Purple Wifi
# 4               Wifi              Purple Wifi
# ...              ...                      ...
# 9965978  Past Guests        Karma Royal Palms
# 9965979  Past Guests  Karma Sitabani, Corbett
# 9965980         Quiz                     <NA>
# 9965981  Past Guests           Karma Jimbaran
# 9965982  Web Enquiry           Karma Sitabani
#
#                                    Lead Source Description Lead Regions  \
# 0                                                     <NA>         SEAP
# 1                                                     <NA>        Other
# 2                                                     <NA>         SEAP
# 3                                                     <NA>    UK/Europe
# 4                                    WIFI USER ID 13494142         SEAP
# ...                                                    ...          ...
# 9965978                                          Viewpoint         <NA>
# 9965979                                          Viewpoint         <NA>
# 9965980  Karma Community | Edition 218 - Words to the Wise        India
# 9965981                                          Viewpoint         <NA>
# 9965982                          Timeshare Booking Request        India
#
#         Lead Status
# 0          New Lead
# 1          New Lead
# 2          New Lead
# 3          New Lead
# 4          New Lead
# ...             ...
# 9965978        <NA>
# 9965979        <NA>
# 9965980        <NA>
# 9965981        <NA>
# 9965982        <NA>
#
# [9965983 rows x 27 columns]

# %%
df_old = m.load_data_multiple(dir_path_old, file_name, cols)
df_old = df_old.reindex(columns=cols)
df_old.shape[0]

df_old['Created Time'] = pd.to_datetime(df_old['Created Time'], format='%Y-%m-%d %H:%M:%S')
df_old['Arrival Date'] = pd.to_datetime(df_old['Arrival Date'], format='%Y-%m-%d')
df_old['Departure Date'] = pd.to_datetime(df_old['Departure Date'], format='%Y-%m-%d')
# fungsi errors cource untuk menhindari error jika value data date null atau kosong
# df['Birthdate'] = pd.to_datetime(df['Birthdate'], format='%Y-%m-%d', errors='coerce')
df_old.dtypes
df_old
# Out:
#                         Record Id        Created Time Created Date First Name  \
# 0        zcrm_3584690000000404058 2019-01-07 15:08:38   2019-01-06   Nicholas
# 1        zcrm_3584690000000404059 2019-01-07 15:08:38   2019-01-06       Liao
# 2        zcrm_3584690000000404060 2019-01-07 15:08:38   2019-01-06    Vedanta
# 3        zcrm_3584690000000404065 2019-01-07 15:08:38   2019-01-06      Aidai
# 4        zcrm_3584690000000404068 2019-01-07 15:08:38   2019-01-06      Ardra
# ...                           ...                 ...          ...        ...
# 4717718  zcrm_3584690000475135007 2024-01-01 18:16:02         <NA>    Upendra
# 4717719  zcrm_3584690000475135045 2024-01-01 18:16:37         <NA>      Mehul
# 4717720  zcrm_3584690000475136005 2024-01-01 18:17:13         <NA>      swati
# 4717721  zcrm_3584690000475138034 2024-01-01 18:48:36         <NA>      SUMON
# 4717722  zcrm_3584690000475138069 2024-01-01 18:52:24         <NA>      Rohit
#
#          Last Name                       Email           Phone  \
# 0             Wood  1230woodnicholas@gmail.com    +61438600845
# 1             Yuan            158066546@qq.com   8618718399923
# 2         Abhiyoga  abhiyoga.vedanta@gmail.com  +6282146524550
# 3        Atakanova      aidai.nurbek@gmail.com    996779641590
# 4            Ardra  aliefardraqariru@gmail.com  +6282139300818
# ...            ...                         ...             ...
# 4717718     Mishra       upendra.sir@gmail.com   +919036084550
# 4717719  Prajapati     mehul.m111985@gmail.com   +919714713689
# 4717720   agarwala         cswatiadv@gmail.com   +919733055636
# 4717721      SAHOO        sumonsahoo@gmail.com   +918910484814
# 4717722      Kadam      rohit0918.rk@gmail.com   +919819185446
#
#                  Mobile   Birthdate Year of Birth  ...   Lead Source  \
# 0                  <NA>        <NA>          <NA>  ...          Wifi
# 1                  <NA>        <NA>          <NA>  ...          Wifi
# 2                  <NA>  2000-07-05          2000  ...          Wifi
# 3                  <NA>  1997-02-05          1997  ...          Wifi
# 4        +6282139300818  2005-01-20          2005  ...          Wifi
# ...                 ...         ...           ...  ...           ...
# 4717718            <NA>        <NA>          <NA>  ...   Web Enquiry
# 4717719            <NA>        <NA>          <NA>  ...  Facebook Ads
# 4717720            <NA>        <NA>          <NA>  ...  Facebook Ads
# 4717721            <NA>        <NA>          <NA>  ...  Facebook Ads
# 4717722            <NA>        <NA>          <NA>  ...  Facebook Ads
#
#                  Lead Locations      Lead Source Description Lead Regions  \
# 0                          <NA>                  Purple Wifi         SEAP
# 1                          <NA>                  Purple Wifi        Other
# 2                          <NA>                  Purple Wifi         SEAP
# 3                          <NA>                  Purple Wifi    UK/Europe
# 4                       Mall 21                  Purple Wifi         SEAP
# ...                         ...                          ...          ...
# 4717718  Karma Sunshine Village    Timeshare Booking Request        India
# 4717719                 General  IND | FB MF | Lead captured         <NA>
# 4717720            Karma Martam         IND | FB MF | Martam         <NA>
# 4717721            Karma Martam         IND | FB MF | Martam         <NA>
# 4717722             Royal Palms            IND | FB AF | KRP         <NA>
#
#         Lead Status Email Opt Out Opt In GDPR Compliant  \
# 0          New Lead         false  false          false
# 1          New Lead         false  false          false
# 2          New Lead         false  false          false
# 3          New Lead         false  false          false
# 4          New Lead         false  false          false
# ...             ...           ...    ...            ...
# 4717718        <NA>         false   true           true
# 4717719        <NA>         false  false          false
# 4717720        <NA>         false  false          false
# 4717721        <NA>         false  false          false
# 4717722        <NA>         false  false          false
#
#                                                    Website Comments
# 0                                                     <NA>     <NA>
# 1                                                     <NA>     <NA>
# 2                                                     <NA>     <NA>
# 3                                                     <NA>     <NA>
# 4                                                     <NA>     <NA>
# ...                                                    ...      ...
# 4717718  https://karmagroup.com/find-destination/karma-...     <NA>
# 4717719                                               <NA>     <NA>
# 4717720                                               <NA>     <NA>
# 4717721                                               <NA>     <NA>
# 4717722                                               <NA>     <NA>
#
# [4717723 rows x 34 columns]

# %%
df_live = m.load_data_multiple(dir_path_live, file_name, cols)
df_live = df_live.reindex(columns=cols)
df_live.shape[0]

df_live['Created Time'] = pd.to_datetime(df_live['Created Time'], format='%Y-%m-%d %H:%M:%S')
df_live['Arrival Date'] = pd.to_datetime(df_live['Arrival Date'], format='%Y-%m-%d')
df_live['Departure Date'] = pd.to_datetime(df_live['Departure Date'], format='%Y-%m-%d')
# fungsi errors cource untuk menhindari error jika value data date null atau kosong
# df['Birthdate'] = pd.to_datetime(df['Birthdate'], format='%Y-%m-%d', errors='coerce')
df_live.dtypes
df_live
# Out:
#                        Record Id        Created Time Created Date First Name  \
# 0       zcrm_3584690000000404602 2019-01-08 11:07:28   2021-07-21   Frederic
# 1       zcrm_3584690000000450071 2019-01-08 16:38:18         <NA>  Sebastian
# 2       zcrm_3584690000000450087 2019-01-08 16:38:18         <NA>    Siobhan
# 3       zcrm_3584690000000450106 2019-01-08 16:38:18         <NA>       Lisa
# 4       zcrm_3584690000000450109 2019-01-08 16:38:18         <NA>  Ana Maria
# ...                          ...                 ...          ...        ...
# 456198  zcrm_3584690000502118035 2024-07-15 17:01:09         <NA>          P
# 456199  zcrm_3584690000502118068 2024-07-15 17:42:29         <NA>    Stephan
# 456200  zcrm_3584690000502119001 2024-07-15 16:34:56         <NA>      Alvin
# 456201  zcrm_3584690000502121002 2024-07-15 17:01:02         <NA>      Quyen
# 456202  zcrm_3584690000502124001 2024-07-15 17:36:44   2024-07-15       <NA>
#
#         Last Name                        Email           Phone         Mobile  \
# 0           Bonin    fredericbonin79@gmail.com  +6281236100502           <NA>
# 1            Rach                         <NA>   +498914342111           <NA>
# 2       Gallagher  gallaghersiobhan@eircom.net    353879597603           <NA>
# 3       Ferkovich         lisajo2009@yahoo.com     14062394749           <NA>
# 4        Weileder     m.weileder@sonnenlink.de     15253234700           <NA>
# ...           ...                          ...             ...            ...
# 456198   M BHADRE           pmbhadre@gmail.com            <NA>           <NA>
# 456199    Joachim          joastephan@yahoo.de   +491621791259           <NA>
# 456200   Cabautan     alvin.cabautan@gmail.com   +610416159756  +610416159756
# 456201     Martin         cindykim10@yahoo.com    +61421235687           <NA>
# 456202   Jen Clay        jenclay22@hotmail.com   +971582433297           <NA>
#
#          Birthdate Year of Birth  ...  Lead Source    Lead Locations  \
# 0       1981-10-03          1981  ...       Agency     Karma Kandara
# 1       1982-04-20          1982  ...  Past Guests     Karma Bavaria
# 2       1973-03-14          1973  ...  Past Guests     Karma Bavaria
# 3       1963-07-08          1963  ...  Past Guests     Karma Bavaria
# 4             <NA>          <NA>  ...        Other     Karma Bavaria
# ...            ...           ...  ...          ...               ...
# 456198        <NA>          <NA>  ...      Webchat              <NA>
# 456199        <NA>          <NA>  ...  Web Enquiry              <NA>
# 456200        <NA>          <NA>  ...  Web Enquiry           General
# 456201        <NA>          <NA>  ...  Web Enquiry   Karma Song Hoai
# 456202        <NA>          <NA>  ...  Web Enquiry  Karma La Herriza
#
#                                   Lead Source Description Lead Regions  \
# 0                                                   KAREN         SEAP
# 1                                                    <NA>    UK/Europe
# 2                                                    <NA>    UK/Europe
# 3                                                    <NA>    UK/Europe
# 4                         MICE Contacts from Ioanna email    UK/Europe
# ...                                                   ...          ...
# 456198               Karma Experience India | Webchat Web        India
# 456199                                    Form Contact Us    UK/Europe
# 456200                       KE | Web | Newsletter Footer         SEAP
# 456201                          Timeshare Booking Request         SEAP
# 456202  Karma La Herriza - Download Wedding Brochure a...  Middle East
#
#           Lead Status Email Opt Out Opt In GDPR Compliant  \
# 0            New Lead         false  false          false
# 1            New Lead          true  false          false
# 2            New Lead         false   true           true
# 3            New Lead          true  false          false
# 4            New Lead         false   true           true
# ...               ...           ...    ...            ...
# 456198           <NA>         false   true          false
# 456199           <NA>         false   true           true
# 456200  Not Qualified         false  false          false
# 456201           <NA>         false   true           true
# 456202           <NA>         false   true          false
#
#                                                   Website Comments
# 0                                                    <NA>     <NA>
# 1                                                    <NA>     <NA>
# 2                                                    <NA>     <NA>
# 3                                                    <NA>     <NA>
# 4                                                    <NA>     <NA>
# ...                                                   ...      ...
# 456198               https://karmagroup.com/member-login/     <NA>
# 456199                 https://karmagroup.com/contact-us/     <NA>
# 456200                   https://www.karmaexperience.com/     <NA>
# 456201                            https://karmagroup.com/     <NA>
# 456202  https://karmagroup.com/weddings-at-karma-la-he...     <NA>
#
# [456203 rows x 34 columns]

# %%
df = pd.concat([df_all,df_old,df_live])
count_data_awal = df.shape[0]
df
# Out:
#                        Record Id        Created Time Created Date First Name  \
# 0       zcrm_3584690000000404058 2019-01-07 15:08:38   2019-01-06   Nicholas
# 1       zcrm_3584690000000404059 2019-01-07 15:08:38   2019-01-06       Liao
# 2       zcrm_3584690000000404060 2019-01-07 15:08:38   2019-01-06    Vedanta
# 3       zcrm_3584690000000404065 2019-01-07 15:08:38   2019-01-06      Aidai
# 4       zcrm_3584690000000404068 2019-01-07 15:08:38   2019-01-06      Ardra
# ...                          ...                 ...          ...        ...
# 456198  zcrm_3584690000502118035 2024-07-15 17:01:09         <NA>          P
# 456199  zcrm_3584690000502118068 2024-07-15 17:42:29         <NA>    Stephan
# 456200  zcrm_3584690000502119001 2024-07-15 16:34:56         <NA>      Alvin
# 456201  zcrm_3584690000502121002 2024-07-15 17:01:02         <NA>      Quyen
# 456202  zcrm_3584690000502124001 2024-07-15 17:36:44   2024-07-15       <NA>
#
#         Last Name                       Email           Phone          Mobile  \
# 0            Wood  1230woodnicholas@gmail.com     61438600845            <NA>
# 1            Yuan            158066546@qq.com   8618718399923            <NA>
# 2        Abhiyoga  abhiyoga.vedanta@gmail.com   6282146524550            <NA>
# 3       Atakanova      aidai.nurbek@gmail.com    996779641590            <NA>
# 4           Ardra  aliefardraqariru@gmail.com  +6282139300818  +6282139300818
# ...           ...                         ...             ...             ...
# 456198   M BHADRE          pmbhadre@gmail.com            <NA>            <NA>
# 456199    Joachim         joastephan@yahoo.de   +491621791259            <NA>
# 456200   Cabautan    alvin.cabautan@gmail.com   +610416159756   +610416159756
# 456201     Martin        cindykim10@yahoo.com    +61421235687            <NA>
# 456202   Jen Clay       jenclay22@hotmail.com   +971582433297            <NA>
#
#          Birthdate Year of Birth  ...  \
# 0             <NA>          <NA>  ...
# 1             <NA>          <NA>  ...
# 2       2000-07-05          2000  ...
# 3       1997-02-05          1997  ...
# 4       2005-01-20          2005  ...
# ...            ...           ...  ...
# 456198        <NA>          <NA>  ...
# 456199        <NA>          <NA>  ...
# 456200        <NA>          <NA>  ...
# 456201        <NA>          <NA>  ...
# 456202        <NA>          <NA>  ...
#
#                                   Lead Source Description Lead Regions  \
# 0                                                    <NA>         SEAP
# 1                                                    <NA>        Other
# 2                                                    <NA>         SEAP
# 3                                                    <NA>    UK/Europe
# 4                                   WIFI USER ID 13494142         SEAP
# ...                                                   ...          ...
# 456198               Karma Experience India | Webchat Web        India
# 456199                                    Form Contact Us    UK/Europe
# 456200                       KE | Web | Newsletter Footer         SEAP
# 456201                          Timeshare Booking Request         SEAP
# 456202  Karma La Herriza - Download Wedding Brochure a...  Middle East
#
#           Lead Status Booking Status BookRef Email Opt Out Opt In  \
# 0            New Lead           <NA>    <NA>          <NA>   <NA>
# 1            New Lead           <NA>    <NA>          <NA>   <NA>
# 2            New Lead           <NA>    <NA>          <NA>   <NA>
# 3            New Lead           <NA>    <NA>          <NA>   <NA>
# 4            New Lead           <NA>    <NA>          <NA>   <NA>
# ...               ...            ...     ...           ...    ...
# 456198           <NA>           <NA>    <NA>         false   true
# 456199           <NA>           <NA>    <NA>         false   true
# 456200  Not Qualified           <NA>    <NA>         false  false
# 456201           <NA>           <NA>    <NA>         false   true
# 456202           <NA>           <NA>    <NA>         false   true
#
#        GDPR Compliant                                            Website  \
# 0                <NA>                                               <NA>
# 1                <NA>                                               <NA>
# 2                <NA>                                               <NA>
# 3                <NA>                                               <NA>
# 4                <NA>                                               <NA>
# ...               ...                                                ...
# 456198          false               https://karmagroup.com/member-login/
# 456199           true                 https://karmagroup.com/contact-us/
# 456200          false                   https://www.karmaexperience.com/
# 456201           true                            https://karmagroup.com/
# 456202          false  https://karmagroup.com/weddings-at-karma-la-he...
#
#        Comments
# 0          <NA>
# 1          <NA>
# 2          <NA>
# 3          <NA>
# 4          <NA>
# ...         ...
# 456198     <NA>
# 456199     <NA>
# 456200     <NA>
# 456201     <NA>
# 456202     <NA>
#
# [15139909 rows x 34 columns]

# %%
path = r'G:\.shortcut-targets-by-id\0B_d3smBjzo04eXpvS1NXTWF2RVE\_BOOKING\Booking By Year\FlyBuy Booking Data (BGAU & BGID & KE).xlsx'
df_booking = pd.read_excel(path, dtype='string', sheet_name='BOOKING_BGAU_BGID_KE')

path = r'G:\.shortcut-targets-by-id\0B_d3smBjzo04UUNBME5GOVhoMjA\_ODYSSEY\Phone Members.xlsx'
df_phone = pd.read_excel(path, dtype='string', sheet_name='Sheet1')

path = r'G:\.shortcut-targets-by-id\0B_d3smBjzo04UUNBME5GOVhoMjA\_ODYSSEY\Email Members.xlsx'
df_email = pd.read_excel(path, dtype='string', sheet_name='Sheet1')

# %%
if operator == 'is':
    zoho_df = df.loc[df[column_name] == search_value].copy()
else:
    zoho_df = df.loc[df[column_name].str.contains(search_value, regex=True, flags=re.I)].copy()

zoho_df.reset_index(drop=True, inplace=True)
count_filter_awal = zoho_df.shape[0]

# zoho_df.to_excel(r'C:\Users\fajar\Documents\Python\Data\test_leads.xlsx', index=False)
# mengisi kolom <NA> dengan value string 'empty' supaya mudah mengecek data member dan booking dengan isin

zoho_df.fillna('empty', inplace=True)
zoho_df.sort_values('Created Time', ascending=True)
zoho_df
# Out:
#                        Record Id        Created Time Created Date  \
# 0       zcrm_3584690000007050147 2019-04-02 05:26:55   2017-01-13
# 1       zcrm_3584690000007050148 2019-04-02 05:26:55   2017-11-06
# 2       zcrm_3584690000007050149 2019-04-02 05:26:55   2017-11-24
# 3       zcrm_3584690000007050150 2019-04-02 05:26:55   2017-05-23
# 4       zcrm_3584690000007050151 2019-04-02 05:26:55   2016-02-23
# ...                          ...                 ...          ...
# 224109  zcrm_3584690000465300072 2023-10-15 20:06:22        empty
# 224110  zcrm_3584690000465671001 2023-10-17 20:42:27        empty
# 224111  zcrm_3584690000465788001 2023-10-18 05:29:53        empty
# 224112  zcrm_3584690000465809001 2023-10-18 13:00:39        empty
# 224113  zcrm_3584690000465855001 2023-10-18 14:21:44        empty
#
#           First Name     Last Name                            Email  \
# 0              James        Parson            jparsons252@gmail.com
# 1             Johnny         Miaco               jpas01@outlook.com
# 2            Jessica        Paulin              jpaulin86@gmail.com
# 3              James        Boggan             jpboggan@hotmail.com
# 4               John          Brad              jpbraid@bigpond.com
# ...              ...           ...                              ...
# 224109      Ruewayne      Rungsamy      ruewayne.rungsamy@gmail.com
# 224110  Abdul Ghafar        Didari           abdul.didari@yahoo.com
# 224111        Kristy      Bartlett       Kristyxxbartlett@gmail.com
# 224112   Abdul rahim        Akbari          rahim.gulalai@gmail.com
# 224113    Hermansyah  Budi Prakasa  hermansyahbudiprakasa@gmail.com
#
#                  Phone       Mobile   Birthdate Year of Birth  ...  \
# 0          61438662484        empty  1974-01-30          1974  ...
# 1          61402469987        empty  1981-05-22          1981  ...
# 2          61405440021        empty  1986-09-28          1986  ...
# 3                empty        empty  1975-09-25          1975  ...
# 4          61408114721  61895771767  1950-08-10          1950  ...
# ...                ...          ...         ...           ...  ...
# 224109    +27615072171        empty  1994-06-13         empty  ...
# 224110    +61424344540        empty  1995-07-31         empty  ...
# 224111    +61421005474        empty  1978-04-14         empty  ...
# 224112    +61406961087        empty  1992-08-02         empty  ...
# 224113  +6281369330888        empty  1973-06-23         empty  ...
#
#                            Lead Source Description Lead Regions Lead Status  \
# 0                                  Sales Deck Bali         SEAP       empty
# 1                                    Internal Form         SEAP       empty
# 2                                    Karma Web App         SEAP       empty
# 3                                            RUGBY         SEAP       empty
# 4                                    Internal Form         SEAP       empty
# ...                                            ...          ...         ...
# 224109  KCE | Web | w1aug22 | Redeem PriorityGifts         SEAP    New Lead
# 224110  KCE | Web | w1aug22 | Redeem PriorityGifts         SEAP    New Lead
# 224111  KCE | Web | w1aug22 | Redeem PriorityGifts         SEAP    New Lead
# 224112  KCE | Web | w1aug22 | Redeem PriorityGifts         SEAP    New Lead
# 224113  KCE | Web | w1aug22 | Redeem PriorityGifts         SEAP    New Lead
#
#        Booking Status BookRef Email Opt Out Opt In GDPR Compliant Website  \
# 0               empty   empty         empty  empty          empty   empty
# 1               empty   empty         empty  empty          empty   empty
# 2               empty   empty         empty  empty          empty   empty
# 3               empty   empty         empty  empty          empty   empty
# 4               empty   empty         empty  empty          empty   empty
# ...               ...     ...           ...    ...            ...     ...
# 224109          empty   empty         false  false          false   empty
# 224110          empty   empty         false  false          false   empty
# 224111          empty   empty         false  false          false   empty
# 224112          empty   empty         false  false          false   empty
# 224113          empty   empty         false  false          false   empty
#
#        Comments
# 0         empty
# 1         empty
# 2         empty
# 3         empty
# 4         empty
# ...         ...
# 224109    empty
# 224110    empty
# 224111    empty
# 224112    empty
# 224113    empty
#
# [224114 rows x 34 columns]

# %%
# data phone, mobile dam email member yang ada di master data (wash member)

m.clean_number(zoho_df, 'Phone')
m.clean_number(zoho_df, 'Mobile')
m.replace_not_valid_to_empty(zoho_df, 'Phone')
m.replace_not_valid_to_empty(zoho_df, 'Mobile')
zoho_df['Email'] = m.lowercase(zoho_df, 'Email')
m.clean_space(zoho_df, 'Email')
m.clean_not_valid_email_format(zoho_df, 'Email')

m.clean_number(df_booking, 'Phone1')
m.clean_number(df_booking, 'Mobile')
df_booking['Email'] = m.lowercase(df_booking, 'Email')
m.clean_space(df_booking, 'Email')
m.clean_not_valid_email_format(df_booking, 'Email')

m.clean_number(df_phone, 'Mobile')

df_email['Email'] = m.lowercase(df_email, 'Email')
m.clean_space(df_email, 'Email')
m.clean_not_valid_email_format(df_email, 'Email')
# Out:
# c:\Users\fajar\Documents\Python\Task Offline\zoho_data_app\main_module.py:67: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[df_columns].replace(' ','', regex=True, inplace=True)
# c:\Users\fajar\Documents\Python\Task Offline\zoho_data_app\main_module.py:68: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[df_columns].replace('[^0-9]','', regex=True, inplace=True)
# c:\Users\fajar\Documents\Python\Task Offline\zoho_data_app\main_module.py:90: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[df_columns].replace(' ','', regex=True, inplace=True)
# c:\Users\fajar\Documents\Python\Task Offline\zoho_data_app\main_module.py:67: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[df_columns].replace(' ','', regex=True, inplace=True)
# c:\Users\fajar\Documents\Python\Task Offline\zoho_data_app\main_module.py:68: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[df_columns].replace('[^0-9]','', regex=True, inplace=True)
# 'Email'

# %%
zoho_df.loc[
    (zoho_df['Phone'] == 'empty') & (zoho_df['Mobile'] != 'empty'), 
    'Phone'] = zoho_df['Mobile']
zoho_df.loc[zoho_df['Phone'] == zoho_df['Mobile'],'Mobile'] = 'empty'

# %%
count_deleted_wrong_format = m.delete_email_wrong_format(zoho_df, 'Email')
count_after_deleted_wrong_format = zoho_df.shape[0]

# %%
# hitung jumlah duplicate
count_duplicate_general = zoho_df.loc[zoho_df.duplicated(subset=['Email', 'Phone', 'Lead Brand', 'Lead Sub-Brand', 'Lead Source'])].shape[0]

zoho_df.loc[zoho_df.duplicated(subset=['Email', 'Phone', 'Lead Brand', 'Lead Sub-Brand', 'Lead Source'])]
# Out:
#                        Record Id        Created Time Created Date  \
# 73480   zcrm_3584690000291429172 2021-05-19 03:37:26        empty
# 74694   zcrm_3584690000303257303 2021-08-02 14:39:37        empty
# 74877   zcrm_3584690000308516466 2021-08-15 00:55:34        empty
# 74879   zcrm_3584690000308604454 2021-08-15 01:03:12        empty
# 76247   zcrm_3584690000320897235 2021-10-19 16:46:46        empty
# ...                          ...                 ...          ...
# 224109  zcrm_3584690000465300072 2023-10-15 20:06:22        empty
# 224110  zcrm_3584690000465671001 2023-10-17 20:42:27        empty
# 224111  zcrm_3584690000465788001 2023-10-18 05:29:53        empty
# 224112  zcrm_3584690000465809001 2023-10-18 13:00:39        empty
# 224113  zcrm_3584690000465855001 2023-10-18 14:21:44        empty
#
#           First Name     Last Name                            Email  \
# 73480           DAVE         GREEN                greeners2@sky.com
# 74694        Anthony       Taranto              ldeitch78@gmail.com
# 74877        Charles       Moloney          chasmoloney@hotmail.com
# 74879         gareth        taylor         suntory_time@hotmail.com
# 76247         Dionne         Baker      dionnelouisebaker@gmail.com
# ...              ...           ...                              ...
# 224109      Ruewayne      Rungsamy      ruewayne.rungsamy@gmail.com
# 224110  Abdul Ghafar        Didari           abdul.didari@yahoo.com
# 224111        Kristy      Bartlett       kristyxxbartlett@gmail.com
# 224112   Abdul rahim        Akbari          rahim.gulalai@gmail.com
# 224113    Hermansyah  Budi Prakasa  hermansyahbudiprakasa@gmail.com
#
#                 Phone Mobile   Birthdate Year of Birth  ...  \
# 73480    447732878363  empty       empty         empty  ...
# 74694     61408928323  empty       empty         empty  ...
# 74877    447533947020  empty       empty         empty  ...
# 74879    447817713077  empty       empty         empty  ...
# 76247    447545322250  empty       empty         empty  ...
# ...               ...    ...         ...           ...  ...
# 224109    27615072171  empty  1994-06-13         empty  ...
# 224110    61424344540  empty  1995-07-31         empty  ...
# 224111    61421005474  empty  1978-04-14         empty  ...
# 224112    61406961087  empty  1992-08-02         empty  ...
# 224113  6281369330888  empty  1973-06-23         empty  ...
#
#                                   Lead Source Description Lead Regions  \
# 73480   Gloucestershire Rugby 1873 Business Club 2021-May        empty
# 74694                                Join Full Membership         SEAP
# 74877                                Join Full Membership        empty
# 74879                                Join Full Membership        empty
# 76247   Operation Recuperation 2021-June - Associate F...        empty
# ...                                                   ...          ...
# 224109         KCE | Web | w1aug22 | Redeem PriorityGifts         SEAP
# 224110         KCE | Web | w1aug22 | Redeem PriorityGifts         SEAP
# 224111         KCE | Web | w1aug22 | Redeem PriorityGifts         SEAP
# 224112         KCE | Web | w1aug22 | Redeem PriorityGifts         SEAP
# 224113         KCE | Web | w1aug22 | Redeem PriorityGifts         SEAP
#
#        Lead Status Booking Status BookRef Email Opt Out Opt In GDPR Compliant  \
# 73480        empty          empty   empty         empty  empty          empty
# 74694        empty          empty   empty         empty  empty          empty
# 74877        empty          empty   empty         empty  empty          empty
# 74879        empty          empty   empty         empty  empty          empty
# 76247        empty          empty   empty         empty  empty          empty
# ...            ...            ...     ...           ...    ...            ...
# 224109    New Lead          empty   empty         false  false          false
# 224110    New Lead          empty   empty         false  false          false
# 224111    New Lead          empty   empty         false  false          false
# 224112    New Lead          empty   empty         false  false          false
# 224113    New Lead          empty   empty         false  false          false
#
#        Website Comments
# 73480    empty    empty
# 74694    empty    empty
# 74877    empty    empty
# 74879    empty    empty
# 76247    empty    empty
# ...        ...      ...
# 224109   empty    empty
# 224110   empty    empty
# 224111   empty    empty
# 224112   empty    empty
# 224113   empty    empty
#
# [129736 rows x 34 columns]

# %%
zoho_df.drop_duplicates(subset=['Email', 'Phone', 'Lead Brand', 'Lead Sub-Brand', 'Lead Source'], inplace=True)
zoho_df.reset_index(drop=True, inplace=True)

# hitung jumlah setelah value duplicate dihapus
count_after_dedup_duplicate = zoho_df.shape[0]

zoho_df
# Out:
#                       Record Id        Created Time Created Date First Name  \
# 0      zcrm_3584690000007050147 2019-04-02 05:26:55   2017-01-13      James
# 1      zcrm_3584690000007050148 2019-04-02 05:26:55   2017-11-06     Johnny
# 2      zcrm_3584690000007050149 2019-04-02 05:26:55   2017-11-24    Jessica
# 3      zcrm_3584690000007050150 2019-04-02 05:26:55   2017-05-23      James
# 4      zcrm_3584690000007050151 2019-04-02 05:26:55   2016-02-23       John
# ...                         ...                 ...          ...        ...
# 94373  zcrm_3584690000007311535 2019-04-02 05:42:20   2016-06-13    Michael
# 94374  zcrm_3584690000007311543 2019-04-02 05:42:20   2017-03-15     Pravin
# 94375  zcrm_3584690000097137562 2019-08-16 16:37:55        empty      Peter
# 94376  zcrm_3584690000097184076 2019-08-16 16:42:35        empty       John
# 94377  zcrm_3584690000295093657 2021-06-10 21:20:19        empty         Jj
#
#       Last Name                  Email         Phone       Mobile   Birthdate  \
# 0        Parson  jparsons252@gmail.com   61438662484        empty  1974-01-30
# 1         Miaco     jpas01@outlook.com   61402469987        empty  1981-05-22
# 2        Paulin    jpaulin86@gmail.com   61405440021        empty  1986-09-28
# 3        Boggan   jpboggan@hotmail.com         empty        empty  1975-09-25
# 4          Brad    jpbraid@bigpond.com   61408114721  61895771767  1950-08-10
# ...         ...                    ...           ...          ...         ...
# 94373     Noble                  empty   61401171716        empty       empty
# 94374   K Gupta                  empty  919214342370        empty  1974-04-12
# 94375     Barry  peter_barry@gmail.com         empty        empty       empty
# 94376  Paterson   johnboy669@gmail.com         empty        empty       empty
# 94377        Jj                  empty  447777777777        empty       empty
#
#       Year of Birth  ...                      Lead Source Description  \
# 0              1974  ...                              Sales Deck Bali
# 1              1981  ...                                Internal Form
# 2              1986  ...                                Karma Web App
# 3              1975  ...                                        RUGBY
# 4              1950  ...                                Internal Form
# ...             ...  ...                                          ...
# 94373         empty  ...                                Western Force
# 94374          1974  ...  Sales Deck Cold Line Reception Haathi Mahal
# 94375         empty  ...                                        empty
# 94376         empty  ...                     Healthy Magazine batch 1
# 94377         empty  ...             Operation Recuperation 2021-June
#
#       Lead Regions Lead Status Booking Status BookRef Email Opt Out Opt In  \
# 0             SEAP       empty          empty   empty         empty  empty
# 1             SEAP       empty          empty   empty         empty  empty
# 2             SEAP       empty          empty   empty         empty  empty
# 3             SEAP       empty          empty   empty         empty  empty
# 4             SEAP       empty          empty   empty         empty  empty
# ...            ...         ...            ...     ...           ...    ...
# 94373         SEAP       empty          empty   empty         false  false
# 94374        India       empty          empty   empty         false  false
# 94375        empty    New Lead          empty   empty         false  false
# 94376        empty    New Lead          empty   empty         false  false
# 94377    UK/Europe       empty          empty   empty         false   true
#
#       GDPR Compliant                                            Website  \
# 0              empty                                              empty
# 1              empty                                              empty
# 2              empty                                              empty
# 3              empty                                              empty
# 4              empty                                              empty
# ...              ...                                                ...
# 94373          false                                              empty
# 94374          false                                              empty
# 94375          false                                              empty
# 94376          false  https://www.healthy-magazine.co.uk/competition...
# 94377           true  https://karmaclub.com/associate-membership-nhs...
#
#                                                 Comments
# 0                                                  empty
# 1                                                  empty
# 2                                                  empty
# 3                                                  empty
# 4                                                  empty
# ...                                                  ...
# 94373                                              empty
# 94374                                              empty
# 94375                                     KE3 - database
# 94376  Yes, I agree to my details being shared with K...
# 94377                                              empty
#
# [94378 rows x 34 columns]

# %%
# Cek leads test
test_leads = zoho_df.loc[
    
        zoho_df['Email'].str.contains('^test@', flags=re.I, regex=True) |
        zoho_df['Email'].str.contains('\+test', flags=re.I, regex=True) |
    
        zoho_df['First Name'].str.contains('^test$', flags=re.I, regex=True) |
        zoho_df['Last Name'].str.contains('^test$', flags=re.I, regex=True) |

        zoho_df['First Name'].str.contains('test 1', flags=re.I, regex=True) |
        zoho_df['Last Name'].str.contains('test 2', flags=re.I, regex=True)|
        zoho_df['First Name'].str.contains('test1', flags=re.I, regex=True) |
        zoho_df['Last Name'].str.contains('test2', flags=re.I, regex=True)|

        zoho_df['First Name'].str.contains(' test ', flags=re.I, regex=True) | 
        zoho_df['Last Name'].str.contains(' test ', flags=re.I, regex=True) | 
        zoho_df['Last Name'].str.contains(' test$', flags=re.I, regex=True)
    ]

count_leads_test = test_leads.shape[0]

# test_leads.to_excel(r'C:\Users\fajar\Documents\Python\Data\test_leads_2.xlsx', index=False)
test_leads
# Out:
#                       Record Id        Created Time Created Date   First Name  \
# 13863  zcrm_3584690000007188441 2019-04-02 05:29:43   2015-05-12         Dale
# 73435  zcrm_3584690000207146844 2020-07-25 13:04:28        empty         Test
# 73436  zcrm_3584690000207154430 2020-07-25 12:23:35        empty         Test
# 75706  zcrm_3584690000314632217 2021-09-15 10:12:47        empty         Test
# 76506  zcrm_3584690000331722001 2021-12-15 22:03:45        empty  Andrea Test
# 76727  zcrm_3584690000346049110 2022-02-16 22:33:44        empty         Test
# 76729  zcrm_3584690000346060454 2022-02-17 18:35:23        empty         test
# 76885  zcrm_3584690000406230858 2022-10-24 12:30:13        empty        cendy
# 76903  zcrm_3584690000412082163 2022-11-21 12:26:01        empty    Ivan test
# 77386  zcrm_3584690000463662003 2023-10-04 10:59:21        empty          Bob
#
#                    Last Name  \
# 13863                      M
# 73435  ExclusiveOfferBavaria
# 73436             KClubOffer
# 75706              Rottnest3
# 76506           Pavlidi Test
# 76727                   Test
# 76729                   test
# 76885                   test
# 76903          Oktasiva Test
# 77386                   Bill
#
#                                                    Email           Phone  \
# 13863                                     test@email.com    447814119185
# 73435  wayan.wirka+testexclusiveofferbavaria@karmagro...           empty
# 73436          wayan.wirka+testkcluboffer@karmagroup.com           empty
# 75706                     mike.kelly@education.wa.edu.au   6281916143350
# 76506                     andrea.pavlidis@karmagroup.com           empty
# 76727                                 fantools@gmail.com    491622543381
# 76729                   sunilkumartripathi2007@gmail.com    918971199665
# 76885                      cendy.narendra@karmagroup.com    619442829102
# 76903                       ivan.oktasiva@karmagroup.com  62812345678900
# 77386                                      test@test.com    614111111111
#
#              Mobile   Birthdate Year of Birth  ...  \
# 13863  447814119185       empty          1997  ...
# 73435         empty       empty         empty  ...
# 73436         empty       empty         empty  ...
# 75706         empty       empty         empty  ...
# 76506  306979898735       empty         empty  ...
# 76727         empty       empty         empty  ...
# 76729         empty       empty         empty  ...
# 76885         empty       empty         empty  ...
# 76903         empty       empty         empty  ...
# 77386         empty  1998-10-07         empty  ...
#
#                              Lead Source Description Lead Regions Lead Status  \
# 13863                             WIFI USER ID 19544    UK/Europe       empty
# 73435           Karma Club | Request Exclusive Offer         SEAP       empty
# 73436                 Karma Club | Book Member Offer         SEAP       empty
# 75706                                 Suzy Humphreys         SEAP       empty
# 76506                                     Karma Club    UK/Europe       empty
# 76727  Good Karma 2021-October - Associate FOC Night    UK/Europe       empty
# 76729                                    Veloid Dias        India       empty
# 76885     KCE | Web | w1aug22 | Redeem PriorityGifts         SEAP    New Lead
# 76903     KCE | Web | w1aug22 | Redeem PriorityGifts         SEAP    New Lead
# 77386     KCE | Web | w1aug22 | Redeem PriorityGifts         SEAP    New Lead
#
#       Booking Status BookRef Email Opt Out Opt In GDPR Compliant Website  \
# 13863          empty   empty         empty  empty          empty   empty
# 73435          empty   empty         empty  empty          empty   empty
# 73436          empty   empty         empty  empty          empty   empty
# 75706          empty   empty         empty  empty          empty   empty
# 76506          empty   empty         empty  empty          empty   empty
# 76727          empty   empty         empty  empty          empty   empty
# 76729          empty   empty         empty  empty          empty   empty
# 76885          empty   empty         empty  empty          empty   empty
# 76903          empty   empty         empty  empty          empty   empty
# 77386          empty   empty         empty  empty          empty   empty
#
#       Comments
# 13863    empty
# 73435    empty
# 73436    empty
# 75706    empty
# 76506    empty
# 76727    empty
# 76729    empty
# 76885    empty
# 76903    empty
# 77386    empty
#
# [10 rows x 34 columns]

# %%
zoho_df.drop(test_leads.index, inplace=True)
zoho_df.reset_index(drop=True, inplace=True)

count_after_dedup_test = zoho_df.shape[0]

# %%
# Cek Email OTA
email_OTA = m.find_OTA(zoho_df, 'Email')
count_email_OTA = email_OTA.shape[0]
# email_OTA.to_excel(r'C:\Users\fajar\Documents\Python\Data\email_OTA.xlsx', index=False)

email_OTA
# Out:
#                       Record Id        Created Time Created Date First Name  \
# 4302   zcrm_3584690000007168127 2019-04-02 05:27:45   2016-09-22   Prasanth
# 4660   zcrm_3584690000007168911 2019-04-02 05:27:50   2014-12-22      Ashok
# 7674   zcrm_3584690000007175345 2019-04-02 05:28:26   2016-05-18      Kence
# 7831   zcrm_3584690000007175717 2019-04-02 05:28:29   2016-09-24       Noel
# 8674   zcrm_3584690000007177403 2019-04-02 05:28:38   2014-03-11     Harish
# ...                         ...                 ...          ...        ...
# 69901  zcrm_3584690000007307854 2019-04-02 05:41:57   2016-10-03          P
# 70210  zcrm_3584690000007308485 2019-04-02 05:42:01   2013-08-20     Kirpal
# 70468  zcrm_3584690000007309059 2019-04-02 05:42:05   2016-09-21   Sharmila
# 70921  zcrm_3584690000007310035 2019-04-02 05:42:11   2016-09-24          R
# 76359  zcrm_3584690000323768609 2021-11-06 15:16:00        empty    William
#
#             Last Name                     Email          Phone        Mobile  \
# 4302   C Ramachandran   sails.tourism@gmail.com   919884144855         empty
# 4660            Umale   bakul.tourism@gmail.com   919673929153         empty
# 7674          Georgey   mail@ecotourskerala.com   919446439252         empty
# 7831           Christ   makemytourhsn@yahoo.com   919844888844         empty
# 8674      Chandra Ray    sibsai.tours@gmail.com   919433521412         empty
# ...               ...                       ...            ...           ...
# 69901      Veerakumar     info@tourismsouth.org   919567447950         empty
# 70210           Singh     ostrichtour@gmail.com   911752371886  919781600086
# 70468       K V Kafle  holiday@apoorvatours.com          empty         empty
# 70921       Narayanan  heritagetourss@yahoo.com   919445321234         empty
# 76359         bourget  william.aptour@gmail.com  6281353009603         empty
#
#         Birthdate Year of Birth  ...  \
# 4302   1987-06-08          1987  ...
# 4660   1971-07-01          1971  ...
# 7674   1966-05-28          1966  ...
# 7831   1980-10-27          1980  ...
# 8674   1954-06-05          1954  ...
# ...           ...           ...  ...
# 69901  1974-05-30          1974  ...
# 70210  1976-08-12          1976  ...
# 70468  1981-01-04          1981  ...
# 70921  1964-12-12          1964  ...
# 76359       empty         empty  ...
#
#                            Lead Source Description Lead Regions Lead Status  \
# 4302                                   BHARAT JAIN        India       empty
# 4660                                   BHARAT JAIN        India       empty
# 7674                              Sales Deck India        India       empty
# 7831                                   BHARAT JAIN        India       empty
# 8674                                   BHARAT JAIN        India       empty
# ...                                            ...          ...         ...
# 69901                                  BHARAT JAIN        India       empty
# 70210                                  BHARAT JAIN        India       empty
# 70468                                  BHARAT JAIN         SEAP       empty
# 70921                                  BHARAT JAIN        India       empty
# 76359  Karma Beach VIP 2021-August - Associate PMR         SEAP       empty
#
#       Booking Status BookRef Email Opt Out Opt In GDPR Compliant Website  \
# 4302           empty   empty         empty  empty          empty   empty
# 4660           empty   empty         empty  empty          empty   empty
# 7674           empty   empty         empty  empty          empty   empty
# 7831           empty   empty         empty  empty          empty   empty
# 8674           empty   empty         empty  empty          empty   empty
# ...              ...     ...           ...    ...            ...     ...
# 69901          empty   empty         empty  empty          empty   empty
# 70210          empty   empty         empty  empty          empty   empty
# 70468          empty   empty         empty  empty          empty   empty
# 70921          empty   empty         empty  empty          empty   empty
# 76359          empty   empty         empty  empty          empty   empty
#
#       Comments
# 4302     empty
# 4660     empty
# 7674     empty
# 7831     empty
# 8674     empty
# ...        ...
# 69901    empty
# 70210    empty
# 70468    empty
# 70921    empty
# 76359    empty
#
# [93 rows x 34 columns]

# %%
# delete email OTA
count_after_clean_OTA = m.delete_OTA(zoho_df, 'Email')
# zoho_df.to_excel(r'C:\Users\fajar\Documents\Python\Data\after_clean_OTA.xlsx', index=False)

zoho_df
# Out:
#                       Record Id        Created Time Created Date First Name  \
# 0      zcrm_3584690000007050147 2019-04-02 05:26:55   2017-01-13      James
# 1      zcrm_3584690000007050148 2019-04-02 05:26:55   2017-11-06     Johnny
# 2      zcrm_3584690000007050149 2019-04-02 05:26:55   2017-11-24    Jessica
# 3      zcrm_3584690000007050150 2019-04-02 05:26:55   2017-05-23      James
# 4      zcrm_3584690000007050151 2019-04-02 05:26:55   2016-02-23       John
# ...                         ...                 ...          ...        ...
# 94270  zcrm_3584690000007311535 2019-04-02 05:42:20   2016-06-13    Michael
# 94271  zcrm_3584690000007311543 2019-04-02 05:42:20   2017-03-15     Pravin
# 94272  zcrm_3584690000097137562 2019-08-16 16:37:55        empty      Peter
# 94273  zcrm_3584690000097184076 2019-08-16 16:42:35        empty       John
# 94274  zcrm_3584690000295093657 2021-06-10 21:20:19        empty         Jj
#
#       Last Name                  Email         Phone       Mobile   Birthdate  \
# 0        Parson  jparsons252@gmail.com   61438662484        empty  1974-01-30
# 1         Miaco     jpas01@outlook.com   61402469987        empty  1981-05-22
# 2        Paulin    jpaulin86@gmail.com   61405440021        empty  1986-09-28
# 3        Boggan   jpboggan@hotmail.com         empty        empty  1975-09-25
# 4          Brad    jpbraid@bigpond.com   61408114721  61895771767  1950-08-10
# ...         ...                    ...           ...          ...         ...
# 94270     Noble                  empty   61401171716        empty       empty
# 94271   K Gupta                  empty  919214342370        empty  1974-04-12
# 94272     Barry  peter_barry@gmail.com         empty        empty       empty
# 94273  Paterson   johnboy669@gmail.com         empty        empty       empty
# 94274        Jj                  empty  447777777777        empty       empty
#
#       Year of Birth  ...                      Lead Source Description  \
# 0              1974  ...                              Sales Deck Bali
# 1              1981  ...                                Internal Form
# 2              1986  ...                                Karma Web App
# 3              1975  ...                                        RUGBY
# 4              1950  ...                                Internal Form
# ...             ...  ...                                          ...
# 94270         empty  ...                                Western Force
# 94271          1974  ...  Sales Deck Cold Line Reception Haathi Mahal
# 94272         empty  ...                                        empty
# 94273         empty  ...                     Healthy Magazine batch 1
# 94274         empty  ...             Operation Recuperation 2021-June
#
#       Lead Regions Lead Status Booking Status BookRef Email Opt Out Opt In  \
# 0             SEAP       empty          empty   empty         empty  empty
# 1             SEAP       empty          empty   empty         empty  empty
# 2             SEAP       empty          empty   empty         empty  empty
# 3             SEAP       empty          empty   empty         empty  empty
# 4             SEAP       empty          empty   empty         empty  empty
# ...            ...         ...            ...     ...           ...    ...
# 94270         SEAP       empty          empty   empty         false  false
# 94271        India       empty          empty   empty         false  false
# 94272        empty    New Lead          empty   empty         false  false
# 94273        empty    New Lead          empty   empty         false  false
# 94274    UK/Europe       empty          empty   empty         false   true
#
#       GDPR Compliant                                            Website  \
# 0              empty                                              empty
# 1              empty                                              empty
# 2              empty                                              empty
# 3              empty                                              empty
# 4              empty                                              empty
# ...              ...                                                ...
# 94270          false                                              empty
# 94271          false                                              empty
# 94272          false                                              empty
# 94273          false  https://www.healthy-magazine.co.uk/competition...
# 94274           true  https://karmaclub.com/associate-membership-nhs...
#
#                                                 Comments
# 0                                                  empty
# 1                                                  empty
# 2                                                  empty
# 3                                                  empty
# 4                                                  empty
# ...                                                  ...
# 94270                                              empty
# 94271                                              empty
# 94272                                     KE3 - database
# 94273  Yes, I agree to my details being shared with K...
# 94274                                              empty
#
# [94275 rows x 34 columns]

# %%
# Cek Email Karma
email_karma = m.find_karma(zoho_df, 'Email')
count_email_karma = email_karma.shape[0]
# email_OTA.to_excel(r'C:\Users\fajar\Documents\Python\Data\email_OTA.xlsx', index=False)

email_karma
# Out:
#                       Record Id        Created Time Created Date First Name  \
# 11280  zcrm_3584690000007183001 2019-04-02 05:29:12   2015-07-10      empty
# 14558  zcrm_3584690000007189905 2019-04-02 05:29:52   2017-03-01       Andy
# 28909  zcrm_3584690000007220354 2019-04-02 05:32:54   2016-12-30     Tridip
# 59986  zcrm_3584690000007287056 2019-04-02 05:39:44   2016-05-16          E
# 76720  zcrm_3584690000353117429 2022-03-22 17:21:38        empty  Ekaterina
#
#        Last Name                           Email          Phone       Mobile  \
# 11280      Mirah      mirah@royalperspective.com  8978907897897        empty
# 14558     Keegan        andyk@thebaligetaway.com   628113863845  61401223323
# 28909   Banerjee         tridip.banerjee@rci.com   919845058405        empty
# 59986          K      eka@33royalperspective.com       81928282    819293838
# 76720  Khalikova  concierge.europe@karmaclub.com    79851463599        empty
#
#         Birthdate Year of Birth  ... Lead Source Description Lead Regions  \
# 11280       empty         empty  ...            Website form         SEAP
# 14558  1986-07-06          1986  ...    Karma Club Join Form         SEAP
# 28909  1975-10-01          1975  ...                   PALMS        India
# 59986  2016-05-01          2016  ...           Karma Bavaria         SEAP
# 76720       empty         empty  ...         Andrea Pavlidis    UK/Europe
#
#       Lead Status Booking Status BookRef Email Opt Out Opt In GDPR Compliant  \
# 11280       empty          empty   empty         empty  empty          empty
# 14558       empty          empty   empty         empty  empty          empty
# 28909       empty          empty   empty         empty  empty          empty
# 59986       empty          empty   empty         empty  empty          empty
# 76720       empty          empty   empty         empty  empty          empty
#
#       Website Comments
# 11280   empty    empty
# 14558   empty    empty
# 28909   empty    empty
# 59986   empty    empty
# 76720   empty    empty
#
# [5 rows x 34 columns]

# %%
# delete email Karma
count_after_clean_karma = m.delete_karma(zoho_df, 'Email')
# zoho_df.to_excel(r'C:\Users\fajar\Documents\Python\Data\after_clean_OTA.xlsx', index=False)

zoho_df
# Out:
#                       Record Id        Created Time Created Date First Name  \
# 0      zcrm_3584690000007050147 2019-04-02 05:26:55   2017-01-13      James
# 1      zcrm_3584690000007050148 2019-04-02 05:26:55   2017-11-06     Johnny
# 2      zcrm_3584690000007050149 2019-04-02 05:26:55   2017-11-24    Jessica
# 3      zcrm_3584690000007050150 2019-04-02 05:26:55   2017-05-23      James
# 4      zcrm_3584690000007050151 2019-04-02 05:26:55   2016-02-23       John
# ...                         ...                 ...          ...        ...
# 94265  zcrm_3584690000007311535 2019-04-02 05:42:20   2016-06-13    Michael
# 94266  zcrm_3584690000007311543 2019-04-02 05:42:20   2017-03-15     Pravin
# 94267  zcrm_3584690000097137562 2019-08-16 16:37:55        empty      Peter
# 94268  zcrm_3584690000097184076 2019-08-16 16:42:35        empty       John
# 94269  zcrm_3584690000295093657 2021-06-10 21:20:19        empty         Jj
#
#       Last Name                  Email         Phone       Mobile   Birthdate  \
# 0        Parson  jparsons252@gmail.com   61438662484        empty  1974-01-30
# 1         Miaco     jpas01@outlook.com   61402469987        empty  1981-05-22
# 2        Paulin    jpaulin86@gmail.com   61405440021        empty  1986-09-28
# 3        Boggan   jpboggan@hotmail.com         empty        empty  1975-09-25
# 4          Brad    jpbraid@bigpond.com   61408114721  61895771767  1950-08-10
# ...         ...                    ...           ...          ...         ...
# 94265     Noble                  empty   61401171716        empty       empty
# 94266   K Gupta                  empty  919214342370        empty  1974-04-12
# 94267     Barry  peter_barry@gmail.com         empty        empty       empty
# 94268  Paterson   johnboy669@gmail.com         empty        empty       empty
# 94269        Jj                  empty  447777777777        empty       empty
#
#       Year of Birth  ...                      Lead Source Description  \
# 0              1974  ...                              Sales Deck Bali
# 1              1981  ...                                Internal Form
# 2              1986  ...                                Karma Web App
# 3              1975  ...                                        RUGBY
# 4              1950  ...                                Internal Form
# ...             ...  ...                                          ...
# 94265         empty  ...                                Western Force
# 94266          1974  ...  Sales Deck Cold Line Reception Haathi Mahal
# 94267         empty  ...                                        empty
# 94268         empty  ...                     Healthy Magazine batch 1
# 94269         empty  ...             Operation Recuperation 2021-June
#
#       Lead Regions Lead Status Booking Status BookRef Email Opt Out Opt In  \
# 0             SEAP       empty          empty   empty         empty  empty
# 1             SEAP       empty          empty   empty         empty  empty
# 2             SEAP       empty          empty   empty         empty  empty
# 3             SEAP       empty          empty   empty         empty  empty
# 4             SEAP       empty          empty   empty         empty  empty
# ...            ...         ...            ...     ...           ...    ...
# 94265         SEAP       empty          empty   empty         false  false
# 94266        India       empty          empty   empty         false  false
# 94267        empty    New Lead          empty   empty         false  false
# 94268        empty    New Lead          empty   empty         false  false
# 94269    UK/Europe       empty          empty   empty         false   true
#
#       GDPR Compliant                                            Website  \
# 0              empty                                              empty
# 1              empty                                              empty
# 2              empty                                              empty
# 3              empty                                              empty
# 4              empty                                              empty
# ...              ...                                                ...
# 94265          false                                              empty
# 94266          false                                              empty
# 94267          false                                              empty
# 94268          false  https://www.healthy-magazine.co.uk/competition...
# 94269           true  https://karmaclub.com/associate-membership-nhs...
#
#                                                 Comments
# 0                                                  empty
# 1                                                  empty
# 2                                                  empty
# 3                                                  empty
# 4                                                  empty
# ...                                                  ...
# 94265                                              empty
# 94266                                              empty
# 94267                                     KE3 - database
# 94268  Yes, I agree to my details being shared with K...
# 94269                                              empty
#
# [94270 rows x 34 columns]

# %%
find_member_booking = zoho_df.copy()

find_member_booking.loc[find_member_booking['Phone'].isin(df_booking['Phone1']), 'Same Value Find'] = 'Booking-Phone1'
find_member_booking.loc[find_member_booking['Phone'].isin(df_booking['Mobile']), 'Same Value Find'] = 'Booking-Mobile'
find_member_booking.loc[find_member_booking['Mobile'].isin(df_booking['Phone1']), 'Same Value Find'] = 'Booking-Phone1' 
find_member_booking.loc[find_member_booking['Mobile'].isin(df_booking['Mobile']), 'Same Value Find'] = 'Booking-Mobile'
find_member_booking.loc[find_member_booking['Email'].isin(df_booking['Email']), 'Same Value Find'] = 'Booking-Email'

find_member_booking.loc[find_member_booking['Phone'].isin(df_phone['Mobile']), 'Same Value Find'] = 'Member-Mobile' 
find_member_booking.loc[find_member_booking['Mobile'].isin(df_phone['Mobile']), 'Same Value Find'] = 'Member-Mobile'

find_member_booking.loc[find_member_booking['Email'].isin(df_email['Email']), 'Same Value Find'] = 'Member-Email'

find_member_booking.drop(find_member_booking.loc[find_member_booking['Same Value Find'].isna()].index, inplace=True)

count_booking_dedup = find_member_booking.loc[find_member_booking['Same Value Find'].str.contains('Booking', flags=re.I, regex=True)].shape[0]
count_member_dedup = find_member_booking.loc[find_member_booking['Same Value Find'].str.contains('Member', flags=re.I, regex=True)].shape[0]

find_member_booking.replace('empty', '', inplace=True)
# find_member_booking.to_csv(r'C:\Users\fajar\Documents\Python\Data\booking-member-dedup.csv', index=False)
# find_member_booking.to_excel(r'C:\Users\fajar\Documents\Python\Data\booking-member-dedup.xlsx', index=False)

#find_member_booking.loc[find_member_booking['Same Value Find'] == 'Booking-Phone1']

# %%
# data phone, mobile dam email member yang ada di master data 
count_wash_member = zoho_df.loc[
    zoho_df['Phone'].isin(df_booking['Phone1']) | 
    zoho_df['Phone'].isin(df_booking['Mobile']) |
    zoho_df['Mobile'].isin(df_booking['Phone1']) | 
    zoho_df['Mobile'].isin(df_booking['Mobile']) |
    zoho_df['Email'].isin(df_booking['Email'])| 

    zoho_df['Phone'].isin(df_phone['Mobile']) | 
    zoho_df['Mobile'].isin(df_phone['Mobile']) |

    zoho_df['Email'].isin(df_email['Email'])

].shape[0]

zoho_df.drop(zoho_df.loc[
    zoho_df['Phone'].isin(df_booking['Phone1']) | 
    zoho_df['Phone'].isin(df_booking['Mobile']) |
    zoho_df['Mobile'].isin(df_booking['Phone1']) | 
    zoho_df['Mobile'].isin(df_booking['Mobile']) |
    zoho_df['Email'].isin(df_booking['Email']) |
    
    zoho_df['Phone'].isin(df_phone['Mobile']) | 
    zoho_df['Mobile'].isin(df_phone['Mobile']) |

    zoho_df['Email'].isin(df_email['Email'])

    ].index, inplace=True)
    
zoho_df.reset_index(drop=True, inplace=True)

count_after_wash_member = zoho_df.shape[0]

# %%
# Categorize contacts
m.categorize_contacts(zoho_df)

# Count contact types
count_email_only = (zoho_df['Contact Type'] == 'Email Only').sum()
count_phone_only = (zoho_df['Contact Type'] == 'Phone Only').sum()
count_email_and_phone = (zoho_df['Contact Type'] == 'Email and Phone').sum()
count_blank = (zoho_df['Contact Type'] == 'Blank').sum()

# Remove blank contacts if needed
zoho_df = zoho_df[zoho_df['Contact Type'] != 'Blank']
zoho_df.reset_index(drop=True, inplace=True)

count_after_wash_blank = zoho_df.shape[0]

# %%
arr_dedup = [count_deleted_wrong_format, count_duplicate_general, count_leads_test, count_email_OTA, count_email_karma, count_blank]
count_sum_dedup = sum(arr_dedup)
count_sum_dedup
# Out:
# np.int64(129844)

# %%
print("==========================================================")
print("Summary")
print("==========================================================")
print("Jumlah Keseluruhan Master Zoho : "+str(count_data_awal))
print("Jumlah Filter Leads Awal : "+str(count_filter_awal))
print("Jumlah Format Email Salah : "+str(count_deleted_wrong_format))
print("Jumlah Setelah Clean Format Email Salah : "+str(count_after_deleted_wrong_format))
print("Jumlah Duplicate (Phone, Mobile dan Email) : "+str(count_duplicate_general))
print("Jumlah Setelah Clean Duplicate : "+str(count_after_dedup_duplicate))
print("Jumlah Lead Test : "+str(count_leads_test))
print("Jumlah Setelah Clean Lead Test : "+str(count_after_dedup_test))
# print("Jumlah Lead Do Not Mail : "+str(count_dnm))
# print("Jumlah Setelah Clean Lead Do Not Mail : "+str(count_after_dedup_dnm))
print("Jumlah Email OTA : "+str(count_email_OTA))
print("Jumlah Setelah Clean Email OTA : "+str(count_after_clean_OTA))
print("Jumlah Email Karma : "+str(count_email_karma))
print("Jumlah Setelah Clean Email Karma : "+str(count_after_clean_karma))
print("Jumlah Wash Member : "+str(count_member_dedup))
print("Jumlah Wash Booking : "+str(count_booking_dedup))
print("Jumlah Setelah Wash Member : "+str(count_after_wash_member))
print("Jumlah Phone Email Blank (Setelah phone yang tidak valid dihapus) : "+str(count_blank))
print("Jumlah Setelah Wash Phone Email Blank : "+str(count_after_wash_blank))
print("==========================================================")
print("Contact Type")
print("==========================================================")
print("Jumlah Email Only : "+str(count_email_only))
print("Jumlah Phone Only : "+str(count_phone_only))
print("Jumlah Email dan Phone : "+str(count_email_and_phone))
# Out:
# ==========================================================
# Summary
# ==========================================================
# Jumlah Keseluruhan Master Zoho : 15139909
# Jumlah Filter Leads Awal : 224114
# Jumlah Format Email Salah : 0
# Jumlah Setelah Clean Format Email Salah : 224114
# Jumlah Duplicate (Phone, Mobile dan Email) : 129736
# Jumlah Setelah Clean Duplicate : 94378
# Jumlah Lead Test : 10
# Jumlah Setelah Clean Lead Test : 94368
# Jumlah Email OTA : 93
# Jumlah Setelah Clean Email OTA : 94275
# Jumlah Email Karma : 5
# Jumlah Setelah Clean Email Karma : 94270
# Jumlah Wash Member : 7906
# Jumlah Wash Booking : 800
# Jumlah Setelah Wash Member : 85564
# Jumlah Phone Email Blank (Setelah phone yang tidak valid dihapus) : 0
# Jumlah Setelah Wash Phone Email Blank : 85564
# ==========================================================
# Contact Type
# ==========================================================
# Jumlah Email Only : 3784
# Jumlah Phone Only : 16463
# Jumlah Email dan Phone : 65317

# %%
print("==========================================================")
print("Summary Report")
print("==========================================================")
print("Jumlah Data Awal : "+str(count_filter_awal))
print("Jumlah Wash Dedup : "+str(count_sum_dedup))
print("Jumlah Wash Member : "+str(count_member_dedup))
print("Jumlah Wash Booking : "+str(count_booking_dedup))
print("Jumlah Data Akhir : "+str(count_after_wash_blank))
# Out:
# ==========================================================
# Summary Report
# ==========================================================
# Jumlah Data Awal : 224114
# Jumlah Wash Dedup : 129844
# Jumlah Wash Member : 7906
# Jumlah Wash Booking : 800
# Jumlah Data Akhir : 85564

# %%
zoho_df['First Name'] = zoho_df['First Name'].str.title()
zoho_df['Last Name'] = zoho_df['Last Name'].str.title()
zoho_df.replace('empty', '', inplace=True, regex=True)

zoho_df
# Out:
#                       Record Id        Created Time Created Date First Name  \
# 0      zcrm_3584690000007050147 2019-04-02 05:26:55   2017-01-13      James
# 1      zcrm_3584690000007050148 2019-04-02 05:26:55   2017-11-06     Johnny
# 2      zcrm_3584690000007050149 2019-04-02 05:26:55   2017-11-24    Jessica
# 3      zcrm_3584690000007050150 2019-04-02 05:26:55   2017-05-23      James
# 4      zcrm_3584690000007050151 2019-04-02 05:26:55   2016-02-23       John
# ...                         ...                 ...          ...        ...
# 85559  zcrm_3584690000007311535 2019-04-02 05:42:20   2016-06-13    Michael
# 85560  zcrm_3584690000007311543 2019-04-02 05:42:20   2017-03-15     Pravin
# 85561  zcrm_3584690000097137562 2019-08-16 16:37:55                   Peter
# 85562  zcrm_3584690000097184076 2019-08-16 16:42:35                    John
# 85563  zcrm_3584690000295093657 2021-06-10 21:20:19                      Jj
#
#       Last Name                  Email         Phone       Mobile   Birthdate  \
# 0        Parson  jparsons252@gmail.com   61438662484               1974-01-30
# 1         Miaco     jpas01@outlook.com   61402469987               1981-05-22
# 2        Paulin    jpaulin86@gmail.com   61405440021               1986-09-28
# 3        Boggan   jpboggan@hotmail.com                             1975-09-25
# 4          Brad    jpbraid@bigpond.com   61408114721  61895771767  1950-08-10
# ...         ...                    ...           ...          ...         ...
# 85559     Noble                          61401171716
# 85560   K Gupta                         919214342370               1974-04-12
# 85561     Barry  peter_barry@gmail.com
# 85562  Paterson   johnboy669@gmail.com
# 85563        Jj                         447777777777
#
#       Year of Birth  ... Lead Regions Lead Status Booking Status BookRef  \
# 0              1974  ...         SEAP
# 1              1981  ...         SEAP
# 2              1986  ...         SEAP
# 3              1975  ...         SEAP
# 4              1950  ...         SEAP
# ...             ...  ...          ...         ...            ...     ...
# 85559                ...         SEAP
# 85560          1974  ...        India
# 85561                ...                 New Lead
# 85562                ...                 New Lead
# 85563                ...    UK/Europe
#
#       Email Opt Out Opt In GDPR Compliant  \
# 0
# 1
# 2
# 3
# 4
# ...             ...    ...            ...
# 85559         false  false          false
# 85560         false  false          false
# 85561         false  false          false
# 85562         false  false          false
# 85563         false   true           true
#
#                                                  Website  \
# 0
# 1
# 2
# 3
# 4
# ...                                                  ...
# 85559
# 85560
# 85561
# 85562  https://www.healthy-magazine.co.uk/competition...
# 85563  https://karmaclub.com/associate-membership-nhs...
#
#                                                 Comments     Contact Type
# 0                                                         Email and Phone
# 1                                                         Email and Phone
# 2                                                         Email and Phone
# 3                                                              Email Only
# 4                                                         Email and Phone
# ...                                                  ...              ...
# 85559                                                          Phone Only
# 85560                                                          Phone Only
# 85561                                     KE3 - database       Email Only
# 85562  Yes, I agree to my details being shared with K...       Email Only
# 85563                                                          Phone Only
#
# [85564 rows x 35 columns]

# %%
if (zoho_df.shape[0]>20000):

    row_split = 200000
    file_name = search_value

    m.split_file(zoho_df, row_split, file_name, file_type, target_location)
else:
    zoho_df.to_excel(target_location+'\\'+search_value+"."+file_type, index=False)
