# %%
import main_module as m
import zoho_filter_module as fil
import pandas as pd
import re
import numpy as np

# %load_ext autoreload
# %autoreload 2

dir_path = r'C:\Users\fajar\Documents\Python\Data\Zoho_Backup\2020-2024\\'
dir_path_live = r'C:\Users\fajar\Documents\Python\Data\Zoho_Backup\\'
dir_path_old = r'C:\Users\fajar\Documents\Python\Data\Zoho_Backup\old\\'
file_name = '\Leads_'

cols = ['Record Id',	
'Created Time',
'Created Date',	
'First Name',	
'Last Name',	
'Email',	
'Phone',	
'Mobile',	
'Birthdate',	
'Year of Birth',
'Street',	
'Street2',	
'City',	
'State',	
'Country',	
'Nationality',
'Booking Status', 
'BookRef',
'Departure Date',	
'Arrival Date',	
'Card Type',	
'Marital Status',	
'Lead Brand',	
'Lead Sub-Brand',	
'Lead Source',	
'Lead Locations',	
'Lead Source Description',	
'Lead Regions',
'Lead Status',
'Email Opt Out',	
'Opt In',
'GDPR Compliant',
'Website',
'Comments']

# %%
column_name = 'Lead Brand'
search_value = 'Karma Resorts'

target_location = r'C:\Users\fajar\Documents\Python\Data'
file_type = 'xlsx'

# %%
path = dir_path+'\\backup.csv'
df_all = pd.read_csv(path, dtype='string', on_bad_lines='skip')
df_all.drop(df_all.loc[df_all['Created Time'].str.len() < 5 ].index, inplace=True)
df_all.reset_index(drop=True, inplace=True)

df_all['Created Time'] = pd.to_datetime(df_all['Created Time'], format='%Y-%m-%d %H:%M:%S')

df_all.shape[0]
df_all
# Out:
#                         Record Id        Created Time Created Date First Name  \
# 0        zcrm_3584690000000404058 2019-01-07 15:08:38   2019-01-06   Nicholas
# 1        zcrm_3584690000000404059 2019-01-07 15:08:38   2019-01-06       Liao
# 2        zcrm_3584690000000404060 2019-01-07 15:08:38   2019-01-06    Vedanta
# 3        zcrm_3584690000000404065 2019-01-07 15:08:38   2019-01-06      Aidai
# 4        zcrm_3584690000000404068 2019-01-07 15:08:38   2019-01-06      Ardra
# ...                           ...                 ...          ...        ...
# 9965978  zcrm_3584690000489266005 2024-03-25 16:19:45         <NA>      Keval
# 9965979  zcrm_3584690000489266034 2024-03-25 16:19:51         <NA>     Suresh
# 9965980  zcrm_3584690000489266063 2024-03-25 17:29:27         <NA>     Nathan
# 9965981  zcrm_3584690000489269015 2024-03-25 16:20:25         <NA>    Leonora
# 9965982  zcrm_3584690000489271002 2024-03-25 18:40:17         <NA>       Annu
#
#           Last Name                                 Email           Phone  \
# 0              Wood            1230woodnicholas@gmail.com     61438600845
# 1              Yuan                      158066546@qq.com   8618718399923
# 2          Abhiyoga            abhiyoga.vedanta@gmail.com   6282146524550
# 3         Atakanova                aidai.nurbek@gmail.com    996779641590
# 4             Ardra            aliefardraqariru@gmail.com  +6282139300818
# ...             ...                                   ...             ...
# 9965978        Gala                   keval2403@gmail.com   +919022872972
# 9965979      Shroff  sureshshroff@breachcandyhospital.org   +919819533303
# 9965980   Fernandes       nathan.fernandes@karmagroup.com  +9179724486854
# 9965981     Hackman                leonora_hf@bigpond.com    +61439855115
# 9965982  Shriwastav          annusrivastava1990@gmail.com   +919561074124
#
#                  Mobile   Birthdate Year of Birth  ...         Arrival Date  \
# 0                  <NA>        <NA>          <NA>  ...  2019-01-06 00:00:00
# 1                  <NA>        <NA>          <NA>  ...  2019-01-06 00:00:00
# 2                  <NA>  2000-07-05          2000  ...  2018-12-01 00:00:00
# 3                  <NA>  1997-02-05          1997  ...  2019-01-06 00:00:00
# 4        +6282139300818  2005-01-20          2005  ...  2018-11-30 00:00:00
# ...                 ...         ...           ...  ...                  ...
# 9965978   +917700904802        <NA>          <NA>  ...           2024-03-21
# 9965979   +919819814280        <NA>          <NA>  ...           2024-03-21
# 9965980            <NA>        <NA>          <NA>  ...                 <NA>
# 9965981            <NA>        <NA>          <NA>  ...           2024-03-14
# 9965982            <NA>        <NA>          <NA>  ...                 <NA>
#
#         Card Type Marital Status           Lead Brand   Lead Sub-Brand  \
# 0            <NA>           <NA>  Timeshare Marketing    Other Bali DB
# 1            <NA>           <NA>  Timeshare Marketing    Other Bali DB
# 2            <NA>        Pelajar  Timeshare Marketing    Other Bali DB
# 3            <NA>         Single  Timeshare Marketing    Other Bali DB
# 4            <NA>          OTHER  Timeshare Marketing    Other Bali DB
# ...           ...            ...                  ...              ...
# 9965978      <NA>           <NA>        Karma Resorts            Other
# 9965979      <NA>           <NA>        Karma Resorts            Other
# 9965980      <NA>           <NA>          Karma Group  Karma Community
# 9965981      <NA>           <NA>        Karma Resorts            Other
# 9965982      <NA>           <NA>  Timeshare Marketing            Other
#
#          Lead Source           Lead Locations  \
# 0               Wifi              Purple Wifi
# 1               Wifi              Purple Wifi
# 2               Wifi              Purple Wifi
# 3               Wifi              Purple Wifi
# 4               Wifi              Purple Wifi
# ...              ...                      ...
# 9965978  Past Guests        Karma Royal Palms
# 9965979  Past Guests  Karma Sitabani, Corbett
# 9965980         Quiz                     <NA>
# 9965981  Past Guests           Karma Jimbaran
# 9965982  Web Enquiry           Karma Sitabani
#
#                                    Lead Source Description Lead Regions  \
# 0                                                     <NA>         SEAP
# 1                                                     <NA>        Other
# 2                                                     <NA>         SEAP
# 3                                                     <NA>    UK/Europe
# 4                                    WIFI USER ID 13494142         SEAP
# ...                                                    ...          ...
# 9965978                                          Viewpoint         <NA>
# 9965979                                          Viewpoint         <NA>
# 9965980  Karma Community | Edition 218 - Words to the Wise        India
# 9965981                                          Viewpoint         <NA>
# 9965982                          Timeshare Booking Request        India
#
#         Lead Status
# 0          New Lead
# 1          New Lead
# 2          New Lead
# 3          New Lead
# 4          New Lead
# ...             ...
# 9965978        <NA>
# 9965979        <NA>
# 9965980        <NA>
# 9965981        <NA>
# 9965982        <NA>
#
# [9965983 rows x 27 columns]

# %%
df_old = m.load_data_multiple(dir_path_old, file_name, cols)
df_old = df_old.reindex(columns=cols)
df_old.shape[0]

df_old['Created Time'] = pd.to_datetime(df_old['Created Time'], format='%Y-%m-%d %H:%M:%S')
df_old['Arrival Date'] = pd.to_datetime(df_old['Arrival Date'], format='%Y-%m-%d')
df_old['Departure Date'] = pd.to_datetime(df_old['Departure Date'], format='%Y-%m-%d')
# fungsi errors cource untuk menhindari error jika value data date null atau kosong
# df['Birthdate'] = pd.to_datetime(df['Birthdate'], format='%Y-%m-%d', errors='coerce')
df_old.dtypes
df_old
# Out:
#                         Record Id        Created Time Created Date First Name  \
# 0        zcrm_3584690000000404058 2019-01-07 15:08:38   2019-01-06   Nicholas
# 1        zcrm_3584690000000404059 2019-01-07 15:08:38   2019-01-06       Liao
# 2        zcrm_3584690000000404060 2019-01-07 15:08:38   2019-01-06    Vedanta
# 3        zcrm_3584690000000404065 2019-01-07 15:08:38   2019-01-06      Aidai
# 4        zcrm_3584690000000404068 2019-01-07 15:08:38   2019-01-06      Ardra
# ...                           ...                 ...          ...        ...
# 4717718  zcrm_3584690000475135007 2024-01-01 18:16:02         <NA>    Upendra
# 4717719  zcrm_3584690000475135045 2024-01-01 18:16:37         <NA>      Mehul
# 4717720  zcrm_3584690000475136005 2024-01-01 18:17:13         <NA>      swati
# 4717721  zcrm_3584690000475138034 2024-01-01 18:48:36         <NA>      SUMON
# 4717722  zcrm_3584690000475138069 2024-01-01 18:52:24         <NA>      Rohit
#
#          Last Name                       Email           Phone  \
# 0             Wood  1230woodnicholas@gmail.com    +61438600845
# 1             Yuan            158066546@qq.com   8618718399923
# 2         Abhiyoga  abhiyoga.vedanta@gmail.com  +6282146524550
# 3        Atakanova      aidai.nurbek@gmail.com    996779641590
# 4            Ardra  aliefardraqariru@gmail.com  +6282139300818
# ...            ...                         ...             ...
# 4717718     Mishra       upendra.sir@gmail.com   +919036084550
# 4717719  Prajapati     mehul.m111985@gmail.com   +919714713689
# 4717720   agarwala         cswatiadv@gmail.com   +919733055636
# 4717721      SAHOO        sumonsahoo@gmail.com   +918910484814
# 4717722      Kadam      rohit0918.rk@gmail.com   +919819185446
#
#                  Mobile   Birthdate Year of Birth  ...   Lead Source  \
# 0                  <NA>        <NA>          <NA>  ...          Wifi
# 1                  <NA>        <NA>          <NA>  ...          Wifi
# 2                  <NA>  2000-07-05          2000  ...          Wifi
# 3                  <NA>  1997-02-05          1997  ...          Wifi
# 4        +6282139300818  2005-01-20          2005  ...          Wifi
# ...                 ...         ...           ...  ...           ...
# 4717718            <NA>        <NA>          <NA>  ...   Web Enquiry
# 4717719            <NA>        <NA>          <NA>  ...  Facebook Ads
# 4717720            <NA>        <NA>          <NA>  ...  Facebook Ads
# 4717721            <NA>        <NA>          <NA>  ...  Facebook Ads
# 4717722            <NA>        <NA>          <NA>  ...  Facebook Ads
#
#                  Lead Locations      Lead Source Description Lead Regions  \
# 0                          <NA>                  Purple Wifi         SEAP
# 1                          <NA>                  Purple Wifi        Other
# 2                          <NA>                  Purple Wifi         SEAP
# 3                          <NA>                  Purple Wifi    UK/Europe
# 4                       Mall 21                  Purple Wifi         SEAP
# ...                         ...                          ...          ...
# 4717718  Karma Sunshine Village    Timeshare Booking Request        India
# 4717719                 General  IND | FB MF | Lead captured         <NA>
# 4717720            Karma Martam         IND | FB MF | Martam         <NA>
# 4717721            Karma Martam         IND | FB MF | Martam         <NA>
# 4717722             Royal Palms            IND | FB AF | KRP         <NA>
#
#         Lead Status Email Opt Out Opt In GDPR Compliant  \
# 0          New Lead         false  false          false
# 1          New Lead         false  false          false
# 2          New Lead         false  false          false
# 3          New Lead         false  false          false
# 4          New Lead         false  false          false
# ...             ...           ...    ...            ...
# 4717718        <NA>         false   true           true
# 4717719        <NA>         false  false          false
# 4717720        <NA>         false  false          false
# 4717721        <NA>         false  false          false
# 4717722        <NA>         false  false          false
#
#                                                    Website Comments
# 0                                                     <NA>     <NA>
# 1                                                     <NA>     <NA>
# 2                                                     <NA>     <NA>
# 3                                                     <NA>     <NA>
# 4                                                     <NA>     <NA>
# ...                                                    ...      ...
# 4717718  https://karmagroup.com/find-destination/karma-...     <NA>
# 4717719                                               <NA>     <NA>
# 4717720                                               <NA>     <NA>
# 4717721                                               <NA>     <NA>
# 4717722                                               <NA>     <NA>
#
# [4717723 rows x 34 columns]

# %%
df_live = m.load_data_multiple(dir_path_live, file_name, cols)
df_live = df_live.reindex(columns=cols)
df_live.shape[0]

df_live['Created Time'] = pd.to_datetime(df_live['Created Time'], format='%Y-%m-%d %H:%M:%S')
df_live['Arrival Date'] = pd.to_datetime(df_live['Arrival Date'], format='%Y-%m-%d')
df_live['Departure Date'] = pd.to_datetime(df_live['Departure Date'], format='%Y-%m-%d')
# fungsi errors cource untuk menhindari error jika value data date null atau kosong
# df['Birthdate'] = pd.to_datetime(df['Birthdate'], format='%Y-%m-%d', errors='coerce')
df_live.dtypes
df_live
# Out:
#                        Record Id        Created Time Created Date First Name  \
# 0       zcrm_3584690000000404602 2019-01-08 11:07:28   2021-07-21   Frederic
# 1       zcrm_3584690000000450071 2019-01-08 16:38:18         <NA>  Sebastian
# 2       zcrm_3584690000000450087 2019-01-08 16:38:18         <NA>    Siobhan
# 3       zcrm_3584690000000450106 2019-01-08 16:38:18         <NA>       Lisa
# 4       zcrm_3584690000000450109 2019-01-08 16:38:18         <NA>  Ana Maria
# ...                          ...                 ...          ...        ...
# 456198  zcrm_3584690000502118035 2024-07-15 17:01:09         <NA>          P
# 456199  zcrm_3584690000502118068 2024-07-15 17:42:29         <NA>    Stephan
# 456200  zcrm_3584690000502119001 2024-07-15 16:34:56         <NA>      Alvin
# 456201  zcrm_3584690000502121002 2024-07-15 17:01:02         <NA>      Quyen
# 456202  zcrm_3584690000502124001 2024-07-15 17:36:44   2024-07-15       <NA>
#
#         Last Name                        Email           Phone         Mobile  \
# 0           Bonin    fredericbonin79@gmail.com  +6281236100502           <NA>
# 1            Rach                         <NA>   +498914342111           <NA>
# 2       Gallagher  gallaghersiobhan@eircom.net    353879597603           <NA>
# 3       Ferkovich         lisajo2009@yahoo.com     14062394749           <NA>
# 4        Weileder     m.weileder@sonnenlink.de     15253234700           <NA>
# ...           ...                          ...             ...            ...
# 456198   M BHADRE           pmbhadre@gmail.com            <NA>           <NA>
# 456199    Joachim          joastephan@yahoo.de   +491621791259           <NA>
# 456200   Cabautan     alvin.cabautan@gmail.com   +610416159756  +610416159756
# 456201     Martin         cindykim10@yahoo.com    +61421235687           <NA>
# 456202   Jen Clay        jenclay22@hotmail.com   +971582433297           <NA>
#
#          Birthdate Year of Birth  ...  Lead Source    Lead Locations  \
# 0       1981-10-03          1981  ...       Agency     Karma Kandara
# 1       1982-04-20          1982  ...  Past Guests     Karma Bavaria
# 2       1973-03-14          1973  ...  Past Guests     Karma Bavaria
# 3       1963-07-08          1963  ...  Past Guests     Karma Bavaria
# 4             <NA>          <NA>  ...        Other     Karma Bavaria
# ...            ...           ...  ...          ...               ...
# 456198        <NA>          <NA>  ...      Webchat              <NA>
# 456199        <NA>          <NA>  ...  Web Enquiry              <NA>
# 456200        <NA>          <NA>  ...  Web Enquiry           General
# 456201        <NA>          <NA>  ...  Web Enquiry   Karma Song Hoai
# 456202        <NA>          <NA>  ...  Web Enquiry  Karma La Herriza
#
#                                   Lead Source Description Lead Regions  \
# 0                                                   KAREN         SEAP
# 1                                                    <NA>    UK/Europe
# 2                                                    <NA>    UK/Europe
# 3                                                    <NA>    UK/Europe
# 4                         MICE Contacts from Ioanna email    UK/Europe
# ...                                                   ...          ...
# 456198               Karma Experience India | Webchat Web        India
# 456199                                    Form Contact Us    UK/Europe
# 456200                       KE | Web | Newsletter Footer         SEAP
# 456201                          Timeshare Booking Request         SEAP
# 456202  Karma La Herriza - Download Wedding Brochure a...  Middle East
#
#           Lead Status Email Opt Out Opt In GDPR Compliant  \
# 0            New Lead         false  false          false
# 1            New Lead          true  false          false
# 2            New Lead         false   true           true
# 3            New Lead          true  false          false
# 4            New Lead         false   true           true
# ...               ...           ...    ...            ...
# 456198           <NA>         false   true          false
# 456199           <NA>         false   true           true
# 456200  Not Qualified         false  false          false
# 456201           <NA>         false   true           true
# 456202           <NA>         false   true          false
#
#                                                   Website Comments
# 0                                                    <NA>     <NA>
# 1                                                    <NA>     <NA>
# 2                                                    <NA>     <NA>
# 3                                                    <NA>     <NA>
# 4                                                    <NA>     <NA>
# ...                                                   ...      ...
# 456198               https://karmagroup.com/member-login/     <NA>
# 456199                 https://karmagroup.com/contact-us/     <NA>
# 456200                   https://www.karmaexperience.com/     <NA>
# 456201                            https://karmagroup.com/     <NA>
# 456202  https://karmagroup.com/weddings-at-karma-la-he...     <NA>
#
# [456203 rows x 34 columns]

# %%
df = pd.concat([df_all,df_old,df_live])
count_data_awal = df.shape[0]
df
# Out:
#                        Record Id        Created Time Created Date First Name  \
# 0       zcrm_3584690000000404058 2019-01-07 15:08:38   2019-01-06   Nicholas
# 1       zcrm_3584690000000404059 2019-01-07 15:08:38   2019-01-06       Liao
# 2       zcrm_3584690000000404060 2019-01-07 15:08:38   2019-01-06    Vedanta
# 3       zcrm_3584690000000404065 2019-01-07 15:08:38   2019-01-06      Aidai
# 4       zcrm_3584690000000404068 2019-01-07 15:08:38   2019-01-06      Ardra
# ...                          ...                 ...          ...        ...
# 456198  zcrm_3584690000502118035 2024-07-15 17:01:09         <NA>          P
# 456199  zcrm_3584690000502118068 2024-07-15 17:42:29         <NA>    Stephan
# 456200  zcrm_3584690000502119001 2024-07-15 16:34:56         <NA>      Alvin
# 456201  zcrm_3584690000502121002 2024-07-15 17:01:02         <NA>      Quyen
# 456202  zcrm_3584690000502124001 2024-07-15 17:36:44   2024-07-15       <NA>
#
#         Last Name                       Email           Phone          Mobile  \
# 0            Wood  1230woodnicholas@gmail.com     61438600845            <NA>
# 1            Yuan            158066546@qq.com   8618718399923            <NA>
# 2        Abhiyoga  abhiyoga.vedanta@gmail.com   6282146524550            <NA>
# 3       Atakanova      aidai.nurbek@gmail.com    996779641590            <NA>
# 4           Ardra  aliefardraqariru@gmail.com  +6282139300818  +6282139300818
# ...           ...                         ...             ...             ...
# 456198   M BHADRE          pmbhadre@gmail.com            <NA>            <NA>
# 456199    Joachim         joastephan@yahoo.de   +491621791259            <NA>
# 456200   Cabautan    alvin.cabautan@gmail.com   +610416159756   +610416159756
# 456201     Martin        cindykim10@yahoo.com    +61421235687            <NA>
# 456202   Jen Clay       jenclay22@hotmail.com   +971582433297            <NA>
#
#          Birthdate Year of Birth  ...  \
# 0             <NA>          <NA>  ...
# 1             <NA>          <NA>  ...
# 2       2000-07-05          2000  ...
# 3       1997-02-05          1997  ...
# 4       2005-01-20          2005  ...
# ...            ...           ...  ...
# 456198        <NA>          <NA>  ...
# 456199        <NA>          <NA>  ...
# 456200        <NA>          <NA>  ...
# 456201        <NA>          <NA>  ...
# 456202        <NA>          <NA>  ...
#
#                                   Lead Source Description Lead Regions  \
# 0                                                    <NA>         SEAP
# 1                                                    <NA>        Other
# 2                                                    <NA>         SEAP
# 3                                                    <NA>    UK/Europe
# 4                                   WIFI USER ID 13494142         SEAP
# ...                                                   ...          ...
# 456198               Karma Experience India | Webchat Web        India
# 456199                                    Form Contact Us    UK/Europe
# 456200                       KE | Web | Newsletter Footer         SEAP
# 456201                          Timeshare Booking Request         SEAP
# 456202  Karma La Herriza - Download Wedding Brochure a...  Middle East
#
#           Lead Status Booking Status BookRef Email Opt Out Opt In  \
# 0            New Lead           <NA>    <NA>          <NA>   <NA>
# 1            New Lead           <NA>    <NA>          <NA>   <NA>
# 2            New Lead           <NA>    <NA>          <NA>   <NA>
# 3            New Lead           <NA>    <NA>          <NA>   <NA>
# 4            New Lead           <NA>    <NA>          <NA>   <NA>
# ...               ...            ...     ...           ...    ...
# 456198           <NA>           <NA>    <NA>         false   true
# 456199           <NA>           <NA>    <NA>         false   true
# 456200  Not Qualified           <NA>    <NA>         false  false
# 456201           <NA>           <NA>    <NA>         false   true
# 456202           <NA>           <NA>    <NA>         false   true
#
#        GDPR Compliant                                            Website  \
# 0                <NA>                                               <NA>
# 1                <NA>                                               <NA>
# 2                <NA>                                               <NA>
# 3                <NA>                                               <NA>
# 4                <NA>                                               <NA>
# ...               ...                                                ...
# 456198          false               https://karmagroup.com/member-login/
# 456199           true                 https://karmagroup.com/contact-us/
# 456200          false                   https://www.karmaexperience.com/
# 456201           true                            https://karmagroup.com/
# 456202          false  https://karmagroup.com/weddings-at-karma-la-he...
#
#        Comments
# 0          <NA>
# 1          <NA>
# 2          <NA>
# 3          <NA>
# 4          <NA>
# ...         ...
# 456198     <NA>
# 456199     <NA>
# 456200     <NA>
# 456201     <NA>
# 456202     <NA>
#
# [15139909 rows x 34 columns]

# %%
path = r'G:\.shortcut-targets-by-id\0B_d3smBjzo04eXpvS1NXTWF2RVE\_BOOKING\Booking By Year\FlyBuy Booking Data (BGAU & BGID & KE).xlsx'
df_booking = pd.read_excel(path, dtype='string', sheet_name='BOOKING_BGAU_BGID_KE')

path = r'G:\.shortcut-targets-by-id\0B_d3smBjzo04UUNBME5GOVhoMjA\_ODYSSEY\Phone Members.xlsx'
df_phone = pd.read_excel(path, dtype='string', sheet_name='Sheet1')

path = r'G:\.shortcut-targets-by-id\0B_d3smBjzo04UUNBME5GOVhoMjA\_ODYSSEY\Email Members.xlsx'
df_email = pd.read_excel(path, dtype='string', sheet_name='Sheet1')

# %%
zoho_df = df.loc[df[column_name] == search_value].copy() # menggunakan copy untuk menghindari setting copy warning
zoho_df.reset_index(drop=True, inplace=True)
count_filter_awal = zoho_df.shape[0]

# zoho_df.to_excel(r'C:\Users\fajar\Documents\Python\Data\test_leads.xlsx', index=False)
# mengisi kolom <NA> dengan value string 'empty' supaya mudah mengecek data member dan booking dengan isin

zoho_df.fillna('empty', inplace=True)
zoho_df.sort_values('Created Time', ascending=True)
zoho_df
# Out:
#                        Record Id        Created Time Created Date First Name  \
# 0       zcrm_3584690000000462232 2019-01-09 11:11:25        empty     Murray
# 1       zcrm_3584690000000527009 2019-01-10 13:05:49   2019-01-10      Ronna
# 2       zcrm_3584690000000527015 2019-01-10 13:40:17   2019-01-10      Vinay
# 3       zcrm_3584690000000549002 2019-01-10 18:44:15   2019-01-10      Manoj
# 4       zcrm_3584690000000591002 2019-01-11 03:45:37   2019-01-10      Emily
# ...                          ...                 ...          ...        ...
# 181425  zcrm_3584690000502090001 2024-07-15 15:13:53        empty      NITIN
# 181426  zcrm_3584690000502098001 2024-07-15 15:27:27        empty      empty
# 181427  zcrm_3584690000502103001 2024-07-15 15:33:05        empty     Ramesh
# 181428  zcrm_3584690000502118002 2024-07-15 16:23:28        empty          P
# 181429  zcrm_3584690000502118035 2024-07-15 17:01:09        empty          P
#
#         Last Name                           Email          Phone Mobile  \
# 0           Frean  mfrean@financialmentors.com.au    61892286444  empty
# 1          Butler     ronnabutler@netspace.net.au          empty  empty
# 2            Jain             jain.golu@gmail.com          empty  empty
# 3            Shah              mnshah51@gmail.com     9820036610  empty
# 4       Partridge               emilyalix@aol.com     7795246409  empty
# ...           ...                             ...            ...    ...
# 181425     Raghav            nittin1977@gmail.com  +919810619515  empty
# 181426      Tarun       tarunkchiefmate@gmail.com          empty  empty
# 181427        Pal                 rp250@gmail.com          empty  empty
# 181428   M BHADRE              pmbhadre@gmail.com          empty  empty
# 181429   M BHADRE              pmbhadre@gmail.com          empty  empty
#
#        Birthdate Year of Birth  ...               Lead Source Description  \
# 0          empty         empty  ...                   Management Companie
# 1          empty         empty  ...                                 empty
# 2          empty         empty  ...                                 empty
# 3          empty         empty  ...                                 empty
# 4          empty         empty  ...                                 empty
# ...          ...           ...  ...                                   ...
# 181425     empty         empty  ...  Karma Experience India | Webchat Web
# 181426     empty         empty  ...  Karma Experience India | Webchat Web
# 181427     empty         empty  ...  Karma Experience India | Webchat Web
# 181428     empty         empty  ...  Karma Experience India | Webchat Web
# 181429     empty         empty  ...  Karma Experience India | Webchat Web
#
#        Lead Regions Lead Status Booking Status BookRef Email Opt Out Opt In  \
# 0              SEAP    New Lead          empty   empty         empty  empty
# 1              SEAP    New Lead          empty   empty         empty  empty
# 2             Other    New Lead          empty   empty         empty  empty
# 3             India    New Lead          empty   empty         empty  empty
# 4             Other    New Lead          empty   empty         empty  empty
# ...             ...         ...            ...     ...           ...    ...
# 181425        India       empty          empty   empty         false   true
# 181426        India       empty          empty   empty         false   true
# 181427        India       empty          empty   empty         false   true
# 181428        India       empty          empty   empty         false   true
# 181429        India       empty          empty   empty         false   true
#
#        GDPR Compliant                                   Website Comments
# 0               empty                                     empty    empty
# 1               empty                                     empty    empty
# 2               empty                                     empty    empty
# 3               empty                                     empty    empty
# 4               empty                                     empty    empty
# ...               ...                                       ...      ...
# 181425          false                   https://karmagroup.com/    empty
# 181426          false  https://karmagroup.com/find-destination/    empty
# 181427          false      https://karmagroup.com/member-login/    empty
# 181428          false      https://karmagroup.com/member-login/    empty
# 181429          false      https://karmagroup.com/member-login/    empty
#
# [181430 rows x 34 columns]

# %%
# data phone, mobile dam email member yang ada di master data (wash member)

m.clean_number(zoho_df, 'Phone')
m.clean_number(zoho_df, 'Mobile')
m.replace_not_valid_to_empty(zoho_df, 'Phone')
m.replace_not_valid_to_empty(zoho_df, 'Mobile')
zoho_df['Email'] = m.lowercase(zoho_df, 'Email')
m.clean_space(zoho_df, 'Email')
m.clean_not_valid_email_format(zoho_df, 'Email')

m.clean_number(df_booking, 'Phone1')
m.clean_number(df_booking, 'Mobile')
df_booking['Email'] = m.lowercase(df_booking, 'Email')
m.clean_space(df_booking, 'Email')
m.clean_not_valid_email_format(df_booking, 'Email')

m.clean_number(df_phone, 'Mobile')

df_email['Email'] = m.lowercase(df_email, 'Email')
m.clean_space(df_email, 'Email')
m.clean_not_valid_email_format(df_email, 'Email')
# Out:
# c:\Users\fajar\Documents\Python\Task Offline\zoho_data_app\main_module.py:67: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[df_columns].replace(' ','', regex=True, inplace=True)
# c:\Users\fajar\Documents\Python\Task Offline\zoho_data_app\main_module.py:68: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[df_columns].replace('[^0-9]','', regex=True, inplace=True)
# c:\Users\fajar\Documents\Python\Task Offline\zoho_data_app\main_module.py:90: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[df_columns].replace(' ','', regex=True, inplace=True)
# c:\Users\fajar\Documents\Python\Task Offline\zoho_data_app\main_module.py:67: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[df_columns].replace(' ','', regex=True, inplace=True)
# c:\Users\fajar\Documents\Python\Task Offline\zoho_data_app\main_module.py:68: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[df_columns].replace('[^0-9]','', regex=True, inplace=True)
# 'Email'

# %%
count_deleted_wrong_format = m.delete_email_wrong_format(zoho_df, 'Email')
count_after_deleted_wrong_format = zoho_df.shape[0]

# %%
# hitung jumlah duplicate
count_duplicate_general = zoho_df.loc[zoho_df.duplicated(subset=['Email', 'Phone', 'Lead Brand', 'Lead Sub-Brand', 'Lead Source'])].shape[0]

zoho_df.loc[zoho_df.duplicated(subset=['Email', 'Phone', 'Lead Brand', 'Lead Sub-Brand', 'Lead Source'])]
# Out:
#                        Record Id        Created Time Created Date First Name  \
# 339     zcrm_3584690000002030004 2019-02-14 14:41:03   2019-02-14     Natraj
# 15471   zcrm_3584690000025158920 2019-04-09 21:51:50        empty       Phil
# 15473   zcrm_3584690000025158922 2019-04-09 21:51:50        empty       Paul
# 15514   zcrm_3584690000025159165 2019-04-09 21:51:53        empty        Rod
# 15548   zcrm_3584690000025159202 2019-04-09 21:51:53        empty       Dean
# ...                          ...                 ...          ...        ...
# 181389  zcrm_3584690000501919303 2024-07-12 10:44:09        empty        Ian
# 181395  zcrm_3584690000501949251 2024-07-13 01:47:50   2024-07-13  Catherine
# 181407  zcrm_3584690000501969409 2024-07-14 05:11:46        empty        Leo
# 181410  zcrm_3584690000501973109 2024-07-12 13:56:54        empty      empty
# 181419  zcrm_3584690000502118035 2024-07-15 17:01:09        empty          P
#
#            Last Name                      Email          Phone Mobile  \
# 339           Sharma   natraj.sharma1@gmail.com          empty  empty
# 15471          Jones                      empty    61892135120  empty
# 15473          Clark                      empty    61894497000  empty
# 15514        Michell                      empty    61892611361  empty
# 15548         Nalder                      empty    61893238111  empty
# ...              ...                        ...            ...    ...
# 181389  Drummond-Hay         imdrum@outlook.com          empty  empty
# 181395         Eaden  cath.eaden@protonmail.com          empty  empty
# 181407         Novac       leonovac27@gmail.com  4915783502187  empty
# 181410        Rajesh      dr.raju2609@gmail.com   919964531160  empty
# 181419      M BHADRE         pmbhadre@gmail.com          empty  empty
#
#        Birthdate Year of Birth  ...               Lead Source Description  \
# 339        empty         empty  ...                                 empty
# 15471      empty         empty  ...                                 Banks
# 15473      empty         empty  ...                                 Banks
# 15514      empty         empty  ...                   Consultin Companies
# 15548      empty         empty  ...                 Director Mailing List
# ...          ...           ...  ...                                   ...
# 181389     empty         empty  ...  Karma Experience India | Webchat Web
# 181395     empty         empty  ...               Newsletter Subscription
# 181407     empty         empty  ...  Friend of Karma - Discount Card 2023
# 181410     empty         empty  ...  Karma Experience India | Webchat Web
# 181419     empty         empty  ...  Karma Experience India | Webchat Web
#
#        Lead Regions Lead Status Booking Status BookRef Email Opt Out Opt In  \
# 339           Other    New Lead          empty   empty         empty  empty
# 15471          SEAP    New Lead          empty   empty         empty  empty
# 15473          SEAP    New Lead          empty   empty         empty  empty
# 15514          SEAP    New Lead          empty   empty         empty  empty
# 15548          SEAP    New Lead          empty   empty         empty  empty
# ...             ...         ...            ...     ...           ...    ...
# 181389         SEAP       empty          empty   empty         false   true
# 181395        empty       empty          empty   empty         false  false
# 181407    UK/Europe       empty          empty   empty         false   true
# 181410        India       empty          empty   empty         false   true
# 181419        India       empty          empty   empty         false   true
#
#        GDPR Compliant                                            Website  \
# 339             empty                                              empty
# 15471           empty                                              empty
# 15473           empty                                              empty
# 15514           empty                                              empty
# 15548           empty                                              empty
# ...               ...                                                ...
# 181389          false                            https://www.google.com/
# 181395          false           https://karmagroup.com/find-destination/
# 181407           true  https://karmagroup.com/friend-of-karma-bavaria...
# 181410          false                            https://karmagroup.com/
# 181419          false               https://karmagroup.com/member-login/
#
#        Comments
# 339       empty
# 15471     empty
# 15473     empty
# 15514     empty
# 15548     empty
# ...         ...
# 181389    empty
# 181395    empty
# 181407    empty
# 181410    empty
# 181419    empty
#
# [116025 rows x 34 columns]

# %%
zoho_df.drop_duplicates(subset=['Email', 'Phone', 'Lead Brand', 'Lead Sub-Brand', 'Lead Source'], inplace=True)
zoho_df.reset_index(drop=True, inplace=True)

# hitung jumlah setelah value duplicate dihapus
count_after_dedup_duplicate = zoho_df.shape[0]

zoho_df
# Out:
#                       Record Id        Created Time Created Date First Name  \
# 0      zcrm_3584690000000462232 2019-01-09 11:11:25        empty     Murray
# 1      zcrm_3584690000000527009 2019-01-10 13:05:49   2019-01-10      Ronna
# 2      zcrm_3584690000000527015 2019-01-10 13:40:17   2019-01-10      Vinay
# 3      zcrm_3584690000000549002 2019-01-10 18:44:15   2019-01-10      Manoj
# 4      zcrm_3584690000000591002 2019-01-11 03:45:37   2019-01-10      Emily
# ...                         ...                 ...          ...        ...
# 65390  zcrm_3584690000501997720 2024-07-15 10:30:29        empty     Amrita
# 65391  zcrm_3584690000502090001 2024-07-15 15:13:53        empty      NITIN
# 65392  zcrm_3584690000502098001 2024-07-15 15:27:27        empty      empty
# 65393  zcrm_3584690000502103001 2024-07-15 15:33:05        empty     Ramesh
# 65394  zcrm_3584690000502118002 2024-07-15 16:23:28        empty          P
#
#          Last Name                           Email         Phone Mobile  \
# 0            Frean  mfrean@financialmentors.com.au   61892286444  empty
# 1           Butler     ronnabutler@netspace.net.au         empty  empty
# 2             Jain             jain.golu@gmail.com         empty  empty
# 3             Shah              mnshah51@gmail.com    9820036610  empty
# 4        Partridge               emilyalix@aol.com    7795246409  empty
# ...            ...                             ...           ...    ...
# 65390  Neelakantan              amster04@gmail.com         empty  empty
# 65391       Raghav            nittin1977@gmail.com  919810619515  empty
# 65392        Tarun       tarunkchiefmate@gmail.com         empty  empty
# 65393          Pal                 rp250@gmail.com         empty  empty
# 65394     M BHADRE              pmbhadre@gmail.com         empty  empty
#
#       Birthdate Year of Birth  ...               Lead Source Description  \
# 0         empty         empty  ...                   Management Companie
# 1         empty         empty  ...                                 empty
# 2         empty         empty  ...                                 empty
# 3         empty         empty  ...                                 empty
# 4         empty         empty  ...                                 empty
# ...         ...           ...  ...                                   ...
# 65390     empty         empty  ...  Karma Experience India | Webchat Web
# 65391     empty         empty  ...  Karma Experience India | Webchat Web
# 65392     empty         empty  ...  Karma Experience India | Webchat Web
# 65393     empty         empty  ...  Karma Experience India | Webchat Web
# 65394     empty         empty  ...  Karma Experience India | Webchat Web
#
#       Lead Regions Lead Status Booking Status BookRef Email Opt Out Opt In  \
# 0             SEAP    New Lead          empty   empty         empty  empty
# 1             SEAP    New Lead          empty   empty         empty  empty
# 2            Other    New Lead          empty   empty         empty  empty
# 3            India    New Lead          empty   empty         empty  empty
# 4            Other    New Lead          empty   empty         empty  empty
# ...            ...         ...            ...     ...           ...    ...
# 65390        India       empty          empty   empty         false   true
# 65391        India       empty          empty   empty         false   true
# 65392        India       empty          empty   empty         false   true
# 65393        India       empty          empty   empty         false   true
# 65394        India       empty          empty   empty         false   true
#
#       GDPR Compliant                                   Website Comments
# 0              empty                                     empty    empty
# 1              empty                                     empty    empty
# 2              empty                                     empty    empty
# 3              empty                                     empty    empty
# 4              empty                                     empty    empty
# ...              ...                                       ...      ...
# 65390          false                   https://karmagroup.com/    empty
# 65391          false                   https://karmagroup.com/    empty
# 65392          false  https://karmagroup.com/find-destination/    empty
# 65393          false      https://karmagroup.com/member-login/    empty
# 65394          false      https://karmagroup.com/member-login/    empty
#
# [65395 rows x 34 columns]

# %%
# Cek leads test
test_leads = zoho_df.loc[
    
        zoho_df['Email'].str.contains('^test@', flags=re.I, regex=True) |
        zoho_df['Email'].str.contains('\+test', flags=re.I, regex=True) |
    
        zoho_df['First Name'].str.contains('^test$', flags=re.I, regex=True) |
        zoho_df['Last Name'].str.contains('^test$', flags=re.I, regex=True) |

        zoho_df['First Name'].str.contains('test 1', flags=re.I, regex=True) |
        zoho_df['Last Name'].str.contains('test 2', flags=re.I, regex=True)|
        zoho_df['First Name'].str.contains('test1', flags=re.I, regex=True) |
        zoho_df['Last Name'].str.contains('test2', flags=re.I, regex=True)|

        zoho_df['First Name'].str.contains(' test ', flags=re.I, regex=True) | 
        zoho_df['Last Name'].str.contains(' test ', flags=re.I, regex=True) | 
        zoho_df['Last Name'].str.contains(' test$', flags=re.I, regex=True)
    ]

count_leads_test = test_leads.shape[0]

# test_leads.to_excel(r'C:\Users\fajar\Documents\Python\Data\test_leads_2.xlsx', index=False)
test_leads
# Out:
#                       Record Id        Created Time Created Date  \
# 38481  zcrm_3584690000164779908 2020-02-11 14:18:02        empty
# 40248  zcrm_3584690000202044134 2020-07-06 14:48:28        empty
# 40326  zcrm_3584690000204306098 2020-07-13 15:25:59        empty
# 40362  zcrm_3584690000205213163 2020-07-15 11:57:03   2020-06-26
# 40363  zcrm_3584690000205213164 2020-07-15 11:57:03   2020-06-26
# 40634  zcrm_3584690000205542873 2020-07-20 16:26:10        empty
# 40695  zcrm_3584690000206260101 2020-07-21 18:18:18   2020-07-21
# 40801  zcrm_3584690000207245885 2020-07-27 12:43:09        empty
# 40802  zcrm_3584690000207246539 2020-07-27 12:34:53        empty
# 40879  zcrm_3584690000208706001 2020-08-03 16:56:04        empty
# 40881  zcrm_3584690000208713001 2020-08-03 18:10:03        empty
# 48091  zcrm_3584690000330759866 2021-12-13 16:57:47   2021-12-13
# 48095  zcrm_3584690000330773511 2021-12-13 17:03:14   2021-12-13
# 48105  zcrm_3584690000330907479 2021-12-14 10:57:18   2021-12-14
# 48113  zcrm_3584690000330926193 2021-12-14 10:27:10   2021-12-14
# 48162  zcrm_3584690000332078177 2021-12-18 09:54:50        empty
# 50279  zcrm_3584690000407120449 2022-10-31 15:41:52        empty
# 50406  zcrm_3584690000411813181 2022-11-19 14:44:07        empty
# 50493  zcrm_3584690000414094091 2022-11-29 18:05:09   2022-11-29
# 50495  zcrm_3584690000414111019 2022-11-29 17:21:04   2022-11-29
# 50500  zcrm_3584690000414159034 2022-11-29 17:18:59   2022-11-29
# 50503  zcrm_3584690000414167004 2022-11-29 17:13:52   2022-11-29
# 50562  zcrm_3584690000414652318 2022-12-03 13:31:31        empty
# 50565  zcrm_3584690000414652990 2022-12-05 11:23:57        empty
# 50571  zcrm_3584690000414915087 2022-12-05 11:26:42        empty
# 50672  zcrm_3584690000416280778 2022-12-12 14:38:31        empty
# 52411  zcrm_3584690000416907316 2022-12-14 12:57:44        empty
# 52413  zcrm_3584690000416908308 2022-12-14 12:36:56        empty
# 52431  zcrm_3584690000417018285 2022-12-14 12:46:00        empty
# 53229  zcrm_3584690000419452284 2022-12-26 12:46:01        empty
# 55279  zcrm_3584690000445143569 2023-05-18 17:26:18        empty
# 55283  zcrm_3584690000445151384 2023-05-18 11:54:58        empty
# 55555  zcrm_3584690000448297285 2023-06-08 17:28:18        empty
# 55831  zcrm_3584690000450718899 2023-06-26 10:22:38        empty
# 55839  zcrm_3584690000450744063 2023-06-26 10:31:40        empty
# 57740  zcrm_3584690000467634929 2023-10-31 18:11:59        empty
# 58025  zcrm_3584690000471165352 2023-11-28 10:37:04   2023-11-28
# 58295  zcrm_3584690000472705075 2023-12-12 20:51:06        empty
# 59711  zcrm_3584690000485778112 2024-03-01 11:22:24        empty
# 59718  zcrm_3584690000485805127 2024-03-01 11:17:34        empty
# 59723  zcrm_3584690000485825077 2024-03-01 11:24:07        empty
# 64202  zcrm_3584690000490960568 2024-04-08 16:37:00        empty
# 64885  zcrm_3584690000497560142 2024-05-30 19:15:26        empty
# 64889  zcrm_3584690000497596233 2024-05-31 17:59:34        empty
# 65206  zcrm_3584690000500662043 2024-06-29 11:08:21        empty
#
#           First Name     Last Name  \
# 38481       Teofilus        Candra
# 40248          wayan          test
# 40326  JamesBondQuiz          Test
# 40362    Wayan Wirka         Bagus
# 40363    Wayan Wirka         Wisnu
# 40634       Bolywood          Test
# 40695           test         kclub
# 40801           test  foodiesquiz2
# 40802           test   foodiesquiz
# 40879           Form          Test
# 40881           Form          Test
# 48091          Ferry          test
# 48095          Ferry          test
# 48105          Ferry          test
# 48113          Ferry          test
# 48162           test         bajra
# 50279           test         bajra
# 50406           test         bajra
# 50493           Form          Test
# 50495          Ferry          test
# 50500          Ferry          test
# 50503          Ferry          Test
# 50562          Wayan         Wirka
# 50565           test         bajra
# 50571           test         bajra
# 50672           test         bajra
# 52411           Form          Test
# 52413           Form          Test
# 52431           Form          Test
# 53229           test         bajra
# 55279           Test         Testq
# 55283           test             -
# 55555    Andrea Test  Pavlidi Test
# 55831           test         bajra
# 55839           test         bajra
# 57740         Neeraj       Chauhan
# 58025          Ferry          test
# 58295          empty       Bhaumik
# 59711          Ferry          test
# 59718          Ferry          test
# 59723          Ferry          test
# 64202           Form          Test
# 64885           test          test
# 64889          ferry          test
# 65206       Ferry333          test
#
#                                                 Email            Phone Mobile  \
# 38481                  teofiluschandra+test@gmail.com    6289681180786  empty
# 40248                      wayan.wirka@karmagroup.com    6281916143356  empty
# 40326            wayan.wirka+jamesbons@karmagroup.com    6281916143350  empty
# 40362    wayan.wirka+testchatoffline26@karmagroup.com            empty  empty
# 40363     wayan.wirka+testofflinechat4@karmagroup.com            empty  empty
# 40634           wayan.wirka+quiz30test@karmagroup.com    6281916143351  empty
# 40695        wayan.wirka+testnewskclub@karmagroup.com            empty  empty
# 40801           wayan.wirka+quiz31test@karmagroup.com    6281916143352  empty
# 40802      wayan.wirka+testfoodiesquiz@karmagroup.com    6281916143352  empty
# 40879       wayan.wirka+testweeklyquiz@karmagroup.com    6281916143354  empty
# 40881     wayan.wirka+testsurveyaugust@karmagroup.com    6281916143353  empty
# 48091                  ferry.yudhitama@karmagroup.com            empty  empty
# 48095             ferry.yudhitama+dev2@karmagroup.com            empty  empty
# 48105           ferry.yudhitama+ete121@karmagroup.com            empty  empty
# 48113          ferry.yudhitama+dev0921@karmagroup.com            empty  empty
# 48162    bajra.idabagus+karmagrouptest@karmagroup.com    6281180123321  empty
# 50279    bajra.idabagus+karmagrouptest@karmagroup.com    6281180123312  empty
# 50406    bajra.idabagus+karmagrouptest@karmagroup.com     628118012331  empty
# 50493       wayan.wirka+testnewsletter@karmagroup.com            empty  empty
# 50495        ferry.yudhitama+test22123@karmagroup.com            empty  empty
# 50500        ferry.yudhitama+test22231@karmagroup.com            empty  empty
# 50503          ferry.yudhitama+test212@karmagroup.com            empty  empty
# 50562               wayan.wirka+test03@karmagroup.com    6281916143350  empty
# 50565    bajra.idabagus+karmagrouptest@karmagroup.com     081180123321  empty
# 50571    bajra.idabagus+karmagrouptest@karmagroup.com  628112801232321  empty
# 50672    bajra.idabagus+karmagrouptest@karmagroup.com    6281180123231  empty
# 52411              wayan.wirka+testksm@karmagroup.com    6281916143350  empty
# 52413             wayan.wirka+testksh2@karmagroup.com    6281916143350  empty
# 52431             wayan.wirka+testklom@karmagroup.com    6281916143350  empty
# 53229    bajra.idabagus+karmagrouptest@karmagroup.com      81180123321  empty
# 55279                            asdasdasda@gmail.com     917766776666  empty
# 55283                                   test@tect.com            empty  empty
# 55555                  andrea.pavlidis@karmagroup.com     306979898735  empty
# 55831    bajra.idabagus+karmagrouptest@karmagroup.com    6281180132321  empty
# 55839    bajra.idabagus+karmagrouptest@karmagroup.com   62812182123321  empty
# 57740                                  test@gmail.com     918788502197  empty
# 58025  ferry.yudhitama+testnewsletter1@karmagroup.com            empty  empty
# 58295                                   test@test.com     919998999898  empty
# 59711         ferry.yudhitama+test2123@karmagroup.com    6287861085145  empty
# 59718             ferry.yudhitama+test@karmagroup.com    6287861085145  empty
# 59723                  ferry.yudhitama@karmagroup.com    6287861085145  empty
# 64202                      wayan.wirka@karmagroup.com    6281916143350  empty
# 64885                    hrisha.rashmi@karmagroup.com        910849484  empty
# 64889                  ferry.yudhitama@karmagroup.com    6287861085173  empty
# 65206                  ferry.yudhitama@karmagroup.com      62878617321  empty
#
#         Birthdate Year of Birth  ...  \
# 38481       empty         empty  ...
# 40248       empty         empty  ...
# 40326       empty         empty  ...
# 40362       empty         empty  ...
# 40363       empty         empty  ...
# 40634       empty         empty  ...
# 40695       empty         empty  ...
# 40801       empty         empty  ...
# 40802       empty         empty  ...
# 40879       empty         empty  ...
# 40881       empty         empty  ...
# 48091       empty         empty  ...
# 48095       empty         empty  ...
# 48105       empty         empty  ...
# 48113       empty         empty  ...
# 48162       empty         empty  ...
# 50279       empty         empty  ...
# 50406       empty         empty  ...
# 50493       empty         empty  ...
# 50495       empty         empty  ...
# 50500       empty         empty  ...
# 50503       empty         empty  ...
# 50562  1990-12-06         empty  ...
# 50565       empty         empty  ...
# 50571       empty         empty  ...
# 50672       empty         empty  ...
# 52411       empty         empty  ...
# 52413       empty         empty  ...
# 52431       empty         empty  ...
# 53229       empty         empty  ...
# 55279       empty         empty  ...
# 55283       empty         empty  ...
# 55555       empty         empty  ...
# 55831       empty         empty  ...
# 55839       empty         empty  ...
# 57740       empty         empty  ...
# 58025       empty         empty  ...
# 58295       empty         empty  ...
# 59711       empty         empty  ...
# 59718       empty         empty  ...
# 59723       empty         empty  ...
# 64202       empty         empty  ...
# 64885       empty         empty  ...
# 64889       empty         empty  ...
# 65206       empty         empty  ...
#
#                                  Lead Source Description Lead Regions  \
# 38481                         Web Site Enquiry Timeshare         SEAP
# 40248                   Karma Community Survey June 2020         SEAP
# 40326                  Karma Community | James Bond Quiz         SEAP
# 40362        Karma Group Website Concierge | Webchat Web         SEAP
# 40363        Karma Group Website Concierge | Webchat Web         SEAP
# 40634                   Karma Community | Bollywood Quiz         SEAP
# 40695                            Newsletter Subscription         SEAP
# 40801                     Karma Community | Foodies Quiz         SEAP
# 40802                     Karma Community | Foodies Quiz         SEAP
# 40879                      Karma Community | Weekly Quiz         SEAP
# 40881                 Karma Community Survey August 2020         SEAP
# 48091                            Newsletter Subscription         SEAP
# 48095                            Newsletter Subscription         SEAP
# 48105                            Newsletter Subscription         SEAP
# 48113                            Newsletter Subscription         SEAP
# 48162  Karma Community | Editon 102 | 12 Days Christm...         SEAP
# 50279  Karma Community | Editon 147 | Edition 147 - H...         SEAP
# 50406  Karma Community | Editon 150 | Edition 150 - T...         SEAP
# 50493                            Newsletter Subscription         SEAP
# 50495                            Newsletter Subscription         SEAP
# 50500                            Newsletter Subscription         SEAP
# 50503                            Newsletter Subscription         SEAP
# 50562                             29 Years Of Good Karma         SEAP
# 50565  Karma Community | Edition 152 | Edition 152 - ...        empty
# 50571  Karma Community | Edition 152 | Edition 152 - ...         SEAP
# 50672  Karma Community | Editon 153 | Edition 153 - P...         SEAP
# 52411               Friend of Karma - Discount Card 2023         SEAP
# 52413               Friend of Karma - Discount Card 2023         SEAP
# 52431               Friend of Karma - Discount Card 2023         SEAP
# 53229  Karma Community | Editon 155 | Edition 155 - 2...        empty
# 55279                             IND | Karma Ambassador        empty
# 55283                                       Karma MayDay         SEAP
# 55555  Karma Community | Editon 177 | Edition 177 - E...    UK/Europe
# 55831  Karma Community | Editon 180 | Edition 180 - H...         SEAP
# 55839  Karma Community | Editon 180 | Edition 180 - H...         SEAP
# 57740               Karma Experience India | Webchat Web        India
# 58025                            Newsletter Subscription         SEAP
# 58295               Karma Experience India | Webchat Web        India
# 59711               Friend of Karma - Discount Card 2023         SEAP
# 59718               Friend of Karma - Discount Card 2023         SEAP
# 59723               Friend of Karma - Discount Card 2023         SEAP
# 64202   Karma Community | Edition 220 - Gamarana Viarit!         SEAP
# 64885  Karma Community | Editon 227 | The Great Evere...        India
# 64889  Karma Community | Editon 227 | The Great Evere...         SEAP
# 65206                                               test         SEAP
#
#       Lead Status Booking Status BookRef Email Opt Out Opt In GDPR Compliant  \
# 38481       empty          empty   empty         empty  empty          empty
# 40248       empty          empty   empty         empty  empty          empty
# 40326       empty          empty   empty         empty  empty          empty
# 40362    New Lead          empty   empty         empty  empty          empty
# 40363    New Lead          empty   empty         empty  empty          empty
# 40634       empty          empty   empty         empty  empty          empty
# 40695       empty          empty   empty         empty  empty          empty
# 40801       empty          empty   empty         empty  empty          empty
# 40802       empty          empty   empty         empty  empty          empty
# 40879       empty          empty   empty         empty  empty          empty
# 40881       empty          empty   empty         empty  empty          empty
# 48091       empty          empty   empty         empty  empty          empty
# 48095       empty          empty   empty         empty  empty          empty
# 48105       empty          empty   empty         empty  empty          empty
# 48113       empty          empty   empty         empty  empty          empty
# 48162       empty          empty   empty         empty  empty          empty
# 50279       empty          empty   empty         empty  empty          empty
# 50406       empty          empty   empty         empty  empty          empty
# 50493       empty          empty   empty         empty  empty          empty
# 50495       empty          empty   empty         empty  empty          empty
# 50500       empty          empty   empty         empty  empty          empty
# 50503       empty          empty   empty         empty  empty          empty
# 50562       empty          empty   empty         empty  empty          empty
# 50565       empty          empty   empty         empty  empty          empty
# 50571       empty          empty   empty         empty  empty          empty
# 50672       empty          empty   empty         empty  empty          empty
# 52411       empty          empty   empty         empty  empty          empty
# 52413       empty          empty   empty         empty  empty          empty
# 52431       empty          empty   empty         empty  empty          empty
# 53229       empty          empty   empty         empty  empty          empty
# 55279       empty          empty   empty         empty  empty          empty
# 55283       empty          empty   empty         empty  empty          empty
# 55555       empty          empty   empty         empty  empty          empty
# 55831       empty          empty   empty         empty  empty          empty
# 55839       empty          empty   empty         empty  empty          empty
# 57740       empty          empty   empty         empty  empty          empty
# 58025       empty          empty   empty         empty  empty          empty
# 58295       empty          empty   empty         empty  empty          empty
# 59711       empty          empty   empty         empty  empty          empty
# 59718       empty          empty   empty         empty  empty          empty
# 59723       empty          empty   empty         empty  empty          empty
# 64202       empty          empty   empty         false   true          false
# 64885       empty          empty   empty         false   true          false
# 64889       empty          empty   empty         false   true          false
# 65206       empty          empty   empty         false   true          false
#
#                                                  Website Comments
# 38481                                              empty    empty
# 40248                                              empty    empty
# 40326                                              empty    empty
# 40362                                              empty    empty
# 40363                                              empty    empty
# 40634                                              empty    empty
# 40695                                              empty    empty
# 40801                                              empty    empty
# 40802                                              empty    empty
# 40879                                              empty    empty
# 40881                                              empty    empty
# 48091                                              empty    empty
# 48095                                              empty    empty
# 48105                                              empty    empty
# 48113                                              empty    empty
# 48162                                              empty    empty
# 50279                                              empty    empty
# 50406                                              empty    empty
# 50493                                              empty    empty
# 50495                                              empty    empty
# 50500                                              empty    empty
# 50503                                              empty    empty
# 50562                                              empty    empty
# 50565                                              empty    empty
# 50571                                              empty    empty
# 50672                                              empty    empty
# 52411                                              empty    empty
# 52413                                              empty    empty
# 52431                                              empty    empty
# 53229                                              empty    empty
# 55279                                              empty    empty
# 55283                                              empty    empty
# 55555                                              empty    empty
# 55831                                              empty    empty
# 55839                                              empty    empty
# 57740                                              empty    empty
# 58025                                              empty    empty
# 58295                                              empty    empty
# 59711                                              empty    empty
# 59718                                              empty    empty
# 59723                                              empty    empty
# 64202  https://karmacommunity.karmagroup.com/experien...    empty
# 64885  https://karmacommunity.karmagroup.com/experien...    empty
# 64889  https://karmacommunity.karmagroup.com/?p=34773...    empty
# 65206                            https://karmagroup.com/    empty
#
# [45 rows x 34 columns]

# %%
zoho_df.drop(test_leads.index, inplace=True)
zoho_df.reset_index(drop=True, inplace=True)

count_after_dedup_test = zoho_df.shape[0]

# %%
# Cek Email OTA
email_OTA = m.find_OTA(zoho_df, 'Email')
count_email_OTA = email_OTA.shape[0]
# email_OTA.to_excel(r'C:\Users\fajar\Documents\Python\Data\email_OTA.xlsx', index=False)

email_OTA
# Out:
#                       Record Id        Created Time Created Date  First Name  \
# 405    zcrm_3584690000002392011 2019-02-20 14:01:55   2019-02-20     Akansha
# 773    zcrm_3584690000004326011 2019-03-11 21:19:48   2019-03-11    Wolfgang
# 1278   zcrm_3584690000006111290 2019-04-02 03:14:05   2015-05-12       Holly
# 1434   zcrm_3584690000006457044 2019-04-02 03:58:51   2015-03-10    AurÃ©lia
# 1439   zcrm_3584690000006460632 2019-04-02 03:59:11   2015-03-10  Christophe
# ...                         ...                 ...          ...         ...
# 58233  zcrm_3584690000472604111 2023-12-12 12:50:09   2023-12-11      Ernest
# 59795  zcrm_3584690000487498031 2024-03-12 16:10:01        empty       empty
# 60260  zcrm_3584690000007141264 2019-04-02 05:23:20   2018-10-29        Doli
# 60300  zcrm_3584690000007141678 2019-04-02 05:23:22   2017-11-07       Lucky
# 65258  zcrm_3584690000501287749 2024-07-08 14:44:00        empty       empty
#
#              Last Name                                  Email          Phone  \
# 405             Pandey                akansha@protourism.news          empty
# 773           Oberfeld               tourleader01@hotmail.com          empty
# 1278              Tate            tourism@experienceperth.com    61894810221
# 1434        Devilliers  aurelia.devilliers@australietours.com      153702342
# 1439           Beysard                  lausanne@novatours.ch   410213115040
# ...                ...                                    ...            ...
# 58233         Chandana           jalanjalanmamstour@gmail.com  6281775488685
# 59795     Inayathullah           flyglobaltours2022@gmail.com   919444011709
# 60260  Martua Nasution                  martuatours@gmail.com  6282167402694
# 60300            Tours            merlineluckytours@gmail.com  6282122777351
# 65258           Harsha               tour.skyandsky@gmail.com   917845752523
#
#       Mobile   Birthdate Year of Birth  ...  \
# 405    empty       empty         empty  ...
# 773    empty       empty         empty  ...
# 1278   empty       empty         empty  ...
# 1434   empty       empty         empty  ...
# 1439   empty       empty         empty  ...
# ...      ...         ...           ...  ...
# 58233  empty       empty         empty  ...
# 59795  empty       empty         empty  ...
# 60260  empty  1981-08-09          1981  ...
# 60300  empty       empty         empty  ...
# 65258  empty       empty         empty  ...
#
#                     Lead Source Description Lead Regions Lead Status  \
# 405                                   empty        Other    New Lead
# 773                         KG | Newsletter        Other    New Lead
# 1278         Perth Holiday Travel Expo 2010         SEAP       empty
# 1434                          Travel Agents    UK/Europe       empty
# 1439                            London 2009    UK/Europe       empty
# ...                                     ...          ...         ...
# 58233                      12 Days of Karma         SEAP    New Lead
# 59795  Karma Experience India | Webchat Web        India       empty
# 60260                           competition         SEAP       empty
# 60300                                 empty         SEAP       empty
# 65258  Karma Experience India | Webchat Web        India       empty
#
#       Booking Status BookRef Email Opt Out Opt In GDPR Compliant  \
# 405            empty   empty         empty  empty          empty
# 773            empty   empty         empty  empty          empty
# 1278           empty   empty         empty  empty          empty
# 1434           empty   empty         empty  empty          empty
# 1439           empty   empty         empty  empty          empty
# ...              ...     ...           ...    ...            ...
# 58233          empty   empty         empty  empty          empty
# 59795          empty   empty         empty  empty          empty
# 60260          empty   empty         false  false          false
# 60300          empty   empty         false  false          false
# 65258          empty   empty         false   true          false
#
#                                                  Website Comments
# 405                                                empty    empty
# 773                                                empty    empty
# 1278                                               empty    empty
# 1434                                               empty    empty
# 1439                                               empty    empty
# ...                                                  ...      ...
# 58233                                              empty    empty
# 59795                                              empty    empty
# 60260                                              empty    empty
# 60300                                              empty    empty
# 65258  https://karmagroup.com/find-destination/karma-...    empty
#
# [133 rows x 34 columns]

# %%
# delete email OTA
count_after_clean_OTA = m.delete_OTA(zoho_df, 'Email')
# zoho_df.to_excel(r'C:\Users\fajar\Documents\Python\Data\after_clean_OTA.xlsx', index=False)

zoho_df
# Out:
#                       Record Id        Created Time Created Date First Name  \
# 0      zcrm_3584690000000462232 2019-01-09 11:11:25        empty     Murray
# 1      zcrm_3584690000000527009 2019-01-10 13:05:49   2019-01-10      Ronna
# 2      zcrm_3584690000000527015 2019-01-10 13:40:17   2019-01-10      Vinay
# 3      zcrm_3584690000000549002 2019-01-10 18:44:15   2019-01-10      Manoj
# 4      zcrm_3584690000000591002 2019-01-11 03:45:37   2019-01-10      Emily
# ...                         ...                 ...          ...        ...
# 65212  zcrm_3584690000501997720 2024-07-15 10:30:29        empty     Amrita
# 65213  zcrm_3584690000502090001 2024-07-15 15:13:53        empty      NITIN
# 65214  zcrm_3584690000502098001 2024-07-15 15:27:27        empty      empty
# 65215  zcrm_3584690000502103001 2024-07-15 15:33:05        empty     Ramesh
# 65216  zcrm_3584690000502118002 2024-07-15 16:23:28        empty          P
#
#          Last Name                           Email         Phone Mobile  \
# 0            Frean  mfrean@financialmentors.com.au   61892286444  empty
# 1           Butler     ronnabutler@netspace.net.au         empty  empty
# 2             Jain             jain.golu@gmail.com         empty  empty
# 3             Shah              mnshah51@gmail.com    9820036610  empty
# 4        Partridge               emilyalix@aol.com    7795246409  empty
# ...            ...                             ...           ...    ...
# 65212  Neelakantan              amster04@gmail.com         empty  empty
# 65213       Raghav            nittin1977@gmail.com  919810619515  empty
# 65214        Tarun       tarunkchiefmate@gmail.com         empty  empty
# 65215          Pal                 rp250@gmail.com         empty  empty
# 65216     M BHADRE              pmbhadre@gmail.com         empty  empty
#
#       Birthdate Year of Birth  ...               Lead Source Description  \
# 0         empty         empty  ...                   Management Companie
# 1         empty         empty  ...                                 empty
# 2         empty         empty  ...                                 empty
# 3         empty         empty  ...                                 empty
# 4         empty         empty  ...                                 empty
# ...         ...           ...  ...                                   ...
# 65212     empty         empty  ...  Karma Experience India | Webchat Web
# 65213     empty         empty  ...  Karma Experience India | Webchat Web
# 65214     empty         empty  ...  Karma Experience India | Webchat Web
# 65215     empty         empty  ...  Karma Experience India | Webchat Web
# 65216     empty         empty  ...  Karma Experience India | Webchat Web
#
#       Lead Regions Lead Status Booking Status BookRef Email Opt Out Opt In  \
# 0             SEAP    New Lead          empty   empty         empty  empty
# 1             SEAP    New Lead          empty   empty         empty  empty
# 2            Other    New Lead          empty   empty         empty  empty
# 3            India    New Lead          empty   empty         empty  empty
# 4            Other    New Lead          empty   empty         empty  empty
# ...            ...         ...            ...     ...           ...    ...
# 65212        India       empty          empty   empty         false   true
# 65213        India       empty          empty   empty         false   true
# 65214        India       empty          empty   empty         false   true
# 65215        India       empty          empty   empty         false   true
# 65216        India       empty          empty   empty         false   true
#
#       GDPR Compliant                                   Website Comments
# 0              empty                                     empty    empty
# 1              empty                                     empty    empty
# 2              empty                                     empty    empty
# 3              empty                                     empty    empty
# 4              empty                                     empty    empty
# ...              ...                                       ...      ...
# 65212          false                   https://karmagroup.com/    empty
# 65213          false                   https://karmagroup.com/    empty
# 65214          false  https://karmagroup.com/find-destination/    empty
# 65215          false      https://karmagroup.com/member-login/    empty
# 65216          false      https://karmagroup.com/member-login/    empty
#
# [65217 rows x 34 columns]

# %%
# Cek Email Karma
email_karma = m.find_karma(zoho_df, 'Email')
count_email_karma = email_karma.shape[0]
# email_OTA.to_excel(r'C:\Users\fajar\Documents\Python\Data\email_OTA.xlsx', index=False)

email_karma
# Out:
#                       Record Id        Created Time Created Date First Name  \
# 1178   zcrm_3584690000005943397 2019-04-02 02:14:38   2015-03-11        Bob
# 2087   zcrm_3584690000006861299 2019-04-02 04:44:08   2015-03-11      Gregg
# 3792   zcrm_3584690000007141540 2019-04-02 05:23:21   2015-06-17      empty
# 4303   zcrm_3584690000007142679 2019-04-02 05:23:27   2018-11-04     Anance
# 11222  zcrm_3584690000007157037 2019-04-02 05:24:46   2016-07-26       Seri
# ...                         ...                 ...          ...        ...
# 64259  zcrm_3584690000493948264 2024-04-30 18:31:09        empty    Shivani
# 64272  zcrm_3584690000494105180 2024-05-01 14:05:24        empty     Batman
# 64587  zcrm_3584690000496072039 2024-05-18 14:53:18        empty    Francis
# 64842  zcrm_3584690000498442101 2024-06-10 18:56:48        empty      Nidhi
# 64848  zcrm_3584690000498457247 2024-06-11 17:57:19        empty       Riya
#
#        Last Name                                Email          Phone  \
# 1178     McGrath                  bob.mcgrath@rci.com    17028699924
# 2087    Anderson               gregg.anderson@rci.com    14072268430
# 3792       empty            emeric@thebaligetaway.com         215454
# 4303     Kotouki         anance.baligetaway@gmail.com  6281248125349
# 11222       Seri                   seri.okuno@rci.com     6585690316
# ...          ...                                  ...            ...
# 64259   Yeshwant      shivani.yeshwant@karmagroup.com     7682075005
# 64272   Superman  karmaconcierge.india@karmagroup.com          empty
# 64587   Falleiro      francis.falleiro@karmagroup.com   628123817783
# 64842      Gurav           nidhi.gurav@karmagroup.com   919579589503
# 64848  Srivastav        riya.srivastav@karmagroup.com          empty
#
#             Mobile   Birthdate Year of Birth  ...  \
# 1178   17023382537       empty         empty  ...
# 2087   14074969355       empty         empty  ...
# 3792         empty       empty         empty  ...
# 4303         empty  2018-04-14          2018  ...
# 11222        15708       empty         empty  ...
# ...            ...         ...           ...  ...
# 64259        empty       empty         empty  ...
# 64272        empty       empty         empty  ...
# 64587        empty       empty         empty  ...
# 64842        empty       empty         empty  ...
# 64848        empty       empty         empty  ...
#
#                                  Lead Source Description Lead Regions  \
# 1178                                               empty         SEAP
# 2087                                           Belvedere         SEAP
# 3792                                Iphone 6 competition    UK/Europe
# 4303                                         competition         SEAP
# 11222                                              empty        Other
# ...                                                  ...          ...
# 64259  Karma Community | Edition 223 - What Kind of K...        empty
# 64272  Karma Community | Edition 223 - The Fab Four P...        India
# 64587  Karma Community | Edition 225 - Ready to Play ...         SEAP
# 64842  Karma Community | Edition 229 - Gin’s the Perf...        India
# 64848                                Comment on Articles        empty
#
#       Lead Status Booking Status BookRef Email Opt Out Opt In GDPR Compliant  \
# 1178        empty          empty   empty         empty  empty          empty
# 2087        empty          empty   empty         empty  empty          empty
# 3792        empty          empty   empty         empty  empty          empty
# 4303        empty          empty   empty         empty  empty          empty
# 11222       empty          empty   empty         empty  empty          empty
# ...           ...            ...     ...           ...    ...            ...
# 64259       empty          empty   empty         false   true          false
# 64272       empty          empty   empty         false   true          false
# 64587       empty          empty   empty         false   true          false
# 64842       empty          empty   empty         false   true          false
# 64848       empty          empty   empty         false  false          false
#
#                                                  Website Comments
# 1178                                               empty    empty
# 2087                                               empty    empty
# 3792                                               empty    empty
# 4303                                               empty    empty
# 11222                                              empty    empty
# ...                                                  ...      ...
# 64259  https://karmacommunity.karmagroup.com/experien...    empty
# 64272  https://karmacommunity.karmagroup.com/experien...    empty
# 64587  https://karmacommunity.karmagroup.com/experien...    empty
# 64842  https://karmacommunity.karmagroup.com/experien...    empty
# 64848                                              empty    empty
#
# [99 rows x 34 columns]

# %%
# delete email Karma
count_after_clean_karma = m.delete_karma(zoho_df, 'Email')
# zoho_df.to_excel(r'C:\Users\fajar\Documents\Python\Data\after_clean_OTA.xlsx', index=False)

zoho_df
# Out:
#                       Record Id        Created Time Created Date First Name  \
# 0      zcrm_3584690000000462232 2019-01-09 11:11:25        empty     Murray
# 1      zcrm_3584690000000527009 2019-01-10 13:05:49   2019-01-10      Ronna
# 2      zcrm_3584690000000527015 2019-01-10 13:40:17   2019-01-10      Vinay
# 3      zcrm_3584690000000549002 2019-01-10 18:44:15   2019-01-10      Manoj
# 4      zcrm_3584690000000591002 2019-01-11 03:45:37   2019-01-10      Emily
# ...                         ...                 ...          ...        ...
# 65113  zcrm_3584690000501997720 2024-07-15 10:30:29        empty     Amrita
# 65114  zcrm_3584690000502090001 2024-07-15 15:13:53        empty      NITIN
# 65115  zcrm_3584690000502098001 2024-07-15 15:27:27        empty      empty
# 65116  zcrm_3584690000502103001 2024-07-15 15:33:05        empty     Ramesh
# 65117  zcrm_3584690000502118002 2024-07-15 16:23:28        empty          P
#
#          Last Name                           Email         Phone Mobile  \
# 0            Frean  mfrean@financialmentors.com.au   61892286444  empty
# 1           Butler     ronnabutler@netspace.net.au         empty  empty
# 2             Jain             jain.golu@gmail.com         empty  empty
# 3             Shah              mnshah51@gmail.com    9820036610  empty
# 4        Partridge               emilyalix@aol.com    7795246409  empty
# ...            ...                             ...           ...    ...
# 65113  Neelakantan              amster04@gmail.com         empty  empty
# 65114       Raghav            nittin1977@gmail.com  919810619515  empty
# 65115        Tarun       tarunkchiefmate@gmail.com         empty  empty
# 65116          Pal                 rp250@gmail.com         empty  empty
# 65117     M BHADRE              pmbhadre@gmail.com         empty  empty
#
#       Birthdate Year of Birth  ...               Lead Source Description  \
# 0         empty         empty  ...                   Management Companie
# 1         empty         empty  ...                                 empty
# 2         empty         empty  ...                                 empty
# 3         empty         empty  ...                                 empty
# 4         empty         empty  ...                                 empty
# ...         ...           ...  ...                                   ...
# 65113     empty         empty  ...  Karma Experience India | Webchat Web
# 65114     empty         empty  ...  Karma Experience India | Webchat Web
# 65115     empty         empty  ...  Karma Experience India | Webchat Web
# 65116     empty         empty  ...  Karma Experience India | Webchat Web
# 65117     empty         empty  ...  Karma Experience India | Webchat Web
#
#       Lead Regions Lead Status Booking Status BookRef Email Opt Out Opt In  \
# 0             SEAP    New Lead          empty   empty         empty  empty
# 1             SEAP    New Lead          empty   empty         empty  empty
# 2            Other    New Lead          empty   empty         empty  empty
# 3            India    New Lead          empty   empty         empty  empty
# 4            Other    New Lead          empty   empty         empty  empty
# ...            ...         ...            ...     ...           ...    ...
# 65113        India       empty          empty   empty         false   true
# 65114        India       empty          empty   empty         false   true
# 65115        India       empty          empty   empty         false   true
# 65116        India       empty          empty   empty         false   true
# 65117        India       empty          empty   empty         false   true
#
#       GDPR Compliant                                   Website Comments
# 0              empty                                     empty    empty
# 1              empty                                     empty    empty
# 2              empty                                     empty    empty
# 3              empty                                     empty    empty
# 4              empty                                     empty    empty
# ...              ...                                       ...      ...
# 65113          false                   https://karmagroup.com/    empty
# 65114          false                   https://karmagroup.com/    empty
# 65115          false  https://karmagroup.com/find-destination/    empty
# 65116          false      https://karmagroup.com/member-login/    empty
# 65117          false      https://karmagroup.com/member-login/    empty
#
# [65118 rows x 34 columns]

# %%
find_member_booking = zoho_df.copy()

find_member_booking.loc[find_member_booking['Phone'].isin(df_booking['Phone1']), 'Same Value Find'] = 'Booking-Phone1'
find_member_booking.loc[find_member_booking['Phone'].isin(df_booking['Mobile']), 'Same Value Find'] = 'Booking-Mobile'
find_member_booking.loc[find_member_booking['Mobile'].isin(df_booking['Phone1']), 'Same Value Find'] = 'Booking-Phone1' 
find_member_booking.loc[find_member_booking['Mobile'].isin(df_booking['Mobile']), 'Same Value Find'] = 'Booking-Mobile'
find_member_booking.loc[find_member_booking['Email'].isin(df_booking['Email']), 'Same Value Find'] = 'Booking-Email'

find_member_booking.loc[find_member_booking['Phone'].isin(df_phone['Mobile']), 'Same Value Find'] = 'Member-Mobile' 
find_member_booking.loc[find_member_booking['Mobile'].isin(df_phone['Mobile']), 'Same Value Find'] = 'Member-Mobile'

find_member_booking.loc[find_member_booking['Email'].isin(df_email['Email']), 'Same Value Find'] = 'Member-Email'

find_member_booking.drop(find_member_booking.loc[find_member_booking['Same Value Find'].isna()].index, inplace=True)

count_booking_dedup = find_member_booking.loc[find_member_booking['Same Value Find'].str.contains('Booking', flags=re.I, regex=True)].shape[0]
count_member_dedup = find_member_booking.loc[find_member_booking['Same Value Find'].str.contains('Member', flags=re.I, regex=True)].shape[0]

find_member_booking.replace('empty', '', inplace=True)
# find_member_booking.to_csv(r'C:\Users\fajar\Documents\Python\Data\booking-member-dedup.csv', index=False)
# find_member_booking.to_excel(r'C:\Users\fajar\Documents\Python\Data\booking-member-dedup.xlsx', index=False)

#find_member_booking.loc[find_member_booking['Same Value Find'] == 'Booking-Phone1']

# %%
# data phone, mobile dam email member yang ada di master data 
count_wash_member = zoho_df.loc[
    zoho_df['Phone'].isin(df_booking['Phone1']) | 
    zoho_df['Phone'].isin(df_booking['Mobile']) |
    zoho_df['Mobile'].isin(df_booking['Phone1']) | 
    zoho_df['Mobile'].isin(df_booking['Mobile']) |
    zoho_df['Email'].isin(df_booking['Email'])| 

    zoho_df['Phone'].isin(df_phone['Mobile']) | 
    zoho_df['Mobile'].isin(df_phone['Mobile']) |

    zoho_df['Email'].isin(df_email['Email'])

].shape[0]

zoho_df.drop(zoho_df.loc[
    zoho_df['Phone'].isin(df_booking['Phone1']) | 
    zoho_df['Phone'].isin(df_booking['Mobile']) |
    zoho_df['Mobile'].isin(df_booking['Phone1']) | 
    zoho_df['Mobile'].isin(df_booking['Mobile']) |
    zoho_df['Email'].isin(df_booking['Email']) |
    
    zoho_df['Phone'].isin(df_phone['Mobile']) | 
    zoho_df['Mobile'].isin(df_phone['Mobile']) |

    zoho_df['Email'].isin(df_email['Email'])

    ].index, inplace=True)
    
zoho_df.reset_index(drop=True, inplace=True)

count_after_wash_member = zoho_df.shape[0]

# %%
# Categorize contacts
m.categorize_contacts(zoho_df)

# Count contact types
count_email_only = (zoho_df['Contact Type'] == 'Email Only').sum()
count_phone_only = (zoho_df['Contact Type'] == 'Phone Only').sum()
count_email_and_phone = (zoho_df['Contact Type'] == 'Email and Phone').sum()
count_blank = (zoho_df['Contact Type'] == 'Blank').sum()

# Remove blank contacts if needed
zoho_df = zoho_df[zoho_df['Contact Type'] != 'Blank']
zoho_df.reset_index(drop=True, inplace=True)

count_after_wash_blank = zoho_df.shape[0]

# %%
arr_dedup = [count_deleted_wrong_format, count_duplicate_general, count_leads_test, count_email_OTA, count_email_karma, count_blank]
count_sum_dedup = sum(arr_dedup)
count_sum_dedup
# Out:
# np.int64(116316)

# %%
print("==========================================================")
print("Summary")
print("==========================================================")
print("Jumlah Keseluruhan Master Zoho : "+str(count_data_awal))
print("Jumlah Filter Leads Awal : "+str(count_filter_awal))
print("Jumlah Format Email Salah : "+str(count_deleted_wrong_format))
print("Jumlah Setelah Clean Format Email Salah : "+str(count_after_deleted_wrong_format))
print("Jumlah Duplicate (Phone, Mobile dan Email) : "+str(count_duplicate_general))
print("Jumlah Setelah Clean Duplicate : "+str(count_after_dedup_duplicate))
print("Jumlah Lead Test : "+str(count_leads_test))
print("Jumlah Setelah Clean Lead Test : "+str(count_after_dedup_test))
# print("Jumlah Lead Do Not Mail : "+str(count_dnm))
# print("Jumlah Setelah Clean Lead Do Not Mail : "+str(count_after_dedup_dnm))
print("Jumlah Email OTA : "+str(count_email_OTA))
print("Jumlah Setelah Clean Email OTA : "+str(count_after_clean_OTA))
print("Jumlah Email Karma : "+str(count_email_karma))
print("Jumlah Setelah Clean Email Karma : "+str(count_after_clean_karma))
print("Jumlah Wash Member : "+str(count_member_dedup))
print("Jumlah Wash Booking : "+str(count_booking_dedup))
print("Jumlah Setelah Wash Member : "+str(count_after_wash_member))
print("Jumlah Phone Email Blank (Setelah phone yang tidak valid dihapus) : "+str(count_blank))
print("Jumlah Setelah Wash Phone Email Blank : "+str(count_after_wash_blank))
print("==========================================================")
print("Contact Type")
print("==========================================================")
print("Jumlah Email Only : "+str(count_email_only))
print("Jumlah Phone Only : "+str(count_phone_only))
print("Jumlah Email dan Phone : "+str(count_email_and_phone))
# Out:
# ==========================================================
# Summary
# ==========================================================
# Jumlah Keseluruhan Master Zoho : 15139909
# Jumlah Filter Leads Awal : 181430
# Jumlah Format Email Salah : 10
# Jumlah Setelah Clean Format Email Salah : 181420
# Jumlah Duplicate (Phone, Mobile dan Email) : 116025
# Jumlah Setelah Clean Duplicate : 65395
# Jumlah Lead Test : 45
# Jumlah Setelah Clean Lead Test : 65350
# Jumlah Email OTA : 133
# Jumlah Setelah Clean Email OTA : 65217
# Jumlah Email Karma : 99
# Jumlah Setelah Clean Email Karma : 65118
# Jumlah Wash Member : 9976
# Jumlah Wash Booking : 644
# Jumlah Setelah Wash Member : 54498
# Jumlah Phone Email Blank (Setelah phone yang tidak valid dihapus) : 4
# Jumlah Setelah Wash Phone Email Blank : 54494
# ==========================================================
# Contact Type
# ==========================================================
# Jumlah Email Only : 23692
# Jumlah Phone Only : 5385
# Jumlah Email dan Phone : 25417

# %%
print("==========================================================")
print("Summary Report")
print("==========================================================")
print("Jumlah Data Awal : "+str(count_filter_awal))
print("Jumlah Wash Dedup : "+str(count_sum_dedup))
print("Jumlah Wash Member : "+str(count_member_dedup))
print("Jumlah Wash Booking : "+str(count_booking_dedup))
print("Jumlah Data Akhir : "+str(count_after_wash_blank))
# Out:
# ==========================================================
# Summary Report
# ==========================================================
# Jumlah Data Awal : 181430
# Jumlah Wash Dedup : 116316
# Jumlah Wash Member : 9976
# Jumlah Wash Booking : 644
# Jumlah Data Akhir : 54494

# %%
zoho_df['First Name'] = zoho_df['First Name'].str.title()
zoho_df['Last Name'] = zoho_df['Last Name'].str.title()
zoho_df.replace('empty', '', inplace=True, regex=True)

zoho_df
# Out:
# C:\Users\fajar\AppData\Local\Temp\ipykernel_7920\3294794079.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   zoho_df['First Name'] = zoho_df['First Name'].str.title()
# C:\Users\fajar\AppData\Local\Temp\ipykernel_7920\3294794079.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   zoho_df['Last Name'] = zoho_df['Last Name'].str.title()
# C:\Users\fajar\AppData\Local\Temp\ipykernel_7920\3294794079.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   zoho_df.replace('empty', '', inplace=True, regex=True)
#                       Record Id        Created Time Created Date First Name  \
# 0      zcrm_3584690000000462232 2019-01-09 11:11:25                  Murray
# 1      zcrm_3584690000000527009 2019-01-10 13:05:49   2019-01-10      Ronna
# 2      zcrm_3584690000000527015 2019-01-10 13:40:17   2019-01-10      Vinay
# 3      zcrm_3584690000000591002 2019-01-11 03:45:37   2019-01-10      Emily
# 4      zcrm_3584690000000591008 2019-01-11 08:07:47   2019-01-11        Yas
# ...                         ...                 ...          ...        ...
# 54489  zcrm_3584690000501977436 2024-07-14 15:11:41   2024-07-14      Jenny
# 54490  zcrm_3584690000501997360 2024-07-13 21:30:50   2024-07-13      Aadya
# 54491  zcrm_3584690000502090001 2024-07-15 15:13:53                   Nitin
# 54492  zcrm_3584690000502098001 2024-07-15 15:27:27                   Empty
# 54493  zcrm_3584690000502103001 2024-07-15 15:33:05                  Ramesh
#
#        Last Name                           Email         Phone Mobile  \
# 0          Frean  mfrean@financialmentors.com.au   61892286444
# 1         Butler     ronnabutler@netspace.net.au
# 2           Jain             jain.golu@gmail.com
# 3      Partridge               emilyalix@aol.com    7795246409
# 4         Matsui               yasmatsui@msn.com
# ...          ...                             ...           ...    ...
# 54489    Kataria       jennykataria044@gmail.com
# 54490     Sengar       aadyasengar2727@gmail.com
# 54491     Raghav            nittin1977@gmail.com  919810619515
# 54492      Tarun       tarunkchiefmate@gmail.com
# 54493        Pal                 rp250@gmail.com
#
#       Birthdate Year of Birth  ... Lead Regions Lead Status Booking Status  \
# 0                              ...         SEAP    New Lead
# 1                              ...         SEAP    New Lead
# 2                              ...        Other    New Lead
# 3                              ...        Other    New Lead
# 4                              ...        Other    New Lead
# ...         ...           ...  ...          ...         ...            ...
# 54489                          ...        India
# 54490                          ...        India
# 54491                          ...        India
# 54492                          ...        India
# 54493                          ...        India
#
#       BookRef Email Opt Out Opt In GDPR Compliant  \
# 0
# 1
# 2
# 3
# 4
# ...       ...           ...    ...            ...
# 54489                 false  false          false
# 54490                 false  false          false
# 54491                 false   true          false
# 54492                 false   true          false
# 54493                 false   true          false
#
#                                         Website Comments     Contact Type
# 0                                                         Email and Phone
# 1                                                              Email Only
# 2                                                              Email Only
# 3                                                         Email and Phone
# 4                                                              Email Only
# ...                                         ...      ...              ...
# 54489          https://karmagroup.com/healthy/#                Email Only
# 54490  https://karmagroup.com/find-destination/                Email Only
# 54491                   https://karmagroup.com/           Email and Phone
# 54492  https://karmagroup.com/find-destination/                Email Only
# 54493      https://karmagroup.com/member-login/                Email Only
#
# [54494 rows x 35 columns]

# %%
if (zoho_df.shape[0]>20000):

    row_split = 200000
    file_name = search_value

    m.split_file(zoho_df, row_split, file_name, file_type, target_location)
else:
    zoho_df.to_excel(target_location+'\\'+search_value+file_type, index=False)
