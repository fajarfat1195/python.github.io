# %%
import main_module as m
import pandas as pd
import re
import numpy as np

# %load_ext autoreload
# %autoreload 2

dir_path = r'C:\Users\fajar.fatoni\Documents\Python\Data\Zoho_Backup\2020-2024\\'
dir_path_live = r'C:\Users\fajar.fatoni\Documents\Python\Data\Zoho_Backup\\'
dir_path_old = r'C:\Users\fajar.fatoni\Documents\Python\Data\Zoho_Backup\old\\'
file_name = '\Leads_'

cols = ['Record Id',	
'Created Time',
'Created Date',	
'First Name',	
'Last Name',	
'Email',	
'Phone',	
'Mobile',	
'Birthdate',	
'Year of Birth',
'Street',	
'Street2',	
'City',	
'State',	
'Country',	
'Nationality',
'Booking Status', 
'BookRef',
'Departure Date',	
'Arrival Date',	
'Card Type',	
'Marital Status',	
'Lead Brand',	
'Lead Sub-Brand',	
'Lead Source',	
'Lead Locations',	
'Lead Source Description',	
'Lead Regions',
'Lead Status',
'Email Opt Out',	
'Opt In',
'GDPR Compliant',
'Website',
'Comments']

# %%
column_name = 'Lead Sub-Brand'
search_value = 'BGAU'

operator = 'is'
# operator = 'contains'

target_location = r'C:\Users\fajar.fatoni\Documents\Python\Data'
file_type = 'xlsx'

# %%
path = dir_path+'\\backup.csv'
df_all = pd.read_csv(path, dtype='string', on_bad_lines='skip')
df_all.drop(df_all.loc[df_all['Created Time'].str.len() < 5 ].index, inplace=True)
df_all.reset_index(drop=True, inplace=True)

df_all['Created Time'] = pd.to_datetime(df_all['Created Time'], format='%Y-%m-%d %H:%M:%S')

df_all.shape[0]
df_all
# Out:
#                         Record Id        Created Time Created Date First Name  \
# 0        zcrm_3584690000000404058 2019-01-07 15:08:38   2019-01-06   Nicholas
# 1        zcrm_3584690000000404059 2019-01-07 15:08:38   2019-01-06       Liao
# 2        zcrm_3584690000000404060 2019-01-07 15:08:38   2019-01-06    Vedanta
# 3        zcrm_3584690000000404065 2019-01-07 15:08:38   2019-01-06      Aidai
# 4        zcrm_3584690000000404068 2019-01-07 15:08:38   2019-01-06      Ardra
# ...                           ...                 ...          ...        ...
# 9965978  zcrm_3584690000489266005 2024-03-25 16:19:45         <NA>      Keval
# 9965979  zcrm_3584690000489266034 2024-03-25 16:19:51         <NA>     Suresh
# 9965980  zcrm_3584690000489266063 2024-03-25 17:29:27         <NA>     Nathan
# 9965981  zcrm_3584690000489269015 2024-03-25 16:20:25         <NA>    Leonora
# 9965982  zcrm_3584690000489271002 2024-03-25 18:40:17         <NA>       Annu
#
#           Last Name                                 Email           Phone  \
# 0              Wood            1230woodnicholas@gmail.com     61438600845
# 1              Yuan                      158066546@qq.com   8618718399923
# 2          Abhiyoga            abhiyoga.vedanta@gmail.com   6282146524550
# 3         Atakanova                aidai.nurbek@gmail.com    996779641590
# 4             Ardra            aliefardraqariru@gmail.com  +6282139300818
# ...             ...                                   ...             ...
# 9965978        Gala                   keval2403@gmail.com   +919022872972
# 9965979      Shroff  sureshshroff@breachcandyhospital.org   +919819533303
# 9965980   Fernandes       nathan.fernandes@karmagroup.com  +9179724486854
# 9965981     Hackman                leonora_hf@bigpond.com    +61439855115
# 9965982  Shriwastav          annusrivastava1990@gmail.com   +919561074124
#
#                  Mobile   Birthdate Year of Birth  ...         Arrival Date  \
# 0                  <NA>        <NA>          <NA>  ...  2019-01-06 00:00:00
# 1                  <NA>        <NA>          <NA>  ...  2019-01-06 00:00:00
# 2                  <NA>  2000-07-05          2000  ...  2018-12-01 00:00:00
# 3                  <NA>  1997-02-05          1997  ...  2019-01-06 00:00:00
# 4        +6282139300818  2005-01-20          2005  ...  2018-11-30 00:00:00
# ...                 ...         ...           ...  ...                  ...
# 9965978   +917700904802        <NA>          <NA>  ...           2024-03-21
# 9965979   +919819814280        <NA>          <NA>  ...           2024-03-21
# 9965980            <NA>        <NA>          <NA>  ...                 <NA>
# 9965981            <NA>        <NA>          <NA>  ...           2024-03-14
# 9965982            <NA>        <NA>          <NA>  ...                 <NA>
#
#         Card Type Marital Status           Lead Brand   Lead Sub-Brand  \
# 0            <NA>           <NA>  Timeshare Marketing    Other Bali DB
# 1            <NA>           <NA>  Timeshare Marketing    Other Bali DB
# 2            <NA>        Pelajar  Timeshare Marketing    Other Bali DB
# 3            <NA>         Single  Timeshare Marketing    Other Bali DB
# 4            <NA>          OTHER  Timeshare Marketing    Other Bali DB
# ...           ...            ...                  ...              ...
# 9965978      <NA>           <NA>        Karma Resorts            Other
# 9965979      <NA>           <NA>        Karma Resorts            Other
# 9965980      <NA>           <NA>          Karma Group  Karma Community
# 9965981      <NA>           <NA>        Karma Resorts            Other
# 9965982      <NA>           <NA>  Timeshare Marketing            Other
#
#          Lead Source           Lead Locations  \
# 0               Wifi              Purple Wifi
# 1               Wifi              Purple Wifi
# 2               Wifi              Purple Wifi
# 3               Wifi              Purple Wifi
# 4               Wifi              Purple Wifi
# ...              ...                      ...
# 9965978  Past Guests        Karma Royal Palms
# 9965979  Past Guests  Karma Sitabani, Corbett
# 9965980         Quiz                     <NA>
# 9965981  Past Guests           Karma Jimbaran
# 9965982  Web Enquiry           Karma Sitabani
#
#                                    Lead Source Description Lead Regions  \
# 0                                                     <NA>         SEAP
# 1                                                     <NA>        Other
# 2                                                     <NA>         SEAP
# 3                                                     <NA>    UK/Europe
# 4                                    WIFI USER ID 13494142         SEAP
# ...                                                    ...          ...
# 9965978                                          Viewpoint         <NA>
# 9965979                                          Viewpoint         <NA>
# 9965980  Karma Community | Edition 218 - Words to the Wise        India
# 9965981                                          Viewpoint         <NA>
# 9965982                          Timeshare Booking Request        India
#
#         Lead Status
# 0          New Lead
# 1          New Lead
# 2          New Lead
# 3          New Lead
# 4          New Lead
# ...             ...
# 9965978        <NA>
# 9965979        <NA>
# 9965980        <NA>
# 9965981        <NA>
# 9965982        <NA>
#
# [9965983 rows x 27 columns]

# %%
df_old = m.load_data_multiple(dir_path_old, file_name, cols)
df_old = df_old.reindex(columns=cols)
df_old.shape[0]

df_old['Created Time'] = pd.to_datetime(df_old['Created Time'], format='%Y-%m-%d %H:%M:%S')
df_old['Arrival Date'] = pd.to_datetime(df_old['Arrival Date'], format='%Y-%m-%d')
df_old['Departure Date'] = pd.to_datetime(df_old['Departure Date'], format='%Y-%m-%d')
# fungsi errors cource untuk menhindari error jika value data date null atau kosong
# df['Birthdate'] = pd.to_datetime(df['Birthdate'], format='%Y-%m-%d', errors='coerce')
df_old.dtypes
df_old
# Out:
# C:\Users\fajar.fatoni\Documents\Python\Data\Zoho_Backup\old\\\Leads_001.csv
# C:\Users\fajar.fatoni\Documents\Python\Data\Zoho_Backup\old\\\Leads_002.csv
# C:\Users\fajar.fatoni\Documents\Python\Data\Zoho_Backup\old\\\Leads_003.csv
# C:\Users\fajar.fatoni\Documents\Python\Data\Zoho_Backup\old\\\Leads_004.csv
# C:\Users\fajar.fatoni\Documents\Python\Data\Zoho_Backup\old\\\Leads_005.csv
# C:\Users\fajar.fatoni\Documents\Python\Data\Zoho_Backup\old\\\Leads_006.csv
# C:\Users\fajar.fatoni\Documents\Python\Data\Zoho_Backup\old\\\Leads_007.csv
# C:\Users\fajar.fatoni\Documents\Python\Data\Zoho_Backup\old\\\Leads_008.csv
# C:\Users\fajar.fatoni\Documents\Python\Data\Zoho_Backup\old\\\Leads_009.csv
# C:\Users\fajar.fatoni\Documents\Python\Data\Zoho_Backup\old\\\Leads_010.csv
# C:\Users\fajar.fatoni\Documents\Python\Data\Zoho_Backup\old\\\Leads_011.csv
# C:\Users\fajar.fatoni\Documents\Python\Data\Zoho_Backup\old\\\Leads_012.csv
# C:\Users\fajar.fatoni\Documents\Python\Data\Zoho_Backup\old\\\Leads_013.csv
# C:\Users\fajar.fatoni\Documents\Python\Data\Zoho_Backup\old\\\Leads_014.csv
# C:\Users\fajar.fatoni\Documents\Python\Data\Zoho_Backup\old\\\Leads_015.csv
# C:\Users\fajar.fatoni\Documents\Python\Data\Zoho_Backup\old\\\Leads_016.csv
# C:\Users\fajar.fatoni\Documents\Python\Data\Zoho_Backup\old\\\Leads_017.csv
# C:\Users\fajar.fatoni\Documents\Python\Data\Zoho_Backup\old\\\Leads_018.csv
# C:\Users\fajar.fatoni\Documents\Python\Data\Zoho_Backup\old\\\Leads_019.csv
# C:\Users\fajar.fatoni\Documents\Python\Data\Zoho_Backup\old\\\Leads_020.csv
# C:\Users\fajar.fatoni\Documents\Python\Data\Zoho_Backup\old\\\Leads_021.csv
# C:\Users\fajar.fatoni\Documents\Python\Data\Zoho_Backup\old\\\Leads_022.csv
# C:\Users\fajar.fatoni\Documents\Python\Data\Zoho_Backup\old\\\Leads_023.csv
# C:\Users\fajar.fatoni\Documents\Python\Data\Zoho_Backup\old\\\Leads_024.csv
# C:\Users\fajar.fatoni\Documents\Python\Data\Zoho_Backup\old\\\Leads_025.csv
# C:\Users\fajar.fatoni\Documents\Python\Data\Zoho_Backup\old\\\Leads_026.csv
# C:\Users\fajar.fatoni\Documents\Python\Data\Zoho_Backup\old\\\Leads_027.csv
# C:\Users\fajar.fatoni\Documents\Python\Data\Zoho_Backup\old\\\Leads_028.csv
# C:\Users\fajar.fatoni\Documents\Python\Data\Zoho_Backup\old\\\Leads_029.csv
# C:\Users\fajar.fatoni\Documents\Python\Data\Zoho_Backup\old\\\Leads_030.csv
# C:\Users\fajar.fatoni\Documents\Python\Data\Zoho_Backup\old\\\Leads_031.csv
# C:\Users\fajar.fatoni\Documents\Python\Data\Zoho_Backup\old\\\Leads_032.csv
# C:\Users\fajar.fatoni\Documents\Python\Data\Zoho_Backup\old\\\Leads_033.csv
# C:\Users\fajar.fatoni\Documents\Python\Data\Zoho_Backup\old\\\Leads_034.csv
# C:\Users\fajar.fatoni\Documents\Python\Data\Zoho_Backup\old\\\Leads_035.csv
# C:\Users\fajar.fatoni\Documents\Python\Data\Zoho_Backup\old\\\Leads_036.csv
# C:\Users\fajar.fatoni\Documents\Python\Data\Zoho_Backup\old\\\Leads_037.csv
# C:\Users\fajar.fatoni\Documents\Python\Data\Zoho_Backup\old\\\Leads_038.csv
# C:\Users\fajar.fatoni\Documents\Python\Data\Zoho_Backup\old\\\Leads_039.csv
# C:\Users\fajar.fatoni\Documents\Python\Data\Zoho_Backup\old\\\Leads_040.csv
# C:\Users\fajar.fatoni\Documents\Python\Data\Zoho_Backup\old\\\Leads_041.csv
# C:\Users\fajar.fatoni\Documents\Python\Data\Zoho_Backup\old\\\Leads_042.csv
# C:\Users\fajar.fatoni\Documents\Python\Data\Zoho_Backup\old\\\Leads_043.csv
# C:\Users\fajar.fatoni\Documents\Python\Data\Zoho_Backup\old\\\Leads_044.csv
# C:\Users\fajar.fatoni\Documents\Python\Data\Zoho_Backup\old\\\Leads_045.csv
# C:\Users\fajar.fatoni\Documents\Python\Data\Zoho_Backup\old\\\Leads_046.csv
# C:\Users\fajar.fatoni\Documents\Python\Data\Zoho_Backup\old\\\Leads_047.csv
# C:\Users\fajar.fatoni\Documents\Python\Data\Zoho_Backup\old\\\Leads_048.csv
#                         Record Id        Created Time Created Date First Name  \
# 0        zcrm_3584690000000404058 2019-01-07 15:08:38   2019-01-06   Nicholas
# 1        zcrm_3584690000000404059 2019-01-07 15:08:38   2019-01-06       Liao
# 2        zcrm_3584690000000404060 2019-01-07 15:08:38   2019-01-06    Vedanta
# 3        zcrm_3584690000000404065 2019-01-07 15:08:38   2019-01-06      Aidai
# 4        zcrm_3584690000000404068 2019-01-07 15:08:38   2019-01-06      Ardra
# ...                           ...                 ...          ...        ...
# 4717718  zcrm_3584690000475135007 2024-01-01 18:16:02         <NA>    Upendra
# 4717719  zcrm_3584690000475135045 2024-01-01 18:16:37         <NA>      Mehul
# 4717720  zcrm_3584690000475136005 2024-01-01 18:17:13         <NA>      swati
# 4717721  zcrm_3584690000475138034 2024-01-01 18:48:36         <NA>      SUMON
# 4717722  zcrm_3584690000475138069 2024-01-01 18:52:24         <NA>      Rohit
#
#          Last Name                       Email           Phone  \
# 0             Wood  1230woodnicholas@gmail.com    +61438600845
# 1             Yuan            158066546@qq.com   8618718399923
# 2         Abhiyoga  abhiyoga.vedanta@gmail.com  +6282146524550
# 3        Atakanova      aidai.nurbek@gmail.com    996779641590
# 4            Ardra  aliefardraqariru@gmail.com  +6282139300818
# ...            ...                         ...             ...
# 4717718     Mishra       upendra.sir@gmail.com   +919036084550
# 4717719  Prajapati     mehul.m111985@gmail.com   +919714713689
# 4717720   agarwala         cswatiadv@gmail.com   +919733055636
# 4717721      SAHOO        sumonsahoo@gmail.com   +918910484814
# 4717722      Kadam      rohit0918.rk@gmail.com   +919819185446
#
#                  Mobile   Birthdate Year of Birth  ...   Lead Source  \
# 0                  <NA>        <NA>          <NA>  ...          Wifi
# 1                  <NA>        <NA>          <NA>  ...          Wifi
# 2                  <NA>  2000-07-05          2000  ...          Wifi
# 3                  <NA>  1997-02-05          1997  ...          Wifi
# 4        +6282139300818  2005-01-20          2005  ...          Wifi
# ...                 ...         ...           ...  ...           ...
# 4717718            <NA>        <NA>          <NA>  ...   Web Enquiry
# 4717719            <NA>        <NA>          <NA>  ...  Facebook Ads
# 4717720            <NA>        <NA>          <NA>  ...  Facebook Ads
# 4717721            <NA>        <NA>          <NA>  ...  Facebook Ads
# 4717722            <NA>        <NA>          <NA>  ...  Facebook Ads
#
#                  Lead Locations      Lead Source Description Lead Regions  \
# 0                          <NA>                  Purple Wifi         SEAP
# 1                          <NA>                  Purple Wifi        Other
# 2                          <NA>                  Purple Wifi         SEAP
# 3                          <NA>                  Purple Wifi    UK/Europe
# 4                       Mall 21                  Purple Wifi         SEAP
# ...                         ...                          ...          ...
# 4717718  Karma Sunshine Village    Timeshare Booking Request        India
# 4717719                 General  IND | FB MF | Lead captured         <NA>
# 4717720            Karma Martam         IND | FB MF | Martam         <NA>
# 4717721            Karma Martam         IND | FB MF | Martam         <NA>
# 4717722             Royal Palms            IND | FB AF | KRP         <NA>
#
#         Lead Status Email Opt Out Opt In GDPR Compliant  \
# 0          New Lead         false  false          false
# 1          New Lead         false  false          false
# 2          New Lead         false  false          false
# 3          New Lead         false  false          false
# 4          New Lead         false  false          false
# ...             ...           ...    ...            ...
# 4717718        <NA>         false   true           true
# 4717719        <NA>         false  false          false
# 4717720        <NA>         false  false          false
# 4717721        <NA>         false  false          false
# 4717722        <NA>         false  false          false
#
#                                                    Website Comments
# 0                                                     <NA>     <NA>
# 1                                                     <NA>     <NA>
# 2                                                     <NA>     <NA>
# 3                                                     <NA>     <NA>
# 4                                                     <NA>     <NA>
# ...                                                    ...      ...
# 4717718  https://karmagroup.com/find-destination/karma-...     <NA>
# 4717719                                               <NA>     <NA>
# 4717720                                               <NA>     <NA>
# 4717721                                               <NA>     <NA>
# 4717722                                               <NA>     <NA>
#
# [4717723 rows x 34 columns]

# %%
df_live = m.load_data_multiple(dir_path_live, file_name, cols)
df_live = df_live.reindex(columns=cols)
df_live.shape[0]

df_live['Created Time'] = pd.to_datetime(df_live['Created Time'], format='%Y-%m-%d %H:%M:%S')
df_live['Arrival Date'] = pd.to_datetime(df_live['Arrival Date'], format='%Y-%m-%d')
df_live['Departure Date'] = pd.to_datetime(df_live['Departure Date'], format='%Y-%m-%d')
# fungsi errors cource untuk menhindari error jika value data date null atau kosong
# df['Birthdate'] = pd.to_datetime(df['Birthdate'], format='%Y-%m-%d', errors='coerce')
df_live.dtypes
df_live
# Out:
# C:\Users\fajar.fatoni\Documents\Python\Data\Zoho_Backup\\\Leads_001.csv
# C:\Users\fajar.fatoni\Documents\Python\Data\Zoho_Backup\\\Leads_002.csv
# C:\Users\fajar.fatoni\Documents\Python\Data\Zoho_Backup\\\Leads_003.csv
# C:\Users\fajar.fatoni\Documents\Python\Data\Zoho_Backup\\\Leads_004.csv
# C:\Users\fajar.fatoni\Documents\Python\Data\Zoho_Backup\\\Leads_005.csv
# C:\Users\fajar.fatoni\Documents\Python\Data\Zoho_Backup\\\Leads_006.csv
#                        Record Id        Created Time Created Date First Name  \
# 0       zcrm_3584690000000404602 2019-01-08 11:07:28   2021-07-21   Frederic
# 1       zcrm_3584690000000450071 2019-01-08 16:38:18         <NA>  Sebastian
# 2       zcrm_3584690000000450087 2019-01-08 16:38:18         <NA>    Siobhan
# 3       zcrm_3584690000000450106 2019-01-08 16:38:18         <NA>       Lisa
# 4       zcrm_3584690000000450109 2019-01-08 16:38:18         <NA>  Ana Maria
# ...                          ...                 ...          ...        ...
# 516376  zcrm_3584690000565363037 2025-07-21 17:41:32         <NA>      Susan
# 516377  zcrm_3584690000565367001 2025-07-21 17:30:24   2025-07-20  Vladyslav
# 516378  zcrm_3584690000565367037 2025-07-21 17:30:26   2025-07-20      Gillw
# 516379  zcrm_3584690000565369001 2025-07-21 17:30:52   2025-07-21         Ax
# 516380  zcrm_3584690000565370001 2025-07-21 17:38:13         <NA>       <NA>
#
#         Last Name                        Email             Phone Mobile  \
# 0           Bonin    fredericbonin79@gmail.com    +6281236100502   <NA>
# 1            Rach                         <NA>     +498914342111   <NA>
# 2       Gallagher  gallaghersiobhan@eircom.net      353879597603   <NA>
# 3       Ferkovich         lisajo2009@yahoo.com       14062394749   <NA>
# 4        Weileder     m.weileder@sonnenlink.de       15253234700   <NA>
# ...           ...                          ...               ...    ...
# 516376      Jones       susanhelen91@gmail.com     +447543096118   <NA>
# 516377  Vladyslav                         <NA>  +380 68 071 5622   <NA>
# 516378      Gillw                         <NA>   +61 413 351 082   <NA>
# 516379         Ax                         <NA>    +7 916 6567743   <NA>
# 516380      Radha     radhaojethra80@gmail.com              <NA>   <NA>
#
#          Birthdate Year of Birth  ...  Lead Source Lead Locations  \
# 0       1981-10-03          1981  ...       Agency  Karma Kandara
# 1       1982-04-20          1982  ...  Past Guests  Karma Bavaria
# 2       1973-03-14          1973  ...  Past Guests  Karma Bavaria
# 3       1963-07-08          1963  ...  Past Guests  Karma Bavaria
# 4             <NA>          <NA>  ...        Other  Karma Bavaria
# ...            ...           ...  ...          ...            ...
# 516376  1991-03-01          <NA>  ...          Web           <NA>
# 516377        <NA>          <NA>  ...        Phone  Karma Kandara
# 516378        <NA>          <NA>  ...     WhatsApp  Karma Kandara
# 516379        <NA>          <NA>  ...     WhatsApp  Karma Kandara
# 516380        <NA>          <NA>  ...      Webchat           <NA>
#
#                       Lead Source Description Lead Regions Lead Status  \
# 0                                       KAREN         SEAP    New Lead
# 1                                        <NA>    UK/Europe    New Lead
# 2                                        <NA>    UK/Europe    New Lead
# 3                                        <NA>    UK/Europe    New Lead
# 4             MICE Contacts from Ioanna email    UK/Europe    New Lead
# ...                                       ...          ...         ...
# 516376               Karma Reciprocal Members    UK/Europe        <NA>
# 516377  Karma Reservations - WhatsApp Channel         SEAP        <NA>
# 516378  Karma Reservations - WhatsApp Channel         SEAP        <NA>
# 516379  Karma Reservations - WhatsApp Channel         SEAP        <NA>
# 516380   Karma Experience India | Webchat Web         <NA>        <NA>
#
#        Email Opt Out Opt In GDPR Compliant  \
# 0              false  false          false
# 1               true  false          false
# 2              false   true           true
# 3               true  false          false
# 4              false   true           true
# ...              ...    ...            ...
# 516376         false   true           true
# 516377         false  false          false
# 516378         false  false          false
# 516379         false  false          false
# 516380         false   true          false
#
#                                                   Website Comments
# 0                                                    <NA>     <NA>
# 1                                                    <NA>     <NA>
# 2                                                    <NA>     <NA>
# 3                                                    <NA>     <NA>
# 4                                                    <NA>     <NA>
# ...                                                   ...      ...
# 516376  https://karmaclub.karmagroup.com/reciprocal-me...     <NA>
# 516377                                               <NA>     <NA>
# 516378                                               <NA>     <NA>
# 516379                                               <NA>     <NA>
# 516380                             http://m.facebook.com/     <NA>
#
# [516381 rows x 34 columns]

# %%
df = pd.concat([df_all,df_old,df_live])
count_data_awal = df.shape[0]
df
# Out:
#                        Record Id        Created Time Created Date First Name  \
# 0       zcrm_3584690000000404058 2019-01-07 15:08:38   2019-01-06   Nicholas
# 1       zcrm_3584690000000404059 2019-01-07 15:08:38   2019-01-06       Liao
# 2       zcrm_3584690000000404060 2019-01-07 15:08:38   2019-01-06    Vedanta
# 3       zcrm_3584690000000404065 2019-01-07 15:08:38   2019-01-06      Aidai
# 4       zcrm_3584690000000404068 2019-01-07 15:08:38   2019-01-06      Ardra
# ...                          ...                 ...          ...        ...
# 516376  zcrm_3584690000565363037 2025-07-21 17:41:32         <NA>      Susan
# 516377  zcrm_3584690000565367001 2025-07-21 17:30:24   2025-07-20  Vladyslav
# 516378  zcrm_3584690000565367037 2025-07-21 17:30:26   2025-07-20      Gillw
# 516379  zcrm_3584690000565369001 2025-07-21 17:30:52   2025-07-21         Ax
# 516380  zcrm_3584690000565370001 2025-07-21 17:38:13         <NA>       <NA>
#
#         Last Name                       Email             Phone  \
# 0            Wood  1230woodnicholas@gmail.com       61438600845
# 1            Yuan            158066546@qq.com     8618718399923
# 2        Abhiyoga  abhiyoga.vedanta@gmail.com     6282146524550
# 3       Atakanova      aidai.nurbek@gmail.com      996779641590
# 4           Ardra  aliefardraqariru@gmail.com    +6282139300818
# ...           ...                         ...               ...
# 516376      Jones      susanhelen91@gmail.com     +447543096118
# 516377  Vladyslav                        <NA>  +380 68 071 5622
# 516378      Gillw                        <NA>   +61 413 351 082
# 516379         Ax                        <NA>    +7 916 6567743
# 516380      Radha    radhaojethra80@gmail.com              <NA>
#
#                 Mobile   Birthdate Year of Birth  ...  \
# 0                 <NA>        <NA>          <NA>  ...
# 1                 <NA>        <NA>          <NA>  ...
# 2                 <NA>  2000-07-05          2000  ...
# 3                 <NA>  1997-02-05          1997  ...
# 4       +6282139300818  2005-01-20          2005  ...
# ...                ...         ...           ...  ...
# 516376            <NA>  1991-03-01          <NA>  ...
# 516377            <NA>        <NA>          <NA>  ...
# 516378            <NA>        <NA>          <NA>  ...
# 516379            <NA>        <NA>          <NA>  ...
# 516380            <NA>        <NA>          <NA>  ...
#
#                       Lead Source Description Lead Regions Lead Status  \
# 0                                        <NA>         SEAP    New Lead
# 1                                        <NA>        Other    New Lead
# 2                                        <NA>         SEAP    New Lead
# 3                                        <NA>    UK/Europe    New Lead
# 4                       WIFI USER ID 13494142         SEAP    New Lead
# ...                                       ...          ...         ...
# 516376               Karma Reciprocal Members    UK/Europe        <NA>
# 516377  Karma Reservations - WhatsApp Channel         SEAP        <NA>
# 516378  Karma Reservations - WhatsApp Channel         SEAP        <NA>
# 516379  Karma Reservations - WhatsApp Channel         SEAP        <NA>
# 516380   Karma Experience India | Webchat Web         <NA>        <NA>
#
#        Booking Status BookRef Email Opt Out Opt In GDPR Compliant  \
# 0                <NA>    <NA>          <NA>   <NA>           <NA>
# 1                <NA>    <NA>          <NA>   <NA>           <NA>
# 2                <NA>    <NA>          <NA>   <NA>           <NA>
# 3                <NA>    <NA>          <NA>   <NA>           <NA>
# 4                <NA>    <NA>          <NA>   <NA>           <NA>
# ...               ...     ...           ...    ...            ...
# 516376           <NA>    <NA>         false   true           true
# 516377           <NA>    <NA>         false  false          false
# 516378           <NA>    <NA>         false  false          false
# 516379           <NA>    <NA>         false  false          false
# 516380           <NA>    <NA>         false   true          false
#
#                                                   Website Comments
# 0                                                    <NA>     <NA>
# 1                                                    <NA>     <NA>
# 2                                                    <NA>     <NA>
# 3                                                    <NA>     <NA>
# 4                                                    <NA>     <NA>
# ...                                                   ...      ...
# 516376  https://karmaclub.karmagroup.com/reciprocal-me...     <NA>
# 516377                                               <NA>     <NA>
# 516378                                               <NA>     <NA>
# 516379                                               <NA>     <NA>
# 516380                             http://m.facebook.com/     <NA>
#
# [15200087 rows x 34 columns]

# %%
m.clean_number(df, 'Phone')
m.clean_number(df, 'Mobile')
m.replace_not_valid_to_empty(df, 'Phone')
m.replace_not_valid_to_empty(df, 'Mobile')
df['Email'] = m.lowercase(df, 'Email')
m.clean_space(df, 'Email')
m.clean_not_valid_email_format(df, 'Email')
# Out:
# c:\Users\fajar.fatoni\Documents\Python\Task Offline\zoho_data_app\main_module.py:104: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[df_columns].replace(' ','', regex=True, inplace=True)
# c:\Users\fajar.fatoni\Documents\Python\Task Offline\zoho_data_app\main_module.py:105: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[df_columns].replace('[^0-9]','', regex=True, inplace=True)
# c:\Users\fajar.fatoni\Documents\Python\Task Offline\zoho_data_app\main_module.py:127: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[df_columns].replace(' ','', regex=True, inplace=True)
# 'Email'

# %%
path = r'G:\.shortcut-targets-by-id\0B_d3smBjzo04eXpvS1NXTWF2RVE\_BOOKING\Booking By Year\FlyBuy Booking Data (BGAU & BGID & KE).xlsx'
df_booking = pd.read_excel(path, dtype='string', sheet_name='BOOKING_BGAU_BGID_KE')

path = r'G:\.shortcut-targets-by-id\0B_d3smBjzo04UUNBME5GOVhoMjA\_ODYSSEY\Phone Members.xlsx'
df_phone = pd.read_excel(path, dtype='string', sheet_name='Sheet1')

path = r'G:\.shortcut-targets-by-id\0B_d3smBjzo04UUNBME5GOVhoMjA\_ODYSSEY\Email Members.xlsx'
df_email = pd.read_excel(path, dtype='string', sheet_name='Sheet1')

# %%
if operator == 'is':
    zoho_df = df.loc[df[column_name] == search_value].copy()
else:
    zoho_df = df.loc[df[column_name].str.contains(search_value, regex=True, flags=re.I)].copy()


# zoho_df = df.loc[
#     (df['Lead Sub-Brand'].str.contains('BGAU', regex=True, flags=re.I)) &
#     # Bagian ini akan mencakup 61 di awal, bahkan jika ada karakter tersembunyi non-digit
#     (df['Phone'].str.contains('^\D*61', regex=True, flags=re.I))
# ].copy()

zoho_df.reset_index(drop=True, inplace=True)
count_filter_awal = zoho_df.shape[0]

zoho_df.fillna('empty', inplace=True)
zoho_df.sort_values('Created Time', ascending=True)
zoho_df

# zoho_df.to_excel(r'C:\Users\fajar.fatoni\Documents\Python\Data\test_leads.xlsx', index=False)
# mengisi kolom <NA> dengan value string 'empty' supaya mudah mengecek data member dan booking dengan isin
# Out:
#                        Record Id        Created Time Created Date  \
# 0       zcrm_3584690000001068067 2019-01-25 23:52:59        empty
# 1       zcrm_3584690000001192049 2019-01-29 16:19:43        empty
# 2       zcrm_3584690000001225025 2019-01-30 06:22:10        empty
# 3       zcrm_3584690000001232061 2019-01-30 12:28:39        empty
# 4       zcrm_3584690000001278049 2019-01-31 11:31:18        empty
# ...                          ...                 ...          ...
# 249016  zcrm_3584690000562451001 2025-07-08 15:12:16        empty
# 249017  zcrm_3584690000562557001 2025-07-08 21:37:51        empty
# 249018  zcrm_3584690000562917003 2025-07-10 07:32:14        empty
# 249019  zcrm_3584690000563381001 2025-07-11 13:17:27        empty
# 249020  zcrm_3584690000565112001 2025-07-17 10:41:53        empty
#
#          First Name       Last Name                        Email  \
# 0           Belinda           Walsh       bindywalsh@hotmail.com
# 1             Vicky        Smileski    vickysmileski@hotmail.com
# 2           Crystal         Roebeck   crystal.roebeck3@gmail.com
# 3         Juliannki        Schembri   littlebearrock@hotmail.com
# 4             Karel          Tepper      kareltepper@hotmail.com
# ...             ...             ...                          ...
# 249016         Gede  Krisnamahayana          buleslash@gmail.com
# 249017        Vicki        Richards  vickirichards57@outlook.com
# 249018   ywurwytoro      dzudyqwsnd        gzewnwvg@testform.xyz
# 249019  Sofian arif         susanto      ian_susanto@hotmail.com
# 249020      Helleni     Paora-Quirk             quirky@gmail.com
#
#                  Phone Mobile   Birthdate    Year of Birth  ...  \
# 0            431270511  empty       empty             1979  ...
# 1            432646221  empty  1974-12-25             1974  ...
# 2           2102277635  empty  1981-07-09             1981  ...
# 3          61405100858  empty  1964-01-10             1964  ...
# 4            435404940  empty  1953-04-02             1953  ...
# ...                ...    ...         ...              ...  ...
# 249016  62081936064627  empty       empty             1984  ...
# 249017     61402441867  empty       empty             1957  ...
# 249018           empty  empty       empty  -Year of birth-  ...
# 249019     62811342971  empty       empty             1994  ...
# 249020    610490899110  empty       empty            empty  ...
#
#                                   Lead Source Description Lead Regions  \
# 0                                                   empty         SEAP
# 1                                                   empty         SEAP
# 2                                                   empty         SEAP
# 3                                                   empty         SEAP
# 4                                                   empty         SEAP
# ...                                                   ...          ...
# 249016  BGAU | Web | Packages The Lerina Hotel Nusa Du...         SEAP
# 249017          BGAU | Web | Packages Champlung Mas Hotel         SEAP
# 249018                           BGAU | Web | Testimonial         SEAP
# 249019                  BGAU | Web | Form Homepage Bottom         SEAP
# 249020                  BGAU | Web | Form Homepage Bottom         SEAP
#
#           Lead Status Booking Status BookRef Email Opt Out Opt In  \
# 0               empty          empty   empty         empty  empty
# 1               empty          empty   empty         empty  empty
# 2               empty          empty   empty         empty  empty
# 3               empty          empty   empty         empty  empty
# 4               empty          empty   empty         empty  empty
# ...               ...            ...     ...           ...    ...
# 249016   Hot Prospect          empty   empty         false  false
# 249017  Not Qualified          empty   empty         false  false
# 249018   Hot Prospect          empty   empty         false  false
# 249019   Hot Prospect          empty   empty         false  false
# 249020   Hot Prospect          empty   empty         false  false
#
#        GDPR Compliant Website Comments
# 0               empty   empty    empty
# 1               empty   empty    empty
# 2               empty   empty    empty
# 3               empty   empty    empty
# 4               empty   empty    empty
# ...               ...     ...      ...
# 249016          false   empty    empty
# 249017          false   empty    empty
# 249018          false   empty    empty
# 249019          false   empty    empty
# 249020          false   empty    empty
#
# [249021 rows x 34 columns]

# %%
# data phone, mobile dam email member yang ada di master data (wash member)

m.clean_number(df_booking, 'Phone1')
m.clean_number(df_booking, 'Mobile')
df_booking['Email'] = m.lowercase(df_booking, 'Email')
m.clean_space(df_booking, 'Email')
m.clean_not_valid_email_format(df_booking, 'Email')

m.clean_number(df_phone, 'Mobile')

df_email['Email'] = m.lowercase(df_email, 'Email')
m.clean_space(df_email, 'Email')
m.clean_not_valid_email_format(df_email, 'Email')
# Out:
# c:\Users\fajar.fatoni\Documents\Python\Task Offline\zoho_data_app\main_module.py:104: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[df_columns].replace(' ','', regex=True, inplace=True)
# c:\Users\fajar.fatoni\Documents\Python\Task Offline\zoho_data_app\main_module.py:105: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[df_columns].replace('[^0-9]','', regex=True, inplace=True)
# c:\Users\fajar.fatoni\Documents\Python\Task Offline\zoho_data_app\main_module.py:127: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[df_columns].replace(' ','', regex=True, inplace=True)
# c:\Users\fajar.fatoni\Documents\Python\Task Offline\zoho_data_app\main_module.py:104: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[df_columns].replace(' ','', regex=True, inplace=True)
# c:\Users\fajar.fatoni\Documents\Python\Task Offline\zoho_data_app\main_module.py:105: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[df_columns].replace('[^0-9]','', regex=True, inplace=True)
# 'Email'

# %%
zoho_df.loc[
    (zoho_df['Phone'] == 'empty') & (zoho_df['Mobile'] != 'empty'), 
    'Phone'] = zoho_df['Mobile']
zoho_df.loc[zoho_df['Phone'] == zoho_df['Mobile'],'Mobile'] = 'empty'

# %%
deleted_wrong_format = m.delete_email_wrong_format(zoho_df, 'Email')
display(deleted_wrong_format)
# deleted_wrong_format.to_excel(r'C:\Users\fajar.fatoni.fatoni\Documents\Python\Data\deleted_wrong_format.xlsx', index=False)
count_deleted_wrong_format = deleted_wrong_format.shape[0]
count_after_deleted_wrong_format = zoho_df.shape[0]
# Out:
# Empty DataFrame
# Columns: [Record Id, Created Time, Created Date, First Name, Last Name, Email, Phone, Mobile, Birthdate, Year of Birth, Street, Street2, City, State, Country, Nationality, Departure Date, Arrival Date, Card Type, Marital Status, Lead Brand, Lead Sub-Brand, Lead Source, Lead Locations, Lead Source Description, Lead Regions, Lead Status, Booking Status, BookRef, Email Opt Out, Opt In, GDPR Compliant, Website, Comments]
# Index: []
#
# [0 rows x 34 columns]

# %%
# hitung jumlah duplicate
count_duplicate_general = zoho_df.loc[zoho_df.duplicated(subset=['Email', 'Phone', 'Lead Brand', 'Lead Sub-Brand', 'Lead Source'])].shape[0]

zoho_df.loc[zoho_df.duplicated(subset=['Email', 'Phone', 'Lead Brand', 'Lead Sub-Brand', 'Lead Source'])]
# Out:
#                        Record Id         Created Time Created Date  \
# 32949   zcrm_3584690000006198072  2019-04-02 03:22:23   2017-10-24
# 43039   zcrm_3584690000029069857  2019-05-07 10:36:36        empty
# 43064   zcrm_3584690000039161932  2019-06-04 19:34:25        empty
# 43125   zcrm_3584690000067790057  2019-07-12 17:06:47        empty
# 43172   zcrm_3584690000068534795  2019-07-13 11:57:36        empty
# ...                          ...                  ...          ...
# 186749  zcrm_3584690000470967128  2023-11-26 10:46:41        empty
# 186755  zcrm_3584690000505204001  2024-08-20 16:20:13        empty
# 186756  zcrm_3584690000506044042  2024-08-30 10:49:51        empty
# 186761  zcrm_3584690000520283034  2025-01-08 04:49:22        empty
# 186767  zcrm_3584690000548346001  2025-05-15 05:56:47        empty
#
#         First Name   Last Name                                Email  \
# 32949        Javis     Brozywa                                empty
# 43039        Cathy   Sheargold            cathy.sheargold@gmail.com
# 43064    Chovatiya      Kapila              kapilachaplot@gmail.com
# 43125   Bernadette       Keane         keane.bernadette@hotmail.com
# 43172        Debra     Carmody                debbydoo17@icloud.com
# ...            ...         ...                                  ...
# 186749       Lesly  Marsyeliny                   l35lie@yahoo.co.id
# 186755        Gary     Charles  gary_charles@dominatingkeywords.com
# 186756        Gary     Charles   garycharles@dominatingkeywords.com
# 186761         kat      Pearce                     kwp744@gmail.com
# 186767      Sophia      Prokos              sophiaprokos1@gmail.com
#
#                  Phone Mobile   Birthdate Year of Birth  ...  \
# 32949      61350227812  empty       empty         empty  ...
# 43039      61406283307  empty  1973-05-19          1973  ...
# 43064      61433228722  empty       empty         empty  ...
# 43125      61418337042  empty  1954-11-15          1954  ...
# 43172      61400140449  empty  1975-11-17          1975  ...
# ...                ...    ...         ...           ...  ...
# 186749  61081363403933  empty       empty         empty  ...
# 186755    618185327032  empty       empty         empty  ...
# 186756    618185327032  empty       empty         empty  ...
# 186761    610412929135  empty       empty          1970  ...
# 186767    610412234924  empty       empty          1957  ...
#
#                                   Lead Source Description Lead Regions  \
# 32949                                  Adelaide Home Show         SEAP
# 43039                   BGAU | Web | Form Homepage Bottom         SEAP
# 43064                           BGAU | WEB | Contact Page         SEAP
# 43125   BGAU | FB Competition Automation | w2july19 | ...         SEAP
# 43172   BGAU | FB Competition Automation | w2july19 | ...         SEAP
# ...                                                   ...          ...
# 186749                     BGAU | Web | Newsletter Footer         SEAP
# 186755                          BGAU | WEB | Contact Page         SEAP
# 186756                          BGAU | WEB | Contact Page         SEAP
# 186761  BGAU | Web | Packages Swiss-Belresort Watu Jimbar         SEAP
# 186767          BGAU | Web | Packages Champlung Mas Hotel         SEAP
#
#           Lead Status Booking Status BookRef Email Opt Out Opt In  \
# 32949           empty          empty   empty         empty  empty
# 43039           empty          empty   empty         empty  empty
# 43064           empty          empty   empty         empty  empty
# 43125           empty          empty   empty         empty  empty
# 43172           empty          empty   empty         empty  empty
# ...               ...            ...     ...           ...    ...
# 186749  Not Qualified          empty   empty         false  false
# 186755       New Lead          empty   empty         false  false
# 186756       New Lead          empty   empty         false  false
# 186761   Hot Prospect          empty   empty         false  false
# 186767   Hot Prospect          empty   empty         false  false
#
#        GDPR Compliant Website Comments
# 32949           empty   empty    empty
# 43039           empty   empty    empty
# 43064           empty   empty    empty
# 43125           empty   empty    empty
# 43172           empty   empty    empty
# ...               ...     ...      ...
# 186749          false   empty    empty
# 186755          false   empty    empty
# 186756          false   empty    empty
# 186761          false   empty    empty
# 186767          false   empty    empty
#
# [98795 rows x 34 columns]

# %%
zoho_df.drop_duplicates(subset=['Email', 'Phone', 'Lead Brand', 'Lead Sub-Brand', 'Lead Source'], inplace=True)
zoho_df.reset_index(drop=True, inplace=True)

# hitung jumlah setelah value duplicate dihapus
count_after_dedup_duplicate = zoho_df.shape[0]

zoho_df
# Out:
#                       Record Id         Created Time Created Date First Name  \
# 0      zcrm_3584690000001232061  2019-01-30 12:28:39        empty  Juliannki
# 1      zcrm_3584690000001866211  2019-02-12 16:02:53        empty     Hector
# 2      zcrm_3584690000001872139  2019-02-12 09:33:16        empty     Tracey
# 3      zcrm_3584690000001906064  2019-02-13 11:18:32        empty       Lisa
# 4      zcrm_3584690000002009049  2019-02-14 11:51:29        empty    Michael
# ...                         ...                  ...          ...        ...
# 87971  zcrm_3584690000546051001  2025-05-10 01:53:34        empty       Gary
# 87972  zcrm_3584690000548345001  2025-05-15 05:52:06        empty     Sophia
# 87973  zcrm_3584690000559050001  2025-06-21 06:14:05        empty       Sean
# 87974  zcrm_3584690000562557001  2025-07-08 21:37:51        empty      Vicki
# 87975  zcrm_3584690000565112001  2025-07-17 10:41:53        empty    Helleni
#
#          Last Name                                Email         Phone Mobile  \
# 0         Schembri           littlebearrock@hotmail.com   61405100858  empty
# 1           Paskal             sweetvicious89@gmail.com   61419998833  empty
# 2           Benson            st.benson@optusnet.com.au    6142169264  empty
# 3         Bascombe            lisa.bascombe@bigpond.com   61417900028  empty
# 4             Rout                mjr_59@hotmail.com.au   61889569646  empty
# ...            ...                                  ...           ...    ...
# 87971      Charles  gary.charles@dominatingkeywords.com  618054002077  empty
# 87972       Prokos              sophiaprokos1@gmail.com  610412234924  empty
# 87973        Hicks      seanhicks@dominate-keywords.com  618054002077  empty
# 87974     Richards          vickirichards57@outlook.com   61402441867  empty
# 87975  Paora-Quirk                     quirky@gmail.com  610490899110  empty
#
#         Birthdate Year of Birth  ...  \
# 0      1964-01-10          1964  ...
# 1      1991-03-20          1991  ...
# 2      1959-08-18          1959  ...
# 3      1966-10-06          1966  ...
# 4      1961-09-07          1961  ...
# ...           ...           ...  ...
# 87971       empty         empty  ...
# 87972       empty          1957  ...
# 87973       empty         empty  ...
# 87974       empty          1957  ...
# 87975       empty         empty  ...
#
#                           Lead Source Description Lead Regions    Lead Status  \
# 0                                           empty         SEAP          empty
# 1                                    We Love Bali         SEAP          empty
# 2                                           empty         SEAP          empty
# 3                                    We Love Bali         SEAP          empty
# 4                                    We Love Bali         SEAP          empty
# ...                                           ...          ...            ...
# 87971                   BGAU | WEB | Contact Page         SEAP       New Lead
# 87972  BGAU | Web | Packages Melasti Beach Resort         SEAP   Hot Prospect
# 87973                   BGAU | WEB | Contact Page         SEAP       New Lead
# 87974   BGAU | Web | Packages Champlung Mas Hotel         SEAP  Not Qualified
# 87975           BGAU | Web | Form Homepage Bottom         SEAP   Hot Prospect
#
#       Booking Status BookRef Email Opt Out Opt In GDPR Compliant Website  \
# 0              empty   empty         empty  empty          empty   empty
# 1              empty   empty         empty  empty          empty   empty
# 2              empty   empty         empty  empty          empty   empty
# 3              empty   empty         empty  empty          empty   empty
# 4              empty   empty         empty  empty          empty   empty
# ...              ...     ...           ...    ...            ...     ...
# 87971          empty   empty         false  false          false   empty
# 87972          empty   empty         false  false          false   empty
# 87973          empty   empty         false  false          false   empty
# 87974          empty   empty         false  false          false   empty
# 87975          empty   empty         false  false          false   empty
#
#       Comments
# 0        empty
# 1        empty
# 2        empty
# 3        empty
# 4        empty
# ...        ...
# 87971    empty
# 87972    empty
# 87973    empty
# 87974    empty
# 87975    empty
#
# [87976 rows x 34 columns]

# %%
# Cek leads test
test_leads = zoho_df.loc[
    
        zoho_df['Email'].str.contains('^test@', flags=re.I, regex=True) |
        zoho_df['Email'].str.contains('\+test', flags=re.I, regex=True) |
    
        zoho_df['First Name'].str.contains('^test$', flags=re.I, regex=True) |
        zoho_df['Last Name'].str.contains('^test$', flags=re.I, regex=True) |

        zoho_df['First Name'].str.contains('test 1', flags=re.I, regex=True) |
        zoho_df['Last Name'].str.contains('test 2', flags=re.I, regex=True)|
        zoho_df['First Name'].str.contains('test1', flags=re.I, regex=True) |
        zoho_df['Last Name'].str.contains('test2', flags=re.I, regex=True)|

        zoho_df['First Name'].str.contains(' test ', flags=re.I, regex=True) | 
        zoho_df['Last Name'].str.contains(' test ', flags=re.I, regex=True) | 
        zoho_df['Last Name'].str.contains(' test$', flags=re.I, regex=True)
    ]

count_leads_test = test_leads.shape[0]

# test_leads.to_excel(r'C:\Users\fajar.fatoni\Documents\Python\Data\test_leads_2.xlsx', index=False)
test_leads
# Out:
#                       Record Id         Created Time Created Date First Name  \
# 517    zcrm_3584690000006082754  2019-04-02 03:11:29   2015-05-12      empty
# 518    zcrm_3584690000006082755  2019-04-02 03:11:29   2015-05-12      empty
# 519    zcrm_3584690000006082759  2019-04-02 03:11:29   2015-05-12    Hosanna
# 520    zcrm_3584690000006082761  2019-04-02 03:11:29   2015-05-12      empty
# 521    zcrm_3584690000006082763  2019-04-02 03:11:29   2015-05-12      empty
# 57428  zcrm_3584690000132257487  2019-10-15 16:56:54        empty        eka
# 76266  zcrm_3584690000204748146  2020-07-14 16:26:56        empty        eka
# 76269  zcrm_3584690000206300798  2020-07-21 17:05:55        empty        eka
# 76270  zcrm_3584690000207801542  2020-07-29 14:27:06        empty        eka
# 76272  zcrm_3584690000207810252  2020-07-29 15:09:37        empty        eka
# 76273  zcrm_3584690000207811246  2020-07-29 15:19:16        empty        eka
# 76274  zcrm_3584690000207811300  2020-07-29 15:33:41        empty        eka
# 76275  zcrm_3584690000207812513  2020-07-29 14:25:30        empty        eka
# 83359  zcrm_3584690000414409002  2022-11-30 23:04:39        empty       Test
# 84418  zcrm_3584690000419010693  2022-12-23 14:21:14        empty       test
#
#           Last Name                                        Email  \
# 517           empty                                test@bali.com
# 518           empty                               test@benny.com
# 519         Hosanna                                test@mail.com
# 520           empty                                test@test.net
# 521           empty                               test@tests.com
# 57428      suryawan                    guseka.dev+test@gmail.com
# 76266          test            eka.suryawan+12345@karmagroup.com
# 76269          test             eka.suryawan+1917@karmagroup.com
# 76270          test            eka.suryawan+1bgau@karmagroup.com
# 76272      test api  eka.suryawan+testcontactbgau@karmagroup.com
# 76273  test checkin      eka.suryawan+testcheckin@karmagroup.com
# 76274          test     eka.suryawan+newsletterau@karmagroup.com
# 76275          test          eka.suryawan+123bgau@karmagroup.com
# 83359          Test                           test.test@test.com
# 84418          test                    chico.naga@karmagroup.com
#
#                 Phone         Mobile   Birthdate Year of Birth  ...  \
# 517       61361254566          empty       empty         empty  ...
# 518       61361767767    61361232211       empty         empty  ...
# 519        6117324567  9718754212356  1989-09-11          1989  ...
# 520       61361890898          empty       empty         empty  ...
# 521       61909090909          empty       empty         empty  ...
# 57428    618123456789          empty  1964-10-01          1964  ...
# 76266     61891234556          empty       empty         empty  ...
# 76269    618192819181          empty  2020-07-01         empty  ...
# 76270    618192819181          empty       empty          1989  ...
# 76272    618191828222          empty       empty         empty  ...
# 76273     61819281716          empty       empty          1979  ...
# 76274    611781278121          empty       empty         empty  ...
# 76275  61812918191811          empty       empty          1983  ...
# 83359         6112345          empty       empty          1994  ...
# 84418     61852852852          empty  1989-01-24          1989  ...
#
#                                  Lead Source Description Lead Regions  \
# 517                  BaliGetaway AUS Email - Phuket - #1         SEAP
# 518                  BaliGetaway AUS Email - Phuket - #1         SEAP
# 519    BGAU - Digital - EDM - w2apr17 - Fave Hotel Um...        Other
# 520                BaliGetaway AUS Email - Phuket - $199         SEAP
# 521                                   Web Originate - J4         SEAP
# 57428  BGAU | FB Competition | w3aug19 | Big Giveaway...         SEAP
# 76266                      BGAU | Web | Newsletter Popup         SEAP
# 76269                  BGAU | Web | Form Homepage Bottom         SEAP
# 76270                  BGAU | Web | Form Homepage Bottom         SEAP
# 76272                          BGAU | WEB | Contact Page         SEAP
# 76273          BGAU | Web | Packages Alea Hotel Seminyak         SEAP
# 76274                      BGAU | Web | Newsletter Popup         SEAP
# 76275                  BGAU | Web | Form Homepage Bottom         SEAP
# 83359         BGAU | Web | Packages Sense Hotel Seminyak         SEAP
# 84418                            AU | FB LP | Eden Hotel         SEAP
#
#          Lead Status Booking Status BookRef Email Opt Out Opt In  \
# 517            empty          empty   empty         empty  empty
# 518            empty          empty   empty         empty  empty
# 519            empty          empty   empty         empty  empty
# 520            empty          empty   empty         empty  empty
# 521            empty          empty   empty         empty  empty
# 57428          empty          empty   empty         empty  empty
# 76266          empty          empty   empty         empty  empty
# 76269          empty          empty   empty         empty  empty
# 76270   Hot Prospect          empty   empty         empty  empty
# 76272  Not Qualified          empty   empty         empty  empty
# 76273   Hot Prospect          empty   empty         empty  empty
# 76274          empty          empty   empty         empty  empty
# 76275  Not Qualified          empty   empty         empty  empty
# 83359   Hot Prospect          empty   empty         empty  empty
# 84418   Hot Prospect          empty   empty         empty  empty
#
#       GDPR Compliant Website Comments
# 517            empty   empty    empty
# 518            empty   empty    empty
# 519            empty   empty    empty
# 520            empty   empty    empty
# 521            empty   empty    empty
# 57428          empty   empty    empty
# 76266          empty   empty    empty
# 76269          empty   empty    empty
# 76270          empty   empty    empty
# 76272          empty   empty    empty
# 76273          empty   empty    empty
# 76274          empty   empty    empty
# 76275          empty   empty    empty
# 83359          empty   empty    empty
# 84418          empty   empty    empty
#
# [15 rows x 34 columns]

# %%
zoho_df.drop(test_leads.index, inplace=True)
zoho_df.reset_index(drop=True, inplace=True)

count_after_dedup_test = zoho_df.shape[0]

# %%
# Cek Email OTA
email_OTA = m.find_OTA(zoho_df, 'Email')
count_email_OTA = email_OTA.shape[0]
# email_OTA.to_excel(r'C:\Users\fajar.fatoni\Documents\Python\Data\email_OTA.xlsx', index=False)

email_OTA
# Out:
#                       Record Id         Created Time Created Date First Name  \
# 1570   zcrm_3584690000006086404  2019-04-02 03:11:49   2015-05-12      empty
# 3633   zcrm_3584690000006093888  2019-04-02 03:12:29   2017-03-27       Brad
# 3818   zcrm_3584690000006094519  2019-04-02 03:12:33   2015-03-18      empty
# 6378   zcrm_3584690000006103775  2019-04-02 03:13:24   2015-03-10      David
# 9134   zcrm_3584690000006113520  2019-04-02 03:14:18   2015-03-26       Mary
# 9218   zcrm_3584690000006113893  2019-04-02 03:14:20   2015-05-12      empty
# 10599  zcrm_3584690000006118919  2019-04-02 03:14:48   2015-05-12      empty
# 11991  zcrm_3584690000006123940  2019-04-02 03:15:16   2015-03-27      Ralph
# 14184  zcrm_3584690000006132097  2019-04-02 03:16:02   2015-05-12      empty
# 18096  zcrm_3584690000006146772  2019-04-02 03:17:25   2015-05-12      empty
# 19376  zcrm_3584690000006151028  2019-04-02 03:17:48   2017-05-26      empty
# 20878  zcrm_3584690000006156464  2019-04-02 03:18:19   2015-03-27    Bronwyn
# 22757  zcrm_3584690000006163351  2019-04-02 03:18:59   2015-05-12      Cathy
# 23985  zcrm_3584690000006167639  2019-04-02 03:19:24   2015-05-12      empty
# 27941  zcrm_3584690000006181958  2019-04-02 03:20:47   2015-04-22      Renae
# 30097  zcrm_3584690000006189397  2019-04-02 03:21:31   2015-05-12      empty
# 35241  zcrm_3584690000006203189  2019-04-02 03:22:53   2015-03-18         Jo
# 39850  zcrm_3584690000006220117  2019-04-02 03:24:36   2015-05-12      empty
# 39851  zcrm_3584690000006220118  2019-04-02 03:24:36   2015-05-12      empty
# 41404  zcrm_3584690000006225826  2019-04-02 03:25:11   2015-05-12      empty
# 42870  zcrm_3584690000007371951  2019-04-02 05:49:40   2015-05-12      empty
# 51554  zcrm_3584690000105123501  2019-08-26 07:17:30        empty      Wayne
# 53636  zcrm_3584690000112825999  2019-09-07 17:04:19        empty     Simone
# 60371  zcrm_3584690000142087661  2019-11-12 05:18:35        empty       Mark
# 64384  zcrm_3584690000151098067  2019-12-10 19:47:33        empty     Daniel
# 65925  zcrm_3584690000155746448  2019-12-28 09:54:25        empty     Debbie
# 66611  zcrm_3584690000156406741  2019-12-31 15:27:19        empty      Jodie
# 72165  zcrm_3584690000163742830  2020-02-07 11:22:11        empty      Tiago
# 72170  zcrm_3584690000163747377  2020-02-07 11:22:43        empty      Tiago
# 75898  zcrm_3584690000173187073  2020-03-11 05:25:47        empty     Nadine
# 78792  zcrm_3584690000375841641  2022-06-17 16:38:02        empty     Corbin
# 78802  zcrm_3584690000375863468  2022-06-17 16:33:29        empty     Corbin
# 80843  zcrm_3584690000396635359  2022-09-02 12:00:58        empty     Daniel
# 85177  zcrm_3584690000421328046  2023-01-08 10:46:22        empty      empty
# 86128  zcrm_3584690000424740220  2023-01-26 09:54:41        empty      empty
#
#                       Last Name                            Email  \
# 1570                      empty      ikelly@pinnacletours.com.au
# 3633                      Bunce          brad@gowesttours.com.au
# 3818                      Ralph             ralph@awtours.com.au
# 6378                      Smith       dave.trike.tours@gmail.com
# 9134                    Toulmin          marytourmin@bigpond.com
# 9218                      empty            vinestour@hotmail.com
# 10599                     empty  info@essentialwinetourguide.com
# 11991                  Clissold              info@awtours.com.au
# 14184                     empty                john@atour.com.au
# 18096                     empty         leeannontour@hotmail.com
# 19376                     empty          jagodadragi@hotmail.com
# 20878                    Latour         bronwyn.latour@gmail.com
# 22757                   Phillyb             contours@aapt.net.au
# 23985                     empty         neil@grandtourer.comm.au
# 27941                     Baker            renontour@yahoo.co.nz
# 30097                     empty               woktours@gmail.com
# 35241                    Ellies       jo.ellies@aptouring.com.au
# 39850                     empty      debbieventouras@gotmail.com
# 39851                     empty      debbieventouras@hotmail.com
# 41404                     empty         mickyontourusa@gmail.com
# 42870                     empty      mckenziesontour@bigpond.com
# 51554                    Squire         amazeintours@outlook.com
# 53636                     Wells        simsworldtour@hotmail.com
# 60371                      Beck        brummieontour@hotmail.com
# 64384                   Bennett      daniel@goldrushtours.com.au
# 65925                 Ventouras      debbieventouras@hotmail.com
# 66611                Tourtouras       jodie.tourtouras@gmail.com
# 72165                Dallamaria      tiagodallamaria@hotmail.com
# 72170                Dallamaria        tiagodallamaria@gmail.com
# 75898                     Rhook            nudieontour@gmail.com
# 78792                      Nash      cnash@tourism.australia.com
# 78802                      Nash      cnash@tourism.australia.com
# 80843                    Lohrey        wolfpacktouring@gmail.com
# 85177  Barbara Koryzna Kijowski         alltours@optusnet.com.au
# 86128          Robyn Letourneau          rletourneau@bigpond.com
#
#               Phone Mobile   Birthdate Year of Birth  ...  \
# 1570    61413122872  empty       empty         empty  ...
# 3633    61458066004  empty       empty         empty  ...
# 3818    61265877188  empty       empty         empty  ...
# 6378    61439079201  empty       empty         empty  ...
# 9134    61429372833  empty       empty         empty  ...
# 9218    61422245154  empty       empty         empty  ...
# 10599   61407445570  empty       empty         empty  ...
# 11991   61265877144  empty       empty         empty  ...
# 14184   61407823408  empty       empty         empty  ...
# 18096   61416336524  empty       empty         empty  ...
# 19376   61449759615  empty       empty         empty  ...
# 20878   61412686403  empty       empty         empty  ...
# 22757   61400207201  empty       empty         empty  ...
# 23985   61425706795  empty       empty         empty  ...
# 27941   61427172156  empty       empty         empty  ...
# 30097   61892041001  empty       empty         empty  ...
# 35241   61417950982  empty       empty         empty  ...
# 39850   61439918880  empty       empty         empty  ...
# 39851   61893426892  empty       empty         empty  ...
# 41404   61417332790  empty       empty         empty  ...
# 42870   61412444108  empty       empty         empty  ...
# 51554   61422576019  empty  2019-02-09          2019  ...
# 53636   61412909902  empty  1980-11-25          1980  ...
# 60371   61452456232  empty  1975-06-14          1975  ...
# 64384   61411373602  empty  1974-08-10          1974  ...
# 65925  610439918880  empty  1963-08-16          1963  ...
# 66611   61414307207  empty  1974-12-20          1974  ...
# 72165   61401478176  empty  1984-05-31         empty  ...
# 72170   61401478176  empty  1984-05-31         empty  ...
# 75898   61419868300  empty  1973-02-02         empty  ...
# 78792   61405486322  empty       empty         empty  ...
# 78802   61405486322  empty  1990-11-30          1990  ...
# 80843   61409203420  empty  1993-04-17         empty  ...
# 85177   61414558292  empty  1957-03-08         empty  ...
# 86128  610402008495  empty  1962-04-23         empty  ...
#
#                                  Lead Source Description Lead Regions  \
# 1570                    PAKRE - Perth Airport Prize Draw         SEAP
# 3633   BGAU - Digital - EDM - w3mar17 - Sense Hotel S...         SEAP
# 3818                         Web Originate - Fave Hotels         SEAP
# 6378                               Facebook YTG - Phuket         SEAP
# 9134                                PAVT - Perth Airport         SEAP
# 9218                                               empty         SEAP
# 10599         Margaret River Wine Regional Festival 2010         SEAP
# 11991              Web Originate - Seminyak Square Offer         SEAP
# 14184                  PAKRE - Perth Airport Karma Royal         SEAP
# 18096               YGT - FB - Phuket - James Bond Offer         SEAP
# 19376  BGAU - Digital - FB - w3may17 - Fave Hotel Umalas         SEAP
# 20878                           Google Lead Thailand New         SEAP
# 22757                   Everywoman Expo, 27-29 June 2008         SEAP
# 23985                        Web Originate - Fave Hotels         SEAP
# 27941              Every Woman Expo Perth, 15-17 June 07         SEAP
# 30097                      Bali Getaway RBBC Seminyak #2         SEAP
# 35241                                        Show Data 2         SEAP
# 39850                        DBM - FB BGAU - Tusita $159         SEAP
# 39851                BGAU - FB - W2Feb15 - Champlung Mas         SEAP
# 41404          BGAU - FB - JS - W5Jan15 - The Oasis Kuta         SEAP
# 42870                           Restaurant Survey (Rosy)         SEAP
# 51554  BGAU | FB Competition | w3aug19 | Big Giveaway...         SEAP
# 53636  BGAU | FB Competition | w3aug19 | Big Giveaway...         SEAP
# 60371  BGAU | FB Competition | w3aug19 | Big Giveaway...         SEAP
# 64384  BGAU | FB Competition | w3aug19 | Big Giveaway...         SEAP
# 65925      BGAU | FB LMD | w3oct19 | Win 7 Nights 8 Days         SEAP
# 66611  BGAU | FB Competition | w3aug19 | Big Giveaway...         SEAP
# 72165  BGAU | FB Competition | w3aug19 | Big Giveaway...         SEAP
# 72170  BGAU | FB Competition | w3aug19 | Big Giveaway...         SEAP
# 75898  BGAU | FB Competition | w3aug19 | Big Giveaway...         SEAP
# 78792  BGW | Competition Automation | w2may22 | Every...         SEAP
# 78802  BGW | Competition | w2may22 | Everyone is a Wi...         SEAP
# 80843               BGW | FB Ads | w2aug22 | save 75% v1         SEAP
# 85177  Week 50 -51, Dec 16 - Dec 22, 2022 | AU | FB A...        empty
# 86128  Week 50 -51, Dec 16 - Dec 22, 2022 | AU | FB A...        empty
#
#         Lead Status Booking Status BookRef Email Opt Out Opt In  \
# 1570          empty          empty   empty         empty  empty
# 3633          empty          empty   empty         empty  empty
# 3818          empty          empty   empty         empty  empty
# 6378          empty          empty   empty         empty  empty
# 9134          empty          empty   empty         empty  empty
# 9218          empty          empty   empty         empty  empty
# 10599         empty          empty   empty         empty  empty
# 11991         empty          empty   empty         empty  empty
# 14184         empty          empty   empty         empty  empty
# 18096         empty          empty   empty         empty  empty
# 19376         empty          empty   empty         empty  empty
# 20878         empty          empty   empty         empty  empty
# 22757         empty          empty   empty         empty  empty
# 23985         empty          empty   empty         empty  empty
# 27941         empty          empty   empty         empty  empty
# 30097         empty          empty   empty         empty  empty
# 35241         empty          empty   empty         empty  empty
# 39850         empty          empty   empty         empty  empty
# 39851         empty          empty   empty         empty  empty
# 41404         empty          empty   empty         empty  empty
# 42870         empty          empty   empty         empty  empty
# 51554         empty          empty   empty         empty  empty
# 53636         empty          empty   empty         empty  empty
# 60371         empty          empty   empty         empty  empty
# 64384         empty          empty   empty         empty  empty
# 65925         empty          empty   empty         empty  empty
# 66611         empty          empty   empty         empty  empty
# 72165         empty          empty   empty         empty  empty
# 72170         empty          empty   empty         empty  empty
# 75898         empty          empty   empty         empty  empty
# 78792  Hot Prospect          empty   empty         empty  empty
# 78802  Hot Prospect          empty   empty         empty  empty
# 80843  Hot Prospect          empty   empty         empty  empty
# 85177         empty          empty   empty         empty  empty
# 86128         empty          empty   empty         empty  empty
#
#       GDPR Compliant Website Comments
# 1570           empty   empty    empty
# 3633           empty   empty    empty
# 3818           empty   empty    empty
# 6378           empty   empty    empty
# 9134           empty   empty    empty
# 9218           empty   empty    empty
# 10599          empty   empty    empty
# 11991          empty   empty    empty
# 14184          empty   empty    empty
# 18096          empty   empty    empty
# 19376          empty   empty    empty
# 20878          empty   empty    empty
# 22757          empty   empty    empty
# 23985          empty   empty    empty
# 27941          empty   empty    empty
# 30097          empty   empty    empty
# 35241          empty   empty    empty
# 39850          empty   empty    empty
# 39851          empty   empty    empty
# 41404          empty   empty    empty
# 42870          empty   empty    empty
# 51554          empty   empty    empty
# 53636          empty   empty    empty
# 60371          empty   empty    empty
# 64384          empty   empty    empty
# 65925          empty   empty    empty
# 66611          empty   empty    empty
# 72165          empty   empty    empty
# 72170          empty   empty    empty
# 75898          empty   empty    empty
# 78792          empty   empty    empty
# 78802          empty   empty    empty
# 80843          empty   empty    empty
# 85177          empty   empty    empty
# 86128          empty   empty    empty
#
# [35 rows x 34 columns]

# %%
# delete email OTA
count_after_clean_OTA = m.delete_OTA(zoho_df, 'Email')
# zoho_df.to_excel(r'C:\Users\fajar.fatoni\Documents\Python\Data\after_clean_OTA.xlsx', index=False)

zoho_df
# Out:
#                       Record Id         Created Time Created Date First Name  \
# 0      zcrm_3584690000001232061  2019-01-30 12:28:39        empty  Juliannki
# 1      zcrm_3584690000001866211  2019-02-12 16:02:53        empty     Hector
# 2      zcrm_3584690000001872139  2019-02-12 09:33:16        empty     Tracey
# 3      zcrm_3584690000001906064  2019-02-13 11:18:32        empty       Lisa
# 4      zcrm_3584690000002009049  2019-02-14 11:51:29        empty    Michael
# ...                         ...                  ...          ...        ...
# 87921  zcrm_3584690000546051001  2025-05-10 01:53:34        empty       Gary
# 87922  zcrm_3584690000548345001  2025-05-15 05:52:06        empty     Sophia
# 87923  zcrm_3584690000559050001  2025-06-21 06:14:05        empty       Sean
# 87924  zcrm_3584690000562557001  2025-07-08 21:37:51        empty      Vicki
# 87925  zcrm_3584690000565112001  2025-07-17 10:41:53        empty    Helleni
#
#          Last Name                                Email         Phone Mobile  \
# 0         Schembri           littlebearrock@hotmail.com   61405100858  empty
# 1           Paskal             sweetvicious89@gmail.com   61419998833  empty
# 2           Benson            st.benson@optusnet.com.au    6142169264  empty
# 3         Bascombe            lisa.bascombe@bigpond.com   61417900028  empty
# 4             Rout                mjr_59@hotmail.com.au   61889569646  empty
# ...            ...                                  ...           ...    ...
# 87921      Charles  gary.charles@dominatingkeywords.com  618054002077  empty
# 87922       Prokos              sophiaprokos1@gmail.com  610412234924  empty
# 87923        Hicks      seanhicks@dominate-keywords.com  618054002077  empty
# 87924     Richards          vickirichards57@outlook.com   61402441867  empty
# 87925  Paora-Quirk                     quirky@gmail.com  610490899110  empty
#
#         Birthdate Year of Birth  ...  \
# 0      1964-01-10          1964  ...
# 1      1991-03-20          1991  ...
# 2      1959-08-18          1959  ...
# 3      1966-10-06          1966  ...
# 4      1961-09-07          1961  ...
# ...           ...           ...  ...
# 87921       empty         empty  ...
# 87922       empty          1957  ...
# 87923       empty         empty  ...
# 87924       empty          1957  ...
# 87925       empty         empty  ...
#
#                           Lead Source Description Lead Regions    Lead Status  \
# 0                                           empty         SEAP          empty
# 1                                    We Love Bali         SEAP          empty
# 2                                           empty         SEAP          empty
# 3                                    We Love Bali         SEAP          empty
# 4                                    We Love Bali         SEAP          empty
# ...                                           ...          ...            ...
# 87921                   BGAU | WEB | Contact Page         SEAP       New Lead
# 87922  BGAU | Web | Packages Melasti Beach Resort         SEAP   Hot Prospect
# 87923                   BGAU | WEB | Contact Page         SEAP       New Lead
# 87924   BGAU | Web | Packages Champlung Mas Hotel         SEAP  Not Qualified
# 87925           BGAU | Web | Form Homepage Bottom         SEAP   Hot Prospect
#
#       Booking Status BookRef Email Opt Out Opt In GDPR Compliant Website  \
# 0              empty   empty         empty  empty          empty   empty
# 1              empty   empty         empty  empty          empty   empty
# 2              empty   empty         empty  empty          empty   empty
# 3              empty   empty         empty  empty          empty   empty
# 4              empty   empty         empty  empty          empty   empty
# ...              ...     ...           ...    ...            ...     ...
# 87921          empty   empty         false  false          false   empty
# 87922          empty   empty         false  false          false   empty
# 87923          empty   empty         false  false          false   empty
# 87924          empty   empty         false  false          false   empty
# 87925          empty   empty         false  false          false   empty
#
#       Comments
# 0        empty
# 1        empty
# 2        empty
# 3        empty
# 4        empty
# ...        ...
# 87921    empty
# 87922    empty
# 87923    empty
# 87924    empty
# 87925    empty
#
# [87926 rows x 34 columns]

# %%
# Cek Email Karma
email_karma = m.find_karma(zoho_df, 'Email')
count_email_karma = email_karma.shape[0]
# email_OTA.to_excel(r'C:\Users\fajar.fatoni\Documents\Python\Data\email_OTA.xlsx', index=False)

email_karma
# Out:
#                       Record Id         Created Time Created Date First Name  \
# 13251  zcrm_3584690000006128606  2019-04-02 03:15:42   2015-05-12      empty
# 23778  zcrm_3584690000006167006  2019-04-02 03:19:20   2015-05-12      empty
# 29627  zcrm_3584690000006187649  2019-04-02 03:21:20   2015-05-12      empty
# 40077  zcrm_3584690000006220962  2019-04-02 03:24:41   2015-03-10       Mark
# 43579  zcrm_3584690000071703656  2019-07-15 15:31:05        empty       Sami
# 44554  zcrm_3584690000079416727  2019-07-22 10:22:05        empty       Sami
# 50139  zcrm_3584690000101309601  2019-08-20 17:20:44        empty   Samantha
# 76229  zcrm_3584690000203211836  2020-07-09 12:36:18        empty        eka
# 76230  zcrm_3584690000204843003  2020-07-15 10:13:45        empty       ekas
# 76231  zcrm_3584690000206252828  2020-07-21 13:13:29        empty        eka
# 76232  zcrm_3584690000207809548  2020-07-29 15:39:20        empty        eka
# 81555  zcrm_3584690000404712043  2022-10-14 05:14:52        empty       Ilmo
#
#                    Last Name                                   Email  \
# 13251                  empty              bhanu@royalperspective.com
# 23778                  empty         lee+baligetawaycomau@ccp.com.au
# 29627                  empty               tom2@royalperspective.com
# 40077               Burkster           mark.burke@thebaligetaway.com
# 43579                Benafia              sam.benafia@hotel.discount
# 44554                benafia          sam.benafia@thebaligetaway.com
# 50139               Pennance                 sam@karmaroyalgroup.com
# 76229  test newsletter bg au  eka.suryawan+newsletter@karmagroup.com
# 76230               suryawan      eka.suryawan+191819@karmagroup.com
# 76231              test bgau         eka.suryawan+789@karmagroup.com
# 76232                 testWJ          eka.suryawan+wj@karmagroup.com
# 81555                    Ott        ilmo.ott+baligetaway@hotmail.com
#
#                  Phone       Mobile   Birthdate Year of Birth  ...  \
# 13251   61412123123123        empty       empty         empty  ...
# 23778      61400481632        empty       empty         empty  ...
# 29627      61143143541        empty       empty         empty  ...
# 40077       6199999999  12152266666       empty         empty  ...
# 43579      61123456789        empty  1968-07-07          1968  ...
# 44554      61123456789        empty  1968-07-07          1968  ...
# 50139      61416928269        empty       empty         empty  ...
# 76229      61718271817        empty       empty         empty  ...
# 76230  618192891819181        empty       empty         empty  ...
# 76231    6171817281711        empty  1965-07-30         empty  ...
# 76232     617182718171        empty       empty          1991  ...
# 81555      61450381573        empty  1995-11-02         empty  ...
#
#                                Lead Source Description Lead Regions  \
# 13251          BaliGetaway Seminyak Square AUS Group 1         SEAP
# 23778                                BGAU - FB - Ion 2         SEAP
# 29627     Probably the Best Holiday Offer in the World         SEAP
# 40077                       TTM Survey Form - JIMBARAN         SEAP
# 43579  BGAU | FB Competition | w2july19 | Big Giveaway         SEAP
# 44554  BGAU | FB Competition | w2july19 | Big Giveaway         SEAP
# 50139                                            empty         SEAP
# 76229                          BGAU | Web | Newsletter         SEAP
# 76230                    BGAU | Web | Newsletter Popup         SEAP
# 76231                BGAU | Web | Form Homepage Bottom         SEAP
# 76232              BGAU | Web | Packages Champlung Mas         SEAP
# 81555             BGW | FB Ads | w2aug22 | save 75% v1         SEAP
#
#          Lead Status Booking Status BookRef Email Opt Out Opt In  \
# 13251          empty          empty   empty         empty  empty
# 23778          empty          empty   empty         empty  empty
# 29627          empty          empty   empty         empty  empty
# 40077          empty          empty   empty         empty  empty
# 43579          empty          empty   empty         empty  empty
# 44554          empty          empty   empty         empty  empty
# 50139       New Lead          empty   empty         empty  empty
# 76229          empty          empty   empty         empty  empty
# 76230          empty          empty   empty         empty  empty
# 76231          empty          empty   empty         empty  empty
# 76232  Not Qualified          empty   empty         empty  empty
# 81555   Hot Prospect          empty   empty         empty  empty
#
#       GDPR Compliant Website Comments
# 13251          empty   empty    empty
# 23778          empty   empty    empty
# 29627          empty   empty    empty
# 40077          empty   empty    empty
# 43579          empty   empty    empty
# 44554          empty   empty    empty
# 50139          empty   empty    empty
# 76229          empty   empty    empty
# 76230          empty   empty    empty
# 76231          empty   empty    empty
# 76232          empty   empty    empty
# 81555          empty   empty    empty
#
# [12 rows x 34 columns]

# %%
# delete email Karma
count_after_clean_karma = m.delete_karma(zoho_df, 'Email')
# zoho_df.to_excel(r'C:\Users\fajar.fatoni\Documents\Python\Data\after_clean_OTA.xlsx', index=False)

zoho_df
# Out:
#                       Record Id         Created Time Created Date First Name  \
# 0      zcrm_3584690000001232061  2019-01-30 12:28:39        empty  Juliannki
# 1      zcrm_3584690000001866211  2019-02-12 16:02:53        empty     Hector
# 2      zcrm_3584690000001872139  2019-02-12 09:33:16        empty     Tracey
# 3      zcrm_3584690000001906064  2019-02-13 11:18:32        empty       Lisa
# 4      zcrm_3584690000002009049  2019-02-14 11:51:29        empty    Michael
# ...                         ...                  ...          ...        ...
# 87909  zcrm_3584690000546051001  2025-05-10 01:53:34        empty       Gary
# 87910  zcrm_3584690000548345001  2025-05-15 05:52:06        empty     Sophia
# 87911  zcrm_3584690000559050001  2025-06-21 06:14:05        empty       Sean
# 87912  zcrm_3584690000562557001  2025-07-08 21:37:51        empty      Vicki
# 87913  zcrm_3584690000565112001  2025-07-17 10:41:53        empty    Helleni
#
#          Last Name                                Email         Phone Mobile  \
# 0         Schembri           littlebearrock@hotmail.com   61405100858  empty
# 1           Paskal             sweetvicious89@gmail.com   61419998833  empty
# 2           Benson            st.benson@optusnet.com.au    6142169264  empty
# 3         Bascombe            lisa.bascombe@bigpond.com   61417900028  empty
# 4             Rout                mjr_59@hotmail.com.au   61889569646  empty
# ...            ...                                  ...           ...    ...
# 87909      Charles  gary.charles@dominatingkeywords.com  618054002077  empty
# 87910       Prokos              sophiaprokos1@gmail.com  610412234924  empty
# 87911        Hicks      seanhicks@dominate-keywords.com  618054002077  empty
# 87912     Richards          vickirichards57@outlook.com   61402441867  empty
# 87913  Paora-Quirk                     quirky@gmail.com  610490899110  empty
#
#         Birthdate Year of Birth  ...  \
# 0      1964-01-10          1964  ...
# 1      1991-03-20          1991  ...
# 2      1959-08-18          1959  ...
# 3      1966-10-06          1966  ...
# 4      1961-09-07          1961  ...
# ...           ...           ...  ...
# 87909       empty         empty  ...
# 87910       empty          1957  ...
# 87911       empty         empty  ...
# 87912       empty          1957  ...
# 87913       empty         empty  ...
#
#                           Lead Source Description Lead Regions    Lead Status  \
# 0                                           empty         SEAP          empty
# 1                                    We Love Bali         SEAP          empty
# 2                                           empty         SEAP          empty
# 3                                    We Love Bali         SEAP          empty
# 4                                    We Love Bali         SEAP          empty
# ...                                           ...          ...            ...
# 87909                   BGAU | WEB | Contact Page         SEAP       New Lead
# 87910  BGAU | Web | Packages Melasti Beach Resort         SEAP   Hot Prospect
# 87911                   BGAU | WEB | Contact Page         SEAP       New Lead
# 87912   BGAU | Web | Packages Champlung Mas Hotel         SEAP  Not Qualified
# 87913           BGAU | Web | Form Homepage Bottom         SEAP   Hot Prospect
#
#       Booking Status BookRef Email Opt Out Opt In GDPR Compliant Website  \
# 0              empty   empty         empty  empty          empty   empty
# 1              empty   empty         empty  empty          empty   empty
# 2              empty   empty         empty  empty          empty   empty
# 3              empty   empty         empty  empty          empty   empty
# 4              empty   empty         empty  empty          empty   empty
# ...              ...     ...           ...    ...            ...     ...
# 87909          empty   empty         false  false          false   empty
# 87910          empty   empty         false  false          false   empty
# 87911          empty   empty         false  false          false   empty
# 87912          empty   empty         false  false          false   empty
# 87913          empty   empty         false  false          false   empty
#
#       Comments
# 0        empty
# 1        empty
# 2        empty
# 3        empty
# 4        empty
# ...        ...
# 87909    empty
# 87910    empty
# 87911    empty
# 87912    empty
# 87913    empty
#
# [87914 rows x 34 columns]

# %%
find_member_booking = zoho_df.copy()

find_member_booking.loc[find_member_booking['Phone'].isin(df_booking['Phone1']), 'Same Value Find'] = 'Booking-Phone1'
find_member_booking.loc[find_member_booking['Phone'].isin(df_booking['Mobile']), 'Same Value Find'] = 'Booking-Mobile'
find_member_booking.loc[find_member_booking['Mobile'].isin(df_booking['Phone1']), 'Same Value Find'] = 'Booking-Phone1' 
find_member_booking.loc[find_member_booking['Mobile'].isin(df_booking['Mobile']), 'Same Value Find'] = 'Booking-Mobile'
find_member_booking.loc[find_member_booking['Email'].isin(df_booking['Email']), 'Same Value Find'] = 'Booking-Email'

find_member_booking.loc[find_member_booking['Phone'].isin(df_phone['Mobile']), 'Same Value Find'] = 'Member-Mobile' 
find_member_booking.loc[find_member_booking['Mobile'].isin(df_phone['Mobile']), 'Same Value Find'] = 'Member-Mobile'

find_member_booking.loc[find_member_booking['Email'].isin(df_email['Email']), 'Same Value Find'] = 'Member-Email'

find_member_booking.drop(find_member_booking.loc[find_member_booking['Same Value Find'].isna()].index, inplace=True)

count_booking_dedup = find_member_booking.loc[find_member_booking['Same Value Find'].str.contains('Booking', flags=re.I, regex=True)].shape[0]
count_member_dedup = find_member_booking.loc[find_member_booking['Same Value Find'].str.contains('Member', flags=re.I, regex=True)].shape[0]

find_member_booking.replace('empty', '', inplace=True)
# find_member_booking.to_csv(r'C:\Users\fajar.fatoni\Documents\Python\Data\booking-member-dedup.csv', index=False)
# find_member_booking.to_excel(r'C:\Users\fajar.fatoni\Documents\Python\Data\booking-member-dedup.xlsx', index=False)

#find_member_booking.loc[find_member_booking['Same Value Find'] == 'Booking-Phone1']
# Out:
# C:\Users\fajar.fatoni\AppData\Local\Temp\ipykernel_11596\3664672327.py:19: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   find_member_booking.replace('empty', '', inplace=True)

# %%
# data phone, mobile dam email member yang ada di master data 
count_wash_member = zoho_df.loc[
    zoho_df['Phone'].isin(df_booking['Phone1']) | 
    zoho_df['Phone'].isin(df_booking['Mobile']) |
    zoho_df['Mobile'].isin(df_booking['Phone1']) | 
    zoho_df['Mobile'].isin(df_booking['Mobile']) |
    zoho_df['Email'].isin(df_booking['Email'])| 

    zoho_df['Phone'].isin(df_phone['Mobile']) | 
    zoho_df['Mobile'].isin(df_phone['Mobile']) |

    zoho_df['Email'].isin(df_email['Email'])

].shape[0]

zoho_df.drop(zoho_df.loc[
    zoho_df['Phone'].isin(df_booking['Phone1']) | 
    zoho_df['Phone'].isin(df_booking['Mobile']) |
    zoho_df['Mobile'].isin(df_booking['Phone1']) | 
    zoho_df['Mobile'].isin(df_booking['Mobile']) |
    zoho_df['Email'].isin(df_booking['Email']) |
    
    zoho_df['Phone'].isin(df_phone['Mobile']) | 
    zoho_df['Mobile'].isin(df_phone['Mobile']) |

    zoho_df['Email'].isin(df_email['Email'])

    ].index, inplace=True)
    
zoho_df.reset_index(drop=True, inplace=True)

count_after_wash_member = zoho_df.shape[0]

# %%
# Categorize contacts
m.categorize_contacts(zoho_df)

# Count contact types
count_email_only = (zoho_df['Contact Type'] == 'Email Only').sum()
count_phone_only = (zoho_df['Contact Type'] == 'Phone Only').sum()
count_email_and_phone = (zoho_df['Contact Type'] == 'Email and Phone').sum()
count_blank = (zoho_df['Contact Type'] == 'Blank').sum()

# Remove blank contacts if needed
zoho_df = zoho_df[zoho_df['Contact Type'] != 'Blank']
zoho_df.reset_index(drop=True, inplace=True)

count_after_wash_blank = zoho_df.shape[0]

# %%
arr_dedup = [count_deleted_wrong_format, count_duplicate_general, count_leads_test, count_email_OTA, count_email_karma, count_blank]
count_sum_dedup = sum(arr_dedup)
count_sum_dedup
# Out:
# np.int64(98857)

# %%
print("==========================================================")
print("Summary")
print("==========================================================")
print("Jumlah Keseluruhan Master Zoho : "+str(count_data_awal))
print("Jumlah Filter Leads Awal : "+str(count_filter_awal))
print("Jumlah Format Email Salah : "+str(count_deleted_wrong_format))
print("Jumlah Setelah Clean Format Email Salah : "+str(count_after_deleted_wrong_format))
print("Jumlah Duplicate (Phone, Mobile dan Email) : "+str(count_duplicate_general))
print("Jumlah Setelah Clean Duplicate : "+str(count_after_dedup_duplicate))
print("Jumlah Lead Test : "+str(count_leads_test))
print("Jumlah Setelah Clean Lead Test : "+str(count_after_dedup_test))
# print("Jumlah Lead Do Not Mail : "+str(count_dnm))
# print("Jumlah Setelah Clean Lead Do Not Mail : "+str(count_after_dedup_dnm))
print("Jumlah Email OTA : "+str(count_email_OTA))
print("Jumlah Setelah Clean Email OTA : "+str(count_after_clean_OTA))
print("Jumlah Email Karma : "+str(count_email_karma))
print("Jumlah Setelah Clean Email Karma : "+str(count_after_clean_karma))
print("Jumlah Wash Member : "+str(count_member_dedup))
print("Jumlah Wash Booking : "+str(count_booking_dedup))
print("Jumlah Setelah Wash Member : "+str(count_after_wash_member))
print("Jumlah Phone Email Blank (Setelah phone yang tidak valid dihapus) : "+str(count_blank))
print("Jumlah Setelah Wash Phone Email Blank : "+str(count_after_wash_blank))
print("==========================================================")
print("Contact Type")
print("==========================================================")
print("Jumlah Email Only : "+str(count_email_only))
print("Jumlah Phone Only : "+str(count_phone_only))
print("Jumlah Email dan Phone : "+str(count_email_and_phone))
# Out:
# ==========================================================
# Summary
# ==========================================================
# Jumlah Keseluruhan Master Zoho : 15200087
# Jumlah Filter Leads Awal : 186771
# Jumlah Format Email Salah : 0
# Jumlah Setelah Clean Format Email Salah : 186771
# Jumlah Duplicate (Phone, Mobile dan Email) : 98795
# Jumlah Setelah Clean Duplicate : 87976
# Jumlah Lead Test : 15
# Jumlah Setelah Clean Lead Test : 87961
# Jumlah Email OTA : 35
# Jumlah Setelah Clean Email OTA : 87926
# Jumlah Email Karma : 12
# Jumlah Setelah Clean Email Karma : 87914
# Jumlah Wash Member : 2055
# Jumlah Wash Booking : 3140
# Jumlah Setelah Wash Member : 82719
# Jumlah Phone Email Blank (Setelah phone yang tidak valid dihapus) : 0
# Jumlah Setelah Wash Phone Email Blank : 82719
# ==========================================================
# Contact Type
# ==========================================================
# Jumlah Email Only : 9
# Jumlah Phone Only : 3681
# Jumlah Email dan Phone : 79029

# %%
print("==========================================================")
print("Summary Report")
print("==========================================================")
print("Jumlah Data Awal : "+str(count_filter_awal))
print("Jumlah Wash Dedup : "+str(count_sum_dedup))
print("Jumlah Wash Member : "+str(count_member_dedup))
print("Jumlah Wash Booking : "+str(count_booking_dedup))
print("Jumlah Data Akhir : "+str(count_after_wash_blank))
# Out:
# ==========================================================
# Summary Report
# ==========================================================
# Jumlah Data Awal : 186771
# Jumlah Wash Dedup : 98857
# Jumlah Wash Member : 2055
# Jumlah Wash Booking : 3140
# Jumlah Data Akhir : 82719

# %%
zoho_df['First Name'] = zoho_df['First Name'].str.title()
zoho_df['Last Name'] = zoho_df['Last Name'].str.title()
zoho_df.replace('empty', '', inplace=True, regex=True)

zoho_df
# Out:
# C:\Users\fajar.fatoni\AppData\Local\Temp\ipykernel_11596\657929512.py:3: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   zoho_df.replace('empty', '', inplace=True, regex=True)
#                       Record Id        Created Time Created Date First Name  \
# 0      zcrm_3584690000001866211 2019-02-12 16:02:53                  Hector
# 1      zcrm_3584690000001872139 2019-02-12 09:33:16                  Tracey
# 2      zcrm_3584690000001906064 2019-02-13 11:18:32                    Lisa
# 3      zcrm_3584690000002009049 2019-02-14 11:51:29                 Michael
# 4      zcrm_3584690000002010046 2019-02-14 12:13:05                  Andrea
# ...                         ...                 ...          ...        ...
# 82714  zcrm_3584690000546051001 2025-05-10 01:53:34                    Gary
# 82715  zcrm_3584690000548345001 2025-05-15 05:52:06                  Sophia
# 82716  zcrm_3584690000559050001 2025-06-21 06:14:05                    Sean
# 82717  zcrm_3584690000562557001 2025-07-08 21:37:51                   Vicki
# 82718  zcrm_3584690000565112001 2025-07-17 10:41:53                 Helleni
#
#          Last Name                                Email         Phone Mobile  \
# 0           Paskal             sweetvicious89@gmail.com   61419998833
# 1           Benson            st.benson@optusnet.com.au    6142169264
# 2         Bascombe            lisa.bascombe@bigpond.com   61417900028
# 3             Rout                mjr_59@hotmail.com.au   61889569646
# 4       Pozdwickoa      andreapozdmickova@hotmail.co.uk   61415094478
# ...            ...                                  ...           ...    ...
# 82714      Charles  gary.charles@dominatingkeywords.com  618054002077
# 82715       Prokos              sophiaprokos1@gmail.com  610412234924
# 82716        Hicks      seanhicks@dominate-keywords.com  618054002077
# 82717     Richards          vickirichards57@outlook.com   61402441867
# 82718  Paora-Quirk                     quirky@gmail.com  610490899110
#
#         Birthdate Year of Birth  ... Lead Regions    Lead Status  \
# 0      1991-03-20          1991  ...         SEAP
# 1      1959-08-18          1959  ...         SEAP
# 2      1966-10-06          1966  ...         SEAP
# 3      1961-09-07          1961  ...         SEAP
# 4      1984-03-28          1984  ...    UK/Europe
# ...           ...           ...  ...          ...            ...
# 82714                            ...         SEAP       New Lead
# 82715                      1957  ...         SEAP   Hot Prospect
# 82716                            ...         SEAP       New Lead
# 82717                      1957  ...         SEAP  Not Qualified
# 82718                            ...         SEAP   Hot Prospect
#
#       Booking Status BookRef Email Opt Out Opt In GDPR Compliant Website  \
# 0
# 1
# 2
# 3
# 4
# ...              ...     ...           ...    ...            ...     ...
# 82714                                false  false          false
# 82715                                false  false          false
# 82716                                false  false          false
# 82717                                false  false          false
# 82718                                false  false          false
#
#       Comments     Contact Type
# 0               Email and Phone
# 1               Email and Phone
# 2               Email and Phone
# 3               Email and Phone
# 4               Email and Phone
# ...        ...              ...
# 82714           Email and Phone
# 82715           Email and Phone
# 82716           Email and Phone
# 82717           Email and Phone
# 82718           Email and Phone
#
# [82719 rows x 35 columns]

# %%
zoho_df.replace('empty', '', inplace=True, regex=True)

if (zoho_df.shape[0]>20000):

    row_split = 200000
    file_name = search_value

    m.split_file(zoho_df, row_split, file_name, file_type, target_location)
else:
    zoho_df.to_excel(target_location+'\\'+search_value+"."+file_type, index=False)
