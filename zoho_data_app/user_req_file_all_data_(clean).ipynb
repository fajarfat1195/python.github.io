# %%
import main_module as m
import pandas as pd
import re
import numpy as np

# %load_ext autoreload
# %autoreload 2

dir_path = r'C:\Users\fajar\Documents\Python\Data\Zoho_Backup\2020-2024\\'
dir_path_live = r'C:\Users\fajar\Documents\Python\Data\Zoho_Backup\\'
dir_path_old = r'C:\Users\fajar\Documents\Python\Data\Zoho_Backup\old\\'
file_name = '\Leads_'

cols = ['Record Id',	
'Created Time',
'Created Date',	
'First Name',	
'Last Name',	
'Email',	
'Phone',	
'Mobile',	
'Birthdate',	
'Year of Birth',
'Street',	
'Street2',	
'City',	
'State',	
'Country',	
'Nationality',
'Booking Status', 
'BookRef',
'Departure Date',	
'Arrival Date',	
'Card Type',	
'Marital Status',	
'Lead Brand',	
'Lead Sub-Brand',	
'Lead Source',	
'Lead Locations',	
'Lead Source Description',	
'Lead Regions',
'Lead Status',
'Email Opt Out',	
'Opt In',
'GDPR Compliant',
'Website',
'Comments']
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
column_name = 'Lead Brand'
search_value = 'Karma Resorts'

target_location = r'C:\Users\fajar\Documents\Python\Data'
file_type = 'xlsx'

# %%
path = dir_path+'\\backup.csv'
df_all = pd.read_csv(path, dtype='string', on_bad_lines='skip')
df_all.drop(df_all.loc[df_all['Created Time'].str.len() < 5 ].index, inplace=True)
df_all.reset_index(drop=True, inplace=True)

df_all['Created Time'] = pd.to_datetime(df_all['Created Time'], format='%Y-%m-%d %H:%M:%S')

df_all.shape[0]
df_all
# Out:
#                         Record Id        Created Time Created Date First Name  \
# 0        zcrm_3584690000000404058 2019-01-07 15:08:38   2019-01-06   Nicholas
# 1        zcrm_3584690000000404059 2019-01-07 15:08:38   2019-01-06       Liao
# 2        zcrm_3584690000000404060 2019-01-07 15:08:38   2019-01-06    Vedanta
# 3        zcrm_3584690000000404065 2019-01-07 15:08:38   2019-01-06      Aidai
# 4        zcrm_3584690000000404068 2019-01-07 15:08:38   2019-01-06      Ardra
# ...                           ...                 ...          ...        ...
# 9965978  zcrm_3584690000489266005 2024-03-25 16:19:45         <NA>      Keval
# 9965979  zcrm_3584690000489266034 2024-03-25 16:19:51         <NA>     Suresh
# 9965980  zcrm_3584690000489266063 2024-03-25 17:29:27         <NA>     Nathan
# 9965981  zcrm_3584690000489269015 2024-03-25 16:20:25         <NA>    Leonora
# 9965982  zcrm_3584690000489271002 2024-03-25 18:40:17         <NA>       Annu
#
#           Last Name                                 Email           Phone  \
# 0              Wood            1230woodnicholas@gmail.com     61438600845
# 1              Yuan                      158066546@qq.com   8618718399923
# 2          Abhiyoga            abhiyoga.vedanta@gmail.com   6282146524550
# 3         Atakanova                aidai.nurbek@gmail.com    996779641590
# 4             Ardra            aliefardraqariru@gmail.com  +6282139300818
# ...             ...                                   ...             ...
# 9965978        Gala                   keval2403@gmail.com   +919022872972
# 9965979      Shroff  sureshshroff@breachcandyhospital.org   +919819533303
# 9965980   Fernandes       nathan.fernandes@karmagroup.com  +9179724486854
# 9965981     Hackman                leonora_hf@bigpond.com    +61439855115
# 9965982  Shriwastav          annusrivastava1990@gmail.com   +919561074124
#
#                  Mobile   Birthdate Year of Birth  ...         Arrival Date  \
# 0                  <NA>        <NA>          <NA>  ...  2019-01-06 00:00:00
# 1                  <NA>        <NA>          <NA>  ...  2019-01-06 00:00:00
# 2                  <NA>  2000-07-05          2000  ...  2018-12-01 00:00:00
# 3                  <NA>  1997-02-05          1997  ...  2019-01-06 00:00:00
# 4        +6282139300818  2005-01-20          2005  ...  2018-11-30 00:00:00
# ...                 ...         ...           ...  ...                  ...
# 9965978   +917700904802        <NA>          <NA>  ...           2024-03-21
# 9965979   +919819814280        <NA>          <NA>  ...           2024-03-21
# 9965980            <NA>        <NA>          <NA>  ...                 <NA>
# 9965981            <NA>        <NA>          <NA>  ...           2024-03-14
# 9965982            <NA>        <NA>          <NA>  ...                 <NA>
#
#         Card Type Marital Status           Lead Brand   Lead Sub-Brand  \
# 0            <NA>           <NA>  Timeshare Marketing    Other Bali DB
# 1            <NA>           <NA>  Timeshare Marketing    Other Bali DB
# 2            <NA>        Pelajar  Timeshare Marketing    Other Bali DB
# 3            <NA>         Single  Timeshare Marketing    Other Bali DB
# 4            <NA>          OTHER  Timeshare Marketing    Other Bali DB
# ...           ...            ...                  ...              ...
# 9965978      <NA>           <NA>        Karma Resorts            Other
# 9965979      <NA>           <NA>        Karma Resorts            Other
# 9965980      <NA>           <NA>          Karma Group  Karma Community
# 9965981      <NA>           <NA>        Karma Resorts            Other
# 9965982      <NA>           <NA>  Timeshare Marketing            Other
#
#          Lead Source           Lead Locations  \
# 0               Wifi              Purple Wifi
# 1               Wifi              Purple Wifi
# 2               Wifi              Purple Wifi
# 3               Wifi              Purple Wifi
# 4               Wifi              Purple Wifi
# ...              ...                      ...
# 9965978  Past Guests        Karma Royal Palms
# 9965979  Past Guests  Karma Sitabani, Corbett
# 9965980         Quiz                     <NA>
# 9965981  Past Guests           Karma Jimbaran
# 9965982  Web Enquiry           Karma Sitabani
#
#                                    Lead Source Description Lead Regions  \
# 0                                                     <NA>         SEAP
# 1                                                     <NA>        Other
# 2                                                     <NA>         SEAP
# 3                                                     <NA>    UK/Europe
# 4                                    WIFI USER ID 13494142         SEAP
# ...                                                    ...          ...
# 9965978                                          Viewpoint         <NA>
# 9965979                                          Viewpoint         <NA>
# 9965980  Karma Community | Edition 218 - Words to the Wise        India
# 9965981                                          Viewpoint         <NA>
# 9965982                          Timeshare Booking Request        India
#
#         Lead Status
# 0          New Lead
# 1          New Lead
# 2          New Lead
# 3          New Lead
# 4          New Lead
# ...             ...
# 9965978        <NA>
# 9965979        <NA>
# 9965980        <NA>
# 9965981        <NA>
# 9965982        <NA>
#
# [9965983 rows x 27 columns]

# %%
df_old = m.load_data_multiple(dir_path_old, file_name, cols)
df_old = df_old.reindex(columns=cols)
df_old.shape[0]

df_old['Created Time'] = pd.to_datetime(df_old['Created Time'], format='%Y-%m-%d %H:%M:%S')
df_old['Arrival Date'] = pd.to_datetime(df_old['Arrival Date'], format='%Y-%m-%d')
df_old['Departure Date'] = pd.to_datetime(df_old['Departure Date'], format='%Y-%m-%d')
# fungsi errors cource untuk menhindari error jika value data date null atau kosong
# df['Birthdate'] = pd.to_datetime(df['Birthdate'], format='%Y-%m-%d', errors='coerce')
df_old.dtypes
df_old
# Out:
#                         Record Id        Created Time Created Date First Name  \
# 0        zcrm_3584690000000404058 2019-01-07 15:08:38   2019-01-06   Nicholas
# 1        zcrm_3584690000000404059 2019-01-07 15:08:38   2019-01-06       Liao
# 2        zcrm_3584690000000404060 2019-01-07 15:08:38   2019-01-06    Vedanta
# 3        zcrm_3584690000000404065 2019-01-07 15:08:38   2019-01-06      Aidai
# 4        zcrm_3584690000000404068 2019-01-07 15:08:38   2019-01-06      Ardra
# ...                           ...                 ...          ...        ...
# 4717718  zcrm_3584690000475135007 2024-01-01 18:16:02         <NA>    Upendra
# 4717719  zcrm_3584690000475135045 2024-01-01 18:16:37         <NA>      Mehul
# 4717720  zcrm_3584690000475136005 2024-01-01 18:17:13         <NA>      swati
# 4717721  zcrm_3584690000475138034 2024-01-01 18:48:36         <NA>      SUMON
# 4717722  zcrm_3584690000475138069 2024-01-01 18:52:24         <NA>      Rohit
#
#          Last Name                       Email           Phone  \
# 0             Wood  1230woodnicholas@gmail.com    +61438600845
# 1             Yuan            158066546@qq.com   8618718399923
# 2         Abhiyoga  abhiyoga.vedanta@gmail.com  +6282146524550
# 3        Atakanova      aidai.nurbek@gmail.com    996779641590
# 4            Ardra  aliefardraqariru@gmail.com  +6282139300818
# ...            ...                         ...             ...
# 4717718     Mishra       upendra.sir@gmail.com   +919036084550
# 4717719  Prajapati     mehul.m111985@gmail.com   +919714713689
# 4717720   agarwala         cswatiadv@gmail.com   +919733055636
# 4717721      SAHOO        sumonsahoo@gmail.com   +918910484814
# 4717722      Kadam      rohit0918.rk@gmail.com   +919819185446
#
#                  Mobile   Birthdate Year of Birth  ...   Lead Source  \
# 0                  <NA>        <NA>          <NA>  ...          Wifi
# 1                  <NA>        <NA>          <NA>  ...          Wifi
# 2                  <NA>  2000-07-05          2000  ...          Wifi
# 3                  <NA>  1997-02-05          1997  ...          Wifi
# 4        +6282139300818  2005-01-20          2005  ...          Wifi
# ...                 ...         ...           ...  ...           ...
# 4717718            <NA>        <NA>          <NA>  ...   Web Enquiry
# 4717719            <NA>        <NA>          <NA>  ...  Facebook Ads
# 4717720            <NA>        <NA>          <NA>  ...  Facebook Ads
# 4717721            <NA>        <NA>          <NA>  ...  Facebook Ads
# 4717722            <NA>        <NA>          <NA>  ...  Facebook Ads
#
#                  Lead Locations      Lead Source Description Lead Regions  \
# 0                          <NA>                  Purple Wifi         SEAP
# 1                          <NA>                  Purple Wifi        Other
# 2                          <NA>                  Purple Wifi         SEAP
# 3                          <NA>                  Purple Wifi    UK/Europe
# 4                       Mall 21                  Purple Wifi         SEAP
# ...                         ...                          ...          ...
# 4717718  Karma Sunshine Village    Timeshare Booking Request        India
# 4717719                 General  IND | FB MF | Lead captured         <NA>
# 4717720            Karma Martam         IND | FB MF | Martam         <NA>
# 4717721            Karma Martam         IND | FB MF | Martam         <NA>
# 4717722             Royal Palms            IND | FB AF | KRP         <NA>
#
#         Lead Status Email Opt Out Opt In GDPR Compliant  \
# 0          New Lead         false  false          false
# 1          New Lead         false  false          false
# 2          New Lead         false  false          false
# 3          New Lead         false  false          false
# 4          New Lead         false  false          false
# ...             ...           ...    ...            ...
# 4717718        <NA>         false   true           true
# 4717719        <NA>         false  false          false
# 4717720        <NA>         false  false          false
# 4717721        <NA>         false  false          false
# 4717722        <NA>         false  false          false
#
#                                                    Website Comments
# 0                                                     <NA>     <NA>
# 1                                                     <NA>     <NA>
# 2                                                     <NA>     <NA>
# 3                                                     <NA>     <NA>
# 4                                                     <NA>     <NA>
# ...                                                    ...      ...
# 4717718  https://karmagroup.com/find-destination/karma-...     <NA>
# 4717719                                               <NA>     <NA>
# 4717720                                               <NA>     <NA>
# 4717721                                               <NA>     <NA>
# 4717722                                               <NA>     <NA>
#
# [4717723 rows x 34 columns]

# %%
df_live = m.load_data_multiple(dir_path_live, file_name, cols)
df_live = df_live.reindex(columns=cols)
df_live.shape[0]

df_live['Created Time'] = pd.to_datetime(df_live['Created Time'], format='%Y-%m-%d %H:%M:%S')
df_live['Arrival Date'] = pd.to_datetime(df_live['Arrival Date'], format='%Y-%m-%d')
df_live['Departure Date'] = pd.to_datetime(df_live['Departure Date'], format='%Y-%m-%d')
# fungsi errors cource untuk menhindari error jika value data date null atau kosong
# df['Birthdate'] = pd.to_datetime(df['Birthdate'], format='%Y-%m-%d', errors='coerce')
df_live.dtypes
df_live
# Out:
#                        Record Id        Created Time Created Date First Name  \
# 0       zcrm_3584690000000404602 2019-01-08 11:07:28   2021-07-21   Frederic
# 1       zcrm_3584690000000450071 2019-01-08 16:38:18         <NA>  Sebastian
# 2       zcrm_3584690000000450087 2019-01-08 16:38:18         <NA>    Siobhan
# 3       zcrm_3584690000000450106 2019-01-08 16:38:18         <NA>       Lisa
# 4       zcrm_3584690000000450109 2019-01-08 16:38:18         <NA>  Ana Maria
# ...                          ...                 ...          ...        ...
# 456198  zcrm_3584690000502118035 2024-07-15 17:01:09         <NA>          P
# 456199  zcrm_3584690000502118068 2024-07-15 17:42:29         <NA>    Stephan
# 456200  zcrm_3584690000502119001 2024-07-15 16:34:56         <NA>      Alvin
# 456201  zcrm_3584690000502121002 2024-07-15 17:01:02         <NA>      Quyen
# 456202  zcrm_3584690000502124001 2024-07-15 17:36:44   2024-07-15       <NA>
#
#         Last Name                        Email           Phone         Mobile  \
# 0           Bonin    fredericbonin79@gmail.com  +6281236100502           <NA>
# 1            Rach                         <NA>   +498914342111           <NA>
# 2       Gallagher  gallaghersiobhan@eircom.net    353879597603           <NA>
# 3       Ferkovich         lisajo2009@yahoo.com     14062394749           <NA>
# 4        Weileder     m.weileder@sonnenlink.de     15253234700           <NA>
# ...           ...                          ...             ...            ...
# 456198   M BHADRE           pmbhadre@gmail.com            <NA>           <NA>
# 456199    Joachim          joastephan@yahoo.de   +491621791259           <NA>
# 456200   Cabautan     alvin.cabautan@gmail.com   +610416159756  +610416159756
# 456201     Martin         cindykim10@yahoo.com    +61421235687           <NA>
# 456202   Jen Clay        jenclay22@hotmail.com   +971582433297           <NA>
#
#          Birthdate Year of Birth  ...  Lead Source    Lead Locations  \
# 0       1981-10-03          1981  ...       Agency     Karma Kandara
# 1       1982-04-20          1982  ...  Past Guests     Karma Bavaria
# 2       1973-03-14          1973  ...  Past Guests     Karma Bavaria
# 3       1963-07-08          1963  ...  Past Guests     Karma Bavaria
# 4             <NA>          <NA>  ...        Other     Karma Bavaria
# ...            ...           ...  ...          ...               ...
# 456198        <NA>          <NA>  ...      Webchat              <NA>
# 456199        <NA>          <NA>  ...  Web Enquiry              <NA>
# 456200        <NA>          <NA>  ...  Web Enquiry           General
# 456201        <NA>          <NA>  ...  Web Enquiry   Karma Song Hoai
# 456202        <NA>          <NA>  ...  Web Enquiry  Karma La Herriza
#
#                                   Lead Source Description Lead Regions  \
# 0                                                   KAREN         SEAP
# 1                                                    <NA>    UK/Europe
# 2                                                    <NA>    UK/Europe
# 3                                                    <NA>    UK/Europe
# 4                         MICE Contacts from Ioanna email    UK/Europe
# ...                                                   ...          ...
# 456198               Karma Experience India | Webchat Web        India
# 456199                                    Form Contact Us    UK/Europe
# 456200                       KE | Web | Newsletter Footer         SEAP
# 456201                          Timeshare Booking Request         SEAP
# 456202  Karma La Herriza - Download Wedding Brochure a...  Middle East
#
#           Lead Status Email Opt Out Opt In GDPR Compliant  \
# 0            New Lead         false  false          false
# 1            New Lead          true  false          false
# 2            New Lead         false   true           true
# 3            New Lead          true  false          false
# 4            New Lead         false   true           true
# ...               ...           ...    ...            ...
# 456198           <NA>         false   true          false
# 456199           <NA>         false   true           true
# 456200  Not Qualified         false  false          false
# 456201           <NA>         false   true           true
# 456202           <NA>         false   true          false
#
#                                                   Website Comments
# 0                                                    <NA>     <NA>
# 1                                                    <NA>     <NA>
# 2                                                    <NA>     <NA>
# 3                                                    <NA>     <NA>
# 4                                                    <NA>     <NA>
# ...                                                   ...      ...
# 456198               https://karmagroup.com/member-login/     <NA>
# 456199                 https://karmagroup.com/contact-us/     <NA>
# 456200                   https://www.karmaexperience.com/     <NA>
# 456201                            https://karmagroup.com/     <NA>
# 456202  https://karmagroup.com/weddings-at-karma-la-he...     <NA>
#
# [456203 rows x 34 columns]

# %%
df = pd.concat([df_all,df_old,df_live])
count_data_awal = df.shape[0]
df
# Out:
#                        Record Id        Created Time Created Date First Name  \
# 0       zcrm_3584690000000404058 2019-01-07 15:08:38   2019-01-06   Nicholas
# 1       zcrm_3584690000000404059 2019-01-07 15:08:38   2019-01-06       Liao
# 2       zcrm_3584690000000404060 2019-01-07 15:08:38   2019-01-06    Vedanta
# 3       zcrm_3584690000000404065 2019-01-07 15:08:38   2019-01-06      Aidai
# 4       zcrm_3584690000000404068 2019-01-07 15:08:38   2019-01-06      Ardra
# ...                          ...                 ...          ...        ...
# 456198  zcrm_3584690000502118035 2024-07-15 17:01:09         <NA>          P
# 456199  zcrm_3584690000502118068 2024-07-15 17:42:29         <NA>    Stephan
# 456200  zcrm_3584690000502119001 2024-07-15 16:34:56         <NA>      Alvin
# 456201  zcrm_3584690000502121002 2024-07-15 17:01:02         <NA>      Quyen
# 456202  zcrm_3584690000502124001 2024-07-15 17:36:44   2024-07-15       <NA>
#
#         Last Name                       Email           Phone          Mobile  \
# 0            Wood  1230woodnicholas@gmail.com     61438600845            <NA>
# 1            Yuan            158066546@qq.com   8618718399923            <NA>
# 2        Abhiyoga  abhiyoga.vedanta@gmail.com   6282146524550            <NA>
# 3       Atakanova      aidai.nurbek@gmail.com    996779641590            <NA>
# 4           Ardra  aliefardraqariru@gmail.com  +6282139300818  +6282139300818
# ...           ...                         ...             ...             ...
# 456198   M BHADRE          pmbhadre@gmail.com            <NA>            <NA>
# 456199    Joachim         joastephan@yahoo.de   +491621791259            <NA>
# 456200   Cabautan    alvin.cabautan@gmail.com   +610416159756   +610416159756
# 456201     Martin        cindykim10@yahoo.com    +61421235687            <NA>
# 456202   Jen Clay       jenclay22@hotmail.com   +971582433297            <NA>
#
#          Birthdate Year of Birth  ...  \
# 0             <NA>          <NA>  ...
# 1             <NA>          <NA>  ...
# 2       2000-07-05          2000  ...
# 3       1997-02-05          1997  ...
# 4       2005-01-20          2005  ...
# ...            ...           ...  ...
# 456198        <NA>          <NA>  ...
# 456199        <NA>          <NA>  ...
# 456200        <NA>          <NA>  ...
# 456201        <NA>          <NA>  ...
# 456202        <NA>          <NA>  ...
#
#                                   Lead Source Description Lead Regions  \
# 0                                                    <NA>         SEAP
# 1                                                    <NA>        Other
# 2                                                    <NA>         SEAP
# 3                                                    <NA>    UK/Europe
# 4                                   WIFI USER ID 13494142         SEAP
# ...                                                   ...          ...
# 456198               Karma Experience India | Webchat Web        India
# 456199                                    Form Contact Us    UK/Europe
# 456200                       KE | Web | Newsletter Footer         SEAP
# 456201                          Timeshare Booking Request         SEAP
# 456202  Karma La Herriza - Download Wedding Brochure a...  Middle East
#
#           Lead Status Booking Status BookRef Email Opt Out Opt In  \
# 0            New Lead           <NA>    <NA>          <NA>   <NA>
# 1            New Lead           <NA>    <NA>          <NA>   <NA>
# 2            New Lead           <NA>    <NA>          <NA>   <NA>
# 3            New Lead           <NA>    <NA>          <NA>   <NA>
# 4            New Lead           <NA>    <NA>          <NA>   <NA>
# ...               ...            ...     ...           ...    ...
# 456198           <NA>           <NA>    <NA>         false   true
# 456199           <NA>           <NA>    <NA>         false   true
# 456200  Not Qualified           <NA>    <NA>         false  false
# 456201           <NA>           <NA>    <NA>         false   true
# 456202           <NA>           <NA>    <NA>         false   true
#
#        GDPR Compliant                                            Website  \
# 0                <NA>                                               <NA>
# 1                <NA>                                               <NA>
# 2                <NA>                                               <NA>
# 3                <NA>                                               <NA>
# 4                <NA>                                               <NA>
# ...               ...                                                ...
# 456198          false               https://karmagroup.com/member-login/
# 456199           true                 https://karmagroup.com/contact-us/
# 456200          false                   https://www.karmaexperience.com/
# 456201           true                            https://karmagroup.com/
# 456202          false  https://karmagroup.com/weddings-at-karma-la-he...
#
#        Comments
# 0          <NA>
# 1          <NA>
# 2          <NA>
# 3          <NA>
# 4          <NA>
# ...         ...
# 456198     <NA>
# 456199     <NA>
# 456200     <NA>
# 456201     <NA>
# 456202     <NA>
#
# [15139909 rows x 34 columns]

# %%
path = r'G:\.shortcut-targets-by-id\0B_d3smBjzo04eXpvS1NXTWF2RVE\_BOOKING\Booking By Year\FlyBuy Booking Data (BGAU & BGID & KE).xlsx'
df_booking = pd.read_excel(path, dtype='string', sheet_name='BOOKING_BGAU_BGID_KE')

path = r'G:\.shortcut-targets-by-id\0B_d3smBjzo04UUNBME5GOVhoMjA\_ODYSSEY\Phone Members.xlsx'
df_phone = pd.read_excel(path, dtype='string', sheet_name='Sheet1')

path = r'G:\.shortcut-targets-by-id\0B_d3smBjzo04UUNBME5GOVhoMjA\_ODYSSEY\Email Members.xlsx'
df_email = pd.read_excel(path, dtype='string', sheet_name='Sheet1')

# %%
zoho_df = df.loc[df[column_name] == search_value].copy() # menggunakan copy untuk menghindari setting copy warning
zoho_df.reset_index(drop=True, inplace=True)
count_filter_awal = zoho_df.shape[0]

# zoho_df.to_excel(r'C:\Users\fajar\Documents\Python\Data\test_leads.xlsx', index=False)
# mengisi kolom <NA> dengan value string 'empty' supaya mudah mengecek data member dan booking dengan isin

zoho_df.fillna('empty', inplace=True)
zoho_df.sort_values('Created Time', ascending=True)
zoho_df
# Out:
#                        Record Id        Created Time Created Date First Name  \
# 0       zcrm_3584690000000450067 2019-01-08 16:38:18        empty       Andy
# 1       zcrm_3584690000000450071 2019-01-08 16:38:18        empty  Sebastian
# 2       zcrm_3584690000000450087 2019-01-08 16:38:18        empty    Siobhan
# 3       zcrm_3584690000000450106 2019-01-08 16:38:18        empty       Lisa
# 4       zcrm_3584690000000450109 2019-01-08 16:38:18        empty  Ana Maria
# ...                          ...                 ...          ...        ...
# 945614  zcrm_3584690000502093034 2024-07-15 17:02:50        empty        Liz
# 945615  zcrm_3584690000502104001 2024-07-15 15:35:03        empty     DANIIL
# 945616  zcrm_3584690000502106001 2024-07-15 15:42:41   2024-07-15  Katherine
# 945617  zcrm_3584690000502110001 2024-07-15 15:49:19   2024-07-15      James
# 945618  zcrm_3584690000502124001 2024-07-15 17:36:44   2024-07-15      empty
#
#         Last Name                        Email           Phone       Mobile  \
# 0         Hartono    andytjeng_bkr@yahoo.co.id     62315933726  62812352936
# 1            Rach        basti.2004@hotmail.de    498914342111        empty
# 2       Gallagher  gallaghersiobhan@eircom.net    353879597603        empty
# 3       Ferkovich         lisajo2009@yahoo.com     14062394749        empty
# 4        Weileder     m.weileder@sonnenlink.de     15253234700        empty
# ...           ...                          ...             ...          ...
# 945614  Pattenden         lizzyfun@hotmail.com    +61413173819        empty
# 945615     Egorov     egorov.danya98@gmail.com    +79854847378        empty
# 945616          -                        empty  +6262812888724        empty
# 945617      Jones  gdvedwardsmith536@gmail.com      +620000000        empty
# 945618   Jen Clay        jenclay22@hotmail.com   +971582433297        empty
#
#          Birthdate Year of Birth  ...  \
# 0       1970-02-15          1970  ...
# 1       1982-04-20          1982  ...
# 2       1973-03-14          1973  ...
# 3       1963-07-08          1963  ...
# 4            empty         empty  ...
# ...            ...           ...  ...
# 945614       empty         empty  ...
# 945615       empty         empty  ...
# 945616       empty         empty  ...
# 945617       empty         empty  ...
# 945618       empty         empty  ...
#
#                                   Lead Source Description Lead Regions  \
# 0                                                   empty         SEAP
# 1                                                   empty    UK/Europe
# 2                                                   empty    UK/Europe
# 3                                                   empty    UK/Europe
# 4                         MICE Contacts from Ioanna email    UK/Europe
# ...                                                   ...          ...
# 945614            Karma Beach VIP membership sign up 2023         SEAP
# 945615            Karma Beach VIP membership sign up 2023    UK/Europe
# 945616              Karma Reservations - WhatsApp Channel        empty
# 945617              Karma Reservations - WhatsApp Channel        empty
# 945618  Karma La Herriza - Download Wedding Brochure a...  Middle East
#
#        Lead Status Booking Status BookRef Email Opt Out Opt In GDPR Compliant  \
# 0         New Lead          empty   empty         empty  empty          empty
# 1         New Lead          empty   empty         empty  empty          empty
# 2         New Lead          empty   empty         empty  empty          empty
# 3         New Lead          empty   empty         empty  empty          empty
# 4         New Lead          empty   empty         empty  empty          empty
# ...            ...            ...     ...           ...    ...            ...
# 945614       empty          empty   empty         false   true          false
# 945615       empty          empty   empty         false   true          false
# 945616    New Lead          empty   empty         false  false          false
# 945617    New Lead          empty   empty         false  false          false
# 945618       empty          empty   empty         false   true          false
#
#                                                   Website Comments
# 0                                                   empty    empty
# 1                                                   empty    empty
# 2                                                   empty    empty
# 3                                                   empty    empty
# 4                                                   empty    empty
# ...                                                   ...      ...
# 945614            https://karmagroup.com/karma-beach-vip/    empty
# 945615            https://karmagroup.com/karma-beach-vip/    empty
# 945616                                              empty    empty
# 945617                                              empty    empty
# 945618  https://karmagroup.com/weddings-at-karma-la-he...    empty
#
# [945619 rows x 34 columns]

# %%
# data phone, mobile dam email member yang ada di master data (wash member)

m.clean_number(zoho_df, 'Phone')
m.clean_number(zoho_df, 'Mobile')
m.replace_not_valid_to_empty(zoho_df, 'Phone')
m.replace_not_valid_to_empty(zoho_df, 'Mobile')
zoho_df['Email'] = m.lowercase(zoho_df, 'Email')
m.clean_space(zoho_df, 'Email')
m.clean_not_valid_email_format(zoho_df, 'Email')

m.clean_number(df_booking, 'Phone1')
m.clean_number(df_booking, 'Mobile')
df_booking['Email'] = m.lowercase(df_booking, 'Email')
m.clean_space(df_booking, 'Email')
m.clean_not_valid_email_format(df_booking, 'Email')

m.clean_number(df_phone, 'Mobile')

df_email['Email'] = m.lowercase(df_email, 'Email')
m.clean_space(df_email, 'Email')
m.clean_not_valid_email_format(df_email, 'Email')
# Out:
# c:\Users\fajar\Documents\Python\Task Offline\zoho_data_app\main_module.py:67: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[df_columns].replace(' ','', regex=True, inplace=True)
# c:\Users\fajar\Documents\Python\Task Offline\zoho_data_app\main_module.py:68: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[df_columns].replace('[^0-9]','', regex=True, inplace=True)
# c:\Users\fajar\Documents\Python\Task Offline\zoho_data_app\main_module.py:90: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[df_columns].replace(' ','', regex=True, inplace=True)
# c:\Users\fajar\Documents\Python\Task Offline\zoho_data_app\main_module.py:67: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[df_columns].replace(' ','', regex=True, inplace=True)
# c:\Users\fajar\Documents\Python\Task Offline\zoho_data_app\main_module.py:68: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[df_columns].replace('[^0-9]','', regex=True, inplace=True)
# 'Email'

# %%
count_deleted_wrong_format = m.delete_email_wrong_format(zoho_df, 'Email')
count_after_deleted_wrong_format = zoho_df.shape[0]

# %%
# hitung jumlah duplicate
count_duplicate_general = zoho_df.loc[zoho_df.duplicated(subset=['Email', 'Phone', 'Lead Brand', 'Lead Sub-Brand', 'Lead Source'])].shape[0]

zoho_df.loc[zoho_df.duplicated(subset=['Email', 'Phone', 'Lead Brand', 'Lead Sub-Brand', 'Lead Source'])]
# Out:
#                        Record Id        Created Time Created Date  \
# 274     zcrm_3584690000000456543 2019-01-09 11:10:52        empty
# 411     zcrm_3584690000000456890 2019-01-09 11:10:54        empty
# 730     zcrm_3584690000000457444 2019-01-09 11:10:56        empty
# 738     zcrm_3584690000000457453 2019-01-09 11:10:56        empty
# 883     zcrm_3584690000000457811 2019-01-09 11:10:59        empty
# ...                          ...                 ...          ...
# 945325  zcrm_3584690000501980001 2024-07-12 01:20:24   2024-07-11
# 945328  zcrm_3584690000501980176 2024-07-12 17:50:45        empty
# 945331  zcrm_3584690000501980311 2024-07-13 00:24:01        empty
# 945332  zcrm_3584690000501980344 2024-07-13 07:27:21   2024-07-13
# 945353  zcrm_3584690000501997001 2024-07-12 07:28:55        empty
#
#               First Name       Last Name                       Email  \
# 274               Angela      Myerscough                       empty
# 411                 Alex          Shafiq                       empty
# 730                Craig           Blake                       empty
# 738                 Chun       Ming Chan                       empty
# 883            Catherine         Leonard                       empty
# ...                  ...             ...                         ...
# 945325             empty       Aimee lou            amzmcl@gmail.com
# 945328  Kathryn Mei Fern            Chai     kathrynchai18@yahoo.com
# 945331         anastasia          levina   angelina.levina@gmail.com
# 945332             empty  Denise McBride  denisemcbride807@gmail.com
# 945353            Evelyn         Jackson     findmymeaning@gmail.com
#
#                 Phone Mobile Birthdate Year of Birth  ...  \
# 274      612035640799  empty     empty         empty  ...
# 411       33664519310  empty     empty         empty  ...
# 730      612035640799  empty     empty         empty  ...
# 738      612035640799  empty     empty         empty  ...
# 883      612035640799  empty     empty         empty  ...
# ...               ...    ...       ...           ...  ...
# 945325   447305204728  empty     empty         empty  ...
# 945328     6598269028  empty     empty         empty  ...
# 945331  6285318078809  empty     empty         empty  ...
# 945332   447387978333  empty     empty         empty  ...
# 945353    61438633631  empty     empty         empty  ...
#
#                                   Lead Source Description Lead Regions  \
# 274                                                 empty         SEAP
# 411                                                 empty    UK/Europe
# 730                                                 empty         SEAP
# 738                                                 empty         SEAP
# 883                                                 empty         SEAP
# ...                                                   ...          ...
# 945325  Karma Lake Of Menteith - Download Wedding Broc...    UK/Europe
# 945328  Karma Kandara -Download Wedding Brochure at Ka...        Other
# 945331  Karma Kandara -Download Wedding Brochure at Ka...         SEAP
# 945332  Karma Lake Of Menteith - Download Wedding Broc...    UK/Europe
# 945353  Karma Kandara -Download Wedding Brochure at Ka...         SEAP
#
#        Lead Status Booking Status BookRef Email Opt Out Opt In GDPR Compliant  \
# 274       New Lead          empty   empty         empty  empty          empty
# 411       New Lead          empty   empty         empty  empty          empty
# 730       New Lead          empty   empty         empty  empty          empty
# 738       New Lead          empty   empty         empty  empty          empty
# 883       New Lead          empty   empty         empty  empty          empty
# ...            ...            ...     ...           ...    ...            ...
# 945325       empty          empty   empty         false   true           true
# 945328       empty          empty   empty         false   true          false
# 945331       empty          empty   empty         false   true          false
# 945332       empty          empty   empty         false   true           true
# 945353       empty          empty   empty         false   true          false
#
#                                                   Website Comments
# 274                                                 empty    empty
# 411                                                 empty    empty
# 730                                                 empty    empty
# 738                                                 empty    empty
# 883                                                 empty    empty
# ...                                                   ...      ...
# 945325  https://karmagroup.com/weddings-at-karma-lake-...    empty
# 945328  https://karmagroup.com/weddings-at-karma-kanda...    empty
# 945331  https://karmagroup.com/weddings-at-karma-kanda...    empty
# 945332  https://karmagroup.com/weddings-at-karma-lake-...    empty
# 945353  https://karmagroup.com/weddings-at-karma-kanda...    empty
#
# [605452 rows x 34 columns]

# %%
zoho_df.drop_duplicates(subset=['Email', 'Phone', 'Lead Brand', 'Lead Sub-Brand', 'Lead Source'], inplace=True)
zoho_df.reset_index(drop=True, inplace=True)

# hitung jumlah setelah value duplicate dihapus
count_after_dedup_duplicate = zoho_df.shape[0]

zoho_df
# Out:
#                        Record Id        Created Time Created Date First Name  \
# 0       zcrm_3584690000000450067 2019-01-08 16:38:18        empty       Andy
# 1       zcrm_3584690000000450071 2019-01-08 16:38:18        empty  Sebastian
# 2       zcrm_3584690000000450087 2019-01-08 16:38:18        empty    Siobhan
# 3       zcrm_3584690000000450106 2019-01-08 16:38:18        empty       Lisa
# 4       zcrm_3584690000000450109 2019-01-08 16:38:18        empty  Ana Maria
# ...                          ...                 ...          ...        ...
# 340064  zcrm_3584690000502093034 2024-07-15 17:02:50        empty        Liz
# 340065  zcrm_3584690000502104001 2024-07-15 15:35:03        empty     DANIIL
# 340066  zcrm_3584690000502106001 2024-07-15 15:42:41   2024-07-15  Katherine
# 340067  zcrm_3584690000502110001 2024-07-15 15:49:19   2024-07-15      James
# 340068  zcrm_3584690000502124001 2024-07-15 17:36:44   2024-07-15      empty
#
#         Last Name                        Email          Phone       Mobile  \
# 0         Hartono    andytjeng_bkr@yahoo.co.id    62315933726  62812352936
# 1            Rach        basti.2004@hotmail.de   498914342111        empty
# 2       Gallagher  gallaghersiobhan@eircom.net   353879597603        empty
# 3       Ferkovich         lisajo2009@yahoo.com    14062394749        empty
# 4        Weileder     m.weileder@sonnenlink.de    15253234700        empty
# ...           ...                          ...            ...          ...
# 340064  Pattenden         lizzyfun@hotmail.com    61413173819        empty
# 340065     Egorov     egorov.danya98@gmail.com    79854847378        empty
# 340066          -                        empty  6262812888724        empty
# 340067      Jones  gdvedwardsmith536@gmail.com      620000000        empty
# 340068   Jen Clay        jenclay22@hotmail.com   971582433297        empty
#
#          Birthdate Year of Birth  ...  \
# 0       1970-02-15          1970  ...
# 1       1982-04-20          1982  ...
# 2       1973-03-14          1973  ...
# 3       1963-07-08          1963  ...
# 4            empty         empty  ...
# ...            ...           ...  ...
# 340064       empty         empty  ...
# 340065       empty         empty  ...
# 340066       empty         empty  ...
# 340067       empty         empty  ...
# 340068       empty         empty  ...
#
#                                   Lead Source Description Lead Regions  \
# 0                                                   empty         SEAP
# 1                                                   empty    UK/Europe
# 2                                                   empty    UK/Europe
# 3                                                   empty    UK/Europe
# 4                         MICE Contacts from Ioanna email    UK/Europe
# ...                                                   ...          ...
# 340064            Karma Beach VIP membership sign up 2023         SEAP
# 340065            Karma Beach VIP membership sign up 2023    UK/Europe
# 340066              Karma Reservations - WhatsApp Channel        empty
# 340067              Karma Reservations - WhatsApp Channel        empty
# 340068  Karma La Herriza - Download Wedding Brochure a...  Middle East
#
#        Lead Status Booking Status BookRef Email Opt Out Opt In GDPR Compliant  \
# 0         New Lead          empty   empty         empty  empty          empty
# 1         New Lead          empty   empty         empty  empty          empty
# 2         New Lead          empty   empty         empty  empty          empty
# 3         New Lead          empty   empty         empty  empty          empty
# 4         New Lead          empty   empty         empty  empty          empty
# ...            ...            ...     ...           ...    ...            ...
# 340064       empty          empty   empty         false   true          false
# 340065       empty          empty   empty         false   true          false
# 340066    New Lead          empty   empty         false  false          false
# 340067    New Lead          empty   empty         false  false          false
# 340068       empty          empty   empty         false   true          false
#
#                                                   Website Comments
# 0                                                   empty    empty
# 1                                                   empty    empty
# 2                                                   empty    empty
# 3                                                   empty    empty
# 4                                                   empty    empty
# ...                                                   ...      ...
# 340064            https://karmagroup.com/karma-beach-vip/    empty
# 340065            https://karmagroup.com/karma-beach-vip/    empty
# 340066                                              empty    empty
# 340067                                              empty    empty
# 340068  https://karmagroup.com/weddings-at-karma-la-he...    empty
#
# [340069 rows x 34 columns]

# %%
# Cek leads test
test_leads = zoho_df.loc[
    
        zoho_df['Email'].str.contains('^test@', flags=re.I, regex=True) |
        zoho_df['Email'].str.contains('\+test', flags=re.I, regex=True) |
    
        zoho_df['First Name'].str.contains('^test$', flags=re.I, regex=True) |
        zoho_df['Last Name'].str.contains('^test$', flags=re.I, regex=True) |

        zoho_df['First Name'].str.contains('test 1', flags=re.I, regex=True) |
        zoho_df['Last Name'].str.contains('test 2', flags=re.I, regex=True)|
        zoho_df['First Name'].str.contains('test1', flags=re.I, regex=True) |
        zoho_df['Last Name'].str.contains('test2', flags=re.I, regex=True)|

        zoho_df['First Name'].str.contains(' test ', flags=re.I, regex=True) | 
        zoho_df['Last Name'].str.contains(' test ', flags=re.I, regex=True) | 
        zoho_df['Last Name'].str.contains(' test$', flags=re.I, regex=True)
    ]

count_leads_test = test_leads.shape[0]

# test_leads.to_excel(r'C:\Users\fajar\Documents\Python\Data\test_leads_2.xlsx', index=False)
test_leads
# Out:
#                        Record Id        Created Time Created Date First Name  \
# 15066   zcrm_3584690000005952087 2019-04-02 02:15:27   2015-12-21      empty
# 130386  zcrm_3584690000064814887 2019-07-10 13:40:11        empty       Mark
# 153219  zcrm_3584690000174294063 2020-03-13 17:23:03        empty     A2Test
# 154753  zcrm_3584690000206276154 2020-07-21 10:29:26        empty       test
# 185373  zcrm_3584690000305511893 2021-08-10 10:06:23        empty       Test
# ...                          ...                 ...          ...        ...
# 333283  zcrm_3584690000496234769 2024-05-21 14:08:35        empty       test
# 339558  zcrm_3584690000501893461 2024-07-14 20:16:46        empty       Test
# 339646  zcrm_3584690000501908739 2024-07-14 20:18:10        empty       Test
# 339656  zcrm_3584690000501919336 2024-07-12 10:54:31        empty        eka
# 339831  zcrm_3584690000501970085 2024-07-12 11:50:03        empty  izha test
#
#        Last Name                                          Email  \
# 15066      empty                                  test@satu.com
# 130386      Bark                                  test@test.com
# 153219    P2Test      andrea.pavlidis+test213mar@karmagroup.com
# 154753       abu  finneganpennington.sc.817973990@mojorage.life
# 185373   Booking                     hazeline.furing@sojern.com
# ...          ...                                            ...
# 333283      test                       maidapratiwi93@gmail.com
# 339558      Test                                  test@test.com
# 339646      Test                          tekayeg380@cartep.com
# 339656      test              eka.suryawan+test1@karmagroup.com
# 339831      test             izha.mahendra+test1@karmagroup.com
#
#                  Phone       Mobile Birthdate Year of Birth  ...  \
# 15066     628119503646        empty     empty         empty  ...
# 130386     13102592227  13102592227     empty         empty  ...
# 153219    306971212345        empty     empty         empty  ...
# 154753    623224242234        empty     empty         empty  ...
# 185373        98745632        empty     empty         empty  ...
# ...                ...          ...       ...           ...  ...
# 333283  62879877664643        empty     empty         empty  ...
# 339558     61412345678        empty     empty         empty  ...
# 339646     61412345678        empty     empty         empty  ...
# 339656   6281339669949        empty     empty         empty  ...
# 339831   6285151515151        empty     empty         empty  ...
#
#                                   Lead Source Description Lead Regions  \
# 15066                                    Royal Chiang Mai         SEAP
# 130386                                 WIFI USER ID 32811         SEAP
# 153219                     Karma Beach Bali offer sign up    UK/Europe
# 154753            Karma Developments | WEB | Contact Page         SEAP
# 185373                                              empty        empty
# ...                                                   ...          ...
# 333283  Karma Kandara -Download Wedding Brochure at Ka...         SEAP
# 339558  Karma Kandara -Download Wedding Brochure at Ka...         SEAP
# 339646  Karma Kandara -Download Wedding Brochure at Ka...         SEAP
# 339656                        Karma Concierge online form         SEAP
# 339831                        Karma Concierge online form         SEAP
#
#        Lead Status Booking Status BookRef Email Opt Out Opt In GDPR Compliant  \
# 15066        empty          empty   empty         empty  empty          empty
# 130386       empty          empty   empty         empty  empty          empty
# 153219       empty          empty   empty         empty  empty          empty
# 154753       empty          empty   empty         empty  empty          empty
# 185373       empty          empty   empty         empty  empty          empty
# ...            ...            ...     ...           ...    ...            ...
# 333283       empty          empty   empty         false   true          false
# 339558       empty          empty   empty         false   true          false
# 339646       empty          empty   empty         false   true          false
# 339656       empty          empty   empty         false   true          false
# 339831       empty          empty   empty         false   true          false
#
#                                                   Website Comments
# 15066                                               empty    empty
# 130386                                              empty    empty
# 153219                                              empty    empty
# 154753                                              empty    empty
# 185373                                              empty    empty
# ...                                                   ...      ...
# 333283  https://karmagroup.com/weddings-at-karma-kanda...    empty
# 339558  https://karmagroup.com/weddings-at-karma-kanda...    empty
# 339646  https://karmagroup.com/weddings-at-karma-kanda...    empty
# 339656  https://karmaconcierge.karmagroup.com/contact-us/    empty
# 339831  https://karmaconcierge.karmagroup.com/contact-us/    empty
#
# [76 rows x 34 columns]

# %%
zoho_df.drop(test_leads.index, inplace=True)
zoho_df.reset_index(drop=True, inplace=True)

count_after_dedup_test = zoho_df.shape[0]

# %%
# Cek Email OTA
email_OTA = m.find_OTA(zoho_df, 'Email')
count_email_OTA = email_OTA.shape[0]
# email_OTA.to_excel(r'C:\Users\fajar\Documents\Python\Data\email_OTA.xlsx', index=False)

email_OTA
# Out:
#                        Record Id        Created Time Created Date  \
# 130     zcrm_3584690000000456181 2019-01-09 11:10:49        empty
# 474     zcrm_3584690000000456961 2019-01-09 11:10:54        empty
# 688     zcrm_3584690000000457400 2019-01-09 11:10:56        empty
# 1346    zcrm_3584690000000458930 2019-01-09 11:11:06        empty
# 1369    zcrm_3584690000000458955 2019-01-09 11:11:06        empty
# ...                          ...                 ...          ...
# 339455  zcrm_3584690000501825001 2024-07-10 14:30:51   2024-07-10
# 339725  zcrm_3584690000501961123 2024-07-13 18:05:44   2024-07-13
# 339816  zcrm_3584690000501983095 2024-07-13 18:06:14   2024-07-13
# 339823  zcrm_3584690000501993005 2024-07-13 18:05:14   2024-07-13
# 339845  zcrm_3584690000502007001 2024-07-12 17:37:43   2024-07-12
#
#              First Name        Last Name  \
# 130               Aedin  Nic Chonchradha
# 474             Bettina             Bach
# 688            Amandine          Buisson
# 1346               Elke  Rosner-Guderian
# 1369            Soetomo          Soetomo
# ...                 ...              ...
# 339455         Kristian      Vestergaard
# 339725  Sysslomansgatan                -
# 339816           Lardet                -
# 339823            Eagar                -
# 339845             Cara           Gordon
#
#                                          Email          Phone Mobile  \
# 130              achonc637787@guestbooking.com    41795965105  empty
# 474                      bach@guestbooking.com   491776668777  empty
# 688         capucine.dhalluin@eure-tourisme.fr      698312169  empty
# 1346                 er@interalp-touristik.com   436641209565  empty
# 1369                         expedia@tiket.com        6905125  empty
# ...                                        ...            ...    ...
# 339455         kveste.351453@guest.booking.com  6161407848038  empty
# 339725  7x8rwqrrma@m.expediapartnercentral.com        6200000  empty
# 339816  2kxy6o4ntc@m.expediapartnercentral.com        6200000  empty
# 339823         reagar.311981@guest.booking.com        6200000  empty
# 339845         cgordo.763697@guest.booking.com        6200000  empty
#
#          Birthdate Year of Birth  ...                Lead Source Description  \
# 130          empty         empty  ...                                  empty
# 474     1973-12-03          1973  ...                                  empty
# 688          empty         empty  ...                                  empty
# 1346    1975-09-30          1975  ...                                  empty
# 1369    1992-05-30          1992  ...                                  empty
# ...            ...           ...  ...                                    ...
# 339455       empty         empty  ...  Karma Reservations - WhatsApp Channel
# 339725       empty         empty  ...  Karma Reservations - WhatsApp Channel
# 339816       empty         empty  ...  Karma Reservations - WhatsApp Channel
# 339823       empty         empty  ...  Karma Reservations - WhatsApp Channel
# 339845       empty         empty  ...  Karma Reservations - WhatsApp Channel
#
#        Lead Regions Lead Status Booking Status BookRef Email Opt Out Opt In  \
# 130       UK/Europe    New Lead          empty   empty         empty  empty
# 474       UK/Europe    New Lead          empty   empty         empty  empty
# 688       UK/Europe    New Lead          empty   empty         empty  empty
# 1346      UK/Europe    New Lead          empty   empty         empty  empty
# 1369           SEAP    New Lead          empty   empty         empty  empty
# ...             ...         ...            ...     ...           ...    ...
# 339455        empty    New Lead          empty   empty         false  false
# 339725        empty    New Lead          empty   empty         false  false
# 339816        empty    New Lead          empty   empty         false  false
# 339823        empty    New Lead          empty   empty         false  false
# 339845        empty    New Lead          empty   empty         false  false
#
#        GDPR Compliant Website Comments
# 130             empty   empty    empty
# 474             empty   empty    empty
# 688             empty   empty    empty
# 1346            empty   empty    empty
# 1369            empty   empty    empty
# ...               ...     ...      ...
# 339455          false   empty    empty
# 339725          false   empty    empty
# 339816          false   empty    empty
# 339823          false   empty    empty
# 339845          false   empty    empty
#
# [1182 rows x 34 columns]

# %%
# delete email OTA
count_after_clean_OTA = m.delete_OTA(zoho_df, 'Email')
# zoho_df.to_excel(r'C:\Users\fajar\Documents\Python\Data\after_clean_OTA.xlsx', index=False)

zoho_df
# Out:
#                        Record Id        Created Time Created Date First Name  \
# 0       zcrm_3584690000000450067 2019-01-08 16:38:18        empty       Andy
# 1       zcrm_3584690000000450071 2019-01-08 16:38:18        empty  Sebastian
# 2       zcrm_3584690000000450087 2019-01-08 16:38:18        empty    Siobhan
# 3       zcrm_3584690000000450106 2019-01-08 16:38:18        empty       Lisa
# 4       zcrm_3584690000000450109 2019-01-08 16:38:18        empty  Ana Maria
# ...                          ...                 ...          ...        ...
# 338806  zcrm_3584690000502093034 2024-07-15 17:02:50        empty        Liz
# 338807  zcrm_3584690000502104001 2024-07-15 15:35:03        empty     DANIIL
# 338808  zcrm_3584690000502106001 2024-07-15 15:42:41   2024-07-15  Katherine
# 338809  zcrm_3584690000502110001 2024-07-15 15:49:19   2024-07-15      James
# 338810  zcrm_3584690000502124001 2024-07-15 17:36:44   2024-07-15      empty
#
#         Last Name                        Email          Phone       Mobile  \
# 0         Hartono    andytjeng_bkr@yahoo.co.id    62315933726  62812352936
# 1            Rach        basti.2004@hotmail.de   498914342111        empty
# 2       Gallagher  gallaghersiobhan@eircom.net   353879597603        empty
# 3       Ferkovich         lisajo2009@yahoo.com    14062394749        empty
# 4        Weileder     m.weileder@sonnenlink.de    15253234700        empty
# ...           ...                          ...            ...          ...
# 338806  Pattenden         lizzyfun@hotmail.com    61413173819        empty
# 338807     Egorov     egorov.danya98@gmail.com    79854847378        empty
# 338808          -                        empty  6262812888724        empty
# 338809      Jones  gdvedwardsmith536@gmail.com      620000000        empty
# 338810   Jen Clay        jenclay22@hotmail.com   971582433297        empty
#
#          Birthdate Year of Birth  ...  \
# 0       1970-02-15          1970  ...
# 1       1982-04-20          1982  ...
# 2       1973-03-14          1973  ...
# 3       1963-07-08          1963  ...
# 4            empty         empty  ...
# ...            ...           ...  ...
# 338806       empty         empty  ...
# 338807       empty         empty  ...
# 338808       empty         empty  ...
# 338809       empty         empty  ...
# 338810       empty         empty  ...
#
#                                   Lead Source Description Lead Regions  \
# 0                                                   empty         SEAP
# 1                                                   empty    UK/Europe
# 2                                                   empty    UK/Europe
# 3                                                   empty    UK/Europe
# 4                         MICE Contacts from Ioanna email    UK/Europe
# ...                                                   ...          ...
# 338806            Karma Beach VIP membership sign up 2023         SEAP
# 338807            Karma Beach VIP membership sign up 2023    UK/Europe
# 338808              Karma Reservations - WhatsApp Channel        empty
# 338809              Karma Reservations - WhatsApp Channel        empty
# 338810  Karma La Herriza - Download Wedding Brochure a...  Middle East
#
#        Lead Status Booking Status BookRef Email Opt Out Opt In GDPR Compliant  \
# 0         New Lead          empty   empty         empty  empty          empty
# 1         New Lead          empty   empty         empty  empty          empty
# 2         New Lead          empty   empty         empty  empty          empty
# 3         New Lead          empty   empty         empty  empty          empty
# 4         New Lead          empty   empty         empty  empty          empty
# ...            ...            ...     ...           ...    ...            ...
# 338806       empty          empty   empty         false   true          false
# 338807       empty          empty   empty         false   true          false
# 338808    New Lead          empty   empty         false  false          false
# 338809    New Lead          empty   empty         false  false          false
# 338810       empty          empty   empty         false   true          false
#
#                                                   Website Comments
# 0                                                   empty    empty
# 1                                                   empty    empty
# 2                                                   empty    empty
# 3                                                   empty    empty
# 4                                                   empty    empty
# ...                                                   ...      ...
# 338806            https://karmagroup.com/karma-beach-vip/    empty
# 338807            https://karmagroup.com/karma-beach-vip/    empty
# 338808                                              empty    empty
# 338809                                              empty    empty
# 338810  https://karmagroup.com/weddings-at-karma-la-he...    empty
#
# [338811 rows x 34 columns]

# %%
# Cek Email Karma
email_karma = m.find_karma(zoho_df, 'Email')
count_email_karma = email_karma.shape[0]
# email_OTA.to_excel(r'C:\Users\fajar\Documents\Python\Data\email_OTA.xlsx', index=False)

email_karma
# Out:
#                        Record Id        Created Time Created Date First Name  \
# 1010    zcrm_3584690000000458152 2019-01-09 11:11:01        empty      David
# 7420    zcrm_3584690000005935773 2019-04-02 02:13:55   2017-01-18     Nicola
# 9066    zcrm_3584690000005939212 2019-04-02 02:14:14   2015-03-11      empty
# 11374   zcrm_3584690000005944224 2019-04-02 02:14:43   2015-03-11      empty
# 11770   zcrm_3584690000005945055 2019-04-02 02:14:48   2015-03-11      Chris
# ...                          ...                 ...          ...        ...
# 308747  zcrm_3584690000086912611 2019-08-01 16:13:29        empty      empty
# 327958  zcrm_3584690000490771248 2024-04-05 12:07:54        empty     Lottie
# 329363  zcrm_3584690000491983036 2024-04-16 18:26:51        empty    Stephen
# 329409  zcrm_3584690000492392060 2024-04-18 15:56:41        empty      Tanya
# 332374  zcrm_3584690000496311706 2024-05-21 12:46:21   2024-05-21      Maida
#
#           Last Name                               Email           Phone  \
# 1010         Hadson          david@royalperspective.com      6236341519
# 7420         Stokes               nicola.stokes@rci.com    441536314307
# 9066         Adrian                  adrian.lee@rci.com           empty
# 11374         Carol             carol.rodriguez@rci.com           empty
# 11770         Chris                chris.clarke@rci.com           empty
# ...             ...                                 ...             ...
# 308747        empty     mikelionis@karmasanctumsoho.com           empty
# 327958     Phillips      lottie.phillips@karmagroup.com      7824631942
# 329363        Halim   salescoordinator@karmaresorts.com   6281617722971
# 329409  Klimentyeva  tanya.klimentyeva@karmakandara.com   6281138305940
# 332374        Maida      maida.pratiwi@karmaresorts.com  62878900098978
#
#                Mobile   Birthdate Year of Birth  ...  \
# 1010    6281338045821  1969-10-13          1969  ...
# 7420     447961952360  1980-12-31          1980  ...
# 9066            empty       empty         empty  ...
# 11374           empty       empty         empty  ...
# 11770           empty       empty         empty  ...
# ...               ...         ...           ...  ...
# 308747          empty       empty         empty  ...
# 327958          empty  2021-11-17         empty  ...
# 329363          empty       empty         empty  ...
# 329409          empty       empty         empty  ...
# 332374          empty       empty         empty  ...
#
#                                   Lead Source Description Lead Regions  \
# 1010                                                empty         SEAP
# 7420                                       Karma Jimbaran    UK/Europe
# 9066                                                empty         SEAP
# 11374                                               empty         SEAP
# 11770                                               empty         SEAP
# ...                                                   ...          ...
# 308747                                   Rezlynx database        Other
# 327958                                Inner Karma Sanctum    UK/Europe
# 329363  Karma Kandara -Download Wedding Brochure at Ka...         SEAP
# 329409  Karma Kandara -Download Wedding Brochure at Ka...         SEAP
# 332374          Karma Kandara - Weddings at Karma Kandara         SEAP
#
#        Lead Status Booking Status BookRef Email Opt Out Opt In GDPR Compliant  \
# 1010      New Lead          empty   empty         empty  empty          empty
# 7420         empty          empty   empty         empty  empty          empty
# 9066         empty          empty   empty         empty  empty          empty
# 11374        empty          empty   empty         empty  empty          empty
# 11770        empty          empty   empty         empty  empty          empty
# ...            ...            ...     ...           ...    ...            ...
# 308747    New Lead          empty   empty         false  false          false
# 327958    New Lead          empty   empty         false  false          false
# 329363       empty          empty   empty         false   true          false
# 329409       empty          empty   empty         false   true          false
# 332374       empty          empty   empty         false   true          false
#
#                                                   Website Comments
# 1010                                                empty    empty
# 7420                                                empty    empty
# 9066                                                empty    empty
# 11374                                               empty    empty
# 11770                                               empty    empty
# ...                                                   ...      ...
# 308747                                              empty    empty
# 327958                                              empty    empty
# 329363  https://karmagroup.com/weddings-at-karma-kanda...    empty
# 329409  https://karmagroup.com/weddings-at-karma-kanda...    empty
# 332374  https://karmagroup.com/weddings-at-karma-kanda...    empty
#
# [165 rows x 34 columns]

# %%
# delete email Karma
count_after_clean_karma = m.delete_karma(zoho_df, 'Email')
# zoho_df.to_excel(r'C:\Users\fajar\Documents\Python\Data\after_clean_OTA.xlsx', index=False)

zoho_df
# Out:
#                        Record Id        Created Time Created Date First Name  \
# 0       zcrm_3584690000000450067 2019-01-08 16:38:18        empty       Andy
# 1       zcrm_3584690000000450071 2019-01-08 16:38:18        empty  Sebastian
# 2       zcrm_3584690000000450087 2019-01-08 16:38:18        empty    Siobhan
# 3       zcrm_3584690000000450106 2019-01-08 16:38:18        empty       Lisa
# 4       zcrm_3584690000000450109 2019-01-08 16:38:18        empty  Ana Maria
# ...                          ...                 ...          ...        ...
# 338641  zcrm_3584690000502093034 2024-07-15 17:02:50        empty        Liz
# 338642  zcrm_3584690000502104001 2024-07-15 15:35:03        empty     DANIIL
# 338643  zcrm_3584690000502106001 2024-07-15 15:42:41   2024-07-15  Katherine
# 338644  zcrm_3584690000502110001 2024-07-15 15:49:19   2024-07-15      James
# 338645  zcrm_3584690000502124001 2024-07-15 17:36:44   2024-07-15      empty
#
#         Last Name                        Email          Phone       Mobile  \
# 0         Hartono    andytjeng_bkr@yahoo.co.id    62315933726  62812352936
# 1            Rach        basti.2004@hotmail.de   498914342111        empty
# 2       Gallagher  gallaghersiobhan@eircom.net   353879597603        empty
# 3       Ferkovich         lisajo2009@yahoo.com    14062394749        empty
# 4        Weileder     m.weileder@sonnenlink.de    15253234700        empty
# ...           ...                          ...            ...          ...
# 338641  Pattenden         lizzyfun@hotmail.com    61413173819        empty
# 338642     Egorov     egorov.danya98@gmail.com    79854847378        empty
# 338643          -                        empty  6262812888724        empty
# 338644      Jones  gdvedwardsmith536@gmail.com      620000000        empty
# 338645   Jen Clay        jenclay22@hotmail.com   971582433297        empty
#
#          Birthdate Year of Birth  ...  \
# 0       1970-02-15          1970  ...
# 1       1982-04-20          1982  ...
# 2       1973-03-14          1973  ...
# 3       1963-07-08          1963  ...
# 4            empty         empty  ...
# ...            ...           ...  ...
# 338641       empty         empty  ...
# 338642       empty         empty  ...
# 338643       empty         empty  ...
# 338644       empty         empty  ...
# 338645       empty         empty  ...
#
#                                   Lead Source Description Lead Regions  \
# 0                                                   empty         SEAP
# 1                                                   empty    UK/Europe
# 2                                                   empty    UK/Europe
# 3                                                   empty    UK/Europe
# 4                         MICE Contacts from Ioanna email    UK/Europe
# ...                                                   ...          ...
# 338641            Karma Beach VIP membership sign up 2023         SEAP
# 338642            Karma Beach VIP membership sign up 2023    UK/Europe
# 338643              Karma Reservations - WhatsApp Channel        empty
# 338644              Karma Reservations - WhatsApp Channel        empty
# 338645  Karma La Herriza - Download Wedding Brochure a...  Middle East
#
#        Lead Status Booking Status BookRef Email Opt Out Opt In GDPR Compliant  \
# 0         New Lead          empty   empty         empty  empty          empty
# 1         New Lead          empty   empty         empty  empty          empty
# 2         New Lead          empty   empty         empty  empty          empty
# 3         New Lead          empty   empty         empty  empty          empty
# 4         New Lead          empty   empty         empty  empty          empty
# ...            ...            ...     ...           ...    ...            ...
# 338641       empty          empty   empty         false   true          false
# 338642       empty          empty   empty         false   true          false
# 338643    New Lead          empty   empty         false  false          false
# 338644    New Lead          empty   empty         false  false          false
# 338645       empty          empty   empty         false   true          false
#
#                                                   Website Comments
# 0                                                   empty    empty
# 1                                                   empty    empty
# 2                                                   empty    empty
# 3                                                   empty    empty
# 4                                                   empty    empty
# ...                                                   ...      ...
# 338641            https://karmagroup.com/karma-beach-vip/    empty
# 338642            https://karmagroup.com/karma-beach-vip/    empty
# 338643                                              empty    empty
# 338644                                              empty    empty
# 338645  https://karmagroup.com/weddings-at-karma-la-he...    empty
#
# [338646 rows x 34 columns]

# %%
find_member_booking = zoho_df.copy()

find_member_booking.loc[find_member_booking['Phone'].isin(df_booking['Phone1']), 'Same Value Find'] = 'Booking-Phone1'
find_member_booking.loc[find_member_booking['Phone'].isin(df_booking['Mobile']), 'Same Value Find'] = 'Booking-Mobile'
find_member_booking.loc[find_member_booking['Mobile'].isin(df_booking['Phone1']), 'Same Value Find'] = 'Booking-Phone1' 
find_member_booking.loc[find_member_booking['Mobile'].isin(df_booking['Mobile']), 'Same Value Find'] = 'Booking-Mobile'
find_member_booking.loc[find_member_booking['Email'].isin(df_booking['Email']), 'Same Value Find'] = 'Booking-Email'

find_member_booking.loc[find_member_booking['Phone'].isin(df_phone['Mobile']), 'Same Value Find'] = 'Member-Mobile' 
find_member_booking.loc[find_member_booking['Mobile'].isin(df_phone['Mobile']), 'Same Value Find'] = 'Member-Mobile'

find_member_booking.loc[find_member_booking['Email'].isin(df_email['Email']), 'Same Value Find'] = 'Member-Email'

find_member_booking.drop(find_member_booking.loc[find_member_booking['Same Value Find'].isna()].index, inplace=True)

count_booking_dedup = find_member_booking.loc[find_member_booking['Same Value Find'].str.contains('Booking', flags=re.I, regex=True)].shape[0]
count_member_dedup = find_member_booking.loc[find_member_booking['Same Value Find'].str.contains('Member', flags=re.I, regex=True)].shape[0]

find_member_booking.replace('empty', '', inplace=True)
# find_member_booking.to_csv(r'C:\Users\fajar\Documents\Python\Data\booking-member-dedup.csv', index=False)
# find_member_booking.to_excel(r'C:\Users\fajar\Documents\Python\Data\booking-member-dedup.xlsx', index=False)

#find_member_booking.loc[find_member_booking['Same Value Find'] == 'Booking-Phone1']

# %%
# data phone, mobile dam email member yang ada di master data 
count_wash_member = zoho_df.loc[
    zoho_df['Phone'].isin(df_booking['Phone1']) | 
    zoho_df['Phone'].isin(df_booking['Mobile']) |
    zoho_df['Mobile'].isin(df_booking['Phone1']) | 
    zoho_df['Mobile'].isin(df_booking['Mobile']) |
    zoho_df['Email'].isin(df_booking['Email'])| 

    zoho_df['Phone'].isin(df_phone['Mobile']) | 
    zoho_df['Mobile'].isin(df_phone['Mobile']) |

    zoho_df['Email'].isin(df_email['Email'])

].shape[0]

zoho_df.drop(zoho_df.loc[
    zoho_df['Phone'].isin(df_booking['Phone1']) | 
    zoho_df['Phone'].isin(df_booking['Mobile']) |
    zoho_df['Mobile'].isin(df_booking['Phone1']) | 
    zoho_df['Mobile'].isin(df_booking['Mobile']) |
    zoho_df['Email'].isin(df_booking['Email']) |
    
    zoho_df['Phone'].isin(df_phone['Mobile']) | 
    zoho_df['Mobile'].isin(df_phone['Mobile']) |

    zoho_df['Email'].isin(df_email['Email'])

    ].index, inplace=True)
    
zoho_df.reset_index(drop=True, inplace=True)

count_after_wash_member = zoho_df.shape[0]

# %%
# Categorize contacts
m.categorize_contacts(zoho_df)

# Count contact types
count_email_only = (zoho_df['Contact Type'] == 'Email Only').sum()
count_phone_only = (zoho_df['Contact Type'] == 'Phone Only').sum()
count_email_and_phone = (zoho_df['Contact Type'] == 'Email and Phone').sum()
count_blank = (zoho_df['Contact Type'] == 'Blank').sum()

# Remove blank contacts if needed
zoho_df = zoho_df[zoho_df['Contact Type'] != 'Blank']
zoho_df.reset_index(drop=True, inplace=True)

count_after_wash_blank = zoho_df.shape[0]

# %%
arr_dedup = [count_deleted_wrong_format, count_duplicate_general, count_leads_test, count_email_OTA, count_email_karma, count_blank]
count_sum_dedup = sum(arr_dedup)
count_sum_dedup
# Out:
# np.int64(606984)

# %%
print("==========================================================")
print("Summary")
print("==========================================================")
print("Jumlah Keseluruhan Master Zoho : "+str(count_data_awal))
print("Jumlah Filter Leads Awal : "+str(count_filter_awal))
print("Jumlah Format Email Salah : "+str(count_deleted_wrong_format))
print("Jumlah Setelah Clean Format Email Salah : "+str(count_after_deleted_wrong_format))
print("Jumlah Duplicate (Phone, Mobile dan Email) : "+str(count_duplicate_general))
print("Jumlah Setelah Clean Duplicate : "+str(count_after_dedup_duplicate))
print("Jumlah Lead Test : "+str(count_leads_test))
print("Jumlah Setelah Clean Lead Test : "+str(count_after_dedup_test))
# print("Jumlah Lead Do Not Mail : "+str(count_dnm))
# print("Jumlah Setelah Clean Lead Do Not Mail : "+str(count_after_dedup_dnm))
print("Jumlah Email OTA : "+str(count_email_OTA))
print("Jumlah Setelah Clean Email OTA : "+str(count_after_clean_OTA))
print("Jumlah Email Karma : "+str(count_email_karma))
print("Jumlah Setelah Clean Email Karma : "+str(count_after_clean_karma))
print("Jumlah Wash Member : "+str(count_member_dedup))
print("Jumlah Wash Booking : "+str(count_booking_dedup))
print("Jumlah Setelah Wash Member : "+str(count_after_wash_member))
print("Jumlah Phone Email Blank (Setelah phone yang tidak valid dihapus) : "+str(count_blank))
print("Jumlah Setelah Wash Phone Email Blank : "+str(count_after_wash_blank))
print("==========================================================")
print("Contact Type")
print("==========================================================")
print("Jumlah Email Only : "+str(count_email_only))
print("Jumlah Phone Only : "+str(count_phone_only))
print("Jumlah Email dan Phone : "+str(count_email_and_phone))
# Out:
# ==========================================================
# Summary
# ==========================================================
# Jumlah Keseluruhan Master Zoho : 15139909
# Jumlah Filter Leads Awal : 945619
# Jumlah Format Email Salah : 98
# Jumlah Setelah Clean Format Email Salah : 945521
# Jumlah Duplicate (Phone, Mobile dan Email) : 605452
# Jumlah Setelah Clean Duplicate : 340069
# Jumlah Lead Test : 76
# Jumlah Setelah Clean Lead Test : 339993
# Jumlah Email OTA : 1182
# Jumlah Setelah Clean Email OTA : 338811
# Jumlah Email Karma : 165
# Jumlah Setelah Clean Email Karma : 338646
# Jumlah Wash Member : 14671
# Jumlah Wash Booking : 5084
# Jumlah Setelah Wash Member : 318891
# Jumlah Phone Email Blank (Setelah phone yang tidak valid dihapus) : 11
# Jumlah Setelah Wash Phone Email Blank : 318880
# ==========================================================
# Contact Type
# ==========================================================
# Jumlah Email Only : 78173
# Jumlah Phone Only : 70258
# Jumlah Email dan Phone : 170449

# %%
print("==========================================================")
print("Summary Report")
print("==========================================================")
print("Jumlah Data Awal : "+str(count_filter_awal))
print("Jumlah Wash Dedup : "+str(count_sum_dedup))
print("Jumlah Wash Member : "+str(count_member_dedup))
print("Jumlah Wash Booking : "+str(count_booking_dedup))
print("Jumlah Data Akhir : "+str(count_after_wash_blank))
# Out:
# ==========================================================
# Summary Report
# ==========================================================
# Jumlah Data Awal : 945619
# Jumlah Wash Dedup : 606984
# Jumlah Wash Member : 14671
# Jumlah Wash Booking : 5084
# Jumlah Data Akhir : 318880

# %%
zoho_df['First Name'] = zoho_df['First Name'].str.title()
zoho_df['Last Name'] = zoho_df['Last Name'].str.title()
zoho_df.replace('empty', '', inplace=True, regex=True)

zoho_df
# Out:
# C:\Users\fajar\AppData\Local\Temp\ipykernel_7920\3294794079.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   zoho_df['First Name'] = zoho_df['First Name'].str.title()
# C:\Users\fajar\AppData\Local\Temp\ipykernel_7920\3294794079.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   zoho_df['Last Name'] = zoho_df['Last Name'].str.title()
# C:\Users\fajar\AppData\Local\Temp\ipykernel_7920\3294794079.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   zoho_df.replace('empty', '', inplace=True, regex=True)
#                        Record Id        Created Time Created Date First Name  \
# 0       zcrm_3584690000000450071 2019-01-08 16:38:18               Sebastian
# 1       zcrm_3584690000000450087 2019-01-08 16:38:18                 Siobhan
# 2       zcrm_3584690000000450106 2019-01-08 16:38:18                    Lisa
# 3       zcrm_3584690000000450109 2019-01-08 16:38:18               Ana Maria
# 4       zcrm_3584690000000450110 2019-01-08 16:38:18                   Maeve
# ...                          ...                 ...          ...        ...
# 318875  zcrm_3584690000502093034 2024-07-15 17:02:50                     Liz
# 318876  zcrm_3584690000502104001 2024-07-15 15:35:03                  Daniil
# 318877  zcrm_3584690000502106001 2024-07-15 15:42:41   2024-07-15  Katherine
# 318878  zcrm_3584690000502110001 2024-07-15 15:49:19   2024-07-15      James
# 318879  zcrm_3584690000502124001 2024-07-15 17:36:44   2024-07-15      Empty
#
#         Last Name                        Email          Phone Mobile  \
# 0            Rach        basti.2004@hotmail.de   498914342111
# 1       Gallagher  gallaghersiobhan@eircom.net   353879597603
# 2       Ferkovich         lisajo2009@yahoo.com    14062394749
# 3        Weileder     m.weileder@sonnenlink.de    15253234700
# 4           Maher        maeve.maher@gmail.com   353868702583
# ...           ...                          ...            ...    ...
# 318875  Pattenden         lizzyfun@hotmail.com    61413173819
# 318876     Egorov     egorov.danya98@gmail.com    79854847378
# 318877          -                               6262812888724
# 318878      Jones  gdvedwardsmith536@gmail.com      620000000
# 318879   Jen Clay        jenclay22@hotmail.com   971582433297
#
#          Birthdate Year of Birth  ... Lead Regions Lead Status Booking Status  \
# 0       1982-04-20          1982  ...    UK/Europe    New Lead
# 1       1973-03-14          1973  ...    UK/Europe    New Lead
# 2       1963-07-08          1963  ...    UK/Europe    New Lead
# 3                                 ...    UK/Europe    New Lead
# 4       1973-01-15          1973  ...    UK/Europe    New Lead
# ...            ...           ...  ...          ...         ...            ...
# 318875                            ...         SEAP
# 318876                            ...    UK/Europe
# 318877                            ...                 New Lead
# 318878                            ...                 New Lead
# 318879                            ...  Middle East
#
#        BookRef Email Opt Out Opt In GDPR Compliant  \
# 0
# 1
# 2
# 3
# 4
# ...        ...           ...    ...            ...
# 318875                 false   true          false
# 318876                 false   true          false
# 318877                 false  false          false
# 318878                 false  false          false
# 318879                 false   true          false
#
#                                                   Website Comments  \
# 0
# 1
# 2
# 3
# 4
# ...                                                   ...      ...
# 318875            https://karmagroup.com/karma-beach-vip/
# 318876            https://karmagroup.com/karma-beach-vip/
# 318877
# 318878
# 318879  https://karmagroup.com/weddings-at-karma-la-he...
#
#            Contact Type
# 0       Email and Phone
# 1       Email and Phone
# 2       Email and Phone
# 3       Email and Phone
# 4       Email and Phone
# ...                 ...
# 318875  Email and Phone
# 318876  Email and Phone
# 318877       Phone Only
# 318878  Email and Phone
# 318879  Email and Phone
#
# [318880 rows x 35 columns]

# %%
if (zoho_df.shape[0]>20000):

    row_split = 200000
    file_name = search_value

    m.split_file(zoho_df, row_split, file_name, file_type, target_location)
else:
    zoho_df.to_excel(target_location+'\\'+search_value+file_type, index=False)
