# %%
import main_module as m
import zoho_filter_module as fil
import pandas as pd
import re
import numpy as np

# %load_ext autoreload
# %autoreload 2

# %%
path_db = r'C:\Users\fajar.fatoni\Documents\Python\Data\Master Data Backup\CRM\All\23 Jul\zoho_data.xlsx'

# %%
df = pd.read_excel(path_db, dtype='string', sheet_name='Data')

# %%
df
# Out:
#                        Record Id         Created Time Time Categorized  \
# 0       zcrm_3584690000000404602  2019-01-08 11:07:28            Older
# 1       zcrm_3584690000000450071  2019-01-08 16:38:18            Older
# 2       zcrm_3584690000000450087  2019-01-08 16:38:18            Older
# 3       zcrm_3584690000000450106  2019-01-08 16:38:18            Older
# 4       zcrm_3584690000000450109  2019-01-08 16:38:18            Older
# ...                          ...                  ...              ...
# 516376  zcrm_3584690000565363037  2025-07-21 17:41:32       Last month
# 516377  zcrm_3584690000565367001  2025-07-21 17:30:24       Last month
# 516378  zcrm_3584690000565367037  2025-07-21 17:30:26       Last month
# 516379  zcrm_3584690000565369001  2025-07-21 17:30:52       Last month
# 516380  zcrm_3584690000565370001  2025-07-21 17:38:13       Last month
#
#                Created Date First Name  Last Name  \
# 0       2021-07-21 00:00:00   Frederic      Bonin
# ...

# %%
new_df = df.groupby(
    ['Lead Brand', 'Lead Sub-Brand', 'Lead Source'], 
    dropna=False
)['Record Id'].count().reset_index(name='Count').copy()

# %%
new_df
# Out:
#               Lead Brand       Lead Sub-Brand  \
# 0             Karma Club        Karma Club 21
# 1             Karma Club        Karma Club 21
# 2             Karma Club        Karma Club 21
# 3             Karma Club        Karma Club 21
# 4             Karma Club        Karma Club 21
# ..                   ...                  ...
# 145  Timeshare Marketing  Karma Experience UK
# 146  Timeshare Marketing                Other
# 147  Timeshare Marketing                Other
# 148  Timeshare Marketing          Yuk Tamasya
# 149                 <NA>                 <NA>
#
#                                            Lead Source  Count
# 0                             Associate Member Upgrade     30
# 1                  Christmas Quiz - Competition Winner      1
# 2                                          Competition      1
# 3                                       Exchange Guest      5
# 4    Existing Karma Club Member purchasing another one      1
# ...

# %%
new_df.to_csv(r"C:\Users\fajar.fatoni\Documents\Python\Data\zoho_crm_matrix_report.csv", index=False)
