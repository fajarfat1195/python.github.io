# %%
import main_module as m
import zoho_filter_module as fil
import pandas as pd
import re
import numpy as np

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
path_db = r'C:\Users\fajar.fatoni\Documents\Python\Data\Master Data Backup\CRM\All\23 Jul\zoho_data_clean.xlsx'

# %%
df = pd.read_excel(path_db, dtype='string', sheet_name='Sheet1')

# %%
df
# Out:
#                        Record Id         Created Time Time Categorized  \
# 0       zcrm_3584690000000404602  2019-01-08 11:07:28            Older
# 1       zcrm_3584690000000450071  2019-01-08 16:38:18            Older
# 2       zcrm_3584690000000450087  2019-01-08 16:38:18            Older
# 3       zcrm_3584690000000450106  2019-01-08 16:38:18            Older
# 4       zcrm_3584690000000450109  2019-01-08 16:38:18            Older
# ...                          ...                  ...              ...
# 453440  zcrm_3584690000565362001  2025-07-21 17:17:29       Last month
# 453441  zcrm_3584690000565363037  2025-07-21 17:41:32       Last month
# 453442  zcrm_3584690000565367001  2025-07-21 17:30:24       Last month
# 453443  zcrm_3584690000565369001  2025-07-21 17:30:52       Last month
# 453444  zcrm_3584690000565370001  2025-07-21 17:38:13       Last month
#
#                Created Date First Name  Last Name  \
# 0       2021-07-21 00:00:00   Frederic      Bonin
# ...

# %%
new_df = df.groupby(
    ['Lead Brand', 'Lead Sub-Brand', 'Lead Source'], 
    dropna=False
)['Record Id'].count().reset_index(name='Count').copy()

# %%
new_df
# Out:
#               Lead Brand       Lead Sub-Brand  \
# 0             Karma Club        Karma Club 21
# 1             Karma Club        Karma Club 21
# 2             Karma Club        Karma Club 21
# 3             Karma Club        Karma Club 21
# 4             Karma Club        Karma Club 21
# ..                   ...                  ...
# 103  Timeshare Marketing  Karma Experience UK
# 104  Timeshare Marketing                Other
# 105  Timeshare Marketing                Other
# 106  Timeshare Marketing          Yuk Tamasya
# 107                 <NA>                 <NA>
#
#                               Lead Source  Count
# 0                             Flybuy lead      1
# 1        Gloucester Constabulary 2021-May      3
# 2             Karma Beach VIP 2021-August      2
# 3    Karma Rottnest Past Guests 2021-June      1
# 4        Operation Recuperation 2021-June      1
# ..                                    ...    ...
# 103                                Bamboo     55
# ...

# %%
new_df.to_csv(r"C:\Users\fajar.fatoni\Documents\Python\Data\zoho_crm_clean_matrix_report.csv", index=False)
