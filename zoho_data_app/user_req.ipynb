# %%
import main_module as m
import zoho_filter_module as fil
import pandas as pd
from openpyxl.utils.exceptions import IllegalCharacterError
import re
import numpy as np

# %load_ext autoreload
# %autoreload 2

dir_path = r'C:\Users\fajar.fatoni\Documents\Python\Data\Zoho_Backup'
file_name = '\Leads_'

cols = ['Record Id',	
'Created Time',
'Created Date',	
'First Name',	
'Last Name',	
'Email',	
'Phone',	
'Mobile',	
'Birthdate',	
'Year of Birth',
'Street',	
'Street2',	
'City',	
'State',	
'Country',	
'Nationality',
'Booking Status', 
'BookRef',
'Departure Date',	
'Arrival Date',	
'Card Type',	
'Marital Status',	
'Lead Brand',	
'Lead Sub-Brand',	
'Lead Source',	
'Lead Locations',	
'Lead Source Description',	
'Lead Regions',
'Lead Status',
'Email Opt Out',	
'Opt In',
'GDPR Compliant',
'Website',
'Comments',
'Do you live in Bali?']
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
df = m.load_data_multiple(dir_path, file_name, cols)
count_data_awal = df.shape[0]
df = df.reindex(columns=cols)
df.shape[0]

df['Created Time'] = pd.to_datetime(df['Created Time'], format='%Y-%m-%d %H:%M:%S')
df['Arrival Date'] = pd.to_datetime(df['Arrival Date'], format='%Y-%m-%d')
df['Departure Date'] = pd.to_datetime(df['Departure Date'], format='%Y-%m-%d')
# fungsi errors cource untuk menhindari error jika value data date null atau kosong
# df['Birthdate'] = pd.to_datetime(df['Birthdate'], format='%Y-%m-%d', errors='coerce')
df.dtypes
df
# Out:
#                        Record Id        Created Time Created Date First Name  \
# 0       zcrm_3584690000000404602 2019-01-08 11:07:28   2021-07-21   Frederic
# 1       zcrm_3584690000000450071 2019-01-08 16:38:18         <NA>  Sebastian
# 2       zcrm_3584690000000450087 2019-01-08 16:38:18         <NA>    Siobhan
# 3       zcrm_3584690000000450106 2019-01-08 16:38:18         <NA>       Lisa
# 4       zcrm_3584690000000450109 2019-01-08 16:38:18         <NA>  Ana Maria
# ...                          ...                 ...          ...        ...
# 500010  zcrm_3584690000531084001 2025-03-17 16:10:04   2025-03-17       Gary
# 500011  zcrm_3584690000531086001 2025-03-17 16:13:48   2025-03-17       TEST
# 500012  zcrm_3584690000531094001 2025-03-17 16:25:04   2025-03-17       Jana
# 500013  zcrm_3584690000531126001 2025-03-17 17:25:17         <NA>    Georgia
# 500014  zcrm_3584690000531144001 2025-03-17 17:59:52   2025-03-17       Feby
#
#         Last Name                        Email             Phone Mobile  \
# 0           Bonin    fredericbonin79@gmail.com    +6281236100502   <NA>
# 1            Rach                         <NA>     +498914342111   <NA>
# 2       Gallagher  gallaghersiobhan@eircom.net      353879597603   <NA>
# 3       Ferkovich         lisajo2009@yahoo.com       14062394749   <NA>
# 4        Weileder     m.weileder@sonnenlink.de       15253234700   <NA>
# ...           ...                          ...               ...    ...
# 500010   Cosgrove    cosgrove_gary@yahoo.co.uk    +4407709529900   <NA>
# 500011       TEST  rajesh.kumar@karmagroup.com     +919876655432   <NA>
# 500012          D              jana@pragma.law      +61405501543   <NA>
# 500013    Goodyer  georgiaraedunkley@gmail.com     +447840040213   <NA>
# 500014    Jolanda                         <NA>  +62818-0347-7331   <NA>
#
#          Birthdate Year of Birth  ...      Lead Locations  \
# 0       1981-10-03          1981  ...       Karma Kandara
# 1       1982-04-20          1982  ...       Karma Bavaria
# 2       1973-03-14          1973  ...       Karma Bavaria
# 3       1963-07-08          1963  ...       Karma Bavaria
# 4             <NA>          <NA>  ...       Karma Bavaria
# ...            ...           ...  ...                 ...
# 500010        <NA>          <NA>  ...         Karma Bayon
# 500011        <NA>          <NA>  ...  Karma Salford Hall
# 500012        <NA>          <NA>  ...       Karma Kandara
# 500013  1989-11-06          <NA>  ...                <NA>
# 500014        <NA>          <NA>  ...       Karma Kandara
#
#                                   Lead Source Description Lead Regions  \
# 0                                                   KAREN         SEAP
# 1                                                    <NA>    UK/Europe
# 2                                                    <NA>    UK/Europe
# 3                                                    <NA>    UK/Europe
# 4                         MICE Contacts from Ioanna email    UK/Europe
# ...                                                   ...          ...
# 500010              Karma Reservations - WhatsApp Channel         <NA>
# 500011  Karma Salford Hall - Weddings at Karma Salford...        India
# 500012              Karma Reservations - WhatsApp Channel         <NA>
# 500013                           Karma Reciprocal Members    UK/Europe
# 500014              Karma Reservations - WhatsApp Channel         <NA>
#
#        Lead Status Email Opt Out Opt In GDPR Compliant  \
# 0         New Lead         false  false          false
# 1         New Lead          true  false          false
# 2         New Lead         false   true           true
# 3         New Lead          true  false          false
# 4         New Lead         false   true           true
# ...            ...           ...    ...            ...
# 500010    New Lead         false  false          false
# 500011        <NA>         false   true          false
# 500012    New Lead         false  false          false
# 500013        <NA>         false   true           true
# 500014    New Lead         false  false          false
#
#                                                   Website Comments  \
# 0                                                    <NA>     <NA>
# 1                                                    <NA>     <NA>
# 2                                                    <NA>     <NA>
# 3                                                    <NA>     <NA>
# 4                                                    <NA>     <NA>
# ...                                                   ...      ...
# 500010                                               <NA>     <NA>
# 500011  https://karmagroup.com/weddings-at-karma-salfo...     <NA>
# 500012                                               <NA>     <NA>
# 500013  https://karmaclub.karmagroup.com/reciprocal-me...     <NA>
# 500014                                               <NA>     <NA>
#
#        Do you live in Bali?
# 0                     false
# 1                     false
# 2                     false
# 3                     false
# 4                     false
# ...                     ...
# 500010                false
# 500011                false
# 500012                false
# 500013                false
# 500014                false
#
# [500015 rows x 35 columns]

# %%
df.loc[df['Phone'].str.contains('^\\+62', regex=True)]
# Out:
#                        Record Id        Created Time Created Date  \
# 0       zcrm_3584690000000404602 2019-01-08 11:07:28   2021-07-21
# 10      zcrm_3584690000000450191 2019-01-08 16:38:18   2021-07-21
# 12      zcrm_3584690000000450226 2019-01-08 16:38:18   2021-07-21
# 33      zcrm_3584690000000456097 2019-01-09 11:10:49   2021-07-21
# 86      zcrm_3584690000000456162 2019-01-09 11:10:49   2021-07-21
# ...                          ...                 ...          ...
# 499898  zcrm_3584690000530900043 2025-03-17 11:15:16         <NA>
# 499912  zcrm_3584690000530900502 2025-03-17 15:24:42         <NA>
# 500001  zcrm_3584690000530905489 2025-03-17 13:00:53         <NA>
# 500003  zcrm_3584690000531033039 2025-03-17 18:00:52   2025-03-17
# 500014  zcrm_3584690000531144001 2025-03-17 17:59:52   2025-03-17
#
#            First Name   Last Name                         Email  \
# 0            Frederic       Bonin     fredericbonin79@gmail.com
# 10      Ni Made Novia    Andryani          novia_made@yahoo.com
# 12        Maureellins     Joewyns  maureellinsjoewyns@gmail.com
# 33                 Di       Zhang              156864136@qq.com
# 86         Ganef Hari  Sulistiono         abahdendy99@gmail.com
# ...               ...         ...                           ...
# 499898              -     Hartono      hartonoserutan@gmail.com
# 499912       Nadezhda    Shuvaeva         nvshuvaeva7@gmail.com
# 500001        Evgenii    Semenkin         gaya108tree@gmail.com
# 500003              -           -                          <NA>
# 500014           Feby     Jolanda                          <NA>
#
#                    Phone Mobile   Birthdate Year of Birth  ...  \
# 0         +6281236100502   <NA>  1981-10-03          1981  ...
# 10        +6281511634635   <NA>  1980-11-10          1980  ...
# 12        +6282221100639   <NA>  2000-04-14          2000  ...
# 33      +628618339280777   <NA>        <NA>          <NA>  ...
# 86         +628123255435   <NA>  1963-12-16          1963  ...
# ...                  ...    ...         ...           ...  ...
# 499898     +628816404670   <NA>        <NA>          <NA>  ...
# 499912    +6285190227284   <NA>        <NA>          <NA>  ...
# 500001    +6281225467695   <NA>        <NA>          <NA>  ...
# 500003  +62813-8178-5254   <NA>        <NA>          <NA>  ...
# 500014  +62818-0347-7331   <NA>        <NA>          <NA>  ...
#
#            Lead Locations                  Lead Source Description  \
# 0           Karma Kandara                                    KAREN
# 10          Karma Kandara                                    KAREN
# 12          Karma Kandara                                    KAREN
# 33          Karma Kandara                                    KAREN
# 86          Karma Kandara                                    KAREN
# ...                   ...                                      ...
# 499898  Karma Royal Sanur                                Viewpoint
# 499912               <NA>  Karma Beach VIP membership sign up 2023
# 500001               <NA>  Karma Beach VIP membership sign up 2023
# 500003      Karma Kandara    Karma Reservations - WhatsApp Channel
# 500014      Karma Kandara    Karma Reservations - WhatsApp Channel
#
#        Lead Regions Lead Status Email Opt Out Opt In GDPR Compliant  \
# 0              SEAP    New Lead         false  false          false
# 10             SEAP    New Lead         false  false          false
# 12             SEAP    New Lead         false  false          false
# 33             SEAP    New Lead         false  false          false
# 86             SEAP    New Lead         false  false          false
# ...             ...         ...           ...    ...            ...
# 499898         <NA>        <NA>         false   true          false
# 499912         SEAP        <NA>         false   true          false
# 500001         SEAP        <NA>         false   true          false
# 500003         <NA>    New Lead         false  false          false
# 500014         <NA>    New Lead         false  false          false
#
#                                         Website Comments Do you live in Bali?
# 0                                          <NA>     <NA>                false
# 10                                         <NA>     <NA>                false
# 12                                         <NA>     <NA>                false
# 33                                         <NA>     <NA>                false
# 86                                         <NA>     <NA>                false
# ...                                         ...      ...                  ...
# 499898                                     <NA>     <NA>                false
# 499912  https://karmagroup.com/karma-beach-vip/     <NA>                false
# 500001  https://karmagroup.com/karma-beach-vip/     <NA>                false
# 500003                                     <NA>     <NA>                false
# 500014                                     <NA>     <NA>                false
#
# [35974 rows x 35 columns]

# %%
path = r'G:\.shortcut-targets-by-id\0B_d3smBjzo04eXpvS1NXTWF2RVE\_BOOKING\Booking By Year\FlyBuy Booking Data (BGAU & BGID & KE).xlsx'
df_booking = pd.read_excel(path, dtype='string', sheet_name='BOOKING_BGAU_BGID_KE')

# path = r'G:\.shortcut-targets-by-id\0B_d3smBjzo04UUNBME5GOVhoMjA\_ODYSSEY\Phone Members.xlsx'
# df_phone = pd.read_excel(path, dtype='string', sheet_name='Sheet1')

path = r'C:\Users\fajar.fatoni\Documents\Python\Data\Phone Members for toni 22mar25.csv'
df_phone = pd.read_csv(path, dtype='string', encoding='ISO-8859-1')

# path = r'G:\.shortcut-targets-by-id\0B_d3smBjzo04UUNBME5GOVhoMjA\_ODYSSEY\Email Members.xlsx'
# df_email = pd.read_excel(path, dtype='string', sheet_name='Sheet1')

path = r'C:\Users\fajar.fatoni\Documents\Python\Data\Email Members for toni 22mar25.csv'
df_email = pd.read_csv(path, dtype='string', encoding='ISO-8859-1')

# %%
zoho_filter = fil.user_req(df)
zoho_df = df.loc[zoho_filter].copy() # menggunakan copy untuk menghindari setting copy warning
zoho_df.reset_index(drop=True, inplace=True)
count_filter_awal = zoho_df.shape[0]

# zoho_df.to_excel(r'C:\Users\fajar.fatoni\Documents\Python\Data\test_leads.xlsx', index=False)
# mengisi kolom <NA> dengan value string 'empty' supaya mudah mengecek data member dan booking dengan isin

zoho_df.fillna('empty', inplace=True)
zoho_df.sort_values('Created Time', ascending=True)
# Out:
# C:\Users\fajar.fatoni\AppData\Local\Temp\ipykernel_2636\2027893311.py:9: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'empty' has dtype incompatible with datetime64[ns], please explicitly cast to a compatible dtype first.
#   zoho_df.fillna('empty', inplace=True)
#                     Record Id        Created Time Created Date  \
# 2    zcrm_3584690000501061001 2024-07-03 21:56:57        empty
# 3    zcrm_3584690000501102002 2024-07-04 06:13:21        empty
# 0    zcrm_3584690000501053077 2024-07-04 07:54:15        empty
# 1    zcrm_3584690000501057143 2024-07-04 14:52:47        empty
# 5    zcrm_3584690000501151001 2024-07-04 17:27:04        empty
# ..                        ...                 ...          ...
# 791  zcrm_3584690000530815033 2025-03-17 09:22:31        empty
# 792  zcrm_3584690000530901644 2025-03-17 13:39:02        empty
# 789  zcrm_3584690000530642578 2025-03-17 13:52:57        empty
# 793  zcrm_3584690000530902623 2025-03-17 14:35:05        empty
# 794  zcrm_3584690000531042001 2025-03-17 14:55:56        empty
#
#          First Name       Last Name                      Email          Phone  \
# 2    Michael Roepen  Michael Roepen      cackle067@hotmail.com   +61403602041
# 3            Ganesh        Shevkari          gps7777@gmail.com   +61423962131
# 0            Rishan       Neelawala        Littauk@yahoo.co.uk  +610433912771
# 1            Yilmaz           Erbas      ylmzerbas@hotmail.com   +61423207375
# 5            Leanne            Gatt     leannegatt62@gmail.com   +61402312248
# ..              ...             ...                        ...            ...
# 791            Mark           Cross  markcross502@yahoo.com.au  +610411606162
# 792       Julieanne          Patten  julieannep@westnet.com.au   +61428590886
# 789            Test           Thiru    test305thi3ru@gmail.com  +912313212123
# 793           Test2         Thiru93    test034thiru2@gmail.com   +61465654565
# 794           Tanya     Esterhuizen       tanyaglam2@gmail.com  +610405140796
#
#             Mobile Birthdate Year of Birth  ... Lead Locations  \
# 2     +61403602041     empty         empty  ...        General
# 3     +61423962131     empty         empty  ...        General
# 0    +610433912771     empty         empty  ...        General
# 1     +61423207375     empty         empty  ...        General
# 5     +61402312248     empty         empty  ...        General
# ..             ...       ...           ...  ...            ...
# 791  +610411606162     empty         empty  ...        General
# 792   +61428590886     empty         empty  ...        General
# 789  +912313212123     empty         empty  ...          empty
# 793   +61465654565     empty         empty  ...          empty
# 794  +610405140796     empty          1971  ...        General
#
#                                Lead Source Description Lead Regions  \
# 2    KE | Web | Destination Amina Lantana Hoi An Ho...         SEAP
# 3          KE | Web | Destination Karma Royal Jimbaran         SEAP
# 0                                KE | WEB | Contact Us         SEAP
# 1    KE | Web | Destination Amina Lantana Hoi An Ho...         SEAP
# 5                 KE | Web | Destination Karma Kandara         SEAP
# ..                                                 ...          ...
# 791  KE | Web | Destination March Samui Resort, Koh...         SEAP
# 792  KE | Web | Destination Karma Kandara Mentari R...         SEAP
# 789                                KE | WEB | Jimbaran         SEAP
# 793                               KE | WEB | KEPH Pago         SEAP
# 794  KE3 | EDM | KARMA KAMELEON - KARMA KANDARA | w...         SEAP
#
#        Lead Status Email Opt Out Opt In GDPR Compliant  \
# 2    Not Qualified         false  false          false
# 3    Not Qualified         false  false          false
# 0    Not Qualified         false  false          false
# 1    Not Qualified         false  false          false
# 5    Not Qualified         false  false          false
# ..             ...           ...    ...            ...
# 791  Not Qualified         false  false          false
# 792  Not Qualified         false  false          false
# 789  Not Qualified         false  false          false
# 793  Not Qualified         false  false          false
# 794          empty         false  false          false
#
#                                                Website Comments  \
# 2    https://www.karmaexperience.com/destinations/a...    empty
# 3    https://www.karmaexperience.com/destinations/k...    empty
# 0             https://www.karmaexperience.com/contact/    empty
# 1    https://www.karmaexperience.com/destinations/a...    empty
# 5    https://www.karmaexperience.com/destinations/k...    empty
# ..                                                 ...      ...
# 791  https://karmaexperience.com/hotel-partner/marc...    empty
# 792  https://karmaexperience.com/destinations/karma...    empty
# 789                       https://karmaexperience.com/    empty
# 793                      https://karmaexperience.com/#    empty
# 794                                              empty    empty
#
#     Do you live in Bali?
# 2                  false
# 3                  false
# 0                  false
# 1                  false
# 5                  false
# ..                   ...
# 791                false
# 792                false
# 789                false
# 793                false
# 794                false
#
# [795 rows x 35 columns]

# %%
zoho_df.loc[zoho_df['Lead Source Description'].str.contains('walk', regex=True, flags=re.I)]
# Out:
# Empty DataFrame
# Columns: [Record Id, Created Time, Created Date, First Name, Last Name, Email, Phone, Mobile, Birthdate, Year of Birth, Street, Street2, City, State, Country, Nationality, Booking Status, BookRef, Departure Date, Arrival Date, Card Type, Marital Status, Lead Brand, Lead Sub-Brand, Lead Source, Lead Locations, Lead Source Description, Lead Regions, Lead Status, Email Opt Out, Opt In, GDPR Compliant, Website, Comments, Do you live in Bali?]
# Index: []
#
# [0 rows x 35 columns]

# %% [markdown]
# # ====================== Awal Filter Umum ======================

# %%
# data phone, mobile dam email member yang ada di master data (wash member)

m.clean_number(zoho_df, 'Phone')
m.clean_number(zoho_df, 'Mobile')
m.replace_not_valid_to_empty(zoho_df, 'Phone')
m.replace_not_valid_to_empty(zoho_df, 'Mobile')
zoho_df['Email'] = m.lowercase(zoho_df, 'Email')
m.clean_space(zoho_df, 'Email')
m.clean_not_valid_email_format(zoho_df, 'Email')

m.clean_number(df_booking, 'Phone1')
m.clean_number(df_booking, 'Mobile')
df_booking['Email'] = m.lowercase(df_booking, 'Email')
m.clean_space(df_booking, 'Email')
m.clean_not_valid_email_format(df_booking, 'Email')

m.clean_number(df_phone, 'Mobile')

df_email['Email'] = m.lowercase(df_email, 'Email')
m.clean_space(df_email, 'Email')
m.clean_not_valid_email_format(df_email, 'Email')
# Out:
# c:\Users\fajar.fatoni\Documents\Python\Task Offline\zoho_data_app\main_module.py:71: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[df_columns].replace(' ','', regex=True, inplace=True)
# c:\Users\fajar.fatoni\Documents\Python\Task Offline\zoho_data_app\main_module.py:72: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[df_columns].replace('[^0-9]','', regex=True, inplace=True)
# c:\Users\fajar.fatoni\Documents\Python\Task Offline\zoho_data_app\main_module.py:94: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[df_columns].replace(' ','', regex=True, inplace=True)
# c:\Users\fajar.fatoni\Documents\Python\Task Offline\zoho_data_app\main_module.py:71: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[df_columns].replace(' ','', regex=True, inplace=True)
# c:\Users\fajar.fatoni\Documents\Python\Task Offline\zoho_data_app\main_module.py:72: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[df_columns].replace('[^0-9]','', regex=True, inplace=True)
# 'Email'

# %%
zoho_df.loc[zoho_df['Phone']=='']
# Out:
# Empty DataFrame
# Columns: [Record Id, Created Time, Created Date, First Name, Last Name, Email, Phone, Mobile, Birthdate, Year of Birth, Street, Street2, City, State, Country, Nationality, Booking Status, BookRef, Departure Date, Arrival Date, Card Type, Marital Status, Lead Brand, Lead Sub-Brand, Lead Source, Lead Locations, Lead Source Description, Lead Regions, Lead Status, Email Opt Out, Opt In, GDPR Compliant, Website, Comments, Do you live in Bali?]
# Index: []
#
# [0 rows x 35 columns]

# %%
count_deleted_wrong_format = m.delete_email_wrong_format(zoho_df, 'Email')
count_after_deleted_wrong_format = zoho_df.shape[0]

# %%
# hitung jumlah duplicate
count_duplicate_general = zoho_df.loc[zoho_df.duplicated(subset=['Phone','Email', 'Mobile'])].shape[0]

zoho_df.loc[zoho_df.duplicated(subset=['Phone','Email', 'Mobile'])]
# Out:
#                     Record Id        Created Time Created Date    First Name  \
# 5    zcrm_3584690000501151001 2024-07-04 17:27:04        empty        Leanne
# 38   zcrm_3584690000501808001 2024-07-10 13:46:17        empty        Rhonda
# 80   zcrm_3584690000503188333 2024-07-23 05:55:37        empty   Anita Jones
# 101  zcrm_3584690000503934144 2024-07-31 19:31:04        empty         David
# 113  zcrm_3584690000504138633 2024-08-05 11:34:04        empty        Tevita
# 161  zcrm_3584690000505648001 2024-08-23 05:49:11        empty          Brad
# 221  zcrm_3584690000508082001 2024-09-12 16:55:32        empty         Inang
# 243  zcrm_3584690000508568068 2024-09-20 12:20:48        empty        Edmond
# 276  zcrm_3584690000509661001 2024-09-29 15:52:49        empty        Philip
# 290  zcrm_3584690000510893001 2024-10-04 13:44:33        empty          Jill
# 310  zcrm_3584690000511458161 2024-10-09 14:53:11        empty        Brooke
# 317  zcrm_3584690000511869424 2024-10-14 12:39:53        empty       benazir
# 327  zcrm_3584690000512056043 2024-10-16 16:55:58        empty          Nivi
# 401  zcrm_3584690000514289337 2024-11-07 15:47:35        empty       sourabh
# 422  zcrm_3584690000515262109 2024-11-14 10:22:11        empty   AUBREY NOEL
# 436  zcrm_3584690000516000001 2024-11-22 05:33:01        empty          Paul
# 442  zcrm_3584690000516181067 2024-11-23 16:26:58        empty         Chris
# 452  zcrm_3584690000516413143 2024-11-26 21:00:07        empty         Sofia
# 556  zcrm_3584690000519737001 2024-12-27 23:16:19        empty      Devinder
# 558  zcrm_3584690000519768128 2024-12-29 01:53:14        empty       Sandeep
# 568  zcrm_3584690000519905040 2025-01-02 23:51:05        empty         empty
# 600  zcrm_3584690000520543069 2025-01-10 13:30:16        empty       Charrie
# 603  zcrm_3584690000520701045 2025-01-11 13:53:37        empty       Charrie
# 656  zcrm_3584690000525622077 2025-02-25 08:03:29        empty        Chirag
# 690  zcrm_3584690000526318482 2025-03-03 15:55:29        empty     Manjunath
# 757  zcrm_3584690000527747001 2025-03-11 21:06:20        empty   Abdul Hanan
# 758  zcrm_3584690000527756119 2025-03-12 10:55:06        empty  vishal kumar
# 780  zcrm_3584690000529834001 2025-03-15 19:49:57        empty    DR HEMLATA
#
#         Last Name                               Email          Phone  \
# 5            Gatt              leannegatt62@gmail.com    61402312248
# 38      Parkinson         ronnieparkinson15@gmail.com    61452421117
# 80    Anita Jones                       neet68@me.com   610474355043
# 101        Newell          newell.david1962@gmail.com    61411507203
# 113         Tupou             tevitatupou19@gmail.com    61432284223
# 161        Hayden  bradhaydenbonvillevalley@gmail.com    61439041886
# 221          Nang                 nangi1397@gmail.com  6285776503618
# 243           Hui                  hlmed429@gmail.com   610413061332
# 276         Pucci                fillsway@bigpond.com   610419254694
# 290  Wood ainslie          torridonequine@hotmail.com    61498045631
# 310     Eckersley           brookeeckersley@gmail.com   610492421596
# 317    khoshbooie              julilene10@hotmail.com    61431522514
# 327       Nishant               nivinishant@gmail.com   610481258288
# 401          jain                jainsorabh@gmail.com   919871464600
# 422       DOHERTY            adeecleaning@bigpond.com   610417238589
# 436         Green                 paul.green@live.com    61404880880
# 442       Lourens           angchrislourens@gmail.com   610400039572
# 452      Kyriacou            sililildreamer@gmail.com   610411087740
# 556         Kumar           kumardevinder24@gmail.com   916239302931
# 558         Patni          sandeep_ksl@rediffmail.com   919028011008
# 568        Hemixa                itc_paresh@yahoo.com          empty
# 600           RHI                charriee@hotmail.com    61415290076
# 603           Rhi                charriee@hotmail.com    61415290076
# 656         Desai             chirag.sydney@gmail.com   610421202261
# 690            Pv             pvmanjunath91@gmail.com   619900224088
# 757         Sayed       hanan.shah.official@gmail.com    61452436117
# 758  vishal kumar          vinnierajput1988@gmail.com   610449501565
# 780        JADHAV                 aayushmsh@yahoo.com   919321221000
#
#             Mobile Birthdate Year of Birth  ... Lead Locations  \
# 5      61402312248     empty         empty  ...        General
# 38     61452421117     empty         empty  ...        General
# 80    610474355043     empty         empty  ...        General
# 101    61411507203     empty         empty  ...        General
# 113    61432284223     empty         empty  ...        General
# 161    61439041886     empty         empty  ...          empty
# 221  6285776503618     empty         empty  ...        General
# 243   610413061332     empty         empty  ...        General
# 276   610419254694     empty         empty  ...        General
# 290    61498045631     empty         empty  ...        General
# 310   610492421596     empty         empty  ...        General
# 317    61431522514     empty         empty  ...        General
# 327   610481258288     empty         empty  ...        General
# 401   919871464600     empty         empty  ...        General
# 422   610417238589     empty         empty  ...        General
# 436    61404880880     empty         empty  ...          empty
# 442   610400039572     empty         empty  ...        General
# 452   610411087740     empty         empty  ...        General
# 556   916239302931     empty         empty  ...        General
# 558   919028011008     empty         empty  ...        General
# 568          empty     empty         empty  ...        General
# 600    61415290076     empty         empty  ...        General
# 603    61415290076     empty         empty  ...          empty
# 656   610421202261     empty         empty  ...        General
# 690   619900224088     empty         empty  ...          empty
# 757    61452436117     empty         empty  ...          empty
# 758   610449501565     empty         empty  ...        General
# 780   919321221000     empty         empty  ...        General
#
#                                Lead Source Description Lead Regions  \
# 5                 KE | Web | Destination Karma Kandara         SEAP
# 38                        KE | Web | Newsletter Footer         SEAP
# 80   KE | Web | Destination Karma Kandara Mentari R...         SEAP
# 101  KE | Web | Destination | amina-lantana-hoi-an-...         SEAP
# 113         KE | Web | Destination The Oceanic Sportel         SEAP
# 161                                 KE | WEB | Kandara         SEAP
# 221  KE | Automation Competition | w1apr21 | KE Sal...         SEAP
# 243  KE | Web | Destination Karma Kandara Mentari R...         SEAP
# 276  KE | Web | Destination Karma Kandara Mentari R...         SEAP
# 290  KE | Web | Destination Karma Kandara Mentari R...         SEAP
# 310  KE | Web | Destination Karma Minoan, Crete, Gr...         SEAP
# 317  KE | Web | Destination Karma Kandara Mentari R...         SEAP
# 327         KE | Web | Destination The Oceanic Sportel         SEAP
# 401  KE | Web | Destination Jimbaran Bay Resort and...         SEAP
# 422  KE | Web | Destination Amina Lantana Hoi An Ho...         SEAP
# 436                                   KE | WEB | Bayon         SEAP
# 442  KE | Web | Destination Karma Kandara Mentari R...         SEAP
# 452  KE | Web | Destination Amina Lantana Hoi An Ho...         SEAP
# 556       KE3 | FB LMD | Multi Offer Resorts | w4oct19         SEAP
# 558       KE3 | FB LMD | Multi Offer Resorts | w4oct19         SEAP
# 568         KE | Web | Booking Confirmation | 50 Admin         SEAP
# 600  KE | Web | Destination Karma Kandara Mentari R...         SEAP
# 603                                 KE | WEB | Kandara         SEAP
# 656  KE | Web | Destination Karma Kandara Mentari R...         SEAP
# 690                            KE | WEB | KEPH Oceanic         SEAP
# 757                              KE | WEB | KEPH Amina         SEAP
# 758  KE | Web | Destination Amina Lantana Hoi An Ho...         SEAP
# 780       KE3 | FB LMD | Multi Offer Resorts | w4oct19         SEAP
#
#        Lead Status Email Opt Out Opt In GDPR Compliant  \
# 5    Not Qualified         false  false          false
# 38   Not Qualified         false  false          false
# 80   Not Qualified         false  false          false
# 101  Not Qualified         false  false          false
# 113  Not Qualified         false  false          false
# 161  Not Qualified         false  false          false
# 221          empty         false  false          false
# 243  Not Qualified         false  false          false
# 276  Not Qualified         false  false          false
# 290  Not Qualified         false  false          false
# 310  Not Qualified         false  false          false
# 317  Not Qualified         false  false          false
# 327  Not Qualified         false  false          false
# 401  Not Qualified         false  false          false
# 422  Not Qualified         false  false          false
# 436  Not Qualified         false  false          false
# 442  Not Qualified         false  false          false
# 452  Not Qualified         false  false          false
# 556          empty         false  false          false
# 558          empty         false  false          false
# 568       New Lead         false  false          false
# 600  Not Qualified         false  false          false
# 603  Not Qualified         false  false          false
# 656  Not Qualified         false  false          false
# 690  Not Qualified         false  false          false
# 757  Not Qualified         false  false          false
# 758  Not Qualified         false  false          false
# 780          empty         false  false          false
#
#                                                Website Comments  \
# 5    https://www.karmaexperience.com/destinations/k...    empty
# 38             https://www.karmaexperience.com/thanks/    empty
# 80   https://www.karmaexperience.com/destinations/k...    empty
# 101  https://www.karmaexperience.com/find-destinati...    empty
# 113  https://www.karmaexperience.com/destinations/t...    empty
# 161           https://www.karmaexperience.com/contact/    empty
# 221                                              empty    empty
# 243  https://www.karmaexperience.com/destinations/k...    empty
# 276  https://www.karmaexperience.com/destinations/k...    empty
# 290  https://www.karmaexperience.com/destinations/k...    empty
# 310  https://www.karmaexperience.com/destinations/k...    empty
# 317  https://www.karmaexperience.com/destinations/k...    empty
# 327  https://www.karmaexperience.com/hotel-partner/...    empty
# 401  https://www.karmaexperience.com/hotel-partner/...    empty
# 422  https://www.karmaexperience.com/hotel-partner/...    empty
# 436           https://www.karmaexperience.com/contact/    empty
# 442  https://www.karmaexperience.com/destinations/k...    empty
# 452  https://www.karmaexperience.com/hotel-partner/...    empty
# 556                                              empty    empty
# 558                                              empty    empty
# 568                                              empty    empty
# 600  https://www.karmaexperience.com/destinations/k...    empty
# 603           https://www.karmaexperience.com/contact/    empty
# 656  https://karmaexperience.com/destinations/karma...    empty
# 690                       https://karmaexperience.com/    empty
# 757                       https://karmaexperience.com/    empty
# 758  https://karmaexperience.com/destinations/amina...    empty
# 780                                              empty    empty
#
#     Do you live in Bali?
# 5                  false
# 38                 false
# 80                 false
# 101                false
# 113                false
# 161                false
# 221                false
# 243                false
# 276                false
# 290                false
# 310                false
# 317                false
# 327                false
# 401                false
# 422                false
# 436                false
# 442                false
# 452                false
# 556                false
# 558                false
# 568                false
# 600                false
# 603                false
# 656                false
# 690                false
# 757                false
# 758                false
# 780                false
#
# [28 rows x 35 columns]

# %%
zoho_df.drop_duplicates(subset=['Phone','Email', 'Mobile'], inplace=True)
zoho_df.reset_index(drop=True, inplace=True)

# hitung jumlah setelah value duplicate dihapus
count_after_dedup_duplicate = zoho_df.shape[0]

zoho_df
# Out:
#                     Record Id        Created Time Created Date  \
# 0    zcrm_3584690000501053077 2024-07-04 07:54:15        empty
# 1    zcrm_3584690000501057143 2024-07-04 14:52:47        empty
# 2    zcrm_3584690000501061001 2024-07-03 21:56:57        empty
# 3    zcrm_3584690000501102002 2024-07-04 06:13:21        empty
# 4    zcrm_3584690000501132076 2024-07-04 17:31:54        empty
# ..                        ...                 ...          ...
# 762  zcrm_3584690000530696001 2025-03-17 01:03:04        empty
# 763  zcrm_3584690000530815033 2025-03-17 09:22:31        empty
# 764  zcrm_3584690000530901644 2025-03-17 13:39:02        empty
# 765  zcrm_3584690000530902623 2025-03-17 14:35:05        empty
# 766  zcrm_3584690000531042001 2025-03-17 14:55:56        empty
#
#          First Name       Last Name                      Email         Phone  \
# 0            Rishan       Neelawala        littauk@yahoo.co.uk  610433912771
# 1            Yilmaz           Erbas      ylmzerbas@hotmail.com   61423207375
# 2    Michael Roepen  Michael Roepen      cackle067@hotmail.com   61403602041
# 3            Ganesh        Shevkari          gps7777@gmail.com   61423962131
# 4            Leanne            Gatt     leannegatt62@gmail.com   61402312248
# ..              ...             ...                        ...           ...
# 762         Vherine         Stiller       cherines@live.com.au   61424862780
# 763            Mark           Cross  markcross502@yahoo.com.au  610411606162
# 764       Julieanne          Patten  julieannep@westnet.com.au   61428590886
# 765           Test2         Thiru93    test034thiru2@gmail.com   61465654565
# 766           Tanya     Esterhuizen       tanyaglam2@gmail.com  610405140796
#
#            Mobile Birthdate Year of Birth  ... Lead Locations  \
# 0    610433912771     empty         empty  ...        General
# 1     61423207375     empty         empty  ...        General
# 2     61403602041     empty         empty  ...        General
# 3     61423962131     empty         empty  ...        General
# 4     61402312248     empty         empty  ...        General
# ..            ...       ...           ...  ...            ...
# 762   61424862780     empty         empty  ...          empty
# 763  610411606162     empty         empty  ...        General
# 764   61428590886     empty         empty  ...        General
# 765   61465654565     empty         empty  ...          empty
# 766  610405140796     empty          1971  ...        General
#
#                                Lead Source Description Lead Regions  \
# 0                                KE | WEB | Contact Us         SEAP
# 1    KE | Web | Destination Amina Lantana Hoi An Ho...         SEAP
# 2    KE | Web | Destination Amina Lantana Hoi An Ho...         SEAP
# 3          KE | Web | Destination Karma Royal Jimbaran         SEAP
# 4                             KE | Web | Destination |         SEAP
# ..                                                 ...          ...
# 762                                 KE | WEB | Kandara         SEAP
# 763  KE | Web | Destination March Samui Resort, Koh...         SEAP
# 764  KE | Web | Destination Karma Kandara Mentari R...         SEAP
# 765                               KE | WEB | KEPH Pago         SEAP
# 766  KE3 | EDM | KARMA KAMELEON - KARMA KANDARA | w...         SEAP
#
#        Lead Status Email Opt Out Opt In GDPR Compliant  \
# 0    Not Qualified         false  false          false
# 1    Not Qualified         false  false          false
# 2    Not Qualified         false  false          false
# 3    Not Qualified         false  false          false
# 4    Not Qualified         false  false          false
# ..             ...           ...    ...            ...
# 762  Not Qualified         false  false          false
# 763  Not Qualified         false  false          false
# 764  Not Qualified         false  false          false
# 765  Not Qualified         false  false          false
# 766          empty         false  false          false
#
#                                                Website Comments  \
# 0             https://www.karmaexperience.com/contact/    empty
# 1    https://www.karmaexperience.com/destinations/a...    empty
# 2    https://www.karmaexperience.com/destinations/a...    empty
# 3    https://www.karmaexperience.com/destinations/k...    empty
# 4    https://www.karmaexperience.com/#destinationch...    empty
# ..                                                 ...      ...
# 762                       https://karmaexperience.com/    empty
# 763  https://karmaexperience.com/hotel-partner/marc...    empty
# 764  https://karmaexperience.com/destinations/karma...    empty
# 765                      https://karmaexperience.com/#    empty
# 766                                              empty    empty
#
#     Do you live in Bali?
# 0                  false
# 1                  false
# 2                  false
# 3                  false
# 4                  false
# ..                   ...
# 762                false
# 763                false
# 764                false
# 765                false
# 766                false
#
# [767 rows x 35 columns]

# %%
# Cek leads test
test_leads = zoho_df.loc[
    
        zoho_df['Email'].str.contains('^test@', flags=re.I, regex=True) |
        zoho_df['Email'].str.contains('\+test', flags=re.I, regex=True) |
    
        zoho_df['First Name'].str.contains('^test$', flags=re.I, regex=True) |
        zoho_df['Last Name'].str.contains('^test$', flags=re.I, regex=True) |

        zoho_df['First Name'].str.contains('test 1', flags=re.I, regex=True) |
        zoho_df['Last Name'].str.contains('test 2', flags=re.I, regex=True)|
        zoho_df['First Name'].str.contains('test1', flags=re.I, regex=True) |
        zoho_df['Last Name'].str.contains('test2', flags=re.I, regex=True)|

        zoho_df['First Name'].str.contains(' test ', flags=re.I, regex=True) | 
        zoho_df['Last Name'].str.contains(' test ', flags=re.I, regex=True) | 
        zoho_df['Last Name'].str.contains(' test$', flags=re.I, regex=True)
    ]

count_leads_test = test_leads.shape[0]

# test_leads.to_excel(r'C:\Users\fajar.fatoni\Documents\Python\Data\test_leads_2.xlsx', index=False)
test_leads
# Out:
#                     Record Id        Created Time Created Date First Name  \
# 725  zcrm_3584690000527717001 2025-03-11 19:42:54        empty       test
# 761  zcrm_3584690000530642578 2025-03-17 13:52:57        empty       Test
#
#     Last Name                    Email         Phone        Mobile Birthdate  \
# 725     asdas        asdasdg@gmail.com  618889888889  618889888889     empty
# 761     Thiru  test305thi3ru@gmail.com  912313212123  912313212123     empty
#
#     Year of Birth  ... Lead Locations Lead Source Description Lead Regions  \
# 725         empty  ...          empty      KE | WEB | Kandara         SEAP
# 761         empty  ...          empty     KE | WEB | Jimbaran         SEAP
#
#        Lead Status Email Opt Out Opt In GDPR Compliant  \
# 725  Not Qualified         false  false          false
# 761  Not Qualified         false  false          false
#
#                           Website Comments Do you live in Bali?
# 725  https://karmaexperience.com/    empty                false
# 761  https://karmaexperience.com/    empty                false
#
# [2 rows x 35 columns]

# %%
zoho_df.drop(test_leads.index, inplace=True)
zoho_df.reset_index(drop=True, inplace=True)

count_after_dedup_test = zoho_df.shape[0]

# %%
# dnm_leads = zoho_df.loc[(zoho_df['Do Not Mail'] == 'true') | (zoho_df['Do Not Contact'] == 'true')]
# count_dnm = dnm_leads.shape[0]

# %%
# zoho_df.drop(dnm_leads.index, inplace=True)
# zoho_df.reset_index(drop=True, inplace=True)

# count_after_dedup_dnm = zoho_df.shape[0]

# %%
# Cek Email OTA
email_OTA = m.find_OTA(zoho_df, 'Email')
count_email_OTA = email_OTA.shape[0]
# email_OTA.to_excel(r'C:\Users\fajar.fatoni\Documents\Python\Data\email_OTA.xlsx', index=False)

email_OTA
# Out:
# Empty DataFrame
# Columns: [Record Id, Created Time, Created Date, First Name, Last Name, Email, Phone, Mobile, Birthdate, Year of Birth, Street, Street2, City, State, Country, Nationality, Booking Status, BookRef, Departure Date, Arrival Date, Card Type, Marital Status, Lead Brand, Lead Sub-Brand, Lead Source, Lead Locations, Lead Source Description, Lead Regions, Lead Status, Email Opt Out, Opt In, GDPR Compliant, Website, Comments, Do you live in Bali?]
# Index: []
#
# [0 rows x 35 columns]

# %%
# delete email OTA
count_after_clean_OTA = m.delete_OTA(zoho_df, 'Email')
# zoho_df.to_excel(r'C:\Users\fajar.fatoni\Documents\Python\Data\after_clean_OTA.xlsx', index=False)

zoho_df
# Out:
#                     Record Id        Created Time Created Date  \
# 0    zcrm_3584690000501053077 2024-07-04 07:54:15        empty
# 1    zcrm_3584690000501057143 2024-07-04 14:52:47        empty
# 2    zcrm_3584690000501061001 2024-07-03 21:56:57        empty
# 3    zcrm_3584690000501102002 2024-07-04 06:13:21        empty
# 4    zcrm_3584690000501132076 2024-07-04 17:31:54        empty
# ..                        ...                 ...          ...
# 760  zcrm_3584690000530696001 2025-03-17 01:03:04        empty
# 761  zcrm_3584690000530815033 2025-03-17 09:22:31        empty
# 762  zcrm_3584690000530901644 2025-03-17 13:39:02        empty
# 763  zcrm_3584690000530902623 2025-03-17 14:35:05        empty
# 764  zcrm_3584690000531042001 2025-03-17 14:55:56        empty
#
#          First Name       Last Name                      Email         Phone  \
# 0            Rishan       Neelawala        littauk@yahoo.co.uk  610433912771
# 1            Yilmaz           Erbas      ylmzerbas@hotmail.com   61423207375
# 2    Michael Roepen  Michael Roepen      cackle067@hotmail.com   61403602041
# 3            Ganesh        Shevkari          gps7777@gmail.com   61423962131
# 4            Leanne            Gatt     leannegatt62@gmail.com   61402312248
# ..              ...             ...                        ...           ...
# 760         Vherine         Stiller       cherines@live.com.au   61424862780
# 761            Mark           Cross  markcross502@yahoo.com.au  610411606162
# 762       Julieanne          Patten  julieannep@westnet.com.au   61428590886
# 763           Test2         Thiru93    test034thiru2@gmail.com   61465654565
# 764           Tanya     Esterhuizen       tanyaglam2@gmail.com  610405140796
#
#            Mobile Birthdate Year of Birth  ... Lead Locations  \
# 0    610433912771     empty         empty  ...        General
# 1     61423207375     empty         empty  ...        General
# 2     61403602041     empty         empty  ...        General
# 3     61423962131     empty         empty  ...        General
# 4     61402312248     empty         empty  ...        General
# ..            ...       ...           ...  ...            ...
# 760   61424862780     empty         empty  ...          empty
# 761  610411606162     empty         empty  ...        General
# 762   61428590886     empty         empty  ...        General
# 763   61465654565     empty         empty  ...          empty
# 764  610405140796     empty          1971  ...        General
#
#                                Lead Source Description Lead Regions  \
# 0                                KE | WEB | Contact Us         SEAP
# 1    KE | Web | Destination Amina Lantana Hoi An Ho...         SEAP
# 2    KE | Web | Destination Amina Lantana Hoi An Ho...         SEAP
# 3          KE | Web | Destination Karma Royal Jimbaran         SEAP
# 4                             KE | Web | Destination |         SEAP
# ..                                                 ...          ...
# 760                                 KE | WEB | Kandara         SEAP
# 761  KE | Web | Destination March Samui Resort, Koh...         SEAP
# 762  KE | Web | Destination Karma Kandara Mentari R...         SEAP
# 763                               KE | WEB | KEPH Pago         SEAP
# 764  KE3 | EDM | KARMA KAMELEON - KARMA KANDARA | w...         SEAP
#
#        Lead Status Email Opt Out Opt In GDPR Compliant  \
# 0    Not Qualified         false  false          false
# 1    Not Qualified         false  false          false
# 2    Not Qualified         false  false          false
# 3    Not Qualified         false  false          false
# 4    Not Qualified         false  false          false
# ..             ...           ...    ...            ...
# 760  Not Qualified         false  false          false
# 761  Not Qualified         false  false          false
# 762  Not Qualified         false  false          false
# 763  Not Qualified         false  false          false
# 764          empty         false  false          false
#
#                                                Website Comments  \
# 0             https://www.karmaexperience.com/contact/    empty
# 1    https://www.karmaexperience.com/destinations/a...    empty
# 2    https://www.karmaexperience.com/destinations/a...    empty
# 3    https://www.karmaexperience.com/destinations/k...    empty
# 4    https://www.karmaexperience.com/#destinationch...    empty
# ..                                                 ...      ...
# 760                       https://karmaexperience.com/    empty
# 761  https://karmaexperience.com/hotel-partner/marc...    empty
# 762  https://karmaexperience.com/destinations/karma...    empty
# 763                      https://karmaexperience.com/#    empty
# 764                                              empty    empty
#
#     Do you live in Bali?
# 0                  false
# 1                  false
# 2                  false
# 3                  false
# 4                  false
# ..                   ...
# 760                false
# 761                false
# 762                false
# 763                false
# 764                false
#
# [765 rows x 35 columns]

# %%
# Cek Email Karma
email_karma = m.find_karma(zoho_df, 'Email')
count_email_karma = email_karma.shape[0]
# email_OTA.to_excel(r'C:\Users\fajar.fatoni\Documents\Python\Data\email_OTA.xlsx', index=False)

email_karma
# Out:
# Empty DataFrame
# Columns: [Record Id, Created Time, Created Date, First Name, Last Name, Email, Phone, Mobile, Birthdate, Year of Birth, Street, Street2, City, State, Country, Nationality, Booking Status, BookRef, Departure Date, Arrival Date, Card Type, Marital Status, Lead Brand, Lead Sub-Brand, Lead Source, Lead Locations, Lead Source Description, Lead Regions, Lead Status, Email Opt Out, Opt In, GDPR Compliant, Website, Comments, Do you live in Bali?]
# Index: []
#
# [0 rows x 35 columns]

# %%
# delete email Karma
count_after_clean_karma = m.delete_karma(zoho_df, 'Email')
# zoho_df.to_excel(r'C:\Users\fajar.fatoni\Documents\Python\Data\after_clean_OTA.xlsx', index=False)

zoho_df
# Out:
#                     Record Id        Created Time Created Date  \
# 0    zcrm_3584690000501053077 2024-07-04 07:54:15        empty
# 1    zcrm_3584690000501057143 2024-07-04 14:52:47        empty
# 2    zcrm_3584690000501061001 2024-07-03 21:56:57        empty
# 3    zcrm_3584690000501102002 2024-07-04 06:13:21        empty
# 4    zcrm_3584690000501132076 2024-07-04 17:31:54        empty
# ..                        ...                 ...          ...
# 760  zcrm_3584690000530696001 2025-03-17 01:03:04        empty
# 761  zcrm_3584690000530815033 2025-03-17 09:22:31        empty
# 762  zcrm_3584690000530901644 2025-03-17 13:39:02        empty
# 763  zcrm_3584690000530902623 2025-03-17 14:35:05        empty
# 764  zcrm_3584690000531042001 2025-03-17 14:55:56        empty
#
#          First Name       Last Name                      Email         Phone  \
# 0            Rishan       Neelawala        littauk@yahoo.co.uk  610433912771
# 1            Yilmaz           Erbas      ylmzerbas@hotmail.com   61423207375
# 2    Michael Roepen  Michael Roepen      cackle067@hotmail.com   61403602041
# 3            Ganesh        Shevkari          gps7777@gmail.com   61423962131
# 4            Leanne            Gatt     leannegatt62@gmail.com   61402312248
# ..              ...             ...                        ...           ...
# 760         Vherine         Stiller       cherines@live.com.au   61424862780
# 761            Mark           Cross  markcross502@yahoo.com.au  610411606162
# 762       Julieanne          Patten  julieannep@westnet.com.au   61428590886
# 763           Test2         Thiru93    test034thiru2@gmail.com   61465654565
# 764           Tanya     Esterhuizen       tanyaglam2@gmail.com  610405140796
#
#            Mobile Birthdate Year of Birth  ... Lead Locations  \
# 0    610433912771     empty         empty  ...        General
# 1     61423207375     empty         empty  ...        General
# 2     61403602041     empty         empty  ...        General
# 3     61423962131     empty         empty  ...        General
# 4     61402312248     empty         empty  ...        General
# ..            ...       ...           ...  ...            ...
# 760   61424862780     empty         empty  ...          empty
# 761  610411606162     empty         empty  ...        General
# 762   61428590886     empty         empty  ...        General
# 763   61465654565     empty         empty  ...          empty
# 764  610405140796     empty          1971  ...        General
#
#                                Lead Source Description Lead Regions  \
# 0                                KE | WEB | Contact Us         SEAP
# 1    KE | Web | Destination Amina Lantana Hoi An Ho...         SEAP
# 2    KE | Web | Destination Amina Lantana Hoi An Ho...         SEAP
# 3          KE | Web | Destination Karma Royal Jimbaran         SEAP
# 4                             KE | Web | Destination |         SEAP
# ..                                                 ...          ...
# 760                                 KE | WEB | Kandara         SEAP
# 761  KE | Web | Destination March Samui Resort, Koh...         SEAP
# 762  KE | Web | Destination Karma Kandara Mentari R...         SEAP
# 763                               KE | WEB | KEPH Pago         SEAP
# 764  KE3 | EDM | KARMA KAMELEON - KARMA KANDARA | w...         SEAP
#
#        Lead Status Email Opt Out Opt In GDPR Compliant  \
# 0    Not Qualified         false  false          false
# 1    Not Qualified         false  false          false
# 2    Not Qualified         false  false          false
# 3    Not Qualified         false  false          false
# 4    Not Qualified         false  false          false
# ..             ...           ...    ...            ...
# 760  Not Qualified         false  false          false
# 761  Not Qualified         false  false          false
# 762  Not Qualified         false  false          false
# 763  Not Qualified         false  false          false
# 764          empty         false  false          false
#
#                                                Website Comments  \
# 0             https://www.karmaexperience.com/contact/    empty
# 1    https://www.karmaexperience.com/destinations/a...    empty
# 2    https://www.karmaexperience.com/destinations/a...    empty
# 3    https://www.karmaexperience.com/destinations/k...    empty
# 4    https://www.karmaexperience.com/#destinationch...    empty
# ..                                                 ...      ...
# 760                       https://karmaexperience.com/    empty
# 761  https://karmaexperience.com/hotel-partner/marc...    empty
# 762  https://karmaexperience.com/destinations/karma...    empty
# 763                      https://karmaexperience.com/#    empty
# 764                                              empty    empty
#
#     Do you live in Bali?
# 0                  false
# 1                  false
# 2                  false
# 3                  false
# 4                  false
# ..                   ...
# 760                false
# 761                false
# 762                false
# 763                false
# 764                false
#
# [765 rows x 35 columns]

# %%
find_member_booking = zoho_df.copy()

find_member_booking.loc[find_member_booking['Phone'].isin(df_booking['Phone1']), 'Same Value Find'] = 'Booking-Phone1'
find_member_booking.loc[find_member_booking['Phone'].isin(df_booking['Mobile']), 'Same Value Find'] = 'Booking-Mobile'
find_member_booking.loc[find_member_booking['Mobile'].isin(df_booking['Phone1']), 'Same Value Find'] = 'Booking-Phone1' 
find_member_booking.loc[find_member_booking['Mobile'].isin(df_booking['Mobile']), 'Same Value Find'] = 'Booking-Mobile'
find_member_booking.loc[find_member_booking['Email'].isin(df_booking['Email']), 'Same Value Find'] = 'Booking-Email'

find_member_booking.loc[find_member_booking['Phone'].isin(df_phone['Mobile']), 'Same Value Find'] = 'Member-Mobile' 
find_member_booking.loc[find_member_booking['Mobile'].isin(df_phone['Mobile']), 'Same Value Find'] = 'Member-Mobile'

find_member_booking.loc[find_member_booking['Email'].isin(df_email['Email']), 'Same Value Find'] = 'Member-Email'

find_member_booking.drop(find_member_booking.loc[find_member_booking['Same Value Find'].isna()].index, inplace=True)

count_booking_dedup = find_member_booking.loc[find_member_booking['Same Value Find'].str.contains('Booking', flags=re.I, regex=True)].shape[0]
count_member_dedup = find_member_booking.loc[find_member_booking['Same Value Find'].str.contains('Member', flags=re.I, regex=True)].shape[0]

find_member_booking.replace('empty', '', inplace=True)
# find_member_booking.to_csv(r'C:\Users\fajar.fatoni\Documents\Python\Data\booking-member-dedup.csv', index=False)
# find_member_booking.to_excel(r'C:\Users\fajar.fatoni\Documents\Python\Data\booking-member-dedup.xlsx', index=False)

#find_member_booking.loc[find_member_booking['Same Value Find'] == 'Booking-Phone1']

# %%
# data phone, mobile dam email member yang ada di master data 
count_wash_member = zoho_df.loc[
    zoho_df['Phone'].isin(df_booking['Phone1']) | 
    zoho_df['Phone'].isin(df_booking['Mobile']) |
    zoho_df['Mobile'].isin(df_booking['Phone1']) | 
    zoho_df['Mobile'].isin(df_booking['Mobile']) |
    zoho_df['Email'].isin(df_booking['Email'])| 

    zoho_df['Phone'].isin(df_phone['Mobile']) | 
    zoho_df['Mobile'].isin(df_phone['Mobile']) |

    zoho_df['Email'].isin(df_email['Email'])

].shape[0]

zoho_df.drop(zoho_df.loc[
    zoho_df['Phone'].isin(df_booking['Phone1']) | 
    zoho_df['Phone'].isin(df_booking['Mobile']) |
    zoho_df['Mobile'].isin(df_booking['Phone1']) | 
    zoho_df['Mobile'].isin(df_booking['Mobile']) |
    zoho_df['Email'].isin(df_booking['Email']) |
    
    zoho_df['Phone'].isin(df_phone['Mobile']) | 
    zoho_df['Mobile'].isin(df_phone['Mobile']) |

    zoho_df['Email'].isin(df_email['Email'])

    ].index, inplace=True)
    
zoho_df.reset_index(drop=True, inplace=True)

count_after_wash_member = zoho_df.shape[0]

# %%
# Categorize contacts
m.categorize_contacts(zoho_df)

# Count contact types
count_email_only = (zoho_df['Contact Type'] == 'Email Only').sum()
count_phone_only = (zoho_df['Contact Type'] == 'Phone Only').sum()
count_email_and_phone = (zoho_df['Contact Type'] == 'Email and Phone').sum()
count_blank = (zoho_df['Contact Type'] == 'Blank').sum()

# Remove blank contacts if needed
zoho_df = zoho_df[zoho_df['Contact Type'] != 'Blank']
zoho_df.reset_index(drop=True, inplace=True)

count_after_wash_blank = zoho_df.shape[0]

# %%
arr_dedup = [count_deleted_wrong_format, count_duplicate_general, count_leads_test, count_email_OTA, count_email_karma, count_blank]
count_sum_dedup = sum(arr_dedup)
count_sum_dedup
# Out:
# np.int64(30)

# %%
print("==========================================================")
print("Summary")
print("==========================================================")
print("Jumlah Keseluruhan Master Zoho : "+str(count_data_awal))
print("Jumlah Filter Leads Awal : "+str(count_filter_awal))
print("Jumlah Format Email Salah : "+str(count_deleted_wrong_format))
print("Jumlah Setelah Clean Format Email Salah : "+str(count_after_deleted_wrong_format))
print("Jumlah Duplicate (Phone, Mobile dan Email) : "+str(count_duplicate_general))
print("Jumlah Setelah Clean Duplicate : "+str(count_after_dedup_duplicate))
print("Jumlah Lead Test : "+str(count_leads_test))
print("Jumlah Setelah Clean Lead Test : "+str(count_after_dedup_test))
# print("Jumlah Lead Do Not Mail : "+str(count_dnm))
# print("Jumlah Setelah Clean Lead Do Not Mail : "+str(count_after_dedup_dnm))
print("Jumlah Email OTA : "+str(count_email_OTA))
print("Jumlah Setelah Clean Email OTA : "+str(count_after_clean_OTA))
print("Jumlah Email Karma : "+str(count_email_karma))
print("Jumlah Setelah Clean Email Karma : "+str(count_after_clean_karma))
print("Jumlah Wash Member : "+str(count_member_dedup))
print("Jumlah Wash Booking : "+str(count_booking_dedup))
print("Jumlah Setelah Wash Member : "+str(count_after_wash_member))
print("Jumlah Phone Email Blank (Setelah phone yang tidak valid dihapus) : "+str(count_blank))
print("Jumlah Setelah Wash Phone Email Blank : "+str(count_after_wash_blank))
print("==========================================================")
print("Contact Type")
print("==========================================================")
print("Jumlah Email Only : "+str(count_email_only))
print("Jumlah Phone Only : "+str(count_phone_only))
print("Jumlah Email dan Phone : "+str(count_email_and_phone))
# Out:
# ==========================================================
# Summary
# ==========================================================
# Jumlah Keseluruhan Master Zoho : 500015
# Jumlah Filter Leads Awal : 795
# Jumlah Format Email Salah : 0
# Jumlah Setelah Clean Format Email Salah : 795
# Jumlah Duplicate (Phone, Mobile dan Email) : 28
# Jumlah Setelah Clean Duplicate : 767
# Jumlah Lead Test : 2
# Jumlah Setelah Clean Lead Test : 765
# Jumlah Email OTA : 0
# Jumlah Setelah Clean Email OTA : 765
# Jumlah Email Karma : 0
# Jumlah Setelah Clean Email Karma : 765
# Jumlah Wash Member : 44
# Jumlah Wash Booking : 16
# Jumlah Setelah Wash Member : 705
# Jumlah Phone Email Blank (Setelah phone yang tidak valid dihapus) : 0
# Jumlah Setelah Wash Phone Email Blank : 705
# ==========================================================
# Contact Type
# ==========================================================
# Jumlah Email Only : 8
# Jumlah Phone Only : 0
# Jumlah Email dan Phone : 697

# %%
print("==========================================================")
print("Summary Report")
print("==========================================================")
print("Jumlah Data Awal : "+str(count_filter_awal))
print("Jumlah Wash Dedup : "+str(count_sum_dedup))
print("Jumlah Wash Member : "+str(count_member_dedup))
print("Jumlah Wash Booking : "+str(count_booking_dedup))
print("Jumlah Data Akhir : "+str(count_after_wash_blank))
# Out:
# ==========================================================
# Summary Report
# ==========================================================
# Jumlah Data Awal : 795
# Jumlah Wash Dedup : 30
# Jumlah Wash Member : 44
# Jumlah Wash Booking : 16
# Jumlah Data Akhir : 705

# %% [markdown]
# # ====================== Akhir Filter Umum ======================

# %%
# Function to clean illegal characters except "Created Time"
def clean_illegal_chars(df):
    def remove_illegal_chars(value):
        if isinstance(value, str):
            return "".join(c for c in value if ord(c) >= 32)
        return value
    
    # Apply cleaning only to non-"Created Time" columns
    for col in df.columns:
        if col != "Created Time":  # Exclude "Created Time" from cleaning
            df[col] = df[col].apply(remove_illegal_chars)

    return df

# Load your dataframe (zoho_df assumed to be already loaded)
zoho_df.replace('empty', '', inplace=True, regex=True)

# Format name columns properly
zoho_df['First Name'] = zoho_df['First Name'].str.title()
zoho_df['Last Name'] = zoho_df['Last Name'].str.title()

# Define output path
output_path = r'C:\Users\fajar.fatoni\Documents\Python\Data\karma_experience.xlsx'

try:
    zoho_df.to_excel(output_path, index=False)
except IllegalCharacterError:
    print("IllegalCharacterError detected! Cleaning data...")
    zoho_df = clean_illegal_chars(zoho_df)  # Clean only non-"Created Time" columns
    zoho_df.to_excel(output_path, index=False)
    print("File saved successfully after cleaning.")

print(f"File saved at: {output_path}")
# Out:
# File saved at: C:\Users\fajar.fatoni\Documents\Python\Data\karma_experience.xlsx

# %%
zoho_df.groupby('Country').count()
# Out:
#                       Record Id  Created Time  Created Date  First Name  \
# Country
#                               7             7             7           7
# Australia                   569           569           569         569
# Brunei                        1             1             1           1
# Canada                        2             2             2           2
# Denmark                       2             2             2           2
# France                        1             1             1           1
# Germany                       1             1             1           1
# Hong Kong                     1             1             1           1
# India                        74            74            74          74
# Indonesia                    18            18            18          18
# Ireland                       1             1             1           1
# Israel                        1             1             1           1
# Latvia                        1             1             1           1
# Malaysia                      2             2             2           2
# Montenegro                    1             1             1           1
# Nepal                         1             1             1           1
# Philippines                   1             1             1           1
# Singapore                     5             5             5           5
# Spain                         1             1             1           1
# Thailand                      1             1             1           1
# Thailand (ไทย)                1             1             1           1
# Tunisia                       1             1             1           1
# United Arab Emirates          2             2             2           2
# United Kingdom                4             4             4           4
# United States                 6             6             6           6
#
#                       Last Name  Email  Phone  Mobile  Birthdate  \
# Country
#                               7      7      7       7          7
# Australia                   569    569    569     569        569
# Brunei                        1      1      1       1          1
# Canada                        2      2      2       2          2
# Denmark                       2      2      2       2          2
# France                        1      1      1       1          1
# Germany                       1      1      1       1          1
# Hong Kong                     1      1      1       1          1
# India                        74     74     74      74         74
# Indonesia                    18     18     18      18         18
# Ireland                       1      1      1       1          1
# Israel                        1      1      1       1          1
# Latvia                        1      1      1       1          1
# Malaysia                      2      2      2       2          2
# Montenegro                    1      1      1       1          1
# Nepal                         1      1      1       1          1
# Philippines                   1      1      1       1          1
# Singapore                     5      5      5       5          5
# Spain                         1      1      1       1          1
# Thailand                      1      1      1       1          1
# Thailand (ไทย)                1      1      1       1          1
# Tunisia                       1      1      1       1          1
# United Arab Emirates          2      2      2       2          2
# United Kingdom                4      4      4       4          4
# United States                 6      6      6       6          6
#
#                       Year of Birth  ...  Lead Source Description  \
# Country                              ...
#                                   7  ...                        7
# Australia                       569  ...                      569
# Brunei                            1  ...                        1
# Canada                            2  ...                        2
# Denmark                           2  ...                        2
# France                            1  ...                        1
# Germany                           1  ...                        1
# Hong Kong                         1  ...                        1
# India                            74  ...                       74
# Indonesia                        18  ...                       18
# Ireland                           1  ...                        1
# Israel                            1  ...                        1
# Latvia                            1  ...                        1
# Malaysia                          2  ...                        2
# Montenegro                        1  ...                        1
# Nepal                             1  ...                        1
# Philippines                       1  ...                        1
# Singapore                         5  ...                        5
# Spain                             1  ...                        1
# Thailand                          1  ...                        1
# Thailand (ไทย)                    1  ...                        1
# Tunisia                           1  ...                        1
# United Arab Emirates              2  ...                        2
# United Kingdom                    4  ...                        4
# United States                     6  ...                        6
#
#                       Lead Regions  Lead Status  Email Opt Out  Opt In  \
# Country
#                                  7            7              7       7
# Australia                      569          569            569     569
# Brunei                           1            1              1       1
# Canada                           2            2              2       2
# Denmark                          2            2              2       2
# France                           1            1              1       1
# Germany                          1            1              1       1
# Hong Kong                        1            1              1       1
# India                           74           74             74      74
# Indonesia                       18           18             18      18
# Ireland                          1            1              1       1
# Israel                           1            1              1       1
# Latvia                           1            1              1       1
# Malaysia                         2            2              2       2
# Montenegro                       1            1              1       1
# Nepal                            1            1              1       1
# Philippines                      1            1              1       1
# Singapore                        5            5              5       5
# Spain                            1            1              1       1
# Thailand                         1            1              1       1
# Thailand (ไทย)                   1            1              1       1
# Tunisia                          1            1              1       1
# United Arab Emirates             2            2              2       2
# United Kingdom                   4            4              4       4
# United States                    6            6              6       6
#
#                       GDPR Compliant  Website  Comments  Do you live in Bali?  \
# Country
#                                    7        7         7                     7
# Australia                        569      569       569                   569
# Brunei                             1        1         1                     1
# Canada                             2        2         2                     2
# Denmark                            2        2         2                     2
# France                             1        1         1                     1
# Germany                            1        1         1                     1
# Hong Kong                          1        1         1                     1
# India                             74       74        74                    74
# Indonesia                         18       18        18                    18
# Ireland                            1        1         1                     1
# Israel                             1        1         1                     1
# Latvia                             1        1         1                     1
# Malaysia                           2        2         2                     2
# Montenegro                         1        1         1                     1
# Nepal                              1        1         1                     1
# Philippines                        1        1         1                     1
# Singapore                          5        5         5                     5
# Spain                              1        1         1                     1
# Thailand                           1        1         1                     1
# Thailand (ไทย)                     1        1         1                     1
# Tunisia                            1        1         1                     1
# United Arab Emirates               2        2         2                     2
# United Kingdom                     4        4         4                     4
# United States                      6        6         6                     6
#
#                       Contact Type
# Country
#                                  7
# Australia                      569
# Brunei                           1
# Canada                           2
# Denmark                          2
# France                           1
# Germany                          1
# Hong Kong                        1
# India                           74
# Indonesia                       18
# Ireland                          1
# Israel                           1
# Latvia                           1
# Malaysia                         2
# Montenegro                       1
# Nepal                            1
# Philippines                      1
# Singapore                        5
# Spain                            1
# Thailand                         1
# Thailand (ไทย)                   1
# Tunisia                          1
# United Arab Emirates             2
# United Kingdom                   4
# United States                    6
#
# [25 rows x 35 columns]

# %%
# zoho_df['Country'].loc[
#     (zoho_df['Phone'].str.contains('^44|^\+44')) & 
#     (~zoho_df['Country'].str.contains('united kingdom|wales|england|scotland|northern ireland', regex=True, flags=re.I))
# ]
