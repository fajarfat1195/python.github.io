# %%
import main_module as m
import zoho_filter_module as fil
import pandas as pd
import re
import numpy as np

# %load_ext autoreload
# %autoreload 2

dir_path = r'C:\Users\fajar\Documents\Python\Data\Zoho_Backup'
file_name = '\Leads_'

cols = ['Record Id',	
'Created Time',
'Created Date',	
'First Name',	
'Last Name',	
'Email',	
'Phone',	
'Mobile',	
'Birthdate',	
'Year of Birth',
'Street',	
'Street2',	
'City',	
'State',	
'Country',	
'Nationality',
'Booking Status', 
'BookRef',
'Departure Date',	
'Arrival Date',	
'Card Type',	
'Marital Status',	
'Lead Brand',	
'Lead Sub-Brand',	
'Lead Source',	
'Lead Locations',	
'Lead Source Description',	
'Lead Regions',
'Lead Status',
'Email Opt Out',	
'Opt In',
'GDPR Compliant',
'Website']
# Out:
# <>:11: SyntaxWarning: invalid escape sequence '\L'
# <>:11: SyntaxWarning: invalid escape sequence '\L'
# C:\Users\fajar\AppData\Local\Temp\ipykernel_8380\3222793355.py:11: SyntaxWarning: invalid escape sequence '\L'
#   file_name = '\Leads_'

# %%
df = m.load_data_multiple(dir_path, file_name, cols)
count_data_awal = df.shape[0]
df = df.reindex(columns=cols)
df.shape[0]

df['Created Time'] = pd.to_datetime(df['Created Time'], format='%Y-%m-%d %H:%M:%S')
df['Arrival Date'] = pd.to_datetime(df['Arrival Date'], format='%Y-%m-%d')
df['Departure Date'] = pd.to_datetime(df['Departure Date'], format='%Y-%m-%d')
# fungsi errors cource untuk menhindari error jika value data date null atau kosong
# df['Birthdate'] = pd.to_datetime(df['Birthdate'], format='%Y-%m-%d', errors='coerce')
df.dtypes
df
# Out:
#                        Record Id        Created Time Created Date First Name  \
# 0       zcrm_3584690000000404602 2019-01-08 11:07:28   2021-07-21   Frederic
# 1       zcrm_3584690000000450071 2019-01-08 16:38:18         <NA>  Sebastian
# 2       zcrm_3584690000000450087 2019-01-08 16:38:18         <NA>    Siobhan
# 3       zcrm_3584690000000450106 2019-01-08 16:38:18         <NA>       Lisa
# 4       zcrm_3584690000000450109 2019-01-08 16:38:18         <NA>  Ana Maria
# ...                          ...                 ...          ...        ...
# 462403  zcrm_3584690000504265571 2024-08-05 17:37:48         <NA>      Goyal
# 462404  zcrm_3584690000504265572 2024-08-05 17:37:48         <NA>      Bryan
# 462405  zcrm_3584690000504265573 2024-08-05 17:37:48         <NA>        Oki
# 462406  zcrm_3584690000504265574 2024-08-05 17:37:48         <NA>       Arya
# 462407  zcrm_3584690000504265575 2024-08-05 17:37:48         <NA>       Info
#
#         Last Name                        Email           Phone Mobile  \
# 0           Bonin    fredericbonin79@gmail.com  +6281236100502   <NA>
# 1            Rach                         <NA>   +498914342111   <NA>
# 2       Gallagher  gallaghersiobhan@eircom.net    353879597603   <NA>
# 3       Ferkovich         lisajo2009@yahoo.com     14062394749   <NA>
# 4        Weileder     m.weileder@sonnenlink.de     15253234700   <NA>
# ...           ...                          ...             ...    ...
# 462403  Madhurima                         <NA>    919986885250   <NA>
# 462404    Whiting                         <NA>    447931789709   <NA>
# 462405  Ramadhana                         <NA>     62811150700   <NA>
# 462406     Wijaya                         <NA>   6285738679736   <NA>
# 462407        Bri                         <NA>   6281393445510   <NA>
#
#          Birthdate Year of Birth  ... Lead Sub-Brand       Lead Source  \
# 0       1981-10-03          1981  ...          Other            Agency
# 1       1982-04-20          1982  ...          Other       Past Guests
# 2       1973-03-14          1973  ...          Other       Past Guests
# 3       1963-07-08          1963  ...          Other       Past Guests
# 4             <NA>          <NA>  ...          Other             Other
# ...            ...           ...  ...            ...               ...
# 462403        <NA>          <NA>  ...          Other  WhatsApp Enquiry
# 462404        <NA>          <NA>  ...          Other  WhatsApp Enquiry
# 462405        <NA>          <NA>  ...          Other  WhatsApp Enquiry
# 462406        <NA>          <NA>  ...          Other  WhatsApp Enquiry
# 462407        <NA>          <NA>  ...          Other  WhatsApp Enquiry
#
#         Lead Locations          Lead Source Description Lead Regions  \
# 0        Karma Kandara                            KAREN         SEAP
# 1        Karma Bavaria                             <NA>    UK/Europe
# 2        Karma Bavaria                             <NA>    UK/Europe
# 3        Karma Bavaria                             <NA>    UK/Europe
# 4        Karma Bavaria  MICE Contacts from Ioanna email    UK/Europe
# ...                ...                              ...          ...
# 462403  Karma Jimbaran                             <NA>         <NA>
# 462404  Karma Jimbaran                             <NA>         <NA>
# 462405  Karma Jimbaran                             <NA>         <NA>
# 462406  Karma Jimbaran                             <NA>         <NA>
# 462407  Karma Jimbaran                             <NA>         <NA>
#
#        Lead Status Email Opt Out Opt In GDPR Compliant Website
# 0         New Lead         false  false          false    <NA>
# 1         New Lead          true  false          false    <NA>
# 2         New Lead         false   true           true    <NA>
# 3         New Lead          true  false          false    <NA>
# 4         New Lead         false   true           true    <NA>
# ...            ...           ...    ...            ...     ...
# 462403    New Lead         false  false          false    <NA>
# 462404    New Lead         false  false          false    <NA>
# 462405    New Lead         false  false          false    <NA>
# 462406    New Lead         false  false          false    <NA>
# 462407    New Lead         false  false          false    <NA>
#
# [462408 rows x 33 columns]

# %%
df.loc[df['Phone'].str.contains('^\\+62', regex=True)]
# Out:
#                        Record Id        Created Time Created Date  \
# 0       zcrm_3584690000000404602 2019-01-08 11:07:28   2021-07-21
# 10      zcrm_3584690000000450191 2019-01-08 16:38:18   2021-07-21
# 12      zcrm_3584690000000450226 2019-01-08 16:38:18   2021-07-21
# 33      zcrm_3584690000000456097 2019-01-09 11:10:49   2021-07-21
# 86      zcrm_3584690000000456162 2019-01-09 11:10:49   2021-07-21
# ...                          ...                 ...          ...
# 460110  zcrm_3584690000504244407 2024-08-05 16:51:13         <NA>
# 460111  zcrm_3584690000504244475 2024-08-05 16:53:24         <NA>
# 460133  zcrm_3584690000504251108 2024-08-05 16:50:03         <NA>
# 460136  zcrm_3584690000504252097 2024-08-05 16:30:03         <NA>
# 460144  zcrm_3584690000504256006 2024-08-05 16:20:54         <NA>
#
#            First Name   Last Name                                   Email  \
# 0            Frederic       Bonin               fredericbonin79@gmail.com
# 10      Ni Made Novia    Andryani                    novia_made@yahoo.com
# 12        Maureellins     Joewyns            maureellinsjoewyns@gmail.com
# 33                 Di       Zhang                        156864136@qq.com
# 86         Ganef Hari  Sulistiono                   abahdendy99@gmail.com
# ...               ...         ...                                     ...
# 460110          Benny     Risanto  benny.risanto+no18rtest@karmagroup.com
# 460111          Benny     Risanto     benny.risanto+yayem3@karmagroup.com
# 460133          Benny     Risanto       benny.risanto+tgtr@karmagroup.com
# 460136          Benny     Risanto      benny.risanto+TRGCR@karmagroup.com
# 460144          Benny     Risanto       benny.risanto+TEST@karmagroup.com
#
#                    Phone Mobile   Birthdate Year of Birth  ...  \
# 0         +6281236100502   <NA>  1981-10-03          1981  ...
# 10        +6281511634635   <NA>  1980-11-10          1980  ...
# 12        +6282221100639   <NA>  2000-04-14          2000  ...
# 33      +628618339280777   <NA>        <NA>          <NA>  ...
# 86         +628123255435   <NA>  1963-12-16          1963  ...
# ...                  ...    ...         ...           ...  ...
# 460110      +62811392202   <NA>  2024-08-30          <NA>  ...
# 460111      +62811392202   <NA>  2024-08-27          <NA>  ...
# 460133      +62811392202   <NA>  2024-08-14          <NA>  ...
# 460136      +62811392202   <NA>  1991-03-01          <NA>  ...
# 460144      +62811392202   <NA>  2005-08-03          <NA>  ...
#
#         Lead Sub-Brand Lead Source Lead Locations   Lead Source Description  \
# 0                Other      Agency  Karma Kandara                     KAREN
# 10               Other      Agency  Karma Kandara                     KAREN
# 12               Other      Agency  Karma Kandara                     KAREN
# 33               Other      Agency  Karma Kandara                     KAREN
# 86               Other      Agency  Karma Kandara                     KAREN
# ...                ...         ...            ...                       ...
# 460110  House Of Karma         Web           <NA>  Karma Reciprocal Members
# 460111  House Of Karma         Web           <NA>  Karma Reciprocal Members
# 460133  House Of Karma         Web           <NA>  Karma Reciprocal Members
# 460136  House Of Karma         Web           <NA>  Karma Reciprocal Members
# 460144  House Of Karma         Web           <NA>  Karma Reciprocal Members
#
#        Lead Regions Lead Status Email Opt Out Opt In GDPR Compliant  \
# 0              SEAP    New Lead         false  false          false
# 10             SEAP    New Lead         false  false          false
# 12             SEAP    New Lead         false  false          false
# 33             SEAP    New Lead         false  false          false
# 86             SEAP    New Lead         false  false          false
# ...             ...         ...           ...    ...            ...
# 460110         SEAP        <NA>         false   true          false
# 460111         SEAP        <NA>         false   true          false
# 460133         SEAP        <NA>         false   true          false
# 460136         SEAP        <NA>         false   true          false
# 460144         SEAP        <NA>         false   true          false
#
#                                                   Website
# 0                                                    <NA>
# 10                                                   <NA>
# 12                                                   <NA>
# 33                                                   <NA>
# 86                                                   <NA>
# ...                                                   ...
# 460110  https://karmaclub.karmagroup.com/reciprocal-me...
# 460111  https://karmaclub.karmagroup.com/reciprocal-me...
# 460133  https://karmaclub.karmagroup.com/reciprocal-me...
# 460136  https://karmaclub.karmagroup.com/reciprocal-me...
# 460144  https://karmaclub.karmagroup.com/reciprocal-me...
#
# [33906 rows x 33 columns]

# %%
path = r'G:\.shortcut-targets-by-id\0B_d3smBjzo04eXpvS1NXTWF2RVE\_BOOKING\Booking By Year\FlyBuy Booking Data (BGAU & BGID & KE).xlsx'
df_booking = pd.read_excel(path, dtype='string', sheet_name='BOOKING_BGAU_BGID_KE')

path = r'G:\.shortcut-targets-by-id\0B_d3smBjzo04UUNBME5GOVhoMjA\_ODYSSEY\Phone Members.xlsx'
df_phone = pd.read_excel(path, dtype='string', sheet_name='Sheet1')

path = r'G:\.shortcut-targets-by-id\0B_d3smBjzo04UUNBME5GOVhoMjA\_ODYSSEY\Email Members.xlsx'
df_email = pd.read_excel(path, dtype='string', sheet_name='Sheet1')

# %%
zoho_filter = fil.user_req(df)
zoho_df = df.loc[zoho_filter].copy() # menggunakan copy untuk menghindari setting copy warning
zoho_df.reset_index(drop=True, inplace=True)
count_filter_awal = zoho_df.shape[0]

# zoho_df.to_excel(r'C:\Users\fajar\Documents\Python\Data\test_leads.xlsx', index=False)
# mengisi kolom <NA> dengan value string 'empty' supaya mudah mengecek data member dan booking dengan isin

zoho_df.fillna('empty', inplace=True)
zoho_df.sort_values('Created Time', ascending=True)
# Out:
#                      Record Id        Created Time Created Date First Name  \
# 0     zcrm_3584690000000456191 2019-01-09 11:10:49        empty   Kim Guan
# 1     zcrm_3584690000000456198 2019-01-09 11:10:49        empty    Pauline
# 2     zcrm_3584690000000457744 2019-01-09 11:10:59        empty  Tan Cheng
# 3     zcrm_3584690000000458638 2019-01-09 11:11:04        empty    Eilleen
# 4     zcrm_3584690000000459002 2019-01-09 11:11:06        empty       Fong
# ...                        ...                 ...          ...        ...
# 4813  zcrm_3584690000501949300 2024-07-13 14:02:21        empty        Hue
# 4819  zcrm_3584690000501997518 2024-07-14 11:29:42        empty   philippe
# 4814  zcrm_3584690000501952879 2024-07-14 16:52:37        empty     Aileen
# 4816  zcrm_3584690000501960205 2024-07-14 19:56:26   2024-07-01     Simeen
# 4820  zcrm_3584690000501997940 2024-07-15 12:33:59        empty    Ong Sze
#
#        Last Name                     Email          Phone Mobile   Birthdate  \
# 0            Pua  adelinephua555@gmail.com          empty  empty  1937-09-14
# 1           Shek      admin@surpass.com.sg     6597811782  empty       empty
# 2           Kiat    christan@telair.com.sg     6596601533  empty  1963-11-03
# 3     Keith Luna    ekalfarosale@gmail.com     6598607340  empty  1988-11-07
# 4       Jong Han                     empty    60122987926  empty       empty
# ...          ...                       ...            ...    ...         ...
# 4813   Vern Chie       joyce_hue@yahoo.com  +600122749032  empty       empty
# 4819      magnin   philippe.mr@outlook.com    +6580234245  empty       empty
# 4814        Neoh         aneoh@hotmail.com    +6588230189  empty       empty
# 4816       Malik         simeenz@gmail.com          empty  empty       empty
# 4820       Keong       ongsk2626@gmail.com   +60123132626  empty       empty
#
#      Year of Birth  ... Lead Sub-Brand  Lead Source   Lead Locations  \
# 0             1937  ...          Other  Past Guests   Karma Jimbaran
# 1            empty  ...          Other  Past Guests   Karma Rottnest
# 2             1963  ...          Other  Past Guests    Karma Bavaria
# 3             1988  ...          Other  Past Guests    Karma Kandara
# 4            empty  ...          Other  Past Guests   Karma Rottnest
# ...            ...  ...            ...          ...              ...
# 4813         empty  ...          Other  Web Enquiry    Karma Cay Tre
# 4819         empty  ...          Other  Web Enquiry  Karma Song Hoai
# 4814         empty  ...          Other  Web Enquiry      Karma Bayon
# 4816         empty  ...      Karma Spa  Past Guests    Karma Kandara
# 4820         empty  ...          Other  Past Guests   Karma Jimbaran
#
#         Lead Source Description Lead Regions  Lead Status Email Opt Out  \
# 0                         empty        Other     New Lead          true
# 1                         empty        Other     New Lead          true
# 2                         empty        Other  No Response          true
# 3                         empty        Other  No Response          true
# 4                         empty        Other     New Lead          true
# ...                         ...          ...          ...           ...
# 4813            Form Contact Us        Other        empty         false
# 4819            Form Contact Us        Other        empty         false
# 4814  Timeshare Booking Request        Other        empty         false
# 4816                      empty        empty     New Lead         false
# 4820                  Viewpoint        empty        empty         false
#
#      Opt In GDPR Compliant                                            Website
# 0     false          false                                              empty
# 1     false          false                                              empty
# 2     false          false                                              empty
# 3     false          false                                              empty
# 4     false          false                                              empty
# ...     ...            ...                                                ...
# 4813   true          false                 https://karmagroup.com/contact-us/
# 4819   true          false                 https://karmagroup.com/contact-us/
# 4814   true           true  https://karmagroup.com/find-destination/karma-...
# 4816  false          false                                              empty
# 4820   true          false                                              empty
#
# [4821 rows x 33 columns]

# %%
zoho_df.loc[zoho_df['Lead Source Description'].str.contains('walk', regex=True, flags=re.I)]
# Out:
# Empty DataFrame
# Columns: [Record Id, Created Time, Created Date, First Name, Last Name, Email, Phone, Mobile, Birthdate, Year of Birth, Street, Street2, City, State, Country, Nationality, Booking Status, BookRef, Departure Date, Arrival Date, Card Type, Marital Status, Lead Brand, Lead Sub-Brand, Lead Source, Lead Locations, Lead Source Description, Lead Regions, Lead Status, Email Opt Out, Opt In, GDPR Compliant, Website]
# Index: []
#
# [0 rows x 33 columns]

# %% [markdown]
# # ====================== Awal Filter Umum ======================

# %%
# data phone, mobile dam email member yang ada di master data (wash member)

m.clean_number(zoho_df, 'Phone')
m.clean_number(zoho_df, 'Mobile')
m.replace_not_valid_to_empty(zoho_df, 'Phone')
m.replace_not_valid_to_empty(zoho_df, 'Mobile')
zoho_df['Email'] = m.lowercase(zoho_df, 'Email')
m.clean_space(zoho_df, 'Email')
m.clean_not_valid_email_format(zoho_df, 'Email')

m.clean_number(df_booking, 'Phone1')
m.clean_number(df_booking, 'Mobile')
df_booking['Email'] = m.lowercase(df_booking, 'Email')
m.clean_space(df_booking, 'Email')
m.clean_not_valid_email_format(df_booking, 'Email')

m.clean_number(df_phone, 'Mobile')

df_email['Email'] = m.lowercase(df_email, 'Email')
m.clean_space(df_email, 'Email')
m.clean_not_valid_email_format(df_email, 'Email')
# Out:
# 'Email'

# %%
zoho_df.loc[zoho_df['Phone']=='']
# Out:
# Empty DataFrame
# Columns: [Record Id, Created Time, Created Date, First Name, Last Name, Email, Phone, Mobile, Birthdate, Year of Birth, Street, Street2, City, State, Country, Nationality, Booking Status, BookRef, Departure Date, Arrival Date, Card Type, Marital Status, Lead Brand, Lead Sub-Brand, Lead Source, Lead Locations, Lead Source Description, Lead Regions, Lead Status, Email Opt Out, Opt In, GDPR Compliant, Website]
# Index: []
#
# [0 rows x 33 columns]

# %%
count_deleted_wrong_format = m.delete_email_wrong_format(zoho_df, 'Email')
count_after_deleted_wrong_format = zoho_df.shape[0]

# %%
# hitung jumlah duplicate
count_duplicate_general = zoho_df.loc[zoho_df.duplicated(subset=['Phone','Email', 'Mobile'])].shape[0]

zoho_df.loc[zoho_df.duplicated(subset=['Phone','Email', 'Mobile'])]
# Out:
#                      Record Id        Created Time Created Date  \
# 1643  zcrm_3584690000007255329 2019-04-02 05:36:29   2016-12-19
# 2061  zcrm_3584690000025158031 2019-04-09 21:51:45        empty
# 2283  zcrm_3584690000036494005 2019-05-28 19:46:00   2019-05-28
# 3027  zcrm_3584690000044531463 2019-06-13 16:08:39        empty
# 3085  zcrm_3584690000044532581 2019-06-13 16:08:48        empty
# ...                        ...                 ...          ...
# 4806  zcrm_3584690000501852034 2024-07-10 17:07:44        empty
# 4807  zcrm_3584690000501853034 2024-07-10 17:07:44        empty
# 4810  zcrm_3584690000501937269 2024-07-12 17:59:19        empty
# 4815  zcrm_3584690000501953346 2024-07-12 17:50:44        empty
# 4818  zcrm_3584690000501980176 2024-07-12 17:50:45        empty
#
#             First Name Last Name                      Email       Phone  \
# 1643           Sabrina        Ng                      empty  6565337704
# 2061           Jillian       Wah                      empty  6562275535
# 2283            Charis    Cheung  charischeung119@yahoo.com       empty
# 3027          Margaret       Koh                      empty  6565357704
# 3085             Janel       Teo                      empty  6591886673
# ...                ...       ...                        ...         ...
# 4806            Nicole  Urbanski          nicoleur@live.com  6580328537
# 4807            Nicole  Urbanski          nicoleur@live.com  6580328537
# 4810  Kathryn Mei Fern      Chai    kathrynchai18@yahoo.com  6598269028
# 4815  Kathryn Mei Fern      Chai    kathrynchai18@yahoo.com  6598269028
# 4818  Kathryn Mei Fern      Chai    kathrynchai18@yahoo.com  6598269028
#
#      Mobile   Birthdate Year of Birth  ... Lead Sub-Brand        Lead Source  \
# 1643  empty  1990-10-10          1990  ...     Karma Club         Membership
# 2061  empty       empty         empty  ...          Other  Chairman database
# 2283  empty       empty         empty  ...      Karma Spa        Past Guests
# 3027  empty       empty         empty  ...          Other             Agency
# 3085  empty       empty         empty  ...          Other             Agency
# ...     ...         ...           ...  ...            ...                ...
# 4806  empty       empty         empty  ...          Other        Web Enquiry
# 4807  empty       empty         empty  ...          Other        Web Enquiry
# 4810  empty       empty         empty  ...          Other        Web Enquiry
# 4815  empty       empty         empty  ...          Other        Web Enquiry
# 4818  empty       empty         empty  ...          Other        Web Enquiry
#
#      Lead Locations                            Lead Source Description  \
# 1643          empty                               External Custom Form
# 2061          empty                                          Singapore
# 2283  Karma Kandara                                              empty
# 3027          empty                                              empty
# 3085          empty                                              empty
# ...             ...                                                ...
# 4806  Karma Kandara  Karma Kandara -Download Wedding Brochure at Ka...
# 4807  Karma Kandara  Karma Kandara -Download Wedding Brochure at Ka...
# 4810  Karma Kandara  Karma Kandara -Download Wedding Brochure at Ka...
# 4815  Karma Kandara  Karma Kandara -Download Wedding Brochure at Ka...
# 4818  Karma Kandara  Karma Kandara -Download Wedding Brochure at Ka...
#
#      Lead Regions Lead Status Email Opt Out Opt In GDPR Compliant  \
# 1643        Other       empty         false  false          false
# 2061        Other    New Lead         false  false          false
# 2283        Other       empty         false  false          false
# 3027        Other    New Lead         false  false          false
# 3085        Other    New Lead         false  false          false
# ...           ...         ...           ...    ...            ...
# 4806        Other       empty         false   true          false
# 4807        Other       empty         false   true          false
# 4810        Other       empty         false   true          false
# 4815        Other       empty         false   true          false
# 4818        Other       empty         false   true          false
#
#                                                 Website
# 1643                                              empty
# 2061                                              empty
# 2283                                              empty
# 3027                                              empty
# 3085                                              empty
# ...                                                 ...
# 4806  https://karmagroup.com/weddings-at-karma-kanda...
# 4807  https://karmagroup.com/weddings-at-karma-kanda...
# 4810  https://karmagroup.com/weddings-at-karma-kanda...
# 4815  https://karmagroup.com/weddings-at-karma-kanda...
# 4818  https://karmagroup.com/weddings-at-karma-kanda...
#
# [119 rows x 33 columns]

# %%
zoho_df.drop_duplicates(subset=['Phone','Email', 'Mobile'], inplace=True)
zoho_df.reset_index(drop=True, inplace=True)

# hitung jumlah setelah value duplicate dihapus
count_after_dedup_duplicate = zoho_df.shape[0]

zoho_df
# Out:
#                      Record Id        Created Time Created Date First Name  \
# 0     zcrm_3584690000000456191 2019-01-09 11:10:49        empty   Kim Guan
# 1     zcrm_3584690000000456198 2019-01-09 11:10:49        empty    Pauline
# 2     zcrm_3584690000000457744 2019-01-09 11:10:59        empty  Tan Cheng
# 3     zcrm_3584690000000458638 2019-01-09 11:11:04        empty    Eilleen
# 4     zcrm_3584690000000459002 2019-01-09 11:11:06        empty       Fong
# ...                        ...                 ...          ...        ...
# 4697  zcrm_3584690000501952879 2024-07-14 16:52:37        empty     Aileen
# 4698  zcrm_3584690000501960205 2024-07-14 19:56:26   2024-07-01     Simeen
# 4699  zcrm_3584690000501977044 2024-07-12 03:12:18        empty     Jolene
# 4700  zcrm_3584690000501997518 2024-07-14 11:29:42        empty   philippe
# 4701  zcrm_3584690000501997940 2024-07-15 12:33:59        empty    Ong Sze
#
#        Last Name                     Email        Phone Mobile   Birthdate  \
# 0            Pua  adelinephua555@gmail.com        empty  empty  1937-09-14
# 1           Shek      admin@surpass.com.sg   6597811782  empty       empty
# 2           Kiat    christan@telair.com.sg   6596601533  empty  1963-11-03
# 3     Keith Luna    ekalfarosale@gmail.com   6598607340  empty  1988-11-07
# 4       Jong Han                     empty  60122987926  empty       empty
# ...          ...                       ...          ...    ...         ...
# 4697        Neoh         aneoh@hotmail.com   6588230189  empty       empty
# 4698       Malik         simeenz@gmail.com        empty  empty       empty
# 4699        Quek     jolenedayle@gmail.com   6596920977  empty       empty
# 4700      magnin   philippe.mr@outlook.com   6580234245  empty       empty
# 4701       Keong       ongsk2626@gmail.com  60123132626  empty       empty
#
#      Year of Birth  ... Lead Sub-Brand  Lead Source   Lead Locations  \
# 0             1937  ...          Other  Past Guests   Karma Jimbaran
# 1            empty  ...          Other  Past Guests   Karma Rottnest
# 2             1963  ...          Other  Past Guests    Karma Bavaria
# 3             1988  ...          Other  Past Guests    Karma Kandara
# 4            empty  ...          Other  Past Guests   Karma Rottnest
# ...            ...  ...            ...          ...              ...
# 4697         empty  ...          Other  Web Enquiry      Karma Bayon
# 4698         empty  ...      Karma Spa  Past Guests    Karma Kandara
# 4699         empty  ...          Other  Web Enquiry    Karma Kandara
# 4700         empty  ...          Other  Web Enquiry  Karma Song Hoai
# 4701         empty  ...          Other  Past Guests   Karma Jimbaran
#
#                                 Lead Source Description Lead Regions  \
# 0                                                 empty        Other
# 1                                                 empty        Other
# 2                                                 empty        Other
# 3                                                 empty        Other
# 4                                                 empty        Other
# ...                                                 ...          ...
# 4697                          Timeshare Booking Request        Other
# 4698                                              empty        empty
# 4699  Karma Kandara -Download Wedding Brochure at Ka...        Other
# 4700                                    Form Contact Us        Other
# 4701                                          Viewpoint        empty
#
#       Lead Status Email Opt Out Opt In GDPR Compliant  \
# 0        New Lead          true  false          false
# 1        New Lead          true  false          false
# 2     No Response          true  false          false
# 3     No Response          true  false          false
# 4        New Lead          true  false          false
# ...           ...           ...    ...            ...
# 4697        empty         false   true           true
# 4698     New Lead         false  false          false
# 4699        empty         false   true          false
# 4700        empty         false   true          false
# 4701        empty         false   true          false
#
#                                                 Website
# 0                                                 empty
# 1                                                 empty
# 2                                                 empty
# 3                                                 empty
# 4                                                 empty
# ...                                                 ...
# 4697  https://karmagroup.com/find-destination/karma-...
# 4698                                              empty
# 4699  https://karmagroup.com/weddings-at-karma-kanda...
# 4700                 https://karmagroup.com/contact-us/
# 4701                                              empty
#
# [4702 rows x 33 columns]

# %%
# Cek leads test
test_leads = zoho_df.loc[
    
        zoho_df['Email'].str.contains('^test@', flags=re.I, regex=True) |
        zoho_df['Email'].str.contains('\+test', flags=re.I, regex=True) |
    
        zoho_df['First Name'].str.contains('^test$', flags=re.I, regex=True) |
        zoho_df['Last Name'].str.contains('^test$', flags=re.I, regex=True) |

        zoho_df['First Name'].str.contains('test 1', flags=re.I, regex=True) |
        zoho_df['Last Name'].str.contains('test 2', flags=re.I, regex=True)|
        zoho_df['First Name'].str.contains('test1', flags=re.I, regex=True) |
        zoho_df['Last Name'].str.contains('test2', flags=re.I, regex=True)|

        zoho_df['First Name'].str.contains(' test ', flags=re.I, regex=True) | 
        zoho_df['Last Name'].str.contains(' test ', flags=re.I, regex=True) | 
        zoho_df['Last Name'].str.contains(' test$', flags=re.I, regex=True)
    ]

count_leads_test = test_leads.shape[0]

# test_leads.to_excel(r'C:\Users\fajar\Documents\Python\Data\test_leads_2.xlsx', index=False)
test_leads
# Out:
# Empty DataFrame
# Columns: [Record Id, Created Time, Created Date, First Name, Last Name, Email, Phone, Mobile, Birthdate, Year of Birth, Street, Street2, City, State, Country, Nationality, Booking Status, BookRef, Departure Date, Arrival Date, Card Type, Marital Status, Lead Brand, Lead Sub-Brand, Lead Source, Lead Locations, Lead Source Description, Lead Regions, Lead Status, Email Opt Out, Opt In, GDPR Compliant, Website]
# Index: []
#
# [0 rows x 33 columns]

# %%
zoho_df.drop(test_leads.index, inplace=True)
zoho_df.reset_index(drop=True, inplace=True)

count_after_dedup_test = zoho_df.shape[0]

# %%
# dnm_leads = zoho_df.loc[(zoho_df['Do Not Mail'] == 'true') | (zoho_df['Do Not Contact'] == 'true')]
# count_dnm = dnm_leads.shape[0]

# %%
# zoho_df.drop(dnm_leads.index, inplace=True)
# zoho_df.reset_index(drop=True, inplace=True)

# count_after_dedup_dnm = zoho_df.shape[0]

# %%
# Cek Email OTA
email_OTA = m.find_OTA(zoho_df, 'Email')
count_email_OTA = email_OTA.shape[0]
# email_OTA.to_excel(r'C:\Users\fajar\Documents\Python\Data\email_OTA.xlsx', index=False)

email_OTA
# Out:
#                      Record Id        Created Time Created Date First Name  \
# 836   zcrm_3584690000005994723 2019-04-02 02:19:27   2015-03-11      Nopri
# 1110  zcrm_3584690000006463501 2019-04-02 03:59:28   2015-03-10       Hock
# 1201  zcrm_3584690000007152561 2019-04-02 05:24:22   2016-04-21      James
# 3020  zcrm_3584690000044531427 2019-06-13 16:08:39        empty        Woo
# 3026  zcrm_3584690000044531711 2019-06-13 16:08:42        empty     Eileen
# 3030  zcrm_3584690000044531717 2019-06-13 16:08:42        empty     Elaine
# 3046  zcrm_3584690000044531850 2019-06-13 16:08:42        empty       Lynn
# 3101  zcrm_3584690000044532949 2019-06-13 16:08:51        empty        Amy
# 3409  zcrm_3584690000178433001 2020-04-07 20:00:42        empty      empty
#
#         Last Name                             Email        Phone       Mobile  \
# 836         Aries     summertourtravel@yahoo.com.sg        empty        empty
# 1110          Goh           beltraveltour@yahoo.com   6062822712  60126822712
# 1201       Pelham   james@culturebitesfoodtours.com   6597694845        empty
# 3020  K M (Jimmy)               econtours@gmail.com     62613218        empty
# 3026          Lim           eileen.lim@hanatour.com   6562224501   6596731516
# 3030          Lim  outbound.sales2@skyzonetours.com  60321187888        empty
# 3046           Ng             jjlynnng@hanatour.com   6562224501   6597450803
# 3101          Zuo             amyzuo@satours.com.sg     65352611   6565013927
# 3409        Jowee               jowee.soh@agoda.com        empty        empty
#
#        Birthdate Year of Birth  ... Lead Sub-Brand        Lead Source  \
# 836        empty         empty  ...          Other   Karma Chronicles
# 1110       empty         empty  ...          Other  Chairman database
# 1201  1978-10-03          1978  ...          Other  Chairman database
# 3020       empty         empty  ...          Other             Agency
# 3026       empty         empty  ...          Other             Agency
# 3030       empty         empty  ...          Other             Agency
# 3046       empty         empty  ...          Other             Agency
# 3101       empty         empty  ...          Other             Agency
# 3409       empty         empty  ...          Other            Webchat
#
#      Lead Locations                   Lead Source Description Lead Regions  \
# 836           empty                                     empty        Other
# 1110          empty                                 Singapore        Other
# 1201    John Spence                     Event Chairman Invite        Other
# 3020          empty                                     empty        Other
# 3026          empty               Yemi - 30%, TA Asian market        Other
# 3030          empty                                     empty        Other
# 3046          empty               Yemi - 30%, TA Asian market        Other
# 3101          empty               Yemi - 30%, TA Asian market        Other
# 3409          empty  Karma Resorts Reservations | Webchat Web        Other
#
#      Lead Status Email Opt Out Opt In GDPR Compliant                  Website
# 836        empty         false  false          false                    empty
# 1110       empty         false  false          false                    empty
# 1201       empty         false  false          false                    empty
# 3020    New Lead         false  false          false                    empty
# 3026    New Lead         false  false          false                    empty
# 3030    New Lead         false  false          false                    empty
# 3046    New Lead         false  false          false                    empty
# 3101    New Lead         false  false          false                    empty
# 3409       empty         false  false          false  https://www.google.com/
#
# [9 rows x 33 columns]

# %%
# delete email OTA
count_after_clean_OTA = m.delete_OTA(zoho_df, 'Email')
# zoho_df.to_excel(r'C:\Users\fajar\Documents\Python\Data\after_clean_OTA.xlsx', index=False)

zoho_df
# Out:
#                      Record Id        Created Time Created Date First Name  \
# 0     zcrm_3584690000000456191 2019-01-09 11:10:49        empty   Kim Guan
# 1     zcrm_3584690000000456198 2019-01-09 11:10:49        empty    Pauline
# 2     zcrm_3584690000000457744 2019-01-09 11:10:59        empty  Tan Cheng
# 3     zcrm_3584690000000458638 2019-01-09 11:11:04        empty    Eilleen
# 4     zcrm_3584690000000459002 2019-01-09 11:11:06        empty       Fong
# ...                        ...                 ...          ...        ...
# 4688  zcrm_3584690000501952879 2024-07-14 16:52:37        empty     Aileen
# 4689  zcrm_3584690000501960205 2024-07-14 19:56:26   2024-07-01     Simeen
# 4690  zcrm_3584690000501977044 2024-07-12 03:12:18        empty     Jolene
# 4691  zcrm_3584690000501997518 2024-07-14 11:29:42        empty   philippe
# 4692  zcrm_3584690000501997940 2024-07-15 12:33:59        empty    Ong Sze
#
#        Last Name                     Email        Phone Mobile   Birthdate  \
# 0            Pua  adelinephua555@gmail.com        empty  empty  1937-09-14
# 1           Shek      admin@surpass.com.sg   6597811782  empty       empty
# 2           Kiat    christan@telair.com.sg   6596601533  empty  1963-11-03
# 3     Keith Luna    ekalfarosale@gmail.com   6598607340  empty  1988-11-07
# 4       Jong Han                     empty  60122987926  empty       empty
# ...          ...                       ...          ...    ...         ...
# 4688        Neoh         aneoh@hotmail.com   6588230189  empty       empty
# 4689       Malik         simeenz@gmail.com        empty  empty       empty
# 4690        Quek     jolenedayle@gmail.com   6596920977  empty       empty
# 4691      magnin   philippe.mr@outlook.com   6580234245  empty       empty
# 4692       Keong       ongsk2626@gmail.com  60123132626  empty       empty
#
#      Year of Birth  ... Lead Sub-Brand  Lead Source   Lead Locations  \
# 0             1937  ...          Other  Past Guests   Karma Jimbaran
# 1            empty  ...          Other  Past Guests   Karma Rottnest
# 2             1963  ...          Other  Past Guests    Karma Bavaria
# 3             1988  ...          Other  Past Guests    Karma Kandara
# 4            empty  ...          Other  Past Guests   Karma Rottnest
# ...            ...  ...            ...          ...              ...
# 4688         empty  ...          Other  Web Enquiry      Karma Bayon
# 4689         empty  ...      Karma Spa  Past Guests    Karma Kandara
# 4690         empty  ...          Other  Web Enquiry    Karma Kandara
# 4691         empty  ...          Other  Web Enquiry  Karma Song Hoai
# 4692         empty  ...          Other  Past Guests   Karma Jimbaran
#
#                                 Lead Source Description Lead Regions  \
# 0                                                 empty        Other
# 1                                                 empty        Other
# 2                                                 empty        Other
# 3                                                 empty        Other
# 4                                                 empty        Other
# ...                                                 ...          ...
# 4688                          Timeshare Booking Request        Other
# 4689                                              empty        empty
# 4690  Karma Kandara -Download Wedding Brochure at Ka...        Other
# 4691                                    Form Contact Us        Other
# 4692                                          Viewpoint        empty
#
#       Lead Status Email Opt Out Opt In GDPR Compliant  \
# 0        New Lead          true  false          false
# 1        New Lead          true  false          false
# 2     No Response          true  false          false
# 3     No Response          true  false          false
# 4        New Lead          true  false          false
# ...           ...           ...    ...            ...
# 4688        empty         false   true           true
# 4689     New Lead         false  false          false
# 4690        empty         false   true          false
# 4691        empty         false   true          false
# 4692        empty         false   true          false
#
#                                                 Website
# 0                                                 empty
# 1                                                 empty
# 2                                                 empty
# 3                                                 empty
# 4                                                 empty
# ...                                                 ...
# 4688  https://karmagroup.com/find-destination/karma-...
# 4689                                              empty
# 4690  https://karmagroup.com/weddings-at-karma-kanda...
# 4691                 https://karmagroup.com/contact-us/
# 4692                                              empty
#
# [4693 rows x 33 columns]

# %%
# Cek Email Karma
email_karma = m.find_karma(zoho_df, 'Email')
count_email_karma = email_karma.shape[0]
# email_OTA.to_excel(r'C:\Users\fajar\Documents\Python\Data\email_OTA.xlsx', index=False)

email_karma
# Out:
#                      Record Id        Created Time Created Date First Name  \
# 571   zcrm_3584690000005973712 2019-04-02 02:17:28   2017-01-18      Fariz
# 1082  zcrm_3584690000006012896 2019-04-02 02:21:13   2017-01-18    Natalie
# 1218  zcrm_3584690000007157037 2019-04-02 05:24:46   2016-07-26       Seri
# 1889  zcrm_3584690000008522519 2019-04-02 08:11:21   2017-01-18   Jonathan
# 3308  zcrm_3584690000158666052 2020-01-13 20:54:22   2019-10-22      empty
# 3756  zcrm_3584690000414915776 2022-12-05 13:29:19        empty   Liu Juan
#
#      Last Name                   Email        Phone Mobile   Birthdate  \
# 571         Ab  odysseyasiapac@rci.com   6591060936  empty  1982-10-05
# 1082       Poh     natalie.poh@rci.com  65064122146  empty       empty
# 1218      Seri      seri.okuno@rci.com   6585690316  15708       empty
# 1889     Mills  jonathan.mills@rci.com  65091380059  empty       empty
# 3308     empty    alisa.nguyen@rci.com   6562234333  empty       empty
# 3756      Jane        jane.liu@rci.com   6562234333  empty       empty
#
#      Year of Birth  ... Lead Sub-Brand        Lead Source  \
# 571           1982  ...          Other        Past Guests
# 1082         empty  ...          Other        Past Guests
# 1218         empty  ...          Other            Webchat
# 1889         empty  ...  Other Bali DB  Chairman database
# 3308         empty  ...          Other            Webchat
# 3756         empty  ...          Other        Past Guests
#
#              Lead Locations        Lead Source Description Lead Regions  \
# 571          Karma Jimbaran                 Karma Jimbaran        Other
# 1082          Karma Kandara                  Karma Kandara        Other
# 1218                  empty                          empty        Other
# 1889                  empty                    Purple Wifi        Other
# 3308                  empty  Karma Group Website Concierge        Other
# 3756  Karma Royal Candidasa                      Viewpoint        empty
#
#       Lead Status Email Opt Out Opt In GDPR Compliant                  Website
# 571   No Response         false  false          false                    empty
# 1082  No Response         false  false          false                    empty
# 1218        empty         false  false          false                    empty
# 1889        empty         false  false          false                    empty
# 3308     New Lead         false  false          false  https://karmagroup.com/
# 3756        empty         false   true          false                    empty
#
# [6 rows x 33 columns]

# %%
# delete email Karma
count_after_clean_karma = m.delete_karma(zoho_df, 'Email')
# zoho_df.to_excel(r'C:\Users\fajar\Documents\Python\Data\after_clean_OTA.xlsx', index=False)

zoho_df
# Out:
#                      Record Id        Created Time Created Date First Name  \
# 0     zcrm_3584690000000456191 2019-01-09 11:10:49        empty   Kim Guan
# 1     zcrm_3584690000000456198 2019-01-09 11:10:49        empty    Pauline
# 2     zcrm_3584690000000457744 2019-01-09 11:10:59        empty  Tan Cheng
# 3     zcrm_3584690000000458638 2019-01-09 11:11:04        empty    Eilleen
# 4     zcrm_3584690000000459002 2019-01-09 11:11:06        empty       Fong
# ...                        ...                 ...          ...        ...
# 4682  zcrm_3584690000501952879 2024-07-14 16:52:37        empty     Aileen
# 4683  zcrm_3584690000501960205 2024-07-14 19:56:26   2024-07-01     Simeen
# 4684  zcrm_3584690000501977044 2024-07-12 03:12:18        empty     Jolene
# 4685  zcrm_3584690000501997518 2024-07-14 11:29:42        empty   philippe
# 4686  zcrm_3584690000501997940 2024-07-15 12:33:59        empty    Ong Sze
#
#        Last Name                     Email        Phone Mobile   Birthdate  \
# 0            Pua  adelinephua555@gmail.com        empty  empty  1937-09-14
# 1           Shek      admin@surpass.com.sg   6597811782  empty       empty
# 2           Kiat    christan@telair.com.sg   6596601533  empty  1963-11-03
# 3     Keith Luna    ekalfarosale@gmail.com   6598607340  empty  1988-11-07
# 4       Jong Han                     empty  60122987926  empty       empty
# ...          ...                       ...          ...    ...         ...
# 4682        Neoh         aneoh@hotmail.com   6588230189  empty       empty
# 4683       Malik         simeenz@gmail.com        empty  empty       empty
# 4684        Quek     jolenedayle@gmail.com   6596920977  empty       empty
# 4685      magnin   philippe.mr@outlook.com   6580234245  empty       empty
# 4686       Keong       ongsk2626@gmail.com  60123132626  empty       empty
#
#      Year of Birth  ... Lead Sub-Brand  Lead Source   Lead Locations  \
# 0             1937  ...          Other  Past Guests   Karma Jimbaran
# 1            empty  ...          Other  Past Guests   Karma Rottnest
# 2             1963  ...          Other  Past Guests    Karma Bavaria
# 3             1988  ...          Other  Past Guests    Karma Kandara
# 4            empty  ...          Other  Past Guests   Karma Rottnest
# ...            ...  ...            ...          ...              ...
# 4682         empty  ...          Other  Web Enquiry      Karma Bayon
# 4683         empty  ...      Karma Spa  Past Guests    Karma Kandara
# 4684         empty  ...          Other  Web Enquiry    Karma Kandara
# 4685         empty  ...          Other  Web Enquiry  Karma Song Hoai
# 4686         empty  ...          Other  Past Guests   Karma Jimbaran
#
#                                 Lead Source Description Lead Regions  \
# 0                                                 empty        Other
# 1                                                 empty        Other
# 2                                                 empty        Other
# 3                                                 empty        Other
# 4                                                 empty        Other
# ...                                                 ...          ...
# 4682                          Timeshare Booking Request        Other
# 4683                                              empty        empty
# 4684  Karma Kandara -Download Wedding Brochure at Ka...        Other
# 4685                                    Form Contact Us        Other
# 4686                                          Viewpoint        empty
#
#       Lead Status Email Opt Out Opt In GDPR Compliant  \
# 0        New Lead          true  false          false
# 1        New Lead          true  false          false
# 2     No Response          true  false          false
# 3     No Response          true  false          false
# 4        New Lead          true  false          false
# ...           ...           ...    ...            ...
# 4682        empty         false   true           true
# 4683     New Lead         false  false          false
# 4684        empty         false   true          false
# 4685        empty         false   true          false
# 4686        empty         false   true          false
#
#                                                 Website
# 0                                                 empty
# 1                                                 empty
# 2                                                 empty
# 3                                                 empty
# 4                                                 empty
# ...                                                 ...
# 4682  https://karmagroup.com/find-destination/karma-...
# 4683                                              empty
# 4684  https://karmagroup.com/weddings-at-karma-kanda...
# 4685                 https://karmagroup.com/contact-us/
# 4686                                              empty
#
# [4687 rows x 33 columns]

# %%
find_member_booking = zoho_df.copy()

find_member_booking.loc[find_member_booking['Phone'].isin(df_booking['Phone1']), 'Same Value Find'] = 'Booking-Phone1'
find_member_booking.loc[find_member_booking['Phone'].isin(df_booking['Mobile']), 'Same Value Find'] = 'Booking-Mobile'
find_member_booking.loc[find_member_booking['Mobile'].isin(df_booking['Phone1']), 'Same Value Find'] = 'Booking-Phone1' 
find_member_booking.loc[find_member_booking['Mobile'].isin(df_booking['Mobile']), 'Same Value Find'] = 'Booking-Mobile'
find_member_booking.loc[find_member_booking['Email'].isin(df_booking['Email']), 'Same Value Find'] = 'Booking-Email'

find_member_booking.loc[find_member_booking['Phone'].isin(df_phone['Mobile']), 'Same Value Find'] = 'Member-Mobile' 
find_member_booking.loc[find_member_booking['Mobile'].isin(df_phone['Mobile']), 'Same Value Find'] = 'Member-Mobile'

find_member_booking.loc[find_member_booking['Email'].isin(df_email['Email']), 'Same Value Find'] = 'Member-Email'

find_member_booking.drop(find_member_booking.loc[find_member_booking['Same Value Find'].isna()].index, inplace=True)

count_booking_dedup = find_member_booking.loc[find_member_booking['Same Value Find'].str.contains('Booking', flags=re.I, regex=True)].shape[0]
count_member_dedup = find_member_booking.loc[find_member_booking['Same Value Find'].str.contains('Member', flags=re.I, regex=True)].shape[0]

find_member_booking.replace('empty', '', inplace=True)
# find_member_booking.to_csv(r'C:\Users\fajar\Documents\Python\Data\booking-member-dedup.csv', index=False)
# find_member_booking.to_excel(r'C:\Users\fajar\Documents\Python\Data\booking-member-dedup.xlsx', index=False)

#find_member_booking.loc[find_member_booking['Same Value Find'] == 'Booking-Phone1']

# %%
# data phone, mobile dam email member yang ada di master data 
count_wash_member = zoho_df.loc[
    zoho_df['Phone'].isin(df_booking['Phone1']) | 
    zoho_df['Phone'].isin(df_booking['Mobile']) |
    zoho_df['Mobile'].isin(df_booking['Phone1']) | 
    zoho_df['Mobile'].isin(df_booking['Mobile']) |
    zoho_df['Email'].isin(df_booking['Email'])| 

    zoho_df['Phone'].isin(df_phone['Mobile']) | 
    zoho_df['Mobile'].isin(df_phone['Mobile']) |

    zoho_df['Email'].isin(df_email['Email'])

].shape[0]

zoho_df.drop(zoho_df.loc[
    zoho_df['Phone'].isin(df_booking['Phone1']) | 
    zoho_df['Phone'].isin(df_booking['Mobile']) |
    zoho_df['Mobile'].isin(df_booking['Phone1']) | 
    zoho_df['Mobile'].isin(df_booking['Mobile']) |
    zoho_df['Email'].isin(df_booking['Email']) |
    
    zoho_df['Phone'].isin(df_phone['Mobile']) | 
    zoho_df['Mobile'].isin(df_phone['Mobile']) |

    zoho_df['Email'].isin(df_email['Email'])

    ].index, inplace=True)
    
zoho_df.reset_index(drop=True, inplace=True)

count_after_wash_member = zoho_df.shape[0]

# %%
# Categorize contacts
m.categorize_contacts(zoho_df)

# Count contact types
count_email_only = (zoho_df['Contact Type'] == 'Email Only').sum()
count_phone_only = (zoho_df['Contact Type'] == 'Phone Only').sum()
count_email_and_phone = (zoho_df['Contact Type'] == 'Email and Phone').sum()
count_blank = (zoho_df['Contact Type'] == 'Blank').sum()

# Remove blank contacts if needed
zoho_df = zoho_df[zoho_df['Contact Type'] != 'Blank']
zoho_df.reset_index(drop=True, inplace=True)

count_after_wash_blank = zoho_df.shape[0]

# %%
arr_dedup = [count_deleted_wrong_format, count_duplicate_general, count_leads_test, count_email_OTA, count_email_karma, count_blank]
count_sum_dedup = sum(arr_dedup)
count_sum_dedup
# Out:
# 134

# %%
print("==========================================================")
print("Summary")
print("==========================================================")
print("Jumlah Keseluruhan Master Zoho : "+str(count_data_awal))
print("Jumlah Filter Leads Awal : "+str(count_filter_awal))
print("Jumlah Format Email Salah : "+str(count_deleted_wrong_format))
print("Jumlah Setelah Clean Format Email Salah : "+str(count_after_deleted_wrong_format))
print("Jumlah Duplicate (Phone, Mobile dan Email) : "+str(count_duplicate_general))
print("Jumlah Setelah Clean Duplicate : "+str(count_after_dedup_duplicate))
print("Jumlah Lead Test : "+str(count_leads_test))
print("Jumlah Setelah Clean Lead Test : "+str(count_after_dedup_test))
# print("Jumlah Lead Do Not Mail : "+str(count_dnm))
# print("Jumlah Setelah Clean Lead Do Not Mail : "+str(count_after_dedup_dnm))
print("Jumlah Email OTA : "+str(count_email_OTA))
print("Jumlah Setelah Clean Email OTA : "+str(count_after_clean_OTA))
print("Jumlah Email Karma : "+str(count_email_karma))
print("Jumlah Setelah Clean Email Karma : "+str(count_after_clean_karma))
print("Jumlah Wash Member : "+str(count_member_dedup))
print("Jumlah Wash Booking : "+str(count_booking_dedup))
print("Jumlah Setelah Wash Member : "+str(count_after_wash_member))
print("Jumlah Phone Email Blank (Setelah phone yang tidak valid dihapus) : "+str(count_blank))
print("Jumlah Setelah Wash Phone Email Blank : "+str(count_after_wash_blank))
print("==========================================================")
print("Contact Type")
print("==========================================================")
print("Jumlah Email Only : "+str(count_email_only))
print("Jumlah Phone Only : "+str(count_phone_only))
print("Jumlah Email dan Phone : "+str(count_email_and_phone))
# Out:
# ==========================================================
# Summary
# ==========================================================
# Jumlah Keseluruhan Master Zoho : 456203
# Jumlah Filter Leads Awal : 4821
# Jumlah Format Email Salah : 0
# Jumlah Setelah Clean Format Email Salah : 4821
# Jumlah Duplicate (Phone, Mobile dan Email) : 119
# Jumlah Setelah Clean Duplicate : 4702
# Jumlah Lead Test : 0
# Jumlah Setelah Clean Lead Test : 4702
# Jumlah Email OTA : 9
# Jumlah Setelah Clean Email OTA : 4693
# Jumlah Email Karma : 6
# Jumlah Setelah Clean Email Karma : 4687
# Jumlah Wash Member : 187
# Jumlah Wash Booking : 19
# Jumlah Setelah Wash Member : 4481
# Jumlah Phone Email Blank (Setelah phone yang tidak valid dihapus) : 0
# Jumlah Setelah Wash Phone Email Blank : 4481
# ==========================================================
# Contact Type
# ==========================================================
# Jumlah Email Only : 880
# Jumlah Phone Only : 583
# Jumlah Email dan Phone : 3018

# %%
print("==========================================================")
print("Summary Report")
print("==========================================================")
print("Jumlah Data Awal : "+str(count_filter_awal))
print("Jumlah Wash Dedup : "+str(count_sum_dedup))
print("Jumlah Wash Member : "+str(count_member_dedup))
print("Jumlah Wash Booking : "+str(count_booking_dedup))
print("Jumlah Data Akhir : "+str(count_after_wash_blank))
# Out:
# ==========================================================
# Summary Report
# ==========================================================
# Jumlah Data Awal : 4821
# Jumlah Wash Dedup : 134
# Jumlah Wash Member : 187
# Jumlah Wash Booking : 19
# Jumlah Data Akhir : 4481

# %% [markdown]
# # ====================== Akhir Filter Umum ======================

# %%
zoho_df.replace('empty', '', inplace=True, regex=True)

zoho_df['First Name'] = zoho_df['First Name'].str.title()
zoho_df['Last Name'] = zoho_df['Last Name'].str.title()

zoho_df.to_excel(r'C:\Users\fajar\Documents\Python\Data\data_req_new.xlsx', index=False)

# %%
zoho_df.groupby('Country').count()
# Out:
#                       Record Id  Created Time  Created Date  First Name  \
# Country
# Australia                     5             5             5           5
# China                         3             3             3           3
# France                        1             1             1           1
# Germany                       4             4             4           4
# Indonesia                     8             8             8           8
# Malaysia                    898           898           898         898
# New Zealand                   1             1             1           1
# SIngapore                     1             1             1           1
# Singapore                  3548          3548          3548        3548
# South Korea                   2             2             2           2
# United Arab Emirates          1             1             1           1
# United Kingdom                3             3             3           3
# United States                 1             1             1           1
# empty                         2             2             2           2
# singapore                     3             3             3           3
#
#                       Last Name  Email  Phone  Mobile  Birthdate  \
# Country
# Australia                     5      5      5       5          5
# China                         3      3      3       3          3
# France                        1      1      1       1          1
# Germany                       4      4      4       4          4
# Indonesia                     8      8      8       8          8
# Malaysia                    898    898    898     898        898
# New Zealand                   1      1      1       1          1
# SIngapore                     1      1      1       1          1
# Singapore                  3548   3548   3548    3548       3548
# South Korea                   2      2      2       2          2
# United Arab Emirates          1      1      1       1          1
# United Kingdom                3      3      3       3          3
# United States                 1      1      1       1          1
# empty                         2      2      2       2          2
# singapore                     3      3      3       3          3
#
#                       Year of Birth  ...  Lead Source  Lead Locations  \
# Country                              ...
# Australia                         5  ...            5               5
# China                             3  ...            3               3
# France                            1  ...            1               1
# Germany                           4  ...            4               4
# Indonesia                         8  ...            8               8
# Malaysia                        898  ...          898             898
# New Zealand                       1  ...            1               1
# SIngapore                         1  ...            1               1
# Singapore                      3548  ...         3548            3548
# South Korea                       2  ...            2               2
# United Arab Emirates              1  ...            1               1
# United Kingdom                    3  ...            3               3
# United States                     1  ...            1               1
# empty                             2  ...            2               2
# singapore                         3  ...            3               3
#
#                       Lead Source Description  Lead Regions  Lead Status  \
# Country
# Australia                                   5             5            5
# China                                       3             3            3
# France                                      1             1            1
# Germany                                     4             4            4
# Indonesia                                   8             8            8
# Malaysia                                  898           898          898
# New Zealand                                 1             1            1
# SIngapore                                   1             1            1
# Singapore                                3548          3548         3548
# South Korea                                 2             2            2
# United Arab Emirates                        1             1            1
# United Kingdom                              3             3            3
# United States                               1             1            1
# empty                                       2             2            2
# singapore                                   3             3            3
#
#                       Email Opt Out  Opt In  GDPR Compliant  Website  \
# Country
# Australia                         5       5               5        5
# China                             3       3               3        3
# France                            1       1               1        1
# Germany                           4       4               4        4
# Indonesia                         8       8               8        8
# Malaysia                        898     898             898      898
# New Zealand                       1       1               1        1
# SIngapore                         1       1               1        1
# Singapore                      3548    3548            3548     3548
# South Korea                       2       2               2        2
# United Arab Emirates              1       1               1        1
# United Kingdom                    3       3               3        3
# United States                     1       1               1        1
# empty                             2       2               2        2
# singapore                         3       3               3        3
#
#                       Contact Type
# Country
# Australia                        5
# China                            3
# France                           1
# Germany                          4
# Indonesia                        8
# Malaysia                       898
# New Zealand                      1
# SIngapore                        1
# Singapore                     3548
# South Korea                      2
# United Arab Emirates             1
# United Kingdom                   3
# United States                    1
# empty                            2
# singapore                        3
#
# [15 rows x 33 columns]

# %%
# zoho_df['Country'].loc[
#     (zoho_df['Phone'].str.contains('^44|^\+44')) & 
#     (~zoho_df['Country'].str.contains('united kingdom|wales|england|scotland|northern ireland', regex=True, flags=re.I))
# ]
