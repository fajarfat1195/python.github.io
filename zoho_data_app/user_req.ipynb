# %%
import main_module as m
import zoho_filter_module as fil
import pandas as pd
import re
import numpy as np

# %load_ext autoreload
# %autoreload 2

dir_path = r'C:\Users\fajar\Documents\Python\Data\Zoho_Backup'
file_name = '\Leads_'

cols = ['Record Id',	
'Created Time',
'Created Date',	
'First Name',	
'Last Name',	
'Email',	
'Phone',	
'Mobile',	
'Birthdate',	
'Year of Birth',
'Street',	
'Street2',	
'City',	
'State',	
'Country',	
'Nationality',
'Booking Status', 
'BookRef',
'Departure Date',	
'Arrival Date',	
'Card Type',	
'Marital Status',	
'Lead Brand',	
'Lead Sub-Brand',	
'Lead Source',	
'Lead Locations',	
'Lead Source Description',	
'Lead Regions',
'Lead Status',
'Email Opt Out',	
'Opt In',
'GDPR Compliant',
'Website']
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# <>:11: SyntaxWarning: invalid escape sequence '\L'
# <>:11: SyntaxWarning: invalid escape sequence '\L'
# C:\Users\fajar\AppData\Local\Temp\ipykernel_11708\3222793355.py:11: SyntaxWarning: invalid escape sequence '\L'
#   file_name = '\Leads_'

# %%
df = m.load_data_multiple(dir_path, file_name, cols)
count_data_awal = df.shape[0]
df = df.reindex(columns=cols)
df.shape[0]

df['Created Time'] = pd.to_datetime(df['Created Time'], format='%Y-%m-%d %H:%M:%S')
df['Arrival Date'] = pd.to_datetime(df['Arrival Date'], format='%Y-%m-%d')
df['Departure Date'] = pd.to_datetime(df['Departure Date'], format='%Y-%m-%d')
# fungsi errors cource untuk menhindari error jika value data date null atau kosong
# df['Birthdate'] = pd.to_datetime(df['Birthdate'], format='%Y-%m-%d', errors='coerce')
df.dtypes
df
# Out:
#                        Record Id        Created Time Created Date First Name  \
# 0       zcrm_3584690000000404602 2019-01-08 11:07:28   2021-07-21   Frederic
# 1       zcrm_3584690000000450071 2019-01-08 16:38:18         <NA>  Sebastian
# 2       zcrm_3584690000000450087 2019-01-08 16:38:18         <NA>    Siobhan
# 3       zcrm_3584690000000450106 2019-01-08 16:38:18         <NA>       Lisa
# 4       zcrm_3584690000000450109 2019-01-08 16:38:18         <NA>  Ana Maria
# ...                          ...                 ...          ...        ...
# 493244  zcrm_3584690000521016067 2025-01-13 18:12:02         <NA>       Toni
# 493245  zcrm_3584690000521016109 2025-01-13 18:29:28         <NA>     neeraj
# 493246  zcrm_3584690000521017001 2025-01-13 17:23:30   2025-01-13       ~ayu
# 493247  zcrm_3584690000521017040 2025-01-13 17:26:16   2025-01-13       Jack
# 493248  zcrm_3584690000521019001 2025-01-13 17:25:45   2025-01-13     ~Robin
#
#         Last Name                        Email             Phone Mobile  \
# 0           Bonin    fredericbonin79@gmail.com    +6281236100502   <NA>
# 1            Rach                         <NA>     +498914342111   <NA>
# 2       Gallagher  gallaghersiobhan@eircom.net      353879597603   <NA>
# 3       Ferkovich         lisajo2009@yahoo.com       14062394749   <NA>
# 4        Weileder     m.weileder@sonnenlink.de       15253234700   <NA>
# ...           ...                          ...               ...    ...
# 493244      Truda         toni.truda@gmail.com      +61420361072   <NA>
# 493245     prasad           gomtipus@gmail.com     +919889192155   <NA>
# 493246  suwidiani                         <NA>  +62821-4552-2338   <NA>
# 493247     Davies                         <NA>  +1(207) 653-9484   <NA>
# 493248     Bugeja                         <NA>     +9733967 1748   <NA>
#
#          Birthdate Year of Birth  ... Lead Sub-Brand       Lead Source  \
# 0       1981-10-03          1981  ...          Other            Agency
# 1       1982-04-20          1982  ...          Other       Past Guests
# 2       1973-03-14          1973  ...          Other       Past Guests
# 3       1963-07-08          1963  ...          Other       Past Guests
# 4             <NA>          <NA>  ...          Other             Other
# ...            ...           ...  ...            ...               ...
# 493244        <NA>          <NA>  ...          Other       Web Enquiry
# 493245        <NA>          <NA>  ...          Other       Web Enquiry
# 493246        <NA>          <NA>  ...          Other  WhatsApp Enquiry
# 493247        <NA>          <NA>  ...          Other  WhatsApp Enquiry
# 493248        <NA>          <NA>  ...          Other  WhatsApp Enquiry
#
#            Lead Locations                Lead Source Description Lead Regions  \
# 0           Karma Kandara                                  KAREN         SEAP
# 1           Karma Bavaria                                   <NA>    UK/Europe
# 2           Karma Bavaria                                   <NA>    UK/Europe
# 3           Karma Bavaria                                   <NA>    UK/Europe
# 4           Karma Bavaria        MICE Contacts from Ioanna email    UK/Europe
# ...                   ...                                    ...          ...
# 493244      Karma Kandara              Timeshare Booking Request         SEAP
# 493245  Karma Golden Camp              Timeshare Booking Request        India
# 493246      Karma Kandara  Karma Reservations - WhatsApp Channel         <NA>
# 493247      Karma Kandara  Karma Reservations - WhatsApp Channel         <NA>
# 493248      Karma Kandara  Karma Reservations - WhatsApp Channel         <NA>
#
#        Lead Status Email Opt Out Opt In GDPR Compliant  \
# 0         New Lead         false  false          false
# 1         New Lead          true  false          false
# 2         New Lead         false   true           true
# 3         New Lead          true  false          false
# 4         New Lead         false   true           true
# ...            ...           ...    ...            ...
# 493244        <NA>         false   true           true
# 493245        <NA>         false   true           true
# 493246    New Lead         false  false          false
# 493247    New Lead         false  false          false
# 493248    New Lead         false  false          false
#
#                                                   Website
# 0                                                    <NA>
# 1                                                    <NA>
# 2                                                    <NA>
# 3                                                    <NA>
# 4                                                    <NA>
# ...                                                   ...
# 493244  https://karmagroup.com/find-destination/karma-...
# 493245  https://karmagroup.com/find-destination/karma-...
# 493246                                               <NA>
# 493247                                               <NA>
# 493248                                               <NA>
#
# [493249 rows x 33 columns]

# %%
df.loc[df['Phone'].str.contains('^\\+62', regex=True)]
# Out:
#                        Record Id        Created Time Created Date  \
# 0       zcrm_3584690000000404602 2019-01-08 11:07:28   2021-07-21
# 10      zcrm_3584690000000450191 2019-01-08 16:38:18   2021-07-21
# 12      zcrm_3584690000000450226 2019-01-08 16:38:18   2021-07-21
# 33      zcrm_3584690000000456097 2019-01-09 11:10:49   2021-07-21
# 86      zcrm_3584690000000456162 2019-01-09 11:10:49   2021-07-21
# ...                          ...                 ...          ...
# 493110  zcrm_3584690000520951712 2025-01-13 12:07:53         <NA>
# 493117  zcrm_3584690000520953129 2025-01-13 11:29:15         <NA>
# 493194  zcrm_3584690000520970109 2025-01-13 11:56:46         <NA>
# 493210  zcrm_3584690000520970640 2025-01-13 12:04:11         <NA>
# 493246  zcrm_3584690000521017001 2025-01-13 17:23:30   2025-01-13
#
#            First Name   Last Name                         Email  \
# 0            Frederic       Bonin     fredericbonin79@gmail.com
# 10      Ni Made Novia    Andryani          novia_made@yahoo.com
# 12        Maureellins     Joewyns  maureellinsjoewyns@gmail.com
# 33                 Di       Zhang              156864136@qq.com
# 86         Ganef Hari  Sulistiono         abahdendy99@gmail.com
# ...               ...         ...                           ...
# 493110         Vaneza   Gabriella     gabriellavaneza@gmail.com
# 493117      Anastasia    Mironova           afleytukh@gmail.com
# 493194        Tatiana    Makarova          advertwave@yandex.ru
# 493210        Chinbat  Enkhjargal         chinbat6655@gmail.com
# 493246           ~ayu   suwidiani                          <NA>
#
#                    Phone Mobile   Birthdate Year of Birth  ... Lead Sub-Brand  \
# 0         +6281236100502   <NA>  1981-10-03          1981  ...          Other
# 10        +6281511634635   <NA>  1980-11-10          1980  ...          Other
# 12        +6282221100639   <NA>  2000-04-14          2000  ...          Other
# 33      +628618339280777   <NA>        <NA>          <NA>  ...          Other
# 86         +628123255435   <NA>  1963-12-16          1963  ...          Other
# ...                  ...    ...         ...           ...  ...            ...
# 493110     +628112400150   <NA>        <NA>          <NA>  ...          Other
# 493117    +6285190229029   <NA>        <NA>          <NA>  ...    Karma Beach
# 493194    +6285190229027   <NA>        <NA>          <NA>  ...    Karma Beach
# 493210    +6282119439966   <NA>        <NA>          <NA>  ...          Other
# 493246  +62821-4552-2338   <NA>        <NA>          <NA>  ...          Other
#
#                  Lead Source  Lead Locations  \
# 0                     Agency   Karma Kandara
# 10                    Agency   Karma Kandara
# 12                    Agency   Karma Kandara
# 33                    Agency   Karma Kandara
# 86                    Agency   Karma Kandara
# ...                      ...             ...
# 493110           Past Guests  Karma Jimbaran
# 493117  Karma Beach VIP 2023            <NA>
# 493194  Karma Beach VIP 2023            <NA>
# 493210           Past Guests  Karma Jimbaran
# 493246      WhatsApp Enquiry   Karma Kandara
#
#                         Lead Source Description Lead Regions Lead Status  \
# 0                                         KAREN         SEAP    New Lead
# 10                                        KAREN         SEAP    New Lead
# 12                                        KAREN         SEAP    New Lead
# 33                                        KAREN         SEAP    New Lead
# 86                                        KAREN         SEAP    New Lead
# ...                                         ...          ...         ...
# 493110                                Viewpoint         <NA>        <NA>
# 493117  Karma Beach VIP membership sign up 2023         SEAP        <NA>
# 493194  Karma Beach VIP membership sign up 2023         SEAP        <NA>
# 493210                                Viewpoint         <NA>        <NA>
# 493246    Karma Reservations - WhatsApp Channel         <NA>    New Lead
#
#        Email Opt Out Opt In GDPR Compliant  \
# 0              false  false          false
# 10             false  false          false
# 12             false  false          false
# 33             false  false          false
# 86             false  false          false
# ...              ...    ...            ...
# 493110         false   true          false
# 493117         false   true          false
# 493194         false   true          false
# 493210         false   true          false
# 493246         false  false          false
#
#                                         Website
# 0                                          <NA>
# 10                                         <NA>
# 12                                         <NA>
# 33                                         <NA>
# 86                                         <NA>
# ...                                         ...
# 493110                                     <NA>
# 493117  https://karmagroup.com/karma-beach-vip/
# 493194  https://karmagroup.com/karma-beach-vip/
# 493210                                     <NA>
# 493246                                     <NA>
#
# [35239 rows x 33 columns]

# %%
path = r'G:\.shortcut-targets-by-id\0B_d3smBjzo04eXpvS1NXTWF2RVE\_BOOKING\Booking By Year\FlyBuy Booking Data (BGAU & BGID & KE).xlsx'
df_booking = pd.read_excel(path, dtype='string', sheet_name='BOOKING_BGAU_BGID_KE')

path = r'G:\.shortcut-targets-by-id\0B_d3smBjzo04UUNBME5GOVhoMjA\_ODYSSEY\Phone Members.xlsx'
df_phone = pd.read_excel(path, dtype='string', sheet_name='Sheet1')

path = r'G:\.shortcut-targets-by-id\0B_d3smBjzo04UUNBME5GOVhoMjA\_ODYSSEY\Email Members.xlsx'
df_email = pd.read_excel(path, dtype='string', sheet_name='Sheet1')

# %%
zoho_filter = fil.user_req(df)
zoho_df = df.loc[zoho_filter].copy() # menggunakan copy untuk menghindari setting copy warning
zoho_df.reset_index(drop=True, inplace=True)
count_filter_awal = zoho_df.shape[0]

# zoho_df.to_excel(r'C:\Users\fajar\Documents\Python\Data\test_leads.xlsx', index=False)
# mengisi kolom <NA> dengan value string 'empty' supaya mudah mengecek data member dan booking dengan isin

zoho_df.fillna('empty', inplace=True)
zoho_df.sort_values('Created Time', ascending=True)
# Out:
# Empty DataFrame
# Columns: [Record Id, Created Time, Created Date, First Name, Last Name, Email, Phone, Mobile, Birthdate, Year of Birth, Street, Street2, City, State, Country, Nationality, Booking Status, BookRef, Departure Date, Arrival Date, Card Type, Marital Status, Lead Brand, Lead Sub-Brand, Lead Source, Lead Locations, Lead Source Description, Lead Regions, Lead Status, Email Opt Out, Opt In, GDPR Compliant, Website]
# Index: []
#
# [0 rows x 33 columns]

# %%
zoho_df.loc[zoho_df['Lead Source Description'].str.contains('walk', regex=True, flags=re.I)]
# Out:
# Empty DataFrame
# Columns: [Record Id, Created Time, Created Date, First Name, Last Name, Email, Phone, Mobile, Birthdate, Year of Birth, Street, Street2, City, State, Country, Nationality, Booking Status, BookRef, Departure Date, Arrival Date, Card Type, Marital Status, Lead Brand, Lead Sub-Brand, Lead Source, Lead Locations, Lead Source Description, Lead Regions, Lead Status, Email Opt Out, Opt In, GDPR Compliant, Website]
# Index: []
#
# [0 rows x 33 columns]

# %% [markdown]
# # ====================== Awal Filter Umum ======================

# %%
# data phone, mobile dam email member yang ada di master data (wash member)

m.clean_number(zoho_df, 'Phone')
m.clean_number(zoho_df, 'Mobile')
m.replace_not_valid_to_empty(zoho_df, 'Phone')
m.replace_not_valid_to_empty(zoho_df, 'Mobile')
zoho_df['Email'] = m.lowercase(zoho_df, 'Email')
m.clean_space(zoho_df, 'Email')
m.clean_not_valid_email_format(zoho_df, 'Email')

m.clean_number(df_booking, 'Phone1')
m.clean_number(df_booking, 'Mobile')
df_booking['Email'] = m.lowercase(df_booking, 'Email')
m.clean_space(df_booking, 'Email')
m.clean_not_valid_email_format(df_booking, 'Email')

m.clean_number(df_phone, 'Mobile')

df_email['Email'] = m.lowercase(df_email, 'Email')
m.clean_space(df_email, 'Email')
m.clean_not_valid_email_format(df_email, 'Email')
# Out:
# c:\Users\fajar\Documents\Python\Task Offline\zoho_data_app\main_module.py:67: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[df_columns].replace(' ','', regex=True, inplace=True)
# c:\Users\fajar\Documents\Python\Task Offline\zoho_data_app\main_module.py:68: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[df_columns].replace('[^0-9]','', regex=True, inplace=True)
# c:\Users\fajar\Documents\Python\Task Offline\zoho_data_app\main_module.py:90: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[df_columns].replace(' ','', regex=True, inplace=True)
# c:\Users\fajar\Documents\Python\Task Offline\zoho_data_app\main_module.py:67: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[df_columns].replace(' ','', regex=True, inplace=True)
# c:\Users\fajar\Documents\Python\Task Offline\zoho_data_app\main_module.py:68: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[df_columns].replace('[^0-9]','', regex=True, inplace=True)
# 'Email'

# %%
zoho_df.loc[zoho_df['Phone']=='']
# Out:
# Empty DataFrame
# Columns: [Record Id, Created Time, Created Date, First Name, Last Name, Email, Phone, Mobile, Birthdate, Year of Birth, Street, Street2, City, State, Country, Nationality, Booking Status, BookRef, Departure Date, Arrival Date, Card Type, Marital Status, Lead Brand, Lead Sub-Brand, Lead Source, Lead Locations, Lead Source Description, Lead Regions, Lead Status, Email Opt Out, Opt In, GDPR Compliant, Website]
# Index: []
#
# [0 rows x 33 columns]

# %%
count_deleted_wrong_format = m.delete_email_wrong_format(zoho_df, 'Email')
count_after_deleted_wrong_format = zoho_df.shape[0]

# %%
# hitung jumlah duplicate
count_duplicate_general = zoho_df.loc[zoho_df.duplicated(subset=['Phone','Email', 'Mobile'])].shape[0]

zoho_df.loc[zoho_df.duplicated(subset=['Phone','Email', 'Mobile'])]
# Out:
#                      Record Id        Created Time Created Date First Name  \
# 2220  zcrm_3584690000500539043 2024-06-28 08:26:46        empty    Nabilla
# 2449  zcrm_3584690000502684034 2024-07-18 01:56:29        empty     Pietet
# 3194  zcrm_3584690000511575001 2024-10-10 19:06:44        empty        Eva
# 3821  zcrm_3584690000519431068 2024-12-25 14:36:56        empty     Milena
# 3905  zcrm_3584690000519817290 2024-12-30 16:57:35        empty  EKATERINA
# 3906  zcrm_3584690000519817332 2024-12-30 16:58:40        empty  EKATERINA
# 3910  zcrm_3584690000519818247 2024-12-30 16:59:12        empty     Regina
#
#           Last Name                             Email           Phone Mobile  \
# 2220    Choirunissa      choirunnisanabilla@gmail.com   6287773360266  empty
# 2449  Van den hogen        pietervandenhogen@mail.com     31628630420  empty
# 3194        Felisha              evafelisha@gmail.com   6281218544573  empty
# 3821       Lozovych          milenalozovych@gmail.com   6285190175718  empty
# 3905      MEDVEDEVA  medvedeva.ekaterina777@yandex.ru  62813309119950  empty
# 3906      MEDVEDEVA  medvedeva.ekaterina777@yandex.ru  62813309119950  empty
# 3910       Smirnova     regina.smirnova2011@yandex.ru   6281330909887  empty
#
#      Birthdate Year of Birth  ... Lead Sub-Brand           Lead Source  \
# 2220     empty         empty  ...    Karma Beach  Karma Beach VIP 2023
# 2449     empty         empty  ...    Karma Beach  Karma Beach VIP 2023
# 3194     empty         empty  ...    Karma Beach  Karma Beach VIP 2023
# 3821     empty         empty  ...    Karma Beach  Karma Beach VIP 2023
# 3905     empty         empty  ...    Karma Beach  Karma Beach VIP 2023
# 3906     empty         empty  ...    Karma Beach  Karma Beach VIP 2023
# 3910     empty         empty  ...    Karma Beach  Karma Beach VIP 2023
#
#      Lead Locations                  Lead Source Description Lead Regions  \
# 2220          empty  Karma Beach VIP membership sign up 2023         SEAP
# 2449          empty  Karma Beach VIP membership sign up 2023    UK/Europe
# 3194          empty  Karma Beach VIP membership sign up 2023        empty
# 3821          empty  Karma Beach VIP membership sign up 2023         SEAP
# 3905          empty  Karma Beach VIP membership sign up 2023         SEAP
# 3906          empty  Karma Beach VIP membership sign up 2023         SEAP
# 3910          empty  Karma Beach VIP membership sign up 2023         SEAP
#
#      Lead Status Email Opt Out Opt In GDPR Compliant  \
# 2220       empty         false   true          false
# 2449       empty         false   true           true
# 3194       empty         false   true          false
# 3821       empty         false   true          false
# 3905       empty         false   true          false
# 3906       empty         false   true          false
# 3910       empty         false   true          false
#
#                                       Website
# 2220  https://karmagroup.com/karma-beach-vip/
# 2449  https://karmagroup.com/karma-beach-vip/
# 3194  https://karmagroup.com/karma-beach-vip/
# 3821  https://karmagroup.com/karma-beach-vip/
# 3905  https://karmagroup.com/karma-beach-vip/
# 3906  https://karmagroup.com/karma-beach-vip/
# 3910  https://karmagroup.com/karma-beach-vip/
#
# [7 rows x 33 columns]

# %%
zoho_df.drop_duplicates(subset=['Phone','Email', 'Mobile'], inplace=True)
zoho_df.reset_index(drop=True, inplace=True)

# hitung jumlah setelah value duplicate dihapus
count_after_dedup_duplicate = zoho_df.shape[0]

zoho_df
# Out:
#                      Record Id        Created Time Created Date  \
# 0     zcrm_3584690000001379021 2019-02-03 08:42:45   2019-02-03
# 1     zcrm_3584690000002932135 2019-02-28 03:24:54   2022-12-11
# 2     zcrm_3584690000005944396 2019-04-02 02:14:44   2017-03-08
# 3     zcrm_3584690000005945085 2019-04-02 02:14:48   2015-05-12
# 4     zcrm_3584690000005948267 2019-04-02 02:15:06   2017-01-18
# ...                        ...                 ...          ...
# 4046  zcrm_3584690000520945043 2025-01-12 18:26:29        empty
# 4047  zcrm_3584690000520945346 2025-01-13 07:34:25        empty
# 4048  zcrm_3584690000520953129 2025-01-13 11:29:15        empty
# 4049  zcrm_3584690000520970109 2025-01-13 11:56:46        empty
# 4050  zcrm_3584690000521012156 2025-01-13 15:55:03        empty
#
#          First Name   Last Name                       Email          Phone  \
# 0              Keli      Parkes          keli@keliaroha.com    61413422227
# 1     Almas Hussain       Rizvi           almas_h@yahoo.com   919886790473
# 2             Caryl    Costello  carylcostello@yahoo.com.au    61417074510
# 3              Dawn       Poole    chrisdawnpoole@gmail.com    61417854221
# 4            Elycia     Martins    elycia.martins@gmail.com    61403924069
# ...             ...         ...                         ...            ...
# 4046         Robert     Bertone  robert.bertone@hotmail.com    61403497091
# 4047          Utami  Rohmayanti        utamiraden@gmail.com  6281212162940
# 4048      Anastasia    Mironova         afleytukh@gmail.com  6285190229029
# 4049        Tatiana    Makarova        advertwave@yandex.ru  6285190229027
# 4050            Sue       Parle         suemparle@gmail.com    64211658694
#
#            Mobile   Birthdate Year of Birth  ... Lead Sub-Brand  \
# 0     61413422227  1976-05-14          1976  ...          Other
# 1           empty       empty         empty  ...          Other
# 2           empty  1940-01-01          1940  ...          Other
# 3           empty       empty         empty  ...          Other
# 4           empty       empty         empty  ...          Other
# ...           ...         ...           ...  ...            ...
# 4046        empty       empty         empty  ...    Karma Beach
# 4047        empty       empty         empty  ...    Karma Beach
# 4048        empty       empty         empty  ...    Karma Beach
# 4049        empty       empty         empty  ...    Karma Beach
# 4050        empty       empty         empty  ...    Karma Beach
#
#                Lead Source  Lead Locations  \
# 0              Web Enquiry           empty
# 1             Facebook Ads         General
# 2              Past Guests  Karma Jimbaran
# 3              Past Guests   Karma Bavaria
# 4              Past Guests  Karma Rottnest
# ...                    ...             ...
# 4046  Karma Beach VIP 2023           empty
# 4047  Karma Beach VIP 2023           empty
# 4048  Karma Beach VIP 2023           empty
# 4049  Karma Beach VIP 2023           empty
# 4050  Karma Beach VIP 2023           empty
#
#                       Lead Source Description Lead Regions Lead Status  \
# 0     Karma Beach VIP membership sign up 2023         SEAP    New Lead
# 1     Karma Beach VIP membership sign up 2023        India    New Lead
# 2     Karma Beach VIP membership sign up 2023         SEAP    Not Sold
# 3     Karma Beach VIP membership sign up 2023         SEAP       empty
# 4     Karma Beach VIP membership sign up 2023         SEAP       empty
# ...                                       ...          ...         ...
# 4046  Karma Beach VIP membership sign up 2023         SEAP       empty
# 4047  Karma Beach VIP membership sign up 2023         SEAP       empty
# 4048  Karma Beach VIP membership sign up 2023         SEAP       empty
# 4049  Karma Beach VIP membership sign up 2023         SEAP       empty
# 4050  Karma Beach VIP membership sign up 2023         SEAP       empty
#
#      Email Opt Out Opt In GDPR Compliant  \
# 0            false   true           true
# 1            false   true           true
# 2            false   true           true
# 3            false   true           true
# 4            false   true           true
# ...            ...    ...            ...
# 4046         false   true          false
# 4047         false   true          false
# 4048         false   true          false
# 4049         false   true          false
# 4050         false   true          false
#
#                                       Website
# 0     https://karmagroup.com/karma-beach-vip/
# 1     https://karmagroup.com/karma-beach-vip/
# 2     https://karmagroup.com/karma-beach-vip/
# 3     https://karmagroup.com/karma-beach-vip/
# 4     https://karmagroup.com/karma-beach-vip/
# ...                                       ...
# 4046  https://karmagroup.com/karma-beach-vip/
# 4047  https://karmagroup.com/karma-beach-vip/
# 4048  https://karmagroup.com/karma-beach-vip/
# 4049  https://karmagroup.com/karma-beach-vip/
# 4050  https://karmagroup.com/karma-beach-vip/
#
# [4051 rows x 33 columns]

# %%
# Cek leads test
test_leads = zoho_df.loc[
    
        zoho_df['Email'].str.contains('^test@', flags=re.I, regex=True) |
        zoho_df['Email'].str.contains('\+test', flags=re.I, regex=True) |
    
        zoho_df['First Name'].str.contains('^test$', flags=re.I, regex=True) |
        zoho_df['Last Name'].str.contains('^test$', flags=re.I, regex=True) |

        zoho_df['First Name'].str.contains('test 1', flags=re.I, regex=True) |
        zoho_df['Last Name'].str.contains('test 2', flags=re.I, regex=True)|
        zoho_df['First Name'].str.contains('test1', flags=re.I, regex=True) |
        zoho_df['Last Name'].str.contains('test2', flags=re.I, regex=True)|

        zoho_df['First Name'].str.contains(' test ', flags=re.I, regex=True) | 
        zoho_df['Last Name'].str.contains(' test ', flags=re.I, regex=True) | 
        zoho_df['Last Name'].str.contains(' test$', flags=re.I, regex=True)
    ]

count_leads_test = test_leads.shape[0]

# test_leads.to_excel(r'C:\Users\fajar\Documents\Python\Data\test_leads_2.xlsx', index=False)
test_leads
# Out:
# <>:5: SyntaxWarning: invalid escape sequence '\+'
# <>:5: SyntaxWarning: invalid escape sequence '\+'
# C:\Users\fajar\AppData\Local\Temp\ipykernel_11708\907236175.py:5: SyntaxWarning: invalid escape sequence '\+'
#   zoho_df['Email'].str.contains('\+test', flags=re.I, regex=True) |
# Empty DataFrame
# Columns: [Record Id, Created Time, Created Date, First Name, Last Name, Email, Phone, Mobile, Birthdate, Year of Birth, Street, Street2, City, State, Country, Nationality, Booking Status, BookRef, Departure Date, Arrival Date, Card Type, Marital Status, Lead Brand, Lead Sub-Brand, Lead Source, Lead Locations, Lead Source Description, Lead Regions, Lead Status, Email Opt Out, Opt In, GDPR Compliant, Website]
# Index: []
#
# [0 rows x 33 columns]

# %%
zoho_df.drop(test_leads.index, inplace=True)
zoho_df.reset_index(drop=True, inplace=True)

count_after_dedup_test = zoho_df.shape[0]

# %%
# dnm_leads = zoho_df.loc[(zoho_df['Do Not Mail'] == 'true') | (zoho_df['Do Not Contact'] == 'true')]
# count_dnm = dnm_leads.shape[0]

# %%
# zoho_df.drop(dnm_leads.index, inplace=True)
# zoho_df.reset_index(drop=True, inplace=True)

# count_after_dedup_dnm = zoho_df.shape[0]

# %%
# Cek Email OTA
email_OTA = m.find_OTA(zoho_df, 'Email')
count_email_OTA = email_OTA.shape[0]
# email_OTA.to_excel(r'C:\Users\fajar\Documents\Python\Data\email_OTA.xlsx', index=False)

email_OTA
# Out:
#                      Record Id        Created Time Created Date First Name  \
# 1340  zcrm_3584690000491845127 2024-04-14 00:26:53        empty      Ankit
# 1341  zcrm_3584690000491845156 2024-04-14 00:29:07        empty   Priyanka
# 3241  zcrm_3584690000512153086 2024-10-17 13:15:08        empty     Tamara
#
#      Last Name                     Email          Phone Mobile Birthdate  \
# 1340   Agarwal          ankit@yotours.in   917276282020  empty     empty
# 1341    Mangal           info@yotours.in   918451823654  empty     empty
# 3241   Skroman  supermarkettours@mail.ru  6281225297099  empty     empty
#
#      Year of Birth  ... Lead Sub-Brand           Lead Source Lead Locations  \
# 1340         empty  ...    Karma Beach  Karma Beach VIP 2023          empty
# 1341         empty  ...    Karma Beach  Karma Beach VIP 2023          empty
# 3241         empty  ...    Karma Beach  Karma Beach VIP 2023          empty
#
#                       Lead Source Description Lead Regions Lead Status  \
# 1340  Karma Beach VIP membership sign up 2023        India       empty
# 1341  Karma Beach VIP membership sign up 2023        India       empty
# 3241  Karma Beach VIP membership sign up 2023         SEAP       empty
#
#      Email Opt Out Opt In GDPR Compliant  \
# 1340         false   true          false
# 1341         false   true          false
# 3241         false   true          false
#
#                                       Website
# 1340  https://karmagroup.com/karma-beach-vip/
# 1341  https://karmagroup.com/karma-beach-vip/
# 3241  https://karmagroup.com/karma-beach-vip/
#
# [3 rows x 33 columns]

# %%
# delete email OTA
count_after_clean_OTA = m.delete_OTA(zoho_df, 'Email')
# zoho_df.to_excel(r'C:\Users\fajar\Documents\Python\Data\after_clean_OTA.xlsx', index=False)

zoho_df
# Out:
#                      Record Id        Created Time Created Date  \
# 0     zcrm_3584690000001379021 2019-02-03 08:42:45   2019-02-03
# 1     zcrm_3584690000002932135 2019-02-28 03:24:54   2022-12-11
# 2     zcrm_3584690000005944396 2019-04-02 02:14:44   2017-03-08
# 3     zcrm_3584690000005945085 2019-04-02 02:14:48   2015-05-12
# 4     zcrm_3584690000005948267 2019-04-02 02:15:06   2017-01-18
# ...                        ...                 ...          ...
# 4043  zcrm_3584690000520945043 2025-01-12 18:26:29        empty
# 4044  zcrm_3584690000520945346 2025-01-13 07:34:25        empty
# 4045  zcrm_3584690000520953129 2025-01-13 11:29:15        empty
# 4046  zcrm_3584690000520970109 2025-01-13 11:56:46        empty
# 4047  zcrm_3584690000521012156 2025-01-13 15:55:03        empty
#
#          First Name   Last Name                       Email          Phone  \
# 0              Keli      Parkes          keli@keliaroha.com    61413422227
# 1     Almas Hussain       Rizvi           almas_h@yahoo.com   919886790473
# 2             Caryl    Costello  carylcostello@yahoo.com.au    61417074510
# 3              Dawn       Poole    chrisdawnpoole@gmail.com    61417854221
# 4            Elycia     Martins    elycia.martins@gmail.com    61403924069
# ...             ...         ...                         ...            ...
# 4043         Robert     Bertone  robert.bertone@hotmail.com    61403497091
# 4044          Utami  Rohmayanti        utamiraden@gmail.com  6281212162940
# 4045      Anastasia    Mironova         afleytukh@gmail.com  6285190229029
# 4046        Tatiana    Makarova        advertwave@yandex.ru  6285190229027
# 4047            Sue       Parle         suemparle@gmail.com    64211658694
#
#            Mobile   Birthdate Year of Birth  ... Lead Sub-Brand  \
# 0     61413422227  1976-05-14          1976  ...          Other
# 1           empty       empty         empty  ...          Other
# 2           empty  1940-01-01          1940  ...          Other
# 3           empty       empty         empty  ...          Other
# 4           empty       empty         empty  ...          Other
# ...           ...         ...           ...  ...            ...
# 4043        empty       empty         empty  ...    Karma Beach
# 4044        empty       empty         empty  ...    Karma Beach
# 4045        empty       empty         empty  ...    Karma Beach
# 4046        empty       empty         empty  ...    Karma Beach
# 4047        empty       empty         empty  ...    Karma Beach
#
#                Lead Source  Lead Locations  \
# 0              Web Enquiry           empty
# 1             Facebook Ads         General
# 2              Past Guests  Karma Jimbaran
# 3              Past Guests   Karma Bavaria
# 4              Past Guests  Karma Rottnest
# ...                    ...             ...
# 4043  Karma Beach VIP 2023           empty
# 4044  Karma Beach VIP 2023           empty
# 4045  Karma Beach VIP 2023           empty
# 4046  Karma Beach VIP 2023           empty
# 4047  Karma Beach VIP 2023           empty
#
#                       Lead Source Description Lead Regions Lead Status  \
# 0     Karma Beach VIP membership sign up 2023         SEAP    New Lead
# 1     Karma Beach VIP membership sign up 2023        India    New Lead
# 2     Karma Beach VIP membership sign up 2023         SEAP    Not Sold
# 3     Karma Beach VIP membership sign up 2023         SEAP       empty
# 4     Karma Beach VIP membership sign up 2023         SEAP       empty
# ...                                       ...          ...         ...
# 4043  Karma Beach VIP membership sign up 2023         SEAP       empty
# 4044  Karma Beach VIP membership sign up 2023         SEAP       empty
# 4045  Karma Beach VIP membership sign up 2023         SEAP       empty
# 4046  Karma Beach VIP membership sign up 2023         SEAP       empty
# 4047  Karma Beach VIP membership sign up 2023         SEAP       empty
#
#      Email Opt Out Opt In GDPR Compliant  \
# 0            false   true           true
# 1            false   true           true
# 2            false   true           true
# 3            false   true           true
# 4            false   true           true
# ...            ...    ...            ...
# 4043         false   true          false
# 4044         false   true          false
# 4045         false   true          false
# 4046         false   true          false
# 4047         false   true          false
#
#                                       Website
# 0     https://karmagroup.com/karma-beach-vip/
# 1     https://karmagroup.com/karma-beach-vip/
# 2     https://karmagroup.com/karma-beach-vip/
# 3     https://karmagroup.com/karma-beach-vip/
# 4     https://karmagroup.com/karma-beach-vip/
# ...                                       ...
# 4043  https://karmagroup.com/karma-beach-vip/
# 4044  https://karmagroup.com/karma-beach-vip/
# 4045  https://karmagroup.com/karma-beach-vip/
# 4046  https://karmagroup.com/karma-beach-vip/
# 4047  https://karmagroup.com/karma-beach-vip/
#
# [4048 rows x 33 columns]

# %%
# Cek Email Karma
email_karma = m.find_karma(zoho_df, 'Email')
count_email_karma = email_karma.shape[0]
# email_OTA.to_excel(r'C:\Users\fajar\Documents\Python\Data\email_OTA.xlsx', index=False)

email_karma
# Out:
#                     Record Id        Created Time Created Date First Name  \
# 138  zcrm_3584690000472907352 2023-12-14 08:24:49        empty      Shaun
# 139  zcrm_3584690000472907381 2023-12-14 09:12:09        empty      James
# 520  zcrm_3584690000476213047 2024-01-10 06:59:19        empty    Michael
#
#      Last Name                             Email          Phone Mobile  \
# 138  Duenhofen  shaun.duenhofen@karmakandara.com  6281138006892  empty
# 139      Casey        james.casey@karmagroup.com   628123601872  empty
# 520       Wood       michael.wood@karmagroup.com   628111111111  empty
#
#     Birthdate Year of Birth  ... Lead Sub-Brand           Lead Source  \
# 138     empty         empty  ...    Karma Beach  Karma Beach VIP 2023
# 139     empty         empty  ...    Karma Beach  Karma Beach VIP 2023
# 520     empty         empty  ...    Karma Beach  Karma Beach VIP 2023
#
#     Lead Locations                  Lead Source Description Lead Regions  \
# 138          empty  Karma Beach VIP membership sign up 2023         SEAP
# 139          empty  Karma Beach VIP membership sign up 2023         SEAP
# 520          empty  Karma Beach VIP membership sign up 2023         SEAP
#
#     Lead Status Email Opt Out Opt In GDPR Compliant  \
# 138       empty         false   true          false
# 139       empty         false   true          false
# 520       empty         false   true          false
#
#                                      Website
# 138  https://karmagroup.com/karma-beach-vip/
# 139  https://karmagroup.com/karma-beach-vip/
# 520  https://karmagroup.com/karma-beach-vip/
#
# [3 rows x 33 columns]

# %%
# delete email Karma
count_after_clean_karma = m.delete_karma(zoho_df, 'Email')
# zoho_df.to_excel(r'C:\Users\fajar\Documents\Python\Data\after_clean_OTA.xlsx', index=False)

zoho_df
# Out:
#                      Record Id        Created Time Created Date  \
# 0     zcrm_3584690000001379021 2019-02-03 08:42:45   2019-02-03
# 1     zcrm_3584690000002932135 2019-02-28 03:24:54   2022-12-11
# 2     zcrm_3584690000005944396 2019-04-02 02:14:44   2017-03-08
# 3     zcrm_3584690000005945085 2019-04-02 02:14:48   2015-05-12
# 4     zcrm_3584690000005948267 2019-04-02 02:15:06   2017-01-18
# ...                        ...                 ...          ...
# 4040  zcrm_3584690000520945043 2025-01-12 18:26:29        empty
# 4041  zcrm_3584690000520945346 2025-01-13 07:34:25        empty
# 4042  zcrm_3584690000520953129 2025-01-13 11:29:15        empty
# 4043  zcrm_3584690000520970109 2025-01-13 11:56:46        empty
# 4044  zcrm_3584690000521012156 2025-01-13 15:55:03        empty
#
#          First Name   Last Name                       Email          Phone  \
# 0              Keli      Parkes          keli@keliaroha.com    61413422227
# 1     Almas Hussain       Rizvi           almas_h@yahoo.com   919886790473
# 2             Caryl    Costello  carylcostello@yahoo.com.au    61417074510
# 3              Dawn       Poole    chrisdawnpoole@gmail.com    61417854221
# 4            Elycia     Martins    elycia.martins@gmail.com    61403924069
# ...             ...         ...                         ...            ...
# 4040         Robert     Bertone  robert.bertone@hotmail.com    61403497091
# 4041          Utami  Rohmayanti        utamiraden@gmail.com  6281212162940
# 4042      Anastasia    Mironova         afleytukh@gmail.com  6285190229029
# 4043        Tatiana    Makarova        advertwave@yandex.ru  6285190229027
# 4044            Sue       Parle         suemparle@gmail.com    64211658694
#
#            Mobile   Birthdate Year of Birth  ... Lead Sub-Brand  \
# 0     61413422227  1976-05-14          1976  ...          Other
# 1           empty       empty         empty  ...          Other
# 2           empty  1940-01-01          1940  ...          Other
# 3           empty       empty         empty  ...          Other
# 4           empty       empty         empty  ...          Other
# ...           ...         ...           ...  ...            ...
# 4040        empty       empty         empty  ...    Karma Beach
# 4041        empty       empty         empty  ...    Karma Beach
# 4042        empty       empty         empty  ...    Karma Beach
# 4043        empty       empty         empty  ...    Karma Beach
# 4044        empty       empty         empty  ...    Karma Beach
#
#                Lead Source  Lead Locations  \
# 0              Web Enquiry           empty
# 1             Facebook Ads         General
# 2              Past Guests  Karma Jimbaran
# 3              Past Guests   Karma Bavaria
# 4              Past Guests  Karma Rottnest
# ...                    ...             ...
# 4040  Karma Beach VIP 2023           empty
# 4041  Karma Beach VIP 2023           empty
# 4042  Karma Beach VIP 2023           empty
# 4043  Karma Beach VIP 2023           empty
# 4044  Karma Beach VIP 2023           empty
#
#                       Lead Source Description Lead Regions Lead Status  \
# 0     Karma Beach VIP membership sign up 2023         SEAP    New Lead
# 1     Karma Beach VIP membership sign up 2023        India    New Lead
# 2     Karma Beach VIP membership sign up 2023         SEAP    Not Sold
# 3     Karma Beach VIP membership sign up 2023         SEAP       empty
# 4     Karma Beach VIP membership sign up 2023         SEAP       empty
# ...                                       ...          ...         ...
# 4040  Karma Beach VIP membership sign up 2023         SEAP       empty
# 4041  Karma Beach VIP membership sign up 2023         SEAP       empty
# 4042  Karma Beach VIP membership sign up 2023         SEAP       empty
# 4043  Karma Beach VIP membership sign up 2023         SEAP       empty
# 4044  Karma Beach VIP membership sign up 2023         SEAP       empty
#
#      Email Opt Out Opt In GDPR Compliant  \
# 0            false   true           true
# 1            false   true           true
# 2            false   true           true
# 3            false   true           true
# 4            false   true           true
# ...            ...    ...            ...
# 4040         false   true          false
# 4041         false   true          false
# 4042         false   true          false
# 4043         false   true          false
# 4044         false   true          false
#
#                                       Website
# 0     https://karmagroup.com/karma-beach-vip/
# 1     https://karmagroup.com/karma-beach-vip/
# 2     https://karmagroup.com/karma-beach-vip/
# 3     https://karmagroup.com/karma-beach-vip/
# 4     https://karmagroup.com/karma-beach-vip/
# ...                                       ...
# 4040  https://karmagroup.com/karma-beach-vip/
# 4041  https://karmagroup.com/karma-beach-vip/
# 4042  https://karmagroup.com/karma-beach-vip/
# 4043  https://karmagroup.com/karma-beach-vip/
# 4044  https://karmagroup.com/karma-beach-vip/
#
# [4045 rows x 33 columns]

# %%
find_member_booking = zoho_df.copy()

find_member_booking.loc[find_member_booking['Phone'].isin(df_booking['Phone1']), 'Same Value Find'] = 'Booking-Phone1'
find_member_booking.loc[find_member_booking['Phone'].isin(df_booking['Mobile']), 'Same Value Find'] = 'Booking-Mobile'
find_member_booking.loc[find_member_booking['Mobile'].isin(df_booking['Phone1']), 'Same Value Find'] = 'Booking-Phone1' 
find_member_booking.loc[find_member_booking['Mobile'].isin(df_booking['Mobile']), 'Same Value Find'] = 'Booking-Mobile'
find_member_booking.loc[find_member_booking['Email'].isin(df_booking['Email']), 'Same Value Find'] = 'Booking-Email'

find_member_booking.loc[find_member_booking['Phone'].isin(df_phone['Mobile']), 'Same Value Find'] = 'Member-Mobile' 
find_member_booking.loc[find_member_booking['Mobile'].isin(df_phone['Mobile']), 'Same Value Find'] = 'Member-Mobile'

find_member_booking.loc[find_member_booking['Email'].isin(df_email['Email']), 'Same Value Find'] = 'Member-Email'

find_member_booking.drop(find_member_booking.loc[find_member_booking['Same Value Find'].isna()].index, inplace=True)

count_booking_dedup = find_member_booking.loc[find_member_booking['Same Value Find'].str.contains('Booking', flags=re.I, regex=True)].shape[0]
count_member_dedup = find_member_booking.loc[find_member_booking['Same Value Find'].str.contains('Member', flags=re.I, regex=True)].shape[0]

find_member_booking.replace('empty', '', inplace=True)
# find_member_booking.to_csv(r'C:\Users\fajar\Documents\Python\Data\booking-member-dedup.csv', index=False)
# find_member_booking.to_excel(r'C:\Users\fajar\Documents\Python\Data\booking-member-dedup.xlsx', index=False)

#find_member_booking.loc[find_member_booking['Same Value Find'] == 'Booking-Phone1']

# %%
# data phone, mobile dam email member yang ada di master data 
count_wash_member = zoho_df.loc[
    zoho_df['Phone'].isin(df_booking['Phone1']) | 
    zoho_df['Phone'].isin(df_booking['Mobile']) |
    zoho_df['Mobile'].isin(df_booking['Phone1']) | 
    zoho_df['Mobile'].isin(df_booking['Mobile']) |
    zoho_df['Email'].isin(df_booking['Email'])| 

    zoho_df['Phone'].isin(df_phone['Mobile']) | 
    zoho_df['Mobile'].isin(df_phone['Mobile']) |

    zoho_df['Email'].isin(df_email['Email'])

].shape[0]

zoho_df.drop(zoho_df.loc[
    zoho_df['Phone'].isin(df_booking['Phone1']) | 
    zoho_df['Phone'].isin(df_booking['Mobile']) |
    zoho_df['Mobile'].isin(df_booking['Phone1']) | 
    zoho_df['Mobile'].isin(df_booking['Mobile']) |
    zoho_df['Email'].isin(df_booking['Email']) |
    
    zoho_df['Phone'].isin(df_phone['Mobile']) | 
    zoho_df['Mobile'].isin(df_phone['Mobile']) |

    zoho_df['Email'].isin(df_email['Email'])

    ].index, inplace=True)
    
zoho_df.reset_index(drop=True, inplace=True)

count_after_wash_member = zoho_df.shape[0]

# %%
# Categorize contacts
m.categorize_contacts(zoho_df)

# Count contact types
count_email_only = (zoho_df['Contact Type'] == 'Email Only').sum()
count_phone_only = (zoho_df['Contact Type'] == 'Phone Only').sum()
count_email_and_phone = (zoho_df['Contact Type'] == 'Email and Phone').sum()
count_blank = (zoho_df['Contact Type'] == 'Blank').sum()

# Remove blank contacts if needed
zoho_df = zoho_df[zoho_df['Contact Type'] != 'Blank']
zoho_df.reset_index(drop=True, inplace=True)

count_after_wash_blank = zoho_df.shape[0]

# %%
arr_dedup = [count_deleted_wrong_format, count_duplicate_general, count_leads_test, count_email_OTA, count_email_karma, count_blank]
count_sum_dedup = sum(arr_dedup)
count_sum_dedup
# Out:
# np.int64(13)

# %%
print("==========================================================")
print("Summary")
print("==========================================================")
print("Jumlah Keseluruhan Master Zoho : "+str(count_data_awal))
print("Jumlah Filter Leads Awal : "+str(count_filter_awal))
print("Jumlah Format Email Salah : "+str(count_deleted_wrong_format))
print("Jumlah Setelah Clean Format Email Salah : "+str(count_after_deleted_wrong_format))
print("Jumlah Duplicate (Phone, Mobile dan Email) : "+str(count_duplicate_general))
print("Jumlah Setelah Clean Duplicate : "+str(count_after_dedup_duplicate))
print("Jumlah Lead Test : "+str(count_leads_test))
print("Jumlah Setelah Clean Lead Test : "+str(count_after_dedup_test))
# print("Jumlah Lead Do Not Mail : "+str(count_dnm))
# print("Jumlah Setelah Clean Lead Do Not Mail : "+str(count_after_dedup_dnm))
print("Jumlah Email OTA : "+str(count_email_OTA))
print("Jumlah Setelah Clean Email OTA : "+str(count_after_clean_OTA))
print("Jumlah Email Karma : "+str(count_email_karma))
print("Jumlah Setelah Clean Email Karma : "+str(count_after_clean_karma))
print("Jumlah Wash Member : "+str(count_member_dedup))
print("Jumlah Wash Booking : "+str(count_booking_dedup))
print("Jumlah Setelah Wash Member : "+str(count_after_wash_member))
print("Jumlah Phone Email Blank (Setelah phone yang tidak valid dihapus) : "+str(count_blank))
print("Jumlah Setelah Wash Phone Email Blank : "+str(count_after_wash_blank))
print("==========================================================")
print("Contact Type")
print("==========================================================")
print("Jumlah Email Only : "+str(count_email_only))
print("Jumlah Phone Only : "+str(count_phone_only))
print("Jumlah Email dan Phone : "+str(count_email_and_phone))
# Out:
# ==========================================================
# Summary
# ==========================================================
# Jumlah Keseluruhan Master Zoho : 493249
# Jumlah Filter Leads Awal : 4058
# Jumlah Format Email Salah : 0
# Jumlah Setelah Clean Format Email Salah : 4058
# Jumlah Duplicate (Phone, Mobile dan Email) : 7
# Jumlah Setelah Clean Duplicate : 4051
# Jumlah Lead Test : 0
# Jumlah Setelah Clean Lead Test : 4051
# Jumlah Email OTA : 3
# Jumlah Setelah Clean Email OTA : 4048
# Jumlah Email Karma : 3
# Jumlah Setelah Clean Email Karma : 4045
# Jumlah Wash Member : 224
# Jumlah Wash Booking : 10
# Jumlah Setelah Wash Member : 3811
# Jumlah Phone Email Blank (Setelah phone yang tidak valid dihapus) : 0
# Jumlah Setelah Wash Phone Email Blank : 3811
# ==========================================================
# Contact Type
# ==========================================================
# Jumlah Email Only : 6
# Jumlah Phone Only : 1
# Jumlah Email dan Phone : 3804

# %%
print("==========================================================")
print("Summary Report")
print("==========================================================")
print("Jumlah Data Awal : "+str(count_filter_awal))
print("Jumlah Wash Dedup : "+str(count_sum_dedup))
print("Jumlah Wash Member : "+str(count_member_dedup))
print("Jumlah Wash Booking : "+str(count_booking_dedup))
print("Jumlah Data Akhir : "+str(count_after_wash_blank))
# Out:
# ==========================================================
# Summary Report
# ==========================================================
# Jumlah Data Awal : 4058
# Jumlah Wash Dedup : 13
# Jumlah Wash Member : 224
# Jumlah Wash Booking : 10
# Jumlah Data Akhir : 3811

# %% [markdown]
# # ====================== Akhir Filter Umum ======================

# %%
zoho_df.replace('empty', '', inplace=True, regex=True)

zoho_df['First Name'] = zoho_df['First Name'].str.title()
zoho_df['Last Name'] = zoho_df['Last Name'].str.title()

zoho_df.to_excel(r'C:\Users\fajar\Documents\Python\Data\data_req_new.xlsx', index=False)

# %%
zoho_df.groupby('Country').count()
# Out:
#                 Record Id  Created Time  Created Date  First Name  Last Name  \
# Country
#                        31            31            31          31         31
# Argentina               4             4             4           4          4
# Armenia                 2             2             2           2          2
# Australia             558           558           558         558        558
# Austria                33            33            33          33         33
# ...                   ...           ...           ...         ...        ...
# United Kingdom        165           165           165         165        165
# United States         155           155           155         155        155
# Uzbekistan              5             5             5           5          5
# Venezuela               1             1             1           1          1
# Vietnam                 4             4             4           4          4
#
#                 Email  Phone  Mobile  Birthdate  Year of Birth  ...  \
# Country                                                         ...
#                    31     31      31         31             31  ...
# Argentina           4      4       4          4              4  ...
# Armenia             2      2       2          2              2  ...
# Australia         558    558     558        558            558  ...
# Austria            33     33      33         33             33  ...
# ...               ...    ...     ...        ...            ...  ...
# United Kingdom    165    165     165        165            165  ...
# United States     155    155     155        155            155  ...
# Uzbekistan          5      5       5          5              5  ...
# Venezuela           1      1       1          1              1  ...
# Vietnam             4      4       4          4              4  ...
#
#                 Lead Source  Lead Locations  Lead Source Description  \
# Country
#                          31              31                       31
# Argentina                 4               4                        4
# Armenia                   2               2                        2
# Australia               558             558                      558
# Austria                  33              33                       33
# ...                     ...             ...                      ...
# United Kingdom          165             165                      165
# United States           155             155                      155
# Uzbekistan                5               5                        5
# Venezuela                 1               1                        1
# Vietnam                   4               4                        4
#
#                 Lead Regions  Lead Status  Email Opt Out  Opt In  \
# Country
#                           31           31             31      31
# Argentina                  4            4              4       4
# Armenia                    2            2              2       2
# Australia                558          558            558     558
# Austria                   33           33             33      33
# ...                      ...          ...            ...     ...
# United Kingdom           165          165            165     165
# United States            155          155            155     155
# Uzbekistan                 5            5              5       5
# Venezuela                  1            1              1       1
# Vietnam                    4            4              4       4
#
#                 GDPR Compliant  Website  Contact Type
# Country
#                             31       31            31
# Argentina                    4        4             4
# Armenia                      2        2             2
# Australia                  558      558           558
# Austria                     33       33            33
# ...                        ...      ...           ...
# United Kingdom             165      165           165
# United States              155      155           155
# Uzbekistan                   5        5             5
# Venezuela                    1        1             1
# Vietnam                      4        4             4
#
# [79 rows x 33 columns]

# %%
# zoho_df['Country'].loc[
#     (zoho_df['Phone'].str.contains('^44|^\+44')) & 
#     (~zoho_df['Country'].str.contains('united kingdom|wales|england|scotland|northern ireland', regex=True, flags=re.I))
# ]
