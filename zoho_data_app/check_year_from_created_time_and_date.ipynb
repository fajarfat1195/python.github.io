# %%
import main_module as m
import zoho_filter_module as fil
import pandas as pd
import re
import numpy as np

# %load_ext autoreload
# %autoreload 2

dir_path = r'C:\Users\fajar\Documents\Python\Data\Zoho_Backup'
file_name = '\Leads_'

# %%
path = r'C:\Users\fajar\Documents\Python\Data\Request Data\Suhali\Agustus\10 Agustus\Flybuy ID\Update 12 Dec\zoho_tm_id_clean_update_12_dec.xlsx'
zoho_df = pd.read_excel(path, dtype='string', sheet_name='Sheet1')

zoho_df.reset_index(drop=True, inplace=True)
count_filter_awal = zoho_df.shape[0]

# mengisi kolom <NA> dengan value string 'empty' supaya mudah mengecek data member dan booking dengan isin

zoho_df.fillna('empty', inplace=True)
zoho_df
# Out:
#                        Record Id         Created Time Created Date First Name  \
# 0       zcrm_3584690000000404471  2019-01-08 11:07:28   2019-01-03       Ayuk
# 1       zcrm_3584690000000404474  2019-01-08 11:07:28   2019-01-03        Luh
# 2       zcrm_3584690000000404477  2019-01-08 11:07:28   2019-01-03       Anak
# 3       zcrm_3584690000000404481  2019-01-08 11:07:28   2019-01-03    Michael
# 4       zcrm_3584690000000404589  2019-01-08 11:07:28   2019-01-03      Baden
# ...                          ...                  ...          ...        ...
# 709061  zcrm_3584690000456702029  2023-08-06 11:57:54        empty       Cici
# 709062  zcrm_3584690000456702731  2023-08-07 17:43:41        empty      Hsjhs
# 709063  zcrm_3584690000456724001  2023-08-06 18:30:10        empty     Isyana
# 709064  zcrm_3584690000456725027  2023-08-06 18:44:57        empty      Agung
# 709065  zcrm_3584690000456727041  2023-08-07 01:38:47        empty        Ela
#
#         Last Name                           Email          Phone  \
# 0         Purnama            piscesia88@gmail.com  6281901228055
# 1            Srik            sriyaniluh@gmail.com  6281936915201
# 2       Kleyangan     timotiustono83.tt@gmail.com  6285737081378
# 3         Margono        michaelmargono@gmail.com  6287862823000
# 4            Gray            baden@prosper.org.nz    62272446663
# ...           ...                             ...            ...
# 709061       Asih  cici21.liocollection@gmail.com  6281353358951
# 709062     Uuieug                 raafh@gmail.com   628167769289
# 709063     Yudita              isyanayl@gmail.com  6281277120679
# 709064      Agung               aduuunk@gmail.com  6281282819991
# 709065        Ela            blacklanaa@gmail.com  6287869605822
#
#                Mobile   Birthdate Year of Birth  ...  Lead Source  \
# 0               empty       empty         empty  ...         Wifi
# 1               empty  1997-02-22          1997  ...         Wifi
# 2               empty       empty         empty  ...         Wifi
# 3       6287862823000  2001-01-16          2001  ...         Wifi
# 4               empty  1968-06-26          1968  ...         Wifi
# ...               ...         ...           ...  ...          ...
# 709061          empty       empty         empty  ...         Wifi
# 709062          empty       empty         empty  ...         Wifi
# 709063  6281277120679       empty          1982  ...  Web Enquiry
# 709064  6281282819991       empty          1982  ...  Web Enquiry
# 709065  6287869605822       empty          1984  ...  Web Enquiry
#
#               Lead Locations  \
# 0                      empty
# 1                      empty
# 2                      empty
# 3                    Mall 21
# 4                      empty
# ...                      ...
# 709061      Karma Beach Bali
# 709062      Karma Beach Bali
# 709063  Nyoman Cafe Jimbaran
# 709064       Rame Restaurant
# 709065           Pandan Sari
#
#                                   Lead Source Description Lead Regions  \
# 0                                             Purple Wifi         SEAP
# 1                                             Purple Wifi         SEAP
# 2                                             Purple Wifi         SEAP
# 3                                             Purple Wifi         SEAP
# 4                                             Purple Wifi         SEAP
# ...                                                   ...          ...
# 709061                                        Purple Wifi         SEAP
# 709062                                        Purple Wifi         SEAP
# 709063  YTID | Web | W2MAR23 | Guest Survey ID Nyoman ...         SEAP
# 709064  YTID | Web | W2MAR23 | Guest Survey ID Rame Re...         SEAP
# 709065  YTID | Web | W2MAR23 | Guest Survey ID Pandan ...         SEAP
#
#          Lead Status Email Opt Out Opt In Do Not Contact Do Not Mail  \
# 0           New Lead         false  false          false       false
# 1           New Lead         false  false          false       false
# 2           New Lead         false  false          false       false
# 3           New Lead         false  false          false       false
# 4           New Lead         false  false          false       false
# ...              ...           ...    ...            ...         ...
# 709061      New Lead         false  false          false       false
# 709062      New Lead         false  false          false       false
# 709063  Hot Prospect         false  false          false       false
# 709064  Hot Prospect         false  false          false       false
# 709065  Hot Prospect         false  false          false       false
#
#            Contact Type
# 0       Email and Phone
# 1       Email and Phone
# 2       Email and Phone
# 3       Email and Phone
# 4       Email and Phone
# ...                 ...
# 709061  Email and Phone
# 709062  Email and Phone
# 709063  Email and Phone
# 709064  Email and Phone
# 709065  Email and Phone
#
# [709066 rows x 34 columns]

# %%
path = r'G:\.shortcut-targets-by-id\0B_d3smBjzo04eXpvS1NXTWF2RVE\_BOOKING\Booking By Year\FlyBuy Booking Data (BGAU & BGID & KE).xlsx'
df_booking = pd.read_excel(path, dtype='string', sheet_name='BOOKING_BGAU_BGID_KE')

path = r'G:\.shortcut-targets-by-id\0B_d3smBjzo04UUNBME5GOVhoMjA\_ODYSSEY\Phone Members.xlsx'
df_phone = pd.read_excel(path, dtype='string', sheet_name='Sheet1')

path = r'G:\.shortcut-targets-by-id\0B_d3smBjzo04UUNBME5GOVhoMjA\_ODYSSEY\Email Members.xlsx'
df_email = pd.read_excel(path, dtype='string', sheet_name='Sheet1')

# %% [markdown]
# # ====================== Awal Filter Umum ======================

# %%
# data phone, mobile dam email member yang ada di master data (wash member)

m.clean_number(zoho_df, 'Phone')
m.clean_number(zoho_df, 'Mobile')
m.replace_not_valid_to_empty(zoho_df, 'Phone')
m.replace_not_valid_to_empty(zoho_df, 'Mobile')
zoho_df['Email'] = m.lowercase(zoho_df, 'Email')
m.clean_space(zoho_df, 'Email')

m.clean_number(df_booking, 'Phone1')
m.clean_number(df_booking, 'Mobile')
df_booking['Email'] = m.lowercase(df_booking, 'Email')
m.clean_space(df_booking, 'Email')

m.clean_number(df_phone, 'Mobile')

df_email['Email'] = m.lowercase(df_email, 'Email')
m.clean_space(df_email, 'Email')
# Out:
# 0               harvey@liblink.co.za
# 1                _benezi@hotmail.com
# 2                    0000987@mail.ru
# 3                  0007psc@gmail.com
# 4                 001paras@gmail.com
#                      ...
# 304941    narkhede.sheetal@gmail.com
# 304942    joshua.redmond81@gmail.com
# 304943    phoebe.e.cetoupe@gmail.com
# 304944    rithikahedge0010@gmail.com
# 304945            sheila@amaneer.com
# Name: Email, Length: 304946, dtype: string

# %%
find_member_booking = zoho_df.copy()

find_member_booking.loc[find_member_booking['Phone'].isin(df_booking['Phone1']), 'Same Value Find'] = 'Booking-Phone1'
find_member_booking.loc[find_member_booking['Phone'].isin(df_booking['Mobile']), 'Same Value Find'] = 'Booking-Mobile'
find_member_booking.loc[find_member_booking['Mobile'].isin(df_booking['Phone1']), 'Same Value Find'] = 'Booking-Phone1' 
find_member_booking.loc[find_member_booking['Mobile'].isin(df_booking['Mobile']), 'Same Value Find'] = 'Booking-Mobile'
find_member_booking.loc[find_member_booking['Email'].isin(df_booking['Email']), 'Same Value Find'] = 'Booking-Email'

find_member_booking.loc[find_member_booking['Phone'].isin(df_phone['Mobile']), 'Same Value Find'] = 'Member-Mobile' 
find_member_booking.loc[find_member_booking['Mobile'].isin(df_phone['Mobile']), 'Same Value Find'] = 'Member-Mobile'

find_member_booking.loc[find_member_booking['Email'].isin(df_email['Email']), 'Same Value Find'] = 'Member-Email'

find_member_booking.drop(find_member_booking.loc[find_member_booking['Same Value Find'].isna()].index, inplace=True)

count_booking_dedup = find_member_booking.loc[find_member_booking['Same Value Find'].str.contains('Booking', flags=re.I, regex=True)].shape[0]
count_member_dedup = find_member_booking.loc[find_member_booking['Same Value Find'].str.contains('Member', flags=re.I, regex=True)].shape[0]

find_member_booking.replace('empty', '', inplace=True)
# find_member_booking.to_csv(r'C:\Users\fajar\Documents\Python\Data\booking-member-dedup.csv', index=False)
# find_member_booking.to_excel(r'C:\Users\fajar\Documents\Python\Data\booking-member-dedup.xlsx', index=False)

#find_member_booking.loc[find_member_booking['Same Value Find'] == 'Booking-Phone1']

# %%
# data phone, mobile dam email member yang ada di master data 
count_wash_member = zoho_df.loc[
    zoho_df['Phone'].isin(df_booking['Phone1']) | 
    zoho_df['Phone'].isin(df_booking['Mobile']) |
    zoho_df['Mobile'].isin(df_booking['Phone1']) | 
    zoho_df['Mobile'].isin(df_booking['Mobile']) |
    zoho_df['Email'].isin(df_booking['Email'])| 

    zoho_df['Phone'].isin(df_phone['Mobile']) | 
    zoho_df['Mobile'].isin(df_phone['Mobile']) |

    zoho_df['Email'].isin(df_email['Email'])

].shape[0]

zoho_df.drop(zoho_df.loc[
    zoho_df['Phone'].isin(df_booking['Phone1']) | 
    zoho_df['Phone'].isin(df_booking['Mobile']) |
    zoho_df['Mobile'].isin(df_booking['Phone1']) | 
    zoho_df['Mobile'].isin(df_booking['Mobile']) |
    zoho_df['Email'].isin(df_booking['Email']) |
    
    zoho_df['Phone'].isin(df_phone['Mobile']) | 
    zoho_df['Mobile'].isin(df_phone['Mobile']) |

    zoho_df['Email'].isin(df_email['Email'])

    ].index, inplace=True)
    
zoho_df.reset_index(drop=True, inplace=True)

count_after_wash_member = zoho_df.shape[0]

# %%
count_final = zoho_df.shape[0]
zoho_df
# Out:
#                        Record Id         Created Time Created Date First Name  \
# 0       zcrm_3584690000000404471  2019-01-08 11:07:28   2019-01-03       Ayuk
# 1       zcrm_3584690000000404474  2019-01-08 11:07:28   2019-01-03        Luh
# 2       zcrm_3584690000000404477  2019-01-08 11:07:28   2019-01-03       Anak
# 3       zcrm_3584690000000404481  2019-01-08 11:07:28   2019-01-03    Michael
# 4       zcrm_3584690000000404589  2019-01-08 11:07:28   2019-01-03      Baden
# ...                          ...                  ...          ...        ...
# 709061  zcrm_3584690000456702029  2023-08-06 11:57:54        empty       Cici
# 709062  zcrm_3584690000456702731  2023-08-07 17:43:41        empty      Hsjhs
# 709063  zcrm_3584690000456724001  2023-08-06 18:30:10        empty     Isyana
# 709064  zcrm_3584690000456725027  2023-08-06 18:44:57        empty      Agung
# 709065  zcrm_3584690000456727041  2023-08-07 01:38:47        empty        Ela
#
#         Last Name                           Email          Phone  \
# 0         Purnama            piscesia88@gmail.com  6281901228055
# 1            Srik            sriyaniluh@gmail.com  6281936915201
# 2       Kleyangan     timotiustono83.tt@gmail.com  6285737081378
# 3         Margono        michaelmargono@gmail.com  6287862823000
# 4            Gray            baden@prosper.org.nz    62272446663
# ...           ...                             ...            ...
# 709061       Asih  cici21.liocollection@gmail.com  6281353358951
# 709062     Uuieug                 raafh@gmail.com   628167769289
# 709063     Yudita              isyanayl@gmail.com  6281277120679
# 709064      Agung               aduuunk@gmail.com  6281282819991
# 709065        Ela            blacklanaa@gmail.com  6287869605822
#
#                Mobile   Birthdate Year of Birth  ...  Lead Source  \
# 0               empty       empty         empty  ...         Wifi
# 1               empty  1997-02-22          1997  ...         Wifi
# 2               empty       empty         empty  ...         Wifi
# 3       6287862823000  2001-01-16          2001  ...         Wifi
# 4               empty  1968-06-26          1968  ...         Wifi
# ...               ...         ...           ...  ...          ...
# 709061          empty       empty         empty  ...         Wifi
# 709062          empty       empty         empty  ...         Wifi
# 709063  6281277120679       empty          1982  ...  Web Enquiry
# 709064  6281282819991       empty          1982  ...  Web Enquiry
# 709065  6287869605822       empty          1984  ...  Web Enquiry
#
#               Lead Locations  \
# 0                      empty
# 1                      empty
# 2                      empty
# 3                    Mall 21
# 4                      empty
# ...                      ...
# 709061      Karma Beach Bali
# 709062      Karma Beach Bali
# 709063  Nyoman Cafe Jimbaran
# 709064       Rame Restaurant
# 709065           Pandan Sari
#
#                                   Lead Source Description Lead Regions  \
# 0                                             Purple Wifi         SEAP
# 1                                             Purple Wifi         SEAP
# 2                                             Purple Wifi         SEAP
# 3                                             Purple Wifi         SEAP
# 4                                             Purple Wifi         SEAP
# ...                                                   ...          ...
# 709061                                        Purple Wifi         SEAP
# 709062                                        Purple Wifi         SEAP
# 709063  YTID | Web | W2MAR23 | Guest Survey ID Nyoman ...         SEAP
# 709064  YTID | Web | W2MAR23 | Guest Survey ID Rame Re...         SEAP
# 709065  YTID | Web | W2MAR23 | Guest Survey ID Pandan ...         SEAP
#
#          Lead Status Email Opt Out Opt In Do Not Contact Do Not Mail  \
# 0           New Lead         false  false          false       false
# 1           New Lead         false  false          false       false
# 2           New Lead         false  false          false       false
# 3           New Lead         false  false          false       false
# 4           New Lead         false  false          false       false
# ...              ...           ...    ...            ...         ...
# 709061      New Lead         false  false          false       false
# 709062      New Lead         false  false          false       false
# 709063  Hot Prospect         false  false          false       false
# 709064  Hot Prospect         false  false          false       false
# 709065  Hot Prospect         false  false          false       false
#
#            Contact Type
# 0       Email and Phone
# 1       Email and Phone
# 2       Email and Phone
# 3       Email and Phone
# 4       Email and Phone
# ...                 ...
# 709061  Email and Phone
# 709062  Email and Phone
# 709063  Email and Phone
# 709064  Email and Phone
# 709065  Email and Phone
#
# [709066 rows x 34 columns]

# %%
created_date = zoho_df['Created Date'].str.split('-', expand=True)
created_time = zoho_df['Created Time'].str.split('-', expand=True)
date_year = created_date[0]
time_year = created_time[0]

# %%
zoho_df['New Year'] = date_year

# %%
zoho_df.loc[zoho_df['New Year'] == 'empty', 'New Year'] = time_year

# %%
zoho_df.loc[zoho_df['New Year'] == 'empty']
zoho_df.loc[zoho_df['New Year'] == '2000']
# zoho_df
# Out:
#                        Record Id         Created Time Created Date  \
# 31755   zcrm_3584690000005929436  2019-04-02 03:56:26   2000-01-01
# 31756   zcrm_3584690000005929437  2019-04-02 03:56:26   2000-01-01
# 31834   zcrm_3584690000006080032  2019-04-02 04:17:04   2000-01-01
# 31847   zcrm_3584690000006080243  2019-04-02 04:17:05   2000-01-01
# 31867   zcrm_3584690000006080640  2019-04-02 04:17:08   2000-01-01
# ...                          ...                  ...          ...
# 214648  zcrm_3584690000014368779  2019-04-02 22:23:26   2000-01-01
# 214735  zcrm_3584690000015911168  2019-04-03 02:32:42   2000-01-01
# 215120  zcrm_3584690000017483515  2019-04-03 06:26:30   2000-01-01
# 215124  zcrm_3584690000017776588  2019-04-03 07:41:35   2000-01-01
# 215276  zcrm_3584690000021779822  2019-04-03 17:39:25   2000-01-01
#
#             First Name       Last Name                  Email          Phone  \
# 31755            Kapil        Mehrotra  kapil1874@hotmail.com  6281364410414
# 31756            Kapil        Mehrotra    kapil1874@yahoo.com  6281364410414
# 31834            Setya       Aryaputra  kentung1982@yahoo.com   628128469854
# 31847          Mutiara  Sakti Hasibuan  sakti_hsb@yahoo.co.id    62778363367
# 31867            Kevin            Yoon    kevin2004@empal.com   628179752231
# ...                ...             ...                    ...            ...
# 214648          John K           empty                  empty  6281558501203
# 214735  Lussal Release           empty                  empty    62811546602
# 215120      S N Jadiya           empty                  empty     9925773772
# 215124      S N Jadiya           empty                  empty    62882662655
# 215276    Eng Guan Lee           empty                  empty     6296570314
#
#                Mobile Birthdate Year of Birth  ... Lead Locations  \
# 31755           empty     empty         empty  ...          empty
# 31756           empty     empty         empty  ...          empty
# 31834   6281330388337     empty         empty  ...          empty
# 31847   6281364724433     empty         empty  ...          empty
# 31867      8179752231     empty         empty  ...          empty
# ...               ...       ...           ...  ...            ...
# 214648          empty     empty          1963  ...  Indian survey
# 214735          empty     empty          1963  ...  Indian survey
# 215120          empty     empty          1969  ...  Indian survey
# 215124          empty     empty          1969  ...  Indian survey
# 215276          empty     empty         empty  ...  Indian survey
#
#                            Lead Source Description Lead Regions Lead Status  \
# 31755   Karma list email for Bhanu - International         SEAP       empty
# 31756   Karma list email for Bhanu - International         SEAP       empty
# 31834   Karma list email for Bhanu - International         SEAP       empty
# 31847   Karma list email for Bhanu - International         SEAP       empty
# 31867          KarmaRoyalGroup-Indonesia-EmailOnly         SEAP       empty
# ...                                            ...          ...         ...
# 214648       COLDLINE DATA-AIRPORT SURVEYS BATCH 2         SEAP       empty
# 214735       COLDLINE DATA-AIRPORT SURVEYS BATCH 4         SEAP       empty
# 215120                       MAHABALESHWAR SURVEYS         SEAP       empty
# 215124                       MAHABALESHWAR SURVEYS         SEAP       empty
# 215276                         GUEST EXIT JIMBARAN         SEAP       empty
#
#        Email Opt Out Opt In Do Not Contact Do Not Mail     Contact Type  \
# 31755          false  false          false       false  Email and Phone
# 31756          false  false          false       false  Email and Phone
# 31834          false  false          false       false  Email and Phone
# 31847          false  false          false       false  Email and Phone
# 31867          false  false          false       false  Email and Phone
# ...              ...    ...            ...         ...              ...
# 214648         false  false          false       false       Phone Only
# 214735         false  false          false       false       Phone Only
# 215120         false  false          false       false       Phone Only
# 215124         false  false          false       false       Phone Only
# 215276         false  false          false       false       Phone Only
#
#        New Year
# 31755      2000
# 31756      2000
# 31834      2000
# 31847      2000
# 31867      2000
# ...         ...
# 214648     2000
# 214735     2000
# 215120     2000
# 215124     2000
# 215276     2000
#
# [2468 rows x 35 columns]

# %% [markdown]
# # ====================== Akhir Filter Umum ======================

# %%
print("==========================================================")
print("Summary Report")
print("==========================================================")
print("Jumlah Data Awal : "+str(count_filter_awal))
print("Jumlah Wash Member : "+str(count_member_dedup))
print("Jumlah Wash Booking : "+str(count_booking_dedup))
print("Jumlah Wash Booking : "+str(count_final))
# Out:
# ==========================================================
# Summary Report
# ==========================================================
# Jumlah Data Awal : 709066
# Jumlah Wash Member : 0
# Jumlah Wash Booking : 0
# Jumlah Wash Booking : 709066

# %%
zoho_df.replace('empty', '', inplace=True)
zoho_df.to_excel(r'C:\Users\fajar\Documents\Python\Data\Request Data\Suhali\Agustus\10 Agustus\Flybuy ID\Update 12 Dec\zoho_tm_id_clean_update_12_dec_year.xlsx', index=False)
