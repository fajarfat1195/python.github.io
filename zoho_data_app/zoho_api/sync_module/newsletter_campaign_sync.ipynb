# %%
import pandas as pd
import numpy as np
from datetime import date
from datetime import datetime
from datetime import datetime, timedelta
from pandas import json_normalize

import re

import sys
sys.path.append('../')

import zoho_crm_api_module as crm
import accell_mail_api_module as campaign
import requests

import sys
sys.path.append('../../../zoho_data_app/')

# importing
import main_module as m
import zoho_filter_module as fil

# %load_ext autoreload
# %autoreload 2

# %%
cols = [
    'Created_Time', 
    'id', 
    'First_Name', 
    'Last_Name', 
    'Email', 
    'Phone', 
    'Mobile', 
    'Brand', 
    'Lead_Sub_Brand', 
    'Lead_Source', 
    'Lead_Regions',
    'Lead_Locations', 
    'City', 
    'Nationality', 
    'Country', 
    'Booking_Status', 
    'Guest_Type', 
    'Email_Opt_In',
    'Email_Opt_Out', 
    'BookRef',
    'Email_status', 
    'Odyssey_Members', 
    'Do_Not_Mail', 
    'Do_Not_Contact'
]

# %%
crm_token = crm.get_crm_token()

# %%
df = crm.get_newsletter_data(crm_token, cols)
df.fillna('empty', inplace=True)
new_df = crm.get_newsletter_data_filter(df)
new_df.sort_values('Created_Time', ascending=True, inplace=True)
new_df.reset_index(drop=True, inplace=True)
count_data_awal = new_df.shape[0]

# %%
new_df['First_Name'] = new_df['First_Name'].str.title()
new_df['Last_Name'] = new_df['Last_Name'].str.title()
new_df['Email'] = m.lowercase(new_df, 'Email')
m.clean_space(new_df, 'Email')

new_df
# new_df.to_excel(r"C:\Users\fajar\Documents\Python\Data\newsletter_zoho.xlsx", index=False)
# Out:
#                  Created_Time                   id First_Name  \
# 0   2024-07-21T02:53:50+08:00  3584690000503099166      Sasha
# 1   2024-07-21T17:06:52+08:00  3584690000503076352      Hetal
# 2   2024-07-21T17:11:20+08:00  3584690000503088389      Debra
# 3   2024-07-22T14:25:11+08:00  3584690000503191143       Alex
# 4   2024-07-22T16:35:44+08:00  3584690000503178512       Renu
# 5   2024-07-22T16:40:07+08:00  3584690000503184294       Rina
# 6   2024-07-22T17:50:57+08:00  3584690000503186290    Baljeet
# 7   2024-07-23T09:46:39+08:00  3584690000503185653       Arun
# 8   2024-07-23T12:24:52+08:00  3584690000503178636       Shiv
# 9   2024-07-23T16:18:56+08:00  3584690000503270001   Sharmila
# 10  2024-07-23T18:43:19+08:00  3584690000503286043   Nikhlesh
# 11  2024-07-24T06:18:32+08:00  3584690000503338034    Richard
# 12  2024-07-24T11:29:46+08:00  3584690000503337068     Kavita
# 13  2024-07-24T16:14:21+08:00  3584690000503419001     Khushi
# 14  2024-07-24T16:30:31+08:00  3584690000503431001      Peter
# 15  2024-07-24T17:46:32+08:00  3584690000503444035      Irfan
# 16  2024-07-25T15:09:38+08:00  3584690000503549002      Kerry
# 17  2024-07-25T16:24:56+08:00  3584690000503540109    Deepaka
# 18  2024-07-25T20:06:10+08:00  3584690000503579001      Ahmed
# 19  2024-07-25T23:20:37+08:00  3584690000503583076   Virender
#
#            Last_Name                            Email  Phone Mobile  \
# 0           Whitaker            sashawhitaker@msn.com  empty  empty
# 1               Shah             hetal77hjs@gmail.com  empty  empty
# 2              Hehir            dreamofbali@gmail.com  empty  empty
# 3              Tyers                riches@y7mail.com  empty  empty
# 4              Saini            s.bagai1927@gmail.com  empty  empty
# 5               Shah              rinks1967@gmail.com  empty  empty
# 6              Singh            baljeet224u@gmail.com  empty  empty
# 7                Sah          arunkrsah9431@gmail.com  empty  empty
# 8            Chedwal        dr.shivcchedwal@gmail.com  empty  empty
# 9          Doddamanu       dharmilahosur889@gmail.com  empty  empty
# 10           Ramanuj         ramanuj.nikhil@gmail.com  empty  empty
# 11             Ramli         jusniatychitra@gmail.com  empty  empty
# 12             Verma              nkkavi786@gmail.com  empty  empty
# 13            Sharma              ks7050965@gmail.com  empty  empty
# 14            Kruhse          peterkruhse@hotmail.com  empty  empty
# 15             Latif              ihlatif@hotmail.com  empty  empty
# 16  Naylor Griffiths                kezzaford@msn.com  empty  empty
# 17            Sharma            deepaka2502@gmail.com  empty  empty
# 18           Mostafa  ahmedmostafa.am601176@gmail.com  empty  empty
# 19              Jain                 vkjxyz@gmail.com  empty  empty
#
#           Brand Lead_Sub_Brand Lead_Source  ...    Country Booking_Status  \
# 0   Karma Group          Other  Newsletter  ...   Portugal          empty
# 1   Karma Group          Other  Newsletter  ...      India          empty
# 2   Karma Group          Other  Newsletter  ...  Australia          empty
# 3   Karma Group          Other  Newsletter  ...  Indonesia          empty
# 4   Karma Group          Other  Newsletter  ...      India          empty
# 5   Karma Group          Other  Newsletter  ...  Australia          empty
# 6   Karma Group          Other  Newsletter  ...      India          empty
# 7   Karma Group          Other  Newsletter  ...      India          empty
# 8   Karma Group          Other  Newsletter  ...      India          empty
# 9   Karma Group          Other  Newsletter  ...      India          empty
# 10  Karma Group          Other  Newsletter  ...      India          empty
# 11  Karma Group          Other  Newsletter  ...  Indonesia          empty
# 12  Karma Group          Other  Newsletter  ...      India          empty
# 13  Karma Group          Other  Newsletter  ...      India          empty
# 14  Karma Group          Other  Newsletter  ...  Australia          empty
# 15  Karma Group          Other  Newsletter  ...      empty          empty
# 16  Karma Group          Other  Newsletter  ...      empty          empty
# 17  Karma Group          Other  Newsletter  ...      India          empty
# 18  Karma Group          Other  Newsletter  ...      Egypt          empty
# 19  Karma Group          Other  Newsletter  ...      India          empty
#
#    Guest_Type Email_Opt_In Email_Opt_Out BookRef Email_status  \
# 0       empty        False         False   empty        empty
# 1       empty        False         False   empty        empty
# 2       empty        False         False   empty        empty
# 3       empty        False         False   empty        empty
# 4       empty        False         False   empty        empty
# 5       empty        False         False   empty        empty
# 6       empty        False         False   empty        empty
# 7       empty        False         False   empty        empty
# 8       empty        False         False   empty        empty
# 9       empty        False         False   empty        empty
# 10      empty        False         False   empty        empty
# 11      empty        False         False   empty        empty
# 12      empty        False         False   empty        empty
# 13      empty        False         False   empty        empty
# 14      empty        False         False   empty        empty
# 15      empty        False         False   empty        empty
# 16      empty        False         False   empty        empty
# 17      empty        False         False   empty        empty
# 18      empty        False         False   empty        empty
# 19      empty        False         False   empty        empty
#
#     Odyssey_Members  Do_Not_Mail Do_Not_Contact
# 0             False        False          False
# 1             False        False          False
# 2             False        False          False
# 3             False        False          False
# 4             False        False          False
# 5             False        False          False
# 6             False        False          False
# 7             False        False          False
# 8             False        False          False
# 9             False        False          False
# 10            False        False          False
# 11            False        False          False
# 12            False        False          False
# 13            False        False          False
# 14            False        False          False
# 15            False        False          False
# 16            False        False          False
# 17            False        False          False
# 18            False        False          False
# 19            False        False          False
#
# [20 rows x 24 columns]

# %%
# # mencari tanggal 8 hari kebelakang
# calculate_date = datetime.now() - timedelta(days=8)
# new_cal_date = str(calculate_date.strftime("%Y-%m-%d")).split(' ')
# first_date = new_cal_date[0]

# # mencari tanggal hari ini
# today = datetime.now() 
# second_date = today.strftime("%Y-%m-%d")

# print(first_date)
# print(second_date)

# %%
# new_df['Lead_Locations']

# %%
new_df.replace('empty', '', inplace=True)
new_df
# Out:
#                  Created_Time                   id First_Name  \
# 0   2024-07-21T02:53:50+08:00  3584690000503099166      Sasha
# 1   2024-07-21T17:06:52+08:00  3584690000503076352      Hetal
# 2   2024-07-21T17:11:20+08:00  3584690000503088389      Debra
# 3   2024-07-22T14:25:11+08:00  3584690000503191143       Alex
# 4   2024-07-22T16:35:44+08:00  3584690000503178512       Renu
# 5   2024-07-22T16:40:07+08:00  3584690000503184294       Rina
# 6   2024-07-22T17:50:57+08:00  3584690000503186290    Baljeet
# 7   2024-07-23T09:46:39+08:00  3584690000503185653       Arun
# 8   2024-07-23T12:24:52+08:00  3584690000503178636       Shiv
# 9   2024-07-23T16:18:56+08:00  3584690000503270001   Sharmila
# 10  2024-07-23T18:43:19+08:00  3584690000503286043   Nikhlesh
# 11  2024-07-24T06:18:32+08:00  3584690000503338034    Richard
# 12  2024-07-24T11:29:46+08:00  3584690000503337068     Kavita
# 13  2024-07-24T16:14:21+08:00  3584690000503419001     Khushi
# 14  2024-07-24T16:30:31+08:00  3584690000503431001      Peter
# 15  2024-07-24T17:46:32+08:00  3584690000503444035      Irfan
# 16  2024-07-25T15:09:38+08:00  3584690000503549002      Kerry
# 17  2024-07-25T16:24:56+08:00  3584690000503540109    Deepaka
# 18  2024-07-25T20:06:10+08:00  3584690000503579001      Ahmed
# 19  2024-07-25T23:20:37+08:00  3584690000503583076   Virender
#
#            Last_Name                            Email Phone Mobile  \
# 0           Whitaker            sashawhitaker@msn.com
# 1               Shah             hetal77hjs@gmail.com
# 2              Hehir            dreamofbali@gmail.com
# 3              Tyers                riches@y7mail.com
# 4              Saini            s.bagai1927@gmail.com
# 5               Shah              rinks1967@gmail.com
# 6              Singh            baljeet224u@gmail.com
# 7                Sah          arunkrsah9431@gmail.com
# 8            Chedwal        dr.shivcchedwal@gmail.com
# 9          Doddamanu       dharmilahosur889@gmail.com
# 10           Ramanuj         ramanuj.nikhil@gmail.com
# 11             Ramli         jusniatychitra@gmail.com
# 12             Verma              nkkavi786@gmail.com
# 13            Sharma              ks7050965@gmail.com
# 14            Kruhse          peterkruhse@hotmail.com
# 15             Latif              ihlatif@hotmail.com
# 16  Naylor Griffiths                kezzaford@msn.com
# 17            Sharma            deepaka2502@gmail.com
# 18           Mostafa  ahmedmostafa.am601176@gmail.com
# 19              Jain                 vkjxyz@gmail.com
#
#           Brand Lead_Sub_Brand Lead_Source  ...    Country Booking_Status  \
# 0   Karma Group          Other  Newsletter  ...   Portugal
# 1   Karma Group          Other  Newsletter  ...      India
# 2   Karma Group          Other  Newsletter  ...  Australia
# 3   Karma Group          Other  Newsletter  ...  Indonesia
# 4   Karma Group          Other  Newsletter  ...      India
# 5   Karma Group          Other  Newsletter  ...  Australia
# 6   Karma Group          Other  Newsletter  ...      India
# 7   Karma Group          Other  Newsletter  ...      India
# 8   Karma Group          Other  Newsletter  ...      India
# 9   Karma Group          Other  Newsletter  ...      India
# 10  Karma Group          Other  Newsletter  ...      India
# 11  Karma Group          Other  Newsletter  ...  Indonesia
# 12  Karma Group          Other  Newsletter  ...      India
# 13  Karma Group          Other  Newsletter  ...      India
# 14  Karma Group          Other  Newsletter  ...  Australia
# 15  Karma Group          Other  Newsletter  ...
# 16  Karma Group          Other  Newsletter  ...
# 17  Karma Group          Other  Newsletter  ...      India
# 18  Karma Group          Other  Newsletter  ...      Egypt
# 19  Karma Group          Other  Newsletter  ...      India
#
#    Guest_Type Email_Opt_In Email_Opt_Out BookRef Email_status  \
# 0                    False         False
# 1                    False         False
# 2                    False         False
# 3                    False         False
# 4                    False         False
# 5                    False         False
# 6                    False         False
# 7                    False         False
# 8                    False         False
# 9                    False         False
# 10                   False         False
# 11                   False         False
# 12                   False         False
# 13                   False         False
# 14                   False         False
# 15                   False         False
# 16                   False         False
# 17                   False         False
# 18                   False         False
# 19                   False         False
#
#     Odyssey_Members  Do_Not_Mail Do_Not_Contact
# 0             False        False          False
# 1             False        False          False
# 2             False        False          False
# 3             False        False          False
# 4             False        False          False
# 5             False        False          False
# 6             False        False          False
# 7             False        False          False
# 8             False        False          False
# 9             False        False          False
# 10            False        False          False
# 11            False        False          False
# 12            False        False          False
# 13            False        False          False
# 14            False        False          False
# 15            False        False          False
# 16            False        False          False
# 17            False        False          False
# 18            False        False          False
# 19            False        False          False
#
# [20 rows x 24 columns]

# %%
# new_df = new_df.loc[new_df['Email'] == 'ferry.yudhitama+112312test@karmagroup.com'].copy()
# new_df.reset_index(drop=True, inplace=True)

# new_df = new_df.iloc[0:1].copy()
# new_df.reset_index(drop=True, inplace=True)

# new_df

# %%
# cek push newsletter data
# new_df.to_excel(r"C:\Users\fajar\Documents\Python\Data\push_newsletter.xlsx", index=False)

# %%
# Cek leads test
test_leads = new_df.loc[
    
        new_df['Email'].str.contains('^test@', flags=re.I, regex=True) |
        new_df['Email'].str.contains('\+test', flags=re.I, regex=True) |
    
        new_df['First_Name'].str.contains('^test$', flags=re.I, regex=True) |
        new_df['Last_Name'].str.contains('^test$', flags=re.I, regex=True) |

        new_df['First_Name'].str.contains('test 1', flags=re.I, regex=True) |
        new_df['Last_Name'].str.contains('test 2', flags=re.I, regex=True) |
        new_df['First_Name'].str.contains('test1', flags=re.I, regex=True) |
        new_df['Last_Name'].str.contains('test2', flags=re.I, regex=True) |

        new_df['First_Name'].str.contains(' test ', flags=re.I, regex=True) | 
        new_df['Last_Name'].str.contains(' test ', flags=re.I, regex=True) | 
        new_df['Last_Name'].str.contains(' test$', flags=re.I, regex=True)
    ]

count_leads_test = test_leads.shape[0]

# test_leads.to_excel(r'C:\Users\fajar\Documents\Python\Data\test_leads_2.xlsx', index=False)
test_leads
# Out:
# Empty DataFrame
# Columns: [Created_Time, id, First_Name, Last_Name, Email, Phone, Mobile, Brand, Lead_Sub_Brand, Lead_Source, Lead_Regions, Lead_Locations, City, Nationality, Country, Booking_Status, Guest_Type, Email_Opt_In, Email_Opt_Out, BookRef, Email_status, Odyssey_Members, Do_Not_Mail, Do_Not_Contact]
# Index: []
#
# [0 rows x 24 columns]

# %%
new_df.drop(test_leads.index, inplace=True)
new_df.reset_index(drop=True, inplace=True)

count_after_dedup_test = new_df.shape[0]
count_after_dedup_test
# Out:
# 20

# %%
count_final_data = new_df.shape[0]

# %%
# Define a dictionary containing ICC rankings
summary = {'Summary Description': ['Data Awal', 'Data Test', 'After Wash Test', '', 'Data Akhir'],
			'Count': [count_data_awal, count_leads_test, count_after_dedup_test,'', count_final_data]}

# Convert the dictionary into DataFrame
df_summary = pd.DataFrame(summary)
df_summary
# Out:
#   Summary Description Count
# 0           Data Awal    20
# 1           Data Test     0
# 2     After Wash Test    20
# 3
# 4          Data Akhir    20

# %%
row_data = new_df.shape[0]

if row_data > 0 :
    print('push data')
else :
    print('data empty')
# Out:
# push data

# %%
# merubah listkey di area ini

# list key list test
list_key = campaign.get_list_key()
list_name = 'Newsletter'

# push data ke list zoho campaign
push_data = campaign.push_data(list_key[list_name], list_name, new_df)
push_data
# Out:
#           Push Datetime   List Name         Email Created Time  \
# 0   06-08-2024 11:57:33  Newsletter  2024-07-21T02:53:50+08:00
# 1   06-08-2024 11:57:33  Newsletter  2024-07-21T17:06:52+08:00
# 2   06-08-2024 11:57:33  Newsletter  2024-07-21T17:11:20+08:00
# 3   06-08-2024 11:57:33  Newsletter  2024-07-22T14:25:11+08:00
# 4   06-08-2024 11:57:34  Newsletter  2024-07-22T16:35:44+08:00
# 5   06-08-2024 11:57:34  Newsletter  2024-07-22T16:40:07+08:00
# 6   06-08-2024 11:57:34  Newsletter  2024-07-22T17:50:57+08:00
# 7   06-08-2024 11:57:34  Newsletter  2024-07-23T09:46:39+08:00
# 8   06-08-2024 11:57:34  Newsletter  2024-07-23T12:24:52+08:00
# 9   06-08-2024 11:57:35  Newsletter  2024-07-23T16:18:56+08:00
# 10  06-08-2024 11:57:35  Newsletter  2024-07-23T18:43:19+08:00
# 11  06-08-2024 11:57:35  Newsletter  2024-07-24T06:18:32+08:00
# 12  06-08-2024 11:57:35  Newsletter  2024-07-24T11:29:46+08:00
# 13  06-08-2024 11:57:35  Newsletter  2024-07-24T16:14:21+08:00
# 14  06-08-2024 11:57:36  Newsletter  2024-07-24T16:30:31+08:00
# 15  06-08-2024 11:57:36  Newsletter  2024-07-24T17:46:32+08:00
# 16  06-08-2024 11:57:36  Newsletter  2024-07-25T15:09:38+08:00
# 17  06-08-2024 11:57:36  Newsletter  2024-07-25T16:24:56+08:00
# 18  06-08-2024 11:57:36  Newsletter  2024-07-25T20:06:10+08:00
# 19  06-08-2024 11:57:37  Newsletter  2024-07-25T23:20:37+08:00
#
#                               Email    Response Description  \
# 0             sashawhitaker@msn.com  Contact Already Exists
# 1              hetal77hjs@gmail.com  Contact Already Exists
# 2             dreamofbali@gmail.com  Contact Already Exists
# 3                 riches@y7mail.com  Contact Already Exists
# 4             s.bagai1927@gmail.com  Contact Already Exists
# 5               rinks1967@gmail.com  Contact Already Exists
# 6             baljeet224u@gmail.com  Contact Already Exists
# 7           arunkrsah9431@gmail.com       New Contact Added
# 8         dr.shivcchedwal@gmail.com  Contact Already Exists
# 9        dharmilahosur889@gmail.com       New Contact Added
# 10         ramanuj.nikhil@gmail.com       New Contact Added
# 11         jusniatychitra@gmail.com  Contact Already Exists
# 12              nkkavi786@gmail.com  Contact Already Exists
# 13              ks7050965@gmail.com  Contact Already Exists
# 14          peterkruhse@hotmail.com  Contact Already Exists
# 15              ihlatif@hotmail.com  Contact Already Exists
# 16                kezzaford@msn.com       New Contact Added
# 17            deepaka2502@gmail.com  Contact Already Exists
# 18  ahmedmostafa.am601176@gmail.com  Contact Already Exists
# 19                 vkjxyz@gmail.com       New Contact Added
#
#                                    Token Campaign API
# 0   3HgP0r8Q9N5g27bvhSa70nP0xkGSirTno9tnerl1CukoNg...
# 1   3HgP0r8Q9N5g27bvhSa70nP0xkGSirTno9tnerl1CukoNg...
# 2   3HgP0r8Q9N5g27bvhSa70nP0xkGSirTno9tnerl1CukoNg...
# 3   3HgP0r8Q9N5g27bvhSa70nP0xkGSirTno9tnerl1CukoNg...
# 4   3HgP0r8Q9N5g27bvhSa70nP0xkGSirTno9tnerl1CukoNg...
# 5   3HgP0r8Q9N5g27bvhSa70nP0xkGSirTno9tnerl1CukoNg...
# 6   3HgP0r8Q9N5g27bvhSa70nP0xkGSirTno9tnerl1CukoNg...
# 7   3HgP0r8Q9N5g27bvhSa70nP0xkGSirTno9tnerl1CukoNg...
# 8   3HgP0r8Q9N5g27bvhSa70nP0xkGSirTno9tnerl1CukoNg...
# 9   3HgP0r8Q9N5g27bvhSa70nP0xkGSirTno9tnerl1CukoNg...
# 10  3HgP0r8Q9N5g27bvhSa70nP0xkGSirTno9tnerl1CukoNg...
# 11  3HgP0r8Q9N5g27bvhSa70nP0xkGSirTno9tnerl1CukoNg...
# 12  3HgP0r8Q9N5g27bvhSa70nP0xkGSirTno9tnerl1CukoNg...
# 13  3HgP0r8Q9N5g27bvhSa70nP0xkGSirTno9tnerl1CukoNg...
# 14  3HgP0r8Q9N5g27bvhSa70nP0xkGSirTno9tnerl1CukoNg...
# 15  3HgP0r8Q9N5g27bvhSa70nP0xkGSirTno9tnerl1CukoNg...
# 16  3HgP0r8Q9N5g27bvhSa70nP0xkGSirTno9tnerl1CukoNg...
# 17  3HgP0r8Q9N5g27bvhSa70nP0xkGSirTno9tnerl1CukoNg...
# 18  3HgP0r8Q9N5g27bvhSa70nP0xkGSirTno9tnerl1CukoNg...
# 19  3HgP0r8Q9N5g27bvhSa70nP0xkGSirTno9tnerl1CukoNg...

# %%
today = datetime.now() 
date = today.strftime("%d-%m-%Y")

path = r'C:\Users\fajar\Documents\Python\Data\Zoho_Campaign\push data\api_log_history\newsletter\newsletter_log_history_'+str(date)+'.xlsx'

push_data.to_excel(path, sheet_name='Log History', index=False)
df_responses  = push_data.groupby(['Response Description'])['Email'].count().reset_index(name='Email Count').copy()

# %%
# jika ingin menambahkan sheets baru
with pd.ExcelWriter(path, mode="a", engine="openpyxl") as writer:
    df_summary.to_excel(writer, sheet_name="Summary Leads", index=False)
    df_responses.to_excel(writer, sheet_name="Summary Responses", index=False)
