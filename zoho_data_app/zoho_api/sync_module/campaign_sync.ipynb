# %%
import pandas as pd
import numpy as np
from datetime import datetime
from pandas import json_normalize

import re

import sys
sys.path.append('../')

import zoho_crm_api_module as crm
import zoho_campaign_api_module as campaign
import requests

import sys
sys.path.append('../../../zoho_data_app/')

# importing
import main_module as m
import zoho_filter_module as fil

# %load_ext autoreload
# %autoreload 2

# %%
cols = [
    'Created_Time', 
    'id', 
    'First_Name', 
    'Last_Name', 
    'Email', 
    'Phone', 
    'Mobile', 
    'Brand', 
    'Lead_Sub_Brand', 
    'Lead_Source', 
    'Lead_Regions',
    'Lead_Locations', 
    'City', 
    'Nationality', 
    'Country', 
    'Booking_Status', 
    'Guest_Type', 
    'Email_Opt_In',
    'Email_Opt_Out', 
    'BookRef'
]

# %%
campaign_token = campaign.get_campaign_token()
crm_token = crm.get_crm_token()

# %%
df_dict = {
    'First_Name':['Fajar', 'Toni'], 
    'Last_Name':['Fatoni', 'Skyland'],
    'Email':['fajarfatonisocial@gmail.com', 'toniskyland21@gmail.com'],
    'Phone':['081237114798', '08132479914'],
    'Mobile':['081237114791', '08132479912'],
    'Lead_Locations':['Karma Bavaria', 'Karma Karnak'],
    'City':['Denpasar', 'Badung'],
    'Nationality':['Indonesia', 'Malaysia'],
    'Country':['Brazil', 'Argentina'],
    'Booking_Status':['Check-In', 'Check-Out'],
    'BookRef':['123456', '654321']
    }
new_df = pd.DataFrame.from_dict(df_dict)
new_df
# Out:
#   First_Name Last_Name                        Email         Phone  \
# 0      Fajar    Fatoni  fajarfatonisocial@gmail.com  081237114798
# 1       Toni   Skyland      toniskyland21@gmail.com   08132479914
#
#          Mobile Lead_Locations      City Nationality    Country  \
# 0  081237114791  Karma Bavaria  Denpasar   Indonesia     Brazil
# 1   08132479912   Karma Karnak    Badung    Malaysia  Argentina
#
#   Booking_Status BookRef
# 0       Check-In  123456
# 1      Check-Out  654321

# %%
new_df['First_Name'] = new_df['First_Name'].str.title()
new_df['Last_Name'] = new_df['Last_Name'].str.title()
new_df['Email'] = m.lowercase(new_df, 'Email')
m.clean_space(new_df, 'Email')

new_df
# Out:
#   First_Name Last_Name                        Email         Phone  \
# 0      Fajar    Fatoni  fajarfatonisocial@gmail.com  081237114798
# 1       Toni   Skyland      toniskyland21@gmail.com   08132479914
#
#          Mobile Lead_Locations      City Nationality    Country  \
# 0  081237114791  Karma Bavaria  Denpasar   Indonesia     Brazil
# 1   08132479912   Karma Karnak    Badung    Malaysia  Argentina
#
#   Booking_Status BookRef
# 0       Check-In  123456
# 1      Check-Out  654321

# %%
# new_df['Lead_Locations'] = new_df['Lead_Locations'].astype('string')
# new_df['Lead_Locations'].replace('\[|\]|\'','', regex=True, inplace=True)
# new_df

# new_df.replace('empty', '', inplace=True)

# test_df = new_df.loc[new_df['Email'] == 'guslin_love@yahoo.co.id'].copy()
# test_df['Lead_Locations'] = test_df['Lead_Locations'].astype('string')
# test_df['Lead_Locations'].replace('\[|\]|\'','', regex=True, inplace=True)
# test_df
# Out:
#                   Created_Time                   id First_Name Last_Name  \
# 122  2022-11-21T13:23:21+08:00  3584690000411793886       Lina  Giantari
#
#                        Email         Phone Mobile          Brand  \
# 122  guslin_love@yahoo.co.id  628170728999         Karma Resorts
#
#     Lead_Sub_Brand  Lead_Source Lead_Regions       Lead_Locations  \
# 122          Other  Past Guests               KRR @ Karma Kandara
#
#               City Nationality    Country Booking_Status Guest_Type  \
# 122  Jakarta Barat  Indonesian  Indonesia    Checked-Out    Booking
#
#      Email_Opt_In  Email_Opt_Out  BookRef
# 122          True          False  2091120

# %%
# list key list test
list_key = campaign.get_list_key()
list_name = 'Test'

push_data = campaign.push_data(list_key['Test'], list_name, campaign_token, new_df)
push_data
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\core\indexes\base.py:3800, in Index.get_loc(self, key, method, tolerance)
#    3799 try:
# -> 3800     return self._engine.get_loc(casted_key)
#    3801 except KeyError as err:
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Created_Time'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In [6], line 5
#       2 list_key = campaign.get_list_key()
#       3 list_name = 'Test'
# ----> 5 push_data = campaign.push_data(list_key['Test'], list_name, campaign_token, new_df)
#       6 push_data
#
# File c:\Users\fajar\Documents\Python\Task Offline\zoho_data_app\zoho_api\sync_module\..\zoho_campaign_api_module.py:52, in push_data(list_key, list_name, token, df)
#      48 pushcounter = 0 # menghitung jumlah data yang sudah dipush
#      50 for index, row in df.iterrows():
# ---> 52     created_time = row['Created_Time']
#      54     first_name = '"First Name" :'+'"'+row['First_Name']+'",'
#      55     last_name = '"Last Name" :'+'"'+row['Last_Name']+'",'
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\core\series.py:982, in Series.__getitem__(self, key)
#     979     return self._values[key]
#     981 elif key_is_scalar:
# --> 982     return self._get_value(key)
#     984 if is_hashable(key):
#     985     # Otherwise index.get_value will raise InvalidIndexError
#     986     try:
#     987         # For labels that don't resolve as scalars like tuples and frozensets
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\core\series.py:1092, in Series._get_value(self, label, takeable)
#    1089     return self._values[label]
#    1091 # Similar to Index.get_value, but we do not fall back to positional
# -> 1092 loc = self.index.get_loc(label)
#    1093 return self.index._get_values_for_loc(self, loc, label)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3800     return self._engine.get_loc(casted_key)
#    3801 except KeyError as err:
# -> 3802     raise KeyError(key) from err
#    3803 except TypeError:
#    3804     # If we have a listlike key, _check_indexing_error will raise
#    3805     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3806     #  the TypeError.
#    3807     self._check_indexing_error(key)
#
# KeyError: 'Created_Time'

# %%
today = datetime.today()

# dd/mm/YY
date = today.strftime("%d-%m-%Y")
print(date)
# Out:
# 10-01-2023

# %%
path = r'C:\Users\fajar\Documents\Python\Data\Zoho_Campaign\push data\api_log_history\test\test_'+str(date)+'.xlsx'
push_data.to_excel(path, sheet_name='Log History', index=False)

df_responses  = push_data.groupby(['Response Description'])['Email'].count().reset_index(name='Email Count').copy()

# jika ingin menambahkan sheets baru
with pd.ExcelWriter(path, mode="a", engine="openpyxl") as writer:
    df_responses.to_excel(writer, sheet_name="Summary Responses", index=False)
