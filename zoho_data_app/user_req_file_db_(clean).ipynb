# %%
import main_module as m
import zoho_filter_module as fil
import pandas as pd
import re
import numpy as np

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
path_db = r'C:\Users\fajar\Documents\Python\Data\Request Data\DS Req\2024\27 Mar\all_email_unique_brand_and_subs(marked unsubs and bounced).csv'
path_export = r'C:\Users\fajar\Documents\Python\Data\Request Data\DS Req\2024\27 Mar'
lead_brand = 'Karma Club'
dedup_duplicated = ['Email','Lead Brand','Lead Sub-Brand']


path_export_file = path_export+'\\'
filename = path_export_file+lead_brand+'.csv'

# %%
df = pd.read_csv(path_db, dtype='string', on_bad_lines='skip')
df.drop(columns='New Phone', inplace=True)
zoho_df = df.loc[df['Lead Brand'].str.contains(lead_brand, regex=True, flags=re.I)].copy()

zoho_df.reset_index(drop=True, inplace=True)
count_filter_awal = zoho_df.shape[0]

# mengisi kolom <NA> dengan value string 'empty' supaya mudah mengecek data member dan booking dengan isin
zoho_df.fillna('empty', inplace=True)
zoho_df
# Out:
#                      Record Id         Created Time Created Date First Name  \
# 0     zcrm_3584690000279341112  2021-04-26 23:32:33        empty      Barry
# 1     zcrm_3584690000279344185  2021-04-26 22:01:29        empty    Richard
# 2     zcrm_3584690000279374184  2021-04-26 21:05:02        empty      Steve
# 3     zcrm_3584690000279374305  2021-04-26 23:00:58        empty       Alex
# 4     zcrm_3584690000279377246  2021-04-26 20:35:05        empty      Wyatt
# ...                        ...                  ...          ...        ...
# 6225  zcrm_3584690000489144068  2024-03-23 10:57:28        empty   Anbumani
# 6226  zcrm_3584690000489154174  2024-03-24 16:32:24        empty      Kohei
# 6227  zcrm_3584690000489176297  2024-03-25 14:44:39        empty     Ronald
# 6228  zcrm_3584690000489176377  2024-03-25 15:12:08        empty    soeroso
# 6229  zcrm_3584690000489227335  2024-03-25 02:56:49        empty     Cecile
#
#         Last Name                              Email          Phone Mobile  \
# 0         Oakhill           barry@ironandearth.co.uk    07534455419  empty
# 1         Mathews               rmathews@optps.co.uk    07753457295  empty
# 2           White             stevew@bplglobal.co.uk     7912377697  empty
# 3         Diaconu            alex@brutonstreet.co.uk    07403128178  empty
# 4           Davis           wyattdavis@hotmail.co.uk    07757794676  empty
# ...           ...                                ...            ...    ...
# 6225  Karuppannan          karuppannan1945@gmail.com   +60176219543  empty
# 6226      Iwanaga            remi.i.k.0707@gmail.com    +6587576318  empty
# 6227     Williams  ronald@deluxehomeproperties.co.za   +27749093921  empty
# 6228     soewargo               fifi.yin@yahoo.co.id  +628123289061  empty
# 6229         Raye              cecilefraye@gmail.com   +33630841150  empty
#
#      Birthdate Year of Birth  ... Email Opt Out Opt In Do Not Contact  \
# 0        empty         empty  ...         false   true          false
# 1        empty         empty  ...         false   true          false
# 2        empty         empty  ...         false   true          false
# 3        empty         empty  ...         false   true          false
# 4        empty         empty  ...         false   true          false
# ...        ...           ...  ...           ...    ...            ...
# 6225     empty         empty  ...         false   true          false
# 6226     empty         empty  ...         false   true          false
# 6227     empty         empty  ...         false   true          false
# 6228     empty         empty  ...         false   true          false
# 6229     empty         empty  ...         false   true          false
#
#      Do Not Mail GDPR Compliant  \
# 0          false           true
# 1          false           true
# 2          false           true
# 3          false           true
# 4          false           true
# ...          ...            ...
# 6225       false          false
# 6226       false          false
# 6227       false          false
# 6228       false          false
# 6229       false           true
#
#                                                 Website     Contact Type  \
# 0      https://karmaclub.com/associate-membership/join/  Email and Phone
# 1      https://karmaclub.com/associate-membership/join/  Email and Phone
# 2      https://karmaclub.com/associate-membership/join/  Email and Phone
# 3      https://karmaclub.com/associate-membership/join/  Email and Phone
# 4      https://karmaclub.com/associate-membership/join/  Email and Phone
# ...                                                 ...              ...
# 6225          https://karmaclub.karmagroup.com/enquire/  Email and Phone
# 6226                  https://karmaclub.karmagroup.com/  Email and Phone
# 6227     https://karmaclub.karmagroup.com/destinations/  Email and Phone
# 6228  https://karmaclub.karmagroup.com/?_gl=1%2A38ar...  Email and Phone
# 6229     https://karmaclub.karmagroup.com/destinations/  Email and Phone
#
#      Unsubscribed Status Bounced Status Unsubs/Bounced
# 0                    Yes             No            Yes
# 1                    Yes             No            Yes
# 2                    Yes             No            Yes
# 3                    Yes             No            Yes
# 4                    Yes             No            Yes
# ...                  ...            ...            ...
# 6225                 Yes             No            Yes
# 6226                  No             No             No
# 6227                 Yes             No            Yes
# 6228                 Yes             No            Yes
# 6229                  No             No             No
#
# [6230 rows x 39 columns]

# %%
zoho_df[['Lead Brand', 'Lead Sub-Brand']].loc[zoho_df['Email'] == 'natraj.sharma1@gmail.com']
# Out:
# Empty DataFrame
# Columns: [Lead Brand, Lead Sub-Brand]
# Index: []

# %%
zoho_df.groupby('Lead Brand').count()
# Out:
#                Record Id  Created Time  Created Date  First Name  Last Name  \
# Lead Brand
# Karma Club          1727          1727          1727        1727       1727
# Karma Club 21       4153          4153          4153        4153       4153
# Karma Club 22        350           350           350         350        350
#
#                Email  Phone  Mobile  Birthdate  Year of Birth  ...  \
# Lead Brand                                                     ...
# Karma Club      1727   1727    1727       1727           1727  ...
# Karma Club 21   4153   4153    4153       4153           4153  ...
# Karma Club 22    350    350     350        350            350  ...
#
#                Email Opt Out  Opt In  Do Not Contact  Do Not Mail  \
# Lead Brand
# Karma Club              1727    1727            1727         1727
# Karma Club 21           4153    4153            4153         4153
# Karma Club 22            350     350             350          350
#
#                GDPR Compliant  Website  Contact Type  Unsubscribed Status  \
# Lead Brand
# Karma Club               1727     1727          1727                 1727
# Karma Club 21            4153     4153          4153                 4153
# Karma Club 22             350      350           350                  350
#
#                Bounced Status  Unsubs/Bounced
# Lead Brand
# Karma Club               1727            1727
# Karma Club 21            4153            4153
# Karma Club 22             350             350
#
# [3 rows x 38 columns]

# %%
zoho_df.columns
# Out:
# Index(['Record Id', 'Created Time', 'Created Date', 'First Name', 'Last Name',
#        'Email', 'Phone', 'Mobile', 'Birthdate', 'Year of Birth', 'Street',
#        'Street2', 'City', 'State', 'Country', 'Nationality', 'Booking Status',
#        'BookRef', 'Departure Date', 'Arrival Date', 'Card Type',
#        'Marital Status', 'Lead Brand', 'Lead Sub-Brand', 'Lead Source',
#        'Lead Locations', 'Lead Source Description', 'Lead Regions',
#        'Lead Status', 'Email Opt Out', 'Opt In', 'Do Not Contact',
#        'Do Not Mail', 'GDPR Compliant', 'Website', 'Contact Type',
#        'Unsubscribed Status', 'Bounced Status', 'Unsubs/Bounced'],
#       dtype='object')

# %%
path = r'G:\.shortcut-targets-by-id\0B_d3smBjzo04eXpvS1NXTWF2RVE\_BOOKING\Booking By Year\FlyBuy Booking Data (BGAU & BGID & KE).xlsx'
df_booking = pd.read_excel(path, dtype='string', sheet_name='BOOKING_BGAU_BGID_KE')

path = r'G:\.shortcut-targets-by-id\0B_d3smBjzo04UUNBME5GOVhoMjA\_ODYSSEY\Phone Members.xlsx'
df_phone = pd.read_excel(path, dtype='string', sheet_name='Sheet1')

path = r'G:\.shortcut-targets-by-id\0B_d3smBjzo04UUNBME5GOVhoMjA\_ODYSSEY\Email Members.xlsx'
df_email = pd.read_excel(path, dtype='string', sheet_name='Sheet1')

# %% [markdown]
# # ====================== Awal Filter Umum ======================

# %%
# data phone, mobile dam email member yang ada di master data (wash member)

m.clean_number(zoho_df, 'Phone')
m.clean_number(zoho_df, 'Mobile')
m.replace_not_valid_to_empty(zoho_df, 'Phone')
m.replace_not_valid_to_empty(zoho_df, 'Mobile')
zoho_df['Email'] = m.lowercase(zoho_df, 'Email')
m.clean_space(zoho_df, 'Email')
m.clean_not_valid_email_format(zoho_df, 'Email')

m.clean_number(df_booking, 'Phone1')
m.clean_number(df_booking, 'Mobile')
df_booking['Email'] = m.lowercase(df_booking, 'Email')
m.clean_space(df_booking, 'Email')
m.clean_not_valid_email_format(df_booking, 'Email')

m.clean_number(df_phone, 'Mobile')

df_email['Email'] = m.lowercase(df_email, 'Email')
m.clean_space(df_email, 'Email')
m.clean_not_valid_email_format(df_email, 'Email')
# Out:
# 'Email'

# %%
zoho_df.loc[
    (zoho_df['Phone'] == 'empty') & (zoho_df['Mobile'] != 'empty'), 
    'Phone'] = zoho_df['Mobile']
zoho_df.loc[zoho_df['Phone'] == zoho_df['Mobile'],'Mobile'] = 'empty'

# %%
count_deleted_wrong_format = m.delete_email_wrong_format(zoho_df, 'Email')
count_after_deleted_wrong_format = zoho_df.shape[0]

# %% [markdown]
# # ====================== Akhir Filter Umum ======================

# %%
# # hitung jumlah duplicate
# count_duplicate_general = zoho_df.loc[zoho_df.duplicated(subset=['Phone','Mobile','Email'])].shape[0]

# zoho_df.loc[zoho_df.duplicated(subset=['Phone','Mobile','Email'])]

count_duplicate_general = zoho_df.loc[zoho_df.duplicated(subset=dedup_duplicated)].shape[0]

zoho_df.loc[zoho_df.duplicated(subset=dedup_duplicated)]
# Out:
#                      Record Id         Created Time Created Date First Name  \
# 3045  zcrm_3584690000330531518  2021-12-11 01:37:24        empty       Paul
# 3055  zcrm_3584690000331715014  2021-12-16 00:53:32        empty     Kerrie
# 3143  zcrm_3584690000339140002  2022-01-12 02:26:53        empty     Ashley
# 3157  zcrm_3584690000339510717  2022-01-15 18:17:53        empty      David
# 3998  zcrm_3584690000438611283  2023-04-04 11:55:09   2023-04-01      Diane
#
#         Last Name                          Email         Phone        Mobile  \
# 3045        James     paul.james66@hotmail.co.uk         empty  447846110422
# 3055  Henshaw-Cox     kerrie.henshaw@yahoo.co.uk         empty  447557541093
# 3143       Davies      big_davies4@hotmail.co.uk         empty  447584654865
# 3157    Kingsland      kingsland.david@gmail.com  447521448683         empty
# 3998       Mooney  diane_mooney_1963@yahoo.co.uk  447367964898         empty
#
#      Birthdate Year of Birth  ... Email Opt Out Opt In Do Not Contact  \
# 3045     empty         empty  ...         false   true          false
# 3055     empty         empty  ...         false   true          false
# 3143     empty         empty  ...         false   true          false
# 3157     empty         empty  ...         false   true          false
# 3998     empty         empty  ...         false   true          false
#
#      Do Not Mail GDPR Compliant  \
# 3045       false           true
# 3055       false           true
# 3143       false           true
# 3157       false           true
# 3998       false           true
#
#                                                 Website     Contact Type  \
# 3045                https://karmaclub.com/destinations/  Email and Phone
# 3055                https://karmaclub.com/destinations/  Email and Phone
# 3143                https://karmaclub.com/destinations/  Email and Phone
# 3157                        https://karmaclub.com/join/  Email and Phone
# 3998  https://karmaclub.karmagroup.com/cornwall-livi...  Email and Phone
#
#      Unsubscribed Status Bounced Status Unsubs/Bounced
# 3045                 Yes             No            Yes
# 3055                  No            Yes            Yes
# 3143                 Yes             No            Yes
# 3157                 Yes             No            Yes
# 3998                  No             No             No
#
# [5 rows x 39 columns]

# %%
# zoho_df.drop_duplicates(subset=['Phone','Mobile','Email'], inplace=True)
zoho_df.drop_duplicates(subset=dedup_duplicated, inplace=True)
zoho_df.reset_index(drop=True, inplace=True)

# hitung jumlah setelah value duplicate dihapus
count_after_dedup_duplicate = zoho_df.shape[0]

zoho_df
# Out:
#                      Record Id         Created Time Created Date First Name  \
# 0     zcrm_3584690000279341112  2021-04-26 23:32:33        empty      Barry
# 1     zcrm_3584690000279344185  2021-04-26 22:01:29        empty    Richard
# 2     zcrm_3584690000279374184  2021-04-26 21:05:02        empty      Steve
# 3     zcrm_3584690000279374305  2021-04-26 23:00:58        empty       Alex
# 4     zcrm_3584690000279377246  2021-04-26 20:35:05        empty      Wyatt
# ...                        ...                  ...          ...        ...
# 6220  zcrm_3584690000489144068  2024-03-23 10:57:28        empty   Anbumani
# 6221  zcrm_3584690000489154174  2024-03-24 16:32:24        empty      Kohei
# 6222  zcrm_3584690000489176297  2024-03-25 14:44:39        empty     Ronald
# 6223  zcrm_3584690000489176377  2024-03-25 15:12:08        empty    soeroso
# 6224  zcrm_3584690000489227335  2024-03-25 02:56:49        empty     Cecile
#
#         Last Name                              Email         Phone Mobile  \
# 0         Oakhill           barry@ironandearth.co.uk   07534455419  empty
# 1         Mathews               rmathews@optps.co.uk   07753457295  empty
# 2           White             stevew@bplglobal.co.uk    7912377697  empty
# 3         Diaconu            alex@brutonstreet.co.uk   07403128178  empty
# 4           Davis           wyattdavis@hotmail.co.uk   07757794676  empty
# ...           ...                                ...           ...    ...
# 6220  Karuppannan          karuppannan1945@gmail.com   60176219543  empty
# 6221      Iwanaga            remi.i.k.0707@gmail.com    6587576318  empty
# 6222     Williams  ronald@deluxehomeproperties.co.za   27749093921  empty
# 6223     soewargo               fifi.yin@yahoo.co.id  628123289061  empty
# 6224         Raye              cecilefraye@gmail.com   33630841150  empty
#
#      Birthdate Year of Birth  ... Email Opt Out Opt In Do Not Contact  \
# 0        empty         empty  ...         false   true          false
# 1        empty         empty  ...         false   true          false
# 2        empty         empty  ...         false   true          false
# 3        empty         empty  ...         false   true          false
# 4        empty         empty  ...         false   true          false
# ...        ...           ...  ...           ...    ...            ...
# 6220     empty         empty  ...         false   true          false
# 6221     empty         empty  ...         false   true          false
# 6222     empty         empty  ...         false   true          false
# 6223     empty         empty  ...         false   true          false
# 6224     empty         empty  ...         false   true          false
#
#      Do Not Mail GDPR Compliant  \
# 0          false           true
# 1          false           true
# 2          false           true
# 3          false           true
# 4          false           true
# ...          ...            ...
# 6220       false          false
# 6221       false          false
# 6222       false          false
# 6223       false          false
# 6224       false           true
#
#                                                 Website     Contact Type  \
# 0      https://karmaclub.com/associate-membership/join/  Email and Phone
# 1      https://karmaclub.com/associate-membership/join/  Email and Phone
# 2      https://karmaclub.com/associate-membership/join/  Email and Phone
# 3      https://karmaclub.com/associate-membership/join/  Email and Phone
# 4      https://karmaclub.com/associate-membership/join/  Email and Phone
# ...                                                 ...              ...
# 6220          https://karmaclub.karmagroup.com/enquire/  Email and Phone
# 6221                  https://karmaclub.karmagroup.com/  Email and Phone
# 6222     https://karmaclub.karmagroup.com/destinations/  Email and Phone
# 6223  https://karmaclub.karmagroup.com/?_gl=1%2A38ar...  Email and Phone
# 6224     https://karmaclub.karmagroup.com/destinations/  Email and Phone
#
#      Unsubscribed Status Bounced Status Unsubs/Bounced
# 0                    Yes             No            Yes
# 1                    Yes             No            Yes
# 2                    Yes             No            Yes
# 3                    Yes             No            Yes
# 4                    Yes             No            Yes
# ...                  ...            ...            ...
# 6220                 Yes             No            Yes
# 6221                  No             No             No
# 6222                 Yes             No            Yes
# 6223                 Yes             No            Yes
# 6224                  No             No             No
#
# [6225 rows x 39 columns]

# %%
# Cek leads test
test_leads = zoho_df.loc[
    
        zoho_df['Email'].str.contains('^test@', flags=re.I, regex=True) |
        zoho_df['Email'].str.contains('\+test', flags=re.I, regex=True) |
    
        zoho_df['First Name'].str.contains('^test$', flags=re.I, regex=True) |
        zoho_df['Last Name'].str.contains('^test$', flags=re.I, regex=True) |

        zoho_df['First Name'].str.contains('test 1', flags=re.I, regex=True) |
        zoho_df['Last Name'].str.contains('test 2', flags=re.I, regex=True)|
        zoho_df['First Name'].str.contains('test1', flags=re.I, regex=True) |
        zoho_df['Last Name'].str.contains('test2', flags=re.I, regex=True)|

        zoho_df['First Name'].str.contains(' test ', flags=re.I, regex=True) | 
        zoho_df['Last Name'].str.contains(' test ', flags=re.I, regex=True) | 
        zoho_df['Last Name'].str.contains(' test$', flags=re.I, regex=True)
    ]

count_leads_test = test_leads.shape[0]

# test_leads.to_excel(r'C:\Users\fajar\Documents\Python\Data\test_leads_2.xlsx', index=False)
test_leads
# Out:
# Empty DataFrame
# Columns: [Record Id, Created Time, Created Date, First Name, Last Name, Email, Phone, Mobile, Birthdate, Year of Birth, Street, Street2, City, State, Country, Nationality, Booking Status, BookRef, Departure Date, Arrival Date, Card Type, Marital Status, Lead Brand, Lead Sub-Brand, Lead Source, Lead Locations, Lead Source Description, Lead Regions, Lead Status, Email Opt Out, Opt In, Do Not Contact, Do Not Mail, GDPR Compliant, Website, Contact Type, Unsubscribed Status, Bounced Status, Unsubs/Bounced]
# Index: []
#
# [0 rows x 39 columns]

# %%
zoho_df.drop(test_leads.index, inplace=True)
zoho_df.reset_index(drop=True, inplace=True)

count_after_dedup_test = zoho_df.shape[0]

# %%
dnm_leads = zoho_df.loc[(zoho_df['Do Not Mail'] == 'true') | (zoho_df['Do Not Contact'] == 'true')]
count_dnm = dnm_leads.shape[0]

# %%
zoho_df.drop(dnm_leads.index, inplace=True)
zoho_df.reset_index(drop=True, inplace=True)

count_after_dedup_dnm = zoho_df.shape[0]

# %%
# Cek Email Karma
email_karma = m.find_karma(zoho_df, 'Email')
count_email_karma = email_karma.shape[0]
# email_OTA.to_excel(r'C:\Users\fajar\Documents\Python\Data\email_OTA.xlsx', index=False)

email_karma
# Out:
#                      Record Id         Created Time Created Date First Name  \
# 3379  zcrm_3584690000353117429  2022-03-22 17:21:38        empty  Ekaterina
#
#       Last Name                           Email        Phone Mobile Birthdate  \
# 3379  Khalikova  concierge.europe@karmaclub.com  79851463599  empty     empty
#
#      Year of Birth  ... Email Opt Out Opt In Do Not Contact Do Not Mail  \
# 3379         empty  ...         false   true          false       false
#
#      GDPR Compliant                      Website     Contact Type  \
# 3379           true  https://karmaclub.com/join/  Email and Phone
#
#      Unsubscribed Status Bounced Status Unsubs/Bounced
# 3379                 Yes             No            Yes
#
# [1 rows x 39 columns]

# %%
# delete email Karma
count_after_clean_karma = m.delete_karma(zoho_df, 'Email')
# zoho_df.to_excel(r'C:\Users\fajar\Documents\Python\Data\after_clean_OTA.xlsx', index=False)

zoho_df
# Out:
#                      Record Id         Created Time Created Date First Name  \
# 0     zcrm_3584690000279341112  2021-04-26 23:32:33        empty      Barry
# 1     zcrm_3584690000279344185  2021-04-26 22:01:29        empty    Richard
# 2     zcrm_3584690000279374184  2021-04-26 21:05:02        empty      Steve
# 3     zcrm_3584690000279374305  2021-04-26 23:00:58        empty       Alex
# 4     zcrm_3584690000279377246  2021-04-26 20:35:05        empty      Wyatt
# ...                        ...                  ...          ...        ...
# 6218  zcrm_3584690000489144068  2024-03-23 10:57:28        empty   Anbumani
# 6219  zcrm_3584690000489154174  2024-03-24 16:32:24        empty      Kohei
# 6220  zcrm_3584690000489176297  2024-03-25 14:44:39        empty     Ronald
# 6221  zcrm_3584690000489176377  2024-03-25 15:12:08        empty    soeroso
# 6222  zcrm_3584690000489227335  2024-03-25 02:56:49        empty     Cecile
#
#         Last Name                              Email         Phone Mobile  \
# 0         Oakhill           barry@ironandearth.co.uk   07534455419  empty
# 1         Mathews               rmathews@optps.co.uk   07753457295  empty
# 2           White             stevew@bplglobal.co.uk    7912377697  empty
# 3         Diaconu            alex@brutonstreet.co.uk   07403128178  empty
# 4           Davis           wyattdavis@hotmail.co.uk   07757794676  empty
# ...           ...                                ...           ...    ...
# 6218  Karuppannan          karuppannan1945@gmail.com   60176219543  empty
# 6219      Iwanaga            remi.i.k.0707@gmail.com    6587576318  empty
# 6220     Williams  ronald@deluxehomeproperties.co.za   27749093921  empty
# 6221     soewargo               fifi.yin@yahoo.co.id  628123289061  empty
# 6222         Raye              cecilefraye@gmail.com   33630841150  empty
#
#      Birthdate Year of Birth  ... Email Opt Out Opt In Do Not Contact  \
# 0        empty         empty  ...         false   true          false
# 1        empty         empty  ...         false   true          false
# 2        empty         empty  ...         false   true          false
# 3        empty         empty  ...         false   true          false
# 4        empty         empty  ...         false   true          false
# ...        ...           ...  ...           ...    ...            ...
# 6218     empty         empty  ...         false   true          false
# 6219     empty         empty  ...         false   true          false
# 6220     empty         empty  ...         false   true          false
# 6221     empty         empty  ...         false   true          false
# 6222     empty         empty  ...         false   true          false
#
#      Do Not Mail GDPR Compliant  \
# 0          false           true
# 1          false           true
# 2          false           true
# 3          false           true
# 4          false           true
# ...          ...            ...
# 6218       false          false
# 6219       false          false
# 6220       false          false
# 6221       false          false
# 6222       false           true
#
#                                                 Website     Contact Type  \
# 0      https://karmaclub.com/associate-membership/join/  Email and Phone
# 1      https://karmaclub.com/associate-membership/join/  Email and Phone
# 2      https://karmaclub.com/associate-membership/join/  Email and Phone
# 3      https://karmaclub.com/associate-membership/join/  Email and Phone
# 4      https://karmaclub.com/associate-membership/join/  Email and Phone
# ...                                                 ...              ...
# 6218          https://karmaclub.karmagroup.com/enquire/  Email and Phone
# 6219                  https://karmaclub.karmagroup.com/  Email and Phone
# 6220     https://karmaclub.karmagroup.com/destinations/  Email and Phone
# 6221  https://karmaclub.karmagroup.com/?_gl=1%2A38ar...  Email and Phone
# 6222     https://karmaclub.karmagroup.com/destinations/  Email and Phone
#
#      Unsubscribed Status Bounced Status Unsubs/Bounced
# 0                    Yes             No            Yes
# 1                    Yes             No            Yes
# 2                    Yes             No            Yes
# 3                    Yes             No            Yes
# 4                    Yes             No            Yes
# ...                  ...            ...            ...
# 6218                 Yes             No            Yes
# 6219                  No             No             No
# 6220                 Yes             No            Yes
# 6221                 Yes             No            Yes
# 6222                  No             No             No
#
# [6223 rows x 39 columns]

# %%
find_member_booking = zoho_df.copy()

find_member_booking.loc[find_member_booking['Phone'].isin(df_booking['Phone1']), 'Same Value Find'] = 'Booking-Phone1'
find_member_booking.loc[find_member_booking['Phone'].isin(df_booking['Mobile']), 'Same Value Find'] = 'Booking-Mobile'
find_member_booking.loc[find_member_booking['Mobile'].isin(df_booking['Phone1']), 'Same Value Find'] = 'Booking-Phone1' 
find_member_booking.loc[find_member_booking['Mobile'].isin(df_booking['Mobile']), 'Same Value Find'] = 'Booking-Mobile'
find_member_booking.loc[find_member_booking['Email'].isin(df_booking['Email']), 'Same Value Find'] = 'Booking-Email'

find_member_booking.loc[find_member_booking['Phone'].isin(df_phone['Mobile']), 'Same Value Find'] = 'Member-Mobile' 
find_member_booking.loc[find_member_booking['Mobile'].isin(df_phone['Mobile']), 'Same Value Find'] = 'Member-Mobile'

find_member_booking.loc[find_member_booking['Email'].isin(df_email['Email']), 'Same Value Find'] = 'Member-Email'

find_member_booking.drop(find_member_booking.loc[find_member_booking['Same Value Find'].isna()].index, inplace=True)

count_booking_dedup = find_member_booking.loc[find_member_booking['Same Value Find'].str.contains('Booking', flags=re.I, regex=True)].shape[0]
count_member_dedup = find_member_booking.loc[find_member_booking['Same Value Find'].str.contains('Member', flags=re.I, regex=True)].shape[0]

find_member_booking.replace('empty', '', inplace=True)
# find_member_booking.to_csv(r'C:\Users\fajar\Documents\Python\Data\booking-member-dedup.csv', index=False)
# find_member_booking.to_excel(r'C:\Users\fajar\Documents\Python\Data\booking-member-dedup.xlsx', index=False)

#find_member_booking.loc[find_member_booking['Same Value Find'] == 'Booking-Phone1']

# %%
# data phone, mobile dam email member yang ada di master data 
count_wash_member = zoho_df.loc[
    zoho_df['Phone'].isin(df_booking['Phone1']) | 
    zoho_df['Phone'].isin(df_booking['Mobile']) |
    zoho_df['Mobile'].isin(df_booking['Phone1']) | 
    zoho_df['Mobile'].isin(df_booking['Mobile']) |
    zoho_df['Email'].isin(df_booking['Email'])| 

    zoho_df['Phone'].isin(df_phone['Mobile']) | 
    zoho_df['Mobile'].isin(df_phone['Mobile']) |

    zoho_df['Email'].isin(df_email['Email'])

].shape[0]

zoho_df.drop(zoho_df.loc[
    zoho_df['Phone'].isin(df_booking['Phone1']) | 
    zoho_df['Phone'].isin(df_booking['Mobile']) |
    zoho_df['Mobile'].isin(df_booking['Phone1']) | 
    zoho_df['Mobile'].isin(df_booking['Mobile']) |
    zoho_df['Email'].isin(df_booking['Email']) |
    
    zoho_df['Phone'].isin(df_phone['Mobile']) | 
    zoho_df['Mobile'].isin(df_phone['Mobile']) |

    zoho_df['Email'].isin(df_email['Email'])

    ].index, inplace=True)
    
zoho_df.reset_index(drop=True, inplace=True)

count_after_wash_member = zoho_df.shape[0]

# %%
count_email_only = zoho_df.loc[(zoho_df['Email'] != 'empty') & ((zoho_df['Phone'] == 'empty') & (zoho_df['Mobile'] == 'empty'))].shape[0]
count_phone_only = zoho_df.loc[(zoho_df['Email'] == 'empty') & ((zoho_df['Phone'] != 'empty') | (zoho_df['Mobile'] != 'empty'))].shape[0]
count_email_and_phone = zoho_df.loc[(zoho_df['Email'] != 'empty') & ((zoho_df['Phone'] != 'empty') | (zoho_df['Mobile'] != 'empty'))].shape[0]

count_blank = zoho_df.loc[(zoho_df['Email'] =='empty') & (zoho_df['Phone']=='empty') & (zoho_df['Mobile']=='empty')].shape[0]

# zoho_df.loc[(zoho_df['Email'] =='empty') & (zoho_df['Phone']=='empty') & (zoho_df['Mobile']=='empty')].to_excel(r'C:\Users\fajar\Documents\Python\Data\blank_data.xlsx', index=False)

zoho_df.loc[(zoho_df['Email'] != 'empty') & ((zoho_df['Phone'] == 'empty') & (zoho_df['Mobile'] == 'empty')), 'Contact Type'] = 'Email Only'
zoho_df.loc[(zoho_df['Email'] == 'empty') & ((zoho_df['Phone'] != 'empty') | (zoho_df['Mobile'] != 'empty')), 'Contact Type'] = 'Phone Only'
zoho_df.loc[(zoho_df['Email'] != 'empty') & ((zoho_df['Phone'] != 'empty') | (zoho_df['Mobile'] != 'empty')), 'Contact Type'] = 'Email and Phone'

zoho_df.drop(zoho_df.loc[(zoho_df['Email'] =='empty') & (zoho_df['Phone']=='empty') & (zoho_df['Mobile']=='empty')].index, inplace=True)
zoho_df.reset_index(drop=True, inplace=True)

count_after_wash_blank = zoho_df.shape[0]

# %%
arr_dedup = [count_deleted_wrong_format, count_duplicate_general, count_leads_test, count_dnm, count_email_karma, count_blank]
count_sum_dedup = sum(arr_dedup)
count_sum_dedup
# Out:
# 7

# %%
print("==========================================================")
print("Summary")
print("==========================================================")
print("Jumlah Leads Awal : "+str(count_filter_awal))
print("Jumlah Format Email Salah : "+str(count_deleted_wrong_format))
print("Jumlah Setelah Clean Format Email Salah : "+str(count_after_deleted_wrong_format))
print("Jumlah Duplicate (Email, Lead Brand dan Lead Sub-Brand) : "+str(count_duplicate_general))
print("Jumlah Setelah Clean Duplicate : "+str(count_after_dedup_duplicate))
print("Jumlah Lead Test : "+str(count_leads_test))
print("Jumlah Setelah Clean Lead Test : "+str(count_after_dedup_test))
print("Jumlah Lead Do Not Mail : "+str(count_dnm))
print("Jumlah Setelah Clean Lead Do Not Mail : "+str(count_after_dedup_dnm))
print("Jumlah Email Karma : "+str(count_email_karma))
print("Jumlah Setelah Clean Email Karma : "+str(count_after_clean_karma))
print("Jumlah Wash Member : "+str(count_member_dedup))
print("Jumlah Wash Booking : "+str(count_booking_dedup))
print("Jumlah Setelah Wash Member : "+str(count_after_wash_member))
print("Jumlah Phone Email Blank (Setelah phone yang tidak valid dihapus) : "+str(count_blank))
print("Jumlah Setelah Wash Phone Email Blank : "+str(count_after_wash_blank))
print("==========================================================")
print("Contact Type")
print("==========================================================")
print("Jumlah Email Only : "+str(count_email_only))
print("Jumlah Phone Only : "+str(count_phone_only))
print("Jumlah Email dan Phone : "+str(count_email_and_phone))
# Out:
# ==========================================================
# Summary
# ==========================================================
# Jumlah Leads Awal : 6230
# Jumlah Format Email Salah : 0
# Jumlah Setelah Clean Format Email Salah : 6230
# Jumlah Duplicate (Email, Lead Brand dan Lead Sub-Brand) : 5
# Jumlah Setelah Clean Duplicate : 6225
# Jumlah Lead Test : 0
# Jumlah Setelah Clean Lead Test : 6225
# Jumlah Lead Do Not Mail : 1
# Jumlah Setelah Clean Lead Do Not Mail : 6224
# Jumlah Email Karma : 1
# Jumlah Setelah Clean Email Karma : 6223
# Jumlah Wash Member : 3606
# Jumlah Wash Booking : 31
# Jumlah Setelah Wash Member : 2586
# Jumlah Phone Email Blank (Setelah phone yang tidak valid dihapus) : 0
# Jumlah Setelah Wash Phone Email Blank : 2586
# ==========================================================
# Contact Type
# ==========================================================
# Jumlah Email Only : 1216
# Jumlah Phone Only : 0
# Jumlah Email dan Phone : 1370

# %%
print("==========================================================")
print("Summary Report")
print("==========================================================")
print("Jumlah Data Awal : "+str(count_filter_awal))
print("Jumlah Wash Dedup : "+str(count_sum_dedup))
print("Jumlah Wash Member : "+str(count_member_dedup))
print("Jumlah Wash Booking : "+str(count_booking_dedup))
print("Jumlah Data Akhir : "+str(count_after_wash_blank))
# Out:
# ==========================================================
# Summary Report
# ==========================================================
# Jumlah Data Awal : 6230
# Jumlah Wash Dedup : 7
# Jumlah Wash Member : 3606
# Jumlah Wash Booking : 31
# Jumlah Data Akhir : 2586

# %%
zoho_df.replace('empty', '', inplace=True, regex=True)

# %%
if zoho_df.shape[0] > 500000:
    row_split = 250000
    file_name = lead_brand
    file_type = 'csv'

    m.split_file(zoho_df, row_split, file_name, file_type, path_export_file)
else:
    zoho_df.to_csv(filename, index=False)
