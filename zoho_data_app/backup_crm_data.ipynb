# %%
import main_module as m
import zoho_filter_module as fil
import pandas as pd
import re
import numpy as np

# %load_ext autoreload
# %autoreload 2

dir_path = r'C:\Users\fajar\Documents\Python\Data\Zoho_Backup'
file_name = '\Leads_'

cols = ['Record Id',	
'Created Time',
'Created Date',	
'First Name',	
'Last Name',	
'Email',	
'PHONE',	
'Mobile',	
'Birthdate',	
'Year of Birth',
'Street',	
'Street2',	
'City',	
'State',	
'Country',	
'Nationality',
'Booking Status', 
'BookRef',
'Departure Date',	
'Arrival Date',	
'Card Type',	
'Marital Status',	
'Lead Brand',	
'Lead Sub-Brand',	
'Lead Source',	
'Lead Locations',	
'Lead Source Description',	
'Lead Regions',
'Lead Status',
'Email Opt Out',	
'Opt In',
'Do Not Contact',
'Do Not Mail']

# %%
df = m.load_data_multiple_all(dir_path, file_name)
count_data_awal = df.shape[0]
df.shape[0]
df.dtypes
df
# Out:
#                         Record Id             Lead Owner.id Company  \
# 0        zcrm_3584690000000404058  zcrm_3584690000000180021    <NA>
# 1        zcrm_3584690000000404059  zcrm_3584690000000180021    <NA>
# 2        zcrm_3584690000000404060  zcrm_3584690000000180021    <NA>
# 3        zcrm_3584690000000404065  zcrm_3584690000000180021    <NA>
# 4        zcrm_3584690000000404068  zcrm_3584690000002265001    <NA>
# ...                           ...                       ...     ...
# 4705476  zcrm_3584690000472560346  zcrm_3584690000000180021    <NA>
# 4705477  zcrm_3584690000472560347  zcrm_3584690000000180021    <NA>
# 4705478  zcrm_3584690000472560348  zcrm_3584690000000180021    <NA>
# 4705479  zcrm_3584690000472561001  zcrm_3584690000000180021    <NA>
# 4705480  zcrm_3584690000472568001  zcrm_3584690000000180021    <NA>
#
#         First Name  Last Name Title                       Email  \
# 0         Nicholas       Wood  <NA>  1230woodnicholas@gmail.com
# ...

# %%
zoho_filter = fil.user_backup_crm(df)
zoho_df = df.loc[zoho_filter].copy() # menggunakan copy untuk menghindari setting copy warning
zoho_df.reset_index(drop=True, inplace=True)
count_filter_awal = zoho_df.shape[0]

# zoho_df.to_excel(r'C:\Users\fajar\Documents\Python\Data\test_leads.xlsx', index=False)
# mengisi kolom <NA> dengan value string 'empty' supaya mudah mengecek data member dan booking dengan isin

# zoho_df.fillna('empty', inplace=True)
zoho_df
# Out:
#                        Record Id             Lead Owner.id Company First Name  \
# 0       zcrm_3584690000000404602  zcrm_3584690000000180021    <NA>   Frederic
# 1       zcrm_3584690000000409050  zcrm_3584690000000180021    <NA>   Takenori
# 2       zcrm_3584690000000414023  zcrm_3584690000000180021    <NA>      Conor
# 3       zcrm_3584690000000414030  zcrm_3584690000000180021    <NA>        Ian
# 4       zcrm_3584690000000417044  zcrm_3584690000000180021    <NA>    Edwards
# ...                          ...                       ...     ...        ...
# 621128  zcrm_3584690000472560345  zcrm_3584690000000180021    <NA>         종규
# 621129  zcrm_3584690000472560346  zcrm_3584690000000180021    <NA>         인근
# 621130  zcrm_3584690000472560347  zcrm_3584690000000180021    <NA>         희연
# 621131  zcrm_3584690000472560348  zcrm_3584690000000180021    <NA>          김
# 621132  zcrm_3584690000472561001  zcrm_3584690000000180021    <NA>       Dani
#
# ...

# %%
zoho_df.groupby('Lead Brand').count()
# Out:
#                      Record Id  Lead Owner.id  Company  First Name  Last Name  \
# Lead Brand
# Karma Group              58814          58814     5561       43719      46280
# Karma Resorts           300133         300133     3782      262426     281081
# Timeshare Marketing     262186         262186        4      257041     121141
#
#                      Title   Email   Phone  Fax  Mobile  ...  \
# Lead Brand                                               ...
# Karma Group           4901   55169   31557    0    3850  ...
# Karma Resorts         3409  239309  224195    0   35166  ...
# Timeshare Marketing  10457  223291  228024    0   26114  ...
#
#                      Is this your first time to Vietnam?  \
# Lead Brand
# Karma Group                                            0
# Karma Resorts                                          0
# Timeshare Marketing                                    0
#
#                      Which hotel are you staying in?  \
# Lead Brand
# ...

# %%
zoho_df.to_csv(r'C:\Users\fajar\Documents\Python\Data\Master Data Backup\CRM\crm_all_column.csv', index=False, encoding='utf-8')

# %%
zoho_df_new_col = zoho_df.reindex(columns=cols)
zoho_df_new_col.to_excel(r'C:\Users\fajar\Documents\Python\Data\Master Data Backup\CRM\crm_spec_column.xlsx', index=False)
