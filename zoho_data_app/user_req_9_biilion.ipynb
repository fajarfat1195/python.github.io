# %%
import main_module as m
import zoho_filter_module as fil
import pandas as pd
import re
import numpy as np

# %load_ext autoreload
# %autoreload 2

# %%
path = r'C:\Users\fajar\Documents\Python\Data\Zoho_Backup\2020-2024\backup.csv'
df = pd.read_csv(path, dtype='string', on_bad_lines='skip')
count_data_awal = df.shape[0]
df.shape[0]
# Out:
# 9965985

# %%
path = r'G:\.shortcut-targets-by-id\0B_d3smBjzo04eXpvS1NXTWF2RVE\_BOOKING\Booking By Year\FlyBuy Booking Data (BGAU & BGID & KE).xlsx'
df_booking = pd.read_excel(path, dtype='string', sheet_name='BOOKING_BGAU_BGID_KE')

path = r'G:\.shortcut-targets-by-id\0B_d3smBjzo04UUNBME5GOVhoMjA\_ODYSSEY\Phone Members.xlsx'
df_phone = pd.read_excel(path, dtype='string', sheet_name='Sheet1')

path = r'G:\.shortcut-targets-by-id\0B_d3smBjzo04UUNBME5GOVhoMjA\_ODYSSEY\Email Members.xlsx'
df_email = pd.read_excel(path, dtype='string', sheet_name='Sheet1')

# %%
path = r'C:\Users\fajar\Documents\Python\Data\Unsubs\all_unsubs_master.xlsx'
df_unsubs = pd.read_excel(path, sheet_name='Sheet1')

path = r'C:\Users\fajar\Documents\Python\Data\Debounce\all_bounce_master.xlsx'
df_bounce = pd.read_excel(path, sheet_name='Sheet1')

path = r'C:\Users\fajar\Documents\Python\Data\Member Data\kce_vp\list-subscribers-KCE.csv'
df_kce = pd.read_csv(path, dtype='string')

# %%
df_kce.rename(columns={'EMAIL': 'Email'}, inplace=True)
df_kce
# Out:
#          SERVICING_OFFICE      BATCH   NUMBER        KARMA_CLUB_PROGRAM  \
# 0      KC EXPERIENCE Bali  NONINDIA1  1000458               KARMA SALAK
# 1      KC EXPERIENCE Bali  NONINDIA1  1001045               KARMA SALAK
# 2      KC EXPERIENCE Bali  NONINDIA1  1002916               KARMA SALAK
# 3      KC EXPERIENCE Bali  NONINDIA1  1034469  KARMA SALAK; KARMA SALAK
# 4      KC EXPERIENCE Bali  NONINDIA1  1048405              KARMA MERAPI
# ...                   ...        ...      ...                       ...
# 62644  KC EXPERIENCE Bali  NONINDIA4  1171609       JIMBARAN SALES DECK
# 62645  KC EXPERIENCE Bali  NONINDIA4  1171596     PETITENGET SALES DECK
# 62646  KC EXPERIENCE Bali  NONINDIA4  1170751       JIMBARAN SALES DECK
# 62647  KC EXPERIENCE Bali  NONINDIA4  1171248     PETITENGET SALES DECK
# 62648  KC EXPERIENCE Bali  NONINDIA4  1171247       JIMBARAN SALES DECK
#
#        OTHER_OWNERS         PRIMARY_OWNER  EXPIRYDATE COMMENCE_DATE  \
# 0      David  Salim           David Salim  19/11/2023    19/11/2022
# 1              <NA>        Nobby Suhendra  12/11/2023    12/11/2022
# 2              <NA>           Tjhie Fandi  17/09/2023    17/09/2022
# 3              <NA>     Arya Rachmadianto  30/09/2023    30/09/2022
# 4              <NA>  Muhammad Ali Muhazir  28/08/2023    28/08/2022
# ...             ...                   ...         ...           ...
# 62644          <NA>                  <NA>        <NA>          <NA>
# 62645          <NA>                  <NA>        <NA>          <NA>
# 62646          <NA>                  <NA>        <NA>          <NA>
# 62647          <NA>                  <NA>        <NA>          <NA>
# 62648          <NA>                  <NA>        <NA>          <NA>
#
#          MEMBER_ID                       Email  ...       IP_ADDRESS  \
# 0      IVO20228478  quenty.hirando@yahoo.co.id  ...  180.222.114.200
# 1      IVO20228270        nobby_kent@yahoo.com  ...    103.190.60.34
# 2      IVO20226602           fandijs@gmail.com  ...     74.125.209.7
# 3      IVO20227038      arya.mochtar@gmail.com  ...    172.225.72.11
# 4      IVO20225839         azier.gio@gmail.com  ...    66.249.84.200
# ...            ...                         ...  ...              ...
# 62644         <NA>        graham_a61@yahoo.com  ...             <NA>
# 62645         <NA>       dee.sanetra@gmail.com  ...             <NA>
# 62646         <NA>      patrick.hy70@gmail.com  ...             <NA>
# 62647         <NA>      johannetmr@hotmail.com  ...             <NA>
# 62648         <NA>      engineeraamg@yahoo.com  ...   180.222.114.70
#
#                 DATE_ADDED OPTIN_IP OPTIN_DATE OPTIN_CONFIRM_IP  \
# 0      2022-11-28 09:35:29     <NA>       <NA>             <NA>
# 1      2022-11-28 09:35:29     <NA>       <NA>             <NA>
# 2      2022-11-28 09:35:29     <NA>       <NA>             <NA>
# 3      2022-11-28 09:35:29     <NA>       <NA>             <NA>
# 4      2022-11-28 09:35:29     <NA>       <NA>             <NA>
# ...                    ...      ...        ...              ...
# 62644  2024-03-25 06:59:34     <NA>       <NA>             <NA>
# 62645  2024-03-25 06:59:34     <NA>       <NA>             <NA>
# 62646  2024-03-25 06:59:34     <NA>       <NA>             <NA>
# 62647  2024-03-25 06:59:34     <NA>       <NA>             <NA>
# 62648  2024-03-25 06:59:34     <NA>       <NA>             <NA>
#
#       OPTIN_CONFIRM_DATE OPTOUT_IP OPTOUT_DATE OPTOUT_CONFIRM_IP  \
# 0                   <NA>      <NA>        <NA>              <NA>
# 1                   <NA>      <NA>        <NA>              <NA>
# 2                   <NA>      <NA>        <NA>              <NA>
# 3                   <NA>      <NA>        <NA>              <NA>
# 4                   <NA>      <NA>        <NA>              <NA>
# ...                  ...       ...         ...               ...
# 62644               <NA>      <NA>        <NA>              <NA>
# 62645               <NA>      <NA>        <NA>              <NA>
# 62646               <NA>      <NA>        <NA>              <NA>
# 62647               <NA>      <NA>        <NA>              <NA>
# 62648               <NA>      <NA>        <NA>              <NA>
#
#       OPTOUT_CONFIRM_DATE
# 0                    <NA>
# 1                    <NA>
# 2                    <NA>
# 3                    <NA>
# 4                    <NA>
# ...                   ...
# 62644                <NA>
# 62645                <NA>
# 62646                <NA>
# 62647                <NA>
# 62648                <NA>
#
# [62649 rows x 29 columns]

# %%
zoho_filter = fil.user_req(df)
zoho_df = df.loc[zoho_filter].copy() # menggunakan copy untuk menghindari setting copy warning
zoho_df.reset_index(drop=True, inplace=True)
count_filter_awal = zoho_df.shape[0]

# zoho_df.to_excel(r'C:\Users\fajar\Documents\Python\Data\test_leads.xlsx', index=False)
# mengisi kolom <NA> dengan value string 'empty' supaya mudah mengecek data member dan booking dengan isin

zoho_df.fillna('empty', inplace=True)
zoho_df
# Out:
# Empty DataFrame
# Columns: [Record Id, Created Time, Created Date, First Name, Last Name, Email, Phone, Mobile, Birthdate, Year of Birth, Street, Street2, City, State, Country, Nationality, Departure Date, Arrival Date, Card Type, Marital Status, Lead Brand, Lead Sub-Brand, Lead Source, Lead Locations, Lead Source Description, Lead Regions, Lead Status]
# Index: []
#
# [0 rows x 27 columns]

# %%
zoho_df.groupby('Lead Sub-Brand').count()
# Out:
#                   Record Id  Created Time  Created Date  First Name  \
# Lead Sub-Brand
# BGAU                 123624        123624        123624      123624
# BGID                 476654        476654        476654      476654
# Hotel Discount        90236         90236         90236       90236
# Karma Experience     352713        352713        352713      352713
#
#                   Last Name   Email   Phone  Mobile  Birthdate  Year of Birth  \
# Lead Sub-Brand
# BGAU                 123624  123624  123624  123624     123624         123624
# BGID                 476654  476654  476654  476654     476654         476654
# Hotel Discount        90236   90236   90236   90236      90236          90236
# Karma Experience     352713  352713  352713  352713     352713         352713
#
#                   ...  Departure Date  Arrival Date  Card Type  \
# Lead Sub-Brand    ...
# BGAU              ...          123624        123624     123624
# BGID              ...          476654        476654     476654
# Hotel Discount    ...           90236         90236      90236
# Karma Experience  ...          352713        352713     352713
#
#                   Marital Status  Lead Brand  Lead Source  Lead Locations  \
# Lead Sub-Brand
# BGAU                      123624      123624       123624          123624
# BGID                      476654      476654       476654          476654
# Hotel Discount             90236       90236        90236           90236
# Karma Experience          352713      352713       352713          352713
#
#                   Lead Source Description  Lead Regions  Lead Status
# Lead Sub-Brand
# BGAU                               123624        123624       123624
# BGID                               476654        476654       476654
# Hotel Discount                      90236         90236        90236
# Karma Experience                   352713        352713       352713
#
# [4 rows x 26 columns]

# %% [markdown]
# # ====================== Awal Filter Umum ======================

# %%
# data phone, mobile dam email member yang ada di master data (wash member)

m.clean_number(zoho_df, 'Phone')
m.clean_number(zoho_df, 'Mobile')
m.replace_not_valid_to_empty(zoho_df, 'Phone')
m.replace_not_valid_to_empty(zoho_df, 'Mobile')
zoho_df['Email'] = m.lowercase(zoho_df, 'Email')
m.clean_space(zoho_df, 'Email')
m.clean_not_valid_email_format(zoho_df, 'Email')

m.clean_number(df_booking, 'Phone1')
m.clean_number(df_booking, 'Mobile')
df_booking['Email'] = m.lowercase(df_booking, 'Email')
m.clean_space(df_booking, 'Email')
m.clean_not_valid_email_format(df_booking, 'Email')

m.clean_number(df_phone, 'Mobile')

df_unsubs['Email'] = m.lowercase(df_unsubs, 'Email')
m.clean_space(df_unsubs, 'Email')
m.clean_not_valid_email_format(df_unsubs, 'Email')

df_bounce['Email'] = m.lowercase(df_bounce, 'Email')
m.clean_space(df_bounce, 'Email')
m.clean_not_valid_email_format(df_bounce, 'Email')

df_kce['Email'] = m.lowercase(df_kce, 'Email')
m.clean_space(df_kce, 'Email')
m.clean_not_valid_email_format(df_kce, 'Email')
# Out:
# 'Email'

# %%
zoho_df.loc[zoho_df['Phone']=='']
# Out:
# Empty DataFrame
# Columns: [Record Id, Created Time, Created Date, First Name, Last Name, Email, Phone, Mobile, Birthdate, Year of Birth, Street, Street2, City, State, Country, Nationality, Departure Date, Arrival Date, Card Type, Marital Status, Lead Brand, Lead Sub-Brand, Lead Source, Lead Locations, Lead Source Description, Lead Regions, Lead Status]
# Index: []
#
# [0 rows x 27 columns]

# %%
count_deleted_wrong_format = m.delete_email_wrong_format(zoho_df, 'Email')
count_after_deleted_wrong_format = zoho_df.shape[0]

# %%
# hitung jumlah duplicate
count_duplicate_general = zoho_df.loc[zoho_df.duplicated(subset=['Email'])].shape[0]

zoho_df.loc[zoho_df.duplicated(subset=['Email'])]
# Out:
#                         Record Id         Created Time Created Date  \
# 5527     zcrm_3584690000000930151  2019-01-22 13:46:09        empty
# 6297     zcrm_3584690000001015301  2019-01-25 15:15:39        empty
# 10625    zcrm_3584690000001679151  2019-02-08 15:20:27        empty
# 27977    zcrm_3584690000005104084  2019-03-25 20:18:01        empty
# 69009    zcrm_3584690000006168864  2019-04-02 03:19:30   2015-03-18
# ...                           ...                  ...          ...
# 1043145  zcrm_3584690000489203048  2024-03-24 10:00:30        empty
# 1043182  zcrm_3584690000489218408  2024-03-25 12:03:23        empty
# 1043189  zcrm_3584690000489221077  2024-03-24 11:11:30        empty
# 1043203  zcrm_3584690000489228144  2024-03-24 15:53:49        empty
# 1043226  zcrm_3584690000489256095  2024-03-25 15:28:46        empty
#
#         First Name     Last Name                        Email          Phone  \
# 5527         Sarah        Juniar     myjune21_becky@yahoo.com    85269192900
# 6297           Har          Tato           tatorich@yahoo.com     8113674888
# 10625         Dewi  Purnama Sari  d3w1_purnama_sari@yahoo.com    81286661186
# 27977    Handayani         Saman    handayani.saman@yahoo.com    85311133033
# 69009        empty  Nickeylawton   nickeylawton1@yahoo.com.au    61439886488
# ...            ...           ...                          ...            ...
# 1043145     DAMIEN     PRESPAKIS      jodiedamien@bigpond.com    61419221312
# 1043182      KAMAL      SHINGALA     shruti.choubey@ymail.com    61402523754
# 1043189      AGUNG    INDRATMOKO   agung.indratmoko@yahoo.com  6287739474564
# 1043203       DODI       IRWANTO      cindylystiani@gmail.com   627738084485
# 1043226     CHETAN        RAJPUT   chetanrajput2198@gmail.com   919824388176
#
#                 Mobile   Birthdate Year of Birth  ... Arrival Date  \
# 5527             empty  1985-01-01          1985  ...        empty
# 6297             empty  1988-01-01          1988  ...        empty
# 10625            empty  1987-01-01          1987  ...        empty
# 27977            empty       empty          1971  ...        empty
# 69009            empty       empty         empty  ...        empty
# ...                ...         ...           ...  ...          ...
# 1043145    61419221312  1900-01-01          1900  ...        empty
# 1043182    61402523754  1990-10-10          1990  ...        empty
# 1043189  6287739474564  1900-01-01          1900  ...        empty
# 1043203   627738084485  1989-08-14          1989  ...        empty
# 1043226   919824388176  1979-08-04          1979  ...        empty
#
#               Card Type Marital Status           Lead Brand    Lead Sub-Brand  \
# 5527           Platinum        Married  Timeshare Marketing              BGID
# 6297     Visa Signature        Married  Timeshare Marketing              BGID
# 10625          Platinum         Single  Timeshare Marketing              BGID
# 27977              Gold          empty  Timeshare Marketing              BGID
# 69009             empty          empty  Timeshare Marketing              BGAU
# ...                 ...            ...                  ...               ...
# 1043145           empty          empty  Timeshare Marketing  Karma Experience
# 1043182           empty          empty  Timeshare Marketing  Karma Experience
# 1043189           empty          empty  Timeshare Marketing  Karma Experience
# 1043203           empty          empty  Timeshare Marketing  Karma Experience
# 1043226           empty          empty  Timeshare Marketing  Karma Experience
#
#           Lead Source       Lead Locations  \
# 5527     Facebook Ads                empty
# 6297     Facebook Ads                empty
# 10625     Web Enquiry                empty
# 27977     Web Enquiry        Hotel Partner
# 69009     Web Enquiry                empty
# ...               ...                  ...
# 1043145    Guest Exit  Sales Deck Jimbaran
# 1043182    Guest Exit                empty
# 1043189    Guest Exit  Sales Deck Jimbaran
# 1043203    Guest Exit                empty
# 1043226    Guest Exit                empty
#
#                                    Lead Source Description Lead Regions  \
# 5527                                                 empty         SEAP
# 6297                                                 empty         SEAP
# 10625                                                empty         SEAP
# 27977                         BGID | Web | Form Homepage 2         SEAP
# 69009                  Bali Getaway Australia Contact Form         SEAP
# ...                                                    ...          ...
# 1043145  Sales Deck Jimbaran | Redeem Karma | EXCLUSIVE...         SEAP
# 1043182  Sales Deck petitenget | Redeem Karma | EXCLUSI...         SEAP
# 1043189  Sales Deck Jimbaran | Redeem Karma | EXCLUSIVE...         SEAP
# 1043203  Sales Deck petitenget | Redeem Karma | EXCLUSI...         SEAP
# 1043226  Sales Deck petitenget | Redeem Karma | EXCLUSI...         SEAP
#
#         Lead Status
# 5527          empty
# 6297          empty
# 10625         empty
# 27977         empty
# 69009         empty
# ...             ...
# 1043145       empty
# 1043182       empty
# 1043189       empty
# 1043203       empty
# 1043226       empty
#
# [253708 rows x 27 columns]

# %%
zoho_df.drop_duplicates(subset=['Email'], inplace=True)
zoho_df.reset_index(drop=True, inplace=True)

# hitung jumlah setelah value duplicate dihapus
count_after_dedup_duplicate = zoho_df.shape[0]

zoho_df
# Out:
#                        Record Id         Created Time Created Date  \
# 0       zcrm_3584690000000408007  2019-01-07 13:29:59        empty
# 1       zcrm_3584690000000408013  2019-01-07 17:22:27        empty
# 2       zcrm_3584690000000408020  2019-01-07 18:22:28        empty
# 3       zcrm_3584690000000408026  2019-01-07 20:07:11        empty
# 4       zcrm_3584690000000409019  2019-01-07 15:00:14        empty
# ...                          ...                  ...          ...
# 789514  zcrm_3584690000489240189  2024-03-25 16:06:36        empty
# 789515  zcrm_3584690000489243001  2024-03-24 13:15:27        empty
# 789516  zcrm_3584690000489243048  2024-03-24 15:57:55        empty
# 789517  zcrm_3584690000489256001  2024-03-25 14:17:46        empty
# 789518  zcrm_3584690000489256048  2024-03-25 15:03:45        empty
#
#                First Name  Last Name                       Email  \
# 0              Ht Chandra    N Usman       ichan051163@gmail.com
# 1                   Endah    Haryani      awal.endah83@gmail.com
# 2            Alda Beatrix  Wattimena   aldabeatrix.abw@gmail.com
# 3                    Rini    Siregar    rini.siregar21@gmail.com
# 4       Christine Marylin    Effendi  christinemarylin@gmail.com
# ...                   ...        ...                         ...
# 789514               SINO     MATHEW    teleenavthomas@gmail.com
# 789515             ANDREW     RIMMER    andrewrimmer@outlook.com
# 789516             ROMMEL     GeorGE        rjgeorge86@gmail.com
# 789517            SAULIUS    ROMERIS    sauliusromeris@gmail.com
# 789518              JOLYN         NG        jolyn.ng@live.com.sg
#
#                 Phone        Mobile   Birthdate Year of Birth  ...  \
# 0        628116190115    8126542115  1963-01-01          1963  ...
# 1         87888802700         empty  1983-01-01          1983  ...
# 2       6285344502233         empty  1986-01-01          1986  ...
# 3         87888282359         empty       empty         empty  ...
# 4               empty         empty       empty         empty  ...
# ...               ...           ...         ...           ...  ...
# 789514   918086206032  918086206032  1990-04-07          1990  ...
# 789515    61408022047   61408022047  1959-03-26          1959  ...
# 789516   919562897817  919562897817  1986-07-09          1986  ...
# 789517   353873546112  353873546112  1987-06-15          1987  ...
# 789518     6597128546    6597128546  1990-12-15          1990  ...
#
#        Arrival Date         Card Type Marital Status           Lead Brand  \
# 0             empty  Mastercard World         Single  Timeshare Marketing
# 1             empty          Platinum        Married  Timeshare Marketing
# 2             empty              Gold        Married  Timeshare Marketing
# 3             empty              Gold        Married  Timeshare Marketing
# 4             empty             empty          empty  Timeshare Marketing
# ...             ...               ...            ...                  ...
# 789514        empty             empty          empty  Timeshare Marketing
# 789515        empty             empty          empty  Timeshare Marketing
# 789516        empty             empty          empty  Timeshare Marketing
# 789517        empty             empty          empty  Timeshare Marketing
# 789518        empty             empty          empty  Timeshare Marketing
#
#           Lead Sub-Brand Lead Source       Lead Locations  \
# 0                   BGID  Newsletter                empty
# 1                   BGID  Newsletter                empty
# 2                   BGID  Newsletter                empty
# 3                   BGID  Newsletter                empty
# 4                   BGID  Newsletter                empty
# ...                  ...         ...                  ...
# 789514  Karma Experience  Guest Exit  Sales Deck Jimbaran
# 789515  Karma Experience  Guest Exit                empty
# 789516  Karma Experience  Guest Exit  Sales Deck Jimbaran
# 789517  Karma Experience  Guest Exit  Sales Deck Jimbaran
# 789518  Karma Experience  Guest Exit                empty
#
#                                   Lead Source Description Lead Regions  \
# 0                                                   empty         SEAP
# 1                                                   empty         SEAP
# 2                                                   empty         SEAP
# 3                                                   empty         SEAP
# 4                                                   empty         SEAP
# ...                                                   ...          ...
# 789514  Sales Deck Jimbaran | Redeem Karma | EXCLUSIVE...         SEAP
# 789515  Sales Deck petitenget | Redeem Karma | EXCLUSI...         SEAP
# 789516  Sales Deck Jimbaran | Redeem Karma | EXCLUSIVE...         SEAP
# 789517  Sales Deck Jimbaran | Redeem Karma | EXCLUSIVE...         SEAP
# 789518  Sales Deck petitenget | Redeem Karma | EXCLUSI...         SEAP
#
#        Lead Status
# 0            empty
# 1            empty
# 2            empty
# 3            empty
# 4            empty
# ...            ...
# 789514       empty
# 789515       empty
# 789516       empty
# 789517       empty
# 789518       empty
#
# [789519 rows x 27 columns]

# %%
# Cek leads test
test_leads = zoho_df.loc[
    
        zoho_df['Email'].str.contains('^test@', flags=re.I, regex=True) |
        zoho_df['Email'].str.contains('\+test', flags=re.I, regex=True) |
    
        zoho_df['First Name'].str.contains('^test$', flags=re.I, regex=True) |
        zoho_df['Last Name'].str.contains('^test$', flags=re.I, regex=True) |

        zoho_df['First Name'].str.contains('test 1', flags=re.I, regex=True) |
        zoho_df['Last Name'].str.contains('test 2', flags=re.I, regex=True)|
        zoho_df['First Name'].str.contains('test1', flags=re.I, regex=True) |
        zoho_df['Last Name'].str.contains('test2', flags=re.I, regex=True)|

        zoho_df['First Name'].str.contains(' test ', flags=re.I, regex=True) | 
        zoho_df['Last Name'].str.contains(' test ', flags=re.I, regex=True) | 
        zoho_df['Last Name'].str.contains(' test$', flags=re.I, regex=True)
    ]

count_leads_test = test_leads.shape[0]

# test_leads.to_excel(r'C:\Users\fajar\Documents\Python\Data\test_leads_2.xlsx', index=False)
test_leads
# Out:
#                        Record Id         Created Time Created Date First Name  \
# 33085   zcrm_3584690000006082754  2019-04-02 03:11:29   2015-05-12      empty
# 33086   zcrm_3584690000006082755  2019-04-02 03:11:29   2015-05-12      empty
# 33087   zcrm_3584690000006082758  2019-04-02 03:11:29   2015-05-12    Michael
# 33088   zcrm_3584690000006082759  2019-04-02 03:11:29   2015-05-12    Hosanna
# 33089   zcrm_3584690000006082761  2019-04-02 03:11:29   2015-05-12      empty
# ...                          ...                  ...          ...        ...
# 787245  zcrm_3584690000477543346  2024-01-11 16:50:47        empty        eka
# 787269  zcrm_3584690000479828731  2024-01-15 16:45:42        empty        eka
# 787276  zcrm_3584690000479905111  2024-01-15 17:47:14        empty        eka
# 787598  zcrm_3584690000481794042  2024-01-30 16:28:26        empty        eka
# 787601  zcrm_3584690000481796165  2024-01-30 18:13:54        empty        Eka
#
#        Last Name                                 Email          Phone  \
# 33085      empty                         test@bali.com    61361254566
# 33086      empty                        test@benny.com    61361767767
# 33087      Angus                      test@hotmail.com        6666666
# 33088    Hosanna                         test@mail.com     6117324567
# 33089      empty                         test@test.net    61361890898
# ...          ...                                   ...            ...
# 787245      test      eka.suryawan+1888@karmagroup.com   628192817281
# 787269      test      eka.suryawan+1982@karmagroup.com   618192811711
# 787276      test  eka.suryawan+1099test@karmagroup.com   618192817161
# 787598      test      eka.suryawan+178x@karmagroup.com  6280182716611
# 787601     Test2     eka.suryawan+8922x@karmagroup.com  6281721718171
#
#                Mobile   Birthdate Year of Birth  ... Arrival Date Card Type  \
# 33085           empty       empty         empty  ...        empty     empty
# 33086     61361232211       empty         empty  ...        empty     empty
# 33087           empty       empty         empty  ...        empty     empty
# 33088   9718754212356  1989-09-11          1989  ...        empty     empty
# 33089           empty       empty         empty  ...        empty     empty
# ...               ...         ...           ...  ...          ...       ...
# 787245   628192817281       empty         empty  ...        empty     empty
# 787269   618192811711       empty         empty  ...        empty     empty
# 787276   618192817161       empty         empty  ...   2024-01-19     empty
# 787598  6280182716611  1986-01-01          1986  ...        empty     empty
# 787601  6281721718171  1981-01-01          1981  ...        empty     empty
#
#        Marital Status           Lead Brand    Lead Sub-Brand  Lead Source  \
# 33085           empty  Timeshare Marketing              BGAU          Edm
# 33086           empty  Timeshare Marketing              BGAU          Edm
# 33087           empty  Timeshare Marketing              BGAU          Edm
# 33088           empty  Timeshare Marketing              BGAU          Edm
# 33089           empty  Timeshare Marketing              BGAU          Edm
# ...               ...                  ...               ...          ...
# 787245         Single  Timeshare Marketing  Karma Experience  Web Enquiry
# 787269        Married  Timeshare Marketing  Karma Experience  Web Enquiry
# 787276        Married  Timeshare Marketing  Karma Experience  Web Enquiry
# 787598          empty  Timeshare Marketing  Karma Experience   Guest Exit
# 787601          empty  Timeshare Marketing  Karma Experience   Guest Exit
#
#                Lead Locations  \
# 33085                   empty
# 33086                   empty
# 33087                   empty
# 33088                   empty
# 33089                   empty
# ...                       ...
# 787245                General
# 787269                General
# 787276                General
# 787598  Sales Deck Petitenget
# 787601    Sales Deck Jimbaran
#
#                                   Lead Source Description Lead Regions  \
# 33085                 BaliGetaway AUS Email - Phuket - #1         SEAP
# 33086                 BaliGetaway AUS Email - Phuket - #1         SEAP
# 33087                 BaliGetaway AUS Email - J4 - VO_BMG         SEAP
# 33088   BGAU - Digital - EDM - w2apr17 - Fave Hotel Um...        Other
# 33089               BaliGetaway AUS Email - Phuket - $199         SEAP
# ...                                                   ...          ...
# 787245                           KE | Web | Destination |         SEAP
# 787269        KE | Web | Destination | karma-haveli-india         SEAP
# 787276           KE | Web | Destination Karma Royal Palms         SEAP
# 787598  Sales Deck Petitenget | Redeem Karma | EXCLUSI...         SEAP
# 787601  Sales Deck Jimbaran | Redeem Karma | EXCLUSIVE...         SEAP
#
#           Lead Status
# 33085           empty
# 33086           empty
# 33087           empty
# 33088           empty
# 33089           empty
# ...               ...
# 787245  Not Qualified
# 787269  Not Qualified
# 787276  Not Qualified
# 787598          empty
# 787601          empty
#
# [137 rows x 27 columns]

# %%
zoho_df.drop(test_leads.index, inplace=True)
zoho_df.reset_index(drop=True, inplace=True)

count_after_dedup_test = zoho_df.shape[0]

# %%
# Cek Email OTA
email_OTA = m.find_OTA(zoho_df, 'Email')
count_email_OTA = email_OTA.shape[0]
# email_OTA.to_excel(r'C:\Users\fajar\Documents\Python\Data\email_OTA.xlsx', index=False)

email_OTA
# Out:
#                        Record Id         Created Time Created Date  \
# 965     zcrm_3584690000000657181  2019-01-13 06:55:40        empty
# 2231    zcrm_3584690000000668331  2019-01-13 15:50:42        empty
# 2452    zcrm_3584690000000670403  2019-01-13 17:40:08        empty
# 2821    zcrm_3584690000000706621  2019-01-17 01:35:43        empty
# 2941    zcrm_3584690000000708359  2019-01-16 08:48:15        empty
# ...                          ...                  ...          ...
# 771426  zcrm_3584690000430855268  2023-02-23 07:14:24        empty
# 778352  zcrm_3584690000438198168  2023-04-01 08:57:16        empty
# 781656  zcrm_3584690000460374320  2023-09-05 17:54:24   2023-06-30
# 787901  zcrm_3584690000483695129  2024-02-14 13:18:46        empty
# 789245  zcrm_3584690000489157182  2024-03-25 12:41:11        empty
#
#                First Name    Last Name                             Email  \
# 965     Yohanes Pamungkas      Santoso        yohanes@smailingtour.co.id
# 2231               Silvia        Utami        glorietourpadang@gmail.com
# 2452                 Moen         Moen               moen.tour@yahoo.com
# 2821                Anang  Hardiansyah   selebritis.tourtravel@gmail.com
# 2941             Yulianto         Budi           tours_permata@yahoo.com
# ...                   ...          ...                               ...
# 771426             Victor        Vabio        pasiartourtravel@yahoo.com
# 778352               Ardi      Pramono               ardiatour@gmail.com
# 781656            Natasha        Price            tashontour@hotmail.com
# 787901            SAURABH      TALREJA  raaheintoursandtravels@gmail.com
# 789245          ISTORLINO     DA COSTA             gesanotour1@gmail.com
#
#                 Phone         Mobile   Birthdate Year of Birth  ...  \
# 965        8158082392          empty  1981-09-14          1981  ...
# 2231      87877744428          empty  1962-03-25          1962  ...
# 2452      81219991033          empty  1982-01-01          1982  ...
# 2821      89681821456          empty  1989-01-01          1989  ...
# 2941    6282233295200          empty  1986-01-01          1986  ...
# ...               ...            ...         ...           ...  ...
# 771426  6285358856161  6285358856161  1990-03-30          1990  ...
# 778352   628156800919   628156800919  1969-12-13          1969  ...
# 781656   447821056065          empty  1977-08-08         empty  ...
# 787901   919670999100   919670999100       empty         empty  ...
# 789245    67074417115    67074417115  1982-04-07          1982  ...
#
#        Arrival Date Card Type Marital Status           Lead Brand  \
# 965           empty      Gold        Married  Timeshare Marketing
# 2231          empty  Platinum        Married  Timeshare Marketing
# 2452          empty  Platinum         Single  Timeshare Marketing
# 2821          empty  Platinum        Married  Timeshare Marketing
# 2941          empty      Gold        Married  Timeshare Marketing
# ...             ...       ...            ...                  ...
# 771426        empty        No        Married  Timeshare Marketing
# 778352        empty  Platinum        Married  Timeshare Marketing
# 781656        empty     empty          empty  Timeshare Marketing
# 787901   2024-03-26     empty        Married  Timeshare Marketing
# 789245        empty     empty          empty  Timeshare Marketing
#
#           Lead Sub-Brand   Lead Source       Lead Locations  \
# 965                 BGID  Facebook Ads                empty
# 2231                BGID  Facebook Ads                empty
# 2452                BGID  Facebook Ads                empty
# 2821                BGID  Facebook Ads                empty
# 2941                BGID  Facebook Ads                empty
# ...                  ...           ...                  ...
# 771426              BGID  Facebook Ads        Hotel Partner
# 778352  Karma Experience  Facebook Ads        Hotel Partner
# 781656  Karma Experience  Facebook Ads        Karma Bavaria
# 787901  Karma Experience   Web Enquiry              General
# 789245  Karma Experience    Guest Exit  Sales Deck Jimbaran
#
#                                   Lead Source Description Lead Regions  \
# 965                                                 empty         SEAP
# 2231                                                empty         SEAP
# 2452                                                empty         SEAP
# 2821                                                empty         SEAP
# 2941                                                empty         SEAP
# ...                                                   ...          ...
# 771426             ID | FB LP | Sense Seminyak Combo Deal         SEAP
# 778352           KEID | FB Ads | w3mar23 | Sense Seminyak         SEAP
# 781656  FlyBuy Leads (Kevin O'Connor) Resort Preview S...    UK/Europe
# 787901    KE | Web | Destination Karma Royal Haathi Mahal         SEAP
# 789245  Sales Deck Jimbaran | Redeem Karma | EXCLUSIVE...         SEAP
#
#           Lead Status
# 965             empty
# 2231            empty
# 2452            empty
# 2821            empty
# 2941            empty
# ...               ...
# 771426   Hot Prospect
# 778352   Hot Prospect
# 781656       New Lead
# 787901  Not Qualified
# 789245          empty
#
# [488 rows x 27 columns]

# %%
# delete email OTA
count_after_clean_OTA = m.delete_OTA(zoho_df, 'Email')
# zoho_df.to_excel(r'C:\Users\fajar\Documents\Python\Data\after_clean_OTA.xlsx', index=False)

zoho_df
# Out:
#                        Record Id         Created Time Created Date  \
# 0       zcrm_3584690000000408007  2019-01-07 13:29:59        empty
# 1       zcrm_3584690000000408013  2019-01-07 17:22:27        empty
# 2       zcrm_3584690000000408020  2019-01-07 18:22:28        empty
# 3       zcrm_3584690000000408026  2019-01-07 20:07:11        empty
# 4       zcrm_3584690000000409019  2019-01-07 15:00:14        empty
# ...                          ...                  ...          ...
# 788889  zcrm_3584690000489240189  2024-03-25 16:06:36        empty
# 788890  zcrm_3584690000489243001  2024-03-24 13:15:27        empty
# 788891  zcrm_3584690000489243048  2024-03-24 15:57:55        empty
# 788892  zcrm_3584690000489256001  2024-03-25 14:17:46        empty
# 788893  zcrm_3584690000489256048  2024-03-25 15:03:45        empty
#
#                First Name  Last Name                       Email  \
# 0              Ht Chandra    N Usman       ichan051163@gmail.com
# 1                   Endah    Haryani      awal.endah83@gmail.com
# 2            Alda Beatrix  Wattimena   aldabeatrix.abw@gmail.com
# 3                    Rini    Siregar    rini.siregar21@gmail.com
# 4       Christine Marylin    Effendi  christinemarylin@gmail.com
# ...                   ...        ...                         ...
# 788889               SINO     MATHEW    teleenavthomas@gmail.com
# 788890             ANDREW     RIMMER    andrewrimmer@outlook.com
# 788891             ROMMEL     GeorGE        rjgeorge86@gmail.com
# 788892            SAULIUS    ROMERIS    sauliusromeris@gmail.com
# 788893              JOLYN         NG        jolyn.ng@live.com.sg
#
#                 Phone        Mobile   Birthdate Year of Birth  ...  \
# 0        628116190115    8126542115  1963-01-01          1963  ...
# 1         87888802700         empty  1983-01-01          1983  ...
# 2       6285344502233         empty  1986-01-01          1986  ...
# 3         87888282359         empty       empty         empty  ...
# 4               empty         empty       empty         empty  ...
# ...               ...           ...         ...           ...  ...
# 788889   918086206032  918086206032  1990-04-07          1990  ...
# 788890    61408022047   61408022047  1959-03-26          1959  ...
# 788891   919562897817  919562897817  1986-07-09          1986  ...
# 788892   353873546112  353873546112  1987-06-15          1987  ...
# 788893     6597128546    6597128546  1990-12-15          1990  ...
#
#        Arrival Date         Card Type Marital Status           Lead Brand  \
# 0             empty  Mastercard World         Single  Timeshare Marketing
# 1             empty          Platinum        Married  Timeshare Marketing
# 2             empty              Gold        Married  Timeshare Marketing
# 3             empty              Gold        Married  Timeshare Marketing
# 4             empty             empty          empty  Timeshare Marketing
# ...             ...               ...            ...                  ...
# 788889        empty             empty          empty  Timeshare Marketing
# 788890        empty             empty          empty  Timeshare Marketing
# 788891        empty             empty          empty  Timeshare Marketing
# 788892        empty             empty          empty  Timeshare Marketing
# 788893        empty             empty          empty  Timeshare Marketing
#
#           Lead Sub-Brand Lead Source       Lead Locations  \
# 0                   BGID  Newsletter                empty
# 1                   BGID  Newsletter                empty
# 2                   BGID  Newsletter                empty
# 3                   BGID  Newsletter                empty
# 4                   BGID  Newsletter                empty
# ...                  ...         ...                  ...
# 788889  Karma Experience  Guest Exit  Sales Deck Jimbaran
# 788890  Karma Experience  Guest Exit                empty
# 788891  Karma Experience  Guest Exit  Sales Deck Jimbaran
# 788892  Karma Experience  Guest Exit  Sales Deck Jimbaran
# 788893  Karma Experience  Guest Exit                empty
#
#                                   Lead Source Description Lead Regions  \
# 0                                                   empty         SEAP
# 1                                                   empty         SEAP
# 2                                                   empty         SEAP
# 3                                                   empty         SEAP
# 4                                                   empty         SEAP
# ...                                                   ...          ...
# 788889  Sales Deck Jimbaran | Redeem Karma | EXCLUSIVE...         SEAP
# 788890  Sales Deck petitenget | Redeem Karma | EXCLUSI...         SEAP
# 788891  Sales Deck Jimbaran | Redeem Karma | EXCLUSIVE...         SEAP
# 788892  Sales Deck Jimbaran | Redeem Karma | EXCLUSIVE...         SEAP
# 788893  Sales Deck petitenget | Redeem Karma | EXCLUSI...         SEAP
#
#        Lead Status
# 0            empty
# 1            empty
# 2            empty
# 3            empty
# 4            empty
# ...            ...
# 788889       empty
# 788890       empty
# 788891       empty
# 788892       empty
# 788893       empty
#
# [788894 rows x 27 columns]

# %%
# Cek Email Karma
email_karma = m.find_karma(zoho_df, 'Email')
count_email_karma = email_karma.shape[0]
# email_OTA.to_excel(r'C:\Users\fajar\Documents\Python\Data\email_OTA.xlsx', index=False)

email_karma
# Out:
#                        Record Id         Created Time Created Date First Name  \
# 14167   zcrm_3584690000002492722  2019-02-22 14:51:05        empty       Reza
# 35287   zcrm_3584690000006087837  2019-04-02 03:11:56   2015-05-12      empty
# 52316   zcrm_3584690000006128606  2019-04-02 03:15:42   2015-05-12      empty
# 68133   zcrm_3584690000006167006  2019-04-02 03:19:20   2015-05-12      empty
# 75550   zcrm_3584690000006184540  2019-04-02 03:21:02   2017-02-13     Shally
# ...                          ...                  ...          ...        ...
# 786544  zcrm_3584690000474852001  2023-12-29 16:22:49        empty        Eka
# 786545  zcrm_3584690000474865001  2023-12-29 16:29:26        empty        Eka
# 786547  zcrm_3584690000474996001  2023-12-30 10:02:19        empty        eka
# 786775  zcrm_3584690000481190001  2024-01-23 10:45:01        empty        eka
# 786777  zcrm_3584690000481191001  2024-01-23 10:48:03        empty        eka
#
#              Last Name                               Email            Phone  \
# 14167   Bintang Aurora     reza.bintang@thebaligetaway.com       8113961761
# 35287            empty         itdept@royalperspective.com       6235157821
# 52316            empty          bhanu@royalperspective.com   61412123123123
# 68133            empty     lee+baligetawaycomau@ccp.com.au      61400481632
# 75550           Shally           shally@thebaligetaway.com            empty
# ...                ...                                 ...              ...
# 786544         TestKIC  eka.suryawan+198kic@karmagroup.com   62819281918911
# 786545         Testing   eka.suryawan+88xx2@karmagroup.com    6281928191811
# 786547          Test19     eka.suryawan+188@karmagroup.com  618192818767111
# 786775             eka    eka.suryawan+1892@karmagroup.com    6181927181711
# 786777    test vietnam   eka.suryawan+1982x@karmagroup.com      61819281716
#
#                  Mobile   Birthdate Year of Birth  ... Arrival Date Card Type  \
# 14167             empty       empty          1980  ...        empty  Platinum
# 35287             empty       empty         empty  ...        empty     empty
# 52316             empty       empty         empty  ...        empty     empty
# 68133             empty       empty         empty  ...        empty     empty
# 75550             empty       empty         empty  ...        empty     empty
# ...                 ...         ...           ...  ...          ...       ...
# 786544   62819281918911  1987-12-03          1987  ...        empty     empty
# 786545    6281928191811  1996-12-05          1996  ...        empty     empty
# 786547  618192818767111  1994-12-01          1994  ...        empty     empty
# 786775    6181927181711  1987-01-08          1987  ...        empty     empty
# 786777      61819281716  1988-01-07          1988  ...        empty     empty
#
#        Marital Status           Lead Brand    Lead Sub-Brand   Lead Source  \
# 14167           empty  Timeshare Marketing              BGID  Facebook Ads
# 35287           empty  Timeshare Marketing              BGAU           Edm
# 52316           empty  Timeshare Marketing              BGAU           Edm
# 68133           empty  Timeshare Marketing              BGAU  Facebook Ads
# 75550           empty  Timeshare Marketing              BGAU  Facebook Ads
# ...               ...                  ...               ...           ...
# 786544          empty  Timeshare Marketing  Karma Experience    Guest Exit
# 786545          empty  Timeshare Marketing  Karma Experience    Guest Exit
# 786547          empty  Timeshare Marketing  Karma Experience    Guest Exit
# 786775          empty  Timeshare Marketing  Karma Experience    Guest Exit
# 786777          empty  Timeshare Marketing  Karma Experience    Guest Exit
#
#              Lead Locations  \
# 14167                 empty
# 35287                 empty
# 52316                 empty
# 68133                 empty
# 75550                 empty
# ...                     ...
# 786544  Sales Deck Jimbaran
# 786545  Sales Deck Jimbaran
# 786547  Sales Deck Jimbaran
# 786775  Sales Deck Jimbaran
# 786777   Sales Deck Vietnam
#
#                                   Lead Source Description Lead Regions  \
# 14167                                               empty         SEAP
# 35287     BGAU - Email - Sunny Christmas - Neo Petitenget         SEAP
# 52316             BaliGetaway Seminyak Square AUS Group 1         SEAP
# 68133                                   BGAU - FB - Ion 2         SEAP
# 75550      BGAU - Digital - FB - w2feb17 - Neo Hotel Kuta         SEAP
# ...                                                   ...          ...
# 786544  TEST | Redeem Karma | EXCLUSIVE FREE STAY VOUCHER         SEAP
# 786545  TEST | Redeem Karma | EXCLUSIVE FREE STAY VOUCHER         SEAP
# 786547  TEST | Redeem Karma | EXCLUSIVE FREE STAY VOUCHER         SEAP
# 786775  TEST | Sales Deck Petitenget | Redeem Karma | ...         SEAP
# 786777  TEST | Sales Deck Vietnam | Redeem Karma | EXC...         SEAP
#
#        Lead Status
# 14167        empty
# 35287        empty
# 52316        empty
# 68133        empty
# 75550        empty
# ...            ...
# 786544       empty
# 786545       empty
# 786547       empty
# 786775       empty
# 786777       empty
#
# [225 rows x 27 columns]

# %%
# delete email Karma
count_after_clean_karma = m.delete_karma(zoho_df, 'Email')
# zoho_df.to_excel(r'C:\Users\fajar\Documents\Python\Data\after_clean_OTA.xlsx', index=False)

zoho_df
# Out:
#                        Record Id         Created Time Created Date  \
# 0       zcrm_3584690000000408007  2019-01-07 13:29:59        empty
# 1       zcrm_3584690000000408013  2019-01-07 17:22:27        empty
# 2       zcrm_3584690000000408020  2019-01-07 18:22:28        empty
# 3       zcrm_3584690000000408026  2019-01-07 20:07:11        empty
# 4       zcrm_3584690000000409019  2019-01-07 15:00:14        empty
# ...                          ...                  ...          ...
# 788664  zcrm_3584690000489240189  2024-03-25 16:06:36        empty
# 788665  zcrm_3584690000489243001  2024-03-24 13:15:27        empty
# 788666  zcrm_3584690000489243048  2024-03-24 15:57:55        empty
# 788667  zcrm_3584690000489256001  2024-03-25 14:17:46        empty
# 788668  zcrm_3584690000489256048  2024-03-25 15:03:45        empty
#
#                First Name  Last Name                       Email  \
# 0              Ht Chandra    N Usman       ichan051163@gmail.com
# 1                   Endah    Haryani      awal.endah83@gmail.com
# 2            Alda Beatrix  Wattimena   aldabeatrix.abw@gmail.com
# 3                    Rini    Siregar    rini.siregar21@gmail.com
# 4       Christine Marylin    Effendi  christinemarylin@gmail.com
# ...                   ...        ...                         ...
# 788664               SINO     MATHEW    teleenavthomas@gmail.com
# 788665             ANDREW     RIMMER    andrewrimmer@outlook.com
# 788666             ROMMEL     GeorGE        rjgeorge86@gmail.com
# 788667            SAULIUS    ROMERIS    sauliusromeris@gmail.com
# 788668              JOLYN         NG        jolyn.ng@live.com.sg
#
#                 Phone        Mobile   Birthdate Year of Birth  ...  \
# 0        628116190115    8126542115  1963-01-01          1963  ...
# 1         87888802700         empty  1983-01-01          1983  ...
# 2       6285344502233         empty  1986-01-01          1986  ...
# 3         87888282359         empty       empty         empty  ...
# 4               empty         empty       empty         empty  ...
# ...               ...           ...         ...           ...  ...
# 788664   918086206032  918086206032  1990-04-07          1990  ...
# 788665    61408022047   61408022047  1959-03-26          1959  ...
# 788666   919562897817  919562897817  1986-07-09          1986  ...
# 788667   353873546112  353873546112  1987-06-15          1987  ...
# 788668     6597128546    6597128546  1990-12-15          1990  ...
#
#        Arrival Date         Card Type Marital Status           Lead Brand  \
# 0             empty  Mastercard World         Single  Timeshare Marketing
# 1             empty          Platinum        Married  Timeshare Marketing
# 2             empty              Gold        Married  Timeshare Marketing
# 3             empty              Gold        Married  Timeshare Marketing
# 4             empty             empty          empty  Timeshare Marketing
# ...             ...               ...            ...                  ...
# 788664        empty             empty          empty  Timeshare Marketing
# 788665        empty             empty          empty  Timeshare Marketing
# 788666        empty             empty          empty  Timeshare Marketing
# 788667        empty             empty          empty  Timeshare Marketing
# 788668        empty             empty          empty  Timeshare Marketing
#
#           Lead Sub-Brand Lead Source       Lead Locations  \
# 0                   BGID  Newsletter                empty
# 1                   BGID  Newsletter                empty
# 2                   BGID  Newsletter                empty
# 3                   BGID  Newsletter                empty
# 4                   BGID  Newsletter                empty
# ...                  ...         ...                  ...
# 788664  Karma Experience  Guest Exit  Sales Deck Jimbaran
# 788665  Karma Experience  Guest Exit                empty
# 788666  Karma Experience  Guest Exit  Sales Deck Jimbaran
# 788667  Karma Experience  Guest Exit  Sales Deck Jimbaran
# 788668  Karma Experience  Guest Exit                empty
#
#                                   Lead Source Description Lead Regions  \
# 0                                                   empty         SEAP
# 1                                                   empty         SEAP
# 2                                                   empty         SEAP
# 3                                                   empty         SEAP
# 4                                                   empty         SEAP
# ...                                                   ...          ...
# 788664  Sales Deck Jimbaran | Redeem Karma | EXCLUSIVE...         SEAP
# 788665  Sales Deck petitenget | Redeem Karma | EXCLUSI...         SEAP
# 788666  Sales Deck Jimbaran | Redeem Karma | EXCLUSIVE...         SEAP
# 788667  Sales Deck Jimbaran | Redeem Karma | EXCLUSIVE...         SEAP
# 788668  Sales Deck petitenget | Redeem Karma | EXCLUSI...         SEAP
#
#        Lead Status
# 0            empty
# 1            empty
# 2            empty
# 3            empty
# 4            empty
# ...            ...
# 788664       empty
# 788665       empty
# 788666       empty
# 788667       empty
# 788668       empty
#
# [788669 rows x 27 columns]

# %%
find_member_booking = zoho_df.copy()

find_member_booking.loc[find_member_booking['Phone'].isin(df_booking['Phone1']), 'Same Value Find'] = 'Booking-Phone1'
find_member_booking.loc[find_member_booking['Phone'].isin(df_booking['Mobile']), 'Same Value Find'] = 'Booking-Mobile'
find_member_booking.loc[find_member_booking['Mobile'].isin(df_booking['Phone1']), 'Same Value Find'] = 'Booking-Phone1' 
find_member_booking.loc[find_member_booking['Mobile'].isin(df_booking['Mobile']), 'Same Value Find'] = 'Booking-Mobile'
find_member_booking.loc[find_member_booking['Email'].isin(df_booking['Email']), 'Same Value Find'] = 'Booking-Email'

find_member_booking.loc[find_member_booking['Phone'].isin(df_phone['Mobile']), 'Same Value Find'] = 'Member-Mobile' 
find_member_booking.loc[find_member_booking['Mobile'].isin(df_phone['Mobile']), 'Same Value Find'] = 'Member-Mobile'

find_member_booking.loc[find_member_booking['Email'].isin(df_email['Email']), 'Same Value Find'] = 'Member-Email'

find_member_booking.loc[find_member_booking['Email'].isin(df_unsubs['Email']), 'Same Value Find'] = 'Unsubs-Email'
find_member_booking.loc[find_member_booking['Email'].isin(df_bounce['Email']), 'Same Value Find'] = 'Bounce-Email'
find_member_booking.loc[find_member_booking['Email'].isin(df_kce['Email']), 'Same Value Find'] = 'KCE-Email'

find_member_booking.drop(find_member_booking.loc[find_member_booking['Same Value Find'].isna()].index, inplace=True)

count_booking_dedup = find_member_booking.loc[find_member_booking['Same Value Find'].str.contains('Booking', flags=re.I, regex=True)].shape[0]
count_member_dedup = find_member_booking.loc[find_member_booking['Same Value Find'].str.contains('Member', flags=re.I, regex=True)].shape[0]
count_unsubs_dedup = find_member_booking.loc[find_member_booking['Same Value Find'].str.contains('Unsubs', flags=re.I, regex=True)].shape[0]
count_bounce_dedup = find_member_booking.loc[find_member_booking['Same Value Find'].str.contains('Bounce', flags=re.I, regex=True)].shape[0]
count_kce_dedup = find_member_booking.loc[find_member_booking['Same Value Find'].str.contains('KCE', flags=re.I, regex=True)].shape[0]

find_member_booking.replace('empty', '', inplace=True)
# find_member_booking.to_csv(r'C:\Users\fajar\Documents\Python\Data\booking-member-dedup.csv', index=False)
# find_member_booking.to_excel(r'C:\Users\fajar\Documents\Python\Data\booking-member-dedup.xlsx', index=False)

#find_member_booking.loc[find_member_booking['Same Value Find'] == 'Booking-Phone1']

# %%
# data phone, mobile dam email member yang ada di master data 
count_wash_member = zoho_df.loc[
    zoho_df['Phone'].isin(df_booking['Phone1']) | 
    zoho_df['Phone'].isin(df_booking['Mobile']) |
    zoho_df['Mobile'].isin(df_booking['Phone1']) | 
    zoho_df['Mobile'].isin(df_booking['Mobile']) |
    zoho_df['Email'].isin(df_booking['Email'])| 

    zoho_df['Phone'].isin(df_phone['Mobile']) | 
    zoho_df['Mobile'].isin(df_phone['Mobile']) |

    zoho_df['Email'].isin(df_email['Email'])|

    zoho_df['Email'].isin(df_unsubs['Email'])|
    zoho_df['Email'].isin(df_bounce['Email'])|
    zoho_df['Email'].isin(df_kce['Email'])

].shape[0]

zoho_df.drop(zoho_df.loc[
    zoho_df['Phone'].isin(df_booking['Phone1']) | 
    zoho_df['Phone'].isin(df_booking['Mobile']) |
    zoho_df['Mobile'].isin(df_booking['Phone1']) | 
    zoho_df['Mobile'].isin(df_booking['Mobile']) |
    zoho_df['Email'].isin(df_booking['Email']) |
    
    zoho_df['Phone'].isin(df_phone['Mobile']) | 
    zoho_df['Mobile'].isin(df_phone['Mobile']) |

    zoho_df['Email'].isin(df_email['Email']) |
    zoho_df['Email'].isin(df_unsubs['Email'])|
    zoho_df['Email'].isin(df_bounce['Email'])|
    zoho_df['Email'].isin(df_kce['Email'])

    ].index, inplace=True)
    
zoho_df.reset_index(drop=True, inplace=True)

count_after_wash_member = zoho_df.shape[0]

# %%
count_email_only = zoho_df.loc[(zoho_df['Email'] != 'empty') & ((zoho_df['Phone'] == 'empty') & (zoho_df['Mobile'] == 'empty'))].shape[0]
count_phone_only = zoho_df.loc[(zoho_df['Email'] == 'empty') & ((zoho_df['Phone'] != 'empty') | (zoho_df['Mobile'] != 'empty'))].shape[0]
count_email_and_phone = zoho_df.loc[(zoho_df['Email'] != 'empty') & ((zoho_df['Phone'] != 'empty') | (zoho_df['Mobile'] != 'empty'))].shape[0]

count_blank = zoho_df.loc[(zoho_df['Email'] =='empty') & (zoho_df['Phone']=='empty') & (zoho_df['Mobile']=='empty')].shape[0]

# zoho_df.loc[(zoho_df['Email'] =='empty') & (zoho_df['Phone']=='empty') & (zoho_df['Mobile']=='empty')].to_excel(r'C:\Users\fajar\Documents\Python\Data\blank_data.xlsx', index=False)

zoho_df.loc[(zoho_df['Email'] != 'empty') & ((zoho_df['Phone'] == 'empty') & (zoho_df['Mobile'] == 'empty')), 'Contact Type'] = 'Email Only'
zoho_df.loc[(zoho_df['Email'] == 'empty') & ((zoho_df['Phone'] != 'empty') | (zoho_df['Mobile'] != 'empty')), 'Contact Type'] = 'Phone Only'
zoho_df.loc[(zoho_df['Email'] != 'empty') & ((zoho_df['Phone'] != 'empty') | (zoho_df['Mobile'] != 'empty')), 'Contact Type'] = 'Email and Phone'

zoho_df.drop(zoho_df.loc[(zoho_df['Email'] =='empty') & (zoho_df['Phone']=='empty') & (zoho_df['Mobile']=='empty')].index, inplace=True)
zoho_df.reset_index(drop=True, inplace=True)

count_after_wash_blank = zoho_df.shape[0]

# %%
arr_dedup = [count_deleted_wrong_format, count_duplicate_general, count_leads_test, count_email_OTA, count_email_karma, count_blank]
count_sum_dedup = sum(arr_dedup)
count_sum_dedup
# Out:
# 254558

# %%
print("==========================================================")
print("Summary")
print("==========================================================")
print("Jumlah Keseluruhan Master Zoho : "+str(count_data_awal))
print("Jumlah Filter Leads Awal : "+str(count_filter_awal))
print("Jumlah Format Email Salah : "+str(count_deleted_wrong_format))
print("Jumlah Setelah Clean Format Email Salah : "+str(count_after_deleted_wrong_format))
print("Jumlah Duplicate (Email) : "+str(count_duplicate_general))
print("Jumlah Setelah Clean Duplicate : "+str(count_after_dedup_duplicate))
print("Jumlah Lead Test : "+str(count_leads_test))
print("Jumlah Setelah Clean Lead Test : "+str(count_after_dedup_test))
print("Jumlah Email OTA : "+str(count_email_OTA))
print("Jumlah Setelah Clean Email OTA : "+str(count_after_clean_OTA))
print("Jumlah Email Karma : "+str(count_email_karma))
print("Jumlah Setelah Clean Email Karma : "+str(count_after_clean_karma))
print("Jumlah Wash Member : "+str(count_member_dedup))
print("Jumlah Wash Booking : "+str(count_booking_dedup))
print("Jumlah Wash Unsubs : "+str(count_unsubs_dedup))
print("Jumlah Wash Bounce : "+str(count_bounce_dedup))
print("Jumlah Wash KCE : "+str(count_kce_dedup))
print("Jumlah Setelah Wash Member+Bounce+Unsubs+KCE : "+str(count_after_wash_member))
print("Jumlah Phone Email Blank (Setelah phone yang tidak valid dihapus) : "+str(count_blank))
print("Jumlah Setelah Wash Phone Email Blank : "+str(count_after_wash_blank))
print("==========================================================")
print("Contact Type")
print("==========================================================")
print("Jumlah Email Only : "+str(count_email_only))
print("Jumlah Phone Only : "+str(count_phone_only))
print("Jumlah Email dan Phone : "+str(count_email_and_phone))
# Out:
# ==========================================================
# Summary
# ==========================================================
# Jumlah Keseluruhan Master Zoho : 9965985
# Jumlah Filter Leads Awal : 0
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [7], line 6
#       4 print("Jumlah Keseluruhan Master Zoho : "+str(count_data_awal))
#       5 print("Jumlah Filter Leads Awal : "+str(count_filter_awal))
# ----> 6 print("Jumlah Format Email Salah : "+str(count_deleted_wrong_format))
#       7 print("Jumlah Setelah Clean Format Email Salah : "+str(count_after_deleted_wrong_format))
#       8 print("Jumlah Duplicate (Email) : "+str(count_duplicate_general))
#
# NameError: name 'count_deleted_wrong_format' is not defined

# %%
print("==========================================================")
print("Summary Report")
print("==========================================================")
print("Jumlah Data Awal : "+str(count_filter_awal))
print("Jumlah Wash Dedup : "+str(count_sum_dedup))
print("Jumlah Wash Member : "+str(count_member_dedup))
print("Jumlah Wash Booking : "+str(count_booking_dedup))
print("Jumlah Wash Unsubs : "+str(count_unsubs_dedup))
print("Jumlah Wash Bounce : "+str(count_bounce_dedup))
print("Jumlah Wash KCE : "+str(count_kce_dedup))
print("Jumlah Data Akhir : "+str(count_after_wash_blank))
# Out:
# ==========================================================
# Summary Report
# ==========================================================
# Jumlah Data Awal : 1043227
# Jumlah Wash Dedup : 254558
# Jumlah Wash Member : 1225
# Jumlah Wash Booking : 2819
# Jumlah Wash Unsubs : 67753
# Jumlah Wash Bounce : 142484
# Jumlah Wash KCE : 4812
# Jumlah Data Akhir : 569576

# %% [markdown]
# # ====================== Akhir Filter Umum ======================

# %%
zoho_df.replace('empty', '', inplace=True, regex=True)
zoho_df.loc[zoho_df['Lead Sub-Brand'] == 'BGAU'].to_excel(r'C:\Users\fajar\Documents\Python\Data\database_tm_old_db(BGAU).xlsx', index=False)
zoho_df.loc[zoho_df['Lead Sub-Brand'] == 'BGID'].to_excel(r'C:\Users\fajar\Documents\Python\Data\database_tm_old_db(BGID).xlsx', index=False)
zoho_df.loc[zoho_df['Lead Sub-Brand'] == 'Hotel Discount'].to_excel(r'C:\Users\fajar\Documents\Python\Data\database_tm_old_db(Hotel Discount).xlsx', index=False)
zoho_df.loc[zoho_df['Lead Sub-Brand'] == 'Karma Experience'].to_excel(r'C:\Users\fajar\Documents\Python\Data\database_tm_old_db(Karma Experience).xlsx', index=False)

# %%
zoho_df.groupby('Lead Sub-Brand').count()
# Out:
#                   Record Id  Created Time  Created Date  First Name  \
# Lead Sub-Brand
# BGAU                  45020         45020         45020       45020
# BGID                 279396        279396        279396      279396
# Hotel Discount        36515         36515         36515       36515
# Karma Experience     208645        208645        208645      208645
#
#                   Last Name   Email   Phone  Mobile  Birthdate  Year of Birth  \
# Lead Sub-Brand
# BGAU                  45020   45020   45020   45020      45020          45020
# BGID                 279396  279396  279396  279396     279396         279396
# Hotel Discount        36515   36515   36515   36515      36515          36515
# Karma Experience     208645  208645  208645  208645     208645         208645
#
#                   ...  Arrival Date  Card Type  Marital Status  Lead Brand  \
# Lead Sub-Brand    ...
# BGAU              ...         45020      45020           45020       45020
# BGID              ...        279396     279396          279396      279396
# Hotel Discount    ...         36515      36515           36515       36515
# Karma Experience  ...        208645     208645          208645      208645
#
#                   Lead Source  Lead Locations  Lead Source Description  \
# Lead Sub-Brand
# BGAU                    45020           45020                    45020
# BGID                   279396          279396                   279396
# Hotel Discount          36515           36515                    36515
# Karma Experience       208645          208645                   208645
#
#                   Lead Regions  Lead Status  Contact Type
# Lead Sub-Brand
# BGAU                     45020        45020         45020
# BGID                    279396       279396        279396
# Hotel Discount           36515        36515         36515
# Karma Experience        208645       208645        208645
#
# [4 rows x 27 columns]

# %%
# zoho_df['Country'].loc[
#     (zoho_df['Phone'].str.contains('^44|^\+44')) & 
#     (~zoho_df['Country'].str.contains('united kingdom|wales|england|scotland|northern ireland', regex=True, flags=re.I))
# ]
