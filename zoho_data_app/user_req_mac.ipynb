# %%
import main_module as m
import zoho_filter_module as fil
import pandas as pd
from openpyxl.utils.exceptions import IllegalCharacterError
import re
import numpy as np

# %load_ext autoreload
# %autoreload 2

dir_path = '/Users/dewiindahpurnama_/Documents/Python/Data/Zoho_Backup'
file_prefix = 'Leads_'

cols = ['Record Id', 'Created Time', 'Created Date', 'First Name', 'Last Name', 'Email', 
        'Phone', 'Mobile', 'Birthdate', 'Year of Birth', 'Street', 'Street2', 'City', 
        'State', 'Country', 'Nationality', 'Booking Status', 'BookRef', 'Departure Date', 
        'Arrival Date', 'Card Type', 'Marital Status', 'Lead Brand', 'Lead Sub-Brand', 
        'Lead Source', 'Lead Locations', 'Lead Source Description', 'Lead Regions', 
        'Lead Status', 'Email Opt Out', 'Opt In', 'GDPR Compliant', 'Website', 
        'Comments', 'Do you live in Bali?']
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
df = m.load_data_multiple_mac(dir_path, file_prefix, cols)
count_data_awal = df.shape[0]
df = df.reindex(columns=cols)
df.shape[0]

df['Created Time'] = pd.to_datetime(df['Created Time'], format='%Y-%m-%d %H:%M:%S')
df['Arrival Date'] = pd.to_datetime(df['Arrival Date'], format='%Y-%m-%d')
df['Departure Date'] = pd.to_datetime(df['Departure Date'], format='%Y-%m-%d')
# fungsi errors cource untuk menhindari error jika value data date null atau kosong
# df['Birthdate'] = pd.to_datetime(df['Birthdate'], format='%Y-%m-%d', errors='coerce')
df.dtypes
df
# Out:
# Loading: Leads_001.csv
# Loading: Leads_002.csv
# Loading: Leads_003.csv
# Loading: Leads_004.csv
# Loading: Leads_005.csv
# Loading: Leads_006.csv
#                        Record Id        Created Time Created Date First Name  \
# 0       zcrm_3584690000000404602 2019-01-08 11:07:28   2021-07-21   Frederic
# 1       zcrm_3584690000000450071 2019-01-08 16:38:18         <NA>  Sebastian
# 2       zcrm_3584690000000450087 2019-01-08 16:38:18         <NA>    Siobhan
# 3       zcrm_3584690000000450106 2019-01-08 16:38:18         <NA>       Lisa
# 4       zcrm_3584690000000450109 2019-01-08 16:38:18         <NA>  Ana Maria
# ...                          ...                 ...          ...        ...
# 506068  zcrm_3584690000543419257 2025-05-05 12:13:38         <NA>     Pankaj
# 506069  zcrm_3584690000543419289 2025-05-05 12:13:51         <NA>      Shyam
# 506070  zcrm_3584690000543419321 2025-05-05 12:14:54         <NA>     Bijaya
# 506071  zcrm_3584690000543498001 2025-05-05 17:06:17         <NA>     DEBBIE
# 506072  zcrm_3584690000543509001 2025-05-05 17:36:33         <NA>   Jennifer
#
#               Last Name                        Email           Phone  \
# 0                 Bonin    fredericbonin79@gmail.com  +6281236100502
# 1                  Rach                         <NA>   +498914342111
# 2             Gallagher  gallaghersiobhan@eircom.net    353879597603
# 3             Ferkovich         lisajo2009@yahoo.com     14062394749
# 4              Weileder     m.weileder@sonnenlink.de     15253234700
# ...                 ...                          ...             ...
# 506068        Acharekar   pankaj.acharekar@gmail.com   +919930888227
# 506069  Vithalrao Ugale         ugalef2009@gmail.com   +918956719344
# 506070     Ketan Parida        bijay.crown@gmail.com   +918122490838
# 506071           Elvins         deelvins@yahoo.co.uk   +447446978291
# 506072            Poate         jenpoate@yahoo.co.uk    +33634119518
#
#                Mobile   Birthdate Year of Birth  ...      Lead Locations  \
# 0                <NA>  1981-10-03          1981  ...       Karma Kandara
# 1                <NA>  1982-04-20          1982  ...       Karma Bavaria
# 2                <NA>  1973-03-14          1973  ...       Karma Bavaria
# 3                <NA>  1963-07-08          1963  ...       Karma Bavaria
# 4                <NA>        <NA>          <NA>  ...       Karma Bavaria
# ...               ...         ...           ...  ...                 ...
# 506068  +912228941642        <NA>          <NA>  ...   Karma Royal Palms
# 506069  +919960995220        <NA>          <NA>  ...   Karma Royal Palms
# 506070  +918015884595        <NA>          <NA>  ...   Karma Royal Palms
# 506071           <NA>        <NA>          <NA>  ...  Karma Salford Hall
# 506072           <NA>        <NA>          <NA>  ...                <NA>
#
#                                   Lead Source Description Lead Regions  \
# 0                                                   KAREN         SEAP
# 1                                                    <NA>    UK/Europe
# 2                                                    <NA>    UK/Europe
# 3                                                    <NA>    UK/Europe
# 4                         MICE Contacts from Ioanna email    UK/Europe
# ...                                                   ...          ...
# 506068                                          Viewpoint         <NA>
# 506069                                          Viewpoint         <NA>
# 506070                                          Viewpoint         <NA>
# 506071               Friend of Karma - Discount Card 2023    UK/Europe
# 506072  Karma Curated Experience - Desert Passage: Tak...    UK/Europe
#
#        Lead Status Email Opt Out Opt In GDPR Compliant  \
# 0         New Lead         false  false          false
# 1         New Lead          true  false          false
# 2         New Lead         false   true           true
# 3         New Lead          true  false          false
# 4         New Lead         false   true           true
# ...            ...           ...    ...            ...
# 506068        <NA>         false   true          false
# 506069        <NA>         false   true          false
# 506070        <NA>         false   true          false
# 506071        <NA>         false   true           true
# 506072        <NA>         false   true           true
#
#                                                   Website Comments  \
# 0                                                    <NA>     <NA>
# 1                                                    <NA>     <NA>
# 2                                                    <NA>     <NA>
# 3                                                    <NA>     <NA>
# 4                                                    <NA>     <NA>
# ...                                                   ...      ...
# 506068                                               <NA>     <NA>
# 506069                                               <NA>     <NA>
# 506070                                               <NA>     <NA>
# 506071  https://karmagroup.com/friend-of-karma-salford...     <NA>
# 506072  https://karmaclub.karmagroup.com/karma-curated...     <NA>
#
#        Do you live in Bali?
# 0                     false
# 1                     false
# 2                     false
# 3                     false
# 4                     false
# ...                     ...
# 506068                false
# 506069                false
# 506070                false
# 506071                false
# 506072                false
#
# [506073 rows x 35 columns]

# %%
df.loc[df['Phone'].str.contains('^\\+62', regex=True)]
# Out:
#                        Record Id        Created Time Created Date  \
# 0       zcrm_3584690000000404602 2019-01-08 11:07:28   2021-07-21
# 10      zcrm_3584690000000450191 2019-01-08 16:38:18   2021-07-21
# 12      zcrm_3584690000000450226 2019-01-08 16:38:18   2021-07-21
# 33      zcrm_3584690000000456097 2019-01-09 11:10:49   2021-07-21
# 86      zcrm_3584690000000456162 2019-01-09 11:10:49   2021-07-21
# ...                          ...                 ...          ...
# 505937  zcrm_3584690000543301001 2025-05-04 22:39:46         <NA>
# 505957  zcrm_3584690000543325065 2025-05-05 11:35:16         <NA>
# 505969  zcrm_3584690000543325479 2025-05-05 13:21:23         <NA>
# 505988  zcrm_3584690000543412166 2025-05-05 12:06:33         <NA>
# 506041  zcrm_3584690000543417065 2025-05-05 11:36:51         <NA>
#
#                 First Name   Last Name                             Email  \
# 0                 Frederic       Bonin         fredericbonin79@gmail.com
# 10           Ni Made Novia    Andryani              novia_made@yahoo.com
# 12             Maureellins     Joewyns      maureellinsjoewyns@gmail.com
# 33                      Di       Zhang                  156864136@qq.com
# 86              Ganef Hari  Sulistiono             abahdendy99@gmail.com
# ...                    ...         ...                               ...
# 505937               Benny     Risanto  benny.risanto+007@karmagroup.com
# 505957  Floris / Kanokporn    Pituktae       floris_engelkes@hotmail.com
# 505969                TONG          YI      temperamentalqueen@gmail.com
# 505988     Jaimee Lorraine     Mcmahon             jaimemcr334@gmail.com
# 506041               Susan         Bay                  fossick@mail.com
#
#                    Phone         Mobile   Birthdate Year of Birth  ...  \
# 0         +6281236100502           <NA>  1981-10-03          1981  ...
# 10        +6281511634635           <NA>  1980-11-10          1980  ...
# 12        +6282221100639           <NA>  2000-04-14          2000  ...
# 33      +628618339280777           <NA>        <NA>          <NA>  ...
# 86         +628123255435           <NA>  1963-12-16          1963  ...
# ...                  ...            ...         ...           ...  ...
# 505937     +620811392202           <NA>        <NA>          <NA>  ...
# 505957      +62811388775   +62811388775        <NA>          <NA>  ...
# 505969    +6281239347494           <NA>        <NA>          <NA>  ...
# 505988    +6282119439966           <NA>        <NA>          <NA>  ...
# 506041     +628128408468  +628128408468        <NA>          <NA>  ...
#
#         Lead Locations                  Lead Source Description Lead Regions  \
# 0        Karma Kandara                                    KAREN         SEAP
# 10       Karma Kandara                                    KAREN         SEAP
# 12       Karma Kandara                                    KAREN         SEAP
# 33       Karma Kandara                                    KAREN         SEAP
# 86       Karma Kandara                                    KAREN         SEAP
# ...                ...                                      ...          ...
# 505937            <NA>                          Form Contact Us         SEAP
# 505957   Karma Kandara                                     <NA>         <NA>
# 505969            <NA>  Karma Beach VIP membership sign up 2023         SEAP
# 505988  Karma Jimbaran                                Viewpoint         <NA>
# 506041   Karma Kandara                                     <NA>         <NA>
#
#        Lead Status Email Opt Out Opt In GDPR Compliant  \
# 0         New Lead         false  false          false
# 10        New Lead         false  false          false
# 12        New Lead         false  false          false
# 33        New Lead         false  false          false
# 86        New Lead         false  false          false
# ...            ...           ...    ...            ...
# 505937        <NA>         false   true          false
# 505957        <NA>         false   true          false
# 505969        <NA>         false   true          false
# 505988        <NA>         false   true          false
# 506041        <NA>         false   true          false
#
#                                                   Website Comments  \
# 0                                                    <NA>     <NA>
# 10                                                   <NA>     <NA>
# 12                                                   <NA>     <NA>
# 33                                                   <NA>     <NA>
# 86                                                   <NA>     <NA>
# ...                                                   ...      ...
# 505937  https://karmagroup.com/find-destination/karma-...     <NA>
# 505957                                               <NA>     <NA>
# 505969            https://karmagroup.com/karma-beach-vip/     <NA>
# 505988                                               <NA>     <NA>
# 506041                                               <NA>     <NA>
#
#        Do you live in Bali?
# 0                     false
# 10                    false
# 12                    false
# 33                    false
# 86                    false
# ...                     ...
# 505937                false
# 505957                false
# 505969                false
# 505988                false
# 506041                false
#
# [36388 rows x 35 columns]

# %%
path = r'/Users/dewiindahpurnama_/Library/CloudStorage/GoogleDrive-fajar.fatoni@karmagroup.com/My Drive/_BOOKING/Booking By Year/FlyBuy Booking Data (BGAU & BGID & KE).xlsx'
df_booking = pd.read_excel(path, dtype='string', sheet_name='BOOKING_BGAU_BGID_KE')

path = r'/Users/dewiindahpurnama_/Library/CloudStorage/GoogleDrive-fajar.fatoni@karmagroup.com/My Drive/_ODYSSEY/Phone Members.xlsx'
df_phone = pd.read_excel(path, dtype='string', sheet_name='Sheet1')

path = r'/Users/dewiindahpurnama_/Library/CloudStorage/GoogleDrive-fajar.fatoni@karmagroup.com/My Drive/_ODYSSEY/Email Members.xlsx'
df_email = pd.read_excel(path, dtype='string', sheet_name='Sheet1')

# %%
zoho_filter = fil.user_req(df)
zoho_df = df.loc[zoho_filter].copy() # menggunakan copy untuk menghindari setting copy warning
zoho_df.reset_index(drop=True, inplace=True)
count_filter_awal = zoho_df.shape[0]

# zoho_df.to_excel(r'C:\Users\fajar.fatoni\Documents\Python\Data\test_leads.xlsx', index=False)
# mengisi kolom <NA> dengan value string 'empty' supaya mudah mengecek data member dan booking dengan isin

zoho_df.fillna('empty', inplace=True)
zoho_df.sort_values('Created Time', ascending=True)
# Out:
# /var/folders/2q/56qtpvp16ylc5y0qp_v9js1w0000gn/T/ipykernel_5005/2027893311.py:9: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'empty' has dtype incompatible with datetime64[ns], please explicitly cast to a compatible dtype first.
#   zoho_df.fillna('empty', inplace=True)
#                    Record Id        Created Time Created Date  \
# 0   zcrm_3584690000500242001 2024-06-25 23:37:34        empty
# 1   zcrm_3584690000500659126 2024-06-30 01:59:39        empty
# 2   zcrm_3584690000503153040 2024-07-22 12:20:38        empty
# 3   zcrm_3584690000503538042 2024-07-25 21:57:00        empty
# 4   zcrm_3584690000504408001 2024-08-07 10:24:41        empty
# 5   zcrm_3584690000504960118 2024-08-16 12:52:08        empty
# 6   zcrm_3584690000505204001 2024-08-20 16:20:13        empty
# 7   zcrm_3584690000506044042 2024-08-30 10:49:51        empty
# 8   zcrm_3584690000506124034 2024-08-30 19:14:32        empty
# 9   zcrm_3584690000510697002 2024-10-02 14:15:31        empty
# 10  zcrm_3584690000519858011 2025-01-01 14:53:53        empty
# 12  zcrm_3584690000520283034 2025-01-08 04:49:22        empty
# 11  zcrm_3584690000520178108 2025-01-08 05:01:29        empty
# 13  zcrm_3584690000520542015 2025-01-10 15:24:39        empty
# 14  zcrm_3584690000525736001 2025-02-26 04:14:09        empty
# 15  zcrm_3584690000532278001 2025-03-19 16:35:09        empty
#
#                     First Name      Last Name  \
# 0                      Aleenah        Aleenah
# 1                         Gary           Gary
# 2                         Gary           Gary
# 3                         Doni       Prasetya
# 4                    Demetrios  Kyriakopoulos
# 5   Doni Mayfer Berry Prasetya       Prasetya
# 6                         Gary        Charles
# 7                         Gary        Charles
# 8                        Holly          Lange
# 9                         Matt     Harrington
# 10                       scott       atkinson
# 12                         kat         Pearce
# 11                         kat         Pearce
# 13                       Halie        Johnson
# 14                        Gary        Charles
# 15                 Jason David     Gilbertson
#
#                                   Email          Phone Mobile   Birthdate  \
# 0             ttqbjwbtbm.j@silesia.life              1  empty       empty
# 1   gary_charles@dominatingkeywords.com  +618185327032  empty       empty
# 2    garycharles@dominatingkeywords.com  +618185327032  empty       empty
# 3                donimayferbp@gmail.com  +618563755668  empty  1997-08-15
# 4                      jkyriakou@me.com  +610407296533  empty       empty
# 5                donimayfer12@gmail.com    +6145121678  empty  1997-05-24
# 6   gary_charles@dominatingkeywords.com  +618185327032  empty       empty
# 7    garycharles@dominatingkeywords.com  +618185327032  empty       empty
# 8             Hollychanelle@hotmail.com   +61431797773  empty       empty
# 9                 matt_lah@yahoo.com.sg   +61458827899  empty       empty
# 10          scottatkinson1979@gmail.com  +610419918057  empty       empty
# 12                     kwp744@gmail.com  +610412929135  empty       empty
# 11                     kwp744@gmail.com  +610412929135  empty       empty
# 13             haliebabie1209@gmail.com  +612019402400  empty       empty
# 14   garycharles@dominatingkeywords.com  +618054002077  empty       empty
# 15          jasongilbertson37@gmail.com   +61412437752  empty       empty
#
#    Year of Birth  ... Lead Locations  \
# 0           2015  ...        General
# 1          empty  ...        General
# 2          empty  ...        General
# 3           1997  ...        General
# 4           1974  ...        General
# 5           1997  ...        General
# 6          empty  ...        General
# 7          empty  ...        General
# 8           1988  ...        General
# 9           2009  ...        General
# 10          1980  ...        General
# 12          1970  ...        General
# 11          1970  ...        General
# 13         empty  ...        General
# 14         empty  ...        General
# 15         empty  ...        General
#
#                               Lead Source Description Lead Regions  \
# 0                   BGAU | Web | Form Homepage Bottom         SEAP
# 1                           BGAU | WEB | Contact Page         SEAP
# 2                           BGAU | WEB | Contact Page         SEAP
# 3   BGW | FB Org | w3June22 | Everyone is a Winner...         SEAP
# 4                   BGAU | Web | Form Homepage Bottom         SEAP
# 5   BGW | FB Org | w3June22 | Everyone is a Winner...         SEAP
# 6                           BGAU | WEB | Contact Page         SEAP
# 7                           BGAU | WEB | Contact Page         SEAP
# 8   BGAU | Web | Packages de Vins Sky Seminyak Bal...         SEAP
# 9                   BGAU | Web | Form Homepage Bottom         SEAP
# 10  BGAU | Web | Packages Swiss-Belresort Watu Jimbar         SEAP
# 12  BGAU | Web | Packages Swiss-Belresort Watu Jimbar         SEAP
# 11    BGAU | Web | Packages Away Bali Legian Camakila         SEAP
# 13                          BGAU | WEB | Contact Page         SEAP
# 14                          BGAU | WEB | Contact Page         SEAP
# 15                          BGAU | WEB | Contact Page         SEAP
#
#       Lead Status Email Opt Out Opt In GDPR Compliant Website Comments  \
# 0   Not Qualified         false  false          false   empty    empty
# 1        New Lead         false  false          false   empty    empty
# 2        New Lead         false  false          false   empty    empty
# 3    Hot Prospect         false  false          false   empty    empty
# 4    Hot Prospect         false  false          false   empty    empty
# 5    Hot Prospect         false  false          false   empty    empty
# 6        New Lead         false  false          false   empty    empty
# 7        New Lead         false  false          false   empty    empty
# 8    Hot Prospect         false  false          false   empty    empty
# 9   Not Qualified         false  false          false   empty    empty
# 10   Hot Prospect         false  false          false   empty    empty
# 12   Hot Prospect         false  false          false   empty    empty
# 11   Hot Prospect         false  false          false   empty    empty
# 13       New Lead         false  false          false   empty    empty
# 14       New Lead         false  false          false   empty    empty
# 15       New Lead         false  false          false   empty    empty
#
#    Do you live in Bali?
# 0                 false
# 1                 false
# 2                 false
# 3                 false
# 4                 false
# 5                 false
# 6                 false
# 7                 false
# 8                 false
# 9                 false
# 10                false
# 12                false
# 11                false
# 13                false
# 14                false
# 15                false
#
# [16 rows x 35 columns]

# %%
zoho_df.loc[zoho_df['Lead Source Description'].str.contains('walk', regex=True, flags=re.I)]
# Out:
# Empty DataFrame
# Columns: [Record Id, Created Time, Created Date, First Name, Last Name, Email, Phone, Mobile, Birthdate, Year of Birth, Street, Street2, City, State, Country, Nationality, Booking Status, BookRef, Departure Date, Arrival Date, Card Type, Marital Status, Lead Brand, Lead Sub-Brand, Lead Source, Lead Locations, Lead Source Description, Lead Regions, Lead Status, Email Opt Out, Opt In, GDPR Compliant, Website, Comments, Do you live in Bali?]
# Index: []
#
# [0 rows x 35 columns]

# %% [markdown]
# # ====================== Awal Filter Umum ======================

# %%
# data phone, mobile dam email member yang ada di master data (wash member)

m.clean_number(zoho_df, 'Phone')
m.clean_number(zoho_df, 'Mobile')
m.replace_not_valid_to_empty(zoho_df, 'Phone')
m.replace_not_valid_to_empty(zoho_df, 'Mobile')
zoho_df['Email'] = m.lowercase(zoho_df, 'Email')
m.clean_space(zoho_df, 'Email')
m.clean_not_valid_email_format(zoho_df, 'Email')

m.clean_number(df_booking, 'Phone1')
m.clean_number(df_booking, 'Mobile')
df_booking['Email'] = m.lowercase(df_booking, 'Email')
m.clean_space(df_booking, 'Email')
m.clean_not_valid_email_format(df_booking, 'Email')

m.clean_number(df_phone, 'Mobile')

df_email['Email'] = m.lowercase(df_email, 'Email')
m.clean_space(df_email, 'Email')
m.clean_not_valid_email_format(df_email, 'Email')
# Out:
# /Users/dewiindahpurnama_/Documents/Python/python.github.io/zoho_data_app/main_module.py:104: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#
# /Users/dewiindahpurnama_/Documents/Python/python.github.io/zoho_data_app/main_module.py:105: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df.loc[df[df_columns].str.len() < 5, df_columns] = 'empty'
# /Users/dewiindahpurnama_/Documents/Python/python.github.io/zoho_data_app/main_module.py:127: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   (df[df_columns] != 'empty')
# /Users/dewiindahpurnama_/Documents/Python/python.github.io/zoho_data_app/main_module.py:104: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#
# /Users/dewiindahpurnama_/Documents/Python/python.github.io/zoho_data_app/main_module.py:105: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df.loc[df[df_columns].str.len() < 5, df_columns] = 'empty'
# 'Email'

# %%
zoho_df.loc[zoho_df['Phone']=='']
# Out:
# Empty DataFrame
# Columns: [Record Id, Created Time, Created Date, First Name, Last Name, Email, Phone, Mobile, Birthdate, Year of Birth, Street, Street2, City, State, Country, Nationality, Booking Status, BookRef, Departure Date, Arrival Date, Card Type, Marital Status, Lead Brand, Lead Sub-Brand, Lead Source, Lead Locations, Lead Source Description, Lead Regions, Lead Status, Email Opt Out, Opt In, GDPR Compliant, Website, Comments, Do you live in Bali?]
# Index: []
#
# [0 rows x 35 columns]

# %%
count_deleted_wrong_format = m.delete_email_wrong_format(zoho_df, 'Email')
count_after_deleted_wrong_format = zoho_df.shape[0]

# %%
# hitung jumlah duplicate
count_duplicate_general = zoho_df.loc[zoho_df.duplicated(subset=['Phone','Email', 'Mobile'])].shape[0]

zoho_df.loc[zoho_df.duplicated(subset=['Phone','Email', 'Mobile'])]
# Out:
#                    Record Id        Created Time Created Date First Name  \
# 6   zcrm_3584690000505204001 2024-08-20 16:20:13        empty       Gary
# 7   zcrm_3584690000506044042 2024-08-30 10:49:51        empty       Gary
# 12  zcrm_3584690000520283034 2025-01-08 04:49:22        empty        kat
#
#    Last Name                                Email         Phone Mobile  \
# 6    Charles  gary_charles@dominatingkeywords.com  618185327032  empty
# 7    Charles   garycharles@dominatingkeywords.com  618185327032  empty
# 12    Pearce                     kwp744@gmail.com  610412929135  empty
#
#    Birthdate Year of Birth  ... Lead Locations  \
# 6      empty         empty  ...        General
# 7      empty         empty  ...        General
# 12     empty          1970  ...        General
#
#                               Lead Source Description Lead Regions  \
# 6                           BGAU | WEB | Contact Page         SEAP
# 7                           BGAU | WEB | Contact Page         SEAP
# 12  BGAU | Web | Packages Swiss-Belresort Watu Jimbar         SEAP
#
#      Lead Status Email Opt Out Opt In GDPR Compliant Website Comments  \
# 6       New Lead         false  false          false   empty    empty
# 7       New Lead         false  false          false   empty    empty
# 12  Hot Prospect         false  false          false   empty    empty
#
#    Do you live in Bali?
# 6                 false
# 7                 false
# 12                false
#
# [3 rows x 35 columns]

# %%
zoho_df.drop_duplicates(subset=['Phone','Email', 'Mobile'], inplace=True)
zoho_df.reset_index(drop=True, inplace=True)

# hitung jumlah setelah value duplicate dihapus
count_after_dedup_duplicate = zoho_df.shape[0]

zoho_df
# Out:
#                    Record Id        Created Time Created Date  \
# 0   zcrm_3584690000500242001 2024-06-25 23:37:34        empty
# 1   zcrm_3584690000500659126 2024-06-30 01:59:39        empty
# 2   zcrm_3584690000503153040 2024-07-22 12:20:38        empty
# 3   zcrm_3584690000503538042 2024-07-25 21:57:00        empty
# 4   zcrm_3584690000504408001 2024-08-07 10:24:41        empty
# 5   zcrm_3584690000504960118 2024-08-16 12:52:08        empty
# 6   zcrm_3584690000506124034 2024-08-30 19:14:32        empty
# 7   zcrm_3584690000510697002 2024-10-02 14:15:31        empty
# 8   zcrm_3584690000519858011 2025-01-01 14:53:53        empty
# 9   zcrm_3584690000520178108 2025-01-08 05:01:29        empty
# 10  zcrm_3584690000520542015 2025-01-10 15:24:39        empty
# 11  zcrm_3584690000525736001 2025-02-26 04:14:09        empty
# 12  zcrm_3584690000532278001 2025-03-19 16:35:09        empty
#
#                     First Name      Last Name  \
# 0                      Aleenah        Aleenah
# 1                         Gary           Gary
# 2                         Gary           Gary
# 3                         Doni       Prasetya
# 4                    Demetrios  Kyriakopoulos
# 5   Doni Mayfer Berry Prasetya       Prasetya
# 6                        Holly          Lange
# 7                         Matt     Harrington
# 8                        scott       atkinson
# 9                          kat         Pearce
# 10                       Halie        Johnson
# 11                        Gary        Charles
# 12                 Jason David     Gilbertson
#
#                                   Email         Phone Mobile   Birthdate  \
# 0             ttqbjwbtbm.j@silesia.life         empty  empty       empty
# 1   gary_charles@dominatingkeywords.com  618185327032  empty       empty
# 2    garycharles@dominatingkeywords.com  618185327032  empty       empty
# 3                donimayferbp@gmail.com  618563755668  empty  1997-08-15
# 4                      jkyriakou@me.com  610407296533  empty       empty
# 5                donimayfer12@gmail.com    6145121678  empty  1997-05-24
# 6             hollychanelle@hotmail.com   61431797773  empty       empty
# 7                 matt_lah@yahoo.com.sg   61458827899  empty       empty
# 8           scottatkinson1979@gmail.com  610419918057  empty       empty
# 9                      kwp744@gmail.com  610412929135  empty       empty
# 10             haliebabie1209@gmail.com  612019402400  empty       empty
# 11   garycharles@dominatingkeywords.com  618054002077  empty       empty
# 12          jasongilbertson37@gmail.com   61412437752  empty       empty
#
#    Year of Birth  ... Lead Locations  \
# 0           2015  ...        General
# 1          empty  ...        General
# 2          empty  ...        General
# 3           1997  ...        General
# 4           1974  ...        General
# 5           1997  ...        General
# 6           1988  ...        General
# 7           2009  ...        General
# 8           1980  ...        General
# 9           1970  ...        General
# 10         empty  ...        General
# 11         empty  ...        General
# 12         empty  ...        General
#
#                               Lead Source Description Lead Regions  \
# 0                   BGAU | Web | Form Homepage Bottom         SEAP
# 1                           BGAU | WEB | Contact Page         SEAP
# 2                           BGAU | WEB | Contact Page         SEAP
# 3   BGW | FB Org | w3June22 | Everyone is a Winner...         SEAP
# 4                   BGAU | Web | Form Homepage Bottom         SEAP
# 5   BGW | FB Org | w3June22 | Everyone is a Winner...         SEAP
# 6   BGAU | Web | Packages de Vins Sky Seminyak Bal...         SEAP
# 7                   BGAU | Web | Form Homepage Bottom         SEAP
# 8   BGAU | Web | Packages Swiss-Belresort Watu Jimbar         SEAP
# 9     BGAU | Web | Packages Away Bali Legian Camakila         SEAP
# 10                          BGAU | WEB | Contact Page         SEAP
# 11                          BGAU | WEB | Contact Page         SEAP
# 12                          BGAU | WEB | Contact Page         SEAP
#
#       Lead Status Email Opt Out Opt In GDPR Compliant Website Comments  \
# 0   Not Qualified         false  false          false   empty    empty
# 1        New Lead         false  false          false   empty    empty
# 2        New Lead         false  false          false   empty    empty
# 3    Hot Prospect         false  false          false   empty    empty
# 4    Hot Prospect         false  false          false   empty    empty
# 5    Hot Prospect         false  false          false   empty    empty
# 6    Hot Prospect         false  false          false   empty    empty
# 7   Not Qualified         false  false          false   empty    empty
# 8    Hot Prospect         false  false          false   empty    empty
# 9    Hot Prospect         false  false          false   empty    empty
# 10       New Lead         false  false          false   empty    empty
# 11       New Lead         false  false          false   empty    empty
# 12       New Lead         false  false          false   empty    empty
#
#    Do you live in Bali?
# 0                 false
# 1                 false
# 2                 false
# 3                 false
# 4                 false
# 5                 false
# 6                 false
# 7                 false
# 8                 false
# 9                 false
# 10                false
# 11                false
# 12                false
#
# [13 rows x 35 columns]

# %%
# Cek leads test
test_leads = zoho_df.loc[
    
        zoho_df['Email'].str.contains('^test@', flags=re.I, regex=True) |
        zoho_df['Email'].str.contains('\+test', flags=re.I, regex=True) |
    
        zoho_df['First Name'].str.contains('^test$', flags=re.I, regex=True) |
        zoho_df['Last Name'].str.contains('^test$', flags=re.I, regex=True) |

        zoho_df['First Name'].str.contains('test 1', flags=re.I, regex=True) |
        zoho_df['Last Name'].str.contains('test 2', flags=re.I, regex=True)|
        zoho_df['First Name'].str.contains('test1', flags=re.I, regex=True) |
        zoho_df['Last Name'].str.contains('test2', flags=re.I, regex=True)|

        zoho_df['First Name'].str.contains(' test ', flags=re.I, regex=True) | 
        zoho_df['Last Name'].str.contains(' test ', flags=re.I, regex=True) | 
        zoho_df['Last Name'].str.contains(' test$', flags=re.I, regex=True)
    ]

count_leads_test = test_leads.shape[0]

# test_leads.to_excel(r'C:\Users\fajar.fatoni\Documents\Python\Data\test_leads_2.xlsx', index=False)
test_leads
# Out:
# Empty DataFrame
# Columns: [Record Id, Created Time, Created Date, First Name, Last Name, Email, Phone, Mobile, Birthdate, Year of Birth, Street, Street2, City, State, Country, Nationality, Booking Status, BookRef, Departure Date, Arrival Date, Card Type, Marital Status, Lead Brand, Lead Sub-Brand, Lead Source, Lead Locations, Lead Source Description, Lead Regions, Lead Status, Email Opt Out, Opt In, GDPR Compliant, Website, Comments, Do you live in Bali?]
# Index: []
#
# [0 rows x 35 columns]

# %%
zoho_df.drop(test_leads.index, inplace=True)
zoho_df.reset_index(drop=True, inplace=True)

count_after_dedup_test = zoho_df.shape[0]

# %%
# dnm_leads = zoho_df.loc[(zoho_df['Do Not Mail'] == 'true') | (zoho_df['Do Not Contact'] == 'true')]
# count_dnm = dnm_leads.shape[0]

# %%
# zoho_df.drop(dnm_leads.index, inplace=True)
# zoho_df.reset_index(drop=True, inplace=True)

# count_after_dedup_dnm = zoho_df.shape[0]

# %%
# Cek Email OTA
email_OTA = m.find_OTA(zoho_df, 'Email')
count_email_OTA = email_OTA.shape[0]
# email_OTA.to_excel(r'C:\Users\fajar.fatoni\Documents\Python\Data\email_OTA.xlsx', index=False)

email_OTA
# Out:
# Empty DataFrame
# Columns: [Record Id, Created Time, Created Date, First Name, Last Name, Email, Phone, Mobile, Birthdate, Year of Birth, Street, Street2, City, State, Country, Nationality, Booking Status, BookRef, Departure Date, Arrival Date, Card Type, Marital Status, Lead Brand, Lead Sub-Brand, Lead Source, Lead Locations, Lead Source Description, Lead Regions, Lead Status, Email Opt Out, Opt In, GDPR Compliant, Website, Comments, Do you live in Bali?]
# Index: []
#
# [0 rows x 35 columns]

# %%
# delete email OTA
count_after_clean_OTA = m.delete_OTA(zoho_df, 'Email')
# zoho_df.to_excel(r'C:\Users\fajar.fatoni\Documents\Python\Data\after_clean_OTA.xlsx', index=False)

zoho_df
# Out:
#                    Record Id        Created Time Created Date  \
# 0   zcrm_3584690000500242001 2024-06-25 23:37:34        empty
# 1   zcrm_3584690000500659126 2024-06-30 01:59:39        empty
# 2   zcrm_3584690000503153040 2024-07-22 12:20:38        empty
# 3   zcrm_3584690000503538042 2024-07-25 21:57:00        empty
# 4   zcrm_3584690000504408001 2024-08-07 10:24:41        empty
# 5   zcrm_3584690000504960118 2024-08-16 12:52:08        empty
# 6   zcrm_3584690000506124034 2024-08-30 19:14:32        empty
# 7   zcrm_3584690000510697002 2024-10-02 14:15:31        empty
# 8   zcrm_3584690000519858011 2025-01-01 14:53:53        empty
# 9   zcrm_3584690000520178108 2025-01-08 05:01:29        empty
# 10  zcrm_3584690000520542015 2025-01-10 15:24:39        empty
# 11  zcrm_3584690000525736001 2025-02-26 04:14:09        empty
# 12  zcrm_3584690000532278001 2025-03-19 16:35:09        empty
#
#                     First Name      Last Name  \
# 0                      Aleenah        Aleenah
# 1                         Gary           Gary
# 2                         Gary           Gary
# 3                         Doni       Prasetya
# 4                    Demetrios  Kyriakopoulos
# 5   Doni Mayfer Berry Prasetya       Prasetya
# 6                        Holly          Lange
# 7                         Matt     Harrington
# 8                        scott       atkinson
# 9                          kat         Pearce
# 10                       Halie        Johnson
# 11                        Gary        Charles
# 12                 Jason David     Gilbertson
#
#                                   Email         Phone Mobile   Birthdate  \
# 0             ttqbjwbtbm.j@silesia.life         empty  empty       empty
# 1   gary_charles@dominatingkeywords.com  618185327032  empty       empty
# 2    garycharles@dominatingkeywords.com  618185327032  empty       empty
# 3                donimayferbp@gmail.com  618563755668  empty  1997-08-15
# 4                      jkyriakou@me.com  610407296533  empty       empty
# 5                donimayfer12@gmail.com    6145121678  empty  1997-05-24
# 6             hollychanelle@hotmail.com   61431797773  empty       empty
# 7                 matt_lah@yahoo.com.sg   61458827899  empty       empty
# 8           scottatkinson1979@gmail.com  610419918057  empty       empty
# 9                      kwp744@gmail.com  610412929135  empty       empty
# 10             haliebabie1209@gmail.com  612019402400  empty       empty
# 11   garycharles@dominatingkeywords.com  618054002077  empty       empty
# 12          jasongilbertson37@gmail.com   61412437752  empty       empty
#
#    Year of Birth  ... Lead Locations  \
# 0           2015  ...        General
# 1          empty  ...        General
# 2          empty  ...        General
# 3           1997  ...        General
# 4           1974  ...        General
# 5           1997  ...        General
# 6           1988  ...        General
# 7           2009  ...        General
# 8           1980  ...        General
# 9           1970  ...        General
# 10         empty  ...        General
# 11         empty  ...        General
# 12         empty  ...        General
#
#                               Lead Source Description Lead Regions  \
# 0                   BGAU | Web | Form Homepage Bottom         SEAP
# 1                           BGAU | WEB | Contact Page         SEAP
# 2                           BGAU | WEB | Contact Page         SEAP
# 3   BGW | FB Org | w3June22 | Everyone is a Winner...         SEAP
# 4                   BGAU | Web | Form Homepage Bottom         SEAP
# 5   BGW | FB Org | w3June22 | Everyone is a Winner...         SEAP
# 6   BGAU | Web | Packages de Vins Sky Seminyak Bal...         SEAP
# 7                   BGAU | Web | Form Homepage Bottom         SEAP
# 8   BGAU | Web | Packages Swiss-Belresort Watu Jimbar         SEAP
# 9     BGAU | Web | Packages Away Bali Legian Camakila         SEAP
# 10                          BGAU | WEB | Contact Page         SEAP
# 11                          BGAU | WEB | Contact Page         SEAP
# 12                          BGAU | WEB | Contact Page         SEAP
#
#       Lead Status Email Opt Out Opt In GDPR Compliant Website Comments  \
# 0   Not Qualified         false  false          false   empty    empty
# 1        New Lead         false  false          false   empty    empty
# 2        New Lead         false  false          false   empty    empty
# 3    Hot Prospect         false  false          false   empty    empty
# 4    Hot Prospect         false  false          false   empty    empty
# 5    Hot Prospect         false  false          false   empty    empty
# 6    Hot Prospect         false  false          false   empty    empty
# 7   Not Qualified         false  false          false   empty    empty
# 8    Hot Prospect         false  false          false   empty    empty
# 9    Hot Prospect         false  false          false   empty    empty
# 10       New Lead         false  false          false   empty    empty
# 11       New Lead         false  false          false   empty    empty
# 12       New Lead         false  false          false   empty    empty
#
#    Do you live in Bali?
# 0                 false
# 1                 false
# 2                 false
# 3                 false
# 4                 false
# 5                 false
# 6                 false
# 7                 false
# 8                 false
# 9                 false
# 10                false
# 11                false
# 12                false
#
# [13 rows x 35 columns]

# %%
# Cek Email Karma
email_karma = m.find_karma(zoho_df, 'Email')
count_email_karma = email_karma.shape[0]
# email_OTA.to_excel(r'C:\Users\fajar.fatoni\Documents\Python\Data\email_OTA.xlsx', index=False)

email_karma
# Out:
# Empty DataFrame
# Columns: [Record Id, Created Time, Created Date, First Name, Last Name, Email, Phone, Mobile, Birthdate, Year of Birth, Street, Street2, City, State, Country, Nationality, Booking Status, BookRef, Departure Date, Arrival Date, Card Type, Marital Status, Lead Brand, Lead Sub-Brand, Lead Source, Lead Locations, Lead Source Description, Lead Regions, Lead Status, Email Opt Out, Opt In, GDPR Compliant, Website, Comments, Do you live in Bali?]
# Index: []
#
# [0 rows x 35 columns]

# %%
# delete email Karma
count_after_clean_karma = m.delete_karma(zoho_df, 'Email')
# zoho_df.to_excel(r'C:\Users\fajar.fatoni\Documents\Python\Data\after_clean_OTA.xlsx', index=False)

zoho_df
# Out:
#                    Record Id        Created Time Created Date  \
# 0   zcrm_3584690000500242001 2024-06-25 23:37:34        empty
# 1   zcrm_3584690000500659126 2024-06-30 01:59:39        empty
# 2   zcrm_3584690000503153040 2024-07-22 12:20:38        empty
# 3   zcrm_3584690000503538042 2024-07-25 21:57:00        empty
# 4   zcrm_3584690000504408001 2024-08-07 10:24:41        empty
# 5   zcrm_3584690000504960118 2024-08-16 12:52:08        empty
# 6   zcrm_3584690000506124034 2024-08-30 19:14:32        empty
# 7   zcrm_3584690000510697002 2024-10-02 14:15:31        empty
# 8   zcrm_3584690000519858011 2025-01-01 14:53:53        empty
# 9   zcrm_3584690000520178108 2025-01-08 05:01:29        empty
# 10  zcrm_3584690000520542015 2025-01-10 15:24:39        empty
# 11  zcrm_3584690000525736001 2025-02-26 04:14:09        empty
# 12  zcrm_3584690000532278001 2025-03-19 16:35:09        empty
#
#                     First Name      Last Name  \
# 0                      Aleenah        Aleenah
# 1                         Gary           Gary
# 2                         Gary           Gary
# 3                         Doni       Prasetya
# 4                    Demetrios  Kyriakopoulos
# 5   Doni Mayfer Berry Prasetya       Prasetya
# 6                        Holly          Lange
# 7                         Matt     Harrington
# 8                        scott       atkinson
# 9                          kat         Pearce
# 10                       Halie        Johnson
# 11                        Gary        Charles
# 12                 Jason David     Gilbertson
#
#                                   Email         Phone Mobile   Birthdate  \
# 0             ttqbjwbtbm.j@silesia.life         empty  empty       empty
# 1   gary_charles@dominatingkeywords.com  618185327032  empty       empty
# 2    garycharles@dominatingkeywords.com  618185327032  empty       empty
# 3                donimayferbp@gmail.com  618563755668  empty  1997-08-15
# 4                      jkyriakou@me.com  610407296533  empty       empty
# 5                donimayfer12@gmail.com    6145121678  empty  1997-05-24
# 6             hollychanelle@hotmail.com   61431797773  empty       empty
# 7                 matt_lah@yahoo.com.sg   61458827899  empty       empty
# 8           scottatkinson1979@gmail.com  610419918057  empty       empty
# 9                      kwp744@gmail.com  610412929135  empty       empty
# 10             haliebabie1209@gmail.com  612019402400  empty       empty
# 11   garycharles@dominatingkeywords.com  618054002077  empty       empty
# 12          jasongilbertson37@gmail.com   61412437752  empty       empty
#
#    Year of Birth  ... Lead Locations  \
# 0           2015  ...        General
# 1          empty  ...        General
# 2          empty  ...        General
# 3           1997  ...        General
# 4           1974  ...        General
# 5           1997  ...        General
# 6           1988  ...        General
# 7           2009  ...        General
# 8           1980  ...        General
# 9           1970  ...        General
# 10         empty  ...        General
# 11         empty  ...        General
# 12         empty  ...        General
#
#                               Lead Source Description Lead Regions  \
# 0                   BGAU | Web | Form Homepage Bottom         SEAP
# 1                           BGAU | WEB | Contact Page         SEAP
# 2                           BGAU | WEB | Contact Page         SEAP
# 3   BGW | FB Org | w3June22 | Everyone is a Winner...         SEAP
# 4                   BGAU | Web | Form Homepage Bottom         SEAP
# 5   BGW | FB Org | w3June22 | Everyone is a Winner...         SEAP
# 6   BGAU | Web | Packages de Vins Sky Seminyak Bal...         SEAP
# 7                   BGAU | Web | Form Homepage Bottom         SEAP
# 8   BGAU | Web | Packages Swiss-Belresort Watu Jimbar         SEAP
# 9     BGAU | Web | Packages Away Bali Legian Camakila         SEAP
# 10                          BGAU | WEB | Contact Page         SEAP
# 11                          BGAU | WEB | Contact Page         SEAP
# 12                          BGAU | WEB | Contact Page         SEAP
#
#       Lead Status Email Opt Out Opt In GDPR Compliant Website Comments  \
# 0   Not Qualified         false  false          false   empty    empty
# 1        New Lead         false  false          false   empty    empty
# 2        New Lead         false  false          false   empty    empty
# 3    Hot Prospect         false  false          false   empty    empty
# 4    Hot Prospect         false  false          false   empty    empty
# 5    Hot Prospect         false  false          false   empty    empty
# 6    Hot Prospect         false  false          false   empty    empty
# 7   Not Qualified         false  false          false   empty    empty
# 8    Hot Prospect         false  false          false   empty    empty
# 9    Hot Prospect         false  false          false   empty    empty
# 10       New Lead         false  false          false   empty    empty
# 11       New Lead         false  false          false   empty    empty
# 12       New Lead         false  false          false   empty    empty
#
#    Do you live in Bali?
# 0                 false
# 1                 false
# 2                 false
# 3                 false
# 4                 false
# 5                 false
# 6                 false
# 7                 false
# 8                 false
# 9                 false
# 10                false
# 11                false
# 12                false
#
# [13 rows x 35 columns]

# %%
find_member_booking = zoho_df.copy()

find_member_booking.loc[find_member_booking['Phone'].isin(df_booking['Phone1']), 'Same Value Find'] = 'Booking-Phone1'
find_member_booking.loc[find_member_booking['Phone'].isin(df_booking['Mobile']), 'Same Value Find'] = 'Booking-Mobile'
find_member_booking.loc[find_member_booking['Mobile'].isin(df_booking['Phone1']), 'Same Value Find'] = 'Booking-Phone1' 
find_member_booking.loc[find_member_booking['Mobile'].isin(df_booking['Mobile']), 'Same Value Find'] = 'Booking-Mobile'
find_member_booking.loc[find_member_booking['Email'].isin(df_booking['Email']), 'Same Value Find'] = 'Booking-Email'

find_member_booking.loc[find_member_booking['Phone'].isin(df_phone['Mobile']), 'Same Value Find'] = 'Member-Mobile' 
find_member_booking.loc[find_member_booking['Mobile'].isin(df_phone['Mobile']), 'Same Value Find'] = 'Member-Mobile'

find_member_booking.loc[find_member_booking['Email'].isin(df_email['Email']), 'Same Value Find'] = 'Member-Email'

find_member_booking.drop(find_member_booking.loc[find_member_booking['Same Value Find'].isna()].index, inplace=True)

count_booking_dedup = find_member_booking.loc[find_member_booking['Same Value Find'].str.contains('Booking', flags=re.I, regex=True)].shape[0]
count_member_dedup = find_member_booking.loc[find_member_booking['Same Value Find'].str.contains('Member', flags=re.I, regex=True)].shape[0]

find_member_booking.replace('empty', '', inplace=True)
# find_member_booking.to_csv(r'C:\Users\fajar.fatoni\Documents\Python\Data\booking-member-dedup.csv', index=False)
# find_member_booking.to_excel(r'C:\Users\fajar.fatoni\Documents\Python\Data\booking-member-dedup.xlsx', index=False)

#find_member_booking.loc[find_member_booking['Same Value Find'] == 'Booking-Phone1']

# %%
# data phone, mobile dam email member yang ada di master data 
count_wash_member = zoho_df.loc[
    zoho_df['Phone'].isin(df_booking['Phone1']) | 
    zoho_df['Phone'].isin(df_booking['Mobile']) |
    zoho_df['Mobile'].isin(df_booking['Phone1']) | 
    zoho_df['Mobile'].isin(df_booking['Mobile']) |
    zoho_df['Email'].isin(df_booking['Email'])| 

    zoho_df['Phone'].isin(df_phone['Mobile']) | 
    zoho_df['Mobile'].isin(df_phone['Mobile']) |

    zoho_df['Email'].isin(df_email['Email'])

].shape[0]

zoho_df.drop(zoho_df.loc[
    zoho_df['Phone'].isin(df_booking['Phone1']) | 
    zoho_df['Phone'].isin(df_booking['Mobile']) |
    zoho_df['Mobile'].isin(df_booking['Phone1']) | 
    zoho_df['Mobile'].isin(df_booking['Mobile']) |
    zoho_df['Email'].isin(df_booking['Email']) |
    
    zoho_df['Phone'].isin(df_phone['Mobile']) | 
    zoho_df['Mobile'].isin(df_phone['Mobile']) |

    zoho_df['Email'].isin(df_email['Email'])

    ].index, inplace=True)
    
zoho_df.reset_index(drop=True, inplace=True)

count_after_wash_member = zoho_df.shape[0]

# %%
# Categorize contacts
m.categorize_contacts(zoho_df)

# Count contact types
count_email_only = (zoho_df['Contact Type'] == 'Email Only').sum()
count_phone_only = (zoho_df['Contact Type'] == 'Phone Only').sum()
count_email_and_phone = (zoho_df['Contact Type'] == 'Email and Phone').sum()
count_blank = (zoho_df['Contact Type'] == 'Blank').sum()

# Remove blank contacts if needed
zoho_df = zoho_df[zoho_df['Contact Type'] != 'Blank']
zoho_df.reset_index(drop=True, inplace=True)

count_after_wash_blank = zoho_df.shape[0]

# %%
arr_dedup = [count_deleted_wrong_format, count_duplicate_general, count_leads_test, count_email_OTA, count_email_karma, count_blank]
count_sum_dedup = sum(arr_dedup)
count_sum_dedup
# Out:
# np.int64(3)

# %%
print("==========================================================")
print("Summary")
print("==========================================================")
print("Jumlah Keseluruhan Master Zoho : "+str(count_data_awal))
print("Jumlah Filter Leads Awal : "+str(count_filter_awal))
print("Jumlah Format Email Salah : "+str(count_deleted_wrong_format))
print("Jumlah Setelah Clean Format Email Salah : "+str(count_after_deleted_wrong_format))
print("Jumlah Duplicate (Phone, Mobile dan Email) : "+str(count_duplicate_general))
print("Jumlah Setelah Clean Duplicate : "+str(count_after_dedup_duplicate))
print("Jumlah Lead Test : "+str(count_leads_test))
print("Jumlah Setelah Clean Lead Test : "+str(count_after_dedup_test))
# print("Jumlah Lead Do Not Mail : "+str(count_dnm))
# print("Jumlah Setelah Clean Lead Do Not Mail : "+str(count_after_dedup_dnm))
print("Jumlah Email OTA : "+str(count_email_OTA))
print("Jumlah Setelah Clean Email OTA : "+str(count_after_clean_OTA))
print("Jumlah Email Karma : "+str(count_email_karma))
print("Jumlah Setelah Clean Email Karma : "+str(count_after_clean_karma))
print("Jumlah Wash Member : "+str(count_member_dedup))
print("Jumlah Wash Booking : "+str(count_booking_dedup))
print("Jumlah Setelah Wash Member : "+str(count_after_wash_member))
print("Jumlah Phone Email Blank (Setelah phone yang tidak valid dihapus) : "+str(count_blank))
print("Jumlah Setelah Wash Phone Email Blank : "+str(count_after_wash_blank))
print("==========================================================")
print("Contact Type")
print("==========================================================")
print("Jumlah Email Only : "+str(count_email_only))
print("Jumlah Phone Only : "+str(count_phone_only))
print("Jumlah Email dan Phone : "+str(count_email_and_phone))
# Out:
# ==========================================================
# Summary
# ==========================================================
# Jumlah Keseluruhan Master Zoho : 506073
# Jumlah Filter Leads Awal : 16
# Jumlah Format Email Salah : 0
# Jumlah Setelah Clean Format Email Salah : 16
# Jumlah Duplicate (Phone, Mobile dan Email) : 3
# Jumlah Setelah Clean Duplicate : 13
# Jumlah Lead Test : 0
# Jumlah Setelah Clean Lead Test : 13
# Jumlah Email OTA : 0
# Jumlah Setelah Clean Email OTA : 13
# Jumlah Email Karma : 0
# Jumlah Setelah Clean Email Karma : 13
# Jumlah Wash Member : 0
# Jumlah Wash Booking : 2
# Jumlah Setelah Wash Member : 11
# Jumlah Phone Email Blank (Setelah phone yang tidak valid dihapus) : 0
# Jumlah Setelah Wash Phone Email Blank : 11
# ==========================================================
# Contact Type
# ==========================================================
# Jumlah Email Only : 1
# Jumlah Phone Only : 0
# Jumlah Email dan Phone : 10

# %%
print("==========================================================")
print("Summary Report")
print("==========================================================")
print("Jumlah Data Awal : "+str(count_filter_awal))
print("Jumlah Wash Dedup : "+str(count_sum_dedup))
print("Jumlah Wash Member : "+str(count_member_dedup))
print("Jumlah Wash Booking : "+str(count_booking_dedup))
print("Jumlah Data Akhir : "+str(count_after_wash_blank))
# Out:
# ==========================================================
# Summary Report
# ==========================================================
# Jumlah Data Awal : 16
# Jumlah Wash Dedup : 3
# Jumlah Wash Member : 0
# Jumlah Wash Booking : 2
# Jumlah Data Akhir : 11

# %% [markdown]
# # ====================== Akhir Filter Umum ======================

# %%
# Function to clean illegal characters except "Created Time"
def clean_illegal_chars(df):
    def remove_illegal_chars(value):
        if isinstance(value, str):
            return "".join(c for c in value if ord(c) >= 32)
        return value
    
    # Apply cleaning only to non-"Created Time" columns
    for col in df.columns:
        if col != "Created Time":  # Exclude "Created Time" from cleaning
            df[col] = df[col].apply(remove_illegal_chars)

    return df

# Load your dataframe (zoho_df assumed to be already loaded)
zoho_df.replace('empty', '', inplace=True, regex=True)

# Format name columns properly
zoho_df['First Name'] = zoho_df['First Name'].str.title()
zoho_df['Last Name'] = zoho_df['Last Name'].str.title()

# Define output path
output_path = r'/Users/dewiindahpurnama_/Documents/Python/Data/karma_experience.xlsx'

try:
    zoho_df.to_excel(output_path, index=False)
except IllegalCharacterError:
    print("IllegalCharacterError detected! Cleaning data...")
    zoho_df = clean_illegal_chars(zoho_df)  # Clean only non-"Created Time" columns
    zoho_df.to_excel(output_path, index=False)
    print("File saved successfully after cleaning.")

print(f"File saved at: {output_path}")
# Out:
# File saved at: /Users/dewiindahpurnama_/Documents/Python/Data/karma_experience.xlsx

# %%
zoho_df.groupby('Country').count()
# Out:
#                            Record Id  Created Time  Created Date  First Name  \
# Country
#                                    4             4             4           4
# 1                                  1             1             1           1
# Australia                          2             2             2           2
# BGAU | WEB | Contact Page          3             3             3           3
# Bgau | Web | Contact Page          1             1             1           1
#
#                            Last Name  Email  Phone  Mobile  Birthdate  \
# Country
#                                    4      4      4       4          4
# 1                                  1      1      1       1          1
# Australia                          2      2      2       2          2
# BGAU | WEB | Contact Page          3      3      3       3          3
# Bgau | Web | Contact Page          1      1      1       1          1
#
#                            Year of Birth  ...  Lead Source Description  \
# Country                                   ...
#                                        4  ...                        4
# 1                                      1  ...                        1
# Australia                              2  ...                        2
# BGAU | WEB | Contact Page              3  ...                        3
# Bgau | Web | Contact Page              1  ...                        1
#
#                            Lead Regions  Lead Status  Email Opt Out  Opt In  \
# Country
#                                       4            4              4       4
# 1                                     1            1              1       1
# Australia                             2            2              2       2
# BGAU | WEB | Contact Page             3            3              3       3
# Bgau | Web | Contact Page             1            1              1       1
#
#                            GDPR Compliant  Website  Comments  \
# Country
#                                         4        4         4
# 1                                       1        1         1
# Australia                               2        2         2
# BGAU | WEB | Contact Page               3        3         3
# Bgau | Web | Contact Page               1        1         1
#
#                            Do you live in Bali?  Contact Type
# Country
#                                               4             4
# 1                                             1             1
# Australia                                     2             2
# BGAU | WEB | Contact Page                     3             3
# Bgau | Web | Contact Page                     1             1
#
# [5 rows x 35 columns]

# %%
# zoho_df['Country'].loc[
#     (zoho_df['Phone'].str.contains('^44|^\+44')) & 
#     (~zoho_df['Country'].str.contains('united kingdom|wales|england|scotland|northern ireland', regex=True, flags=re.I))
# ]
