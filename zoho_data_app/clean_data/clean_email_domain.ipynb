# %%
# %load_ext autoreload
# %autoreload 2

import sys
sys.path.append('../')

import main_module as m
import zoho_filter_module as fil
import pandas as pd
import re
import numpy as np

dir_path = r'C:\Users\fajar\Documents\Python\Data\Zoho_Backup'
file_name = '\Leads_'
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
path = r'C:\Users\fajar\Documents\Python\Data\import_errors_259577.csv'
df = pd.read_csv(path, on_bad_lines='skip')
count_data_awal = df.shape[0]
df.fillna('', inplace=True)
df
# Out:
#                                            Email error   Number ContactID  \
# 0    email address has an invalid domain (the part ...    18843     22583
# 1    email address has an invalid domain (the part ...    71405     77551
# 2    email address has an invalid domain (the part ...  1018220    947227
# 3    email address has an invalid domain (the part ...   108069    147633
# 4    email address has an invalid domain (the part ...   104335      1042
# ..                                                 ...      ...       ...
# 632  email address had a syntax error and can't be ...
# 633  email address had a syntax error and can't be ...
# 634  email address had a syntax error and can't be ...
# 635  email address had a syntax error and can't be ...
# 636  email address had a syntax error and can't be ...   132366    135364
#
#           First Name  Last Name               AddressLine1  \
# 0             Thomas    Atasana      JL. PLAMBOYAN NO. 8-A
# 1              Vinay     Sharma  B1/F2 Serenity Apartments
# 2             Werner  Stenschke                SEESTR. 87A
# 3    Jacintha Anitha   Saldanha                         '-
# 4             Hemant   Engineer       23, SHYAMAL BUNGLOWS
# ..               ...        ...                        ...
# 632
# 633
# 634
# 635
# 636            Peter  Gilchrist                         '-
#
#                           AddressLine2         State        City  \
# 0               RT 02/03, BINTARA JAYA  BEKASI BARAT  JAWA BARAT
# 1    Aradi Socorro, Porvorim North Goa      PORVORIM         GOA
# 2                                    .   HOPPEGARTEN    BRANDENB
# 3                         PO BOX 10797            '-          '-
# 4           NR. D-MART, VAGHODIYA ROAD      VADODARA     GUJARAT
# ..                                 ...           ...         ...
# 632
# 633
# 634
# 635
# 636                     CLARENDON ROAD            '-          '-
#
#             Country  ...       Servicing Office        Keywords   PanCardNo  \
# 0         Indonesia  ...   KARMA CONCIERGE BALI
# 1             India  ...  KARMA CONCIERGE INDIA      Email Only  ACHPS0007J
# 2           Germany  ...   KARMA CONCIERGE BALI
# 3      Saudi Arabia  ...   KARMA CONCIERGE BALI
# 4             India  ...  KARMA CONCIERGE INDIA
# ..              ...  ...                    ...             ...         ...
# 632                  ...
# 633                  ...
# 634                  ...
# 635                  ...
# 636  United Kingdom  ...  KARMA CONCIERGE INDIA  Special Waiver
#
#      OdysseyNo Member Segment Account Currency Main DB     Sub DB     Date DB  \
# 0    C82000587         Active                      KCB     ID-Exc  21-10-2024
# 1    C82010093         Active              INR     KCI      India  21-10-2024
# 2    C82046471         Active                      KCB    ENG-Exc  21-10-2024
# 3    C82025891         Active                      KCB    ENG-Exc  21-10-2024
# 4    C82016989         Active              INR     KCI      India  21-10-2024
# ..         ...            ...              ...     ...        ...         ...
# 632
# 633
# 634
# 635
# 636  C82045914         Active                      KCI  Non India  21-10-2024
#
#         Tags
# 0    Members
# 1    Members
# 2    Members
# 3    Members
# 4    Members
# ..       ...
# 632
# 633
# 634
# 635
# 636  Members
#
# [637 rows x 31 columns]

# %%
m.clean_space(df, 'Email')
m.email_correction(df, 'Email')
# Out:
# c:\Users\fajar\Documents\Python\Task Offline\zoho_data_app\clean_data\..\main_module.py:193: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[df_columns].replace('mailto:','', inplace=True)

# %%
df.to_csv(r'C:\Users\fajar\Documents\Python\Data\email-correction.csv', index=False)
