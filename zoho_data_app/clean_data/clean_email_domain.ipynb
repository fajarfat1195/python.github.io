# %%
import main_module as m
import zoho_filter_module as fil
import pandas as pd
import re
import numpy as np

dir_path = r'C:\Users\fajar\Documents\Python\Data\Zoho_Backup'
file_name = '\Leads_'

# %%
# df = pd.DataFrame({'mail': ["gmul.com","gemail.com","gmaile.id.com","gmail.id.com","gmaildot.com","gamaeil.com","g.mail.com","q.mail.com","gmile.com","g.mail","gimail.com","gmail.net","gmai.co","gmail.cim","qmail.com","gamail.com","gmwol.com","gma1il.com","gmail.om","gmail.vom","gmail.id","gamil.com","gmailyahoo.com","gkail.com","ymanil.com","gemael.com","gmail.co","gmail.col","gmail.conlm","gmail.contact","gmail.conn","gmail.conil.com","gmail.con.au","hmail.com","gmail.co.id","gnail.com","g.mail.com","gmail.coom","gmal.com","gmil.com","g.com","gmali.com","gmaill.com","gmaill.com.id","gmial.com","gmail.conm","gmai.com","gmail.con","gmaim.com","ggmail.con","ggmail.com","gmaill.com","gmail679.com","gmeil.com","gmaail.com","G.mail","gma.com","gmail.cik","gmail.cong","gmail.cok","gmail.comilaen","ymail.con","gnail.con","gmal.con","gnail.con","mail.con","fmail.con","gmill.com","gmakl.com","gimail.com","gimail.come","gmail.commm","gmail.come","gmail.coma","gmail.comb","gmail.comc","gmail.comg","gmail.comh","gmail.comi"]})

# %%
# df2 = pd.DataFrame({'mail': ["gmul.com","gemail.com","gmaile.id.com","gmail.id.com","gmaildot.com","gamaeil.com","g.mail.com","q.mail.com","gmile.com","g.mail","gimail.com","gmail.net","gmai.co","gmail.cim","qmail.com","gamail.com","gmwol.com","gma1il.com","gmail.om","gmail.vom","gmail.id","gamil.com","gmailyahoo.com","gkail.com","ymanil.com","gemael.com","gmail.co","gmail.col","gmail.conlm","gmail.contact","gmail.conn","gmail.conil.com","gmail.con.au","hmail.com","gmail.co.id","gnail.com","g.mail.com","gmail.coom","gmal.com","gmil.com","g.com","gmali.com","gmaill.com","gmaill.com.id","gmial.com","gmail.conm","gmai.com","gmail.con","gmaim.com","ggmail.con","ggmail.com","gmaill.com","gmail679.com","gmeil.com","gmaail.com","G.mail","gma.com","gmail.cik","gmail.cong","gmail.cok","gmail.comilaen","ymail.con","gnail.con","gmal.con","gnail.con","mail.con","fmail.con","gmill.com","gmakl.com","gimail.com","gimail.come","gmail.commm","gmail.come","gmail.coma","gmail.comb","gmail.comc","gmail.comg","gmail.comh","gmail.comi"]})

# %%
# df2.loc[~df['mail'].isin(df['mail'])]

# %%
cols = ['Record Id',	
'Created Time',
'Created Date',	
'First Name',	
'Last Name',	
'Email',	
'Phone',	
'Mobile']

df = m.load_data_multiple(dir_path, file_name, cols)
count_data_awal = df.shape[0]
df = df.reindex(columns=cols)
df.shape[0]
# fungsi errors cource untuk menhindari error jika value data date null atau kosong
# df['Birthdate'] = pd.to_datetime(df['Birthdate'], format='%Y-%m-%d', errors='coerce')
df.dtypes
df
# Out:
#                         Record Id         Created Time Created Date  \
# 0        zcrm_3584690000000404058  2019-01-07 15:08:38   2019-01-06
# 1        zcrm_3584690000000404059  2019-01-07 15:08:38   2019-01-06
# 2        zcrm_3584690000000404060  2019-01-07 15:08:38   2019-01-06
# 3        zcrm_3584690000000404065  2019-01-07 15:08:38   2019-01-06
# 4        zcrm_3584690000000404068  2019-01-07 15:08:38   2019-01-06
# ...                           ...                  ...          ...
# 1895494  zcrm_3584690000499272002  2024-06-17 17:04:08         <NA>
# 1895495  zcrm_3584690000499272036  2024-06-17 17:39:40   2024-06-17
# 1895496  zcrm_3584690000499275001  2024-06-17 17:15:09         <NA>
# 1895497  zcrm_3584690000499276001  2024-06-17 17:37:47         <NA>
# 1895498  zcrm_3584690000499279001  2024-06-17 17:47:02   2024-06-17
#
#                 First Name  Last Name                         Email  \
# 0                 Nicholas       Wood    1230woodnicholas@gmail.com
# ...

# %%
df_gmail = df.loc[df['Email'].str.contains('gmail', regex=True, flags=re.I)].copy()

# %%
email_split = df_gmail['Email'].str.split("@", expand=True)
df_gmail['Domain'] = email_split[1]

# %%
df_gmail.groupby('Domain')['Record Id'].count().reset_index(name='Count').to_excel(r'C:\Users\fajar\Documents\Python\Data\Zoho CRM\clean data\update\email\gmail.xlsx', index=False)
