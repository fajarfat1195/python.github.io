# %%
import sys
sys.path.append('../')

import main_module as m
import clean_data_modul as fil
import pandas as pd
import re
import numpy as np

# %load_ext autoreload
# %autoreload 2

dir_path = r'C:\Users\fajar\Documents\Python\Data\Zoho_Backup'
file_name = '\Leads_'

cols = ['Record Id',	
'Created Time',
'Created Date',	
'First Name',	
'Last Name',	
'Email',	
'Phone',	
'Mobile',	
'Birthdate',	
'Year of Birth',
'Street',	
'Street2',	
'City',	
'State',	
'Country',	
'Nationality',
'Booking Status', 
'BookRef',
'Departure Date',	
'Arrival Date',	
'Card Type',	
'Marital Status',	
'Lead Brand',	
'Lead Sub-Brand',	
'Lead Source',	
'Lead Locations',	
'Lead Source Description',	
'Lead Regions',
'Lead Status',
'Email Opt Out',	
'Opt In',
'Do Not Contact',
'Do Not Mail']

# %%
df = m.load_data_multiple(dir_path, file_name, cols)
count_data_awal = df.shape[0]
df = df.reindex(columns=cols)
df.shape[0]

# df['Created Time'] = pd.to_datetime(df['Created Time'], format='%Y-%m-%d %H:%M:%S')
# fungsi errors cource untuk menhindari error jika value data date null atau kosong
# df['Birthdate'] = pd.to_datetime(df['Birthdate'], format='%Y-%m-%d', errors='coerce')
df.dtypes
df
# Out:
#                         Record Id         Created Time Created Date  \
# 0        zcrm_3584690000000404058  2019-01-07 15:08:38   2019-01-06
# 1        zcrm_3584690000000404059  2019-01-07 15:08:38   2019-01-06
# 2        zcrm_3584690000000404060  2019-01-07 15:08:38   2019-01-06
# 3        zcrm_3584690000000404065  2019-01-07 15:08:38   2019-01-06
# 4        zcrm_3584690000000404068  2019-01-07 15:08:38   2019-01-06
# ...                           ...                  ...          ...
# 4717718  zcrm_3584690000475135007  2024-01-01 18:16:02         <NA>
# 4717719  zcrm_3584690000475135045  2024-01-01 18:16:37         <NA>
# 4717720  zcrm_3584690000475136005  2024-01-01 18:17:13         <NA>
# 4717721  zcrm_3584690000475138034  2024-01-01 18:48:36         <NA>
# 4717722  zcrm_3584690000475138069  2024-01-01 18:52:24         <NA>
#
#         First Name  Last Name                       Email           Phone  \
# 0         Nicholas       Wood  1230woodnicholas@gmail.com    +61438600845
# ...

# %%
zoho_filter = fil.custom(df)
zoho_df = df.loc[zoho_filter].copy() # menggunakan copy untuk menghindari setting copy warning
zoho_df.reset_index(drop=True, inplace=True)
count_filter_awal = zoho_df.shape[0]

# zoho_df.to_excel(r'C:\Users\fajar\Documents\Python\Data\test_leads.xlsx', index=False)
# mengisi kolom <NA> dengan value string 'empty' supaya mudah mengecek data member dan booking dengan isin
zoho_df
# Out:
#                        Record Id         Created Time Created Date  \
# 0       zcrm_3584690000006633162  2019-04-02 15:15:36   2013-01-12
# 1       zcrm_3584690000006633179  2019-04-02 15:15:36   2008-01-07
# 2       zcrm_3584690000006633200  2019-04-02 15:15:36   2012-01-01
# 3       zcrm_3584690000006633383  2019-04-02 15:15:39   2013-09-16
# 4       zcrm_3584690000006633416  2019-04-02 15:15:39   2010-08-23
# ...                          ...                  ...          ...
# 987970  zcrm_3584690000022290728  2019-04-03 19:05:28   2000-01-01
# 987971  zcrm_3584690000022290735  2019-04-03 19:05:28   2015-06-15
# 987972  zcrm_3584690000022290740  2019-04-03 19:05:28   2010-01-01
# 987973  zcrm_3584690000022290744  2019-04-03 19:05:28   2011-01-01
# 987974  zcrm_3584690000022290746  2019-04-03 19:05:28   2000-01-01
#
#                      First Name Last Name                      Email  \
# 0                  Ashok P Shah      <NA>          goldstar@vsnl.net
# ...

# %%
zoho_df.groupby('Lead Sub-Brand').count()
# Out:
#                 Record Id  Created Time  Created Date  First Name  Last Name  \
# Lead Sub-Brand
# Other India DB     987975        987975        987975      982339     112119
#
#                 Email   Phone  Mobile  Birthdate  Year of Birth  ...  \
# Lead Sub-Brand                                                   ...
# Other India DB  74057  984829   53586      15471          24266  ...
#
#                 Lead Brand  Lead Source  Lead Locations  \
# Lead Sub-Brand
# Other India DB      987975       987975               0
#
#                 Lead Source Description  Lead Regions  Lead Status  \
# Lead Sub-Brand
# Other India DB                   987975        987975            0
#
#                 Email Opt Out  Opt In  Do Not Contact  Do Not Mail
# Lead Sub-Brand
# Other India DB         987975  987975          987975       987975
#
# [1 rows x 32 columns]

# %%
filename = 'Other India DB-Club IN'
zoho_df.to_excel(r'C:\Users\fajar\Documents\Python\Data\Zoho CRM\clean data\delete\All CRM Project\10 Januari\\'+filename+'.xlsx', index=False)

zoho_df = zoho_df[['Record Id']]
zoho_df['Test'] = True
zoho_df
# Out:
# C:\Users\fajar\AppData\Local\Temp\ipykernel_8932\2335553423.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   zoho_df['Test'] = True
#                        Record Id  Test
# 0       zcrm_3584690000006633162  True
# 1       zcrm_3584690000006633179  True
# 2       zcrm_3584690000006633200  True
# 3       zcrm_3584690000006633383  True
# 4       zcrm_3584690000006633416  True
# ...                          ...   ...
# 987970  zcrm_3584690000022290728  True
# 987971  zcrm_3584690000022290735  True
# 987972  zcrm_3584690000022290740  True
# 987973  zcrm_3584690000022290744  True
# 987974  zcrm_3584690000022290746  True
#
# [987975 rows x 2 columns]

# %%
if zoho_df.shape[0]>30000:
    location = r'C:\Users\fajar\Documents\Python\Data\Zoho CRM\clean data\delete\All CRM Project\10 Januari\split'

    row_split = 30000
    file_name = filename
    file_type = 'csv'

    m.split_file(zoho_df, row_split, file_name, file_type, location)

else:
    zoho_df.to_csv(r'C:\Users\fajar\Documents\Python\Data\Zoho CRM\clean data\delete\All CRM Project\10 Januari\\'+filename+'.csv', index=False)
