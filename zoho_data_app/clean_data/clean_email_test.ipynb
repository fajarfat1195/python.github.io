# %%
import sys
sys.path.append('../')

import main_module as m
import zoho_filter_module as fil
import pandas as pd
import re
import numpy as np

# %load_ext autoreload
# %autoreload 2

dir_path = r'C:\Users\fajar.fatoni\Documents\Python\Data\Zoho_Backup'
file_name = '\Leads_'

cols = ['Record Id',	
'Created Time',
'Created Date',	
'First Name',	
'Last Name',	
'Email',	
'Phone',	
'Mobile',	
'Birthdate',	
'Year of Birth',
'Street',	
'Street2',	
'City',	
'State',	
'Country',	
'Nationality',
'Booking Status', 
'BookRef',
'Departure Date',	
'Arrival Date',	
'Card Type',	
'Marital Status',	
'Lead Brand',	
'Lead Sub-Brand',	
'Lead Source',	
'Lead Locations',	
'Lead Source Description',	
'Lead Regions',
'Lead Status',
'Email Opt Out',	
'Opt In',
'Do Not Contact',
'Do Not Mail',
'Website']

# %%
df = m.load_data_multiple(dir_path, file_name, cols)
count_data_awal = df.shape[0]
df = df.reindex(columns=cols)
df.shape[0]

df['Created Time'] = pd.to_datetime(df['Created Time'], format='%Y-%m-%d %H:%M:%S')
# fungsi errors cource untuk menhindari error jika value data date null atau kosong
# df['Birthdate'] = pd.to_datetime(df['Birthdate'], format='%Y-%m-%d', errors='coerce')
df.sort_values('Created Time', ascending=False, inplace=True)
df.dtypes
df
# Out:
#                        Record Id        Created Time Created Date First Name  \
# 498277  zcrm_3584690000526382158 2025-03-03 18:39:17         <NA>      Chloe
# 498014  zcrm_3584690000526292971 2025-03-03 18:28:51         <NA>  Zakiuddin
# 498258  zcrm_3584690000526373263 2025-03-03 18:26:53         <NA>     Maksim
# 497846  zcrm_3584690000526265995 2025-03-03 18:25:31         <NA>      Huned
# 498144  zcrm_3584690000526311079 2025-03-03 18:05:11   2025-03-03      Simon
# ...                          ...                 ...          ...        ...
# 5       zcrm_3584690000000450110 2019-01-08 16:38:18         <NA>      Maeve
# 4       zcrm_3584690000000450109 2019-01-08 16:38:18         <NA>  Ana Maria
# 3       zcrm_3584690000000450106 2019-01-08 16:38:18         <NA>       Lisa
# 2       zcrm_3584690000000450087 2019-01-08 16:38:18         <NA>    Siobhan
# 0       zcrm_3584690000000404602 2019-01-08 11:07:28   2021-07-21   Frederic
#
#          Last Name                          Email           Phone Mobile  \
# 498277       Usher  enquiries@wearethedrama.co.uk  +4407411383478   <NA>
# 498014   Dhariwala             zakki786@gmail.com  +9108956152378   <NA>
# 498258    Sidiakin           maximargus@gmail.com  +6282147599590   <NA>
# 497846  Contractor               hunedc@gmail.com   +917756851467   <NA>
# 498144     Roberts                           <NA>  +4407966193418   <NA>
# ...            ...                            ...             ...    ...
# 5            Maher          maeve.maher@gmail.com    353868702583   <NA>
# 4         Weileder       m.weileder@sonnenlink.de     15253234700   <NA>
# 3        Ferkovich           lisajo2009@yahoo.com     14062394749   <NA>
# 2        Gallagher    gallaghersiobhan@eircom.net    353879597603   <NA>
# 0            Bonin      fredericbonin79@gmail.com  +6281236100502   <NA>
#
#          Birthdate Year of Birth  ...       Lead Source      Lead Locations  \
# 498277        <NA>          <NA>  ...       Web Enquiry                <NA>
# 498014        <NA>          <NA>  ...       Web Enquiry                <NA>
# 498258        <NA>          <NA>  ...       Web Enquiry                <NA>
# 497846        <NA>          <NA>  ...           Webchat                <NA>
# 498144        <NA>          <NA>  ...  WhatsApp Enquiry  Karma St. Martin's
# ...            ...           ...  ...               ...                 ...
# 5       1973-01-15          1973  ...       Past Guests       Karma Bavaria
# 4             <NA>          <NA>  ...             Other       Karma Bavaria
# 3       1963-07-08          1963  ...       Past Guests       Karma Bavaria
# 2       1973-03-14          1973  ...       Past Guests       Karma Bavaria
# 0       1981-10-03          1981  ...            Agency       Karma Kandara
#
#                       Lead Source Description Lead Regions Lead Status  \
# 498277                        Form Contact Us    UK/Europe        <NA>
# 498014                        Form Contact Us        India        <NA>
# 498258                     Karma Club Enquiry         SEAP        <NA>
# 497846   Karma Experience India | Webchat Web        India        <NA>
# 498144  Karma Reservations - WhatsApp Channel         <NA>    New Lead
# ...                                       ...          ...         ...
# 5                                        <NA>    UK/Europe    New Lead
# 4             MICE Contacts from Ioanna email    UK/Europe    New Lead
# 3                                        <NA>    UK/Europe    New Lead
# 2                                        <NA>    UK/Europe    New Lead
# 0                                       KAREN         SEAP    New Lead
#
#        Email Opt Out Opt In Do Not Contact Do Not Mail  \
# 498277         false   true          false       false
# 498014         false   true          false       false
# 498258         false   true          false       false
# 497846         false   true          false       false
# 498144         false  false          false       false
# ...              ...    ...            ...         ...
# 5              false   true           true        true
# 4              false   true          false       false
# 3               true  false           true        true
# 2              false   true           true        true
# 0              false  false          false       false
#
#                                                   Website
# 498277                 https://karmagroup.com/contact-us/
# 498014  https://karmagroup.com/find-destination/karma-...
# 498258          https://karmaclub.karmagroup.com/enquire/
# 497846  https://karmagroup.com/membership/?gad_source=...
# 498144                                               <NA>
# ...                                                   ...
# 5                                                    <NA>
# 4                                                    <NA>
# 3                                                    <NA>
# 2                                                    <NA>
# 0                                                    <NA>
#
# [498281 rows x 34 columns]

# %% [markdown]
# # ====================== Awal Filter Umum ======================

# %%
df.loc[(df['Email'].str.contains(r'\+')) & (df['Email'].str.contains(r'karmagroup.com')),'Test'] = True
df_final = df.loc[df['Test'] == True,['Record Id', 'Test']].copy()
df_final.to_csv(r'C:\Users\fajar.fatoni\Documents\Python\Data\delete_email_test.csv', index=False)

# %% [markdown]
# # ====================== Akhir Filter Umum ======================
