# %%
import sys
sys.path.append('../')

import main_module as m
import zoho_filter_module as fil
import pandas as pd
import re
import numpy as np

# %load_ext autoreload
# %autoreload 2

dir_path = r'C:\Users\fajar.fatoni\Documents\Python\Data\Zoho_Backup'
file_name = '\Leads_'

cols = ['Record Id',	
'Created Time',
'Created Date',	
'First Name',	
'Last Name',	
'Email',	
'Phone',	
'Mobile',	
'Birthdate',	
'Year of Birth',
'Street',	
'Street2',	
'City',	
'State',	
'Country',	
'Nationality',
'Booking Status', 
'BookRef',
'Departure Date',	
'Arrival Date',	
'Card Type',	
'Marital Status',	
'Lead Brand',	
'Lead Sub-Brand',	
'Lead Source',	
'Lead Locations',	
'Lead Source Description',	
'Lead Regions',
'Lead Status',
'Email Opt Out',	
'Opt In',
'Do Not Contact',
'Do Not Mail',
'Website']

# %%
df = m.load_data_multiple(dir_path, file_name, cols)
count_data_awal = df.shape[0]
df = df.reindex(columns=cols)
df.shape[0]

df['Created Time'] = pd.to_datetime(df['Created Time'], format='%Y-%m-%d %H:%M:%S')
# fungsi errors cource untuk menhindari error jika value data date null atau kosong
# df['Birthdate'] = pd.to_datetime(df['Birthdate'], format='%Y-%m-%d', errors='coerce')
df.sort_values('Created Time', ascending=False, inplace=True)
df.dtypes
df
# Out:
# C:\Users\fajar.fatoni\Documents\Python\Data\Zoho_Backup\Leads_001.csv
# C:\Users\fajar.fatoni\Documents\Python\Data\Zoho_Backup\Leads_002.csv
# C:\Users\fajar.fatoni\Documents\Python\Data\Zoho_Backup\Leads_003.csv
# C:\Users\fajar.fatoni\Documents\Python\Data\Zoho_Backup\Leads_004.csv
# C:\Users\fajar.fatoni\Documents\Python\Data\Zoho_Backup\Leads_005.csv
# C:\Users\fajar.fatoni\Documents\Python\Data\Zoho_Backup\Leads_006.csv
#                        Record Id        Created Time Created Date  \
# 514491  zcrm_3584690000562013560 2025-07-07 17:30:24   2025-07-06
# 514155  zcrm_3584690000561948684 2025-07-07 17:30:21   2025-07-06
# 514555  zcrm_3584690000562017647 2025-07-07 17:30:19   2025-07-06
# 514665  zcrm_3584690000562024906 2025-07-07 17:30:16   2025-07-06
# 514341  zcrm_3584690000561986781 2025-07-07 17:11:44         <NA>
# ...                          ...                 ...          ...
# 5       zcrm_3584690000000450110 2019-01-08 16:38:18         <NA>
# 4       zcrm_3584690000000450109 2019-01-08 16:38:18         <NA>
# 3       zcrm_3584690000000450106 2019-01-08 16:38:18         <NA>
# 2       zcrm_3584690000000450087 2019-01-08 16:38:18         <NA>
# 0       zcrm_3584690000000404602 2019-01-08 11:07:28   2021-07-21
#
#             First Name       Last Name                         Email  \
# 514491          Evelyn          Evelyn                          <NA>
# 514155   Anderson Tien   Anderson Tien                          <NA>
# 514555       Chen I Ju       Chen I Ju                          <NA>
# 514665  Simone Hickman  Simone Hickman  simone_hickman18@hotmail.com
# 514341           Keryn       Adhiwisnu      kongatthealtar@gmail.com
# ...                ...             ...                           ...
# 5                Maeve           Maher         maeve.maher@gmail.com
# 4            Ana Maria        Weileder      m.weileder@sonnenlink.de
# 3                 Lisa       Ferkovich          lisajo2009@yahoo.com
# 2              Siobhan       Gallagher   gallaghersiobhan@eircom.net
# 0             Frederic           Bonin     fredericbonin79@gmail.com
#
#                   Phone Mobile   Birthdate Year of Birth  ...  Lead Source  \
# 514491    +65 8260 4100   <NA>        <NA>          <NA>  ...     WhatsApp
# 514155    +65 8298 4953   <NA>        <NA>          <NA>  ...     WhatsApp
# 514555  +62 81916251041   <NA>        <NA>          <NA>  ...     WhatsApp
# 514665             <NA>   <NA>        <NA>          <NA>  ...        Email
# 514341     +61468935354   <NA>        <NA>          <NA>  ...  Web Enquiry
# ...                 ...    ...         ...           ...  ...          ...
# 5          353868702583   <NA>  1973-01-15          1973  ...  Past Guests
# 4           15253234700   <NA>        <NA>          <NA>  ...        Other
# 3           14062394749   <NA>  1963-07-08          1963  ...  Past Guests
# 2          353879597603   <NA>  1973-03-14          1973  ...  Past Guests
# 0        +6281236100502   <NA>  1981-10-03          1981  ...       Agency
#
#        Lead Locations                            Lead Source Description  \
# 514491  Karma Kandara              Karma Reservations - WhatsApp Channel
# 514155  Karma Kandara              Karma Reservations - WhatsApp Channel
# 514555  Karma Kandara              Karma Reservations - WhatsApp Channel
# 514665  Karma Kandara              Karma Reservations - WhatsApp Channel
# 514341  Karma Kandara  Karma Kandara -Download Wedding Brochure at Ka...
# ...               ...                                                ...
# 5       Karma Bavaria                                               <NA>
# 4       Karma Bavaria                    MICE Contacts from Ioanna email
# 3       Karma Bavaria                                               <NA>
# 2       Karma Bavaria                                               <NA>
# 0       Karma Kandara                                              KAREN
#
#        Lead Regions Lead Status Email Opt Out Opt In Do Not Contact  \
# 514491         SEAP        <NA>         false  false          false
# 514155         SEAP        <NA>         false  false          false
# 514555         SEAP        <NA>         false  false          false
# 514665         SEAP        <NA>         false  false          false
# 514341         SEAP        <NA>         false   true          false
# ...             ...         ...           ...    ...            ...
# 5         UK/Europe    New Lead         false   true           true
# 4         UK/Europe    New Lead         false   true          false
# 3         UK/Europe    New Lead          true  false           true
# 2         UK/Europe    New Lead         false   true           true
# 0              SEAP    New Lead         false  false          false
#
#        Do Not Mail                                            Website
# 514491       false                                               <NA>
# 514155       false                                               <NA>
# 514555       false                                               <NA>
# 514665       false                                               <NA>
# 514341       false  https://karmagroup.com/weddings-at-karma-kanda...
# ...            ...                                                ...
# 5             true                                               <NA>
# 4            false                                               <NA>
# 3             true                                               <NA>
# 2             true                                               <NA>
# 0            false                                               <NA>
#
# [514666 rows x 34 columns]

# %% [markdown]
# # ====================== Awal Filter Umum ======================

# %%
df.loc[(df['Email'].str.contains(r'\+')) & (df['Email'].str.contains(r'karmagroup.com')),'Test'] = True
df.loc[(df['Email'].str.contains(r'^test@gmail.com')),'Test'] = True
df.loc[(df['First Name'].str.contains(r'^test$', regex=True, flags=re.I)) | (df['Last Name'].str.contains(r'^test$', regex=True, flags=re.I)),'Test'] = True
df_details = df.loc[df['Test'] == True,['Record Id', 'First Name', 'Last Name', 'Email', 'Test']].copy()
df_delete_test = df.loc[df['Test'] == True,['Record Id', 'Test']].copy()

# %%
df_details.to_csv(r'C:\Users\fajar.fatoni\Documents\Python\Data\details_email_test.csv', index=False)
df_delete_test.to_csv(r'C:\Users\fajar.fatoni\Documents\Python\Data\delete_email_test.csv', index=False)

# %% [markdown]
# # ====================== Akhir Filter Umum ======================
