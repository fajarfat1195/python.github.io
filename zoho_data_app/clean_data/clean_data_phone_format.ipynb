# %%
import sys

sys.path.append('../')

import main_module as m
import zoho_filter_module as fil
import pandas as pd
import re
import numpy as np

# %load_ext autoreload
# %autoreload 2

dir_path = r'C:\Users\fajar\Documents\Python\Data\Zoho_Backup'
file_name = '\Leads_'

cols = ['Record Id',	
'Created Time',
'Created Date',	
'First Name',	
'Last Name',	
'Email',	
'PHONE',	
'Mobile',	
'Birthdate',	
'Year of Birth',
'Street',	
'Street2',	
'City',	
'State',	
'Country',	
'Nationality',
'Booking Status', 
'BookRef',
'Departure Date',	
'Arrival Date',	
'Card Type',	
'Marital Status',	
'Lead Brand',	
'Lead Sub-Brand',	
'Lead Source',	
'Lead Locations',	
'Lead Source Description',	
'Lead Regions',
'Lead Status',
'Email Opt Out',	
'Opt In',
'Do Not Contact',
'Do Not Mail']
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
path = r'C:\Users\fajar\Documents\Python\Data\pg_kandara.csv'
zoho_df = pd.read_csv(path, dtype='string')

zoho_df.reset_index(drop=True, inplace=True)
count_filter_awal = zoho_df.shape[0]

zoho_df['Mobile'] = 'empty'

# mengisi kolom <NA> dengan value string 'empty' supaya mudah mengecek data member dan booking dengan isin
zoho_df.fillna('empty', inplace=True)
zoho_df
# Out:
#                       Record Id             Lead Owner.id        Lead Owner  \
# 0      zcrm_3584690000000450173  zcrm_3584690000040796001  Vicky  Alavantis
# 1      zcrm_3584690000000450184  zcrm_3584690000000180021     Benny Risanto
# 2      zcrm_3584690000000450188  zcrm_3584690000000180021     Benny Risanto
# 3      zcrm_3584690000000450193  zcrm_3584690000040796001  Vicky  Alavantis
# 4      zcrm_3584690000000456084  zcrm_3584690000040796001  Vicky  Alavantis
# ...                         ...                       ...               ...
# 18397  zcrm_3584690000485508030  zcrm_3584690000000180021     Benny Risanto
# 18398  zcrm_3584690000485511059  zcrm_3584690000000180021     Benny Risanto
# 18399  zcrm_3584690000485516001  zcrm_3584690000000180021     Benny Risanto
# 18400  zcrm_3584690000485534001  zcrm_3584690000000180021     Benny Risanto
# 18401  zcrm_3584690000485663001  zcrm_3584690000000180021     Benny Risanto
#
#               Created Time Card Number                Lead Source Description  \
# 0      2019-01-08 16:38:18       empty                                  empty
# 1      2019-01-08 16:38:18       empty                                  empty
# 2      2019-01-08 16:38:18       empty                                  empty
# 3      2019-01-08 16:38:18       empty                                  empty
# 4      2019-01-09 11:10:49       empty                                  empty
# ...                    ...         ...                                    ...
# 18397  2024-02-28 12:35:13       empty  Karma Reservations - WhatsApp Channel
# 18398  2024-02-28 17:51:58       empty  Karma Reservations - WhatsApp Channel
# 18399  2024-02-28 09:15:57       empty  Karma Reservations - WhatsApp Channel
# 18400  2024-02-28 17:53:58       empty  Karma Reservations - WhatsApp Channel
# 18401  2024-02-29 12:06:59       empty  Karma Reservations - WhatsApp Channel
#
#       Website  First Name     Last Name                                 Email  \
# 0       empty  Dr. Steven         Tracy                                 empty
# 1       empty        Paul           May  paulmay@intercept-australia.asia.com
# 2       empty    Muhammad  Andi H.N, St               nurkusumahadi@gmail.com
# 3       empty    Michelle       Rasborn               mrasborn@netvigator.com
# 4       empty       Bohao         Zhang                      100252655@qq.com
# ...       ...         ...           ...                                   ...
# 18397   empty  ICS Travel             -                                 empty
# 18398   empty     Pavlova             -                                 empty
# 18399   empty         Mia             -                                 empty
# 18400   empty     Sanghee          Park                                 empty
# 18401   empty        Novi             -                                 empty
#
#        ... Lead Regions Street2    Country GDPR Compliant       City  \
# 0      ...         SEAP   empty  Australia          false      empty
# 1      ...         SEAP   empty  Australia          false  Melbourne
# 2      ...         SEAP   empty  Indonesia          false      empty
# 3      ...    UK/Europe   empty     Sweden           true      empty
# 4      ...        Other   empty      China          false      empty
# ...    ...          ...     ...        ...            ...        ...
# 18397  ...        empty   empty      empty          false      empty
# 18398  ...        empty   empty      empty          false      empty
# 18399  ...        empty   empty      empty          false      empty
# 18400  ...        empty   empty      empty          false      empty
# 18401  ...        empty   empty      empty          false      empty
#
#                           Street Lead Locations            Messages  \
# 0        1406/168 Kent St Sydney  Karma Kandara               empty
# 1         1234 Po Box 1234 South  Karma Kandara               empty
# 2      Lor In Residence F16 Solo  Karma Kandara               empty
# 3                          empty  Karma Kandara               empty
# 4                          empty  Karma Kandara               empty
# ...                          ...            ...                 ...
# 18397                      empty  Karma Kandara  Phone Leads, Agent
# 18398                      empty  Karma Kandara               empty
# 18399                      empty  Karma Kandara  Phone Leads, Agent
# 18400                      empty  Karma Kandara               empty
# 18401                      empty  Karma Kandara               empty
#
#       Agree with Terms and Condition Mobile
# 0                              false  empty
# 1                              false  empty
# 2                              false  empty
# 3                              false  empty
# 4                              false  empty
# ...                              ...    ...
# 18397                          false  empty
# 18398                          false  empty
# 18399                          false  empty
# 18400                          false  empty
# 18401                          false  empty
#
# [18402 rows x 24 columns]

# %%
zoho_df[['Record Id','Phone']][zoho_df['Phone'].str.contains('^4444', regex=True)]
# Out:
# Empty DataFrame
# Columns: [Record Id, Phone]
# Index: []

# %%
path = r'G:\.shortcut-targets-by-id\0B_d3smBjzo04eXpvS1NXTWF2RVE\_BOOKING\Booking By Year\FlyBuy Booking Data (BGAU & BGID & KE).xlsx'
df_booking = pd.read_excel(path, dtype='string', sheet_name='BOOKING_BGAU_BGID_KE')

path = r'G:\.shortcut-targets-by-id\0B_d3smBjzo04UUNBME5GOVhoMjA\_ODYSSEY\Phone Members.xlsx'
df_phone = pd.read_excel(path, dtype='string', sheet_name='Sheet1')

path = r'G:\.shortcut-targets-by-id\0B_d3smBjzo04UUNBME5GOVhoMjA\_ODYSSEY\Email Members.xlsx'
df_email = pd.read_excel(path, dtype='string', sheet_name='Sheet1')

# %% [markdown]
# # ====================== Awal Filter Umum ======================

# %%
# data phone, mobile dam email member yang ada di master data (wash member)

m.clean_number(zoho_df, 'Phone')
m.clean_number(zoho_df, 'Mobile')
m.replace_not_valid_to_empty(zoho_df, 'Phone')
m.replace_not_valid_to_empty(zoho_df, 'Mobile')
zoho_df['Email'] = m.lowercase(zoho_df, 'Email')
m.clean_space(zoho_df, 'Email')

m.clean_number(df_booking, 'Phone1')
m.clean_number(df_booking, 'Mobile')
df_booking['Email'] = m.lowercase(df_booking, 'Email')
m.clean_space(df_booking, 'Email')

m.clean_number(df_phone, 'Mobile')

df_email['Email'] = m.lowercase(df_email, 'Email')
m.clean_space(df_email, 'Email')
# Out:
# 0                    harvey@liblink.co.za
# 1                     _benezi@hotmail.com
# 2                         0000987@mail.ru
# 3                       0007psc@gmail.com
# 4                      001paras@gmail.com
#                        ...
# 308560         vishruthhvasanth@gmail.com
# 308561    woods.point.hotel@activ8.net.au
# 308562        yadavneelam.delhi@gmail.com
# 308563            yashkohli5855@gmail.com
# 308564                 zman9278@gmail.com
# Name: Email, Length: 308565, dtype: string

# %%
count_deleted_wrong_format = m.delete_email_wrong_format(zoho_df, 'Email')
count_after_deleted_wrong_format = zoho_df.shape[0]

# %% [markdown]
# # ====================== Akhir Filter Umum ======================

# %%
# hitung jumlah duplicate
count_duplicate_general = zoho_df.loc[zoho_df.duplicated(subset=['Phone','Mobile','Email'])].shape[0]

zoho_df.loc[zoho_df.duplicated(subset=['Phone','Mobile','Email'])]
# Out:
#                       Record Id             Lead Owner.id         Lead Owner  \
# 194    zcrm_3584690000000463023  zcrm_3584690000000180021      Benny Risanto
# 1828   zcrm_3584690000005961423  zcrm_3584690000025257097  Dominika Garajova
# 2262   zcrm_3584690000005966627  zcrm_3584690000025257097  Dominika Garajova
# 2805   zcrm_3584690000005973485  zcrm_3584690000025257097  Dominika Garajova
# 3274   zcrm_3584690000005985036  zcrm_3584690000095278106       Linsey Malta
# ...                         ...                       ...                ...
# 18343  zcrm_3584690000485009001  zcrm_3584690000000180021      Benny Risanto
# 18385  zcrm_3584690000485345083  zcrm_3584690000000180021      Benny Risanto
# 18387  zcrm_3584690000485385126  zcrm_3584690000000180021      Benny Risanto
# 18397  zcrm_3584690000485508030  zcrm_3584690000000180021      Benny Risanto
# 18399  zcrm_3584690000485516001  zcrm_3584690000000180021      Benny Risanto
#
#               Created Time Card Number                Lead Source Description  \
# 194    2019-01-09 11:11:30       empty                                  empty
# 1828   2019-04-02 02:16:20       empty                          Karma Kandara
# 2262   2019-04-02 02:16:49       empty                                  Ex KC
# 2805   2019-04-02 02:17:27       empty                          Karma Kandara
# 3274   2019-04-02 02:18:31       empty                          Karma Kandara
# ...                    ...         ...                                    ...
# 18343  2024-02-25 11:13:23       empty  Karma Reservations - WhatsApp Channel
# 18385  2024-02-27 18:01:59       empty  Karma Reservations - WhatsApp Channel
# 18387  2024-02-27 18:03:31       empty  Karma Reservations - WhatsApp Channel
# 18397  2024-02-28 12:35:13       empty  Karma Reservations - WhatsApp Channel
# 18399  2024-02-28 09:15:57       empty  Karma Reservations - WhatsApp Channel
#
#       Website   First Name   Last Name  Email  ... Lead Regions Street2  \
# 194     empty        Narek  Sirakanyan  empty  ...    UK/Europe   empty
# 1828    empty    Jung Yong         Jin  empty  ...        Other   empty
# 2262    empty         Dane     Sanders  empty  ...         SEAP   empty
# 2805    empty    Choe Yong         Jin  empty  ...        Other   empty
# 3274    empty      Heather        Peet  empty  ...         SEAP   empty
# ...       ...          ...         ...    ...  ...          ...     ...
# 18343   empty  Karuppannan    Anbumani  empty  ...        empty   empty
# 18385   empty        Louis           -  empty  ...        empty   empty
# 18387   empty       cahaya           -  empty  ...        empty   empty
# 18397   empty   ICS Travel           -  empty  ...        empty   empty
# 18399   empty          Mia           -  empty  ...        empty   empty
#
#            Country GDPR Compliant        City                     Street  \
# 194         Russia          false      Moscow       Nikolskaya Street 10
# 1828   South Korea          false       seoul  184 daesamto ILsaiiseo-gu
# 2262     Australia          false   Chatswood   6/372 Eastern Valley Way
# 2805   South Korea          false       seoul                      korea
# 3274     Australia          false  CITY BEACH       63 BRANKSOME GARDENS
# ...            ...            ...         ...                        ...
# 18343        empty          false       empty                      empty
# 18385        empty          false       empty                      empty
# 18387        empty          false       empty                      empty
# 18397        empty          false       empty                      empty
# 18399        empty          false       empty                      empty
#
#       Lead Locations            Messages Agree with Terms and Condition Mobile
# 194    Karma Kandara               empty                          false  empty
# 1828   Karma Kandara               empty                          false  empty
# 2262   Karma Kandara               empty                          false  empty
# 2805   Karma Kandara               empty                          false  empty
# 3274   Karma Kandara               empty                          false  empty
# ...              ...                 ...                            ...    ...
# 18343  Karma Kandara      Sent the quote                          false  empty
# 18385  Karma Kandara               empty                          false  empty
# 18387  Karma Kandara               empty                          false  empty
# 18397  Karma Kandara  Phone Leads, Agent                          false  empty
# 18399  Karma Kandara  Phone Leads, Agent                          false  empty
#
# [293 rows x 24 columns]

# %%
zoho_df.drop_duplicates(subset=['Phone','Mobile','Email'], inplace=True)
zoho_df.reset_index(drop=True, inplace=True)

# hitung jumlah setelah value duplicate dihapus
count_after_dedup_duplicate = zoho_df.shape[0]

zoho_df
# Out:
#                       Record Id             Lead Owner.id        Lead Owner  \
# 0      zcrm_3584690000000450173  zcrm_3584690000040796001  Vicky  Alavantis
# 1      zcrm_3584690000000450184  zcrm_3584690000000180021     Benny Risanto
# 2      zcrm_3584690000000450188  zcrm_3584690000000180021     Benny Risanto
# 3      zcrm_3584690000000450193  zcrm_3584690000040796001  Vicky  Alavantis
# 4      zcrm_3584690000000456084  zcrm_3584690000040796001  Vicky  Alavantis
# ...                         ...                       ...               ...
# 18104  zcrm_3584690000485490003  zcrm_3584690000000180021     Benny Risanto
# 18105  zcrm_3584690000485494003  zcrm_3584690000000180021     Benny Risanto
# 18106  zcrm_3584690000485511059  zcrm_3584690000000180021     Benny Risanto
# 18107  zcrm_3584690000485534001  zcrm_3584690000000180021     Benny Risanto
# 18108  zcrm_3584690000485663001  zcrm_3584690000000180021     Benny Risanto
#
#               Created Time Card Number                Lead Source Description  \
# 0      2019-01-08 16:38:18       empty                                  empty
# 1      2019-01-08 16:38:18       empty                                  empty
# 2      2019-01-08 16:38:18       empty                                  empty
# 3      2019-01-08 16:38:18       empty                                  empty
# 4      2019-01-09 11:10:49       empty                                  empty
# ...                    ...         ...                                    ...
# 18104  2024-02-28 17:52:58       empty  Karma Reservations - WhatsApp Channel
# 18105  2024-02-28 09:16:57       empty  Karma Reservations - WhatsApp Channel
# 18106  2024-02-28 17:51:58       empty  Karma Reservations - WhatsApp Channel
# 18107  2024-02-28 17:53:58       empty  Karma Reservations - WhatsApp Channel
# 18108  2024-02-29 12:06:59       empty  Karma Reservations - WhatsApp Channel
#
#       Website  First Name     Last Name                                 Email  \
# 0       empty  Dr. Steven         Tracy                                 empty
# 1       empty        Paul           May  paulmay@intercept-australia.asia.com
# 2       empty    Muhammad  Andi H.N, St               nurkusumahadi@gmail.com
# 3       empty    Michelle       Rasborn               mrasborn@netvigator.com
# 4       empty       Bohao         Zhang                      100252655@qq.com
# ...       ...         ...           ...                                   ...
# 18104   empty        Eliz             -                                 empty
# 18105   empty         Mel        Harrop                                 empty
# 18106   empty     Pavlova             -                                 empty
# 18107   empty     Sanghee          Park                                 empty
# 18108   empty        Novi             -                                 empty
#
#        ... Lead Regions Street2    Country GDPR Compliant       City  \
# 0      ...         SEAP   empty  Australia          false      empty
# 1      ...         SEAP   empty  Australia          false  Melbourne
# 2      ...         SEAP   empty  Indonesia          false      empty
# 3      ...    UK/Europe   empty     Sweden           true      empty
# 4      ...        Other   empty      China          false      empty
# ...    ...          ...     ...        ...            ...        ...
# 18104  ...        empty   empty      empty          false      empty
# 18105  ...        empty   empty      empty          false      empty
# 18106  ...        empty   empty      empty          false      empty
# 18107  ...        empty   empty      empty          false      empty
# 18108  ...        empty   empty      empty          false      empty
#
#                           Street Lead Locations            Messages  \
# 0        1406/168 Kent St Sydney  Karma Kandara               empty
# 1         1234 Po Box 1234 South  Karma Kandara               empty
# 2      Lor In Residence F16 Solo  Karma Kandara               empty
# 3                          empty  Karma Kandara               empty
# 4                          empty  Karma Kandara               empty
# ...                          ...            ...                 ...
# 18104                      empty  Karma Kandara               empty
# 18105                      empty  Karma Kandara  Phone Leads, Agent
# 18106                      empty  Karma Kandara               empty
# 18107                      empty  Karma Kandara               empty
# 18108                      empty  Karma Kandara               empty
#
#       Agree with Terms and Condition Mobile
# 0                              false  empty
# 1                              false  empty
# 2                              false  empty
# 3                              false  empty
# 4                              false  empty
# ...                              ...    ...
# 18104                          false  empty
# 18105                          false  empty
# 18106                          false  empty
# 18107                          false  empty
# 18108                          false  empty
#
# [18109 rows x 24 columns]

# %%
# Cek leads test
test_leads = zoho_df.loc[
    
        zoho_df['Email'].str.contains('^test@', flags=re.I, regex=True) |
        zoho_df['Email'].str.contains('\+test', flags=re.I, regex=True) |
    
        zoho_df['First Name'].str.contains('^test$', flags=re.I, regex=True) |
        zoho_df['Last Name'].str.contains('^test$', flags=re.I, regex=True) |

        zoho_df['First Name'].str.contains('test 1', flags=re.I, regex=True) |
        zoho_df['Last Name'].str.contains('test 2', flags=re.I, regex=True)|
        zoho_df['First Name'].str.contains('test1', flags=re.I, regex=True) |
        zoho_df['Last Name'].str.contains('test2', flags=re.I, regex=True)|

        zoho_df['First Name'].str.contains(' test ', flags=re.I, regex=True) | 
        zoho_df['Last Name'].str.contains(' test ', flags=re.I, regex=True) | 
        zoho_df['Last Name'].str.contains(' test$', flags=re.I, regex=True)
    ]

count_leads_test = test_leads.shape[0]

# test_leads.to_excel(r'C:\Users\fajar\Documents\Python\Data\test_leads_2.xlsx', index=False)
test_leads
# Out:
# Empty DataFrame
# Columns: [Record Id, Lead Owner.id, Lead Owner, Created Time, Card Number, Lead Source Description, Website, First Name, Last Name, Email, Phone, Lead Brand, Lead Sub-Brand, Lead Source, Lead Regions, Street2, Country, GDPR Compliant, City, Street, Lead Locations, Messages, Agree with Terms and Condition, Mobile]
# Index: []
#
# [0 rows x 24 columns]

# %%
zoho_df.drop(test_leads.index, inplace=True)
zoho_df.reset_index(drop=True, inplace=True)

count_after_dedup_test = zoho_df.shape[0]

# %%
# Cek Email OTA
email_OTA = m.find_OTA(zoho_df, 'Email')
count_email_OTA = email_OTA.shape[0]
# email_OTA.to_excel(r'C:\Users\fajar\Documents\Python\Data\email_OTA.xlsx', index=False)

email_OTA
# Out:
#                      Record Id             Lead Owner.id          Lead Owner  \
# 2350  zcrm_3584690000005968713  zcrm_3584690000001239001  Karolina Balionyte
# 3151  zcrm_3584690000005982559  zcrm_3584690000001239001  Karolina Balionyte
# 3763  zcrm_3584690000005992704  zcrm_3584690000025257097   Dominika Garajova
# 4460  zcrm_3584690000006008835  zcrm_3584690000095310001      Mehdi Doukkali
# 4549  zcrm_3584690000006010291  zcrm_3584690000095306001     Mary  Alavantis
# 5847  zcrm_3584690000006042630  zcrm_3584690000025257097   Dominika Garajova
# 7416  zcrm_3584690000058643283  zcrm_3584690000025257097   Dominika Garajova
# 7994  zcrm_3584690000129725683  zcrm_3584690000095316001     Andrea Pavlidis
# 8280  zcrm_3584690000149249216  zcrm_3584690000095316001     Andrea Pavlidis
# 8545  zcrm_3584690000205750165  zcrm_3584690000000180021       Benny Risanto
# 9585  zcrm_3584690000305511255  zcrm_3584690000002277001     Richard Firnaji
#
#              Created Time Card Number Lead Source Description Website  \
# 2350  2019-04-02 02:17:00       empty           Karma Kandara   empty
# 3151  2019-04-02 02:18:18       empty           Karma Kandara   empty
# 3763  2019-04-02 02:19:15       empty           Karma Kandara   empty
# 4460  2019-04-02 02:20:50       empty           Karma Kandara   empty
# 4549  2019-04-02 02:20:58       empty           Karma Kandara   empty
# 5847  2019-04-02 02:24:17       empty           Karma Kandara   empty
# 7416  2019-07-04 18:36:29       empty                   empty   empty
# 7994  2019-10-09 22:04:31       empty                   empty   empty
# 8280  2019-12-05 17:09:17       empty                   empty   empty
# 8545  2020-07-20 13:49:09       empty                   empty   empty
# 9585  2021-08-10 03:11:54       empty                   empty   empty
#
#        First Name   Last Name                             Email  ...  \
# 2350     Nadezhda   Medvedeva              medvedeva@arttour.ru  ...
# 3151  Fedosseyeva  Yekaterina         reservation@kompastour.kz  ...
# 3763   Mun Byoung          Su                   sptour@nate.com  ...
# 4460        empty       Li Li               weilitour@gmail.com  ...
# 4549        James     O'regan  james.oregan@wendywutours.com.au  ...
# 5847          Tom       Dedek                  td@tomontour.com  ...
# 7416        Renee      Rudolf             renee@xiiitouring.com  ...
# 7994        Olena    Shpakova            service@teztour.com.ua  ...
# 8280      Benitto      Ridwan              fit-ops@egltours.com  ...
# 8545      Soetomo     Soetomo                 expedia@tiket.com  ...
# 9585        Huizi       Zhang         zhanghuizi@utourworld.com  ...
#
#      Lead Regions Street2      Country GDPR Compliant    City  \
# 2350    UK/Europe   empty       Russia          false   empty
# 3151    UK/Europe   empty   Kazakhstan          false  Almaty
# 3763        Other   empty  South Korea          false   Seoul
# 4460        Other   empty        China          false   empty
# 4549         SEAP   empty    Australia          false  mosman
# 5847         SEAP   empty    Australia          false   empty
# 7416         SEAP   empty    Australia          false   empty
# 7994    UK/Europe   empty       Russia           true   empty
# 8280         SEAP   empty    Indonesia          false   empty
# 8545         SEAP   empty    Indonesia          false   empty
# 9585        empty   empty        China          false   empty
#
#                           Street            Lead Locations Messages  \
# 2350                      Russia             Karma Kandara    empty
# 3151              Zarcohnaya 18H             Karma Kandara    empty
# 3763                 seoul korea             Karma Kandara    empty
# 4460                  weili tour             Karma Kandara    empty
# 4549                  1 snell st             Karma Kandara    empty
# 5847    jl villa Kandara Ungasan             Karma Kandara    empty
# 7416  250/806 Bourke St Waterloo             Karma Kandara    empty
# 7994                       empty             Karma Kandara    empty
# 8280                       empty             Karma Kandara    empty
# 8545                       empty  Karma Reef;Karma Kandara    empty
# 9585                       empty             Karma Kandara    empty
#
#      Agree with Terms and Condition Mobile
# 2350                          false  empty
# 3151                          false  empty
# 3763                          false  empty
# 4460                          false  empty
# 4549                          false  empty
# 5847                          false  empty
# 7416                          false  empty
# 7994                          false  empty
# 8280                          false  empty
# 8545                          false  empty
# 9585                          false  empty
#
# [11 rows x 24 columns]

# %%
# delete email OTA
count_after_clean_OTA = m.delete_OTA(zoho_df, 'Email')
# zoho_df.to_excel(r'C:\Users\fajar\Documents\Python\Data\after_clean_OTA.xlsx', index=False)

zoho_df
# Out:
#                       Record Id             Lead Owner.id        Lead Owner  \
# 0      zcrm_3584690000000450173  zcrm_3584690000040796001  Vicky  Alavantis
# 1      zcrm_3584690000000450184  zcrm_3584690000000180021     Benny Risanto
# 2      zcrm_3584690000000450188  zcrm_3584690000000180021     Benny Risanto
# 3      zcrm_3584690000000450193  zcrm_3584690000040796001  Vicky  Alavantis
# 4      zcrm_3584690000000456084  zcrm_3584690000040796001  Vicky  Alavantis
# ...                         ...                       ...               ...
# 18093  zcrm_3584690000485490003  zcrm_3584690000000180021     Benny Risanto
# 18094  zcrm_3584690000485494003  zcrm_3584690000000180021     Benny Risanto
# 18095  zcrm_3584690000485511059  zcrm_3584690000000180021     Benny Risanto
# 18096  zcrm_3584690000485534001  zcrm_3584690000000180021     Benny Risanto
# 18097  zcrm_3584690000485663001  zcrm_3584690000000180021     Benny Risanto
#
#               Created Time Card Number                Lead Source Description  \
# 0      2019-01-08 16:38:18       empty                                  empty
# 1      2019-01-08 16:38:18       empty                                  empty
# 2      2019-01-08 16:38:18       empty                                  empty
# 3      2019-01-08 16:38:18       empty                                  empty
# 4      2019-01-09 11:10:49       empty                                  empty
# ...                    ...         ...                                    ...
# 18093  2024-02-28 17:52:58       empty  Karma Reservations - WhatsApp Channel
# 18094  2024-02-28 09:16:57       empty  Karma Reservations - WhatsApp Channel
# 18095  2024-02-28 17:51:58       empty  Karma Reservations - WhatsApp Channel
# 18096  2024-02-28 17:53:58       empty  Karma Reservations - WhatsApp Channel
# 18097  2024-02-29 12:06:59       empty  Karma Reservations - WhatsApp Channel
#
#       Website  First Name     Last Name                                 Email  \
# 0       empty  Dr. Steven         Tracy                                 empty
# 1       empty        Paul           May  paulmay@intercept-australia.asia.com
# 2       empty    Muhammad  Andi H.N, St               nurkusumahadi@gmail.com
# 3       empty    Michelle       Rasborn               mrasborn@netvigator.com
# 4       empty       Bohao         Zhang                      100252655@qq.com
# ...       ...         ...           ...                                   ...
# 18093   empty        Eliz             -                                 empty
# 18094   empty         Mel        Harrop                                 empty
# 18095   empty     Pavlova             -                                 empty
# 18096   empty     Sanghee          Park                                 empty
# 18097   empty        Novi             -                                 empty
#
#        ... Lead Regions Street2    Country GDPR Compliant       City  \
# 0      ...         SEAP   empty  Australia          false      empty
# 1      ...         SEAP   empty  Australia          false  Melbourne
# 2      ...         SEAP   empty  Indonesia          false      empty
# 3      ...    UK/Europe   empty     Sweden           true      empty
# 4      ...        Other   empty      China          false      empty
# ...    ...          ...     ...        ...            ...        ...
# 18093  ...        empty   empty      empty          false      empty
# 18094  ...        empty   empty      empty          false      empty
# 18095  ...        empty   empty      empty          false      empty
# 18096  ...        empty   empty      empty          false      empty
# 18097  ...        empty   empty      empty          false      empty
#
#                           Street Lead Locations            Messages  \
# 0        1406/168 Kent St Sydney  Karma Kandara               empty
# 1         1234 Po Box 1234 South  Karma Kandara               empty
# 2      Lor In Residence F16 Solo  Karma Kandara               empty
# 3                          empty  Karma Kandara               empty
# 4                          empty  Karma Kandara               empty
# ...                          ...            ...                 ...
# 18093                      empty  Karma Kandara               empty
# 18094                      empty  Karma Kandara  Phone Leads, Agent
# 18095                      empty  Karma Kandara               empty
# 18096                      empty  Karma Kandara               empty
# 18097                      empty  Karma Kandara               empty
#
#       Agree with Terms and Condition Mobile
# 0                              false  empty
# 1                              false  empty
# 2                              false  empty
# 3                              false  empty
# 4                              false  empty
# ...                              ...    ...
# 18093                          false  empty
# 18094                          false  empty
# 18095                          false  empty
# 18096                          false  empty
# 18097                          false  empty
#
# [18098 rows x 24 columns]

# %%
# Cek Email Karma
email_karma = m.find_karma(zoho_df, 'Email')
count_email_karma = email_karma.shape[0]
# email_OTA.to_excel(r'C:\Users\fajar\Documents\Python\Data\email_OTA.xlsx', index=False)

email_karma
# Out:
#                       Record Id             Lead Owner.id          Lead Owner  \
# 4658   zcrm_3584690000006012896  zcrm_3584690000095310001      Mehdi Doukkali
# 7271   zcrm_3584690000029614360  zcrm_3584690000001239001  Karolina Balionyte
# 12451  zcrm_3584690000332206595  zcrm_3584690000002277001     Richard Firnaji
# 15123  zcrm_3584690000431673011  zcrm_3584690000000180021       Benny Risanto
#
#               Created Time Card Number Lead Source Description Website  \
# 4658   2019-04-02 02:21:13       empty           Karma Kandara   empty
# 7271   2019-05-09 16:26:26       empty                   empty   empty
# 12451  2021-12-20 14:03:05       empty                   empty   empty
# 15123  2023-02-27 14:52:18       empty                   empty   empty
#
#          First Name Last Name                               Email  ...  \
# 4658        Natalie       Poh                 natalie.poh@rci.com  ...
# 7271        Patrick    Reason  patrick.reason@karmaroyalgroup.com  ...
# 12451  Sumita Jiten    Parikh     conciergeindia@krresidences.com  ...
# 15123         A. B.     Gupta          isaac.dsouza@karmgroup.com  ...
#
#       Lead Regions Street2    Country GDPR Compliant   City  \
# 4658         Other   empty  Singapore          false  empty
# 7271         empty   empty      empty          false  empty
# 12451        empty   empty      India          false    Guj
# 15123        empty   empty      India          false    Mah
#
#                                                   Street  \
# 4658                         223 mountbatten road #03-11
# 7271                                               empty
# 12451  A-702, Rudraprayug Tower Nr Ramdevnagar Char R...
# 15123            Magnolia Meadow 24 Gulmohar Park, Aundh
#
#                     Lead Locations Messages Agree with Terms and Condition  \
# 4658                 Karma Kandara    empty                          false
# 7271                 Karma Kandara    empty                          false
# 12451  Karma Bavaria;Karma Kandara    empty                          false
# 15123                Karma Kandara    empty                          false
#
#       Mobile
# 4658   empty
# 7271   empty
# 12451  empty
# 15123  empty
#
# [4 rows x 24 columns]

# %%
# delete email Karma
count_after_clean_karma = m.delete_karma(zoho_df, 'Email')
# zoho_df.to_excel(r'C:\Users\fajar\Documents\Python\Data\after_clean_OTA.xlsx', index=False)

zoho_df
# Out:
#                       Record Id             Lead Owner.id        Lead Owner  \
# 0      zcrm_3584690000000450173  zcrm_3584690000040796001  Vicky  Alavantis
# 1      zcrm_3584690000000450184  zcrm_3584690000000180021     Benny Risanto
# 2      zcrm_3584690000000450188  zcrm_3584690000000180021     Benny Risanto
# 3      zcrm_3584690000000450193  zcrm_3584690000040796001  Vicky  Alavantis
# 4      zcrm_3584690000000456084  zcrm_3584690000040796001  Vicky  Alavantis
# ...                         ...                       ...               ...
# 18089  zcrm_3584690000485490003  zcrm_3584690000000180021     Benny Risanto
# 18090  zcrm_3584690000485494003  zcrm_3584690000000180021     Benny Risanto
# 18091  zcrm_3584690000485511059  zcrm_3584690000000180021     Benny Risanto
# 18092  zcrm_3584690000485534001  zcrm_3584690000000180021     Benny Risanto
# 18093  zcrm_3584690000485663001  zcrm_3584690000000180021     Benny Risanto
#
#               Created Time Card Number                Lead Source Description  \
# 0      2019-01-08 16:38:18       empty                                  empty
# 1      2019-01-08 16:38:18       empty                                  empty
# 2      2019-01-08 16:38:18       empty                                  empty
# 3      2019-01-08 16:38:18       empty                                  empty
# 4      2019-01-09 11:10:49       empty                                  empty
# ...                    ...         ...                                    ...
# 18089  2024-02-28 17:52:58       empty  Karma Reservations - WhatsApp Channel
# 18090  2024-02-28 09:16:57       empty  Karma Reservations - WhatsApp Channel
# 18091  2024-02-28 17:51:58       empty  Karma Reservations - WhatsApp Channel
# 18092  2024-02-28 17:53:58       empty  Karma Reservations - WhatsApp Channel
# 18093  2024-02-29 12:06:59       empty  Karma Reservations - WhatsApp Channel
#
#       Website  First Name     Last Name                                 Email  \
# 0       empty  Dr. Steven         Tracy                                 empty
# 1       empty        Paul           May  paulmay@intercept-australia.asia.com
# 2       empty    Muhammad  Andi H.N, St               nurkusumahadi@gmail.com
# 3       empty    Michelle       Rasborn               mrasborn@netvigator.com
# 4       empty       Bohao         Zhang                      100252655@qq.com
# ...       ...         ...           ...                                   ...
# 18089   empty        Eliz             -                                 empty
# 18090   empty         Mel        Harrop                                 empty
# 18091   empty     Pavlova             -                                 empty
# 18092   empty     Sanghee          Park                                 empty
# 18093   empty        Novi             -                                 empty
#
#        ... Lead Regions Street2    Country GDPR Compliant       City  \
# 0      ...         SEAP   empty  Australia          false      empty
# 1      ...         SEAP   empty  Australia          false  Melbourne
# 2      ...         SEAP   empty  Indonesia          false      empty
# 3      ...    UK/Europe   empty     Sweden           true      empty
# 4      ...        Other   empty      China          false      empty
# ...    ...          ...     ...        ...            ...        ...
# 18089  ...        empty   empty      empty          false      empty
# 18090  ...        empty   empty      empty          false      empty
# 18091  ...        empty   empty      empty          false      empty
# 18092  ...        empty   empty      empty          false      empty
# 18093  ...        empty   empty      empty          false      empty
#
#                           Street Lead Locations            Messages  \
# 0        1406/168 Kent St Sydney  Karma Kandara               empty
# 1         1234 Po Box 1234 South  Karma Kandara               empty
# 2      Lor In Residence F16 Solo  Karma Kandara               empty
# 3                          empty  Karma Kandara               empty
# 4                          empty  Karma Kandara               empty
# ...                          ...            ...                 ...
# 18089                      empty  Karma Kandara               empty
# 18090                      empty  Karma Kandara  Phone Leads, Agent
# 18091                      empty  Karma Kandara               empty
# 18092                      empty  Karma Kandara               empty
# 18093                      empty  Karma Kandara               empty
#
#       Agree with Terms and Condition Mobile
# 0                              false  empty
# 1                              false  empty
# 2                              false  empty
# 3                              false  empty
# 4                              false  empty
# ...                              ...    ...
# 18089                          false  empty
# 18090                          false  empty
# 18091                          false  empty
# 18092                          false  empty
# 18093                          false  empty
#
# [18094 rows x 24 columns]

# %%
find_member_booking = zoho_df.copy()

find_member_booking.loc[find_member_booking['Phone'].isin(df_booking['Phone1']), 'Same Value Find'] = 'Booking-Phone1'
find_member_booking.loc[find_member_booking['Phone'].isin(df_booking['Mobile']), 'Same Value Find'] = 'Booking-Mobile'
find_member_booking.loc[find_member_booking['Mobile'].isin(df_booking['Phone1']), 'Same Value Find'] = 'Booking-Phone1' 
find_member_booking.loc[find_member_booking['Mobile'].isin(df_booking['Mobile']), 'Same Value Find'] = 'Booking-Mobile'
find_member_booking.loc[find_member_booking['Email'].isin(df_booking['Email']), 'Same Value Find'] = 'Booking-Email'

find_member_booking.loc[find_member_booking['Phone'].isin(df_phone['Mobile']), 'Same Value Find'] = 'Member-Mobile' 
find_member_booking.loc[find_member_booking['Mobile'].isin(df_phone['Mobile']), 'Same Value Find'] = 'Member-Mobile'

find_member_booking.loc[find_member_booking['Email'].isin(df_email['Email']), 'Same Value Find'] = 'Member-Email'

find_member_booking.drop(find_member_booking.loc[find_member_booking['Same Value Find'].isna()].index, inplace=True)

count_booking_dedup = find_member_booking.loc[find_member_booking['Same Value Find'].str.contains('Booking', flags=re.I, regex=True)].shape[0]
count_member_dedup = find_member_booking.loc[find_member_booking['Same Value Find'].str.contains('Member', flags=re.I, regex=True)].shape[0]

find_member_booking.replace('empty', '', inplace=True)
# find_member_booking.to_csv(r'C:\Users\fajar\Documents\Python\Data\booking-member-dedup.csv', index=False)
# find_member_booking.to_excel(r'C:\Users\fajar\Documents\Python\Data\booking-member-dedup.xlsx', index=False)

#find_member_booking.loc[find_member_booking['Same Value Find'] == 'Booking-Phone1']

# %%
# data phone, mobile dam email member yang ada di master data 
count_wash_member = zoho_df.loc[
    zoho_df['Phone'].isin(df_booking['Phone1']) | 
    zoho_df['Phone'].isin(df_booking['Mobile']) |
    zoho_df['Mobile'].isin(df_booking['Phone1']) | 
    zoho_df['Mobile'].isin(df_booking['Mobile']) |
    zoho_df['Email'].isin(df_booking['Email'])| 

    zoho_df['Phone'].isin(df_phone['Mobile']) | 
    zoho_df['Mobile'].isin(df_phone['Mobile']) |

    zoho_df['Email'].isin(df_email['Email'])

].shape[0]

zoho_df.drop(zoho_df.loc[
    zoho_df['Phone'].isin(df_booking['Phone1']) | 
    zoho_df['Phone'].isin(df_booking['Mobile']) |
    zoho_df['Mobile'].isin(df_booking['Phone1']) | 
    zoho_df['Mobile'].isin(df_booking['Mobile']) |
    zoho_df['Email'].isin(df_booking['Email']) |
    
    zoho_df['Phone'].isin(df_phone['Mobile']) | 
    zoho_df['Mobile'].isin(df_phone['Mobile']) |

    zoho_df['Email'].isin(df_email['Email'])

    ].index, inplace=True)
    
zoho_df.reset_index(drop=True, inplace=True)

count_after_wash_member = zoho_df.shape[0]

# %%
count_email_only = zoho_df.loc[(zoho_df['Email'] != 'empty') & ((zoho_df['Phone'] == 'empty') & (zoho_df['Mobile'] == 'empty'))].shape[0]
count_phone_only = zoho_df.loc[(zoho_df['Email'] == 'empty') & ((zoho_df['Phone'] != 'empty') | (zoho_df['Mobile'] != 'empty'))].shape[0]
count_email_and_phone = zoho_df.loc[(zoho_df['Email'] != 'empty') & ((zoho_df['Phone'] != 'empty') | (zoho_df['Mobile'] != 'empty'))].shape[0]

count_blank = zoho_df.loc[(zoho_df['Email'] =='empty') & (zoho_df['Phone']=='empty') & (zoho_df['Mobile']=='empty')].shape[0]

# zoho_df.loc[(zoho_df['Email'] =='empty') & (zoho_df['Phone']=='empty') & (zoho_df['Mobile']=='empty')].to_excel(r'C:\Users\fajar\Documents\Python\Data\blank_data.xlsx', index=False)

zoho_df.loc[(zoho_df['Email'] != 'empty') & ((zoho_df['Phone'] == 'empty') & (zoho_df['Mobile'] == 'empty')), 'Contact Type'] = 'Email Only'
zoho_df.loc[(zoho_df['Email'] == 'empty') & ((zoho_df['Phone'] != 'empty') | (zoho_df['Mobile'] != 'empty')), 'Contact Type'] = 'Phone Only'
zoho_df.loc[(zoho_df['Email'] != 'empty') & ((zoho_df['Phone'] != 'empty') | (zoho_df['Mobile'] != 'empty')), 'Contact Type'] = 'Email and Phone'

zoho_df.drop(zoho_df.loc[(zoho_df['Email'] =='empty') & (zoho_df['Phone']=='empty') & (zoho_df['Mobile']=='empty')].index, inplace=True)
zoho_df.reset_index(drop=True, inplace=True)

count_after_wash_blank = zoho_df.shape[0]

# %%
arr_dedup = [count_deleted_wrong_format, count_duplicate_general, count_leads_test, count_email_OTA, count_email_karma, count_blank]
count_sum_dedup = sum(arr_dedup)
count_sum_dedup
# Out:
# 309

# %%
print("==========================================================")
print("Summary")
print("==========================================================")
print("Jumlah Filter Leads Awal : "+str(count_filter_awal))
print("Jumlah Format Email Salah : "+str(count_deleted_wrong_format))
print("Jumlah Setelah Clean Format Email Salah : "+str(count_after_deleted_wrong_format))
print("Jumlah Duplicate (Phone, Mobile dan Email) : "+str(count_duplicate_general))
print("Jumlah Setelah Clean Duplicate : "+str(count_after_dedup_duplicate))
print("Jumlah Lead Test : "+str(count_leads_test))
print("Jumlah Setelah Clean Lead Test : "+str(count_after_dedup_test))
print("Jumlah Email OTA : "+str(count_email_OTA))
print("Jumlah Setelah Clean Email OTA : "+str(count_after_clean_OTA))
print("Jumlah Email Karma : "+str(count_email_karma))
print("Jumlah Setelah Clean Email Karma : "+str(count_after_clean_karma))
print("Jumlah Wash Member : "+str(count_member_dedup))
print("Jumlah Wash Booking : "+str(count_booking_dedup))
print("Jumlah Setelah Wash Member : "+str(count_after_wash_member))
print("Jumlah Phone Email Blank (Setelah phone yang tidak valid dihapus) : "+str(count_blank))
print("Jumlah Setelah Wash Phone Email Blank : "+str(count_after_wash_blank))
print("==========================================================")
print("Contact Type")
print("==========================================================")
print("Jumlah Email Only : "+str(count_email_only))
print("Jumlah Phone Only : "+str(count_phone_only))
print("Jumlah Email dan Phone : "+str(count_email_and_phone))
# Out:
# ==========================================================
# Summary
# ==========================================================
# Jumlah Filter Leads Awal : 18402
# Jumlah Format Email Salah : 0
# Jumlah Setelah Clean Format Email Salah : 18402
# Jumlah Duplicate (Phone, Mobile dan Email) : 293
# Jumlah Setelah Clean Duplicate : 18109
# Jumlah Lead Test : 0
# Jumlah Setelah Clean Lead Test : 18109
# Jumlah Email OTA : 11
# Jumlah Setelah Clean Email OTA : 18098
# Jumlah Email Karma : 4
# Jumlah Setelah Clean Email Karma : 18094
# Jumlah Wash Member : 1091
# Jumlah Wash Booking : 245
# Jumlah Setelah Wash Member : 16758
# Jumlah Phone Email Blank (Setelah phone yang tidak valid dihapus) : 1
# Jumlah Setelah Wash Phone Email Blank : 16757
# ==========================================================
# Contact Type
# ==========================================================
# Jumlah Email Only : 0
# Jumlah Phone Only : 6026
# Jumlah Email dan Phone : 10731

# %%
print("==========================================================")
print("Summary Report")
print("==========================================================")
print("Jumlah Data Awal : "+str(count_filter_awal))
print("Jumlah Wash Dedup : "+str(count_sum_dedup))
print("Jumlah Wash Member : "+str(count_member_dedup))
print("Jumlah Wash Booking : "+str(count_booking_dedup))
print("Jumlah Data Akhir : "+str(count_after_wash_blank))
# Out:
# ==========================================================
# Summary Report
# ==========================================================
# Jumlah Data Awal : 18402
# Jumlah Wash Dedup : 309
# Jumlah Wash Member : 1091
# Jumlah Wash Booking : 245
# Jumlah Data Akhir : 16757

# %%
zoho_df['Phone-Old'] = zoho_df['Phone']

zoho_df.loc[zoho_df['Phone'].str.contains('^4444', regex=True), 'Zoho Updated'] = 'Yes'
zoho_df['Phone'].replace('^4444','44', inplace=True, regex=True)

zoho_df.loc[zoho_df['Phone'].str.contains('^6161|^6204|^62004|^624|^620614|^62614', regex=True), 'Zoho Updated'] = 'Yes'
zoho_df['Phone'].replace('^6161','61', inplace=True, regex=True)
zoho_df['Phone'].replace('^6204|^62004|^624|^620614|^62614','614', inplace=True, regex=True)

zoho_df.loc[zoho_df['Phone'].str.contains('^62628|^62008|^6208|^620628|^6206208|^6200361|^620361|^626236', regex=True), 'Zoho Updated'] = 'Yes'
zoho_df['Phone'].replace('^62628|^62008|^6208|^620628|^6206208','628', inplace=True, regex=True)
zoho_df['Phone'].replace('^6200361|^620361|^6262361','^62361', inplace=True, regex=True)
zoho_df.loc[zoho_df['Phone'].str.contains('^62361', regex=True), 'Telpon Rumah'] = 'Yes'


zoho_df.loc[zoho_df['Phone'].str.contains('^62060', regex=True), 'Zoho Updated'] = 'Yes'
zoho_df['Phone'].replace('^62060','60', inplace=True, regex=True)

zoho_df.loc[zoho_df['Phone'].str.contains('^62065', regex=True), 'Zoho Updated'] = 'Yes'
zoho_df['Phone'].replace('^62065','65', inplace=True, regex=True)

zoho_df.loc[zoho_df['Phone'].str.contains('^6282$|^62813$', regex=True), 'Zoho Updated'] = 'Yes'
zoho_df['Phone'].replace('^6282$|^62813$','', inplace=True, regex=True)

# %%
zoho_df['New Phone'] = '\'+' +zoho_df['Phone']

# %%
zoho_df.loc[
    (zoho_df['Phone'].str.contains('^44|^\+44')),
'New Country'
] = 'United Kingdom'

zoho_df.loc[
    (zoho_df['Phone'].str.contains('^62|^\+62')),
'New Country'
] = 'Indonesia'

zoho_df.loc[
    (zoho_df['Phone'].str.contains('^61|^\+61')),
'New Country'
] = 'Australia'

# %%
zoho_df.replace('empty', '', inplace=True)
zoho_df.to_csv(r'C:\Users\fajar\Documents\Python\Data\pg-kandara-updated.csv', index=False)
zoho_df.to_excel(r'C:\Users\fajar\Documents\Python\Data\pg-kandara-updated.xlsx', index=False)
