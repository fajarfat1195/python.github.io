# %%
import sys
sys.path.append('../')

import main_module as m
import zoho_filter_module as fil
import pandas as pd
import re
import numpy as np

# %load_ext autoreload
# %autoreload 2

dir_path = r'C:\Users\fajar\Documents\Python\Data\Zoho_Backup'
file_name = '\Leads_'

subset_col = ['Email']

# %%
df = pd.read_csv(r'C:\Users\fajar\Documents\Python\Data\data wedding.csv', on_bad_lines='skip')
count_data_awal = df.shape[0]
df.shape[0]

df['Created Time'] = pd.to_datetime(df['Created Time'], errors='coerce')
# fungsi errors cource untuk menhindari error jika value data date null atau kosong
# df['Birthdate'] = pd.to_datetime(df['Birthdate'], format='%Y-%m-%d', errors='coerce')
df.dtypes
df
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 df = pd.read_csv(r'C:\Users\fajar\Documents\Python\Data\data wedding.csv', on_bad_lines='skip')
#       2 count_data_awal = df.shape[0]
#       3 df.shape[0]
#
# ...

# %% [markdown]
# # ====================== Awal Filter Umum ======================

# %%
# hitung jumlah duplicate
count_duplicate_general = df.loc[df.duplicated(subset=subset_col)].shape[0]

zoho_df = df.loc[df.duplicated(subset=subset_col)].copy()

df.loc[df.duplicated(subset=subset_col)]
# Out:
#                      Record Id        Created Time  Lead Status  \
# 1     zcrm_3584690000503236067 2024-07-23 18:50:00          NaN
# 12    zcrm_3584690000507177079 2024-09-03 16:13:00          NaN
# 14    zcrm_3584690000514803100 2024-11-11 10:10:00          NaN
# 15    zcrm_3584690000514807119 2024-11-11 10:10:00          NaN
# 16    zcrm_3584690000514821113 2024-11-11 10:10:00          NaN
# ...                        ...                 ...          ...
# 6923  zcrm_3584690000516510116 2024-11-27 17:06:00          NaN
# 6938  zcrm_3584690000496545196 2024-05-23 04:42:00          NaN
# 6969  zcrm_3584690000489211243 2024-03-25 04:58:00          NaN
# 6977  zcrm_3584690000484306170 2024-02-20 05:34:00          NaN
# 6979  zcrm_3584690000504938876 2024-08-18 21:45:00          NaN
#
#          Lead Brand Lead Sub-Brand  Lead Source  \
# 1     Karma Resorts          Other  Web Enquiry
# 12    Karma Resorts          Other  Web Enquiry
# 14    Karma Resorts          Other  Web Enquiry
# ...

# %% [markdown]
# # ====================== Akhir Filter Umum ======================

# %%
zoho_df.replace('empty', '', inplace=True)
zoho_df.to_excel(r'C:\Users\fajar\Documents\Python\Data\zoho_dupe.xlsx', index=False)
