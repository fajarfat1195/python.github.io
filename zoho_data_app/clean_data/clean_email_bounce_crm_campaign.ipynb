# %%
import sys

import clean_data_modul as fil

sys.path.append('../')

import main_module as m
import pandas as pd
import re
import numpy as np

from datetime import date
from datetime import datetime
from datetime import datetime, timedelta

# %load_ext autoreload
# %autoreload 2

dir_path = r'C:\Users\fajar\Documents\Python\Data\Zoho_Backup'
file_name = '\Leads_'

cols = ['Record Id',	
'Created Time',
'Created Date',	
'First Name',	
'Last Name',	
'Email',	
'Phone',	
'Mobile',	
'Birthdate',	
'Year of Birth',
'Street',	
'Street2',	
'City',	
'State',	
'Country',	
'Nationality',
'Booking Status', 
'BookRef',
'Departure Date',	
'Arrival Date',	
'Card Type',	
'Marital Status',	
'Lead Brand',	
'Lead Sub-Brand',	
'Lead Source',	
'Lead Locations',	
'Lead Location Description',	
'Lead Source Description',	
'Lead Regions',
'Lead Status',
'Email Opt Out',	
'Opt In',
'Do Not Contact',
'Do Not Mail']
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
zoho_df = m.load_data_multiple(dir_path, file_name, cols)
count_data_awal = zoho_df.shape[0]
zoho_df = zoho_df.reindex(columns=cols)
zoho_df.shape[0]

zoho_df['Created Time'] = pd.to_datetime(zoho_df['Created Time'], format='%Y-%m-%d %H:%M:%S')
# fungsi errors cource untuk menhindari error jika value data date null atau kosong
# df['Birthdate'] = pd.to_datetime(df['Birthdate'], format='%Y-%m-%d', errors='coerce')

zoho_df.fillna('empty', inplace=True)
zoho_df
# Out:
#                         Record Id        Created Time Created Date  \
# 0        zcrm_3584690000000404058 2019-01-07 15:08:38   2019-01-06
# 1        zcrm_3584690000000404059 2019-01-07 15:08:38   2019-01-06
# 2        zcrm_3584690000000404060 2019-01-07 15:08:38   2019-01-06
# 3        zcrm_3584690000000404065 2019-01-07 15:08:38   2019-01-06
# 4        zcrm_3584690000000404068 2019-01-07 15:08:38   2019-01-06
# ...                           ...                 ...          ...
# 1890009  zcrm_3584690000481642001 2024-01-29 18:18:26        empty
# 1890010  zcrm_3584690000481646001 2024-01-29 18:23:00        empty
# 1890011  zcrm_3584690000481646030 2024-01-29 18:43:30        empty
# 1890012  zcrm_3584690000481647001 2024-01-29 18:26:22        empty
# 1890013  zcrm_3584690000481648001 2024-01-29 18:34:24        empty
#
#              First Name  Last Name                       Email  \
# 0              Nicholas       Wood  1230woodnicholas@gmail.com
# 1                  Liao       Yuan            158066546@qq.com
# 2               Vedanta   Abhiyoga  abhiyoga.vedanta@gmail.com
# 3                 Aidai  Atakanova      aidai.nurbek@gmail.com
# 4                 Ardra      Ardra  aliefardraqariru@gmail.com
# ...                 ...        ...                         ...
# 1890009        Narendra        Das          ndas3011@gmail.com
# 1890010        Narendra        Das          ndas3011@gmail.com
# 1890011            John      Milad      johnemilad@hotmail.com
# 1890012  Dimpal Rathore      Dewal         rdimpal95@gmail.com
# 1890013            John      Milad      johnemilad@hotmail.com
#
#                   Phone          Mobile   Birthdate Year of Birth  ...  \
# 0          +61438600845           empty       empty         empty  ...
# 1         8618718399923           empty       empty         empty  ...
# 2        +6282146524550           empty  2000-07-05          2000  ...
# 3          996779641590           empty  1997-02-05          1997  ...
# 4        +6282139300818  +6282139300818  2005-01-20          2005  ...
# ...                 ...             ...         ...           ...  ...
# 1890009    +19324412000           empty       empty         empty  ...
# 1890010   +919324412000           empty       empty         empty  ...
# 1890011   +447920583445           empty       empty         empty  ...
# 1890012   +917021362505           empty       empty         empty  ...
# 1890013   +447920583445           empty  1972-07-05         empty  ...
#
#          Lead Source     Lead Locations Lead Location Description  \
# 0               Wifi              empty                     empty
# 1               Wifi              empty                     empty
# 2               Wifi              empty                     empty
# 3               Wifi              empty                     empty
# 4               Wifi            Mall 21                     empty
# ...              ...                ...                       ...
# 1890009      Webchat              empty                     empty
# 1890010      Webchat              empty                     empty
# 1890011  Web Enquiry              empty                     empty
# 1890012  Web Enquiry  Karma Golden Camp                     empty
# 1890013          Web              empty                     empty
#
#                       Lead Source Description Lead Regions Lead Status  \
# 0                                 Purple Wifi         SEAP    New Lead
# 1                                 Purple Wifi        Other    New Lead
# 2                                 Purple Wifi         SEAP    New Lead
# 3                                 Purple Wifi    UK/Europe    New Lead
# 4                                 Purple Wifi         SEAP    New Lead
# ...                                       ...          ...         ...
# 1890009  Karma Experience India | Webchat Web        India       empty
# 1890010  Karma Experience India | Webchat Web        India       empty
# 1890011                    Karma Club Enquiry    UK/Europe       empty
# 1890012                       Form Contact Us        India       empty
# 1890013              Karma Reciprocal Members    UK/Europe       empty
#
#         Email Opt Out Opt In Do Not Contact Do Not Mail
# 0               false  false           true       false
# 1               false  false           true       false
# 2               false  false           true       false
# 3               false  false           true       false
# 4               false  false           true       false
# ...               ...    ...            ...         ...
# 1890009         false   true          false       false
# 1890010         false   true          false       false
# 1890011         false   true          false       false
# 1890012         false   true          false       false
# 1890013         false   true          false       false
#
# [1890014 rows x 34 columns]

# %%
path = r'C:\Users\fajar\Documents\Python\Data\Debounce\zoho campaign\compiled\Email Debounce Campaign Master.xlsx'
df_email = pd.read_excel(path, dtype='string', sheet_name='Master Delete')
df_email
# Out:
#                           Contact Email  \
# 0             dr_sanashaikh@hotmail.com
# 1       quintessentialcakes@hotmail.com
# 2               david@precinctmc.com.au
# 3            lizal@warragulearth.com.au
# 4            garymulvenney@gmail.com.au
# ...                                 ...
# 179793           achielladian@gmail.com
# 179794            marioradyko@gmail.com
# 179795               sandra@isynergy.id
# 179796             dwiyudi907@gmail.com
# 179797                    Tes@gmail.com
#
#                                             Bounce reason Delete Date Update
# 0       Permanent failure :ZCMTA error :email address ...   True  27-01-2024
# 1       Permanent failure :ZCMTA error :email address ...   True  27-01-2024
# 2                           Permanent failure :bad-domain   True  27-01-2024
# 3                           Permanent failure :bad-domain   True  27-01-2024
# 4              Permanent failure :ZCMTA error :bad-domain   True  27-01-2024
# ...                                                   ...    ...         ...
# 179793        Permanent failure :ZCMTA error :bad-mailbox   True  27-01-2024
# 179794        Permanent failure :ZCMTA error :bad-mailbox   True  27-01-2024
# 179795        Permanent failure :ZCMTA error :bad-mailbox   True  27-01-2024
# 179796   Permanent failure :ZCMTA error :inactive-mailbox   True  27-01-2024
# 179797        Permanent failure :ZCMTA error :bad-mailbox   True  27-01-2024
#
# [179798 rows x 4 columns]

# %%
df_email
# Out:
#                           Contact Email  \
# 0             dr_sanashaikh@hotmail.com
# 1       quintessentialcakes@hotmail.com
# 2               david@precinctmc.com.au
# 3            lizal@warragulearth.com.au
# 4            garymulvenney@gmail.com.au
# ...                                 ...
# 179793           achielladian@gmail.com
# 179794            marioradyko@gmail.com
# 179795               sandra@isynergy.id
# 179796             dwiyudi907@gmail.com
# 179797                    Tes@gmail.com
#
#                                             Bounce reason Delete Date Update
# 0       Permanent failure :ZCMTA error :email address ...   True  27-01-2024
# 1       Permanent failure :ZCMTA error :email address ...   True  27-01-2024
# 2                           Permanent failure :bad-domain   True  27-01-2024
# 3                           Permanent failure :bad-domain   True  27-01-2024
# 4              Permanent failure :ZCMTA error :bad-domain   True  27-01-2024
# ...                                                   ...    ...         ...
# 179793        Permanent failure :ZCMTA error :bad-mailbox   True  27-01-2024
# 179794        Permanent failure :ZCMTA error :bad-mailbox   True  27-01-2024
# 179795        Permanent failure :ZCMTA error :bad-mailbox   True  27-01-2024
# 179796   Permanent failure :ZCMTA error :inactive-mailbox   True  27-01-2024
# 179797        Permanent failure :ZCMTA error :bad-mailbox   True  27-01-2024
#
# [179798 rows x 4 columns]

# %%
# data phone, mobile dam email member yang ada di master data (wash member)
zoho_df['Email'] = m.lowercase(zoho_df, 'Email')
m.clean_space(zoho_df, 'Email')

df_email['Contact Email'] = m.lowercase(df_email, 'Contact Email')
m.clean_space(df_email, 'Contact Email')
# Out:
# 0               dr_sanashaikh@hotmail.com
# 1         quintessentialcakes@hotmail.com
# 2                 david@precinctmc.com.au
# 3              lizal@warragulearth.com.au
# 4              garymulvenney@gmail.com.au
#                        ...
# 179793             achielladian@gmail.com
# 179794              marioradyko@gmail.com
# 179795                 sandra@isynergy.id
# 179796               dwiyudi907@gmail.com
# 179797                      tes@gmail.com
# Name: Contact Email, Length: 179798, dtype: string

# %%
# data phone, mobile dam email member yang ada di master data 
count_deleted_email = zoho_df.loc[

    zoho_df['Email'].isin(df_email['Contact Email'])

].shape[0]

# data phone, mobile dam email member yang ada di master data 
deleted_email = zoho_df.loc[

    zoho_df['Email'].isin(df_email['Contact Email'])

].copy()

# %%
count_email_only = deleted_email.loc[(deleted_email['Email'] != 'empty') & ((deleted_email['Phone'] == 'empty') & (deleted_email['Mobile'] == 'empty'))].shape[0]
count_phone_only = deleted_email.loc[(deleted_email['Email'] == 'empty') & ((deleted_email['Phone'] != 'empty') | (deleted_email['Mobile'] != 'empty'))].shape[0]
count_email_and_phone = deleted_email.loc[(deleted_email['Email'] != 'empty') & ((deleted_email['Phone'] != 'empty') | (deleted_email['Mobile'] != 'empty'))].shape[0]

count_blank = deleted_email.loc[(deleted_email['Email'] =='empty') & (deleted_email['Phone']=='empty') & (deleted_email['Mobile']=='empty')].shape[0]

# deleted_email.loc[(deleted_email['Email'] =='empty') & (deleted_email['Phone']=='empty') & (deleted_email['Mobile']=='empty')].to_excel(r'C:\Users\fajar\Documents\Python\Data\blank_data.xlsx', index=False)

deleted_email.loc[(deleted_email['Email'] != 'empty') & ((deleted_email['Phone'] == 'empty') & (deleted_email['Mobile'] == 'empty')), 'Contact Type'] = 'Email Only'
deleted_email.loc[(deleted_email['Email'] == 'empty') & ((deleted_email['Phone'] != 'empty') | (deleted_email['Mobile'] != 'empty')), 'Contact Type'] = 'Phone Only'
deleted_email.loc[(deleted_email['Email'] != 'empty') & ((deleted_email['Phone'] != 'empty') | (deleted_email['Mobile'] != 'empty')), 'Contact Type'] = 'Email and Phone'

deleted_email.drop(deleted_email.loc[(deleted_email['Email'] =='empty') & (deleted_email['Phone']=='empty') & (deleted_email['Mobile']=='empty')].index, inplace=True)
deleted_email.reset_index(drop=True, inplace=True)

count_after_wash_blank = deleted_email.shape[0]

# %%
print("Jumlah Data Yang Akan di Delete : "+str(count_deleted_email))
print("Jumlah Phone Email Blank (Setelah phone yang tidak valid dihapus) : "+str(count_blank))
print("Jumlah Setelah Wash Phone Email Blank : "+str(count_after_wash_blank))
print("==========================================================")
print("Contact Type")
print("==========================================================")
print("Jumlah Email Only : "+str(count_email_only))
print("Jumlah Phone Only : "+str(count_phone_only))
print("Jumlah Email dan Phone : "+str(count_email_and_phone))
# Out:
# Jumlah Data Yang Akan di Delete : 59224
# Jumlah Phone Email Blank (Setelah phone yang tidak valid dihapus) : 0
# Jumlah Setelah Wash Phone Email Blank : 59224
# ==========================================================
# Contact Type
# ==========================================================
# Jumlah Email Only : 14938
# Jumlah Phone Only : 0
# Jumlah Email dan Phone : 44286

# %%
deleted_email.replace('empty', '', inplace=True)

# %%
deleted_email
# Out:
#                       Record Id        Created Time Created Date First Name  \
# 0      zcrm_3584690000000404455 2019-01-08 11:07:28   2019-01-03        Nat
# 1      zcrm_3584690000000404466 2019-01-08 11:07:28   2019-01-03      Sarah
# 2      zcrm_3584690000000404486 2019-01-08 11:07:28   2019-01-03       Sari
# 3      zcrm_3584690000000404507 2019-01-08 11:07:28   2019-01-03      James
# 4      zcrm_3584690000000404509 2019-01-08 11:07:28   2019-01-03      Peter
# ...                         ...                 ...          ...        ...
# 59219  zcrm_3584690000475801621 2024-01-08 15:12:46                   Madhu
# 59220  zcrm_3584690000475975691 2024-01-09 14:40:25   2024-01-09     Mayuri
# 59221  zcrm_3584690000479763437 2024-01-15 14:27:52                 Mandeep
# 59222  zcrm_3584690000479806812 2024-01-15 14:33:09                  Andrew
# 59223  zcrm_3584690000479822239 2024-01-15 09:40:07   2024-01-14      Marco
#
#        Last Name                                       Email          Phone  \
# 0            Rou                               nat@gmail.com   +61422009343
# 1      Chalklley                             sarah@gmail.com  +971555746655
# 2          Akita  sari.soccer-kj_syl6-c.tl37v_v@docomo.ne.jp    19076861888
# 3        Rainbow                     jim.rainbow@hotmail.com  +447789878787
# 4         Lester                        peter.lester@rbs.com  +447932063075
# ...          ...                                         ...            ...
# 59219          K                                yy@gmail.com   +91989098789
# 59220      Potay                      pogaru2010@gmail.co.in
# 59221      Singh                           singh06@yahoo.com  +917986838516
# 59222     Duncan               andrewrichardduncan@yahoo.com  +351920092832
# 59223     Signar                    marco.signar01@gmail.com
#
#               Mobile   Birthdate Year of Birth  ...           Lead Locations  \
# 0                                               ...
# 1      +971555746655                      1920  ...         Karma Beach Bali
# 2                                               ...
# 3                                               ...
# 4                     1979-04-17          1979  ...
# ...              ...         ...           ...  ...                      ...
# 59219                                           ...  Karma Royal Boat Lagoon
# 59220                                           ...
# 59221                                           ...        Karma Royal Palms
# 59222                                           ...     Karma Royal Jimbaran
# 59223                                           ...            Karma Kandara
#
#       Lead Location Description    Lead Source Description Lead Regions  \
# 0                                              Purple Wifi         SEAP
# 1                                              Purple Wifi  Middle East
# 2                                              Purple Wifi        Other
# 3                                              Purple Wifi    UK/Europe
# 4                                              Purple Wifi    UK/Europe
# ...                         ...                        ...          ...
# 59219                            IND | FB MF | Boat Lagoon
# 59220                              Newsletter Subscription        India
# 59221                                            Viewpoint
# 59222                                            Viewpoint
# 59223
#
#       Lead Status Email Opt Out Opt In Do Not Contact Do Not Mail  \
# 0        New Lead         false  false          false       false
# 1        New Lead         false  false          false       false
# 2        New Lead         false  false          false       false
# 3        New Lead         false  false          false       false
# 4        New Lead         false  false          false       false
# ...           ...           ...    ...            ...         ...
# 59219                     false  false          false       false
# 59220                     false  false          false       false
# 59221                     false   true          false       false
# 59222                     false   true          false       false
# 59223    New Lead         false  false          false       false
#
#           Contact Type
# 0      Email and Phone
# 1      Email and Phone
# 2      Email and Phone
# 3      Email and Phone
# 4      Email and Phone
# ...                ...
# 59219  Email and Phone
# 59220       Email Only
# 59221  Email and Phone
# 59222  Email and Phone
# 59223       Email Only
#
# [59224 rows x 35 columns]

# %%
delete_record_crm = deleted_email.loc[deleted_email['Contact Type'] == 'Email Only'].copy()
update_record_crm = deleted_email.loc[deleted_email['Contact Type'] == 'Email and Phone'].copy()


delete_crm_cols = ['Record Id']
update_crm_cols = ['Record Id','Email']

delete_record_crm = delete_record_crm.reindex(columns=delete_crm_cols)
update_record_crm = update_record_crm.reindex(columns=update_crm_cols)

delete_record_crm['Test'] = True
update_record_crm['Email'] = ''

# %%
# delete_record_crm.to_excel(r'C:\Users\fajar\Documents\Python\Data\Debounce\mailwizz debounce log - vps\Clean\2024\Jan\02 Jan\delete_record_crm.xlsx', index=False)
# update_record_crm.to_excel(r'C:\Users\fajar\Documents\Python\Data\Debounce\mailwizz debounce log - vps\Clean\2024\Jan\02 Jan\update_record_crm.xlsx', index=False)
# deleted_email.to_excel(r'C:\Users\fajar\Documents\Python\Data\Debounce\mailwizz debounce log - vps\Clean\2024\Jan\02 Jan\clean_data_email.xlsx', index=False)

delete_record_crm.to_csv(r'C:\Users\fajar\Documents\Python\Data\Debounce\zoho campaign\clean\2024\Jan\30 Jan\delete_record_crm.csv', index=False)
update_record_crm.to_csv(r'C:\Users\fajar\Documents\Python\Data\Debounce\zoho campaign\clean\2024\Jan\30 Jan\update_record_crm.csv', index=False)
deleted_email.to_excel(r'C:\Users\fajar\Documents\Python\Data\Debounce\zoho campaign\clean\2024\Jan\30 Jan\clean_data_email.xlsx', index=False)
