# %%
import sys
sys.path.append('../')

import main_module as m
import zoho_filter_module as fil
import pandas as pd
import re
import numpy as np

# %load_ext autoreload
# %autoreload 2

dir_path = r'C:\Users\fajar\Documents\Python\Data\Zoho_Backup'
file_name = '\Leads_'

cols = ['Record Id',	
'Created Time',
'Created Date',	
'First Name',	
'Last Name',	
'Email',	
'Phone',	
'Mobile',	
'Birthdate',	
'Year of Birth',
'Street',	
'Street2',	
'City',	
'State',	
'Country',	
'Nationality',
'Booking Status', 
'BookRef',
'Departure Date',	
'Arrival Date',	
'Card Type',	
'Marital Status',	
'Lead Brand',	
'Lead Sub-Brand',	
'Lead Source',	
'Lead Locations',	
'Lead Source Description',	
'Lead Regions',
'Lead Status',
'Email Opt Out',	
'Opt In',
'Do Not Contact',
'Do Not Mail',
'Website']

# %%
df = m.load_data_multiple(dir_path, file_name, cols)
count_data_awal = df.shape[0]
df = df.reindex(columns=cols)
df.shape[0]

df['Created Time'] = pd.to_datetime(df['Created Time'], format='%Y-%m-%d %H:%M:%S')
# fungsi errors cource untuk menhindari error jika value data date null atau kosong
# df['Birthdate'] = pd.to_datetime(df['Birthdate'], format='%Y-%m-%d', errors='coerce')
df.dtypes
df
# Out:
#                         Record Id        Created Time Created Date First Name  \
# 0        zcrm_3584690000000404058 2019-01-07 15:08:38   2019-01-06   Nicholas
# 1        zcrm_3584690000000404059 2019-01-07 15:08:38   2019-01-06       Liao
# 2        zcrm_3584690000000404060 2019-01-07 15:08:38   2019-01-06    Vedanta
# 3        zcrm_3584690000000404065 2019-01-07 15:08:38   2019-01-06      Aidai
# 4        zcrm_3584690000000404068 2019-01-07 15:08:38   2019-01-06      Ardra
# ...                           ...                 ...          ...        ...
# 4705476  zcrm_3584690000472560346 2023-12-11 17:56:13         <NA>         인근
# 4705477  zcrm_3584690000472560347 2023-12-11 17:56:13         <NA>         희연
# 4705478  zcrm_3584690000472560348 2023-12-11 17:56:13         <NA>          김
# 4705479  zcrm_3584690000472561001 2023-12-11 18:19:07         <NA>       Dani
# 4705480  zcrm_3584690000472568001 2023-12-11 18:42:31         <NA>       Dewi
#
#          Last Name                       Email           Phone  \
# 0             Wood  1230woodnicholas@gmail.com    +61438600845
# 1             Yuan            158066546@qq.com   8618718399923
# 2         Abhiyoga  abhiyoga.vedanta@gmail.com  +6282146524550
# 3        Atakanova      aidai.nurbek@gmail.com    996779641590
# 4            Ardra  aliefardraqariru@gmail.com  +6282139300818
# ...            ...                         ...             ...
# 4705476          조           97demian@daum.net    821048467956
# 4705477          진      wlsehdwns123@naver.com    821032321917
# 4705478         현오         kho053070@gmail.com    821062752908
# 4705479     George     danigeorge100@gmail.com   +971508846110
# 4705480   nursanti      santitaengoo@gmail.com  +6285695166646
#
#                  Mobile   Birthdate Year of Birth  ...  Lead Source  \
# 0                  <NA>        <NA>          <NA>  ...         Wifi
# 1                  <NA>        <NA>          <NA>  ...         Wifi
# 2                  <NA>  2000-07-05          2000  ...         Wifi
# 3                  <NA>  1997-02-05          1997  ...         Wifi
# 4        +6282139300818  2005-01-20          2005  ...         Wifi
# ...                 ...         ...           ...  ...          ...
# 4705476            <NA>        <NA>          <NA>  ...        Other
# 4705477            <NA>        <NA>          <NA>  ...        Other
# 4705478            <NA>        <NA>          <NA>  ...        Other
# 4705479            <NA>  1986-01-08          1986  ...   Guest Exit
# 4705480  +6285695166646        <NA>          1996  ...  Web Enquiry
#
#               Lead Locations  \
# 0                       <NA>
# 1                       <NA>
# 2                       <NA>
# 3                       <NA>
# 4                    Mall 21
# ...                      ...
# 4705476          Karma Beach
# 4705477          Karma Beach
# 4705478          Karma Beach
# 4705479  Sales Deck Jimbaran
# 4705480      intan sari cafe
#
#                                    Lead Source Description Lead Regions  \
# 0                                              Purple Wifi         SEAP
# 1                                              Purple Wifi        Other
# 2                                              Purple Wifi         SEAP
# 3                                              Purple Wifi    UK/Europe
# 4                                              Purple Wifi         SEAP
# ...                                                    ...          ...
# 4705476  Reservation di Mare Restaurant  & Karma Beach ...         SEAP
# 4705477  Reservation di Mare Restaurant  & Karma Beach ...         SEAP
# 4705478  Reservation di Mare Restaurant  & Karma Beach ...         SEAP
# 4705479  Jimbaran | REGISTRATION CONFIRMED | Your Exclu...         SEAP
# 4705480  YTID | Web | W2MAR23 | Guest Survey ID intan s...         SEAP
#
#           Lead Status Email Opt Out Opt In Do Not Contact Do Not Mail Website
# 0            New Lead         false  false           true       false    <NA>
# 1            New Lead         false  false           true       false    <NA>
# 2            New Lead         false  false           true       false    <NA>
# 3            New Lead         false  false           true       false    <NA>
# 4            New Lead         false  false           true       false    <NA>
# ...               ...           ...    ...            ...         ...     ...
# 4705476      New Lead         false   true          false       false    <NA>
# 4705477      New Lead         false   true          false       false    <NA>
# 4705478      New Lead         false   true          false       false    <NA>
# 4705479  Hot Prospect         false   true          false       false    <NA>
# 4705480  Hot Prospect         false  false          false       false    <NA>
#
# [4705481 rows x 34 columns]

# %% [markdown]
# # ====================== Awal Filter Umum ======================

# %%
# hitung jumlah duplicate
count_duplicate_general = df.loc[df.duplicated(subset=['First Name', 'Last Name', 'Phone','Mobile','Email', 'Lead Brand',	
'Lead Sub-Brand', 'Lead Source', 'Lead Source Description'])].shape[0]

zoho_df = df.loc[df.duplicated(subset=['First Name', 'Last Name', 'Phone','Mobile','Email', 'Lead Brand',	
'Lead Sub-Brand', 'Lead Source', 'Lead Source Description'])].copy()

df.loc[df.duplicated(subset=['First Name', 'Last Name', 'Phone','Mobile','Email', 'Lead Brand',	
'Lead Sub-Brand', 'Lead Source', 'Lead Source Description'])]
# Out:
#                         Record Id        Created Time Created Date  \
# 4660030  zcrm_3584690000463573383 2023-10-02 19:21:18         <NA>
# 4660055  zcrm_3584690000463595001 2023-10-02 21:13:33         <NA>
# 4660056  zcrm_3584690000463596001 2023-10-02 21:13:33         <NA>
# 4660143  zcrm_3584690000463620828 2023-10-03 17:40:53         <NA>
# 4660219  zcrm_3584690000463630404 2023-10-03 14:11:07         <NA>
# ...                           ...                 ...          ...
# 4701202  zcrm_3584690000472487380 2023-12-11 16:34:00   2023-12-11
# 4701242  zcrm_3584690000472492071 2023-12-11 16:04:08         <NA>
# 4701261  zcrm_3584690000472493275 2023-12-11 17:11:06         <NA>
# 4701278  zcrm_3584690000472494269 2023-12-11 16:33:58   2023-12-11
# 4701290  zcrm_3584690000472495211 2023-12-11 16:34:01   2023-12-11
#
#          First Name          Last Name                               Email  \
# 4660030      Pravin    Prataprao Patil                newpppatil@gmail.com
# 4660055        Hồng                 Ny  noemailfield+667306@karmagroup.com
# 4660056        Hồng                 Ny  noemailfield+667306@karmagroup.com
# 4660143     Timothy  John Hetherington          timhetherington2@gmail.com
# 4660219    Paramita                Das              arpankundu89@gmail.com
# ...             ...                ...                                 ...
# 4701202  Katie King         Katie King                 katie.king5@nhs.net
# 4701242  Dhusrathan         Padayachee                 dussiep59@gmail.com
# 4701261       Sohan            S Patil                patilsohan@gmail.com
# 4701278  Katie King         Katie King                 katie.king5@nhs.net
# 4701290  Katie King         Katie King                 katie.king5@nhs.net
#
#                  Phone        Mobile Birthdate Year of Birth  ...  \
# 4660030           <NA>          <NA>      <NA>          <NA>  ...
# 4660055   +84896216333  +84896216333      <NA>          <NA>  ...
# 4660056   +84896216333  +84896216333      <NA>          <NA>  ...
# 4660143           <NA>          <NA>      <NA>          <NA>  ...
# 4660219           <NA>          <NA>      <NA>          <NA>  ...
# ...                ...           ...       ...           ...  ...
# 4701202  +447496210194          <NA>      <NA>          <NA>  ...
# 4701242           <NA>          <NA>      <NA>          <NA>  ...
# 4701261           <NA>          <NA>      <NA>          <NA>  ...
# 4701278  +447496210194          <NA>      <NA>          <NA>  ...
# 4701290  +447496210194          <NA>      <NA>          <NA>  ...
#
#          Lead Source      Lead Locations  \
# 4660030      Webchat                <NA>
# 4660055  Web Enquiry             General
# 4660056  Web Enquiry             General
# 4660143      Webchat                <NA>
# 4660219      Webchat                <NA>
# ...              ...                 ...
# 4701202  Web Enquiry  Karma Salford Hall
# 4701242      Webchat                <NA>
# 4701261      Webchat                <NA>
# 4701278  Web Enquiry  Karma Salford Hall
# 4701290  Web Enquiry  Karma Salford Hall
#
#                                    Lead Source Description Lead Regions  \
# 4660030     Karma Concierge India Fractional | Webchat Web        India
# 4660055   KE | Web | W3SEP23 | Restaurant Feedback Vietnam         <NA>
# 4660056   KE | Web | W3SEP23 | Restaurant Feedback Vietnam         <NA>
# 4660143                 Karma Concierge Bali | Webchat Web        Other
# 4660219                Karma Concierge India | Webchat Web        India
# ...                                                    ...          ...
# 4701202  Karma Salford Hall -Download Wedding Brochure ...    UK/Europe
# 4701242                 Karma Concierge Bali | Webchat Web         SEAP
# 4701261                Karma Concierge India | Webchat Web    UK/Europe
# 4701278  Karma Salford Hall -Download Wedding Brochure ...    UK/Europe
# 4701290  Karma Salford Hall -Download Wedding Brochure ...    UK/Europe
#
#         Lead Status Email Opt Out Opt In Do Not Contact Do Not Mail  \
# 4660030        <NA>         false   true          false       false
# 4660055    New Lead         false  false          false       false
# 4660056    New Lead         false  false          false       false
# 4660143        <NA>         false   true          false       false
# 4660219        <NA>         false   true          false       false
# ...             ...           ...    ...            ...         ...
# 4701202        <NA>         false   true          false       false
# 4701242        <NA>         false   true          false       false
# 4701261        <NA>         false   true          false       false
# 4701278        <NA>         false   true          false       false
# 4701290        <NA>         false   true          false       false
#
#                                                    Website
# 4660030  https://karmagroup.com/find-destination/karma-...
# 4660055                                               <NA>
# 4660056                                               <NA>
# 4660143               https://karmagroup.com/member-login/
# 4660219                                               <NA>
# ...                                                    ...
# 4701202  https://karmagroup.com/weddings-at-karma-salfo...
# 4701242     https://karmaclub.karmagroup.com/member/login/
# 4701261               https://karmagroup.com/member-login/
# 4701278  https://karmagroup.com/weddings-at-karma-salfo...
# 4701290  https://karmagroup.com/weddings-at-karma-salfo...
#
# [1595 rows x 34 columns]

# %% [markdown]
# # ====================== Akhir Filter Umum ======================

# %%
zoho_df.replace('empty', '', inplace=True)
zoho_df.to_excel(r'C:\Users\fajar\Documents\Python\Data\zoho_dupe.xlsx', index=False)
