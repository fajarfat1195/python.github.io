# %%
import sys
sys.path.append('../')

import main_module as m
import zoho_filter_module as fil
import pandas as pd
import re
import numpy as np

# %load_ext autoreload
# %autoreload 2

dir_path = r'C:\Users\fajar\Documents\Python\Data\Zoho_Backup'
file_name = '\Leads_'

cols = ['Record Id',	
'Created Time',
'Created Date',	
'First Name',	
'Last Name',	
'Email',	
'Phone',	
'Mobile',	
'Birthdate',	
'Year of Birth',
'Street',	
'Street2',	
'City',	
'State',	
'Country',	
'Nationality',
'Booking Status', 
'BookRef',
'Departure Date',	
'Arrival Date',	
'Card Type',	
'Marital Status',	
'Lead Brand',	
'Lead Sub-Brand',	
'Lead Source',	
'Lead Locations',	
'Lead Source Description',	
'Lead Regions',
'Lead Status',
'Email Opt Out',	
'Opt In',
'Do Not Contact',
'Do Not Mail',
'Website']
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
df = m.load_data_multiple(dir_path, file_name, cols)
count_data_awal = df.shape[0]
df = df.reindex(columns=cols)
df.shape[0]

df['Created Time'] = pd.to_datetime(df['Created Time'], format='%Y-%m-%d %H:%M:%S')
# fungsi errors cource untuk menhindari error jika value data date null atau kosong
# df['Birthdate'] = pd.to_datetime(df['Birthdate'], format='%Y-%m-%d', errors='coerce')
df.sort_values('Created Time', ascending=False, inplace=True)
df.dtypes
df
# Out:
#                        Record Id        Created Time Created Date First Name  \
# 490546  zcrm_3584690000519302001 2024-12-23 18:38:44         <NA>     Mahesh
# 490535  zcrm_3584690000519277148 2024-12-23 18:29:46         <NA>      Vikas
# 490534  zcrm_3584690000519277115 2024-12-23 18:04:04         <NA>   Vladimir
# 490545  zcrm_3584690000519298001 2024-12-23 18:02:31         <NA>    Aleksei
# 490544  zcrm_3584690000519294034 2024-12-23 17:57:49         <NA>     Regina
# ...                          ...                 ...          ...        ...
# 5       zcrm_3584690000000450110 2019-01-08 16:38:18         <NA>      Maeve
# 4       zcrm_3584690000000450109 2019-01-08 16:38:18         <NA>  Ana Maria
# 3       zcrm_3584690000000450106 2019-01-08 16:38:18         <NA>       Lisa
# 2       zcrm_3584690000000450087 2019-01-08 16:38:18         <NA>    Siobhan
# 0       zcrm_3584690000000404602 2019-01-08 11:07:28   2021-07-21   Frederic
#
#         Last Name                          Email           Phone Mobile  \
# 490546       Bhat  maheshbhat5676@rediffmail.com   +919833138338   <NA>
# 490535    Vishnoi         vikvishnoi@yahoo.co.in   +919897601630   <NA>
# 490534  Goncharov                 wws9@yandex.ru    +79688464775   <NA>
# 490545    Iurinov          middle.fngz@gmail.com  +6281239020607   <NA>
# 490544  Giriichuk            re_gi_sh_ka@mail.ru  +6281239020598   <NA>
# ...           ...                            ...             ...    ...
# 5           Maher          maeve.maher@gmail.com    353868702583   <NA>
# 4        Weileder       m.weileder@sonnenlink.de     15253234700   <NA>
# 3       Ferkovich           lisajo2009@yahoo.com     14062394749   <NA>
# 2       Gallagher    gallaghersiobhan@eircom.net    353879597603   <NA>
# 0           Bonin      fredericbonin79@gmail.com  +6281236100502   <NA>
#
#          Birthdate Year of Birth  ...           Lead Source  \
# 490546        <NA>          <NA>  ...           Web Enquiry
# 490535        <NA>          <NA>  ...           Web Enquiry
# 490534        <NA>          <NA>  ...  Karma Beach VIP 2023
# 490545        <NA>          <NA>  ...  Karma Beach VIP 2023
# 490544        <NA>          <NA>  ...  Karma Beach VIP 2023
# ...            ...           ...  ...                   ...
# 5       1973-01-15          1973  ...           Past Guests
# 4             <NA>          <NA>  ...                 Other
# 3       1963-07-08          1963  ...           Past Guests
# 2       1973-03-14          1973  ...           Past Guests
# 0       1981-10-03          1981  ...                Agency
#
#             Lead Locations                  Lead Source Description  \
# 490546  Royal Haathi Mahal                Timeshare Booking Request
# 490535        Karma Haveli                Timeshare Booking Request
# 490534                <NA>  Karma Beach VIP membership sign up 2023
# 490545                <NA>  Karma Beach VIP membership sign up 2023
# 490544                <NA>  Karma Beach VIP membership sign up 2023
# ...                    ...                                      ...
# 5            Karma Bavaria                                     <NA>
# 4            Karma Bavaria          MICE Contacts from Ioanna email
# 3            Karma Bavaria                                     <NA>
# 2            Karma Bavaria                                     <NA>
# 0            Karma Kandara                                    KAREN
#
#        Lead Regions Lead Status Email Opt Out Opt In Do Not Contact  \
# 490546        India        <NA>         false   true          false
# 490535        India        <NA>         false   true          false
# 490534    UK/Europe        <NA>         false   true          false
# 490545         SEAP        <NA>         false   true          false
# 490544         SEAP        <NA>         false   true          false
# ...             ...         ...           ...    ...            ...
# 5         UK/Europe    New Lead         false   true           true
# 4         UK/Europe    New Lead         false   true          false
# 3         UK/Europe    New Lead          true  false           true
# 2         UK/Europe    New Lead         false   true           true
# 0              SEAP    New Lead         false  false          false
#
#        Do Not Mail                                            Website
# 490546       false  https://karmagroup.com/find-destination/karma-...
# 490535       false  https://karmagroup.com/find-destination/karma-...
# 490534       false            https://karmagroup.com/karma-beach-vip/
# 490545       false            https://karmagroup.com/karma-beach-vip/
# 490544       false            https://karmagroup.com/karma-beach-vip/
# ...            ...                                                ...
# 5             true                                               <NA>
# 4            false                                               <NA>
# 3             true                                               <NA>
# 2             true                                               <NA>
# 0            false                                               <NA>
#
# [490547 rows x 34 columns]

# %% [markdown]
# # ====================== Awal Filter Umum ======================

# %%
# hitung jumlah duplicate
count_duplicate_general = df.loc[df.duplicated(subset=['First Name', 'Last Name', 'Phone','Mobile','Email', 'Lead Brand',	
'Lead Sub-Brand', 'Lead Source', 'Lead Source Description'])].shape[0]

zoho_df = df.loc[df.duplicated(subset=['First Name', 'Last Name', 'Phone','Mobile','Email', 'Lead Brand',	
'Lead Sub-Brand', 'Lead Source', 'Lead Source Description'])].copy()

zoho_df_all_dupe = df.loc[df.duplicated(subset=['First Name', 'Last Name', 'Phone','Mobile','Email', 'Lead Brand',	
'Lead Sub-Brand', 'Lead Source', 'Lead Source Description'], keep=False)].copy()

df.loc[df.duplicated(subset=['First Name', 'Last Name', 'Phone','Mobile','Email', 'Lead Brand',	
'Lead Sub-Brand', 'Lead Source', 'Lead Source Description'])]
# Out:
#                        Record Id        Created Time Created Date First Name  \
# 490274  zcrm_3584690000519144231 2024-12-23 12:39:58         <NA>     Xinyan
# 490007  zcrm_3584690000519097380 2024-12-23 01:41:25         <NA>   Anuradha
# 490063  zcrm_3584690000519106500 2024-12-23 01:41:06   2024-12-23   Anuradha
# 490191  zcrm_3584690000519134364 2024-12-23 01:39:40         <NA>   Anuradha
# 490273  zcrm_3584690000519144184 2024-12-23 01:35:17         <NA>   Anuradha
# ...                          ...                 ...          ...        ...
# 2192    zcrm_3584690000000461791 2019-01-09 11:11:23         <NA>     Marcin
# 2282    zcrm_3584690000000461897 2019-01-09 11:11:23         <NA>      Tracy
# 1555    zcrm_3584690000000460280 2019-01-09 11:11:13         <NA>        Jan
# 1009    zcrm_3584690000000459050 2019-01-09 11:11:06         <NA>  Friedbert
# 619     zcrm_3584690000000457838 2019-01-09 11:10:59         <NA>   Bertrand
#
#         Last Name                       Email           Phone          Mobile  \
# 490274        Xin         245770508@gmail.com  +8613502730531  +8613502730531
# 490007    Labania  anuradhaslabania@gmail.com   +918178888948            <NA>
# 490063    Labania  anuradhaslabania@gmail.com            <NA>            <NA>
# 490191    Labania  anuradhaslabania@gmail.com   +918178888948            <NA>
# 490273    Labania  anuradhaslabania@gmail.com   +918178888948            <NA>
# ...           ...                         ...             ...             ...
# 2192         Klos                        <NA>     48608283399            <NA>
# 2282       Markey                        <NA>    +61416393927            <NA>
# 1555      Honnens                        <NA>    +61421324120            <NA>
# 1009     Anschutz                        <NA>  +4915222542768            <NA>
# 619     Lemettais                        <NA>     33643785279            <NA>
#
#          Birthdate Year of Birth  ...  Lead Source  \
# 490274        <NA>          <NA>  ...  Past Guests
# 490007        <NA>          <NA>  ...  Web Enquiry
# 490063        <NA>          <NA>  ...   Newsletter
# 490191        <NA>          <NA>  ...  Web Enquiry
# 490273        <NA>          <NA>  ...  Web Enquiry
# ...            ...           ...  ...          ...
# 2192    1975-03-06          1975  ...  Past Guests
# 2282          <NA>          <NA>  ...  Past Guests
# 1555          <NA>          <NA>  ...  Past Guests
# 1009    1953-09-20          1953  ...  Past Guests
# 619           <NA>          <NA>  ...  Past Guests
#
#                                    Lead Locations    Lead Source Description  \
# 490274                              Karma Kandara                       <NA>
# 490007                             Karma Sitabani  Timeshare Booking Request
# 490063                                       <NA>    Newsletter Subscription
# 490191                       Karma Martam Retreat  Timeshare Booking Request
# 490273                             Karma Sitabani  Timeshare Booking Request
# ...                                           ...                        ...
# 2192                                Karma Bavaria                       <NA>
# 2282                               Karma Jimbaran                       <NA>
# 1555                               Karma Rottnest                       <NA>
# 1009                                Karma Bavaria                       <NA>
# 619     Karma Manoir;Karma Manoir des Deux Amants                       <NA>
#
#        Lead Regions   Lead Status Email Opt Out Opt In Do Not Contact  \
# 490274         <NA>          <NA>         false   true          false
# 490007        India          <NA>         false   true          false
# 490063        India          <NA>         false  false          false
# 490191        India          <NA>         false   true          false
# 490273        India          <NA>         false   true          false
# ...             ...           ...           ...    ...            ...
# 2192      UK/Europe      New Lead          true  false           true
# 2282           SEAP  Wrong Number         false  false          false
# 1555           SEAP      New Lead         false  false          false
# 1009      UK/Europe      New Lead         false   true          false
# 619       UK/Europe      New Lead         false   true           true
#
#        Do Not Mail                                            Website
# 490274       false                                               <NA>
# 490007       false  https://karmagroup.com/find-destination/karma-...
# 490063       false  https://karmagroup.com/find-destination/karma-...
# 490191       false  https://karmagroup.com/gallery/gallery-karma-s...
# 490273       false  https://karmagroup.com/find-destination/karma-...
# ...            ...                                                ...
# 2192          true                                               <NA>
# 2282         false                                               <NA>
# 1555         false                                               <NA>
# 1009         false                                               <NA>
# 619           true                                               <NA>
#
# [2831 rows x 34 columns]

# %% [markdown]
# # ====================== Akhir Filter Umum ======================

# %%
zoho_df.replace('empty', '', inplace=True)
zoho_df_all_dupe.replace('empty', '', inplace=True)
zoho_df.to_excel(r'C:\Users\fajar\Documents\Python\Data\zoho_dupe.xlsx', index=False)
zoho_df_all_dupe.to_excel(r'C:\Users\fajar\Documents\Python\Data\zoho_all_dupe.xlsx', index=False)
