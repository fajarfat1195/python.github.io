# %%
import sys
sys.path.append('../')

import main_module as m
import zoho_filter_module as fil
import pandas as pd
import re
import numpy as np

# %load_ext autoreload
# %autoreload 2

dir_path = r'C:\Users\fajar.fatoni\Documents\Python\Data\Zoho_Backup'
file_name = '\Leads_'

cols = ['Record Id',	
'Created Time',
'Created Date',	
'First Name',	
'Last Name',	
'Email',	
'Phone',	
'Mobile',	
'Birthdate',	
'Year of Birth',
'Street',	
'Street2',	
'City',	
'State',	
'Country',	
'Nationality',
'Booking Status', 
'BookRef',
'Departure Date',	
'Arrival Date',	
'Card Type',	
'Marital Status',	
'Lead Brand',	
'Lead Sub-Brand',	
'Lead Source',	
'Lead Locations',	
'Lead Source Description',	
'Lead Regions',
'Lead Status',
'Email Opt Out',	
'Opt In',
'Do Not Contact',
'Do Not Mail',
'Website']

# %%
df = m.load_data_multiple(dir_path, file_name, cols)
count_data_awal = df.shape[0]
df = df.reindex(columns=cols)
df.shape[0]

df['Created Time'] = pd.to_datetime(df['Created Time'], format='%Y-%m-%d %H:%M:%S')
# fungsi errors cource untuk menhindari error jika value data date null atau kosong
# df['Birthdate'] = pd.to_datetime(df['Birthdate'], format='%Y-%m-%d', errors='coerce')
df.sort_values('Created Time', ascending=False, inplace=True)
df.dtypes
df
# Out:
# C:\Users\fajar.fatoni\Documents\Python\Data\Zoho_Backup\Leads_001.csv
# C:\Users\fajar.fatoni\Documents\Python\Data\Zoho_Backup\Leads_002.csv
# C:\Users\fajar.fatoni\Documents\Python\Data\Zoho_Backup\Leads_003.csv
# C:\Users\fajar.fatoni\Documents\Python\Data\Zoho_Backup\Leads_004.csv
# C:\Users\fajar.fatoni\Documents\Python\Data\Zoho_Backup\Leads_005.csv
# C:\Users\fajar.fatoni\Documents\Python\Data\Zoho_Backup\Leads_006.csv
#                        Record Id        Created Time Created Date  \
# 528815  zcrm_3584690000574622706 2025-11-24 18:40:39         <NA>
# 528875  zcrm_3584690000574631440 2025-11-24 18:34:18         <NA>
# 528908  zcrm_3584690000574634463 2025-11-24 18:25:10         <NA>
# 528907  zcrm_3584690000574634432 2025-11-24 17:57:28         <NA>
# 528874  zcrm_3584690000574631410 2025-11-24 17:57:18         <NA>
# ...                          ...                 ...          ...
# 10      zcrm_3584690000000450191 2019-01-08 16:38:18   2021-07-21
# 11      zcrm_3584690000000450193 2019-01-08 16:38:18         <NA>
# 12      zcrm_3584690000000450226 2019-01-08 16:38:18   2021-07-21
# 13      zcrm_3584690000000450260 2019-01-08 16:38:18         <NA>
# 0       zcrm_3584690000000404602 2019-01-08 11:07:28   2021-07-21
#
#            First Name  Last Name                         Email  \
# 528815          Chloe        Goh          chloegoh95@gmail.com
# 528875           <NA>        Raj       Rajsingh.2987@gmail.com
# 528908           <NA>     Reshmi        smithalpha@hotmail.com
# 528907        PALLAVI      SARAF    pallavisaraf2015@gmail.com
# 528874          Ishan     Sharma        Sharmaishan0@gmail.com
# ...               ...        ...                           ...
# 10      Ni Made Novia   Andryani          novia_made@yahoo.com
# 11           Michelle    Rasborn       mrasborn@netvigator.com
# 12        Maureellins    Joewyns  maureellinsjoewyns@gmail.com
# 13              Katia  Lansdowne     katia.lansdowne@sgcib.com
# 0            Frederic      Bonin     fredericbonin79@gmail.com
#
#                  Phone Mobile   Birthdate Year of Birth  ...  Lead Source  \
# 528815   +447831203665   <NA>        <NA>          <NA>  ...  Web Enquiry
# 528875            <NA>   <NA>        <NA>          <NA>  ...      Webchat
# 528908            <NA>   <NA>        <NA>          <NA>  ...      Webchat
# 528907            <NA>   <NA>        <NA>          <NA>  ...      Webchat
# 528874   +447436978903   <NA>        <NA>          <NA>  ...  Web Enquiry
# ...                ...    ...         ...           ...  ...          ...
# 10      +6281511634635   <NA>  1980-11-10          1980  ...       Agency
# 11         85290173230   <NA>  1976-08-20          1976  ...  Past Guests
# 12      +6282221100639   <NA>  2000-04-14          2000  ...       Agency
# 13       +447904244011   <NA>        <NA>          <NA>  ...  Past Guests
# 0       +6281236100502   <NA>  1981-10-03          1981  ...       Agency
#
#                                    Lead Locations  \
# 528815                              Karma Kandara
# 528875                                       <NA>
# 528908                                       <NA>
# 528907                                       <NA>
# 528874                                       <NA>
# ...                                           ...
# 10                                  Karma Kandara
# 11                                  Karma Kandara
# 12                                  Karma Kandara
# 13      Karma Manoir;Karma Manoir des Deux Amants
# 0                                   Karma Kandara
#
#                                   Lead Source Description Lead Regions  \
# 528815  Karma Kandara -Download Wedding Brochure at Ka...    UK/Europe
# 528875               Karma Experience India | Webchat Web         <NA>
# 528908               Karma Experience India | Webchat Web         SEAP
# 528907               Karma Experience India | Webchat Web        India
# 528874                                     World of Karma         <NA>
# ...                                                   ...          ...
# 10                                                  KAREN         SEAP
# 11                                                   <NA>    UK/Europe
# 12                                                  KAREN         SEAP
# 13                                                   <NA>    UK/Europe
# 0                                                   KAREN         SEAP
#
#         Lead Status Email Opt Out Opt In Do Not Contact Do Not Mail  \
# 528815         <NA>         false   true          false       false
# 528875         <NA>         false   true          false       false
# 528908         <NA>         false   true          false       false
# 528907         <NA>         false   true          false       false
# 528874         <NA>         false   true          false       false
# ...             ...           ...    ...            ...         ...
# 10         New Lead         false  false          false       false
# 11      No Response         false   true          false       false
# 12         New Lead         false  false          false       false
# 13         New Lead          true  false           true        true
# 0          New Lead         false  false          false       false
#
#                                                   Website
# 528815  https://karmagroup.com/weddings-at-karma-kanda...
# 528875                                               <NA>
# 528908                             http://m.facebook.com/
# 528907              https://karmaexperience.com/about.php
# 528874  https://karmaclub.karmagroup.com/world-of-karm...
# ...                                                   ...
# 10                                                   <NA>
# 11                                                   <NA>
# 12                                                   <NA>
# 13                                                   <NA>
# 0                                                    <NA>
#
# [529037 rows x 34 columns]

# %% [markdown]
# # ====================== Awal Filter Umum ======================

# %%
# hitung jumlah duplicate
count_duplicate_general = df.loc[df.duplicated(subset=['First Name', 'Last Name', 'Phone','Mobile','Email', 'Lead Brand',	
'Lead Sub-Brand', 'Lead Source', 'Lead Source Description'])].shape[0]

zoho_df = df.loc[df.duplicated(subset=['First Name', 'Last Name', 'Phone','Mobile','Email', 'Lead Brand',	
'Lead Sub-Brand', 'Lead Source', 'Lead Source Description'])].copy()

zoho_df_all_dupe = df.loc[df.duplicated(subset=['First Name', 'Last Name', 'Phone','Mobile','Email', 'Lead Brand',	
'Lead Sub-Brand', 'Lead Source', 'Lead Source Description'], keep=False)].copy()

df.loc[df.duplicated(subset=['First Name', 'Last Name', 'Phone','Mobile','Email', 'Lead Brand',	
'Lead Sub-Brand', 'Lead Source', 'Lead Source Description'])]
# Out:
#                        Record Id        Created Time Created Date  \
# 528668  zcrm_3584690000574582001 2025-11-23 12:42:13         <NA>
# 528657  zcrm_3584690000574577001 2025-11-23 12:41:23         <NA>
# 528637  zcrm_3584690000574571002 2025-11-23 12:40:17         <NA>
# 528620  zcrm_3584690000574491002 2025-11-22 10:12:39         <NA>
# 528611  zcrm_3584690000574434002 2025-11-21 21:11:41         <NA>
# ...                          ...                 ...          ...
# 269127  zcrm_3584690000261638417 2021-02-01 18:42:35   2021-02-01
# 266416  zcrm_3584690000247801254 2020-11-30 13:34:41   2020-11-30
# 264803  zcrm_3584690000242868834 2020-11-03 00:58:30   2020-11-03
# 264635  zcrm_3584690000241924554 2020-10-24 18:04:14   2020-10-24
# 261489  zcrm_3584690000206319002 2020-07-21 19:45:08   2020-07-21
#
#          First Name Last Name                        Email          Phone  \
# 528668       BABAJI      HULE             bvhule@gmail.com  +919892395417
# 528657       BABAJI      HULE             bvhule@gmail.com  +919892395417
# 528637       BABAJI      HULE             bvhule@gmail.com  +919892395417
# 528620         jude     mills       judemills_@hotmail.com   +61468887830
# 528611      Dr Arun     Patil        arunpatil93@gmail.com  +919964031248
# ...             ...       ...                          ...            ...
# 269127     Bhaswati  Mazumdar          bhaswatih@gmail.com           <NA>
# 266416     Ashfaque     Qadri         aqadri1604@gmail.com           <NA>
# 264803  Krishnanand   Gaonkar  krishnandagoankar@gmail.com           <NA>
# 264635         Ajit     Agtey             agteys@gmail.com           <NA>
# 261489       Khushi   Ganwani           khushjaydp@msn.com           <NA>
#
#        Mobile Birthdate Year of Birth  ...  Lead Source  Lead Locations  \
# 528668   <NA>      <NA>          <NA>  ...  Web Enquiry  Karma Jimbaran
# 528657   <NA>      <NA>          <NA>  ...  Web Enquiry   Karma Kandara
# 528637   <NA>      <NA>          <NA>  ...  Web Enquiry   Karma Kandara
# 528620   <NA>      <NA>          <NA>  ...  Web Enquiry   Karma Panalee
# 528611   <NA>      <NA>          <NA>  ...  Web Enquiry            <NA>
# ...       ...       ...           ...  ...          ...             ...
# 269127   <NA>      <NA>          <NA>  ...   Newsletter      Karma Kasa
# 266416   <NA>      <NA>          <NA>  ...   Newsletter            <NA>
# 264803   <NA>      <NA>          <NA>  ...   Newsletter            <NA>
# 264635   <NA>      <NA>          <NA>  ...   Newsletter            <NA>
# 261489   <NA>      <NA>          <NA>  ...   Newsletter            <NA>
#
#                             Lead Source Description Lead Regions Lead Status  \
# 528668  Karma Resort Destinations - Booking Enquiry        India        <NA>
# 528657  Karma Resort Destinations - Booking Enquiry        India        <NA>
# 528637  Karma Resort Destinations - Booking Enquiry        India        <NA>
# 528620         Karma Panalee - Two Palms Beach Club         SEAP        <NA>
# 528611                        Karma Club Contact Us        India        <NA>
# ...                                             ...          ...         ...
# 269127                      Newsletter Subscription        India        <NA>
# 266416                      Newsletter Subscription        India        <NA>
# 264803                      Newsletter Subscription        India        <NA>
# 264635                      Newsletter Subscription        India        <NA>
# 261489                      Newsletter Subscription        India        <NA>
#
#        Email Opt Out Opt In Do Not Contact Do Not Mail  \
# 528668         false   true          false       false
# 528657         false   true          false       false
# 528637         false   true          false       false
# 528620         false   true          false       false
# 528611         false   true          false       false
# ...              ...    ...            ...         ...
# 269127         false  false          false       false
# 266416         false  false          false       false
# 264803         false  false          false       false
# 264635         false  false          false       false
# 261489         false  false          false       false
#
#                                                   Website
# 528668  https://karmaresortdestinations.com/booking-en...
# 528657  https://karmaresortdestinations.com/booking-en...
# 528637  https://karmaresortdestinations.com/booking-en...
# 528620      https://karmagroup.com/karma-two-palms-beach/
# 528611     https://karmaclub.karmagroup.com/destinations/
# ...                                                   ...
# 269127  https://karmakasa.karmagroup.com/?utm_medium=e...
# 266416                            https://karmagroup.com/
# 264803       https://karmagroup.com/gallery/karma-chakra/
# 264635                 https://karmagroup.com/membership/
# 261489                            https://karmagroup.com/
#
# [1212 rows x 34 columns]

# %% [markdown]
# # ====================== Akhir Filter Umum ======================

# %%
zoho_df.replace('empty', '', inplace=True)
zoho_df_all_dupe.replace('empty', '', inplace=True)
zoho_df.to_excel(r'C:\Users\fajar.fatoni\Documents\Python\Data\zoho_dupe.xlsx', index=False)
zoho_df_all_dupe.to_excel(r'C:\Users\fajar.fatoni\Documents\Python\Data\zoho_dupe(keep original).xlsx', index=False)
