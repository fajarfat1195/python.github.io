# %%
import sys
sys.path.append('../')

import main_module as m
import zoho_filter_module as fil
import pandas as pd
import re
import numpy as np

# %load_ext autoreload
# %autoreload 2

dir_path = r'C:\Users\fajar.fatoni\Documents\Python\Data\Zoho_Backup'
file_name = '\Leads_'

cols = ['Record Id',	
'Created Time',
'Created Date',	
'First Name',	
'Last Name',	
'Email',	
'Phone',	
'Mobile',	
'Birthdate',	
'Year of Birth',
'Street',	
'Street2',	
'City',	
'State',	
'Country',	
'Nationality',
'Booking Status', 
'BookRef',
'Departure Date',	
'Arrival Date',	
'Card Type',	
'Marital Status',	
'Lead Brand',	
'Lead Sub-Brand',	
'Lead Source',	
'Lead Locations',	
'Lead Source Description',	
'Lead Regions',
'Lead Status',
'Email Opt Out',	
'Opt In',
'Do Not Contact',
'Do Not Mail',
'Website']
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
df = m.load_data_multiple(dir_path, file_name, cols)
count_data_awal = df.shape[0]
df = df.reindex(columns=cols)
df.shape[0]

df['Created Time'] = pd.to_datetime(df['Created Time'], format='%Y-%m-%d %H:%M:%S')
# fungsi errors cource untuk menhindari error jika value data date null atau kosong
# df['Birthdate'] = pd.to_datetime(df['Birthdate'], format='%Y-%m-%d', errors='coerce')
df.sort_values('Created Time', ascending=False, inplace=True)
df.dtypes
df
# Out:
#                        Record Id        Created Time Created Date First Name  \
# 496185  zcrm_3584690000524777155 2025-02-17 18:34:53         <NA>      Sahil
# 496188  zcrm_3584690000524778106 2025-02-17 18:28:45         <NA>       Test
# 496109  zcrm_3584690000524732034 2025-02-17 17:59:56   2025-02-17       Adam
# 495938  zcrm_3584690000524693112 2025-02-17 17:59:25   2025-02-17   Shraddha
# 496195  zcrm_3584690000524788001 2025-02-17 17:58:53   2025-02-17        aRy
# ...                          ...                 ...          ...        ...
# 5       zcrm_3584690000000450110 2019-01-08 16:38:18         <NA>      Maeve
# 4       zcrm_3584690000000450109 2019-01-08 16:38:18         <NA>  Ana Maria
# 3       zcrm_3584690000000450106 2019-01-08 16:38:18         <NA>       Lisa
# 2       zcrm_3584690000000450087 2019-01-08 16:38:18         <NA>    Siobhan
# 0       zcrm_3584690000000404602 2019-01-08 11:07:28   2021-07-21   Frederic
#
#         Last Name                        Email             Phone Mobile  \
# 496185      Bagga     coolsahilbagga@gmail.com     +919310880880   <NA>
# 496188       Test               test@gmail.com     +919988998899   <NA>
# 496109    Burford       gillianeb@yahoo.com.au              <NA>   <NA>
# 495938          -  shraddhapatel84@yahoo.co.in              <NA>   <NA>
# 496195          -                         <NA>  +62877-8294-1744   <NA>
# ...           ...                          ...               ...    ...
# 5           Maher        maeve.maher@gmail.com      353868702583   <NA>
# 4        Weileder     m.weileder@sonnenlink.de       15253234700   <NA>
# 3       Ferkovich         lisajo2009@yahoo.com       14062394749   <NA>
# 2       Gallagher  gallaghersiobhan@eircom.net      353879597603   <NA>
# 0           Bonin    fredericbonin79@gmail.com    +6281236100502   <NA>
#
#          Birthdate Year of Birth  ...       Lead Source      Lead Locations  \
# 496185        <NA>          <NA>  ...         Karma App  Royal Haathi Mahal
# 496188        <NA>          <NA>  ...       Web Enquiry      Royal Monterio
# 496109        <NA>          <NA>  ...  WhatsApp Enquiry       Karma Kandara
# 495938        <NA>          <NA>  ...  WhatsApp Enquiry       Karma Kandara
# 496195        <NA>          <NA>  ...  WhatsApp Enquiry       Karma Kandara
# ...            ...           ...  ...               ...                 ...
# 5       1973-01-15          1973  ...       Past Guests       Karma Bavaria
# 4             <NA>          <NA>  ...             Other       Karma Bavaria
# 3       1963-07-08          1963  ...       Past Guests       Karma Bavaria
# 2       1973-03-14          1973  ...       Past Guests       Karma Bavaria
# 0       1981-10-03          1981  ...            Agency       Karma Kandara
#
#                       Lead Source Description Lead Regions Lead Status  \
# 496185              Timeshare Booking Request        India        <NA>
# 496188              Timeshare Booking Request        India        <NA>
# 496109  Karma Reservations - WhatsApp Channel         <NA>    New Lead
# 495938  Karma Reservations - WhatsApp Channel         <NA>    New Lead
# 496195  Karma Reservations - WhatsApp Channel         <NA>    New Lead
# ...                                       ...          ...         ...
# 5                                        <NA>    UK/Europe    New Lead
# 4             MICE Contacts from Ioanna email    UK/Europe    New Lead
# 3                                        <NA>    UK/Europe    New Lead
# 2                                        <NA>    UK/Europe    New Lead
# 0                                       KAREN         SEAP    New Lead
#
#        Email Opt Out Opt In Do Not Contact Do Not Mail  \
# 496185         false  false          false       false
# 496188         false   true          false       false
# 496109         false  false          false       false
# 495938         false  false          false       false
# 496195         false  false          false       false
# ...              ...    ...            ...         ...
# 5              false   true           true        true
# 4              false   true          false       false
# 3               true  false           true        true
# 2              false   true           true        true
# 0              false  false          false       false
#
#                                                   Website
# 496185                                               <NA>
# 496188  https://karmagroup.com/find-destination/karma-...
# 496109                                               <NA>
# 495938                                               <NA>
# 496195                                               <NA>
# ...                                                   ...
# 5                                                    <NA>
# 4                                                    <NA>
# 3                                                    <NA>
# 2                                                    <NA>
# 0                                                    <NA>
#
# [496196 rows x 34 columns]

# %% [markdown]
# # ====================== Awal Filter Umum ======================

# %%
# hitung jumlah duplicate
count_duplicate_general = df.loc[df.duplicated(subset=['First Name', 'Last Name', 'Phone','Mobile','Email', 'Lead Brand',	
'Lead Sub-Brand', 'Lead Source', 'Lead Source Description'])].shape[0]

zoho_df = df.loc[df.duplicated(subset=['First Name', 'Last Name', 'Phone','Mobile','Email', 'Lead Brand',	
'Lead Sub-Brand', 'Lead Source', 'Lead Source Description'])].copy()

zoho_df_all_dupe = df.loc[df.duplicated(subset=['First Name', 'Last Name', 'Phone','Mobile','Email', 'Lead Brand',	
'Lead Sub-Brand', 'Lead Source', 'Lead Source Description'], keep=False)].copy()

df.loc[df.duplicated(subset=['First Name', 'Last Name', 'Phone','Mobile','Email', 'Lead Brand',	
'Lead Sub-Brand', 'Lead Source', 'Lead Source Description'])]
# Out:
#                        Record Id        Created Time Created Date First Name  \
# 495565  zcrm_3584690000524625044 2025-02-14 16:03:00         <NA>       Prue
# 495526  zcrm_3584690000524559034 2025-02-14 10:57:18         <NA>   Shivendu
# 495516  zcrm_3584690000524543077 2025-02-14 10:41:33   2025-02-14        Ann
# 495552  zcrm_3584690000524612001 2025-02-14 10:41:33   2025-02-14        Ann
# 495545  zcrm_3584690000524608034 2025-02-14 10:41:33   2025-02-14        Ann
# ...                          ...                 ...          ...        ...
# 237978  zcrm_3584690000086908941 2019-08-01 16:13:02         <NA>       <NA>
# 106922  zcrm_3584690000007215325 2019-04-02 05:32:24   2016-03-22      Linda
# 98757   zcrm_3584690000007197402 2019-04-02 05:30:38   2016-05-12      Peter
# 17233   zcrm_3584690000005956562 2019-04-02 02:15:53   2017-01-18    Maureen
# 6089    zcrm_3584690000002016024 2019-02-14 14:39:20   2019-02-14     Natraj
#
#         Last Name                        Email          Phone Mobile  \
# 495565  Armistead      pruearmistead@gmail.com           <NA>   <NA>
# 495526       Gaur   Shivendu@bookmybooking.com  +917827946132   <NA>
# 495516         An  lolitailse@soarinfotech.com           <NA>   <NA>
# 495552         An  lolitailse@soarinfotech.com           <NA>   <NA>
# 495545         An  lolitailse@soarinfotech.com           <NA>   <NA>
# ...           ...                          ...            ...    ...
# 237978       <NA>                         <NA>           <NA>   <NA>
# 106922    Garrett                         <NA>   +61408572868   <NA>
# 98757      Brauer                         <NA>   +61437449088   <NA>
# 17233    Campbell          bboyang@hotmail.com   +61409688017   <NA>
# 6089       Sharma     natraj.sharma1@gmail.com           <NA>   <NA>
#
#          Birthdate Year of Birth  ...  Lead Source  Lead Locations  \
# 495565        <NA>          <NA>  ...      Webchat            <NA>
# 495526        <NA>          <NA>  ...  Web Enquiry            <NA>
# 495516        <NA>          <NA>  ...   Newsletter            <NA>
# 495552        <NA>          <NA>  ...   Newsletter            <NA>
# 495545        <NA>          <NA>  ...   Newsletter            <NA>
# ...            ...           ...  ...          ...             ...
# 237978        <NA>          <NA>  ...   Newsletter            <NA>
# 106922  1961-09-08          1961  ...   Membership            <NA>
# 98757   1954-03-27          1954  ...   Membership            <NA>
# 17233         <NA>          <NA>  ...  Past Guests  Karma Rottnest
# 6089          <NA>          <NA>  ...   Newsletter            <NA>
#
#                      Lead Source Description Lead Regions Lead Status  \
# 495565  Karma Experience India | Webchat Web         SEAP        <NA>
# 495526                       Form Contact Us        India        <NA>
# 495516               Newsletter Subscription         <NA>        <NA>
# 495552               Newsletter Subscription         <NA>        <NA>
# 495545               Newsletter Subscription         <NA>        <NA>
# ...                                      ...          ...         ...
# 237978                        VIP ambassador    UK/Europe    New Lead
# 106922                       Website Enquiry         SEAP        <NA>
# 98757                        Sales Deck Bali         SEAP        <NA>
# 17233                                   <NA>         SEAP        <NA>
# 6089                                    <NA>        Other    New Lead
#
#        Email Opt Out Opt In Do Not Contact Do Not Mail  \
# 495565         false   true          false       false
# 495526         false   true          false       false
# 495516         false  false          false       false
# 495552         false  false          false       false
# 495545         false  false          false       false
# ...              ...    ...            ...         ...
# 237978         false  false          false       false
# 106922         false  false          false       false
# 98757          false  false          false       false
# 17233          false  false          false       false
# 6089           false  false          false       false
#
#                                    Website
# 495565                                <NA>
# 495526  https://karmagroup.com/contact-us/
# 495516             https://karmagroup.com/
# 495552             https://karmagroup.com/
# 495545             https://karmagroup.com/
# ...                                    ...
# 237978                                <NA>
# 106922                                <NA>
# 98757                                 <NA>
# 17233                                 <NA>
# 6089                                  <NA>
#
# [251 rows x 34 columns]

# %% [markdown]
# # ====================== Akhir Filter Umum ======================

# %%
zoho_df.replace('empty', '', inplace=True)
zoho_df_all_dupe.replace('empty', '', inplace=True)
zoho_df.to_excel(r'C:\Users\fajar.fatoni\Documents\Python\Data\zoho_dupe.xlsx', index=False)
zoho_df_all_dupe.to_excel(r'C:\Users\fajar.fatoni\Documents\Python\Data\zoho_dupe(keep original).xlsx', index=False)
