# %%
import sys
sys.path.append('../')

import main_module as m
import zoho_filter_module as fil
import pandas as pd
import re
import numpy as np

# %load_ext autoreload
# %autoreload 2

dir_path = r'C:\Users\fajar\Documents\Python\Data\Zoho_Backup'
file_name = '\Leads_'

cols = ['Record Id',	
'Created Time',
'Created Date',	
'First Name',	
'Last Name',	
'Email',	
'Phone',	
'Mobile',	
'Birthdate',	
'Year of Birth',
'Street',	
'Street2',	
'City',	
'State',	
'Country',	
'Nationality',
'Booking Status', 
'BookRef',
'Departure Date',	
'Arrival Date',	
'Card Type',	
'Marital Status',	
'Lead Brand',	
'Lead Sub-Brand',	
'Lead Source',	
'Lead Locations',	
'Lead Source Description',	
'Lead Regions',
'Lead Status',
'Email Opt Out',	
'Opt In',
'Do Not Contact',
'Do Not Mail',
'Website']

# %%
df = m.load_data_multiple(dir_path, file_name, cols)
count_data_awal = df.shape[0]
df = df.reindex(columns=cols)
df.shape[0]

df['Created Time'] = pd.to_datetime(df['Created Time'], format='%Y-%m-%d %H:%M:%S')
# fungsi errors cource untuk menhindari error jika value data date null atau kosong
# df['Birthdate'] = pd.to_datetime(df['Birthdate'], format='%Y-%m-%d', errors='coerce')
df.sort_values('Created Time', ascending=False, inplace=True)
df.dtypes
df
# Out:
#                        Record Id        Created Time Created Date First Name  \
# 493159  zcrm_3584690000520957790 2025-01-13 18:36:37   2025-01-13       <NA>
# 493245  zcrm_3584690000521016109 2025-01-13 18:29:28         <NA>     neeraj
# 492873  zcrm_3584690000520916710 2025-01-13 18:28:44         <NA>     Bhavin
# 492958  zcrm_3584690000520932873 2025-01-13 18:26:14         <NA>       Maha
# 493244  zcrm_3584690000521016067 2025-01-13 18:12:02         <NA>       Toni
# ...                          ...                 ...          ...        ...
# 5       zcrm_3584690000000450110 2019-01-08 16:38:18         <NA>      Maeve
# 4       zcrm_3584690000000450109 2019-01-08 16:38:18         <NA>  Ana Maria
# 3       zcrm_3584690000000450106 2019-01-08 16:38:18         <NA>       Lisa
# 2       zcrm_3584690000000450087 2019-01-08 16:38:18         <NA>    Siobhan
# 0       zcrm_3584690000000404602 2019-01-08 11:07:28   2021-07-21   Frederic
#
#                 Last Name                         Email           Phone  \
# 493159  Samantha Williams  samantha67williams@gmail.com   +447341252874
# 493245             prasad            gomtipus@gmail.com   +919889192155
# 492873                  P             bvn2307@gmail.com   +919925516688
# 492958             Hijazi           mahairz@hotmail.com    +61451991276
# 493244              Truda          toni.truda@gmail.com    +61420361072
# ...                   ...                           ...             ...
# 5                   Maher         maeve.maher@gmail.com    353868702583
# 4                Weileder      m.weileder@sonnenlink.de     15253234700
# 3               Ferkovich          lisajo2009@yahoo.com     14062394749
# 2               Gallagher   gallaghersiobhan@eircom.net    353879597603
# 0                   Bonin     fredericbonin79@gmail.com  +6281236100502
#
#        Mobile   Birthdate Year of Birth  ...  Lead Source  \
# 493159   <NA>        <NA>          <NA>  ...  Web Enquiry
# 493245   <NA>        <NA>          <NA>  ...  Web Enquiry
# 492873   <NA>        <NA>          <NA>  ...  Web Enquiry
# 492958   <NA>        <NA>          <NA>  ...  Web Enquiry
# 493244   <NA>        <NA>          <NA>  ...  Web Enquiry
# ...       ...         ...           ...  ...          ...
# 5        <NA>  1973-01-15          1973  ...  Past Guests
# 4        <NA>        <NA>          <NA>  ...        Other
# 3        <NA>  1963-07-08          1963  ...  Past Guests
# 2        <NA>  1973-03-14          1973  ...  Past Guests
# 0        <NA>  1981-10-03          1981  ...       Agency
#
#                 Lead Locations  \
# 493159  Karma Lake Of Menteith
# 493245       Karma Golden Camp
# 492873            Karma Chakra
# 492958           Karma Kandara
# 493244           Karma Kandara
# ...                        ...
# 5                Karma Bavaria
# 4                Karma Bavaria
# 3                Karma Bavaria
# 2                Karma Bavaria
# 0                Karma Kandara
#
#                                   Lead Source Description Lead Regions  \
# 493159  Karma Lake Of Menteith - Download Wedding Broc...    UK/Europe
# 493245                          Timeshare Booking Request        India
# 492873                          Timeshare Booking Request        India
# 492958                          Timeshare Booking Request         SEAP
# 493244                          Timeshare Booking Request         SEAP
# ...                                                   ...          ...
# 5                                                    <NA>    UK/Europe
# 4                         MICE Contacts from Ioanna email    UK/Europe
# 3                                                    <NA>    UK/Europe
# 2                                                    <NA>    UK/Europe
# 0                                                   KAREN         SEAP
#
#        Lead Status Email Opt Out Opt In Do Not Contact Do Not Mail  \
# 493159        <NA>         false   true          false       false
# 493245        <NA>         false   true          false       false
# 492873        <NA>         false   true          false       false
# 492958        <NA>         false   true          false       false
# 493244        <NA>         false   true          false       false
# ...            ...           ...    ...            ...         ...
# 5         New Lead         false   true           true        true
# 4         New Lead         false   true          false       false
# 3         New Lead          true  false           true        true
# 2         New Lead         false   true           true        true
# 0         New Lead         false  false          false       false
#
#                                                   Website
# 493159  https://karmagroup.com/weddings-at-karma-lake-...
# 493245  https://karmagroup.com/find-destination/karma-...
# 492873  https://karmagroup.com/find-destination/karma-...
# 492958  https://karmagroup.com/find-destination/karma-...
# 493244  https://karmagroup.com/find-destination/karma-...
# ...                                                   ...
# 5                                                    <NA>
# 4                                                    <NA>
# 3                                                    <NA>
# 2                                                    <NA>
# 0                                                    <NA>
#
# [493249 rows x 34 columns]

# %% [markdown]
# # ====================== Awal Filter Umum ======================

# %%
# hitung jumlah duplicate
count_duplicate_general = df.loc[df.duplicated(subset=['First Name', 'Last Name', 'Phone','Mobile','Email', 'Lead Brand',	
'Lead Sub-Brand', 'Lead Source', 'Lead Source Description'])].shape[0]

zoho_df = df.loc[df.duplicated(subset=['First Name', 'Last Name', 'Phone','Mobile','Email', 'Lead Brand',	
'Lead Sub-Brand', 'Lead Source', 'Lead Source Description'])].copy()

zoho_df_all_dupe = df.loc[df.duplicated(subset=['First Name', 'Last Name', 'Phone','Mobile','Email', 'Lead Brand',	
'Lead Sub-Brand', 'Lead Source', 'Lead Source Description'], keep=False)].copy()

df.loc[df.duplicated(subset=['First Name', 'Last Name', 'Phone','Mobile','Email', 'Lead Brand',	
'Lead Sub-Brand', 'Lead Source', 'Lead Source Description'])]
# Out:
#                        Record Id        Created Time Created Date  \
# 493192  zcrm_3584690000520970035 2025-01-13 01:10:45         <NA>
# 492984  zcrm_3584690000520937044 2025-01-12 20:18:33   2025-01-12
# 492908  zcrm_3584690000520929088 2025-01-12 18:18:04   2025-01-12
# 492781  zcrm_3584690000520816076 2025-01-12 03:50:21   2025-01-11
# 492758  zcrm_3584690000520734001 2025-01-11 15:53:46         <NA>
# ...                          ...                 ...          ...
# 2192    zcrm_3584690000000461791 2019-01-09 11:11:23         <NA>
# 2282    zcrm_3584690000000461897 2019-01-09 11:11:23         <NA>
# 1555    zcrm_3584690000000460280 2019-01-09 11:11:13         <NA>
# 1009    zcrm_3584690000000459050 2019-01-09 11:11:06         <NA>
# 619     zcrm_3584690000000457838 2019-01-09 11:10:59         <NA>
#
#          First Name  Last Name                       Email           Phone  \
# 493192       martha   saridewi   saridewi.martha@gmail.com    +61406557889
# 492984  Shubhaprada  Sudarshan          shuba_hv@yahoo.com            <NA>
# 492908       ronald      cragg        roncragg@outlook.com            <NA>
# 492781         Sion    Roberts  sionrobertss@hotmail.co.uk   +447557946971
# 492758       sushil      goyal    sushilrgoyal80@gmail.com            <NA>
# ...             ...        ...                         ...             ...
# 2192         Marcin       Klos                        <NA>     48608283399
# 2282          Tracy     Markey                        <NA>    +61416393927
# 1555            Jan    Honnens                        <NA>    +61421324120
# 1009      Friedbert   Anschutz                        <NA>  +4915222542768
# 619        Bertrand  Lemettais                        <NA>     33643785279
#
#        Mobile   Birthdate Year of Birth  ...  Lead Source  \
# 493192   <NA>        <NA>          <NA>  ...  Web Enquiry
# 492984   <NA>        <NA>          <NA>  ...   Newsletter
# 492908   <NA>        <NA>          <NA>  ...   Newsletter
# 492781   <NA>        <NA>          <NA>  ...  Web Enquiry
# 492758   <NA>        <NA>          <NA>  ...      Webchat
# ...       ...         ...           ...  ...          ...
# 2192     <NA>  1975-03-06          1975  ...  Past Guests
# 2282     <NA>        <NA>          <NA>  ...  Past Guests
# 1555     <NA>        <NA>          <NA>  ...  Past Guests
# 1009     <NA>  1953-09-20          1953  ...  Past Guests
# 619      <NA>        <NA>          <NA>  ...  Past Guests
#
#                                    Lead Locations  \
# 493192                              Karma Kandara
# 492984                                       <NA>
# 492908                         Karma Sanctum SOHO
# 492781                         Karma Salford Hall
# 492758                                       <NA>
# ...                                           ...
# 2192                                Karma Bavaria
# 2282                               Karma Jimbaran
# 1555                               Karma Rottnest
# 1009                                Karma Bavaria
# 619     Karma Manoir;Karma Manoir des Deux Amants
#
#                                   Lead Source Description Lead Regions  \
# 493192  Karma Kandara -Download Wedding Brochure at Ka...         SEAP
# 492984                            Newsletter Subscription        India
# 492908                            Newsletter Subscription         <NA>
# 492781  Karma Salford Hall - Download Events Brochure ...    UK/Europe
# 492758               Karma Experience India | Webchat Web        India
# ...                                                   ...          ...
# 2192                                                 <NA>    UK/Europe
# 2282                                                 <NA>         SEAP
# 1555                                                 <NA>         SEAP
# 1009                                                 <NA>    UK/Europe
# 619                                                  <NA>    UK/Europe
#
#          Lead Status Email Opt Out Opt In Do Not Contact Do Not Mail  \
# 493192          <NA>         false   true          false       false
# 492984          <NA>         false  false          false       false
# 492908          <NA>         false  false          false       false
# 492781          <NA>         false   true          false       false
# 492758          <NA>         false   true          false       false
# ...              ...           ...    ...            ...         ...
# 2192        New Lead          true  false           true        true
# 2282    Wrong Number         false  false          false       false
# 1555        New Lead         false  false          false       false
# 1009        New Lead         false   true          false       false
# 619         New Lead         false   true           true        true
#
#                                                   Website
# 493192  https://karmagroup.com/weddings-at-karma-kanda...
# 492984             https://karmagroup.com/privacy-policy/
# 492908             https://www.sanctumsoho.com/restaurant
# 492781  https://karmagroup.com/events-at-karma-salford...
# 492758                            https://karmagroup.com/
# ...                                                   ...
# 2192                                                 <NA>
# 2282                                                 <NA>
# 1555                                                 <NA>
# 1009                                                 <NA>
# 619                                                  <NA>
#
# [2554 rows x 34 columns]

# %% [markdown]
# # ====================== Akhir Filter Umum ======================

# %%
zoho_df.replace('empty', '', inplace=True)
zoho_df_all_dupe.replace('empty', '', inplace=True)
zoho_df.to_excel(r'C:\Users\fajar\Documents\Python\Data\zoho_dupe.xlsx', index=False)
zoho_df_all_dupe.to_excel(r'C:\Users\fajar\Documents\Python\Data\zoho_all_dupe.xlsx', index=False)
