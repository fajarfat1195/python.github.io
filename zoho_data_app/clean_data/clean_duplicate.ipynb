# %%
import sys
sys.path.append('../')

import main_module as m
import zoho_filter_module as fil
import pandas as pd
import re
import numpy as np

# %load_ext autoreload
# %autoreload 2

dir_path = r'C:\Users\fajar.fatoni\Documents\Python\Data\Zoho_Backup'
file_name = '\Leads_'

cols = ['Record Id',	
'Created Time',
'Created Date',	
'First Name',	
'Last Name',	
'Email',	
'Phone',	
'Mobile',	
'Birthdate',	
'Year of Birth',
'Street',	
'Street2',	
'City',	
'State',	
'Country',	
'Nationality',
'Booking Status', 
'BookRef',
'Departure Date',	
'Arrival Date',	
'Card Type',	
'Marital Status',	
'Lead Brand',	
'Lead Sub-Brand',	
'Lead Source',	
'Lead Locations',	
'Lead Source Description',	
'Lead Regions',
'Lead Status',
'Email Opt Out',	
'Opt In',
'Do Not Contact',
'Do Not Mail',
'Website']

# %%
df = m.load_data_multiple(dir_path, file_name, cols)
count_data_awal = df.shape[0]
df = df.reindex(columns=cols)
df.shape[0]

df['Created Time'] = pd.to_datetime(df['Created Time'], format='%Y-%m-%d %H:%M:%S')
# fungsi errors cource untuk menhindari error jika value data date null atau kosong
# df['Birthdate'] = pd.to_datetime(df['Birthdate'], format='%Y-%m-%d', errors='coerce')
df.sort_values('Created Time', ascending=False, inplace=True)
df.dtypes
df
# Out:
#                        Record Id        Created Time Created Date  \
# 506072  zcrm_3584690000543509001 2025-05-05 17:36:33         <NA>
# 506071  zcrm_3584690000543498001 2025-05-05 17:06:17         <NA>
# 506038  zcrm_3584690000543416470 2025-05-05 16:59:47   2025-05-05
# 505843  zcrm_3584690000543159546 2025-05-05 16:14:07         <NA>
# 505704  zcrm_3584690000543050679 2025-05-05 16:07:53         <NA>
# ...                          ...                 ...          ...
# 10      zcrm_3584690000000450191 2019-01-08 16:38:18   2021-07-21
# 11      zcrm_3584690000000450193 2019-01-08 16:38:18         <NA>
# 12      zcrm_3584690000000450226 2019-01-08 16:38:18   2021-07-21
# 13      zcrm_3584690000000450260 2019-01-08 16:38:18         <NA>
# 0       zcrm_3584690000000404602 2019-01-08 11:07:28   2021-07-21
#
#             First Name       Last Name                         Email  \
# 506072        Jennifer           Poate          jenpoate@yahoo.co.uk
# 506071          DEBBIE          Elvins          deelvins@yahoo.co.uk
# 506038  Debbie Boucher  Debbie Boucher           bdebbie14@gmail.com
# 505843            <NA>            Alok          alokdhuria@gmail.com
# 505704        Julieann        Schembri    Littlebearrock@hotmail.com
# ...                ...             ...                           ...
# 10       Ni Made Novia        Andryani          novia_made@yahoo.com
# 11            Michelle         Rasborn       mrasborn@netvigator.com
# 12         Maureellins         Joewyns  maureellinsjoewyns@gmail.com
# 13               Katia       Lansdowne     katia.lansdowne@sgcib.com
# 0             Frederic           Bonin     fredericbonin79@gmail.com
#
#                  Phone Mobile   Birthdate Year of Birth  ...  Lead Source  \
# 506072    +33634119518   <NA>        <NA>          <NA>  ...  Web Enquiry
# 506071   +447446978291   <NA>        <NA>          <NA>  ...  Web Enquiry
# 506038   +447775917413   <NA>        <NA>          <NA>  ...  Web Enquiry
# 505843            <NA>   <NA>        <NA>          <NA>  ...      Webchat
# 505704            <NA>   <NA>        <NA>          <NA>  ...      Webchat
# ...                ...    ...         ...           ...  ...          ...
# 10      +6281511634635   <NA>  1980-11-10          1980  ...       Agency
# 11         85290173230   <NA>  1976-08-20          1976  ...  Past Guests
# 12      +6282221100639   <NA>  2000-04-14          2000  ...       Agency
# 13       +447904244011   <NA>        <NA>          <NA>  ...  Past Guests
# 0       +6281236100502   <NA>  1981-10-03          1981  ...       Agency
#
#                                    Lead Locations  \
# 506072                                       <NA>
# 506071                         Karma Salford Hall
# 506038                         Karma St. Martin's
# 505843                                       <NA>
# 505704                                       <NA>
# ...                                           ...
# 10                                  Karma Kandara
# 11                                  Karma Kandara
# 12                                  Karma Kandara
# 13      Karma Manoir;Karma Manoir des Deux Amants
# 0                                   Karma Kandara
#
#                                   Lead Source Description Lead Regions  \
# 506072  Karma Curated Experience - Desert Passage: Tak...    UK/Europe
# 506071               Friend of Karma - Discount Card 2023    UK/Europe
# 506038  Karma St. Martin's - Download Wedding Brochure...    UK/Europe
# 505843               Karma Experience India | Webchat Web        India
# 505704               Karma Experience India | Webchat Web         SEAP
# ...                                                   ...          ...
# 10                                                  KAREN         SEAP
# 11                                                   <NA>    UK/Europe
# 12                                                  KAREN         SEAP
# 13                                                   <NA>    UK/Europe
# 0                                                   KAREN         SEAP
#
#         Lead Status Email Opt Out Opt In Do Not Contact Do Not Mail  \
# 506072         <NA>         false   true          false       false
# 506071         <NA>         false   true          false       false
# 506038         <NA>         false   true          false       false
# 505843         <NA>         false   true          false       false
# 505704         <NA>         false   true          false       false
# ...             ...           ...    ...            ...         ...
# 10         New Lead         false  false          false       false
# 11      No Response         false   true          false       false
# 12         New Lead         false  false          false       false
# 13         New Lead          true  false           true        true
# 0          New Lead         false  false          false       false
#
#                                                   Website
# 506072  https://karmaclub.karmagroup.com/karma-curated...
# 506071  https://karmagroup.com/friend-of-karma-salford...
# 506038  https://karmagroup.com/weddings-at-karma-st-ma...
# 505843                          https://www.google.co.in/
# 505704                            https://www.google.com/
# ...                                                   ...
# 10                                                   <NA>
# 11                                                   <NA>
# 12                                                   <NA>
# 13                                                   <NA>
# 0                                                    <NA>
#
# [506073 rows x 34 columns]

# %% [markdown]
# # ====================== Awal Filter Umum ======================

# %%
# hitung jumlah duplicate
count_duplicate_general = df.loc[df.duplicated(subset=['First Name', 'Last Name', 'Phone','Mobile','Email', 'Lead Brand',	
'Lead Sub-Brand', 'Lead Source', 'Lead Source Description'])].shape[0]

zoho_df = df.loc[df.duplicated(subset=['First Name', 'Last Name', 'Phone','Mobile','Email', 'Lead Brand',	
'Lead Sub-Brand', 'Lead Source', 'Lead Source Description'])].copy()

zoho_df_all_dupe = df.loc[df.duplicated(subset=['First Name', 'Last Name', 'Phone','Mobile','Email', 'Lead Brand',	
'Lead Sub-Brand', 'Lead Source', 'Lead Source Description'], keep=False)].copy()

df.loc[df.duplicated(subset=['First Name', 'Last Name', 'Phone','Mobile','Email', 'Lead Brand',	
'Lead Sub-Brand', 'Lead Source', 'Lead Source Description'])]
# Out:
#                        Record Id        Created Time Created Date First Name  \
# 505585  zcrm_3584690000542643042 2025-05-03 01:27:54   2025-05-02       <NA>
# 505520  zcrm_3584690000542296001 2025-05-01 15:16:03         <NA>       <NA>
# 505463  zcrm_3584690000542086033 2025-05-01 07:28:28   2025-05-01       <NA>
# 505386  zcrm_3584690000541817065 2025-04-29 11:57:18   2025-04-29     Dennis
# 504789  zcrm_3584690000541579206 2025-04-28 15:01:10         <NA>      Ferry
# ...                          ...                 ...          ...        ...
# 452005  zcrm_3584690000502789001 2024-07-18 13:15:50         <NA>   Prashant
# 441231  zcrm_3584690000494125898 2024-05-03 02:09:07         <NA>        Les
# 400161  zcrm_3584690000451440001 2023-06-30 00:39:28   2023-06-30      Sanvi
# 398820  zcrm_3584690000449476277 2023-06-18 22:00:44   2023-06-18      Clive
# 312265  zcrm_3584690000313976917 2021-09-13 09:25:09   2021-06-26       Hala
#
#                 Last Name                                 Email  \
# 505585      Daniela Silva         danielasofiasilvauk@gmail.com
# 505520           Anupriya                  anupriya12@yahoo.com
# 505463  Jacqueline Gibson                jac.sweeney@icloud.com
# 505386             Lomman     jdstilingservice.dennis@gmail.com
# 504789               Test  ferry.yudhitama+21233@karmagroup.com
# ...                   ...                                   ...
# 452005               More              prashantnivas8@gmail.com
# 441231             Thomas              les.thomas0691@gmail.com
# 400161          Menghwani              menghwanisanvi@gmail.com
# 398820               Faux                    csfaux@hotmail.com
# 312265          Alnehlawi               halaalnehlawi@gmail.com
#
#                  Phone Mobile Birthdate Year of Birth  ...  Lead Source  \
# 505585   +447810454573   <NA>      <NA>          <NA>  ...  Web Enquiry
# 505520            <NA>   <NA>      <NA>          <NA>  ...      Webchat
# 505463   +447921511815   <NA>      <NA>          <NA>  ...  Web Enquiry
# 505386    +61408734574   <NA>      <NA>          <NA>  ...    Karma App
# 504789  +6287861085145   <NA>      <NA>          <NA>  ...  Web Enquiry
# ...                ...    ...       ...           ...  ...          ...
# 452005            <NA>   <NA>      <NA>          <NA>  ...      Webchat
# 441231   +447771887249   <NA>      <NA>          <NA>  ...  Web Enquiry
# 400161            <NA>   <NA>      <NA>          <NA>  ...   Newsletter
# 398820            <NA>   <NA>      <NA>          <NA>  ...   Newsletter
# 312265            <NA>   <NA>      <NA>          <NA>  ...  Past Guests
#
#                 Lead Locations  \
# 505585  Karma Lake Of Menteith
# 505520                    <NA>
# 505463  Karma Lake Of Menteith
# 505386          Karma Jimbaran
# 504789            Karma Minoan
# ...                        ...
# 452005                    <NA>
# 441231      Karma Salford Hall
# 400161                    <NA>
# 398820                    <NA>
# 312265           Karma Kandara
#
#                                   Lead Source Description Lead Regions  \
# 505585  Karma Lake Of Menteith - Download Wedding Broc...    UK/Europe
# 505520               Karma Experience India | Webchat Web        India
# 505463  Karma Lake Of Menteith - Download Elopement We...    UK/Europe
# 505386                                    Booking Request         SEAP
# 504789               Friend of Karma - Discount Card 2025         SEAP
# ...                                                   ...          ...
# 452005               Karma Experience India | Webchat Web        India
# 441231               Friend of Karma - Discount Card 2023    UK/Europe
# 400161                            Newsletter Subscription        India
# 398820                            Newsletter Subscription         <NA>
# 312265                                               <NA>         <NA>
#
#        Lead Status Email Opt Out Opt In Do Not Contact Do Not Mail  \
# 505585        <NA>         false   true          false       false
# 505520        <NA>         false   true          false       false
# 505463        <NA>         false   true          false       false
# 505386        <NA>         false  false          false       false
# 504789        <NA>         false   true          false       false
# ...            ...           ...    ...            ...         ...
# 452005        <NA>         false   true          false       false
# 441231        <NA>         false   true          false       false
# 400161        <NA>         false  false          false       false
# 398820        <NA>         false  false          false       false
# 312265    New Lead         false  false          false       false
#
#                                                   Website
# 505585  https://karmagroup.com/weddings-at-karma-lake-...
# 505520  https://karmagroup.com/find-destination/karma-...
# 505463  https://karmagroup.com/weddings-at-karma-lake-...
# 505386                                               <NA>
# 504789  https://karmagroup.com/friend-of-karma-minoan-...
# ...                                                   ...
# 452005  https://karmagroup.com/karma-curated-events/qu...
# 441231  https://karmagroup.com/friend-of-karma-salford...
# 400161           https://karmagroup.com/find-destination/
# 398820  https://karmagroup.com/gallery/karma-st-martins/#
# 312265                                               <NA>
#
# [103 rows x 34 columns]

# %% [markdown]
# # ====================== Akhir Filter Umum ======================

# %%
zoho_df.replace('empty', '', inplace=True)
zoho_df_all_dupe.replace('empty', '', inplace=True)
zoho_df.to_excel(r'C:\Users\fajar.fatoni\Documents\Python\Data\zoho_dupe.xlsx', index=False)
zoho_df_all_dupe.to_excel(r'C:\Users\fajar.fatoni\Documents\Python\Data\zoho_dupe(keep original).xlsx', index=False)
