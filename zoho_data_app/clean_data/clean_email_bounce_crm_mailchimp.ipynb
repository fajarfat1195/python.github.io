# %%
import sys

import clean_data_modul as fil

sys.path.append('../')

import main_module as m
import pandas as pd
import re
import numpy as np

from datetime import date
from datetime import datetime
from datetime import datetime, timedelta

# %load_ext autoreload
# %autoreload 2

dir_path = r'C:\Users\fajar.fatoni\Documents\Python\Data\Zoho_Backup'
file_name = '\Leads_'

cols = ['Record Id',	
'Created Time',
'Created Date',	
'First Name',	
'Last Name',	
'Email',	
'Phone',	
'Mobile',	
'Birthdate',	
'Year of Birth',
'Street',	
'Street2',	
'City',	
'State',	
'Country',	
'Nationality',
'Booking Status', 
'BookRef',
'Departure Date',	
'Arrival Date',	
'Card Type',	
'Marital Status',	
'Lead Brand',	
'Lead Sub-Brand',	
'Lead Source',	
'Lead Locations',	
'Lead Location Description',	
'Lead Source Description',	
'Lead Regions',
'Lead Status',
'Email Opt Out',	
'Opt In',
'Do Not Contact',
'Do Not Mail']
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
zoho_df = m.load_data_multiple(dir_path, file_name, cols)
count_data_awal = zoho_df.shape[0]
zoho_df = zoho_df.reindex(columns=cols)
zoho_df.shape[0]

zoho_df['Created Time'] = pd.to_datetime(zoho_df['Created Time'], format='%Y-%m-%d %H:%M:%S')
# fungsi errors cource untuk menhindari error jika value data date null atau kosong
# df['Birthdate'] = pd.to_datetime(df['Birthdate'], format='%Y-%m-%d', errors='coerce')

zoho_df.fillna('empty', inplace=True)
zoho_df
# Out:
# C:\Users\fajar.fatoni\Documents\Python\Data\Zoho_Backup\Leads_001.csv
# C:\Users\fajar.fatoni\Documents\Python\Data\Zoho_Backup\Leads_002.csv
# C:\Users\fajar.fatoni\Documents\Python\Data\Zoho_Backup\Leads_003.csv
# C:\Users\fajar.fatoni\Documents\Python\Data\Zoho_Backup\Leads_004.csv
# C:\Users\fajar.fatoni\Documents\Python\Data\Zoho_Backup\Leads_005.csv
# C:\Users\fajar.fatoni\Documents\Python\Data\Zoho_Backup\Leads_006.csv
#                        Record Id        Created Time Created Date First Name  \
# 0       zcrm_3584690000000404602 2019-01-08 11:07:28   2021-07-21   Frederic
# 1       zcrm_3584690000000450071 2019-01-08 16:38:18        empty  Sebastian
# 2       zcrm_3584690000000450087 2019-01-08 16:38:18        empty    Siobhan
# 3       zcrm_3584690000000450106 2019-01-08 16:38:18        empty       Lisa
# 4       zcrm_3584690000000450109 2019-01-08 16:38:18        empty  Ana Maria
# ...                          ...                 ...          ...        ...
# 516376  zcrm_3584690000565363037 2025-07-21 17:41:32        empty      Susan
# 516377  zcrm_3584690000565367001 2025-07-21 17:30:24   2025-07-20  Vladyslav
# 516378  zcrm_3584690000565367037 2025-07-21 17:30:26   2025-07-20      Gillw
# 516379  zcrm_3584690000565369001 2025-07-21 17:30:52   2025-07-21         Ax
# 516380  zcrm_3584690000565370001 2025-07-21 17:38:13        empty      empty
#
#         Last Name                        Email             Phone Mobile  \
# 0           Bonin    fredericbonin79@gmail.com    +6281236100502  empty
# 1            Rach                        empty     +498914342111  empty
# 2       Gallagher  gallaghersiobhan@eircom.net      353879597603  empty
# 3       Ferkovich         lisajo2009@yahoo.com       14062394749  empty
# 4        Weileder     m.weileder@sonnenlink.de       15253234700  empty
# ...           ...                          ...               ...    ...
# 516376      Jones       susanhelen91@gmail.com     +447543096118  empty
# 516377  Vladyslav                        empty  +380 68 071 5622  empty
# 516378      Gillw                        empty   +61 413 351 082  empty
# 516379         Ax                        empty    +7 916 6567743  empty
# 516380      Radha     radhaojethra80@gmail.com             empty  empty
#
#          Birthdate Year of Birth  ...  Lead Source Lead Locations  \
# 0       1981-10-03          1981  ...       Agency  Karma Kandara
# 1       1982-04-20          1982  ...  Past Guests  Karma Bavaria
# 2       1973-03-14          1973  ...  Past Guests  Karma Bavaria
# 3       1963-07-08          1963  ...  Past Guests  Karma Bavaria
# 4            empty         empty  ...        Other  Karma Bavaria
# ...            ...           ...  ...          ...            ...
# 516376  1991-03-01         empty  ...          Web          empty
# 516377       empty         empty  ...        Phone  Karma Kandara
# 516378       empty         empty  ...     WhatsApp  Karma Kandara
# 516379       empty         empty  ...     WhatsApp  Karma Kandara
# 516380       empty         empty  ...      Webchat          empty
#
#        Lead Location Description                Lead Source Description  \
# 0                          empty                                  KAREN
# 1                          empty                                  empty
# 2                          empty                                  empty
# 3                          empty                                  empty
# 4                          empty        MICE Contacts from Ioanna email
# ...                          ...                                    ...
# 516376                     empty               Karma Reciprocal Members
# 516377                     empty  Karma Reservations - WhatsApp Channel
# 516378                     empty  Karma Reservations - WhatsApp Channel
# 516379                     empty  Karma Reservations - WhatsApp Channel
# 516380                     empty   Karma Experience India | Webchat Web
#
#        Lead Regions Lead Status Email Opt Out Opt In Do Not Contact  \
# 0              SEAP    New Lead         false  false          false
# 1         UK/Europe    New Lead          true  false           true
# 2         UK/Europe    New Lead         false   true           true
# 3         UK/Europe    New Lead          true  false           true
# 4         UK/Europe    New Lead         false   true          false
# ...             ...         ...           ...    ...            ...
# 516376    UK/Europe       empty         false   true          false
# 516377         SEAP       empty         false  false          false
# 516378         SEAP       empty         false  false          false
# 516379         SEAP       empty         false  false          false
# 516380        empty       empty         false   true          false
#
#        Do Not Mail
# 0            false
# 1             true
# 2             true
# 3             true
# 4            false
# ...            ...
# 516376       false
# 516377       false
# 516378       false
# 516379       false
# 516380       false
#
# [516381 rows x 34 columns]

# %%
path = r'C:\Users\fajar.fatoni\Documents\Python\Data\Debounce\mailchimp\bounced-mailchimp.xlsx'
df_email = pd.read_excel(path, dtype='string', sheet_name='Sheet1')
df_email
# Out:
#                                              Email error  \
# 0      email address has been hard bounced from this ...
# 1      email address has been hard bounced from this ...
# 2      email address has been hard bounced from this ...
# 3      email address has been hard bounced from this ...
# 4      email address has been hard bounced from this ...
# ...                                                  ...
# 10563  email address has been hard bounced from this ...
# 10564  email address has been hard bounced from this ...
# 10565  email address has been hard bounced from this ...
# 10566  email address has been hard bounced from this ...
# 10567  email address has been hard bounced from this ...
#
#                                  Email
# 0      corrinatraceyrundle@hotmail.com
# 1                anil.mortch@gmail.com
# 2           ghmimilsanir2303@gmail.com
# 3               thaenutweety@gmail.com
# 4                   rahiaa06@gmail.com
# ...                                ...
# 10563          sonnyk1@optusnet.com.au
# 10564         aayracreations@gmail.com
# 10565             ssumal@thegoring.com
# 10566                  sporty63@web.de
# 10567           angiebrooke@live.co.uk
#
# [10568 rows x 2 columns]

# %%
df_email
# Out:
#                                              Email error  \
# 0      email address has been hard bounced from this ...
# 1      email address has been hard bounced from this ...
# 2      email address has been hard bounced from this ...
# 3      email address has been hard bounced from this ...
# 4      email address has been hard bounced from this ...
# ...                                                  ...
# 10563  email address has been hard bounced from this ...
# 10564  email address has been hard bounced from this ...
# 10565  email address has been hard bounced from this ...
# 10566  email address has been hard bounced from this ...
# 10567  email address has been hard bounced from this ...
#
#                                  Email
# 0      corrinatraceyrundle@hotmail.com
# 1                anil.mortch@gmail.com
# 2           ghmimilsanir2303@gmail.com
# 3               thaenutweety@gmail.com
# 4                   rahiaa06@gmail.com
# ...                                ...
# 10563          sonnyk1@optusnet.com.au
# 10564         aayracreations@gmail.com
# 10565             ssumal@thegoring.com
# 10566                  sporty63@web.de
# 10567           angiebrooke@live.co.uk
#
# [10568 rows x 2 columns]

# %%
# data phone, mobile dam email member yang ada di master data (wash member)
zoho_df['Email'] = m.lowercase(zoho_df, 'Email')
m.clean_space(zoho_df, 'Email')

df_email['Email'] = m.lowercase(df_email, 'Email')
m.clean_space(df_email, 'Email')
# Out:
# c:\Users\fajar.fatoni\Documents\Python\Task Offline\zoho_data_app\clean_data\..\main_module.py:127: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[df_columns].replace(' ','', regex=True, inplace=True)
# 0        corrinatraceyrundle@hotmail.com
# 1                  anil.mortch@gmail.com
# 2             ghmimilsanir2303@gmail.com
# 3                 thaenutweety@gmail.com
# 4                     rahiaa06@gmail.com
#                       ...
# 10563            sonnyk1@optusnet.com.au
# 10564           aayracreations@gmail.com
# 10565               ssumal@thegoring.com
# 10566                    sporty63@web.de
# 10567             angiebrooke@live.co.uk
# Name: Email, Length: 10568, dtype: string

# %%
# data phone, mobile dam email member yang ada di master data 
count_deleted_email = zoho_df.loc[

    (zoho_df['Email'].isin(df_email['Email']))

].shape[0]

# data phone, mobile dam email member yang ada di master data 
deleted_email = zoho_df.loc[

    (zoho_df['Email'].isin(df_email['Email']))
    
].copy()

# %%
count_email_only = deleted_email.loc[(deleted_email['Email'] != 'empty') & ((deleted_email['Phone'] == 'empty') & (deleted_email['Mobile'] == 'empty'))].shape[0]
count_phone_only = deleted_email.loc[(deleted_email['Email'] == 'empty') & ((deleted_email['Phone'] != 'empty') | (deleted_email['Mobile'] != 'empty'))].shape[0]
count_email_and_phone = deleted_email.loc[(deleted_email['Email'] != 'empty') & ((deleted_email['Phone'] != 'empty') | (deleted_email['Mobile'] != 'empty'))].shape[0]

count_blank = deleted_email.loc[(deleted_email['Email'] =='empty') & (deleted_email['Phone']=='empty') & (deleted_email['Mobile']=='empty')].shape[0]

# deleted_email.loc[(deleted_email['Email'] =='empty') & (deleted_email['Phone']=='empty') & (deleted_email['Mobile']=='empty')].to_excel(r'C:\Users\fajar.fatoni\Documents\Python\Data\blank_data.xlsx', index=False)

deleted_email.loc[(deleted_email['Email'] != 'empty') & ((deleted_email['Phone'] == 'empty') & (deleted_email['Mobile'] == 'empty')), 'Contact Type'] = 'Email Only'
deleted_email.loc[(deleted_email['Email'] == 'empty') & ((deleted_email['Phone'] != 'empty') | (deleted_email['Mobile'] != 'empty')), 'Contact Type'] = 'Phone Only'
deleted_email.loc[(deleted_email['Email'] != 'empty') & ((deleted_email['Phone'] != 'empty') | (deleted_email['Mobile'] != 'empty')), 'Contact Type'] = 'Email and Phone'

deleted_email.drop(deleted_email.loc[(deleted_email['Email'] =='empty') & (deleted_email['Phone']=='empty') & (deleted_email['Mobile']=='empty')].index, inplace=True)
deleted_email.reset_index(drop=True, inplace=True)

count_after_wash_blank = deleted_email.shape[0]

# %%
print("Jumlah Data Yang Akan di Delete : "+str(count_deleted_email))
print("Jumlah Phone Email Blank (Setelah phone yang tidak valid dihapus) : "+str(count_blank))
print("Jumlah Setelah Wash Phone Email Blank : "+str(count_after_wash_blank))
print("==========================================================")
print("Contact Type")
print("==========================================================")
print("Jumlah Email Only : "+str(count_email_only))
print("Jumlah Phone Only : "+str(count_phone_only))
print("Jumlah Email dan Phone : "+str(count_email_and_phone))
# Out:
# Jumlah Data Yang Akan di Delete : 7841
# Jumlah Phone Email Blank (Setelah phone yang tidak valid dihapus) : 0
# Jumlah Setelah Wash Phone Email Blank : 7841
# ==========================================================
# Contact Type
# ==========================================================
# Jumlah Email Only : 1735
# Jumlah Phone Only : 0
# Jumlah Email dan Phone : 6106

# %%
deleted_email.replace('empty', '', inplace=True)

# %%
deleted_email
# Out:
#                      Record Id        Created Time Created Date  \
# 0     zcrm_3584690000000456187 2019-01-09 11:10:49
# 1     zcrm_3584690000000456262 2019-01-09 11:10:49
# 2     zcrm_3584690000000456502 2019-01-09 11:10:52
# 3     zcrm_3584690000000456560 2019-01-09 11:10:52
# 4     zcrm_3584690000000456614 2019-01-09 11:10:52
# ...                        ...                 ...          ...
# 7836  zcrm_3584690000565265149 2025-07-21 12:14:22
# 7837  zcrm_3584690000565268100 2025-07-21 12:13:57
# 7838  zcrm_3584690000565273091 2025-07-21 12:15:36
# 7839  zcrm_3584690000565273700 2025-07-21 12:26:57
# 7840  zcrm_3584690000565278165 2025-07-21 12:23:36
#
#                  First Name   Last Name  \
# 0                      Adam      Seaton
# 1                      Alan     Perkins
# 2                     Kevin     Peacock
# 3                    Andras     Szennay
# 4                      Anna     Midgley
# ...                     ...         ...
# 7836                      .       Herry
# 7837                    Lee    Matthews
# 7838                Kerstin  Ottersberg
# 7839  Nandini Yogendrasingh       Patil
# 7840                   Lucy    Burkhead
#
#                                       Email           Phone         Mobile  \
# 0                 adam@seatonpartners.co.uk   +447917540228
# 1              alanperkins0659@talktalk.net   +447775685164  +441794522633
# 2     alison.peacock@mccarthyandstone.co.uk   +441173039298  +447793279815
# 3                  andras.szennay@utazok.hu     36705541792
# 4         anna.midgley@albionchambers.co.uk   +447467223557
# ...                                     ...             ...            ...
# 7836                 bullbullhary@gmail.com  +6285364373766
# 7837          matthewsdesignsr@yahoo.com.au    +61415041168
# 7838            pasrim.ottersberg@gmail.com   +491736037248
# 7839             aakaryogchiktisa@gmail.com   +918788014761
# 7840                i.k.ankhead@outlook.com   +447931582644
#
#        Birthdate Year of Birth  ...              Lead Locations  \
# 0                               ...          Karma St. Martin's
# 1     1959-12-06          1959  ...          Karma St. Martin's
# 2                               ...          Karma St. Martin's
# 3     1982-03-09          1982  ...               Karma Bavaria
# 4                               ...          Karma St. Martin's
# ...          ...           ...  ...                         ...
# 7836  1988-06-06                ...               Karma Kandara
# 7837  1976-09-25                ...               Karma Kandara
# 7838  1962-09-22                ...               Karma Bavaria
# 7839  2007-10-18                ...  Karma Seven Lakes, Udaipur
# 7840  1999-09-02                ...            Karma La Herriza
#
#      Lead Location Description Lead Source Description Lead Regions  \
# 0                                                         UK/Europe
# 1                                                         UK/Europe
# 2                                                         UK/Europe
# 3                                                         UK/Europe
# 4                                                         UK/Europe
# ...                        ...                     ...          ...
# 7836
# 7837
# 7838
# 7839                                         Viewpoint
# 7840                                         Viewpoint
#
#      Lead Status Email Opt Out Opt In Do Not Contact Do Not Mail  \
# 0       New Lead         false   true           true        true
# 1       New Lead         false   true          false       false
# 2       New Lead         false   true           true        true
# 3       New Lead         false   true           true        true
# 4       New Lead         false   true           true        true
# ...          ...           ...    ...            ...         ...
# 7836                     false   true          false       false
# 7837                     false   true          false       false
# 7838                     false   true          false       false
# 7839                     false   true          false       false
# 7840                     false   true          false       false
#
#          Contact Type
# 0     Email and Phone
# 1     Email and Phone
# 2     Email and Phone
# 3     Email and Phone
# 4     Email and Phone
# ...               ...
# 7836  Email and Phone
# 7837  Email and Phone
# 7838  Email and Phone
# 7839  Email and Phone
# 7840  Email and Phone
#
# [7841 rows x 35 columns]

# %%
delete_record_crm = deleted_email.loc[deleted_email['Contact Type'] == 'Email Only'].copy()
update_record_crm = deleted_email.loc[deleted_email['Contact Type'] == 'Email and Phone'].copy()


delete_crm_cols = ['Record Id']
update_crm_cols = ['Record Id','Email']

delete_record_crm = delete_record_crm.reindex(columns=delete_crm_cols)
update_record_crm = update_record_crm.reindex(columns=update_crm_cols)

delete_record_crm['Test'] = True
update_record_crm['Email'] = ''

# %%
# delete_record_crm.to_excel(r'C:\Users\fajar.fatoni\Documents\Python\Data\Debounce\mailchimp\Clean\2024\Sep\24 Sep\delete_record_crm.xlsx', index=False)
# update_record_crm.to_excel(r'C:\Users\fajar.fatoni\Documents\Python\Data\Debounce\mailchimp\Clean\2024\Sep\24 Sep\update_record_crm.xlsx', index=False)
# deleted_email.to_excel(r'C:\Users\fajar.fatoni\Documents\Python\Data\Debounce\mailchimp\Clean\2024\Sep\24 Sep\clean_data_email.xlsx', index=False)

delete_record_crm.to_csv(r'C:\Users\fajar.fatoni\Documents\Python\Data\Debounce\mailchimp\Clean\2024\Sep\24 Sep\delete_record_crm.csv', index=False)
update_record_crm.to_csv(r'C:\Users\fajar.fatoni\Documents\Python\Data\Debounce\mailchimp\Clean\2024\Sep\24 Sep\update_record_crm.csv', index=False)
deleted_email.to_excel(r'C:\Users\fajar.fatoni\Documents\Python\Data\Debounce\mailchimp\Clean\2024\Sep\24 Sep\clean_data_email.xlsx', index=False)
