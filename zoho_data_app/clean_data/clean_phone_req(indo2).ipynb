# %%
import sys
sys.path.append('../')

import main_module as m
import zoho_filter_module as fil
import pandas as pd
import re
import numpy as np

# %load_ext autoreload
# %autoreload 2

dir_path = r'C:\Users\fajar\Documents\Python\Data\Zoho_Backup'
file_name = '\Leads_'

cols = ['Record Id',	
'Created Time',
'Created Date',	
'First Name',	
'Last Name',	
'Email',	
'Phone',	
'Mobile',	
'Birthdate',	
'Year of Birth',
'Street',	
'Street2',	
'City',	
'State',	
'Country',	
'Nationality',
'Booking Status', 
'BookRef',
'Departure Date',	
'Arrival Date',	
'Card Type',	
'Marital Status',	
'Lead Brand',	
'Lead Sub-Brand',	
'Lead Source',	
'Lead Locations',	
'Lead Location Description',	
'Lead Source Description',	
'Lead Regions',
'Lead Status',
'Email Opt Out',	
'Opt In',
'Do Not Contact',
'Do Not Mail',
'Data ONE']

# %%
df = m.load_data_multiple(dir_path, file_name, cols)
count_data_awal = df.shape[0]
df = df.reindex(columns=cols)
df.shape[0]

df['Created Time'] = pd.to_datetime(df['Created Time'], format='%Y-%m-%d %H:%M:%S')
# fungsi errors cource untuk menhindari error jika value data date null atau kosong
# df['Birthdate'] = pd.to_datetime(df['Birthdate'], format='%Y-%m-%d', errors='coerce')
df.dtypes
df
# Out:
#                         Record Id        Created Time Created Date First Name  \
# 0        zcrm_3584690000000404058 2019-01-07 15:08:38   2019-01-06   Nicholas
# 1        zcrm_3584690000000404059 2019-01-07 15:08:38   2019-01-06       Liao
# 2        zcrm_3584690000000404060 2019-01-07 15:08:38   2019-01-06    Vedanta
# 3        zcrm_3584690000000404065 2019-01-07 15:08:38   2019-01-06      Aidai
# 4        zcrm_3584690000000404068 2019-01-07 15:08:38   2019-01-06      Ardra
# ...                           ...                 ...          ...        ...
# 4654820  zcrm_3584690000455020141 2023-07-24 16:42:43         <NA>     Chetas
# 4654821  zcrm_3584690000455020168 2023-07-24 16:43:16         <NA>  Ganapathi
# 4654822  zcrm_3584690000455020203 2023-07-24 16:43:45         <NA>        Luc
# 4654823  zcrm_3584690000455027025 2023-07-24 16:44:37         <NA>  Deepanshu
# 4654824  zcrm_3584690000455030024 2023-07-24 17:06:05         <NA>     Aniket
#
# ...

# %%
df_update = df.loc[
    (df['Phone'].str.contains('^6208|^\+6208', regex=True)) &
    (df['Country'] == 'Indonesia')
    ].copy()

df_update
# Out:
#                         Record Id        Created Time Created Date First Name  \
# 8531     zcrm_3584690000000670682 2019-01-14 07:44:38         <NA>     Shandy
# 13803    zcrm_3584690000000967181 2019-01-23 17:24:22         <NA>    Rosiani
# 15624    zcrm_3584690000001102277 2019-01-28 08:23:01         <NA>       Elly
# 19469    zcrm_3584690000001463451 2019-02-06 19:32:31         <NA>      Teddy
# 56166    zcrm_3584690000005298947 2019-03-28 17:23:15         <NA>   Muhammad
# ...                           ...                 ...          ...        ...
# 4628386  zcrm_3584690000446595001 2023-05-30 11:46:56         <NA>      Jelly
# 4636193  zcrm_3584690000448623085 2023-06-11 21:08:20         <NA>       Dadi
# 4638485  zcrm_3584690000449117059 2023-06-15 13:02:34         <NA>     RIDUAN
# 4638632  zcrm_3584690000449150001 2023-06-14 12:11:13         <NA>   Madalena
# 4639281  zcrm_3584690000449293037 2023-06-15 19:52:21         <NA>      Takha
#
# ...

# %%
df_update.to_excel(r'C:\Users\fajar\Documents\Python\Data\df_indo_update_2_before.xlsx', index=False)
df_update
# Out:
#                         Record Id        Created Time Created Date First Name  \
# 8531     zcrm_3584690000000670682 2019-01-14 07:44:38         <NA>     Shandy
# 13803    zcrm_3584690000000967181 2019-01-23 17:24:22         <NA>    Rosiani
# 15624    zcrm_3584690000001102277 2019-01-28 08:23:01         <NA>       Elly
# 19469    zcrm_3584690000001463451 2019-02-06 19:32:31         <NA>      Teddy
# 56166    zcrm_3584690000005298947 2019-03-28 17:23:15         <NA>   Muhammad
# ...                           ...                 ...          ...        ...
# 4628386  zcrm_3584690000446595001 2023-05-30 11:46:56         <NA>      Jelly
# 4636193  zcrm_3584690000448623085 2023-06-11 21:08:20         <NA>       Dadi
# 4638485  zcrm_3584690000449117059 2023-06-15 13:02:34         <NA>     RIDUAN
# 4638632  zcrm_3584690000449150001 2023-06-14 12:11:13         <NA>   Madalena
# 4639281  zcrm_3584690000449293037 2023-06-15 19:52:21         <NA>      Takha
#
# ...

# %%
df_update['Phone'] = df_update['Phone'].str.replace('^6208|^\+6208', '+628', regex=True)
df_update['Mobile'] = df_update['Mobile'].str.replace('^6208|^\+6208', '+628', regex=True)

# %%
df_update.groupby('Country').count()
# Out:
#            Record Id  Created Time  Created Date  First Name  Last Name  \
# Country
# Indonesia       2036          2036           462        2000       1998
#
#            Email  Phone  Mobile  Birthdate  Year of Birth  ...  \
# Country                                                    ...
# Indonesia   1924   2036    1517        245            867  ...
#
#            Lead Locations  Lead Location Description  Lead Source Description  \
# Country
# Indonesia            1737                          4                     1878
#
#            Lead Regions  Lead Status  Email Opt Out  Opt In  Do Not Contact  \
# Country
# Indonesia          1921          726           2036    2036            2036
#
#            Do Not Mail  Data ONE
# Country
# Indonesia         2036      2036
#
# [1 rows x 34 columns]

# %%
df_update.loc[
    df_update['Phone'].str.contains('-', regex=True)
]
# Out:
# Empty DataFrame
# Columns: [Record Id, Created Time, Created Date, First Name, Last Name, Email, Phone, Mobile, Birthdate, Year of Birth, Street, Street2, City, State, Country, Nationality, Booking Status, BookRef, Departure Date, Arrival Date, Card Type, Marital Status, Lead Brand, Lead Sub-Brand, Lead Source, Lead Locations, Lead Location Description, Lead Source Description, Lead Regions, Lead Status, Email Opt Out, Opt In, Do Not Contact, Do Not Mail, Data ONE]
# Index: []
#
# [0 rows x 35 columns]

# %%
df_update['Phone'].replace(' ','', regex=True, inplace=True)
df_update['Phone'].replace('\-','', regex=True, inplace=True)
df_update['Mobile'].replace(' ','', regex=True, inplace=True)
df_update['Mobile'].replace('\-','', regex=True, inplace=True)

# %%
# df_update.loc[df_update['Record Id'] == 'zcrm_3584690000000457016']
df.loc[df['Record Id'] == 'zcrm_3584690000392449725']
# Out:
#                         Record Id        Created Time Created Date First Name  \
# 4294294  zcrm_3584690000392449725 2022-08-18 15:35:22         <NA>  Evangelia
#
#            Last Name              Email          Phone Mobile Birthdate  \
# 4294294  Spyropoulou  epou100@yahoo.com  4917642009464   <NA>      <NA>
#
#         Year of Birth  ...          Lead Locations Lead Location Description  \
# 4294294          <NA>  ...  Karma Lake of Menteith                      <NA>
#
#         Lead Source Description Lead Regions Lead Status Email Opt Out Opt In  \
# 4294294               Viewpoint    UK/Europe        <NA>          true   true
#
#         Do Not Contact Do Not Mail Data ONE
# 4294294          false       false     true
#
# [1 rows x 35 columns]

# %%
df_update.loc[df_update['Phone'].notna()]
# Out:
#                         Record Id        Created Time Created Date First Name  \
# 8531     zcrm_3584690000000670682 2019-01-14 07:44:38         <NA>     Shandy
# 13803    zcrm_3584690000000967181 2019-01-23 17:24:22         <NA>    Rosiani
# 15624    zcrm_3584690000001102277 2019-01-28 08:23:01         <NA>       Elly
# 19469    zcrm_3584690000001463451 2019-02-06 19:32:31         <NA>      Teddy
# 56166    zcrm_3584690000005298947 2019-03-28 17:23:15         <NA>   Muhammad
# ...                           ...                 ...          ...        ...
# 4628386  zcrm_3584690000446595001 2023-05-30 11:46:56         <NA>      Jelly
# 4636193  zcrm_3584690000448623085 2023-06-11 21:08:20         <NA>       Dadi
# 4638485  zcrm_3584690000449117059 2023-06-15 13:02:34         <NA>     RIDUAN
# 4638632  zcrm_3584690000449150001 2023-06-14 12:11:13         <NA>   Madalena
# 4639281  zcrm_3584690000449293037 2023-06-15 19:52:21         <NA>      Takha
#
# ...

# %%
df_update = df_update.reindex(columns=['Record Id', 'Phone', 'Mobile'])

# %%
df_update.to_excel(r'C:\Users\fajar\Documents\Python\Data\df_indo_update_2__after.xlsx', index=False)
