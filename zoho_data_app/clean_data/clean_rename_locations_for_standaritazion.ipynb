# %%
import sys

import clean_data_modul as fil

sys.path.append('../')

import main_module as m
import pandas as pd
import re
import numpy as np

from datetime import date
from datetime import datetime
from datetime import datetime, timedelta

# %load_ext autoreload
# %autoreload 2

dir_path = r'C:\Users\fajar\Documents\Python\Data\Zoho_Backup'
file_name = '\Leads_'

cols = ['Record Id',	
'Created Time',
'Created Date',	
'First Name',	
'Last Name',	
'Email',	
'Phone',	
'Mobile',	
'Birthdate',	
'Year of Birth',
'Street',	
'Street2',	
'City',	
'State',	
'Country',	
'Nationality',
'Booking Status', 
'BookRef',
'Departure Date',	
'Arrival Date',	
'Card Type',	
'Marital Status',	
'Lead Brand',	
'Lead Sub-Brand',	
'Lead Source',	
'Lead Locations',	
'Lead Location Description',	
'Lead Source Description',	
'Lead Regions',
'Lead Status',
'Email Opt Out',	
'Opt In',
'Do Not Contact',
'Do Not Mail',
'Website']

# %%
df = m.load_data_multiple(dir_path, file_name, cols)
count_data_awal = df.shape[0]
df = df.reindex(columns=cols)
df.shape[0]

df['Created Time'] = pd.to_datetime(df['Created Time'], format='%Y-%m-%d %H:%M:%S')
# fungsi errors cource untuk menhindari error jika value data date null atau kosong
# df['Birthdate'] = pd.to_datetime(df['Birthdate'], format='%Y-%m-%d', errors='coerce')
df.dtypes
df
# Out:
#                         Record Id        Created Time Created Date First Name  \
# 0        zcrm_3584690000000404058 2019-01-07 15:08:38   2019-01-06   Nicholas
# 1        zcrm_3584690000000404059 2019-01-07 15:08:38   2019-01-06       Liao
# 2        zcrm_3584690000000404060 2019-01-07 15:08:38   2019-01-06    Vedanta
# 3        zcrm_3584690000000404065 2019-01-07 15:08:38   2019-01-06      Aidai
# 4        zcrm_3584690000000404068 2019-01-07 15:08:38   2019-01-06      Ardra
# ...                           ...                 ...          ...        ...
# 4705476  zcrm_3584690000472560346 2023-12-11 17:56:13         <NA>         인근
# 4705477  zcrm_3584690000472560347 2023-12-11 17:56:13         <NA>         희연
# 4705478  zcrm_3584690000472560348 2023-12-11 17:56:13         <NA>          김
# 4705479  zcrm_3584690000472561001 2023-12-11 18:19:07         <NA>       Dani
# 4705480  zcrm_3584690000472568001 2023-12-11 18:42:31         <NA>       Dewi
#
# ...

# %%
today = datetime.now() 
date = today.strftime("%d-%m-%Y")

# %%
zoho_filter = fil.get_loc(df)
zoho_df = df.loc[zoho_filter].copy() # menggunakan copy untuk menghindari setting copy warning
zoho_df.reset_index(drop=True, inplace=True)
count_filter_awal = zoho_df.shape[0]

# mengisi kolom <NA> dengan value string 'empty' supaya mudah mengecek data member dan booking dengan isin
zoho_df
# Out:
# Empty DataFrame
# Columns: [Record Id, Created Time, Created Date, First Name, Last Name, Email, Phone, Mobile, Birthdate, Year of Birth, Street, Street2, City, State, Country, Nationality, Booking Status, BookRef, Departure Date, Arrival Date, Card Type, Marital Status, Lead Brand, Lead Sub-Brand, Lead Source, Lead Locations, Lead Location Description, Lead Source Description, Lead Regions, Lead Status, Email Opt Out, Opt In, Do Not Contact, Do Not Mail, Website]
# Index: []
#
# [0 rows x 35 columns]

# %%
zoho_df.groupby('Lead Locations').count()
# Out:
#                                                    Record Id  Created Time  \
# Lead Locations
# Karma Bavaria;Karma Sallford Hall                          1             1
# Karma Bavaria;Karma Sallford Hall;Karma Salfor...          1             1
# Karma Jimbaran;Karma Sallford Hall                         1             1
# Karma Kandara;Karma Sallford Hall                          2             2
# Karma SALFORD HALL;Karma Sallford Hall                     1             1
# Karma Salford Hall;Karma Sallford Hall                     4             4
# Karma Sallford Hall                                      211           211
# Karma Sallford Hall;Karma Bavaria                          2             2
# Karma Sallford Hall;Karma Bavaria;Karma Royal ...          1             1
# Karma Sallford Hall;Karma Lake of Menteith                 1             1
# Karma Sallford Hall;Karma Rottnest;Karma Kanda...          1             1
# ...

# %%
zoho_df.to_excel(r'C:\Users\fajar\Documents\Python\Data\Karma Sallford Hall Before Update '+str(date)+'.xlsx', index=False)

# %%
# zoho_df['Lead Locations'] = 'Karma Grand Residence Maria'
zoho_df['Lead Locations'].replace('^Royal Palms$', 'Karma Royal Palms', inplace=True, regex=True)
zoho_df['Lead Locations'].replace('^Karma Borgo$', 'Karma Borgo di Colleoli', inplace=True, regex=True)
zoho_df['Lead Locations'].replace('Karma Cay Tre', 'Karma Cây Tre', inplace=True, regex=True)
zoho_df['Lead Locations'].replace('Karma Chateau De Samary', 'Karma Chateau de Samary', inplace=True, regex=True)
zoho_df['Lead Locations'].replace('^Royal Boat Lagoon$', 'Karma Royal Boat Lagoon', inplace=True, regex=True)
zoho_df['Lead Locations'].replace('^Royal Jimbaran$', 'Karma Royal Jimbaran', inplace=True, regex=True)
zoho_df['Lead Locations'].replace('^Royal MonteRio$', 'Karma Royal MonteRio', inplace=True, regex=True)
zoho_df['Lead Locations'].replace('^Royal Sanur$', 'Karma Royal Sanur', inplace=True, regex=True)
zoho_df['Lead Locations'].replace('^Sanctum Soho$', 'Karma Sanctum Soho', inplace=True, regex=True)
zoho_df['Lead Locations'].replace('Karma St.Martins|Karma St.Martins', 'Karma St.Martin\'s', inplace=True, regex=True)
zoho_df['Lead Locations'].replace('Karma Le Preverger', 'Le Preverger', inplace=True, regex=True)

zoho_df['Lead Locations'].replace('Karma REEF', 'Karma Reef', inplace=True, regex=True)
zoho_df['Lead Locations'].replace('Karma Residence Normande', 'Karma Résidence Normande', inplace=True, regex=True)
zoho_df['Lead Locations'].replace('^Royal Benaulim$', 'Karma Royal Benaulim', inplace=True, regex=True)
zoho_df['Lead Locations'].replace('^Royal Haathi Mahal$', 'Karma Royal Haathi Mahal', inplace=True, regex=True)
zoho_df['Lead Locations'].replace('^Golden Camp$|Karma Golden Camp, Jaisalmer', 'Karma Golden Camp', inplace=True, regex=True)
zoho_df['Lead Locations'].replace('Karma Haveli, Jaipur', 'Karma Haveli', inplace=True, regex=True)
zoho_df['Lead Locations'].replace('Karma Sitabani, Corbett', 'Karma Sitabani', inplace=True, regex=True)
zoho_df['Lead Locations'].replace('Karma Chakra, Kerala', 'Karma Chakra', inplace=True, regex=True)
zoho_df['Lead Locations'].replace('Karma Munnar, Kerala', 'Karma Munnar', inplace=True, regex=True)
zoho_df['Lead Locations'].replace('Karma Seven Lakes, Udaipur', 'Karma Seven Lakes', inplace=True, regex=True)
zoho_df['Lead Locations'].replace('Karma Utopia, Manali', 'Karma Utopia', inplace=True, regex=True)
zoho_df['Lead Locations'].replace('^Royal Candidasa$', 'Karma Royal Candidasa', inplace=True, regex=True)
zoho_df['Lead Locations'].replace('Karma Sallford Hall', 'Karma Salford Hall', inplace=True, regex=True)

final_df = zoho_df.copy()
final_df
# Out:
#                     Record Id        Created Time Created Date First Name  \
# 0    zcrm_3584690000000465811 2019-01-09 11:11:47         <NA>   Beverley
# 1    zcrm_3584690000000468608 2019-01-09 11:12:04         <NA>      Robin
# 2    zcrm_3584690000005937559 2019-04-02 02:14:05   2015-02-28      Peter
# 3    zcrm_3584690000006075885 2019-04-02 02:27:41   2017-01-18     Steven
# 4    zcrm_3584690000129724583 2019-10-09 22:04:22         <NA>      Janet
# ..                        ...                 ...          ...        ...
# 236  zcrm_3584690000341321483 2022-01-24 15:50:17         <NA>      Mandy
# 237  zcrm_3584690000341323160 2022-01-24 15:25:26         <NA>   Jonathan
# 238  zcrm_3584690000341325033 2022-01-24 15:25:34         <NA>    Stephen
# 239  zcrm_3584690000341342055 2022-01-24 15:34:35         <NA>    Clemens
# 240  zcrm_3584690000341342073 2022-01-24 15:34:51         <NA>    Richard
#
#          Last Name                      Email          Phone Mobile Birthdate  \
# ...

# %%
final_df[['Record Id', 'Lead Locations']].to_csv(r'C:\Users\fajar\Documents\Python\Data\Karma Sallford Hall After Update '+str(date)+'.csv', index=False)
