# %%
import sys

sys.path.append('../../')

import main_module as m
import bounce_clean_module as bc
import pandas as pd
import re
import numpy as np
from datetime import date
from datetime import datetime
from datetime import datetime, timedelta

# %load_ext autoreload
# %autoreload 2

dir_path = r'C:\Users\fajar\Documents\Python\Data\Zoho_Backup'
file_name = '\Leads_'
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
path = r'C:\Users\fajar\Documents\Python\Data\Debounce\mailwizz debounce log\Email Debounce Mailwizz Master.xlsx'
zoho_df = pd.read_excel(path, dtype='string', sheet_name='mw_bounce_log')

zoho_df.reset_index(drop=True, inplace=True)
count_filter_awal = zoho_df.shape[0]

# mengisi kolom <NA> dengan value string 'empty' supaya mudah mengecek data member dan booking dengan isin
zoho_df.fillna('empty', inplace=True)
zoho_df
# Out:
#         log_id                                   email  \
# 0          633         julia@williamsgraphicdesign.com
# 1          634                      h@gregorynpd.co.uk
# 2          635                   pr3temp@sail2sail.com
# 3          636                      sholway@holway.com
# 4          637                    bigal@waney.plus.com
# ...        ...                                     ...
# 309063  445346  yakubov.sherzod.tadjibaevich@gmail.com
# 309064  445347                    tajinder.gill@osm.no
# 309065  445348                               lr@lo.com
# 309066  445349                  tomeisenloeffel@web.de
# 309067  445350                   ian.cambell@adyen.com
#
#                                                   message bounce_type  \
# 0        smtp; 550-Mailcore(2503): Your email was dete...    internal
# 1        smtp; 550-Mailcore(2503): Your email was dete...    internal
# 2                         smtp; 552 Spam Message Rejected    internal
# 3        smtp; 550 5.7.1 11HF8mvC030930 This message h...    internal
# 4                         smtp; 552 Spam Message Rejected    internal
# ...                                                   ...         ...
# 309063   smtp; 452-4.2.2 The recipient's inbox is out ...        soft
# 309064   smtp;550 5.4.316 Message expired, connection ...    internal
# 309065                                    Internal Bounce    internal
# 309066                                    Internal Bounce    internal
# 309067   smtp; 450 4.1.1 <ian.cambell@adyen.com>: Reci...        hard
#
#                                                      name           date_added
# 0       Karma Club | W3Feb21 | Karma Salford Hall - UK...  2021-02-17 12:00:03
# 1       Karma Club | W3Feb21 | Karma Salford Hall - UK...  2021-02-17 12:30:03
# 2       Karma Club | W3Feb21 | Karma Salford Hall - UK...  2021-02-17 14:20:04
# 3       Karma Club | W3Feb21 | Karma Salford Hall - UK...  2021-02-17 15:10:03
# 4       Karma Club | W3Feb21 | Karma Salford Hall - UK...  2021-02-17 16:20:03
# ...                                                   ...                  ...
# 309063              14_Karma_Beach_VIP_Programme_2023_NO3  2023-12-27 11:00:05
# 309064               8_Karma_Beach_VIP_Programme_2023_NO3  2023-12-27 18:40:03
# 309065           6_Karma_Resorts_Past_Guests_Promote_2024  2023-12-27 20:20:03
# 309066           6_Karma_Resorts_Past_Guests_Promote_2024  2023-12-28 10:10:03
# 309067           6_Karma_Resorts_Past_Guests_Promote_2024  2023-12-28 19:10:03
#
# [309068 rows x 6 columns]

# %%
path = r'C:\Users\fajar\Documents\Python\Data\Debounce\mailwizz debounce log\Email Debounce Mailwizz Master.xlsx'
df_email = pd.read_excel(path, dtype='string', sheet_name='Delete Email Master')
df_email
# Out:
#                                Email           Unnamed: 1
# 0      strawberryandcheese@yahoo.com                 <NA>
# 1           reyn.agustinus@yahoo.com                 <NA>
# 2                   igun88@yahoo.com                 <NA>
# 3       zatria_christian@yahoo.co.id                 <NA>
# 4               yatch_dpon@yahoo.com                 <NA>
# ...                              ...                  ...
# 16999            timdun4@yahoo.co.uk                 <NA>
# 17000    hashleyboylan17@hotmail.com                 <NA>
# 17001   cristopher.evans@hotmail.com                 <NA>
# 17002    claire-musgrave@hotmail.com                 <NA>
# 17003       camilladuclos@hotmail.fr  2023-02-01 00:00:00
#
# [17004 rows x 2 columns]

# %%
# data phone, mobile dam email member yang ada di master data (wash member)
zoho_df['email'] = m.lowercase(zoho_df, 'email')
m.clean_space(zoho_df, 'email')

df_email['Email'] = m.lowercase(df_email, 'Email')
m.clean_space(df_email, 'Email')
# Out:
# 0        strawberryandcheese@yahoo.com
# 1             reyn.agustinus@yahoo.com
# 2                     igun88@yahoo.com
# 3         zatria_christian@yahoo.co.id
# 4                 yatch_dpon@yahoo.com
#                      ...
# 16999              timdun4@yahoo.co.uk
# 17000      hashleyboylan17@hotmail.com
# 17001     cristopher.evans@hotmail.com
# 17002      claire-musgrave@hotmail.com
# 17003         camilladuclos@hotmail.fr
# Name: Email, Length: 17004, dtype: string

# %%
zoho_df["Delete"] = zoho_df.apply(
    lambda x: bc.get_desc(x['message']) ,
      
    axis=1,
)

delete_df = zoho_df.loc[
    zoho_df['Delete']=='Yes'
].copy()

count_delete = delete_df.shape[0]
delete_df
# Out:
#         log_id                         email  \
# 178        849    sf.eletrical@btconnect.com
# 208        993        austenslattery@lrs.com
# 209       1008         nsharma@pageone.co.uk
# 212       1035  john.dalgleish@metglobal.com
# 213       1037  scharton@antrim.ifsgroup.com
# ...        ...                           ...
# 309020  445303                   daas@aap.nl
# 309028  445311       rahayu.hoef@makarim.com
# 309033  445316       bob@spartandirect.co.uk
# 309042  445325      nlbwz5@mail.missouri.edu
# 309045  445328           support@support.com
#
#                                                   message bounce_type  \
# 178      smtp; 550 5.4.1 Recipient address rejected: A...    internal
# 208      smtp; 550 5.4.1 Recipient address rejected: A...    internal
# 209      smtp; 550 5.4.1 Recipient address rejected: A...    internal
# 212      smtp;554 5.4.14 Hop count exceeded - possible...    internal
# 213      smtp; 550 5.4.1 Recipient address rejected: A...    internal
# ...                                                   ...         ...
# 309020   smtp; 550 cuda_nsu 5.4.1 Recipient address re...    internal
# 309028   smtp; 550 5.4.1 Recipient address rejected: A...    internal
# 309033   smtp; 550 5.4.1 Recipient address rejected: A...    internal
# 309042   smtp; 550 5.4.1 Recipient address rejected: A...    internal
# 309045   smtp; 550 5.4.1 Recipient address rejected: A...    internal
#
#                                                      name  \
# 178     Karma Club | W3Feb21 | Karma Salford Hall - UK...
# 208     Karma Club | W3Feb21 | Karma Salford Hall - UK...
# 209     Karma Club | W3Feb21 | Karma Salford Hall - UK...
# 212     Karma Club | W3Feb21 | Karma Salford Hall - UK...
# 213     Karma Club | W3Feb21 | Karma Salford Hall - UK...
# ...                                                   ...
# 309020              13_Karma_Beach_VIP_Programme_2023_NO3
# 309028              14_Karma_Beach_VIP_Programme_2023_NO3
# 309033              14_Karma_Beach_VIP_Programme_2023_NO3
# 309042              14_Karma_Beach_VIP_Programme_2023_NO3
# 309045              14_Karma_Beach_VIP_Programme_2023_NO3
#
#                  date_added Delete
# 178     2021-02-20 00:10:02    Yes
# 208     2021-02-20 04:20:02    Yes
# 209     2021-02-20 05:20:02    Yes
# 212     2021-02-20 06:20:01    Yes
# 213     2021-02-20 06:20:01    Yes
# ...                     ...    ...
# 309020  2023-12-27 05:20:05    Yes
# 309028  2023-12-27 06:10:05    Yes
# 309033  2023-12-27 06:20:05    Yes
# 309042  2023-12-27 06:40:04    Yes
# 309045  2023-12-27 06:50:04    Yes
#
# [38973 rows x 7 columns]

# %%
count_dedup_master_delete_email = delete_df.loc[
    delete_df['email'].isin(df_email['Email'])
].shape[0]

delete_df.loc[
    delete_df['email'].isin(df_email['Email'])
]
# Out:
#         log_id                         email  \
# 178        849    sf.eletrical@btconnect.com
# 208        993        austenslattery@lrs.com
# 209       1008         nsharma@pageone.co.uk
# 212       1035  john.dalgleish@metglobal.com
# 213       1037  scharton@antrim.ifsgroup.com
# ...        ...                           ...
# 309020  445303                   daas@aap.nl
# 309028  445311       rahayu.hoef@makarim.com
# 309033  445316       bob@spartandirect.co.uk
# 309042  445325      nlbwz5@mail.missouri.edu
# 309045  445328           support@support.com
#
#                                                   message bounce_type  \
# 178      smtp; 550 5.4.1 Recipient address rejected: A...    internal
# 208      smtp; 550 5.4.1 Recipient address rejected: A...    internal
# 209      smtp; 550 5.4.1 Recipient address rejected: A...    internal
# 212      smtp;554 5.4.14 Hop count exceeded - possible...    internal
# 213      smtp; 550 5.4.1 Recipient address rejected: A...    internal
# ...                                                   ...         ...
# 309020   smtp; 550 cuda_nsu 5.4.1 Recipient address re...    internal
# 309028   smtp; 550 5.4.1 Recipient address rejected: A...    internal
# 309033   smtp; 550 5.4.1 Recipient address rejected: A...    internal
# 309042   smtp; 550 5.4.1 Recipient address rejected: A...    internal
# 309045   smtp; 550 5.4.1 Recipient address rejected: A...    internal
#
#                                                      name  \
# 178     Karma Club | W3Feb21 | Karma Salford Hall - UK...
# 208     Karma Club | W3Feb21 | Karma Salford Hall - UK...
# 209     Karma Club | W3Feb21 | Karma Salford Hall - UK...
# 212     Karma Club | W3Feb21 | Karma Salford Hall - UK...
# 213     Karma Club | W3Feb21 | Karma Salford Hall - UK...
# ...                                                   ...
# 309020              13_Karma_Beach_VIP_Programme_2023_NO3
# 309028              14_Karma_Beach_VIP_Programme_2023_NO3
# 309033              14_Karma_Beach_VIP_Programme_2023_NO3
# 309042              14_Karma_Beach_VIP_Programme_2023_NO3
# 309045              14_Karma_Beach_VIP_Programme_2023_NO3
#
#                  date_added Delete
# 178     2021-02-20 00:10:02    Yes
# 208     2021-02-20 04:20:02    Yes
# 209     2021-02-20 05:20:02    Yes
# 212     2021-02-20 06:20:01    Yes
# 213     2021-02-20 06:20:01    Yes
# ...                     ...    ...
# 309020  2023-12-27 05:20:05    Yes
# 309028  2023-12-27 06:10:05    Yes
# 309033  2023-12-27 06:20:05    Yes
# 309042  2023-12-27 06:40:04    Yes
# 309045  2023-12-27 06:50:04    Yes
#
# [38973 rows x 7 columns]

# %%
delete_df.drop(delete_df.loc[
    
    delete_df['email'].isin(df_email['Email'])
].index, inplace=True)

delete_df.reset_index(drop=True, inplace=True)

count_after_dedup_master_delete_email = delete_df.shape[0]

delete_df
# Out:
# Empty DataFrame
# Columns: [log_id, email, message, bounce_type, name, date_added, Delete]
# Index: []

# %%
print("==========================================================")
print("Summary Report")
print("==========================================================")
print("Jumlah Data Awal Yang Akan di Delete : "+str(count_delete))
print("Jumlah Wash Dengan Master Delete Email : "+str(count_dedup_master_delete_email))
print("Jumlah Setelah Wash Master Delete Email : "+str(count_after_dedup_master_delete_email))
print("Jumlah Data Akhir : "+str(count_after_dedup_master_delete_email))
# Out:
# ==========================================================
# Summary Report
# ==========================================================
# Jumlah Data Awal Yang Akan di Delete : 38973
# Jumlah Wash Dengan Master Delete Email : 38973
# Jumlah Setelah Wash Master Delete Email : 0
# Jumlah Data Akhir : 0

# %%
# hitung jumlah duplicate

unique_email = delete_df.drop_duplicates(subset=['email']).copy()
unique_email
# Out:
# Empty DataFrame
# Columns: [log_id, email, message, bounce_type, name, date_added, Delete]
# Index: []

# %%
today = datetime.now() 
date = today.strftime("%d-%m-%Y")
path = r'C:\Users\fajar\Documents\Python\Data\Debounce\mailwizz debounce log\All Debounce\2024\Jan\02 Jan\data_ready_to_delete_'+str(date)+'.xlsx'

count_check_delete = delete_df.groupby(['message'])['log_id'].count().reset_index(name='Count Email').sort_values('message', ascending=True).copy()
count_check_delete.to_excel(path, sheet_name='Message Summary', index=False)

# %%
# jika ingin menambahkan sheets baru
with pd.ExcelWriter(path, mode="a", engine="openpyxl") as writer:
    delete_df.to_excel(writer, sheet_name="Delete Data Detail", index=False)
    unique_email['email'].to_excel(writer, sheet_name="Unique Email", index=False)
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Cell In [105], line 2
#       1 # jika ingin menambahkan sheets baru
# ----> 2 with pd.ExcelWriter(path, mode="a", engine="openpyxl") as writer:
#       3     delete_df.to_excel(writer, sheet_name="Delete Data Detail", index=False)
#       4     unique_email['email'].to_excel(writer, sheet_name="Unique Email", index=False)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\io\excel\_openpyxl.py:60, in OpenpyxlWriter.__init__(self, path, engine, date_format, datetime_format, mode, storage_options, if_sheet_exists, engine_kwargs, **kwargs)
#      56 from openpyxl.workbook import Workbook
#      58 engine_kwargs = combine_kwargs(engine_kwargs, kwargs)
# ---> 60 super().__init__(
#      61     path,
#      62     mode=mode,
#      63     storage_options=storage_options,
#      64     if_sheet_exists=if_sheet_exists,
#      65     engine_kwargs=engine_kwargs,
#      66 )
#      68 # ExcelWriter replaced "a" by "r+" to allow us to first read the excel file from
#      69 # the file and later write to it
#      70 if "r+" in self._mode:  # Load from existing workbook
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\io\excel\_base.py:1302, in ExcelWriter.__init__(self, path, engine, date_format, datetime_format, mode, storage_options, if_sheet_exists, engine_kwargs, **kwargs)
#    1298 self._handles = IOHandles(
#    1299     cast(IO[bytes], path), compression={"compression": None}
#    1300 )
#    1301 if not isinstance(path, ExcelWriter):
# -> 1302     self._handles = get_handle(
#    1303         path, mode, storage_options=storage_options, is_text=False
#    1304     )
#    1305 self._cur_sheet = None
#    1307 if date_format is None:
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\io\common.py:866, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     857         handle = open(
#     858             handle,
#     859             ioargs.mode,
#    (...)
#     862             newline="",
#     863         )
#     864     else:
#     865         # Binary mode
# --> 866         handle = open(handle, ioargs.mode)
#     867     handles.append(handle)
#     869 # Convert BytesIO or file objects passed with an encoding
#
# PermissionError: [Errno 13] Permission denied: 'C:\\Users\\fajar\\Documents\\Python\\Data\\Debounce\\mailwizz debounce log\\Email Debounce Mailwizz Master.xlsx'
