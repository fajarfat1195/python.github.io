# %%
import sys
sys.path.append('../')


import main_module as m
import zoho_filter_module as fil
import pandas as pd
import re
import numpy as np

# %load_ext autoreload
# %autoreload 2

dir_path = r'C:\Users\fajar\Documents\Python\Data\Zoho_Backup'
file_name = '\Leads_'

cols = ['Record Id',	
'Created Time',
'Created Date',	
'First Name',	
'Last Name',	
'Email',	
'Phone',	
'Mobile',	
'Birthdate',	
'Year of Birth',
'Street',	
'Street2',	
'City',	
'State',	
'Country',	
'Nationality',
'Booking Status', 
'BookRef',
'Departure Date',	
'Arrival Date',	
'Card Type',	
'Marital Status',	
'Lead Brand',	
'Lead Sub-Brand',	
'Lead Source',	
'Lead Locations',	
'Lead Source Description',	
'Lead Regions',
'Lead Status',
'Email Opt Out',	
'Opt In',
'Do Not Contact',
'Do Not Mail']

# %%
df = m.load_data_multiple(dir_path, file_name, cols)
count_data_awal = df.shape[0]
df = df.reindex(columns=cols)
df.shape[0]

df['Created Time'] = pd.to_datetime(df['Created Time'], format='%Y-%m-%d %H:%M:%S')
df['Arrival Date'] = pd.to_datetime(df['Arrival Date'], format='%Y-%m-%d')
df['Departure Date'] = pd.to_datetime(df['Departure Date'], format='%Y-%m-%d')
# fungsi errors cource untuk menhindari error jika value data date null atau kosong
# df['Birthdate'] = pd.to_datetime(df['Birthdate'], format='%Y-%m-%d', errors='coerce')
df.dtypes
df
# Out:
#                         Record Id        Created Time Created Date  \
# 0        zcrm_3584690000000404058 2019-01-07 15:08:38   2019-01-06
# 1        zcrm_3584690000000404059 2019-01-07 15:08:38   2019-01-06
# 2        zcrm_3584690000000404060 2019-01-07 15:08:38   2019-01-06
# 3        zcrm_3584690000000404065 2019-01-07 15:08:38   2019-01-06
# 4        zcrm_3584690000000404068 2019-01-07 15:08:38   2019-01-06
# ...                           ...                 ...          ...
# 1890009  zcrm_3584690000481642001 2024-01-29 18:18:26         <NA>
# 1890010  zcrm_3584690000481646001 2024-01-29 18:23:00         <NA>
# 1890011  zcrm_3584690000481646030 2024-01-29 18:43:30         <NA>
# 1890012  zcrm_3584690000481647001 2024-01-29 18:26:22         <NA>
# 1890013  zcrm_3584690000481648001 2024-01-29 18:34:24         <NA>
#
#              First Name  Last Name                       Email  \
# 0              Nicholas       Wood  1230woodnicholas@gmail.com
# 1                  Liao       Yuan            158066546@qq.com
# 2               Vedanta   Abhiyoga  abhiyoga.vedanta@gmail.com
# 3                 Aidai  Atakanova      aidai.nurbek@gmail.com
# 4                 Ardra      Ardra  aliefardraqariru@gmail.com
# ...                 ...        ...                         ...
# 1890009        Narendra        Das          ndas3011@gmail.com
# 1890010        Narendra        Das          ndas3011@gmail.com
# 1890011            John      Milad      johnemilad@hotmail.com
# 1890012  Dimpal Rathore      Dewal         rdimpal95@gmail.com
# 1890013            John      Milad      johnemilad@hotmail.com
#
#                   Phone          Mobile   Birthdate Year of Birth  ...  \
# 0          +61438600845            <NA>        <NA>          <NA>  ...
# 1         8618718399923            <NA>        <NA>          <NA>  ...
# 2        +6282146524550            <NA>  2000-07-05          2000  ...
# 3          996779641590            <NA>  1997-02-05          1997  ...
# 4        +6282139300818  +6282139300818  2005-01-20          2005  ...
# ...                 ...             ...         ...           ...  ...
# 1890009    +19324412000            <NA>        <NA>          <NA>  ...
# 1890010   +919324412000            <NA>        <NA>          <NA>  ...
# 1890011   +447920583445            <NA>        <NA>          <NA>  ...
# 1890012   +917021362505            <NA>        <NA>          <NA>  ...
# 1890013   +447920583445            <NA>  1972-07-05          <NA>  ...
#
#          Lead Sub-Brand  Lead Source     Lead Locations  \
# 0         Other Bali DB         Wifi               <NA>
# 1         Other Bali DB         Wifi               <NA>
# 2         Other Bali DB         Wifi               <NA>
# 3         Other Bali DB         Wifi               <NA>
# 4         Other Bali DB         Wifi            Mall 21
# ...                 ...          ...                ...
# 1890009           Other      Webchat               <NA>
# 1890010           Other      Webchat               <NA>
# 1890011           Other  Web Enquiry               <NA>
# 1890012           Other  Web Enquiry  Karma Golden Camp
# 1890013  House Of Karma          Web               <NA>
#
#                       Lead Source Description Lead Regions Lead Status  \
# 0                                 Purple Wifi         SEAP    New Lead
# 1                                 Purple Wifi        Other    New Lead
# 2                                 Purple Wifi         SEAP    New Lead
# 3                                 Purple Wifi    UK/Europe    New Lead
# 4                                 Purple Wifi         SEAP    New Lead
# ...                                       ...          ...         ...
# 1890009  Karma Experience India | Webchat Web        India        <NA>
# 1890010  Karma Experience India | Webchat Web        India        <NA>
# 1890011                    Karma Club Enquiry    UK/Europe        <NA>
# 1890012                       Form Contact Us        India        <NA>
# 1890013              Karma Reciprocal Members    UK/Europe        <NA>
#
#         Email Opt Out Opt In Do Not Contact Do Not Mail
# 0               false  false           true       false
# 1               false  false           true       false
# 2               false  false           true       false
# 3               false  false           true       false
# 4               false  false           true       false
# ...               ...    ...            ...         ...
# 1890009         false   true          false       false
# 1890010         false   true          false       false
# 1890011         false   true          false       false
# 1890012         false   true          false       false
# 1890013         false   true          false       false
#
# [1890014 rows x 33 columns]

# %%
new_df = df.groupby(['Lead Brand', 'Lead Sub-Brand', 'Lead Source'])['Record Id'].count().reset_index(name='Count').copy()
new_df
# Out:
#               Lead Brand       Lead Sub-Brand  \
# 0             Karma Club                Other
# 1             Karma Club                Other
# 2          Karma Club 21           Karma Club
# 3          Karma Club 21           Karma Club
# 4          Karma Club 21           Karma Club
# ..                   ...                  ...
# 179  Timeshare Marketing       Other India DB
# 180  Timeshare Marketing   RPS Bali 2  Ad Set
# 181  Timeshare Marketing  RPS Vietnam  Ad Set
# 182  Timeshare Marketing  Test House Of Karma
# 183  Timeshare Marketing          Yuk Tamasya
#
#                              Lead Source  Count
# 0                            Competition   1664
# 1                            Web Enquiry     63
# 2               Associate Member Upgrade     30
# 3    Christmas Quiz - Competition Winner      1
# 4                            Competition      1
# ..                                   ...    ...
# 179                     KE2 (Guest Exit)   6685
# 180                         Facebook Ads      2
# 181                         Facebook Ads      5
# 182                                  Web     35
# 183                          Web Enquiry   2661
#
# [184 rows x 4 columns]

# %%
new_df.to_excel(r'C:\Users\fajar\Documents\Python\Data\Zoho CRM\Summary\summary.xlsx', index=False)
