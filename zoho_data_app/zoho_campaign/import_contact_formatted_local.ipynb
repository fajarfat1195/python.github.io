# %%
import pandas as pd
import re
import openpyxl

import sys
sys.path.append('../')

import main_module as m
# Out:
# c:\Users\fajar\Documents\Python\Task Offline\zoho_data_app\zoho_campaign\..\main_module.py:114: SyntaxWarning: invalid escape sequence '\s'
#   df[df_columns] = df[df_columns].replace('\s|\`|\^|\&|\<|\>|\(|\)|\?','', regex=True)
# c:\Users\fajar\Documents\Python\Task Offline\zoho_data_app\zoho_campaign\..\main_module.py:147: SyntaxWarning: invalid escape sequence '\.'
#   filter_karma = 'johnspence88@hotmail\.com|baligetaway|rottnestlodge\.com\.au|hotel\.discount|balirewardscard\.com|conceptvenues\.com|discoverkarma\.com|discoveryourkarma\.com|geales\.com|haathimahal\.com|'
# c:\Users\fajar\Documents\Python\Task Offline\zoho_data_app\zoho_campaign\..\main_module.py:148: SyntaxWarning: invalid escape sequence '\.'
#   filter_karma += 'adimahkota\.com|baligetaway\.co\.id|baligetaway\.com\.au|catkingproductions\.com|complementarystay-karmaexperience\.com|confirmation-karmaexperience\.com|tiketmurahbali\.com|karmasanctumsoho\.co|'
# c:\Users\fajar\Documents\Python\Task Offline\zoho_data_app\zoho_campaign\..\main_module.py:149: SyntaxWarning: invalid escape sequence '\.'
#   filter_karma += 'experiencekarmaclub\.com|karmabavaria\.com|karmabeach\.com|karmaclub\.com|karmadevelopments\.com|karmaestates\.com|karmaexperience\.co\.uk|karmaexperience\.com|karmaexperience\.in|'
# c:\Users\fajar\Documents\Python\Task Offline\zoho_data_app\zoho_campaign\..\main_module.py:150: SyntaxWarning: invalid escape sequence '\.'
#   filter_karma += 'karmagroup\.com|karmajimbaran\.com|karmakandara\.com|karmaminoan\.com|karmanormandy\.com|karmapelikanos\.com|karmareef\.com|karmaresorts\.com|karmaroyalexperience\.co\.uk|karmaroyalexperience\.com|'
# c:\Users\fajar\Documents\Python\Task Offline\zoho_data_app\zoho_campaign\..\main_module.py:151: SyntaxWarning: invalid escape sequence '\.'
#   filter_karma += 'karmaroyalgroup\.com|karmaroyalvacations\.com|karmasalak\.com|karmasalfordhall\.com|karmastmartins\.com|karmgroup\.com|krresidences\.com|lepreverger\.com|odysseypremier\.com|rci\.com|thebaligetaway\.com'
# c:\Users\fajar\Documents\Python\Task Offline\zoho_data_app\zoho_campaign\..\main_module.py:152: SyntaxWarning: invalid escape sequence '\.'
#   filter_karma += 'karmarottnest\.com\.au|karmasanctumonthegreen\.com|karmasanctumclub\.com|balifreestay\.com|karma25\.com|karmarottnest\.com\.au|karmasanctumsoho\.com|karmaroyalpromotions\.com|'
# c:\Users\fajar\Documents\Python\Task Offline\zoho_data_app\zoho_campaign\..\main_module.py:153: SyntaxWarning: invalid escape sequence '\.'
#   filter_karma += 'justclickbali\.com|karmaapsara\.com|karmabahamas\.com|karmaborgodicolleoli\.com|karmacamino\.com|karmaclub\.community|karmaclubhouse\.club|karmaclubhouse\.com|karma-concierge|karmaconcierge|'
# c:\Users\fajar\Documents\Python\Task Offline\zoho_data_app\zoho_campaign\..\main_module.py:154: SyntaxWarning: invalid escape sequence '\.'
#   filter_karma += 'karmaconstellation\.com|karmadestinations\.com|karmaexperiences\.com|karmaexperiences\.com|karmagroupreviews\.com|karmakasa|karmalaherizza|karmamargaretriver\.com|karmamayura\.com|'
# c:\Users\fajar\Documents\Python\Task Offline\zoho_data_app\zoho_campaign\..\main_module.py:155: SyntaxWarning: invalid escape sequence '\.'
#   filter_karma += 'karmaminoan\.com|karmamykonos\.com|karmapassport\.com|karmaprivilege\.com|karmaprivileges\.com|karmaresortdestinations\.com|karmarestaurants\.com|karmaroyalbellavista\.com|karmaroyalboatlagoon\.com|'
# c:\Users\fajar\Documents\Python\Task Offline\zoho_data_app\zoho_campaign\..\main_module.py:156: SyntaxWarning: invalid escape sequence '\.'
#   filter_karma += 'karmaroyalresidences\.com|karmasanctum\.com|karmasanctumspa\.com|karmaspa\.com|karmaspas\.com|karmastmartin\.com|karmaubud\.com|karmawinery\.com|krgstorage\.com|mykarmaconcierge\.com|odysseykarma\.com|'
# c:\Users\fajar\Documents\Python\Task Offline\zoho_data_app\zoho_campaign\..\main_module.py:157: SyntaxWarning: invalid escape sequence '\.'
#   filter_karma += 'odysseypremier\.com|royalbalitimeshare\.com|royalperspective\.com|royalresortsasia\.com|royalresortstimeshare\.com|sanctumhotel\.com|sanctumsoho\.com|thebaligetaway\.com|thekarmaclub\.com|'
# c:\Users\fajar\Documents\Python\Task Offline\zoho_data_app\zoho_campaign\..\main_module.py:158: SyntaxWarning: invalid escape sequence '\.'
#   filter_karma += 'thekarmacollection|themoleandbadger\.com|timesharebali\.com|wildheartbarandgrill\.com|wildheartsoho\.com|yuktamasya\.com'
# c:\Users\fajar\Documents\Python\Task Offline\zoho_data_app\zoho_campaign\..\main_module.py:172: SyntaxWarning: invalid escape sequence '\.'
#   filter_karma = 'johnspence88@hotmail\.com|baligetaway|rottnestlodge\.com\.au|hotel\.discount|balirewardscard\.com|conceptvenues\.com|discoverkarma\.com|discoveryourkarma\.com|geales\.com|haathimahal\.com|'
# c:\Users\fajar\Documents\Python\Task Offline\zoho_data_app\zoho_campaign\..\main_module.py:173: SyntaxWarning: invalid escape sequence '\.'
#   filter_karma += 
.']
# c:\Users\fajar\Documents\Python\Task Offline\zoho_data_app\zoho_campaign\..\main_module.py:207: SyntaxWarning: invalid escape sequence '\.'
#   list_correction_hotmail = ['@jotmail\.','@hotmil\.','@hotlamil\.','@h0tmail\.','@hotjail\.','@hotmaio\.']
# c:\Users\fajar\Documents\Python\Task Offline\zoho_data_app\zoho_campaign\..\main_module.py:207: SyntaxWarning: invalid escape sequence '\.'
#   list_correction_hotmail = ['@jotmail\.','@hotmil\.','@hotlamil\.','@h0tmail\.','@hotjail\.','@hotmaio\.']
# c:\Users\fajar\Documents\Python\Task Offline\zoho_data_app\zoho_campaign\..\main_module.py:207: SyntaxWarning: invalid escape sequence '\.'
#   list_correction_hotmail = ['@jotmail\.','@hotmil\.','@hotlamil\.','@h0tmail\.','@hotjail\.','@hotmaio\.']
# c:\Users\fajar\Documents\Python\Task Offline\zoho_data_app\zoho_campaign\..\main_module.py:207: SyntaxWarning: invalid escape sequence '\.'
#   list_correction_hotmail = ['@jotmail\.','@hotmil\.','@hotlamil\.','@h0tmail\.','@hotjail\.','@hotmaio\.']
# c:\Users\fajar\Documents\Python\Task Offline\zoho_data_app\zoho_campaign\..\main_module.py:207: SyntaxWarning: invalid escape sequence '\.'
#   list_correction_hotmail = ['@jotmail\.','@hotmil\.','@hotlamil\.','@h0tmail\.','@hotjail\.','@hotmaio\.']
# c:\Users\fajar\Documents\Python\Task Offline\zoho_data_app\zoho_campaign\..\main_module.py:208: SyntaxWarning: invalid escape sequence '\.'
#   list_correction_hotmail_com = ['@jotmail\.dom', '@hotmail\.com,']
# c:\Users\fajar\Documents\Python\Task Offline\zoho_data_app\zoho_campaign\..\main_module.py:208: SyntaxWarning: invalid escape sequence '\.'
#   list_correction_hotmail_com = ['@jotmail\.dom', '@hotmail\.com,']
# c:\Users\fajar\Documents\Python\Task Offline\zoho_data_app\zoho_campaign\..\main_module.py:209: SyntaxWarning: invalid escape sequence '\.'
#   list_correction_yahoo_com = ['@yahoo\.com(noemailtobesent)']
# c:\Users\fajar\Documents\Python\Task Offline\zoho_data_app\zoho_campaign\..\main_module.py:210: SyntaxWarning: invalid escape sequence '\.'
#   list_correction_yahoo = ['@yahho\.','@yaho\.','@gyahoo\.','@yahoom\.', '@yaoo\.','@yehoo\.','@yahio\.','@rotmail\.','@yshoo\.']
# c:\Users\fajar\Documents\Python\Task Offline\zoho_data_app\zoho_campaign\..\main_module.py:210: SyntaxWarning: invalid escape sequence '\.'
#   list_correction_yahoo = ['@yahho\.','@yaho\.','@gyahoo\.','@yahoom\.', '@yaoo\.','@yehoo\.','@yahio\.','@rotmail\.','@yshoo\.']
# c:\Users\fajar\Documents\Python\Task Offline\zoho_data_app\zoho_campaign\..\main_module.py:210: SyntaxWarning: invalid escape sequence '\.'
#   list_correction_yahoo = ['@yahho\.','@yaho\.','@gyahoo\.','@yahoom\.', '@yaoo\.','@yehoo\.','@yahio\.','@rotmail\.','@yshoo\.']
# c:\Users\fajar\Documents\Python\Task Offline\zoho_data_app\zoho_campaign\..\main_module.py:210: SyntaxWarning: invalid escape sequence '\.'
#   list_correction_yahoo = ['@yahho\.','@yaho\.','@gyahoo\.','@yahoom\.', '@yaoo\.','@yehoo\.','@yahio\.','@rotmail\.','@yshoo\.']
# c:\Users\fajar\Documents\Python\Task Offline\zoho_data_app\zoho_campaign\..\main_module.py:210: SyntaxWarning: invalid escape sequence '\.'
#   list_correction_yahoo = ['@yahho\.','@yaho\.','@gyahoo\.','@yahoom\.', '@yaoo\.','@yehoo\.','@yahio\.','@rotmail\.','@yshoo\.']
# c:\Users\fajar\Documents\Python\Task Offline\zoho_data_app\zoho_campaign\..\main_module.py:210: SyntaxWarning: invalid escape sequence '\.'
#   list_correction_yahoo = ['@yahho\.','@yaho\.','@gyahoo\.','@yahoom\.', '@yaoo\.','@yehoo\.','@yahio\.','@rotmail\.','@yshoo\.']
# c:\Users\fajar\Documents\Python\Task Offline\zoho_data_app\zoho_campaign\..\main_module.py:210: SyntaxWarning: invalid escape sequence '\.'
#   list_correction_yahoo = ['@yahho\.','@yaho\.','@gyahoo\.','@yahoom\.', '@yaoo\.','@yehoo\.','@yahio\.','@rotmail\.','@yshoo\.']
# c:\Users\fajar\Documents\Python\Task Offline\zoho_data_app\zoho_campaign\..\main_module.py:210: SyntaxWarning: invalid escape sequence '\.'
#   list_correction_yahoo = ['@yahho\.','@yaho\.','@gyahoo\.','@yahoom\.', '@yaoo\.','@yehoo\.','@yahio\.','@rotmail\.','@yshoo\.']
# c:\Users\fajar\Documents\Python\Task Offline\zoho_data_app\zoho_campaign\..\main_module.py:210: SyntaxWarning: invalid escape sequence '\.'
#   list_correction_yahoo = ['@yahho\.','@yaho\.','@gyahoo\.','@yahoom\.', '@yaoo\.','@yehoo\.','@yahio\.','@rotmail\.','@yshoo\.']
# c:\Users\fajar\Documents\Python\Task Offline\zoho_data_app\zoho_campaign\..\main_module.py:211: SyntaxWarning: invalid escape sequence '\.'
#   list_correction_yahoo_in = ['@yahoo\.co\.in-pri']
# c:\Users\fajar\Documents\Python\Task Offline\zoho_data_app\zoho_campaign\..\main_module.py:307: SyntaxWarning: invalid escape sequence '\d'
#   df.to_csv(location+'\df_'+file_name+'.csv', index=False)
# c:\Users\fajar\Documents\Python\Task Offline\zoho_data_app\zoho_campaign\..\main_module.py:309: SyntaxWarning: invalid escape sequence '\d'
#   df.to_excel(location+'\df_'+file_name+'.xlsx', index=False, engine='xlsxwriter')
# c:\Users\fajar\Documents\Python\Task Offline\zoho_data_app\zoho_campaign\..\main_module.py:332: SyntaxWarning: invalid escape sequence '\d'
#   new_df[n].to_csv(location+'\df_'+file_name+'_'+str(i)+'.csv', index=False)
# c:\Users\fajar\Documents\Python\Task Offline\zoho_data_app\zoho_campaign\..\main_module.py:334: SyntaxWarning: invalid escape sequence '\d'
#   new_df[n].to_excel(location+'\df_'+file_name+'_'+str(i)+'.xlsx', index=False, engine='xlsxwriter')

# %%
cols = ['First Name', 
    'Last Name',
    'Email', 
    'Phone', 
    'Mobile', 
    'City', 
    'State',
    'Country', 
    'Nationality',
    'Lead Locations', 
    'Booking Status',
    'Lead Source', 
    'BookRef']

# %%
path = r'C:\Users\fajar\Documents\Python\Data\push-pastguest.xlsx'
df_push = pd.read_excel(path, dtype='string', usecols=cols, sheet_name='Sheet0', engine='openpyxl')
df_push.fillna('empty', inplace=True)
count_total_data = df_push.shape[0]
df_push.columns
# Out:
# c:\Users\fajar\Documents\Python\Task Offline\venv12\Lib\site-packages\openpyxl\styles\stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# Index(['First Name', 'Last Name', 'Email', 'Phone', 'Mobile', 'City', 'State',
#        'Country', 'Nationality', 'Lead Source', 'Lead Locations',
#        'Booking Status', 'BookRef'],
#       dtype='object')

# %%
df_push
# Out:
#           First Name Last Name                         Email          Phone  \
# 0           Dyah Ayu    Palupi         upi.dyahayu@gmail.com   +61410190353
# 1               Jodi     Hooke          jodi.hooke@gmail.com   +61402427619
# 2    Bhupender Singh   Khanuja  drbhupenderkhanuja@gmail.com  +919826081008
# 3              Rahul   Digraje       digraje.rahul@gmail.com  +919960300085
# 4             Faheem    Ansari      faheemansari78@gmail.com  +918654905430
# ..               ...       ...                           ...            ...
# 331           Tobias   Persson       tobias@tobiasperson.org   +46705597491
# 332          Divyank       Aru         divyank.aru@gmail.com  +919970802989
# 333          Deborah     Maren           debymaren@gmail.com  +447956112034
# 334             Raja         R     binduchowdary18@gmail.com  +919739979429
# 335         Frederic    Bartel     bantel.frederic@orange.fr   +33786838737
#
#             Mobile              City           State    Country Nationality  \
# 0     +61410190353               QLD               X  Australia  Australian
# 1     +61402427619      Altona North             VIC  Australia  Australian
# 2            empty            Indore  Madhya Pradesh      India      Indian
# 3    +919561946175          KOLHAPUR     MAHARASHTRA      India      Indian
# 4    +918855865295         BANGALORE       KARNATAKA      India      Indian
# ..             ...               ...             ...        ...         ...
# 331          empty                 -               -     Sweden     Swedish
# 332          empty              Pune     Maharashtra      India      Indian
# 333          empty             empty           empty    Nigeria    Nigerian
# 334  +918971508899         BENGALURU       KARNATAKA      India      Indian
# 335          empty  La Petite Pierre           empty     France      French
#
#      Lead Source                           Lead Locations Booking Status  \
# 0    Past Guests  KRR @ Karma Kandara, Mentari Residences    Checked-Out
# 1    Past Guests                            Karma Kandara    Checked-Out
# 2    Past Guests                     Karma Royal Monterio    Checked-Out
# 3    Past Guests                        Karma Royal Palms    Checked-Out
# 4    Past Guests                     Karma Munnar, Kerala    Checked-Out
# ..           ...                                      ...            ...
# 331  Past Guests                           Karma Jimbaran    Checked-Out
# 332  Past Guests                 Karma Royal Haathi Mahal    Checked-Out
# 333  Past Guests                   Karma Lake of Menteith    Checked-Out
# 334  Past Guests                   Karma Sunshine Village    Checked-Out
# 335  Past Guests                            Karma Bavaria    Checked-Out
#
#       BookRef
# 0     2633025
# 1     2691460
# 2     2692850
# 3     2688613
# 4     2690235
# ..        ...
# 331   2723741
# 332   2717248
# 333   2449550
# 334   2713148
# 335  KB046456
#
# [336 rows x 13 columns]

# %%
path = r'C:\Users\fajar\Documents\Python\Data\Debounce\debounce_backup.csv'
df_1 = pd.read_csv(path, dtype='string')

path = r'C:\Users\fajar\Documents\Python\Data\Debounce\debounce_new_temp.csv'
df_2 = pd.read_csv(path, dtype='string')


frames = [df_1, df_2]
df_bounced = pd.concat(frames, ignore_index=True)
df_bounced
# Out:
#                                  EMAIL        RESULT       REASON STATUS CODE  \
# 0                00001111den@gmail.com  Safe to Send  Deliverable           5
# 1        007dhananjaykumbhar@gmail.com  Safe to Send  Deliverable           5
# 2                      0597396@mail.ru  Safe to Send  Deliverable           5
# 3                07deepanshu@gmail.com  Safe to Send  Deliverable           5
# 4                    1078049354@qq.com  Safe to Send  Deliverable           5
# ...                                ...           ...          ...         ...
# 1266206         amanmadaan80@gmail.com  Safe to Send  Deliverable           5
# 1266207             vik.4151@ymail.com  Safe to Send  Deliverable           5
# 1266208       bhattmandar444@gmail.com  Safe to Send  Deliverable           5
# 1266209           ravina2394@gmail.com  Safe to Send  Deliverable           5
# 1266210            dlc_fea@yahoo.co.uk  Safe to Send  Deliverable           5
#
#           ROLE   FREE     DOMAIN    Sheet Name
# 0           No    Yes  gmail.com  All Campaign
# 1           No    Yes  gmail.com  All Campaign
# 2           No    Yes    mail.ru  All Campaign
# 3           No    Yes  gmail.com  All Campaign
# 4           No    Yes     qq.com  All Campaign
# ...        ...    ...        ...           ...
# 1266206  FALSE  FALSE       <NA>          <NA>
# 1266207  FALSE  FALSE       <NA>          <NA>
# 1266208  FALSE  FALSE       <NA>          <NA>
# 1266209  FALSE  FALSE       <NA>          <NA>
# 1266210  FALSE  FALSE       <NA>          <NA>
#
# [1266211 rows x 8 columns]

# %%
df_bounced.drop_duplicates(subset='EMAIL', inplace=True)
df_bounced.reset_index(drop=True, inplace=True)
df_bounced
# Out:
#                                  EMAIL        RESULT       REASON STATUS CODE  \
# 0                00001111den@gmail.com  Safe to Send  Deliverable           5
# 1        007dhananjaykumbhar@gmail.com  Safe to Send  Deliverable           5
# 2                      0597396@mail.ru  Safe to Send  Deliverable           5
# 3                07deepanshu@gmail.com  Safe to Send  Deliverable           5
# 4                    1078049354@qq.com  Safe to Send  Deliverable           5
# ...                                ...           ...          ...         ...
# 1020076         amanmadaan80@gmail.com  Safe to Send  Deliverable           5
# 1020077             vik.4151@ymail.com  Safe to Send  Deliverable           5
# 1020078       bhattmandar444@gmail.com  Safe to Send  Deliverable           5
# 1020079           ravina2394@gmail.com  Safe to Send  Deliverable           5
# 1020080            dlc_fea@yahoo.co.uk  Safe to Send  Deliverable           5
#
#           ROLE   FREE     DOMAIN    Sheet Name
# 0           No    Yes  gmail.com  All Campaign
# 1           No    Yes  gmail.com  All Campaign
# 2           No    Yes    mail.ru  All Campaign
# 3           No    Yes  gmail.com  All Campaign
# 4           No    Yes     qq.com  All Campaign
# ...        ...    ...        ...           ...
# 1020076  FALSE  FALSE       <NA>          <NA>
# 1020077  FALSE  FALSE       <NA>          <NA>
# 1020078  FALSE  FALSE       <NA>          <NA>
# 1020079  FALSE  FALSE       <NA>          <NA>
# 1020080  FALSE  FALSE       <NA>          <NA>
#
# [1020081 rows x 8 columns]

# %%
df_bounced.groupby('RESULT').count()
# Out:
#                EMAIL  REASON  STATUS CODE    ROLE    FREE  DOMAIN  Sheet Name
# RESULT
# Invalid       110158  110158       109865  108065  107501  105061      110158
# Risky          54022   54022        53677   48120   48106   47313       54022
# Safe to Send  807022  807022       807022  788244  787839  760827      806500
# Unknown        48868   48868        48868   45567   45562   44919       48868

# %%
df_push.loc[df_push['Email'].isin(df_bounced['EMAIL'])]
# Out:
#                  First Name Last Name                             Email  \
# 0                  Dyah Ayu    Palupi             upi.dyahayu@gmail.com
# 107  Irving, Lance & Angela         -  lance_angela_irving@yahoo.com.au
# 131                  Gaurav     Patni             gauravpatni@yahoo.com
# 289                  Hannah    Oliver         lil-hannaho@hotmail.co.uk
#
#              Phone        Mobile   City  State         Country Nationality  \
# 0     +61410190353  +61410190353    QLD      X       Australia  Australian
# 107     +490501970         empty  empty  empty           empty       empty
# 131   +61415758346         empty  empty  empty       Australia  Australian
# 289  +447576627605         empty  empty  empty  United Kingdom     British
#
#      Lead Source                           Lead Locations Booking Status  \
# 0    Past Guests  KRR @ Karma Kandara, Mentari Residences    Checked-Out
# 107  Past Guests        Wyndham -  Manoir des Deux Amants    Checked-Out
# 131  Past Guests                  Karma Borgo Di Colleoli    Checked-Out
# 289  Past Guests                       Karma Salford Hall    Checked-Out
#
#      BookRef
# 0    2633025
# 107  2681219
# 131  2399159
# 289  2541910

# %%
count_empty_contact = df_push.loc[(df_push['Email'] == 'empty') &
            (df_push['Phone'] == 'empty') &
            (df_push['Mobile'] == 'empty')].shape[0]

df_push.drop(df_push.loc[(df_push['Email'] == 'empty') &
            (df_push['Phone'] == 'empty') &
            (df_push['Mobile'] == 'empty')
            ].index, inplace=True)

count_after_wash_empty_contact = df_push.shape[0]

# %%
# df_bounced.loc[df_bounced['EMAIL'] == 'pawan_chhikara2001@yahoo.com']

# %%
joined_df = pd.merge(df_push,
                     df_bounced,
                     left_on ='Email',
                     right_on ='EMAIL',
                     how ='left')
joined_df.fillna('empty', inplace=True)

# %%
joined_df.groupby('RESULT').count()
# Out:
#               First Name  Last Name  Email  Phone  Mobile  City  State  \
# RESULT
# Safe to Send           4          4      4      4       4     4      4
# empty                332        332    332    332     332   332    332
#
#               Country  Nationality  Lead Source  Lead Locations  \
# RESULT
# Safe to Send        4            4            4               4
# empty             332          332          332             332
#
#               Booking Status  BookRef  EMAIL  REASON  STATUS CODE  ROLE  FREE  \
# RESULT
# Safe to Send               4        4      4       4            4     4     4
# empty                    332      332    332     332          332   332   332
#
#               DOMAIN  Sheet Name
# RESULT
# Safe to Send       4           4
# empty            332         332

# %%
joined_list = joined_df.loc[~joined_df['RESULT'].isna()].copy()
joined_list.reset_index(drop=True, inplace=True)

not_exist_list = joined_df.loc[joined_df['RESULT'].isna()].copy()
not_exist_list.reset_index(drop=True, inplace=True)

count_exist_in_bounce = joined_list.shape[0]
count_not_exist_in_bounce = not_exist_list.shape[0]

# %%
safe_to_send = joined_list.loc[~joined_list['RESULT'].str.contains('Invalid|Risky',regex=True)|joined_list['RESULT'].str.contains('empty',regex=True)].copy()
safe_to_send.reset_index(drop=True, inplace=True)
count_safe_to_send = safe_to_send.shape[0]

ex_safe_to_send = joined_list.loc[joined_list['RESULT'] != 'Safe to Send'].copy()
ex_safe_to_send.reset_index(drop=True, inplace=True)
count_ex_safe_to_send = ex_safe_to_send.shape[0]

# %%
print("==========================================================")
print("Summary")
print("==========================================================")
print("Jumlah Total Data : "+str(count_total_data))
print("Jumlah Data Contact Empty : "+str(count_empty_contact))
print("Jumlah Data Setelah Wash Empty Contact : "+str(count_empty_contact))
print("Jumlah Data Exist di Database Bounce : "+str(count_exist_in_bounce))
print("Jumlah Data Tidak Exist di Database Bounce : "+str(count_not_exist_in_bounce))
print("==========================================================")
print("Summary Bounced")
print("==========================================================")
print("Jumlah Data Safe to Send : "+str(count_safe_to_send))
print("Jumlah Data not Safe to Send : "+str(count_ex_safe_to_send))
# Out:
# ==========================================================
# Summary
# ==========================================================
# Jumlah Total Data : 336
# Jumlah Data Contact Empty : 0
# Jumlah Data Setelah Wash Empty Contact : 0
# Jumlah Data Exist di Database Bounce : 336
# Jumlah Data Tidak Exist di Database Bounce : 0
# ==========================================================
# Summary Bounced
# ==========================================================
# Jumlah Data Safe to Send : 336
# Jumlah Data not Safe to Send : 332

# %%
not_exist_list.loc[not_exist_list['Email'] == 'mohdasifaliak2016@gmail.com']
# df_1.loc[df_1['EMAIL'] == 'matthew.w.giles@gmail.com']
# df_1.loc[df_1['EMAIL'] == 'venkjaya@gmail.com']
# joined_df.loc[joined_df['RESULT'] == 'Safe to Send']
# df_bounced.loc[df_bounced['EMAIL'] == ]
# Out:
# Empty DataFrame
# Columns: [First Name, Last Name, Email, Phone, Mobile, City, State, Country, Nationality, Lead Source, Lead Locations, Booking Status, BookRef, EMAIL, RESULT, REASON, STATUS CODE, ROLE, FREE, DOMAIN, Sheet Name]
# Index: []
#
# [0 rows x 21 columns]

# %%
safe_to_send.replace('empty', '', inplace=True)
safe_to_send.reset_index(drop=True, inplace=True)
df_safe = safe_to_send.reindex(columns=cols)
df_safe['City'].replace('-', '',regex=True, inplace=True)
df_safe['State'].replace('-', '',regex=True, inplace=True)
df_safe.rename(columns={'Lead Source':'Lead Sources'}, inplace=True)

df_safe['Tags'] = 'Non Members,Past Guest'
df_safe.loc[df_safe['Lead Locations'].str.contains('kandara', regex=True, flags=re.I),"Tags"]=df_safe['Tags']+',Past Guests - KK'
df_safe.loc[df_safe['Lead Locations'].str.contains('bavaria', regex=True, flags=re.I),"Tags"]=df_safe['Tags']+',Past Guests - KB'
df_safe.loc[df_safe['Lead Locations'].str.contains('menteith', regex=True, flags=re.I),"Tags"]=df_safe['Tags']+',Past Guests - KLOM'


df_safe.to_csv(r'C:\Users\fajar\Documents\Python\Data\push-pastguest-formatted.csv', index=False, encoding='utf-8')

joined_df.replace('empty', '', inplace=True)
joined_df.to_csv(r'C:\Users\fajar\Documents\Python\Data\check-debounce.csv', index=False, encoding='utf-8')
# Out:
# C:\Users\fajar\AppData\Local\Temp\ipykernel_10448\2900155512.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_safe['City'].replace('-', '',regex=True, inplace=True)
# C:\Users\fajar\AppData\Local\Temp\ipykernel_10448\2900155512.py:5: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_safe['State'].replace('-', '',regex=True, inplace=True)

# %%
df_safe[df_safe['Email'] == 'mani.p.mk@gmail.com']
# Out:
# Empty DataFrame
# Columns: [First Name, Last Name, Email, Phone, Mobile, City, State, Country, Nationality, Lead Locations, Booking Status, Lead Sources, BookRef, Tags]
# Index: []

# %%
ex_safe_to_send.replace('empty', '', inplace=True)
ex_safe_to_send.reset_index(drop=True, inplace=True)
df_ex_safe_to_send = ex_safe_to_send.reindex(columns=cols)
df_ex_safe_to_send

df_ex_safe_to_send.to_excel(r'C:\Users\fajar\Documents\Python\Data\not-safe-to-send-debounce.xlsx', index=False)

# %%
not_exist_list.replace('empty', '', inplace=True)
not_exist_list.reset_index(drop=True, inplace=True)
df_not_exist = not_exist_list.reindex(columns=cols)
df_not_exist

df_not_exist.to_excel(r'C:\Users\fajar\Documents\Python\Data\not-exist-debounce.xlsx', index=False)
