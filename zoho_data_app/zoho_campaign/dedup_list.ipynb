# %%
import pandas as pd
import re
import openpyxl


import sys
sys.path.append('../')

import main_module as m

# %%
path = r'C:\Users\fajar\Documents\Python\Data\Zoho_Campaign\push data\check exist\karma-spa-zoho-campaign.csv'
df_campaign = pd.read_csv(path, dtype='string')

# %%
path = r'C:\Users\fajar\Documents\Python\Data\Zoho_Campaign\push data\check exist\karma-spa-zoho-crm.xlsx'
df_crm = pd.read_excel(path, dtype='string', engine='openpyxl', sheet_name='Sheet0')
# Out:
# C:\Users\fajar\AppData\Roaming\Python\Python310\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")

# %%
df_crm.shape[0]
# Out:
# 7527

# %%
df_campaign.columns
# Out:
# Index(['Contact Email', 'Opt_in', 'Confirmed Time',
#        'Agreed to Privacy Policy and Terms', 'Opt-in type'],
#       dtype='object')

# %%
df_campaign
# Out:
#                       Contact Email Opt_in Confirmed Time  \
# 0      000helentmorrow000@gmail.com  false           <NA>
# 1            007shivshivu@gmail.com  false           <NA>
# 2           05simransingh@gmail.com  false           <NA>
# 3                 09ambac@gmail.com  false           <NA>
# 4       09MARKTAYLOR@GOOGLEMAIL.COM  false           <NA>
# ...                             ...    ...            ...
# 13052          zuzarkanch@gmail.com  false           <NA>
# 13053       zvezdakhorola@gmail.com  false           <NA>
# 13054             zvezdakov@list.ru  false           <NA>
# 13055     zx123xz321hm3@hotmail.com  false           <NA>
# 13056     zxleong070827@hotmail.com  false           <NA>
#
#       Agreed to Privacy Policy and Terms Opt-in type
# 0                                  false        None
# 1                                  false        None
# 2                                  false        None
# 3                                  false        None
# ...

# %%
df_crm.fillna('empty', inplace=True)
df_crm
# Out:
#                      Record Id         Created Time         Created Date  \
# 0     zcrm_3584690000370851001  2022-05-27 18:31:00  2022-05-04 00:00:00
# 1     zcrm_3584690000370751169  2022-05-27 14:26:00  2022-05-02 00:00:00
# 2     zcrm_3584690000370734377  2022-05-27 14:58:00  2022-05-04 00:00:00
# 3     zcrm_3584690000370729366  2022-05-27 14:51:00  2022-05-03 00:00:00
# 4     zcrm_3584690000370729343  2022-05-27 14:28:00  2022-05-02 00:00:00
# ...                        ...                  ...                  ...
# 7522  zcrm_3584690000002904071  2019-02-26 21:10:00                empty
# 7523  zcrm_3584690000002904070  2019-02-26 21:10:00                empty
# 7524  zcrm_3584690000002904066  2019-02-26 21:10:00                empty
# 7525  zcrm_3584690000002904065  2019-02-26 21:10:00                empty
# 7526  zcrm_3584690000002904064  2019-02-26 21:10:00                empty
#
#      First Name   Last Name                         Email           Phone  \
# ...

# %%
df_crm['Email'] = m.lowercase(df_crm, 'Email')
m.clean_space(df_crm, 'Email')

df_campaign['Contact Email'] = m.lowercase(df_campaign, 'Contact Email')
m.clean_space(df_campaign, 'Contact Email')

df_crm
# Out:
#                      Record Id         Created Time         Created Date  \
# 0     zcrm_3584690000370851001  2022-05-27 18:31:00  2022-05-04 00:00:00
# 1     zcrm_3584690000370751169  2022-05-27 14:26:00  2022-05-02 00:00:00
# 2     zcrm_3584690000370734377  2022-05-27 14:58:00  2022-05-04 00:00:00
# 3     zcrm_3584690000370729366  2022-05-27 14:51:00  2022-05-03 00:00:00
# 4     zcrm_3584690000370729343  2022-05-27 14:28:00  2022-05-02 00:00:00
# ...                        ...                  ...                  ...
# 7522  zcrm_3584690000002904071  2019-02-26 21:10:00                empty
# 7523  zcrm_3584690000002904070  2019-02-26 21:10:00                empty
# 7524  zcrm_3584690000002904066  2019-02-26 21:10:00                empty
# 7525  zcrm_3584690000002904065  2019-02-26 21:10:00                empty
# 7526  zcrm_3584690000002904064  2019-02-26 21:10:00                empty
#
#      First Name   Last Name                         Email           Phone  \
# ...

# %%
# df_crm.loc[df_crm['Email'].str.contains('Bhanuprasadmodi', flags=re.I, regex=True)]
# df_campaign.loc[df_campaign['Contact Email'].str.contains('Bhanuprasadmodi', flags=re.I, regex=True)]
# Out:
#                   Contact Email Opt_in Confirmed Time  \
# 1499  bhanuprasadmodi@gmail.com  false           <NA>
#
#      Agreed to Privacy Policy and Terms Opt-in type
# 1499                              false        None

# %%
push_df = df_crm.loc[~df_crm['Email'].isin(df_campaign['Contact Email'])].copy()
push_df.reset_index(drop=True, inplace=True)
push_df.replace('empty', '', inplace=True)
push_df
# Out:
#                      Record Id         Created Time         Created Date  \
# 0     zcrm_3584690000370851001  2022-05-27 18:31:00  2022-05-04 00:00:00
# 1     zcrm_3584690000370719235  2022-05-27 14:46:00  2022-05-03 00:00:00
# 2     zcrm_3584690000370702342  2022-05-27 14:50:00  2022-05-03 00:00:00
# 3     zcrm_3584690000370701318  2022-05-27 13:46:00  2022-05-01 00:00:00
# 4     zcrm_3584690000370694343  2022-05-27 14:40:00  2022-05-03 00:00:00
# ...                        ...                  ...                  ...
# 2562  zcrm_3584690000002904071  2019-02-26 21:10:00
# 2563  zcrm_3584690000002904070  2019-02-26 21:10:00
# 2564  zcrm_3584690000002904066  2019-02-26 21:10:00
# 2565  zcrm_3584690000002904065  2019-02-26 21:10:00
# 2566  zcrm_3584690000002904064  2019-02-26 21:10:00
#
#      First Name   Last Name                         Email           Phone  \
# 0          tesa  Evangeline           tesa.evin@gmail.com   +628119333628
# ...

# %%
push_df.to_excel(r'C:\Users\fajar\Documents\Python\Data\Zoho_Campaign\push data\push-karma-spa.xlsx', index=False)
