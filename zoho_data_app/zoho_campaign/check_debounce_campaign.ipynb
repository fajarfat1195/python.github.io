# %%
import pandas as pd
import re
import openpyxl


import sys
sys.path.append('../')

import main_module as m

# %%
cols = ['First Name', 
    'Last Name',
    'Email', 
    'Phone', 
    'Mobile', 
    'City', 
    'Country', 
    'Nationality',
    'Lead Locations', 
    'Booking Status', 
    'BookRef']

# %%
path = r'C:\Users\fajar\Documents\Python\Data\push-pastguest.xlsx'
df_push = pd.read_excel(path, dtype='string', usecols=cols, sheet_name='Sheet0')
df_push.fillna('empty', inplace=True)
df_push.columns
# Out:
# C:\Users\fajar\AppData\Roaming\Python\Python310\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# Index(['First Name', 'Last Name', 'Email', 'Phone', 'Mobile', 'City',
#        'Country', 'Nationality', 'Lead Locations', 'Booking Status',
#        'BookRef'],
#       dtype='object')

# %%
df_push
# Out:
#               First Name   Last Name                        Email  \
# 0                  Niraj  Srivastava     neeraj.sri0107@gmail.com
# 1           Mr. Prasen V       Gupta            sbgbm@hotmail.com
# 2                Praveen     Kumar R  praveenkumar076@outlook.com
# 3               Ngatiman           -        timanteyeng@gmail.com
# 4                 Neeraj       Gupta   sakshichitkara18@gmail.com
# ..                   ...         ...                          ...
# 336               Naveen   Kumar M V      naveenreddy82@gmail.com
# 337  Mr. Rajesh Ramapati      Pandey     rajeshpandey30@gmail.com
# 338               Haroon      Shaikh         hararhshk2@gmail.com
# 339                 Amit     Kaushik      kaushikamit40@gmail.com
# 340              Matthew       Giles    matthew.w.giles@gmail.com
#
#              Phone        Mobile       City         Country Nationality  \
# 0     919550367824  919984874254  HYDERABAD           India      Indian
# ...

# %%
path = r'C:\Users\fajar\Documents\Python\Data\Debounce\debounce_backup.csv'
df_bounced = pd.read_csv(path, dtype='string')
df_bounced
# Out:
#                                  EMAIL        RESULT       REASON STATUS CODE  \
# 0                00001111den@gmail.com  Safe to Send  Deliverable           5
# 1        007dhananjaykumbhar@gmail.com  Safe to Send  Deliverable           5
# 2                      0597396@mail.ru  Safe to Send  Deliverable           5
# 3                07deepanshu@gmail.com  Safe to Send  Deliverable           5
# 4                    1078049354@qq.com  Safe to Send  Deliverable           5
# ...                                ...           ...          ...         ...
# 1223936        z_forbes_92@hotmail.com  Safe to Send  Deliverable           5
# 1223937          z_mingwei@hotmail.com  Safe to Send  Deliverable           5
# 1223938             z_o_ni@hotmail.com  Safe to Send  Deliverable           5
# 1223939                  _argo@mail.ru  Safe to Send  Deliverable           5
# 1223940    _joanne_mckay@hotmail.co.nz  Safe to Send  Deliverable           5
#
# ...

# %%
df_bounced.drop_duplicates(subset='EMAIL', inplace=True)
df_bounced.reset_index(drop=True, inplace=True)
df_bounced
# Out:
#                                 EMAIL        RESULT       REASON STATUS CODE  \
# 0               00001111den@gmail.com  Safe to Send  Deliverable           5
# 1       007dhananjaykumbhar@gmail.com  Safe to Send  Deliverable           5
# 2                     0597396@mail.ru  Safe to Send  Deliverable           5
# 3               07deepanshu@gmail.com  Safe to Send  Deliverable           5
# 4                   1078049354@qq.com  Safe to Send  Deliverable           5
# ...                               ...           ...          ...         ...
# 982853        z_forbes_92@hotmail.com  Safe to Send  Deliverable           5
# 982854          z_mingwei@hotmail.com  Safe to Send  Deliverable           5
# 982855             z_o_ni@hotmail.com  Safe to Send  Deliverable           5
# 982856                  _argo@mail.ru  Safe to Send  Deliverable           5
# 982857    _joanne_mckay@hotmail.co.nz  Safe to Send  Deliverable           5
#
# ...

# %%
df_push['Email'] = m.lowercase(df_push, 'Email')
m.clean_space(df_push, 'Email')

df_bounced['EMAIL'] = m.lowercase(df_bounced, 'EMAIL')
m.clean_space(df_bounced, 'EMAIL')
# Out:
# 0                 00001111den@gmail.com
# 1         007dhananjaykumbhar@gmail.com
# 2                       0597396@mail.ru
# 3                 07deepanshu@gmail.com
# 4                     1078049354@qq.com
#                       ...
# 982853          z_forbes_92@hotmail.com
# 982854            z_mingwei@hotmail.com
# 982855               z_o_ni@hotmail.com
# 982856                    _argo@mail.ru
# 982857      _joanne_mckay@hotmail.co.nz
# Name: EMAIL, Length: 982858, dtype: string

# %%
df_push.loc[df_push['Email'].isin(df_bounced['EMAIL'])]
# Out:
#        First Name Last Name                   Email         Phone  \
# 112     Mr. Navin     Sikka    navinsikka@gmail.com  919810879324
# 193  Adele Louise    Curcio  adelecurcii8@gmail.com   61411428051
#
#            Mobile   City    Country Nationality           Lead Locations  \
# 112  919810874332  DELHI      India      Indian  Karma Sitabani, Corbett
# 193         empty      -  Australia  Australian    Karma Royal Candidasa
#
#     Booking Status  BookRef
# 112    Checked-Out  2168062
# 193    Checked-Out  2104722

# %%
joined_df = pd.merge(df_push,
                     df_bounced,
                     left_on ='Email',
                     right_on ='EMAIL',
                     how ='left')
joined_df
# Out:
#               First Name   Last Name                        Email  \
# 0                  Niraj  Srivastava     neeraj.sri0107@gmail.com
# 1           Mr. Prasen V       Gupta            sbgbm@hotmail.com
# 2                Praveen     Kumar R  praveenkumar076@outlook.com
# 3               Ngatiman           -        timanteyeng@gmail.com
# 4                 Neeraj       Gupta   sakshichitkara18@gmail.com
# ..                   ...         ...                          ...
# 336               Naveen   Kumar M V      naveenreddy82@gmail.com
# 337  Mr. Rajesh Ramapati      Pandey     rajeshpandey30@gmail.com
# 338               Haroon      Shaikh         hararhshk2@gmail.com
# 339                 Amit     Kaushik      kaushikamit40@gmail.com
# 340              Matthew       Giles    matthew.w.giles@gmail.com
#
#              Phone        Mobile       City         Country Nationality  \
# 0     919550367824  919984874254  HYDERABAD           India      Indian
# ...

# %%
joined_df['Email'].loc[joined_df['EMAIL'].isna()].to_csv(r'C:\Users\fajar\Documents\Python\Data\push-pastguest-debounce.csv', index=False, encoding='utf-8')

# %%
joined_df.loc[joined_df['RESULT'] == 'Safe to Send']
# Out:
#        First Name Last Name                   Email         Phone  \
# 112     Mr. Navin     Sikka    navinsikka@gmail.com  919810879324
# 193  Adele Louise    Curcio  adelecurcii8@gmail.com   61411428051
#
#            Mobile   City    Country Nationality           Lead Locations  \
# 112  919810874332  DELHI      India      Indian  Karma Sitabani, Corbett
# 193         empty      -  Australia  Australian    Karma Royal Candidasa
#
#     Booking Status  BookRef                   EMAIL        RESULT  \
# 112    Checked-Out  2168062    navinsikka@gmail.com  Safe to Send
# 193    Checked-Out  2104722  adelecurcii8@gmail.com  Safe to Send
#
#           REASON STATUS CODE ROLE FREE     DOMAIN               Sheet Name
# 112  Deliverable           5   No  Yes  gmail.com               Past Guest
# 193  Deliverable           5   No  Yes  gmail.com  SEAP-Western2 - 18Mar22

# %%
# df_push.replace('empty', '', inplace=True)
# df_push.to_csv(r'C:\Users\fajar\Documents\Python\Data\push-pastguest-formatted.csv', index=False, encoding='utf-8')

# %%
df_bounced.loc[df_bounced['EMAIL'].str.contains('nhnovika@gmail.com', flags=re.I, regex=True)]
# Out:
# Empty DataFrame
# Columns: [EMAIL, RESULT, REASON, STATUS CODE, ROLE, FREE, DOMAIN, Sheet Name]
# Index: []
