# %%
import pandas as pd
import re
import openpyxl

import sys
sys.path.append('../')

import main_module as m

# %%
cols = ['First Name', 
    'Last Name',
    'Email', 
    'Phone', 
    'Mobile', 
    'City', 
    'State',
    'Country', 
    'Nationality',
    'Lead Locations', 
    'Booking Status',
    'Lead Source', 
    'BookRef']

# %%
path = r'C:\Users\fajar\Documents\Python\Data\push-pastguest.xlsx'
df_push = pd.read_excel(path, dtype='string', usecols=cols, sheet_name='Sheet0', engine='openpyxl')
df_push.fillna('empty', inplace=True)
count_total_data = df_push.shape[0]
df_push.columns
# Out:
# c:\Users\fajar\Documents\Python\Task Offline\venv12\Lib\site-packages\openpyxl\styles\stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# Index(['First Name', 'Last Name', 'Email', 'Phone', 'Mobile', 'City', 'State',
#        'Country', 'Nationality', 'Lead Source', 'Lead Locations',
#        'Booking Status', 'BookRef'],
#       dtype='object')

# %%
df_push
# Out:
#                  First Name             Last Name  \
# 0     D J Siddalinga Prasad                Prasad
# 1                    Anurag                 Sethi
# 2      Mr. Tallam Shravan &  Mrs. Vaibhavi Tallam
# 3                      Emma               Rynberk
# 4               Ishwer Dutt           Ishwer Dutt
# ..                      ...                   ...
# 380            Amit Bhowmik               Bhowmik
# 381                  Ashish               Trivedi
# 382  Mr. Mahendra Hanumanth              Bhalerao
# 383                     Tom                Waters
# 384                     Xue                   Bai
#
#                            Email           Phone         Mobile       City  \
# 0           djs_prasad@yahoo.com   +919980461508  +919845472453  BANGALORE
# 1            anurag445@gmail.com   +919815615445  +917087254445  PANCHKULA
# 2       vaibhavi.garlu@gmail.com   +919986203098  +917760766909  BANGALORE
# 3          rynberkemma@gmail.com   +447758867947          empty      empty
# 4    ishwerdutt1974.im@gmail.com   +919466894144  +919711693994   GURUGRAM
# ..                           ...             ...            ...        ...
# 380     amit_bhowmik1@rediff.com   +917675839754  +919573247672  HYDERABAD
# 381         ashi525252@gmail.com   +919871012035  +918052525256      NOIDA
# 382        swapnil6298@gmail.com   +918600018083  +918600018240       PUNE
# 383   sophiejeanwilson@gmail.com   +447894589478  +447894589478     London
# 384               8531086@99.com  +8651410107888          empty      empty
#
#              State         Country Nationality  Lead Source  \
# 0        KARNATAKA           India      Indian  Past Guests
# 1          HARYANA           India      Indian  Past Guests
# 2        KARNATAKA           India      Indian  Past Guests
# 3            empty  United Kingdom     British  Past Guests
# 4          HARYANA           India      Indian  Past Guests
# ..             ...             ...         ...          ...
# 380      TELANGANA           India      Indian  Past Guests
# 381  UTTAR PRADESH           India      Indian  Past Guests
# 382    MAHARASHTRA           India      Indian  Past Guests
# 383          empty  United Kingdom     British  Past Guests
# 384          empty           China     Chinese  Past Guests
#
#               Lead Locations Booking Status    BookRef
# 0          Karma Royal Palms    Checked-Out    2609691
# 1       Karma Utopia, Manali    Checked-Out    2487858
# 2     Karma Bayon, Siam Reap    Checked-Out    2578690
# 3           Karma La Herriza    Checked-Out    2428686
# 4          Karma Royal Palms    Checked-Out    2637324
# ..                       ...            ...        ...
# 380     Karma Royal Monterio    Checked-Out    2610555
# 381  Karma Sitabani, Corbett    Checked-Out    2617739
# 382        Karma Royal Palms    Checked-Out    2620369
# 383         Karma St Martins    Checked-Out  KSM011391
# 384            Karma Kandara    Checked-Out   KK061292
#
# [385 rows x 13 columns]

# %%
path = r'C:\Users\fajar\Documents\Python\Data\Debounce\debounce_backup.csv'
df_1 = pd.read_csv(path, dtype='string')

path = r'C:\Users\fajar\Documents\Python\Data\Debounce\debounce_new_temp.csv'
df_2 = pd.read_csv(path, dtype='string')


frames = [df_1, df_2]
df_bounced = pd.concat(frames, ignore_index=True)
df_bounced
# Out:
#                                  EMAIL        RESULT       REASON STATUS CODE  \
# 0                00001111den@gmail.com  Safe to Send  Deliverable           5
# 1        007dhananjaykumbhar@gmail.com  Safe to Send  Deliverable           5
# 2                      0597396@mail.ru  Safe to Send  Deliverable           5
# 3                07deepanshu@gmail.com  Safe to Send  Deliverable           5
# 4                    1078049354@qq.com  Safe to Send  Deliverable           5
# ...                                ...           ...          ...         ...
# 1261864       madhureddy1606@gmail.com  Safe to Send  Deliverable           5
# 1261865            dlsrajesh@gmail.com  Safe to Send  Deliverable           5
# 1261866         sadiqmulla77@gmail.com  Safe to Send  Deliverable           5
# 1261867          dvgupta1990@gmail.com  Safe to Send  Deliverable           5
# 1261868          satish20781@gmail.com  Safe to Send  Deliverable           5
#
#           ROLE  FREE     DOMAIN    Sheet Name
# 0           No   Yes  gmail.com  All Campaign
# 1           No   Yes  gmail.com  All Campaign
# 2           No   Yes    mail.ru  All Campaign
# 3           No   Yes  gmail.com  All Campaign
# 4           No   Yes     qq.com  All Campaign
# ...        ...   ...        ...           ...
# 1261864  FALSE  TRUE       <NA>          <NA>
# 1261865  FALSE  TRUE       <NA>          <NA>
# 1261866  FALSE  TRUE       <NA>          <NA>
# 1261867  FALSE  TRUE       <NA>          <NA>
# 1261868  FALSE  TRUE       <NA>          <NA>
#
# [1261869 rows x 8 columns]

# %%
df_bounced.drop_duplicates(subset='EMAIL', inplace=True)
df_bounced.reset_index(drop=True, inplace=True)
df_bounced
# Out:
#                                  EMAIL        RESULT       REASON STATUS CODE  \
# 0                00001111den@gmail.com  Safe to Send  Deliverable           5
# 1        007dhananjaykumbhar@gmail.com  Safe to Send  Deliverable           5
# 2                      0597396@mail.ru  Safe to Send  Deliverable           5
# 3                07deepanshu@gmail.com  Safe to Send  Deliverable           5
# 4                    1078049354@qq.com  Safe to Send  Deliverable           5
# ...                                ...           ...          ...         ...
# 1017841       madhureddy1606@gmail.com  Safe to Send  Deliverable           5
# 1017842            dlsrajesh@gmail.com  Safe to Send  Deliverable           5
# 1017843         sadiqmulla77@gmail.com  Safe to Send  Deliverable           5
# 1017844          dvgupta1990@gmail.com  Safe to Send  Deliverable           5
# 1017845          satish20781@gmail.com  Safe to Send  Deliverable           5
#
#           ROLE  FREE     DOMAIN    Sheet Name
# 0           No   Yes  gmail.com  All Campaign
# 1           No   Yes  gmail.com  All Campaign
# 2           No   Yes    mail.ru  All Campaign
# 3           No   Yes  gmail.com  All Campaign
# 4           No   Yes     qq.com  All Campaign
# ...        ...   ...        ...           ...
# 1017841  FALSE  TRUE       <NA>          <NA>
# 1017842  FALSE  TRUE       <NA>          <NA>
# 1017843  FALSE  TRUE       <NA>          <NA>
# 1017844  FALSE  TRUE       <NA>          <NA>
# 1017845  FALSE  TRUE       <NA>          <NA>
#
# [1017846 rows x 8 columns]

# %%
df_push['Email'] = m.lowercase(df_push, 'Email')
m.clean_space(df_push, 'Email')

df_bounced['EMAIL'] = m.lowercase(df_bounced, 'EMAIL')
m.clean_space(df_bounced, 'EMAIL')
# Out:
# c:\Users\fajar\Documents\Python\Task Offline\zoho_data_app\zoho_campaign\..\main_module.py:90: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[df_columns].replace(' ','', regex=True, inplace=True)
# 0                  00001111den@gmail.com
# 1          007dhananjaykumbhar@gmail.com
# 2                        0597396@mail.ru
# 3                  07deepanshu@gmail.com
# 4                      1078049354@qq.com
#                        ...
# 1017841         madhureddy1606@gmail.com
# 1017842              dlsrajesh@gmail.com
# 1017843           sadiqmulla77@gmail.com
# 1017844            dvgupta1990@gmail.com
# 1017845            satish20781@gmail.com
# Name: EMAIL, Length: 1017846, dtype: string

# %%
df_push.loc[df_push['Email'].isin(df_bounced['EMAIL'])]
# Out:
#                  First Name             Last Name  \
# 0     D J Siddalinga Prasad                Prasad
# 1                    Anurag                 Sethi
# 2      Mr. Tallam Shravan &  Mrs. Vaibhavi Tallam
# 3                      Emma               Rynberk
# 4               Ishwer Dutt           Ishwer Dutt
# ..                      ...                   ...
# 380            Amit Bhowmik               Bhowmik
# 381                  Ashish               Trivedi
# 382  Mr. Mahendra Hanumanth              Bhalerao
# 383                     Tom                Waters
# 384                     Xue                   Bai
#
#                            Email           Phone         Mobile       City  \
# 0           djs_prasad@yahoo.com   +919980461508  +919845472453  BANGALORE
# 1            anurag445@gmail.com   +919815615445  +917087254445  PANCHKULA
# 2       vaibhavi.garlu@gmail.com   +919986203098  +917760766909  BANGALORE
# 3          rynberkemma@gmail.com   +447758867947          empty      empty
# 4    ishwerdutt1974.im@gmail.com   +919466894144  +919711693994   GURUGRAM
# ..                           ...             ...            ...        ...
# 380     amit_bhowmik1@rediff.com   +917675839754  +919573247672  HYDERABAD
# 381         ashi525252@gmail.com   +919871012035  +918052525256      NOIDA
# 382        swapnil6298@gmail.com   +918600018083  +918600018240       PUNE
# 383   sophiejeanwilson@gmail.com   +447894589478  +447894589478     London
# 384               8531086@99.com  +8651410107888          empty      empty
#
#              State         Country Nationality  Lead Source  \
# 0        KARNATAKA           India      Indian  Past Guests
# 1          HARYANA           India      Indian  Past Guests
# 2        KARNATAKA           India      Indian  Past Guests
# 3            empty  United Kingdom     British  Past Guests
# 4          HARYANA           India      Indian  Past Guests
# ..             ...             ...         ...          ...
# 380      TELANGANA           India      Indian  Past Guests
# 381  UTTAR PRADESH           India      Indian  Past Guests
# 382    MAHARASHTRA           India      Indian  Past Guests
# 383          empty  United Kingdom     British  Past Guests
# 384          empty           China     Chinese  Past Guests
#
#               Lead Locations Booking Status    BookRef
# 0          Karma Royal Palms    Checked-Out    2609691
# 1       Karma Utopia, Manali    Checked-Out    2487858
# 2     Karma Bayon, Siam Reap    Checked-Out    2578690
# 3           Karma La Herriza    Checked-Out    2428686
# 4          Karma Royal Palms    Checked-Out    2637324
# ..                       ...            ...        ...
# 380     Karma Royal Monterio    Checked-Out    2610555
# 381  Karma Sitabani, Corbett    Checked-Out    2617739
# 382        Karma Royal Palms    Checked-Out    2620369
# 383         Karma St Martins    Checked-Out  KSM011391
# 384            Karma Kandara    Checked-Out   KK061292
#
# [385 rows x 13 columns]

# %%
count_empty_contact = df_push.loc[(df_push['Email'] == 'empty') &
            (df_push['Phone'] == 'empty') &
            (df_push['Mobile'] == 'empty')].shape[0]

df_push.drop(df_push.loc[(df_push['Email'] == 'empty') &
            (df_push['Phone'] == 'empty') &
            (df_push['Mobile'] == 'empty')
            ].index, inplace=True)

count_after_wash_empty_contact = df_push.shape[0]

# %%
# df_bounced.loc[df_bounced['EMAIL'] == 'pawan_chhikara2001@yahoo.com']

# %%
joined_df = pd.merge(df_push,
                     df_bounced,
                     left_on ='Email',
                     right_on ='EMAIL',
                     how ='left')
joined_df
# Out:
#                  First Name             Last Name  \
# 0     D J Siddalinga Prasad                Prasad
# 1                    Anurag                 Sethi
# 2      Mr. Tallam Shravan &  Mrs. Vaibhavi Tallam
# 3                      Emma               Rynberk
# 4               Ishwer Dutt           Ishwer Dutt
# ..                      ...                   ...
# 380            Amit Bhowmik               Bhowmik
# 381                  Ashish               Trivedi
# 382  Mr. Mahendra Hanumanth              Bhalerao
# 383                     Tom                Waters
# 384                     Xue                   Bai
#
#                            Email           Phone         Mobile       City  \
# 0           djs_prasad@yahoo.com   +919980461508  +919845472453  BANGALORE
# 1            anurag445@gmail.com   +919815615445  +917087254445  PANCHKULA
# 2       vaibhavi.garlu@gmail.com   +919986203098  +917760766909  BANGALORE
# 3          rynberkemma@gmail.com   +447758867947          empty      empty
# 4    ishwerdutt1974.im@gmail.com   +919466894144  +919711693994   GURUGRAM
# ..                           ...             ...            ...        ...
# 380     amit_bhowmik1@rediff.com   +917675839754  +919573247672  HYDERABAD
# 381         ashi525252@gmail.com   +919871012035  +918052525256      NOIDA
# 382        swapnil6298@gmail.com   +918600018083  +918600018240       PUNE
# 383   sophiejeanwilson@gmail.com   +447894589478  +447894589478     London
# 384               8531086@99.com  +8651410107888          empty      empty
#
#              State         Country Nationality  Lead Source  ...  \
# 0        KARNATAKA           India      Indian  Past Guests  ...
# 1          HARYANA           India      Indian  Past Guests  ...
# 2        KARNATAKA           India      Indian  Past Guests  ...
# 3            empty  United Kingdom     British  Past Guests  ...
# 4          HARYANA           India      Indian  Past Guests  ...
# ..             ...             ...         ...          ...  ...
# 380      TELANGANA           India      Indian  Past Guests  ...
# 381  UTTAR PRADESH           India      Indian  Past Guests  ...
# 382    MAHARASHTRA           India      Indian  Past Guests  ...
# 383          empty  United Kingdom     British  Past Guests  ...
# 384          empty           China     Chinese  Past Guests  ...
#
#     Booking Status    BookRef                        EMAIL        RESULT  \
# 0      Checked-Out    2609691         djs_prasad@yahoo.com  Safe to Send
# 1      Checked-Out    2487858          anurag445@gmail.com  Safe to Send
# 2      Checked-Out    2578690     vaibhavi.garlu@gmail.com  Safe to Send
# 3      Checked-Out    2428686        rynberkemma@gmail.com  Safe to Send
# 4      Checked-Out    2637324  ishwerdutt1974.im@gmail.com  Safe to Send
# ..             ...        ...                          ...           ...
# 380    Checked-Out    2610555     amit_bhowmik1@rediff.com  Safe to Send
# 381    Checked-Out    2617739         ashi525252@gmail.com  Safe to Send
# 382    Checked-Out    2620369        swapnil6298@gmail.com  Safe to Send
# 383    Checked-Out  KSM011391   sophiejeanwilson@gmail.com  Safe to Send
# 384    Checked-Out   KK061292               8531086@99.com       Invalid
#
#           REASON STATUS CODE   ROLE   FREE DOMAIN Sheet Name
# 0    Deliverable           5  FALSE   TRUE   <NA>       <NA>
# 1    Deliverable           5  FALSE   TRUE   <NA>       <NA>
# 2    Deliverable           5  FALSE   TRUE   <NA>       <NA>
# 3    Deliverable           5  FALSE   TRUE   <NA>       <NA>
# 4    Deliverable           5  FALSE   TRUE   <NA>       <NA>
# ..           ...         ...    ...    ...    ...        ...
# 380  Deliverable           5  FALSE   TRUE   <NA>       <NA>
# 381  Deliverable           5  FALSE   TRUE   <NA>       <NA>
# 382  Deliverable           5  FALSE   TRUE   <NA>       <NA>
# 383  Deliverable           5  FALSE   TRUE   <NA>       <NA>
# 384   Disposable           3  FALSE  FALSE   <NA>       <NA>
#
# [385 rows x 21 columns]

# %%
joined_list = joined_df.loc[~joined_df['RESULT'].isna()].copy()
joined_list.reset_index(drop=True, inplace=True)

not_exist_list = joined_df.loc[joined_df['RESULT'].isna()].copy()
not_exist_list.reset_index(drop=True, inplace=True)

count_exist_in_bounce = joined_list.shape[0]
count_not_exist_in_bounce = not_exist_list.shape[0]

# %%
safe_to_send = joined_list.loc[joined_list['RESULT'] == 'Safe to Send'].copy()
safe_to_send.reset_index(drop=True, inplace=True)
count_safe_to_send = safe_to_send.shape[0]

ex_safe_to_send = joined_list.loc[joined_list['RESULT'] != 'Safe to Send'].copy()
ex_safe_to_send.reset_index(drop=True, inplace=True)
count_ex_safe_to_send = ex_safe_to_send.shape[0]

# %%
print("==========================================================")
print("Summary")
print("==========================================================")
print("Jumlah Total Data : "+str(count_total_data))
print("Jumlah Data Contact Empty : "+str(count_empty_contact))
print("Jumlah Data Setelah Wash Empty Contact : "+str(count_empty_contact))
print("Jumlah Data Exist di Database Bounce : "+str(count_exist_in_bounce))
print("Jumlah Data Tidak Exist di Database Bounce : "+str(count_not_exist_in_bounce))
print("==========================================================")
print("Summary Bounced")
print("==========================================================")
print("Jumlah Data Safe to Send : "+str(count_safe_to_send))
print("Jumlah Data not Safe to Send : "+str(count_ex_safe_to_send))
# Out:
# ==========================================================
# Summary
# ==========================================================
# Jumlah Total Data : 385
# Jumlah Data Contact Empty : 0
# Jumlah Data Setelah Wash Empty Contact : 0
# Jumlah Data Exist di Database Bounce : 385
# Jumlah Data Tidak Exist di Database Bounce : 0
# ==========================================================
# Summary Bounced
# ==========================================================
# Jumlah Data Safe to Send : 340
# Jumlah Data not Safe to Send : 45

# %%
not_exist_list.loc[not_exist_list['Email'] == 'mohdasifaliak2016@gmail.com']
# df_1.loc[df_1['EMAIL'] == 'matthew.w.giles@gmail.com']
# df_1.loc[df_1['EMAIL'] == 'venkjaya@gmail.com']
# joined_df.loc[joined_df['RESULT'] == 'Safe to Send']
# df_bounced.loc[df_bounced['EMAIL'] == ]
# Out:
# Empty DataFrame
# Columns: [First Name, Last Name, Email, Phone, Mobile, City, State, Country, Nationality, Lead Source, Lead Locations, Booking Status, BookRef, EMAIL, RESULT, REASON, STATUS CODE, ROLE, FREE, DOMAIN, Sheet Name]
# Index: []
#
# [0 rows x 21 columns]

# %%
joined_df.loc[joined_df['Email'] == 'mohdasifaliak2016@gmail.com']
# Out:
# Empty DataFrame
# Columns: [First Name, Last Name, Email, Phone, Mobile, City, State, Country, Nationality, Lead Source, Lead Locations, Booking Status, BookRef, EMAIL, RESULT, REASON, STATUS CODE, ROLE, FREE, DOMAIN, Sheet Name]
# Index: []
#
# [0 rows x 21 columns]

# %%
safe_to_send.replace('empty', '', inplace=True)
safe_to_send.reset_index(drop=True, inplace=True)
df_safe = safe_to_send.reindex(columns=cols)
df_safe.rename(columns={'Lead Source':'Lead Sources'}, inplace=True)

df_safe.to_csv(r'C:\Users\fajar\Documents\Python\Data\push-pastguest-formatted.csv', index=False, encoding='utf-8')

# %%
ex_safe_to_send.replace('empty', '', inplace=True)
ex_safe_to_send.reset_index(drop=True, inplace=True)
df_ex_safe_to_send = ex_safe_to_send.reindex(columns=cols)
df_ex_safe_to_send

df_ex_safe_to_send.to_excel(r'C:\Users\fajar\Documents\Python\Data\not-safe-to-send-debounce.xlsx', index=False)

# %%
not_exist_list.replace('empty', '', inplace=True)
not_exist_list.reset_index(drop=True, inplace=True)
df_not_exist = not_exist_list.reindex(columns=cols)
df_not_exist

df_not_exist.to_excel(r'C:\Users\fajar\Documents\Python\Data\not-exist-debounce.xlsx', index=False)
