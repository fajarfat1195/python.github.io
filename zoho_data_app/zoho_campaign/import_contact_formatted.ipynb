# %%
import pandas as pd
import re
import openpyxl

import sys
sys.path.append('../')

import main_module as m

# %%
cols = ['First Name', 
    'Last Name',
    'Email', 
    'Phone', 
    'Mobile', 
    'City', 
    'State',
    'Country', 
    'Nationality',
    'Lead Locations', 
    'Booking Status',
    'Lead Source', 
    'BookRef']

# %%
path = r'C:\Users\fajar\Documents\Python\Data\push-pastguest.xlsx'
df_push = pd.read_excel(path, dtype='string', usecols=cols, sheet_name='Sheet0', engine='openpyxl')
df_push.fillna('empty', inplace=True)
count_total_data = df_push.shape[0]
df_push.columns
# Out:
# c:\Users\fajar\Documents\Python\Task Offline\venv12\Lib\site-packages\openpyxl\styles\stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# Index(['First Name', 'Last Name', 'Email', 'Phone', 'Mobile', 'City', 'State',
#        'Country', 'Nationality', 'Lead Source', 'Lead Locations',
#        'Booking Status', 'BookRef'],
#       dtype='object')

# %%
df_push
# Out:
#        First Name Last Name                           Email           Phone  \
# 0    Balachandran         S               arbala2@gmail.com   +918095552475
# 1         Patrick     Minal   nicole_minall@optisnet.com.au    +61423854814
# 2           Rohit         S             darshi025@gmail.com   +919686631212
# 3    Patel Jagrut         B       jagrutpatel1910@yahoo.com   +919737404240
# 4           Vivek     Singh       viveksinghoct87@gmail.com   +919667208006
# ..            ...       ...                             ...             ...
# 371         Oscar  Jonasson            lillaoscar@gmail.com    +61459496703
# 372         Colin  Mcharrie         annmcharrie54@gmail.com   +447931593660
# 373        Victor    Harris  viktorharisanatasiia@gmail.com  +4915164081846
# 374         Annie   Minihan           mini-anni@hotmail.com           empty
# 375        Robert       Lea             lea3838@hotmail.com   +441225920797
#
#             Mobile          City          State         Country  \
# 0    +919488059452     .BANGLORE     .KARNATAKA           India
# 1            empty             .              .     New Zealand
# 2    +919108279084     BANGALORE      KARNATAKA           India
# 3    +919979857708  GANDHI NAGAR        GUJARAT           India
# 4    +919643765160       LUCKNOW  UTTAR PRADESH           India
# ..             ...           ...            ...             ...
# 371          empty         empty          empty       Australia
# 372          empty         empty          empty  United Kingdom
# 373          empty             -              -         Ukraine
# 374          empty           Tba          empty           India
# 375  +447570968978          Bath     Batheaston  United Kingdom
#
#        Nationality  Lead Source                Lead Locations Booking Status  \
# 0           Indian  Past Guests             Karma Royal Palms    Checked-Out
# 1    New Zealander  Past Guests               Karma Song Hoai    Checked-Out
# 2           Indian  Past Guests       Karma Sitabani, Corbett    Checked-Out
# 3           Indian  Past Guests  Karma Golden Camp, Jaisalmer    Checked-Out
# 4           Indian  Past Guests       Karma Sitabani, Corbett    Checked-Out
# ..             ...          ...                           ...            ...
# 371        Swedish  Past Guests                   Amina hotel    Checked-Out
# 372        British  Past Guests        Karma Lake of Menteith    Checked-Out
# 373      Ukrainian  Past Guests                Karma Jimbaran    Checked-Out
# 374          empty  Past Guests            Karma Salford Hall      CANCELLED
# 375        British  Past Guests              Karma St Martins    Checked-Out
#
#        BookRef
# 0      2608681
# 1      2505001
# 2      2653781
# 3      2633381
# 4      2607652
# ..         ...
# 371    2617874
# 372  KLM006738
# 373    2621088
# 374  KSH020507
# 375  KSM014155
#
# [376 rows x 13 columns]

# %%
path = r'C:\Users\fajar\Documents\Python\Data\Debounce\debounce_backup.csv'
df_1 = pd.read_csv(path, dtype='string')

path = r'C:\Users\fajar\Documents\Python\Data\Debounce\debounce_new_temp.csv'
df_2 = pd.read_csv(path, dtype='string')


frames = [df_1, df_2]
df_bounced = pd.concat(frames, ignore_index=True)
df_bounced
# Out:
#                                  EMAIL        RESULT       REASON STATUS CODE  \
# 0                00001111den@gmail.com  Safe to Send  Deliverable           5
# 1        007dhananjaykumbhar@gmail.com  Safe to Send  Deliverable           5
# 2                      0597396@mail.ru  Safe to Send  Deliverable           5
# 3                07deepanshu@gmail.com  Safe to Send  Deliverable           5
# 4                    1078049354@qq.com  Safe to Send  Deliverable           5
# ...                                ...           ...          ...         ...
# 1262249     ambreen.dabherao@gmail.com  Safe to Send  Deliverable           5
# 1262250     theresehanhdaisy@gmail.com  Safe to Send  Deliverable           5
# 1262251    mukesh.kayasth70@karmai.com       Invalid       Bounce           6
# 1262252        kaushal.anand@gmail.com  Safe to Send  Deliverable           5
# 1262253         send2jyotika@gmail.com       Invalid       Bounce           6
#
#           ROLE   FREE     DOMAIN    Sheet Name
# 0           No    Yes  gmail.com  All Campaign
# 1           No    Yes  gmail.com  All Campaign
# 2           No    Yes    mail.ru  All Campaign
# 3           No    Yes  gmail.com  All Campaign
# 4           No    Yes     qq.com  All Campaign
# ...        ...    ...        ...           ...
# 1262249  FALSE   TRUE       <NA>          <NA>
# 1262250  FALSE   TRUE       <NA>          <NA>
# 1262251  FALSE  FALSE       <NA>          <NA>
# 1262252  FALSE   TRUE       <NA>          <NA>
# 1262253  FALSE   TRUE       <NA>          <NA>
#
# [1262254 rows x 8 columns]

# %%
df_bounced.drop_duplicates(subset='EMAIL', inplace=True)
df_bounced.reset_index(drop=True, inplace=True)
df_bounced
# Out:
#                                  EMAIL        RESULT       REASON STATUS CODE  \
# 0                00001111den@gmail.com  Safe to Send  Deliverable           5
# 1        007dhananjaykumbhar@gmail.com  Safe to Send  Deliverable           5
# 2                      0597396@mail.ru  Safe to Send  Deliverable           5
# 3                07deepanshu@gmail.com  Safe to Send  Deliverable           5
# 4                    1078049354@qq.com  Safe to Send  Deliverable           5
# ...                                ...           ...          ...         ...
# 1018226     ambreen.dabherao@gmail.com  Safe to Send  Deliverable           5
# 1018227     theresehanhdaisy@gmail.com  Safe to Send  Deliverable           5
# 1018228    mukesh.kayasth70@karmai.com       Invalid       Bounce           6
# 1018229        kaushal.anand@gmail.com  Safe to Send  Deliverable           5
# 1018230         send2jyotika@gmail.com       Invalid       Bounce           6
#
#           ROLE   FREE     DOMAIN    Sheet Name
# 0           No    Yes  gmail.com  All Campaign
# 1           No    Yes  gmail.com  All Campaign
# 2           No    Yes    mail.ru  All Campaign
# 3           No    Yes  gmail.com  All Campaign
# 4           No    Yes     qq.com  All Campaign
# ...        ...    ...        ...           ...
# 1018226  FALSE   TRUE       <NA>          <NA>
# 1018227  FALSE   TRUE       <NA>          <NA>
# 1018228  FALSE  FALSE       <NA>          <NA>
# 1018229  FALSE   TRUE       <NA>          <NA>
# 1018230  FALSE   TRUE       <NA>          <NA>
#
# [1018231 rows x 8 columns]

# %%
df_push['Email'] = m.lowercase(df_push, 'Email')
m.clean_space(df_push, 'Email')

df_bounced['EMAIL'] = m.lowercase(df_bounced, 'EMAIL')
m.clean_space(df_bounced, 'EMAIL')
# Out:
# c:\Users\fajar\Documents\Python\Task Offline\zoho_data_app\zoho_campaign\..\main_module.py:90: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[df_columns].replace(' ','', regex=True, inplace=True)
# 0                  00001111den@gmail.com
# 1          007dhananjaykumbhar@gmail.com
# 2                        0597396@mail.ru
# 3                  07deepanshu@gmail.com
# 4                      1078049354@qq.com
#                        ...
# 1018226       ambreen.dabherao@gmail.com
# 1018227       theresehanhdaisy@gmail.com
# 1018228      mukesh.kayasth70@karmai.com
# 1018229          kaushal.anand@gmail.com
# 1018230           send2jyotika@gmail.com
# Name: EMAIL, Length: 1018231, dtype: string

# %%
df_push.loc[df_push['Email'].isin(df_bounced['EMAIL'])]
# Out:
#        First Name Last Name                           Email           Phone  \
# 0    Balachandran         S               arbala2@gmail.com   +918095552475
# 1         Patrick     Minal   nicole_minall@optisnet.com.au    +61423854814
# 2           Rohit         S             darshi025@gmail.com   +919686631212
# 3    Patel Jagrut         B       jagrutpatel1910@yahoo.com   +919737404240
# 4           Vivek     Singh       viveksinghoct87@gmail.com   +919667208006
# ..            ...       ...                             ...             ...
# 371         Oscar  Jonasson            lillaoscar@gmail.com    +61459496703
# 372         Colin  Mcharrie         annmcharrie54@gmail.com   +447931593660
# 373        Victor    Harris  viktorharisanatasiia@gmail.com  +4915164081846
# 374         Annie   Minihan           mini-anni@hotmail.com           empty
# 375        Robert       Lea             lea3838@hotmail.com   +441225920797
#
#             Mobile          City          State         Country  \
# 0    +919488059452     .BANGLORE     .KARNATAKA           India
# 1            empty             .              .     New Zealand
# 2    +919108279084     BANGALORE      KARNATAKA           India
# 3    +919979857708  GANDHI NAGAR        GUJARAT           India
# 4    +919643765160       LUCKNOW  UTTAR PRADESH           India
# ..             ...           ...            ...             ...
# 371          empty         empty          empty       Australia
# 372          empty         empty          empty  United Kingdom
# 373          empty             -              -         Ukraine
# 374          empty           Tba          empty           India
# 375  +447570968978          Bath     Batheaston  United Kingdom
#
#        Nationality  Lead Source                Lead Locations Booking Status  \
# 0           Indian  Past Guests             Karma Royal Palms    Checked-Out
# 1    New Zealander  Past Guests               Karma Song Hoai    Checked-Out
# 2           Indian  Past Guests       Karma Sitabani, Corbett    Checked-Out
# 3           Indian  Past Guests  Karma Golden Camp, Jaisalmer    Checked-Out
# 4           Indian  Past Guests       Karma Sitabani, Corbett    Checked-Out
# ..             ...          ...                           ...            ...
# 371        Swedish  Past Guests                   Amina hotel    Checked-Out
# 372        British  Past Guests        Karma Lake of Menteith    Checked-Out
# 373      Ukrainian  Past Guests                Karma Jimbaran    Checked-Out
# 374          empty  Past Guests            Karma Salford Hall      CANCELLED
# 375        British  Past Guests              Karma St Martins    Checked-Out
#
#        BookRef
# 0      2608681
# 1      2505001
# 2      2653781
# 3      2633381
# 4      2607652
# ..         ...
# 371    2617874
# 372  KLM006738
# 373    2621088
# 374  KSH020507
# 375  KSM014155
#
# [374 rows x 13 columns]

# %%
count_empty_contact = df_push.loc[(df_push['Email'] == 'empty') &
            (df_push['Phone'] == 'empty') &
            (df_push['Mobile'] == 'empty')].shape[0]

df_push.drop(df_push.loc[(df_push['Email'] == 'empty') &
            (df_push['Phone'] == 'empty') &
            (df_push['Mobile'] == 'empty')
            ].index, inplace=True)

count_after_wash_empty_contact = df_push.shape[0]

# %%
# df_bounced.loc[df_bounced['EMAIL'] == 'pawan_chhikara2001@yahoo.com']

# %%
joined_df = pd.merge(df_push,
                     df_bounced,
                     left_on ='Email',
                     right_on ='EMAIL',
                     how ='left')
joined_df
# Out:
#        First Name Last Name                           Email           Phone  \
# 0    Balachandran         S               arbala2@gmail.com   +918095552475
# 1         Patrick     Minal   nicole_minall@optisnet.com.au    +61423854814
# 2           Rohit         S             darshi025@gmail.com   +919686631212
# 3    Patel Jagrut         B       jagrutpatel1910@yahoo.com   +919737404240
# 4           Vivek     Singh       viveksinghoct87@gmail.com   +919667208006
# ..            ...       ...                             ...             ...
# 371         Oscar  Jonasson            lillaoscar@gmail.com    +61459496703
# 372         Colin  Mcharrie         annmcharrie54@gmail.com   +447931593660
# 373        Victor    Harris  viktorharisanatasiia@gmail.com  +4915164081846
# 374         Annie   Minihan           mini-anni@hotmail.com           empty
# 375        Robert       Lea             lea3838@hotmail.com   +441225920797
#
#             Mobile          City          State         Country  \
# 0    +919488059452     .BANGLORE     .KARNATAKA           India
# 1            empty             .              .     New Zealand
# 2    +919108279084     BANGALORE      KARNATAKA           India
# 3    +919979857708  GANDHI NAGAR        GUJARAT           India
# 4    +919643765160       LUCKNOW  UTTAR PRADESH           India
# ..             ...           ...            ...             ...
# 371          empty         empty          empty       Australia
# 372          empty         empty          empty  United Kingdom
# 373          empty             -              -         Ukraine
# 374          empty           Tba          empty           India
# 375  +447570968978          Bath     Batheaston  United Kingdom
#
#        Nationality  Lead Source  ... Booking Status    BookRef  \
# 0           Indian  Past Guests  ...    Checked-Out    2608681
# 1    New Zealander  Past Guests  ...    Checked-Out    2505001
# 2           Indian  Past Guests  ...    Checked-Out    2653781
# 3           Indian  Past Guests  ...    Checked-Out    2633381
# 4           Indian  Past Guests  ...    Checked-Out    2607652
# ..             ...          ...  ...            ...        ...
# 371        Swedish  Past Guests  ...    Checked-Out    2617874
# 372        British  Past Guests  ...    Checked-Out  KLM006738
# 373      Ukrainian  Past Guests  ...    Checked-Out    2621088
# 374          empty  Past Guests  ...      CANCELLED  KSH020507
# 375        British  Past Guests  ...    Checked-Out  KSM014155
#
#                               EMAIL        RESULT       REASON STATUS CODE  \
# 0                 arbala2@gmail.com  Safe to Send  Deliverable           5
# 1     nicole_minall@optisnet.com.au       Invalid       Bounce           6
# 2               darshi025@gmail.com  Safe to Send  Deliverable           5
# 3         jagrutpatel1910@yahoo.com  Safe to Send  Deliverable           5
# 4         viveksinghoct87@gmail.com  Safe to Send  Deliverable           5
# ..                              ...           ...          ...         ...
# 371            lillaoscar@gmail.com  Safe to Send  Deliverable           5
# 372         annmcharrie54@gmail.com  Safe to Send  Deliverable           5
# 373  viktorharisanatasiia@gmail.com       Invalid       Bounce           6
# 374           mini-anni@hotmail.com  Safe to Send  Deliverable           5
# 375             lea3838@hotmail.com  Safe to Send  Deliverable           5
#
#       ROLE   FREE DOMAIN Sheet Name
# 0    FALSE   TRUE   <NA>       <NA>
# 1    FALSE  FALSE   <NA>       <NA>
# 2    FALSE   TRUE   <NA>       <NA>
# 3    FALSE   TRUE   <NA>       <NA>
# 4    FALSE   TRUE   <NA>       <NA>
# ..     ...    ...    ...        ...
# 371  FALSE   TRUE   <NA>       <NA>
# 372  FALSE   TRUE   <NA>       <NA>
# 373  FALSE   TRUE   <NA>       <NA>
# 374  FALSE   TRUE   <NA>       <NA>
# 375  FALSE   TRUE   <NA>       <NA>
#
# [376 rows x 21 columns]

# %%
joined_list = joined_df.loc[~joined_df['RESULT'].isna()].copy()
joined_list.reset_index(drop=True, inplace=True)

not_exist_list = joined_df.loc[joined_df['RESULT'].isna()].copy()
not_exist_list.reset_index(drop=True, inplace=True)

count_exist_in_bounce = joined_list.shape[0]
count_not_exist_in_bounce = not_exist_list.shape[0]

# %%
safe_to_send = joined_list.loc[joined_list['RESULT'] == 'Safe to Send'].copy()
safe_to_send.reset_index(drop=True, inplace=True)
count_safe_to_send = safe_to_send.shape[0]

ex_safe_to_send = joined_list.loc[joined_list['RESULT'] != 'Safe to Send'].copy()
ex_safe_to_send.reset_index(drop=True, inplace=True)
count_ex_safe_to_send = ex_safe_to_send.shape[0]

# %%
print("==========================================================")
print("Summary")
print("==========================================================")
print("Jumlah Total Data : "+str(count_total_data))
print("Jumlah Data Contact Empty : "+str(count_empty_contact))
print("Jumlah Data Setelah Wash Empty Contact : "+str(count_empty_contact))
print("Jumlah Data Exist di Database Bounce : "+str(count_exist_in_bounce))
print("Jumlah Data Tidak Exist di Database Bounce : "+str(count_not_exist_in_bounce))
print("==========================================================")
print("Summary Bounced")
print("==========================================================")
print("Jumlah Data Safe to Send : "+str(count_safe_to_send))
print("Jumlah Data not Safe to Send : "+str(count_ex_safe_to_send))
# Out:
# ==========================================================
# Summary
# ==========================================================
# Jumlah Total Data : 376
# Jumlah Data Contact Empty : 0
# Jumlah Data Setelah Wash Empty Contact : 0
# Jumlah Data Exist di Database Bounce : 374
# Jumlah Data Tidak Exist di Database Bounce : 2
# ==========================================================
# Summary Bounced
# ==========================================================
# Jumlah Data Safe to Send : 323
# Jumlah Data not Safe to Send : 51

# %%
not_exist_list.loc[not_exist_list['Email'] == 'mohdasifaliak2016@gmail.com']
# df_1.loc[df_1['EMAIL'] == 'matthew.w.giles@gmail.com']
# df_1.loc[df_1['EMAIL'] == 'venkjaya@gmail.com']
# joined_df.loc[joined_df['RESULT'] == 'Safe to Send']
# df_bounced.loc[df_bounced['EMAIL'] == ]
# Out:
# Empty DataFrame
# Columns: [First Name, Last Name, Email, Phone, Mobile, City, State, Country, Nationality, Lead Source, Lead Locations, Booking Status, BookRef, EMAIL, RESULT, REASON, STATUS CODE, ROLE, FREE, DOMAIN, Sheet Name]
# Index: []
#
# [0 rows x 21 columns]

# %%
joined_df.loc[joined_df['Email'] == 'mohdasifaliak2016@gmail.com']
# Out:
# Empty DataFrame
# Columns: [First Name, Last Name, Email, Phone, Mobile, City, State, Country, Nationality, Lead Source, Lead Locations, Booking Status, BookRef, EMAIL, RESULT, REASON, STATUS CODE, ROLE, FREE, DOMAIN, Sheet Name]
# Index: []
#
# [0 rows x 21 columns]

# %%
safe_to_send.replace('empty', '', inplace=True)
safe_to_send.reset_index(drop=True, inplace=True)
df_safe = safe_to_send.reindex(columns=cols)
df_safe.rename(columns={'Lead Source':'Lead Sources'}, inplace=True)

df_safe.to_csv(r'C:\Users\fajar\Documents\Python\Data\push-pastguest-formatted.csv', index=False, encoding='utf-8')

# %%
ex_safe_to_send.replace('empty', '', inplace=True)
ex_safe_to_send.reset_index(drop=True, inplace=True)
df_ex_safe_to_send = ex_safe_to_send.reindex(columns=cols)
df_ex_safe_to_send

df_ex_safe_to_send.to_excel(r'C:\Users\fajar\Documents\Python\Data\not-safe-to-send-debounce.xlsx', index=False)

# %%
not_exist_list.replace('empty', '', inplace=True)
not_exist_list.reset_index(drop=True, inplace=True)
df_not_exist = not_exist_list.reindex(columns=cols)
df_not_exist

df_not_exist.to_excel(r'C:\Users\fajar\Documents\Python\Data\not-exist-debounce.xlsx', index=False)
