# %%
import pandas as pd
import re
import openpyxl

import sys
sys.path.append('../')

import main_module as m

# %%
cols = ['First Name', 
    'Last Name',
    'Email', 
    'Phone', 
    'Mobile', 
    'City', 
    'Country', 
    'Nationality',
    'Lead Locations', 
    'Booking Status',
    'Lead Source', 
    'BookRef']

# %%
path = r'C:\Users\fajar\Documents\Python\Data\push-pastguest.xlsx'
df_push = pd.read_excel(path, dtype='string', usecols=cols, sheet_name='Sheet0', engine='openpyxl')
df_push.fillna('empty', inplace=True)
count_total_data = df_push.shape[0]
df_push.columns
# Out:
# C:\Users\fajar\AppData\Roaming\Python\Python310\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# Index(['First Name', 'Last Name', 'Email', 'Phone', 'Mobile', 'City',
#        'Country', 'Nationality', 'Lead Source', 'Lead Locations',
#        'Booking Status', 'BookRef'],
#       dtype='object')

# %%
df_push
# Out:
#         First Name     Last Name                           Email  \
# 0            Rahul       Agrawal       rahulagrawal427@gmail.com
# 1    Sandeep Singh     Bhadouria     sandeep.bhadourya@gmail.com
# 2           Leanne       Pereira     leannepereira2002@gmail.com
# 3         Lawrence       Pereira         lawry_pereira@yahoo.com
# 4             Ojas           Rao      neha.deshpande26@gmail.com
# ..             ...           ...                             ...
# 255          Alice  Shuttleworth  alice_shuttleworth@yahoo.co.uk
# 256      Shih-Ping          Yang        tsaeyang002@yahoo.com.tw
# 257     Seah Cheng           San         chengsan@singnet.com.sg
# 258         Deepak         Kumar      deepakmuteja1979@gmail.com
# 259          Sarah       Mhlanga     sarahgreen82@googlemail.com
#
#              Phone         Mobile       City         Country  Nationality  \
# 0    +919131331655          empty      Korba           India       Indian
# 1    +919545231100  +918390305170       PUNE           India       Indian
# 2    +919741992031          empty   Banglore           India       Indian
# 3    +919901907414          empty   Banglore           India       Indian
# 4    +918095861162  +918147338292  BENGALURU           India       Indian
# ..             ...            ...        ...             ...          ...
# 255  +447815960436          empty      empty  United Kingdom      British
# 256  +886983185791          empty          -          Taiwan    Taiwanese
# 257          empty          empty          .       Singapore  Singaporean
# 258  +919996006842  +918529084740    BHIWANI           India       Indian
# 259  +447557117808          empty      empty  United Kingdom      British
#
#      Lead Source                           Lead Locations Booking Status  \
# 0    Past Guests  KRR @ Karma Kandara, Mentari Residences    Checked-Out
# 1    Past Guests                        Karma Royal Palms    Checked-Out
# 2    Past Guests                   Karma Sunshine Village    Checked-Out
# 3    Past Guests                   Karma Sunshine Village    Checked-Out
# 4    Past Guests                        Karma Royal Palms    Checked-Out
# ..           ...                                      ...            ...
# 255  Past Guests                         Karma La Herriza    Checked-Out
# 256  Past Guests                           Karma Jimbaran    Checked-Out
# 257  Past Guests  KRR @ Karma Kandara, Mentari Residences    Checked-Out
# 258  Past Guests                  Karma Sitabani, Corbett    Checked-Out
# 259  Past Guests                         Karma La Herriza    Checked-Out
#
#      BookRef
# 0    2578611
# 1    2518438
# 2    2539018
# 3    2539019
# 4    2574113
# ..       ...
# 255  2522243
# 256  2558600
# 257  2456671
# 258  2537352
# 259  2530230
#
# [260 rows x 12 columns]

# %%
path = r'C:\Users\fajar\Documents\Python\Data\Debounce\debounce_backup.csv'
df_1 = pd.read_csv(path, dtype='string')

path = r'C:\Users\fajar\Documents\Python\Data\Debounce\debounce_new_temp.csv'
df_2 = pd.read_csv(path, dtype='string')


frames = [df_1, df_2]
df_bounced = pd.concat(frames, ignore_index=True)
df_bounced
# Out:
#                                  EMAIL        RESULT       REASON STATUS CODE  \
# 0                00001111den@gmail.com  Safe to Send  Deliverable           5
# 1        007dhananjaykumbhar@gmail.com  Safe to Send  Deliverable           5
# 2                      0597396@mail.ru  Safe to Send  Deliverable           5
# 3                07deepanshu@gmail.com  Safe to Send  Deliverable           5
# 4                    1078049354@qq.com  Safe to Send  Deliverable           5
# ...                                ...           ...          ...         ...
# 1258263              kppahwa@gmail.com  Safe to Send  Deliverable           5
# 1258264               jb8886@gmail.com  Safe to Send  Deliverable           5
# 1258265    ashwinkarhade2002@gmail.com  Safe to Send  Deliverable           5
# 1258266               jobykr@gmail.com  Safe to Send  Deliverable           5
# 1258267     neha.deshpande26@gmail.com  Safe to Send  Deliverable           5
#
#           ROLE  FREE     DOMAIN    Sheet Name
# 0           No   Yes  gmail.com  All Campaign
# 1           No   Yes  gmail.com  All Campaign
# 2           No   Yes    mail.ru  All Campaign
# 3           No   Yes  gmail.com  All Campaign
# 4           No   Yes     qq.com  All Campaign
# ...        ...   ...        ...           ...
# 1258263  FALSE  TRUE       <NA>          <NA>
# 1258264  FALSE  TRUE       <NA>          <NA>
# 1258265  FALSE  TRUE       <NA>          <NA>
# 1258266  FALSE  TRUE       <NA>          <NA>
# 1258267  FALSE  TRUE       <NA>          <NA>
#
# [1258268 rows x 8 columns]

# %%
df_bounced.drop_duplicates(subset='EMAIL', inplace=True)
df_bounced.reset_index(drop=True, inplace=True)
df_bounced
# Out:
#                                  EMAIL        RESULT       REASON STATUS CODE  \
# 0                00001111den@gmail.com  Safe to Send  Deliverable           5
# 1        007dhananjaykumbhar@gmail.com  Safe to Send  Deliverable           5
# 2                      0597396@mail.ru  Safe to Send  Deliverable           5
# 3                07deepanshu@gmail.com  Safe to Send  Deliverable           5
# 4                    1078049354@qq.com  Safe to Send  Deliverable           5
# ...                                ...           ...          ...         ...
# 1014501              kppahwa@gmail.com  Safe to Send  Deliverable           5
# 1014502               jb8886@gmail.com  Safe to Send  Deliverable           5
# 1014503    ashwinkarhade2002@gmail.com  Safe to Send  Deliverable           5
# 1014504               jobykr@gmail.com  Safe to Send  Deliverable           5
# 1014505     neha.deshpande26@gmail.com  Safe to Send  Deliverable           5
#
#           ROLE  FREE     DOMAIN    Sheet Name
# 0           No   Yes  gmail.com  All Campaign
# 1           No   Yes  gmail.com  All Campaign
# 2           No   Yes    mail.ru  All Campaign
# 3           No   Yes  gmail.com  All Campaign
# 4           No   Yes     qq.com  All Campaign
# ...        ...   ...        ...           ...
# 1014501  FALSE  TRUE       <NA>          <NA>
# 1014502  FALSE  TRUE       <NA>          <NA>
# 1014503  FALSE  TRUE       <NA>          <NA>
# 1014504  FALSE  TRUE       <NA>          <NA>
# 1014505  FALSE  TRUE       <NA>          <NA>
#
# [1014506 rows x 8 columns]

# %%
df_push['Email'] = m.lowercase(df_push, 'Email')
m.clean_space(df_push, 'Email')

df_bounced['EMAIL'] = m.lowercase(df_bounced, 'EMAIL')
m.clean_space(df_bounced, 'EMAIL')
# Out:
# 0                  00001111den@gmail.com
# 1          007dhananjaykumbhar@gmail.com
# 2                        0597396@mail.ru
# 3                  07deepanshu@gmail.com
# 4                      1078049354@qq.com
#                        ...
# 1014501                kppahwa@gmail.com
# 1014502                 jb8886@gmail.com
# 1014503      ashwinkarhade2002@gmail.com
# 1014504                 jobykr@gmail.com
# 1014505       neha.deshpande26@gmail.com
# Name: EMAIL, Length: 1014506, dtype: string

# %%
df_push.loc[df_push['Email'].isin(df_bounced['EMAIL'])]
# Out:
#         First Name     Last Name                           Email  \
# 0            Rahul       Agrawal       rahulagrawal427@gmail.com
# 1    Sandeep Singh     Bhadouria     sandeep.bhadourya@gmail.com
# 2           Leanne       Pereira     leannepereira2002@gmail.com
# 3         Lawrence       Pereira         lawry_pereira@yahoo.com
# 4             Ojas           Rao      neha.deshpande26@gmail.com
# ..             ...           ...                             ...
# 255          Alice  Shuttleworth  alice_shuttleworth@yahoo.co.uk
# 256      Shih-Ping          Yang        tsaeyang002@yahoo.com.tw
# 257     Seah Cheng           San         chengsan@singnet.com.sg
# 258         Deepak         Kumar      deepakmuteja1979@gmail.com
# 259          Sarah       Mhlanga     sarahgreen82@googlemail.com
#
#              Phone         Mobile       City         Country  Nationality  \
# 0    +919131331655          empty      Korba           India       Indian
# 1    +919545231100  +918390305170       PUNE           India       Indian
# 2    +919741992031          empty   Banglore           India       Indian
# 3    +919901907414          empty   Banglore           India       Indian
# 4    +918095861162  +918147338292  BENGALURU           India       Indian
# ..             ...            ...        ...             ...          ...
# 255  +447815960436          empty      empty  United Kingdom      British
# 256  +886983185791          empty          -          Taiwan    Taiwanese
# 257          empty          empty          .       Singapore  Singaporean
# 258  +919996006842  +918529084740    BHIWANI           India       Indian
# 259  +447557117808          empty      empty  United Kingdom      British
#
#      Lead Source                           Lead Locations Booking Status  \
# 0    Past Guests  KRR @ Karma Kandara, Mentari Residences    Checked-Out
# 1    Past Guests                        Karma Royal Palms    Checked-Out
# 2    Past Guests                   Karma Sunshine Village    Checked-Out
# 3    Past Guests                   Karma Sunshine Village    Checked-Out
# 4    Past Guests                        Karma Royal Palms    Checked-Out
# ..           ...                                      ...            ...
# 255  Past Guests                         Karma La Herriza    Checked-Out
# 256  Past Guests                           Karma Jimbaran    Checked-Out
# 257  Past Guests  KRR @ Karma Kandara, Mentari Residences    Checked-Out
# 258  Past Guests                  Karma Sitabani, Corbett    Checked-Out
# 259  Past Guests                         Karma La Herriza    Checked-Out
#
#      BookRef
# 0    2578611
# 1    2518438
# 2    2539018
# 3    2539019
# 4    2574113
# ..       ...
# 255  2522243
# 256  2558600
# 257  2456671
# 258  2537352
# 259  2530230
#
# [260 rows x 12 columns]

# %%
count_empty_contact = df_push.loc[(df_push['Email'] == 'empty') &
            (df_push['Phone'] == 'empty') &
            (df_push['Mobile'] == 'empty')].shape[0]

df_push.drop(df_push.loc[(df_push['Email'] == 'empty') &
            (df_push['Phone'] == 'empty') &
            (df_push['Mobile'] == 'empty')
            ].index, inplace=True)

count_after_wash_empty_contact = df_push.shape[0]

# %%
# df_bounced.loc[df_bounced['EMAIL'] == 'pawan_chhikara2001@yahoo.com']

# %%
joined_df = pd.merge(df_push,
                     df_bounced,
                     left_on ='Email',
                     right_on ='EMAIL',
                     how ='left')
joined_df
# Out:
#         First Name     Last Name                           Email  \
# 0            Rahul       Agrawal       rahulagrawal427@gmail.com
# 1    Sandeep Singh     Bhadouria     sandeep.bhadourya@gmail.com
# 2           Leanne       Pereira     leannepereira2002@gmail.com
# 3         Lawrence       Pereira         lawry_pereira@yahoo.com
# 4             Ojas           Rao      neha.deshpande26@gmail.com
# ..             ...           ...                             ...
# 255          Alice  Shuttleworth  alice_shuttleworth@yahoo.co.uk
# 256      Shih-Ping          Yang        tsaeyang002@yahoo.com.tw
# 257     Seah Cheng           San         chengsan@singnet.com.sg
# 258         Deepak         Kumar      deepakmuteja1979@gmail.com
# 259          Sarah       Mhlanga     sarahgreen82@googlemail.com
#
#              Phone         Mobile       City         Country  Nationality  \
# 0    +919131331655          empty      Korba           India       Indian
# 1    +919545231100  +918390305170       PUNE           India       Indian
# 2    +919741992031          empty   Banglore           India       Indian
# 3    +919901907414          empty   Banglore           India       Indian
# 4    +918095861162  +918147338292  BENGALURU           India       Indian
# ..             ...            ...        ...             ...          ...
# 255  +447815960436          empty      empty  United Kingdom      British
# 256  +886983185791          empty          -          Taiwan    Taiwanese
# 257          empty          empty          .       Singapore  Singaporean
# 258  +919996006842  +918529084740    BHIWANI           India       Indian
# 259  +447557117808          empty      empty  United Kingdom      British
#
#      Lead Source                           Lead Locations Booking Status  \
# 0    Past Guests  KRR @ Karma Kandara, Mentari Residences    Checked-Out
# 1    Past Guests                        Karma Royal Palms    Checked-Out
# 2    Past Guests                   Karma Sunshine Village    Checked-Out
# 3    Past Guests                   Karma Sunshine Village    Checked-Out
# 4    Past Guests                        Karma Royal Palms    Checked-Out
# ..           ...                                      ...            ...
# 255  Past Guests                         Karma La Herriza    Checked-Out
# 256  Past Guests                           Karma Jimbaran    Checked-Out
# 257  Past Guests  KRR @ Karma Kandara, Mentari Residences    Checked-Out
# 258  Past Guests                  Karma Sitabani, Corbett    Checked-Out
# 259  Past Guests                         Karma La Herriza    Checked-Out
#
#      BookRef                           EMAIL        RESULT       REASON  \
# 0    2578611       rahulagrawal427@gmail.com  Safe to Send  Deliverable
# 1    2518438     sandeep.bhadourya@gmail.com       Invalid       Bounce
# 2    2539018     leannepereira2002@gmail.com  Safe to Send  Deliverable
# 3    2539019         lawry_pereira@yahoo.com  Safe to Send  Deliverable
# 4    2574113      neha.deshpande26@gmail.com  Safe to Send  Deliverable
# ..       ...                             ...           ...          ...
# 255  2522243  alice_shuttleworth@yahoo.co.uk  Safe to Send  Deliverable
# 256  2558600        tsaeyang002@yahoo.com.tw       Invalid       Bounce
# 257  2456671         chengsan@singnet.com.sg  Safe to Send  Deliverable
# 258  2537352      deepakmuteja1979@gmail.com  Safe to Send  Deliverable
# 259  2530230     sarahgreen82@googlemail.com  Safe to Send  Deliverable
#
#     STATUS CODE   ROLE  FREE DOMAIN Sheet Name
# 0             5  FALSE  TRUE   <NA>       <NA>
# 1             6  FALSE  TRUE   <NA>       <NA>
# 2             5  FALSE  TRUE   <NA>       <NA>
# 3             5  FALSE  TRUE   <NA>       <NA>
# 4             5  FALSE  TRUE   <NA>       <NA>
# ..          ...    ...   ...    ...        ...
# 255           5  FALSE  TRUE   <NA>       <NA>
# 256           6  FALSE  TRUE   <NA>       <NA>
# 257           5  FALSE  TRUE   <NA>       <NA>
# 258           5  FALSE  TRUE   <NA>       <NA>
# 259           5  FALSE  TRUE   <NA>       <NA>
#
# [260 rows x 20 columns]

# %%
joined_list = joined_df.loc[~joined_df['RESULT'].isna()].copy()
joined_list.reset_index(drop=True, inplace=True)

not_exist_list = joined_df.loc[joined_df['RESULT'].isna()].copy()
not_exist_list.reset_index(drop=True, inplace=True)

count_exist_in_bounce = joined_list.shape[0]
count_not_exist_in_bounce = not_exist_list.shape[0]

# %%
safe_to_send = joined_list.loc[joined_list['RESULT'] == 'Safe to Send'].copy()
safe_to_send.reset_index(drop=True, inplace=True)
count_safe_to_send = safe_to_send.shape[0]

ex_safe_to_send = joined_list.loc[joined_list['RESULT'] != 'Safe to Send'].copy()
ex_safe_to_send.reset_index(drop=True, inplace=True)
count_ex_safe_to_send = ex_safe_to_send.shape[0]

# %%
print("==========================================================")
print("Summary")
print("==========================================================")
print("Jumlah Total Data : "+str(count_total_data))
print("Jumlah Data Contact Empty : "+str(count_empty_contact))
print("Jumlah Data Setelah Wash Empty Contact : "+str(count_empty_contact))
print("Jumlah Data Exist di Database Bounce : "+str(count_exist_in_bounce))
print("Jumlah Data Tidak Exist di Database Bounce : "+str(count_not_exist_in_bounce))
print("==========================================================")
print("Summary Bounced")
print("==========================================================")
print("Jumlah Data Safe to Send : "+str(count_safe_to_send))
print("Jumlah Data not Safe to Send : "+str(count_ex_safe_to_send))
# Out:
# ==========================================================
# Summary
# ==========================================================
# Jumlah Total Data : 260
# Jumlah Data Contact Empty : 0
# Jumlah Data Setelah Wash Empty Contact : 0
# Jumlah Data Exist di Database Bounce : 260
# Jumlah Data Tidak Exist di Database Bounce : 0
# ==========================================================
# Summary Bounced
# ==========================================================
# Jumlah Data Safe to Send : 229
# Jumlah Data not Safe to Send : 31

# %%
not_exist_list.loc[not_exist_list['Email'] == 'mohdasifaliak2016@gmail.com']
# df_1.loc[df_1['EMAIL'] == 'matthew.w.giles@gmail.com']
# df_1.loc[df_1['EMAIL'] == 'venkjaya@gmail.com']
# joined_df.loc[joined_df['RESULT'] == 'Safe to Send']
# df_bounced.loc[df_bounced['EMAIL'] == ]
# Out:
# Empty DataFrame
# Columns: [First Name, Last Name, Email, Phone, Mobile, City, Country, Nationality, Lead Source, Lead Locations, Booking Status, BookRef, EMAIL, RESULT, REASON, STATUS CODE, ROLE, FREE, DOMAIN, Sheet Name]
# Index: []

# %%
joined_df.loc[joined_df['Email'] == 'mohdasifaliak2016@gmail.com']
# Out:
# Empty DataFrame
# Columns: [First Name, Last Name, Email, Phone, Mobile, City, Country, Nationality, Lead Source, Lead Locations, Booking Status, BookRef, EMAIL, RESULT, REASON, STATUS CODE, ROLE, FREE, DOMAIN, Sheet Name]
# Index: []

# %%
safe_to_send.replace('empty', '', inplace=True)
safe_to_send.reset_index(drop=True, inplace=True)
df_safe = safe_to_send.reindex(columns=cols)
df_safe.rename(columns={'Lead Source':'Lead Sources'}, inplace=True)

df_safe.to_csv(r'C:\Users\fajar\Documents\Python\Data\push-pastguest-formatted.csv', index=False, encoding='utf-8')

# %%
ex_safe_to_send.replace('empty', '', inplace=True)
ex_safe_to_send.reset_index(drop=True, inplace=True)
df_ex_safe_to_send = ex_safe_to_send.reindex(columns=cols)
df_ex_safe_to_send

df_ex_safe_to_send.to_excel(r'C:\Users\fajar\Documents\Python\Data\not-safe-to-send-debounce.xlsx', index=False)

# %%
not_exist_list.replace('empty', '', inplace=True)
not_exist_list.reset_index(drop=True, inplace=True)
df_not_exist = not_exist_list.reindex(columns=cols)
df_not_exist

df_not_exist.to_excel(r'C:\Users\fajar\Documents\Python\Data\not-exist-debounce.xlsx', index=False)
