# %%
import pandas as pd
import re
import openpyxl

import sys
sys.path.append('../')

import main_module as m

# %%
cols = ['First Name', 
    'Last Name',
    'Email', 
    'Phone', 
    'Mobile', 
    'City', 
    'Country', 
    'Nationality',
    'Lead Locations', 
    'Booking Status',
    'Lead Source', 
    'BookRef']

# %%
path = r'C:\Users\fajar\Documents\Python\Data\push-pastguest.xlsx'
df_push = pd.read_excel(path, dtype='string', usecols=cols, sheet_name='Sheet0', engine='openpyxl')
df_push.fillna('empty', inplace=True)
count_total_data = df_push.shape[0]
df_push.columns
# Out:
# c:\Users\fajar\Documents\Python\Task Offline\venv12\Lib\site-packages\openpyxl\styles\stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# Index(['First Name', 'Last Name', 'Email', 'Phone', 'Mobile', 'City',
#        'Country', 'Nationality', 'Lead Source', 'Lead Locations',
#        'Booking Status', 'BookRef'],
#       dtype='object')

# %%
df_push
# Out:
#                   First Name    Last Name                        Email  \
# 0              Praveen Kumar            A  praveen_cookie7@hotmail.com
# 1                      Rajat       Mathur           tajarmtr@gmail.com
# 2                     Pramod            R         pramodr800@gmail.com
# 3        Kotni Krishna Kumar        Kumar           remokrim@gmail.com
# 4               Jaya Shankar          M N     jayashankar.mn@gmail.com
# ..                       ...          ...                          ...
# 376                     Maya       Sharma        mayapanthi7@gmail.com
# 377                     Mohd       Shakir    sameeerkhan4428@gmail.com
# 378                 Caroline         Dunn  caroline@carolinedunn.co.uk
# 379  Vijay Kumar Vishwakarma  Vishwakarma           vartak84@gmail.com
# 380                    Bernd       Gönner       info@goenner-dental.de
#
#              Phone         Mobile           City         Country Nationality  \
# 0    +919880009738  +919980300057      BANGALORE           India      Indian
# 1    +919785599554  +917976221755         JAIPUR           India      Indian
# 2    +919916545550  +919513918425      BENGALURU           India      Indian
# 3    +918374122008  +918374873870  VISAKHAPATNAM           India      Indian
# 4    +917204733542  +919538055275      BANGALORE           India      Indian
# ..             ...            ...            ...             ...         ...
# 376  +919035086964  +917406635056      BANGALORE           India      Indian
# 377  +919643835833  +919871700718          DELHI           India      Indian
# 378  +447779137956          empty          empty  United Kingdom     British
# 379  +919930363804  +919224131102         MUMBAI           India      Indian
# 380  +491709618200          empty  Beimerstetten         Germany      German
#
#      Lead Source              Lead Locations Booking Status   BookRef
# 0    Past Guests           Karma Royal Palms    Checked-Out   2575952
# 1    Past Guests  Karma Seven Lakes, Udaipur    Checked-Out   2574108
# 2    Past Guests           Karma Royal Palms    Checked-Out   2535534
# 3    Past Guests           Karma Royal Palms    Checked-Out   2577135
# 4    Past Guests           Karma Royal Palms    Checked-Out   2604176
# ..           ...                         ...            ...       ...
# 376  Past Guests           Karma Royal Palms    Checked-Out   2584983
# 377  Past Guests     Karma Sitabani, Corbett    Checked-Out   2580163
# 378  Past Guests      Karma Lake of Menteith    Checked-Out   2382581
# 379  Past Guests           Karma Royal Palms    Checked-Out   2601244
# 380  Past Guests               Karma Bavaria      CANCELLED  KB043637
#
# [381 rows x 12 columns]

# %%
path = r'C:\Users\fajar\Documents\Python\Data\Debounce\debounce_backup.csv'
df_1 = pd.read_csv(path, dtype='string')

path = r'C:\Users\fajar\Documents\Python\Data\Debounce\debounce_new_temp.csv'
df_2 = pd.read_csv(path, dtype='string')


frames = [df_1, df_2]
df_bounced = pd.concat(frames, ignore_index=True)
df_bounced
# Out:
#                                  EMAIL        RESULT             REASON  \
# 0                00001111den@gmail.com  Safe to Send        Deliverable
# 1        007dhananjaykumbhar@gmail.com  Safe to Send        Deliverable
# 2                      0597396@mail.ru  Safe to Send        Deliverable
# 3                07deepanshu@gmail.com  Safe to Send        Deliverable
# 4                    1078049354@qq.com  Safe to Send        Deliverable
# ...                                ...           ...                ...
# 1259589         tauqiradmani@gmail.com  Safe to Send        Deliverable
# 1259590   indermendiratta168@gmail.com  Safe to Send        Deliverable
# 1259591        nicola_paul@hotmail.com  Safe to Send        Deliverable
# 1259592                   info@kmco.id         Risky  Deliverable, Role
# 1259593              rimjith@gmail.com  Safe to Send        Deliverable
#
#         STATUS CODE   ROLE   FREE     DOMAIN    Sheet Name
# 0                 5     No    Yes  gmail.com  All Campaign
# 1                 5     No    Yes  gmail.com  All Campaign
# 2                 5     No    Yes    mail.ru  All Campaign
# 3                 5     No    Yes  gmail.com  All Campaign
# 4                 5     No    Yes     qq.com  All Campaign
# ...             ...    ...    ...        ...           ...
# 1259589           5  FALSE   TRUE       <NA>          <NA>
# 1259590           5  FALSE   TRUE       <NA>          <NA>
# 1259591           5  FALSE   TRUE       <NA>          <NA>
# 1259592           5   TRUE  FALSE       <NA>          <NA>
# 1259593           5  FALSE   TRUE       <NA>          <NA>
#
# [1259594 rows x 8 columns]

# %%
df_bounced.drop_duplicates(subset='EMAIL', inplace=True)
df_bounced.reset_index(drop=True, inplace=True)
df_bounced
# Out:
#                                  EMAIL        RESULT             REASON  \
# 0                00001111den@gmail.com  Safe to Send        Deliverable
# 1        007dhananjaykumbhar@gmail.com  Safe to Send        Deliverable
# 2                      0597396@mail.ru  Safe to Send        Deliverable
# 3                07deepanshu@gmail.com  Safe to Send        Deliverable
# 4                    1078049354@qq.com  Safe to Send        Deliverable
# ...                                ...           ...                ...
# 1015734         tauqiradmani@gmail.com  Safe to Send        Deliverable
# 1015735   indermendiratta168@gmail.com  Safe to Send        Deliverable
# 1015736        nicola_paul@hotmail.com  Safe to Send        Deliverable
# 1015737                   info@kmco.id         Risky  Deliverable, Role
# 1015738              rimjith@gmail.com  Safe to Send        Deliverable
#
#         STATUS CODE   ROLE   FREE     DOMAIN    Sheet Name
# 0                 5     No    Yes  gmail.com  All Campaign
# 1                 5     No    Yes  gmail.com  All Campaign
# 2                 5     No    Yes    mail.ru  All Campaign
# 3                 5     No    Yes  gmail.com  All Campaign
# 4                 5     No    Yes     qq.com  All Campaign
# ...             ...    ...    ...        ...           ...
# 1015734           5  FALSE   TRUE       <NA>          <NA>
# 1015735           5  FALSE   TRUE       <NA>          <NA>
# 1015736           5  FALSE   TRUE       <NA>          <NA>
# 1015737           5   TRUE  FALSE       <NA>          <NA>
# 1015738           5  FALSE   TRUE       <NA>          <NA>
#
# [1015739 rows x 8 columns]

# %%
df_push['Email'] = m.lowercase(df_push, 'Email')
m.clean_space(df_push, 'Email')

df_bounced['EMAIL'] = m.lowercase(df_bounced, 'EMAIL')
m.clean_space(df_bounced, 'EMAIL')
# Out:
# c:\Users\fajar\Documents\Python\Task Offline\zoho_data_app\zoho_campaign\..\main_module.py:90: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[df_columns].replace(' ','', regex=True, inplace=True)
# 0                  00001111den@gmail.com
# 1          007dhananjaykumbhar@gmail.com
# 2                        0597396@mail.ru
# 3                  07deepanshu@gmail.com
# 4                      1078049354@qq.com
#                        ...
# 1015734           tauqiradmani@gmail.com
# 1015735     indermendiratta168@gmail.com
# 1015736          nicola_paul@hotmail.com
# 1015737                     info@kmco.id
# 1015738                rimjith@gmail.com
# Name: EMAIL, Length: 1015739, dtype: string

# %%
df_push.loc[df_push['Email'].isin(df_bounced['EMAIL'])]
# Out:
#                   First Name    Last Name                        Email  \
# 0              Praveen Kumar            A  praveen_cookie7@hotmail.com
# 1                      Rajat       Mathur           tajarmtr@gmail.com
# 2                     Pramod            R         pramodr800@gmail.com
# 3        Kotni Krishna Kumar        Kumar           remokrim@gmail.com
# 4               Jaya Shankar          M N     jayashankar.mn@gmail.com
# ..                       ...          ...                          ...
# 376                     Maya       Sharma        mayapanthi7@gmail.com
# 377                     Mohd       Shakir    sameeerkhan4428@gmail.com
# 378                 Caroline         Dunn  caroline@carolinedunn.co.uk
# 379  Vijay Kumar Vishwakarma  Vishwakarma           vartak84@gmail.com
# 380                    Bernd       Gönner       info@goenner-dental.de
#
#              Phone         Mobile           City         Country Nationality  \
# 0    +919880009738  +919980300057      BANGALORE           India      Indian
# 1    +919785599554  +917976221755         JAIPUR           India      Indian
# 2    +919916545550  +919513918425      BENGALURU           India      Indian
# 3    +918374122008  +918374873870  VISAKHAPATNAM           India      Indian
# 4    +917204733542  +919538055275      BANGALORE           India      Indian
# ..             ...            ...            ...             ...         ...
# 376  +919035086964  +917406635056      BANGALORE           India      Indian
# 377  +919643835833  +919871700718          DELHI           India      Indian
# 378  +447779137956          empty          empty  United Kingdom     British
# 379  +919930363804  +919224131102         MUMBAI           India      Indian
# 380  +491709618200          empty  Beimerstetten         Germany      German
#
#      Lead Source              Lead Locations Booking Status   BookRef
# 0    Past Guests           Karma Royal Palms    Checked-Out   2575952
# 1    Past Guests  Karma Seven Lakes, Udaipur    Checked-Out   2574108
# 2    Past Guests           Karma Royal Palms    Checked-Out   2535534
# 3    Past Guests           Karma Royal Palms    Checked-Out   2577135
# 4    Past Guests           Karma Royal Palms    Checked-Out   2604176
# ..           ...                         ...            ...       ...
# 376  Past Guests           Karma Royal Palms    Checked-Out   2584983
# 377  Past Guests     Karma Sitabani, Corbett    Checked-Out   2580163
# 378  Past Guests      Karma Lake of Menteith    Checked-Out   2382581
# 379  Past Guests           Karma Royal Palms    Checked-Out   2601244
# 380  Past Guests               Karma Bavaria      CANCELLED  KB043637
#
# [381 rows x 12 columns]

# %%
count_empty_contact = df_push.loc[(df_push['Email'] == 'empty') &
            (df_push['Phone'] == 'empty') &
            (df_push['Mobile'] == 'empty')].shape[0]

df_push.drop(df_push.loc[(df_push['Email'] == 'empty') &
            (df_push['Phone'] == 'empty') &
            (df_push['Mobile'] == 'empty')
            ].index, inplace=True)

count_after_wash_empty_contact = df_push.shape[0]

# %%
# df_bounced.loc[df_bounced['EMAIL'] == 'pawan_chhikara2001@yahoo.com']

# %%
joined_df = pd.merge(df_push,
                     df_bounced,
                     left_on ='Email',
                     right_on ='EMAIL',
                     how ='left')
joined_df
# Out:
#                   First Name    Last Name                        Email  \
# 0              Praveen Kumar            A  praveen_cookie7@hotmail.com
# 1                      Rajat       Mathur           tajarmtr@gmail.com
# 2                     Pramod            R         pramodr800@gmail.com
# 3        Kotni Krishna Kumar        Kumar           remokrim@gmail.com
# 4               Jaya Shankar          M N     jayashankar.mn@gmail.com
# ..                       ...          ...                          ...
# 376                     Maya       Sharma        mayapanthi7@gmail.com
# 377                     Mohd       Shakir    sameeerkhan4428@gmail.com
# 378                 Caroline         Dunn  caroline@carolinedunn.co.uk
# 379  Vijay Kumar Vishwakarma  Vishwakarma           vartak84@gmail.com
# 380                    Bernd       Gönner       info@goenner-dental.de
#
#              Phone         Mobile           City         Country Nationality  \
# 0    +919880009738  +919980300057      BANGALORE           India      Indian
# 1    +919785599554  +917976221755         JAIPUR           India      Indian
# 2    +919916545550  +919513918425      BENGALURU           India      Indian
# 3    +918374122008  +918374873870  VISAKHAPATNAM           India      Indian
# 4    +917204733542  +919538055275      BANGALORE           India      Indian
# ..             ...            ...            ...             ...         ...
# 376  +919035086964  +917406635056      BANGALORE           India      Indian
# 377  +919643835833  +919871700718          DELHI           India      Indian
# 378  +447779137956          empty          empty  United Kingdom     British
# 379  +919930363804  +919224131102         MUMBAI           India      Indian
# 380  +491709618200          empty  Beimerstetten         Germany      German
#
#      Lead Source              Lead Locations Booking Status   BookRef  \
# 0    Past Guests           Karma Royal Palms    Checked-Out   2575952
# 1    Past Guests  Karma Seven Lakes, Udaipur    Checked-Out   2574108
# 2    Past Guests           Karma Royal Palms    Checked-Out   2535534
# 3    Past Guests           Karma Royal Palms    Checked-Out   2577135
# 4    Past Guests           Karma Royal Palms    Checked-Out   2604176
# ..           ...                         ...            ...       ...
# 376  Past Guests           Karma Royal Palms    Checked-Out   2584983
# 377  Past Guests     Karma Sitabani, Corbett    Checked-Out   2580163
# 378  Past Guests      Karma Lake of Menteith    Checked-Out   2382581
# 379  Past Guests           Karma Royal Palms    Checked-Out   2601244
# 380  Past Guests               Karma Bavaria      CANCELLED  KB043637
#
#                            EMAIL        RESULT       REASON STATUS CODE  \
# 0    praveen_cookie7@hotmail.com  Safe to Send  Deliverable           5
# 1             tajarmtr@gmail.com  Safe to Send  Deliverable           5
# 2           pramodr800@gmail.com  Safe to Send  Deliverable           5
# 3             remokrim@gmail.com  Safe to Send  Deliverable           5
# 4       jayashankar.mn@gmail.com  Safe to Send  Deliverable           5
# ..                           ...           ...          ...         ...
# 376        mayapanthi7@gmail.com  Safe to Send  Deliverable           5
# 377    sameeerkhan4428@gmail.com       Invalid       Bounce           6
# 378  caroline@carolinedunn.co.uk  Safe to Send  Deliverable           5
# 379           vartak84@gmail.com  Safe to Send  Deliverable           5
# 380       info@goenner-dental.de       Unknown      Unknown           7
#
#       ROLE   FREE DOMAIN Sheet Name
# 0    FALSE   TRUE   <NA>       <NA>
# 1    FALSE   TRUE   <NA>       <NA>
# 2    FALSE   TRUE   <NA>       <NA>
# 3    FALSE   TRUE   <NA>       <NA>
# 4    FALSE   TRUE   <NA>       <NA>
# ..     ...    ...    ...        ...
# 376  FALSE   TRUE   <NA>       <NA>
# 377  FALSE   TRUE   <NA>       <NA>
# 378  FALSE  FALSE   <NA>       <NA>
# 379  FALSE   TRUE   <NA>       <NA>
# 380   TRUE  FALSE   <NA>       <NA>
#
# [381 rows x 20 columns]

# %%
joined_list = joined_df.loc[~joined_df['RESULT'].isna()].copy()
joined_list.reset_index(drop=True, inplace=True)

not_exist_list = joined_df.loc[joined_df['RESULT'].isna()].copy()
not_exist_list.reset_index(drop=True, inplace=True)

count_exist_in_bounce = joined_list.shape[0]
count_not_exist_in_bounce = not_exist_list.shape[0]

# %%
safe_to_send = joined_list.loc[joined_list['RESULT'] == 'Safe to Send'].copy()
safe_to_send.reset_index(drop=True, inplace=True)
count_safe_to_send = safe_to_send.shape[0]

ex_safe_to_send = joined_list.loc[joined_list['RESULT'] != 'Safe to Send'].copy()
ex_safe_to_send.reset_index(drop=True, inplace=True)
count_ex_safe_to_send = ex_safe_to_send.shape[0]

# %%
print("==========================================================")
print("Summary")
print("==========================================================")
print("Jumlah Total Data : "+str(count_total_data))
print("Jumlah Data Contact Empty : "+str(count_empty_contact))
print("Jumlah Data Setelah Wash Empty Contact : "+str(count_empty_contact))
print("Jumlah Data Exist di Database Bounce : "+str(count_exist_in_bounce))
print("Jumlah Data Tidak Exist di Database Bounce : "+str(count_not_exist_in_bounce))
print("==========================================================")
print("Summary Bounced")
print("==========================================================")
print("Jumlah Data Safe to Send : "+str(count_safe_to_send))
print("Jumlah Data not Safe to Send : "+str(count_ex_safe_to_send))
# Out:
# ==========================================================
# Summary
# ==========================================================
# Jumlah Total Data : 381
# Jumlah Data Contact Empty : 0
# Jumlah Data Setelah Wash Empty Contact : 0
# Jumlah Data Exist di Database Bounce : 381
# Jumlah Data Tidak Exist di Database Bounce : 0
# ==========================================================
# Summary Bounced
# ==========================================================
# Jumlah Data Safe to Send : 338
# Jumlah Data not Safe to Send : 43

# %%
not_exist_list.loc[not_exist_list['Email'] == 'mohdasifaliak2016@gmail.com']
# df_1.loc[df_1['EMAIL'] == 'matthew.w.giles@gmail.com']
# df_1.loc[df_1['EMAIL'] == 'venkjaya@gmail.com']
# joined_df.loc[joined_df['RESULT'] == 'Safe to Send']
# df_bounced.loc[df_bounced['EMAIL'] == ]
# Out:
# Empty DataFrame
# Columns: [First Name, Last Name, Email, Phone, Mobile, City, Country, Nationality, Lead Source, Lead Locations, Booking Status, BookRef, EMAIL, RESULT, REASON, STATUS CODE, ROLE, FREE, DOMAIN, Sheet Name]
# Index: []

# %%
joined_df.loc[joined_df['Email'] == 'mohdasifaliak2016@gmail.com']
# Out:
# Empty DataFrame
# Columns: [First Name, Last Name, Email, Phone, Mobile, City, Country, Nationality, Lead Source, Lead Locations, Booking Status, BookRef, EMAIL, RESULT, REASON, STATUS CODE, ROLE, FREE, DOMAIN, Sheet Name]
# Index: []

# %%
safe_to_send.replace('empty', '', inplace=True)
safe_to_send.reset_index(drop=True, inplace=True)
df_safe = safe_to_send.reindex(columns=cols)
df_safe.rename(columns={'Lead Source':'Lead Sources'}, inplace=True)

df_safe.to_csv(r'C:\Users\fajar\Documents\Python\Data\push-pastguest-formatted.csv', index=False, encoding='utf-8')

# %%
ex_safe_to_send.replace('empty', '', inplace=True)
ex_safe_to_send.reset_index(drop=True, inplace=True)
df_ex_safe_to_send = ex_safe_to_send.reindex(columns=cols)
df_ex_safe_to_send

df_ex_safe_to_send.to_excel(r'C:\Users\fajar\Documents\Python\Data\not-safe-to-send-debounce.xlsx', index=False)

# %%
not_exist_list.replace('empty', '', inplace=True)
not_exist_list.reset_index(drop=True, inplace=True)
df_not_exist = not_exist_list.reindex(columns=cols)
df_not_exist

df_not_exist.to_excel(r'C:\Users\fajar\Documents\Python\Data\not-exist-debounce.xlsx', index=False)
