# %%
import pandas as pd
import re
import openpyxl

import sys
sys.path.append('../')

import main_module as m

# %%
cols = ['First Name', 
    'Last Name',
    'Email', 
    'Phone', 
    'Mobile', 
    'City', 
    'Country', 
    'Nationality',
    'Lead Locations', 
    'Booking Status',
    'Lead Source', 
    'BookRef']

# %%
path = r'C:\Users\fajar\Documents\Python\Data\push-pastguest.xlsx'
df_push = pd.read_excel(path, dtype='string', usecols=cols, sheet_name='Sheet0', engine='openpyxl')
df_push.fillna('empty', inplace=True)
count_total_data = df_push.shape[0]
df_push.columns
# Out:
# c:\Users\fajar\Documents\Python\Task Offline\venv12\Lib\site-packages\openpyxl\styles\stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# Index(['First Name', 'Last Name', 'Email', 'Phone', 'Mobile', 'City',
#        'Country', 'Nationality', 'Lead Source', 'Lead Locations',
#        'Booking Status', 'BookRef'],
#       dtype='object')

# %%
df_push
# Out:
#          First Name   Last Name                          Email          Phone  \
# 0             Kiran       Reddy          kiran.kkr96@gmail.com  +918978991795
# 1          Shailesh      S Modi         smodivijapur@gmail.com  +919429318816
# 2             Vijay       Vohra    luckyenterprise80@gmail.com  +919780781068
# 3            Gaurav  Khandelwal  gaurav28.khandelwal@gmail.com  +919868532474
# 4            Rupali    Aggarwal             rupali08@gmail.com  +919819760438
# ..              ...         ...                            ...            ...
# 284       Mr. Divya        Kant          divyakant10@gmail.com  +917895022141
# 285       Padmanabh      Keskar      keskarpadmanabh@gmail.com  +919762258650
# 286  P S Anand Siva      Sairam           anandram16@gmail.com  +919036510706
# 287           Elena     Lankina                mbk1997@mail.uk   +79175988137
# 288       Ragupathi           K             kirthy.s@gmail.com  +918810302151
#
#             Mobile        City Country Nationality  Lead Source  \
# 0            empty   Hyderabad   India      Indian  Past Guests
# 1    +918780472822     VIJAPUR   India     British  Past Guests
# 2    +917888639303    AMRITSAR   India      Indian  Past Guests
# 3    +918510093010   NEW DELHI   India      Indian  Past Guests
# 4            empty           -   India      Indian  Past Guests
# ..             ...         ...     ...         ...          ...
# 284  +918279725597        AGRA   India      Indian  Past Guests
# 285  +919226731811        PUNE   India      Indian  Past Guests
# 286  +919036516136   BANGALORE   India      Indian  Past Guests
# 287          empty           -  Russia     Russian  Past Guests
# 288  +919625770552  DHARMAPURI   India      Indian  Past Guests
#
#                Lead Locations Booking Status  BookRef
# 0           Karma Royal Palms    Checked-Out  2589616
# 1        Karma Royal Monterio    Checked-Out  2562656
# 2    Karma Royal Haathi Mahal    Checked-Out  2601832
# 3     Karma Sitabani, Corbett    Checked-Out  2572698
# 4    Karma Royal Haathi Mahal    Checked-Out  2548774
# ..                        ...            ...      ...
# 284      Karma Haveli, Jaipur    Checked-Out  2569051
# 285         Karma Royal Palms    Checked-Out  2561366
# 286      Karma Munnar, Kerala    Checked-Out  2461861
# 287            Karma Jimbaran    Checked-Out  2579844
# 288   Karma Sitabani, Corbett    Checked-Out  2534086
#
# [289 rows x 12 columns]

# %%
path = r'C:\Users\fajar\Documents\Python\Data\Debounce\debounce_backup.csv'
df_1 = pd.read_csv(path, dtype='string')

path = r'C:\Users\fajar\Documents\Python\Data\Debounce\debounce_new_temp.csv'
df_2 = pd.read_csv(path, dtype='string')


frames = [df_1, df_2]
df_bounced = pd.concat(frames, ignore_index=True)
df_bounced
# Out:
#                                  EMAIL        RESULT       REASON STATUS CODE  \
# 0                00001111den@gmail.com  Safe to Send  Deliverable           5
# 1        007dhananjaykumbhar@gmail.com  Safe to Send  Deliverable           5
# 2                      0597396@mail.ru  Safe to Send  Deliverable           5
# 3                07deepanshu@gmail.com  Safe to Send  Deliverable           5
# 4                    1078049354@qq.com  Safe to Send  Deliverable           5
# ...                                ...           ...          ...         ...
# 1259196         nitin.wala@hotmail.com  Safe to Send  Deliverable           5
# 1259197     dilipkanjariya68@gmail.com  Safe to Send  Deliverable           5
# 1259198            vikas.jnv@gmail.com  Safe to Send  Deliverable           5
# 1259199          kiran.kkr96@gmail.com  Safe to Send  Deliverable           5
# 1259200         smita.umarji@gmail.com  Safe to Send  Deliverable           5
#
#           ROLE  FREE     DOMAIN    Sheet Name
# 0           No   Yes  gmail.com  All Campaign
# 1           No   Yes  gmail.com  All Campaign
# 2           No   Yes    mail.ru  All Campaign
# 3           No   Yes  gmail.com  All Campaign
# 4           No   Yes     qq.com  All Campaign
# ...        ...   ...        ...           ...
# 1259196  FALSE  TRUE       <NA>          <NA>
# 1259197  FALSE  TRUE       <NA>          <NA>
# 1259198  FALSE  TRUE       <NA>          <NA>
# 1259199  FALSE  TRUE       <NA>          <NA>
# 1259200  FALSE  TRUE       <NA>          <NA>
#
# [1259201 rows x 8 columns]

# %%
df_bounced.drop_duplicates(subset='EMAIL', inplace=True)
df_bounced.reset_index(drop=True, inplace=True)
df_bounced
# Out:
#                                  EMAIL        RESULT       REASON STATUS CODE  \
# 0                00001111den@gmail.com  Safe to Send  Deliverable           5
# 1        007dhananjaykumbhar@gmail.com  Safe to Send  Deliverable           5
# 2                      0597396@mail.ru  Safe to Send  Deliverable           5
# 3                07deepanshu@gmail.com  Safe to Send  Deliverable           5
# 4                    1078049354@qq.com  Safe to Send  Deliverable           5
# ...                                ...           ...          ...         ...
# 1015342         nitin.wala@hotmail.com  Safe to Send  Deliverable           5
# 1015343     dilipkanjariya68@gmail.com  Safe to Send  Deliverable           5
# 1015344            vikas.jnv@gmail.com  Safe to Send  Deliverable           5
# 1015345          kiran.kkr96@gmail.com  Safe to Send  Deliverable           5
# 1015346         smita.umarji@gmail.com  Safe to Send  Deliverable           5
#
#           ROLE  FREE     DOMAIN    Sheet Name
# 0           No   Yes  gmail.com  All Campaign
# 1           No   Yes  gmail.com  All Campaign
# 2           No   Yes    mail.ru  All Campaign
# 3           No   Yes  gmail.com  All Campaign
# 4           No   Yes     qq.com  All Campaign
# ...        ...   ...        ...           ...
# 1015342  FALSE  TRUE       <NA>          <NA>
# 1015343  FALSE  TRUE       <NA>          <NA>
# 1015344  FALSE  TRUE       <NA>          <NA>
# 1015345  FALSE  TRUE       <NA>          <NA>
# 1015346  FALSE  TRUE       <NA>          <NA>
#
# [1015347 rows x 8 columns]

# %%
df_push['Email'] = m.lowercase(df_push, 'Email')
m.clean_space(df_push, 'Email')

df_bounced['EMAIL'] = m.lowercase(df_bounced, 'EMAIL')
m.clean_space(df_bounced, 'EMAIL')
# Out:
# c:\Users\fajar\Documents\Python\Task Offline\zoho_data_app\zoho_campaign\..\main_module.py:90: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[df_columns].replace(' ','', regex=True, inplace=True)
# 0                  00001111den@gmail.com
# 1          007dhananjaykumbhar@gmail.com
# 2                        0597396@mail.ru
# 3                  07deepanshu@gmail.com
# 4                      1078049354@qq.com
#                        ...
# 1015342           nitin.wala@hotmail.com
# 1015343       dilipkanjariya68@gmail.com
# 1015344              vikas.jnv@gmail.com
# 1015345            kiran.kkr96@gmail.com
# 1015346           smita.umarji@gmail.com
# Name: EMAIL, Length: 1015347, dtype: string

# %%
df_push.loc[df_push['Email'].isin(df_bounced['EMAIL'])]
# Out:
#          First Name   Last Name                          Email          Phone  \
# 0             Kiran       Reddy          kiran.kkr96@gmail.com  +918978991795
# 1          Shailesh      S Modi         smodivijapur@gmail.com  +919429318816
# 2             Vijay       Vohra    luckyenterprise80@gmail.com  +919780781068
# 3            Gaurav  Khandelwal  gaurav28.khandelwal@gmail.com  +919868532474
# 4            Rupali    Aggarwal             rupali08@gmail.com  +919819760438
# ..              ...         ...                            ...            ...
# 284       Mr. Divya        Kant          divyakant10@gmail.com  +917895022141
# 285       Padmanabh      Keskar      keskarpadmanabh@gmail.com  +919762258650
# 286  P S Anand Siva      Sairam           anandram16@gmail.com  +919036510706
# 287           Elena     Lankina                mbk1997@mail.uk   +79175988137
# 288       Ragupathi           K             kirthy.s@gmail.com  +918810302151
#
#             Mobile        City Country Nationality  Lead Source  \
# 0            empty   Hyderabad   India      Indian  Past Guests
# 1    +918780472822     VIJAPUR   India     British  Past Guests
# 2    +917888639303    AMRITSAR   India      Indian  Past Guests
# 3    +918510093010   NEW DELHI   India      Indian  Past Guests
# 4            empty           -   India      Indian  Past Guests
# ..             ...         ...     ...         ...          ...
# 284  +918279725597        AGRA   India      Indian  Past Guests
# 285  +919226731811        PUNE   India      Indian  Past Guests
# 286  +919036516136   BANGALORE   India      Indian  Past Guests
# 287          empty           -  Russia     Russian  Past Guests
# 288  +919625770552  DHARMAPURI   India      Indian  Past Guests
#
#                Lead Locations Booking Status  BookRef
# 0           Karma Royal Palms    Checked-Out  2589616
# 1        Karma Royal Monterio    Checked-Out  2562656
# 2    Karma Royal Haathi Mahal    Checked-Out  2601832
# 3     Karma Sitabani, Corbett    Checked-Out  2572698
# 4    Karma Royal Haathi Mahal    Checked-Out  2548774
# ..                        ...            ...      ...
# 284      Karma Haveli, Jaipur    Checked-Out  2569051
# 285         Karma Royal Palms    Checked-Out  2561366
# 286      Karma Munnar, Kerala    Checked-Out  2461861
# 287            Karma Jimbaran    Checked-Out  2579844
# 288   Karma Sitabani, Corbett    Checked-Out  2534086
#
# [289 rows x 12 columns]

# %%
count_empty_contact = df_push.loc[(df_push['Email'] == 'empty') &
            (df_push['Phone'] == 'empty') &
            (df_push['Mobile'] == 'empty')].shape[0]

df_push.drop(df_push.loc[(df_push['Email'] == 'empty') &
            (df_push['Phone'] == 'empty') &
            (df_push['Mobile'] == 'empty')
            ].index, inplace=True)

count_after_wash_empty_contact = df_push.shape[0]

# %%
# df_bounced.loc[df_bounced['EMAIL'] == 'pawan_chhikara2001@yahoo.com']

# %%
joined_df = pd.merge(df_push,
                     df_bounced,
                     left_on ='Email',
                     right_on ='EMAIL',
                     how ='left')
joined_df
# Out:
#          First Name   Last Name                          Email          Phone  \
# 0             Kiran       Reddy          kiran.kkr96@gmail.com  +918978991795
# 1          Shailesh      S Modi         smodivijapur@gmail.com  +919429318816
# 2             Vijay       Vohra    luckyenterprise80@gmail.com  +919780781068
# 3            Gaurav  Khandelwal  gaurav28.khandelwal@gmail.com  +919868532474
# 4            Rupali    Aggarwal             rupali08@gmail.com  +919819760438
# ..              ...         ...                            ...            ...
# 284       Mr. Divya        Kant          divyakant10@gmail.com  +917895022141
# 285       Padmanabh      Keskar      keskarpadmanabh@gmail.com  +919762258650
# 286  P S Anand Siva      Sairam           anandram16@gmail.com  +919036510706
# 287           Elena     Lankina                mbk1997@mail.uk   +79175988137
# 288       Ragupathi           K             kirthy.s@gmail.com  +918810302151
#
#             Mobile        City Country Nationality  Lead Source  \
# 0            empty   Hyderabad   India      Indian  Past Guests
# 1    +918780472822     VIJAPUR   India     British  Past Guests
# 2    +917888639303    AMRITSAR   India      Indian  Past Guests
# 3    +918510093010   NEW DELHI   India      Indian  Past Guests
# 4            empty           -   India      Indian  Past Guests
# ..             ...         ...     ...         ...          ...
# 284  +918279725597        AGRA   India      Indian  Past Guests
# 285  +919226731811        PUNE   India      Indian  Past Guests
# 286  +919036516136   BANGALORE   India      Indian  Past Guests
# 287          empty           -  Russia     Russian  Past Guests
# 288  +919625770552  DHARMAPURI   India      Indian  Past Guests
#
#                Lead Locations Booking Status  BookRef  \
# 0           Karma Royal Palms    Checked-Out  2589616
# 1        Karma Royal Monterio    Checked-Out  2562656
# 2    Karma Royal Haathi Mahal    Checked-Out  2601832
# 3     Karma Sitabani, Corbett    Checked-Out  2572698
# 4    Karma Royal Haathi Mahal    Checked-Out  2548774
# ..                        ...            ...      ...
# 284      Karma Haveli, Jaipur    Checked-Out  2569051
# 285         Karma Royal Palms    Checked-Out  2561366
# 286      Karma Munnar, Kerala    Checked-Out  2461861
# 287            Karma Jimbaran    Checked-Out  2579844
# 288   Karma Sitabani, Corbett    Checked-Out  2534086
#
#                              EMAIL        RESULT       REASON STATUS CODE  \
# 0            kiran.kkr96@gmail.com  Safe to Send  Deliverable           5
# 1           smodivijapur@gmail.com  Safe to Send  Deliverable           5
# 2      luckyenterprise80@gmail.com  Safe to Send  Deliverable           5
# 3    gaurav28.khandelwal@gmail.com  Safe to Send  Deliverable           5
# 4               rupali08@gmail.com  Safe to Send  Deliverable           5
# ..                             ...           ...          ...         ...
# 284          divyakant10@gmail.com  Safe to Send  Deliverable           5
# 285      keskarpadmanabh@gmail.com  Safe to Send  Deliverable           5
# 286           anandram16@gmail.com  Safe to Send  Deliverable           5
# 287                mbk1997@mail.uk       Invalid       Bounce           6
# 288             kirthy.s@gmail.com  Safe to Send  Deliverable           5
#
#       ROLE   FREE DOMAIN Sheet Name
# 0    FALSE   TRUE   <NA>       <NA>
# 1    FALSE   TRUE   <NA>       <NA>
# 2    FALSE   TRUE   <NA>       <NA>
# 3    FALSE   TRUE   <NA>       <NA>
# 4    FALSE   TRUE   <NA>       <NA>
# ..     ...    ...    ...        ...
# 284  FALSE   TRUE   <NA>       <NA>
# 285  FALSE   TRUE   <NA>       <NA>
# 286  FALSE   TRUE   <NA>       <NA>
# 287  FALSE  FALSE   <NA>       <NA>
# 288  FALSE   TRUE   <NA>       <NA>
#
# [289 rows x 20 columns]

# %%
joined_list = joined_df.loc[~joined_df['RESULT'].isna()].copy()
joined_list.reset_index(drop=True, inplace=True)

not_exist_list = joined_df.loc[joined_df['RESULT'].isna()].copy()
not_exist_list.reset_index(drop=True, inplace=True)

count_exist_in_bounce = joined_list.shape[0]
count_not_exist_in_bounce = not_exist_list.shape[0]

# %%
safe_to_send = joined_list.loc[joined_list['RESULT'] == 'Safe to Send'].copy()
safe_to_send.reset_index(drop=True, inplace=True)
count_safe_to_send = safe_to_send.shape[0]

ex_safe_to_send = joined_list.loc[joined_list['RESULT'] != 'Safe to Send'].copy()
ex_safe_to_send.reset_index(drop=True, inplace=True)
count_ex_safe_to_send = ex_safe_to_send.shape[0]

# %%
print("==========================================================")
print("Summary")
print("==========================================================")
print("Jumlah Total Data : "+str(count_total_data))
print("Jumlah Data Contact Empty : "+str(count_empty_contact))
print("Jumlah Data Setelah Wash Empty Contact : "+str(count_empty_contact))
print("Jumlah Data Exist di Database Bounce : "+str(count_exist_in_bounce))
print("Jumlah Data Tidak Exist di Database Bounce : "+str(count_not_exist_in_bounce))
print("==========================================================")
print("Summary Bounced")
print("==========================================================")
print("Jumlah Data Safe to Send : "+str(count_safe_to_send))
print("Jumlah Data not Safe to Send : "+str(count_ex_safe_to_send))
# Out:
# ==========================================================
# Summary
# ==========================================================
# Jumlah Total Data : 289
# Jumlah Data Contact Empty : 0
# Jumlah Data Setelah Wash Empty Contact : 0
# Jumlah Data Exist di Database Bounce : 289
# Jumlah Data Tidak Exist di Database Bounce : 0
# ==========================================================
# Summary Bounced
# ==========================================================
# Jumlah Data Safe to Send : 250
# Jumlah Data not Safe to Send : 39

# %%
not_exist_list.loc[not_exist_list['Email'] == 'mohdasifaliak2016@gmail.com']
# df_1.loc[df_1['EMAIL'] == 'matthew.w.giles@gmail.com']
# df_1.loc[df_1['EMAIL'] == 'venkjaya@gmail.com']
# joined_df.loc[joined_df['RESULT'] == 'Safe to Send']
# df_bounced.loc[df_bounced['EMAIL'] == ]
# Out:
# Empty DataFrame
# Columns: [First Name, Last Name, Email, Phone, Mobile, City, Country, Nationality, Lead Source, Lead Locations, Booking Status, BookRef, EMAIL, RESULT, REASON, STATUS CODE, ROLE, FREE, DOMAIN, Sheet Name]
# Index: []

# %%
joined_df.loc[joined_df['Email'] == 'mohdasifaliak2016@gmail.com']
# Out:
# Empty DataFrame
# Columns: [First Name, Last Name, Email, Phone, Mobile, City, Country, Nationality, Lead Source, Lead Locations, Booking Status, BookRef, EMAIL, RESULT, REASON, STATUS CODE, ROLE, FREE, DOMAIN, Sheet Name]
# Index: []

# %%
safe_to_send.replace('empty', '', inplace=True)
safe_to_send.reset_index(drop=True, inplace=True)
df_safe = safe_to_send.reindex(columns=cols)
df_safe.rename(columns={'Lead Source':'Lead Sources'}, inplace=True)

df_safe.to_csv(r'C:\Users\fajar\Documents\Python\Data\push-pastguest-formatted.csv', index=False, encoding='utf-8')

# %%
ex_safe_to_send.replace('empty', '', inplace=True)
ex_safe_to_send.reset_index(drop=True, inplace=True)
df_ex_safe_to_send = ex_safe_to_send.reindex(columns=cols)
df_ex_safe_to_send

df_ex_safe_to_send.to_excel(r'C:\Users\fajar\Documents\Python\Data\not-safe-to-send-debounce.xlsx', index=False)

# %%
not_exist_list.replace('empty', '', inplace=True)
not_exist_list.reset_index(drop=True, inplace=True)
df_not_exist = not_exist_list.reindex(columns=cols)
df_not_exist

df_not_exist.to_excel(r'C:\Users\fajar\Documents\Python\Data\not-exist-debounce.xlsx', index=False)
