# %%
import pandas as pd
import re
import openpyxl

import sys
sys.path.append('../')

import main_module as m

# %%
cols = ['First Name', 
    'Last Name',
    'Email', 
    'Phone', 
    'Mobile', 
    'City', 
    'State',
    'Country', 
    'Nationality',
    'Lead Locations', 
    'Booking Status',
    'Lead Source', 
    'BookRef']

# %%
path = r'C:\Users\fajar\Documents\Python\Data\push-pastguest.xlsx'
df_push = pd.read_excel(path, dtype='string', usecols=cols, sheet_name='Sheet0', engine='openpyxl')
df_push.fillna('empty', inplace=True)
count_total_data = df_push.shape[0]
df_push.columns
# Out:
# c:\Users\fajar\Documents\Python\Task Offline\venv12\Lib\site-packages\openpyxl\styles\stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# Index(['First Name', 'Last Name', 'Email', 'Phone', 'Mobile', 'City', 'State',
#        'Country', 'Nationality', 'Lead Source', 'Lead Locations',
#        'Booking Status', 'BookRef'],
#       dtype='object')

# %%
df_push
# Out:
#          First Name    Last Name                          Email  \
# 0         Veerendra           Hv           v.tulasi86@gmail.com
# 1         Brightson  Christopher        brightson1311@gmail.com
# 2             Samir       Shinde      samirshinde2804@gmail.com
# 3         Dr Mahesh    Bilapatte      maheshbilapatte@yahoo.com
# 4            Nikita        Singh            ns9266455@gmail.com
# ..              ...          ...                            ...
# 402  Kristian James         Drew       krisdrew2002@yahoo.co.uk
# 403          Sonali        Thora         sonalithora1@gmail.com
# 404       Friedrich       Byloff            byloff@byloff.co.at
# 405       Francesca     Williams  frankie.alexandra@outlook.com
# 406          Svenja        Blaha            svenja.blaha@gmx.de
#
#               Phone         Mobile           City           State  \
# 0     +919108363425  +919880034239      BANGALORE       KARNATAKA
# 1     +919008076076  +919840496076  THIRUVALLUVAR      TAMIL NADU
# 2     +918689816222  +918425980052     -BANGALORE      -KARNATAKA
# 3     +919822551227  +912382227007          LATUR     MAHARASHTRA
# 4     +918766348247          empty      AHMEDABAD         Gujarat
# ..              ...            ...            ...             ...
# 402  +6281237558965          empty              -               -
# 403   +918719815067          empty         Indore  Madhya Pradesh
# 404   +436763020457  +436763020457           Graz           empty
# 405   +447305850215  +447305850215   Witney, Oxon           empty
# 406  +4917697740508          empty         Erbach           empty
#
#                     Country Nationality  Lead Source           Lead Locations  \
# 0                     India      Indian  Past Guests        Karma Royal Palms
# 1                     India      Indian  Past Guests        Karma Royal Palms
# 2                     India      Indian  Past Guests        Karma Royal Palms
# 3                     India      Indian  Past Guests        Karma Royal Palms
# 4                     India      Indian  Past Guests  Karma Sitabani, Corbett
# ..                      ...         ...          ...                      ...
# 402  British Virgin Islands     British  Past Guests           Karma Jimbaran
# 403                   India      Indian  Past Guests     Karma Royal Monterio
# 404                 Austria     British  Past Guests         Karma St Martins
# 405          United Kingdom     British  Past Guests       Karma Salford Hall
# 406                 Germany      German  Past Guests            Karma Bavaria
#
#     Booking Status    BookRef
# 0      Checked-Out    2626417
# 1      Checked-Out    2630343
# 2      Checked-Out    2612669
# 3      Checked-Out    2609384
# 4      Checked-Out    2644484
# ..             ...        ...
# 402    Checked-Out    2621810
# 403    Checked-Out    2572025
# 404    Checked-Out  KSM013596
# 405    Checked-Out  KSH016947
# 406    Checked-Out   KB041615
#
# [407 rows x 13 columns]

# %%
path = r'C:\Users\fajar\Documents\Python\Data\Debounce\debounce_backup.csv'
df_1 = pd.read_csv(path, dtype='string')

path = r'C:\Users\fajar\Documents\Python\Data\Debounce\debounce_new_temp.csv'
df_2 = pd.read_csv(path, dtype='string')


frames = [df_1, df_2]
df_bounced = pd.concat(frames, ignore_index=True)
df_bounced
# Out:
#                                     EMAIL        RESULT       REASON  \
# 0                   00001111den@gmail.com  Safe to Send  Deliverable
# 1           007dhananjaykumbhar@gmail.com  Safe to Send  Deliverable
# 2                         0597396@mail.ru  Safe to Send  Deliverable
# 3                   07deepanshu@gmail.com  Safe to Send  Deliverable
# 4                       1078049354@qq.com  Safe to Send  Deliverable
# ...                                   ...           ...          ...
# 1261464             dilip.jawan@gmail.com  Safe to Send  Deliverable
# 1261465          vinodboricha66@gmail.com  Safe to Send  Deliverable
# 1261466            sengar.ajay1@gmail.com  Safe to Send  Deliverable
# 1261467          ph.scheuringer@gmail.com  Safe to Send  Deliverable
# 1261468  prashant.harapanahalli@gmail.com  Safe to Send  Deliverable
#
#         STATUS CODE   ROLE  FREE     DOMAIN    Sheet Name
# 0                 5     No   Yes  gmail.com  All Campaign
# 1                 5     No   Yes  gmail.com  All Campaign
# 2                 5     No   Yes    mail.ru  All Campaign
# 3                 5     No   Yes  gmail.com  All Campaign
# 4                 5     No   Yes     qq.com  All Campaign
# ...             ...    ...   ...        ...           ...
# 1261464           5  FALSE  TRUE       <NA>          <NA>
# 1261465           5  FALSE  TRUE       <NA>          <NA>
# 1261466           5  FALSE  TRUE       <NA>          <NA>
# 1261467           5  FALSE  TRUE       <NA>          <NA>
# 1261468           5  FALSE  TRUE       <NA>          <NA>
#
# [1261469 rows x 8 columns]

# %%
df_bounced.drop_duplicates(subset='EMAIL', inplace=True)
df_bounced.reset_index(drop=True, inplace=True)
df_bounced
# Out:
#                                     EMAIL        RESULT       REASON  \
# 0                   00001111den@gmail.com  Safe to Send  Deliverable
# 1           007dhananjaykumbhar@gmail.com  Safe to Send  Deliverable
# 2                         0597396@mail.ru  Safe to Send  Deliverable
# 3                   07deepanshu@gmail.com  Safe to Send  Deliverable
# 4                       1078049354@qq.com  Safe to Send  Deliverable
# ...                                   ...           ...          ...
# 1017441         gayle.davie1006@gmail.com  Safe to Send  Deliverable
# 1017442        mandeepdhillon29@gmail.com  Safe to Send  Deliverable
# 1017443            anand_k@rediffmail.com  Safe to Send  Deliverable
# 1017444          ph.scheuringer@gmail.com  Safe to Send  Deliverable
# 1017445  prashant.harapanahalli@gmail.com  Safe to Send  Deliverable
#
#         STATUS CODE   ROLE  FREE     DOMAIN    Sheet Name
# 0                 5     No   Yes  gmail.com  All Campaign
# 1                 5     No   Yes  gmail.com  All Campaign
# 2                 5     No   Yes    mail.ru  All Campaign
# 3                 5     No   Yes  gmail.com  All Campaign
# 4                 5     No   Yes     qq.com  All Campaign
# ...             ...    ...   ...        ...           ...
# 1017441           5  FALSE  TRUE       <NA>          <NA>
# 1017442           5  FALSE  TRUE       <NA>          <NA>
# 1017443           5  FALSE  TRUE       <NA>          <NA>
# 1017444           5  FALSE  TRUE       <NA>          <NA>
# 1017445           5  FALSE  TRUE       <NA>          <NA>
#
# [1017446 rows x 8 columns]

# %%
df_push['Email'] = m.lowercase(df_push, 'Email')
m.clean_space(df_push, 'Email')

df_bounced['EMAIL'] = m.lowercase(df_bounced, 'EMAIL')
m.clean_space(df_bounced, 'EMAIL')
# Out:
# c:\Users\fajar\Documents\Python\Task Offline\zoho_data_app\zoho_campaign\..\main_module.py:90: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[df_columns].replace(' ','', regex=True, inplace=True)
# 0                     00001111den@gmail.com
# 1             007dhananjaykumbhar@gmail.com
# 2                           0597396@mail.ru
# 3                     07deepanshu@gmail.com
# 4                         1078049354@qq.com
#                          ...
# 1017441           gayle.davie1006@gmail.com
# 1017442          mandeepdhillon29@gmail.com
# 1017443              anand_k@rediffmail.com
# 1017444            ph.scheuringer@gmail.com
# 1017445    prashant.harapanahalli@gmail.com
# Name: EMAIL, Length: 1017446, dtype: string

# %%
df_push.loc[df_push['Email'].isin(df_bounced['EMAIL'])]
# Out:
#          First Name    Last Name                          Email  \
# 0         Veerendra           Hv           v.tulasi86@gmail.com
# 1         Brightson  Christopher        brightson1311@gmail.com
# 2             Samir       Shinde      samirshinde2804@gmail.com
# 3         Dr Mahesh    Bilapatte      maheshbilapatte@yahoo.com
# 4            Nikita        Singh            ns9266455@gmail.com
# ..              ...          ...                            ...
# 402  Kristian James         Drew       krisdrew2002@yahoo.co.uk
# 403          Sonali        Thora         sonalithora1@gmail.com
# 404       Friedrich       Byloff            byloff@byloff.co.at
# 405       Francesca     Williams  frankie.alexandra@outlook.com
# 406          Svenja        Blaha            svenja.blaha@gmx.de
#
#               Phone         Mobile           City           State  \
# 0     +919108363425  +919880034239      BANGALORE       KARNATAKA
# 1     +919008076076  +919840496076  THIRUVALLUVAR      TAMIL NADU
# 2     +918689816222  +918425980052     -BANGALORE      -KARNATAKA
# 3     +919822551227  +912382227007          LATUR     MAHARASHTRA
# 4     +918766348247          empty      AHMEDABAD         Gujarat
# ..              ...            ...            ...             ...
# 402  +6281237558965          empty              -               -
# 403   +918719815067          empty         Indore  Madhya Pradesh
# 404   +436763020457  +436763020457           Graz           empty
# 405   +447305850215  +447305850215   Witney, Oxon           empty
# 406  +4917697740508          empty         Erbach           empty
#
#                     Country Nationality  Lead Source           Lead Locations  \
# 0                     India      Indian  Past Guests        Karma Royal Palms
# 1                     India      Indian  Past Guests        Karma Royal Palms
# 2                     India      Indian  Past Guests        Karma Royal Palms
# 3                     India      Indian  Past Guests        Karma Royal Palms
# 4                     India      Indian  Past Guests  Karma Sitabani, Corbett
# ..                      ...         ...          ...                      ...
# 402  British Virgin Islands     British  Past Guests           Karma Jimbaran
# 403                   India      Indian  Past Guests     Karma Royal Monterio
# 404                 Austria     British  Past Guests         Karma St Martins
# 405          United Kingdom     British  Past Guests       Karma Salford Hall
# 406                 Germany      German  Past Guests            Karma Bavaria
#
#     Booking Status    BookRef
# 0      Checked-Out    2626417
# 1      Checked-Out    2630343
# 2      Checked-Out    2612669
# 3      Checked-Out    2609384
# 4      Checked-Out    2644484
# ..             ...        ...
# 402    Checked-Out    2621810
# 403    Checked-Out    2572025
# 404    Checked-Out  KSM013596
# 405    Checked-Out  KSH016947
# 406    Checked-Out   KB041615
#
# [407 rows x 13 columns]

# %%
count_empty_contact = df_push.loc[(df_push['Email'] == 'empty') &
            (df_push['Phone'] == 'empty') &
            (df_push['Mobile'] == 'empty')].shape[0]

df_push.drop(df_push.loc[(df_push['Email'] == 'empty') &
            (df_push['Phone'] == 'empty') &
            (df_push['Mobile'] == 'empty')
            ].index, inplace=True)

count_after_wash_empty_contact = df_push.shape[0]

# %%
# df_bounced.loc[df_bounced['EMAIL'] == 'pawan_chhikara2001@yahoo.com']

# %%
joined_df = pd.merge(df_push,
                     df_bounced,
                     left_on ='Email',
                     right_on ='EMAIL',
                     how ='left')
joined_df
# Out:
#          First Name    Last Name                          Email  \
# 0         Veerendra           Hv           v.tulasi86@gmail.com
# 1         Brightson  Christopher        brightson1311@gmail.com
# 2             Samir       Shinde      samirshinde2804@gmail.com
# 3         Dr Mahesh    Bilapatte      maheshbilapatte@yahoo.com
# 4            Nikita        Singh            ns9266455@gmail.com
# ..              ...          ...                            ...
# 402  Kristian James         Drew       krisdrew2002@yahoo.co.uk
# 403          Sonali        Thora         sonalithora1@gmail.com
# 404       Friedrich       Byloff            byloff@byloff.co.at
# 405       Francesca     Williams  frankie.alexandra@outlook.com
# 406          Svenja        Blaha            svenja.blaha@gmx.de
#
#               Phone         Mobile           City           State  \
# 0     +919108363425  +919880034239      BANGALORE       KARNATAKA
# 1     +919008076076  +919840496076  THIRUVALLUVAR      TAMIL NADU
# 2     +918689816222  +918425980052     -BANGALORE      -KARNATAKA
# 3     +919822551227  +912382227007          LATUR     MAHARASHTRA
# 4     +918766348247          empty      AHMEDABAD         Gujarat
# ..              ...            ...            ...             ...
# 402  +6281237558965          empty              -               -
# 403   +918719815067          empty         Indore  Madhya Pradesh
# 404   +436763020457  +436763020457           Graz           empty
# 405   +447305850215  +447305850215   Witney, Oxon           empty
# 406  +4917697740508          empty         Erbach           empty
#
#                     Country Nationality  Lead Source  ... Booking Status  \
# 0                     India      Indian  Past Guests  ...    Checked-Out
# 1                     India      Indian  Past Guests  ...    Checked-Out
# 2                     India      Indian  Past Guests  ...    Checked-Out
# 3                     India      Indian  Past Guests  ...    Checked-Out
# 4                     India      Indian  Past Guests  ...    Checked-Out
# ..                      ...         ...          ...  ...            ...
# 402  British Virgin Islands     British  Past Guests  ...    Checked-Out
# 403                   India      Indian  Past Guests  ...    Checked-Out
# 404                 Austria     British  Past Guests  ...    Checked-Out
# 405          United Kingdom     British  Past Guests  ...    Checked-Out
# 406                 Germany      German  Past Guests  ...    Checked-Out
#
#        BookRef                          EMAIL        RESULT       REASON  \
# 0      2626417           v.tulasi86@gmail.com  Safe to Send  Deliverable
# 1      2630343        brightson1311@gmail.com  Safe to Send  Deliverable
# 2      2612669      samirshinde2804@gmail.com  Safe to Send  Deliverable
# 3      2609384      maheshbilapatte@yahoo.com  Safe to Send  Deliverable
# 4      2644484            ns9266455@gmail.com  Safe to Send  Deliverable
# ..         ...                            ...           ...          ...
# 402    2621810       krisdrew2002@yahoo.co.uk  Safe to Send  Deliverable
# 403    2572025         sonalithora1@gmail.com  Safe to Send  Deliverable
# 404  KSM013596            byloff@byloff.co.at       Invalid       Bounce
# 405  KSH016947  frankie.alexandra@outlook.com  Safe to Send  Deliverable
# 406   KB041615            svenja.blaha@gmx.de       Unknown  Unreachable
#
#     STATUS CODE   ROLE   FREE DOMAIN Sheet Name
# 0             5  FALSE   TRUE   <NA>       <NA>
# 1             5  FALSE   TRUE   <NA>       <NA>
# 2             5  FALSE   TRUE   <NA>       <NA>
# 3             5  FALSE   TRUE   <NA>       <NA>
# 4             5  FALSE   TRUE   <NA>       <NA>
# ..          ...    ...    ...    ...        ...
# 402           5  FALSE   TRUE   <NA>       <NA>
# 403           5  FALSE   TRUE   <NA>       <NA>
# 404           6  FALSE  FALSE   <NA>       <NA>
# 405           5  FALSE   TRUE   <NA>       <NA>
# 406           7  FALSE   TRUE   <NA>       <NA>
#
# [407 rows x 21 columns]

# %%
joined_list = joined_df.loc[~joined_df['RESULT'].isna()].copy()
joined_list.reset_index(drop=True, inplace=True)

not_exist_list = joined_df.loc[joined_df['RESULT'].isna()].copy()
not_exist_list.reset_index(drop=True, inplace=True)

count_exist_in_bounce = joined_list.shape[0]
count_not_exist_in_bounce = not_exist_list.shape[0]

# %%
safe_to_send = joined_list.loc[joined_list['RESULT'] == 'Safe to Send'].copy()
safe_to_send.reset_index(drop=True, inplace=True)
count_safe_to_send = safe_to_send.shape[0]

ex_safe_to_send = joined_list.loc[joined_list['RESULT'] != 'Safe to Send'].copy()
ex_safe_to_send.reset_index(drop=True, inplace=True)
count_ex_safe_to_send = ex_safe_to_send.shape[0]

# %%
print("==========================================================")
print("Summary")
print("==========================================================")
print("Jumlah Total Data : "+str(count_total_data))
print("Jumlah Data Contact Empty : "+str(count_empty_contact))
print("Jumlah Data Setelah Wash Empty Contact : "+str(count_empty_contact))
print("Jumlah Data Exist di Database Bounce : "+str(count_exist_in_bounce))
print("Jumlah Data Tidak Exist di Database Bounce : "+str(count_not_exist_in_bounce))
print("==========================================================")
print("Summary Bounced")
print("==========================================================")
print("Jumlah Data Safe to Send : "+str(count_safe_to_send))
print("Jumlah Data not Safe to Send : "+str(count_ex_safe_to_send))
# Out:
# ==========================================================
# Summary
# ==========================================================
# Jumlah Total Data : 407
# Jumlah Data Contact Empty : 0
# Jumlah Data Setelah Wash Empty Contact : 0
# Jumlah Data Exist di Database Bounce : 407
# Jumlah Data Tidak Exist di Database Bounce : 0
# ==========================================================
# Summary Bounced
# ==========================================================
# Jumlah Data Safe to Send : 363
# Jumlah Data not Safe to Send : 44

# %%
not_exist_list.loc[not_exist_list['Email'] == 'mohdasifaliak2016@gmail.com']
# df_1.loc[df_1['EMAIL'] == 'matthew.w.giles@gmail.com']
# df_1.loc[df_1['EMAIL'] == 'venkjaya@gmail.com']
# joined_df.loc[joined_df['RESULT'] == 'Safe to Send']
# df_bounced.loc[df_bounced['EMAIL'] == ]
# Out:
# Empty DataFrame
# Columns: [First Name, Last Name, Email, Phone, Mobile, City, State, Country, Nationality, Lead Source, Lead Locations, Booking Status, BookRef, EMAIL, RESULT, REASON, STATUS CODE, ROLE, FREE, DOMAIN, Sheet Name]
# Index: []
#
# [0 rows x 21 columns]

# %%
joined_df.loc[joined_df['Email'] == 'mohdasifaliak2016@gmail.com']
# Out:
# Empty DataFrame
# Columns: [First Name, Last Name, Email, Phone, Mobile, City, State, Country, Nationality, Lead Source, Lead Locations, Booking Status, BookRef, EMAIL, RESULT, REASON, STATUS CODE, ROLE, FREE, DOMAIN, Sheet Name]
# Index: []
#
# [0 rows x 21 columns]

# %%
safe_to_send.replace('empty', '', inplace=True)
safe_to_send.reset_index(drop=True, inplace=True)
df_safe = safe_to_send.reindex(columns=cols)
df_safe.rename(columns={'Lead Source':'Lead Sources'}, inplace=True)

df_safe.to_csv(r'C:\Users\fajar\Documents\Python\Data\push-pastguest-formatted.csv', index=False, encoding='utf-8')

# %%
ex_safe_to_send.replace('empty', '', inplace=True)
ex_safe_to_send.reset_index(drop=True, inplace=True)
df_ex_safe_to_send = ex_safe_to_send.reindex(columns=cols)
df_ex_safe_to_send

df_ex_safe_to_send.to_excel(r'C:\Users\fajar\Documents\Python\Data\not-safe-to-send-debounce.xlsx', index=False)

# %%
not_exist_list.replace('empty', '', inplace=True)
not_exist_list.reset_index(drop=True, inplace=True)
df_not_exist = not_exist_list.reindex(columns=cols)
df_not_exist

df_not_exist.to_excel(r'C:\Users\fajar\Documents\Python\Data\not-exist-debounce.xlsx', index=False)
