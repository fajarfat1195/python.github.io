# %%
import pandas as pd
import re
import openpyxl

import sys
sys.path.append('../')

import main_module as m

# %%
cols = ['First Name', 
    'Last Name',
    'Email', 
    'Phone', 
    'Mobile', 
    'City', 
    'Country', 
    'Nationality',
    'Lead Locations', 
    'Booking Status',
    'Lead Source', 
    'BookRef']

# %%
path = r'C:\Users\fajar\Documents\Python\Data\push-pastguest.xlsx'
df_push = pd.read_excel(path, dtype='string', usecols=cols, sheet_name='Sheet0', engine='openpyxl')
df_push.fillna('empty', inplace=True)
count_total_data = df_push.shape[0]
df_push.columns
# Out:
# c:\Users\fajar\Documents\Python\Task Offline\venv12\Lib\site-packages\openpyxl\styles\stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# Index(['First Name', 'Last Name', 'Email', 'Phone', 'Mobile', 'City',
#        'Country', 'Nationality', 'Lead Source', 'Lead Locations',
#        'Booking Status', 'BookRef'],
#       dtype='object')

# %%
df_push
# Out:
#           First Name Last Name                             Email  \
# 0         Ajay Singh    Sengar            sengar.ajay1@gmail.com
# 1            Abhinav    Sharma        abhinavsharma989@gmail.com
# 2           Yogesh K   Vispute         yogeshg.vispute@gmail.com
# 3    Chinmaya Phatak  Kulkarni  aditya.kulkarni.151989@gmail.com
# 4              Nitin   Khuller           nitin.khuller@gmail.com
# ..               ...       ...                               ...
# 450          Fabiana     Rizzi         rizzi.fabiana89@gmail.com
# 451         Angelika  Sklarzik            a_sklarzik@hotmail.com
# 452             Phil    Carter               pudde1201@yahoo.com
# 453            Debra    Dutton              debs.d1207@gmail.com
# 454              Joy   Morning         jimmorning@btinternet.com
#
#               Phone          Mobile              City         Country  \
# 0     +919987510895   +919967640167       NAVI MUMBAI           India
# 1     +919953933747           empty                 .           India
# 2     +919510939494   +919737701122          SILVASSA           India
# 3     +918689860248   +919049885681              Pune           India
# 4     +919833983418           empty            MUMBAI           India
# ..              ...             ...               ...             ...
# 450   +393275456067   +393275456067             .Roma           Italy
# 451  +4917698285569  +4917698285569  Unterschleißheim         Germany
# 452    +16618103398           empty             empty  United Kingdom
# 453   +447790452740   +447790442740        Hednesford  United Kingdom
# 454     +4443239196           empty            Slough  United Kingdom
#
#     Nationality  Lead Source                           Lead Locations  \
# 0        Indian  Past Guests                        Karma Royal Palms
# 1        Indian  Past Guests  KRR @ Karma Kandara, Mentari Residences
# 2        Indian  Past Guests                 Karma Royal Haathi Mahal
# 3        Indian  Past Guests                 Karma Royal Haathi Mahal
# 4        Indian  Past Guests                        Karma Royal Palms
# ..          ...          ...                                      ...
# 450     British  Past Guests                   Karma Lake of Menteith
# 451      German  Past Guests                            Karma Bavaria
# 452    American  Past Guests                            Karma Kandara
# 453     British  Past Guests                         Karma St Martins
# 454       empty  Past Guests                         Karma St Martins
#
#     Booking Status    BookRef
# 0      Checked-Out    2619148
# 1      Checked-Out    2622413
# 2      Checked-Out    2638473
# 3      Checked-Out    2638158
# 4      Checked-Out    2619861
# ..             ...        ...
# 450    Checked-Out  KLM006628
# 451    Checked-Out   KB040469
# 452    Checked-Out   KK055175
# 453    Checked-Out  KSM010908
# 454    Checked-Out  KSM011827
#
# [455 rows x 12 columns]

# %%
path = r'C:\Users\fajar\Documents\Python\Data\Debounce\debounce_backup.csv'
df_1 = pd.read_csv(path, dtype='string')

path = r'C:\Users\fajar\Documents\Python\Data\Debounce\debounce_new_temp.csv'
df_2 = pd.read_csv(path, dtype='string')


frames = [df_1, df_2]
df_bounced = pd.concat(frames, ignore_index=True)
df_bounced
# Out:
#                                  EMAIL        RESULT       REASON STATUS CODE  \
# 0                00001111den@gmail.com  Safe to Send  Deliverable           5
# 1        007dhananjaykumbhar@gmail.com  Safe to Send  Deliverable           5
# 2                      0597396@mail.ru  Safe to Send  Deliverable           5
# 3                07deepanshu@gmail.com  Safe to Send  Deliverable           5
# 4                    1078049354@qq.com  Safe to Send  Deliverable           5
# ...                                ...           ...          ...         ...
# 1260979       sunil.patole77@gmail.com  Safe to Send  Deliverable           5
# 1260980              in.sree@gmail.com  Safe to Send  Deliverable           5
# 1260981          dilip.jawan@gmail.com  Safe to Send  Deliverable           5
# 1260982       vinodboricha66@gmail.com  Safe to Send  Deliverable           5
# 1260983         sengar.ajay1@gmail.com  Safe to Send  Deliverable           5
#
#           ROLE  FREE     DOMAIN    Sheet Name
# 0           No   Yes  gmail.com  All Campaign
# 1           No   Yes  gmail.com  All Campaign
# 2           No   Yes    mail.ru  All Campaign
# 3           No   Yes  gmail.com  All Campaign
# 4           No   Yes     qq.com  All Campaign
# ...        ...   ...        ...           ...
# 1260979  FALSE  TRUE       <NA>          <NA>
# 1260980  FALSE  TRUE       <NA>          <NA>
# 1260981  FALSE  TRUE       <NA>          <NA>
# 1260982  FALSE  TRUE       <NA>          <NA>
# 1260983  FALSE  TRUE       <NA>          <NA>
#
# [1260984 rows x 8 columns]

# %%
df_bounced.drop_duplicates(subset='EMAIL', inplace=True)
df_bounced.reset_index(drop=True, inplace=True)
df_bounced
# Out:
#                                  EMAIL        RESULT       REASON STATUS CODE  \
# 0                00001111den@gmail.com  Safe to Send  Deliverable           5
# 1        007dhananjaykumbhar@gmail.com  Safe to Send  Deliverable           5
# 2                      0597396@mail.ru  Safe to Send  Deliverable           5
# 3                07deepanshu@gmail.com  Safe to Send  Deliverable           5
# 4                    1078049354@qq.com  Safe to Send  Deliverable           5
# ...                                ...           ...          ...         ...
# 1017022       sunil.patole77@gmail.com  Safe to Send  Deliverable           5
# 1017023              in.sree@gmail.com  Safe to Send  Deliverable           5
# 1017024          dilip.jawan@gmail.com  Safe to Send  Deliverable           5
# 1017025       vinodboricha66@gmail.com  Safe to Send  Deliverable           5
# 1017026         sengar.ajay1@gmail.com  Safe to Send  Deliverable           5
#
#           ROLE  FREE     DOMAIN    Sheet Name
# 0           No   Yes  gmail.com  All Campaign
# 1           No   Yes  gmail.com  All Campaign
# 2           No   Yes    mail.ru  All Campaign
# 3           No   Yes  gmail.com  All Campaign
# 4           No   Yes     qq.com  All Campaign
# ...        ...   ...        ...           ...
# 1017022  FALSE  TRUE       <NA>          <NA>
# 1017023  FALSE  TRUE       <NA>          <NA>
# 1017024  FALSE  TRUE       <NA>          <NA>
# 1017025  FALSE  TRUE       <NA>          <NA>
# 1017026  FALSE  TRUE       <NA>          <NA>
#
# [1017027 rows x 8 columns]

# %%
df_push['Email'] = m.lowercase(df_push, 'Email')
m.clean_space(df_push, 'Email')

df_bounced['EMAIL'] = m.lowercase(df_bounced, 'EMAIL')
m.clean_space(df_bounced, 'EMAIL')
# Out:
# c:\Users\fajar\Documents\Python\Task Offline\zoho_data_app\zoho_campaign\..\main_module.py:90: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[df_columns].replace(' ','', regex=True, inplace=True)
# 0                  00001111den@gmail.com
# 1          007dhananjaykumbhar@gmail.com
# 2                        0597396@mail.ru
# 3                  07deepanshu@gmail.com
# 4                      1078049354@qq.com
#                        ...
# 1017022         sunil.patole77@gmail.com
# 1017023                in.sree@gmail.com
# 1017024            dilip.jawan@gmail.com
# 1017025         vinodboricha66@gmail.com
# 1017026           sengar.ajay1@gmail.com
# Name: EMAIL, Length: 1017027, dtype: string

# %%
df_push.loc[df_push['Email'].isin(df_bounced['EMAIL'])]
# Out:
#           First Name Last Name                             Email  \
# 0         Ajay Singh    Sengar            sengar.ajay1@gmail.com
# 1            Abhinav    Sharma        abhinavsharma989@gmail.com
# 2           Yogesh K   Vispute         yogeshg.vispute@gmail.com
# 3    Chinmaya Phatak  Kulkarni  aditya.kulkarni.151989@gmail.com
# 4              Nitin   Khuller           nitin.khuller@gmail.com
# ..               ...       ...                               ...
# 450          Fabiana     Rizzi         rizzi.fabiana89@gmail.com
# 451         Angelika  Sklarzik            a_sklarzik@hotmail.com
# 452             Phil    Carter               pudde1201@yahoo.com
# 453            Debra    Dutton              debs.d1207@gmail.com
# 454              Joy   Morning         jimmorning@btinternet.com
#
#               Phone          Mobile              City         Country  \
# 0     +919987510895   +919967640167       NAVI MUMBAI           India
# 1     +919953933747           empty                 .           India
# 2     +919510939494   +919737701122          SILVASSA           India
# 3     +918689860248   +919049885681              Pune           India
# 4     +919833983418           empty            MUMBAI           India
# ..              ...             ...               ...             ...
# 450   +393275456067   +393275456067             .Roma           Italy
# 451  +4917698285569  +4917698285569  Unterschleißheim         Germany
# 452    +16618103398           empty             empty  United Kingdom
# 453   +447790452740   +447790442740        Hednesford  United Kingdom
# 454     +4443239196           empty            Slough  United Kingdom
#
#     Nationality  Lead Source                           Lead Locations  \
# 0        Indian  Past Guests                        Karma Royal Palms
# 1        Indian  Past Guests  KRR @ Karma Kandara, Mentari Residences
# 2        Indian  Past Guests                 Karma Royal Haathi Mahal
# 3        Indian  Past Guests                 Karma Royal Haathi Mahal
# 4        Indian  Past Guests                        Karma Royal Palms
# ..          ...          ...                                      ...
# 450     British  Past Guests                   Karma Lake of Menteith
# 451      German  Past Guests                            Karma Bavaria
# 452    American  Past Guests                            Karma Kandara
# 453     British  Past Guests                         Karma St Martins
# 454       empty  Past Guests                         Karma St Martins
#
#     Booking Status    BookRef
# 0      Checked-Out    2619148
# 1      Checked-Out    2622413
# 2      Checked-Out    2638473
# 3      Checked-Out    2638158
# 4      Checked-Out    2619861
# ..             ...        ...
# 450    Checked-Out  KLM006628
# 451    Checked-Out   KB040469
# 452    Checked-Out   KK055175
# 453    Checked-Out  KSM010908
# 454    Checked-Out  KSM011827
#
# [454 rows x 12 columns]

# %%
count_empty_contact = df_push.loc[(df_push['Email'] == 'empty') &
            (df_push['Phone'] == 'empty') &
            (df_push['Mobile'] == 'empty')].shape[0]

df_push.drop(df_push.loc[(df_push['Email'] == 'empty') &
            (df_push['Phone'] == 'empty') &
            (df_push['Mobile'] == 'empty')
            ].index, inplace=True)

count_after_wash_empty_contact = df_push.shape[0]

# %%
# df_bounced.loc[df_bounced['EMAIL'] == 'pawan_chhikara2001@yahoo.com']

# %%
joined_df = pd.merge(df_push,
                     df_bounced,
                     left_on ='Email',
                     right_on ='EMAIL',
                     how ='left')
joined_df
# Out:
#           First Name Last Name                             Email  \
# 0         Ajay Singh    Sengar            sengar.ajay1@gmail.com
# 1            Abhinav    Sharma        abhinavsharma989@gmail.com
# 2           Yogesh K   Vispute         yogeshg.vispute@gmail.com
# 3    Chinmaya Phatak  Kulkarni  aditya.kulkarni.151989@gmail.com
# 4              Nitin   Khuller           nitin.khuller@gmail.com
# ..               ...       ...                               ...
# 450          Fabiana     Rizzi         rizzi.fabiana89@gmail.com
# 451         Angelika  Sklarzik            a_sklarzik@hotmail.com
# 452             Phil    Carter               pudde1201@yahoo.com
# 453            Debra    Dutton              debs.d1207@gmail.com
# 454              Joy   Morning         jimmorning@btinternet.com
#
#               Phone          Mobile              City         Country  \
# 0     +919987510895   +919967640167       NAVI MUMBAI           India
# 1     +919953933747           empty                 .           India
# 2     +919510939494   +919737701122          SILVASSA           India
# 3     +918689860248   +919049885681              Pune           India
# 4     +919833983418           empty            MUMBAI           India
# ..              ...             ...               ...             ...
# 450   +393275456067   +393275456067             .Roma           Italy
# 451  +4917698285569  +4917698285569  Unterschleißheim         Germany
# 452    +16618103398           empty             empty  United Kingdom
# 453   +447790452740   +447790442740        Hednesford  United Kingdom
# 454     +4443239196           empty            Slough  United Kingdom
#
#     Nationality  Lead Source                           Lead Locations  \
# 0        Indian  Past Guests                        Karma Royal Palms
# 1        Indian  Past Guests  KRR @ Karma Kandara, Mentari Residences
# 2        Indian  Past Guests                 Karma Royal Haathi Mahal
# 3        Indian  Past Guests                 Karma Royal Haathi Mahal
# 4        Indian  Past Guests                        Karma Royal Palms
# ..          ...          ...                                      ...
# 450     British  Past Guests                   Karma Lake of Menteith
# 451      German  Past Guests                            Karma Bavaria
# 452    American  Past Guests                            Karma Kandara
# 453     British  Past Guests                         Karma St Martins
# 454       empty  Past Guests                         Karma St Martins
#
#     Booking Status    BookRef                             EMAIL        RESULT  \
# 0      Checked-Out    2619148            sengar.ajay1@gmail.com  Safe to Send
# 1      Checked-Out    2622413        abhinavsharma989@gmail.com  Safe to Send
# 2      Checked-Out    2638473         yogeshg.vispute@gmail.com  Safe to Send
# 3      Checked-Out    2638158  aditya.kulkarni.151989@gmail.com  Safe to Send
# 4      Checked-Out    2619861           nitin.khuller@gmail.com  Safe to Send
# ..             ...        ...                               ...           ...
# 450    Checked-Out  KLM006628         rizzi.fabiana89@gmail.com  Safe to Send
# 451    Checked-Out   KB040469            a_sklarzik@hotmail.com  Safe to Send
# 452    Checked-Out   KK055175               pudde1201@yahoo.com       Invalid
# 453    Checked-Out  KSM010908              debs.d1207@gmail.com  Safe to Send
# 454    Checked-Out  KSM011827         jimmorning@btinternet.com  Safe to Send
#
#           REASON STATUS CODE   ROLE  FREE DOMAIN Sheet Name
# 0    Deliverable           5  FALSE  TRUE   <NA>       <NA>
# 1    Deliverable           5  FALSE  TRUE   <NA>       <NA>
# 2    Deliverable           5  FALSE  TRUE   <NA>       <NA>
# 3    Deliverable           5  FALSE  TRUE   <NA>       <NA>
# 4    Deliverable           5  FALSE  TRUE   <NA>       <NA>
# ..           ...         ...    ...   ...    ...        ...
# 450  Deliverable           5  FALSE  TRUE   <NA>       <NA>
# 451  Deliverable           5  FALSE  TRUE   <NA>       <NA>
# 452       Bounce           6  FALSE  TRUE   <NA>       <NA>
# 453  Deliverable           5  FALSE  TRUE   <NA>       <NA>
# 454  Deliverable           5  FALSE  TRUE   <NA>       <NA>
#
# [455 rows x 20 columns]

# %%
joined_list = joined_df.loc[~joined_df['RESULT'].isna()].copy()
joined_list.reset_index(drop=True, inplace=True)

not_exist_list = joined_df.loc[joined_df['RESULT'].isna()].copy()
not_exist_list.reset_index(drop=True, inplace=True)

count_exist_in_bounce = joined_list.shape[0]
count_not_exist_in_bounce = not_exist_list.shape[0]

# %%
safe_to_send = joined_list.loc[joined_list['RESULT'] == 'Safe to Send'].copy()
safe_to_send.reset_index(drop=True, inplace=True)
count_safe_to_send = safe_to_send.shape[0]

ex_safe_to_send = joined_list.loc[joined_list['RESULT'] != 'Safe to Send'].copy()
ex_safe_to_send.reset_index(drop=True, inplace=True)
count_ex_safe_to_send = ex_safe_to_send.shape[0]

# %%
print("==========================================================")
print("Summary")
print("==========================================================")
print("Jumlah Total Data : "+str(count_total_data))
print("Jumlah Data Contact Empty : "+str(count_empty_contact))
print("Jumlah Data Setelah Wash Empty Contact : "+str(count_empty_contact))
print("Jumlah Data Exist di Database Bounce : "+str(count_exist_in_bounce))
print("Jumlah Data Tidak Exist di Database Bounce : "+str(count_not_exist_in_bounce))
print("==========================================================")
print("Summary Bounced")
print("==========================================================")
print("Jumlah Data Safe to Send : "+str(count_safe_to_send))
print("Jumlah Data not Safe to Send : "+str(count_ex_safe_to_send))
# Out:
# ==========================================================
# Summary
# ==========================================================
# Jumlah Total Data : 455
# Jumlah Data Contact Empty : 0
# Jumlah Data Setelah Wash Empty Contact : 0
# Jumlah Data Exist di Database Bounce : 454
# Jumlah Data Tidak Exist di Database Bounce : 1
# ==========================================================
# Summary Bounced
# ==========================================================
# Jumlah Data Safe to Send : 380
# Jumlah Data not Safe to Send : 74

# %%
not_exist_list.loc[not_exist_list['Email'] == 'mohdasifaliak2016@gmail.com']
# df_1.loc[df_1['EMAIL'] == 'matthew.w.giles@gmail.com']
# df_1.loc[df_1['EMAIL'] == 'venkjaya@gmail.com']
# joined_df.loc[joined_df['RESULT'] == 'Safe to Send']
# df_bounced.loc[df_bounced['EMAIL'] == ]
# Out:
# Empty DataFrame
# Columns: [First Name, Last Name, Email, Phone, Mobile, City, Country, Nationality, Lead Source, Lead Locations, Booking Status, BookRef, EMAIL, RESULT, REASON, STATUS CODE, ROLE, FREE, DOMAIN, Sheet Name]
# Index: []

# %%
joined_df.loc[joined_df['Email'] == 'mohdasifaliak2016@gmail.com']
# Out:
# Empty DataFrame
# Columns: [First Name, Last Name, Email, Phone, Mobile, City, Country, Nationality, Lead Source, Lead Locations, Booking Status, BookRef, EMAIL, RESULT, REASON, STATUS CODE, ROLE, FREE, DOMAIN, Sheet Name]
# Index: []

# %%
safe_to_send.replace('empty', '', inplace=True)
safe_to_send.reset_index(drop=True, inplace=True)
df_safe = safe_to_send.reindex(columns=cols)
df_safe.rename(columns={'Lead Source':'Lead Sources'}, inplace=True)

df_safe.to_csv(r'C:\Users\fajar\Documents\Python\Data\push-pastguest-formatted.csv', index=False, encoding='utf-8')

# %%
ex_safe_to_send.replace('empty', '', inplace=True)
ex_safe_to_send.reset_index(drop=True, inplace=True)
df_ex_safe_to_send = ex_safe_to_send.reindex(columns=cols)
df_ex_safe_to_send

df_ex_safe_to_send.to_excel(r'C:\Users\fajar\Documents\Python\Data\not-safe-to-send-debounce.xlsx', index=False)

# %%
not_exist_list.replace('empty', '', inplace=True)
not_exist_list.reset_index(drop=True, inplace=True)
df_not_exist = not_exist_list.reindex(columns=cols)
df_not_exist

df_not_exist.to_excel(r'C:\Users\fajar\Documents\Python\Data\not-exist-debounce.xlsx', index=False)
