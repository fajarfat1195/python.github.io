# %%
import pandas as pd
import re
import openpyxl

import sys
sys.path.append('../')

import main_module as m

# %%
cols = ['First Name', 
    'Last Name',
    'Email', 
    'Phone', 
    'Mobile', 
    'City', 
    'State',
    'Country', 
    'Nationality',
    'Lead Locations', 
    'Booking Status',
    'Lead Source', 
    'BookRef']

# %%
path = r'C:\Users\fajar\Documents\Python\Data\push-pastguest.xlsx'
df_push = pd.read_excel(path, dtype='string', usecols=cols, sheet_name='Sheet0', engine='openpyxl')
df_push.fillna('empty', inplace=True)
count_total_data = df_push.shape[0]
df_push.columns
# Out:
# Index(['First Name', 'Last Name', 'Email', 'Phone', 'Mobile', 'City', 'State',
#        'Country', 'Nationality', 'Lead Source', 'Lead Locations',
#        'Booking Status', 'BookRef'],
#       dtype='object')

# %%
df_push
# Out:
#          First Name Last Name                        Email           Phone  \
# 0      George De La      Cour          dlc_fea@yahoo.co.uk    +85295280927
# 1             Karan    Dhawan         ravina2394@gmail.com   +918700153609
# 2    Mandar Prakash     Bhatt     bhattmandar444@gmail.com   +919975289309
# 3             Vikas   Chandok           vik.4151@ymail.com   +917986322727
# 4              Aman    Madaan       amanmadaan80@gmail.com   +919971235785
# ..              ...       ...                          ...             ...
# 616  Devesh Prakash  Vaishnav  devesh_vaishnav@hotmail.com   +919480036806
# 617     Nazir Ahmed    Hullur           nihullur@gmail.com   +919481126428
# 618            Toby   Edwards       theangler37@icloud.com   +441620614347
# 619    Marie Louise     Garms            mlgarms@gmail.com  +4917623555095
# 620            Jack    Weller         jack.weller@live.com   +642108410947
#
#             Mobile         City        State         Country Nationality  \
# 0            empty    Hong Kong            -       Hong Kong     British
# 1    +919582557870  UTTAM NAGAR    NEW DELHI           India      Indian
# 2    +918007566870        THANE  MAHARASHTRA           India      Indian
# 3    +919888504151     AMRITSAR       PUNJAB           India      Indian
# 4    +919910152793        DELHI    NEW DELHI           India      Indian
# ..             ...          ...          ...             ...         ...
# 616  +918105563291    BANGALORE    KARNATAKA           India      Indian
# 617  +918762835448        HUBLI    KARNATAKA           India      Indian
# 618  +441620614347        empty        empty  United Kingdom     British
# 619          empty     Parsdorf        empty         Germany      German
# 620          empty     Auckland        empty     New Zealand       empty
#
#      Lead Source                           Lead Locations Booking Status  \
# 0    Past Guests  KRR @ Karma Kandara, Mentari Residences    Checked-Out
# 1    Past Guests                     Karma Utopia, Manali    Checked-Out
# 2    Past Guests                        Karma Royal Palms    Checked-Out
# 3    Past Guests                     Karma Utopia, Manali    Checked-Out
# 4    Past Guests                  Karma Sitabani, Corbett    Checked-Out
# ..           ...                                      ...            ...
# 616  Past Guests                        Karma Royal Palms    Checked-Out
# 617  Past Guests                        Karma Royal Palms    Checked-Out
# 618  Past Guests                   Karma Lake of Menteith      CANCELLED
# 619  Past Guests                            Karma Bavaria      CANCELLED
# 620  Past Guests                            Karma Kandara      CANCELLED
#
#        BookRef
# 0      2690917
# 1      2688152
# 2      2679450
# 3      2690027
# 4      2686600
# ..         ...
# 616    2657413
# 617    2674520
# 618  KLM006246
# 619   KB044110
# 620   KK064104
#
# [621 rows x 13 columns]

# %%
path = r'C:\Users\fajar\Documents\Python\Data\Debounce\debounce_backup.csv'
df_1 = pd.read_csv(path, dtype='string')

path = r'C:\Users\fajar\Documents\Python\Data\Debounce\debounce_new_temp.csv'
df_2 = pd.read_csv(path, dtype='string')


frames = [df_1, df_2]
df_bounced = pd.concat(frames, ignore_index=True)
df_bounced
# Out:
#                                  EMAIL        RESULT           REASON  \
# 0                00001111den@gmail.com  Safe to Send      Deliverable
# 1        007dhananjaykumbhar@gmail.com  Safe to Send      Deliverable
# 2                      0597396@mail.ru  Safe to Send      Deliverable
# 3                07deepanshu@gmail.com  Safe to Send      Deliverable
# 4                    1078049354@qq.com  Safe to Send      Deliverable
# ...                                ...           ...              ...
# 1266206         amanmadaan80@gmail.com       Invalid  HandShacke Fail
# 1266207             vik.4151@ymail.com       Invalid  HandShacke Fail
# 1266208       bhattmandar444@gmail.com       Invalid  HandShacke Fail
# 1266209           ravina2394@gmail.com       Invalid  HandShacke Fail
# 1266210            dlc_fea@yahoo.co.uk       Invalid  HandShacke Fail
#
#         STATUS CODE   ROLE   FREE     DOMAIN    Sheet Name
# 0                 5     No    Yes  gmail.com  All Campaign
# 1                 5     No    Yes  gmail.com  All Campaign
# 2                 5     No    Yes    mail.ru  All Campaign
# 3                 5     No    Yes  gmail.com  All Campaign
# 4                 5     No    Yes     qq.com  All Campaign
# ...             ...    ...    ...        ...           ...
# 1266206          10  false  false       <NA>          <NA>
# 1266207          10  false  false       <NA>          <NA>
# 1266208          10  false  false       <NA>          <NA>
# 1266209          10  false  false       <NA>          <NA>
# 1266210          10  false  false       <NA>          <NA>
#
# [1266211 rows x 8 columns]

# %%
df_bounced.drop_duplicates(subset='EMAIL', inplace=True)
df_bounced.reset_index(drop=True, inplace=True)
df_bounced
# Out:
#                                  EMAIL        RESULT           REASON  \
# 0                00001111den@gmail.com  Safe to Send      Deliverable
# 1        007dhananjaykumbhar@gmail.com  Safe to Send      Deliverable
# 2                      0597396@mail.ru  Safe to Send      Deliverable
# 3                07deepanshu@gmail.com  Safe to Send      Deliverable
# 4                    1078049354@qq.com  Safe to Send      Deliverable
# ...                                ...           ...              ...
# 1020076         amanmadaan80@gmail.com       Invalid  HandShacke Fail
# 1020077             vik.4151@ymail.com       Invalid  HandShacke Fail
# 1020078       bhattmandar444@gmail.com       Invalid  HandShacke Fail
# 1020079           ravina2394@gmail.com       Invalid  HandShacke Fail
# 1020080            dlc_fea@yahoo.co.uk       Invalid  HandShacke Fail
#
#         STATUS CODE   ROLE   FREE     DOMAIN    Sheet Name
# 0                 5     No    Yes  gmail.com  All Campaign
# 1                 5     No    Yes  gmail.com  All Campaign
# 2                 5     No    Yes    mail.ru  All Campaign
# 3                 5     No    Yes  gmail.com  All Campaign
# 4                 5     No    Yes     qq.com  All Campaign
# ...             ...    ...    ...        ...           ...
# 1020076          10  false  false       <NA>          <NA>
# 1020077          10  false  false       <NA>          <NA>
# 1020078          10  false  false       <NA>          <NA>
# 1020079          10  false  false       <NA>          <NA>
# 1020080          10  false  false       <NA>          <NA>
#
# [1020081 rows x 8 columns]

# %%
df_push['Email'] = m.lowercase(df_push, 'Email')
m.clean_space(df_push, 'Email')

df_bounced['EMAIL'] = m.lowercase(df_bounced, 'EMAIL')
m.clean_space(df_bounced, 'EMAIL')
# Out:
# c:\Users\fajar\Documents\Python\Task Offline\zoho_data_app\zoho_campaign\..\main_module.py:90: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[df_columns].replace(' ','', regex=True, inplace=True)
# 0                  00001111den@gmail.com
# 1          007dhananjaykumbhar@gmail.com
# 2                        0597396@mail.ru
# 3                  07deepanshu@gmail.com
# 4                      1078049354@qq.com
#                        ...
# 1020076           amanmadaan80@gmail.com
# 1020077               vik.4151@ymail.com
# 1020078         bhattmandar444@gmail.com
# 1020079             ravina2394@gmail.com
# 1020080              dlc_fea@yahoo.co.uk
# Name: EMAIL, Length: 1020081, dtype: string

# %%
df_push.loc[df_push['Email'].isin(df_bounced['EMAIL'])]
# Out:
#           First Name Last Name                        Email          Phone  \
# 0       George De La      Cour          dlc_fea@yahoo.co.uk   +85295280927
# 1              Karan    Dhawan         ravina2394@gmail.com  +918700153609
# 2     Mandar Prakash     Bhatt     bhattmandar444@gmail.com  +919975289309
# 3              Vikas   Chandok           vik.4151@ymail.com  +917986322727
# 4               Aman    Madaan       amanmadaan80@gmail.com  +919971235785
# ..               ...       ...                          ...            ...
# 614          Manoj K     Bhise       krushnai2012@gmail.com  +919822232888
# 615  Ramandeep Singh  Kaberwal      ramandeep6682@gmail.com  +919987439662
# 616   Devesh Prakash  Vaishnav  devesh_vaishnav@hotmail.com  +919480036806
# 617      Nazir Ahmed    Hullur           nihullur@gmail.com  +919481126428
# 620             Jack    Weller         jack.weller@live.com  +642108410947
#
#             Mobile         City        State      Country Nationality  \
# 0            empty    Hong Kong            -    Hong Kong     British
# 1    +919582557870  UTTAM NAGAR    NEW DELHI        India      Indian
# 2    +918007566870        THANE  MAHARASHTRA        India      Indian
# 3    +919888504151     AMRITSAR       PUNJAB        India      Indian
# 4    +919910152793        DELHI    NEW DELHI        India      Indian
# ..             ...          ...          ...          ...         ...
# 614  +918208698844       NAGPUR  MAHARASHTRA        India      Indian
# 615  +919619621313       MUMBAI  MAHARASHTRA        India      Indian
# 616  +918105563291    BANGALORE    KARNATAKA        India      Indian
# 617  +918762835448        HUBLI    KARNATAKA        India      Indian
# 620          empty     Auckland        empty  New Zealand       empty
#
#      Lead Source                           Lead Locations Booking Status  \
# 0    Past Guests  KRR @ Karma Kandara, Mentari Residences    Checked-Out
# 1    Past Guests                     Karma Utopia, Manali    Checked-Out
# 2    Past Guests                        Karma Royal Palms    Checked-Out
# 3    Past Guests                     Karma Utopia, Manali    Checked-Out
# 4    Past Guests                  Karma Sitabani, Corbett    Checked-Out
# ..           ...                                      ...            ...
# 614  Past Guests                        Karma Royal Palms    Checked-Out
# 615  Past Guests                     Karma Utopia, Manali    Checked-Out
# 616  Past Guests                        Karma Royal Palms    Checked-Out
# 617  Past Guests                        Karma Royal Palms    Checked-Out
# 620  Past Guests                            Karma Kandara      CANCELLED
#
#       BookRef
# 0     2690917
# 1     2688152
# 2     2679450
# 3     2690027
# 4     2686600
# ..        ...
# 614   2675596
# 615   2544976
# 616   2657413
# 617   2674520
# 620  KK064104
#
# [619 rows x 13 columns]

# %%
count_empty_contact = df_push.loc[(df_push['Email'] == 'empty') &
            (df_push['Phone'] == 'empty') &
            (df_push['Mobile'] == 'empty')].shape[0]

df_push.drop(df_push.loc[(df_push['Email'] == 'empty') &
            (df_push['Phone'] == 'empty') &
            (df_push['Mobile'] == 'empty')
            ].index, inplace=True)

count_after_wash_empty_contact = df_push.shape[0]

# %%
# df_bounced.loc[df_bounced['EMAIL'] == 'pawan_chhikara2001@yahoo.com']

# %%
joined_df = pd.merge(df_push,
                     df_bounced,
                     left_on ='Email',
                     right_on ='EMAIL',
                     how ='left')
joined_df
# Out:
#          First Name Last Name                        Email           Phone  \
# 0      George De La      Cour          dlc_fea@yahoo.co.uk    +85295280927
# 1             Karan    Dhawan         ravina2394@gmail.com   +918700153609
# 2    Mandar Prakash     Bhatt     bhattmandar444@gmail.com   +919975289309
# 3             Vikas   Chandok           vik.4151@ymail.com   +917986322727
# 4              Aman    Madaan       amanmadaan80@gmail.com   +919971235785
# ..              ...       ...                          ...             ...
# 616  Devesh Prakash  Vaishnav  devesh_vaishnav@hotmail.com   +919480036806
# 617     Nazir Ahmed    Hullur           nihullur@gmail.com   +919481126428
# 618            Toby   Edwards       theangler37@icloud.com   +441620614347
# 619    Marie Louise     Garms            mlgarms@gmail.com  +4917623555095
# 620            Jack    Weller         jack.weller@live.com   +642108410947
#
#             Mobile         City        State         Country Nationality  \
# 0            empty    Hong Kong            -       Hong Kong     British
# 1    +919582557870  UTTAM NAGAR    NEW DELHI           India      Indian
# 2    +918007566870        THANE  MAHARASHTRA           India      Indian
# 3    +919888504151     AMRITSAR       PUNJAB           India      Indian
# 4    +919910152793        DELHI    NEW DELHI           India      Indian
# ..             ...          ...          ...             ...         ...
# 616  +918105563291    BANGALORE    KARNATAKA           India      Indian
# 617  +918762835448        HUBLI    KARNATAKA           India      Indian
# 618  +441620614347        empty        empty  United Kingdom     British
# 619          empty     Parsdorf        empty         Germany      German
# 620          empty     Auckland        empty     New Zealand       empty
#
#      Lead Source  ... Booking Status    BookRef                        EMAIL  \
# 0    Past Guests  ...    Checked-Out    2690917          dlc_fea@yahoo.co.uk
# 1    Past Guests  ...    Checked-Out    2688152         ravina2394@gmail.com
# 2    Past Guests  ...    Checked-Out    2679450     bhattmandar444@gmail.com
# 3    Past Guests  ...    Checked-Out    2690027           vik.4151@ymail.com
# 4    Past Guests  ...    Checked-Out    2686600       amanmadaan80@gmail.com
# ..           ...  ...            ...        ...                          ...
# 616  Past Guests  ...    Checked-Out    2657413  devesh_vaishnav@hotmail.com
# 617  Past Guests  ...    Checked-Out    2674520           nihullur@gmail.com
# 618  Past Guests  ...      CANCELLED  KLM006246                         <NA>
# 619  Past Guests  ...      CANCELLED   KB044110                         <NA>
# 620  Past Guests  ...      CANCELLED   KK064104         jack.weller@live.com
#
#            RESULT           REASON STATUS CODE   ROLE   FREE DOMAIN  \
# 0         Invalid  HandShacke Fail          10  false  false   <NA>
# 1         Invalid  HandShacke Fail          10  false  false   <NA>
# 2         Invalid  HandShacke Fail          10  false  false   <NA>
# 3         Invalid  HandShacke Fail          10  false  false   <NA>
# 4         Invalid  HandShacke Fail          10  false  false   <NA>
# ..            ...              ...         ...    ...    ...    ...
# 616  Safe to Send      Deliverable           5  False   True   <NA>
# 617  Safe to Send      Deliverable           5  False   True   <NA>
# 618          <NA>             <NA>        <NA>   <NA>   <NA>   <NA>
# 619          <NA>             <NA>        <NA>   <NA>   <NA>   <NA>
# 620  Safe to Send      Deliverable           5  False   True   <NA>
#
#      Sheet Name
# 0          <NA>
# 1          <NA>
# 2          <NA>
# 3          <NA>
# 4          <NA>
# ..          ...
# 616  Past Guest
# 617  Past Guest
# 618        <NA>
# 619        <NA>
# 620  Past Guest
#
# [621 rows x 21 columns]

# %%
joined_list = joined_df.loc[~joined_df['RESULT'].isna()].copy()
joined_list.reset_index(drop=True, inplace=True)

not_exist_list = joined_df.loc[joined_df['RESULT'].isna()].copy()
not_exist_list.reset_index(drop=True, inplace=True)

count_exist_in_bounce = joined_list.shape[0]
count_not_exist_in_bounce = not_exist_list.shape[0]

# %%
safe_to_send = joined_list.loc[joined_list['RESULT'] == 'Safe to Send'].copy()
safe_to_send.reset_index(drop=True, inplace=True)
count_safe_to_send = safe_to_send.shape[0]

ex_safe_to_send = joined_list.loc[joined_list['RESULT'] != 'Safe to Send'].copy()
ex_safe_to_send.reset_index(drop=True, inplace=True)
count_ex_safe_to_send = ex_safe_to_send.shape[0]

# %%
print("==========================================================")
print("Summary")
print("==========================================================")
print("Jumlah Total Data : "+str(count_total_data))
print("Jumlah Data Contact Empty : "+str(count_empty_contact))
print("Jumlah Data Setelah Wash Empty Contact : "+str(count_empty_contact))
print("Jumlah Data Exist di Database Bounce : "+str(count_exist_in_bounce))
print("Jumlah Data Tidak Exist di Database Bounce : "+str(count_not_exist_in_bounce))
print("==========================================================")
print("Summary Bounced")
print("==========================================================")
print("Jumlah Data Safe to Send : "+str(count_safe_to_send))
print("Jumlah Data not Safe to Send : "+str(count_ex_safe_to_send))
# Out:
# ==========================================================
# Summary
# ==========================================================
# Jumlah Total Data : 621
# Jumlah Data Contact Empty : 0
# Jumlah Data Setelah Wash Empty Contact : 0
# Jumlah Data Exist di Database Bounce : 619
# Jumlah Data Tidak Exist di Database Bounce : 2
# ==========================================================
# Summary Bounced
# ==========================================================
# Jumlah Data Safe to Send : 91
# Jumlah Data not Safe to Send : 528

# %%
not_exist_list.loc[not_exist_list['Email'] == 'mohdasifaliak2016@gmail.com']
# df_1.loc[df_1['EMAIL'] == 'matthew.w.giles@gmail.com']
# df_1.loc[df_1['EMAIL'] == 'venkjaya@gmail.com']
# joined_df.loc[joined_df['RESULT'] == 'Safe to Send']
# df_bounced.loc[df_bounced['EMAIL'] == ]
# Out:
# Empty DataFrame
# Columns: [First Name, Last Name, Email, Phone, Mobile, City, State, Country, Nationality, Lead Source, Lead Locations, Booking Status, BookRef, EMAIL, RESULT, REASON, STATUS CODE, ROLE, FREE, DOMAIN, Sheet Name]
# Index: []
#
# [0 rows x 21 columns]

# %%
joined_df.loc[joined_df['Email'] == 'mohdasifaliak2016@gmail.com']
# Out:
# Empty DataFrame
# Columns: [First Name, Last Name, Email, Phone, Mobile, City, State, Country, Nationality, Lead Source, Lead Locations, Booking Status, BookRef, EMAIL, RESULT, REASON, STATUS CODE, ROLE, FREE, DOMAIN, Sheet Name]
# Index: []
#
# [0 rows x 21 columns]

# %%
safe_to_send.replace('empty', '', inplace=True)
safe_to_send.reset_index(drop=True, inplace=True)
df_safe = safe_to_send.reindex(columns=cols)
df_safe.rename(columns={'Lead Source':'Lead Sources'}, inplace=True)
df_safe['Tags'] = 'Non Members,Past Guest'

df_safe.to_csv(r'C:\Users\fajar\Documents\Python\Data\push-pastguest-formatted.csv', index=False, encoding='utf-8')

# %%
ex_safe_to_send.replace('empty', '', inplace=True)
ex_safe_to_send.reset_index(drop=True, inplace=True)
df_ex_safe_to_send = ex_safe_to_send.reindex(columns=cols)
df_ex_safe_to_send

df_ex_safe_to_send.to_excel(r'C:\Users\fajar\Documents\Python\Data\not-safe-to-send-debounce.xlsx', index=False)

# %%
not_exist_list.replace('empty', '', inplace=True)
not_exist_list.reset_index(drop=True, inplace=True)
df_not_exist = not_exist_list.reindex(columns=cols)
df_not_exist

df_not_exist.to_excel(r'C:\Users\fajar\Documents\Python\Data\not-exist-debounce.xlsx', index=False)
