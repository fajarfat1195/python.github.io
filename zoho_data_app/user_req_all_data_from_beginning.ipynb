# %%
import main_module as m
import zoho_filter_module as fil
import pandas as pd
import re
import numpy as np

# %load_ext autoreload
# %autoreload 2

dir_path = r'C:\Users\fajar.fatoni\Documents\Python\Data\Zoho_Backup\2020-2024'
dir_path_live = r'C:\Users\fajar.fatoni\Documents\Python\Data\Zoho_Backup'
dir_path_old = r'C:\Users\fajar.fatoni\Documents\Python\Data\Zoho_Backup\old'
file_name = '\Leads_'

cols = ['Record Id',	
'Created Time',
'Created Date',	
'First Name',	
'Last Name',	
'Email',	
'Phone',	
'Mobile',	
'Birthdate',	
'Year of Birth',
'Street',	
'Street2',	
'City',	
'State',	
'Country',	
'Nationality',
'Booking Status', 
'BookRef',
'Departure Date',	
'Arrival Date',	
'Card Type',	
'Marital Status',	
'Lead Brand',	
'Lead Sub-Brand',	
'Lead Source',	
'Lead Locations',	
'Lead Source Description',	
'Lead Regions',
'Lead Status',
'Email Opt Out',	
'Opt In',
'GDPR Compliant',
'Website',
'Comments',
'Do you live in Bali?']
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
email = 'swas83m@gmail.com|sambisays@gmail.com'

# %%
path = dir_path+'\\backup.csv'
df_all = pd.read_csv(path, dtype='string', on_bad_lines='skip')
count_data_awal = df_all.shape[0]
df_all.drop(df_all.loc[df_all['Created Time'].str.len() < 5 ].index, inplace=True)
df_all.reset_index(drop=True, inplace=True)

df_all['Created Time'] = pd.to_datetime(df_all['Created Time'], format='%Y-%m-%d %H:%M:%S')

df_all.shape[0]
df_all
# Out:
#                         Record Id        Created Time Created Date First Name  \
# 0        zcrm_3584690000000404058 2019-01-07 15:08:38   2019-01-06   Nicholas
# 1        zcrm_3584690000000404059 2019-01-07 15:08:38   2019-01-06       Liao
# 2        zcrm_3584690000000404060 2019-01-07 15:08:38   2019-01-06    Vedanta
# 3        zcrm_3584690000000404065 2019-01-07 15:08:38   2019-01-06      Aidai
# 4        zcrm_3584690000000404068 2019-01-07 15:08:38   2019-01-06      Ardra
# ...                           ...                 ...          ...        ...
# 9965978  zcrm_3584690000489266005 2024-03-25 16:19:45         <NA>      Keval
# 9965979  zcrm_3584690000489266034 2024-03-25 16:19:51         <NA>     Suresh
# 9965980  zcrm_3584690000489266063 2024-03-25 17:29:27         <NA>     Nathan
# 9965981  zcrm_3584690000489269015 2024-03-25 16:20:25         <NA>    Leonora
# 9965982  zcrm_3584690000489271002 2024-03-25 18:40:17         <NA>       Annu
#
#           Last Name                                 Email           Phone  \
# 0              Wood            1230woodnicholas@gmail.com     61438600845
# 1              Yuan                      158066546@qq.com   8618718399923
# 2          Abhiyoga            abhiyoga.vedanta@gmail.com   6282146524550
# 3         Atakanova                aidai.nurbek@gmail.com    996779641590
# 4             Ardra            aliefardraqariru@gmail.com  +6282139300818
# ...             ...                                   ...             ...
# 9965978        Gala                   keval2403@gmail.com   +919022872972
# 9965979      Shroff  sureshshroff@breachcandyhospital.org   +919819533303
# 9965980   Fernandes       nathan.fernandes@karmagroup.com  +9179724486854
# 9965981     Hackman                leonora_hf@bigpond.com    +61439855115
# 9965982  Shriwastav          annusrivastava1990@gmail.com   +919561074124
#
#                  Mobile   Birthdate Year of Birth  ...         Arrival Date  \
# 0                  <NA>        <NA>          <NA>  ...  2019-01-06 00:00:00
# 1                  <NA>        <NA>          <NA>  ...  2019-01-06 00:00:00
# 2                  <NA>  2000-07-05          2000  ...  2018-12-01 00:00:00
# 3                  <NA>  1997-02-05          1997  ...  2019-01-06 00:00:00
# 4        +6282139300818  2005-01-20          2005  ...  2018-11-30 00:00:00
# ...                 ...         ...           ...  ...                  ...
# 9965978   +917700904802        <NA>          <NA>  ...           2024-03-21
# 9965979   +919819814280        <NA>          <NA>  ...           2024-03-21
# 9965980            <NA>        <NA>          <NA>  ...                 <NA>
# 9965981            <NA>        <NA>          <NA>  ...           2024-03-14
# 9965982            <NA>        <NA>          <NA>  ...                 <NA>
#
#         Card Type Marital Status           Lead Brand   Lead Sub-Brand  \
# 0            <NA>           <NA>  Timeshare Marketing    Other Bali DB
# 1            <NA>           <NA>  Timeshare Marketing    Other Bali DB
# 2            <NA>        Pelajar  Timeshare Marketing    Other Bali DB
# 3            <NA>         Single  Timeshare Marketing    Other Bali DB
# 4            <NA>          OTHER  Timeshare Marketing    Other Bali DB
# ...           ...            ...                  ...              ...
# 9965978      <NA>           <NA>        Karma Resorts            Other
# 9965979      <NA>           <NA>        Karma Resorts            Other
# 9965980      <NA>           <NA>          Karma Group  Karma Community
# 9965981      <NA>           <NA>        Karma Resorts            Other
# 9965982      <NA>           <NA>  Timeshare Marketing            Other
#
#          Lead Source           Lead Locations  \
# 0               Wifi              Purple Wifi
# 1               Wifi              Purple Wifi
# 2               Wifi              Purple Wifi
# 3               Wifi              Purple Wifi
# 4               Wifi              Purple Wifi
# ...              ...                      ...
# 9965978  Past Guests        Karma Royal Palms
# 9965979  Past Guests  Karma Sitabani, Corbett
# 9965980         Quiz                     <NA>
# 9965981  Past Guests           Karma Jimbaran
# 9965982  Web Enquiry           Karma Sitabani
#
#                                    Lead Source Description Lead Regions  \
# 0                                                     <NA>         SEAP
# 1                                                     <NA>        Other
# 2                                                     <NA>         SEAP
# 3                                                     <NA>    UK/Europe
# 4                                    WIFI USER ID 13494142         SEAP
# ...                                                    ...          ...
# 9965978                                          Viewpoint         <NA>
# 9965979                                          Viewpoint         <NA>
# 9965980  Karma Community | Edition 218 - Words to the Wise        India
# 9965981                                          Viewpoint         <NA>
# 9965982                          Timeshare Booking Request        India
#
#         Lead Status
# 0          New Lead
# 1          New Lead
# 2          New Lead
# 3          New Lead
# 4          New Lead
# ...             ...
# 9965978        <NA>
# 9965979        <NA>
# 9965980        <NA>
# 9965981        <NA>
# 9965982        <NA>
#
# [9965983 rows x 27 columns]

# %%
df_old = m.load_data_multiple(dir_path_old, file_name, cols)
count_data_awal = df_old.shape[0]
df_old = df_old.reindex(columns=cols)
df_old.shape[0]

df_old['Created Time'] = pd.to_datetime(df_old['Created Time'], format='%Y-%m-%d %H:%M:%S')
df_old['Arrival Date'] = pd.to_datetime(df_old['Arrival Date'], format='%Y-%m-%d')
df_old['Departure Date'] = pd.to_datetime(df_old['Departure Date'], format='%Y-%m-%d')
# fungsi errors cource untuk menhindari error jika value data date null atau kosong
# df['Birthdate'] = pd.to_datetime(df['Birthdate'], format='%Y-%m-%d', errors='coerce')
df_old.dtypes
df_old
# Out:
#                         Record Id        Created Time Created Date First Name  \
# 0        zcrm_3584690000000404058 2019-01-07 15:08:38   2019-01-06   Nicholas
# 1        zcrm_3584690000000404059 2019-01-07 15:08:38   2019-01-06       Liao
# 2        zcrm_3584690000000404060 2019-01-07 15:08:38   2019-01-06    Vedanta
# 3        zcrm_3584690000000404065 2019-01-07 15:08:38   2019-01-06      Aidai
# 4        zcrm_3584690000000404068 2019-01-07 15:08:38   2019-01-06      Ardra
# ...                           ...                 ...          ...        ...
# 4717718  zcrm_3584690000475135007 2024-01-01 18:16:02         <NA>    Upendra
# 4717719  zcrm_3584690000475135045 2024-01-01 18:16:37         <NA>      Mehul
# 4717720  zcrm_3584690000475136005 2024-01-01 18:17:13         <NA>      swati
# 4717721  zcrm_3584690000475138034 2024-01-01 18:48:36         <NA>      SUMON
# 4717722  zcrm_3584690000475138069 2024-01-01 18:52:24         <NA>      Rohit
#
#          Last Name                       Email           Phone  \
# 0             Wood  1230woodnicholas@gmail.com    +61438600845
# 1             Yuan            158066546@qq.com   8618718399923
# 2         Abhiyoga  abhiyoga.vedanta@gmail.com  +6282146524550
# 3        Atakanova      aidai.nurbek@gmail.com    996779641590
# 4            Ardra  aliefardraqariru@gmail.com  +6282139300818
# ...            ...                         ...             ...
# 4717718     Mishra       upendra.sir@gmail.com   +919036084550
# 4717719  Prajapati     mehul.m111985@gmail.com   +919714713689
# 4717720   agarwala         cswatiadv@gmail.com   +919733055636
# 4717721      SAHOO        sumonsahoo@gmail.com   +918910484814
# 4717722      Kadam      rohit0918.rk@gmail.com   +919819185446
#
#                  Mobile   Birthdate Year of Birth  ...  \
# 0                  <NA>        <NA>          <NA>  ...
# 1                  <NA>        <NA>          <NA>  ...
# 2                  <NA>  2000-07-05          2000  ...
# 3                  <NA>  1997-02-05          1997  ...
# 4        +6282139300818  2005-01-20          2005  ...
# ...                 ...         ...           ...  ...
# 4717718            <NA>        <NA>          <NA>  ...
# 4717719            <NA>        <NA>          <NA>  ...
# 4717720            <NA>        <NA>          <NA>  ...
# 4717721            <NA>        <NA>          <NA>  ...
# 4717722            <NA>        <NA>          <NA>  ...
#
#                  Lead Locations      Lead Source Description Lead Regions  \
# 0                          <NA>                  Purple Wifi         SEAP
# 1                          <NA>                  Purple Wifi        Other
# 2                          <NA>                  Purple Wifi         SEAP
# 3                          <NA>                  Purple Wifi    UK/Europe
# 4                       Mall 21                  Purple Wifi         SEAP
# ...                         ...                          ...          ...
# 4717718  Karma Sunshine Village    Timeshare Booking Request        India
# 4717719                 General  IND | FB MF | Lead captured         <NA>
# 4717720            Karma Martam         IND | FB MF | Martam         <NA>
# 4717721            Karma Martam         IND | FB MF | Martam         <NA>
# 4717722             Royal Palms            IND | FB AF | KRP         <NA>
#
#         Lead Status Email Opt Out Opt In GDPR Compliant  \
# 0          New Lead         false  false          false
# 1          New Lead         false  false          false
# 2          New Lead         false  false          false
# 3          New Lead         false  false          false
# 4          New Lead         false  false          false
# ...             ...           ...    ...            ...
# 4717718        <NA>         false   true           true
# 4717719        <NA>         false  false          false
# 4717720        <NA>         false  false          false
# 4717721        <NA>         false  false          false
# 4717722        <NA>         false  false          false
#
#                                                    Website Comments  \
# 0                                                     <NA>     <NA>
# 1                                                     <NA>     <NA>
# 2                                                     <NA>     <NA>
# 3                                                     <NA>     <NA>
# 4                                                     <NA>     <NA>
# ...                                                    ...      ...
# 4717718  https://karmagroup.com/find-destination/karma-...     <NA>
# 4717719                                               <NA>     <NA>
# 4717720                                               <NA>     <NA>
# 4717721                                               <NA>     <NA>
# 4717722                                               <NA>     <NA>
#
#         Do you live in Bali?
# 0                      false
# 1                      false
# 2                      false
# 3                      false
# 4                      false
# ...                      ...
# 4717718                false
# 4717719                false
# 4717720                false
# 4717721                false
# 4717722                false
#
# [4717723 rows x 35 columns]

# %%
df_live = m.load_data_multiple(dir_path_live, file_name, cols)
count_data_awal = df_live.shape[0]
df_live = df_live.reindex(columns=cols)
df_live.shape[0]

df_live['Created Time'] = pd.to_datetime(df_live['Created Time'], format='%Y-%m-%d %H:%M:%S')
df_live['Arrival Date'] = pd.to_datetime(df_live['Arrival Date'], format='%Y-%m-%d')
df_live['Departure Date'] = pd.to_datetime(df_live['Departure Date'], format='%Y-%m-%d')
# fungsi errors cource untuk menhindari error jika value data date null atau kosong
# df['Birthdate'] = pd.to_datetime(df['Birthdate'], format='%Y-%m-%d', errors='coerce')
df_live.dtypes
df_live
# Out:
#                        Record Id        Created Time Created Date First Name  \
# 0       zcrm_3584690000000404602 2019-01-08 11:07:28   2021-07-21   Frederic
# 1       zcrm_3584690000000450071 2019-01-08 16:38:18         <NA>  Sebastian
# 2       zcrm_3584690000000450087 2019-01-08 16:38:18         <NA>    Siobhan
# 3       zcrm_3584690000000450106 2019-01-08 16:38:18         <NA>       Lisa
# 4       zcrm_3584690000000450109 2019-01-08 16:38:18         <NA>  Ana Maria
# ...                          ...                 ...          ...        ...
# 500010  zcrm_3584690000531084001 2025-03-17 16:10:04   2025-03-17       Gary
# 500011  zcrm_3584690000531086001 2025-03-17 16:13:48   2025-03-17       TEST
# 500012  zcrm_3584690000531094001 2025-03-17 16:25:04   2025-03-17       Jana
# 500013  zcrm_3584690000531126001 2025-03-17 17:25:17         <NA>    Georgia
# 500014  zcrm_3584690000531144001 2025-03-17 17:59:52   2025-03-17       Feby
#
#         Last Name                        Email             Phone Mobile  \
# 0           Bonin    fredericbonin79@gmail.com    +6281236100502   <NA>
# 1            Rach                         <NA>     +498914342111   <NA>
# 2       Gallagher  gallaghersiobhan@eircom.net      353879597603   <NA>
# 3       Ferkovich         lisajo2009@yahoo.com       14062394749   <NA>
# 4        Weileder     m.weileder@sonnenlink.de       15253234700   <NA>
# ...           ...                          ...               ...    ...
# 500010   Cosgrove    cosgrove_gary@yahoo.co.uk    +4407709529900   <NA>
# 500011       TEST  rajesh.kumar@karmagroup.com     +919876655432   <NA>
# 500012          D              jana@pragma.law      +61405501543   <NA>
# 500013    Goodyer  georgiaraedunkley@gmail.com     +447840040213   <NA>
# 500014    Jolanda                         <NA>  +62818-0347-7331   <NA>
#
#          Birthdate Year of Birth  ...      Lead Locations  \
# 0       1981-10-03          1981  ...       Karma Kandara
# 1       1982-04-20          1982  ...       Karma Bavaria
# 2       1973-03-14          1973  ...       Karma Bavaria
# 3       1963-07-08          1963  ...       Karma Bavaria
# 4             <NA>          <NA>  ...       Karma Bavaria
# ...            ...           ...  ...                 ...
# 500010        <NA>          <NA>  ...         Karma Bayon
# 500011        <NA>          <NA>  ...  Karma Salford Hall
# 500012        <NA>          <NA>  ...       Karma Kandara
# 500013  1989-11-06          <NA>  ...                <NA>
# 500014        <NA>          <NA>  ...       Karma Kandara
#
#                                   Lead Source Description Lead Regions  \
# 0                                                   KAREN         SEAP
# 1                                                    <NA>    UK/Europe
# 2                                                    <NA>    UK/Europe
# 3                                                    <NA>    UK/Europe
# 4                         MICE Contacts from Ioanna email    UK/Europe
# ...                                                   ...          ...
# 500010              Karma Reservations - WhatsApp Channel         <NA>
# 500011  Karma Salford Hall - Weddings at Karma Salford...        India
# 500012              Karma Reservations - WhatsApp Channel         <NA>
# 500013                           Karma Reciprocal Members    UK/Europe
# 500014              Karma Reservations - WhatsApp Channel         <NA>
#
#        Lead Status Email Opt Out Opt In GDPR Compliant  \
# 0         New Lead         false  false          false
# 1         New Lead          true  false          false
# 2         New Lead         false   true           true
# 3         New Lead          true  false          false
# 4         New Lead         false   true           true
# ...            ...           ...    ...            ...
# 500010    New Lead         false  false          false
# 500011        <NA>         false   true          false
# 500012    New Lead         false  false          false
# 500013        <NA>         false   true           true
# 500014    New Lead         false  false          false
#
#                                                   Website Comments  \
# 0                                                    <NA>     <NA>
# 1                                                    <NA>     <NA>
# 2                                                    <NA>     <NA>
# 3                                                    <NA>     <NA>
# 4                                                    <NA>     <NA>
# ...                                                   ...      ...
# 500010                                               <NA>     <NA>
# 500011  https://karmagroup.com/weddings-at-karma-salfo...     <NA>
# 500012                                               <NA>     <NA>
# 500013  https://karmaclub.karmagroup.com/reciprocal-me...     <NA>
# 500014                                               <NA>     <NA>
#
#        Do you live in Bali?
# 0                     false
# 1                     false
# 2                     false
# 3                     false
# 4                     false
# ...                     ...
# 500010                false
# 500011                false
# 500012                false
# 500013                false
# 500014                false
#
# [500015 rows x 35 columns]

# %%
df = pd.concat([df_all,df_old,df_live])
df
# Out:
#                        Record Id        Created Time Created Date First Name  \
# 0       zcrm_3584690000000404058 2019-01-07 15:08:38   2019-01-06   Nicholas
# 1       zcrm_3584690000000404059 2019-01-07 15:08:38   2019-01-06       Liao
# 2       zcrm_3584690000000404060 2019-01-07 15:08:38   2019-01-06    Vedanta
# 3       zcrm_3584690000000404065 2019-01-07 15:08:38   2019-01-06      Aidai
# 4       zcrm_3584690000000404068 2019-01-07 15:08:38   2019-01-06      Ardra
# ...                          ...                 ...          ...        ...
# 500010  zcrm_3584690000531084001 2025-03-17 16:10:04   2025-03-17       Gary
# 500011  zcrm_3584690000531086001 2025-03-17 16:13:48   2025-03-17       TEST
# 500012  zcrm_3584690000531094001 2025-03-17 16:25:04   2025-03-17       Jana
# 500013  zcrm_3584690000531126001 2025-03-17 17:25:17         <NA>    Georgia
# 500014  zcrm_3584690000531144001 2025-03-17 17:59:52   2025-03-17       Feby
#
#         Last Name                        Email             Phone  \
# 0            Wood   1230woodnicholas@gmail.com       61438600845
# 1            Yuan             158066546@qq.com     8618718399923
# 2        Abhiyoga   abhiyoga.vedanta@gmail.com     6282146524550
# 3       Atakanova       aidai.nurbek@gmail.com      996779641590
# 4           Ardra   aliefardraqariru@gmail.com    +6282139300818
# ...           ...                          ...               ...
# 500010   Cosgrove    cosgrove_gary@yahoo.co.uk    +4407709529900
# 500011       TEST  rajesh.kumar@karmagroup.com     +919876655432
# 500012          D              jana@pragma.law      +61405501543
# 500013    Goodyer  georgiaraedunkley@gmail.com     +447840040213
# 500014    Jolanda                         <NA>  +62818-0347-7331
#
#                 Mobile   Birthdate Year of Birth  ... Lead Regions  \
# 0                 <NA>        <NA>          <NA>  ...         SEAP
# 1                 <NA>        <NA>          <NA>  ...        Other
# 2                 <NA>  2000-07-05          2000  ...         SEAP
# 3                 <NA>  1997-02-05          1997  ...    UK/Europe
# 4       +6282139300818  2005-01-20          2005  ...         SEAP
# ...                ...         ...           ...  ...          ...
# 500010            <NA>        <NA>          <NA>  ...         <NA>
# 500011            <NA>        <NA>          <NA>  ...        India
# 500012            <NA>        <NA>          <NA>  ...         <NA>
# 500013            <NA>  1989-11-06          <NA>  ...    UK/Europe
# 500014            <NA>        <NA>          <NA>  ...         <NA>
#
#        Lead Status Booking Status BookRef Email Opt Out Opt In GDPR Compliant  \
# 0         New Lead           <NA>    <NA>          <NA>   <NA>           <NA>
# 1         New Lead           <NA>    <NA>          <NA>   <NA>           <NA>
# 2         New Lead           <NA>    <NA>          <NA>   <NA>           <NA>
# 3         New Lead           <NA>    <NA>          <NA>   <NA>           <NA>
# 4         New Lead           <NA>    <NA>          <NA>   <NA>           <NA>
# ...            ...            ...     ...           ...    ...            ...
# 500010    New Lead           <NA>    <NA>         false  false          false
# 500011        <NA>           <NA>    <NA>         false   true          false
# 500012    New Lead           <NA>    <NA>         false  false          false
# 500013        <NA>           <NA>    <NA>         false   true           true
# 500014    New Lead           <NA>    <NA>         false  false          false
#
#                                                   Website Comments  \
# 0                                                    <NA>     <NA>
# 1                                                    <NA>     <NA>
# 2                                                    <NA>     <NA>
# 3                                                    <NA>     <NA>
# 4                                                    <NA>     <NA>
# ...                                                   ...      ...
# 500010                                               <NA>     <NA>
# 500011  https://karmagroup.com/weddings-at-karma-salfo...     <NA>
# 500012                                               <NA>     <NA>
# 500013  https://karmaclub.karmagroup.com/reciprocal-me...     <NA>
# 500014                                               <NA>     <NA>
#
#        Do you live in Bali?
# 0                      <NA>
# 1                      <NA>
# 2                      <NA>
# 3                      <NA>
# 4                      <NA>
# ...                     ...
# 500010                false
# 500011                false
# 500012                false
# 500013                false
# 500014                false
#
# [15183721 rows x 35 columns]

# %%
# df.loc[df['Email'] == email]
df.loc[df['Email'].str.contains(email, regex=True, flags=re.I)]
# Out:
# Empty DataFrame
# Columns: [Record Id, Created Time, Created Date, First Name, Last Name, Email, Phone, Mobile, Birthdate, Year of Birth, Street, Street2, City, State, Country, Nationality, Departure Date, Arrival Date, Card Type, Marital Status, Lead Brand, Lead Sub-Brand, Lead Source, Lead Locations, Lead Source Description, Lead Regions, Lead Status, Booking Status, BookRef, Email Opt Out, Opt In, GDPR Compliant, Website, Comments, Do you live in Bali?]
# Index: []
#
# [0 rows x 35 columns]

# %%
df.drop_duplicates(subset=['Record Id'], inplace=True)
df.reset_index(drop=True, inplace=True)
count_data_awal = df.shape[0]
df
# Out:
#                          Record Id        Created Time Created Date  \
# 0         zcrm_3584690000000404058 2019-01-07 15:08:38   2019-01-06
# 1         zcrm_3584690000000404059 2019-01-07 15:08:38   2019-01-06
# 2         zcrm_3584690000000404060 2019-01-07 15:08:38   2019-01-06
# 3         zcrm_3584690000000404065 2019-01-07 15:08:38   2019-01-06
# 4         zcrm_3584690000000404068 2019-01-07 15:08:38   2019-01-06
# ...                            ...                 ...          ...
# 10030856  zcrm_3584690000531084001 2025-03-17 16:10:04   2025-03-17
# 10030857  zcrm_3584690000531086001 2025-03-17 16:13:48   2025-03-17
# 10030858  zcrm_3584690000531094001 2025-03-17 16:25:04   2025-03-17
# 10030859  zcrm_3584690000531126001 2025-03-17 17:25:17         <NA>
# 10030860  zcrm_3584690000531144001 2025-03-17 17:59:52   2025-03-17
#
#          First Name  Last Name                        Email             Phone  \
# 0          Nicholas       Wood   1230woodnicholas@gmail.com       61438600845
# 1              Liao       Yuan             158066546@qq.com     8618718399923
# 2           Vedanta   Abhiyoga   abhiyoga.vedanta@gmail.com     6282146524550
# 3             Aidai  Atakanova       aidai.nurbek@gmail.com      996779641590
# 4             Ardra      Ardra   aliefardraqariru@gmail.com    +6282139300818
# ...             ...        ...                          ...               ...
# 10030856       Gary   Cosgrove    cosgrove_gary@yahoo.co.uk    +4407709529900
# 10030857       TEST       TEST  rajesh.kumar@karmagroup.com     +919876655432
# 10030858       Jana          D              jana@pragma.law      +61405501543
# 10030859    Georgia    Goodyer  georgiaraedunkley@gmail.com     +447840040213
# 10030860       Feby    Jolanda                         <NA>  +62818-0347-7331
#
#                   Mobile   Birthdate Year of Birth  ... Lead Regions  \
# 0                   <NA>        <NA>          <NA>  ...         SEAP
# 1                   <NA>        <NA>          <NA>  ...        Other
# 2                   <NA>  2000-07-05          2000  ...         SEAP
# 3                   <NA>  1997-02-05          1997  ...    UK/Europe
# 4         +6282139300818  2005-01-20          2005  ...         SEAP
# ...                  ...         ...           ...  ...          ...
# 10030856            <NA>        <NA>          <NA>  ...         <NA>
# 10030857            <NA>        <NA>          <NA>  ...        India
# 10030858            <NA>        <NA>          <NA>  ...         <NA>
# 10030859            <NA>  1989-11-06          <NA>  ...    UK/Europe
# 10030860            <NA>        <NA>          <NA>  ...         <NA>
#
#          Lead Status Booking Status BookRef Email Opt Out Opt In  \
# 0           New Lead           <NA>    <NA>          <NA>   <NA>
# 1           New Lead           <NA>    <NA>          <NA>   <NA>
# 2           New Lead           <NA>    <NA>          <NA>   <NA>
# 3           New Lead           <NA>    <NA>          <NA>   <NA>
# 4           New Lead           <NA>    <NA>          <NA>   <NA>
# ...              ...            ...     ...           ...    ...
# 10030856    New Lead           <NA>    <NA>         false  false
# 10030857        <NA>           <NA>    <NA>         false   true
# 10030858    New Lead           <NA>    <NA>         false  false
# 10030859        <NA>           <NA>    <NA>         false   true
# 10030860    New Lead           <NA>    <NA>         false  false
#
#          GDPR Compliant                                            Website  \
# 0                  <NA>                                               <NA>
# 1                  <NA>                                               <NA>
# 2                  <NA>                                               <NA>
# 3                  <NA>                                               <NA>
# 4                  <NA>                                               <NA>
# ...                 ...                                                ...
# 10030856          false                                               <NA>
# 10030857          false  https://karmagroup.com/weddings-at-karma-salfo...
# 10030858          false                                               <NA>
# 10030859           true  https://karmaclub.karmagroup.com/reciprocal-me...
# 10030860          false                                               <NA>
#
#          Comments Do you live in Bali?
# 0            <NA>                 <NA>
# 1            <NA>                 <NA>
# 2            <NA>                 <NA>
# 3            <NA>                 <NA>
# 4            <NA>                 <NA>
# ...           ...                  ...
# 10030856     <NA>                false
# 10030857     <NA>                false
# 10030858     <NA>                false
# 10030859     <NA>                false
# 10030860     <NA>                false
#
# [10030861 rows x 35 columns]

# %%
df.dtypes
# Out:
# Record Id                  string[python]
# Created Time               datetime64[ns]
# Created Date               string[python]
# First Name                 string[python]
# Last Name                  string[python]
# Email                      string[python]
# Phone                      string[python]
# Mobile                     string[python]
# Birthdate                  string[python]
# Year of Birth              string[python]
# Street                     string[python]
# Street2                    string[python]
# City                       string[python]
# State                      string[python]
# Country                    string[python]
# Nationality                string[python]
# Departure Date                     object
# Arrival Date                       object
# Card Type                  string[python]
# Marital Status             string[python]
# Lead Brand                 string[python]
# Lead Sub-Brand             string[python]
# Lead Source                string[python]
# Lead Locations             string[python]
# Lead Source Description    string[python]
# Lead Regions               string[python]
# Lead Status                string[python]
# Booking Status             string[python]
# BookRef                    string[python]
# Email Opt Out              string[python]
# Opt In                     string[python]
# GDPR Compliant             string[python]
# Website                    string[python]
# Comments                   string[python]
# Do you live in Bali?       string[python]
# dtype: object

# %%
path = r'G:\.shortcut-targets-by-id\0B_d3smBjzo04eXpvS1NXTWF2RVE\_BOOKING\Booking By Year\FlyBuy Booking Data (BGAU & BGID & KE).xlsx'
df_booking = pd.read_excel(path, dtype='string', sheet_name='BOOKING_BGAU_BGID_KE')

path = r'G:\.shortcut-targets-by-id\0B_d3smBjzo04UUNBME5GOVhoMjA\_ODYSSEY\Phone Members.xlsx'
df_phone = pd.read_excel(path, dtype='string', sheet_name='Sheet1')

path = r'G:\.shortcut-targets-by-id\0B_d3smBjzo04UUNBME5GOVhoMjA\_ODYSSEY\Email Members.xlsx'
df_email = pd.read_excel(path, dtype='string', sheet_name='Sheet1')

# %%
zoho_filter = fil.user_req(df)
zoho_df = df.loc[zoho_filter].copy() # menggunakan copy untuk menghindari setting copy warning
zoho_df.reset_index(drop=True, inplace=True)
count_filter_awal = zoho_df.shape[0]

# zoho_df.to_excel(r'C:\Users\fajar.fatoni\Documents\Python\Data\test_leads.xlsx', index=False)
# mengisi kolom <NA> dengan value string 'empty' supaya mudah mengecek data member dan booking dengan isin

zoho_df.fillna('empty', inplace=True)
# zoho_df.sort_values('Created Time', ascending=True)

# %%
zoho_df
# Out:
#                        Record Id        Created Time Created Date  \
# 0       zcrm_3584690000000408007 2019-01-07 13:29:59        empty
# 1       zcrm_3584690000000408013 2019-01-07 17:22:27        empty
# 2       zcrm_3584690000000408020 2019-01-07 18:22:28        empty
# 3       zcrm_3584690000000408026 2019-01-07 20:07:11        empty
# 4       zcrm_3584690000000409019 2019-01-07 15:00:14        empty
# ...                          ...                 ...          ...
# 600136  zcrm_3584690000519858011 2025-01-01 14:53:53        empty
# 600137  zcrm_3584690000520178108 2025-01-08 05:01:29        empty
# 600138  zcrm_3584690000520283034 2025-01-08 04:49:22        empty
# 600139  zcrm_3584690000520542015 2025-01-10 15:24:39        empty
# 600140  zcrm_3584690000525736001 2025-02-26 04:14:09        empty
#
#                First Name  Last Name                               Email  \
# 0              Ht Chandra    N Usman               ichan051163@gmail.com
# 1                   Endah    Haryani              awal.endah83@gmail.com
# 2            Alda Beatrix  Wattimena           aldabeatrix.abw@gmail.com
# 3                    Rini    Siregar            rini.siregar21@gmail.com
# 4       Christine Marylin    Effendi          christinemarylin@gmail.com
# ...                   ...        ...                                 ...
# 600136              scott   atkinson         scottatkinson1979@gmail.com
# 600137                kat     Pearce                    kwp744@gmail.com
# 600138                kat     Pearce                    kwp744@gmail.com
# 600139              Halie    Johnson            haliebabie1209@gmail.com
# 600140               Gary    Charles  garycharles@dominatingkeywords.com
#
#                 Phone      Mobile   Birthdate Year of Birth  ... Lead Regions  \
# 0        628116190115  8126542115  1963-01-01          1963  ...         SEAP
# 1         87888802700       empty  1983-01-01          1983  ...         SEAP
# 2       6285344502233       empty  1986-01-01          1986  ...         SEAP
# 3         87888282359       empty       empty         empty  ...         SEAP
# 4               empty       empty       empty         empty  ...         SEAP
# ...               ...         ...         ...           ...  ...          ...
# 600136  +610419918057       empty       empty          1980  ...         SEAP
# 600137  +610412929135       empty       empty          1970  ...         SEAP
# 600138  +610412929135       empty       empty          1970  ...         SEAP
# 600139  +612019402400       empty       empty         empty  ...         SEAP
# 600140  +618054002077       empty       empty         empty  ...         SEAP
#
#          Lead Status Booking Status BookRef Email Opt Out Opt In  \
# 0              empty          empty   empty         empty  empty
# 1              empty          empty   empty         empty  empty
# 2              empty          empty   empty         empty  empty
# 3              empty          empty   empty         empty  empty
# 4              empty          empty   empty         empty  empty
# ...              ...            ...     ...           ...    ...
# 600136  Hot Prospect          empty   empty         false  false
# 600137  Hot Prospect          empty   empty         false  false
# 600138  Hot Prospect          empty   empty         false  false
# 600139      New Lead          empty   empty         false  false
# 600140      New Lead          empty   empty         false  false
#
#        GDPR Compliant Website Comments Do you live in Bali?
# 0               empty   empty    empty                empty
# 1               empty   empty    empty                empty
# 2               empty   empty    empty                empty
# 3               empty   empty    empty                empty
# 4               empty   empty    empty                empty
# ...               ...     ...      ...                  ...
# 600136          false   empty    empty                false
# 600137          false   empty    empty                false
# 600138          false   empty    empty                false
# 600139          false   empty    empty                false
# 600140          false   empty    empty                false
#
# [600141 rows x 35 columns]

# %% [markdown]
# # ====================== Awal Filter Umum ======================

# %%
# data phone, mobile dam email member yang ada di master data (wash member)

m.clean_number(zoho_df, 'Phone')
m.clean_number(zoho_df, 'Mobile')
m.replace_not_valid_to_empty(zoho_df, 'Phone')
m.replace_not_valid_to_empty(zoho_df, 'Mobile')
zoho_df['Email'] = m.lowercase(zoho_df, 'Email')
m.clean_space(zoho_df, 'Email')
m.clean_not_valid_email_format(zoho_df, 'Email')

m.clean_number(df_booking, 'Phone1')
m.clean_number(df_booking, 'Mobile')
df_booking['Email'] = m.lowercase(df_booking, 'Email')
m.clean_space(df_booking, 'Email')
m.clean_not_valid_email_format(df_booking, 'Email')

m.clean_number(df_phone, 'Mobile')

df_email['Email'] = m.lowercase(df_email, 'Email')
m.clean_space(df_email, 'Email')
m.clean_not_valid_email_format(df_email, 'Email')
# Out:
# c:\Users\fajar.fatoni\Documents\Python\Task Offline\zoho_data_app\main_module.py:71: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[df_columns].replace(' ','', regex=True, inplace=True)
# c:\Users\fajar.fatoni\Documents\Python\Task Offline\zoho_data_app\main_module.py:72: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[df_columns].replace('[^0-9]','', regex=True, inplace=True)
# c:\Users\fajar.fatoni\Documents\Python\Task Offline\zoho_data_app\main_module.py:94: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[df_columns].replace(' ','', regex=True, inplace=True)
# c:\Users\fajar.fatoni\Documents\Python\Task Offline\zoho_data_app\main_module.py:71: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[df_columns].replace(' ','', regex=True, inplace=True)
# c:\Users\fajar.fatoni\Documents\Python\Task Offline\zoho_data_app\main_module.py:72: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[df_columns].replace('[^0-9]','', regex=True, inplace=True)
# 'Email'

# %%
zoho_df.loc[zoho_df['Phone']=='']
# Out:
# Empty DataFrame
# Columns: [Record Id, Created Time, Created Date, First Name, Last Name, Email, Phone, Mobile, Birthdate, Year of Birth, Street, Street2, City, State, Country, Nationality, Departure Date, Arrival Date, Card Type, Marital Status, Lead Brand, Lead Sub-Brand, Lead Source, Lead Locations, Lead Source Description, Lead Regions, Lead Status, Booking Status, BookRef, Email Opt Out, Opt In, GDPR Compliant, Website, Comments, Do you live in Bali?]
# Index: []
#
# [0 rows x 35 columns]

# %%
count_deleted_wrong_format = m.delete_email_wrong_format(zoho_df, 'Email')
count_after_deleted_wrong_format = zoho_df.shape[0]

# %%
# hitung jumlah duplicate
count_duplicate_general = zoho_df.loc[zoho_df.duplicated(subset=['Phone','Email', 'Mobile'])].shape[0]

zoho_df.loc[zoho_df.duplicated(subset=['Phone','Email'])]
# Out:
#                        Record Id        Created Time Created Date First Name  \
# 5310    zcrm_3584690000000930151 2019-01-22 13:46:09        empty      Sarah
# 6025    zcrm_3584690000001015301 2019-01-25 15:15:39        empty        Har
# 24222   zcrm_3584690000005104084 2019-03-25 20:18:01        empty  Handayani
# 64066   zcrm_3584690000006168864 2019-04-02 03:19:30   2015-03-18      empty
# 78349   zcrm_3584690000006208571 2019-04-02 03:23:26   2015-03-18       Andy
# ...                          ...                 ...          ...        ...
# 600116  zcrm_3584690000467103041 2023-10-26 16:49:40        empty     Ritesh
# 600117  zcrm_3584690000467237001 2023-10-27 19:12:00        empty     MhAmad
# 600132  zcrm_3584690000505204001 2024-08-20 16:20:13        empty       Gary
# 600133  zcrm_3584690000506044042 2024-08-30 10:49:51        empty       Gary
# 600138  zcrm_3584690000520283034 2025-01-08 04:49:22        empty        kat
#
#            Last Name                                Email         Phone  \
# 5310          Juniar             myjune21_becky@yahoo.com   85269192900
# 6025            Tato                   tatorich@yahoo.com    8113674888
# 24222          Saman            handayani.saman@yahoo.com   85311133033
# 64066   Nickeylawton           nickeylawton1@yahoo.com.au   61439886488
# 78349        Mcmanus           andy.mcmanus@dot.wa.edu.au   61411144301
# ...              ...                                  ...           ...
# 600116          Jain               rgjain.jain7@gmail.com   61469874054
# 600117       Hussein             mohamadhoussein@live.com   61420609622
# 600132       Charles  gary_charles@dominatingkeywords.com  618185327032
# 600133       Charles   garycharles@dominatingkeywords.com  618185327032
# 600138        Pearce                     kwp744@gmail.com  610412929135
#
#        Mobile   Birthdate Year of Birth  ... Lead Regions    Lead Status  \
# 5310    empty  1985-01-01          1985  ...         SEAP          empty
# 6025    empty  1988-01-01          1988  ...         SEAP          empty
# 24222   empty       empty          1971  ...         SEAP          empty
# 64066   empty       empty         empty  ...         SEAP          empty
# 78349   empty       empty         empty  ...         SEAP          empty
# ...       ...         ...           ...  ...          ...            ...
# 600116  empty       empty         empty  ...         SEAP  Not Qualified
# 600117  empty       empty          1993  ...         SEAP   Hot Prospect
# 600132  empty       empty         empty  ...         SEAP       New Lead
# 600133  empty       empty         empty  ...         SEAP       New Lead
# 600138  empty       empty          1970  ...         SEAP   Hot Prospect
#
#        Booking Status BookRef Email Opt Out Opt In GDPR Compliant Website  \
# 5310            empty   empty         empty  empty          empty   empty
# 6025            empty   empty         empty  empty          empty   empty
# 24222           empty   empty         empty  empty          empty   empty
# 64066           empty   empty         empty  empty          empty   empty
# 78349           empty   empty         empty  empty          empty   empty
# ...               ...     ...           ...    ...            ...     ...
# 600116          empty   empty         empty  empty          empty   empty
# 600117          empty   empty         empty  empty          empty   empty
# 600132          empty   empty         false  false          false   empty
# 600133          empty   empty         false  false          false   empty
# 600138          empty   empty         false  false          false   empty
#
#        Comments Do you live in Bali?
# 5310      empty                empty
# 6025      empty                empty
# 24222     empty                empty
# 64066     empty                empty
# 78349     empty                empty
# ...         ...                  ...
# 600116    empty                empty
# 600117    empty                empty
# 600132    empty                false
# 600133    empty                false
# 600138    empty                false
#
# [71811 rows x 35 columns]

# %%
zoho_df.drop_duplicates(subset=['Phone','Email', 'Mobile'], inplace=True)
zoho_df.reset_index(drop=True, inplace=True)

# hitung jumlah setelah value duplicate dihapus
count_after_dedup_duplicate = zoho_df.shape[0]

zoho_df
# Out:
#                        Record Id        Created Time Created Date  \
# 0       zcrm_3584690000000408007 2019-01-07 13:29:59        empty
# 1       zcrm_3584690000000408013 2019-01-07 17:22:27        empty
# 2       zcrm_3584690000000408020 2019-01-07 18:22:28        empty
# 3       zcrm_3584690000000408026 2019-01-07 20:07:11        empty
# 4       zcrm_3584690000000409019 2019-01-07 15:00:14        empty
# ...                          ...                 ...          ...
# 534523  zcrm_3584690000510697002 2024-10-02 14:15:31        empty
# 534524  zcrm_3584690000519858011 2025-01-01 14:53:53        empty
# 534525  zcrm_3584690000520178108 2025-01-08 05:01:29        empty
# 534526  zcrm_3584690000520542015 2025-01-10 15:24:39        empty
# 534527  zcrm_3584690000525736001 2025-02-26 04:14:09        empty
#
#                First Name   Last Name                               Email  \
# 0              Ht Chandra     N Usman               ichan051163@gmail.com
# 1                   Endah     Haryani              awal.endah83@gmail.com
# 2            Alda Beatrix   Wattimena           aldabeatrix.abw@gmail.com
# 3                    Rini     Siregar            rini.siregar21@gmail.com
# 4       Christine Marylin     Effendi          christinemarylin@gmail.com
# ...                   ...         ...                                 ...
# 534523               Matt  Harrington               matt_lah@yahoo.com.sg
# 534524              scott    atkinson         scottatkinson1979@gmail.com
# 534525                kat      Pearce                    kwp744@gmail.com
# 534526              Halie     Johnson            haliebabie1209@gmail.com
# 534527               Gary     Charles  garycharles@dominatingkeywords.com
#
#                 Phone      Mobile   Birthdate Year of Birth  ... Lead Regions  \
# 0        628116190115  8126542115  1963-01-01          1963  ...         SEAP
# 1         87888802700       empty  1983-01-01          1983  ...         SEAP
# 2       6285344502233       empty  1986-01-01          1986  ...         SEAP
# 3         87888282359       empty       empty         empty  ...         SEAP
# 4               empty       empty       empty         empty  ...         SEAP
# ...               ...         ...         ...           ...  ...          ...
# 534523    61458827899       empty       empty          2009  ...         SEAP
# 534524   610419918057       empty       empty          1980  ...         SEAP
# 534525   610412929135       empty       empty          1970  ...         SEAP
# 534526   612019402400       empty       empty         empty  ...         SEAP
# 534527   618054002077       empty       empty         empty  ...         SEAP
#
#           Lead Status Booking Status BookRef Email Opt Out Opt In  \
# 0               empty          empty   empty         empty  empty
# 1               empty          empty   empty         empty  empty
# 2               empty          empty   empty         empty  empty
# 3               empty          empty   empty         empty  empty
# 4               empty          empty   empty         empty  empty
# ...               ...            ...     ...           ...    ...
# 534523  Not Qualified          empty   empty         false  false
# 534524   Hot Prospect          empty   empty         false  false
# 534525   Hot Prospect          empty   empty         false  false
# 534526       New Lead          empty   empty         false  false
# 534527       New Lead          empty   empty         false  false
#
#        GDPR Compliant Website Comments Do you live in Bali?
# 0               empty   empty    empty                empty
# 1               empty   empty    empty                empty
# 2               empty   empty    empty                empty
# 3               empty   empty    empty                empty
# 4               empty   empty    empty                empty
# ...               ...     ...      ...                  ...
# 534523          false   empty    empty                false
# 534524          false   empty    empty                false
# 534525          false   empty    empty                false
# 534526          false   empty    empty                false
# 534527          false   empty    empty                false
#
# [534528 rows x 35 columns]

# %%
# Cek leads test
test_leads = zoho_df.loc[
    
        zoho_df['Email'].str.contains('^test@', flags=re.I, regex=True) |
        zoho_df['Email'].str.contains('\+test', flags=re.I, regex=True) |
    
        zoho_df['First Name'].str.contains('^test$', flags=re.I, regex=True) |
        zoho_df['Last Name'].str.contains('^test$', flags=re.I, regex=True) |

        zoho_df['First Name'].str.contains('test 1', flags=re.I, regex=True) |
        zoho_df['Last Name'].str.contains('test 2', flags=re.I, regex=True)|
        zoho_df['First Name'].str.contains('test1', flags=re.I, regex=True) |
        zoho_df['Last Name'].str.contains('test2', flags=re.I, regex=True)|

        zoho_df['First Name'].str.contains(' test ', flags=re.I, regex=True) | 
        zoho_df['Last Name'].str.contains(' test ', flags=re.I, regex=True) | 
        zoho_df['Last Name'].str.contains(' test$', flags=re.I, regex=True)
    ]

count_leads_test = test_leads.shape[0]

# test_leads.to_excel(r'C:\Users\fajar.fatoni\Documents\Python\Data\test_leads_2.xlsx', index=False)
test_leads
# Out:
#                        Record Id        Created Time Created Date First Name  \
# 28144   zcrm_3584690000006082754 2019-04-02 03:11:29   2015-05-12      empty
# 28145   zcrm_3584690000006082755 2019-04-02 03:11:29   2015-05-12      empty
# 28146   zcrm_3584690000006082758 2019-04-02 03:11:29   2015-05-12    Michael
# 28147   zcrm_3584690000006082759 2019-04-02 03:11:29   2015-05-12    Hosanna
# 28148   zcrm_3584690000006082761 2019-04-02 03:11:29   2015-05-12      empty
# 28149   zcrm_3584690000006082763 2019-04-02 03:11:29   2015-05-12      empty
# 28150   zcrm_3584690000006082765 2019-04-02 03:11:29   2015-05-12      empty
# 178855  zcrm_3584690000007514372 2019-04-02 06:05:24   2015-04-14     14rose
# 178856  zcrm_3584690000007514374 2019-04-02 06:05:24   2015-05-12      empty
# 178857  zcrm_3584690000007514375 2019-04-02 06:05:24   2015-05-12      empty
# 178858  zcrm_3584690000007514378 2019-04-02 06:05:24   2015-05-12      empty
# 311114  zcrm_3584690000132257487 2019-10-15 16:56:54        empty        eka
# 380698  zcrm_3584690000208472763 2020-08-01 09:35:15        empty       Test
# 443978  zcrm_3584690000346106113 2022-02-17 14:57:37        empty       TEST
# 494896  zcrm_3584690000411589404 2022-11-18 14:55:40        empty    Herlina
# 500140  zcrm_3584690000414409002 2022-11-30 23:04:39        empty       Test
# 500141  zcrm_3584690000414410041 2022-11-30 22:59:26        empty       Test
# 505210  zcrm_3584690000416977562 2022-12-14 16:07:02        empty       test
# 505642  zcrm_3584690000417318433 2022-12-15 15:41:13        empty      empty
#
#                                     Last Name  \
# 28144                                   empty
# 28145                                   empty
# 28146                                   Angus
# 28147                                 Hosanna
# 28148                                   empty
# 28149                                   empty
# 28150                                   empty
# 178855                                     Is
# 178856                                  empty
# 178857                                  empty
# 178858                                  empty
# 311114                               suryawan
# 380698                                   Test
# 443978                                   test
# 494896                                   test
# 500140                                   Test
# 500141                                   Test
# 505210                                   test
# 505642  <test lead: dummy data for full_name>
#
#                                    Email          Phone         Mobile  \
# 28144                      test@bali.com    61361254566          empty
# 28145                     test@benny.com    61361767767    61361232211
# 28146                   test@hotmail.com        6666666          empty
# 28147                      test@mail.com     6117324567  9718754212356
# 28148                      test@test.net    61361890898          empty
# 28149                     test@tests.com    61909090909          empty
# 28150            test@thebaligetaway.com       40556801          empty
# 178855                 test@14rosein.com          empty          empty
# 178856                      test@bte.com      361765675          empty
# 178857                     test@chooo.fr       11121456          empty
# 178858  test@test-ramadaencore-email.com          empty          empty
# 311114         guseka.dev+test@gmail.com   618123456789          empty
# 380698                    test@gmail.com   628123456789          empty
# 443978     rizkykyledjaelani@outlook.com  6287777101586  6287777101586
# 494896     herlina.priscilla29@gmail.com  6281296778870  6281296778870
# 500140                test.test@test.com        6112345          empty
# 500141                test.test@test.com          12345          empty
# 505210               tetststst@gmail.com    62787777777    62787777777
# 505642                       test@fb.com          empty          empty
#
#          Birthdate Year of Birth  ... Lead Regions    Lead Status  \
# 28144        empty         empty  ...         SEAP          empty
# 28145        empty         empty  ...         SEAP          empty
# 28146        empty         empty  ...         SEAP          empty
# 28147   1989-09-11          1989  ...        Other          empty
# 28148        empty         empty  ...         SEAP          empty
# 28149        empty         empty  ...         SEAP          empty
# 28150        empty         empty  ...         SEAP          empty
# 178855       empty         empty  ...         SEAP          empty
# 178856       empty         empty  ...         SEAP          empty
# 178857       empty         empty  ...         SEAP          empty
# 178858       empty         empty  ...         SEAP          empty
# 311114  1964-10-01          1964  ...         SEAP          empty
# 380698       empty         empty  ...         SEAP          empty
# 443978       empty          1979  ...         SEAP   Hot Prospect
# 494896  1998-10-29         empty  ...        empty          empty
# 500140       empty          1994  ...         SEAP   Hot Prospect
# 500141       empty         empty  ...         SEAP   Hot Prospect
# 505210  2022-12-14          2022  ...         SEAP  Not Qualified
# 505642       empty         empty  ...        empty          empty
#
#        Booking Status BookRef Email Opt Out Opt In GDPR Compliant Website  \
# 28144           empty   empty         empty  empty          empty   empty
# 28145           empty   empty         empty  empty          empty   empty
# 28146           empty   empty         empty  empty          empty   empty
# 28147           empty   empty         empty  empty          empty   empty
# 28148           empty   empty         empty  empty          empty   empty
# 28149           empty   empty         empty  empty          empty   empty
# 28150           empty   empty         empty  empty          empty   empty
# 178855          empty   empty         empty  empty          empty   empty
# 178856          empty   empty         empty  empty          empty   empty
# 178857          empty   empty         empty  empty          empty   empty
# 178858          empty   empty         empty  empty          empty   empty
# 311114          empty   empty         empty  empty          empty   empty
# 380698          empty   empty         empty  empty          empty   empty
# 443978          empty   empty         empty  empty          empty   empty
# 494896          empty   empty         empty  empty          empty   empty
# 500140          empty   empty         empty  empty          empty   empty
# 500141          empty   empty         empty  empty          empty   empty
# 505210          empty   empty         empty  empty          empty   empty
# 505642          empty   empty         empty  empty          empty   empty
#
#        Comments Do you live in Bali?
# 28144     empty                empty
# 28145     empty                empty
# 28146     empty                empty
# 28147     empty                empty
# 28148     empty                empty
# 28149     empty                empty
# 28150     empty                empty
# 178855    empty                empty
# 178856    empty                empty
# 178857    empty                empty
# 178858    empty                empty
# 311114    empty                empty
# 380698    empty                empty
# 443978    empty                empty
# 494896    empty                empty
# 500140    empty                empty
# 500141    empty                empty
# 505210    empty                empty
# 505642    empty                empty
#
# [19 rows x 35 columns]

# %%
zoho_df.drop(test_leads.index, inplace=True)
zoho_df.reset_index(drop=True, inplace=True)

count_after_dedup_test = zoho_df.shape[0]

# %%
# dnm_leads = zoho_df.loc[(zoho_df['Do Not Mail'] == 'true') | (zoho_df['Do Not Contact'] == 'true')]
# count_dnm = dnm_leads.shape[0]

# %%
# zoho_df.drop(dnm_leads.index, inplace=True)
# zoho_df.reset_index(drop=True, inplace=True)

# count_after_dedup_dnm = zoho_df.shape[0]

# %%
# Cek Email OTA
email_OTA = m.find_OTA(zoho_df, 'Email')
count_email_OTA = email_OTA.shape[0]
# email_OTA.to_excel(r'C:\Users\fajar.fatoni\Documents\Python\Data\email_OTA.xlsx', index=False)

email_OTA
# Out:
#                        Record Id        Created Time Created Date  \
# 938     zcrm_3584690000000657181 2019-01-13 06:55:40        empty
# 2194    zcrm_3584690000000668331 2019-01-13 15:50:42        empty
# 2413    zcrm_3584690000000670403 2019-01-13 17:40:08        empty
# 2776    zcrm_3584690000000706621 2019-01-17 01:35:43        empty
# 2892    zcrm_3584690000000708359 2019-01-16 08:48:15        empty
# ...                          ...                 ...          ...
# 518796  zcrm_3584690000422787209 2023-01-14 07:30:46        empty
# 520473  zcrm_3584690000423027034 2023-01-16 15:34:11        empty
# 522387  zcrm_3584690000423791301 2023-01-21 09:47:48        empty
# 524590  zcrm_3584690000424740220 2023-01-26 09:54:41        empty
# 532466  zcrm_3584690000430855268 2023-02-23 07:14:24        empty
#
#                First Name         Last Name                            Email  \
# 938     Yohanes Pamungkas           Santoso       yohanes@smailingtour.co.id
# 2194               Silvia             Utami       glorietourpadang@gmail.com
# 2413                 Moen              Moen              moen.tour@yahoo.com
# 2776                Anang       Hardiansyah  selebritis.tourtravel@gmail.com
# 2892             Yulianto              Budi          tours_permata@yahoo.com
# ...                   ...               ...                              ...
# 518796                Eny           Cahyani        enyms.tourism28@gmail.com
# 520473              RISMA       BORU TAMBUN     axltourtravelbatam@gmail.com
# 522387             Darwin           Witarsa           qtourslombok@gmail.com
# 524590              empty  Robyn Letourneau          rletourneau@bigpond.com
# 532466             Victor             Vabio       pasiartourtravel@yahoo.com
#
#                 Phone         Mobile   Birthdate Year of Birth  ...  \
# 938        8158082392          empty  1981-09-14          1981  ...
# 2194      87877744428          empty  1962-03-25          1962  ...
# 2413      81219991033          empty  1982-01-01          1982  ...
# 2776      89681821456          empty  1989-01-01          1989  ...
# 2892    6282233295200          empty  1986-01-01          1986  ...
# ...               ...            ...         ...           ...  ...
# 518796  6282247755757  6282247755757  1990-09-28          1990  ...
# 520473  6281364723772  6281364723772  1974-10-17          1974  ...
# 522387  6282144304565  6282144304565  1981-06-06          1981  ...
# 524590   610402008495          empty  1962-04-23         empty  ...
# 532466  6285358856161  6285358856161  1990-03-30          1990  ...
#
#        Lead Regions   Lead Status Booking Status BookRef Email Opt Out Opt In  \
# 938            SEAP         empty          empty   empty         empty  empty
# 2194           SEAP         empty          empty   empty         empty  empty
# 2413           SEAP         empty          empty   empty         empty  empty
# 2776           SEAP         empty          empty   empty         empty  empty
# 2892           SEAP         empty          empty   empty         empty  empty
# ...             ...           ...            ...     ...           ...    ...
# 518796         SEAP  Hot Prospect          empty   empty         empty  empty
# 520473         SEAP  Hot Prospect          empty   empty         empty  empty
# 522387         SEAP  Hot Prospect          empty   empty         empty  empty
# 524590        empty         empty          empty   empty         empty  empty
# 532466         SEAP  Hot Prospect          empty   empty         empty  empty
#
#        GDPR Compliant Website Comments Do you live in Bali?
# 938             empty   empty    empty                empty
# 2194            empty   empty    empty                empty
# 2413            empty   empty    empty                empty
# 2776            empty   empty    empty                empty
# 2892            empty   empty    empty                empty
# ...               ...     ...      ...                  ...
# 518796          empty   empty    empty                empty
# 520473          empty   empty    empty                empty
# 522387          empty   empty    empty                empty
# 524590          empty   empty    empty                empty
# 532466          empty   empty    empty                empty
#
# [384 rows x 35 columns]

# %%
# delete email OTA
count_after_clean_OTA = m.delete_OTA(zoho_df, 'Email')
# zoho_df.to_excel(r'C:\Users\fajar.fatoni\Documents\Python\Data\after_clean_OTA.xlsx', index=False)

zoho_df
# Out:
#                        Record Id        Created Time Created Date  \
# 0       zcrm_3584690000000408007 2019-01-07 13:29:59        empty
# 1       zcrm_3584690000000408013 2019-01-07 17:22:27        empty
# 2       zcrm_3584690000000408020 2019-01-07 18:22:28        empty
# 3       zcrm_3584690000000408026 2019-01-07 20:07:11        empty
# 4       zcrm_3584690000000409019 2019-01-07 15:00:14        empty
# ...                          ...                 ...          ...
# 534120  zcrm_3584690000510697002 2024-10-02 14:15:31        empty
# 534121  zcrm_3584690000519858011 2025-01-01 14:53:53        empty
# 534122  zcrm_3584690000520178108 2025-01-08 05:01:29        empty
# 534123  zcrm_3584690000520542015 2025-01-10 15:24:39        empty
# 534124  zcrm_3584690000525736001 2025-02-26 04:14:09        empty
#
#                First Name   Last Name                               Email  \
# 0              Ht Chandra     N Usman               ichan051163@gmail.com
# 1                   Endah     Haryani              awal.endah83@gmail.com
# 2            Alda Beatrix   Wattimena           aldabeatrix.abw@gmail.com
# 3                    Rini     Siregar            rini.siregar21@gmail.com
# 4       Christine Marylin     Effendi          christinemarylin@gmail.com
# ...                   ...         ...                                 ...
# 534120               Matt  Harrington               matt_lah@yahoo.com.sg
# 534121              scott    atkinson         scottatkinson1979@gmail.com
# 534122                kat      Pearce                    kwp744@gmail.com
# 534123              Halie     Johnson            haliebabie1209@gmail.com
# 534124               Gary     Charles  garycharles@dominatingkeywords.com
#
#                 Phone      Mobile   Birthdate Year of Birth  ... Lead Regions  \
# 0        628116190115  8126542115  1963-01-01          1963  ...         SEAP
# 1         87888802700       empty  1983-01-01          1983  ...         SEAP
# 2       6285344502233       empty  1986-01-01          1986  ...         SEAP
# 3         87888282359       empty       empty         empty  ...         SEAP
# 4               empty       empty       empty         empty  ...         SEAP
# ...               ...         ...         ...           ...  ...          ...
# 534120    61458827899       empty       empty          2009  ...         SEAP
# 534121   610419918057       empty       empty          1980  ...         SEAP
# 534122   610412929135       empty       empty          1970  ...         SEAP
# 534123   612019402400       empty       empty         empty  ...         SEAP
# 534124   618054002077       empty       empty         empty  ...         SEAP
#
#           Lead Status Booking Status BookRef Email Opt Out Opt In  \
# 0               empty          empty   empty         empty  empty
# 1               empty          empty   empty         empty  empty
# 2               empty          empty   empty         empty  empty
# 3               empty          empty   empty         empty  empty
# 4               empty          empty   empty         empty  empty
# ...               ...            ...     ...           ...    ...
# 534120  Not Qualified          empty   empty         false  false
# 534121   Hot Prospect          empty   empty         false  false
# 534122   Hot Prospect          empty   empty         false  false
# 534123       New Lead          empty   empty         false  false
# 534124       New Lead          empty   empty         false  false
#
#        GDPR Compliant Website Comments Do you live in Bali?
# 0               empty   empty    empty                empty
# 1               empty   empty    empty                empty
# 2               empty   empty    empty                empty
# 3               empty   empty    empty                empty
# 4               empty   empty    empty                empty
# ...               ...     ...      ...                  ...
# 534120          false   empty    empty                false
# 534121          false   empty    empty                false
# 534122          false   empty    empty                false
# 534123          false   empty    empty                false
# 534124          false   empty    empty                false
#
# [534125 rows x 35 columns]

# %%
# Cek Email Karma
email_karma = m.find_karma(zoho_df, 'Email')
count_email_karma = email_karma.shape[0]
# email_OTA.to_excel(r'C:\Users\fajar.fatoni\Documents\Python\Data\email_OTA.xlsx', index=False)

email_karma
# Out:
#                        Record Id        Created Time Created Date  \
# 12587   zcrm_3584690000002492722 2019-02-22 14:51:05        empty
# 30350   zcrm_3584690000006087837 2019-04-02 03:11:56   2015-05-12
# 47378   zcrm_3584690000006128606 2019-04-02 03:15:42   2015-05-12
# 63195   zcrm_3584690000006167006 2019-04-02 03:19:20   2015-05-12
# 70612   zcrm_3584690000006184540 2019-04-02 03:21:02   2017-02-13
# 72024   zcrm_3584690000006187636 2019-04-02 03:21:20   2015-03-18
# 72037   zcrm_3584690000006187649 2019-04-02 03:21:20   2015-05-12
# 83316   zcrm_3584690000006220962 2019-04-02 03:24:41   2015-03-10
# 83792   zcrm_3584690000006222148 2019-04-02 03:24:49   2015-05-12
# 128444  zcrm_3584690000007412007 2019-04-02 05:55:30   2018-11-20
# 137286  zcrm_3584690000007429978 2019-04-02 05:57:08   2015-05-12
# 141194  zcrm_3584690000007437877 2019-04-02 05:57:51   2015-05-12
# 146563  zcrm_3584690000007448810 2019-04-02 05:58:51   2015-08-20
# 146564  zcrm_3584690000007448913 2019-04-02 05:58:53   2015-08-20
# 199827  zcrm_3584690000007557407 2019-04-02 06:09:56   2015-07-29
# 256683  zcrm_3584690000029298161 2019-05-08 09:54:02        empty
# 274046  zcrm_3584690000071703656 2019-07-15 15:31:05        empty
# 276337  zcrm_3584690000079416727 2019-07-22 10:22:05        empty
# 289436  zcrm_3584690000101159142 2019-08-20 17:19:58        empty
# 290163  zcrm_3584690000101304458 2019-08-20 17:20:07        empty
# 291849  zcrm_3584690000101307967 2019-08-20 17:20:33        empty
# 291850  zcrm_3584690000101307968 2019-08-20 17:20:33        empty
# 291851  zcrm_3584690000101307969 2019-08-20 17:20:33        empty
# 291852  zcrm_3584690000101307970 2019-08-20 17:20:33        empty
# 291853  zcrm_3584690000101307971 2019-08-20 17:20:33        empty
# 291854  zcrm_3584690000101307972 2019-08-20 17:20:33        empty
# 291855  zcrm_3584690000101307973 2019-08-20 17:20:33        empty
# 292415  zcrm_3584690000101309140 2019-08-20 17:20:41        empty
# 292673  zcrm_3584690000101309601 2019-08-20 17:20:44        empty
# 292738  zcrm_3584690000101309666 2019-08-20 17:20:44        empty
# 293085  zcrm_3584690000101310419 2019-08-20 17:20:50        empty
# 296830  zcrm_3584690000106114375 2019-08-27 12:05:29        empty
# 330512  zcrm_3584690000150395320 2019-10-02 16:14:31        empty
# 425162  zcrm_3584690000313730122 2021-09-10 19:32:37        empty
# 434372  zcrm_3584690000330651573 2021-12-12 01:54:49        empty
# 434455  zcrm_3584690000330670624 2021-12-12 01:52:18        empty
# 483568  zcrm_3584690000404712043 2022-10-14 05:14:52        empty
#
#                  First Name            Last Name  \
# 12587                  Reza       Bintang Aurora
# 30350                 empty                empty
# 47378                 empty                empty
# 63195                 empty                empty
# 70612                Shally               Shally
# 72024                 empty                  Tom
# 72037                 empty                empty
# 83316                  Mark             Burkster
# 83792                 empty                empty
# 128444                  Tes                  Tes
# 137286              Alfredo          Pangaribuan
# 141194               Antien              Ritonga
# 146563                empty                empty
# 146564                empty                empty
# 199827                empty                empty
# 256683                empty               Wannee
# 274046                 Sami              Benafia
# 276337                 Sami              benafia
# 289436              Clinton          Albuquerque
# 290163              Richard                    D
# 291849                empty                empty
# 291850                empty                empty
# 291851                empty                empty
# 291852                empty                empty
# 291853                empty                empty
# 291854                empty                empty
# 291855                empty                empty
# 292415                empty                empty
# 292673             Samantha             Pennance
# 292738                empty             Ponidjan
# 293085                empty                 Sean
# 296830               Jaykee             Bautista
# 330512  baligetawaydeal.com  baligetawaydeal.com
# 425162           Nama Depan        Nama Belakang
# 434372                depan             belakang
# 434455           Nama depan        Nama belakang
# 483568                 Ilmo                  Ott
#
#                                           Email               Phone  \
# 12587           reza.bintang@thebaligetaway.com          8113961761
# 30350               itdept@royalperspective.com          6235157821
# 47378                bhanu@royalperspective.com      61412123123123
# 63195           lee+baligetawaycomau@ccp.com.au         61400481632
# 70612                 shally@thebaligetaway.com               empty
# 72024                  tom@royalperspective.com          9809854208
# 72037                 tom2@royalperspective.com         61143143541
# 83316             mark.burke@thebaligetaway.com          6199999999
# 83792                  matt@trhebaligetaway.com         81111222333
# 128444           arif.alhana@thebaligetaway.com              181727
# 137286               alfredo@thebaligetaway.com         87860581444
# 141194        antien.ritonga@thebaligetaway.com               empty
# 146563                3232@royalperspective.com           361245789
# 146564              323212@royalperspective.com           361245789
# 199827           wayan.wirka@odysseypremier.com               empty
# 256683              putrilagi@baligetaway.co.id          0218765432
# 274046               sam.benafia@hotel.discount         61123456789
# 276337           sam.benafia@thebaligetaway.com         61123456789
# 289436  clinton.albuquerque@karmaroyalgroup.com               empty
# 290163           ric.hallam@karmaroyalgroup.com               empty
# 291849                 aaron@thebaligetaway.com               empty
# 291850                daniel@thebaligetaway.com               empty
# 291851                 joyce@thebaligetaway.com               empty
# 291852                  liam@thebaligetaway.com               empty
# 291853             michael_s@thebaligetaway.com               empty
# 291854                 moses@thebaligetaway.com               empty
# 291855                   rob@thebaligetaway.com               empty
# 292415      matt.heslington@karmaroyalgroup.com               empty
# 292673                  sam@karmaroyalgroup.com         61416928269
# 292738                     rdm@karmakandara.com               empty
# 293085                 sean@karmaroyalgroup.com               empty
# 296830           jaykee.bautista@hotel.discount        639558478015
# 330512           baligetawaydeal.com@domstat.su               empty
# 425162                  email@baligetaway.co.id  628888888888888888
# 434372                    baligetaway@gmail.com        628123456789
# 434455                prikitiew@baligetaway.com       6281111111111
# 483568         ilmo.ott+baligetaway@hotmail.com         61450381573
#
#                     Mobile   Birthdate Year of Birth  ... Lead Regions  \
# 12587                empty       empty          1980  ...         SEAP
# 30350                empty       empty         empty  ...         SEAP
# 47378                empty       empty         empty  ...         SEAP
# 63195                empty       empty         empty  ...         SEAP
# 70612                empty       empty         empty  ...         SEAP
# 72024                empty       empty         empty  ...         SEAP
# 72037                empty       empty         empty  ...         SEAP
# 83316          12152266666       empty         empty  ...         SEAP
# 83792                empty       empty         empty  ...         SEAP
# 128444               empty  1986-01-01          1986  ...         SEAP
# 137286               empty       empty         empty  ...         SEAP
# 141194               empty       empty         empty  ...         SEAP
# 146563               empty       empty         empty  ...         SEAP
# 146564               empty       empty         empty  ...         SEAP
# 199827               empty       empty         empty  ...         SEAP
# 256683          0218765432       empty          1920  ...         SEAP
# 274046               empty  1968-07-07          1968  ...         SEAP
# 276337               empty  1968-07-07          1968  ...         SEAP
# 289436               empty       empty         empty  ...         SEAP
# 290163               empty       empty         empty  ...         SEAP
# 291849               empty       empty         empty  ...         SEAP
# 291850               empty       empty         empty  ...         SEAP
# 291851               empty       empty         empty  ...         SEAP
# 291852               empty       empty         empty  ...         SEAP
# 291853               empty       empty         empty  ...         SEAP
# 291854               empty       empty         empty  ...         SEAP
# 291855               empty       empty         empty  ...         SEAP
# 292415               empty       empty         empty  ...         SEAP
# 292673               empty       empty         empty  ...         SEAP
# 292738               empty       empty         empty  ...         SEAP
# 293085               empty       empty         empty  ...         SEAP
# 296830               empty  1988-01-19          1988  ...        Other
# 330512               empty       empty         empty  ...    UK/Europe
# 425162  628888888888888888       empty          2011  ...         SEAP
# 434372        628123456789       empty          2007  ...         SEAP
# 434455       6281111111111       empty          2007  ...         SEAP
# 483568               empty  1995-11-02         empty  ...         SEAP
#
#           Lead Status Booking Status BookRef Email Opt Out Opt In  \
# 12587           empty          empty   empty         empty  empty
# 30350           empty          empty   empty         empty  empty
# 47378           empty          empty   empty         empty  empty
# 63195           empty          empty   empty         empty  empty
# 70612           empty          empty   empty         empty  empty
# 72024           empty          empty   empty         empty  empty
# 72037           empty          empty   empty         empty  empty
# 83316           empty          empty   empty         empty  empty
# 83792           empty          empty   empty         empty  empty
# 128444          empty          empty   empty         empty  empty
# 137286          empty          empty   empty         empty  empty
# 141194          empty          empty   empty         empty  empty
# 146563          empty          empty   empty         empty  empty
# 146564          empty          empty   empty         empty  empty
# 199827          empty          empty   empty         empty  empty
# 256683  Not Qualified          empty   empty         empty  empty
# 274046          empty          empty   empty         empty  empty
# 276337          empty          empty   empty         empty  empty
# 289436       New Lead          empty   empty         empty  empty
# 290163       New Lead          empty   empty         empty  empty
# 291849       New Lead          empty   empty         empty  empty
# 291850       New Lead          empty   empty         empty  empty
# 291851       New Lead          empty   empty         empty  empty
# 291852       New Lead          empty   empty         empty  empty
# 291853       New Lead          empty   empty         empty  empty
# 291854       New Lead          empty   empty         empty  empty
# 291855       New Lead          empty   empty         empty  empty
# 292415       New Lead          empty   empty         empty  empty
# 292673       New Lead          empty   empty         empty  empty
# 292738       New Lead          empty   empty         empty  empty
# 293085       New Lead          empty   empty         empty  empty
# 296830          empty          empty   empty         empty  empty
# 330512          empty          empty   empty         empty  empty
# 425162  Not Qualified          empty   empty         empty  empty
# 434372  Not Qualified          empty   empty         empty  empty
# 434455  Not Qualified          empty   empty         empty  empty
# 483568   Hot Prospect          empty   empty         empty  empty
#
#        GDPR Compliant Website Comments Do you live in Bali?
# 12587           empty   empty    empty                empty
# 30350           empty   empty    empty                empty
# 47378           empty   empty    empty                empty
# 63195           empty   empty    empty                empty
# 70612           empty   empty    empty                empty
# 72024           empty   empty    empty                empty
# 72037           empty   empty    empty                empty
# 83316           empty   empty    empty                empty
# 83792           empty   empty    empty                empty
# 128444          empty   empty    empty                empty
# 137286          empty   empty    empty                empty
# 141194          empty   empty    empty                empty
# 146563          empty   empty    empty                empty
# 146564          empty   empty    empty                empty
# 199827          empty   empty    empty                empty
# 256683          empty   empty    empty                empty
# 274046          empty   empty    empty                empty
# 276337          empty   empty    empty                empty
# 289436          empty   empty    empty                empty
# 290163          empty   empty    empty                empty
# 291849          empty   empty    empty                empty
# 291850          empty   empty    empty                empty
# 291851          empty   empty    empty                empty
# 291852          empty   empty    empty                empty
# 291853          empty   empty    empty                empty
# 291854          empty   empty    empty                empty
# 291855          empty   empty    empty                empty
# 292415          empty   empty    empty                empty
# 292673          empty   empty    empty                empty
# 292738          empty   empty    empty                empty
# 293085          empty   empty    empty                empty
# 296830          empty   empty    empty                empty
# 330512          empty   empty    empty                empty
# 425162          empty   empty    empty                empty
# 434372          empty   empty    empty                empty
# 434455          empty   empty    empty                empty
# 483568          empty   empty    empty                empty
#
# [37 rows x 35 columns]

# %%
# delete email Karma
count_after_clean_karma = m.delete_karma(zoho_df, 'Email')
# zoho_df.to_excel(r'C:\Users\fajar.fatoni\Documents\Python\Data\after_clean_OTA.xlsx', index=False)

zoho_df
# Out:
#                        Record Id        Created Time Created Date  \
# 0       zcrm_3584690000000408007 2019-01-07 13:29:59        empty
# 1       zcrm_3584690000000408013 2019-01-07 17:22:27        empty
# 2       zcrm_3584690000000408020 2019-01-07 18:22:28        empty
# 3       zcrm_3584690000000408026 2019-01-07 20:07:11        empty
# 4       zcrm_3584690000000409019 2019-01-07 15:00:14        empty
# ...                          ...                 ...          ...
# 534083  zcrm_3584690000510697002 2024-10-02 14:15:31        empty
# 534084  zcrm_3584690000519858011 2025-01-01 14:53:53        empty
# 534085  zcrm_3584690000520178108 2025-01-08 05:01:29        empty
# 534086  zcrm_3584690000520542015 2025-01-10 15:24:39        empty
# 534087  zcrm_3584690000525736001 2025-02-26 04:14:09        empty
#
#                First Name   Last Name                               Email  \
# 0              Ht Chandra     N Usman               ichan051163@gmail.com
# 1                   Endah     Haryani              awal.endah83@gmail.com
# 2            Alda Beatrix   Wattimena           aldabeatrix.abw@gmail.com
# 3                    Rini     Siregar            rini.siregar21@gmail.com
# 4       Christine Marylin     Effendi          christinemarylin@gmail.com
# ...                   ...         ...                                 ...
# 534083               Matt  Harrington               matt_lah@yahoo.com.sg
# 534084              scott    atkinson         scottatkinson1979@gmail.com
# 534085                kat      Pearce                    kwp744@gmail.com
# 534086              Halie     Johnson            haliebabie1209@gmail.com
# 534087               Gary     Charles  garycharles@dominatingkeywords.com
#
#                 Phone      Mobile   Birthdate Year of Birth  ... Lead Regions  \
# 0        628116190115  8126542115  1963-01-01          1963  ...         SEAP
# 1         87888802700       empty  1983-01-01          1983  ...         SEAP
# 2       6285344502233       empty  1986-01-01          1986  ...         SEAP
# 3         87888282359       empty       empty         empty  ...         SEAP
# 4               empty       empty       empty         empty  ...         SEAP
# ...               ...         ...         ...           ...  ...          ...
# 534083    61458827899       empty       empty          2009  ...         SEAP
# 534084   610419918057       empty       empty          1980  ...         SEAP
# 534085   610412929135       empty       empty          1970  ...         SEAP
# 534086   612019402400       empty       empty         empty  ...         SEAP
# 534087   618054002077       empty       empty         empty  ...         SEAP
#
#           Lead Status Booking Status BookRef Email Opt Out Opt In  \
# 0               empty          empty   empty         empty  empty
# 1               empty          empty   empty         empty  empty
# 2               empty          empty   empty         empty  empty
# 3               empty          empty   empty         empty  empty
# 4               empty          empty   empty         empty  empty
# ...               ...            ...     ...           ...    ...
# 534083  Not Qualified          empty   empty         false  false
# 534084   Hot Prospect          empty   empty         false  false
# 534085   Hot Prospect          empty   empty         false  false
# 534086       New Lead          empty   empty         false  false
# 534087       New Lead          empty   empty         false  false
#
#        GDPR Compliant Website Comments Do you live in Bali?
# 0               empty   empty    empty                empty
# 1               empty   empty    empty                empty
# 2               empty   empty    empty                empty
# 3               empty   empty    empty                empty
# 4               empty   empty    empty                empty
# ...               ...     ...      ...                  ...
# 534083          false   empty    empty                false
# 534084          false   empty    empty                false
# 534085          false   empty    empty                false
# 534086          false   empty    empty                false
# 534087          false   empty    empty                false
#
# [534088 rows x 35 columns]

# %%
find_member_booking = zoho_df.copy()

find_member_booking.loc[find_member_booking['Phone'].isin(df_booking['Phone1']), 'Same Value Find'] = 'Booking-Phone1'
find_member_booking.loc[find_member_booking['Phone'].isin(df_booking['Mobile']), 'Same Value Find'] = 'Booking-Mobile'
find_member_booking.loc[find_member_booking['Mobile'].isin(df_booking['Phone1']), 'Same Value Find'] = 'Booking-Phone1' 
find_member_booking.loc[find_member_booking['Mobile'].isin(df_booking['Mobile']), 'Same Value Find'] = 'Booking-Mobile'
find_member_booking.loc[find_member_booking['Email'].isin(df_booking['Email']), 'Same Value Find'] = 'Booking-Email'

find_member_booking.loc[find_member_booking['Phone'].isin(df_phone['Mobile']), 'Same Value Find'] = 'Member-Mobile' 
find_member_booking.loc[find_member_booking['Mobile'].isin(df_phone['Mobile']), 'Same Value Find'] = 'Member-Mobile'

find_member_booking.loc[find_member_booking['Email'].isin(df_email['Email']), 'Same Value Find'] = 'Member-Email'

find_member_booking.drop(find_member_booking.loc[find_member_booking['Same Value Find'].isna()].index, inplace=True)

count_booking_dedup = find_member_booking.loc[find_member_booking['Same Value Find'].str.contains('Booking', flags=re.I, regex=True)].shape[0]
count_member_dedup = find_member_booking.loc[find_member_booking['Same Value Find'].str.contains('Member', flags=re.I, regex=True)].shape[0]

find_member_booking.replace('empty', '', inplace=True)
# find_member_booking.to_csv(r'C:\Users\fajar.fatoni\Documents\Python\Data\booking-member-dedup.csv', index=False)
# find_member_booking.to_excel(r'C:\Users\fajar.fatoni\Documents\Python\Data\booking-member-dedup.xlsx', index=False)

#find_member_booking.loc[find_member_booking['Same Value Find'] == 'Booking-Phone1']

# %%
# data phone, mobile dam email member yang ada di master data 
count_wash_member = zoho_df.loc[
    zoho_df['Phone'].isin(df_booking['Phone1']) | 
    zoho_df['Phone'].isin(df_booking['Mobile']) |
    zoho_df['Mobile'].isin(df_booking['Phone1']) | 
    zoho_df['Mobile'].isin(df_booking['Mobile']) |
    zoho_df['Email'].isin(df_booking['Email'])| 

    zoho_df['Phone'].isin(df_phone['Mobile']) | 
    zoho_df['Mobile'].isin(df_phone['Mobile']) |

    zoho_df['Email'].isin(df_email['Email'])

].shape[0]

zoho_df.drop(zoho_df.loc[
    zoho_df['Phone'].isin(df_booking['Phone1']) | 
    zoho_df['Phone'].isin(df_booking['Mobile']) |
    zoho_df['Mobile'].isin(df_booking['Phone1']) | 
    zoho_df['Mobile'].isin(df_booking['Mobile']) |
    zoho_df['Email'].isin(df_booking['Email']) |
    
    zoho_df['Phone'].isin(df_phone['Mobile']) | 
    zoho_df['Mobile'].isin(df_phone['Mobile']) |

    zoho_df['Email'].isin(df_email['Email'])

    ].index, inplace=True)
    
zoho_df.reset_index(drop=True, inplace=True)

count_after_wash_member = zoho_df.shape[0]

# %%
count_email_only = zoho_df.loc[(zoho_df['Email'] != 'empty') & ((zoho_df['Phone'] == 'empty') & (zoho_df['Mobile'] == 'empty'))].shape[0]
count_phone_only = zoho_df.loc[(zoho_df['Email'] == 'empty') & ((zoho_df['Phone'] != 'empty') | (zoho_df['Mobile'] != 'empty'))].shape[0]
count_email_and_phone = zoho_df.loc[(zoho_df['Email'] != 'empty') & ((zoho_df['Phone'] != 'empty') | (zoho_df['Mobile'] != 'empty'))].shape[0]

count_blank = zoho_df.loc[(zoho_df['Email'] =='empty') & (zoho_df['Phone']=='empty') & (zoho_df['Mobile']=='empty')].shape[0]

# zoho_df.loc[(zoho_df['Email'] =='empty') & (zoho_df['Phone']=='empty') & (zoho_df['Mobile']=='empty')].to_excel(r'C:\Users\fajar.fatoni\Documents\Python\Data\blank_data.xlsx', index=False)

zoho_df.loc[(zoho_df['Email'] != 'empty') & ((zoho_df['Phone'] == 'empty') & (zoho_df['Mobile'] == 'empty')), 'Contact Type'] = 'Email Only'
zoho_df.loc[(zoho_df['Email'] == 'empty') & ((zoho_df['Phone'] != 'empty') | (zoho_df['Mobile'] != 'empty')), 'Contact Type'] = 'Phone Only'
zoho_df.loc[(zoho_df['Email'] != 'empty') & ((zoho_df['Phone'] != 'empty') | (zoho_df['Mobile'] != 'empty')), 'Contact Type'] = 'Email and Phone'

zoho_df.drop(zoho_df.loc[(zoho_df['Email'] =='empty') & (zoho_df['Phone']=='empty') & (zoho_df['Mobile']=='empty')].index, inplace=True)
zoho_df.reset_index(drop=True, inplace=True)

count_after_wash_blank = zoho_df.shape[0]

# %%
arr_dedup = [count_deleted_wrong_format, count_duplicate_general, count_leads_test, count_email_OTA, count_email_karma, count_blank]
count_sum_dedup = sum(arr_dedup)
count_sum_dedup
# Out:
# 66053

# %%
print("==========================================================")
print("Summary")
print("==========================================================")
print("Jumlah Keseluruhan Master Zoho : "+str(count_data_awal))
print("Jumlah Filter Leads Awal : "+str(count_filter_awal))
print("Jumlah Format Email Salah : "+str(count_deleted_wrong_format))
print("Jumlah Setelah Clean Format Email Salah : "+str(count_after_deleted_wrong_format))
print("Jumlah Duplicate (Phone, Mobile dan Email) : "+str(count_duplicate_general))
print("Jumlah Setelah Clean Duplicate : "+str(count_after_dedup_duplicate))
print("Jumlah Lead Test : "+str(count_leads_test))
print("Jumlah Setelah Clean Lead Test : "+str(count_after_dedup_test))
# print("Jumlah Lead Do Not Mail : "+str(count_dnm))
# print("Jumlah Setelah Clean Lead Do Not Mail : "+str(count_after_dedup_dnm))
print("Jumlah Email OTA : "+str(count_email_OTA))
print("Jumlah Setelah Clean Email OTA : "+str(count_after_clean_OTA))
print("Jumlah Email Karma : "+str(count_email_karma))
print("Jumlah Setelah Clean Email Karma : "+str(count_after_clean_karma))
print("Jumlah Wash Member : "+str(count_member_dedup))
print("Jumlah Wash Booking : "+str(count_booking_dedup))
print("Jumlah Setelah Wash Member : "+str(count_after_wash_member))
print("Jumlah Phone Email Blank (Setelah phone yang tidak valid dihapus) : "+str(count_blank))
print("Jumlah Setelah Wash Phone Email Blank : "+str(count_after_wash_blank))
print("==========================================================")
print("Contact Type")
print("==========================================================")
print("Jumlah Email Only : "+str(count_email_only))
print("Jumlah Phone Only : "+str(count_phone_only))
print("Jumlah Email dan Phone : "+str(count_email_and_phone))
# Out:
# ==========================================================
# Summary
# ==========================================================
# Jumlah Keseluruhan Master Zoho : 10030861
# Jumlah Filter Leads Awal : 600141
# Jumlah Format Email Salah : 0
# Jumlah Setelah Clean Format Email Salah : 600141
# Jumlah Duplicate (Phone, Mobile dan Email) : 65613
# Jumlah Setelah Clean Duplicate : 534528
# Jumlah Lead Test : 19
# Jumlah Setelah Clean Lead Test : 534509
# Jumlah Email OTA : 384
# Jumlah Setelah Clean Email OTA : 534125
# Jumlah Email Karma : 37
# Jumlah Setelah Clean Email Karma : 534088
# Jumlah Wash Member : 12298
# Jumlah Wash Booking : 22000
# Jumlah Setelah Wash Member : 499790
# Jumlah Phone Email Blank (Setelah phone yang tidak valid dihapus) : 0
# Jumlah Setelah Wash Phone Email Blank : 499790
# ==========================================================
# Contact Type
# ==========================================================
# Jumlah Email Only : 45084
# Jumlah Phone Only : 0
# Jumlah Email dan Phone : 454706

# %%
print("==========================================================")
print("Summary Report")
print("==========================================================")
print("Jumlah Data Awal : "+str(count_filter_awal))
print("Jumlah Wash Dedup : "+str(count_sum_dedup))
print("Jumlah Wash Member : "+str(count_member_dedup))
print("Jumlah Wash Booking : "+str(count_booking_dedup))
print("Jumlah Data Akhir : "+str(count_after_wash_blank))
# Out:
# ==========================================================
# Summary Report
# ==========================================================
# Jumlah Data Awal : 600141
# Jumlah Wash Dedup : 66053
# Jumlah Wash Member : 12298
# Jumlah Wash Booking : 22000
# Jumlah Data Akhir : 499790

# %% [markdown]
# # ====================== Akhir Filter Umum ======================

# %%
zoho_df.replace('empty', '', inplace=True, regex=True)

zoho_df['First Name'] = zoho_df['First Name'].str.title()
zoho_df['Last Name'] = zoho_df['Last Name'].str.title()

# zoho_df.to_excel(r'C:\Users\fajar.fatoni\Documents\Python\Data\baligateway_all_time.xlsx', index=False)

# %%
zoho_df.groupby('Country').count()
# Out:
#                  Record Id  Created Time  Created Date  First Name  Last Name  \
# Country
#                      13955         13955         13955       13955      13955
# 1                        1             1             1           1          1
# Afghanistan              1             1             1           1          1
# Albania                  3             3             3           3          3
# Algeria                  2             2             2           2          2
# ...                    ...           ...           ...         ...        ...
# raelynn cowan            1             1             1           1          1
# reagan douglas           2             2             2           2          2
# riya li                  4             4             4           4          4
# roselyn flowers          1             1             1           1          1
# zackary bruce            3             3             3           3          3
#
#                  Email  Phone  Mobile  Birthdate  Year of Birth  ...  \
# Country                                                          ...
#                  13955  13955   13955      13955          13955  ...
# 1                    1      1       1          1              1  ...
# Afghanistan          1      1       1          1              1  ...
# Albania              3      3       3          3              3  ...
# Algeria              2      2       2          2              2  ...
# ...                ...    ...     ...        ...            ...  ...
# raelynn cowan        1      1       1          1              1  ...
# reagan douglas       2      2       2          2              2  ...
# riya li              4      4       4          4              4  ...
# roselyn flowers      1      1       1          1              1  ...
# zackary bruce        3      3       3          3              3  ...
#
#                  Lead Status  Booking Status  BookRef  Email Opt Out  Opt In  \
# Country
#                        13955           13955    13955          13955   13955
# 1                          1               1        1              1       1
# Afghanistan                1               1        1              1       1
# Albania                    3               3        3              3       3
# Algeria                    2               2        2              2       2
# ...                      ...             ...      ...            ...     ...
# raelynn cowan              1               1        1              1       1
# reagan douglas             2               2        2              2       2
# riya li                    4               4        4              4       4
# roselyn flowers            1               1        1              1       1
# zackary bruce              3               3        3              3       3
#
#                  GDPR Compliant  Website  Comments  Do you live in Bali?  \
# Country
#                           13955    13955     13955                 13955
# 1                             1        1         1                     1
# Afghanistan                   1        1         1                     1
# Albania                       3        3         3                     3
# Algeria                       2        2         2                     2
# ...                         ...      ...       ...                   ...
# raelynn cowan                 1        1         1                     1
# reagan douglas                2        2         2                     2
# riya li                       4        4         4                     4
# roselyn flowers               1        1         1                     1
# zackary bruce                 3        3         3                     3
#
#                  Contact Type
# Country
#                         13955
# 1                           1
# Afghanistan                 1
# Albania                     3
# Algeria                     2
# ...                       ...
# raelynn cowan               1
# reagan douglas              2
# riya li                     4
# roselyn flowers             1
# zackary bruce               3
#
# [109 rows x 35 columns]

# %%
# zoho_df['Country'].loc[
#     (zoho_df['Phone'].str.contains('^44|^\+44')) & 
#     (~zoho_df['Country'].str.contains('united kingdom|wales|england|scotland|northern ireland', regex=True, flags=re.I))
# ]
