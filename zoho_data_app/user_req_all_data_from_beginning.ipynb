# %%
import main_module as m
import zoho_filter_module as fil
import pandas as pd
import re
import numpy as np
from openpyxl.utils.exceptions import IllegalCharacterError

# %load_ext autoreload
# %autoreload 2

dir_path = r'C:\Users\fajar.fatoni\Documents\Python\Data\Zoho_Backup\2020-2024'
dir_path_live = r'C:\Users\fajar.fatoni\Documents\Python\Data\Zoho_Backup'
dir_path_old = r'C:\Users\fajar.fatoni\Documents\Python\Data\Zoho_Backup\old'
file_name = '\Leads_'

cols = ['Record Id',	
'Created Time',
'Created Date',	
'First Name',	
'Last Name',	
'Email',	
'Phone',	
'Mobile',	
'Birthdate',	
'Year of Birth',
'Street',	
'Street2',	
'City',	
'State',	
'Country',	
'Nationality',
'Booking Status', 
'BookRef',
'Departure Date',	
'Arrival Date',	
'Card Type',	
'Marital Status',	
'Lead Brand',	
'Lead Sub-Brand',	
'Lead Source',	
'Lead Locations',	
'Lead Source Description',	
'Lead Regions',
'Lead Status',
'Email Opt Out',	
'Opt In',
'GDPR Compliant',
'Website',
'Comments',
'Do you live in Bali?']
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
email = 'swas83m@gmail.com|sambisays@gmail.com'

# %%
path = dir_path+'\\backup.csv'
df_all = pd.read_csv(path, dtype='string', on_bad_lines='skip')
count_data_awal = df_all.shape[0]
df_all.drop(df_all.loc[df_all['Created Time'].str.len() < 5 ].index, inplace=True)
df_all.reset_index(drop=True, inplace=True)

df_all['Created Time'] = pd.to_datetime(df_all['Created Time'], format='%Y-%m-%d %H:%M:%S')

df_all.shape[0]
df_all
# Out:
#                         Record Id        Created Time Created Date First Name  \
# 0        zcrm_3584690000000404058 2019-01-07 15:08:38   2019-01-06   Nicholas
# 1        zcrm_3584690000000404059 2019-01-07 15:08:38   2019-01-06       Liao
# 2        zcrm_3584690000000404060 2019-01-07 15:08:38   2019-01-06    Vedanta
# 3        zcrm_3584690000000404065 2019-01-07 15:08:38   2019-01-06      Aidai
# 4        zcrm_3584690000000404068 2019-01-07 15:08:38   2019-01-06      Ardra
# ...                           ...                 ...          ...        ...
# 9965978  zcrm_3584690000489266005 2024-03-25 16:19:45         <NA>      Keval
# 9965979  zcrm_3584690000489266034 2024-03-25 16:19:51         <NA>     Suresh
# 9965980  zcrm_3584690000489266063 2024-03-25 17:29:27         <NA>     Nathan
# 9965981  zcrm_3584690000489269015 2024-03-25 16:20:25         <NA>    Leonora
# 9965982  zcrm_3584690000489271002 2024-03-25 18:40:17         <NA>       Annu
#
#           Last Name                                 Email           Phone  \
# 0              Wood            1230woodnicholas@gmail.com     61438600845
# 1              Yuan                      158066546@qq.com   8618718399923
# 2          Abhiyoga            abhiyoga.vedanta@gmail.com   6282146524550
# 3         Atakanova                aidai.nurbek@gmail.com    996779641590
# 4             Ardra            aliefardraqariru@gmail.com  +6282139300818
# ...             ...                                   ...             ...
# 9965978        Gala                   keval2403@gmail.com   +919022872972
# 9965979      Shroff  sureshshroff@breachcandyhospital.org   +919819533303
# 9965980   Fernandes       nathan.fernandes@karmagroup.com  +9179724486854
# 9965981     Hackman                leonora_hf@bigpond.com    +61439855115
# 9965982  Shriwastav          annusrivastava1990@gmail.com   +919561074124
#
#                  Mobile   Birthdate Year of Birth  ...         Arrival Date  \
# 0                  <NA>        <NA>          <NA>  ...  2019-01-06 00:00:00
# 1                  <NA>        <NA>          <NA>  ...  2019-01-06 00:00:00
# 2                  <NA>  2000-07-05          2000  ...  2018-12-01 00:00:00
# 3                  <NA>  1997-02-05          1997  ...  2019-01-06 00:00:00
# 4        +6282139300818  2005-01-20          2005  ...  2018-11-30 00:00:00
# ...                 ...         ...           ...  ...                  ...
# 9965978   +917700904802        <NA>          <NA>  ...           2024-03-21
# 9965979   +919819814280        <NA>          <NA>  ...           2024-03-21
# 9965980            <NA>        <NA>          <NA>  ...                 <NA>
# 9965981            <NA>        <NA>          <NA>  ...           2024-03-14
# 9965982            <NA>        <NA>          <NA>  ...                 <NA>
#
#         Card Type Marital Status           Lead Brand   Lead Sub-Brand  \
# 0            <NA>           <NA>  Timeshare Marketing    Other Bali DB
# 1            <NA>           <NA>  Timeshare Marketing    Other Bali DB
# 2            <NA>        Pelajar  Timeshare Marketing    Other Bali DB
# 3            <NA>         Single  Timeshare Marketing    Other Bali DB
# 4            <NA>          OTHER  Timeshare Marketing    Other Bali DB
# ...           ...            ...                  ...              ...
# 9965978      <NA>           <NA>        Karma Resorts            Other
# 9965979      <NA>           <NA>        Karma Resorts            Other
# 9965980      <NA>           <NA>          Karma Group  Karma Community
# 9965981      <NA>           <NA>        Karma Resorts            Other
# 9965982      <NA>           <NA>  Timeshare Marketing            Other
#
#          Lead Source           Lead Locations  \
# 0               Wifi              Purple Wifi
# 1               Wifi              Purple Wifi
# 2               Wifi              Purple Wifi
# 3               Wifi              Purple Wifi
# 4               Wifi              Purple Wifi
# ...              ...                      ...
# 9965978  Past Guests        Karma Royal Palms
# 9965979  Past Guests  Karma Sitabani, Corbett
# 9965980         Quiz                     <NA>
# 9965981  Past Guests           Karma Jimbaran
# 9965982  Web Enquiry           Karma Sitabani
#
#                                    Lead Source Description Lead Regions  \
# 0                                                     <NA>         SEAP
# 1                                                     <NA>        Other
# 2                                                     <NA>         SEAP
# 3                                                     <NA>    UK/Europe
# 4                                    WIFI USER ID 13494142         SEAP
# ...                                                    ...          ...
# 9965978                                          Viewpoint         <NA>
# 9965979                                          Viewpoint         <NA>
# 9965980  Karma Community | Edition 218 - Words to the Wise        India
# 9965981                                          Viewpoint         <NA>
# 9965982                          Timeshare Booking Request        India
#
#         Lead Status
# 0          New Lead
# 1          New Lead
# 2          New Lead
# 3          New Lead
# 4          New Lead
# ...             ...
# 9965978        <NA>
# 9965979        <NA>
# 9965980        <NA>
# 9965981        <NA>
# 9965982        <NA>
#
# [9965983 rows x 27 columns]

# %%
df_old = m.load_data_multiple(dir_path_old, file_name, cols)
count_data_awal = df_old.shape[0]
df_old = df_old.reindex(columns=cols)
df_old.shape[0]

df_old['Created Time'] = pd.to_datetime(df_old['Created Time'], format='%Y-%m-%d %H:%M:%S')
df_old['Arrival Date'] = pd.to_datetime(df_old['Arrival Date'], format='%Y-%m-%d')
df_old['Departure Date'] = pd.to_datetime(df_old['Departure Date'], format='%Y-%m-%d')
# fungsi errors cource untuk menhindari error jika value data date null atau kosong
# df['Birthdate'] = pd.to_datetime(df['Birthdate'], format='%Y-%m-%d', errors='coerce')
df_old.dtypes
df_old
# Out:
# C:\Users\fajar.fatoni\Documents\Python\Data\Zoho_Backup\old\Leads_001.csv
# C:\Users\fajar.fatoni\Documents\Python\Data\Zoho_Backup\old\Leads_002.csv
# C:\Users\fajar.fatoni\Documents\Python\Data\Zoho_Backup\old\Leads_003.csv
# C:\Users\fajar.fatoni\Documents\Python\Data\Zoho_Backup\old\Leads_004.csv
# C:\Users\fajar.fatoni\Documents\Python\Data\Zoho_Backup\old\Leads_005.csv
# C:\Users\fajar.fatoni\Documents\Python\Data\Zoho_Backup\old\Leads_006.csv
# C:\Users\fajar.fatoni\Documents\Python\Data\Zoho_Backup\old\Leads_007.csv
# C:\Users\fajar.fatoni\Documents\Python\Data\Zoho_Backup\old\Leads_008.csv
# C:\Users\fajar.fatoni\Documents\Python\Data\Zoho_Backup\old\Leads_009.csv
# C:\Users\fajar.fatoni\Documents\Python\Data\Zoho_Backup\old\Leads_010.csv
# C:\Users\fajar.fatoni\Documents\Python\Data\Zoho_Backup\old\Leads_011.csv
# C:\Users\fajar.fatoni\Documents\Python\Data\Zoho_Backup\old\Leads_012.csv
# C:\Users\fajar.fatoni\Documents\Python\Data\Zoho_Backup\old\Leads_013.csv
# C:\Users\fajar.fatoni\Documents\Python\Data\Zoho_Backup\old\Leads_014.csv
# C:\Users\fajar.fatoni\Documents\Python\Data\Zoho_Backup\old\Leads_015.csv
# C:\Users\fajar.fatoni\Documents\Python\Data\Zoho_Backup\old\Leads_016.csv
# C:\Users\fajar.fatoni\Documents\Python\Data\Zoho_Backup\old\Leads_017.csv
# C:\Users\fajar.fatoni\Documents\Python\Data\Zoho_Backup\old\Leads_018.csv
# C:\Users\fajar.fatoni\Documents\Python\Data\Zoho_Backup\old\Leads_019.csv
# C:\Users\fajar.fatoni\Documents\Python\Data\Zoho_Backup\old\Leads_020.csv
# C:\Users\fajar.fatoni\Documents\Python\Data\Zoho_Backup\old\Leads_021.csv
# C:\Users\fajar.fatoni\Documents\Python\Data\Zoho_Backup\old\Leads_022.csv
# C:\Users\fajar.fatoni\Documents\Python\Data\Zoho_Backup\old\Leads_023.csv
# C:\Users\fajar.fatoni\Documents\Python\Data\Zoho_Backup\old\Leads_024.csv
# C:\Users\fajar.fatoni\Documents\Python\Data\Zoho_Backup\old\Leads_025.csv
# C:\Users\fajar.fatoni\Documents\Python\Data\Zoho_Backup\old\Leads_026.csv
# C:\Users\fajar.fatoni\Documents\Python\Data\Zoho_Backup\old\Leads_027.csv
# C:\Users\fajar.fatoni\Documents\Python\Data\Zoho_Backup\old\Leads_028.csv
# C:\Users\fajar.fatoni\Documents\Python\Data\Zoho_Backup\old\Leads_029.csv
# C:\Users\fajar.fatoni\Documents\Python\Data\Zoho_Backup\old\Leads_030.csv
# C:\Users\fajar.fatoni\Documents\Python\Data\Zoho_Backup\old\Leads_031.csv
# C:\Users\fajar.fatoni\Documents\Python\Data\Zoho_Backup\old\Leads_032.csv
# C:\Users\fajar.fatoni\Documents\Python\Data\Zoho_Backup\old\Leads_033.csv
# C:\Users\fajar.fatoni\Documents\Python\Data\Zoho_Backup\old\Leads_034.csv
# C:\Users\fajar.fatoni\Documents\Python\Data\Zoho_Backup\old\Leads_035.csv
# C:\Users\fajar.fatoni\Documents\Python\Data\Zoho_Backup\old\Leads_036.csv
# C:\Users\fajar.fatoni\Documents\Python\Data\Zoho_Backup\old\Leads_037.csv
# C:\Users\fajar.fatoni\Documents\Python\Data\Zoho_Backup\old\Leads_038.csv
# C:\Users\fajar.fatoni\Documents\Python\Data\Zoho_Backup\old\Leads_039.csv
# C:\Users\fajar.fatoni\Documents\Python\Data\Zoho_Backup\old\Leads_040.csv
# C:\Users\fajar.fatoni\Documents\Python\Data\Zoho_Backup\old\Leads_041.csv
# C:\Users\fajar.fatoni\Documents\Python\Data\Zoho_Backup\old\Leads_042.csv
# C:\Users\fajar.fatoni\Documents\Python\Data\Zoho_Backup\old\Leads_043.csv
# C:\Users\fajar.fatoni\Documents\Python\Data\Zoho_Backup\old\Leads_044.csv
# C:\Users\fajar.fatoni\Documents\Python\Data\Zoho_Backup\old\Leads_045.csv
# C:\Users\fajar.fatoni\Documents\Python\Data\Zoho_Backup\old\Leads_046.csv
# C:\Users\fajar.fatoni\Documents\Python\Data\Zoho_Backup\old\Leads_047.csv
# C:\Users\fajar.fatoni\Documents\Python\Data\Zoho_Backup\old\Leads_048.csv
#                         Record Id        Created Time Created Date First Name  \
# 0        zcrm_3584690000000404058 2019-01-07 15:08:38   2019-01-06   Nicholas
# 1        zcrm_3584690000000404059 2019-01-07 15:08:38   2019-01-06       Liao
# 2        zcrm_3584690000000404060 2019-01-07 15:08:38   2019-01-06    Vedanta
# 3        zcrm_3584690000000404065 2019-01-07 15:08:38   2019-01-06      Aidai
# 4        zcrm_3584690000000404068 2019-01-07 15:08:38   2019-01-06      Ardra
# ...                           ...                 ...          ...        ...
# 4717718  zcrm_3584690000475135007 2024-01-01 18:16:02         <NA>    Upendra
# 4717719  zcrm_3584690000475135045 2024-01-01 18:16:37         <NA>      Mehul
# 4717720  zcrm_3584690000475136005 2024-01-01 18:17:13         <NA>      swati
# 4717721  zcrm_3584690000475138034 2024-01-01 18:48:36         <NA>      SUMON
# 4717722  zcrm_3584690000475138069 2024-01-01 18:52:24         <NA>      Rohit
#
#          Last Name                       Email           Phone  \
# 0             Wood  1230woodnicholas@gmail.com    +61438600845
# 1             Yuan            158066546@qq.com   8618718399923
# 2         Abhiyoga  abhiyoga.vedanta@gmail.com  +6282146524550
# 3        Atakanova      aidai.nurbek@gmail.com    996779641590
# 4            Ardra  aliefardraqariru@gmail.com  +6282139300818
# ...            ...                         ...             ...
# 4717718     Mishra       upendra.sir@gmail.com   +919036084550
# 4717719  Prajapati     mehul.m111985@gmail.com   +919714713689
# 4717720   agarwala         cswatiadv@gmail.com   +919733055636
# 4717721      SAHOO        sumonsahoo@gmail.com   +918910484814
# 4717722      Kadam      rohit0918.rk@gmail.com   +919819185446
#
#                  Mobile   Birthdate Year of Birth  ...  \
# 0                  <NA>        <NA>          <NA>  ...
# 1                  <NA>        <NA>          <NA>  ...
# 2                  <NA>  2000-07-05          2000  ...
# 3                  <NA>  1997-02-05          1997  ...
# 4        +6282139300818  2005-01-20          2005  ...
# ...                 ...         ...           ...  ...
# 4717718            <NA>        <NA>          <NA>  ...
# 4717719            <NA>        <NA>          <NA>  ...
# 4717720            <NA>        <NA>          <NA>  ...
# 4717721            <NA>        <NA>          <NA>  ...
# 4717722            <NA>        <NA>          <NA>  ...
#
#                  Lead Locations      Lead Source Description Lead Regions  \
# 0                          <NA>                  Purple Wifi         SEAP
# 1                          <NA>                  Purple Wifi        Other
# 2                          <NA>                  Purple Wifi         SEAP
# 3                          <NA>                  Purple Wifi    UK/Europe
# 4                       Mall 21                  Purple Wifi         SEAP
# ...                         ...                          ...          ...
# 4717718  Karma Sunshine Village    Timeshare Booking Request        India
# 4717719                 General  IND | FB MF | Lead captured         <NA>
# 4717720            Karma Martam         IND | FB MF | Martam         <NA>
# 4717721            Karma Martam         IND | FB MF | Martam         <NA>
# 4717722             Royal Palms            IND | FB AF | KRP         <NA>
#
#         Lead Status Email Opt Out Opt In GDPR Compliant  \
# 0          New Lead         false  false          false
# 1          New Lead         false  false          false
# 2          New Lead         false  false          false
# 3          New Lead         false  false          false
# 4          New Lead         false  false          false
# ...             ...           ...    ...            ...
# 4717718        <NA>         false   true           true
# 4717719        <NA>         false  false          false
# 4717720        <NA>         false  false          false
# 4717721        <NA>         false  false          false
# 4717722        <NA>         false  false          false
#
#                                                    Website Comments  \
# 0                                                     <NA>     <NA>
# 1                                                     <NA>     <NA>
# 2                                                     <NA>     <NA>
# 3                                                     <NA>     <NA>
# 4                                                     <NA>     <NA>
# ...                                                    ...      ...
# 4717718  https://karmagroup.com/find-destination/karma-...     <NA>
# 4717719                                               <NA>     <NA>
# 4717720                                               <NA>     <NA>
# 4717721                                               <NA>     <NA>
# 4717722                                               <NA>     <NA>
#
#         Do you live in Bali?
# 0                      false
# 1                      false
# 2                      false
# 3                      false
# 4                      false
# ...                      ...
# 4717718                false
# 4717719                false
# 4717720                false
# 4717721                false
# 4717722                false
#
# [4717723 rows x 35 columns]

# %%
df_live = m.load_data_multiple(dir_path_live, file_name, cols)
count_data_awal = df_live.shape[0]
df_live = df_live.reindex(columns=cols)
df_live.shape[0]

df_live['Created Time'] = pd.to_datetime(df_live['Created Time'], format='%Y-%m-%d %H:%M:%S')
df_live['Arrival Date'] = pd.to_datetime(df_live['Arrival Date'], format='%Y-%m-%d')
df_live['Departure Date'] = pd.to_datetime(df_live['Departure Date'], format='%Y-%m-%d')
# fungsi errors cource untuk menhindari error jika value data date null atau kosong
# df['Birthdate'] = pd.to_datetime(df['Birthdate'], format='%Y-%m-%d', errors='coerce')
df_live.dtypes
df_live
# Out:
# C:\Users\fajar.fatoni\Documents\Python\Data\Zoho_Backup\Leads_001.csv
# C:\Users\fajar.fatoni\Documents\Python\Data\Zoho_Backup\Leads_002.csv
# C:\Users\fajar.fatoni\Documents\Python\Data\Zoho_Backup\Leads_003.csv
# C:\Users\fajar.fatoni\Documents\Python\Data\Zoho_Backup\Leads_004.csv
# C:\Users\fajar.fatoni\Documents\Python\Data\Zoho_Backup\Leads_005.csv
# C:\Users\fajar.fatoni\Documents\Python\Data\Zoho_Backup\Leads_006.csv
#                        Record Id        Created Time Created Date  \
# 0       zcrm_3584690000000404602 2019-01-08 11:07:28   2021-07-21
# 1       zcrm_3584690000000450071 2019-01-08 16:38:18         <NA>
# 2       zcrm_3584690000000450087 2019-01-08 16:38:18         <NA>
# 3       zcrm_3584690000000450106 2019-01-08 16:38:18         <NA>
# 4       zcrm_3584690000000450109 2019-01-08 16:38:18         <NA>
# ...                          ...                 ...          ...
# 509984  zcrm_3584690000555548001 2025-06-09 17:31:09   2025-06-07
# 509985  zcrm_3584690000555549001 2025-06-09 17:31:11   2025-06-07
# 509986  zcrm_3584690000555550001 2025-06-09 17:31:14   2025-06-07
# 509987  zcrm_3584690000555551001 2025-06-09 17:31:34   2025-06-08
# 509988  zcrm_3584690000555552001 2025-06-09 17:31:36   2025-06-08
#
#               First Name         Last Name                        Email  \
# 0               Frederic             Bonin    fredericbonin79@gmail.com
# 1              Sebastian              Rach                         <NA>
# 2                Siobhan         Gallagher  gallaghersiobhan@eircom.net
# 3                   Lisa         Ferkovich         lisajo2009@yahoo.com
# 4              Ana Maria          Weileder     m.weileder@sonnenlink.de
# ...                  ...               ...                          ...
# 509984              Lina              Lina                         <NA>
# 509985             Karen             Tabet                         <NA>
# 509986            Michel                 -                         <NA>
# 509987     Thariepoetrie     Thariepoetrie                         <NA>
# 509988  Ceccillia (Cici)  Ceccillia (Cici)                         <NA>
#
#                    Phone Mobile   Birthdate Year of Birth  ... Lead Locations  \
# 0         +6281236100502   <NA>  1981-10-03          1981  ...  Karma Kandara
# 1          +498914342111   <NA>  1982-04-20          1982  ...  Karma Bavaria
# 2           353879597603   <NA>  1973-03-14          1973  ...  Karma Bavaria
# 3            14062394749   <NA>  1963-07-08          1963  ...  Karma Bavaria
# 4            15253234700   <NA>        <NA>          <NA>  ...  Karma Bavaria
# ...                  ...    ...         ...           ...  ...            ...
# 509984  +39 344 570 7399   <NA>        <NA>          <NA>  ...  Karma Kandara
# 509985  +971 52 798 4487   <NA>        <NA>          <NA>  ...  Karma Kandara
# 509986   +62 87716381678   <NA>        <NA>          <NA>  ...  Karma Kandara
# 509987   +62 81225302376   <NA>        <NA>          <NA>  ...  Karma Kandara
# 509988   +61 430 449 934   <NA>        <NA>          <NA>  ...  Karma Kandara
#
#                       Lead Source Description Lead Regions Lead Status  \
# 0                                       KAREN         SEAP    New Lead
# 1                                        <NA>    UK/Europe    New Lead
# 2                                        <NA>    UK/Europe    New Lead
# 3                                        <NA>    UK/Europe    New Lead
# 4             MICE Contacts from Ioanna email    UK/Europe    New Lead
# ...                                       ...          ...         ...
# 509984  Karma Reservations - WhatsApp Channel         SEAP        <NA>
# 509985  Karma Reservations - WhatsApp Channel         SEAP        <NA>
# 509986  Karma Reservations - WhatsApp Channel         SEAP        <NA>
# 509987  Karma Reservations - WhatsApp Channel         SEAP        <NA>
# 509988  Karma Reservations - WhatsApp Channel         SEAP        <NA>
#
#        Email Opt Out Opt In GDPR Compliant Website Comments  \
# 0              false  false          false    <NA>     <NA>
# 1               true  false          false    <NA>     <NA>
# 2              false   true           true    <NA>     <NA>
# 3               true  false          false    <NA>     <NA>
# 4              false   true           true    <NA>     <NA>
# ...              ...    ...            ...     ...      ...
# 509984         false  false          false    <NA>     <NA>
# 509985         false  false          false    <NA>     <NA>
# 509986         false  false          false    <NA>     <NA>
# 509987         false  false          false    <NA>     <NA>
# 509988         false  false          false    <NA>     <NA>
#
#        Do you live in Bali?
# 0                     false
# 1                     false
# 2                     false
# 3                     false
# 4                     false
# ...                     ...
# 509984                false
# 509985                false
# 509986                false
# 509987                false
# 509988                false
#
# [509989 rows x 35 columns]

# %%
df = pd.concat([df_all,df_old,df_live])
df
# Out:
#                        Record Id        Created Time Created Date  \
# 0       zcrm_3584690000000404058 2019-01-07 15:08:38   2019-01-06
# 1       zcrm_3584690000000404059 2019-01-07 15:08:38   2019-01-06
# 2       zcrm_3584690000000404060 2019-01-07 15:08:38   2019-01-06
# 3       zcrm_3584690000000404065 2019-01-07 15:08:38   2019-01-06
# 4       zcrm_3584690000000404068 2019-01-07 15:08:38   2019-01-06
# ...                          ...                 ...          ...
# 509984  zcrm_3584690000555548001 2025-06-09 17:31:09   2025-06-07
# 509985  zcrm_3584690000555549001 2025-06-09 17:31:11   2025-06-07
# 509986  zcrm_3584690000555550001 2025-06-09 17:31:14   2025-06-07
# 509987  zcrm_3584690000555551001 2025-06-09 17:31:34   2025-06-08
# 509988  zcrm_3584690000555552001 2025-06-09 17:31:36   2025-06-08
#
#               First Name         Last Name                       Email  \
# 0               Nicholas              Wood  1230woodnicholas@gmail.com
# 1                   Liao              Yuan            158066546@qq.com
# 2                Vedanta          Abhiyoga  abhiyoga.vedanta@gmail.com
# 3                  Aidai         Atakanova      aidai.nurbek@gmail.com
# 4                  Ardra             Ardra  aliefardraqariru@gmail.com
# ...                  ...               ...                         ...
# 509984              Lina              Lina                        <NA>
# 509985             Karen             Tabet                        <NA>
# 509986            Michel                 -                        <NA>
# 509987     Thariepoetrie     Thariepoetrie                        <NA>
# 509988  Ceccillia (Cici)  Ceccillia (Cici)                        <NA>
#
#                    Phone          Mobile   Birthdate Year of Birth  ...  \
# 0            61438600845            <NA>        <NA>          <NA>  ...
# 1          8618718399923            <NA>        <NA>          <NA>  ...
# 2          6282146524550            <NA>  2000-07-05          2000  ...
# 3           996779641590            <NA>  1997-02-05          1997  ...
# 4         +6282139300818  +6282139300818  2005-01-20          2005  ...
# ...                  ...             ...         ...           ...  ...
# 509984  +39 344 570 7399            <NA>        <NA>          <NA>  ...
# 509985  +971 52 798 4487            <NA>        <NA>          <NA>  ...
# 509986   +62 87716381678            <NA>        <NA>          <NA>  ...
# 509987   +62 81225302376            <NA>        <NA>          <NA>  ...
# 509988   +61 430 449 934            <NA>        <NA>          <NA>  ...
#
#        Lead Regions Lead Status Booking Status BookRef Email Opt Out Opt In  \
# 0              SEAP    New Lead           <NA>    <NA>          <NA>   <NA>
# 1             Other    New Lead           <NA>    <NA>          <NA>   <NA>
# 2              SEAP    New Lead           <NA>    <NA>          <NA>   <NA>
# 3         UK/Europe    New Lead           <NA>    <NA>          <NA>   <NA>
# 4              SEAP    New Lead           <NA>    <NA>          <NA>   <NA>
# ...             ...         ...            ...     ...           ...    ...
# 509984         SEAP        <NA>           <NA>    <NA>         false  false
# 509985         SEAP        <NA>           <NA>    <NA>         false  false
# 509986         SEAP        <NA>           <NA>    <NA>         false  false
# 509987         SEAP        <NA>           <NA>    <NA>         false  false
# 509988         SEAP        <NA>           <NA>    <NA>         false  false
#
#        GDPR Compliant Website Comments Do you live in Bali?
# 0                <NA>    <NA>     <NA>                 <NA>
# 1                <NA>    <NA>     <NA>                 <NA>
# 2                <NA>    <NA>     <NA>                 <NA>
# 3                <NA>    <NA>     <NA>                 <NA>
# 4                <NA>    <NA>     <NA>                 <NA>
# ...               ...     ...      ...                  ...
# 509984          false    <NA>     <NA>                false
# 509985          false    <NA>     <NA>                false
# 509986          false    <NA>     <NA>                false
# 509987          false    <NA>     <NA>                false
# 509988          false    <NA>     <NA>                false
#
# [15193695 rows x 35 columns]

# %%
# df.loc[df['Email'] == email]
df.loc[df['Email'].str.contains(email, regex=True, flags=re.I)]
# Out:
# Empty DataFrame
# Columns: [Record Id, Created Time, Created Date, First Name, Last Name, Email, Phone, Mobile, Birthdate, Year of Birth, Street, Street2, City, State, Country, Nationality, Departure Date, Arrival Date, Card Type, Marital Status, Lead Brand, Lead Sub-Brand, Lead Source, Lead Locations, Lead Source Description, Lead Regions, Lead Status, Booking Status, BookRef, Email Opt Out, Opt In, GDPR Compliant, Website, Comments, Do you live in Bali?]
# Index: []
#
# [0 rows x 35 columns]

# %%
df.drop_duplicates(subset=['Record Id'], inplace=True)
df.reset_index(drop=True, inplace=True)
count_data_awal = df.shape[0]
df
# Out:
#                          Record Id        Created Time Created Date  \
# 0         zcrm_3584690000000404058 2019-01-07 15:08:38   2019-01-06
# 1         zcrm_3584690000000404059 2019-01-07 15:08:38   2019-01-06
# 2         zcrm_3584690000000404060 2019-01-07 15:08:38   2019-01-06
# 3         zcrm_3584690000000404065 2019-01-07 15:08:38   2019-01-06
# 4         zcrm_3584690000000404068 2019-01-07 15:08:38   2019-01-06
# ...                            ...                 ...          ...
# 10040851  zcrm_3584690000555548001 2025-06-09 17:31:09   2025-06-07
# 10040852  zcrm_3584690000555549001 2025-06-09 17:31:11   2025-06-07
# 10040853  zcrm_3584690000555550001 2025-06-09 17:31:14   2025-06-07
# 10040854  zcrm_3584690000555551001 2025-06-09 17:31:34   2025-06-08
# 10040855  zcrm_3584690000555552001 2025-06-09 17:31:36   2025-06-08
#
#                 First Name         Last Name                       Email  \
# 0                 Nicholas              Wood  1230woodnicholas@gmail.com
# 1                     Liao              Yuan            158066546@qq.com
# 2                  Vedanta          Abhiyoga  abhiyoga.vedanta@gmail.com
# 3                    Aidai         Atakanova      aidai.nurbek@gmail.com
# 4                    Ardra             Ardra  aliefardraqariru@gmail.com
# ...                    ...               ...                         ...
# 10040851              Lina              Lina                        <NA>
# 10040852             Karen             Tabet                        <NA>
# 10040853            Michel                 -                        <NA>
# 10040854     Thariepoetrie     Thariepoetrie                        <NA>
# 10040855  Ceccillia (Cici)  Ceccillia (Cici)                        <NA>
#
#                      Phone          Mobile   Birthdate Year of Birth  ...  \
# 0              61438600845            <NA>        <NA>          <NA>  ...
# 1            8618718399923            <NA>        <NA>          <NA>  ...
# 2            6282146524550            <NA>  2000-07-05          2000  ...
# 3             996779641590            <NA>  1997-02-05          1997  ...
# 4           +6282139300818  +6282139300818  2005-01-20          2005  ...
# ...                    ...             ...         ...           ...  ...
# 10040851  +39 344 570 7399            <NA>        <NA>          <NA>  ...
# 10040852  +971 52 798 4487            <NA>        <NA>          <NA>  ...
# 10040853   +62 87716381678            <NA>        <NA>          <NA>  ...
# 10040854   +62 81225302376            <NA>        <NA>          <NA>  ...
# 10040855   +61 430 449 934            <NA>        <NA>          <NA>  ...
#
#          Lead Regions Lead Status Booking Status BookRef Email Opt Out Opt In  \
# 0                SEAP    New Lead           <NA>    <NA>          <NA>   <NA>
# 1               Other    New Lead           <NA>    <NA>          <NA>   <NA>
# 2                SEAP    New Lead           <NA>    <NA>          <NA>   <NA>
# 3           UK/Europe    New Lead           <NA>    <NA>          <NA>   <NA>
# 4                SEAP    New Lead           <NA>    <NA>          <NA>   <NA>
# ...               ...         ...            ...     ...           ...    ...
# 10040851         SEAP        <NA>           <NA>    <NA>         false  false
# 10040852         SEAP        <NA>           <NA>    <NA>         false  false
# 10040853         SEAP        <NA>           <NA>    <NA>         false  false
# 10040854         SEAP        <NA>           <NA>    <NA>         false  false
# 10040855         SEAP        <NA>           <NA>    <NA>         false  false
#
#          GDPR Compliant Website Comments Do you live in Bali?
# 0                  <NA>    <NA>     <NA>                 <NA>
# 1                  <NA>    <NA>     <NA>                 <NA>
# 2                  <NA>    <NA>     <NA>                 <NA>
# 3                  <NA>    <NA>     <NA>                 <NA>
# 4                  <NA>    <NA>     <NA>                 <NA>
# ...                 ...     ...      ...                  ...
# 10040851          false    <NA>     <NA>                false
# 10040852          false    <NA>     <NA>                false
# 10040853          false    <NA>     <NA>                false
# 10040854          false    <NA>     <NA>                false
# 10040855          false    <NA>     <NA>                false
#
# [10040856 rows x 35 columns]

# %%
df.dtypes
# Out:
# Record Id                  string[python]
# Created Time               datetime64[ns]
# Created Date               string[python]
# First Name                 string[python]
# Last Name                  string[python]
# Email                      string[python]
# Phone                      string[python]
# Mobile                     string[python]
# Birthdate                  string[python]
# Year of Birth              string[python]
# Street                     string[python]
# Street2                    string[python]
# City                       string[python]
# State                      string[python]
# Country                    string[python]
# Nationality                string[python]
# Departure Date                     object
# Arrival Date                       object
# Card Type                  string[python]
# Marital Status             string[python]
# Lead Brand                 string[python]
# Lead Sub-Brand             string[python]
# Lead Source                string[python]
# Lead Locations             string[python]
# Lead Source Description    string[python]
# Lead Regions               string[python]
# Lead Status                string[python]
# Booking Status             string[python]
# BookRef                    string[python]
# Email Opt Out              string[python]
# Opt In                     string[python]
# GDPR Compliant             string[python]
# Website                    string[python]
# Comments                   string[python]
# Do you live in Bali?       string[python]
# dtype: object

# %%
path = r'G:\.shortcut-targets-by-id\0B_d3smBjzo04eXpvS1NXTWF2RVE\_BOOKING\Booking By Year\FlyBuy Booking Data (BGAU & BGID & KE).xlsx'
df_booking = pd.read_excel(path, dtype='string', sheet_name='BOOKING_BGAU_BGID_KE')

path = r'G:\.shortcut-targets-by-id\0B_d3smBjzo04UUNBME5GOVhoMjA\_ODYSSEY\Phone Members.xlsx'
df_phone = pd.read_excel(path, dtype='string', sheet_name='Sheet1')

path = r'G:\.shortcut-targets-by-id\0B_d3smBjzo04UUNBME5GOVhoMjA\_ODYSSEY\Email Members.xlsx'
df_email = pd.read_excel(path, dtype='string', sheet_name='Sheet1')

# %%
zoho_filter = fil.user_req(df)
zoho_df = df.loc[zoho_filter].copy() # menggunakan copy untuk menghindari setting copy warning
zoho_df.reset_index(drop=True, inplace=True)
count_filter_awal = zoho_df.shape[0]

# zoho_df.to_excel(r'C:\Users\fajar.fatoni\Documents\Python\Data\test_leads.xlsx', index=False)
# mengisi kolom <NA> dengan value string 'empty' supaya mudah mengecek data member dan booking dengan isin

zoho_df.fillna('empty', inplace=True)
# zoho_df.sort_values('Created Time', ascending=True)

# %%
zoho_df
# Out:
#                        Record Id        Created Time Created Date  \
# 0       zcrm_3584690000000404115 2019-01-07 15:08:38   2019-01-06
# 1       zcrm_3584690000000404196 2019-01-07 15:08:38   2019-01-07
# 2       zcrm_3584690000000404209 2019-01-07 15:08:38   2019-01-06
# 3       zcrm_3584690000000404459 2019-01-08 11:07:28   2019-01-03
# 4       zcrm_3584690000000404460 2019-01-08 11:07:28   2019-01-03
# ...                          ...                 ...          ...
# 169287  zcrm_3584690000555509137 2025-06-09 11:51:05        empty
# 169288  zcrm_3584690000555509367 2025-06-09 11:55:37        empty
# 169289  zcrm_3584690000555514001 2025-06-09 01:50:38   2025-06-08
# 169290  zcrm_3584690000555514164 2025-06-09 11:49:51        empty
# 169291  zcrm_3584690000555514228 2025-06-09 11:51:08        empty
#
#           First Name   Last Name                      Email          Phone  \
# 0             Harley     Russell     hars_russ7@hotmail.com   447834782590
# 1             Tobias     Klitsch   tobias.klitsch@gmail.com   447516721033
# 2             Thomas        Wood  wood.thomas99@yahoo.co.uk   447887405046
# 3       Sophie-Irene     Averman     sonicaverman@gmail.com   380503048815
# 4               Юлия       Жулий        y.zhulii@icloud.com   380633945350
# ...              ...         ...                        ...            ...
# 169287         Janis    Allerton    j4nisallerton@gmail.com  +447710107054
# 169288        Martin     Maloney    martinusahols@gmail.com  +447533715827
# 169289    Eugene May  Eugene May       eugenelmay@gmail.com  +447413538915
# 169290         Linda      Lawley     lindalawley4@gmail.com  +447773014928
# 169291        Trevor      Parvin    trevorparvin@icloud.com  +447792914660
#
#        Mobile   Birthdate Year of Birth  ... Lead Regions Lead Status  \
# 0       empty  1995-01-24          1995  ...    UK/Europe    New Lead
# 1       empty  1982-06-01          1982  ...    UK/Europe    New Lead
# 2       empty  1990-09-01          1990  ...    UK/Europe    New Lead
# 3       empty  1981-08-22          1981  ...    UK/Europe    New Lead
# 4       empty       empty         empty  ...    UK/Europe    New Lead
# ...       ...         ...           ...  ...          ...         ...
# 169287  empty       empty         empty  ...        empty       empty
# 169288  empty       empty         empty  ...        empty       empty
# 169289  empty       empty         empty  ...    UK/Europe       empty
# 169290  empty       empty         empty  ...        empty       empty
# 169291  empty       empty         empty  ...        empty       empty
#
#        Booking Status  BookRef Email Opt Out Opt In GDPR Compliant  \
# 0               empty    empty         empty  empty          empty
# 1               empty    empty         empty  empty          empty
# 2               empty    empty         empty  empty          empty
# 3               empty    empty         empty  empty          empty
# 4               empty    empty         empty  empty          empty
# ...               ...      ...           ...    ...            ...
# 169287    Checked-Out  2774216         false   true           true
# 169288    Checked-Out  2847346         false   true           true
# 169289          empty    empty         false   true           true
# 169290    Checked-Out  2760709         false   true           true
# 169291    Checked-Out  2768456         false   true           true
#
#                                                   Website Comments  \
# 0                                                   empty    empty
# 1                                                   empty    empty
# 2                                                   empty    empty
# 3                                                   empty    empty
# 4                                                   empty    empty
# ...                                                   ...      ...
# 169287                                              empty    empty
# 169288                                              empty    empty
# 169289  https://karmagroup.com/weddings-at-karma-st-ma...    empty
# 169290                                              empty    empty
# 169291                                              empty    empty
#
#        Do you live in Bali?
# 0                     empty
# 1                     empty
# 2                     empty
# 3                     empty
# 4                     empty
# ...                     ...
# 169287                false
# 169288                false
# 169289                false
# 169290                false
# 169291                false
#
# [169292 rows x 35 columns]

# %% [markdown]
# # ====================== Awal Filter Umum ======================

# %%
# data phone, mobile dam email member yang ada di master data (wash member)

m.clean_number(zoho_df, 'Phone')
m.clean_number(zoho_df, 'Mobile')
m.replace_not_valid_to_empty(zoho_df, 'Phone')
m.replace_not_valid_to_empty(zoho_df, 'Mobile')
zoho_df['Email'] = m.lowercase(zoho_df, 'Email')
m.clean_space(zoho_df, 'Email')
m.clean_not_valid_email_format(zoho_df, 'Email')

m.clean_number(df_booking, 'Phone1')
m.clean_number(df_booking, 'Mobile')
df_booking['Email'] = m.lowercase(df_booking, 'Email')
m.clean_space(df_booking, 'Email')
m.clean_not_valid_email_format(df_booking, 'Email')

m.clean_number(df_phone, 'Mobile')

df_email['Email'] = m.lowercase(df_email, 'Email')
m.clean_space(df_email, 'Email')
m.clean_not_valid_email_format(df_email, 'Email')
# Out:
# c:\Users\fajar.fatoni\Documents\Python\Task Offline\zoho_data_app\main_module.py:104: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[df_columns].replace(' ','', regex=True, inplace=True)
# c:\Users\fajar.fatoni\Documents\Python\Task Offline\zoho_data_app\main_module.py:105: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[df_columns].replace('[^0-9]','', regex=True, inplace=True)
# c:\Users\fajar.fatoni\Documents\Python\Task Offline\zoho_data_app\main_module.py:127: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[df_columns].replace(' ','', regex=True, inplace=True)
# c:\Users\fajar.fatoni\Documents\Python\Task Offline\zoho_data_app\main_module.py:104: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[df_columns].replace(' ','', regex=True, inplace=True)
# c:\Users\fajar.fatoni\Documents\Python\Task Offline\zoho_data_app\main_module.py:105: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[df_columns].replace('[^0-9]','', regex=True, inplace=True)
# 'Email'

# %%
zoho_df.loc[
    (zoho_df['Phone'] == 'empty') & (zoho_df['Mobile'] != 'empty'), 
    'Phone'] = zoho_df['Mobile']
zoho_df.loc[zoho_df['Phone'] == zoho_df['Mobile'],'Mobile'] = 'empty'

# %%
zoho_df.loc[zoho_df['Phone']=='']
# Out:
# Empty DataFrame
# Columns: [Record Id, Created Time, Created Date, First Name, Last Name, Email, Phone, Mobile, Birthdate, Year of Birth, Street, Street2, City, State, Country, Nationality, Departure Date, Arrival Date, Card Type, Marital Status, Lead Brand, Lead Sub-Brand, Lead Source, Lead Locations, Lead Source Description, Lead Regions, Lead Status, Booking Status, BookRef, Email Opt Out, Opt In, GDPR Compliant, Website, Comments, Do you live in Bali?]
# Index: []
#
# [0 rows x 35 columns]

# %%
count_deleted_wrong_format = m.delete_email_wrong_format(zoho_df, 'Email')
count_after_deleted_wrong_format = zoho_df.shape[0]

# %%
# hitung jumlah duplicate
count_duplicate_general = zoho_df.loc[zoho_df.duplicated(subset=['Phone','Email', 'Mobile'])].shape[0]

zoho_df.loc[zoho_df.duplicated(subset=['Phone','Email'])]
# Out:
#                        Record Id        Created Time Created Date First Name  \
# 472     zcrm_3584690000000461356 2019-01-09 11:11:21        empty       Lisa
# 473     zcrm_3584690000000461357 2019-01-09 11:11:21        empty       Lisa
# 2594    zcrm_3584690000005160488 2019-03-26 03:25:35        empty     Adrian
# 2609    zcrm_3584690000005160503 2019-03-26 03:25:35        empty       Andy
# 2620    zcrm_3584690000005160514 2019-03-26 03:25:35        empty    Rebecca
# ...                          ...                 ...          ...        ...
# 169211  zcrm_3584690000554648079 2025-06-02 11:52:49        empty    Kathryn
# 169222  zcrm_3584690000554660259 2025-06-02 11:56:29        empty     Yan Gu
# 169243  zcrm_3584690000554991077 2025-06-04 17:55:40   2025-06-04     graham
# 169273  zcrm_3584690000555486043 2025-06-07 20:07:25   2025-06-07    Shelley
# 169282  zcrm_3584690000555505322 2025-06-09 11:48:30        empty   Danielle
#
#        Last Name                      Email         Phone Mobile Birthdate  \
# 472       Ayling                      empty  447753473354  empty     empty
# 473       Ayling                      empty  447753473354  empty     empty
# 2594       Price         adejp2@yahoo.co.uk  447923120641  empty     empty
# 2609       Burse    andyburse@hotmail.co.uk  447733400824  empty     empty
# 2620     Paynter       barasheed8@gmail.com  447562947177  empty     empty
# ...          ...                        ...           ...    ...       ...
# 169211    Harris  imkathrynharris@gmail.com  447455744407  empty     empty
# 169222     Sharp         ysharp69@gmail.com  447532238400  empty     empty
# 169243    penney   gpenney49@googlemail.com  447860358495  empty     empty
# 169273     Banks   shelleybanks88@gmail.com  447514818898  empty     empty
# 169282      Mavi     danimavi@hotmail.co.uk  447395502141  empty     empty
#
#        Year of Birth  ... Lead Regions Lead Status Booking Status  BookRef  \
# 472            empty  ...    UK/Europe    New Lead          empty    empty
# 473            empty  ...    UK/Europe    New Lead          empty    empty
# 2594            1969  ...    UK/Europe    New Lead          empty    empty
# 2609            2001  ...    UK/Europe    New Lead          empty    empty
# 2620            1991  ...    UK/Europe    New Lead          empty    empty
# ...              ...  ...          ...         ...            ...      ...
# 169211         empty  ...        empty       empty    Checked-Out  2845180
# 169222         empty  ...        empty       empty    Checked-Out  2606699
# 169243         empty  ...    UK/Europe       empty          empty    empty
# 169273         empty  ...    UK/Europe       empty          empty    empty
# 169282         empty  ...        empty       empty    Checked-Out  2809901
#
#        Email Opt Out Opt In GDPR Compliant  \
# 472            empty  empty          empty
# 473            empty  empty          empty
# 2594           empty  empty          empty
# 2609           empty  empty          empty
# 2620           empty  empty          empty
# ...              ...    ...            ...
# 169211         false   true           true
# 169222         false   true           true
# 169243         false   true           true
# 169273         false   true           true
# 169282         false   true           true
#
#                                                   Website  \
# 472                                                 empty
# 473                                                 empty
# 2594                                                empty
# 2609                                                empty
# 2620                                                empty
# ...                                                   ...
# 169211                                              empty
# 169222                                              empty
# 169243    https://karmagroup.com/gdpr-form/?render=dialog
# 169273  https://karmagroup.com/events-at-karma-salford...
# 169282                                              empty
#
#                                                 Comments Do you live in Bali?
# 472                                                empty                empty
# 473                                                empty                empty
# 2594                                               empty                empty
# 2609                                               empty                empty
# 2620                                               empty                empty
# ...                                                  ...                  ...
# 169211                                             empty                false
# 169222                                             empty                false
# 169243                                             empty                false
# 169273  Type of Event: Party / Date of Event: 12-10-2025                false
# 169282                                             empty                false
#
# [11888 rows x 35 columns]

# %%
zoho_df.drop_duplicates(subset=['Phone','Email', 'Mobile'], inplace=True)
zoho_df.reset_index(drop=True, inplace=True)

# hitung jumlah setelah value duplicate dihapus
count_after_dedup_duplicate = zoho_df.shape[0]

zoho_df
# Out:
#                        Record Id        Created Time Created Date  \
# 0       zcrm_3584690000000404115 2019-01-07 15:08:38   2019-01-06
# 1       zcrm_3584690000000404196 2019-01-07 15:08:38   2019-01-07
# 2       zcrm_3584690000000404209 2019-01-07 15:08:38   2019-01-06
# 3       zcrm_3584690000000404459 2019-01-08 11:07:28   2019-01-03
# 4       zcrm_3584690000000404460 2019-01-08 11:07:28   2019-01-03
# ...                          ...                 ...          ...
# 158231  zcrm_3584690000555509137 2025-06-09 11:51:05        empty
# 158232  zcrm_3584690000555509367 2025-06-09 11:55:37        empty
# 158233  zcrm_3584690000555514001 2025-06-09 01:50:38   2025-06-08
# 158234  zcrm_3584690000555514164 2025-06-09 11:49:51        empty
# 158235  zcrm_3584690000555514228 2025-06-09 11:51:08        empty
#
#           First Name   Last Name                      Email         Phone  \
# 0             Harley     Russell     hars_russ7@hotmail.com  447834782590
# 1             Tobias     Klitsch   tobias.klitsch@gmail.com  447516721033
# 2             Thomas        Wood  wood.thomas99@yahoo.co.uk  447887405046
# 3       Sophie-Irene     Averman     sonicaverman@gmail.com  380503048815
# 4               Юлия       Жулий        y.zhulii@icloud.com  380633945350
# ...              ...         ...                        ...           ...
# 158231         Janis    Allerton    j4nisallerton@gmail.com  447710107054
# 158232        Martin     Maloney    martinusahols@gmail.com  447533715827
# 158233    Eugene May  Eugene May       eugenelmay@gmail.com  447413538915
# 158234         Linda      Lawley     lindalawley4@gmail.com  447773014928
# 158235        Trevor      Parvin    trevorparvin@icloud.com  447792914660
#
#        Mobile   Birthdate Year of Birth  ... Lead Regions Lead Status  \
# 0       empty  1995-01-24          1995  ...    UK/Europe    New Lead
# 1       empty  1982-06-01          1982  ...    UK/Europe    New Lead
# 2       empty  1990-09-01          1990  ...    UK/Europe    New Lead
# 3       empty  1981-08-22          1981  ...    UK/Europe    New Lead
# 4       empty       empty         empty  ...    UK/Europe    New Lead
# ...       ...         ...           ...  ...          ...         ...
# 158231  empty       empty         empty  ...        empty       empty
# 158232  empty       empty         empty  ...        empty       empty
# 158233  empty       empty         empty  ...    UK/Europe       empty
# 158234  empty       empty         empty  ...        empty       empty
# 158235  empty       empty         empty  ...        empty       empty
#
#        Booking Status  BookRef Email Opt Out Opt In GDPR Compliant  \
# 0               empty    empty         empty  empty          empty
# 1               empty    empty         empty  empty          empty
# 2               empty    empty         empty  empty          empty
# 3               empty    empty         empty  empty          empty
# 4               empty    empty         empty  empty          empty
# ...               ...      ...           ...    ...            ...
# 158231    Checked-Out  2774216         false   true           true
# 158232    Checked-Out  2847346         false   true           true
# 158233          empty    empty         false   true           true
# 158234    Checked-Out  2760709         false   true           true
# 158235    Checked-Out  2768456         false   true           true
#
#                                                   Website Comments  \
# 0                                                   empty    empty
# 1                                                   empty    empty
# 2                                                   empty    empty
# 3                                                   empty    empty
# 4                                                   empty    empty
# ...                                                   ...      ...
# 158231                                              empty    empty
# 158232                                              empty    empty
# 158233  https://karmagroup.com/weddings-at-karma-st-ma...    empty
# 158234                                              empty    empty
# 158235                                              empty    empty
#
#        Do you live in Bali?
# 0                     empty
# 1                     empty
# 2                     empty
# 3                     empty
# 4                     empty
# ...                     ...
# 158231                false
# 158232                false
# 158233                false
# 158234                false
# 158235                false
#
# [158236 rows x 35 columns]

# %%
# Cek leads test
test_leads = zoho_df.loc[
    
        zoho_df['Email'].str.contains('^test@', flags=re.I, regex=True) |
        zoho_df['Email'].str.contains('\+test', flags=re.I, regex=True) |
    
        zoho_df['First Name'].str.contains('^test$', flags=re.I, regex=True) |
        zoho_df['Last Name'].str.contains('^test$', flags=re.I, regex=True) |

        zoho_df['First Name'].str.contains('test 1', flags=re.I, regex=True) |
        zoho_df['Last Name'].str.contains('test 2', flags=re.I, regex=True)|
        zoho_df['First Name'].str.contains('test1', flags=re.I, regex=True) |
        zoho_df['Last Name'].str.contains('test2', flags=re.I, regex=True)|

        zoho_df['First Name'].str.contains(' test ', flags=re.I, regex=True) | 
        zoho_df['Last Name'].str.contains(' test ', flags=re.I, regex=True) | 
        zoho_df['Last Name'].str.contains(' test$', flags=re.I, regex=True)
    ]

count_leads_test = test_leads.shape[0]

# test_leads.to_excel(r'C:\Users\fajar.fatoni\Documents\Python\Data\test_leads_2.xlsx', index=False)
test_leads
# Out:
#                        Record Id        Created Time Created Date First Name  \
# 23928   zcrm_3584690000007188441 2019-04-02 05:29:43   2015-05-12       Dale
# 131184  zcrm_3584690000407110581 2022-10-31 03:38:54        empty       test
# 133697  zcrm_3584690000412149318 2022-11-21 15:26:19        empty  Karma lsq
# 134270  zcrm_3584690000413599783 2022-11-28 14:52:45        empty  Karma lsq
# 139029  zcrm_3584690000449180597 2023-06-15 16:01:04        empty       Test
# 148276  zcrm_3584690000466714576 2023-10-25 10:59:20        empty      Fajar
# 157885  zcrm_3584690000545564001 2025-05-09 05:31:09        empty       Test
#
#        Last Name                              Email         Phone  \
# 23928          M                     test@email.com  447814119185
# 131184      test                      test@test.com  447488277095
# 133697  Lsq test                              empty  447715000376
# 134270  Lsq test                              empty  447944674947
# 139029       Yes                 azad9292@gmail.com  447405156500
# 148276    Fatoni  fajar.fatoni+test@karmagroup.coom  447575610397
# 157885      Test              gm@karmastmartins.com  447756613312
#
#               Mobile   Birthdate Year of Birth  ... Lead Regions Lead Status  \
# 23928   447814119185       empty          1997  ...    UK/Europe       empty
# 131184         empty       empty         empty  ...    UK/Europe       empty
# 133697  919999077777  1970-01-01         empty  ...        India       empty
# 134270  919999077777  1970-01-01         empty  ...        India       empty
# 139029  447405156500       empty         empty  ...    UK/Europe       empty
# 148276         empty       empty         empty  ...    UK/Europe       empty
# 157885         empty       empty         empty  ...    UK/Europe       empty
#
#        Booking Status BookRef Email Opt Out Opt In GDPR Compliant  \
# 23928           empty   empty         empty  empty          empty
# 131184          empty   empty         empty  empty          empty
# 133697          empty   empty         empty  empty          empty
# 134270          empty   empty         empty  empty          empty
# 139029          empty   empty         empty  empty          empty
# 148276          empty   empty         empty  empty          empty
# 157885          empty   empty         false   true           true
#
#                                                   Website Comments  \
# 23928                                               empty    empty
# 131184                                              empty    empty
# 133697                                              empty    empty
# 134270                                              empty    empty
# 139029                                              empty    empty
# 148276                                              empty    empty
# 157885  https://karmagroup.com/friend-of-karma-st-mart...    empty
#
#        Do you live in Bali?
# 23928                 empty
# 131184                empty
# 133697                empty
# 134270                empty
# 139029                empty
# 148276                empty
# 157885                false
#
# [7 rows x 35 columns]

# %%
zoho_df.drop(test_leads.index, inplace=True)
zoho_df.reset_index(drop=True, inplace=True)

count_after_dedup_test = zoho_df.shape[0]

# %%
# dnm_leads = zoho_df.loc[(zoho_df['Do Not Mail'] == 'true') | (zoho_df['Do Not Contact'] == 'true')]
# count_dnm = dnm_leads.shape[0]

# %%
# zoho_df.drop(dnm_leads.index, inplace=True)
# zoho_df.reset_index(drop=True, inplace=True)

# count_after_dedup_dnm = zoho_df.shape[0]

# %%
# Cek Email OTA
email_OTA = m.find_OTA(zoho_df, 'Email')
count_email_OTA = email_OTA.shape[0]
# email_OTA.to_excel(r'C:\Users\fajar.fatoni\Documents\Python\Data\email_OTA.xlsx', index=False)

email_OTA
# Out:
#                        Record Id        Created Time Created Date  \
# 433     zcrm_3584690000000460684 2019-01-09 11:11:16        empty
# 617     zcrm_3584690000000463367 2019-01-09 11:11:33        empty
# 665     zcrm_3584690000000463847 2019-01-09 11:11:35        empty
# 1444    zcrm_3584690000002514113 2019-02-22 12:03:52   2019-02-22
# 1456    zcrm_3584690000002719504 2019-02-25 12:15:17   2019-02-25
# 4604    zcrm_3584690000005230585 2019-03-26 17:44:06        empty
# 6508    zcrm_3584690000005234670 2019-03-26 17:44:30        empty
# 10236   zcrm_3584690000005243033 2019-03-26 17:45:21        empty
# 10614   zcrm_3584690000005243820 2019-03-26 17:45:25        empty
# 13126   zcrm_3584690000006024637 2019-04-02 02:22:26   2017-08-30
# 13281   zcrm_3584690000006026638 2019-04-02 02:22:39   2016-02-27
# 13983   zcrm_3584690000006042565 2019-04-02 02:24:17   2015-03-11
# 16977   zcrm_3584690000006242563 2019-04-02 03:28:24   2018-08-29
# 17895   zcrm_3584690000006245194 2019-04-02 03:28:39   2018-09-06
# 20485   zcrm_3584690000006451625 2019-04-02 03:58:20   2000-01-01
# 26213   zcrm_3584690000007279221 2019-04-02 05:38:55   2017-07-20
# 28067   zcrm_3584690000008606746 2019-04-02 08:21:02   2015-03-09
# 29046   zcrm_3584690000009115488 2019-04-02 09:57:47   2000-01-01
# 29448   zcrm_3584690000009313992 2019-04-02 10:24:34   2013-09-17
# 30148   zcrm_3584690000009658744 2019-04-02 11:17:35   2013-09-17
# 30480   zcrm_3584690000009816149 2019-04-02 11:44:30   2012-01-01
# 32463   zcrm_3584690000011098468 2019-04-02 14:20:23   2012-10-22
# 32628   zcrm_3584690000011246699 2019-04-02 14:31:33   2013-09-17
# 33495   zcrm_3584690000012083678 2019-04-02 15:46:26   2013-09-17
# 33496   zcrm_3584690000012083705 2019-04-02 15:46:26   2013-09-17
# 43603   zcrm_3584690000024615300 2019-04-07 16:57:38   2019-02-14
# 97840   zcrm_3584690000025158368 2019-04-09 21:51:48        empty
# 97888   zcrm_3584690000025158418 2019-04-09 21:51:48        empty
# 97897   zcrm_3584690000025158427 2019-04-09 21:51:48        empty
# 97931   zcrm_3584690000025158461 2019-04-09 21:51:48        empty
# 98013   zcrm_3584690000025158745 2019-04-09 21:51:50        empty
# 98014   zcrm_3584690000025158746 2019-04-09 21:51:50        empty
# 98015   zcrm_3584690000025158747 2019-04-09 21:51:50        empty
# 98569   zcrm_3584690000026739291 2019-04-18 19:13:53        empty
# 101662  zcrm_3584690000044532588 2019-06-13 16:08:48        empty
# 105492  zcrm_3584690000145109564 2019-11-20 20:19:54        empty
# 122431  zcrm_3584690000317284317 2021-09-28 18:52:34        empty
# 126599  zcrm_3584690000382580449 2022-07-12 12:39:26   2022-06-15
# 130220  zcrm_3584690000401600183 2022-09-27 20:49:00        empty
# 130469  zcrm_3584690000403806940 2022-10-10 16:18:08        empty
# 135275  zcrm_3584690000424810863 2023-01-27 11:36:04        empty
# 138285  zcrm_3584690000444134148 2023-05-11 16:02:44        empty
# 139992  zcrm_3584690000453972088 2023-07-18 23:06:52        empty
# 142599  zcrm_3584690000460374320 2023-09-05 17:54:24   2023-06-30
# 156455  zcrm_3584690000523983449 2025-02-09 22:40:47        empty
#
#                First Name        Last Name  \
# 433                 James            Wilde
# 617                 Peter          Dowling
# 665                Rachel            Kelly
# 1444                 Tina           Dahmen
# 1456              Cameron          Roucher
# 4604                Laura        Ahtiainen
# 6508                Nadia        Linkleter
# 10236               David          Charles
# 10614                 Has       Saboowalla
# 13126           Andreasen           Folmer
# 13281           Ann-marie  Dawson & Ashton
# 13983           Christian        Kimberley
# 16977            Catriona          Mcphail
# 17895             Eleanor         Robinson
# 20485               empty              Atl
# 26213             Ngarita          Te Patu
# 28067               Ahmad          Suwardi
# 29046    Pamela Camposano            empty
# 29448                Sham         Kalaskar
# 30148                Sham         Kalaskar
# 30480         R Ravivarma            empty
# 32463           Taj Tours            empty
# 32628       Arvind Gurung            empty
# 33495   Hari Krishnan P K            empty
# 33496              Sheikh             Moin
# 43603           Elizabeth        Whitehorn
# 97840               Leigh         Sorenson
# 97888              Anabel         Thomasse
# 97897                Glen            Davis
# 97931             Richard        Warburton
# 98013               Sarah          Barnett
# 98014             Silvija        Stojkovic
# 98015               Erika        Lamanuzzi
# 98569                Paul              Kim
# 101662         Novosadova      Tetyana/Mrs
# 105492            William           Lagoda
# 122431               Lana          Bennett
# 126599               Fran          Wintour
# 130220               Jeff           Spence
# 130469               Neil          Jackson
# 135275            Malcolm          Goodall
# 138285               Neil          Jackson
# 139992               Kate          Roberts
# 142599            Natasha            Price
# 156455              David          Spooner
#
#                                            Email          Phone        Mobile  \
# 433                jwilde826368@guestbooking.com   447971421148         empty
# 617            pete.dowling@riverstouridb.org.uk   447729745806         empty
# 665                rkelly475533@guestbooking.com   447768781970         empty
# 1444                      go@luxurybalitours.com   447596824458         empty
# 1456                      groverontour@gmail.com   441323871048  447730217422
# 4604                   tourist-4ever@hotmail.com   447455836796         empty
# 6508                     nadiaontour@hotmail.com   447766568224         empty
# 10236              stourbridgebaggie@yahoo.co.uk   447821593540         empty
# 10614                      hasontour@hotmail.com   447958354291         empty
# 13126                  fandre.711965@booking.com   444524628643         empty
# 13281                  ashtonsontour@yahoo.co.uk   442085917643  447782221110
# 13983                   dturner@europeantour.com   447500829083         empty
# 16977                          tourist35@aol.com   447879641120         empty
# 17895                     eleanor@gowertours.com   447806565602         empty
# 20485              s.youssef@alliedtourism.co.uk   902123434304         empty
# 26213                       ngatours@yahoo.co.uk    64212032357         empty
# 28067                   lorannatours@yahoo.co.uk   628123676615         empty
# 29046              fame_travelntours@yahoo.co.uk   639153923060         empty
# 29448                      india@startours.co.uk   912228881131  912228881132
# 30148                       sham@startours.co.uk   912228881131  912228881132
# 30480          tourismindiamarketing@yahoo.co.uk   919947260531  914712315256
# 32463                      mumbai@tajtours.co.uk   912224445699  912224446699
# 32628               dharamsala_tours@yahoo.co.uk   911892224015         empty
# 33495                        tours@linkair.co.uk   914712527093  919847273135
# 33496                     tours_rant@yahoo.co.uk   917462233505  917462265296
# 43603                 missendentours@supanet.com     1844344545         empty
# 97840            lsorensen@tourism.australia.com   442074384614  447775938012
# 97888            athomasse@tourism.australia.com   442074384635         empty
# 97897               gdavis@tourism.australia.com   442074384614  447715002229
# 97931                     rwarburton@expedia.com   442070192000         empty
# 98013             sbarnett@tourism.australia.com   442074384618         empty
# 98014           sstojkovic@tourism.australia.com  4420774384603         empty
# 98015           elamanuzzi@tourism.australia.com   442074384602         empty
# 98569                   bbp.feedback@booking.com   442036847925         empty
# 101662                      office@vstours.ks.ua   380552440131         empty
# 105492                       lagoda@ntlworld.com   447974123058         empty
# 122431              lana@tours-international.com  4401892515825         empty
# 126599                      fwintour@hotmail.com  4407788947772         empty
# 130220  enquiries@purpleheatherscottishtours.com   447428693623         empty
# 130469                   neil@pennywoodtours.com   441622434981  441622434981
# 135275                   malc_ontour@yahoo.co.uk   447969421009  447969421009
# 138285                   neil@pennywoodtours.com   447780994013  447780994013
# 139992               kate@livetravelandtours.com   441372722154         empty
# 142599                    tashontour@hotmail.com   447821056065         empty
# 156455                   david@scottourguide.com   447842889109         empty
#
#          Birthdate Year of Birth  ... Lead Regions Lead Status Booking Status  \
# 433          empty         empty  ...    UK/Europe    New Lead          empty
# 617          empty         empty  ...    UK/Europe    New Lead          empty
# 665          empty         empty  ...    UK/Europe    New Lead          empty
# 1444         empty         empty  ...         SEAP    New Lead          empty
# 1456    1977-12-21          1977  ...    UK/Europe       empty          empty
# 4604         empty          1991  ...    UK/Europe    New Lead          empty
# 6508         empty          1984  ...    UK/Europe    New Lead          empty
# 10236        empty          1984  ...    UK/Europe    New Lead          empty
# 10614        empty          1984  ...    UK/Europe    New Lead          empty
# 13126        empty         empty  ...    UK/Europe       empty          empty
# 13281        empty         empty  ...    UK/Europe       empty          empty
# 13983        empty         empty  ...    UK/Europe       empty          empty
# 16977   1961-12-04          1961  ...    UK/Europe       empty          empty
# 17895   1970-06-03          1970  ...    UK/Europe       empty          empty
# 20485        empty         empty  ...    UK/Europe       empty          empty
# 26213   1977-01-29          1977  ...    UK/Europe       empty          empty
# 28067        empty         empty  ...    UK/Europe       empty          empty
# 29046        empty         empty  ...    UK/Europe       empty          empty
# 29448        empty         empty  ...    UK/Europe       empty          empty
# 30148        empty         empty  ...    UK/Europe       empty          empty
# 30480        empty         empty  ...    UK/Europe       empty          empty
# 32463        empty         empty  ...    UK/Europe       empty          empty
# 32628        empty         empty  ...    UK/Europe       empty          empty
# 33495        empty         empty  ...    UK/Europe       empty          empty
# 33496        empty         empty  ...    UK/Europe       empty          empty
# 43603        empty         empty  ...    UK/Europe    New Lead          empty
# 97840        empty         empty  ...    UK/Europe    New Lead          empty
# 97888        empty         empty  ...    UK/Europe    New Lead          empty
# 97897        empty         empty  ...    UK/Europe    New Lead          empty
# 97931        empty         empty  ...    UK/Europe    New Lead          empty
# 98013        empty         empty  ...    UK/Europe    New Lead          empty
# 98014        empty         empty  ...    UK/Europe    New Lead          empty
# 98015        empty         empty  ...    UK/Europe    New Lead          empty
# 98569        empty         empty  ...         SEAP    New Lead          empty
# 101662       empty         empty  ...    UK/Europe    New Lead          empty
# 105492       empty         empty  ...    UK/Europe       empty          empty
# 122431       empty         empty  ...         SEAP       empty          empty
# 126599       empty         empty  ...        empty    New Lead          empty
# 130220       empty         empty  ...         SEAP       empty          empty
# 130469       empty         empty  ...    UK/Europe       empty          empty
# 135275       empty         empty  ...    UK/Europe       empty          empty
# 138285       empty         empty  ...    UK/Europe       empty          empty
# 139992       empty         empty  ...    UK/Europe       empty          empty
# 142599  1977-08-08         empty  ...    UK/Europe    New Lead          empty
# 156455       empty         empty  ...    UK/Europe       empty          empty
#
#        BookRef Email Opt Out Opt In GDPR Compliant  \
# 433      empty         empty  empty          empty
# 617      empty         empty  empty          empty
# 665      empty         empty  empty          empty
# 1444     empty         empty  empty          empty
# 1456     empty         empty  empty          empty
# 4604     empty         empty  empty          empty
# 6508     empty         empty  empty          empty
# 10236    empty         empty  empty          empty
# 10614    empty         empty  empty          empty
# 13126    empty         empty  empty          empty
# 13281    empty         empty  empty          empty
# 13983    empty         empty  empty          empty
# 16977    empty         empty  empty          empty
# 17895    empty         empty  empty          empty
# 20485    empty         empty  empty          empty
# 26213    empty         empty  empty          empty
# 28067    empty         empty  empty          empty
# 29046    empty         empty  empty          empty
# 29448    empty         empty  empty          empty
# 30148    empty         empty  empty          empty
# 30480    empty         empty  empty          empty
# 32463    empty         empty  empty          empty
# 32628    empty         empty  empty          empty
# 33495    empty         empty  empty          empty
# 33496    empty         empty  empty          empty
# 43603    empty         empty  empty          empty
# 97840    empty         empty  empty          empty
# 97888    empty         empty  empty          empty
# 97897    empty         empty  empty          empty
# 97931    empty         empty  empty          empty
# 98013    empty         empty  empty          empty
# 98014    empty         empty  empty          empty
# 98015    empty         empty  empty          empty
# 98569    empty         empty  empty          empty
# 101662   empty         empty  empty          empty
# 105492   empty         empty  empty          empty
# 122431   empty         empty  empty          empty
# 126599   empty         empty  empty          empty
# 130220   empty         empty  empty          empty
# 130469   empty         empty  empty          empty
# 135275   empty         empty  empty          empty
# 138285   empty         empty  empty          empty
# 139992   empty         empty  empty          empty
# 142599   empty         empty  empty          empty
# 156455   empty         false   true           true
#
#                                                   Website Comments  \
# 433                                                 empty    empty
# 617                                                 empty    empty
# 665                                                 empty    empty
# 1444                                                empty    empty
# 1456                                                empty    empty
# 4604                                                empty    empty
# 6508                                                empty    empty
# 10236                                               empty    empty
# 10614                                               empty    empty
# 13126                                               empty    empty
# 13281                                               empty    empty
# 13983                                               empty    empty
# 16977                                               empty    empty
# 17895                                               empty    empty
# 20485                                               empty    empty
# 26213                                               empty    empty
# 28067                                               empty    empty
# 29046                                               empty    empty
# 29448                                               empty    empty
# 30148                                               empty    empty
# 30480                                               empty    empty
# 32463                                               empty    empty
# 32628                                               empty    empty
# 33495                                               empty    empty
# 33496                                               empty    empty
# 43603                                               empty    empty
# 97840                                               empty    empty
# 97888                                               empty    empty
# 97897                                               empty    empty
# 97931                                               empty    empty
# 98013                                               empty    empty
# 98014                                               empty    empty
# 98015                                               empty    empty
# 98569                                               empty    empty
# 101662                                              empty    empty
# 105492                                              empty    empty
# 122431                                              empty    empty
# 126599                                              empty    empty
# 130220                                              empty    empty
# 130469                                              empty    empty
# 135275                                              empty    empty
# 138285                                              empty    empty
# 139992                                              empty    empty
# 142599                                              empty    empty
# 156455  https://karmagroup.com/find-destination/karma-...    empty
#
#        Do you live in Bali?
# 433                   empty
# 617                   empty
# 665                   empty
# 1444                  empty
# 1456                  empty
# 4604                  empty
# 6508                  empty
# 10236                 empty
# 10614                 empty
# 13126                 empty
# 13281                 empty
# 13983                 empty
# 16977                 empty
# 17895                 empty
# 20485                 empty
# 26213                 empty
# 28067                 empty
# 29046                 empty
# 29448                 empty
# 30148                 empty
# 30480                 empty
# 32463                 empty
# 32628                 empty
# 33495                 empty
# 33496                 empty
# 43603                 empty
# 97840                 empty
# 97888                 empty
# 97897                 empty
# 97931                 empty
# 98013                 empty
# 98014                 empty
# 98015                 empty
# 98569                 empty
# 101662                empty
# 105492                empty
# 122431                empty
# 126599                empty
# 130220                empty
# 130469                empty
# 135275                empty
# 138285                empty
# 139992                empty
# 142599                empty
# 156455                false
#
# [45 rows x 35 columns]

# %%
# delete email OTA
count_after_clean_OTA = m.delete_OTA(zoho_df, 'Email')
# zoho_df.to_excel(r'C:\Users\fajar.fatoni\Documents\Python\Data\after_clean_OTA.xlsx', index=False)

zoho_df
# Out:
#                        Record Id        Created Time Created Date  \
# 0       zcrm_3584690000000404115 2019-01-07 15:08:38   2019-01-06
# 1       zcrm_3584690000000404196 2019-01-07 15:08:38   2019-01-07
# 2       zcrm_3584690000000404209 2019-01-07 15:08:38   2019-01-06
# 3       zcrm_3584690000000404459 2019-01-08 11:07:28   2019-01-03
# 4       zcrm_3584690000000404460 2019-01-08 11:07:28   2019-01-03
# ...                          ...                 ...          ...
# 158179  zcrm_3584690000555509137 2025-06-09 11:51:05        empty
# 158180  zcrm_3584690000555509367 2025-06-09 11:55:37        empty
# 158181  zcrm_3584690000555514001 2025-06-09 01:50:38   2025-06-08
# 158182  zcrm_3584690000555514164 2025-06-09 11:49:51        empty
# 158183  zcrm_3584690000555514228 2025-06-09 11:51:08        empty
#
#           First Name   Last Name                      Email         Phone  \
# 0             Harley     Russell     hars_russ7@hotmail.com  447834782590
# 1             Tobias     Klitsch   tobias.klitsch@gmail.com  447516721033
# 2             Thomas        Wood  wood.thomas99@yahoo.co.uk  447887405046
# 3       Sophie-Irene     Averman     sonicaverman@gmail.com  380503048815
# 4               Юлия       Жулий        y.zhulii@icloud.com  380633945350
# ...              ...         ...                        ...           ...
# 158179         Janis    Allerton    j4nisallerton@gmail.com  447710107054
# 158180        Martin     Maloney    martinusahols@gmail.com  447533715827
# 158181    Eugene May  Eugene May       eugenelmay@gmail.com  447413538915
# 158182         Linda      Lawley     lindalawley4@gmail.com  447773014928
# 158183        Trevor      Parvin    trevorparvin@icloud.com  447792914660
#
#        Mobile   Birthdate Year of Birth  ... Lead Regions Lead Status  \
# 0       empty  1995-01-24          1995  ...    UK/Europe    New Lead
# 1       empty  1982-06-01          1982  ...    UK/Europe    New Lead
# 2       empty  1990-09-01          1990  ...    UK/Europe    New Lead
# 3       empty  1981-08-22          1981  ...    UK/Europe    New Lead
# 4       empty       empty         empty  ...    UK/Europe    New Lead
# ...       ...         ...           ...  ...          ...         ...
# 158179  empty       empty         empty  ...        empty       empty
# 158180  empty       empty         empty  ...        empty       empty
# 158181  empty       empty         empty  ...    UK/Europe       empty
# 158182  empty       empty         empty  ...        empty       empty
# 158183  empty       empty         empty  ...        empty       empty
#
#        Booking Status  BookRef Email Opt Out Opt In GDPR Compliant  \
# 0               empty    empty         empty  empty          empty
# 1               empty    empty         empty  empty          empty
# 2               empty    empty         empty  empty          empty
# 3               empty    empty         empty  empty          empty
# 4               empty    empty         empty  empty          empty
# ...               ...      ...           ...    ...            ...
# 158179    Checked-Out  2774216         false   true           true
# 158180    Checked-Out  2847346         false   true           true
# 158181          empty    empty         false   true           true
# 158182    Checked-Out  2760709         false   true           true
# 158183    Checked-Out  2768456         false   true           true
#
#                                                   Website Comments  \
# 0                                                   empty    empty
# 1                                                   empty    empty
# 2                                                   empty    empty
# 3                                                   empty    empty
# 4                                                   empty    empty
# ...                                                   ...      ...
# 158179                                              empty    empty
# 158180                                              empty    empty
# 158181  https://karmagroup.com/weddings-at-karma-st-ma...    empty
# 158182                                              empty    empty
# 158183                                              empty    empty
#
#        Do you live in Bali?
# 0                     empty
# 1                     empty
# 2                     empty
# 3                     empty
# 4                     empty
# ...                     ...
# 158179                false
# 158180                false
# 158181                false
# 158182                false
# 158183                false
#
# [158184 rows x 35 columns]

# %%
# Cek Email Karma
email_karma = m.find_karma(zoho_df, 'Email')
count_email_karma = email_karma.shape[0]
# email_OTA.to_excel(r'C:\Users\fajar.fatoni\Documents\Python\Data\email_OTA.xlsx', index=False)

email_karma
# Out:
#                        Record Id        Created Time Created Date  \
# 11124   zcrm_3584690000005935773 2019-04-02 02:13:55   2017-01-18
# 97462   zcrm_3584690000024724404 2019-04-07 17:14:49   2019-02-20
# 98583   zcrm_3584690000026741697 2019-04-18 19:14:10        empty
# 98584   zcrm_3584690000026741698 2019-04-18 19:14:10        empty
# 100064  zcrm_3584690000029454628 2019-05-08 18:45:24        empty
# 103391  zcrm_3584690000108073083 2019-08-29 19:43:59        empty
# 103392  zcrm_3584690000108073124 2019-08-29 22:37:48        empty
# 104761  zcrm_3584690000132031790 2019-10-14 18:15:14        empty
# 104762  zcrm_3584690000132034336 2019-10-14 18:15:17        empty
# 106435  zcrm_3584690000161107425 2020-01-24 18:41:51        empty
# 106441  zcrm_3584690000161118304 2020-01-24 18:11:37        empty
# 106443  zcrm_3584690000161124164 2020-01-24 17:04:14        empty
# 106444  zcrm_3584690000161124249 2020-01-24 17:26:12        empty
# 106495  zcrm_3584690000162055460 2020-01-28 21:41:37        empty
# 107427  zcrm_3584690000205762046 2020-07-20 15:08:23        empty
# 112881  zcrm_3584690000310839101 2021-08-27 03:15:13        empty
# 113086  zcrm_3584690000310845621 2021-08-27 03:52:21        empty
# 113446  zcrm_3584690000310853131 2021-08-27 03:23:32        empty
# 113475  zcrm_3584690000310853447 2021-08-27 03:51:30        empty
# 114276  zcrm_3584690000310881780 2021-08-27 05:12:11        empty
# 114839  zcrm_3584690000310892692 2021-08-27 09:26:26        empty
# 115698  zcrm_3584690000310955531 2021-08-27 10:23:42        empty
# 115826  zcrm_3584690000310959318 2021-08-27 10:20:09        empty
# 115941  zcrm_3584690000310960963 2021-08-27 10:52:29        empty
# 116283  zcrm_3584690000310983039 2021-08-27 10:41:55        empty
# 116504  zcrm_3584690000310993182 2021-08-27 10:56:17        empty
# 116516  zcrm_3584690000310993322 2021-08-27 11:33:19        empty
# 124261  zcrm_3584690000347647003 2022-02-24 16:34:23        empty
# 127446  zcrm_3584690000384873749 2022-07-20 12:59:46        empty
# 130834  zcrm_3584690000405820115 2022-10-21 20:23:22   2022-10-21
# 132517  zcrm_3584690000409569251 2022-11-09 18:04:59   2022-11-09
# 132581  zcrm_3584690000409779353 2022-11-10 16:01:03        empty
# 134182  zcrm_3584690000413009236 2022-11-24 16:01:12        empty
# 134456  zcrm_3584690000416992435 2022-12-14 15:32:36        empty
# 134639  zcrm_3584690000418805348 2022-12-22 16:01:20        empty
# 135681  zcrm_3584690000429061041 2023-02-14 20:41:52        empty
# 136685  zcrm_3584690000437989059 2023-03-30 16:01:22        empty
# 138853  zcrm_3584690000448305247 2023-06-08 16:49:03        empty
# 138858  zcrm_3584690000448317066 2023-06-08 16:00:41        empty
# 139017  zcrm_3584690000449253322 2023-06-15 16:01:37        empty
# 140417  zcrm_3584690000456167592 2023-08-04 15:20:52        empty
# 141188  zcrm_3584690000459619693 2023-08-31 13:53:19   2023-08-31
# 147394  zcrm_3584690000462508488 2023-09-23 16:27:30        empty
# 153601  zcrm_3584690000505118034 2024-08-19 23:34:10        empty
# 154136  zcrm_3584690000508307043 2024-09-17 19:56:20   2024-09-17
#
#           First Name       Last Name  \
# 11124         Nicola          Stokes
# 97462         Monika          Monika
# 98583         Graham         Fischer
# 98584      Rosemarie            Lane
# 100064          John          spence
# 103391         Karyn          Dalili
# 103392         Karyn          Dalali
# 104761            GM              GM
# 104762        Denise           Tubbs
# 106435             A            P114
# 106441             A            P110
# 106443             A            P104
# 106444             A            P107
# 106495             A            P175
# 107427          Mike           Evens
# 112881       Orsolya           Galfi
# 113086          Mark          Fuller
# 113446           Tom         Laslett
# 113475          Mark          Fuller
# 114276         empty            Tash
# 114839         empty          Emilio
# 115698         empty           Haleh
# 115826           Cat            King
# 115941      Dimitris         Manikis
# 116283           Ani         Chirita
# 116504           Mel           Hoven
# 116516          Kate            Moss
# 124261       brijesh           patel
# 127446         James        Woodhams
# 130834          Miss  Elise Williams
# 132517  [first-name]     [last-name]
# 132581           Dan         Fgghyfc
# 134182          Judy           Yates
# 134456           DAN        RICHARDS
# 134639     Sebastian         Moeller
# 135681         Elise        Williams
# 136685      Anything         Anytibg
# 138853         Lizzy          Mclean
# 138858     Sebastian         Moeller
# 139017        Adrian        Willmers
# 140417        Adrian        Willmers
# 141188       Annette        Fairburn
# 147394           Ian          Grange
# 153601         Lizzy         McLeans
# 154136         empty           James
#
#                                                     Email           Phone  \
# 11124                               nicola.stokes@rci.com    441536314307
# 97462                              monika.borbely@rci.com  35321569874665
# 98583                        reception@karmastmartins.com    447727299577
# 98584                         recption@karmastmartins.com    447871195989
# 100064                           johnspence88@hotmail.com    447808651562
# 103391                       reservation@karmabavaria.com    441720422368
# 103392                       reception@karmastmartins.com  44441720422368
# 104761                              gm@karmastmartins.com    441720422368
# 104762                             fom@karmastmartins.com      7900220055
# 106435  andrea.pavlidis+baligetawaycompetition@karmagr...     44114114114
# 106441  andrea.pavlidis+qbhbedrockhotelkuta@karmagroup...     44110110110
# 106443  andrea.pavlidis+lmdramadaencoreseminyak@karmag...     44104104104
# 106444  andrea.pavlidis+nahotelskutaangelhotelluxuriou...    441071071017
# 106495  andrea.pavlidis+resortenquirykarmamayura@karma...    446979898175
# 107427                          mike.evens@karmagroup.com     66808057205
# 112881                            orsolya@sanctumsoho.com      7752459369
# 113086                               mf@conceptvenues.com      7774213846
# 113446                                tom@sanctumsoho.com      7703363103
# 113475                       reservations@sanctumsoho.com      7774213846
# 114276                               tash@sanctumsoho.com      7795078057
# 114839                             emilio@sanctumsoho.com      7782146662
# 115698                              haleh@sanctumsoho.com      7583116480
# 115826                         cat@catkingproductions.com      7976723033
# 115941                           dimitris.manikis@rci.com    441536314651
# 116283                                ani@sanctumsoho.com      2072926100
# 116504                                mel@sanctumsoho.com      7771557840
# 116516                               kate@sanctumsoho.com      7714290028
# 124261                            fb@karmasalfordhall.com    447403365413
# 127446                      headchef@karmasalfordhall.com    447412663350
# 130834                        events@karmasalfordhall.com    441386871300
# 132517                        events@karmasalfordhall.com    447552069179
# 132581                     daniel.richards@karmagroup.com    447957777238
# 134182                          judy.yates@karmagroup.com    447749970522
# 134456                     daniel.richards@karmagroup.com    447957777238
# 134639                   sebastian.moeller@karmagroup.com   4401721723232
# 135681                     reception@karmasalfordhall.com    447764618513
# 136685                     reception@karmasalfordhall.com     44123456789
# 138853                            fb@karmasalfordhall.com    447984370142
# 138858                   sebastian.moeller@karmagroup.com    441726802987
# 139017                            gm@karmasalfordhall.com   4407827542105
# 140417                            gm@karmasalfordhall.com    447827542105
# 141188                       ramesh.hebbar@karmagroup.com    447782280742
# 147394                       ramesh.hebbar@karmagroup.com    447834732920
# 153601                    opsmanager@karmasalfordhall.com    447984370142
# 154136                      headchef@karmasalfordhall.com    447412663350
#
#                Mobile   Birthdate Year of Birth  ... Lead Regions Lead Status  \
# 11124    447961952360  1980-12-31          1980  ...    UK/Europe       empty
# 97462           empty       empty         empty  ...    UK/Europe    New Lead
# 98583           empty       empty         empty  ...    UK/Europe    New Lead
# 98584           empty       empty         empty  ...    UK/Europe    New Lead
# 100064          empty       empty         empty  ...    UK/Europe    New Lead
# 103391          empty  1964-08-06          1964  ...    UK/Europe       empty
# 103392          empty  1991-08-12          1991  ...    UK/Europe       empty
# 104761   441720422368       empty         empty  ...    UK/Europe    New Lead
# 104762          empty       empty         empty  ...    UK/Europe    New Lead
# 106435          empty  1990-01-01         empty  ...    UK/Europe       empty
# 106441          empty       empty          1999  ...    UK/Europe       empty
# 106443          empty       empty          1990  ...    UK/Europe       empty
# 106444          empty       empty          1993  ...    UK/Europe       empty
# 106495          empty       empty         empty  ...         SEAP       empty
# 107427          empty  1957-09-05         empty  ...    UK/Europe    New Lead
# 112881          empty       empty         empty  ...        empty       empty
# 113086          empty       empty         empty  ...        empty       empty
# 113446          empty       empty         empty  ...        empty       empty
# 113475          empty       empty         empty  ...        empty       empty
# 114276          empty       empty         empty  ...        empty       empty
# 114839          empty       empty         empty  ...        empty       empty
# 115698          empty       empty         empty  ...        empty       empty
# 115826          empty       empty         empty  ...        empty       empty
# 115941          empty       empty         empty  ...        empty       empty
# 116283          empty       empty         empty  ...        empty       empty
# 116504          empty       empty         empty  ...        empty       empty
# 116516          empty       empty         empty  ...        empty       empty
# 124261   447403365413       empty         empty  ...    UK/Europe       empty
# 127446   447412663350       empty         empty  ...    UK/Europe       empty
# 130834          empty       empty         empty  ...    UK/Europe       empty
# 132517          empty       empty         empty  ...    UK/Europe       empty
# 132581   447957777238       empty         empty  ...    UK/Europe       empty
# 134182   447749970522       empty         empty  ...    UK/Europe       empty
# 134456          empty       empty         empty  ...    UK/Europe       empty
# 134639  4401721723232       empty         empty  ...    UK/Europe       empty
# 135681          empty       empty         empty  ...    UK/Europe       empty
# 136685    44123456789       empty         empty  ...    UK/Europe       empty
# 138853          empty       empty         empty  ...    UK/Europe    New Lead
# 138858   441726802987       empty         empty  ...    UK/Europe       empty
# 139017  4407827542105       empty         empty  ...    UK/Europe       empty
# 140417          empty       empty         empty  ...    UK/Europe       empty
# 141188          empty       empty         empty  ...        India       empty
# 147394          empty       empty         empty  ...    UK/Europe       empty
# 153601          empty       empty         empty  ...    UK/Europe       empty
# 154136          empty       empty         empty  ...    UK/Europe       empty
#
#        Booking Status BookRef Email Opt Out Opt In GDPR Compliant  \
# 11124           empty   empty         empty  empty          empty
# 97462           empty   empty         empty  empty          empty
# 98583           empty   empty         empty  empty          empty
# 98584           empty   empty         empty  empty          empty
# 100064          empty   empty         empty  empty          empty
# 103391          empty   empty         empty  empty          empty
# 103392          empty   empty         empty  empty          empty
# 104761          empty   empty         empty  empty          empty
# 104762          empty   empty         empty  empty          empty
# 106435          empty   empty         empty  empty          empty
# 106441          empty   empty         empty  empty          empty
# 106443          empty   empty         empty  empty          empty
# 106444          empty   empty         empty  empty          empty
# 106495          empty   empty         empty  empty          empty
# 107427          empty   empty         empty  empty          empty
# 112881          empty   empty         empty  empty          empty
# 113086          empty   empty         empty  empty          empty
# 113446          empty   empty         empty  empty          empty
# 113475          empty   empty         empty  empty          empty
# 114276          empty   empty         empty  empty          empty
# 114839          empty   empty         empty  empty          empty
# 115698          empty   empty         empty  empty          empty
# 115826          empty   empty         empty  empty          empty
# 115941          empty   empty         empty  empty          empty
# 116283          empty   empty         empty  empty          empty
# 116504          empty   empty         empty  empty          empty
# 116516          empty   empty         empty  empty          empty
# 124261          empty   empty         empty  empty          empty
# 127446          empty   empty         empty  empty          empty
# 130834          empty   empty         empty  empty          empty
# 132517          empty   empty         empty  empty          empty
# 132581          empty   empty         empty  empty          empty
# 134182          empty   empty         empty  empty          empty
# 134456          empty   empty         empty  empty          empty
# 134639          empty   empty         empty  empty          empty
# 135681          empty   empty         empty  empty          empty
# 136685          empty   empty         empty  empty          empty
# 138853          empty   empty         empty  empty          empty
# 138858          empty   empty         empty  empty          empty
# 139017          empty   empty         empty  empty          empty
# 140417          empty   empty         empty  empty          empty
# 141188          empty   empty         empty  empty          empty
# 147394          empty   empty         empty  empty          empty
# 153601          empty   empty         false   true           true
# 154136          empty   empty         false   true           true
#
#                                                   Website Comments  \
# 11124                                               empty    empty
# 97462                                               empty    empty
# 98583                                               empty    empty
# 98584                                               empty    empty
# 100064                                              empty    empty
# 103391                                              empty    empty
# 103392                                              empty    empty
# 104761                                              empty    empty
# 104762                                              empty    empty
# 106435                                              empty    empty
# 106441                                              empty    empty
# 106443                                              empty    empty
# 106444                                              empty    empty
# 106495                                              empty    empty
# 107427                                              empty    empty
# 112881                                              empty    empty
# 113086                                              empty    empty
# 113446                                              empty    empty
# 113475                                              empty    empty
# 114276                                              empty    empty
# 114839                                              empty    empty
# 115698                                              empty    empty
# 115826                                              empty    empty
# 115941                                              empty    empty
# 116283                                              empty    empty
# 116504                                              empty    empty
# 116516                                              empty    empty
# 124261                                              empty    empty
# 127446                                              empty    empty
# 130834                                              empty    empty
# 132517                                              empty    empty
# 132581                                              empty    empty
# 134182                                              empty    empty
# 134456                                              empty    empty
# 134639                                              empty    empty
# 135681                                              empty    empty
# 136685                                              empty    empty
# 138853                                              empty    empty
# 138858                                              empty    empty
# 139017                                              empty    empty
# 140417                                              empty    empty
# 141188                                              empty    empty
# 147394                                              empty    empty
# 153601  https://karmagroup.com/?p=79138&#038;post_type...    empty
# 154136  https://karmagroup.com/weddings-at-karma-la-he...    empty
#
#        Do you live in Bali?
# 11124                 empty
# 97462                 empty
# 98583                 empty
# 98584                 empty
# 100064                empty
# 103391                empty
# 103392                empty
# 104761                empty
# 104762                empty
# 106435                empty
# 106441                empty
# 106443                empty
# 106444                empty
# 106495                empty
# 107427                empty
# 112881                empty
# 113086                empty
# 113446                empty
# 113475                empty
# 114276                empty
# 114839                empty
# 115698                empty
# 115826                empty
# 115941                empty
# 116283                empty
# 116504                empty
# 116516                empty
# 124261                empty
# 127446                empty
# 130834                empty
# 132517                empty
# 132581                empty
# 134182                empty
# 134456                empty
# 134639                empty
# 135681                empty
# 136685                empty
# 138853                empty
# 138858                empty
# 139017                empty
# 140417                empty
# 141188                empty
# 147394                empty
# 153601                false
# 154136                false
#
# [45 rows x 35 columns]

# %%
# delete email Karma
count_after_clean_karma = m.delete_karma(zoho_df, 'Email')
# zoho_df.to_excel(r'C:\Users\fajar.fatoni\Documents\Python\Data\after_clean_OTA.xlsx', index=False)

zoho_df
# Out:
#                        Record Id        Created Time Created Date  \
# 0       zcrm_3584690000000404115 2019-01-07 15:08:38   2019-01-06
# 1       zcrm_3584690000000404196 2019-01-07 15:08:38   2019-01-07
# 2       zcrm_3584690000000404209 2019-01-07 15:08:38   2019-01-06
# 3       zcrm_3584690000000404459 2019-01-08 11:07:28   2019-01-03
# 4       zcrm_3584690000000404460 2019-01-08 11:07:28   2019-01-03
# ...                          ...                 ...          ...
# 158134  zcrm_3584690000555509137 2025-06-09 11:51:05        empty
# 158135  zcrm_3584690000555509367 2025-06-09 11:55:37        empty
# 158136  zcrm_3584690000555514001 2025-06-09 01:50:38   2025-06-08
# 158137  zcrm_3584690000555514164 2025-06-09 11:49:51        empty
# 158138  zcrm_3584690000555514228 2025-06-09 11:51:08        empty
#
#           First Name   Last Name                      Email         Phone  \
# 0             Harley     Russell     hars_russ7@hotmail.com  447834782590
# 1             Tobias     Klitsch   tobias.klitsch@gmail.com  447516721033
# 2             Thomas        Wood  wood.thomas99@yahoo.co.uk  447887405046
# 3       Sophie-Irene     Averman     sonicaverman@gmail.com  380503048815
# 4               Юлия       Жулий        y.zhulii@icloud.com  380633945350
# ...              ...         ...                        ...           ...
# 158134         Janis    Allerton    j4nisallerton@gmail.com  447710107054
# 158135        Martin     Maloney    martinusahols@gmail.com  447533715827
# 158136    Eugene May  Eugene May       eugenelmay@gmail.com  447413538915
# 158137         Linda      Lawley     lindalawley4@gmail.com  447773014928
# 158138        Trevor      Parvin    trevorparvin@icloud.com  447792914660
#
#        Mobile   Birthdate Year of Birth  ... Lead Regions Lead Status  \
# 0       empty  1995-01-24          1995  ...    UK/Europe    New Lead
# 1       empty  1982-06-01          1982  ...    UK/Europe    New Lead
# 2       empty  1990-09-01          1990  ...    UK/Europe    New Lead
# 3       empty  1981-08-22          1981  ...    UK/Europe    New Lead
# 4       empty       empty         empty  ...    UK/Europe    New Lead
# ...       ...         ...           ...  ...          ...         ...
# 158134  empty       empty         empty  ...        empty       empty
# 158135  empty       empty         empty  ...        empty       empty
# 158136  empty       empty         empty  ...    UK/Europe       empty
# 158137  empty       empty         empty  ...        empty       empty
# 158138  empty       empty         empty  ...        empty       empty
#
#        Booking Status  BookRef Email Opt Out Opt In GDPR Compliant  \
# 0               empty    empty         empty  empty          empty
# 1               empty    empty         empty  empty          empty
# 2               empty    empty         empty  empty          empty
# 3               empty    empty         empty  empty          empty
# 4               empty    empty         empty  empty          empty
# ...               ...      ...           ...    ...            ...
# 158134    Checked-Out  2774216         false   true           true
# 158135    Checked-Out  2847346         false   true           true
# 158136          empty    empty         false   true           true
# 158137    Checked-Out  2760709         false   true           true
# 158138    Checked-Out  2768456         false   true           true
#
#                                                   Website Comments  \
# 0                                                   empty    empty
# 1                                                   empty    empty
# 2                                                   empty    empty
# 3                                                   empty    empty
# 4                                                   empty    empty
# ...                                                   ...      ...
# 158134                                              empty    empty
# 158135                                              empty    empty
# 158136  https://karmagroup.com/weddings-at-karma-st-ma...    empty
# 158137                                              empty    empty
# 158138                                              empty    empty
#
#        Do you live in Bali?
# 0                     empty
# 1                     empty
# 2                     empty
# 3                     empty
# 4                     empty
# ...                     ...
# 158134                false
# 158135                false
# 158136                false
# 158137                false
# 158138                false
#
# [158139 rows x 35 columns]

# %%
find_member_booking = zoho_df.copy()

find_member_booking.loc[find_member_booking['Phone'].isin(df_booking['Phone1']), 'Same Value Find'] = 'Booking-Phone1'
find_member_booking.loc[find_member_booking['Phone'].isin(df_booking['Mobile']), 'Same Value Find'] = 'Booking-Mobile'
find_member_booking.loc[find_member_booking['Mobile'].isin(df_booking['Phone1']), 'Same Value Find'] = 'Booking-Phone1' 
find_member_booking.loc[find_member_booking['Mobile'].isin(df_booking['Mobile']), 'Same Value Find'] = 'Booking-Mobile'
find_member_booking.loc[find_member_booking['Email'].isin(df_booking['Email']), 'Same Value Find'] = 'Booking-Email'

find_member_booking.loc[find_member_booking['Phone'].isin(df_phone['Mobile']), 'Same Value Find'] = 'Member-Mobile' 
find_member_booking.loc[find_member_booking['Mobile'].isin(df_phone['Mobile']), 'Same Value Find'] = 'Member-Mobile'

find_member_booking.loc[find_member_booking['Email'].isin(df_email['Email']), 'Same Value Find'] = 'Member-Email'

find_member_booking.drop(find_member_booking.loc[find_member_booking['Same Value Find'].isna()].index, inplace=True)

count_booking_dedup = find_member_booking.loc[find_member_booking['Same Value Find'].str.contains('Booking', flags=re.I, regex=True)].shape[0]
count_member_dedup = find_member_booking.loc[find_member_booking['Same Value Find'].str.contains('Member', flags=re.I, regex=True)].shape[0]

find_member_booking.replace('empty', '', inplace=True)
# find_member_booking.to_csv(r'C:\Users\fajar.fatoni\Documents\Python\Data\booking-member-dedup.csv', index=False)
# find_member_booking.to_excel(r'C:\Users\fajar.fatoni\Documents\Python\Data\booking-member-dedup.xlsx', index=False)

#find_member_booking.loc[find_member_booking['Same Value Find'] == 'Booking-Phone1']

# %%
# data phone, mobile dam email member yang ada di master data 
count_wash_member = zoho_df.loc[
    zoho_df['Phone'].isin(df_booking['Phone1']) | 
    zoho_df['Phone'].isin(df_booking['Mobile']) |
    zoho_df['Mobile'].isin(df_booking['Phone1']) | 
    zoho_df['Mobile'].isin(df_booking['Mobile']) |
    zoho_df['Email'].isin(df_booking['Email'])| 

    zoho_df['Phone'].isin(df_phone['Mobile']) | 
    zoho_df['Mobile'].isin(df_phone['Mobile']) |

    zoho_df['Email'].isin(df_email['Email'])

].shape[0]

zoho_df.drop(zoho_df.loc[
    zoho_df['Phone'].isin(df_booking['Phone1']) | 
    zoho_df['Phone'].isin(df_booking['Mobile']) |
    zoho_df['Mobile'].isin(df_booking['Phone1']) | 
    zoho_df['Mobile'].isin(df_booking['Mobile']) |
    zoho_df['Email'].isin(df_booking['Email']) |
    
    zoho_df['Phone'].isin(df_phone['Mobile']) | 
    zoho_df['Mobile'].isin(df_phone['Mobile']) |

    zoho_df['Email'].isin(df_email['Email'])

    ].index, inplace=True)
    
zoho_df.reset_index(drop=True, inplace=True)

count_after_wash_member = zoho_df.shape[0]

# %%
count_email_only = zoho_df.loc[(zoho_df['Email'] != 'empty') & ((zoho_df['Phone'] == 'empty') & (zoho_df['Mobile'] == 'empty'))].shape[0]
count_phone_only = zoho_df.loc[(zoho_df['Email'] == 'empty') & ((zoho_df['Phone'] != 'empty') | (zoho_df['Mobile'] != 'empty'))].shape[0]
count_email_and_phone = zoho_df.loc[(zoho_df['Email'] != 'empty') & ((zoho_df['Phone'] != 'empty') | (zoho_df['Mobile'] != 'empty'))].shape[0]

count_blank = zoho_df.loc[(zoho_df['Email'] =='empty') & (zoho_df['Phone']=='empty') & (zoho_df['Mobile']=='empty')].shape[0]

# zoho_df.loc[(zoho_df['Email'] =='empty') & (zoho_df['Phone']=='empty') & (zoho_df['Mobile']=='empty')].to_excel(r'C:\Users\fajar.fatoni\Documents\Python\Data\blank_data.xlsx', index=False)

zoho_df.loc[(zoho_df['Email'] != 'empty') & ((zoho_df['Phone'] == 'empty') & (zoho_df['Mobile'] == 'empty')), 'Contact Type'] = 'Email Only'
zoho_df.loc[(zoho_df['Email'] == 'empty') & ((zoho_df['Phone'] != 'empty') | (zoho_df['Mobile'] != 'empty')), 'Contact Type'] = 'Phone Only'
zoho_df.loc[(zoho_df['Email'] != 'empty') & ((zoho_df['Phone'] != 'empty') | (zoho_df['Mobile'] != 'empty')), 'Contact Type'] = 'Email and Phone'

zoho_df.drop(zoho_df.loc[(zoho_df['Email'] =='empty') & (zoho_df['Phone']=='empty') & (zoho_df['Mobile']=='empty')].index, inplace=True)
zoho_df.reset_index(drop=True, inplace=True)

count_after_wash_blank = zoho_df.shape[0]

# %%
arr_dedup = [count_deleted_wrong_format, count_duplicate_general, count_leads_test, count_email_OTA, count_email_karma, count_blank]
count_sum_dedup = sum(arr_dedup)
count_sum_dedup
# Out:
# 11154

# %%
print("==========================================================")
print("Summary")
print("==========================================================")
print("Jumlah Keseluruhan Master Zoho : "+str(count_data_awal))
print("Jumlah Filter Leads Awal : "+str(count_filter_awal))
print("Jumlah Format Email Salah : "+str(count_deleted_wrong_format))
print("Jumlah Setelah Clean Format Email Salah : "+str(count_after_deleted_wrong_format))
print("Jumlah Duplicate (Phone, Mobile dan Email) : "+str(count_duplicate_general))
print("Jumlah Setelah Clean Duplicate : "+str(count_after_dedup_duplicate))
print("Jumlah Lead Test : "+str(count_leads_test))
print("Jumlah Setelah Clean Lead Test : "+str(count_after_dedup_test))
# print("Jumlah Lead Do Not Mail : "+str(count_dnm))
# print("Jumlah Setelah Clean Lead Do Not Mail : "+str(count_after_dedup_dnm))
print("Jumlah Email OTA : "+str(count_email_OTA))
print("Jumlah Setelah Clean Email OTA : "+str(count_after_clean_OTA))
print("Jumlah Email Karma : "+str(count_email_karma))
print("Jumlah Setelah Clean Email Karma : "+str(count_after_clean_karma))
print("Jumlah Wash Member : "+str(count_member_dedup))
print("Jumlah Wash Booking : "+str(count_booking_dedup))
print("Jumlah Setelah Wash Member : "+str(count_after_wash_member))
print("Jumlah Phone Email Blank (Setelah phone yang tidak valid dihapus) : "+str(count_blank))
print("Jumlah Setelah Wash Phone Email Blank : "+str(count_after_wash_blank))
print("==========================================================")
print("Contact Type")
print("==========================================================")
print("Jumlah Email Only : "+str(count_email_only))
print("Jumlah Phone Only : "+str(count_phone_only))
print("Jumlah Email dan Phone : "+str(count_email_and_phone))
# Out:
# ==========================================================
# Summary
# ==========================================================
# Jumlah Keseluruhan Master Zoho : 10040856
# Jumlah Filter Leads Awal : 169292
# Jumlah Format Email Salah : 1
# Jumlah Setelah Clean Format Email Salah : 169291
# Jumlah Duplicate (Phone, Mobile dan Email) : 11055
# Jumlah Setelah Clean Duplicate : 158236
# Jumlah Lead Test : 7
# Jumlah Setelah Clean Lead Test : 158229
# Jumlah Email OTA : 45
# Jumlah Setelah Clean Email OTA : 158184
# Jumlah Email Karma : 45
# Jumlah Setelah Clean Email Karma : 158139
# Jumlah Wash Member : 5639
# Jumlah Wash Booking : 533
# Jumlah Setelah Wash Member : 151967
# Jumlah Phone Email Blank (Setelah phone yang tidak valid dihapus) : 1
# Jumlah Setelah Wash Phone Email Blank : 151966
# ==========================================================
# Contact Type
# ==========================================================
# Jumlah Email Only : 48
# Jumlah Phone Only : 8571
# Jumlah Email dan Phone : 143347

# %%
print("==========================================================")
print("Summary Report")
print("==========================================================")
print("Jumlah Data Awal : "+str(count_filter_awal))
print("Jumlah Wash Dedup : "+str(count_sum_dedup))
print("Jumlah Wash Member : "+str(count_member_dedup))
print("Jumlah Wash Booking : "+str(count_booking_dedup))
print("Jumlah Data Akhir : "+str(count_after_wash_blank))
# Out:
# ==========================================================
# Summary Report
# ==========================================================
# Jumlah Data Awal : 169292
# Jumlah Wash Dedup : 11154
# Jumlah Wash Member : 5639
# Jumlah Wash Booking : 533
# Jumlah Data Akhir : 151966

# %% [markdown]
# # ====================== Akhir Filter Umum ======================

# %%
# Function to clean illegal characters except "Created Time"
def clean_illegal_chars(df):
    def remove_illegal_chars(value):
        if isinstance(value, str):
            return "".join(c for c in value if ord(c) >= 32)
        return value
    
    # Apply cleaning only to non-"Created Time" columns
    for col in df.columns:
        if col != "Created Time":  # Exclude "Created Time" from cleaning
            df[col] = df[col].apply(remove_illegal_chars)

    return df

# Load your dataframe (zoho_df assumed to be already loaded)
zoho_df.replace('empty', '', inplace=True, regex=True)

# Format name columns properly
zoho_df['First Name'] = zoho_df['First Name'].str.title()
zoho_df['Last Name'] = zoho_df['Last Name'].str.title()

# Define output path
output_path = r'C:\Users\fajar.fatoni\Documents\Python\Data\uk_data.xlsx'

try:
    zoho_df.to_excel(output_path, index=False)
except IllegalCharacterError:
    print("IllegalCharacterError detected! Cleaning data...")
    zoho_df = clean_illegal_chars(zoho_df)  # Clean only non-"Created Time" columns
    zoho_df.to_excel(output_path, index=False)
    print("File saved successfully after cleaning.")

print(f"File saved at: {output_path}")
# Out:
# IllegalCharacterError detected! Cleaning data...
# File saved successfully after cleaning.
# File saved at: C:\Users\fajar.fatoni\Documents\Python\Data\uk_data.xlsx

# %%
zoho_df.groupby('Country').count()
# Out:
#                  Record Id  Created Time  Created Date  First Name  Last Name  \
# Country
#                      13955         13955         13955       13955      13955
# 1                        1             1             1           1          1
# Afghanistan              1             1             1           1          1
# Albania                  3             3             3           3          3
# Algeria                  2             2             2           2          2
# ...                    ...           ...           ...         ...        ...
# raelynn cowan            1             1             1           1          1
# reagan douglas           2             2             2           2          2
# riya li                  4             4             4           4          4
# roselyn flowers          1             1             1           1          1
# zackary bruce            3             3             3           3          3
#
#                  Email  Phone  Mobile  Birthdate  Year of Birth  ...  \
# Country                                                          ...
#                  13955  13955   13955      13955          13955  ...
# 1                    1      1       1          1              1  ...
# Afghanistan          1      1       1          1              1  ...
# Albania              3      3       3          3              3  ...
# Algeria              2      2       2          2              2  ...
# ...                ...    ...     ...        ...            ...  ...
# raelynn cowan        1      1       1          1              1  ...
# reagan douglas       2      2       2          2              2  ...
# riya li              4      4       4          4              4  ...
# roselyn flowers      1      1       1          1              1  ...
# zackary bruce        3      3       3          3              3  ...
#
#                  Lead Status  Booking Status  BookRef  Email Opt Out  Opt In  \
# Country
#                        13955           13955    13955          13955   13955
# 1                          1               1        1              1       1
# Afghanistan                1               1        1              1       1
# Albania                    3               3        3              3       3
# Algeria                    2               2        2              2       2
# ...                      ...             ...      ...            ...     ...
# raelynn cowan              1               1        1              1       1
# reagan douglas             2               2        2              2       2
# riya li                    4               4        4              4       4
# roselyn flowers            1               1        1              1       1
# zackary bruce              3               3        3              3       3
#
#                  GDPR Compliant  Website  Comments  Do you live in Bali?  \
# Country
#                           13955    13955     13955                 13955
# 1                             1        1         1                     1
# Afghanistan                   1        1         1                     1
# Albania                       3        3         3                     3
# Algeria                       2        2         2                     2
# ...                         ...      ...       ...                   ...
# raelynn cowan                 1        1         1                     1
# reagan douglas                2        2         2                     2
# riya li                       4        4         4                     4
# roselyn flowers               1        1         1                     1
# zackary bruce                 3        3         3                     3
#
#                  Contact Type
# Country
#                         13955
# 1                           1
# Afghanistan                 1
# Albania                     3
# Algeria                     2
# ...                       ...
# raelynn cowan               1
# reagan douglas              2
# riya li                     4
# roselyn flowers             1
# zackary bruce               3
#
# [109 rows x 35 columns]

# %%
# zoho_df['Country'].loc[
#     (zoho_df['Phone'].str.contains('^44|^\+44')) & 
#     (~zoho_df['Country'].str.contains('united kingdom|wales|england|scotland|northern ireland', regex=True, flags=re.I))
# ]
