# %%
import main_module as m
import zoho_filter_module as fil
import pandas as pd
import re
import numpy as np

# %load_ext autoreload
# %autoreload 2

dir_path = r'C:\Users\fajar\Documents\Python\Data\Zoho_Backup\2020-2024'
dir_path_live = r'C:\Users\fajar\Documents\Python\Data\Zoho_Backup'
dir_path_old = r'C:\Users\fajar\Documents\Python\Data\Zoho_Backup\old'
file_name = '\Leads_'

cols = ['Record Id',	
'Created Time',
'Created Date',	
'First Name',	
'Last Name',	
'Email',	
'Phone',	
'Mobile',	
'Birthdate',	
'Year of Birth',
'Street',	
'Street2',	
'City',	
'State',	
'Country',	
'Nationality',
'Booking Status', 
'BookRef',
'Departure Date',	
'Arrival Date',	
'Card Type',	
'Marital Status',	
'Lead Brand',	
'Lead Sub-Brand',	
'Lead Source',	
'Lead Locations',	
'Lead Source Description',	
'Lead Regions',
'Lead Status',
'Email Opt Out',	
'Opt In',
'GDPR Compliant',
'Website',
'Comments',
'Do you live in Bali?']

# %%
email = 'swas83m@gmail.com|sambisays@gmail.com'

# %%
path = dir_path+'\\backup.csv'
df_all = pd.read_csv(path, dtype='string', on_bad_lines='skip')
count_data_awal = df_all.shape[0]
df_all.drop(df_all.loc[df_all['Created Time'].str.len() < 5 ].index, inplace=True)
df_all.reset_index(drop=True, inplace=True)

df_all['Created Time'] = pd.to_datetime(df_all['Created Time'], format='%Y-%m-%d %H:%M:%S')

df_all.shape[0]
df_all
# Out:
#                         Record Id        Created Time Created Date First Name  \
# 0        zcrm_3584690000000404058 2019-01-07 15:08:38   2019-01-06   Nicholas
# 1        zcrm_3584690000000404059 2019-01-07 15:08:38   2019-01-06       Liao
# 2        zcrm_3584690000000404060 2019-01-07 15:08:38   2019-01-06    Vedanta
# 3        zcrm_3584690000000404065 2019-01-07 15:08:38   2019-01-06      Aidai
# 4        zcrm_3584690000000404068 2019-01-07 15:08:38   2019-01-06      Ardra
# ...                           ...                 ...          ...        ...
# 9965978  zcrm_3584690000489266005 2024-03-25 16:19:45         <NA>      Keval
# 9965979  zcrm_3584690000489266034 2024-03-25 16:19:51         <NA>     Suresh
# 9965980  zcrm_3584690000489266063 2024-03-25 17:29:27         <NA>     Nathan
# 9965981  zcrm_3584690000489269015 2024-03-25 16:20:25         <NA>    Leonora
# 9965982  zcrm_3584690000489271002 2024-03-25 18:40:17         <NA>       Annu
#
#           Last Name                                 Email           Phone  \
# 0              Wood            1230woodnicholas@gmail.com     61438600845
# 1              Yuan                      158066546@qq.com   8618718399923
# 2          Abhiyoga            abhiyoga.vedanta@gmail.com   6282146524550
# 3         Atakanova                aidai.nurbek@gmail.com    996779641590
# 4             Ardra            aliefardraqariru@gmail.com  +6282139300818
# ...             ...                                   ...             ...
# 9965978        Gala                   keval2403@gmail.com   +919022872972
# 9965979      Shroff  sureshshroff@breachcandyhospital.org   +919819533303
# 9965980   Fernandes       nathan.fernandes@karmagroup.com  +9179724486854
# 9965981     Hackman                leonora_hf@bigpond.com    +61439855115
# 9965982  Shriwastav          annusrivastava1990@gmail.com   +919561074124
#
#                  Mobile   Birthdate Year of Birth  ...         Arrival Date  \
# 0                  <NA>        <NA>          <NA>  ...  2019-01-06 00:00:00
# 1                  <NA>        <NA>          <NA>  ...  2019-01-06 00:00:00
# 2                  <NA>  2000-07-05          2000  ...  2018-12-01 00:00:00
# 3                  <NA>  1997-02-05          1997  ...  2019-01-06 00:00:00
# 4        +6282139300818  2005-01-20          2005  ...  2018-11-30 00:00:00
# ...                 ...         ...           ...  ...                  ...
# 9965978   +917700904802        <NA>          <NA>  ...           2024-03-21
# 9965979   +919819814280        <NA>          <NA>  ...           2024-03-21
# 9965980            <NA>        <NA>          <NA>  ...                 <NA>
# 9965981            <NA>        <NA>          <NA>  ...           2024-03-14
# 9965982            <NA>        <NA>          <NA>  ...                 <NA>
#
#         Card Type Marital Status           Lead Brand   Lead Sub-Brand  \
# 0            <NA>           <NA>  Timeshare Marketing    Other Bali DB
# 1            <NA>           <NA>  Timeshare Marketing    Other Bali DB
# 2            <NA>        Pelajar  Timeshare Marketing    Other Bali DB
# 3            <NA>         Single  Timeshare Marketing    Other Bali DB
# 4            <NA>          OTHER  Timeshare Marketing    Other Bali DB
# ...           ...            ...                  ...              ...
# 9965978      <NA>           <NA>        Karma Resorts            Other
# 9965979      <NA>           <NA>        Karma Resorts            Other
# 9965980      <NA>           <NA>          Karma Group  Karma Community
# 9965981      <NA>           <NA>        Karma Resorts            Other
# 9965982      <NA>           <NA>  Timeshare Marketing            Other
#
#          Lead Source           Lead Locations  \
# 0               Wifi              Purple Wifi
# 1               Wifi              Purple Wifi
# 2               Wifi              Purple Wifi
# 3               Wifi              Purple Wifi
# 4               Wifi              Purple Wifi
# ...              ...                      ...
# 9965978  Past Guests        Karma Royal Palms
# 9965979  Past Guests  Karma Sitabani, Corbett
# 9965980         Quiz                     <NA>
# 9965981  Past Guests           Karma Jimbaran
# 9965982  Web Enquiry           Karma Sitabani
#
#                                    Lead Source Description Lead Regions  \
# 0                                                     <NA>         SEAP
# 1                                                     <NA>        Other
# 2                                                     <NA>         SEAP
# 3                                                     <NA>    UK/Europe
# 4                                    WIFI USER ID 13494142         SEAP
# ...                                                    ...          ...
# 9965978                                          Viewpoint         <NA>
# 9965979                                          Viewpoint         <NA>
# 9965980  Karma Community | Edition 218 - Words to the Wise        India
# 9965981                                          Viewpoint         <NA>
# 9965982                          Timeshare Booking Request        India
#
#         Lead Status
# 0          New Lead
# 1          New Lead
# 2          New Lead
# 3          New Lead
# 4          New Lead
# ...             ...
# 9965978        <NA>
# 9965979        <NA>
# 9965980        <NA>
# 9965981        <NA>
# 9965982        <NA>
#
# [9965983 rows x 27 columns]

# %%
df_old = m.load_data_multiple(dir_path_old, file_name, cols)
count_data_awal = df_old.shape[0]
df_old = df_old.reindex(columns=cols)
df_old.shape[0]

df_old['Created Time'] = pd.to_datetime(df_old['Created Time'], format='%Y-%m-%d %H:%M:%S')
df_old['Arrival Date'] = pd.to_datetime(df_old['Arrival Date'], format='%Y-%m-%d')
df_old['Departure Date'] = pd.to_datetime(df_old['Departure Date'], format='%Y-%m-%d')
# fungsi errors cource untuk menhindari error jika value data date null atau kosong
# df['Birthdate'] = pd.to_datetime(df['Birthdate'], format='%Y-%m-%d', errors='coerce')
df_old.dtypes
df_old
# Out:
#                         Record Id        Created Time Created Date First Name  \
# 0        zcrm_3584690000000404058 2019-01-07 15:08:38   2019-01-06   Nicholas
# 1        zcrm_3584690000000404059 2019-01-07 15:08:38   2019-01-06       Liao
# 2        zcrm_3584690000000404060 2019-01-07 15:08:38   2019-01-06    Vedanta
# 3        zcrm_3584690000000404065 2019-01-07 15:08:38   2019-01-06      Aidai
# 4        zcrm_3584690000000404068 2019-01-07 15:08:38   2019-01-06      Ardra
# ...                           ...                 ...          ...        ...
# 4717718  zcrm_3584690000475135007 2024-01-01 18:16:02         <NA>    Upendra
# 4717719  zcrm_3584690000475135045 2024-01-01 18:16:37         <NA>      Mehul
# 4717720  zcrm_3584690000475136005 2024-01-01 18:17:13         <NA>      swati
# 4717721  zcrm_3584690000475138034 2024-01-01 18:48:36         <NA>      SUMON
# 4717722  zcrm_3584690000475138069 2024-01-01 18:52:24         <NA>      Rohit
#
#          Last Name                       Email           Phone  \
# 0             Wood  1230woodnicholas@gmail.com    +61438600845
# 1             Yuan            158066546@qq.com   8618718399923
# 2         Abhiyoga  abhiyoga.vedanta@gmail.com  +6282146524550
# 3        Atakanova      aidai.nurbek@gmail.com    996779641590
# 4            Ardra  aliefardraqariru@gmail.com  +6282139300818
# ...            ...                         ...             ...
# 4717718     Mishra       upendra.sir@gmail.com   +919036084550
# 4717719  Prajapati     mehul.m111985@gmail.com   +919714713689
# 4717720   agarwala         cswatiadv@gmail.com   +919733055636
# 4717721      SAHOO        sumonsahoo@gmail.com   +918910484814
# 4717722      Kadam      rohit0918.rk@gmail.com   +919819185446
#
#                  Mobile   Birthdate Year of Birth  ...  \
# 0                  <NA>        <NA>          <NA>  ...
# 1                  <NA>        <NA>          <NA>  ...
# 2                  <NA>  2000-07-05          2000  ...
# 3                  <NA>  1997-02-05          1997  ...
# 4        +6282139300818  2005-01-20          2005  ...
# ...                 ...         ...           ...  ...
# 4717718            <NA>        <NA>          <NA>  ...
# 4717719            <NA>        <NA>          <NA>  ...
# 4717720            <NA>        <NA>          <NA>  ...
# 4717721            <NA>        <NA>          <NA>  ...
# 4717722            <NA>        <NA>          <NA>  ...
#
#                  Lead Locations      Lead Source Description Lead Regions  \
# 0                          <NA>                  Purple Wifi         SEAP
# 1                          <NA>                  Purple Wifi        Other
# 2                          <NA>                  Purple Wifi         SEAP
# 3                          <NA>                  Purple Wifi    UK/Europe
# 4                       Mall 21                  Purple Wifi         SEAP
# ...                         ...                          ...          ...
# 4717718  Karma Sunshine Village    Timeshare Booking Request        India
# 4717719                 General  IND | FB MF | Lead captured         <NA>
# 4717720            Karma Martam         IND | FB MF | Martam         <NA>
# 4717721            Karma Martam         IND | FB MF | Martam         <NA>
# 4717722             Royal Palms            IND | FB AF | KRP         <NA>
#
#         Lead Status Email Opt Out Opt In GDPR Compliant  \
# 0          New Lead         false  false          false
# 1          New Lead         false  false          false
# 2          New Lead         false  false          false
# 3          New Lead         false  false          false
# 4          New Lead         false  false          false
# ...             ...           ...    ...            ...
# 4717718        <NA>         false   true           true
# 4717719        <NA>         false  false          false
# 4717720        <NA>         false  false          false
# 4717721        <NA>         false  false          false
# 4717722        <NA>         false  false          false
#
#                                                    Website Comments  \
# 0                                                     <NA>     <NA>
# 1                                                     <NA>     <NA>
# 2                                                     <NA>     <NA>
# 3                                                     <NA>     <NA>
# 4                                                     <NA>     <NA>
# ...                                                    ...      ...
# 4717718  https://karmagroup.com/find-destination/karma-...     <NA>
# 4717719                                               <NA>     <NA>
# 4717720                                               <NA>     <NA>
# 4717721                                               <NA>     <NA>
# 4717722                                               <NA>     <NA>
#
#         Do you live in Bali?
# 0                      false
# 1                      false
# 2                      false
# 3                      false
# 4                      false
# ...                      ...
# 4717718                false
# 4717719                false
# 4717720                false
# 4717721                false
# 4717722                false
#
# [4717723 rows x 35 columns]

# %%
df_live = m.load_data_multiple(dir_path_live, file_name, cols)
count_data_awal = df_live.shape[0]
df_live = df_live.reindex(columns=cols)
df_live.shape[0]

df_live['Created Time'] = pd.to_datetime(df_live['Created Time'], format='%Y-%m-%d %H:%M:%S')
df_live['Arrival Date'] = pd.to_datetime(df_live['Arrival Date'], format='%Y-%m-%d')
df_live['Departure Date'] = pd.to_datetime(df_live['Departure Date'], format='%Y-%m-%d')
# fungsi errors cource untuk menhindari error jika value data date null atau kosong
# df['Birthdate'] = pd.to_datetime(df['Birthdate'], format='%Y-%m-%d', errors='coerce')
df_live.dtypes
df_live
# Out:
#                        Record Id        Created Time Created Date First Name  \
# 0       zcrm_3584690000000404602 2019-01-08 11:07:28   2021-07-21   Frederic
# 1       zcrm_3584690000000450071 2019-01-08 16:38:18         <NA>  Sebastian
# 2       zcrm_3584690000000450087 2019-01-08 16:38:18         <NA>    Siobhan
# 3       zcrm_3584690000000450106 2019-01-08 16:38:18         <NA>       Lisa
# 4       zcrm_3584690000000450109 2019-01-08 16:38:18         <NA>  Ana Maria
# ...                          ...                 ...          ...        ...
# 493244  zcrm_3584690000521016067 2025-01-13 18:12:02         <NA>       Toni
# 493245  zcrm_3584690000521016109 2025-01-13 18:29:28         <NA>     neeraj
# 493246  zcrm_3584690000521017001 2025-01-13 17:23:30   2025-01-13       ~ayu
# 493247  zcrm_3584690000521017040 2025-01-13 17:26:16   2025-01-13       Jack
# 493248  zcrm_3584690000521019001 2025-01-13 17:25:45   2025-01-13     ~Robin
#
#         Last Name                        Email             Phone Mobile  \
# 0           Bonin    fredericbonin79@gmail.com    +6281236100502   <NA>
# 1            Rach                         <NA>     +498914342111   <NA>
# 2       Gallagher  gallaghersiobhan@eircom.net      353879597603   <NA>
# 3       Ferkovich         lisajo2009@yahoo.com       14062394749   <NA>
# 4        Weileder     m.weileder@sonnenlink.de       15253234700   <NA>
# ...           ...                          ...               ...    ...
# 493244      Truda         toni.truda@gmail.com      +61420361072   <NA>
# 493245     prasad           gomtipus@gmail.com     +919889192155   <NA>
# 493246  suwidiani                         <NA>  +62821-4552-2338   <NA>
# 493247     Davies                         <NA>  +1(207) 653-9484   <NA>
# 493248     Bugeja                         <NA>     +9733967 1748   <NA>
#
#          Birthdate Year of Birth  ...     Lead Locations  \
# 0       1981-10-03          1981  ...      Karma Kandara
# 1       1982-04-20          1982  ...      Karma Bavaria
# 2       1973-03-14          1973  ...      Karma Bavaria
# 3       1963-07-08          1963  ...      Karma Bavaria
# 4             <NA>          <NA>  ...      Karma Bavaria
# ...            ...           ...  ...                ...
# 493244        <NA>          <NA>  ...      Karma Kandara
# 493245        <NA>          <NA>  ...  Karma Golden Camp
# 493246        <NA>          <NA>  ...      Karma Kandara
# 493247        <NA>          <NA>  ...      Karma Kandara
# 493248        <NA>          <NA>  ...      Karma Kandara
#
#                       Lead Source Description Lead Regions Lead Status  \
# 0                                       KAREN         SEAP    New Lead
# 1                                        <NA>    UK/Europe    New Lead
# 2                                        <NA>    UK/Europe    New Lead
# 3                                        <NA>    UK/Europe    New Lead
# 4             MICE Contacts from Ioanna email    UK/Europe    New Lead
# ...                                       ...          ...         ...
# 493244              Timeshare Booking Request         SEAP        <NA>
# 493245              Timeshare Booking Request        India        <NA>
# 493246  Karma Reservations - WhatsApp Channel         <NA>    New Lead
# 493247  Karma Reservations - WhatsApp Channel         <NA>    New Lead
# 493248  Karma Reservations - WhatsApp Channel         <NA>    New Lead
#
#        Email Opt Out Opt In GDPR Compliant  \
# 0              false  false          false
# 1               true  false          false
# 2              false   true           true
# 3               true  false          false
# 4              false   true           true
# ...              ...    ...            ...
# 493244         false   true           true
# 493245         false   true           true
# 493246         false  false          false
# 493247         false  false          false
# 493248         false  false          false
#
#                                                   Website Comments  \
# 0                                                    <NA>     <NA>
# 1                                                    <NA>     <NA>
# 2                                                    <NA>     <NA>
# 3                                                    <NA>     <NA>
# 4                                                    <NA>     <NA>
# ...                                                   ...      ...
# 493244  https://karmagroup.com/find-destination/karma-...     <NA>
# 493245  https://karmagroup.com/find-destination/karma-...     <NA>
# 493246                                               <NA>     <NA>
# 493247                                               <NA>     <NA>
# 493248                                               <NA>     <NA>
#
#        Do you live in Bali?
# 0                     false
# 1                     false
# 2                     false
# 3                     false
# 4                     false
# ...                     ...
# 493244                false
# 493245                false
# 493246                false
# 493247                false
# 493248                false
#
# [493249 rows x 35 columns]

# %%
df = pd.concat([df_all,df_old,df_live])
df
# Out:
#                        Record Id        Created Time Created Date First Name  \
# 0       zcrm_3584690000000404058 2019-01-07 15:08:38   2019-01-06   Nicholas
# 1       zcrm_3584690000000404059 2019-01-07 15:08:38   2019-01-06       Liao
# 2       zcrm_3584690000000404060 2019-01-07 15:08:38   2019-01-06    Vedanta
# 3       zcrm_3584690000000404065 2019-01-07 15:08:38   2019-01-06      Aidai
# 4       zcrm_3584690000000404068 2019-01-07 15:08:38   2019-01-06      Ardra
# ...                          ...                 ...          ...        ...
# 493244  zcrm_3584690000521016067 2025-01-13 18:12:02         <NA>       Toni
# 493245  zcrm_3584690000521016109 2025-01-13 18:29:28         <NA>     neeraj
# 493246  zcrm_3584690000521017001 2025-01-13 17:23:30   2025-01-13       ~ayu
# 493247  zcrm_3584690000521017040 2025-01-13 17:26:16   2025-01-13       Jack
# 493248  zcrm_3584690000521019001 2025-01-13 17:25:45   2025-01-13     ~Robin
#
#         Last Name                       Email             Phone  \
# 0            Wood  1230woodnicholas@gmail.com       61438600845
# 1            Yuan            158066546@qq.com     8618718399923
# 2        Abhiyoga  abhiyoga.vedanta@gmail.com     6282146524550
# 3       Atakanova      aidai.nurbek@gmail.com      996779641590
# 4           Ardra  aliefardraqariru@gmail.com    +6282139300818
# ...           ...                         ...               ...
# 493244      Truda        toni.truda@gmail.com      +61420361072
# 493245     prasad          gomtipus@gmail.com     +919889192155
# 493246  suwidiani                        <NA>  +62821-4552-2338
# 493247     Davies                        <NA>  +1(207) 653-9484
# 493248     Bugeja                        <NA>     +9733967 1748
#
#                 Mobile   Birthdate Year of Birth  ... Lead Regions  \
# 0                 <NA>        <NA>          <NA>  ...         SEAP
# 1                 <NA>        <NA>          <NA>  ...        Other
# 2                 <NA>  2000-07-05          2000  ...         SEAP
# 3                 <NA>  1997-02-05          1997  ...    UK/Europe
# 4       +6282139300818  2005-01-20          2005  ...         SEAP
# ...                ...         ...           ...  ...          ...
# 493244            <NA>        <NA>          <NA>  ...         SEAP
# 493245            <NA>        <NA>          <NA>  ...        India
# 493246            <NA>        <NA>          <NA>  ...         <NA>
# 493247            <NA>        <NA>          <NA>  ...         <NA>
# 493248            <NA>        <NA>          <NA>  ...         <NA>
#
#        Lead Status Booking Status BookRef Email Opt Out Opt In GDPR Compliant  \
# 0         New Lead           <NA>    <NA>          <NA>   <NA>           <NA>
# 1         New Lead           <NA>    <NA>          <NA>   <NA>           <NA>
# 2         New Lead           <NA>    <NA>          <NA>   <NA>           <NA>
# 3         New Lead           <NA>    <NA>          <NA>   <NA>           <NA>
# 4         New Lead           <NA>    <NA>          <NA>   <NA>           <NA>
# ...            ...            ...     ...           ...    ...            ...
# 493244        <NA>           <NA>    <NA>         false   true           true
# 493245        <NA>           <NA>    <NA>         false   true           true
# 493246    New Lead           <NA>    <NA>         false  false          false
# 493247    New Lead           <NA>    <NA>         false  false          false
# 493248    New Lead           <NA>    <NA>         false  false          false
#
#                                                   Website Comments  \
# 0                                                    <NA>     <NA>
# 1                                                    <NA>     <NA>
# 2                                                    <NA>     <NA>
# 3                                                    <NA>     <NA>
# 4                                                    <NA>     <NA>
# ...                                                   ...      ...
# 493244  https://karmagroup.com/find-destination/karma-...     <NA>
# 493245  https://karmagroup.com/find-destination/karma-...     <NA>
# 493246                                               <NA>     <NA>
# 493247                                               <NA>     <NA>
# 493248                                               <NA>     <NA>
#
#        Do you live in Bali?
# 0                      <NA>
# 1                      <NA>
# 2                      <NA>
# 3                      <NA>
# 4                      <NA>
# ...                     ...
# 493244                false
# 493245                false
# 493246                false
# 493247                false
# 493248                false
#
# [15176955 rows x 35 columns]

# %%
# df.loc[df['Email'] == email]
df.loc[df['Email'].str.contains(email, regex=True, flags=re.I)]
# Out:
# Empty DataFrame
# Columns: [Record Id, Created Time, Created Date, First Name, Last Name, Email, Phone, Mobile, Birthdate, Year of Birth, Street, Street2, City, State, Country, Nationality, Departure Date, Arrival Date, Card Type, Marital Status, Lead Brand, Lead Sub-Brand, Lead Source, Lead Locations, Lead Source Description, Lead Regions, Lead Status, Booking Status, BookRef, Email Opt Out, Opt In, GDPR Compliant, Website, Comments, Do you live in Bali?]
# Index: []
#
# [0 rows x 35 columns]

# %%
df.drop_duplicates(subset=['Record Id'], inplace=True)
df.reset_index(drop=True, inplace=True)
count_data_awal = df.shape[0]
df
# Out:
#                          Record Id        Created Time Created Date  \
# 0         zcrm_3584690000000404058 2019-01-07 15:08:38   2019-01-06
# 1         zcrm_3584690000000404059 2019-01-07 15:08:38   2019-01-06
# 2         zcrm_3584690000000404060 2019-01-07 15:08:38   2019-01-06
# 3         zcrm_3584690000000404065 2019-01-07 15:08:38   2019-01-06
# 4         zcrm_3584690000000404068 2019-01-07 15:08:38   2019-01-06
# ...                            ...                 ...          ...
# 10022602  zcrm_3584690000521016067 2025-01-13 18:12:02         <NA>
# 10022603  zcrm_3584690000521016109 2025-01-13 18:29:28         <NA>
# 10022604  zcrm_3584690000521017001 2025-01-13 17:23:30   2025-01-13
# 10022605  zcrm_3584690000521017040 2025-01-13 17:26:16   2025-01-13
# 10022606  zcrm_3584690000521019001 2025-01-13 17:25:45   2025-01-13
#
#          First Name  Last Name                       Email             Phone  \
# 0          Nicholas       Wood  1230woodnicholas@gmail.com       61438600845
# 1              Liao       Yuan            158066546@qq.com     8618718399923
# 2           Vedanta   Abhiyoga  abhiyoga.vedanta@gmail.com     6282146524550
# 3             Aidai  Atakanova      aidai.nurbek@gmail.com      996779641590
# 4             Ardra      Ardra  aliefardraqariru@gmail.com    +6282139300818
# ...             ...        ...                         ...               ...
# 10022602       Toni      Truda        toni.truda@gmail.com      +61420361072
# 10022603     neeraj     prasad          gomtipus@gmail.com     +919889192155
# 10022604       ~ayu  suwidiani                        <NA>  +62821-4552-2338
# 10022605       Jack     Davies                        <NA>  +1(207) 653-9484
# 10022606     ~Robin     Bugeja                        <NA>     +9733967 1748
#
#                   Mobile   Birthdate Year of Birth  ... Lead Regions  \
# 0                   <NA>        <NA>          <NA>  ...         SEAP
# 1                   <NA>        <NA>          <NA>  ...        Other
# 2                   <NA>  2000-07-05          2000  ...         SEAP
# 3                   <NA>  1997-02-05          1997  ...    UK/Europe
# 4         +6282139300818  2005-01-20          2005  ...         SEAP
# ...                  ...         ...           ...  ...          ...
# 10022602            <NA>        <NA>          <NA>  ...         SEAP
# 10022603            <NA>        <NA>          <NA>  ...        India
# 10022604            <NA>        <NA>          <NA>  ...         <NA>
# 10022605            <NA>        <NA>          <NA>  ...         <NA>
# 10022606            <NA>        <NA>          <NA>  ...         <NA>
#
#          Lead Status Booking Status BookRef Email Opt Out Opt In  \
# 0           New Lead           <NA>    <NA>          <NA>   <NA>
# 1           New Lead           <NA>    <NA>          <NA>   <NA>
# 2           New Lead           <NA>    <NA>          <NA>   <NA>
# 3           New Lead           <NA>    <NA>          <NA>   <NA>
# 4           New Lead           <NA>    <NA>          <NA>   <NA>
# ...              ...            ...     ...           ...    ...
# 10022602        <NA>           <NA>    <NA>         false   true
# 10022603        <NA>           <NA>    <NA>         false   true
# 10022604    New Lead           <NA>    <NA>         false  false
# 10022605    New Lead           <NA>    <NA>         false  false
# 10022606    New Lead           <NA>    <NA>         false  false
#
#          GDPR Compliant                                            Website  \
# 0                  <NA>                                               <NA>
# 1                  <NA>                                               <NA>
# 2                  <NA>                                               <NA>
# 3                  <NA>                                               <NA>
# 4                  <NA>                                               <NA>
# ...                 ...                                                ...
# 10022602           true  https://karmagroup.com/find-destination/karma-...
# 10022603           true  https://karmagroup.com/find-destination/karma-...
# 10022604          false                                               <NA>
# 10022605          false                                               <NA>
# 10022606          false                                               <NA>
#
#          Comments Do you live in Bali?
# 0            <NA>                 <NA>
# 1            <NA>                 <NA>
# 2            <NA>                 <NA>
# 3            <NA>                 <NA>
# 4            <NA>                 <NA>
# ...           ...                  ...
# 10022602     <NA>                false
# 10022603     <NA>                false
# 10022604     <NA>                false
# 10022605     <NA>                false
# 10022606     <NA>                false
#
# [10022607 rows x 35 columns]

# %%
df.dtypes
# Out:
# Record Id                          string
# Created Time               datetime64[ns]
# Created Date                       string
# First Name                         string
# Last Name                          string
# Email                              string
# Phone                              string
# Mobile                             string
# Birthdate                          string
# Year of Birth                      string
# Street                             string
# Street2                            string
# City                               string
# State                              string
# Country                            string
# Nationality                        string
# Departure Date                     object
# Arrival Date                       object
# Card Type                          string
# Marital Status                     string
# Lead Brand                         string
# Lead Sub-Brand                     string
# Lead Source                        string
# Lead Locations                     string
# Lead Source Description            string
# Lead Regions                       string
# Lead Status                        string
# Booking Status                     string
# BookRef                            string
# Email Opt Out                      string
# Opt In                             string
# GDPR Compliant                     string
# Website                            string
# Comments                           string
# Do you live in Bali?               string
# dtype: object

# %%
path = r'G:\.shortcut-targets-by-id\0B_d3smBjzo04eXpvS1NXTWF2RVE\_BOOKING\Booking By Year\FlyBuy Booking Data (BGAU & BGID & KE).xlsx'
df_booking = pd.read_excel(path, dtype='string', sheet_name='BOOKING_BGAU_BGID_KE')

path = r'G:\.shortcut-targets-by-id\0B_d3smBjzo04UUNBME5GOVhoMjA\_ODYSSEY\Phone Members.xlsx'
df_phone = pd.read_excel(path, dtype='string', sheet_name='Sheet1')

path = r'G:\.shortcut-targets-by-id\0B_d3smBjzo04UUNBME5GOVhoMjA\_ODYSSEY\Email Members.xlsx'
df_email = pd.read_excel(path, dtype='string', sheet_name='Sheet1')

# %%
zoho_filter = fil.user_req(df)
zoho_df = df.loc[zoho_filter].copy() # menggunakan copy untuk menghindari setting copy warning
zoho_df.reset_index(drop=True, inplace=True)
count_filter_awal = zoho_df.shape[0]

# zoho_df.to_excel(r'C:\Users\fajar\Documents\Python\Data\test_leads.xlsx', index=False)
# mengisi kolom <NA> dengan value string 'empty' supaya mudah mengecek data member dan booking dengan isin

zoho_df.fillna('empty', inplace=True)
# zoho_df.sort_values('Created Time', ascending=True)

# %%
zoho_df
# Out:
#                      Record Id        Created Time Created Date First Name  \
# 0     zcrm_3584690000004983243 2019-03-25 15:51:36   2020-06-13        Tom
# 1     zcrm_3584690000005939555 2019-04-02 02:14:16   2020-06-25     Robert
# 2     zcrm_3584690000005947831 2019-04-02 02:15:04   2020-06-19       Joan
# 3     zcrm_3584690000005955729 2019-04-02 02:15:48   2020-06-19     Kirsty
# 4     zcrm_3584690000005961815 2019-04-02 02:16:22   2020-06-06       Karl
# ...                        ...                 ...          ...        ...
# 8318  zcrm_3584690000472158850 2023-12-08 11:28:04   2021-09-10      Citra
# 8319  zcrm_3584690000472158852 2023-12-08 11:28:04   2021-09-10       Mark
# 8320  zcrm_3584690000472158853 2023-12-08 11:28:04   2021-09-10    Labibah
# 8321  zcrm_3584690000472158854 2023-12-08 11:28:04   2021-09-15    Suryadi
# 8322  zcrm_3584690000472158855 2023-12-08 11:28:04   2021-09-15     Ariska
#
#      Last Name                        Email         Phone       Mobile  \
# 0       Hawtin          tomie.h@hotmail.com   61401644180        empty
# 1      van Erp           rfvanerp@gmail.com   61488031867        empty
# 2      Dugdale      dugdale@optusnet.com.au   61413189408        empty
# 3       Morgan     aysiajane@ozemail.com.au   61438467919        empty
# 4      Pratley        kpratley@iinet.net.au   61411868425  61413946747
# ...        ...                          ...           ...          ...
# 8318         -         citralaras@gmail.com  087878734051        empty
# 8319         -    tia_sabrina2112@gmail.com  081390815624        empty
# 8320         -           labibaah@gmail.com  081231814308        empty
# 8321         -  suryadi.rubicon96@gmail.com  082119990280        empty
# 8322         -          disariska@gmail.com  081221523153        empty
#
#        Birthdate Year of Birth  ... Lead Regions Lead Status Booking Status  \
# 0     1982-04-20          1982  ...         SEAP    New Lead          empty
# 1          empty         empty  ...         SEAP       empty          empty
# 2          empty         empty  ...         SEAP       empty          empty
# 3          empty         empty  ...         SEAP       empty          empty
# 4     1964-07-18          1964  ...         SEAP    Not Sold          empty
# ...          ...           ...  ...          ...         ...            ...
# 8318       empty         empty  ...         SEAP    New Lead          empty
# 8319       empty         empty  ...         SEAP    New Lead          empty
# 8320       empty         empty  ...         SEAP    New Lead          empty
# 8321       empty         empty  ...         SEAP    New Lead          empty
# 8322       empty         empty  ...         SEAP    New Lead          empty
#
#      BookRef Email Opt Out Opt In GDPR Compliant Website Comments  \
# 0      empty         empty  empty          empty   empty    empty
# 1      empty         empty  empty          empty   empty    empty
# 2      empty         empty  empty          empty   empty    empty
# 3      empty         empty  empty          empty   empty    empty
# 4      empty         empty  empty          empty   empty    empty
# ...      ...           ...    ...            ...     ...      ...
# 8318   empty         empty  empty          empty   empty    empty
# 8319   empty         empty  empty          empty   empty    empty
# 8320   empty         empty  empty          empty   empty    empty
# 8321   empty         empty  empty          empty   empty    empty
# 8322   empty         empty  empty          empty   empty    empty
#
#      Do you live in Bali?
# 0                   empty
# 1                   empty
# 2                   empty
# 3                   empty
# 4                   empty
# ...                   ...
# 8318                empty
# 8319                empty
# 8320                empty
# 8321                empty
# 8322                empty
#
# [8323 rows x 35 columns]

# %%
zoho_df.to_csv(r'C:\Users\fajar\Documents\Python\Data\test_leads.csv', index=False)

# %% [markdown]
# # ====================== Awal Filter Umum ======================

# %%
# data phone, mobile dam email member yang ada di master data (wash member)

m.clean_number(zoho_df, 'Phone')
m.clean_number(zoho_df, 'Mobile')
m.replace_not_valid_to_empty(zoho_df, 'Phone')
m.replace_not_valid_to_empty(zoho_df, 'Mobile')
zoho_df['Email'] = m.lowercase(zoho_df, 'Email')
m.clean_space(zoho_df, 'Email')
m.clean_not_valid_email_format(zoho_df, 'Email')

m.clean_number(df_booking, 'Phone1')
m.clean_number(df_booking, 'Mobile')
df_booking['Email'] = m.lowercase(df_booking, 'Email')
m.clean_space(df_booking, 'Email')
m.clean_not_valid_email_format(df_booking, 'Email')

m.clean_number(df_phone, 'Mobile')

df_email['Email'] = m.lowercase(df_email, 'Email')
m.clean_space(df_email, 'Email')
m.clean_not_valid_email_format(df_email, 'Email')
# Out:
# 'Email'

# %%
zoho_df.loc[zoho_df['Phone']=='']
# Out:
# Empty DataFrame
# Columns: [Record Id, Created Time, Created Date, First Name, Last Name, Email, Phone, Mobile, Birthdate, Year of Birth, Street, Street2, City, State, Country, Nationality, Departure Date, Arrival Date, Card Type, Marital Status, Lead Brand, Lead Sub-Brand, Lead Source, Lead Locations, Lead Source Description, Lead Regions, Lead Status, Booking Status, BookRef, Email Opt Out, Opt In, GDPR Compliant, Website, Comments, Do you live in Bali?]
# Index: []
#
# [0 rows x 35 columns]

# %%
count_deleted_wrong_format = m.delete_email_wrong_format(zoho_df, 'Email')
count_after_deleted_wrong_format = zoho_df.shape[0]

# %%
# hitung jumlah duplicate
count_duplicate_general = zoho_df.loc[zoho_df.duplicated(subset=['Phone','Email', 'Mobile'])].shape[0]

zoho_df.loc[zoho_df.duplicated(subset=['Phone','Email'])]
# Out:
#                      Record Id        Created Time Created Date First Name  \
# 52    zcrm_3584690000205244196 2020-07-16 10:08:45   2020-05-19          T
# 62    zcrm_3584690000205244206 2020-07-16 10:08:45   2020-05-20     Vinson
# 78    zcrm_3584690000205244222 2020-07-16 10:08:45   2020-06-06     Meagan
# 85    zcrm_3584690000205244229 2020-07-16 10:08:45   2020-06-06       Karl
# 91    zcrm_3584690000205244235 2020-07-16 10:08:45   2020-06-06       Sean
# ...                        ...                 ...          ...        ...
# 7873  zcrm_3584690000472158145 2023-12-08 11:28:00   2020-07-04       Alva
# 7874  zcrm_3584690000472158146 2023-12-08 11:28:00   2020-07-11     Firiwi
# 7875  zcrm_3584690000472158147 2023-12-08 11:28:00   2020-07-11   Jashmine
# 7876  zcrm_3584690000472158148 2023-12-08 11:28:00   2020-07-11    Sherina
# 7877  zcrm_3584690000472158149 2023-12-08 11:28:00   2020-07-19     Amalia
#
#      Last Name                        Email         Phone Mobile Birthdate  \
# 52    Shepherd            noemail@gmail.com   61476153874  empty     empty
# 62        Wang     yinsonvinson@hotmail.com   61428839471  empty     empty
# 78    Eastwood  meagan_eastwood@hotmail.com   61405215093  empty     empty
# 85     Pratley        kpratley@iinet.net.au   61411868425  empty     empty
# 91    Lawrence          sean._7@hotmail.com   61414479164  empty     empty
# ...        ...                          ...           ...    ...       ...
# 7873    Susilo        alva.susilo@gmail.com  062843541819  empty     empty
# 7874         -            vxlereii@gmail.co         empty  empty     empty
# 7875         -         jasmin.aser@gmail.co         empty  empty     empty
# 7876         -          serhinadey@gmail.co         empty  empty     empty
# 7877         -           amalyahas@yahoo.co         empty  empty     empty
#
#      Year of Birth  ... Lead Regions Lead Status Booking Status BookRef  \
# 52           empty  ...         SEAP    New Lead          empty   empty
# 62           empty  ...         SEAP    New Lead          empty   empty
# 78           empty  ...         SEAP    New Lead          empty   empty
# 85           empty  ...         SEAP    New Lead          empty   empty
# 91           empty  ...         SEAP    New Lead          empty   empty
# ...            ...  ...          ...         ...            ...     ...
# 7873         empty  ...         SEAP    New Lead          empty   empty
# 7874         empty  ...         SEAP    New Lead          empty   empty
# 7875         empty  ...         SEAP    New Lead          empty   empty
# 7876         empty  ...         SEAP    New Lead          empty   empty
# 7877         empty  ...         SEAP    New Lead          empty   empty
#
#      Email Opt Out Opt In GDPR Compliant Website Comments Do you live in Bali?
# 52           empty  empty          empty   empty    empty                empty
# 62           empty  empty          empty   empty    empty                empty
# 78           empty  empty          empty   empty    empty                empty
# 85           empty  empty          empty   empty    empty                empty
# 91           empty  empty          empty   empty    empty                empty
# ...            ...    ...            ...     ...      ...                  ...
# 7873         empty  empty          empty   empty    empty                empty
# 7874         empty  empty          empty   empty    empty                empty
# 7875         empty  empty          empty   empty    empty                empty
# 7876         empty  empty          empty   empty    empty                empty
# 7877         empty  empty          empty   empty    empty                empty
#
# [726 rows x 35 columns]

# %%
zoho_df.drop_duplicates(subset=['Phone','Email', 'Mobile'], inplace=True)
zoho_df.reset_index(drop=True, inplace=True)

# hitung jumlah setelah value duplicate dihapus
count_after_dedup_duplicate = zoho_df.shape[0]

zoho_df
# Out:
#                      Record Id        Created Time Created Date First Name  \
# 0     zcrm_3584690000004983243 2019-03-25 15:51:36   2020-06-13        Tom
# 1     zcrm_3584690000005939555 2019-04-02 02:14:16   2020-06-25     Robert
# 2     zcrm_3584690000005947831 2019-04-02 02:15:04   2020-06-19       Joan
# 3     zcrm_3584690000005955729 2019-04-02 02:15:48   2020-06-19     Kirsty
# 4     zcrm_3584690000005961815 2019-04-02 02:16:22   2020-06-06       Karl
# ...                        ...                 ...          ...        ...
# 7661  zcrm_3584690000472158850 2023-12-08 11:28:04   2021-09-10      Citra
# 7662  zcrm_3584690000472158852 2023-12-08 11:28:04   2021-09-10       Mark
# 7663  zcrm_3584690000472158853 2023-12-08 11:28:04   2021-09-10    Labibah
# 7664  zcrm_3584690000472158854 2023-12-08 11:28:04   2021-09-15    Suryadi
# 7665  zcrm_3584690000472158855 2023-12-08 11:28:04   2021-09-15     Ariska
#
#      Last Name                        Email         Phone       Mobile  \
# 0       Hawtin          tomie.h@hotmail.com   61401644180        empty
# 1      van Erp           rfvanerp@gmail.com   61488031867        empty
# 2      Dugdale      dugdale@optusnet.com.au   61413189408        empty
# 3       Morgan     aysiajane@ozemail.com.au   61438467919        empty
# 4      Pratley        kpratley@iinet.net.au   61411868425  61413946747
# ...        ...                          ...           ...          ...
# 7661         -         citralaras@gmail.com  087878734051        empty
# 7662         -    tia_sabrina2112@gmail.com  081390815624        empty
# 7663         -           labibaah@gmail.com  081231814308        empty
# 7664         -  suryadi.rubicon96@gmail.com  082119990280        empty
# 7665         -          disariska@gmail.com  081221523153        empty
#
#        Birthdate Year of Birth  ... Lead Regions Lead Status Booking Status  \
# 0     1982-04-20          1982  ...         SEAP    New Lead          empty
# 1          empty         empty  ...         SEAP       empty          empty
# 2          empty         empty  ...         SEAP       empty          empty
# 3          empty         empty  ...         SEAP       empty          empty
# 4     1964-07-18          1964  ...         SEAP    Not Sold          empty
# ...          ...           ...  ...          ...         ...            ...
# 7661       empty         empty  ...         SEAP    New Lead          empty
# 7662       empty         empty  ...         SEAP    New Lead          empty
# 7663       empty         empty  ...         SEAP    New Lead          empty
# 7664       empty         empty  ...         SEAP    New Lead          empty
# 7665       empty         empty  ...         SEAP    New Lead          empty
#
#      BookRef Email Opt Out Opt In GDPR Compliant Website Comments  \
# 0      empty         empty  empty          empty   empty    empty
# 1      empty         empty  empty          empty   empty    empty
# 2      empty         empty  empty          empty   empty    empty
# 3      empty         empty  empty          empty   empty    empty
# 4      empty         empty  empty          empty   empty    empty
# ...      ...           ...    ...            ...     ...      ...
# 7661   empty         empty  empty          empty   empty    empty
# 7662   empty         empty  empty          empty   empty    empty
# 7663   empty         empty  empty          empty   empty    empty
# 7664   empty         empty  empty          empty   empty    empty
# 7665   empty         empty  empty          empty   empty    empty
#
#      Do you live in Bali?
# 0                   empty
# 1                   empty
# 2                   empty
# 3                   empty
# 4                   empty
# ...                   ...
# 7661                empty
# 7662                empty
# 7663                empty
# 7664                empty
# 7665                empty
#
# [7666 rows x 35 columns]

# %%
# Cek leads test
test_leads = zoho_df.loc[
    
        zoho_df['Email'].str.contains('^test@', flags=re.I, regex=True) |
        zoho_df['Email'].str.contains('\+test', flags=re.I, regex=True) |
    
        zoho_df['First Name'].str.contains('^test$', flags=re.I, regex=True) |
        zoho_df['Last Name'].str.contains('^test$', flags=re.I, regex=True) |

        zoho_df['First Name'].str.contains('test 1', flags=re.I, regex=True) |
        zoho_df['Last Name'].str.contains('test 2', flags=re.I, regex=True)|
        zoho_df['First Name'].str.contains('test1', flags=re.I, regex=True) |
        zoho_df['Last Name'].str.contains('test2', flags=re.I, regex=True)|

        zoho_df['First Name'].str.contains(' test ', flags=re.I, regex=True) | 
        zoho_df['Last Name'].str.contains(' test ', flags=re.I, regex=True) | 
        zoho_df['Last Name'].str.contains(' test$', flags=re.I, regex=True)
    ]

count_leads_test = test_leads.shape[0]

# test_leads.to_excel(r'C:\Users\fajar\Documents\Python\Data\test_leads_2.xlsx', index=False)
test_leads
# Out:
# Empty DataFrame
# Columns: [Record Id, Created Time, Created Date, First Name, Last Name, Email, Phone, Mobile, Birthdate, Year of Birth, Street, Street2, City, State, Country, Nationality, Departure Date, Arrival Date, Card Type, Marital Status, Lead Brand, Lead Sub-Brand, Lead Source, Lead Locations, Lead Source Description, Lead Regions, Lead Status, Booking Status, BookRef, Email Opt Out, Opt In, GDPR Compliant, Website, Comments, Do you live in Bali?]
# Index: []
#
# [0 rows x 35 columns]

# %%
zoho_df.drop(test_leads.index, inplace=True)
zoho_df.reset_index(drop=True, inplace=True)

count_after_dedup_test = zoho_df.shape[0]

# %%
# dnm_leads = zoho_df.loc[(zoho_df['Do Not Mail'] == 'true') | (zoho_df['Do Not Contact'] == 'true')]
# count_dnm = dnm_leads.shape[0]

# %%
# zoho_df.drop(dnm_leads.index, inplace=True)
# zoho_df.reset_index(drop=True, inplace=True)

# count_after_dedup_dnm = zoho_df.shape[0]

# %%
# Cek Email OTA
email_OTA = m.find_OTA(zoho_df, 'Email')
count_email_OTA = email_OTA.shape[0]
# email_OTA.to_excel(r'C:\Users\fajar\Documents\Python\Data\email_OTA.xlsx', index=False)

email_OTA
# Out:
#                      Record Id        Created Time Created Date First Name  \
# 1019  zcrm_3584690000236271324 2020-09-23 13:23:29   2020-07-30      empty
# 1500  zcrm_3584690000241854616 2020-10-24 11:51:15   2020-10-24      empty
# 2778  zcrm_3584690000258991805 2021-01-16 14:26:37   2020-12-20      empty
# 3386  zcrm_3584690000268170406 2021-02-28 16:53:30        empty       Toni
# 5644  zcrm_3584690000293784167 2021-06-01 23:58:26   2020-12-20      empty
# 7239  zcrm_3584690000472158168 2023-12-08 11:28:00   2020-12-20      Ronal
#
#      Last Name                             Email          Phone      Mobile  \
# 1019     Aaron                   aaron@agoda.com          empty       empty
# 1500    Sandra             sandra.tjoa@agoda.com     8123827678  8123827678
# 2778     Ronal  balitourgemilangintown@gmail.com   081236795101       empty
# 3386     Halim            letsgotourku@gmail.com  6281361447545       empty
# 5644     Ronal  balitourgemilangintown@gmail.com    81236795101       empty
# 7239         -  balitourgemilangintown@gmail.con   081236795101       empty
#
#      Birthdate Year of Birth  ... Lead Regions Lead Status Booking Status  \
# 1019     empty         empty  ...         SEAP    New Lead          empty
# 1500     empty         empty  ...         SEAP    New Lead          empty
# 2778     empty         empty  ...         SEAP    New Lead          empty
# 3386     empty         empty  ...         SEAP    New Lead          empty
# 5644     empty         empty  ...         SEAP    New Lead          empty
# 7239     empty         empty  ...         SEAP    New Lead          empty
#
#      BookRef Email Opt Out Opt In GDPR Compliant Website Comments  \
# 1019   empty         empty  empty          empty   empty    empty
# 1500   empty         empty  empty          empty   empty    empty
# 2778   empty         empty  empty          empty   empty    empty
# 3386   empty         empty  empty          empty   empty    empty
# 5644   empty         empty  empty          empty   empty    empty
# 7239   empty         empty  empty          empty   empty    empty
#
#      Do you live in Bali?
# 1019                empty
# 1500                empty
# 2778                empty
# 3386                empty
# 5644                empty
# 7239                empty
#
# [6 rows x 35 columns]

# %%
# delete email OTA
count_after_clean_OTA = m.delete_OTA(zoho_df, 'Email')
# zoho_df.to_excel(r'C:\Users\fajar\Documents\Python\Data\after_clean_OTA.xlsx', index=False)

zoho_df
# Out:
#                      Record Id        Created Time Created Date First Name  \
# 0     zcrm_3584690000004983243 2019-03-25 15:51:36   2020-06-13        Tom
# 1     zcrm_3584690000005939555 2019-04-02 02:14:16   2020-06-25     Robert
# 2     zcrm_3584690000005947831 2019-04-02 02:15:04   2020-06-19       Joan
# 3     zcrm_3584690000005955729 2019-04-02 02:15:48   2020-06-19     Kirsty
# 4     zcrm_3584690000005961815 2019-04-02 02:16:22   2020-06-06       Karl
# ...                        ...                 ...          ...        ...
# 7655  zcrm_3584690000472158850 2023-12-08 11:28:04   2021-09-10      Citra
# 7656  zcrm_3584690000472158852 2023-12-08 11:28:04   2021-09-10       Mark
# 7657  zcrm_3584690000472158853 2023-12-08 11:28:04   2021-09-10    Labibah
# 7658  zcrm_3584690000472158854 2023-12-08 11:28:04   2021-09-15    Suryadi
# 7659  zcrm_3584690000472158855 2023-12-08 11:28:04   2021-09-15     Ariska
#
#      Last Name                        Email         Phone       Mobile  \
# 0       Hawtin          tomie.h@hotmail.com   61401644180        empty
# 1      van Erp           rfvanerp@gmail.com   61488031867        empty
# 2      Dugdale      dugdale@optusnet.com.au   61413189408        empty
# 3       Morgan     aysiajane@ozemail.com.au   61438467919        empty
# 4      Pratley        kpratley@iinet.net.au   61411868425  61413946747
# ...        ...                          ...           ...          ...
# 7655         -         citralaras@gmail.com  087878734051        empty
# 7656         -    tia_sabrina2112@gmail.com  081390815624        empty
# 7657         -           labibaah@gmail.com  081231814308        empty
# 7658         -  suryadi.rubicon96@gmail.com  082119990280        empty
# 7659         -          disariska@gmail.com  081221523153        empty
#
#        Birthdate Year of Birth  ... Lead Regions Lead Status Booking Status  \
# 0     1982-04-20          1982  ...         SEAP    New Lead          empty
# 1          empty         empty  ...         SEAP       empty          empty
# 2          empty         empty  ...         SEAP       empty          empty
# 3          empty         empty  ...         SEAP       empty          empty
# 4     1964-07-18          1964  ...         SEAP    Not Sold          empty
# ...          ...           ...  ...          ...         ...            ...
# 7655       empty         empty  ...         SEAP    New Lead          empty
# 7656       empty         empty  ...         SEAP    New Lead          empty
# 7657       empty         empty  ...         SEAP    New Lead          empty
# 7658       empty         empty  ...         SEAP    New Lead          empty
# 7659       empty         empty  ...         SEAP    New Lead          empty
#
#      BookRef Email Opt Out Opt In GDPR Compliant Website Comments  \
# 0      empty         empty  empty          empty   empty    empty
# 1      empty         empty  empty          empty   empty    empty
# 2      empty         empty  empty          empty   empty    empty
# 3      empty         empty  empty          empty   empty    empty
# 4      empty         empty  empty          empty   empty    empty
# ...      ...           ...    ...            ...     ...      ...
# 7655   empty         empty  empty          empty   empty    empty
# 7656   empty         empty  empty          empty   empty    empty
# 7657   empty         empty  empty          empty   empty    empty
# 7658   empty         empty  empty          empty   empty    empty
# 7659   empty         empty  empty          empty   empty    empty
#
#      Do you live in Bali?
# 0                   empty
# 1                   empty
# 2                   empty
# 3                   empty
# 4                   empty
# ...                   ...
# 7655                empty
# 7656                empty
# 7657                empty
# 7658                empty
# 7659                empty
#
# [7660 rows x 35 columns]

# %%
# Cek Email Karma
email_karma = m.find_karma(zoho_df, 'Email')
count_email_karma = email_karma.shape[0]
# email_OTA.to_excel(r'C:\Users\fajar\Documents\Python\Data\email_OTA.xlsx', index=False)

email_karma
# Out:
#                      Record Id        Created Time Created Date First Name  \
# 2039  zcrm_3584690000252265746 2020-12-15 10:46:28   2020-06-28       Mona
#
#         Last Name                              Email       Phone Mobile  \
# 2039  Bhartolomay  mona.bhartolomay@karmaestates.com  8113863499  empty
#
#      Birthdate Year of Birth  ... Lead Regions Lead Status Booking Status  \
# 2039     empty         empty  ...         SEAP    New Lead          empty
#
#      BookRef Email Opt Out Opt In GDPR Compliant Website Comments  \
# 2039   empty         empty  empty          empty   empty    empty
#
#      Do you live in Bali?
# 2039                empty
#
# [1 rows x 35 columns]

# %%
# delete email Karma
count_after_clean_karma = m.delete_karma(zoho_df, 'Email')
# zoho_df.to_excel(r'C:\Users\fajar\Documents\Python\Data\after_clean_OTA.xlsx', index=False)

zoho_df
# Out:
#                      Record Id        Created Time Created Date First Name  \
# 0     zcrm_3584690000004983243 2019-03-25 15:51:36   2020-06-13        Tom
# 1     zcrm_3584690000005939555 2019-04-02 02:14:16   2020-06-25     Robert
# 2     zcrm_3584690000005947831 2019-04-02 02:15:04   2020-06-19       Joan
# 3     zcrm_3584690000005955729 2019-04-02 02:15:48   2020-06-19     Kirsty
# 4     zcrm_3584690000005961815 2019-04-02 02:16:22   2020-06-06       Karl
# ...                        ...                 ...          ...        ...
# 7654  zcrm_3584690000472158850 2023-12-08 11:28:04   2021-09-10      Citra
# 7655  zcrm_3584690000472158852 2023-12-08 11:28:04   2021-09-10       Mark
# 7656  zcrm_3584690000472158853 2023-12-08 11:28:04   2021-09-10    Labibah
# 7657  zcrm_3584690000472158854 2023-12-08 11:28:04   2021-09-15    Suryadi
# 7658  zcrm_3584690000472158855 2023-12-08 11:28:04   2021-09-15     Ariska
#
#      Last Name                        Email         Phone       Mobile  \
# 0       Hawtin          tomie.h@hotmail.com   61401644180        empty
# 1      van Erp           rfvanerp@gmail.com   61488031867        empty
# 2      Dugdale      dugdale@optusnet.com.au   61413189408        empty
# 3       Morgan     aysiajane@ozemail.com.au   61438467919        empty
# 4      Pratley        kpratley@iinet.net.au   61411868425  61413946747
# ...        ...                          ...           ...          ...
# 7654         -         citralaras@gmail.com  087878734051        empty
# 7655         -    tia_sabrina2112@gmail.com  081390815624        empty
# 7656         -           labibaah@gmail.com  081231814308        empty
# 7657         -  suryadi.rubicon96@gmail.com  082119990280        empty
# 7658         -          disariska@gmail.com  081221523153        empty
#
#        Birthdate Year of Birth  ... Lead Regions Lead Status Booking Status  \
# 0     1982-04-20          1982  ...         SEAP    New Lead          empty
# 1          empty         empty  ...         SEAP       empty          empty
# 2          empty         empty  ...         SEAP       empty          empty
# 3          empty         empty  ...         SEAP       empty          empty
# 4     1964-07-18          1964  ...         SEAP    Not Sold          empty
# ...          ...           ...  ...          ...         ...            ...
# 7654       empty         empty  ...         SEAP    New Lead          empty
# 7655       empty         empty  ...         SEAP    New Lead          empty
# 7656       empty         empty  ...         SEAP    New Lead          empty
# 7657       empty         empty  ...         SEAP    New Lead          empty
# 7658       empty         empty  ...         SEAP    New Lead          empty
#
#      BookRef Email Opt Out Opt In GDPR Compliant Website Comments  \
# 0      empty         empty  empty          empty   empty    empty
# 1      empty         empty  empty          empty   empty    empty
# 2      empty         empty  empty          empty   empty    empty
# 3      empty         empty  empty          empty   empty    empty
# 4      empty         empty  empty          empty   empty    empty
# ...      ...           ...    ...            ...     ...      ...
# 7654   empty         empty  empty          empty   empty    empty
# 7655   empty         empty  empty          empty   empty    empty
# 7656   empty         empty  empty          empty   empty    empty
# 7657   empty         empty  empty          empty   empty    empty
# 7658   empty         empty  empty          empty   empty    empty
#
#      Do you live in Bali?
# 0                   empty
# 1                   empty
# 2                   empty
# 3                   empty
# 4                   empty
# ...                   ...
# 7654                empty
# 7655                empty
# 7656                empty
# 7657                empty
# 7658                empty
#
# [7659 rows x 35 columns]

# %%
find_member_booking = zoho_df.copy()

find_member_booking.loc[find_member_booking['Phone'].isin(df_booking['Phone1']), 'Same Value Find'] = 'Booking-Phone1'
find_member_booking.loc[find_member_booking['Phone'].isin(df_booking['Mobile']), 'Same Value Find'] = 'Booking-Mobile'
find_member_booking.loc[find_member_booking['Mobile'].isin(df_booking['Phone1']), 'Same Value Find'] = 'Booking-Phone1' 
find_member_booking.loc[find_member_booking['Mobile'].isin(df_booking['Mobile']), 'Same Value Find'] = 'Booking-Mobile'
find_member_booking.loc[find_member_booking['Email'].isin(df_booking['Email']), 'Same Value Find'] = 'Booking-Email'

find_member_booking.loc[find_member_booking['Phone'].isin(df_phone['Mobile']), 'Same Value Find'] = 'Member-Mobile' 
find_member_booking.loc[find_member_booking['Mobile'].isin(df_phone['Mobile']), 'Same Value Find'] = 'Member-Mobile'

find_member_booking.loc[find_member_booking['Email'].isin(df_email['Email']), 'Same Value Find'] = 'Member-Email'

find_member_booking.drop(find_member_booking.loc[find_member_booking['Same Value Find'].isna()].index, inplace=True)

count_booking_dedup = find_member_booking.loc[find_member_booking['Same Value Find'].str.contains('Booking', flags=re.I, regex=True)].shape[0]
count_member_dedup = find_member_booking.loc[find_member_booking['Same Value Find'].str.contains('Member', flags=re.I, regex=True)].shape[0]

find_member_booking.replace('empty', '', inplace=True)
# find_member_booking.to_csv(r'C:\Users\fajar\Documents\Python\Data\booking-member-dedup.csv', index=False)
# find_member_booking.to_excel(r'C:\Users\fajar\Documents\Python\Data\booking-member-dedup.xlsx', index=False)

#find_member_booking.loc[find_member_booking['Same Value Find'] == 'Booking-Phone1']

# %%
# data phone, mobile dam email member yang ada di master data 
count_wash_member = zoho_df.loc[
    zoho_df['Phone'].isin(df_booking['Phone1']) | 
    zoho_df['Phone'].isin(df_booking['Mobile']) |
    zoho_df['Mobile'].isin(df_booking['Phone1']) | 
    zoho_df['Mobile'].isin(df_booking['Mobile']) |
    zoho_df['Email'].isin(df_booking['Email'])| 

    zoho_df['Phone'].isin(df_phone['Mobile']) | 
    zoho_df['Mobile'].isin(df_phone['Mobile']) |

    zoho_df['Email'].isin(df_email['Email'])

].shape[0]

zoho_df.drop(zoho_df.loc[
    zoho_df['Phone'].isin(df_booking['Phone1']) | 
    zoho_df['Phone'].isin(df_booking['Mobile']) |
    zoho_df['Mobile'].isin(df_booking['Phone1']) | 
    zoho_df['Mobile'].isin(df_booking['Mobile']) |
    zoho_df['Email'].isin(df_booking['Email']) |
    
    zoho_df['Phone'].isin(df_phone['Mobile']) | 
    zoho_df['Mobile'].isin(df_phone['Mobile']) |

    zoho_df['Email'].isin(df_email['Email'])

    ].index, inplace=True)
    
zoho_df.reset_index(drop=True, inplace=True)

count_after_wash_member = zoho_df.shape[0]

# %%
count_email_only = zoho_df.loc[(zoho_df['Email'] != 'empty') & ((zoho_df['Phone'] == 'empty') & (zoho_df['Mobile'] == 'empty'))].shape[0]
count_phone_only = zoho_df.loc[(zoho_df['Email'] == 'empty') & ((zoho_df['Phone'] != 'empty') | (zoho_df['Mobile'] != 'empty'))].shape[0]
count_email_and_phone = zoho_df.loc[(zoho_df['Email'] != 'empty') & ((zoho_df['Phone'] != 'empty') | (zoho_df['Mobile'] != 'empty'))].shape[0]

count_blank = zoho_df.loc[(zoho_df['Email'] =='empty') & (zoho_df['Phone']=='empty') & (zoho_df['Mobile']=='empty')].shape[0]

# zoho_df.loc[(zoho_df['Email'] =='empty') & (zoho_df['Phone']=='empty') & (zoho_df['Mobile']=='empty')].to_excel(r'C:\Users\fajar\Documents\Python\Data\blank_data.xlsx', index=False)

zoho_df.loc[(zoho_df['Email'] != 'empty') & ((zoho_df['Phone'] == 'empty') & (zoho_df['Mobile'] == 'empty')), 'Contact Type'] = 'Email Only'
zoho_df.loc[(zoho_df['Email'] == 'empty') & ((zoho_df['Phone'] != 'empty') | (zoho_df['Mobile'] != 'empty')), 'Contact Type'] = 'Phone Only'
zoho_df.loc[(zoho_df['Email'] != 'empty') & ((zoho_df['Phone'] != 'empty') | (zoho_df['Mobile'] != 'empty')), 'Contact Type'] = 'Email and Phone'

zoho_df.drop(zoho_df.loc[(zoho_df['Email'] =='empty') & (zoho_df['Phone']=='empty') & (zoho_df['Mobile']=='empty')].index, inplace=True)
zoho_df.reset_index(drop=True, inplace=True)

count_after_wash_blank = zoho_df.shape[0]

# %%
arr_dedup = [count_deleted_wrong_format, count_duplicate_general, count_leads_test, count_email_OTA, count_email_karma, count_blank]
count_sum_dedup = sum(arr_dedup)
count_sum_dedup
# Out:
# 664

# %%
print("==========================================================")
print("Summary")
print("==========================================================")
print("Jumlah Keseluruhan Master Zoho : "+str(count_data_awal))
print("Jumlah Filter Leads Awal : "+str(count_filter_awal))
print("Jumlah Format Email Salah : "+str(count_deleted_wrong_format))
print("Jumlah Setelah Clean Format Email Salah : "+str(count_after_deleted_wrong_format))
print("Jumlah Duplicate (Phone, Mobile dan Email) : "+str(count_duplicate_general))
print("Jumlah Setelah Clean Duplicate : "+str(count_after_dedup_duplicate))
print("Jumlah Lead Test : "+str(count_leads_test))
print("Jumlah Setelah Clean Lead Test : "+str(count_after_dedup_test))
# print("Jumlah Lead Do Not Mail : "+str(count_dnm))
# print("Jumlah Setelah Clean Lead Do Not Mail : "+str(count_after_dedup_dnm))
print("Jumlah Email OTA : "+str(count_email_OTA))
print("Jumlah Setelah Clean Email OTA : "+str(count_after_clean_OTA))
print("Jumlah Email Karma : "+str(count_email_karma))
print("Jumlah Setelah Clean Email Karma : "+str(count_after_clean_karma))
print("Jumlah Wash Member : "+str(count_member_dedup))
print("Jumlah Wash Booking : "+str(count_booking_dedup))
print("Jumlah Setelah Wash Member : "+str(count_after_wash_member))
print("Jumlah Phone Email Blank (Setelah phone yang tidak valid dihapus) : "+str(count_blank))
print("Jumlah Setelah Wash Phone Email Blank : "+str(count_after_wash_blank))
print("==========================================================")
print("Contact Type")
print("==========================================================")
print("Jumlah Email Only : "+str(count_email_only))
print("Jumlah Phone Only : "+str(count_phone_only))
print("Jumlah Email dan Phone : "+str(count_email_and_phone))
# Out:
# ==========================================================
# Summary
# ==========================================================
# Jumlah Keseluruhan Master Zoho : 10022607
# Jumlah Filter Leads Awal : 8323
# Jumlah Format Email Salah : 0
# Jumlah Setelah Clean Format Email Salah : 8323
# Jumlah Duplicate (Phone, Mobile dan Email) : 657
# Jumlah Setelah Clean Duplicate : 7666
# Jumlah Lead Test : 0
# Jumlah Setelah Clean Lead Test : 7666
# Jumlah Email OTA : 6
# Jumlah Setelah Clean Email OTA : 7660
# Jumlah Email Karma : 1
# Jumlah Setelah Clean Email Karma : 7659
# Jumlah Wash Member : 806
# Jumlah Wash Booking : 252
# Jumlah Setelah Wash Member : 6601
# Jumlah Phone Email Blank (Setelah phone yang tidak valid dihapus) : 0
# Jumlah Setelah Wash Phone Email Blank : 6601
# ==========================================================
# Contact Type
# ==========================================================
# Jumlah Email Only : 1137
# Jumlah Phone Only : 5
# Jumlah Email dan Phone : 5459

# %%
print("==========================================================")
print("Summary Report")
print("==========================================================")
print("Jumlah Data Awal : "+str(count_filter_awal))
print("Jumlah Wash Dedup : "+str(count_sum_dedup))
print("Jumlah Wash Member : "+str(count_member_dedup))
print("Jumlah Wash Booking : "+str(count_booking_dedup))
print("Jumlah Data Akhir : "+str(count_after_wash_blank))
# Out:
# ==========================================================
# Summary Report
# ==========================================================
# Jumlah Data Awal : 8323
# Jumlah Wash Dedup : 664
# Jumlah Wash Member : 806
# Jumlah Wash Booking : 252
# Jumlah Data Akhir : 6601

# %% [markdown]
# # ====================== Akhir Filter Umum ======================

# %%
zoho_df.replace('empty', '', inplace=True, regex=True)

zoho_df['First Name'] = zoho_df['First Name'].str.title()
zoho_df['Last Name'] = zoho_df['Last Name'].str.title()

zoho_df.to_excel(r'C:\Users\fajar\Documents\Python\Data\covid register.xlsx', index=False)

# %%
zoho_df.groupby('Country').count()
# Out:
#                 Record Id  Created Time  Created Date  First Name  Last Name  \
# Country
#                      4795          4795          4795        4795       4795
# Australia             361           361           361         361        361
# Belarus                 2             2             2           2          2
# Belgium                 3             3             3           3          3
# Canada                  2             2             2           2          2
# Fintsvilla              1             1             1           1          1
# France                  2             2             2           2          2
# Germany                48            48            48          48         48
# Hungary                 1             1             1           1          1
# India                 275           275           275         275        275
# Indonesia             979           979           979         979        979
# Italia                  1             1             1           1          1
# Italy                   2             2             2           2          2
# Kazakhstan              1             1             1           1          1
# Kazakhtan               1             1             1           1          1
# Latvia                  2             2             2           2          2
# Malaysia                1             1             1           1          1
# Netherlands             2             2             2           2          2
# Norway                  1             1             1           1          1
# Rusia                   1             1             1           1          1
# Russia                 49            49            49          49         49
# Singapore               1             1             1           1          1
# Spain                   3             3             3           3          3
# Sweden                  6             6             6           6          6
# Switzerland             1             1             1           1          1
# Thailand                1             1             1           1          1
# USA                     2             2             2           2          2
# Ukraine                 8             8             8           8          8
# United Kingdom         41            41            41          41         41
# United States           8             8             8           8          8
#
#                 Email  Phone  Mobile  Birthdate  Year of Birth  ...  \
# Country                                                         ...
#                  4795   4795    4795       4795           4795  ...
# Australia         361    361     361        361            361  ...
# Belarus             2      2       2          2              2  ...
# Belgium             3      3       3          3              3  ...
# Canada              2      2       2          2              2  ...
# Fintsvilla          1      1       1          1              1  ...
# France              2      2       2          2              2  ...
# Germany            48     48      48         48             48  ...
# Hungary             1      1       1          1              1  ...
# India             275    275     275        275            275  ...
# Indonesia         979    979     979        979            979  ...
# Italia              1      1       1          1              1  ...
# Italy               2      2       2          2              2  ...
# Kazakhstan          1      1       1          1              1  ...
# Kazakhtan           1      1       1          1              1  ...
# Latvia              2      2       2          2              2  ...
# Malaysia            1      1       1          1              1  ...
# Netherlands         2      2       2          2              2  ...
# Norway              1      1       1          1              1  ...
# Rusia               1      1       1          1              1  ...
# Russia             49     49      49         49             49  ...
# Singapore           1      1       1          1              1  ...
# Spain               3      3       3          3              3  ...
# Sweden              6      6       6          6              6  ...
# Switzerland         1      1       1          1              1  ...
# Thailand            1      1       1          1              1  ...
# USA                 2      2       2          2              2  ...
# Ukraine             8      8       8          8              8  ...
# United Kingdom     41     41      41         41             41  ...
# United States       8      8       8          8              8  ...
#
#                 Lead Status  Booking Status  BookRef  Email Opt Out  Opt In  \
# Country
#                        4795            4795     4795           4795    4795
# Australia               361             361      361            361     361
# Belarus                   2               2        2              2       2
# Belgium                   3               3        3              3       3
# Canada                    2               2        2              2       2
# Fintsvilla                1               1        1              1       1
# France                    2               2        2              2       2
# Germany                  48              48       48             48      48
# Hungary                   1               1        1              1       1
# India                   275             275      275            275     275
# Indonesia               979             979      979            979     979
# Italia                    1               1        1              1       1
# Italy                     2               2        2              2       2
# Kazakhstan                1               1        1              1       1
# Kazakhtan                 1               1        1              1       1
# Latvia                    2               2        2              2       2
# Malaysia                  1               1        1              1       1
# Netherlands               2               2        2              2       2
# Norway                    1               1        1              1       1
# Rusia                     1               1        1              1       1
# Russia                   49              49       49             49      49
# Singapore                 1               1        1              1       1
# Spain                     3               3        3              3       3
# Sweden                    6               6        6              6       6
# Switzerland               1               1        1              1       1
# Thailand                  1               1        1              1       1
# USA                       2               2        2              2       2
# Ukraine                   8               8        8              8       8
# United Kingdom           41              41       41             41      41
# United States             8               8        8              8       8
#
#                 GDPR Compliant  Website  Comments  Do you live in Bali?  \
# Country
#                           4795     4795      4795                  4795
# Australia                  361      361       361                   361
# Belarus                      2        2         2                     2
# Belgium                      3        3         3                     3
# Canada                       2        2         2                     2
# Fintsvilla                   1        1         1                     1
# France                       2        2         2                     2
# Germany                     48       48        48                    48
# Hungary                      1        1         1                     1
# India                      275      275       275                   275
# Indonesia                  979      979       979                   979
# Italia                       1        1         1                     1
# Italy                        2        2         2                     2
# Kazakhstan                   1        1         1                     1
# Kazakhtan                    1        1         1                     1
# Latvia                       2        2         2                     2
# Malaysia                     1        1         1                     1
# Netherlands                  2        2         2                     2
# Norway                       1        1         1                     1
# Rusia                        1        1         1                     1
# Russia                      49       49        49                    49
# Singapore                    1        1         1                     1
# Spain                        3        3         3                     3
# Sweden                       6        6         6                     6
# Switzerland                  1        1         1                     1
# Thailand                     1        1         1                     1
# USA                          2        2         2                     2
# Ukraine                      8        8         8                     8
# United Kingdom              41       41        41                    41
# United States                8        8         8                     8
#
#                 Contact Type
# Country
#                         4795
# Australia                361
# Belarus                    2
# Belgium                    3
# Canada                     2
# Fintsvilla                 1
# France                     2
# Germany                   48
# Hungary                    1
# India                    275
# Indonesia                979
# Italia                     1
# Italy                      2
# Kazakhstan                 1
# Kazakhtan                  1
# Latvia                     2
# Malaysia                   1
# Netherlands                2
# Norway                     1
# Rusia                      1
# Russia                    49
# Singapore                  1
# Spain                      3
# Sweden                     6
# Switzerland                1
# Thailand                   1
# USA                        2
# Ukraine                    8
# United Kingdom            41
# United States              8
#
# [30 rows x 35 columns]

# %%
# zoho_df['Country'].loc[
#     (zoho_df['Phone'].str.contains('^44|^\+44')) & 
#     (~zoho_df['Country'].str.contains('united kingdom|wales|england|scotland|northern ireland', regex=True, flags=re.I))
# ]
