# %%
import main_module as m
import zoho_filter_module as fil
import pandas as pd
import re
import numpy as np

# %load_ext autoreload
# %autoreload 2

dir_path = r'C:\Users\fajar\Documents\Python\Data\Zoho_Backup\2020-2024'
dir_path_live = r'C:\Users\fajar\Documents\Python\Data\Zoho_Backup'
dir_path_old = r'C:\Users\fajar\Documents\Python\Data\Zoho_Backup\old'
file_name = '\Leads_'

cols = ['Record Id',	
'Created Time',
'Created Date',	
'First Name',	
'Last Name',	
'Email',	
'Phone',	
'Mobile',	
'Birthdate',	
'Year of Birth',
'Street',	
'Street2',	
'City',	
'State',	
'Country',	
'Nationality',
'Booking Status', 
'BookRef',
'Departure Date',	
'Arrival Date',	
'Card Type',	
'Marital Status',	
'Lead Brand',	
'Lead Sub-Brand',	
'Lead Source',	
'Lead Locations',	
'Lead Source Description',	
'Lead Regions',
'Lead Status',
'Email Opt Out',	
'Opt In',
'GDPR Compliant',
'Website',
'Comments',
'IP Address']

# %%
email = 'zzangss75@hotmail.com'

# %%
path = dir_path+'\\backup.csv'
df_all = pd.read_csv(path, dtype='string', on_bad_lines='skip')
count_data_awal = df_all.shape[0]
df_all.drop(df_all.loc[df_all['Created Time'].str.len() < 5 ].index, inplace=True)
df_all.reset_index(drop=True, inplace=True)

df_all['Created Time'] = pd.to_datetime(df_all['Created Time'], format='%Y-%m-%d %H:%M:%S')

df_all.shape[0]
df_all
# Out:
#                         Record Id        Created Time Created Date First Name  \
# 0        zcrm_3584690000000404058 2019-01-07 15:08:38   2019-01-06   Nicholas
# 1        zcrm_3584690000000404059 2019-01-07 15:08:38   2019-01-06       Liao
# 2        zcrm_3584690000000404060 2019-01-07 15:08:38   2019-01-06    Vedanta
# 3        zcrm_3584690000000404065 2019-01-07 15:08:38   2019-01-06      Aidai
# 4        zcrm_3584690000000404068 2019-01-07 15:08:38   2019-01-06      Ardra
# ...                           ...                 ...          ...        ...
# 9965978  zcrm_3584690000489266005 2024-03-25 16:19:45         <NA>      Keval
# 9965979  zcrm_3584690000489266034 2024-03-25 16:19:51         <NA>     Suresh
# 9965980  zcrm_3584690000489266063 2024-03-25 17:29:27         <NA>     Nathan
# 9965981  zcrm_3584690000489269015 2024-03-25 16:20:25         <NA>    Leonora
# 9965982  zcrm_3584690000489271002 2024-03-25 18:40:17         <NA>       Annu
#
#           Last Name                                 Email           Phone  \
# 0              Wood            1230woodnicholas@gmail.com     61438600845
# 1              Yuan                      158066546@qq.com   8618718399923
# 2          Abhiyoga            abhiyoga.vedanta@gmail.com   6282146524550
# 3         Atakanova                aidai.nurbek@gmail.com    996779641590
# 4             Ardra            aliefardraqariru@gmail.com  +6282139300818
# ...             ...                                   ...             ...
# 9965978        Gala                   keval2403@gmail.com   +919022872972
# 9965979      Shroff  sureshshroff@breachcandyhospital.org   +919819533303
# 9965980   Fernandes       nathan.fernandes@karmagroup.com  +9179724486854
# 9965981     Hackman                leonora_hf@bigpond.com    +61439855115
# 9965982  Shriwastav          annusrivastava1990@gmail.com   +919561074124
#
#                  Mobile   Birthdate Year of Birth  ...         Arrival Date  \
# 0                  <NA>        <NA>          <NA>  ...  2019-01-06 00:00:00
# 1                  <NA>        <NA>          <NA>  ...  2019-01-06 00:00:00
# 2                  <NA>  2000-07-05          2000  ...  2018-12-01 00:00:00
# 3                  <NA>  1997-02-05          1997  ...  2019-01-06 00:00:00
# 4        +6282139300818  2005-01-20          2005  ...  2018-11-30 00:00:00
# ...                 ...         ...           ...  ...                  ...
# 9965978   +917700904802        <NA>          <NA>  ...           2024-03-21
# 9965979   +919819814280        <NA>          <NA>  ...           2024-03-21
# 9965980            <NA>        <NA>          <NA>  ...                 <NA>
# 9965981            <NA>        <NA>          <NA>  ...           2024-03-14
# 9965982            <NA>        <NA>          <NA>  ...                 <NA>
#
#         Card Type Marital Status           Lead Brand   Lead Sub-Brand  \
# 0            <NA>           <NA>  Timeshare Marketing    Other Bali DB
# 1            <NA>           <NA>  Timeshare Marketing    Other Bali DB
# 2            <NA>        Pelajar  Timeshare Marketing    Other Bali DB
# 3            <NA>         Single  Timeshare Marketing    Other Bali DB
# 4            <NA>          OTHER  Timeshare Marketing    Other Bali DB
# ...           ...            ...                  ...              ...
# 9965978      <NA>           <NA>        Karma Resorts            Other
# 9965979      <NA>           <NA>        Karma Resorts            Other
# 9965980      <NA>           <NA>          Karma Group  Karma Community
# 9965981      <NA>           <NA>        Karma Resorts            Other
# 9965982      <NA>           <NA>  Timeshare Marketing            Other
#
#          Lead Source           Lead Locations  \
# 0               Wifi              Purple Wifi
# 1               Wifi              Purple Wifi
# 2               Wifi              Purple Wifi
# 3               Wifi              Purple Wifi
# 4               Wifi              Purple Wifi
# ...              ...                      ...
# 9965978  Past Guests        Karma Royal Palms
# 9965979  Past Guests  Karma Sitabani, Corbett
# 9965980         Quiz                     <NA>
# 9965981  Past Guests           Karma Jimbaran
# 9965982  Web Enquiry           Karma Sitabani
#
#                                    Lead Source Description Lead Regions  \
# 0                                                     <NA>         SEAP
# 1                                                     <NA>        Other
# 2                                                     <NA>         SEAP
# 3                                                     <NA>    UK/Europe
# 4                                    WIFI USER ID 13494142         SEAP
# ...                                                    ...          ...
# 9965978                                          Viewpoint         <NA>
# 9965979                                          Viewpoint         <NA>
# 9965980  Karma Community | Edition 218 - Words to the Wise        India
# 9965981                                          Viewpoint         <NA>
# 9965982                          Timeshare Booking Request        India
#
#         Lead Status
# 0          New Lead
# 1          New Lead
# 2          New Lead
# 3          New Lead
# 4          New Lead
# ...             ...
# 9965978        <NA>
# 9965979        <NA>
# 9965980        <NA>
# 9965981        <NA>
# 9965982        <NA>
#
# [9965983 rows x 27 columns]

# %%
df_old = m.load_data_multiple(dir_path_old, file_name, cols)
count_data_awal = df_old.shape[0]
df_old = df_old.reindex(columns=cols)
df_old.shape[0]

df_old['Created Time'] = pd.to_datetime(df_old['Created Time'], format='%Y-%m-%d %H:%M:%S')
df_old['Arrival Date'] = pd.to_datetime(df_old['Arrival Date'], format='%Y-%m-%d')
df_old['Departure Date'] = pd.to_datetime(df_old['Departure Date'], format='%Y-%m-%d')
# fungsi errors cource untuk menhindari error jika value data date null atau kosong
# df['Birthdate'] = pd.to_datetime(df['Birthdate'], format='%Y-%m-%d', errors='coerce')
df_old.dtypes
df_old
# Out:
#                         Record Id        Created Time Created Date First Name  \
# 0        zcrm_3584690000000404058 2019-01-07 15:08:38   2019-01-06   Nicholas
# 1        zcrm_3584690000000404059 2019-01-07 15:08:38   2019-01-06       Liao
# 2        zcrm_3584690000000404060 2019-01-07 15:08:38   2019-01-06    Vedanta
# 3        zcrm_3584690000000404065 2019-01-07 15:08:38   2019-01-06      Aidai
# 4        zcrm_3584690000000404068 2019-01-07 15:08:38   2019-01-06      Ardra
# ...                           ...                 ...          ...        ...
# 4717718  zcrm_3584690000475135007 2024-01-01 18:16:02         <NA>    Upendra
# 4717719  zcrm_3584690000475135045 2024-01-01 18:16:37         <NA>      Mehul
# 4717720  zcrm_3584690000475136005 2024-01-01 18:17:13         <NA>      swati
# 4717721  zcrm_3584690000475138034 2024-01-01 18:48:36         <NA>      SUMON
# 4717722  zcrm_3584690000475138069 2024-01-01 18:52:24         <NA>      Rohit
#
#          Last Name                       Email           Phone  \
# 0             Wood  1230woodnicholas@gmail.com    +61438600845
# 1             Yuan            158066546@qq.com   8618718399923
# 2         Abhiyoga  abhiyoga.vedanta@gmail.com  +6282146524550
# 3        Atakanova      aidai.nurbek@gmail.com    996779641590
# 4            Ardra  aliefardraqariru@gmail.com  +6282139300818
# ...            ...                         ...             ...
# 4717718     Mishra       upendra.sir@gmail.com   +919036084550
# 4717719  Prajapati     mehul.m111985@gmail.com   +919714713689
# 4717720   agarwala         cswatiadv@gmail.com   +919733055636
# 4717721      SAHOO        sumonsahoo@gmail.com   +918910484814
# 4717722      Kadam      rohit0918.rk@gmail.com   +919819185446
#
#                  Mobile   Birthdate Year of Birth  ...  \
# 0                  <NA>        <NA>          <NA>  ...
# 1                  <NA>        <NA>          <NA>  ...
# 2                  <NA>  2000-07-05          2000  ...
# 3                  <NA>  1997-02-05          1997  ...
# 4        +6282139300818  2005-01-20          2005  ...
# ...                 ...         ...           ...  ...
# 4717718            <NA>        <NA>          <NA>  ...
# 4717719            <NA>        <NA>          <NA>  ...
# 4717720            <NA>        <NA>          <NA>  ...
# 4717721            <NA>        <NA>          <NA>  ...
# 4717722            <NA>        <NA>          <NA>  ...
#
#                  Lead Locations      Lead Source Description Lead Regions  \
# 0                          <NA>                  Purple Wifi         SEAP
# 1                          <NA>                  Purple Wifi        Other
# 2                          <NA>                  Purple Wifi         SEAP
# 3                          <NA>                  Purple Wifi    UK/Europe
# 4                       Mall 21                  Purple Wifi         SEAP
# ...                         ...                          ...          ...
# 4717718  Karma Sunshine Village    Timeshare Booking Request        India
# 4717719                 General  IND | FB MF | Lead captured         <NA>
# 4717720            Karma Martam         IND | FB MF | Martam         <NA>
# 4717721            Karma Martam         IND | FB MF | Martam         <NA>
# 4717722             Royal Palms            IND | FB AF | KRP         <NA>
#
#         Lead Status Email Opt Out Opt In GDPR Compliant  \
# 0          New Lead         false  false          false
# 1          New Lead         false  false          false
# 2          New Lead         false  false          false
# 3          New Lead         false  false          false
# 4          New Lead         false  false          false
# ...             ...           ...    ...            ...
# 4717718        <NA>         false   true           true
# 4717719        <NA>         false  false          false
# 4717720        <NA>         false  false          false
# 4717721        <NA>         false  false          false
# 4717722        <NA>         false  false          false
#
#                                                    Website Comments  \
# 0                                                     <NA>     <NA>
# 1                                                     <NA>     <NA>
# 2                                                     <NA>     <NA>
# 3                                                     <NA>     <NA>
# 4                                                     <NA>     <NA>
# ...                                                    ...      ...
# 4717718  https://karmagroup.com/find-destination/karma-...     <NA>
# 4717719                                               <NA>     <NA>
# 4717720                                               <NA>     <NA>
# 4717721                                               <NA>     <NA>
# 4717722                                               <NA>     <NA>
#
#             IP Address
# 0                 <NA>
# 1                 <NA>
# 2                 <NA>
# 3                 <NA>
# 4                 <NA>
# ...                ...
# 4717718  223.186.58.75
# 4717719           <NA>
# 4717720           <NA>
# 4717721           <NA>
# 4717722           <NA>
#
# [4717723 rows x 35 columns]

# %%
df_live = m.load_data_multiple(dir_path_live, file_name, cols)
count_data_awal = df_live.shape[0]
df_live = df_live.reindex(columns=cols)
df_live.shape[0]

df_live['Created Time'] = pd.to_datetime(df_live['Created Time'], format='%Y-%m-%d %H:%M:%S')
df_live['Arrival Date'] = pd.to_datetime(df_live['Arrival Date'], format='%Y-%m-%d')
df_live['Departure Date'] = pd.to_datetime(df_live['Departure Date'], format='%Y-%m-%d')
# fungsi errors cource untuk menhindari error jika value data date null atau kosong
# df['Birthdate'] = pd.to_datetime(df['Birthdate'], format='%Y-%m-%d', errors='coerce')
df_live.dtypes
df_live
# Out:
#                        Record Id        Created Time Created Date First Name  \
# 0       zcrm_3584690000000404602 2019-01-08 11:07:28   2021-07-21   Frederic
# 1       zcrm_3584690000000450071 2019-01-08 16:38:18         <NA>  Sebastian
# 2       zcrm_3584690000000450087 2019-01-08 16:38:18         <NA>    Siobhan
# 3       zcrm_3584690000000450106 2019-01-08 16:38:18         <NA>       Lisa
# 4       zcrm_3584690000000450109 2019-01-08 16:38:18         <NA>  Ana Maria
# ...                          ...                 ...          ...        ...
# 462403  zcrm_3584690000504265571 2024-08-05 17:37:48         <NA>      Goyal
# 462404  zcrm_3584690000504265572 2024-08-05 17:37:48         <NA>      Bryan
# 462405  zcrm_3584690000504265573 2024-08-05 17:37:48         <NA>        Oki
# 462406  zcrm_3584690000504265574 2024-08-05 17:37:48         <NA>       Arya
# 462407  zcrm_3584690000504265575 2024-08-05 17:37:48         <NA>       Info
#
#         Last Name                        Email           Phone Mobile  \
# 0           Bonin    fredericbonin79@gmail.com  +6281236100502   <NA>
# 1            Rach                         <NA>   +498914342111   <NA>
# 2       Gallagher  gallaghersiobhan@eircom.net    353879597603   <NA>
# 3       Ferkovich         lisajo2009@yahoo.com     14062394749   <NA>
# 4        Weileder     m.weileder@sonnenlink.de     15253234700   <NA>
# ...           ...                          ...             ...    ...
# 462403  Madhurima                         <NA>    919986885250   <NA>
# 462404    Whiting                         <NA>    447931789709   <NA>
# 462405  Ramadhana                         <NA>     62811150700   <NA>
# 462406     Wijaya                         <NA>   6285738679736   <NA>
# 462407        Bri                         <NA>   6281393445510   <NA>
#
#          Birthdate Year of Birth  ...  Lead Locations  \
# 0       1981-10-03          1981  ...   Karma Kandara
# 1       1982-04-20          1982  ...   Karma Bavaria
# 2       1973-03-14          1973  ...   Karma Bavaria
# 3       1963-07-08          1963  ...   Karma Bavaria
# 4             <NA>          <NA>  ...   Karma Bavaria
# ...            ...           ...  ...             ...
# 462403        <NA>          <NA>  ...  Karma Jimbaran
# 462404        <NA>          <NA>  ...  Karma Jimbaran
# 462405        <NA>          <NA>  ...  Karma Jimbaran
# 462406        <NA>          <NA>  ...  Karma Jimbaran
# 462407        <NA>          <NA>  ...  Karma Jimbaran
#
#                 Lead Source Description Lead Regions Lead Status  \
# 0                                 KAREN         SEAP    New Lead
# 1                                  <NA>    UK/Europe    New Lead
# 2                                  <NA>    UK/Europe    New Lead
# 3                                  <NA>    UK/Europe    New Lead
# 4       MICE Contacts from Ioanna email    UK/Europe    New Lead
# ...                                 ...          ...         ...
# 462403                             <NA>         <NA>    New Lead
# 462404                             <NA>         <NA>    New Lead
# 462405                             <NA>         <NA>    New Lead
# 462406                             <NA>         <NA>    New Lead
# 462407                             <NA>         <NA>    New Lead
#
#        Email Opt Out Opt In GDPR Compliant Website Comments IP Address
# 0              false  false          false    <NA>     <NA>       <NA>
# 1               true  false          false    <NA>     <NA>       <NA>
# 2              false   true           true    <NA>     <NA>       <NA>
# 3               true  false          false    <NA>     <NA>       <NA>
# 4              false   true           true    <NA>     <NA>       <NA>
# ...              ...    ...            ...     ...      ...        ...
# 462403         false  false          false    <NA>     <NA>       <NA>
# 462404         false  false          false    <NA>     <NA>       <NA>
# 462405         false  false          false    <NA>     <NA>       <NA>
# 462406         false  false          false    <NA>     <NA>       <NA>
# 462407         false  false          false    <NA>     <NA>       <NA>
#
# [462408 rows x 35 columns]

# %%
df = pd.concat([df_all,df_old,df_live])
df
# Out:
#                        Record Id        Created Time Created Date First Name  \
# 0       zcrm_3584690000000404058 2019-01-07 15:08:38   2019-01-06   Nicholas
# 1       zcrm_3584690000000404059 2019-01-07 15:08:38   2019-01-06       Liao
# 2       zcrm_3584690000000404060 2019-01-07 15:08:38   2019-01-06    Vedanta
# 3       zcrm_3584690000000404065 2019-01-07 15:08:38   2019-01-06      Aidai
# 4       zcrm_3584690000000404068 2019-01-07 15:08:38   2019-01-06      Ardra
# ...                          ...                 ...          ...        ...
# 462403  zcrm_3584690000504265571 2024-08-05 17:37:48         <NA>      Goyal
# 462404  zcrm_3584690000504265572 2024-08-05 17:37:48         <NA>      Bryan
# 462405  zcrm_3584690000504265573 2024-08-05 17:37:48         <NA>        Oki
# 462406  zcrm_3584690000504265574 2024-08-05 17:37:48         <NA>       Arya
# 462407  zcrm_3584690000504265575 2024-08-05 17:37:48         <NA>       Info
#
#         Last Name                       Email           Phone          Mobile  \
# 0            Wood  1230woodnicholas@gmail.com     61438600845            <NA>
# 1            Yuan            158066546@qq.com   8618718399923            <NA>
# 2        Abhiyoga  abhiyoga.vedanta@gmail.com   6282146524550            <NA>
# 3       Atakanova      aidai.nurbek@gmail.com    996779641590            <NA>
# 4           Ardra  aliefardraqariru@gmail.com  +6282139300818  +6282139300818
# ...           ...                         ...             ...             ...
# 462403  Madhurima                        <NA>    919986885250            <NA>
# 462404    Whiting                        <NA>    447931789709            <NA>
# 462405  Ramadhana                        <NA>     62811150700            <NA>
# 462406     Wijaya                        <NA>   6285738679736            <NA>
# 462407        Bri                        <NA>   6281393445510            <NA>
#
#          Birthdate Year of Birth  ... Lead Regions Lead Status Booking Status  \
# 0             <NA>          <NA>  ...         SEAP    New Lead           <NA>
# 1             <NA>          <NA>  ...        Other    New Lead           <NA>
# 2       2000-07-05          2000  ...         SEAP    New Lead           <NA>
# 3       1997-02-05          1997  ...    UK/Europe    New Lead           <NA>
# 4       2005-01-20          2005  ...         SEAP    New Lead           <NA>
# ...            ...           ...  ...          ...         ...            ...
# 462403        <NA>          <NA>  ...         <NA>    New Lead           <NA>
# 462404        <NA>          <NA>  ...         <NA>    New Lead           <NA>
# 462405        <NA>          <NA>  ...         <NA>    New Lead           <NA>
# 462406        <NA>          <NA>  ...         <NA>    New Lead           <NA>
# 462407        <NA>          <NA>  ...         <NA>    New Lead           <NA>
#
#        BookRef Email Opt Out Opt In GDPR Compliant Website Comments IP Address
# 0         <NA>          <NA>   <NA>           <NA>    <NA>     <NA>       <NA>
# 1         <NA>          <NA>   <NA>           <NA>    <NA>     <NA>       <NA>
# 2         <NA>          <NA>   <NA>           <NA>    <NA>     <NA>       <NA>
# 3         <NA>          <NA>   <NA>           <NA>    <NA>     <NA>       <NA>
# 4         <NA>          <NA>   <NA>           <NA>    <NA>     <NA>       <NA>
# ...        ...           ...    ...            ...     ...      ...        ...
# 462403    <NA>         false  false          false    <NA>     <NA>       <NA>
# 462404    <NA>         false  false          false    <NA>     <NA>       <NA>
# 462405    <NA>         false  false          false    <NA>     <NA>       <NA>
# 462406    <NA>         false  false          false    <NA>     <NA>       <NA>
# 462407    <NA>         false  false          false    <NA>     <NA>       <NA>
#
# [15146114 rows x 35 columns]

# %%
df.loc[df['Email'] == email]
# Out:
#                        Record Id        Created Time Created Date First Name  \
# 114578  zcrm_3584690000006037729 2019-04-02 02:23:47   2015-03-11       <NA>
# 111283  zcrm_3584690000006037729 2019-04-02 02:23:47   2015-03-11       <NA>
# 54555   zcrm_3584690000006037729 2019-04-02 02:23:47   2015-03-11       <NA>
#
#        Last Name                  Email Phone Mobile Birthdate Year of Birth  \
# 114578   Zzangss  zzangss75@hotmail.com  <NA>   <NA>      <NA>          <NA>
# 111283   Zzangss  zzangss75@hotmail.com  <NA>   <NA>      <NA>          <NA>
# 54555    Zzangss  zzangss75@hotmail.com  <NA>   <NA>      <NA>          <NA>
#
#         ... Lead Regions Lead Status Booking Status BookRef Email Opt Out  \
# 114578  ...        Other        <NA>           <NA>    <NA>          <NA>
# 111283  ...        Other        <NA>           <NA>    <NA>         false
# 54555   ...        Other        <NA>           <NA>    <NA>         false
#
#        Opt In GDPR Compliant Website Comments IP Address
# 114578   <NA>           <NA>    <NA>     <NA>       <NA>
# 111283   true          false    <NA>     <NA>       <NA>
# 54555    true          false    <NA>     <NA>       <NA>
#
# [3 rows x 35 columns]

# %%
df.drop_duplicates(subset=['Record Id'], inplace=True)
df.reset_index(drop=True, inplace=True)
count_data_awal = df.shape[0]
df
# Out:
#                         Record Id        Created Time Created Date First Name  \
# 0        zcrm_3584690000000404058 2019-01-07 15:08:38   2019-01-06   Nicholas
# 1        zcrm_3584690000000404059 2019-01-07 15:08:38   2019-01-06       Liao
# 2        zcrm_3584690000000404060 2019-01-07 15:08:38   2019-01-06    Vedanta
# 3        zcrm_3584690000000404065 2019-01-07 15:08:38   2019-01-06      Aidai
# 4        zcrm_3584690000000404068 2019-01-07 15:08:38   2019-01-06      Ardra
# ...                           ...                 ...          ...        ...
# 9991089  zcrm_3584690000504265571 2024-08-05 17:37:48         <NA>      Goyal
# 9991090  zcrm_3584690000504265572 2024-08-05 17:37:48         <NA>      Bryan
# 9991091  zcrm_3584690000504265573 2024-08-05 17:37:48         <NA>        Oki
# 9991092  zcrm_3584690000504265574 2024-08-05 17:37:48         <NA>       Arya
# 9991093  zcrm_3584690000504265575 2024-08-05 17:37:48         <NA>       Info
#
#          Last Name                       Email           Phone  \
# 0             Wood  1230woodnicholas@gmail.com     61438600845
# 1             Yuan            158066546@qq.com   8618718399923
# 2         Abhiyoga  abhiyoga.vedanta@gmail.com   6282146524550
# 3        Atakanova      aidai.nurbek@gmail.com    996779641590
# 4            Ardra  aliefardraqariru@gmail.com  +6282139300818
# ...            ...                         ...             ...
# 9991089  Madhurima                        <NA>    919986885250
# 9991090    Whiting                        <NA>    447931789709
# 9991091  Ramadhana                        <NA>     62811150700
# 9991092     Wijaya                        <NA>   6285738679736
# 9991093        Bri                        <NA>   6281393445510
#
#                  Mobile   Birthdate Year of Birth  ... Lead Regions  \
# 0                  <NA>        <NA>          <NA>  ...         SEAP
# 1                  <NA>        <NA>          <NA>  ...        Other
# 2                  <NA>  2000-07-05          2000  ...         SEAP
# 3                  <NA>  1997-02-05          1997  ...    UK/Europe
# 4        +6282139300818  2005-01-20          2005  ...         SEAP
# ...                 ...         ...           ...  ...          ...
# 9991089            <NA>        <NA>          <NA>  ...         <NA>
# 9991090            <NA>        <NA>          <NA>  ...         <NA>
# 9991091            <NA>        <NA>          <NA>  ...         <NA>
# 9991092            <NA>        <NA>          <NA>  ...         <NA>
# 9991093            <NA>        <NA>          <NA>  ...         <NA>
#
#         Lead Status Booking Status BookRef Email Opt Out Opt In  \
# 0          New Lead           <NA>    <NA>          <NA>   <NA>
# 1          New Lead           <NA>    <NA>          <NA>   <NA>
# 2          New Lead           <NA>    <NA>          <NA>   <NA>
# 3          New Lead           <NA>    <NA>          <NA>   <NA>
# 4          New Lead           <NA>    <NA>          <NA>   <NA>
# ...             ...            ...     ...           ...    ...
# 9991089    New Lead           <NA>    <NA>         false  false
# 9991090    New Lead           <NA>    <NA>         false  false
# 9991091    New Lead           <NA>    <NA>         false  false
# 9991092    New Lead           <NA>    <NA>         false  false
# 9991093    New Lead           <NA>    <NA>         false  false
#
#         GDPR Compliant Website Comments IP Address
# 0                 <NA>    <NA>     <NA>       <NA>
# 1                 <NA>    <NA>     <NA>       <NA>
# 2                 <NA>    <NA>     <NA>       <NA>
# 3                 <NA>    <NA>     <NA>       <NA>
# 4                 <NA>    <NA>     <NA>       <NA>
# ...                ...     ...      ...        ...
# 9991089          false    <NA>     <NA>       <NA>
# 9991090          false    <NA>     <NA>       <NA>
# 9991091          false    <NA>     <NA>       <NA>
# 9991092          false    <NA>     <NA>       <NA>
# 9991093          false    <NA>     <NA>       <NA>
#
# [9991094 rows x 35 columns]

# %%
path = r'G:\.shortcut-targets-by-id\0B_d3smBjzo04eXpvS1NXTWF2RVE\_BOOKING\Booking By Year\FlyBuy Booking Data (BGAU & BGID & KE).xlsx'
df_booking = pd.read_excel(path, dtype='string', sheet_name='BOOKING_BGAU_BGID_KE')

path = r'G:\.shortcut-targets-by-id\0B_d3smBjzo04UUNBME5GOVhoMjA\_ODYSSEY\Phone Members.xlsx'
df_phone = pd.read_excel(path, dtype='string', sheet_name='Sheet1')

path = r'G:\.shortcut-targets-by-id\0B_d3smBjzo04UUNBME5GOVhoMjA\_ODYSSEY\Email Members.xlsx'
df_email = pd.read_excel(path, dtype='string', sheet_name='Sheet1')

# %%
zoho_filter = fil.user_req(df)
zoho_df = df.loc[zoho_filter].copy() # menggunakan copy untuk menghindari setting copy warning
zoho_df.reset_index(drop=True, inplace=True)
count_filter_awal = zoho_df.shape[0]

# zoho_df.to_excel(r'C:\Users\fajar\Documents\Python\Data\test_leads.xlsx', index=False)
# mengisi kolom <NA> dengan value string 'empty' supaya mudah mengecek data member dan booking dengan isin

zoho_df.fillna('empty', inplace=True)
zoho_df.sort_values('Created Time', ascending=True)
# Out:
#                   Record Id        Created Time Created Date First Name  \
# 0  zcrm_3584690000006037729 2019-04-02 02:23:47   2015-03-11      empty
#
#   Last Name                  Email  Phone Mobile Birthdate Year of Birth  ...  \
# 0   Zzangss  zzangss75@hotmail.com  empty  empty     empty         empty  ...
#
#   Lead Regions Lead Status Booking Status BookRef Email Opt Out Opt In  \
# 0        Other       empty          empty   empty         empty  empty
#
#   GDPR Compliant Website Comments IP Address
# 0          empty   empty    empty      empty
#
# [1 rows x 35 columns]

# %% [markdown]
# # ====================== Awal Filter Umum ======================

# %%
# data phone, mobile dam email member yang ada di master data (wash member)

m.clean_number(zoho_df, 'Phone')
m.clean_number(zoho_df, 'Mobile')
m.replace_not_valid_to_empty(zoho_df, 'Phone')
m.replace_not_valid_to_empty(zoho_df, 'Mobile')
zoho_df['Email'] = m.lowercase(zoho_df, 'Email')
m.clean_space(zoho_df, 'Email')
m.clean_not_valid_email_format(zoho_df, 'Email')

m.clean_number(df_booking, 'Phone1')
m.clean_number(df_booking, 'Mobile')
df_booking['Email'] = m.lowercase(df_booking, 'Email')
m.clean_space(df_booking, 'Email')
m.clean_not_valid_email_format(df_booking, 'Email')

m.clean_number(df_phone, 'Mobile')

df_email['Email'] = m.lowercase(df_email, 'Email')
m.clean_space(df_email, 'Email')
m.clean_not_valid_email_format(df_email, 'Email')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [11], line 17
#      14 m.clean_space(df_booking, 'Email')
#      15 m.clean_not_valid_email_format(df_booking, 'Email')
# ---> 17 m.clean_number(df_phone, 'Mobile')
#      19 df_email['Email'] = m.lowercase(df_email, 'Email')
#      20 m.clean_space(df_email, 'Email')
#
# File c:\Users\fajar\Documents\Python\Task Offline\zoho_data_app\main_module.py:67, in clean_number(df, df_columns)
#      65 def clean_number(df, df_columns):
# ---> 67   df[df_columns].replace(' ','', regex=True, inplace=True)
#      68   df[df_columns].replace('[^0-9]','', regex=True, inplace=True)
#      70   return df[df_columns]
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\util\_decorators.py:317, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     311 if len(args) > num_allow_args:
#     312     warnings.warn(
#     313         msg.format(arguments=arguments),
#     314         FutureWarning,
#     315         stacklevel=find_stack_level(inspect.currentframe()),
#     316     )
# --> 317 return func(*args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\core\series.py:5383, in Series.replace(self, to_replace, value, inplace, limit, regex, method)
#    5365 @deprecate_nonkeyword_arguments(
#    5366     version=None, allowed_args=["self", "to_replace", "value"]
#    5367 )
#    (...)
#    5381     method: Literal["pad", "ffill", "bfill"] | lib.NoDefault = lib.no_default,
#    5382 ) -> Series | None:
# -> 5383     return super().replace(
#    5384         to_replace=to_replace,
#    5385         value=value,
#    5386         inplace=inplace,
#    5387         limit=limit,
#    5388         regex=regex,
#    5389         method=method,
#    5390     )
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\util\_decorators.py:317, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     311 if len(args) > num_allow_args:
#     312     warnings.warn(
#     313         msg.format(arguments=arguments),
#     314         FutureWarning,
#     315         stacklevel=find_stack_level(inspect.currentframe()),
#     316     )
# --> 317 return func(*args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\core\generic.py:7279, in NDFrame.replace(self, to_replace, value, inplace, limit, regex, method)
#    7277 regex = should_use_regex(regex, to_replace)
#    7278 if regex:
# -> 7279     new_data = self._mgr.replace_regex(
#    7280         to_replace=to_replace,
#    7281         value=value,
#    7282         inplace=inplace,
#    7283     )
#    7284 else:
#    7285     new_data = self._mgr.replace(
#    7286         to_replace=to_replace, value=value, inplace=inplace
#    7287     )
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\core\internals\managers.py:473, in BaseBlockManager.replace_regex(self, **kwargs)
#     472 def replace_regex(self, **kwargs):
# --> 473     return self.apply("_replace_regex", **kwargs)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\core\internals\managers.py:348, in BaseBlockManager.apply(self, f, align_keys, ignore_failures, **kwargs)
#     346         applied = b.apply(f, **kwargs)
#     347     else:
# --> 348         applied = getattr(b, f)(**kwargs)
#     349 except (TypeError, NotImplementedError):
#     350     if not ignore_failures:
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\core\internals\blocks.py:672, in Block._replace_regex(self, to_replace, value, inplace, convert, mask)
#     669 rx = re.compile(to_replace)
#     671 new_values = self.values if inplace else self.values.copy()
# --> 672 replace_regex(new_values, rx, value, mask)
#     674 block = self.make_block(new_values)
#     675 return block.convert(numeric=False, copy=False)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\core\array_algos\replace.py:159, in replace_regex(values, rx, value, mask)
#     156 f = np.vectorize(re_replacer, otypes=[np.object_])
#     158 if mask is None:
# --> 159     values[:] = f(values)
#     160 else:
#     161     values[mask] = f(values[mask])
#
# File ~\AppData\Roaming\Python\Python310\site-packages\numpy\lib\function_base.py:2328, in vectorize.__call__(self, *args, **kwargs)
#    2325     vargs = [args[_i] for _i in inds]
#    2326     vargs.extend([kwargs[_n] for _n in names])
# -> 2328 return self._vectorize_call(func=func, args=vargs)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\numpy\lib\function_base.py:2411, in vectorize._vectorize_call(self, func, args)
#    2408 # Convert args to object arrays first
#    2409 inputs = [asanyarray(a, dtype=object) for a in args]
# -> 2411 outputs = ufunc(*inputs)
#    2413 if ufunc.nout == 1:
#    2414     res = asanyarray(outputs, dtype=otypes[0])
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\core\array_algos\replace.py:150, in replace_regex.<locals>.re_replacer(s)
#     145             return s
#     147 else:
#     148     # value is guaranteed to be a string here, s can be either a string
#     149     # or null if it's null it gets returned
# --> 150     def re_replacer(s):
#     151         if is_re(rx) and isinstance(s, str):
#     152             return rx.sub(value, s)
#
# KeyboardInterrupt:

# %%
zoho_df.loc[zoho_df['Phone']=='']
# Out:
# Empty DataFrame
# Columns: [Record Id, Created Time, Created Date, First Name, Last Name, Email, Phone, Mobile, Birthdate, Year of Birth, Street, Street2, City, State, Country, Nationality, Departure Date, Arrival Date, Card Type, Marital Status, Lead Brand, Lead Sub-Brand, Lead Source, Lead Locations, Lead Source Description, Lead Regions, Lead Status, Booking Status, BookRef, Email Opt Out, Opt In, GDPR Compliant, Website, Comments]
# Index: []
#
# [0 rows x 34 columns]

# %%
count_deleted_wrong_format = m.delete_email_wrong_format(zoho_df, 'Email')
count_after_deleted_wrong_format = zoho_df.shape[0]

# %%
# hitung jumlah duplicate
count_duplicate_general = zoho_df.loc[zoho_df.duplicated(subset=['Phone','Email', 'Mobile'])].shape[0]

zoho_df.loc[zoho_df.duplicated(subset=['Phone','Email'])]
# Out:
#                       Record Id        Created Time Created Date  \
# 61     zcrm_3584690000000462533 2019-01-09 11:11:28        empty
# 19822  zcrm_3584690000007587628 2019-04-02 06:13:56   2017-01-16
# 36986  zcrm_3584690000009897230 2019-04-02 11:59:09   2000-01-01
# 49856  zcrm_3584690000024579388 2019-04-07 15:29:28        empty
# 50017  zcrm_3584690000027868823 2019-04-28 19:09:35        empty
# ...                         ...                 ...          ...
# 56093  zcrm_3584690000498865287 2024-06-14 14:25:22        empty
# 56102  zcrm_3584690000499041168 2024-06-16 12:21:40        empty
# 56108  zcrm_3584690000499823664 2024-06-24 15:25:28        empty
# 56111  zcrm_3584690000499884136 2024-06-23 20:40:13   2024-06-23
# 56112  zcrm_3584690000499974416 2024-06-24 15:29:53        empty
#
#                             First Name                Last Name  \
# 61                                 Min                   Li Lee
# 19822                            Binod                    Kumar
# 36986                        Azumi Zul                    empty
# 49856                        Elisabeth                      Cox
# 50017                        Mariawaty                Mariawaty
# ...                                ...                      ...
# 56093                       Khoo Kwang                  Ulysses
# 56102                          Harshal                    Joshi
# 56108  Rayyan Revinnath Tengga Daram &  Fatimah Jamal Sandairan
# 56111                              Eli                     Weir
# 56112                      Subramaniam                 Muniandy
#
#                               Email         Phone      Mobile Birthdate  \
# 61                            empty  602035640799       empty     empty
# 19822             manju@treamyk.com   60193235960       empty     empty
# 36986           zaarnis@hotmail.com    6063027629       empty     empty
# 49856                         empty    6564699780       empty     empty
# 50017           mariatjoe@yahoo.com  601115417735       empty     empty
# ...                             ...           ...         ...       ...
# 56093         ulysseskhoo@gmail.com    6594375261  6596652223     empty
# 56102        jharshal29jo@gmail.com    6591039703       empty     empty
# 56108  revinnath.personal@gmail.com   60173464207       empty     empty
# 56111            eli@weirwhanau.com         empty       empty     empty
# 56112       subramuni6633@gmail.com   60124730660       empty     empty
#
#       Year of Birth  ...                            Lead Source Description  \
# 61            empty  ...                                              empty
# 19822         empty  ...                             Black Hole Consolidate
# 36986         empty  ...          MALAYSIAN ASSOCIATION IN HONG KONG - SONI
# 49856         empty  ...                                              empty
# 50017          1978  ...  BGID | Teleperformance | w4apr19 | Free stay m...
# ...             ...  ...                                                ...
# 56093         empty  ...                                          Viewpoint
# 56102         empty  ...                     Chat with your Karma Concierge
# 56108         empty  ...                                          Viewpoint
# 56111         empty  ...                                              empty
# 56112         empty  ...                                          Viewpoint
#
#       Lead Regions Lead Status Booking Status  BookRef Email Opt Out Opt In  \
# 61           Other    New Lead          empty    empty         empty  empty
# 19822        Other       empty          empty    empty         empty  empty
# 36986        Other       empty          empty    empty         empty  empty
# 49856        Other    New Lead          empty    empty         empty  empty
# 50017        Other       empty          empty    empty         empty  empty
# ...            ...         ...            ...      ...           ...    ...
# 56093        empty       empty    Checked-Out  2381476         false   true
# 56102        Other       empty          empty    empty         false  false
# 56108        empty       empty    Checked-Out  2293889         false   true
# 56111        empty    New Lead          empty    empty         false  false
# 56112        empty       empty    Checked-Out  2475345         false   true
#
#       GDPR Compliant                          Website Comments
# 61             empty                            empty    empty
# 19822          empty                            empty    empty
# 36986          empty                            empty    empty
# 49856          empty                            empty    empty
# 50017          empty                            empty    empty
# ...              ...                              ...      ...
# 56093          false                            empty    empty
# 56102          false  https://karmaai.karmagroup.com/    empty
# 56108          false                            empty    empty
# 56111          false                            empty    empty
# 56112          false                            empty    empty
#
# [552 rows x 34 columns]

# %%
zoho_df.drop_duplicates(subset=['Phone','Email', 'Mobile'], inplace=True)
zoho_df.reset_index(drop=True, inplace=True)

# hitung jumlah setelah value duplicate dihapus
count_after_dedup_duplicate = zoho_df.shape[0]

zoho_df
# Out:
#                       Record Id        Created Time Created Date First Name  \
# 0      zcrm_3584690000000404133 2019-01-07 15:08:38   2019-01-06   Johannes
# 1      zcrm_3584690000000404160 2019-01-07 15:08:38   2019-01-06   Philippa
# 2      zcrm_3584690000000404199 2019-01-07 15:08:38   2019-01-06          V
# 3      zcrm_3584690000000404452 2019-01-08 11:07:28   2019-01-03     Shigeo
# 4      zcrm_3584690000000404870 2019-01-08 11:07:30   2019-01-03       Hsbs
# ...                         ...                 ...          ...        ...
# 55631  zcrm_3584690000499165001 2024-06-17 14:42:23        empty     Angela
# 55632  zcrm_3584690000499443111 2024-06-18 23:47:02        empty       sals
# 55633  zcrm_3584690000499792076 2024-06-21 10:27:41        empty       Hahs
# 55634  zcrm_3584690000499836586 2024-06-24 15:20:40        empty       Loic
# 55635  zcrm_3584690000499860873 2024-06-24 15:31:48        empty    Yixiang
#
#        Last Name                          Email        Phone Mobile  \
# 0      Hauptmann          johannesh@hotmail.com   6590189726  empty
# 1       Spellman       philspellman@hotmail.com   6596515025  empty
# 2              H  vimidaminiharidasan@gmail.com   6596526640  empty
# 3       Kawasaki          shigeou1123@gmail.com   6597228507  empty
# 4          Babas                    ssd@sss.com   6593728273  empty
# ...          ...                            ...          ...    ...
# 55631        Tay      angela.wearnxin@gmail.com  60177595390  empty
# 55632      gupta           salonigaba@yahoo.com   6586062557  empty
# 55633      Hshhz                hshsj@gmail.com   6584160285  empty
# 55634     Hemard          loic.hemard@gmail.com   6598270507  empty
# 55635       Zhou              benkden@yahoo.com   6598319447  empty
#
#         Birthdate Year of Birth  ...  \
# 0      1982-05-19          1982  ...
# 1      1972-05-10          1972  ...
# 2           empty         empty  ...
# 3      1977-11-23          1977  ...
# 4           empty         empty  ...
# ...           ...           ...  ...
# 55631       empty         empty  ...
# 55632       empty         empty  ...
# 55633       empty         empty  ...
# 55634       empty         empty  ...
# 55635       empty         empty  ...
#
#                                  Lead Source Description Lead Regions  \
# 0                                                  empty        Other
# 1                                                  empty        Other
# 2                                                  empty        Other
# 3                                                  empty        Other
# 4                                                  empty        Other
# ...                                                  ...          ...
# 55631  Karma Kandara -Download Wedding Brochure at Ka...        Other
# 55632                          Timeshare Booking Request        Other
# 55633            Karma Beach VIP membership sign up 2023        Other
# 55634                                          Viewpoint        empty
# 55635                                          Viewpoint        empty
#
#       Lead Status Booking Status  BookRef Email Opt Out Opt In GDPR Compliant  \
# 0        New Lead          empty    empty         empty  empty          empty
# 1        New Lead          empty    empty         empty  empty          empty
# 2        New Lead          empty    empty         empty  empty          empty
# 3        New Lead          empty    empty         empty  empty          empty
# 4        New Lead          empty    empty         empty  empty          empty
# ...           ...            ...      ...           ...    ...            ...
# 55631       empty          empty    empty         false   true          false
# 55632       empty          empty    empty         false   true           true
# 55633       empty          empty    empty         false   true          false
# 55634       empty    Checked-Out  2456649         false   true          false
# 55635       empty    Checked-Out  2538889         false   true          false
#
#                                                  Website Comments
# 0                                                  empty    empty
# 1                                                  empty    empty
# 2                                                  empty    empty
# 3                                                  empty    empty
# 4                                                  empty    empty
# ...                                                  ...      ...
# 55631  https://karmagroup.com/weddings-at-karma-kanda...    empty
# 55632  https://karmagroup.com/find-destination/karma-...    empty
# 55633            https://karmagroup.com/karma-beach-vip/    empty
# 55634                                              empty    empty
# 55635                                              empty    empty
#
# [55636 rows x 34 columns]

# %%
# Cek leads test
test_leads = zoho_df.loc[
    
        zoho_df['Email'].str.contains('^test@', flags=re.I, regex=True) |
        zoho_df['Email'].str.contains('\+test', flags=re.I, regex=True) |
    
        zoho_df['First Name'].str.contains('^test$', flags=re.I, regex=True) |
        zoho_df['Last Name'].str.contains('^test$', flags=re.I, regex=True) |

        zoho_df['First Name'].str.contains('test 1', flags=re.I, regex=True) |
        zoho_df['Last Name'].str.contains('test 2', flags=re.I, regex=True)|
        zoho_df['First Name'].str.contains('test1', flags=re.I, regex=True) |
        zoho_df['Last Name'].str.contains('test2', flags=re.I, regex=True)|

        zoho_df['First Name'].str.contains(' test ', flags=re.I, regex=True) | 
        zoho_df['Last Name'].str.contains(' test ', flags=re.I, regex=True) | 
        zoho_df['Last Name'].str.contains(' test$', flags=re.I, regex=True)
    ]

count_leads_test = test_leads.shape[0]

# test_leads.to_excel(r'C:\Users\fajar\Documents\Python\Data\test_leads_2.xlsx', index=False)
test_leads
# Out:
#                       Record Id        Created Time Created Date First Name  \
# 53313  zcrm_3584690000305511893 2021-08-10 10:06:23        empty       Test
# 53722  zcrm_3584690000414940071 2022-12-05 13:17:30        empty       Test
# 53764  zcrm_3584690000418823383 2022-12-22 15:14:53        empty      Fajar
#
#       Last Name                             Email       Phone Mobile  \
# 53313   Booking        hazeline.furing@sojern.com    98745632  empty
# 53722      Test            testing-ads@google.com    12345678  empty
# 53764    Fatoni  fajar.fatoni+test@karmagroup.com  1234759984  empty
#
#       Birthdate Year of Birth  ... Lead Source Description Lead Regions  \
# 53313     empty         empty  ...                   empty        empty
# 53722     empty         empty  ...                   empty        empty
# 53764     empty         empty  ...                   empty        empty
#
#       Lead Status Booking Status BookRef Email Opt Out Opt In GDPR Compliant  \
# 53313       empty          empty   empty         empty  empty          empty
# 53722       empty          empty   empty         empty  empty          empty
# 53764    New Lead          empty   empty         empty  empty          empty
#
#       Website Comments
# 53313   empty    empty
# 53722   empty    empty
# 53764   empty    empty
#
# [3 rows x 34 columns]

# %%
zoho_df.drop(test_leads.index, inplace=True)
zoho_df.reset_index(drop=True, inplace=True)

count_after_dedup_test = zoho_df.shape[0]

# %%
# dnm_leads = zoho_df.loc[(zoho_df['Do Not Mail'] == 'true') | (zoho_df['Do Not Contact'] == 'true')]
# count_dnm = dnm_leads.shape[0]

# %%
# zoho_df.drop(dnm_leads.index, inplace=True)
# zoho_df.reset_index(drop=True, inplace=True)

# count_after_dedup_dnm = zoho_df.shape[0]

# %%
# Cek Email OTA
email_OTA = m.find_OTA(zoho_df, 'Email')
count_email_OTA = email_OTA.shape[0]
# email_OTA.to_excel(r'C:\Users\fajar\Documents\Python\Data\email_OTA.xlsx', index=False)

email_OTA
# Out:
#                       Record Id        Created Time Created Date  \
# 1173   zcrm_3584690000005994723 2019-04-02 02:19:27   2015-03-11
# 2064   zcrm_3584690000006445354 2019-04-02 03:57:45   2000-01-01
# 2423   zcrm_3584690000006463501 2019-04-02 03:59:28   2015-03-10
# 3736   zcrm_3584690000006523479 2019-04-02 04:05:30   2000-01-01
# 3739   zcrm_3584690000006523490 2019-04-02 04:05:30   2000-01-01
# 5358   zcrm_3584690000006595652 2019-04-02 04:12:49   2000-01-01
# 6652   zcrm_3584690000006654115 2019-04-02 04:19:23   2015-04-23
# 6738   zcrm_3584690000006656277 2019-04-02 04:19:38   2000-01-01
# 6774   zcrm_3584690000006658105 2019-04-02 04:19:50   2000-01-01
# 7344   zcrm_3584690000006686949 2019-04-02 04:22:59   2000-01-01
# 7345   zcrm_3584690000006686975 2019-04-02 04:22:59   2000-01-01
# 9937   zcrm_3584690000006798096 2019-04-02 04:36:00   2000-01-01
# 10097  zcrm_3584690000006804938 2019-04-02 04:36:50   2000-01-01
# 10557  zcrm_3584690000006822553 2019-04-02 04:38:59   2000-01-01
# 11441  zcrm_3584690000006860465 2019-04-02 04:44:01   2000-01-01
# 12454  zcrm_3584690000006905676 2019-04-02 04:49:38   2000-01-01
# 13707  zcrm_3584690000006964042 2019-04-02 04:56:45   2000-01-01
# 14383  zcrm_3584690000006994924 2019-04-02 05:00:58   2000-01-01
# 14424  zcrm_3584690000006996781 2019-04-02 05:01:14   2015-03-11
# 15109  zcrm_3584690000007025790 2019-04-02 05:05:29   2000-01-01
# 15370  zcrm_3584690000007036773 2019-04-02 05:07:01   2000-01-01
# 17343  zcrm_3584690000007122458 2019-04-02 05:20:04   2000-01-01
# 17344  zcrm_3584690000007122459 2019-04-02 05:20:04   2000-01-01
# 17757  zcrm_3584690000007152561 2019-04-02 05:24:22   2016-04-21
# 18658  zcrm_3584690000007330996 2019-04-02 05:45:54   2015-03-11
# 18823  zcrm_3584690000007342876 2019-04-02 05:46:59   2015-03-11
# 19176  zcrm_3584690000007371608 2019-04-02 05:49:38   2015-03-13
# 19581  zcrm_3584690000007420455 2019-04-02 05:56:16   2015-03-11
# 20127  zcrm_3584690000007590487 2019-04-02 06:14:12   2017-01-16
# 21563  zcrm_3584690000007604603 2019-04-02 06:15:33   2015-05-12
# 21778  zcrm_3584690000007606452 2019-04-02 06:15:42   2015-04-18
# 23519  zcrm_3584690000007658602 2019-04-02 06:27:00   2017-06-29
# 25330  zcrm_3584690000007880061 2019-04-02 06:50:30   2017-06-29
# 29867  zcrm_3584690000008073709 2019-04-02 07:14:51   2017-06-21
# 32374  zcrm_3584690000008538262 2019-04-02 08:13:32   2000-01-01
# 33505  zcrm_3584690000008668965 2019-04-02 08:28:06   2019-02-08
# 33706  zcrm_3584690000008731835 2019-04-02 09:13:16   2012-01-01
# 35272  zcrm_3584690000009311975 2019-04-02 10:24:17   2011-01-01
# 35276  zcrm_3584690000009313858 2019-04-02 10:24:33   2009-01-01
# 37412  zcrm_3584690000010080674 2019-04-02 12:33:52   2016-07-11
# 40970  zcrm_3584690000012083677 2019-04-02 15:46:26   2015-08-05
# 41250  zcrm_3584690000012265482 2019-04-02 16:03:38   2000-01-01
# 49866  zcrm_3584690000025157953 2019-04-09 21:51:45        empty
# 49888  zcrm_3584690000025158022 2019-04-09 21:51:45        empty
# 49895  zcrm_3584690000025158029 2019-04-09 21:51:45        empty
# 51092  zcrm_3584690000044531427 2019-06-13 16:08:39        empty
# 51099  zcrm_3584690000044531711 2019-06-13 16:08:42        empty
# 51103  zcrm_3584690000044531717 2019-06-13 16:08:42        empty
# 51119  zcrm_3584690000044531850 2019-06-13 16:08:42        empty
# 51148  zcrm_3584690000044532563 2019-06-13 16:08:48        empty
# 51164  zcrm_3584690000044532654 2019-06-13 16:08:48        empty
# 51174  zcrm_3584690000044532917 2019-06-13 16:08:51        empty
# 51176  zcrm_3584690000044532949 2019-06-13 16:08:51        empty
# 52117  zcrm_3584690000178433001 2020-04-07 20:00:42        empty
# 53798  zcrm_3584690000421287078 2023-01-07 18:54:23        empty
#
#               First Name                 Last Name  \
# 1173               Nopri                     Aries
# 2064            Norazran                  Bmohdnor
# 2423                Hock                       Goh
# 3736          Frederique                   Tourret
# 3739             Freddie                       Sim
# 5358               Jenny                      Wong
# 6652               Simon                    Graves
# 6738              Dennis                    Twchoo
# 6774                Siti  Majminshaikhsallehjalani
# 7344                Wang                   Shouzhi
# 7345            Gopinath                    Pillai
# 9937                Jeff              Radzuankasim
# 10097           Brigitte                        Ow
# 10557              David                       Lai
# 11441              Alice                       Lim
# 12454         Jacqueline                Limkahling
# 13707              Karin                       Lee
# 14383              Noran                     Ujang
# 14424            Luciano                 Paparelli
# 15109              Fabio                    Delisi
# 15370              Prema                  Muniandy
# 17343            Padmini        Narayanansivakumar
# 17344            Padmini                 Narayanan
# 17757              James                    Pelham
# 18658            Noredah                    Otiman
# 18823              empty                    Andrey
# 19176             Callie                       Tan
# 19581              Djony                         A
# 20127              empty                      Jada
# 21563              empty                     empty
# 21778               Jane                    Durham
# 23519               Rzzz                       Ali
# 25330           Norlizah               Soon Jahaya
# 29867              Kitty                     Chong
# 32374               Geoh                   Coombes
# 33505            Anthony                       Lee
# 33706     Shekhar Basnet                     empty
# 35272     Om Prakash Rao                     empty
# 35276   Bhuvana Ramanand                     empty
# 37412  M Balasubramanian                     empty
# 40970        Paramasvari                     empty
# 41250      Pradeep Kumar                     empty
# 49866            Stephen                     Cheah
# 49888               Fara                   Nokmang
# 49895              Leong                       Low
# 51092                Woo               K M (Jimmy)
# 51099             Eileen                       Lim
# 51103             Elaine                       Lim
# 51119               Lynn                        Ng
# 51148             Eileen                       Tan
# 51164                Kar                 Wei Kwong
# 51174             Hanson                      Yong
# 51176                Amy                       Zuo
# 52117              empty                     Jowee
# 53798             Judith                von Prockl
#
#                                                    Email        Phone  \
# 1173                       summertourtravel@yahoo.com.sg        empty
# 2064                             roy2000tour@hotmail.com  60341061900
# 2423                             beltraveltour@yahoo.com   6062822712
# 3736                      frederique.tourret@clubmed.com   6568300821
# 3739                        fredsim@creativetours.com.sg   6563203209
# 5358                          jenny@creativetours.com.sg   6563203226
# 6652                    simon.graves@pagoda-partners.com     90664607
# 6738                           dchoo@holidaytours.com.sg   6562354222
# 6774                            smj@tourismpenang.gov.my   6042620202
# 7344                          tour@singachinatrvl.com.sg   6565329988
# 7345                        tourmasters@tour-masters.com   6562957770
# 9937                               jeff@skyzonetours.com  60321187988
# 10097                        bodycontours@pacific.net.sg        empty
# 10557                          davidlai@skyzonetours.com  60321429288
# 11441                         alice@creativetours.com.sg   6563203220
# 12454                      jackielim@holidaytours.com.my  60327191833
# 13707                                  klee@toureast.net   6562382894
# 14383                               noran@tourism.gov.my  60326935188
# 14424                               luk@originaltour.net        empty
# 15109                     fabio.delisi@synergy-tours.com  60321633833
# 15370                               prema@tourlandmy.com  60379554753
# 17343                        padmini@millenium-tours.com   6562956930
# 17344                       padmini@millennium-tours.com   6562956930
# 17757                    james@culturebitesfoodtours.com   6597694845
# 18658                           noredah@sabahtourism.com        empty
# 18823                               lolita@vista-tour.ru        empty
# 19176                     callie.tan@holidaytours.com.my        empty
# 19581                                 djony@bmbtours.com     90012013
# 20127                         jacquelitourneur@yahoo.com        empty
# 21563                             wiwit@amythastours.com        empty
# 21778                                 tours@okavango.com        empty
# 23519                                   tours@hin.com.my        empty
# 25330                            norlizah@tourism.gov.my        empty
# 29867                            deluxetours@hotmail.com        empty
# 32374                            geoff@tourdecure.com.au   6581386865
# 33505                             owrdreamtour@gmail.com   6598506066
# 33706  acmetours@wlink.com.np/fivetravel@streamyx.com...  60320267878
# 35272                       omprakashr@airlinkstours.com   6562995664
# 35276                         india@millennium-tours.com   6562956930
# 37412                               info@moulistours.com        empty
# 40970                    tours@kualalampurbadgrttown.com  60193790571
# 41250                    pradeep@asianfamoustours.com.my  60342581018
# 49866                       scheah@tourism.australia.com  60326111143
# 49888                           fnokmang@fastbooking.com   6562332730
# 49895                              ellow@fastbooking.com   6562232730
# 51092                                econtours@gmail.com     62613218
# 51099                            eileen.lim@hanatour.com   6562224501
# 51103                   outbound.sales2@skyzonetours.com  60321187888
# 51119                              jjlynnng@hanatour.com   6562224501
# 51148                                 eileen@atgtours.sg   6564382811
# 51164                    karwei.kwong@holidatours.com.my  60362866200
# 51174                                   hanson@mtg.tours   6569061089
# 51176                              amyzuo@satours.com.sg     65352611
# 52117                                jowee.soh@agoda.com        empty
# 53798                               jp@gourmetontour.com   6587277080
#
#             Mobile   Birthdate Year of Birth  ...  \
# 1173         empty       empty         empty  ...
# 2064         empty       empty         empty  ...
# 2423   60126822712       empty         empty  ...
# 3736         empty       empty         empty  ...
# 3739         empty       empty         empty  ...
# 5358         empty       empty         empty  ...
# 6652      98184475       empty         empty  ...
# 6738    6562382800       empty         empty  ...
# 6774         empty       empty         empty  ...
# 7344         empty       empty         empty  ...
# 7345         empty       empty         empty  ...
# 9937   60321187999       empty         empty  ...
# 10097        empty       empty         empty  ...
# 10557        empty       empty         empty  ...
# 11441        empty       empty         empty  ...
# 12454        empty       empty         empty  ...
# 13707        empty       empty         empty  ...
# 14383        empty       empty         empty  ...
# 14424        empty       empty         empty  ...
# 15109        empty       empty         empty  ...
# 15370        empty       empty         empty  ...
# 17343        empty       empty         empty  ...
# 17344        empty       empty         empty  ...
# 17757        empty  1978-10-03          1978  ...
# 18658        empty       empty         empty  ...
# 18823        empty       empty         empty  ...
# 19176        empty       empty         empty  ...
# 19581        empty       empty         empty  ...
# 20127        empty       empty         empty  ...
# 21563        empty       empty         empty  ...
# 21778        empty       empty         empty  ...
# 23519        empty       empty         empty  ...
# 25330        empty       empty         empty  ...
# 29867        empty       empty         empty  ...
# 32374  61294373225       empty         empty  ...
# 33505        empty       empty         empty  ...
# 33706   6562960317       empty         empty  ...
# 35272   6596581214       empty         empty  ...
# 35276   9444393595       empty         empty  ...
# 37412        empty       empty         empty  ...
# 40970        empty       empty         empty  ...
# 41250        empty       empty         empty  ...
# 49866        empty       empty         empty  ...
# 49888   6591264917       empty         empty  ...
# 49895   6597953436       empty         empty  ...
# 51092        empty       empty         empty  ...
# 51099   6596731516       empty         empty  ...
# 51103        empty       empty         empty  ...
# 51119   6597450803       empty         empty  ...
# 51148   6585118313       empty         empty  ...
# 51164        empty       empty         empty  ...
# 51174   6598580389       empty         empty  ...
# 51176   6565013927       empty         empty  ...
# 52117        empty       empty         empty  ...
# 53798        empty       empty         empty  ...
#
#                           Lead Source Description Lead Regions Lead Status  \
# 1173                                        empty        Other       empty
# 2064   Karma list email for Bhanu - International        Other       empty
# 2423                                    Singapore        Other       empty
# 3736           Karma list email for Bhanu - Karma        Other       empty
# 3739           Karma list email for Bhanu - Karma        Other       empty
# 5358           Karma list email for Bhanu - Karma        Other       empty
# 6652                                    Belvedere        Other       empty
# 6738                      KARMA DATA - BOOTH DATA        Other       empty
# 6774   Karma list email for Bhanu - International        Other       empty
# 7344           Karma list email for Bhanu - Karma        Other       empty
# 7345           Karma list email for Bhanu - Karma        Other       empty
# 9937   Karma list email for Bhanu - International        Other       empty
# 10097          Karma list email for Bhanu - Karma        Other       empty
# 10557  Karma list email for Bhanu - International        Other       empty
# 11441          Karma list email for Bhanu - Karma        Other       empty
# 12454  Karma list email for Bhanu - International        Other       empty
# 13707  Karma list email for Bhanu - International        Other       empty
# 14383  Karma list email for Bhanu - International        Other       empty
# 14424                   Business Card Competition        Other       empty
# 15109  Karma list email for Bhanu - International        Other       empty
# 15370  Karma list email for Bhanu - International        Other       empty
# 17343  Karma list email for Bhanu - International        Other       empty
# 17344          Karma list email for Bhanu - Karma        Other       empty
# 17757                       Event Chairman Invite        Other       empty
# 18658              Perth Holiday Travel Expo 2010        Other       empty
# 18823                    Restaurant Survey (Rosy)        Other       empty
# 19176                                       empty        Other       empty
# 19581            DATA Jakarta_all_survey NOV 2012        Other       empty
# 20127                      Black Hole Consolidate        Other       empty
# 21563                   Black All Database Mergin        Other       empty
# 21778                      Black Hole Consolidate        Other       empty
# 23519                                       empty        Other       empty
# 25330                                       empty        Other       empty
# 29867                                       empty        Other       empty
# 32374                                  Guest exit        Other       empty
# 33505                                       empty        Other       empty
# 33706                               TTF HYDERABAD        Other       empty
# 35272                               TTF BANGALORE        Other       empty
# 35276                                IITM CHENNAI        Other       empty
# 37412             GULF LEADS PRITI 2016 - BATCH 2        Other       empty
# 40970                         IITM BANGALORE 2015        Other       empty
# 41250             ARABIAN TRAVEL MART 2007(UMMAR)        Other       empty
# 49866                                       Media        Other    New Lead
# 49888                                   Singapore        Other    New Lead
# 49895                                   Singapore        Other    New Lead
# 51092                                       empty        Other    New Lead
# 51099                 Yemi - 30%, TA Asian market        Other    New Lead
# 51103                                       empty        Other    New Lead
# 51119                 Yemi - 30%, TA Asian market        Other    New Lead
# 51148                 Yemi - 30%, TA Asian market        Other    New Lead
# 51164                                       empty        Other    New Lead
# 51174                 Yemi - 30%, TA Asian market        Other    New Lead
# 51176                 Yemi - 30%, TA Asian market        Other    New Lead
# 52117    Karma Resorts Reservations | Webchat Web        Other       empty
# 53798                             Form Contact Us         SEAP       empty
#
#       Booking Status BookRef Email Opt Out Opt In GDPR Compliant Website  \
# 1173           empty   empty         empty  empty          empty   empty
# 2064           empty   empty         empty  empty          empty   empty
# 2423           empty   empty         empty  empty          empty   empty
# 3736           empty   empty         empty  empty          empty   empty
# 3739           empty   empty         empty  empty          empty   empty
# 5358           empty   empty         empty  empty          empty   empty
# 6652           empty   empty         empty  empty          empty   empty
# 6738           empty   empty         empty  empty          empty   empty
# 6774           empty   empty         empty  empty          empty   empty
# 7344           empty   empty         empty  empty          empty   empty
# 7345           empty   empty         empty  empty          empty   empty
# 9937           empty   empty         empty  empty          empty   empty
# 10097          empty   empty         empty  empty          empty   empty
# 10557          empty   empty         empty  empty          empty   empty
# 11441          empty   empty         empty  empty          empty   empty
# 12454          empty   empty         empty  empty          empty   empty
# 13707          empty   empty         empty  empty          empty   empty
# 14383          empty   empty         empty  empty          empty   empty
# 14424          empty   empty         empty  empty          empty   empty
# 15109          empty   empty         empty  empty          empty   empty
# 15370          empty   empty         empty  empty          empty   empty
# 17343          empty   empty         empty  empty          empty   empty
# 17344          empty   empty         empty  empty          empty   empty
# 17757          empty   empty         empty  empty          empty   empty
# 18658          empty   empty         empty  empty          empty   empty
# 18823          empty   empty         empty  empty          empty   empty
# 19176          empty   empty         empty  empty          empty   empty
# 19581          empty   empty         empty  empty          empty   empty
# 20127          empty   empty         empty  empty          empty   empty
# 21563          empty   empty         empty  empty          empty   empty
# 21778          empty   empty         empty  empty          empty   empty
# 23519          empty   empty         empty  empty          empty   empty
# 25330          empty   empty         empty  empty          empty   empty
# 29867          empty   empty         empty  empty          empty   empty
# 32374          empty   empty         empty  empty          empty   empty
# 33505          empty   empty         empty  empty          empty   empty
# 33706          empty   empty         empty  empty          empty   empty
# 35272          empty   empty         empty  empty          empty   empty
# 35276          empty   empty         empty  empty          empty   empty
# 37412          empty   empty         empty  empty          empty   empty
# 40970          empty   empty         empty  empty          empty   empty
# 41250          empty   empty         empty  empty          empty   empty
# 49866          empty   empty         empty  empty          empty   empty
# 49888          empty   empty         empty  empty          empty   empty
# 49895          empty   empty         empty  empty          empty   empty
# 51092          empty   empty         empty  empty          empty   empty
# 51099          empty   empty         empty  empty          empty   empty
# 51103          empty   empty         empty  empty          empty   empty
# 51119          empty   empty         empty  empty          empty   empty
# 51148          empty   empty         empty  empty          empty   empty
# 51164          empty   empty         empty  empty          empty   empty
# 51174          empty   empty         empty  empty          empty   empty
# 51176          empty   empty         empty  empty          empty   empty
# 52117          empty   empty         empty  empty          empty   empty
# 53798          empty   empty         empty  empty          empty   empty
#
#       Comments
# 1173     empty
# 2064     empty
# 2423     empty
# 3736     empty
# 3739     empty
# 5358     empty
# 6652     empty
# 6738     empty
# 6774     empty
# 7344     empty
# 7345     empty
# 9937     empty
# 10097    empty
# 10557    empty
# 11441    empty
# 12454    empty
# 13707    empty
# 14383    empty
# 14424    empty
# 15109    empty
# 15370    empty
# 17343    empty
# 17344    empty
# 17757    empty
# 18658    empty
# 18823    empty
# 19176    empty
# 19581    empty
# 20127    empty
# 21563    empty
# 21778    empty
# 23519    empty
# 25330    empty
# 29867    empty
# 32374    empty
# 33505    empty
# 33706    empty
# 35272    empty
# 35276    empty
# 37412    empty
# 40970    empty
# 41250    empty
# 49866    empty
# 49888    empty
# 49895    empty
# 51092    empty
# 51099    empty
# 51103    empty
# 51119    empty
# 51148    empty
# 51164    empty
# 51174    empty
# 51176    empty
# 52117    empty
# 53798    empty
#
# [55 rows x 34 columns]

# %%
# delete email OTA
count_after_clean_OTA = m.delete_OTA(zoho_df, 'Email')
# zoho_df.to_excel(r'C:\Users\fajar\Documents\Python\Data\after_clean_OTA.xlsx', index=False)

zoho_df
# Out:
#                       Record Id        Created Time Created Date First Name  \
# 0      zcrm_3584690000000404133 2019-01-07 15:08:38   2019-01-06   Johannes
# 1      zcrm_3584690000000404160 2019-01-07 15:08:38   2019-01-06   Philippa
# 2      zcrm_3584690000000404199 2019-01-07 15:08:38   2019-01-06          V
# 3      zcrm_3584690000000404452 2019-01-08 11:07:28   2019-01-03     Shigeo
# 4      zcrm_3584690000000404870 2019-01-08 11:07:30   2019-01-03       Hsbs
# ...                         ...                 ...          ...        ...
# 55573  zcrm_3584690000499165001 2024-06-17 14:42:23        empty     Angela
# 55574  zcrm_3584690000499443111 2024-06-18 23:47:02        empty       sals
# 55575  zcrm_3584690000499792076 2024-06-21 10:27:41        empty       Hahs
# 55576  zcrm_3584690000499836586 2024-06-24 15:20:40        empty       Loic
# 55577  zcrm_3584690000499860873 2024-06-24 15:31:48        empty    Yixiang
#
#        Last Name                          Email        Phone Mobile  \
# 0      Hauptmann          johannesh@hotmail.com   6590189726  empty
# 1       Spellman       philspellman@hotmail.com   6596515025  empty
# 2              H  vimidaminiharidasan@gmail.com   6596526640  empty
# 3       Kawasaki          shigeou1123@gmail.com   6597228507  empty
# 4          Babas                    ssd@sss.com   6593728273  empty
# ...          ...                            ...          ...    ...
# 55573        Tay      angela.wearnxin@gmail.com  60177595390  empty
# 55574      gupta           salonigaba@yahoo.com   6586062557  empty
# 55575      Hshhz                hshsj@gmail.com   6584160285  empty
# 55576     Hemard          loic.hemard@gmail.com   6598270507  empty
# 55577       Zhou              benkden@yahoo.com   6598319447  empty
#
#         Birthdate Year of Birth  ...  \
# 0      1982-05-19          1982  ...
# 1      1972-05-10          1972  ...
# 2           empty         empty  ...
# 3      1977-11-23          1977  ...
# 4           empty         empty  ...
# ...           ...           ...  ...
# 55573       empty         empty  ...
# 55574       empty         empty  ...
# 55575       empty         empty  ...
# 55576       empty         empty  ...
# 55577       empty         empty  ...
#
#                                  Lead Source Description Lead Regions  \
# 0                                                  empty        Other
# 1                                                  empty        Other
# 2                                                  empty        Other
# 3                                                  empty        Other
# 4                                                  empty        Other
# ...                                                  ...          ...
# 55573  Karma Kandara -Download Wedding Brochure at Ka...        Other
# 55574                          Timeshare Booking Request        Other
# 55575            Karma Beach VIP membership sign up 2023        Other
# 55576                                          Viewpoint        empty
# 55577                                          Viewpoint        empty
#
#       Lead Status Booking Status  BookRef Email Opt Out Opt In GDPR Compliant  \
# 0        New Lead          empty    empty         empty  empty          empty
# 1        New Lead          empty    empty         empty  empty          empty
# 2        New Lead          empty    empty         empty  empty          empty
# 3        New Lead          empty    empty         empty  empty          empty
# 4        New Lead          empty    empty         empty  empty          empty
# ...           ...            ...      ...           ...    ...            ...
# 55573       empty          empty    empty         false   true          false
# 55574       empty          empty    empty         false   true           true
# 55575       empty          empty    empty         false   true          false
# 55576       empty    Checked-Out  2456649         false   true          false
# 55577       empty    Checked-Out  2538889         false   true          false
#
#                                                  Website Comments
# 0                                                  empty    empty
# 1                                                  empty    empty
# 2                                                  empty    empty
# 3                                                  empty    empty
# 4                                                  empty    empty
# ...                                                  ...      ...
# 55573  https://karmagroup.com/weddings-at-karma-kanda...    empty
# 55574  https://karmagroup.com/find-destination/karma-...    empty
# 55575            https://karmagroup.com/karma-beach-vip/    empty
# 55576                                              empty    empty
# 55577                                              empty    empty
#
# [55578 rows x 34 columns]

# %%
# Cek Email Karma
email_karma = m.find_karma(zoho_df, 'Email')
count_email_karma = email_karma.shape[0]
# email_OTA.to_excel(r'C:\Users\fajar\Documents\Python\Data\email_OTA.xlsx', index=False)

email_karma
# Out:
#                       Record Id        Created Time Created Date  \
# 861    zcrm_3584690000005973712 2019-04-02 02:17:28   2017-01-18
# 1476   zcrm_3584690000006012896 2019-04-02 02:21:13   2017-01-18
# 3578   zcrm_3584690000006516392 2019-04-02 04:04:45   2017-01-23
# 5272   zcrm_3584690000006591763 2019-04-02 04:12:25   2015-04-23
# 7312   zcrm_3584690000006685934 2019-04-02 04:22:52   2015-05-12
# 10386  zcrm_3584690000006816897 2019-04-02 04:38:17   2015-05-12
# 11277  zcrm_3584690000006853411 2019-04-02 04:43:11   2017-01-16
# 17758  zcrm_3584690000007157037 2019-04-02 05:24:46   2016-07-26
# 32185  zcrm_3584690000008522519 2019-04-02 08:11:21   2017-01-18
# 49886  zcrm_3584690000025161556 2019-04-09 21:52:07        empty
# 51820  zcrm_3584690000158666052 2020-01-13 20:54:22   2019-10-22
# 51939  zcrm_3584690000163489418 2020-02-06 11:14:38        empty
# 53666  zcrm_3584690000414915776 2022-12-05 13:29:19        empty
#
#           First Name          Last Name                               Email  \
# 861            Fariz                 Ab              odysseyasiapac@rci.com
# 1476         Natalie                Poh                 natalie.poh@rci.com
# 3578          Eunice                Yap                  eunice.yap@rci.com
# 5272          Winnie               Ding                 winnie.ding@rci.com
# 7312           Edena  Soong Ing Low Ing                   edena.low@rci.com
# 10386          empty              empty                chris.joseph@rci.com
# 11277        Kendall                Oei                 kendall.oei@rci.com
# 17758           Seri               Seri                  seri.okuno@rci.com
# 32185       Jonathan              Mills              jonathan.mills@rci.com
# 49886        Ricardo          Montaudon           ricardo.montaudon@rci.com
# 51820          empty              empty                alisa.nguyen@rci.com
# 51939  Beewer Corona               Plej  adhitya.putra.20dev@karmagroup.com
# 53666       Liu Juan               Jane                    jane.liu@rci.com
#
#              Phone      Mobile   Birthdate Year of Birth  ...  \
# 861     6591060936       empty  1982-10-05          1982  ...
# 1476   65064122146       empty       empty         empty  ...
# 3578      64122171       empty       empty         empty  ...
# 5272         empty       empty       empty         empty  ...
# 7312         empty       empty       empty         empty  ...
# 10386        empty       empty       empty         empty  ...
# 11277    811797218       empty       empty         empty  ...
# 17758   6585690316       15708       empty         empty  ...
# 32185  65091380059       empty       empty         empty  ...
# 49886   6564122106  6597762360       empty         empty  ...
# 51820   6562234333       empty       empty         empty  ...
# 51939        empty       empty       empty         empty  ...
# 53666   6562234333       empty       empty         empty  ...
#
#              Lead Source Description Lead Regions  Lead Status Booking Status  \
# 861                   Karma Jimbaran        Other  No Response          empty
# 1476                   Karma Kandara        Other  No Response          empty
# 3578                       Belvedere        Other        empty          empty
# 5272                       Belvedere        Other        empty          empty
# 7312                       Belvedere        Other        empty          empty
# 10386           Karma Samui In House        Other        empty          empty
# 11277                      Belvedere        Other        empty          empty
# 17758                          empty        Other        empty          empty
# 32185              registration_form        Other        empty          empty
# 49886                          empty        Other     New Lead          empty
# 51820  Karma Group Website Concierge        Other     New Lead          empty
# 51939    Test Bot Bali | Webchat Web        Other        empty          empty
# 53666                      Viewpoint        empty        empty          empty
#
#       BookRef Email Opt Out Opt In GDPR Compliant Website Comments
# 861     empty         empty  empty          empty   empty    empty
# 1476    empty         empty  empty          empty   empty    empty
# 3578    empty         empty  empty          empty   empty    empty
# 5272    empty         empty  empty          empty   empty    empty
# 7312    empty         empty  empty          empty   empty    empty
# 10386   empty         empty  empty          empty   empty    empty
# 11277   empty         empty  empty          empty   empty    empty
# 17758   empty         empty  empty          empty   empty    empty
# 32185   empty         empty  empty          empty   empty    empty
# 49886   empty         empty  empty          empty   empty    empty
# 51820   empty         empty  empty          empty   empty    empty
# 51939   empty         empty  empty          empty   empty    empty
# 53666   empty         empty  empty          empty   empty    empty
#
# [13 rows x 34 columns]

# %%
# delete email Karma
count_after_clean_karma = m.delete_karma(zoho_df, 'Email')
# zoho_df.to_excel(r'C:\Users\fajar\Documents\Python\Data\after_clean_OTA.xlsx', index=False)

zoho_df
# Out:
#                       Record Id        Created Time Created Date First Name  \
# 0      zcrm_3584690000000404133 2019-01-07 15:08:38   2019-01-06   Johannes
# 1      zcrm_3584690000000404160 2019-01-07 15:08:38   2019-01-06   Philippa
# 2      zcrm_3584690000000404199 2019-01-07 15:08:38   2019-01-06          V
# 3      zcrm_3584690000000404452 2019-01-08 11:07:28   2019-01-03     Shigeo
# 4      zcrm_3584690000000404870 2019-01-08 11:07:30   2019-01-03       Hsbs
# ...                         ...                 ...          ...        ...
# 55560  zcrm_3584690000499165001 2024-06-17 14:42:23        empty     Angela
# 55561  zcrm_3584690000499443111 2024-06-18 23:47:02        empty       sals
# 55562  zcrm_3584690000499792076 2024-06-21 10:27:41        empty       Hahs
# 55563  zcrm_3584690000499836586 2024-06-24 15:20:40        empty       Loic
# 55564  zcrm_3584690000499860873 2024-06-24 15:31:48        empty    Yixiang
#
#        Last Name                          Email        Phone Mobile  \
# 0      Hauptmann          johannesh@hotmail.com   6590189726  empty
# 1       Spellman       philspellman@hotmail.com   6596515025  empty
# 2              H  vimidaminiharidasan@gmail.com   6596526640  empty
# 3       Kawasaki          shigeou1123@gmail.com   6597228507  empty
# 4          Babas                    ssd@sss.com   6593728273  empty
# ...          ...                            ...          ...    ...
# 55560        Tay      angela.wearnxin@gmail.com  60177595390  empty
# 55561      gupta           salonigaba@yahoo.com   6586062557  empty
# 55562      Hshhz                hshsj@gmail.com   6584160285  empty
# 55563     Hemard          loic.hemard@gmail.com   6598270507  empty
# 55564       Zhou              benkden@yahoo.com   6598319447  empty
#
#         Birthdate Year of Birth  ...  \
# 0      1982-05-19          1982  ...
# 1      1972-05-10          1972  ...
# 2           empty         empty  ...
# 3      1977-11-23          1977  ...
# 4           empty         empty  ...
# ...           ...           ...  ...
# 55560       empty         empty  ...
# 55561       empty         empty  ...
# 55562       empty         empty  ...
# 55563       empty         empty  ...
# 55564       empty         empty  ...
#
#                                  Lead Source Description Lead Regions  \
# 0                                                  empty        Other
# 1                                                  empty        Other
# 2                                                  empty        Other
# 3                                                  empty        Other
# 4                                                  empty        Other
# ...                                                  ...          ...
# 55560  Karma Kandara -Download Wedding Brochure at Ka...        Other
# 55561                          Timeshare Booking Request        Other
# 55562            Karma Beach VIP membership sign up 2023        Other
# 55563                                          Viewpoint        empty
# 55564                                          Viewpoint        empty
#
#       Lead Status Booking Status  BookRef Email Opt Out Opt In GDPR Compliant  \
# 0        New Lead          empty    empty         empty  empty          empty
# 1        New Lead          empty    empty         empty  empty          empty
# 2        New Lead          empty    empty         empty  empty          empty
# 3        New Lead          empty    empty         empty  empty          empty
# 4        New Lead          empty    empty         empty  empty          empty
# ...           ...            ...      ...           ...    ...            ...
# 55560       empty          empty    empty         false   true          false
# 55561       empty          empty    empty         false   true           true
# 55562       empty          empty    empty         false   true          false
# 55563       empty    Checked-Out  2456649         false   true          false
# 55564       empty    Checked-Out  2538889         false   true          false
#
#                                                  Website Comments
# 0                                                  empty    empty
# 1                                                  empty    empty
# 2                                                  empty    empty
# 3                                                  empty    empty
# 4                                                  empty    empty
# ...                                                  ...      ...
# 55560  https://karmagroup.com/weddings-at-karma-kanda...    empty
# 55561  https://karmagroup.com/find-destination/karma-...    empty
# 55562            https://karmagroup.com/karma-beach-vip/    empty
# 55563                                              empty    empty
# 55564                                              empty    empty
#
# [55565 rows x 34 columns]

# %%
find_member_booking = zoho_df.copy()

find_member_booking.loc[find_member_booking['Phone'].isin(df_booking['Phone1']), 'Same Value Find'] = 'Booking-Phone1'
find_member_booking.loc[find_member_booking['Phone'].isin(df_booking['Mobile']), 'Same Value Find'] = 'Booking-Mobile'
find_member_booking.loc[find_member_booking['Mobile'].isin(df_booking['Phone1']), 'Same Value Find'] = 'Booking-Phone1' 
find_member_booking.loc[find_member_booking['Mobile'].isin(df_booking['Mobile']), 'Same Value Find'] = 'Booking-Mobile'
find_member_booking.loc[find_member_booking['Email'].isin(df_booking['Email']), 'Same Value Find'] = 'Booking-Email'

find_member_booking.loc[find_member_booking['Phone'].isin(df_phone['Mobile']), 'Same Value Find'] = 'Member-Mobile' 
find_member_booking.loc[find_member_booking['Mobile'].isin(df_phone['Mobile']), 'Same Value Find'] = 'Member-Mobile'

find_member_booking.loc[find_member_booking['Email'].isin(df_email['Email']), 'Same Value Find'] = 'Member-Email'

find_member_booking.drop(find_member_booking.loc[find_member_booking['Same Value Find'].isna()].index, inplace=True)

count_booking_dedup = find_member_booking.loc[find_member_booking['Same Value Find'].str.contains('Booking', flags=re.I, regex=True)].shape[0]
count_member_dedup = find_member_booking.loc[find_member_booking['Same Value Find'].str.contains('Member', flags=re.I, regex=True)].shape[0]

find_member_booking.replace('empty', '', inplace=True)
# find_member_booking.to_csv(r'C:\Users\fajar\Documents\Python\Data\booking-member-dedup.csv', index=False)
# find_member_booking.to_excel(r'C:\Users\fajar\Documents\Python\Data\booking-member-dedup.xlsx', index=False)

#find_member_booking.loc[find_member_booking['Same Value Find'] == 'Booking-Phone1']

# %%
# data phone, mobile dam email member yang ada di master data 
count_wash_member = zoho_df.loc[
    zoho_df['Phone'].isin(df_booking['Phone1']) | 
    zoho_df['Phone'].isin(df_booking['Mobile']) |
    zoho_df['Mobile'].isin(df_booking['Phone1']) | 
    zoho_df['Mobile'].isin(df_booking['Mobile']) |
    zoho_df['Email'].isin(df_booking['Email'])| 

    zoho_df['Phone'].isin(df_phone['Mobile']) | 
    zoho_df['Mobile'].isin(df_phone['Mobile']) |

    zoho_df['Email'].isin(df_email['Email'])

].shape[0]

zoho_df.drop(zoho_df.loc[
    zoho_df['Phone'].isin(df_booking['Phone1']) | 
    zoho_df['Phone'].isin(df_booking['Mobile']) |
    zoho_df['Mobile'].isin(df_booking['Phone1']) | 
    zoho_df['Mobile'].isin(df_booking['Mobile']) |
    zoho_df['Email'].isin(df_booking['Email']) |
    
    zoho_df['Phone'].isin(df_phone['Mobile']) | 
    zoho_df['Mobile'].isin(df_phone['Mobile']) |

    zoho_df['Email'].isin(df_email['Email'])

    ].index, inplace=True)
    
zoho_df.reset_index(drop=True, inplace=True)

count_after_wash_member = zoho_df.shape[0]

# %%
count_email_only = zoho_df.loc[(zoho_df['Email'] != 'empty') & ((zoho_df['Phone'] == 'empty') & (zoho_df['Mobile'] == 'empty'))].shape[0]
count_phone_only = zoho_df.loc[(zoho_df['Email'] == 'empty') & ((zoho_df['Phone'] != 'empty') | (zoho_df['Mobile'] != 'empty'))].shape[0]
count_email_and_phone = zoho_df.loc[(zoho_df['Email'] != 'empty') & ((zoho_df['Phone'] != 'empty') | (zoho_df['Mobile'] != 'empty'))].shape[0]

count_blank = zoho_df.loc[(zoho_df['Email'] =='empty') & (zoho_df['Phone']=='empty') & (zoho_df['Mobile']=='empty')].shape[0]

# zoho_df.loc[(zoho_df['Email'] =='empty') & (zoho_df['Phone']=='empty') & (zoho_df['Mobile']=='empty')].to_excel(r'C:\Users\fajar\Documents\Python\Data\blank_data.xlsx', index=False)

zoho_df.loc[(zoho_df['Email'] != 'empty') & ((zoho_df['Phone'] == 'empty') & (zoho_df['Mobile'] == 'empty')), 'Contact Type'] = 'Email Only'
zoho_df.loc[(zoho_df['Email'] == 'empty') & ((zoho_df['Phone'] != 'empty') | (zoho_df['Mobile'] != 'empty')), 'Contact Type'] = 'Phone Only'
zoho_df.loc[(zoho_df['Email'] != 'empty') & ((zoho_df['Phone'] != 'empty') | (zoho_df['Mobile'] != 'empty')), 'Contact Type'] = 'Email and Phone'

zoho_df.drop(zoho_df.loc[(zoho_df['Email'] =='empty') & (zoho_df['Phone']=='empty') & (zoho_df['Mobile']=='empty')].index, inplace=True)
zoho_df.reset_index(drop=True, inplace=True)

count_after_wash_blank = zoho_df.shape[0]

# %%
arr_dedup = [count_deleted_wrong_format, count_duplicate_general, count_leads_test, count_email_OTA, count_email_karma, count_blank]
count_sum_dedup = sum(arr_dedup)
count_sum_dedup
# Out:
# 549

# %%
print("==========================================================")
print("Summary")
print("==========================================================")
print("Jumlah Keseluruhan Master Zoho : "+str(count_data_awal))
print("Jumlah Filter Leads Awal : "+str(count_filter_awal))
print("Jumlah Format Email Salah : "+str(count_deleted_wrong_format))
print("Jumlah Setelah Clean Format Email Salah : "+str(count_after_deleted_wrong_format))
print("Jumlah Duplicate (Phone, Mobile dan Email) : "+str(count_duplicate_general))
print("Jumlah Setelah Clean Duplicate : "+str(count_after_dedup_duplicate))
print("Jumlah Lead Test : "+str(count_leads_test))
print("Jumlah Setelah Clean Lead Test : "+str(count_after_dedup_test))
# print("Jumlah Lead Do Not Mail : "+str(count_dnm))
# print("Jumlah Setelah Clean Lead Do Not Mail : "+str(count_after_dedup_dnm))
print("Jumlah Email OTA : "+str(count_email_OTA))
print("Jumlah Setelah Clean Email OTA : "+str(count_after_clean_OTA))
print("Jumlah Email Karma : "+str(count_email_karma))
print("Jumlah Setelah Clean Email Karma : "+str(count_after_clean_karma))
print("Jumlah Wash Member : "+str(count_member_dedup))
print("Jumlah Wash Booking : "+str(count_booking_dedup))
print("Jumlah Setelah Wash Member : "+str(count_after_wash_member))
print("Jumlah Phone Email Blank (Setelah phone yang tidak valid dihapus) : "+str(count_blank))
print("Jumlah Setelah Wash Phone Email Blank : "+str(count_after_wash_blank))
print("==========================================================")
print("Contact Type")
print("==========================================================")
print("Jumlah Email Only : "+str(count_email_only))
print("Jumlah Phone Only : "+str(count_phone_only))
print("Jumlah Email dan Phone : "+str(count_email_and_phone))
# Out:
# ==========================================================
# Summary
# ==========================================================
# Jumlah Keseluruhan Master Zoho : 9984376
# Jumlah Filter Leads Awal : 56114
# Jumlah Format Email Salah : 1
# Jumlah Setelah Clean Format Email Salah : 56113
# Jumlah Duplicate (Phone, Mobile dan Email) : 477
# Jumlah Setelah Clean Duplicate : 55636
# Jumlah Lead Test : 3
# Jumlah Setelah Clean Lead Test : 55633
# Jumlah Email OTA : 55
# Jumlah Setelah Clean Email OTA : 55578
# Jumlah Email Karma : 13
# Jumlah Setelah Clean Email Karma : 55565
# Jumlah Wash Member : 2143
# Jumlah Wash Booking : 79
# Jumlah Setelah Wash Member : 53343
# Jumlah Phone Email Blank (Setelah phone yang tidak valid dihapus) : 0
# Jumlah Setelah Wash Phone Email Blank : 53343
# ==========================================================
# Contact Type
# ==========================================================
# Jumlah Email Only : 15775
# Jumlah Phone Only : 9585
# Jumlah Email dan Phone : 27983

# %%
print("==========================================================")
print("Summary Report")
print("==========================================================")
print("Jumlah Data Awal : "+str(count_filter_awal))
print("Jumlah Wash Dedup : "+str(count_sum_dedup))
print("Jumlah Wash Member : "+str(count_member_dedup))
print("Jumlah Wash Booking : "+str(count_booking_dedup))
print("Jumlah Data Akhir : "+str(count_after_wash_blank))
# Out:
# ==========================================================
# Summary Report
# ==========================================================
# Jumlah Data Awal : 56114
# Jumlah Wash Dedup : 549
# Jumlah Wash Member : 2143
# Jumlah Wash Booking : 79
# Jumlah Data Akhir : 53343

# %% [markdown]
# # ====================== Akhir Filter Umum ======================

# %%
zoho_df.replace('empty', '', inplace=True, regex=True)

zoho_df['First Name'] = zoho_df['First Name'].str.title()
zoho_df['Last Name'] = zoho_df['Last Name'].str.title()

zoho_df.to_excel(r'C:\Users\fajar\Documents\Python\Data\check_data.xlsx', index=False)

# %%
zoho_df.groupby('Country').count()
# Out:
#                       Record Id  Created Time  Created Date  First Name  \
# Country
#                               2             2             2           2
# Australia                     6             6             6           6
# China                         2             2             2           2
# France                        1             1             1           1
# Germany                       4             4             4           4
# Indonesia                     7             7             7           7
# MALAYSIA                    188           188           188         188
# Malaysia                  15004         15004         15004       15004
# New Zealand                   2             2             2           2
# SINGAPORE                   180           180           180         180
# SIngapore                     1             1             1           1
# Singapore                 37936         37936         37936       37936
# South Korea                   2             2             2           2
# United Arab Emirates          1             1             1           1
# United Kingdom                4             4             4           4
# United States                 1             1             1           1
# singapore                     2             2             2           2
#
#                       Last Name  Email  Phone  Mobile  Birthdate  \
# Country
#                               2      2      2       2          2
# Australia                     6      6      6       6          6
# China                         2      2      2       2          2
# France                        1      1      1       1          1
# Germany                       4      4      4       4          4
# Indonesia                     7      7      7       7          7
# MALAYSIA                    188    188    188     188        188
# Malaysia                  15004  15004  15004   15004      15004
# New Zealand                   2      2      2       2          2
# SINGAPORE                   180    180    180     180        180
# SIngapore                     1      1      1       1          1
# Singapore                 37936  37936  37936   37936      37936
# South Korea                   2      2      2       2          2
# United Arab Emirates          1      1      1       1          1
# United Kingdom                4      4      4       4          4
# United States                 1      1      1       1          1
# singapore                     2      2      2       2          2
#
#                       Year of Birth  ...  Lead Regions  Lead Status  \
# Country                              ...
#                                   2  ...             2            2
# Australia                         6  ...             6            6
# China                             2  ...             2            2
# France                            1  ...             1            1
# Germany                           4  ...             4            4
# Indonesia                         7  ...             7            7
# MALAYSIA                        188  ...           188          188
# Malaysia                      15004  ...         15004        15004
# New Zealand                       2  ...             2            2
# SINGAPORE                       180  ...           180          180
# SIngapore                         1  ...             1            1
# Singapore                     37936  ...         37936        37936
# South Korea                       2  ...             2            2
# United Arab Emirates              1  ...             1            1
# United Kingdom                    4  ...             4            4
# United States                     1  ...             1            1
# singapore                         2  ...             2            2
#
#                       Booking Status  BookRef  Email Opt Out  Opt In  \
# Country
#                                    2        2              2       2
# Australia                          6        6              6       6
# China                              2        2              2       2
# France                             1        1              1       1
# Germany                            4        4              4       4
# Indonesia                          7        7              7       7
# MALAYSIA                         188      188            188     188
# Malaysia                       15004    15004          15004   15004
# New Zealand                        2        2              2       2
# SINGAPORE                        180      180            180     180
# SIngapore                          1        1              1       1
# Singapore                      37936    37936          37936   37936
# South Korea                        2        2              2       2
# United Arab Emirates               1        1              1       1
# United Kingdom                     4        4              4       4
# United States                      1        1              1       1
# singapore                          2        2              2       2
#
#                       GDPR Compliant  Website  Comments  Contact Type
# Country
#                                    2        2         2             2
# Australia                          6        6         6             6
# China                              2        2         2             2
# France                             1        1         1             1
# Germany                            4        4         4             4
# Indonesia                          7        7         7             7
# MALAYSIA                         188      188       188           188
# Malaysia                       15004    15004     15004         15004
# New Zealand                        2        2         2             2
# SINGAPORE                        180      180       180           180
# SIngapore                          1        1         1             1
# Singapore                      37936    37936     37936         37936
# South Korea                        2        2         2             2
# United Arab Emirates               1        1         1             1
# United Kingdom                     4        4         4             4
# United States                      1        1         1             1
# singapore                          2        2         2             2
#
# [17 rows x 34 columns]

# %%
# zoho_df['Country'].loc[
#     (zoho_df['Phone'].str.contains('^44|^\+44')) & 
#     (~zoho_df['Country'].str.contains('united kingdom|wales|england|scotland|northern ireland', regex=True, flags=re.I))
# ]
