# %%
import sys
sys.path.append('../')

import main_module as m
import gdpr_filter_module as fil
import pandas as pd
import re
import numpy as np

# %load_ext autoreload
# %autoreload 2

dir_path = r'C:\Users\fajar\Documents\Python\Data\Zoho_Backup'
file_name = '\Leads_'

cols = ['Record Id',	
'Created Time',
'Created Date',	
'First Name',	
'Last Name',	
'Email',	
'Phone',	
'Mobile',	
'Birthdate',	
'Year of Birth',
'Street',	
'Street2',	
'City',	
'State',	
'Country',	
'Nationality',
'Booking Status', 
'BookRef',
'Departure Date',	
'Arrival Date',	
'Card Type',	
'Marital Status',	
'Lead Brand',	
'Lead Sub-Brand',	
'Lead Source',	
'Lead Locations',	
'Lead Source Description',	
'Lead Regions',
'Lead Status',
'Email Opt Out',	
'Opt In',
'Do Not Contact',
'Do Not Mail',
'United Kingdom']
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
df = m.load_data_multiple(dir_path, file_name, cols)
count_data_awal = df.shape[0]
df = df.reindex(columns=cols)
df.shape[0]

df['Created Time'] = pd.to_datetime(df['Created Time'], format='%Y-%m-%d %H:%M:%S')
# fungsi errors cource untuk menhindari error jika value data date null atau kosong
# df['Birthdate'] = pd.to_datetime(df['Birthdate'], format='%Y-%m-%d', errors='coerce')
df.dtypes
df
# Out:
#                         Record Id        Created Time Created Date  \
# 0        zcrm_3584690000000404058 2019-01-07 15:08:38   2019-01-06
# 1        zcrm_3584690000000404059 2019-01-07 15:08:38   2019-01-06
# 2        zcrm_3584690000000404060 2019-01-07 15:08:38   2019-01-06
# 3        zcrm_3584690000000404065 2019-01-07 15:08:38   2019-01-06
# 4        zcrm_3584690000000404068 2019-01-07 15:08:38   2019-01-06
# ...                           ...                 ...          ...
# 4661018  zcrm_3584690000463574001 2023-10-02 16:37:39         <NA>
# 4661019  zcrm_3584690000463581001 2023-10-02 17:10:49         <NA>
# 4661020  zcrm_3584690000463583001 2023-10-02 17:14:54         <NA>
# 4661021  zcrm_3584690000463584001 2023-10-02 17:18:01         <NA>
# 4661022  zcrm_3584690000463585001 2023-10-02 17:30:42         <NA>
#
#          First Name  Last Name                       Email           Phone  \
# 0          Nicholas       Wood  1230woodnicholas@gmail.com    +61438600845
# 1              Liao       Yuan            158066546@qq.com   8618718399923
# 2           Vedanta   Abhiyoga  abhiyoga.vedanta@gmail.com  +6282146524550
# 3             Aidai  Atakanova      aidai.nurbek@gmail.com    996779641590
# 4             Ardra      Ardra  aliefardraqariru@gmail.com  +6282139300818
# ...             ...        ...                         ...             ...
# 4661018        Alok    Prakash       kashukhushi@gmail.com   +917019778943
# 4661019     Harshal       Naik          hnaik5@hotmail.com   +447506114549
# 4661020  Rashpinder      Sidhu    risjisaron1985@gmail.com    +61415854786
# 4661021      Baylee    Sequoia              bayleej@me.com    +61403659752
# 4661022   Hendrikus  Welerubun   hendrowelerubun@gmail.com  +6282198912009
#
#                  Mobile   Birthdate Year of Birth  ...   Lead Source  \
# 0                  <NA>        <NA>          <NA>  ...          Wifi
# 1                  <NA>        <NA>          <NA>  ...          Wifi
# 2                  <NA>  2000-07-05          2000  ...          Wifi
# 3                  <NA>  1997-02-05          1997  ...          Wifi
# 4        +6282139300818  2005-01-20          2005  ...          Wifi
# ...                 ...         ...           ...  ...           ...
# 4661018            <NA>  1991-12-14          1991  ...    Guest Exit
# 4661019            <NA>  1990-12-05          1990  ...    Guest Exit
# 4661020            <NA>  1985-04-16          1985  ...    Guest Exit
# 4661021            <NA>        <NA>          <NA>  ...  Facebook Ads
# 4661022            <NA>  1987-01-20          1987  ...    Guest Exit
#
#               Lead Locations  \
# 0                       <NA>
# 1                       <NA>
# 2                       <NA>
# 3                       <NA>
# 4                    Mall 21
# ...                      ...
# 4661018  Sales Deck Jimbaran
# 4661019  Sales Deck Jimbaran
# 4661020  Sales Deck Jimbaran
# 4661021                 <NA>
# 4661022  Sales Deck Jimbaran
#
#                                    Lead Source Description Lead Regions  \
# 0                                              Purple Wifi         SEAP
# 1                                              Purple Wifi        Other
# 2                                              Purple Wifi         SEAP
# 3                                              Purple Wifi    UK/Europe
# 4                                              Purple Wifi         SEAP
# ...                                                    ...          ...
# 4661018  REGISTRATION CONFIRMED | Your Exclusive 7 NIGH...         SEAP
# 4661019  REGISTRATION CONFIRMED | Your Exclusive 7 NIGH...         SEAP
# 4661020  REGISTRATION CONFIRMED | Your Exclusive 7 NIGH...         SEAP
# 4661021                                   HOK Tell Me More         SEAP
# 4661022  REGISTRATION CONFIRMED | Your Exclusive 7 NIGH...         SEAP
#
#           Lead Status Email Opt Out Opt In Do Not Contact Do Not Mail  \
# 0            New Lead         false  false           true       false
# 1            New Lead         false  false           true       false
# 2            New Lead         false  false           true       false
# 3            New Lead         false  false           true       false
# 4            New Lead         false  false           true       false
# ...               ...           ...    ...            ...         ...
# 4661018  Hot Prospect         false   true          false       false
# 4661019  Hot Prospect         false   true          false       false
# 4661020  Hot Prospect         false   true          false       false
# 4661021      New Lead         false  false          false       false
# 4661022  Hot Prospect         false   true          false       false
#
#         United Kingdom
# 0                false
# 1                false
# 2                false
# 3                false
# 4                false
# ...                ...
# 4661018          false
# 4661019           true
# 4661020          false
# 4661021          false
# 4661022          false
#
# [4661023 rows x 34 columns]

# %%
zoho_filter = fil.uk_teritory(df)
zoho_df = df.loc[zoho_filter].copy() # menggunakan copy untuk menghindari setting copy warning
zoho_df.reset_index(drop=True, inplace=True)
count_filter_awal = zoho_df.shape[0]

# mengisi kolom <NA> dengan value string 'empty' supaya mudah mengecek data member dan booking dengan isin

zoho_df.fillna('empty', inplace=True)
zoho_df
# Out:
#                    Record Id        Created Time Created Date  \
# 0   zcrm_3584690000458372228 2023-08-22 14:29:30        empty
# 1   zcrm_3584690000459083030 2023-08-26 14:32:34        empty
# 2   zcrm_3584690000459262030 2023-08-29 15:47:07        empty
# 3   zcrm_3584690000460453003 2023-09-06 19:22:12        empty
# 4   zcrm_3584690000460628001 2023-09-07 16:54:56        empty
# ..                       ...                 ...          ...
# 72  zcrm_3584690000461634991 2023-09-18 15:36:44        empty
# 73  zcrm_3584690000461816003 2023-09-18 15:36:44        empty
# 74  zcrm_3584690000461816007 2023-09-18 15:36:44        empty
# 75  zcrm_3584690000461816009 2023-09-18 15:36:44        empty
# 76  zcrm_3584690000461816013 2023-09-18 15:36:44        empty
#
#             First Name       Last Name                        Email  \
# 0                empty  Amy Sussemilch        amysuss@hotmail.co.uk
# 1              Stephen           Moore       steverrmoore@gmail.com
# 2                Barry           Cooke         bazcooke@hotmail.com
# 3                empty     Nigel Baker       nigel.baker@icloud.com
# 4                 John          Sheehy          vsheehy95@gmail.com
# ..                 ...             ...                          ...
# 72            Jonathan       Beardmore           jon@beardmores.com
# 73             Venessa           Swaby      venessabobb@outlook.com
# 74                John         Scruton         john.scruton@sky.com
# 75  Chanelle Alexandra        Connolly  chanellebussell@yahoo.co.uk
# 76               Susan           Price       sueprice62@yahoo.co.uk
#
#              Phone        Mobile   Birthdate Year of Birth  ...  Lead Source  \
# 0    +447940302489         empty       empty         empty  ...  Web Enquiry
# 1    +919650737775         empty  1962-08-24          1962  ...   Guest Exit
# 2     +64275525995         empty  1963-02-28          1963  ...   Guest Exit
# 3   +4407515891235         empty       empty         empty  ...  Web Enquiry
# 4     +32477607680         empty  1963-06-20          1963  ...   Guest Exit
# ..             ...           ...         ...           ...  ...          ...
# 72    441296681961  447740423439       empty         empty  ...  Past Guests
# 73    447947198362         empty       empty         empty  ...  Past Guests
# 74    447868607590         empty       empty         empty  ...  Past Guests
# 75    447946340706         empty       empty         empty  ...  Past Guests
# 76    447803772768         empty       empty         empty  ...  Past Guests
#
#             Lead Locations                            Lead Source Description  \
# 0                  General                                 KE | Web | Booking
# 1       Sales Deck Vietnam  Vietnam | REGISTRATION CONFIRMED | Your Exclus...
# 2       Sales Deck Vietnam  Vietnam | REGISTRATION CONFIRMED | Your Exclus...
# 3                  General                                 KE | Web | Booking
# 4       Sales Deck Vietnam  Vietnam | REGISTRATION CONFIRMED | Your Exclus...
# ..                     ...                                                ...
# 72            Karma Minoan                                          Viewpoint
# 73  Karma Lake of Menteith                                          Viewpoint
# 74  Karma Lake of Menteith                                          Viewpoint
# 75      Karma Salford Hall                                          Viewpoint
# 76      Karma Salford Hall                                          Viewpoint
#
#    Lead Regions   Lead Status Email Opt Out Opt In Do Not Contact Do Not Mail  \
# 0          SEAP      New Lead         false  false          false       false
# 1          SEAP  Hot Prospect         false   true          false       false
# 2          SEAP  Hot Prospect         false   true          false       false
# 3          SEAP      New Lead         false  false          false       false
# 4          SEAP  Hot Prospect         false   true          false       false
# ..          ...           ...           ...    ...            ...         ...
# 72        empty      New Lead         false   true          false       false
# 73        empty      New Lead         false   true          false       false
# 74        empty      New Lead         false   true          false       false
# 75        empty      New Lead         false   true          false       false
# 76        empty      New Lead         false   true          false       false
#
#    United Kingdom
# 0           false
# 1           false
# 2           false
# 3           false
# 4           false
# ..            ...
# 72          false
# 73          false
# 74          false
# 75          false
# 76          false
#
# [77 rows x 34 columns]

# %%
zoho_df.groupby('Country').count()
# Out:
#                 Record Id  Created Time  Created Date  First Name  Last Name  \
# Country
# SCOTLAND                1             1             1           1          1
# United Kingdom         76            76            76          76         76
#
#                 Email  Phone  Mobile  Birthdate  Year of Birth  ...  \
# Country                                                         ...
# SCOTLAND            1      1       1          1              1  ...
# United Kingdom     76     76      76         76             76  ...
#
#                 Lead Source  Lead Locations  Lead Source Description  \
# Country
# SCOTLAND                  1               1                        1
# United Kingdom           76              76                       76
#
#                 Lead Regions  Lead Status  Email Opt Out  Opt In  \
# Country
# SCOTLAND                   1            1              1       1
# United Kingdom            76           76             76      76
#
#                 Do Not Contact  Do Not Mail  United Kingdom
# Country
# SCOTLAND                     1            1               1
# United Kingdom              76           76              76
#
# [2 rows x 33 columns]

# %%
zoho_df.groupby('United Kingdom').count()
# Out:
#                 Record Id  Created Time  Created Date  First Name  Last Name  \
# United Kingdom
# false                  77            77            77          77         77
#
#                 Email  Phone  Mobile  Birthdate  Year of Birth  ...  \
# United Kingdom                                                  ...
# false              77     77      77         77             77  ...
#
#                 Lead Sub-Brand  Lead Source  Lead Locations  \
# United Kingdom
# false                       77           77              77
#
#                 Lead Source Description  Lead Regions  Lead Status  \
# United Kingdom
# false                                77            77           77
#
#                 Email Opt Out  Opt In  Do Not Contact  Do Not Mail
# United Kingdom
# false                      77      77              77           77
#
# [1 rows x 33 columns]

# %%
zoho_df.replace('empty', '', inplace=True)
zoho_df.to_excel(r'C:\Users\fajar\Documents\Python\Data\update_uk_checkbox.xlsx', index=False)
