# %%
import pandas as pd

# Load JSON data from a file
file_path = r'C:\Users\fajar.fatoni\Documents\Python\Data\Event List\event.json'  
df = pd.read_json(file_path)

# Display the DataFrame
print(df)
# Out:
#                                                  name                  dates  \
# 0           Celebrate Ganesha’s Divine Journey in Goa  26 Aug to 29 Aug 2025
# 1                    Watersports & Wellness Weekender  23 Aug to 25 Aug 2025
# 2      Culinary Adventures & Cultural Wonders in Bali  10 Aug to 13 Aug 2025
# 3             Journey into the Heart of Co Tu Culture  06 Aug to 08 Aug 2025
# 4             Wild Birds, Wilderness & Warming Whisky  03 Aug to 06 Aug 2025
# 5   Arabian Nights: Gourmet Starlit Magic Carpet Ride  17 Jul to 19 Jul 2025
# 6                     A VIP Rugby Spectacle in Sydney            05 Jul 2025
# 7                            Karma Summer Social 2025            05 Jul 2025
# 8      Lords of the Game: A Luxury Cricket Experience  03 Jul to 05 Jul 2025
# 9           Alpine Adventures: Bavarian Nature Escape  29 Jun to 02 Jul 2025
# 10       Witness The Legendary & Grand Lions In Perth            28 Jun 2025
# ...

# %%
df.to_excel(r'C:\Users\fajar.fatoni\Documents\Python\Data\Event List\event.xlsx', index=False)
