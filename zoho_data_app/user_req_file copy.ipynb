# %%
import main_module as m
import zoho_filter_module as fil
import pandas as pd
import re
import numpy as np

# %load_ext autoreload
# %autoreload 2

cols = ['Record Id',	
'Created Time',
'Created Date',	
'First Name',	
'Last Name',	
'Email',	
'PHONE',	
'Mobile',	
'Birthdate',	
'Year of Birth',
'Street',	
'Street2',	
'City',	
'State',	
'Country',	
'Nationality',
'Booking Status', 
'BookRef',
'Departure Date',	
'Arrival Date',	
'Card Type',	
'Marital Status',	
'Lead Brand',	
'Lead Sub-Brand',	
'Lead Source',	
'Lead Locations',	
'Lead Source Description',	
'Lead Regions',
'Lead Status',
'Email Opt Out',	
'Opt In']
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
path = r'C:\Users\fajar.fatoni\Documents\Python\Data\Beambox\df_beambox.xlsx'
# zoho_df = pd.read_csv(path, dtype='string')
zoho_df = pd.read_excel(path, dtype='string', sheet_name='Sheet1')

zoho_df.reset_index(drop=True, inplace=True)
count_filter_awal = zoho_df.shape[0]

# mengisi kolom <NA> dengan value string 'empty' supaya mudah mengecek data member dan booking dengan isin
zoho_df.fillna('empty', inplace=True)

zoho_df['Mobile'] = 'empty'
# zoho_df['Phone'] = 'empty'
zoho_df
# Out:
#              Id                          Email Provider              Uid  \
# 0      17340163             divyanne@gmail.com    email  239910935240012
# 1      17340162          jodantubevr@gmail.com    email  846906216443618
# 2      17339832  samanthacollins3333@gmail.com    email  637017535740981
# 3      17339610    sharonritu.sottin@gmail.com    email    3174195076545
# 4      17339336         alisonjgough@gmail.com    email  513915885766959
# ...         ...                            ...      ...              ...
# 23712   3424613  andrewkaye562@btinternet.com     email  474323627022275
# 23713   3424576       AnastasiaGNP@live.co.uk     email  352670088510713
# 23714   3424572        AnastasiaGNP@live.co.uk    email  582293510627406
# 23715   3424548    pippa.dowson@karmagroup.com    email  744025985038564
# 23716   3388976          admin@elementel.co.uk   import            empty
#
#                Full name Gender Age range Location Picture Auth token  ...  \
# 0      Divya Anne Joseph  empty     empty    empty   empty      empty  ...
# 1            Jodan Jacob  empty     empty    empty   empty      empty  ...
# 2       Samantha Collins  empty     empty    empty   empty      empty  ...
# 3          Sharon Sottin  empty     empty    empty   empty      empty  ...
# 4           Alison Gough  empty     empty    empty   empty      empty  ...
# ...                  ...    ...       ...      ...     ...        ...  ...
# 23712        Andrew Kaye  empty     empty    empty   empty      empty  ...
# 23713  Anastasia Nevarez  empty     empty    empty   empty      empty  ...
# 23714  Anastasia Nevarez  empty     empty    empty   empty      empty  ...
# 23715       Pippa Dowson  empty     empty    empty   empty      empty  ...
# 23716         Elemen Tel  empty     empty    empty   empty      empty  ...
#
#       Deleted at Is email validated Is archived Sms subscribed  \
# 0          empty              false       false           true
# 1          empty              false       false           true
# 2          empty              false       false           true
# 3          empty              false       false           true
# 4          empty              false       false           true
# ...          ...                ...         ...            ...
# 23712      empty              false       false          false
# 23713      empty              false       false          false
# 23714      empty              false       false          false
# 23715      empty              false       false           true
# 23716      empty              false       false          false
#
#       Is sms validated Is manual unsubscribe Validated at Validated by  \
# 0                false                 false        empty      pending
# 1                false                 false        empty      pending
# 2                false                 false        empty      pending
# 3                false                 false        empty      pending
# 4                false                 false        empty      pending
# ...                ...                   ...          ...          ...
# 23712            false                 false        empty      pending
# 23713            false                 false        empty      pending
# 23714            false                 false        empty      pending
# 23715            false                 false        empty      pending
# 23716            false                 false        empty      pending
#
#                      filename Mobile
# 0           Karma Bavaria.csv  empty
# 1           Karma Bavaria.csv  empty
# 2           Karma Bavaria.csv  empty
# 3           Karma Bavaria.csv  empty
# 4           Karma Bavaria.csv  empty
# ...                       ...    ...
# 23712  Karma Salford Hall.csv  empty
# 23713  Karma Salford Hall.csv  empty
# 23714  Karma Salford Hall.csv  empty
# 23715  Karma Salford Hall.csv  empty
# 23716  Karma Salford Hall.csv  empty
#
# [23717 rows x 48 columns]

# %%
path = r'G:\.shortcut-targets-by-id\0B_d3smBjzo04eXpvS1NXTWF2RVE\_BOOKING\Booking By Year\FlyBuy Booking Data (BGAU & BGID & KE).xlsx'
df_booking = pd.read_excel(path, dtype='string', sheet_name='BOOKING_BGAU_BGID_KE')

path = r'G:\.shortcut-targets-by-id\0B_d3smBjzo04UUNBME5GOVhoMjA\_ODYSSEY\Phone Members.xlsx'
df_phone = pd.read_excel(path, dtype='string', sheet_name='Sheet1')

path = r'G:\.shortcut-targets-by-id\0B_d3smBjzo04UUNBME5GOVhoMjA\_ODYSSEY\Email Members.xlsx'
df_email = pd.read_excel(path, dtype='string', sheet_name='Sheet1')

# %% [markdown]
# # ====================== Awal Filter Umum ======================

# %%
# data phone, mobile dam email member yang ada di master data (wash member)

m.clean_number(zoho_df, 'Phone')
m.clean_number(zoho_df, 'Mobile')
m.replace_not_valid_to_empty(zoho_df, 'Phone')
m.replace_not_valid_to_empty(zoho_df, 'Mobile')
zoho_df['Email'] = m.lowercase(zoho_df, 'Email')
m.clean_space(zoho_df, 'Email')
m.clean_not_valid_email_format(zoho_df, 'Email')

m.clean_number(df_booking, 'Phone1')
m.clean_number(df_booking, 'Mobile')
df_booking['Email'] = m.lowercase(df_booking, 'Email')
m.clean_space(df_booking, 'Email')
m.clean_not_valid_email_format(df_booking, 'Email')

m.clean_number(df_phone, 'Mobile')

df_email['Email'] = m.lowercase(df_email, 'Email')
m.clean_space(df_email, 'Email')
m.clean_not_valid_email_format(df_email, 'Email')
# Out:
# c:\Users\fajar.fatoni\Documents\Python\Task Offline\zoho_data_app\main_module.py:67: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[df_columns].replace(' ','', regex=True, inplace=True)
# c:\Users\fajar.fatoni\Documents\Python\Task Offline\zoho_data_app\main_module.py:68: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[df_columns].replace('[^0-9]','', regex=True, inplace=True)
# c:\Users\fajar.fatoni\Documents\Python\Task Offline\zoho_data_app\main_module.py:90: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[df_columns].replace(' ','', regex=True, inplace=True)
# c:\Users\fajar.fatoni\Documents\Python\Task Offline\zoho_data_app\main_module.py:67: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[df_columns].replace(' ','', regex=True, inplace=True)
# c:\Users\fajar.fatoni\Documents\Python\Task Offline\zoho_data_app\main_module.py:68: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[df_columns].replace('[^0-9]','', regex=True, inplace=True)
# 'Email'

# %%
count_deleted_wrong_format = m.delete_email_wrong_format(zoho_df, 'Email')
count_after_deleted_wrong_format = zoho_df.shape[0]

# %% [markdown]
# # ====================== Akhir Filter Umum ======================

# %%
# hitung jumlah duplicate
count_duplicate_general = zoho_df.loc[zoho_df.duplicated(subset=['Phone','Mobile','Email','filename'])].shape[0]

zoho_df.loc[zoho_df.duplicated(subset=['Phone','Mobile','Email','filename'])]
# Out:
#             Id                     Email Provider              Uid  \
# 23264  3809427       zuzanie.b@gmail.com    email  839644673554266
# 23405  3612894        lesdix27@gmail.com    email  920174041863104
# 23661  3444478  kelvin.fernandes@sky.com    email  856783743246309
# 23662  3444475  kelvin.fernandes@sky.com    email  242296144265918
# 23664  3444158   markeatkins@hotmail.com    email  625026888570244
# 23684  3436600   harlow.gaines@gmail.com    email  324331651105938
# 23714  3424572   anastasiagnp@live.co.uk    email  582293510627406
#
#                Full name Gender Age range Location Picture Auth token  ...  \
# 23264  Zuzana Brunatova   empty     empty    empty   empty      empty  ...
# 23405            Les Dix  empty     empty    empty   empty      empty  ...
# 23661    Maria Fernandes  empty     empty    empty   empty      empty  ...
# 23662  Kelvin Fernandes   empty     empty    empty   empty      empty  ...
# 23664        Mark Atkins  empty     empty    empty   empty      empty  ...
# 23684       Anita Gaines  empty     empty    empty   empty      empty  ...
# 23714  Anastasia Nevarez  empty     empty    empty   empty      empty  ...
#
#       Deleted at Is email validated Is archived Sms subscribed  \
# 23264      empty              false       false           true
# 23405      empty              false       false           true
# 23661      empty              false       false          false
# 23662      empty              false       false          false
# 23664      empty              false       false          false
# 23684      empty              false       false          false
# 23714      empty              false       false          false
#
#       Is sms validated Is manual unsubscribe Validated at Validated by  \
# 23264            false                 false        empty      pending
# 23405            false                 false        empty      pending
# 23661            false                 false        empty      pending
# 23662            false                 false        empty      pending
# 23664            false                 false        empty      pending
# 23684            false                 false        empty      pending
# 23714            false                 false        empty      pending
#
#                      filename Mobile
# 23264  Karma Salford Hall.csv  empty
# 23405  Karma Salford Hall.csv  empty
# 23661  Karma Salford Hall.csv  empty
# 23662  Karma Salford Hall.csv  empty
# 23664  Karma Salford Hall.csv  empty
# 23684  Karma Salford Hall.csv  empty
# 23714  Karma Salford Hall.csv  empty
#
# [7 rows x 48 columns]

# %%
zoho_df.drop_duplicates(subset=['Phone','Mobile','Email','filename'], inplace=True)
zoho_df.reset_index(drop=True, inplace=True)

# hitung jumlah setelah value duplicate dihapus
count_after_dedup_duplicate = zoho_df.shape[0]

zoho_df
# Out:
#              Id                          Email Provider              Uid  \
# 0      17340163             divyanne@gmail.com    email  239910935240012
# 1      17340162          jodantubevr@gmail.com    email  846906216443618
# 2      17339832  samanthacollins3333@gmail.com    email  637017535740981
# 3      17339610    sharonritu.sottin@gmail.com    email    3174195076545
# 4      17339336         alisonjgough@gmail.com    email  513915885766959
# ...         ...                            ...      ...              ...
# 23705   3425220        danillocooper@gmail.com    email  400917882689601
# 23706   3424613   andrewkaye562@btinternet.com    email  474323627022275
# 23707   3424576        anastasiagnp@live.co.uk    email  352670088510713
# 23708   3424548    pippa.dowson@karmagroup.com    email  744025985038564
# 23709   3388976          admin@elementel.co.uk   import            empty
#
#                Full name Gender Age range Location Picture Auth token  ...  \
# 0      Divya Anne Joseph  empty     empty    empty   empty      empty  ...
# 1            Jodan Jacob  empty     empty    empty   empty      empty  ...
# 2       Samantha Collins  empty     empty    empty   empty      empty  ...
# 3          Sharon Sottin  empty     empty    empty   empty      empty  ...
# 4           Alison Gough  empty     empty    empty   empty      empty  ...
# ...                  ...    ...       ...      ...     ...        ...  ...
# 23705         Dan Cooper  empty     empty    empty   empty      empty  ...
# 23706        Andrew Kaye  empty     empty    empty   empty      empty  ...
# 23707  Anastasia Nevarez  empty     empty    empty   empty      empty  ...
# 23708       Pippa Dowson  empty     empty    empty   empty      empty  ...
# 23709         Elemen Tel  empty     empty    empty   empty      empty  ...
#
#       Deleted at Is email validated Is archived Sms subscribed  \
# 0          empty              false       false           true
# 1          empty              false       false           true
# 2          empty              false       false           true
# 3          empty              false       false           true
# 4          empty              false       false           true
# ...          ...                ...         ...            ...
# 23705      empty              false       false          false
# 23706      empty              false       false          false
# 23707      empty              false       false          false
# 23708      empty              false       false           true
# 23709      empty              false       false          false
#
#       Is sms validated Is manual unsubscribe Validated at Validated by  \
# 0                false                 false        empty      pending
# 1                false                 false        empty      pending
# 2                false                 false        empty      pending
# 3                false                 false        empty      pending
# 4                false                 false        empty      pending
# ...                ...                   ...          ...          ...
# 23705            false                 false        empty      pending
# 23706            false                 false        empty      pending
# 23707            false                 false        empty      pending
# 23708            false                 false        empty      pending
# 23709            false                 false        empty      pending
#
#                      filename Mobile
# 0           Karma Bavaria.csv  empty
# 1           Karma Bavaria.csv  empty
# 2           Karma Bavaria.csv  empty
# 3           Karma Bavaria.csv  empty
# 4           Karma Bavaria.csv  empty
# ...                       ...    ...
# 23705  Karma Salford Hall.csv  empty
# 23706  Karma Salford Hall.csv  empty
# 23707  Karma Salford Hall.csv  empty
# 23708  Karma Salford Hall.csv  empty
# 23709  Karma Salford Hall.csv  empty
#
# [23710 rows x 48 columns]

# %%
# # Cek leads test
# test_leads = zoho_df.loc[
    
#         zoho_df['Email'].str.contains('^test@', flags=re.I, regex=True) |
#         zoho_df['Email'].str.contains('\+test', flags=re.I, regex=True) |
    
#         zoho_df['First Name'].str.contains('^test$', flags=re.I, regex=True) |
#         zoho_df['Last Name'].str.contains('^test$', flags=re.I, regex=True) |

#         zoho_df['First Name'].str.contains('test 1', flags=re.I, regex=True) |
#         zoho_df['Last Name'].str.contains('test 2', flags=re.I, regex=True)|
#         zoho_df['First Name'].str.contains('test1', flags=re.I, regex=True) |
#         zoho_df['Last Name'].str.contains('test2', flags=re.I, regex=True)|

#         zoho_df['First Name'].str.contains(' test ', flags=re.I, regex=True) | 
#         zoho_df['Last Name'].str.contains(' test ', flags=re.I, regex=True) | 
#         zoho_df['Last Name'].str.contains(' test$', flags=re.I, regex=True)
#     ]

# count_leads_test = test_leads.shape[0]

# # test_leads.to_excel(r'C:\Users\fajar.fatoni\Documents\Python\Data\Beambox\test_leads_2.xlsx', index=False)
# test_leads

# %%
# zoho_df.drop(test_leads.index, inplace=True)
# zoho_df.reset_index(drop=True, inplace=True)

# count_after_dedup_test = zoho_df.shape[0]

# %%
# dnm_leads = zoho_df.loc[(zoho_df['Do Not Mail'] == 'true') | (zoho_df['Do Not Contact'] == 'true')]
# count_dnm = dnm_leads.shape[0]

# %%
# zoho_df.drop(dnm_leads.index, inplace=True)
# zoho_df.reset_index(drop=True, inplace=True)

# count_after_dedup_dnm = zoho_df.shape[0]

# %%
# Cek Email OTA
email_OTA = m.find_OTA(zoho_df, 'Email')
count_email_OTA = email_OTA.shape[0]
# email_OTA.to_excel(r'C:\Users\fajar.fatoni\Documents\Python\Data\Beambox\email_OTA.xlsx', index=False)

email_OTA
# Out:
#              Id                        Email Provider              Uid  \
# 7403   11937855      enquiry@duntourscot.com    email   42103320259700
# 7618   11580102       office@scotustours.com    email  587714425966837
# 10164   6941688   toni_coleman24@booking.com    email   51752907840957
# 10566   6484489    beth.clelland@booking.com    email  390672753247243
# 13204  16327740             ankit@yotours.in    email  544092488531487
# 19990   8059496      malc_ontour@yahoo.co.uk    email  599246937832636
# 23231   3876972  emilyoftours@googlemail.com    email  606146226903337
#
#                   Full name Gender Age range Location Picture Auth token  ...  \
# 7403   Duncan Stuart Barker  empty     empty    empty   empty      empty  ...
# 7618          James Wallace  empty     empty    empty   empty      empty  ...
# 10164          Toni Coleman  empty     empty    empty   empty      empty  ...
# 10566         Beth Clelland  empty     empty    empty   empty      empty  ...
# 13204         Ankit Agarwal  empty     empty    empty   empty      empty  ...
# 19990       Malcolm Goodall  empty     empty    empty   empty      empty  ...
# 23231         Emily Kessler  empty     empty    empty   empty      empty  ...
#
#       Deleted at Is email validated Is archived Sms subscribed  \
# 7403       empty              false       false           true
# 7618       empty              false       false           true
# 10164      empty              false       false           true
# 10566      empty              false       false           true
# 13204      empty               true       false           true
# 19990      empty              false       false           true
# 23231      empty              false       false           true
#
#       Is sms validated Is manual unsubscribe             Validated at  \
# 7403             false                 false                    empty
# 7618             false                 false                    empty
# 10164            false                 false                    empty
# 10566            false                 false                    empty
# 13204            false                 false  2024-11-13 16:12:53 UTC
# 19990            false                 false                    empty
# 23231            false                 false                    empty
#
#       Validated by                    filename Mobile
# 7403       pending  Karma Lake of Menteith.csv  empty
# 7618       pending  Karma Lake of Menteith.csv  empty
# 10164      pending  Karma Lake of Menteith.csv  empty
# 10566      pending  Karma Lake of Menteith.csv  empty
# 13204  zero_bounce      Karma Salford Hall.csv  empty
# 19990      pending      Karma Salford Hall.csv  empty
# 23231      pending      Karma Salford Hall.csv  empty
#
# [7 rows x 48 columns]

# %%
# delete email OTA
count_after_clean_OTA = m.delete_OTA(zoho_df, 'Email')
# zoho_df.to_excel(r'C:\Users\fajar.fatoni\Documents\Python\Data\Beambox\after_clean_OTA.xlsx', index=False)

zoho_df
# Out:
#              Id                          Email Provider              Uid  \
# 0      17340163             divyanne@gmail.com    email  239910935240012
# 1      17340162          jodantubevr@gmail.com    email  846906216443618
# 2      17339832  samanthacollins3333@gmail.com    email  637017535740981
# 3      17339610    sharonritu.sottin@gmail.com    email    3174195076545
# 4      17339336         alisonjgough@gmail.com    email  513915885766959
# ...         ...                            ...      ...              ...
# 23698   3425220        danillocooper@gmail.com    email  400917882689601
# 23699   3424613   andrewkaye562@btinternet.com    email  474323627022275
# 23700   3424576        anastasiagnp@live.co.uk    email  352670088510713
# 23701   3424548    pippa.dowson@karmagroup.com    email  744025985038564
# 23702   3388976          admin@elementel.co.uk   import            empty
#
#                Full name Gender Age range Location Picture Auth token  ...  \
# 0      Divya Anne Joseph  empty     empty    empty   empty      empty  ...
# 1            Jodan Jacob  empty     empty    empty   empty      empty  ...
# 2       Samantha Collins  empty     empty    empty   empty      empty  ...
# 3          Sharon Sottin  empty     empty    empty   empty      empty  ...
# 4           Alison Gough  empty     empty    empty   empty      empty  ...
# ...                  ...    ...       ...      ...     ...        ...  ...
# 23698         Dan Cooper  empty     empty    empty   empty      empty  ...
# 23699        Andrew Kaye  empty     empty    empty   empty      empty  ...
# 23700  Anastasia Nevarez  empty     empty    empty   empty      empty  ...
# 23701       Pippa Dowson  empty     empty    empty   empty      empty  ...
# 23702         Elemen Tel  empty     empty    empty   empty      empty  ...
#
#       Deleted at Is email validated Is archived Sms subscribed  \
# 0          empty              false       false           true
# 1          empty              false       false           true
# 2          empty              false       false           true
# 3          empty              false       false           true
# 4          empty              false       false           true
# ...          ...                ...         ...            ...
# 23698      empty              false       false          false
# 23699      empty              false       false          false
# 23700      empty              false       false          false
# 23701      empty              false       false           true
# 23702      empty              false       false          false
#
#       Is sms validated Is manual unsubscribe Validated at Validated by  \
# 0                false                 false        empty      pending
# 1                false                 false        empty      pending
# 2                false                 false        empty      pending
# 3                false                 false        empty      pending
# 4                false                 false        empty      pending
# ...                ...                   ...          ...          ...
# 23698            false                 false        empty      pending
# 23699            false                 false        empty      pending
# 23700            false                 false        empty      pending
# 23701            false                 false        empty      pending
# 23702            false                 false        empty      pending
#
#                      filename Mobile
# 0           Karma Bavaria.csv  empty
# 1           Karma Bavaria.csv  empty
# 2           Karma Bavaria.csv  empty
# 3           Karma Bavaria.csv  empty
# 4           Karma Bavaria.csv  empty
# ...                       ...    ...
# 23698  Karma Salford Hall.csv  empty
# 23699  Karma Salford Hall.csv  empty
# 23700  Karma Salford Hall.csv  empty
# 23701  Karma Salford Hall.csv  empty
# 23702  Karma Salford Hall.csv  empty
#
# [23703 rows x 48 columns]

# %%
# Cek Email Karma
email_karma = m.find_karma(zoho_df, 'Email')
count_email_karma = email_karma.shape[0]
# email_OTA.to_excel(r'C:\Users\fajar.fatoni\Documents\Python\Data\Beambox\email_OTA.xlsx', index=False)

email_karma
# Out:
#              Id                               Email Provider              Uid  \
# 224    17167366         david.beaghe@karmagroup.com    email  301312705791503
# 664    16703370       elisa.lochmann@karmagroup.com    email  806777871755014
# 838    16573978         david.hadson@karmagroup.com    email  134937204202768
# 850    16557242         manish.dubey@karmagroup.com    email  874517062582884
# 984    16381029        lulu.shahirah@karmagroup.com    email  905809911120058
# 1328   16032532               info@karmabavaria.com    email  161325037722136
# 1665   15521615    annemieke.eekhout@karmagroup.com    email  366462920744724
# 2108   15206182       ricardo.coppen@karmagroup.com    email  383520348156266
# 2111   15201258        blue.sunshine@karmagroup.com    email  375236945731776
# 2128   15192937         irvan.fauzie@karmagroup.com   import            empty
# 2204   15065763        nihan.rebello@karmagroup.com    email  220079752830253
# 2577   14840212    petra.hoffmeister@karmagroup.com    email  433489340680247
# 2708   14752168         vic.faulkner@karmagroup.com    email  174870037657945
# 2712   14750252   maurizio.valentini@karmagroup.com    email  858104000452025
# 2714   14749902             events@karmabavaria.com    email  164452534778889
# 2735   14709132       headchef@karmasalfordhall.com    email  695991510603423
# 2952   14565089        chris.kindred@karmagroup.com    email  474764256407658
# 3041   14515953    sebastian.moeller@karmagroup.com    email  931161918524442
# 3777   13955570         tosh.todorov@karmagroup.com    email   57205249262317
# 3952   13871318   valerios.koutsonis@karmagroup.com   import            empty
# 3953   13871183      axel.reimlinger@karmagroup.com    email   70273369341291
# 3959   13871010          reception@karmabavaria.com    email  352180304588676
# 3991   13850424           beambox.kb@karmagroup.com   import            empty
# 4128   17175065          jo.richards@karmagroup.com    email  457038962068270
# 4408   16554659           chris.ward@karmagroup.com    email  234813039843531
# 5530   14538209    joseph.antonishek@karmagroup.com    email  782548752370367
# 5961   14011901         adele.blythe@karmagroup.com    email  458411173649399
# 6232   13701137      david.scheckter@karmagroup.com    email  650737789066695
# 7353   12005744      andrea.pavlidis@karmagroup.com    email  292469127351876
# 7414   11922666         headchef@karmastmartins.com    email  723637531411044
# 7852   11262749        paul.ferguson@karmagroup.com    email  494839158993703
# 8700    9911396             gm@karmasalfordhall.com    email  252835578381344
# 9104    9475390            johnspence88@hotmail.com    email  879915454174614
# 9580    8933058       melanie.hyslop@karmagroup.com    email  471597440508821
# 9795    8566896       neil.aitchison@karmagroup.com    email  943740473650131
# 10213   6860880               gm@karmastmartins.com    email  460676707939217
# 10375   6695734       mihaly.horvath@karmagroup.com    email  166091760384636
# 10501   6535291         maik.schramm@karmagroup.com    email  842441985338138
# 10616   6351659            ruth.liew@karmagroup.com    email  570011845215239
# 11183   5365380           paul.moran@karmagroup.com    email  692709710752737
# 11966   4675493          luisa.nunes@karmagroup.com    email  565949016312097
# 12045   4586715      maria.wedemeier@karmagroup.com    email  754199845784829
# 12200   4414404        chris.diplock@karmagroup.com    email  682665279351696
# 12224   4387911         hanna.thomas@karmagroup.com    email  854689701131109
# 12231   4386806  clinton.albuquerque@karmagroup.com    email  627462989956070
# 12275   4338145        peter.knights@karmagroup.com    email  435817247982478
# 14148  14968865        alex.slabbert@karmagroup.com    email  897534088618038
# 14817  14231192           ash.naciri@karmagroup.com    email   99630763294228
# 16274  12806110                tuna@sanctumsoho.com    email  792797355905116
# 18681   9931892       myral.florindo@karmagroup.com    email  674865830456961
# 19058   9519440          sesh.kandel@karmagroup.com    email  570321807850128
# 19113   9452486           shane.gore@karmagroup.com    email  522198913895026
# 23128   3994255    sebastian.moeller@karmagroup.com    email  138690394330788
# 23133   3990511         scott.fisher@karmagroup.com    email  939641231974967
# 23135   3990475    sebastian.moeller@karmagroup.com    email  546837381807121
# 23551   3489342           judy.yates@karmagroup.com    email  381769052106324
# 23561   3485157       andrew.eastham@karmagroup.com    email  311201424185862
# 23701   3424548         pippa.dowson@karmagroup.com    email  744025985038564
#
#                      Full name Gender Age range Location Picture Auth token  \
# 224               David Beaghe  empty     empty    empty   empty      empty
# 664             Elisa Lochmann  empty     empty    empty   empty      empty
# 838               David Hadson  empty     empty    empty   empty      empty
# 850               Manish Dubey  empty     empty    empty   empty      empty
# 984              Lulu Shahirah  empty     empty    empty   empty      empty
# 1328          Werner Stenschke  empty     empty    empty   empty      empty
# 1665     Annemieke Van Eekhout  empty     empty    empty   empty      empty
# 2108            Ricardo Coppen  empty     empty    empty   empty      empty
# 2111             Blue Sunshine  empty     empty    empty   empty      empty
# 2128              Irvan Fauzie  empty     empty    empty   empty      empty
# 2204             Nihan Rebello  empty     empty    empty   empty      empty
# 2577   Piwi Hoffmeister Saurer  empty     empty    empty   empty      empty
# 2708              Vic Faulkner  empty     empty    empty   empty      empty
# 2712        Maurizio Valentini  empty     empty    empty   empty      empty
# 2714            Elise Williams  empty     empty    empty   empty      empty
# 2735            James Woodhams  empty     empty    empty   empty      empty
# 2952       Christopher Kindred  empty     empty    empty   empty      empty
# 3041         Sebastian Moeller  empty     empty    empty   empty      empty
# 3777              Tosh Todorov  empty     empty    empty   empty      empty
# 3952        Valerios Koutsonis  empty     empty    empty   empty      empty
# 3953           Axel Reimlinger  empty     empty    empty   empty      empty
# 3959             Bose  Shajsja  empty     empty    empty   empty      empty
# 3991              Irvan Fauzie  empty     empty    empty   empty      empty
# 4128               Jo Richards  empty     empty    empty   empty      empty
# 4408                Chris Ward  empty     empty    empty   empty      empty
# 5530         Joseph Antonishek  empty     empty    empty   empty      empty
# 5961              Adele Blythe  empty     empty    empty   empty      empty
# 6232               David David  empty     empty    empty   empty      empty
# 7353           Andrea Pavlidis  empty     empty    empty   empty      empty
# 7414             Anthony Hinds  empty     empty    empty   empty      empty
# 7852             Paul Ferguson  empty     empty    empty   empty      empty
# 8700           Adrian Willmers  empty     empty    empty   empty      empty
# 9104               John Spence  empty     empty    empty   empty      empty
# 9580            Melanie Hyslop  empty     empty    empty   empty      empty
# 9795            Neil Aitchison  empty     empty    empty   empty      empty
# 10213          Martin Hathaway  empty     empty    empty   empty      empty
# 10375           Mihaly Horvath  empty     empty    empty   empty      empty
# 10501             Maik Schramm  empty     empty    empty   empty      empty
# 10616                Ruth Liew  empty     empty    empty   empty      empty
# 11183               Paul Moran  empty     empty    empty   empty      empty
# 11966              Luisa Nunes  empty     empty    empty   empty      empty
# 12045          maria wedemeier  empty     empty    empty   empty      empty
# 12200           Chris  Diplock  empty     empty    empty   empty      empty
# 12224             Hanna Thomas  empty     empty    empty   empty      empty
# 12231     Clinton Albuquerque   empty     empty    empty   empty      empty
# 12275            Peter Knights  empty     empty    empty   empty      empty
# 14148            Alex Slabbert  empty     empty    empty   empty      empty
# 14817               Ash Naciri  empty     empty    empty   empty      empty
# 16274                Tuna Usta  empty     empty    empty   empty      empty
# 18681           Myral Florindo  empty     empty    empty   empty      empty
# 19058              Sesh Kandel  empty     empty    empty   empty      empty
# 19113               Shane Gore  empty     empty    empty   empty      empty
# 23128       Sebastian Moeller   empty     empty    empty   empty      empty
# 23133             Scott Fisher  empty     empty    empty   empty      empty
# 23135       Sebastian Moeller   empty     empty    empty   empty      empty
# 23551               Judy Yates  empty     empty    empty   empty      empty
# 23561           Andrew Eastham  empty     empty    empty   empty      empty
# 23701             Pippa Dowson  empty     empty    empty   empty      empty
#
#        ... Deleted at Is email validated Is archived Sms subscribed  \
# 224    ...      empty              false       false           true
# 664    ...      empty              false       false           true
# 838    ...      empty              false       false           true
# 850    ...      empty              false       false           true
# 984    ...      empty               true       false           true
# 1328   ...      empty               true       false           true
# 1665   ...      empty               true       false           true
# 2108   ...      empty              false       false           true
# 2111   ...      empty              false       false           true
# 2128   ...      empty              false       false          false
# 2204   ...      empty              false       false           true
# 2577   ...      empty               true       false           true
# 2708   ...      empty              false       false           true
# 2712   ...      empty              false       false           true
# 2714   ...      empty              false       false           true
# 2735   ...      empty              false       false           true
# 2952   ...      empty              false       false           true
# 3041   ...      empty              false       false           true
# 3777   ...      empty              false       false           true
# 3952   ...      empty              false       false          false
# 3953   ...      empty              false       false           true
# 3959   ...      empty              false       false           true
# 3991   ...      empty              false       false          false
# 4128   ...      empty              false       false          false
# 4408   ...      empty              false       false          false
# 5530   ...      empty              false       false          false
# 5961   ...      empty              false       false          false
# 6232   ...      empty              false       false          false
# 7353   ...      empty              false       false           true
# 7414   ...      empty              false       false           true
# 7852   ...      empty              false       false           true
# 8700   ...      empty              false       false           true
# 9104   ...      empty              false       false           true
# 9580   ...      empty              false       false           true
# 9795   ...      empty              false       false           true
# 10213  ...      empty              false       false           true
# 10375  ...      empty              false       false           true
# 10501  ...      empty              false       false           true
# 10616  ...      empty              false       false           true
# 11183  ...      empty              false       false           true
# 11966  ...      empty              false       false           true
# 12045  ...      empty              false       false           true
# 12200  ...      empty              false       false           true
# 12224  ...      empty              false       false           true
# 12231  ...      empty              false       false           true
# 12275  ...      empty              false       false           true
# 14148  ...      empty              false       false           true
# 14817  ...      empty              false       false           true
# 16274  ...      empty              false       false           true
# 18681  ...      empty              false       false           true
# 19058  ...      empty              false       false           true
# 19113  ...      empty              false       false           true
# 23128  ...      empty              false       false           true
# 23133  ...      empty              false       false           true
# 23135  ...      empty              false       false           true
# 23551  ...      empty              false       false           true
# 23561  ...      empty              false       false           true
# 23701  ...      empty              false       false           true
#
#       Is sms validated Is manual unsubscribe             Validated at  \
# 224              false                 false                    empty
# 664              false                 false                    empty
# 838              false                 false                    empty
# 850              false                 false                    empty
# 984              false                 false  2024-11-19 09:45:25 UTC
# 1328             false                 false  2024-10-23 17:26:22 UTC
# 1665             false                 false                    empty
# 2108             false                 false                    empty
# 2111             false                 false                    empty
# 2128             false                 false                    empty
# 2204             false                 false                    empty
# 2577             false                 false                    empty
# 2708             false                 false                    empty
# 2712             false                 false                    empty
# 2714             false                 false                    empty
# 2735             false                 false                    empty
# 2952             false                 false                    empty
# 3041             false                 false                    empty
# 3777             false                 false                    empty
# 3952             false                 false                    empty
# 3953             false                 false                    empty
# 3959             false                 false                    empty
# 3991             false                 false                    empty
# 4128             false                 false                    empty
# 4408             false                 false                    empty
# 5530             false                 false                    empty
# 5961             false                 false                    empty
# 6232             false                 false                    empty
# 7353             false                 false                    empty
# 7414             false                 false                    empty
# 7852             false                 false                    empty
# 8700             false                 false                    empty
# 9104             false                 false                    empty
# 9580             false                 false                    empty
# 9795             false                 false                    empty
# 10213            false                 false                    empty
# 10375            false                 false                    empty
# 10501            false                 false                    empty
# 10616            false                 false                    empty
# 11183            false                 false                    empty
# 11966            false                 false                    empty
# 12045            false                 false                    empty
# 12200            false                 false                    empty
# 12224            false                 false                    empty
# 12231            false                 false                    empty
# 12275            false                 false                    empty
# 14148            false                 false                    empty
# 14817            false                 false                    empty
# 16274            false                 false                    empty
# 18681            false                 false                    empty
# 19058            false                 false                    empty
# 19113            false                 false                    empty
# 23128            false                 false                    empty
# 23133            false                 false                    empty
# 23135            false                 false                    empty
# 23551            false                 false                    empty
# 23561            false                 false                    empty
# 23701            false                 false                    empty
#
#       Validated by                    filename Mobile
# 224        pending           Karma Bavaria.csv  empty
# 664        pending           Karma Bavaria.csv  empty
# 838        pending           Karma Bavaria.csv  empty
# 850        pending           Karma Bavaria.csv  empty
# 984    zero_bounce           Karma Bavaria.csv  empty
# 1328   zero_bounce           Karma Bavaria.csv  empty
# 1665   zero_bounce           Karma Bavaria.csv  empty
# 2108       pending           Karma Bavaria.csv  empty
# 2111       pending           Karma Bavaria.csv  empty
# 2128       pending           Karma Bavaria.csv  empty
# 2204       pending           Karma Bavaria.csv  empty
# 2577       pending           Karma Bavaria.csv  empty
# 2708       pending           Karma Bavaria.csv  empty
# 2712       pending           Karma Bavaria.csv  empty
# 2714       pending           Karma Bavaria.csv  empty
# 2735       pending           Karma Bavaria.csv  empty
# 2952       pending           Karma Bavaria.csv  empty
# 3041       pending           Karma Bavaria.csv  empty
# 3777       pending           Karma Bavaria.csv  empty
# 3952       pending           Karma Bavaria.csv  empty
# 3953       pending           Karma Bavaria.csv  empty
# 3959       pending           Karma Bavaria.csv  empty
# 3991       pending           Karma Bavaria.csv  empty
# 4128       pending  Karma Lake of Menteith.csv  empty
# 4408       pending  Karma Lake of Menteith.csv  empty
# 5530       pending  Karma Lake of Menteith.csv  empty
# 5961       pending  Karma Lake of Menteith.csv  empty
# 6232       pending  Karma Lake of Menteith.csv  empty
# 7353       pending  Karma Lake of Menteith.csv  empty
# 7414       pending  Karma Lake of Menteith.csv  empty
# 7852       pending  Karma Lake of Menteith.csv  empty
# 8700       pending  Karma Lake of Menteith.csv  empty
# 9104       pending  Karma Lake of Menteith.csv  empty
# 9580       pending  Karma Lake of Menteith.csv  empty
# 9795       pending  Karma Lake of Menteith.csv  empty
# 10213      pending  Karma Lake of Menteith.csv  empty
# 10375      pending  Karma Lake of Menteith.csv  empty
# 10501      pending  Karma Lake of Menteith.csv  empty
# 10616      pending  Karma Lake of Menteith.csv  empty
# 11183      pending  Karma Lake of Menteith.csv  empty
# 11966      pending  Karma Lake of Menteith.csv  empty
# 12045      pending  Karma Lake of Menteith.csv  empty
# 12200      pending  Karma Lake of Menteith.csv  empty
# 12224      pending  Karma Lake of Menteith.csv  empty
# 12231      pending  Karma Lake of Menteith.csv  empty
# 12275      pending  Karma Lake of Menteith.csv  empty
# 14148      pending      Karma Salford Hall.csv  empty
# 14817      pending      Karma Salford Hall.csv  empty
# 16274      pending      Karma Salford Hall.csv  empty
# 18681      pending      Karma Salford Hall.csv  empty
# 19058      pending      Karma Salford Hall.csv  empty
# 19113      pending      Karma Salford Hall.csv  empty
# 23128      pending      Karma Salford Hall.csv  empty
# 23133      pending      Karma Salford Hall.csv  empty
# 23135      pending      Karma Salford Hall.csv  empty
# 23551      pending      Karma Salford Hall.csv  empty
# 23561      pending      Karma Salford Hall.csv  empty
# 23701      pending      Karma Salford Hall.csv  empty
#
# [58 rows x 48 columns]

# %%
# delete email Karma
count_after_clean_karma = m.delete_karma(zoho_df, 'Email')
# zoho_df.to_excel(r'C:\Users\fajar.fatoni\Documents\Python\Data\Beambox\after_clean_OTA.xlsx', index=False)

zoho_df
# Out:
#              Id                          Email Provider              Uid  \
# 0      17340163             divyanne@gmail.com    email  239910935240012
# 1      17340162          jodantubevr@gmail.com    email  846906216443618
# 2      17339832  samanthacollins3333@gmail.com    email  637017535740981
# 3      17339610    sharonritu.sottin@gmail.com    email    3174195076545
# 4      17339336         alisonjgough@gmail.com    email  513915885766959
# ...         ...                            ...      ...              ...
# 23640   3425230              pct92@yahoo.co.uk    email  712785665995128
# 23641   3425220        danillocooper@gmail.com    email  400917882689601
# 23642   3424613   andrewkaye562@btinternet.com    email  474323627022275
# 23643   3424576        anastasiagnp@live.co.uk    email  352670088510713
# 23644   3388976          admin@elementel.co.uk   import            empty
#
#                Full name Gender Age range Location Picture Auth token  ...  \
# 0      Divya Anne Joseph  empty     empty    empty   empty      empty  ...
# 1            Jodan Jacob  empty     empty    empty   empty      empty  ...
# 2       Samantha Collins  empty     empty    empty   empty      empty  ...
# 3          Sharon Sottin  empty     empty    empty   empty      empty  ...
# 4           Alison Gough  empty     empty    empty   empty      empty  ...
# ...                  ...    ...       ...      ...     ...        ...  ...
# 23640        Phil Turner  empty     empty    empty   empty      empty  ...
# 23641         Dan Cooper  empty     empty    empty   empty      empty  ...
# 23642        Andrew Kaye  empty     empty    empty   empty      empty  ...
# 23643  Anastasia Nevarez  empty     empty    empty   empty      empty  ...
# 23644         Elemen Tel  empty     empty    empty   empty      empty  ...
#
#       Deleted at Is email validated Is archived Sms subscribed  \
# 0          empty              false       false           true
# 1          empty              false       false           true
# 2          empty              false       false           true
# 3          empty              false       false           true
# 4          empty              false       false           true
# ...          ...                ...         ...            ...
# 23640      empty              false       false           true
# 23641      empty              false       false          false
# 23642      empty              false       false          false
# 23643      empty              false       false          false
# 23644      empty              false       false          false
#
#       Is sms validated Is manual unsubscribe Validated at Validated by  \
# 0                false                 false        empty      pending
# 1                false                 false        empty      pending
# 2                false                 false        empty      pending
# 3                false                 false        empty      pending
# 4                false                 false        empty      pending
# ...                ...                   ...          ...          ...
# 23640            false                 false        empty      pending
# 23641            false                 false        empty      pending
# 23642            false                 false        empty      pending
# 23643            false                 false        empty      pending
# 23644            false                 false        empty      pending
#
#                      filename Mobile
# 0           Karma Bavaria.csv  empty
# 1           Karma Bavaria.csv  empty
# 2           Karma Bavaria.csv  empty
# 3           Karma Bavaria.csv  empty
# 4           Karma Bavaria.csv  empty
# ...                       ...    ...
# 23640  Karma Salford Hall.csv  empty
# 23641  Karma Salford Hall.csv  empty
# 23642  Karma Salford Hall.csv  empty
# 23643  Karma Salford Hall.csv  empty
# 23644  Karma Salford Hall.csv  empty
#
# [23645 rows x 48 columns]

# %%
find_member_booking = zoho_df.copy()

find_member_booking.loc[find_member_booking['Phone'].isin(df_booking['Phone1']), 'Same Value Find'] = 'Booking-Phone1'
find_member_booking.loc[find_member_booking['Phone'].isin(df_booking['Mobile']), 'Same Value Find'] = 'Booking-Mobile'
find_member_booking.loc[find_member_booking['Mobile'].isin(df_booking['Phone1']), 'Same Value Find'] = 'Booking-Phone1' 
find_member_booking.loc[find_member_booking['Mobile'].isin(df_booking['Mobile']), 'Same Value Find'] = 'Booking-Mobile'
find_member_booking.loc[find_member_booking['Email'].isin(df_booking['Email']), 'Same Value Find'] = 'Booking-Email'

find_member_booking.loc[find_member_booking['Phone'].isin(df_phone['Mobile']), 'Same Value Find'] = 'Member-Mobile' 
find_member_booking.loc[find_member_booking['Mobile'].isin(df_phone['Mobile']), 'Same Value Find'] = 'Member-Mobile'

find_member_booking.loc[find_member_booking['Email'].isin(df_email['Email']), 'Same Value Find'] = 'Member-Email'

find_member_booking.drop(find_member_booking.loc[find_member_booking['Same Value Find'].isna()].index, inplace=True)

count_booking_dedup = find_member_booking.loc[find_member_booking['Same Value Find'].str.contains('Booking', flags=re.I, regex=True)].shape[0]
count_member_dedup = find_member_booking.loc[find_member_booking['Same Value Find'].str.contains('Member', flags=re.I, regex=True)].shape[0]

find_member_booking.replace('empty', '', inplace=True)
# find_member_booking.to_csv(r'C:\Users\fajar.fatoni\Documents\Python\Data\Beambox\booking-member-dedup.csv', index=False)
# find_member_booking.to_excel(r'C:\Users\fajar.fatoni\Documents\Python\Data\Beambox\booking-member-dedup.xlsx', index=False)

#find_member_booking.loc[find_member_booking['Same Value Find'] == 'Booking-Phone1']

# %%
# data phone, mobile dam email member yang ada di master data 
count_wash_member = zoho_df.loc[
    zoho_df['Phone'].isin(df_booking['Phone1']) | 
    zoho_df['Phone'].isin(df_booking['Mobile']) |
    zoho_df['Mobile'].isin(df_booking['Phone1']) | 
    zoho_df['Mobile'].isin(df_booking['Mobile']) |
    zoho_df['Email'].isin(df_booking['Email'])| 

    zoho_df['Phone'].isin(df_phone['Mobile']) | 
    zoho_df['Mobile'].isin(df_phone['Mobile']) |

    zoho_df['Email'].isin(df_email['Email'])

].shape[0]

zoho_df.drop(zoho_df.loc[
    zoho_df['Phone'].isin(df_booking['Phone1']) | 
    zoho_df['Phone'].isin(df_booking['Mobile']) |
    zoho_df['Mobile'].isin(df_booking['Phone1']) | 
    zoho_df['Mobile'].isin(df_booking['Mobile']) |
    zoho_df['Email'].isin(df_booking['Email']) |
    
    zoho_df['Phone'].isin(df_phone['Mobile']) | 
    zoho_df['Mobile'].isin(df_phone['Mobile']) |

    zoho_df['Email'].isin(df_email['Email'])

    ].index, inplace=True)
    
zoho_df.reset_index(drop=True, inplace=True)

count_after_wash_member = zoho_df.shape[0]

# %%
count_email_only = zoho_df.loc[(zoho_df['Email'] != 'empty') & ((zoho_df['Phone'] == 'empty') & (zoho_df['Mobile'] == 'empty'))].shape[0]
count_phone_only = zoho_df.loc[(zoho_df['Email'] == 'empty') & ((zoho_df['Phone'] != 'empty') | (zoho_df['Mobile'] != 'empty'))].shape[0]
count_email_and_phone = zoho_df.loc[(zoho_df['Email'] != 'empty') & ((zoho_df['Phone'] != 'empty') | (zoho_df['Mobile'] != 'empty'))].shape[0]

count_blank = zoho_df.loc[(zoho_df['Email'] =='empty') & (zoho_df['Phone']=='empty') & (zoho_df['Mobile']=='empty')].shape[0]

# zoho_df.loc[(zoho_df['Email'] =='empty') & (zoho_df['Phone']=='empty') & (zoho_df['Mobile']=='empty')].to_excel(r'C:\Users\fajar.fatoni\Documents\Python\Data\Beambox\blank_data.xlsx', index=False)

zoho_df.loc[(zoho_df['Email'] != 'empty') & ((zoho_df['Phone'] == 'empty') & (zoho_df['Mobile'] == 'empty')), 'Contact Type'] = 'Email Only'
zoho_df.loc[(zoho_df['Email'] == 'empty') & ((zoho_df['Phone'] != 'empty') | (zoho_df['Mobile'] != 'empty')), 'Contact Type'] = 'Phone Only'
zoho_df.loc[(zoho_df['Email'] != 'empty') & ((zoho_df['Phone'] != 'empty') | (zoho_df['Mobile'] != 'empty')), 'Contact Type'] = 'Email and Phone'

zoho_df.drop(zoho_df.loc[(zoho_df['Email'] =='empty') & (zoho_df['Phone']=='empty') & (zoho_df['Mobile']=='empty')].index, inplace=True)
zoho_df.reset_index(drop=True, inplace=True)

count_after_wash_blank = zoho_df.shape[0]

# %%
arr_dedup = [count_deleted_wrong_format, count_duplicate_general, count_email_OTA, count_email_karma, count_blank]
count_sum_dedup = sum(arr_dedup)
count_sum_dedup
# Out:
# 73

# %%
print("==========================================================")
print("Summary")
print("==========================================================")
print("Jumlah Filter Leads Awal : "+str(count_filter_awal))
print("Jumlah Format Email Salah : "+str(count_deleted_wrong_format))
print("Jumlah Setelah Clean Format Email Salah : "+str(count_after_deleted_wrong_format))
print("Jumlah Duplicate (Phone, Mobile dan Email) : "+str(count_duplicate_general))
print("Jumlah Setelah Clean Duplicate : "+str(count_after_dedup_duplicate))
# print("Jumlah Lead Test : "+str(count_leads_test))
# print("Jumlah Setelah Clean Lead Test : "+str(count_after_dedup_test))
# print("Jumlah Lead Do Not Mail : "+str(count_dnm))
# print("Jumlah Setelah Clean Lead Do Not Mail : "+str(count_after_dedup_dnm))
print("Jumlah Email OTA : "+str(count_email_OTA))
print("Jumlah Setelah Clean Email OTA : "+str(count_after_clean_OTA))
print("Jumlah Email Karma : "+str(count_email_karma))
print("Jumlah Setelah Clean Email Karma : "+str(count_after_clean_karma))
print("Jumlah Wash Member : "+str(count_member_dedup))
print("Jumlah Wash Booking : "+str(count_booking_dedup))
print("Jumlah Setelah Wash Member : "+str(count_after_wash_member))
print("Jumlah Phone Email Blank (Setelah phone yang tidak valid dihapus) : "+str(count_blank))
print("Jumlah Setelah Wash Phone Email Blank : "+str(count_after_wash_blank))
print("==========================================================")
print("Contact Type")
print("==========================================================")
print("Jumlah Email Only : "+str(count_email_only))
print("Jumlah Phone Only : "+str(count_phone_only))
print("Jumlah Email dan Phone : "+str(count_email_and_phone))
# Out:
# ==========================================================
# Summary
# ==========================================================
# Jumlah Filter Leads Awal : 23717
# Jumlah Format Email Salah : 0
# Jumlah Setelah Clean Format Email Salah : 23717
# Jumlah Duplicate (Phone, Mobile dan Email) : 7
# Jumlah Setelah Clean Duplicate : 23710
# Jumlah Email OTA : 7
# Jumlah Setelah Clean Email OTA : 23703
# Jumlah Email Karma : 58
# Jumlah Setelah Clean Email Karma : 23645
# Jumlah Wash Member : 4202
# Jumlah Wash Booking : 19
# Jumlah Setelah Wash Member : 19424
# Jumlah Phone Email Blank (Setelah phone yang tidak valid dihapus) : 1
# Jumlah Setelah Wash Phone Email Blank : 19423
# ==========================================================
# Contact Type
# ==========================================================
# Jumlah Email Only : 2689
# Jumlah Phone Only : 0
# Jumlah Email dan Phone : 16734

# %%
print("==========================================================")
print("Summary Report")
print("==========================================================")
print("Jumlah Data Awal : "+str(count_filter_awal))
print("Jumlah Wash Dedup : "+str(count_sum_dedup))
print("Jumlah Wash Member : "+str(count_member_dedup))
print("Jumlah Wash Booking : "+str(count_booking_dedup))
print("Jumlah Data Akhir : "+str(count_after_wash_blank))
# Out:
# ==========================================================
# Summary Report
# ==========================================================
# Jumlah Data Awal : 23717
# Jumlah Wash Dedup : 73
# Jumlah Wash Member : 4202
# Jumlah Wash Booking : 19
# Jumlah Data Akhir : 19423

# %%
zoho_df.replace('empty', '', inplace=True, regex=True)

# zoho_df['First Name'] = zoho_df['First Name'].str.title()
# zoho_df['Last Name'] = zoho_df['Last Name'].str.title()

# zoho_df.to_csv(r'C:\Users\fajar.fatoni\Documents\Python\Data\Beambox\karma beach cleand.csv', index=False)
zoho_df.to_excel(r'C:\Users\fajar.fatoni\Documents\Python\Data\Beambox\df_beambox_clean.xlsx', index=False)
