# %%
import main_module as m
import zoho_filter_module as fil
import pandas as pd
import re
import numpy as np

# %load_ext autoreload
# %autoreload 2

cols = ['Record Id',	
'Created Time',
'Created Date',	
'First Name',	
'Last Name',	
'Email',	
'Phone',	
'Mobile',	
'Birthdate',	
'Year of Birth',
'Street',	
'Street2',	
'City',	
'State',	
'Country',	
'Nationality',
'Booking Status', 
'BookRef',
'Departure Date',	
'Arrival Date',	
'Card Type',	
'Marital Status',	
'Lead Brand',	
'Lead Sub-Brand',	
'Lead Source',	
'Lead Locations',	
'Lead Source Description',	
'Lead Regions',
'Lead Status',
'Email Opt Out',	
'Opt In']
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
path = r'C:\Users\fajar.fatoni\Documents\Python\Data\Leads_2025_04_08.csv'
zoho_df = pd.read_csv(path, dtype='string')
# zoho_df = pd.read_excel(path, dtype='string', sheet_name='KK Wedding Leads')

zoho_df.reset_index(drop=True, inplace=True)
count_filter_awal = zoho_df.shape[0]

# mengisi kolom <NA> dengan value string 'empty' supaya mudah mengecek data member dan booking dengan isin
zoho_df.fillna('empty', inplace=True)

zoho_df['Mobile'] = 'empty'
# zoho_df['Phone'] = 'empty'
zoho_df
# Out:
#                      Record Id         Created Time Created Date Salutation  \
# 0     zcrm_3584690000472588119  2023-12-12 16:32:25   2022-10-01      empty
# 1     zcrm_3584690000472588120  2023-12-12 16:32:25   2022-10-01      empty
# 2     zcrm_3584690000472588121  2023-12-12 16:32:25   2022-10-01      empty
# 3     zcrm_3584690000472588122  2023-12-12 16:32:25   2022-10-01      empty
# 4     zcrm_3584690000472588125  2023-12-12 16:32:25   2022-10-01      empty
# ...                        ...                  ...          ...        ...
# 8840  zcrm_3584690000536494033  2025-04-07 18:02:44   2025-04-07      empty
# 8841  zcrm_3584690000536495033  2025-04-07 17:26:22   2025-04-07      empty
# 8842  zcrm_3584690000536495071  2025-04-07 17:26:52   2025-04-07        Mrs
# 8843  zcrm_3584690000536802001  2025-04-07 18:01:43   2025-04-07      empty
# 8844  zcrm_3584690000536803001  2025-04-07 18:02:13   2025-04-07      empty
#
#      First Name    Last Name                       Email             Phone  \
# 0           Dea  Kristiansen                       empty        2147483647
# 1          Orin            -                       empty        2147483647
# 2          Ardi            -                       empty        2147483647
# 3        Amalia            -                       empty        2147483647
# 4         Merry            -                       empty        2147483647
# ...         ...          ...                         ...               ...
# 8840    Michael            .                       empty   +62817-6337-954
# 8841    Georgie       Wright  georgiewright8@hotmail.com      +61406162554
# 8842     Joanne        Yahoo    asljoanne85@yahoo.com.sg             empty
# 8843      Cindy      Cecilia                       empty  +62877-7605-0001
# 8844      Galih      Ginting                       empty  +62812-9359-9596
#
#      Country     Lead Brand  \
# 0      empty  Karma Resorts
# 1      empty  Karma Resorts
# 2      empty  Karma Resorts
# 3      empty  Karma Resorts
# 4      empty  Karma Resorts
# ...      ...            ...
# 8840   empty  Karma Resorts
# 8841   empty  Karma Resorts
# 8842   empty  Karma Resorts
# 8843   empty  Karma Resorts
# 8844   empty  Karma Resorts
#
#                                                Messages Lead Sub-Brand  \
# 0                                                 empty          Other
# 1                                                 empty          Other
# 2                                                 empty          Other
# 3                                                 empty          Other
# 4                                                 empty          Other
# ...                                                 ...            ...
# 8840                                              empty          Other
# 8841                                              empty          Other
# 8842                                              empty          Other
# 8843                                              empty          Other
# 8844  Click Last Minutes Offer, asking for details, ...          Other
#
#            Lead Source Lead Locations                Lead Source Description  \
# 0     WhatsApp Enquiry  Karma Kandara                       WhatsApp Channel
# 1     WhatsApp Enquiry  Karma Kandara                       WhatsApp Channel
# 2     WhatsApp Enquiry  Karma Kandara                       WhatsApp Channel
# 3     WhatsApp Enquiry  Karma Kandara                       WhatsApp Channel
# 4     WhatsApp Enquiry  Karma Kandara                       WhatsApp Channel
# ...                ...            ...                                    ...
# 8840  WhatsApp Enquiry  Karma Kandara  Karma Reservations - WhatsApp Channel
# 8841  WhatsApp Enquiry  Karma Kandara  Karma Reservations - WhatsApp Channel
# 8842  WhatsApp Enquiry  Karma Kandara  Karma Reservations - WhatsApp Channel
# 8843  WhatsApp Enquiry  Karma Kandara  Karma Reservations - WhatsApp Channel
# 8844  WhatsApp Enquiry  Karma Kandara  Karma Reservations - WhatsApp Channel
#
#                                            Lead History      Contact Label  \
# 0     Interest for Karma Beach, entrance fee, hostin...      WA Leads, KBB
# 1     Interest for Karma Beach, entrance fee, hostin...   Phone Leads, KBB
# 2     Interest for Karma Beach, entrance fee, hostin...   Phone Leads, KBB
# 3     Interest for Karma Beach, entrance fee, hostin...   Phone Leads, KBB
# 4     Interest for Karma Beach, entrance fee, hostin...   Phone Leads, KBB
# ...                                                 ...                ...
# 8840  Interest for Karma Beach, entrance fee, hostin...      WA Leads, KBB
# 8841  Inquiry for Karma Experience promotion-inform ...              empty
# 8842                       Check availability and rates              empty
# 8843                    Interest for Di Mare Restaurant  WA Leads, di Mare
# 8844                                             Others           WA Leads
#
#      Mobile
# 0     empty
# 1     empty
# 2     empty
# 3     empty
# 4     empty
# ...     ...
# 8840  empty
# 8841  empty
# 8842  empty
# 8843  empty
# 8844  empty
#
# [8845 rows x 18 columns]

# %%
path = r'G:\.shortcut-targets-by-id\0B_d3smBjzo04eXpvS1NXTWF2RVE\_BOOKING\Booking By Year\FlyBuy Booking Data (BGAU & BGID & KE).xlsx'
df_booking = pd.read_excel(path, dtype='string', sheet_name='BOOKING_BGAU_BGID_KE')

path = r'G:\.shortcut-targets-by-id\0B_d3smBjzo04UUNBME5GOVhoMjA\_ODYSSEY\Phone Members.xlsx'
df_phone = pd.read_excel(path, dtype='string', sheet_name='Sheet1')

path = r'G:\.shortcut-targets-by-id\0B_d3smBjzo04UUNBME5GOVhoMjA\_ODYSSEY\Email Members.xlsx'
df_email = pd.read_excel(path, dtype='string', sheet_name='Sheet1')

# %% [markdown]
# # ====================== Awal Filter Umum ======================

# %%
# data phone, mobile dam email member yang ada di master data (wash member)

m.clean_number(zoho_df, 'Phone')
m.clean_number(zoho_df, 'Mobile')
m.replace_not_valid_to_empty(zoho_df, 'Phone')
m.replace_not_valid_to_empty(zoho_df, 'Mobile')
zoho_df['Email'] = m.lowercase(zoho_df, 'Email')
m.clean_space(zoho_df, 'Email')
m.clean_not_valid_email_format(zoho_df, 'Email')

m.clean_number(df_booking, 'Phone1')
m.clean_number(df_booking, 'Mobile')
df_booking['Email'] = m.lowercase(df_booking, 'Email')
m.clean_space(df_booking, 'Email')
m.clean_not_valid_email_format(df_booking, 'Email')

m.clean_number(df_phone, 'Mobile')

df_email['Email'] = m.lowercase(df_email, 'Email')
m.clean_space(df_email, 'Email')
m.clean_not_valid_email_format(df_email, 'Email')
# Out:
# c:\Users\fajar.fatoni\Documents\Python\Task Offline\zoho_data_app\main_module.py:71: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[df_columns].replace(' ','', regex=True, inplace=True)
# c:\Users\fajar.fatoni\Documents\Python\Task Offline\zoho_data_app\main_module.py:72: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[df_columns].replace('[^0-9]','', regex=True, inplace=True)
# c:\Users\fajar.fatoni\Documents\Python\Task Offline\zoho_data_app\main_module.py:94: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[df_columns].replace(' ','', regex=True, inplace=True)
# c:\Users\fajar.fatoni\Documents\Python\Task Offline\zoho_data_app\main_module.py:71: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[df_columns].replace(' ','', regex=True, inplace=True)
# c:\Users\fajar.fatoni\Documents\Python\Task Offline\zoho_data_app\main_module.py:72: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[df_columns].replace('[^0-9]','', regex=True, inplace=True)
# 'Email'

# %%
count_deleted_wrong_format = m.delete_email_wrong_format(zoho_df, 'Email')
count_after_deleted_wrong_format = zoho_df.shape[0]

# %% [markdown]
# # ====================== Akhir Filter Umum ======================

# %%
# hitung jumlah duplicate
count_duplicate_general = zoho_df.loc[zoho_df.duplicated(subset=['Phone','Mobile','Email','Lead History'])].shape[0]

zoho_df.loc[zoho_df.duplicated(subset=['Phone','Mobile','Email','Lead History'])]
# Out:
#                      Record Id         Created Time Created Date Salutation  \
# 1     zcrm_3584690000472588120  2023-12-12 16:32:25   2022-10-01      empty
# 2     zcrm_3584690000472588121  2023-12-12 16:32:25   2022-10-01      empty
# 3     zcrm_3584690000472588122  2023-12-12 16:32:25   2022-10-01      empty
# 4     zcrm_3584690000472588125  2023-12-12 16:32:25   2022-10-01      empty
# 6     zcrm_3584690000472588128  2023-12-12 16:32:25   2022-10-01      empty
# ...                        ...                  ...          ...        ...
# 8653  zcrm_3584690000534489001  2025-03-24 18:51:36   2025-03-24         Mr
# 8713  zcrm_3584690000535454001  2025-04-01 17:59:56   2025-04-01      empty
# 8813  zcrm_3584690000535985001  2025-04-04 14:41:30   2025-04-04      empty
# 8825  zcrm_3584690000536153043  2025-04-06 16:00:01   2025-04-06         Mr
# 8830  zcrm_3584690000536330001  2025-04-05 20:37:14   2025-04-05      empty
#
#      First Name Last Name  Email          Phone Country     Lead Brand  \
# 1          Orin         -  empty     2147483647   empty  Karma Resorts
# 2          Ardi         -  empty     2147483647   empty  Karma Resorts
# 3        Amalia         -  empty     2147483647   empty  Karma Resorts
# 4         Merry         -  empty     2147483647   empty  Karma Resorts
# 6        Sheila         -  empty     2147483647   empty  Karma Resorts
# ...         ...       ...    ...            ...     ...            ...
# 8653      Amish     Doshi  empty   918879646406   empty  Karma Resorts
# 8713          -         -  empty   966558391160   empty  Karma Resorts
# 8813      ~Sasa     Bozic  empty    38641662231   empty  Karma Resorts
# 8825     Nathan   Earsman  empty    61418279256   empty  Karma Resorts
# 8830        DMC         -  empty  6285230197700   empty  Karma Resorts
#
#      Messages Lead Sub-Brand       Lead Source Lead Locations  \
# 1       empty          Other  WhatsApp Enquiry  Karma Kandara
# 2       empty          Other  WhatsApp Enquiry  Karma Kandara
# 3       empty          Other  WhatsApp Enquiry  Karma Kandara
# 4       empty          Other  WhatsApp Enquiry  Karma Kandara
# 6       empty          Other  WhatsApp Enquiry  Karma Kandara
# ...       ...            ...               ...            ...
# 8653    empty          Other  WhatsApp Enquiry  Karma Kandara
# 8713    empty          Other  WhatsApp Enquiry  Karma Kandara
# 8813    empty          Other  WhatsApp Enquiry  Karma Kandara
# 8825    empty          Other  WhatsApp Enquiry  Karma Kandara
# 8830    empty          Other  WhatsApp Enquiry  Karma Kandara
#
#                     Lead Source Description  \
# 1                          WhatsApp Channel
# 2                          WhatsApp Channel
# 3                          WhatsApp Channel
# 4                          WhatsApp Channel
# 6                          WhatsApp Channel
# ...                                     ...
# 8653  Karma Reservations - WhatsApp Channel
# 8713  Karma Reservations - WhatsApp Channel
# 8813  Karma Reservations - WhatsApp Channel
# 8825  Karma Reservations - WhatsApp Channel
# 8830  Karma Reservations - WhatsApp Channel
#
#                                            Lead History         Contact Label  \
# 1     Interest for Karma Beach, entrance fee, hostin...      Phone Leads, KBB
# 2     Interest for Karma Beach, entrance fee, hostin...      Phone Leads, KBB
# 3     Interest for Karma Beach, entrance fee, hostin...      Phone Leads, KBB
# 4     Interest for Karma Beach, entrance fee, hostin...      Phone Leads, KBB
# 6     Interest for Karma Beach, entrance fee, hostin...         WA Leads, KBB
# ...                                                 ...                   ...
# 8653  Membership inquiry, forward to Karma Concierge...  WA Leads, Membership
# 8713  Interest for Karma Beach, entrance fee, hostin...         WA Leads, KBB
# 8813  Interest for Karma Beach, entrance fee, hostin...         WA Leads, KBB
# 8825                          Reconfirm booking/payment       WA Leads, Villa
# 8830  Interest for Karma Beach, entrance fee, hostin...         WA Leads, KBB
#
#      Mobile
# 1     empty
# 2     empty
# 3     empty
# 4     empty
# 6     empty
# ...     ...
# 8653  empty
# 8713  empty
# 8813  empty
# 8825  empty
# 8830  empty
#
# [1042 rows x 18 columns]

# %%
zoho_df.drop_duplicates(subset=['Phone','Mobile','Email','Lead History'], inplace=True)
zoho_df.reset_index(drop=True, inplace=True)

# hitung jumlah setelah value duplicate dihapus
count_after_dedup_duplicate = zoho_df.shape[0]

zoho_df
# Out:
#                      Record Id         Created Time Created Date Salutation  \
# 0     zcrm_3584690000472588119  2023-12-12 16:32:25   2022-10-01      empty
# 1     zcrm_3584690000472588127  2023-12-12 16:32:25   2022-10-01      empty
# 2     zcrm_3584690000472588129  2023-12-12 16:32:25   2022-10-01      empty
# 3     zcrm_3584690000472588130  2023-12-12 16:32:25   2022-10-01      empty
# 4     zcrm_3584690000472588131  2023-12-12 16:32:25   2022-10-01      empty
# ...                        ...                  ...          ...        ...
# 7798  zcrm_3584690000536494033  2025-04-07 18:02:44   2025-04-07      empty
# 7799  zcrm_3584690000536495033  2025-04-07 17:26:22   2025-04-07      empty
# 7800  zcrm_3584690000536495071  2025-04-07 17:26:52   2025-04-07        Mrs
# 7801  zcrm_3584690000536802001  2025-04-07 18:01:43   2025-04-07      empty
# 7802  zcrm_3584690000536803001  2025-04-07 18:02:13   2025-04-07      empty
#
#         First Name    Last Name                       Email          Phone  \
# 0              Dea  Kristiansen                       empty     2147483647
# 1              Zoe       Bishop                       empty     2147483647
# 2          Yogi Ap            -                       empty     2147483647
# 3             Jack   Sutherland                       empty     2147483647
# 4     Ni Gusti Ayu     Nanditha                       empty     2147483647
# ...            ...          ...                         ...            ...
# 7798       Michael            .                       empty   628176337954
# 7799       Georgie       Wright  georgiewright8@hotmail.com    61406162554
# 7800        Joanne        Yahoo    asljoanne85@yahoo.com.sg          empty
# 7801         Cindy      Cecilia                       empty  6287776050001
# 7802         Galih      Ginting                       empty  6281293599596
#
#      Country     Lead Brand  \
# 0      empty  Karma Resorts
# 1      empty  Karma Resorts
# 2      empty  Karma Resorts
# 3      empty  Karma Resorts
# 4      empty  Karma Resorts
# ...      ...            ...
# 7798   empty  Karma Resorts
# 7799   empty  Karma Resorts
# 7800   empty  Karma Resorts
# 7801   empty  Karma Resorts
# 7802   empty  Karma Resorts
#
#                                                Messages Lead Sub-Brand  \
# 0                                                 empty          Other
# 1                                                 empty          Other
# 2                                                 empty          Other
# 3                                                 empty          Other
# 4                                                 empty          Other
# ...                                                 ...            ...
# 7798                                              empty          Other
# 7799                                              empty          Other
# 7800                                              empty          Other
# 7801                                              empty          Other
# 7802  Click Last Minutes Offer, asking for details, ...          Other
#
#            Lead Source Lead Locations                Lead Source Description  \
# 0     WhatsApp Enquiry  Karma Kandara                       WhatsApp Channel
# 1     WhatsApp Enquiry  Karma Kandara                       WhatsApp Channel
# 2     WhatsApp Enquiry  Karma Kandara                       WhatsApp Channel
# 3     WhatsApp Enquiry  Karma Kandara                       WhatsApp Channel
# 4     WhatsApp Enquiry  Karma Kandara                       WhatsApp Channel
# ...                ...            ...                                    ...
# 7798  WhatsApp Enquiry  Karma Kandara  Karma Reservations - WhatsApp Channel
# 7799  WhatsApp Enquiry  Karma Kandara  Karma Reservations - WhatsApp Channel
# 7800  WhatsApp Enquiry  Karma Kandara  Karma Reservations - WhatsApp Channel
# 7801  WhatsApp Enquiry  Karma Kandara  Karma Reservations - WhatsApp Channel
# 7802  WhatsApp Enquiry  Karma Kandara  Karma Reservations - WhatsApp Channel
#
#                                            Lead History  \
# 0     Interest for Karma Beach, entrance fee, hostin...
# 1                            Reconfirm the rest payment
# 2                                          Advertisment
# 3      Interest for Spa-inform Karma Spa contact number
# 4                              Check villa availability
# ...                                                 ...
# 7798  Interest for Karma Beach, entrance fee, hostin...
# 7799  Inquiry for Karma Experience promotion-inform ...
# 7800                       Check availability and rates
# 7801                    Interest for Di Mare Restaurant
# 7802                                             Others
#
#                 Contact Label Mobile
# 0               WA Leads, KBB  empty
# 1     WA Leads, Villa, Repeat  empty
# 2                 WA Supplier  empty
# 3               WA Leads, Spa  empty
# 4             WA Leads, Villa  empty
# ...                       ...    ...
# 7798            WA Leads, KBB  empty
# 7799                    empty  empty
# 7800                    empty  empty
# 7801        WA Leads, di Mare  empty
# 7802                 WA Leads  empty
#
# [7803 rows x 18 columns]

# %%
# # Cek leads test
# test_leads = zoho_df.loc[
    
#         zoho_df['Email'].str.contains('^test@', flags=re.I, regex=True) |
#         zoho_df['Email'].str.contains('\+test', flags=re.I, regex=True) |
    
#         zoho_df['First Name'].str.contains('^test$', flags=re.I, regex=True) |
#         zoho_df['Last Name'].str.contains('^test$', flags=re.I, regex=True) |

#         zoho_df['First Name'].str.contains('test 1', flags=re.I, regex=True) |
#         zoho_df['Last Name'].str.contains('test 2', flags=re.I, regex=True)|
#         zoho_df['First Name'].str.contains('test1', flags=re.I, regex=True) |
#         zoho_df['Last Name'].str.contains('test2', flags=re.I, regex=True)|

#         zoho_df['First Name'].str.contains(' test ', flags=re.I, regex=True) | 
#         zoho_df['Last Name'].str.contains(' test ', flags=re.I, regex=True) | 
#         zoho_df['Last Name'].str.contains(' test$', flags=re.I, regex=True)
#     ]

# count_leads_test = test_leads.shape[0]

# # test_leads.to_excel(r'C:\Users\fajar.fatoni\Documents\Python\Data\Beambox\test_leads_2.xlsx', index=False)
# test_leads

# %%
# zoho_df.drop(test_leads.index, inplace=True)
# zoho_df.reset_index(drop=True, inplace=True)

# count_after_dedup_test = zoho_df.shape[0]

# %%
# dnm_leads = zoho_df.loc[(zoho_df['Do Not Mail'] == 'true') | (zoho_df['Do Not Contact'] == 'true')]
# count_dnm = dnm_leads.shape[0]

# %%
# zoho_df.drop(dnm_leads.index, inplace=True)
# zoho_df.reset_index(drop=True, inplace=True)

# count_after_dedup_dnm = zoho_df.shape[0]

# %%
# Cek Email OTA
email_OTA = m.find_OTA(zoho_df, 'Email')
count_email_OTA = email_OTA.shape[0]
# email_OTA.to_excel(r'C:\Users\fajar.fatoni\Documents\Python\Data\Beambox\email_OTA.xlsx', index=False)

email_OTA
# Out:
#                      Record Id         Created Time Created Date Salutation  \
# 1367  zcrm_3584690000492594355  2024-04-21 16:01:01   2024-04-21        Mrs
# 1389  zcrm_3584690000492819095  2024-04-23 16:23:46   2024-04-23         Mr
# 1393  zcrm_3584690000492864048  2024-04-23 16:44:12   2024-04-23         Mr
# 1403  zcrm_3584690000492889036  2024-04-23 19:10:32   2024-04-23         Ms
# 1415  zcrm_3584690000493108036  2024-04-24 16:05:26   2024-04-24         Ms
# ...                        ...                  ...          ...        ...
# 7531  zcrm_3584690000531033001  2025-03-17 14:44:12   2025-03-17      empty
# 7586  zcrm_3584690000533516039  2025-03-23 17:05:15   2025-03-23         Ms
# 7599  zcrm_3584690000533705122  2025-03-24 18:52:06   2025-03-24      empty
# 7657  zcrm_3584690000535049001  2025-03-28 20:31:16   2025-03-28         Mr
# 7666  zcrm_3584690000535298001  2025-03-30 20:38:57   2025-03-30         Ms
#
#      First Name      Last Name                            Email         Phone  \
# 1367      Katie  Littleton-San  klittl.433940@guest.booking.com  447969992201
# 1389   Noritada          Tsuda  ntsuda.181584@guest.booking.com  622035640799
# 1393      Artem       Trefilov  atrefi.933732@guest.booking.com  779197041000
# 1403     Joanne        Roberts  jrober.208781@guest.booking.com  447887840580
# 1415     Kassia        Aksenov  kaksen.631638@guest.booking.com   61416590972
# ...         ...            ...                              ...           ...
# 7531      Irina        Shelest  ishele.417342@guest.booking.com   79851256634
# 7586    Eleanor       Ashworth  eashwo.780105@guest.booking.com         empty
# 7599         Lu          Zhiyu     zlu.506379@guest.booking.com         empty
# 7657   Sternson        Tristan  strist.547706@guest.booking.com         empty
# 7666      Irina        Shelest  ishele.752217@guest.booking.com         empty
#
#      Country     Lead Brand            Messages Lead Sub-Brand  \
# 1367   empty  Karma Resorts         Email Leads          Other
# 1389   empty  Karma Resorts         email leads          Other
# 1393   empty  Karma Resorts         email leads          Other
# 1403   empty  Karma Resorts  Email Leads, Villa          Other
# 1415   empty  Karma Resorts         email leads          Other
# ...      ...            ...                 ...            ...
# 7531   empty  Karma Resorts               empty          Other
# 7586   empty  Karma Resorts         Email Leads          Other
# 7599   empty  Karma Resorts         Email Leads          Other
# 7657   empty  Karma Resorts         Email Leads          Other
# 7666   empty  Karma Resorts         Email Leads          Other
#
#            Lead Source Lead Locations                Lead Source Description  \
# 1367  WhatsApp Enquiry  Karma Kandara  Karma Reservations - WhatsApp Channel
# 1389  WhatsApp Enquiry  Karma Kandara  Karma Reservations - WhatsApp Channel
# 1393  WhatsApp Enquiry  Karma Kandara  Karma Reservations - WhatsApp Channel
# 1403  WhatsApp Enquiry  Karma Kandara  Karma Reservations - WhatsApp Channel
# 1415  WhatsApp Enquiry  Karma Kandara  Karma Reservations - WhatsApp Channel
# ...                ...            ...                                    ...
# 7531  WhatsApp Enquiry  Karma Kandara  Karma Reservations - WhatsApp Channel
# 7586  WhatsApp Enquiry  Karma Kandara  Karma Reservations - WhatsApp Channel
# 7599  WhatsApp Enquiry  Karma Kandara  Karma Reservations - WhatsApp Channel
# 7657  WhatsApp Enquiry  Karma Kandara  Karma Reservations - WhatsApp Channel
# 7666  WhatsApp Enquiry  Karma Kandara  Karma Reservations - WhatsApp Channel
#
#                    Lead History    Contact Label Mobile
# 1367  Reconfirm booking/payment            empty  empty
# 1389  Reconfirm booking/payment            empty  empty
# 1393                     Others            empty  empty
# 1403  Reconfirm booking/payment  WA Leads, Villa  empty
# 1415                     Others            empty  empty
# ...                         ...              ...    ...
# 7531  Reconfirm booking/payment            empty  empty
# 7586  Reconfirm booking/payment  WA Leads, Villa  empty
# 7599  Reconfirm booking/payment  WA Leads, Villa  empty
# 7657  Reconfirm booking/payment  WA Leads, Villa  empty
# 7666  Reconfirm booking/payment  WA Leads, Villa  empty
#
# [156 rows x 18 columns]

# %%
# delete email OTA
count_after_clean_OTA = m.delete_OTA(zoho_df, 'Email')
# zoho_df.to_excel(r'C:\Users\fajar.fatoni\Documents\Python\Data\Beambox\after_clean_OTA.xlsx', index=False)

zoho_df
# Out:
#                      Record Id         Created Time Created Date Salutation  \
# 0     zcrm_3584690000472588119  2023-12-12 16:32:25   2022-10-01      empty
# 1     zcrm_3584690000472588127  2023-12-12 16:32:25   2022-10-01      empty
# 2     zcrm_3584690000472588129  2023-12-12 16:32:25   2022-10-01      empty
# 3     zcrm_3584690000472588130  2023-12-12 16:32:25   2022-10-01      empty
# 4     zcrm_3584690000472588131  2023-12-12 16:32:25   2022-10-01      empty
# ...                        ...                  ...          ...        ...
# 7642  zcrm_3584690000536494033  2025-04-07 18:02:44   2025-04-07      empty
# 7643  zcrm_3584690000536495033  2025-04-07 17:26:22   2025-04-07      empty
# 7644  zcrm_3584690000536495071  2025-04-07 17:26:52   2025-04-07        Mrs
# 7645  zcrm_3584690000536802001  2025-04-07 18:01:43   2025-04-07      empty
# 7646  zcrm_3584690000536803001  2025-04-07 18:02:13   2025-04-07      empty
#
#         First Name    Last Name                       Email          Phone  \
# 0              Dea  Kristiansen                       empty     2147483647
# 1              Zoe       Bishop                       empty     2147483647
# 2          Yogi Ap            -                       empty     2147483647
# 3             Jack   Sutherland                       empty     2147483647
# 4     Ni Gusti Ayu     Nanditha                       empty     2147483647
# ...            ...          ...                         ...            ...
# 7642       Michael            .                       empty   628176337954
# 7643       Georgie       Wright  georgiewright8@hotmail.com    61406162554
# 7644        Joanne        Yahoo    asljoanne85@yahoo.com.sg          empty
# 7645         Cindy      Cecilia                       empty  6287776050001
# 7646         Galih      Ginting                       empty  6281293599596
#
#      Country     Lead Brand  \
# 0      empty  Karma Resorts
# 1      empty  Karma Resorts
# 2      empty  Karma Resorts
# 3      empty  Karma Resorts
# 4      empty  Karma Resorts
# ...      ...            ...
# 7642   empty  Karma Resorts
# 7643   empty  Karma Resorts
# 7644   empty  Karma Resorts
# 7645   empty  Karma Resorts
# 7646   empty  Karma Resorts
#
#                                                Messages Lead Sub-Brand  \
# 0                                                 empty          Other
# 1                                                 empty          Other
# 2                                                 empty          Other
# 3                                                 empty          Other
# 4                                                 empty          Other
# ...                                                 ...            ...
# 7642                                              empty          Other
# 7643                                              empty          Other
# 7644                                              empty          Other
# 7645                                              empty          Other
# 7646  Click Last Minutes Offer, asking for details, ...          Other
#
#            Lead Source Lead Locations                Lead Source Description  \
# 0     WhatsApp Enquiry  Karma Kandara                       WhatsApp Channel
# 1     WhatsApp Enquiry  Karma Kandara                       WhatsApp Channel
# 2     WhatsApp Enquiry  Karma Kandara                       WhatsApp Channel
# 3     WhatsApp Enquiry  Karma Kandara                       WhatsApp Channel
# 4     WhatsApp Enquiry  Karma Kandara                       WhatsApp Channel
# ...                ...            ...                                    ...
# 7642  WhatsApp Enquiry  Karma Kandara  Karma Reservations - WhatsApp Channel
# 7643  WhatsApp Enquiry  Karma Kandara  Karma Reservations - WhatsApp Channel
# 7644  WhatsApp Enquiry  Karma Kandara  Karma Reservations - WhatsApp Channel
# 7645  WhatsApp Enquiry  Karma Kandara  Karma Reservations - WhatsApp Channel
# 7646  WhatsApp Enquiry  Karma Kandara  Karma Reservations - WhatsApp Channel
#
#                                            Lead History  \
# 0     Interest for Karma Beach, entrance fee, hostin...
# 1                            Reconfirm the rest payment
# 2                                          Advertisment
# 3      Interest for Spa-inform Karma Spa contact number
# 4                              Check villa availability
# ...                                                 ...
# 7642  Interest for Karma Beach, entrance fee, hostin...
# 7643  Inquiry for Karma Experience promotion-inform ...
# 7644                       Check availability and rates
# 7645                    Interest for Di Mare Restaurant
# 7646                                             Others
#
#                 Contact Label Mobile
# 0               WA Leads, KBB  empty
# 1     WA Leads, Villa, Repeat  empty
# 2                 WA Supplier  empty
# 3               WA Leads, Spa  empty
# 4             WA Leads, Villa  empty
# ...                       ...    ...
# 7642            WA Leads, KBB  empty
# 7643                    empty  empty
# 7644                    empty  empty
# 7645        WA Leads, di Mare  empty
# 7646                 WA Leads  empty
#
# [7647 rows x 18 columns]

# %%
# Cek Email Karma
email_karma = m.find_karma(zoho_df, 'Email')
count_email_karma = email_karma.shape[0]
# email_OTA.to_excel(r'C:\Users\fajar.fatoni\Documents\Python\Data\Beambox\email_OTA.xlsx', index=False)

email_karma
# Out:
# Empty DataFrame
# Columns: [Record Id, Created Time, Created Date, Salutation, First Name, Last Name, Email, Phone, Country, Lead Brand, Messages, Lead Sub-Brand, Lead Source, Lead Locations, Lead Source Description, Lead History, Contact Label, Mobile]
# Index: []

# %%
# delete email Karma
count_after_clean_karma = m.delete_karma(zoho_df, 'Email')
# zoho_df.to_excel(r'C:\Users\fajar.fatoni\Documents\Python\Data\Beambox\after_clean_OTA.xlsx', index=False)

zoho_df
# Out:
#                      Record Id         Created Time Created Date Salutation  \
# 0     zcrm_3584690000472588119  2023-12-12 16:32:25   2022-10-01      empty
# 1     zcrm_3584690000472588127  2023-12-12 16:32:25   2022-10-01      empty
# 2     zcrm_3584690000472588129  2023-12-12 16:32:25   2022-10-01      empty
# 3     zcrm_3584690000472588130  2023-12-12 16:32:25   2022-10-01      empty
# 4     zcrm_3584690000472588131  2023-12-12 16:32:25   2022-10-01      empty
# ...                        ...                  ...          ...        ...
# 7642  zcrm_3584690000536494033  2025-04-07 18:02:44   2025-04-07      empty
# 7643  zcrm_3584690000536495033  2025-04-07 17:26:22   2025-04-07      empty
# 7644  zcrm_3584690000536495071  2025-04-07 17:26:52   2025-04-07        Mrs
# 7645  zcrm_3584690000536802001  2025-04-07 18:01:43   2025-04-07      empty
# 7646  zcrm_3584690000536803001  2025-04-07 18:02:13   2025-04-07      empty
#
#         First Name    Last Name                       Email          Phone  \
# 0              Dea  Kristiansen                       empty     2147483647
# 1              Zoe       Bishop                       empty     2147483647
# 2          Yogi Ap            -                       empty     2147483647
# 3             Jack   Sutherland                       empty     2147483647
# 4     Ni Gusti Ayu     Nanditha                       empty     2147483647
# ...            ...          ...                         ...            ...
# 7642       Michael            .                       empty   628176337954
# 7643       Georgie       Wright  georgiewright8@hotmail.com    61406162554
# 7644        Joanne        Yahoo    asljoanne85@yahoo.com.sg          empty
# 7645         Cindy      Cecilia                       empty  6287776050001
# 7646         Galih      Ginting                       empty  6281293599596
#
#      Country     Lead Brand  \
# 0      empty  Karma Resorts
# 1      empty  Karma Resorts
# 2      empty  Karma Resorts
# 3      empty  Karma Resorts
# 4      empty  Karma Resorts
# ...      ...            ...
# 7642   empty  Karma Resorts
# 7643   empty  Karma Resorts
# 7644   empty  Karma Resorts
# 7645   empty  Karma Resorts
# 7646   empty  Karma Resorts
#
#                                                Messages Lead Sub-Brand  \
# 0                                                 empty          Other
# 1                                                 empty          Other
# 2                                                 empty          Other
# 3                                                 empty          Other
# 4                                                 empty          Other
# ...                                                 ...            ...
# 7642                                              empty          Other
# 7643                                              empty          Other
# 7644                                              empty          Other
# 7645                                              empty          Other
# 7646  Click Last Minutes Offer, asking for details, ...          Other
#
#            Lead Source Lead Locations                Lead Source Description  \
# 0     WhatsApp Enquiry  Karma Kandara                       WhatsApp Channel
# 1     WhatsApp Enquiry  Karma Kandara                       WhatsApp Channel
# 2     WhatsApp Enquiry  Karma Kandara                       WhatsApp Channel
# 3     WhatsApp Enquiry  Karma Kandara                       WhatsApp Channel
# 4     WhatsApp Enquiry  Karma Kandara                       WhatsApp Channel
# ...                ...            ...                                    ...
# 7642  WhatsApp Enquiry  Karma Kandara  Karma Reservations - WhatsApp Channel
# 7643  WhatsApp Enquiry  Karma Kandara  Karma Reservations - WhatsApp Channel
# 7644  WhatsApp Enquiry  Karma Kandara  Karma Reservations - WhatsApp Channel
# 7645  WhatsApp Enquiry  Karma Kandara  Karma Reservations - WhatsApp Channel
# 7646  WhatsApp Enquiry  Karma Kandara  Karma Reservations - WhatsApp Channel
#
#                                            Lead History  \
# 0     Interest for Karma Beach, entrance fee, hostin...
# 1                            Reconfirm the rest payment
# 2                                          Advertisment
# 3      Interest for Spa-inform Karma Spa contact number
# 4                              Check villa availability
# ...                                                 ...
# 7642  Interest for Karma Beach, entrance fee, hostin...
# 7643  Inquiry for Karma Experience promotion-inform ...
# 7644                       Check availability and rates
# 7645                    Interest for Di Mare Restaurant
# 7646                                             Others
#
#                 Contact Label Mobile
# 0               WA Leads, KBB  empty
# 1     WA Leads, Villa, Repeat  empty
# 2                 WA Supplier  empty
# 3               WA Leads, Spa  empty
# 4             WA Leads, Villa  empty
# ...                       ...    ...
# 7642            WA Leads, KBB  empty
# 7643                    empty  empty
# 7644                    empty  empty
# 7645        WA Leads, di Mare  empty
# 7646                 WA Leads  empty
#
# [7647 rows x 18 columns]

# %%
find_member_booking = zoho_df.copy()

find_member_booking.loc[find_member_booking['Phone'].isin(df_booking['Phone1']), 'Same Value Find'] = 'Booking-Phone1'
find_member_booking.loc[find_member_booking['Phone'].isin(df_booking['Mobile']), 'Same Value Find'] = 'Booking-Mobile'
find_member_booking.loc[find_member_booking['Mobile'].isin(df_booking['Phone1']), 'Same Value Find'] = 'Booking-Phone1' 
find_member_booking.loc[find_member_booking['Mobile'].isin(df_booking['Mobile']), 'Same Value Find'] = 'Booking-Mobile'
find_member_booking.loc[find_member_booking['Email'].isin(df_booking['Email']), 'Same Value Find'] = 'Booking-Email'

find_member_booking.loc[find_member_booking['Phone'].isin(df_phone['Mobile']), 'Same Value Find'] = 'Member-Mobile' 
find_member_booking.loc[find_member_booking['Mobile'].isin(df_phone['Mobile']), 'Same Value Find'] = 'Member-Mobile'

find_member_booking.loc[find_member_booking['Email'].isin(df_email['Email']), 'Same Value Find'] = 'Member-Email'

find_member_booking.drop(find_member_booking.loc[find_member_booking['Same Value Find'].isna()].index, inplace=True)

count_booking_dedup = find_member_booking.loc[find_member_booking['Same Value Find'].str.contains('Booking', flags=re.I, regex=True)].shape[0]
count_member_dedup = find_member_booking.loc[find_member_booking['Same Value Find'].str.contains('Member', flags=re.I, regex=True)].shape[0]

find_member_booking.replace('empty', '', inplace=True)
# find_member_booking.to_csv(r'C:\Users\fajar.fatoni\Documents\Python\Data\Beambox\booking-member-dedup.csv', index=False)
# find_member_booking.to_excel(r'C:\Users\fajar.fatoni\Documents\Python\Data\Beambox\booking-member-dedup.xlsx', index=False)

#find_member_booking.loc[find_member_booking['Same Value Find'] == 'Booking-Phone1']

# %%
# data phone, mobile dam email member yang ada di master data 
count_wash_member = zoho_df.loc[
    zoho_df['Phone'].isin(df_booking['Phone1']) | 
    zoho_df['Phone'].isin(df_booking['Mobile']) |
    zoho_df['Mobile'].isin(df_booking['Phone1']) | 
    zoho_df['Mobile'].isin(df_booking['Mobile']) |
    zoho_df['Email'].isin(df_booking['Email'])| 

    zoho_df['Phone'].isin(df_phone['Mobile']) | 
    zoho_df['Mobile'].isin(df_phone['Mobile']) |

    zoho_df['Email'].isin(df_email['Email'])

].shape[0]

zoho_df.drop(zoho_df.loc[
    zoho_df['Phone'].isin(df_booking['Phone1']) | 
    zoho_df['Phone'].isin(df_booking['Mobile']) |
    zoho_df['Mobile'].isin(df_booking['Phone1']) | 
    zoho_df['Mobile'].isin(df_booking['Mobile']) |
    zoho_df['Email'].isin(df_booking['Email']) |
    
    zoho_df['Phone'].isin(df_phone['Mobile']) | 
    zoho_df['Mobile'].isin(df_phone['Mobile']) |

    zoho_df['Email'].isin(df_email['Email'])

    ].index, inplace=True)
    
zoho_df.reset_index(drop=True, inplace=True)

count_after_wash_member = zoho_df.shape[0]

# %%
count_email_only = zoho_df.loc[(zoho_df['Email'] != 'empty') & ((zoho_df['Phone'] == 'empty') & (zoho_df['Mobile'] == 'empty'))].shape[0]
count_phone_only = zoho_df.loc[(zoho_df['Email'] == 'empty') & ((zoho_df['Phone'] != 'empty') | (zoho_df['Mobile'] != 'empty'))].shape[0]
count_email_and_phone = zoho_df.loc[(zoho_df['Email'] != 'empty') & ((zoho_df['Phone'] != 'empty') | (zoho_df['Mobile'] != 'empty'))].shape[0]

count_blank = zoho_df.loc[(zoho_df['Email'] =='empty') & (zoho_df['Phone']=='empty') & (zoho_df['Mobile']=='empty')].shape[0]

# zoho_df.loc[(zoho_df['Email'] =='empty') & (zoho_df['Phone']=='empty') & (zoho_df['Mobile']=='empty')].to_excel(r'C:\Users\fajar.fatoni\Documents\Python\Data\Beambox\blank_data.xlsx', index=False)

zoho_df.loc[(zoho_df['Email'] != 'empty') & ((zoho_df['Phone'] == 'empty') & (zoho_df['Mobile'] == 'empty')), 'Contact Type'] = 'Email Only'
zoho_df.loc[(zoho_df['Email'] == 'empty') & ((zoho_df['Phone'] != 'empty') | (zoho_df['Mobile'] != 'empty')), 'Contact Type'] = 'Phone Only'
zoho_df.loc[(zoho_df['Email'] != 'empty') & ((zoho_df['Phone'] != 'empty') | (zoho_df['Mobile'] != 'empty')), 'Contact Type'] = 'Email and Phone'

zoho_df.drop(zoho_df.loc[(zoho_df['Email'] =='empty') & (zoho_df['Phone']=='empty') & (zoho_df['Mobile']=='empty')].index, inplace=True)
zoho_df.reset_index(drop=True, inplace=True)

count_after_wash_blank = zoho_df.shape[0]

# %%
arr_dedup = [count_deleted_wrong_format, count_duplicate_general, count_email_OTA, count_email_karma, count_blank]
count_sum_dedup = sum(arr_dedup)
count_sum_dedup
# Out:
# 1204

# %%
print("==========================================================")
print("Summary")
print("==========================================================")
print("Jumlah Filter Leads Awal : "+str(count_filter_awal))
print("Jumlah Format Email Salah : "+str(count_deleted_wrong_format))
print("Jumlah Setelah Clean Format Email Salah : "+str(count_after_deleted_wrong_format))
print("Jumlah Duplicate (Phone, Mobile, Email dan LSD) : "+str(count_duplicate_general))
print("Jumlah Setelah Clean Duplicate : "+str(count_after_dedup_duplicate))
# print("Jumlah Lead Test : "+str(count_leads_test))
# print("Jumlah Setelah Clean Lead Test : "+str(count_after_dedup_test))
# print("Jumlah Lead Do Not Mail : "+str(count_dnm))
# print("Jumlah Setelah Clean Lead Do Not Mail : "+str(count_after_dedup_dnm))
print("Jumlah Email OTA : "+str(count_email_OTA))
print("Jumlah Setelah Clean Email OTA : "+str(count_after_clean_OTA))
print("Jumlah Email Karma : "+str(count_email_karma))
print("Jumlah Setelah Clean Email Karma : "+str(count_after_clean_karma))
print("Jumlah Wash Member : "+str(count_member_dedup))
print("Jumlah Wash Booking : "+str(count_booking_dedup))
print("Jumlah Setelah Wash Member : "+str(count_after_wash_member))
print("Jumlah Phone Email Blank (Setelah phone yang tidak valid dihapus) : "+str(count_blank))
print("Jumlah Setelah Wash Phone Email Blank : "+str(count_after_wash_blank))
print("==========================================================")
print("Contact Type")
print("==========================================================")
print("Jumlah Email Only : "+str(count_email_only))
print("Jumlah Phone Only : "+str(count_phone_only))
print("Jumlah Email dan Phone : "+str(count_email_and_phone))
# Out:
# ==========================================================
# Summary
# ==========================================================
# Jumlah Filter Leads Awal : 8845
# Jumlah Format Email Salah : 0
# Jumlah Setelah Clean Format Email Salah : 8845
# Jumlah Duplicate (Phone, Mobile, Email dan LSD) : 1042
# Jumlah Setelah Clean Duplicate : 7803
# Jumlah Email OTA : 156
# Jumlah Setelah Clean Email OTA : 7647
# Jumlah Email Karma : 0
# Jumlah Setelah Clean Email Karma : 7647
# Jumlah Wash Member : 637
# Jumlah Wash Booking : 75
# Jumlah Setelah Wash Member : 6935
# Jumlah Phone Email Blank (Setelah phone yang tidak valid dihapus) : 6
# Jumlah Setelah Wash Phone Email Blank : 6929
# ==========================================================
# Contact Type
# ==========================================================
# Jumlah Email Only : 334
# Jumlah Phone Only : 6540
# Jumlah Email dan Phone : 55

# %%
print("==========================================================")
print("Summary Report")
print("==========================================================")
print("Jumlah Data Awal : "+str(count_filter_awal))
print("Jumlah Wash Dedup : "+str(count_sum_dedup))
print("Jumlah Wash Member : "+str(count_member_dedup))
print("Jumlah Wash Booking : "+str(count_booking_dedup))
print("Jumlah Data Akhir : "+str(count_after_wash_blank))
# Out:
# ==========================================================
# Summary Report
# ==========================================================
# Jumlah Data Awal : 8845
# Jumlah Wash Dedup : 1204
# Jumlah Wash Member : 637
# Jumlah Wash Booking : 75
# Jumlah Data Akhir : 6929

# %%
zoho_df.replace('empty', '', inplace=True, regex=True)

zoho_df['First Name'] = zoho_df['First Name'].str.title()
zoho_df['Last Name'] = zoho_df['Last Name'].str.title()

zoho_df.to_csv(r'C:\Users\fajar.fatoni\Documents\Python\Data\whatsapp channel.csv', index=False)
# zoho_df.to_excel(r'C:\Users\fajar.fatoni\Documents\Python\Data\whatsapp channel.xlsx', index=False)
