# %%
import main_module as m
import zoho_filter_module as fil
import pandas as pd
import re
import numpy as np

# %load_ext autoreload
# %autoreload 2

cols = ['Record Id',	
'Created Time',
'Created Date',	
'First Name',	
'Last Name',	
'Email',	
'Phone',	
'Mobile',	
'Birthdate',	
'Year of Birth',
'Street',	
'Street2',	
'City',	
'State',	
'Country',	
'Nationality',
'Booking Status', 
'BookRef',
'Departure Date',	
'Arrival Date',	
'Card Type',	
'Marital Status',	
'Lead Brand',	
'Lead Sub-Brand',	
'Lead Source',	
'Lead Locations',	
'Lead Source Description',	
'Lead Regions',
'Lead Status',
'Email Opt Out',	
'Opt In']
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
path = r'C:\Users\fajar.fatoni\Documents\Python\Data\Friend of Karma - Discount Card 2023.xlsx'
# zoho_df = pd.read_csv(path, dtype='string')
zoho_df = pd.read_excel(path, dtype='string', sheet_name='Leads_2025_04_24')

zoho_df.reset_index(drop=True, inplace=True)
count_filter_awal = zoho_df.shape[0]

# mengisi kolom <NA> dengan value string 'empty' supaya mudah mengecek data member dan booking dengan isin
zoho_df.fillna('empty', inplace=True)

zoho_df['Mobile'] = 'empty'
# zoho_df['Phone'] = 'empty'
zoho_df
# Out:
#                     Record Id         Created Time Created Date First Name  \
# 0    zcrm_3584690000417563854  2022-12-19 02:30:00        empty    Andreas
# 1    zcrm_3584690000418527066  2022-12-21 22:32:00        empty      Linda
# 2    zcrm_3584690000418623040  2022-12-22 01:56:00        empty  Felicitas
# 3    zcrm_3584690000418657001  2022-12-21 23:31:00        empty        Ian
# 4    zcrm_3584690000418657084  2022-12-22 00:47:00        empty      Paula
# ..                        ...                  ...          ...        ...
# 518  zcrm_3584690000540814034  2025-04-20 21:22:00        empty     Elliot
# 519  zcrm_3584690000540821001  2025-04-20 20:15:00        empty        Les
# 520  zcrm_3584690000540825034  2025-04-20 23:26:00        empty       Lucy
# 521  zcrm_3584690000540915630  2025-04-22 02:05:00        empty    Barbara
# 522  zcrm_3584690000541091001  2025-04-23 02:48:00        empty        Val
#
#        Last Name                          Email          Phone  \
# 0      Schmidtke             askeylargo@aol.com   491637726861
# 1            Ogg           lindaogg83@gmail.com   447746910548
# 2    Thierfelder    felicitasthierfelder@web.de  4980263873570
# 3        Rishton           ianrishton@gmail.com   447870270129
# 4       Glascott     paulajoblack@hotmail.co.uk   447718287234
# ..           ...                            ...            ...
# 518        Toney          3lli0tt0ney@gmail.com   447597124010
# 519       Thomas       les.thomas0691@gmail.com   447771887249
# 520        Floyd             lucy_floyd@sky.com   447533076131
# 521    Stahlmann  barbara.stahlmann@t-online.de  4915116918537
# 522        Tonks       tonks.val@googlemail.com   447535976698
#
#             Country   Lead Brand Lead Sub-Brand  \
# 0           Germany  Karma Group          Other
# 1    United Kingdom  Karma Group          Other
# 2           Germany  Karma Group          Other
# 3    United Kingdom  Karma Group          Other
# 4    United Kingdom  Karma Group          Other
# ..              ...          ...            ...
# 518  United Kingdom  Karma Group          Other
# 519  United Kingdom  Karma Group          Other
# 520  United Kingdom  Karma Group          Other
# 521         Germany  Karma Group          Other
# 522  United Kingdom  Karma Group          Other
#
#                   Lead Source Description  Lead Source      Lead Locations  \
# 0    Friend of Karma - Discount Card 2023  Web Enquiry       Karma Bavaria
# 1    Friend of Karma - Discount Card 2023  Web Enquiry  Karma Salford Hall
# 2    Friend of Karma - Discount Card 2023  Web Enquiry       Karma Bavaria
# 3    Friend of Karma - Discount Card 2023  Web Enquiry  Karma Salford Hall
# 4    Friend of Karma - Discount Card 2023  Web Enquiry  Karma Salford Hall
# ..                                    ...          ...                 ...
# 518  Friend of Karma - Discount Card 2023  Web Enquiry  Karma Salford Hall
# 519  Friend of Karma - Discount Card 2023  Web Enquiry  Karma Salford Hall
# 520  Friend of Karma - Discount Card 2023  Web Enquiry  Karma Salford Hall
# 521  Friend of Karma - Discount Card 2023  Web Enquiry       Karma Bavaria
# 522  Friend of Karma - Discount Card 2023  Web Enquiry  Karma Salford Hall
#
#                                                Website Opt In  \
# 0    https://karmagroup.com/friend-of-karma-bavaria...  False
# 1    https://karmagroup.com/friend-of-karma-salford...  False
# 2    https://karmagroup.com/friend-of-karma-bavaria...  False
# 3    https://karmagroup.com/friend-of-karma-salford...  False
# 4    https://karmagroup.com/friend-of-karma-salford...  False
# ..                                                 ...    ...
# 518  https://karmagroup.com/friend-of-karma-salford...   True
# 519  https://karmagroup.com/friend-of-karma-salford...   True
# 520  https://karmagroup.com/friend-of-karma-salford...   True
# 521  https://karmagroup.com/friend-of-karma-bavaria...   True
# 522  https://karmagroup.com/friend-of-karma-salford...   True
#
#     Agree with Terms and Condition GDPR Compliant     Contact type  \
# 0                            False          False            empty
# 1                            False          False            empty
# 2                            False          False            empty
# 3                            False          False            empty
# 4                            False          False            empty
# ..                             ...            ...              ...
# 518                           True           True  Email and Phone
# 519                           True           True  Email and Phone
# 520                           True           True  Email and Phone
# 521                           True           True  Email and Phone
# 522                           True           True  Email and Phone
#
#                  Enquiry sent to Mobile
# 0    maik.schramm@karmagroup.com  empty
# 1    maik.schramm@karmagroup.com  empty
# 2    maik.schramm@karmagroup.com  empty
# 3    maik.schramm@karmagroup.com  empty
# 4    maik.schramm@karmagroup.com  empty
# ..                           ...    ...
# 518      gm@karmasalfordhall.com  empty
# 519      gm@karmasalfordhall.com  empty
# 520      gm@karmasalfordhall.com  empty
# 521          gm@karmabavaria.com  empty
# 522      gm@karmasalfordhall.com  empty
#
# [523 rows x 20 columns]

# %%
path = r'G:\.shortcut-targets-by-id\0B_d3smBjzo04eXpvS1NXTWF2RVE\_BOOKING\Booking By Year\FlyBuy Booking Data (BGAU & BGID & KE).xlsx'
df_booking = pd.read_excel(path, dtype='string', sheet_name='BOOKING_BGAU_BGID_KE')

path = r'G:\.shortcut-targets-by-id\0B_d3smBjzo04UUNBME5GOVhoMjA\_ODYSSEY\Phone Members.xlsx'
df_phone = pd.read_excel(path, dtype='string', sheet_name='Sheet1')

path = r'G:\.shortcut-targets-by-id\0B_d3smBjzo04UUNBME5GOVhoMjA\_ODYSSEY\Email Members.xlsx'
df_email = pd.read_excel(path, dtype='string', sheet_name='Sheet1')

# %% [markdown]
# # ====================== Awal Filter Umum ======================

# %%
# data phone, mobile dam email member yang ada di master data (wash member)

m.clean_number(zoho_df, 'Phone')
m.clean_number(zoho_df, 'Mobile')
m.replace_not_valid_to_empty(zoho_df, 'Phone')
m.replace_not_valid_to_empty(zoho_df, 'Mobile')
zoho_df['Email'] = m.lowercase(zoho_df, 'Email')
m.clean_space(zoho_df, 'Email')
m.clean_not_valid_email_format(zoho_df, 'Email')

m.clean_number(df_booking, 'Phone1')
m.clean_number(df_booking, 'Mobile')
df_booking['Email'] = m.lowercase(df_booking, 'Email')
m.clean_space(df_booking, 'Email')
m.clean_not_valid_email_format(df_booking, 'Email')

m.clean_number(df_phone, 'Mobile')

df_email['Email'] = m.lowercase(df_email, 'Email')
m.clean_space(df_email, 'Email')
m.clean_not_valid_email_format(df_email, 'Email')
# Out:
# c:\Users\fajar.fatoni\Documents\Python\Task Offline\zoho_data_app\main_module.py:71: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[df_columns].replace(' ','', regex=True, inplace=True)
# c:\Users\fajar.fatoni\Documents\Python\Task Offline\zoho_data_app\main_module.py:72: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[df_columns].replace('[^0-9]','', regex=True, inplace=True)
# c:\Users\fajar.fatoni\Documents\Python\Task Offline\zoho_data_app\main_module.py:94: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[df_columns].replace(' ','', regex=True, inplace=True)
# c:\Users\fajar.fatoni\Documents\Python\Task Offline\zoho_data_app\main_module.py:71: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[df_columns].replace(' ','', regex=True, inplace=True)
# c:\Users\fajar.fatoni\Documents\Python\Task Offline\zoho_data_app\main_module.py:72: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[df_columns].replace('[^0-9]','', regex=True, inplace=True)
# 'Email'

# %%
count_deleted_wrong_format = m.delete_email_wrong_format(zoho_df, 'Email')
count_after_deleted_wrong_format = zoho_df.shape[0]

# %% [markdown]
# # ====================== Akhir Filter Umum ======================

# %%
# hitung jumlah duplicate
count_duplicate_general = zoho_df.loc[zoho_df.duplicated(subset=['Phone','Mobile','Email','Lead Locations'])].shape[0]

zoho_df.loc[zoho_df.duplicated(subset=['Phone','Mobile','Email','Lead Locations'])]
# Out:
#                     Record Id         Created Time Created Date First Name  \
# 78   zcrm_3584690000444442643  2023-05-14 05:45:00        empty      Paula
# 79   zcrm_3584690000444589006  2023-05-15 02:44:00        empty      Sally
# 89   zcrm_3584690000450604531  2023-06-23 01:54:00        empty       Andy
# 462  zcrm_3584690000535211139  2025-03-31 20:32:00        empty      David
# 490  zcrm_3584690000537566034  2025-04-11 16:00:00        empty        Ben
# 505  zcrm_3584690000539993001  2025-04-15 03:19:00        empty       Jack
# 519  zcrm_3584690000540821001  2025-04-20 20:15:00        empty        Les
#
#        Last Name                            Email         Phone  \
# 78         Black       paulajoblack@hotmail.co.uk  447718287234
# 79          Hall             annihall67@gmail.com  447917870264
# 89         Lyons      harborneproperty@live.co.uk  447940991783
# 462  Rice-Davies  david.davies1948@googlemail.com  447729307469
# 490      Clifton            brclifton@yahoo.co.uk  447795210710
# 505      Clayson              jgclayson@gmail.com  447473384100
# 519       Thomas         les.thomas0691@gmail.com  447771887249
#
#             Country   Lead Brand Lead Sub-Brand  \
# 78   United Kingdom  Karma Group          Other
# 79   United Kingdom  Karma Group          Other
# 89   United Kingdom  Karma Group          Other
# 462  United Kingdom  Karma Group          Other
# 490  United Kingdom  Karma Group          Other
# 505  United Kingdom  Karma Group          Other
# 519  United Kingdom  Karma Group          Other
#
#                   Lead Source Description  Lead Source      Lead Locations  \
# 78   Friend of Karma - Discount Card 2023  Web Enquiry  Karma Salford Hall
# 79   Friend of Karma - Discount Card 2023  Web Enquiry  Karma Salford Hall
# 89   Friend of Karma - Discount Card 2023  Web Enquiry  Karma Salford Hall
# 462  Friend of Karma - Discount Card 2023  Web Enquiry  Karma Salford Hall
# 490  Friend of Karma - Discount Card 2023  Web Enquiry  Karma Salford Hall
# 505  Friend of Karma - Discount Card 2023  Web Enquiry  Karma Salford Hall
# 519  Friend of Karma - Discount Card 2023  Web Enquiry  Karma Salford Hall
#
#                                                Website Opt In  \
# 78   https://karmagroup.com/friend-of-karma-salford...   True
# 79   https://karmagroup.com/friend-of-karma-salford...   True
# 89   https://karmagroup.com/friend-of-karma-salford...   True
# 462  https://karmagroup.com/friend-of-karma-salford...   True
# 490  https://karmagroup.com/friend-of-karma-salford...   True
# 505  https://karmagroup.com/friend-of-karma-salford...   True
# 519  https://karmagroup.com/friend-of-karma-salford...   True
#
#     Agree with Terms and Condition GDPR Compliant     Contact type  \
# 78                            True           True            empty
# 79                            True           True            empty
# 89                            True           True            empty
# 462                           True           True  Email and Phone
# 490                           True           True  Email and Phone
# 505                           True           True  Email and Phone
# 519                           True           True  Email and Phone
#
#                  Enquiry sent to Mobile
# 78   maik.schramm@karmagroup.com  empty
# 79   maik.schramm@karmagroup.com  empty
# 89   maik.schramm@karmagroup.com  empty
# 462      gm@karmasalfordhall.com  empty
# 490      gm@karmasalfordhall.com  empty
# 505      gm@karmasalfordhall.com  empty
# 519      gm@karmasalfordhall.com  empty

# %%
zoho_df.drop_duplicates(subset=['Phone','Mobile','Email','Lead Locations'], inplace=True)
zoho_df.reset_index(drop=True, inplace=True)

# hitung jumlah setelah value duplicate dihapus
count_after_dedup_duplicate = zoho_df.shape[0]

zoho_df
# Out:
#                     Record Id         Created Time Created Date First Name  \
# 0    zcrm_3584690000417563854  2022-12-19 02:30:00        empty    Andreas
# 1    zcrm_3584690000418527066  2022-12-21 22:32:00        empty      Linda
# 2    zcrm_3584690000418623040  2022-12-22 01:56:00        empty  Felicitas
# 3    zcrm_3584690000418657001  2022-12-21 23:31:00        empty        Ian
# 4    zcrm_3584690000418657084  2022-12-22 00:47:00        empty      Paula
# ..                        ...                  ...          ...        ...
# 511  zcrm_3584690000540814001  2025-04-20 19:44:00        empty      Nigel
# 512  zcrm_3584690000540814034  2025-04-20 21:22:00        empty     Elliot
# 513  zcrm_3584690000540825034  2025-04-20 23:26:00        empty       Lucy
# 514  zcrm_3584690000540915630  2025-04-22 02:05:00        empty    Barbara
# 515  zcrm_3584690000541091001  2025-04-23 02:48:00        empty        Val
#
#        Last Name                          Email          Phone  \
# 0      Schmidtke             askeylargo@aol.com   491637726861
# 1            Ogg           lindaogg83@gmail.com   447746910548
# 2    Thierfelder    felicitasthierfelder@web.de  4980263873570
# 3        Rishton           ianrishton@gmail.com   447870270129
# 4       Glascott     paulajoblack@hotmail.co.uk   447718287234
# ..           ...                            ...            ...
# 511         Pugh    nigelpugh.40@btinternet.com   447973867185
# 512        Toney          3lli0tt0ney@gmail.com   447597124010
# 513        Floyd             lucy_floyd@sky.com   447533076131
# 514    Stahlmann  barbara.stahlmann@t-online.de  4915116918537
# 515        Tonks       tonks.val@googlemail.com   447535976698
#
#             Country   Lead Brand Lead Sub-Brand  \
# 0           Germany  Karma Group          Other
# 1    United Kingdom  Karma Group          Other
# 2           Germany  Karma Group          Other
# 3    United Kingdom  Karma Group          Other
# 4    United Kingdom  Karma Group          Other
# ..              ...          ...            ...
# 511  United Kingdom  Karma Group          Other
# 512  United Kingdom  Karma Group          Other
# 513  United Kingdom  Karma Group          Other
# 514         Germany  Karma Group          Other
# 515  United Kingdom  Karma Group          Other
#
#                   Lead Source Description  Lead Source      Lead Locations  \
# 0    Friend of Karma - Discount Card 2023  Web Enquiry       Karma Bavaria
# 1    Friend of Karma - Discount Card 2023  Web Enquiry  Karma Salford Hall
# 2    Friend of Karma - Discount Card 2023  Web Enquiry       Karma Bavaria
# 3    Friend of Karma - Discount Card 2023  Web Enquiry  Karma Salford Hall
# 4    Friend of Karma - Discount Card 2023  Web Enquiry  Karma Salford Hall
# ..                                    ...          ...                 ...
# 511  Friend of Karma - Discount Card 2023  Web Enquiry  Karma Salford Hall
# 512  Friend of Karma - Discount Card 2023  Web Enquiry  Karma Salford Hall
# 513  Friend of Karma - Discount Card 2023  Web Enquiry  Karma Salford Hall
# 514  Friend of Karma - Discount Card 2023  Web Enquiry       Karma Bavaria
# 515  Friend of Karma - Discount Card 2023  Web Enquiry  Karma Salford Hall
#
#                                                Website Opt In  \
# 0    https://karmagroup.com/friend-of-karma-bavaria...  False
# 1    https://karmagroup.com/friend-of-karma-salford...  False
# 2    https://karmagroup.com/friend-of-karma-bavaria...  False
# 3    https://karmagroup.com/friend-of-karma-salford...  False
# 4    https://karmagroup.com/friend-of-karma-salford...  False
# ..                                                 ...    ...
# 511  https://karmagroup.com/friend-of-karma-salford...   True
# 512  https://karmagroup.com/friend-of-karma-salford...   True
# 513  https://karmagroup.com/friend-of-karma-salford...   True
# 514  https://karmagroup.com/friend-of-karma-bavaria...   True
# 515  https://karmagroup.com/friend-of-karma-salford...   True
#
#     Agree with Terms and Condition GDPR Compliant     Contact type  \
# 0                            False          False            empty
# 1                            False          False            empty
# 2                            False          False            empty
# 3                            False          False            empty
# 4                            False          False            empty
# ..                             ...            ...              ...
# 511                           True           True  Email and Phone
# 512                           True           True  Email and Phone
# 513                           True           True  Email and Phone
# 514                           True           True  Email and Phone
# 515                           True           True  Email and Phone
#
#                  Enquiry sent to Mobile
# 0    maik.schramm@karmagroup.com  empty
# 1    maik.schramm@karmagroup.com  empty
# 2    maik.schramm@karmagroup.com  empty
# 3    maik.schramm@karmagroup.com  empty
# 4    maik.schramm@karmagroup.com  empty
# ..                           ...    ...
# 511      gm@karmasalfordhall.com  empty
# 512      gm@karmasalfordhall.com  empty
# 513      gm@karmasalfordhall.com  empty
# 514          gm@karmabavaria.com  empty
# 515      gm@karmasalfordhall.com  empty
#
# [516 rows x 20 columns]

# %%
# # Cek leads test
# test_leads = zoho_df.loc[
    
#         zoho_df['Email'].str.contains('^test@', flags=re.I, regex=True) |
#         zoho_df['Email'].str.contains('\+test', flags=re.I, regex=True) |
    
#         zoho_df['First Name'].str.contains('^test$', flags=re.I, regex=True) |
#         zoho_df['Last Name'].str.contains('^test$', flags=re.I, regex=True) |

#         zoho_df['First Name'].str.contains('test 1', flags=re.I, regex=True) |
#         zoho_df['Last Name'].str.contains('test 2', flags=re.I, regex=True)|
#         zoho_df['First Name'].str.contains('test1', flags=re.I, regex=True) |
#         zoho_df['Last Name'].str.contains('test2', flags=re.I, regex=True)|

#         zoho_df['First Name'].str.contains(' test ', flags=re.I, regex=True) | 
#         zoho_df['Last Name'].str.contains(' test ', flags=re.I, regex=True) | 
#         zoho_df['Last Name'].str.contains(' test$', flags=re.I, regex=True)
#     ]

# count_leads_test = test_leads.shape[0]

# # test_leads.to_excel(r'C:\Users\fajar.fatoni\Documents\Python\Data\Beambox\test_leads_2.xlsx', index=False)
# test_leads

# %%
# zoho_df.drop(test_leads.index, inplace=True)
# zoho_df.reset_index(drop=True, inplace=True)

# count_after_dedup_test = zoho_df.shape[0]

# %%
# dnm_leads = zoho_df.loc[(zoho_df['Do Not Mail'] == 'true') | (zoho_df['Do Not Contact'] == 'true')]
# count_dnm = dnm_leads.shape[0]

# %%
# zoho_df.drop(dnm_leads.index, inplace=True)
# zoho_df.reset_index(drop=True, inplace=True)

# count_after_dedup_dnm = zoho_df.shape[0]

# %%
# Cek Email OTA
email_OTA = m.find_OTA(zoho_df, 'Email')
count_email_OTA = email_OTA.shape[0]
# email_OTA.to_excel(r'C:\Users\fajar.fatoni\Documents\Python\Data\Beambox\email_OTA.xlsx', index=False)

email_OTA
# Out:
# Empty DataFrame
# Columns: [Record Id, Created Time, Created Date, First Name, Last Name, Email, Phone, Country, Lead Brand, Lead Sub-Brand, Lead Source Description, Lead Source, Lead Locations, Website, Opt In, Agree with Terms and Condition, GDPR Compliant, Contact type, Enquiry sent to, Mobile]
# Index: []

# %%
# delete email OTA
count_after_clean_OTA = m.delete_OTA(zoho_df, 'Email')
# zoho_df.to_excel(r'C:\Users\fajar.fatoni\Documents\Python\Data\Beambox\after_clean_OTA.xlsx', index=False)

zoho_df
# Out:
#                     Record Id         Created Time Created Date First Name  \
# 0    zcrm_3584690000417563854  2022-12-19 02:30:00        empty    Andreas
# 1    zcrm_3584690000418527066  2022-12-21 22:32:00        empty      Linda
# 2    zcrm_3584690000418623040  2022-12-22 01:56:00        empty  Felicitas
# 3    zcrm_3584690000418657001  2022-12-21 23:31:00        empty        Ian
# 4    zcrm_3584690000418657084  2022-12-22 00:47:00        empty      Paula
# ..                        ...                  ...          ...        ...
# 511  zcrm_3584690000540814001  2025-04-20 19:44:00        empty      Nigel
# 512  zcrm_3584690000540814034  2025-04-20 21:22:00        empty     Elliot
# 513  zcrm_3584690000540825034  2025-04-20 23:26:00        empty       Lucy
# 514  zcrm_3584690000540915630  2025-04-22 02:05:00        empty    Barbara
# 515  zcrm_3584690000541091001  2025-04-23 02:48:00        empty        Val
#
#        Last Name                          Email          Phone  \
# 0      Schmidtke             askeylargo@aol.com   491637726861
# 1            Ogg           lindaogg83@gmail.com   447746910548
# 2    Thierfelder    felicitasthierfelder@web.de  4980263873570
# 3        Rishton           ianrishton@gmail.com   447870270129
# 4       Glascott     paulajoblack@hotmail.co.uk   447718287234
# ..           ...                            ...            ...
# 511         Pugh    nigelpugh.40@btinternet.com   447973867185
# 512        Toney          3lli0tt0ney@gmail.com   447597124010
# 513        Floyd             lucy_floyd@sky.com   447533076131
# 514    Stahlmann  barbara.stahlmann@t-online.de  4915116918537
# 515        Tonks       tonks.val@googlemail.com   447535976698
#
#             Country   Lead Brand Lead Sub-Brand  \
# 0           Germany  Karma Group          Other
# 1    United Kingdom  Karma Group          Other
# 2           Germany  Karma Group          Other
# 3    United Kingdom  Karma Group          Other
# 4    United Kingdom  Karma Group          Other
# ..              ...          ...            ...
# 511  United Kingdom  Karma Group          Other
# 512  United Kingdom  Karma Group          Other
# 513  United Kingdom  Karma Group          Other
# 514         Germany  Karma Group          Other
# 515  United Kingdom  Karma Group          Other
#
#                   Lead Source Description  Lead Source      Lead Locations  \
# 0    Friend of Karma - Discount Card 2023  Web Enquiry       Karma Bavaria
# 1    Friend of Karma - Discount Card 2023  Web Enquiry  Karma Salford Hall
# 2    Friend of Karma - Discount Card 2023  Web Enquiry       Karma Bavaria
# 3    Friend of Karma - Discount Card 2023  Web Enquiry  Karma Salford Hall
# 4    Friend of Karma - Discount Card 2023  Web Enquiry  Karma Salford Hall
# ..                                    ...          ...                 ...
# 511  Friend of Karma - Discount Card 2023  Web Enquiry  Karma Salford Hall
# 512  Friend of Karma - Discount Card 2023  Web Enquiry  Karma Salford Hall
# 513  Friend of Karma - Discount Card 2023  Web Enquiry  Karma Salford Hall
# 514  Friend of Karma - Discount Card 2023  Web Enquiry       Karma Bavaria
# 515  Friend of Karma - Discount Card 2023  Web Enquiry  Karma Salford Hall
#
#                                                Website Opt In  \
# 0    https://karmagroup.com/friend-of-karma-bavaria...  False
# 1    https://karmagroup.com/friend-of-karma-salford...  False
# 2    https://karmagroup.com/friend-of-karma-bavaria...  False
# 3    https://karmagroup.com/friend-of-karma-salford...  False
# 4    https://karmagroup.com/friend-of-karma-salford...  False
# ..                                                 ...    ...
# 511  https://karmagroup.com/friend-of-karma-salford...   True
# 512  https://karmagroup.com/friend-of-karma-salford...   True
# 513  https://karmagroup.com/friend-of-karma-salford...   True
# 514  https://karmagroup.com/friend-of-karma-bavaria...   True
# 515  https://karmagroup.com/friend-of-karma-salford...   True
#
#     Agree with Terms and Condition GDPR Compliant     Contact type  \
# 0                            False          False            empty
# 1                            False          False            empty
# 2                            False          False            empty
# 3                            False          False            empty
# 4                            False          False            empty
# ..                             ...            ...              ...
# 511                           True           True  Email and Phone
# 512                           True           True  Email and Phone
# 513                           True           True  Email and Phone
# 514                           True           True  Email and Phone
# 515                           True           True  Email and Phone
#
#                  Enquiry sent to Mobile
# 0    maik.schramm@karmagroup.com  empty
# 1    maik.schramm@karmagroup.com  empty
# 2    maik.schramm@karmagroup.com  empty
# 3    maik.schramm@karmagroup.com  empty
# 4    maik.schramm@karmagroup.com  empty
# ..                           ...    ...
# 511      gm@karmasalfordhall.com  empty
# 512      gm@karmasalfordhall.com  empty
# 513      gm@karmasalfordhall.com  empty
# 514          gm@karmabavaria.com  empty
# 515      gm@karmasalfordhall.com  empty
#
# [516 rows x 20 columns]

# %%
# Cek Email Karma
email_karma = m.find_karma(zoho_df, 'Email')
count_email_karma = email_karma.shape[0]
# email_OTA.to_excel(r'C:\Users\fajar.fatoni\Documents\Python\Data\Beambox\email_OTA.xlsx', index=False)

email_karma
# Out:
#                     Record Id         Created Time Created Date First Name  \
# 128  zcrm_3584690000456840373  2023-08-08 21:56:00        empty     Esther
#
#      Last Name                  Email          Phone  Country   Lead Brand  \
# 128  Burkhardt  afom@karmabavaria.com  4915159061850  Germany  Karma Group
#
#     Lead Sub-Brand               Lead Source Description  Lead Source  \
# 128          Other  Friend of Karma - Discount Card 2023  Web Enquiry
#
#     Lead Locations                                            Website Opt In  \
# 128  Karma Bavaria  https://karmagroup.com/friend-of-karma-bavaria...   True
#
#     Agree with Terms and Condition GDPR Compliant     Contact type  \
# 128                           True           True  Email and Phone
#
#          Enquiry sent to Mobile
# 128  gm@karmabavaria.com  empty

# %%
# delete email Karma
count_after_clean_karma = m.delete_karma(zoho_df, 'Email')
# zoho_df.to_excel(r'C:\Users\fajar.fatoni\Documents\Python\Data\Beambox\after_clean_OTA.xlsx', index=False)

zoho_df
# Out:
#                     Record Id         Created Time Created Date First Name  \
# 0    zcrm_3584690000417563854  2022-12-19 02:30:00        empty    Andreas
# 1    zcrm_3584690000418527066  2022-12-21 22:32:00        empty      Linda
# 2    zcrm_3584690000418623040  2022-12-22 01:56:00        empty  Felicitas
# 3    zcrm_3584690000418657001  2022-12-21 23:31:00        empty        Ian
# 4    zcrm_3584690000418657084  2022-12-22 00:47:00        empty      Paula
# ..                        ...                  ...          ...        ...
# 510  zcrm_3584690000540814001  2025-04-20 19:44:00        empty      Nigel
# 511  zcrm_3584690000540814034  2025-04-20 21:22:00        empty     Elliot
# 512  zcrm_3584690000540825034  2025-04-20 23:26:00        empty       Lucy
# 513  zcrm_3584690000540915630  2025-04-22 02:05:00        empty    Barbara
# 514  zcrm_3584690000541091001  2025-04-23 02:48:00        empty        Val
#
#        Last Name                          Email          Phone  \
# 0      Schmidtke             askeylargo@aol.com   491637726861
# 1            Ogg           lindaogg83@gmail.com   447746910548
# 2    Thierfelder    felicitasthierfelder@web.de  4980263873570
# 3        Rishton           ianrishton@gmail.com   447870270129
# 4       Glascott     paulajoblack@hotmail.co.uk   447718287234
# ..           ...                            ...            ...
# 510         Pugh    nigelpugh.40@btinternet.com   447973867185
# 511        Toney          3lli0tt0ney@gmail.com   447597124010
# 512        Floyd             lucy_floyd@sky.com   447533076131
# 513    Stahlmann  barbara.stahlmann@t-online.de  4915116918537
# 514        Tonks       tonks.val@googlemail.com   447535976698
#
#             Country   Lead Brand Lead Sub-Brand  \
# 0           Germany  Karma Group          Other
# 1    United Kingdom  Karma Group          Other
# 2           Germany  Karma Group          Other
# 3    United Kingdom  Karma Group          Other
# 4    United Kingdom  Karma Group          Other
# ..              ...          ...            ...
# 510  United Kingdom  Karma Group          Other
# 511  United Kingdom  Karma Group          Other
# 512  United Kingdom  Karma Group          Other
# 513         Germany  Karma Group          Other
# 514  United Kingdom  Karma Group          Other
#
#                   Lead Source Description  Lead Source      Lead Locations  \
# 0    Friend of Karma - Discount Card 2023  Web Enquiry       Karma Bavaria
# 1    Friend of Karma - Discount Card 2023  Web Enquiry  Karma Salford Hall
# 2    Friend of Karma - Discount Card 2023  Web Enquiry       Karma Bavaria
# 3    Friend of Karma - Discount Card 2023  Web Enquiry  Karma Salford Hall
# 4    Friend of Karma - Discount Card 2023  Web Enquiry  Karma Salford Hall
# ..                                    ...          ...                 ...
# 510  Friend of Karma - Discount Card 2023  Web Enquiry  Karma Salford Hall
# 511  Friend of Karma - Discount Card 2023  Web Enquiry  Karma Salford Hall
# 512  Friend of Karma - Discount Card 2023  Web Enquiry  Karma Salford Hall
# 513  Friend of Karma - Discount Card 2023  Web Enquiry       Karma Bavaria
# 514  Friend of Karma - Discount Card 2023  Web Enquiry  Karma Salford Hall
#
#                                                Website Opt In  \
# 0    https://karmagroup.com/friend-of-karma-bavaria...  False
# 1    https://karmagroup.com/friend-of-karma-salford...  False
# 2    https://karmagroup.com/friend-of-karma-bavaria...  False
# 3    https://karmagroup.com/friend-of-karma-salford...  False
# 4    https://karmagroup.com/friend-of-karma-salford...  False
# ..                                                 ...    ...
# 510  https://karmagroup.com/friend-of-karma-salford...   True
# 511  https://karmagroup.com/friend-of-karma-salford...   True
# 512  https://karmagroup.com/friend-of-karma-salford...   True
# 513  https://karmagroup.com/friend-of-karma-bavaria...   True
# 514  https://karmagroup.com/friend-of-karma-salford...   True
#
#     Agree with Terms and Condition GDPR Compliant     Contact type  \
# 0                            False          False            empty
# 1                            False          False            empty
# 2                            False          False            empty
# 3                            False          False            empty
# 4                            False          False            empty
# ..                             ...            ...              ...
# 510                           True           True  Email and Phone
# 511                           True           True  Email and Phone
# 512                           True           True  Email and Phone
# 513                           True           True  Email and Phone
# 514                           True           True  Email and Phone
#
#                  Enquiry sent to Mobile
# 0    maik.schramm@karmagroup.com  empty
# 1    maik.schramm@karmagroup.com  empty
# 2    maik.schramm@karmagroup.com  empty
# 3    maik.schramm@karmagroup.com  empty
# 4    maik.schramm@karmagroup.com  empty
# ..                           ...    ...
# 510      gm@karmasalfordhall.com  empty
# 511      gm@karmasalfordhall.com  empty
# 512      gm@karmasalfordhall.com  empty
# 513          gm@karmabavaria.com  empty
# 514      gm@karmasalfordhall.com  empty
#
# [515 rows x 20 columns]

# %%
find_member_booking = zoho_df.copy()

find_member_booking.loc[find_member_booking['Phone'].isin(df_booking['Phone1']), 'Same Value Find'] = 'Booking-Phone1'
find_member_booking.loc[find_member_booking['Phone'].isin(df_booking['Mobile']), 'Same Value Find'] = 'Booking-Mobile'
find_member_booking.loc[find_member_booking['Mobile'].isin(df_booking['Phone1']), 'Same Value Find'] = 'Booking-Phone1' 
find_member_booking.loc[find_member_booking['Mobile'].isin(df_booking['Mobile']), 'Same Value Find'] = 'Booking-Mobile'
find_member_booking.loc[find_member_booking['Email'].isin(df_booking['Email']), 'Same Value Find'] = 'Booking-Email'

find_member_booking.loc[find_member_booking['Phone'].isin(df_phone['Mobile']), 'Same Value Find'] = 'Member-Mobile' 
find_member_booking.loc[find_member_booking['Mobile'].isin(df_phone['Mobile']), 'Same Value Find'] = 'Member-Mobile'

find_member_booking.loc[find_member_booking['Email'].isin(df_email['Email']), 'Same Value Find'] = 'Member-Email'

find_member_booking.drop(find_member_booking.loc[find_member_booking['Same Value Find'].isna()].index, inplace=True)

count_booking_dedup = find_member_booking.loc[find_member_booking['Same Value Find'].str.contains('Booking', flags=re.I, regex=True)].shape[0]
count_member_dedup = find_member_booking.loc[find_member_booking['Same Value Find'].str.contains('Member', flags=re.I, regex=True)].shape[0]

find_member_booking.replace('empty', '', inplace=True)
# find_member_booking.to_csv(r'C:\Users\fajar.fatoni\Documents\Python\Data\Beambox\booking-member-dedup.csv', index=False)
# find_member_booking.to_excel(r'C:\Users\fajar.fatoni\Documents\Python\Data\Beambox\booking-member-dedup.xlsx', index=False)

#find_member_booking.loc[find_member_booking['Same Value Find'] == 'Booking-Phone1']

# %%
# data phone, mobile dam email member yang ada di master data 
count_wash_member = zoho_df.loc[
    zoho_df['Phone'].isin(df_booking['Phone1']) | 
    zoho_df['Phone'].isin(df_booking['Mobile']) |
    zoho_df['Mobile'].isin(df_booking['Phone1']) | 
    zoho_df['Mobile'].isin(df_booking['Mobile']) |
    zoho_df['Email'].isin(df_booking['Email'])| 

    zoho_df['Phone'].isin(df_phone['Mobile']) | 
    zoho_df['Mobile'].isin(df_phone['Mobile']) |

    zoho_df['Email'].isin(df_email['Email'])

].shape[0]

zoho_df.drop(zoho_df.loc[
    zoho_df['Phone'].isin(df_booking['Phone1']) | 
    zoho_df['Phone'].isin(df_booking['Mobile']) |
    zoho_df['Mobile'].isin(df_booking['Phone1']) | 
    zoho_df['Mobile'].isin(df_booking['Mobile']) |
    zoho_df['Email'].isin(df_booking['Email']) |
    
    zoho_df['Phone'].isin(df_phone['Mobile']) | 
    zoho_df['Mobile'].isin(df_phone['Mobile']) |

    zoho_df['Email'].isin(df_email['Email'])

    ].index, inplace=True)
    
zoho_df.reset_index(drop=True, inplace=True)

count_after_wash_member = zoho_df.shape[0]

# %%
count_email_only = zoho_df.loc[(zoho_df['Email'] != 'empty') & ((zoho_df['Phone'] == 'empty') & (zoho_df['Mobile'] == 'empty'))].shape[0]
count_phone_only = zoho_df.loc[(zoho_df['Email'] == 'empty') & ((zoho_df['Phone'] != 'empty') | (zoho_df['Mobile'] != 'empty'))].shape[0]
count_email_and_phone = zoho_df.loc[(zoho_df['Email'] != 'empty') & ((zoho_df['Phone'] != 'empty') | (zoho_df['Mobile'] != 'empty'))].shape[0]

count_blank = zoho_df.loc[(zoho_df['Email'] =='empty') & (zoho_df['Phone']=='empty') & (zoho_df['Mobile']=='empty')].shape[0]

# zoho_df.loc[(zoho_df['Email'] =='empty') & (zoho_df['Phone']=='empty') & (zoho_df['Mobile']=='empty')].to_excel(r'C:\Users\fajar.fatoni\Documents\Python\Data\Beambox\blank_data.xlsx', index=False)

zoho_df.loc[(zoho_df['Email'] != 'empty') & ((zoho_df['Phone'] == 'empty') & (zoho_df['Mobile'] == 'empty')), 'Contact Type'] = 'Email Only'
zoho_df.loc[(zoho_df['Email'] == 'empty') & ((zoho_df['Phone'] != 'empty') | (zoho_df['Mobile'] != 'empty')), 'Contact Type'] = 'Phone Only'
zoho_df.loc[(zoho_df['Email'] != 'empty') & ((zoho_df['Phone'] != 'empty') | (zoho_df['Mobile'] != 'empty')), 'Contact Type'] = 'Email and Phone'

zoho_df.drop(zoho_df.loc[(zoho_df['Email'] =='empty') & (zoho_df['Phone']=='empty') & (zoho_df['Mobile']=='empty')].index, inplace=True)
zoho_df.reset_index(drop=True, inplace=True)

count_after_wash_blank = zoho_df.shape[0]

# %%
arr_dedup = [count_deleted_wrong_format, count_duplicate_general, count_email_OTA, count_email_karma, count_blank]
count_sum_dedup = sum(arr_dedup)
count_sum_dedup
# Out:
# 9

# %%
print("==========================================================")
print("Summary")
print("==========================================================")
print("Jumlah Filter Leads Awal : "+str(count_filter_awal))
print("Jumlah Format Email Salah : "+str(count_deleted_wrong_format))
print("Jumlah Setelah Clean Format Email Salah : "+str(count_after_deleted_wrong_format))
print("Jumlah Duplicate (Phone, Mobile, Email dan LSD) : "+str(count_duplicate_general))
print("Jumlah Setelah Clean Duplicate : "+str(count_after_dedup_duplicate))
# print("Jumlah Lead Test : "+str(count_leads_test))
# print("Jumlah Setelah Clean Lead Test : "+str(count_after_dedup_test))
# print("Jumlah Lead Do Not Mail : "+str(count_dnm))
# print("Jumlah Setelah Clean Lead Do Not Mail : "+str(count_after_dedup_dnm))
print("Jumlah Email OTA : "+str(count_email_OTA))
print("Jumlah Setelah Clean Email OTA : "+str(count_after_clean_OTA))
print("Jumlah Email Karma : "+str(count_email_karma))
print("Jumlah Setelah Clean Email Karma : "+str(count_after_clean_karma))
print("Jumlah Wash Member : "+str(count_member_dedup))
print("Jumlah Wash Booking : "+str(count_booking_dedup))
print("Jumlah Setelah Wash Member : "+str(count_after_wash_member))
print("Jumlah Phone Email Blank (Setelah phone yang tidak valid dihapus) : "+str(count_blank))
print("Jumlah Setelah Wash Phone Email Blank : "+str(count_after_wash_blank))
print("==========================================================")
print("Contact Type")
print("==========================================================")
print("Jumlah Email Only : "+str(count_email_only))
print("Jumlah Phone Only : "+str(count_phone_only))
print("Jumlah Email dan Phone : "+str(count_email_and_phone))
# Out:
# ==========================================================
# Summary
# ==========================================================
# Jumlah Filter Leads Awal : 523
# Jumlah Format Email Salah : 0
# Jumlah Setelah Clean Format Email Salah : 523
# Jumlah Duplicate (Phone, Mobile, Email dan LSD) : 7
# Jumlah Setelah Clean Duplicate : 516
# Jumlah Email OTA : 0
# Jumlah Setelah Clean Email OTA : 516
# Jumlah Email Karma : 1
# Jumlah Setelah Clean Email Karma : 515
# Jumlah Wash Member : 1
# Jumlah Wash Booking : 0
# Jumlah Setelah Wash Member : 514
# Jumlah Phone Email Blank (Setelah phone yang tidak valid dihapus) : 1
# Jumlah Setelah Wash Phone Email Blank : 513
# ==========================================================
# Contact Type
# ==========================================================
# Jumlah Email Only : 2
# Jumlah Phone Only : 1
# Jumlah Email dan Phone : 510

# %%
print("==========================================================")
print("Summary Report")
print("==========================================================")
print("Jumlah Data Awal : "+str(count_filter_awal))
print("Jumlah Wash Dedup : "+str(count_sum_dedup))
print("Jumlah Wash Member : "+str(count_member_dedup))
print("Jumlah Wash Booking : "+str(count_booking_dedup))
print("Jumlah Data Akhir : "+str(count_after_wash_blank))
# Out:
# ==========================================================
# Summary Report
# ==========================================================
# Jumlah Data Awal : 523
# Jumlah Wash Dedup : 9
# Jumlah Wash Member : 1
# Jumlah Wash Booking : 0
# Jumlah Data Akhir : 513

# %%
zoho_df.replace('empty', '', inplace=True, regex=True)

zoho_df['First Name'] = zoho_df['First Name'].str.title()
zoho_df['Last Name'] = zoho_df['Last Name'].str.title()

zoho_df.to_csv(r'C:\Users\fajar.fatoni\Documents\Python\Data\friend of karma.csv', index=False)
# zoho_df.to_excel(r'C:\Users\fajar.fatoni\Documents\Python\Data\whatsapp channel.xlsx', index=False)
