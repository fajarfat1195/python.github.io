# %%
import main_module as m
import zoho_filter_module as fil
import pandas as pd
import re
import numpy as np

# %load_ext autoreload
# %autoreload 2

cols = ['Record Id',	
'Created Time',
'Created Date',	
'First Name',	
'Last Name',	
'Email',	
'Phone',	
'Mobile',	
'Birthdate',	
'Year of Birth',
'Street',	
'Street2',	
'City',	
'State',	
'Country',	
'Nationality',
'Booking Status', 
'BookRef',
'Departure Date',	
'Arrival Date',	
'Card Type',	
'Marital Status',	
'Lead Brand',	
'Lead Sub-Brand',	
'Lead Source',	
'Lead Locations',	
'Lead Source Description',	
'Lead Regions',
'Lead Status',
'Email Opt Out',	
'Opt In']
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
path = r'C:\Users\fajar.fatoni\Documents\Python\Data\Karma Kandara - Wedding Leads.xlsx'
# zoho_df = pd.read_csv(path, dtype='string')
zoho_df = pd.read_excel(path, dtype='string', sheet_name='KK Wedding Leads')

zoho_df.reset_index(drop=True, inplace=True)
count_filter_awal = zoho_df.shape[0]

# mengisi kolom <NA> dengan value string 'empty' supaya mudah mengecek data member dan booking dengan isin
zoho_df.fillna('empty', inplace=True)

zoho_df['Mobile'] = 'empty'
# zoho_df['Phone'] = 'empty'
zoho_df
# Out:
#                      Record Id         Created Time         Created Date  \
# 0     zcrm_3584690000535783234  2025-04-04 11:46:26  2025-04-03 00:00:00
# 1     zcrm_3584690000535783235  2025-04-04 11:46:26  2025-04-03 00:00:00
# 2     zcrm_3584690000535783236  2025-04-04 11:46:26  2025-04-03 00:00:00
# 3     zcrm_3584690000535783237  2025-04-04 11:46:26  2025-04-02 00:00:00
# 4     zcrm_3584690000535783238  2025-04-04 11:46:26  2025-04-02 00:00:00
# ...                        ...                  ...                  ...
# 3346  zcrm_3584690000088602263  2019-08-05 17:22:05  2021-07-21 00:00:00
# 3347  zcrm_3584690000053541163  2019-06-27 20:37:26  2021-07-21 00:00:00
# 3348  zcrm_3584690000029445895  2019-05-08 18:44:25  2021-07-21 00:00:00
# 3349  zcrm_3584690000024815001  2019-04-08 22:44:50  2021-07-21 00:00:00
# 3350  zcrm_3584690000001674307  2019-02-08 17:46:35  2021-07-21 00:00:00
#
#      First Name Last Name                           Email          Phone  \
# 0          Dani      Love                           empty    61433287423
# 1      Danielle      Love    danielle.love@outlook.com.au    61433287423
# 2         Reece    Limond                           empty    61421081363
# 3         Isaac      Lake                           empty    61420562484
# 4       Mariana         -                           empty    61422438172
# ...         ...       ...                             ...            ...
# 3346       Andy     Cocoy            legacywo@hotmail.com  6287823303095
# 3347       Imaa         -              masace@indo.net.id   628123914666
# 3348       Ekin         -  lebali.international@gmail.com  6281933035158
# 3349       Viki  Kurniadi          vikikurniadi@gmail.com   628122376517
# 3350     Calvin   Aprileo         calvinaprileo@yahoo.com  6282112898950
#
#         City    Country     Lead Brand  ...  \
# 0     Sydney  Australia  Karma Resorts  ...
# 1     Sydney  Australia  Karma Resorts  ...
# 2     Sydney  Australia  Karma Resorts  ...
# 3     Sydney  Australia  Karma Resorts  ...
# 4     Sydney  Australia  Karma Resorts  ...
# ...      ...        ...            ...  ...
# 3346   empty  Indonesia  Karma Resorts  ...
# 3347   empty  Indonesia  Karma Resorts  ...
# 3348  Badung  Indonesia  Karma Resorts  ...
# 3349   empty  Indonesia  Karma Resorts  ...
# 3350   empty  Indonesia  Karma Resorts  ...
#
#      Which type of wedding package are you interested  \
# 0                                               empty
# 1                                               empty
# 2                                               empty
# 3                                               empty
# 4                                               empty
# ...                                               ...
# 3346                                            empty
# 3347                                            empty
# 3348                                            empty
# 3349                                            empty
# 3350                                            empty
#
#      Approximately when are you planning to book wed  \
# 0                                              empty
# 1                                              empty
# 2                                              empty
# 3                                              empty
# 4                                              empty
# ...                                              ...
# 3346                                           empty
# 3347                                           empty
# 3348                                           empty
# 3349                                           empty
# 3350                                           empty
#
#      What is the estimated size of your guest list?   Agency Name Messages  \
# 0                                         Guest <49  ONTOP Agency    empty
# 1                                             empty  ONTOP Agency    empty
# 2                                         Guest <49  ONTOP Agency    empty
# 3                                       Guest 50-99  ONTOP Agency    empty
# 4                                         Guest <49  ONTOP Agency    empty
# ...                                             ...           ...      ...
# 3346                                          empty         empty    empty
# 3347                                          empty         empty    empty
# 3348                                          empty         empty    empty
# 3349                                          empty         empty    empty
# 3350                                          empty         empty    empty
#
#                             Description/Deal Stage       Enquiry/Budget  \
# 0                                 ? Qualified Lead                empty
# 1                                 ? Qualified Lead                empty
# 2                                 ? Qualified Lead  Budget 10 - 25K AUD
# 3                          ?ï¸_x008f_First Contact  Budget 10 - 25K AUD
# 4                          ?ï¸_x008f_First Contact                empty
# ...                                            ...                  ...
# 3346                                         empty                empty
# 3347                                         empty                empty
# 3348                                         empty                empty
# 3349                                         empty                empty
# 3350  BGID | FB3 | w4dec18 | Harris Hotel Seminyak                empty
#
#                                                Comments  \
# 0                                                 empty
# 1                                                 empty
# 2                                                 empty
# 3                                                 empty
# 4                                                 empty
# ...                                                 ...
# 3346                                              empty
# 3347  Reservation ref. -  Retail Agent , Market - Do...
# 3348        Market: India, Segmentation: Overseas Agent
# 3349                                              empty
# 3350                                              empty
#
#                                                 Website Mobile
# 0     https://weddings.karmagroup.com/sydney?utm_sou...  empty
# 1     https://weddings.karmagroup.com/sydney?utm_sou...  empty
# 2     https://weddings.karmagroup.com/sydney?utm_sou...  empty
# 3     https://weddings.karmagroup.com/sydney?utm_sou...  empty
# 4     https://weddings.karmagroup.com/sydney?utm_sou...  empty
# ...                                                 ...    ...
# 3346                                              empty  empty
# 3347                                              empty  empty
# 3348                                              empty  empty
# 3349                                              empty  empty
# 3350                                              empty  empty
#
# [3351 rows x 27 columns]

# %%
path = r'G:\.shortcut-targets-by-id\0B_d3smBjzo04eXpvS1NXTWF2RVE\_BOOKING\Booking By Year\FlyBuy Booking Data (BGAU & BGID & KE).xlsx'
df_booking = pd.read_excel(path, dtype='string', sheet_name='BOOKING_BGAU_BGID_KE')

path = r'G:\.shortcut-targets-by-id\0B_d3smBjzo04UUNBME5GOVhoMjA\_ODYSSEY\Phone Members.xlsx'
df_phone = pd.read_excel(path, dtype='string', sheet_name='Sheet1')

path = r'G:\.shortcut-targets-by-id\0B_d3smBjzo04UUNBME5GOVhoMjA\_ODYSSEY\Email Members.xlsx'
df_email = pd.read_excel(path, dtype='string', sheet_name='Sheet1')

# %% [markdown]
# # ====================== Awal Filter Umum ======================

# %%
# data phone, mobile dam email member yang ada di master data (wash member)

m.clean_number(zoho_df, 'Phone')
m.clean_number(zoho_df, 'Mobile')
m.replace_not_valid_to_empty(zoho_df, 'Phone')
m.replace_not_valid_to_empty(zoho_df, 'Mobile')
zoho_df['Email'] = m.lowercase(zoho_df, 'Email')
m.clean_space(zoho_df, 'Email')
m.clean_not_valid_email_format(zoho_df, 'Email')

m.clean_number(df_booking, 'Phone1')
m.clean_number(df_booking, 'Mobile')
df_booking['Email'] = m.lowercase(df_booking, 'Email')
m.clean_space(df_booking, 'Email')
m.clean_not_valid_email_format(df_booking, 'Email')

m.clean_number(df_phone, 'Mobile')

df_email['Email'] = m.lowercase(df_email, 'Email')
m.clean_space(df_email, 'Email')
m.clean_not_valid_email_format(df_email, 'Email')
# Out:
# c:\Users\fajar.fatoni\Documents\Python\Task Offline\zoho_data_app\main_module.py:71: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[df_columns].replace(' ','', regex=True, inplace=True)
# c:\Users\fajar.fatoni\Documents\Python\Task Offline\zoho_data_app\main_module.py:72: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[df_columns].replace('[^0-9]','', regex=True, inplace=True)
# c:\Users\fajar.fatoni\Documents\Python\Task Offline\zoho_data_app\main_module.py:94: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[df_columns].replace(' ','', regex=True, inplace=True)
# c:\Users\fajar.fatoni\Documents\Python\Task Offline\zoho_data_app\main_module.py:71: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[df_columns].replace(' ','', regex=True, inplace=True)
# c:\Users\fajar.fatoni\Documents\Python\Task Offline\zoho_data_app\main_module.py:72: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[df_columns].replace('[^0-9]','', regex=True, inplace=True)
# 'Email'

# %%
count_deleted_wrong_format = m.delete_email_wrong_format(zoho_df, 'Email')
count_after_deleted_wrong_format = zoho_df.shape[0]

# %% [markdown]
# # ====================== Akhir Filter Umum ======================

# %%
# hitung jumlah duplicate
count_duplicate_general = zoho_df.loc[zoho_df.duplicated(subset=['Phone','Mobile','Email','Lead Source Description'])].shape[0]

zoho_df.loc[zoho_df.duplicated(subset=['Phone','Mobile','Email','Lead Source Description'])]
# Out:
#                     Record Id         Created Time         Created Date  \
# 705  zcrm_3584690000504001050  2024-07-31 17:27:34  2024-07-31 00:00:00
#
#     First Name Last Name  Email  Phone   City Country     Lead Brand  ...  \
# 705    Sherina         -  empty  empty  empty   empty  Karma Resorts  ...
#
#     Which type of wedding package are you interested  \
# 705                                            empty
#
#     Approximately when are you planning to book wed  \
# 705                                           empty
#
#     What is the estimated size of your guest list? Agency Name Messages  \
# 705                                          empty       empty    empty
#
#     Description/Deal Stage Enquiry/Budget Comments Website Mobile
# 705                  empty          empty    empty   empty  empty
#
# [1 rows x 27 columns]

# %%
zoho_df.drop_duplicates(subset=['Phone','Mobile','Email','Lead Source Description'], inplace=True)
zoho_df.reset_index(drop=True, inplace=True)

# hitung jumlah setelah value duplicate dihapus
count_after_dedup_duplicate = zoho_df.shape[0]

zoho_df
# Out:
#                      Record Id         Created Time         Created Date  \
# 0     zcrm_3584690000535783234  2025-04-04 11:46:26  2025-04-03 00:00:00
# 1     zcrm_3584690000535783235  2025-04-04 11:46:26  2025-04-03 00:00:00
# 2     zcrm_3584690000535783236  2025-04-04 11:46:26  2025-04-03 00:00:00
# 3     zcrm_3584690000535783237  2025-04-04 11:46:26  2025-04-02 00:00:00
# 4     zcrm_3584690000535783238  2025-04-04 11:46:26  2025-04-02 00:00:00
# ...                        ...                  ...                  ...
# 3345  zcrm_3584690000088602263  2019-08-05 17:22:05  2021-07-21 00:00:00
# 3346  zcrm_3584690000053541163  2019-06-27 20:37:26  2021-07-21 00:00:00
# 3347  zcrm_3584690000029445895  2019-05-08 18:44:25  2021-07-21 00:00:00
# 3348  zcrm_3584690000024815001  2019-04-08 22:44:50  2021-07-21 00:00:00
# 3349  zcrm_3584690000001674307  2019-02-08 17:46:35  2021-07-21 00:00:00
#
#      First Name Last Name                           Email          Phone  \
# 0          Dani      Love                           empty    61433287423
# 1      Danielle      Love    danielle.love@outlook.com.au    61433287423
# 2         Reece    Limond                           empty    61421081363
# 3         Isaac      Lake                           empty    61420562484
# 4       Mariana         -                           empty    61422438172
# ...         ...       ...                             ...            ...
# 3345       Andy     Cocoy            legacywo@hotmail.com  6287823303095
# 3346       Imaa         -              masace@indo.net.id   628123914666
# 3347       Ekin         -  lebali.international@gmail.com  6281933035158
# 3348       Viki  Kurniadi          vikikurniadi@gmail.com   628122376517
# 3349     Calvin   Aprileo         calvinaprileo@yahoo.com  6282112898950
#
#         City    Country     Lead Brand  ...  \
# 0     Sydney  Australia  Karma Resorts  ...
# 1     Sydney  Australia  Karma Resorts  ...
# 2     Sydney  Australia  Karma Resorts  ...
# 3     Sydney  Australia  Karma Resorts  ...
# 4     Sydney  Australia  Karma Resorts  ...
# ...      ...        ...            ...  ...
# 3345   empty  Indonesia  Karma Resorts  ...
# 3346   empty  Indonesia  Karma Resorts  ...
# 3347  Badung  Indonesia  Karma Resorts  ...
# 3348   empty  Indonesia  Karma Resorts  ...
# 3349   empty  Indonesia  Karma Resorts  ...
#
#      Which type of wedding package are you interested  \
# 0                                               empty
# 1                                               empty
# 2                                               empty
# 3                                               empty
# 4                                               empty
# ...                                               ...
# 3345                                            empty
# 3346                                            empty
# 3347                                            empty
# 3348                                            empty
# 3349                                            empty
#
#      Approximately when are you planning to book wed  \
# 0                                              empty
# 1                                              empty
# 2                                              empty
# 3                                              empty
# 4                                              empty
# ...                                              ...
# 3345                                           empty
# 3346                                           empty
# 3347                                           empty
# 3348                                           empty
# 3349                                           empty
#
#      What is the estimated size of your guest list?   Agency Name Messages  \
# 0                                         Guest <49  ONTOP Agency    empty
# 1                                             empty  ONTOP Agency    empty
# 2                                         Guest <49  ONTOP Agency    empty
# 3                                       Guest 50-99  ONTOP Agency    empty
# 4                                         Guest <49  ONTOP Agency    empty
# ...                                             ...           ...      ...
# 3345                                          empty         empty    empty
# 3346                                          empty         empty    empty
# 3347                                          empty         empty    empty
# 3348                                          empty         empty    empty
# 3349                                          empty         empty    empty
#
#                             Description/Deal Stage       Enquiry/Budget  \
# 0                                 ? Qualified Lead                empty
# 1                                 ? Qualified Lead                empty
# 2                                 ? Qualified Lead  Budget 10 - 25K AUD
# 3                          ?ï¸_x008f_First Contact  Budget 10 - 25K AUD
# 4                          ?ï¸_x008f_First Contact                empty
# ...                                            ...                  ...
# 3345                                         empty                empty
# 3346                                         empty                empty
# 3347                                         empty                empty
# 3348                                         empty                empty
# 3349  BGID | FB3 | w4dec18 | Harris Hotel Seminyak                empty
#
#                                                Comments  \
# 0                                                 empty
# 1                                                 empty
# 2                                                 empty
# 3                                                 empty
# 4                                                 empty
# ...                                                 ...
# 3345                                              empty
# 3346  Reservation ref. -  Retail Agent , Market - Do...
# 3347        Market: India, Segmentation: Overseas Agent
# 3348                                              empty
# 3349                                              empty
#
#                                                 Website Mobile
# 0     https://weddings.karmagroup.com/sydney?utm_sou...  empty
# 1     https://weddings.karmagroup.com/sydney?utm_sou...  empty
# 2     https://weddings.karmagroup.com/sydney?utm_sou...  empty
# 3     https://weddings.karmagroup.com/sydney?utm_sou...  empty
# 4     https://weddings.karmagroup.com/sydney?utm_sou...  empty
# ...                                                 ...    ...
# 3345                                              empty  empty
# 3346                                              empty  empty
# 3347                                              empty  empty
# 3348                                              empty  empty
# 3349                                              empty  empty
#
# [3350 rows x 27 columns]

# %%
# # Cek leads test
# test_leads = zoho_df.loc[
    
#         zoho_df['Email'].str.contains('^test@', flags=re.I, regex=True) |
#         zoho_df['Email'].str.contains('\+test', flags=re.I, regex=True) |
    
#         zoho_df['First Name'].str.contains('^test$', flags=re.I, regex=True) |
#         zoho_df['Last Name'].str.contains('^test$', flags=re.I, regex=True) |

#         zoho_df['First Name'].str.contains('test 1', flags=re.I, regex=True) |
#         zoho_df['Last Name'].str.contains('test 2', flags=re.I, regex=True)|
#         zoho_df['First Name'].str.contains('test1', flags=re.I, regex=True) |
#         zoho_df['Last Name'].str.contains('test2', flags=re.I, regex=True)|

#         zoho_df['First Name'].str.contains(' test ', flags=re.I, regex=True) | 
#         zoho_df['Last Name'].str.contains(' test ', flags=re.I, regex=True) | 
#         zoho_df['Last Name'].str.contains(' test$', flags=re.I, regex=True)
#     ]

# count_leads_test = test_leads.shape[0]

# # test_leads.to_excel(r'C:\Users\fajar.fatoni\Documents\Python\Data\Beambox\test_leads_2.xlsx', index=False)
# test_leads

# %%
# zoho_df.drop(test_leads.index, inplace=True)
# zoho_df.reset_index(drop=True, inplace=True)

# count_after_dedup_test = zoho_df.shape[0]

# %%
# dnm_leads = zoho_df.loc[(zoho_df['Do Not Mail'] == 'true') | (zoho_df['Do Not Contact'] == 'true')]
# count_dnm = dnm_leads.shape[0]

# %%
# zoho_df.drop(dnm_leads.index, inplace=True)
# zoho_df.reset_index(drop=True, inplace=True)

# count_after_dedup_dnm = zoho_df.shape[0]

# %%
# Cek Email OTA
email_OTA = m.find_OTA(zoho_df, 'Email')
count_email_OTA = email_OTA.shape[0]
# email_OTA.to_excel(r'C:\Users\fajar.fatoni\Documents\Python\Data\Beambox\email_OTA.xlsx', index=False)

email_OTA
# Out:
#                      Record Id         Created Time         Created Date  \
# 3333  zcrm_3584690000301303893  2021-07-21 16:59:49  2021-07-21 00:00:00
# 3336  zcrm_3584690000301303943  2021-07-21 16:59:49  2021-07-21 00:00:00
#
#      First Name    Last Name                            Email          Phone  \
# 3333      Susan  Kosasih, SE        baliamazingtour@yahoo.com   628126373522
# 3336  Chatarina        Riris  chatarina.riris@lestaritour.com  6281802718899
#
#        City    Country     Lead Brand  ...  \
# 3333  empty  Indonesia  Karma Resorts  ...
# 3336  empty  Indonesia  Karma Resorts  ...
#
#      Which type of wedding package are you interested  \
# 3333                                            empty
# 3336                                            empty
#
#      Approximately when are you planning to book wed  \
# 3333                                           empty
# 3336                                           empty
#
#      What is the estimated size of your guest list? Agency Name Messages  \
# 3333                                          empty       empty    empty
# 3336                                          empty       empty    empty
#
#      Description/Deal Stage Enquiry/Budget Comments Website Mobile
# 3333                  empty          empty    empty   empty  empty
# 3336                  empty          empty    empty   empty  empty
#
# [2 rows x 27 columns]

# %%
# delete email OTA
count_after_clean_OTA = m.delete_OTA(zoho_df, 'Email')
# zoho_df.to_excel(r'C:\Users\fajar.fatoni\Documents\Python\Data\Beambox\after_clean_OTA.xlsx', index=False)

zoho_df
# Out:
#                      Record Id         Created Time         Created Date  \
# 0     zcrm_3584690000535783234  2025-04-04 11:46:26  2025-04-03 00:00:00
# 1     zcrm_3584690000535783235  2025-04-04 11:46:26  2025-04-03 00:00:00
# 2     zcrm_3584690000535783236  2025-04-04 11:46:26  2025-04-03 00:00:00
# 3     zcrm_3584690000535783237  2025-04-04 11:46:26  2025-04-02 00:00:00
# 4     zcrm_3584690000535783238  2025-04-04 11:46:26  2025-04-02 00:00:00
# ...                        ...                  ...                  ...
# 3343  zcrm_3584690000088602263  2019-08-05 17:22:05  2021-07-21 00:00:00
# 3344  zcrm_3584690000053541163  2019-06-27 20:37:26  2021-07-21 00:00:00
# 3345  zcrm_3584690000029445895  2019-05-08 18:44:25  2021-07-21 00:00:00
# 3346  zcrm_3584690000024815001  2019-04-08 22:44:50  2021-07-21 00:00:00
# 3347  zcrm_3584690000001674307  2019-02-08 17:46:35  2021-07-21 00:00:00
#
#      First Name Last Name                           Email          Phone  \
# 0          Dani      Love                           empty    61433287423
# 1      Danielle      Love    danielle.love@outlook.com.au    61433287423
# 2         Reece    Limond                           empty    61421081363
# 3         Isaac      Lake                           empty    61420562484
# 4       Mariana         -                           empty    61422438172
# ...         ...       ...                             ...            ...
# 3343       Andy     Cocoy            legacywo@hotmail.com  6287823303095
# 3344       Imaa         -              masace@indo.net.id   628123914666
# 3345       Ekin         -  lebali.international@gmail.com  6281933035158
# 3346       Viki  Kurniadi          vikikurniadi@gmail.com   628122376517
# 3347     Calvin   Aprileo         calvinaprileo@yahoo.com  6282112898950
#
#         City    Country     Lead Brand  ...  \
# 0     Sydney  Australia  Karma Resorts  ...
# 1     Sydney  Australia  Karma Resorts  ...
# 2     Sydney  Australia  Karma Resorts  ...
# 3     Sydney  Australia  Karma Resorts  ...
# 4     Sydney  Australia  Karma Resorts  ...
# ...      ...        ...            ...  ...
# 3343   empty  Indonesia  Karma Resorts  ...
# 3344   empty  Indonesia  Karma Resorts  ...
# 3345  Badung  Indonesia  Karma Resorts  ...
# 3346   empty  Indonesia  Karma Resorts  ...
# 3347   empty  Indonesia  Karma Resorts  ...
#
#      Which type of wedding package are you interested  \
# 0                                               empty
# 1                                               empty
# 2                                               empty
# 3                                               empty
# 4                                               empty
# ...                                               ...
# 3343                                            empty
# 3344                                            empty
# 3345                                            empty
# 3346                                            empty
# 3347                                            empty
#
#      Approximately when are you planning to book wed  \
# 0                                              empty
# 1                                              empty
# 2                                              empty
# 3                                              empty
# 4                                              empty
# ...                                              ...
# 3343                                           empty
# 3344                                           empty
# 3345                                           empty
# 3346                                           empty
# 3347                                           empty
#
#      What is the estimated size of your guest list?   Agency Name Messages  \
# 0                                         Guest <49  ONTOP Agency    empty
# 1                                             empty  ONTOP Agency    empty
# 2                                         Guest <49  ONTOP Agency    empty
# 3                                       Guest 50-99  ONTOP Agency    empty
# 4                                         Guest <49  ONTOP Agency    empty
# ...                                             ...           ...      ...
# 3343                                          empty         empty    empty
# 3344                                          empty         empty    empty
# 3345                                          empty         empty    empty
# 3346                                          empty         empty    empty
# 3347                                          empty         empty    empty
#
#                             Description/Deal Stage       Enquiry/Budget  \
# 0                                 ? Qualified Lead                empty
# 1                                 ? Qualified Lead                empty
# 2                                 ? Qualified Lead  Budget 10 - 25K AUD
# 3                          ?ï¸_x008f_First Contact  Budget 10 - 25K AUD
# 4                          ?ï¸_x008f_First Contact                empty
# ...                                            ...                  ...
# 3343                                         empty                empty
# 3344                                         empty                empty
# 3345                                         empty                empty
# 3346                                         empty                empty
# 3347  BGID | FB3 | w4dec18 | Harris Hotel Seminyak                empty
#
#                                                Comments  \
# 0                                                 empty
# 1                                                 empty
# 2                                                 empty
# 3                                                 empty
# 4                                                 empty
# ...                                                 ...
# 3343                                              empty
# 3344  Reservation ref. -  Retail Agent , Market - Do...
# 3345        Market: India, Segmentation: Overseas Agent
# 3346                                              empty
# 3347                                              empty
#
#                                                 Website Mobile
# 0     https://weddings.karmagroup.com/sydney?utm_sou...  empty
# 1     https://weddings.karmagroup.com/sydney?utm_sou...  empty
# 2     https://weddings.karmagroup.com/sydney?utm_sou...  empty
# 3     https://weddings.karmagroup.com/sydney?utm_sou...  empty
# 4     https://weddings.karmagroup.com/sydney?utm_sou...  empty
# ...                                                 ...    ...
# 3343                                              empty  empty
# 3344                                              empty  empty
# 3345                                              empty  empty
# 3346                                              empty  empty
# 3347                                              empty  empty
#
# [3348 rows x 27 columns]

# %%
# Cek Email Karma
email_karma = m.find_karma(zoho_df, 'Email')
count_email_karma = email_karma.shape[0]
# email_OTA.to_excel(r'C:\Users\fajar.fatoni\Documents\Python\Data\Beambox\email_OTA.xlsx', index=False)

email_karma
# Out:
#                      Record Id         Created Time         Created Date  \
# 118   zcrm_3584690000534660035  2025-03-26 11:19:47  2025-03-26 00:00:00
# 151   zcrm_3584690000531049042  2025-03-18 14:52:43  2025-03-18 00:00:00
# 223   zcrm_3584690000524711431  2025-02-17 12:01:15                empty
# 226   zcrm_3584690000524712318  2025-02-17 11:39:57                empty
# 241   zcrm_3584690000524238218  2025-02-12 10:55:59                empty
# 243   zcrm_3584690000524290202  2025-02-12 10:53:56                empty
# 407   zcrm_3584690000517464001  2024-12-05 10:03:32  2024-12-05 00:00:00
# 408   zcrm_3584690000517451035  2024-12-05 10:02:40  2024-12-05 00:00:00
# 409   zcrm_3584690000517412068  2024-12-05 10:02:24  2024-12-05 00:00:00
# 1352  zcrm_3584690000496311706  2024-05-21 12:46:21  2024-05-21 00:00:00
# 1422  zcrm_3584690000492392060  2024-04-18 15:56:41                empty
# 1427  zcrm_3584690000491983036  2024-04-16 18:26:51                empty
# 1795  zcrm_3584690000470644676  2023-11-22 11:57:12                empty
# 2907  zcrm_3584690000415832001  2022-12-08 21:36:33                empty
#
#      First Name    Last Name                               Email  \
# 118       Benny      Risanto    benny.risanto+007@karmagroup.com
# 151       Ferry        Ferry   ferry.yudhitama+85@karmagroup.com
# 223         tkl          tkl  tanya.klimentyeva@karmakandara.com
# 226        Agus      Maryana       agus.maryana@karmaresorts.com
# 241    Asthinni          Sri   eventcoordinator@karmakandara.com
# 243     Alfonso            R    alfonso.carnevali@karmagroup.com
# 407        Dayu         Dayu          asst.dohr@karmakandara.com
# 408         Rai          Rai        rai.artawan@karmakandara.com
# 409       Shaun        Shaun                 gm@karmakandara.com
# 1352      Maida        Maida      maida.pratiwi@karmaresorts.com
# 1422      Tanya  Klimentyeva  tanya.klimentyeva@karmakandara.com
# 1427    Stephen        Halim   salescoordinator@karmaresorts.com
# 1795       Lita       Rahayu      novalita.rahayu@karmagroup.com
# 2907      Shaun    Duenhofen    shaun.duenhofen@karmakandara.com
#
#                Phone   City    Country     Lead Brand  ...  \
# 118      62811392202  empty  Indonesia  Karma Resorts  ...
# 151    6287861085142  empty  Indonesia  Karma Resorts  ...
# 223    6281130835940  empty  Indonesia  Karma Resorts  ...
# 226     628122730101  empty  Indonesia  Karma Resorts  ...
# 241   62895355698853  empty  Indonesia  Karma Resorts  ...
# 243    6281330916979  empty  Indonesia  Karma Resorts  ...
# 407    6282144135058  empty  Indonesia  Karma Resorts  ...
# 408    6281338016603  empty  Indonesia  Karma Resorts  ...
# 409    6281138006892  empty  Indonesia  Karma Resorts  ...
# 1352  62878900098978  empty  Indonesia  Karma Resorts  ...
# 1422   6281138305940  empty  Indonesia  Karma Resorts  ...
# 1427   6281617722971  empty  Indonesia  Karma Resorts  ...
# 1795   6282237453320  empty  Indonesia  Karma Resorts  ...
# 2907   6281138006892  empty  Indonesia  Karma Resorts  ...
#
#      Which type of wedding package are you interested  \
# 118                                             empty
# 151                                             empty
# 223                                             empty
# 226                                             empty
# 241                                             empty
# 243                                             empty
# 407                                             empty
# 408                                             empty
# 409                                             empty
# 1352                                            empty
# 1422                                            empty
# 1427                                            empty
# 1795                                            empty
# 2907                                            empty
#
#      Approximately when are you planning to book wed  \
# 118                                            empty
# 151                                            empty
# 223                                            empty
# 226                                            empty
# 241                                            empty
# 243                                            empty
# 407                                            empty
# 408                                            empty
# 409                                            empty
# 1352                                           empty
# 1422                                           empty
# 1427                                           empty
# 1795                                           empty
# 2907                                           empty
#
#      What is the estimated size of your guest list? Agency Name  \
# 118                                           empty       empty
# 151                                           empty       empty
# 223                                           empty       empty
# 226                                           empty       empty
# 241                                           empty       empty
# 243                                           empty       empty
# 407                                           empty       empty
# 408                                           empty       empty
# 409                                           empty       empty
# 1352                                          empty       empty
# 1422                                          empty       empty
# 1427                                          empty       empty
# 1795                                          empty       empty
# 2907                                          empty       empty
#
#                                                Messages  \
# 118                                                Test
# 151   Test Message from web developer,  Please ignor...
# 223                                               empty
# 226                                               empty
# 241                                               empty
# 243                                               empty
# 407   Please provide me the detail for more information
# 408                       Wedding booking in march 2025
# 409                                            Location
# 1352                                              empty
# 1422                                              empty
# 1427                                              empty
# 1795                                              empty
# 2907                                              empty
#
#      Description/Deal Stage Enquiry/Budget Comments  \
# 118                   empty          empty    empty
# 151                   empty          empty    empty
# 223                   empty          empty    empty
# 226                   empty          empty    empty
# 241                   empty          empty    empty
# 243                   empty          empty    empty
# 407                   empty          empty    empty
# 408                   empty          empty    empty
# 409                   empty          empty    empty
# 1352                  empty          empty    empty
# 1422                  empty          empty    empty
# 1427                  empty          empty    empty
# 1795                  empty          empty    empty
# 2907                  empty          empty    empty
#
#                                                 Website Mobile
# 118   https://karmagroup.com/weddings-at-karma-kanda...  empty
# 151   https://karmagroup.com/weddings-at-karma-kanda...  empty
# 223   https://karmagroup.com/weddings-at-karma-kanda...  empty
# 226   https://karmagroup.com/weddings-at-karma-kanda...  empty
# 241   https://karmagroup.com/weddings-at-karma-kanda...  empty
# 243   https://karmagroup.com/weddings-at-karma-kanda...  empty
# 407   https://karmagroup.com/weddings-at-karma-kanda...  empty
# 408   https://karmagroup.com/weddings-at-karma-kanda...  empty
# 409   https://karmagroup.com/weddings-at-karma-kanda...  empty
# 1352  https://karmagroup.com/weddings-at-karma-kanda...  empty
# 1422  https://karmagroup.com/weddings-at-karma-kanda...  empty
# 1427  https://karmagroup.com/weddings-at-karma-kanda...  empty
# 1795  https://karmagroup.com/weddings-at-karma-kanda...  empty
# 2907  https://karmagroup.com/weddings-at-karma-kanda...  empty
#
# [14 rows x 27 columns]

# %%
# delete email Karma
count_after_clean_karma = m.delete_karma(zoho_df, 'Email')
# zoho_df.to_excel(r'C:\Users\fajar.fatoni\Documents\Python\Data\Beambox\after_clean_OTA.xlsx', index=False)

zoho_df
# Out:
#                      Record Id         Created Time         Created Date  \
# 0     zcrm_3584690000535783234  2025-04-04 11:46:26  2025-04-03 00:00:00
# 1     zcrm_3584690000535783235  2025-04-04 11:46:26  2025-04-03 00:00:00
# 2     zcrm_3584690000535783236  2025-04-04 11:46:26  2025-04-03 00:00:00
# 3     zcrm_3584690000535783237  2025-04-04 11:46:26  2025-04-02 00:00:00
# 4     zcrm_3584690000535783238  2025-04-04 11:46:26  2025-04-02 00:00:00
# ...                        ...                  ...                  ...
# 3329  zcrm_3584690000088602263  2019-08-05 17:22:05  2021-07-21 00:00:00
# 3330  zcrm_3584690000053541163  2019-06-27 20:37:26  2021-07-21 00:00:00
# 3331  zcrm_3584690000029445895  2019-05-08 18:44:25  2021-07-21 00:00:00
# 3332  zcrm_3584690000024815001  2019-04-08 22:44:50  2021-07-21 00:00:00
# 3333  zcrm_3584690000001674307  2019-02-08 17:46:35  2021-07-21 00:00:00
#
#      First Name Last Name                           Email          Phone  \
# 0          Dani      Love                           empty    61433287423
# 1      Danielle      Love    danielle.love@outlook.com.au    61433287423
# 2         Reece    Limond                           empty    61421081363
# 3         Isaac      Lake                           empty    61420562484
# 4       Mariana         -                           empty    61422438172
# ...         ...       ...                             ...            ...
# 3329       Andy     Cocoy            legacywo@hotmail.com  6287823303095
# 3330       Imaa         -              masace@indo.net.id   628123914666
# 3331       Ekin         -  lebali.international@gmail.com  6281933035158
# 3332       Viki  Kurniadi          vikikurniadi@gmail.com   628122376517
# 3333     Calvin   Aprileo         calvinaprileo@yahoo.com  6282112898950
#
#         City    Country     Lead Brand  ...  \
# 0     Sydney  Australia  Karma Resorts  ...
# 1     Sydney  Australia  Karma Resorts  ...
# 2     Sydney  Australia  Karma Resorts  ...
# 3     Sydney  Australia  Karma Resorts  ...
# 4     Sydney  Australia  Karma Resorts  ...
# ...      ...        ...            ...  ...
# 3329   empty  Indonesia  Karma Resorts  ...
# 3330   empty  Indonesia  Karma Resorts  ...
# 3331  Badung  Indonesia  Karma Resorts  ...
# 3332   empty  Indonesia  Karma Resorts  ...
# 3333   empty  Indonesia  Karma Resorts  ...
#
#      Which type of wedding package are you interested  \
# 0                                               empty
# 1                                               empty
# 2                                               empty
# 3                                               empty
# 4                                               empty
# ...                                               ...
# 3329                                            empty
# 3330                                            empty
# 3331                                            empty
# 3332                                            empty
# 3333                                            empty
#
#      Approximately when are you planning to book wed  \
# 0                                              empty
# 1                                              empty
# 2                                              empty
# 3                                              empty
# 4                                              empty
# ...                                              ...
# 3329                                           empty
# 3330                                           empty
# 3331                                           empty
# 3332                                           empty
# 3333                                           empty
#
#      What is the estimated size of your guest list?   Agency Name Messages  \
# 0                                         Guest <49  ONTOP Agency    empty
# 1                                             empty  ONTOP Agency    empty
# 2                                         Guest <49  ONTOP Agency    empty
# 3                                       Guest 50-99  ONTOP Agency    empty
# 4                                         Guest <49  ONTOP Agency    empty
# ...                                             ...           ...      ...
# 3329                                          empty         empty    empty
# 3330                                          empty         empty    empty
# 3331                                          empty         empty    empty
# 3332                                          empty         empty    empty
# 3333                                          empty         empty    empty
#
#                             Description/Deal Stage       Enquiry/Budget  \
# 0                                 ? Qualified Lead                empty
# 1                                 ? Qualified Lead                empty
# 2                                 ? Qualified Lead  Budget 10 - 25K AUD
# 3                          ?ï¸_x008f_First Contact  Budget 10 - 25K AUD
# 4                          ?ï¸_x008f_First Contact                empty
# ...                                            ...                  ...
# 3329                                         empty                empty
# 3330                                         empty                empty
# 3331                                         empty                empty
# 3332                                         empty                empty
# 3333  BGID | FB3 | w4dec18 | Harris Hotel Seminyak                empty
#
#                                                Comments  \
# 0                                                 empty
# 1                                                 empty
# 2                                                 empty
# 3                                                 empty
# 4                                                 empty
# ...                                                 ...
# 3329                                              empty
# 3330  Reservation ref. -  Retail Agent , Market - Do...
# 3331        Market: India, Segmentation: Overseas Agent
# 3332                                              empty
# 3333                                              empty
#
#                                                 Website Mobile
# 0     https://weddings.karmagroup.com/sydney?utm_sou...  empty
# 1     https://weddings.karmagroup.com/sydney?utm_sou...  empty
# 2     https://weddings.karmagroup.com/sydney?utm_sou...  empty
# 3     https://weddings.karmagroup.com/sydney?utm_sou...  empty
# 4     https://weddings.karmagroup.com/sydney?utm_sou...  empty
# ...                                                 ...    ...
# 3329                                              empty  empty
# 3330                                              empty  empty
# 3331                                              empty  empty
# 3332                                              empty  empty
# 3333                                              empty  empty
#
# [3334 rows x 27 columns]

# %%
find_member_booking = zoho_df.copy()

find_member_booking.loc[find_member_booking['Phone'].isin(df_booking['Phone1']), 'Same Value Find'] = 'Booking-Phone1'
find_member_booking.loc[find_member_booking['Phone'].isin(df_booking['Mobile']), 'Same Value Find'] = 'Booking-Mobile'
find_member_booking.loc[find_member_booking['Mobile'].isin(df_booking['Phone1']), 'Same Value Find'] = 'Booking-Phone1' 
find_member_booking.loc[find_member_booking['Mobile'].isin(df_booking['Mobile']), 'Same Value Find'] = 'Booking-Mobile'
find_member_booking.loc[find_member_booking['Email'].isin(df_booking['Email']), 'Same Value Find'] = 'Booking-Email'

find_member_booking.loc[find_member_booking['Phone'].isin(df_phone['Mobile']), 'Same Value Find'] = 'Member-Mobile' 
find_member_booking.loc[find_member_booking['Mobile'].isin(df_phone['Mobile']), 'Same Value Find'] = 'Member-Mobile'

find_member_booking.loc[find_member_booking['Email'].isin(df_email['Email']), 'Same Value Find'] = 'Member-Email'

find_member_booking.drop(find_member_booking.loc[find_member_booking['Same Value Find'].isna()].index, inplace=True)

count_booking_dedup = find_member_booking.loc[find_member_booking['Same Value Find'].str.contains('Booking', flags=re.I, regex=True)].shape[0]
count_member_dedup = find_member_booking.loc[find_member_booking['Same Value Find'].str.contains('Member', flags=re.I, regex=True)].shape[0]

find_member_booking.replace('empty', '', inplace=True)
# find_member_booking.to_csv(r'C:\Users\fajar.fatoni\Documents\Python\Data\Beambox\booking-member-dedup.csv', index=False)
# find_member_booking.to_excel(r'C:\Users\fajar.fatoni\Documents\Python\Data\Beambox\booking-member-dedup.xlsx', index=False)

#find_member_booking.loc[find_member_booking['Same Value Find'] == 'Booking-Phone1']

# %%
# data phone, mobile dam email member yang ada di master data 
count_wash_member = zoho_df.loc[
    zoho_df['Phone'].isin(df_booking['Phone1']) | 
    zoho_df['Phone'].isin(df_booking['Mobile']) |
    zoho_df['Mobile'].isin(df_booking['Phone1']) | 
    zoho_df['Mobile'].isin(df_booking['Mobile']) |
    zoho_df['Email'].isin(df_booking['Email'])| 

    zoho_df['Phone'].isin(df_phone['Mobile']) | 
    zoho_df['Mobile'].isin(df_phone['Mobile']) |

    zoho_df['Email'].isin(df_email['Email'])

].shape[0]

zoho_df.drop(zoho_df.loc[
    zoho_df['Phone'].isin(df_booking['Phone1']) | 
    zoho_df['Phone'].isin(df_booking['Mobile']) |
    zoho_df['Mobile'].isin(df_booking['Phone1']) | 
    zoho_df['Mobile'].isin(df_booking['Mobile']) |
    zoho_df['Email'].isin(df_booking['Email']) |
    
    zoho_df['Phone'].isin(df_phone['Mobile']) | 
    zoho_df['Mobile'].isin(df_phone['Mobile']) |

    zoho_df['Email'].isin(df_email['Email'])

    ].index, inplace=True)
    
zoho_df.reset_index(drop=True, inplace=True)

count_after_wash_member = zoho_df.shape[0]

# %%
count_email_only = zoho_df.loc[(zoho_df['Email'] != 'empty') & ((zoho_df['Phone'] == 'empty') & (zoho_df['Mobile'] == 'empty'))].shape[0]
count_phone_only = zoho_df.loc[(zoho_df['Email'] == 'empty') & ((zoho_df['Phone'] != 'empty') | (zoho_df['Mobile'] != 'empty'))].shape[0]
count_email_and_phone = zoho_df.loc[(zoho_df['Email'] != 'empty') & ((zoho_df['Phone'] != 'empty') | (zoho_df['Mobile'] != 'empty'))].shape[0]

count_blank = zoho_df.loc[(zoho_df['Email'] =='empty') & (zoho_df['Phone']=='empty') & (zoho_df['Mobile']=='empty')].shape[0]

# zoho_df.loc[(zoho_df['Email'] =='empty') & (zoho_df['Phone']=='empty') & (zoho_df['Mobile']=='empty')].to_excel(r'C:\Users\fajar.fatoni\Documents\Python\Data\Beambox\blank_data.xlsx', index=False)

zoho_df.loc[(zoho_df['Email'] != 'empty') & ((zoho_df['Phone'] == 'empty') & (zoho_df['Mobile'] == 'empty')), 'Contact Type'] = 'Email Only'
zoho_df.loc[(zoho_df['Email'] == 'empty') & ((zoho_df['Phone'] != 'empty') | (zoho_df['Mobile'] != 'empty')), 'Contact Type'] = 'Phone Only'
zoho_df.loc[(zoho_df['Email'] != 'empty') & ((zoho_df['Phone'] != 'empty') | (zoho_df['Mobile'] != 'empty')), 'Contact Type'] = 'Email and Phone'

zoho_df.drop(zoho_df.loc[(zoho_df['Email'] =='empty') & (zoho_df['Phone']=='empty') & (zoho_df['Mobile']=='empty')].index, inplace=True)
zoho_df.reset_index(drop=True, inplace=True)

count_after_wash_blank = zoho_df.shape[0]

# %%
arr_dedup = [count_deleted_wrong_format, count_duplicate_general, count_email_OTA, count_email_karma, count_blank]
count_sum_dedup = sum(arr_dedup)
count_sum_dedup
# Out:
# 19

# %%
print("==========================================================")
print("Summary")
print("==========================================================")
print("Jumlah Filter Leads Awal : "+str(count_filter_awal))
print("Jumlah Format Email Salah : "+str(count_deleted_wrong_format))
print("Jumlah Setelah Clean Format Email Salah : "+str(count_after_deleted_wrong_format))
print("Jumlah Duplicate (Phone, Mobile, Email dan LSD) : "+str(count_duplicate_general))
print("Jumlah Setelah Clean Duplicate : "+str(count_after_dedup_duplicate))
# print("Jumlah Lead Test : "+str(count_leads_test))
# print("Jumlah Setelah Clean Lead Test : "+str(count_after_dedup_test))
# print("Jumlah Lead Do Not Mail : "+str(count_dnm))
# print("Jumlah Setelah Clean Lead Do Not Mail : "+str(count_after_dedup_dnm))
print("Jumlah Email OTA : "+str(count_email_OTA))
print("Jumlah Setelah Clean Email OTA : "+str(count_after_clean_OTA))
print("Jumlah Email Karma : "+str(count_email_karma))
print("Jumlah Setelah Clean Email Karma : "+str(count_after_clean_karma))
print("Jumlah Wash Member : "+str(count_member_dedup))
print("Jumlah Wash Booking : "+str(count_booking_dedup))
print("Jumlah Setelah Wash Member : "+str(count_after_wash_member))
print("Jumlah Phone Email Blank (Setelah phone yang tidak valid dihapus) : "+str(count_blank))
print("Jumlah Setelah Wash Phone Email Blank : "+str(count_after_wash_blank))
print("==========================================================")
print("Contact Type")
print("==========================================================")
print("Jumlah Email Only : "+str(count_email_only))
print("Jumlah Phone Only : "+str(count_phone_only))
print("Jumlah Email dan Phone : "+str(count_email_and_phone))
# Out:
# ==========================================================
# Summary
# ==========================================================
# Jumlah Filter Leads Awal : 3351
# Jumlah Format Email Salah : 0
# Jumlah Setelah Clean Format Email Salah : 3351
# Jumlah Duplicate (Phone, Mobile, Email dan LSD) : 1
# Jumlah Setelah Clean Duplicate : 3350
# Jumlah Email OTA : 2
# Jumlah Setelah Clean Email OTA : 3348
# Jumlah Email Karma : 14
# Jumlah Setelah Clean Email Karma : 3334
# Jumlah Wash Member : 133
# Jumlah Wash Booking : 4
# Jumlah Setelah Wash Member : 3197
# Jumlah Phone Email Blank (Setelah phone yang tidak valid dihapus) : 2
# Jumlah Setelah Wash Phone Email Blank : 3195
# ==========================================================
# Contact Type
# ==========================================================
# Jumlah Email Only : 50
# Jumlah Phone Only : 164
# Jumlah Email dan Phone : 2981

# %%
print("==========================================================")
print("Summary Report")
print("==========================================================")
print("Jumlah Data Awal : "+str(count_filter_awal))
print("Jumlah Wash Dedup : "+str(count_sum_dedup))
print("Jumlah Wash Member : "+str(count_member_dedup))
print("Jumlah Wash Booking : "+str(count_booking_dedup))
print("Jumlah Data Akhir : "+str(count_after_wash_blank))
# Out:
# ==========================================================
# Summary Report
# ==========================================================
# Jumlah Data Awal : 3351
# Jumlah Wash Dedup : 19
# Jumlah Wash Member : 133
# Jumlah Wash Booking : 4
# Jumlah Data Akhir : 3195

# %%
zoho_df.replace('empty', '', inplace=True, regex=True)

# zoho_df['First Name'] = zoho_df['First Name'].str.title()
# zoho_df['Last Name'] = zoho_df['Last Name'].str.title()

# zoho_df.to_csv(r'C:\Users\fajar.fatoni\Documents\Python\Data\Beambox\karma beach cleand.csv', index=False)
zoho_df.to_excel(r'C:\Users\fajar.fatoni\Documents\Python\Data\Karma Kandara - Wedding Leads - clean.xlsx', index=False)
