# %%
import pandas as pd
import re

import past_guest_module as pm

import sys
sys.path.append('../zoho_data_app/')

import main_module as m

# %load_ext autoreload
# %autoreload 2

# %%
cols = ['Account ID', 'FirstName', 'lastname', 'Country', 'Email', 'Phone',
       'AcStatus', 'Servicing Office','KarmaClubProgram']

# %%
path = r'C:\Users\fajar\Documents\Python\Data\KCC cc-cl\2024\Aug\11 Aug - 19 Aug\KCE CC CL 11 Aug - 19 Aug.xlsx'
df_kce = pd.read_excel(path, dtype='string', sheet_name='Sheet1', usecols=cols)
count_data_awal = df_kce.shape[0]
df_kce
# Out:
#     Account ID FirstName      lastname    Country  \
# 0      1197195    Ronald         North  Australia
# 1      1196922     Aaron       Koplick  Australia
# 2      1197199    Joshua        Sugden  Australia
# 3      1196215   Kenneth       Forrest  Australia
# 4      1196377       Ali         Nawaz  Australia
# ..         ...       ...           ...        ...
# 690    1196145    Khader         Yafai       <NA>
# 691    1196430      Ryan        Farran       <NA>
# 692    1196381    Semere  Ghebremariam       <NA>
# 693    1196714     Chris       Jackson       <NA>
# 694    1196142    Subash            Kc       <NA>
#
#                              Email        Phone AcStatus    Servicing Office  \
# 0                2ronshi@gmail.com  61424245453   ACTIVE  KC EXPERIENCE Bali
# 1         aaronkoplick@hotmail.com  61409040484   ACTIVE  KC EXPERIENCE Bali
# 2    admin@suggosconstructions.com  61414926326   ACTIVE  KC EXPERIENCE Bali
# 3            adriannef12@gmail.com  61418721041   ACTIVE  KC EXPERIENCE Bali
# 4             ali.nawaz@live.co.uk  61450054092   ACTIVE  KC EXPERIENCE Bali
# ..                             ...          ...      ...                 ...
# 690           kyafai1128@yahoo.com  14142176682   ACTIVE  KC EXPERIENCE Bali
# 691            ryan_farran@ntm.org  15732838483   ACTIVE  KC EXPERIENCE Bali
# 692          samotiteame@gmail.com  19258959204   ACTIVE  KC EXPERIENCE Bali
# 693          scurrie63@hotmail.com  85294985444   ACTIVE  KC EXPERIENCE Bali
# 694          suubashkc61@gmail.com  14697328971   ACTIVE  KC EXPERIENCE Bali
#
#           KarmaClubProgram
# 0      Jimbaran Sales Deck
# 1    Petitenget Sales Deck
# 2      Jimbaran Sales Deck
# 3    Petitenget Sales Deck
# 4      Jimbaran Sales Deck
# ..                     ...
# 690    Jimbaran Sales Deck
# 691    Jimbaran Sales Deck
# 692    Jimbaran Sales Deck
# 693     Vietnam Sales Deck
# 694    Jimbaran Sales Deck
#
# [695 rows x 9 columns]

# %%
df_kce.columns
# Out:
# Index(['Account ID', 'FirstName', 'lastname', 'Country', 'Email', 'Phone',
#        'AcStatus', 'Servicing Office', 'KarmaClubProgram'],
#       dtype='object')

# %%
df_kce.rename(columns = {
    'Account ID':'number', 
    'AcStatus':'Account Status',
    'KarmaClubProgram':'Karma Club Program',
    }, inplace = True)

# %%
df_kce.fillna('empty', inplace=True)

# %%
path = r'G:\.shortcut-targets-by-id\0B_d3smBjzo04UUNBME5GOVhoMjA\_ODYSSEY\Phone Members.xlsx'
df_phone_member_odd = pd.read_excel(path, dtype='string', sheet_name='Sheet1')

path = r'G:\.shortcut-targets-by-id\0B_d3smBjzo04UUNBME5GOVhoMjA\_ODYSSEY\Email Members.xlsx'
df_email_member_odd = pd.read_excel(path, dtype='string', sheet_name='Sheet1')

path = r'G:\.shortcut-targets-by-id\0B_d3smBjzo04UUNBME5GOVhoMjA\_ODYSSEY\KCE Members.xlsx'
df_phone_member_kce = pd.read_excel(path, dtype='string', sheet_name='Phone')

path = r'G:\.shortcut-targets-by-id\0B_d3smBjzo04UUNBME5GOVhoMjA\_ODYSSEY\KCE Members.xlsx'
df_email_member_kce = pd.read_excel(path, dtype='string', sheet_name='Email')

# %%
m.clean_number(df_kce, 'Phone')
m.replace_not_valid_to_empty(df_kce, 'Phone')
df_kce['Email'] = m.lowercase(df_kce, 'Email')
m.clean_space(df_kce, 'Email')

m.clean_number(df_phone_member_odd, 'Mobile')
df_email_member_odd['Email'] = m.lowercase(df_email_member_odd, 'Email')
m.clean_space(df_email_member_odd, 'Email')

m.clean_number(df_phone_member_kce, 'Phone')
df_email_member_kce['Email'] = m.lowercase(df_email_member_kce, 'Email')
m.clean_space(df_email_member_kce, 'Email')
# Out:
# 0          aameercok@gmail.com.com
# 1              imerwan@hotmail.com
# 2              mkptech15@gmail.com
# 3        sovitmittal2000@yahoo.com
# 4          smritidas1431@gmail.com
#                    ...
# 83497     richardjstokes@gmail.com
# 83498        sidharth_ga@yahoo.com
# 83499      traceypaige03@gmail.com
# 83500             ssvemp@yahoo.com
# 83501      tomikastevens@gmail.com
# Name: Email, Length: 83502, dtype: string

# %%
pm.email_correction(df_kce, 'Email')
df_kce
# Out:
#       number FirstName      lastname    Country  \
# 0    1197195    Ronald         North  Australia
# 1    1196922     Aaron       Koplick  Australia
# 2    1197199    Joshua        Sugden  Australia
# 3    1196215   Kenneth       Forrest  Australia
# 4    1196377       Ali         Nawaz  Australia
# ..       ...       ...           ...        ...
# 690  1196145    Khader         Yafai      empty
# 691  1196430      Ryan        Farran      empty
# 692  1196381    Semere  Ghebremariam      empty
# 693  1196714     Chris       Jackson      empty
# 694  1196142    Subash            Kc      empty
#
#                              Email        Phone Account Status  \
# 0                2ronshi@gmail.com  61424245453         ACTIVE
# 1         aaronkoplick@hotmail.com  61409040484         ACTIVE
# 2    admin@suggosconstructions.com  61414926326         ACTIVE
# 3            adriannef12@gmail.com  61418721041         ACTIVE
# 4             ali.nawaz@live.co.uk  61450054092         ACTIVE
# ..                             ...          ...            ...
# 690           kyafai1128@yahoo.com  14142176682         ACTIVE
# 691            ryan_farran@ntm.org  15732838483         ACTIVE
# 692          samotiteame@gmail.com  19258959204         ACTIVE
# 693          scurrie63@hotmail.com  85294985444         ACTIVE
# 694          suubashkc61@gmail.com  14697328971         ACTIVE
#
#        Servicing Office     Karma Club Program
# 0    KC EXPERIENCE Bali    Jimbaran Sales Deck
# 1    KC EXPERIENCE Bali  Petitenget Sales Deck
# 2    KC EXPERIENCE Bali    Jimbaran Sales Deck
# 3    KC EXPERIENCE Bali  Petitenget Sales Deck
# 4    KC EXPERIENCE Bali    Jimbaran Sales Deck
# ..                  ...                    ...
# 690  KC EXPERIENCE Bali    Jimbaran Sales Deck
# 691  KC EXPERIENCE Bali    Jimbaran Sales Deck
# 692  KC EXPERIENCE Bali    Jimbaran Sales Deck
# 693  KC EXPERIENCE Bali     Vietnam Sales Deck
# 694  KC EXPERIENCE Bali    Jimbaran Sales Deck
#
# [695 rows x 9 columns]

# %%
count_email_phone_empty = df_kce.loc[(df_kce['Email'] == 'empty') & (df_kce['Phone'] == 'empty')].shape[0]

df_kce.loc[(df_kce['Email'] == 'empty') & (df_kce['Phone'] == 'empty')].to_csv(r'C:\Users\fajar\Documents\Python\Data\cek_email_phone_empty_kce.csv', index=False)

df_kce.drop(df_kce.loc[(df_kce['Email'] == 'empty') & (df_kce['Phone'] == 'empty')].index, inplace=True)
df_kce.reset_index(drop=True, inplace=True)

count_after_email_phone_empty = df_kce.shape[0]

# %%
# Cek leads test
test_leads = df_kce.loc[
    
        df_kce['Email'].str.contains('^test@', flags=re.I, regex=True) |
        df_kce['Email'].str.contains('\+test', flags=re.I, regex=True) |
    
        df_kce['FirstName'].str.contains('^test$', flags=re.I, regex=True) |
        df_kce['lastname'].str.contains('^test$', flags=re.I, regex=True) |

        df_kce['FirstName'].str.contains('test 1', flags=re.I, regex=True) |
        df_kce['lastname'].str.contains('test 2', flags=re.I, regex=True)|
        df_kce['FirstName'].str.contains('test1', flags=re.I, regex=True) |
        df_kce['lastname'].str.contains('test2', flags=re.I, regex=True)|

        df_kce['FirstName'].str.contains(' test ', flags=re.I, regex=True) | 
        df_kce['lastname'].str.contains(' test ', flags=re.I, regex=True) | 
        df_kce['lastname'].str.contains(' test$', flags=re.I, regex=True)
    
    
    ]

count_leads_test = test_leads.shape[0]

test_leads.to_excel(r'C:\Users\fajar\Documents\Python\Data\test_leads.xlsx', index=False)
test_leads
# Out:
# Empty DataFrame
# Columns: [number, FirstName, lastname, Country, Email, Phone, Account Status, Servicing Office, Karma Club Program]
# Index: []

# %%
df_kce.drop(test_leads.index, inplace=True)
df_kce.reset_index(drop=True, inplace=True)

count_after_dedup_test = df_kce.shape[0]

# %%
# Cek Email Karma
email_karma = m.find_karma(df_kce, 'Email')
count_email_karma = email_karma.shape[0]
# email_OTA.to_excel(r'C:\Users\fajar\Documents\Python\Data\email_OTA.xlsx', index=False)

email_karma
# Out:
# Empty DataFrame
# Columns: [number, FirstName, lastname, Country, Email, Phone, Account Status, Servicing Office, Karma Club Program]
# Index: []

# %%
# delete email Karma
count_after_clean_karma = m.delete_karma(df_kce, 'Email')
# zoho_df.to_excel(r'C:\Users\fajar\Documents\Python\Data\after_clean_OTA.xlsx', index=False)

df_kce
# Out:
#       number FirstName      lastname    Country  \
# 0    1197195    Ronald         North  Australia
# 1    1196922     Aaron       Koplick  Australia
# 2    1197199    Joshua        Sugden  Australia
# 3    1196215   Kenneth       Forrest  Australia
# 4    1196377       Ali         Nawaz  Australia
# ..       ...       ...           ...        ...
# 688  1196145    Khader         Yafai      empty
# 689  1196430      Ryan        Farran      empty
# 690  1196381    Semere  Ghebremariam      empty
# 691  1196714     Chris       Jackson      empty
# 692  1196142    Subash            Kc      empty
#
#                              Email        Phone Account Status  \
# 0                2ronshi@gmail.com  61424245453         ACTIVE
# 1         aaronkoplick@hotmail.com  61409040484         ACTIVE
# 2    admin@suggosconstructions.com  61414926326         ACTIVE
# 3            adriannef12@gmail.com  61418721041         ACTIVE
# 4             ali.nawaz@live.co.uk  61450054092         ACTIVE
# ..                             ...          ...            ...
# 688           kyafai1128@yahoo.com  14142176682         ACTIVE
# 689            ryan_farran@ntm.org  15732838483         ACTIVE
# 690          samotiteame@gmail.com  19258959204         ACTIVE
# 691          scurrie63@hotmail.com  85294985444         ACTIVE
# 692          suubashkc61@gmail.com  14697328971         ACTIVE
#
#        Servicing Office     Karma Club Program
# 0    KC EXPERIENCE Bali    Jimbaran Sales Deck
# 1    KC EXPERIENCE Bali  Petitenget Sales Deck
# 2    KC EXPERIENCE Bali    Jimbaran Sales Deck
# 3    KC EXPERIENCE Bali  Petitenget Sales Deck
# 4    KC EXPERIENCE Bali    Jimbaran Sales Deck
# ..                  ...                    ...
# 688  KC EXPERIENCE Bali    Jimbaran Sales Deck
# 689  KC EXPERIENCE Bali    Jimbaran Sales Deck
# 690  KC EXPERIENCE Bali    Jimbaran Sales Deck
# 691  KC EXPERIENCE Bali     Vietnam Sales Deck
# 692  KC EXPERIENCE Bali    Jimbaran Sales Deck
#
# [693 rows x 9 columns]

# %%
find_member_oddysey = df_kce.copy()

find_member_oddysey.loc[find_member_oddysey['Phone'].isin(df_phone_member_odd['Mobile']), 'Same Value Find'] = 'Member-Mobile' 

find_member_oddysey.loc[find_member_oddysey['Email'].isin(df_email_member_odd['Email']), 'Same Value Find'] = 'Member-Email'
find_member_oddysey.drop(find_member_oddysey.loc[find_member_oddysey['Same Value Find'].isna()].index, inplace=True)

find_member_oddysey.replace('empty', '', inplace=True)

find_member_oddysey.to_csv(r'C:\Users\fajar\Documents\Python\Data\cek_member_odyssey.csv', index=False)

# %%
count_dedup_member_odd = df_kce.loc[
    
    df_kce['Phone'].isin(df_phone_member_odd['Mobile']) | 
    df_kce['Email'].isin(df_email_member_odd['Email'])
].shape[0]

df_kce.loc[
    
    df_kce['Phone'].isin(df_phone_member_odd['Mobile']) | 
    df_kce['Email'].isin(df_email_member_odd['Email'])
]
# Out:
#       number                        FirstName                    lastname  \
# 246  1197219                         Avnish N                     Jhaveri
# 362  1196339  Mr. Bhavesh Dilipkumar Gandhi &  Mrs. Patel Megha Jigarbhai
# 394  1196689                         MOHAMMED                      JIBRAN
# 541  1196472                           SUSHIL                       GUPTA
#
#     Country                     Email         Phone Account Status  \
# 246   India  avnishnjhaveri@gmail.com  919320301720         ACTIVE
# 362   India   kinjalbgandhi@gmail.com  919833166212         ACTIVE
# 394   India    mohammedjibz@gmail.com  919686557002         ACTIVE
# 541   India      sushil0281@gmail.com  919819701516         ACTIVE
#
#         Servicing Office Karma Club Program
# 246  KC EXPERIENCE India          South Goa
# 362  KC EXPERIENCE India              empty
# 394  KC EXPERIENCE India              empty
# 541  KC EXPERIENCE India              empty

# %%
df_kce.drop(df_kce.loc[
    
    df_kce['Phone'].isin(df_phone_member_odd['Mobile']) | 
    df_kce['Email'].isin(df_email_member_odd['Email'])
].index, inplace=True)

df_kce.reset_index(drop=True, inplace=True)

count_after_dedup_member_odd = df_kce.shape[0]
df_kce
# Out:
#       number FirstName      lastname    Country  \
# 0    1197195    Ronald         North  Australia
# 1    1196922     Aaron       Koplick  Australia
# 2    1197199    Joshua        Sugden  Australia
# 3    1196215   Kenneth       Forrest  Australia
# 4    1196377       Ali         Nawaz  Australia
# ..       ...       ...           ...        ...
# 684  1196145    Khader         Yafai      empty
# 685  1196430      Ryan        Farran      empty
# 686  1196381    Semere  Ghebremariam      empty
# 687  1196714     Chris       Jackson      empty
# 688  1196142    Subash            Kc      empty
#
#                              Email        Phone Account Status  \
# 0                2ronshi@gmail.com  61424245453         ACTIVE
# 1         aaronkoplick@hotmail.com  61409040484         ACTIVE
# 2    admin@suggosconstructions.com  61414926326         ACTIVE
# 3            adriannef12@gmail.com  61418721041         ACTIVE
# 4             ali.nawaz@live.co.uk  61450054092         ACTIVE
# ..                             ...          ...            ...
# 684           kyafai1128@yahoo.com  14142176682         ACTIVE
# 685            ryan_farran@ntm.org  15732838483         ACTIVE
# 686          samotiteame@gmail.com  19258959204         ACTIVE
# 687          scurrie63@hotmail.com  85294985444         ACTIVE
# 688          suubashkc61@gmail.com  14697328971         ACTIVE
#
#        Servicing Office     Karma Club Program
# 0    KC EXPERIENCE Bali    Jimbaran Sales Deck
# 1    KC EXPERIENCE Bali  Petitenget Sales Deck
# 2    KC EXPERIENCE Bali    Jimbaran Sales Deck
# 3    KC EXPERIENCE Bali  Petitenget Sales Deck
# 4    KC EXPERIENCE Bali    Jimbaran Sales Deck
# ..                  ...                    ...
# 684  KC EXPERIENCE Bali    Jimbaran Sales Deck
# 685  KC EXPERIENCE Bali    Jimbaran Sales Deck
# 686  KC EXPERIENCE Bali    Jimbaran Sales Deck
# 687  KC EXPERIENCE Bali     Vietnam Sales Deck
# 688  KC EXPERIENCE Bali    Jimbaran Sales Deck
#
# [689 rows x 9 columns]

# %%
find_member_kce = df_kce.copy()

find_member_kce.loc[find_member_kce['Phone'].isin(df_phone_member_kce['Phone']), 'Same Value Find'] = 'Member-KCE-Mobile' 

find_member_kce.loc[find_member_kce['Email'].isin(df_email_member_kce['Email']), 'Same Value Find'] = 'Member-KCE-Email'
find_member_kce.drop(find_member_kce.loc[find_member_kce['Same Value Find'].isna()].index, inplace=True)

find_member_kce.replace('empty', '', inplace=True)

find_member_kce.to_csv(r'C:\Users\fajar\Documents\Python\Data\cek_member_kce.csv', index=False)

# %%
count_dedup_member_kce = df_kce.loc[
    
    df_kce['Phone'].isin(df_phone_member_kce['Phone']) | 
    df_kce['Email'].isin(df_email_member_kce['Email'])

].shape[0]

df_kce.loc[
    
    df_kce['Phone'].isin(df_phone_member_kce['Phone']) | 
    df_kce['Email'].isin(df_email_member_kce['Email'])
]
# Out:
#       number     FirstName lastname Country                        Email  \
# 218  1189742         AMRIT  TALREJA   India  amrittalreja.1987@gmail.com
# 274  1151856        CHETAN  MOKASHI   India        chetanmok18@gmail.com
# 298  1084088      AKHILEAH  DWIVEDI   India     dwivedijigyasa@gmail.com
# 348  1196035  VENKATARAMAN        .   India         kalai.art1@gmail.com
# 516  1196514        GAURAV   CHOPRA   India     sonamkhatri.sk@gmail.com
# 523  1196468     SUDERSHAN    CHUGH   India    sudershan_chugh@yahoo.com
#
#             Phone Account Status     Servicing Office Karma Club Program
# 218  917666911911         ACTIVE  KC EXPERIENCE India              empty
# 274  919960347462         ACTIVE  KC EXPERIENCE India              empty
# 298  919811984809        EXPIRED  KC EXPERIENCE India              empty
# 348  918553222285         ACTIVE  KC EXPERIENCE India              empty
# 516  917503773106         ACTIVE  KC EXPERIENCE India              empty
# 523  919873394191         ACTIVE  KC EXPERIENCE India              empty

# %%
df_kce.drop(df_kce.loc[
    
    df_kce['Phone'].isin(df_phone_member_kce['Phone']) | 
    df_kce['Email'].isin(df_email_member_kce['Email'])
].index, inplace=True)

df_kce.reset_index(drop=True, inplace=True)

count_after_dedup_member_kce = df_kce.shape[0]
df_kce
# Out:
#       number FirstName      lastname    Country  \
# 0    1197195    Ronald         North  Australia
# 1    1196922     Aaron       Koplick  Australia
# 2    1197199    Joshua        Sugden  Australia
# 3    1196215   Kenneth       Forrest  Australia
# 4    1196377       Ali         Nawaz  Australia
# ..       ...       ...           ...        ...
# 678  1196145    Khader         Yafai      empty
# 679  1196430      Ryan        Farran      empty
# 680  1196381    Semere  Ghebremariam      empty
# 681  1196714     Chris       Jackson      empty
# 682  1196142    Subash            Kc      empty
#
#                              Email        Phone Account Status  \
# 0                2ronshi@gmail.com  61424245453         ACTIVE
# 1         aaronkoplick@hotmail.com  61409040484         ACTIVE
# 2    admin@suggosconstructions.com  61414926326         ACTIVE
# 3            adriannef12@gmail.com  61418721041         ACTIVE
# 4             ali.nawaz@live.co.uk  61450054092         ACTIVE
# ..                             ...          ...            ...
# 678           kyafai1128@yahoo.com  14142176682         ACTIVE
# 679            ryan_farran@ntm.org  15732838483         ACTIVE
# 680          samotiteame@gmail.com  19258959204         ACTIVE
# 681          scurrie63@hotmail.com  85294985444         ACTIVE
# 682          suubashkc61@gmail.com  14697328971         ACTIVE
#
#        Servicing Office     Karma Club Program
# 0    KC EXPERIENCE Bali    Jimbaran Sales Deck
# 1    KC EXPERIENCE Bali  Petitenget Sales Deck
# 2    KC EXPERIENCE Bali    Jimbaran Sales Deck
# 3    KC EXPERIENCE Bali  Petitenget Sales Deck
# 4    KC EXPERIENCE Bali    Jimbaran Sales Deck
# ..                  ...                    ...
# 678  KC EXPERIENCE Bali    Jimbaran Sales Deck
# 679  KC EXPERIENCE Bali    Jimbaran Sales Deck
# 680  KC EXPERIENCE Bali    Jimbaran Sales Deck
# 681  KC EXPERIENCE Bali     Vietnam Sales Deck
# 682  KC EXPERIENCE Bali    Jimbaran Sales Deck
#
# [683 rows x 9 columns]

# %%
# hitung jumlah duplicate
count_duplicate_general = df_kce.loc[df_kce.duplicated(subset=['Email','Phone'])].shape[0]

df_kce.loc[df_kce.duplicated(subset=['Email','Phone'])]
# Out:
#       number        FirstName    lastname Country  \
# 408  1196840   Nikhil Manohar  Manchalwar   India
#
#                            Email         Phone Account Status  \
# 408  nikhil.manchalwar@gmail.com  919850344844         ACTIVE
#
#         Servicing Office Karma Club Program
# 408  KC EXPERIENCE India              empty

# %%
df_kce.drop_duplicates(subset=['Email','Phone'], inplace=True)
df_kce.reset_index(drop=True, inplace=True)

# hitung jumlah setelah value duplicate dihapus
count_after_dedup_duplicate = df_kce.shape[0]

df_kce
# Out:
#       number FirstName      lastname    Country  \
# 0    1197195    Ronald         North  Australia
# 1    1196922     Aaron       Koplick  Australia
# 2    1197199    Joshua        Sugden  Australia
# 3    1196215   Kenneth       Forrest  Australia
# 4    1196377       Ali         Nawaz  Australia
# ..       ...       ...           ...        ...
# 677  1196145    Khader         Yafai      empty
# 678  1196430      Ryan        Farran      empty
# 679  1196381    Semere  Ghebremariam      empty
# 680  1196714     Chris       Jackson      empty
# 681  1196142    Subash            Kc      empty
#
#                              Email        Phone Account Status  \
# 0                2ronshi@gmail.com  61424245453         ACTIVE
# 1         aaronkoplick@hotmail.com  61409040484         ACTIVE
# 2    admin@suggosconstructions.com  61414926326         ACTIVE
# 3            adriannef12@gmail.com  61418721041         ACTIVE
# 4             ali.nawaz@live.co.uk  61450054092         ACTIVE
# ..                             ...          ...            ...
# 677           kyafai1128@yahoo.com  14142176682         ACTIVE
# 678            ryan_farran@ntm.org  15732838483         ACTIVE
# 679          samotiteame@gmail.com  19258959204         ACTIVE
# 680          scurrie63@hotmail.com  85294985444         ACTIVE
# 681          suubashkc61@gmail.com  14697328971         ACTIVE
#
#        Servicing Office     Karma Club Program
# 0    KC EXPERIENCE Bali    Jimbaran Sales Deck
# 1    KC EXPERIENCE Bali  Petitenget Sales Deck
# 2    KC EXPERIENCE Bali    Jimbaran Sales Deck
# 3    KC EXPERIENCE Bali  Petitenget Sales Deck
# 4    KC EXPERIENCE Bali    Jimbaran Sales Deck
# ..                  ...                    ...
# 677  KC EXPERIENCE Bali    Jimbaran Sales Deck
# 678  KC EXPERIENCE Bali    Jimbaran Sales Deck
# 679  KC EXPERIENCE Bali    Jimbaran Sales Deck
# 680  KC EXPERIENCE Bali     Vietnam Sales Deck
# 681  KC EXPERIENCE Bali    Jimbaran Sales Deck
#
# [682 rows x 9 columns]

# %%
list_UK_EU = pm.get_list_UK_EU()
list_Others = pm.get_list_Others()

# %%
df_kce.loc[df_kce['Country'].isin(list_Others)]
# Out:
#       number     FirstName  lastname               Country  \
# 0    1197195        Ronald     North             Australia
# 1    1196922         Aaron   Koplick             Australia
# 2    1197199        Joshua    Sugden             Australia
# 3    1196215       Kenneth   Forrest             Australia
# 4    1196377           Ali     Nawaz             Australia
# ..       ...           ...       ...                   ...
# 645  1196541       Elliott   Imzayin  United Arab Emirates
# 646  1196168       Clinton  Coutinho  United Arab Emirates
# 647  1196133      Mikhayel     Jacob  United Arab Emirates
# 648  1196154  Harsh Rajesh     Joshi  United Arab Emirates
# 675  1196127         Ciano    Joasil                   USA
#
#                              Email         Phone Account Status  \
# 0                2ronshi@gmail.com   61424245453         ACTIVE
# 1         aaronkoplick@hotmail.com   61409040484         ACTIVE
# 2    admin@suggosconstructions.com   61414926326         ACTIVE
# 3            adriannef12@gmail.com   61418721041         ACTIVE
# 4             ali.nawaz@live.co.uk   61450054092         ACTIVE
# ..                             ...           ...            ...
# 645       elliottimzayin@gmail.com  971543778887         ACTIVE
# 646             jmaben29@gmail.com  971525323961         ACTIVE
# 647         mikhayel.j@hotmail.com  971507328797         ACTIVE
# 648           siddhirj@hotmail.com  971559683301         ACTIVE
# 675         ciano.joasil@gmail.com   19178047073         ACTIVE
#
#        Servicing Office     Karma Club Program
# 0    KC EXPERIENCE Bali    Jimbaran Sales Deck
# 1    KC EXPERIENCE Bali  Petitenget Sales Deck
# 2    KC EXPERIENCE Bali    Jimbaran Sales Deck
# 3    KC EXPERIENCE Bali  Petitenget Sales Deck
# 4    KC EXPERIENCE Bali    Jimbaran Sales Deck
# ..                  ...                    ...
# 645  KC EXPERIENCE Bali    Jimbaran Sales Deck
# 646  KC EXPERIENCE Bali     Vietnam Sales Deck
# 647  KC EXPERIENCE Bali    Jimbaran Sales Deck
# 648  KC EXPERIENCE Bali  Petitenget Sales Deck
# 675  KC EXPERIENCE Bali  Petitenget Sales Deck
#
# [204 rows x 9 columns]

# %%
df_kce.loc[df_kce['Country'].str.contains('India'), 'Area'] = 'India'
df_kce.loc[df_kce['Country'].isin(list_UK_EU), 'Area'] = 'UK EU'
df_kce.loc[df_kce['Country'].isin(list_Others), 'Area'] = 'Others'

# %%
df_kce.loc[df_kce['Area'] == 'India', 'Batch'] = 'INDIA'
df_kce.loc[df_kce['Area'] == 'UK EU', 'Batch'] = 'NONINDIA'
df_kce.loc[df_kce['Area'] == 'Others', 'Batch'] = 'NONINDIA'

# %%
df_kce.replace('empty', '', inplace=True)

# %%
df_kce.columns
# Out:
# Index(['number', 'FirstName', 'lastname', 'Country', 'Email', 'Phone',
#        'Account Status', 'Servicing Office', 'Karma Club Program', 'Area',
#        'Batch'],
#       dtype='object')

# %%
new_cols = ['number', 'FirstName', 'lastname', 'Country', 'Area', 'Batch', 'Email', 'Phone',
       'Account Status', 'Servicing Office', 'Karma Club Program']

df_kce = df_kce.reindex(columns=new_cols)

# %%
count_data_akhir = df_kce.shape[0]

df_kce.to_csv(r'C:\Users\fajar\Documents\Python\Data\final_kce.csv', index=False)

# %%
print("==========================================================")
print("Summary")
print("==========================================================")
print("Jumlah Data Awal KCE CC-CL : "+str(count_data_awal))
print("Jumlah Data Email dan Phone Kosong : "+str(count_email_phone_empty))
print("Jumlah Data Setelah Hapus Email dan Phone Yang Kosong : "+str(count_after_email_phone_empty))
print("Jumlah Lead Test : "+str(count_leads_test))
print("Jumlah Setelah Clean Lead Test : "+str(count_after_dedup_test))
print("Jumlah Email Karma : "+str(count_email_karma))
print("Jumlah Setelah Clean Email Karma : "+str(count_after_clean_karma))
print("Jumlah Data Yang Terkena Dedup Member Oddysey : "+str(count_dedup_member_odd))
print("Jumlah Data Setelah Dedup Member Oddysey : "+str(count_after_dedup_member_odd))
print("Jumlah Data Yang Terkena Dedup Past Guest KCE : "+str(count_dedup_member_kce))
print("Jumlah Data Setelah Dedup Past Guest KCE : "+str(count_after_dedup_member_kce))
print("Jumlah Data Yang Duplicate : "+str(count_duplicate_general))
print("Jumlah Data Setelah Hapus Duplicate : "+str(count_after_dedup_duplicate))
print("Jumlah Data Akhir : "+str(count_data_akhir))
# Out:
# ==========================================================
# Summary
# ==========================================================
# Jumlah Data Awal KCE CC-CL : 695
# Jumlah Data Email dan Phone Kosong : 2
# Jumlah Data Setelah Hapus Email dan Phone Yang Kosong : 693
# Jumlah Lead Test : 0
# Jumlah Setelah Clean Lead Test : 693
# Jumlah Email Karma : 0
# Jumlah Setelah Clean Email Karma : 693
# Jumlah Data Yang Terkena Dedup Member Oddysey : 4
# Jumlah Data Setelah Dedup Member Oddysey : 689
# Jumlah Data Yang Terkena Dedup Past Guest KCE : 6
# Jumlah Data Setelah Dedup Past Guest KCE : 683
# Jumlah Data Yang Duplicate : 1
# Jumlah Data Setelah Hapus Duplicate : 682
# Jumlah Data Akhir : 682
