# %%
import pandas as pd
import re

import past_guest_module as pm

import sys
sys.path.append('../zoho_data_app/')

import main_module as m

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
cols = ['Account ID', 'FirstName', 'lastname', 'Country', 'Email', 'Phone',
       'AcStatus', 'Servicing Office','KarmaClubProgram']

# %%
path = r'C:\Users\fajar\Documents\Python\Data\KCC cc-cl\2024\Aug\28 July - 5 Aug\KCE CC CL 28 July - 5 Aug.xlsx'
df_kce = pd.read_excel(path, dtype='string', sheet_name='Sheet1', usecols=cols)
count_data_awal = df_kce.shape[0]
df_kce
# Out:
#     Account ID                 FirstName   lastname      Country  \
# 0      1195036                     Kapil     Thakur        India
# 1      1195313                    Ashish     Pandey        India
# 2      1196236  Shirin Kumar Jagdishbhai      Patel        India
# 3      1195370                     Arjun  Datterjee        India
# 4      1196249                    Aadish   Sardesai        India
# ..         ...                       ...        ...          ...
# 751    1195360                      TONY     RIDDLE  New Zealand
# 752    1195525                    Aevant       Jain        India
# 753    1195564                     Pawan      Kumar        India
# 754    1195566                    Swapan      Basak        India
# 755    1196244                    Mukesh    Chauhan        India
#
#                         Email         Phone AcStatus     Servicing Office  \
# 0          26kapil1@gmail.com  919221848156   ACTIVE  KC EXPERIENCE India
# 1     2ashishpandey@gmail.com  919739241381   ACTIVE  KC EXPERIENCE India
# 2          90shirin@gmail.com  919426644918   ACTIVE  KC EXPERIENCE India
# 3       a.c.aryan46@gmail.com  918147719805   ACTIVE  KC EXPERIENCE India
# 4    aadishsardesai@gmail.com  918411078156   ACTIVE  KC EXPERIENCE India
# ..                        ...           ...      ...                  ...
# 751                      <NA>          <NA>   ACTIVE   KC EXPERIENCE Bali
# 752                      <NA>  919893798055   ACTIVE  KC EXPERIENCE India
# 753                      <NA>  918684878727   ACTIVE  KC EXPERIENCE India
# 754                      <NA>  919733115861   ACTIVE  KC EXPERIENCE India
# 755                      <NA>  919833991131   ACTIVE  KC EXPERIENCE India
#
#        KarmaClubProgram
# 0             North Goa
# 1             South Goa
# 2             North Goa
# 3             South Goa
# 4             South Goa
# ..                  ...
# 751  Vietnam Sales Deck
# 752           North Goa
# 753           North Goa
# 754           North Goa
# 755           South Goa
#
# [756 rows x 9 columns]

# %%
df_kce.columns
# Out:
# Index(['Account ID', 'FirstName', 'lastname', 'Country', 'Email', 'Phone',
#        'AcStatus', 'Servicing Office', 'KarmaClubProgram'],
#       dtype='object')

# %%
df_kce.rename(columns = {
    'Account ID':'number', 
    'AcStatus':'Account Status',
    'KarmaClubProgram':'Karma Club Program',
    }, inplace = True)

# %%
df_kce.fillna('empty', inplace=True)

# %%
path = r'G:\.shortcut-targets-by-id\0B_d3smBjzo04UUNBME5GOVhoMjA\_ODYSSEY\Phone Members.xlsx'
df_phone_member_odd = pd.read_excel(path, dtype='string', sheet_name='Sheet1')

path = r'G:\.shortcut-targets-by-id\0B_d3smBjzo04UUNBME5GOVhoMjA\_ODYSSEY\Email Members.xlsx'
df_email_member_odd = pd.read_excel(path, dtype='string', sheet_name='Sheet1')

path = r'G:\.shortcut-targets-by-id\0B_d3smBjzo04UUNBME5GOVhoMjA\_ODYSSEY\KCE Members.xlsx'
df_phone_member_kce = pd.read_excel(path, dtype='string', sheet_name='Phone')

path = r'G:\.shortcut-targets-by-id\0B_d3smBjzo04UUNBME5GOVhoMjA\_ODYSSEY\KCE Members.xlsx'
df_email_member_kce = pd.read_excel(path, dtype='string', sheet_name='Email')

# %%
m.clean_number(df_kce, 'Phone')
m.replace_not_valid_to_empty(df_kce, 'Phone')
df_kce['Email'] = m.lowercase(df_kce, 'Email')
m.clean_space(df_kce, 'Email')

m.clean_number(df_phone_member_odd, 'Mobile')
df_email_member_odd['Email'] = m.lowercase(df_email_member_odd, 'Email')
m.clean_space(df_email_member_odd, 'Email')

m.clean_number(df_phone_member_kce, 'Phone')
df_email_member_kce['Email'] = m.lowercase(df_email_member_kce, 'Email')
m.clean_space(df_email_member_kce, 'Email')
# Out:
# 0          aameercok@gmail.com.com
# 1              imerwan@hotmail.com
# 2              mkptech15@gmail.com
# 3        sovitmittal2000@yahoo.com
# 4          smritidas1431@gmail.com
#                    ...
# 83497     richardjstokes@gmail.com
# 83498        sidharth_ga@yahoo.com
# 83499      traceypaige03@gmail.com
# 83500             ssvemp@yahoo.com
# 83501      tomikastevens@gmail.com
# Name: Email, Length: 83502, dtype: string

# %%
pm.email_correction(df_kce, 'Email')
df_kce
# Out:
#       number                 FirstName   lastname      Country  \
# 0    1195036                     Kapil     Thakur        India
# 1    1195313                    Ashish     Pandey        India
# 2    1196236  Shirin Kumar Jagdishbhai      Patel        India
# 3    1195370                     Arjun  Datterjee        India
# 4    1196249                    Aadish   Sardesai        India
# ..       ...                       ...        ...          ...
# 751  1195360                      TONY     RIDDLE  New Zealand
# 752  1195525                    Aevant       Jain        India
# 753  1195564                     Pawan      Kumar        India
# 754  1195566                    Swapan      Basak        India
# 755  1196244                    Mukesh    Chauhan        India
#
#                         Email         Phone Account Status  \
# 0          26kapil1@gmail.com  919221848156         ACTIVE
# 1     2ashishpandey@gmail.com  919739241381         ACTIVE
# 2          90shirin@gmail.com  919426644918         ACTIVE
# 3       a.c.aryan46@gmail.com  918147719805         ACTIVE
# 4    aadishsardesai@gmail.com  918411078156         ACTIVE
# ..                        ...           ...            ...
# 751                     empty         empty         ACTIVE
# 752                     empty  919893798055         ACTIVE
# 753                     empty  918684878727         ACTIVE
# 754                     empty  919733115861         ACTIVE
# 755                     empty  919833991131         ACTIVE
#
#         Servicing Office  Karma Club Program
# 0    KC EXPERIENCE India           North Goa
# 1    KC EXPERIENCE India           South Goa
# 2    KC EXPERIENCE India           North Goa
# 3    KC EXPERIENCE India           South Goa
# 4    KC EXPERIENCE India           South Goa
# ..                   ...                 ...
# 751   KC EXPERIENCE Bali  Vietnam Sales Deck
# 752  KC EXPERIENCE India           North Goa
# 753  KC EXPERIENCE India           North Goa
# 754  KC EXPERIENCE India           North Goa
# 755  KC EXPERIENCE India           South Goa
#
# [756 rows x 9 columns]

# %%
count_email_phone_empty = df_kce.loc[(df_kce['Email'] == 'empty') & (df_kce['Phone'] == 'empty')].shape[0]

df_kce.loc[(df_kce['Email'] == 'empty') & (df_kce['Phone'] == 'empty')].to_csv(r'C:\Users\fajar\Documents\Python\Data\cek_email_phone_empty_kce.csv', index=False)

df_kce.drop(df_kce.loc[(df_kce['Email'] == 'empty') & (df_kce['Phone'] == 'empty')].index, inplace=True)
df_kce.reset_index(drop=True, inplace=True)

count_after_email_phone_empty = df_kce.shape[0]

# %%
# Cek leads test
test_leads = df_kce.loc[
    
        df_kce['Email'].str.contains('^test@', flags=re.I, regex=True) |
        df_kce['Email'].str.contains('\+test', flags=re.I, regex=True) |
    
        df_kce['FirstName'].str.contains('^test$', flags=re.I, regex=True) |
        df_kce['lastname'].str.contains('^test$', flags=re.I, regex=True) |

        df_kce['FirstName'].str.contains('test 1', flags=re.I, regex=True) |
        df_kce['lastname'].str.contains('test 2', flags=re.I, regex=True)|
        df_kce['FirstName'].str.contains('test1', flags=re.I, regex=True) |
        df_kce['lastname'].str.contains('test2', flags=re.I, regex=True)|

        df_kce['FirstName'].str.contains(' test ', flags=re.I, regex=True) | 
        df_kce['lastname'].str.contains(' test ', flags=re.I, regex=True) | 
        df_kce['lastname'].str.contains(' test$', flags=re.I, regex=True)
    
    
    ]

count_leads_test = test_leads.shape[0]

test_leads.to_excel(r'C:\Users\fajar\Documents\Python\Data\test_leads.xlsx', index=False)
test_leads
# Out:
# Empty DataFrame
# Columns: [number, FirstName, lastname, Country, Email, Phone, Account Status, Servicing Office, Karma Club Program]
# Index: []

# %%
df_kce.drop(test_leads.index, inplace=True)
df_kce.reset_index(drop=True, inplace=True)

count_after_dedup_test = df_kce.shape[0]

# %%
# Cek Email Karma
email_karma = m.find_karma(df_kce, 'Email')
count_email_karma = email_karma.shape[0]
# email_OTA.to_excel(r'C:\Users\fajar\Documents\Python\Data\email_OTA.xlsx', index=False)

email_karma
# Out:
# Empty DataFrame
# Columns: [number, FirstName, lastname, Country, Email, Phone, Account Status, Servicing Office, Karma Club Program]
# Index: []

# %%
# delete email Karma
count_after_clean_karma = m.delete_karma(df_kce, 'Email')
# zoho_df.to_excel(r'C:\Users\fajar\Documents\Python\Data\after_clean_OTA.xlsx', index=False)

df_kce
# Out:
#       number                 FirstName   lastname Country  \
# 0    1195036                     Kapil     Thakur   India
# 1    1195313                    Ashish     Pandey   India
# 2    1196236  Shirin Kumar Jagdishbhai      Patel   India
# 3    1195370                     Arjun  Datterjee   India
# 4    1196249                    Aadish   Sardesai   India
# ..       ...                       ...        ...     ...
# 744  1195139                   Valji M     Parmar   India
# 745  1195525                    Aevant       Jain   India
# 746  1195564                     Pawan      Kumar   India
# 747  1195566                    Swapan      Basak   India
# 748  1196244                    Mukesh    Chauhan   India
#
#                         Email         Phone Account Status  \
# 0          26kapil1@gmail.com  919221848156         ACTIVE
# 1     2ashishpandey@gmail.com  919739241381         ACTIVE
# 2          90shirin@gmail.com  919426644918         ACTIVE
# 3       a.c.aryan46@gmail.com  918147719805         ACTIVE
# 4    aadishsardesai@gmail.com  918411078156         ACTIVE
# ..                        ...           ...            ...
# 744                     empty  919869030742         ACTIVE
# 745                     empty  919893798055         ACTIVE
# 746                     empty  918684878727         ACTIVE
# 747                     empty  919733115861         ACTIVE
# 748                     empty  919833991131         ACTIVE
#
#         Servicing Office Karma Club Program
# 0    KC EXPERIENCE India          North Goa
# 1    KC EXPERIENCE India          South Goa
# 2    KC EXPERIENCE India          North Goa
# 3    KC EXPERIENCE India          South Goa
# 4    KC EXPERIENCE India          South Goa
# ..                   ...                ...
# 744  KC EXPERIENCE India          South Goa
# 745  KC EXPERIENCE India          North Goa
# 746  KC EXPERIENCE India          North Goa
# 747  KC EXPERIENCE India          North Goa
# 748  KC EXPERIENCE India          South Goa
#
# [749 rows x 9 columns]

# %%
find_member_oddysey = df_kce.copy()

find_member_oddysey.loc[find_member_oddysey['Phone'].isin(df_phone_member_odd['Mobile']), 'Same Value Find'] = 'Member-Mobile' 

find_member_oddysey.loc[find_member_oddysey['Email'].isin(df_email_member_odd['Email']), 'Same Value Find'] = 'Member-Email'
find_member_oddysey.drop(find_member_oddysey.loc[find_member_oddysey['Same Value Find'].isna()].index, inplace=True)

find_member_oddysey.replace('empty', '', inplace=True)

find_member_oddysey.to_csv(r'C:\Users\fajar\Documents\Python\Data\cek_member_odyssey.csv', index=False)

# %%
count_dedup_member_odd = df_kce.loc[
    
    df_kce['Phone'].isin(df_phone_member_odd['Mobile']) | 
    df_kce['Email'].isin(df_email_member_odd['Email'])
].shape[0]

df_kce.loc[
    
    df_kce['Phone'].isin(df_phone_member_odd['Mobile']) | 
    df_kce['Email'].isin(df_email_member_odd['Email'])
]
# Out:
#       number     FirstName         lastname         Country  \
# 337  1193021         Vibha                .           India
# 353  1189118         SUNNY           KAWALE           India
# 407  1195150  Gangadhara N                .           India
# 437  1195456           Naz              Ali  United Kingdom
# 532  1195936           Rob         Naysmith       Australia
# 688  1195230   DIPAKSOMANI           SOMANI           India
# 715  1195849         VINAY  NANDKUMAR KASBE           India
#
#                             Email         Phone Account Status  \
# 337       kuntal.manish@gmail.com  919654096787        PENDING
# 353        mabelkawale5@gmail.com  919769560920         ACTIVE
# 407       n.gangadhara1@gmail.com  919448755490         ACTIVE
# 437        nova_star4@yahoo.co.uk  447577053770         ACTIVE
# 532       robnaysmith@hotmail.com   61429112008         ACTIVE
# 688  tulsienterprise049@gmail.com  918200601328         ACTIVE
# 715         vinaynk1970@gmail.com  919028797707         ACTIVE
#
#           Servicing Office   Karma Club Program
# 337  KARMA CONCIERGE INDIA                empty
# 353                  empty                empty
# 407    KC EXPERIENCE India            North Goa
# 437    KC EXPERIENCE India                empty
# 532     KC EXPERIENCE Bali  Jimbaran Sales Deck
# 688    KC EXPERIENCE India                empty
# 715    KC EXPERIENCE India                empty

# %%
df_kce.drop(df_kce.loc[
    
    df_kce['Phone'].isin(df_phone_member_odd['Mobile']) | 
    df_kce['Email'].isin(df_email_member_odd['Email'])
].index, inplace=True)

df_kce.reset_index(drop=True, inplace=True)

count_after_dedup_member_odd = df_kce.shape[0]
df_kce
# Out:
#       number                 FirstName   lastname Country  \
# 0    1195036                     Kapil     Thakur   India
# 1    1195313                    Ashish     Pandey   India
# 2    1196236  Shirin Kumar Jagdishbhai      Patel   India
# 3    1195370                     Arjun  Datterjee   India
# 4    1196249                    Aadish   Sardesai   India
# ..       ...                       ...        ...     ...
# 737  1195139                   Valji M     Parmar   India
# 738  1195525                    Aevant       Jain   India
# 739  1195564                     Pawan      Kumar   India
# 740  1195566                    Swapan      Basak   India
# 741  1196244                    Mukesh    Chauhan   India
#
#                         Email         Phone Account Status  \
# 0          26kapil1@gmail.com  919221848156         ACTIVE
# 1     2ashishpandey@gmail.com  919739241381         ACTIVE
# 2          90shirin@gmail.com  919426644918         ACTIVE
# 3       a.c.aryan46@gmail.com  918147719805         ACTIVE
# 4    aadishsardesai@gmail.com  918411078156         ACTIVE
# ..                        ...           ...            ...
# 737                     empty  919869030742         ACTIVE
# 738                     empty  919893798055         ACTIVE
# 739                     empty  918684878727         ACTIVE
# 740                     empty  919733115861         ACTIVE
# 741                     empty  919833991131         ACTIVE
#
#         Servicing Office Karma Club Program
# 0    KC EXPERIENCE India          North Goa
# 1    KC EXPERIENCE India          South Goa
# 2    KC EXPERIENCE India          North Goa
# 3    KC EXPERIENCE India          South Goa
# 4    KC EXPERIENCE India          South Goa
# ..                   ...                ...
# 737  KC EXPERIENCE India          South Goa
# 738  KC EXPERIENCE India          North Goa
# 739  KC EXPERIENCE India          North Goa
# 740  KC EXPERIENCE India          North Goa
# 741  KC EXPERIENCE India          South Goa
#
# [742 rows x 9 columns]

# %%
find_member_kce = df_kce.copy()

find_member_kce.loc[find_member_kce['Phone'].isin(df_phone_member_kce['Phone']), 'Same Value Find'] = 'Member-KCE-Mobile' 

find_member_kce.loc[find_member_kce['Email'].isin(df_email_member_kce['Email']), 'Same Value Find'] = 'Member-KCE-Email'
find_member_kce.drop(find_member_kce.loc[find_member_kce['Same Value Find'].isna()].index, inplace=True)

find_member_kce.replace('empty', '', inplace=True)

find_member_kce.to_csv(r'C:\Users\fajar\Documents\Python\Data\cek_member_kce.csv', index=False)

# %%
count_dedup_member_kce = df_kce.loc[
    
    df_kce['Phone'].isin(df_phone_member_kce['Phone']) | 
    df_kce['Email'].isin(df_email_member_kce['Email'])

].shape[0]

df_kce.loc[
    
    df_kce['Phone'].isin(df_phone_member_kce['Phone']) | 
    df_kce['Email'].isin(df_email_member_kce['Email'])
]
# Out:
#       number        FirstName lastname    Country                       Email  \
# 0    1195036            Kapil   Thakur      India          26kapil1@gmail.com
# 8    1195043         Abhishek  Saharia      India  abhishek-saharia@yahoo.com
# 26   1195107              Ali    Dieni  Australia        alex_dieni@yahoo.com
# 41   1195132           Aniket    Gupta      India   aniketgupta1234@gmail.com
# 43   1194626          SAGAR R   MUTTUR      India   anis.traders100@gmail.com
# ..       ...              ...      ...        ...                         ...
# 723  1195057             Yash     Modi      India      yasmali13137@gmail.com
# 728  1195045           Yogesh        .      India        yogesh0387@gmail.com
# 729  1194997           Yogesh    Sandu      India           ypsandu@yahoo.com
# 730  1195147  Mohd. Zakaullah   Quadri      India   zaka.quadri2012@gmail.com
# 737  1195139          Valji M   Parmar      India                       empty
#
#             Phone Account Status     Servicing Office     Karma Club Program
# 0    919221848156         ACTIVE  KC EXPERIENCE India              North Goa
# 8    919435030818         ACTIVE  KC EXPERIENCE India              South Goa
# 26    61414294703         ACTIVE   KC EXPERIENCE Bali  Petitenget Sales Deck
# 41   919899630250         ACTIVE  KC EXPERIENCE India              South Goa
# 43   919164216909         ACTIVE  KC EXPERIENCE India                  empty
# ..            ...            ...                  ...                    ...
# 723  919893613137         ACTIVE  KC EXPERIENCE India              South Goa
# 728  919154602112         ACTIVE  KC EXPERIENCE India              South Goa
# 729  919022030053         ACTIVE  KC EXPERIENCE India              South Goa
# 730  919398970859         ACTIVE  KC EXPERIENCE India              South Goa
# 737  919869030742         ACTIVE  KC EXPERIENCE India              South Goa
#
# [128 rows x 9 columns]

# %%
df_kce.drop(df_kce.loc[
    
    df_kce['Phone'].isin(df_phone_member_kce['Phone']) | 
    df_kce['Email'].isin(df_email_member_kce['Email'])
].index, inplace=True)

df_kce.reset_index(drop=True, inplace=True)

count_after_dedup_member_kce = df_kce.shape[0]
df_kce
# Out:
#       number                 FirstName   lastname    Country  \
# 0    1195313                    Ashish     Pandey      India
# 1    1196236  Shirin Kumar Jagdishbhai      Patel      India
# 2    1195370                     Arjun  Datterjee      India
# 3    1196249                    Aadish   Sardesai      India
# 4    1195774                Abdirahman       Abdi  Australia
# ..       ...                       ...        ...        ...
# 609  1195473                    RAJESH    GANOTRA      India
# 610  1195525                    Aevant       Jain      India
# 611  1195564                     Pawan      Kumar      India
# 612  1195566                    Swapan      Basak      India
# 613  1196244                    Mukesh    Chauhan      India
#
#                           Email         Phone Account Status  \
# 0       2ashishpandey@gmail.com  919739241381         ACTIVE
# 1            90shirin@gmail.com  919426644918         ACTIVE
# 2         a.c.aryan46@gmail.com  918147719805         ACTIVE
# 3      aadishsardesai@gmail.com  918411078156         ACTIVE
# 4    abdirahman95abdi@gmail.com  447522053986         ACTIVE
# ..                          ...           ...            ...
# 609                       empty  919910446009         ACTIVE
# 610                       empty  919893798055         ACTIVE
# 611                       empty  918684878727         ACTIVE
# 612                       empty  919733115861         ACTIVE
# 613                       empty  919833991131         ACTIVE
#
#         Servicing Office   Karma Club Program
# 0    KC EXPERIENCE India            South Goa
# 1    KC EXPERIENCE India            North Goa
# 2    KC EXPERIENCE India            South Goa
# 3    KC EXPERIENCE India            South Goa
# 4     KC EXPERIENCE Bali  Jimbaran Sales Deck
# ..                   ...                  ...
# 609                empty                empty
# 610  KC EXPERIENCE India            North Goa
# 611  KC EXPERIENCE India            North Goa
# 612  KC EXPERIENCE India            North Goa
# 613  KC EXPERIENCE India            South Goa
#
# [614 rows x 9 columns]

# %%
# hitung jumlah duplicate
count_duplicate_general = df_kce.loc[df_kce.duplicated(subset=['Email','Phone'])].shape[0]

df_kce.loc[df_kce.duplicated(subset=['Email','Phone'])]
# Out:
#       number FirstName lastname Country                 Email         Phone  \
# 273  1195192   SATHISH  KUMAR K   India  ksathishme@gmail.com  918197550385
#
#     Account Status     Servicing Office Karma Club Program
# 273         ACTIVE  KC EXPERIENCE India              empty

# %%
df_kce.drop_duplicates(subset=['Email','Phone'], inplace=True)
df_kce.reset_index(drop=True, inplace=True)

# hitung jumlah setelah value duplicate dihapus
count_after_dedup_duplicate = df_kce.shape[0]

df_kce
# Out:
#       number                 FirstName   lastname    Country  \
# 0    1195313                    Ashish     Pandey      India
# 1    1196236  Shirin Kumar Jagdishbhai      Patel      India
# 2    1195370                     Arjun  Datterjee      India
# 3    1196249                    Aadish   Sardesai      India
# 4    1195774                Abdirahman       Abdi  Australia
# ..       ...                       ...        ...        ...
# 608  1195473                    RAJESH    GANOTRA      India
# 609  1195525                    Aevant       Jain      India
# 610  1195564                     Pawan      Kumar      India
# 611  1195566                    Swapan      Basak      India
# 612  1196244                    Mukesh    Chauhan      India
#
#                           Email         Phone Account Status  \
# 0       2ashishpandey@gmail.com  919739241381         ACTIVE
# 1            90shirin@gmail.com  919426644918         ACTIVE
# 2         a.c.aryan46@gmail.com  918147719805         ACTIVE
# 3      aadishsardesai@gmail.com  918411078156         ACTIVE
# 4    abdirahman95abdi@gmail.com  447522053986         ACTIVE
# ..                          ...           ...            ...
# 608                       empty  919910446009         ACTIVE
# 609                       empty  919893798055         ACTIVE
# 610                       empty  918684878727         ACTIVE
# 611                       empty  919733115861         ACTIVE
# 612                       empty  919833991131         ACTIVE
#
#         Servicing Office   Karma Club Program
# 0    KC EXPERIENCE India            South Goa
# 1    KC EXPERIENCE India            North Goa
# 2    KC EXPERIENCE India            South Goa
# 3    KC EXPERIENCE India            South Goa
# 4     KC EXPERIENCE Bali  Jimbaran Sales Deck
# ..                   ...                  ...
# 608                empty                empty
# 609  KC EXPERIENCE India            North Goa
# 610  KC EXPERIENCE India            North Goa
# 611  KC EXPERIENCE India            North Goa
# 612  KC EXPERIENCE India            South Goa
#
# [613 rows x 9 columns]

# %%
list_UK_EU = pm.get_list_UK_EU()
list_Others = pm.get_list_Others()

# %%
df_kce.loc[df_kce['Country'].isin(list_Others)]
# Out:
#       number    FirstName   lastname      Country                       Email  \
# 4    1195774   Abdirahman       Abdi    Australia  abdirahman95abdi@gmail.com
# 12   1196215      Kenneth    Forrest    Australia       adriannef12@gmail.com
# 13   1195307        Aabid      Pasha         Oman   afiyashabnam786@gmail.com
# 16   1195328  Bal Krishna     Sharma       Bhutan           aitt226@gmail.com
# 18   1196232       Akaash    Bhagria       Canada     akaash_b123@hotmail.com
# ..       ...          ...        ...          ...                         ...
# 596  1196151         Mark  Wilkinson    Australia      wilkinson84@icloud.com
# 597  1196201         TONY   DALAMERE  New Zealand     wonky_world@hotmail.com
# 598  1195960          Ash    Russell    Australia     woodashley293@gmail.com
# 603  1195939       Zakary      Evans    Australia     zakaryevans22@gmail.com
# 606  1195309       Zeljko      Nogic    Australia          znogic@hotmail.com
#
#             Phone Account Status    Servicing Office     Karma Club Program
# 4    447522053986         ACTIVE  KC EXPERIENCE Bali    Jimbaran Sales Deck
# 12    61418721041         ACTIVE  KC EXPERIENCE Bali  Petitenget Sales Deck
# 13    96895983158         ACTIVE  KC EXPERIENCE Bali    Jimbaran Sales Deck
# 16    97517951140         ACTIVE  KC EXPERIENCE Bali    Jimbaran Sales Deck
# 18    14038017030         ACTIVE  KC EXPERIENCE Bali    Jimbaran Sales Deck
# ..            ...            ...                 ...                    ...
# 596   61406737082         ACTIVE  KC EXPERIENCE Bali    Jimbaran Sales Deck
# 597   61474536426         ACTIVE  KC EXPERIENCE Bali    Jimbaran Sales Deck
# 598   61431756700         ACTIVE  KC EXPERIENCE Bali  Petitenget Sales Deck
# 603   61408695258         ACTIVE  KC EXPERIENCE Bali    Jimbaran Sales Deck
# 606   61416074596         ACTIVE  KC EXPERIENCE Bali    Jimbaran Sales Deck
#
# [158 rows x 9 columns]

# %%
df_kce.loc[df_kce['Country'].str.contains('India'), 'Area'] = 'India'
df_kce.loc[df_kce['Country'].isin(list_UK_EU), 'Area'] = 'UK EU'
df_kce.loc[df_kce['Country'].isin(list_Others), 'Area'] = 'Others'

# %%
df_kce.loc[df_kce['Area'] == 'India', 'Batch'] = 'INDIA'
df_kce.loc[df_kce['Area'] == 'UK EU', 'Batch'] = 'NONINDIA'
df_kce.loc[df_kce['Area'] == 'Others', 'Batch'] = 'NONINDIA'

# %%
df_kce.replace('empty', '', inplace=True)

# %%
df_kce.columns
# Out:
# Index(['number', 'FirstName', 'lastname', 'Country', 'Email', 'Phone',
#        'Account Status', 'Servicing Office', 'Karma Club Program', 'Area',
#        'Batch'],
#       dtype='object')

# %%
new_cols = ['number', 'FirstName', 'lastname', 'Country', 'Area', 'Batch', 'Email', 'Phone',
       'Account Status', 'Servicing Office', 'Karma Club Program']

df_kce = df_kce.reindex(columns=new_cols)

# %%
count_data_akhir = df_kce.shape[0]

df_kce.to_csv(r'C:\Users\fajar\Documents\Python\Data\final_kce.csv', index=False)

# %%
print("==========================================================")
print("Summary")
print("==========================================================")
print("Jumlah Data Awal KCE CC-CL : "+str(count_data_awal))
print("Jumlah Data Email dan Phone Kosong : "+str(count_email_phone_empty))
print("Jumlah Data Setelah Hapus Email dan Phone Yang Kosong : "+str(count_after_email_phone_empty))
print("Jumlah Lead Test : "+str(count_leads_test))
print("Jumlah Setelah Clean Lead Test : "+str(count_after_dedup_test))
print("Jumlah Email Karma : "+str(count_email_karma))
print("Jumlah Setelah Clean Email Karma : "+str(count_after_clean_karma))
print("Jumlah Data Yang Terkena Dedup Member Oddysey : "+str(count_dedup_member_odd))
print("Jumlah Data Setelah Dedup Member Oddysey : "+str(count_after_dedup_member_odd))
print("Jumlah Data Yang Terkena Dedup Past Guest KCE : "+str(count_dedup_member_kce))
print("Jumlah Data Setelah Dedup Past Guest KCE : "+str(count_after_dedup_member_kce))
print("Jumlah Data Yang Duplicate : "+str(count_duplicate_general))
print("Jumlah Data Setelah Hapus Duplicate : "+str(count_after_dedup_duplicate))
print("Jumlah Data Akhir : "+str(count_data_akhir))
# Out:
# ==========================================================
# Summary
# ==========================================================
# Jumlah Data Awal KCE CC-CL : 756
# Jumlah Data Email dan Phone Kosong : 7
# Jumlah Data Setelah Hapus Email dan Phone Yang Kosong : 749
# Jumlah Lead Test : 0
# Jumlah Setelah Clean Lead Test : 749
# Jumlah Email Karma : 0
# Jumlah Setelah Clean Email Karma : 749
# Jumlah Data Yang Terkena Dedup Member Oddysey : 7
# Jumlah Data Setelah Dedup Member Oddysey : 742
# Jumlah Data Yang Terkena Dedup Past Guest KCE : 128
# Jumlah Data Setelah Dedup Past Guest KCE : 614
# Jumlah Data Yang Duplicate : 1
# Jumlah Data Setelah Hapus Duplicate : 613
# Jumlah Data Akhir : 613
