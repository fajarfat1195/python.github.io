# %%
import pandas as pd
import re

import past_guest_module as pm

import sys
sys.path.append('../zoho_data_app/')

import main_module as m

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
cols = ['Account ID', 'FirstName', 'lastname', 'Country', 'Email', 'Phone',
       'AcStatus', 'Servicing Office','KarmaClubProgram']

# %%
path = r'C:\Users\fajar\Documents\Python\Data\KCC cc-cl\2024\Juli\14 July - 22 July\KCE CC CL 14 July - 22 July.xlsx'
df_kce = pd.read_excel(path, dtype='string', sheet_name='Sheet1', usecols=cols)
count_data_awal = df_kce.shape[0]
df_kce
# Out:
#     Account ID      FirstName    lastname    Country  \
# 0      1193515         Raghav        Shah  Australia
# 1      1193765          Aaron      Hockey  Australia
# 2      1193974  Chandraseknar      Etwari  Australia
# 3      1193489          Aijin  Mukkadakal  Australia
# 4      1193498          Ailen    Christie  Australia
# ..         ...            ...         ...        ...
# 656    1193972         Gaurav      Paudel       <NA>
# 657    1193973        Jeffrey      Bailey       <NA>
# 658    1193976         Daniel       Wojno       <NA>
# 659    1193332          Isaac      Flores       <NA>
# 660    1193343         Trevor       Olsen       <NA>
#
#                              Email        Phone AcStatus    Servicing Office  \
# 0                87pshah@gmail.com  61433360018   ACTIVE  KC EXPERIENCE Bali
# 1        aaronhockey83@hotmail.com  61424789954   ACTIVE  KC EXPERIENCE Bali
# 2          aatish.etwari@gmail.com  61452582026   ACTIVE  KC EXPERIENCE Bali
# 3               aijin007@gmail.com  61488395909   ACTIVE  KC EXPERIENCE Bali
# 4             alcat28@yahoo.com.au  61488078094   ACTIVE  KC EXPERIENCE Bali
# ..                             ...          ...      ...                 ...
# 656         gauravpaudel@gmail.com  15129094562   ACTIVE  KC EXPERIENCE Bali
# 657     jeffrey.bailey95@gmail.com  13852869036   ACTIVE  KC EXPERIENCE Bali
# 658          lerma.gayle@gmail.com  19203069338   ACTIVE  KC EXPERIENCE Bali
# 659  romerobenitezsusana@gmail.com  12027900261   ACTIVE  KC EXPERIENCE Bali
# 660        trevorolsen87@gmail.com  15414202928   ACTIVE  KC EXPERIENCE Bali
#
#           KarmaClubProgram
# 0      Jimbaran Sales Deck
# 1      Jimbaran Sales Deck
# 2      Jimbaran Sales Deck
# 3      Jimbaran Sales Deck
# 4      Jimbaran Sales Deck
# ..                     ...
# 656    Jimbaran Sales Deck
# 657    Jimbaran Sales Deck
# 658    Jimbaran Sales Deck
# 659    Jimbaran Sales Deck
# 660  Petitenget Sales Deck
#
# [661 rows x 9 columns]

# %%
df_kce.columns
# Out:
# Index(['Account ID', 'FirstName', 'lastname', 'Country', 'Email', 'Phone',
#        'AcStatus', 'Servicing Office', 'KarmaClubProgram'],
#       dtype='object')

# %%
df_kce.rename(columns = {
    'Account ID':'number', 
    'AcStatus':'Account Status',
    'KarmaClubProgram':'Karma Club Program',
    }, inplace = True)

# %%
df_kce.fillna('empty', inplace=True)

# %%
path = r'G:\.shortcut-targets-by-id\0B_d3smBjzo04UUNBME5GOVhoMjA\_ODYSSEY\Phone Members.xlsx'
df_phone_member_odd = pd.read_excel(path, dtype='string', sheet_name='Sheet1')

path = r'G:\.shortcut-targets-by-id\0B_d3smBjzo04UUNBME5GOVhoMjA\_ODYSSEY\Email Members.xlsx'
df_email_member_odd = pd.read_excel(path, dtype='string', sheet_name='Sheet1')

path = r'G:\.shortcut-targets-by-id\0B_d3smBjzo04UUNBME5GOVhoMjA\_ODYSSEY\KCE Members.xlsx'
df_phone_member_kce = pd.read_excel(path, dtype='string', sheet_name='Phone')

path = r'G:\.shortcut-targets-by-id\0B_d3smBjzo04UUNBME5GOVhoMjA\_ODYSSEY\KCE Members.xlsx'
df_email_member_kce = pd.read_excel(path, dtype='string', sheet_name='Email')

# %%
m.clean_number(df_kce, 'Phone')
m.replace_not_valid_to_empty(df_kce, 'Phone')
df_kce['Email'] = m.lowercase(df_kce, 'Email')
m.clean_space(df_kce, 'Email')

m.clean_number(df_phone_member_odd, 'Mobile')
df_email_member_odd['Email'] = m.lowercase(df_email_member_odd, 'Email')
m.clean_space(df_email_member_odd, 'Email')

m.clean_number(df_phone_member_kce, 'Phone')
df_email_member_kce['Email'] = m.lowercase(df_email_member_kce, 'Email')
m.clean_space(df_email_member_kce, 'Email')
# Out:
# 0          aameercok@gmail.com.com
# 1              imerwan@hotmail.com
# 2              mkptech15@gmail.com
# 3        sovitmittal2000@yahoo.com
# 4          smritidas1431@gmail.com
#                    ...
# 82327        leung.sweta@gmail.com
# 82328        malbashir06@gmail.com
# 82329          roksolidz@gmail.com
# 82330    stephaniebasca3@gmail.com
# 82331        yaseen91.ya@gmail.com
# Name: Email, Length: 82332, dtype: string

# %%
pm.email_correction(df_kce, 'Email')
df_kce
# Out:
#       number      FirstName    lastname    Country  \
# 0    1193515         Raghav        Shah  Australia
# 1    1193765          Aaron      Hockey  Australia
# 2    1193974  Chandraseknar      Etwari  Australia
# 3    1193489          Aijin  Mukkadakal  Australia
# 4    1193498          Ailen    Christie  Australia
# ..       ...            ...         ...        ...
# 656  1193972         Gaurav      Paudel      empty
# 657  1193973        Jeffrey      Bailey      empty
# 658  1193976         Daniel       Wojno      empty
# 659  1193332          Isaac      Flores      empty
# 660  1193343         Trevor       Olsen      empty
#
#                              Email        Phone Account Status  \
# 0                87pshah@gmail.com  61433360018         ACTIVE
# 1        aaronhockey83@hotmail.com  61424789954         ACTIVE
# 2          aatish.etwari@gmail.com  61452582026         ACTIVE
# 3               aijin007@gmail.com  61488395909         ACTIVE
# 4             alcat28@yahoo.com.au  61488078094         ACTIVE
# ..                             ...          ...            ...
# 656         gauravpaudel@gmail.com  15129094562         ACTIVE
# 657     jeffrey.bailey95@gmail.com  13852869036         ACTIVE
# 658          lerma.gayle@gmail.com  19203069338         ACTIVE
# 659  romerobenitezsusana@gmail.com  12027900261         ACTIVE
# 660        trevorolsen87@gmail.com  15414202928         ACTIVE
#
#        Servicing Office     Karma Club Program
# 0    KC EXPERIENCE Bali    Jimbaran Sales Deck
# 1    KC EXPERIENCE Bali    Jimbaran Sales Deck
# 2    KC EXPERIENCE Bali    Jimbaran Sales Deck
# 3    KC EXPERIENCE Bali    Jimbaran Sales Deck
# 4    KC EXPERIENCE Bali    Jimbaran Sales Deck
# ..                  ...                    ...
# 656  KC EXPERIENCE Bali    Jimbaran Sales Deck
# 657  KC EXPERIENCE Bali    Jimbaran Sales Deck
# 658  KC EXPERIENCE Bali    Jimbaran Sales Deck
# 659  KC EXPERIENCE Bali    Jimbaran Sales Deck
# 660  KC EXPERIENCE Bali  Petitenget Sales Deck
#
# [661 rows x 9 columns]

# %%
count_email_phone_empty = df_kce.loc[(df_kce['Email'] == 'empty') & (df_kce['Phone'] == 'empty')].shape[0]

df_kce.loc[(df_kce['Email'] == 'empty') & (df_kce['Phone'] == 'empty')].to_csv(r'C:\Users\fajar\Documents\Python\Data\cek_email_phone_empty_kce.csv', index=False)

df_kce.drop(df_kce.loc[(df_kce['Email'] == 'empty') & (df_kce['Phone'] == 'empty')].index, inplace=True)
df_kce.reset_index(drop=True, inplace=True)

count_after_email_phone_empty = df_kce.shape[0]

# %%
# Cek leads test
test_leads = df_kce.loc[
    
        df_kce['Email'].str.contains('^test@', flags=re.I, regex=True) |
        df_kce['Email'].str.contains('\+test', flags=re.I, regex=True) |
    
        df_kce['FirstName'].str.contains('^test$', flags=re.I, regex=True) |
        df_kce['lastname'].str.contains('^test$', flags=re.I, regex=True) |

        df_kce['FirstName'].str.contains('test 1', flags=re.I, regex=True) |
        df_kce['lastname'].str.contains('test 2', flags=re.I, regex=True)|
        df_kce['FirstName'].str.contains('test1', flags=re.I, regex=True) |
        df_kce['lastname'].str.contains('test2', flags=re.I, regex=True)|

        df_kce['FirstName'].str.contains(' test ', flags=re.I, regex=True) | 
        df_kce['lastname'].str.contains(' test ', flags=re.I, regex=True) | 
        df_kce['lastname'].str.contains(' test$', flags=re.I, regex=True)
    
    
    ]

count_leads_test = test_leads.shape[0]

test_leads.to_excel(r'C:\Users\fajar\Documents\Python\Data\test_leads.xlsx', index=False)
test_leads
# Out:
# Empty DataFrame
# Columns: [number, FirstName, lastname, Country, Email, Phone, Account Status, Servicing Office, Karma Club Program]
# Index: []

# %%
df_kce.drop(test_leads.index, inplace=True)
df_kce.reset_index(drop=True, inplace=True)

count_after_dedup_test = df_kce.shape[0]

# %%
# Cek Email Karma
email_karma = m.find_karma(df_kce, 'Email')
count_email_karma = email_karma.shape[0]
# email_OTA.to_excel(r'C:\Users\fajar\Documents\Python\Data\email_OTA.xlsx', index=False)

email_karma
# Out:
# Empty DataFrame
# Columns: [number, FirstName, lastname, Country, Email, Phone, Account Status, Servicing Office, Karma Club Program]
# Index: []

# %%
# delete email Karma
count_after_clean_karma = m.delete_karma(df_kce, 'Email')
# zoho_df.to_excel(r'C:\Users\fajar\Documents\Python\Data\after_clean_OTA.xlsx', index=False)

df_kce
# Out:
#       number      FirstName    lastname    Country  \
# 0    1193515         Raghav        Shah  Australia
# 1    1193765          Aaron      Hockey  Australia
# 2    1193974  Chandraseknar      Etwari  Australia
# 3    1193489          Aijin  Mukkadakal  Australia
# 4    1193498          Ailen    Christie  Australia
# ..       ...            ...         ...        ...
# 653  1193972         Gaurav      Paudel      empty
# 654  1193973        Jeffrey      Bailey      empty
# 655  1193976         Daniel       Wojno      empty
# 656  1193332          Isaac      Flores      empty
# 657  1193343         Trevor       Olsen      empty
#
#                              Email        Phone Account Status  \
# 0                87pshah@gmail.com  61433360018         ACTIVE
# 1        aaronhockey83@hotmail.com  61424789954         ACTIVE
# 2          aatish.etwari@gmail.com  61452582026         ACTIVE
# 3               aijin007@gmail.com  61488395909         ACTIVE
# 4             alcat28@yahoo.com.au  61488078094         ACTIVE
# ..                             ...          ...            ...
# 653         gauravpaudel@gmail.com  15129094562         ACTIVE
# 654     jeffrey.bailey95@gmail.com  13852869036         ACTIVE
# 655          lerma.gayle@gmail.com  19203069338         ACTIVE
# 656  romerobenitezsusana@gmail.com  12027900261         ACTIVE
# 657        trevorolsen87@gmail.com  15414202928         ACTIVE
#
#        Servicing Office     Karma Club Program
# 0    KC EXPERIENCE Bali    Jimbaran Sales Deck
# 1    KC EXPERIENCE Bali    Jimbaran Sales Deck
# 2    KC EXPERIENCE Bali    Jimbaran Sales Deck
# 3    KC EXPERIENCE Bali    Jimbaran Sales Deck
# 4    KC EXPERIENCE Bali    Jimbaran Sales Deck
# ..                  ...                    ...
# 653  KC EXPERIENCE Bali    Jimbaran Sales Deck
# 654  KC EXPERIENCE Bali    Jimbaran Sales Deck
# 655  KC EXPERIENCE Bali    Jimbaran Sales Deck
# 656  KC EXPERIENCE Bali    Jimbaran Sales Deck
# 657  KC EXPERIENCE Bali  Petitenget Sales Deck
#
# [658 rows x 9 columns]

# %%
find_member_oddysey = df_kce.copy()

find_member_oddysey.loc[find_member_oddysey['Phone'].isin(df_phone_member_odd['Mobile']), 'Same Value Find'] = 'Member-Mobile' 

find_member_oddysey.loc[find_member_oddysey['Email'].isin(df_email_member_odd['Email']), 'Same Value Find'] = 'Member-Email'
find_member_oddysey.drop(find_member_oddysey.loc[find_member_oddysey['Same Value Find'].isna()].index, inplace=True)

find_member_oddysey.replace('empty', '', inplace=True)

find_member_oddysey.to_csv(r'C:\Users\fajar\Documents\Python\Data\cek_member_odyssey.csv', index=False)

# %%
count_dedup_member_odd = df_kce.loc[
    
    df_kce['Phone'].isin(df_phone_member_odd['Mobile']) | 
    df_kce['Email'].isin(df_email_member_odd['Email'])
].shape[0]

df_kce.loc[
    
    df_kce['Phone'].isin(df_phone_member_odd['Mobile']) | 
    df_kce['Email'].isin(df_email_member_odd['Email'])
]
# Out:
#       number FirstName  lastname Country                           Email  \
# 416  1193100    CHETAN   PANCHAL   India        panchalchetank@gmail.com
# 512  1192733      SONU  MUNDOTIA   India          sonumundotia@gmail.com
# 515  1193398  SPOORTHI         S   India  spoorthi_sajjanapu@yahoo.co.in
# 566  1193924     Vipul         .   India                 vipul@gmail.com
#
#             Phone Account Status     Servicing Office Karma Club Program
# 416  919979894054         ACTIVE     KARMA CLUB INDIA              empty
# 512  919501999104         ACTIVE  KC EXPERIENCE India              empty
# 515  918407999647         ACTIVE  KC EXPERIENCE India              empty
# 566  919370678090         ACTIVE  KC EXPERIENCE India          South Goa

# %%
df_kce.drop(df_kce.loc[
    
    df_kce['Phone'].isin(df_phone_member_odd['Mobile']) | 
    df_kce['Email'].isin(df_email_member_odd['Email'])
].index, inplace=True)

df_kce.reset_index(drop=True, inplace=True)

count_after_dedup_member_odd = df_kce.shape[0]
df_kce
# Out:
#       number      FirstName    lastname    Country  \
# 0    1193515         Raghav        Shah  Australia
# 1    1193765          Aaron      Hockey  Australia
# 2    1193974  Chandraseknar      Etwari  Australia
# 3    1193489          Aijin  Mukkadakal  Australia
# 4    1193498          Ailen    Christie  Australia
# ..       ...            ...         ...        ...
# 649  1193972         Gaurav      Paudel      empty
# 650  1193973        Jeffrey      Bailey      empty
# 651  1193976         Daniel       Wojno      empty
# 652  1193332          Isaac      Flores      empty
# 653  1193343         Trevor       Olsen      empty
#
#                              Email        Phone Account Status  \
# 0                87pshah@gmail.com  61433360018         ACTIVE
# 1        aaronhockey83@hotmail.com  61424789954         ACTIVE
# 2          aatish.etwari@gmail.com  61452582026         ACTIVE
# 3               aijin007@gmail.com  61488395909         ACTIVE
# 4             alcat28@yahoo.com.au  61488078094         ACTIVE
# ..                             ...          ...            ...
# 649         gauravpaudel@gmail.com  15129094562         ACTIVE
# 650     jeffrey.bailey95@gmail.com  13852869036         ACTIVE
# 651          lerma.gayle@gmail.com  19203069338         ACTIVE
# 652  romerobenitezsusana@gmail.com  12027900261         ACTIVE
# 653        trevorolsen87@gmail.com  15414202928         ACTIVE
#
#        Servicing Office     Karma Club Program
# 0    KC EXPERIENCE Bali    Jimbaran Sales Deck
# 1    KC EXPERIENCE Bali    Jimbaran Sales Deck
# 2    KC EXPERIENCE Bali    Jimbaran Sales Deck
# 3    KC EXPERIENCE Bali    Jimbaran Sales Deck
# 4    KC EXPERIENCE Bali    Jimbaran Sales Deck
# ..                  ...                    ...
# 649  KC EXPERIENCE Bali    Jimbaran Sales Deck
# 650  KC EXPERIENCE Bali    Jimbaran Sales Deck
# 651  KC EXPERIENCE Bali    Jimbaran Sales Deck
# 652  KC EXPERIENCE Bali    Jimbaran Sales Deck
# 653  KC EXPERIENCE Bali  Petitenget Sales Deck
#
# [654 rows x 9 columns]

# %%
find_member_kce = df_kce.copy()

find_member_kce.loc[find_member_kce['Phone'].isin(df_phone_member_kce['Phone']), 'Same Value Find'] = 'Member-KCE-Mobile' 

find_member_kce.loc[find_member_kce['Email'].isin(df_email_member_kce['Email']), 'Same Value Find'] = 'Member-KCE-Email'
find_member_kce.drop(find_member_kce.loc[find_member_kce['Same Value Find'].isna()].index, inplace=True)

find_member_kce.replace('empty', '', inplace=True)

find_member_kce.to_csv(r'C:\Users\fajar\Documents\Python\Data\cek_member_kce.csv', index=False)

# %%
count_dedup_member_kce = df_kce.loc[
    
    df_kce['Phone'].isin(df_phone_member_kce['Phone']) | 
    df_kce['Email'].isin(df_email_member_kce['Email'])

].shape[0]

df_kce.loc[
    
    df_kce['Phone'].isin(df_phone_member_kce['Phone']) | 
    df_kce['Email'].isin(df_email_member_kce['Email'])
]
# Out:
#       number            FirstName          lastname      Country  \
# 6    1192927                James             Oking    Australia
# 17   1192923              Charles           La Rosa    Australia
# 41   1192920              Bradley           Apostle    Australia
# 43   1192942                 Igor         Rosenfeld    Australia
# 62   1192918    Ocean Tanmaletila             Maulo    Australia
# 70   1192925                Peter           Purchas    Australia
# 83   1192922                Ovais              Tawa    Australia
# 103  1192932              Sandeep            Sekhon    Australia
# 105  1192924                Benno            Fenger    Australia
# 107  1192935               Dakota          Abberton    Australia
# 110  1192931                Simon          Mccuskey    Australia
# 147  1192939                  Sri              Iyer      England
# 148  1192930                Lewis              Wood      England
# 151  1192948              SANDEEP            SIDANA      England
# 156  1192928  Rabetokdany Lalaina              Toni      Germany
# 157  1192958                 Syam  Sadasivan Pillai      Germany
# 167  1192944             Siddhart            Jadhav        India
# 177  1192950                 Amit            Sharma        India
# 218  1192949            Ravikumar                 .        India
# 239  1193267              AVIJEET               DEB        India
# 247  1191445               DILEEP                 C        India
# 254  1192938            Satyendra            Prasad        India
# 258  1192941               Farhan             Adeni        India
# 261  1192961             Ganesh N            Nigade        India
# 283  1192947             Himanshu            Panwar        India
# 290  1192921                Ishan              Garg        India
# 291  1192960               Ishwar       V Vadoderia        India
# 309  1192933               Rohith   Totada Nagaraja        India
# 315  1193028        KRISHNAMURTHY               RAO        India
# 320  1192963              Kiran H             Pinge        India
# 322  1192962                Kiran                 V        India
# 327  1192943          Jiwan Kumar              Garg        India
# 360  1192955               Arvind             Gupta        India
# 373  1192919               Monish           Bhapker        India
# 379  1192959               Ashish             Kumar        India
# 394  1192945                Vijay      Neshanth P M        India
# 414  1192965               Akshay              Kirt        India
# 439  1192934        Raghul Rajesh              Ravi        India
# 447  1193008              Ravasab          Dhupadel        India
# 452  1192951         Razin Rafeek          Mohammed        India
# 474  1192946               Sanjay           Agarwal        India
# 481  1192954         Satinder Pal             Singh        India
# 493  1192929        Shashi Ranjan             Kumar        India
# 495  1192957              Shikher            Saxena        India
# 501  1192952               Shoyab            Shaikh        India
# 535  1193251                TARUN             KUMAR        India
# 552  1192953                Sunny             Sinha        India
# 559  1192940                 Vinu           Abraham        India
# 572  1192956               Yogesh            Sehgal        India
# 574  1192964                Zakir            Shaikh        India
# 602  1192936            Fransisco           Serrano  New Zealand
# 617  1192937              Karthik         Raghunath    Singapore
# 621  1192926            Rajendran  Jamardananpillai    Singapore
#
#                               Email          Phone Account Status  \
# 6              amileigh88@gmail.com    61411794917         ACTIVE
# 17             chasfaye@hotmail.com    61409257226         ACTIVE
# 41               hanns440@gmail.com    61401574220         ACTIVE
# 43                 igrrsn@gmail.com    61421610096         ACTIVE
# 62            kimi2nora@hotmail.com    61449640591         ACTIVE
# 70           lisa@dancescene.com.au    61410518401         ACTIVE
# 83              ovaistawa@gmail.com    61416354007         ACTIVE
# 103         sandeepsekhon@gmail.com    61451053336         ACTIVE
# 105      sasha-benno@outlook.com.au    61423989687         ACTIVE
# 107               slcoop3@gmail.com    61434698652         ACTIVE
# 110            spmccuskey@gmail.com    61410291030         ACTIVE
# 147                iyersm@yahoo.com   447808391210         ACTIVE
# 148                 lewo@live.co.uk   447527335977         ACTIVE
# 151         sakshamsidana@gmail.com   447765920321         ACTIVE
# 156        katzwinkelmanja@yahoo.fr  4915756165233         ACTIVE
# 157           spillaisyam@gmail.com  4915901534339         ACTIVE
# 167        advsiddharth06@gmail.com   919011746666         ACTIVE
# 177      amitsharma.assam@gmail.com   919435015657         ACTIVE
# 218             bpr.oryza@gmail.com   919448457349         ACTIVE
# 239          debavijeet77@gmail.com   919748477107         ACTIVE
# 247             draj450@outlook.com   919964171711         ACTIVE
# 254  er.sateyendra.prasad@gmail.com   919610942844         ACTIVE
# 258          farhan.adeni@gmail.com   919677013949         ACTIVE
# 261         ganesh.nigade@gmail.com   919908422284         ACTIVE
# 283      himanshu.pawar99@gmail.com   918949287323         ACTIVE
# 290         ishan.hr.garg@gmail.com   917988742668         ACTIVE
# 291        ishwarvadodaxa@gmail.com   919924871070         ACTIVE
# 309     justcontactus.jcu@gmail.com   919886519170         ACTIVE
# 315      kavithamdiabetes@gmail.com   919945693939         ACTIVE
# 320               khpinge@gmail.com   919136990377         ACTIVE
# 322             kiran7691@gmail.com   919962856443         ACTIVE
# 327          kjiwankumar@gnmail.com   919815355202         ACTIVE
# 360            meenakshig@gmail.com   919811587955         ACTIVE
# 373       monishbhapkar77@gmail.com   919892687652         ACTIVE
# 379        munjalashish@hotmail.com   919711200910         ACTIVE
# 394         neshanthvijay@gmail.com   919092117270         ACTIVE
# 414           pallavi3882@gmail.com   918800773882         ACTIVE
# 439        raghulrajesh28@gmail.com   918148326713         ACTIVE
# 447             ravasab87@gmail.com   919036051008         ACTIVE
# 452         razinrafeek@hotmail.com   919656364253         ACTIVE
# 474       sanjayagr2002@yahoo.co.in   919810507065         ACTIVE
# 481        satinderpal136@yahoo.com   916284188439         ACTIVE
# 493      shashiranjan2909@gmail.com   919871517182         ACTIVE
# 495       shikhersaxena93@gmail.com   918218967884         ACTIVE
# 501       shoyab.1987.sss@gmail.com   918291565457         ACTIVE
# 535         tarunk12000@yahoo.co.in   919599855168         ACTIVE
# 552         varnikasinha6@gmail.com   918757830309         ACTIVE
# 559                 vinab@gmail.com   919387211771         ACTIVE
# 572     yogeshsehgal65652@yahoo.com   919915388767         ACTIVE
# 574    zakirshaik13061989@gmail.com   917039458540         ACTIVE
# 602      serranofrancisco@gmail.com    64211952000         ACTIVE
# 617            karthik849@gmail.com     6581397850         ACTIVE
# 621         rpi62817@bigpond.net.au    61438966421         ACTIVE
#
#         Servicing Office     Karma Club Program
# 6     KC EXPERIENCE Bali     Vietnam Sales Deck
# 17    KC EXPERIENCE Bali    Jimbaran Sales Deck
# 41    KC EXPERIENCE Bali  Petitenget Sales Deck
# 43    KC EXPERIENCE Bali    Jimbaran Sales Deck
# 62    KC EXPERIENCE Bali  Petitenget Sales Deck
# 70    KC EXPERIENCE Bali    Jimbaran Sales Deck
# 83    KC EXPERIENCE Bali  Petitenget Sales Deck
# 103   KC EXPERIENCE Bali    Jimbaran Sales Deck
# 105   KC EXPERIENCE Bali    Jimbaran Sales Deck
# 107   KC EXPERIENCE Bali    Jimbaran Sales Deck
# 110   KC EXPERIENCE Bali    Jimbaran Sales Deck
# 147   KC EXPERIENCE Bali  Petitenget Sales Deck
# 148   KC EXPERIENCE Bali  Petitenget Sales Deck
# 151   KC EXPERIENCE Bali    Jimbaran Sales Deck
# 156   KC EXPERIENCE Bali     Vietnam Sales Deck
# 157   KC EXPERIENCE Bali     Vietnam Sales Deck
# 167  KC EXPERIENCE India              South Goa
# 177   KC EXPERIENCE Bali    Jimbaran Sales Deck
# 218  KC EXPERIENCE India              South Goa
# 239  KC EXPERIENCE India                  empty
# 247  KC EXPERIENCE India                  empty
# 254  KC EXPERIENCE India              South Goa
# 258   KC EXPERIENCE Bali    Jimbaran Sales Deck
# 261  KC EXPERIENCE India              South Goa
# 283  KC EXPERIENCE India              South Goa
# 290   KC EXPERIENCE Bali  Petitenget Sales Deck
# 291  KC EXPERIENCE India              South Goa
# 309   KC EXPERIENCE Bali    Jimbaran Sales Deck
# 315  KC EXPERIENCE India                  empty
# 320  KC EXPERIENCE India              South Goa
# 322  KC EXPERIENCE India              South Goa
# 327  KC EXPERIENCE India              South Goa
# 360  KC EXPERIENCE India              South Goa
# 373   KC EXPERIENCE Bali    Jimbaran Sales Deck
# 379  KC EXPERIENCE India              South Goa
# 394   KC EXPERIENCE Bali    Jimbaran Sales Deck
# 414  KC EXPERIENCE India              South Goa
# 439   KC EXPERIENCE Bali    Jimbaran Sales Deck
# 447  KC EXPERIENCE India                  empty
# 452   KC EXPERIENCE Bali    Jimbaran Sales Deck
# 474   KC EXPERIENCE Bali    Jimbaran Sales Deck
# 481  KC EXPERIENCE India              South Goa
# 493  KC EXPERIENCE India              South Goa
# 495  KC EXPERIENCE India              South Goa
# 501  KC EXPERIENCE India              South Goa
# 535     KARMA CLUB INDIA                  empty
# 552  KC EXPERIENCE India              North Goa
# 559  KC EXPERIENCE India              South Goa
# 572  KC EXPERIENCE India              South Goa
# 574  KC EXPERIENCE India              South Goa
# 602   KC EXPERIENCE Bali  Petitenget Sales Deck
# 617   KC EXPERIENCE Bali  Petitenget Sales Deck
# 621   KC EXPERIENCE Bali     Vietnam Sales Deck

# %%
df_kce.drop(df_kce.loc[
    
    df_kce['Phone'].isin(df_phone_member_kce['Phone']) | 
    df_kce['Email'].isin(df_email_member_kce['Email'])
].index, inplace=True)

df_kce.reset_index(drop=True, inplace=True)

count_after_dedup_member_kce = df_kce.shape[0]
df_kce
# Out:
#       number      FirstName    lastname    Country  \
# 0    1193515         Raghav        Shah  Australia
# 1    1193765          Aaron      Hockey  Australia
# 2    1193974  Chandraseknar      Etwari  Australia
# 3    1193489          Aijin  Mukkadakal  Australia
# 4    1193498          Ailen    Christie  Australia
# ..       ...            ...         ...        ...
# 596  1193972         Gaurav      Paudel      empty
# 597  1193973        Jeffrey      Bailey      empty
# 598  1193976         Daniel       Wojno      empty
# 599  1193332          Isaac      Flores      empty
# 600  1193343         Trevor       Olsen      empty
#
#                              Email        Phone Account Status  \
# 0                87pshah@gmail.com  61433360018         ACTIVE
# 1        aaronhockey83@hotmail.com  61424789954         ACTIVE
# 2          aatish.etwari@gmail.com  61452582026         ACTIVE
# 3               aijin007@gmail.com  61488395909         ACTIVE
# 4             alcat28@yahoo.com.au  61488078094         ACTIVE
# ..                             ...          ...            ...
# 596         gauravpaudel@gmail.com  15129094562         ACTIVE
# 597     jeffrey.bailey95@gmail.com  13852869036         ACTIVE
# 598          lerma.gayle@gmail.com  19203069338         ACTIVE
# 599  romerobenitezsusana@gmail.com  12027900261         ACTIVE
# 600        trevorolsen87@gmail.com  15414202928         ACTIVE
#
#        Servicing Office     Karma Club Program
# 0    KC EXPERIENCE Bali    Jimbaran Sales Deck
# 1    KC EXPERIENCE Bali    Jimbaran Sales Deck
# 2    KC EXPERIENCE Bali    Jimbaran Sales Deck
# 3    KC EXPERIENCE Bali    Jimbaran Sales Deck
# 4    KC EXPERIENCE Bali    Jimbaran Sales Deck
# ..                  ...                    ...
# 596  KC EXPERIENCE Bali    Jimbaran Sales Deck
# 597  KC EXPERIENCE Bali    Jimbaran Sales Deck
# 598  KC EXPERIENCE Bali    Jimbaran Sales Deck
# 599  KC EXPERIENCE Bali    Jimbaran Sales Deck
# 600  KC EXPERIENCE Bali  Petitenget Sales Deck
#
# [601 rows x 9 columns]

# %%
# hitung jumlah duplicate
count_duplicate_general = df_kce.loc[df_kce.duplicated(subset=['Email','Phone'])].shape[0]

df_kce.loc[df_kce.duplicated(subset=['Email','Phone'])]
# Out:
#       number FirstName         lastname Country                       Email  \
# 234  1193286      AJAY            SINGH   India  evergreenajay007@gmail.com
# 246  1193278       DR.  GIRISH MANGLEEK   India            gmnglk@gmail.com
#
#             Phone Account Status     Servicing Office Karma Club Program
# 234  918861959081         ACTIVE  KC EXPERIENCE India              empty
# 246  919868152425         ACTIVE  KC EXPERIENCE India              empty

# %%
df_kce.drop_duplicates(subset=['Email','Phone'], inplace=True)
df_kce.reset_index(drop=True, inplace=True)

# hitung jumlah setelah value duplicate dihapus
count_after_dedup_duplicate = df_kce.shape[0]

df_kce
# Out:
#       number      FirstName    lastname    Country  \
# 0    1193515         Raghav        Shah  Australia
# 1    1193765          Aaron      Hockey  Australia
# 2    1193974  Chandraseknar      Etwari  Australia
# 3    1193489          Aijin  Mukkadakal  Australia
# 4    1193498          Ailen    Christie  Australia
# ..       ...            ...         ...        ...
# 594  1193972         Gaurav      Paudel      empty
# 595  1193973        Jeffrey      Bailey      empty
# 596  1193976         Daniel       Wojno      empty
# 597  1193332          Isaac      Flores      empty
# 598  1193343         Trevor       Olsen      empty
#
#                              Email        Phone Account Status  \
# 0                87pshah@gmail.com  61433360018         ACTIVE
# 1        aaronhockey83@hotmail.com  61424789954         ACTIVE
# 2          aatish.etwari@gmail.com  61452582026         ACTIVE
# 3               aijin007@gmail.com  61488395909         ACTIVE
# 4             alcat28@yahoo.com.au  61488078094         ACTIVE
# ..                             ...          ...            ...
# 594         gauravpaudel@gmail.com  15129094562         ACTIVE
# 595     jeffrey.bailey95@gmail.com  13852869036         ACTIVE
# 596          lerma.gayle@gmail.com  19203069338         ACTIVE
# 597  romerobenitezsusana@gmail.com  12027900261         ACTIVE
# 598        trevorolsen87@gmail.com  15414202928         ACTIVE
#
#        Servicing Office     Karma Club Program
# 0    KC EXPERIENCE Bali    Jimbaran Sales Deck
# 1    KC EXPERIENCE Bali    Jimbaran Sales Deck
# 2    KC EXPERIENCE Bali    Jimbaran Sales Deck
# 3    KC EXPERIENCE Bali    Jimbaran Sales Deck
# 4    KC EXPERIENCE Bali    Jimbaran Sales Deck
# ..                  ...                    ...
# 594  KC EXPERIENCE Bali    Jimbaran Sales Deck
# 595  KC EXPERIENCE Bali    Jimbaran Sales Deck
# 596  KC EXPERIENCE Bali    Jimbaran Sales Deck
# 597  KC EXPERIENCE Bali    Jimbaran Sales Deck
# 598  KC EXPERIENCE Bali  Petitenget Sales Deck
#
# [599 rows x 9 columns]

# %%
list_UK_EU = pm.get_list_UK_EU()
list_Others = pm.get_list_Others()

# %%
df_kce.loc[df_kce['Country'].isin(list_Others)]
# Out:
#       number      FirstName     lastname               Country  \
# 0    1193515         Raghav         Shah             Australia
# 1    1193765          Aaron       Hockey             Australia
# 2    1193974  Chandraseknar       Etwari             Australia
# 3    1193489          Aijin   Mukkadakal             Australia
# 4    1193498          Ailen     Christie             Australia
# ..       ...            ...          ...                   ...
# 569  1193353        Stephen         Pang             Singapore
# 570  1193072      Yashkumar         Amin  United Arab Emirates
# 589  1193512           Kris          Moa                   USA
# 590  1193629      Stanislav  Berenshtein                   USA
# 591  1193748      Kristofer        Jones                   USA
#
#                          Email         Phone Account Status  \
# 0            87pshah@gmail.com   61433360018         ACTIVE
# 1    aaronhockey83@hotmail.com   61424789954         ACTIVE
# 2      aatish.etwari@gmail.com   61452582026         ACTIVE
# 3           aijin007@gmail.com   61488395909         ACTIVE
# 4         alcat28@yahoo.com.au   61488078094         ACTIVE
# ..                         ...           ...            ...
# 569          stppang@gmail.com    6597525951         ACTIVE
# 570         yashamin@gmail.com  971506924641         ACTIVE
# 589         kris.moa@yahoo.com   16027626394         ACTIVE
# 590    s.berenshtein@yahoo.com   17817108374         ACTIVE
# 591        tinabonsu@gmail.com   13477534682         ACTIVE
#
#        Servicing Office     Karma Club Program
# 0    KC EXPERIENCE Bali    Jimbaran Sales Deck
# 1    KC EXPERIENCE Bali    Jimbaran Sales Deck
# 2    KC EXPERIENCE Bali    Jimbaran Sales Deck
# 3    KC EXPERIENCE Bali    Jimbaran Sales Deck
# 4    KC EXPERIENCE Bali    Jimbaran Sales Deck
# ..                  ...                    ...
# 569  KC EXPERIENCE Bali    Jimbaran Sales Deck
# 570  KC EXPERIENCE Bali  Petitenget Sales Deck
# 589  KC EXPERIENCE Bali     Vietnam Sales Deck
# 590  KC EXPERIENCE Bali  Petitenget Sales Deck
# 591  KC EXPERIENCE Bali  Petitenget Sales Deck
#
# [173 rows x 9 columns]

# %%
df_kce.loc[df_kce['Country'].str.contains('India'), 'Area'] = 'India'
df_kce.loc[df_kce['Country'].isin(list_UK_EU), 'Area'] = 'UK EU'
df_kce.loc[df_kce['Country'].isin(list_Others), 'Area'] = 'Others'

# %%
df_kce.loc[df_kce['Area'] == 'India', 'Batch'] = 'INDIA'
df_kce.loc[df_kce['Area'] == 'UK EU', 'Batch'] = 'NONINDIA'
df_kce.loc[df_kce['Area'] == 'Others', 'Batch'] = 'NONINDIA'

# %%
df_kce.replace('empty', '', inplace=True)

# %%
df_kce.columns
# Out:
# Index(['number', 'FirstName', 'lastname', 'Country', 'Email', 'Phone',
#        'Account Status', 'Servicing Office', 'Karma Club Program', 'Area',
#        'Batch'],
#       dtype='object')

# %%
new_cols = ['number', 'FirstName', 'lastname', 'Country', 'Area', 'Batch', 'Email', 'Phone',
       'Account Status', 'Servicing Office', 'Karma Club Program']

df_kce = df_kce.reindex(columns=new_cols)

# %%
count_data_akhir = df_kce.shape[0]

df_kce.to_csv(r'C:\Users\fajar\Documents\Python\Data\final_kce.csv', index=False)

# %%
print("==========================================================")
print("Summary")
print("==========================================================")
print("Jumlah Data Awal KCE CC-CL : "+str(count_data_awal))
print("Jumlah Data Email dan Phone Kosong : "+str(count_email_phone_empty))
print("Jumlah Data Setelah Hapus Email dan Phone Yang Kosong : "+str(count_after_email_phone_empty))
print("Jumlah Lead Test : "+str(count_leads_test))
print("Jumlah Setelah Clean Lead Test : "+str(count_after_dedup_test))
print("Jumlah Email Karma : "+str(count_email_karma))
print("Jumlah Setelah Clean Email Karma : "+str(count_after_clean_karma))
print("Jumlah Data Yang Terkena Dedup Member Oddysey : "+str(count_dedup_member_odd))
print("Jumlah Data Setelah Dedup Member Oddysey : "+str(count_after_dedup_member_odd))
print("Jumlah Data Yang Terkena Dedup Past Guest KCE : "+str(count_dedup_member_kce))
print("Jumlah Data Setelah Dedup Past Guest KCE : "+str(count_after_dedup_member_kce))
print("Jumlah Data Yang Duplicate : "+str(count_duplicate_general))
print("Jumlah Data Setelah Hapus Duplicate : "+str(count_after_dedup_duplicate))
print("Jumlah Data Akhir : "+str(count_data_akhir))
# Out:
# ==========================================================
# Summary
# ==========================================================
# Jumlah Data Awal KCE CC-CL : 661
# Jumlah Data Email dan Phone Kosong : 3
# Jumlah Data Setelah Hapus Email dan Phone Yang Kosong : 658
# Jumlah Lead Test : 0
# Jumlah Setelah Clean Lead Test : 658
# Jumlah Email Karma : 0
# Jumlah Setelah Clean Email Karma : 658
# Jumlah Data Yang Terkena Dedup Member Oddysey : 4
# Jumlah Data Setelah Dedup Member Oddysey : 654
# Jumlah Data Yang Terkena Dedup Past Guest KCE : 53
# Jumlah Data Setelah Dedup Past Guest KCE : 601
# Jumlah Data Yang Duplicate : 2
# Jumlah Data Setelah Hapus Duplicate : 599
# Jumlah Data Akhir : 599
