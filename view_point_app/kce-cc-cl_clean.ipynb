# %%
import pandas as pd
import re

import past_guest_module as pm

import sys
sys.path.append('../zoho_data_app/')

import main_module as m

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
cols = ['Account ID', 'FirstName', 'lastname', 'Country', 'Email', 'Phone',
       'AcStatus', 'Servicing Office','KarmaClubProgram']

# %%
path = r'C:\Users\fajar\Documents\Python\Data\KCC cc-cl\2024\Aug\18 Aug - 26 Aug\KCE CC CL 18 Aug - 26 Aug.xlsx'
df_kce = pd.read_excel(path, dtype='string', sheet_name='Sheet1', usecols=cols)
count_data_awal = df_kce.shape[0]
df_kce
# Out:
#     Account ID           FirstName   lastname    Country  \
# 0      1198511                Adam     Ouarak  Australia
# 1      1199505               David     Strade  Australia
# 2      1199506            Mohammad      Ridha  Australia
# 3      1198812              Andrew     Bertei  Australia
# 4      1199500                Luis  Longhares  Australia
# ..         ...                 ...        ...        ...
# 813    1199188              Rhonda     Thomas       <NA>
# 814    1199201             Koushik      Chava       <NA>
# 815    1198802             Shantel      Jones       <NA>
# 816    1199198                 Son     Nguyen       <NA>
# 817    1199551  Veeravelli Sumanth      Reddy       <NA>
#
#                             Email         Phone AcStatus     Servicing Office  \
# 0           adamouarak1@gmail.com   61414494286   ACTIVE   KC EXPERIENCE Bali
# 1        admin@dtsplumbing.com.au   61409017519   ACTIVE   KC EXPERIENCE Bali
# 2         amaelzant2005@gmail.com   61420483039   ACTIVE   KC EXPERIENCE Bali
# 3              aplegg46@gmail.com   61421369712   ACTIVE   KC EXPERIENCE Bali
# 4           arusharmini@gmail.com   61402130753   ACTIVE   KC EXPERIENCE Bali
# ..                            ...           ...      ...                  ...
# 813      aviaskincare@outlook.com   19412748576   ACTIVE   KC EXPERIENCE Bali
# 814          koushikch2@gmail.com   18636676994   ACTIVE   KC EXPERIENCE Bali
# 815         shudggins85@yahoo.com   13232368496   ACTIVE   KC EXPERIENCE Bali
# 816          soncynkily@gmail.com   18048982163   ACTIVE   KC EXPERIENCE Bali
# 817  sumanth.veeravelli@gmail.com  919550355846   ACTIVE  KC EXPERIENCE India
#
#           KarmaClubProgram
# 0    Petitenget Sales Deck
# 1    Petitenget Sales Deck
# 2    Petitenget Sales Deck
# 3       Vietnam Sales Deck
# 4      Jimbaran Sales Deck
# ..                     ...
# 813     Vietnam Sales Deck
# 814    Jimbaran Sales Deck
# 815  Petitenget Sales Deck
# 816    Jimbaran Sales Deck
# 817              South Goa
#
# [818 rows x 9 columns]

# %%
df_kce.columns
# Out:
# Index(['Account ID', 'FirstName', 'lastname', 'Country', 'Email', 'Phone',
#        'AcStatus', 'Servicing Office', 'KarmaClubProgram'],
#       dtype='object')

# %%
df_kce.rename(columns = {
    'Account ID':'number', 
    'AcStatus':'Account Status',
    'KarmaClubProgram':'Karma Club Program',
    }, inplace = True)

# %%
df_kce.fillna('empty', inplace=True)

# %%
path = r'G:\.shortcut-targets-by-id\0B_d3smBjzo04UUNBME5GOVhoMjA\_ODYSSEY\Phone Members.xlsx'
df_phone_member_odd = pd.read_excel(path, dtype='string', sheet_name='Sheet1')

path = r'G:\.shortcut-targets-by-id\0B_d3smBjzo04UUNBME5GOVhoMjA\_ODYSSEY\Email Members.xlsx'
df_email_member_odd = pd.read_excel(path, dtype='string', sheet_name='Sheet1')

path = r'G:\.shortcut-targets-by-id\0B_d3smBjzo04UUNBME5GOVhoMjA\_ODYSSEY\KCE Members.xlsx'
df_phone_member_kce = pd.read_excel(path, dtype='string', sheet_name='Phone')

path = r'G:\.shortcut-targets-by-id\0B_d3smBjzo04UUNBME5GOVhoMjA\_ODYSSEY\KCE Members.xlsx'
df_email_member_kce = pd.read_excel(path, dtype='string', sheet_name='Email')

# %%
m.clean_number(df_kce, 'Phone')
m.replace_not_valid_to_empty(df_kce, 'Phone')
df_kce['Email'] = m.lowercase(df_kce, 'Email')
m.clean_space(df_kce, 'Email')

m.clean_number(df_phone_member_odd, 'Mobile')
df_email_member_odd['Email'] = m.lowercase(df_email_member_odd, 'Email')
m.clean_space(df_email_member_odd, 'Email')

m.clean_number(df_phone_member_kce, 'Phone')
df_email_member_kce['Email'] = m.lowercase(df_email_member_kce, 'Email')
m.clean_space(df_email_member_kce, 'Email')
# Out:
# 0          aameercok@gmail.com.com
# 1              imerwan@hotmail.com
# 2              mkptech15@gmail.com
# 3        sovitmittal2000@yahoo.com
# 4          smritidas1431@gmail.com
#                    ...
# 84910     erica.green822@gmail.com
# 84911       cmgonnella@outlook.com
# 84912       robert_duyen@yahoo.com
# 84913             kobez8@yahoo.com
# 84914         ruairilamb@gmail.com
# Name: Email, Length: 84915, dtype: string

# %%
pm.email_correction(df_kce, 'Email')
df_kce
# Out:
#       number           FirstName   lastname    Country  \
# 0    1198511                Adam     Ouarak  Australia
# 1    1199505               David     Strade  Australia
# 2    1199506            Mohammad      Ridha  Australia
# 3    1198812              Andrew     Bertei  Australia
# 4    1199500                Luis  Longhares  Australia
# ..       ...                 ...        ...        ...
# 813  1199188              Rhonda     Thomas      empty
# 814  1199201             Koushik      Chava      empty
# 815  1198802             Shantel      Jones      empty
# 816  1199198                 Son     Nguyen      empty
# 817  1199551  Veeravelli Sumanth      Reddy      empty
#
#                             Email         Phone Account Status  \
# 0           adamouarak1@gmail.com   61414494286         ACTIVE
# 1        admin@dtsplumbing.com.au   61409017519         ACTIVE
# 2         amaelzant2005@gmail.com   61420483039         ACTIVE
# 3              aplegg46@gmail.com   61421369712         ACTIVE
# 4           arusharmini@gmail.com   61402130753         ACTIVE
# ..                            ...           ...            ...
# 813      aviaskincare@outlook.com   19412748576         ACTIVE
# 814          koushikch2@gmail.com   18636676994         ACTIVE
# 815         shudggins85@yahoo.com   13232368496         ACTIVE
# 816          soncynkily@gmail.com   18048982163         ACTIVE
# 817  sumanth.veeravelli@gmail.com  919550355846         ACTIVE
#
#         Servicing Office     Karma Club Program
# 0     KC EXPERIENCE Bali  Petitenget Sales Deck
# 1     KC EXPERIENCE Bali  Petitenget Sales Deck
# 2     KC EXPERIENCE Bali  Petitenget Sales Deck
# 3     KC EXPERIENCE Bali     Vietnam Sales Deck
# 4     KC EXPERIENCE Bali    Jimbaran Sales Deck
# ..                   ...                    ...
# 813   KC EXPERIENCE Bali     Vietnam Sales Deck
# 814   KC EXPERIENCE Bali    Jimbaran Sales Deck
# 815   KC EXPERIENCE Bali  Petitenget Sales Deck
# 816   KC EXPERIENCE Bali    Jimbaran Sales Deck
# 817  KC EXPERIENCE India              South Goa
#
# [818 rows x 9 columns]

# %%
count_email_phone_empty = df_kce.loc[(df_kce['Email'] == 'empty') & (df_kce['Phone'] == 'empty')].shape[0]

df_kce.loc[(df_kce['Email'] == 'empty') & (df_kce['Phone'] == 'empty')].to_csv(r'C:\Users\fajar\Documents\Python\Data\cek_email_phone_empty_kce.csv', index=False)

df_kce.drop(df_kce.loc[(df_kce['Email'] == 'empty') & (df_kce['Phone'] == 'empty')].index, inplace=True)
df_kce.reset_index(drop=True, inplace=True)

count_after_email_phone_empty = df_kce.shape[0]

# %%
# Cek leads test
test_leads = df_kce.loc[
    
        df_kce['Email'].str.contains('^test@', flags=re.I, regex=True) |
        df_kce['Email'].str.contains('\+test', flags=re.I, regex=True) |
    
        df_kce['FirstName'].str.contains('^test$', flags=re.I, regex=True) |
        df_kce['lastname'].str.contains('^test$', flags=re.I, regex=True) |

        df_kce['FirstName'].str.contains('test 1', flags=re.I, regex=True) |
        df_kce['lastname'].str.contains('test 2', flags=re.I, regex=True)|
        df_kce['FirstName'].str.contains('test1', flags=re.I, regex=True) |
        df_kce['lastname'].str.contains('test2', flags=re.I, regex=True)|

        df_kce['FirstName'].str.contains(' test ', flags=re.I, regex=True) | 
        df_kce['lastname'].str.contains(' test ', flags=re.I, regex=True) | 
        df_kce['lastname'].str.contains(' test$', flags=re.I, regex=True)
    
    
    ]

count_leads_test = test_leads.shape[0]

test_leads.to_excel(r'C:\Users\fajar\Documents\Python\Data\test_leads.xlsx', index=False)
test_leads
# Out:
# Empty DataFrame
# Columns: [number, FirstName, lastname, Country, Email, Phone, Account Status, Servicing Office, Karma Club Program]
# Index: []

# %%
df_kce.drop(test_leads.index, inplace=True)
df_kce.reset_index(drop=True, inplace=True)

count_after_dedup_test = df_kce.shape[0]

# %%
# Cek Email Karma
email_karma = m.find_karma(df_kce, 'Email')
count_email_karma = email_karma.shape[0]
# email_OTA.to_excel(r'C:\Users\fajar\Documents\Python\Data\email_OTA.xlsx', index=False)

email_karma
# Out:
# Empty DataFrame
# Columns: [number, FirstName, lastname, Country, Email, Phone, Account Status, Servicing Office, Karma Club Program]
# Index: []

# %%
# delete email Karma
count_after_clean_karma = m.delete_karma(df_kce, 'Email')
# zoho_df.to_excel(r'C:\Users\fajar\Documents\Python\Data\after_clean_OTA.xlsx', index=False)

df_kce
# Out:
#       number           FirstName   lastname    Country  \
# 0    1198511                Adam     Ouarak  Australia
# 1    1199505               David     Strade  Australia
# 2    1199506            Mohammad      Ridha  Australia
# 3    1198812              Andrew     Bertei  Australia
# 4    1199500                Luis  Longhares  Australia
# ..       ...                 ...        ...        ...
# 811  1199188              Rhonda     Thomas      empty
# 812  1199201             Koushik      Chava      empty
# 813  1198802             Shantel      Jones      empty
# 814  1199198                 Son     Nguyen      empty
# 815  1199551  Veeravelli Sumanth      Reddy      empty
#
#                             Email         Phone Account Status  \
# 0           adamouarak1@gmail.com   61414494286         ACTIVE
# 1        admin@dtsplumbing.com.au   61409017519         ACTIVE
# 2         amaelzant2005@gmail.com   61420483039         ACTIVE
# 3              aplegg46@gmail.com   61421369712         ACTIVE
# 4           arusharmini@gmail.com   61402130753         ACTIVE
# ..                            ...           ...            ...
# 811      aviaskincare@outlook.com   19412748576         ACTIVE
# 812          koushikch2@gmail.com   18636676994         ACTIVE
# 813         shudggins85@yahoo.com   13232368496         ACTIVE
# 814          soncynkily@gmail.com   18048982163         ACTIVE
# 815  sumanth.veeravelli@gmail.com  919550355846         ACTIVE
#
#         Servicing Office     Karma Club Program
# 0     KC EXPERIENCE Bali  Petitenget Sales Deck
# 1     KC EXPERIENCE Bali  Petitenget Sales Deck
# 2     KC EXPERIENCE Bali  Petitenget Sales Deck
# 3     KC EXPERIENCE Bali     Vietnam Sales Deck
# 4     KC EXPERIENCE Bali    Jimbaran Sales Deck
# ..                   ...                    ...
# 811   KC EXPERIENCE Bali     Vietnam Sales Deck
# 812   KC EXPERIENCE Bali    Jimbaran Sales Deck
# 813   KC EXPERIENCE Bali  Petitenget Sales Deck
# 814   KC EXPERIENCE Bali    Jimbaran Sales Deck
# 815  KC EXPERIENCE India              South Goa
#
# [816 rows x 9 columns]

# %%
find_member_oddysey = df_kce.copy()

find_member_oddysey.loc[find_member_oddysey['Phone'].isin(df_phone_member_odd['Mobile']), 'Same Value Find'] = 'Member-Mobile' 

find_member_oddysey.loc[find_member_oddysey['Email'].isin(df_email_member_odd['Email']), 'Same Value Find'] = 'Member-Email'
find_member_oddysey.drop(find_member_oddysey.loc[find_member_oddysey['Same Value Find'].isna()].index, inplace=True)

find_member_oddysey.replace('empty', '', inplace=True)

find_member_oddysey.to_csv(r'C:\Users\fajar\Documents\Python\Data\cek_member_odyssey.csv', index=False)

# %%
count_dedup_member_odd = df_kce.loc[
    
    df_kce['Phone'].isin(df_phone_member_odd['Mobile']) | 
    df_kce['Email'].isin(df_email_member_odd['Email'])
].shape[0]

df_kce.loc[
    
    df_kce['Phone'].isin(df_phone_member_odd['Mobile']) | 
    df_kce['Email'].isin(df_email_member_odd['Email'])
]
# Out:
#       number           FirstName  lastname  Country                 Email  \
# 145  1199528               Vijay  Lakhesar  England        vlkhsr@aol.com
# 338  1199208  Imran Rasheed Syed         .    India  imrankkl39@gmail.com
#
#             Phone Account Status     Servicing Office   Karma Club Program
# 145  447801654333         ACTIVE   KC EXPERIENCE Bali  Jimbaran Sales Deck
# 338  919740243636         ACTIVE  KC EXPERIENCE India            North Goa

# %%
df_kce.drop(df_kce.loc[
    
    df_kce['Phone'].isin(df_phone_member_odd['Mobile']) | 
    df_kce['Email'].isin(df_email_member_odd['Email'])
].index, inplace=True)

df_kce.reset_index(drop=True, inplace=True)

count_after_dedup_member_odd = df_kce.shape[0]
df_kce
# Out:
#       number           FirstName   lastname    Country  \
# 0    1198511                Adam     Ouarak  Australia
# 1    1199505               David     Strade  Australia
# 2    1199506            Mohammad      Ridha  Australia
# 3    1198812              Andrew     Bertei  Australia
# 4    1199500                Luis  Longhares  Australia
# ..       ...                 ...        ...        ...
# 809  1199188              Rhonda     Thomas      empty
# 810  1199201             Koushik      Chava      empty
# 811  1198802             Shantel      Jones      empty
# 812  1199198                 Son     Nguyen      empty
# 813  1199551  Veeravelli Sumanth      Reddy      empty
#
#                             Email         Phone Account Status  \
# 0           adamouarak1@gmail.com   61414494286         ACTIVE
# 1        admin@dtsplumbing.com.au   61409017519         ACTIVE
# 2         amaelzant2005@gmail.com   61420483039         ACTIVE
# 3              aplegg46@gmail.com   61421369712         ACTIVE
# 4           arusharmini@gmail.com   61402130753         ACTIVE
# ..                            ...           ...            ...
# 809      aviaskincare@outlook.com   19412748576         ACTIVE
# 810          koushikch2@gmail.com   18636676994         ACTIVE
# 811         shudggins85@yahoo.com   13232368496         ACTIVE
# 812          soncynkily@gmail.com   18048982163         ACTIVE
# 813  sumanth.veeravelli@gmail.com  919550355846         ACTIVE
#
#         Servicing Office     Karma Club Program
# 0     KC EXPERIENCE Bali  Petitenget Sales Deck
# 1     KC EXPERIENCE Bali  Petitenget Sales Deck
# 2     KC EXPERIENCE Bali  Petitenget Sales Deck
# 3     KC EXPERIENCE Bali     Vietnam Sales Deck
# 4     KC EXPERIENCE Bali    Jimbaran Sales Deck
# ..                   ...                    ...
# 809   KC EXPERIENCE Bali     Vietnam Sales Deck
# 810   KC EXPERIENCE Bali    Jimbaran Sales Deck
# 811   KC EXPERIENCE Bali  Petitenget Sales Deck
# 812   KC EXPERIENCE Bali    Jimbaran Sales Deck
# 813  KC EXPERIENCE India              South Goa
#
# [814 rows x 9 columns]

# %%
find_member_kce = df_kce.copy()

find_member_kce.loc[find_member_kce['Phone'].isin(df_phone_member_kce['Phone']), 'Same Value Find'] = 'Member-KCE-Mobile' 

find_member_kce.loc[find_member_kce['Email'].isin(df_email_member_kce['Email']), 'Same Value Find'] = 'Member-KCE-Email'
find_member_kce.drop(find_member_kce.loc[find_member_kce['Same Value Find'].isna()].index, inplace=True)

find_member_kce.replace('empty', '', inplace=True)

find_member_kce.to_csv(r'C:\Users\fajar\Documents\Python\Data\cek_member_kce.csv', index=False)

# %%
count_dedup_member_kce = df_kce.loc[
    
    df_kce['Phone'].isin(df_phone_member_kce['Phone']) | 
    df_kce['Email'].isin(df_email_member_kce['Email'])

].shape[0]

df_kce.loc[
    
    df_kce['Phone'].isin(df_phone_member_kce['Phone']) | 
    df_kce['Email'].isin(df_email_member_kce['Email'])
]
# Out:
#       number   FirstName   lastname      Country  \
# 0    1198511        Adam     Ouarak    Australia
# 5    1198452        RORI    MATAORA    Australia
# 7    1198451      Albert      Barna    Australia
# 18   1198475  Simbarashe   Samuriwo    Australia
# 21   1198473        Dean      Ewens    Australia
# ..       ...         ...        ...          ...
# 722  1198662       Nirar  Kauthekar        India
# 723  1198665       Nirar  Christran        India
# 724  1198668     Prakash   Mangtani        India
# 769  1198460     Matthew   Brownlie  New Zealand
# 774  1198444      Faisal       Alam     Pakistan
#
#                             Email         Phone Account Status  \
# 0           adamouarak1@gmail.com   61414494286         ACTIVE
# 5    ashleighjadeleslie@gmail.com   61403698173         ACTIVE
# 7           barnazilla1@gmail.com   61413031639         ACTIVE
# 18         chazsamuriwo@yahoo.com   61410597370         ACTIVE
# 21          clairefarr6@gmail.com   61432740742         ACTIVE
# ..                            ...           ...            ...
# 722                         empty  918960965003         ACTIVE
# 723                         empty  917990909154         ACTIVE
# 724                         empty  919922332424         ACTIVE
# 769         mbrownlie93@gmail.com   61273390193         ACTIVE
# 774      faisal.alam.ku@gmail.com  923002985004         ACTIVE
#
#         Servicing Office     Karma Club Program
# 0     KC EXPERIENCE Bali  Petitenget Sales Deck
# 5     KC EXPERIENCE Bali    Jimbaran Sales Deck
# 7     KC EXPERIENCE Bali    Jimbaran Sales Deck
# 18    KC EXPERIENCE Bali    Jimbaran Sales Deck
# 21    KC EXPERIENCE Bali    Jimbaran Sales Deck
# ..                   ...                    ...
# 722  KC EXPERIENCE India              South Goa
# 723  KC EXPERIENCE India              South Goa
# 724  KC EXPERIENCE India              North Goa
# 769   KC EXPERIENCE Bali  Petitenget Sales Deck
# 774   KC EXPERIENCE Bali  Petitenget Sales Deck
#
# [225 rows x 9 columns]

# %%
df_kce.drop(df_kce.loc[
    
    df_kce['Phone'].isin(df_phone_member_kce['Phone']) | 
    df_kce['Email'].isin(df_email_member_kce['Email'])
].index, inplace=True)

df_kce.reset_index(drop=True, inplace=True)

count_after_dedup_member_kce = df_kce.shape[0]
df_kce
# Out:
#       number           FirstName   lastname    Country  \
# 0    1199505               David     Strade  Australia
# 1    1199506            Mohammad      Ridha  Australia
# 2    1198812              Andrew     Bertei  Australia
# 3    1199500                Luis  Longhares  Australia
# 4    1199499               Harry     Maurey  Australia
# ..       ...                 ...        ...        ...
# 584  1199188              Rhonda     Thomas      empty
# 585  1199201             Koushik      Chava      empty
# 586  1198802             Shantel      Jones      empty
# 587  1199198                 Son     Nguyen      empty
# 588  1199551  Veeravelli Sumanth      Reddy      empty
#
#                             Email         Phone Account Status  \
# 0        admin@dtsplumbing.com.au   61409017519         ACTIVE
# 1         amaelzant2005@gmail.com   61420483039         ACTIVE
# 2              aplegg46@gmail.com   61421369712         ACTIVE
# 3           arusharmini@gmail.com   61402130753         ACTIVE
# 4        barlenmaurey@hotmail.com   61412427001         ACTIVE
# ..                            ...           ...            ...
# 584      aviaskincare@outlook.com   19412748576         ACTIVE
# 585          koushikch2@gmail.com   18636676994         ACTIVE
# 586         shudggins85@yahoo.com   13232368496         ACTIVE
# 587          soncynkily@gmail.com   18048982163         ACTIVE
# 588  sumanth.veeravelli@gmail.com  919550355846         ACTIVE
#
#         Servicing Office     Karma Club Program
# 0     KC EXPERIENCE Bali  Petitenget Sales Deck
# 1     KC EXPERIENCE Bali  Petitenget Sales Deck
# 2     KC EXPERIENCE Bali     Vietnam Sales Deck
# 3     KC EXPERIENCE Bali    Jimbaran Sales Deck
# 4     KC EXPERIENCE Bali    Jimbaran Sales Deck
# ..                   ...                    ...
# 584   KC EXPERIENCE Bali     Vietnam Sales Deck
# 585   KC EXPERIENCE Bali    Jimbaran Sales Deck
# 586   KC EXPERIENCE Bali  Petitenget Sales Deck
# 587   KC EXPERIENCE Bali    Jimbaran Sales Deck
# 588  KC EXPERIENCE India              South Goa
#
# [589 rows x 9 columns]

# %%
# hitung jumlah duplicate
count_duplicate_general = df_kce.loc[df_kce.duplicated(subset=['Email','Phone'])].shape[0]

df_kce.loc[df_kce.duplicated(subset=['Email','Phone'])]
# Out:
#       number   FirstName lastname Country                    Email  \
# 248  1199280  MANJUNATHA       HN   India      hnmanju91@gmail.com
# 379  1197789       RAMAN     GOEL   India  raman_einfo@yahoo.co.in
#
#             Phone Account Status     Servicing Office Karma Club Program
# 248  919739664705         ACTIVE  KC EXPERIENCE India              empty
# 379  919990634264         ACTIVE  KC EXPERIENCE India              empty

# %%
df_kce.drop_duplicates(subset=['Email','Phone'], inplace=True)
df_kce.reset_index(drop=True, inplace=True)

# hitung jumlah setelah value duplicate dihapus
count_after_dedup_duplicate = df_kce.shape[0]

df_kce
# Out:
#       number           FirstName   lastname    Country  \
# 0    1199505               David     Strade  Australia
# 1    1199506            Mohammad      Ridha  Australia
# 2    1198812              Andrew     Bertei  Australia
# 3    1199500                Luis  Longhares  Australia
# 4    1199499               Harry     Maurey  Australia
# ..       ...                 ...        ...        ...
# 582  1199188              Rhonda     Thomas      empty
# 583  1199201             Koushik      Chava      empty
# 584  1198802             Shantel      Jones      empty
# 585  1199198                 Son     Nguyen      empty
# 586  1199551  Veeravelli Sumanth      Reddy      empty
#
#                             Email         Phone Account Status  \
# 0        admin@dtsplumbing.com.au   61409017519         ACTIVE
# 1         amaelzant2005@gmail.com   61420483039         ACTIVE
# 2              aplegg46@gmail.com   61421369712         ACTIVE
# 3           arusharmini@gmail.com   61402130753         ACTIVE
# 4        barlenmaurey@hotmail.com   61412427001         ACTIVE
# ..                            ...           ...            ...
# 582      aviaskincare@outlook.com   19412748576         ACTIVE
# 583          koushikch2@gmail.com   18636676994         ACTIVE
# 584         shudggins85@yahoo.com   13232368496         ACTIVE
# 585          soncynkily@gmail.com   18048982163         ACTIVE
# 586  sumanth.veeravelli@gmail.com  919550355846         ACTIVE
#
#         Servicing Office     Karma Club Program
# 0     KC EXPERIENCE Bali  Petitenget Sales Deck
# 1     KC EXPERIENCE Bali  Petitenget Sales Deck
# 2     KC EXPERIENCE Bali     Vietnam Sales Deck
# 3     KC EXPERIENCE Bali    Jimbaran Sales Deck
# 4     KC EXPERIENCE Bali    Jimbaran Sales Deck
# ..                   ...                    ...
# 582   KC EXPERIENCE Bali     Vietnam Sales Deck
# 583   KC EXPERIENCE Bali    Jimbaran Sales Deck
# 584   KC EXPERIENCE Bali  Petitenget Sales Deck
# 585   KC EXPERIENCE Bali    Jimbaran Sales Deck
# 586  KC EXPERIENCE India              South Goa
#
# [587 rows x 9 columns]

# %%
list_UK_EU = pm.get_list_UK_EU()
list_Others = pm.get_list_Others()

# %%
df_kce.loc[df_kce['Country'].isin(list_Others)]
# Out:
#       number       FirstName        lastname               Country  \
# 0    1199505           David          Strade             Australia
# 1    1199506        Mohammad           Ridha             Australia
# 2    1198812          Andrew          Bertei             Australia
# 3    1199500            Luis       Longhares             Australia
# 4    1199499           Harry          Maurey             Australia
# ..       ...             ...             ...                   ...
# 554  1198817    Abdul Rahman  Mohamed Yussvf             Singapore
# 555  1198815        Abhilash       Venkatesh             Singapore
# 556  1199524  MOHAMED ZAFFER    Mohamed Raza             Sri Lanka
# 558  1199522          Zaheer      Ahmedabadi  United Arab Emirates
# 581  1199190    Neeraj Reddy          Seelam                   USA
#
#                         Email         Phone Account Status  \
# 0    admin@dtsplumbing.com.au   61409017519         ACTIVE
# 1     amaelzant2005@gmail.com   61420483039         ACTIVE
# 2          aplegg46@gmail.com   61421369712         ACTIVE
# 3       arusharmini@gmail.com   61402130753         ACTIVE
# 4    barlenmaurey@hotmail.com   61412427001         ACTIVE
# ..                        ...           ...            ...
# 554       abdul78sg@gmail.com    6597209614         ACTIVE
# 555  abhilashothers@gmail.com    6596950535         ACTIVE
# 556    razazaffer07@gmail.com   94777717655         ACTIVE
# 558  zaheerkhan1982@gmail.com  971528787080         ACTIVE
# 581   neerajreddy11@gmail.com   15109447709         ACTIVE
#
#        Servicing Office     Karma Club Program
# 0    KC EXPERIENCE Bali  Petitenget Sales Deck
# 1    KC EXPERIENCE Bali  Petitenget Sales Deck
# 2    KC EXPERIENCE Bali     Vietnam Sales Deck
# 3    KC EXPERIENCE Bali    Jimbaran Sales Deck
# 4    KC EXPERIENCE Bali    Jimbaran Sales Deck
# ..                  ...                    ...
# 554  KC EXPERIENCE Bali     Vietnam Sales Deck
# 555  KC EXPERIENCE Bali     Vietnam Sales Deck
# 556  KC EXPERIENCE Bali    Jimbaran Sales Deck
# 558  KC EXPERIENCE Bali    Jimbaran Sales Deck
# 581  KC EXPERIENCE Bali     Vietnam Sales Deck
#
# [130 rows x 9 columns]

# %%
df_kce.loc[df_kce['Country'].str.contains('India'), 'Area'] = 'India'
df_kce.loc[df_kce['Country'].isin(list_UK_EU), 'Area'] = 'UK EU'
df_kce.loc[df_kce['Country'].isin(list_Others), 'Area'] = 'Others'

# %%
df_kce.loc[df_kce['Area'] == 'India', 'Batch'] = 'INDIA'
df_kce.loc[df_kce['Area'] == 'UK EU', 'Batch'] = 'NONINDIA'
df_kce.loc[df_kce['Area'] == 'Others', 'Batch'] = 'NONINDIA'

# %%
df_kce.replace('empty', '', inplace=True)

# %%
df_kce.columns
# Out:
# Index(['number', 'FirstName', 'lastname', 'Country', 'Email', 'Phone',
#        'Account Status', 'Servicing Office', 'Karma Club Program', 'Area',
#        'Batch'],
#       dtype='object')

# %%
new_cols = ['number', 'FirstName', 'lastname', 'Country', 'Area', 'Batch', 'Email', 'Phone',
       'Account Status', 'Servicing Office', 'Karma Club Program']

df_kce = df_kce.reindex(columns=new_cols)

# %%
count_data_akhir = df_kce.shape[0]

df_kce.to_csv(r'C:\Users\fajar\Documents\Python\Data\final_kce.csv', index=False)

# %%
print("==========================================================")
print("Summary")
print("==========================================================")
print("Jumlah Data Awal KCE CC-CL : "+str(count_data_awal))
print("Jumlah Data Email dan Phone Kosong : "+str(count_email_phone_empty))
print("Jumlah Data Setelah Hapus Email dan Phone Yang Kosong : "+str(count_after_email_phone_empty))
print("Jumlah Lead Test : "+str(count_leads_test))
print("Jumlah Setelah Clean Lead Test : "+str(count_after_dedup_test))
print("Jumlah Email Karma : "+str(count_email_karma))
print("Jumlah Setelah Clean Email Karma : "+str(count_after_clean_karma))
print("Jumlah Data Yang Terkena Dedup Member Oddysey : "+str(count_dedup_member_odd))
print("Jumlah Data Setelah Dedup Member Oddysey : "+str(count_after_dedup_member_odd))
print("Jumlah Data Yang Terkena Dedup Past Guest KCE : "+str(count_dedup_member_kce))
print("Jumlah Data Setelah Dedup Past Guest KCE : "+str(count_after_dedup_member_kce))
print("Jumlah Data Yang Duplicate : "+str(count_duplicate_general))
print("Jumlah Data Setelah Hapus Duplicate : "+str(count_after_dedup_duplicate))
print("Jumlah Data Akhir : "+str(count_data_akhir))
# Out:
# ==========================================================
# Summary
# ==========================================================
# Jumlah Data Awal KCE CC-CL : 818
# Jumlah Data Email dan Phone Kosong : 2
# Jumlah Data Setelah Hapus Email dan Phone Yang Kosong : 816
# Jumlah Lead Test : 0
# Jumlah Setelah Clean Lead Test : 816
# Jumlah Email Karma : 0
# Jumlah Setelah Clean Email Karma : 816
# Jumlah Data Yang Terkena Dedup Member Oddysey : 2
# Jumlah Data Setelah Dedup Member Oddysey : 814
# Jumlah Data Yang Terkena Dedup Past Guest KCE : 225
# Jumlah Data Setelah Dedup Past Guest KCE : 589
# Jumlah Data Yang Duplicate : 2
# Jumlah Data Setelah Hapus Duplicate : 587
# Jumlah Data Akhir : 587
