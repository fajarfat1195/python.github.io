# %%
import pandas as pd
import re

import past_guest_module as pm

import sys
sys.path.append('../zoho_data_app/')

import main_module as m

# %load_ext autoreload
# %autoreload 2

# %%
cols = ['Account ID', 'FirstName', 'lastname', 'Country', 'Email', 'Phone',
       'AcStatus', 'Servicing Office','KarmaClubProgram']

# %%
path = r'C:\Users\fajar\Documents\Python\Data\KCC cc-cl\2024\Sep\8 Sep - 13 Sep\KCE CC CL 8 Sep - 13 Sep.xlsx'
df_kce = pd.read_excel(path, dtype='string', sheet_name='Sheet1', usecols=cols)
count_data_awal = df_kce.shape[0]
df_kce
# Out:
#     Account ID    FirstName      lastname      Country  \
# 0      1202089  Shafiqullah         Raiey  Afghanistan
# 1      1201352        Aghil         Igder    Australia
# 2      1200931        Aaron          Mete    Australia
# 3      1202008       Adrian        Mooney    Australia
# 4      1202121      Abhiraj         Singh    Australia
# ..         ...          ...           ...          ...
# 875    1201745        David         Oneil         <NA>
# 876    1201372       Edward         Moody         <NA>
# 877    1201005        Navin  Pari Parwani         <NA>
# 878    1202094       Tauhir         Jones         <NA>
# 879    1201150       Rodney      Yacinthe         <NA>
#
#                          Email         Phone AcStatus     Servicing Office  \
# 0                         <NA>  919370957037   ACTIVE  KC EXPERIENCE India
# 1          a.igder21@gmail.com   61406691590   ACTIVE   KC EXPERIENCE Bali
# 2          aaronmete@gmail.com   61418523131   ACTIVE   KC EXPERIENCE Bali
# 3         abeckley82@gmail.com   61421917668   ACTIVE   KC EXPERIENCE Bali
# 4    abhiraj.singh.15@live.com   61430374661   ACTIVE   KC EXPERIENCE Bali
# ..                         ...           ...      ...                  ...
# 875           herblif1@aol.com   16173652642   ACTIVE   KC EXPERIENCE Bali
# 876           moodysix@aol.com   19493836752   ACTIVE   KC EXPERIENCE Bali
# 877        nicky@londonrag.com   85261329354   ACTIVE   KC EXPERIENCE Bali
# 878     tauhir.jones@gmail.com   13122860573   ACTIVE   KC EXPERIENCE Bali
# 879     yacinthe1112@yahoo.com   13474377826   ACTIVE   KC EXPERIENCE Bali
#
#           KarmaClubProgram
# 0             Karma Utopia
# 1      Jimbaran Sales Deck
# 2    Petitenget Sales Deck
# 3       Vietnam Sales Deck
# 4    Petitenget Sales Deck
# ..                     ...
# 875  Petitenget Sales Deck
# 876    Jimbaran Sales Deck
# 877    Jimbaran Sales Deck
# 878    Jimbaran Sales Deck
# 879  Petitenget Sales Deck
#
# [880 rows x 9 columns]

# %%
df_kce.columns
# Out:
# Index(['Account ID', 'FirstName', 'lastname', 'Country', 'Email', 'Phone',
#        'AcStatus', 'Servicing Office', 'KarmaClubProgram'],
#       dtype='object')

# %%
df_kce.rename(columns = {
    'Account ID':'number', 
    'AcStatus':'Account Status',
    'KarmaClubProgram':'Karma Club Program',
    }, inplace = True)

# %%
df_kce.fillna('empty', inplace=True)

# %%
path = r'G:\.shortcut-targets-by-id\0B_d3smBjzo04UUNBME5GOVhoMjA\_ODYSSEY\Phone Members.xlsx'
df_phone_member_odd = pd.read_excel(path, dtype='string', sheet_name='Sheet1')

path = r'G:\.shortcut-targets-by-id\0B_d3smBjzo04UUNBME5GOVhoMjA\_ODYSSEY\Email Members.xlsx'
df_email_member_odd = pd.read_excel(path, dtype='string', sheet_name='Sheet1')

path = r'G:\.shortcut-targets-by-id\0B_d3smBjzo04UUNBME5GOVhoMjA\_ODYSSEY\KCE Members.xlsx'
df_phone_member_kce = pd.read_excel(path, dtype='string', sheet_name='Phone')

path = r'G:\.shortcut-targets-by-id\0B_d3smBjzo04UUNBME5GOVhoMjA\_ODYSSEY\KCE Members.xlsx'
df_email_member_kce = pd.read_excel(path, dtype='string', sheet_name='Email')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [7], line 2
#       1 path = r'G:\.shortcut-targets-by-id\0B_d3smBjzo04UUNBME5GOVhoMjA\_ODYSSEY\Phone Members.xlsx'
# ----> 2 df_phone_member_odd = pd.read_excel(path, dtype='string', sheet_name='Sheet1')
#       4 path = r'G:\.shortcut-targets-by-id\0B_d3smBjzo04UUNBME5GOVhoMjA\_ODYSSEY\Email Members.xlsx'
#       5 df_email_member_odd = pd.read_excel(path, dtype='string', sheet_name='Sheet1')
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\util\_decorators.py:317, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     311 if len(args) > num_allow_args:
#     312     warnings.warn(
#     313         msg.format(arguments=arguments),
#     314         FutureWarning,
#     315         stacklevel=find_stack_level(inspect.currentframe()),
#     316     )
# --> 317 return func(*args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\io\excel\_base.py:491, in read_excel(io, sheet_name, header, names, index_col, usecols, squeeze, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, thousands, decimal, comment, skipfooter, convert_float, mangle_dupe_cols, storage_options)
#     485     raise ValueError(
#     486         "Engine should not be specified when passing "
#     487         "an ExcelFile - ExcelFile already has the engine set"
#     488     )
#     490 try:
# --> 491     data = io.parse(
#     492         sheet_name=sheet_name,
#     493         header=header,
#     494         names=names,
#     495         index_col=index_col,
#     496         usecols=usecols,
#     497         squeeze=squeeze,
#     498         dtype=dtype,
#     499         converters=converters,
#     500         true_values=true_values,
#     501         false_values=false_values,
#     502         skiprows=skiprows,
#     503         nrows=nrows,
#     504         na_values=na_values,
#     505         keep_default_na=keep_default_na,
#     506         na_filter=na_filter,
#     507         verbose=verbose,
#     508         parse_dates=parse_dates,
#     509         date_parser=date_parser,
#     510         thousands=thousands,
#     511         decimal=decimal,
#     512         comment=comment,
#     513         skipfooter=skipfooter,
#     514         convert_float=convert_float,
#     515         mangle_dupe_cols=mangle_dupe_cols,
#     516     )
#     517 finally:
#     518     # make sure to close opened file handles
#     519     if should_close:
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\io\excel\_base.py:1711, in ExcelFile.parse(self, sheet_name, header, names, index_col, usecols, squeeze, converters, true_values, false_values, skiprows, nrows, na_values, parse_dates, date_parser, thousands, comment, skipfooter, convert_float, mangle_dupe_cols, **kwds)
#    1677 def parse(
#    1678     self,
#    1679     sheet_name: str | int | list[int] | list[str] | None = 0,
#    (...)
#    1698     **kwds,
#    1699 ) -> DataFrame | dict[str, DataFrame] | dict[int, DataFrame]:
#    1700     """
#    1701     Parse specified sheet(s) into a DataFrame.
#    1702
#    (...)
#    1709         DataFrame from the passed in Excel file.
#    1710     """
# -> 1711     return self._reader.parse(
#    1712         sheet_name=sheet_name,
#    1713         header=header,
#    1714         names=names,
#    1715         index_col=index_col,
#    1716         usecols=usecols,
#    1717         squeeze=squeeze,
#    1718         converters=converters,
#    1719         true_values=true_values,
#    1720         false_values=false_values,
#    1721         skiprows=skiprows,
#    1722         nrows=nrows,
#    1723         na_values=na_values,
#    1724         parse_dates=parse_dates,
#    1725         date_parser=date_parser,
#    1726         thousands=thousands,
#    1727         comment=comment,
#    1728         skipfooter=skipfooter,
#    1729         convert_float=convert_float,
#    1730         mangle_dupe_cols=mangle_dupe_cols,
#    1731         **kwds,
#    1732     )
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\io\excel\_base.py:766, in BaseExcelReader.parse(self, sheet_name, header, names, index_col, usecols, squeeze, dtype, true_values, false_values, skiprows, nrows, na_values, verbose, parse_dates, date_parser, thousands, decimal, comment, skipfooter, convert_float, mangle_dupe_cols, **kwds)
#     763     sheet = self.get_sheet_by_index(asheetname)
#     765 file_rows_needed = self._calc_rows(header, index_col, skiprows, nrows)
# --> 766 data = self.get_sheet_data(sheet, convert_float, file_rows_needed)
#     767 if hasattr(sheet, "close"):
#     768     # pyxlsb opens two TemporaryFiles
#     769     sheet.close()
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\io\excel\_openpyxl.py:607, in OpenpyxlReader.get_sheet_data(self, sheet, convert_float, file_rows_needed)
#     605 data: list[list[Scalar]] = []
#     606 last_row_with_data = -1
# --> 607 for row_number, row in enumerate(sheet.rows):
#     608     converted_row = [self._convert_cell(cell, convert_float) for cell in row]
#     609     while converted_row and converted_row[-1] == "":
#     610         # trim trailing empty elements
#
# File ~\AppData\Roaming\Python\Python310\site-packages\openpyxl\worksheet\_read_only.py:79, in ReadOnlyWorksheet._cells_by_row(self, min_col, min_row, max_col, max_row, values_only)
#      75 src = self._get_source()
#      76 parser = WorkSheetParser(src, self._shared_strings,
#      77                          data_only=self.parent.data_only, epoch=self.parent.epoch,
#      78                          date_formats=self.parent._date_formats)
# ---> 79 for idx, row in parser.parse():
#      80     if max_row is not None and idx > max_row:
#      81         break
#
# File ~\AppData\Roaming\Python\Python310\site-packages\openpyxl\worksheet\_reader.py:144, in WorkSheetParser.parse(self)
#     125 properties = {
#     126     PRINT_TAG: ('print_options', PrintOptions),
#     127     MARGINS_TAG: ('page_margins', PageMargins),
#    (...)
#     139
#     140 }
#     142 it = iterparse(self.source) # add a finaliser to close the source when this becomes possible
# --> 144 for _, element in it:
#     145     tag_name = element.tag
#     146     if tag_name in dispatcher:
#
# File c:\Program Files\Python310\lib\xml\etree\ElementTree.py:1255, in iterparse.<locals>.iterator(source)
#    1253 yield from pullparser.read_events()
#    1254 # load event buffer
# -> 1255 data = source.read(16 * 1024)
#    1256 if not data:
#    1257     break
#
# File c:\Program Files\Python310\lib\zipfile.py:925, in ZipExtFile.read(self, n)
#     923 self._offset = 0
#     924 while n > 0 and not self._eof:
# --> 925     data = self._read1(n)
#     926     if n < len(data):
#     927         self._readbuffer = data
#
# File c:\Program Files\Python310\lib\zipfile.py:1001, in ZipExtFile._read1(self, n)
#     999 elif self._compress_type == ZIP_DEFLATED:
#    1000     n = max(n, self.MIN_READ_SIZE)
# -> 1001     data = self._decompressor.decompress(data, n)
#    1002     self._eof = (self._decompressor.eof or
#    1003                  self._compress_left <= 0 and
#    1004                  not self._decompressor.unconsumed_tail)
#    1005     if self._eof:
#
# KeyboardInterrupt:

# %%
m.clean_number(df_kce, 'Phone')
m.replace_not_valid_to_empty(df_kce, 'Phone')
df_kce['Email'] = m.lowercase(df_kce, 'Email')
m.clean_space(df_kce, 'Email')

m.clean_number(df_phone_member_odd, 'Mobile')
df_email_member_odd['Email'] = m.lowercase(df_email_member_odd, 'Email')
m.clean_space(df_email_member_odd, 'Email')

m.clean_number(df_phone_member_kce, 'Phone')
df_email_member_kce['Email'] = m.lowercase(df_email_member_kce, 'Email')
m.clean_space(df_email_member_kce, 'Email')
# Out:
# 0          aameercok@gmail.com.com
# 1              imerwan@hotmail.com
# 2              mkptech15@gmail.com
# 3        sovitmittal2000@yahoo.com
# 4          smritidas1431@gmail.com
#                    ...
# 86177          juneochoa@yahoo.com
# 86178          nicky@londonrag.com
# 86179    ronniekessner96@yahoo.com
# 86180         shahkalpin@gmail.com
# 86181        virgobrebre@gmail.com
# Name: Email, Length: 86182, dtype: string

# %%
pm.email_correction(df_kce, 'Email')
df_kce
# Out:
#       number    FirstName      lastname      Country  \
# 0    1202089  Shafiqullah         Raiey  Afghanistan
# 1    1201352        Aghil         Igder    Australia
# 2    1200931        Aaron          Mete    Australia
# 3    1202008       Adrian        Mooney    Australia
# 4    1202121      Abhiraj         Singh    Australia
# ..       ...          ...           ...          ...
# 875  1201745        David         Oneil        empty
# 876  1201372       Edward         Moody        empty
# 877  1201005        Navin  Pari Parwani        empty
# 878  1202094       Tauhir         Jones        empty
# 879  1201150       Rodney      Yacinthe        empty
#
#                          Email         Phone Account Status  \
# 0                        empty  919370957037         ACTIVE
# 1          a.igder21@gmail.com   61406691590         ACTIVE
# 2          aaronmete@gmail.com   61418523131         ACTIVE
# 3         abeckley82@gmail.com   61421917668         ACTIVE
# 4    abhiraj.singh.15@live.com   61430374661         ACTIVE
# ..                         ...           ...            ...
# 875           herblif1@aol.com   16173652642         ACTIVE
# 876           moodysix@aol.com   19493836752         ACTIVE
# 877        nicky@londonrag.com   85261329354         ACTIVE
# 878     tauhir.jones@gmail.com   13122860573         ACTIVE
# 879     yacinthe1112@yahoo.com   13474377826         ACTIVE
#
#         Servicing Office     Karma Club Program
# 0    KC EXPERIENCE India           Karma Utopia
# 1     KC EXPERIENCE Bali    Jimbaran Sales Deck
# 2     KC EXPERIENCE Bali  Petitenget Sales Deck
# 3     KC EXPERIENCE Bali     Vietnam Sales Deck
# 4     KC EXPERIENCE Bali  Petitenget Sales Deck
# ..                   ...                    ...
# 875   KC EXPERIENCE Bali  Petitenget Sales Deck
# 876   KC EXPERIENCE Bali    Jimbaran Sales Deck
# 877   KC EXPERIENCE Bali    Jimbaran Sales Deck
# 878   KC EXPERIENCE Bali    Jimbaran Sales Deck
# 879   KC EXPERIENCE Bali  Petitenget Sales Deck
#
# [880 rows x 9 columns]

# %%
count_email_phone_empty = df_kce.loc[(df_kce['Email'] == 'empty') & (df_kce['Phone'] == 'empty')].shape[0]

df_kce.loc[(df_kce['Email'] == 'empty') & (df_kce['Phone'] == 'empty')].to_csv(r'C:\Users\fajar\Documents\Python\Data\cek_email_phone_empty_kce.csv', index=False)

df_kce.drop(df_kce.loc[(df_kce['Email'] == 'empty') & (df_kce['Phone'] == 'empty')].index, inplace=True)
df_kce.reset_index(drop=True, inplace=True)

count_after_email_phone_empty = df_kce.shape[0]

# %%
# Cek leads test
test_leads = df_kce.loc[
    
        df_kce['Email'].str.contains('^test@', flags=re.I, regex=True) |
        df_kce['Email'].str.contains('\+test', flags=re.I, regex=True) |
    
        df_kce['FirstName'].str.contains('^test$', flags=re.I, regex=True) |
        df_kce['lastname'].str.contains('^test$', flags=re.I, regex=True) |

        df_kce['FirstName'].str.contains('test 1', flags=re.I, regex=True) |
        df_kce['lastname'].str.contains('test 2', flags=re.I, regex=True)|
        df_kce['FirstName'].str.contains('test1', flags=re.I, regex=True) |
        df_kce['lastname'].str.contains('test2', flags=re.I, regex=True)|

        df_kce['FirstName'].str.contains(' test ', flags=re.I, regex=True) | 
        df_kce['lastname'].str.contains(' test ', flags=re.I, regex=True) | 
        df_kce['lastname'].str.contains(' test$', flags=re.I, regex=True)
    
    
    ]

count_leads_test = test_leads.shape[0]

test_leads.to_excel(r'C:\Users\fajar\Documents\Python\Data\test_leads.xlsx', index=False)
test_leads
# Out:
# Empty DataFrame
# Columns: [number, FirstName, lastname, Country, Email, Phone, Account Status, Servicing Office, Karma Club Program]
# Index: []

# %%
df_kce.drop(test_leads.index, inplace=True)
df_kce.reset_index(drop=True, inplace=True)

count_after_dedup_test = df_kce.shape[0]

# %%
# Cek Email Karma
email_karma = m.find_karma(df_kce, 'Email')
count_email_karma = email_karma.shape[0]
# email_OTA.to_excel(r'C:\Users\fajar\Documents\Python\Data\email_OTA.xlsx', index=False)

email_karma
# Out:
# Empty DataFrame
# Columns: [number, FirstName, lastname, Country, Email, Phone, Account Status, Servicing Office, Karma Club Program]
# Index: []

# %%
# delete email Karma
count_after_clean_karma = m.delete_karma(df_kce, 'Email')
# zoho_df.to_excel(r'C:\Users\fajar\Documents\Python\Data\after_clean_OTA.xlsx', index=False)

df_kce
# Out:
#       number    FirstName      lastname      Country  \
# 0    1202089  Shafiqullah         Raiey  Afghanistan
# 1    1201352        Aghil         Igder    Australia
# 2    1200931        Aaron          Mete    Australia
# 3    1202008       Adrian        Mooney    Australia
# 4    1202121      Abhiraj         Singh    Australia
# ..       ...          ...           ...          ...
# 875  1201745        David         Oneil        empty
# 876  1201372       Edward         Moody        empty
# 877  1201005        Navin  Pari Parwani        empty
# 878  1202094       Tauhir         Jones        empty
# 879  1201150       Rodney      Yacinthe        empty
#
#                          Email         Phone Account Status  \
# 0                        empty  919370957037         ACTIVE
# 1          a.igder21@gmail.com   61406691590         ACTIVE
# 2          aaronmete@gmail.com   61418523131         ACTIVE
# 3         abeckley82@gmail.com   61421917668         ACTIVE
# 4    abhiraj.singh.15@live.com   61430374661         ACTIVE
# ..                         ...           ...            ...
# 875           herblif1@aol.com   16173652642         ACTIVE
# 876           moodysix@aol.com   19493836752         ACTIVE
# 877        nicky@londonrag.com   85261329354         ACTIVE
# 878     tauhir.jones@gmail.com   13122860573         ACTIVE
# 879     yacinthe1112@yahoo.com   13474377826         ACTIVE
#
#         Servicing Office     Karma Club Program
# 0    KC EXPERIENCE India           Karma Utopia
# 1     KC EXPERIENCE Bali    Jimbaran Sales Deck
# 2     KC EXPERIENCE Bali  Petitenget Sales Deck
# 3     KC EXPERIENCE Bali     Vietnam Sales Deck
# 4     KC EXPERIENCE Bali  Petitenget Sales Deck
# ..                   ...                    ...
# 875   KC EXPERIENCE Bali  Petitenget Sales Deck
# 876   KC EXPERIENCE Bali    Jimbaran Sales Deck
# 877   KC EXPERIENCE Bali    Jimbaran Sales Deck
# 878   KC EXPERIENCE Bali    Jimbaran Sales Deck
# 879   KC EXPERIENCE Bali  Petitenget Sales Deck
#
# [880 rows x 9 columns]

# %%
find_member_oddysey = df_kce.copy()

find_member_oddysey.loc[find_member_oddysey['Phone'].isin(df_phone_member_odd['Mobile']), 'Same Value Find'] = 'Member-Mobile' 

find_member_oddysey.loc[find_member_oddysey['Email'].isin(df_email_member_odd['Email']), 'Same Value Find'] = 'Member-Email'
find_member_oddysey.drop(find_member_oddysey.loc[find_member_oddysey['Same Value Find'].isna()].index, inplace=True)

find_member_oddysey.replace('empty', '', inplace=True)

find_member_oddysey.to_csv(r'C:\Users\fajar\Documents\Python\Data\cek_member_odyssey.csv', index=False)

# %%
count_dedup_member_odd = df_kce.loc[
    
    df_kce['Phone'].isin(df_phone_member_odd['Mobile']) | 
    df_kce['Email'].isin(df_email_member_odd['Email'])
].shape[0]

df_kce.loc[
    
    df_kce['Phone'].isin(df_phone_member_odd['Mobile']) | 
    df_kce['Email'].isin(df_email_member_odd['Email'])
]
# Out:
#       number   FirstName   lastname Country                       Email  \
# 289  1200891       Bipin     Mashru   India       bipinmashru@gmail.com
# 538  1200791          JS      RAJAN   India         rajanjs24@gmail.com
# 563  1194496  RAVI KUMAR  BODAKUNTA   India  ravi_109_kumar@yahoo.co.in
#
#             Phone Account Status       Servicing Office Karma Club Program
# 289  919825115369         ACTIVE    KC EXPERIENCE India          South Goa
# 538  916361690619         ACTIVE  KARMA CONCIERGE INDIA              empty
# 563  916309544115         ACTIVE    KC EXPERIENCE India              empty

# %%
df_kce.drop(df_kce.loc[
    
    df_kce['Phone'].isin(df_phone_member_odd['Mobile']) | 
    df_kce['Email'].isin(df_email_member_odd['Email'])
].index, inplace=True)

df_kce.reset_index(drop=True, inplace=True)

count_after_dedup_member_odd = df_kce.shape[0]
df_kce
# Out:
#       number    FirstName      lastname      Country  \
# 0    1202089  Shafiqullah         Raiey  Afghanistan
# 1    1201352        Aghil         Igder    Australia
# 2    1200931        Aaron          Mete    Australia
# 3    1202008       Adrian        Mooney    Australia
# 4    1202121      Abhiraj         Singh    Australia
# ..       ...          ...           ...          ...
# 872  1201745        David         Oneil        empty
# 873  1201372       Edward         Moody        empty
# 874  1201005        Navin  Pari Parwani        empty
# 875  1202094       Tauhir         Jones        empty
# 876  1201150       Rodney      Yacinthe        empty
#
#                          Email         Phone Account Status  \
# 0                        empty  919370957037         ACTIVE
# 1          a.igder21@gmail.com   61406691590         ACTIVE
# 2          aaronmete@gmail.com   61418523131         ACTIVE
# 3         abeckley82@gmail.com   61421917668         ACTIVE
# 4    abhiraj.singh.15@live.com   61430374661         ACTIVE
# ..                         ...           ...            ...
# 872           herblif1@aol.com   16173652642         ACTIVE
# 873           moodysix@aol.com   19493836752         ACTIVE
# 874        nicky@londonrag.com   85261329354         ACTIVE
# 875     tauhir.jones@gmail.com   13122860573         ACTIVE
# 876     yacinthe1112@yahoo.com   13474377826         ACTIVE
#
#         Servicing Office     Karma Club Program
# 0    KC EXPERIENCE India           Karma Utopia
# 1     KC EXPERIENCE Bali    Jimbaran Sales Deck
# 2     KC EXPERIENCE Bali  Petitenget Sales Deck
# 3     KC EXPERIENCE Bali     Vietnam Sales Deck
# 4     KC EXPERIENCE Bali  Petitenget Sales Deck
# ..                   ...                    ...
# 872   KC EXPERIENCE Bali  Petitenget Sales Deck
# 873   KC EXPERIENCE Bali    Jimbaran Sales Deck
# 874   KC EXPERIENCE Bali    Jimbaran Sales Deck
# 875   KC EXPERIENCE Bali    Jimbaran Sales Deck
# 876   KC EXPERIENCE Bali  Petitenget Sales Deck
#
# [877 rows x 9 columns]

# %%
find_member_kce = df_kce.copy()

find_member_kce.loc[find_member_kce['Phone'].isin(df_phone_member_kce['Phone']), 'Same Value Find'] = 'Member-KCE-Mobile' 

find_member_kce.loc[find_member_kce['Email'].isin(df_email_member_kce['Email']), 'Same Value Find'] = 'Member-KCE-Email'
find_member_kce.drop(find_member_kce.loc[find_member_kce['Same Value Find'].isna()].index, inplace=True)

find_member_kce.replace('empty', '', inplace=True)

find_member_kce.to_csv(r'C:\Users\fajar\Documents\Python\Data\cek_member_kce.csv', index=False)

# %%
count_dedup_member_kce = df_kce.loc[
    
    df_kce['Phone'].isin(df_phone_member_kce['Phone']) | 
    df_kce['Email'].isin(df_email_member_kce['Email'])

].shape[0]

df_kce.loc[
    
    df_kce['Phone'].isin(df_phone_member_kce['Phone']) | 
    df_kce['Email'].isin(df_email_member_kce['Email'])
]
# Out:
#       number FirstName      lastname         Country  \
# 2    1200931     Aaron          Mete       Australia
# 8    1201004      Alex         Rasho       Australia
# 19   1200863       Aso      Hamzehei       Australia
# 20   1200856   Atayyab      Siddiqui       Australia
# 26   1200911     Brent          Ward       Australia
# ..       ...       ...           ...             ...
# 840  1200860    Markus        Handau     Switzerland
# 845  1201843      Carl         Evans  United Kingdom
# 865  1200813       Ray       Plowman             USA
# 870  1200833     David        Lennon           empty
# 874  1201005     Navin  Pari Parwani           empty
#
#                              Email         Phone Account Status  \
# 2              aaronmete@gmail.com   61418523131         ACTIVE
# 8             alex.rasho@gmail.com   61416682720         ACTIVE
# 19             aso.zehei@gmail.com   61450550137         ACTIVE
# 20            atayyabsid@gmail.com   61469175702         ACTIVE
# 26         brentward93@outlook.com   61438017502         ACTIVE
# ..                             ...           ...            ...
# 840         markus.handau@yahoo.de   41798407719         ACTIVE
# 845    carl.cjevans@btinternet.com  447947399814         ACTIVE
# 865           p31plowman@yahoo.com   19104426574         ACTIVE
# 870  davidandcassidy1223@gmail.com   19293098078         ACTIVE
# 874            nicky@londonrag.com   85261329354         ACTIVE
#
#         Servicing Office     Karma Club Program
# 2     KC EXPERIENCE Bali  Petitenget Sales Deck
# 8     KC EXPERIENCE Bali  Petitenget Sales Deck
# 19    KC EXPERIENCE Bali    Jimbaran Sales Deck
# 20    KC EXPERIENCE Bali  Petitenget Sales Deck
# 26    KC EXPERIENCE Bali    Jimbaran Sales Deck
# ..                   ...                    ...
# 840   KC EXPERIENCE Bali    Jimbaran Sales Deck
# 845  KC EXPERIENCE India                  empty
# 865   KC EXPERIENCE Bali     Vietnam Sales Deck
# 870   KC EXPERIENCE Bali    Jimbaran Sales Deck
# 874   KC EXPERIENCE Bali    Jimbaran Sales Deck
#
# [205 rows x 9 columns]

# %%
df_kce.drop(df_kce.loc[
    
    df_kce['Phone'].isin(df_phone_member_kce['Phone']) | 
    df_kce['Email'].isin(df_email_member_kce['Email'])
].index, inplace=True)

df_kce.reset_index(drop=True, inplace=True)

count_after_dedup_member_kce = df_kce.shape[0]
df_kce
# Out:
#       number    FirstName  lastname      Country                      Email  \
# 0    1202089  Shafiqullah     Raiey  Afghanistan                      empty
# 1    1201352        Aghil     Igder    Australia        a.igder21@gmail.com
# 2    1202008       Adrian    Mooney    Australia       abeckley82@gmail.com
# 3    1202121      Abhiraj     Singh    Australia  abhiraj.singh.15@live.com
# 4    1201541       Audrey     Acton    Australia        acton05@outlook.com
# ..       ...          ...       ...          ...                        ...
# 667  1201378        Devin   Crowley        empty  devin.g.crowley@gmail.com
# 668  1201745        David     Oneil        empty           herblif1@aol.com
# 669  1201372       Edward     Moody        empty           moodysix@aol.com
# 670  1202094       Tauhir     Jones        empty     tauhir.jones@gmail.com
# 671  1201150       Rodney  Yacinthe        empty     yacinthe1112@yahoo.com
#
#             Phone Account Status     Servicing Office     Karma Club Program
# 0    919370957037         ACTIVE  KC EXPERIENCE India           Karma Utopia
# 1     61406691590         ACTIVE   KC EXPERIENCE Bali    Jimbaran Sales Deck
# 2     61421917668         ACTIVE   KC EXPERIENCE Bali     Vietnam Sales Deck
# 3     61430374661         ACTIVE   KC EXPERIENCE Bali  Petitenget Sales Deck
# 4     61411813935         ACTIVE   KC EXPERIENCE Bali    Jimbaran Sales Deck
# ..            ...            ...                  ...                    ...
# 667   12066509513         ACTIVE   KC EXPERIENCE Bali    Jimbaran Sales Deck
# 668   16173652642         ACTIVE   KC EXPERIENCE Bali  Petitenget Sales Deck
# 669   19493836752         ACTIVE   KC EXPERIENCE Bali    Jimbaran Sales Deck
# 670   13122860573         ACTIVE   KC EXPERIENCE Bali    Jimbaran Sales Deck
# 671   13474377826         ACTIVE   KC EXPERIENCE Bali  Petitenget Sales Deck
#
# [672 rows x 9 columns]

# %%
# hitung jumlah duplicate
count_duplicate_general = df_kce.loc[df_kce.duplicated(subset=['Email','Phone'])].shape[0]

df_kce.loc[df_kce.duplicated(subset=['Email','Phone'])]
# Out:
#       number FirstName lastname Country                       Email  \
# 165  1201063    AKSHAY  KOTHARI   India  akshay.kothari02@gmail.com
#
#             Phone Account Status     Servicing Office Karma Club Program
# 165  919028922499         ACTIVE  KC EXPERIENCE India              empty

# %%
df_kce.drop_duplicates(subset=['Email','Phone'], inplace=True)
df_kce.reset_index(drop=True, inplace=True)

# hitung jumlah setelah value duplicate dihapus
count_after_dedup_duplicate = df_kce.shape[0]

df_kce
# Out:
#       number    FirstName  lastname      Country                      Email  \
# 0    1202089  Shafiqullah     Raiey  Afghanistan                      empty
# 1    1201352        Aghil     Igder    Australia        a.igder21@gmail.com
# 2    1202008       Adrian    Mooney    Australia       abeckley82@gmail.com
# 3    1202121      Abhiraj     Singh    Australia  abhiraj.singh.15@live.com
# 4    1201541       Audrey     Acton    Australia        acton05@outlook.com
# ..       ...          ...       ...          ...                        ...
# 666  1201378        Devin   Crowley        empty  devin.g.crowley@gmail.com
# 667  1201745        David     Oneil        empty           herblif1@aol.com
# 668  1201372       Edward     Moody        empty           moodysix@aol.com
# 669  1202094       Tauhir     Jones        empty     tauhir.jones@gmail.com
# 670  1201150       Rodney  Yacinthe        empty     yacinthe1112@yahoo.com
#
#             Phone Account Status     Servicing Office     Karma Club Program
# 0    919370957037         ACTIVE  KC EXPERIENCE India           Karma Utopia
# 1     61406691590         ACTIVE   KC EXPERIENCE Bali    Jimbaran Sales Deck
# 2     61421917668         ACTIVE   KC EXPERIENCE Bali     Vietnam Sales Deck
# 3     61430374661         ACTIVE   KC EXPERIENCE Bali  Petitenget Sales Deck
# 4     61411813935         ACTIVE   KC EXPERIENCE Bali    Jimbaran Sales Deck
# ..            ...            ...                  ...                    ...
# 666   12066509513         ACTIVE   KC EXPERIENCE Bali    Jimbaran Sales Deck
# 667   16173652642         ACTIVE   KC EXPERIENCE Bali  Petitenget Sales Deck
# 668   19493836752         ACTIVE   KC EXPERIENCE Bali    Jimbaran Sales Deck
# 669   13122860573         ACTIVE   KC EXPERIENCE Bali    Jimbaran Sales Deck
# 670   13474377826         ACTIVE   KC EXPERIENCE Bali  Petitenget Sales Deck
#
# [671 rows x 9 columns]

# %%
list_UK_EU = pm.get_list_UK_EU()
list_Others = pm.get_list_Others()

# %%
df_kce.loc[df_kce['Country'].isin(list_Others)]
# Out:
#       number    FirstName  lastname               Country  \
# 0    1202089  Shafiqullah     Raiey           Afghanistan
# 1    1201352        Aghil     Igder             Australia
# 2    1202008       Adrian    Mooney             Australia
# 3    1202121      Abhiraj     Singh             Australia
# 4    1201541       Audrey     Acton             Australia
# ..       ...          ...       ...                   ...
# 641  1202113         Juan     Illan              Thailand
# 642  1202030       Jasbir    Thakur  United Arab Emirates
# 660  1201364       Calvin  Roberson                   USA
# 661  1201896      Melissa  Atkinson                   USA
# 662  1201577     Roderick  Whitaker                   USA
#
#                              Email         Phone Account Status  \
# 0                            empty  919370957037         ACTIVE
# 1              a.igder21@gmail.com   61406691590         ACTIVE
# 2             abeckley82@gmail.com   61421917668         ACTIVE
# 3        abhiraj.singh.15@live.com   61430374661         ACTIVE
# 4              acton05@outlook.com   61411813935         ACTIVE
# ..                             ...           ...            ...
# 641  juanramonillanrubio@gmail.com   34603663034         ACTIVE
# 642       himachaliboy04@gmail.com   97166193058         ACTIVE
# 660         calroberson1@gmail.com   12027168259         ACTIVE
# 661          melissaah10@yahoo.com   18322332050         ACTIVE
# 662          tayah.jones@yahoo.com   15022981825         ACTIVE
#
#         Servicing Office     Karma Club Program
# 0    KC EXPERIENCE India           Karma Utopia
# 1     KC EXPERIENCE Bali    Jimbaran Sales Deck
# 2     KC EXPERIENCE Bali     Vietnam Sales Deck
# 3     KC EXPERIENCE Bali  Petitenget Sales Deck
# 4     KC EXPERIENCE Bali    Jimbaran Sales Deck
# ..                   ...                    ...
# 641   KC EXPERIENCE Bali    Jimbaran Sales Deck
# 642   KC EXPERIENCE Bali    Jimbaran Sales Deck
# 660   KC EXPERIENCE Bali  Petitenget Sales Deck
# 661   KC EXPERIENCE Bali  Petitenget Sales Deck
# 662   KC EXPERIENCE Bali    Jimbaran Sales Deck
#
# [166 rows x 9 columns]

# %%
df_kce.loc[df_kce['Country'].str.contains('India'), 'Area'] = 'India'
df_kce.loc[df_kce['Country'].isin(list_UK_EU), 'Area'] = 'UK EU'
df_kce.loc[df_kce['Country'].isin(list_Others), 'Area'] = 'Others'

# %%
df_kce.loc[df_kce['Area'] == 'India', 'Batch'] = 'INDIA'
df_kce.loc[df_kce['Area'] == 'UK EU', 'Batch'] = 'NONINDIA'
df_kce.loc[df_kce['Area'] == 'Others', 'Batch'] = 'NONINDIA'

# %%
df_kce.replace('empty', '', inplace=True)

# %%
df_kce.columns
# Out:
# Index(['number', 'FirstName', 'lastname', 'Country', 'Email', 'Phone',
#        'Account Status', 'Servicing Office', 'Karma Club Program', 'Area',
#        'Batch'],
#       dtype='object')

# %%
new_cols = ['number', 'FirstName', 'lastname', 'Country', 'Area', 'Batch', 'Email', 'Phone',
       'Account Status', 'Servicing Office', 'Karma Club Program']

df_kce = df_kce.reindex(columns=new_cols)

# %%
count_data_akhir = df_kce.shape[0]

df_kce.to_csv(r'C:\Users\fajar\Documents\Python\Data\final_kce.csv', index=False)

# %%
print("==========================================================")
print("Summary")
print("==========================================================")
print("Jumlah Data Awal KCE CC-CL : "+str(count_data_awal))
print("Jumlah Data Email dan Phone Kosong : "+str(count_email_phone_empty))
print("Jumlah Data Setelah Hapus Email dan Phone Yang Kosong : "+str(count_after_email_phone_empty))
print("Jumlah Lead Test : "+str(count_leads_test))
print("Jumlah Setelah Clean Lead Test : "+str(count_after_dedup_test))
print("Jumlah Email Karma : "+str(count_email_karma))
print("Jumlah Setelah Clean Email Karma : "+str(count_after_clean_karma))
print("Jumlah Data Yang Terkena Dedup Member Oddysey : "+str(count_dedup_member_odd))
print("Jumlah Data Setelah Dedup Member Oddysey : "+str(count_after_dedup_member_odd))
print("Jumlah Data Yang Terkena Dedup Past Guest KCE : "+str(count_dedup_member_kce))
print("Jumlah Data Setelah Dedup Past Guest KCE : "+str(count_after_dedup_member_kce))
print("Jumlah Data Yang Duplicate : "+str(count_duplicate_general))
print("Jumlah Data Setelah Hapus Duplicate : "+str(count_after_dedup_duplicate))
print("Jumlah Data Akhir : "+str(count_data_akhir))
# Out:
# ==========================================================
# Summary
# ==========================================================
# Jumlah Data Awal KCE CC-CL : 880
# Jumlah Data Email dan Phone Kosong : 0
# Jumlah Data Setelah Hapus Email dan Phone Yang Kosong : 880
# Jumlah Lead Test : 0
# Jumlah Setelah Clean Lead Test : 880
# Jumlah Email Karma : 0
# Jumlah Setelah Clean Email Karma : 880
# Jumlah Data Yang Terkena Dedup Member Oddysey : 3
# Jumlah Data Setelah Dedup Member Oddysey : 877
# Jumlah Data Yang Terkena Dedup Past Guest KCE : 205
# Jumlah Data Setelah Dedup Past Guest KCE : 672
# Jumlah Data Yang Duplicate : 1
# Jumlah Data Setelah Hapus Duplicate : 671
# Jumlah Data Akhir : 671
