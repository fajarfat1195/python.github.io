# %%
import pandas as pd
import re

import past_guest_module as pm

import sys
sys.path.append('../zoho_data_app/')

import main_module as m

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
cols = ['Account ID', 'FirstName', 'lastname', 'Country', 'Email', 'Phone',
       'AcStatus', 'Servicing Office','KarmaClubProgram']

# %%
path = r'C:\Users\fajar\Documents\Python\Data\KCC cc-cl\2024\Aug\11 Aug - 19 Aug\KCE CC CL 11 Aug - 19 Aug.xlsx'
df_kce = pd.read_excel(path, dtype='string', sheet_name='Sheet1', usecols=cols)
count_data_awal = df_kce.shape[0]
df_kce
# Out:
#     Account ID    FirstName       lastname    Country  \
# 0      1197706       Roland         Butler    Armenia
# 1      1197166       Steven         Cooper  Australia
# 2      1197167         STAN        GRAIKOS  Australia
# 3      1197169        Cregg          Plank  Australia
# 4      1197185       Robert      Belvedere  Australia
# ..         ...          ...            ...        ...
# 928    1197724        Erica          Green       <NA>
# 929    1197916  Christopher       Gonnella       <NA>
# 930    1197955   Constantin  Koemtzopoulos       <NA>
# 931    1198097          Ken            Oku       <NA>
# 932    1198320       Ruairi           Lamb       <NA>
#
#                           Email        Phone AcStatus    Servicing Office  \
# 0    liana.baghramian@gmail.com  37499042207   ACTIVE  KC EXPERIENCE Bali
# 1      stevenford78@outlook.com  61488225084   ACTIVE  KC EXPERIENCE Bali
# 2        soniagraikos@gmail.com  61412227790   ACTIVE  KC EXPERIENCE Bali
# 3         gusha@netspace.net.au  61492996615   ACTIVE  KC EXPERIENCE Bali
# 4         rmbelvedere@gmail.com  61407559240   ACTIVE  KC EXPERIENCE Bali
# ..                          ...          ...      ...                 ...
# 928    erica.green822@gmail.com  12174889669   ACTIVE  KC EXPERIENCE Bali
# 929      cmgonnella@outlook.com  15097417440   ACTIVE  KC EXPERIENCE Bali
# 930      robert_duyen@yahoo.com  15102992050   ACTIVE  KC EXPERIENCE Bali
# 931            kobez8@yahoo.com  15105987102   ACTIVE  KC EXPERIENCE Bali
# 932        ruairilamb@gmail.com  85294046398   ACTIVE  KC EXPERIENCE Bali
#
#           KarmaClubProgram
# 0    Petitenget Sales Deck
# 1      Jimbaran Sales Deck
# 2      Jimbaran Sales Deck
# 3      Jimbaran Sales Deck
# 4      Jimbaran Sales Deck
# ..                     ...
# 928  Petitenget Sales Deck
# 929  Petitenget Sales Deck
# 930    Jimbaran Sales Deck
# 931  Petitenget Sales Deck
# 932     Vietnam Sales Deck
#
# [933 rows x 9 columns]

# %%
df_kce.columns
# Out:
# Index(['Account ID', 'FirstName', 'lastname', 'Country', 'Email', 'Phone',
#        'AcStatus', 'Servicing Office', 'KarmaClubProgram'],
#       dtype='object')

# %%
df_kce.rename(columns = {
    'Account ID':'number', 
    'AcStatus':'Account Status',
    'KarmaClubProgram':'Karma Club Program',
    }, inplace = True)

# %%
df_kce.fillna('empty', inplace=True)

# %%
path = r'G:\.shortcut-targets-by-id\0B_d3smBjzo04UUNBME5GOVhoMjA\_ODYSSEY\Phone Members.xlsx'
df_phone_member_odd = pd.read_excel(path, dtype='string', sheet_name='Sheet1')

path = r'G:\.shortcut-targets-by-id\0B_d3smBjzo04UUNBME5GOVhoMjA\_ODYSSEY\Email Members.xlsx'
df_email_member_odd = pd.read_excel(path, dtype='string', sheet_name='Sheet1')

path = r'G:\.shortcut-targets-by-id\0B_d3smBjzo04UUNBME5GOVhoMjA\_ODYSSEY\KCE Members.xlsx'
df_phone_member_kce = pd.read_excel(path, dtype='string', sheet_name='Phone')

path = r'G:\.shortcut-targets-by-id\0B_d3smBjzo04UUNBME5GOVhoMjA\_ODYSSEY\KCE Members.xlsx'
df_email_member_kce = pd.read_excel(path, dtype='string', sheet_name='Email')

# %%
m.clean_number(df_kce, 'Phone')
m.replace_not_valid_to_empty(df_kce, 'Phone')
df_kce['Email'] = m.lowercase(df_kce, 'Email')
m.clean_space(df_kce, 'Email')

m.clean_number(df_phone_member_odd, 'Mobile')
df_email_member_odd['Email'] = m.lowercase(df_email_member_odd, 'Email')
m.clean_space(df_email_member_odd, 'Email')

m.clean_number(df_phone_member_kce, 'Phone')
df_email_member_kce['Email'] = m.lowercase(df_email_member_kce, 'Email')
m.clean_space(df_email_member_kce, 'Email')
# Out:
# 0          aameercok@gmail.com.com
# 1              imerwan@hotmail.com
# 2              mkptech15@gmail.com
# 3        sovitmittal2000@yahoo.com
# 4          smritidas1431@gmail.com
#                    ...
# 84170         kyafai1128@yahoo.com
# 84171          ryan_farran@ntm.org
# 84172        samotiteame@gmail.com
# 84173        scurrie63@hotmail.com
# 84174        suubashkc61@gmail.com
# Name: Email, Length: 84175, dtype: string

# %%
pm.email_correction(df_kce, 'Email')
df_kce
# Out:
#       number    FirstName       lastname    Country  \
# 0    1197706       Roland         Butler    Armenia
# 1    1197166       Steven         Cooper  Australia
# 2    1197167         STAN        GRAIKOS  Australia
# 3    1197169        Cregg          Plank  Australia
# 4    1197185       Robert      Belvedere  Australia
# ..       ...          ...            ...        ...
# 928  1197724        Erica          Green      empty
# 929  1197916  Christopher       Gonnella      empty
# 930  1197955   Constantin  Koemtzopoulos      empty
# 931  1198097          Ken            Oku      empty
# 932  1198320       Ruairi           Lamb      empty
#
#                           Email        Phone Account Status  \
# 0    liana.baghramian@gmail.com  37499042207         ACTIVE
# 1      stevenford78@outlook.com  61488225084         ACTIVE
# 2        soniagraikos@gmail.com  61412227790         ACTIVE
# 3         gusha@netspace.net.au  61492996615         ACTIVE
# 4         rmbelvedere@gmail.com  61407559240         ACTIVE
# ..                          ...          ...            ...
# 928    erica.green822@gmail.com  12174889669         ACTIVE
# 929      cmgonnella@outlook.com  15097417440         ACTIVE
# 930      robert_duyen@yahoo.com  15102992050         ACTIVE
# 931            kobez8@yahoo.com  15105987102         ACTIVE
# 932        ruairilamb@gmail.com  85294046398         ACTIVE
#
#        Servicing Office     Karma Club Program
# 0    KC EXPERIENCE Bali  Petitenget Sales Deck
# 1    KC EXPERIENCE Bali    Jimbaran Sales Deck
# 2    KC EXPERIENCE Bali    Jimbaran Sales Deck
# 3    KC EXPERIENCE Bali    Jimbaran Sales Deck
# 4    KC EXPERIENCE Bali    Jimbaran Sales Deck
# ..                  ...                    ...
# 928  KC EXPERIENCE Bali  Petitenget Sales Deck
# 929  KC EXPERIENCE Bali  Petitenget Sales Deck
# 930  KC EXPERIENCE Bali    Jimbaran Sales Deck
# 931  KC EXPERIENCE Bali  Petitenget Sales Deck
# 932  KC EXPERIENCE Bali     Vietnam Sales Deck
#
# [933 rows x 9 columns]

# %%
count_email_phone_empty = df_kce.loc[(df_kce['Email'] == 'empty') & (df_kce['Phone'] == 'empty')].shape[0]

df_kce.loc[(df_kce['Email'] == 'empty') & (df_kce['Phone'] == 'empty')].to_csv(r'C:\Users\fajar\Documents\Python\Data\cek_email_phone_empty_kce.csv', index=False)

df_kce.drop(df_kce.loc[(df_kce['Email'] == 'empty') & (df_kce['Phone'] == 'empty')].index, inplace=True)
df_kce.reset_index(drop=True, inplace=True)

count_after_email_phone_empty = df_kce.shape[0]

# %%
# Cek leads test
test_leads = df_kce.loc[
    
        df_kce['Email'].str.contains('^test@', flags=re.I, regex=True) |
        df_kce['Email'].str.contains('\+test', flags=re.I, regex=True) |
    
        df_kce['FirstName'].str.contains('^test$', flags=re.I, regex=True) |
        df_kce['lastname'].str.contains('^test$', flags=re.I, regex=True) |

        df_kce['FirstName'].str.contains('test 1', flags=re.I, regex=True) |
        df_kce['lastname'].str.contains('test 2', flags=re.I, regex=True)|
        df_kce['FirstName'].str.contains('test1', flags=re.I, regex=True) |
        df_kce['lastname'].str.contains('test2', flags=re.I, regex=True)|

        df_kce['FirstName'].str.contains(' test ', flags=re.I, regex=True) | 
        df_kce['lastname'].str.contains(' test ', flags=re.I, regex=True) | 
        df_kce['lastname'].str.contains(' test$', flags=re.I, regex=True)
    
    
    ]

count_leads_test = test_leads.shape[0]

test_leads.to_excel(r'C:\Users\fajar\Documents\Python\Data\test_leads.xlsx', index=False)
test_leads
# Out:
# Empty DataFrame
# Columns: [number, FirstName, lastname, Country, Email, Phone, Account Status, Servicing Office, Karma Club Program]
# Index: []

# %%
df_kce.drop(test_leads.index, inplace=True)
df_kce.reset_index(drop=True, inplace=True)

count_after_dedup_test = df_kce.shape[0]

# %%
# Cek Email Karma
email_karma = m.find_karma(df_kce, 'Email')
count_email_karma = email_karma.shape[0]
# email_OTA.to_excel(r'C:\Users\fajar\Documents\Python\Data\email_OTA.xlsx', index=False)

email_karma
# Out:
# Empty DataFrame
# Columns: [number, FirstName, lastname, Country, Email, Phone, Account Status, Servicing Office, Karma Club Program]
# Index: []

# %%
# delete email Karma
count_after_clean_karma = m.delete_karma(df_kce, 'Email')
# zoho_df.to_excel(r'C:\Users\fajar\Documents\Python\Data\after_clean_OTA.xlsx', index=False)

df_kce
# Out:
#       number    FirstName       lastname    Country  \
# 0    1197706       Roland         Butler    Armenia
# 1    1197166       Steven         Cooper  Australia
# 2    1197167         STAN        GRAIKOS  Australia
# 3    1197169        Cregg          Plank  Australia
# 4    1197185       Robert      Belvedere  Australia
# ..       ...          ...            ...        ...
# 925  1197724        Erica          Green      empty
# 926  1197916  Christopher       Gonnella      empty
# 927  1197955   Constantin  Koemtzopoulos      empty
# 928  1198097          Ken            Oku      empty
# 929  1198320       Ruairi           Lamb      empty
#
#                           Email        Phone Account Status  \
# 0    liana.baghramian@gmail.com  37499042207         ACTIVE
# 1      stevenford78@outlook.com  61488225084         ACTIVE
# 2        soniagraikos@gmail.com  61412227790         ACTIVE
# 3         gusha@netspace.net.au  61492996615         ACTIVE
# 4         rmbelvedere@gmail.com  61407559240         ACTIVE
# ..                          ...          ...            ...
# 925    erica.green822@gmail.com  12174889669         ACTIVE
# 926      cmgonnella@outlook.com  15097417440         ACTIVE
# 927      robert_duyen@yahoo.com  15102992050         ACTIVE
# 928            kobez8@yahoo.com  15105987102         ACTIVE
# 929        ruairilamb@gmail.com  85294046398         ACTIVE
#
#        Servicing Office     Karma Club Program
# 0    KC EXPERIENCE Bali  Petitenget Sales Deck
# 1    KC EXPERIENCE Bali    Jimbaran Sales Deck
# 2    KC EXPERIENCE Bali    Jimbaran Sales Deck
# 3    KC EXPERIENCE Bali    Jimbaran Sales Deck
# 4    KC EXPERIENCE Bali    Jimbaran Sales Deck
# ..                  ...                    ...
# 925  KC EXPERIENCE Bali  Petitenget Sales Deck
# 926  KC EXPERIENCE Bali  Petitenget Sales Deck
# 927  KC EXPERIENCE Bali    Jimbaran Sales Deck
# 928  KC EXPERIENCE Bali  Petitenget Sales Deck
# 929  KC EXPERIENCE Bali     Vietnam Sales Deck
#
# [930 rows x 9 columns]

# %%
find_member_oddysey = df_kce.copy()

find_member_oddysey.loc[find_member_oddysey['Phone'].isin(df_phone_member_odd['Mobile']), 'Same Value Find'] = 'Member-Mobile' 

find_member_oddysey.loc[find_member_oddysey['Email'].isin(df_email_member_odd['Email']), 'Same Value Find'] = 'Member-Email'
find_member_oddysey.drop(find_member_oddysey.loc[find_member_oddysey['Same Value Find'].isna()].index, inplace=True)

find_member_oddysey.replace('empty', '', inplace=True)

find_member_oddysey.to_csv(r'C:\Users\fajar\Documents\Python\Data\cek_member_odyssey.csv', index=False)

# %%
count_dedup_member_odd = df_kce.loc[
    
    df_kce['Phone'].isin(df_phone_member_odd['Mobile']) | 
    df_kce['Email'].isin(df_email_member_odd['Email'])
].shape[0]

df_kce.loc[
    
    df_kce['Phone'].isin(df_phone_member_odd['Mobile']) | 
    df_kce['Email'].isin(df_email_member_odd['Email'])
]
# Out:
#       number              FirstName   lastname Country  \
# 238  1197387       MOHAMMED HUSSAIN  CHOUDHARY   India
# 273  1197621             N PRASANNA      KUMAR   India
# 299  1197790                      J    EBINESH   India
# 307  1197811                  POOJA     BIYANI   India
# 316  1197834                  VEOLA      PINHO   India
# 336  1198178                   RAMA     BHAKTA   India
# 343  1198212  DEEPAK KALIDAS KAKADE     KAKADE   India
# 381  1197219               Avnish N    Jhaveri   India
# 524  1197925                  Shaji        S P   India
# 562  1197974                 Satish   Hiremath   India
# 613  1198246                 Raju P      Manek   India
# 631  1198264                  Sunil      Vohra   India
# 655  1198310                Saurabh      Bajaj   India
#
#                                Email         Phone Account Status  \
# 238     mdhussainchoudhary@gmail.com  919867868652         ACTIVE
# 273  dhirajassociates@rediffmail.com  919845392958         ACTIVE
# 299         ebinesh_mech@yahoo.co.in  919790272778         ACTIVE
# 307              biyanip80@gmail.com  919899150474         ACTIVE
# 316                 veolac@gmail.com  919867193396         ACTIVE
# 336             rambhaktha@gmail.com  919742615139         ACTIVE
# 343      deepakkakade11111@gmail.com  917887716674         ACTIVE
# 381         avnishnjhaveri@gmail.com  919320301720         ACTIVE
# 524          prathi4social@gmail.com  919731019216         ACTIVE
# 562            satish.hmth@gmail.com  919850440273         ACTIVE
# 613              manekraju@yahoo.com  919322277778         ACTIVE
# 631         automationeqpt@gmail.com  919820034742         ACTIVE
# 655                            empty  919560786579         ACTIVE
#
#         Servicing Office Karma Club Program
# 238  KC EXPERIENCE India              empty
# 273  KC EXPERIENCE India              empty
# 299  KC EXPERIENCE India              empty
# 307  KC EXPERIENCE India              empty
# 316  KC EXPERIENCE India              empty
# 336  KC EXPERIENCE India              empty
# 343  KC EXPERIENCE India              empty
# 381  KC EXPERIENCE India          South Goa
# 524  KC EXPERIENCE India          South Goa
# 562  KC EXPERIENCE India          South Goa
# 613  KC EXPERIENCE India          South Goa
# 631  KC EXPERIENCE India          South Goa
# 655  KC EXPERIENCE India       Karma Utopia

# %%
df_kce.drop(df_kce.loc[
    
    df_kce['Phone'].isin(df_phone_member_odd['Mobile']) | 
    df_kce['Email'].isin(df_email_member_odd['Email'])
].index, inplace=True)

df_kce.reset_index(drop=True, inplace=True)

count_after_dedup_member_odd = df_kce.shape[0]
df_kce
# Out:
#       number    FirstName       lastname    Country  \
# 0    1197706       Roland         Butler    Armenia
# 1    1197166       Steven         Cooper  Australia
# 2    1197167         STAN        GRAIKOS  Australia
# 3    1197169        Cregg          Plank  Australia
# 4    1197185       Robert      Belvedere  Australia
# ..       ...          ...            ...        ...
# 912  1197724        Erica          Green      empty
# 913  1197916  Christopher       Gonnella      empty
# 914  1197955   Constantin  Koemtzopoulos      empty
# 915  1198097          Ken            Oku      empty
# 916  1198320       Ruairi           Lamb      empty
#
#                           Email        Phone Account Status  \
# 0    liana.baghramian@gmail.com  37499042207         ACTIVE
# 1      stevenford78@outlook.com  61488225084         ACTIVE
# 2        soniagraikos@gmail.com  61412227790         ACTIVE
# 3         gusha@netspace.net.au  61492996615         ACTIVE
# 4         rmbelvedere@gmail.com  61407559240         ACTIVE
# ..                          ...          ...            ...
# 912    erica.green822@gmail.com  12174889669         ACTIVE
# 913      cmgonnella@outlook.com  15097417440         ACTIVE
# 914      robert_duyen@yahoo.com  15102992050         ACTIVE
# 915            kobez8@yahoo.com  15105987102         ACTIVE
# 916        ruairilamb@gmail.com  85294046398         ACTIVE
#
#        Servicing Office     Karma Club Program
# 0    KC EXPERIENCE Bali  Petitenget Sales Deck
# 1    KC EXPERIENCE Bali    Jimbaran Sales Deck
# 2    KC EXPERIENCE Bali    Jimbaran Sales Deck
# 3    KC EXPERIENCE Bali    Jimbaran Sales Deck
# 4    KC EXPERIENCE Bali    Jimbaran Sales Deck
# ..                  ...                    ...
# 912  KC EXPERIENCE Bali  Petitenget Sales Deck
# 913  KC EXPERIENCE Bali  Petitenget Sales Deck
# 914  KC EXPERIENCE Bali    Jimbaran Sales Deck
# 915  KC EXPERIENCE Bali  Petitenget Sales Deck
# 916  KC EXPERIENCE Bali     Vietnam Sales Deck
#
# [917 rows x 9 columns]

# %%
find_member_kce = df_kce.copy()

find_member_kce.loc[find_member_kce['Phone'].isin(df_phone_member_kce['Phone']), 'Same Value Find'] = 'Member-KCE-Mobile' 

find_member_kce.loc[find_member_kce['Email'].isin(df_email_member_kce['Email']), 'Same Value Find'] = 'Member-KCE-Email'
find_member_kce.drop(find_member_kce.loc[find_member_kce['Same Value Find'].isna()].index, inplace=True)

find_member_kce.replace('empty', '', inplace=True)

find_member_kce.to_csv(r'C:\Users\fajar\Documents\Python\Data\cek_member_kce.csv', index=False)

# %%
count_dedup_member_kce = df_kce.loc[
    
    df_kce['Phone'].isin(df_phone_member_kce['Phone']) | 
    df_kce['Email'].isin(df_email_member_kce['Email'])

].shape[0]

df_kce.loc[
    
    df_kce['Phone'].isin(df_phone_member_kce['Phone']) | 
    df_kce['Email'].isin(df_email_member_kce['Email'])
]
# Out:
#       number    FirstName   lastname         Country  \
# 1    1197166       Steven     Cooper       Australia
# 2    1197167         STAN    GRAIKOS       Australia
# 3    1197169        Cregg      Plank       Australia
# 4    1197185       Robert  Belvedere       Australia
# 5    1197186       Jayden     Heaney       Australia
# ..       ...          ...        ...             ...
# 853  1197295         Dane     Rolton     New Zealand
# 854  1197296         Gary     Bright     New Zealand
# 855  1197303  Vinod Kumar     Chawla     New Zealand
# 856  1197309        Maiko     Filipo     New Zealand
# 881  1197251      Maxwell     Reader  United Kingdom
#
#                                  Email         Phone Account Status  \
# 1             stevenford78@outlook.com   61488225084         ACTIVE
# 2               soniagraikos@gmail.com   61412227790         ACTIVE
# 3                gusha@netspace.net.au   61492996615         ACTIVE
# 4                rmbelvedere@gmail.com   61407559240         ACTIVE
# 5    jayden.zeropointrecords@gmail.com   61487998873         ACTIVE
# ..                                 ...           ...            ...
# 853          dane.rolton@hotmail.co.nz   64272021170         ACTIVE
# 854                     esg@xtra.co.nz    6421641888         ACTIVE
# 855            luxuryhome4me@gmail.com   64212320978         ACTIVE
# 856           maiko-filipo@hotmail.com   64277717410         ACTIVE
# 881       maxwell.reader@maxal-ltd.com  447779240080         ACTIVE
#
#         Servicing Office     Karma Club Program
# 1     KC EXPERIENCE Bali    Jimbaran Sales Deck
# 2     KC EXPERIENCE Bali    Jimbaran Sales Deck
# 3     KC EXPERIENCE Bali    Jimbaran Sales Deck
# 4     KC EXPERIENCE Bali    Jimbaran Sales Deck
# 5     KC EXPERIENCE Bali    Jimbaran Sales Deck
# ..                   ...                    ...
# 853   KC EXPERIENCE Bali  Petitenget Sales Deck
# 854   KC EXPERIENCE Bali  Petitenget Sales Deck
# 855   KC EXPERIENCE Bali    Jimbaran Sales Deck
# 856   KC EXPERIENCE Bali    Jimbaran Sales Deck
# 881  KC EXPERIENCE India                  empty
#
# [132 rows x 9 columns]

# %%
df_kce.drop(df_kce.loc[
    
    df_kce['Phone'].isin(df_phone_member_kce['Phone']) | 
    df_kce['Email'].isin(df_email_member_kce['Email'])
].index, inplace=True)

df_kce.reset_index(drop=True, inplace=True)

count_after_dedup_member_kce = df_kce.shape[0]
df_kce
# Out:
#       number    FirstName       lastname    Country  \
# 0    1197706       Roland         Butler    Armenia
# 1    1197463       Morgan       Williams  Australia
# 2    1197464         Jack         Foster  Australia
# 3    1197465       Steven       Townsend  Australia
# 4    1197466       Andrew       Cheetham  Australia
# ..       ...          ...            ...        ...
# 780  1197724        Erica          Green      empty
# 781  1197916  Christopher       Gonnella      empty
# 782  1197955   Constantin  Koemtzopoulos      empty
# 783  1198097          Ken            Oku      empty
# 784  1198320       Ruairi           Lamb      empty
#
#                            Email        Phone Account Status  \
# 0     liana.baghramian@gmail.com  37499042207         ACTIVE
# 1            mckbonnie@gmail.com  61424459581         ACTIVE
# 2        jackfoster1@live.com.au  61411823985         ACTIVE
# 3    townsendgardening@gmail.com  61409996631         ACTIVE
# 4       cheethamjessie@gmail.com  61410435943         ACTIVE
# ..                           ...          ...            ...
# 780     erica.green822@gmail.com  12174889669         ACTIVE
# 781       cmgonnella@outlook.com  15097417440         ACTIVE
# 782       robert_duyen@yahoo.com  15102992050         ACTIVE
# 783             kobez8@yahoo.com  15105987102         ACTIVE
# 784         ruairilamb@gmail.com  85294046398         ACTIVE
#
#        Servicing Office     Karma Club Program
# 0    KC EXPERIENCE Bali  Petitenget Sales Deck
# 1    KC EXPERIENCE Bali  Petitenget Sales Deck
# 2    KC EXPERIENCE Bali  Petitenget Sales Deck
# 3    KC EXPERIENCE Bali  Petitenget Sales Deck
# 4    KC EXPERIENCE Bali  Petitenget Sales Deck
# ..                  ...                    ...
# 780  KC EXPERIENCE Bali  Petitenget Sales Deck
# 781  KC EXPERIENCE Bali  Petitenget Sales Deck
# 782  KC EXPERIENCE Bali    Jimbaran Sales Deck
# 783  KC EXPERIENCE Bali  Petitenget Sales Deck
# 784  KC EXPERIENCE Bali     Vietnam Sales Deck
#
# [785 rows x 9 columns]

# %%
# hitung jumlah duplicate
count_duplicate_general = df_kce.loc[df_kce.duplicated(subset=['Email','Phone'])].shape[0]

df_kce.loc[df_kce.duplicated(subset=['Email','Phone'])]
# Out:
# Empty DataFrame
# Columns: [number, FirstName, lastname, Country, Email, Phone, Account Status, Servicing Office, Karma Club Program]
# Index: []

# %%
df_kce.drop_duplicates(subset=['Email','Phone'], inplace=True)
df_kce.reset_index(drop=True, inplace=True)

# hitung jumlah setelah value duplicate dihapus
count_after_dedup_duplicate = df_kce.shape[0]

df_kce
# Out:
#       number    FirstName       lastname    Country  \
# 0    1197706       Roland         Butler    Armenia
# 1    1197463       Morgan       Williams  Australia
# 2    1197464         Jack         Foster  Australia
# 3    1197465       Steven       Townsend  Australia
# 4    1197466       Andrew       Cheetham  Australia
# ..       ...          ...            ...        ...
# 780  1197724        Erica          Green      empty
# 781  1197916  Christopher       Gonnella      empty
# 782  1197955   Constantin  Koemtzopoulos      empty
# 783  1198097          Ken            Oku      empty
# 784  1198320       Ruairi           Lamb      empty
#
#                            Email        Phone Account Status  \
# 0     liana.baghramian@gmail.com  37499042207         ACTIVE
# 1            mckbonnie@gmail.com  61424459581         ACTIVE
# 2        jackfoster1@live.com.au  61411823985         ACTIVE
# 3    townsendgardening@gmail.com  61409996631         ACTIVE
# 4       cheethamjessie@gmail.com  61410435943         ACTIVE
# ..                           ...          ...            ...
# 780     erica.green822@gmail.com  12174889669         ACTIVE
# 781       cmgonnella@outlook.com  15097417440         ACTIVE
# 782       robert_duyen@yahoo.com  15102992050         ACTIVE
# 783             kobez8@yahoo.com  15105987102         ACTIVE
# 784         ruairilamb@gmail.com  85294046398         ACTIVE
#
#        Servicing Office     Karma Club Program
# 0    KC EXPERIENCE Bali  Petitenget Sales Deck
# 1    KC EXPERIENCE Bali  Petitenget Sales Deck
# 2    KC EXPERIENCE Bali  Petitenget Sales Deck
# 3    KC EXPERIENCE Bali  Petitenget Sales Deck
# 4    KC EXPERIENCE Bali  Petitenget Sales Deck
# ..                  ...                    ...
# 780  KC EXPERIENCE Bali  Petitenget Sales Deck
# 781  KC EXPERIENCE Bali  Petitenget Sales Deck
# 782  KC EXPERIENCE Bali    Jimbaran Sales Deck
# 783  KC EXPERIENCE Bali  Petitenget Sales Deck
# 784  KC EXPERIENCE Bali     Vietnam Sales Deck
#
# [785 rows x 9 columns]

# %%
list_UK_EU = pm.get_list_UK_EU()
list_Others = pm.get_list_Others()

# %%
df_kce.loc[df_kce['Country'].isin(list_Others)]
# Out:
#       number FirstName  lastname               Country  \
# 1    1197463    Morgan  Williams             Australia
# 2    1197464      Jack    Foster             Australia
# 3    1197465    Steven  Townsend             Australia
# 4    1197466    Andrew  Cheetham             Australia
# 5    1197468       Hai     Quach             Australia
# ..       ...       ...       ...                   ...
# 747  1197483      Jaco  Schoeman                Taiwan
# 748  1197508      Jiju     Jacob  United Arab Emirates
# 749  1198073     Ahmed    Haddad  United Arab Emirates
# 778  1197734   Timothy     Gates                   USA
# 779  1197917   Terence     Kombe                Zambia
#
#                            Email         Phone Account Status  \
# 1            mckbonnie@gmail.com   61424459581         ACTIVE
# 2        jackfoster1@live.com.au   61411823985         ACTIVE
# 3    townsendgardening@gmail.com   61409996631         ACTIVE
# 4       cheethamjessie@gmail.com   61410435943         ACTIVE
# 5             r2889@yahoo.com.au   61407989238         ACTIVE
# ..                           ...           ...            ...
# 747          jacoankia@gmail.com  886974015151         ACTIVE
# 748          jk.jacob@icloud.com  971528742651         ACTIVE
# 749      haddadahmed35@yahoo.com  971504965033         ACTIVE
# 778       timgates6074@gmail.com   12513258795         ACTIVE
# 779       terencekombe@gmail.com  260966547168         ACTIVE
#
#        Servicing Office     Karma Club Program
# 1    KC EXPERIENCE Bali  Petitenget Sales Deck
# 2    KC EXPERIENCE Bali  Petitenget Sales Deck
# 3    KC EXPERIENCE Bali  Petitenget Sales Deck
# 4    KC EXPERIENCE Bali  Petitenget Sales Deck
# 5    KC EXPERIENCE Bali  Petitenget Sales Deck
# ..                  ...                    ...
# 747  KC EXPERIENCE Bali     Vietnam Sales Deck
# 748  KC EXPERIENCE Bali    Jimbaran Sales Deck
# 749  KC EXPERIENCE Bali    Jimbaran Sales Deck
# 778  KC EXPERIENCE Bali     Vietnam Sales Deck
# 779  KC EXPERIENCE Bali  Petitenget Sales Deck
#
# [144 rows x 9 columns]

# %%
df_kce.loc[df_kce['Country'].str.contains('India'), 'Area'] = 'India'
df_kce.loc[df_kce['Country'].isin(list_UK_EU), 'Area'] = 'UK EU'
df_kce.loc[df_kce['Country'].isin(list_Others), 'Area'] = 'Others'

# %%
df_kce.loc[df_kce['Area'] == 'India', 'Batch'] = 'INDIA'
df_kce.loc[df_kce['Area'] == 'UK EU', 'Batch'] = 'NONINDIA'
df_kce.loc[df_kce['Area'] == 'Others', 'Batch'] = 'NONINDIA'

# %%
df_kce.replace('empty', '', inplace=True)

# %%
df_kce.columns
# Out:
# Index(['number', 'FirstName', 'lastname', 'Country', 'Email', 'Phone',
#        'Account Status', 'Servicing Office', 'Karma Club Program', 'Area',
#        'Batch'],
#       dtype='object')

# %%
new_cols = ['number', 'FirstName', 'lastname', 'Country', 'Area', 'Batch', 'Email', 'Phone',
       'Account Status', 'Servicing Office', 'Karma Club Program']

df_kce = df_kce.reindex(columns=new_cols)

# %%
count_data_akhir = df_kce.shape[0]

df_kce.to_csv(r'C:\Users\fajar\Documents\Python\Data\final_kce.csv', index=False)

# %%
print("==========================================================")
print("Summary")
print("==========================================================")
print("Jumlah Data Awal KCE CC-CL : "+str(count_data_awal))
print("Jumlah Data Email dan Phone Kosong : "+str(count_email_phone_empty))
print("Jumlah Data Setelah Hapus Email dan Phone Yang Kosong : "+str(count_after_email_phone_empty))
print("Jumlah Lead Test : "+str(count_leads_test))
print("Jumlah Setelah Clean Lead Test : "+str(count_after_dedup_test))
print("Jumlah Email Karma : "+str(count_email_karma))
print("Jumlah Setelah Clean Email Karma : "+str(count_after_clean_karma))
print("Jumlah Data Yang Terkena Dedup Member Oddysey : "+str(count_dedup_member_odd))
print("Jumlah Data Setelah Dedup Member Oddysey : "+str(count_after_dedup_member_odd))
print("Jumlah Data Yang Terkena Dedup Past Guest KCE : "+str(count_dedup_member_kce))
print("Jumlah Data Setelah Dedup Past Guest KCE : "+str(count_after_dedup_member_kce))
print("Jumlah Data Yang Duplicate : "+str(count_duplicate_general))
print("Jumlah Data Setelah Hapus Duplicate : "+str(count_after_dedup_duplicate))
print("Jumlah Data Akhir : "+str(count_data_akhir))
# Out:
# ==========================================================
# Summary
# ==========================================================
# Jumlah Data Awal KCE CC-CL : 933
# Jumlah Data Email dan Phone Kosong : 3
# Jumlah Data Setelah Hapus Email dan Phone Yang Kosong : 930
# Jumlah Lead Test : 0
# Jumlah Setelah Clean Lead Test : 930
# Jumlah Email Karma : 0
# Jumlah Setelah Clean Email Karma : 930
# Jumlah Data Yang Terkena Dedup Member Oddysey : 13
# Jumlah Data Setelah Dedup Member Oddysey : 917
# Jumlah Data Yang Terkena Dedup Past Guest KCE : 132
# Jumlah Data Setelah Dedup Past Guest KCE : 785
# Jumlah Data Yang Duplicate : 0
# Jumlah Data Setelah Hapus Duplicate : 785
# Jumlah Data Akhir : 785
