# %%
import pandas as pd
import re

import past_guest_module as pm

import sys
sys.path.append('../zoho_data_app/')

import main_module as m

# %load_ext autoreload
# %autoreload 2

# %%
path = r'C:\Users\fajar\Documents\Python\Data\Past Guest Data\Zoho Analytic\2024\Aug\11 Aug - 19 Aug\CRM_Rental_Report_11_Aug_-_19_Aug.xlsx'
df_analytic = pd.read_excel(path, dtype='string', sheet_name='Sheet1')
count_data_awal = df_analytic.shape[0]
df_analytic
# Out:
#    Booking_Id              TelNo       MobileNo  \
# 0    KK054679               <NA>           <NA>
# 1    KB036990   +49 1523 4115575           <NA>
# 2   KSH013109               <NA>           <NA>
# 3   KSM012328   +39 348 856 6393           <NA>
# 4    KB043815       +49080266080  4915252705825
# ..        ...                ...            ...
# 84   KK044997       +61428916843           <NA>
# 85   KB041614               <NA>           <NA>
# 86   KB043833  +33 6 78 73 22 07           <NA>
# 87   KB043124    +49 173 5764742           <NA>
# 88   KB042840   +49 176 34165098           <NA>
#
#                              Email     Lead Brand Lead Sub- Brand  \
# 0         alanamcuthbert@gmail.com  Karma Resorts           Other
# 1       alexander1988franke@web.de  Karma Resorts           Other
# 2      amanda.walters007@gmail.com  Karma Resorts           Other
# 3              anndeclara@alice.ir  Karma Resorts           Other
# 4   axel.reimlinger@karmagroup.com  Karma Resorts           Other
# ..                             ...            ...             ...
# 84                            <NA>  Karma Resorts           Other
# 85                            <NA>  Karma Resorts           Other
# 86                            <NA>  Karma Resorts           Other
# 87                            <NA>  Karma Resorts           Other
# 88                            <NA>  Karma Resorts           Other
#
#     Lead Source         Resort_Name ProfileRef Salutation  ...  \
# 0   Past Guests       Karma Kandara   PF271164        Mrs  ...
# 1   Past Guests       Karma Bavaria   PF248952       Herr  ...
# 2   Past Guests  Karma Salford Hall   PF244371        Mrs  ...
# 3   Past Guests    Karma St Martins   PF268671        Mrs  ...
# 4   Past Guests       Karma Bavaria   PF126784       Herr  ...
# ..          ...                 ...        ...        ...  ...
# 84  Past Guests       Karma Kandara   PF253055         Ms  ...
# 85  Past Guests       Karma Bavaria   PF282161       Frau  ...
# 86  Past Guests       Karma Bavaria   PF273258        Mrs  ...
# 87  Past Guests       Karma Bavaria   PF278376       Herr  ...
# 88  Past Guests       Karma Bavaria   PF276562       Herr  ...
#
#              DateDepart No. of Nights Market_Segment Media_Code  \
# 0   2024-08-12 00:00:00             2            DIR       CHAT
# 1   2024-08-11 00:00:00             3            OTA        OTA
# 2   2024-08-19 00:00:00             2            DIR    WEDDING
# 3   2024-08-11 00:00:00             2            OTA        OTA
# 4   2024-08-12 00:00:00             1           COMP      STAFF
# ..                  ...           ...            ...        ...
# 84  2024-08-16 00:00:00             4            OTA        OTA
# 85  2024-08-11 00:00:00             1            OTA        OTA
# 86  2024-08-13 00:00:00             1           COMP         TA
# 87  2024-08-11 00:00:00             1            OTA        OTA
# 88  2024-08-11 00:00:00             3            OTA        OTA
#
#    Media Code Group No. of Adult No. of Children No. of Infants Contact Type  \
# 0           DIGITAL            6               0              0
# 1            RETAIL            2               1              1
# 2             GROUP            2               0              0
# 3            RETAIL            2               0              0
# 4              COMP            1               0              0
# ..              ...          ...             ...            ...          ...
# 84           RETAIL            7               0              0
# 85           RETAIL            4               0              0
# 86           RETAIL            2               0              0
# 87           RETAIL            2               0              0
# 88           RETAIL            2               0              0
#
#    Odyssey Members
# 0
# 1
# 2
# 3
# 4
# ..             ...
# 84
# 85
# 86
# 87
# 88
#
# [89 rows x 37 columns]

# %%
df_analytic.columns
# Out:
# Index(['Booking_Id', 'TelNo', 'MobileNo', 'Email', 'Lead Brand',
#        'Lead Sub- Brand', 'Lead Source', 'Resort_Name', 'ProfileRef',
#        'Salutation', 'First_Name', 'Surname', 'Gender', 'Language', 'DOB',
#        'Street', 'Area', 'Town', 'County', 'Country', 'Nationality',
#        'PostCode', 'Exclude From Mailing', 'Opt In', 'Booking Code',
#        'Booking Status', 'DateArrival', 'DateDepart', 'No. of Nights',
#        'Market_Segment', 'Media_Code', 'Media Code Group', 'No. of Adult',
#        'No. of Children', 'No. of Infants', 'Contact Type', 'Odyssey Members'],
#       dtype='object')

# %%
new_cols = ['Booking_Id', 'Lead Brand', 'Lead Sub- Brand', 'Lead Source',
       'Resort_Name', 'ProfileRef', 'Salutation', 'First_Name', 'Surname',
       'Gender', 'Language', 'DOB', 'Street', 'Area', 'Town', 'County',
       'Country', 'Nationality', 'PostCode', 'TelNo', 'MobileNo', 'Email',
       'Exclude From Mailing', 'Opt In', 'Booking Status',
       'DateArrival', 'DateDepart', 'No. of Nights', 'Market_Segment',
       'Media_Code', 'Media Code Group', 'No. of Adult', 'No. of Children',
       'No. of Infants', 'Contact Type', 'Odyssey Members']																																																																																																																																						

df_analytic = df_analytic.reindex(columns=new_cols)

# %%
df_analytic.fillna('empty', inplace=True)
df_analytic['Contact Type'] = 'empty'
df_analytic['Odyssey Members'] = 'NO'

# %%
df_analytic.loc[df_analytic['Surname'] == 'empty', 'Surname'] = '-'

# %%
df_analytic['Salutation'].replace('empty', '', inplace=True)
df_analytic['First_Name'].replace('empty', '', inplace=True)
df_analytic['Surname'].replace('empty', '', inplace=True)

df_analytic['Salutation'] = df_analytic['Salutation'].str.title()
df_analytic['First_Name'] = df_analytic['First_Name'].str.title()
df_analytic['Surname'] = df_analytic['Surname'].str.title()

df_analytic
# Out:
#    Booking_Id     Lead Brand Lead Sub- Brand  Lead Source         Resort_Name  \
# 0    KK054679  Karma Resorts           Other  Past Guests       Karma Kandara
# 1    KB036990  Karma Resorts           Other  Past Guests       Karma Bavaria
# 2   KSH013109  Karma Resorts           Other  Past Guests  Karma Salford Hall
# 3   KSM012328  Karma Resorts           Other  Past Guests    Karma St Martins
# 4    KB043815  Karma Resorts           Other  Past Guests       Karma Bavaria
# ..        ...            ...             ...          ...                 ...
# 84   KK044997  Karma Resorts           Other  Past Guests       Karma Kandara
# 85   KB041614  Karma Resorts           Other  Past Guests       Karma Bavaria
# 86   KB043833  Karma Resorts           Other  Past Guests       Karma Bavaria
# 87   KB043124  Karma Resorts           Other  Past Guests       Karma Bavaria
# 88   KB042840  Karma Resorts           Other  Past Guests       Karma Bavaria
#
#    ProfileRef Salutation   First_Name     Surname   Gender  ...  \
# 0    PF271164        Mrs        Alana    Cuthbert   Female  ...
# 1    PF248952       Herr    Alexander      Franke     Male  ...
# 2    PF244371        Mrs       Amanda     Walters   Female  ...
# 3    PF268671        Mrs     Isabella     Dascola  Unknown  ...
# 4    PF126784       Herr         Axel  Reimlinger     Male  ...
# ..        ...        ...          ...         ...      ...  ...
# 84   PF253055         Ms         Rose     Mannion   Female  ...
# 85   PF282161       Frau        Julia       Drees  Unknown  ...
# 86   PF273258        Mrs    Charlotte    Vesselle  Unknown  ...
# 87   PF278376       Herr        Elmar     Schobel     Male  ...
# 88   PF276562       Herr  Josef Peter      Mertes     Male  ...
#
#              DateDepart No. of Nights Market_Segment Media_Code  \
# 0   2024-08-12 00:00:00             2            DIR       CHAT
# 1   2024-08-11 00:00:00             3            OTA        OTA
# 2   2024-08-19 00:00:00             2            DIR    WEDDING
# 3   2024-08-11 00:00:00             2            OTA        OTA
# 4   2024-08-12 00:00:00             1           COMP      STAFF
# ..                  ...           ...            ...        ...
# 84  2024-08-16 00:00:00             4            OTA        OTA
# 85  2024-08-11 00:00:00             1            OTA        OTA
# 86  2024-08-13 00:00:00             1           COMP         TA
# 87  2024-08-11 00:00:00             1            OTA        OTA
# 88  2024-08-11 00:00:00             3            OTA        OTA
#
#    Media Code Group No. of Adult No. of Children No. of Infants Contact Type  \
# 0           DIGITAL            6               0              0        empty
# 1            RETAIL            2               1              1        empty
# 2             GROUP            2               0              0        empty
# 3            RETAIL            2               0              0        empty
# 4              COMP            1               0              0        empty
# ..              ...          ...             ...            ...          ...
# 84           RETAIL            7               0              0        empty
# 85           RETAIL            4               0              0        empty
# 86           RETAIL            2               0              0        empty
# 87           RETAIL            2               0              0        empty
# 88           RETAIL            2               0              0        empty
#
#    Odyssey Members
# 0               NO
# 1               NO
# 2               NO
# 3               NO
# 4               NO
# ..             ...
# 84              NO
# 85              NO
# 86              NO
# 87              NO
# 88              NO
#
# [89 rows x 36 columns]

# %%
m.clean_number(df_analytic, 'TelNo')
m.clean_number(df_analytic, 'MobileNo')
m.replace_not_valid_to_empty(df_analytic, 'TelNo')
m.replace_not_valid_to_empty(df_analytic, 'MobileNo')

df_analytic.loc[df_analytic['TelNo'].str.contains('00000'), 'TelNo'] = 'empty'
df_analytic.loc[df_analytic['MobileNo'].str.contains('00000'), 'MobileNo'] = 'empty'

m.clean_space(df_analytic, 'Email')
df_analytic['Email'] = m.lowercase(df_analytic, 'Email')

# %%
pm.email_correction(df_analytic, 'Email')

# %%
df_analytic.loc[(df_analytic['Email'] != 'empty') & ((df_analytic['TelNo'] != 'empty') | (df_analytic['MobileNo'] != 'empty')), 'Contact Type'] = 'Email and Phone'
df_analytic.loc[(df_analytic['Email'] != 'empty') & ((df_analytic['TelNo'] == 'empty') & (df_analytic['MobileNo'] == 'empty')), 'Contact Type'] = 'Email Only'
df_analytic.loc[(df_analytic['Email'] == 'empty') & ((df_analytic['TelNo'] != 'empty') | (df_analytic['MobileNo'] != 'empty')), 'Contact Type'] = 'Phone Only'

df_analytic.loc[df_analytic['Contact Type'] == 'empty'].to_csv(r'C:\Users\fajar\Documents\Python\Data\contact_type_empty_analytic.csv', index=False)

count_contact_type_empty = df_analytic.loc[df_analytic['Contact Type'] == 'empty'].shape[0]

df_analytic.drop(df_analytic.loc[df_analytic['Contact Type'] == 'empty'].index, inplace=True)
df_analytic.reset_index(drop=True, inplace=True)

count_after_contact_type_empty = df_analytic.shape[0]

df_analytic
# Out:
#    Booking_Id     Lead Brand Lead Sub- Brand  Lead Source         Resort_Name  \
# 0    KK054679  Karma Resorts           Other  Past Guests       Karma Kandara
# 1    KB036990  Karma Resorts           Other  Past Guests       Karma Bavaria
# 2   KSH013109  Karma Resorts           Other  Past Guests  Karma Salford Hall
# 3   KSM012328  Karma Resorts           Other  Past Guests    Karma St Martins
# 4    KB043815  Karma Resorts           Other  Past Guests       Karma Bavaria
# ..        ...            ...             ...          ...                 ...
# 63   KK054540  Karma Resorts           Other  Past Guests       Karma Kandara
# 64   KK044997  Karma Resorts           Other  Past Guests       Karma Kandara
# 65   KB043833  Karma Resorts           Other  Past Guests       Karma Bavaria
# 66   KB043124  Karma Resorts           Other  Past Guests       Karma Bavaria
# 67   KB042840  Karma Resorts           Other  Past Guests       Karma Bavaria
#
#    ProfileRef Salutation   First_Name     Surname   Gender  ...  \
# 0    PF271164        Mrs        Alana    Cuthbert   Female  ...
# 1    PF248952       Herr    Alexander      Franke     Male  ...
# 2    PF244371        Mrs       Amanda     Walters   Female  ...
# 3    PF268671        Mrs     Isabella     Dascola  Unknown  ...
# 4    PF126784       Herr         Axel  Reimlinger     Male  ...
# ..        ...        ...          ...         ...      ...  ...
# 63   PF270867        Mrs        Elias       Copin   Female  ...
# 64   PF253055         Ms         Rose     Mannion   Female  ...
# 65   PF273258        Mrs    Charlotte    Vesselle  Unknown  ...
# 66   PF278376       Herr        Elmar     Schobel     Male  ...
# 67   PF276562       Herr  Josef Peter      Mertes     Male  ...
#
#              DateDepart No. of Nights Market_Segment Media_Code  \
# 0   2024-08-12 00:00:00             2            DIR       CHAT
# 1   2024-08-11 00:00:00             3            OTA        OTA
# 2   2024-08-19 00:00:00             2            DIR    WEDDING
# 3   2024-08-11 00:00:00             2            OTA        OTA
# 4   2024-08-12 00:00:00             1           COMP      STAFF
# ..                  ...           ...            ...        ...
# 63  2024-08-13 00:00:00             2            OTA        OTA
# 64  2024-08-16 00:00:00             4            OTA        OTA
# 65  2024-08-13 00:00:00             1           COMP         TA
# 66  2024-08-11 00:00:00             1            OTA        OTA
# 67  2024-08-11 00:00:00             3            OTA        OTA
#
#    Media Code Group No. of Adult No. of Children No. of Infants  \
# 0           DIGITAL            6               0              0
# 1            RETAIL            2               1              1
# 2             GROUP            2               0              0
# 3            RETAIL            2               0              0
# 4              COMP            1               0              0
# ..              ...          ...             ...            ...
# 63           RETAIL            6               2              0
# 64           RETAIL            7               0              0
# 65           RETAIL            2               0              0
# 66           RETAIL            2               0              0
# 67           RETAIL            2               0              0
#
#        Contact Type Odyssey Members
# 0        Email Only              NO
# 1   Email and Phone              NO
# 2        Email Only              NO
# 3   Email and Phone              NO
# 4   Email and Phone              NO
# ..              ...             ...
# 63       Phone Only              NO
# 64       Phone Only              NO
# 65       Phone Only              NO
# 66       Phone Only              NO
# 67       Phone Only              NO
#
# [68 rows x 36 columns]

# %%
# Cek Email Karma
email_karma = m.find_karma(df_analytic, 'Email')
count_email_karma = email_karma.shape[0]
email_karma.to_csv(r'C:\Users\fajar\Documents\Python\Data\email_deleted_analytic.csv', index=False)

email_karma
# Out:
#    Booking_Id     Lead Brand Lead Sub- Brand  Lead Source  \
# 4    KB043815  Karma Resorts           Other  Past Guests
# 24   KB043236  Karma Resorts           Other  Past Guests
# 25   KB043108  Karma Resorts           Other  Past Guests
# 35   KB041658  Karma Resorts           Other  Past Guests
# 42  KLM005862  Karma Resorts           Other  Past Guests
#
#                Resort_Name ProfileRef Salutation First_Name     Surname  \
# 4            Karma Bavaria   PF126784       Herr       Axel  Reimlinger
# 24           Karma Bavaria   PF278254        Mrs     Maryna    Voranava
# 25           Karma Bavaria   PF278254        Mrs     Maryna    Voranava
# 35           Karma Bavaria   PF112154       Herr  Sebastian      Möller
# 42  Karma Lake of Menteith   PF076160         Mr        Vic    Faulkner
#
#     Gender  ...           DateDepart No. of Nights Market_Segment Media_Code  \
# 4     Male  ...  2024-08-12 00:00:00             1           COMP      STAFF
# 24  Female  ...  2024-08-11 00:00:00             6           COMP      STAFF
# 25  Female  ...  2024-08-12 00:00:00             8           COMP      STAFF
# 35    Male  ...  2024-08-11 00:00:00             7           COMP      STAFF
# 42    Male  ...  2024-08-11 00:00:00             4           COMP        VIP
#
#    Media Code Group No. of Adult No. of Children No. of Infants  \
# 4              COMP            1               0              0
# 24             COMP            1               0              0
# 25             COMP            1               0              0
# 35             COMP            2               2              0
# 42             COMP            2               0              0
#
#        Contact Type Odyssey Members
# 4   Email and Phone              NO
# 24       Email Only              NO
# 25       Email Only              NO
# 35  Email and Phone              NO
# 42  Email and Phone              NO
#
# [5 rows x 36 columns]

# %%
# delete email Karma
count_after_clean_karma = m.delete_karma(df_analytic, 'Email')

df_analytic
# Out:
#    Booking_Id     Lead Brand Lead Sub- Brand  Lead Source         Resort_Name  \
# 0    KK054679  Karma Resorts           Other  Past Guests       Karma Kandara
# 1    KB036990  Karma Resorts           Other  Past Guests       Karma Bavaria
# 2   KSH013109  Karma Resorts           Other  Past Guests  Karma Salford Hall
# 3   KSM012328  Karma Resorts           Other  Past Guests    Karma St Martins
# 4    KB043092  Karma Resorts           Other  Past Guests       Karma Bavaria
# ..        ...            ...             ...          ...                 ...
# 58   KK054540  Karma Resorts           Other  Past Guests       Karma Kandara
# 59   KK044997  Karma Resorts           Other  Past Guests       Karma Kandara
# 60   KB043833  Karma Resorts           Other  Past Guests       Karma Bavaria
# 61   KB043124  Karma Resorts           Other  Past Guests       Karma Bavaria
# 62   KB042840  Karma Resorts           Other  Past Guests       Karma Bavaria
#
#    ProfileRef Salutation   First_Name     Surname   Gender  ...  \
# 0    PF271164        Mrs        Alana    Cuthbert   Female  ...
# 1    PF248952       Herr    Alexander      Franke     Male  ...
# 2    PF244371        Mrs       Amanda     Walters   Female  ...
# 3    PF268671        Mrs     Isabella     Dascola  Unknown  ...
# 4    PF278114       Herr        David  Eisenbeiss     Male  ...
# ..        ...        ...          ...         ...      ...  ...
# 58   PF270867        Mrs        Elias       Copin   Female  ...
# 59   PF253055         Ms         Rose     Mannion   Female  ...
# 60   PF273258        Mrs    Charlotte    Vesselle  Unknown  ...
# 61   PF278376       Herr        Elmar     Schobel     Male  ...
# 62   PF276562       Herr  Josef Peter      Mertes     Male  ...
#
#              DateDepart No. of Nights Market_Segment Media_Code  \
# 0   2024-08-12 00:00:00             2            DIR       CHAT
# 1   2024-08-11 00:00:00             3            OTA        OTA
# 2   2024-08-19 00:00:00             2            DIR    WEDDING
# 3   2024-08-11 00:00:00             2            OTA        OTA
# 4   2024-08-11 00:00:00             2            OTA        OTA
# ..                  ...           ...            ...        ...
# 58  2024-08-13 00:00:00             2            OTA        OTA
# 59  2024-08-16 00:00:00             4            OTA        OTA
# 60  2024-08-13 00:00:00             1           COMP         TA
# 61  2024-08-11 00:00:00             1            OTA        OTA
# 62  2024-08-11 00:00:00             3            OTA        OTA
#
#    Media Code Group No. of Adult No. of Children No. of Infants  \
# 0           DIGITAL            6               0              0
# 1            RETAIL            2               1              1
# 2             GROUP            2               0              0
# 3            RETAIL            2               0              0
# 4            RETAIL            2               0              0
# ..              ...          ...             ...            ...
# 58           RETAIL            6               2              0
# 59           RETAIL            7               0              0
# 60           RETAIL            2               0              0
# 61           RETAIL            2               0              0
# 62           RETAIL            2               0              0
#
#        Contact Type Odyssey Members
# 0        Email Only              NO
# 1   Email and Phone              NO
# 2        Email Only              NO
# 3   Email and Phone              NO
# 4   Email and Phone              NO
# ..              ...             ...
# 58       Phone Only              NO
# 59       Phone Only              NO
# 60       Phone Only              NO
# 61       Phone Only              NO
# 62       Phone Only              NO
#
# [63 rows x 36 columns]

# %%
df_analytic['Salutation']
# Out:
# 0      Mrs
# 1     Herr
# 2      Mrs
# 3      Mrs
# 4     Herr
#       ...
# 58     Mrs
# 59      Ms
# 60     Mrs
# 61    Herr
# 62    Herr
# Name: Salutation, Length: 63, dtype: string

# %%
# Cek leads test
test_leads = df_analytic.loc[
    
        df_analytic['Email'].str.contains('^test@', flags=re.I, regex=True) |
        df_analytic['Email'].str.contains('\+test', flags=re.I, regex=True) |
    
        df_analytic['First_Name'].str.contains('^test$', flags=re.I, regex=True) |
        df_analytic['Surname'].str.contains('^test$', flags=re.I, regex=True) |

        df_analytic['First_Name'].str.contains('test 1', flags=re.I, regex=True) |
        df_analytic['Surname'].str.contains('test 2', flags=re.I, regex=True)|
        df_analytic['First_Name'].str.contains('test1', flags=re.I, regex=True) |
        df_analytic['Surname'].str.contains('test2', flags=re.I, regex=True)|

        df_analytic['First_Name'].str.contains(' test ', flags=re.I, regex=True) | 
        df_analytic['Surname'].str.contains(' test ', flags=re.I, regex=True) | 
        df_analytic['Surname'].str.contains(' test$', flags=re.I, regex=True)
    ]

count_leads_test = test_leads.shape[0]

test_leads.to_csv(r'C:\Users\fajar\Documents\Python\Data\test_leads_analytic.csv', index=False)
test_leads
# Out:
# Empty DataFrame
# Columns: [Booking_Id, Lead Brand, Lead Sub- Brand, Lead Source, Resort_Name, ProfileRef, Salutation, First_Name, Surname, Gender, Language, DOB, Street, Area, Town, County, Country, Nationality, PostCode, TelNo, MobileNo, Email, Exclude From Mailing, Opt In, Booking Status, DateArrival, DateDepart, No. of Nights, Market_Segment, Media_Code, Media Code Group, No. of Adult, No. of Children, No. of Infants, Contact Type, Odyssey Members]
# Index: []
#
# [0 rows x 36 columns]

# %%
df_analytic.drop(test_leads.index, inplace=True)
df_analytic.reset_index(drop=True, inplace=True)

count_after_dedup_test = df_analytic.shape[0]
count_after_dedup_test
# Out:
# 63

# %%
count_final_data = count_after_dedup_test

# %%
# df_analytic.loc[(df_analytic['Email'] == 'jonmosley6@yahoo.com')]

# %%
df_analytic.replace('empty', '', inplace=True)

# %%
print("==========================================================")
print("Summary")
print("==========================================================")
print("Jumlah Data Awal Zoho Analytic : "+str(count_data_awal))
print("Jumlah Data Email dan Phone Kosong : "+str(count_contact_type_empty))
print("Jumlah Data Setelah Hapus Email dan Phone Yang Kosong : "+str(count_after_contact_type_empty))
print("Jumlah Data Email Yang Termasuk List Karma : "+str(count_email_karma))
print("Jumlah Data Email Setelah List Karma Dihapus : "+str(count_after_clean_karma))
print("Jumlah Data Test : "+str(count_leads_test))
print("Jumlah Data Email Setelah Data Test Dihapus : "+str(count_after_dedup_test))
print("Jumlah Data Akhir : "+str(count_final_data))
# Out:
# ==========================================================
# Summary
# ==========================================================
# Jumlah Data Awal Zoho Analytic : 89
# Jumlah Data Email dan Phone Kosong : 21
# Jumlah Data Setelah Hapus Email dan Phone Yang Kosong : 68
# Jumlah Data Email Yang Termasuk List Karma : 5
# Jumlah Data Email Setelah List Karma Dihapus : 63
# Jumlah Data Test : 0
# Jumlah Data Email Setelah Data Test Dihapus : 63
# Jumlah Data Akhir : 63

# %%
df_analytic.to_excel(r'C:\Users\fajar\Documents\Python\Data\check_country_code_analytic.xlsx', index=False)
