# %%
import pandas as pd
import re

import past_guest_module as pm

import sys
sys.path.append('../zoho_data_app/')

import main_module as m

# %load_ext autoreload
# %autoreload 2

# %%
path = r'C:\Users\fajar\Documents\Python\Data\Past Guest Data\Zoho Analytic\2024\Aug\17 Aug - 2 Sep\CRM_Rental_Report_17_Aug_-_2_Sep.xlsx'
df_analytic = pd.read_excel(path, dtype='string', sheet_name='Sheet1')
count_data_awal = df_analytic.shape[0]
df_analytic
# Out:
#     Booking_Id             TelNo        MobileNo                       Email  \
# 0     KB042159  +49 160 90567400            <NA>         a.dienstbier@web.de
# 1     KB043940     4917652829356  49017652829356  alex.haidacher76@gmail.com
# 2     KB040641       +4990430620    491799725190    Annkulenkampff@gmail.com
# 3     KB043964    +31 6 27175586            <NA>         arengbers@gmail.com
# 4     KB043948      +31639895070            <NA>      arjanmazreku@gmail.com
# ..         ...               ...             ...                         ...
# 146   KB043961              <NA>            <NA>                        <NA>
# 147   KB042794  +49 176 95749514            <NA>                        <NA>
# 148   KB037833   +44 7742 300603            <NA>                        <NA>
# 149   KB044058              <NA>            <NA>                        <NA>
# 150   KB037858  +49 1511 0948487            <NA>                        <NA>
#
#         Lead Brand Lead Sub- Brand  Lead Source    Resort_Name ProfileRef  \
# 0    Karma Resorts           Other  Past Guests  Karma Bavaria   PF135533
# 1    Karma Resorts           Other  Past Guests  Karma Bavaria   PF282939
# 2    Karma Resorts           Other  Past Guests  Karma Bavaria   PF067871
# 3    Karma Resorts           Other  Past Guests  Karma Bavaria   PF283174
# 4    Karma Resorts           Other  Past Guests  Karma Bavaria   PF283077
# ..             ...             ...          ...            ...        ...
# 146  Karma Resorts           Other  Past Guests  Karma Bavaria       <NA>
# 147  Karma Resorts           Other  Past Guests  Karma Bavaria   PF252090
# 148  Karma Resorts           Other  Past Guests  Karma Bavaria   PF252106
# 149  Karma Resorts           Other  Past Guests  Karma Bavaria   PF080008
# 150  Karma Resorts           Other  Past Guests  Karma Bavaria   PF252159
#
#     Salutation  ...           DateDepart No. of Nights Market_Segment  \
# 0         Herr  ...  2024-08-24 00:00:00             5            OTA
# 1         Frau  ...  2024-08-29 00:00:00             4            OTA
# 2         Frau  ...  2024-08-18 00:00:00             7            DIR
# 3          Mrs  ...  2024-08-22 00:00:00             1            OTA
# 4           Mr  ...  2024-08-19 00:00:00             1            DIR
# ..         ...  ...                  ...           ...            ...
# 146       <NA>  ...  2024-08-19 21:00:00             0            LGR
# 147       Frau  ...  2024-08-25 00:00:00             2            DIR
# 148       <NA>  ...  2024-08-25 00:00:00             2            OTA
# 149       <NA>  ...  2024-08-25 17:00:00             0            LGR
# 150       <NA>  ...  2024-08-25 00:00:00             1            OTA
#
#        Media_Code Media Code Group No. of Adult No. of Children  \
# 0             OTA           RETAIL            2               2
# 1             OTA           RETAIL            3               1
# 2    EMAIL_MRKTNG          DIGITAL            1               0
# 3             OTA           RETAIL            2               3
# 4          WALKIN           RETAIL            4               3
# ..            ...              ...          ...             ...
# 146           LGR            GROUP            1               0
# 147           LGR            GROUP            4               0
# 148           OTA           RETAIL            2               0
# 149           LGR            GROUP            1               0
# 150           OTA           RETAIL            2               0
#
#     No. of Infants Contact Type Odyssey Members
# 0                0
# 1                0
# 2                0
# 3                1
# 4                1
# ..             ...          ...             ...
# 146              0
# 147              0
# 148              0
# 149              0
# 150              0
#
# [151 rows x 37 columns]

# %%
df_analytic.columns
# Out:
# Index(['Booking_Id', 'TelNo', 'MobileNo', 'Email', 'Lead Brand',
#        'Lead Sub- Brand', 'Lead Source', 'Resort_Name', 'ProfileRef',
#        'Salutation', 'First_Name', 'Surname', 'Gender', 'Language', 'DOB',
#        'Street', 'Area', 'Town', 'County', 'Country', 'Nationality',
#        'PostCode', 'Exclude From Mailing', 'Opt In', 'Booking Code',
#        'Booking Status', 'DateArrival', 'DateDepart', 'No. of Nights',
#        'Market_Segment', 'Media_Code', 'Media Code Group', 'No. of Adult',
#        'No. of Children', 'No. of Infants', 'Contact Type', 'Odyssey Members'],
#       dtype='object')

# %%
new_cols = ['Booking_Id', 'Lead Brand', 'Lead Sub- Brand', 'Lead Source',
       'Resort_Name', 'ProfileRef', 'Salutation', 'First_Name', 'Surname',
       'Gender', 'Language', 'DOB', 'Street', 'Area', 'Town', 'County',
       'Country', 'Nationality', 'PostCode', 'TelNo', 'MobileNo', 'Email',
       'Exclude From Mailing', 'Opt In', 'Booking Status',
       'DateArrival', 'DateDepart', 'No. of Nights', 'Market_Segment',
       'Media_Code', 'Media Code Group', 'No. of Adult', 'No. of Children',
       'No. of Infants', 'Contact Type', 'Odyssey Members']																																																																																																																																						

df_analytic = df_analytic.reindex(columns=new_cols)

# %%
df_analytic.fillna('empty', inplace=True)
df_analytic['Contact Type'] = 'empty'
df_analytic['Odyssey Members'] = 'NO'

# %%
df_analytic.loc[df_analytic['Surname'] == 'empty', 'Surname'] = '-'

# %%
df_analytic['Salutation'].replace('empty', '', inplace=True)
df_analytic['First_Name'].replace('empty', '', inplace=True)
df_analytic['Surname'].replace('empty', '', inplace=True)

df_analytic['Salutation'] = df_analytic['Salutation'].str.title()
df_analytic['First_Name'] = df_analytic['First_Name'].str.title()
df_analytic['Surname'] = df_analytic['Surname'].str.title()

df_analytic
# Out:
#     Booking_Id     Lead Brand Lead Sub- Brand  Lead Source    Resort_Name  \
# 0     KB042159  Karma Resorts           Other  Past Guests  Karma Bavaria
# 1     KB043940  Karma Resorts           Other  Past Guests  Karma Bavaria
# 2     KB040641  Karma Resorts           Other  Past Guests  Karma Bavaria
# 3     KB043964  Karma Resorts           Other  Past Guests  Karma Bavaria
# 4     KB043948  Karma Resorts           Other  Past Guests  Karma Bavaria
# ..         ...            ...             ...          ...            ...
# 146   KB043961  Karma Resorts           Other  Past Guests  Karma Bavaria
# 147   KB042794  Karma Resorts           Other  Past Guests  Karma Bavaria
# 148   KB037833  Karma Resorts           Other  Past Guests  Karma Bavaria
# 149   KB044058  Karma Resorts           Other  Past Guests  Karma Bavaria
# 150   KB037858  Karma Resorts           Other  Past Guests  Karma Bavaria
#
#     ProfileRef Salutation First_Name         Surname   Gender  ...  \
# 0     PF135533       Herr    Andreas      Dienstbier     Male  ...
# 1     PF282939       Frau  Alexandra       Haidacher   Female  ...
# 2     PF067871       Frau        Ann     Kulenkampff   Female  ...
# 3     PF283174        Mrs       Anne         Engbers   Female  ...
# 4     PF283077         Mr     Fatmir         Mazreku     Male  ...
# ..         ...        ...        ...             ...      ...  ...
# 146      empty                                     -  Unknown  ...
# 147   PF252090       Frau       Anke          Schulz   Female  ...
# 148   PF252106                 Emily       Sandiford  Unknown  ...
# 149   PF080008                   Kea  Marketing Gmbh  Unknown  ...
# 150   PF252159             Katherine         Schwind  Unknown  ...
#
#               DateDepart No. of Nights Market_Segment    Media_Code  \
# 0    2024-08-24 00:00:00             5            OTA           OTA
# 1    2024-08-29 00:00:00             4            OTA           OTA
# 2    2024-08-18 00:00:00             7            DIR  EMAIL_MRKTNG
# 3    2024-08-22 00:00:00             1            OTA           OTA
# 4    2024-08-19 00:00:00             1            DIR        WALKIN
# ..                   ...           ...            ...           ...
# 146  2024-08-19 21:00:00             0            LGR           LGR
# 147  2024-08-25 00:00:00             2            DIR           LGR
# 148  2024-08-25 00:00:00             2            OTA           OTA
# 149  2024-08-25 17:00:00             0            LGR           LGR
# 150  2024-08-25 00:00:00             1            OTA           OTA
#
#     Media Code Group No. of Adult No. of Children No. of Infants Contact Type  \
# 0             RETAIL            2               2              0        empty
# 1             RETAIL            3               1              0        empty
# 2            DIGITAL            1               0              0        empty
# 3             RETAIL            2               3              1        empty
# 4             RETAIL            4               3              1        empty
# ..               ...          ...             ...            ...          ...
# 146            GROUP            1               0              0        empty
# 147            GROUP            4               0              0        empty
# 148           RETAIL            2               0              0        empty
# 149            GROUP            1               0              0        empty
# 150           RETAIL            2               0              0        empty
#
#     Odyssey Members
# 0                NO
# 1                NO
# 2                NO
# 3                NO
# 4                NO
# ..              ...
# 146              NO
# 147              NO
# 148              NO
# 149              NO
# 150              NO
#
# [151 rows x 36 columns]

# %%
m.clean_number(df_analytic, 'TelNo')
m.clean_number(df_analytic, 'MobileNo')
m.replace_not_valid_to_empty(df_analytic, 'TelNo')
m.replace_not_valid_to_empty(df_analytic, 'MobileNo')

df_analytic.loc[df_analytic['TelNo'].str.contains('00000'), 'TelNo'] = 'empty'
df_analytic.loc[df_analytic['MobileNo'].str.contains('00000'), 'MobileNo'] = 'empty'

m.clean_space(df_analytic, 'Email')
df_analytic['Email'] = m.lowercase(df_analytic, 'Email')

# %%
pm.email_correction(df_analytic, 'Email')

# %%
df_analytic.loc[(df_analytic['Email'] != 'empty') & ((df_analytic['TelNo'] != 'empty') | (df_analytic['MobileNo'] != 'empty')), 'Contact Type'] = 'Email and Phone'
df_analytic.loc[(df_analytic['Email'] != 'empty') & ((df_analytic['TelNo'] == 'empty') & (df_analytic['MobileNo'] == 'empty')), 'Contact Type'] = 'Email Only'
df_analytic.loc[(df_analytic['Email'] == 'empty') & ((df_analytic['TelNo'] != 'empty') | (df_analytic['MobileNo'] != 'empty')), 'Contact Type'] = 'Phone Only'

df_analytic.loc[df_analytic['Contact Type'] == 'empty'].to_csv(r'C:\Users\fajar\Documents\Python\Data\contact_type_empty_analytic.csv', index=False)

count_contact_type_empty = df_analytic.loc[df_analytic['Contact Type'] == 'empty'].shape[0]

df_analytic.drop(df_analytic.loc[df_analytic['Contact Type'] == 'empty'].index, inplace=True)
df_analytic.reset_index(drop=True, inplace=True)

count_after_contact_type_empty = df_analytic.shape[0]

df_analytic
# Out:
#     Booking_Id     Lead Brand Lead Sub- Brand  Lead Source    Resort_Name  \
# 0     KB042159  Karma Resorts           Other  Past Guests  Karma Bavaria
# 1     KB043940  Karma Resorts           Other  Past Guests  Karma Bavaria
# 2     KB040641  Karma Resorts           Other  Past Guests  Karma Bavaria
# 3     KB043964  Karma Resorts           Other  Past Guests  Karma Bavaria
# 4     KB043948  Karma Resorts           Other  Past Guests  Karma Bavaria
# ..         ...            ...             ...          ...            ...
# 132   KB042573  Karma Resorts           Other  Past Guests  Karma Bavaria
# 133   KB040786  Karma Resorts           Other  Past Guests  Karma Bavaria
# 134   KB042794  Karma Resorts           Other  Past Guests  Karma Bavaria
# 135   KB037833  Karma Resorts           Other  Past Guests  Karma Bavaria
# 136   KB037858  Karma Resorts           Other  Past Guests  Karma Bavaria
#
#     ProfileRef Salutation First_Name      Surname   Gender  ...  \
# 0     PF135533       Herr    Andreas   Dienstbier     Male  ...
# 1     PF282939       Frau  Alexandra    Haidacher   Female  ...
# 2     PF067871       Frau        Ann  Kulenkampff   Female  ...
# 3     PF283174        Mrs       Anne      Engbers   Female  ...
# 4     PF283077         Mr     Fatmir      Mazreku     Male  ...
# ..         ...        ...        ...          ...      ...  ...
# 132   PF274784             Stephanie      Pangerl  Unknown  ...
# 133   PF265121                Nadine       Oetzel  Unknown  ...
# 134   PF252090       Frau       Anke       Schulz   Female  ...
# 135   PF252106                 Emily    Sandiford  Unknown  ...
# 136   PF252159             Katherine      Schwind  Unknown  ...
#
#               DateDepart No. of Nights Market_Segment    Media_Code  \
# 0    2024-08-24 00:00:00             5            OTA           OTA
# 1    2024-08-29 00:00:00             4            OTA           OTA
# 2    2024-08-18 00:00:00             7            DIR  EMAIL_MRKTNG
# 3    2024-08-22 00:00:00             1            OTA           OTA
# 4    2024-08-19 00:00:00             1            DIR        WALKIN
# ..                   ...           ...            ...           ...
# 132  2024-08-22 00:00:00             2            OTA           OTA
# 133  2024-08-31 00:00:00             1            OTA           OTA
# 134  2024-08-25 00:00:00             2            DIR           LGR
# 135  2024-08-25 00:00:00             2            OTA           OTA
# 136  2024-08-25 00:00:00             1            OTA           OTA
#
#     Media Code Group No. of Adult No. of Children No. of Infants  \
# 0             RETAIL            2               2              0
# 1             RETAIL            3               1              0
# 2            DIGITAL            1               0              0
# 3             RETAIL            2               3              1
# 4             RETAIL            4               3              1
# ..               ...          ...             ...            ...
# 132           RETAIL            2               1              0
# 133           RETAIL            1               0              0
# 134            GROUP            4               0              0
# 135           RETAIL            2               0              0
# 136           RETAIL            2               0              0
#
#         Contact Type Odyssey Members
# 0    Email and Phone              NO
# 1    Email and Phone              NO
# 2    Email and Phone              NO
# 3    Email and Phone              NO
# 4    Email and Phone              NO
# ..               ...             ...
# 132       Phone Only              NO
# 133       Phone Only              NO
# 134       Phone Only              NO
# 135       Phone Only              NO
# 136       Phone Only              NO
#
# [137 rows x 36 columns]

# %%
# Cek Email Karma
email_karma = m.find_karma(df_analytic, 'Email')
count_email_karma = email_karma.shape[0]
email_karma.to_csv(r'C:\Users\fajar\Documents\Python\Data\email_deleted_analytic.csv', index=False)

email_karma
# Out:
#    Booking_Id     Lead Brand Lead Sub- Brand  Lead Source    Resort_Name  \
# 5    KB043525  Karma Resorts           Other  Past Guests  Karma Bavaria
# 12   KB043982  Karma Resorts           Other  Past Guests  Karma Bavaria
# 13   KB044129  Karma Resorts           Other  Past Guests  Karma Bavaria
# 14   KB044090  Karma Resorts           Other  Past Guests  Karma Bavaria
#
#    ProfileRef Salutation First_Name     Surname Gender  ...  \
# 5    PF126784       Herr       Axel  Reimlinger   Male  ...
# 12   PF233671         Mr      Dario   Quinteros   Male  ...
# 13   PF233671         Mr      Dario   Quinteros   Male  ...
# 14   PF159006       Herr     Dennis    Rietveld   Male  ...
#
#              DateDepart No. of Nights Market_Segment Media_Code  \
# 5   2024-08-23 00:00:00             4           COMP      STAFF
# 12  2024-08-22 00:00:00             1           COMP      STAFF
# 13  2024-08-29 00:00:00             1           COMP      STAFF
# 14  2024-09-01 00:00:00             3     STAFF_PRIV      STAFF
#
#    Media Code Group No. of Adult No. of Children No. of Infants  \
# 5              COMP            1               0              0
# 12             COMP            1               3              0
# 13             COMP            1               0              0
# 14             COMP            1               0              0
#
#        Contact Type Odyssey Members
# 5   Email and Phone              NO
# 12  Email and Phone              NO
# 13  Email and Phone              NO
# 14  Email and Phone              NO
#
# [4 rows x 36 columns]

# %%
# delete email Karma
count_after_clean_karma = m.delete_karma(df_analytic, 'Email')

df_analytic
# Out:
#     Booking_Id     Lead Brand Lead Sub- Brand  Lead Source    Resort_Name  \
# 0     KB042159  Karma Resorts           Other  Past Guests  Karma Bavaria
# 1     KB043940  Karma Resorts           Other  Past Guests  Karma Bavaria
# 2     KB040641  Karma Resorts           Other  Past Guests  Karma Bavaria
# 3     KB043964  Karma Resorts           Other  Past Guests  Karma Bavaria
# 4     KB043948  Karma Resorts           Other  Past Guests  Karma Bavaria
# ..         ...            ...             ...          ...            ...
# 128   KB042573  Karma Resorts           Other  Past Guests  Karma Bavaria
# 129   KB040786  Karma Resorts           Other  Past Guests  Karma Bavaria
# 130   KB042794  Karma Resorts           Other  Past Guests  Karma Bavaria
# 131   KB037833  Karma Resorts           Other  Past Guests  Karma Bavaria
# 132   KB037858  Karma Resorts           Other  Past Guests  Karma Bavaria
#
#     ProfileRef Salutation First_Name      Surname   Gender  ...  \
# 0     PF135533       Herr    Andreas   Dienstbier     Male  ...
# 1     PF282939       Frau  Alexandra    Haidacher   Female  ...
# 2     PF067871       Frau        Ann  Kulenkampff   Female  ...
# 3     PF283174        Mrs       Anne      Engbers   Female  ...
# 4     PF283077         Mr     Fatmir      Mazreku     Male  ...
# ..         ...        ...        ...          ...      ...  ...
# 128   PF274784             Stephanie      Pangerl  Unknown  ...
# 129   PF265121                Nadine       Oetzel  Unknown  ...
# 130   PF252090       Frau       Anke       Schulz   Female  ...
# 131   PF252106                 Emily    Sandiford  Unknown  ...
# 132   PF252159             Katherine      Schwind  Unknown  ...
#
#               DateDepart No. of Nights Market_Segment    Media_Code  \
# 0    2024-08-24 00:00:00             5            OTA           OTA
# 1    2024-08-29 00:00:00             4            OTA           OTA
# 2    2024-08-18 00:00:00             7            DIR  EMAIL_MRKTNG
# 3    2024-08-22 00:00:00             1            OTA           OTA
# 4    2024-08-19 00:00:00             1            DIR        WALKIN
# ..                   ...           ...            ...           ...
# 128  2024-08-22 00:00:00             2            OTA           OTA
# 129  2024-08-31 00:00:00             1            OTA           OTA
# 130  2024-08-25 00:00:00             2            DIR           LGR
# 131  2024-08-25 00:00:00             2            OTA           OTA
# 132  2024-08-25 00:00:00             1            OTA           OTA
#
#     Media Code Group No. of Adult No. of Children No. of Infants  \
# 0             RETAIL            2               2              0
# 1             RETAIL            3               1              0
# 2            DIGITAL            1               0              0
# 3             RETAIL            2               3              1
# 4             RETAIL            4               3              1
# ..               ...          ...             ...            ...
# 128           RETAIL            2               1              0
# 129           RETAIL            1               0              0
# 130            GROUP            4               0              0
# 131           RETAIL            2               0              0
# 132           RETAIL            2               0              0
#
#         Contact Type Odyssey Members
# 0    Email and Phone              NO
# 1    Email and Phone              NO
# 2    Email and Phone              NO
# 3    Email and Phone              NO
# 4    Email and Phone              NO
# ..               ...             ...
# 128       Phone Only              NO
# 129       Phone Only              NO
# 130       Phone Only              NO
# 131       Phone Only              NO
# 132       Phone Only              NO
#
# [133 rows x 36 columns]

# %%
df_analytic['Salutation']
# Out:
# 0      Herr
# 1      Frau
# 2      Frau
# 3       Mrs
# 4        Mr
#        ...
# 128
# 129
# 130    Frau
# 131
# 132
# Name: Salutation, Length: 133, dtype: string

# %%
# Cek leads test
test_leads = df_analytic.loc[
    
        df_analytic['Email'].str.contains('^test@', flags=re.I, regex=True) |
        df_analytic['Email'].str.contains('\+test', flags=re.I, regex=True) |
    
        df_analytic['First_Name'].str.contains('^test$', flags=re.I, regex=True) |
        df_analytic['Surname'].str.contains('^test$', flags=re.I, regex=True) |

        df_analytic['First_Name'].str.contains('test 1', flags=re.I, regex=True) |
        df_analytic['Surname'].str.contains('test 2', flags=re.I, regex=True)|
        df_analytic['First_Name'].str.contains('test1', flags=re.I, regex=True) |
        df_analytic['Surname'].str.contains('test2', flags=re.I, regex=True)|

        df_analytic['First_Name'].str.contains(' test ', flags=re.I, regex=True) | 
        df_analytic['Surname'].str.contains(' test ', flags=re.I, regex=True) | 
        df_analytic['Surname'].str.contains(' test$', flags=re.I, regex=True)
    ]

count_leads_test = test_leads.shape[0]

test_leads.to_csv(r'C:\Users\fajar\Documents\Python\Data\test_leads_analytic.csv', index=False)
test_leads
# Out:
# Empty DataFrame
# Columns: [Booking_Id, Lead Brand, Lead Sub- Brand, Lead Source, Resort_Name, ProfileRef, Salutation, First_Name, Surname, Gender, Language, DOB, Street, Area, Town, County, Country, Nationality, PostCode, TelNo, MobileNo, Email, Exclude From Mailing, Opt In, Booking Status, DateArrival, DateDepart, No. of Nights, Market_Segment, Media_Code, Media Code Group, No. of Adult, No. of Children, No. of Infants, Contact Type, Odyssey Members]
# Index: []
#
# [0 rows x 36 columns]

# %%
df_analytic.drop(test_leads.index, inplace=True)
df_analytic.reset_index(drop=True, inplace=True)

count_after_dedup_test = df_analytic.shape[0]
count_after_dedup_test
# Out:
# 133

# %%
count_final_data = count_after_dedup_test

# %%
# df_analytic.loc[(df_analytic['Email'] == 'jonmosley6@yahoo.com')]

# %%
df_analytic.replace('empty', '', inplace=True)

# %%
print("==========================================================")
print("Summary")
print("==========================================================")
print("Jumlah Data Awal Zoho Analytic : "+str(count_data_awal))
print("Jumlah Data Email dan Phone Kosong : "+str(count_contact_type_empty))
print("Jumlah Data Setelah Hapus Email dan Phone Yang Kosong : "+str(count_after_contact_type_empty))
print("Jumlah Data Email Yang Termasuk List Karma : "+str(count_email_karma))
print("Jumlah Data Email Setelah List Karma Dihapus : "+str(count_after_clean_karma))
print("Jumlah Data Test : "+str(count_leads_test))
print("Jumlah Data Email Setelah Data Test Dihapus : "+str(count_after_dedup_test))
print("Jumlah Data Akhir : "+str(count_final_data))
# Out:
# ==========================================================
# Summary
# ==========================================================
# Jumlah Data Awal Zoho Analytic : 151
# Jumlah Data Email dan Phone Kosong : 14
# Jumlah Data Setelah Hapus Email dan Phone Yang Kosong : 137
# Jumlah Data Email Yang Termasuk List Karma : 4
# Jumlah Data Email Setelah List Karma Dihapus : 133
# Jumlah Data Test : 0
# Jumlah Data Email Setelah Data Test Dihapus : 133
# Jumlah Data Akhir : 133

# %%
df_analytic.to_excel(r'C:\Users\fajar\Documents\Python\Data\check_country_code_analytic.xlsx', index=False)
