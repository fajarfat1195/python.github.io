# %%
import pandas as pd
import re

import past_guest_module as pm

import sys
sys.path.append('../zoho_data_app/')

import main_module as m

# %load_ext autoreload
# %autoreload 2

# %%
path = r'C:\Users\fajar\Documents\Python\Data\Past Guest Data\Zoho Analytic\2024\Sep\8 Sep - 13 Sep\CRM_Rental_Report_8_Sep_-_13_Sep.xlsx'
df_analytic = pd.read_excel(path, dtype='string', sheet_name='Sheet1')
count_data_awal = df_analytic.shape[0]
df_analytic
# Out:
#     Booking_Id             TelNo MobileNo                       Email  \
# 0     KK060135       17605965999     <NA>             87001191@qq.com
# 1    KSM013791              <NA>     <NA>      adrianfate@hotmail.com
# 2     KB043913     +353899799704     <NA>           ana.p@live.com.au
# 3    KSM013415       07975908512     <NA>  angiescrisp@btinternet.com
# 4     KB041933   +49 177 6780971     <NA>         anjawee@hotmail.com
# ..         ...               ...      ...                         ...
# 121  KSM011112   +44 7785 919372     <NA>                        <NA>
# 122   KB043555  +49 176 70068396     <NA>                        <NA>
# 123   KB036937              <NA>     <NA>                        <NA>
# 124   KB036603   +49 171 4791167     <NA>                        <NA>
# 125  KLM006180    +31 6 27020026     <NA>                        <NA>
#
#         Lead Brand Lead Sub- Brand  Lead Source             Resort_Name  \
# 0    Karma Resorts           Other  Past Guests           Karma Kandara
# 1    Karma Resorts           Other  Past Guests        Karma St Martins
# 2    Karma Resorts           Other  Past Guests           Karma Bavaria
# 3    Karma Resorts           Other  Past Guests        Karma St Martins
# 4    Karma Resorts           Other  Past Guests           Karma Bavaria
# ..             ...             ...          ...                     ...
# 121  Karma Resorts           Other  Past Guests        Karma St Martins
# 122  Karma Resorts           Other  Past Guests           Karma Bavaria
# 123  Karma Resorts           Other  Past Guests           Karma Bavaria
# 124  Karma Resorts           Other  Past Guests           Karma Bavaria
# 125  Karma Resorts           Other  Past Guests  Karma Lake of Menteith
#
#     ProfileRef Salutation  ...           DateDepart No. of Nights  \
# 0     PF284400         Mr  ...  2024-09-05 00:00:00             4
# 1     PF279572         Mr  ...  2024-09-05 00:00:00             3
# 2     PF284073       Frau  ...  2024-09-05 00:00:00             7
# 3     PF280014        Mrs  ...  2024-09-04 00:00:00             2
# 4     PF171576       <NA>  ...  2024-09-05 00:00:00             3
# ..         ...        ...  ...                  ...           ...
# 121   PF248479       <NA>  ...  2024-09-02 00:00:00             5
# 122   PF267462       <NA>  ...  2024-09-01 00:00:00             1
# 123   PF248758       Herr  ...  2024-09-08 22:00:00             0
# 124   PF247291       <NA>  ...  2024-09-06 00:00:00             1
# 125   PF281769       <NA>  ...  2024-09-05 00:00:00             2
#
#     Market_Segment   Media_Code Media Code Group No. of Adult No. of Children  \
# 0        HOUSE_USE  V_OWNER_NRB             COMP            5               0
# 1             COMP        STAFF             COMP            1               0
# 2          WYNDHAM      WYNDHAM          WYNDHAM            1               0
# 3              DIR      WEBSITE          DIGITAL            2               0
# 4              OTA          OTA           RETAIL            3               2
# ..             ...          ...              ...          ...             ...
# 121            OTA          OTA           RETAIL            2               0
# 122            OTA          OTA           RETAIL            3               0
# 123             CB           CB            GROUP            1               0
# 124            OTA          OTA           RETAIL            1               0
# 125            OTA          OTA           RETAIL            2               0
#
#     No. of Infants Contact Type Odyssey Members
# 0                0
# 1                0
# 2                0
# 3                0
# 4                0
# ..             ...          ...             ...
# 121              0
# 122              0
# 123              0
# 124              0
# 125              0
#
# [126 rows x 37 columns]

# %%
df_analytic.columns
# Out:
# Index(['Booking_Id', 'TelNo', 'MobileNo', 'Email', 'Lead Brand',
#        'Lead Sub- Brand', 'Lead Source', 'Resort_Name', 'ProfileRef',
#        'Salutation', 'First_Name', 'Surname', 'Gender', 'Language', 'DOB',
#        'Street', 'Area', 'Town', 'County', 'Country', 'Nationality',
#        'PostCode', 'Exclude From Mailing', 'Opt In', 'Booking Code',
#        'Booking Status', 'DateArrival', 'DateDepart', 'No. of Nights',
#        'Market_Segment', 'Media_Code', 'Media Code Group', 'No. of Adult',
#        'No. of Children', 'No. of Infants', 'Contact Type', 'Odyssey Members'],
#       dtype='object')

# %%
new_cols = ['Booking_Id', 'Lead Brand', 'Lead Sub- Brand', 'Lead Source',
       'Resort_Name', 'ProfileRef', 'Salutation', 'First_Name', 'Surname',
       'Gender', 'Language', 'DOB', 'Street', 'Area', 'Town', 'County',
       'Country', 'Nationality', 'PostCode', 'TelNo', 'MobileNo', 'Email',
       'Exclude From Mailing', 'Opt In', 'Booking Status',
       'DateArrival', 'DateDepart', 'No. of Nights', 'Market_Segment',
       'Media_Code', 'Media Code Group', 'No. of Adult', 'No. of Children',
       'No. of Infants', 'Contact Type', 'Odyssey Members']																																																																																																																																						

df_analytic = df_analytic.reindex(columns=new_cols)

# %%
df_analytic.fillna('empty', inplace=True)
df_analytic['Contact Type'] = 'empty'
df_analytic['Odyssey Members'] = 'NO'

# %%
df_analytic.loc[df_analytic['Surname'] == 'empty', 'Surname'] = '-'

# %%
df_analytic['Salutation'].replace('empty', '', inplace=True)
df_analytic['First_Name'].replace('empty', '', inplace=True)
df_analytic['Surname'].replace('empty', '', inplace=True)

df_analytic['Salutation'] = df_analytic['Salutation'].str.title()
df_analytic['First_Name'] = df_analytic['First_Name'].str.title()
df_analytic['Surname'] = df_analytic['Surname'].str.title()

df_analytic
# Out:
#     Booking_Id     Lead Brand Lead Sub- Brand  Lead Source  \
# 0     KK060135  Karma Resorts           Other  Past Guests
# 1    KSM013791  Karma Resorts           Other  Past Guests
# 2     KB043913  Karma Resorts           Other  Past Guests
# 3    KSM013415  Karma Resorts           Other  Past Guests
# 4     KB041933  Karma Resorts           Other  Past Guests
# ..         ...            ...             ...          ...
# 121  KSM011112  Karma Resorts           Other  Past Guests
# 122   KB043555  Karma Resorts           Other  Past Guests
# 123   KB036937  Karma Resorts           Other  Past Guests
# 124   KB036603  Karma Resorts           Other  Past Guests
# 125  KLM006180  Karma Resorts           Other  Past Guests
#
#                 Resort_Name ProfileRef Salutation First_Name      Surname  \
# 0             Karma Kandara   PF284400         Mr        Aqi           Wu
# 1          Karma St Martins   PF279572         Mr     Adrian    Fatechand
# 2             Karma Bavaria   PF284073       Frau      Diana      Pateman
# 3          Karma St Martins   PF280014        Mrs     Angela        Crisp
# 4             Karma Bavaria   PF171576                  Anja          Wee
# ..                      ...        ...        ...        ...          ...
# 121        Karma St Martins   PF248479                 Penny       Porter
# 122           Karma Bavaria   PF267462              Stefanie        Maier
# 123           Karma Bavaria   PF248758       Herr       Karl  Fleischmann
# 124           Karma Bavaria   PF247291               Stephan        Greve
# 125  Karma Lake of Menteith   PF281769                  Hans     Marijnen
#
#       Gender  ...           DateDepart No. of Nights Market_Segment  \
# 0       Male  ...  2024-09-05 00:00:00             4      HOUSE_USE
# 1    Unknown  ...  2024-09-05 00:00:00             3           COMP
# 2     Female  ...  2024-09-05 00:00:00             7        WYNDHAM
# 3    Unknown  ...  2024-09-04 00:00:00             2            DIR
# 4     Female  ...  2024-09-05 00:00:00             3            OTA
# ..       ...  ...                  ...           ...            ...
# 121  Unknown  ...  2024-09-02 00:00:00             5            OTA
# 122  Unknown  ...  2024-09-01 00:00:00             1            OTA
# 123     Male  ...  2024-09-08 22:00:00             0             CB
# 124  Unknown  ...  2024-09-06 00:00:00             1            OTA
# 125  Unknown  ...  2024-09-05 00:00:00             2            OTA
#
#       Media_Code Media Code Group No. of Adult No. of Children No. of Infants  \
# 0    V_OWNER_NRB             COMP            5               0              0
# 1          STAFF             COMP            1               0              0
# 2        WYNDHAM          WYNDHAM            1               0              0
# 3        WEBSITE          DIGITAL            2               0              0
# 4            OTA           RETAIL            3               2              0
# ..           ...              ...          ...             ...            ...
# 121          OTA           RETAIL            2               0              0
# 122          OTA           RETAIL            3               0              0
# 123           CB            GROUP            1               0              0
# 124          OTA           RETAIL            1               0              0
# 125          OTA           RETAIL            2               0              0
#
#     Contact Type Odyssey Members
# 0          empty              NO
# 1          empty              NO
# 2          empty              NO
# 3          empty              NO
# 4          empty              NO
# ..           ...             ...
# 121        empty              NO
# 122        empty              NO
# 123        empty              NO
# 124        empty              NO
# 125        empty              NO
#
# [126 rows x 36 columns]

# %%
m.clean_number(df_analytic, 'TelNo')
m.clean_number(df_analytic, 'MobileNo')
m.replace_not_valid_to_empty(df_analytic, 'TelNo')
m.replace_not_valid_to_empty(df_analytic, 'MobileNo')

df_analytic.loc[df_analytic['TelNo'].str.contains('00000'), 'TelNo'] = 'empty'
df_analytic.loc[df_analytic['MobileNo'].str.contains('00000'), 'MobileNo'] = 'empty'

m.clean_space(df_analytic, 'Email')
df_analytic['Email'] = m.lowercase(df_analytic, 'Email')

# %%
pm.email_correction(df_analytic, 'Email')

# %%
df_analytic.loc[(df_analytic['Email'] != 'empty') & ((df_analytic['TelNo'] != 'empty') | (df_analytic['MobileNo'] != 'empty')), 'Contact Type'] = 'Email and Phone'
df_analytic.loc[(df_analytic['Email'] != 'empty') & ((df_analytic['TelNo'] == 'empty') & (df_analytic['MobileNo'] == 'empty')), 'Contact Type'] = 'Email Only'
df_analytic.loc[(df_analytic['Email'] == 'empty') & ((df_analytic['TelNo'] != 'empty') | (df_analytic['MobileNo'] != 'empty')), 'Contact Type'] = 'Phone Only'

df_analytic.loc[df_analytic['Contact Type'] == 'empty'].to_csv(r'C:\Users\fajar\Documents\Python\Data\contact_type_empty_analytic.csv', index=False)

count_contact_type_empty = df_analytic.loc[df_analytic['Contact Type'] == 'empty'].shape[0]

df_analytic.drop(df_analytic.loc[df_analytic['Contact Type'] == 'empty'].index, inplace=True)
df_analytic.reset_index(drop=True, inplace=True)

count_after_contact_type_empty = df_analytic.shape[0]

df_analytic
# Out:
#     Booking_Id     Lead Brand Lead Sub- Brand  Lead Source  \
# 0     KK060135  Karma Resorts           Other  Past Guests
# 1    KSM013791  Karma Resorts           Other  Past Guests
# 2     KB043913  Karma Resorts           Other  Past Guests
# 3    KSM013415  Karma Resorts           Other  Past Guests
# 4     KB041933  Karma Resorts           Other  Past Guests
# ..         ...            ...             ...          ...
# 105   KK055225  Karma Resorts           Other  Past Guests
# 106  KSM011112  Karma Resorts           Other  Past Guests
# 107   KB043555  Karma Resorts           Other  Past Guests
# 108   KB036603  Karma Resorts           Other  Past Guests
# 109  KLM006180  Karma Resorts           Other  Past Guests
#
#                 Resort_Name ProfileRef Salutation First_Name    Surname  \
# 0             Karma Kandara   PF284400         Mr        Aqi         Wu
# 1          Karma St Martins   PF279572         Mr     Adrian  Fatechand
# 2             Karma Bavaria   PF284073       Frau      Diana    Pateman
# 3          Karma St Martins   PF280014        Mrs     Angela      Crisp
# 4             Karma Bavaria   PF171576                  Anja        Wee
# ..                      ...        ...        ...        ...        ...
# 105           Karma Kandara   PF272380         Ms    Daniela     Georgi
# 106        Karma St Martins   PF248479                 Penny     Porter
# 107           Karma Bavaria   PF267462              Stefanie      Maier
# 108           Karma Bavaria   PF247291               Stephan      Greve
# 109  Karma Lake of Menteith   PF281769                  Hans   Marijnen
#
#       Gender  ...           DateDepart No. of Nights Market_Segment  \
# 0       Male  ...  2024-09-05 00:00:00             4      HOUSE_USE
# 1    Unknown  ...  2024-09-05 00:00:00             3           COMP
# 2     Female  ...  2024-09-05 00:00:00             7        WYNDHAM
# 3    Unknown  ...  2024-09-04 00:00:00             2            DIR
# 4     Female  ...  2024-09-05 00:00:00             3            OTA
# ..       ...  ...                  ...           ...            ...
# 105   Female  ...  2024-09-04 00:00:00             3            OTA
# 106  Unknown  ...  2024-09-02 00:00:00             5            OTA
# 107  Unknown  ...  2024-09-01 00:00:00             1            OTA
# 108  Unknown  ...  2024-09-06 00:00:00             1            OTA
# 109  Unknown  ...  2024-09-05 00:00:00             2            OTA
#
#       Media_Code Media Code Group No. of Adult No. of Children No. of Infants  \
# 0    V_OWNER_NRB             COMP            5               0              0
# 1          STAFF             COMP            1               0              0
# 2        WYNDHAM          WYNDHAM            1               0              0
# 3        WEBSITE          DIGITAL            2               0              0
# 4            OTA           RETAIL            3               2              0
# ..           ...              ...          ...             ...            ...
# 105          OTA           RETAIL            2               1              0
# 106          OTA           RETAIL            2               0              0
# 107          OTA           RETAIL            3               0              0
# 108          OTA           RETAIL            1               0              0
# 109          OTA           RETAIL            2               0              0
#
#         Contact Type Odyssey Members
# 0    Email and Phone              NO
# 1         Email Only              NO
# 2    Email and Phone              NO
# 3    Email and Phone              NO
# 4    Email and Phone              NO
# ..               ...             ...
# 105       Phone Only              NO
# 106       Phone Only              NO
# 107       Phone Only              NO
# 108       Phone Only              NO
# 109       Phone Only              NO
#
# [110 rows x 36 columns]

# %%
# Cek Email Karma
email_karma = m.find_karma(df_analytic, 'Email')
count_email_karma = email_karma.shape[0]
email_karma.to_csv(r'C:\Users\fajar\Documents\Python\Data\email_deleted_analytic.csv', index=False)

email_karma
# Out:
#    Booking_Id     Lead Brand Lead Sub- Brand  Lead Source       Resort_Name  \
# 8    KB043527  Karma Resorts           Other  Past Guests     Karma Bavaria
# 20   KB039533  Karma Resorts           Other  Past Guests     Karma Bavaria
# 21   KB044238  Karma Resorts           Other  Past Guests     Karma Bavaria
# 22   KB044175  Karma Resorts           Other  Past Guests     Karma Bavaria
# 24   KB039534  Karma Resorts           Other  Past Guests     Karma Bavaria
# 25   KB044090  Karma Resorts           Other  Past Guests     Karma Bavaria
# 70  KSM013796  Karma Resorts           Other  Past Guests  Karma St Martins
# 71   KB044102  Karma Resorts           Other  Past Guests     Karma Bavaria
# 72   KB044109  Karma Resorts           Other  Past Guests     Karma Bavaria
# 73   KB044222  Karma Resorts           Other  Past Guests     Karma Bavaria
#
#    ProfileRef Salutation   First_Name     Surname Gender  ...  \
# 8    PF126784       Herr         Axel  Reimlinger   Male  ...
# 20   PF066594         Mr  Christopher     Kindred   Male  ...
# 21   PF233671         Mr        Dario   Quinteros   Male  ...
# 22   PF233671         Mr        Dario   Quinteros   Male  ...
# 24   PF159006       Herr       Dennis    Rietveld   Male  ...
# 25   PF159006       Herr       Dennis    Rietveld   Male  ...
# 70   PF235049         Mr        Karma       Staff   Male  ...
# 71   PF246628         Mr      Ricardo      Coppen   Male  ...
# 72   PF246628         Mr      Ricardo      Coppen   Male  ...
# 73   PF246628         Mr      Ricardo      Coppen   Male  ...
#
#              DateDepart No. of Nights Market_Segment Media_Code  \
# 8   2024-09-06 00:00:00             4           COMP      STAFF
# 20  2024-09-01 00:00:00            31     STAFF_PRIV      STAFF
# 21  2024-09-06 00:00:00             2           COMP      STAFF
# 22  2024-09-02 00:00:00             2           COMP      STAFF
# 24  2024-09-01 00:00:00            31     STAFF_PRIV      STAFF
# 25  2024-09-01 00:00:00             3     STAFF_PRIV      STAFF
# 70  2024-09-05 00:00:00             5           COMP      STAFF
# 71  2024-09-06 00:00:00             1           COMP      STAFF
# 72  2024-09-05 00:00:00             1           COMP      STAFF
# 73  2024-09-06 00:00:00             2     STAFF_PRIV      STAFF
#
#    Media Code Group No. of Adult No. of Children No. of Infants  \
# 8              COMP            1               0              0
# 20             COMP            1               0              0
# 21             COMP            1               0              0
# 22             COMP            2               0              0
# 24             COMP            1               0              0
# 25             COMP            1               0              0
# 70             COMP            1               0              0
# 71             COMP            1               0              0
# 72             COMP            1               0              0
# 73             COMP            1               0              0
#
#        Contact Type Odyssey Members
# 8   Email and Phone              NO
# 20  Email and Phone              NO
# 21  Email and Phone              NO
# 22  Email and Phone              NO
# 24  Email and Phone              NO
# 25  Email and Phone              NO
# 70  Email and Phone              NO
# 71  Email and Phone              NO
# 72  Email and Phone              NO
# 73  Email and Phone              NO
#
# [10 rows x 36 columns]

# %%
# delete email Karma
count_after_clean_karma = m.delete_karma(df_analytic, 'Email')

df_analytic
# Out:
#    Booking_Id     Lead Brand Lead Sub- Brand  Lead Source  \
# 0    KK060135  Karma Resorts           Other  Past Guests
# 1   KSM013791  Karma Resorts           Other  Past Guests
# 2    KB043913  Karma Resorts           Other  Past Guests
# 3   KSM013415  Karma Resorts           Other  Past Guests
# 4    KB041933  Karma Resorts           Other  Past Guests
# ..        ...            ...             ...          ...
# 95   KK055225  Karma Resorts           Other  Past Guests
# 96  KSM011112  Karma Resorts           Other  Past Guests
# 97   KB043555  Karma Resorts           Other  Past Guests
# 98   KB036603  Karma Resorts           Other  Past Guests
# 99  KLM006180  Karma Resorts           Other  Past Guests
#
#                Resort_Name ProfileRef Salutation First_Name    Surname  \
# 0            Karma Kandara   PF284400         Mr        Aqi         Wu
# 1         Karma St Martins   PF279572         Mr     Adrian  Fatechand
# 2            Karma Bavaria   PF284073       Frau      Diana    Pateman
# 3         Karma St Martins   PF280014        Mrs     Angela      Crisp
# 4            Karma Bavaria   PF171576                  Anja        Wee
# ..                     ...        ...        ...        ...        ...
# 95           Karma Kandara   PF272380         Ms    Daniela     Georgi
# 96        Karma St Martins   PF248479                 Penny     Porter
# 97           Karma Bavaria   PF267462              Stefanie      Maier
# 98           Karma Bavaria   PF247291               Stephan      Greve
# 99  Karma Lake of Menteith   PF281769                  Hans   Marijnen
#
#      Gender  ...           DateDepart No. of Nights Market_Segment  \
# 0      Male  ...  2024-09-05 00:00:00             4      HOUSE_USE
# 1   Unknown  ...  2024-09-05 00:00:00             3           COMP
# 2    Female  ...  2024-09-05 00:00:00             7        WYNDHAM
# 3   Unknown  ...  2024-09-04 00:00:00             2            DIR
# 4    Female  ...  2024-09-05 00:00:00             3            OTA
# ..      ...  ...                  ...           ...            ...
# 95   Female  ...  2024-09-04 00:00:00             3            OTA
# 96  Unknown  ...  2024-09-02 00:00:00             5            OTA
# 97  Unknown  ...  2024-09-01 00:00:00             1            OTA
# 98  Unknown  ...  2024-09-06 00:00:00             1            OTA
# 99  Unknown  ...  2024-09-05 00:00:00             2            OTA
#
#      Media_Code Media Code Group No. of Adult No. of Children No. of Infants  \
# 0   V_OWNER_NRB             COMP            5               0              0
# 1         STAFF             COMP            1               0              0
# 2       WYNDHAM          WYNDHAM            1               0              0
# 3       WEBSITE          DIGITAL            2               0              0
# 4           OTA           RETAIL            3               2              0
# ..          ...              ...          ...             ...            ...
# 95          OTA           RETAIL            2               1              0
# 96          OTA           RETAIL            2               0              0
# 97          OTA           RETAIL            3               0              0
# 98          OTA           RETAIL            1               0              0
# 99          OTA           RETAIL            2               0              0
#
#        Contact Type Odyssey Members
# 0   Email and Phone              NO
# 1        Email Only              NO
# 2   Email and Phone              NO
# 3   Email and Phone              NO
# 4   Email and Phone              NO
# ..              ...             ...
# 95       Phone Only              NO
# 96       Phone Only              NO
# 97       Phone Only              NO
# 98       Phone Only              NO
# 99       Phone Only              NO
#
# [100 rows x 36 columns]

# %%
df_analytic['Salutation']
# Out:
# 0       Mr
# 1       Mr
# 2     Frau
# 3      Mrs
# 4
#       ...
# 95      Ms
# 96
# 97
# 98
# 99
# Name: Salutation, Length: 100, dtype: string

# %%
# Cek leads test
test_leads = df_analytic.loc[
    
        df_analytic['Email'].str.contains('^test@', flags=re.I, regex=True) |
        df_analytic['Email'].str.contains('\+test', flags=re.I, regex=True) |
    
        df_analytic['First_Name'].str.contains('^test$', flags=re.I, regex=True) |
        df_analytic['Surname'].str.contains('^test$', flags=re.I, regex=True) |

        df_analytic['First_Name'].str.contains('test 1', flags=re.I, regex=True) |
        df_analytic['Surname'].str.contains('test 2', flags=re.I, regex=True)|
        df_analytic['First_Name'].str.contains('test1', flags=re.I, regex=True) |
        df_analytic['Surname'].str.contains('test2', flags=re.I, regex=True)|

        df_analytic['First_Name'].str.contains(' test ', flags=re.I, regex=True) | 
        df_analytic['Surname'].str.contains(' test ', flags=re.I, regex=True) | 
        df_analytic['Surname'].str.contains(' test$', flags=re.I, regex=True)
    ]

count_leads_test = test_leads.shape[0]

test_leads.to_csv(r'C:\Users\fajar\Documents\Python\Data\test_leads_analytic.csv', index=False)
test_leads
# Out:
# Empty DataFrame
# Columns: [Booking_Id, Lead Brand, Lead Sub- Brand, Lead Source, Resort_Name, ProfileRef, Salutation, First_Name, Surname, Gender, Language, DOB, Street, Area, Town, County, Country, Nationality, PostCode, TelNo, MobileNo, Email, Exclude From Mailing, Opt In, Booking Status, DateArrival, DateDepart, No. of Nights, Market_Segment, Media_Code, Media Code Group, No. of Adult, No. of Children, No. of Infants, Contact Type, Odyssey Members]
# Index: []
#
# [0 rows x 36 columns]

# %%
df_analytic.drop(test_leads.index, inplace=True)
df_analytic.reset_index(drop=True, inplace=True)

count_after_dedup_test = df_analytic.shape[0]
count_after_dedup_test
# Out:
# 100

# %%
count_final_data = count_after_dedup_test

# %%
# df_analytic.loc[(df_analytic['Email'] == 'jonmosley6@yahoo.com')]

# %%
df_analytic.replace('empty', '', inplace=True)

# %%
print("==========================================================")
print("Summary")
print("==========================================================")
print("Jumlah Data Awal Zoho Analytic : "+str(count_data_awal))
print("Jumlah Data Email dan Phone Kosong : "+str(count_contact_type_empty))
print("Jumlah Data Setelah Hapus Email dan Phone Yang Kosong : "+str(count_after_contact_type_empty))
print("Jumlah Data Email Yang Termasuk List Karma : "+str(count_email_karma))
print("Jumlah Data Email Setelah List Karma Dihapus : "+str(count_after_clean_karma))
print("Jumlah Data Test : "+str(count_leads_test))
print("Jumlah Data Email Setelah Data Test Dihapus : "+str(count_after_dedup_test))
print("Jumlah Data Akhir : "+str(count_final_data))
# Out:
# ==========================================================
# Summary
# ==========================================================
# Jumlah Data Awal Zoho Analytic : 126
# Jumlah Data Email dan Phone Kosong : 16
# Jumlah Data Setelah Hapus Email dan Phone Yang Kosong : 110
# Jumlah Data Email Yang Termasuk List Karma : 10
# Jumlah Data Email Setelah List Karma Dihapus : 100
# Jumlah Data Test : 0
# Jumlah Data Email Setelah Data Test Dihapus : 100
# Jumlah Data Akhir : 100

# %%
df_analytic.to_excel(r'C:\Users\fajar\Documents\Python\Data\check_country_code_analytic.xlsx', index=False)
