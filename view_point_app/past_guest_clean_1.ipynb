# %%
import pandas as pd
import re

import past_guest_module as pm

import sys
sys.path.append('../zoho_data_app/')

import main_module as m

# %load_ext autoreload
# %autoreload 2

# %%
path = r'C:\Users\fajar\Documents\Python\Data\Past Guest Data\Zoho Analytic\2024\Sep\8 Sep - 13 Sep\CRM_Rental_Report_8_Sep_-_13_Sep.xlsx'
df_analytic = pd.read_excel(path, dtype='string', sheet_name='Sheet1')
count_data_awal = df_analytic.shape[0]
df_analytic
# Out:
#    Booking_Id            TelNo       MobileNo  \
# 0    KK060270             <NA>  6287860574419
# 1    KB039267   +4915156162177           <NA>
# 2    KB042228  +49 179 8429428           <NA>
# 3    KB042967  +49 162 3485200           <NA>
# 4   KLM003624      07904088215           <NA>
# ..        ...              ...            ...
# 67   KB044288             <NA>           <NA>
# 68  KLM003286             <NA>           <NA>
# 69   KB039842             <NA>           <NA>
# 70   KB040327             <NA>           <NA>
# 71   KB044287             <NA>           <NA>
#
#                                Email     Lead Brand Lead Sub- Brand  \
# 0   agung.triyono@finnsbeachclub.com  Karma Resorts           Other
# 1          ana.chevtchenko@gmail.com  Karma Resorts           Other
# 2                  anita.riel@web.de  Karma Resorts           Other
# 3         anton.Feuereck@t-online.de  Karma Resorts           Other
# 4      carol.milne10@virginmedia.com  Karma Resorts           Other
# ..                               ...            ...             ...
# 67                              <NA>  Karma Resorts           Other
# 68                              <NA>  Karma Resorts           Other
# 69                              <NA>  Karma Resorts           Other
# 70                              <NA>  Karma Resorts           Other
# 71                              <NA>  Karma Resorts           Other
#
#     Lead Source             Resort_Name ProfileRef Salutation  ...  \
# 0   Past Guests           Karma Kandara   PF284757         Mr  ...
# 1   Past Guests           Karma Bavaria   PF283978        Mrs  ...
# 2   Past Guests           Karma Bavaria   PF273069       Frau  ...
# 3   Past Guests           Karma Bavaria   PF277210       Frau  ...
# 4   Past Guests  Karma Lake of Menteith   PF254172        Mrs  ...
# ..          ...                     ...        ...        ...  ...
# 67  Past Guests           Karma Bavaria   PF080008       <NA>  ...
# 68  Past Guests  Karma Lake of Menteith       <NA>       <NA>  ...
# 69  Past Guests           Karma Bavaria       <NA>      Firma  ...
# 70  Past Guests           Karma Bavaria       <NA>      Firma  ...
# 71  Past Guests           Karma Bavaria   PF080008       <NA>  ...
#
#              DateDepart No. of Nights Market_Segment   Media_Code  \
# 0   2024-09-08 00:00:00             2      HOUSE_USE  V_OWNER_NRB
# 1   2024-09-08 00:00:00             2        WYNDHAM      WYNDHAM
# 2   2024-09-08 00:00:00             1            OTA          OTA
# 3   2024-09-08 00:00:00             1            OTA          OTA
# 4   2024-09-08 00:00:00             1        DIGITAL          TEL
# ..                  ...           ...            ...          ...
# 67  2024-09-08 17:00:00             0            LGR          LGR
# 68  2024-09-09 00:00:00             1            DIR          OTA
# 69  2024-09-09 18:00:00             0             CB           CB
# 70  2024-09-11 18:00:00             2             CB           CB
# 71  2024-09-08 19:00:00             0            LGR          LGR
#
#    Media Code Group No. of Adult No. of Children No. of Infants Contact Type  \
# 0              COMP            6               0              0
# 1           WYNDHAM            2               0              0
# 2            RETAIL            4               0              0
# 3            RETAIL            6               0              0
# 4            RETAIL            2               0              0
# ..              ...          ...             ...            ...          ...
# 67            GROUP            1               0              0
# 68           RETAIL            2               0              0
# 69            GROUP            1               0              0
# 70            GROUP            1               0              0
# 71            GROUP            1               0              0
#
#    Odyssey Members
# 0
# 1
# 2
# 3
# 4
# ..             ...
# 67
# 68
# 69
# 70
# 71
#
# [72 rows x 37 columns]

# %%
df_analytic.columns
# Out:
# Index(['Booking_Id', 'TelNo', 'MobileNo', 'Email', 'Lead Brand',
#        'Lead Sub- Brand', 'Lead Source', 'Resort_Name', 'ProfileRef',
#        'Salutation', 'First_Name', 'Surname', 'Gender', 'Language', 'DOB',
#        'Street', 'Area', 'Town', 'County', 'Country', 'Nationality',
#        'PostCode', 'Exclude From Mailing', 'Opt In', 'Booking Code',
#        'Booking Status', 'DateArrival', 'DateDepart', 'No. of Nights',
#        'Market_Segment', 'Media_Code', 'Media Code Group', 'No. of Adult',
#        'No. of Children', 'No. of Infants', 'Contact Type', 'Odyssey Members'],
#       dtype='object')

# %%
new_cols = ['Booking_Id', 'Lead Brand', 'Lead Sub- Brand', 'Lead Source',
       'Resort_Name', 'ProfileRef', 'Salutation', 'First_Name', 'Surname',
       'Gender', 'Language', 'DOB', 'Street', 'Area', 'Town', 'County',
       'Country', 'Nationality', 'PostCode', 'TelNo', 'MobileNo', 'Email',
       'Exclude From Mailing', 'Opt In', 'Booking Status',
       'DateArrival', 'DateDepart', 'No. of Nights', 'Market_Segment',
       'Media_Code', 'Media Code Group', 'No. of Adult', 'No. of Children',
       'No. of Infants', 'Contact Type', 'Odyssey Members']																																																																																																																																						

df_analytic = df_analytic.reindex(columns=new_cols)

# %%
df_analytic.fillna('empty', inplace=True)
df_analytic['Contact Type'] = 'empty'
df_analytic['Odyssey Members'] = 'NO'

# %%
df_analytic.loc[df_analytic['Surname'] == 'empty', 'Surname'] = '-'

# %%
df_analytic['Salutation'].replace('empty', '', inplace=True)
df_analytic['First_Name'].replace('empty', '', inplace=True)
df_analytic['Surname'].replace('empty', '', inplace=True)

df_analytic['Salutation'] = df_analytic['Salutation'].str.title()
df_analytic['First_Name'] = df_analytic['First_Name'].str.title()
df_analytic['Surname'] = df_analytic['Surname'].str.title()

df_analytic
# Out:
#    Booking_Id     Lead Brand Lead Sub- Brand  Lead Source  \
# 0    KK060270  Karma Resorts           Other  Past Guests
# 1    KB039267  Karma Resorts           Other  Past Guests
# 2    KB042228  Karma Resorts           Other  Past Guests
# 3    KB042967  Karma Resorts           Other  Past Guests
# 4   KLM003624  Karma Resorts           Other  Past Guests
# ..        ...            ...             ...          ...
# 67   KB044288  Karma Resorts           Other  Past Guests
# 68  KLM003286  Karma Resorts           Other  Past Guests
# 69   KB039842  Karma Resorts           Other  Past Guests
# 70   KB040327  Karma Resorts           Other  Past Guests
# 71   KB044287  Karma Resorts           Other  Past Guests
#
#                Resort_Name ProfileRef Salutation  First_Name         Surname  \
# 0            Karma Kandara   PF284757         Mr      Darren           Bowen
# 1            Karma Bavaria   PF283978        Mrs  Anastasiya     Chevtchenko
# 2            Karma Bavaria   PF273069       Frau       Anita            Riel
# 3            Karma Bavaria   PF277210       Frau     Barbara        Feuereck
# 4   Karma Lake of Menteith   PF254172        Mrs       Carol           Milne
# ..                     ...        ...        ...         ...             ...
# 67           Karma Bavaria   PF080008                    Kea  Marketing Gmbh
# 68  Karma Lake of Menteith      empty                             Jean Owens
# 69           Karma Bavaria      empty      Firma         Tum    Venture Labs
# 70           Karma Bavaria      empty      Firma         Tum    Venture Labs
# 71           Karma Bavaria   PF080008                    Kea  Marketing Gmbh
#
#      Gender  ...           DateDepart No. of Nights Market_Segment  \
# 0      Male  ...  2024-09-08 00:00:00             2      HOUSE_USE
# 1    Female  ...  2024-09-08 00:00:00             2        WYNDHAM
# 2    Female  ...  2024-09-08 00:00:00             1            OTA
# 3    Female  ...  2024-09-08 00:00:00             1            OTA
# 4   Unknown  ...  2024-09-08 00:00:00             1        DIGITAL
# ..      ...  ...                  ...           ...            ...
# 67  Unknown  ...  2024-09-08 17:00:00             0            LGR
# 68  Unknown  ...  2024-09-09 00:00:00             1            DIR
# 69  Unknown  ...  2024-09-09 18:00:00             0             CB
# 70  Unknown  ...  2024-09-11 18:00:00             2             CB
# 71  Unknown  ...  2024-09-08 19:00:00             0            LGR
#
#      Media_Code Media Code Group No. of Adult No. of Children No. of Infants  \
# 0   V_OWNER_NRB             COMP            6               0              0
# 1       WYNDHAM          WYNDHAM            2               0              0
# 2           OTA           RETAIL            4               0              0
# 3           OTA           RETAIL            6               0              0
# 4           TEL           RETAIL            2               0              0
# ..          ...              ...          ...             ...            ...
# 67          LGR            GROUP            1               0              0
# 68          OTA           RETAIL            2               0              0
# 69           CB            GROUP            1               0              0
# 70           CB            GROUP            1               0              0
# 71          LGR            GROUP            1               0              0
#
#    Contact Type Odyssey Members
# 0         empty              NO
# 1         empty              NO
# 2         empty              NO
# 3         empty              NO
# 4         empty              NO
# ..          ...             ...
# 67        empty              NO
# 68        empty              NO
# 69        empty              NO
# 70        empty              NO
# 71        empty              NO
#
# [72 rows x 36 columns]

# %%
m.clean_number(df_analytic, 'TelNo')
m.clean_number(df_analytic, 'MobileNo')
m.replace_not_valid_to_empty(df_analytic, 'TelNo')
m.replace_not_valid_to_empty(df_analytic, 'MobileNo')

df_analytic.loc[df_analytic['TelNo'].str.contains('00000'), 'TelNo'] = 'empty'
df_analytic.loc[df_analytic['MobileNo'].str.contains('00000'), 'MobileNo'] = 'empty'

m.clean_space(df_analytic, 'Email')
df_analytic['Email'] = m.lowercase(df_analytic, 'Email')

# %%
pm.email_correction(df_analytic, 'Email')

# %%
df_analytic.loc[(df_analytic['Email'] != 'empty') & ((df_analytic['TelNo'] != 'empty') | (df_analytic['MobileNo'] != 'empty')), 'Contact Type'] = 'Email and Phone'
df_analytic.loc[(df_analytic['Email'] != 'empty') & ((df_analytic['TelNo'] == 'empty') & (df_analytic['MobileNo'] == 'empty')), 'Contact Type'] = 'Email Only'
df_analytic.loc[(df_analytic['Email'] == 'empty') & ((df_analytic['TelNo'] != 'empty') | (df_analytic['MobileNo'] != 'empty')), 'Contact Type'] = 'Phone Only'

df_analytic.loc[df_analytic['Contact Type'] == 'empty'].to_csv(r'C:\Users\fajar\Documents\Python\Data\contact_type_empty_analytic.csv', index=False)

count_contact_type_empty = df_analytic.loc[df_analytic['Contact Type'] == 'empty'].shape[0]

df_analytic.drop(df_analytic.loc[df_analytic['Contact Type'] == 'empty'].index, inplace=True)
df_analytic.reset_index(drop=True, inplace=True)

count_after_contact_type_empty = df_analytic.shape[0]

df_analytic
# Out:
#    Booking_Id     Lead Brand Lead Sub- Brand  Lead Source  \
# 0    
# 13           Karma Bavaria   PF283218         Mr             Gary
# 14           Karma Bavaria   PF283218         Mr             Gary
# 15  Karma Lake of Menteith   PF228848         Mr           Adrian
# 16        Karma St Martins   PF086043         Mr            Karma
# 17           Karma Bavaria   PF284843       Frau            Petra
# 18           Karma Kandara   PF283420         Mr          Imanuel
# 19  Karma Lake of Menteith   PF280926         Ms            Joann
# 20           Karma Kandara   PF285218        Mrs    Heidi Heather
# 21           Karma Bavaria   PF254425       Frau        Jeannette
# 22           Karma Bavaria   PF168470       Herr          Joachim
# 23  Karma Lake of Menteith   PF250885         Mr           Jordan
# 24           Karma Bavaria   PF252168       Herr         Jaroslaw
# 25        Karma St Martins   PF280907        Mrs            Layne
# 26           Karma Kandara   PF265506         Mr  Lucas Alejandro
# 27           Karma Bavaria   PF285098       Herr           Lorenz
# 28           Karma Bavaria   PF285201         Mr              Lou
# 29           Karma Bavaria   PF279656       Herr          Norbert
# 30      Karma Salford Hall   PF285159         Mr          Russell
# 31           Karma Bavaria   PF269690       Frau            Julia
# 32        Karma St Martins   PF256125        Mrs            Sally
# 33           Karma Bavaria   PF095400       Frau         Stefanie
# 34           Karma Kandara   PF285072         Ms          Sushant
# 35           Karma Bavaria   PF269302       Herr           Thomas
# 36  Karma Lake of Menteith   PF285244         Mr          Timothy
# 37           Karma Kandara   PF279290         Ms     Vanessa Pino
# 38  Karma Lake of Menteith   PF247202                      Sharon
# 39           Karma Bavaria   PF265178                       Linda
# 40           Karma Bavaria   PF280064                       Achim
# 41           Karma Bavaria   PF262326                        Grit
# 42  Karma Lake of Menteith   PF253383                 Christopher
# 43           Karma Bavaria   PF217948       Frau        Christine
# 44           Karma Bavaria   PF269661                      Gunter
# 45           Karma Bavaria   PF269983                     Norbert
# 46           Karma Bavaria   PF280054                       Schon
# 47           Karma Kandara   PF281871                     Evgenii
# 48           Karma Bavaria   PF244986       Herr          Manolis
# 49           Karma Bavaria   PF269652                     Volkmar
#
#              Surname   Gender  ...           DateDepart No. of Nights  \
# 0              Bowen     Male  ...  2024-09-08 00:00:00             2
# 1        Chevtchenko   Female  ...  2024-09-08 00:00:00             2
# 2               Riel   Female  ...  2024-09-08 00:00:00             1
# 3           Feuereck   Female  ...  2024-09-08 00:00:00             1
# 4              Milne  Unknown  ...  2024-09-08 00:00:00             1
# 5           Holidays  Unknown  ...  2024-09-13 00:00:00             2
# 6   Galligani Raeder   Female  ...  2024-09-11 00:00:00             5
# 7           Dalladay   Female  ...  2024-09-08 00:00:00             3
# 8              Tribe  Unknown  ...  2024-09-09 00:00:00             2
# 9             Bowden     Male  ...  2024-09-08 00:00:00            28
# 10          Prestige  Unknown  ...  2024-09-10 00:00:00             5
# 11            Bailey     Male  ...  2024-09-08 00:00:00             3
# 12           Cameron  Unknown  ...  2024-09-09 00:00:00             3
# 13             Pryor     Male  ...  2024-09-08 00:00:00             7
# 14             Pryor     Male  ...  2024-09-08 00:00:00             7
# 15          Willmers  Unknown  ...  2024-09-08 00:00:00             2
# 16        Management  Unknown  ...  2024-09-13 00:00:00            16
# 17           Grammel   Female  ...  2024-09-08 00:00:00             3
# 18               Ong     Male  ...  2024-09-10 00:00:00             2
# 19             Shann   Female  ...  2024-09-08 00:00:00             1
# 20            Wright   Female  ...  2024-09-10 00:00:00             2
# 21          Matthews   Female  ...  2024-09-09 20:30:00             0
# 22             Schug     Male  ...  2024-09-12 00:00:00             4
# 23            Powell  Unknown  ...  2024-09-09 00:00:00             1
# 24          Rafinski     Male  ...  2024-09-08 00:00:00             1
# 25           Lambert  Unknown  ...  2024-09-09 00:00:00             5
# 26            Schuty     Male  ...  2024-09-08 00:00:00             2
# 27            Franke     Male  ...  2024-09-08 00:00:00             1
# 28          Vulovich     Male  ...  2024-09-08 00:00:00             1
# 29          Schuster     Male  ...  2024-09-08 00:00:00             2
# 30            Miller     Male  ...  2024-09-08 00:00:00             1
# 31            Rumpel   Female  ...  2024-09-08 00:00:00             1
# 32           Simpson  Unknown  ...  2024-09-09 00:00:00             2
# 33           Kuschel   Female  ...  2024-09-09 00:00:00             3
# 34             Gupta   Female  ...  2024-09-09 00:00:00             2
# 35         Schreiner     Male  ...  2024-09-08 00:00:00             1
# 36            Powell  Unknown  ...  2024-09-09 00:00:00             1
# 37             Brown   Female  ...  2024-09-08 00:00:00             3
# 38             Owens  Unknown  ...  2024-09-09 00:00:00             1
# 39              Song  Unknown  ...  2024-09-13 00:00:00             2
# 40          Rischert  Unknown  ...  2024-09-12 00:00:00             4
# 41              Koch  Unknown  ...  2024-09-08 00:00:00             1
# 42        Pennington  Unknown  ...  2024-09-10 00:00:00             1
# 43            Konrad   Female  ...  2024-09-08 00:00:00             1
# 44              Huth  Unknown  ...  2024-09-13 00:00:00             1
# 45          Schuster  Unknown  ...  2024-09-08 00:00:00             2
# 46            Markus  Unknown  ...  2024-09-13 00:00:00             4
# 47           Lezhnev  Unknown  ...  2024-09-12 00:00:00             7
# 48        Grigorakis     Male  ...  2024-09-08 00:00:00           191
# 49          Meyhofer  Unknown  ...  2024-09-08 00:00:00             1
#
#    Market_Segment   Media_Code Media Code Group No. of Adult No. of Children  \
# 0       HOUSE_USE  V_OWNER_NRB             COMP            6               0
# 1         WYNDHAM      WYNDHAM          WYNDHAM            2               0
# 2             OTA          OTA           RETAIL            4               0
# 3             OTA          OTA           RETAIL            6               0
# 4         DIGITAL          TEL           RETAIL            2               0
# 5              TA          TEL           RETAIL            2               0
# 6             DIR         CHAT          DIGITAL            4               0
# 7            COMP          VIP             COMP            2               0
# 8             OTA          OTA           RETAIL            2               0
# 9       HOUSE_USE  V_OWNER_NRB             COMP            1               0
# 10            DIR          TEL           RETAIL            2               0
# 11            DIR         CHAT          DIGITAL            2               0
# 12            OTA          OTA           RETAIL            2               0
# 13        WYNDHAM      WYNDHAM          WYNDHAM            2               0
# 14        WYNDHAM      WYNDHAM          WYNDHAM            2               0
# 15           COMP        STAFF             COMP            2               0
# 16           COMP        STAFF             COMP            2               0
# 17            OTA          OTA           RETAIL            3               0
# 18        DIGITAL      WEBSITE          DIGITAL            4               0
# 19            DIR      WEBSITE          DIGITAL            2               0
# 20      HOUSE_USE  V_OWNER_NRB             COMP            4               0
# 21            DIR       WALKIN           RETAIL            1               0
# 22           COMP      GER_OWE             COMP            2               0
# 23            OTA          OTA           RETAIL            2               0
# 24            DIR      WEBSITE          DIGITAL            2               0
# 25            DIR          TEL           RETAIL            2               0
# 26             TO           TO           RETAIL            2               0
# 27            DIR          TEL           RETAIL            2               0
# 28            DIR       WALKIN           RETAIL            2               0
# 29            DIR          TEL           RETAIL            5               0
# 30            OTA          OTA           RETAIL            2               0
# 31            OTA          OTA           RETAIL            3               0
# 32            DIR      WEBSITE          DIGITAL            2               0
# 33           COMP      GER_OWE             COMP            2               1
# 34      HOUSE_USE  V_OWNER_NRB             COMP            4               0
# 35            OTA          OTA           RETAIL            2               0
# 36            OTA          OTA           RETAIL            2               0
# 37      HOUSE_USE  V_OWNER_NRB             COMP            2               0
# 38            DIR          OTA           RETAIL            2               0
# 39            OTA          OTA           RETAIL            2               0
# 40            OTA          OTA           RETAIL            2               0
# 41            OTA          OTA           RETAIL            2               0
# 42            OTA          OTA           RETAIL            2               0
# 43            OTA          OTA           RETAIL            2               0
# 44            OTA          OTA           RETAIL            2               0
# 45            OTA          OTA           RETAIL            2               0
# 46            OTA          OTA           RETAIL            2               0
# 47            OTA          OTA           RETAIL            3               1
# 48           COMP        STAFF             COMP            1               0
# 49            OTA          OTA           RETAIL            2               0
#
#    No. of Infants     Contact Type Odyssey Members
# 0               0  Email and Phone              NO
# 1               0  Email and Phone              NO
# 2               0  Email and Phone              NO
# 3               0  Email and Phone              NO
# 4               0  Email and Phone              NO
# 5               0  Email and Phone              NO
# 6               0  Email and Phone              NO
# 7               0  Email and Phone              NO
# 8               0  Email and Phone              NO
# 9               0  Email and Phone              NO
# 10              0  Email and Phone              NO
# 11              0  Email and Phone              NO
# 12              0  Email and Phone              NO
# 13              0  Email and Phone              NO
# 14              0  Email and Phone              NO
# 15              0  Email and Phone              NO
# 16              0  Email and Phone              NO
# 17              0  Email and Phone              NO
# 18              0  Email and Phone              NO
# 19              0       Email Only              NO
# 20              0  Email and Phone              NO
# 21              0       Email Only              NO
# 22              0  Email and Phone              NO
# 23              0  Email and Phone              NO
# 24              0  Email and Phone              NO
# 25              0  Email and Phone              NO
# 26              0  Email and Phone              NO
# 27              0  Email and Phone              NO
# 28              0  Email and Phone              NO
# 29              0  Email and Phone              NO
# 30              0  Email and Phone              NO
# 31              0  Email and Phone              NO
# 32              0  Email and Phone              NO
# 33              0  Email and Phone              NO
# 34              0  Email and Phone              NO
# 35              0  Email and Phone              NO
# 36              0  Email and Phone              NO
# 37              0  Email and Phone              NO
# 38              0       Phone Only              NO
# 39              0       Phone Only              NO
# 40              0       Phone Only              NO
# 41              0       Phone Only              NO
# 42              0       Phone Only              NO
# 43              0       Phone Only              NO
# 44              0       Phone Only              NO
# 45              0       Phone Only              NO
# 46              0       Phone Only              NO
# 47              0       Phone Only              NO
# 48              0       Phone Only              NO
# 49              0       Phone Only              NO
#
# [50 rows x 36 columns]

# %%
# Cek Email Karma
email_karma = m.find_karma(df
# 46   KK059079  Karma Resorts           Other  Past Guests
# 47   KB040583  Karma Resorts           Other  Past Guests
# 48   KB041680  Karma Resorts           Other  Past Guests
#
#                Resort_Name ProfileRef Salutation       First_Name  \
# 0            Karma Kandara   PF284757         Mr           Darren
# 1            Karma Bavaria   PF283978        Mrs       Anastasiya
# 2            Karma Bavaria   PF273069       Frau            Anita
# 3            Karma Bavaria   PF277210       Frau          Barbara
# 4   Karma Lake of Menteith   PF254172        Mrs            Carol
# 5         Karma St Martins   PF223581         Mr          Premier
# 6            Karma Kandara   PF232757        Mrs          Cecilie
# 7   Karma Lake of Menteith   PF283489         Ms            Cissy
# 8         Karma St Martins   PF267465        Mrs         Caroline
# 9            Karma Kandara   PF050744         Mr            Brian
# 10        Karma St Martins   PF282581         Mr           Dave @
# 11           Karma Kandara   PF259965         Mr            Dylan
# 12        Karma St Martins   PF271165         Ms            Fiona
# 13           Karma Bavaria   PF283218         Mr             Gary
# 14           Karma Bavaria   PF283218         Mr             Gary
# 15  Karma Lake of Menteith   PF228848         Mr           Adrian
# 16           Karma Bavaria   PF284843       Frau            Petra
# 17           Karma Kandara   PF283420         Mr          Imanuel
# 18  Karma Lake of Menteith   PF280926         Ms            Joann
# 19           Karma Kandara   PF285218        Mrs    Heidi Heather
# 20           Karma Bavaria   PF254425       Frau        Jeannette
# 21           Karma Bavaria   PF168470       Herr          Joachim
# 22  Karma Lake of Menteith   PF250885         Mr           Jordan
# 23           Karma Bavaria   PF252168       Herr         Jaroslaw
# 24        Karma St Martins   PF280907        Mrs            Layne
# 25           Karma Kandara   PF265506         Mr  Lucas Alejandro
# 26           Karma Bavaria   PF285098       Herr           Lorenz
# 27           Karma Bavaria   PF285201         Mr              Lou
# 28           Karma Bavaria   PF279656       Herr          Norbert
# 29      Karma Salford Hall   PF285159         Mr          Russell
# 30           Karma Bavaria   PF269690       Frau            Julia
# 31        Karma St Martins   PF256125        Mrs            Sally
# 32           Karma Bavaria   PF095400       Frau         Stefanie
# 33           Karma Kandara   PF285072         Ms          Sushant
# 34           Karma Bavaria   PF269302       Herr           Thomas
# 35  Karma Lake of Menteith   PF285244         Mr          Timothy
# 36           Karma Kandara   PF279290         Ms     Vanessa Pino
# 37  Karma Lake of Menteith   PF247202                      Sharon
# 38           Karma Bavaria   PF265178                       Linda
# 39           Karma Bavaria   PF280064                       Achim
# 40           Karma Bavaria   PF262326                        Grit
# 41  Karma Lake of Menteith   PF253383                 Christopher
# 42           Karma Bavaria   PF217948       Frau        Christine
# 43           Karma Bavaria   PF269661                      Gunter
# 44           Karma Bavaria   PF269983                     Norbert
# 45           Karma Bavaria   PF280054                       Schon
# 46           Karma Kandara   PF281871                     Evgenii
# 47           Karma Bavaria   PF244986       Herr          Manolis
# 48           Karma Bavaria   PF269652                     Volkmar
#
#              Surname   Gender  ...           DateDepart No. of Nights  \
# 0              Bowen     Male  ...  2024-09-08 00:00:00             2
# 1        Chevtchenko   Female  ...  2024-09-08 00:00:00             2
# 2             OTA          OTA           RETAIL            4               0
# 3             OTA          OTA           RETAIL            6               0
# 4         DIGITAL          TEL           RETAIL            2               0
# 5              TA          TEL           RETAIL            2               0
# 6             DIR         CHAT          DIGITAL            4               0
# 7            COMP          VIP             COMP            2               0
# 8             OTA          OTA           RETAIL            2               0
# 9       HOUSE_USE  V_OWNER_NRB             COMP            1               0
# 10            DIR          TEL           RETAIL            2               0
# 11            DIR         CHAT          DIGITAL            2               0
# 12            OTA          OTA           RETAIL            2               0
# 13        WYNDHAM      WYNDHAM          WYNDHAM            2               0
# 14        WYNDHAM      WYNDHAM          WYNDHAM            2               0
# 15           COMP        STAFF             COMP            2               0
# 16            OTA          OTA           RETAIL            3               0
# 17        DIGITAL      WEBSITE          DIGITAL            4               0
# 18            DIR      WEBSITE          DIGITAL            2               0
# 19      HOUSE_USE  V_OWNER_NRB             COMP            4               0
# 20            DIR       WALKIN           RETAIL            1               0
# 21           COMP      GER_OWE             COMP            2               0
# 22            OTA          OTA           RETAIL            2               0
# 23            DIR      WEBSITE          DIGITAL            2               0
# 24            DIR          TEL           RETAIL            2               0
# 25             TO           TO           RETAIL            2               0
# 26            DIR          TEL           RETAIL            2               0
# 27            DIR       WALKIN           RETAIL            2               0
# 28            DIR          TEL           RETAIL            5               0
# 29            OTA          OTA           RETAIL            2               0
# 30            OTA          OTA           RETAIL            3               0
# 31            DIR      WEBSITE          DIGITAL            2               0
# 32           COMP      GER_OWE             COMP            2               1
# 33      HOUSE_USE  V_OWNER_NRB             COMP            4               0
# 34            OTA          OTA           RETAIL            2               0
# 35            OTA          OTA           RETAIL            2               0
# 36      HOUSE_USE  V_OWNER_NRB             COMP            2               0
# 37            DIR          OTA           RETAIL            2               0
# 38            OTA          OTA           RETAIL            2               0
# 39            OTA          OTA           RETAIL            2               0
# 40            OTA          OTA           RETAIL            2               0
# 41            OTA          OTA           RETAIL            2               0
# 42            OTA          OTA           RETAIL            2               0
# 43            OTA          OTA           RETAIL            2               0
# 44            OTA          OTA           RETAIL            2               0
# 45            OTA          OTA           RETAIL            2               0
# 46            OTA          OTA           RETAIL            3               1
# 47           COMP        STAFF             COMP            1               0
# 48            OTA          OTA           RETAIL            2               0
#
#    No. of Infants     Contact Type Odyssey Members
# 0               0  Email and Phone              NO
# 1               0  Email and Phone              NO
# 2               0  Email and Phone              NO
# 3               0  Email and Phone              NO
# 4               0  Email and Phone              NO
# 5               0  Email and Phone              NO
# 6               0  Email and Phone              NO
# 7               0  Email and Phone              NO
# 8               0  Email and Phone              NO
# 9               0  Email and Phone              NO
# 10              0  Email and Phone              NO
# 11              0  Email and Phone              NO
# 12              0  Email and Phone              NO
# 13              0  Email and Phone              NO
# 14              0  Email and Phone              NO
# 15              0  Email and Phone              NO
# 16              0  Email and Phone              NO
# 17              0  Email and Phone              NO
# 18              0       Email Only              NO
# 19              0  Email and Phone              NO
# 20              0       Email Only              NO
# 21              0  Email and Phone              NO
# 22              0  Email and Phone              NO
# 23              0  Email and Phone              NO
# 24              0  Email and Phone              NO
# 25              0  Email and Phone              NO
# 26              0  Email and Phone              NO
# 27              0  Email and Phone              NO
# 28              0  Email and Phone              NO
# 29              0  Email and Phone              NO
# 30              0  Email and Phone              NO
# 31              0  Email and Phone              NO
# 32              0  Email and Phone              NO
# 33              0  Email and Phone              NO
# 34              0  Email and Phone              NO
# 35              0  Email and Phone              NO
# 36              0  Email and Phone              NO
# 37              0       Phone Only              NO
# 38              0       Phone Only              NO
# 39              0       Phone Only              NO
# 40              0       Phone Only              NO
# 41              0       Phone Only              NO
# 42              0       Phone Only              NO
# 43              0       Phone Only              NO
# 44              0       Phone Only              NO
# 45              0       Phone Only              NO
# 46              0       Phone Only              NO
# 47              0       Phone Only              NO
# 48              0       Phone Only              NO
#
# [49 rows x 36 columns]

# %%
df_analytic['Salutation']
# Out:
# 0       Mr
# 1      Mrs
# 2     Frau
# 3     Frau
# 4      Mrs
# 5       Mr
# 6      Mrs
# 7       Ms
# 8      Mrs
# 9       Mr
# 10      Mr
# 11      Mr
# 12      Ms
# 13      Mr
# 14      Mr
# 15      Mr
# 16    Frau
# 17      Mr
# 18      Ms
# 19     Mrs
# 20    Frau
# 21    Herr
# 22      Mr
# 23    Herr
# 24     Mrs
# 25      Mr
# 26    Herr
# 27      Mr
# 28    Herr
# 29      Mr
# 30    Frau
# 31     Mrs
# 32    Frau
# 33      Ms
# 34    Herr
# 35      Mr
# 36      Ms
# 37
# 38
# 39
# 40
# 41
# 42    Frau
# 43
# 44
# 45
# 46
# 47    Herr
# 48
# Name: Salutation, dtype: string

# %%
# Cek leads test
test_leads = df_analytic.loc[
    
        df_analytic['Email'].str.contains('^test@', flags=re.I, regex=True) |
        df_analytic['Email'].str.contains('\+test', flags=re.I, regex=True) |
    
        df_analytic['First_Name'].str.contains('^test$', flags=re.I, regex=True) |
        df_analytic['Surname'].str.contains('^test$', flags=re.I, regex=True) |

        df_analytic['First_Name'].str.contains('test 1', flags=re.I, regex=True) |
        df_analytic['Surname'].str.contains('test 2', flags=re.I, regex=True)|
        df_analytic['First_Name'].str.contains('test1', flags=re.I, regex=True) |
        df_analytic['Surname'].str.contains('test2', flags=re.I, regex=True)|

        df_analytic['First_Name'].str.contains(' test ', flags=re.I, regex=True) | 
        df_analytic['Surname'].str.contains(' test ', flags=re.I, regex=True) | 
        df_analytic['Surname'].str.contains(' test$', flags=re.I, regex=True)
    ]

count_leads_test = test_leads.shape[0]

test_leads.to_csv(r'C:\Users\fajar\Documents\Python\Data\test_leads_analytic.csv', index=False)
test_leads
# Out:
# Empty DataFrame
# Columns: [Booking_Id, Lead Brand, Lead Sub- Brand, Lead Source, Resort_Name, ProfileRef, Salutation, First_Name, Surname, Gender, Language, DOB, Street, Area, Town, County, Country, Nationality, PostCode, TelNo, MobileNo, Email, Exclude From Mailing, Opt In, Booking Status, DateArrival, DateDepart, No. of Nights, Market_Segment, Media_Code, Media Code Group, No. of Adult, No. of Children, No. of Infants, Contact Type, Odyssey Members]
# Index: []
#
# [0 rows x 36 columns]

# %%
df_analytic.drop(test_leads.index, inplace=True)
df_analytic.reset_index(drop=True, inplace=True)

count_after_dedup_test = df_analytic.shape[0]
count_after_dedup_test
# Out:
# 49

# %%
count_final_data = count_after_dedup_test

# %%
# df_analytic.loc[(df_analytic['Email'] == 'jonmosley6@yahoo.com')]

# %%
df_analytic.replace('empty', '', inplace=True)

# %%
print("==========================================================")
print("Summary")
print("==========================================================")
print("Jumlah Data Awal Zoho Analytic : "+str(count_data_awal))
print("Jumlah Data Email dan Phone Kosong : "+str(count_contact_type_empty))
print("Jumlah Data Setelah Hapus Email dan Phone Yang Kosong : "+str(count_after_contact_type_empty))
print("Jumlah Data Email Yang Termasuk List Karma : "+str(count_email_karma))
print("Jumlah Data Email Setelah List Karma Dihapus : "+str(count_after_clean_karma))
print("Jumlah Data Test : "+str(count_leads_test))
print("Jumlah Data Email Setelah Data Test Dihapus : "+str(count_after_dedup_test))
print("Jumlah Data Akhir : "+str(count_final_data))
# Out:
# ==========================================================
# Summary
# ==========================================================
# Jumlah Data Awal Zoho Analytic : 72
# Jumlah Data Email dan Phone Kosong : 22
# Jumlah Data Setelah Hapus Email dan Phone Yang Kosong : 50
# Jumlah Data Email Yang Termasuk List Karma : 1
# Jumlah Data Email Setelah List Karma Dihapus : 49
# Jumlah Data Test : 0
# Jumlah Data Email Setelah Data Test Dihapus : 49
# Jumlah Data Akhir : 49

# %%
df_analytic.to_excel(r'C:\Users\fajar\Documents\Python\Data\check_country_code_analytic.xlsx', index=False)
