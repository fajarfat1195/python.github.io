# %%
import pandas as pd
import re

import past_guest_module as pm

import sys
sys.path.append('../zoho_data_app/')

import main_module as m

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
path = r'C:\Users\fajar\Documents\Python\Data\Past Guest Data\Zoho Analytic\2024\Juli\14 July - 29 July\CRM_Rental_Report_14_July_-_29_July.xlsx'
df_analytic = pd.read_excel(path, dtype='string', sheet_name='Sheet1')
count_data_awal = df_analytic.shape[0]
df_analytic
# Out:
#     Booking_Id            TelNo     MobileNo               Email  \
# 0     KK056470      81318185866         <NA>    397693317@qq.com
# 1     KK055941        -82629190         <NA>     67081548@qq.com
# 2    KSH018615      13808908830         <NA>    676929594@99.com
# 3     KK057945        -82629190  18828082255  80923531@gmail.com
# 4    KSM012021             <NA>   1250889765    aalm1229@aol.com
# ..         ...              ...          ...                 ...
# 439   KB042351      -1714715584         <NA>                <NA>
# 440   KB043393  +49 175 1549227         <NA>                <NA>
# 441  KSM013431  +44 7837 928196         <NA>                <NA>
# 442  KLM005265             <NA>         <NA>                <NA>
# 443   KK050439             <NA>         <NA>                <NA>
#
#         Lead Brand Lead Sub- Brand  Lead Source             Resort_Name  \
# 0    Karma Resorts           Other  Past Guests           Karma Kandara
# 1    Karma Resorts           Other  Past Guests           Karma Kandara
# 2    Karma Resorts           Other  Past Guests      Karma Salford Hall
# 3    Karma Resorts           Other  Past Guests           Karma Kandara
# 4    Karma Resorts           Other  Past Guests        Karma St Martins
# ..             ...             ...          ...                     ...
# 439  Karma Resorts           Other  Past Guests           Karma Bavaria
# 440  Karma Resorts           Other  Past Guests           Karma Bavaria
# 441  Karma Resorts           Other  Past Guests        Karma St Martins
# 442  Karma Resorts           Other  Past Guests  Karma Lake of Menteith
# 443  Karma Resorts           Other  Past Guests           Karma Kandara
#
#     ProfileRef Salutation  ...           DateDepart No. of Nights  \
# 0     PF275413         Mr  ...  14/07/2024 00:00:00             1
# 1     PF274115         Ms  ...  22/07/2024 00:00:00             2
# 2     PF275372        Mrs  ...  20/07/2024 00:00:00             1
# 3     PF279381        Mrs  ...  24/07/2024 00:00:00             2
# 4     PF278952        Mrs  ...  14/07/2024 00:00:00             2
# ..         ...        ...  ...                  ...           ...
# 439   PF273719       <NA>  ...  21/07/2024 00:00:00             2
# 440   PF279961       Herr  ...  23/07/2024 00:00:00             2
# 441   PF280229         Mr  ...  27/07/2024 00:00:00             1
# 442       <NA>         Mr  ...  16/07/2024 00:00:00             1
# 443   PF263567         Mr  ...  22/07/2024 00:00:00             2
#
#     Market_Segment Media_Code Media Code Group No. of Adult No. of Children  \
# 0              OTA        OTA           RETAIL            2               2
# 1              OTA        OTA           RETAIL            3               0
# 2              OTA        OTA           RETAIL            2               0
# 3              OTA        OTA           RETAIL            4               0
# 4              DIR        TEL           RETAIL            1               0
# ..             ...        ...              ...          ...             ...
# 439            OTA        OTA           RETAIL            2               0
# 440            OTA        OTA           RETAIL            2               1
# 441            OTA        OTA           RETAIL            4               0
# 442           COMP      STAFF             COMP            1               0
# 443             TO         TO           RETAIL            2               0
#
#     No. of Infants Contact Type Odyssey Members
# 0                0
# 1                0
# 2                0
# 3                0
# 4                0
# ..             ...          ...             ...
# 439              0
# 440              0
# 441              0
# 442              0
# 443              0
#
# [444 rows x 37 columns]

# %%
df_analytic.columns
# Out:
# Index(['Booking_Id', 'TelNo', 'MobileNo', 'Email', 'Lead Brand',
#        'Lead Sub- Brand', 'Lead Source', 'Resort_Name', 'ProfileRef',
#        'Salutation', 'First_Name', 'Surname', 'Gender', 'Language', 'DOB',
#        'Street', 'Area', 'Town', 'County', 'Country', 'Nationality',
#        'PostCode', 'Exclude From Mailing', 'Opt In', 'Booking Code',
#        'Booking Status', 'DateArrival', 'DateDepart', 'No. of Nights',
#        'Market_Segment', 'Media_Code', 'Media Code Group', 'No. of Adult',
#        'No. of Children', 'No. of Infants', 'Contact Type', 'Odyssey Members'],
#       dtype='object')

# %%
new_cols = ['Booking_Id', 'Lead Brand', 'Lead Sub- Brand', 'Lead Source',
       'Resort_Name', 'ProfileRef', 'Salutation', 'First_Name', 'Surname',
       'Gender', 'Language', 'DOB', 'Street', 'Area', 'Town', 'County',
       'Country', 'Nationality', 'PostCode', 'TelNo', 'MobileNo', 'Email',
       'Exclude From Mailing', 'Opt In', 'Booking Status',
       'DateArrival', 'DateDepart', 'No. of Nights', 'Market_Segment',
       'Media_Code', 'Media Code Group', 'No. of Adult', 'No. of Children',
       'No. of Infants', 'Contact Type', 'Odyssey Members']																																																																																																																																						

df_analytic = df_analytic.reindex(columns=new_cols)

# %%
df_analytic.fillna('empty', inplace=True)
df_analytic['Contact Type'] = 'empty'
df_analytic['Odyssey Members'] = 'NO'

# %%
df_analytic.loc[df_analytic['Surname'] == 'empty', 'Surname'] = '-'

# %%
df_analytic['Salutation'].replace('empty', '', inplace=True)
df_analytic['First_Name'].replace('empty', '', inplace=True)
df_analytic['Surname'].replace('empty', '', inplace=True)

df_analytic['Salutation'] = df_analytic['Salutation'].str.title()
df_analytic['First_Name'] = df_analytic['First_Name'].str.title()
df_analytic['Surname'] = df_analytic['Surname'].str.title()

df_analytic
# Out:
#     Booking_Id     Lead Brand Lead Sub- Brand  Lead Source  \
# 0     KK056470  Karma Resorts           Other  Past Guests
# 1     KK055941  Karma Resorts           Other  Past Guests
# 2    KSH018615  Karma Resorts           Other  Past Guests
# 3     KK057945  Karma Resorts           Other  Past Guests
# 4    KSM012021  Karma Resorts           Other  Past Guests
# ..         ...            ...             ...          ...
# 439   KB042351  Karma Resorts           Other  Past Guests
# 440   KB043393  Karma Resorts           Other  Past Guests
# 441  KSM013431  Karma Resorts           Other  Past Guests
# 442  KLM005265  Karma Resorts           Other  Past Guests
# 443   KK050439  Karma Resorts           Other  Past Guests
#
#                 Resort_Name ProfileRef Salutation First_Name      Surname  \
# 0             Karma Kandara   PF275413         Mr   Cai Chun          Yue
# 1             Karma Kandara   PF274115         Ms       Yuan           Li
# 2        Karma Salford Hall   PF275372        Mrs   Xiaoqian           Yu
# 3             Karma Kandara   PF279381        Mrs      Bijia          Sun
# 4          Karma St Martins   PF278952        Mrs     Arlene          Alm
# ..                      ...        ...        ...        ...          ...
# 439           Karma Bavaria   PF273719                 Frank         Buhl
# 440           Karma Bavaria   PF279961       Herr     Roland         Seda
# 441        Karma St Martins   PF280229         Mr    Shanaka  Jayawardena
# 442  Karma Lake of Menteith      empty         Mr  Sebastian      Moeller
# 443           Karma Kandara   PF263567         Mr      Dawon         Jung
#
#       Gender  ...           DateDepart No. of Nights Market_Segment  \
# 0       Male  ...  14/07/2024 00:00:00             1            OTA
# 1     Female  ...  22/07/2024 00:00:00             2            OTA
# 2     Female  ...  20/07/2024 00:00:00             1            OTA
# 3     Female  ...  24/07/2024 00:00:00             2            OTA
# 4    Unknown  ...  14/07/2024 00:00:00             2            DIR
# ..       ...  ...                  ...           ...            ...
# 439  Unknown  ...  21/07/2024 00:00:00             2            OTA
# 440     Male  ...  23/07/2024 00:00:00             2            OTA
# 441  Unknown  ...  27/07/2024 00:00:00             1            OTA
# 442  Unknown  ...  16/07/2024 00:00:00             1           COMP
# 443     Male  ...  22/07/2024 00:00:00             2             TO
#
#     Media_Code Media Code Group No. of Adult No. of Children No. of Infants  \
# 0          OTA           RETAIL            2               2              0
# 1          OTA           RETAIL            3               0              0
# 2          OTA           RETAIL            2               0              0
# 3          OTA           RETAIL            4               0              0
# 4          TEL           RETAIL            1               0              0
# ..         ...              ...          ...             ...            ...
# 439        OTA           RETAIL            2               0              0
# 440        OTA           RETAIL            2               1              0
# 441        OTA           RETAIL            4               0              0
# 442      STAFF             COMP            1               0              0
# 443         TO           RETAIL            2               0              0
#
#     Contact Type Odyssey Members
# 0          empty              NO
# 1          empty              NO
# 2          empty              NO
# 3          empty              NO
# 4          empty              NO
# ..           ...             ...
# 439        empty              NO
# 440        empty              NO
# 441        empty              NO
# 442        empty              NO
# 443        empty              NO
#
# [444 rows x 36 columns]

# %%
m.clean_number(df_analytic, 'TelNo')
m.clean_number(df_analytic, 'MobileNo')
m.replace_not_valid_to_empty(df_analytic, 'TelNo')
m.replace_not_valid_to_empty(df_analytic, 'MobileNo')

df_analytic.loc[df_analytic['TelNo'].str.contains('00000'), 'TelNo'] = 'empty'
df_analytic.loc[df_analytic['MobileNo'].str.contains('00000'), 'MobileNo'] = 'empty'

m.clean_space(df_analytic, 'Email')
df_analytic['Email'] = m.lowercase(df_analytic, 'Email')

# %%
pm.email_correction(df_analytic, 'Email')

# %%
df_analytic.loc[(df_analytic['Email'] != 'empty') & ((df_analytic['TelNo'] != 'empty') | (df_analytic['MobileNo'] != 'empty')), 'Contact Type'] = 'Email and Phone'
df_analytic.loc[(df_analytic['Email'] != 'empty') & ((df_analytic['TelNo'] == 'empty') & (df_analytic['MobileNo'] == 'empty')), 'Contact Type'] = 'Email Only'
df_analytic.loc[(df_analytic['Email'] == 'empty') & ((df_analytic['TelNo'] != 'empty') | (df_analytic['MobileNo'] != 'empty')), 'Contact Type'] = 'Phone Only'

df_analytic.loc[df_analytic['Contact Type'] == 'empty'].to_csv(r'C:\Users\fajar\Documents\Python\Data\contact_type_empty_analytic.csv', index=False)

count_contact_type_empty = df_analytic.loc[df_analytic['Contact Type'] == 'empty'].shape[0]

df_analytic.drop(df_analytic.loc[df_analytic['Contact Type'] == 'empty'].index, inplace=True)
df_analytic.reset_index(drop=True, inplace=True)

count_after_contact_type_empty = df_analytic.shape[0]

df_analytic
# Out:
#     Booking_Id     Lead Brand Lead Sub- Brand  Lead Source  \
# 0     KK056470  Karma Resorts           Other  Past Guests
# 1     KK055941  Karma Resorts           Other  Past Guests
# 2    KSH018615  Karma Resorts           Other  Past Guests
# 3     KK057945  Karma Resorts           Other  Past Guests
# 4    KSM012021  Karma Resorts           Other  Past Guests
# ..         ...            ...             ...          ...
# 402   KB039010  Karma Resorts           Other  Past Guests
# 403   KB041712  Karma Resorts           Other  Past Guests
# 404   KB042351  Karma Resorts           Other  Past Guests
# 405   KB043393  Karma Resorts           Other  Past Guests
# 406  KSM013431  Karma Resorts           Other  Past Guests
#
#             Resort_Name ProfileRef Salutation First_Name      Surname  \
# 0         Karma Kandara   PF275413         Mr   Cai Chun          Yue
# 1         Karma Kandara   PF274115         Ms       Yuan           Li
# 2    Karma Salford Hall   PF275372        Mrs   Xiaoqian           Yu
# 3         Karma Kandara   PF279381        Mrs      Bijia          Sun
# 4      Karma St Martins   PF278952        Mrs     Arlene          Alm
# ..                  ...        ...        ...        ...          ...
# 402       Karma Bavaria   PF257320                Steffi     Dobmeier
# 403       Karma Bavaria   PF269944                Roxann       Dsouza
# 404       Karma Bavaria   PF273719                 Frank         Buhl
# 405       Karma Bavaria   PF279961       Herr     Roland         Seda
# 406    Karma St Martins   PF280229         Mr    Shanaka  Jayawardena
#
#       Gender  ...           DateDepart No. of Nights Market_Segment  \
# 0       Male  ...  14/07/2024 00:00:00             1            OTA
# 1     Female  ...  22/07/2024 00:00:00             2            OTA
# 2     Female  ...  20/07/2024 00:00:00             1            OTA
# 3     Female  ...  24/07/2024 00:00:00             2            OTA
# 4    Unknown  ...  14/07/2024 00:00:00             2            DIR
# ..       ...  ...                  ...           ...            ...
# 402  Unknown  ...  21/07/2024 00:00:00             2            OTA
# 403  Unknown  ...  26/07/2024 00:00:00             2            OTA
# 404  Unknown  ...  21/07/2024 00:00:00             2            OTA
# 405     Male  ...  23/07/2024 00:00:00             2            OTA
# 406  Unknown  ...  27/07/2024 00:00:00             1            OTA
#
#     Media_Code Media Code Group No. of Adult No. of Children No. of Infants  \
# 0          OTA           RETAIL            2               2              0
# 1          OTA           RETAIL            3               0              0
# 2          OTA           RETAIL            2               0              0
# 3          OTA           RETAIL            4               0              0
# 4          TEL           RETAIL            1               0              0
# ..         ...              ...          ...             ...            ...
# 402        OTA           RETAIL            2               0              0
# 403        OTA           RETAIL            2               0              0
# 404        OTA           RETAIL            2               0              0
# 405        OTA           RETAIL            2               1              0
# 406        OTA           RETAIL            4               0              0
#
#         Contact Type Odyssey Members
# 0    Email and Phone              NO
# 1    Email and Phone              NO
# 2    Email and Phone              NO
# 3    Email and Phone              NO
# 4    Email and Phone              NO
# ..               ...             ...
# 402       Phone Only              NO
# 403       Phone Only              NO
# 404       Phone Only              NO
# 405       Phone Only              NO
# 406       Phone Only              NO
#
# [407 rows x 36 columns]

# %%
# Cek Email Karma
email_karma = m.find_karma(df_analytic, 'Email')
count_email_karma = email_karma.shape[0]
email_karma.to_csv(r'C:\Users\fajar\Documents\Python\Data\email_deleted_analytic.csv', index=False)

email_karma
# Out:
#     Booking_Id     Lead Brand Lead Sub- Brand  Lead Source  \
# 7     KK057239  Karma Resorts           Other  Past Guests
# 8     KK058111  Karma Resorts           Other  Past Guests
# 10    KB042626  Karma Resorts           Other  Past Guests
# 23    KB043021  Karma Resorts           Other  Past Guests
# 24    KB043071  Karma Resorts           Other  Past Guests
# 81    KK056052  Karma Resorts           Other  Past Guests
# 187  KLM006013  Karma Resorts           Other  Past Guests
# 223  KSM013332  Karma Resorts           Other  Past Guests
# 228   KB041803  Karma Resorts           Other  Past Guests
# 296   KB043268  Karma Resorts           Other  Past Guests
# 319  KSM013350  Karma Resorts           Other  Past Guests
#
#                 Resort_Name ProfileRef Salutation First_Name     Surname  \
# 7             Karma Kandara   PF269858         Mr        Adi      Wibawa
# 8             Karma Kandara   PF269858         Mr        Adi      Wibawa
# 10            Karma Bavaria   PF196598        Mrs     Esther   Burkhardt
# 23            Karma Bavaria   PF126784       Herr       Axel  Reimlinger
# 24            Karma Bavaria   PF126784       Herr       Axel  Reimlinger
# 81            Karma Kandara   PF077581         Mr    Patrick      Lawlor
# 187  Karma Lake of Menteith   PF250060         Mr     Joseph  Antonishek
# 223        Karma St Martins   PF261021         Ms      Luisa       Nunes
# 228           Karma Bavaria   PF206245         Mr       Maik     Schramm
# 296           Karma Bavaria   PF112154       Herr  Sebastian      Möller
# 319        Karma St Martins   PF279238         Mr     Thomas      Murphy
#
#       Gender  ...           DateDepart No. of Nights Market_Segment  \
# 7       Male  ...  20/07/2024 00:00:00             1      HOUSE_USE
# 8       Male  ...  19/07/2024 00:00:00             1           COMP
# 10    Female  ...  17/07/2024 00:00:00             2           COMP
# 23      Male  ...  19/07/2024 00:00:00             4           COMP
# 24      Male  ...  23/07/2024 00:00:00             1           COMP
# 81      Male  ...  27/07/2024 00:00:00            24      HOUSE_USE
# 187     Male  ...  25/07/2024 00:00:00             3           COMP
# 223   Female  ...  16/07/2024 00:00:00             4           COMP
# 228     Male  ...  14/07/2024 14:00:00            30            LGR
# 296     Male  ...  21/07/2024 00:00:00             1           COMP
# 319  Unknown  ...  15/07/2024 00:00:00             1           COMP
#
#       Media_Code Media Code Group No. of Adult No. of Children No. of Infants  \
# 7          STAFF             COMP            1               0              0
# 8          STAFF             COMP            3               0              0
# 10         STAFF             COMP            1               0              0
# 23         STAFF             COMP            1               0              0
# 24         STAFF             COMP            1               0              0
# 81   V_OWNER_NRB             COMP            6               0              0
# 187        STAFF             COMP            1               0              0
# 223        STAFF             COMP            1               0              0
# 228          LGR            GROUP            1               0              0
# 296        STAFF             COMP            2               2              0
# 319        STAFF             COMP            2               0              0
#
#         Contact Type Odyssey Members
# 7    Email and Phone              NO
# 8    Email and Phone              NO
# 10   Email and Phone              NO
# 23   Email and Phone              NO
# 24   Email and Phone              NO
# 81   Email and Phone              NO
# 187  Email and Phone              NO
# 223  Email and Phone              NO
# 228       Email Only              NO
# 296  Email and Phone              NO
# 319  Email and Phone              NO
#
# [11 rows x 36 columns]

# %%
# delete email Karma
count_after_clean_karma = m.delete_karma(df_analytic, 'Email')

df_analytic
# Out:
#     Booking_Id     Lead Brand Lead Sub- Brand  Lead Source  \
# 0     KK056470  Karma Resorts           Other  Past Guests
# 1     KK055941  Karma Resorts           Other  Past Guests
# 2    KSH018615  Karma Resorts           Other  Past Guests
# 3     KK057945  Karma Resorts           Other  Past Guests
# 4    KSM012021  Karma Resorts           Other  Past Guests
# ..         ...            ...             ...          ...
# 391   KB039010  Karma Resorts           Other  Past Guests
# 392   KB041712  Karma Resorts           Other  Past Guests
# 393   KB042351  Karma Resorts           Other  Past Guests
# 394   KB043393  Karma Resorts           Other  Past Guests
# 395  KSM013431  Karma Resorts           Other  Past Guests
#
#             Resort_Name ProfileRef Salutation First_Name      Surname  \
# 0         Karma Kandara   PF275413         Mr   Cai Chun          Yue
# 1         Karma Kandara   PF274115         Ms       Yuan           Li
# 2    Karma Salford Hall   PF275372        Mrs   Xiaoqian           Yu
# 3         Karma Kandara   PF279381        Mrs      Bijia          Sun
# 4      Karma St Martins   PF278952        Mrs     Arlene          Alm
# ..                  ...        ...        ...        ...          ...
# 391       Karma Bavaria   PF257320                Steffi     Dobmeier
# 392       Karma Bavaria   PF269944                Roxann       Dsouza
# 393       Karma Bavaria   PF273719                 Frank         Buhl
# 394       Karma Bavaria   PF279961       Herr     Roland         Seda
# 395    Karma St Martins   PF280229         Mr    Shanaka  Jayawardena
#
#       Gender  ...           DateDepart No. of Nights Market_Segment  \
# 0       Male  ...  14/07/2024 00:00:00             1            OTA
# 1     Female  ...  22/07/2024 00:00:00             2            OTA
# 2     Female  ...  20/07/2024 00:00:00             1            OTA
# 3     Female  ...  24/07/2024 00:00:00             2            OTA
# 4    Unknown  ...  14/07/2024 00:00:00             2            DIR
# ..       ...  ...                  ...           ...            ...
# 391  Unknown  ...  21/07/2024 00:00:00             2            OTA
# 392  Unknown  ...  26/07/2024 00:00:00             2            OTA
# 393  Unknown  ...  21/07/2024 00:00:00             2            OTA
# 394     Male  ...  23/07/2024 00:00:00             2            OTA
# 395  Unknown  ...  27/07/2024 00:00:00             1            OTA
#
#     Media_Code Media Code Group No. of Adult No. of Children No. of Infants  \
# 0          OTA           RETAIL            2               2              0
# 1          OTA           RETAIL            3               0              0
# 2          OTA           RETAIL            2               0              0
# 3          OTA           RETAIL            4               0              0
# 4          TEL           RETAIL            1               0              0
# ..         ...              ...          ...             ...            ...
# 391        OTA           RETAIL            2               0              0
# 392        OTA           RETAIL            2               0              0
# 393        OTA           RETAIL            2               0              0
# 394        OTA           RETAIL            2               1              0
# 395        OTA           RETAIL            4               0              0
#
#         Contact Type Odyssey Members
# 0    Email and Phone              NO
# 1    Email and Phone              NO
# 2    Email and Phone              NO
# 3    Email and Phone              NO
# 4    Email and Phone              NO
# ..               ...             ...
# 391       Phone Only              NO
# 392       Phone Only              NO
# 393       Phone Only              NO
# 394       Phone Only              NO
# 395       Phone Only              NO
#
# [396 rows x 36 columns]

# %%
df_analytic['Salutation']
# Out:
# 0        Mr
# 1        Ms
# 2       Mrs
# 3       Mrs
# 4       Mrs
#        ...
# 391
# 392
# 393
# 394    Herr
# 395      Mr
# Name: Salutation, Length: 396, dtype: string

# %%
# Cek leads test
test_leads = df_analytic.loc[
    
        df_analytic['Email'].str.contains('^test@', flags=re.I, regex=True) |
        df_analytic['Email'].str.contains('\+test', flags=re.I, regex=True) |
    
        df_analytic['First_Name'].str.contains('^test$', flags=re.I, regex=True) |
        df_analytic['Surname'].str.contains('^test$', flags=re.I, regex=True) |

        df_analytic['First_Name'].str.contains('test 1', flags=re.I, regex=True) |
        df_analytic['Surname'].str.contains('test 2', flags=re.I, regex=True)|
        df_analytic['First_Name'].str.contains('test1', flags=re.I, regex=True) |
        df_analytic['Surname'].str.contains('test2', flags=re.I, regex=True)|

        df_analytic['First_Name'].str.contains(' test ', flags=re.I, regex=True) | 
        df_analytic['Surname'].str.contains(' test ', flags=re.I, regex=True) | 
        df_analytic['Surname'].str.contains(' test$', flags=re.I, regex=True)
    ]

count_leads_test = test_leads.shape[0]

test_leads.to_csv(r'C:\Users\fajar\Documents\Python\Data\test_leads_analytic.csv', index=False)
test_leads
# Out:
#     Booking_Id     Lead Brand Lead Sub- Brand  Lead Source    Resort_Name  \
# 191   KK056158  Karma Resorts           Other  Past Guests  Karma Kandara
#
#     ProfileRef Salutation First_Name      Surname  Gender  ...  \
# 191   PF274586       Miss       Test  Reservation  Female  ...
#
#               DateDepart No. of Nights Market_Segment Media_Code  \
# 191  26/07/2024 00:00:00             1        DIGITAL    WEBSITE
#
#     Media Code Group No. of Adult No. of Children No. of Infants  \
# 191          DIGITAL            2               0              0
#
#         Contact Type Odyssey Members
# 191  Email and Phone              NO
#
# [1 rows x 36 columns]

# %%
df_analytic.drop(test_leads.index, inplace=True)
df_analytic.reset_index(drop=True, inplace=True)

count_after_dedup_test = df_analytic.shape[0]
count_after_dedup_test
# Out:
# 395

# %%
count_final_data = count_after_dedup_test

# %%
# df_analytic.loc[(df_analytic['Email'] == 'jonmosley6@yahoo.com')]

# %%
df_analytic.replace('empty', '', inplace=True)

# %%
print("==========================================================")
print("Summary")
print("==========================================================")
print("Jumlah Data Awal Zoho Analytic : "+str(count_data_awal))
print("Jumlah Data Email dan Phone Kosong : "+str(count_contact_type_empty))
print("Jumlah Data Setelah Hapus Email dan Phone Yang Kosong : "+str(count_after_contact_type_empty))
print("Jumlah Data Email Yang Termasuk List Karma : "+str(count_email_karma))
print("Jumlah Data Email Setelah List Karma Dihapus : "+str(count_after_clean_karma))
print("Jumlah Data Test : "+str(count_leads_test))
print("Jumlah Data Email Setelah Data Test Dihapus : "+str(count_after_dedup_test))
print("Jumlah Data Akhir : "+str(count_final_data))
# Out:
# ==========================================================
# Summary
# ==========================================================
# Jumlah Data Awal Zoho Analytic : 444
# Jumlah Data Email dan Phone Kosong : 37
# Jumlah Data Setelah Hapus Email dan Phone Yang Kosong : 407
# Jumlah Data Email Yang Termasuk List Karma : 11
# Jumlah Data Email Setelah List Karma Dihapus : 396
# Jumlah Data Test : 1
# Jumlah Data Email Setelah Data Test Dihapus : 395
# Jumlah Data Akhir : 395

# %%
df_analytic.to_excel(r'C:\Users\fajar\Documents\Python\Data\check_country_code_analytic.xlsx', index=False)
