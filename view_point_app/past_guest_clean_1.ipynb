# %%
import pandas as pd
import re

import past_guest_module as pm

import sys
sys.path.append('../zoho_data_app/')

import main_module as m

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
path = r'C:\Users\fajar\Documents\Python\Data\Past Guest Data\Zoho Analytic\2024\Juli\7 July - 15 July\CRM_Rental_Report_7_July_-_15_July.xlsx'
df_analytic = pd.read_excel(path, dtype='string', sheet_name='Sheet1')
count_data_awal = df_analytic.shape[0]
df_analytic
# Out:
#     Booking_Id     Lead Brand Lead Sub- Brand  Lead Source       Resort_Name  \
# 0    KSM010228  Karma Resorts           Other  Past Guests  Karma St Martins
# 1     KK057491  Karma Resorts           Other  Past Guests     Karma Kandara
# 2     KB040725  Karma Resorts           Other  Past Guests     Karma Bavaria
# 3     KB040725  Karma Resorts           Other  Past Guests     Karma Bavaria
# 4     KB040725  Karma Resorts           Other  Past Guests     Karma Bavaria
# ..         ...            ...             ...          ...               ...
# 113   KB040621  Karma Resorts           Other  Past Guests     Karma Bavaria
# 114   KB036696  Karma Resorts           Other  Past Guests     Karma Bavaria
# 115   KB041219  Karma Resorts           Other  Past Guests     Karma Bavaria
# 116   KB042374  Karma Resorts           Other  Past Guests     Karma Bavaria
# 117   KK056678  Karma Resorts           Other  Past Guests     Karma Kandara
#
#     ProfileRef Salutation First_Name    Surname   Gender  ...  \
# 0     PF018605       <NA>    Phillip     Callan  Unknown  ...
# 1     PF278128         Mr          .       Doly     Male  ...
# 2     PF264744       Frau     Andrea     Kälber   Female  ...
# 3     PF278220       Frau       Fuer     Kälber   Female  ...
# 4     PF278213       Frau     Hensel     Kälber   Female  ...
# ..         ...        ...        ...        ...      ...  ...
# 113   PF264273       <NA>    Lyaysan  Nurullina  Unknown  ...
# 114   PF247774       <NA>       John   Karlsson  Unknown  ...
# 115   PF267164         Mr      Jacek       Kuhn     Male  ...
# 116       <NA>      Firma      Karma    Bavaria  Unknown  ...
# 117   PF276094         Mr      Manoj   Aidasani     Male  ...
#
#               DateDepart No. of Nights Market_Segment   Media_Code  \
# 0    2024-07-08 00:00:00             2           COMP          TEL
# 1    2024-07-08 00:00:00             2      HOUSE_USE  V_OWNER_NRB
# 2    2024-07-07 00:00:00             1            OTA          OTA
# 3    2024-07-07 00:00:00             1            OTA          OTA
# 4    2024-07-07 00:00:00             1            OTA          OTA
# ..                   ...           ...            ...          ...
# 113  2024-07-13 00:00:00             1            OTA          OTA
# 114  2024-07-14 00:00:00             1            OTA          OTA
# 115  2024-07-07 00:00:00             1            OTA          OTA
# 116  2024-07-14 23:00:00            19            LGR          LGR
# 117  2024-07-11 00:00:00             4            OTA          OTA
#
#     Media Code Group No. of Adult No. of Children No. of Infants Contact Type  \
# 0             RETAIL            1               0              0
# 1               COMP            3               0              0
# 2             RETAIL            4               0              0
# 3             RETAIL            3               0              0
# 4             RETAIL            4               0              0
# ..               ...          ...             ...            ...          ...
# 113           RETAIL            2               0              0
# 114           RETAIL            2               0              0
# 115           RETAIL            2               0              0
# 116            GROUP            1               0              0
# 117           RETAIL            2               0              0
#
#     Odyssey Members
# 0
# 1
# 2
# 3
# 4
# ..              ...
# 113
# 114
# 115
# 116
# 117
#
# [118 rows x 37 columns]

# %%
df_analytic.columns
# Out:
# Index(['Booking_Id', 'Lead Brand', 'Lead Sub- Brand', 'Lead Source',
#        'Resort_Name', 'ProfileRef', 'Salutation', 'First_Name', 'Surname',
#        'Gender', 'Language', 'DOB', 'Street', 'Area', 'Town', 'County',
#        'Country', 'Nationality', 'PostCode', 'TelNo', 'MobileNo', 'Email',
#        'Exclude From Mailing', 'Opt In', 'Booking Code', 'Booking Status',
#        'DateArrival', 'DateDepart', 'No. of Nights', 'Market_Segment',
#        'Media_Code', 'Media Code Group', 'No. of Adult', 'No. of Children',
#        'No. of Infants', 'Contact Type', 'Odyssey Members'],
#       dtype='object')

# %%
new_cols = ['Booking_Id', 'Lead Brand', 'Lead Sub- Brand', 'Lead Source',
       'Resort_Name', 'ProfileRef', 'Salutation', 'First_Name', 'Surname',
       'Gender', 'Language', 'DOB', 'Street', 'Area', 'Town', 'County',
       'Country', 'Nationality', 'PostCode', 'TelNo', 'MobileNo', 'Email',
       'Exclude From Mailing', 'Opt In', 'Booking Status',
       'DateArrival', 'DateDepart', 'No. of Nights', 'Market_Segment',
       'Media_Code', 'Media Code Group', 'No. of Adult', 'No. of Children',
       'No. of Infants', 'Contact Type', 'Odyssey Members']																																																																																																																																						

df_analytic = df_analytic.reindex(columns=new_cols)

# %%
df_analytic.fillna('empty', inplace=True)
df_analytic['Contact Type'] = 'empty'
df_analytic['Odyssey Members'] = 'NO'

# %%
df_analytic.loc[df_analytic['Surname'] == 'empty', 'Surname'] = '-'

# %%
df_analytic['Salutation'].replace('empty', '', inplace=True)
df_analytic['First_Name'].replace('empty', '', inplace=True)
df_analytic['Surname'].replace('empty', '', inplace=True)

df_analytic['Salutation'] = df_analytic['Salutation'].str.title()
df_analytic['First_Name'] = df_analytic['First_Name'].str.title()
df_analytic['Surname'] = df_analytic['Surname'].str.title()

df_analytic
# Out:
#     Booking_Id     Lead Brand Lead Sub- Brand  Lead Source       Resort_Name  \
# 0    KSM010228  Karma Resorts           Other  Past Guests  Karma St Martins
# 1     KK057491  Karma Resorts           Other  Past Guests     Karma Kandara
# 2     KB040725  Karma Resorts           Other  Past Guests     Karma Bavaria
# 3     KB040725  Karma Resorts           Other  Past Guests     Karma Bavaria
# 4     KB040725  Karma Resorts           Other  Past Guests     Karma Bavaria
# ..         ...            ...             ...          ...               ...
# 113   KB040621  Karma Resorts           Other  Past Guests     Karma Bavaria
# 114   KB036696  Karma Resorts           Other  Past Guests     Karma Bavaria
# 115   KB041219  Karma Resorts           Other  Past Guests     Karma Bavaria
# 116   KB042374  Karma Resorts           Other  Past Guests     Karma Bavaria
# 117   KK056678  Karma Resorts           Other  Past Guests     Karma Kandara
#
#     ProfileRef Salutation First_Name    Surname   Gender  ...  \
# 0     PF018605               Phillip     Callan  Unknown  ...
# 1     PF278128         Mr          .       Doly     Male  ...
# 2     PF264744       Frau     Andrea     Kälber   Female  ...
# 3     PF278220       Frau       Fuer     Kälber   Female  ...
# 4     PF278213       Frau     Hensel     Kälber   Female  ...
# ..         ...        ...        ...        ...      ...  ...
# 113   PF264273               Lyaysan  Nurullina  Unknown  ...
# 114   PF247774                  John   Karlsson  Unknown  ...
# 115   PF267164         Mr      Jacek       Kuhn     Male  ...
# 116      empty      Firma      Karma    Bavaria  Unknown  ...
# 117   PF276094         Mr      Manoj   Aidasani     Male  ...
#
#               DateDepart No. of Nights Market_Segment   Media_Code  \
# 0    2024-07-08 00:00:00             2           COMP          TEL
# 1    2024-07-08 00:00:00             2      HOUSE_USE  V_OWNER_NRB
# 2    2024-07-07 00:00:00             1            OTA          OTA
# 3    2024-07-07 00:00:00             1            OTA          OTA
# 4    2024-07-07 00:00:00             1            OTA          OTA
# ..                   ...           ...            ...          ...
# 113  2024-07-13 00:00:00             1            OTA          OTA
# 114  2024-07-14 00:00:00             1            OTA          OTA
# 115  2024-07-07 00:00:00             1            OTA          OTA
# 116  2024-07-14 23:00:00            19            LGR          LGR
# 117  2024-07-11 00:00:00             4            OTA          OTA
#
#     Media Code Group No. of Adult No. of Children No. of Infants Contact Type  \
# 0             RETAIL            1               0              0        empty
# 1               COMP            3               0              0        empty
# 2             RETAIL            4               0              0        empty
# 3             RETAIL            3               0              0        empty
# 4             RETAIL            4               0              0        empty
# ..               ...          ...             ...            ...          ...
# 113           RETAIL            2               0              0        empty
# 114           RETAIL            2               0              0        empty
# 115           RETAIL            2               0              0        empty
# 116            GROUP            1               0              0        empty
# 117           RETAIL            2               0              0        empty
#
#     Odyssey Members
# 0                NO
# 1                NO
# 2                NO
# 3                NO
# 4                NO
# ..              ...
# 113              NO
# 114              NO
# 115              NO
# 116              NO
# 117              NO
#
# [118 rows x 36 columns]

# %%
m.clean_number(df_analytic, 'TelNo')
m.clean_number(df_analytic, 'MobileNo')
m.replace_not_valid_to_empty(df_analytic, 'TelNo')
m.replace_not_valid_to_empty(df_analytic, 'MobileNo')

df_analytic.loc[df_analytic['TelNo'].str.contains('00000'), 'TelNo'] = 'empty'
df_analytic.loc[df_analytic['MobileNo'].str.contains('00000'), 'MobileNo'] = 'empty'

m.clean_space(df_analytic, 'Email')
df_analytic['Email'] = m.lowercase(df_analytic, 'Email')

# %%
pm.email_correction(df_analytic, 'Email')

# %%
df_analytic.loc[(df_analytic['Email'] != 'empty') & ((df_analytic['TelNo'] != 'empty') | (df_analytic['MobileNo'] != 'empty')), 'Contact Type'] = 'Email and Phone'
df_analytic.loc[(df_analytic['Email'] != 'empty') & ((df_analytic['TelNo'] == 'empty') & (df_analytic['MobileNo'] == 'empty')), 'Contact Type'] = 'Email Only'
df_analytic.loc[(df_analytic['Email'] == 'empty') & ((df_analytic['TelNo'] != 'empty') | (df_analytic['MobileNo'] != 'empty')), 'Contact Type'] = 'Phone Only'

df_analytic.loc[df_analytic['Contact Type'] == 'empty'].to_csv(r'C:\Users\fajar\Documents\Python\Data\contact_type_empty_analytic.csv', index=False)

count_contact_type_empty = df_analytic.loc[df_analytic['Contact Type'] == 'empty'].shape[0]

df_analytic.drop(df_analytic.loc[df_analytic['Contact Type'] == 'empty'].index, inplace=True)
df_analytic.reset_index(drop=True, inplace=True)

count_after_contact_type_empty = df_analytic.shape[0]

df_analytic
# Out:
#     Booking_Id     Lead Brand Lead Sub- Brand  Lead Source  \
# 0    KSM010228  Karma Resorts           Other  Past Guests
# 1     KK057491  Karma Resorts           Other  Past Guests
# 2     KB040725  Karma Resorts           Other  Past Guests
# 3     KB040725  Karma Resorts           Other  Past Guests
# 4     KB040725  Karma Resorts           Other  Past Guests
# ..         ...            ...             ...          ...
# 97   KSH018842  Karma Resorts           Other  Past Guests
# 98    KB040621  Karma Resorts           Other  Past Guests
# 99    KB036696  Karma Resorts           Other  Past Guests
# 100   KB041219  Karma Resorts           Other  Past Guests
# 101   KK056678  Karma Resorts           Other  Past Guests
#
#             Resort_Name ProfileRef Salutation First_Name    Surname   Gender  \
# 0      Karma St Martins   PF018605               Phillip     Callan  Unknown
# 1         Karma Kandara   PF278128         Mr          .       Doly     Male
# 2         Karma Bavaria   PF264744       Frau     Andrea     Kälber   Female
# 3         Karma Bavaria   PF278220       Frau       Fuer     Kälber   Female
# 4         Karma Bavaria   PF278213       Frau     Hensel     Kälber   Female
# ..                  ...        ...        ...        ...        ...      ...
# 97   Karma Salford Hall   PF277028                 Craig       Nash  Unknown
# 98        Karma Bavaria   PF264273               Lyaysan  Nurullina  Unknown
# 99        Karma Bavaria   PF247774                  John   Karlsson  Unknown
# 100       Karma Bavaria   PF267164         Mr      Jacek       Kuhn     Male
# 101       Karma Kandara   PF276094         Mr      Manoj   Aidasani     Male
#
#      ...           DateDepart No. of Nights Market_Segment   Media_Code  \
# 0    ...  2024-07-08 00:00:00             2           COMP          TEL
# 1    ...  2024-07-08 00:00:00             2      HOUSE_USE  V_OWNER_NRB
# 2    ...  2024-07-07 00:00:00             1            OTA          OTA
# 3    ...  2024-07-07 00:00:00             1            OTA          OTA
# 4    ...  2024-07-07 00:00:00             1            OTA          OTA
# ..   ...                  ...           ...            ...          ...
# 97   ...  2024-07-07 00:00:00             1            OTA          OTA
# 98   ...  2024-07-13 00:00:00             1            OTA          OTA
# 99   ...  2024-07-14 00:00:00             1            OTA          OTA
# 100  ...  2024-07-07 00:00:00             1            OTA          OTA
# 101  ...  2024-07-11 00:00:00             4            OTA          OTA
#
#     Media Code Group No. of Adult No. of Children No. of Infants  \
# 0             RETAIL            1               0              0
# 1               COMP            3               0              0
# 2             RETAIL            4               0              0
# 3             RETAIL            3               0              0
# 4             RETAIL            4               0              0
# ..               ...          ...             ...            ...
# 97            RETAIL            2               0              0
# 98            RETAIL            2               0              0
# 99            RETAIL            2               0              0
# 100           RETAIL            2               0              0
# 101           RETAIL            2               0              0
#
#         Contact Type Odyssey Members
# 0         Phone Only              NO
# 1    Email and Phone              NO
# 2    Email and Phone              NO
# 3    Email and Phone              NO
# 4    Email and Phone              NO
# ..               ...             ...
# 97        Phone Only              NO
# 98        Phone Only              NO
# 99        Phone Only              NO
# 100       Phone Only              NO
# 101       Phone Only              NO
#
# [102 rows x 36 columns]

# %%
# Cek Email Karma
email_karma = m.find_karma(df_analytic, 'Email')
count_email_karma = email_karma.shape[0]
email_karma.to_csv(r'C:\Users\fajar\Documents\Python\Data\email_deleted_analytic.csv', index=False)

email_karma
# Out:
#    Booking_Id     Lead Brand Lead Sub- Brand  Lead Source       Resort_Name  \
# 62  KSM012423  Karma Resorts           Other  Past Guests  Karma St Martins
#
#    ProfileRef Salutation First_Name  Surname   Gender  ...  \
# 62   PF231659         Mr  Sebastian  Moeller  Unknown  ...
#
#              DateDepart No. of Nights Market_Segment Media_Code  \
# 62  2024-07-12 00:00:00             3           COMP      STAFF
#
#    Media Code Group No. of Adult No. of Children No. of Infants Contact Type  \
# 62             COMP            2               0              0   Email Only
#
#    Odyssey Members
# 62              NO
#
# [1 rows x 36 columns]

# %%
# delete email Karma
count_after_clean_karma = m.delete_karma(df_analytic, 'Email')

df_analytic
# Out:
#     Booking_Id     Lead Brand Lead Sub- Brand  Lead Source  \
# 0    KSM010228  Karma Resorts           Other  Past Guests
# 1     KK057491  Karma Resorts           Other  Past Guests
# 2     KB040725  Karma Resorts           Other  Past Guests
# 3     KB040725  Karma Resorts           Other  Past Guests
# 4     KB040725  Karma Resorts           Other  Past Guests
# ..         ...            ...             ...          ...
# 96   KSH018842  Karma Resorts           Other  Past Guests
# 97    KB040621  Karma Resorts           Other  Past Guests
# 98    KB036696  Karma Resorts           Other  Past Guests
# 99    KB041219  Karma Resorts           Other  Past Guests
# 100   KK056678  Karma Resorts           Other  Past Guests
#
#             Resort_Name ProfileRef Salutation First_Name    Surname   Gender  \
# 0      Karma St Martins   PF018605               Phillip     Callan  Unknown
# 1         Karma Kandara   PF278128         Mr          .       Doly     Male
# 2         Karma Bavaria   PF264744       Frau     Andrea     Kälber   Female
# 3         Karma Bavaria   PF278220       Frau       Fuer     Kälber   Female
# 4         Karma Bavaria   PF278213       Frau     Hensel     Kälber   Female
# ..                  ...        ...        ...        ...        ...      ...
# 96   Karma Salford Hall   PF277028                 Craig       Nash  Unknown
# 97        Karma Bavaria   PF264273               Lyaysan  Nurullina  Unknown
# 98        Karma Bavaria   PF247774                  John   Karlsson  Unknown
# 99        Karma Bavaria   PF267164         Mr      Jacek       Kuhn     Male
# 100       Karma Kandara   PF276094         Mr      Manoj   Aidasani     Male
#
#      ...           DateDepart No. of Nights Market_Segment   Media_Code  \
# 0    ...  2024-07-08 00:00:00             2           COMP          TEL
# 1    ...  2024-07-08 00:00:00             2      HOUSE_USE  V_OWNER_NRB
# 2    ...  2024-07-07 00:00:00             1            OTA          OTA
# 3    ...  2024-07-07 00:00:00             1            OTA          OTA
# 4    ...  2024-07-07 00:00:00             1            OTA          OTA
# ..   ...                  ...           ...            ...          ...
# 96   ...  2024-07-07 00:00:00             1            OTA          OTA
# 97   ...  2024-07-13 00:00:00             1            OTA          OTA
# 98   ...  2024-07-14 00:00:00             1            OTA          OTA
# 99   ...  2024-07-07 00:00:00             1            OTA          OTA
# 100  ...  2024-07-11 00:00:00             4            OTA          OTA
#
#     Media Code Group No. of Adult No. of Children No. of Infants  \
# 0             RETAIL            1               0              0
# 1               COMP            3               0              0
# 2             RETAIL            4               0              0
# 3             RETAIL            3               0              0
# 4             RETAIL            4               0              0
# ..               ...          ...             ...            ...
# 96            RETAIL            2               0              0
# 97            RETAIL            2               0              0
# 98            RETAIL            2               0              0
# 99            RETAIL            2               0              0
# 100           RETAIL            2               0              0
#
#         Contact Type Odyssey Members
# 0         Phone Only              NO
# 1    Email and Phone              NO
# 2    Email and Phone              NO
# 3    Email and Phone              NO
# 4    Email and Phone              NO
# ..               ...             ...
# 96        Phone Only              NO
# 97        Phone Only              NO
# 98        Phone Only              NO
# 99        Phone Only              NO
# 100       Phone Only              NO
#
# [101 rows x 36 columns]

# %%
df_analytic['Salutation']
# Out:
# 0
# 1        Mr
# 2      Frau
# 3      Frau
# 4      Frau
#        ...
# 96
# 97
# 98
# 99       Mr
# 100      Mr
# Name: Salutation, Length: 101, dtype: string

# %%
# Cek leads test
test_leads = df_analytic.loc[
    
        df_analytic['Email'].str.contains('^test@', flags=re.I, regex=True) |
        df_analytic['Email'].str.contains('\+test', flags=re.I, regex=True) |
    
        df_analytic['First_Name'].str.contains('^test$', flags=re.I, regex=True) |
        df_analytic['Surname'].str.contains('^test$', flags=re.I, regex=True) |

        df_analytic['First_Name'].str.contains('test 1', flags=re.I, regex=True) |
        df_analytic['Surname'].str.contains('test 2', flags=re.I, regex=True)|
        df_analytic['First_Name'].str.contains('test1', flags=re.I, regex=True) |
        df_analytic['Surname'].str.contains('test2', flags=re.I, regex=True)|

        df_analytic['First_Name'].str.contains(' test ', flags=re.I, regex=True) | 
        df_analytic['Surname'].str.contains(' test ', flags=re.I, regex=True) | 
        df_analytic['Surname'].str.contains(' test$', flags=re.I, regex=True)
    ]

count_leads_test = test_leads.shape[0]

test_leads.to_csv(r'C:\Users\fajar\Documents\Python\Data\test_leads_analytic.csv', index=False)
test_leads
# Out:
# Empty DataFrame
# Columns: [Booking_Id, Lead Brand, Lead Sub- Brand, Lead Source, Resort_Name, ProfileRef, Salutation, First_Name, Surname, Gender, Language, DOB, Street, Area, Town, County, Country, Nationality, PostCode, TelNo, MobileNo, Email, Exclude From Mailing, Opt In, Booking Status, DateArrival, DateDepart, No. of Nights, Market_Segment, Media_Code, Media Code Group, No. of Adult, No. of Children, No. of Infants, Contact Type, Odyssey Members]
# Index: []
#
# [0 rows x 36 columns]

# %%
df_analytic.drop(test_leads.index, inplace=True)
df_analytic.reset_index(drop=True, inplace=True)

count_after_dedup_test = df_analytic.shape[0]
count_after_dedup_test
# Out:
# 101

# %%
count_final_data = count_after_dedup_test

# %%
# df_analytic.loc[(df_analytic['Email'] == 'jonmosley6@yahoo.com')]

# %%
df_analytic.replace('empty', '', inplace=True)

# %%
print("==========================================================")
print("Summary")
print("==========================================================")
print("Jumlah Data Awal Zoho Analytic : "+str(count_data_awal))
print("Jumlah Data Email dan Phone Kosong : "+str(count_contact_type_empty))
print("Jumlah Data Setelah Hapus Email dan Phone Yang Kosong : "+str(count_after_contact_type_empty))
print("Jumlah Data Email Yang Termasuk List Karma : "+str(count_email_karma))
print("Jumlah Data Email Setelah List Karma Dihapus : "+str(count_after_clean_karma))
print("Jumlah Data Test : "+str(count_leads_test))
print("Jumlah Data Email Setelah Data Test Dihapus : "+str(count_after_dedup_test))
print("Jumlah Data Akhir : "+str(count_final_data))
# Out:
# ==========================================================
# Summary
# ==========================================================
# Jumlah Data Awal Zoho Analytic : 118
# Jumlah Data Email dan Phone Kosong : 16
# Jumlah Data Setelah Hapus Email dan Phone Yang Kosong : 102
# Jumlah Data Email Yang Termasuk List Karma : 1
# Jumlah Data Email Setelah List Karma Dihapus : 101
# Jumlah Data Test : 0
# Jumlah Data Email Setelah Data Test Dihapus : 101
# Jumlah Data Akhir : 101

# %%
df_analytic.to_excel(r'C:\Users\fajar\Documents\Python\Data\check_country_code_analytic.xlsx', index=False)
