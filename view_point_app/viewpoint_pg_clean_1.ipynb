# %%
import pandas as pd
import re

import past_guest_module as pm

import sys
sys.path.append('../zoho_data_app/')

import main_module as m

# %load_ext autoreload
# %autoreload 2

# %%
path = r'C:\Users\fajar\Documents\Python\Data\Past Guest Data\View Point\2024\Aug\4 Aug - 12 Aug\CheckOutReport 4 Aug - 12 Aug.xlsx'
df_viewpoint = pd.read_excel(path, dtype='string', sheet_name='Sheet1')
count_data_awal = df_viewpoint.shape[0]
df_viewpoint
# Out:
#      Title       Firstname    lastname                  DOB     PAN CARD  \
# 0       Ms         YINGLIN        ZHAO                 <NA>         <NA>
# 1       Mr            Yiyu         Zhu  1986-08-23 00:00:00         <NA>
# 2       Mr        YONGCHAO        TANG  2001-06-06 00:00:00         <NA>
# 3       Mr  Bhushan Ramesh      Chavan  1988-11-22 00:00:00   ALDPC2142B
# 4       Mr           David       Flatz  1957-09-04 00:00:00         <NA>
# ...    ...             ...         ...                  ...          ...
# 1488  <NA>            ERIC      LEROUX                 <NA>         <NA>
# 1489  <NA>           Walid  Benghabrit                 <NA>         <NA>
# 1490  <NA>        Baptiste       THEFO                 <NA>         <NA>
# 1491  <NA>            ERIC      LEROUX                 <NA>         <NA>
# 1492   krg    Fajar Fatoni          86                 <NA>         <NA>
#
#                          Email          Phone        Mobile  \
# 0          15630101619@163.com  8615630101619  628113855855
# 1              16088354@qq.com  8618696668775  628113855855
# 2            1789663701@qq.com  8618235441999          <NA>
# 3     1bhushanchavan@gmail.com   919372945279          <NA>
# 4            57flatz@gmail.com   441915214120  447478722704
# ...                        ...            ...           ...
# 1488                      <NA>           <NA>          <NA>
# 1489                      <NA>           <NA>          <NA>
# 1490                      <NA>           <NA>          <NA>
# 1491                      <NA>           <NA>          <NA>
# 1492                      <NA>           <NA>          <NA>
#
#                                         AddressLine1  \
# 0                                                  -
# 1                                                  -
# 2                                             Shanxi
# 3     FLAT NO 101, VASTUSHREE BUILDING JYESHTNAGARIK
# 4                                        7 HOPTON DR
# ...                                              ...
# 1488                                               -
# 1489                                               -
# 1490                                               -
# 1491                                               -
# 1492                                            <NA>
#
#                                AddressLine2  ...          CheckInDate  \
# 0                                      <NA>  ...  2024-08-04 01:24:40
# 1                                      <NA>  ...  2024-08-08 21:25:27
# 2                                      <NA>  ...  2024-08-03 13:10:28
# 3     OPP PANVEL RURAL HOSPITAL. SANGH MARG  ...  2024-08-01 19:08:09
# 4                   Hawksley Grange, Ryhope  ...  2024-08-08 23:32:07
# ...                                     ...  ...                  ...
# 1488                                   <NA>  ...  2024-08-10 23:04:05
# 1489                                   <NA>  ...  2024-08-10 00:38:44
# 1490                                   <NA>  ...  2024-08-10 20:40:05
# 1491                                   <NA>  ...  2024-08-10 23:02:51
# 1492                                   <NA>  ...                 <NA>
#
#              CheckOutDate    room                    UnitCategory BookingNo  \
# 0     2024-08-06 16:38:13  07 - N  3 Bedroom Garden View Pool Vil   2578094
# 1     2024-08-10 16:24:31    18-N           4 Bedroom Valley View   2539694
# 2     2024-08-04 15:32:45      11  3 Bedroom Garden View Pool Vil   2579805
# 3     2024-08-05 14:23:26    V102            2 Bedroom Fractional   2578031
# 4     2024-08-10 15:02:05       4                   Heritage Room   2533656
# ...                   ...     ...                             ...       ...
# 1488  2024-08-11 16:00:24     225             1 Bedroom Apartment   2590389
# 1489  2024-08-11 16:02:07     121                Studio Apartment   2589372
# 1490  2024-08-11 16:03:23     234             1 Bedroom Apartment   2590387
# 1491  2024-08-11 16:07:01     232                Studio Apartment   2590388
# 1492                 <NA>    <NA>                            <NA>      <NA>
#
#      BookingSourceDesc     BookingTypeDesc Date of Tour  \
# 0       Hotel Bookings     Nakula - Rental         <NA>
# 1       Hotel Bookings     Nakula - Rental         <NA>
# 2       Hotel Bookings     Nakula - Rental         <NA>
# 3            KC Member  Entitlement Member         <NA>
# 4            KC Member  Entitlement Member         <NA>
# ...                ...                 ...          ...
# 1488    Hotel Bookings      Wyndham Guests         <NA>
# 1489    Hotel Bookings         Booking.com         <NA>
# 1490    Hotel Bookings      Wyndham Guests         <NA>
# 1491    Hotel Bookings      Wyndham Guests         <NA>
# 1492              <NA>                <NA>         <NA>
#
#      Sales Rep and Comments Opt In
# 0                      <NA>    YES
# 1                      <NA>    YES
# 2                      <NA>    YES
# 3                      <NA>    YES
# 4                      <NA>     NO
# ...                     ...    ...
# 1488                   <NA>    YES
# 1489                   <NA>    YES
# 1490                   <NA>    YES
# 1491                   <NA>    YES
# 1492                   <NA>   <NA>
#
# [1493 rows x 29 columns]

# %%
df_viewpoint.columns
# Out:
# Index(['Title', 'Firstname', 'lastname', 'DOB', 'PAN CARD', 'Email', 'Phone',
#        'Mobile', 'AddressLine1', 'AddressLine2', 'Town', 'State', 'Country',
#        'PostCode', 'Nationality', 'MaritalStatus', 'resortname', 'Arrival',
#        'Departure', 'CheckInDate', 'CheckOutDate', 'room', 'UnitCategory',
#        'BookingNo', 'BookingSourceDesc', 'BookingTypeDesc', 'Date of Tour',
#        'Sales Rep and Comments', 'Opt In'],
#       dtype='object')

# %%
df_viewpoint.fillna('empty', inplace=True)

df_viewpoint['Contact Type'] = 'empty'
df_viewpoint['Odyssey Members'] = 'NO'

df_viewpoint['Lead Brand'] = 'Karma Resorts'
df_viewpoint['Lead Sub-Brand'] = 'Other'
df_viewpoint['Lead Source'] = 'Past Guests'
df_viewpoint['Lead Locations'] = df_viewpoint['resortname']
df_viewpoint['Lead Source Description'] = 'Viewpoint'

# %%
df_viewpoint.loc[df_viewpoint['Opt In'] == 'YES', 'Exclude From Mailing'] = 'NO'
df_viewpoint.loc[df_viewpoint['Opt In'] == 'NO', 'Exclude From Mailing'] = 'YES'

# %%
df_viewpoint.loc[df_viewpoint['lastname'] == 'empty', 'lastname'] = '-'

# %%
df_viewpoint['Title'].replace('empty', '', inplace=True)
df_viewpoint['Firstname'].replace('empty', '', inplace=True)
df_viewpoint['lastname'].replace('empty', '', inplace=True)

df_viewpoint['Title'] = df_viewpoint['Title'].str.title()
df_viewpoint['Firstname'] = df_viewpoint['Firstname'].str.title()
df_viewpoint['lastname'] = df_viewpoint['lastname'].str.title()

df_viewpoint
# Out:
#      Title       Firstname    lastname                  DOB     PAN CARD  \
# 0       Ms         Yinglin        Zhao                empty        empty
# 1       Mr            Yiyu         Zhu  1986-08-23 00:00:00        empty
# 2       Mr        Yongchao        Tang  2001-06-06 00:00:00        empty
# 3       Mr  Bhushan Ramesh      Chavan  1988-11-22 00:00:00   ALDPC2142B
# 4       Mr           David       Flatz  1957-09-04 00:00:00        empty
# ...    ...             ...         ...                  ...          ...
# 1488                  Eric      Leroux                empty        empty
# 1489                 Walid  Benghabrit                empty        empty
# 1490              Baptiste       Thefo                empty        empty
# 1491                  Eric      Leroux                empty        empty
# 1492   Krg    Fajar Fatoni          86                empty        empty
#
#                          Email          Phone        Mobile  \
# 0          15630101619@163.com  8615630101619  628113855855
# 1              16088354@qq.com  8618696668775  628113855855
# 2            1789663701@qq.com  8618235441999         empty
# 3     1bhushanchavan@gmail.com   919372945279         empty
# 4            57flatz@gmail.com   441915214120  447478722704
# ...                        ...            ...           ...
# 1488                     empty          empty         empty
# 1489                     empty          empty         empty
# 1490                     empty          empty         empty
# 1491                     empty          empty         empty
# 1492                     empty          empty         empty
#
#                                         AddressLine1  \
# 0                                                  -
# 1                                                  -
# 2                                             Shanxi
# 3     FLAT NO 101, VASTUSHREE BUILDING JYESHTNAGARIK
# 4                                        7 HOPTON DR
# ...                                              ...
# 1488                                               -
# 1489                                               -
# 1490                                               -
# 1491                                               -
# 1492                                           empty
#
#                                AddressLine2  ... Sales Rep and Comments  \
# 0                                     empty  ...                  empty
# 1                                     empty  ...                  empty
# 2                                     empty  ...                  empty
# 3     OPP PANVEL RURAL HOSPITAL. SANGH MARG  ...                  empty
# 4                   Hawksley Grange, Ryhope  ...                  empty
# ...                                     ...  ...                    ...
# 1488                                  empty  ...                  empty
# 1489                                  empty  ...                  empty
# 1490                                  empty  ...                  empty
# 1491                                  empty  ...                  empty
# 1492                                  empty  ...                  empty
#
#      Opt In Contact Type Odyssey Members     Lead Brand Lead Sub-Brand  \
# 0       YES        empty              NO  Karma Resorts          Other
# 1       YES        empty              NO  Karma Resorts          Other
# 2       YES        empty              NO  Karma Resorts          Other
# 3       YES        empty              NO  Karma Resorts          Other
# 4        NO        empty              NO  Karma Resorts          Other
# ...     ...          ...             ...            ...            ...
# 1488    YES        empty              NO  Karma Resorts          Other
# 1489    YES        empty              NO  Karma Resorts          Other
# 1490    YES        empty              NO  Karma Resorts          Other
# 1491    YES        empty              NO  Karma Resorts          Other
# 1492  empty        empty              NO  Karma Resorts          Other
#
#       Lead Source                     Lead Locations Lead Source Description  \
# 0     Past Guests                     Karma Jimbaran               Viewpoint
# 1     Past Guests                     Karma Jimbaran               Viewpoint
# 2     Past Guests                     Karma Jimbaran               Viewpoint
# 3     Past Guests           Karma Royal Haathi Mahal               Viewpoint
# 4     Past Guests             Karma Lake of Menteith               Viewpoint
# ...           ...                                ...                     ...
# 1488  Past Guests  Wyndham -  Manoir des Deux Amants               Viewpoint
# 1489  Past Guests  Wyndham -  Manoir des Deux Amants               Viewpoint
# 1490  Past Guests  Wyndham -  Manoir des Deux Amants               Viewpoint
# 1491  Past Guests  Wyndham -  Manoir des Deux Amants               Viewpoint
# 1492  Past Guests                              empty               Viewpoint
#
#      Exclude From Mailing
# 0                      NO
# 1                      NO
# 2                      NO
# 3                      NO
# 4                     YES
# ...                   ...
# 1488                   NO
# 1489                   NO
# 1490                   NO
# 1491                   NO
# 1492                  NaN
#
# [1493 rows x 37 columns]

# %%
m.clean_number(df_viewpoint, 'Phone')
m.clean_number(df_viewpoint, 'Mobile')
m.replace_not_valid_to_empty(df_viewpoint, 'Phone')
m.replace_not_valid_to_empty(df_viewpoint, 'Mobile')

df_viewpoint.loc[df_viewpoint['Phone'].str.contains('00000'), 'Phone'] = 'empty'
df_viewpoint.loc[df_viewpoint['Mobile'].str.contains('00000'), 'Mobile'] = 'empty'

m.clean_space(df_viewpoint, 'Email')
df_viewpoint['Email'] = m.lowercase(df_viewpoint, 'Email')

# %%
pm.email_correction(df_viewpoint, 'Email')

# %%
df_viewpoint.loc[(df_viewpoint['Email'] != 'empty') & ((df_viewpoint['Phone'] != 'empty') | (df_viewpoint['Mobile'] != 'empty')), 'Contact Type'] = 'Email and Phone'
df_viewpoint.loc[(df_viewpoint['Email'] != 'empty') & ((df_viewpoint['Phone'] == 'empty') & (df_viewpoint['Mobile'] == 'empty')), 'Contact Type'] = 'Email Only'
df_viewpoint.loc[(df_viewpoint['Email'] == 'empty') & ((df_viewpoint['Phone'] != 'empty') | (df_viewpoint['Mobile'] != 'empty')), 'Contact Type'] = 'Phone Only'

df_viewpoint.loc[df_viewpoint['Contact Type'] == 'empty'].to_csv(r'C:\Users\fajar\Documents\Python\Data\contact_type_empty_viewpoint.csv', index=False)

count_contact_type_empty = df_viewpoint.loc[df_viewpoint['Contact Type'] == 'empty'].shape[0]

df_viewpoint.drop(df_viewpoint.loc[df_viewpoint['Contact Type'] == 'empty'].index, inplace=True)
df_viewpoint.reset_index(drop=True, inplace=True)

count_after_contact_type_empty = df_viewpoint.shape[0]

df_viewpoint
# Out:
#      Title       Firstname lastname                  DOB     PAN CARD  \
# 0       Ms         Yinglin     Zhao                empty        empty
# 1       Mr            Yiyu      Zhu  1986-08-23 00:00:00        empty
# 2       Mr        Yongchao     Tang  2001-06-06 00:00:00        empty
# 3       Mr  Bhushan Ramesh   Chavan  1988-11-22 00:00:00   ALDPC2142B
# 4       Mr           David    Flatz  1957-09-04 00:00:00        empty
# ...    ...             ...      ...                  ...          ...
# 1348    Mr            Prem    Kumar  1974-01-31 00:00:00        empty
# 1349     -            Iris    Frund                empty        empty
# 1350     -         Kirsten  Schuijt                empty        empty
# 1351     -         Antoine   Hovine                empty        empty
# 1352   Mrs           Marie  Souliez                empty        empty
#
#                          Email          Phone        Mobile  \
# 0          15630101619@163.com  8615630101619  628113855855
# 1              16088354@qq.com  8618696668775  628113855855
# 2            1789663701@qq.com  8618235441999         empty
# 3     1bhushanchavan@gmail.com   919372945279         empty
# 4            57flatz@gmail.com   441915214120  447478722704
# ...                        ...            ...           ...
# 1348                     empty   918860976030  918010438488
# 1349                     empty    31618650503         empty
# 1350                     empty    31627131954         empty
# 1351                     empty    33677732929         empty
# 1352                     empty    33629243036         empty
#
#                                         AddressLine1  \
# 0                                                  -
# 1                                                  -
# 2                                             Shanxi
# 3     FLAT NO 101, VASTUSHREE BUILDING JYESHTNAGARIK
# 4                                        7 HOPTON DR
# ...                                              ...
# 1348                       C46 NAYA BAZAR  NAJAFGARH
# 1349                                           empty
# 1350                                           empty
# 1351                                           empty
# 1352                                               .
#
#                                AddressLine2  ... Sales Rep and Comments  \
# 0                                     empty  ...                  empty
# 1                                     empty  ...                  empty
# 2                                     empty  ...                  empty
# 3     OPP PANVEL RURAL HOSPITAL. SANGH MARG  ...                  empty
# 4                   Hawksley Grange, Ryhope  ...                  empty
# ...                                     ...  ...                    ...
# 1348                       NEW DELHI 110043  ...                  empty
# 1349                                  empty  ...                  empty
# 1350                                  empty  ...                  empty
# 1351                                  empty  ...                  empty
# 1352                                      .  ...                  empty
#
#      Opt In     Contact Type Odyssey Members     Lead Brand Lead Sub-Brand  \
# 0       YES  Email and Phone              NO  Karma Resorts          Other
# 1       YES  Email and Phone              NO  Karma Resorts          Other
# 2       YES  Email and Phone              NO  Karma Resorts          Other
# 3       YES  Email and Phone              NO  Karma Resorts          Other
# 4        NO  Email and Phone              NO  Karma Resorts          Other
# ...     ...              ...             ...            ...            ...
# 1348    YES       Phone Only              NO  Karma Resorts          Other
# 1349    YES       Phone Only              NO  Karma Resorts          Other
# 1350    YES       Phone Only              NO  Karma Resorts          Other
# 1351    YES       Phone Only              NO  Karma Resorts          Other
# 1352    YES       Phone Only              NO  Karma Resorts          Other
#
#       Lead Source                     Lead Locations Lead Source Description  \
# 0     Past Guests                     Karma Jimbaran               Viewpoint
# 1     Past Guests                     Karma Jimbaran               Viewpoint
# 2     Past Guests                     Karma Jimbaran               Viewpoint
# 3     Past Guests           Karma Royal Haathi Mahal               Viewpoint
# 4     Past Guests             Karma Lake of Menteith               Viewpoint
# ...           ...                                ...                     ...
# 1348  Past Guests            Karma Sitabani, Corbett               Viewpoint
# 1349  Past Guests  Wyndham -  Manoir des Deux Amants               Viewpoint
# 1350  Past Guests  Wyndham -  Manoir des Deux Amants               Viewpoint
# 1351  Past Guests  Wyndham -  Manoir des Deux Amants               Viewpoint
# 1352  Past Guests  Wyndham -  Manoir des Deux Amants               Viewpoint
#
#      Exclude From Mailing
# 0                      NO
# 1                      NO
# 2                      NO
# 3                      NO
# 4                     YES
# ...                   ...
# 1348                   NO
# 1349                   NO
# 1350                   NO
# 1351                   NO
# 1352                   NO
#
# [1353 rows x 37 columns]

# %%
# Cek Email Karma
email_karma = m.find_karma(df_viewpoint, 'Email')
count_email_karma = email_karma.shape[0]
email_karma.to_csv(r'C:\Users\fajar\Documents\Python\Data\email_deleted_viewpoint.csv', index=False)

email_karma
# Out:
#      Title           Firstname              lastname    DOB PAN CARD  \
# 234           Maintenance Room          Karma Chakra  empty    empty
# 235           Maintenance Room          Karma Chakra  empty    empty
# 236           Maintenance Room          Karma Chakra  empty    empty
# 237           Maintenance Room          Karma Chakra  empty    empty
# 273     Mr               David                Hadson  empty    empty
# 391     Mr              George                  Lobo  empty    empty
# 392     Mr              George                  Lobo  empty    empty
# 473     Mr               James                 Casey  empty    empty
# 719      -  Maintenance Room -  Karma Royal Monterio  empty    empty
# 1099    Mr                Shiv                 Suman  empty    empty
# 1100    Mr                Shiv                 Suman  empty    empty
# 1101    Mr                Shiv                 Suman  empty    empty
#
#                             Email         Phone        Mobile  \
# 234         chakra@karmagroup.com  914812526252  919446080121
# 235         chakra@karmagroup.com  914812526252  919446080121
# 236         chakra@karmagroup.com  914812526252  919446080121
# 237         chakra@karmagroup.com  914812526252  919446080121
# 273   david.hadson@karmagroup.com  626236341519         empty
# 391    george.lobo@karmagroup.com  918326725300         empty
# 392    george.lobo@karmagroup.com  918326725300         empty
# 473    james.casey@karmagroup.com         empty         empty
# 719     mr.asstfom@karmagroup.com  918326716200         empty
# 1099   shivsuman.b@karmagroup.com  919325868122         empty
# 1100   shivsuman.b@karmagroup.com  919325868122         empty
# 1101   shivsuman.b@karmagroup.com  919325868122         empty
#
#                                   AddressLine1         AddressLine2  ...  \
# 234   Ward # 09, Block#12, Near Nasrath Church             KOTTAYAM  ...
# 235   Ward # 09, Block#12, Near Nasrath Church             KOTTAYAM  ...
# 236   Ward # 09, Block#12, Near Nasrath Church             KOTTAYAM  ...
# 237   Ward # 09, Block#12, Near Nasrath Church             KOTTAYAM  ...
# 273                               C/- IVO BALI                empty  ...
# 391               c/o karma royal Haathi mahal                empty  ...
# 392               c/o karma royal Haathi mahal                empty  ...
# 473      Jl. By Pass Ngurah Rai No.61, Pemogan  Kec. Denpasar Sel.,  ...
# 719                       karma royal monetrio               Arpora  ...
# 1099                                         -                    -  ...
# 1100                                         -                    -  ...
# 1101                                         -                    -  ...
#
#      Sales Rep and Comments Opt In     Contact Type Odyssey Members  \
# 234                   empty    YES  Email and Phone              NO
# 235                   empty    YES  Email and Phone              NO
# 236                   empty    YES  Email and Phone              NO
# 237                   empty    YES  Email and Phone              NO
# 273                   empty    YES  Email and Phone              NO
# 391                   empty    YES  Email and Phone              NO
# 392                   empty    YES  Email and Phone              NO
# 473                   empty    YES       Email Only              NO
# 719                   empty    YES  Email and Phone              NO
# 1099                  empty    YES  Email and Phone              NO
# 1100                  empty    YES  Email and Phone              NO
# 1101                  empty    YES  Email and Phone              NO
#
#          Lead Brand Lead Sub-Brand  Lead Source            Lead Locations  \
# 234   Karma Resorts          Other  Past Guests      Karma Chakra, Kerala
# 235   Karma Resorts          Other  Past Guests      Karma Chakra, Kerala
# 236   Karma Resorts          Other  Past Guests      Karma Chakra, Kerala
# 237   Karma Resorts          Other  Past Guests      Karma Chakra, Kerala
# 273   Karma Resorts          Other  Past Guests  Karma Royal Haathi Mahal
# 391   Karma Resorts          Other  Past Guests      Karma Chakra, Kerala
# 392   Karma Resorts          Other  Past Guests      Karma Munnar, Kerala
# 473   Karma Resorts          Other  Past Guests           Karma Song Hoai
# 719   Karma Resorts          Other  Past Guests      Karma Royal Monterio
# 1099  Karma Resorts          Other  Past Guests      Karma Royal Monterio
# 1100  Karma Resorts          Other  Past Guests      Karma Royal Monterio
# 1101  Karma Resorts          Other  Past Guests      Karma Royal Monterio
#
#      Lead Source Description Exclude From Mailing
# 234                Viewpoint                   NO
# 235                Viewpoint                   NO
# 236                Viewpoint                   NO
# 237                Viewpoint                   NO
# 273                Viewpoint                   NO
# 391                Viewpoint                   NO
# 392                Viewpoint                   NO
# 473                Viewpoint                   NO
# 719                Viewpoint                   NO
# 1099               Viewpoint                   NO
# 1100               Viewpoint                   NO
# 1101               Viewpoint                   NO
#
# [12 rows x 37 columns]

# %%
# delete email Karma
count_after_clean_karma = m.delete_karma(df_viewpoint, 'Email')

df_viewpoint
# Out:
#      Title       Firstname lastname                  DOB     PAN CARD  \
# 0       Ms         Yinglin     Zhao                empty        empty
# 1       Mr            Yiyu      Zhu  1986-08-23 00:00:00        empty
# 2       Mr        Yongchao     Tang  2001-06-06 00:00:00        empty
# 3       Mr  Bhushan Ramesh   Chavan  1988-11-22 00:00:00   ALDPC2142B
# 4       Mr           David    Flatz  1957-09-04 00:00:00        empty
# ...    ...             ...      ...                  ...          ...
# 1336    Mr            Prem    Kumar  1974-01-31 00:00:00        empty
# 1337     -            Iris    Frund                empty        empty
# 1338     -         Kirsten  Schuijt                empty        empty
# 1339     -         Antoine   Hovine                empty        empty
# 1340   Mrs           Marie  Souliez                empty        empty
#
#                          Email          Phone        Mobile  \
# 0          15630101619@163.com  8615630101619  628113855855
# 1              16088354@qq.com  8618696668775  628113855855
# 2            1789663701@qq.com  8618235441999         empty
# 3     1bhushanchavan@gmail.com   919372945279         empty
# 4            57flatz@gmail.com   441915214120  447478722704
# ...                        ...            ...           ...
# 1336                     empty   918860976030  918010438488
# 1337                     empty    31618650503         empty
# 1338                     empty    31627131954         empty
# 1339                     empty    33677732929         empty
# 1340                     empty    33629243036         empty
#
#                                         AddressLine1  \
# 0                                                  -
# 1                                                  -
# 2                                             Shanxi
# 3     FLAT NO 101, VASTUSHREE BUILDING JYESHTNAGARIK
# 4                                        7 HOPTON DR
# ...                                              ...
# 1336                       C46 NAYA BAZAR  NAJAFGARH
# 1337                                           empty
# 1338                                           empty
# 1339                                           empty
# 1340                                               .
#
#                                AddressLine2  ... Sales Rep and Comments  \
# 0                                     empty  ...                  empty
# 1                                     empty  ...                  empty
# 2                                     empty  ...                  empty
# 3     OPP PANVEL RURAL HOSPITAL. SANGH MARG  ...                  empty
# 4                   Hawksley Grange, Ryhope  ...                  empty
# ...                                     ...  ...                    ...
# 1336                       NEW DELHI 110043  ...                  empty
# 1337                                  empty  ...                  empty
# 1338                                  empty  ...                  empty
# 1339                                  empty  ...                  empty
# 1340                                      .  ...                  empty
#
#      Opt In     Contact Type Odyssey Members     Lead Brand Lead Sub-Brand  \
# 0       YES  Email and Phone              NO  Karma Resorts          Other
# 1       YES  Email and Phone              NO  Karma Resorts          Other
# 2       YES  Email and Phone              NO  Karma Resorts          Other
# 3       YES  Email and Phone              NO  Karma Resorts          Other
# 4        NO  Email and Phone              NO  Karma Resorts          Other
# ...     ...              ...             ...            ...            ...
# 1336    YES       Phone Only              NO  Karma Resorts          Other
# 1337    YES       Phone Only              NO  Karma Resorts          Other
# 1338    YES       Phone Only              NO  Karma Resorts          Other
# 1339    YES       Phone Only              NO  Karma Resorts          Other
# 1340    YES       Phone Only              NO  Karma Resorts          Other
#
#       Lead Source                     Lead Locations Lead Source Description  \
# 0     Past Guests                     Karma Jimbaran               Viewpoint
# 1     Past Guests                     Karma Jimbaran               Viewpoint
# 2     Past Guests                     Karma Jimbaran               Viewpoint
# 3     Past Guests           Karma Royal Haathi Mahal               Viewpoint
# 4     Past Guests             Karma Lake of Menteith               Viewpoint
# ...           ...                                ...                     ...
# 1336  Past Guests            Karma Sitabani, Corbett               Viewpoint
# 1337  Past Guests  Wyndham -  Manoir des Deux Amants               Viewpoint
# 1338  Past Guests  Wyndham -  Manoir des Deux Amants               Viewpoint
# 1339  Past Guests  Wyndham -  Manoir des Deux Amants               Viewpoint
# 1340  Past Guests  Wyndham -  Manoir des Deux Amants               Viewpoint
#
#      Exclude From Mailing
# 0                      NO
# 1                      NO
# 2                      NO
# 3                      NO
# 4                     YES
# ...                   ...
# 1336                   NO
# 1337                   NO
# 1338                   NO
# 1339                   NO
# 1340                   NO
#
# [1341 rows x 37 columns]

# %%
# Cek leads test
test_leads = df_viewpoint.loc[
    
        df_viewpoint['Email'].str.contains('^test@', flags=re.I, regex=True) |
        df_viewpoint['Email'].str.contains('\+test', flags=re.I, regex=True) |
    
        df_viewpoint['Firstname'].str.contains('^test$', flags=re.I, regex=True) |
        df_viewpoint['lastname'].str.contains('^test$', flags=re.I, regex=True) |

        df_viewpoint['Firstname'].str.contains('test 1', flags=re.I, regex=True) |
        df_viewpoint['lastname'].str.contains('test 2', flags=re.I, regex=True)|
        df_viewpoint['Firstname'].str.contains('test1', flags=re.I, regex=True) |
        df_viewpoint['lastname'].str.contains('test2', flags=re.I, regex=True)|

        df_viewpoint['Firstname'].str.contains(' test ', flags=re.I, regex=True) | 
        df_viewpoint['lastname'].str.contains(' test ', flags=re.I, regex=True) | 
        df_viewpoint['lastname'].str.contains(' test$', flags=re.I, regex=True)
    ]

count_leads_test = test_leads.shape[0]

test_leads.to_csv(r'C:\Users\fajar\Documents\Python\Data\test_leads_viewpoint.csv', index=False)
test_leads
# Out:
# Empty DataFrame
# Columns: [Title, Firstname, lastname, DOB, PAN CARD, Email, Phone, Mobile, AddressLine1, AddressLine2, Town, State, Country, PostCode, Nationality, MaritalStatus, resortname, Arrival, Departure, CheckInDate, CheckOutDate, room, UnitCategory, BookingNo, BookingSourceDesc, BookingTypeDesc, Date of Tour, Sales Rep and Comments, Opt In, Contact Type, Odyssey Members, Lead Brand, Lead Sub-Brand, Lead Source, Lead Locations, Lead Source Description, Exclude From Mailing]
# Index: []
#
# [0 rows x 37 columns]

# %%
df_viewpoint.drop(test_leads.index, inplace=True)
df_viewpoint.reset_index(drop=True, inplace=True)

count_after_dedup_test = df_viewpoint.shape[0]
count_after_dedup_test
# Out:
# 1341

# %%
count_final_data = count_after_dedup_test

# %%
# df_viewpoint.loc[df_viewpoint['BookingNo'] == '2070341']

# %%
df_viewpoint.replace('empty', '', inplace=True)

# %%
print("==========================================================")
print("Summary")
print("==========================================================")
print("Jumlah Data Awal Viewpoint : "+str(count_data_awal))
print("Jumlah Data Email dan Phone Kosong : "+str(count_contact_type_empty))
print("Jumlah Data Setelah Hapus Email dan Phone Yang Kosong : "+str(count_after_contact_type_empty))
print("Jumlah Data Email Yang Termasuk List Karma : "+str(count_email_karma))
print("Jumlah Data Email Setelah List Karma Dihapus : "+str(count_after_clean_karma))
print("Jumlah Data Test : "+str(count_leads_test))
print("Jumlah Data Email Setelah Data Test Dihapus : "+str(count_after_dedup_test))
print("Jumlah Data Akhir : "+str(count_final_data))
# Out:
# ==========================================================
# Summary
# ==========================================================
# Jumlah Data Awal Viewpoint : 1493
# Jumlah Data Email dan Phone Kosong : 140
# Jumlah Data Setelah Hapus Email dan Phone Yang Kosong : 1353
# Jumlah Data Email Yang Termasuk List Karma : 12
# Jumlah Data Email Setelah List Karma Dihapus : 1341
# Jumlah Data Test : 0
# Jumlah Data Email Setelah Data Test Dihapus : 1341
# Jumlah Data Akhir : 1341

# %%
df_viewpoint.to_excel(r'C:\Users\fajar\Documents\Python\Data\check_country_code_viewpoint.xlsx', index=False)
