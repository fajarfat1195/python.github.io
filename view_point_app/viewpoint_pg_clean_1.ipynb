# %%
import pandas as pd
import re

import past_guest_module as pm

import sys
sys.path.append('../zoho_data_app/')

import main_module as m

# %load_ext autoreload
# %autoreload 2

# %%
path = r'C:\Users\fajar\Documents\Python\Data\Past Guest Data\View Point\2024\Aug\28 July - 5 Aug\CheckOutReport 28 Jul - 5 Aug.xlsx'
df_viewpoint = pd.read_excel(path, dtype='string', sheet_name='Sheet1')
count_data_awal = df_viewpoint.shape[0]
df_viewpoint
# Out:
#      Title     Firstname   lastname                  DOB PAN CARD  \
# 0       Mr      YONGCHAO       TANG  2001-06-06 00:00:00     <NA>
# 1       Mr        LINLIN       ZHOU                 <NA>     <NA>
# 2       Mr           Ran     Feifei  1993-01-01 00:00:00     <NA>
# 3       Mr         Aaron  Mahadevan                 <NA>     <NA>
# 4       Mr        Satish     Sharma                 <NA>     <NA>
# ...    ...           ...        ...                  ...      ...
# 1682  <NA>        Zeineb  Ben kahla                 <NA>     <NA>
# 1683  <NA>          Badr   El attar                 <NA>     <NA>
# 1684  <NA>      Marjorie   Hardouin                 <NA>     <NA>
# 1685     -          JOHN    LUCENTE                 <NA>     <NA>
# 1686   krg  Fajar Fatoni         86                 <NA>     <NA>
#
#                              Email          Phone Mobile  \
# 0                1789663701@qq.com  8618235441999   <NA>
# 1                   3166190@gg.com  8613632766525   <NA>
# 2                  62583086@99.com   628113088069   <NA>
# 3                aaronnm@gmail.com           <NA>   <NA>
# 4     aasthasharma19june@gmail.com  91 9811335532   <NA>
# ...                            ...            ...    ...
# 1682                          <NA>           <NA>   <NA>
# 1683                          <NA>           <NA>   <NA>
# 1684                          <NA>           <NA>   <NA>
# 1685                          <NA>           <NA>   <NA>
# 1686                          <NA>           <NA>   <NA>
#
#                         AddressLine1   AddressLine2  ...          CheckInDate  \
# 0                             Shanxi           <NA>  ...  2024-08-03 13:10:28
# 1                                  -              -  ...  2024-07-30 14:33:01
# 2                              China           <NA>  ...  2024-08-01 16:36:50
# 3      4 PARSONS AVENUE, STRATHFIELD           <NA>  ...  2024-07-31 21:00:32
# 4     C-15, TYPE II NEW POLOCE LINE,  KINGSWAY CAMP  ...  2024-07-27 14:37:14
# ...                              ...            ...  ...                  ...
# 1682                               .              .  ...  2024-08-02 03:40:50
# 1683                               .              .  ...  2024-08-03 23:04:53
# 1684                               -           <NA>  ...  2024-08-03 21:21:24
# 1685                               .           <NA>  ...  2024-08-01 19:42:14
# 1686                            <NA>           <NA>  ...                 <NA>
#
#              CheckOutDate    room                    UnitCategory BookingNo  \
# 0     2024-08-04 15:32:45      11  3 Bedroom Garden View Pool Vil   2579805
# 1     2024-08-02 15:54:14  33 - N  3 Bedroom Garden View Pool Vil   2563886
# 2     2024-08-02 15:54:19      11  3 Bedroom Garden View Pool Vil   2580717
# 3     2024-08-02 19:50:39      06               Hotel Unit Deluxe   2554274
# 4     2024-07-30 15:47:29     305                      Hotel Unit   2536144
# ...                   ...     ...                             ...       ...
# 1682  2024-08-04 16:12:49     114             1 Bedroom Apartment   2581852
# 1683  2024-08-04 16:50:26     217             1 Bedroom Apartment   2584180
# 1684  2024-08-04 17:11:06     102             2 Bedroom Apartment   2583646
# 1685  2024-08-04 18:07:36     122             2 Bedroom Apartment   2542337
# 1686                 <NA>    <NA>                            <NA>      <NA>
#
#      BookingSourceDesc     BookingTypeDesc Date of Tour  \
# 0       Hotel Bookings     Nakula - Rental         <NA>
# 1       Hotel Bookings     Nakula - Rental         <NA>
# 2       Hotel Bookings     Nakula - Rental         <NA>
# 3            KC Member         Entitlement         <NA>
# 4            KC Member  Entitlement Member         <NA>
# ...                ...                 ...          ...
# 1682    Hotel Bookings         Booking.com         <NA>
# 1683    Hotel Bookings         Booking.com         <NA>
# 1684    Hotel Bookings         Booking.com         <NA>
# 1685    Hotel Bookings      Wyndham Guests         <NA>
# 1686              <NA>                <NA>         <NA>
#
#      Sales Rep and Comments Opt In
# 0                      <NA>    YES
# 1                      <NA>    YES
# 2                      <NA>    YES
# 3                      <NA>    YES
# 4                      <NA>    YES
# ...                     ...    ...
# 1682                   <NA>    YES
# 1683                   <NA>    YES
# 1684                   <NA>    YES
# 1685                   <NA>    YES
# 1686                   <NA>   <NA>
#
# [1687 rows x 29 columns]

# %%
df_viewpoint.columns
# Out:
# Index(['Title', 'Firstname', 'lastname', 'DOB', 'PAN CARD', 'Email', 'Phone',
#        'Mobile', 'AddressLine1', 'AddressLine2', 'Town', 'State', 'Country',
#        'PostCode', 'Nationality', 'MaritalStatus', 'resortname', 'Arrival',
#        'Departure', 'CheckInDate', 'CheckOutDate', 'room', 'UnitCategory',
#        'BookingNo', 'BookingSourceDesc', 'BookingTypeDesc', 'Date of Tour',
#        'Sales Rep and Comments', 'Opt In'],
#       dtype='object')

# %%
df_viewpoint.fillna('empty', inplace=True)

df_viewpoint['Contact Type'] = 'empty'
df_viewpoint['Odyssey Members'] = 'NO'

df_viewpoint['Lead Brand'] = 'Karma Resorts'
df_viewpoint['Lead Sub-Brand'] = 'Other'
df_viewpoint['Lead Source'] = 'Past Guests'
df_viewpoint['Lead Locations'] = df_viewpoint['resortname']
df_viewpoint['Lead Source Description'] = 'Viewpoint'

# %%
df_viewpoint.loc[df_viewpoint['Opt In'] == 'YES', 'Exclude From Mailing'] = 'NO'
df_viewpoint.loc[df_viewpoint['Opt In'] == 'NO', 'Exclude From Mailing'] = 'YES'

# %%
df_viewpoint.loc[df_viewpoint['lastname'] == 'empty', 'lastname'] = '-'

# %%
df_viewpoint['Title'].replace('empty', '', inplace=True)
df_viewpoint['Firstname'].replace('empty', '', inplace=True)
df_viewpoint['lastname'].replace('empty', '', inplace=True)

df_viewpoint['Title'] = df_viewpoint['Title'].str.title()
df_viewpoint['Firstname'] = df_viewpoint['Firstname'].str.title()
df_viewpoint['lastname'] = df_viewpoint['lastname'].str.title()

df_viewpoint
# Out:
#      Title     Firstname   lastname                  DOB PAN CARD  \
# 0       Mr      Yongchao       Tang  2001-06-06 00:00:00    empty
# 1       Mr        Linlin       Zhou                empty    empty
# 2       Mr           Ran     Feifei  1993-01-01 00:00:00    empty
# 3       Mr         Aaron  Mahadevan                empty    empty
# 4       Mr        Satish     Sharma                empty    empty
# ...    ...           ...        ...                  ...      ...
# 1682              Zeineb  Ben Kahla                empty    empty
# 1683                Badr   El Attar                empty    empty
# 1684            Marjorie   Hardouin                empty    empty
# 1685     -          John    Lucente                empty    empty
# 1686   Krg  Fajar Fatoni         86                empty    empty
#
#                              Email          Phone Mobile  \
# 0                1789663701@qq.com  8618235441999  empty
# 1                   3166190@gg.com  8613632766525  empty
# 2                  62583086@99.com   628113088069  empty
# 3                aaronnm@gmail.com          empty  empty
# 4     aasthasharma19june@gmail.com  91 9811335532  empty
# ...                            ...            ...    ...
# 1682                         empty          empty  empty
# 1683                         empty          empty  empty
# 1684                         empty          empty  empty
# 1685                         empty          empty  empty
# 1686                         empty          empty  empty
#
#                         AddressLine1   AddressLine2  ...  \
# 0                             Shanxi          empty  ...
# 1                                  -              -  ...
# 2                              China          empty  ...
# 3      4 PARSONS AVENUE, STRATHFIELD          empty  ...
# 4     C-15, TYPE II NEW POLOCE LINE,  KINGSWAY CAMP  ...
# ...                              ...            ...  ...
# 1682                               .              .  ...
# 1683                               .              .  ...
# 1684                               -          empty  ...
# 1685                               .          empty  ...
# 1686                           empty          empty  ...
#
#      Sales Rep and Comments Opt In Contact Type Odyssey Members  \
# 0                     empty    YES        empty              NO
# 1                     empty    YES        empty              NO
# 2                     empty    YES        empty              NO
# 3                     empty    YES        empty              NO
# 4                     empty    YES        empty              NO
# ...                     ...    ...          ...             ...
# 1682                  empty    YES        empty              NO
# 1683                  empty    YES        empty              NO
# 1684                  empty    YES        empty              NO
# 1685                  empty    YES        empty              NO
# 1686                  empty  empty        empty              NO
#
#          Lead Brand Lead Sub-Brand  Lead Source  \
# 0     Karma Resorts          Other  Past Guests
# 1     Karma Resorts          Other  Past Guests
# 2     Karma Resorts          Other  Past Guests
# 3     Karma Resorts          Other  Past Guests
# 4     Karma Resorts          Other  Past Guests
# ...             ...            ...          ...
# 1682  Karma Resorts          Other  Past Guests
# 1683  Karma Resorts          Other  Past Guests
# 1684  Karma Resorts          Other  Past Guests
# 1685  Karma Resorts          Other  Past Guests
# 1686  Karma Resorts          Other  Past Guests
#
#                          Lead Locations Lead Source Description  \
# 0                        Karma Jimbaran               Viewpoint
# 1                        Karma Jimbaran               Viewpoint
# 2                        Karma Jimbaran               Viewpoint
# 3        Chateau de Samary, Carcassonne               Viewpoint
# 4               Karma Sitabani, Corbett               Viewpoint
# ...                                 ...                     ...
# 1682  Wyndham -  Manoir des Deux Amants               Viewpoint
# 1683  Wyndham -  Manoir des Deux Amants               Viewpoint
# 1684  Wyndham -  Manoir des Deux Amants               Viewpoint
# 1685  Wyndham -  Manoir des Deux Amants               Viewpoint
# 1686                              empty               Viewpoint
#
#      Exclude From Mailing
# 0                      NO
# 1                      NO
# 2                      NO
# 3                      NO
# 4                      NO
# ...                   ...
# 1682                   NO
# 1683                   NO
# 1684                   NO
# 1685                   NO
# 1686                  NaN
#
# [1687 rows x 37 columns]

# %%
m.clean_number(df_viewpoint, 'Phone')
m.clean_number(df_viewpoint, 'Mobile')
m.replace_not_valid_to_empty(df_viewpoint, 'Phone')
m.replace_not_valid_to_empty(df_viewpoint, 'Mobile')

df_viewpoint.loc[df_viewpoint['Phone'].str.contains('00000'), 'Phone'] = 'empty'
df_viewpoint.loc[df_viewpoint['Mobile'].str.contains('00000'), 'Mobile'] = 'empty'

m.clean_space(df_viewpoint, 'Email')
df_viewpoint['Email'] = m.lowercase(df_viewpoint, 'Email')

# %%
pm.email_correction(df_viewpoint, 'Email')

# %%
df_viewpoint.loc[(df_viewpoint['Email'] != 'empty') & ((df_viewpoint['Phone'] != 'empty') | (df_viewpoint['Mobile'] != 'empty')), 'Contact Type'] = 'Email and Phone'
df_viewpoint.loc[(df_viewpoint['Email'] != 'empty') & ((df_viewpoint['Phone'] == 'empty') & (df_viewpoint['Mobile'] == 'empty')), 'Contact Type'] = 'Email Only'
df_viewpoint.loc[(df_viewpoint['Email'] == 'empty') & ((df_viewpoint['Phone'] != 'empty') | (df_viewpoint['Mobile'] != 'empty')), 'Contact Type'] = 'Phone Only'

df_viewpoint.loc[df_viewpoint['Contact Type'] == 'empty'].to_csv(r'C:\Users\fajar\Documents\Python\Data\contact_type_empty_viewpoint.csv', index=False)

count_contact_type_empty = df_viewpoint.loc[df_viewpoint['Contact Type'] == 'empty'].shape[0]

df_viewpoint.drop(df_viewpoint.loc[df_viewpoint['Contact Type'] == 'empty'].index, inplace=True)
df_viewpoint.reset_index(drop=True, inplace=True)

count_after_contact_type_empty = df_viewpoint.shape[0]

df_viewpoint
# Out:
#      Title  Firstname     lastname                  DOB PAN CARD  \
# 0       Mr   Yongchao         Tang  2001-06-06 00:00:00    empty
# 1       Mr     Linlin         Zhou                empty    empty
# 2       Mr        Ran       Feifei  1993-01-01 00:00:00    empty
# 3       Mr      Aaron    Mahadevan                empty    empty
# 4       Mr     Satish       Sharma                empty    empty
# ...    ...        ...          ...                  ...      ...
# 1539    Mr       Otto  Aalbersberg                empty    empty
# 1540     -   Maurizio     Pagliani                empty    empty
# 1541     -      Merel      Volgers                empty    empty
# 1542     -        Amé     De Zwart                empty    empty
# 1543     -      Helen         Bora                empty    empty
#
#                              Email          Phone Mobile  \
# 0                1789663701@qq.com  8618235441999  empty
# 1                   3166190@gg.com  8613632766525  empty
# 2                  62583086@99.com   628113088069  empty
# 3                aaronnm@gmail.com          empty  empty
# 4     aasthasharma19june@gmail.com   919811335532  empty
# ...                            ...            ...    ...
# 1539                         empty    31683447216  empty
# 1540                         empty  3903245973810  empty
# 1541                         empty    31639012964  empty
# 1542                         empty    31610919181  empty
# 1543                         empty    33678999245  empty
#
#                         AddressLine1   AddressLine2  ...  \
# 0                             Shanxi          empty  ...
# 1                                  -              -  ...
# 2                              China          empty  ...
# 3      4 PARSONS AVENUE, STRATHFIELD          empty  ...
# 4     C-15, TYPE II NEW POLOCE LINE,  KINGSWAY CAMP  ...
# ...                              ...            ...  ...
# 1539                               .              .  ...
# 1540                           empty          empty  ...
# 1541                           empty          empty  ...
# 1542                           empty          empty  ...
# 1543                               .              .  ...
#
#      Sales Rep and Comments Opt In     Contact Type Odyssey Members  \
# 0                     empty    YES  Email and Phone              NO
# 1                     empty    YES  Email and Phone              NO
# 2                     empty    YES  Email and Phone              NO
# 3                     empty    YES       Email Only              NO
# 4                     empty    YES  Email and Phone              NO
# ...                     ...    ...              ...             ...
# 1539                  empty    YES       Phone Only              NO
# 1540                  empty    YES       Phone Only              NO
# 1541                  empty    YES       Phone Only              NO
# 1542                  empty    YES       Phone Only              NO
# 1543                  empty    YES       Phone Only              NO
#
#          Lead Brand Lead Sub-Brand  Lead Source  \
# 0     Karma Resorts          Other  Past Guests
# 1     Karma Resorts          Other  Past Guests
# 2     Karma Resorts          Other  Past Guests
# 3     Karma Resorts          Other  Past Guests
# 4     Karma Resorts          Other  Past Guests
# ...             ...            ...          ...
# 1539  Karma Resorts          Other  Past Guests
# 1540  Karma Resorts          Other  Past Guests
# 1541  Karma Resorts          Other  Past Guests
# 1542  Karma Resorts          Other  Past Guests
# 1543  Karma Resorts          Other  Past Guests
#
#                          Lead Locations Lead Source Description  \
# 0                        Karma Jimbaran               Viewpoint
# 1                        Karma Jimbaran               Viewpoint
# 2                        Karma Jimbaran               Viewpoint
# 3        Chateau de Samary, Carcassonne               Viewpoint
# 4               Karma Sitabani, Corbett               Viewpoint
# ...                                 ...                     ...
# 1539  Wyndham -  Manoir des Deux Amants               Viewpoint
# 1540  Wyndham -  Manoir des Deux Amants               Viewpoint
# 1541  Wyndham -  Manoir des Deux Amants               Viewpoint
# 1542  Wyndham -  Manoir des Deux Amants               Viewpoint
# 1543  Wyndham -  Manoir des Deux Amants               Viewpoint
#
#      Exclude From Mailing
# 0                      NO
# 1                      NO
# 2                      NO
# 3                      NO
# 4                      NO
# ...                   ...
# 1539                   NO
# 1540                   NO
# 1541                   NO
# 1542                   NO
# 1543                   NO
#
# [1544 rows x 37 columns]

# %%
# Cek Email Karma
email_karma = m.find_karma(df_viewpoint, 'Email')
count_email_karma = email_karma.shape[0]
email_karma.to_csv(r'C:\Users\fajar\Documents\Python\Data\email_deleted_viewpoint.csv', index=False)

email_karma
# Out:
#      Title           Firstname              lastname    DOB PAN CARD  \
# 236           Maintenance Room          Karma Chakra  empty    empty
# 237           Maintenance Room          Karma Chakra  empty    empty
# 238           Maintenance Room          Karma Chakra  empty    empty
# 239           Maintenance Room          Karma Chakra  empty    empty
# 292     Mr               David                Hadson  empty    empty
# 293     Mr               David                Hadson  empty    empty
# 409     Ms           Esperanca              Patricio  empty    empty
# 410     Ms           Esperanca              Patricio  empty    empty
# 589     Ms             Jessica             Fernandes  empty    empty
# 590     Ms             Jessica             Fernandes  empty    empty
# 614     Mr              Joseph            Antonishek  empty    empty
# 788     Mr             Michael                  Wood  empty    empty
# 789     Mr             Michael                  Wood  empty    empty
# 826      -  Maintenance Room -  Karma Royal Monterio  empty    empty
# 827     Mr              Milesh                 Chari  empty    empty
# 997     Mr              Pramod        Balasubramanya  empty    empty
# 1268    Mr                Shiv                 Suman  empty    empty
# 1269    Mr                Shiv                 Suman  empty    empty
# 1270    Mr                Shiv                 Suman  empty    empty
# 1360    Mr      Sukhjender Pal                 Singh  empty    empty
#
#                                      Email          Phone        Mobile  \
# 236                  chakra@karmagroup.com   914812526252  919446080121
# 237                  chakra@karmagroup.com   914812526252  919446080121
# 238                  chakra@karmagroup.com   914812526252  919446080121
# 239                  chakra@karmagroup.com   914812526252  919446080121
# 292            david.hadson@karmagroup.com   626236341519         empty
# 293            david.hadson@karmagroup.com   626236341519         empty
# 409      esperanca.patricio@karmagroup.com   919921378384         empty
# 410      esperanca.patricio@karmagroup.com   919921378384         empty
# 589       jessica.fernandes@karmagroup.com   917774006996         empty
# 590       jessica.fernandes@karmagroup.com   917774006996         empty
# 614       joseph.antonishek@karmagroup.com  6282235541045         empty
# 788            michael.wood@karmagroup.com   628113971444         empty
# 789            michael.wood@karmagroup.com   628113971444         empty
# 826              mr.asstfom@karmagroup.com   918326716200         empty
# 827                   mr.hk@karmagroup.com   918326716200  919175089732
# 997   pramod.balasubramanya@karmagroup.com   919538510610  919538510610
# 1268            shivsuman.b@karmagroup.com   919325868122         empty
# 1269            shivsuman.b@karmagroup.com   919325868122         empty
# 1270            shivsuman.b@karmagroup.com   919325868122         empty
# 1360       sukhjender.singh@karmagroup.com   917807770241         empty
#
#                                   AddressLine1        AddressLine2  ...  \
# 236   Ward # 09, Block#12, Near Nasrath Church            KOTTAYAM  ...
# 237   Ward # 09, Block#12, Near Nasrath Church            KOTTAYAM  ...
# 238   Ward # 09, Block#12, Near Nasrath Church            KOTTAYAM  ...
# 239   Ward # 09, Block#12, Near Nasrath Church            KOTTAYAM  ...
# 292                               C/- IVO BALI               empty  ...
# 293                               C/- IVO BALI               empty  ...
# 409                         CAVELOSSIM, MOBOR,                   .  ...
# 410                         CAVELOSSIM, MOBOR,                   .  ...
# 589                               Haathi Mahal               empty  ...
# 590                               Haathi Mahal               empty  ...
# 614                      C/- CHEF OF K KANDARA               empty  ...
# 788     Jl. By Pass Ngurah Rai No.61, Pemogan,  Kec. Denpasar Sel.  ...
# 789     Jl. By Pass Ngurah Rai No.61, Pemogan,  Kec. Denpasar Sel.  ...
# 826                       karma royal monetrio              Arpora  ...
# 827                       Karma Royal Monterio    Arpora Baga Road  ...
# 997                                          -                   -  ...
# 1268                                         -                   -  ...
# 1269                                         -                   -  ...
# 1270                                         -                   -  ...
# 1360             Village Tohu, Indru Nag Road,               empty  ...
#
#      Sales Rep and Comments Opt In     Contact Type Odyssey Members  \
# 236                   empty    YES  Email and Phone              NO
# 237                   empty    YES  Email and Phone              NO
# 238                   empty    YES  Email and Phone              NO
# 239                   empty    YES  Email and Phone              NO
# 292                   empty    YES  Email and Phone              NO
# 293                   empty    YES  Email and Phone              NO
# 409                   empty    YES  Email and Phone              NO
# 410                   empty    YES  Email and Phone              NO
# 589                   empty    YES  Email and Phone              NO
# 590                   empty    YES  Email and Phone              NO
# 614                   empty    YES  Email and Phone              NO
# 788                   empty    YES  Email and Phone              NO
# 789                   empty    YES  Email and Phone              NO
# 826                   empty    YES  Email and Phone              NO
# 827                   empty    YES  Email and Phone              NO
# 997                   empty    YES  Email and Phone              NO
# 1268                  empty    YES  Email and Phone              NO
# 1269                  empty    YES  Email and Phone              NO
# 1270                  empty    YES  Email and Phone              NO
# 1360                  empty    YES  Email and Phone              NO
#
#          Lead Brand Lead Sub-Brand  Lead Source  \
# 236   Karma Resorts          Other  Past Guests
# 237   Karma Resorts          Other  Past Guests
# 238   Karma Resorts          Other  Past Guests
# 239   Karma Resorts          Other  Past Guests
# 292   Karma Resorts          Other  Past Guests
# 293   Karma Resorts          Other  Past Guests
# 409   Karma Resorts          Other  Past Guests
# 410   Karma Resorts          Other  Past Guests
# 589   Karma Resorts          Other  Past Guests
# 590   Karma Resorts          Other  Past Guests
# 614   Karma Resorts          Other  Past Guests
# 788   Karma Resorts          Other  Past Guests
# 789   Karma Resorts          Other  Past Guests
# 826   Karma Resorts          Other  Past Guests
# 827   Karma Resorts          Other  Past Guests
# 997   Karma Resorts          Other  Past Guests
# 1268  Karma Resorts          Other  Past Guests
# 1269  Karma Resorts          Other  Past Guests
# 1270  Karma Resorts          Other  Past Guests
# 1360  Karma Resorts          Other  Past Guests
#
#                                Lead Locations Lead Source Description  \
# 236                      Karma Chakra, Kerala               Viewpoint
# 237                      Karma Chakra, Kerala               Viewpoint
# 238                      Karma Chakra, Kerala               Viewpoint
# 239                      Karma Chakra, Kerala               Viewpoint
# 292                      Karma Haveli, Jaipur               Viewpoint
# 293                  Karma Royal Haathi Mahal               Viewpoint
# 409                  Karma Royal Haathi Mahal               Viewpoint
# 410                  Karma Royal Haathi Mahal               Viewpoint
# 589                      Karma Royal Jimbaran               Viewpoint
# 590   KRR @ Karma Kandara, Mentari Residences               Viewpoint
# 614                              Karma Minoan               Viewpoint
# 788                         Karma St. Martins               Viewpoint
# 789                         Karma St. Martins               Viewpoint
# 826                      Karma Royal Monterio               Viewpoint
# 827                      Karma Royal Monterio               Viewpoint
# 997                      Karma Royal Monterio               Viewpoint
# 1268                     Karma Royal Monterio               Viewpoint
# 1269                     Karma Royal Monterio               Viewpoint
# 1270                     Karma Royal Monterio               Viewpoint
# 1360                     Karma Martam Retreat               Viewpoint
#
#      Exclude From Mailing
# 236                    NO
# 237                    NO
# 238                    NO
# 239                    NO
# 292                    NO
# 293                    NO
# 409                    NO
# 410                    NO
# 589                    NO
# 590                    NO
# 614                    NO
# 788                    NO
# 789                    NO
# 826                    NO
# 827                    NO
# 997                    NO
# 1268                   NO
# 1269                   NO
# 1270                   NO
# 1360                   NO
#
# [20 rows x 37 columns]

# %%
# delete email Karma
count_after_clean_karma = m.delete_karma(df_viewpoint, 'Email')

df_viewpoint
# Out:
#      Title  Firstname     lastname                  DOB PAN CARD  \
# 0       Mr   Yongchao         Tang  2001-06-06 00:00:00    empty
# 1       Mr     Linlin         Zhou                empty    empty
# 2       Mr        Ran       Feifei  1993-01-01 00:00:00    empty
# 3       Mr      Aaron    Mahadevan                empty    empty
# 4       Mr     Satish       Sharma                empty    empty
# ...    ...        ...          ...                  ...      ...
# 1519    Mr       Otto  Aalbersberg                empty    empty
# 1520     -   Maurizio     Pagliani                empty    empty
# 1521     -      Merel      Volgers                empty    empty
# 1522     -        Amé     De Zwart                empty    empty
# 1523     -      Helen         Bora                empty    empty
#
#                              Email          Phone Mobile  \
# 0                1789663701@qq.com  8618235441999  empty
# 1                   3166190@gg.com  8613632766525  empty
# 2                  62583086@99.com   628113088069  empty
# 3                aaronnm@gmail.com          empty  empty
# 4     aasthasharma19june@gmail.com   919811335532  empty
# ...                            ...            ...    ...
# 1519                         empty    31683447216  empty
# 1520                         empty  3903245973810  empty
# 1521                         empty    31639012964  empty
# 1522                         empty    31610919181  empty
# 1523                         empty    33678999245  empty
#
#                         AddressLine1   AddressLine2  ...  \
# 0                             Shanxi          empty  ...
# 1                                  -              -  ...
# 2                              China          empty  ...
# 3      4 PARSONS AVENUE, STRATHFIELD          empty  ...
# 4     C-15, TYPE II NEW POLOCE LINE,  KINGSWAY CAMP  ...
# ...                              ...            ...  ...
# 1519                               .              .  ...
# 1520                           empty          empty  ...
# 1521                           empty          empty  ...
# 1522                           empty          empty  ...
# 1523                               .              .  ...
#
#      Sales Rep and Comments Opt In     Contact Type Odyssey Members  \
# 0                     empty    YES  Email and Phone              NO
# 1                     empty    YES  Email and Phone              NO
# 2                     empty    YES  Email and Phone              NO
# 3                     empty    YES       Email Only              NO
# 4                     empty    YES  Email and Phone              NO
# ...                     ...    ...              ...             ...
# 1519                  empty    YES       Phone Only              NO
# 1520                  empty    YES       Phone Only              NO
# 1521                  empty    YES       Phone Only              NO
# 1522                  empty    YES       Phone Only              NO
# 1523                  empty    YES       Phone Only              NO
#
#          Lead Brand Lead Sub-Brand  Lead Source  \
# 0     Karma Resorts          Other  Past Guests
# 1     Karma Resorts          Other  Past Guests
# 2     Karma Resorts          Other  Past Guests
# 3     Karma Resorts          Other  Past Guests
# 4     Karma Resorts          Other  Past Guests
# ...             ...            ...          ...
# 1519  Karma Resorts          Other  Past Guests
# 1520  Karma Resorts          Other  Past Guests
# 1521  Karma Resorts          Other  Past Guests
# 1522  Karma Resorts          Other  Past Guests
# 1523  Karma Resorts          Other  Past Guests
#
#                          Lead Locations Lead Source Description  \
# 0                        Karma Jimbaran               Viewpoint
# 1                        Karma Jimbaran               Viewpoint
# 2                        Karma Jimbaran               Viewpoint
# 3        Chateau de Samary, Carcassonne               Viewpoint
# 4               Karma Sitabani, Corbett               Viewpoint
# ...                                 ...                     ...
# 1519  Wyndham -  Manoir des Deux Amants               Viewpoint
# 1520  Wyndham -  Manoir des Deux Amants               Viewpoint
# 1521  Wyndham -  Manoir des Deux Amants               Viewpoint
# 1522  Wyndham -  Manoir des Deux Amants               Viewpoint
# 1523  Wyndham -  Manoir des Deux Amants               Viewpoint
#
#      Exclude From Mailing
# 0                      NO
# 1                      NO
# 2                      NO
# 3                      NO
# 4                      NO
# ...                   ...
# 1519                   NO
# 1520                   NO
# 1521                   NO
# 1522                   NO
# 1523                   NO
#
# [1524 rows x 37 columns]

# %%
# Cek leads test
test_leads = df_viewpoint.loc[
    
        df_viewpoint['Email'].str.contains('^test@', flags=re.I, regex=True) |
        df_viewpoint['Email'].str.contains('\+test', flags=re.I, regex=True) |
    
        df_viewpoint['Firstname'].str.contains('^test$', flags=re.I, regex=True) |
        df_viewpoint['lastname'].str.contains('^test$', flags=re.I, regex=True) |

        df_viewpoint['Firstname'].str.contains('test 1', flags=re.I, regex=True) |
        df_viewpoint['lastname'].str.contains('test 2', flags=re.I, regex=True)|
        df_viewpoint['Firstname'].str.contains('test1', flags=re.I, regex=True) |
        df_viewpoint['lastname'].str.contains('test2', flags=re.I, regex=True)|

        df_viewpoint['Firstname'].str.contains(' test ', flags=re.I, regex=True) | 
        df_viewpoint['lastname'].str.contains(' test ', flags=re.I, regex=True) | 
        df_viewpoint['lastname'].str.contains(' test$', flags=re.I, regex=True)
    ]

count_leads_test = test_leads.shape[0]

test_leads.to_csv(r'C:\Users\fajar\Documents\Python\Data\test_leads_viewpoint.csv', index=False)
test_leads
# Out:
# Empty DataFrame
# Columns: [Title, Firstname, lastname, DOB, PAN CARD, Email, Phone, Mobile, AddressLine1, AddressLine2, Town, State, Country, PostCode, Nationality, MaritalStatus, resortname, Arrival, Departure, CheckInDate, CheckOutDate, room, UnitCategory, BookingNo, BookingSourceDesc, BookingTypeDesc, Date of Tour, Sales Rep and Comments, Opt In, Contact Type, Odyssey Members, Lead Brand, Lead Sub-Brand, Lead Source, Lead Locations, Lead Source Description, Exclude From Mailing]
# Index: []
#
# [0 rows x 37 columns]

# %%
df_viewpoint.drop(test_leads.index, inplace=True)
df_viewpoint.reset_index(drop=True, inplace=True)

count_after_dedup_test = df_viewpoint.shape[0]
count_after_dedup_test
# Out:
# 1524

# %%
count_final_data = count_after_dedup_test

# %%
# df_viewpoint.loc[df_viewpoint['BookingNo'] == '2070341']

# %%
df_viewpoint.replace('empty', '', inplace=True)

# %%
print("==========================================================")
print("Summary")
print("==========================================================")
print("Jumlah Data Awal Viewpoint : "+str(count_data_awal))
print("Jumlah Data Email dan Phone Kosong : "+str(count_contact_type_empty))
print("Jumlah Data Setelah Hapus Email dan Phone Yang Kosong : "+str(count_after_contact_type_empty))
print("Jumlah Data Email Yang Termasuk List Karma : "+str(count_email_karma))
print("Jumlah Data Email Setelah List Karma Dihapus : "+str(count_after_clean_karma))
print("Jumlah Data Test : "+str(count_leads_test))
print("Jumlah Data Email Setelah Data Test Dihapus : "+str(count_after_dedup_test))
print("Jumlah Data Akhir : "+str(count_final_data))
# Out:
# ==========================================================
# Summary
# ==========================================================
# Jumlah Data Awal Viewpoint : 1687
# Jumlah Data Email dan Phone Kosong : 143
# Jumlah Data Setelah Hapus Email dan Phone Yang Kosong : 1544
# Jumlah Data Email Yang Termasuk List Karma : 20
# Jumlah Data Email Setelah List Karma Dihapus : 1524
# Jumlah Data Test : 0
# Jumlah Data Email Setelah Data Test Dihapus : 1524
# Jumlah Data Akhir : 1524

# %%
df_viewpoint.to_excel(r'C:\Users\fajar\Documents\Python\Data\check_country_code_viewpoint.xlsx', index=False)
