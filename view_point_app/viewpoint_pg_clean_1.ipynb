# %%
import pandas as pd
import re

import past_guest_module as pm

import sys
sys.path.append('../zoho_data_app/')

import main_module as m

# %load_ext autoreload
# %autoreload 2

# %%
path = r'C:\Users\fajar\Documents\Python\Data\Past Guest Data\View Point\2024\Sep\22 Sep - 30 Sep\CheckOutReport 22 Sep - 30 Sep.xlsx'
df_viewpoint = pd.read_excel(path, dtype='string', sheet_name='Sheet1')
count_data_awal = df_viewpoint.shape[0]
df_viewpoint
# Out:
#      Title     Firstname       lastname                  DOB PAN CARD  \
# 0       Mr         Sunny          Kumar                 <NA>     <NA>
# 1       Mr        Andrew           Chok  1995-09-30 00:00:00     <NA>
# 2       Mr        Andrew           Chok  1995-09-30 00:00:00     <NA>
# 3      Mrs         Jyoti          Gupta  1982-01-21 00:00:00     <NA>
# 4       Mr       NAUSHAD          IQBAL                 <NA>     <NA>
# ...    ...           ...            ...                  ...      ...
# 1803     -         BRUCE         BAILEY                 <NA>     <NA>
# 1804  <NA>        Didier        Logeais                 <NA>     <NA>
# 1805  <NA>       Vanessa          Bogey                 <NA>     <NA>
# 1806   Dr.        SELARL  DOCTEUR PUECH                 <NA>     <NA>
# 1807   krg  Fajar Fatoni             86                 <NA>     <NA>
#
#                          Email         Phone        Mobile  \
# 0                            .             .             .
# 1        _yu19960803@gmail.com          <NA>          <NA>
# 2        _yu19960803@gmail.com  886956330803          <NA>
# 3     7ravindergupta@gmail.com  919717989810          <NA>
# 4            9shad.i@gmail.com  919738776620  919901420272
# ...                        ...           ...           ...
# 1803                      <NA>          <NA>          <NA>
# 1804                      <NA>          <NA>          <NA>
# 1805                      <NA>          <NA>          <NA>
# 1806                      <NA>          <NA>          <NA>
# 1807                      <NA>          <NA>          <NA>
#
#                                            AddressLine1 AddressLine2  ...  \
# 0                                                     .            .  ...
# 1                                             Singapore         <NA>  ...
# 2                                                     -         <NA>  ...
# 3                      17/42, 3RD FLOOR , SUBHASH NAGAR         <NA>  ...
# 4     NO 38 1ST FLOOR 4TH STREET NARAYAN PILAI STREE...            -  ...
# ...                                                 ...          ...  ...
# 1803                                                  .         <NA>  ...
# 1804                                                  -         <NA>  ...
# 1805                                                  -         <NA>  ...
# 1806                                       2 rue de mai         <NA>  ...
# 1807                                               <NA>         <NA>  ...
#
#               CheckInDate         CheckOutDate    room  \
# 0     2024-09-17 20:42:57  2024-09-28 02:05:34   06(8)
# 1     2024-09-20 17:42:33  2024-09-22 13:18:22      10
# 2     2024-09-20 11:33:55  2024-09-22 13:18:27  16 - N
# 3     2024-09-21 18:47:18  2024-09-28 15:26:39    V191
# 4     2024-09-26 14:31:50  2024-09-29 12:45:14   33(1)
# ...                   ...                  ...     ...
# 1803  2024-09-25 19:54:11  2024-09-29 15:38:22     125
# 1804  2024-09-28 23:15:57  2024-09-29 16:04:13     232
# 1805  2024-09-29 00:15:54  2024-09-29 16:34:07     223
# 1806  2024-09-28 23:02:21  2024-09-29 16:58:58     204
# 1807                 <NA>                 <NA>    <NA>
#
#                         UnitCategory BookingNo BookingSourceDesc  \
# 0                1 Bedroom Apartment   2626572             STAFF
# 1     3 Bedroom Garden View Pool Vil   2589483    Hotel Bookings
# 2     4 Bedroom Garden View Pool Vil   2589484    Hotel Bookings
# 3               1 Bedroom Fractional   2592869         KC Member
# 4                2 Bedroom Apartment   2588933    Fly Buy Indian
# ...                              ...       ...               ...
# 1803             2 Bedroom Apartment   2556603    Hotel Bookings
# 1804                Studio Apartment   2637661    Hotel Bookings
# 1805             2 Bedroom Apartment   2637665    Hotel Bookings
# 1806             2 Bedroom Apartment   2637978    Hotel Bookings
# 1807                            <NA>      <NA>              <NA>
#
#               BookingTypeDesc         Date of Tour Sales Rep and Comments  \
# 0                 Staff Karma                 <NA>                   <NA>
# 1             Nakula - Rental                 <NA>                   <NA>
# 2             Nakula - Rental                 <NA>                   <NA>
# 3     Charter Membership Pack                 <NA>                   <NA>
# 4      Karma Experience India  2024-09-28 18:37:00                 IRSHAD
# ...                       ...                  ...                    ...
# 1803           Wyndham Guests                 <NA>                   <NA>
# 1804              Booking.com                 <NA>                   <NA>
# 1805              Booking.com                 <NA>                   <NA>
# 1806              Booking.com                 <NA>                   <NA>
# 1807                     <NA>                 <NA>                   <NA>
#
#      Opt In
# 0       YES
# 1       YES
# 2       YES
# 3       YES
# 4       YES
# ...     ...
# 1803    YES
# 1804    YES
# 1805    YES
# 1806    YES
# 1807   <NA>
#
# [1808 rows x 29 columns]

# %%
df_viewpoint.columns
# Out:
# Index(['Title', 'Firstname', 'lastname', 'DOB', 'PAN CARD', 'Email', 'Phone',
#        'Mobile', 'AddressLine1', 'AddressLine2', 'Town', 'State', 'Country',
#        'PostCode', 'Nationality', 'MaritalStatus', 'resortname', 'Arrival',
#        'Departure', 'CheckInDate', 'CheckOutDate', 'room', 'UnitCategory',
#        'BookingNo', 'BookingSourceDesc', 'BookingTypeDesc', 'Date of Tour',
#        'Sales Rep and Comments', 'Opt In'],
#       dtype='object')

# %%
df_viewpoint.fillna('empty', inplace=True)

df_viewpoint['Contact Type'] = 'empty'
df_viewpoint['Odyssey Members'] = 'NO'

df_viewpoint['Lead Brand'] = 'Karma Resorts'
df_viewpoint['Lead Sub-Brand'] = 'Other'
df_viewpoint['Lead Source'] = 'Past Guests'
df_viewpoint['Lead Locations'] = df_viewpoint['resortname']
df_viewpoint['Lead Source Description'] = 'Viewpoint'

# %%
df_viewpoint.loc[df_viewpoint['Opt In'] == 'YES', 'Exclude From Mailing'] = 'NO'
df_viewpoint.loc[df_viewpoint['Opt In'] == 'NO', 'Exclude From Mailing'] = 'YES'

# %%
df_viewpoint.loc[df_viewpoint['lastname'] == 'empty', 'lastname'] = '-'

# %%
df_viewpoint['Title'].replace('empty', '', inplace=True)
df_viewpoint['Firstname'].replace('empty', '', inplace=True)
df_viewpoint['lastname'].replace('empty', '', inplace=True)

df_viewpoint['Title'] = df_viewpoint['Title'].str.title()
df_viewpoint['Firstname'] = df_viewpoint['Firstname'].str.title()
df_viewpoint['lastname'] = df_viewpoint['lastname'].str.title()

df_viewpoint
# Out:
#      Title     Firstname       lastname                  DOB PAN CARD  \
# 0       Mr         Sunny          Kumar                empty    empty
# 1       Mr        Andrew           Chok  1995-09-30 00:00:00    empty
# 2       Mr        Andrew           Chok  1995-09-30 00:00:00    empty
# 3      Mrs         Jyoti          Gupta  1982-01-21 00:00:00    empty
# 4       Mr       Naushad          Iqbal                empty    empty
# ...    ...           ...            ...                  ...      ...
# 1803     -         Bruce         Bailey                empty    empty
# 1804              Didier        Logeais                empty    empty
# 1805             Vanessa          Bogey                empty    empty
# 1806   Dr.        Selarl  Docteur Puech                empty    empty
# 1807   Krg  Fajar Fatoni             86                empty    empty
#
#                          Email         Phone        Mobile  \
# 0                            .             .             .
# 1        _yu19960803@gmail.com         empty         empty
# 2        _yu19960803@gmail.com  886956330803         empty
# 3     7ravindergupta@gmail.com  919717989810         empty
# 4            9shad.i@gmail.com  919738776620  919901420272
# ...                        ...           ...           ...
# 1803                     empty         empty         empty
# 1804                     empty         empty         empty
# 1805                     empty         empty         empty
# 1806                     empty         empty         empty
# 1807                     empty         empty         empty
#
#                                            AddressLine1 AddressLine2  ...  \
# 0                                                     .            .  ...
# 1                                             Singapore        empty  ...
# 2                                                     -        empty  ...
# 3                      17/42, 3RD FLOOR , SUBHASH NAGAR        empty  ...
# 4     NO 38 1ST FLOOR 4TH STREET NARAYAN PILAI STREE...            -  ...
# ...                                                 ...          ...  ...
# 1803                                                  .        empty  ...
# 1804                                                  -        empty  ...
# 1805                                                  -        empty  ...
# 1806                                       2 rue de mai        empty  ...
# 1807                                              empty        empty  ...
#
#      Sales Rep and Comments Opt In Contact Type Odyssey Members  \
# 0                     empty    YES        empty              NO
# 1                     empty    YES        empty              NO
# 2                     empty    YES        empty              NO
# 3                     empty    YES        empty              NO
# 4                    IRSHAD    YES        empty              NO
# ...                     ...    ...          ...             ...
# 1803                  empty    YES        empty              NO
# 1804                  empty    YES        empty              NO
# 1805                  empty    YES        empty              NO
# 1806                  empty    YES        empty              NO
# 1807                  empty  empty        empty              NO
#
#          Lead Brand Lead Sub-Brand  Lead Source  \
# 0     Karma Resorts          Other  Past Guests
# 1     Karma Resorts          Other  Past Guests
# 2     Karma Resorts          Other  Past Guests
# 3     Karma Resorts          Other  Past Guests
# 4     Karma Resorts          Other  Past Guests
# ...             ...            ...          ...
# 1803  Karma Resorts          Other  Past Guests
# 1804  Karma Resorts          Other  Past Guests
# 1805  Karma Resorts          Other  Past Guests
# 1806  Karma Resorts          Other  Past Guests
# 1807  Karma Resorts          Other  Past Guests
#
#                          Lead Locations Lead Source Description  \
# 0                     Karma Royal Palms               Viewpoint
# 1                        Karma Jimbaran               Viewpoint
# 2                        Karma Jimbaran               Viewpoint
# 3              Karma Royal Haathi Mahal               Viewpoint
# 4                     Karma Royal Palms               Viewpoint
# ...                                 ...                     ...
# 1803  Wyndham -  Manoir des Deux Amants               Viewpoint
# 1804  Wyndham -  Manoir des Deux Amants               Viewpoint
# 1805  Wyndham -  Manoir des Deux Amants               Viewpoint
# 1806  Wyndham -  Manoir des Deux Amants               Viewpoint
# 1807                              empty               Viewpoint
#
#      Exclude From Mailing
# 0                      NO
# 1                      NO
# 2                      NO
# 3                      NO
# 4                      NO
# ...                   ...
# 1803                   NO
# 1804                   NO
# 1805                   NO
# 1806                   NO
# 1807                  NaN
#
# [1808 rows x 37 columns]

# %%
m.clean_number(df_viewpoint, 'Phone')
m.clean_number(df_viewpoint, 'Mobile')
m.replace_not_valid_to_empty(df_viewpoint, 'Phone')
m.replace_not_valid_to_empty(df_viewpoint, 'Mobile')

df_viewpoint.loc[df_viewpoint['Phone'].str.contains('00000'), 'Phone'] = 'empty'
df_viewpoint.loc[df_viewpoint['Mobile'].str.contains('00000'), 'Mobile'] = 'empty'

m.clean_space(df_viewpoint, 'Email')
df_viewpoint['Email'] = m.lowercase(df_viewpoint, 'Email')

# %%
pm.email_correction(df_viewpoint, 'Email')

# %%
df_viewpoint.loc[(df_viewpoint['Email'] != 'empty') & ((df_viewpoint['Phone'] != 'empty') | (df_viewpoint['Mobile'] != 'empty')), 'Contact Type'] = 'Email and Phone'
df_viewpoint.loc[(df_viewpoint['Email'] != 'empty') & ((df_viewpoint['Phone'] == 'empty') & (df_viewpoint['Mobile'] == 'empty')), 'Contact Type'] = 'Email Only'
df_viewpoint.loc[(df_viewpoint['Email'] == 'empty') & ((df_viewpoint['Phone'] != 'empty') | (df_viewpoint['Mobile'] != 'empty')), 'Contact Type'] = 'Phone Only'

df_viewpoint.loc[df_viewpoint['Contact Type'] == 'empty'].to_csv(r'C:\Users\fajar\Documents\Python\Data\contact_type_empty_viewpoint.csv', index=False)

count_contact_type_empty = df_viewpoint.loc[df_viewpoint['Contact Type'] == 'empty'].shape[0]

df_viewpoint.drop(df_viewpoint.loc[df_viewpoint['Contact Type'] == 'empty'].index, inplace=True)
df_viewpoint.reset_index(drop=True, inplace=True)

count_after_contact_type_empty = df_viewpoint.shape[0]

df_viewpoint
# Out:
#      Title       Firstname lastname                  DOB PAN CARD  \
# 0       Mr           Sunny    Kumar                empty    empty
# 1       Mr          Andrew     Chok  1995-09-30 00:00:00    empty
# 2       Mr          Andrew     Chok  1995-09-30 00:00:00    empty
# 3      Mrs           Jyoti    Gupta  1982-01-21 00:00:00    empty
# 4       Mr         Naushad    Iqbal                empty    empty
# ...    ...             ...      ...                  ...      ...
# 1705   Mrs          Tamara    Nance                empty    empty
# 1706    Mr           Peter   Coombe                empty    empty
# 1707    Ms          Joanne    Dixon  1974-10-14 00:00:00    empty
# 1708     -        Virginie   Cornee                empty    empty
# 1709        Rufus, Kaylene        -                empty    empty
#
#                          Email         Phone        Mobile  \
# 0                            .         empty         empty
# 1        _yu19960803@gmail.com         empty         empty
# 2        _yu19960803@gmail.com  886956330803         empty
# 3     7ravindergupta@gmail.com  919717989810         empty
# 4            9shad.i@gmail.com  919738776620  919901420272
# ...                        ...           ...           ...
# 1705                     empty  447960742889         empty
# 1706                     empty  441579383572  447970441748
# 1707                     empty   61413489907         empty
# 1708                     empty   33689296744         empty
# 1709                     empty     414824496         empty
#
#                                            AddressLine1 AddressLine2  ...  \
# 0                                                     .            .  ...
# 1                                             Singapore        empty  ...
# 2                                                     -        empty  ...
# 3                      17/42, 3RD FLOOR , SUBHASH NAGAR        empty  ...
# 4     NO 38 1ST FLOOR 4TH STREET NARAYAN PILAI STREE...            -  ...
# ...                                                 ...          ...  ...
# 1705                                                  -            -  ...
# 1706                                          DANELEIGH  DUPATH ROAD  ...
# 1707                                    20 LINER STREET        empty  ...
# 1708                                              empty        empty  ...
# 1709                                              empty        empty  ...
#
#      Sales Rep and Comments Opt In     Contact Type Odyssey Members  \
# 0                     empty    YES       Email Only              NO
# 1                     empty    YES       Email Only              NO
# 2                     empty    YES  Email and Phone              NO
# 3                     empty    YES  Email and Phone              NO
# 4                    IRSHAD    YES  Email and Phone              NO
# ...                     ...    ...              ...             ...
# 1705                  empty    YES       Phone Only              NO
# 1706                  empty    YES       Phone Only              NO
# 1707                  empty    YES       Phone Only              NO
# 1708                  empty    YES       Phone Only              NO
# 1709                  empty    YES       Phone Only              NO
#
#          Lead Brand Lead Sub-Brand  Lead Source  \
# 0     Karma Resorts          Other  Past Guests
# 1     Karma Resorts          Other  Past Guests
# 2     Karma Resorts          Other  Past Guests
# 3     Karma Resorts          Other  Past Guests
# 4     Karma Resorts          Other  Past Guests
# ...             ...            ...          ...
# 1705  Karma Resorts          Other  Past Guests
# 1706  Karma Resorts          Other  Past Guests
# 1707  Karma Resorts          Other  Past Guests
# 1708  Karma Resorts          Other  Past Guests
# 1709  Karma Resorts          Other  Past Guests
#
#                          Lead Locations Lead Source Description  \
# 0                     Karma Royal Palms               Viewpoint
# 1                        Karma Jimbaran               Viewpoint
# 2                        Karma Jimbaran               Viewpoint
# 3              Karma Royal Haathi Mahal               Viewpoint
# 4                     Karma Royal Palms               Viewpoint
# ...                                 ...                     ...
# 1705                  Karma St. Martins               Viewpoint
# 1706                  Karma St. Martins               Viewpoint
# 1707       KRR @ Karma Kandara, Phase V               Viewpoint
# 1708  Wyndham -  Manoir des Deux Amants               Viewpoint
# 1709  Wyndham -  Manoir des Deux Amants               Viewpoint
#
#      Exclude From Mailing
# 0                      NO
# 1                      NO
# 2                      NO
# 3                      NO
# 4                      NO
# ...                   ...
# 1705                   NO
# 1706                   NO
# 1707                   NO
# 1708                   NO
# 1709                   NO
#
# [1710 rows x 37 columns]

# %%
# Cek Email Karma
email_karma = m.find_karma(df_viewpoint, 'Email')
count_email_karma = email_karma.shape[0]
email_karma.to_csv(r'C:\Users\fajar\Documents\Python\Data\email_deleted_viewpoint.csv', index=False)

email_karma
# Out:
#       Title            Firstname              lastname                  DOB  \
# 135      Mr                 Anuj                 Singh                empty
# 282             Maintenance Room          Karma Chakra                empty
# 283             Maintenance Room          Karma Chakra                empty
# 284             Maintenance Room          Karma Chakra                empty
# 285             Maintenance Room          Karma Chakra                empty
# 399       -             Dominika              Garajova  1977-09-10 00:00:00
# 559   Bapak                 Hero              Kharisma                empty
# 651      Mr               Joseph            Antonishek                empty
# 652      Mr               Joseph            Antonishek                empty
# 844      Ms  Marlinde Anne Maria              Verhoeff                empty
# 845      Ms  Marlinde Anne Maria              Verhoeff                empty
# 846      Ms  Marlinde Anne Maria              Verhoeff                empty
# 876      Mr               Mihaly               Horvath                empty
# 877      Mr               Mihaly               Horvath                empty
# 910       -   Maintenance Room -  Karma Royal Monterio                empty
# 911       -   Maintenance Room -  Karma Royal Monterio                empty
# 912       -   Maintenance Room -  Karma Royal Monterio                empty
# 1411     Mr                 Shiv                 Suman                empty
#
#      PAN CARD                             Email          Phone        Mobile  \
# 135     empty         anuj.yadav@karmagroup.com   917355922764         empty
# 282     empty             chakra@karmagroup.com   914812526252  919446080121
# 283     empty             chakra@karmagroup.com   914812526252  919446080121
# 284     empty             chakra@karmagroup.com   914812526252  919446080121
# 285     empty             chakra@karmagroup.com   914812526252  919446080121
# 399     empty  dominika.garajova@karmagroup.com          empty         empty
# 559     empty      hero.kharisma@karmagroup.com  6281999374824         empty
# 651     empty  joseph.antonishek@karmagroup.com  6282235541045         empty
# 652     empty  joseph.antonishek@karmagroup.com  6282235541045         empty
# 844     empty  marlinde.verhoeff@karmagroup.com  6282237493002         empty
# 845     empty  marlinde.verhoeff@karmagroup.com  6282237493002         empty
# 846     empty  marlinde.verhoeff@karmagroup.com  6282237493002         empty
# 876     empty     mihaly.horvath@karmagroup.com  6281338119643         empty
# 877     empty     mihaly.horvath@karmagroup.com  6281338119643         empty
# 910     empty         mr.asstfom@karmagroup.com   918326716200         empty
# 911     empty         mr.asstfom@karmagroup.com   918326716200         empty
# 912     empty         mr.asstfom@karmagroup.com   918326716200         empty
# 1411    empty        shivsuman.b@karmagroup.com   919325868122         empty
#
#                                   AddressLine1 AddressLine2  ...  \
# 135                                          -            -  ...
# 282   Ward # 09, Block#12, Near Nasrath Church     KOTTAYAM  ...
# 283   Ward # 09, Block#12, Near Nasrath Church     KOTTAYAM  ...
# 284   Ward # 09, Block#12, Near Nasrath Church     KOTTAYAM  ...
# 285   Ward # 09, Block#12, Near Nasrath Church     KOTTAYAM  ...
# 399                Global Village E7, Nusa Dua        empty  ...
# 559         Perum Dawas Indah Permai Blok A.36        empty  ...
# 651                      C/- CHEF OF K KANDARA        empty  ...
# 652                      C/- CHEF OF K KANDARA        empty  ...
# 844                                  INDONESIA        empty  ...
# 845                                  INDONESIA        empty  ...
# 846                                  INDONESIA        empty  ...
# 876                                        TBA        empty  ...
# 877                                        TBA        empty  ...
# 910                       karma royal monetrio       Arpora  ...
# 911                       karma royal monetrio       Arpora  ...
# 912                       karma royal monetrio       Arpora  ...
# 1411                                         -            -  ...
#
#      Sales Rep and Comments Opt In     Contact Type Odyssey Members  \
# 135                   empty     NO  Email and Phone              NO
# 282                   empty    YES  Email and Phone              NO
# 283                   empty    YES  Email and Phone              NO
# 284                   empty    YES  Email and Phone              NO
# 285                   empty    YES  Email and Phone              NO
# 399                   empty    YES       Email Only              NO
# 559                   empty    YES  Email and Phone              NO
# 651                   empty    YES  Email and Phone              NO
# 652                   empty    YES  Email and Phone              NO
# 844                   empty    YES  Email and Phone              NO
# 845                   empty    YES  Email and Phone              NO
# 846                   empty    YES  Email and Phone              NO
# 876                   empty    YES  Email and Phone              NO
# 877                   empty    YES  Email and Phone              NO
# 910                   empty    YES  Email and Phone              NO
# 911                   empty    YES  Email and Phone              NO
# 912                   empty    YES  Email and Phone              NO
# 1411                  empty    YES  Email and Phone              NO
#
#          Lead Brand Lead Sub-Brand  Lead Source            Lead Locations  \
# 135   Karma Resorts          Other  Past Guests         Karma Royal Palms
# 282   Karma Resorts          Other  Past Guests      Karma Chakra, Kerala
# 283   Karma Resorts          Other  Past Guests      Karma Chakra, Kerala
# 284   Karma Resorts          Other  Past Guests      Karma Chakra, Kerala
# 285   Karma Resorts          Other  Past Guests      Karma Chakra, Kerala
# 399   Karma Resorts          Other  Past Guests     Karma Royal Candidasa
# 559   Karma Resorts          Other  Past Guests         Karma Royal Sanur
# 651   Karma Resorts          Other  Past Guests  Karma Royal Haathi Mahal
# 652   Karma Resorts          Other  Past Guests  Karma Royal Haathi Mahal
# 844   Karma Resorts          Other  Past Guests     Karma Royal Candidasa
# 845   Karma Resorts          Other  Past Guests     Karma Royal Candidasa
# 846   Karma Resorts          Other  Past Guests     Karma Royal Candidasa
# 876   Karma Resorts          Other  Past Guests    Karma Bayon, Siam Reap
# 877   Karma Resorts          Other  Past Guests    Karma Bayon, Siam Reap
# 910   Karma Resorts          Other  Past Guests      Karma Royal Monterio
# 911   Karma Resorts          Other  Past Guests      Karma Royal Monterio
# 912   Karma Resorts          Other  Past Guests      Karma Royal Monterio
# 1411  Karma Resorts          Other  Past Guests      Karma Royal Monterio
#
#      Lead Source Description Exclude From Mailing
# 135                Viewpoint                  YES
# 282                Viewpoint                   NO
# 283                Viewpoint                   NO
# 284                Viewpoint                   NO
# 285                Viewpoint                   NO
# 399                Viewpoint                   NO
# 559                Viewpoint                   NO
# 651                Viewpoint                   NO
# 652                Viewpoint                   NO
# 844                Viewpoint                   NO
# 845                Viewpoint                   NO
# 846                Viewpoint                   NO
# 876                Viewpoint                   NO
# 877                Viewpoint                   NO
# 910                Viewpoint                   NO
# 911                Viewpoint                   NO
# 912                Viewpoint                   NO
# 1411               Viewpoint                   NO
#
# [18 rows x 37 columns]

# %%
# delete email Karma
count_after_clean_karma = m.delete_karma(df_viewpoint, 'Email')

df_viewpoint
# Out:
#      Title       Firstname lastname                  DOB PAN CARD  \
# 0       Mr           Sunny    Kumar                empty    empty
# 1       Mr          Andrew     Chok  1995-09-30 00:00:00    empty
# 2       Mr          Andrew     Chok  1995-09-30 00:00:00    empty
# 3      Mrs           Jyoti    Gupta  1982-01-21 00:00:00    empty
# 4       Mr         Naushad    Iqbal                empty    empty
# ...    ...             ...      ...                  ...      ...
# 1687   Mrs          Tamara    Nance                empty    empty
# 1688    Mr           Peter   Coombe                empty    empty
# 1689    Ms          Joanne    Dixon  1974-10-14 00:00:00    empty
# 1690     -        Virginie   Cornee                empty    empty
# 1691        Rufus, Kaylene        -                empty    empty
#
#                          Email         Phone        Mobile  \
# 0                            .         empty         empty
# 1        _yu19960803@gmail.com         empty         empty
# 2        _yu19960803@gmail.com  886956330803         empty
# 3     7ravindergupta@gmail.com  919717989810         empty
# 4            9shad.i@gmail.com  919738776620  919901420272
# ...                        ...           ...           ...
# 1687                     empty  447960742889         empty
# 1688                     empty  441579383572  447970441748
# 1689                     empty   61413489907         empty
# 1690                     empty   33689296744         empty
# 1691                     empty     414824496         empty
#
#                                            AddressLine1 AddressLine2  ...  \
# 0                                                     .            .  ...
# 1                                             Singapore        empty  ...
# 2                                                     -        empty  ...
# 3                      17/42, 3RD FLOOR , SUBHASH NAGAR        empty  ...
# 4     NO 38 1ST FLOOR 4TH STREET NARAYAN PILAI STREE...            -  ...
# ...                                                 ...          ...  ...
# 1687                                                  -            -  ...
# 1688                                          DANELEIGH  DUPATH ROAD  ...
# 1689                                    20 LINER STREET        empty  ...
# 1690                                              empty        empty  ...
# 1691                                              empty        empty  ...
#
#      Sales Rep and Comments Opt In     Contact Type Odyssey Members  \
# 0                     empty    YES       Email Only              NO
# 1                     empty    YES       Email Only              NO
# 2                     empty    YES  Email and Phone              NO
# 3                     empty    YES  Email and Phone              NO
# 4                    IRSHAD    YES  Email and Phone              NO
# ...                     ...    ...              ...             ...
# 1687                  empty    YES       Phone Only              NO
# 1688                  empty    YES       Phone Only              NO
# 1689                  empty    YES       Phone Only              NO
# 1690                  empty    YES       Phone Only              NO
# 1691                  empty    YES       Phone Only              NO
#
#          Lead Brand Lead Sub-Brand  Lead Source  \
# 0     Karma Resorts          Other  Past Guests
# 1     Karma Resorts          Other  Past Guests
# 2     Karma Resorts          Other  Past Guests
# 3     Karma Resorts          Other  Past Guests
# 4     Karma Resorts          Other  Past Guests
# ...             ...            ...          ...
# 1687  Karma Resorts          Other  Past Guests
# 1688  Karma Resorts          Other  Past Guests
# 1689  Karma Resorts          Other  Past Guests
# 1690  Karma Resorts          Other  Past Guests
# 1691  Karma Resorts          Other  Past Guests
#
#                          Lead Locations Lead Source Description  \
# 0                     Karma Royal Palms               Viewpoint
# 1                        Karma Jimbaran               Viewpoint
# 2                        Karma Jimbaran               Viewpoint
# 3              Karma Royal Haathi Mahal               Viewpoint
# 4                     Karma Royal Palms               Viewpoint
# ...                                 ...                     ...
# 1687                  Karma St. Martins               Viewpoint
# 1688                  Karma St. Martins               Viewpoint
# 1689       KRR @ Karma Kandara, Phase V               Viewpoint
# 1690  Wyndham -  Manoir des Deux Amants               Viewpoint
# 1691  Wyndham -  Manoir des Deux Amants               Viewpoint
#
#      Exclude From Mailing
# 0                      NO
# 1                      NO
# 2                      NO
# 3                      NO
# 4                      NO
# ...                   ...
# 1687                   NO
# 1688                   NO
# 1689                   NO
# 1690                   NO
# 1691                   NO
#
# [1692 rows x 37 columns]

# %%
# Cek leads test
test_leads = df_viewpoint.loc[
    
        df_viewpoint['Email'].str.contains('^test@', flags=re.I, regex=True) |
        df_viewpoint['Email'].str.contains('\+test', flags=re.I, regex=True) |
    
        df_viewpoint['Firstname'].str.contains('^test$', flags=re.I, regex=True) |
        df_viewpoint['lastname'].str.contains('^test$', flags=re.I, regex=True) |

        df_viewpoint['Firstname'].str.contains('test 1', flags=re.I, regex=True) |
        df_viewpoint['lastname'].str.contains('test 2', flags=re.I, regex=True)|
        df_viewpoint['Firstname'].str.contains('test1', flags=re.I, regex=True) |
        df_viewpoint['lastname'].str.contains('test2', flags=re.I, regex=True)|

        df_viewpoint['Firstname'].str.contains(' test ', flags=re.I, regex=True) | 
        df_viewpoint['lastname'].str.contains(' test ', flags=re.I, regex=True) | 
        df_viewpoint['lastname'].str.contains(' test$', flags=re.I, regex=True)
    ]

count_leads_test = test_leads.shape[0]

test_leads.to_csv(r'C:\Users\fajar\Documents\Python\Data\test_leads_viewpoint.csv', index=False)
test_leads
# Out:
# Empty DataFrame
# Columns: [Title, Firstname, lastname, DOB, PAN CARD, Email, Phone, Mobile, AddressLine1, AddressLine2, Town, State, Country, PostCode, Nationality, MaritalStatus, resortname, Arrival, Departure, CheckInDate, CheckOutDate, room, UnitCategory, BookingNo, BookingSourceDesc, BookingTypeDesc, Date of Tour, Sales Rep and Comments, Opt In, Contact Type, Odyssey Members, Lead Brand, Lead Sub-Brand, Lead Source, Lead Locations, Lead Source Description, Exclude From Mailing]
# Index: []
#
# [0 rows x 37 columns]

# %%
df_viewpoint.drop(test_leads.index, inplace=True)
df_viewpoint.reset_index(drop=True, inplace=True)

count_after_dedup_test = df_viewpoint.shape[0]
count_after_dedup_test
# Out:
# 1692

# %%
count_final_data = count_after_dedup_test

# %%
# df_viewpoint.loc[df_viewpoint['BookingNo'] == '2070341']

# %%
df_viewpoint.replace('empty', '', inplace=True)

# %%
print("==========================================================")
print("Summary")
print("==========================================================")
print("Jumlah Data Awal Viewpoint : "+str(count_data_awal))
print("Jumlah Data Email dan Phone Kosong : "+str(count_contact_type_empty))
print("Jumlah Data Setelah Hapus Email dan Phone Yang Kosong : "+str(count_after_contact_type_empty))
print("Jumlah Data Email Yang Termasuk List Karma : "+str(count_email_karma))
print("Jumlah Data Email Setelah List Karma Dihapus : "+str(count_after_clean_karma))
print("Jumlah Data Test : "+str(count_leads_test))
print("Jumlah Data Email Setelah Data Test Dihapus : "+str(count_after_dedup_test))
print("Jumlah Data Akhir : "+str(count_final_data))
# Out:
# ==========================================================
# Summary
# ==========================================================
# Jumlah Data Awal Viewpoint : 1808
# Jumlah Data Email dan Phone Kosong : 98
# Jumlah Data Setelah Hapus Email dan Phone Yang Kosong : 1710
# Jumlah Data Email Yang Termasuk List Karma : 18
# Jumlah Data Email Setelah List Karma Dihapus : 1692
# Jumlah Data Test : 0
# Jumlah Data Email Setelah Data Test Dihapus : 1692
# Jumlah Data Akhir : 1692

# %%
df_viewpoint.to_excel(r'C:\Users\fajar\Documents\Python\Data\check_country_code_viewpoint.xlsx', index=False)
