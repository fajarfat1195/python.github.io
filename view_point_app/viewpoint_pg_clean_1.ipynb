# %%
import pandas as pd
import re

import past_guest_module as pm

import sys
sys.path.append('../zoho_data_app/')

import main_module as m

# %load_ext autoreload
# %autoreload 2

# %%
path = r'C:\Users\fajar\Documents\Python\Data\Past Guest Data\View Point\2024\Juli\7 July - 15 July\CheckOutReport 7 July - 15 July.xlsx'
df_viewpoint = pd.read_excel(path, dtype='string', sheet_name='Sheet1')
count_data_awal = df_viewpoint.shape[0]
df_viewpoint
# Out:
#      Title                Firstname  lastname                  DOB PAN CARD  \
# 0       Mr                  Timothy   Ritchie  1963-06-10 00:00:00     <NA>
# 1       Mr                   Warren   Milward  1972-02-22 00:00:00     <NA>
# 2       Mr                 KRISTINE    COUTTS                 <NA>     <NA>
# 3      Dr.                  Bidhyut     Banik  1986-08-08 00:00:00     <NA>
# 4       Mr                    Kerry      Ford                 <NA>     <NA>
# ...    ...                      ...       ...                  ...      ...
# 1881  <NA>                    Hervé  bAUTISTA                 <NA>     <NA>
# 1882  <NA>  Chevallier, Jean Pierre      <NA>                 <NA>     <NA>
# 1883  <NA>         Francisco, Paulo      <NA>                 <NA>     <NA>
# 1884  <NA>                     <NA>      <NA>                 <NA>     <NA>
# 1885   krg             Fajar Fatoni        86                 <NA>     <NA>
#
#                           Email        Phone       Mobile  \
# 0          ninukaveri@gmail.com  61431569325         <NA>
# 1     warrenmilward@outlook.com  61419963104         <NA>
# 2           kcoutts@outlook.com  61499235755  61414282813
# 3             bidhyut@gmail.com  61413663043         <NA>
# 4     fred.kerry.ford@gmail.com  61408003407         <NA>
# ...                         ...          ...          ...
# 1881                       <NA>         <NA>         <NA>
# 1882                       <NA>         <NA>         <NA>
# 1883                booking.com        211.5         <NA>
# 1884                       <NA>         <NA>         <NA>
# 1885                       <NA>         <NA>         <NA>
#
#                                           AddressLine1  \
# 0                                       121 WARREN AVE
# 1                                   63A BEAMISH AVENUE
# 2     116 PATERSON STREET BYRON BAY NSW 2481 AUSTRALIA
# 3                                          30B WELD ST
# 4                    24 THE AVENUE Heathcote NSW  2233
# ...                                                ...
# 1881                                                 .
# 1882                                              <NA>
# 1883                                              <NA>
# 1884                                              <NA>
# 1885                                              <NA>
#
#                            AddressLine2  ...          CheckInDate  \
# 0                                  <NA>  ...  2024-07-07 07:27:39
# 1                                  <NA>  ...  2024-06-30 21:36:52
# 2     NSW 2481 AUSTRALIA 2481 AUSTRALIA  ...  2024-07-04 19:15:30
# 3                                  <NA>  ...  2024-07-06 23:00:10
# 4                   Heathcote NSW  2233  ...  2024-07-06 15:03:16
# ...                                 ...  ...                  ...
# 1881                                  .  ...  2024-07-14 01:06:55
# 1882                               <NA>  ...  2024-07-13 01:37:26
# 1883                               <NA>  ...  2024-07-14 10:11:56
# 1884                               <NA>  ...  2024-07-01 18:02:09
# 1885                               <NA>  ...                 <NA>
#
#              CheckOutDate  room         UnitCategory BookingNo  \
# 0     2024-07-09 14:34:10    11          Deluxe Room   2476900
# 1     2024-07-09 15:25:10    07          Deluxe Room   2516282
# 2     2024-07-11 12:43:05    09          Deluxe Room   2549826
# 3     2024-07-13 11:19:39    10          Deluxe Room   2494529
# 4     2024-07-13 11:19:43    03          Deluxe Room   2504186
# ...                   ...   ...                  ...       ...
# 1881  2024-07-14 16:27:22   102  2 Bedroom Apartment   2563880
# 1882  2024-07-14 16:34:08   101  1 Bedroom Apartment   2523984
# 1883  2024-07-14 18:32:25   122  2 Bedroom Apartment   2559806
# 1884  2024-07-14 18:48:48   126  1 Bedroom Apartment   2372576
# 1885                 <NA>  <NA>                 <NA>      <NA>
#
#      BookingSourceDesc        BookingTypeDesc Date of Tour  \
# 0      Fly Buy Western            Via Resorts         <NA>
# 1      Fly Buy Western  KE - Karma Experience         <NA>
# 2      Fly Buy Western  KE - Karma Experience         <NA>
# 3      Fly Buy Western        Fly Buy Western         <NA>
# 4      Fly Buy Western            Via Resorts         <NA>
# ...                ...                    ...          ...
# 1881    Hotel Bookings            Booking.com         <NA>
# 1882    Hotel Bookings         Wyndham Guests         <NA>
# 1883    Hotel Bookings         Wyndham Guests         <NA>
# 1884    Hotel Bookings         Wyndham Guests         <NA>
# 1885              <NA>                   <NA>         <NA>
#
#      Sales Rep and Comments Opt In
# 0                      <NA>    YES
# 1                      <NA>    YES
# 2                      <NA>    YES
# 3                      <NA>    YES
# 4                      <NA>    YES
# ...                     ...    ...
# 1881                   <NA>    YES
# 1882                   <NA>    YES
# 1883                   <NA>    YES
# 1884                   <NA>    YES
# 1885                   <NA>   <NA>
#
# [1886 rows x 29 columns]

# %%
df_viewpoint.columns
# Out:
# Index(['Title', 'Firstname', 'lastname', 'DOB', 'PAN CARD', 'Email', 'Phone',
#        'Mobile', 'AddressLine1', 'AddressLine2', 'Town', 'State', 'Country',
#        'PostCode', 'Nationality', 'MaritalStatus', 'resortname', 'Arrival',
#        'Departure', 'CheckInDate', 'CheckOutDate', 'room', 'UnitCategory',
#        'BookingNo', 'BookingSourceDesc', 'BookingTypeDesc', 'Date of Tour',
#        'Sales Rep and Comments', 'Opt In'],
#       dtype='object')

# %%
df_viewpoint.fillna('empty', inplace=True)

df_viewpoint['Contact Type'] = 'empty'
df_viewpoint['Odyssey Members'] = 'NO'

df_viewpoint['Lead Brand'] = 'Karma Resorts'
df_viewpoint['Lead Sub-Brand'] = 'Other'
df_viewpoint['Lead Source'] = 'Past Guests'
df_viewpoint['Lead Locations'] = df_viewpoint['resortname']
df_viewpoint['Lead Source Description'] = 'Viewpoint'

# %%
df_viewpoint.loc[df_viewpoint['Opt In'] == 'YES', 'Exclude From Mailing'] = 'NO'
df_viewpoint.loc[df_viewpoint['Opt In'] == 'NO', 'Exclude From Mailing'] = 'YES'

# %%
df_viewpoint.loc[df_viewpoint['lastname'] == 'empty', 'lastname'] = '-'

# %%
df_viewpoint['Title'].replace('empty', '', inplace=True)
df_viewpoint['Firstname'].replace('empty', '', inplace=True)
df_viewpoint['lastname'].replace('empty', '', inplace=True)

df_viewpoint['Title'] = df_viewpoint['Title'].str.title()
df_viewpoint['Firstname'] = df_viewpoint['Firstname'].str.title()
df_viewpoint['lastname'] = df_viewpoint['lastname'].str.title()

df_viewpoint
# Out:
#      Title                Firstname  lastname                  DOB PAN CARD  \
# 0       Mr                  Timothy   Ritchie  1963-06-10 00:00:00    empty
# 1       Mr                   Warren   Milward  1972-02-22 00:00:00    empty
# 2       Mr                 Kristine    Coutts                empty    empty
# 3      Dr.                  Bidhyut     Banik  1986-08-08 00:00:00    empty
# 4       Mr                    Kerry      Ford                empty    empty
# ...    ...                      ...       ...                  ...      ...
# 1881                          Hervé  Bautista                empty    empty
# 1882        Chevallier, Jean Pierre         -                empty    empty
# 1883               Francisco, Paulo         -                empty    empty
# 1884                                        -                empty    empty
# 1885   Krg             Fajar Fatoni        86                empty    empty
#
#                           Email        Phone       Mobile  \
# 0          ninukaveri@gmail.com  61431569325        empty
# 1     warrenmilward@outlook.com  61419963104        empty
# 2           kcoutts@outlook.com  61499235755  61414282813
# 3             bidhyut@gmail.com  61413663043        empty
# 4     fred.kerry.ford@gmail.com  61408003407        empty
# ...                         ...          ...          ...
# 1881                      empty        empty        empty
# 1882                      empty        empty        empty
# 1883                booking.com        211.5        empty
# 1884                      empty        empty        empty
# 1885                      empty        empty        empty
#
#                                           AddressLine1  \
# 0                                       121 WARREN AVE
# 1                                   63A BEAMISH AVENUE
# 2     116 PATERSON STREET BYRON BAY NSW 2481 AUSTRALIA
# 3                                          30B WELD ST
# 4                    24 THE AVENUE Heathcote NSW  2233
# ...                                                ...
# 1881                                                 .
# 1882                                             empty
# 1883                                             empty
# 1884                                             empty
# 1885                                             empty
#
#                            AddressLine2  ... Sales Rep and Comments Opt In  \
# 0                                 empty  ...                  empty    YES
# 1                                 empty  ...                  empty    YES
# 2     NSW 2481 AUSTRALIA 2481 AUSTRALIA  ...                  empty    YES
# 3                                 empty  ...                  empty    YES
# 4                   Heathcote NSW  2233  ...                  empty    YES
# ...                                 ...  ...                    ...    ...
# 1881                                  .  ...                  empty    YES
# 1882                              empty  ...                  empty    YES
# 1883                              empty  ...                  empty    YES
# 1884                              empty  ...                  empty    YES
# 1885                              empty  ...                  empty  empty
#
#      Contact Type Odyssey Members     Lead Brand Lead Sub-Brand  Lead Source  \
# 0           empty              NO  Karma Resorts          Other  Past Guests
# 1           empty              NO  Karma Resorts          Other  Past Guests
# 2           empty              NO  Karma Resorts          Other  Past Guests
# 3           empty              NO  Karma Resorts          Other  Past Guests
# 4           empty              NO  Karma Resorts          Other  Past Guests
# ...           ...             ...            ...            ...          ...
# 1881        empty              NO  Karma Resorts          Other  Past Guests
# 1882        empty              NO  Karma Resorts          Other  Past Guests
# 1883        empty              NO  Karma Resorts          Other  Past Guests
# 1884        empty              NO  Karma Resorts          Other  Past Guests
# 1885        empty              NO  Karma Resorts          Other  Past Guests
#
#                          Lead Locations Lead Source Description  \
# 0                           Amina hotel               Viewpoint
# 1                           Amina hotel               Viewpoint
# 2                           Amina hotel               Viewpoint
# 3                           Amina hotel               Viewpoint
# 4                           Amina hotel               Viewpoint
# ...                                 ...                     ...
# 1881  Wyndham -  Manoir des Deux Amants               Viewpoint
# 1882  Wyndham -  Manoir des Deux Amants               Viewpoint
# 1883  Wyndham -  Manoir des Deux Amants               Viewpoint
# 1884  Wyndham -  Manoir des Deux Amants               Viewpoint
# 1885                              empty               Viewpoint
#
#      Exclude From Mailing
# 0                      NO
# 1                      NO
# 2                      NO
# 3                      NO
# 4                      NO
# ...                   ...
# 1881                   NO
# 1882                   NO
# 1883                   NO
# 1884                   NO
# 1885                  NaN
#
# [1886 rows x 37 columns]

# %%
m.clean_number(df_viewpoint, 'Phone')
m.clean_number(df_viewpoint, 'Mobile')
m.replace_not_valid_to_empty(df_viewpoint, 'Phone')
m.replace_not_valid_to_empty(df_viewpoint, 'Mobile')

df_viewpoint.loc[df_viewpoint['Phone'].str.contains('00000'), 'Phone'] = 'empty'
df_viewpoint.loc[df_viewpoint['Mobile'].str.contains('00000'), 'Mobile'] = 'empty'

m.clean_space(df_viewpoint, 'Email')
df_viewpoint['Email'] = m.lowercase(df_viewpoint, 'Email')

# %%
pm.email_correction(df_viewpoint, 'Email')

# %%
df_viewpoint.loc[(df_viewpoint['Email'] != 'empty') & ((df_viewpoint['Phone'] != 'empty') | (df_viewpoint['Mobile'] != 'empty')), 'Contact Type'] = 'Email and Phone'
df_viewpoint.loc[(df_viewpoint['Email'] != 'empty') & ((df_viewpoint['Phone'] == 'empty') & (df_viewpoint['Mobile'] == 'empty')), 'Contact Type'] = 'Email Only'
df_viewpoint.loc[(df_viewpoint['Email'] == 'empty') & ((df_viewpoint['Phone'] != 'empty') | (df_viewpoint['Mobile'] != 'empty')), 'Contact Type'] = 'Phone Only'

df_viewpoint.loc[df_viewpoint['Contact Type'] == 'empty'].to_csv(r'C:\Users\fajar\Documents\Python\Data\contact_type_empty_viewpoint.csv', index=False)

count_contact_type_empty = df_viewpoint.loc[df_viewpoint['Contact Type'] == 'empty'].shape[0]

df_viewpoint.drop(df_viewpoint.loc[df_viewpoint['Contact Type'] == 'empty'].index, inplace=True)
df_viewpoint.reset_index(drop=True, inplace=True)

count_after_contact_type_empty = df_viewpoint.shape[0]

df_viewpoint
# Out:
#      Title          Firstname lastname                  DOB PAN CARD  \
# 0       Mr            Timothy  Ritchie  1963-06-10 00:00:00    empty
# 1       Mr             Warren  Milward  1972-02-22 00:00:00    empty
# 2       Mr           Kristine   Coutts                empty    empty
# 3      Dr.            Bidhyut    Banik  1986-08-08 00:00:00    empty
# 4       Mr              Kerry     Ford                empty    empty
# ...    ...                ...      ...                  ...      ...
# 1712        Salem, Marc Godel        -                empty    empty
# 1713        Salem, Marc Godel        -                empty    empty
# 1714        Salem, Marc Godel        -                empty    empty
# 1715            Ligni, Emilie        -                empty    empty
# 1716         Francisco, Paulo        -                empty    empty
#
#                           Email        Phone       Mobile  \
# 0          ninukaveri@gmail.com  61431569325        empty
# 1     warrenmilward@outlook.com  61419963104        empty
# 2           kcoutts@outlook.com  61499235755  61414282813
# 3             bidhyut@gmail.com  61413663043        empty
# 4     fred.kerry.ford@gmail.com  61408003407        empty
# ...                         ...          ...          ...
# 1712                booking.com        empty        empty
# 1713                booking.com        empty        empty
# 1714                booking.com        empty        empty
# 1715                booking.com        empty        empty
# 1716                booking.com        empty        empty
#
#                                           AddressLine1  \
# 0                                       121 WARREN AVE
# 1                                   63A BEAMISH AVENUE
# 2     116 PATERSON STREET BYRON BAY NSW 2481 AUSTRALIA
# 3                                          30B WELD ST
# 4                    24 THE AVENUE Heathcote NSW  2233
# ...                                                ...
# 1712                                             empty
# 1713                                             empty
# 1714                                             empty
# 1715                                             empty
# 1716                                             empty
#
#                            AddressLine2  ... Sales Rep and Comments Opt In  \
# 0                                 empty  ...                  empty    YES
# 1                                 empty  ...                  empty    YES
# 2     NSW 2481 AUSTRALIA 2481 AUSTRALIA  ...                  empty    YES
# 3                                 empty  ...                  empty    YES
# 4                   Heathcote NSW  2233  ...                  empty    YES
# ...                                 ...  ...                    ...    ...
# 1712                              empty  ...                  empty    YES
# 1713                              empty  ...                  empty    YES
# 1714                              empty  ...                  empty    YES
# 1715                              empty  ...                  empty    YES
# 1716                              empty  ...                  empty    YES
#
#          Contact Type Odyssey Members     Lead Brand Lead Sub-Brand  \
# 0     Email and Phone              NO  Karma Resorts          Other
# 1     Email and Phone              NO  Karma Resorts          Other
# 2     Email and Phone              NO  Karma Resorts          Other
# 3     Email and Phone              NO  Karma Resorts          Other
# 4     Email and Phone              NO  Karma Resorts          Other
# ...               ...             ...            ...            ...
# 1712       Email Only              NO  Karma Resorts          Other
# 1713       Email Only              NO  Karma Resorts          Other
# 1714       Email Only              NO  Karma Resorts          Other
# 1715       Email Only              NO  Karma Resorts          Other
# 1716       Email Only              NO  Karma Resorts          Other
#
#       Lead Source                     Lead Locations Lead Source Description  \
# 0     Past Guests                        Amina hotel               Viewpoint
# 1     Past Guests                        Amina hotel               Viewpoint
# 2     Past Guests                        Amina hotel               Viewpoint
# 3     Past Guests                        Amina hotel               Viewpoint
# 4     Past Guests                        Amina hotel               Viewpoint
# ...           ...                                ...                     ...
# 1712  Past Guests  Wyndham -  Manoir des Deux Amants               Viewpoint
# 1713  Past Guests  Wyndham -  Manoir des Deux Amants               Viewpoint
# 1714  Past Guests  Wyndham -  Manoir des Deux Amants               Viewpoint
# 1715  Past Guests  Wyndham -  Manoir des Deux Amants               Viewpoint
# 1716  Past Guests  Wyndham -  Manoir des Deux Amants               Viewpoint
#
#      Exclude From Mailing
# 0                      NO
# 1                      NO
# 2                      NO
# 3                      NO
# 4                      NO
# ...                   ...
# 1712                   NO
# 1713                   NO
# 1714                   NO
# 1715                   NO
# 1716                   NO
#
# [1717 rows x 37 columns]

# %%
# Cek Email Karma
email_karma = m.find_karma(df_viewpoint, 'Email')
count_email_karma = email_karma.shape[0]
email_karma.to_csv(r'C:\Users\fajar\Documents\Python\Data\email_deleted_viewpoint.csv', index=False)

email_karma
# Out:
#       Title           Firstname              lastname    DOB PAN CARD  \
# 77       Mr                Gary               Knowles  empty    empty
# 113            Maintenance Room          Karma Chakra  empty    empty
# 115            Maintenance Room          Karma Chakra  empty    empty
# 118            Maintenance Room          Karma Chakra  empty    empty
# 138            Maintenance Room          Karma Chakra  empty    empty
# 139            Maintenance Room          Karma Chakra  empty    empty
# 150            Maintenance Room          Karma Chakra  empty    empty
# 303      Mr             Michael                  Wood  empty    empty
# 417      Mr      Sukhjender Pal                 Singh  empty    empty
# 565   Bapak                Hero              Kharisma  empty    empty
# 813       -  Maintenance Room -  Karma Royal Monterio  empty    empty
# 818      Mr                Shiv                 Suman  empty    empty
# 860      Mr               Suraj                  Naik  empty    empty
# 861      Mr               Suraj                  Naik  empty    empty
# 870       -  Maintenance Room -  Karma Royal Monterio  empty    empty
# 878      Mr              Rehber                Ansari  empty    empty
# 886      Mr              Pramod        Balasubramanya  empty    empty
# 887      Mr                Shiv                 Suman  empty    empty
# 888      Mr                Shiv                 Suman  empty    empty
# 891      Mr                Shiv                 Suman  empty    empty
# 1049     Mr              Pramod        Balasubramanya  empty    empty
# 1596     Mr               David                Hadson  empty    empty
#
#                                      Email          Phone        Mobile  \
# 77             gary.knowles@karmagroup.com    61409587457         empty
# 113                  chakra@karmagroup.com   914812526252  919446080121
# 115                  chakra@karmagroup.com   914812526252  919446080121
# 118                  chakra@karmagroup.com   914812526252  919446080121
# 138                  chakra@karmagroup.com   914812526252  919446080121
# 139                  chakra@karmagroup.com   914812526252  919446080121
# 150                  chakra@karmagroup.com   914812526252  919446080121
# 303            michael.wood@karmagroup.com   628113971444         empty
# 417        sukhjender.singh@karmagroup.com   917807770241         empty
# 565           hero.kharisma@karmagroup.com  6281999374824         empty
# 813              mr.asstfom@karmagroup.com   918326716200         empty
# 818             shivsuman.b@karmagroup.com   919325868122         empty
# 860              suraj.naik@karmagroup.com   919999768129         empty
# 861              suraj.naik@karmagroup.com   919999768129         empty
# 870              mr.asstfom@karmagroup.com   918326716200         empty
# 878           rehber.ansari@karmagroup.com   919637297845  919637297845
# 886   pramod.balasubramanya@karmagroup.com   919538510610  919538510610
# 887             shivsuman.b@karmagroup.com   919325868122         empty
# 888             shivsuman.b@karmagroup.com   919325868122         empty
# 891             shivsuman.b@karmagroup.com   919325868122         empty
# 1049  pramod.balasubramanya@karmagroup.com   919538510610  919538510610
# 1596           david.hadson@karmagroup.com   626236341519         empty
#
#                                            AddressLine1  \
# 77                Jl. By Pass Ngurah Rai No.61, Pemogan
# 113            Ward # 09, Block#12, Near Nasrath Church
# 115            Ward # 09, Block#12, Near Nasrath Church
# 118            Ward # 09, Block#12, Near Nasrath Church
# 138            Ward # 09, Block#12, Near Nasrath Church
# 139            Ward # 09, Block#12, Near Nasrath Church
# 150            Ward # 09, Block#12, Near Nasrath Church
# 303              Jl. By Pass Ngurah Rai No.61, Pemogan,
# 417                       Village Tohu, Indru Nag Road,
# 565                  Perum Dawas Indah Permai Blok A.36
# 813                                karma royal monetrio
# 818                                                   -
# 860                     HNO 25 D 1 CUNCHELIM KHADPAWADA
# 861                     HNO 25 D 1 CUNCHELIM KHADPAWADA
# 870                                karma royal monetrio
# 878   .PRATIBHA SOCIETY FLATE NO G 12 AQUEM ALTO MAR...
# 886                                                   -
# 887                                                   -
# 888                                                   -
# 891                                                   -
# 1049                                                  -
# 1596                                       C/- IVO BALI
#
#                  AddressLine2  ... Sales Rep and Comments Opt In  \
# 77        Kec. Denpasar Sel.,  ...                  empty    YES
# 113                  KOTTAYAM  ...                  empty    YES
# 115                  KOTTAYAM  ...                  empty    YES
# 118                  KOTTAYAM  ...                  empty    YES
# 138                  KOTTAYAM  ...                  empty    YES
# 139                  KOTTAYAM  ...                  empty    YES
# 150                  KOTTAYAM  ...                  empty    YES
# 303        Kec. Denpasar Sel.  ...                  empty    YES
# 417                     empty  ...                  empty    YES
# 565                     empty  ...                  empty    YES
# 813                    Arpora  ...                  empty    YES
# 818                         -  ...                  empty    YES
# 860   MAPUSA BARDEZ NORTH GOA  ...                  empty    YES
# 861   MAPUSA BARDEZ NORTH GOA  ...                  empty    YES
# 870                    Arpora  ...                  empty    YES
# 878                         .  ...                  empty    YES
# 886                         -  ...                  empty    YES
# 887                         -  ...                  empty    YES
# 888                         -  ...                  empty    YES
# 891                         -  ...                  empty    YES
# 1049                        -  ...                  empty    YES
# 1596                    empty  ...                  empty    YES
#
#          Contact Type Odyssey Members     Lead Brand Lead Sub-Brand  \
# 77    Email and Phone              NO  Karma Resorts          Other
# 113   Email and Phone              NO  Karma Resorts          Other
# 115   Email and Phone              NO  Karma Resorts          Other
# 118   Email and Phone              NO  Karma Resorts          Other
# 138   Email and Phone              NO  Karma Resorts          Other
# 139   Email and Phone              NO  Karma Resorts          Other
# 150   Email and Phone              NO  Karma Resorts          Other
# 303   Email and Phone              NO  Karma Resorts          Other
# 417   Email and Phone              NO  Karma Resorts          Other
# 565   Email and Phone              NO  Karma Resorts          Other
# 813   Email and Phone              NO  Karma Resorts          Other
# 818   Email and Phone              NO  Karma Resorts          Other
# 860   Email and Phone              NO  Karma Resorts          Other
# 861   Email and Phone              NO  Karma Resorts          Other
# 870   Email and Phone              NO  Karma Resorts          Other
# 878   Email and Phone              NO  Karma Resorts          Other
# 886   Email and Phone              NO  Karma Resorts          Other
# 887   Email and Phone              NO  Karma Resorts          Other
# 888   Email and Phone              NO  Karma Resorts          Other
# 891   Email and Phone              NO  Karma Resorts          Other
# 1049  Email and Phone              NO  Karma Resorts          Other
# 1596  Email and Phone              NO  Karma Resorts          Other
#
#       Lead Source                           Lead Locations  \
# 77    Past Guests                  Karma Borgo Di Colleoli
# 113   Past Guests                     Karma Chakra, Kerala
# 115   Past Guests                     Karma Chakra, Kerala
# 118   Past Guests                     Karma Chakra, Kerala
# 138   Past Guests                     Karma Chakra, Kerala
# 139   Past Guests                     Karma Chakra, Kerala
# 150   Past Guests                     Karma Chakra, Kerala
# 303   Past Guests                         Karma La Herriza
# 417   Past Guests                     Karma Martam Retreat
# 565   Past Guests                    Karma Royal Candidasa
# 813   Past Guests                     Karma Royal Monterio
# 818   Past Guests                     Karma Royal Monterio
# 860   Past Guests                     Karma Royal Monterio
# 861   Past Guests                     Karma Royal Monterio
# 870   Past Guests                     Karma Royal Monterio
# 878   Past Guests                     Karma Royal Monterio
# 886   Past Guests                     Karma Royal Monterio
# 887   Past Guests                     Karma Royal Monterio
# 888   Past Guests                     Karma Royal Monterio
# 891   Past Guests                     Karma Royal Monterio
# 1049  Past Guests                        Karma Royal Palms
# 1596  Past Guests  KRR @ Karma Kandara, Mentari Residences
#
#      Lead Source Description Exclude From Mailing
# 77                 Viewpoint                   NO
# 113                Viewpoint                   NO
# 115                Viewpoint                   NO
# 118                Viewpoint                   NO
# 138                Viewpoint                   NO
# 139                Viewpoint                   NO
# 150                Viewpoint                   NO
# 303                Viewpoint                   NO
# 417                Viewpoint                   NO
# 565                Viewpoint                   NO
# 813                Viewpoint                   NO
# 818                Viewpoint                   NO
# 860                Viewpoint                   NO
# 861                Viewpoint                   NO
# 870                Viewpoint                   NO
# 878                Viewpoint                   NO
# 886                Viewpoint                   NO
# 887                Viewpoint                   NO
# 888                Viewpoint                   NO
# 891                Viewpoint                   NO
# 1049               Viewpoint                   NO
# 1596               Viewpoint                   NO
#
# [22 rows x 37 columns]

# %%
# delete email Karma
count_after_clean_karma = m.delete_karma(df_viewpoint, 'Email')

df_viewpoint
# Out:
#      Title          Firstname lastname                  DOB PAN CARD  \
# 0       Mr            Timothy  Ritchie  1963-06-10 00:00:00    empty
# 1       Mr             Warren  Milward  1972-02-22 00:00:00    empty
# 2       Mr           Kristine   Coutts                empty    empty
# 3      Dr.            Bidhyut    Banik  1986-08-08 00:00:00    empty
# 4       Mr              Kerry     Ford                empty    empty
# ...    ...                ...      ...                  ...      ...
# 1690        Salem, Marc Godel        -                empty    empty
# 1691        Salem, Marc Godel        -                empty    empty
# 1692        Salem, Marc Godel        -                empty    empty
# 1693            Ligni, Emilie        -                empty    empty
# 1694         Francisco, Paulo        -                empty    empty
#
#                           Email        Phone       Mobile  \
# 0          ninukaveri@gmail.com  61431569325        empty
# 1     warrenmilward@outlook.com  61419963104        empty
# 2           kcoutts@outlook.com  61499235755  61414282813
# 3             bidhyut@gmail.com  61413663043        empty
# 4     fred.kerry.ford@gmail.com  61408003407        empty
# ...                         ...          ...          ...
# 1690                booking.com        empty        empty
# 1691                booking.com        empty        empty
# 1692                booking.com        empty        empty
# 1693                booking.com        empty        empty
# 1694                booking.com        empty        empty
#
#                                           AddressLine1  \
# 0                                       121 WARREN AVE
# 1                                   63A BEAMISH AVENUE
# 2     116 PATERSON STREET BYRON BAY NSW 2481 AUSTRALIA
# 3                                          30B WELD ST
# 4                    24 THE AVENUE Heathcote NSW  2233
# ...                                                ...
# 1690                                             empty
# 1691                                             empty
# 1692                                             empty
# 1693                                             empty
# 1694                                             empty
#
#                            AddressLine2  ... Sales Rep and Comments Opt In  \
# 0                                 empty  ...                  empty    YES
# 1                                 empty  ...                  empty    YES
# 2     NSW 2481 AUSTRALIA 2481 AUSTRALIA  ...                  empty    YES
# 3                                 empty  ...                  empty    YES
# 4                   Heathcote NSW  2233  ...                  empty    YES
# ...                                 ...  ...                    ...    ...
# 1690                              empty  ...                  empty    YES
# 1691                              empty  ...                  empty    YES
# 1692                              empty  ...                  empty    YES
# 1693                              empty  ...                  empty    YES
# 1694                              empty  ...                  empty    YES
#
#          Contact Type Odyssey Members     Lead Brand Lead Sub-Brand  \
# 0     Email and Phone              NO  Karma Resorts          Other
# 1     Email and Phone              NO  Karma Resorts          Other
# 2     Email and Phone              NO  Karma Resorts          Other
# 3     Email and Phone              NO  Karma Resorts          Other
# 4     Email and Phone              NO  Karma Resorts          Other
# ...               ...             ...            ...            ...
# 1690       Email Only              NO  Karma Resorts          Other
# 1691       Email Only              NO  Karma Resorts          Other
# 1692       Email Only              NO  Karma Resorts          Other
# 1693       Email Only              NO  Karma Resorts          Other
# 1694       Email Only              NO  Karma Resorts          Other
#
#       Lead Source                     Lead Locations Lead Source Description  \
# 0     Past Guests                        Amina hotel               Viewpoint
# 1     Past Guests                        Amina hotel               Viewpoint
# 2     Past Guests                        Amina hotel               Viewpoint
# 3     Past Guests                        Amina hotel               Viewpoint
# 4     Past Guests                        Amina hotel               Viewpoint
# ...           ...                                ...                     ...
# 1690  Past Guests  Wyndham -  Manoir des Deux Amants               Viewpoint
# 1691  Past Guests  Wyndham -  Manoir des Deux Amants               Viewpoint
# 1692  Past Guests  Wyndham -  Manoir des Deux Amants               Viewpoint
# 1693  Past Guests  Wyndham -  Manoir des Deux Amants               Viewpoint
# 1694  Past Guests  Wyndham -  Manoir des Deux Amants               Viewpoint
#
#      Exclude From Mailing
# 0                      NO
# 1                      NO
# 2                      NO
# 3                      NO
# 4                      NO
# ...                   ...
# 1690                   NO
# 1691                   NO
# 1692                   NO
# 1693                   NO
# 1694                   NO
#
# [1695 rows x 37 columns]

# %%
# Cek leads test
test_leads = df_viewpoint.loc[
    
        df_viewpoint['Email'].str.contains('^test@', flags=re.I, regex=True) |
        df_viewpoint['Email'].str.contains('\+test', flags=re.I, regex=True) |
    
        df_viewpoint['Firstname'].str.contains('^test$', flags=re.I, regex=True) |
        df_viewpoint['lastname'].str.contains('^test$', flags=re.I, regex=True) |

        df_viewpoint['Firstname'].str.contains('test 1', flags=re.I, regex=True) |
        df_viewpoint['lastname'].str.contains('test 2', flags=re.I, regex=True)|
        df_viewpoint['Firstname'].str.contains('test1', flags=re.I, regex=True) |
        df_viewpoint['lastname'].str.contains('test2', flags=re.I, regex=True)|

        df_viewpoint['Firstname'].str.contains(' test ', flags=re.I, regex=True) | 
        df_viewpoint['lastname'].str.contains(' test ', flags=re.I, regex=True) | 
        df_viewpoint['lastname'].str.contains(' test$', flags=re.I, regex=True)
    ]

count_leads_test = test_leads.shape[0]

test_leads.to_csv(r'C:\Users\fajar\Documents\Python\Data\test_leads_viewpoint.csv', index=False)
test_leads
# Out:
# Empty DataFrame
# Columns: [Title, Firstname, lastname, DOB, PAN CARD, Email, Phone, Mobile, AddressLine1, AddressLine2, Town, State, Country, PostCode, Nationality, MaritalStatus, resortname, Arrival, Departure, CheckInDate, CheckOutDate, room, UnitCategory, BookingNo, BookingSourceDesc, BookingTypeDesc, Date of Tour, Sales Rep and Comments, Opt In, Contact Type, Odyssey Members, Lead Brand, Lead Sub-Brand, Lead Source, Lead Locations, Lead Source Description, Exclude From Mailing]
# Index: []
#
# [0 rows x 37 columns]

# %%
df_viewpoint.drop(test_leads.index, inplace=True)
df_viewpoint.reset_index(drop=True, inplace=True)

count_after_dedup_test = df_viewpoint.shape[0]
count_after_dedup_test
# Out:
# 1695

# %%
count_final_data = count_after_dedup_test

# %%
# df_viewpoint.loc[df_viewpoint['BookingNo'] == '2070341']

# %%
df_viewpoint.replace('empty', '', inplace=True)

# %%
print("==========================================================")
print("Summary")
print("==========================================================")
print("Jumlah Data Awal Viewpoint : "+str(count_data_awal))
print("Jumlah Data Email dan Phone Kosong : "+str(count_contact_type_empty))
print("Jumlah Data Setelah Hapus Email dan Phone Yang Kosong : "+str(count_after_contact_type_empty))
print("Jumlah Data Email Yang Termasuk List Karma : "+str(count_email_karma))
print("Jumlah Data Email Setelah List Karma Dihapus : "+str(count_after_clean_karma))
print("Jumlah Data Test : "+str(count_leads_test))
print("Jumlah Data Email Setelah Data Test Dihapus : "+str(count_after_dedup_test))
print("Jumlah Data Akhir : "+str(count_final_data))
# Out:
# ==========================================================
# Summary
# ==========================================================
# Jumlah Data Awal Viewpoint : 1886
# Jumlah Data Email dan Phone Kosong : 169
# Jumlah Data Setelah Hapus Email dan Phone Yang Kosong : 1717
# Jumlah Data Email Yang Termasuk List Karma : 22
# Jumlah Data Email Setelah List Karma Dihapus : 1695
# Jumlah Data Test : 0
# Jumlah Data Email Setelah Data Test Dihapus : 1695
# Jumlah Data Akhir : 1695

# %%
df_viewpoint.to_excel(r'C:\Users\fajar\Documents\Python\Data\check_country_code_viewpoint.xlsx', index=False)
