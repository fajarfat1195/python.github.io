# %%
import pandas as pd
import re

import past_guest_module as pm

import sys
sys.path.append('../zoho_data_app/')

import main_module as m

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
path = r'C:\Users\fajar\Documents\Python\Data\Past Guest Data\View Point\2024\Sep\1 Sep - 9 Sep\CheckOutReport 1 Sep - 9 Sep.xlsx'
df_viewpoint = pd.read_excel(path, dtype='string', sheet_name='Sheet1')
count_data_awal = df_viewpoint.shape[0]
df_viewpoint
# Out:
#      Title         Firstname    lastname                  DOB PAN CARD  \
# 0       Mr              XING        QIAN                 <NA>     <NA>
# 1       Mr                S.  Asirvatham                 <NA>     <NA>
# 2       Mr                S.  Asirvatham                 <NA>     <NA>
# 3       Mr  Shailendra kumar     Choubey  1971-12-10 00:00:00     <NA>
# 4       Mr  Shailendra kumar     Choubey  1971-12-10 00:00:00     <NA>
# ...    ...               ...         ...                  ...      ...
# 1589  <NA>      Waller, Paul        <NA>                 <NA>     <NA>
# 1590  <NA>            Oceane     Cormier                 <NA>     <NA>
# 1591     -              GREG     RAMIREZ                 <NA>     <NA>
# 1592     -              Yves       Ménez                 <NA>     <NA>
# 1593   krg      Fajar Fatoni          86                 <NA>     <NA>
#
#                     Email           Phone                      Mobile  \
# 0       1114048930@gg.com   8617700612345                        <NA>
# 1      1952asir@gmail.com  91  9444951557   91 9654207066/ 9840095462
# 2      1952asir@gmail.com  91  9444951557   91 9654207066/ 9840095462
# 3     1971shail@gmail.com    919410072538                919410039697
# 4     1971shail@gmail.com    919410072538                919410039697
# ...                   ...             ...                         ...
# 1589                 <NA>            <NA>                        <NA>
# 1590                 <NA>            <NA>                        <NA>
# 1591                 <NA>            <NA>                        <NA>
# 1592                 <NA>            <NA>                        <NA>
# 1593                 <NA>            <NA>                        <NA>
#
#                                           AddressLine1 AddressLine2  ...  \
# 0                                                    -         <NA>  ...
# 1          No.9, Nehru Colony, Kamaraj Nagar P.O Avadi         <NA>  ...
# 2          No.9, Nehru Colony, Kamaraj Nagar P.O Avadi         <NA>  ...
# 3     87B, GURUDUWARA ROAD OFFICERS ACCOMMODATION CAMP         <NA>  ...
# 4     87B, GURUDUWARA ROAD OFFICERS ACCOMMODATION CAMP         <NA>  ...
# ...                                                ...          ...  ...
# 1589                                              <NA>         <NA>  ...
# 1590                                                 .            .  ...
# 1591                                                 -         <NA>  ...
# 1592                                                 -         <NA>  ...
# 1593                                              <NA>         <NA>  ...
#
#               CheckInDate         CheckOutDate    room  \
# 0     2024-09-04 11:09:07  2024-09-05 16:19:54  33 - N
# 1     2024-09-06 01:36:04  2024-09-07 13:03:15     403
# 2     2024-09-06 01:36:29  2024-09-07 13:03:23     404
# 3     2024-09-05 05:02:06  2024-09-07 15:32:07       8
# 4     2024-09-05 05:02:07  2024-09-07 15:32:08      10
# ...                   ...                  ...     ...
# 1589  2024-08-31 23:20:39  2024-09-07 16:31:11     115
# 1590  2024-09-07 07:24:00  2024-09-07 16:40:28     232
# 1591  2024-09-02 23:06:13  2024-09-08 14:18:19     224
# 1592  2024-09-08 05:11:42  2024-09-08 18:07:36     225
# 1593                 <NA>                 <NA>    <NA>
#
#                         UnitCategory BookingNo BookingSourceDesc  \
# 0     3 Bedroom Garden View Pool Vil   2607795    Hotel Bookings
# 1                Hotel Unit max 1ch.   2611823         KC Member
# 2                Hotel Unit max 1ch.   2611828         KC Member
# 3                      Heritage Room   2410627         KC Member
# 4                      Heritage Room   2410630         KC Member
# ...                              ...       ...               ...
# 1589             2 Bedroom Apartment   2426738    Hotel Bookings
# 1590                Studio Apartment   2616696    Hotel Bookings
# 1591             1 Bedroom Apartment   2593675    Hotel Bookings
# 1592             1 Bedroom Apartment   2617233    Hotel Bookings
# 1593                            <NA>      <NA>              <NA>
#
#          BookingTypeDesc Date of Tour Sales Rep and Comments Opt In
# 0        Nakula - Rental         <NA>                   <NA>    YES
# 1     Entitlement Member         <NA>                   <NA>    YES
# 2     Entitlement Member         <NA>                   <NA>    YES
# 3     Entitlement Member         <NA>                   <NA>    YES
# 4     Entitlement Member         <NA>                   <NA>    YES
# ...                  ...          ...                    ...    ...
# 1589      Wyndham Guests         <NA>                   <NA>    YES
# 1590         Booking.com         <NA>                   <NA>    YES
# 1591      Wyndham Guests         <NA>                   <NA>    YES
# 1592         Booking.com         <NA>                   <NA>    YES
# 1593                <NA>         <NA>                   <NA>   <NA>
#
# [1594 rows x 29 columns]

# %%
df_viewpoint.columns
# Out:
# Index(['Title', 'Firstname', 'lastname', 'DOB', 'PAN CARD', 'Email', 'Phone',
#        'Mobile', 'AddressLine1', 'AddressLine2', 'Town', 'State', 'Country',
#        'PostCode', 'Nationality', 'MaritalStatus', 'resortname', 'Arrival',
#        'Departure', 'CheckInDate', 'CheckOutDate', 'room', 'UnitCategory',
#        'BookingNo', 'BookingSourceDesc', 'BookingTypeDesc', 'Date of Tour',
#        'Sales Rep and Comments', 'Opt In'],
#       dtype='object')

# %%
df_viewpoint.fillna('empty', inplace=True)

df_viewpoint['Contact Type'] = 'empty'
df_viewpoint['Odyssey Members'] = 'NO'

df_viewpoint['Lead Brand'] = 'Karma Resorts'
df_viewpoint['Lead Sub-Brand'] = 'Other'
df_viewpoint['Lead Source'] = 'Past Guests'
df_viewpoint['Lead Locations'] = df_viewpoint['resortname']
df_viewpoint['Lead Source Description'] = 'Viewpoint'

# %%
df_viewpoint.loc[df_viewpoint['Opt In'] == 'YES', 'Exclude From Mailing'] = 'NO'
df_viewpoint.loc[df_viewpoint['Opt In'] == 'NO', 'Exclude From Mailing'] = 'YES'

# %%
df_viewpoint.loc[df_viewpoint['lastname'] == 'empty', 'lastname'] = '-'

# %%
df_viewpoint['Title'].replace('empty', '', inplace=True)
df_viewpoint['Firstname'].replace('empty', '', inplace=True)
df_viewpoint['lastname'].replace('empty', '', inplace=True)

df_viewpoint['Title'] = df_viewpoint['Title'].str.title()
df_viewpoint['Firstname'] = df_viewpoint['Firstname'].str.title()
df_viewpoint['lastname'] = df_viewpoint['lastname'].str.title()

df_viewpoint
# Out:
#      Title         Firstname    lastname                  DOB PAN CARD  \
# 0       Mr              Xing        Qian                empty    empty
# 1       Mr                S.  Asirvatham                empty    empty
# 2       Mr                S.  Asirvatham                empty    empty
# 3       Mr  Shailendra Kumar     Choubey  1971-12-10 00:00:00    empty
# 4       Mr  Shailendra Kumar     Choubey  1971-12-10 00:00:00    empty
# ...    ...               ...         ...                  ...      ...
# 1589            Waller, Paul           -                empty    empty
# 1590                  Oceane     Cormier                empty    empty
# 1591     -              Greg     Ramirez                empty    empty
# 1592     -              Yves       Ménez                empty    empty
# 1593   Krg      Fajar Fatoni          86                empty    empty
#
#                     Email           Phone                      Mobile  \
# 0       1114048930@gg.com   8617700612345                       empty
# 1      1952asir@gmail.com  91  9444951557   91 9654207066/ 9840095462
# 2      1952asir@gmail.com  91  9444951557   91 9654207066/ 9840095462
# 3     1971shail@gmail.com    919410072538                919410039697
# 4     1971shail@gmail.com    919410072538                919410039697
# ...                   ...             ...                         ...
# 1589                empty           empty                       empty
# 1590                empty           empty                       empty
# 1591                empty           empty                       empty
# 1592                empty           empty                       empty
# 1593                empty           empty                       empty
#
#                                           AddressLine1 AddressLine2  ...  \
# 0                                                    -        empty  ...
# 1          No.9, Nehru Colony, Kamaraj Nagar P.O Avadi        empty  ...
# 2          No.9, Nehru Colony, Kamaraj Nagar P.O Avadi        empty  ...
# 3     87B, GURUDUWARA ROAD OFFICERS ACCOMMODATION CAMP        empty  ...
# 4     87B, GURUDUWARA ROAD OFFICERS ACCOMMODATION CAMP        empty  ...
# ...                                                ...          ...  ...
# 1589                                             empty        empty  ...
# 1590                                                 .            .  ...
# 1591                                                 -        empty  ...
# 1592                                                 -        empty  ...
# 1593                                             empty        empty  ...
#
#      Sales Rep and Comments Opt In Contact Type Odyssey Members  \
# 0                     empty    YES        empty              NO
# 1                     empty    YES        empty              NO
# 2                     empty    YES        empty              NO
# 3                     empty    YES        empty              NO
# 4                     empty    YES        empty              NO
# ...                     ...    ...          ...             ...
# 1589                  empty    YES        empty              NO
# 1590                  empty    YES        empty              NO
# 1591                  empty    YES        empty              NO
# 1592                  empty    YES        empty              NO
# 1593                  empty  empty        empty              NO
#
#          Lead Brand Lead Sub-Brand  Lead Source  \
# 0     Karma Resorts          Other  Past Guests
# 1     Karma Resorts          Other  Past Guests
# 2     Karma Resorts          Other  Past Guests
# 3     Karma Resorts          Other  Past Guests
# 4     Karma Resorts          Other  Past Guests
# ...             ...            ...          ...
# 1589  Karma Resorts          Other  Past Guests
# 1590  Karma Resorts          Other  Past Guests
# 1591  Karma Resorts          Other  Past Guests
# 1592  Karma Resorts          Other  Past Guests
# 1593  Karma Resorts          Other  Past Guests
#
#                          Lead Locations Lead Source Description  \
# 0                        Karma Jimbaran               Viewpoint
# 1                  Karma Munnar, Kerala               Viewpoint
# 2                  Karma Munnar, Kerala               Viewpoint
# 3                Karma Lake of Menteith               Viewpoint
# 4                Karma Lake of Menteith               Viewpoint
# ...                                 ...                     ...
# 1589  Wyndham -  Manoir des Deux Amants               Viewpoint
# 1590  Wyndham -  Manoir des Deux Amants               Viewpoint
# 1591  Wyndham -  Manoir des Deux Amants               Viewpoint
# 1592  Wyndham -  Manoir des Deux Amants               Viewpoint
# 1593                              empty               Viewpoint
#
#      Exclude From Mailing
# 0                      NO
# 1                      NO
# 2                      NO
# 3                      NO
# 4                      NO
# ...                   ...
# 1589                   NO
# 1590                   NO
# 1591                   NO
# 1592                   NO
# 1593                  NaN
#
# [1594 rows x 37 columns]

# %%
m.clean_number(df_viewpoint, 'Phone')
m.clean_number(df_viewpoint, 'Mobile')
m.replace_not_valid_to_empty(df_viewpoint, 'Phone')
m.replace_not_valid_to_empty(df_viewpoint, 'Mobile')

df_viewpoint.loc[df_viewpoint['Phone'].str.contains('00000'), 'Phone'] = 'empty'
df_viewpoint.loc[df_viewpoint['Mobile'].str.contains('00000'), 'Mobile'] = 'empty'

m.clean_space(df_viewpoint, 'Email')
df_viewpoint['Email'] = m.lowercase(df_viewpoint, 'Email')

# %%
pm.email_correction(df_viewpoint, 'Email')

# %%
df_viewpoint.loc[(df_viewpoint['Email'] != 'empty') & ((df_viewpoint['Phone'] != 'empty') | (df_viewpoint['Mobile'] != 'empty')), 'Contact Type'] = 'Email and Phone'
df_viewpoint.loc[(df_viewpoint['Email'] != 'empty') & ((df_viewpoint['Phone'] == 'empty') & (df_viewpoint['Mobile'] == 'empty')), 'Contact Type'] = 'Email Only'
df_viewpoint.loc[(df_viewpoint['Email'] == 'empty') & ((df_viewpoint['Phone'] != 'empty') | (df_viewpoint['Mobile'] != 'empty')), 'Contact Type'] = 'Phone Only'

df_viewpoint.loc[df_viewpoint['Contact Type'] == 'empty'].to_csv(r'C:\Users\fajar\Documents\Python\Data\contact_type_empty_viewpoint.csv', index=False)

count_contact_type_empty = df_viewpoint.loc[df_viewpoint['Contact Type'] == 'empty'].shape[0]

df_viewpoint.drop(df_viewpoint.loc[df_viewpoint['Contact Type'] == 'empty'].index, inplace=True)
df_viewpoint.reset_index(drop=True, inplace=True)

count_after_contact_type_empty = df_viewpoint.shape[0]

df_viewpoint
# Out:
#      Title         Firstname    lastname                  DOB PAN CARD  \
# 0       Mr              Xing        Qian                empty    empty
# 1       Mr                S.  Asirvatham                empty    empty
# 2       Mr                S.  Asirvatham                empty    empty
# 3       Mr  Shailendra Kumar     Choubey  1971-12-10 00:00:00    empty
# 4       Mr  Shailendra Kumar     Choubey  1971-12-10 00:00:00    empty
# ...    ...               ...         ...                  ...      ...
# 1501    Ms   Parishma Suresh     Gaikwad                empty    empty
# 1502    Mr            Stuart       Baird                empty    empty
# 1503   Mrs         Elizaveta      Elkina  1982-09-08 00:00:00    empty
# 1504   Mrs         Elizaveta      Elkina  1982-09-08 00:00:00    empty
# 1505                Stephane      Varray                empty    empty
#
#                     Email          Phone                  Mobile  \
# 0       1114048930@gg.com  8617700612345                   empty
# 1      1952asir@gmail.com   919444951557  9196542070669840095462
# 2      1952asir@gmail.com   919444951557  9196542070669840095462
# 3     1971shail@gmail.com   919410072538            919410039697
# 4     1971shail@gmail.com   919410072538            919410039697
# ...                   ...            ...                     ...
# 1501                empty   917038614104                   empty
# 1502                empty   441709709850                   empty
# 1503                empty    79647171339                   empty
# 1504                empty    79647171339                   empty
# 1505                empty    41798125679                   empty
#
#                                           AddressLine1  AddressLine2  ...  \
# 0                                                    -         empty  ...
# 1          No.9, Nehru Colony, Kamaraj Nagar P.O Avadi         empty  ...
# 2          No.9, Nehru Colony, Kamaraj Nagar P.O Avadi         empty  ...
# 3     87B, GURUDUWARA ROAD OFFICERS ACCOMMODATION CAMP         empty  ...
# 4     87B, GURUDUWARA ROAD OFFICERS ACCOMMODATION CAMP         empty  ...
# ...                                                ...           ...  ...
# 1501                                                 -             -  ...
# 1502                                   7 PASTURE CROFT     THURCROFT  ...
# 1503                             ULITSA KOMITETSKI LES  18/1 APT 254  ...
# 1504                             ULITSA KOMITETSKI LES  18/1 APT 254  ...
# 1505                                                 .         empty  ...
#
#      Sales Rep and Comments Opt In     Contact Type Odyssey Members  \
# 0                     empty    YES  Email and Phone              NO
# 1                     empty    YES  Email and Phone              NO
# 2                     empty    YES  Email and Phone              NO
# 3                     empty    YES  Email and Phone              NO
# 4                     empty    YES  Email and Phone              NO
# ...                     ...    ...              ...             ...
# 1501                  empty    YES       Phone Only              NO
# 1502                  empty     NO       Phone Only              NO
# 1503                  JIMMY    YES       Phone Only              NO
# 1504                  empty    YES       Phone Only              NO
# 1505                  empty    YES       Phone Only              NO
#
#          Lead Brand Lead Sub-Brand  Lead Source  \
# 0     Karma Resorts          Other  Past Guests
# 1     Karma Resorts          Other  Past Guests
# 2     Karma Resorts          Other  Past Guests
# 3     Karma Resorts          Other  Past Guests
# 4     Karma Resorts          Other  Past Guests
# ...             ...            ...          ...
# 1501  Karma Resorts          Other  Past Guests
# 1502  Karma Resorts          Other  Past Guests
# 1503  Karma Resorts          Other  Past Guests
# 1504  Karma Resorts          Other  Past Guests
# 1505  Karma Resorts          Other  Past Guests
#
#                                Lead Locations Lead Source Description  \
# 0                              Karma Jimbaran               Viewpoint
# 1                        Karma Munnar, Kerala               Viewpoint
# 2                        Karma Munnar, Kerala               Viewpoint
# 3                      Karma Lake of Menteith               Viewpoint
# 4                      Karma Lake of Menteith               Viewpoint
# ...                                       ...                     ...
# 1501                     Karma Royal Monterio               Viewpoint
# 1502                       Karma Salford Hall               Viewpoint
# 1503  KRR @ Karma Kandara, Mentari Residences               Viewpoint
# 1504             KRR @ Karma Kandara, Phase V               Viewpoint
# 1505        Wyndham -  Manoir des Deux Amants               Viewpoint
#
#      Exclude From Mailing
# 0                      NO
# 1                      NO
# 2                      NO
# 3                      NO
# 4                      NO
# ...                   ...
# 1501                   NO
# 1502                  YES
# 1503                   NO
# 1504                   NO
# 1505                   NO
#
# [1506 rows x 37 columns]

# %%
# Cek Email Karma
email_karma = m.find_karma(df_viewpoint, 'Email')
count_email_karma = email_karma.shape[0]
email_karma.to_csv(r'C:\Users\fajar\Documents\Python\Data\email_deleted_viewpoint.csv', index=False)

email_karma
# Out:
#      Title           Firstname              lastname    DOB PAN CARD  \
# 308     Ms              Tahlia                Hadson  empty    empty
# 395     Ms           Esperanca              Patricio  empty    empty
# 396     Ms           Esperanca              Patricio  empty    empty
# 542     Mr               James                 Casey  empty    empty
# 805      -  Maintenance Room -  Karma Royal Monterio  empty    empty
# 806      -  Maintenance Room -  Karma Royal Monterio  empty    empty
# 807      -  Maintenance Room -  Karma Royal Monterio  empty    empty
# 808      -  Maintenance Room -  Karma Royal Monterio  empty    empty
# 809      -  Maintenance Room -  Karma Royal Monterio  empty    empty
# 810      -  Maintenance Room -  Karma Royal Monterio  empty    empty
# 811     Mr              Milesh                 Chari  empty    empty
# 962     Mr              Pramod        Balasubramanya  empty    empty
# 963     Mr              Pramod        Balasubramanya  empty    empty
# 1054    Mr             Ricardo                Coppen  empty    empty
# 1055    Mr             Ricardo                Coppen  empty    empty
# 1166    Mr           Sebastian               Moeller  empty    empty
# 1201    Mr                Shiv                 Suman  empty    empty
# 1202    Mr                Shiv                 Suman  empty    empty
# 1407    Mr            Valerios             Koutsonis  empty    empty
#
#                                      Email          Phone        Mobile  \
# 308             davidhadson@karmagroup.com   626236341519         empty
# 395      esperanca.patricio@karmagroup.com   919921378384         empty
# 396      esperanca.patricio@karmagroup.com   919921378384         empty
# 542             james.casey@karmagroup.com          empty         empty
# 805              mr.asstfom@karmagroup.com   918326716200         empty
# 806              mr.asstfom@karmagroup.com   918326716200         empty
# 807              mr.asstfom@karmagroup.com   918326716200         empty
# 808              mr.asstfom@karmagroup.com   918326716200         empty
# 809              mr.asstfom@karmagroup.com   918326716200         empty
# 810              mr.asstfom@karmagroup.com   918326716200         empty
# 811                   mr.hk@karmagroup.com   918326716200  919175089732
# 962   pramod.balasubramanya@karmagroup.com   919538510610  919538510610
# 963   pramod.balasubramanya@karmagroup.com   919538510610  919538510610
# 1054         ricardo.coppen@karmagroup.com  6281213501888         empty
# 1055         ricardo.coppen@karmagroup.com  6281213501888         empty
# 1166      sebastian.moeller@karmagroup.com   491726802987         empty
# 1201            shivsuman.b@karmagroup.com   919325868122         empty
# 1202            shivsuman.b@karmagroup.com   919325868122         empty
# 1407     valerios.koutsonis@karmagroup.com          empty         empty
#
#                                AddressLine1         AddressLine2  ...  \
# 308                        C/- DAVID HADSON                empty  ...
# 395                      CAVELOSSIM, MOBOR,                    .  ...
# 396                      CAVELOSSIM, MOBOR,                    .  ...
# 542   Jl. By Pass Ngurah Rai No.61, Pemogan  Kec. Denpasar Sel.,  ...
# 805                    karma royal monetrio               Arpora  ...
# 806                    karma royal monetrio               Arpora  ...
# 807                    karma royal monetrio               Arpora  ...
# 808                    karma royal monetrio               Arpora  ...
# 809                    karma royal monetrio               Arpora  ...
# 810                    karma royal monetrio               Arpora  ...
# 811                    Karma Royal Monterio     Arpora Baga Road  ...
# 962                                       -                    -  ...
# 963                                       -                    -  ...
# 1054       JL. KARTIKA PLAZA 90A & B, TUBAN                empty  ...
# 1055       JL. KARTIKA PLAZA 90A & B, TUBAN                empty  ...
# 1166    Schulenburgring 126, D-12101 Berlin                    -  ...
# 1201                                      -                    -  ...
# 1202                                      -                    -  ...
# 1407                                 France                empty  ...
#
#      Sales Rep and Comments Opt In     Contact Type Odyssey Members  \
# 308                   empty    YES  Email and Phone              NO
# 395                   empty    YES  Email and Phone              NO
# 396                   empty    YES  Email and Phone              NO
# 542                   empty    YES       Email Only              NO
# 805                   empty    YES  Email and Phone              NO
# 806                   empty    YES  Email and Phone              NO
# 807                   empty    YES  Email and Phone              NO
# 808                   empty    YES  Email and Phone              NO
# 809                   empty    YES  Email and Phone              NO
# 810                   empty    YES  Email and Phone              NO
# 811                   empty    YES  Email and Phone              NO
# 962                   empty    YES  Email and Phone              NO
# 963                   empty    YES  Email and Phone              NO
# 1054                  empty    YES  Email and Phone              NO
# 1055                  empty    YES  Email and Phone              NO
# 1166                  empty    YES  Email and Phone              NO
# 1201                  empty    YES  Email and Phone              NO
# 1202                  empty    YES  Email and Phone              NO
# 1407                  empty    YES       Email Only              NO
#
#          Lead Brand Lead Sub-Brand  Lead Source                Lead Locations  \
# 308   Karma Resorts          Other  Past Guests  KRR @ Karma Kandara, Phase V
# 395   Karma Resorts          Other  Past Guests      Karma Royal Haathi Mahal
# 396   Karma Resorts          Other  Past Guests      Karma Royal Haathi Mahal
# 542   Karma Resorts          Other  Past Guests               Karma Song Hoai
# 805   Karma Resorts          Other  Past Guests          Karma Royal Monterio
# 806   Karma Resorts          Other  Past Guests          Karma Royal Monterio
# 807   Karma Resorts          Other  Past Guests          Karma Royal Monterio
# 808   Karma Resorts          Other  Past Guests          Karma Royal Monterio
# 809   Karma Resorts          Other  Past Guests          Karma Royal Monterio
# 810   Karma Resorts          Other  Past Guests          Karma Royal Monterio
# 811   Karma Resorts          Other  Past Guests          Karma Royal Monterio
# 962   Karma Resorts          Other  Past Guests          Karma Royal Monterio
# 963   Karma Resorts          Other  Past Guests          Karma Royal Monterio
# 1054  Karma Resorts          Other  Past Guests                 Karma Bavaria
# 1055  Karma Resorts          Other  Past Guests            Karma Salford Hall
# 1166  Karma Resorts          Other  Past Guests      Karma Royal Haathi Mahal
# 1201  Karma Resorts          Other  Past Guests          Karma Royal Monterio
# 1202  Karma Resorts          Other  Past Guests          Karma Royal Monterio
# 1407  Karma Resorts          Other  Past Guests      Karma Royal Haathi Mahal
#
#      Lead Source Description Exclude From Mailing
# 308                Viewpoint                   NO
# 395                Viewpoint                   NO
# 396                Viewpoint                   NO
# 542                Viewpoint                   NO
# 805                Viewpoint                   NO
# 806                Viewpoint                   NO
# 807                Viewpoint                   NO
# 808                Viewpoint                   NO
# 809                Viewpoint                   NO
# 810                Viewpoint                   NO
# 811                Viewpoint                   NO
# 962                Viewpoint                   NO
# 963                Viewpoint                   NO
# 1054               Viewpoint                   NO
# 1055               Viewpoint                   NO
# 1166               Viewpoint                   NO
# 1201               Viewpoint                   NO
# 1202               Viewpoint                   NO
# 1407               Viewpoint                   NO
#
# [19 rows x 37 columns]

# %%
# delete email Karma
count_after_clean_karma = m.delete_karma(df_viewpoint, 'Email')

df_viewpoint
# Out:
#      Title         Firstname    lastname                  DOB PAN CARD  \
# 0       Mr              Xing        Qian                empty    empty
# 1       Mr                S.  Asirvatham                empty    empty
# 2       Mr                S.  Asirvatham                empty    empty
# 3       Mr  Shailendra Kumar     Choubey  1971-12-10 00:00:00    empty
# 4       Mr  Shailendra Kumar     Choubey  1971-12-10 00:00:00    empty
# ...    ...               ...         ...                  ...      ...
# 1482    Ms   Parishma Suresh     Gaikwad                empty    empty
# 1483    Mr            Stuart       Baird                empty    empty
# 1484   Mrs         Elizaveta      Elkina  1982-09-08 00:00:00    empty
# 1485   Mrs         Elizaveta      Elkina  1982-09-08 00:00:00    empty
# 1486                Stephane      Varray                empty    empty
#
#                     Email          Phone                  Mobile  \
# 0       1114048930@gg.com  8617700612345                   empty
# 1      1952asir@gmail.com   919444951557  9196542070669840095462
# 2      1952asir@gmail.com   919444951557  9196542070669840095462
# 3     1971shail@gmail.com   919410072538            919410039697
# 4     1971shail@gmail.com   919410072538            919410039697
# ...                   ...            ...                     ...
# 1482                empty   917038614104                   empty
# 1483                empty   441709709850                   empty
# 1484                empty    79647171339                   empty
# 1485                empty    79647171339                   empty
# 1486                empty    41798125679                   empty
#
#                                           AddressLine1  AddressLine2  ...  \
# 0                                                    -         empty  ...
# 1          No.9, Nehru Colony, Kamaraj Nagar P.O Avadi         empty  ...
# 2          No.9, Nehru Colony, Kamaraj Nagar P.O Avadi         empty  ...
# 3     87B, GURUDUWARA ROAD OFFICERS ACCOMMODATION CAMP         empty  ...
# 4     87B, GURUDUWARA ROAD OFFICERS ACCOMMODATION CAMP         empty  ...
# ...                                                ...           ...  ...
# 1482                                                 -             -  ...
# 1483                                   7 PASTURE CROFT     THURCROFT  ...
# 1484                             ULITSA KOMITETSKI LES  18/1 APT 254  ...
# 1485                             ULITSA KOMITETSKI LES  18/1 APT 254  ...
# 1486                                                 .         empty  ...
#
#      Sales Rep and Comments Opt In     Contact Type Odyssey Members  \
# 0                     empty    YES  Email and Phone              NO
# 1                     empty    YES  Email and Phone              NO
# 2                     empty    YES  Email and Phone              NO
# 3                     empty    YES  Email and Phone              NO
# 4                     empty    YES  Email and Phone              NO
# ...                     ...    ...              ...             ...
# 1482                  empty    YES       Phone Only              NO
# 1483                  empty     NO       Phone Only              NO
# 1484                  JIMMY    YES       Phone Only              NO
# 1485                  empty    YES       Phone Only              NO
# 1486                  empty    YES       Phone Only              NO
#
#          Lead Brand Lead Sub-Brand  Lead Source  \
# 0     Karma Resorts          Other  Past Guests
# 1     Karma Resorts          Other  Past Guests
# 2     Karma Resorts          Other  Past Guests
# 3     Karma Resorts          Other  Past Guests
# 4     Karma Resorts          Other  Past Guests
# ...             ...            ...          ...
# 1482  Karma Resorts          Other  Past Guests
# 1483  Karma Resorts          Other  Past Guests
# 1484  Karma Resorts          Other  Past Guests
# 1485  Karma Resorts          Other  Past Guests
# 1486  Karma Resorts          Other  Past Guests
#
#                                Lead Locations Lead Source Description  \
# 0                              Karma Jimbaran               Viewpoint
# 1                        Karma Munnar, Kerala               Viewpoint
# 2                        Karma Munnar, Kerala               Viewpoint
# 3                      Karma Lake of Menteith               Viewpoint
# 4                      Karma Lake of Menteith               Viewpoint
# ...                                       ...                     ...
# 1482                     Karma Royal Monterio               Viewpoint
# 1483                       Karma Salford Hall               Viewpoint
# 1484  KRR @ Karma Kandara, Mentari Residences               Viewpoint
# 1485             KRR @ Karma Kandara, Phase V               Viewpoint
# 1486        Wyndham -  Manoir des Deux Amants               Viewpoint
#
#      Exclude From Mailing
# 0                      NO
# 1                      NO
# 2                      NO
# 3                      NO
# 4                      NO
# ...                   ...
# 1482                   NO
# 1483                  YES
# 1484                   NO
# 1485                   NO
# 1486                   NO
#
# [1487 rows x 37 columns]

# %%
# Cek leads test
test_leads = df_viewpoint.loc[
    
        df_viewpoint['Email'].str.contains('^test@', flags=re.I, regex=True) |
        df_viewpoint['Email'].str.contains('\+test', flags=re.I, regex=True) |
    
        df_viewpoint['Firstname'].str.contains('^test$', flags=re.I, regex=True) |
        df_viewpoint['lastname'].str.contains('^test$', flags=re.I, regex=True) |

        df_viewpoint['Firstname'].str.contains('test 1', flags=re.I, regex=True) |
        df_viewpoint['lastname'].str.contains('test 2', flags=re.I, regex=True)|
        df_viewpoint['Firstname'].str.contains('test1', flags=re.I, regex=True) |
        df_viewpoint['lastname'].str.contains('test2', flags=re.I, regex=True)|

        df_viewpoint['Firstname'].str.contains(' test ', flags=re.I, regex=True) | 
        df_viewpoint['lastname'].str.contains(' test ', flags=re.I, regex=True) | 
        df_viewpoint['lastname'].str.contains(' test$', flags=re.I, regex=True)
    ]

count_leads_test = test_leads.shape[0]

test_leads.to_csv(r'C:\Users\fajar\Documents\Python\Data\test_leads_viewpoint.csv', index=False)
test_leads
# Out:
#      Title          Firstname lastname                  DOB PAN CARD  \
# 1339   Mrs  Sumana Vishwanath   Tantry  1964-09-03 00:00:00    empty
#
#               Email  Phone Mobile                   AddressLine1 AddressLine2  \
# 1339  test@test.com  empty  empty  KRISHNA, 5/14/1319 MANNAGUDDA        empty
#
#       ... Sales Rep and Comments Opt In Contact Type Odyssey Members  \
# 1339  ...                  empty    YES   Email Only              NO
#
#          Lead Brand Lead Sub-Brand  Lead Source            Lead Locations  \
# 1339  Karma Resorts          Other  Past Guests  Karma Royal Haathi Mahal
#
#      Lead Source Description Exclude From Mailing
# 1339               Viewpoint                   NO
#
# [1 rows x 37 columns]

# %%
df_viewpoint.drop(test_leads.index, inplace=True)
df_viewpoint.reset_index(drop=True, inplace=True)

count_after_dedup_test = df_viewpoint.shape[0]
count_after_dedup_test
# Out:
# 1486

# %%
count_final_data = count_after_dedup_test

# %%
# df_viewpoint.loc[df_viewpoint['BookingNo'] == '2070341']

# %%
df_viewpoint.replace('empty', '', inplace=True)

# %%
print("==========================================================")
print("Summary")
print("==========================================================")
print("Jumlah Data Awal Viewpoint : "+str(count_data_awal))
print("Jumlah Data Email dan Phone Kosong : "+str(count_contact_type_empty))
print("Jumlah Data Setelah Hapus Email dan Phone Yang Kosong : "+str(count_after_contact_type_empty))
print("Jumlah Data Email Yang Termasuk List Karma : "+str(count_email_karma))
print("Jumlah Data Email Setelah List Karma Dihapus : "+str(count_after_clean_karma))
print("Jumlah Data Test : "+str(count_leads_test))
print("Jumlah Data Email Setelah Data Test Dihapus : "+str(count_after_dedup_test))
print("Jumlah Data Akhir : "+str(count_final_data))
# Out:
# ==========================================================
# Summary
# ==========================================================
# Jumlah Data Awal Viewpoint : 1594
# Jumlah Data Email dan Phone Kosong : 88
# Jumlah Data Setelah Hapus Email dan Phone Yang Kosong : 1506
# Jumlah Data Email Yang Termasuk List Karma : 19
# Jumlah Data Email Setelah List Karma Dihapus : 1487
# Jumlah Data Test : 1
# Jumlah Data Email Setelah Data Test Dihapus : 1486
# Jumlah Data Akhir : 1486

# %%
df_viewpoint.to_excel(r'C:\Users\fajar\Documents\Python\Data\check_country_code_viewpoint.xlsx', index=False)
