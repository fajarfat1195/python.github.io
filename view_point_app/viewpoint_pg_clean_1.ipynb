# %%
import pandas as pd
import re

import past_guest_module as pm

import sys
sys.path.append('../zoho_data_app/')

import main_module as m

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
path = r'C:\Users\fajar\Documents\Python\Data\Past Guest Data\View Point\2024\Sep\8 Sep - 13 Sep\CheckOutReport 8 Sep - 13 Sep.xlsx'
df_viewpoint = pd.read_excel(path, dtype='string', sheet_name='Sheet1')
count_data_awal = df_viewpoint.shape[0]
df_viewpoint
# Out:
#     Title          Firstname  lastname                  DOB  \
# 0      Mr  Jayant Dattatraya      Kale  1965-03-27 00:00:00
# 1      Mr       Rizwan Ahmed   Shariff  1975-09-18 00:00:00
# 2      Mr                MIN         /                 <NA>
# 3      Mr             Andrew     Rands                 <NA>
# 4      Mr              JITIN      JAIN  1980-02-14 00:00:00
# ..    ...                ...       ...                  ...
# 977  <NA>          Sebastien    Beuque                 <NA>
# 978  <NA>             Xavier      LABE                 <NA>
# 979     -          ELIZABETH      BATY                 <NA>
# 980  <NA>             Nikzad  Dehghani                 <NA>
# 981   krg       Fajar Fatoni        86                 <NA>
#
#                              PAN CARD                     Email  \
# 0    ADNPK2360D,ADNPK2360D,ADNPK2360D       27.jayant@gmail.com
# 1                          BVDPS8513D        786riz05@gmail.com
# 2                                <NA>          910354281@gg.com
# 3                                <NA>           a.rands@mac.com
# 4                                <NA>  AANCHALJAIN.AJ@GMAIL.COM
# ..                                ...                       ...
# 977                              <NA>                      <NA>
# 978                              <NA>                      <NA>
# 979                              <NA>                      <NA>
# 980                              <NA>                      <NA>
# 981                              <NA>                      <NA>
#
#              Phone        Mobile  \
# 0     919689930863          <NA>
# 1     919986406301  919535367296
# 2    8617872366331          <NA>
# 3      61438951450          <NA>
# 4     919810856000  919716867559
# ..             ...           ...
# 977           <NA>          <NA>
# 978           <NA>          <NA>
# 979           <NA>          <NA>
# 980           <NA>          <NA>
# 981           <NA>          <NA>
#
#                                           AddressLine1  \
# 0                                B - 32, SHIROLE BAUG,
# 1    Flat No. 002, Sunshine Apartment, East End 'd'...
# 2                                                    -
# 3                                         2 KIRRA ROAD
# 4                                           C-2 SECTOR
# ..                                                 ...
# 977                                                  -
# 978                                                  -
# 979                                                  -
# 980                                                  -
# 981                                               <NA>
#
#                         AddressLine2  ...          CheckInDate  \
# 0    GANESHKHIND ROAD, MODEL COLONY,  ...  2024-09-08 23:00:52
# 1              Jayanagar, 9th Block,  ...  2024-09-09 21:13:51
# 2                               <NA>  ...  2024-09-08 20:34:27
# 3                     SECRET HARBOUR  ...  2024-09-04 22:02:14
# 4                           50 NOIDA  ...  2024-09-07 21:18:43
# ..                               ...  ...                  ...
# 977                             <NA>  ...  2024-09-12 00:29:13
# 978                             <NA>  ...  2024-09-11 22:47:01
# 979                             <NA>  ...  2024-09-11 01:40:31
# 980                             <NA>  ...  2024-09-07 17:58:26
# 981                             <NA>  ...                 <NA>
#
#             CheckOutDate    room                    UnitCategory BookingNo  \
# 0    2024-09-11 19:21:37    V162            2 Bedroom Fractional   2591054
# 1    2024-09-09 21:14:01    V043            1 Bedroom Fractional   2618379
# 2    2024-09-10 15:02:03  07 - N  3 Bedroom Garden View Pool Vil   2588545
# 3    2024-09-11 09:14:11   01-02           2 Bedroom Combination   2369818
# 4    2024-09-10 13:48:14     101           Non Member Hotel Unit   2603177
# ..                   ...     ...                             ...       ...
# 977  2024-09-12 13:40:41     225             1 Bedroom Apartment   2620955
# 978  2024-09-12 15:58:49     234             1 Bedroom Apartment   2619799
# 979  2024-09-12 16:10:57     114             1 Bedroom Apartment   2412235
# 980  2024-09-12 16:20:49     202             1 Bedroom Apartment   2617088
# 981                 <NA>    <NA>                            <NA>      <NA>
#
#     BookingSourceDesc            BookingTypeDesc         Date of Tour  \
# 0           KC Member                 Sales Gift  2024-09-11 10:56:00
# 1           KC Member  Complimentary Booking FOC                 <NA>
# 2      Hotel Bookings            Nakula - Rental                 <NA>
# 3           KC Member         Entitlement Member  2024-09-11 17:41:00
# 4      Fly Buy Indian     Karma Experience India  2024-09-08 10:30:00
# ..                ...                        ...                  ...
# 977    Hotel Bookings                Booking.com                 <NA>
# 978    Hotel Bookings                Booking.com                 <NA>
# 979    Hotel Bookings             Wyndham Guests                 <NA>
# 980     Resort Rental              Resort Rental                 <NA>
# 981              <NA>                       <NA>                 <NA>
#
#     Sales Rep and Comments Opt In
# 0                   Shifah    YES
# 1                     <NA>    YES
# 2                     <NA>    YES
# 3                    RAFIK    YES
# 4             DARSHIT SHAH    YES
# ..                     ...    ...
# 977                   <NA>    YES
# 978                   <NA>    YES
# 979                   <NA>    YES
# 980                   <NA>    YES
# 981                   <NA>   <NA>
#
# [982 rows x 29 columns]

# %%
df_viewpoint.columns
# Out:
# Index(['Title', 'Firstname', 'lastname', 'DOB', 'PAN CARD', 'Email', 'Phone',
#        'Mobile', 'AddressLine1', 'AddressLine2', 'Town', 'State', 'Country',
#        'PostCode', 'Nationality', 'MaritalStatus', 'resortname', 'Arrival',
#        'Departure', 'CheckInDate', 'CheckOutDate', 'room', 'UnitCategory',
#        'BookingNo', 'BookingSourceDesc', 'BookingTypeDesc', 'Date of Tour',
#        'Sales Rep and Comments', 'Opt In'],
#       dtype='object')

# %%
df_viewpoint.fillna('empty', inplace=True)

df_viewpoint['Contact Type'] = 'empty'
df_viewpoint['Odyssey Members'] = 'NO'

df_viewpoint['Lead Brand'] = 'Karma Resorts'
df_viewpoint['Lead Sub-Brand'] = 'Other'
df_viewpoint['Lead Source'] = 'Past Guests'
df_viewpoint['Lead Locations'] = df_viewpoint['resortname']
df_viewpoint['Lead Source Description'] = 'Viewpoint'

# %%
df_viewpoint.loc[df_viewpoint['Opt In'] == 'YES', 'Exclude From Mailing'] = 'NO'
df_viewpoint.loc[df_viewpoint['Opt In'] == 'NO', 'Exclude From Mailing'] = 'YES'

# %%
df_viewpoint.loc[df_viewpoint['lastname'] == 'empty', 'lastname'] = '-'

# %%
df_viewpoint['Title'].replace('empty', '', inplace=True)
df_viewpoint['Firstname'].replace('empty', '', inplace=True)
df_viewpoint['lastname'].replace('empty', '', inplace=True)

df_viewpoint['Title'] = df_viewpoint['Title'].str.title()
df_viewpoint['Firstname'] = df_viewpoint['Firstname'].str.title()
df_viewpoint['lastname'] = df_viewpoint['lastname'].str.title()

df_viewpoint
# Out:
#     Title          Firstname  lastname                  DOB  \
# 0      Mr  Jayant Dattatraya      Kale  1965-03-27 00:00:00
# 1      Mr       Rizwan Ahmed   Shariff  1975-09-18 00:00:00
# 2      Mr                Min         /                empty
# 3      Mr             Andrew     Rands                empty
# 4      Mr              Jitin      Jain  1980-02-14 00:00:00
# ..    ...                ...       ...                  ...
# 977                Sebastien    Beuque                empty
# 978                   Xavier      Labe                empty
# 979     -          Elizabeth      Baty                empty
# 980                   Nikzad  Dehghani                empty
# 981   Krg       Fajar Fatoni        86                empty
#
#                              PAN CARD                     Email  \
# 0    ADNPK2360D,ADNPK2360D,ADNPK2360D       27.jayant@gmail.com
# 1                          BVDPS8513D        786riz05@gmail.com
# 2                               empty          910354281@gg.com
# 3                               empty           a.rands@mac.com
# 4                               empty  AANCHALJAIN.AJ@GMAIL.COM
# ..                                ...                       ...
# 977                             empty                     empty
# 978                             empty                     empty
# 979                             empty                     empty
# 980                             empty                     empty
# 981                             empty                     empty
#
#              Phone        Mobile  \
# 0     919689930863         empty
# 1     919986406301  919535367296
# 2    8617872366331         empty
# 3      61438951450         empty
# 4     919810856000  919716867559
# ..             ...           ...
# 977          empty         empty
# 978          empty         empty
# 979          empty         empty
# 980          empty         empty
# 981          empty         empty
#
#                                           AddressLine1  \
# 0                                B - 32, SHIROLE BAUG,
# 1    Flat No. 002, Sunshine Apartment, East End 'd'...
# 2                                                    -
# 3                                         2 KIRRA ROAD
# 4                                           C-2 SECTOR
# ..                                                 ...
# 977                                                  -
# 978                                                  -
# 979                                                  -
# 980                                                  -
# 981                                              empty
#
#                         AddressLine2  ... Sales Rep and Comments Opt In  \
# 0    GANESHKHIND ROAD, MODEL COLONY,  ...                 Shifah    YES
# 1              Jayanagar, 9th Block,  ...                  empty    YES
# 2                              empty  ...                  empty    YES
# 3                     SECRET HARBOUR  ...                  RAFIK    YES
# 4                           50 NOIDA  ...           DARSHIT SHAH    YES
# ..                               ...  ...                    ...    ...
# 977                            empty  ...                  empty    YES
# 978                            empty  ...                  empty    YES
# 979                            empty  ...                  empty    YES
# 980                            empty  ...                  empty    YES
# 981                            empty  ...                  empty  empty
#
#     Contact Type Odyssey Members     Lead Brand Lead Sub-Brand  Lead Source  \
# 0          empty              NO  Karma Resorts          Other  Past Guests
# 1          empty              NO  Karma Resorts          Other  Past Guests
# 2          empty              NO  Karma Resorts          Other  Past Guests
# 3          empty              NO  Karma Resorts          Other  Past Guests
# 4          empty              NO  Karma Resorts          Other  Past Guests
# ..           ...             ...            ...            ...          ...
# 977        empty              NO  Karma Resorts          Other  Past Guests
# 978        empty              NO  Karma Resorts          Other  Past Guests
# 979        empty              NO  Karma Resorts          Other  Past Guests
# 980        empty              NO  Karma Resorts          Other  Past Guests
# 981        empty              NO  Karma Resorts          Other  Past Guests
#
#                         Lead Locations Lead Source Description  \
# 0             Karma Royal Haathi Mahal               Viewpoint
# 1             Karma Royal Haathi Mahal               Viewpoint
# 2                       Karma Jimbaran               Viewpoint
# 3                 Karma Royal Jimbaran               Viewpoint
# 4              Karma Sitabani, Corbett               Viewpoint
# ..                                 ...                     ...
# 977  Wyndham -  Manoir des Deux Amants               Viewpoint
# 978  Wyndham -  Manoir des Deux Amants               Viewpoint
# 979  Wyndham -  Manoir des Deux Amants               Viewpoint
# 980  Wyndham -  Manoir des Deux Amants               Viewpoint
# 981                              empty               Viewpoint
#
#     Exclude From Mailing
# 0                     NO
# 1                     NO
# 2                     NO
# 3                     NO
# 4                     NO
# ..                   ...
# 977                   NO
# 978                   NO
# 979                   NO
# 980                   NO
# 981                  NaN
#
# [982 rows x 37 columns]

# %%
m.clean_number(df_viewpoint, 'Phone')
m.clean_number(df_viewpoint, 'Mobile')
m.replace_not_valid_to_empty(df_viewpoint, 'Phone')
m.replace_not_valid_to_empty(df_viewpoint, 'Mobile')

df_viewpoint.loc[df_viewpoint['Phone'].str.contains('00000'), 'Phone'] = 'empty'
df_viewpoint.loc[df_viewpoint['Mobile'].str.contains('00000'), 'Mobile'] = 'empty'

m.clean_space(df_viewpoint, 'Email')
df_viewpoint['Email'] = m.lowercase(df_viewpoint, 'Email')

# %%
pm.email_correction(df_viewpoint, 'Email')

# %%
df_viewpoint.loc[(df_viewpoint['Email'] != 'empty') & ((df_viewpoint['Phone'] != 'empty') | (df_viewpoint['Mobile'] != 'empty')), 'Contact Type'] = 'Email and Phone'
df_viewpoint.loc[(df_viewpoint['Email'] != 'empty') & ((df_viewpoint['Phone'] == 'empty') & (df_viewpoint['Mobile'] == 'empty')), 'Contact Type'] = 'Email Only'
df_viewpoint.loc[(df_viewpoint['Email'] == 'empty') & ((df_viewpoint['Phone'] != 'empty') | (df_viewpoint['Mobile'] != 'empty')), 'Contact Type'] = 'Phone Only'

df_viewpoint.loc[df_viewpoint['Contact Type'] == 'empty'].to_csv(r'C:\Users\fajar\Documents\Python\Data\contact_type_empty_viewpoint.csv', index=False)

count_contact_type_empty = df_viewpoint.loc[df_viewpoint['Contact Type'] == 'empty'].shape[0]

df_viewpoint.drop(df_viewpoint.loc[df_viewpoint['Contact Type'] == 'empty'].index, inplace=True)
df_viewpoint.reset_index(drop=True, inplace=True)

count_after_contact_type_empty = df_viewpoint.shape[0]

df_viewpoint
# Out:
#     Title          Firstname  lastname                  DOB  \
# 0      Mr  Jayant Dattatraya      Kale  1965-03-27 00:00:00
# 1      Mr       Rizwan Ahmed   Shariff  1975-09-18 00:00:00
# 2      Mr                Min         /                empty
# 3      Mr             Andrew     Rands                empty
# 4      Mr              Jitin      Jain  1980-02-14 00:00:00
# ..    ...                ...       ...                  ...
# 920    Ms    Parishma Suresh   Gaikwad                empty
# 921    Ms      Alo Mukherjee    Veloso                empty
# 922    Ms             Bhavya    Mishra                empty
# 923    Mr             Aakash    Sharma  1993-07-04 00:00:00
# 924    Mr             Steven  Gonzales                empty
#
#                              PAN CARD                     Email  \
# 0    ADNPK2360D,ADNPK2360D,ADNPK2360D       27.jayant@gmail.com
# 1                          BVDPS8513D        786riz05@gmail.com
# 2                               empty          910354281@gg.com
# 3                               empty           a.rands@mac.com
# 4                               empty  aanchaljain.aj@gmail.com
# ..                                ...                       ...
# 920                             empty                     empty
# 921                             empty                     empty
# 922                             empty                     empty
# 923                             empty                     empty
# 924                             empty                     empty
#
#              Phone        Mobile  \
# 0     919689930863         empty
# 1     919986406301  919535367296
# 2    8617872366331         empty
# 3      61438951450         empty
# 4     919810856000  919716867559
# ..             ...           ...
# 920   917038614104         empty
# 921   919822142611         empty
# 922   919910178224         empty
# 923   919874421250         empty
# 924    61478032239   61478032239
#
#                                           AddressLine1  \
# 0                                B - 32, SHIROLE BAUG,
# 1    Flat No. 002, Sunshine Apartment, East End 'd'...
# 2                                                    -
# 3                                         2 KIRRA ROAD
# 4                                           C-2 SECTOR
# ..                                                 ...
# 920                                                  -
# 921                                                  -
# 922                         C-503, ROSEWOOD APARTMENTS
# 923                                  3, JANKI DAS LANE
# 924                                                 --
#
#                         AddressLine2  ... Sales Rep and Comments Opt In  \
# 0    GANESHKHIND ROAD, MODEL COLONY,  ...                 Shifah    YES
# 1              Jayanagar, 9th Block,  ...                  empty    YES
# 2                              empty  ...                  empty    YES
# 3                     SECRET HARBOUR  ...                  RAFIK    YES
# 4                           50 NOIDA  ...           DARSHIT SHAH    YES
# ..                               ...  ...                    ...    ...
# 920                                -  ...                  empty    YES
# 921                                -  ...                  empty    YES
# 922              MAYUR VIHAR-1 EXTN,  ...                  empty    YES
# 923                            empty  ...                  empty    YES
# 924                                -  ...                  empty    YES
#
#         Contact Type Odyssey Members     Lead Brand Lead Sub-Brand  \
# 0    Email and Phone              NO  Karma Resorts          Other
# 1    Email and Phone              NO  Karma Resorts          Other
# 2    Email and Phone              NO  Karma Resorts          Other
# 3    Email and Phone              NO  Karma Resorts          Other
# 4    Email and Phone              NO  Karma Resorts          Other
# ..               ...             ...            ...            ...
# 920       Phone Only              NO  Karma Resorts          Other
# 921       Phone Only              NO  Karma Resorts          Other
# 922       Phone Only              NO  Karma Resorts          Other
# 923       Phone Only              NO  Karma Resorts          Other
# 924       Phone Only              NO  Karma Resorts          Other
#
#      Lead Source                           Lead Locations  \
# 0    Past Guests                 Karma Royal Haathi Mahal
# 1    Past Guests                 Karma Royal Haathi Mahal
# 2    Past Guests                           Karma Jimbaran
# 3    Past Guests                     Karma Royal Jimbaran
# 4    Past Guests                  Karma Sitabani, Corbett
# ..           ...                                      ...
# 920  Past Guests                     Karma Royal Monterio
# 921  Past Guests                        Karma Royal Palms
# 922  Past Guests                        Karma Royal Palms
# 923  Past Guests                     Karma Utopia, Manali
# 924  Past Guests  KRR @ Karma Kandara, Mentari Residences
#
#     Lead Source Description Exclude From Mailing
# 0                 Viewpoint                   NO
# 1                 Viewpoint                   NO
# 2                 Viewpoint                   NO
# 3                 Viewpoint                   NO
# 4                 Viewpoint                   NO
# ..                      ...                  ...
# 920               Viewpoint                   NO
# 921               Viewpoint                   NO
# 922               Viewpoint                   NO
# 923               Viewpoint                   NO
# 924               Viewpoint                   NO
#
# [925 rows x 37 columns]

# %%
# Cek Email Karma
email_karma = m.find_karma(df_viewpoint, 'Email')
count_email_karma = email_karma.shape[0]
email_karma.to_csv(r'C:\Users\fajar\Documents\Python\Data\email_deleted_viewpoint.csv', index=False)

email_karma
# Out:
#     Title           Firstname              lastname                  DOB  \
# 123    Mr                 Ben             Robertson                empty
# 203    Mr               David                Hadson                empty
# 207    Mr               David             Scheckter  1970-06-11 00:00:00
# 208    Mr               David             Scheckter  1970-06-11 00:00:00
# 500     -  Maintenance Room -  Karma Royal Monterio                empty
# 501     -  Maintenance Room -  Karma Royal Monterio                empty
# 502     -  Maintenance Room -  Karma Royal Monterio                empty
# 503     -  Maintenance Room -  Karma Royal Monterio                empty
# 504     -  Maintenance Room -  Karma Royal Monterio                empty
# 603   Mrs              Pythia              Barretto                empty
# 650    Mr           Roosevelt             Fernandes  1978-06-28 00:00:00
# 651    Mr           Roosevelt             Fernandes  1978-06-28 00:00:00
# 652    Mr           Roosevelt             Fernandes  1978-06-28 00:00:00
# 660     -                Ruth                  Liew                empty
#
#     PAN CARD                               Email          Phone Mobile  \
# 123    empty        ben.robertson@karmagroup.com          empty  empty
# 203    empty         david.hadson@karmagroup.com   626236341519  empty
# 207    empty      david.scheckter@karmagroup.com   628113893039  empty
# 208    empty      david.scheckter@karmagroup.com   628113893039  empty
# 500    empty           mr.asstfom@karmagroup.com   918326716200  empty
# 501    empty           mr.asstfom@karmagroup.com   918326716200  empty
# 502    empty           mr.asstfom@karmagroup.com   918326716200  empty
# 503    empty           mr.asstfom@karmagroup.com   918326716200  empty
# 504    empty           mr.asstfom@karmagroup.com   918326716200  empty
# 603    empty      pythia.barretto@karmagroup.com          empty  empty
# 650    empty  roosevelt.fernandes@karmagroup.com  6281558822330  empty
# 651    empty  roosevelt.fernandes@karmagroup.com  6281558822330  empty
# 652    empty  roosevelt.fernandes@karmagroup.com  6281558822330  empty
# 660    empty            ruth.liew@karmagroup.com   971508626588  empty
#
#                                           AddressLine1 AddressLine2  ...  \
# 123                                                  -            -  ...
# 203                                       C/- IVO BALI        empty  ...
# 207                                               Bali        empty  ...
# 208                                               Bali        empty  ...
# 500                               karma royal monetrio       Arpora  ...
# 501                               karma royal monetrio       Arpora  ...
# 502                               karma royal monetrio       Arpora  ...
# 503                               karma royal monetrio       Arpora  ...
# 504                               karma royal monetrio       Arpora  ...
# 603                                                  .        empty  ...
# 650  Address is, Room no 7, Mamasu home stay, Gang ...        empty  ...
# 651  Address is, Room no 7, Mamasu home stay, Gang ...        empty  ...
# 652  Address is, Room no 7, Mamasu home stay, Gang ...        empty  ...
# 660                                                TBA        empty  ...
#
#     Sales Rep and Comments Opt In     Contact Type Odyssey Members  \
# 123                  empty    YES       Email Only              NO
# 203                  empty    YES  Email and Phone              NO
# 207                  empty    YES  Email and Phone              NO
# 208                  empty    YES  Email and Phone              NO
# 500                  empty    YES  Email and Phone              NO
# 501                  empty    YES  Email and Phone              NO
# 502                  empty    YES  Email and Phone              NO
# 503                  empty    YES  Email and Phone              NO
# 504                  empty    YES  Email and Phone              NO
# 603                  empty    YES       Email Only              NO
# 650                  empty    YES  Email and Phone              NO
# 651                  empty    YES  Email and Phone              NO
# 652                  empty    YES  Email and Phone              NO
# 660                  empty    YES  Email and Phone              NO
#
#         Lead Brand Lead Sub-Brand  Lead Source  \
# 123  Karma Resorts          Other  Past Guests
# 203  Karma Resorts          Other  Past Guests
# 207  Karma Resorts          Other  Past Guests
# 208  Karma Resorts          Other  Past Guests
# 500  Karma Resorts          Other  Past Guests
# 501  Karma Resorts          Other  Past Guests
# 502  Karma Resorts          Other  Past Guests
# 503  Karma Resorts          Other  Past Guests
# 504  Karma Resorts          Other  Past Guests
# 603  Karma Resorts          Other  Past Guests
# 650  Karma Resorts          Other  Past Guests
# 651  Karma Resorts          Other  Past Guests
# 652  Karma Resorts          Other  Past Guests
# 660  Karma Resorts          Other  Past Guests
#
#                               Lead Locations Lead Source Description  \
# 123                   Karma Bayon, Siam Reap               Viewpoint
# 203  KRR @ Karma Kandara, Mentari Residences               Viewpoint
# 207  KRR @ Karma Kandara, Mentari Residences               Viewpoint
# 208  KRR @ Karma Kandara, Mentari Residences               Viewpoint
# 500                     Karma Royal Monterio               Viewpoint
# 501                     Karma Royal Monterio               Viewpoint
# 502                     Karma Royal Monterio               Viewpoint
# 503                     Karma Royal Monterio               Viewpoint
# 504                     Karma Royal Monterio               Viewpoint
# 603                 Karma Royal Haathi Mahal               Viewpoint
# 650             KRR @ Karma Kandara, Phase V               Viewpoint
# 651             KRR @ Karma Kandara, Phase V               Viewpoint
# 652             KRR @ Karma Kandara, Phase V               Viewpoint
# 660  KRR @ Karma Kandara, Mentari Residences               Viewpoint
#
#     Exclude From Mailing
# 123                   NO
# 203                   NO
# 207                   NO
# 208                   NO
# 500                   NO
# 501                   NO
# 502                   NO
# 503                   NO
# 504                   NO
# 603                   NO
# 650                   NO
# 651                   NO
# 652                   NO
# 660                   NO
#
# [14 rows x 37 columns]

# %%
# delete email Karma
count_after_clean_karma = m.delete_karma(df_viewpoint, 'Email')

df_viewpoint
# Out:
#     Title          Firstname  lastname                  DOB  \
# 0      Mr  Jayant Dattatraya      Kale  1965-03-27 00:00:00
# 1      Mr       Rizwan Ahmed   Shariff  1975-09-18 00:00:00
# 2      Mr                Min         /                empty
# 3      Mr             Andrew     Rands                empty
# 4      Mr              Jitin      Jain  1980-02-14 00:00:00
# ..    ...                ...       ...                  ...
# 906    Ms    Parishma Suresh   Gaikwad                empty
# 907    Ms      Alo Mukherjee    Veloso                empty
# 908    Ms             Bhavya    Mishra                empty
# 909    Mr             Aakash    Sharma  1993-07-04 00:00:00
# 910    Mr             Steven  Gonzales                empty
#
#                              PAN CARD                     Email  \
# 0    ADNPK2360D,ADNPK2360D,ADNPK2360D       27.jayant@gmail.com
# 1                          BVDPS8513D        786riz05@gmail.com
# 2                               empty          910354281@gg.com
# 3                               empty           a.rands@mac.com
# 4                               empty  aanchaljain.aj@gmail.com
# ..                                ...                       ...
# 906                             empty                     empty
# 907                             empty                     empty
# 908                             empty                     empty
# 909                             empty                     empty
# 910                             empty                     empty
#
#              Phone        Mobile  \
# 0     919689930863         empty
# 1     919986406301  919535367296
# 2    8617872366331         empty
# 3      61438951450         empty
# 4     919810856000  919716867559
# ..             ...           ...
# 906   917038614104         empty
# 907   919822142611         empty
# 908   919910178224         empty
# 909   919874421250         empty
# 910    61478032239   61478032239
#
#                                           AddressLine1  \
# 0                                B - 32, SHIROLE BAUG,
# 1    Flat No. 002, Sunshine Apartment, East End 'd'...
# 2                                                    -
# 3                                         2 KIRRA ROAD
# 4                                           C-2 SECTOR
# ..                                                 ...
# 906                                                  -
# 907                                                  -
# 908                         C-503, ROSEWOOD APARTMENTS
# 909                                  3, JANKI DAS LANE
# 910                                                 --
#
#                         AddressLine2  ... Sales Rep and Comments Opt In  \
# 0    GANESHKHIND ROAD, MODEL COLONY,  ...                 Shifah    YES
# 1              Jayanagar, 9th Block,  ...                  empty    YES
# 2                              empty  ...                  empty    YES
# 3                     SECRET HARBOUR  ...                  RAFIK    YES
# 4                           50 NOIDA  ...           DARSHIT SHAH    YES
# ..                               ...  ...                    ...    ...
# 906                                -  ...                  empty    YES
# 907                                -  ...                  empty    YES
# 908              MAYUR VIHAR-1 EXTN,  ...                  empty    YES
# 909                            empty  ...                  empty    YES
# 910                                -  ...                  empty    YES
#
#         Contact Type Odyssey Members     Lead Brand Lead Sub-Brand  \
# 0    Email and Phone              NO  Karma Resorts          Other
# 1    Email and Phone              NO  Karma Resorts          Other
# 2    Email and Phone              NO  Karma Resorts          Other
# 3    Email and Phone              NO  Karma Resorts          Other
# 4    Email and Phone              NO  Karma Resorts          Other
# ..               ...             ...            ...            ...
# 906       Phone Only              NO  Karma Resorts          Other
# 907       Phone Only              NO  Karma Resorts          Other
# 908       Phone Only              NO  Karma Resorts          Other
# 909       Phone Only              NO  Karma Resorts          Other
# 910       Phone Only              NO  Karma Resorts          Other
#
#      Lead Source                           Lead Locations  \
# 0    Past Guests                 Karma Royal Haathi Mahal
# 1    Past Guests                 Karma Royal Haathi Mahal
# 2    Past Guests                           Karma Jimbaran
# 3    Past Guests                     Karma Royal Jimbaran
# 4    Past Guests                  Karma Sitabani, Corbett
# ..           ...                                      ...
# 906  Past Guests                     Karma Royal Monterio
# 907  Past Guests                        Karma Royal Palms
# 908  Past Guests                        Karma Royal Palms
# 909  Past Guests                     Karma Utopia, Manali
# 910  Past Guests  KRR @ Karma Kandara, Mentari Residences
#
#     Lead Source Description Exclude From Mailing
# 0                 Viewpoint                   NO
# 1                 Viewpoint                   NO
# 2                 Viewpoint                   NO
# 3                 Viewpoint                   NO
# 4                 Viewpoint                   NO
# ..                      ...                  ...
# 906               Viewpoint                   NO
# 907               Viewpoint                   NO
# 908               Viewpoint                   NO
# 909               Viewpoint                   NO
# 910               Viewpoint                   NO
#
# [911 rows x 37 columns]

# %%
# Cek leads test
test_leads = df_viewpoint.loc[
    
        df_viewpoint['Email'].str.contains('^test@', flags=re.I, regex=True) |
        df_viewpoint['Email'].str.contains('\+test', flags=re.I, regex=True) |
    
        df_viewpoint['Firstname'].str.contains('^test$', flags=re.I, regex=True) |
        df_viewpoint['lastname'].str.contains('^test$', flags=re.I, regex=True) |

        df_viewpoint['Firstname'].str.contains('test 1', flags=re.I, regex=True) |
        df_viewpoint['lastname'].str.contains('test 2', flags=re.I, regex=True)|
        df_viewpoint['Firstname'].str.contains('test1', flags=re.I, regex=True) |
        df_viewpoint['lastname'].str.contains('test2', flags=re.I, regex=True)|

        df_viewpoint['Firstname'].str.contains(' test ', flags=re.I, regex=True) | 
        df_viewpoint['lastname'].str.contains(' test ', flags=re.I, regex=True) | 
        df_viewpoint['lastname'].str.contains(' test$', flags=re.I, regex=True)
    ]

count_leads_test = test_leads.shape[0]

test_leads.to_csv(r'C:\Users\fajar\Documents\Python\Data\test_leads_viewpoint.csv', index=False)
test_leads
# Out:
# Empty DataFrame
# Columns: [Title, Firstname, lastname, DOB, PAN CARD, Email, Phone, Mobile, AddressLine1, AddressLine2, Town, State, Country, PostCode, Nationality, MaritalStatus, resortname, Arrival, Departure, CheckInDate, CheckOutDate, room, UnitCategory, BookingNo, BookingSourceDesc, BookingTypeDesc, Date of Tour, Sales Rep and Comments, Opt In, Contact Type, Odyssey Members, Lead Brand, Lead Sub-Brand, Lead Source, Lead Locations, Lead Source Description, Exclude From Mailing]
# Index: []
#
# [0 rows x 37 columns]

# %%
df_viewpoint.drop(test_leads.index, inplace=True)
df_viewpoint.reset_index(drop=True, inplace=True)

count_after_dedup_test = df_viewpoint.shape[0]
count_after_dedup_test
# Out:
# 911

# %%
count_final_data = count_after_dedup_test

# %%
# df_viewpoint.loc[df_viewpoint['BookingNo'] == '2070341']

# %%
df_viewpoint.replace('empty', '', inplace=True)

# %%
print("==========================================================")
print("Summary")
print("==========================================================")
print("Jumlah Data Awal Viewpoint : "+str(count_data_awal))
print("Jumlah Data Email dan Phone Kosong : "+str(count_contact_type_empty))
print("Jumlah Data Setelah Hapus Email dan Phone Yang Kosong : "+str(count_after_contact_type_empty))
print("Jumlah Data Email Yang Termasuk List Karma : "+str(count_email_karma))
print("Jumlah Data Email Setelah List Karma Dihapus : "+str(count_after_clean_karma))
print("Jumlah Data Test : "+str(count_leads_test))
print("Jumlah Data Email Setelah Data Test Dihapus : "+str(count_after_dedup_test))
print("Jumlah Data Akhir : "+str(count_final_data))
# Out:
# ==========================================================
# Summary
# ==========================================================
# Jumlah Data Awal Viewpoint : 982
# Jumlah Data Email dan Phone Kosong : 57
# Jumlah Data Setelah Hapus Email dan Phone Yang Kosong : 925
# Jumlah Data Email Yang Termasuk List Karma : 14
# Jumlah Data Email Setelah List Karma Dihapus : 911
# Jumlah Data Test : 0
# Jumlah Data Email Setelah Data Test Dihapus : 911
# Jumlah Data Akhir : 911

# %%
df_viewpoint.to_excel(r'C:\Users\fajar\Documents\Python\Data\check_country_code_viewpoint.xlsx', index=False)
