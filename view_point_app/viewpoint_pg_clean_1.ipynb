# %%
import pandas as pd
import re

import past_guest_module as pm

import sys
sys.path.append('../zoho_data_app/')

import main_module as m

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
path = r'C:\Users\fajar\Documents\Python\Data\Past Guest Data\View Point\2024\Juli\21 July - 29 July\CheckOutReport 21 July - 29 July.xlsx'
df_viewpoint = pd.read_excel(path, dtype='string', sheet_name='Sheet1')
count_data_awal = df_viewpoint.shape[0]
df_viewpoint
# Out:
#      Title                       Firstname   lastname                  DOB  \
# 0       Mr                        Shrikant  Baporikar  1963-05-30 00:00:00
# 1      Mrs                         Vandana  Baporikar  1970-11-25 00:00:00
# 2      Mrs                           Linda    Colcott  1900-01-01 00:00:00
# 3       Mr                            Paul    Cassidy                 <NA>
# 4       Mr                          DENISE    KENNEDY                 <NA>
# ...    ...                             ...        ...                  ...
# 1749  <NA>                            <NA>       <NA>                 <NA>
# 1750     -                         ENRIQUE    CHONGCO                 <NA>
# 1751  <NA>                Ademola, Akindes       <NA>                 <NA>
# 1752  <NA>  Wilkins, Alan & Venturi, Norma       <NA>                 <NA>
# 1753   krg                    Fajar Fatoni         86                 <NA>
#
#         PAN CARD                         Email         Phone       Mobile  \
# 0           <NA>       kaushikgets51@gmail.com  918806553676         <NA>
# 1     ASNPB3065D    vandanabaporikar@gmail.com  919011534924         <NA>
# 2           <NA>      frankdolcott@hotmail.com   61418148504         <NA>
# 3           <NA>  paul.cassidy@leadwire.com.au   61403150755  61403150755
# 4           <NA>  denise.j.kennedy@bigpond.com   61402977644  61402977644
# ...          ...                           ...           ...          ...
# 1749        <NA>                          <NA>          <NA>         <NA>
# 1750        <NA>                          <NA>          <NA>         <NA>
# 1751        <NA>                        direct           210         <NA>
# 1752        <NA>                          <NA>          <NA>         <NA>
# 1753        <NA>                          <NA>          <NA>         <NA>
#
#                                  AddressLine1                    AddressLine2  \
# 0            B, 404, KOOL HOMES, GREEN VALLEY  BEHIND MARATHA MANDIR, BAVDHAN
# 1     B, 404, KOOL HOMES, GREEN VALLEY BEHIND         MARATHA MANDIR, BAVDHAN
# 2                                        <NA>                            <NA>
# 3                                           -                            <NA>
# 4                     5 ALICE STREET VIC 3737                               -
# ...                                       ...                             ...
# 1749                                     <NA>                            <NA>
# 1750                                        -                            <NA>
# 1751                                     <NA>                            <NA>
# 1752                                     <NA>                            <NA>
# 1753                                     <NA>                            <NA>
#
#       ...          CheckInDate         CheckOutDate  room  \
# 0     ...  2024-07-15 09:26:14  2024-07-22 10:14:30    01
# 1     ...  2024-07-15 09:26:27  2024-07-22 10:14:37    02
# 2     ...  2024-07-16 18:04:46  2024-07-23 07:24:02    04
# 3     ...  2024-07-17 22:45:40  2024-07-23 07:24:36    06
# 4     ...  2024-07-16 18:04:17  2024-07-25 07:05:18    07
# ...   ...                  ...                  ...   ...
# 1749  ...  2024-07-22 00:29:19  2024-07-28 17:36:54   201
# 1750  ...  2024-07-24 06:10:39  2024-07-28 18:09:35   213
# 1751  ...  2024-07-27 23:57:53  2024-07-28 18:21:54   202
# 1752  ...  2024-07-25 18:27:10  2024-07-28 18:26:35   212
# 1753  ...                 <NA>                 <NA>  <NA>
#
#              UnitCategory BookingNo             BookingSourceDesc  \
# 0             Deluxe Room   2543553                     KC Member
# 1             Deluxe Room   2543556                     KC Member
# 2             Deluxe Room   2490582  KCE2 All Other Nationalities
# 3             Deluxe Room   2547416               Fly Buy Western
# 4             Deluxe Room   2495662               Fly Buy Western
# ...                   ...       ...                           ...
# 1749            3 Bedroom   2248669                Hotel Bookings
# 1750  2 Bedroom Apartment   2456645                Hotel Bookings
# 1751  1 Bedroom Apartment   2559801                Hotel Bookings
# 1752  1 Bedroom Apartment   2474244                Hotel Bookings
# 1753                 <NA>      <NA>                          <NA>
#
#             BookingTypeDesc         Date of Tour Sales Rep and Comments Opt In
# 0                Sales Gift                 <NA>                  SAMBA    YES
# 1                Sales Gift  2024-07-19 15:53:00                  SAMBA    YES
# 2     KCE2 - Redeem Voucher                 <NA>                   <NA>    YES
# 3           Fly Buy Western                 <NA>                   <NA>    YES
# 4     KE - Karma Experience                 <NA>                   <NA>    YES
# ...                     ...                  ...                    ...    ...
# 1749         Wyndham Guests                 <NA>                   <NA>    YES
# 1750         Wyndham Guests                 <NA>                   <NA>    YES
# 1751         Wyndham Guests                 <NA>                   <NA>    YES
# 1752         Wyndham Guests                 <NA>                   <NA>    YES
# 1753                   <NA>                 <NA>                   <NA>   <NA>
#
# [1754 rows x 29 columns]

# %%
df_viewpoint.columns
# Out:
# Index(['Title', 'Firstname', 'lastname', 'DOB', 'PAN CARD', 'Email', 'Phone',
#        'Mobile', 'AddressLine1', 'AddressLine2', 'Town', 'State', 'Country',
#        'PostCode', 'Nationality', 'MaritalStatus', 'resortname', 'Arrival',
#        'Departure', 'CheckInDate', 'CheckOutDate', 'room', 'UnitCategory',
#        'BookingNo', 'BookingSourceDesc', 'BookingTypeDesc', 'Date of Tour',
#        'Sales Rep and Comments', 'Opt In'],
#       dtype='object')

# %%
df_viewpoint.fillna('empty', inplace=True)

df_viewpoint['Contact Type'] = 'empty'
df_viewpoint['Odyssey Members'] = 'NO'

df_viewpoint['Lead Brand'] = 'Karma Resorts'
df_viewpoint['Lead Sub-Brand'] = 'Other'
df_viewpoint['Lead Source'] = 'Past Guests'
df_viewpoint['Lead Locations'] = df_viewpoint['resortname']
df_viewpoint['Lead Source Description'] = 'Viewpoint'

# %%
df_viewpoint.loc[df_viewpoint['Opt In'] == 'YES', 'Exclude From Mailing'] = 'NO'
df_viewpoint.loc[df_viewpoint['Opt In'] == 'NO', 'Exclude From Mailing'] = 'YES'

# %%
df_viewpoint.loc[df_viewpoint['lastname'] == 'empty', 'lastname'] = '-'

# %%
df_viewpoint['Title'].replace('empty', '', inplace=True)
df_viewpoint['Firstname'].replace('empty', '', inplace=True)
df_viewpoint['lastname'].replace('empty', '', inplace=True)

df_viewpoint['Title'] = df_viewpoint['Title'].str.title()
df_viewpoint['Firstname'] = df_viewpoint['Firstname'].str.title()
df_viewpoint['lastname'] = df_viewpoint['lastname'].str.title()

df_viewpoint
# Out:
#      Title                       Firstname   lastname                  DOB  \
# 0       Mr                        Shrikant  Baporikar  1963-05-30 00:00:00
# 1      Mrs                         Vandana  Baporikar  1970-11-25 00:00:00
# 2      Mrs                           Linda    Colcott  1900-01-01 00:00:00
# 3       Mr                            Paul    Cassidy                empty
# 4       Mr                          Denise    Kennedy                empty
# ...    ...                             ...        ...                  ...
# 1749                                                -                empty
# 1750     -                         Enrique    Chongco                empty
# 1751                      Ademola, Akindes          -                empty
# 1752        Wilkins, Alan & Venturi, Norma          -                empty
# 1753   Krg                    Fajar Fatoni         86                empty
#
#         PAN CARD                         Email         Phone       Mobile  \
# 0          empty       kaushikgets51@gmail.com  918806553676        empty
# 1     ASNPB3065D    vandanabaporikar@gmail.com  919011534924        empty
# 2          empty      frankdolcott@hotmail.com   61418148504        empty
# 3          empty  paul.cassidy@leadwire.com.au   61403150755  61403150755
# 4          empty  denise.j.kennedy@bigpond.com   61402977644  61402977644
# ...          ...                           ...           ...          ...
# 1749       empty                         empty         empty        empty
# 1750       empty                         empty         empty        empty
# 1751       empty                        direct           210        empty
# 1752       empty                         empty         empty        empty
# 1753       empty                         empty         empty        empty
#
#                                  AddressLine1                    AddressLine2  \
# 0            B, 404, KOOL HOMES, GREEN VALLEY  BEHIND MARATHA MANDIR, BAVDHAN
# 1     B, 404, KOOL HOMES, GREEN VALLEY BEHIND         MARATHA MANDIR, BAVDHAN
# 2                                       empty                           empty
# 3                                           -                           empty
# 4                     5 ALICE STREET VIC 3737                               -
# ...                                       ...                             ...
# 1749                                    empty                           empty
# 1750                                        -                           empty
# 1751                                    empty                           empty
# 1752                                    empty                           empty
# 1753                                    empty                           empty
#
#       ... Sales Rep and Comments Opt In Contact Type Odyssey Members  \
# 0     ...                  SAMBA    YES        empty              NO
# 1     ...                  SAMBA    YES        empty              NO
# 2     ...                  empty    YES        empty              NO
# 3     ...                  empty    YES        empty              NO
# 4     ...                  empty    YES        empty              NO
# ...   ...                    ...    ...          ...             ...
# 1749  ...                  empty    YES        empty              NO
# 1750  ...                  empty    YES        empty              NO
# 1751  ...                  empty    YES        empty              NO
# 1752  ...                  empty    YES        empty              NO
# 1753  ...                  empty  empty        empty              NO
#
#          Lead Brand Lead Sub-Brand  Lead Source  \
# 0     Karma Resorts          Other  Past Guests
# 1     Karma Resorts          Other  Past Guests
# 2     Karma Resorts          Other  Past Guests
# 3     Karma Resorts          Other  Past Guests
# 4     Karma Resorts          Other  Past Guests
# ...             ...            ...          ...
# 1749  Karma Resorts          Other  Past Guests
# 1750  Karma Resorts          Other  Past Guests
# 1751  Karma Resorts          Other  Past Guests
# 1752  Karma Resorts          Other  Past Guests
# 1753  Karma Resorts          Other  Past Guests
#
#                          Lead Locations Lead Source Description  \
# 0                           Ahoy Hoi An               Viewpoint
# 1                           Ahoy Hoi An               Viewpoint
# 2                           Amina hotel               Viewpoint
# 3                           Amina hotel               Viewpoint
# 4                           Amina hotel               Viewpoint
# ...                                 ...                     ...
# 1749  Wyndham -  Manoir des Deux Amants               Viewpoint
# 1750  Wyndham -  Manoir des Deux Amants               Viewpoint
# 1751  Wyndham -  Manoir des Deux Amants               Viewpoint
# 1752  Wyndham -  Manoir des Deux Amants               Viewpoint
# 1753                              empty               Viewpoint
#
#      Exclude From Mailing
# 0                      NO
# 1                      NO
# 2                      NO
# 3                      NO
# 4                      NO
# ...                   ...
# 1749                   NO
# 1750                   NO
# 1751                   NO
# 1752                   NO
# 1753                  NaN
#
# [1754 rows x 37 columns]

# %%
m.clean_number(df_viewpoint, 'Phone')
m.clean_number(df_viewpoint, 'Mobile')
m.replace_not_valid_to_empty(df_viewpoint, 'Phone')
m.replace_not_valid_to_empty(df_viewpoint, 'Mobile')

df_viewpoint.loc[df_viewpoint['Phone'].str.contains('00000'), 'Phone'] = 'empty'
df_viewpoint.loc[df_viewpoint['Mobile'].str.contains('00000'), 'Mobile'] = 'empty'

m.clean_space(df_viewpoint, 'Email')
df_viewpoint['Email'] = m.lowercase(df_viewpoint, 'Email')

# %%
pm.email_correction(df_viewpoint, 'Email')

# %%
df_viewpoint.loc[(df_viewpoint['Email'] != 'empty') & ((df_viewpoint['Phone'] != 'empty') | (df_viewpoint['Mobile'] != 'empty')), 'Contact Type'] = 'Email and Phone'
df_viewpoint.loc[(df_viewpoint['Email'] != 'empty') & ((df_viewpoint['Phone'] == 'empty') & (df_viewpoint['Mobile'] == 'empty')), 'Contact Type'] = 'Email Only'
df_viewpoint.loc[(df_viewpoint['Email'] == 'empty') & ((df_viewpoint['Phone'] != 'empty') | (df_viewpoint['Mobile'] != 'empty')), 'Contact Type'] = 'Phone Only'

df_viewpoint.loc[df_viewpoint['Contact Type'] == 'empty'].to_csv(r'C:\Users\fajar\Documents\Python\Data\contact_type_empty_viewpoint.csv', index=False)

count_contact_type_empty = df_viewpoint.loc[df_viewpoint['Contact Type'] == 'empty'].shape[0]

df_viewpoint.drop(df_viewpoint.loc[df_viewpoint['Contact Type'] == 'empty'].index, inplace=True)
df_viewpoint.reset_index(drop=True, inplace=True)

count_after_contact_type_empty = df_viewpoint.shape[0]

df_viewpoint
# Out:
#      Title         Firstname   lastname                  DOB    PAN CARD  \
# 0       Mr          Shrikant  Baporikar  1963-05-30 00:00:00       empty
# 1      Mrs           Vandana  Baporikar  1970-11-25 00:00:00  ASNPB3065D
# 2      Mrs             Linda    Colcott  1900-01-01 00:00:00       empty
# 3       Mr              Paul    Cassidy                empty       empty
# 4       Mr            Denise    Kennedy                empty       empty
# ...    ...               ...        ...                  ...         ...
# 1578   Mrs              Anne     Faudet                empty       empty
# 1579         Hillenius, Kees          -                empty       empty
# 1580    Mr            Mootez    Kheriji                empty       empty
# 1581    Mr          Geoffrey    Clément                empty       empty
# 1582        Ademola, Akindes          -                empty       empty
#
#                                 Email         Phone       Mobile  \
# 0             kaushikgets51@gmail.com  918806553676        empty
# 1          vandanabaporikar@gmail.com  919011534924        empty
# 2            frankdolcott@hotmail.com   61418148504        empty
# 3        paul.cassidy@leadwire.com.au   61403150755  61403150755
# 4        denise.j.kennedy@bigpond.com   61402977644  61402977644
# ...                               ...           ...          ...
# 1578  afaude.647969@guest.booking.com   33688495418        empty
# 1579                      booking.com         empty        empty
# 1580  mkheri.899972@guest.booking.com   33768311344        empty
# 1581                            empty   33666982480        empty
# 1582                           direct         empty        empty
#
#                                  AddressLine1                    AddressLine2  \
# 0            B, 404, KOOL HOMES, GREEN VALLEY  BEHIND MARATHA MANDIR, BAVDHAN
# 1     B, 404, KOOL HOMES, GREEN VALLEY BEHIND         MARATHA MANDIR, BAVDHAN
# 2                                       empty                           empty
# 3                                           -                           empty
# 4                     5 ALICE STREET VIC 3737                               -
# ...                                       ...                             ...
# 1578                                        .                               .
# 1579                                    empty                           empty
# 1580                                        .                               .
# 1581                                        .                               .
# 1582                                    empty                           empty
#
#       ... Sales Rep and Comments Opt In     Contact Type Odyssey Members  \
# 0     ...                  SAMBA    YES  Email and Phone              NO
# 1     ...                  SAMBA    YES  Email and Phone              NO
# 2     ...                  empty    YES  Email and Phone              NO
# 3     ...                  empty    YES  Email and Phone              NO
# 4     ...                  empty    YES  Email and Phone              NO
# ...   ...                    ...    ...              ...             ...
# 1578  ...                  empty    YES  Email and Phone              NO
# 1579  ...                  empty    YES       Email Only              NO
# 1580  ...                  empty    YES  Email and Phone              NO
# 1581  ...                  empty    YES       Phone Only              NO
# 1582  ...                  empty    YES       Email Only              NO
#
#          Lead Brand Lead Sub-Brand  Lead Source  \
# 0     Karma Resorts          Other  Past Guests
# 1     Karma Resorts          Other  Past Guests
# 2     Karma Resorts          Other  Past Guests
# 3     Karma Resorts          Other  Past Guests
# 4     Karma Resorts          Other  Past Guests
# ...             ...            ...          ...
# 1578  Karma Resorts          Other  Past Guests
# 1579  Karma Resorts          Other  Past Guests
# 1580  Karma Resorts          Other  Past Guests
# 1581  Karma Resorts          Other  Past Guests
# 1582  Karma Resorts          Other  Past Guests
#
#                          Lead Locations Lead Source Description  \
# 0                           Ahoy Hoi An               Viewpoint
# 1                           Ahoy Hoi An               Viewpoint
# 2                           Amina hotel               Viewpoint
# 3                           Amina hotel               Viewpoint
# 4                           Amina hotel               Viewpoint
# ...                                 ...                     ...
# 1578  Wyndham -  Manoir des Deux Amants               Viewpoint
# 1579  Wyndham -  Manoir des Deux Amants               Viewpoint
# 1580  Wyndham -  Manoir des Deux Amants               Viewpoint
# 1581  Wyndham -  Manoir des Deux Amants               Viewpoint
# 1582  Wyndham -  Manoir des Deux Amants               Viewpoint
#
#      Exclude From Mailing
# 0                      NO
# 1                      NO
# 2                      NO
# 3                      NO
# 4                      NO
# ...                   ...
# 1578                   NO
# 1579                   NO
# 1580                   NO
# 1581                   NO
# 1582                   NO
#
# [1583 rows x 37 columns]

# %%
# Cek Email Karma
email_karma = m.find_karma(df_viewpoint, 'Email')
count_email_karma = email_karma.shape[0]
email_karma.to_csv(r'C:\Users\fajar\Documents\Python\Data\email_deleted_viewpoint.csv', index=False)

email_karma
# Out:
#      Title           Firstname              lastname                  DOB  \
# 81            Maintenance Room          Karma Chakra                empty
# 93            Maintenance Room          Karma Chakra                empty
# 94            Maintenance Room          Karma Chakra                empty
# 118           Maintenance Room          Karma Chakra                empty
# 121           Maintenance Room          Karma Chakra                empty
# 518     Mr               James                 Casey                empty
# 784     Mr              Pramod        Balasubramanya                empty
# 802     Mr                Shiv                 Suman                empty
# 817      -  Maintenance Room -  Karma Royal Monterio                empty
# 827     Mr                Shiv                 Suman                empty
# 858      -  Maintenance Room -  Karma Royal Monterio                empty
# 871     Mr                Shiv                 Suman                empty
# 1326    Mr              Lumtan             Panomtian  1987-01-14 00:00:00
#
#      PAN CARD                                 Email         Phone  \
# 81      empty                 chakra@karmagroup.com  914812526252
# 93      empty                 chakra@karmagroup.com  914812526252
# 94      empty                 chakra@karmagroup.com  914812526252
# 118     empty                 chakra@karmagroup.com  914812526252
# 121     empty                 chakra@karmagroup.com  914812526252
# 518     empty            james.casey@karmagroup.com         empty
# 784     empty  pramod.balasubramanya@karmagroup.com  919538510610
# 802     empty            shivsuman.b@karmagroup.com  919325868122
# 817     empty             mr.asstfom@karmagroup.com  918326716200
# 827     empty            shivsuman.b@karmagroup.com  919325868122
# 858     empty             mr.asstfom@karmagroup.com  918326716200
# 871     empty            shivsuman.b@karmagroup.com  919325868122
# 1326    empty    concierge@karmaroyalbellavista.com         empty
#
#             Mobile                              AddressLine1  \
# 81    919446080121  Ward # 09, Block#12, Near Nasrath Church
# 93    919446080121  Ward # 09, Block#12, Near Nasrath Church
# 94    919446080121  Ward # 09, Block#12, Near Nasrath Church
# 118   919446080121  Ward # 09, Block#12, Near Nasrath Church
# 121   919446080121  Ward # 09, Block#12, Near Nasrath Church
# 518          empty     Jl. By Pass Ngurah Rai No.61, Pemogan
# 784   919538510610                                         -
# 802          empty                                         -
# 817          empty                      karma royal monetrio
# 827          empty                                         -
# 858          empty                      karma royal monetrio
# 871          empty                                         -
# 1326         empty                                Chiang May
#
#              AddressLine2  ... Sales Rep and Comments Opt In     Contact Type  \
# 81               KOTTAYAM  ...                  empty    YES  Email and Phone
# 93               KOTTAYAM  ...                  empty    YES  Email and Phone
# 94               KOTTAYAM  ...                  empty    YES  Email and Phone
# 118              KOTTAYAM  ...                  empty    YES  Email and Phone
# 121              KOTTAYAM  ...                  empty    YES  Email and Phone
# 518   Kec. Denpasar Sel.,  ...                  empty    YES       Email Only
# 784                     -  ...                  empty    YES  Email and Phone
# 802                     -  ...                  empty    YES  Email and Phone
# 817                Arpora  ...                  empty    YES  Email and Phone
# 827                     -  ...                  empty    YES  Email and Phone
# 858                Arpora  ...                  empty    YES  Email and Phone
# 871                     -  ...                  empty    YES  Email and Phone
# 1326                empty  ...                  empty    YES       Email Only
#
#      Odyssey Members     Lead Brand Lead Sub-Brand  Lead Source  \
# 81                NO  Karma Resorts          Other  Past Guests
# 93                NO  Karma Resorts          Other  Past Guests
# 94                NO  Karma Resorts          Other  Past Guests
# 118               NO  Karma Resorts          Other  Past Guests
# 121               NO  Karma Resorts          Other  Past Guests
# 518               NO  Karma Resorts          Other  Past Guests
# 784               NO  Karma Resorts          Other  Past Guests
# 802               NO  Karma Resorts          Other  Past Guests
# 817               NO  Karma Resorts          Other  Past Guests
# 827               NO  Karma Resorts          Other  Past Guests
# 858               NO  Karma Resorts          Other  Past Guests
# 871               NO  Karma Resorts          Other  Past Guests
# 1326              NO  Karma Resorts          Other  Past Guests
#
#              Lead Locations Lead Source Description Exclude From Mailing
# 81     Karma Chakra, Kerala               Viewpoint                   NO
# 93     Karma Chakra, Kerala               Viewpoint                   NO
# 94     Karma Chakra, Kerala               Viewpoint                   NO
# 118    Karma Chakra, Kerala               Viewpoint                   NO
# 121    Karma Chakra, Kerala               Viewpoint                   NO
# 518   Karma Royal Candidasa               Viewpoint                   NO
# 784    Karma Royal Monterio               Viewpoint                   NO
# 802    Karma Royal Monterio               Viewpoint                   NO
# 817    Karma Royal Monterio               Viewpoint                   NO
# 827    Karma Royal Monterio               Viewpoint                   NO
# 858    Karma Royal Monterio               Viewpoint                   NO
# 871    Karma Royal Monterio               Viewpoint                   NO
# 1326        Karma Song Hoai               Viewpoint                   NO
#
# [13 rows x 37 columns]

# %%
# delete email Karma
count_after_clean_karma = m.delete_karma(df_viewpoint, 'Email')

df_viewpoint
# Out:
#      Title         Firstname   lastname                  DOB    PAN CARD  \
# 0       Mr          Shrikant  Baporikar  1963-05-30 00:00:00       empty
# 1      Mrs           Vandana  Baporikar  1970-11-25 00:00:00  ASNPB3065D
# 2      Mrs             Linda    Colcott  1900-01-01 00:00:00       empty
# 3       Mr              Paul    Cassidy                empty       empty
# 4       Mr            Denise    Kennedy                empty       empty
# ...    ...               ...        ...                  ...         ...
# 1565   Mrs              Anne     Faudet                empty       empty
# 1566         Hillenius, Kees          -                empty       empty
# 1567    Mr            Mootez    Kheriji                empty       empty
# 1568    Mr          Geoffrey    Clément                empty       empty
# 1569        Ademola, Akindes          -                empty       empty
#
#                                 Email         Phone       Mobile  \
# 0             kaushikgets51@gmail.com  918806553676        empty
# 1          vandanabaporikar@gmail.com  919011534924        empty
# 2            frankdolcott@hotmail.com   61418148504        empty
# 3        paul.cassidy@leadwire.com.au   61403150755  61403150755
# 4        denise.j.kennedy@bigpond.com   61402977644  61402977644
# ...                               ...           ...          ...
# 1565  afaude.647969@guest.booking.com   33688495418        empty
# 1566                      booking.com         empty        empty
# 1567  mkheri.899972@guest.booking.com   33768311344        empty
# 1568                            empty   33666982480        empty
# 1569                           direct         empty        empty
#
#                                  AddressLine1                    AddressLine2  \
# 0            B, 404, KOOL HOMES, GREEN VALLEY  BEHIND MARATHA MANDIR, BAVDHAN
# 1     B, 404, KOOL HOMES, GREEN VALLEY BEHIND         MARATHA MANDIR, BAVDHAN
# 2                                       empty                           empty
# 3                                           -                           empty
# 4                     5 ALICE STREET VIC 3737                               -
# ...                                       ...                             ...
# 1565                                        .                               .
# 1566                                    empty                           empty
# 1567                                        .                               .
# 1568                                        .                               .
# 1569                                    empty                           empty
#
#       ... Sales Rep and Comments Opt In     Contact Type Odyssey Members  \
# 0     ...                  SAMBA    YES  Email and Phone              NO
# 1     ...                  SAMBA    YES  Email and Phone              NO
# 2     ...                  empty    YES  Email and Phone              NO
# 3     ...                  empty    YES  Email and Phone              NO
# 4     ...                  empty    YES  Email and Phone              NO
# ...   ...                    ...    ...              ...             ...
# 1565  ...                  empty    YES  Email and Phone              NO
# 1566  ...                  empty    YES       Email Only              NO
# 1567  ...                  empty    YES  Email and Phone              NO
# 1568  ...                  empty    YES       Phone Only              NO
# 1569  ...                  empty    YES       Email Only              NO
#
#          Lead Brand Lead Sub-Brand  Lead Source  \
# 0     Karma Resorts          Other  Past Guests
# 1     Karma Resorts          Other  Past Guests
# 2     Karma Resorts          Other  Past Guests
# 3     Karma Resorts          Other  Past Guests
# 4     Karma Resorts          Other  Past Guests
# ...             ...            ...          ...
# 1565  Karma Resorts          Other  Past Guests
# 1566  Karma Resorts          Other  Past Guests
# 1567  Karma Resorts          Other  Past Guests
# 1568  Karma Resorts          Other  Past Guests
# 1569  Karma Resorts          Other  Past Guests
#
#                          Lead Locations Lead Source Description  \
# 0                           Ahoy Hoi An               Viewpoint
# 1                           Ahoy Hoi An               Viewpoint
# 2                           Amina hotel               Viewpoint
# 3                           Amina hotel               Viewpoint
# 4                           Amina hotel               Viewpoint
# ...                                 ...                     ...
# 1565  Wyndham -  Manoir des Deux Amants               Viewpoint
# 1566  Wyndham -  Manoir des Deux Amants               Viewpoint
# 1567  Wyndham -  Manoir des Deux Amants               Viewpoint
# 1568  Wyndham -  Manoir des Deux Amants               Viewpoint
# 1569  Wyndham -  Manoir des Deux Amants               Viewpoint
#
#      Exclude From Mailing
# 0                      NO
# 1                      NO
# 2                      NO
# 3                      NO
# 4                      NO
# ...                   ...
# 1565                   NO
# 1566                   NO
# 1567                   NO
# 1568                   NO
# 1569                   NO
#
# [1570 rows x 37 columns]

# %%
# Cek leads test
test_leads = df_viewpoint.loc[
    
        df_viewpoint['Email'].str.contains('^test@', flags=re.I, regex=True) |
        df_viewpoint['Email'].str.contains('\+test', flags=re.I, regex=True) |
    
        df_viewpoint['Firstname'].str.contains('^test$', flags=re.I, regex=True) |
        df_viewpoint['lastname'].str.contains('^test$', flags=re.I, regex=True) |

        df_viewpoint['Firstname'].str.contains('test 1', flags=re.I, regex=True) |
        df_viewpoint['lastname'].str.contains('test 2', flags=re.I, regex=True)|
        df_viewpoint['Firstname'].str.contains('test1', flags=re.I, regex=True) |
        df_viewpoint['lastname'].str.contains('test2', flags=re.I, regex=True)|

        df_viewpoint['Firstname'].str.contains(' test ', flags=re.I, regex=True) | 
        df_viewpoint['lastname'].str.contains(' test ', flags=re.I, regex=True) | 
        df_viewpoint['lastname'].str.contains(' test$', flags=re.I, regex=True)
    ]

count_leads_test = test_leads.shape[0]

test_leads.to_csv(r'C:\Users\fajar\Documents\Python\Data\test_leads_viewpoint.csv', index=False)
test_leads
# Out:
# Empty DataFrame
# Columns: [Title, Firstname, lastname, DOB, PAN CARD, Email, Phone, Mobile, AddressLine1, AddressLine2, Town, State, Country, PostCode, Nationality, MaritalStatus, resortname, Arrival, Departure, CheckInDate, CheckOutDate, room, UnitCategory, BookingNo, BookingSourceDesc, BookingTypeDesc, Date of Tour, Sales Rep and Comments, Opt In, Contact Type, Odyssey Members, Lead Brand, Lead Sub-Brand, Lead Source, Lead Locations, Lead Source Description, Exclude From Mailing]
# Index: []
#
# [0 rows x 37 columns]

# %%
df_viewpoint.drop(test_leads.index, inplace=True)
df_viewpoint.reset_index(drop=True, inplace=True)

count_after_dedup_test = df_viewpoint.shape[0]
count_after_dedup_test
# Out:
# 1570

# %%
count_final_data = count_after_dedup_test

# %%
# df_viewpoint.loc[df_viewpoint['BookingNo'] == '2070341']

# %%
df_viewpoint.replace('empty', '', inplace=True)

# %%
print("==========================================================")
print("Summary")
print("==========================================================")
print("Jumlah Data Awal Viewpoint : "+str(count_data_awal))
print("Jumlah Data Email dan Phone Kosong : "+str(count_contact_type_empty))
print("Jumlah Data Setelah Hapus Email dan Phone Yang Kosong : "+str(count_after_contact_type_empty))
print("Jumlah Data Email Yang Termasuk List Karma : "+str(count_email_karma))
print("Jumlah Data Email Setelah List Karma Dihapus : "+str(count_after_clean_karma))
print("Jumlah Data Test : "+str(count_leads_test))
print("Jumlah Data Email Setelah Data Test Dihapus : "+str(count_after_dedup_test))
print("Jumlah Data Akhir : "+str(count_final_data))
# Out:
# ==========================================================
# Summary
# ==========================================================
# Jumlah Data Awal Viewpoint : 1754
# Jumlah Data Email dan Phone Kosong : 171
# Jumlah Data Setelah Hapus Email dan Phone Yang Kosong : 1583
# Jumlah Data Email Yang Termasuk List Karma : 13
# Jumlah Data Email Setelah List Karma Dihapus : 1570
# Jumlah Data Test : 0
# Jumlah Data Email Setelah Data Test Dihapus : 1570
# Jumlah Data Akhir : 1570

# %%
df_viewpoint.to_excel(r'C:\Users\fajar\Documents\Python\Data\check_country_code_viewpoint.xlsx', index=False)
