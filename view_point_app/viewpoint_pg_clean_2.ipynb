# %%
import pandas as pd
import re

import past_guest_module as pm

import sys
sys.path.append('../zoho_data_app/')

import main_module as m

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
path = r'C:\Users\fajar\Documents\Python\Data\check_country_code_viewpoint.xlsx'
df_viewpoint = pd.read_excel(path, dtype='string', sheet_name='Sheet1')
count_data_awal = df_viewpoint.shape[0]

# %%
df_viewpoint.fillna('empty', inplace=True)

# %%
path = r'G:\.shortcut-targets-by-id\0B_d3smBjzo04UUNBME5GOVhoMjA\_ODYSSEY\Phone Members.xlsx'
df_phone = pd.read_excel(path, dtype='string', sheet_name='Sheet1')

path = r'G:\.shortcut-targets-by-id\0B_d3smBjzo04UUNBME5GOVhoMjA\_ODYSSEY\Email Members.xlsx'
df_email = pd.read_excel(path, dtype='string', sheet_name='Sheet1')

# %%
m.clean_space(df_email, 'Email')
df_email['Email'] = m.lowercase(df_email, 'Email')

# %%
# hitung jumlah duplicate
count_duplicate_general = df_viewpoint.loc[df_viewpoint.duplicated(subset=['Phone','Mobile','Email'])].shape[0]

df_viewpoint.loc[df_viewpoint.duplicated(subset=['Phone','Mobile','Email'])]
# Out:
#      Title          Firstname     lastname                  DOB PAN CARD  \
# 2       Mr          Alexander  Duncan-Kemp                empty    empty
# 6       Mr     Andrew William     Charlett  1953-08-27 00:00:00    empty
# 13      Mr               Babu       Thomas  1964-05-24 00:00:00    empty
# 16      Mr            Jeffrey      Fussell  1960-07-31 00:00:00    empty
# 18      Mr            Bradley      Davison  1985-06-04 00:00:00    empty
# ..     ...                ...          ...                  ...      ...
# 891     Mr             Adrian        Ralph  1959-05-21 00:00:00    empty
# 901  empty    Andre, Philippe            -                empty    empty
# 902  empty        Andre, Anne            -                empty    empty
# 903  empty        Todd, Chris            -                empty    empty
# 908  empty  Audibert, Vincent            -                empty    empty
#
#                                  Email         Phone        Mobile  \
# 2    alex.duncankemp@adkminserv.com.au   61893710257   61419918165
# 6                   andychar@yahoo.com   61404023936         empty
# 13              bab.thomas01@gmail.com   61416565247         empty
# 16              bounyavong@hotmail.com   61431614921   61431614921
# 18          bradandsteph10@outlook.com   61418119445         empty
# ..                                 ...           ...           ...
# 891                 stanandann@aol.com  447923041816  447923041816
# 901                        booking.com         empty         empty
# 902                        booking.com         empty         empty
# 903                        booking.com         empty         empty
# 908                      expedia-hotel         empty         empty
#
#                        AddressLine1 AddressLine2  ... Sales Rep and Comments  \
# 2                  184 SIXTH AVENUE        empty  ...                  empty
# 6             33A HILLSIDE CRESCENT        empty  ...                   Suzy
# 13   12 BANOOL CRESCENT, CITY BEACH        empty  ...                 Sajith
# 16                   24 BOURKE ROAD        empty  ...                  empty
# 18                64 THORNTON DRIVE        empty  ...                 GAUTAM
# ..                              ...          ...  ...                    ...
# 891       STONIEDALE DOUGLAS AVENUE        empty  ...                  empty
# 901                           empty        empty  ...                  empty
# 902                           empty        empty  ...                  empty
# 903                           empty        empty  ...                  empty
# 908                           empty        empty  ...                  empty
#
#     Opt In     Contact Type Odyssey Members     Lead Brand Lead Sub-Brand  \
# 2      YES  Email and Phone              NO  Karma Resorts          Other
# 6      YES  Email and Phone              NO  Karma Resorts          Other
# 13     YES  Email and Phone              NO  Karma Resorts          Other
# 16     YES  Email and Phone              NO  Karma Resorts          Other
# 18     YES  Email and Phone              NO  Karma Resorts          Other
# ..     ...              ...             ...            ...            ...
# 891    YES  Email and Phone              NO  Karma Resorts          Other
# 901    YES       Email Only              NO  Karma Resorts          Other
# 902    YES       Email Only              NO  Karma Resorts          Other
# 903    YES       Email Only              NO  Karma Resorts          Other
# 908    YES       Email Only              NO  Karma Resorts          Other
#
#      Lead Source                           Lead Locations  \
# 2    Past Guests                   Karma Lake of Menteith
# 6    Past Guests                    Karma Royal Candidasa
# 13   Past Guests             KRR @ Karma Kandara, Phase V
# 16   Past Guests             KRR @ Karma Kandara, Phase V
# 18   Past Guests  KRR @ Karma Kandara, Mentari Residences
# ..           ...                                      ...
# 891  Past Guests                   Karma Lake of Menteith
# 901  Past Guests        Wyndham -  Manoir des Deux Amants
# 902  Past Guests        Wyndham -  Manoir des Deux Amants
# 903  Past Guests        Wyndham -  Manoir des Deux Amants
# 908  Past Guests        Wyndham -  Manoir des Deux Amants
#
#     Lead Source Description Exclude From Mailing
# 2                 Viewpoint                   NO
# 6                 Viewpoint                   NO
# 13                Viewpoint                   NO
# 16                Viewpoint                   NO
# 18                Viewpoint                   NO
# ..                      ...                  ...
# 891               Viewpoint                   NO
# 901               Viewpoint                   NO
# 902               Viewpoint                   NO
# 903               Viewpoint                   NO
# 908               Viewpoint                   NO
#
# [191 rows x 37 columns]

# %%
df_viewpoint.drop_duplicates(subset=['Phone','Mobile','Email'], inplace=True)
df_viewpoint.reset_index(drop=True, inplace=True)

# hitung jumlah setelah value duplicate dihapus
count_after_dedup_duplicate = df_viewpoint.shape[0]

df_viewpoint
# Out:
#      Title                    Firstname     lastname                  DOB  \
# 0       Mr                       Andrew        Rands                empty
# 1       Mr                    Alexander  Duncan-Kemp                empty
# 2       Mr                  John Robert      Doherty                empty
# 3       Mr                      Allison        Nibbs  1975-05-04 00:00:00
# 4       Mr               Andrew William     Charlett  1953-08-27 00:00:00
# ..     ...                          ...          ...                  ...
# 715  empty           Renaudier, Nicolas            -                empty
# 716  empty             Cugier, Valentin            -                empty
# 717  empty            Grange, Sebastien            -                empty
# 718  empty  Mckenna, David & Geertruida            -                empty
# 719  empty      Tuki, Robyn & Alexander            -                empty
#
#     PAN CARD                              Email        Phone       Mobile  \
# 0      empty                    a.rands@mac.com  61438951450        empty
# 1      empty  alex.duncankemp@adkminserv.com.au  61893710257  61419918165
# 2      empty              alidade1980@gmail.com  61400001370        empty
# 3      empty     allison.nibbs@harcourts.com.au  61419597139        empty
# 4      empty                 andychar@yahoo.com  61404023936        empty
# ..       ...                                ...          ...          ...
# 715    empty                            expedia        17765        empty
# 716    empty                            expedia        empty        empty
# 717    empty                      expedia-hotel        empty        empty
# 718    empty          trudymckenna@iinet.net.au    438551210    408705418
# 719    empty              tukiwhanau@xtra.co.nz   6478395233  64274529685
#
#               AddressLine1    AddressLine2  ... Sales Rep and Comments Opt In  \
# 0             2 KIRRA ROAD  SECRET HARBOUR  ...                  RAFIK    YES
# 1         184 SIXTH AVENUE           empty  ...                  empty    YES
# 2     105 ALEXANDER AVENUE           empty  ...                  empty    YES
# 3                    empty           empty  ...                 Dennis    YES
# 4    33A HILLSIDE CRESCENT           empty  ...                  empty    YES
# ..                     ...             ...  ...                    ...    ...
# 715                  empty           empty  ...                  empty    YES
# 716                  empty           empty  ...                  empty    YES
# 717                  empty           empty  ...                  empty    YES
# 718                  empty           empty  ...                  empty    YES
# 719                  empty           empty  ...                  empty    YES
#
#         Contact Type Odyssey Members     Lead Brand Lead Sub-Brand  \
# 0    Email and Phone              NO  Karma Resorts          Other
# 1    Email and Phone              NO  Karma Resorts          Other
# 2    Email and Phone              NO  Karma Resorts          Other
# 3    Email and Phone              NO  Karma Resorts          Other
# 4    Email and Phone              NO  Karma Resorts          Other
# ..               ...             ...            ...            ...
# 715  Email and Phone              NO  Karma Resorts          Other
# 716       Email Only              NO  Karma Resorts          Other
# 717       Email Only              NO  Karma Resorts          Other
# 718  Email and Phone              NO  Karma Resorts          Other
# 719  Email and Phone              NO  Karma Resorts          Other
#
#      Lead Source                     Lead Locations Lead Source Description  \
# 0    Past Guests               Karma Royal Jimbaran               Viewpoint
# 1    Past Guests             Karma Lake of Menteith               Viewpoint
# 2    Past Guests            Karma Royal Boat Lagoon               Viewpoint
# 3    Past Guests            Karma Borgo Di Colleoli               Viewpoint
# 4    Past Guests              Karma Royal Candidasa               Viewpoint
# ..           ...                                ...                     ...
# 715  Past Guests  Wyndham -  Manoir des Deux Amants               Viewpoint
# 716  Past Guests  Wyndham -  Manoir des Deux Amants               Viewpoint
# 717  Past Guests  Wyndham -  Manoir des Deux Amants               Viewpoint
# 718  Past Guests  Wyndham -  Manoir des Deux Amants               Viewpoint
# 719  Past Guests  Wyndham -  Manoir des Deux Amants               Viewpoint
#
#     Exclude From Mailing
# 0                     NO
# 1                     NO
# 2                     NO
# 3                     NO
# 4                     NO
# ..                   ...
# 715                   NO
# 716                   NO
# 717                   NO
# 718                   NO
# 719                   NO
#
# [720 rows x 37 columns]

# %%
find_member_booking = df_viewpoint.copy()

find_member_booking.loc[find_member_booking['Phone'].isin(df_phone['Mobile']), 'Same Value Find'] = 'Member-Mobile' 
find_member_booking.loc[find_member_booking['Mobile'].isin(df_phone['Mobile']), 'Same Value Find'] = 'Member-Mobile'

find_member_booking.loc[find_member_booking['Email'].isin(df_email['Email']), 'Same Value Find'] = 'Member-Email'
find_member_booking.drop(find_member_booking.loc[find_member_booking['Same Value Find'].isna()].index, inplace=True)

# %%
find_member_booking
# Out:
#     Title       Firstname     lastname                  DOB PAN CARD  \
# 0      Mr          Andrew        Rands                empty    empty
# 1      Mr       Alexander  Duncan-Kemp                empty    empty
# 2      Mr     John Robert      Doherty                empty    empty
# 4      Mr  Andrew William     Charlett  1953-08-27 00:00:00    empty
# 5      Ms          Angela       Anjoul                empty    empty
# ..    ...             ...          ...                  ...      ...
# 702    Mr          Thomas     Crawford                empty    empty
# 703    Mr           Wayne       Lawler  1967-11-06 00:00:00    empty
# 704    Mr          Adrian        Ralph  1959-05-21 00:00:00    empty
# 706    Mr           David       Taylor  1960-09-28 00:00:00    empty
# 709    Mr           Zuber     Mohammad  1991-10-22 00:00:00    empty
#
#                                  Email         Phone        Mobile  \
# 0                      a.rands@mac.com   61438951450         empty
# 1    alex.duncankemp@adkminserv.com.au   61893710257   61419918165
# 2                alidade1980@gmail.com   61400001370         empty
# 4                   andychar@yahoo.com   61404023936         empty
# 5              angelahani525@gmail.com   61402357894         empty
# ..                                 ...           ...           ...
# 702           s.crawford57@outlook.com  447818651943         empty
# 703             sacricket125@gmail.com  447956395834         empty
# 704                 stanandann@aol.com  447923041816  447923041816
# 706              taylor4dave@gmail.com  447879414710         empty
# 709         sameerah.desnavi@gmail.com   12133218580         empty
#
#                   AddressLine1    AddressLine2  ... Opt In     Contact Type  \
# 0                 2 KIRRA ROAD  SECRET HARBOUR  ...    YES  Email and Phone
# 1             184 SIXTH AVENUE           empty  ...    YES  Email and Phone
# 2         105 ALEXANDER AVENUE           empty  ...    YES  Email and Phone
# 4        33A HILLSIDE CRESCENT           empty  ...    YES  Email and Phone
# 5             371 GALSTON ROAD           empty  ...    YES  Email and Phone
# ..                         ...             ...  ...    ...              ...
# 702                94 Woodside           empty  ...    YES  Email and Phone
# 703           43 Bramble Close      Broad Lane  ...    YES  Email and Phone
# 704  STONIEDALE DOUGLAS AVENUE           empty  ...    YES  Email and Phone
# 706              31 Manor Road           empty  ...    YES  Email and Phone
# 709          31049 NW Moon St.           empty  ...    YES  Email and Phone
#
#     Odyssey Members     Lead Brand Lead Sub-Brand  Lead Source  \
# 0                NO  Karma Resorts          Other  Past Guests
# 1                NO  Karma Resorts          Other  Past Guests
# 2                NO  Karma Resorts          Other  Past Guests
# 4                NO  Karma Resorts          Other  Past Guests
# 5                NO  Karma Resorts          Other  Past Guests
# ..              ...            ...            ...          ...
# 702              NO  Karma Resorts          Other  Past Guests
# 703              NO  Karma Resorts          Other  Past Guests
# 704              NO  Karma Resorts          Other  Past Guests
# 706              NO  Karma Resorts          Other  Past Guests
# 709              NO  Karma Resorts          Other  Past Guests
#
#               Lead Locations Lead Source Description Exclude From Mailing  \
# 0       Karma Royal Jimbaran               Viewpoint                   NO
# 1     Karma Lake of Menteith               Viewpoint                   NO
# 2    Karma Royal Boat Lagoon               Viewpoint                   NO
# 4      Karma Royal Candidasa               Viewpoint                   NO
# 5    Karma Borgo Di Colleoli               Viewpoint                   NO
# ..                       ...                     ...                  ...
# 702       Karma Salford Hall               Viewpoint                   NO
# 703       Karma Salford Hall               Viewpoint                   NO
# 704   Karma Lake of Menteith               Viewpoint                   NO
# 706       Karma Salford Hall               Viewpoint                   NO
# 709            Karma Bavaria               Viewpoint                   NO
#
#     Same Value Find
# 0      Member-Email
# 1      Member-Email
# 2      Member-Email
# 4      Member-Email
# 5      Member-Email
# ..              ...
# 702    Member-Email
# 703    Member-Email
# 704    Member-Email
# 706    Member-Email
# 709    Member-Email
#
# [496 rows x 38 columns]

# %%
find_member_booking.replace('empty', '', inplace=True)
find_member_booking.to_csv(r'C:\Users\fajar\Documents\Python\Data\cek_member_viewpoint.csv', index=False)

# %%
count_dedup_member = df_viewpoint.loc[
    
    df_viewpoint['Phone'].isin(df_phone['Mobile']) | 
    df_viewpoint['Mobile'].isin(df_phone['Mobile']) |

    df_viewpoint['Email'].isin(df_email['Email'])
    ].shape[0]

df_viewpoint.loc[
    
    df_viewpoint['Phone'].isin(df_phone['Mobile']) | 
    df_viewpoint['Mobile'].isin(df_phone['Mobile']) |

    df_viewpoint['Email'].isin(df_email['Email'])
    ]
# Out:
#     Title       Firstname     lastname                  DOB PAN CARD  \
# 0      Mr          Andrew        Rands                empty    empty
# 1      Mr       Alexander  Duncan-Kemp                empty    empty
# 2      Mr     John Robert      Doherty                empty    empty
# 4      Mr  Andrew William     Charlett  1953-08-27 00:00:00    empty
# 5      Ms          Angela       Anjoul                empty    empty
# ..    ...             ...          ...                  ...      ...
# 702    Mr          Thomas     Crawford                empty    empty
# 703    Mr           Wayne       Lawler  1967-11-06 00:00:00    empty
# 704    Mr          Adrian        Ralph  1959-05-21 00:00:00    empty
# 706    Mr           David       Taylor  1960-09-28 00:00:00    empty
# 709    Mr           Zuber     Mohammad  1991-10-22 00:00:00    empty
#
#                                  Email         Phone        Mobile  \
# 0                      a.rands@mac.com   61438951450         empty
# 1    alex.duncankemp@adkminserv.com.au   61893710257   61419918165
# 2                alidade1980@gmail.com   61400001370         empty
# 4                   andychar@yahoo.com   61404023936         empty
# 5              angelahani525@gmail.com   61402357894         empty
# ..                                 ...           ...           ...
# 702           s.crawford57@outlook.com  447818651943         empty
# 703             sacricket125@gmail.com  447956395834         empty
# 704                 stanandann@aol.com  447923041816  447923041816
# 706              taylor4dave@gmail.com  447879414710         empty
# 709         sameerah.desnavi@gmail.com   12133218580         empty
#
#                   AddressLine1    AddressLine2  ... Sales Rep and Comments  \
# 0                 2 KIRRA ROAD  SECRET HARBOUR  ...                  RAFIK
# 1             184 SIXTH AVENUE           empty  ...                  empty
# 2         105 ALEXANDER AVENUE           empty  ...                  empty
# 4        33A HILLSIDE CRESCENT           empty  ...                  empty
# 5             371 GALSTON ROAD           empty  ...                  empty
# ..                         ...             ...  ...                    ...
# 702                94 Woodside           empty  ...               Victoria
# 703           43 Bramble Close      Broad Lane  ...               Victoria
# 704  STONIEDALE DOUGLAS AVENUE           empty  ...                  empty
# 706              31 Manor Road           empty  ...                Alex S.
# 709          31049 NW Moon St.           empty  ...                  Steve
#
#     Opt In     Contact Type Odyssey Members     Lead Brand Lead Sub-Brand  \
# 0      YES  Email and Phone              NO  Karma Resorts          Other
# 1      YES  Email and Phone              NO  Karma Resorts          Other
# 2      YES  Email and Phone              NO  Karma Resorts          Other
# 4      YES  Email and Phone              NO  Karma Resorts          Other
# 5      YES  Email and Phone              NO  Karma Resorts          Other
# ..     ...              ...             ...            ...            ...
# 702    YES  Email and Phone              NO  Karma Resorts          Other
# 703    YES  Email and Phone              NO  Karma Resorts          Other
# 704    YES  Email and Phone              NO  Karma Resorts          Other
# 706    YES  Email and Phone              NO  Karma Resorts          Other
# 709    YES  Email and Phone              NO  Karma Resorts          Other
#
#      Lead Source           Lead Locations Lead Source Description  \
# 0    Past Guests     Karma Royal Jimbaran               Viewpoint
# 1    Past Guests   Karma Lake of Menteith               Viewpoint
# 2    Past Guests  Karma Royal Boat Lagoon               Viewpoint
# 4    Past Guests    Karma Royal Candidasa               Viewpoint
# 5    Past Guests  Karma Borgo Di Colleoli               Viewpoint
# ..           ...                      ...                     ...
# 702  Past Guests       Karma Salford Hall               Viewpoint
# 703  Past Guests       Karma Salford Hall               Viewpoint
# 704  Past Guests   Karma Lake of Menteith               Viewpoint
# 706  Past Guests       Karma Salford Hall               Viewpoint
# 709  Past Guests            Karma Bavaria               Viewpoint
#
#     Exclude From Mailing
# 0                     NO
# 1                     NO
# 2                     NO
# 4                     NO
# 5                     NO
# ..                   ...
# 702                   NO
# 703                   NO
# 704                   NO
# 706                   NO
# 709                   NO
#
# [496 rows x 37 columns]

# %%
df_viewpoint.drop(df_viewpoint.loc[
    
    df_viewpoint['Phone'].isin(df_phone['Mobile']) | 
    df_viewpoint['Mobile'].isin(df_phone['Mobile']) |

    df_viewpoint['Email'].isin(df_email['Email'])
].index, inplace=True)

df_viewpoint.reset_index(drop=True, inplace=True)

count_after_dedup_member = df_viewpoint.shape[0]

# %%
count_data_akhir = df_viewpoint.shape[0]

# %%
df_viewpoint.sort_values('CheckOutDate', ascending=True, inplace=True)
df_viewpoint.reset_index(drop=True, inplace=True)
df_viewpoint
# Out:
#     Title    Firstname  lastname                  DOB    PAN CARD  \
# 0      Mr       Madhur    Bhatia                empty       empty
# 1      Mr       Sudhir     Dayal  1977-09-03 00:00:00       empty
# 2     Mrs        Reena   Kaushik  1988-03-08 00:00:00  CAKPR8330N
# 3     Mrs        Tammy    Wilson                empty       empty
# 4     Mrs        Anita     Gundi                empty       empty
# ..    ...          ...       ...                  ...         ...
# 219    Mr     Sukhjeet     Singh  1986-03-27 00:00:00       empty
# 220    Mr        Ricky   Mullins  1990-10-31 00:00:00       empty
# 221   Mrs        Pooja   Pradeep                empty       empty
# 222    Mr  Vinay Ashok  Jagjivan                empty       empty
# 223    Mr    Mr.Vishal      Jain                empty       empty
#
#                           Email         Phone        Mobile  \
# 0       madhurbhatia4@gmail.com  919871928208  918860477740
# 1     sudhirdayal0309@gmail.com  919811480757  919818507577
# 2    umeshsharma_1985@yahoo.com  919643408357  919760262387
# 3     tammywilson29@hotmail.com   61431309473         empty
# 4             apgundi@gmail.com   15107082927         empty
# ..                          ...           ...           ...
# 219  manpreetsaini109@gmail.com  919876662572  918427083031
# 220    rickymullins@hotmail.com   64273880879         empty
# 221  pooja.pradeep432@gmail.com         empty         empty
# 222   jagjivanvinay27@gmail.com  919689993200  919168513200
# 223     jainvishal150@gmail.com  919872429150  919779263517
#
#                                           AddressLine1  \
# 0                           PALAM VIHAR GURGAON 122017
# 1          C-201, GREEN VALLEY APARTMENTS, PLOT NO. 18
# 2          H.no. 1401, J-block, Sumadhura Eden Garden,
# 3                                                    -
# 4                   SUNNY SIDE #21, KHOTNUR CROSS ROAD
# ..                                                 ...
# 219        HOUSE NO 279, WARD NO 13, G T ROAD BHOGPUR,
# 220                                43 Kahu St, Burnham
# 221                                                  .
# 222  32, VYANKATESHWARA NAGAR NEAR AMBIKA MANGAL KA...
# 223           WARD NO 7 JAIN MOHALLA BANUR DIST MOHALI
#
#                              AddressLine2  ... Sales Rep and Comments Opt In  \
# 0                                   empty  ...                DELICIA    YES
# 1                           , SECTOR -22,  ...        MERVILLE VIEGAS    YES
# 2             Whitefield, Doddabanahalli,  ...                  empty    YES
# 3                                       -  ...                  empty    YES
# 4    3RD CROSS, S.R COMPOUND BANNERGHATTA  ...         Adarsh Agrawal    YES
# ..                                    ...  ...                    ...    ...
# 219                     JALANDHAR, PUNJAB  ...                  empty    YES
# 220                                 empty  ...                  empty    YES
# 221                                 empty  ...                  empty    YES
# 222                                 empty  ...               ASHWARYA    YES
# 223                                 empty  ...        HARSHVEER SIBGH    YES
#
#         Contact Type Odyssey Members     Lead Brand Lead Sub-Brand  \
# 0    Email and Phone              NO  Karma Resorts          Other
# 1    Email and Phone              NO  Karma Resorts          Other
# 2    Email and Phone              NO  Karma Resorts          Other
# 3    Email and Phone              NO  Karma Resorts          Other
# 4    Email and Phone              NO  Karma Resorts          Other
# ..               ...             ...            ...            ...
# 219  Email and Phone              NO  Karma Resorts          Other
# 220  Email and Phone              NO  Karma Resorts          Other
# 221       Email Only              NO  Karma Resorts          Other
# 222  Email and Phone              NO  Karma Resorts          Other
# 223  Email and Phone              NO  Karma Resorts          Other
#
#      Lead Source                           Lead Locations  \
# 0    Past Guests                 Karma Royal Haathi Mahal
# 1    Past Guests                  Karma Sitabani, Corbett
# 2    Past Guests                 Karma Royal Haathi Mahal
# 3    Past Guests             KRR @ Karma Kandara, Phase V
# 4    Past Guests                     Karma Royal Monterio
# ..           ...                                      ...
# 219  Past Guests                     Karma Haveli, Jaipur
# 220  Past Guests  KRR @ Karma Kandara, Mentari Residences
# 221  Past Guests                     Karma Chakra, Kerala
# 222  Past Guests                        Karma Royal Palms
# 223  Past Guests                  Karma Sitabani, Corbett
#
#     Lead Source Description Exclude From Mailing
# 0                 Viewpoint                   NO
# 1                 Viewpoint                   NO
# 2                 Viewpoint                   NO
# 3                 Viewpoint                   NO
# 4                 Viewpoint                   NO
# ..                      ...                  ...
# 219               Viewpoint                   NO
# 220               Viewpoint                   NO
# 221               Viewpoint                   NO
# 222               Viewpoint                   NO
# 223               Viewpoint                   NO
#
# [224 rows x 37 columns]

# %%
# find_member_booking[['Email','Same Value Find']].loc[find_member_booking['BookingNo'] == '2074237']
# df_viewpoint.loc[df_viewpoint['BookingNo'] == '2097221']
# df_viewpoint.loc[df_viewpoint['Email'].str.contains('prajuizn@gmail.com')]

# %%
df_viewpoint['DOB'].replace('empty', '', inplace=True)
dob_con_date = pd.to_datetime(df_viewpoint['DOB'])
dob_date = dob_con_date.dt.strftime('%Y-%m-%d')

arr_con_date = pd.to_datetime(df_viewpoint['Arrival'])
arr_date = arr_con_date.dt.strftime('%Y-%m-%d')

dep_con_date = pd.to_datetime(df_viewpoint['Departure'])
dep_date = dep_con_date.dt.strftime('%Y-%m-%d')

ci_con_date = pd.to_datetime(df_viewpoint['CheckInDate'])
ci_date = ci_con_date.dt.strftime('%Y-%m-%d')

co_con_date = pd.to_datetime(df_viewpoint['CheckOutDate'])
co_date = co_con_date.dt.strftime('%Y-%m-%d')

df_viewpoint['DOB'] = dob_date
df_viewpoint['Arrival'] = arr_date
df_viewpoint['Departure'] = dep_date
df_viewpoint['CheckInDate'] = ci_date
df_viewpoint['CheckOutDate'] = co_date

# %%
df_viewpoint.columns
# Out:
# Index(['Title', 'Firstname', 'lastname', 'DOB', 'PAN CARD', 'Email', 'Phone',
#        'Mobile', 'AddressLine1', 'AddressLine2', 'Town', 'State', 'Country',
#        'PostCode', 'Nationality', 'MaritalStatus', 'resortname', 'Arrival',
#        'Departure', 'CheckInDate', 'CheckOutDate', 'room', 'UnitCategory',
#        'BookingNo', 'BookingSourceDesc', 'BookingTypeDesc', 'Date of Tour',
#        'Sales Rep and Comments', 'Opt In', 'Contact Type', 'Odyssey Members',
#        'Lead Brand', 'Lead Sub-Brand', 'Lead Source', 'Lead Locations',
#        'Lead Source Description', 'Exclude From Mailing'],
#       dtype='object')

# %%
new_cols = ['Lead Brand','Lead Sub-Brand','Lead Source','Lead Locations','Lead Source Description','Title','Firstname','lastname','DOB','Email','Phone','Mobile','AddressLine1','AddressLine2','Town','State',
'Country','PostCode','Nationality','MaritalStatus',	'resortname', 'Arrival', 'Departure', 'CheckInDate', 'CheckOutDate', 'room', 'UnitCategory', 'BookingNo', 'BookingSourceDesc', 'BookingTypeDesc', 'Date of Tour', 'Sales Rep and Comments',	'Opt In', 'Exclude From Mailing', 'Odyssey Members', 'Contact Type']																																																																																																																																						

df_viewpoint = df_viewpoint.reindex(columns=new_cols)

# %%
df_viewpoint.replace('empty', '', inplace=True)

df_viewpoint.sort_values('Departure', ascending=True, inplace=True)
df_viewpoint.reset_index(drop=True, inplace=True)
df_viewpoint
# Out:
#         Lead Brand Lead Sub-Brand  Lead Source  \
# 0    Karma Resorts          Other  Past Guests
# 1    Karma Resorts          Other  Past Guests
# 2    Karma Resorts          Other  Past Guests
# 3    Karma Resorts          Other  Past Guests
# 4    Karma Resorts          Other  Past Guests
# ..             ...            ...          ...
# 219  Karma Resorts          Other  Past Guests
# 220  Karma Resorts          Other  Past Guests
# 221  Karma Resorts          Other  Past Guests
# 222  Karma Resorts          Other  Past Guests
# 223  Karma Resorts          Other  Past Guests
#
#                         Lead Locations Lead Source Description Title  \
# 0             Karma Royal Haathi Mahal               Viewpoint    Mr
# 1                 Karma Royal Monterio               Viewpoint    Mr
# 2                    Karma Royal Palms               Viewpoint    Mr
# 3                 Karma Royal Monterio               Viewpoint    Mr
# 4                       Karma Jimbaran               Viewpoint   Mrs
# ..                                 ...                     ...   ...
# 219                  Karma Royal Palms               Viewpoint    Mr
# 220                  Karma Royal Palms               Viewpoint    Mr
# 221  Wyndham -  Manoir des Deux Amants               Viewpoint
# 222            Karma Sitabani, Corbett               Viewpoint    Mr
# 223            Karma Sitabani, Corbett               Viewpoint    Mr
#
#               Firstname                   lastname         DOB  \
# 0                Madhur                     Bhatia         NaN
# 1                Deepak                        L T         NaN
# 2       Mohammad Salman                  Kothiwale         NaN
# 3                Rupesh                      Mehta         NaN
# 4                 Gusti  Ayu Dewi Utami Sudjiwa Ba  1982-12-13
# ..                  ...                        ...         ...
# 219              Sumant                   Satarkar         NaN
# 220        Irfan Irshad                       Khan         NaN
# 221  Roux, Jean-Bastien                          -         NaN
# 222              Ujjval                     .Kumar         NaN
# 223           Mr.Vishal                       Jain         NaN
#
#                           Email  ...                    UnitCategory  \
# 0       madhurbhatia4@gmail.com  ...               Hotel Unit Deluxe
# 1         deepakltmca@gmail.com  ...             1 Bedroom Apartment
# 2    salman.kothiwale@gmail.com  ...             1 Bedroom Apartment
# 3       khushburm1713@gmail.com  ...             1 Bedroom Apartment
# 4          amisudjiwa@gmail.com  ...  3 Bedroom Garden View Pool Vil
# ..                          ...  ...                             ...
# 219          myora.23@gmail.com  ...            Non Member 1 Bedroom
# 220          shirfian@gmail.com  ...            Non Member 1 Bedroom
# 221                 booking.com  ...             1 Bedroom Apartment
# 222       ujjvals1983@gmail.com  ...           Non Member Hotel Unit
# 223     jainvishal150@gmail.com  ...           Non Member Hotel Unit
#
#     BookingNo     BookingSourceDesc                         BookingTypeDesc  \
# 0     2553102        Fly Buy Indian                  Karma Experience India
# 1     2605447        Fly Buy Indian                  Karma Experience India
# 2     2581202  Karma Club Discovery  Karma Club Discovery Entitlement Guest
# 3     2603948        Fly Buy Indian                  Karma Experience India
# 4     2591084        Hotel Bookings                         Nakula - Rental
# ..        ...                   ...                                     ...
# 219   2613529        Fly Buy Indian                  Karma Experience India
# 220   2611040        Fly Buy Indian                  Karma Experience India
# 221   2616712        Hotel Bookings                          Wyndham Guests
# 222   2612737        Fly Buy Indian                  Karma Experience India
# 223   2601294           KCE2 Indian                  Karma Experience India
#
#             Date of Tour Sales Rep and Comments Opt In Exclude From Mailing  \
# 0    2024-09-07 18:05:00                DELICIA    YES                   NO
# 1    2024-09-08 12:25:00                 Mahesh    YES                   NO
# 2                                                  YES                   NO
# 3    2024-09-08 12:23:00              Pratiksha    YES                   NO
# 4                                                  YES                   NO
# ..                   ...                    ...    ...                  ...
# 219                                                YES                   NO
# 220                                                YES                   NO
# 221                                                YES                   NO
# 222                                                YES                   NO
# 223  2024-09-12 10:30:00        HARSHVEER SIBGH    YES                   NO
#
#     Odyssey Members     Contact Type
# 0                NO  Email and Phone
# 1                NO  Email and Phone
# 2                NO  Email and Phone
# 3                NO  Email and Phone
# 4                NO  Email and Phone
# ..              ...              ...
# 219              NO  Email and Phone
# 220              NO  Email and Phone
# 221              NO  Email and Phone
# 222              NO  Email and Phone
# 223              NO  Email and Phone
#
# [224 rows x 36 columns]

# %%
print("==========================================================")
print("Summary")
print("==========================================================")
print("Jumlah Data Setelah Script Past Guest Sebelumnya : "+str(count_data_awal))
print("Jumlah Data Yang Duplicate : "+str(count_duplicate_general))
print("Jumlah Data Setelah Hapus Duplicate : "+str(count_after_dedup_duplicate))
print("Jumlah Data Yang Termasuk Member: "+str(count_dedup_member))
print("Jumlah Data Setelah Hapus Member : "+str(count_after_dedup_member))
print("Jumlah Data Akhir : "+str(count_data_akhir))
# Out:
# ==========================================================
# Summary
# ==========================================================
# Jumlah Data Setelah Script Past Guest Sebelumnya : 911
# Jumlah Data Yang Duplicate : 191
# Jumlah Data Setelah Hapus Duplicate : 720
# Jumlah Data Yang Termasuk Member: 496
# Jumlah Data Setelah Hapus Member : 224
# Jumlah Data Akhir : 224

# %%
df_viewpoint.to_excel(r'C:\Users\fajar\Documents\Python\Data\final_viewpoint.xlsx', index=False)
