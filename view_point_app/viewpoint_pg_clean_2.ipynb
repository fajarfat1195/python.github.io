# %%
import pandas as pd
import re

import past_guest_module as pm

import sys
sys.path.append('../zoho_data_app/')

import main_module as m

# %load_ext autoreload
# %autoreload 2

# %%
path = r'C:\Users\fajar\Documents\Python\Data\check_country_code_viewpoint.xlsx'
df_viewpoint = pd.read_excel(path, dtype='string', sheet_name='Sheet1')
count_data_awal = df_viewpoint.shape[0]

# %%
df_viewpoint.fillna('empty', inplace=True)

# %%
path = r'G:\.shortcut-targets-by-id\0B_d3smBjzo04UUNBME5GOVhoMjA\_ODYSSEY\Phone Members.xlsx'
df_phone = pd.read_excel(path, dtype='string', sheet_name='Sheet1')

path = r'G:\.shortcut-targets-by-id\0B_d3smBjzo04UUNBME5GOVhoMjA\_ODYSSEY\Email Members.xlsx'
df_email = pd.read_excel(path, dtype='string', sheet_name='Sheet1')

# %%
m.clean_space(df_email, 'Email')
df_email['Email'] = m.lowercase(df_email, 'Email')

# %%
# hitung jumlah duplicate
count_duplicate_general = df_viewpoint.loc[df_viewpoint.duplicated(subset=['Phone','Mobile','Email'])].shape[0]

df_viewpoint.loc[df_viewpoint.duplicated(subset=['Phone','Mobile','Email'])]
# Out:
#       Title                          Firstname     lastname  \
# 2       Mrs                            Zoubida         Tazi
# 32       Mr                              Chris  Haydon-Wood
# 33       Mr                              Chris  Haydon-Wood
# 55       Mr                        Peter David      Jackson
# 66       Mr                             Verner       Nissen
# ...     ...                                ...          ...
# 1605  empty  Lea Dujardin, Arnaud Defrance And            -
# 1606  empty                     Gorgeu, Amaury            -
# 1607  empty                   Collins, Rebecca            -
# 1614  empty                 Chabrol, Stephanie            -
# 1625  empty                               Hong            /
#
#                       DOB PAN CARD                        Email         Phone  \
# 2                   empty    empty       adilben.ta2i@gmail.com  971527616214
# 32                  empty    empty  chrishaydonwood72@gmail.com   61410856407
# 33                  empty    empty  chrishaydonwood72@gmail.com   61410856407
# 55    1968-08-15 00:00:00    empty          feralfarm@gmail.com   61428710756
# 66    1945-05-13 00:00:00    empty     hjorthhealth@bigpond.com   61409200546
# ...                   ...      ...                          ...           ...
# 1605                empty    empty                  booking.com         empty
# 1606                empty    empty                  booking.com         empty
# 1607                empty    empty                  booking.com         empty
# 1614                empty    empty                       direct         empty
# 1625                empty    empty              info@nakula.com  628113855855
#
#            Mobile        AddressLine1 AddressLine2  ...  \
# 2           empty                   .            .  ...
# 32    61410856407           Australia        empty  ...
# 33    61410856407           Australia        empty  ...
# 55          empty  12 Fishermans Lane        empty  ...
# 66          empty   22 WARATAH STREET        empty  ...
# ...           ...                 ...          ...  ...
# 1605        empty               empty        empty  ...
# 1606        empty               empty        empty  ...
# 1607        empty               empty        empty  ...
# 1614        empty               empty        empty  ...
# 1625        empty               empty        empty  ...
#
#      Sales Rep and Comments Opt In     Contact Type Odyssey Members  \
# 2                     empty    YES  Email and Phone              NO
# 32                    empty    YES  Email and Phone              NO
# 33                    empty    YES  Email and Phone              NO
# 55                    empty    YES  Email and Phone              NO
# 66                  Kevin L    YES  Email and Phone              NO
# ...                     ...    ...              ...             ...
# 1605                  empty    YES       Email Only              NO
# 1606                  empty    YES       Email Only              NO
# 1607                  empty    YES       Email Only              NO
# 1614                  empty    YES       Email Only              NO
# 1625                  empty    YES  Email and Phone              NO
#
#          Lead Brand Lead Sub-Brand  Lead Source  \
# 2     Karma Resorts          Other  Past Guests
# 32    Karma Resorts          Other  Past Guests
# 33    Karma Resorts          Other  Past Guests
# 55    Karma Resorts          Other  Past Guests
# 66    Karma Resorts          Other  Past Guests
# ...             ...            ...          ...
# 1605  Karma Resorts          Other  Past Guests
# 1606  Karma Resorts          Other  Past Guests
# 1607  Karma Resorts          Other  Past Guests
# 1614  Karma Resorts          Other  Past Guests
# 1625  Karma Resorts          Other  Past Guests
#
#                                Lead Locations Lead Source Description  \
# 2                            Karma La Herriza               Viewpoint
# 32    KRR @ Karma Kandara, Mentari Residences               Viewpoint
# 33               KRR @ Karma Kandara, Phase V               Viewpoint
# 55    KRR @ Karma Kandara, Mentari Residences               Viewpoint
# 66                          Karma Royal Sanur               Viewpoint
# ...                                       ...                     ...
# 1605        Wyndham -  Manoir des Deux Amants               Viewpoint
# 1606        Wyndham -  Manoir des Deux Amants               Viewpoint
# 1607        Wyndham -  Manoir des Deux Amants               Viewpoint
# 1614        Wyndham -  Manoir des Deux Amants               Viewpoint
# 1625                           Karma Jimbaran               Viewpoint
#
#      Exclude From Mailing
# 2                      NO
# 32                     NO
# 33                     NO
# 55                     NO
# 66                     NO
# ...                   ...
# 1605                   NO
# 1606                   NO
# 1607                   NO
# 1614                   NO
# 1625                   NO
#
# [358 rows x 37 columns]

# %%
df_viewpoint.drop_duplicates(subset=['Phone','Mobile','Email'], inplace=True)
df_viewpoint.reset_index(drop=True, inplace=True)

# hitung jumlah setelah value duplicate dihapus
count_after_dedup_duplicate = df_viewpoint.shape[0]

df_viewpoint
# Out:
#       Title                          Firstname    lastname  \
# 0     empty                            Agustin     Obarrio
# 1        Mr                               Adil  Benboubker
# 2        Mr                             Andrew        Till
# 3        Mr                              Allan     Godfrey
# 4        Mr                                Jay     Naicker
# ...     ...                                ...         ...
# 1264  empty                 Hansen, Anne-Sofie           -
# 1265  empty  Marius Rafaliarintsoa, Hajaniaina           -
# 1266  empty                   Theisen, Susanne           -
# 1267  empty            Pattison, Hugh & Jeanie           -
# 1268  empty              Wilson, Keith & Susan           -
#
#                       DOB PAN CARD                              Email  \
# 0     1982-08-03 00:00:00    empty              agusobarrio@gmail.com
# 1                   empty    empty             adilben.ta2i@gmail.com
# 2                   empty    empty                  aftilly@gmail.com
# 3     1966-02-11 00:00:00    empty  agodfrey@royallifesavingwa.com.au
# 4     1959-12-31 00:00:00    empty                airvent@live.com.au
# ...                   ...      ...                                ...
# 1264                empty    empty                      expedia-hotel
# 1265                empty    empty                      expedia-hotel
# 1266                empty    empty                        expedia-net
# 1267                empty    empty             hughpattison@yahoo.com
# 1268                empty    empty                  keith@kewi.com.au
#
#               Phone       Mobile              AddressLine1 AddressLine2  ...  \
# 0     4915223022501        empty                     empty        empty  ...
# 1      971527616214        empty                         .        empty  ...
# 2       61409349099        empty          45 SEAHORSE LOOP        empty  ...
# 3       61430477517        empty              6b Beaton St        empty  ...
# 4       61414355996        empty  54  RUBY AVENUE-LANGFORD            -  ...
# ...             ...          ...                       ...          ...  ...
# 1264         140598        empty                     empty        empty  ...
# 1265          empty        empty                     empty        empty  ...
# 1266          10115        empty                     empty        empty  ...
# 1267     6496254376  64221089976                     empty        empty  ...
# 1268      416020952        empty                     empty        empty  ...
#
#      Sales Rep and Comments Opt In     Contact Type Odyssey Members  \
# 0                     empty    YES  Email and Phone              NO
# 1                     empty    YES  Email and Phone              NO
# 2                     empty    YES  Email and Phone              NO
# 3                     FREYA    YES  Email and Phone              NO
# 4                     empty    YES  Email and Phone              NO
# ...                     ...    ...              ...             ...
# 1264                  empty    YES  Email and Phone              NO
# 1265                  empty    YES       Email Only              NO
# 1266                  empty    YES  Email and Phone              NO
# 1267                  empty    YES  Email and Phone              NO
# 1268                  empty    YES  Email and Phone              NO
#
#          Lead Brand Lead Sub-Brand  Lead Source  \
# 0     Karma Resorts          Other  Past Guests
# 1     Karma Resorts          Other  Past Guests
# 2     Karma Resorts          Other  Past Guests
# 3     Karma Resorts          Other  Past Guests
# 4     Karma Resorts          Other  Past Guests
# ...             ...            ...          ...
# 1264  Karma Resorts          Other  Past Guests
# 1265  Karma Resorts          Other  Past Guests
# 1266  Karma Resorts          Other  Past Guests
# 1267  Karma Resorts          Other  Past Guests
# 1268  Karma Resorts          Other  Past Guests
#
#                          Lead Locations Lead Source Description  \
# 0                         Karma Bavaria               Viewpoint
# 1                      Karma La Herriza               Viewpoint
# 2                Karma Lake of Menteith               Viewpoint
# 3                       Karma Song Hoai               Viewpoint
# 4                           Amina hotel               Viewpoint
# ...                                 ...                     ...
# 1264  Wyndham -  Manoir des Deux Amants               Viewpoint
# 1265  Wyndham -  Manoir des Deux Amants               Viewpoint
# 1266  Wyndham -  Manoir des Deux Amants               Viewpoint
# 1267  Wyndham -  Manoir des Deux Amants               Viewpoint
# 1268  Wyndham -  Manoir des Deux Amants               Viewpoint
#
#      Exclude From Mailing
# 0                      NO
# 1                      NO
# 2                      NO
# 3                      NO
# 4                      NO
# ...                   ...
# 1264                   NO
# 1265                   NO
# 1266                   NO
# 1267                   NO
# 1268                   NO
#
# [1269 rows x 37 columns]

# %%
find_member_booking = df_viewpoint.copy()

find_member_booking.loc[find_member_booking['Phone'].isin(df_phone['Mobile']), 'Same Value Find'] = 'Member-Mobile' 
find_member_booking.loc[find_member_booking['Mobile'].isin(df_phone['Mobile']), 'Same Value Find'] = 'Member-Mobile'

find_member_booking.loc[find_member_booking['Email'].isin(df_email['Email']), 'Same Value Find'] = 'Member-Email'
find_member_booking.drop(find_member_booking.loc[find_member_booking['Same Value Find'].isna()].index, inplace=True)

# %%
find_member_booking
# Out:
#       Title         Firstname  lastname                  DOB PAN CARD  \
# 2        Mr            Andrew      Till                empty    empty
# 3        Mr             Allan   Godfrey  1966-02-11 00:00:00    empty
# 4        Mr               Jay   Naicker  1959-12-31 00:00:00    empty
# 5        Mr              Alan  Bennetts  1957-02-10 00:00:00    empty
# 6        Ms           Allison  Charnock                empty    empty
# ...     ...               ...       ...                  ...      ...
# 1232    Dr.             Sarah  Campbell  1984-03-19 00:00:00    empty
# 1235    Mrs            Tracey     Grout  1980-03-27 00:00:00    empty
# 1237     Mr             Vinay     Kumar  1983-08-19 00:00:00    empty
# 1239    Mrs         Anastasia   Xanthos  1976-09-29 00:00:00    empty
# 1266  empty  Theisen, Susanne         -                empty    empty
#
#                                   Email         Phone       Mobile  \
# 2                     aftilly@gmail.com   61409349099        empty
# 3     agodfrey@royallifesavingwa.com.au   61430477517        empty
# 4                   airvent@live.com.au   61414355996        empty
# 5            alan.bennetts@iinet.net.au   61893791956  61430157009
# 6              allisonjane8@outlook.com         empty        empty
# ...                                 ...           ...          ...
# 1232            surreysarah84@gmail.com  447710250414        empty
# 1235             traceybrewis@gmail.com  447557978157        empty
# 1237               vinaykjoon@gmail.com  447435680435  64226814074
# 1239           anastasiaxanthos@aol.com   16319404009  16317934067
# 1266                        expedia-net         10115        empty
#
#                         AddressLine1 AddressLine2  ... Opt In  \
# 2                   45 SEAHORSE LOOP        empty  ...    YES
# 3                       6b Beaton St        empty  ...    YES
# 4           54  RUBY AVENUE-LANGFORD            -  ...    YES
# 5                 58 CHESTERTON ROAD   BASSENDEAN  ...    YES
# 6      UNIT 10 18-20  SCENIC HIGHWAY        empty  ...    YES
# ...                              ...          ...  ...    ...
# 1232        Flat 1, 99B Redland Road        empty  ...    YES
# 1235  2 OLD STOKE ROAD STOKE CHARITY        empty  ...    YES
# 1237                 72 Clinton Road        empty  ...    YES
# 1239              7 SLEEPY HOLLOW LN            .  ...    YES
# 1266                           empty        empty  ...    YES
#
#          Contact Type Odyssey Members     Lead Brand Lead Sub-Brand  \
# 2     Email and Phone              NO  Karma Resorts          Other
# 3     Email and Phone              NO  Karma Resorts          Other
# 4     Email and Phone              NO  Karma Resorts          Other
# 5     Email and Phone              NO  Karma Resorts          Other
# 6          Email Only              NO  Karma Resorts          Other
# ...               ...             ...            ...            ...
# 1232  Email and Phone              NO  Karma Resorts          Other
# 1235  Email and Phone              NO  Karma Resorts          Other
# 1237  Email and Phone              NO  Karma Resorts          Other
# 1239  Email and Phone              NO  Karma Resorts          Other
# 1266  Email and Phone              NO  Karma Resorts          Other
#
#       Lead Source                     Lead Locations Lead Source Description  \
# 2     Past Guests             Karma Lake of Menteith               Viewpoint
# 3     Past Guests                    Karma Song Hoai               Viewpoint
# 4     Past Guests                        Amina hotel               Viewpoint
# 5     Past Guests                  Karma Royal Sanur               Viewpoint
# 6     Past Guests     Chateau de Samary, Carcassonne               Viewpoint
# ...           ...                                ...                     ...
# 1232  Past Guests                 Karma Salford Hall               Viewpoint
# 1235  Past Guests                   Karma La Herriza               Viewpoint
# 1237  Past Guests                   Karma La Herriza               Viewpoint
# 1239  Past Guests                       Karma Minoan               Viewpoint
# 1266  Past Guests  Wyndham -  Manoir des Deux Amants               Viewpoint
#
#      Exclude From Mailing Same Value Find
# 2                      NO    Member-Email
# 3                      NO    Member-Email
# 4                      NO    Member-Email
# 5                      NO    Member-Email
# 6                      NO    Member-Email
# ...                   ...             ...
# 1232                   NO    Member-Email
# 1235                   NO    Member-Email
# 1237                   NO    Member-Email
# 1239                   NO    Member-Email
# 1266                   NO    Member-Email
#
# [843 rows x 38 columns]

# %%
find_member_booking.replace('empty', '', inplace=True)
find_member_booking.to_csv(r'C:\Users\fajar\Documents\Python\Data\cek_member_viewpoint.csv', index=False)

# %%
count_dedup_member = df_viewpoint.loc[
    
    df_viewpoint['Phone'].isin(df_phone['Mobile']) | 
    df_viewpoint['Mobile'].isin(df_phone['Mobile']) |

    df_viewpoint['Email'].isin(df_email['Email'])
    ].shape[0]

df_viewpoint.loc[
    
    df_viewpoint['Phone'].isin(df_phone['Mobile']) | 
    df_viewpoint['Mobile'].isin(df_phone['Mobile']) |

    df_viewpoint['Email'].isin(df_email['Email'])
    ]
# Out:
#       Title         Firstname  lastname                  DOB PAN CARD  \
# 2        Mr            Andrew      Till                empty    empty
# 3        Mr             Allan   Godfrey  1966-02-11 00:00:00    empty
# 4        Mr               Jay   Naicker  1959-12-31 00:00:00    empty
# 5        Mr              Alan  Bennetts  1957-02-10 00:00:00    empty
# 6        Ms           Allison  Charnock                empty    empty
# ...     ...               ...       ...                  ...      ...
# 1232    Dr.             Sarah  Campbell  1984-03-19 00:00:00    empty
# 1235    Mrs            Tracey     Grout  1980-03-27 00:00:00    empty
# 1237     Mr             Vinay     Kumar  1983-08-19 00:00:00    empty
# 1239    Mrs         Anastasia   Xanthos  1976-09-29 00:00:00    empty
# 1266  empty  Theisen, Susanne         -                empty    empty
#
#                                   Email         Phone       Mobile  \
# 2                     aftilly@gmail.com   61409349099        empty
# 3     agodfrey@royallifesavingwa.com.au   61430477517        empty
# 4                   airvent@live.com.au   61414355996        empty
# 5            alan.bennetts@iinet.net.au   61893791956  61430157009
# 6              allisonjane8@outlook.com         empty        empty
# ...                                 ...           ...          ...
# 1232            surreysarah84@gmail.com  447710250414        empty
# 1235             traceybrewis@gmail.com  447557978157        empty
# 1237               vinaykjoon@gmail.com  447435680435  64226814074
# 1239           anastasiaxanthos@aol.com   16319404009  16317934067
# 1266                        expedia-net         10115        empty
#
#                         AddressLine1 AddressLine2  ... Sales Rep and Comments  \
# 2                   45 SEAHORSE LOOP        empty  ...                  empty
# 3                       6b Beaton St        empty  ...                  FREYA
# 4           54  RUBY AVENUE-LANGFORD            -  ...                  empty
# 5                 58 CHESTERTON ROAD   BASSENDEAN  ...                Kevin L
# 6      UNIT 10 18-20  SCENIC HIGHWAY        empty  ...                  empty
# ...                              ...          ...  ...                    ...
# 1232        Flat 1, 99B Redland Road        empty  ...                  empty
# 1235  2 OLD STOKE ROAD STOKE CHARITY        empty  ...        peter aitchison
# 1237                 72 Clinton Road        empty  ...                  empty
# 1239              7 SLEEPY HOLLOW LN            .  ...                 Robert
# 1266                           empty        empty  ...                  empty
#
#      Opt In     Contact Type Odyssey Members     Lead Brand Lead Sub-Brand  \
# 2       YES  Email and Phone              NO  Karma Resorts          Other
# 3       YES  Email and Phone              NO  Karma Resorts          Other
# 4       YES  Email and Phone              NO  Karma Resorts          Other
# 5       YES  Email and Phone              NO  Karma Resorts          Other
# 6       YES       Email Only              NO  Karma Resorts          Other
# ...     ...              ...             ...            ...            ...
# 1232    YES  Email and Phone              NO  Karma Resorts          Other
# 1235    YES  Email and Phone              NO  Karma Resorts          Other
# 1237    YES  Email and Phone              NO  Karma Resorts          Other
# 1239    YES  Email and Phone              NO  Karma Resorts          Other
# 1266    YES  Email and Phone              NO  Karma Resorts          Other
#
#       Lead Source                     Lead Locations Lead Source Description  \
# 2     Past Guests             Karma Lake of Menteith               Viewpoint
# 3     Past Guests                    Karma Song Hoai               Viewpoint
# 4     Past Guests                        Amina hotel               Viewpoint
# 5     Past Guests                  Karma Royal Sanur               Viewpoint
# 6     Past Guests     Chateau de Samary, Carcassonne               Viewpoint
# ...           ...                                ...                     ...
# 1232  Past Guests                 Karma Salford Hall               Viewpoint
# 1235  Past Guests                   Karma La Herriza               Viewpoint
# 1237  Past Guests                   Karma La Herriza               Viewpoint
# 1239  Past Guests                       Karma Minoan               Viewpoint
# 1266  Past Guests  Wyndham -  Manoir des Deux Amants               Viewpoint
#
#      Exclude From Mailing
# 2                      NO
# 3                      NO
# 4                      NO
# 5                      NO
# 6                      NO
# ...                   ...
# 1232                   NO
# 1235                   NO
# 1237                   NO
# 1239                   NO
# 1266                   NO
#
# [843 rows x 37 columns]

# %%
df_viewpoint.drop(df_viewpoint.loc[
    
    df_viewpoint['Phone'].isin(df_phone['Mobile']) | 
    df_viewpoint['Mobile'].isin(df_phone['Mobile']) |

    df_viewpoint['Email'].isin(df_email['Email'])
].index, inplace=True)

df_viewpoint.reset_index(drop=True, inplace=True)

count_after_dedup_member = df_viewpoint.shape[0]

# %%
count_data_akhir = df_viewpoint.shape[0]

# %%
df_viewpoint.sort_values('CheckOutDate', ascending=True, inplace=True)
df_viewpoint.reset_index(drop=True, inplace=True)
df_viewpoint
# Out:
#     Title       Firstname    lastname                  DOB PAN CARD  \
# 0      Mr          Anshul   Chaurasia                empty    empty
# 1      Mr           Kamal       Kumar                empty    empty
# 2      Mr   Bhanu Chander      Chandu                empty    empty
# 3      Mr         Sandeep       Khade                empty    empty
# 4      Mr          Aditya  Chaturvedi                empty    empty
# ..    ...             ...         ...                  ...      ...
# 421   Mrs     Vashundhara      Sharma                empty    empty
# 422    Mr        Shailesh      S Modi                empty    empty
# 423   Mrs    Sneha Rajive      Thampy  1994-08-22 00:00:00    empty
# 424    Mr           Vikas           M                empty    empty
# 425    Mr  Smita Kulkarni      Umarji                empty    empty
#
#                                Email         Phone        Mobile  \
# 0    anshulchaurasia.inbox@gmail.com  919407215300         empty
# 1                   rahulb@gmail.com  917018356138         empty
# 2                   cbc43c@gmail.com  919241205910  919663001147
# 3           sandeep.khade1@gmail.com  918888982915  918788642258
# 4             karma.aditya@gmail.com  917014828214  917014828214
# ..                               ...           ...           ...
# 421     vashundhara.karma@sobrit.com  917044082748         empty
# 422           smodivijapur@gmail.com  919429318816  918780472822
# 423          sneha.rthampy@gmail.com  919819969929         empty
# 424              vikas.jnv@gmail.com  919916763636  919591171032
# 425           smita.umarji@gmail.com  919920250507  919967742016
#
#                                           AddressLine1  \
# 0                                                    .
# 1                                                    -
# 2    101, B BLOCK SLV VAJRA APARTMENTS, HORAMAVU, B...
# 3           FLAT NO 501 SHIVRAJ HEIGHTS AWHALWADI ROAD
# 4                                    D59, anand vihar,
# ..                                                 ...
# 421                          21 ROSE MERRY LANE HOWRAH
# 422           A/25 SHAKUNTAL, BUNGLOWS, MANIPURA ROAD,
# 423      703 Shubhangan, Gajanan Colony, Jawahar Nagar
# 424                           A008 TG LAKE VISTA BEGUR
# 425   2303 BLDG NO 12 REGENCY ANANTAM KALYAN SHIL ROAD
#
#                               AddressLine2  ... Sales Rep and Comments Opt In  \
# 0                                    empty  ...                  empty    YES
# 1                                        -  ...                  empty    YES
# 2                                    empty  ...                  empty    YES
# 3                                  WAGHOLI  ...                  empty    YES
# 4                      .jagat pura, jaipur  ...                  empty    YES
# ..                                     ...  ...                    ...    ...
# 421                                  empty  ...                  empty    YES
# 422             VIJAPUR, VIJAPUR, MAHESANA  ...                  empty    YES
# 423                                  empty  ...                  empty    YES
# 424  SINGASANDRA RD BEGUR BANGALORE 560068  ...                 NARESH    YES
# 425                   DOMBIVLI EAST 421204  ...                 NARESH    YES
#
#         Contact Type Odyssey Members     Lead Brand Lead Sub-Brand  \
# 0    Email and Phone              NO  Karma Resorts          Other
# 1    Email and Phone              NO  Karma Resorts          Other
# 2    Email and Phone              NO  Karma Resorts          Other
# 3    Email and Phone              NO  Karma Resorts          Other
# 4    Email and Phone              NO  Karma Resorts          Other
# ..               ...             ...            ...            ...
# 421  Email and Phone              NO  Karma Resorts          Other
# 422  Email and Phone              NO  Karma Resorts          Other
# 423  Email and Phone              NO  Karma Resorts          Other
# 424  Email and Phone              NO  Karma Resorts          Other
# 425  Email and Phone              NO  Karma Resorts          Other
#
#      Lead Source            Lead Locations Lead Source Description  \
# 0    Past Guests         Karma Royal Palms               Viewpoint
# 1    Past Guests         Karma Royal Palms               Viewpoint
# 2    Past Guests         Karma Royal Palms               Viewpoint
# 3    Past Guests         Karma Royal Palms               Viewpoint
# 4    Past Guests         Karma Royal Palms               Viewpoint
# ..           ...                       ...                     ...
# 421  Past Guests      Karma Royal Monterio               Viewpoint
# 422  Past Guests      Karma Royal Monterio               Viewpoint
# 423  Past Guests      Karma Royal Jimbaran               Viewpoint
# 424  Past Guests         Karma Royal Palms               Viewpoint
# 425  Past Guests  Karma Royal Haathi Mahal               Viewpoint
#
#     Exclude From Mailing
# 0                     NO
# 1                     NO
# 2                     NO
# 3                     NO
# 4                     NO
# ..                   ...
# 421                   NO
# 422                   NO
# 423                   NO
# 424                   NO
# 425                   NO
#
# [426 rows x 37 columns]

# %%
# find_member_booking[['Email','Same Value Find']].loc[find_member_booking['BookingNo'] == '2074237']
# df_viewpoint.loc[df_viewpoint['BookingNo'] == '2097221']
# df_viewpoint.loc[df_viewpoint['Email'].str.contains('prajuizn@gmail.com')]

# %%
df_viewpoint['DOB'].replace('empty', '', inplace=True)
dob_con_date = pd.to_datetime(df_viewpoint['DOB'])
dob_date = dob_con_date.dt.strftime('%Y-%m-%d')

arr_con_date = pd.to_datetime(df_viewpoint['Arrival'])
arr_date = arr_con_date.dt.strftime('%Y-%m-%d')

dep_con_date = pd.to_datetime(df_viewpoint['Departure'])
dep_date = dep_con_date.dt.strftime('%Y-%m-%d')

ci_con_date = pd.to_datetime(df_viewpoint['CheckInDate'])
ci_date = ci_con_date.dt.strftime('%Y-%m-%d')

co_con_date = pd.to_datetime(df_viewpoint['CheckOutDate'])
co_date = co_con_date.dt.strftime('%Y-%m-%d')

df_viewpoint['DOB'] = dob_date
df_viewpoint['Arrival'] = arr_date
df_viewpoint['Departure'] = dep_date
df_viewpoint['CheckInDate'] = ci_date
df_viewpoint['CheckOutDate'] = co_date

# %%
df_viewpoint.columns
# Out:
# Index(['Title', 'Firstname', 'lastname', 'DOB', 'PAN CARD', 'Email', 'Phone',
#        'Mobile', 'AddressLine1', 'AddressLine2', 'Town', 'State', 'Country',
#        'PostCode', 'Nationality', 'MaritalStatus', 'resortname', 'Arrival',
#        'Departure', 'CheckInDate', 'CheckOutDate', 'room', 'UnitCategory',
#        'BookingNo', 'BookingSourceDesc', 'BookingTypeDesc', 'Date of Tour',
#        'Sales Rep and Comments', 'Opt In', 'Contact Type', 'Odyssey Members',
#        'Lead Brand', 'Lead Sub-Brand', 'Lead Source', 'Lead Locations',
#        'Lead Source Description', 'Exclude From Mailing'],
#       dtype='object')

# %%
new_cols = ['Lead Brand','Lead Sub-Brand','Lead Source','Lead Locations','Lead Source Description','Title','Firstname','lastname','DOB','Email','Phone','Mobile','AddressLine1','AddressLine2','Town','State',
'Country','PostCode','Nationality','MaritalStatus',	'resortname', 'Arrival', 'Departure', 'CheckInDate', 'CheckOutDate', 'room', 'UnitCategory', 'BookingNo', 'BookingSourceDesc', 'BookingTypeDesc', 'Date of Tour', 'Sales Rep and Comments',	'Opt In', 'Exclude From Mailing', 'Odyssey Members', 'Contact Type']																																																																																																																																						

df_viewpoint = df_viewpoint.reindex(columns=new_cols)

# %%
df_viewpoint.replace('empty', '', inplace=True)

df_viewpoint.sort_values('Departure', ascending=True, inplace=True)
df_viewpoint.reset_index(drop=True, inplace=True)
df_viewpoint
# Out:
#         Lead Brand Lead Sub-Brand  Lead Source            Lead Locations  \
# 0    Karma Resorts          Other  Past Guests         Karma Royal Palms
# 1    Karma Resorts          Other  Past Guests         Karma Royal Palms
# 2    Karma Resorts          Other  Past Guests   Karma Sitabani, Corbett
# 3    Karma Resorts          Other  Past Guests               Amina hotel
# 4    Karma Resorts          Other  Past Guests               Amina hotel
# ..             ...            ...          ...                       ...
# 421  Karma Resorts          Other  Past Guests         Karma Royal Palms
# 422  Karma Resorts          Other  Past Guests         Karma Royal Palms
# 423  Karma Resorts          Other  Past Guests         Karma Royal Palms
# 424  Karma Resorts          Other  Past Guests         Karma Royal Palms
# 425  Karma Resorts          Other  Past Guests  Karma Royal Haathi Mahal
#
#     Lead Source Description Title         Firstname   lastname         DOB  \
# 0                 Viewpoint    Mr            Anshul  Chaurasia         NaN
# 1                 Viewpoint    Mr          Jobson V     Chacko  1983-02-23
# 2                 Viewpoint    Mr       Mahfooz Ali   Siddiqui         NaN
# 3                 Viewpoint    Mr        Gaganpreet      Saini         NaN
# 4                 Viewpoint    Mr            Sanjay      Kumar  1968-06-17
# ..                      ...   ...               ...        ...         ...
# 421               Viewpoint   Mrs         Nitinwala          .         NaN
# 422               Viewpoint    Mr  Dilip Tulsi Bhai  Kanjariya         NaN
# 423               Viewpoint    Mr             Vikas          M         NaN
# 424               Viewpoint    Mr             Kiran      Reddy         NaN
# 425               Viewpoint    Mr    Smita Kulkarni     Umarji         NaN
#
#                                Email  ...           UnitCategory BookingNo  \
# 0    anshulchaurasia.inbox@gmail.com  ...    1 Bedroom Apartment   2488243
# 1             jobsonchacko@gmail.com  ...   Non Member 1 Bedroom   2534895
# 2           siddiqui.india@gmail.com  ...  Non Member Hotel Unit   2558969
# 3               gsaini0001@gmail.com  ...            Deluxe Room   2562135
# 4      capt.sanjay_kumar@yahoo.co.in  ...            Deluxe Room   2520049
# ..                               ...  ...                    ...       ...
# 421           nitin.wala@hotmail.com  ...   Non Member 1 Bedroom   2593576
# 422       dilipkanjariya68@gmail.com  ...   Non Member 1 Bedroom   2594430
# 423              vikas.jnv@gmail.com  ...   Non Member 1 Bedroom   2515055
# 424            kiran.kkr96@gmail.com  ...    1 Bedroom Apartment   2589616
# 425           smita.umarji@gmail.com  ...    Hotel Unit Standard   2576201
#
#              BookingSourceDesc          BookingTypeDesc         Date of Tour  \
# 0                   Affiliates          Leadgen/7across
# 1                  KCE2 Indian   Karma Experience India  2024-08-17 13:30:00
# 2               Fly Buy Indian   Karma Experience India  2024-08-17 14:30:00
# 3               Fly Buy Indian   Karma Experience India
# 4                  KCE2 Indian    KE - Karma Experience
# ..                         ...                      ...                  ...
# 421             Fly Buy Indian   Karma Experience India
# 422             Fly Buy Indian   Karma Experience India
# 423             Fly Buy Indian   Karma Experience India  2024-08-25 13:35:00
# 424  Guest Of Fractional Owner  Internal Rental / Bonus
# 425             Fly Buy Indian   Karma Experience India  2024-08-25 18:05:00
#
#     Sales Rep and Comments Opt In Exclude From Mailing Odyssey Members  \
# 0                             YES                   NO              NO
# 1                    afsha    YES                   NO              NO
# 2                   AMISHA    YES                   NO              NO
# 3                             YES                   NO              NO
# 4                             YES                   NO              NO
# ..                     ...    ...                  ...             ...
# 421                           YES                   NO              NO
# 422                           YES                   NO              NO
# 423                 NARESH    YES                   NO              NO
# 424                           YES                   NO              NO
# 425                 NARESH    YES                   NO              NO
#
#         Contact Type
# 0    Email and Phone
# 1    Email and Phone
# 2    Email and Phone
# 3    Email and Phone
# 4    Email and Phone
# ..               ...
# 421  Email and Phone
# 422  Email and Phone
# 423  Email and Phone
# 424  Email and Phone
# 425  Email and Phone
#
# [426 rows x 36 columns]

# %%
print("==========================================================")
print("Summary")
print("==========================================================")
print("Jumlah Data Setelah Script Past Guest Sebelumnya : "+str(count_data_awal))
print("Jumlah Data Yang Duplicate : "+str(count_duplicate_general))
print("Jumlah Data Setelah Hapus Duplicate : "+str(count_after_dedup_duplicate))
print("Jumlah Data Yang Termasuk Member: "+str(count_dedup_member))
print("Jumlah Data Setelah Hapus Member : "+str(count_after_dedup_member))
print("Jumlah Data Akhir : "+str(count_data_akhir))
# Out:
# ==========================================================
# Summary
# ==========================================================
# Jumlah Data Setelah Script Past Guest Sebelumnya : 1627
# Jumlah Data Yang Duplicate : 358
# Jumlah Data Setelah Hapus Duplicate : 1269
# Jumlah Data Yang Termasuk Member: 843
# Jumlah Data Setelah Hapus Member : 426
# Jumlah Data Akhir : 426

# %%
df_viewpoint.to_excel(r'C:\Users\fajar\Documents\Python\Data\final_viewpoint.xlsx', index=False)
