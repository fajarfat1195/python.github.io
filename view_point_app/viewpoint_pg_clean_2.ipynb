# %%
import pandas as pd
import re

import past_guest_module as pm

import sys
sys.path.append('../zoho_data_app/')

import main_module as m

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
path = r'C:\Users\fajar\Documents\Python\Data\check_country_code_viewpoint.xlsx'
df_viewpoint = pd.read_excel(path, dtype='string', sheet_name='Sheet1')
count_data_awal = df_viewpoint.shape[0]

# %%
df_viewpoint.fillna('empty', inplace=True)

# %%
path = r'G:\.shortcut-targets-by-id\0B_d3smBjzo04UUNBME5GOVhoMjA\_ODYSSEY\Phone Members.xlsx'
df_phone = pd.read_excel(path, dtype='string', sheet_name='Sheet1')

path = r'G:\.shortcut-targets-by-id\0B_d3smBjzo04UUNBME5GOVhoMjA\_ODYSSEY\Email Members.xlsx'
df_email = pd.read_excel(path, dtype='string', sheet_name='Sheet1')

# %%
m.clean_space(df_email, 'Email')
df_email['Email'] = m.lowercase(df_email, 'Email')

# %%
# hitung jumlah duplicate
count_duplicate_general = df_viewpoint.loc[df_viewpoint.duplicated(subset=['Phone','Mobile','Email'])].shape[0]

df_viewpoint.loc[df_viewpoint.duplicated(subset=['Phone','Mobile','Email'])]
# Out:
#       Title                    Firstname   lastname                  DOB  \
# 11      Mrs                April Nirvesh  Comerford  1948-04-05 00:00:00
# 12      Mrs                April Nirvesh  Comerford  1948-04-05 00:00:00
# 27       Mr                       Robert      James                empty
# 33       Mr                      Stephen     Wilson  1955-02-06 00:00:00
# 35       Ms               Drina Cathleen     Maneze                empty
# ...     ...                          ...        ...                  ...
# 1324  empty          Wietske, Van Schaik          -                empty
# 1325  empty                 Abdat, Salem          -                empty
# 1327  empty  Taylor, Dean & Hayley-Ellen          -                empty
# 1332  empty                      Nicolaj   Johansen                empty
# 1338  empty            Okeefe, Geraldine          -                empty
#
#      PAN CARD                          Email         Phone        Mobile  \
# 11      empty             aprilnow@gmail.com   61418827524         empty
# 12      empty             aprilnow@gmail.com   61418827524         empty
# 27      empty  caroline.marshall@outlook.com   61400981935  447536260357
# 33      empty          cumbria55@bigpond.com   61413351082         empty
# 35      empty           d.maneze@hotmail.com   61422889605         empty
# ...       ...                            ...           ...           ...
# 1324    empty                    booking.com         empty         empty
# 1325    empty                    booking.com         empty         empty
# 1327    empty         dhgbj.taylor@gmail.com     272070785    6421664327
# 1332    empty                info@nakula.com  628113855855         empty
# 1338    empty                          sales         empty         empty
#
#                     AddressLine1      AddressLine2  ...  \
# 11        U5E/52 GOODWIN TERRACE             empty  ...
# 12        U5E/52 GOODWIN TERRACE             empty  ...
# 27            4/508 Sterling Way  Peppermint Grove  ...
# 33    1001/1 POINT PARK CRESCENT             empty  ...
# 35                         empty             empty  ...
# ...                          ...               ...  ...
# 1324                       empty             empty  ...
# 1325                       empty             empty  ...
# 1327                       empty             empty  ...
# 1332                       empty             empty  ...
# 1338                       empty             empty  ...
#
#      Sales Rep and Comments Opt In     Contact Type Odyssey Members  \
# 11                    empty    YES  Email and Phone              NO
# 12                    empty    YES  Email and Phone              NO
# 27                    empty    YES  Email and Phone              NO
# 33                    empty    YES  Email and Phone              NO
# 35                    empty    YES  Email and Phone              NO
# ...                     ...    ...              ...             ...
# 1324                  empty    YES       Email Only              NO
# 1325                  empty    YES       Email Only              NO
# 1327                  empty    YES  Email and Phone              NO
# 1332                  empty    YES  Email and Phone              NO
# 1338                  empty    YES       Email Only              NO
#
#          Lead Brand Lead Sub-Brand  Lead Source  \
# 11    Karma Resorts          Other  Past Guests
# 12    Karma Resorts          Other  Past Guests
# 27    Karma Resorts          Other  Past Guests
# 33    Karma Resorts          Other  Past Guests
# 35    Karma Resorts          Other  Past Guests
# ...             ...            ...          ...
# 1324  Karma Resorts          Other  Past Guests
# 1325  Karma Resorts          Other  Past Guests
# 1327  Karma Resorts          Other  Past Guests
# 1332  Karma Resorts          Other  Past Guests
# 1338  Karma Resorts          Other  Past Guests
#
#                                Lead Locations Lead Source Description  \
# 11    KRR @ Karma Kandara, Mentari Residences               Viewpoint
# 12    KRR @ Karma Kandara, Mentari Residences               Viewpoint
# 27               KRR @ Karma Kandara, Phase V               Viewpoint
# 33    KRR @ Karma Kandara, Mentari Residences               Viewpoint
# 35    KRR @ Karma Kandara, Mentari Residences               Viewpoint
# ...                                       ...                     ...
# 1324        Wyndham -  Manoir des Deux Amants               Viewpoint
# 1325        Wyndham -  Manoir des Deux Amants               Viewpoint
# 1327        Wyndham -  Manoir des Deux Amants               Viewpoint
# 1332                           Karma Jimbaran               Viewpoint
# 1338        Wyndham -  Manoir des Deux Amants               Viewpoint
#
#      Exclude From Mailing
# 11                     NO
# 12                     NO
# 27                     NO
# 33                     NO
# 35                     NO
# ...                   ...
# 1324                   NO
# 1325                   NO
# 1327                   NO
# 1332                   NO
# 1338                   NO
#
# [295 rows x 37 columns]

# %%
df_viewpoint.drop_duplicates(subset=['Phone','Mobile','Email'], inplace=True)
df_viewpoint.reset_index(drop=True, inplace=True)

# hitung jumlah setelah value duplicate dihapus
count_after_dedup_duplicate = df_viewpoint.shape[0]

df_viewpoint
# Out:
#       Title                  Firstname     lastname                  DOB  \
# 0       Mrs                      Linda       Hardey  1959-06-20 00:00:00
# 1        Mr                       Hein  De Villiers  1970-02-22 00:00:00
# 2     empty                       Anna   Guillesser  1958-01-03 00:00:00
# 3        Mr                       Alan       Willey  1950-01-05 00:00:00
# 4        Mr                    Anthony         Lane  1954-07-08 00:00:00
# ...     ...                        ...          ...                  ...
# 1041  empty     Wagner, Pieter & Paola            -                empty
# 1042  empty       Lyons, Robert & Joan            -                empty
# 1043  empty          Okeefe, Geraldine            -                empty
# 1044  empty  Reyno, Clifford & Shirley            -                empty
# 1045  empty   Hegerty, James & Therese            -                empty
#
#      PAN CARD                       Email        Phone      Mobile  \
# 0       empty          8lindah8@gmail.com  61418456404       empty
# 1       empty          admin@capps.com.au  61400853906       empty
# 2       empty     aguillesser@hotmail.com  61428620894       empty
# 3       empty  alan.valwilley@bigpond.com  61429379385       empty
# 4       empty    alaneway@optusnet.com.au  61417378983       empty
# ...       ...                         ...          ...         ...
# 1041    empty       mariela1739@gmail.com  64210426111    21726733
# 1042    empty          ozboss55@gmail.com    409370458       empty
# 1043    empty                       sales        empty       empty
# 1044    empty     shirley.reyno@gmail.com   6421715648  6421715648
# 1045    empty    t.hegerty@teameng.com.au    417757984   419673374
#
#           AddressLine1  AddressLine2  ... Sales Rep and Comments Opt In  \
# 0     11 GEORGE STREET   NORTH BEACH  ...                 GAUTAM    YES
# 1     143 CASUARINA RD         empty  ...                   RYAN    YES
# 2          5 Hyde Road         empty  ...                  empty    YES
# 3                empty         empty  ...                  empty    YES
# 4           PO BOX 315         empty  ...                  LAURE    YES
# ...                ...           ...  ...                    ...    ...
# 1041             empty         empty  ...                  empty    YES
# 1042             empty         empty  ...                  empty    YES
# 1043             empty         empty  ...                  empty    YES
# 1044             empty         empty  ...                  empty    YES
# 1045             empty         empty  ...                  empty    YES
#
#          Contact Type Odyssey Members     Lead Brand Lead Sub-Brand  \
# 0     Email and Phone              NO  Karma Resorts          Other
# 1     Email and Phone              NO  Karma Resorts          Other
# 2     Email and Phone              NO  Karma Resorts          Other
# 3     Email and Phone              NO  Karma Resorts          Other
# 4     Email and Phone              NO  Karma Resorts          Other
# ...               ...             ...            ...            ...
# 1041  Email and Phone              NO  Karma Resorts          Other
# 1042  Email and Phone              NO  Karma Resorts          Other
# 1043       Email Only              NO  Karma Resorts          Other
# 1044  Email and Phone              NO  Karma Resorts          Other
# 1045  Email and Phone              NO  Karma Resorts          Other
#
#       Lead Source                           Lead Locations  \
# 0     Past Guests  KRR @ Karma Kandara, Mentari Residences
# 1     Past Guests             KRR @ Karma Kandara, Phase V
# 2     Past Guests                  Karma Borgo Di Colleoli
# 3     Past Guests                              Amina hotel
# 4     Past Guests             KRR @ Karma Kandara, Phase V
# ...           ...                                      ...
# 1041  Past Guests        Wyndham -  Manoir des Deux Amants
# 1042  Past Guests        Wyndham -  Manoir des Deux Amants
# 1043  Past Guests        Wyndham -  Manoir des Deux Amants
# 1044  Past Guests        Wyndham -  Manoir des Deux Amants
# 1045  Past Guests        Wyndham -  Manoir des Deux Amants
#
#      Lead Source Description Exclude From Mailing
# 0                  Viewpoint                   NO
# 1                  Viewpoint                   NO
# 2                  Viewpoint                   NO
# 3                  Viewpoint                   NO
# 4                  Viewpoint                   NO
# ...                      ...                  ...
# 1041               Viewpoint                   NO
# 1042               Viewpoint                   NO
# 1043               Viewpoint                   NO
# 1044               Viewpoint                   NO
# 1045               Viewpoint                   NO
#
# [1046 rows x 37 columns]

# %%
find_member_booking = df_viewpoint.copy()

find_member_booking.loc[find_member_booking['Phone'].isin(df_phone['Mobile']), 'Same Value Find'] = 'Member-Mobile' 
find_member_booking.loc[find_member_booking['Mobile'].isin(df_phone['Mobile']), 'Same Value Find'] = 'Member-Mobile'

find_member_booking.loc[find_member_booking['Email'].isin(df_email['Email']), 'Same Value Find'] = 'Member-Email'
find_member_booking.drop(find_member_booking.loc[find_member_booking['Same Value Find'].isna()].index, inplace=True)

# %%
find_member_booking
# Out:
#       Title    Firstname     lastname                  DOB PAN CARD  \
# 0       Mrs        Linda       Hardey  1959-06-20 00:00:00    empty
# 1        Mr         Hein  De Villiers  1970-02-22 00:00:00    empty
# 2     empty         Anna   Guillesser  1958-01-03 00:00:00    empty
# 4        Mr      Anthony         Lane  1954-07-08 00:00:00    empty
# 5       Mrs  Amanda Jane       Falvey  1964-01-27 00:00:00    empty
# ...     ...          ...          ...                  ...      ...
# 1025    Mrs        Huyen           Ho  1970-08-01 00:00:00    empty
# 1026     Mr      Patrick        Stone  1949-07-23 00:00:00    empty
# 1027     Mr   John Allen    Thomassen  1958-06-19 00:00:00    empty
# 1029     Ms       Sonali    Manjunath  2005-08-02 00:00:00    empty
# 1032     Mr         Tony      Abraham  1955-01-24 00:00:00    empty
#
#                          Email         Phone       Mobile  \
# 0           8lindah8@gmail.com   61418456404        empty
# 1           admin@capps.com.au   61400853906        empty
# 2      aguillesser@hotmail.com   61428620894        empty
# 4     alaneway@optusnet.com.au   61417378983        empty
# 5       amandafalvey@gmail.com   61412489963        empty
# ...                        ...           ...          ...
# 1025        hho15897@gmail.com   15105021447  15102906846
# 1026      irisnstone@gmail.com   19252126853        empty
# 1027       jatphd123@gmail.com   15853298560        empty
# 1029    sonali.manju@gmail.com   19255497378        empty
# 1032       tonyabraham@mac.com  447947803862        empty
#
#                           AddressLine1          AddressLine2  ... Opt In  \
# 0                     11 GEORGE STREET           NORTH BEACH  ...    YES
# 1                     143 CASUARINA RD                 empty  ...    YES
# 2                          5 Hyde Road                 empty  ...    YES
# 4                           PO BOX 315                 empty  ...    YES
# 5     991 Mooral Creek RD Strath Cedak  MELBOURNE  AUSTRALIA  ...    YES
# ...                                ...                   ...  ...    ...
# 1025           1209 SKYCREST DR. APT.3                 empty  ...    YES
# 1026            1097 NE 65TH ST 980427                 empty  ...    YES
# 1027             831 W BLOOMFIELD ROAD                 empty  ...    YES
# 1029               2168 Quail Roost Dr                 empty  ...    YES
# 1032                      5 aeron view               talsarn  ...    YES
#
#          Contact Type Odyssey Members     Lead Brand Lead Sub-Brand  \
# 0     Email and Phone              NO  Karma Resorts          Other
# 1     Email and Phone              NO  Karma Resorts          Other
# 2     Email and Phone              NO  Karma Resorts          Other
# 4     Email and Phone              NO  Karma Resorts          Other
# 5     Email and Phone              NO  Karma Resorts          Other
# ...               ...             ...            ...            ...
# 1025  Email and Phone              NO  Karma Resorts          Other
# 1026  Email and Phone              NO  Karma Resorts          Other
# 1027  Email and Phone              NO  Karma Resorts          Other
# 1029  Email and Phone              NO  Karma Resorts          Other
# 1032  Email and Phone              NO  Karma Resorts          Other
#
#       Lead Source                           Lead Locations  \
# 0     Past Guests  KRR @ Karma Kandara, Mentari Residences
# 1     Past Guests             KRR @ Karma Kandara, Phase V
# 2     Past Guests                  Karma Borgo Di Colleoli
# 4     Past Guests             KRR @ Karma Kandara, Phase V
# 5     Past Guests                           Karma Jimbaran
# ...           ...                                      ...
# 1025  Past Guests                            Karma Bavaria
# 1026  Past Guests                             Karma Minoan
# 1027  Past Guests                       Karma Salford Hall
# 1029  Past Guests                     Karma Chakra, Kerala
# 1032  Past Guests                       Karma Salford Hall
#
#      Lead Source Description Exclude From Mailing Same Value Find
# 0                  Viewpoint                   NO    Member-Email
# 1                  Viewpoint                   NO    Member-Email
# 2                  Viewpoint                   NO    Member-Email
# 4                  Viewpoint                   NO    Member-Email
# 5                  Viewpoint                   NO    Member-Email
# ...                      ...                  ...             ...
# 1025               Viewpoint                   NO    Member-Email
# 1026               Viewpoint                   NO    Member-Email
# 1027               Viewpoint                   NO    Member-Email
# 1029               Viewpoint                   NO    Member-Email
# 1032               Viewpoint                   NO    Member-Email
#
# [709 rows x 38 columns]

# %%
find_member_booking.replace('empty', '', inplace=True)
find_member_booking.to_csv(r'C:\Users\fajar\Documents\Python\Data\cek_member_viewpoint.csv', index=False)

# %%
count_dedup_member = df_viewpoint.loc[
    
    df_viewpoint['Phone'].isin(df_phone['Mobile']) | 
    df_viewpoint['Mobile'].isin(df_phone['Mobile']) |

    df_viewpoint['Email'].isin(df_email['Email'])
    ].shape[0]

df_viewpoint.loc[
    
    df_viewpoint['Phone'].isin(df_phone['Mobile']) | 
    df_viewpoint['Mobile'].isin(df_phone['Mobile']) |

    df_viewpoint['Email'].isin(df_email['Email'])
    ]
# Out:
#       Title    Firstname     lastname                  DOB PAN CARD  \
# 0       Mrs        Linda       Hardey  1959-06-20 00:00:00    empty
# 1        Mr         Hein  De Villiers  1970-02-22 00:00:00    empty
# 2     empty         Anna   Guillesser  1958-01-03 00:00:00    empty
# 4        Mr      Anthony         Lane  1954-07-08 00:00:00    empty
# 5       Mrs  Amanda Jane       Falvey  1964-01-27 00:00:00    empty
# ...     ...          ...          ...                  ...      ...
# 1025    Mrs        Huyen           Ho  1970-08-01 00:00:00    empty
# 1026     Mr      Patrick        Stone  1949-07-23 00:00:00    empty
# 1027     Mr   John Allen    Thomassen  1958-06-19 00:00:00    empty
# 1029     Ms       Sonali    Manjunath  2005-08-02 00:00:00    empty
# 1032     Mr         Tony      Abraham  1955-01-24 00:00:00    empty
#
#                          Email         Phone       Mobile  \
# 0           8lindah8@gmail.com   61418456404        empty
# 1           admin@capps.com.au   61400853906        empty
# 2      aguillesser@hotmail.com   61428620894        empty
# 4     alaneway@optusnet.com.au   61417378983        empty
# 5       amandafalvey@gmail.com   61412489963        empty
# ...                        ...           ...          ...
# 1025        hho15897@gmail.com   15105021447  15102906846
# 1026      irisnstone@gmail.com   19252126853        empty
# 1027       jatphd123@gmail.com   15853298560        empty
# 1029    sonali.manju@gmail.com   19255497378        empty
# 1032       tonyabraham@mac.com  447947803862        empty
#
#                           AddressLine1          AddressLine2  ...  \
# 0                     11 GEORGE STREET           NORTH BEACH  ...
# 1                     143 CASUARINA RD                 empty  ...
# 2                          5 Hyde Road                 empty  ...
# 4                           PO BOX 315                 empty  ...
# 5     991 Mooral Creek RD Strath Cedak  MELBOURNE  AUSTRALIA  ...
# ...                                ...                   ...  ...
# 1025           1209 SKYCREST DR. APT.3                 empty  ...
# 1026            1097 NE 65TH ST 980427                 empty  ...
# 1027             831 W BLOOMFIELD ROAD                 empty  ...
# 1029               2168 Quail Roost Dr                 empty  ...
# 1032                      5 aeron view               talsarn  ...
#
#      Sales Rep and Comments Opt In     Contact Type Odyssey Members  \
# 0                    GAUTAM    YES  Email and Phone              NO
# 1                      RYAN    YES  Email and Phone              NO
# 2                     empty    YES  Email and Phone              NO
# 4                     LAURE    YES  Email and Phone              NO
# 5                    ESTHER    YES  Email and Phone              NO
# ...                     ...    ...              ...             ...
# 1025            Christopher    YES  Email and Phone              NO
# 1026                 Robert    YES  Email and Phone              NO
# 1027                  empty    YES  Email and Phone              NO
# 1029                  empty    YES  Email and Phone              NO
# 1032                 Landis    YES  Email and Phone              NO
#
#          Lead Brand Lead Sub-Brand  Lead Source  \
# 0     Karma Resorts          Other  Past Guests
# 1     Karma Resorts          Other  Past Guests
# 2     Karma Resorts          Other  Past Guests
# 4     Karma Resorts          Other  Past Guests
# 5     Karma Resorts          Other  Past Guests
# ...             ...            ...          ...
# 1025  Karma Resorts          Other  Past Guests
# 1026  Karma Resorts          Other  Past Guests
# 1027  Karma Resorts          Other  Past Guests
# 1029  Karma Resorts          Other  Past Guests
# 1032  Karma Resorts          Other  Past Guests
#
#                                Lead Locations Lead Source Description  \
# 0     KRR @ Karma Kandara, Mentari Residences               Viewpoint
# 1                KRR @ Karma Kandara, Phase V               Viewpoint
# 2                     Karma Borgo Di Colleoli               Viewpoint
# 4                KRR @ Karma Kandara, Phase V               Viewpoint
# 5                              Karma Jimbaran               Viewpoint
# ...                                       ...                     ...
# 1025                            Karma Bavaria               Viewpoint
# 1026                             Karma Minoan               Viewpoint
# 1027                       Karma Salford Hall               Viewpoint
# 1029                     Karma Chakra, Kerala               Viewpoint
# 1032                       Karma Salford Hall               Viewpoint
#
#      Exclude From Mailing
# 0                      NO
# 1                      NO
# 2                      NO
# 4                      NO
# 5                      NO
# ...                   ...
# 1025                   NO
# 1026                   NO
# 1027                   NO
# 1029                   NO
# 1032                   NO
#
# [709 rows x 37 columns]

# %%
df_viewpoint.drop(df_viewpoint.loc[
    
    df_viewpoint['Phone'].isin(df_phone['Mobile']) | 
    df_viewpoint['Mobile'].isin(df_phone['Mobile']) |

    df_viewpoint['Email'].isin(df_email['Email'])
].index, inplace=True)

df_viewpoint.reset_index(drop=True, inplace=True)

count_after_dedup_member = df_viewpoint.shape[0]

# %%
count_data_akhir = df_viewpoint.shape[0]

# %%
df_viewpoint.sort_values('CheckOutDate', ascending=True, inplace=True)
df_viewpoint.reset_index(drop=True, inplace=True)
df_viewpoint
# Out:
#      Title               Firstname   lastname                  DOB PAN CARD  \
# 0       Mr                 Nishant     Sharma                empty    empty
# 1       Mr             Rao Farrukh    Mahmood  1965-05-13 00:00:00    empty
# 2       Mr                  Eugene     Joseph                empty    empty
# 3       Mr  Priyanka Llewellyn Dsa  Llewellyn                empty    empty
# 4       Mr                  Deepak     Pathak                empty    empty
# ..     ...                     ...        ...                  ...      ...
# 332  empty                  Milica      Bojic  1986-07-30 00:00:00    empty
# 333    Mrs                 Sukhjit      Bains  1978-02-05 00:00:00    empty
# 334     Mr                  Arun D    Attavar                empty    empty
# 335     Mr                  Manish      Lamba                empty    empty
# 336     Mr                 Jasmeet      Singh                empty    empty
#
#                           Email         Phone        Mobile  \
# 0     nsharma.fipfip1@gmail.com  919672994434  918696224434
# 1       rao.farrukh22@gmail.com  919871512929  917428516689
# 2            eupremin@yahoo.com  971504556975         empty
# 3    kumaripriyanka64@gmail.com  917321893621  918235335520
# 4     pathak.deepak00@gmail.com  919873266394  919650640163
# ..                          ...           ...           ...
# 332       milliebojic@gmail.com  447795854043         empty
# 333       suki.bains@caljan.com  447983956167         empty
# 334        nofear3161@gmail.com  918105760699  918722445234
# 335  manishlambablk20@gmail.com  917982878331  919540272979
# 336       jasmeetyank@gmail.com  917827239722  918287075949
#
#                                           AddressLine1  \
# 0      H.N.82/516 PRATAP NAGAR, SANGANER, CHETAK MARG,
# 1                                    303 KAILASH TOWER
# 2                                                Dubai
# 3    PEARL HEAVEN, GROUND FLOOR, KHUMBARWADA, MANIC...
# 4                      A1/180 HASTSAL ROAD UTTAM NAGAR
# ..                                                 ...
# 332                                              empty
# 333                                              empty
# 334              1-41/4,  GURU KRIPA HOUSE,MUGURUKODI,
# 335                              10 C /60, VASUNDHARA,
# 336                 128B NEW SEHGAL BUILDING 1ST FLOOR
#
#                                         AddressLine2  ...  \
# 0    H.N.82/516 PRATAP NAGAR, SANGANER, CHETAK MARG,  ...
# 1                         KAUSHAMBI OPP.PACIFIC MALL  ...
# 2                                              empty  ...
# 3                                                  .  ...
# 4                                       UTTAM  NAGAR  ...
# ..                                               ...  ...
# 332                                            empty  ...
# 333                                            empty  ...
# 334                         PADAVINANGADY, MANGALORE  ...
# 335                                GAZIABAD - 201012  ...
# 336                                         KILOKARI  ...
#
#     Sales Rep and Comments Opt In     Contact Type Odyssey Members  \
# 0                    empty    YES  Email and Phone              NO
# 1                    empty    YES  Email and Phone              NO
# 2                    empty    YES  Email and Phone              NO
# 3                   BRYSON    YES  Email and Phone              NO
# 4                    empty    YES  Email and Phone              NO
# ..                     ...    ...              ...             ...
# 332                 Dennis    YES  Email and Phone              NO
# 333                  Nihan    YES  Email and Phone              NO
# 334                  empty    YES  Email and Phone              NO
# 335                  empty    YES  Email and Phone              NO
# 336                  empty    YES  Email and Phone              NO
#
#         Lead Brand Lead Sub-Brand  Lead Source  \
# 0    Karma Resorts          Other  Past Guests
# 1    Karma Resorts          Other  Past Guests
# 2    Karma Resorts          Other  Past Guests
# 3    Karma Resorts          Other  Past Guests
# 4    Karma Resorts          Other  Past Guests
# ..             ...            ...          ...
# 332  Karma Resorts          Other  Past Guests
# 333  Karma Resorts          Other  Past Guests
# 334  Karma Resorts          Other  Past Guests
# 335  Karma Resorts          Other  Past Guests
# 336  Karma Resorts          Other  Past Guests
#
#                               Lead Locations Lead Source Description  \
# 0                    Karma Sitabani, Corbett               Viewpoint
# 1                    Karma Sitabani, Corbett               Viewpoint
# 2    KRR @ Karma Kandara, Mentari Residences               Viewpoint
# 3                          Karma Royal Palms               Viewpoint
# 4                       Karma Royal Monterio               Viewpoint
# ..                                       ...                     ...
# 332                  Karma Borgo Di Colleoli               Viewpoint
# 333                  Karma Borgo Di Colleoli               Viewpoint
# 334                     Karma Munnar, Kerala               Viewpoint
# 335                  Karma Sitabani, Corbett               Viewpoint
# 336                  Karma Sitabani, Corbett               Viewpoint
#
#     Exclude From Mailing
# 0                     NO
# 1                     NO
# 2                     NO
# 3                     NO
# 4                     NO
# ..                   ...
# 332                   NO
# 333                   NO
# 334                   NO
# 335                   NO
# 336                   NO
#
# [337 rows x 37 columns]

# %%
# find_member_booking[['Email','Same Value Find']].loc[find_member_booking['BookingNo'] == '2074237']
# df_viewpoint.loc[df_viewpoint['BookingNo'] == '2097221']
# df_viewpoint.loc[df_viewpoint['Email'].str.contains('prajuizn@gmail.com')]

# %%
df_viewpoint['DOB'].replace('empty', '', inplace=True)
dob_con_date = pd.to_datetime(df_viewpoint['DOB'])
dob_date = dob_con_date.dt.strftime('%Y-%m-%d')

arr_con_date = pd.to_datetime(df_viewpoint['Arrival'])
arr_date = arr_con_date.dt.strftime('%Y-%m-%d')

dep_con_date = pd.to_datetime(df_viewpoint['Departure'])
dep_date = dep_con_date.dt.strftime('%Y-%m-%d')

ci_con_date = pd.to_datetime(df_viewpoint['CheckInDate'])
ci_date = ci_con_date.dt.strftime('%Y-%m-%d')

co_con_date = pd.to_datetime(df_viewpoint['CheckOutDate'])
co_date = co_con_date.dt.strftime('%Y-%m-%d')

df_viewpoint['DOB'] = dob_date
df_viewpoint['Arrival'] = arr_date
df_viewpoint['Departure'] = dep_date
df_viewpoint['CheckInDate'] = ci_date
df_viewpoint['CheckOutDate'] = co_date

# %%
df_viewpoint.columns
# Out:
# Index(['Title', 'Firstname', 'lastname', 'DOB', 'PAN CARD', 'Email', 'Phone',
#        'Mobile', 'AddressLine1', 'AddressLine2', 'Town', 'State', 'Country',
#        'PostCode', 'Nationality', 'MaritalStatus', 'resortname', 'Arrival',
#        'Departure', 'CheckInDate', 'CheckOutDate', 'room', 'UnitCategory',
#        'BookingNo', 'BookingSourceDesc', 'BookingTypeDesc', 'Date of Tour',
#        'Sales Rep and Comments', 'Opt In', 'Contact Type', 'Odyssey Members',
#        'Lead Brand', 'Lead Sub-Brand', 'Lead Source', 'Lead Locations',
#        'Lead Source Description', 'Exclude From Mailing'],
#       dtype='object')

# %%
new_cols = ['Lead Brand','Lead Sub-Brand','Lead Source','Lead Locations','Lead Source Description','Title','Firstname','lastname','DOB','Email','Phone','Mobile','AddressLine1','AddressLine2','Town','State',
'Country','PostCode','Nationality','MaritalStatus',	'resortname', 'Arrival', 'Departure', 'CheckInDate', 'CheckOutDate', 'room', 'UnitCategory', 'BookingNo', 'BookingSourceDesc', 'BookingTypeDesc', 'Date of Tour', 'Sales Rep and Comments',	'Opt In', 'Exclude From Mailing', 'Odyssey Members', 'Contact Type']																																																																																																																																						

df_viewpoint = df_viewpoint.reindex(columns=new_cols)

# %%
df_viewpoint.replace('empty', '', inplace=True)

df_viewpoint.sort_values('Departure', ascending=True, inplace=True)
df_viewpoint.reset_index(drop=True, inplace=True)
df_viewpoint
# Out:
#         Lead Brand Lead Sub-Brand  Lead Source              Lead Locations  \
# 0    Karma Resorts          Other  Past Guests     Karma Sitabani, Corbett
# 1    Karma Resorts          Other  Past Guests      Karma Sunshine Village
# 2    Karma Resorts          Other  Past Guests    Karma Royal Haathi Mahal
# 3    Karma Resorts          Other  Past Guests    Karma Royal Haathi Mahal
# 4    Karma Resorts          Other  Past Guests  Karma Seven Lakes, Udaipur
# ..             ...            ...          ...                         ...
# 332  Karma Resorts          Other  Past Guests           Karma Royal Palms
# 333  Karma Resorts          Other  Past Guests               Karma Kandara
# 334  Karma Resorts          Other  Past Guests     Karma Sitabani, Corbett
# 335  Karma Resorts          Other  Past Guests        Karma Munnar, Kerala
# 336  Karma Resorts          Other  Past Guests     Karma Sitabani, Corbett
#
#     Lead Source Description Title        Firstname lastname         DOB  \
# 0                 Viewpoint    Mr          Nishant   Sharma         NaN
# 1                 Viewpoint    Mr         Lawrence  Pereira         NaN
# 2                 Viewpoint    Mr   Vatsal Kamlesh   Bavisi         NaN
# 3                 Viewpoint    Mr       Amit Kumar    Sinha  1975-12-31
# 4                 Viewpoint    Mr      Sashikant B    Dound         NaN
# ..                      ...   ...              ...      ...         ...
# 332               Viewpoint    Mr  Mohammed Zaheer    Abbas         NaN
# 333               Viewpoint    Mr           Austin    Smith         NaN
# 334               Viewpoint    Mr           Manish    Lamba         NaN
# 335               Viewpoint    Mr           Arun D  Attavar         NaN
# 336               Viewpoint    Mr          Jasmeet    Singh         NaN
#
#                           Email  ...           UnitCategory BookingNo  \
# 0     nsharma.fipfip1@gmail.com  ...  Non Member Hotel Unit   2567851
# 1       lawry_pereira@yahoo.com  ...      Hotel Unit Double   2539019
# 2         vbavishi244@gmail.com  ...      Hotel Unit Deluxe   2549974
# 3         amitmadhu62@gmail.com  ...   2 Bedroom Fractional   2580331
# 4      doundsashikant@gmail.com  ...        Hotel Unit Twin   2554543
# ..                          ...  ...                    ...       ...
# 332         mzaheer.a@gmail.com  ...   Non Member 1 Bedroom   2565633
# 333    austin.smith@live.com.au  ...   1 Bedroom Pool Villa   2513584
# 334  manishlambablk20@gmail.com  ...  Non Member Hotel Unit   2553450
# 335        nofear3161@gmail.com  ...    Hotel Unit max 1ch.   2541796
# 336       jasmeetyank@gmail.com  ...  Non Member Hotel Unit   2581268
#
#              BookingSourceDesc            BookingTypeDesc  \
# 0               Fly Buy Indian     Karma Experience India
# 1    Guest Of Fractional Owner          Entitlement Guest
# 2            Member Ambassador          Member Ambassador
# 3                    KC Member  Complimentary Booking FOC
# 4              Guest of Member          Entitlement Guest
# ..                         ...                        ...
# 332             Fly Buy Indian     Karma Experience India
# 333            Fly Buy Western            Fly Buy Western
# 334             Fly Buy Indian     Karma Experience India
# 335                KCE2 Indian     Karma Experience India
# 336             Fly Buy Indian     Karma Experience India
#
#             Date of Tour Sales Rep and Comments Opt In Exclude From Mailing  \
# 0                                                  YES                   NO
# 1                                                  YES                   NO
# 2                                                  YES                   NO
# 3                                                  YES                   NO
# 4                                                  YES                   NO
# ..                   ...                    ...    ...                  ...
# 332  2024-08-09 12:50:00                HUSSAIN    YES                   NO
# 333                                                YES                   NO
# 334                                                YES                   NO
# 335                                                YES                   NO
# 336                                                YES                   NO
#
#     Odyssey Members     Contact Type
# 0                NO  Email and Phone
# 1                NO  Email and Phone
# 2                NO  Email and Phone
# 3                NO  Email and Phone
# 4                NO  Email and Phone
# ..              ...              ...
# 332              NO  Email and Phone
# 333              NO  Email and Phone
# 334              NO  Email and Phone
# 335              NO  Email and Phone
# 336              NO  Email and Phone
#
# [337 rows x 36 columns]

# %%
print("==========================================================")
print("Summary")
print("==========================================================")
print("Jumlah Data Setelah Script Past Guest Sebelumnya : "+str(count_data_awal))
print("Jumlah Data Yang Duplicate : "+str(count_duplicate_general))
print("Jumlah Data Setelah Hapus Duplicate : "+str(count_after_dedup_duplicate))
print("Jumlah Data Yang Termasuk Member: "+str(count_dedup_member))
print("Jumlah Data Setelah Hapus Member : "+str(count_after_dedup_member))
print("Jumlah Data Akhir : "+str(count_data_akhir))
# Out:
# ==========================================================
# Summary
# ==========================================================
# Jumlah Data Setelah Script Past Guest Sebelumnya : 1341
# Jumlah Data Yang Duplicate : 295
# Jumlah Data Setelah Hapus Duplicate : 1046
# Jumlah Data Yang Termasuk Member: 709
# Jumlah Data Setelah Hapus Member : 337
# Jumlah Data Akhir : 337

# %%
df_viewpoint.to_excel(r'C:\Users\fajar\Documents\Python\Data\final_viewpoint.xlsx', index=False)
