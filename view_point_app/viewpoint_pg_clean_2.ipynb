# %%
import pandas as pd
import re

import past_guest_module as pm

import sys
sys.path.append('../zoho_data_app/')

import main_module as m

# %load_ext autoreload
# %autoreload 2

# %%
path = r'C:\Users\fajar\Documents\Python\Data\check_country_code_viewpoint.xlsx'
df_viewpoint = pd.read_excel(path, dtype='string', sheet_name='Sheet1')
count_data_awal = df_viewpoint.shape[0]

# %%
df_viewpoint.fillna('empty', inplace=True)

# %%
path = r'G:\.shortcut-targets-by-id\0B_d3smBjzo04UUNBME5GOVhoMjA\_ODYSSEY\Phone Members.xlsx'
df_phone = pd.read_excel(path, dtype='string', sheet_name='Sheet1')

path = r'G:\.shortcut-targets-by-id\0B_d3smBjzo04UUNBME5GOVhoMjA\_ODYSSEY\Email Members.xlsx'
df_email = pd.read_excel(path, dtype='string', sheet_name='Sheet1')

# %%
m.clean_space(df_email, 'Email')
df_email['Email'] = m.lowercase(df_email, 'Email')

# %%
# hitung jumlah duplicate
count_duplicate_general = df_viewpoint.loc[df_viewpoint.duplicated(subset=['Phone','Mobile','Email'])].shape[0]

df_viewpoint.loc[df_viewpoint.duplicated(subset=['Phone','Mobile','Email'])]
# Out:
#       Title                         Firstname lastname                  DOB  \
# 5       Mrs                          Andriena    Munro  1966-05-28 00:00:00
# 9       Mrs                             Angie  Gregory                empty
# 11       Mr                       Mark Andrew  Purcell  1960-06-12 00:00:00
# 14       Mr                              Babu   Thomas  1964-05-24 00:00:00
# 17       Mr                          Benjamin  Golding  1990-08-26 00:00:00
# ...     ...                               ...      ...                  ...
# 1466  empty  De Hubsx, Marie-Laetitia Le Roux        -                empty
# 1468  empty               Nieuwendijk, Berbie        -                empty
# 1469  empty                      Sow, Harouna        -                empty
# 1472  empty                 Fraval, Veronique        -                empty
# 1482  empty                             James    Brown                empty
#
#      PAN CARD                       Email         Phone       Mobile  \
# 5       empty  andriena.munro@bigpond.com   61410437261        empty
# 9       empty       angiegno7@hotmail.com   61407411338        empty
# 11      empty       anniea@bigpond.net.au   61393707929  61404897073
# 14      empty      bab.thomas01@gmail.com   61416565247        empty
# 17      empty     ben.golding26@gmail.com         empty        empty
# ...       ...                         ...           ...          ...
# 1466    empty                 booking.com         empty        empty
# 1468    empty                 booking.com         empty        empty
# 1469    empty                 booking.com         empty        empty
# 1472    empty                 booking.com         empty        empty
# 1482    empty             info@nakula.com  628113855855        empty
#
#                         AddressLine1 AddressLine2  ... Sales Rep and Comments  \
# 5                              empty        empty  ...                  empty
# 9                                  -            -  ...                  empty
# 11                  110A DEAN STREET        empty  ...                Kevin L
# 14    12 BANOOL CRESCENT, CITY BEACH        empty  ...                  empty
# 17                   57 NEWINGTON RD        empty  ...                  empty
# ...                              ...          ...  ...                    ...
# 1466                           empty        empty  ...                  empty
# 1468                           empty        empty  ...                  empty
# 1469                           empty        empty  ...                  empty
# 1472                           empty        empty  ...                  empty
# 1482                           empty        empty  ...                  empty
#
#      Opt In     Contact Type Odyssey Members     Lead Brand Lead Sub-Brand  \
# 5       YES  Email and Phone              NO  Karma Resorts          Other
# 9       YES  Email and Phone              NO  Karma Resorts          Other
# 11      YES  Email and Phone              NO  Karma Resorts          Other
# 14      YES  Email and Phone              NO  Karma Resorts          Other
# 17      YES       Email Only              NO  Karma Resorts          Other
# ...     ...              ...             ...            ...            ...
# 1466    YES       Email Only              NO  Karma Resorts          Other
# 1468    YES       Email Only              NO  Karma Resorts          Other
# 1469    YES       Email Only              NO  Karma Resorts          Other
# 1472    YES       Email Only              NO  Karma Resorts          Other
# 1482    YES  Email and Phone              NO  Karma Resorts          Other
#
#       Lead Source                           Lead Locations  \
# 5     Past Guests                             Karma Minoan
# 9     Past Guests  KRR @ Karma Kandara, Mentari Residences
# 11    Past Guests                        Karma Royal Sanur
# 14    Past Guests             KRR @ Karma Kandara, Phase V
# 17    Past Guests             KRR @ Karma Kandara, Phase V
# ...           ...                                      ...
# 1466  Past Guests        Wyndham -  Manoir des Deux Amants
# 1468  Past Guests        Wyndham -  Manoir des Deux Amants
# 1469  Past Guests        Wyndham -  Manoir des Deux Amants
# 1472  Past Guests        Wyndham -  Manoir des Deux Amants
# 1482  Past Guests                           Karma Jimbaran
#
#      Lead Source Description Exclude From Mailing
# 5                  Viewpoint                   NO
# 9                  Viewpoint                   NO
# 11                 Viewpoint                   NO
# 14                 Viewpoint                   NO
# 17                 Viewpoint                   NO
# ...                      ...                  ...
# 1466               Viewpoint                   NO
# 1468               Viewpoint                   NO
# 1469               Viewpoint                   NO
# 1472               Viewpoint                   NO
# 1482               Viewpoint                   NO
#
# [319 rows x 37 columns]

# %%
df_viewpoint.drop_duplicates(subset=['Phone','Mobile','Email'], inplace=True)
df_viewpoint.reset_index(drop=True, inplace=True)

# hitung jumlah setelah value duplicate dihapus
count_after_dedup_duplicate = df_viewpoint.shape[0]

df_viewpoint
# Out:
#       Title                Firstname     lastname                  DOB  \
# 0        Mr                     Alan    Chatfield  1954-11-16 00:00:00
# 1        Mr              Ajit Romesh  Ambalavaner  1966-12-07 00:00:00
# 2        Mr               Alan James     Bennetts  1957-02-10 00:00:00
# 3       Mrs                      Amy        Rowse  1984-05-06 00:00:00
# 4       Mrs                 Andriena        Munro  1966-05-28 00:00:00
# ...     ...                      ...          ...                  ...
# 1162  empty         Blineau, Nicolas            -                empty
# 1163  empty          Dehghani, Nikki            -                empty
# 1164  empty         Schleger, Leonie            -                empty
# 1165  empty  Stiles, Aaron & Carolyn            -                empty
# 1166  empty       Clements, Clifford            -                empty
#
#      PAN CARD                             Email        Phone       Mobile  \
# 0       empty            achatfield54@gmail.com  61410559843        empty
# 1       empty  ajit@honeylightconsulting.com.au  61410633327        empty
# 2       empty        alan.bennetts@iinet.net.au  61893791956  61430157009
# 3       empty             amy.rowse@hotmail.com  61439375559        empty
# 4       empty        andriena.munro@bigpond.com  61410437261        empty
# ...       ...                               ...          ...          ...
# 1162    empty                     expedia-hotel        empty        empty
# 1163    empty                     expedia-hotel        90248        empty
# 1164    empty         ischleger@optusnet.com.au    393480198    421604879
# 1165    empty                jomie@iinet.net.au    894028229    422559309
# 1166    empty                             sales        empty        empty
#
#              AddressLine1   AddressLine2  ... Sales Rep and Comments Opt In  \
# 0       MOUNTAIN VIEW 169  TREETOPS BLVD  ...                  KEVIN    YES
# 1     5 GARDEN VIEW COURT          empty  ...                  empty    YES
# 2      58 CHESTERTON ROAD     BASSENDEAN  ...                 ESTHER    YES
# 3         3 SCARLET CLOSE          empty  ...                  empty    YES
# 4                   empty          empty  ...                  empty    YES
# ...                   ...            ...  ...                    ...    ...
# 1162                empty          empty  ...                  empty    YES
# 1163                empty          empty  ...                  empty    YES
# 1164                empty          empty  ...                  empty    YES
# 1165                empty          empty  ...                  empty    YES
# 1166                empty          empty  ...                  empty    YES
#
#          Contact Type Odyssey Members     Lead Brand Lead Sub-Brand  \
# 0     Email and Phone              NO  Karma Resorts          Other
# 1     Email and Phone              NO  Karma Resorts          Other
# 2     Email and Phone              NO  Karma Resorts          Other
# 3     Email and Phone              NO  Karma Resorts          Other
# 4     Email and Phone              NO  Karma Resorts          Other
# ...               ...             ...            ...            ...
# 1162       Email Only              NO  Karma Resorts          Other
# 1163  Email and Phone              NO  Karma Resorts          Other
# 1164  Email and Phone              NO  Karma Resorts          Other
# 1165  Email and Phone              NO  Karma Resorts          Other
# 1166       Email Only              NO  Karma Resorts          Other
#
#       Lead Source                           Lead Locations  \
# 0     Past Guests                        Karma Royal Sanur
# 1     Past Guests  KRR @ Karma Kandara, Mentari Residences
# 2     Past Guests                           Karma Jimbaran
# 3     Past Guests                            Karma Kandara
# 4     Past Guests                             Karma Minoan
# ...           ...                                      ...
# 1162  Past Guests        Wyndham -  Manoir des Deux Amants
# 1163  Past Guests        Wyndham -  Manoir des Deux Amants
# 1164  Past Guests        Wyndham -  Manoir des Deux Amants
# 1165  Past Guests        Wyndham -  Manoir des Deux Amants
# 1166  Past Guests        Wyndham -  Manoir des Deux Amants
#
#      Lead Source Description Exclude From Mailing
# 0                  Viewpoint                   NO
# 1                  Viewpoint                   NO
# 2                  Viewpoint                   NO
# 3                  Viewpoint                   NO
# 4                  Viewpoint                   NO
# ...                      ...                  ...
# 1162               Viewpoint                   NO
# 1163               Viewpoint                   NO
# 1164               Viewpoint                   NO
# 1165               Viewpoint                   NO
# 1166               Viewpoint                   NO
#
# [1167 rows x 37 columns]

# %%
find_member_booking = df_viewpoint.copy()

find_member_booking.loc[find_member_booking['Phone'].isin(df_phone['Mobile']), 'Same Value Find'] = 'Member-Mobile' 
find_member_booking.loc[find_member_booking['Mobile'].isin(df_phone['Mobile']), 'Same Value Find'] = 'Member-Mobile'

find_member_booking.loc[find_member_booking['Email'].isin(df_email['Email']), 'Same Value Find'] = 'Member-Email'
find_member_booking.drop(find_member_booking.loc[find_member_booking['Same Value Find'].isna()].index, inplace=True)

# %%
find_member_booking
# Out:
#      Title    Firstname     lastname                  DOB PAN CARD  \
# 0       Mr         Alan    Chatfield  1954-11-16 00:00:00    empty
# 1       Mr  Ajit Romesh  Ambalavaner  1966-12-07 00:00:00    empty
# 2       Mr   Alan James     Bennetts  1957-02-10 00:00:00    empty
# 3      Mrs          Amy        Rowse  1984-05-06 00:00:00    empty
# 4      Mrs     Andriena        Munro  1966-05-28 00:00:00    empty
# ...    ...          ...          ...                  ...      ...
# 1133    Mr       Adrian        Ralph  1959-05-21 00:00:00    empty
# 1134    Mr      Stephen         Page  1966-03-19 00:00:00    empty
# 1138    Mr       Trevor       Baldry                empty    empty
# 1144   Mrs     Madaline         Nick  1956-09-06 00:00:00    empty
# 1145    Mr        Zuber     Mohammad  1991-10-22 00:00:00    empty
#
#                                  Email         Phone        Mobile  \
# 0               achatfield54@gmail.com   61410559843         empty
# 1     ajit@honeylightconsulting.com.au   61410633327         empty
# 2           alan.bennetts@iinet.net.au   61893791956   61430157009
# 3                amy.rowse@hotmail.com   61439375559         empty
# 4           andriena.munro@bigpond.com   61410437261         empty
# ...                                ...           ...           ...
# 1133                stanandann@aol.com  447923041816  447923041816
# 1134     stephen.page17@btinternet.com  447766553375  441623812565
# 1138                trevbaldry@aol.com  447971177747         empty
# 1144           madeline.nick@yahoo.com   18453407405   18453999100
# 1145        sameerah.desnavi@gmail.com   12133218580         empty
#
#                    AddressLine1   AddressLine2  ... Opt In     Contact Type  \
# 0             MOUNTAIN VIEW 169  TREETOPS BLVD  ...    YES  Email and Phone
# 1           5 GARDEN VIEW COURT          empty  ...    YES  Email and Phone
# 2            58 CHESTERTON ROAD     BASSENDEAN  ...    YES  Email and Phone
# 3               3 SCARLET CLOSE          empty  ...    YES  Email and Phone
# 4                         empty          empty  ...    YES  Email and Phone
# ...                         ...            ...  ...    ...              ...
# 1133  STONIEDALE DOUGLAS AVENUE          empty  ...    YES  Email and Phone
# 1134            47 CHEADLE ROAD              -  ...    YES  Email and Phone
# 1138               36 BELL HILL        FINEDON  ...    YES  Email and Phone
# 1144          3000 S OCEAN BLVD        APT 701  ...    YES  Email and Phone
# 1145          31049 NW Moon St.          empty  ...    YES  Email and Phone
#
#      Odyssey Members     Lead Brand Lead Sub-Brand  Lead Source  \
# 0                 NO  Karma Resorts          Other  Past Guests
# 1                 NO  Karma Resorts          Other  Past Guests
# 2                 NO  Karma Resorts          Other  Past Guests
# 3                 NO  Karma Resorts          Other  Past Guests
# 4                 NO  Karma Resorts          Other  Past Guests
# ...              ...            ...            ...          ...
# 1133              NO  Karma Resorts          Other  Past Guests
# 1134              NO  Karma Resorts          Other  Past Guests
# 1138              NO  Karma Resorts          Other  Past Guests
# 1144              NO  Karma Resorts          Other  Past Guests
# 1145              NO  Karma Resorts          Other  Past Guests
#
#                                Lead Locations Lead Source Description  \
# 0                           Karma Royal Sanur               Viewpoint
# 1     KRR @ Karma Kandara, Mentari Residences               Viewpoint
# 2                              Karma Jimbaran               Viewpoint
# 3                               Karma Kandara               Viewpoint
# 4                                Karma Minoan               Viewpoint
# ...                                       ...                     ...
# 1133                   Karma Lake of Menteith               Viewpoint
# 1134                        Karma Royal Palms               Viewpoint
# 1138                       Karma Salford Hall               Viewpoint
# 1144                  Karma Borgo Di Colleoli               Viewpoint
# 1145                            Karma Bavaria               Viewpoint
#
#      Exclude From Mailing Same Value Find
# 0                      NO    Member-Email
# 1                      NO    Member-Email
# 2                      NO    Member-Email
# 3                      NO    Member-Email
# 4                      NO    Member-Email
# ...                   ...             ...
# 1133                   NO    Member-Email
# 1134                   NO    Member-Email
# 1138                   NO    Member-Email
# 1144                   NO    Member-Email
# 1145                   NO    Member-Email
#
# [805 rows x 38 columns]

# %%
find_member_booking.replace('empty', '', inplace=True)
find_member_booking.to_csv(r'C:\Users\fajar\Documents\Python\Data\cek_member_viewpoint.csv', index=False)

# %%
count_dedup_member = df_viewpoint.loc[
    
    df_viewpoint['Phone'].isin(df_phone['Mobile']) | 
    df_viewpoint['Mobile'].isin(df_phone['Mobile']) |

    df_viewpoint['Email'].isin(df_email['Email'])
    ].shape[0]

df_viewpoint.loc[
    
    df_viewpoint['Phone'].isin(df_phone['Mobile']) | 
    df_viewpoint['Mobile'].isin(df_phone['Mobile']) |

    df_viewpoint['Email'].isin(df_email['Email'])
    ]
# Out:
#      Title    Firstname     lastname                  DOB PAN CARD  \
# 0       Mr         Alan    Chatfield  1954-11-16 00:00:00    empty
# 1       Mr  Ajit Romesh  Ambalavaner  1966-12-07 00:00:00    empty
# 2       Mr   Alan James     Bennetts  1957-02-10 00:00:00    empty
# 3      Mrs          Amy        Rowse  1984-05-06 00:00:00    empty
# 4      Mrs     Andriena        Munro  1966-05-28 00:00:00    empty
# ...    ...          ...          ...                  ...      ...
# 1133    Mr       Adrian        Ralph  1959-05-21 00:00:00    empty
# 1134    Mr      Stephen         Page  1966-03-19 00:00:00    empty
# 1138    Mr       Trevor       Baldry                empty    empty
# 1144   Mrs     Madaline         Nick  1956-09-06 00:00:00    empty
# 1145    Mr        Zuber     Mohammad  1991-10-22 00:00:00    empty
#
#                                  Email         Phone        Mobile  \
# 0               achatfield54@gmail.com   61410559843         empty
# 1     ajit@honeylightconsulting.com.au   61410633327         empty
# 2           alan.bennetts@iinet.net.au   61893791956   61430157009
# 3                amy.rowse@hotmail.com   61439375559         empty
# 4           andriena.munro@bigpond.com   61410437261         empty
# ...                                ...           ...           ...
# 1133                stanandann@aol.com  447923041816  447923041816
# 1134     stephen.page17@btinternet.com  447766553375  441623812565
# 1138                trevbaldry@aol.com  447971177747         empty
# 1144           madeline.nick@yahoo.com   18453407405   18453999100
# 1145        sameerah.desnavi@gmail.com   12133218580         empty
#
#                    AddressLine1   AddressLine2  ... Sales Rep and Comments  \
# 0             MOUNTAIN VIEW 169  TREETOPS BLVD  ...                  KEVIN
# 1           5 GARDEN VIEW COURT          empty  ...                  empty
# 2            58 CHESTERTON ROAD     BASSENDEAN  ...                 ESTHER
# 3               3 SCARLET CLOSE          empty  ...                  empty
# 4                         empty          empty  ...                  empty
# ...                         ...            ...  ...                    ...
# 1133  STONIEDALE DOUGLAS AVENUE          empty  ...                  empty
# 1134            47 CHEADLE ROAD              -  ...                  empty
# 1138               36 BELL HILL        FINEDON  ...                  empty
# 1144          3000 S OCEAN BLVD        APT 701  ...                  empty
# 1145          31049 NW Moon St.          empty  ...                  Steve
#
#      Opt In     Contact Type Odyssey Members     Lead Brand Lead Sub-Brand  \
# 0       YES  Email and Phone              NO  Karma Resorts          Other
# 1       YES  Email and Phone              NO  Karma Resorts          Other
# 2       YES  Email and Phone              NO  Karma Resorts          Other
# 3       YES  Email and Phone              NO  Karma Resorts          Other
# 4       YES  Email and Phone              NO  Karma Resorts          Other
# ...     ...              ...             ...            ...            ...
# 1133    YES  Email and Phone              NO  Karma Resorts          Other
# 1134    YES  Email and Phone              NO  Karma Resorts          Other
# 1138    YES  Email and Phone              NO  Karma Resorts          Other
# 1144    YES  Email and Phone              NO  Karma Resorts          Other
# 1145    YES  Email and Phone              NO  Karma Resorts          Other
#
#       Lead Source                           Lead Locations  \
# 0     Past Guests                        Karma Royal Sanur
# 1     Past Guests  KRR @ Karma Kandara, Mentari Residences
# 2     Past Guests                           Karma Jimbaran
# 3     Past Guests                            Karma Kandara
# 4     Past Guests                             Karma Minoan
# ...           ...                                      ...
# 1133  Past Guests                   Karma Lake of Menteith
# 1134  Past Guests                        Karma Royal Palms
# 1138  Past Guests                       Karma Salford Hall
# 1144  Past Guests                  Karma Borgo Di Colleoli
# 1145  Past Guests                            Karma Bavaria
#
#      Lead Source Description Exclude From Mailing
# 0                  Viewpoint                   NO
# 1                  Viewpoint                   NO
# 2                  Viewpoint                   NO
# 3                  Viewpoint                   NO
# 4                  Viewpoint                   NO
# ...                      ...                  ...
# 1133               Viewpoint                   NO
# 1134               Viewpoint                   NO
# 1138               Viewpoint                   NO
# 1144               Viewpoint                   NO
# 1145               Viewpoint                   NO
#
# [805 rows x 37 columns]

# %%
df_viewpoint.drop(df_viewpoint.loc[
    
    df_viewpoint['Phone'].isin(df_phone['Mobile']) | 
    df_viewpoint['Mobile'].isin(df_phone['Mobile']) |

    df_viewpoint['Email'].isin(df_email['Email'])
].index, inplace=True)

df_viewpoint.reset_index(drop=True, inplace=True)

count_after_dedup_member = df_viewpoint.shape[0]

# %%
count_data_akhir = df_viewpoint.shape[0]

# %%
df_viewpoint.sort_values('CheckOutDate', ascending=True, inplace=True)
df_viewpoint.reset_index(drop=True, inplace=True)
df_viewpoint
# Out:
#     Title         Firstname     lastname                  DOB PAN CARD  \
# 0      Mr          Ravindra     -Bhenwal                empty    empty
# 1      Mr    Satyajit Gopal        Manna                empty    empty
# 2      Mr  Ravindra Bhagwan  Suryawanshi                empty    empty
# 3      Mr         Veerendra        Kumar  1989-08-20 00:00:00    empty
# 4      Mr            Manish        Naole                empty    empty
# ..    ...               ...          ...                  ...      ...
# 357    Mr             Vinod        Dhruv                empty    empty
# 358    Mr             Nitin        Kumar                empty    empty
# 359    Mr          Narender       .Singh                empty    empty
# 360    Mr         Ghanshyam       Pathak  2024-09-09 00:00:00    empty
# 361    Mr    Suumit Shripad        Joshi                empty    empty
#
#                           Email         Phone        Mobile  \
# 0      jyotivruksh124@gmail.com  919325571128  919272123272
# 1    satyajit.manna85@gmail.com  919930494270  917039696034
# 2           rs.111369@gmail.com  919819111369  919769111369
# 3       veerendra.vrm@gmail.com  919584455460  919644953421
# 4       manishnaole@yahoo.co.in  919922191122  919834748389
# ..                          ...           ...           ...
# 357      vinod.dhru89@gmail.com  919466010400  919468110400
# 358      jaiswalji.ji@gmail.com  919534672488  918581895089
# 359      dilrana.9090@gmail.com  918750046319  918750046320
# 360      shyam32shyam@gmail.com  919820078475  919167655046
# 361  sumeet_joshi83@yahoo.co.in  919923310008         empty
#
#                                           AddressLine1  \
# 0                               -105/B SAIGANESH KUTIR
# 1    A/104, SWAMI SAMARTH CHS, DATTA MANDIR ROAD, B...
# 2    .ROOM NO. 03, SAKET SOCIETY, NEAR BHAVANA STOR...
# 3                                 WARD NO 06 NEAR MATA
# 4    602 GANESH VISHWA, GOKUL      NAGAR KATRAJ , 4...
# ..                                                 ...
# 357                                     HOUSE NO 393 1
# 358                                   BISHANPUR,SUPAUL
# 359                       A 148 GALI NO.1 HARDEV NAGAR
# 360                         103 SHREE VAIKUNTH CHS LTD
# 361                  303,Suvarnanagri,takshila society
#
#                         AddressLine2  ... Sales Rep and Comments Opt In  \
# 0        - VIJAY NAGAR KALYAN 421306  ...                  empty    YES
# 1                              empty  ...                  empty    YES
# 2                                  .  ...                  empty    YES
# 3                  MANDIR CHAND DIST  ...                  empty    YES
# 4                              empty  ...                  empty    YES
# ..                               ...  ...                    ...    ...
# 357                     ADARSH NAGAR  ...                  empty    YES
# 358                           .BIHAR  ...                  empty    YES
# 359   JHARODA MAZRA BURARI NEW DELHI  ...    RANA HITKARSH SINGH    YES
# 360    UPPER GOVIND NAGAR MALAD EAST  ...                  empty    YES
# 361                            empty  ...                  empty    YES
#
#         Contact Type Odyssey Members     Lead Brand Lead Sub-Brand  \
# 0    Email and Phone              NO  Karma Resorts          Other
# 1    Email and Phone              NO  Karma Resorts          Other
# 2    Email and Phone              NO  Karma Resorts          Other
# 3    Email and Phone              NO  Karma Resorts          Other
# 4    Email and Phone              NO  Karma Resorts          Other
# ..               ...             ...            ...            ...
# 357  Email and Phone              NO  Karma Resorts          Other
# 358  Email and Phone              NO  Karma Resorts          Other
# 359  Email and Phone              NO  Karma Resorts          Other
# 360  Email and Phone              NO  Karma Resorts          Other
# 361  Email and Phone              NO  Karma Resorts          Other
#
#      Lead Source            Lead Locations Lead Source Description  \
# 0    Past Guests         Karma Royal Palms               Viewpoint
# 1    Past Guests         Karma Royal Palms               Viewpoint
# 2    Past Guests         Karma Royal Palms               Viewpoint
# 3    Past Guests         Karma Royal Palms               Viewpoint
# 4    Past Guests         Karma Royal Palms               Viewpoint
# ..           ...                       ...                     ...
# 357  Past Guests   Karma Sitabani, Corbett               Viewpoint
# 358  Past Guests      Karma Haveli, Jaipur               Viewpoint
# 359  Past Guests   Karma Sitabani, Corbett               Viewpoint
# 360  Past Guests         Karma Royal Palms               Viewpoint
# 361  Past Guests  Karma Royal Haathi Mahal               Viewpoint
#
#     Exclude From Mailing
# 0                     NO
# 1                     NO
# 2                     NO
# 3                     NO
# 4                     NO
# ..                   ...
# 357                   NO
# 358                   NO
# 359                   NO
# 360                   NO
# 361                   NO
#
# [362 rows x 37 columns]

# %%
# find_member_booking[['Email','Same Value Find']].loc[find_member_booking['BookingNo'] == '2074237']
# df_viewpoint.loc[df_viewpoint['BookingNo'] == '2097221']
# df_viewpoint.loc[df_viewpoint['Email'].str.contains('prajuizn@gmail.com')]

# %%
df_viewpoint['DOB'].replace('empty', '', inplace=True)
dob_con_date = pd.to_datetime(df_viewpoint['DOB'])
dob_date = dob_con_date.dt.strftime('%Y-%m-%d')

arr_con_date = pd.to_datetime(df_viewpoint['Arrival'])
arr_date = arr_con_date.dt.strftime('%Y-%m-%d')

dep_con_date = pd.to_datetime(df_viewpoint['Departure'])
dep_date = dep_con_date.dt.strftime('%Y-%m-%d')

ci_con_date = pd.to_datetime(df_viewpoint['CheckInDate'])
ci_date = ci_con_date.dt.strftime('%Y-%m-%d')

co_con_date = pd.to_datetime(df_viewpoint['CheckOutDate'])
co_date = co_con_date.dt.strftime('%Y-%m-%d')

df_viewpoint['DOB'] = dob_date
df_viewpoint['Arrival'] = arr_date
df_viewpoint['Departure'] = dep_date
df_viewpoint['CheckInDate'] = ci_date
df_viewpoint['CheckOutDate'] = co_date

# %%
df_viewpoint.columns
# Out:
# Index(['Title', 'Firstname', 'lastname', 'DOB', 'PAN CARD', 'Email', 'Phone',
#        'Mobile', 'AddressLine1', 'AddressLine2', 'Town', 'State', 'Country',
#        'PostCode', 'Nationality', 'MaritalStatus', 'resortname', 'Arrival',
#        'Departure', 'CheckInDate', 'CheckOutDate', 'room', 'UnitCategory',
#        'BookingNo', 'BookingSourceDesc', 'BookingTypeDesc', 'Date of Tour',
#        'Sales Rep and Comments', 'Opt In', 'Contact Type', 'Odyssey Members',
#        'Lead Brand', 'Lead Sub-Brand', 'Lead Source', 'Lead Locations',
#        'Lead Source Description', 'Exclude From Mailing'],
#       dtype='object')

# %%
new_cols = ['Lead Brand','Lead Sub-Brand','Lead Source','Lead Locations','Lead Source Description','Title','Firstname','lastname','DOB','Email','Phone','Mobile','AddressLine1','AddressLine2','Town','State',
'Country','PostCode','Nationality','MaritalStatus',	'resortname', 'Arrival', 'Departure', 'CheckInDate', 'CheckOutDate', 'room', 'UnitCategory', 'BookingNo', 'BookingSourceDesc', 'BookingTypeDesc', 'Date of Tour', 'Sales Rep and Comments',	'Opt In', 'Exclude From Mailing', 'Odyssey Members', 'Contact Type']																																																																																																																																						

df_viewpoint = df_viewpoint.reindex(columns=new_cols)

# %%
df_viewpoint.replace('empty', '', inplace=True)

df_viewpoint.sort_values('Departure', ascending=True, inplace=True)
df_viewpoint.reset_index(drop=True, inplace=True)
df_viewpoint
# Out:
#         Lead Brand Lead Sub-Brand  Lead Source            Lead Locations  \
# 0    Karma Resorts          Other  Past Guests         Karma Royal Palms
# 1    Karma Resorts          Other  Past Guests             Karma Bavaria
# 2    Karma Resorts          Other  Past Guests   Karma Sitabani, Corbett
# 3    Karma Resorts          Other  Past Guests  Karma Royal Haathi Mahal
# 4    Karma Resorts          Other  Past Guests         Karma Royal Palms
# ..             ...            ...          ...                       ...
# 357  Karma Resorts          Other  Past Guests         Karma Royal Palms
# 358  Karma Resorts          Other  Past Guests   Karma Sitabani, Corbett
# 359  Karma Resorts          Other  Past Guests      Karma Haveli, Jaipur
# 360  Karma Resorts          Other  Past Guests   Karma Sitabani, Corbett
# 361  Karma Resorts          Other  Past Guests  Karma Royal Haathi Mahal
#
#     Lead Source Description Title       Firstname  lastname         DOB  \
# 0                 Viewpoint    Mr        Ravindra  -Bhenwal         NaN
# 1                 Viewpoint                Markus   Bischof  1973-01-28
# 2                 Viewpoint    Mr           Karan    Talwar         NaN
# 3                 Viewpoint    Mr           Vivek     Ladge         NaN
# 4                 Viewpoint    Mr       Prem Anil     Sagar         NaN
# ..                      ...   ...             ...       ...         ...
# 357               Viewpoint    Mr       Ghanshyam    Pathak  2024-09-09
# 358               Viewpoint    Mr           Vinod     Dhruv         NaN
# 359               Viewpoint    Mr           Nitin     Kumar         NaN
# 360               Viewpoint    Mr        Narender    .Singh         NaN
# 361               Viewpoint    Mr  Suumit Shripad     Joshi         NaN
#
#                           Email  ...           UnitCategory BookingNo  \
# 0      jyotivruksh124@gmail.com  ...   Non Member 1 Bedroom   2611005
# 1         markus.bischof@gmx.de  ...  Classic Room Superior   2304643
# 2        sonalahuja16@gmail.com  ...  Non Member Hotel Unit   2576979
# 3          vivekladge@gmail.com  ...    Hotel Unit Standard   2578686
# 4        pragnasoni25@gmail.com  ...    1 Bedroom Apartment   2529903
# ..                          ...  ...                    ...       ...
# 357      shyam32shyam@gmail.com  ...   Non Member 1 Bedroom   2616549
# 358      vinod.dhru89@gmail.com  ...  Non Member Hotel Unit   2616373
# 359      jaiswalji.ji@gmail.com  ...             Hotel Unit   2616222
# 360      dilrana.9090@gmail.com  ...  Non Member Hotel Unit   2602563
# 361  sumeet_joshi83@yahoo.co.in  ...    Hotel Unit Standard   2613734
#
#     BookingSourceDesc         BookingTypeDesc         Date of Tour  \
# 0      Fly Buy Indian  Karma Experience India
# 1     Fly Buy Western                  Booksi  2024-08-29 12:01:00
# 2      Fly Buy Indian  Karma Experience India  2024-08-30 03:30:00
# 3         KCE2 Indian  Karma Experience India  2024-08-31 17:38:00
# 4          Affiliates         Leadgen/7across  2024-08-30 11:30:00
# ..                ...                     ...                  ...
# 357    Fly Buy Indian  Karma Experience India
# 358    Fly Buy Indian  Karma Experience India
# 359    Fly Buy Indian  Karma Experience India
# 360    Fly Buy Indian  Karma Experience India  2024-09-08 10:30:00
# 361   Guest of Member       Entitlement Guest
#
#     Sales Rep and Comments Opt In Exclude From Mailing Odyssey Members  \
# 0                             YES                   NO              NO
# 1                     Hava    YES                   NO              NO
# 2            MURARI SHARMA    YES                   NO              NO
# 3                 MITHAEEL    YES                   NO              NO
# 4            Harshit Verma    YES                   NO              NO
# ..                     ...    ...                  ...             ...
# 357                           YES                   NO              NO
# 358                           YES                   NO              NO
# 359                           YES                   NO              NO
# 360    RANA HITKARSH SINGH    YES                   NO              NO
# 361                           YES                   NO              NO
#
#         Contact Type
# 0    Email and Phone
# 1    Email and Phone
# 2    Email and Phone
# 3    Email and Phone
# 4    Email and Phone
# ..               ...
# 357  Email and Phone
# 358  Email and Phone
# 359  Email and Phone
# 360  Email and Phone
# 361  Email and Phone
#
# [362 rows x 36 columns]

# %%
print("==========================================================")
print("Summary")
print("==========================================================")
print("Jumlah Data Setelah Script Past Guest Sebelumnya : "+str(count_data_awal))
print("Jumlah Data Yang Duplicate : "+str(count_duplicate_general))
print("Jumlah Data Setelah Hapus Duplicate : "+str(count_after_dedup_duplicate))
print("Jumlah Data Yang Termasuk Member: "+str(count_dedup_member))
print("Jumlah Data Setelah Hapus Member : "+str(count_after_dedup_member))
print("Jumlah Data Akhir : "+str(count_data_akhir))
# Out:
# ==========================================================
# Summary
# ==========================================================
# Jumlah Data Setelah Script Past Guest Sebelumnya : 1486
# Jumlah Data Yang Duplicate : 319
# Jumlah Data Setelah Hapus Duplicate : 1167
# Jumlah Data Yang Termasuk Member: 805
# Jumlah Data Setelah Hapus Member : 362
# Jumlah Data Akhir : 362

# %%
df_viewpoint.to_excel(r'C:\Users\fajar\Documents\Python\Data\final_viewpoint.xlsx', index=False)
