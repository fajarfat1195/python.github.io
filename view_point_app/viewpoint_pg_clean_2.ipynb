# %%
import pandas as pd
import re

import past_guest_module as pm

import sys
sys.path.append('../zoho_data_app/')

import main_module as m

# %load_ext autoreload
# %autoreload 2

# %%
path = r'C:\Users\fajar\Documents\Python\Data\check_country_code_viewpoint.xlsx'
df_viewpoint = pd.read_excel(path, dtype='string', sheet_name='Sheet1')
count_data_awal = df_viewpoint.shape[0]

# %%
df_viewpoint.fillna('empty', inplace=True)

# %%
path = r'G:\.shortcut-targets-by-id\0B_d3smBjzo04UUNBME5GOVhoMjA\_ODYSSEY\Phone Members.xlsx'
df_phone = pd.read_excel(path, dtype='string', sheet_name='Sheet1')

path = r'G:\.shortcut-targets-by-id\0B_d3smBjzo04UUNBME5GOVhoMjA\_ODYSSEY\Email Members.xlsx'
df_email = pd.read_excel(path, dtype='string', sheet_name='Sheet1')

# %%
m.clean_space(df_email, 'Email')
df_email['Email'] = m.lowercase(df_email, 'Email')

# %%
# hitung jumlah duplicate
count_duplicate_general = df_viewpoint.loc[df_viewpoint.duplicated(subset=['Phone','Mobile','Email'])].shape[0]

df_viewpoint.loc[df_viewpoint.duplicated(subset=['Phone','Mobile','Email'])]
# Out:
#       Title                 Firstname     lastname                  DOB  \
# 7        Mr                    Andrew     Thatcher  1968-12-31 00:00:00
# 10       Mr              Anya Brand &  Simon Laird                empty
# 16       Mr            Ashley Gerrard        Mijat  1971-10-27 00:00:00
# 18       Mr                    Rodney       Atkins                empty
# 20       Ms                    Aurora      Pagonis  1968-07-30 00:00:00
# ...     ...                       ...          ...                  ...
# 1703  empty           Arahou, Nisrine            -                empty
# 1704  empty  Le Chevanton, Marie-Line            -                empty
# 1705  empty              Eley, Aubert            -                empty
# 1716  empty           Albright, Chris            -                empty
# 1723  empty    Wagner, Pieter & Paola            -                empty
#
#      PAN CARD                      Email        Phone       Mobile  \
# 7       empty  andrew.t5@optusnet.com.au  61435846379  61482069255
# 10      empty       anyabrand5@gmail.com  61414622289  61414622289
# 16      empty         ash@globaldial.com  61411744244        empty
# 18      empty       atkinswest@gmail.com  61263524356  61401936466
# 20      empty   aurora.pagonis@gmail.com  61411827226        empty
# ...       ...                        ...          ...          ...
# 1703    empty                booking.com        empty        empty
# 1704    empty                booking.com        empty        empty
# 1705    empty                booking.com        empty        empty
# 1716    empty                    expedia        27051        empty
# 1723    empty      mariela1739@gmail.com  64210426111     21726733
#
#                     AddressLine1 AddressLine2  ... Sales Rep and Comments  \
# 7     17 Mead Crt Wantirna South        empty  ...                  empty
# 10                             -            -  ...                  empty
# 16                   PO BOX 3005     BROADWAY  ...                  empty
# 18                     27 HAY ST        empty  ...                   Suzy
# 20                         empty        empty  ...                  empty
# ...                          ...          ...  ...                    ...
# 1703                       empty        empty  ...                  empty
# 1704                       empty        empty  ...                  empty
# 1705                       empty        empty  ...                  empty
# 1716                       empty        empty  ...                  empty
# 1723                       empty        empty  ...                  empty
#
#      Opt In     Contact Type Odyssey Members     Lead Brand Lead Sub-Brand  \
# 7       YES  Email and Phone              NO  Karma Resorts          Other
# 10      YES  Email and Phone              NO  Karma Resorts          Other
# 16      YES  Email and Phone              NO  Karma Resorts          Other
# 18      YES  Email and Phone              NO  Karma Resorts          Other
# 20      YES  Email and Phone              NO  Karma Resorts          Other
# ...     ...              ...             ...            ...            ...
# 1703    YES       Email Only              NO  Karma Resorts          Other
# 1704    YES       Email Only              NO  Karma Resorts          Other
# 1705    YES       Email Only              NO  Karma Resorts          Other
# 1716    YES  Email and Phone              NO  Karma Resorts          Other
# 1723    YES  Email and Phone              NO  Karma Resorts          Other
#
#       Lead Source                           Lead Locations  \
# 7     Past Guests             KRR @ Karma Kandara, Phase V
# 10    Past Guests  KRR @ Karma Kandara, Mentari Residences
# 16    Past Guests                           Karma Jimbaran
# 18    Past Guests                    Karma Royal Candidasa
# 20    Past Guests  KRR @ Karma Kandara, Mentari Residences
# ...           ...                                      ...
# 1703  Past Guests        Wyndham -  Manoir des Deux Amants
# 1704  Past Guests        Wyndham -  Manoir des Deux Amants
# 1705  Past Guests        Wyndham -  Manoir des Deux Amants
# 1716  Past Guests        Wyndham -  Manoir des Deux Amants
# 1723  Past Guests        Wyndham -  Manoir des Deux Amants
#
#      Lead Source Description Exclude From Mailing
# 7                  Viewpoint                   NO
# 10                 Viewpoint                   NO
# 16                 Viewpoint                   NO
# 18                 Viewpoint                   NO
# 20                 Viewpoint                   NO
# ...                      ...                  ...
# 1703               Viewpoint                   NO
# 1704               Viewpoint                   NO
# 1705               Viewpoint                   NO
# 1716               Viewpoint                   NO
# 1723               Viewpoint                   NO
#
# [419 rows x 37 columns]

# %%
df_viewpoint.drop_duplicates(subset=['Phone','Mobile','Email'], inplace=True)
df_viewpoint.reset_index(drop=True, inplace=True)

# hitung jumlah setelah value duplicate dihapus
count_after_dedup_duplicate = df_viewpoint.shape[0]

df_viewpoint
# Out:
#       Title                 Firstname  lastname                  DOB PAN CARD  \
# 0        Mr                   Matthew       Lee  1971-05-12 00:00:00    empty
# 1        Mr                    Andrew      Till                empty    empty
# 2        Mr                     Allan   Godfrey  1966-02-11 00:00:00    empty
# 3        Ms                    Andrea  Cardwell  1962-02-16 00:00:00    empty
# 4        Ms                 Alexandra   Elliott  1985-03-02 00:00:00    empty
# ...     ...                       ...       ...                  ...      ...
# 1304  empty    Wagner, Pieter & Paola         -                empty    empty
# 1305  empty  Narayan, Andrew & Nergis         -                empty    empty
# 1306  empty      Lyons, Robert & Joan         -                empty    empty
# 1307  empty   Emery, Matthew & Andrea         -                empty    empty
# 1308  empty  Hegerty, James & Therese         -                empty    empty
#
#                                   Email        Phone       Mobile  \
# 0                   admin@lee-croft.com  61417557566        empty
# 1                     aftilly@gmail.com  61409349099        empty
# 2     agodfrey@royallifesavingwa.com.au  61430477517        empty
# 3               al_cardwell@hotmail.com  61895819423  61424342645
# 4             alex.littlejohn@gmail.com  61412950734  61412950734
# ...                                 ...          ...          ...
# 1304              mariela1739@gmail.com  64210426111     21726733
# 1305              nergis@narayan.net.nz   6445673960   6421672588
# 1306                 ozboss55@gmail.com    409370458        empty
# 1307                  styxy10@gmail.com    400330164        empty
# 1308           t.hegerty@teameng.com.au    417757984    419673374
#
#           AddressLine1  AddressLine2  ... Sales Rep and Comments Opt In  \
# 0        25 HACKETT RD         empty  ...                  empty    YES
# 1     45 SEAHORSE LOOP         empty  ...                  empty    YES
# 2         6b Beaton St         empty  ...                  FREYA    YES
# 3      74 PERSEUS ROAD  SILVER SANDS  ...                CRAIG B    YES
# 4      30 Cuming Place         empty  ...                  empty    YES
# ...                ...           ...  ...                    ...    ...
# 1304             empty         empty  ...                  empty    YES
# 1305             empty         empty  ...                  empty    YES
# 1306             empty         empty  ...                  empty    YES
# 1307             empty         empty  ...                  empty    YES
# 1308             empty         empty  ...                  empty    YES
#
#          Contact Type Odyssey Members     Lead Brand Lead Sub-Brand  \
# 0     Email and Phone              NO  Karma Resorts          Other
# 1     Email and Phone              NO  Karma Resorts          Other
# 2     Email and Phone              NO  Karma Resorts          Other
# 3     Email and Phone              NO  Karma Resorts          Other
# 4     Email and Phone              NO  Karma Resorts          Other
# ...               ...             ...            ...            ...
# 1304  Email and Phone              NO  Karma Resorts          Other
# 1305  Email and Phone              NO  Karma Resorts          Other
# 1306  Email and Phone              NO  Karma Resorts          Other
# 1307  Email and Phone              NO  Karma Resorts          Other
# 1308  Email and Phone              NO  Karma Resorts          Other
#
#       Lead Source                           Lead Locations  \
# 0     Past Guests  KRR @ Karma Kandara, Mentari Residences
# 1     Past Guests                   Karma Lake of Menteith
# 2     Past Guests                          Karma Song Hoai
# 3     Past Guests             KRR @ Karma Kandara, Phase V
# 4     Past Guests             KRR @ Karma Kandara, Phase V
# ...           ...                                      ...
# 1304  Past Guests        Wyndham -  Manoir des Deux Amants
# 1305  Past Guests        Wyndham -  Manoir des Deux Amants
# 1306  Past Guests        Wyndham -  Manoir des Deux Amants
# 1307  Past Guests        Wyndham -  Manoir des Deux Amants
# 1308  Past Guests        Wyndham -  Manoir des Deux Amants
#
#      Lead Source Description Exclude From Mailing
# 0                  Viewpoint                   NO
# 1                  Viewpoint                   NO
# 2                  Viewpoint                   NO
# 3                  Viewpoint                   NO
# 4                  Viewpoint                   NO
# ...                      ...                  ...
# 1304               Viewpoint                   NO
# 1305               Viewpoint                   NO
# 1306               Viewpoint                   NO
# 1307               Viewpoint                   NO
# 1308               Viewpoint                   NO
#
# [1309 rows x 37 columns]

# %%
find_member_booking = df_viewpoint.copy()

find_member_booking.loc[find_member_booking['Phone'].isin(df_phone['Mobile']), 'Same Value Find'] = 'Member-Mobile' 
find_member_booking.loc[find_member_booking['Mobile'].isin(df_phone['Mobile']), 'Same Value Find'] = 'Member-Mobile'

find_member_booking.loc[find_member_booking['Email'].isin(df_email['Email']), 'Same Value Find'] = 'Member-Email'
find_member_booking.drop(find_member_booking.loc[find_member_booking['Same Value Find'].isna()].index, inplace=True)

# %%
find_member_booking
# Out:
#       Title         Firstname      lastname                  DOB PAN CARD  \
# 0        Mr           Matthew           Lee  1971-05-12 00:00:00    empty
# 1        Mr            Andrew          Till                empty    empty
# 2        Mr             Allan       Godfrey  1966-02-11 00:00:00    empty
# 3        Ms            Andrea      Cardwell  1962-02-16 00:00:00    empty
# 4        Ms         Alexandra       Elliott  1985-03-02 00:00:00    empty
# ...     ...               ...           ...                  ...      ...
# 1281     Mr        John Allen     Thomassen  1958-06-19 00:00:00    empty
# 1285     Mr              Mark      Williams  1965-04-15 00:00:00    empty
# 1300  empty   Janghyeon, Choi             -                empty    empty
# 1301  empty  Theisen, Susanne             -                empty    empty
# 1302  empty                Mr  Paul Gelardi                empty    empty
#
#                                   Email         Phone       Mobile  \
# 0                   admin@lee-croft.com   61417557566        empty
# 1                     aftilly@gmail.com   61409349099        empty
# 2     agodfrey@royallifesavingwa.com.au   61430477517        empty
# 3               al_cardwell@hotmail.com   61895819423  61424342645
# 4             alex.littlejohn@gmail.com   61412950734  61412950734
# ...                                 ...           ...          ...
# 1281                jatphd123@gmail.com   15853298560        empty
# 1285               markmoth@hotmail.com  447779230001        empty
# 1300                        expedia-net         24224        empty
# 1301                        expedia-net         10115        empty
# 1302                    info@nakula.com  628113855855        empty
#
#                AddressLine1  AddressLine2  ... Opt In     Contact Type  \
# 0             25 HACKETT RD         empty  ...    YES  Email and Phone
# 1          45 SEAHORSE LOOP         empty  ...    YES  Email and Phone
# 2              6b Beaton St         empty  ...    YES  Email and Phone
# 3           74 PERSEUS ROAD  SILVER SANDS  ...    YES  Email and Phone
# 4           30 Cuming Place         empty  ...    YES  Email and Phone
# ...                     ...           ...  ...    ...              ...
# 1281  831 W BLOOMFIELD ROAD         empty  ...    YES  Email and Phone
# 1285          38, LEE CLOSE   COED EDEYRN  ...    YES  Email and Phone
# 1300                  empty         empty  ...    YES  Email and Phone
# 1301                  empty         empty  ...    YES  Email and Phone
# 1302                  empty         empty  ...    YES  Email and Phone
#
#      Odyssey Members     Lead Brand Lead Sub-Brand  Lead Source  \
# 0                 NO  Karma Resorts          Other  Past Guests
# 1                 NO  Karma Resorts          Other  Past Guests
# 2                 NO  Karma Resorts          Other  Past Guests
# 3                 NO  Karma Resorts          Other  Past Guests
# 4                 NO  Karma Resorts          Other  Past Guests
# ...              ...            ...            ...          ...
# 1281              NO  Karma Resorts          Other  Past Guests
# 1285              NO  Karma Resorts          Other  Past Guests
# 1300              NO  Karma Resorts          Other  Past Guests
# 1301              NO  Karma Resorts          Other  Past Guests
# 1302              NO  Karma Resorts          Other  Past Guests
#
#                                Lead Locations Lead Source Description  \
# 0     KRR @ Karma Kandara, Mentari Residences               Viewpoint
# 1                      Karma Lake of Menteith               Viewpoint
# 2                             Karma Song Hoai               Viewpoint
# 3                KRR @ Karma Kandara, Phase V               Viewpoint
# 4                KRR @ Karma Kandara, Phase V               Viewpoint
# ...                                       ...                     ...
# 1281                       Karma Salford Hall               Viewpoint
# 1285                         Karma La Herriza               Viewpoint
# 1300        Wyndham -  Manoir des Deux Amants               Viewpoint
# 1301        Wyndham -  Manoir des Deux Amants               Viewpoint
# 1302                           Karma Jimbaran               Viewpoint
#
#      Exclude From Mailing Same Value Find
# 0                      NO    Member-Email
# 1                      NO    Member-Email
# 2                      NO    Member-Email
# 3                      NO    Member-Email
# 4                      NO    Member-Email
# ...                   ...             ...
# 1281                   NO    Member-Email
# 1285                   NO    Member-Email
# 1300                   NO    Member-Email
# 1301                   NO    Member-Email
# 1302                   NO    Member-Email
#
# [885 rows x 38 columns]

# %%
find_member_booking.replace('empty', '', inplace=True)
find_member_booking.to_csv(r'C:\Users\fajar\Documents\Python\Data\cek_member_viewpoint.csv', index=False)

# %%
count_dedup_member = df_viewpoint.loc[
    
    df_viewpoint['Phone'].isin(df_phone['Mobile']) | 
    df_viewpoint['Mobile'].isin(df_phone['Mobile']) |

    df_viewpoint['Email'].isin(df_email['Email'])
    ].shape[0]

df_viewpoint.loc[
    
    df_viewpoint['Phone'].isin(df_phone['Mobile']) | 
    df_viewpoint['Mobile'].isin(df_phone['Mobile']) |

    df_viewpoint['Email'].isin(df_email['Email'])
    ]
# Out:
#       Title         Firstname      lastname                  DOB PAN CARD  \
# 0        Mr           Matthew           Lee  1971-05-12 00:00:00    empty
# 1        Mr            Andrew          Till                empty    empty
# 2        Mr             Allan       Godfrey  1966-02-11 00:00:00    empty
# 3        Ms            Andrea      Cardwell  1962-02-16 00:00:00    empty
# 4        Ms         Alexandra       Elliott  1985-03-02 00:00:00    empty
# ...     ...               ...           ...                  ...      ...
# 1281     Mr        John Allen     Thomassen  1958-06-19 00:00:00    empty
# 1285     Mr              Mark      Williams  1965-04-15 00:00:00    empty
# 1300  empty   Janghyeon, Choi             -                empty    empty
# 1301  empty  Theisen, Susanne             -                empty    empty
# 1302  empty                Mr  Paul Gelardi                empty    empty
#
#                                   Email         Phone       Mobile  \
# 0                   admin@lee-croft.com   61417557566        empty
# 1                     aftilly@gmail.com   61409349099        empty
# 2     agodfrey@royallifesavingwa.com.au   61430477517        empty
# 3               al_cardwell@hotmail.com   61895819423  61424342645
# 4             alex.littlejohn@gmail.com   61412950734  61412950734
# ...                                 ...           ...          ...
# 1281                jatphd123@gmail.com   15853298560        empty
# 1285               markmoth@hotmail.com  447779230001        empty
# 1300                        expedia-net         24224        empty
# 1301                        expedia-net         10115        empty
# 1302                    info@nakula.com  628113855855        empty
#
#                AddressLine1  AddressLine2  ... Sales Rep and Comments Opt In  \
# 0             25 HACKETT RD         empty  ...                  empty    YES
# 1          45 SEAHORSE LOOP         empty  ...                  empty    YES
# 2              6b Beaton St         empty  ...                  FREYA    YES
# 3           74 PERSEUS ROAD  SILVER SANDS  ...                CRAIG B    YES
# 4           30 Cuming Place         empty  ...                  empty    YES
# ...                     ...           ...  ...                    ...    ...
# 1281  831 W BLOOMFIELD ROAD         empty  ...                  empty    YES
# 1285          38, LEE CLOSE   COED EDEYRN  ...         neil aitchison    YES
# 1300                  empty         empty  ...                  empty    YES
# 1301                  empty         empty  ...                  empty    YES
# 1302                  empty         empty  ...                  empty    YES
#
#          Contact Type Odyssey Members     Lead Brand Lead Sub-Brand  \
# 0     Email and Phone              NO  Karma Resorts          Other
# 1     Email and Phone              NO  Karma Resorts          Other
# 2     Email and Phone              NO  Karma Resorts          Other
# 3     Email and Phone              NO  Karma Resorts          Other
# 4     Email and Phone              NO  Karma Resorts          Other
# ...               ...             ...            ...            ...
# 1281  Email and Phone              NO  Karma Resorts          Other
# 1285  Email and Phone              NO  Karma Resorts          Other
# 1300  Email and Phone              NO  Karma Resorts          Other
# 1301  Email and Phone              NO  Karma Resorts          Other
# 1302  Email and Phone              NO  Karma Resorts          Other
#
#       Lead Source                           Lead Locations  \
# 0     Past Guests  KRR @ Karma Kandara, Mentari Residences
# 1     Past Guests                   Karma Lake of Menteith
# 2     Past Guests                          Karma Song Hoai
# 3     Past Guests             KRR @ Karma Kandara, Phase V
# 4     Past Guests             KRR @ Karma Kandara, Phase V
# ...           ...                                      ...
# 1281  Past Guests                       Karma Salford Hall
# 1285  Past Guests                         Karma La Herriza
# 1300  Past Guests        Wyndham -  Manoir des Deux Amants
# 1301  Past Guests        Wyndham -  Manoir des Deux Amants
# 1302  Past Guests                           Karma Jimbaran
#
#      Lead Source Description Exclude From Mailing
# 0                  Viewpoint                   NO
# 1                  Viewpoint                   NO
# 2                  Viewpoint                   NO
# 3                  Viewpoint                   NO
# 4                  Viewpoint                   NO
# ...                      ...                  ...
# 1281               Viewpoint                   NO
# 1285               Viewpoint                   NO
# 1300               Viewpoint                   NO
# 1301               Viewpoint                   NO
# 1302               Viewpoint                   NO
#
# [885 rows x 37 columns]

# %%
df_viewpoint.drop(df_viewpoint.loc[
    
    df_viewpoint['Phone'].isin(df_phone['Mobile']) | 
    df_viewpoint['Mobile'].isin(df_phone['Mobile']) |

    df_viewpoint['Email'].isin(df_email['Email'])
].index, inplace=True)

df_viewpoint.reset_index(drop=True, inplace=True)

count_after_dedup_member = df_viewpoint.shape[0]

# %%
count_data_akhir = df_viewpoint.shape[0]

# %%
df_viewpoint.sort_values('CheckOutDate', ascending=True, inplace=True)
df_viewpoint.reset_index(drop=True, inplace=True)
df_viewpoint
# Out:
#     Title   Firstname      lastname                  DOB PAN CARD  \
# 0      Mr      Harish             R                empty    empty
# 1      Mr        Odin       Rodgers  1986-04-04 00:00:00    empty
# 2     Mrs       Tegan         Bryan                empty    empty
# 3      Mr     Baiyu V     Divakaray  1970-05-31 00:00:00    empty
# 4      Mr  Julius Ray       Pedroso  1985-12-07 00:00:00    empty
# ..    ...         ...           ...                  ...      ...
# 419    Mr  Jesal Shah          Shah                empty    empty
# 420    Mr       Abhin  Grace Thomas                empty    empty
# 421    Mr       Levon       Sookias                empty    empty
# 422    Mr     Parimal        Parmar                empty    empty
# 423    Mr      Tushar        Pahade                empty    empty
#
#                                     Email         Phone        Mobile  \
# 0                   harishram68@yahoo.com  919035842679  919148438148
# 1                      kcee50@hotmail.com   61406070646         empty
# 2    virtualcommercialsouthwest@gmail.com   61447569142   61447569142
# 3                  baijuvalapad@gmail.com  919447970105  918714480105
# 4                julius_ray2000@yahoo.com    6598421044         empty
# ..                                    ...           ...           ...
# 419                                 empty  919819338193  918369639127
# 420                     abhingt@gmail.com  917406229372         empty
# 421                levonsookies@gmail.com  918805244169         empty
# 422                   pparimalp@gmail.com  919892711181  919920276987
# 423                tusharpahade@gmail.com  919823536686  919764396686
#
#                                           AddressLine1  \
# 0                            NO 13 DODDAMARAPPA LAYOUT
# 1                                                empty
# 2                                                    -
# 3    VAILAPPILLY HOUSE, VALAPAD P O, THRISSUR DISTR...
# 4                                                empty
# ..                                                 ...
# 419                         606 Amar Tower 51 Anandrao
# 420              Bethel No 40 Hutchins road 6 th cross
# 421                                                  -
# 422  SAI TRISHUL CO OP HOUSG SOCT BUNG NO 8 SINDHI ...
# 423                                    SUNCITY SOCIETY
#
#                        AddressLine2  ... Sales Rep and Comments Opt In  \
# 0     HENNUR CROSS BANGALORE 560043  ...                 NARESH    YES
# 1                             empty  ...                  empty    YES
# 2                             empty  ...                  empty    YES
# 3                             empty  ...           Harikrishnan    YES
# 4                             empty  ...                  empty    YES
# ..                              ...  ...                    ...    ...
# 419  Devele Road Juhu Mumbai 400049  ...                  empty    YES
# 420                  St Thomas town  ...                  empty    YES
# 421                               -  ...                  empty    YES
# 422      CHEMBUR EAST MUMBAI 400071  ...                  AKEEL    YES
# 423         ANAND NAGAR PUNE 411051  ...               abhishek    YES
#
#         Contact Type Odyssey Members     Lead Brand Lead Sub-Brand  \
# 0    Email and Phone              NO  Karma Resorts          Other
# 1    Email and Phone              NO  Karma Resorts          Other
# 2    Email and Phone              NO  Karma Resorts          Other
# 3    Email and Phone              NO  Karma Resorts          Other
# 4    Email and Phone              NO  Karma Resorts          Other
# ..               ...             ...            ...            ...
# 419       Phone Only              NO  Karma Resorts          Other
# 420  Email and Phone              NO  Karma Resorts          Other
# 421  Email and Phone              NO  Karma Resorts          Other
# 422  Email and Phone              NO  Karma Resorts          Other
# 423  Email and Phone              NO  Karma Resorts          Other
#
#      Lead Source                Lead Locations Lead Source Description  \
# 0    Past Guests             Karma Royal Palms               Viewpoint
# 1    Past Guests          Karma Royal Jimbaran               Viewpoint
# 2    Past Guests  KRR @ Karma Kandara, Phase V               Viewpoint
# 3    Past Guests          Karma Munnar, Kerala               Viewpoint
# 4    Past Guests                   Amina hotel               Viewpoint
# ..           ...                           ...                     ...
# 419  Past Guests             Karma Royal Palms               Viewpoint
# 420  Past Guests             Karma Royal Palms               Viewpoint
# 421  Past Guests      Karma Royal Haathi Mahal               Viewpoint
# 422  Past Guests             Karma Royal Palms               Viewpoint
# 423  Past Guests             Karma Royal Palms               Viewpoint
#
#     Exclude From Mailing
# 0                     NO
# 1                     NO
# 2                     NO
# 3                     NO
# 4                     NO
# ..                   ...
# 419                   NO
# 420                   NO
# 421                   NO
# 422                   NO
# 423                   NO
#
# [424 rows x 37 columns]

# %%
# find_member_booking[['Email','Same Value Find']].loc[find_member_booking['BookingNo'] == '2074237']
# df_viewpoint.loc[df_viewpoint['BookingNo'] == '2097221']
# df_viewpoint.loc[df_viewpoint['Email'].str.contains('prajuizn@gmail.com')]

# %%
df_viewpoint['DOB'].replace('empty', '', inplace=True)
dob_con_date = pd.to_datetime(df_viewpoint['DOB'])
dob_date = dob_con_date.dt.strftime('%Y-%m-%d')

arr_con_date = pd.to_datetime(df_viewpoint['Arrival'])
arr_date = arr_con_date.dt.strftime('%Y-%m-%d')

dep_con_date = pd.to_datetime(df_viewpoint['Departure'])
dep_date = dep_con_date.dt.strftime('%Y-%m-%d')

ci_con_date = pd.to_datetime(df_viewpoint['CheckInDate'])
ci_date = ci_con_date.dt.strftime('%Y-%m-%d')

co_con_date = pd.to_datetime(df_viewpoint['CheckOutDate'])
co_date = co_con_date.dt.strftime('%Y-%m-%d')

df_viewpoint['DOB'] = dob_date
df_viewpoint['Arrival'] = arr_date
df_viewpoint['Departure'] = dep_date
df_viewpoint['CheckInDate'] = ci_date
df_viewpoint['CheckOutDate'] = co_date

# %%
df_viewpoint.columns
# Out:
# Index(['Title', 'Firstname', 'lastname', 'DOB', 'PAN CARD', 'Email', 'Phone',
#        'Mobile', 'AddressLine1', 'AddressLine2', 'Town', 'State', 'Country',
#        'PostCode', 'Nationality', 'MaritalStatus', 'resortname', 'Arrival',
#        'Departure', 'CheckInDate', 'CheckOutDate', 'room', 'UnitCategory',
#        'BookingNo', 'BookingSourceDesc', 'BookingTypeDesc', 'Date of Tour',
#        'Sales Rep and Comments', 'Opt In', 'Contact Type', 'Odyssey Members',
#        'Lead Brand', 'Lead Sub-Brand', 'Lead Source', 'Lead Locations',
#        'Lead Source Description', 'Exclude From Mailing'],
#       dtype='object')

# %%
new_cols = ['Lead Brand','Lead Sub-Brand','Lead Source','Lead Locations','Lead Source Description','Title','Firstname','lastname','DOB','Email','Phone','Mobile','AddressLine1','AddressLine2','Town','State',
'Country','PostCode','Nationality','MaritalStatus',	'resortname', 'Arrival', 'Departure', 'CheckInDate', 'CheckOutDate', 'room', 'UnitCategory', 'BookingNo', 'BookingSourceDesc', 'BookingTypeDesc', 'Date of Tour', 'Sales Rep and Comments',	'Opt In', 'Exclude From Mailing', 'Odyssey Members', 'Contact Type']																																																																																																																																						

df_viewpoint = df_viewpoint.reindex(columns=new_cols)

# %%
df_viewpoint.replace('empty', '', inplace=True)

df_viewpoint.sort_values('Departure', ascending=True, inplace=True)
df_viewpoint.reset_index(drop=True, inplace=True)
df_viewpoint
# Out:
#         Lead Brand Lead Sub-Brand  Lead Source            Lead Locations  \
# 0    Karma Resorts          Other  Past Guests         Karma Royal Palms
# 1    Karma Resorts          Other  Past Guests  Karma Royal Haathi Mahal
# 2    Karma Resorts          Other  Past Guests  Karma Royal Haathi Mahal
# 3    Karma Resorts          Other  Past Guests            Karma Jimbaran
# 4    Karma Resorts          Other  Past Guests         Karma Royal Palms
# ..             ...            ...          ...                       ...
# 419  Karma Resorts          Other  Past Guests         Karma Royal Palms
# 420  Karma Resorts          Other  Past Guests         Karma Royal Palms
# 421  Karma Resorts          Other  Past Guests         Karma Royal Palms
# 422  Karma Resorts          Other  Past Guests   Karma Sitabani, Corbett
# 423  Karma Resorts          Other  Past Guests         Karma Royal Palms
#
#     Lead Source Description Title      Firstname  lastname         DOB  \
# 0                 Viewpoint    Mr         Harish         R         NaN
# 1                 Viewpoint   Mrs          Tanya     Varma         NaN
# 2                 Viewpoint   Mrs         Seetha    Dhruva         NaN
# 3                 Viewpoint   Mrs        Beatriz     Miras  1980-03-17
# 4                 Viewpoint    Mr       Narendra         R         NaN
# ..                      ...   ...            ...       ...         ...
# 419               Viewpoint    Ms  Kiran Sitaram    Shinde         NaN
# 420               Viewpoint   Mrs          Palak  Sachdeva         NaN
# 421               Viewpoint    Mr         Arvind     Dubey         NaN
# 422               Viewpoint    Mr           Ajay     Kumar  1978-12-13
# 423               Viewpoint    Mr         Tushar    Pahade         NaN
#
#                            Email  ...           UnitCategory BookingNo  \
# 0          harishram68@yahoo.com  ...   Non Member 1 Bedroom   2581496
# 1       tanyavarma1993@gmail.com  ...      Hotel Unit Deluxe   2562111
# 2         seethadhruva@gmail.com  ...   2 Bedroom Fractional   2545177
# 3           bea.minas@lokmail.ti  ...  4 Bedroom Valley View   2369747
# 4         narendra.zam@gmail.com  ...   Non Member 1 Bedroom   2559763
# ..                           ...  ...                    ...       ...
# 419         shindek964@gmail.com  ...   Non Member 1 Bedroom   2593101
# 420        sachdeva900@gmail.com  ...    1 Bedroom Apartment   2570130
# 421  arvinddubey294834@gmail.com  ...   Non Member 1 Bedroom   2593019
# 422     agarwalgeeta53@gmail.com  ...  Non Member Hotel Unit   2551980
# 423       tusharpahade@gmail.com  ...   Non Member 1 Bedroom   2565960
#
#         BookingSourceDesc                      BookingTypeDesc  \
# 0          Fly Buy Indian               Karma Experience India
# 1          Fly Buy Indian               Karma Experience India
# 2               KC Member                    Entitlement Guest
# 3          Hotel Bookings                      Nakula - Rental
# 4          Fly Buy Indian               Karma Experience India
# ..                    ...                                  ...
# 419        Fly Buy Indian               Karma Experience India
# 420  Karma Club Discovery  Karma Club Discovery Sales Gift(NM)
# 421        Fly Buy Indian               Karma Experience India
# 422           KCE2 Indian               Karma Experience India
# 423        Fly Buy Indian               Karma Experience India
#
#             Date of Tour Sales Rep and Comments Opt In Exclude From Mailing  \
# 0    2024-08-12 16:14:00                 NARESH    YES                   NO
# 1    2024-08-12 16:14:00                  SWETA    YES                   NO
# 2                                                  YES                   NO
# 3                                                  YES                   NO
# 4    2024-08-09 16:25:00              vaishnavi    YES                   NO
# ..                   ...                    ...    ...                  ...
# 419  2024-08-17 18:02:00                   ufra    YES                   NO
# 420                                                YES                   NO
# 421                                                YES                   NO
# 422  2024-08-18 10:30:00                  ANAND    YES                   NO
# 423  2024-08-17 13:37:00               abhishek    YES                   NO
#
#     Odyssey Members     Contact Type
# 0                NO  Email and Phone
# 1                NO  Email and Phone
# 2                NO  Email and Phone
# 3                NO  Email and Phone
# 4                NO  Email and Phone
# ..              ...              ...
# 419              NO  Email and Phone
# 420              NO  Email and Phone
# 421              NO  Email and Phone
# 422              NO  Email and Phone
# 423              NO  Email and Phone
#
# [424 rows x 36 columns]

# %%
print("==========================================================")
print("Summary")
print("==========================================================")
print("Jumlah Data Setelah Script Past Guest Sebelumnya : "+str(count_data_awal))
print("Jumlah Data Yang Duplicate : "+str(count_duplicate_general))
print("Jumlah Data Setelah Hapus Duplicate : "+str(count_after_dedup_duplicate))
print("Jumlah Data Yang Termasuk Member: "+str(count_dedup_member))
print("Jumlah Data Setelah Hapus Member : "+str(count_after_dedup_member))
print("Jumlah Data Akhir : "+str(count_data_akhir))
# Out:
# ==========================================================
# Summary
# ==========================================================
# Jumlah Data Setelah Script Past Guest Sebelumnya : 1728
# Jumlah Data Yang Duplicate : 419
# Jumlah Data Setelah Hapus Duplicate : 1309
# Jumlah Data Yang Termasuk Member: 885
# Jumlah Data Setelah Hapus Member : 424
# Jumlah Data Akhir : 424

# %%
df_viewpoint.to_excel(r'C:\Users\fajar\Documents\Python\Data\final_viewpoint.xlsx', index=False)
