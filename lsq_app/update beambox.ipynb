# %%
import sys
sys.path.append('../zoho_data_app')

import main_module as m
import pandas as pd
import re

import gspread

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
gc = gspread.oauth(
    credentials_filename= r'C:\Users\fajar\Documents\Python\Data\test.json'
)

SHEET_ID = '1FZ4bgWOEiVsbICA0WcG7DmBmjqA58v7ZdpiRZrARCqY'
SHEET_NAME_KLOM = 'KLOM'
SHEET_NAME_KSH = 'KSH'
SHEET_NAME_KB = 'KB'
SHEET_NAME_LSQ = 'Done in LSQ'
SHEET_NAME_API = 'API'

# get data gsheet

spreadsheet = gc.open_by_key(SHEET_ID)

worksheet_klom= spreadsheet.worksheet(SHEET_NAME_KLOM)
rows_klom = worksheet_klom.get_all_records()
df_klom = pd.DataFrame(rows_klom)
df_klom['Lead Location'] = 'Karma Lake Of Menteith'

worksheet_ksh= spreadsheet.worksheet(SHEET_NAME_KSH)
rows_ksh = worksheet_ksh.get_all_records()
df_ksh = pd.DataFrame(rows_ksh)
df_ksh['Lead Location'] = 'Karma Salford Hall'

worksheet_kb= spreadsheet.worksheet(SHEET_NAME_KB)
rows_kb = worksheet_kb.get_all_records()
df_kb = pd.DataFrame(rows_kb)
df_kb['Lead Location'] = 'Karma Bavaria'

worksheet_lsq= spreadsheet.worksheet(SHEET_NAME_LSQ)
rows_lsq = worksheet_lsq.get_all_records()
df_lsq = pd.DataFrame(rows_lsq)

worksheet_api= spreadsheet.worksheet(SHEET_NAME_API)
rows_api = worksheet_api.get_all_records()
df_api = pd.DataFrame(rows_api)

df_klom
# Out:
#                Full Name  First Name  Last Name                         Email  \
# 0        Perri Hopkinson       Perri  Hopkinson      hopkinsonperri@gmail.com
# 1          Gavin Barrack       Gavin    Barrack  gavin.barrack@btinternet.com
# 2        Frankie Clifton     Frankie    Clifton   frankie.clifton95@gmail.com
# 3            Joanne Hill      Joanne       Hill      joannehill2018@gmail.com
# 4            Murray Hill      Murray       Hill       murraymhill@hotmail.com
# ...                  ...         ...        ...                           ...
# 6724        Nikhil Selot                                   nselot@hotmail.com
# 6725      Gabriella Snow   Gabriella       Snow    gabriellasnow.gs@gmail.com
# 6726  Jacqueline Gommans  Jacqueline    Gommans          jfjgommans@gmail.com
# 6727   Françoise Frescal   Françoise    Frescal  françoise.frescal@fr.ibm.com
# 6728   Frescal Jean Marc     Frescal       Marc       jeanmarc.frescal@axa.fr
#
#               Phone Gender Date of Birth Nationality Source  Visits  ...  \
# 0      447943613334                                   Email       1  ...
# 1      447533897029                                   Email       1  ...
# 2     4407501677462                                   Email       1  ...
# 3     4412345678910                                   Email       1  ...
# 4      447925997047                                   Email       2  ...
# ...             ...    ...           ...         ...    ...     ...  ...
# 6724                          1975-07-05              Email       5  ...
# 6725                          1993-04-27              Email       1  ...
# 6726                          1964-12-03              Email       1  ...
# 6727                          2000-08-10              Email       1  ...
# 6728                          1959-07-04              Email       1  ...
#
#               First Login           Last Login                Location  \
# 0      02-05-2022 8:15:06   02-05-2022 8:15:06  Karma Lake of Menteith
# 1     19-01-2024 14:53:34  19-01-2024 14:53:34  Karma Lake of Menteith
# 2     02-07-2022 18:40:01  02-07-2022 18:40:01  Karma Lake of Menteith
# 3      02-05-2022 8:36:44   02-05-2022 8:36:44  Karma Lake of Menteith
# 4     13-05-2022 21:08:58   14-05-2022 7:50:02  Karma Lake of Menteith
# ...                   ...                  ...                     ...
# 6724  19-06-2024 15:44:57  22-06-2024 19:24:20  Karma Lake of Menteith
# 6725  19-06-2024 18:44:56  19-06-2024 18:44:56  Karma Lake of Menteith
# 6726  20-06-2024 11:29:09  20-06-2024 11:29:09  Karma Lake of Menteith
# 6727  20-06-2024 18:41:58  20-06-2024 18:41:58  Karma Lake of Menteith
# 6728  20-06-2024 18:28:57  20-06-2024 18:28:57  Karma Lake of Menteith
#
#      Marketing Opt-in        MAC Address  \
# 0               FALSE  b6:3f:7f:ff:a2:fc
# 1                TRUE  24:18:1d:98:62:e4
# 2               FALSE  88:40:3b:e8:ee:ac
# 3                TRUE  6e:f7:5a:32:55:68
# 4               FALSE  ae:e9:2e:b4:d6:a5
# ...               ...                ...
# 6724             TRUE  7e:59:82:4a:89:c4
# 6725             TRUE  e6:26:d8:dc:af:93
# 6726            FALSE  a6:d5:5b:47:6a:dc
# 6727             TRUE  0a:7e:dd:11:f8:cb
# 6728             TRUE  9e:e5:97:03:13:15
#
#      I Agree To Being Contacted By Karma Group. You Can Unsubscribe At Any Time, Please See Karma Group’s Privacy Policy For More Information.  \
# 0
# 1
# 2
# 3
# 4
# ...                                                 ...
# 6724
# 6725
# 6726
# 6727
# 6728
#
#      I Agree To Being Contacted By Karma Group  \
# 0
# 1                                          Yes
# 2
# 3
# 4
# ...                                        ...
# 6724
# 6725
# 6726
# 6727
# 6728
#
#      Https://Karmagroup.Com/Privacy Policy/  \
# 0
# 1
# 2
# 3
# 4
# ...                                     ...
# 6724
# 6725
# 6726
# 6727
# 6728
#
#      I Agree  To Being Contacted By Karma Group           Lead Location
# 0                                                Karma Lake Of Menteith
# 1                                                Karma Lake Of Menteith
# 2                                                Karma Lake Of Menteith
# 3                                                Karma Lake Of Menteith
# 4                                                Karma Lake Of Menteith
# ...                                         ...                     ...
# 6724                                             Karma Lake Of Menteith
# 6725                                             Karma Lake Of Menteith
# 6726                                             Karma Lake Of Menteith
# 6727                                             Karma Lake Of Menteith
# 6728                                             Karma Lake Of Menteith
#
# [6729 rows x 23 columns]

# %%
df_offline_join = pd.concat([df_klom,df_ksh,df_kb])
df_offline_join.loc[df_offline_join['Email'] == '','Email'] = 'empty'
df_offline_join.loc[df_offline_join['Phone'] == '','Email'] = 'empty'

# %% [markdown]
# # ====================== Awal Filter Umum ======================

# %%
# data phone, mobile dam email member yang ada di master data (wash member)

m.clean_number(df_offline_join, 'Phone')
m.replace_not_valid_to_empty(df_offline_join, 'Phone')
df_offline_join['Email'] = m.lowercase(df_offline_join, 'Email')
m.clean_space(df_offline_join, 'Email')

m.clean_number(df_lsq, 'Phone')
df_lsq['Email'] = m.lowercase(df_lsq, 'Email')
m.clean_space(df_lsq, 'Email')

m.clean_number(df_api, 'Phone')
df_lsq['Email'] = m.lowercase(df_api, 'Email')
m.clean_space(df_api, 'Email')
# Out:
# 0            descaldicott@hotmail.com
# 1               jimmeebee@hotmail.com
# 2                chrisband7@gmail.com
# 3             trowe640@btinternet.com
# 4              christina@di-nolfo.com
#                     ...
# 2910    buldanasurgical2918@gmail.com
# 2911          debbiepf@bigpond.net.au
# 2912          markcogs@bigpond.net.au
# 2913      kay.chandler@btinternet.com
# 2914        rahulg.garg1708@gmail.com
# Name: Email, Length: 2915, dtype: object

# %% [markdown]
# # ====================== Akhir Filter Umum ======================

# %%
# hitung jumlah duplicate
count_duplicate_general = df_offline_join.loc[df_offline_join.duplicated(subset=['Email'])].shape[0]

df_offline_join.loc[df_offline_join.duplicated(subset=['Email'])]
# Out:
#             Full Name First Name  Last Name                  Email  \
# 7      Gary Hutchison       Gary  Hutchison                  empty
# 9      Joke Van Daele                                        empty
# 34   Audrey Doeckerty     Audrey  Doeckerty                  empty
# 67     Claudia Laffay    Claudia     Laffay                  empty
# 120      Sarah Carter      Sarah     Carter                  empty
# ..                ...        ...        ...                    ...
# 716      Abhijit Basu                         abhibasu@hotmail.com
# 717    Jayendra Singh   Jayendra      Singh   jayendra73@gmail.com
# 739    Anjuna Agrawal     Anjuna    Agrawal    anjuna.ag@gmail.com
# 740     Anuradha Basu   Anuradha       Basu  meetabasu@hotmail.com
# 743   Amarjit Matharu                        matharu27@yahoo.co.uk
#
#             Phone Gender Date of Birth Nationality    Source  Visits  ...  \
# 7           empty                                   Facebook       1  ...
# 9           empty           1963-09-09                 Email       1  ...
# 34          empty                                   Facebook       0  ...
# 67          empty                                   Facebook       1  ...
# 120         empty           1964-12-08                 Email       1  ...
# ..            ...    ...           ...         ...       ...     ...  ...
# 716  919836304493           1953-11-23                 Email       7  ...
# 717  919871646548           1973-05-16                 Email       7  ...
# 739  919810376849           1975-01-17                 Email       5  ...
# 740  919830112677           1960-08-12                 Email       4  ...
# 743  447907024160           1956-07-27                 Email      27  ...
#
#               Last Login                Location Marketing Opt-in  \
# 7     12-03-2022 9:56:49  Karma Lake of Menteith             TRUE
# 9    10-07-2024 16:39:09  Karma Lake of Menteith             TRUE
# 34                                                           TRUE
# 67   12-11-2022 18:56:29  Karma Lake of Menteith             TRUE
# 120  06-06-2024 13:50:25  Karma Lake of Menteith             TRUE
# ..                   ...                     ...              ...
# 716   19-06-2024 6:16:00           Karma Bavaria             TRUE
# 717   21-06-2024 7:37:56           Karma Bavaria            FALSE
# 739  21-06-2024 15:11:41           Karma Bavaria            FALSE
# 740   19-06-2024 7:07:52           Karma Bavaria             TRUE
# 743  02-07-2024 12:21:18           Karma Bavaria             TRUE
#
#            MAC Address  \
# 7    e2:1e:4b:49:14:16
# 9    a6:a6:24:ba:5d:ec
# 34
# 67   14:77:40:a9:1e:75
# 120  8e:b7:52:1e:37:b8
# ..                 ...
# 716  52:89:8e:c2:85:2c
# 717  9a:21:e5:67:de:02
# 739  da:92:fb:dc:60:80
# 740  3e:a9:aa:ca:2e:66
# 743  de:10:cf:8d:74:c9
#
#     I Agree To Being Contacted By Karma Group. You Can Unsubscribe At Any Time, Please See Karma Group’s Privacy Policy For More Information.  \
# 7
# 9
# 34
# 67
# 120
# ..                                                 ...
# 716                                                NaN
# 717                                                NaN
# 739                                                NaN
# 740                                                NaN
# 743                                                NaN
#
#     I Agree To Being Contacted By Karma Group  \
# 7
# 9
# 34
# 67
# 120
# ..                                        ...
# 716                                       NaN
# 717                                       NaN
# 739                                       NaN
# 740                                       NaN
# 743                                       NaN
#
#     Https://Karmagroup.Com/Privacy Policy/  \
# 7
# 9
# 34
# 67
# 120
# ..                                     ...
# 716                                    NaN
# 717                                    NaN
# 739                                    NaN
# 740                                    NaN
# 743                                    NaN
#
#     I Agree  To Being Contacted By Karma Group           Lead Location  \
# 7                                               Karma Lake Of Menteith
# 9                                               Karma Lake Of Menteith
# 34                                              Karma Lake Of Menteith
# 67                                              Karma Lake Of Menteith
# 120                                             Karma Lake Of Menteith
# ..                                         ...                     ...
# 716                                        NaN           Karma Bavaria
# 717                                        NaN           Karma Bavaria
# 739                                        NaN           Karma Bavaria
# 740                                        NaN           Karma Bavaria
# 743                                        NaN           Karma Bavaria
#
#     Room Number
# 7           NaN
# 9           NaN
# 34          NaN
# 67          NaN
# 120         NaN
# ..          ...
# 716         NaN
# 717         NaN
# 739         NaN
# 740         NaN
# 743         NaN
#
# [2040 rows x 24 columns]

# %%
df_offline_join.drop_duplicates(subset=['Email'], inplace=True)
df_offline_join.reset_index(drop=True, inplace=True)

# hitung jumlah setelah value duplicate dihapus
count_after_dedup_duplicate = df_offline_join.shape[0]

count_data_gabungan = df_offline_join.shape[0]
df_offline_join
# Out:
#              Full Name First Name  Last Name                         Email  \
# 0      Perri Hopkinson      Perri  Hopkinson      hopkinsonperri@gmail.com
# 1        Gavin Barrack      Gavin    Barrack  gavin.barrack@btinternet.com
# 2      Frankie Clifton    Frankie    Clifton   frankie.clifton95@gmail.com
# 3          Joanne Hill     Joanne       Hill      joannehill2018@gmail.com
# 4          Murray Hill     Murray       Hill       murraymhill@hotmail.com
# ...                ...        ...        ...                           ...
# 15360     Linda Martin      Linda     Martin           linda.m70@gmail.com
# 15361     Kokila Bodar                          kokilabordar1963@gmail.com
# 15362       Hans Peter       Hans      Peter              camaro500@web.de
# 15363       Eva Eilers                               evi.eilers@freenet.de
# 15364      Hort Ivanov       Hort     Ivanov          hortivanov@gmail.com
#
#                Phone Gender Date of Birth Nationality Source  Visits  ...  \
# 0       447943613334                                   Email       1  ...
# 1       447533897029                                   Email       1  ...
# 2      4407501677462                                   Email       1  ...
# 3      4412345678910                                   Email       1  ...
# 4       447925997047                                   Email       2  ...
# ...              ...    ...           ...         ...    ...     ...  ...
# 15360   490872729252           1970-01-29              Email      15  ...
# 15361   918200351926           1972-08-06              Email      14  ...
# 15362  4901704775453           1985-08-07              Email       1  ...
# 15363     4976213142           1952-11-01              Email       6  ...
# 15364    35989440527           1983-06-05              Email       1  ...
#
#                 Last Login                Location Marketing Opt-in  \
# 0       02-05-2022 8:15:06  Karma Lake of Menteith            FALSE
# 1      19-01-2024 14:53:34  Karma Lake of Menteith             TRUE
# 2      02-07-2022 18:40:01  Karma Lake of Menteith            FALSE
# 3       02-05-2022 8:36:44  Karma Lake of Menteith             TRUE
# 4       14-05-2022 7:50:02  Karma Lake of Menteith            FALSE
# ...                    ...                     ...              ...
# 15360   23-06-2024 7:27:23           Karma Bavaria             TRUE
# 15361   26-06-2024 8:02:55           Karma Bavaria             TRUE
# 15362  20-06-2024 14:32:53           Karma Bavaria             TRUE
# 15363  24-06-2024 15:13:45           Karma Bavaria             TRUE
# 15364  20-06-2024 18:25:58           Karma Bavaria             TRUE
#
#              MAC Address  \
# 0      b6:3f:7f:ff:a2:fc
# 1      24:18:1d:98:62:e4
# 2      88:40:3b:e8:ee:ac
# 3      6e:f7:5a:32:55:68
# 4      ae:e9:2e:b4:d6:a5
# ...                  ...
# 15360  aa:9c:c1:9e:51:85
# 15361  5c:1c:b9:50:04:d1
# 15362  ce:23:ec:54:02:ff
# 15363  8e:96:48:cb:e1:81
# 15364  1a:2a:45:c3:c1:da
#
#       I Agree To Being Contacted By Karma Group. You Can Unsubscribe At Any Time, Please See Karma Group’s Privacy Policy For More Information.  \
# 0
# 1
# 2
# 3
# 4
# ...                                                  ...
# 15360                                                NaN
# 15361                                                NaN
# 15362                                                NaN
# 15363                                                NaN
# 15364                                                NaN
#
#       I Agree To Being Contacted By Karma Group  \
# 0
# 1                                           Yes
# 2
# 3
# 4
# ...                                         ...
# 15360                                       NaN
# 15361                                       NaN
# 15362                                       NaN
# 15363                                       NaN
# 15364                                       NaN
#
#       Https://Karmagroup.Com/Privacy Policy/  \
# 0
# 1
# 2
# 3
# 4
# ...                                      ...
# 15360                                    NaN
# 15361                                    NaN
# 15362                                    NaN
# 15363                                    NaN
# 15364                                    NaN
#
#       I Agree  To Being Contacted By Karma Group           Lead Location  \
# 0                                                 Karma Lake Of Menteith
# 1                                                 Karma Lake Of Menteith
# 2                                                 Karma Lake Of Menteith
# 3                                                 Karma Lake Of Menteith
# 4                                                 Karma Lake Of Menteith
# ...                                          ...                     ...
# 15360                                        NaN           Karma Bavaria
# 15361                                        NaN           Karma Bavaria
# 15362                                        NaN           Karma Bavaria
# 15363                                        NaN           Karma Bavaria
# 15364                                        NaN           Karma Bavaria
#
#       Room Number
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
# ...           ...
# 15360         NaN
# 15361         NaN
# 15362         NaN
# 15363         NaN
# 15364         NaN
#
# [15365 rows x 24 columns]

# %%
# data phone, mobile dam email member yang ada di master data 
count_wash_before = df_offline_join.loc[
    df_offline_join['Phone'].isin(df_lsq['Phone']) | 
    df_offline_join['Email'].isin(df_lsq['Email'])| 

    df_offline_join['Phone'].isin(df_api['Phone']) | 

    df_offline_join['Email'].isin(df_api['Email'])

].shape[0]

df_offline_join.drop(df_offline_join.loc[
    df_offline_join['Phone'].isin(df_lsq['Phone']) | 
    df_offline_join['Email'].isin(df_lsq['Email'])| 

    df_offline_join['Phone'].isin(df_api['Phone']) | 

    df_offline_join['Email'].isin(df_api['Email'])

    ].index, inplace=True)
    
df_offline_join.reset_index(drop=True, inplace=True)

count_after_wash_before = df_offline_join.shape[0]

# %%
# data phone, mobile dam email member yang ada di master data 
count_wash_contact_empty = df_offline_join.loc[
    (df_offline_join['Email'] == 'empty') & 
    (df_offline_join['Phone'] == 'empty')
    
].shape[0]

df_offline_join.drop(df_offline_join.loc[
    (df_offline_join['Email'] == 'empty') & 
    (df_offline_join['Phone'] == 'empty')
    ].index, inplace=True)
    
df_offline_join.reset_index(drop=True, inplace=True)

count_after_wash_contact_empty = df_offline_join.shape[0]

# %%
print("==========================================================")
print("Summary")
print("==========================================================")
print("Jumlah Filter Leads Awal : "+str(count_data_gabungan))
print("Jumlah Duplicate (Phone, Mobile dan Email) : "+str(count_duplicate_general))
print("Jumlah Setelah Clean Duplicate : "+str(count_after_dedup_duplicate))
print("Jumlah Wash Before : "+str(count_wash_before))
print("Jumlah Setelah Wash Member : "+str(count_after_wash_before))
print("Jumlah Wash Empty Contact : "+str(count_wash_contact_empty))
print("Jumlah Setelah Wash Empty Contact : "+str(count_after_wash_contact_empty))
# Out:
# ==========================================================
# Summary
# ==========================================================
# Jumlah Filter Leads Awal : 15365
# Jumlah Duplicate (Phone, Mobile dan Email) : 2040
# Jumlah Setelah Clean Duplicate : 15365
# Jumlah Wash Before : 10622
# Jumlah Setelah Wash Member : 4743
# Jumlah Wash Empty Contact : 1
# Jumlah Setelah Wash Empty Contact : 4742

# %%
df_final = pd.DataFrame()
df_final['Created Time'] = df_offline_join['First Visit'].copy()
df_final['Lead Location'] = df_offline_join['Lead Location'].copy()
df_final['First Name'] = df_offline_join['First Name'].copy()
df_final['Last Name'] = df_offline_join['Last Name'].copy()
df_final['Email'] = df_offline_join['Email'].copy()
df_final['Phone'] = df_offline_join['Phone'].copy()
df_final['Lead Brand'] = 'Timeshare Marketing'
df_final['Lead Sub-Brand'] = 'Other'
df_final['Lead Source'] = 'Wifi'
df_final['Lead Source Description'] = 'Beambox'
df_final['Email Opt Out'] = False
df_final['Opt In'] = True
df_final['Do Not Contact'] = False
df_final['Do Not Mail'] = False

df_final['Phone'] = df_final['Phone'].astype("string")

df_final['Phone'].replace('^440','44', regex=True, inplace=True)
df_final
# Out:
#              Created Time           Lead Location First Name Last Name  \
# 0     01-05-2022 14:10:18  Karma Lake Of Menteith
# 1     10-04-2022 20:51:21  Karma Lake Of Menteith      Vijay       Raj
# 2     28-07-2022 17:35:59  Karma Lake Of Menteith
# 3     29-05-2022 17:11:18  Karma Lake Of Menteith
# 4     24-06-2022 15:10:51  Karma Lake Of Menteith
# ...                   ...                     ...        ...       ...
# 4737  16-06-2024 20:14:21           Karma Bavaria      Linda    Martin
# 4738  20-06-2024 13:00:36           Karma Bavaria
# 4739  20-06-2024 14:32:53           Karma Bavaria       Hans     Peter
# 4740  20-06-2024 14:35:48           Karma Bavaria
# 4741  20-06-2024 18:25:58           Karma Bavaria       Hort    Ivanov
#
#                            Email          Phone           Lead Brand  \
# 0      submarines999@hotmail.com             44  Timeshare Marketing
# 1      vijayantonyraj2@gmail.com             44  Timeshare Marketing
# 2      ray-rayshaw@hotmail.co.uk             44  Timeshare Marketing
# 3         bprevatt@hotmail.co.uk             44  Timeshare Marketing
# 4       simon.day@ctct-ltd.co.uk             44  Timeshare Marketing
# ...                          ...            ...                  ...
# 4737         linda.m70@gmail.com   490872729252  Timeshare Marketing
# 4738  kokilabordar1963@gmail.com   918200351926  Timeshare Marketing
# 4739            camaro500@web.de  4901704775453  Timeshare Marketing
# 4740       evi.eilers@freenet.de     4976213142  Timeshare Marketing
# 4741        hortivanov@gmail.com    35989440527  Timeshare Marketing
#
#      Lead Sub-Brand Lead Source Lead Source Description  Email Opt Out  \
# 0             Other        Wifi                 Beambox          False
# 1             Other        Wifi                 Beambox          False
# 2             Other        Wifi                 Beambox          False
# 3             Other        Wifi                 Beambox          False
# 4             Other        Wifi                 Beambox          False
# ...             ...         ...                     ...            ...
# 4737          Other        Wifi                 Beambox          False
# 4738          Other        Wifi                 Beambox          False
# 4739          Other        Wifi                 Beambox          False
# 4740          Other        Wifi                 Beambox          False
# 4741          Other        Wifi                 Beambox          False
#
#       Opt In  Do Not Contact  Do Not Mail
# 0       True           False        False
# 1       True           False        False
# 2       True           False        False
# 3       True           False        False
# 4       True           False        False
# ...      ...             ...          ...
# 4737    True           False        False
# 4738    True           False        False
# 4739    True           False        False
# 4740    True           False        False
# 4741    True           False        False
#
# [4742 rows x 14 columns]

# %%
df_final.replace('empty', '', inplace=True, regex=True)
df_final.loc[df_final['Phone'].str.len() < 3, 'Phone'] = ''

# %%
# df_final.to_excel(r'C:\Users\fajar\Documents\Python\Data\update_beambox.xlsx', index=False)

# %%
SHEET_NAME_UPDATE = 'Update Beambox'
# SHEET_NAME_UPDATE = 'Test'
worksheet_update= spreadsheet.worksheet(SHEET_NAME_UPDATE)
worksheet_update.clear()

worksheet_update.update([df_final.columns.values.tolist()] + df_final.values.tolist())
# Out:
# {'spreadsheetId': '1FZ4bgWOEiVsbICA0WcG7DmBmjqA58v7ZdpiRZrARCqY',
#  'updatedRange': "'Update Beambox'!A1:N4743",
#  'updatedRows': 4743,
#  'updatedColumns': 14,
#  'updatedCells': 66402}
