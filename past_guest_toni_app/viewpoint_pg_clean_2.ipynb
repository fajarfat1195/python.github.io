# %%
import pandas as pd
import re

import past_guest_module as pm

import sys
sys.path.append('../zoho_data_app/')

import main_module as m

# %load_ext autoreload
# %autoreload 2

# %%
path = r'C:\Users\fajar\Documents\Python\Data\check_country_code_viewpoint.xlsx'
df_viewpoint = pd.read_excel(path, dtype='string', sheet_name='Sheet1')
count_data_awal = df_viewpoint.shape[0]

# %%
df_viewpoint.fillna('empty', inplace=True)

# %%
path = r'G:\.shortcut-targets-by-id\0B_d3smBjzo04UUNBME5GOVhoMjA\_ODYSSEY\Phone Members.xlsx'
df_phone = pd.read_excel(path, dtype='string', sheet_name='Sheet1')

path = r'G:\.shortcut-targets-by-id\0B_d3smBjzo04UUNBME5GOVhoMjA\_ODYSSEY\Email Members.xlsx'
df_email = pd.read_excel(path, dtype='string', sheet_name='Sheet1')

# %%
m.clean_space(df_email, 'Email')
df_email['Email'] = m.lowercase(df_email, 'Email')
# Out:
# c:\Users\fajar\Documents\Python\Task Offline\past_guest_toni_app\../zoho_data_app\main_module.py:90: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[df_columns].replace(' ','', regex=True, inplace=True)

# %%
# hitung jumlah duplicate
count_duplicate_general = df_viewpoint.loc[df_viewpoint.duplicated(subset=['Phone','Mobile','Email'])].shape[0]

df_viewpoint.loc[df_viewpoint.duplicated(subset=['Phone','Mobile','Email'])]
# Out:
#       Title              Firstname     lastname                  DOB PAN CARD  \
# 7        Mr                 Andrew     Portelli  1963-12-27 00:00:00    empty
# 17       Mr            Karthikeyan   Ramanathan  1974-07-08 00:00:00    empty
# 22      Mrs           Sathya Priya  Karthikeyan  1900-01-01 00:00:00    empty
# 26       Mr                   Paul       Brooks                empty    empty
# 30       Mr                  Peter        Tooke  1952-09-29 00:00:00    empty
# ...     ...                    ...          ...                  ...      ...
# 2008  empty          Candy Jimenez            -                empty    empty
# 2009  empty        Galopin, Jerome            -                empty    empty
# 2010  empty        Salesne, Pierre            -                empty    empty
# 2011  empty  Unit 204, Mold Issues            -                empty    empty
# 2012    Krg          Benny Risanto           86                empty    empty
#
#                          Email        Phone Mobile  \
# 7      andport@optusnet.com.au  61406065364  empty
# 17      raman_karthi@yahoo.com  61432816624  empty
# 22         kspriya77@yahoo.com  61468833514  empty
# 26    ernaxjanhilmer@gmail.com  62818567837  empty
# 30     peter.tooke@bigpond.com  61427789111  empty
# ...                        ...          ...    ...
# 2008                     empty        empty  empty
# 2009                     empty        empty  empty
# 2010                     empty        empty  empty
# 2011                     empty        empty  empty
# 2012                     empty        empty  empty
#
#                                           AddressLine1 AddressLine2  ...  \
# 7                               UNIT1/6 MCINTYRE DRIVE        empty  ...
# 17                                     10 BEJAR STREET   SCHOFIELDS  ...
# 22                                     10 BEJAR STREET   SCHOFIELDS  ...
# 26    Danau Tamblingan Raya no 14 Taman Griya Jimbaran        empty  ...
# 30                                148 CANTERBURY ROAD,        empty  ...
# ...                                                ...          ...  ...
# 2008                                             empty        empty  ...
# 2009                                             empty        empty  ...
# 2010                                             empty        empty  ...
# 2011                                             empty        empty  ...
# 2012                                             empty        empty  ...
#
#      Sales Rep and Comments Opt In     Contact Type Odyssey Members  \
# 7                     empty     NO  Email and Phone              NO
# 17                    empty    YES  Email and Phone              NO
# 22                    empty    YES  Email and Phone              NO
# 26                    empty    YES  Email and Phone              NO
# 30                    Chris    YES  Email and Phone              NO
# ...                     ...    ...              ...             ...
# 2008                  empty    YES       Email Only              NO
# 2009                  empty    YES       Email Only              NO
# 2010                  empty    YES       Email Only              NO
# 2011                  empty    YES       Email Only              NO
# 2012                  empty  empty       Email Only              NO
#
#          Lead Brand Lead Sub-Brand  Lead Source  \
# 7     Karma Resorts          Other  Past Guests
# 17    Karma Resorts          Other  Past Guests
# 22    Karma Resorts          Other  Past Guests
# 26    Karma Resorts          Other  Past Guests
# 30    Karma Resorts          Other  Past Guests
# ...             ...            ...          ...
# 2008  Karma Resorts          Other  Past Guests
# 2009  Karma Resorts          Other  Past Guests
# 2010  Karma Resorts          Other  Past Guests
# 2011  Karma Resorts          Other  Past Guests
# 2012  Karma Resorts          Other  Past Guests
#
#                          Lead Locations Lead Source Description  \
# 7                         Karma Bavaria               Viewpoint
# 17               Karma Bayon, Siam Reap               Viewpoint
# 22               Karma Bayon, Siam Reap               Viewpoint
# 26               Karma Bayon, Siam Reap               Viewpoint
# 30               Karma Bayon, Siam Reap               Viewpoint
# ...                                 ...                     ...
# 2008  Wyndham -  Manoir des Deux Amants               Viewpoint
# 2009  Wyndham -  Manoir des Deux Amants               Viewpoint
# 2010  Wyndham -  Manoir des Deux Amants               Viewpoint
# 2011  Wyndham -  Manoir des Deux Amants               Viewpoint
# 2012                              empty               Viewpoint
#
#      Exclude From Mailing
# 7                     YES
# 17                     NO
# 22                     NO
# 26                     NO
# 30                     NO
# ...                   ...
# 2008                   NO
# 2009                   NO
# 2010                   NO
# 2011                   NO
# 2012                empty
#
# [576 rows x 37 columns]

# %%
df_viewpoint.drop_duplicates(subset=['Phone','Mobile','Email'], inplace=True)
df_viewpoint.reset_index(drop=True, inplace=True)

# hitung jumlah setelah value duplicate dihapus
count_after_dedup_duplicate = df_viewpoint.shape[0]

df_viewpoint
# Out:
#       Title               Firstname   lastname                  DOB PAN CARD  \
# 0        Mr                  Julian      Espin                empty    empty
# 1       Mrs                    Neha  Choudhary                empty    empty
# 2        Mr                    Paul      Beard                empty    empty
# 3        Mr                  Eugene      Luyke  1978-02-14 00:00:00    empty
# 4        Ms                   Stuti    Trivedi                empty    empty
# ...     ...                     ...        ...                  ...      ...
# 1432     Ms                   Debra  Alexander                empty    empty
# 1433  empty            White, Lacey          -                empty    empty
# 1434  empty       Spanneut, Clement          -                empty    empty
# 1435  empty        Ten Eyck, Amanda          -                empty    empty
# 1436  empty  Bond, Judith & Gregory          -                empty    empty
#
#                            Email        Phone       Mobile  \
# 0                          empty        empty        empty
# 1     nehachoudhary.er@gmail.com  61423509606        empty
# 2                          empty  61488223196  61409878822
# 3         eugene.luyke@gmail.com  61402160037        empty
# 4                          empty  61425277101  61425277101
# ...                          ...          ...          ...
# 1432              debact@aol.com  17573057913        empty
# 1433    laceyjfilipich@yahoo.com    894390893    410327186
# 1434                       empty        12398        empty
# 1435                       empty        11876        empty
# 1436       gregrbond@hotmail.com    418120102        empty
#
#                                            AddressLine1  \
# 0                                                     x
# 1                                                     -
# 2     22 PETIT CLOSE, DUDLEY PARK 6210 WESTERN AUSTR...
# 3                                       22 DEANS AVENUE
# 4      242 LANDSDALE ,RD, LANDSDALE ,WA 6065, AUSTRALIA
# ...                                                 ...
# 1432                             GUEST OF ROYAL HOLIDAY
# 1433                                              empty
# 1434                                              empty
# 1435                                              empty
# 1436                                              empty
#
#                                            AddressLine2  ...  \
# 0                                                 empty  ...
# 1                                                     -  ...
# 2     22 PETIT CLOSE, DUDLEY PARK 6210 WESTERN AUSTR...  ...
# 3                                                 empty  ...
# 4      242 LANDSDALE ,RD, LANDSDALE ,WA 6065, AUSTRALIA  ...
# ...                                                 ...  ...
# 1432                                              empty  ...
# 1433                                              empty  ...
# 1434                                              empty  ...
# 1435                                              empty  ...
# 1436                                              empty  ...
#
#      Sales Rep and Comments Opt In     Contact Type Odyssey Members  \
# 0                     empty    YES       Email Only              NO
# 1                     empty    YES  Email and Phone              NO
# 2                     empty    YES  Email and Phone              NO
# 3                     empty    YES  Email and Phone              NO
# 4                     empty    YES  Email and Phone              NO
# ...                     ...    ...              ...             ...
# 1432                  empty    YES  Email and Phone              NO
# 1433                  empty    YES  Email and Phone              NO
# 1434                  empty    YES  Email and Phone              NO
# 1435                  empty    YES  Email and Phone              NO
# 1436                  empty    YES  Email and Phone              NO
#
#          Lead Brand Lead Sub-Brand  Lead Source  \
# 0     Karma Resorts          Other  Past Guests
# 1     Karma Resorts          Other  Past Guests
# 2     Karma Resorts          Other  Past Guests
# 3     Karma Resorts          Other  Past Guests
# 4     Karma Resorts          Other  Past Guests
# ...             ...            ...          ...
# 1432  Karma Resorts          Other  Past Guests
# 1433  Karma Resorts          Other  Past Guests
# 1434  Karma Resorts          Other  Past Guests
# 1435  Karma Resorts          Other  Past Guests
# 1436  Karma Resorts          Other  Past Guests
#
#                          Lead Locations Lead Source Description  \
# 0                          Karma Minoan               Viewpoint
# 1                           Amina hotel               Viewpoint
# 2                           Amina hotel               Viewpoint
# 3                           Amina hotel               Viewpoint
# 4                           Amina hotel               Viewpoint
# ...                                 ...                     ...
# 1432                  Karma Royal Palms               Viewpoint
# 1433  Wyndham -  Manoir des Deux Amants               Viewpoint
# 1434  Wyndham -  Manoir des Deux Amants               Viewpoint
# 1435  Wyndham -  Manoir des Deux Amants               Viewpoint
# 1436  Wyndham -  Manoir des Deux Amants               Viewpoint
#
#      Exclude From Mailing
# 0                      NO
# 1                      NO
# 2                      NO
# 3                      NO
# 4                      NO
# ...                   ...
# 1432                   NO
# 1433                   NO
# 1434                   NO
# 1435                   NO
# 1436                   NO
#
# [1437 rows x 37 columns]

# %%
find_member_booking = df_viewpoint.copy()

find_member_booking.loc[find_member_booking['Phone'].isin(df_phone['Mobile']), 'Same Value Find'] = 'Member-Mobile' 
find_member_booking.loc[find_member_booking['Mobile'].isin(df_phone['Mobile']), 'Same Value Find'] = 'Member-Mobile'

find_member_booking.loc[find_member_booking['Email'].isin(df_email['Email']), 'Same Value Find'] = 'Member-Email'
find_member_booking.drop(find_member_booking.loc[find_member_booking['Same Value Find'].isna()].index, inplace=True)

# %%
find_member_booking
# Out:
#       Title          Firstname     lastname                  DOB PAN CARD  \
# 3        Mr             Eugene        Luyke  1978-02-14 00:00:00    empty
# 4        Ms              Stuti      Trivedi                empty    empty
# 5        Mr       Paul Anthony  Etherington                empty    empty
# 6        Mr             Andrew     Portelli  1963-12-27 00:00:00    empty
# 7        Mr              Jason        Grant  1972-04-18 00:00:00    empty
# ...     ...                ...          ...                  ...      ...
# 1415    Mrs              Fiona         Cole  1961-11-01 00:00:00    empty
# 1420     Mr              David     Lauchmen  1900-01-01 00:00:00    empty
# 1426     Mr       Donald Louis       George  1972-01-09 00:00:00    empty
# 1429     Mr              Simon         Lobo  1956-01-05 00:00:00    empty
# 1430  empty  Hiren Viswanathan  Ramu Sharma  1999-05-19 00:00:00    empty
#
#                         Email         Phone        Mobile  \
# 3      eugene.luyke@gmail.com   61402160037         empty
# 4                       empty   61425277101   61425277101
# 5           swm7566@gmail.com         empty         empty
# 6     andport@optusnet.com.au   61406065364         empty
# 7       jlgrant32@hotmail.com   61432173559   61414521072
# ...                       ...           ...           ...
# 1415      fiona@fionacole.com  447850741251         empty
# 1420      lauchmend@gmail.com   14132502105         empty
# 1426     dlgeorgejr@gmail.com   18086513161    6588092232
# 1429        lobosnl@yahoo.com   17039449440  919036445940
# 1430      hiren1999@gmail.com   16317466219         empty
#
#                                           AddressLine1  \
# 3                                      22 DEANS AVENUE
# 4     242 LANDSDALE ,RD, LANDSDALE ,WA 6065, AUSTRALIA
# 5                                                    -
# 6                               UNIT1/6 MCINTYRE DRIVE
# 7                                   18B BROOKS TERRACE
# ...                                                ...
# 1415                                 141 ASH HILL ROAD
# 1420                                1754 S. OSWEGO ST.
# 1426                                  PSC 470 BOX 3261
# 1429                10452, WHITE GRANITE COURT, OAKTON
# 1430                                4425 Dixie Hill Rd
#
#                                           AddressLine2  ... Opt In  \
# 3                                                empty  ...    YES
# 4     242 LANDSDALE ,RD, LANDSDALE ,WA 6065, AUSTRALIA  ...    YES
# 5                                                empty  ...    YES
# 6                                                empty  ...     NO
# 7                                            KANAHOOKA  ...    YES
# ...                                                ...  ...    ...
# 1415                                           ASHVALE  ...    YES
# 1420                                             empty  ...    YES
# 1426                                             empty  ...    YES
# 1429                                             empty  ...    YES
# 1430                                           Apt.208  ...    YES
#
#          Contact Type Odyssey Members     Lead Brand Lead Sub-Brand  \
# 3     Email and Phone              NO  Karma Resorts          Other
# 4     Email and Phone              NO  Karma Resorts          Other
# 5          Email Only              NO  Karma Resorts          Other
# 6     Email and Phone              NO  Karma Resorts          Other
# 7     Email and Phone              NO  Karma Resorts          Other
# ...               ...             ...            ...            ...
# 1415  Email and Phone              NO  Karma Resorts          Other
# 1420  Email and Phone              NO  Karma Resorts          Other
# 1426  Email and Phone              NO  Karma Resorts          Other
# 1429  Email and Phone              NO  Karma Resorts          Other
# 1430  Email and Phone              NO  Karma Resorts          Other
#
#       Lead Source                     Lead Locations Lead Source Description  \
# 3     Past Guests                        Amina hotel               Viewpoint
# 4     Past Guests                        Amina hotel               Viewpoint
# 5     Past Guests     Chateau de Samary, Carcassonne               Viewpoint
# 6     Past Guests                      Karma Bavaria               Viewpoint
# 7     Past Guests                      Karma Bavaria               Viewpoint
# ...           ...                                ...                     ...
# 1415  Past Guests  Sun Cruiser Karma Fushi, Maldives               Viewpoint
# 1420  Past Guests             Karma Bayon, Siam Reap               Viewpoint
# 1426  Past Guests              Karma Royal Candidasa               Viewpoint
# 1429  Past Guests               Karma Royal Monterio               Viewpoint
# 1430  Past Guests               Karma Royal Monterio               Viewpoint
#
#      Exclude From Mailing Same Value Find
# 3                      NO    Member-Email
# 4                      NO   Member-Mobile
# 5                      NO    Member-Email
# 6                     YES    Member-Email
# 7                      NO    Member-Email
# ...                   ...             ...
# 1415                   NO    Member-Email
# 1420                   NO    Member-Email
# 1426                   NO    Member-Email
# 1429                   NO    Member-Email
# 1430                   NO    Member-Email
#
# [954 rows x 38 columns]

# %%
find_member_booking.replace('empty', '', inplace=True)
find_member_booking.to_csv(r'C:\Users\fajar\Documents\Python\Data\cek_member_viewpoint.csv', index=False)

# %%
count_dedup_member = df_viewpoint.loc[
    
    df_viewpoint['Phone'].isin(df_phone['Mobile']) | 
    df_viewpoint['Mobile'].isin(df_phone['Mobile']) |

    df_viewpoint['Email'].isin(df_email['Email'])
    ].shape[0]

df_viewpoint.loc[
    
    df_viewpoint['Phone'].isin(df_phone['Mobile']) | 
    df_viewpoint['Mobile'].isin(df_phone['Mobile']) |

    df_viewpoint['Email'].isin(df_email['Email'])
    ]
# Out:
#       Title          Firstname     lastname                  DOB PAN CARD  \
# 3        Mr             Eugene        Luyke  1978-02-14 00:00:00    empty
# 4        Ms              Stuti      Trivedi                empty    empty
# 5        Mr       Paul Anthony  Etherington                empty    empty
# 6        Mr             Andrew     Portelli  1963-12-27 00:00:00    empty
# 7        Mr              Jason        Grant  1972-04-18 00:00:00    empty
# ...     ...                ...          ...                  ...      ...
# 1415    Mrs              Fiona         Cole  1961-11-01 00:00:00    empty
# 1420     Mr              David     Lauchmen  1900-01-01 00:00:00    empty
# 1426     Mr       Donald Louis       George  1972-01-09 00:00:00    empty
# 1429     Mr              Simon         Lobo  1956-01-05 00:00:00    empty
# 1430  empty  Hiren Viswanathan  Ramu Sharma  1999-05-19 00:00:00    empty
#
#                         Email         Phone        Mobile  \
# 3      eugene.luyke@gmail.com   61402160037         empty
# 4                       empty   61425277101   61425277101
# 5           swm7566@gmail.com         empty         empty
# 6     andport@optusnet.com.au   61406065364         empty
# 7       jlgrant32@hotmail.com   61432173559   61414521072
# ...                       ...           ...           ...
# 1415      fiona@fionacole.com  447850741251         empty
# 1420      lauchmend@gmail.com   14132502105         empty
# 1426     dlgeorgejr@gmail.com   18086513161    6588092232
# 1429        lobosnl@yahoo.com   17039449440  919036445940
# 1430      hiren1999@gmail.com   16317466219         empty
#
#                                           AddressLine1  \
# 3                                      22 DEANS AVENUE
# 4     242 LANDSDALE ,RD, LANDSDALE ,WA 6065, AUSTRALIA
# 5                                                    -
# 6                               UNIT1/6 MCINTYRE DRIVE
# 7                                   18B BROOKS TERRACE
# ...                                                ...
# 1415                                 141 ASH HILL ROAD
# 1420                                1754 S. OSWEGO ST.
# 1426                                  PSC 470 BOX 3261
# 1429                10452, WHITE GRANITE COURT, OAKTON
# 1430                                4425 Dixie Hill Rd
#
#                                           AddressLine2  ...  \
# 3                                                empty  ...
# 4     242 LANDSDALE ,RD, LANDSDALE ,WA 6065, AUSTRALIA  ...
# 5                                                empty  ...
# 6                                                empty  ...
# 7                                            KANAHOOKA  ...
# ...                                                ...  ...
# 1415                                           ASHVALE  ...
# 1420                                             empty  ...
# 1426                                             empty  ...
# 1429                                             empty  ...
# 1430                                           Apt.208  ...
#
#      Sales Rep and Comments Opt In     Contact Type Odyssey Members  \
# 3                     empty    YES  Email and Phone              NO
# 4                     empty    YES  Email and Phone              NO
# 5                     empty    YES       Email Only              NO
# 6                     empty     NO  Email and Phone              NO
# 7                     empty    YES  Email and Phone              NO
# ...                     ...    ...              ...             ...
# 1415                  empty    YES  Email and Phone              NO
# 1420                  empty    YES  Email and Phone              NO
# 1426                   Suzy    YES  Email and Phone              NO
# 1429                  vijay    YES  Email and Phone              NO
# 1430                  empty    YES  Email and Phone              NO
#
#          Lead Brand Lead Sub-Brand  Lead Source  \
# 3     Karma Resorts          Other  Past Guests
# 4     Karma Resorts          Other  Past Guests
# 5     Karma Resorts          Other  Past Guests
# 6     Karma Resorts          Other  Past Guests
# 7     Karma Resorts          Other  Past Guests
# ...             ...            ...          ...
# 1415  Karma Resorts          Other  Past Guests
# 1420  Karma Resorts          Other  Past Guests
# 1426  Karma Resorts          Other  Past Guests
# 1429  Karma Resorts          Other  Past Guests
# 1430  Karma Resorts          Other  Past Guests
#
#                          Lead Locations Lead Source Description  \
# 3                           Amina hotel               Viewpoint
# 4                           Amina hotel               Viewpoint
# 5        Chateau de Samary, Carcassonne               Viewpoint
# 6                         Karma Bavaria               Viewpoint
# 7                         Karma Bavaria               Viewpoint
# ...                                 ...                     ...
# 1415  Sun Cruiser Karma Fushi, Maldives               Viewpoint
# 1420             Karma Bayon, Siam Reap               Viewpoint
# 1426              Karma Royal Candidasa               Viewpoint
# 1429               Karma Royal Monterio               Viewpoint
# 1430               Karma Royal Monterio               Viewpoint
#
#      Exclude From Mailing
# 3                      NO
# 4                      NO
# 5                      NO
# 6                     YES
# 7                      NO
# ...                   ...
# 1415                   NO
# 1420                   NO
# 1426                   NO
# 1429                   NO
# 1430                   NO
#
# [954 rows x 37 columns]

# %%
df_viewpoint.drop(df_viewpoint.loc[
    
    df_viewpoint['Phone'].isin(df_phone['Mobile']) | 
    df_viewpoint['Mobile'].isin(df_phone['Mobile']) |

    df_viewpoint['Email'].isin(df_email['Email'])
].index, inplace=True)

df_viewpoint.reset_index(drop=True, inplace=True)

count_after_dedup_member = df_viewpoint.shape[0]

# %%
count_data_akhir = df_viewpoint.shape[0]

# %%
df_viewpoint.sort_values('CheckOutDate', ascending=True, inplace=True)
df_viewpoint.reset_index(drop=True, inplace=True)
df_viewpoint
# Out:
#     Title                  Firstname         lastname                  DOB  \
# 0      Mr                      Anway          Mohamed  1995-06-11 00:00:00
# 1      Mr                    Shafath             Khan                empty
# 2      Mr         Vanapalli Nagendra            Kumar  1983-07-01 00:00:00
# 3      Mr                    Santosh  Jagannath Poste  1979-01-02 00:00:00
# 4      Mr            Ganesh Fakatkar         Fakatkar  2024-09-09 00:00:00
# ..    ...                        ...              ...                  ...
# 478    Mr                      Kumar                -                empty
# 479    Mr               Brij Bhushan           Sharma                empty
# 480    Mr                        Lee            Huynh  1981-07-22 00:00:00
# 481    Mr               George Kutty              P G                empty
# 482    Mr   Donthi Reddy  Ramkrishna            Reddy                empty
#
#        PAN CARD                          Email         Phone        Mobile  \
# 0         empty             anwer_m@live.co.uk  447716484849         empty
# 1         empty            shafath19@gmail.com  918105950895  919353311856
# 2    AIHPV4041R  sreedevitextiles999@gmail.com  917013040130  918018399974
# 3         empty             sanposte@gmail.com  918408866939  919730030912
# 4         empty       ganeshfakatkar@gmail.com  918655250697  919892062879
# ..          ...                            ...           ...           ...
# 478       empty       ashwini.mk2010@gmail.com  919342581122  917019927280
# 479       empty        brijbhushansh@gmail.com  917042571005  919312794403
# 480       empty            minchen90@gmail.com   61422342601         empty
# 481       empty      georgekuttypg97@gmail.com  919495104656  918078447618
# 482       empty    ramakrishnad@rocketmail.com  919502431366         empty
#
#                                           AddressLine1  \
# 0                                                empty
# 1                           RAJVISHNU RATSE MANJUNATHA
# 2    8 - 32 - 20, GANDHI NAGAR, VT AGRAHAM, VIZIANA...
# 3                                   A/2 SPARKLE AVENUE
# 4                                PL6A10, 16, SECTOR 1,
# ..                                                 ...
# 478                       N0 1857 20TH CROSS 21ST MAIN
# 479   1452 F1 FIRST FLOOR, SECTOR 3,VASUNDHARA,GHAZ...
# 480                                              empty
# 481                                                  -
# 482                    3-60, Near Veterinary Hospital,
#
#                        AddressLine2  ... Sales Rep and Comments Opt In  \
# 0                             empty  ...                  Peter    YES
# 1         LAY0UT THANISANDRA 560077  ...                  empty    YES
# 2                             empty  ...                  empty    YES
# 3    DATTA NAGAR,DIGHI ,PUNE 410015  ...                  empty    YES
# 4     KHANDA COLONY, PANVEL. 410206  ...               navaniya    YES
# ..                              ...  ...                    ...    ...
# 478     VIJAYNAGAR BANGALORE 560040  ...                 EDWARD    YES
# 479                  UTTAR PRADESH,  ...      TANISHQ CHAURASIA    YES
# 480                           empty  ...                  empty    YES
# 481                               -  ...                  empty    YES
# 482                               .  ...                  empty    YES
#
#         Contact Type Odyssey Members     Lead Brand Lead Sub-Brand  \
# 0    Email and Phone              NO  Karma Resorts          Other
# 1    Email and Phone              NO  Karma Resorts          Other
# 2    Email and Phone              NO  Karma Resorts          Other
# 3    Email and Phone              NO  Karma Resorts          Other
# 4    Email and Phone              NO  Karma Resorts          Other
# ..               ...             ...            ...            ...
# 478  Email and Phone              NO  Karma Resorts          Other
# 479  Email and Phone              NO  Karma Resorts          Other
# 480  Email and Phone              NO  Karma Resorts          Other
# 481  Email and Phone              NO  Karma Resorts          Other
# 482  Email and Phone              NO  Karma Resorts          Other
#
#      Lead Source           Lead Locations Lead Source Description  \
# 0    Past Guests         Karma La Herriza               Viewpoint
# 1    Past Guests        Karma Royal Palms               Viewpoint
# 2    Past Guests        Karma Royal Palms               Viewpoint
# 3    Past Guests        Karma Royal Palms               Viewpoint
# 4    Past Guests        Karma Royal Palms               Viewpoint
# ..           ...                      ...                     ...
# 478  Past Guests        Karma Royal Palms               Viewpoint
# 479  Past Guests  Karma Sitabani, Corbett               Viewpoint
# 480  Past Guests            Karma Kandara               Viewpoint
# 481  Past Guests     Karma Munnar, Kerala               Viewpoint
# 482  Past Guests        Karma Royal Palms               Viewpoint
#
#     Exclude From Mailing
# 0                     NO
# 1                     NO
# 2                     NO
# 3                     NO
# 4                     NO
# ..                   ...
# 478                   NO
# 479                   NO
# 480                   NO
# 481                   NO
# 482                   NO
#
# [483 rows x 37 columns]

# %%
# find_member_booking[['Email','Same Value Find']].loc[find_member_booking['BookingNo'] == '2074237']
# df_viewpoint.loc[df_viewpoint['BookingNo'] == '2097221']
# df_viewpoint.loc[df_viewpoint['Email'].str.contains('prajuizn@gmail.com')]

# %%
df_viewpoint['DOB'].replace('empty', '', inplace=True)
dob_con_date = pd.to_datetime(df_viewpoint['DOB'])
dob_date = dob_con_date.dt.strftime('%Y-%m-%d')

arr_con_date = pd.to_datetime(df_viewpoint['Arrival'])
arr_date = arr_con_date.dt.strftime('%Y-%m-%d')

dep_con_date = pd.to_datetime(df_viewpoint['Departure'])
dep_date = dep_con_date.dt.strftime('%Y-%m-%d')

ci_con_date = pd.to_datetime(df_viewpoint['CheckInDate'])
ci_date = ci_con_date.dt.strftime('%Y-%m-%d')

co_con_date = pd.to_datetime(df_viewpoint['CheckOutDate'])
co_date = co_con_date.dt.strftime('%Y-%m-%d')

df_viewpoint['DOB'] = dob_date
df_viewpoint['Arrival'] = arr_date
df_viewpoint['Departure'] = dep_date
df_viewpoint['CheckInDate'] = ci_date
df_viewpoint['CheckOutDate'] = co_date
# Out:
# C:\Users\fajar\AppData\Local\Temp\ipykernel_836\1121966507.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_viewpoint['DOB'].replace('empty', '', inplace=True)

# %%
df_viewpoint.columns
# Out:
# Index(['Title', 'Firstname', 'lastname', 'DOB', 'PAN CARD', 'Email', 'Phone',
#        'Mobile', 'AddressLine1', 'AddressLine2', 'Town', 'State', 'Country',
#        'PostCode', 'Nationality', 'MaritalStatus', 'resortname', 'Arrival',
#        'Departure', 'CheckInDate', 'CheckOutDate', 'room', 'UnitCategory',
#        'BookingNo', 'BookingSourceDesc', 'BookingTypeDesc', 'Date of Tour',
#        'Sales Rep and Comments', 'Opt In', 'Contact Type', 'Odyssey Members',
#        'Lead Brand', 'Lead Sub-Brand', 'Lead Source', 'Lead Locations',
#        'Lead Source Description', 'Exclude From Mailing'],
#       dtype='object')

# %%
new_cols = ['Lead Brand','Lead Sub-Brand','Lead Source','Lead Locations','Lead Source Description','Title','Firstname','lastname','DOB','Email','Phone','Mobile','AddressLine1','AddressLine2','Town','State',
'Country','PostCode','Nationality','MaritalStatus',	'resortname', 'Arrival', 'Departure', 'CheckInDate', 'CheckOutDate', 'room', 'UnitCategory', 'BookingNo', 'BookingSourceDesc', 'BookingTypeDesc', 'Date of Tour', 'Sales Rep and Comments',	'Opt In', 'Exclude From Mailing', 'Odyssey Members', 'Contact Type']																																																																																																																																						

df_viewpoint = df_viewpoint.reindex(columns=new_cols)

# %%
df_viewpoint.replace('empty', '', inplace=True)

df_viewpoint.sort_values('Departure', ascending=True, inplace=True)
df_viewpoint.reset_index(drop=True, inplace=True)
df_viewpoint
# Out:
#         Lead Brand Lead Sub-Brand  Lead Source  \
# 0    Karma Resorts          Other  Past Guests
# 1    Karma Resorts          Other  Past Guests
# 2    Karma Resorts          Other  Past Guests
# 3    Karma Resorts          Other  Past Guests
# 4    Karma Resorts          Other  Past Guests
# ..             ...            ...          ...
# 478  Karma Resorts          Other  Past Guests
# 479  Karma Resorts          Other  Past Guests
# 480  Karma Resorts          Other  Past Guests
# 481  Karma Resorts          Other  Past Guests
# 482  Karma Resorts          Other  Past Guests
#
#                         Lead Locations Lead Source Description Title  \
# 0                    Karma Royal Palms               Viewpoint   Mrs
# 1    Wyndham -  Manoir des Deux Amants               Viewpoint
# 2    Wyndham -  Manoir des Deux Amants               Viewpoint
# 3         Karma Golden Camp, Jaisalmer               Viewpoint    Mr
# 4                      Karma Song Hoai               Viewpoint    Mr
# ..                                 ...                     ...   ...
# 478               Karma Munnar, Kerala               Viewpoint    Mr
# 479                  Karma Royal Palms               Viewpoint    Mr
# 480             Karma Bayon, Siam Reap               Viewpoint    Mr
# 481            Karma Sitabani, Corbett               Viewpoint    Mr
# 482                  Karma Royal Palms               Viewpoint    Mr
#
#                      Firstname   lastname         DOB  \
# 0                       Abitha        Rao         NaN
# 1            Spanneut, Clement          -         NaN
# 2                 White, Lacey          -         NaN
# 3                     Piyush S  Gandhewar  1991-09-01
# 4                      Stephen    Abraham         NaN
# ..                         ...        ...         ...
# 478               George Kutty        P G         NaN
# 479            Somanth Bapurao      Tagad         NaN
# 480               Niranjan. R.     Kamath  1977-09-25
# 481                      Arbaz        Mev  1990-10-23
# 482   Donthi Reddy  Ramkrishna      Reddy         NaN
#
#                              Email  ...           UnitCategory BookingNo  \
# 0             abithasrao@gmail.com  ...  2 Bedroom Combination   2641958
# 1                                   ...    2 Bedroom Apartment   2658376
# 2         laceyjfilipich@yahoo.com  ...    2 Bedroom Apartment   2647914
# 3             pgandhewar@gmail.com  ...          Tent (NO A/C)   2654848
# 4    stephen.abraham1978@gmail.com  ...      Hotel Unit Double   2552467
# ..                             ...  ...                    ...       ...
# 478      georgekuttypg97@gmail.com  ...    Hotel Unit max 1ch.   2636933
# 479         sbtagad@rediffmail.com  ...    1 Bedroom Apartment   2694578
# 480      niranjan.kamath@gmail.com  ...          Studio Double   2696049
# 481        arbaazmev9584@gmail.com  ...  Non Member Hotel Unit   2669770
# 482    ramakrishnad@rocketmail.com  ...    1 Bedroom Apartment   2674983
#
#              BookingSourceDesc          BookingTypeDesc         Date of Tour  \
# 0              Guest of Member  Internal Rental / Bonus
# 1               Hotel Bookings           Wyndham Guests
# 2               Hotel Bookings           Wyndham Guests
# 3                  KCE2 Indian   Karma Experience India  2024-11-23 19:49:00
# 4    Guest Of Fractional Owner        Entitlement Guest
# ..                         ...                      ...                  ...
# 478                 Non Member       Non Member Program
# 479          Member Ambassador        Member Ambassador
# 480                  KC Member       Entitlement Member
# 481                KCE2 Indian   Karma Experience India  2024-12-01 11:00:00
# 482            Guest of Member        Entitlement Guest
#
#     Sales Rep and Comments Opt In Exclude From Mailing Odyssey Members  \
# 0                             YES                   NO              NO
# 1                             YES                   NO              NO
# 2                             YES                   NO              NO
# 3          DEEPANKAR GHOSH    YES                   NO              NO
# 4                             YES                   NO              NO
# ..                     ...    ...                  ...             ...
# 478                           YES                   NO              NO
# 479                           YES                   NO              NO
# 480                           YES                   NO              NO
# 481         ASIT CHOUDHARY    YES                   NO              NO
# 482                           YES                   NO              NO
#
#         Contact Type
# 0    Email and Phone
# 1    Email and Phone
# 2    Email and Phone
# 3    Email and Phone
# 4    Email and Phone
# ..               ...
# 478  Email and Phone
# 479  Email and Phone
# 480  Email and Phone
# 481  Email and Phone
# 482  Email and Phone
#
# [483 rows x 36 columns]

# %%
print("==========================================================")
print("Summary")
print("==========================================================")
print("Jumlah Data Setelah Script Past Guest Sebelumnya : "+str(count_data_awal))
print("Jumlah Data Yang Duplicate : "+str(count_duplicate_general))
print("Jumlah Data Setelah Hapus Duplicate : "+str(count_after_dedup_duplicate))
print("Jumlah Data Yang Termasuk Member: "+str(count_dedup_member))
print("Jumlah Data Setelah Hapus Member : "+str(count_after_dedup_member))
print("Jumlah Data Akhir : "+str(count_data_akhir))
# Out:
# ==========================================================
# Summary
# ==========================================================
# Jumlah Data Setelah Script Past Guest Sebelumnya : 2013
# Jumlah Data Yang Duplicate : 576
# Jumlah Data Setelah Hapus Duplicate : 1437
# Jumlah Data Yang Termasuk Member: 954
# Jumlah Data Setelah Hapus Member : 483
# Jumlah Data Akhir : 483

# %%
df_viewpoint.to_excel(r'C:\Users\fajar\Documents\Python\Data\final_viewpoint.xlsx', index=False)
