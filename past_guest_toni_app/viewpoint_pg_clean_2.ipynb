# %%
import pandas as pd
import re

import past_guest_module as pm

import sys
sys.path.append('../zoho_data_app/')

import main_module as m

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
path = r'C:\Users\fajar.fatoni\Documents\Python\Data\check_country_code_viewpoint.xlsx'
df_viewpoint = pd.read_excel(path, dtype='string', sheet_name='Sheet1')
count_data_awal = df_viewpoint.shape[0]

# %%
df_viewpoint.fillna('empty', inplace=True)

# %%
path = r'G:\.shortcut-targets-by-id\0B_d3smBjzo04UUNBME5GOVhoMjA\_ODYSSEY\Phone Members.xlsx'
df_phone = pd.read_excel(path, dtype='string', sheet_name='Sheet1')

path = r'G:\.shortcut-targets-by-id\0B_d3smBjzo04UUNBME5GOVhoMjA\_ODYSSEY\Email Members.xlsx'
df_email = pd.read_excel(path, dtype='string', sheet_name='Sheet1')

# %%
m.clean_space(df_email, 'Email')
df_email['Email'] = m.lowercase(df_email, 'Email')
# Out:
# c:\Users\fajar.fatoni\Documents\Python\Task Offline\past_guest_toni_app\../zoho_data_app\main_module.py:127: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[df_columns].replace(' ','', regex=True, inplace=True)

# %%
df_viewpoint.loc[
    (df_viewpoint['Phone'] == 'empty') & (df_viewpoint['Mobile'] != 'empty'), 
    'Phone'] = df_viewpoint['Mobile']
df_viewpoint.loc[df_viewpoint['Phone'] == df_viewpoint['Mobile'],'Mobile'] = 'empty'

# %%
# hitung jumlah duplicate
count_duplicate_general = df_viewpoint.loc[df_viewpoint.duplicated(subset=['Phone','Mobile','Email'])].shape[0]

df_viewpoint.loc[df_viewpoint.duplicated(subset=['Phone','Mobile','Email'])]
# Out:
#       Title      Firstname       lastname                  DOB  \
# 1     empty         Monica  Rastogi Bisht  1967-10-30 00:00:00
# 6        Ms           Yuri       Nakamura                empty
# 18       Mr        Abhinav        Prakash  1988-07-26 00:00:00
# 33    empty        Saurabh        Agarwal  1984-02-20 00:00:00
# 34    empty        Saurabh        Agarwal  1984-02-20 00:00:00
# ...     ...            ...            ...                  ...
# 1508     Mr        Yatnesh            Oza  1981-01-30 00:00:00
# 1510     Mr           Yash       Mahendra  1996-04-22 00:00:00
# 1512     Mr  Puneeth Kumar              S  1990-04-09 00:00:00
# 1514     Mr   Yogasrinivas      Kommineni  1994-06-22 00:00:00
# 1521    Mrs          Zahra        Bhamani  1962-11-30 00:00:00
#
#                               PAN CARD                         Email  \
# 1                           AIUPB3085C        1monicabisht@gmail.com
# 6                                empty           ababkatsu@gmail.com
# 18               BNNPP1032J,BNNPP1032J         abv.prakash@gmail.com
# 33                               empty     agrawalsweety20@gmail.com
# 34                               empty     agrawalsweety20@gmail.com
# ...                                ...                           ...
# 1508                             empty          yash_oza13@yahoo.com
# 1510  CUOPM8616A,CUOPM8616A,CUOPM8616A      yashmahendra22@gmail.com
# 1512                        BXOPP4732N              yenu56@gmail.com
# 1514                             empty  yogasrinivas.munna@gmail.com
# 1521                             empty        zahra1bhamani@yahoo.ca
#
#              Phone        Mobile  \
# 1     919820967906         empty
# 6      81798402992         empty
# 18    919538919085  919861919208
# 33    919889096458         empty
# 34    919889096458         empty
# ...            ...           ...
# 1508  912812477632  919824412399
# 1510  919740663504  919962048512
# 1512  919743118599  919900186573
# 1514   61450346505         empty
# 1521  917021867589   16477782527
#
#                                           AddressLine1  \
# 1                                  F1704 KANAKIA PARIS
# 6                              13 18 FUKAKUSANANMEICHO
# 18     B-301, VS CHALET APTS, LB SHATRY NAGAR HAL POST
# 33    131/3 C.P MISSION COMPOUND, BEHIND DAMAR GODOWN,
# 34    131/3 C.P MISSION COMPOUND, BEHIND DAMAR GODOWN,
# ...                                                ...
# 1508               SURAJ 2 APPT BUILDING A FLAT NO  12
# 1510     K-302, RAHEJA VISTAS, RAHEJA VIHAR CHANDIVALI
# 1512               112/5 26TH CROSS RAJIV GANDHI NAGAR
# 1514                                  12/16 PEARL ROAD
# 1521                          141 Ferndale Drive South
#
#                                           AddressLine2  ...  \
# 1                                          BANDRA EAST  ...
# 6                                           FUSHIMI KU  ...
# 18                                               empty  ...
# 33                              INFRONT OF SHIV MANDIR  ...
# 34                              INFRONT OF SHIV MANDIR  ...
# ...                                                ...  ...
# 1508  SHROFF ROAD OPP CHURCH, Nr. New Collector Office  ...
# 1510                                             empty  ...
# 1512                                      SUNKADAKATTE  ...
# 1514                                             empty  ...
# 1521                                             empty  ...
#
#      Sales Rep and Comments Opt In     Contact Type Odyssey Members  \
# 1                    Calvin    YES  Email and Phone              NO
# 6                     empty    YES  Email and Phone              NO
# 18                    empty    YES  Email and Phone              NO
# 33                    empty    YES  Email and Phone              NO
# 34                    empty    YES  Email and Phone              NO
# ...                     ...    ...              ...             ...
# 1508                  empty    YES  Email and Phone              NO
# 1510                  empty    YES  Email and Phone              NO
# 1512                  empty    YES  Email and Phone              NO
# 1514                Brandon    YES  Email and Phone              NO
# 1521                  empty    YES  Email and Phone              NO
#
#          Lead Brand Lead Sub-Brand  Lead Source  \
# 1     Karma Resorts          Other  Past Guests
# 6     Karma Resorts          Other  Past Guests
# 18    Karma Resorts          Other  Past Guests
# 33    Karma Resorts          Other  Past Guests
# 34    Karma Resorts          Other  Past Guests
# ...             ...            ...          ...
# 1508  Karma Resorts          Other  Past Guests
# 1510  Karma Resorts          Other  Past Guests
# 1512  Karma Resorts          Other  Past Guests
# 1514  Karma Resorts          Other  Past Guests
# 1521  Karma Resorts          Other  Past Guests
#
#                      Lead Locations Lead Source Description  \
# 1                Karma Salford Hall               Viewpoint
# 6                 Karma Royal Sanur               Viewpoint
# 18             Karma Martam Retreat               Viewpoint
# 33         Karma Royal Haathi Mahal               Viewpoint
# 34             Karma Royal Monterio               Viewpoint
# ...                             ...                     ...
# 1508          Karma Royal Candidasa               Viewpoint
# 1510           Karma Munnar, Kerala               Viewpoint
# 1512              Karma Royal Palms               Viewpoint
# 1514         Karma Bayon, Siem Reap               Viewpoint
# 1521  Karma Lakewood, Mahabaleshwar               Viewpoint
#
#      Exclude From Mailing
# 1                      NO
# 6                      NO
# 18                     NO
# 33                     NO
# 34                     NO
# ...                   ...
# 1508                   NO
# 1510                   NO
# 1512                   NO
# 1514                   NO
# 1521                   NO
#
# [342 rows x 37 columns]

# %%
df_viewpoint.drop_duplicates(subset=['Phone','Mobile','Email'], inplace=True)
df_viewpoint.reset_index(drop=True, inplace=True)

# hitung jumlah setelah value duplicate dihapus
count_after_dedup_duplicate = df_viewpoint.shape[0]

df_viewpoint
# Out:
#       Title           Firstname       lastname                  DOB  \
# 0     empty              Monica  Rastogi Bisht  1967-10-30 00:00:00
# 1        Mr                Chen          Jundi  1994-11-25 00:00:00
# 2     empty  Gonzalez, Santiago              -                empty
# 3     empty              Aakash       Parasher                empty
# 4        Mr     Lun Edwin Leung           Kock                empty
# ...     ...                 ...            ...                  ...
# 1197     Mr               Brett        Waldron  1983-05-03 00:00:00
# 1198      -               Luigi          Randi                empty
# 1199  empty                Andy      Northover                empty
# 1200  empty           Valentine           Aing                empty
# 1201      -              Joanna       Guelouza                empty
#
#         PAN CARD                      Email          Phone       Mobile  \
# 0     AIUPB3085C     1monicabisht@gmail.com   919820967906        empty
# 1          empty           623796484@qq.com  6282210015528        empty
# 2          empty      86.santiago@gmail.com    59898686841        empty
# 3     AZDPP3793M  aakash.parasher@gmail.com          empty        empty
# 4          empty        ababkatsu@gmail.com    81798402992        empty
# ...          ...                        ...            ...          ...
# 1197       empty                      empty     6494356008  64275349573
# 1198       empty                      empty   393488267741        empty
# 1199       empty                      empty   447765252344        empty
# 1200       empty                      empty    32488478441        empty
# 1201       empty                      empty    33651126959        empty
#
#                                            AddressLine1 AddressLine2  ...  \
# 0                                   F1704 KANAKIA PARIS  BANDRA EAST  ...
# 1                                                     -        empty  ...
# 2                                                 empty        empty  ...
# 3     202 FIRST FLOOR BUILDING 4  KAUSHALYA PARK,  H...        empty  ...
# 4                               13 18 FUKAKUSANANMEICHO   FUSHIMI KU  ...
# ...                                                 ...          ...  ...
# 1197                           559 Three Mile Bush Road        empty  ...
# 1198                                              empty        empty  ...
# 1199                                                  .        empty  ...
# 1200                                                  .        empty  ...
# 1201                                              empty        empty  ...
#
#      Sales Rep and Comments Opt In     Contact Type Odyssey Members  \
# 0                     empty    YES  Email and Phone              NO
# 1                     empty    YES  Email and Phone              NO
# 2                     empty    YES  Email and Phone              NO
# 3                     empty    YES       Email Only              NO
# 4                     empty    YES  Email and Phone              NO
# ...                     ...    ...              ...             ...
# 1197                  empty    YES       Phone Only              NO
# 1198                  empty    YES       Phone Only              NO
# 1199                  empty    YES       Phone Only              NO
# 1200                  empty    YES       Phone Only              NO
# 1201                  empty    YES       Phone Only              NO
#
#          Lead Brand Lead Sub-Brand  Lead Source  \
# 0     Karma Resorts          Other  Past Guests
# 1     Karma Resorts          Other  Past Guests
# 2     Karma Resorts          Other  Past Guests
# 3     Karma Resorts          Other  Past Guests
# 4     Karma Resorts          Other  Past Guests
# ...             ...            ...          ...
# 1197  Karma Resorts          Other  Past Guests
# 1198  Karma Resorts          Other  Past Guests
# 1199  Karma Resorts          Other  Past Guests
# 1200  Karma Resorts          Other  Past Guests
# 1201  Karma Resorts          Other  Past Guests
#
#                                Lead Locations Lead Source Description  \
# 0                        Karma Haveli, Jaipur               Viewpoint
# 1                              Karma Jimbaran               Viewpoint
# 2           Wyndham -  Manoir des Deux Amants               Viewpoint
# 3     KRR @ Karma Kandara, Mentari Residences               Viewpoint
# 4                           Karma Royal Sanur               Viewpoint
# ...                                       ...                     ...
# 1197  KRR @ Karma Kandara, Mentari Residences               Viewpoint
# 1198        Wyndham -  Manoir des Deux Amants               Viewpoint
# 1199        Wyndham -  Manoir des Deux Amants               Viewpoint
# 1200        Wyndham -  Manoir des Deux Amants               Viewpoint
# 1201        Wyndham -  Manoir des Deux Amants               Viewpoint
#
#      Exclude From Mailing
# 0                      NO
# 1                      NO
# 2                      NO
# 3                      NO
# 4                      NO
# ...                   ...
# 1197                   NO
# 1198                   NO
# 1199                   NO
# 1200                   NO
# 1201                   NO
#
# [1202 rows x 37 columns]

# %%
find_member_booking = df_viewpoint.copy()

find_member_booking.loc[find_member_booking['Phone'].isin(df_phone['Mobile']), 'Same Value Find'] = 'Member-Mobile' 
find_member_booking.loc[find_member_booking['Mobile'].isin(df_phone['Mobile']), 'Same Value Find'] = 'Member-Mobile'

find_member_booking.loc[find_member_booking['Email'].isin(df_email['Email']), 'Same Value Find'] = 'Member-Email'
display(find_member_booking)
find_member_booking.drop(find_member_booking.loc[find_member_booking['Same Value Find'].isna()].index, inplace=True)
# Out:
#       Title           Firstname       lastname                  DOB  \
# 0     empty              Monica  Rastogi Bisht  1967-10-30 00:00:00
# 1        Mr                Chen          Jundi  1994-11-25 00:00:00
# 2     empty  Gonzalez, Santiago              -                empty
# 3     empty              Aakash       Parasher                empty
# 4        Mr     Lun Edwin Leung           Kock                empty
# ...     ...                 ...            ...                  ...
# 1197     Mr               Brett        Waldron  1983-05-03 00:00:00
# 1198      -               Luigi          Randi                empty
# 1199  empty                Andy      Northover                empty
# 1200  empty           Valentine           Aing                empty
# 1201      -              Joanna       Guelouza                empty
#
#         PAN CARD                      Email          Phone       Mobile  \
# 0     AIUPB3085C     1monicabisht@gmail.com   919820967906        empty
# 1          empty           623796484@qq.com  6282210015528        empty
# 2          empty      86.santiago@gmail.com    59898686841        empty
# 3     AZDPP3793M  aakash.parasher@gmail.com          empty        empty
# 4          empty        ababkatsu@gmail.com    81798402992        empty
# ...          ...                        ...            ...          ...
# 1197       empty                      empty     6494356008  64275349573
# 1198       empty                      empty   393488267741        empty
# 1199       empty                      empty   447765252344        empty
# 1200       empty                      empty    32488478441        empty
# 1201       empty                      empty    33651126959        empty
#
#                                            AddressLine1 AddressLine2  ...  \
# 0                                   F1704 KANAKIA PARIS  BANDRA EAST  ...
# 1                                                     -        empty  ...
# 2                                                 empty        empty  ...
# 3     202 FIRST FLOOR BUILDING 4  KAUSHALYA PARK,  H...        empty  ...
# 4                               13 18 FUKAKUSANANMEICHO   FUSHIMI KU  ...
# ...                                                 ...          ...  ...
# 1197                           559 Three Mile Bush Road        empty  ...
# 1198                                              empty        empty  ...
# 1199                                                  .        empty  ...
# 1200                                                  .        empty  ...
# 1201                                              empty        empty  ...
#
#      Opt In     Contact Type Odyssey Members     Lead Brand Lead Sub-Brand  \
# 0       YES  Email and Phone              NO  Karma Resorts          Other
# 1       YES  Email and Phone              NO  Karma Resorts          Other
# 2       YES  Email and Phone              NO  Karma Resorts          Other
# 3       YES       Email Only              NO  Karma Resorts          Other
# 4       YES  Email and Phone              NO  Karma Resorts          Other
# ...     ...              ...             ...            ...            ...
# 1197    YES       Phone Only              NO  Karma Resorts          Other
# 1198    YES       Phone Only              NO  Karma Resorts          Other
# 1199    YES       Phone Only              NO  Karma Resorts          Other
# 1200    YES       Phone Only              NO  Karma Resorts          Other
# 1201    YES       Phone Only              NO  Karma Resorts          Other
#
#       Lead Source                           Lead Locations  \
# 0     Past Guests                     Karma Haveli, Jaipur
# 1     Past Guests                           Karma Jimbaran
# 2     Past Guests        Wyndham -  Manoir des Deux Amants
# 3     Past Guests  KRR @ Karma Kandara, Mentari Residences
# 4     Past Guests                        Karma Royal Sanur
# ...           ...                                      ...
# 1197  Past Guests  KRR @ Karma Kandara, Mentari Residences
# 1198  Past Guests        Wyndham -  Manoir des Deux Amants
# 1199  Past Guests        Wyndham -  Manoir des Deux Amants
# 1200  Past Guests        Wyndham -  Manoir des Deux Amants
# 1201  Past Guests        Wyndham -  Manoir des Deux Amants
#
#      Lead Source Description Exclude From Mailing Same Value Find
# 0                  Viewpoint                   NO    Member-Email
# 1                  Viewpoint                   NO             NaN
# 2                  Viewpoint                   NO             NaN
# 3                  Viewpoint                   NO    Member-Email
# 4                  Viewpoint                   NO             NaN
# ...                      ...                  ...             ...
# 1197               Viewpoint                   NO   Member-Mobile
# 1198               Viewpoint                   NO             NaN
# 1199               Viewpoint                   NO             NaN
# 1200               Viewpoint                   NO             NaN
# 1201               Viewpoint                   NO             NaN
#
# [1202 rows x 38 columns]

# %%
find_member_booking
# Out:
#       Title       Firstname       lastname                  DOB  \
# 0     empty          Monica  Rastogi Bisht  1967-10-30 00:00:00
# 3     empty          Aakash       Parasher                empty
# 5       Mrs           Abbey         Wagner  1963-01-13 00:00:00
# 6        Mr            Brad         Wagner  1963-10-29 00:00:00
# 8        Mr         Abhijit       Gawaskar  1979-03-31 00:00:00
# ...     ...             ...            ...                  ...
# 1190    Mrs  Prasanna Arjun           Ayir  1987-05-04 00:00:00
# 1193     Mr             Raj            Rao                empty
# 1195     Mr          Dinesh         Sharma                empty
# 1196     Mr           Allan          Byrne  1980-01-06 00:00:00
# 1197     Mr           Brett        Waldron  1983-05-03 00:00:00
#
#                    PAN CARD                         Email         Phone  \
# 0                AIUPB3085C        1monicabisht@gmail.com  919820967906
# 3                AZDPP3793M     aakash.parasher@gmail.com         empty
# 5                     empty           abbeywagner@mac.com   13103731940
# 6                     empty           abbeywagner@mac.com   13103451789
# 8     AHKPG7974L,AHKPG7974L  abhi_gawaskar@rediffmail.com  917775048484
# ...                     ...                           ...           ...
# 1190                  empty                         empty  971528374515
# 1193                  empty                         empty  919448273066
# 1195                  empty                         empty  919899689423
# 1196                  empty                         empty   61481764800
# 1197                  empty                         empty    6494356008
#
#             Mobile                                       AddressLine1  \
# 0            empty                                F1704 KANAKIA PARIS
# 3            empty  202 FIRST FLOOR BUILDING 4  KAUSHALYA PARK,  H...
# 5      13103451289                                       321 AVENUE E
# 6      13105053601                                       321 AVENUE E
# 8     919657725286                    A-903, KSHITIJ CHS, SNO 87/1/1A
# ...            ...                                                ...
# 1190  971563056375                         h.no 295/2, voyamol xeldem
# 1193         empty                                                  .
# 1195         empty                                                  .
# 1196         empty                                 21 PROSPERITY ROAD
# 1197   64275349573                           559 Three Mile Bush Road
#
#                              AddressLine2  ... Opt In     Contact Type  \
# 0                             BANDRA EAST  ...    YES  Email and Phone
# 3                                   empty  ...    YES       Email Only
# 5                                   empty  ...    YES  Email and Phone
# 6                                   empty  ...    YES  Email and Phone
# 8     NEAR 9 GREENPARK, SAHAKARNAGAR NO.2  ...     NO  Email and Phone
# ...                                   ...  ...    ...              ...
# 1190                                empty  ...    YES       Phone Only
# 1193                                empty  ...    YES       Phone Only
# 1195                                    .  ...    YES       Phone Only
# 1196                                empty  ...    YES       Phone Only
# 1197                                empty  ...    YES       Phone Only
#
#      Odyssey Members     Lead Brand Lead Sub-Brand  Lead Source  \
# 0                 NO  Karma Resorts          Other  Past Guests
# 3                 NO  Karma Resorts          Other  Past Guests
# 5                 NO  Karma Resorts          Other  Past Guests
# 6                 NO  Karma Resorts          Other  Past Guests
# 8                 NO  Karma Resorts          Other  Past Guests
# ...              ...            ...            ...          ...
# 1190              NO  Karma Resorts          Other  Past Guests
# 1193              NO  Karma Resorts          Other  Past Guests
# 1195              NO  Karma Resorts          Other  Past Guests
# 1196              NO  Karma Resorts          Other  Past Guests
# 1197              NO  Karma Resorts          Other  Past Guests
#
#                                Lead Locations Lead Source Description  \
# 0                        Karma Haveli, Jaipur               Viewpoint
# 3     KRR @ Karma Kandara, Mentari Residences               Viewpoint
# 5                                Karma Minoan               Viewpoint
# 6                                Karma Minoan               Viewpoint
# 8                        Karma Royal Monterio               Viewpoint
# ...                                       ...                     ...
# 1190                 Karma Royal Haathi Mahal               Viewpoint
# 1193                   Karma Sunshine Village               Viewpoint
# 1195                 Karma Tashi, Dharamshala               Viewpoint
# 1196  KRR @ Karma Kandara, Mentari Residences               Viewpoint
# 1197  KRR @ Karma Kandara, Mentari Residences               Viewpoint
#
#      Exclude From Mailing Same Value Find
# 0                      NO    Member-Email
# 3                      NO    Member-Email
# 5                      NO    Member-Email
# 6                      NO    Member-Email
# 8                     YES    Member-Email
# ...                   ...             ...
# 1190                   NO   Member-Mobile
# 1193                   NO   Member-Mobile
# 1195                   NO   Member-Mobile
# 1196                   NO   Member-Mobile
# 1197                   NO   Member-Mobile
#
# [867 rows x 38 columns]

# %%
find_member_booking.replace('empty', '', inplace=True)
find_member_booking.to_csv(r'C:\Users\fajar.fatoni\Documents\Python\Data\cek_member_viewpoint.csv', index=False)

# %%
count_dedup_member = df_viewpoint.loc[
    
    df_viewpoint['Phone'].isin(df_phone['Mobile']) | 
    df_viewpoint['Mobile'].isin(df_phone['Mobile']) |

    df_viewpoint['Email'].isin(df_email['Email'])
    ].shape[0]

df_viewpoint.loc[
    
    df_viewpoint['Phone'].isin(df_phone['Mobile']) | 
    df_viewpoint['Mobile'].isin(df_phone['Mobile']) |

    df_viewpoint['Email'].isin(df_email['Email'])
    ]
# Out:
#       Title       Firstname       lastname                  DOB  \
# 0     empty          Monica  Rastogi Bisht  1967-10-30 00:00:00
# 3     empty          Aakash       Parasher                empty
# 5       Mrs           Abbey         Wagner  1963-01-13 00:00:00
# 6        Mr            Brad         Wagner  1963-10-29 00:00:00
# 8        Mr         Abhijit       Gawaskar  1979-03-31 00:00:00
# ...     ...             ...            ...                  ...
# 1190    Mrs  Prasanna Arjun           Ayir  1987-05-04 00:00:00
# 1193     Mr             Raj            Rao                empty
# 1195     Mr          Dinesh         Sharma                empty
# 1196     Mr           Allan          Byrne  1980-01-06 00:00:00
# 1197     Mr           Brett        Waldron  1983-05-03 00:00:00
#
#                    PAN CARD                         Email         Phone  \
# 0                AIUPB3085C        1monicabisht@gmail.com  919820967906
# 3                AZDPP3793M     aakash.parasher@gmail.com         empty
# 5                     empty           abbeywagner@mac.com   13103731940
# 6                     empty           abbeywagner@mac.com   13103451789
# 8     AHKPG7974L,AHKPG7974L  abhi_gawaskar@rediffmail.com  917775048484
# ...                     ...                           ...           ...
# 1190                  empty                         empty  971528374515
# 1193                  empty                         empty  919448273066
# 1195                  empty                         empty  919899689423
# 1196                  empty                         empty   61481764800
# 1197                  empty                         empty    6494356008
#
#             Mobile                                       AddressLine1  \
# 0            empty                                F1704 KANAKIA PARIS
# 3            empty  202 FIRST FLOOR BUILDING 4  KAUSHALYA PARK,  H...
# 5      13103451289                                       321 AVENUE E
# 6      13105053601                                       321 AVENUE E
# 8     919657725286                    A-903, KSHITIJ CHS, SNO 87/1/1A
# ...            ...                                                ...
# 1190  971563056375                         h.no 295/2, voyamol xeldem
# 1193         empty                                                  .
# 1195         empty                                                  .
# 1196         empty                                 21 PROSPERITY ROAD
# 1197   64275349573                           559 Three Mile Bush Road
#
#                              AddressLine2  ... Sales Rep and Comments Opt In  \
# 0                             BANDRA EAST  ...                  empty    YES
# 3                                   empty  ...                  empty    YES
# 5                                   empty  ...                 Taskin    YES
# 6                                   empty  ...                 Taskin    YES
# 8     NEAR 9 GREENPARK, SAHAKARNAGAR NO.2  ...                  empty     NO
# ...                                   ...  ...                    ...    ...
# 1190                                empty  ...                  empty    YES
# 1193                                empty  ...                  empty    YES
# 1195                                    .  ...                  empty    YES
# 1196                                empty  ...                  empty    YES
# 1197                                empty  ...                  empty    YES
#
#          Contact Type Odyssey Members     Lead Brand Lead Sub-Brand  \
# 0     Email and Phone              NO  Karma Resorts          Other
# 3          Email Only              NO  Karma Resorts          Other
# 5     Email and Phone              NO  Karma Resorts          Other
# 6     Email and Phone              NO  Karma Resorts          Other
# 8     Email and Phone              NO  Karma Resorts          Other
# ...               ...             ...            ...            ...
# 1190       Phone Only              NO  Karma Resorts          Other
# 1193       Phone Only              NO  Karma Resorts          Other
# 1195       Phone Only              NO  Karma Resorts          Other
# 1196       Phone Only              NO  Karma Resorts          Other
# 1197       Phone Only              NO  Karma Resorts          Other
#
#       Lead Source                           Lead Locations  \
# 0     Past Guests                     Karma Haveli, Jaipur
# 3     Past Guests  KRR @ Karma Kandara, Mentari Residences
# 5     Past Guests                             Karma Minoan
# 6     Past Guests                             Karma Minoan
# 8     Past Guests                     Karma Royal Monterio
# ...           ...                                      ...
# 1190  Past Guests                 Karma Royal Haathi Mahal
# 1193  Past Guests                   Karma Sunshine Village
# 1195  Past Guests                 Karma Tashi, Dharamshala
# 1196  Past Guests  KRR @ Karma Kandara, Mentari Residences
# 1197  Past Guests  KRR @ Karma Kandara, Mentari Residences
#
#      Lead Source Description Exclude From Mailing
# 0                  Viewpoint                   NO
# 3                  Viewpoint                   NO
# 5                  Viewpoint                   NO
# 6                  Viewpoint                   NO
# 8                  Viewpoint                  YES
# ...                      ...                  ...
# 1190               Viewpoint                   NO
# 1193               Viewpoint                   NO
# 1195               Viewpoint                   NO
# 1196               Viewpoint                   NO
# 1197               Viewpoint                   NO
#
# [867 rows x 37 columns]

# %%
df_viewpoint.drop(df_viewpoint.loc[
    
    df_viewpoint['Phone'].isin(df_phone['Mobile']) | 
    df_viewpoint['Mobile'].isin(df_phone['Mobile']) |

    df_viewpoint['Email'].isin(df_email['Email'])
].index, inplace=True)

df_viewpoint.reset_index(drop=True, inplace=True)

count_after_dedup_member = df_viewpoint.shape[0]

# %%
count_data_akhir = df_viewpoint.shape[0]

# %%
df_viewpoint.sort_values('CheckOutDate', ascending=True, inplace=True)
df_viewpoint.reset_index(drop=True, inplace=True)
df_viewpoint
# Out:
#     Title    Firstname     lastname                  DOB PAN CARD  \
# 0      Mr      Shreyas     Shikhara  1991-12-28 00:00:00    empty
# 1      Mr       Masood         Khan                empty    empty
# 2      Mr     Mahendra   Pandharkar  1983-11-09 00:00:00    empty
# 3      Mr   Kishore  C        Ranka  1974-04-28 00:00:00    empty
# 4      Mr  Arunachalam            .  1964-01-15 00:00:00    empty
# ..    ...          ...          ...                  ...      ...
# 330    Ms        Emily   Mcconochie                empty    empty
# 331    Mr  Kiran Kumar   Palakurthi  1987-06-05 00:00:00    empty
# 332    Mr    Rajeshwar     Nimodiya  1986-03-15 00:00:00    empty
# 333    Mr        Sunil        Nanda                empty    empty
# 334   Mrs         Olga       Orlova  1961-08-21 00:00:00    empty
#
#                                 Email         Phone        Mobile  \
# 0              charvick123s@gmail.com  919869105996  919960520310
# 1                 masoodk@yahoo.co.in  916363975845         empty
# 2    mahendrapandharkar1983@gmail.com  919923924922  919423174922
# 3          www.kishorehot04@gmail.com  919844243689  917019892722
# 4             ar.sarikaa011@gmail.com  918792853443  919844189385
# ..                                ...           ...           ...
# 330            mcconochie.e@gmail.com   61404488778         empty
# 331  kirankumar.palakurthi1@gmail.com  919492588925  918328037032
# 332            rajeshwar.fr@gmail.com  919172468648  919172468466
# 333                             empty  919811338519         empty
# 334         olgaanderson303@gmail.com   61422086488         empty
#
#                                           AddressLine1  \
# 0                         32 Teacher's housing society
# 1                                            Bangalore
# 2                      pandharkar wadi Nighoj , parner
# 3    378   10th   Cross Shashtrinagar  Nr  Bal  Amb...
# 4    E 603 Rohan Vasantha Apartment, Marathahalli B...
# ..                                                 ...
# 330                                                  -
# 331  10-37-15-1/1 Ram Nagar Drivers Colony  A U Eng...
# 332                     T-1 3RD FLOOR MARIAM APARTMENT
# 333         294/1 FIRST FLOOR 60 FEET ROAD CHATTAR PUR
# 334  Street Address: 49 Owenia st City: Algester St...
#
#                             AddressLine2  ... Sales Rep and Comments Opt In  \
# 0                     south sadar bazaar  ...                  empty    YES
# 1                                  empty  ...                  empty    YES
# 2     Ahmadnagar pune Maharashtra 414306  ...                  empty    YES
# 3                                  empty  ...                  empty    YES
# 4                                      -  ...                  empty    YES
# ..                                   ...  ...                    ...    ...
# 330                                    -  ...                  empty    YES
# 331  Visakhapatnam Andhra Pradesh-530003  ...                  empty    YES
# 332          COOKE TOWN BANGALORE 560005  ...                  empty    YES
# 333                                empty  ...                  empty    YES
# 334                                    -  ...                  empty    YES
#
#         Contact Type Odyssey Members     Lead Brand Lead Sub-Brand  \
# 0    Email and Phone              NO  Karma Resorts          Other
# 1    Email and Phone              NO  Karma Resorts          Other
# 2    Email and Phone              NO  Karma Resorts          Other
# 3    Email and Phone              NO  Karma Resorts          Other
# 4    Email and Phone              NO  Karma Resorts          Other
# ..               ...             ...            ...            ...
# 330  Email and Phone              NO  Karma Resorts          Other
# 331  Email and Phone              NO  Karma Resorts          Other
# 332  Email and Phone              NO  Karma Resorts          Other
# 333       Phone Only              NO  Karma Resorts          Other
# 334  Email and Phone              NO  Karma Resorts          Other
#
#      Lead Source                           Lead Locations  \
# 0    Past Guests                        Karma Royal Palms
# 1    Past Guests                        Karma Royal Palms
# 2    Past Guests                        Karma Royal Palms
# 3    Past Guests                        Karma Royal Palms
# 4    Past Guests                        Karma Royal Palms
# ..           ...                                      ...
# 330  Past Guests                 Karma Panalee, Koh Samui
# 331  Past Guests                        Karma Royal Palms
# 332  Past Guests                        Karma Royal Palms
# 333  Past Guests                  Karma Sitabani, Corbett
# 334  Past Guests  KRR @ Karma Kandara, Mentari Residences
#
#     Lead Source Description Exclude From Mailing
# 0                 Viewpoint                   NO
# 1                 Viewpoint                   NO
# 2                 Viewpoint                   NO
# 3                 Viewpoint                   NO
# 4                 Viewpoint                   NO
# ..                      ...                  ...
# 330               Viewpoint                   NO
# 331               Viewpoint                   NO
# 332               Viewpoint                   NO
# 333               Viewpoint                   NO
# 334               Viewpoint                   NO
#
# [335 rows x 37 columns]

# %%
# find_member_booking[['Email','Same Value Find']].loc[find_member_booking['BookingNo'] == '2074237']
# df_viewpoint.loc[df_viewpoint['BookingNo'] == '2097221']
# df_viewpoint.loc[df_viewpoint['Email'].str.contains('prajuizn@gmail.com')]

# %%
# Replace 'empty' with pd.NaT
df_viewpoint['DOB'].replace('empty', pd.NaT, inplace=True)
df_viewpoint['Arrival'].replace('empty', pd.NaT, inplace=True)
df_viewpoint['Departure'].replace('empty', pd.NaT, inplace=True)
df_viewpoint['CheckInDate'].replace('empty', pd.NaT, inplace=True)
df_viewpoint['CheckOutDate'].replace('empty', pd.NaT, inplace=True)

# Convert to datetime, using errors='coerce' to handle any invalid formats
dob_con_date = pd.to_datetime(df_viewpoint['DOB'], errors='coerce')
dob_date = dob_con_date.dt.strftime('%Y-%m-%d')

arr_con_date = pd.to_datetime(df_viewpoint['Arrival'], errors='coerce')
arr_date = arr_con_date.dt.strftime('%Y-%m-%d')

dep_con_date = pd.to_datetime(df_viewpoint['Departure'], errors='coerce')
dep_date = dep_con_date.dt.strftime('%Y-%m-%d')

ci_con_date = pd.to_datetime(df_viewpoint['CheckInDate'], errors='coerce')
ci_date = ci_con_date.dt.strftime('%Y-%m-%d')

co_con_date = pd.to_datetime(df_viewpoint['CheckOutDate'], errors='coerce')
co_date = co_con_date.dt.strftime('%Y-%m-%d')

# Assign the formatted dates back to the DataFrame
df_viewpoint['DOB'] = dob_date
df_viewpoint['Arrival'] = arr_date
df_viewpoint['Departure'] = dep_date
df_viewpoint['CheckInDate'] = ci_date
df_viewpoint['CheckOutDate'] = co_date

# Display the updated DataFrame
print(df_viewpoint)
# Out:
#     Title    Firstname     lastname         DOB PAN CARD  \
# 0      Mr      Shreyas     Shikhara  1991-12-28    empty
# 1      Mr       Masood         Khan         NaN    empty
# 2      Mr     Mahendra   Pandharkar  1983-11-09    empty
# 3      Mr   Kishore  C        Ranka  1974-04-28    empty
# 4      Mr  Arunachalam            .  1964-01-15    empty
# ..    ...          ...          ...         ...      ...
# 330    Ms        Emily   Mcconochie         NaN    empty
# 331    Mr  Kiran Kumar   Palakurthi  1987-06-05    empty
# 332    Mr    Rajeshwar     Nimodiya  1986-03-15    empty
# 333    Mr        Sunil        Nanda         NaN    empty
# 334   Mrs         Olga       Orlova  1961-08-21    empty
#
#                                 Email         Phone        Mobile  \
# 0              charvick123s@gmail.com  919869105996  919960520310
# 1                 masoodk@yahoo.co.in  916363975845         empty
# 2    mahendrapandharkar1983@gmail.com  919923924922  919423174922
# 3          www.kishorehot04@gmail.com  919844243689  917019892722
# 4             ar.sarikaa011@gmail.com  918792853443  919844189385
# ..                                ...           ...           ...
# 330            mcconochie.e@gmail.com   61404488778         empty
# 331  kirankumar.palakurthi1@gmail.com  919492588925  918328037032
# 332            rajeshwar.fr@gmail.com  919172468648  919172468466
# 333                             empty  919811338519         empty
# 334         olgaanderson303@gmail.com   61422086488         empty
#
#                                           AddressLine1  \
# 0                         32 Teacher's housing society
# 1                                            Bangalore
# 2                      pandharkar wadi Nighoj , parner
# 3    378   10th   Cross Shashtrinagar  Nr  Bal  Amb...
# 4    E 603 Rohan Vasantha Apartment, Marathahalli B...
# ..                                                 ...
# 330                                                  -
# 331  10-37-15-1/1 Ram Nagar Drivers Colony  A U Eng...
# 332                     T-1 3RD FLOOR MARIAM APARTMENT
# 333         294/1 FIRST FLOOR 60 FEET ROAD CHATTAR PUR
# 334  Street Address: 49 Owenia st City: Algester St...
#
#                             AddressLine2  ... Sales Rep and Comments Opt In  \
# 0                     south sadar bazaar  ...                  empty    YES
# 1                                  empty  ...                  empty    YES
# 2     Ahmadnagar pune Maharashtra 414306  ...                  empty    YES
# 3                                  empty  ...                  empty    YES
# 4                                      -  ...                  empty    YES
# ..                                   ...  ...                    ...    ...
# 330                                    -  ...                  empty    YES
# 331  Visakhapatnam Andhra Pradesh-530003  ...                  empty    YES
# 332          COOKE TOWN BANGALORE 560005  ...                  empty    YES
# 333                                empty  ...                  empty    YES
# 334                                    -  ...                  empty    YES
#
#         Contact Type Odyssey Members     Lead Brand Lead Sub-Brand  \
# 0    Email and Phone              NO  Karma Resorts          Other
# 1    Email and Phone              NO  Karma Resorts          Other
# 2    Email and Phone              NO  Karma Resorts          Other
# 3    Email and Phone              NO  Karma Resorts          Other
# 4    Email and Phone              NO  Karma Resorts          Other
# ..               ...             ...            ...            ...
# 330  Email and Phone              NO  Karma Resorts          Other
# 331  Email and Phone              NO  Karma Resorts          Other
# 332  Email and Phone              NO  Karma Resorts          Other
# 333       Phone Only              NO  Karma Resorts          Other
# 334  Email and Phone              NO  Karma Resorts          Other
#
#      Lead Source                           Lead Locations  \
# 0    Past Guests                        Karma Royal Palms
# 1    Past Guests                        Karma Royal Palms
# 2    Past Guests                        Karma Royal Palms
# 3    Past Guests                        Karma Royal Palms
# 4    Past Guests                        Karma Royal Palms
# ..           ...                                      ...
# 330  Past Guests                 Karma Panalee, Koh Samui
# 331  Past Guests                        Karma Royal Palms
# 332  Past Guests                        Karma Royal Palms
# 333  Past Guests                  Karma Sitabani, Corbett
# 334  Past Guests  KRR @ Karma Kandara, Mentari Residences
#
#     Lead Source Description Exclude From Mailing
# 0                 Viewpoint                   NO
# 1                 Viewpoint                   NO
# 2                 Viewpoint                   NO
# 3                 Viewpoint                   NO
# 4                 Viewpoint                   NO
# ..                      ...                  ...
# 330               Viewpoint                   NO
# 331               Viewpoint                   NO
# 332               Viewpoint                   NO
# 333               Viewpoint                   NO
# 334               Viewpoint                   NO
#
# [335 rows x 37 columns]
# C:\Users\fajar.fatoni\AppData\Local\Temp\ipykernel_23068\139261852.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_viewpoint['DOB'].replace('empty', pd.NaT, inplace=True)
# C:\Users\fajar.fatoni\AppData\Local\Temp\ipykernel_23068\139261852.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_viewpoint['Arrival'].replace('empty', pd.NaT, inplace=True)
# C:\Users\fajar.fatoni\AppData\Local\Temp\ipykernel_23068\139261852.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_viewpoint['Departure'].replace('empty', pd.NaT, inplace=True)
# C:\Users\fajar.fatoni\AppData\Local\Temp\ipykernel_23068\139261852.py:5: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_viewpoint['CheckInDate'].replace('empty', pd.NaT, inplace=True)
# C:\Users\fajar.fatoni\AppData\Local\Temp\ipykernel_23068\139261852.py:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_viewpoint['CheckOutDate'].replace('empty', pd.NaT, inplace=True)

# %%
df_viewpoint.columns
# Out:
# Index(['Title', 'Firstname', 'lastname', 'DOB', 'PAN CARD', 'Email', 'Phone',
#        'Mobile', 'AddressLine1', 'AddressLine2', 'Town', 'State', 'Country',
#        'PostCode', 'Nationality', 'MaritalStatus', 'resortname', 'Arrival',
#        'Departure', 'CheckInDate', 'CheckOutDate', 'room', 'UnitCategory',
#        'BookingNo', 'BookingSourceDesc', 'BookingTypeDesc', 'Date of Tour',
#        'Sales Rep and Comments', 'Opt In', 'Contact Type', 'Odyssey Members',
#        'Lead Brand', 'Lead Sub-Brand', 'Lead Source', 'Lead Locations',
#        'Lead Source Description', 'Exclude From Mailing'],
#       dtype='object')

# %%
new_cols = ['Lead Brand','Lead Sub-Brand','Lead Source','Lead Locations','Lead Source Description','Title','Firstname','lastname','DOB','Email','Phone','Mobile','AddressLine1','AddressLine2','Town','State',
'Country','PostCode','Nationality','MaritalStatus',	'resortname', 'Arrival', 'Departure', 'CheckInDate', 'CheckOutDate', 'room', 'UnitCategory', 'BookingNo', 'BookingSourceDesc', 'BookingTypeDesc', 'Date of Tour', 'Sales Rep and Comments',	'Opt In', 'Exclude From Mailing', 'Odyssey Members', 'Contact Type']																																																																																																																																						

df_viewpoint = df_viewpoint.reindex(columns=new_cols)

# %%
df_viewpoint.replace('empty', '', inplace=True)

df_viewpoint.sort_values('Departure', ascending=True, inplace=True)
df_viewpoint.reset_index(drop=True, inplace=True)
df_viewpoint
# Out:
#         Lead Brand Lead Sub-Brand  Lead Source  \
# 0    Karma Resorts          Other  Past Guests
# 1    Karma Resorts          Other  Past Guests
# 2    Karma Resorts          Other  Past Guests
# 3    Karma Resorts          Other  Past Guests
# 4    Karma Resorts          Other  Past Guests
# ..             ...            ...          ...
# 330  Karma Resorts          Other  Past Guests
# 331  Karma Resorts          Other  Past Guests
# 332  Karma Resorts          Other  Past Guests
# 333  Karma Resorts          Other  Past Guests
# 334  Karma Resorts          Other  Past Guests
#
#                               Lead Locations Lead Source Description Title  \
# 0                          Karma Royal Palms               Viewpoint    Mr
# 1                       Karma Royal Monterio               Viewpoint   Mrs
# 2                      Amina Lantana, Hoi An               Viewpoint    Mr
# 3                       Karma Royal Monterio               Viewpoint    Mr
# 4                       Karma Royal Monterio               Viewpoint    Mr
# ..                                       ...                     ...   ...
# 330                        Karma Royal Palms               Viewpoint    Mr
# 331                 Karma Panalee, Koh Samui               Viewpoint    Ms
# 332                        Karma Royal Palms               Viewpoint    Mr
# 333                        Karma Royal Palms               Viewpoint    Mr
# 334  KRR @ Karma Kandara, Mentari Residences               Viewpoint   Mrs
#
#        Firstname     lastname         DOB                             Email  \
# 0        Shreyas     Shikhara  1991-12-28            charvick123s@gmail.com
# 1    Kirti Kiran      Shirali         NaN          kirtishirali16@gmail.com
# 2          Craig      Crafton  1978-02-28               ckcrafton@proton.me
# 3         Aditya       Vaidya         NaN                az7ydota@gmail.com
# 4         Partha    Ajgaonkar         NaN             pajgaokar@hotmail.com
# ..           ...          ...         ...                               ...
# 330       Sachin     Khandare  1987-04-15       sachin.khandare87@gmail.com
# 331        Emily   Mcconochie         NaN            mcconochie.e@gmail.com
# 332  Kiran Kumar   Palakurthi  1987-06-05  kirankumar.palakurthi1@gmail.com
# 333    Rajeshwar     Nimodiya  1986-03-15            rajeshwar.fr@gmail.com
# 334         Olga       Orlova  1961-08-21         olgaanderson303@gmail.com
#
#      ...          UnitCategory BookingNo             BookingSourceDesc  \
# 0    ...  Non Member 1 Bedroom   2925187                Fly Buy Indian
# 1    ...   1 Bedroom Apartment   2894775               Guest of Member
# 2    ...         Deluxe Studio   2927101  KCE2 All Other Nationalities
# 3    ...   1 Bedroom Apartment   2910623               Guest of Member
# 4    ...   1 Bedroom Apartment   2900318               Guest of Member
# ..   ...                   ...       ...                           ...
# 330  ...  Non Member 1 Bedroom   2931210                Fly Buy Indian
# 331  ...     Hotel Unit Double   2939502                     KC Member
# 332  ...  Non Member 1 Bedroom   2909450                Fly Buy Indian
# 333  ...  Non Member 1 Bedroom   2906987                Fly Buy Indian
# 334  ...   Studio Deluxe Suite   2764418               Fly Buy Western
#
#                             BookingTypeDesc Date of Tour  \
# 0                    Karma Experience India
# 1    Karma Club Discovery Entitlement Guest
# 2                    Karma Experience India
# 3                         Entitlement Guest
# 4                         Entitlement Guest
# ..                                      ...          ...
# 330                  Karma Experience India
# 331                             Entitlement
# 332                  Karma Experience India
# 333                  Karma Experience India
# 334                             Via Resorts
#
#     Sales Rep and Comments Opt In Exclude From Mailing Odyssey Members  \
# 0                             YES                   NO              NO
# 1                             YES                   NO              NO
# 2                             YES                   NO              NO
# 3                             YES                   NO              NO
# 4                             YES                   NO              NO
# ..                     ...    ...                  ...             ...
# 330                           YES                   NO              NO
# 331                           YES                   NO              NO
# 332                           YES                   NO              NO
# 333                           YES                   NO              NO
# 334                           YES                   NO              NO
#
#         Contact Type
# 0    Email and Phone
# 1    Email and Phone
# 2    Email and Phone
# 3    Email and Phone
# 4    Email and Phone
# ..               ...
# 330  Email and Phone
# 331  Email and Phone
# 332  Email and Phone
# 333  Email and Phone
# 334  Email and Phone
#
# [335 rows x 36 columns]

# %%
print("==========================================================")
print("Summary")
print("==========================================================")
print("Jumlah Data Setelah Script Past Guest Sebelumnya : "+str(count_data_awal))
print("Jumlah Data Yang Duplicate : "+str(count_duplicate_general))
print("Jumlah Data Setelah Hapus Duplicate : "+str(count_after_dedup_duplicate))
print("Jumlah Data Yang Termasuk Member: "+str(count_dedup_member))
print("Jumlah Data Setelah Hapus Member : "+str(count_after_dedup_member))
print("Jumlah Data Akhir : "+str(count_data_akhir))
# Out:
# ==========================================================
# Summary
# ==========================================================
# Jumlah Data Setelah Script Past Guest Sebelumnya : 1544
# Jumlah Data Yang Duplicate : 342
# Jumlah Data Setelah Hapus Duplicate : 1202
# Jumlah Data Yang Termasuk Member: 867
# Jumlah Data Setelah Hapus Member : 335
# Jumlah Data Akhir : 335

# %%
german_speaking = ['Austria','Belgium','Germany','Liechtenstein','Luxembourg','Switzerland']
country_codes = ['43', '32', '49', '423', '352', '41']

df_viewpoint.loc[df_viewpoint['Country'].isin(german_speaking), 'Language'] = 'deu'   
df_viewpoint.loc[df_viewpoint['Phone'].str.startswith(tuple(country_codes)),'Language'] = 'deu'
df_viewpoint.loc[df_viewpoint['Email'].str.endswith('.de'),'Language'] = 'deu'

# %%
df_viewpoint.to_excel(r'C:\Users\fajar.fatoni\Documents\Python\Data\final_viewpoint.xlsx', index=False)
