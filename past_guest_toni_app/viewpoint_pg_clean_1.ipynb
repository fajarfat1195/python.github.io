# %%
import pandas as pd
import re

import past_guest_module as pm

import sys
sys.path.append('../zoho_data_app/')

import main_module as m

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
path = r'C:\Users\fajar.fatoni\Documents\Python\Data\Past Guest Data\View Point\2025\Oct\19 Oct - 27 Oct\CheckOutReport 19 Oct - 27 Oct.xlsx'
# path = r'C:\Users\fajar.fatoni\Documents\Python\Data\CheckOutReport KBorgo.xlsx'
df_viewpoint = pd.read_excel(path, dtype='string', sheet_name='Sheet1')
count_data_awal = df_viewpoint.shape[0]
df_viewpoint
# Out:
#          Title         Firstname          lastname   DOB PAN CARD Email Phone  \
# 0     ADV(MR).             Vinay            Siwach  <NA>     <NA>     .     .
# 1     ADV(MR).             Vinay            Siwach  <NA>     <NA>     .     .
# 2     ADV(MR).             Vinay            Siwach  <NA>     <NA>     .     .
# 3     ADV(MR).             Vinay            Siwach  <NA>     <NA>     .     .
# 4     ADV(MR).             Vinay            Siwach  <NA>     <NA>     .     .
# ...        ...               ...               ...   ...      ...   ...   ...
# 2289         -           Armenie          Goryagos  <NA>     <NA>  <NA>  <NA>
# 2290         -          Blandine  De saint andrieu  <NA>     <NA>  <NA>  <NA>
# 2291      <NA>  Christophe Morel    Morel d'Arleux  <NA>     <NA>  <NA>  <NA>
# 2292         -           Tatiana            Nzundu  <NA>     <NA>  <NA>  <NA>
# 2293       krg      Fajar Fatoni                86  <NA>     <NA>  <NA>  <NA>
#
#      Mobile AddressLine1 AddressLine2  ...          CheckInDate  \
# 0         .            .            .  ...  2025-10-17 16:05:03
# 1         .            .            .  ...  2025-10-19 19:17:33
# 2         .            .            .  ...  2025-10-20 14:59:01
# 3         .            .            .  ...  2025-10-22 10:50:18
# 4         .            .            .  ...  2025-10-23 12:04:19
# ...     ...          ...          ...  ...                  ...
# 2289   <NA>         <NA>         <NA>  ...  2025-10-25 21:38:24
# 2290   <NA>         <NA>         <NA>  ...  2025-10-26 00:40:02
# 2291   <NA>         <NA>         <NA>  ...  2025-10-26 08:36:45
# 2292   <NA>         <NA>         <NA>  ...  2025-10-26 01:20:37
# 2293   <NA>         <NA>         <NA>  ...                 <NA>
#
#              CheckOutDate  room         UnitCategory BookingNo  \
# 0     2025-10-19 17:30:04   104    Hotel Unit Double   2976466
# 1     2025-10-20 14:48:50   104    Hotel Unit Double   2992023
# 2     2025-10-22 10:49:56   104    Hotel Unit Double   2976467
# 3     2025-10-23 12:00:40   104    Hotel Unit Double   2976657
# 4     2025-10-24 09:58:40   104    Hotel Unit Double   2995069
# ...                   ...   ...                  ...       ...
# 2289  2025-10-26 17:30:11   213  2 Bedroom Apartment   2995712
# 2290  2025-10-26 17:41:36   112     Studio Apartment   2995770
# 2291  2025-10-26 17:41:40   121     Studio Apartment   2995732
# 2292  2025-10-26 21:58:06   201  3 Bedroom Apartment   2995798
# 2293                 <NA>  <NA>                 <NA>      <NA>
#
#      BookingSourceDesc BookingTypeDesc Date of Tour Sales Rep and Comments  \
# 0                STAFF     Staff Karma         <NA>                   <NA>
# 1                STAFF     Staff Karma         <NA>                   <NA>
# 2                STAFF     Staff Karma         <NA>                   <NA>
# 3                STAFF     Staff Karma         <NA>                   <NA>
# 4                STAFF     Staff Karma         <NA>                   <NA>
# ...                ...             ...          ...                    ...
# 2289    Hotel Bookings         Expedia         <NA>                   <NA>
# 2290    Hotel Bookings     Booking.com         <NA>                   <NA>
# 2291    Hotel Bookings     Booking.com         <NA>                   <NA>
# 2292    Hotel Bookings     Booking.com         <NA>                   <NA>
# 2293              <NA>            <NA>         <NA>                   <NA>
#
#      Opt In
# 0       YES
# 1       YES
# 2       YES
# 3       YES
# 4       YES
# ...     ...
# 2289    YES
# 2290    YES
# 2291    YES
# 2292    YES
# 2293   <NA>
#
# [2294 rows x 29 columns]

# %%
df_viewpoint.columns
# Out:
# Index(['Title', 'Firstname', 'lastname', 'DOB', 'PAN CARD', 'Email', 'Phone',
#        'Mobile', 'AddressLine1', 'AddressLine2', 'Town', 'State', 'Country',
#        'PostCode', 'Nationality', 'MaritalStatus', 'resortname', 'Arrival',
#        'Departure', 'CheckInDate', 'CheckOutDate', 'room', 'UnitCategory',
#        'BookingNo', 'BookingSourceDesc', 'BookingTypeDesc', 'Date of Tour',
#        'Sales Rep and Comments', 'Opt In'],
#       dtype='object')

# %%
df_viewpoint.fillna('empty', inplace=True)

df_viewpoint['Contact Type'] = 'empty'
df_viewpoint['Odyssey Members'] = 'NO'

df_viewpoint['Lead Brand'] = 'Karma Resorts'
df_viewpoint['Lead Sub-Brand'] = 'Other'
df_viewpoint['Lead Source'] = 'Past Guests'
df_viewpoint['Lead Locations'] = df_viewpoint['resortname']
df_viewpoint['Lead Source Description'] = 'Viewpoint'

# %%
df_viewpoint.loc[df_viewpoint['Opt In'] == 'YES', 'Exclude From Mailing'] = 'NO'
df_viewpoint.loc[df_viewpoint['Opt In'] == 'NO', 'Exclude From Mailing'] = 'YES'

# %%
df_viewpoint.loc[df_viewpoint['lastname'] == 'empty', 'lastname'] = '-'

# %%
df_viewpoint['Title'].replace('empty', '', inplace=True)
df_viewpoint['Firstname'].replace('empty', '', inplace=True)
df_viewpoint['lastname'].replace('empty', '', inplace=True)

df_viewpoint['Title'] = df_viewpoint['Title'].str.title()
df_viewpoint['Firstname'] = df_viewpoint['Firstname'].str.title()
df_viewpoint['lastname'] = df_viewpoint['lastname'].str.title()

df_viewpoint
# Out:
# C:\Users\fajar.fatoni\AppData\Local\Temp\ipykernel_24464\3404343493.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_viewpoint['Title'].replace('empty', '', inplace=True)
# C:\Users\fajar.fatoni\AppData\Local\Temp\ipykernel_24464\3404343493.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_viewpoint['Firstname'].replace('empty', '', inplace=True)
# C:\Users\fajar.fatoni\AppData\Local\Temp\ipykernel_24464\3404343493.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_viewpoint['lastname'].replace('empty', '', inplace=True)
#          Title         Firstname          lastname    DOB PAN CARD  Email  \
# 0     Adv(Mr).             Vinay            Siwach  empty    empty      .
# 1     Adv(Mr).             Vinay            Siwach  empty    empty      .
# 2     Adv(Mr).             Vinay            Siwach  empty    empty      .
# 3     Adv(Mr).             Vinay            Siwach  empty    empty      .
# 4     Adv(Mr).             Vinay            Siwach  empty    empty      .
# ...        ...               ...               ...    ...      ...    ...
# 2289         -           Armenie          Goryagos  empty    empty  empty
# 2290         -          Blandine  De Saint Andrieu  empty    empty  empty
# 2291            Christophe Morel    Morel D'Arleux  empty    empty  empty
# 2292         -           Tatiana            Nzundu  empty    empty  empty
# 2293       Krg      Fajar Fatoni                86  empty    empty  empty
#
#       Phone Mobile AddressLine1 AddressLine2  ... Sales Rep and Comments  \
# 0         .      .            .            .  ...                  empty
# 1         .      .            .            .  ...                  empty
# 2         .      .            .            .  ...                  empty
# 3         .      .            .            .  ...                  empty
# 4         .      .            .            .  ...                  empty
# ...     ...    ...          ...          ...  ...                    ...
# 2289  empty  empty        empty        empty  ...                  empty
# 2290  empty  empty        empty        empty  ...                  empty
# 2291  empty  empty        empty        empty  ...                  empty
# 2292  empty  empty        empty        empty  ...                  empty
# 2293  empty  empty        empty        empty  ...                  empty
#
#      Opt In Contact Type Odyssey Members     Lead Brand Lead Sub-Brand  \
# 0       YES        empty              NO  Karma Resorts          Other
# 1       YES        empty              NO  Karma Resorts          Other
# 2       YES        empty              NO  Karma Resorts          Other
# 3       YES        empty              NO  Karma Resorts          Other
# 4       YES        empty              NO  Karma Resorts          Other
# ...     ...          ...             ...            ...            ...
# 2289    YES        empty              NO  Karma Resorts          Other
# 2290    YES        empty              NO  Karma Resorts          Other
# 2291    YES        empty              NO  Karma Resorts          Other
# 2292    YES        empty              NO  Karma Resorts          Other
# 2293  empty        empty              NO  Karma Resorts          Other
#
#       Lead Source                     Lead Locations Lead Source Description  \
# 0     Past Guests               Karma Munnar, Kerala               Viewpoint
# 1     Past Guests               Karma Munnar, Kerala               Viewpoint
# 2     Past Guests               Karma Munnar, Kerala               Viewpoint
# 3     Past Guests               Karma Munnar, Kerala               Viewpoint
# 4     Past Guests               Karma Munnar, Kerala               Viewpoint
# ...           ...                                ...                     ...
# 2289  Past Guests  Wyndham -  Manoir des Deux Amants               Viewpoint
# 2290  Past Guests  Wyndham -  Manoir des Deux Amants               Viewpoint
# 2291  Past Guests  Wyndham -  Manoir des Deux Amants               Viewpoint
# 2292  Past Guests  Wyndham -  Manoir des Deux Amants               Viewpoint
# 2293  Past Guests                              empty               Viewpoint
#
#      Exclude From Mailing
# 0                      NO
# 1                      NO
# 2                      NO
# 3                      NO
# 4                      NO
# ...                   ...
# 2289                   NO
# 2290                   NO
# 2291                   NO
# 2292                   NO
# 2293                  NaN
#
# [2294 rows x 37 columns]

# %%
m.clean_number(df_viewpoint, 'Phone')
m.clean_number(df_viewpoint, 'Mobile')
m.replace_not_valid_to_empty(df_viewpoint, 'Phone')
m.replace_not_valid_to_empty(df_viewpoint, 'Mobile')

df_viewpoint.loc[df_viewpoint['Phone'].str.contains('00000'), 'Phone'] = 'empty'
df_viewpoint.loc[df_viewpoint['Mobile'].str.contains('00000'), 'Mobile'] = 'empty'

m.clean_space(df_viewpoint, 'Email')
df_viewpoint['Email'] = m.lowercase(df_viewpoint, 'Email')
m.email_correction(df_viewpoint, 'Email')
# Out:
# c:\Users\fajar.fatoni\Documents\Python\Task Offline\past_guest_toni_app\../zoho_data_app\main_module.py:104: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[df_columns].replace(' ','', regex=True, inplace=True)
# c:\Users\fajar.fatoni\Documents\Python\Task Offline\past_guest_toni_app\../zoho_data_app\main_module.py:105: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[df_columns].replace('[^0-9]','', regex=True, inplace=True)
# c:\Users\fajar.fatoni\Documents\Python\Task Offline\past_guest_toni_app\../zoho_data_app\main_module.py:127: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[df_columns].replace(' ','', regex=True, inplace=True)
# c:\Users\fajar.fatoni\Documents\Python\Task Offline\past_guest_toni_app\../zoho_data_app\main_module.py:271: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[df_columns].replace('^mailto:|-primary$|-pri$|-Mrs$|(noemailtobesent)$','', regex=True, inplace=True)
# c:\Users\fajar.fatoni\Documents\Python\Task Offline\past_guest_toni_app\../zoho_data_app\main_module.py:299: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[df_columns].replace('|'.join(list_correction_mail), '@mail.', regex=True, inplace=True)
# c:\Users\fajar.fatoni\Documents\Python\Task Offline\past_guest_toni_app\../zoho_data_app\main_module.py:300: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[df_columns].replace('|'.join(list_correction_gmail), '@gmail.', regex=True, inplace=True)
# c:\Users\fajar.fatoni\Documents\Python\Task Offline\past_guest_toni_app\../zoho_data_app\main_module.py:301: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[df_columns].replace('|'.join(list_correction_gmail_com), '@gmail.com', regex=True, inplace=True)
# c:\Users\fajar.fatoni\Documents\Python\Task Offline\past_guest_toni_app\../zoho_data_app\main_module.py:302: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[df_columns].replace('|'.join(list_correction_hotmail), '@hotmail.', regex=True, inplace=True)
# c:\Users\fajar.fatoni\Documents\Python\Task Offline\past_guest_toni_app\../zoho_data_app\main_module.py:303: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[df_columns].replace('|'.join(list_correction_hotmail_com), '@hotmail.com', regex=True, inplace=True)
# c:\Users\fajar.fatoni\Documents\Python\Task Offline\past_guest_toni_app\../zoho_data_app\main_module.py:304: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[df_columns].replace('|'.join(list_correction_yahoo_com), '@yahoo.com', regex=True, inplace=True)
# c:\Users\fajar.fatoni\Documents\Python\Task Offline\past_guest_toni_app\../zoho_data_app\main_module.py:305: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[df_columns].replace('|'.join(list_correction_yahoo), '@yahoo.', regex=True, inplace=True)
# c:\Users\fajar.fatoni\Documents\Python\Task Offline\past_guest_toni_app\../zoho_data_app\main_module.py:306: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[df_columns].replace('|'.join(list_correction_yahoo_in), '@yahoo.co.in', regex=True, inplace=True)
# c:\Users\fajar.fatoni\Documents\Python\Task Offline\past_guest_toni_app\../zoho_data_app\main_module.py:321: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[df_columns].loc[~df[df_columns].str.contains('@', df_columns, na=False)] = 'empty'

# %%
df_viewpoint
# Out:
#          Title         Firstname          lastname    DOB PAN CARD  Email  \
# 0     Adv(Mr).             Vinay            Siwach  empty    empty  empty
# 1     Adv(Mr).             Vinay            Siwach  empty    empty  empty
# 2     Adv(Mr).             Vinay            Siwach  empty    empty  empty
# 3     Adv(Mr).             Vinay            Siwach  empty    empty  empty
# 4     Adv(Mr).             Vinay            Siwach  empty    empty  empty
# ...        ...               ...               ...    ...      ...    ...
# 2289         -           Armenie          Goryagos  empty    empty  empty
# 2290         -          Blandine  De Saint Andrieu  empty    empty  empty
# 2291            Christophe Morel    Morel D'Arleux  empty    empty  empty
# 2292         -           Tatiana            Nzundu  empty    empty  empty
# 2293       Krg      Fajar Fatoni                86  empty    empty  empty
#
#       Phone Mobile AddressLine1 AddressLine2  ... Sales Rep and Comments  \
# 0     empty  empty            .            .  ...                  empty
# 1     empty  empty            .            .  ...                  empty
# 2     empty  empty            .            .  ...                  empty
# 3     empty  empty            .            .  ...                  empty
# 4     empty  empty            .            .  ...                  empty
# ...     ...    ...          ...          ...  ...                    ...
# 2289  empty  empty        empty        empty  ...                  empty
# 2290  empty  empty        empty        empty  ...                  empty
# 2291  empty  empty        empty        empty  ...                  empty
# 2292  empty  empty        empty        empty  ...                  empty
# 2293  empty  empty        empty        empty  ...                  empty
#
#      Opt In Contact Type Odyssey Members     Lead Brand Lead Sub-Brand  \
# 0       YES        empty              NO  Karma Resorts          Other
# 1       YES        empty              NO  Karma Resorts          Other
# 2       YES        empty              NO  Karma Resorts          Other
# 3       YES        empty              NO  Karma Resorts          Other
# 4       YES        empty              NO  Karma Resorts          Other
# ...     ...          ...             ...            ...            ...
# 2289    YES        empty              NO  Karma Resorts          Other
# 2290    YES        empty              NO  Karma Resorts          Other
# 2291    YES        empty              NO  Karma Resorts          Other
# 2292    YES        empty              NO  Karma Resorts          Other
# 2293  empty        empty              NO  Karma Resorts          Other
#
#       Lead Source                     Lead Locations Lead Source Description  \
# 0     Past Guests               Karma Munnar, Kerala               Viewpoint
# 1     Past Guests               Karma Munnar, Kerala               Viewpoint
# 2     Past Guests               Karma Munnar, Kerala               Viewpoint
# 3     Past Guests               Karma Munnar, Kerala               Viewpoint
# 4     Past Guests               Karma Munnar, Kerala               Viewpoint
# ...           ...                                ...                     ...
# 2289  Past Guests  Wyndham -  Manoir des Deux Amants               Viewpoint
# 2290  Past Guests  Wyndham -  Manoir des Deux Amants               Viewpoint
# 2291  Past Guests  Wyndham -  Manoir des Deux Amants               Viewpoint
# 2292  Past Guests  Wyndham -  Manoir des Deux Amants               Viewpoint
# 2293  Past Guests                              empty               Viewpoint
#
#      Exclude From Mailing
# 0                      NO
# 1                      NO
# 2                      NO
# 3                      NO
# 4                      NO
# ...                   ...
# 2289                   NO
# 2290                   NO
# 2291                   NO
# 2292                   NO
# 2293                  NaN
#
# [2294 rows x 37 columns]

# %%
df_viewpoint.loc[(df_viewpoint['Email'] != 'empty') & ((df_viewpoint['Phone'] != 'empty') | (df_viewpoint['Mobile'] != 'empty')), 'Contact Type'] = 'Email and Phone'
df_viewpoint.loc[(df_viewpoint['Email'] != 'empty') & ((df_viewpoint['Phone'] == 'empty') & (df_viewpoint['Mobile'] == 'empty')), 'Contact Type'] = 'Email Only'
df_viewpoint.loc[(df_viewpoint['Email'] == 'empty') & ((df_viewpoint['Phone'] != 'empty') | (df_viewpoint['Mobile'] != 'empty')), 'Contact Type'] = 'Phone Only'

df_viewpoint.loc[df_viewpoint['Contact Type'] == 'empty'].to_csv(r'C:\Users\fajar.fatoni\Documents\Python\Data\contact_type_empty_viewpoint.csv', index=False)

count_contact_type_empty = df_viewpoint.loc[df_viewpoint['Contact Type'] == 'empty'].shape[0]

df_viewpoint.drop(df_viewpoint.loc[df_viewpoint['Contact Type'] == 'empty'].index, inplace=True)
df_viewpoint.reset_index(drop=True, inplace=True)

count_after_contact_type_empty = df_viewpoint.shape[0]

df_viewpoint
# Out:
#      Title   Firstname   lastname                  DOB PAN CARD  \
# 0       Mr      Ashley    Noronha                empty    empty
# 1      Mrs      Alison      Davey  1973-09-01 00:00:00    empty
# 2       Mr         Luo        Jia  1984-10-24 00:00:00    empty
# 3       Ms     Zhu/Ran    Zhu/Ran                empty    empty
# 4       Mr        Chen   Xiaoling  1995-10-11 00:00:00    empty
# ...    ...         ...        ...                  ...      ...
# 2175     -  Christophe    Bouguin                empty    empty
# 2176    Mr     Valance      Kevin  1991-08-30 00:00:00    empty
# 2177     -    Mathilda  Montedoro                empty    empty
# 2178     -  Christophe    Bouguin                empty    empty
# 2179     -      Émilie     Ravaux                empty    empty
#
#                            Email          Phone        Mobile  \
# 0     1992davidnoronha@gmail.com   918322741331  918308496243
# 1            1madmummy@gmail.com   447534515926         empty
# 2                46498332@qq.com  8618681802787         empty
# 3               503753015@99.com  6285239098666         empty
# 4               610915567@qq.com  8617600405789         empty
# ...                          ...            ...           ...
# 2175                       empty    33683815693         empty
# 2176                       empty    33638528645         empty
# 2177                       empty    33624665871         empty
# 2178                       empty    33683815693         empty
# 2179                       empty    33614227269         empty
#
#                   AddressLine1     AddressLine2  ... Sales Rep and Comments  \
# 0     FLAT NO F4, NORONHA APTS  FATORDA SALCETE  ...                  empty
# 1                        empty            empty  ...              Elizabeth
# 2                            -            empty  ...                  empty
# 3                            -                -  ...                  empty
# 4                            -            empty  ...                  empty
# ...                        ...              ...  ...                    ...
# 2175                     empty            empty  ...                  empty
# 2176          6 cour du chenil            empty  ...                  empty
# 2177                         .            empty  ...                  empty
# 2178                     empty            empty  ...                  empty
# 2179                     empty            empty  ...                  empty
#
#      Opt In     Contact Type Odyssey Members     Lead Brand Lead Sub-Brand  \
# 0       YES  Email and Phone              NO  Karma Resorts          Other
# 1       YES  Email and Phone              NO  Karma Resorts          Other
# 2       YES  Email and Phone              NO  Karma Resorts          Other
# 3       YES  Email and Phone              NO  Karma Resorts          Other
# 4       YES  Email and Phone              NO  Karma Resorts          Other
# ...     ...              ...             ...            ...            ...
# 2175    YES       Phone Only              NO  Karma Resorts          Other
# 2176    YES       Phone Only              NO  Karma Resorts          Other
# 2177    YES       Phone Only              NO  Karma Resorts          Other
# 2178    YES       Phone Only              NO  Karma Resorts          Other
# 2179    YES       Phone Only              NO  Karma Resorts          Other
#
#       Lead Source                     Lead Locations Lead Source Description  \
# 0     Past Guests                  Karma Royal Palms               Viewpoint
# 1     Past Guests             Karma Lake of Menteith               Viewpoint
# 2     Past Guests                     Karma Jimbaran               Viewpoint
# 3     Past Guests                     Karma Jimbaran               Viewpoint
# 4     Past Guests                     Karma Jimbaran               Viewpoint
# ...           ...                                ...                     ...
# 2175  Past Guests  Wyndham -  Manoir des Deux Amants               Viewpoint
# 2176  Past Guests  Wyndham -  Manoir des Deux Amants               Viewpoint
# 2177  Past Guests  Wyndham -  Manoir des Deux Amants               Viewpoint
# 2178  Past Guests  Wyndham -  Manoir des Deux Amants               Viewpoint
# 2179  Past Guests  Wyndham -  Manoir des Deux Amants               Viewpoint
#
#      Exclude From Mailing
# 0                      NO
# 1                      NO
# 2                      NO
# 3                      NO
# 4                      NO
# ...                   ...
# 2175                   NO
# 2176                   NO
# 2177                   NO
# 2178                   NO
# 2179                   NO
#
# [2180 rows x 37 columns]

# %%
# Cek Email Karma
email_karma = m.find_karma(df_viewpoint, 'Email')
count_email_karma = email_karma.shape[0]
email_karma.to_csv(r'C:\Users\fajar.fatoni\Documents\Python\Data\email_deleted_viewpoint.csv', index=False)

email_karma
# Out:
#      Title    Firstname  lastname                  DOB PAN CARD  \
# 93     Mrs    Elizabeth   Roberts                empty    empty
# 818     Mr  John Andrew    Spence  1961-02-23 00:00:00    empty
# 1986    Mr          Max    Newton                empty    empty
# 2020    Ms        Tulsi   Prakash                empty    empty
# 2077    Mr       Robert  Faulkner  1960-10-27 00:00:00    empty
#
#                                Email         Phone        Mobile  \
# 93    andrea.pavlidis@karmagroup.com         empty         empty
# 818         johnspence88@hotmail.com         empty         empty
# 1986     tety.ginting@karmagroup.com   12039971804         empty
# 2020     tulsiprakash@karmagroup.com  918091005800         empty
# 2077     vic.faulkner@karmagroup.com  628113974868  919630852741
#
#                                 AddressLine1        AddressLine2  ...  \
# 93                                     empty               empty  ...
# 818   JL. BY PASS NGURAH RAI NO.61, PEMOGAN,  KEC. DENPASAR SEL.  ...
# 1986                           INHOUSE STAFF               empty  ...
# 2020        KARMA ROYAL MONTERIO ARPORA BAGA               empty  ...
# 2077         VILLA KASBAH, JL. BUMBAK, NO.14   UMALAS, KEROBOKAN  ...
#
#      Sales Rep and Comments Opt In     Contact Type Odyssey Members  \
# 93                    empty    YES       Email Only              NO
# 818                   empty    YES       Email Only              NO
# 1986                  empty    YES  Email and Phone              NO
# 2020                  empty    YES  Email and Phone              NO
# 2077                  empty     NO  Email and Phone              NO
#
#          Lead Brand Lead Sub-Brand  Lead Source  \
# 93    Karma Resorts          Other  Past Guests
# 818   Karma Resorts          Other  Past Guests
# 1986  Karma Resorts          Other  Past Guests
# 2020  Karma Resorts          Other  Past Guests
# 2077  Karma Resorts          Other  Past Guests
#
#                       Lead Locations Lead Source Description  \
# 93                Karma Salford Hall               Viewpoint
# 818   Chateau de Samary, Carcassonne               Viewpoint
# 1986        Karma Panalee, Koh Samui               Viewpoint
# 2020               Karma Royal Palms               Viewpoint
# 2077           Karma Royal Candidasa               Viewpoint
#
#      Exclude From Mailing
# 93                     NO
# 818                    NO
# 1986                   NO
# 2020                   NO
# 2077                  YES
#
# [5 rows x 37 columns]

# %%
# delete email Karma
count_after_clean_karma = m.delete_karma(df_viewpoint, 'Email')

df_viewpoint
# Out:
#      Title   Firstname   lastname                  DOB PAN CARD  \
# 0       Mr      Ashley    Noronha                empty    empty
# 1      Mrs      Alison      Davey  1973-09-01 00:00:00    empty
# 2       Mr         Luo        Jia  1984-10-24 00:00:00    empty
# 3       Ms     Zhu/Ran    Zhu/Ran                empty    empty
# 4       Mr        Chen   Xiaoling  1995-10-11 00:00:00    empty
# ...    ...         ...        ...                  ...      ...
# 2170     -  Christophe    Bouguin                empty    empty
# 2171    Mr     Valance      Kevin  1991-08-30 00:00:00    empty
# 2172     -    Mathilda  Montedoro                empty    empty
# 2173     -  Christophe    Bouguin                empty    empty
# 2174     -      Émilie     Ravaux                empty    empty
#
#                            Email          Phone        Mobile  \
# 0     1992davidnoronha@gmail.com   918322741331  918308496243
# 1            1madmummy@gmail.com   447534515926         empty
# 2                46498332@qq.com  8618681802787         empty
# 3               503753015@99.com  6285239098666         empty
# 4               610915567@qq.com  8617600405789         empty
# ...                          ...            ...           ...
# 2170                       empty    33683815693         empty
# 2171                       empty    33638528645         empty
# 2172                       empty    33624665871         empty
# 2173                       empty    33683815693         empty
# 2174                       empty    33614227269         empty
#
#                   AddressLine1     AddressLine2  ... Sales Rep and Comments  \
# 0     FLAT NO F4, NORONHA APTS  FATORDA SALCETE  ...                  empty
# 1                        empty            empty  ...              Elizabeth
# 2                            -            empty  ...                  empty
# 3                            -                -  ...                  empty
# 4                            -            empty  ...                  empty
# ...                        ...              ...  ...                    ...
# 2170                     empty            empty  ...                  empty
# 2171          6 cour du chenil            empty  ...                  empty
# 2172                         .            empty  ...                  empty
# 2173                     empty            empty  ...                  empty
# 2174                     empty            empty  ...                  empty
#
#      Opt In     Contact Type Odyssey Members     Lead Brand Lead Sub-Brand  \
# 0       YES  Email and Phone              NO  Karma Resorts          Other
# 1       YES  Email and Phone              NO  Karma Resorts          Other
# 2       YES  Email and Phone              NO  Karma Resorts          Other
# 3       YES  Email and Phone              NO  Karma Resorts          Other
# 4       YES  Email and Phone              NO  Karma Resorts          Other
# ...     ...              ...             ...            ...            ...
# 2170    YES       Phone Only              NO  Karma Resorts          Other
# 2171    YES       Phone Only              NO  Karma Resorts          Other
# 2172    YES       Phone Only              NO  Karma Resorts          Other
# 2173    YES       Phone Only              NO  Karma Resorts          Other
# 2174    YES       Phone Only              NO  Karma Resorts          Other
#
#       Lead Source                     Lead Locations Lead Source Description  \
# 0     Past Guests                  Karma Royal Palms               Viewpoint
# 1     Past Guests             Karma Lake of Menteith               Viewpoint
# 2     Past Guests                     Karma Jimbaran               Viewpoint
# 3     Past Guests                     Karma Jimbaran               Viewpoint
# 4     Past Guests                     Karma Jimbaran               Viewpoint
# ...           ...                                ...                     ...
# 2170  Past Guests  Wyndham -  Manoir des Deux Amants               Viewpoint
# 2171  Past Guests  Wyndham -  Manoir des Deux Amants               Viewpoint
# 2172  Past Guests  Wyndham -  Manoir des Deux Amants               Viewpoint
# 2173  Past Guests  Wyndham -  Manoir des Deux Amants               Viewpoint
# 2174  Past Guests  Wyndham -  Manoir des Deux Amants               Viewpoint
#
#      Exclude From Mailing
# 0                      NO
# 1                      NO
# 2                      NO
# 3                      NO
# 4                      NO
# ...                   ...
# 2170                   NO
# 2171                   NO
# 2172                   NO
# 2173                   NO
# 2174                   NO
#
# [2175 rows x 37 columns]

# %%
# Cek leads test
test_leads = df_viewpoint.loc[
    
        df_viewpoint['Email'].str.contains('^test@', flags=re.I, regex=True) |
        df_viewpoint['Email'].str.contains('\+test', flags=re.I, regex=True) |
    
        df_viewpoint['Firstname'].str.contains('^test$', flags=re.I, regex=True) |
        df_viewpoint['lastname'].str.contains('^test$', flags=re.I, regex=True) |

        df_viewpoint['Firstname'].str.contains('test 1', flags=re.I, regex=True) |
        df_viewpoint['lastname'].str.contains('test 2', flags=re.I, regex=True)|
        df_viewpoint['Firstname'].str.contains('test1', flags=re.I, regex=True) |
        df_viewpoint['lastname'].str.contains('test2', flags=re.I, regex=True)|

        df_viewpoint['Firstname'].str.contains(' test ', flags=re.I, regex=True) | 
        df_viewpoint['lastname'].str.contains(' test ', flags=re.I, regex=True) | 
        df_viewpoint['lastname'].str.contains(' test$', flags=re.I, regex=True)
    ]

count_leads_test = test_leads.shape[0]

test_leads.to_csv(r'C:\Users\fajar.fatoni\Documents\Python\Data\test_leads_viewpoint.csv', index=False)
test_leads
# Out:
# Empty DataFrame
# Columns: [Title, Firstname, lastname, DOB, PAN CARD, Email, Phone, Mobile, AddressLine1, AddressLine2, Town, State, Country, PostCode, Nationality, MaritalStatus, resortname, Arrival, Departure, CheckInDate, CheckOutDate, room, UnitCategory, BookingNo, BookingSourceDesc, BookingTypeDesc, Date of Tour, Sales Rep and Comments, Opt In, Contact Type, Odyssey Members, Lead Brand, Lead Sub-Brand, Lead Source, Lead Locations, Lead Source Description, Exclude From Mailing]
# Index: []
#
# [0 rows x 37 columns]

# %%
df_viewpoint.drop(test_leads.index, inplace=True)
df_viewpoint.reset_index(drop=True, inplace=True)

count_after_dedup_test = df_viewpoint.shape[0]
count_after_dedup_test
# Out:
# 2175

# %%
count_final_data = count_after_dedup_test

# %%
# df_viewpoint.loc[df_viewpoint['BookingNo'] == '2070341']

# %%
df_viewpoint.replace('empty', '', inplace=True)

# %%
print("==========================================================")
print("Summary")
print("==========================================================")
print("Jumlah Data Awal Viewpoint : "+str(count_data_awal))
print("Jumlah Data Email dan Phone Kosong : "+str(count_contact_type_empty))
print("Jumlah Data Setelah Hapus Email dan Phone Yang Kosong : "+str(count_after_contact_type_empty))
print("Jumlah Data Email Yang Termasuk List Karma : "+str(count_email_karma))
print("Jumlah Data Email Setelah List Karma Dihapus : "+str(count_after_clean_karma))
print("Jumlah Data Test : "+str(count_leads_test))
print("Jumlah Data Email Setelah Data Test Dihapus : "+str(count_after_dedup_test))
print("Jumlah Data Akhir : "+str(count_final_data))
# Out:
# ==========================================================
# Summary
# ==========================================================
# Jumlah Data Awal Viewpoint : 2294
# Jumlah Data Email dan Phone Kosong : 114
# Jumlah Data Setelah Hapus Email dan Phone Yang Kosong : 2180
# Jumlah Data Email Yang Termasuk List Karma : 5
# Jumlah Data Email Setelah List Karma Dihapus : 2175
# Jumlah Data Test : 0
# Jumlah Data Email Setelah Data Test Dihapus : 2175
# Jumlah Data Akhir : 2175

# %%
df_viewpoint.to_excel(r'C:\Users\fajar.fatoni\Documents\Python\Data\check_country_code_viewpoint.xlsx', index=False)
