# %%
import pandas as pd
import re

import past_guest_module as pm

import sys
sys.path.append('../zoho_data_app/')

import main_module as m

# %load_ext autoreload
# %autoreload 2

# %%
path = r'C:\Users\fajar.fatoni\Documents\Python\Data\Past Guest Data\View Point\2025\Jun\1 Jun - 9 Jun\CheckOutReport 1 Jun - 9 Jun.xlsx'
df_viewpoint = pd.read_excel(path, dtype='string', sheet_name='Sheet1')
count_data_awal = df_viewpoint.shape[0]
df_viewpoint
# Out:
#      Title              Firstname     lastname                  DOB  \
# 0       Mr        Vrushali Ganesh        Palav  1985-07-14 00:00:00
# 1       Mr                     S.   Asirvatham  1952-09-13 00:00:00
# 2       Mr                A Edwin  Christopher                 <NA>
# 3       Mr                  Tilak          Raj                 <NA>
# 4       Mr                Yaotong          Lyu  2004-09-14 00:00:00
# ...    ...                    ...          ...                  ...
# 2214  <NA>  Teng, Jamie Chew Meng         <NA>                 <NA>
# 2215     -              Stéphanie      Laroque                 <NA>
# 2216  <NA>               Stephane      Lorentz                 <NA>
# 2217     -                   CARL    KITTELSON                 <NA>
# 2218   krg           Fajar Fatoni           86                 <NA>
#
#                               PAN CARD                      Email  \
# 0     AORPP4861R,AORPP4861R,AHLPC0382M  007.ganeshpalav@gmail.com
# 1                                 <NA>         1952asir@gmail.com
# 2                                 <NA>         1952asir@gmail.com
# 3                                 <NA>             2012@gmail.com
# 4                                 <NA>          2338201705@qq.com
# ...                                ...                        ...
# 2214                              <NA>                       <NA>
# 2215                              <NA>                       <NA>
# 2216                              <NA>                       <NA>
# 2217                              <NA>                       <NA>
# 2218                              <NA>                       <NA>
#
#              Phone        Mobile                                 AddressLine1  \
# 0     919324042146  918411013059                         302, NANDINI CORNER,
# 1     919444951557  919654207066  No.9, Nehru Colony, Kamaraj Nagar P.O Avadi
# 2     919654207066          <NA>  No.9, Nehru Colony, Kamaraj Nagar P.O Avadi
# 3     919971806012          <NA>                       SECTOR 14 HOUSE NO 166
# 4     628113855855          <NA>                                            -
# ...            ...           ...                                          ...
# 2214          <NA>          <NA>                                         <NA>
# 2215          <NA>          <NA>                                         <NA>
# 2216          <NA>          <NA>                                            -
# 2217          <NA>          <NA>                                            -
# 2218          <NA>          <NA>                                         <NA>
#
#                            AddressLine2  ...          CheckInDate  \
# 0     CHAKRADHAR NAGAR, NALASOPARA WEST  ...  2025-05-30 01:40:10
# 1                                  <NA>  ...  2025-05-26 23:42:12
# 2                                  <NA>  ...  2025-05-26 23:45:14
# 3                          RAJ NAGAR UP  ...  2025-05-31 04:13:49
# 4                                  <NA>  ...  2025-06-01 23:22:46
# ...                                 ...  ...                  ...
# 2214                               <NA>  ...  2025-06-01 21:17:15
# 2215                               <NA>  ...  2025-06-07 21:26:36
# 2216                               <NA>  ...  2025-06-08 00:07:52
# 2217                               <NA>  ...  2025-06-06 22:05:37
# 2218                               <NA>  ...                 <NA>
#
#              CheckOutDate    room                    UnitCategory BookingNo  \
# 0     2025-06-01 11:32:35   07(1)             1 Bedroom Apartment   2828525
# 1     2025-06-01 11:07:48     303             Hotel Unit max 1ch.   2739556
# 2     2025-06-01 11:07:54     404             Hotel Unit max 1ch.   2739558
# 3     2025-06-02 14:21:16     503             Hotel Unit max 2ch.   2847267
# 4     2025-06-02 12:17:29  10 - N  3 Bedroom Garden View Pool Vil   2829296
# ...                   ...     ...                             ...       ...
# 2214  2025-06-08 14:51:07     216             1 Bedroom Apartment   2647897
# 2215  2025-06-08 15:50:14     131             2 Bedroom Apartment   2873218
# 2216  2025-06-08 16:19:29     234             1 Bedroom Apartment   2873224
# 2217  2025-06-08 18:02:50     126             1 Bedroom Apartment   2853215
# 2218                 <NA>    <NA>                            <NA>      <NA>
#
#          BookingSourceDesc                   BookingTypeDesc  \
# 0     Karma Club Discovery  Karma Club Discovery Entitlement
# 1                KC Member                Entitlement Member
# 2                KC Member                Entitlement Member
# 3        Member Ambassador                 Member Ambassador
# 4           Hotel Bookings                   Nakula - Rental
# ...                    ...                               ...
# 2214        Hotel Bookings                    Wyndham Guests
# 2215        Hotel Bookings                       Booking.com
# 2216        Hotel Bookings                       Booking.com
# 2217        Hotel Bookings                    Wyndham Guests
# 2218                  <NA>                              <NA>
#
#              Date of Tour Sales Rep and Comments Opt In
# 0                    <NA>                   <NA>    YES
# 1                    <NA>                   <NA>    YES
# 2                    <NA>                   <NA>    YES
# 3     2025-05-31 11:06:00                 shoaib    YES
# 4                    <NA>                   <NA>    YES
# ...                   ...                    ...    ...
# 2214                 <NA>                   <NA>    YES
# 2215                 <NA>                   <NA>    YES
# 2216                 <NA>                   <NA>    YES
# 2217                 <NA>                   <NA>    YES
# 2218                 <NA>                   <NA>   <NA>
#
# [2219 rows x 29 columns]

# %%
df_viewpoint.columns
# Out:
# Index(['Title', 'Firstname', 'lastname', 'DOB', 'PAN CARD', 'Email', 'Phone',
#        'Mobile', 'AddressLine1', 'AddressLine2', 'Town', 'State', 'Country',
#        'PostCode', 'Nationality', 'MaritalStatus', 'resortname', 'Arrival',
#        'Departure', 'CheckInDate', 'CheckOutDate', 'room', 'UnitCategory',
#        'BookingNo', 'BookingSourceDesc', 'BookingTypeDesc', 'Date of Tour',
#        'Sales Rep and Comments', 'Opt In'],
#       dtype='object')

# %%
df_viewpoint.fillna('empty', inplace=True)

df_viewpoint['Contact Type'] = 'empty'
df_viewpoint['Odyssey Members'] = 'NO'

df_viewpoint['Lead Brand'] = 'Karma Resorts'
df_viewpoint['Lead Sub-Brand'] = 'Other'
df_viewpoint['Lead Source'] = 'Past Guests'
df_viewpoint['Lead Locations'] = df_viewpoint['resortname']
df_viewpoint['Lead Source Description'] = 'Viewpoint'

# %%
df_viewpoint.loc[df_viewpoint['Opt In'] == 'YES', 'Exclude From Mailing'] = 'NO'
df_viewpoint.loc[df_viewpoint['Opt In'] == 'NO', 'Exclude From Mailing'] = 'YES'

# %%
df_viewpoint.loc[df_viewpoint['lastname'] == 'empty', 'lastname'] = '-'

# %%
df_viewpoint['Title'].replace('empty', '', inplace=True)
df_viewpoint['Firstname'].replace('empty', '', inplace=True)
df_viewpoint['lastname'].replace('empty', '', inplace=True)

df_viewpoint['Title'] = df_viewpoint['Title'].str.title()
df_viewpoint['Firstname'] = df_viewpoint['Firstname'].str.title()
df_viewpoint['lastname'] = df_viewpoint['lastname'].str.title()

df_viewpoint
# Out:
# C:\Users\fajar.fatoni\AppData\Local\Temp\ipykernel_18624\3404343493.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_viewpoint['Title'].replace('empty', '', inplace=True)
# C:\Users\fajar.fatoni\AppData\Local\Temp\ipykernel_18624\3404343493.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_viewpoint['Firstname'].replace('empty', '', inplace=True)
# C:\Users\fajar.fatoni\AppData\Local\Temp\ipykernel_18624\3404343493.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_viewpoint['lastname'].replace('empty', '', inplace=True)
#      Title              Firstname     lastname                  DOB  \
# 0       Mr        Vrushali Ganesh        Palav  1985-07-14 00:00:00
# 1       Mr                     S.   Asirvatham  1952-09-13 00:00:00
# 2       Mr                A Edwin  Christopher                empty
# 3       Mr                  Tilak          Raj                empty
# 4       Mr                Yaotong          Lyu  2004-09-14 00:00:00
# ...    ...                    ...          ...                  ...
# 2214        Teng, Jamie Chew Meng            -                empty
# 2215     -              Stéphanie      Laroque                empty
# 2216                     Stephane      Lorentz                empty
# 2217     -                   Carl    Kittelson                empty
# 2218   Krg           Fajar Fatoni           86                empty
#
#                               PAN CARD                      Email  \
# 0     AORPP4861R,AORPP4861R,AHLPC0382M  007.ganeshpalav@gmail.com
# 1                                empty         1952asir@gmail.com
# 2                                empty         1952asir@gmail.com
# 3                                empty             2012@gmail.com
# 4                                empty          2338201705@qq.com
# ...                                ...                        ...
# 2214                             empty                      empty
# 2215                             empty                      empty
# 2216                             empty                      empty
# 2217                             empty                      empty
# 2218                             empty                      empty
#
#              Phone        Mobile                                 AddressLine1  \
# 0     919324042146  918411013059                         302, NANDINI CORNER,
# 1     919444951557  919654207066  No.9, Nehru Colony, Kamaraj Nagar P.O Avadi
# 2     919654207066         empty  No.9, Nehru Colony, Kamaraj Nagar P.O Avadi
# 3     919971806012         empty                       SECTOR 14 HOUSE NO 166
# 4     628113855855         empty                                            -
# ...            ...           ...                                          ...
# 2214         empty         empty                                        empty
# 2215         empty         empty                                        empty
# 2216         empty         empty                                            -
# 2217         empty         empty                                            -
# 2218         empty         empty                                        empty
#
#                            AddressLine2  ... Sales Rep and Comments Opt In  \
# 0     CHAKRADHAR NAGAR, NALASOPARA WEST  ...                  empty    YES
# 1                                 empty  ...                  empty    YES
# 2                                 empty  ...                  empty    YES
# 3                          RAJ NAGAR UP  ...                 shoaib    YES
# 4                                 empty  ...                  empty    YES
# ...                                 ...  ...                    ...    ...
# 2214                              empty  ...                  empty    YES
# 2215                              empty  ...                  empty    YES
# 2216                              empty  ...                  empty    YES
# 2217                              empty  ...                  empty    YES
# 2218                              empty  ...                  empty  empty
#
#      Contact Type Odyssey Members     Lead Brand Lead Sub-Brand  Lead Source  \
# 0           empty              NO  Karma Resorts          Other  Past Guests
# 1           empty              NO  Karma Resorts          Other  Past Guests
# 2           empty              NO  Karma Resorts          Other  Past Guests
# 3           empty              NO  Karma Resorts          Other  Past Guests
# 4           empty              NO  Karma Resorts          Other  Past Guests
# ...           ...             ...            ...            ...          ...
# 2214        empty              NO  Karma Resorts          Other  Past Guests
# 2215        empty              NO  Karma Resorts          Other  Past Guests
# 2216        empty              NO  Karma Resorts          Other  Past Guests
# 2217        empty              NO  Karma Resorts          Other  Past Guests
# 2218        empty              NO  Karma Resorts          Other  Past Guests
#
#                          Lead Locations Lead Source Description  \
# 0                     Karma Royal Palms               Viewpoint
# 1                  Karma Munnar, Kerala               Viewpoint
# 2                  Karma Munnar, Kerala               Viewpoint
# 3               Karma Sitabani, Corbett               Viewpoint
# 4                        Karma Jimbaran               Viewpoint
# ...                                 ...                     ...
# 2214  Wyndham -  Manoir des Deux Amants               Viewpoint
# 2215  Wyndham -  Manoir des Deux Amants               Viewpoint
# 2216  Wyndham -  Manoir des Deux Amants               Viewpoint
# 2217  Wyndham -  Manoir des Deux Amants               Viewpoint
# 2218                              empty               Viewpoint
#
#      Exclude From Mailing
# 0                      NO
# 1                      NO
# 2                      NO
# 3                      NO
# 4                      NO
# ...                   ...
# 2214                   NO
# 2215                   NO
# 2216                   NO
# 2217                   NO
# 2218                  NaN
#
# [2219 rows x 37 columns]

# %%
m.clean_number(df_viewpoint, 'Phone')
m.clean_number(df_viewpoint, 'Mobile')
m.replace_not_valid_to_empty(df_viewpoint, 'Phone')
m.replace_not_valid_to_empty(df_viewpoint, 'Mobile')

df_viewpoint.loc[df_viewpoint['Phone'].str.contains('00000'), 'Phone'] = 'empty'
df_viewpoint.loc[df_viewpoint['Mobile'].str.contains('00000'), 'Mobile'] = 'empty'

m.clean_space(df_viewpoint, 'Email')
df_viewpoint['Email'] = m.lowercase(df_viewpoint, 'Email')
m.email_correction(df_viewpoint, 'Email')
# Out:
# c:\Users\fajar.fatoni\Documents\Python\Task Offline\past_guest_toni_app\../zoho_data_app\main_module.py:71: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[df_columns].replace(' ','', regex=True, inplace=True)
# c:\Users\fajar.fatoni\Documents\Python\Task Offline\past_guest_toni_app\../zoho_data_app\main_module.py:72: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[df_columns].replace('[^0-9]','', regex=True, inplace=True)
# c:\Users\fajar.fatoni\Documents\Python\Task Offline\past_guest_toni_app\../zoho_data_app\main_module.py:94: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[df_columns].replace(' ','', regex=True, inplace=True)
# c:\Users\fajar.fatoni\Documents\Python\Task Offline\past_guest_toni_app\../zoho_data_app\main_module.py:227: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[df_columns].replace('^mailto:|-primary$|-pri$|-Mrs$|(noemailtobesent)$','', regex=True, inplace=True)
# c:\Users\fajar.fatoni\Documents\Python\Task Offline\past_guest_toni_app\../zoho_data_app\main_module.py:255: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[df_columns].replace('|'.join(list_correction_mail), '@mail.', regex=True, inplace=True)
# c:\Users\fajar.fatoni\Documents\Python\Task Offline\past_guest_toni_app\../zoho_data_app\main_module.py:256: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[df_columns].replace('|'.join(list_correction_gmail), '@gmail.', regex=True, inplace=True)
# c:\Users\fajar.fatoni\Documents\Python\Task Offline\past_guest_toni_app\../zoho_data_app\main_module.py:257: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[df_columns].replace('|'.join(list_correction_gmail_com), '@gmail.com', regex=True, inplace=True)
# c:\Users\fajar.fatoni\Documents\Python\Task Offline\past_guest_toni_app\../zoho_data_app\main_module.py:258: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[df_columns].replace('|'.join(list_correction_hotmail), '@hotmail.', regex=True, inplace=True)
# c:\Users\fajar.fatoni\Documents\Python\Task Offline\past_guest_toni_app\../zoho_data_app\main_module.py:259: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[df_columns].replace('|'.join(list_correction_hotmail_com), '@hotmail.com', regex=True, inplace=True)
# c:\Users\fajar.fatoni\Documents\Python\Task Offline\past_guest_toni_app\../zoho_data_app\main_module.py:260: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[df_columns].replace('|'.join(list_correction_yahoo_com), '@yahoo.com', regex=True, inplace=True)
# c:\Users\fajar.fatoni\Documents\Python\Task Offline\past_guest_toni_app\../zoho_data_app\main_module.py:261: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[df_columns].replace('|'.join(list_correction_yahoo), '@yahoo.', regex=True, inplace=True)
# c:\Users\fajar.fatoni\Documents\Python\Task Offline\past_guest_toni_app\../zoho_data_app\main_module.py:262: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[df_columns].replace('|'.join(list_correction_yahoo_in), '@yahoo.co.in', regex=True, inplace=True)
# c:\Users\fajar.fatoni\Documents\Python\Task Offline\past_guest_toni_app\../zoho_data_app\main_module.py:277: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[df_columns].loc[~df[df_columns].str.contains('@', df_columns, na=False)] = ''

# %%
m.email_correction(df_viewpoint, 'Email')
# Out:
# c:\Users\fajar.fatoni\Documents\Python\Task Offline\past_guest_toni_app\../zoho_data_app\main_module.py:227: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[df_columns].replace('^mailto:|-primary$|-pri$|-Mrs$|(noemailtobesent)$','', regex=True, inplace=True)
# c:\Users\fajar.fatoni\Documents\Python\Task Offline\past_guest_toni_app\../zoho_data_app\main_module.py:255: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[df_columns].replace('|'.join(list_correction_mail), '@mail.', regex=True, inplace=True)
# c:\Users\fajar.fatoni\Documents\Python\Task Offline\past_guest_toni_app\../zoho_data_app\main_module.py:256: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[df_columns].replace('|'.join(list_correction_gmail), '@gmail.', regex=True, inplace=True)
# c:\Users\fajar.fatoni\Documents\Python\Task Offline\past_guest_toni_app\../zoho_data_app\main_module.py:257: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[df_columns].replace('|'.join(list_correction_gmail_com), '@gmail.com', regex=True, inplace=True)
# c:\Users\fajar.fatoni\Documents\Python\Task Offline\past_guest_toni_app\../zoho_data_app\main_module.py:258: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[df_columns].replace('|'.join(list_correction_hotmail), '@hotmail.', regex=True, inplace=True)
# c:\Users\fajar.fatoni\Documents\Python\Task Offline\past_guest_toni_app\../zoho_data_app\main_module.py:259: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[df_columns].replace('|'.join(list_correction_hotmail_com), '@hotmail.com', regex=True, inplace=True)
# c:\Users\fajar.fatoni\Documents\Python\Task Offline\past_guest_toni_app\../zoho_data_app\main_module.py:260: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[df_columns].replace('|'.join(list_correction_yahoo_com), '@yahoo.com', regex=True, inplace=True)
# c:\Users\fajar.fatoni\Documents\Python\Task Offline\past_guest_toni_app\../zoho_data_app\main_module.py:261: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[df_columns].replace('|'.join(list_correction_yahoo), '@yahoo.', regex=True, inplace=True)
# c:\Users\fajar.fatoni\Documents\Python\Task Offline\past_guest_toni_app\../zoho_data_app\main_module.py:262: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[df_columns].replace('|'.join(list_correction_yahoo_in), '@yahoo.co.in', regex=True, inplace=True)

# %%
df_viewpoint.loc[(df_viewpoint['Email'] != 'empty') & ((df_viewpoint['Phone'] != 'empty') | (df_viewpoint['Mobile'] != 'empty')), 'Contact Type'] = 'Email and Phone'
df_viewpoint.loc[(df_viewpoint['Email'] != 'empty') & ((df_viewpoint['Phone'] == 'empty') & (df_viewpoint['Mobile'] == 'empty')), 'Contact Type'] = 'Email Only'
df_viewpoint.loc[(df_viewpoint['Email'] == 'empty') & ((df_viewpoint['Phone'] != 'empty') | (df_viewpoint['Mobile'] != 'empty')), 'Contact Type'] = 'Phone Only'

df_viewpoint.loc[df_viewpoint['Contact Type'] == 'empty'].to_csv(r'C:\Users\fajar.fatoni\Documents\Python\Data\contact_type_empty_viewpoint.csv', index=False)

count_contact_type_empty = df_viewpoint.loc[df_viewpoint['Contact Type'] == 'empty'].shape[0]

df_viewpoint.drop(df_viewpoint.loc[df_viewpoint['Contact Type'] == 'empty'].index, inplace=True)
df_viewpoint.reset_index(drop=True, inplace=True)

count_after_contact_type_empty = df_viewpoint.shape[0]

df_viewpoint
# Out:
#      Title              Firstname     lastname                  DOB  \
# 0       Mr        Vrushali Ganesh        Palav  1985-07-14 00:00:00
# 1       Mr                     S.   Asirvatham  1952-09-13 00:00:00
# 2       Mr                A Edwin  Christopher                empty
# 3       Mr                  Tilak          Raj                empty
# 4       Mr                Yaotong          Lyu  2004-09-14 00:00:00
# ...    ...                    ...          ...                  ...
# 2214        Teng, Jamie Chew Meng            -                empty
# 2215     -              Stéphanie      Laroque                empty
# 2216                     Stephane      Lorentz                empty
# 2217     -                   Carl    Kittelson                empty
# 2218   Krg           Fajar Fatoni           86                empty
#
#                               PAN CARD                      Email  \
# 0     AORPP4861R,AORPP4861R,AHLPC0382M  007.ganeshpalav@gmail.com
# 1                                empty         1952asir@gmail.com
# 2                                empty         1952asir@gmail.com
# 3                                empty             2012@gmail.com
# 4                                empty          2338201705@qq.com
# ...                                ...                        ...
# 2214                             empty
# 2215                             empty
# 2216                             empty
# 2217                             empty
# 2218                             empty
#
#              Phone        Mobile                                 AddressLine1  \
# 0     919324042146  918411013059                         302, NANDINI CORNER,
# 1     919444951557  919654207066  No.9, Nehru Colony, Kamaraj Nagar P.O Avadi
# 2     919654207066         empty  No.9, Nehru Colony, Kamaraj Nagar P.O Avadi
# 3     919971806012         empty                       SECTOR 14 HOUSE NO 166
# 4     628113855855         empty                                            -
# ...            ...           ...                                          ...
# 2214         empty         empty                                        empty
# 2215         empty         empty                                        empty
# 2216         empty         empty                                            -
# 2217         empty         empty                                            -
# 2218         empty         empty                                        empty
#
#                            AddressLine2  ... Sales Rep and Comments Opt In  \
# 0     CHAKRADHAR NAGAR, NALASOPARA WEST  ...                  empty    YES
# 1                                 empty  ...                  empty    YES
# 2                                 empty  ...                  empty    YES
# 3                          RAJ NAGAR UP  ...                 shoaib    YES
# 4                                 empty  ...                  empty    YES
# ...                                 ...  ...                    ...    ...
# 2214                              empty  ...                  empty    YES
# 2215                              empty  ...                  empty    YES
# 2216                              empty  ...                  empty    YES
# 2217                              empty  ...                  empty    YES
# 2218                              empty  ...                  empty  empty
#
#          Contact Type Odyssey Members     Lead Brand Lead Sub-Brand  \
# 0     Email and Phone              NO  Karma Resorts          Other
# 1     Email and Phone              NO  Karma Resorts          Other
# 2     Email and Phone              NO  Karma Resorts          Other
# 3     Email and Phone              NO  Karma Resorts          Other
# 4     Email and Phone              NO  Karma Resorts          Other
# ...               ...             ...            ...            ...
# 2214       Email Only              NO  Karma Resorts          Other
# 2215       Email Only              NO  Karma Resorts          Other
# 2216       Email Only              NO  Karma Resorts          Other
# 2217       Email Only              NO  Karma Resorts          Other
# 2218       Email Only              NO  Karma Resorts          Other
#
#       Lead Source                     Lead Locations Lead Source Description  \
# 0     Past Guests                  Karma Royal Palms               Viewpoint
# 1     Past Guests               Karma Munnar, Kerala               Viewpoint
# 2     Past Guests               Karma Munnar, Kerala               Viewpoint
# 3     Past Guests            Karma Sitabani, Corbett               Viewpoint
# 4     Past Guests                     Karma Jimbaran               Viewpoint
# ...           ...                                ...                     ...
# 2214  Past Guests  Wyndham -  Manoir des Deux Amants               Viewpoint
# 2215  Past Guests  Wyndham -  Manoir des Deux Amants               Viewpoint
# 2216  Past Guests  Wyndham -  Manoir des Deux Amants               Viewpoint
# 2217  Past Guests  Wyndham -  Manoir des Deux Amants               Viewpoint
# 2218  Past Guests                              empty               Viewpoint
#
#      Exclude From Mailing
# 0                      NO
# 1                      NO
# 2                      NO
# 3                      NO
# 4                      NO
# ...                   ...
# 2214                   NO
# 2215                   NO
# 2216                   NO
# 2217                   NO
# 2218                  NaN
#
# [2219 rows x 37 columns]

# %%
# Cek Email Karma
email_karma = m.find_karma(df_viewpoint, 'Email')
count_email_karma = email_karma.shape[0]
email_karma.to_csv(r'C:\Users\fajar.fatoni\Documents\Python\Data\email_deleted_viewpoint.csv', index=False)

email_karma
# Out:
#      Title            Firstname              lastname    DOB PAN CARD  \
# 52      Mr              Ahmed H               Maqbool  empty    empty
# 53      Mr              Ahmed H               Maqbool  empty    empty
# 552                   Esperanca              Patricio  empty    empty
# 553                   Esperanca              Patricio  empty    empty
# 856            Maintenance Room          Karma Haveli  empty    empty
# 1040    Ms  Marlinde Anne Maria              Verhoeff  empty    empty
# 1123     -   Maintenance Room -  Karma Royal Monterio  empty    empty
# 1124     -   Maintenance Room -  Karma Royal Monterio  empty    empty
# 1125    Mr       Milesh & Rajat                 Chari  empty    empty
# 1335    Mr               Pramod        Balasubramanya  empty    empty
# 1896    Ms                Tulsi               Prakash  empty    empty
#
#                                      Email          Phone        Mobile  \
# 52                   ahmed.maqbool@rci.com   919538144477         empty
# 53                   ahmed.maqbool@rci.com   919538144477         empty
# 552      esperanca.patricio@karmagroup.com   918600159512         empty
# 553      esperanca.patricio@karmagroup.com   918600159512         empty
# 856            karma.haveli@karmagroup.com   911412671027  911412671597
# 1040      marlinde.verhoeff@karmagroup.com  6282237493002         empty
# 1123             mr.asstfom@karmagroup.com   918326716200         empty
# 1124             mr.asstfom@karmagroup.com   918326716200         empty
# 1125                  mr.hk@karmagroup.com   918326716200  919175089732
# 1335  pramod.balasubramanya@karmagroup.com   919538510610  919538510610
# 1896           tulsiprakash@karmagroup.com   918091005800         empty
#
#                              AddressLine1  \
# 52                      RCI INDIA PVT LTD
# 53                      RCI INDIA PVT LTD
# 552                    CAVELOSSIM, MOBOR,
# 553                    CAVELOSSIM, MOBOR,
# 856   240 & 242, Gatore Road, Brahmapuri,
# 1040                            INDONESIA
# 1123                 karma royal monetrio
# 1124                 karma royal monetrio
# 1125                 Karma Royal Monterio
# 1335                                    -
# 1896     KARMA ROYAL MONTERIO ARPORA BAGA
#
#                                            AddressLine2  ...  \
# 52                                        WEWORK GALAXY  ...
# 53                                        WEWORK GALAXY  ...
# 552   Karma Royal Haathi Mahal, Cavelossim, Motorola...  ...
# 553   Karma Royal Haathi Mahal, Cavelossim, Motorola...  ...
# 856                                    JAIPUR RAJHASTAN  ...
# 1040                                              empty  ...
# 1123                                             Arpora  ...
# 1124                                             Arpora  ...
# 1125                                   Arpora Baga Road  ...
# 1335                                                  -  ...
# 1896                                              empty  ...
#
#      Sales Rep and Comments Opt In     Contact Type Odyssey Members  \
# 52                    empty    YES  Email and Phone              NO
# 53                    empty    YES  Email and Phone              NO
# 552                   empty    YES  Email and Phone              NO
# 553                   empty    YES  Email and Phone              NO
# 856                   empty    YES  Email and Phone              NO
# 1040                  empty    YES  Email and Phone              NO
# 1123                  empty    YES  Email and Phone              NO
# 1124                  empty    YES  Email and Phone              NO
# 1125                  empty    YES  Email and Phone              NO
# 1335                  empty    YES  Email and Phone              NO
# 1896                  empty    YES  Email and Phone              NO
#
#          Lead Brand Lead Sub-Brand  Lead Source            Lead Locations  \
# 52    Karma Resorts          Other  Past Guests         Karma Royal Palms
# 53    Karma Resorts          Other  Past Guests         Karma Royal Palms
# 552   Karma Resorts          Other  Past Guests  Karma Royal Haathi Mahal
# 553   Karma Resorts          Other  Past Guests  Karma Royal Haathi Mahal
# 856   Karma Resorts          Other  Past Guests      Karma Haveli, Jaipur
# 1040  Karma Resorts          Other  Past Guests     Karma Royal Candidasa
# 1123  Karma Resorts          Other  Past Guests      Karma Royal Monterio
# 1124  Karma Resorts          Other  Past Guests      Karma Royal Monterio
# 1125  Karma Resorts          Other  Past Guests      Karma Royal Monterio
# 1335  Karma Resorts          Other  Past Guests         Karma Royal Palms
# 1896  Karma Resorts          Other  Past Guests         Karma Royal Palms
#
#      Lead Source Description Exclude From Mailing
# 52                 Viewpoint                   NO
# 53                 Viewpoint                   NO
# 552                Viewpoint                   NO
# 553                Viewpoint                   NO
# 856                Viewpoint                   NO
# 1040               Viewpoint                   NO
# 1123               Viewpoint                   NO
# 1124               Viewpoint                   NO
# 1125               Viewpoint                   NO
# 1335               Viewpoint                   NO
# 1896               Viewpoint                   NO
#
# [11 rows x 37 columns]

# %%
# delete email Karma
count_after_clean_karma = m.delete_karma(df_viewpoint, 'Email')

df_viewpoint
# Out:
#      Title              Firstname     lastname                  DOB  \
# 0       Mr        Vrushali Ganesh        Palav  1985-07-14 00:00:00
# 1       Mr                     S.   Asirvatham  1952-09-13 00:00:00
# 2       Mr                A Edwin  Christopher                empty
# 3       Mr                  Tilak          Raj                empty
# 4       Mr                Yaotong          Lyu  2004-09-14 00:00:00
# ...    ...                    ...          ...                  ...
# 2203        Teng, Jamie Chew Meng            -                empty
# 2204     -              Stéphanie      Laroque                empty
# 2205                     Stephane      Lorentz                empty
# 2206     -                   Carl    Kittelson                empty
# 2207   Krg           Fajar Fatoni           86                empty
#
#                               PAN CARD                      Email  \
# 0     AORPP4861R,AORPP4861R,AHLPC0382M  007.ganeshpalav@gmail.com
# 1                                empty         1952asir@gmail.com
# 2                                empty         1952asir@gmail.com
# 3                                empty             2012@gmail.com
# 4                                empty          2338201705@qq.com
# ...                                ...                        ...
# 2203                             empty
# 2204                             empty
# 2205                             empty
# 2206                             empty
# 2207                             empty
#
#              Phone        Mobile                                 AddressLine1  \
# 0     919324042146  918411013059                         302, NANDINI CORNER,
# 1     919444951557  919654207066  No.9, Nehru Colony, Kamaraj Nagar P.O Avadi
# 2     919654207066         empty  No.9, Nehru Colony, Kamaraj Nagar P.O Avadi
# 3     919971806012         empty                       SECTOR 14 HOUSE NO 166
# 4     628113855855         empty                                            -
# ...            ...           ...                                          ...
# 2203         empty         empty                                        empty
# 2204         empty         empty                                        empty
# 2205         empty         empty                                            -
# 2206         empty         empty                                            -
# 2207         empty         empty                                        empty
#
#                            AddressLine2  ... Sales Rep and Comments Opt In  \
# 0     CHAKRADHAR NAGAR, NALASOPARA WEST  ...                  empty    YES
# 1                                 empty  ...                  empty    YES
# 2                                 empty  ...                  empty    YES
# 3                          RAJ NAGAR UP  ...                 shoaib    YES
# 4                                 empty  ...                  empty    YES
# ...                                 ...  ...                    ...    ...
# 2203                              empty  ...                  empty    YES
# 2204                              empty  ...                  empty    YES
# 2205                              empty  ...                  empty    YES
# 2206                              empty  ...                  empty    YES
# 2207                              empty  ...                  empty  empty
#
#          Contact Type Odyssey Members     Lead Brand Lead Sub-Brand  \
# 0     Email and Phone              NO  Karma Resorts          Other
# 1     Email and Phone              NO  Karma Resorts          Other
# 2     Email and Phone              NO  Karma Resorts          Other
# 3     Email and Phone              NO  Karma Resorts          Other
# 4     Email and Phone              NO  Karma Resorts          Other
# ...               ...             ...            ...            ...
# 2203       Email Only              NO  Karma Resorts          Other
# 2204       Email Only              NO  Karma Resorts          Other
# 2205       Email Only              NO  Karma Resorts          Other
# 2206       Email Only              NO  Karma Resorts          Other
# 2207       Email Only              NO  Karma Resorts          Other
#
#       Lead Source                     Lead Locations Lead Source Description  \
# 0     Past Guests                  Karma Royal Palms               Viewpoint
# 1     Past Guests               Karma Munnar, Kerala               Viewpoint
# 2     Past Guests               Karma Munnar, Kerala               Viewpoint
# 3     Past Guests            Karma Sitabani, Corbett               Viewpoint
# 4     Past Guests                     Karma Jimbaran               Viewpoint
# ...           ...                                ...                     ...
# 2203  Past Guests  Wyndham -  Manoir des Deux Amants               Viewpoint
# 2204  Past Guests  Wyndham -  Manoir des Deux Amants               Viewpoint
# 2205  Past Guests  Wyndham -  Manoir des Deux Amants               Viewpoint
# 2206  Past Guests  Wyndham -  Manoir des Deux Amants               Viewpoint
# 2207  Past Guests                              empty               Viewpoint
#
#      Exclude From Mailing
# 0                      NO
# 1                      NO
# 2                      NO
# 3                      NO
# 4                      NO
# ...                   ...
# 2203                   NO
# 2204                   NO
# 2205                   NO
# 2206                   NO
# 2207                  NaN
#
# [2208 rows x 37 columns]

# %%
# Cek leads test
test_leads = df_viewpoint.loc[
    
        df_viewpoint['Email'].str.contains('^test@', flags=re.I, regex=True) |
        df_viewpoint['Email'].str.contains('\+test', flags=re.I, regex=True) |
    
        df_viewpoint['Firstname'].str.contains('^test$', flags=re.I, regex=True) |
        df_viewpoint['lastname'].str.contains('^test$', flags=re.I, regex=True) |

        df_viewpoint['Firstname'].str.contains('test 1', flags=re.I, regex=True) |
        df_viewpoint['lastname'].str.contains('test 2', flags=re.I, regex=True)|
        df_viewpoint['Firstname'].str.contains('test1', flags=re.I, regex=True) |
        df_viewpoint['lastname'].str.contains('test2', flags=re.I, regex=True)|

        df_viewpoint['Firstname'].str.contains(' test ', flags=re.I, regex=True) | 
        df_viewpoint['lastname'].str.contains(' test ', flags=re.I, regex=True) | 
        df_viewpoint['lastname'].str.contains(' test$', flags=re.I, regex=True)
    ]

count_leads_test = test_leads.shape[0]

test_leads.to_csv(r'C:\Users\fajar.fatoni\Documents\Python\Data\test_leads_viewpoint.csv', index=False)
test_leads
# Out:
# Empty DataFrame
# Columns: [Title, Firstname, lastname, DOB, PAN CARD, Email, Phone, Mobile, AddressLine1, AddressLine2, Town, State, Country, PostCode, Nationality, MaritalStatus, resortname, Arrival, Departure, CheckInDate, CheckOutDate, room, UnitCategory, BookingNo, BookingSourceDesc, BookingTypeDesc, Date of Tour, Sales Rep and Comments, Opt In, Contact Type, Odyssey Members, Lead Brand, Lead Sub-Brand, Lead Source, Lead Locations, Lead Source Description, Exclude From Mailing]
# Index: []
#
# [0 rows x 37 columns]

# %%
df_viewpoint.drop(test_leads.index, inplace=True)
df_viewpoint.reset_index(drop=True, inplace=True)

count_after_dedup_test = df_viewpoint.shape[0]
count_after_dedup_test
# Out:
# 2208

# %%
count_final_data = count_after_dedup_test

# %%
# df_viewpoint.loc[df_viewpoint['BookingNo'] == '2070341']

# %%
df_viewpoint.replace('empty', '', inplace=True)

# %%
print("==========================================================")
print("Summary")
print("==========================================================")
print("Jumlah Data Awal Viewpoint : "+str(count_data_awal))
print("Jumlah Data Email dan Phone Kosong : "+str(count_contact_type_empty))
print("Jumlah Data Setelah Hapus Email dan Phone Yang Kosong : "+str(count_after_contact_type_empty))
print("Jumlah Data Email Yang Termasuk List Karma : "+str(count_email_karma))
print("Jumlah Data Email Setelah List Karma Dihapus : "+str(count_after_clean_karma))
print("Jumlah Data Test : "+str(count_leads_test))
print("Jumlah Data Email Setelah Data Test Dihapus : "+str(count_after_dedup_test))
print("Jumlah Data Akhir : "+str(count_final_data))
# Out:
# ==========================================================
# Summary
# ==========================================================
# Jumlah Data Awal Viewpoint : 2219
# Jumlah Data Email dan Phone Kosong : 0
# Jumlah Data Setelah Hapus Email dan Phone Yang Kosong : 2219
# Jumlah Data Email Yang Termasuk List Karma : 11
# Jumlah Data Email Setelah List Karma Dihapus : 2208
# Jumlah Data Test : 0
# Jumlah Data Email Setelah Data Test Dihapus : 2208
# Jumlah Data Akhir : 2208

# %%
df_viewpoint.to_excel(r'C:\Users\fajar.fatoni\Documents\Python\Data\check_country_code_viewpoint.xlsx', index=False)
