# %%
import pandas as pd
import re

import past_guest_module as pm

import sys
sys.path.append('../zoho_data_app/')

import main_module as m

# %load_ext autoreload
# %autoreload 2

# %%
path = r'C:\Users\fajar.fatoni\Documents\Python\Data\Past Guest Data\View Point\2025\Mar\9 Mar - 17 Mar\CheckOutReport 9 Mar - 17 Mar.xlsx'
df_viewpoint = pd.read_excel(path, dtype='string', sheet_name='Sheet1')
count_data_awal = df_viewpoint.shape[0]
df_viewpoint
# Out:
#      Title                            Firstname lastname                  DOB  \
# 0       Mr                                Derek   Martin  1959-05-25 00:00:00
# 1      Mrs                               Katrin    James  1982-07-13 00:00:00
# 2       Ms                                 Lois  Barnett                 <NA>
# 3       Mr                                 Alan   Davies  1948-03-12 00:00:00
# 4      Mrs                                Maree   Dollin                 <NA>
# ...    ...                                  ...      ...                  ...
# 1738   Mrs                          Ruth Veitch   Nicoll                 <NA>
# 1739  <NA>                                 <NA>     <NA>                 <NA>
# 1740  <NA>                                 <NA>     <NA>                 <NA>
# 1741  <NA>  Wallace, Christine & Racine, Martin     <NA>                 <NA>
# 1742   krg                         Fajar Fatoni       86                 <NA>
#
#      PAN CARD                     Email        Phone       Mobile  \
# 0        <NA>         59derek@gmail.com  61457330432         <NA>
# 1        <NA>  admin@karramindie.com.au  61890208036  61417368044
# 2        <NA>    ajwands@bigpond.net.au         <NA>         <NA>
# 3        <NA>  alandavies48@bigpond.com  61458551669         <NA>
# 4        <NA>     amharic2007@gmail.com  61458295886  61458295886
# ...       ...                       ...          ...          ...
# 1738     <NA>                      <NA>         <NA>         <NA>
# 1739     <NA>                      <NA>         <NA>         <NA>
# 1740     <NA>                      <NA>         <NA>         <NA>
# 1741     <NA>                      <NA>         <NA>         <NA>
# 1742     <NA>                      <NA>         <NA>         <NA>
#
#          AddressLine1 AddressLine2  ...          CheckInDate  \
# 0     19 HABER STREET         <NA>  ...  2025-03-08 16:00:44
# 1         PO BOX 2040         <NA>  ...  2025-03-10 20:30:10
# 2                   -         <NA>  ...  2025-03-01 11:12:18
# 3      6 LIDSDALE  ST         <NA>  ...  2025-03-08 15:34:18
# 4          PO Box 197         <NA>  ...  2025-03-04 16:30:04
# ...               ...          ...  ...                  ...
# 1738             <NA>         <NA>  ...  2025-03-14 02:02:14
# 1739             <NA>         <NA>  ...  2025-03-11 17:51:48
# 1740             <NA>         <NA>  ...  2025-03-13 16:21:10
# 1741             <NA>         <NA>  ...  2025-03-04 23:45:37
# 1742             <NA>         <NA>  ...                 <NA>
#
#              CheckOutDate     room                     UnitCategory BookingNo  \
# 0     2025-03-15 13:07:45       05                 Studio Apartment   2728744
# 1     2025-03-17 08:32:42     <NA>  Three Bedroom Deluxe Pool Villa   2745899
# 2     2025-03-15 14:32:33      105    Hotel Unit Double Pool Access   2629283
# 3     2025-03-15 12:25:45  08 - KC     3 Bedroom GV Pool Villa - KC   2587624
# 4     2025-03-11 10:30:05      V69    One Bedroom Deluxe Pool Villa   2635393
# ...                   ...      ...                              ...       ...
# 1738  2025-03-16 19:32:10       10                    Heritage Room   2790353
# 1739  2025-03-13 14:40:52      102              Hotel Unit max 1ch.   2767791
# 1740  2025-03-15 23:14:16     H-08                Hotel Unit Double   2718944
# 1741  2025-03-11 18:05:26      202              1 Bedroom Apartment   2557570
# 1742                 <NA>     <NA>                             <NA>      <NA>
#
#               BookingSourceDesc           BookingTypeDesc  \
# 0                     KC Member               Entitlement
# 1              Fractional Owner               Entitlement
# 2     Guest Of Fractional Owner         Entitlement Guest
# 3              Fractional Owner               Entitlement
# 4               Fly Buy Western           Fly Buy Western
# ...                         ...                       ...
# 1738                  KC Member        Expired membership
# 1739       Karma Club Discovery  Cancelled Member Program
# 1740           Fractional Owner    Entitlement Fractional
# 1741             Hotel Bookings            Wyndham Guests
# 1742                       <NA>                      <NA>
#
#              Date of Tour Sales Rep and Comments Opt In
# 0     2025-03-10 17:00:00                Craig B    YES
# 1                    <NA>                   <NA>    YES
# 2                    <NA>                   <NA>    YES
# 3     2025-03-13 17:10:00                 Martin    YES
# 4                    <NA>                   <NA>    YES
# ...                   ...                    ...    ...
# 1738                 <NA>                   <NA>    YES
# 1739                 <NA>                   <NA>    YES
# 1740                 <NA>                   <NA>    YES
# 1741                 <NA>                   <NA>    YES
# 1742                 <NA>                   <NA>   <NA>
#
# [1743 rows x 29 columns]

# %%
df_viewpoint.columns
# Out:
# Index(['Title', 'Firstname', 'lastname', 'DOB', 'PAN CARD', 'Email', 'Phone',
#        'Mobile', 'AddressLine1', 'AddressLine2', 'Town', 'State', 'Country',
#        'PostCode', 'Nationality', 'MaritalStatus', 'resortname', 'Arrival',
#        'Departure', 'CheckInDate', 'CheckOutDate', 'room', 'UnitCategory',
#        'BookingNo', 'BookingSourceDesc', 'BookingTypeDesc', 'Date of Tour',
#        'Sales Rep and Comments', 'Opt In'],
#       dtype='object')

# %%
df_viewpoint.fillna('empty', inplace=True)

df_viewpoint['Contact Type'] = 'empty'
df_viewpoint['Odyssey Members'] = 'NO'

df_viewpoint['Lead Brand'] = 'Karma Resorts'
df_viewpoint['Lead Sub-Brand'] = 'Other'
df_viewpoint['Lead Source'] = 'Past Guests'
df_viewpoint['Lead Locations'] = df_viewpoint['resortname']
df_viewpoint['Lead Source Description'] = 'Viewpoint'

# %%
df_viewpoint.loc[df_viewpoint['Opt In'] == 'YES', 'Exclude From Mailing'] = 'NO'
df_viewpoint.loc[df_viewpoint['Opt In'] == 'NO', 'Exclude From Mailing'] = 'YES'

# %%
df_viewpoint.loc[df_viewpoint['lastname'] == 'empty', 'lastname'] = '-'

# %%
df_viewpoint['Title'].replace('empty', '', inplace=True)
df_viewpoint['Firstname'].replace('empty', '', inplace=True)
df_viewpoint['lastname'].replace('empty', '', inplace=True)

df_viewpoint['Title'] = df_viewpoint['Title'].str.title()
df_viewpoint['Firstname'] = df_viewpoint['Firstname'].str.title()
df_viewpoint['lastname'] = df_viewpoint['lastname'].str.title()

df_viewpoint
# Out:
# C:\Users\fajar.fatoni\AppData\Local\Temp\ipykernel_29600\3404343493.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_viewpoint['Title'].replace('empty', '', inplace=True)
# C:\Users\fajar.fatoni\AppData\Local\Temp\ipykernel_29600\3404343493.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_viewpoint['Firstname'].replace('empty', '', inplace=True)
# C:\Users\fajar.fatoni\AppData\Local\Temp\ipykernel_29600\3404343493.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_viewpoint['lastname'].replace('empty', '', inplace=True)
#      Title                            Firstname lastname                  DOB  \
# 0       Mr                                Derek   Martin  1959-05-25 00:00:00
# 1      Mrs                               Katrin    James  1982-07-13 00:00:00
# 2       Ms                                 Lois  Barnett                empty
# 3       Mr                                 Alan   Davies  1948-03-12 00:00:00
# 4      Mrs                                Maree   Dollin                empty
# ...    ...                                  ...      ...                  ...
# 1738   Mrs                          Ruth Veitch   Nicoll                empty
# 1739                                                   -                empty
# 1740                                                   -                empty
# 1741        Wallace, Christine & Racine, Martin        -                empty
# 1742   Krg                         Fajar Fatoni       86                empty
#
#      PAN CARD                     Email        Phone       Mobile  \
# 0       empty         59derek@gmail.com  61457330432        empty
# 1       empty  admin@karramindie.com.au  61890208036  61417368044
# 2       empty    ajwands@bigpond.net.au        empty        empty
# 3       empty  alandavies48@bigpond.com  61458551669        empty
# 4       empty     amharic2007@gmail.com  61458295886  61458295886
# ...       ...                       ...          ...          ...
# 1738    empty                     empty        empty        empty
# 1739    empty                     empty        empty        empty
# 1740    empty                     empty        empty        empty
# 1741    empty                     empty        empty        empty
# 1742    empty                     empty        empty        empty
#
#          AddressLine1 AddressLine2  ... Sales Rep and Comments Opt In  \
# 0     19 HABER STREET        empty  ...                Craig B    YES
# 1         PO BOX 2040        empty  ...                  empty    YES
# 2                   -        empty  ...                  empty    YES
# 3      6 LIDSDALE  ST        empty  ...                 Martin    YES
# 4          PO Box 197        empty  ...                  empty    YES
# ...               ...          ...  ...                    ...    ...
# 1738            empty        empty  ...                  empty    YES
# 1739            empty        empty  ...                  empty    YES
# 1740            empty        empty  ...                  empty    YES
# 1741            empty        empty  ...                  empty    YES
# 1742            empty        empty  ...                  empty  empty
#
#      Contact Type Odyssey Members     Lead Brand Lead Sub-Brand  Lead Source  \
# 0           empty              NO  Karma Resorts          Other  Past Guests
# 1           empty              NO  Karma Resorts          Other  Past Guests
# 2           empty              NO  Karma Resorts          Other  Past Guests
# 3           empty              NO  Karma Resorts          Other  Past Guests
# 4           empty              NO  Karma Resorts          Other  Past Guests
# ...           ...             ...            ...            ...          ...
# 1738        empty              NO  Karma Resorts          Other  Past Guests
# 1739        empty              NO  Karma Resorts          Other  Past Guests
# 1740        empty              NO  Karma Resorts          Other  Past Guests
# 1741        empty              NO  Karma Resorts          Other  Past Guests
# 1742        empty              NO  Karma Resorts          Other  Past Guests
#
#                          Lead Locations Lead Source Description  \
# 0                 Karma Royal Candidasa               Viewpoint
# 1          KRR @ Karma Kandara, Phase V               Viewpoint
# 2              Karma Panalee, Koh Samui               Viewpoint
# 3                        Karma Jimbaran               Viewpoint
# 4          KRR @ Karma Kandara, Phase V               Viewpoint
# ...                                 ...                     ...
# 1738             Karma Lake of Menteith               Viewpoint
# 1739               Karma Munnar, Kerala               Viewpoint
# 1740             Karma Sunshine Village               Viewpoint
# 1741  Wyndham -  Manoir des Deux Amants               Viewpoint
# 1742                              empty               Viewpoint
#
#      Exclude From Mailing
# 0                      NO
# 1                      NO
# 2                      NO
# 3                      NO
# 4                      NO
# ...                   ...
# 1738                   NO
# 1739                   NO
# 1740                   NO
# 1741                   NO
# 1742                  NaN
#
# [1743 rows x 37 columns]

# %%
m.clean_number(df_viewpoint, 'Phone')
m.clean_number(df_viewpoint, 'Mobile')
m.replace_not_valid_to_empty(df_viewpoint, 'Phone')
m.replace_not_valid_to_empty(df_viewpoint, 'Mobile')

df_viewpoint.loc[df_viewpoint['Phone'].str.contains('00000'), 'Phone'] = 'empty'
df_viewpoint.loc[df_viewpoint['Mobile'].str.contains('00000'), 'Mobile'] = 'empty'

m.clean_space(df_viewpoint, 'Email')
df_viewpoint['Email'] = m.lowercase(df_viewpoint, 'Email')
m.email_correction(df_viewpoint, 'Email')
# Out:
# c:\Users\fajar.fatoni\Documents\Python\Task Offline\past_guest_toni_app\../zoho_data_app\main_module.py:71: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[df_columns].replace(' ','', regex=True, inplace=True)
# c:\Users\fajar.fatoni\Documents\Python\Task Offline\past_guest_toni_app\../zoho_data_app\main_module.py:72: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[df_columns].replace('[^0-9]','', regex=True, inplace=True)
# c:\Users\fajar.fatoni\Documents\Python\Task Offline\past_guest_toni_app\../zoho_data_app\main_module.py:94: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[df_columns].replace(' ','', regex=True, inplace=True)
# c:\Users\fajar.fatoni\Documents\Python\Task Offline\past_guest_toni_app\../zoho_data_app\main_module.py:227: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[df_columns].replace('^mailto:|-primary$|-pri$|-Mrs$|(noemailtobesent)$','', regex=True, inplace=True)
# c:\Users\fajar.fatoni\Documents\Python\Task Offline\past_guest_toni_app\../zoho_data_app\main_module.py:255: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[df_columns].replace('|'.join(list_correction_mail), '@mail.', regex=True, inplace=True)
# c:\Users\fajar.fatoni\Documents\Python\Task Offline\past_guest_toni_app\../zoho_data_app\main_module.py:256: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[df_columns].replace('|'.join(list_correction_gmail), '@gmail.', regex=True, inplace=True)
# c:\Users\fajar.fatoni\Documents\Python\Task Offline\past_guest_toni_app\../zoho_data_app\main_module.py:257: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[df_columns].replace('|'.join(list_correction_gmail_com), '@gmail.com', regex=True, inplace=True)
# c:\Users\fajar.fatoni\Documents\Python\Task Offline\past_guest_toni_app\../zoho_data_app\main_module.py:258: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[df_columns].replace('|'.join(list_correction_hotmail), '@hotmail.', regex=True, inplace=True)
# c:\Users\fajar.fatoni\Documents\Python\Task Offline\past_guest_toni_app\../zoho_data_app\main_module.py:259: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[df_columns].replace('|'.join(list_correction_hotmail_com), '@hotmail.com', regex=True, inplace=True)
# c:\Users\fajar.fatoni\Documents\Python\Task Offline\past_guest_toni_app\../zoho_data_app\main_module.py:260: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[df_columns].replace('|'.join(list_correction_yahoo_com), '@yahoo.com', regex=True, inplace=True)
# c:\Users\fajar.fatoni\Documents\Python\Task Offline\past_guest_toni_app\../zoho_data_app\main_module.py:261: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[df_columns].replace('|'.join(list_correction_yahoo), '@yahoo.', regex=True, inplace=True)
# c:\Users\fajar.fatoni\Documents\Python\Task Offline\past_guest_toni_app\../zoho_data_app\main_module.py:262: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[df_columns].replace('|'.join(list_correction_yahoo_in), '@yahoo.co.in', regex=True, inplace=True)
# c:\Users\fajar.fatoni\Documents\Python\Task Offline\past_guest_toni_app\../zoho_data_app\main_module.py:277: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[df_columns].loc[~df[df_columns].str.contains('@', df_columns, na=False)] = ''

# %%
m.email_correction(df_viewpoint, 'Email')
# Out:
# c:\Users\fajar.fatoni\Documents\Python\Task Offline\past_guest_toni_app\../zoho_data_app\main_module.py:227: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[df_columns].replace('^mailto:|-primary$|-pri$|-Mrs$|(noemailtobesent)$','', regex=True, inplace=True)
# c:\Users\fajar.fatoni\Documents\Python\Task Offline\past_guest_toni_app\../zoho_data_app\main_module.py:255: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[df_columns].replace('|'.join(list_correction_mail), '@mail.', regex=True, inplace=True)
# c:\Users\fajar.fatoni\Documents\Python\Task Offline\past_guest_toni_app\../zoho_data_app\main_module.py:256: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[df_columns].replace('|'.join(list_correction_gmail), '@gmail.', regex=True, inplace=True)
# c:\Users\fajar.fatoni\Documents\Python\Task Offline\past_guest_toni_app\../zoho_data_app\main_module.py:257: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[df_columns].replace('|'.join(list_correction_gmail_com), '@gmail.com', regex=True, inplace=True)
# c:\Users\fajar.fatoni\Documents\Python\Task Offline\past_guest_toni_app\../zoho_data_app\main_module.py:258: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[df_columns].replace('|'.join(list_correction_hotmail), '@hotmail.', regex=True, inplace=True)
# c:\Users\fajar.fatoni\Documents\Python\Task Offline\past_guest_toni_app\../zoho_data_app\main_module.py:259: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[df_columns].replace('|'.join(list_correction_hotmail_com), '@hotmail.com', regex=True, inplace=True)
# c:\Users\fajar.fatoni\Documents\Python\Task Offline\past_guest_toni_app\../zoho_data_app\main_module.py:260: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[df_columns].replace('|'.join(list_correction_yahoo_com), '@yahoo.com', regex=True, inplace=True)
# c:\Users\fajar.fatoni\Documents\Python\Task Offline\past_guest_toni_app\../zoho_data_app\main_module.py:261: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[df_columns].replace('|'.join(list_correction_yahoo), '@yahoo.', regex=True, inplace=True)
# c:\Users\fajar.fatoni\Documents\Python\Task Offline\past_guest_toni_app\../zoho_data_app\main_module.py:262: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[df_columns].replace('|'.join(list_correction_yahoo_in), '@yahoo.co.in', regex=True, inplace=True)

# %%
df_viewpoint.loc[(df_viewpoint['Email'] != 'empty') & ((df_viewpoint['Phone'] != 'empty') | (df_viewpoint['Mobile'] != 'empty')), 'Contact Type'] = 'Email and Phone'
df_viewpoint.loc[(df_viewpoint['Email'] != 'empty') & ((df_viewpoint['Phone'] == 'empty') & (df_viewpoint['Mobile'] == 'empty')), 'Contact Type'] = 'Email Only'
df_viewpoint.loc[(df_viewpoint['Email'] == 'empty') & ((df_viewpoint['Phone'] != 'empty') | (df_viewpoint['Mobile'] != 'empty')), 'Contact Type'] = 'Phone Only'

df_viewpoint.loc[df_viewpoint['Contact Type'] == 'empty'].to_csv(r'C:\Users\fajar.fatoni\Documents\Python\Data\contact_type_empty_viewpoint.csv', index=False)

count_contact_type_empty = df_viewpoint.loc[df_viewpoint['Contact Type'] == 'empty'].shape[0]

df_viewpoint.drop(df_viewpoint.loc[df_viewpoint['Contact Type'] == 'empty'].index, inplace=True)
df_viewpoint.reset_index(drop=True, inplace=True)

count_after_contact_type_empty = df_viewpoint.shape[0]

df_viewpoint
# Out:
#      Title                            Firstname lastname                  DOB  \
# 0       Mr                                Derek   Martin  1959-05-25 00:00:00
# 1      Mrs                               Katrin    James  1982-07-13 00:00:00
# 2       Ms                                 Lois  Barnett                empty
# 3       Mr                                 Alan   Davies  1948-03-12 00:00:00
# 4      Mrs                                Maree   Dollin                empty
# ...    ...                                  ...      ...                  ...
# 1738   Mrs                          Ruth Veitch   Nicoll                empty
# 1739                                                   -                empty
# 1740                                                   -                empty
# 1741        Wallace, Christine & Racine, Martin        -                empty
# 1742   Krg                         Fajar Fatoni       86                empty
#
#      PAN CARD                     Email        Phone       Mobile  \
# 0       empty         59derek@gmail.com  61457330432        empty
# 1       empty  admin@karramindie.com.au  61890208036  61417368044
# 2       empty    ajwands@bigpond.net.au        empty        empty
# 3       empty  alandavies48@bigpond.com  61458551669        empty
# 4       empty     amharic2007@gmail.com  61458295886  61458295886
# ...       ...                       ...          ...          ...
# 1738    empty                                  empty        empty
# 1739    empty                                  empty        empty
# 1740    empty                                  empty        empty
# 1741    empty                                  empty        empty
# 1742    empty                                  empty        empty
#
#          AddressLine1 AddressLine2  ... Sales Rep and Comments Opt In  \
# 0     19 HABER STREET        empty  ...                Craig B    YES
# 1         PO BOX 2040        empty  ...                  empty    YES
# 2                   -        empty  ...                  empty    YES
# 3      6 LIDSDALE  ST        empty  ...                 Martin    YES
# 4          PO Box 197        empty  ...                  empty    YES
# ...               ...          ...  ...                    ...    ...
# 1738            empty        empty  ...                  empty    YES
# 1739            empty        empty  ...                  empty    YES
# 1740            empty        empty  ...                  empty    YES
# 1741            empty        empty  ...                  empty    YES
# 1742            empty        empty  ...                  empty  empty
#
#          Contact Type Odyssey Members     Lead Brand Lead Sub-Brand  \
# 0     Email and Phone              NO  Karma Resorts          Other
# 1     Email and Phone              NO  Karma Resorts          Other
# 2          Email Only              NO  Karma Resorts          Other
# 3     Email and Phone              NO  Karma Resorts          Other
# 4     Email and Phone              NO  Karma Resorts          Other
# ...               ...             ...            ...            ...
# 1738       Email Only              NO  Karma Resorts          Other
# 1739       Email Only              NO  Karma Resorts          Other
# 1740       Email Only              NO  Karma Resorts          Other
# 1741       Email Only              NO  Karma Resorts          Other
# 1742       Email Only              NO  Karma Resorts          Other
#
#       Lead Source                     Lead Locations Lead Source Description  \
# 0     Past Guests              Karma Royal Candidasa               Viewpoint
# 1     Past Guests       KRR @ Karma Kandara, Phase V               Viewpoint
# 2     Past Guests           Karma Panalee, Koh Samui               Viewpoint
# 3     Past Guests                     Karma Jimbaran               Viewpoint
# 4     Past Guests       KRR @ Karma Kandara, Phase V               Viewpoint
# ...           ...                                ...                     ...
# 1738  Past Guests             Karma Lake of Menteith               Viewpoint
# 1739  Past Guests               Karma Munnar, Kerala               Viewpoint
# 1740  Past Guests             Karma Sunshine Village               Viewpoint
# 1741  Past Guests  Wyndham -  Manoir des Deux Amants               Viewpoint
# 1742  Past Guests                              empty               Viewpoint
#
#      Exclude From Mailing
# 0                      NO
# 1                      NO
# 2                      NO
# 3                      NO
# 4                      NO
# ...                   ...
# 1738                   NO
# 1739                   NO
# 1740                   NO
# 1741                   NO
# 1742                  NaN
#
# [1743 rows x 37 columns]

# %%
# Cek Email Karma
email_karma = m.find_karma(df_viewpoint, 'Email')
count_email_karma = email_karma.shape[0]
email_karma.to_csv(r'C:\Users\fajar.fatoni\Documents\Python\Data\email_deleted_viewpoint.csv', index=False)

email_karma
# Out:
#      Title           Firstname              lastname                  DOB  \
# 218      -             Nicolas            Aquachiara                empty
# 335     Mr                Anuj                 Singh                empty
# 747           Maintenance Room          Karma Haveli                empty
# 748           Maintenance Room          Karma Haveli                empty
# 749           Maintenance Room          Karma Haveli                empty
# 886      -  Maintenance Room -  Karma Royal Monterio                empty
# 887      -  Maintenance Room -  Karma Royal Monterio                empty
# 888      -  Maintenance Room -  Karma Royal Monterio                empty
# 1250    Ms             Shivani              Yeshwant                empty
# 1357    Mr              Tanmay                  Adak                empty
# 1358    Mr              Tanmay                  Adak                empty
# 1359    Mr              Tanmay                  Adak                empty
# 1360    Mr              Tanmay                  Adak                empty
# 1363    Mr               Nirez                  Khan                empty
# 1571    Mr               David             Scheckter  1970-06-11 00:00:00
#
#      PAN CARD                            Email          Phone         Mobile  \
# 218     empty      reception@karmanormandy.com          empty          empty
# 335     empty        anuj.yadav@karmagroup.com   917355922764          empty
# 747     empty      karma.haveli@karmagroup.com  9101412671027  9101412671597
# 748     empty      karma.haveli@karmagroup.com  9101412671027  9101412671597
# 749     empty      karma.haveli@karmagroup.com  9101412671027  9101412671597
# 886     empty        mr.asstfom@karmagroup.com   918326716200          empty
# 887     empty        mr.asstfom@karmagroup.com   918326716200          empty
# 888     empty        mr.asstfom@karmagroup.com   918326716200          empty
# 1250    empty  shivani.yeshwant@karmagroup.com          empty          empty
# 1357    empty       tanmay.adak@karmagroup.com   919657017961          empty
# 1358    empty       tanmay.adak@karmagroup.com   919657017961          empty
# 1359    empty       tanmay.adak@karmagroup.com   919657017961          empty
# 1360    empty       tanmay.adak@karmagroup.com   919657017961          empty
# 1363    empty      tarun.sharma@karmagroup.com   919893137377          empty
# 1571    empty   david.scheckter@karmagroup.com   628113893039          empty
#
#                              AddressLine1 AddressLine2  ...  \
# 218                                     .        empty  ...
# 335                                     -            -  ...
# 747   240 & 242, Gatore Road, Brahmapuri,        empty  ...
# 748   240 & 242, Gatore Road, Brahmapuri,        empty  ...
# 749   240 & 242, Gatore Road, Brahmapuri,        empty  ...
# 886                  karma royal monetrio       Arpora  ...
# 887                  karma royal monetrio       Arpora  ...
# 888                  karma royal monetrio       Arpora  ...
# 1250                                    -            -  ...
# 1357                                    .            .  ...
# 1358                                    .            .  ...
# 1359                                    .            .  ...
# 1360                                    .            .  ...
# 1363                                   MP        empty  ...
# 1571                                 Bali        empty  ...
#
#      Sales Rep and Comments Opt In     Contact Type Odyssey Members  \
# 218                   empty    YES       Email Only              NO
# 335                   empty     NO  Email and Phone              NO
# 747                   empty    YES  Email and Phone              NO
# 748                   empty    YES  Email and Phone              NO
# 749                   empty    YES  Email and Phone              NO
# 886                   empty    YES  Email and Phone              NO
# 887                   empty    YES  Email and Phone              NO
# 888                   empty    YES  Email and Phone              NO
# 1250                  empty    YES       Email Only              NO
# 1357                  empty    YES  Email and Phone              NO
# 1358                  empty    YES  Email and Phone              NO
# 1359                  empty    YES  Email and Phone              NO
# 1360                  empty    YES  Email and Phone              NO
# 1363                  empty    YES  Email and Phone              NO
# 1571                  empty    YES  Email and Phone              NO
#
#          Lead Brand Lead Sub-Brand  Lead Source  \
# 218   Karma Resorts          Other  Past Guests
# 335   Karma Resorts          Other  Past Guests
# 747   Karma Resorts          Other  Past Guests
# 748   Karma Resorts          Other  Past Guests
# 749   Karma Resorts          Other  Past Guests
# 886   Karma Resorts          Other  Past Guests
# 887   Karma Resorts          Other  Past Guests
# 888   Karma Resorts          Other  Past Guests
# 1250  Karma Resorts          Other  Past Guests
# 1357  Karma Resorts          Other  Past Guests
# 1358  Karma Resorts          Other  Past Guests
# 1359  Karma Resorts          Other  Past Guests
# 1360  Karma Resorts          Other  Past Guests
# 1363  Karma Resorts          Other  Past Guests
# 1571  Karma Resorts          Other  Past Guests
#
#                          Lead Locations Lead Source Description  \
# 218   Wyndham -  Manoir des Deux Amants               Viewpoint
# 335                Karma Utopia, Manali               Viewpoint
# 747                Karma Haveli, Jaipur               Viewpoint
# 748                Karma Haveli, Jaipur               Viewpoint
# 749                Karma Haveli, Jaipur               Viewpoint
# 886                Karma Royal Monterio               Viewpoint
# 887                Karma Royal Monterio               Viewpoint
# 888                Karma Royal Monterio               Viewpoint
# 1250           Karma Panalee, Koh Samui               Viewpoint
# 1357               Karma Chakra, Kerala               Viewpoint
# 1358               Karma Chakra, Kerala               Viewpoint
# 1359               Karma Munnar, Kerala               Viewpoint
# 1360               Karma Munnar, Kerala               Viewpoint
# 1363                  Karma Royal Palms               Viewpoint
# 1571           Karma Panalee, Koh Samui               Viewpoint
#
#      Exclude From Mailing
# 218                    NO
# 335                   YES
# 747                    NO
# 748                    NO
# 749                    NO
# 886                    NO
# 887                    NO
# 888                    NO
# 1250                   NO
# 1357                   NO
# 1358                   NO
# 1359                   NO
# 1360                   NO
# 1363                   NO
# 1571                   NO
#
# [15 rows x 37 columns]

# %%
# delete email Karma
count_after_clean_karma = m.delete_karma(df_viewpoint, 'Email')

df_viewpoint
# Out:
#      Title                            Firstname lastname                  DOB  \
# 0       Mr                                Derek   Martin  1959-05-25 00:00:00
# 1      Mrs                               Katrin    James  1982-07-13 00:00:00
# 2       Ms                                 Lois  Barnett                empty
# 3       Mr                                 Alan   Davies  1948-03-12 00:00:00
# 4      Mrs                                Maree   Dollin                empty
# ...    ...                                  ...      ...                  ...
# 1723   Mrs                          Ruth Veitch   Nicoll                empty
# 1724                                                   -                empty
# 1725                                                   -                empty
# 1726        Wallace, Christine & Racine, Martin        -                empty
# 1727   Krg                         Fajar Fatoni       86                empty
#
#      PAN CARD                     Email        Phone       Mobile  \
# 0       empty         59derek@gmail.com  61457330432        empty
# 1       empty  admin@karramindie.com.au  61890208036  61417368044
# 2       empty    ajwands@bigpond.net.au        empty        empty
# 3       empty  alandavies48@bigpond.com  61458551669        empty
# 4       empty     amharic2007@gmail.com  61458295886  61458295886
# ...       ...                       ...          ...          ...
# 1723    empty                                  empty        empty
# 1724    empty                                  empty        empty
# 1725    empty                                  empty        empty
# 1726    empty                                  empty        empty
# 1727    empty                                  empty        empty
#
#          AddressLine1 AddressLine2  ... Sales Rep and Comments Opt In  \
# 0     19 HABER STREET        empty  ...                Craig B    YES
# 1         PO BOX 2040        empty  ...                  empty    YES
# 2                   -        empty  ...                  empty    YES
# 3      6 LIDSDALE  ST        empty  ...                 Martin    YES
# 4          PO Box 197        empty  ...                  empty    YES
# ...               ...          ...  ...                    ...    ...
# 1723            empty        empty  ...                  empty    YES
# 1724            empty        empty  ...                  empty    YES
# 1725            empty        empty  ...                  empty    YES
# 1726            empty        empty  ...                  empty    YES
# 1727            empty        empty  ...                  empty  empty
#
#          Contact Type Odyssey Members     Lead Brand Lead Sub-Brand  \
# 0     Email and Phone              NO  Karma Resorts          Other
# 1     Email and Phone              NO  Karma Resorts          Other
# 2          Email Only              NO  Karma Resorts          Other
# 3     Email and Phone              NO  Karma Resorts          Other
# 4     Email and Phone              NO  Karma Resorts          Other
# ...               ...             ...            ...            ...
# 1723       Email Only              NO  Karma Resorts          Other
# 1724       Email Only              NO  Karma Resorts          Other
# 1725       Email Only              NO  Karma Resorts          Other
# 1726       Email Only              NO  Karma Resorts          Other
# 1727       Email Only              NO  Karma Resorts          Other
#
#       Lead Source                     Lead Locations Lead Source Description  \
# 0     Past Guests              Karma Royal Candidasa               Viewpoint
# 1     Past Guests       KRR @ Karma Kandara, Phase V               Viewpoint
# 2     Past Guests           Karma Panalee, Koh Samui               Viewpoint
# 3     Past Guests                     Karma Jimbaran               Viewpoint
# 4     Past Guests       KRR @ Karma Kandara, Phase V               Viewpoint
# ...           ...                                ...                     ...
# 1723  Past Guests             Karma Lake of Menteith               Viewpoint
# 1724  Past Guests               Karma Munnar, Kerala               Viewpoint
# 1725  Past Guests             Karma Sunshine Village               Viewpoint
# 1726  Past Guests  Wyndham -  Manoir des Deux Amants               Viewpoint
# 1727  Past Guests                              empty               Viewpoint
#
#      Exclude From Mailing
# 0                      NO
# 1                      NO
# 2                      NO
# 3                      NO
# 4                      NO
# ...                   ...
# 1723                   NO
# 1724                   NO
# 1725                   NO
# 1726                   NO
# 1727                  NaN
#
# [1728 rows x 37 columns]

# %%
# Cek leads test
test_leads = df_viewpoint.loc[
    
        df_viewpoint['Email'].str.contains('^test@', flags=re.I, regex=True) |
        df_viewpoint['Email'].str.contains('\+test', flags=re.I, regex=True) |
    
        df_viewpoint['Firstname'].str.contains('^test$', flags=re.I, regex=True) |
        df_viewpoint['lastname'].str.contains('^test$', flags=re.I, regex=True) |

        df_viewpoint['Firstname'].str.contains('test 1', flags=re.I, regex=True) |
        df_viewpoint['lastname'].str.contains('test 2', flags=re.I, regex=True)|
        df_viewpoint['Firstname'].str.contains('test1', flags=re.I, regex=True) |
        df_viewpoint['lastname'].str.contains('test2', flags=re.I, regex=True)|

        df_viewpoint['Firstname'].str.contains(' test ', flags=re.I, regex=True) | 
        df_viewpoint['lastname'].str.contains(' test ', flags=re.I, regex=True) | 
        df_viewpoint['lastname'].str.contains(' test$', flags=re.I, regex=True)
    ]

count_leads_test = test_leads.shape[0]

test_leads.to_csv(r'C:\Users\fajar.fatoni\Documents\Python\Data\test_leads_viewpoint.csv', index=False)
test_leads
# Out:
# Empty DataFrame
# Columns: [Title, Firstname, lastname, DOB, PAN CARD, Email, Phone, Mobile, AddressLine1, AddressLine2, Town, State, Country, PostCode, Nationality, MaritalStatus, resortname, Arrival, Departure, CheckInDate, CheckOutDate, room, UnitCategory, BookingNo, BookingSourceDesc, BookingTypeDesc, Date of Tour, Sales Rep and Comments, Opt In, Contact Type, Odyssey Members, Lead Brand, Lead Sub-Brand, Lead Source, Lead Locations, Lead Source Description, Exclude From Mailing]
# Index: []
#
# [0 rows x 37 columns]

# %%
df_viewpoint.drop(test_leads.index, inplace=True)
df_viewpoint.reset_index(drop=True, inplace=True)

count_after_dedup_test = df_viewpoint.shape[0]
count_after_dedup_test
# Out:
# 1728

# %%
count_final_data = count_after_dedup_test

# %%
# df_viewpoint.loc[df_viewpoint['BookingNo'] == '2070341']

# %%
df_viewpoint.replace('empty', '', inplace=True)

# %%
print("==========================================================")
print("Summary")
print("==========================================================")
print("Jumlah Data Awal Viewpoint : "+str(count_data_awal))
print("Jumlah Data Email dan Phone Kosong : "+str(count_contact_type_empty))
print("Jumlah Data Setelah Hapus Email dan Phone Yang Kosong : "+str(count_after_contact_type_empty))
print("Jumlah Data Email Yang Termasuk List Karma : "+str(count_email_karma))
print("Jumlah Data Email Setelah List Karma Dihapus : "+str(count_after_clean_karma))
print("Jumlah Data Test : "+str(count_leads_test))
print("Jumlah Data Email Setelah Data Test Dihapus : "+str(count_after_dedup_test))
print("Jumlah Data Akhir : "+str(count_final_data))
# Out:
# ==========================================================
# Summary
# ==========================================================
# Jumlah Data Awal Viewpoint : 1743
# Jumlah Data Email dan Phone Kosong : 0
# Jumlah Data Setelah Hapus Email dan Phone Yang Kosong : 1743
# Jumlah Data Email Yang Termasuk List Karma : 15
# Jumlah Data Email Setelah List Karma Dihapus : 1728
# Jumlah Data Test : 0
# Jumlah Data Email Setelah Data Test Dihapus : 1728
# Jumlah Data Akhir : 1728

# %%
df_viewpoint.to_excel(r'C:\Users\fajar.fatoni\Documents\Python\Data\check_country_code_viewpoint.xlsx', index=False)
