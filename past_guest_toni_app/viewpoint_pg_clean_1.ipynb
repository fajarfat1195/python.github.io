# %%
import pandas as pd
import re

import past_guest_module as pm

import sys
sys.path.append('../zoho_data_app/')

import main_module as m

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
path = r'C:\Users\fajar\Documents\Python\Data\Past Guest Data\View Point\2024\Okt\13 Okt - 21 Okt\CheckOutReport 13 Okt - 21 Okt.xlsx'
df_viewpoint = pd.read_excel(path, dtype='string', sheet_name='Sheet1')
count_data_awal = df_viewpoint.shape[0]
df_viewpoint
# Out:
#      Title     Firstname lastname                  DOB    PAN CARD  \
# 0      Mrs  Chandrakanta   Kumari  1996-11-13 00:00:00  IKFPK3006M
# 1       Mr     YOSHIYUKI   FUJITA                 <NA>        <NA>
# 2      Dr.        Allama   Prabhu                 <NA>        <NA>
# 3       Ms         Aasha     Anam  1982-04-04 00:00:00        <NA>
# 4       Mr     Aashutosh    Bhatt  1984-06-01 00:00:00  APGPB7428E
# ...    ...           ...      ...                  ...         ...
# 1946  <NA>       Aurelie   ARMATA                 <NA>        <NA>
# 1947  <NA>     Bérangère  Rousset                 <NA>        <NA>
# 1948  <NA>       Laurent   Aurore                 <NA>        <NA>
# 1949  <NA>      Emmanuel  Leonard                 <NA>        <NA>
# 1950   krg  Fajar Fatoni       86                 <NA>        <NA>
#
#                         Email         Phone        Mobile  \
# 0       28singh.jai@gmail.com  919742963150  917892801312
# 1        77253KI445@GMAIL.COM  819061037252  818066526040
# 2     aallam_prabhu@yahoo.com  918801933333          <NA>
# 3      aashaanam_@hotmail.com  447930673855  447930673855
# 4     aashutosh0412@gmail.com  919829596807  919887736807
# ...                       ...           ...           ...
# 1946                     <NA>          <NA>          <NA>
# 1947                     <NA>          <NA>          <NA>
# 1948                     <NA>          <NA>          <NA>
# 1949                     <NA>          <NA>          <NA>
# 1950                     <NA>          <NA>          <NA>
#
#                                      AddressLine1 AddressLine2  ...  \
# 0     VILL MOHADDIGANJ, BALUATOLA P.O P.S SASARAM         <NA>  ...
# 1                       4 4 7 302 KUGENUMA SHINME         <NA>  ...
# 2                                               .         <NA>  ...
# 3                                  44 EXETER ROAD         <NA>  ...
# 4                       BARUNDANI,TEH MANDAL GARH         <NA>  ...
# ...                                           ...          ...  ...
# 1946                                            -         <NA>  ...
# 1947                                            -         <NA>  ...
# 1948                                            -         <NA>  ...
# 1949                                            -         <NA>  ...
# 1950                                         <NA>         <NA>  ...
#
#               CheckInDate         CheckOutDate  room          UnitCategory  \
# 0     2024-10-16 15:34:58  2024-10-19 11:17:19   303            Hotel Unit
# 1     2024-10-12 12:23:51  2024-10-19 10:21:38   115      Studio Apartment
# 2     2024-10-15 15:43:32  2024-10-17 07:44:44   204            Hotel Unit
# 3     2024-10-14 13:53:01  2024-10-14 23:04:45    06     Hotel Unit Deluxe
# 4     2024-10-14 15:30:31  2024-10-16 10:16:34  V333  2 Bedroom Fractional
# ...                   ...                  ...   ...                   ...
# 1946  2024-10-19 23:00:21  2024-10-20 12:59:03   114   1 Bedroom Apartment
# 1947  2024-10-19 22:56:11  2024-10-20 15:13:07   123   2 Bedroom Apartment
# 1948  2024-10-19 23:37:57  2024-10-20 15:58:59   121      Studio Apartment
# 1949  2024-10-17 23:11:47  2024-10-20 16:06:07   211   1 Bedroom Apartment
# 1950                 <NA>                 <NA>  <NA>                  <NA>
#
#      BookingNo    BookingSourceDesc           BookingTypeDesc  \
# 0      2625021          KCE2 Indian    Karma Experience India
# 1      2263528  RCI Member (non KG)  Deposit: Karma Concierge
# 2      2513200      Guest of Member         Entitlement Guest
# 3      2508630            KC Member        Entitlement Member
# 4      2630001            KC Member                Sales Gift
# ...        ...                  ...                       ...
# 1946   2655754       Hotel Bookings               Booking.com
# 1947   2655773       Hotel Bookings               Booking.com
# 1948   2655762       Hotel Bookings               Booking.com
# 1949   2655714       Hotel Bookings               Booking.com
# 1950      <NA>                 <NA>                      <NA>
#
#              Date of Tour Sales Rep and Comments Opt In
# 0                    <NA>                   <NA>    YES
# 1     2024-10-15 09:00:00                Kevin L    YES
# 2                    <NA>                   <NA>    YES
# 3                    <NA>                   <NA>    YES
# 4     2024-10-16 10:30:00     PRATEEK CHATURVEDI    YES
# ...                   ...                    ...    ...
# 1946                 <NA>                   <NA>    YES
# 1947                 <NA>                   <NA>    YES
# 1948                 <NA>                   <NA>    YES
# 1949                 <NA>                   <NA>    YES
# 1950                 <NA>                   <NA>   <NA>
#
# [1951 rows x 29 columns]

# %%
df_viewpoint.columns
# Out:
# Index(['Title', 'Firstname', 'lastname', 'DOB', 'PAN CARD', 'Email', 'Phone',
#        'Mobile', 'AddressLine1', 'AddressLine2', 'Town', 'State', 'Country',
#        'PostCode', 'Nationality', 'MaritalStatus', 'resortname', 'Arrival',
#        'Departure', 'CheckInDate', 'CheckOutDate', 'room', 'UnitCategory',
#        'BookingNo', 'BookingSourceDesc', 'BookingTypeDesc', 'Date of Tour',
#        'Sales Rep and Comments', 'Opt In'],
#       dtype='object')

# %%
df_viewpoint.fillna('empty', inplace=True)

df_viewpoint['Contact Type'] = 'empty'
df_viewpoint['Odyssey Members'] = 'NO'

df_viewpoint['Lead Brand'] = 'Karma Resorts'
df_viewpoint['Lead Sub-Brand'] = 'Other'
df_viewpoint['Lead Source'] = 'Past Guests'
df_viewpoint['Lead Locations'] = df_viewpoint['resortname']
df_viewpoint['Lead Source Description'] = 'Viewpoint'

# %%
df_viewpoint.loc[df_viewpoint['Opt In'] == 'YES', 'Exclude From Mailing'] = 'NO'
df_viewpoint.loc[df_viewpoint['Opt In'] == 'NO', 'Exclude From Mailing'] = 'YES'

# %%
df_viewpoint.loc[df_viewpoint['lastname'] == 'empty', 'lastname'] = '-'

# %%
df_viewpoint['Title'].replace('empty', '', inplace=True)
df_viewpoint['Firstname'].replace('empty', '', inplace=True)
df_viewpoint['lastname'].replace('empty', '', inplace=True)

df_viewpoint['Title'] = df_viewpoint['Title'].str.title()
df_viewpoint['Firstname'] = df_viewpoint['Firstname'].str.title()
df_viewpoint['lastname'] = df_viewpoint['lastname'].str.title()

df_viewpoint
# Out:
# C:\Users\fajar\AppData\Local\Temp\ipykernel_7984\3404343493.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_viewpoint['Title'].replace('empty', '', inplace=True)
# C:\Users\fajar\AppData\Local\Temp\ipykernel_7984\3404343493.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_viewpoint['Firstname'].replace('empty', '', inplace=True)
# C:\Users\fajar\AppData\Local\Temp\ipykernel_7984\3404343493.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_viewpoint['lastname'].replace('empty', '', inplace=True)
#      Title     Firstname lastname                  DOB    PAN CARD  \
# 0      Mrs  Chandrakanta   Kumari  1996-11-13 00:00:00  IKFPK3006M
# 1       Mr     Yoshiyuki   Fujita                empty       empty
# 2      Dr.        Allama   Prabhu                empty       empty
# 3       Ms         Aasha     Anam  1982-04-04 00:00:00       empty
# 4       Mr     Aashutosh    Bhatt  1984-06-01 00:00:00  APGPB7428E
# ...    ...           ...      ...                  ...         ...
# 1946             Aurelie   Armata                empty       empty
# 1947           Bérangère  Rousset                empty       empty
# 1948             Laurent   Aurore                empty       empty
# 1949            Emmanuel  Leonard                empty       empty
# 1950   Krg  Fajar Fatoni       86                empty       empty
#
#                         Email         Phone        Mobile  \
# 0       28singh.jai@gmail.com  919742963150  917892801312
# 1        77253KI445@GMAIL.COM  819061037252  818066526040
# 2     aallam_prabhu@yahoo.com  918801933333         empty
# 3      aashaanam_@hotmail.com  447930673855  447930673855
# 4     aashutosh0412@gmail.com  919829596807  919887736807
# ...                       ...           ...           ...
# 1946                    empty         empty         empty
# 1947                    empty         empty         empty
# 1948                    empty         empty         empty
# 1949                    empty         empty         empty
# 1950                    empty         empty         empty
#
#                                      AddressLine1 AddressLine2  ...  \
# 0     VILL MOHADDIGANJ, BALUATOLA P.O P.S SASARAM        empty  ...
# 1                       4 4 7 302 KUGENUMA SHINME        empty  ...
# 2                                               .        empty  ...
# 3                                  44 EXETER ROAD        empty  ...
# 4                       BARUNDANI,TEH MANDAL GARH        empty  ...
# ...                                           ...          ...  ...
# 1946                                            -        empty  ...
# 1947                                            -        empty  ...
# 1948                                            -        empty  ...
# 1949                                            -        empty  ...
# 1950                                        empty        empty  ...
#
#      Sales Rep and Comments Opt In Contact Type Odyssey Members  \
# 0                     empty    YES        empty              NO
# 1                   Kevin L    YES        empty              NO
# 2                     empty    YES        empty              NO
# 3                     empty    YES        empty              NO
# 4        PRATEEK CHATURVEDI    YES        empty              NO
# ...                     ...    ...          ...             ...
# 1946                  empty    YES        empty              NO
# 1947                  empty    YES        empty              NO
# 1948                  empty    YES        empty              NO
# 1949                  empty    YES        empty              NO
# 1950                  empty  empty        empty              NO
#
#          Lead Brand Lead Sub-Brand  Lead Source  \
# 0     Karma Resorts          Other  Past Guests
# 1     Karma Resorts          Other  Past Guests
# 2     Karma Resorts          Other  Past Guests
# 3     Karma Resorts          Other  Past Guests
# 4     Karma Resorts          Other  Past Guests
# ...             ...            ...          ...
# 1946  Karma Resorts          Other  Past Guests
# 1947  Karma Resorts          Other  Past Guests
# 1948  Karma Resorts          Other  Past Guests
# 1949  Karma Resorts          Other  Past Guests
# 1950  Karma Resorts          Other  Past Guests
#
#                          Lead Locations Lead Source Description  \
# 0                  Karma Martam Retreat               Viewpoint
# 1                     Karma Royal Sanur               Viewpoint
# 2                  Karma Haveli, Jaipur               Viewpoint
# 3        Chateau de Samary, Carcassonne               Viewpoint
# 4              Karma Royal Haathi Mahal               Viewpoint
# ...                                 ...                     ...
# 1946  Wyndham -  Manoir des Deux Amants               Viewpoint
# 1947  Wyndham -  Manoir des Deux Amants               Viewpoint
# 1948  Wyndham -  Manoir des Deux Amants               Viewpoint
# 1949  Wyndham -  Manoir des Deux Amants               Viewpoint
# 1950                              empty               Viewpoint
#
#      Exclude From Mailing
# 0                      NO
# 1                      NO
# 2                      NO
# 3                      NO
# 4                      NO
# ...                   ...
# 1946                   NO
# 1947                   NO
# 1948                   NO
# 1949                   NO
# 1950                  NaN
#
# [1951 rows x 37 columns]

# %%
m.clean_number(df_viewpoint, 'Phone')
m.clean_number(df_viewpoint, 'Mobile')
m.replace_not_valid_to_empty(df_viewpoint, 'Phone')
m.replace_not_valid_to_empty(df_viewpoint, 'Mobile')

df_viewpoint.loc[df_viewpoint['Phone'].str.contains('00000'), 'Phone'] = 'empty'
df_viewpoint.loc[df_viewpoint['Mobile'].str.contains('00000'), 'Mobile'] = 'empty'

m.clean_space(df_viewpoint, 'Email')
df_viewpoint['Email'] = m.lowercase(df_viewpoint, 'Email')
# Out:
# c:\Users\fajar\Documents\Python\Task Offline\past_guest_toni_app\../zoho_data_app\main_module.py:67: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[df_columns].replace(' ','', regex=True, inplace=True)
# c:\Users\fajar\Documents\Python\Task Offline\past_guest_toni_app\../zoho_data_app\main_module.py:68: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[df_columns].replace('[^0-9]','', regex=True, inplace=True)
# c:\Users\fajar\Documents\Python\Task Offline\past_guest_toni_app\../zoho_data_app\main_module.py:90: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[df_columns].replace(' ','', regex=True, inplace=True)

# %%
m.email_correction(df_viewpoint, 'Email')
# Out:
# c:\Users\fajar\Documents\Python\Task Offline\past_guest_toni_app\past_guest_module.py:25: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[df_columns].replace('|'.join(list_correction_mail), '@mail.', regex=True, inplace=True)
# c:\Users\fajar\Documents\Python\Task Offline\past_guest_toni_app\past_guest_module.py:31: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[df_columns].replace('|'.join(list_correction_gmail), '@gmail.', regex=True, inplace=True)
# c:\Users\fajar\Documents\Python\Task Offline\past_guest_toni_app\past_guest_module.py:35: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[df_columns].replace('|'.join(list_correction_gmail_com), '@gmail.com', regex=True, inplace=True)
# c:\Users\fajar\Documents\Python\Task Offline\past_guest_toni_app\past_guest_module.py:38: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[df_columns].replace('|'.join(list_correction_hotmail), '@hotmail.', regex=True, inplace=True)
# c:\Users\fajar\Documents\Python\Task Offline\past_guest_toni_app\past_guest_module.py:41: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[df_columns].replace('|'.join(list_correction_hotmail_com), '@hotmail.com', regex=True, inplace=True)
# c:\Users\fajar\Documents\Python\Task Offline\past_guest_toni_app\past_guest_module.py:45: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[df_columns].replace('|'.join(list_correction_yahoo), '@yahoo.', regex=True, inplace=True)
# c:\Users\fajar\Documents\Python\Task Offline\past_guest_toni_app\past_guest_module.py:48: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[df_columns].replace('|'.join(list_correction_ymail), '@ymail.', regex=True, inplace=True)

# %%
df_viewpoint.loc[(df_viewpoint['Email'] != 'empty') & ((df_viewpoint['Phone'] != 'empty') | (df_viewpoint['Mobile'] != 'empty')), 'Contact Type'] = 'Email and Phone'
df_viewpoint.loc[(df_viewpoint['Email'] != 'empty') & ((df_viewpoint['Phone'] == 'empty') & (df_viewpoint['Mobile'] == 'empty')), 'Contact Type'] = 'Email Only'
df_viewpoint.loc[(df_viewpoint['Email'] == 'empty') & ((df_viewpoint['Phone'] != 'empty') | (df_viewpoint['Mobile'] != 'empty')), 'Contact Type'] = 'Phone Only'

df_viewpoint.loc[df_viewpoint['Contact Type'] == 'empty'].to_csv(r'C:\Users\fajar\Documents\Python\Data\contact_type_empty_viewpoint.csv', index=False)

count_contact_type_empty = df_viewpoint.loc[df_viewpoint['Contact Type'] == 'empty'].shape[0]

df_viewpoint.drop(df_viewpoint.loc[df_viewpoint['Contact Type'] == 'empty'].index, inplace=True)
df_viewpoint.reset_index(drop=True, inplace=True)

count_after_contact_type_empty = df_viewpoint.shape[0]

df_viewpoint
# Out:
#      Title        Firstname     lastname                  DOB    PAN CARD  \
# 0      Mrs     Chandrakanta       Kumari  1996-11-13 00:00:00  IKFPK3006M
# 1       Mr        Yoshiyuki       Fujita                empty       empty
# 2      Dr.           Allama       Prabhu                empty       empty
# 3       Ms            Aasha         Anam  1982-04-04 00:00:00       empty
# 4       Mr        Aashutosh        Bhatt  1984-06-01 00:00:00  APGPB7428E
# ...    ...              ...          ...                  ...         ...
# 1853    Mr           Yuvraj        Singh                empty       empty
# 1854    Mr            Rowan       Davies                empty       empty
# 1855    Mr          Vincent       Pierre                empty       empty
# 1856     -   Adeline Richer       Richer                empty       empty
# 1857     -            Bruno  De De Pirey                empty       empty
#
#                         Email         Phone        Mobile  \
# 0       28singh.jai@gmail.com  919742963150  917892801312
# 1        77253ki445@gmail.com  819061037252  818066526040
# 2     aallam_prabhu@yahoo.com  918801933333         empty
# 3      aashaanam_@hotmail.com  447930673855  447930673855
# 4     aashutosh0412@gmail.com  919829596807  919887736807
# ...                       ...           ...           ...
# 1853                    empty  919560955784         empty
# 1854                    empty   61412501969   61412501969
# 1855                    empty   33611121314         empty
# 1856                    empty   33768586876         empty
# 1857                    empty   33644067358         empty
#
#                                      AddressLine1    AddressLine2  ...  \
# 0     VILL MOHADDIGANJ, BALUATOLA P.O P.S SASARAM           empty  ...
# 1                       4 4 7 302 KUGENUMA SHINME           empty  ...
# 2                                               .           empty  ...
# 3                                  44 EXETER ROAD           empty  ...
# 4                       BARUNDANI,TEH MANDAL GARH           empty  ...
# ...                                           ...             ...  ...
# 1853                                       BHOPAL  MADHYA PRADESH  ...
# 1854                                            -              --  ...
# 1855                                            .               .  ...
# 1856                                        empty           empty  ...
# 1857                       PE PIREI DESIGN STUDIO           empty  ...
#
#      Sales Rep and Comments Opt In     Contact Type Odyssey Members  \
# 0                     empty    YES  Email and Phone              NO
# 1                   Kevin L    YES  Email and Phone              NO
# 2                     empty    YES  Email and Phone              NO
# 3                     empty    YES  Email and Phone              NO
# 4        PRATEEK CHATURVEDI    YES  Email and Phone              NO
# ...                     ...    ...              ...             ...
# 1853                  empty    YES       Phone Only              NO
# 1854                  empty    YES       Phone Only              NO
# 1855                  empty    YES       Phone Only              NO
# 1856                  empty    YES       Phone Only              NO
# 1857                  empty    YES       Phone Only              NO
#
#          Lead Brand Lead Sub-Brand  Lead Source  \
# 0     Karma Resorts          Other  Past Guests
# 1     Karma Resorts          Other  Past Guests
# 2     Karma Resorts          Other  Past Guests
# 3     Karma Resorts          Other  Past Guests
# 4     Karma Resorts          Other  Past Guests
# ...             ...            ...          ...
# 1853  Karma Resorts          Other  Past Guests
# 1854  Karma Resorts          Other  Past Guests
# 1855  Karma Resorts          Other  Past Guests
# 1856  Karma Resorts          Other  Past Guests
# 1857  Karma Resorts          Other  Past Guests
#
#                                Lead Locations Lead Source Description  \
# 0                        Karma Martam Retreat               Viewpoint
# 1                           Karma Royal Sanur               Viewpoint
# 2                        Karma Haveli, Jaipur               Viewpoint
# 3              Chateau de Samary, Carcassonne               Viewpoint
# 4                    Karma Royal Haathi Mahal               Viewpoint
# ...                                       ...                     ...
# 1853                   Karma Sunshine Village               Viewpoint
# 1854  KRR @ Karma Kandara, Mentari Residences               Viewpoint
# 1855        Wyndham -  Manoir des Deux Amants               Viewpoint
# 1856        Wyndham -  Manoir des Deux Amants               Viewpoint
# 1857        Wyndham -  Manoir des Deux Amants               Viewpoint
#
#      Exclude From Mailing
# 0                      NO
# 1                      NO
# 2                      NO
# 3                      NO
# 4                      NO
# ...                   ...
# 1853                   NO
# 1854                   NO
# 1855                   NO
# 1856                   NO
# 1857                   NO
#
# [1858 rows x 37 columns]

# %%
# Cek Email Karma
email_karma = m.find_karma(df_viewpoint, 'Email')
count_email_karma = email_karma.shape[0]
email_karma.to_csv(r'C:\Users\fajar\Documents\Python\Data\email_deleted_viewpoint.csv', index=False)

email_karma
# Out:
#      Title           Firstname              lastname    DOB PAN CARD  \
# 330           Maintenance Room          Karma Chakra  empty    empty
# 975      -  Maintenance Room -  Karma Royal Monterio  empty    empty
# 1546    Mr              Sandip                 Patel  empty    empty
# 1547    Mr              Sandip                 Patel  empty    empty
# 1729    Mr            Valerios             Koutsonis  empty    empty
#
#                                   Email         Phone        Mobile  \
# 330               chakra@karmagroup.com  914812526252  919446080121
# 975           mr.asstfom@karmagroup.com  918326716200         empty
# 1546    sheldon.dias@karmaexperience.in  919313070083  919714081449
# 1547    sheldon.dias@karmaexperience.in  919313070083  919714081449
# 1729  valerios.koutsonis@karmagroup.com         empty         empty
#
#                                   AddressLine1                 AddressLine2  \
# 330   Ward # 09, Block#12, Near Nasrath Church                     KOTTAYAM
# 975                       karma royal monetrio                       Arpora
# 1546          KALIDAS SHANKAR FALIYU KOTHAMBA-  TA-LUNAWADA,DIST -MAHISAGAR
# 1547          KALIDAS SHANKAR FALIYU KOTHAMBA-  TA-LUNAWADA,DIST -MAHISAGAR
# 1729                                    France                        empty
#
#       ... Sales Rep and Comments Opt In     Contact Type Odyssey Members  \
# 330   ...                  empty    YES  Email and Phone              NO
# 975   ...                  empty    YES  Email and Phone              NO
# 1546  ...        Vaishali Tiwari    YES  Email and Phone              NO
# 1547  ...        Vaishali Tiwari    YES  Email and Phone              NO
# 1729  ...                  empty    YES       Email Only              NO
#
#          Lead Brand Lead Sub-Brand  Lead Source                Lead Locations  \
# 330   Karma Resorts          Other  Past Guests          Karma Chakra, Kerala
# 975   Karma Resorts          Other  Past Guests          Karma Royal Monterio
# 1546  Karma Resorts          Other  Past Guests  Karma Golden Camp, Jaisalmer
# 1547  Karma Resorts          Other  Past Guests  Karma Golden Camp, Jaisalmer
# 1729  Karma Resorts          Other  Past Guests                  Karma Minoan
#
#      Lead Source Description Exclude From Mailing
# 330                Viewpoint                   NO
# 975                Viewpoint                   NO
# 1546               Viewpoint                   NO
# 1547               Viewpoint                   NO
# 1729               Viewpoint                   NO
#
# [5 rows x 37 columns]

# %%
# delete email Karma
count_after_clean_karma = m.delete_karma(df_viewpoint, 'Email')

df_viewpoint
# Out:
#      Title        Firstname     lastname                  DOB    PAN CARD  \
# 0      Mrs     Chandrakanta       Kumari  1996-11-13 00:00:00  IKFPK3006M
# 1       Mr        Yoshiyuki       Fujita                empty       empty
# 2      Dr.           Allama       Prabhu                empty       empty
# 3       Ms            Aasha         Anam  1982-04-04 00:00:00       empty
# 4       Mr        Aashutosh        Bhatt  1984-06-01 00:00:00  APGPB7428E
# ...    ...              ...          ...                  ...         ...
# 1848    Mr           Yuvraj        Singh                empty       empty
# 1849    Mr            Rowan       Davies                empty       empty
# 1850    Mr          Vincent       Pierre                empty       empty
# 1851     -   Adeline Richer       Richer                empty       empty
# 1852     -            Bruno  De De Pirey                empty       empty
#
#                         Email         Phone        Mobile  \
# 0       28singh.jai@gmail.com  919742963150  917892801312
# 1        77253ki445@gmail.com  819061037252  818066526040
# 2     aallam_prabhu@yahoo.com  918801933333         empty
# 3      aashaanam_@hotmail.com  447930673855  447930673855
# 4     aashutosh0412@gmail.com  919829596807  919887736807
# ...                       ...           ...           ...
# 1848                    empty  919560955784         empty
# 1849                    empty   61412501969   61412501969
# 1850                    empty   33611121314         empty
# 1851                    empty   33768586876         empty
# 1852                    empty   33644067358         empty
#
#                                      AddressLine1    AddressLine2  ...  \
# 0     VILL MOHADDIGANJ, BALUATOLA P.O P.S SASARAM           empty  ...
# 1                       4 4 7 302 KUGENUMA SHINME           empty  ...
# 2                                               .           empty  ...
# 3                                  44 EXETER ROAD           empty  ...
# 4                       BARUNDANI,TEH MANDAL GARH           empty  ...
# ...                                           ...             ...  ...
# 1848                                       BHOPAL  MADHYA PRADESH  ...
# 1849                                            -              --  ...
# 1850                                            .               .  ...
# 1851                                        empty           empty  ...
# 1852                       PE PIREI DESIGN STUDIO           empty  ...
#
#      Sales Rep and Comments Opt In     Contact Type Odyssey Members  \
# 0                     empty    YES  Email and Phone              NO
# 1                   Kevin L    YES  Email and Phone              NO
# 2                     empty    YES  Email and Phone              NO
# 3                     empty    YES  Email and Phone              NO
# 4        PRATEEK CHATURVEDI    YES  Email and Phone              NO
# ...                     ...    ...              ...             ...
# 1848                  empty    YES       Phone Only              NO
# 1849                  empty    YES       Phone Only              NO
# 1850                  empty    YES       Phone Only              NO
# 1851                  empty    YES       Phone Only              NO
# 1852                  empty    YES       Phone Only              NO
#
#          Lead Brand Lead Sub-Brand  Lead Source  \
# 0     Karma Resorts          Other  Past Guests
# 1     Karma Resorts          Other  Past Guests
# 2     Karma Resorts          Other  Past Guests
# 3     Karma Resorts          Other  Past Guests
# 4     Karma Resorts          Other  Past Guests
# ...             ...            ...          ...
# 1848  Karma Resorts          Other  Past Guests
# 1849  Karma Resorts          Other  Past Guests
# 1850  Karma Resorts          Other  Past Guests
# 1851  Karma Resorts          Other  Past Guests
# 1852  Karma Resorts          Other  Past Guests
#
#                                Lead Locations Lead Source Description  \
# 0                        Karma Martam Retreat               Viewpoint
# 1                           Karma Royal Sanur               Viewpoint
# 2                        Karma Haveli, Jaipur               Viewpoint
# 3              Chateau de Samary, Carcassonne               Viewpoint
# 4                    Karma Royal Haathi Mahal               Viewpoint
# ...                                       ...                     ...
# 1848                   Karma Sunshine Village               Viewpoint
# 1849  KRR @ Karma Kandara, Mentari Residences               Viewpoint
# 1850        Wyndham -  Manoir des Deux Amants               Viewpoint
# 1851        Wyndham -  Manoir des Deux Amants               Viewpoint
# 1852        Wyndham -  Manoir des Deux Amants               Viewpoint
#
#      Exclude From Mailing
# 0                      NO
# 1                      NO
# 2                      NO
# 3                      NO
# 4                      NO
# ...                   ...
# 1848                   NO
# 1849                   NO
# 1850                   NO
# 1851                   NO
# 1852                   NO
#
# [1853 rows x 37 columns]

# %%
# Cek leads test
test_leads = df_viewpoint.loc[
    
        df_viewpoint['Email'].str.contains('^test@', flags=re.I, regex=True) |
        df_viewpoint['Email'].str.contains('\+test', flags=re.I, regex=True) |
    
        df_viewpoint['Firstname'].str.contains('^test$', flags=re.I, regex=True) |
        df_viewpoint['lastname'].str.contains('^test$', flags=re.I, regex=True) |

        df_viewpoint['Firstname'].str.contains('test 1', flags=re.I, regex=True) |
        df_viewpoint['lastname'].str.contains('test 2', flags=re.I, regex=True)|
        df_viewpoint['Firstname'].str.contains('test1', flags=re.I, regex=True) |
        df_viewpoint['lastname'].str.contains('test2', flags=re.I, regex=True)|

        df_viewpoint['Firstname'].str.contains(' test ', flags=re.I, regex=True) | 
        df_viewpoint['lastname'].str.contains(' test ', flags=re.I, regex=True) | 
        df_viewpoint['lastname'].str.contains(' test$', flags=re.I, regex=True)
    ]

count_leads_test = test_leads.shape[0]

test_leads.to_csv(r'C:\Users\fajar\Documents\Python\Data\test_leads_viewpoint.csv', index=False)
test_leads
# Out:
# Empty DataFrame
# Columns: [Title, Firstname, lastname, DOB, PAN CARD, Email, Phone, Mobile, AddressLine1, AddressLine2, Town, State, Country, PostCode, Nationality, MaritalStatus, resortname, Arrival, Departure, CheckInDate, CheckOutDate, room, UnitCategory, BookingNo, BookingSourceDesc, BookingTypeDesc, Date of Tour, Sales Rep and Comments, Opt In, Contact Type, Odyssey Members, Lead Brand, Lead Sub-Brand, Lead Source, Lead Locations, Lead Source Description, Exclude From Mailing]
# Index: []
#
# [0 rows x 37 columns]

# %%
df_viewpoint.drop(test_leads.index, inplace=True)
df_viewpoint.reset_index(drop=True, inplace=True)

count_after_dedup_test = df_viewpoint.shape[0]
count_after_dedup_test
# Out:
# 1853

# %%
count_final_data = count_after_dedup_test

# %%
# df_viewpoint.loc[df_viewpoint['BookingNo'] == '2070341']

# %%
df_viewpoint.replace('empty', '', inplace=True)

# %%
print("==========================================================")
print("Summary")
print("==========================================================")
print("Jumlah Data Awal Viewpoint : "+str(count_data_awal))
print("Jumlah Data Email dan Phone Kosong : "+str(count_contact_type_empty))
print("Jumlah Data Setelah Hapus Email dan Phone Yang Kosong : "+str(count_after_contact_type_empty))
print("Jumlah Data Email Yang Termasuk List Karma : "+str(count_email_karma))
print("Jumlah Data Email Setelah List Karma Dihapus : "+str(count_after_clean_karma))
print("Jumlah Data Test : "+str(count_leads_test))
print("Jumlah Data Email Setelah Data Test Dihapus : "+str(count_after_dedup_test))
print("Jumlah Data Akhir : "+str(count_final_data))
# Out:
# ==========================================================
# Summary
# ==========================================================
# Jumlah Data Awal Viewpoint : 1951
# Jumlah Data Email dan Phone Kosong : 93
# Jumlah Data Setelah Hapus Email dan Phone Yang Kosong : 1858
# Jumlah Data Email Yang Termasuk List Karma : 5
# Jumlah Data Email Setelah List Karma Dihapus : 1853
# Jumlah Data Test : 0
# Jumlah Data Email Setelah Data Test Dihapus : 1853
# Jumlah Data Akhir : 1853

# %%
df_viewpoint.to_excel(r'C:\Users\fajar\Documents\Python\Data\check_country_code_viewpoint.xlsx', index=False)
