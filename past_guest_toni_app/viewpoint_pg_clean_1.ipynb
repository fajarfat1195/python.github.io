# %%
import pandas as pd
import re

import past_guest_module as pm

import sys
sys.path.append('../zoho_data_app/')

import main_module as m

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# path = r'C:\Users\fajar.fatoni\Documents\Python\Data\Past Guest Data\View Point\2025\Jun\15 Jun - 24 Jun\CheckOutReport 15 Jun - 24 Jun.xlsx'
path = r'C:\Users\fajar.fatoni\Documents\Python\Data\CheckOutReport KLH.xlsx'
df_viewpoint = pd.read_excel(path, dtype='string', sheet_name='Sheet1')
count_data_awal = df_viewpoint.shape[0]
df_viewpoint
# Out:
#     Title     Firstname       lastname                  DOB    PAN CARD  \
# 0      Mr       Winayak        Karikar  1972-02-18 00:00:00  DSWPK2349B
# 1     Mrs       Bobette      Hitchcock  1982-10-08 00:00:00        <NA>
# 2      Mr         Dario      Quinteros                 <NA>        <NA>
# 3      Ms         Lizzy         McLean                 <NA>        <NA>
# 4     Mrs        Renata    Komarzinska                 <NA>        <NA>
# ..    ...           ...            ...                  ...         ...
# 319    Mr         Yared          Woldu  1994-05-07 00:00:00        <NA>
# 320    Mr       Orlaith          Joyce                 <NA>        <NA>
# 321   Mrs         Timea  Jaro Malisova  1977-04-24 00:00:00        <NA>
# 322    Mr      Devanand        Ranlaul  1952-05-05 00:00:00        <NA>
# 323   krg  Fajar Fatoni             86                 <NA>        <NA>
#
#                                 Email         Phone       Mobile  \
# 0               v_karikar@hotmail.com   17039737611  17039737611
# 1             bo.hitchcock@live.co.uk  447540094374         <NA>
# 2        reception@karmalaherriza.com          <NA>         <NA>
# 3    vanessamarquezcorbacho@gmail.com          <NA>         <NA>
# 4        reception@karmalaherriza.com          <NA>         <NA>
# ..                                ...           ...          ...
# 319                yarwol24@gmail.com   46704126394  46762850282
# 320  vanessamarquezcorbacho@gmail.com          <NA>         <NA>
# 321                    mtimea@azet.sk  447732558057         <NA>
# 322           amritaran0902@gmail.com    2306744739  23059151767
# 323                              <NA>          <NA>         <NA>
#
#                    AddressLine1 AddressLine2  ...          CheckInDate  \
# 0    25067 Great Berkhamsted Dr         <NA>  ...  2025-03-30 03:15:10
# 1                 7 TIGER GROVE   midge hall  ...  2025-03-29 21:24:32
# 2                           TBA         <NA>  ...  2025-03-29 20:03:28
# 3                           TBA         <NA>  ...  2025-03-29 20:00:55
# 4                           TBA         <NA>  ...  2025-03-30 02:36:07
# ..                          ...          ...  ...                  ...
# 319   GAMLA, HUDDINGEVAGEN 719A         <NA>  ...  2025-06-20 18:49:09
# 320                         TBA          TBA  ...  2025-06-24 19:54:17
# 321                8 Harris Way         <NA>  ...  2025-06-22 00:16:02
# 322     MORC. ADAMS, EAU COULEE         <NA>  ...  2025-06-22 20:21:33
# 323                        <NA>         <NA>  ...                 <NA>
#
#             CheckOutDate  room         UnitCategory BookingNo  \
# 0    2025-04-01 17:55:51     2      2 Bedroom (4+1)   2765313
# 1    2025-04-01 18:03:52    20     Studio Apartment   2578453
# 2    2025-04-01 18:08:59    10  1 Bedroom Apartment   2740798
# 3    2025-04-01 18:13:28     4      2 Bedroom (4+2)   2775246
# 4    2025-04-01 20:59:04     7  1 Bedroom Apartment   2757219
# ..                   ...   ...                  ...       ...
# 319  2025-06-24 16:26:32    22     Studio Apartment   2735630
# 320  2025-06-25 15:58:55     4      2 Bedroom (4+2)   2815296
# 321  2025-06-25 16:04:13    20     Studio Apartment   2763253
# 322  2025-06-25 16:25:02    18  1 Bedroom Apartment   2796463
# 323                 <NA>  <NA>                 <NA>      <NA>
#
#         BookingSourceDesc                   BookingTypeDesc  \
# 0               KC Member                Entitlement Member
# 1    Karma Club Discovery  Karma Club Discovery Entitlement
# 2                   STAFF                       Staff Karma
# 3                   STAFF                       Staff Karma
# 4          Hotel Bookings                      Direct email
# ..                    ...                               ...
# 319  Karma Club Discovery  Karma Club Discovery Entitlement
# 320        Hotel Bookings                      Direct email
# 321       Fly Buy Western              Resort Preview Stays
# 322             KC Member                Entitlement Member
# 323                  <NA>                              <NA>
#
#             Date of Tour Sales Rep and Comments Opt In
# 0                   <NA>                   <NA>    YES
# 1                   <NA>                   <NA>    YES
# 2                   <NA>                   <NA>    YES
# 3                   <NA>                   <NA>    YES
# 4                   <NA>                   <NA>    YES
# ..                   ...                    ...    ...
# 319  2025-06-23 23:45:00        peter aitchison    YES
# 320                 <NA>                   <NA>    YES
# 321  2025-06-23 10:00:00        peter aitchison    YES
# 322                 <NA>                   <NA>    YES
# 323                 <NA>                   <NA>   <NA>
#
# [324 rows x 29 columns]

# %%
df_viewpoint.columns
# Out:
# Index(['Title', 'Firstname', 'lastname', 'DOB', 'PAN CARD', 'Email', 'Phone',
#        'Mobile', 'AddressLine1', 'AddressLine2', 'Town', 'State', 'Country',
#        'PostCode', 'Nationality', 'MaritalStatus', 'resortname', 'Arrival',
#        'Departure', 'CheckInDate', 'CheckOutDate', 'room', 'UnitCategory',
#        'BookingNo', 'BookingSourceDesc', 'BookingTypeDesc', 'Date of Tour',
#        'Sales Rep and Comments', 'Opt In'],
#       dtype='object')

# %%
df_viewpoint.fillna('empty', inplace=True)

df_viewpoint['Contact Type'] = 'empty'
df_viewpoint['Odyssey Members'] = 'NO'

df_viewpoint['Lead Brand'] = 'Karma Resorts'
df_viewpoint['Lead Sub-Brand'] = 'Other'
df_viewpoint['Lead Source'] = 'Past Guests'
df_viewpoint['Lead Locations'] = df_viewpoint['resortname']
df_viewpoint['Lead Source Description'] = 'Viewpoint'

# %%
df_viewpoint.loc[df_viewpoint['Opt In'] == 'YES', 'Exclude From Mailing'] = 'NO'
df_viewpoint.loc[df_viewpoint['Opt In'] == 'NO', 'Exclude From Mailing'] = 'YES'

# %%
df_viewpoint.loc[df_viewpoint['lastname'] == 'empty', 'lastname'] = '-'

# %%
df_viewpoint['Title'].replace('empty', '', inplace=True)
df_viewpoint['Firstname'].replace('empty', '', inplace=True)
df_viewpoint['lastname'].replace('empty', '', inplace=True)

df_viewpoint['Title'] = df_viewpoint['Title'].str.title()
df_viewpoint['Firstname'] = df_viewpoint['Firstname'].str.title()
df_viewpoint['lastname'] = df_viewpoint['lastname'].str.title()

df_viewpoint
# Out:
# C:\Users\fajar.fatoni\AppData\Local\Temp\ipykernel_9832\3404343493.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_viewpoint['Title'].replace('empty', '', inplace=True)
# C:\Users\fajar.fatoni\AppData\Local\Temp\ipykernel_9832\3404343493.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_viewpoint['Firstname'].replace('empty', '', inplace=True)
# C:\Users\fajar.fatoni\AppData\Local\Temp\ipykernel_9832\3404343493.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_viewpoint['lastname'].replace('empty', '', inplace=True)
#     Title     Firstname       lastname                  DOB    PAN CARD  \
# 0      Mr       Winayak        Karikar  1972-02-18 00:00:00  DSWPK2349B
# 1     Mrs       Bobette      Hitchcock  1982-10-08 00:00:00       empty
# 2      Mr         Dario      Quinteros                empty       empty
# 3      Ms         Lizzy         Mclean                empty       empty
# 4     Mrs        Renata    Komarzinska                empty       empty
# ..    ...           ...            ...                  ...         ...
# 319    Mr         Yared          Woldu  1994-05-07 00:00:00       empty
# 320    Mr       Orlaith          Joyce                empty       empty
# 321   Mrs         Timea  Jaro Malisova  1977-04-24 00:00:00       empty
# 322    Mr      Devanand        Ranlaul  1952-05-05 00:00:00       empty
# 323   Krg  Fajar Fatoni             86                empty       empty
#
#                                 Email         Phone       Mobile  \
# 0               v_karikar@hotmail.com   17039737611  17039737611
# 1             bo.hitchcock@live.co.uk  447540094374        empty
# 2        reception@karmalaherriza.com         empty        empty
# 3    vanessamarquezcorbacho@gmail.com         empty        empty
# 4        reception@karmalaherriza.com         empty        empty
# ..                                ...           ...          ...
# 319                yarwol24@gmail.com   46704126394  46762850282
# 320  vanessamarquezcorbacho@gmail.com         empty        empty
# 321                    mtimea@azet.sk  447732558057        empty
# 322           amritaran0902@gmail.com    2306744739  23059151767
# 323                             empty         empty        empty
#
#                    AddressLine1 AddressLine2  ... Sales Rep and Comments  \
# 0    25067 Great Berkhamsted Dr        empty  ...                  empty
# 1                 7 TIGER GROVE   midge hall  ...                  empty
# 2                           TBA        empty  ...                  empty
# 3                           TBA        empty  ...                  empty
# 4                           TBA        empty  ...                  empty
# ..                          ...          ...  ...                    ...
# 319   GAMLA, HUDDINGEVAGEN 719A        empty  ...        peter aitchison
# 320                         TBA          TBA  ...                  empty
# 321                8 Harris Way        empty  ...        peter aitchison
# 322     MORC. ADAMS, EAU COULEE        empty  ...                  empty
# 323                       empty        empty  ...                  empty
#
#     Opt In Contact Type Odyssey Members     Lead Brand Lead Sub-Brand  \
# 0      YES        empty              NO  Karma Resorts          Other
# 1      YES        empty              NO  Karma Resorts          Other
# 2      YES        empty              NO  Karma Resorts          Other
# 3      YES        empty              NO  Karma Resorts          Other
# 4      YES        empty              NO  Karma Resorts          Other
# ..     ...          ...             ...            ...            ...
# 319    YES        empty              NO  Karma Resorts          Other
# 320    YES        empty              NO  Karma Resorts          Other
# 321    YES        empty              NO  Karma Resorts          Other
# 322    YES        empty              NO  Karma Resorts          Other
# 323  empty        empty              NO  Karma Resorts          Other
#
#      Lead Source    Lead Locations Lead Source Description  \
# 0    Past Guests  Karma La Herriza               Viewpoint
# 1    Past Guests  Karma La Herriza               Viewpoint
# 2    Past Guests  Karma La Herriza               Viewpoint
# 3    Past Guests  Karma La Herriza               Viewpoint
# 4    Past Guests  Karma La Herriza               Viewpoint
# ..           ...               ...                     ...
# 319  Past Guests  Karma La Herriza               Viewpoint
# 320  Past Guests  Karma La Herriza               Viewpoint
# 321  Past Guests  Karma La Herriza               Viewpoint
# 322  Past Guests  Karma La Herriza               Viewpoint
# 323  Past Guests             empty               Viewpoint
#
#     Exclude From Mailing
# 0                     NO
# 1                     NO
# 2                     NO
# 3                     NO
# 4                     NO
# ..                   ...
# 319                   NO
# 320                   NO
# 321                   NO
# 322                   NO
# 323                  NaN
#
# [324 rows x 37 columns]

# %%
m.clean_number(df_viewpoint, 'Phone')
m.clean_number(df_viewpoint, 'Mobile')
m.replace_not_valid_to_empty(df_viewpoint, 'Phone')
m.replace_not_valid_to_empty(df_viewpoint, 'Mobile')

df_viewpoint.loc[df_viewpoint['Phone'].str.contains('00000'), 'Phone'] = 'empty'
df_viewpoint.loc[df_viewpoint['Mobile'].str.contains('00000'), 'Mobile'] = 'empty'

m.clean_space(df_viewpoint, 'Email')
df_viewpoint['Email'] = m.lowercase(df_viewpoint, 'Email')
m.email_correction(df_viewpoint, 'Email')
# Out:
# c:\Users\fajar.fatoni\Documents\Python\Task Offline\past_guest_toni_app\../zoho_data_app\main_module.py:104: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[df_columns].replace(' ','', regex=True, inplace=True)
# c:\Users\fajar.fatoni\Documents\Python\Task Offline\past_guest_toni_app\../zoho_data_app\main_module.py:105: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[df_columns].replace('[^0-9]','', regex=True, inplace=True)
# c:\Users\fajar.fatoni\Documents\Python\Task Offline\past_guest_toni_app\../zoho_data_app\main_module.py:127: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[df_columns].replace(' ','', regex=True, inplace=True)
# c:\Users\fajar.fatoni\Documents\Python\Task Offline\past_guest_toni_app\../zoho_data_app\main_module.py:260: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[df_columns].replace('^mailto:|-primary$|-pri$|-Mrs$|(noemailtobesent)$','', regex=True, inplace=True)
# c:\Users\fajar.fatoni\Documents\Python\Task Offline\past_guest_toni_app\../zoho_data_app\main_module.py:288: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[df_columns].replace('|'.join(list_correction_mail), '@mail.', regex=True, inplace=True)
# c:\Users\fajar.fatoni\Documents\Python\Task Offline\past_guest_toni_app\../zoho_data_app\main_module.py:289: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[df_columns].replace('|'.join(list_correction_gmail), '@gmail.', regex=True, inplace=True)
# c:\Users\fajar.fatoni\Documents\Python\Task Offline\past_guest_toni_app\../zoho_data_app\main_module.py:290: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[df_columns].replace('|'.join(list_correction_gmail_com), '@gmail.com', regex=True, inplace=True)
# c:\Users\fajar.fatoni\Documents\Python\Task Offline\past_guest_toni_app\../zoho_data_app\main_module.py:291: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[df_columns].replace('|'.join(list_correction_hotmail), '@hotmail.', regex=True, inplace=True)
# c:\Users\fajar.fatoni\Documents\Python\Task Offline\past_guest_toni_app\../zoho_data_app\main_module.py:292: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[df_columns].replace('|'.join(list_correction_hotmail_com), '@hotmail.com', regex=True, inplace=True)
# c:\Users\fajar.fatoni\Documents\Python\Task Offline\past_guest_toni_app\../zoho_data_app\main_module.py:293: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[df_columns].replace('|'.join(list_correction_yahoo_com), '@yahoo.com', regex=True, inplace=True)
# c:\Users\fajar.fatoni\Documents\Python\Task Offline\past_guest_toni_app\../zoho_data_app\main_module.py:294: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[df_columns].replace('|'.join(list_correction_yahoo), '@yahoo.', regex=True, inplace=True)
# c:\Users\fajar.fatoni\Documents\Python\Task Offline\past_guest_toni_app\../zoho_data_app\main_module.py:295: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[df_columns].replace('|'.join(list_correction_yahoo_in), '@yahoo.co.in', regex=True, inplace=True)
# c:\Users\fajar.fatoni\Documents\Python\Task Offline\past_guest_toni_app\../zoho_data_app\main_module.py:310: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[df_columns].loc[~df[df_columns].str.contains('@', df_columns, na=False)] = ''

# %%
df_viewpoint
# Out:
#     Title     Firstname       lastname                  DOB    PAN CARD  \
# 0      Mr       Winayak        Karikar  1972-02-18 00:00:00  DSWPK2349B
# 1     Mrs       Bobette      Hitchcock  1982-10-08 00:00:00       empty
# 2      Mr         Dario      Quinteros                empty       empty
# 3      Ms         Lizzy         Mclean                empty       empty
# 4     Mrs        Renata    Komarzinska                empty       empty
# ..    ...           ...            ...                  ...         ...
# 319    Mr         Yared          Woldu  1994-05-07 00:00:00       empty
# 320    Mr       Orlaith          Joyce                empty       empty
# 321   Mrs         Timea  Jaro Malisova  1977-04-24 00:00:00       empty
# 322    Mr      Devanand        Ranlaul  1952-05-05 00:00:00       empty
# 323   Krg  Fajar Fatoni             86                empty       empty
#
#                                 Email         Phone       Mobile  \
# 0               v_karikar@hotmail.com   17039737611  17039737611
# 1             bo.hitchcock@live.co.uk  447540094374        empty
# 2        reception@karmalaherriza.com         empty        empty
# 3    vanessamarquezcorbacho@gmail.com         empty        empty
# 4        reception@karmalaherriza.com         empty        empty
# ..                                ...           ...          ...
# 319                yarwol24@gmail.com   46704126394  46762850282
# 320  vanessamarquezcorbacho@gmail.com         empty        empty
# 321                    mtimea@azet.sk  447732558057        empty
# 322           amritaran0902@gmail.com    2306744739  23059151767
# 323                             empty         empty        empty
#
#                    AddressLine1 AddressLine2  ... Sales Rep and Comments  \
# 0    25067 Great Berkhamsted Dr        empty  ...                  empty
# 1                 7 TIGER GROVE   midge hall  ...                  empty
# 2                           TBA        empty  ...                  empty
# 3                           TBA        empty  ...                  empty
# 4                           TBA        empty  ...                  empty
# ..                          ...          ...  ...                    ...
# 319   GAMLA, HUDDINGEVAGEN 719A        empty  ...        peter aitchison
# 320                         TBA          TBA  ...                  empty
# 321                8 Harris Way        empty  ...        peter aitchison
# 322     MORC. ADAMS, EAU COULEE        empty  ...                  empty
# 323                       empty        empty  ...                  empty
#
#     Opt In Contact Type Odyssey Members     Lead Brand Lead Sub-Brand  \
# 0      YES        empty              NO  Karma Resorts          Other
# 1      YES        empty              NO  Karma Resorts          Other
# 2      YES        empty              NO  Karma Resorts          Other
# 3      YES        empty              NO  Karma Resorts          Other
# 4      YES        empty              NO  Karma Resorts          Other
# ..     ...          ...             ...            ...            ...
# 319    YES        empty              NO  Karma Resorts          Other
# 320    YES        empty              NO  Karma Resorts          Other
# 321    YES        empty              NO  Karma Resorts          Other
# 322    YES        empty              NO  Karma Resorts          Other
# 323  empty        empty              NO  Karma Resorts          Other
#
#      Lead Source    Lead Locations Lead Source Description  \
# 0    Past Guests  Karma La Herriza               Viewpoint
# 1    Past Guests  Karma La Herriza               Viewpoint
# 2    Past Guests  Karma La Herriza               Viewpoint
# 3    Past Guests  Karma La Herriza               Viewpoint
# 4    Past Guests  Karma La Herriza               Viewpoint
# ..           ...               ...                     ...
# 319  Past Guests  Karma La Herriza               Viewpoint
# 320  Past Guests  Karma La Herriza               Viewpoint
# 321  Past Guests  Karma La Herriza               Viewpoint
# 322  Past Guests  Karma La Herriza               Viewpoint
# 323  Past Guests             empty               Viewpoint
#
#     Exclude From Mailing
# 0                     NO
# 1                     NO
# 2                     NO
# 3                     NO
# 4                     NO
# ..                   ...
# 319                   NO
# 320                   NO
# 321                   NO
# 322                   NO
# 323                  NaN
#
# [324 rows x 37 columns]

# %%
df_viewpoint.loc[(df_viewpoint['Email'] != 'empty') & ((df_viewpoint['Phone'] != 'empty') | (df_viewpoint['Mobile'] != 'empty')), 'Contact Type'] = 'Email and Phone'
df_viewpoint.loc[(df_viewpoint['Email'] != 'empty') & ((df_viewpoint['Phone'] == 'empty') & (df_viewpoint['Mobile'] == 'empty')), 'Contact Type'] = 'Email Only'
df_viewpoint.loc[(df_viewpoint['Email'] == 'empty') & ((df_viewpoint['Phone'] != 'empty') | (df_viewpoint['Mobile'] != 'empty')), 'Contact Type'] = 'Phone Only'

df_viewpoint.loc[df_viewpoint['Contact Type'] == 'empty'].to_csv(r'C:\Users\fajar.fatoni\Documents\Python\Data\contact_type_empty_viewpoint.csv', index=False)

count_contact_type_empty = df_viewpoint.loc[df_viewpoint['Contact Type'] == 'empty'].shape[0]

df_viewpoint.drop(df_viewpoint.loc[df_viewpoint['Contact Type'] == 'empty'].index, inplace=True)
df_viewpoint.reset_index(drop=True, inplace=True)

count_after_contact_type_empty = df_viewpoint.shape[0]

df_viewpoint
# Out:
#     Title Firstname       lastname                  DOB    PAN CARD  \
# 0      Mr   Winayak        Karikar  1972-02-18 00:00:00  DSWPK2349B
# 1     Mrs   Bobette      Hitchcock  1982-10-08 00:00:00       empty
# 2      Mr     Dario      Quinteros                empty       empty
# 3      Ms     Lizzy         Mclean                empty       empty
# 4     Mrs    Renata    Komarzinska                empty       empty
# ..    ...       ...            ...                  ...         ...
# 276   Mrs    Amanda        Edwards  1969-05-06 00:00:00       empty
# 277    Mr     Yared          Woldu  1994-05-07 00:00:00       empty
# 278    Mr   Orlaith          Joyce                empty       empty
# 279   Mrs     Timea  Jaro Malisova  1977-04-24 00:00:00       empty
# 280    Mr  Devanand        Ranlaul  1952-05-05 00:00:00       empty
#
#                                 Email         Phone       Mobile  \
# 0               v_karikar@hotmail.com   17039737611  17039737611
# 1             bo.hitchcock@live.co.uk  447540094374        empty
# 2        reception@karmalaherriza.com         empty        empty
# 3    vanessamarquezcorbacho@gmail.com         empty        empty
# 4        reception@karmalaherriza.com         empty        empty
# ..                                ...           ...          ...
# 276      amanda_c_edwards@yahoo.co.uk  447917325888        empty
# 277                yarwol24@gmail.com   46704126394  46762850282
# 278  vanessamarquezcorbacho@gmail.com         empty        empty
# 279                    mtimea@azet.sk  447732558057        empty
# 280           amritaran0902@gmail.com    2306744739  23059151767
#
#                    AddressLine1 AddressLine2  ... Sales Rep and Comments  \
# 0    25067 Great Berkhamsted Dr        empty  ...                  empty
# 1                 7 TIGER GROVE   midge hall  ...                  empty
# 2                           TBA        empty  ...                  empty
# 3                           TBA        empty  ...                  empty
# 4                           TBA        empty  ...                  empty
# ..                          ...          ...  ...                    ...
# 276                    The Barn  Stable Lane  ...                  empty
# 277   GAMLA, HUDDINGEVAGEN 719A        empty  ...        peter aitchison
# 278                         TBA          TBA  ...                  empty
# 279                8 Harris Way        empty  ...        peter aitchison
# 280     MORC. ADAMS, EAU COULEE        empty  ...                  empty
#
#     Opt In     Contact Type Odyssey Members     Lead Brand Lead Sub-Brand  \
# 0      YES  Email and Phone              NO  Karma Resorts          Other
# 1      YES  Email and Phone              NO  Karma Resorts          Other
# 2      YES       Email Only              NO  Karma Resorts          Other
# 3      YES       Email Only              NO  Karma Resorts          Other
# 4      YES       Email Only              NO  Karma Resorts          Other
# ..     ...              ...             ...            ...            ...
# 276    YES  Email and Phone              NO  Karma Resorts          Other
# 277    YES  Email and Phone              NO  Karma Resorts          Other
# 278    YES       Email Only              NO  Karma Resorts          Other
# 279    YES  Email and Phone              NO  Karma Resorts          Other
# 280    YES  Email and Phone              NO  Karma Resorts          Other
#
#      Lead Source    Lead Locations Lead Source Description  \
# 0    Past Guests  Karma La Herriza               Viewpoint
# 1    Past Guests  Karma La Herriza               Viewpoint
# 2    Past Guests  Karma La Herriza               Viewpoint
# 3    Past Guests  Karma La Herriza               Viewpoint
# 4    Past Guests  Karma La Herriza               Viewpoint
# ..           ...               ...                     ...
# 276  Past Guests  Karma La Herriza               Viewpoint
# 277  Past Guests  Karma La Herriza               Viewpoint
# 278  Past Guests  Karma La Herriza               Viewpoint
# 279  Past Guests  Karma La Herriza               Viewpoint
# 280  Past Guests  Karma La Herriza               Viewpoint
#
#     Exclude From Mailing
# 0                     NO
# 1                     NO
# 2                     NO
# 3                     NO
# 4                     NO
# ..                   ...
# 276                   NO
# 277                   NO
# 278                   NO
# 279                   NO
# 280                   NO
#
# [281 rows x 37 columns]

# %%
# Cek Email Karma
email_karma = m.find_karma(df_viewpoint, 'Email')
count_email_karma = email_karma.shape[0]
email_karma.to_csv(r'C:\Users\fajar.fatoni\Documents\Python\Data\email_deleted_viewpoint.csv', index=False)

email_karma
# Out:
# Empty DataFrame
# Columns: [Title, Firstname, lastname, DOB, PAN CARD, Email, Phone, Mobile, AddressLine1, AddressLine2, Town, State, Country, PostCode, Nationality, MaritalStatus, resortname, Arrival, Departure, CheckInDate, CheckOutDate, room, UnitCategory, BookingNo, BookingSourceDesc, BookingTypeDesc, Date of Tour, Sales Rep and Comments, Opt In, Contact Type, Odyssey Members, Lead Brand, Lead Sub-Brand, Lead Source, Lead Locations, Lead Source Description, Exclude From Mailing]
# Index: []
#
# [0 rows x 37 columns]

# %%
# delete email Karma
count_after_clean_karma = m.delete_karma(df_viewpoint, 'Email')

df_viewpoint
# Out:
#     Title Firstname       lastname                  DOB    PAN CARD  \
# 0      Mr   Winayak        Karikar  1972-02-18 00:00:00  DSWPK2349B
# 1     Mrs   Bobette      Hitchcock  1982-10-08 00:00:00       empty
# 2      Mr     Dario      Quinteros                empty       empty
# 3      Ms     Lizzy         Mclean                empty       empty
# 4     Mrs    Renata    Komarzinska                empty       empty
# ..    ...       ...            ...                  ...         ...
# 276   Mrs    Amanda        Edwards  1969-05-06 00:00:00       empty
# 277    Mr     Yared          Woldu  1994-05-07 00:00:00       empty
# 278    Mr   Orlaith          Joyce                empty       empty
# 279   Mrs     Timea  Jaro Malisova  1977-04-24 00:00:00       empty
# 280    Mr  Devanand        Ranlaul  1952-05-05 00:00:00       empty
#
#                                 Email         Phone       Mobile  \
# 0               v_karikar@hotmail.com   17039737611  17039737611
# 1             bo.hitchcock@live.co.uk  447540094374        empty
# 2        reception@karmalaherriza.com         empty        empty
# 3    vanessamarquezcorbacho@gmail.com         empty        empty
# 4        reception@karmalaherriza.com         empty        empty
# ..                                ...           ...          ...
# 276      amanda_c_edwards@yahoo.co.uk  447917325888        empty
# 277                yarwol24@gmail.com   46704126394  46762850282
# 278  vanessamarquezcorbacho@gmail.com         empty        empty
# 279                    mtimea@azet.sk  447732558057        empty
# 280           amritaran0902@gmail.com    2306744739  23059151767
#
#                    AddressLine1 AddressLine2  ... Sales Rep and Comments  \
# 0    25067 Great Berkhamsted Dr        empty  ...                  empty
# 1                 7 TIGER GROVE   midge hall  ...                  empty
# 2                           TBA        empty  ...                  empty
# 3                           TBA        empty  ...                  empty
# 4                           TBA        empty  ...                  empty
# ..                          ...          ...  ...                    ...
# 276                    The Barn  Stable Lane  ...                  empty
# 277   GAMLA, HUDDINGEVAGEN 719A        empty  ...        peter aitchison
# 278                         TBA          TBA  ...                  empty
# 279                8 Harris Way        empty  ...        peter aitchison
# 280     MORC. ADAMS, EAU COULEE        empty  ...                  empty
#
#     Opt In     Contact Type Odyssey Members     Lead Brand Lead Sub-Brand  \
# 0      YES  Email and Phone              NO  Karma Resorts          Other
# 1      YES  Email and Phone              NO  Karma Resorts          Other
# 2      YES       Email Only              NO  Karma Resorts          Other
# 3      YES       Email Only              NO  Karma Resorts          Other
# 4      YES       Email Only              NO  Karma Resorts          Other
# ..     ...              ...             ...            ...            ...
# 276    YES  Email and Phone              NO  Karma Resorts          Other
# 277    YES  Email and Phone              NO  Karma Resorts          Other
# 278    YES       Email Only              NO  Karma Resorts          Other
# 279    YES  Email and Phone              NO  Karma Resorts          Other
# 280    YES  Email and Phone              NO  Karma Resorts          Other
#
#      Lead Source    Lead Locations Lead Source Description  \
# 0    Past Guests  Karma La Herriza               Viewpoint
# 1    Past Guests  Karma La Herriza               Viewpoint
# 2    Past Guests  Karma La Herriza               Viewpoint
# 3    Past Guests  Karma La Herriza               Viewpoint
# 4    Past Guests  Karma La Herriza               Viewpoint
# ..           ...               ...                     ...
# 276  Past Guests  Karma La Herriza               Viewpoint
# 277  Past Guests  Karma La Herriza               Viewpoint
# 278  Past Guests  Karma La Herriza               Viewpoint
# 279  Past Guests  Karma La Herriza               Viewpoint
# 280  Past Guests  Karma La Herriza               Viewpoint
#
#     Exclude From Mailing
# 0                     NO
# 1                     NO
# 2                     NO
# 3                     NO
# 4                     NO
# ..                   ...
# 276                   NO
# 277                   NO
# 278                   NO
# 279                   NO
# 280                   NO
#
# [281 rows x 37 columns]

# %%
# Cek leads test
test_leads = df_viewpoint.loc[
    
        df_viewpoint['Email'].str.contains('^test@', flags=re.I, regex=True) |
        df_viewpoint['Email'].str.contains('\+test', flags=re.I, regex=True) |
    
        df_viewpoint['Firstname'].str.contains('^test$', flags=re.I, regex=True) |
        df_viewpoint['lastname'].str.contains('^test$', flags=re.I, regex=True) |

        df_viewpoint['Firstname'].str.contains('test 1', flags=re.I, regex=True) |
        df_viewpoint['lastname'].str.contains('test 2', flags=re.I, regex=True)|
        df_viewpoint['Firstname'].str.contains('test1', flags=re.I, regex=True) |
        df_viewpoint['lastname'].str.contains('test2', flags=re.I, regex=True)|

        df_viewpoint['Firstname'].str.contains(' test ', flags=re.I, regex=True) | 
        df_viewpoint['lastname'].str.contains(' test ', flags=re.I, regex=True) | 
        df_viewpoint['lastname'].str.contains(' test$', flags=re.I, regex=True)
    ]

count_leads_test = test_leads.shape[0]

test_leads.to_csv(r'C:\Users\fajar.fatoni\Documents\Python\Data\test_leads_viewpoint.csv', index=False)
test_leads
# Out:
# Empty DataFrame
# Columns: [Title, Firstname, lastname, DOB, PAN CARD, Email, Phone, Mobile, AddressLine1, AddressLine2, Town, State, Country, PostCode, Nationality, MaritalStatus, resortname, Arrival, Departure, CheckInDate, CheckOutDate, room, UnitCategory, BookingNo, BookingSourceDesc, BookingTypeDesc, Date of Tour, Sales Rep and Comments, Opt In, Contact Type, Odyssey Members, Lead Brand, Lead Sub-Brand, Lead Source, Lead Locations, Lead Source Description, Exclude From Mailing]
# Index: []
#
# [0 rows x 37 columns]

# %%
df_viewpoint.drop(test_leads.index, inplace=True)
df_viewpoint.reset_index(drop=True, inplace=True)

count_after_dedup_test = df_viewpoint.shape[0]
count_after_dedup_test
# Out:
# 281

# %%
count_final_data = count_after_dedup_test

# %%
# df_viewpoint.loc[df_viewpoint['BookingNo'] == '2070341']

# %%
df_viewpoint.replace('empty', '', inplace=True)

# %%
print("==========================================================")
print("Summary")
print("==========================================================")
print("Jumlah Data Awal Viewpoint : "+str(count_data_awal))
print("Jumlah Data Email dan Phone Kosong : "+str(count_contact_type_empty))
print("Jumlah Data Setelah Hapus Email dan Phone Yang Kosong : "+str(count_after_contact_type_empty))
print("Jumlah Data Email Yang Termasuk List Karma : "+str(count_email_karma))
print("Jumlah Data Email Setelah List Karma Dihapus : "+str(count_after_clean_karma))
print("Jumlah Data Test : "+str(count_leads_test))
print("Jumlah Data Email Setelah Data Test Dihapus : "+str(count_after_dedup_test))
print("Jumlah Data Akhir : "+str(count_final_data))
# Out:
# ==========================================================
# Summary
# ==========================================================
# Jumlah Data Awal Viewpoint : 324
# Jumlah Data Email dan Phone Kosong : 43
# Jumlah Data Setelah Hapus Email dan Phone Yang Kosong : 281
# Jumlah Data Email Yang Termasuk List Karma : 0
# Jumlah Data Email Setelah List Karma Dihapus : 281
# Jumlah Data Test : 0
# Jumlah Data Email Setelah Data Test Dihapus : 281
# Jumlah Data Akhir : 281

# %%
df_viewpoint.to_excel(r'C:\Users\fajar.fatoni\Documents\Python\Data\check_country_code_viewpoint.xlsx', index=False)
