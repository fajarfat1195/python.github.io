# %%
import pandas as pd
import re

import past_guest_module as pm

import sys
sys.path.append('../zoho_data_app/')

import main_module as m

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
path = r'C:\Users\fajar.fatoni\Documents\Python\Data\Past Guest Data\Zoho Analytic\2025\Oct\05 Oct - 13 Oct\CRM_Rental_Report_05_Oct_-_13_Oct.xlsx'
# path = r'C:\Users\fajar.fatoni\Documents\Python\Data\CRM_Rental_Report (2).xlsx'
df_analytic = pd.read_excel(path, dtype='string', sheet_name='Sheet1')
count_data_awal = df_analytic.shape[0]
df_analytic
# Out:
#     Booking_Id               TelNo      MobileNo                    Email  \
# 0     KB053663    +49 1511 8028681  015118028681            lejubi@web.de
# 1     KB053327          4980266080  015159061850    afom@karmabavaria.com
# 2     KB053468         01701066952   01701069252   frankminas@t-online.de
# 3     KB046771    +49 1511 5349737   01703514626  waltraudbuettler@gmx.de
# 4     KB053385     +49 171 2342534   01712342534    e.schneider.93@web.de
# ..         ...                 ...           ...                      ...
# 149   KB053274    +49 176 84569793          <NA>                     <NA>
# 150  KLM009054                <NA>          <NA>                     <NA>
# 151   KB053588  +49 491 5780286785          <NA>                     <NA>
# 152   KB053547  +49 491 5780286785          <NA>                     <NA>
# 153   KB053718     +49 175 8494131          <NA>                     <NA>
#
#         Lead Brand Lead Sub- Brand  Lead Source             Resort_Name  \
# 0    Karma Resorts           Other  Past Guests           Karma Bavaria
# 1    Karma Resorts           Other  Past Guests           Karma Bavaria
# 2    Karma Resorts           Other  Past Guests           Karma Bavaria
# 3    Karma Resorts           Other  Past Guests           Karma Bavaria
# 4    Karma Resorts           Other  Past Guests           Karma Bavaria
# ..             ...             ...          ...                     ...
# 149  Karma Resorts           Other  Past Guests           Karma Bavaria
# 150  Karma Resorts           Other  Past Guests  Karma Lake of Menteith
# 151  Karma Resorts           Other  Past Guests           Karma Bavaria
# 152  Karma Resorts           Other  Past Guests           Karma Bavaria
# 153  Karma Resorts           Other  Past Guests           Karma Bavaria
#
#     ProfileRef Salutation  ... Market_Segment Media_Code Media Code Group  \
# 0     PF331118       Herr  ...            OTA        OTA           RETAIL
# 1     PF196598       Frau  ...           COMP      STAFF             COMP
# 2     PF329929        Dr.  ...           COMP    GER_OWE             COMP
# 3     PF298213       Frau  ...            OTA        OTA           RETAIL
# 4     PF329503       Herr  ...            OTA        OTA           RETAIL
# ..         ...        ...  ...            ...        ...              ...
# 149   PF328936       <NA>  ...            OTA        OTA           RETAIL
# 150       <NA>       <NA>  ...            DIR    WEDDING            GROUP
# 151   PF330329       <NA>  ...            OTA        OTA           RETAIL
# 152   PF330329       <NA>  ...            OTA        OTA           RETAIL
# 153   PF331444       Frau  ...            OTA        OTA           RETAIL
#
#       Media_Group_Description No. of Adult No. of Children No. of Infants  \
# 0         Online Travel Agent            3               0              0
# 1                       Staff            1               0              0
# 2    German Real Estate Owner            2               0              0
# 3         Online Travel Agent            2               0              0
# 4         Online Travel Agent            6               0              0
# ..                        ...          ...             ...            ...
# 149       Online Travel Agent            5               0              0
# 150                   Wedding            2               0              0
# 151       Online Travel Agent            3               0              0
# 152       Online Travel Agent            3               0              0
# 153       Online Travel Agent            2               2              0
#
#     Contact Type Odyssey Members         Guest_Name
# 0                                    Leon Birkmeyer
# 1                                  Esther Burkhardt
# 2                                       Frank Minas
# 3                                    Waltraud Rinck
# 4                                    Eric Schneider
# ..           ...             ...                ...
# 149                               Martina Schindler
# 150                                             Tbc
# 151                                  Nadja Schittko
# 152                                  Nadja Schittko
# 153                                   Tanja Wengner
#
# [154 rows x 40 columns]

# %%
df_analytic.columns
# Out:
# Index(['Booking_Id', 'TelNo', 'MobileNo', 'Email', 'Lead Brand',
#        'Lead Sub- Brand', 'Lead Source', 'Resort_Name', 'ProfileRef',
#        'Salutation', 'First_Name', 'Surname', 'Gender', 'Language', 'DOB',
#        'Street', 'Area', 'Town', 'County', 'Country', 'Nationality',
#        'PostCode', 'Exclude From Mailing', 'Opt In', 'Booking Code',
#        'Booking Status', 'DateArrival', 'DateDepart', 'Departure Year',
#        'No. of Nights', 'Market_Segment', 'Media_Code', 'Media Code Group',
#        'Media_Group_Description', 'No. of Adult', 'No. of Children',
#        'No. of Infants', 'Contact Type', 'Odyssey Members', 'Guest_Name'],
#       dtype='object')

# %%
new_cols = ['Booking_Id', 'Lead Brand', 'Lead Sub- Brand', 'Lead Source',
       'Resort_Name', 'ProfileRef', 'Salutation', 'First_Name', 'Surname',
       'Gender', 'Language', 'DOB', 'Street', 'Area', 'Town', 'County',
       'Country', 'Nationality', 'PostCode', 'TelNo', 'MobileNo', 'Email',
       'Exclude From Mailing', 'Opt In', 'Booking Status',
       'DateArrival', 'DateDepart', 'No. of Nights', 'Market_Segment',
       'Media_Code', 'Media Code Group', 'No. of Adult', 'No. of Children',
       'No. of Infants', 'Contact Type', 'Odyssey Members']																																																																																																																																						

df_analytic = df_analytic.reindex(columns=new_cols)

# %%
df_analytic.fillna('empty', inplace=True)
df_analytic['Contact Type'] = 'empty'
df_analytic['Odyssey Members'] = 'NO'

# %%
df_analytic.loc[df_analytic['Surname'] == 'empty', 'Surname'] = '-'

# %%
df_analytic['Salutation'].replace('empty', '', inplace=True)
df_analytic['First_Name'].replace('empty', '', inplace=True)
df_analytic['Surname'].replace('empty', '', inplace=True)

df_analytic['Salutation'] = df_analytic['Salutation'].str.title()
df_analytic['First_Name'] = df_analytic['First_Name'].str.title()
df_analytic['Surname'] = df_analytic['Surname'].str.title()

df_analytic
# Out:
# C:\Users\fajar.fatoni\AppData\Local\Temp\ipykernel_25284\2281604359.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_analytic['Salutation'].replace('empty', '', inplace=True)
# C:\Users\fajar.fatoni\AppData\Local\Temp\ipykernel_25284\2281604359.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_analytic['First_Name'].replace('empty', '', inplace=True)
# C:\Users\fajar.fatoni\AppData\Local\Temp\ipykernel_25284\2281604359.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_analytic['Surname'].replace('empty', '', inplace=True)
#     Booking_Id     Lead Brand Lead Sub- Brand  Lead Source  \
# 0     KB053663  Karma Resorts           Other  Past Guests
# 1     KB053327  Karma Resorts           Other  Past Guests
# 2     KB053468  Karma Resorts           Other  Past Guests
# 3     KB046771  Karma Resorts           Other  Past Guests
# 4     KB053385  Karma Resorts           Other  Past Guests
# ..         ...            ...             ...          ...
# 149   KB053274  Karma Resorts           Other  Past Guests
# 150  KLM009054  Karma Resorts           Other  Past Guests
# 151   KB053588  Karma Resorts           Other  Past Guests
# 152   KB053547  Karma Resorts           Other  Past Guests
# 153   KB053718  Karma Resorts           Other  Past Guests
#
#                 Resort_Name ProfileRef Salutation First_Name    Surname  \
# 0             Karma Bavaria   PF331118       Herr       Leon  Birkmeyer
# 1             Karma Bavaria   PF196598       Frau     Esther  Burkhardt
# 2             Karma Bavaria   PF329929        Dr.      Frank      Minas
# 3             Karma Bavaria   PF298213       Frau   Waltraud      Rinck
# 4             Karma Bavaria   PF329503       Herr       Eric  Schneider
# ..                      ...        ...        ...        ...        ...
# 149           Karma Bavaria   PF328936               Martina  Schindler
# 150  Karma Lake of Menteith      empty                              Tbc
# 151           Karma Bavaria   PF330329                 Nadja   Schittko
# 152           Karma Bavaria   PF330329                 Nadja   Schittko
# 153           Karma Bavaria   PF331444       Frau      Tanja    Wengner
#
#       Gender  ...           DateDepart No. of Nights Market_Segment  \
# 0       Male  ...  2025-10-05 00:00:00             2            OTA
# 1     Female  ...  2025-10-09 00:00:00             4           COMP
# 2    Unknown  ...  2025-10-10 00:00:00             1           COMP
# 3     Female  ...  2025-10-05 00:00:00             1            OTA
# 4       Male  ...  2025-10-05 00:00:00             2            OTA
# ..       ...  ...                  ...           ...            ...
# 149  Unknown  ...  2025-10-05 00:00:00             2            OTA
# 150  Unknown  ...  2025-10-12 00:00:00             1            DIR
# 151  Unknown  ...  2025-10-12 00:00:00             4            OTA
# 152  Unknown  ...  2025-10-12 00:00:00             4            OTA
# 153   Female  ...  2025-10-05 00:00:00             1            OTA
#
#     Media_Code Media Code Group No. of Adult No. of Children No. of Infants  \
# 0          OTA           RETAIL            3               0              0
# 1        STAFF             COMP            1               0              0
# 2      GER_OWE             COMP            2               0              0
# 3          OTA           RETAIL            2               0              0
# 4          OTA           RETAIL            6               0              0
# ..         ...              ...          ...             ...            ...
# 149        OTA           RETAIL            5               0              0
# 150    WEDDING            GROUP            2               0              0
# 151        OTA           RETAIL            3               0              0
# 152        OTA           RETAIL            3               0              0
# 153        OTA           RETAIL            2               2              0
#
#     Contact Type Odyssey Members
# 0          empty              NO
# 1          empty              NO
# 2          empty              NO
# 3          empty              NO
# 4          empty              NO
# ..           ...             ...
# 149        empty              NO
# 150        empty              NO
# 151        empty              NO
# 152        empty              NO
# 153        empty              NO
#
# [154 rows x 36 columns]

# %%
m.clean_number(df_analytic, 'TelNo')
m.clean_number(df_analytic, 'MobileNo')
m.replace_not_valid_to_empty(df_analytic, 'TelNo')
m.replace_not_valid_to_empty(df_analytic, 'MobileNo')

df_analytic.loc[df_analytic['TelNo'].str.contains('00000'), 'TelNo'] = 'empty'
df_analytic.loc[df_analytic['MobileNo'].str.contains('00000'), 'MobileNo'] = 'empty'

m.clean_space(df_analytic, 'Email')
df_analytic['Email'] = m.lowercase(df_analytic, 'Email')
m.email_correction(df_analytic, 'Email')
# Out:
# c:\Users\fajar.fatoni\Documents\Python\Task Offline\past_guest_toni_app\../zoho_data_app\main_module.py:104: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[df_columns].replace(' ','', regex=True, inplace=True)
# c:\Users\fajar.fatoni\Documents\Python\Task Offline\past_guest_toni_app\../zoho_data_app\main_module.py:105: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[df_columns].replace('[^0-9]','', regex=True, inplace=True)
# c:\Users\fajar.fatoni\Documents\Python\Task Offline\past_guest_toni_app\../zoho_data_app\main_module.py:127: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[df_columns].replace(' ','', regex=True, inplace=True)
# c:\Users\fajar.fatoni\Documents\Python\Task Offline\past_guest_toni_app\../zoho_data_app\main_module.py:271: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[df_columns].replace('^mailto:|-primary$|-pri$|-Mrs$|(noemailtobesent)$','', regex=True, inplace=True)
# c:\Users\fajar.fatoni\Documents\Python\Task Offline\past_guest_toni_app\../zoho_data_app\main_module.py:299: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[df_columns].replace('|'.join(list_correction_mail), '@mail.', regex=True, inplace=True)
# c:\Users\fajar.fatoni\Documents\Python\Task Offline\past_guest_toni_app\../zoho_data_app\main_module.py:300: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[df_columns].replace('|'.join(list_correction_gmail), '@gmail.', regex=True, inplace=True)
# c:\Users\fajar.fatoni\Documents\Python\Task Offline\past_guest_toni_app\../zoho_data_app\main_module.py:301: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[df_columns].replace('|'.join(list_correction_gmail_com), '@gmail.com', regex=True, inplace=True)
# c:\Users\fajar.fatoni\Documents\Python\Task Offline\past_guest_toni_app\../zoho_data_app\main_module.py:302: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[df_columns].replace('|'.join(list_correction_hotmail), '@hotmail.', regex=True, inplace=True)
# c:\Users\fajar.fatoni\Documents\Python\Task Offline\past_guest_toni_app\../zoho_data_app\main_module.py:303: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[df_columns].replace('|'.join(list_correction_hotmail_com), '@hotmail.com', regex=True, inplace=True)
# c:\Users\fajar.fatoni\Documents\Python\Task Offline\past_guest_toni_app\../zoho_data_app\main_module.py:304: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[df_columns].replace('|'.join(list_correction_yahoo_com), '@yahoo.com', regex=True, inplace=True)
# c:\Users\fajar.fatoni\Documents\Python\Task Offline\past_guest_toni_app\../zoho_data_app\main_module.py:305: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[df_columns].replace('|'.join(list_correction_yahoo), '@yahoo.', regex=True, inplace=True)
# c:\Users\fajar.fatoni\Documents\Python\Task Offline\past_guest_toni_app\../zoho_data_app\main_module.py:306: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[df_columns].replace('|'.join(list_correction_yahoo_in), '@yahoo.co.in', regex=True, inplace=True)
# c:\Users\fajar.fatoni\Documents\Python\Task Offline\past_guest_toni_app\../zoho_data_app\main_module.py:321: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[df_columns].loc[~df[df_columns].str.contains('@', df_columns, na=False)] = 'empty'

# %%
df_analytic.loc[(df_analytic['Email'] != 'empty') & ((df_analytic['TelNo'] != 'empty') | (df_analytic['MobileNo'] != 'empty')), 'Contact Type'] = 'Email and Phone'
df_analytic.loc[(df_analytic['Email'] != 'empty') & ((df_analytic['TelNo'] == 'empty') & (df_analytic['MobileNo'] == 'empty')), 'Contact Type'] = 'Email Only'
df_analytic.loc[(df_analytic['Email'] == 'empty') & ((df_analytic['TelNo'] != 'empty') | (df_analytic['MobileNo'] != 'empty')), 'Contact Type'] = 'Phone Only'

df_analytic.loc[df_analytic['Contact Type'] == 'empty'].to_csv(r'C:\Users\fajar.fatoni\Documents\Python\Data\contact_type_empty_analytic.csv', index=False)

count_contact_type_empty = df_analytic.loc[df_analytic['Contact Type'] == 'empty'].shape[0]

df_analytic.drop(df_analytic.loc[df_analytic['Contact Type'] == 'empty'].index, inplace=True)
df_analytic.reset_index(drop=True, inplace=True)

count_after_contact_type_empty = df_analytic.shape[0]

df_analytic
# Out:
#     Booking_Id     Lead Brand Lead Sub- Brand  Lead Source    Resort_Name  \
# 0     KB053663  Karma Resorts           Other  Past Guests  Karma Bavaria
# 1     KB053327  Karma Resorts           Other  Past Guests  Karma Bavaria
# 2     KB053468  Karma Resorts           Other  Past Guests  Karma Bavaria
# 3     KB046771  Karma Resorts           Other  Past Guests  Karma Bavaria
# 4     KB053385  Karma Resorts           Other  Past Guests  Karma Bavaria
# ..         ...            ...             ...          ...            ...
# 132   KB052028  Karma Resorts           Other  Past Guests  Karma Bavaria
# 133   KB053274  Karma Resorts           Other  Past Guests  Karma Bavaria
# 134   KB053588  Karma Resorts           Other  Past Guests  Karma Bavaria
# 135   KB053547  Karma Resorts           Other  Past Guests  Karma Bavaria
# 136   KB053718  Karma Resorts           Other  Past Guests  Karma Bavaria
#
#     ProfileRef Salutation First_Name    Surname   Gender  ...  \
# 0     PF331118       Herr       Leon  Birkmeyer     Male  ...
# 1     PF196598       Frau     Esther  Burkhardt   Female  ...
# 2     PF329929        Dr.      Frank      Minas  Unknown  ...
# 3     PF298213       Frau   Waltraud      Rinck   Female  ...
# 4     PF329503       Herr       Eric  Schneider     Male  ...
# ..         ...        ...        ...        ...      ...  ...
# 132   PF322298       Miss        Eva     Fasser   Female  ...
# 133   PF328936               Martina  Schindler  Unknown  ...
# 134   PF330329                 Nadja   Schittko  Unknown  ...
# 135   PF330329                 Nadja   Schittko  Unknown  ...
# 136   PF331444       Frau      Tanja    Wengner   Female  ...
#
#               DateDepart No. of Nights Market_Segment Media_Code  \
# 0    2025-10-05 00:00:00             2            OTA        OTA
# 1    2025-10-09 00:00:00             4           COMP      STAFF
# 2    2025-10-10 00:00:00             1           COMP    GER_OWE
# 3    2025-10-05 00:00:00             1            OTA        OTA
# 4    2025-10-05 00:00:00             2            OTA        OTA
# ..                   ...           ...            ...        ...
# 132  2025-10-05 00:00:00             1            OTA        OTA
# 133  2025-10-05 00:00:00             2            OTA        OTA
# 134  2025-10-12 00:00:00             4            OTA        OTA
# 135  2025-10-12 00:00:00             4            OTA        OTA
# 136  2025-10-05 00:00:00             1            OTA        OTA
#
#     Media Code Group No. of Adult No. of Children No. of Infants  \
# 0             RETAIL            3               0              0
# 1               COMP            1               0              0
# 2               COMP            2               0              0
# 3             RETAIL            2               0              0
# 4             RETAIL            6               0              0
# ..               ...          ...             ...            ...
# 132           RETAIL            4               0              0
# 133           RETAIL            5               0              0
# 134           RETAIL            3               0              0
# 135           RETAIL            3               0              0
# 136           RETAIL            2               2              0
#
#         Contact Type Odyssey Members
# 0    Email and Phone              NO
# 1    Email and Phone              NO
# 2    Email and Phone              NO
# 3    Email and Phone              NO
# 4    Email and Phone              NO
# ..               ...             ...
# 132       Phone Only              NO
# 133       Phone Only              NO
# 134       Phone Only              NO
# 135       Phone Only              NO
# 136       Phone Only              NO
#
# [137 rows x 36 columns]

# %%
# Cek Email Karma
email_karma = m.find_karma(df_analytic, 'Email')
count_email_karma = email_karma.shape[0]
email_karma.to_csv(r'C:\Users\fajar.fatoni\Documents\Python\Data\email_deleted_analytic.csv', index=False)

email_karma
# Out:
#     Booking_Id     Lead Brand Lead Sub- Brand  Lead Source    Resort_Name  \
# 1     KB053327  Karma Resorts           Other  Past Guests  Karma Bavaria
# 5     KK078648  Karma Resorts           Other  Past Guests  Karma Kandara
# 6     KK080844  Karma Resorts           Other  Past Guests  Karma Kandara
# 7     KK080852  Karma Resorts           Other  Past Guests  Karma Kandara
# 35    KK080149  Karma Resorts           Other  Past Guests  Karma Kandara
# 54    KK078647  Karma Resorts           Other  Past Guests  Karma Kandara
# 61    KK080423  Karma Resorts           Other  Past Guests  Karma Kandara
# 62    KK080540  Karma Resorts           Other  Past Guests  Karma Kandara
# 63    KK080808  Karma Resorts           Other  Past Guests  Karma Kandara
# 64    KK081127  Karma Resorts           Other  Past Guests  Karma Kandara
# 65    KK080805  Karma Resorts           Other  Past Guests  Karma Kandara
# 71    KK080546  Karma Resorts           Other  Past Guests  Karma Kandara
# 72    KK078650  Karma Resorts           Other  Past Guests  Karma Kandara
# 73    KK080788  Karma Resorts           Other  Past Guests  Karma Kandara
# 74    KK080817  Karma Resorts           Other  Past Guests  Karma Kandara
# 114   KB052467  Karma Resorts           Other  Past Guests  Karma Bavaria
# 118   KK078651  Karma Resorts           Other  Past Guests  Karma Kandara
#
#     ProfileRef Salutation      First_Name      Surname   Gender  ...  \
# 1     PF196598       Frau          Esther    Burkhardt   Female  ...
# 5     PF071902         Mr         Clinton  Albuquerque     Male  ...
# 6     PF071902         Mr         Clinton  Albuquerque     Male  ...
# 7     PF071902         Mr         Clinton  Albuquerque     Male  ...
# 35    PF285974         Mr          Arthid    Khengphet     Male  ...
# 54    PF044484         Mr            Gary      Knowles     Male  ...
# 61    PF267042        Mr.  Adrian Richard    Fatechand     Male  ...
# 62    PF063348          -           David       Hadson     Male  ...
# 63    PF063348          -           David       Hadson     Male  ...
# 64    PF063348          -           David       Hadson     Male  ...
# 65    PF050759         Mr           David    Scheckter     Male  ...
# 71    PF197432        Mrs            Ruth         Liew   Female  ...
# 72    PF287311         Mr          Adrian    Fatechand     Male  ...
# 73    PF293969         Mr          Dennis     Rietveld  Unknown  ...
# 74    PF293969         Mr          Dennis     Rietveld  Unknown  ...
# 114   PF135410       Herr       Sebastian       Möller     Male  ...
# 118   PF317995         Mr          Robert     Faulkner     Male  ...
#
#               DateDepart No. of Nights Market_Segment Media_Code  \
# 1    2025-10-09 00:00:00             4           COMP      STAFF
# 5    2025-10-10 00:00:00             4           COMP      STAFF
# 6    2025-10-06 00:00:00             1           COMP      STAFF
# 7    2025-10-06 00:00:00             1           COMP      STAFF
# 35   2025-10-10 00:00:00             3           COMP        VIP
# 54   2025-10-10 00:00:00             4           COMP      STAFF
# 61   2025-10-09 00:00:00             3           COMP      STAFF
# 62   2025-10-09 00:00:00             1           COMP      STAFF
# 63   2025-10-10 00:00:00             4           COMP      STAFF
# 64   2025-10-10 00:00:00             1           COMP      STAFF
# 65   2025-10-10 00:00:00             3           COMP      STAFF
# 71   2025-10-10 00:00:00             4           COMP      STAFF
# 72   2025-10-10 00:00:00             3      HOUSE_USE      STAFF
# 73   2025-10-09 00:00:00             1           COMP      STAFF
# 74   2025-10-08 00:00:00             1           COMP      STAFF
# 114  2025-10-11 00:00:00             2           COMP      STAFF
# 118  2025-10-10 00:00:00             1           COMP      STAFF
#
#     Media Code Group No. of Adult No. of Children No. of Infants  \
# 1               COMP            1               0              0
# 5               COMP            3               0              0
# 6               COMP            1               0              0
# 7               COMP            1               0              0
# 35              COMP            2               0              0
# 54              COMP            3               0              0
# 61              COMP            1               0              0
# 62              COMP            2               0              0
# 63              COMP            1               0              0
# 64              COMP            1               0              0
# 65              COMP            2               0              0
# 71              COMP            1               0              0
# 72              COMP            1               0              0
# 73              COMP            1               0              0
# 74              COMP            1               0              0
# 114             COMP            2               2              1
# 118             COMP            2               0              0
#
#         Contact Type Odyssey Members
# 1    Email and Phone              NO
# 5    Email and Phone              NO
# 6    Email and Phone              NO
# 7    Email and Phone              NO
# 35   Email and Phone              NO
# 54   Email and Phone              NO
# 61   Email and Phone              NO
# 62   Email and Phone              NO
# 63   Email and Phone              NO
# 64   Email and Phone              NO
# 65   Email and Phone              NO
# 71   Email and Phone              NO
# 72   Email and Phone              NO
# 73        Email Only              NO
# 74        Email Only              NO
# 114       Email Only              NO
# 118  Email and Phone              NO
#
# [17 rows x 36 columns]

# %%
# delete email Karma
count_after_clean_karma = m.delete_karma(df_analytic, 'Email')

df_analytic
# Out:
#     Booking_Id     Lead Brand Lead Sub- Brand  Lead Source    Resort_Name  \
# 0     KB053663  Karma Resorts           Other  Past Guests  Karma Bavaria
# 1     KB053468  Karma Resorts           Other  Past Guests  Karma Bavaria
# 2     KB046771  Karma Resorts           Other  Past Guests  Karma Bavaria
# 3     KB053385  Karma Resorts           Other  Past Guests  Karma Bavaria
# 4     KK080861  Karma Resorts           Other  Past Guests  Karma Kandara
# ..         ...            ...             ...          ...            ...
# 115   KB052028  Karma Resorts           Other  Past Guests  Karma Bavaria
# 116   KB053274  Karma Resorts           Other  Past Guests  Karma Bavaria
# 117   KB053588  Karma Resorts           Other  Past Guests  Karma Bavaria
# 118   KB053547  Karma Resorts           Other  Past Guests  Karma Bavaria
# 119   KB053718  Karma Resorts           Other  Past Guests  Karma Bavaria
#
#     ProfileRef Salutation First_Name    Surname   Gender  ...  \
# 0     PF331118       Herr       Leon  Birkmeyer     Male  ...
# 1     PF329929        Dr.      Frank      Minas  Unknown  ...
# 2     PF298213       Frau   Waltraud      Rinck   Female  ...
# 3     PF329503       Herr       Eric  Schneider     Male  ...
# 4     PF331962       Miss     Debbie    Miranda   Female  ...
# ..         ...        ...        ...        ...      ...  ...
# 115   PF322298       Miss        Eva     Fasser   Female  ...
# 116   PF328936               Martina  Schindler  Unknown  ...
# 117   PF330329                 Nadja   Schittko  Unknown  ...
# 118   PF330329                 Nadja   Schittko  Unknown  ...
# 119   PF331444       Frau      Tanja    Wengner   Female  ...
#
#               DateDepart No. of Nights Market_Segment   Media_Code  \
# 0    2025-10-05 00:00:00             2            OTA          OTA
# 1    2025-10-10 00:00:00             1           COMP      GER_OWE
# 2    2025-10-05 00:00:00             1            OTA          OTA
# 3    2025-10-05 00:00:00             2            OTA          OTA
# 4    2025-10-08 00:00:00             4      HOUSE_USE  V_OWNER_NRB
# ..                   ...           ...            ...          ...
# 115  2025-10-05 00:00:00             1            OTA          OTA
# 116  2025-10-05 00:00:00             2            OTA          OTA
# 117  2025-10-12 00:00:00             4            OTA          OTA
# 118  2025-10-12 00:00:00             4            OTA          OTA
# 119  2025-10-05 00:00:00             1            OTA          OTA
#
#     Media Code Group No. of Adult No. of Children No. of Infants  \
# 0             RETAIL            3               0              0
# 1               COMP            2               0              0
# 2             RETAIL            2               0              0
# 3             RETAIL            6               0              0
# 4               COMP            5               2              0
# ..               ...          ...             ...            ...
# 115           RETAIL            4               0              0
# 116           RETAIL            5               0              0
# 117           RETAIL            3               0              0
# 118           RETAIL            3               0              0
# 119           RETAIL            2               2              0
#
#         Contact Type Odyssey Members
# 0    Email and Phone              NO
# 1    Email and Phone              NO
# 2    Email and Phone              NO
# 3    Email and Phone              NO
# 4    Email and Phone              NO
# ..               ...             ...
# 115       Phone Only              NO
# 116       Phone Only              NO
# 117       Phone Only              NO
# 118       Phone Only              NO
# 119       Phone Only              NO
#
# [120 rows x 36 columns]

# %%
df_analytic['Salutation']
# Out:
# 0      Herr
# 1       Dr.
# 2      Frau
# 3      Herr
# 4      Miss
#        ...
# 115    Miss
# 116
# 117
# 118
# 119    Frau
# Name: Salutation, Length: 120, dtype: string

# %%
# Cek leads test
test_leads = df_analytic.loc[
    
        df_analytic['Email'].str.contains('^test@', flags=re.I, regex=True) |
        df_analytic['Email'].str.contains('\+test', flags=re.I, regex=True) |
    
        df_analytic['First_Name'].str.contains('^test$', flags=re.I, regex=True) |
        df_analytic['Surname'].str.contains('^test$', flags=re.I, regex=True) |

        df_analytic['First_Name'].str.contains('test 1', flags=re.I, regex=True) |
        df_analytic['Surname'].str.contains('test 2', flags=re.I, regex=True)|
        df_analytic['First_Name'].str.contains('test1', flags=re.I, regex=True) |
        df_analytic['Surname'].str.contains('test2', flags=re.I, regex=True)|

        df_analytic['First_Name'].str.contains(' test ', flags=re.I, regex=True) | 
        df_analytic['Surname'].str.contains(' test ', flags=re.I, regex=True) | 
        df_analytic['Surname'].str.contains(' test$', flags=re.I, regex=True)
    ]

count_leads_test = test_leads.shape[0]

test_leads.to_csv(r'C:\Users\fajar.fatoni\Documents\Python\Data\test_leads_analytic.csv', index=False)
test_leads
# Out:
# Empty DataFrame
# Columns: [Booking_Id, Lead Brand, Lead Sub- Brand, Lead Source, Resort_Name, ProfileRef, Salutation, First_Name, Surname, Gender, Language, DOB, Street, Area, Town, County, Country, Nationality, PostCode, TelNo, MobileNo, Email, Exclude From Mailing, Opt In, Booking Status, DateArrival, DateDepart, No. of Nights, Market_Segment, Media_Code, Media Code Group, No. of Adult, No. of Children, No. of Infants, Contact Type, Odyssey Members]
# Index: []
#
# [0 rows x 36 columns]

# %%
df_analytic.drop(test_leads.index, inplace=True)
df_analytic.reset_index(drop=True, inplace=True)

count_after_dedup_test = df_analytic.shape[0]
count_after_dedup_test
# Out:
# 120

# %%
count_final_data = count_after_dedup_test

# %%
# df_analytic.loc[(df_analytic['Email'] == 'jonmosley6@yahoo.com')]

# %%
df_analytic.replace('empty', '', inplace=True)

# %%
print("==========================================================")
print("Summary")
print("==========================================================")
print("Jumlah Data Awal Zoho Analytic : "+str(count_data_awal))
print("Jumlah Data Email dan Phone Kosong : "+str(count_contact_type_empty))
print("Jumlah Data Setelah Hapus Email dan Phone Yang Kosong : "+str(count_after_contact_type_empty))
print("Jumlah Data Email Yang Termasuk List Karma : "+str(count_email_karma))
print("Jumlah Data Email Setelah List Karma Dihapus : "+str(count_after_clean_karma))
print("Jumlah Data Test : "+str(count_leads_test))
print("Jumlah Data Email Setelah Data Test Dihapus : "+str(count_after_dedup_test))
print("Jumlah Data Akhir : "+str(count_final_data))
# Out:
# ==========================================================
# Summary
# ==========================================================
# Jumlah Data Awal Zoho Analytic : 154
# Jumlah Data Email dan Phone Kosong : 17
# Jumlah Data Setelah Hapus Email dan Phone Yang Kosong : 137
# Jumlah Data Email Yang Termasuk List Karma : 17
# Jumlah Data Email Setelah List Karma Dihapus : 120
# Jumlah Data Test : 0
# Jumlah Data Email Setelah Data Test Dihapus : 120
# Jumlah Data Akhir : 120

# %%
df_analytic.to_excel(r'C:\Users\fajar.fatoni\Documents\Python\Data\check_country_code_analytic.xlsx', index=False)
