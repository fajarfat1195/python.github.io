# %%
import pandas as pd
import re

import past_guest_module as pm

import sys
sys.path.append('../zoho_data_app/')

import main_module as m

# %load_ext autoreload
# %autoreload 2

# %%
path = r'C:\Users\fajar\Documents\Python\Data\Past Guest Data\Zoho Analytic\2024\Okt\20 Okt - 28 Okt\CRM_Rental_Report_20_Okt_-_28_Okt.xlsx'
df_analytic = pd.read_excel(path, dtype='string', sheet_name='Sheet1')
count_data_awal = df_analytic.shape[0]
df_analytic
# Out:
#    Booking_Id         TelNo       MobileNo                           Email  \
# 0    KB043535  +49080266080  4915252705825  axel.reimlinger@karmagroup.com
# 1   KSH020360   07779911336           <NA>     bobthomas118@btinternet.com
# 2   KSM011097   01720422368           <NA>          gm@karma.stmartins.com
# 3    KK059819  +85292718104           <NA>            jamespar72@gmail.com
# 4    KB044957   01711407017           <NA>        jonathan.weiland@gmx.net
# ..        ...           ...            ...                             ...
# 60  KSM012323          <NA>           <NA>                            <NA>
# 61   KB043879          <NA>           <NA>                            <NA>
# 62   KB043879          <NA>           <NA>                            <NA>
# 63   KK058468          <NA>           <NA>                            <NA>
# 64   KB045167          <NA>           <NA>                            <NA>
#
#        Lead Brand Lead Sub- Brand  Lead Source         Resort_Name ProfileRef  \
# 0   Karma Resorts           Other  Past Guests       Karma Bavaria   PF126784
# 1   Karma Resorts           Other  Past Guests  Karma Salford Hall   PF288351
# 2   Karma Resorts           Other  Past Guests    Karma St Martins   PF067424
# 3   Karma Resorts           Other  Past Guests       Karma Kandara   PF242478
# 4   Karma Resorts           Other  Past Guests       Karma Bavaria   PF288931
# ..            ...             ...          ...                 ...        ...
# 60  Karma Resorts           Other  Past Guests    Karma St Martins       <NA>
# 61  Karma Resorts           Other  Past Guests       Karma Bavaria   PF288298
# 62  Karma Resorts           Other  Past Guests       Karma Bavaria   PF288293
# 63  Karma Resorts           Other  Past Guests       Karma Kandara   PF280585
# 64  Karma Resorts           Other  Past Guests       Karma Bavaria   PF290031
#
#    Salutation  ...           DateDepart No. of Nights Market_Segment  \
# 0        Herr  ...  2024-10-25 00:00:00             4           COMP
# 1          Mr  ...  2024-10-20 00:00:00             1            DIR
# 2          Mr  ...  2024-10-24 00:00:00             3           COMP
# 3          Mr  ...  2024-10-20 00:00:00             9      HOUSE_USE
# 4        Herr  ...  2024-10-20 00:00:00             2            DIR
# ..        ...  ...                  ...           ...            ...
# 60       <NA>  ...  2024-10-27 00:00:00             1           COMP
# 61       Frau  ...  2024-10-20 00:00:00             1            LGR
# 62       Frau  ...  2024-10-20 00:00:00             1            DIR
# 63       <NA>  ...  2024-10-24 00:00:00             1            OTA
# 64       Frau  ...  2024-10-28 00:00:00             1            OTA
#
#     Media_Code Media Code Group No. of Adult No. of Children No. of Infants  \
# 0        STAFF             COMP            1               0              0
# 1           TA           RETAIL            2               0              0
# 2        STAFF             COMP            2               0              0
# 3      V_OWNER             COMP            2               0              0
# 4          TEL           RETAIL            2               2              1
# ..         ...              ...          ...             ...            ...
# 60       STAFF             COMP            2               0              0
# 61         LGR            GROUP            2               0              0
# 62         LGR            GROUP            1               0              0
# 63  HYPERGUEST         CHANNELS            2               0              0
# 64         OTA           RETAIL            2               2              0
#
#    Contact Type Odyssey Members
# 0
# 1
# 2
# 3
# 4
# ..          ...             ...
# 60
# 61
# 62
# 63
# 64
#
# [65 rows x 37 columns]

# %%
df_analytic.columns
# Out:
# Index(['Booking_Id', 'TelNo', 'MobileNo', 'Email', 'Lead Brand',
#        'Lead Sub- Brand', 'Lead Source', 'Resort_Name', 'ProfileRef',
#        'Salutation', 'First_Name', 'Surname', 'Gender', 'Language', 'DOB',
#        'Street', 'Area', 'Town', 'County', 'Country', 'Nationality',
#        'PostCode', 'Exclude From Mailing', 'Opt In', 'Booking Code',
#        'Booking Status', 'DateArrival', 'DateDepart', 'No. of Nights',
#        'Market_Segment', 'Media_Code', 'Media Code Group', 'No. of Adult',
#        'No. of Children', 'No. of Infants', 'Contact Type', 'Odyssey Members'],
#       dtype='object')

# %%
new_cols = ['Booking_Id', 'Lead Brand', 'Lead Sub- Brand', 'Lead Source',
       'Resort_Name', 'ProfileRef', 'Salutation', 'First_Name', 'Surname',
       'Gender', 'Language', 'DOB', 'Street', 'Area', 'Town', 'County',
       'Country', 'Nationality', 'PostCode', 'TelNo', 'MobileNo', 'Email',
       'Exclude From Mailing', 'Opt In', 'Booking Status',
       'DateArrival', 'DateDepart', 'No. of Nights', 'Market_Segment',
       'Media_Code', 'Media Code Group', 'No. of Adult', 'No. of Children',
       'No. of Infants', 'Contact Type', 'Odyssey Members']																																																																																																																																						

df_analytic = df_analytic.reindex(columns=new_cols)

# %%
df_analytic.fillna('empty', inplace=True)
df_analytic['Contact Type'] = 'empty'
df_analytic['Odyssey Members'] = 'NO'

# %%
df_analytic.loc[df_analytic['Surname'] == 'empty', 'Surname'] = '-'

# %%
df_analytic['Salutation'].replace('empty', '', inplace=True)
df_analytic['First_Name'].replace('empty', '', inplace=True)
df_analytic['Surname'].replace('empty', '', inplace=True)

df_analytic['Salutation'] = df_analytic['Salutation'].str.title()
df_analytic['First_Name'] = df_analytic['First_Name'].str.title()
df_analytic['Surname'] = df_analytic['Surname'].str.title()

df_analytic
# Out:
# C:\Users\fajar\AppData\Local\Temp\ipykernel_1332\2281604359.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_analytic['Salutation'].replace('empty', '', inplace=True)
# C:\Users\fajar\AppData\Local\Temp\ipykernel_1332\2281604359.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_analytic['First_Name'].replace('empty', '', inplace=True)
# C:\Users\fajar\AppData\Local\Temp\ipykernel_1332\2281604359.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_analytic['Surname'].replace('empty', '', inplace=True)
#    Booking_Id     Lead Brand Lead Sub- Brand  Lead Source         Resort_Name  \
# 0    KB043535  Karma Resorts           Other  Past Guests       Karma Bavaria
# 1   KSH020360  Karma Resorts           Other  Past Guests  Karma Salford Hall
# 2   KSM011097  Karma Resorts           Other  Past Guests    Karma St Martins
# 3    KK059819  Karma Resorts           Other  Past Guests       Karma Kandara
# 4    KB044957  Karma Resorts           Other  Past Guests       Karma Bavaria
# ..        ...            ...             ...          ...                 ...
# 60  KSM012323  Karma Resorts           Other  Past Guests    Karma St Martins
# 61   KB043879  Karma Resorts           Other  Past Guests       Karma Bavaria
# 62   KB043879  Karma Resorts           Other  Past Guests       Karma Bavaria
# 63   KK058468  Karma Resorts           Other  Past Guests       Karma Kandara
# 64   KB045167  Karma Resorts           Other  Past Guests       Karma Bavaria
#
#    ProfileRef Salutation          First_Name       Surname   Gender  ...  \
# 0    PF126784       Herr                Axel    Reimlinger     Male  ...
# 1    PF288351         Mr                 Bob        Thomas     Male  ...
# 2    PF067424         Mr  Karma St. Martin'S    Management     Male  ...
# 3    PF242478         Mr               James       Parsons     Male  ...
# 4    PF288931       Herr            Jonathan       Weiland     Male  ...
# ..        ...        ...                 ...           ...      ...  ...
# 60      empty                                    Musicians  Unknown  ...
# 61   PF288298       Frau              Sigrid       Skrobek   Female  ...
# 62   PF288293       Frau              Sabine        Peschl   Female  ...
# 63   PF280585                   Test Booking  Test Booking  Unknown  ...
# 64   PF290031       Frau              Carmen         Nagel  Unknown  ...
#
#              DateDepart No. of Nights Market_Segment  Media_Code  \
# 0   2024-10-25 00:00:00             4           COMP       STAFF
# 1   2024-10-20 00:00:00             1            DIR          TA
# 2   2024-10-24 00:00:00             3           COMP       STAFF
# 3   2024-10-20 00:00:00             9      HOUSE_USE     V_OWNER
# 4   2024-10-20 00:00:00             2            DIR         TEL
# ..                  ...           ...            ...         ...
# 60  2024-10-27 00:00:00             1           COMP       STAFF
# 61  2024-10-20 00:00:00             1            LGR         LGR
# 62  2024-10-20 00:00:00             1            DIR         LGR
# 63  2024-10-24 00:00:00             1            OTA  HYPERGUEST
# 64  2024-10-28 00:00:00             1            OTA         OTA
#
#    Media Code Group No. of Adult No. of Children No. of Infants Contact Type  \
# 0              COMP            1               0              0        empty
# 1            RETAIL            2               0              0        empty
# 2              COMP            2               0              0        empty
# 3              COMP            2               0              0        empty
# 4            RETAIL            2               2              1        empty
# ..              ...          ...             ...            ...          ...
# 60             COMP            2               0              0        empty
# 61            GROUP            2               0              0        empty
# 62            GROUP            1               0              0        empty
# 63         CHANNELS            2               0              0        empty
# 64           RETAIL            2               2              0        empty
#
#    Odyssey Members
# 0               NO
# 1               NO
# 2               NO
# 3               NO
# 4               NO
# ..             ...
# 60              NO
# 61              NO
# 62              NO
# 63              NO
# 64              NO
#
# [65 rows x 36 columns]

# %%
m.clean_number(df_analytic, 'TelNo')
m.clean_number(df_analytic, 'MobileNo')
m.replace_not_valid_to_empty(df_analytic, 'TelNo')
m.replace_not_valid_to_empty(df_analytic, 'MobileNo')

df_analytic.loc[df_analytic['TelNo'].str.contains('00000'), 'TelNo'] = 'empty'
df_analytic.loc[df_analytic['MobileNo'].str.contains('00000'), 'MobileNo'] = 'empty'

m.clean_space(df_analytic, 'Email')
df_analytic['Email'] = m.lowercase(df_analytic, 'Email')
# Out:
# c:\Users\fajar\Documents\Python\Task Offline\past_guest_toni_app\../zoho_data_app\main_module.py:67: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[df_columns].replace(' ','', regex=True, inplace=True)
# c:\Users\fajar\Documents\Python\Task Offline\past_guest_toni_app\../zoho_data_app\main_module.py:68: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[df_columns].replace('[^0-9]','', regex=True, inplace=True)
# c:\Users\fajar\Documents\Python\Task Offline\past_guest_toni_app\../zoho_data_app\main_module.py:90: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[df_columns].replace(' ','', regex=True, inplace=True)

# %%
m.email_correction(df_analytic, 'Email')
# Out:
# c:\Users\fajar\Documents\Python\Task Offline\past_guest_toni_app\../zoho_data_app\main_module.py:193: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[df_columns].replace('mailto:','', inplace=True)

# %%
df_analytic.loc[(df_analytic['Email'] != 'empty') & ((df_analytic['TelNo'] != 'empty') | (df_analytic['MobileNo'] != 'empty')), 'Contact Type'] = 'Email and Phone'
df_analytic.loc[(df_analytic['Email'] != 'empty') & ((df_analytic['TelNo'] == 'empty') & (df_analytic['MobileNo'] == 'empty')), 'Contact Type'] = 'Email Only'
df_analytic.loc[(df_analytic['Email'] == 'empty') & ((df_analytic['TelNo'] != 'empty') | (df_analytic['MobileNo'] != 'empty')), 'Contact Type'] = 'Phone Only'

df_analytic.loc[df_analytic['Contact Type'] == 'empty'].to_csv(r'C:\Users\fajar\Documents\Python\Data\contact_type_empty_analytic.csv', index=False)

count_contact_type_empty = df_analytic.loc[df_analytic['Contact Type'] == 'empty'].shape[0]

df_analytic.drop(df_analytic.loc[df_analytic['Contact Type'] == 'empty'].index, inplace=True)
df_analytic.reset_index(drop=True, inplace=True)

count_after_contact_type_empty = df_analytic.shape[0]

df_analytic
# Out:
#    Booking_Id     Lead Brand Lead Sub- Brand  Lead Source         Resort_Name  \
# 0    KB043535  Karma Resorts           Other  Past Guests       Karma Bavaria
# 1   KSH020360  Karma Resorts           Other  Past Guests  Karma Salford Hall
# 2   KSM011097  Karma Resorts           Other  Past Guests    Karma St Martins
# 3    KK059819  Karma Resorts           Other  Past Guests       Karma Kandara
# 4    KB044957  Karma Resorts           Other  Past Guests       Karma Bavaria
# ..        ...            ...             ...          ...                 ...
# 60  KSM012323  Karma Resorts           Other  Past Guests    Karma St Martins
# 61   KB043879  Karma Resorts           Other  Past Guests       Karma Bavaria
# 62   KB043879  Karma Resorts           Other  Past Guests       Karma Bavaria
# 63   KK058468  Karma Resorts           Other  Past Guests       Karma Kandara
# 64   KB045167  Karma Resorts           Other  Past Guests       Karma Bavaria
#
#    ProfileRef Salutation          First_Name       Surname   Gender  ...  \
# 0    PF126784       Herr                Axel    Reimlinger     Male  ...
# 1    PF288351         Mr                 Bob        Thomas     Male  ...
# 2    PF067424         Mr  Karma St. Martin'S    Management     Male  ...
# 3    PF242478         Mr               James       Parsons     Male  ...
# 4    PF288931       Herr            Jonathan       Weiland     Male  ...
# ..        ...        ...                 ...           ...      ...  ...
# 60      empty                                    Musicians  Unknown  ...
# 61   PF288298       Frau              Sigrid       Skrobek   Female  ...
# 62   PF288293       Frau              Sabine        Peschl   Female  ...
# 63   PF280585                   Test Booking  Test Booking  Unknown  ...
# 64   PF290031       Frau              Carmen         Nagel  Unknown  ...
#
#              DateDepart No. of Nights Market_Segment  Media_Code  \
# 0   2024-10-25 00:00:00             4           COMP       STAFF
# 1   2024-10-20 00:00:00             1            DIR          TA
# 2   2024-10-24 00:00:00             3           COMP       STAFF
# 3   2024-10-20 00:00:00             9      HOUSE_USE     V_OWNER
# 4   2024-10-20 00:00:00             2            DIR         TEL
# ..                  ...           ...            ...         ...
# 60  2024-10-27 00:00:00             1           COMP       STAFF
# 61  2024-10-20 00:00:00             1            LGR         LGR
# 62  2024-10-20 00:00:00             1            DIR         LGR
# 63  2024-10-24 00:00:00             1            OTA  HYPERGUEST
# 64  2024-10-28 00:00:00             1            OTA         OTA
#
#    Media Code Group No. of Adult No. of Children No. of Infants  \
# 0              COMP            1               0              0
# 1            RETAIL            2               0              0
# 2              COMP            2               0              0
# 3              COMP            2               0              0
# 4            RETAIL            2               2              1
# ..              ...          ...             ...            ...
# 60             COMP            2               0              0
# 61            GROUP            2               0              0
# 62            GROUP            1               0              0
# 63         CHANNELS            2               0              0
# 64           RETAIL            2               2              0
#
#        Contact Type Odyssey Members
# 0   Email and Phone              NO
# 1   Email and Phone              NO
# 2   Email and Phone              NO
# 3   Email and Phone              NO
# 4   Email and Phone              NO
# ..              ...             ...
# 60       Email Only              NO
# 61       Email Only              NO
# 62       Email Only              NO
# 63       Email Only              NO
# 64       Email Only              NO
#
# [65 rows x 36 columns]

# %%
# Cek Email Karma
email_karma = m.find_karma(df_analytic, 'Email')
count_email_karma = email_karma.shape[0]
email_karma.to_csv(r'C:\Users\fajar\Documents\Python\Data\email_deleted_analytic.csv', index=False)

email_karma
# Out:
#   Booking_Id     Lead Brand Lead Sub- Brand  Lead Source    Resort_Name  \
# 0   KB043535  Karma Resorts           Other  Past Guests  Karma Bavaria
#
#   ProfileRef Salutation First_Name     Surname Gender  ...  \
# 0   PF126784       Herr       Axel  Reimlinger   Male  ...
#
#             DateDepart No. of Nights Market_Segment Media_Code  \
# 0  2024-10-25 00:00:00             4           COMP      STAFF
#
#   Media Code Group No. of Adult No. of Children No. of Infants  \
# 0             COMP            1               0              0
#
#       Contact Type Odyssey Members
# 0  Email and Phone              NO
#
# [1 rows x 36 columns]

# %%
# delete email Karma
count_after_clean_karma = m.delete_karma(df_analytic, 'Email')

df_analytic
# Out:
#    Booking_Id     Lead Brand Lead Sub- Brand  Lead Source         Resort_Name  \
# 0   KSH020360  Karma Resorts           Other  Past Guests  Karma Salford Hall
# 1   KSM011097  Karma Resorts           Other  Past Guests    Karma St Martins
# 2    KK059819  Karma Resorts           Other  Past Guests       Karma Kandara
# 3    KB044957  Karma Resorts           Other  Past Guests       Karma Bavaria
# 4    KB043167  Karma Resorts           Other  Past Guests       Karma Bavaria
# ..        ...            ...             ...          ...                 ...
# 59  KSM012323  Karma Resorts           Other  Past Guests    Karma St Martins
# 60   KB043879  Karma Resorts           Other  Past Guests       Karma Bavaria
# 61   KB043879  Karma Resorts           Other  Past Guests       Karma Bavaria
# 62   KK058468  Karma Resorts           Other  Past Guests       Karma Kandara
# 63   KB045167  Karma Resorts           Other  Past Guests       Karma Bavaria
#
#    ProfileRef Salutation          First_Name       Surname   Gender  ...  \
# 0    PF288351         Mr                 Bob        Thomas     Male  ...
# 1    PF067424         Mr  Karma St. Martin'S    Management     Male  ...
# 2    PF242478         Mr               James       Parsons     Male  ...
# 3    PF288931       Herr            Jonathan       Weiland     Male  ...
# 4    PF278714       Frau               Lobna         Magdy   Female  ...
# ..        ...        ...                 ...           ...      ...  ...
# 59      empty                                    Musicians  Unknown  ...
# 60   PF288298       Frau              Sigrid       Skrobek   Female  ...
# 61   PF288293       Frau              Sabine        Peschl   Female  ...
# 62   PF280585                   Test Booking  Test Booking  Unknown  ...
# 63   PF290031       Frau              Carmen         Nagel  Unknown  ...
#
#              DateDepart No. of Nights Market_Segment  Media_Code  \
# 0   2024-10-20 00:00:00             1            DIR          TA
# 1   2024-10-24 00:00:00             3           COMP       STAFF
# 2   2024-10-20 00:00:00             9      HOUSE_USE     V_OWNER
# 3   2024-10-20 00:00:00             2            DIR         TEL
# 4   2024-10-24 18:00:00             0             CB          CB
# ..                  ...           ...            ...         ...
# 59  2024-10-27 00:00:00             1           COMP       STAFF
# 60  2024-10-20 00:00:00             1            LGR         LGR
# 61  2024-10-20 00:00:00             1            DIR         LGR
# 62  2024-10-24 00:00:00             1            OTA  HYPERGUEST
# 63  2024-10-28 00:00:00             1            OTA         OTA
#
#    Media Code Group No. of Adult No. of Children No. of Infants  \
# 0            RETAIL            2               0              0
# 1              COMP            2               0              0
# 2              COMP            2               0              0
# 3            RETAIL            2               2              1
# 4             GROUP            1               0              0
# ..              ...          ...             ...            ...
# 59             COMP            2               0              0
# 60            GROUP            2               0              0
# 61            GROUP            1               0              0
# 62         CHANNELS            2               0              0
# 63           RETAIL            2               2              0
#
#        Contact Type Odyssey Members
# 0   Email and Phone              NO
# 1   Email and Phone              NO
# 2   Email and Phone              NO
# 3   Email and Phone              NO
# 4   Email and Phone              NO
# ..              ...             ...
# 59       Email Only              NO
# 60       Email Only              NO
# 61       Email Only              NO
# 62       Email Only              NO
# 63       Email Only              NO
#
# [64 rows x 36 columns]

# %%
df_analytic['Salutation']
# Out:
# 0       Mr
# 1       Mr
# 2       Mr
# 3     Herr
# 4     Frau
#       ...
# 59
# 60    Frau
# 61    Frau
# 62
# 63    Frau
# Name: Salutation, Length: 64, dtype: string

# %%
# Cek leads test
test_leads = df_analytic.loc[
    
        df_analytic['Email'].str.contains('^test@', flags=re.I, regex=True) |
        df_analytic['Email'].str.contains('\+test', flags=re.I, regex=True) |
    
        df_analytic['First_Name'].str.contains('^test$', flags=re.I, regex=True) |
        df_analytic['Surname'].str.contains('^test$', flags=re.I, regex=True) |

        df_analytic['First_Name'].str.contains('test 1', flags=re.I, regex=True) |
        df_analytic['Surname'].str.contains('test 2', flags=re.I, regex=True)|
        df_analytic['First_Name'].str.contains('test1', flags=re.I, regex=True) |
        df_analytic['Surname'].str.contains('test2', flags=re.I, regex=True)|

        df_analytic['First_Name'].str.contains(' test ', flags=re.I, regex=True) | 
        df_analytic['Surname'].str.contains(' test ', flags=re.I, regex=True) | 
        df_analytic['Surname'].str.contains(' test$', flags=re.I, regex=True)
    ]

count_leads_test = test_leads.shape[0]

test_leads.to_csv(r'C:\Users\fajar\Documents\Python\Data\test_leads_analytic.csv', index=False)
test_leads
# Out:
# Empty DataFrame
# Columns: [Booking_Id, Lead Brand, Lead Sub- Brand, Lead Source, Resort_Name, ProfileRef, Salutation, First_Name, Surname, Gender, Language, DOB, Street, Area, Town, County, Country, Nationality, PostCode, TelNo, MobileNo, Email, Exclude From Mailing, Opt In, Booking Status, DateArrival, DateDepart, No. of Nights, Market_Segment, Media_Code, Media Code Group, No. of Adult, No. of Children, No. of Infants, Contact Type, Odyssey Members]
# Index: []
#
# [0 rows x 36 columns]

# %%
df_analytic.drop(test_leads.index, inplace=True)
df_analytic.reset_index(drop=True, inplace=True)

count_after_dedup_test = df_analytic.shape[0]
count_after_dedup_test
# Out:
# 64

# %%
count_final_data = count_after_dedup_test

# %%
# df_analytic.loc[(df_analytic['Email'] == 'jonmosley6@yahoo.com')]

# %%
df_analytic.replace('empty', '', inplace=True)

# %%
print("==========================================================")
print("Summary")
print("==========================================================")
print("Jumlah Data Awal Zoho Analytic : "+str(count_data_awal))
print("Jumlah Data Email dan Phone Kosong : "+str(count_contact_type_empty))
print("Jumlah Data Setelah Hapus Email dan Phone Yang Kosong : "+str(count_after_contact_type_empty))
print("Jumlah Data Email Yang Termasuk List Karma : "+str(count_email_karma))
print("Jumlah Data Email Setelah List Karma Dihapus : "+str(count_after_clean_karma))
print("Jumlah Data Test : "+str(count_leads_test))
print("Jumlah Data Email Setelah Data Test Dihapus : "+str(count_after_dedup_test))
print("Jumlah Data Akhir : "+str(count_final_data))
# Out:
# ==========================================================
# Summary
# ==========================================================
# Jumlah Data Awal Zoho Analytic : 65
# Jumlah Data Email dan Phone Kosong : 0
# Jumlah Data Setelah Hapus Email dan Phone Yang Kosong : 65
# Jumlah Data Email Yang Termasuk List Karma : 1
# Jumlah Data Email Setelah List Karma Dihapus : 64
# Jumlah Data Test : 0
# Jumlah Data Email Setelah Data Test Dihapus : 64
# Jumlah Data Akhir : 64

# %%
df_analytic.to_excel(r'C:\Users\fajar\Documents\Python\Data\check_country_code_analytic.xlsx', index=False)
