# %%
import pandas as pd
import re

import past_guest_module as pm

import sys
sys.path.append('../zoho_data_app/')

import main_module as m

# %load_ext autoreload
# %autoreload 2

# %%
path = r'C:\Users\fajar.fatoni\Documents\Python\Data\check_country_code_analytic.xlsx'
df_analytic = pd.read_excel(path, dtype='string', sheet_name='Sheet1')
count_data_awal = df_analytic.shape[0]
df_analytic
# Out:
#        BookRef     Lead Brand Lead Sub-Brand  Lead Source  \
# 0    KLM007585  Karma Resorts          Other  Past Guests
# 1    KLM007185  Karma Resorts          Other  Past Guests
# 2    KLM007256  Karma Resorts          Other  Past Guests
# 3    KLM007363  Karma Resorts          Other  Past Guests
# 4    KLM007340  Karma Resorts          Other  Past Guests
# ..         ...            ...            ...          ...
# 143   KB046460  Karma Resorts          Other  Past Guests
# 144   KB046847  Karma Resorts          Other  Past Guests
# 145   KB046709  Karma Resorts          Other  Past Guests
# 146   KB046842  Karma Resorts          Other  Past Guests
# 147   KB046847  Karma Resorts          Other  Past Guests
#
#               Lead Location PrimaryGuestProfileRef PrimaryGuestTitle  \
# 0    Karma Lake of Menteith                   <NA>                Mr
# 1    Karma Lake of Menteith                   <NA>                Ms
# 2    Karma Lake of Menteith                   <NA>               Mrs
# 3    Karma Lake of Menteith                   <NA>                Ms
# 4    Karma Lake of Menteith                   <NA>                Ms
# ..                      ...                    ...               ...
# 143           Karma Bavaria                   <NA>              Herr
# 144           Karma Bavaria                   <NA>              Frau
# 145           Karma Bavaria                   <NA>              Herr
# 146           Karma Bavaria                   <NA>              Herr
# 147           Karma Bavaria                   <NA>              Herr
#
#     PrimaryGuestForename PrimaryGuestSurname Gender  ...           DateDepart  \
# 0                Charles                Keay   <NA>  ...  2024-12-13 00:00:00
# 1                  Diana             Carmody   <NA>  ...  2024-11-29 00:00:00
# 2                   Anne              Aitken   <NA>  ...  2024-11-18 00:00:00
# 3                 Sufiya               Ahmed   <NA>  ...  2024-11-17 00:00:00
# 4                 Amanda              Saurin   <NA>  ...  2024-11-14 00:00:00
# ..                   ...                 ...    ...  ...                  ...
# 143            Christian            Schroder   <NA>  ...  2025-01-04 00:00:00
# 144            Christine              Sikler   <NA>  ...  2025-01-03 00:00:00
# 145               Harald                King   <NA>  ...  2025-01-03 00:00:00
# 146            Christian                Beck   <NA>  ...  2025-01-03 00:00:00
# 147                Ewald              Sikler   <NA>  ...  2025-01-03 00:00:00
#
#     No. of Nights MarketSegment MediaSourceCode MediaCodeGroup Adults  \
# 0            <NA>           DIR            <NA>        DIGITAL   <NA>
# 1            <NA>           DIR            <NA>         RETAIL   <NA>
# 2            <NA>           OTA            <NA>         RETAIL   <NA>
# 3            <NA>           OTA            <NA>         RETAIL   <NA>
# 4            <NA>           DIR            <NA>          GROUP   <NA>
# ..            ...           ...             ...            ...    ...
# 143          <NA>           OTA            <NA>         RETAIL   <NA>
# 144          <NA>           OTA            <NA>         RETAIL   <NA>
# 145          <NA>           DIR            <NA>        DIGITAL   <NA>
# 146          <NA>           OTA            <NA>         RETAIL   <NA>
# 147          <NA>           OTA            <NA>         RETAIL   <NA>
#
#     Children Infants Contact Type Odyssey Members
# 0       <NA>    <NA>         <NA>              NO
# 1       <NA>    <NA>         <NA>              NO
# 2       <NA>    <NA>         <NA>              NO
# 3       <NA>    <NA>         <NA>              NO
# 4       <NA>    <NA>         <NA>              NO
# ..       ...     ...          ...             ...
# 143     <NA>    <NA>         <NA>              NO
# 144     <NA>    <NA>         <NA>              NO
# 145     <NA>    <NA>         <NA>              NO
# 146     <NA>    <NA>         <NA>              NO
# 147     <NA>    <NA>         <NA>              NO
#
# [148 rows x 36 columns]

# %%
df_analytic.columns
# Out:
# Index(['BookRef', 'Lead Brand', 'Lead Sub-Brand', 'Lead Source',
#        'Lead Location', 'PrimaryGuestProfileRef', 'PrimaryGuestTitle',
#        'PrimaryGuestForename', 'PrimaryGuestSurname', 'Gender', 'Language',
#        'DOB', 'Street', 'Area', 'Town', 'County', 'Country', 'Nationality',
#        'PostCode', 'TelNo', 'MobileNo', 'EMail', 'ExcludeFromMailings',
#        'Opt In', 'BookingStatus', 'DateArrive', 'DateDepart', 'No. of Nights',
#        'MarketSegment', 'MediaSourceCode', 'MediaCodeGroup', 'Adults',
#        'Children', 'Infants', 'Contact Type', 'Odyssey Members'],
#       dtype='object')

# %%
df_analytic.fillna('empty', inplace=True)

# %%
path = r'G:\.shortcut-targets-by-id\0B_d3smBjzo04UUNBME5GOVhoMjA\_ODYSSEY\Phone Members.xlsx'
df_phone = pd.read_excel(path, dtype='string', sheet_name='Sheet1')

path = r'G:\.shortcut-targets-by-id\0B_d3smBjzo04UUNBME5GOVhoMjA\_ODYSSEY\Email Members.xlsx'
df_email = pd.read_excel(path, dtype='string', sheet_name='Sheet1')

# %%
m.clean_space(df_email, 'Email')
df_email['Email'] = m.lowercase(df_email, 'Email')
# Out:
# c:\Users\fajar.fatoni\Documents\Python\Task Offline\past_guest_toni_app\../zoho_data_app\main_module.py:127: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[df_columns].replace(' ','', regex=True, inplace=True)

# %%
# hitung jumlah duplicate
count_duplicate_general = df_analytic.loc[df_analytic.duplicated(subset=['TelNo','MobileNo','Email'])].shape[0]

df_analytic.loc[df_analytic.duplicated(subset=['TelNo','MobileNo','Email'])]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_20604\3492970060.py in ?()
#       1 # hitung jumlah duplicate
# ----> 2 count_duplicate_general = df_analytic.loc[df_analytic.duplicated(subset=['TelNo','MobileNo','Email'])].shape[0]
#       3
#       4 df_analytic.loc[df_analytic.duplicated(subset=['TelNo','MobileNo','Email'])]
#
# c:\Users\fajar.fatoni\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\frame.py in ?(self, subset, keep)
#    6946         # Otherwise, raise a KeyError, same as if you try to __getitem__ with a
#    6947         # key that doesn't exist.
#    6948         diff = set(subset) - set(self.columns)
#    6949         if diff:
# -> 6950             raise KeyError(Index(diff))
#    6951
#    6952         if len(subset) == 1 and self.columns.is_unique:
#    6953             # GH#45236 This is faster than get_group_index below
#
# KeyError: Index(['Email'], dtype='object')

# %%
df_analytic.drop_duplicates(subset=['TelNo','MobileNo','Email'], inplace=True)
df_analytic.reset_index(drop=True, inplace=True)

# hitung jumlah setelah value duplicate dihapus
count_after_dedup_duplicate = df_analytic.shape[0]

df_analytic
# Out:
#     Booking_Id     Lead Brand Lead Sub- Brand  Lead Source       Resort_Name  \
# 0     KK068418  Karma Resorts           Other  Past Guests     Karma Kandara
# 1    KSM012810  Karma Resorts           Other  Past Guests  Karma St Martins
# 2     KK071202  Karma Resorts           Other  Past Guests     Karma Kandara
# 3     KK065489  Karma Resorts           Other  Past Guests     Karma Kandara
# 4     KK065233  Karma Resorts           Other  Past Guests     Karma Kandara
# ..         ...            ...             ...          ...               ...
# 519   KK073940  Karma Resorts           Other  Past Guests     Karma Kandara
# 520  KSM012731  Karma Resorts           Other  Past Guests  Karma St Martins
# 521   KK070290  Karma Resorts           Other  Past Guests     Karma Kandara
# 522   KK072311  Karma Resorts           Other  Past Guests     Karma Kandara
# 523  KSM013613  Karma Resorts           Other  Past Guests  Karma St Martins
#
#     ProfileRef Salutation    First_Name    Surname   Gender  ...  \
# 0     PF300961         Mr       Anthony      Zanco     Male  ...
# 1     PF110200         Mr          Alan     Davies     Male  ...
# 2     PF306575         Ms       Arianna       Gusi   Female  ...
# 3     PF293718         Mr        Andrew      White     Male  ...
# 4     PF087370         Mr  Andrew James     Parkes     Male  ...
# ..         ...        ...           ...        ...      ...  ...
# 519   PF313082      empty          Gwen      Mwila  Unknown  ...
# 520   PF184301      empty      Caroline    Denholm  Unknown  ...
# 521   PF304726      empty         Julie    Farrell  Unknown  ...
# 522   PF308937      empty      Huiyoung        Lee  Unknown  ...
# 523   PF282077      empty        Gaynor  Pritchard  Unknown  ...
#
#               DateDepart No. of Nights Market_Segment   Media_Code  \
# 0    2025-05-12 00:00:00             3            OTA          OTA
# 1    2025-05-24 00:00:00             5            DIR          TEL
# 2    2025-05-15 00:00:00             2      HOUSE_USE  V_OWNER_NRB
# 3    2025-05-21 00:00:00             9            DIR         CHAT
# 4    2025-05-15 00:00:00             6      HOUSE_USE        PRESS
# ..                   ...           ...            ...          ...
# 519  2025-06-06 00:00:00            31        DIGITAL          OTA
# 520  2025-06-04 00:00:00             2            DIR          TEL
# 521  2025-05-11 00:00:00             4            OTA          OTA
# 522  2025-05-13 00:00:00             2            OTA          OTA
# 523  2025-05-27 00:00:00             6            OTA          OTA
#
#     Media Code Group No. of Adult No. of Children No. of Infants  \
# 0             RETAIL            3               1              0
# 1             RETAIL            2               0              0
# 2               COMP            3               0              0
# 3            DIGITAL            4               0              0
# 4              MEDIA            2               1              0
# ..               ...          ...             ...            ...
# 519           RETAIL            2               0              0
# 520           RETAIL            2               0              0
# 521           RETAIL            3               0              0
# 522           RETAIL            2               0              0
# 523           RETAIL            2               0              0
#
#         Contact Type Odyssey Members
# 0    Email and Phone              NO
# 1    Email and Phone              NO
# 2    Email and Phone              NO
# 3    Email and Phone              NO
# 4    Email and Phone              NO
# ..               ...             ...
# 519  Email and Phone              NO
# 520  Email and Phone              NO
# 521  Email and Phone              NO
# 522  Email and Phone              NO
# 523  Email and Phone              NO
#
# [524 rows x 36 columns]

# %%
find_member_booking = df_analytic.copy()

find_member_booking.loc[find_member_booking['TelNo'].isin(df_phone['Mobile']), 'Same Value Find'] = 'Member-Mobile' 
find_member_booking.loc[find_member_booking['MobileNo'].isin(df_phone['Mobile']), 'Same Value Find'] = 'Member-Mobile'

find_member_booking.loc[find_member_booking['Email'].isin(df_email['Email']), 'Same Value Find'] = 'Member-Email'
find_member_booking.drop(find_member_booking.loc[find_member_booking['Same Value Find'].isna()].index, inplace=True)

find_member_booking.replace('empty', '', inplace=True)

# %%
find_member_booking.to_csv(r'C:\Users\fajar.fatoni\Documents\Python\Data\cek_member_zoho_analytic.csv', index=False)

# %%
count_dedup_member = df_analytic.loc[
    
    df_analytic['TelNo'].isin(df_phone['Mobile']) | 
    df_analytic['MobileNo'].isin(df_phone['Mobile']) |

    df_analytic['Email'].isin(df_email['Email'])].shape[0]


df_analytic.loc[
    
    df_analytic['TelNo'].isin(df_phone['Mobile']) | 
    df_analytic['MobileNo'].isin(df_phone['Mobile']) |

    df_analytic['Email'].isin(df_email['Email'])]
# Out:
#     Booking_Id     Lead Brand Lead Sub- Brand  Lead Source       Resort_Name  \
# 1    KSM012810  Karma Resorts           Other  Past Guests  Karma St Martins
# 75    KB045756  Karma Resorts           Other  Past Guests     Karma Bavaria
# 77   KSM013745  Karma Resorts           Other  Past Guests  Karma St Martins
# 82    KB047700  Karma Resorts           Other  Past Guests     Karma Bavaria
# 87    KB046360  Karma Resorts           Other  Past Guests     Karma Bavaria
# 89    KB035688  Karma Resorts           Other  Past Guests     Karma Bavaria
# 92    KB050805  Karma Resorts           Other  Past Guests     Karma Bavaria
# 94    KB044154  Karma Resorts           Other  Past Guests     Karma Bavaria
# 98    KB050586  Karma Resorts           Other  Past Guests     Karma Bavaria
# 99    KB046478  Karma Resorts           Other  Past Guests     Karma Bavaria
# 100   KB047964  Karma Resorts           Other  Past Guests     Karma Bavaria
# 117   KB043667  Karma Resorts           Other  Past Guests     Karma Bavaria
# 132   KB049154  Karma Resorts           Other  Past Guests     Karma Bavaria
# 137   KB048408  Karma Resorts           Other  Past Guests     Karma Bavaria
# 146   KB045523  Karma Resorts           Other  Past Guests     Karma Bavaria
# 150   KB050910  Karma Resorts           Other  Past Guests     Karma Bavaria
# 162   KB041739  Karma Resorts           Other  Past Guests     Karma Bavaria
# 223   KB050452  Karma Resorts           Other  Past Guests     Karma Bavaria
# 228   KK067040  Karma Resorts           Other  Past Guests     Karma Kandara
# 229   KK067197  Karma Resorts           Other  Past Guests     Karma Kandara
# 237   KK075053  Karma Resorts           Other  Past Guests     Karma Kandara
# 254   KK074509  Karma Resorts           Other  Past Guests     Karma Kandara
# 275   KB043668  Karma Resorts           Other  Past Guests     Karma Bavaria
# 295   KK071435  Karma Resorts           Other  Past Guests     Karma Kandara
# 307  KSM014925  Karma Resorts           Other  Past Guests  Karma St Martins
# 356  KSM015504  Karma Resorts           Other  Past Guests  Karma St Martins
# 366  KSM013987  Karma Resorts           Other  Past Guests  Karma St Martins
# 446  KSM014963  Karma Resorts           Other  Past Guests  Karma St Martins
# 466  KSM012759  Karma Resorts           Other  Past Guests  Karma St Martins
# 520  KSM012731  Karma Resorts           Other  Past Guests  Karma St Martins
#
#     ProfileRef Salutation          First_Name            Surname   Gender  \
# 1     PF110200         Mr                Alan             Davies     Male
# 75    PF147772      empty             Claudia              Goebl   Female
# 77    PF276256      Prof.            Dietrich           Grashoff  Unknown
# 82    PF302454       Frau                 Eva        Lingscheidt   Female
# 87    PF250879         Mr               Georg        Freundorfer     Male
# 89    PF198616       Herr        Johann-Georg             Balkau     Male
# 92    PF192683       Frau             Kathrin               Haas   Female
# 94    PF280810       Herr              Harald            Brixner   Female
# 98    PF133894         Mr               Anton          Schwenzer     Male
# 99    PF310645       Frau             Christa          Schwenzer   Female
# 100   PF316414       Herr               Franz              Trapp     Male
# 117   PF311488         Ms             Kirtana          Ganapathi   Female
# 132   PF065347        Dr.              Marion           Peckmann   Female
# 137   PF168613       Frau             Antonia            Caspers   Female
# 146   PF216954       Herr               David             Raguin     Male
# 150   PF242189        Mrs              Sabine       Rimschneider   Female
# 162   PF264770       Herr  Timotheus Matthaus           Stroebel     Male
# 223   PF294155         Mr              Amey V           Kanitkar     Male
# 228   PF297585      empty               Shiju              Shaji  Unknown
# 229   PF295577      empty              Sourab           Pramanik  Unknown
# 237   PF316107         Mr           Armansyah  Jefrikurnia Ganto     Male
# 254   PF314662         Mr                Jack           Mollison     Male
# 275   PF305002      empty         Peter James          Goldstone  Unknown
# 295   PF263751        Mrs                Lene            Fischer   Female
# 307   PF067859       Miss              Lauren               Wall  Unknown
# 356   PF067424         Mr  Karma St. Martin'S         Management     Male
# 366   PF065464         Mr                Hugh              Curry  Unknown
# 446   PF052879         Mr                Paul           Slocombe     Male
# 466   PF266201         Mr               Simon              Yates  Unknown
# 520   PF184301      empty            Caroline            Denholm  Unknown
#
#      ...           DateDepart No. of Nights Market_Segment   Media_Code  \
# 1    ...  2025-05-24 00:00:00             5            DIR          TEL
# 75   ...  2025-05-18 00:00:00             2           COMP      GER_OWE
# 77   ...  2025-05-29 00:00:00             5           COMP      GER_OWE
# 82   ...  2025-05-09 00:00:00             4           COMP      GER_OWE
# 87   ...  2025-06-13 00:00:00             7           COMP      GER_OWE
# 89   ...  2025-06-09 00:00:00             3           COMP      GER_OWE
# 92   ...  2025-06-08 00:00:00             2           COMP      GER_OWE
# 94   ...  2025-06-01 00:00:00             5           COMP      GER_OWE
# 98   ...  2025-05-11 00:00:00             1           COMP      GER_OWE
# 99   ...  2025-05-10 00:00:00             1           COMP      GER_OWE
# 100  ...  2025-05-28 00:00:00             2           COMP      GER_OWE
# 117  ...  2025-05-15 00:00:00            15     STAFF_PRIV        STAFF
# 132  ...  2025-05-31 00:00:00             2           COMP      GER_OWE
# 137  ...  2025-06-08 00:00:00             7           COMP      GER_OWE
# 146  ...  2025-06-10 00:00:00             3           COMP      GER_OWE
# 150  ...  2025-05-25 00:00:00             2           COMP      GER_OWE
# 162  ...  2025-06-01 00:00:00             3           COMP      GER_OWE
# 223  ...  2025-05-10 00:00:00             7           COMP       MEMBER
# 228  ...  2025-06-03 00:00:00             2           COMP     RESERVED
# 229  ...  2025-06-07 00:00:00             3           COMP     RESERVED
# 237  ...  2025-05-26 00:00:00             2            OTA          OTA
# 254  ...  2025-05-23 00:00:00             1      HOUSE_USE  V_OWNER_NRB
# 275  ...  2025-05-17 00:00:00            16     STAFF_PRIV        STAFF
# 295  ...  2025-05-16 00:00:00             9      HOUSE_USE  V_OWNER_NRB
# 307  ...  2025-05-08 00:00:00             1            DIR          TEL
# 356  ...  2025-05-15 00:00:00             2           COMP          TEL
# 366  ...  2025-05-26 00:00:00             6            DIR       WALKIN
# 446  ...  2025-05-15 00:00:00             3            DIR          TEL
# 466  ...  2025-05-24 00:00:00             7            DIR       WALKIN
# 520  ...  2025-06-04 00:00:00             2            DIR          TEL
#
#     Media Code Group No. of Adult No. of Children No. of Infants  \
# 1             RETAIL            2               0              0
# 75              COMP            2               0              0
# 77              COMP            2               0              0
# 82              COMP            2               0              0
# 87              COMP            2               0              0
# 89              COMP            2               1              0
# 92              COMP            2               0              0
# 94              COMP            2               0              0
# 98              COMP            2               0              0
# 99              COMP            2               0              0
# 100             COMP            4               0              0
# 117             COMP            3               0              0
# 132             COMP            2               0              0
# 137             COMP            2               0              0
# 146             COMP            1               0              0
# 150             COMP            2               0              0
# 162             COMP            4               2              0
# 223               KC            1               0              0
# 228               KC            2               0              0
# 229               KC            1               0              0
# 237           RETAIL            1               0              0
# 254             COMP            2               0              0
# 275             COMP            1               0              0
# 295             COMP            2               0              0
# 307           RETAIL            2               0              0
# 356           RETAIL            2               0              0
# 366           RETAIL            2               0              0
# 446           RETAIL            2               0              0
# 466           RETAIL            2               0              0
# 520           RETAIL            2               0              0
#
#         Contact Type Odyssey Members
# 1    Email and Phone              NO
# 75        Email Only              NO
# 77   Email and Phone              NO
# 82   Email and Phone              NO
# 87   Email and Phone              NO
# 89        Email Only              NO
# 92   Email and Phone              NO
# 94   Email and Phone              NO
# 98        Email Only              NO
# 99   Email and Phone              NO
# 100  Email and Phone              NO
# 117  Email and Phone              NO
# 132  Email and Phone              NO
# 137  Email and Phone              NO
# 146  Email and Phone              NO
# 150  Email and Phone              NO
# 162  Email and Phone              NO
# 223  Email and Phone              NO
# 228  Email and Phone              NO
# 229  Email and Phone              NO
# 237  Email and Phone              NO
# 254  Email and Phone              NO
# 275  Email and Phone              NO
# 295  Email and Phone              NO
# 307  Email and Phone              NO
# 356  Email and Phone              NO
# 366  Email and Phone              NO
# 446  Email and Phone              NO
# 466  Email and Phone              NO
# 520  Email and Phone              NO
#
# [30 rows x 36 columns]

# %%
df_analytic.drop(df_analytic.loc[
    
    df_analytic['TelNo'].isin(df_phone['Mobile']) | 
    df_analytic['MobileNo'].isin(df_phone['Mobile']) |

    df_analytic['Email'].isin(df_email['Email'])
].index, inplace=True)

df_analytic.reset_index(drop=True, inplace=True)

count_after_dedup_member = df_analytic.shape[0]

# %%
count_data_akhir = df_analytic.shape[0]

# %%
df_analytic.sort_values('DateDepart', ascending=True, inplace=True)
df_analytic.reset_index(drop=True, inplace=True)
df_analytic
# Out:
#     Booking_Id     Lead Brand Lead Sub- Brand  Lead Source  \
# 0     KB050554  Karma Resorts           Other  Past Guests
# 1     KK072052  Karma Resorts           Other  Past Guests
# 2     KK074035  Karma Resorts           Other  Past Guests
# 3     KB048757  Karma Resorts           Other  Past Guests
# 4     KB050561  Karma Resorts           Other  Past Guests
# ..         ...            ...             ...          ...
# 489  KLM007590  Karma Resorts           Other  Past Guests
# 490   KB043228  Karma Resorts           Other  Past Guests
# 491  KSM013043  Karma Resorts           Other  Past Guests
# 492   KK060167  Karma Resorts           Other  Past Guests
# 493  KSM013413  Karma Resorts           Other  Past Guests
#
#                 Resort_Name ProfileRef Salutation         First_Name  \
# 0             Karma Bavaria   PF313988       Herr             Robert
# 1             Karma Kandara   PF308301      empty               Minh
# 2             Karma Kandara   PF298445         Mr  Tan Ridho Andrean
# 3             Karma Bavaria   PF307021      empty            Lavinia
# 4             Karma Bavaria   PF314029       Herr             Dmitro
# ..                      ...        ...        ...                ...
# 489  Karma Lake of Menteith   PF295881      empty          Elizabeth
# 490           Karma Bavaria   PF278989      empty          Dominique
# 491        Karma St Martins   PF015162         Dr                Ann
# 492           Karma Kandara   PF284590         Mr             Satish
# 493        Karma St Martins   PF279994        Mrs                  C
#
#         Surname   Gender  ...           DateDepart No. of Nights  \
# 0        Schulz  Unknown  ...  2025-05-08 00:00:00             1
# 1        Nguyen  Unknown  ...  2025-05-08 00:00:00             3
# 2             W     Male  ...  2025-05-08 00:00:00             3
# 3       Siebert  Unknown  ...  2025-05-08 00:00:00             3
# 4    Lozins'Kii     Male  ...  2025-05-08 00:00:00             1
# ..          ...      ...  ...                  ...           ...
# 489       Mckie  Unknown  ...  2025-06-15 00:00:00             1
# 490      Mytanz  Unknown  ...  2025-06-15 00:00:00             2
# 491       Frost  Unknown  ...  2025-06-16 00:00:00             1
# 492         Raj     Male  ...  2025-06-16 00:00:00             5
# 493       Jones  Unknown  ...  2025-06-16 00:00:00             2
#
#     Market_Segment Media_Code Media Code Group No. of Adult No. of Children  \
# 0              OTA        OTA           RETAIL            2               0
# 1              OTA        OTA           RETAIL            2               0
# 2        HOUSE_USE      PRESS            MEDIA            2               0
# 3              OTA        OTA           RETAIL            4               0
# 4              OTA        OTA           RETAIL            4               0
# ..             ...        ...              ...          ...             ...
# 489            OTA        OTA           RETAIL            1               0
# 490            OTA        OTA           RETAIL            2               1
# 491            DIR     WALKIN           RETAIL            1               0
# 492        DIGITAL       GHPA          DIGITAL            2               0
# 493             TA         TA           RETAIL            2               0
#
#     No. of Infants     Contact Type Odyssey Members
# 0                0  Email and Phone              NO
# 1                0  Email and Phone              NO
# 2                0  Email and Phone              NO
# 3                0  Email and Phone              NO
# 4                0  Email and Phone              NO
# ..             ...              ...             ...
# 489              0  Email and Phone              NO
# 490              0  Email and Phone              NO
# 491              0  Email and Phone              NO
# 492              0  Email and Phone              NO
# 493              0  Email and Phone              NO
#
# [494 rows x 36 columns]

# %%
df_analytic['DOB'].loc[df_analytic['DOB']=='']
# Out:
# Series([], Name: DOB, dtype: string)

# %%
df_analytic['DOB'].replace('empty', '', inplace=True)
dob_con_date = pd.to_datetime(df_analytic['DOB'], errors='coerce')
dob_date = dob_con_date.dt.strftime('%Y-%m-%d')

arr_con_date = pd.to_datetime(df_analytic['DateArrival'])
arr_date = arr_con_date.dt.strftime('%Y-%m-%d')

dep_con_date = pd.to_datetime(df_analytic['DateDepart'])
dep_date = dep_con_date.dt.strftime('%Y-%m-%d')

df_analytic['DOB'] = dob_date
df_analytic['DateArrival'] = arr_date
df_analytic['DateDepart'] = dep_date
# Out:
# C:\Users\fajar.fatoni\AppData\Local\Temp\ipykernel_18388\1513714307.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_analytic['DOB'].replace('empty', '', inplace=True)

# %%
df_analytic.replace('empty', '', inplace=True)

df_analytic.sort_values('DateDepart', ascending=True, inplace=True)
df_analytic.reset_index(drop=True, inplace=True)
df_analytic
# Out:
#     Booking_Id     Lead Brand Lead Sub- Brand  Lead Source  \
# 0     KB050554  Karma Resorts           Other  Past Guests
# 1     KK072052  Karma Resorts           Other  Past Guests
# 2     KK074035  Karma Resorts           Other  Past Guests
# 3     KB048757  Karma Resorts           Other  Past Guests
# 4     KB050561  Karma Resorts           Other  Past Guests
# ..         ...            ...             ...          ...
# 489  KLM007590  Karma Resorts           Other  Past Guests
# 490   KB043228  Karma Resorts           Other  Past Guests
# 491   KK060167  Karma Resorts           Other  Past Guests
# 492  KSM013043  Karma Resorts           Other  Past Guests
# 493  KSM013413  Karma Resorts           Other  Past Guests
#
#                 Resort_Name ProfileRef Salutation         First_Name  \
# 0             Karma Bavaria   PF313988       Herr             Robert
# 1             Karma Kandara   PF308301                          Minh
# 2             Karma Kandara   PF298445         Mr  Tan Ridho Andrean
# 3             Karma Bavaria   PF307021                       Lavinia
# 4             Karma Bavaria   PF314029       Herr             Dmitro
# ..                      ...        ...        ...                ...
# 489  Karma Lake of Menteith   PF295881                     Elizabeth
# 490           Karma Bavaria   PF278989                     Dominique
# 491           Karma Kandara   PF284590         Mr             Satish
# 492        Karma St Martins   PF015162         Dr                Ann
# 493        Karma St Martins   PF279994        Mrs                  C
#
#         Surname   Gender  ...  DateDepart No. of Nights Market_Segment  \
# 0        Schulz  Unknown  ...  2025-05-08             1            OTA
# 1        Nguyen  Unknown  ...  2025-05-08             3            OTA
# 2             W     Male  ...  2025-05-08             3      HOUSE_USE
# 3       Siebert  Unknown  ...  2025-05-08             3            OTA
# 4    Lozins'Kii     Male  ...  2025-05-08             1            OTA
# ..          ...      ...  ...         ...           ...            ...
# 489       Mckie  Unknown  ...  2025-06-15             1            OTA
# 490      Mytanz  Unknown  ...  2025-06-15             2            OTA
# 491         Raj     Male  ...  2025-06-16             5        DIGITAL
# 492       Frost  Unknown  ...  2025-06-16             1            DIR
# 493       Jones  Unknown  ...  2025-06-16             2             TA
#
#     Media_Code Media Code Group No. of Adult No. of Children No. of Infants  \
# 0          OTA           RETAIL            2               0              0
# 1          OTA           RETAIL            2               0              0
# 2        PRESS            MEDIA            2               0              0
# 3          OTA           RETAIL            4               0              0
# 4          OTA           RETAIL            4               0              0
# ..         ...              ...          ...             ...            ...
# 489        OTA           RETAIL            1               0              0
# 490        OTA           RETAIL            2               1              0
# 491       GHPA          DIGITAL            2               0              0
# 492     WALKIN           RETAIL            1               0              0
# 493         TA           RETAIL            2               0              0
#
#         Contact Type Odyssey Members
# 0    Email and Phone              NO
# 1    Email and Phone              NO
# 2    Email and Phone              NO
# 3    Email and Phone              NO
# 4    Email and Phone              NO
# ..               ...             ...
# 489  Email and Phone              NO
# 490  Email and Phone              NO
# 491  Email and Phone              NO
# 492  Email and Phone              NO
# 493  Email and Phone              NO
#
# [494 rows x 36 columns]

# %%
print("==========================================================")
print("Summary")
print("==========================================================")
print("Jumlah Data Setelah Script Past Guest Sebelumnya : "+str(count_data_awal))
print("Jumlah Data Yang Duplicate : "+str(count_duplicate_general))
print("Jumlah Data Setelah Hapus Duplicate : "+str(count_after_dedup_duplicate))
print("Jumlah Data Yang Termasuk Member: "+str(count_dedup_member))
print("Jumlah Data Setelah Hapus Member : "+str(count_after_dedup_member))
print("Jumlah Data Akhir : "+str(count_data_akhir))
# Out:
# ==========================================================
# Summary
# ==========================================================
# Jumlah Data Setelah Script Past Guest Sebelumnya : 707
# Jumlah Data Yang Duplicate : 183
# Jumlah Data Setelah Hapus Duplicate : 524
# Jumlah Data Yang Termasuk Member: 30
# Jumlah Data Setelah Hapus Member : 494
# Jumlah Data Akhir : 494

# %%
df_analytic.to_excel(r'C:\Users\fajar.fatoni\Documents\Python\Data\final_analytics.xlsx', index=False)
