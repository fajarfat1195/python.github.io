# %%
import pandas as pd
import re

import past_guest_module as pm

import sys
sys.path.append('../zoho_data_app/')

import main_module as m

# %load_ext autoreload
# %autoreload 2

# %%
cols = ['Account ID', 'FirstName', 'lastname', 'Country', 'Email', 'Phone',
       'AcStatus', 'Servicing Office','KarmaClubProgram']

# %%
path = r'C:\Users\fajar\Documents\Python\Data\KCC cc-cl\2024\Sep\22 Sep - 30 Sep\KCE CC CL 22 Sep - 30 Sep.xlsx'
df_kce = pd.read_excel(path, dtype='string', sheet_name='Sheet1', usecols=cols)
count_data_awal = df_kce.shape[0]
df_kce
# Out:
#     Account ID FirstName   lastname    Country  \
# 0      1205238     Clive    Whittle  Australia
# 1      1205203    Pratap    Thakker  Australia
# 2      1205014   Mohamed     Sharif  Australia
# 3      1204827    Roshan   Jhoomuck  Australia
# 4      1204704     Trent     Leahey  Australia
# ..         ...       ...        ...        ...
# 739    1204703   Michael       Winn       <NA>
# 740    1204664    Victor     Sydnor       <NA>
# 741    1204817       Anu  Ahluwalia       <NA>
# 742    1205261     Arash       Asif       <NA>
# 743    1204997    Manuel     Arruda       <NA>
#
#                                Email        Phone AcStatus  \
# 0     clivewhittle195@btinternet.com  44136472014   ACTIVE
# 1                   pktsyd@gmail.com  61400981980   ACTIVE
# 2        mohamedsharif6699@gmail.com  61401255653   ACTIVE
# 3           roshanjhoomuck@yahoo.com  61402663438   ACTIVE
# 4    nicoletrudgett94@outlook.com.au  61402822050   ACTIVE
# ..                               ...          ...      ...
# 739                mawgoat@gmail.com  17189307113   ACTIVE
# 740             tonirosety@yahoo.com  17472329878   ACTIVE
# 741            ahluwalia21@gmail.com  18327045745   ACTIVE
# 742          arashasif2021@gmail.com  19173450885   ACTIVE
# 743         manuelarruda53@yahoo.com  19515156073   ACTIVE
#
#        Servicing Office       KarmaClubProgram
# 0    KC EXPERIENCE Bali     Vietnam Sales Deck
# 1    KC EXPERIENCE Bali    Jimbaran Sales Deck
# 2    KC EXPERIENCE Bali  Petitenget Sales Deck
# 3    KC EXPERIENCE Bali  Petitenget Sales Deck
# 4    KC EXPERIENCE Bali  Petitenget Sales Deck
# ..                  ...                    ...
# 739  KC EXPERIENCE Bali  Petitenget Sales Deck
# 740  KC EXPERIENCE Bali  Petitenget Sales Deck
# 741  KC EXPERIENCE Bali  Petitenget Sales Deck
# 742  KC EXPERIENCE Bali    Jimbaran Sales Deck
# 743  KC EXPERIENCE Bali    Jimbaran Sales Deck
#
# [744 rows x 9 columns]

# %%
df_kce.columns
# Out:
# Index(['Account ID', 'FirstName', 'lastname', 'Country', 'Email', 'Phone',
#        'AcStatus', 'Servicing Office', 'KarmaClubProgram'],
#       dtype='object')

# %%
df_kce.rename(columns = {
    'Account ID':'number', 
    'AcStatus':'Account Status',
    'KarmaClubProgram':'Karma Club Program',
    }, inplace = True)

# %%
df_kce.fillna('empty', inplace=True)

# %%
path = r'G:\.shortcut-targets-by-id\0B_d3smBjzo04UUNBME5GOVhoMjA\_ODYSSEY\Phone Members.xlsx'
df_phone_member_odd = pd.read_excel(path, dtype='string', sheet_name='Sheet1')

path = r'G:\.shortcut-targets-by-id\0B_d3smBjzo04UUNBME5GOVhoMjA\_ODYSSEY\Email Members.xlsx'
df_email_member_odd = pd.read_excel(path, dtype='string', sheet_name='Sheet1')

path = r'G:\.shortcut-targets-by-id\0B_d3smBjzo04UUNBME5GOVhoMjA\_ODYSSEY\KCE Members.xlsx'
df_phone_member_kce = pd.read_excel(path, dtype='string', sheet_name='Phone')

path = r'G:\.shortcut-targets-by-id\0B_d3smBjzo04UUNBME5GOVhoMjA\_ODYSSEY\KCE Members.xlsx'
df_email_member_kce = pd.read_excel(path, dtype='string', sheet_name='Email')

# %%
m.clean_number(df_kce, 'Phone')
m.replace_not_valid_to_empty(df_kce, 'Phone')
df_kce['Email'] = m.lowercase(df_kce, 'Email')
m.clean_space(df_kce, 'Email')

m.clean_number(df_phone_member_odd, 'Mobile')
df_email_member_odd['Email'] = m.lowercase(df_email_member_odd, 'Email')
m.clean_space(df_email_member_odd, 'Email')

m.clean_number(df_phone_member_kce, 'Phone')
df_email_member_kce['Email'] = m.lowercase(df_email_member_kce, 'Email')
m.clean_space(df_email_member_kce, 'Email')
# Out:
# 0            aameercok@gmail.com.com
# 1                imerwan@hotmail.com
# 2                mkptech15@gmail.com
# 3          sovitmittal2000@yahoo.com
# 4            smritidas1431@gmail.com
#                     ...
# 87766        kuntz.michael@gmail.com
# 87767              mawgoat@gmail.com
# 87768           tonirosety@yahoo.com
# 87769    vidhivaghela.2009@gmail.com
# 87770             vkontsev@gmail.com
# Name: Email, Length: 87771, dtype: string

# %%
pm.email_correction(df_kce, 'Email')
df_kce
# Out:
#       number FirstName   lastname    Country                            Email  \
# 0    1205238     Clive    Whittle  Australia   clivewhittle195@btinternet.com
# 1    1205203    Pratap    Thakker  Australia                 pktsyd@gmail.com
# 2    1205014   Mohamed     Sharif  Australia      mohamedsharif6699@gmail.com
# 3    1204827    Roshan   Jhoomuck  Australia         roshanjhoomuck@yahoo.com
# 4    1204704     Trent     Leahey  Australia  nicoletrudgett94@outlook.com.au
# ..       ...       ...        ...        ...                              ...
# 739  1204703   Michael       Winn      empty                mawgoat@gmail.com
# 740  1204664    Victor     Sydnor      empty             tonirosety@yahoo.com
# 741  1204817       Anu  Ahluwalia      empty            ahluwalia21@gmail.com
# 742  1205261     Arash       Asif      empty          arashasif2021@gmail.com
# 743  1204997    Manuel     Arruda      empty         manuelarruda53@yahoo.com
#
#            Phone Account Status    Servicing Office     Karma Club Program
# 0    44136472014         ACTIVE  KC EXPERIENCE Bali     Vietnam Sales Deck
# 1    61400981980         ACTIVE  KC EXPERIENCE Bali    Jimbaran Sales Deck
# 2    61401255653         ACTIVE  KC EXPERIENCE Bali  Petitenget Sales Deck
# 3    61402663438         ACTIVE  KC EXPERIENCE Bali  Petitenget Sales Deck
# 4    61402822050         ACTIVE  KC EXPERIENCE Bali  Petitenget Sales Deck
# ..           ...            ...                 ...                    ...
# 739  17189307113         ACTIVE  KC EXPERIENCE Bali  Petitenget Sales Deck
# 740  17472329878         ACTIVE  KC EXPERIENCE Bali  Petitenget Sales Deck
# 741  18327045745         ACTIVE  KC EXPERIENCE Bali  Petitenget Sales Deck
# 742  19173450885         ACTIVE  KC EXPERIENCE Bali    Jimbaran Sales Deck
# 743  19515156073         ACTIVE  KC EXPERIENCE Bali    Jimbaran Sales Deck
#
# [744 rows x 9 columns]

# %%
count_email_phone_empty = df_kce.loc[(df_kce['Email'] == 'empty') & (df_kce['Phone'] == 'empty')].shape[0]

df_kce.loc[(df_kce['Email'] == 'empty') & (df_kce['Phone'] == 'empty')].to_csv(r'C:\Users\fajar\Documents\Python\Data\cek_email_phone_empty_kce.csv', index=False)

df_kce.drop(df_kce.loc[(df_kce['Email'] == 'empty') & (df_kce['Phone'] == 'empty')].index, inplace=True)
df_kce.reset_index(drop=True, inplace=True)

count_after_email_phone_empty = df_kce.shape[0]

# %%
# Cek leads test
test_leads = df_kce.loc[
    
        df_kce['Email'].str.contains('^test@', flags=re.I, regex=True) |
        df_kce['Email'].str.contains('\+test', flags=re.I, regex=True) |
    
        df_kce['FirstName'].str.contains('^test$', flags=re.I, regex=True) |
        df_kce['lastname'].str.contains('^test$', flags=re.I, regex=True) |

        df_kce['FirstName'].str.contains('test 1', flags=re.I, regex=True) |
        df_kce['lastname'].str.contains('test 2', flags=re.I, regex=True)|
        df_kce['FirstName'].str.contains('test1', flags=re.I, regex=True) |
        df_kce['lastname'].str.contains('test2', flags=re.I, regex=True)|

        df_kce['FirstName'].str.contains(' test ', flags=re.I, regex=True) | 
        df_kce['lastname'].str.contains(' test ', flags=re.I, regex=True) | 
        df_kce['lastname'].str.contains(' test$', flags=re.I, regex=True)
    
    
    ]

count_leads_test = test_leads.shape[0]

test_leads.to_excel(r'C:\Users\fajar\Documents\Python\Data\test_leads.xlsx', index=False)
test_leads
# Out:
# Empty DataFrame
# Columns: [number, FirstName, lastname, Country, Email, Phone, Account Status, Servicing Office, Karma Club Program]
# Index: []

# %%
df_kce.drop(test_leads.index, inplace=True)
df_kce.reset_index(drop=True, inplace=True)

count_after_dedup_test = df_kce.shape[0]

# %%
# Cek Email Karma
email_karma = m.find_karma(df_kce, 'Email')
count_email_karma = email_karma.shape[0]
# email_OTA.to_excel(r'C:\Users\fajar\Documents\Python\Data\email_OTA.xlsx', index=False)

email_karma
# Out:
# Empty DataFrame
# Columns: [number, FirstName, lastname, Country, Email, Phone, Account Status, Servicing Office, Karma Club Program]
# Index: []

# %%
# delete email Karma
count_after_clean_karma = m.delete_karma(df_kce, 'Email')
# zoho_df.to_excel(r'C:\Users\fajar\Documents\Python\Data\after_clean_OTA.xlsx', index=False)

df_kce
# Out:
#       number FirstName   lastname    Country                            Email  \
# 0    1205238     Clive    Whittle  Australia   clivewhittle195@btinternet.com
# 1    1205203    Pratap    Thakker  Australia                 pktsyd@gmail.com
# 2    1205014   Mohamed     Sharif  Australia      mohamedsharif6699@gmail.com
# 3    1204827    Roshan   Jhoomuck  Australia         roshanjhoomuck@yahoo.com
# 4    1204704     Trent     Leahey  Australia  nicoletrudgett94@outlook.com.au
# ..       ...       ...        ...        ...                              ...
# 739  1204703   Michael       Winn      empty                mawgoat@gmail.com
# 740  1204664    Victor     Sydnor      empty             tonirosety@yahoo.com
# 741  1204817       Anu  Ahluwalia      empty            ahluwalia21@gmail.com
# 742  1205261     Arash       Asif      empty          arashasif2021@gmail.com
# 743  1204997    Manuel     Arruda      empty         manuelarruda53@yahoo.com
#
#            Phone Account Status    Servicing Office     Karma Club Program
# 0    44136472014         ACTIVE  KC EXPERIENCE Bali     Vietnam Sales Deck
# 1    61400981980         ACTIVE  KC EXPERIENCE Bali    Jimbaran Sales Deck
# 2    61401255653         ACTIVE  KC EXPERIENCE Bali  Petitenget Sales Deck
# 3    61402663438         ACTIVE  KC EXPERIENCE Bali  Petitenget Sales Deck
# 4    61402822050         ACTIVE  KC EXPERIENCE Bali  Petitenget Sales Deck
# ..           ...            ...                 ...                    ...
# 739  17189307113         ACTIVE  KC EXPERIENCE Bali  Petitenget Sales Deck
# 740  17472329878         ACTIVE  KC EXPERIENCE Bali  Petitenget Sales Deck
# 741  18327045745         ACTIVE  KC EXPERIENCE Bali  Petitenget Sales Deck
# 742  19173450885         ACTIVE  KC EXPERIENCE Bali    Jimbaran Sales Deck
# 743  19515156073         ACTIVE  KC EXPERIENCE Bali    Jimbaran Sales Deck
#
# [744 rows x 9 columns]

# %%
find_member_oddysey = df_kce.copy()

find_member_oddysey.loc[find_member_oddysey['Phone'].isin(df_phone_member_odd['Mobile']), 'Same Value Find'] = 'Member-Mobile' 

find_member_oddysey.loc[find_member_oddysey['Email'].isin(df_email_member_odd['Email']), 'Same Value Find'] = 'Member-Email'
find_member_oddysey.drop(find_member_oddysey.loc[find_member_oddysey['Same Value Find'].isna()].index, inplace=True)

find_member_oddysey.replace('empty', '', inplace=True)

find_member_oddysey.to_csv(r'C:\Users\fajar\Documents\Python\Data\cek_member_odyssey.csv', index=False)

# %%
count_dedup_member_odd = df_kce.loc[
    
    df_kce['Phone'].isin(df_phone_member_odd['Mobile']) | 
    df_kce['Email'].isin(df_email_member_odd['Email'])
].shape[0]

df_kce.loc[
    
    df_kce['Phone'].isin(df_phone_member_odd['Mobile']) | 
    df_kce['Email'].isin(df_email_member_odd['Email'])
]
# Out:
#       number         FirstName  lastname Country  \
# 170  1205267        Dharmendra    Sharma   India
# 268  1202465      MADHAVPRASAD  KULKARNI   India
# 353  1205475             Rajiv    Chawla   India
# 434  1204885            NISHAT         S   India
# 457  1204423            Ashish    Sharma   India
# 528  1204277            SANJOG       SUD   India
# 554  1204612           SHELLIM   SOLOMON   India
# 635  1193424  S.R ADI NARAYANA    GUPTHA   India
#
#                              Email         Phone Account Status  \
# 170               sharma@gmail.com  917415795770         ACTIVE
# 268     madhavppkulkarni@gmail.com  918655596885         ACTIVE
# 353  rajiv.chansonmotors@gmail.com  919311504060         ACTIVE
# 434         nishats@rediffmail.com  919606707866         ACTIVE
# 457     ascoolbudyashish@gmail.com  919701059089         ACTIVE
# 528         sanjog25.sud@gmail.com  919833607140         ACTIVE
# 554       shellimsolomon@gmail.com  919870092019         ACTIVE
# 635             gupthasr@gmail.com  919972766688         ACTIVE
#
#         Servicing Office Karma Club Program
# 170  KC EXPERIENCE India          South Goa
# 268  KC EXPERIENCE India              empty
# 353  KC EXPERIENCE India          South Goa
# 434  KC EXPERIENCE India              empty
# 457  KC EXPERIENCE India              empty
# 528  KC EXPERIENCE India              empty
# 554  KC EXPERIENCE India              empty
# 635  KC EXPERIENCE India              empty

# %%
df_kce.drop(df_kce.loc[
    
    df_kce['Phone'].isin(df_phone_member_odd['Mobile']) | 
    df_kce['Email'].isin(df_email_member_odd['Email'])
].index, inplace=True)

df_kce.reset_index(drop=True, inplace=True)

count_after_dedup_member_odd = df_kce.shape[0]
df_kce
# Out:
#       number FirstName   lastname    Country                            Email  \
# 0    1205238     Clive    Whittle  Australia   clivewhittle195@btinternet.com
# 1    1205203    Pratap    Thakker  Australia                 pktsyd@gmail.com
# 2    1205014   Mohamed     Sharif  Australia      mohamedsharif6699@gmail.com
# 3    1204827    Roshan   Jhoomuck  Australia         roshanjhoomuck@yahoo.com
# 4    1204704     Trent     Leahey  Australia  nicoletrudgett94@outlook.com.au
# ..       ...       ...        ...        ...                              ...
# 731  1204703   Michael       Winn      empty                mawgoat@gmail.com
# 732  1204664    Victor     Sydnor      empty             tonirosety@yahoo.com
# 733  1204817       Anu  Ahluwalia      empty            ahluwalia21@gmail.com
# 734  1205261     Arash       Asif      empty          arashasif2021@gmail.com
# 735  1204997    Manuel     Arruda      empty         manuelarruda53@yahoo.com
#
#            Phone Account Status    Servicing Office     Karma Club Program
# 0    44136472014         ACTIVE  KC EXPERIENCE Bali     Vietnam Sales Deck
# 1    61400981980         ACTIVE  KC EXPERIENCE Bali    Jimbaran Sales Deck
# 2    61401255653         ACTIVE  KC EXPERIENCE Bali  Petitenget Sales Deck
# 3    61402663438         ACTIVE  KC EXPERIENCE Bali  Petitenget Sales Deck
# 4    61402822050         ACTIVE  KC EXPERIENCE Bali  Petitenget Sales Deck
# ..           ...            ...                 ...                    ...
# 731  17189307113         ACTIVE  KC EXPERIENCE Bali  Petitenget Sales Deck
# 732  17472329878         ACTIVE  KC EXPERIENCE Bali  Petitenget Sales Deck
# 733  18327045745         ACTIVE  KC EXPERIENCE Bali  Petitenget Sales Deck
# 734  19173450885         ACTIVE  KC EXPERIENCE Bali    Jimbaran Sales Deck
# 735  19515156073         ACTIVE  KC EXPERIENCE Bali    Jimbaran Sales Deck
#
# [736 rows x 9 columns]

# %%
find_member_kce = df_kce.copy()

find_member_kce.loc[find_member_kce['Phone'].isin(df_phone_member_kce['Phone']), 'Same Value Find'] = 'Member-KCE-Mobile' 

find_member_kce.loc[find_member_kce['Email'].isin(df_email_member_kce['Email']), 'Same Value Find'] = 'Member-KCE-Email'
find_member_kce.drop(find_member_kce.loc[find_member_kce['Same Value Find'].isna()].index, inplace=True)

find_member_kce.replace('empty', '', inplace=True)

find_member_kce.to_csv(r'C:\Users\fajar\Documents\Python\Data\cek_member_kce.csv', index=False)

# %%
count_dedup_member_kce = df_kce.loc[
    
    df_kce['Phone'].isin(df_phone_member_kce['Phone']) | 
    df_kce['Email'].isin(df_email_member_kce['Email'])

].shape[0]

df_kce.loc[
    
    df_kce['Phone'].isin(df_phone_member_kce['Phone']) | 
    df_kce['Email'].isin(df_email_member_kce['Email'])
]
# Out:
#       number FirstName   lastname    Country                            Email  \
# 3    1204827    Roshan   Jhoomuck  Australia         roshanjhoomuck@yahoo.com
# 4    1204704     Trent     Leahey  Australia  nicoletrudgett94@outlook.com.au
# 6    1204806      Paul     Dunlop  Australia            dunlop.28@hotmail.com
# 7    1204675     Grant     Cullen  Australia         sara.cullen.88@gmail.com
# 19   1204804     Geoff  Den Elzen  Australia            gdenelzen60@gmail.com
# ..       ...       ...        ...        ...                              ...
# 725  1204813     Dawid      Bator        USA        batorentreprise@gmail.com
# 728  1204739      Vlad  Kontsevoi      empty               vkontsev@gmail.com
# 731  1204703   Michael       Winn      empty                mawgoat@gmail.com
# 732  1204664    Victor     Sydnor      empty             tonirosety@yahoo.com
# 733  1204817       Anu  Ahluwalia      empty            ahluwalia21@gmail.com
#
#            Phone Account Status    Servicing Office     Karma Club Program
# 3    61402663438         ACTIVE  KC EXPERIENCE Bali  Petitenget Sales Deck
# 4    61402822050         ACTIVE  KC EXPERIENCE Bali  Petitenget Sales Deck
# 6    61405204926         ACTIVE  KC EXPERIENCE Bali    Jimbaran Sales Deck
# 7    61405379353         ACTIVE  KC EXPERIENCE Bali    Jimbaran Sales Deck
# 19   61410258933         ACTIVE  KC EXPERIENCE Bali    Jimbaran Sales Deck
# ..           ...            ...                 ...                    ...
# 725  16462589774         ACTIVE  KC EXPERIENCE Bali  Petitenget Sales Deck
# 728  13122312884         ACTIVE  KC EXPERIENCE Bali  Petitenget Sales Deck
# 731  17189307113         ACTIVE  KC EXPERIENCE Bali  Petitenget Sales Deck
# 732  17472329878         ACTIVE  KC EXPERIENCE Bali  Petitenget Sales Deck
# 733  18327045745         ACTIVE  KC EXPERIENCE Bali  Petitenget Sales Deck
#
# [163 rows x 9 columns]

# %%
df_kce.drop(df_kce.loc[
    
    df_kce['Phone'].isin(df_phone_member_kce['Phone']) | 
    df_kce['Email'].isin(df_email_member_kce['Email'])
].index, inplace=True)

df_kce.reset_index(drop=True, inplace=True)

count_after_dedup_member_kce = df_kce.shape[0]
df_kce
# Out:
#       number FirstName    lastname    Country                           Email  \
# 0    1205238     Clive     Whittle  Australia  clivewhittle195@btinternet.com
# 1    1205203    Pratap     Thakker  Australia                pktsyd@gmail.com
# 2    1205014   Mohamed      Sharif  Australia     mohamedsharif6699@gmail.com
# 3    1205235     Ketan      Khanse  Australia           ketankhanse@yahoo.com
# 4    1205910    Andrew       Leach  Australia         livgoroncy@yahoo.com.au
# ..       ...       ...         ...        ...                             ...
# 568  1205597   Michael  Southworth      Wales      mikesouthworth96@gmail.com
# 569  1205229      Alan         Yee      empty              ayee54@comcast.net
# 570  1205012   Anthony     Sanchez      empty           anthony_s08@yahoo.com
# 571  1205261     Arash        Asif      empty         arashasif2021@gmail.com
# 572  1204997    Manuel      Arruda      empty        manuelarruda53@yahoo.com
#
#             Phone Account Status    Servicing Office     Karma Club Program
# 0     44136472014         ACTIVE  KC EXPERIENCE Bali     Vietnam Sales Deck
# 1     61400981980         ACTIVE  KC EXPERIENCE Bali    Jimbaran Sales Deck
# 2     61401255653         ACTIVE  KC EXPERIENCE Bali  Petitenget Sales Deck
# 3     61403441174         ACTIVE  KC EXPERIENCE Bali     Vietnam Sales Deck
# 4     61405667858         ACTIVE  KC EXPERIENCE Bali  Petitenget Sales Deck
# ..            ...            ...                 ...                    ...
# 568  447812345769         ACTIVE  KC EXPERIENCE Bali     Vietnam Sales Deck
# 569   15037571368         ACTIVE  KC EXPERIENCE Bali     Vietnam Sales Deck
# 570   15593556260         ACTIVE  KC EXPERIENCE Bali  Petitenget Sales Deck
# 571   19173450885         ACTIVE  KC EXPERIENCE Bali    Jimbaran Sales Deck
# 572   19515156073         ACTIVE  KC EXPERIENCE Bali    Jimbaran Sales Deck
#
# [573 rows x 9 columns]

# %%
# hitung jumlah duplicate
count_duplicate_general = df_kce.loc[df_kce.duplicated(subset=['Email','Phone'])].shape[0]

df_kce.loc[df_kce.duplicated(subset=['Email','Phone'])]
# Out:
#       number FirstName     lastname  Country                  Email  \
# 92   1205815      Jörg     Kottusch  Germany  joerg.kottusch@web.de
# 362  1205114     MOHAN  GANGADHAR G    India    mohan_gvb@yahoo.com
#
#             Phone Account Status     Servicing Office Karma Club Program
# 92   491773077284         ACTIVE  KC EXPERIENCE India              empty
# 362  919742103856         ACTIVE  KC EXPERIENCE India              empty

# %%
df_kce.drop_duplicates(subset=['Email','Phone'], inplace=True)
df_kce.reset_index(drop=True, inplace=True)

# hitung jumlah setelah value duplicate dihapus
count_after_dedup_duplicate = df_kce.shape[0]

df_kce
# Out:
#       number FirstName    lastname    Country                           Email  \
# 0    1205238     Clive     Whittle  Australia  clivewhittle195@btinternet.com
# 1    1205203    Pratap     Thakker  Australia                pktsyd@gmail.com
# 2    1205014   Mohamed      Sharif  Australia     mohamedsharif6699@gmail.com
# 3    1205235     Ketan      Khanse  Australia           ketankhanse@yahoo.com
# 4    1205910    Andrew       Leach  Australia         livgoroncy@yahoo.com.au
# ..       ...       ...         ...        ...                             ...
# 566  1205597   Michael  Southworth      Wales      mikesouthworth96@gmail.com
# 567  1205229      Alan         Yee      empty              ayee54@comcast.net
# 568  1205012   Anthony     Sanchez      empty           anthony_s08@yahoo.com
# 569  1205261     Arash        Asif      empty         arashasif2021@gmail.com
# 570  1204997    Manuel      Arruda      empty        manuelarruda53@yahoo.com
#
#             Phone Account Status    Servicing Office     Karma Club Program
# 0     44136472014         ACTIVE  KC EXPERIENCE Bali     Vietnam Sales Deck
# 1     61400981980         ACTIVE  KC EXPERIENCE Bali    Jimbaran Sales Deck
# 2     61401255653         ACTIVE  KC EXPERIENCE Bali  Petitenget Sales Deck
# 3     61403441174         ACTIVE  KC EXPERIENCE Bali     Vietnam Sales Deck
# 4     61405667858         ACTIVE  KC EXPERIENCE Bali  Petitenget Sales Deck
# ..            ...            ...                 ...                    ...
# 566  447812345769         ACTIVE  KC EXPERIENCE Bali     Vietnam Sales Deck
# 567   15037571368         ACTIVE  KC EXPERIENCE Bali     Vietnam Sales Deck
# 568   15593556260         ACTIVE  KC EXPERIENCE Bali  Petitenget Sales Deck
# 569   19173450885         ACTIVE  KC EXPERIENCE Bali    Jimbaran Sales Deck
# 570   19515156073         ACTIVE  KC EXPERIENCE Bali    Jimbaran Sales Deck
#
# [571 rows x 9 columns]

# %%
list_UK_EU = pm.get_list_UK_EU()
list_Others = pm.get_list_Others()

# %%
df_kce.loc[df_kce['Country'].isin(list_Others)]
# Out:
#       number FirstName  lastname               Country  \
# 0    1205238     Clive   Whittle             Australia
# 1    1205203    Pratap   Thakker             Australia
# 2    1205014   Mohamed    Sharif             Australia
# 3    1205235     Ketan    Khanse             Australia
# 4    1205910    Andrew     Leach             Australia
# ..       ...       ...       ...                   ...
# 518  1204991     Erika     Meyer          South Africa
# 522  1205429   Deepais    Israni  United Arab Emirates
# 523  1205906    Ashwin  Ravinder  United Arab Emirates
# 524  1205026      John     Rajan  United Arab Emirates
# 565  1205930    Marlon    Bailey                   USA
#
#                               Email         Phone Account Status  \
# 0    clivewhittle195@btinternet.com   44136472014         ACTIVE
# 1                  pktsyd@gmail.com   61400981980         ACTIVE
# 2       mohamedsharif6699@gmail.com   61401255653         ACTIVE
# 3             ketankhanse@yahoo.com   61403441174         ACTIVE
# 4           livgoroncy@yahoo.com.au   61405667858         ACTIVE
# ..                              ...           ...            ...
# 518   erikameyeranderson9@gmail.com  886972252702         ACTIVE
# 522          deepak@researchrmc.com  919920050568         ACTIVE
# 523          ashwinraj671@gmail.com  971567712439         ACTIVE
# 524              john3110@gmail.com  971568813286         ACTIVE
# 565        marlonbailey15@gmail.com   16464098775         ACTIVE
#
#        Servicing Office     Karma Club Program
# 0    KC EXPERIENCE Bali     Vietnam Sales Deck
# 1    KC EXPERIENCE Bali    Jimbaran Sales Deck
# 2    KC EXPERIENCE Bali  Petitenget Sales Deck
# 3    KC EXPERIENCE Bali     Vietnam Sales Deck
# 4    KC EXPERIENCE Bali  Petitenget Sales Deck
# ..                  ...                    ...
# 518  KC EXPERIENCE Bali     Vietnam Sales Deck
# 522  KC EXPERIENCE Bali     Vietnam Sales Deck
# 523  KC EXPERIENCE Bali    Jimbaran Sales Deck
# 524  KC EXPERIENCE Bali     Vietnam Sales Deck
# 565  KC EXPERIENCE Bali     Vietnam Sales Deck
#
# [85 rows x 9 columns]

# %%
df_kce.loc[df_kce['Country'].str.contains('India'), 'Area'] = 'India'
df_kce.loc[df_kce['Country'].isin(list_UK_EU), 'Area'] = 'UK EU'
df_kce.loc[df_kce['Country'].isin(list_Others), 'Area'] = 'Others'

# %%
df_kce.loc[df_kce['Area'] == 'India', 'Batch'] = 'INDIA'
df_kce.loc[df_kce['Area'] == 'UK EU', 'Batch'] = 'NONINDIA'
df_kce.loc[df_kce['Area'] == 'Others', 'Batch'] = 'NONINDIA'

# %%
df_kce.replace('empty', '', inplace=True)

# %%
df_kce.columns
# Out:
# Index(['number', 'FirstName', 'lastname', 'Country', 'Email', 'Phone',
#        'Account Status', 'Servicing Office', 'Karma Club Program', 'Area',
#        'Batch'],
#       dtype='object')

# %%
new_cols = ['number', 'FirstName', 'lastname', 'Country', 'Area', 'Batch', 'Email', 'Phone',
       'Account Status', 'Servicing Office', 'Karma Club Program']

df_kce = df_kce.reindex(columns=new_cols)

# %%
count_data_akhir = df_kce.shape[0]

df_kce.to_csv(r'C:\Users\fajar\Documents\Python\Data\final_kce.csv', index=False)

# %%
print("==========================================================")
print("Summary")
print("==========================================================")
print("Jumlah Data Awal KCE CC-CL : "+str(count_data_awal))
print("Jumlah Data Email dan Phone Kosong : "+str(count_email_phone_empty))
print("Jumlah Data Setelah Hapus Email dan Phone Yang Kosong : "+str(count_after_email_phone_empty))
print("Jumlah Lead Test : "+str(count_leads_test))
print("Jumlah Setelah Clean Lead Test : "+str(count_after_dedup_test))
print("Jumlah Email Karma : "+str(count_email_karma))
print("Jumlah Setelah Clean Email Karma : "+str(count_after_clean_karma))
print("Jumlah Data Yang Terkena Dedup Member Oddysey : "+str(count_dedup_member_odd))
print("Jumlah Data Setelah Dedup Member Oddysey : "+str(count_after_dedup_member_odd))
print("Jumlah Data Yang Terkena Dedup Past Guest KCE : "+str(count_dedup_member_kce))
print("Jumlah Data Setelah Dedup Past Guest KCE : "+str(count_after_dedup_member_kce))
print("Jumlah Data Yang Duplicate : "+str(count_duplicate_general))
print("Jumlah Data Setelah Hapus Duplicate : "+str(count_after_dedup_duplicate))
print("Jumlah Data Akhir : "+str(count_data_akhir))
# Out:
# ==========================================================
# Summary
# ==========================================================
# Jumlah Data Awal KCE CC-CL : 744
# Jumlah Data Email dan Phone Kosong : 0
# Jumlah Data Setelah Hapus Email dan Phone Yang Kosong : 744
# Jumlah Lead Test : 0
# Jumlah Setelah Clean Lead Test : 744
# Jumlah Email Karma : 0
# Jumlah Setelah Clean Email Karma : 744
# Jumlah Data Yang Terkena Dedup Member Oddysey : 8
# Jumlah Data Setelah Dedup Member Oddysey : 736
# Jumlah Data Yang Terkena Dedup Past Guest KCE : 163
# Jumlah Data Setelah Dedup Past Guest KCE : 573
# Jumlah Data Yang Duplicate : 2
# Jumlah Data Setelah Hapus Duplicate : 571
# Jumlah Data Akhir : 571
